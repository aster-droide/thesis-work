# %% [markdown]
# # Perch Multi Seed Validation
# #### 5 Random (but reproducible) seeds are selected for 5 different runs of train/test
# #### Models have been optimised and verified on validation sets thoroughly, running a final train/test evaluation here
# #### The setup:
#
# - 4 fold StratifiedGroupKFold for stratification and ensuring each cat_id group only appears in one set at a time
# - Final scores averaged over the 4 folds
# - For each seed run we will explore the cat_id predictions through majority voting
# - For each run we will explore the potential impact of gender
# - Includes visualisations & analysis
#
# The dataset is highly unbalanced.

# %%
# Standard imports
import numpy as np
import pandas as pd
import random
from datetime import datetime
from collections import Counter

# Sklearn imports
from sklearn.model_selection import train_test_split, GroupShuffleSplit, GroupKFold, StratifiedGroupKFold
from sklearn.preprocessing import LabelEncoder, MinMaxScaler, RobustScaler, StandardScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report
from sklearn.utils.class_weight import compute_class_weight
from sklearn.inspection import permutation_importance

# Imbalanced-learn import
from imblearn.over_sampling import SMOTE

# TensorFlow and Keras imports
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Dropout, Input, BatchNormalization, concatenate
from tensorflow.keras.optimizers import Adam, RMSprop, SGD, Adamax, AdamW
from tensorflow.keras.callbacks import EarlyStopping, Callback
from tensorflow.keras.utils import to_categorical
from keras.regularizers import l1, l2, L1L2

# Optuna import
import optuna

# Visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Import statistical tests
from scipy.stats import levene

from IPython.display import display
import time

# %%
# Track running time (including analysis)
start_time = time.time()

# %%
# Set an initial seed for reproducibility
np.random.seed(42)  

# Generate a list of 5 random seeds
random_seeds = np.random.randint(0, 10000, size=5)
print("Random Seeds:", random_seeds)
# Out:
# Random Seeds: [7270  860 5390 5191 5734]

# %% [markdown]
# #### TOTAL RESULTS ACROSS SEED INITIATION

# %%
# Lists to collect statistics across all CVs
all_losses, all_accuracies, all_precisions, all_recalls, all_f1 = [], [], [], [], []
average_fold_losses, average_fold_accuracies, average_fold_precisions, average_fold_recalls, average_fold_f1 = [], [], [], [], []
all_majority_vote_accuracies, all_majority_vote_details, all_class_stats, all_gender_stats  = [], [], [], []

# training accuracies
all_best_training_acc = []
total_training_acc = []

# %% [markdown]
# ## Define Functions

# %%
def check_initial_group_split(groups_train, groups_test):
    """
    Check if any group is present in both the train and test sets.

    Parameters:
    - groups_train: Array of group identifiers for the train set
    - groups_test: Array of group identifiers for the test set

    Returns:
    - Prints out any groups found in both sets and the count of such groups
    """
    train_groups = set(groups_train)
    test_groups = set(groups_test)
    common_groups = train_groups.intersection(test_groups)

    if common_groups:
        print(f"Warning: Found {len(common_groups)} common groups in both train/validation and test sets: {common_groups}")
    else:
        print("No common groups found between train and test sets.")

# %%
# Function to perform the swaps based on cat_id, ensuring swaps within the same age_group
def swap_cat_id_instances(dataframe, train_val_idx, test_idx, specific_cat_ids):
    for cat_id in specific_cat_ids:
        # Check if the specific cat_id is not in the training set
        if cat_id not in dataframe.iloc[train_val_idx]['cat_id'].values:
            # Get the age_group of this cat_id
            age_group = dataframe[dataframe['cat_id'] == cat_id]['age_group'].iloc[0]
                
            # Find a different cat_id within the same age_group in the train set that is not in the test set
            other_cat_ids_in_age_group = dataframe[(dataframe['age_group'] == age_group) & 
                                                   (dataframe['cat_id'] != cat_id) &
                                                   (~dataframe['cat_id'].isin(dataframe.iloc[test_idx]['cat_id']))]['cat_id'].unique()
            
            # Choose one other cat_id for swapping
            if len(other_cat_ids_in_age_group) > 0:
                other_cat_id = np.random.choice(other_cat_ids_in_age_group)

                # Find all instances of the other_cat_id in the train set
                other_cat_id_train_val_indices = train_val_idx[dataframe.iloc[train_val_idx]['cat_id'] == other_cat_id]
                
                # Find all instances of the specific cat_id in the test set
                cat_id_test_indices = test_idx[dataframe.iloc[test_idx]['cat_id'] == cat_id]
                
                # Swap the indices
                train_val_idx = np.setdiff1d(train_val_idx, other_cat_id_train_val_indices, assume_unique=True)
                test_idx = np.setdiff1d(test_idx, cat_id_test_indices, assume_unique=True)

                train_val_idx = np.concatenate((train_val_idx, cat_id_test_indices))
                test_idx = np.concatenate((test_idx, other_cat_id_train_val_indices))
            else:
                print(f"No alternative cat_id found in the same age_group as {cat_id} for swapping.")
                
    return train_val_idx, test_idx

# %%
# Function to identify differences in groups
def find_group_differences(original, new):
    # Convert numpy arrays to sets for easy difference computation
    original_set = set(original)
    new_set = set(new)
    # Find differences
    moved_to_new = new_set - original_set
    moved_to_original = original_set - new_set
    return moved_to_new, moved_to_original

# %%
# create custom logger function for local logs & stored in a .txt
def logger(message, file=None):
    print(message)
    if file is not None:
        with open(file, "a") as log_file:
            log_file.write(message + "\n")

log_file_path = "multi-seed-val-D13.txt"

# %%
# Set the aesthetic style of the plots
sns.set(style="whitegrid", palette="deep")

# Define a custom color palette
colors = ["#6aabd1", "#b6e2d3", "#dac292"] 
sns.set_palette(sns.color_palette(colors))

# Function to create bar plots with enhanced style
def styled_barplot(data, x, y, title, xlabel, ylabel):
    plt.figure(figsize=(8, 4))
    bar_plot = sns.barplot(x=x, y=y, data=data, errorbar=None, width=0.5)  
    plt.title(title, fontsize=16, fontweight='bold', color="#333333")
    plt.xlabel(xlabel, fontsize=14, fontweight='bold', color="#333333")
    plt.ylabel(ylabel, fontsize=14, fontweight='bold', color="#333333")
    plt.xticks(fontsize=12, color="#333333")
    plt.yticks(fontsize=12, color="#333333")
    plt.ylim(0, 100) 

    # Adding value labels on top of each bar
    for p in bar_plot.patches:
        height = p.get_height()
        # Annotate the height value on the bar
        bar_plot.annotate(f'{height:.1f}', 
                          (p.get_x() + p.get_width() / 2., height), 
                          ha='center', va='center', 
                          xytext=(0, 9), 
                          textcoords='offset points', fontsize=12, color="#333333")

    plt.show()

# %%
def plot_all_metrics(losses, accuracies, precisions, recalls, f1, metrics_across, x_axis_label):
    fig, ax = plt.subplots(figsize=(12, 8))
    seeds = range(1, len(losses) + 1)

    ax.plot(seeds, losses, marker='o', color='blue', label='Loss')
    ax.plot(seeds, accuracies, marker='o', color='green', label='Accuracy')
    ax.plot(seeds, precisions, marker='o', color='red', label='Precision')
    ax.plot(seeds, recalls, marker='o', color='purple', label='Recall')
    ax.plot(seeds, f1, marker='o', color='orange', label='F1 Score')

    ax.set_title(f'Metrics Across {metrics_across}')
    ax.set_xlabel(x_axis_label)
    ax.set_ylabel('Metric Value')
    ax.set_xticks(seeds)
    ax.legend()
    ax.grid(True)

    return fig

# %%
# store epoch accs
class AccuracyHistory(Callback):
    def on_train_begin(self, logs={}):
        self.acc = []

    def on_epoch_end(self, batch, logs={}):
        self.acc.append(logs.get('accuracy'))

# %% [markdown]
# # RANDOM SEED 1

# %% [markdown]
# ## Prepare Data

# %%
# Set a fixed random seed for reproducibility
random.seed(int(random_seeds[0]))
np.random.seed(int(random_seeds[0]))
tf.random.set_seed(int(random_seeds[0]))

# Load datasets
dataframe = pd.read_csv('/Users/astrid/PycharmProjects/perch-2/scripts/perch_embeddings_april_10.csv')
augmented_df = pd.read_csv('/Users/astrid/PycharmProjects/perch-2/scripts/perch_embeddings_augmented_d3.csv')

dataframe.drop('mean_freq', axis=1, inplace=True)

augmented_df.drop('mean_freq', axis=1, inplace=True)
augmented_df.drop('gender', axis=1, inplace=True)

def assign_age_group(age, age_groups):
    for group_name, age_range in age_groups.items():
        if age_range[0] <= age < age_range[1]:
            return group_name
    return 'Unknown'  # For any age that doesn't fit the defined groups

# Define age groups
age_groups = {
    'kitten': (0, 0.5),
    'adult': (0.5, 12),
    'senior': (12, 20)
}

# Create a new column for the age group
dataframe['age_group'] = dataframe['target'].apply(assign_age_group, age_groups=age_groups)
augmented_df['age_group'] = augmented_df['target'].apply(assign_age_group, age_groups=age_groups)

print(dataframe['age_group'].value_counts())
print(augmented_df['age_group'].value_counts())
# Out:
# adult     509
# senior    149
# kitten    135
# Name: age_group, dtype: int64
# senior    900
# kitten    820
# adult     758
# Name: age_group, dtype: int64

# %%
# Separate features and labels
X = dataframe.iloc[:, :-4].values  # all columns except the last four

# Encode the 'age_group' column as integers using LabelEncoder
label_encoder = LabelEncoder()
encoded_y = label_encoder.fit_transform(dataframe['age_group'].values)

# Use the encoded labels for splitting and one-hot encoding
y = encoded_y  

# Convert 'cat_id' column to numpy array to be used as groups array for GroupKFold
groups = dataframe['cat_id'].values

# %%
tf.keras.backend.clear_session()

# %% [markdown]
# ## Run Setup

# %%
all_cat_ids = []
all_predicted_age_groups = []
all_actual_age_groups = []
all_gender = []

# Define the StratifiedGroupKFold splitter for 4 fold CV with random shuffling
outer_cv = StratifiedGroupKFold(n_splits=4, shuffle=True, random_state=int(random_seeds[0]))

# unseen test set metrics
unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1 = [], [], [], [], []

cv_training_acc_total = []
cv_training_acc_best = []

outer_fold = 0

# Use the splitter to generate indices for training and testing sets
# Note: GroupShuffleSplit.split returns indices, so we use it to index the arrays
for train_val_idx, test_idx in outer_cv.split(X, y, groups):
    outer_fold += 1
    logger(f"outer_fold {outer_fold}", file=log_file_path)

    # Convert indices back to DataFrame for easy manipulation
    df_train_val = dataframe.iloc[train_val_idx]
    df_test = dataframe.iloc[test_idx]

    ##############################
    # ASSESSING SPLITS BY CAT_ID #
    ##############################
    
    # Get the distribution of groups
    training_validation_group_distribution = df_train_val['cat_id'].value_counts()  
    testing_group_distribution = df_test['cat_id'].value_counts()  
    
    # Log or print the distribution
    logger(f"Train Set Group Distribution:\n{training_validation_group_distribution}", file=log_file_path)
    logger(f"Testing Set Group Distribution:\n{testing_group_distribution}", file=log_file_path)

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val['gender'].value_counts()
    testing_gender_distribution = df_test['gender'].value_counts()
    
    # Log the distribution
    logger(f"Training Set Gender Distribution BEFORE SWAP:\n{training_gender_distribution}", file=log_file_path)
    logger(f"Testing Set Gender Distribution BEFORE SWAP:\n{testing_gender_distribution}", file=log_file_path)

    # Group by 'age_group' and then list unique 'cat_id' within each age group
    unique_cat_ids_per_age_group_train_val = df_train_val.groupby('age_group')['cat_id'].unique()
    unique_cat_ids_per_age_group_test = df_test.groupby('age_group')['cat_id'].unique()
    
    # Log results
    logger(f"Unique Cat IDs per Age Group in Training/Validation Set:\n{unique_cat_ids_per_age_group_train_val}", file=log_file_path)
    logger(f"Unique Cat IDs per Age Group in Testing Set:\n{unique_cat_ids_per_age_group_test}", file=log_file_path)

    # Calculate the count of unique identifiers per age group for training and testing set
    counts_train_val = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_train_val.items()}
    counts_test = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_test.items()}

    # Log the counts of unique identifiers per age group
    logger(f"Count of Unique Cat IDs per Age Group in Training/Validation Set:\n{counts_train_val}", file=log_file_path)
    logger(f"Count of Unique Cat IDs per Age Group in Testing Set:\n{counts_test}", file=log_file_path)

    #######################################################
    # CONTINUE WITH ENSURING VALID AND APPROPRIATE SPLITS #
    #######################################################
    
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    groups_train_val, groups_test = groups[train_val_idx], groups[test_idx]

    # logging identifier splits 
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)

    # check group splits
    check_initial_group_split(groups_train_val, groups_test)

    # Specify the cat_ids that must be in the training/validation set
    specific_cat_ids = ['000A', '046A']
    
    # Perform the swapping operation
    train_val_idx, test_idx = swap_cat_id_instances(dataframe, train_val_idx, test_idx, specific_cat_ids)
    
    # Re-assign the sets based on the updated indices
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    new_groups_train_val, new_groups_test = groups[train_val_idx], groups[test_idx]

    # Find differences for training and test sets
    moved_to_train_val, removed_from_train_val = find_group_differences(groups_train_val, new_groups_train_val)
    moved_to_test, removed_from_test = find_group_differences(groups_test, new_groups_test)
    
    # Display the results
    logger(f"Moved to Training/Validation Set:\n{moved_to_train_val}", file=log_file_path)
    logger(f"Removed from Training/Validation Set:\n{removed_from_train_val}", file=log_file_path)
    logger(f"Moved to Test Set:\n{moved_to_test}", file=log_file_path)
    logger(f"Removed from Test Set\n{removed_from_test}", file=log_file_path)

    # Update X_train_val, X_test, y_train_val, y_test, groups_train_val, groups_test based on updated indices
    X_train_val = X[train_val_idx]
    y_train_val = y[train_val_idx]
    groups_train_val = groups[train_val_idx]
    
    X_test = X[test_idx]
    y_test = y[test_idx]
    groups_test = groups[test_idx]

    # logging identifier splits again after potential swaps
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"AFTER SWAP - Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"AFTER SWAP - Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)
    
    # Verify the lengths are consistent
    logger(f"Length of X_train_val:\n{len(X_train_val)}", file=log_file_path)
    logger(f"Length of y_train_val:\n{len(y_train_val)}", file=log_file_path)
    logger(f"Length of groups_train_val:\n{len(groups_train_val)}", file=log_file_path)

    # Check group splits once more
    check_initial_group_split(groups_train_val, groups_test)

    # Convert the modified indices back to a DataFrame representing the updated df_train_val
    df_train_val_updated = dataframe.iloc[train_val_idx].copy()
    df_test_updated = dataframe.iloc[test_idx].copy()

    ############################
    # LOGGING AGE GROUP SPLITS #
    ############################

    # Get the distribution of age groups of age groups before the update
    training_validation_age_group_distribution = df_train_val['age_group'].value_counts()
    testing_age_group_distribution = df_test['age_group'].value_counts()
    
    # Logthe distribution
    logger(f"Train Age Group Distribution BEFORE SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution BEFORE SWAP:\n{testing_age_group_distribution}", file=log_file_path)

    # Get the distribution of age groups after the update
    training_validation_age_group_distribution = df_train_val_updated['age_group'].value_counts()
    testing_age_group_distribution = df_test_updated['age_group'].value_counts()
    
    # Log the distribution
    logger(f"Train Age Group Distribution AFTER SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution AFTER SWAP:\n{testing_age_group_distribution}", file=log_file_path)
    
    ########################################################
    # TRACKING FINAL CAT_IDs & GENDER AFTER REDISTRIBUTION #
    ########################################################

    # Get the distribution of groups
    training_validation_group_distribution = df_train_val_updated['cat_id'].value_counts()  
    testing_group_distribution = df_test_updated['cat_id'].value_counts()  

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val_updated['gender'].value_counts()
    testing_gender_distribution = df_test_updated['gender'].value_counts()
    
    logger(f"\n Starting training on unseen test set\n", file=log_file_path)

    ######################
    # ADD AUGMENTED DATA #
    ######################

    # Filter out augmented data derived from groups in the training set
    augmented_df_filtered = augmented_df[augmented_df['cat_id'].isin(groups_train_val)]
    
    # Convert augmented_df_filtered to numpy array (excluding target and other columns)
    augmented_array = augmented_df_filtered.drop(columns=['target', 'cat_id', 'age_group']).values
    
    # Concatenate the filtered augmented data with X_train_val
    X_train_val = np.concatenate([X_train_val, augmented_array])

    # Extract target labels from the filtered augmented DataFrame
    y_augmented = augmented_df_filtered['age_group'].values
    
    # Encode the labels using the same LabelEncoder instance
    y_augmented_encoded = label_encoder.transform(y_augmented)
    
    # Concatenate the encoded augmented labels with y_train_val
    y_train_val = np.concatenate([y_train_val, y_augmented_encoded])

    # Calculate the distribution of age groups in y_train_val
    age_group_distribution = Counter(y_train_val)
    print("Age group distribution:", age_group_distribution)

    # EarlyStopping callback: monitor 'loss' instead of 'val_loss' for the test set
    early_stopping = EarlyStopping(
        monitor='loss',  
        min_delta=0.001, 
        patience=30,  
        verbose=1,  
        restore_best_weights=True  
    )

    accuracy_history = AccuracyHistory()

    # One final shuffle to ensure randomness
    outer_shuffle_idx = np.random.permutation(len(X_train_val))
    X_train_val = X_train_val[outer_shuffle_idx]
    y_train_val = y_train_val[outer_shuffle_idx]
    
    # Scale the features
    scaler_full = StandardScaler().fit(X_train_val)
    X_train_full_scaled = scaler_full.transform(X_train_val)
    X_test_scaled = scaler_full.transform(X_test)
    
    # Encode the labels
    y_train_full_encoded = to_categorical(y_train_val)
    y_test_encoded = to_categorical(y_test)

    #######################
    # BUILD & TRAIN MODEL #
    #######################

    optimizers = {
        'Adamax': Adamax(learning_rate=0.00510251984616472)
    }
    
    # Model definition with dynamic number of layers
    model_full = Sequential()
    model_full.add(Dense(480, activation='relu', input_shape=(X_train_full_scaled.shape[1],)))
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.2011047009431978))  
    model_full.add(Dense(256, activation='relu',)) 
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.14956886311951184))  
    model_full.add(Dense(256, activation='relu'))  
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.42291461228250665))  
    model_full.add(Dense(3, activation='softmax'))  
    
    # Use the optimizer from the parameters
    optimizer = optimizers['Adamax']  # optimizer_key from parameters
    
    # Compile the model
    model_full.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    
    # Train the model on the full training set
    history_full = model_full.fit(X_train_full_scaled, y_train_full_encoded, epochs=1500, batch_size=64,
                                  verbose=1, callbacks=[early_stopping, accuracy_history])
    
    # log epochs
    best_epoch_index = np.argmin(history_full.history['loss'])  
    best_training_accuracy = accuracy_history.acc[best_epoch_index]

    # Append training acc to total  
    all_best_training_acc.append(best_training_accuracy)
    total_training_acc.append(accuracy_history.acc)

    # Append training acc just for this CV
    cv_training_acc_total.append(accuracy_history.acc)
    cv_training_acc_best.append(best_training_accuracy)
    
    # Evaluate the model on the held-out test set
    test_loss, test_accuracy = model_full.evaluate(X_test_scaled, y_test_encoded)

    y_test_pred_prob = model_full.predict(X_test_scaled)
    y_test_pred = np.argmax(y_test_pred_prob, axis=1)  
    y_test_true = np.argmax(y_test_encoded, axis=1)    

    ################################
    # LOG MAJORITY VOTE PER CAT_ID #
    ################################

    # Convert numeric predictions back to age group labels
    predicted_age_groups = label_encoder.inverse_transform(y_test_pred)
    actual_labels = label_encoder.inverse_transform(y_test_true)
    
    # Map predictions and actual labels back to cat_ids
    test_results = pd.DataFrame({
        'cat_id': df_test_updated['cat_id'],
        'predicted_age_group': predicted_age_groups,
        'actual_age_group': actual_labels
    })
    
    # Group by cat_id and aggregate predicted age groups
    majority_votes = test_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
    actual_groups = test_results.groupby('cat_id')['actual_age_group'].first()
    
    # Calculate the accuracy of majority voting
    correct_predictions = (majority_votes == actual_groups).sum()
    total_cats = len(actual_groups)
    majority_vote_accuracy = correct_predictions / total_cats
    
    # Log the accuracy of the majority voting
    logger(f"Majority Vote Accuracy for cat_id for this fold: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

    ####################################################
    # COLLECT PREDICTIONS FOR GENDER & CAT_ID ANALYSIS #
    ####################################################

    # Debugging print statements
    print(f'Before appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Extend lists with current fold results
    all_cat_ids.extend(df_test_updated['cat_id'].tolist())
    all_predicted_age_groups.extend(predicted_age_groups)
    all_actual_age_groups.extend(actual_labels)
    all_gender.extend(df_test_updated['gender'].tolist())

    # Debugging print statements
    print(f'After appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Calculate additional metrics
    test_precision = precision_score(y_test_true, y_test_pred, average='macro')  # Use 'macro' for imbalanced datasets
    test_recall = recall_score(y_test_true, y_test_pred, average='macro')
    test_f1 = f1_score(y_test_true, y_test_pred, average='macro')

    # prepare averages of outer metrics
    unseen_f1.append(test_f1)
    unseen_losses.append(test_loss)
    unseen_accuracies.append(test_accuracy)
    unseen_precisions.append(test_precision)
    unseen_recalls.append(test_recall)

    # Print final test results
    logger(f"Final Test Results - Loss: {test_loss}, Accuracy: {test_accuracy}, Precision: {test_precision}, Recall: {test_recall}, F1 Score: {test_f1}", file=log_file_path)

    # Generate the confusion matrix
    cm = confusion_matrix(y_test, y_test_pred)
    logger(f"Confusion Matrix:\n {cm}", file=log_file_path)

# Calculate the overall average metrics
unseen_set_avg_f1 = np.mean(unseen_f1)
unseen_set_avg_loss = np.mean(unseen_losses)
unseen_set_avg_acc = np.mean(unseen_accuracies)
unseen_set_avg_precision = np.mean(unseen_precisions)
unseen_set_avg_recall = np.mean(unseen_recalls)

logger(f"\nFinal Average F1-Score across all UNSEEN TEST sets: {unseen_set_avg_f1}", file=log_file_path)
logger(f"\nFinal Average Loss across all UNSEEN TEST sets: {unseen_set_avg_loss}", file=log_file_path)
logger(f"\nFinal Average Accuracy across all UNSEEN TEST sets: {unseen_set_avg_acc}", file=log_file_path)
logger(f"\nFinal Average Precision across all UNSEEN TEST sets: {unseen_set_avg_precision}", file=log_file_path)
logger(f"\nFinal Average Recall across all UNSEEN TEST sets: {unseen_set_avg_recall}\n", file=log_file_path)

# Append averages to total lists
average_fold_f1.append(unseen_set_avg_f1)
average_fold_losses.append(unseen_set_avg_loss)
average_fold_accuracies.append(unseen_set_avg_acc)
average_fold_precisions.append(unseen_set_avg_precision)
average_fold_recalls.append(unseen_set_avg_recall)

# Append all to total lists
all_f1.append(unseen_f1)
all_losses.append(unseen_losses)
all_accuracies.append(unseen_accuracies)
all_precisions.append(unseen_precisions)
all_recalls.append(unseen_recalls)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# outer_fold 1
# Train Set Group Distribution:
# 046A    45
# 103A    33
# 002B    30
# 047A    22
# 020A    20
#         ..
# 110A     1
# 064A     1
# 100A     1
# 090A     1
# 024A     1
# Name: cat_id, Length: 85, dtype: int64
# Testing Set Group Distribution:
# 000A    39
# 000B    19
# 019A    17
# 097A    15
# 051A    12
# 063A    11
# 028A    11
# 059A    10
# 040A    10
# 022A     9
# 005A     9
# 013B     8
# 095A     7
# 036A     7
# 039A     6
# 003A     4
# 018A     2
# 087A     2
# 069A     2
# 076A     1
# 091A     1
# 043A     1
# 049A     1
# 041A     1
# 048A     1
# 019B     1
# 026B     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    249
# X    203
# F    133
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# F    98
# X    73
# M    37
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [006A, 033A, 015A, 001A, 103A, 071A, 097B, 074...
# kitten    [044A, 014B, 111A, 046A, 047A, 042A, 109A, 050...
# senior    [093A, 057A, 106A, 104A, 055A, 113A, 116A, 051...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [000A, 028A, 019A, 022A, 095A, 005A, 091A, 039...
# kitten                       [040A, 043A, 049A, 041A, 048A]
# senior                                   [097A, 059A, 051A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 55, 'kitten': 11, 'senior': 19}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 19, 'kitten': 5, 'senior': 3}
# Unique Training/Validation Group IDs:
# ['001A' '002A' '002B' '004A' '006A' '007A' '008A' '009A' '010A' '011A'
#  '012A' '014A' '014B' '015A' '016A' '020A' '021A' '023A' '023B' '024A'
#  '025A' '025B' '025C' '026A' '026C' '027A' '029A' '031A' '032A' '033A'
#  '034A' '035A' '037A' '038A' '042A' '044A' '045A' '046A' '047A' '050A'
#  '051B' '052A' '053A' '054A' '055A' '056A' '057A' '058A' '060A' '061A'
#  '062A' '064A' '065A' '066A' '067A' '068A' '070A' '071A' '072A' '073A'
#  '074A' '075A' '088A' '090A' '092A' '093A' '094A' '096A' '097B' '099A'
#  '100A' '101A' '102A' '103A' '104A' '105A' '106A' '108A' '109A' '110A'
#  '111A' '113A' '115A' '116A' '117A']
# Unique Test Group IDs:
# ['000A' '000B' '003A' '005A' '013B' '018A' '019A' '019B' '022A' '026B'
#  '028A' '036A' '039A' '040A' '041A' '043A' '048A' '049A' '051A' '059A'
#  '063A' '069A' '076A' '087A' '091A' '095A' '097A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'000A'}
# Removed from Training/Validation Set:
# {'009A'}
# Moved to Test Set:
# {'009A'}
# Removed from Test Set
# {'000A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '001A' '002A' '002B' '004A' '006A' '007A' '008A' '010A' '011A'
#  '012A' '014A' '014B' '015A' '016A' '020A' '021A' '023A' '023B' '024A'
#  '025A' '025B' '025C' '026A' '026C' '027A' '029A' '031A' '032A' '033A'
#  '034A' '035A' '037A' '038A' '042A' '044A' '045A' '046A' '047A' '050A'
#  '051B' '052A' '053A' '054A' '055A' '056A' '057A' '058A' '060A' '061A'
#  '062A' '064A' '065A' '066A' '067A' '068A' '070A' '071A' '072A' '073A'
#  '074A' '075A' '088A' '090A' '092A' '093A' '094A' '096A' '097B' '099A'
#  '100A' '101A' '102A' '103A' '104A' '105A' '106A' '108A' '109A' '110A'
#  '111A' '113A' '115A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['000B' '003A' '005A' '009A' '013B' '018A' '019A' '019B' '022A' '026B'
#  '028A' '036A' '039A' '040A' '041A' '043A' '048A' '049A' '051A' '059A'
#  '063A' '069A' '076A' '087A' '091A' '095A' '097A']
# Length of X_train_val:
# 620
# Length of y_train_val:
# 620
# Length of groups_train_val:
# 620
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     352
# kitten    121
# senior    112
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     157
# senior     37
# kitten     14
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     387
# kitten    121
# senior    112
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     122
# senior     37
# kitten     14
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 968, 1: 865, 2: 796})
# Epoch 1/1500
# 42/42 [==============================] - 1s 6ms/step - loss: 0.4388 - accuracy: 0.8490
# Epoch 2/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.1018 - accuracy: 0.9658
# Epoch 3/1500
# 42/42 [==============================] - 0s 7ms/step - loss: 0.0449 - accuracy: 0.9848
# Epoch 4/1500
# 42/42 [==============================] - 0s 7ms/step - loss: 0.0268 - accuracy: 0.9905
# Epoch 5/1500
# 42/42 [==============================] - 0s 8ms/step - loss: 0.0266 - accuracy: 0.9913
# Epoch 6/1500
# 42/42 [==============================] - 0s 8ms/step - loss: 0.0167 - accuracy: 0.9962
# Epoch 7/1500
# 42/42 [==============================] - 0s 8ms/step - loss: 0.0093 - accuracy: 0.9977
# Epoch 8/1500
# 42/42 [==============================] - 0s 8ms/step - loss: 0.0123 - accuracy: 0.9962
# Epoch 9/1500
# 42/42 [==============================] - 0s 7ms/step - loss: 0.0086 - accuracy: 0.9977
# Epoch 10/1500
# 42/42 [==============================] - 0s 9ms/step - loss: 0.0098 - accuracy: 0.9958
# Epoch 11/1500
# 42/42 [==============================] - 0s 7ms/step - loss: 0.0053 - accuracy: 0.9985
# Epoch 12/1500
# 42/42 [==============================] - 0s 7ms/step - loss: 0.0086 - accuracy: 0.9970
# Epoch 13/1500
# 42/42 [==============================] - 0s 7ms/step - loss: 0.0108 - accuracy: 0.9966
# Epoch 14/1500
# 42/42 [==============================] - 0s 8ms/step - loss: 0.0091 - accuracy: 0.9970
# Epoch 15/1500
# 42/42 [==============================] - 0s 8ms/step - loss: 0.0100 - accuracy: 0.9981
# Epoch 16/1500
# 42/42 [==============================] - 1s 19ms/step - loss: 0.0087 - accuracy: 0.9966
# Epoch 17/1500
# 42/42 [==============================] - 0s 7ms/step - loss: 0.0072 - accuracy: 0.9981
# Epoch 18/1500
# 42/42 [==============================] - 1s 15ms/step - loss: 0.0074 - accuracy: 0.9981
# Epoch 19/1500
# 42/42 [==============================] - 0s 10ms/step - loss: 0.0119 - accuracy: 0.9977
# Epoch 20/1500
# 42/42 [==============================] - 0s 7ms/step - loss: 0.0176 - accuracy: 0.9943
# Epoch 21/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0137 - accuracy: 0.9954
# Epoch 22/1500
# 42/42 [==============================] - 0s 9ms/step - loss: 0.0049 - accuracy: 0.9989
# Epoch 23/1500
# 42/42 [==============================] - 0s 9ms/step - loss: 0.0078 - accuracy: 0.9977
# Epoch 24/1500
# 42/42 [==============================] - 0s 8ms/step - loss: 0.0054 - accuracy: 0.9981
# Epoch 25/1500
# 42/42 [==============================] - 0s 7ms/step - loss: 0.0030 - accuracy: 0.9996
# Epoch 26/1500
# 42/42 [==============================] - 0s 7ms/step - loss: 0.0036 - accuracy: 0.9992
# Epoch 27/1500
# 42/42 [==============================] - 0s 9ms/step - loss: 0.0066 - accuracy: 0.9977
# Epoch 28/1500
# 42/42 [==============================] - 0s 8ms/step - loss: 0.0107 - accuracy: 0.9966
# Epoch 29/1500
# 42/42 [==============================] - 0s 8ms/step - loss: 0.0143 - accuracy: 0.9966
# Epoch 30/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0070 - accuracy: 0.9977
# Epoch 31/1500
# 42/42 [==============================] - 0s 7ms/step - loss: 0.0045 - accuracy: 0.9992
# Epoch 32/1500
# 42/42 [==============================] - 0s 8ms/step - loss: 0.0069 - accuracy: 0.9973
# Epoch 33/1500
# 42/42 [==============================] - 0s 9ms/step - loss: 0.0112 - accuracy: 0.9954
# Epoch 34/1500
# 42/42 [==============================] - 1s 21ms/step - loss: 0.0096 - accuracy: 0.9970
# Epoch 35/1500
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0025 - accuracy: 0.9996
# Epoch 36/1500
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0023 - accuracy: 0.9996
# Epoch 37/1500
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0076 - accuracy: 0.9992
# Epoch 38/1500
# 42/42 [==============================] - 0s 8ms/step - loss: 0.0083 - accuracy: 0.9973
# Epoch 39/1500
# 42/42 [==============================] - 0s 11ms/step - loss: 0.0048 - accuracy: 0.9989
# Epoch 40/1500
# 42/42 [==============================] - 1s 14ms/step - loss: 0.0117 - accuracy: 0.9951
# Epoch 41/1500
# 42/42 [==============================] - 0s 8ms/step - loss: 0.0076 - accuracy: 0.9977
# Epoch 42/1500
# 42/42 [==============================] - 0s 7ms/step - loss: 0.0037 - accuracy: 0.9992
# Epoch 43/1500
# 42/42 [==============================] - 0s 7ms/step - loss: 0.0063 - accuracy: 0.9985
# Epoch 44/1500
# 42/42 [==============================] - 0s 7ms/step - loss: 0.0063 - accuracy: 0.9985
# Epoch 45/1500
# 42/42 [==============================] - 0s 9ms/step - loss: 0.0088 - accuracy: 0.9977
# Epoch 46/1500
# 42/42 [==============================] - 0s 8ms/step - loss: 0.0166 - accuracy: 0.9958
# Epoch 47/1500
# 42/42 [==============================] - 0s 8ms/step - loss: 0.0062 - accuracy: 0.9985
# Epoch 48/1500
# 42/42 [==============================] - 0s 8ms/step - loss: 0.0050 - accuracy: 0.9977
# Epoch 49/1500
# 42/42 [==============================] - 0s 8ms/step - loss: 0.0033 - accuracy: 0.9989
# Epoch 50/1500
# 42/42 [==============================] - 0s 8ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 51/1500
# 42/42 [==============================] - 0s 8ms/step - loss: 0.0063 - accuracy: 0.9977
# Epoch 52/1500
# 42/42 [==============================] - 0s 8ms/step - loss: 0.0103 - accuracy: 0.9977
# Epoch 53/1500
# 42/42 [==============================] - 0s 7ms/step - loss: 0.0049 - accuracy: 0.9989
# Epoch 54/1500
# 42/42 [==============================] - 0s 7ms/step - loss: 0.0079 - accuracy: 0.9981
# Epoch 55/1500
# 40/42 [===========================>..] - ETA: 0s - loss: 0.0036 - accuracy: 0.9992Restoring model weights from the end of the best epoch: 25.
# 42/42 [==============================] - 0s 7ms/step - loss: 0.0039 - accuracy: 0.9989
# Epoch 55: early stopping
# 6/6 [==============================] - 0s 2ms/step - loss: 2.1876 - accuracy: 0.7399
# 6/6 [==============================] - 0s 3ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.81 (22/27)
# Before appending - Cat IDs: 0, Predictions: 0, Actuals: 0, Gender: 0
# After appending - Cat IDs: 173, Predictions: 173, Actuals: 173, Gender: 173
# Final Test Results - Loss: 2.1876420974731445, Accuracy: 0.7398843765258789, Precision: 0.6652421652421653, Recall: 0.7219127792898284, F1 Score: 0.6894607159460716
# Confusion Matrix:
#  [[97  6 19]
#  [ 2 12  0]
#  [18  0 19]]
# outer_fold 2
# Train Set Group Distribution:
# 046A    45
# 000A    39
# 103A    33
# 002B    30
# 020A    20
#         ..
# 041A     1
# 092A     1
# 049A     1
# 043A     1
# 026B     1
# Name: cat_id, Length: 82, dtype: int64
# Testing Set Group Distribution:
# 047A    22
# 029A    15
# 097B    14
# 002A    13
# 111A    12
# 042A    11
# 051B     9
# 071A     9
# 072A     9
# 117A     7
# 027A     7
# 099A     6
# 023A     6
# 109A     5
# 025C     4
# 026A     4
# 056A     3
# 012A     3
# 010A     3
# 060A     3
# 006A     3
# 105A     3
# 052A     2
# 054A     2
# 061A     2
# 102A     2
# 037A     2
# 093A     2
# 090A     1
# 024A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    228
# F    195
# X    185
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    91
# M    58
# F    36
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [000A, 033A, 015A, 001A, 103A, 028A, 019A, 074...
# kitten    [044A, 014B, 040A, 046A, 050A, 043A, 049A, 041...
# senior    [097A, 057A, 106A, 104A, 055A, 059A, 113A, 116...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [006A, 071A, 097B, 029A, 072A, 002A, 023A, 027...
# kitten                             [111A, 047A, 042A, 109A]
# senior     [093A, 051B, 054A, 117A, 056A, 061A, 090A, 024A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 56, 'kitten': 12, 'senior': 14}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 18, 'kitten': 4, 'senior': 8}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002B' '003A' '004A' '005A' '007A' '008A' '009A'
#  '011A' '013B' '014A' '014B' '015A' '016A' '018A' '019A' '019B' '020A'
#  '021A' '022A' '023B' '025A' '025B' '026B' '026C' '028A' '031A' '032A'
#  '033A' '034A' '035A' '036A' '038A' '039A' '040A' '041A' '043A' '044A'
#  '045A' '046A' '048A' '049A' '050A' '051A' '053A' '055A' '057A' '058A'
#  '059A' '062A' '063A' '064A' '065A' '066A' '067A' '068A' '069A' '070A'
#  '073A' '074A' '075A' '076A' '087A' '088A' '091A' '092A' '094A' '095A'
#  '096A' '097A' '100A' '101A' '103A' '104A' '106A' '108A' '110A' '113A'
#  '115A' '116A']
# Unique Test Group IDs:
# ['002A' '006A' '010A' '012A' '023A' '024A' '025C' '026A' '027A' '029A'
#  '037A' '042A' '047A' '051B' '052A' '054A' '056A' '060A' '061A' '071A'
#  '072A' '090A' '093A' '097B' '099A' '102A' '105A' '109A' '111A' '117A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002B' '003A' '004A' '005A' '007A' '008A' '009A'
#  '011A' '013B' '014A' '014B' '015A' '016A' '018A' '019A' '019B' '020A'
#  '021A' '022A' '023B' '025A' '025B' '026B' '026C' '028A' '031A' '032A'
#  '033A' '034A' '035A' '036A' '038A' '039A' '040A' '041A' '043A' '044A'
#  '045A' '046A' '048A' '049A' '050A' '051A' '053A' '055A' '057A' '058A'
#  '059A' '062A' '063A' '064A' '065A' '066A' '067A' '068A' '069A' '070A'
#  '073A' '074A' '075A' '076A' '087A' '088A' '091A' '092A' '094A' '095A'
#  '096A' '097A' '100A' '101A' '103A' '104A' '106A' '108A' '110A' '113A'
#  '115A' '116A']
# AFTER SWAP - Unique Test Group IDs:
# ['002A' '006A' '010A' '012A' '023A' '024A' '025C' '026A' '027A' '029A'
#  '037A' '042A' '047A' '051B' '052A' '054A' '056A' '060A' '061A' '071A'
#  '072A' '090A' '093A' '097B' '099A' '102A' '105A' '109A' '111A' '117A']
# Length of X_train_val:
# 608
# Length of y_train_val:
# 608
# Length of groups_train_val:
# 608
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     401
# senior    122
# kitten     85
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     108
# kitten     50
# senior     27
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     401
# senior    122
# kitten     85
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     108
# kitten     50
# senior     27
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 995, 2: 890, 1: 565})
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Epoch 1/1500
# 39/39 [==============================] - 1s 5ms/step - loss: 0.4627 - accuracy: 0.8388
# Epoch 2/1500
# 39/39 [==============================] - 0s 6ms/step - loss: 0.0916 - accuracy: 0.9682
# Epoch 3/1500
# 39/39 [==============================] - 0s 7ms/step - loss: 0.0500 - accuracy: 0.9824
# Epoch 4/1500
# 39/39 [==============================] - 0s 7ms/step - loss: 0.0271 - accuracy: 0.9939
# Epoch 5/1500
# 39/39 [==============================] - 0s 7ms/step - loss: 0.0209 - accuracy: 0.9935
# Epoch 6/1500
# 39/39 [==============================] - 0s 7ms/step - loss: 0.0181 - accuracy: 0.9943
# Epoch 7/1500
# 39/39 [==============================] - 0s 6ms/step - loss: 0.0144 - accuracy: 0.9963
# Epoch 8/1500
# 39/39 [==============================] - 0s 8ms/step - loss: 0.0086 - accuracy: 0.9984
# Epoch 9/1500
# 39/39 [==============================] - 0s 8ms/step - loss: 0.0097 - accuracy: 0.9967
# Epoch 10/1500
# 39/39 [==============================] - 0s 8ms/step - loss: 0.0057 - accuracy: 0.9984
# Epoch 11/1500
# 39/39 [==============================] - 0s 8ms/step - loss: 0.0058 - accuracy: 0.9988
# Epoch 12/1500
# 39/39 [==============================] - 0s 9ms/step - loss: 0.0115 - accuracy: 0.9959
# Epoch 13/1500
# 39/39 [==============================] - 0s 9ms/step - loss: 0.0072 - accuracy: 0.9967
# Epoch 14/1500
# 39/39 [==============================] - 0s 10ms/step - loss: 0.0047 - accuracy: 0.9988
# Epoch 15/1500
# 39/39 [==============================] - 0s 9ms/step - loss: 0.0031 - accuracy: 0.9996
# Epoch 16/1500
# 39/39 [==============================] - 0s 9ms/step - loss: 0.0030 - accuracy: 0.9992
# Epoch 17/1500
# 39/39 [==============================] - 0s 11ms/step - loss: 0.0037 - accuracy: 0.9984
# Epoch 18/1500
# 39/39 [==============================] - 0s 10ms/step - loss: 0.0028 - accuracy: 0.9988
# Epoch 19/1500
# 39/39 [==============================] - 0s 7ms/step - loss: 0.0061 - accuracy: 0.9984
# Epoch 20/1500
# 39/39 [==============================] - 0s 7ms/step - loss: 0.0027 - accuracy: 0.9992
# Epoch 21/1500
# 39/39 [==============================] - 0s 8ms/step - loss: 0.0029 - accuracy: 0.9992
# Epoch 22/1500
# 39/39 [==============================] - 0s 10ms/step - loss: 0.0063 - accuracy: 0.9984
# Epoch 23/1500
# 39/39 [==============================] - 0s 10ms/step - loss: 0.0035 - accuracy: 0.9988
# Epoch 24/1500
# 39/39 [==============================] - 0s 9ms/step - loss: 0.0029 - accuracy: 0.9988
# Epoch 25/1500
# 39/39 [==============================] - 0s 9ms/step - loss: 0.0024 - accuracy: 0.9988
# Epoch 26/1500
# 39/39 [==============================] - 0s 9ms/step - loss: 0.0027 - accuracy: 0.9988
# Epoch 27/1500
# 39/39 [==============================] - 0s 9ms/step - loss: 0.0068 - accuracy: 0.9971
# Epoch 28/1500
# 39/39 [==============================] - 0s 7ms/step - loss: 0.0050 - accuracy: 0.9984
# Epoch 29/1500
# 39/39 [==============================] - 0s 8ms/step - loss: 0.0052 - accuracy: 0.9988
# Epoch 30/1500
# 39/39 [==============================] - 0s 6ms/step - loss: 0.0057 - accuracy: 0.9984
# Epoch 31/1500
# 39/39 [==============================] - 0s 9ms/step - loss: 0.0035 - accuracy: 0.9988
# Epoch 32/1500
# 39/39 [==============================] - 0s 9ms/step - loss: 0.0048 - accuracy: 0.9988
# Epoch 33/1500
# 39/39 [==============================] - 0s 9ms/step - loss: 0.0100 - accuracy: 0.9980
# Epoch 34/1500
# 39/39 [==============================] - 0s 7ms/step - loss: 0.0124 - accuracy: 0.9967
# Epoch 35/1500
# 39/39 [==============================] - 0s 9ms/step - loss: 0.0120 - accuracy: 0.9967
# Epoch 36/1500
# 39/39 [==============================] - 0s 7ms/step - loss: 0.0107 - accuracy: 0.9971
# Epoch 37/1500
# 39/39 [==============================] - 0s 8ms/step - loss: 0.0043 - accuracy: 0.9980
# Epoch 38/1500
# 39/39 [==============================] - 0s 6ms/step - loss: 0.0045 - accuracy: 0.9988
# Epoch 39/1500
# 39/39 [==============================] - 0s 7ms/step - loss: 0.0031 - accuracy: 0.9992
# Epoch 40/1500
# 39/39 [==============================] - 0s 6ms/step - loss: 0.0018 - accuracy: 0.9996
# Epoch 41/1500
# 39/39 [==============================] - 0s 7ms/step - loss: 0.0010 - accuracy: 0.9996
# Epoch 42/1500
# 39/39 [==============================] - 0s 10ms/step - loss: 0.0012 - accuracy: 0.9996
# Epoch 43/1500
# 39/39 [==============================] - 0s 9ms/step - loss: 0.0011 - accuracy: 0.9996
# Epoch 44/1500
# 39/39 [==============================] - 0s 8ms/step - loss: 5.0012e-04 - accuracy: 1.0000
# Epoch 45/1500
# 39/39 [==============================] - 0s 8ms/step - loss: 0.0031 - accuracy: 0.9988
# Epoch 46/1500
# 39/39 [==============================] - 0s 8ms/step - loss: 0.0047 - accuracy: 0.9980
# Epoch 47/1500
# 39/39 [==============================] - 0s 9ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 48/1500
# 39/39 [==============================] - 0s 7ms/step - loss: 0.0066 - accuracy: 0.9976
# Epoch 49/1500
# 39/39 [==============================] - 0s 7ms/step - loss: 0.0086 - accuracy: 0.9967
# Epoch 50/1500
# 39/39 [==============================] - 0s 7ms/step - loss: 0.0041 - accuracy: 0.9988
# Epoch 51/1500
# 39/39 [==============================] - 0s 8ms/step - loss: 0.0022 - accuracy: 0.9988
# Epoch 52/1500
# 39/39 [==============================] - 0s 7ms/step - loss: 0.0032 - accuracy: 0.9992
# Epoch 53/1500
# 39/39 [==============================] - 0s 11ms/step - loss: 0.0044 - accuracy: 0.9988
# Epoch 54/1500
# 39/39 [==============================] - 1s 20ms/step - loss: 0.0017 - accuracy: 0.9996
# Epoch 55/1500
# 39/39 [==============================] - 0s 9ms/step - loss: 0.0022 - accuracy: 0.9996
# Epoch 56/1500
# 39/39 [==============================] - 0s 9ms/step - loss: 0.0027 - accuracy: 0.9988
# Epoch 57/1500
# 39/39 [==============================] - 0s 8ms/step - loss: 0.0016 - accuracy: 0.9992
# Epoch 58/1500
# 39/39 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 0.9996
# Epoch 59/1500
# 39/39 [==============================] - 0s 8ms/step - loss: 8.6631e-04 - accuracy: 1.0000
# Epoch 60/1500
# 39/39 [==============================] - 0s 8ms/step - loss: 0.0056 - accuracy: 0.9980
# Epoch 61/1500
# 39/39 [==============================] - 0s 12ms/step - loss: 0.0066 - accuracy: 0.9984
# Epoch 62/1500
# 39/39 [==============================] - 0s 9ms/step - loss: 0.0023 - accuracy: 0.9992
# Epoch 63/1500
# 39/39 [==============================] - 0s 8ms/step - loss: 0.0038 - accuracy: 0.9988
# Epoch 64/1500
# 39/39 [==============================] - 0s 11ms/step - loss: 9.4668e-04 - accuracy: 1.0000
# Epoch 65/1500
# 39/39 [==============================] - 1s 16ms/step - loss: 0.0039 - accuracy: 0.9984
# Epoch 66/1500
# 39/39 [==============================] - 0s 11ms/step - loss: 0.0011 - accuracy: 0.9996
# Epoch 67/1500
# 39/39 [==============================] - 0s 11ms/step - loss: 0.0040 - accuracy: 0.9984
# Epoch 68/1500
# 39/39 [==============================] - 0s 9ms/step - loss: 0.0117 - accuracy: 0.9959
# Epoch 69/1500
# 39/39 [==============================] - 0s 11ms/step - loss: 0.0053 - accuracy: 0.9976
# Epoch 70/1500
# 39/39 [==============================] - 0s 10ms/step - loss: 0.0089 - accuracy: 0.9971
# Epoch 71/1500
# 39/39 [==============================] - 0s 8ms/step - loss: 0.0031 - accuracy: 0.9988
# Epoch 72/1500
# 39/39 [==============================] - 0s 7ms/step - loss: 0.0037 - accuracy: 0.9976
# Epoch 73/1500
# 39/39 [==============================] - 0s 9ms/step - loss: 0.0012 - accuracy: 0.9996
# Epoch 74/1500
# 37/39 [===========================>..] - ETA: 0s - loss: 0.0025 - accuracy: 0.9996  Restoring model weights from the end of the best epoch: 44.
# 39/39 [==============================] - 0s 9ms/step - loss: 0.0025 - accuracy: 0.9996
# Epoch 74: early stopping
# 6/6 [==============================] - 0s 2ms/step - loss: 4.0280 - accuracy: 0.6216
# 6/6 [==============================] - 0s 2ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.67 (20/30)
# Before appending - Cat IDs: 173, Predictions: 173, Actuals: 173, Gender: 173
# After appending - Cat IDs: 358, Predictions: 358, Actuals: 358, Gender: 358
# Final Test Results - Loss: 4.027976036071777, Accuracy: 0.6216216087341309, Precision: 0.5496031746031746, Recall: 0.4379012345679012, F1 Score: 0.44679186228482
# Confusion Matrix:
#  [[95  3 10]
#  [32 18  0]
#  [25  0  2]]
# outer_fold 3
# Train Set Group Distribution:
# 046A    45
# 000A    39
# 047A    22
# 000B    19
# 057A    17
#         ..
# 076A     1
# 096A     1
# 043A     1
# 049A     1
# 026B     1
# Name: cat_id, Length: 83, dtype: int64
# Testing Set Group Distribution:
# 103A    33
# 002B    30
# 020A    20
# 106A    13
# 067A    11
# 001A     9
# 065A     9
# 016A     9
# 015A     7
# 031A     7
# 007A     6
# 044A     5
# 094A     5
# 075A     5
# 050A     5
# 021A     5
# 023B     4
# 014A     3
# 058A     3
# 062A     3
# 038A     2
# 025B     2
# 073A     1
# 064A     1
# 026C     1
# 066A     1
# 004A     1
# 115A     1
# 110A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    256
# F    206
# M    128
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# M    158
# F     25
# X     20
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [006A, 000A, 033A, 071A, 097B, 028A, 019A, 074...
# kitten    [014B, 111A, 040A, 046A, 047A, 042A, 109A, 043...
# senior    [093A, 097A, 057A, 104A, 055A, 059A, 113A, 116...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [015A, 001A, 103A, 067A, 020A, 062A, 002B, 065...
# kitten                             [044A, 050A, 115A, 110A]
# senior                             [106A, 058A, 016A, 094A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 53, 'kitten': 12, 'senior': 18}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 21, 'kitten': 4, 'senior': 4}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '002A' '003A' '005A' '006A' '008A' '009A' '010A' '011A'
#  '012A' '013B' '014B' '018A' '019A' '019B' '022A' '023A' '024A' '025A'
#  '025C' '026A' '026B' '027A' '028A' '029A' '032A' '033A' '034A' '035A'
#  '036A' '037A' '039A' '040A' '041A' '042A' '043A' '045A' '046A' '047A'
#  '048A' '049A' '051A' '051B' '052A' '053A' '054A' '055A' '056A' '057A'
#  '059A' '060A' '061A' '063A' '068A' '069A' '070A' '071A' '072A' '074A'
#  '076A' '087A' '088A' '090A' '091A' '092A' '093A' '095A' '096A' '097A'
#  '097B' '099A' '100A' '101A' '102A' '104A' '105A' '108A' '109A' '111A'
#  '113A' '116A' '117A']
# Unique Test Group IDs:
# ['001A' '002B' '004A' '007A' '014A' '015A' '016A' '020A' '021A' '023B'
#  '025B' '026C' '031A' '038A' '044A' '050A' '058A' '062A' '064A' '065A'
#  '066A' '067A' '073A' '075A' '094A' '103A' '106A' '110A' '115A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '002A' '003A' '005A' '006A' '008A' '009A' '010A' '011A'
#  '012A' '013B' '014B' '018A' '019A' '019B' '022A' '023A' '024A' '025A'
#  '025C' '026A' '026B' '027A' '028A' '029A' '032A' '033A' '034A' '035A'
#  '036A' '037A' '039A' '040A' '041A' '042A' '043A' '045A' '046A' '047A'
#  '048A' '049A' '051A' '051B' '052A' '053A' '054A' '055A' '056A' '057A'
#  '059A' '060A' '061A' '063A' '068A' '069A' '070A' '071A' '072A' '074A'
#  '076A' '087A' '088A' '090A' '091A' '092A' '093A' '095A' '096A' '097A'
#  '097B' '099A' '100A' '101A' '102A' '104A' '105A' '108A' '109A' '111A'
#  '113A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['001A' '002B' '004A' '007A' '014A' '015A' '016A' '020A' '021A' '023B'
#  '025B' '026C' '031A' '038A' '044A' '050A' '058A' '062A' '064A' '065A'
#  '066A' '067A' '073A' '075A' '094A' '103A' '106A' '110A' '115A']
# Length of X_train_val:
# 590
# Length of y_train_val:
# 590
# Length of groups_train_val:
# 590
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     348
# kitten    123
# senior    119
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     161
# senior     30
# kitten     12
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     348
# kitten    123
# senior    119
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     161
# senior     30
# kitten     12
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({1: 875, 0: 868, 2: 847})
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Epoch 1/1500
# 41/41 [==============================] - 1s 6ms/step - loss: 0.4527 - accuracy: 0.8394
# Epoch 2/1500
# 41/41 [==============================] - 0s 7ms/step - loss: 0.1022 - accuracy: 0.9637
# Epoch 3/1500
# 41/41 [==============================] - 0s 7ms/step - loss: 0.0502 - accuracy: 0.9815
# Epoch 4/1500
# 41/41 [==============================] - 0s 7ms/step - loss: 0.0379 - accuracy: 0.9888
# Epoch 5/1500
# 41/41 [==============================] - 0s 9ms/step - loss: 0.0262 - accuracy: 0.9931
# Epoch 6/1500
# 41/41 [==============================] - 0s 10ms/step - loss: 0.0138 - accuracy: 0.9954
# Epoch 7/1500
# 41/41 [==============================] - 0s 10ms/step - loss: 0.0147 - accuracy: 0.9965
# Epoch 8/1500
# 41/41 [==============================] - 0s 10ms/step - loss: 0.0083 - accuracy: 0.9981
# Epoch 9/1500
# 41/41 [==============================] - 0s 10ms/step - loss: 0.0093 - accuracy: 0.9973
# Epoch 10/1500
# 41/41 [==============================] - 1s 13ms/step - loss: 0.0050 - accuracy: 0.9992
# Epoch 11/1500
# 41/41 [==============================] - 0s 10ms/step - loss: 0.0055 - accuracy: 0.9977
# Epoch 12/1500
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0079 - accuracy: 0.9981
# Epoch 13/1500
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0105 - accuracy: 0.9961
# Epoch 14/1500
# 41/41 [==============================] - 0s 7ms/step - loss: 0.0090 - accuracy: 0.9965
# Epoch 15/1500
# 41/41 [==============================] - 0s 10ms/step - loss: 0.0099 - accuracy: 0.9958
# Epoch 16/1500
# 41/41 [==============================] - 0s 9ms/step - loss: 0.0040 - accuracy: 0.9988
# Epoch 17/1500
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0022 - accuracy: 0.9996
# Epoch 18/1500
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0035 - accuracy: 0.9992
# Epoch 19/1500
# 41/41 [==============================] - 0s 7ms/step - loss: 0.0045 - accuracy: 0.9985
# Epoch 20/1500
# 41/41 [==============================] - 0s 7ms/step - loss: 0.0094 - accuracy: 0.9973
# Epoch 21/1500
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0028 - accuracy: 0.9992
# Epoch 22/1500
# 41/41 [==============================] - 0s 9ms/step - loss: 0.0019 - accuracy: 0.9996
# Epoch 23/1500
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0124 - accuracy: 0.9977
# Epoch 24/1500
# 41/41 [==============================] - 0s 10ms/step - loss: 0.0051 - accuracy: 0.9988
# Epoch 25/1500
# 41/41 [==============================] - 0s 9ms/step - loss: 0.0018 - accuracy: 0.9992
# Epoch 26/1500
# 41/41 [==============================] - 0s 9ms/step - loss: 8.6632e-04 - accuracy: 1.0000
# Epoch 27/1500
# 41/41 [==============================] - 0s 9ms/step - loss: 0.0029 - accuracy: 0.9988
# Epoch 28/1500
# 41/41 [==============================] - 0s 9ms/step - loss: 0.0033 - accuracy: 0.9988
# Epoch 29/1500
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0061 - accuracy: 0.9981
# Epoch 30/1500
# 41/41 [==============================] - 0s 9ms/step - loss: 0.0037 - accuracy: 0.9996
# Epoch 31/1500
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0069 - accuracy: 0.9981
# Epoch 32/1500
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0051 - accuracy: 0.9988
# Epoch 33/1500
# 41/41 [==============================] - 0s 7ms/step - loss: 0.0029 - accuracy: 0.9992
# Epoch 34/1500
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0027 - accuracy: 0.9988
# Epoch 35/1500
# 41/41 [==============================] - 0s 9ms/step - loss: 9.1974e-04 - accuracy: 1.0000
# Epoch 36/1500
# 41/41 [==============================] - 0s 8ms/step - loss: 5.8492e-04 - accuracy: 1.0000
# Epoch 37/1500
# 41/41 [==============================] - 0s 8ms/step - loss: 5.7081e-04 - accuracy: 1.0000
# Epoch 38/1500
# 41/41 [==============================] - 0s 8ms/step - loss: 9.3885e-04 - accuracy: 1.0000
# Epoch 39/1500
# 41/41 [==============================] - 0s 7ms/step - loss: 0.0041 - accuracy: 0.9985
# Epoch 40/1500
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0047 - accuracy: 0.9985
# Epoch 41/1500
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0062 - accuracy: 0.9985
# Epoch 42/1500
# 41/41 [==============================] - 1s 19ms/step - loss: 0.0124 - accuracy: 0.9977
# Epoch 43/1500
# 41/41 [==============================] - 0s 11ms/step - loss: 0.0119 - accuracy: 0.9965
# Epoch 44/1500
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0072 - accuracy: 0.9977
# Epoch 45/1500
# 41/41 [==============================] - 0s 7ms/step - loss: 0.0043 - accuracy: 0.9985
# Epoch 46/1500
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0049 - accuracy: 0.9985
# Epoch 47/1500
# 41/41 [==============================] - 0s 8ms/step - loss: 9.2387e-04 - accuracy: 1.0000
# Epoch 48/1500
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0030 - accuracy: 0.9988
# Epoch 49/1500
# 41/41 [==============================] - 0s 9ms/step - loss: 0.0029 - accuracy: 0.9988
# Epoch 50/1500
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0063 - accuracy: 0.9977
# Epoch 51/1500
# 41/41 [==============================] - 0s 7ms/step - loss: 0.0057 - accuracy: 0.9996
# Epoch 52/1500
# 41/41 [==============================] - 0s 7ms/step - loss: 0.0082 - accuracy: 0.9969
# Epoch 53/1500
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0056 - accuracy: 0.9985
# Epoch 54/1500
# 41/41 [==============================] - 0s 9ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 55/1500
# 41/41 [==============================] - 0s 7ms/step - loss: 0.0028 - accuracy: 0.9996
# Epoch 56/1500
# 36/41 [=========================>....] - ETA: 0s - loss: 0.0088 - accuracy: 0.9970Restoring model weights from the end of the best epoch: 26.
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0087 - accuracy: 0.9965
# Epoch 56: early stopping
# 7/7 [==============================] - 0s 2ms/step - loss: 1.2528 - accuracy: 0.8079
# 7/7 [==============================] - 0s 2ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.79 (23/29)
# Before appending - Cat IDs: 358, Predictions: 358, Actuals: 358, Gender: 358
# After appending - Cat IDs: 561, Predictions: 561, Actuals: 561, Gender: 561
# Final Test Results - Loss: 1.252773404121399, Accuracy: 0.807881772518158, Precision: 0.6749482401656315, Recall: 0.7051069703243616, F1 Score: 0.6883371501062655
# Confusion Matrix:
#  [[142   3  16]
#  [  2  10   0]
#  [ 17   1  12]]
# outer_fold 4
# Train Set Group Distribution:
# 000A    39
# 103A    33
# 002B    30
# 047A    22
# 020A    20
#         ..
# 064A     1
# 073A     1
# 043A     1
# 076A     1
# 026B     1
# Name: cat_id, Length: 86, dtype: int64
# Testing Set Group Distribution:
# 046A    45
# 057A    17
# 074A    16
# 055A    12
# 101A    12
# 116A    12
# 014B    10
# 025A    10
# 033A     9
# 068A     8
# 108A     5
# 070A     5
# 008A     5
# 104A     4
# 009A     4
# 045A     4
# 113A     3
# 034A     3
# 053A     3
# 011A     2
# 035A     2
# 032A     2
# 092A     1
# 096A     1
# 088A     1
# 100A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    253
# X    184
# F    159
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    92
# F    72
# M    33
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [006A, 000A, 015A, 001A, 103A, 071A, 097B, 028...
# kitten    [044A, 111A, 040A, 047A, 042A, 109A, 050A, 043...
# senior    [093A, 097A, 106A, 059A, 051B, 054A, 117A, 056...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [033A, 074A, 101A, 034A, 009A, 025A, 070A, 032...
# kitten                                   [014B, 046A, 045A]
# senior           [057A, 104A, 055A, 113A, 116A, 108A, 011A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 58, 'kitten': 13, 'senior': 15}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 16, 'kitten': 3, 'senior': 7}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '004A' '005A' '006A' '007A'
#  '010A' '012A' '013B' '014A' '015A' '016A' '018A' '019A' '019B' '020A'
#  '021A' '022A' '023A' '023B' '024A' '025B' '025C' '026A' '026B' '026C'
#  '027A' '028A' '029A' '031A' '036A' '037A' '038A' '039A' '040A' '041A'
#  '042A' '043A' '044A' '047A' '048A' '049A' '050A' '051A' '051B' '052A'
#  '054A' '056A' '058A' '059A' '060A' '061A' '062A' '063A' '064A' '065A'
#  '066A' '067A' '069A' '071A' '072A' '073A' '075A' '076A' '087A' '090A'
#  '091A' '093A' '094A' '095A' '097A' '097B' '099A' '102A' '103A' '105A'
#  '106A' '109A' '110A' '111A' '115A' '117A']
# Unique Test Group IDs:
# ['008A' '009A' '011A' '014B' '025A' '032A' '033A' '034A' '035A' '045A'
#  '046A' '053A' '055A' '057A' '068A' '070A' '074A' '088A' '092A' '096A'
#  '100A' '101A' '104A' '108A' '113A' '116A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'046A'}
# Removed from Training/Validation Set:
# {'043A'}
# Moved to Test Set:
# {'043A'}
# Removed from Test Set
# {'046A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '004A' '005A' '006A' '007A'
#  '010A' '012A' '013B' '014A' '015A' '016A' '018A' '019A' '019B' '020A'
#  '021A' '022A' '023A' '023B' '024A' '025B' '025C' '026A' '026B' '026C'
#  '027A' '028A' '029A' '031A' '036A' '037A' '038A' '039A' '040A' '041A'
#  '042A' '044A' '046A' '047A' '048A' '049A' '050A' '051A' '051B' '052A'
#  '054A' '056A' '058A' '059A' '060A' '061A' '062A' '063A' '064A' '065A'
#  '066A' '067A' '069A' '071A' '072A' '073A' '075A' '076A' '087A' '090A'
#  '091A' '093A' '094A' '095A' '097A' '097B' '099A' '102A' '103A' '105A'
#  '106A' '109A' '110A' '111A' '115A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['008A' '009A' '011A' '014B' '025A' '032A' '033A' '034A' '035A' '043A'
#  '045A' '053A' '055A' '057A' '068A' '070A' '074A' '088A' '092A' '096A'
#  '100A' '101A' '104A' '108A' '113A' '116A']
# Length of X_train_val:
# 640
# Length of y_train_val:
# 640
# Length of groups_train_val:
# 640
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     426
# senior     94
# kitten     76
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     83
# kitten    59
# senior    55
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     426
# kitten    120
# senior     94
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     83
# senior    55
# kitten    15
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 1044, 1: 860, 2: 614})
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Epoch 1/1500
# 40/40 [==============================] - 1s 5ms/step - loss: 0.4253 - accuracy: 0.8531
# Epoch 2/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0901 - accuracy: 0.9738
# Epoch 3/1500
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0390 - accuracy: 0.9897
# Epoch 4/1500
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0278 - accuracy: 0.9929
# Epoch 5/1500
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0183 - accuracy: 0.9952
# Epoch 6/1500
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0208 - accuracy: 0.9936
# Epoch 7/1500
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0116 - accuracy: 0.9972
# Epoch 8/1500
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0084 - accuracy: 0.9984
# Epoch 9/1500
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0098 - accuracy: 0.9964
# Epoch 10/1500
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0064 - accuracy: 0.9980
# Epoch 11/1500
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0079 - accuracy: 0.9972
# Epoch 12/1500
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0050 - accuracy: 0.9988
# Epoch 13/1500
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0051 - accuracy: 0.9988
# Epoch 14/1500
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0074 - accuracy: 0.9984
# Epoch 15/1500
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0053 - accuracy: 0.9984
# Epoch 16/1500
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0044 - accuracy: 0.9984
# Epoch 17/1500
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0056 - accuracy: 0.9976
# Epoch 18/1500
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0089 - accuracy: 0.9968
# Epoch 19/1500
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0050 - accuracy: 0.9988
# Epoch 20/1500
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0024 - accuracy: 0.9996
# Epoch 21/1500
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0028 - accuracy: 0.9996
# Epoch 22/1500
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0040 - accuracy: 0.9988
# Epoch 23/1500
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0031 - accuracy: 0.9988
# Epoch 24/1500
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0064 - accuracy: 0.9972
# Epoch 25/1500
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0136 - accuracy: 0.9960
# Epoch 26/1500
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0050 - accuracy: 0.9988
# Epoch 27/1500
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 28/1500
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0051 - accuracy: 0.9984
# Epoch 29/1500
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0076 - accuracy: 0.9980
# Epoch 30/1500
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0034 - accuracy: 0.9992
# Epoch 31/1500
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0034 - accuracy: 0.9988
# Epoch 32/1500
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0030 - accuracy: 0.9988
# Epoch 33/1500
# 40/40 [==============================] - 0s 8ms/step - loss: 8.1144e-04 - accuracy: 1.0000
# Epoch 34/1500
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0026 - accuracy: 0.9992
# Epoch 35/1500
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0039 - accuracy: 0.9984
# Epoch 36/1500
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0063 - accuracy: 0.9980
# Epoch 37/1500
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0110 - accuracy: 0.9968
# Epoch 38/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0089 - accuracy: 0.9976
# Epoch 39/1500
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0114 - accuracy: 0.9968
# Epoch 40/1500
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0033 - accuracy: 0.9984
# Epoch 41/1500
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0081 - accuracy: 0.9988
# Epoch 42/1500
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0027 - accuracy: 0.9996
# Epoch 43/1500
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0014 - accuracy: 0.9992
# Epoch 44/1500
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0035 - accuracy: 0.9980
# Epoch 45/1500
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0031 - accuracy: 0.9992
# Epoch 46/1500
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0068 - accuracy: 0.9972
# Epoch 47/1500
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0031 - accuracy: 0.9992
# Epoch 48/1500
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0044 - accuracy: 0.9992
# Epoch 49/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0029 - accuracy: 0.9996
# Epoch 50/1500
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 51/1500
# 40/40 [==============================] - 0s 9ms/step - loss: 3.7224e-04 - accuracy: 1.0000
# Epoch 52/1500
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0043 - accuracy: 0.9984
# Epoch 53/1500
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0016 - accuracy: 0.9996
# Epoch 54/1500
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0021 - accuracy: 0.9988
# Epoch 55/1500
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 0.9996
# Epoch 56/1500
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0024 - accuracy: 0.9996
# Epoch 57/1500
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0015 - accuracy: 0.9996
# Epoch 58/1500
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0032 - accuracy: 0.9984
# Epoch 59/1500
# 40/40 [==============================] - 1s 21ms/step - loss: 8.9811e-04 - accuracy: 0.9996
# Epoch 60/1500
# 40/40 [==============================] - 0s 7ms/step - loss: 5.7696e-04 - accuracy: 1.0000
# Epoch 61/1500
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0050 - accuracy: 0.9984
# Epoch 62/1500
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0062 - accuracy: 0.9984
# Epoch 63/1500
# 38/40 [===========================>..] - ETA: 0s - loss: 0.0040 - accuracy: 0.9984Restoring model weights from the end of the best epoch: 33.
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0038 - accuracy: 0.9984
# Epoch 63: early stopping
# 5/5 [==============================] - 0s 2ms/step - loss: 2.9107 - accuracy: 0.6275
# 5/5 [==============================] - 0s 2ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.73 (19/26)
# Before appending - Cat IDs: 561, Predictions: 561, Actuals: 561, Gender: 561
# After appending - Cat IDs: 714, Predictions: 714, Actuals: 714, Gender: 714
# Final Test Results - Loss: 2.910660982131958, Accuracy: 0.6274510025978088, Precision: 0.6677226813590451, Recall: 0.5900937081659973, F1 Score: 0.5897893972403777
# Confusion Matrix:
#  [[75  2  6]
#  [ 2 10  3]
#  [44  0 11]]
#
# Final Average F1-Score across all UNSEEN TEST sets: 0.6035947813943837
#
# Final Average Loss across all UNSEEN TEST sets: 2.5947631299495697
#
# Final Average Accuracy across all UNSEEN TEST sets: 0.6992096900939941
#
# Final Average Precision across all UNSEEN TEST sets: 0.6393790653425041
#
# Final Average Recall across all UNSEEN TEST sets: 0.6137536730870221

# %%
seed_1_folds_values = [unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1]

seed_1_training_acc_values = cv_training_acc_total

# Plotting all fold metrics
seed_1_folds_plot = plot_all_metrics(unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1, "Folds", "Fold Number")

# %% [markdown]
# ## Majority Voting on Total Entries per cat_id

# %%
# Debugging print statements
print(f'Checking - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
# Out:
# Checking - Cat IDs: 714, Predictions: 714, Actuals: 714, Gender: 714

# %%
# Create results df
full_results = pd.DataFrame({
    'cat_id': all_cat_ids,
    'predicted_age_group': all_predicted_age_groups,
    'actual_age_group': all_actual_age_groups,
    'all_gender': all_gender
})

# create a correct majority prediction column
full_results['correct'] = full_results['predicted_age_group'] == full_results['actual_age_group']

# %%
# Group by cat_id and aggregate predicted age groups
majority_votes = full_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first()

# Calculate the accuracy of majority voting
correct_predictions = (majority_votes == actual_groups).sum()
total_cats = len(actual_groups)
majority_vote_accuracy = correct_predictions / total_cats

logger(f"Overall Majority Vote Accuracy for cat_id: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

# store for final evaluation 
all_majority_vote_accuracies.append(majority_vote_accuracy)
# Out:
# Overall Majority Vote Accuracy for cat_id: 0.75 (82/110)

# %%
# Detailed df with predictions, actual labels, and comparison including majority vote
detailed_results = full_results.groupby('cat_id').apply(
    lambda x: pd.Series({
        'Predictions': list(x['predicted_age_group']),
        'Majority Vote': x['predicted_age_group'].mode()[0],
        'Actual Age Group': x['actual_age_group'].iloc[0],
        'Correct Majority Vote': x['predicted_age_group'].mode()[0] == x['actual_age_group'].iloc[0]
    })
).reset_index()

# Convert to DataFrame for better formatting and display
detailed_results = pd.DataFrame(detailed_results)

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 10)
pd.set_option('display.width', 1000)

sorted_detailed_results = detailed_results.sort_values(by='Correct Majority Vote', ascending=False)

# Display the sorted DataFrame
sorted_detailed_results
# Out:
#     cat_id                                        Predictions Majority Vote Actual Age Group  Correct Majority Vote
# 0     000B  [adult, senior, adult, adult, adult, adult, ad...         adult            adult                   True
# 80    074A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 78    072A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 77    071A  [adult, adult, adult, adult, adult, senior, ad...         adult            adult                   True
# 76    070A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 75    069A                                     [adult, adult]         adult            adult                   True
# 74    068A  [adult, senior, adult, adult, senior, adult, a...         adult            adult                   True
# 73    067A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 72    066A                                            [adult]         adult            adult                   True
# 71    065A  [senior, adult, adult, adult, adult, adult, ad...         adult            adult                   True
# 69    063A  [adult, adult, adult, senior, adult, senior, s...         adult            adult                   True
# 68    062A                              [adult, adult, adult]         adult            adult                   True
# 66    060A                              [adult, adult, adult]         adult            adult                   True
# 65    059A  [senior, senior, senior, senior, senior, senio...        senior           senior                   True
# 64    058A                           [senior, senior, senior]        senior           senior                   True
# 59    053A                              [adult, adult, adult]         adult            adult                   True
# 58    052A                                    [adult, senior]         adult            adult                   True
# 53    048A                                           [kitten]        kitten           kitten                   True
# 51    045A                   [kitten, kitten, kitten, kitten]        kitten           kitten                   True
# 50    044A            [adult, kitten, kitten, kitten, kitten]        kitten           kitten                   True
# 49    043A                                   [kitten, kitten]        kitten           kitten                   True
# 79    073A                                            [adult]         adult            adult                   True
# 81    075A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 45    039A         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 82    076A                                            [adult]         adult            adult                   True
# 107   115A                                           [kitten]        kitten           kitten                   True
# 105   111A  [kitten, kitten, kitten, kitten, kitten, kitte...        kitten           kitten                   True
# 104   110A                                           [kitten]        kitten           kitten                   True
# 100   105A                              [adult, adult, adult]         adult            adult                   True
# 98    103A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 97    102A                                     [adult, adult]         adult            adult                   True
# 96    101A  [senior, senior, adult, adult, adult, adult, a...         adult            adult                   True
# 95    100A                                            [adult]         adult            adult                   True
# 94    099A        [adult, adult, adult, kitten, adult, adult]         adult            adult                   True
# 93    097B  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 92    097A  [adult, senior, adult, adult, senior, senior, ...        senior           senior                   True
# 91    096A                                            [adult]         adult            adult                   True
# 90    095A  [senior, adult, adult, adult, adult, adult, se...         adult            adult                   True
# 89    094A            [senior, senior, senior, adult, senior]        senior           senior                   True
# 87    092A                                            [adult]         adult            adult                   True
# 86    091A                                            [adult]         adult            adult                   True
# 85    090A                                           [senior]        senior           senior                   True
# 84    088A                                            [adult]         adult            adult                   True
# 83    087A                                     [adult, adult]         adult            adult                   True
# 46    040A  [kitten, kitten, kitten, kitten, kitten, kitte...        kitten           kitten                   True
# 55    050A            [adult, kitten, kitten, kitten, kitten]        kitten           kitten                   True
# 44    038A                                     [adult, adult]         adult            adult                   True
# 16    014B  [senior, kitten, senior, adult, kitten, kitten...        kitten           kitten                   True
# 30    025C                       [adult, adult, adult, adult]         adult            adult                   True
# 29    025B                                    [senior, adult]         adult            adult                   True
# 28    025A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 26    023B                       [adult, adult, adult, adult]         adult            adult                   True
# 24    022A  [kitten, adult, kitten, kitten, adult, adult, ...         adult            adult                   True
# 23    021A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 22    020A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 20    019A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 19    018A                                     [adult, adult]         adult            adult                   True
# 17    015A  [adult, adult, adult, senior, adult, adult, ad...         adult            adult                   True
# 15    014A                              [adult, adult, adult]         adult            adult                   True
# 32    026B                                            [adult]         adult            adult                   True
# 14    013B  [adult, adult, adult, senior, adult, adult, ki...         adult            adult                   True
# 13    012A                              [adult, adult, adult]         adult            adult                   True
# 11    010A                              [adult, adult, adult]         adult            adult                   True
# 10    009A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 9     008A               [adult, adult, adult, kitten, adult]         adult            adult                   True
# 8     007A         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 7     006A                             [kitten, adult, adult]         adult            adult                   True
# 4     003A                      [kitten, adult, adult, adult]         adult            adult                   True
# 3     002B  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 2     002A  [adult, adult, kitten, adult, adult, adult, ad...         adult            adult                   True
# 31    026A                       [adult, adult, adult, adult]         adult            adult                   True
# 25    023A         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 40    034A                             [adult, adult, kitten]         adult            adult                   True
# 34    027A  [adult, adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 41    035A                                     [adult, adult]         adult            adult                   True
# 35    028A  [adult, adult, adult, senior, adult, adult, ad...         adult            adult                   True
# 36    029A  [senior, senior, adult, adult, adult, adult, a...         adult            adult                   True
# 37    031A  [adult, adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 43    037A                                    [senior, adult]         adult            adult                   True
# 42    036A  [adult, adult, adult, adult, senior, adult, ad...         adult            adult                   True
# 39    033A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 38    032A                                     [adult, adult]         adult            adult                   True
# 5     004A                                           [kitten]        kitten            adult                  False
# 52    047A  [adult, adult, adult, adult, adult, adult, adu...         adult           kitten                  False
# 6     005A  [senior, senior, senior, senior, senior, senio...        senior            adult                  False
# 99    104A                       [adult, adult, adult, adult]         adult           senior                  False
# 70    064A                                           [kitten]        kitten            adult                  False
# 101   106A  [adult, adult, adult, senior, adult, adult, ad...         adult           senior                  False
# 102   108A               [adult, adult, adult, senior, adult]         adult           senior                  False
# 54    049A                                            [adult]         adult           kitten                  False
# 106   113A                             [adult, senior, adult]         adult           senior                  False
# 48    042A  [adult, adult, adult, kitten, adult, adult, ad...         adult           kitten                  False
# 108   116A  [senior, senior, adult, adult, adult, adult, a...         adult           senior                  False
# 103   109A                [adult, adult, adult, adult, adult]         adult           kitten                  False
# 56    051A  [adult, adult, adult, adult, adult, adult, adu...         adult           senior                  False
# 1     001A  [senior, senior, adult, senior, senior, senior...        senior            adult                  False
# 12    011A                                    [adult, senior]         adult           senior                  False
# 33    026C                                           [kitten]        kitten            adult                  False
# 57    051B  [adult, adult, adult, adult, adult, adult, adu...         adult           senior                  False
# 88    093A                                     [adult, adult]         adult           senior                  False
# 60    054A                                     [adult, adult]         adult           senior                  False
# 18    016A  [adult, adult, adult, adult, senior, adult, se...         adult           senior                  False
# 61    055A  [adult, senior, adult, adult, adult, senior, a...         adult           senior                  False
# 62    056A                             [adult, senior, adult]         adult           senior                  False
# 21    019B                                           [senior]        senior            adult                  False
# 63    057A  [adult, senior, adult, adult, adult, adult, ad...         adult           senior                  False
# 47    041A                                            [adult]         adult           kitten                  False
# 27    024A                                            [adult]         adult           senior                  False
# 67    061A                                     [adult, adult]         adult           senior                  False
# 109   117A  [adult, adult, adult, adult, adult, adult, adult]         adult           senior                  False

# %%
# Create df for majority votes
majority_df = majority_votes.reset_index()
majority_df.columns = ['cat_id', 'Majority_Vote']

# Get actual groups for each cat_id
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first().reset_index()

# Merge majority votes with actual groups
majority_with_actual = pd.merge(majority_df, actual_groups, on='cat_id')

# Add a column to check if the majority vote was correct
majority_with_actual['Majority_Correct'] = majority_with_actual['Majority_Vote'] == majority_with_actual['actual_age_group']

# Count correct majority votes per class
correct_majority_votes_per_class = majority_with_actual.groupby('actual_age_group')['Majority_Correct'].sum()

print("Correct Majority Votes per Class:")
print(correct_majority_votes_per_class)
# Out:
# Correct Majority Votes per Class:
# actual_age_group
# adult     67
# kitten    10
# senior     5
# Name: Majority_Correct, dtype: int64

# %%
# Calculate the total count and the number of correct predictions for each class
class_stats = majority_with_actual.groupby('actual_age_group').agg(
    total_count=('Majority_Correct', 'size'),  # Total number of cases per class
    correct_count=('Majority_Correct', 'sum')  # Sum of correct predictions per class
).reset_index()

# Calculate accuracy for each class
class_stats['accuracy'] = class_stats['correct_count'] / class_stats['total_count'] * 100

# store for final evaluation 
all_majority_vote_details.append(class_stats)

# Log detailed stats
print("Detailed Class Statistics for Majority Votes:")
print(class_stats)
# Out:
# Detailed Class Statistics for Majority Votes:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult           73             67  91.780822
# 1           kitten           15             10  66.666667
# 2           senior           22              5  22.727273

# %%
# Plot for Detailed Class Statistics for Majority Votes
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Accuracy of Majority Votes by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Detailed Class Statistics

# %%
# Calculate the total count and the number of correct predictions for each class
class_stats = full_results.groupby('actual_age_group').agg(
    total_count=('correct', 'size'),
    correct_count=('correct', 'sum')
).reset_index()

# Calculate accuracy for each class
class_stats['accuracy'] = class_stats['correct_count'] / class_stats['total_count'] * 100

# store for final evaluation 
all_class_stats.append(class_stats)

# Log the detailed stats
print("Detailed Class Statistics:")
print(class_stats)
# Out:
# Detailed Class Statistics:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult          474            409  86.286920
# 1           kitten           91             50  54.945055
# 2           senior          149             44  29.530201

# %%
# Plot for Detailed Class Statistics (Overall)
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Overall Accuracy by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Gender Exploration

# %%
# Group by gender and calculate the total count, correct predictions, and accuracy
gender_stats = full_results.groupby('all_gender').agg(
    count=('cat_id', 'size'),  # Total number of cases per gender
    correct=('correct', 'sum')  # Sum of correct predictions per gender
).reset_index()

# Calculate accuracy for each gender
gender_stats['accuracy'] = (gender_stats['correct'] / gender_stats['count'] * 100).round(2)

# Display the DataFrame
print("Accuracy by Gender:")
print(gender_stats)

# store for final evaluation 
all_gender_stats.append(gender_stats)
# Out:
# Accuracy by Gender:
#   all_gender  count  correct  accuracy
# 0          F    196      131     66.84
# 1          M    286      222     77.62
# 2          X    232      150     64.66

# %%
# Plot for Accuracy by Gender
styled_barplot(gender_stats, 'all_gender', 'accuracy', 
               'Accuracy by Gender', 
               'Gender', 'Accuracy (%)')

# %% [markdown]
# ### Log current total CV Stats

# %%
print("Total Majority Vote Accuracy so far:", all_majority_vote_accuracies)
print("Total Class Statistics so far:\n", all_class_stats)
print("Total Gender Accuracy so far:\n", all_gender_stats)
# Out:
# Total Majority Vote Accuracy so far: [0.7454545454545455]
# Total Class Statistics so far:
#  [  actual_age_group  total_count  correct_count   accuracy
# 0            adult          474            409  86.286920
# 1           kitten           91             50  54.945055
# 2           senior          149             44  29.530201]
# Total Gender Accuracy so far:
#  [  all_gender  count  correct  accuracy
# 0          F    196      131     66.84
# 1          M    286      222     77.62
# 2          X    232      150     64.66]

# %% [markdown]
# # RANDOM SEED 2

# %%
# Set a fixed random seed for reproducibility
random.seed(int(random_seeds[1]))
np.random.seed(int(random_seeds[1]))
tf.random.set_seed(int(random_seeds[1]))

# Load datasets
dataframe = pd.read_csv('/Users/astrid/PycharmProjects/perch-2/scripts/perch_embeddings_april_10.csv')
augmented_df = pd.read_csv('/Users/astrid/PycharmProjects/perch-2/scripts/perch_embeddings_augmented_d3.csv')

dataframe.drop('mean_freq', axis=1, inplace=True)

augmented_df.drop('mean_freq', axis=1, inplace=True)
augmented_df.drop('gender', axis=1, inplace=True)

def assign_age_group(age, age_groups):
    for group_name, age_range in age_groups.items():
        if age_range[0] <= age < age_range[1]:
            return group_name
    return 'Unknown'  # For any age that doesn't fit the defined groups

# Define age groups
age_groups = {
    'kitten': (0, 0.5),
    'adult': (0.5, 12),
    'senior': (12, 20)
}

# Create a new column for the age group
dataframe['age_group'] = dataframe['target'].apply(assign_age_group, age_groups=age_groups)
augmented_df['age_group'] = augmented_df['target'].apply(assign_age_group, age_groups=age_groups)

print(dataframe['age_group'].value_counts())
print(augmented_df['age_group'].value_counts())
# Out:
# adult     509
# senior    149
# kitten    135
# Name: age_group, dtype: int64
# senior    900
# kitten    820
# adult     758
# Name: age_group, dtype: int64

# %%
# Separate features and labels
X = dataframe.iloc[:, :-4].values  # all columns except the last four

# Encode the 'age_group' column as integers using LabelEncoder
label_encoder = LabelEncoder()
encoded_y = label_encoder.fit_transform(dataframe['age_group'].values)

# Use the encoded labels for splitting and one-hot encoding
y = encoded_y  

# Convert 'cat_id' column to numpy array to be used as groups array for GroupKFold
groups = dataframe['cat_id'].values

# %%
tf.keras.backend.clear_session()

# %% [markdown]
# ## Run Setup

# %%
all_cat_ids = []
all_predicted_age_groups = []
all_actual_age_groups = []
all_gender = []

# Define the StratifiedGroupKFold splitter for 4 fold CV with random shuffling
outer_cv = StratifiedGroupKFold(n_splits=4, shuffle=True, random_state=int(random_seeds[1]))

# unseen test set metrics
unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1 = [], [], [], [], []

cv_training_acc_total = []
cv_training_acc_best = []

outer_fold = 0

# Use the splitter to generate indices for training and testing sets
# Note: GroupShuffleSplit.split returns indices, so we use it to index the arrays
for train_val_idx, test_idx in outer_cv.split(X, y, groups):
    outer_fold += 1
    logger(f"outer_fold {outer_fold}", file=log_file_path)

    # Convert indices back to DataFrame for easy manipulation
    df_train_val = dataframe.iloc[train_val_idx]
    df_test = dataframe.iloc[test_idx]

    ##############################
    # ASSESSING SPLITS BY CAT_ID #
    ##############################
    
    # Get the distribution of groups
    training_validation_group_distribution = df_train_val['cat_id'].value_counts()  
    testing_group_distribution = df_test['cat_id'].value_counts()  
    
    # Log or print the distribution
    logger(f"Train Set Group Distribution:\n{training_validation_group_distribution}", file=log_file_path)
    logger(f"Testing Set Group Distribution:\n{testing_group_distribution}", file=log_file_path)

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val['gender'].value_counts()
    testing_gender_distribution = df_test['gender'].value_counts()
    
    # Log the distribution
    logger(f"Training Set Gender Distribution BEFORE SWAP:\n{training_gender_distribution}", file=log_file_path)
    logger(f"Testing Set Gender Distribution BEFORE SWAP:\n{testing_gender_distribution}", file=log_file_path)

    # Group by 'age_group' and then list unique 'cat_id' within each age group
    unique_cat_ids_per_age_group_train_val = df_train_val.groupby('age_group')['cat_id'].unique()
    unique_cat_ids_per_age_group_test = df_test.groupby('age_group')['cat_id'].unique()
    
    # Log results
    logger(f"Unique Cat IDs per Age Group in Training/Validation Set:\n{unique_cat_ids_per_age_group_train_val}", file=log_file_path)
    logger(f"Unique Cat IDs per Age Group in Testing Set:\n{unique_cat_ids_per_age_group_test}", file=log_file_path)

    # Calculate the count of unique identifiers per age group for training and testing set
    counts_train_val = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_train_val.items()}
    counts_test = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_test.items()}

    # Log the counts of unique identifiers per age group
    logger(f"Count of Unique Cat IDs per Age Group in Training/Validation Set:\n{counts_train_val}", file=log_file_path)
    logger(f"Count of Unique Cat IDs per Age Group in Testing Set:\n{counts_test}", file=log_file_path)

    #######################################################
    # CONTINUE WITH ENSURING VALID AND APPROPRIATE SPLITS #
    #######################################################
    
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    groups_train_val, groups_test = groups[train_val_idx], groups[test_idx]

    # logging identifier splits 
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)

    # check group splits
    check_initial_group_split(groups_train_val, groups_test)

    # Specify the cat_ids that must be in the training/validation set
    specific_cat_ids = ['000A', '046A']
    
    # Perform the swapping operation
    train_val_idx, test_idx = swap_cat_id_instances(dataframe, train_val_idx, test_idx, specific_cat_ids)
    
    # Re-assign the sets based on the updated indices
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    new_groups_train_val, new_groups_test = groups[train_val_idx], groups[test_idx]

    # Find differences for training and test sets
    moved_to_train_val, removed_from_train_val = find_group_differences(groups_train_val, new_groups_train_val)
    moved_to_test, removed_from_test = find_group_differences(groups_test, new_groups_test)
    
    # Display the results
    logger(f"Moved to Training/Validation Set:\n{moved_to_train_val}", file=log_file_path)
    logger(f"Removed from Training/Validation Set:\n{removed_from_train_val}", file=log_file_path)
    logger(f"Moved to Test Set:\n{moved_to_test}", file=log_file_path)
    logger(f"Removed from Test Set\n{removed_from_test}", file=log_file_path)

    # Update X_train_val, X_test, y_train_val, y_test, groups_train_val, groups_test based on updated indices
    X_train_val = X[train_val_idx]
    y_train_val = y[train_val_idx]
    groups_train_val = groups[train_val_idx]
    
    X_test = X[test_idx]
    y_test = y[test_idx]
    groups_test = groups[test_idx]

    # logging identifier splits again after potential swaps
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"AFTER SWAP - Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"AFTER SWAP - Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)
    
    # Verify the lengths are consistent
    logger(f"Length of X_train_val:\n{len(X_train_val)}", file=log_file_path)
    logger(f"Length of y_train_val:\n{len(y_train_val)}", file=log_file_path)
    logger(f"Length of groups_train_val:\n{len(groups_train_val)}", file=log_file_path)

    # Check group splits once more
    check_initial_group_split(groups_train_val, groups_test)

    # Convert the modified indices back to a DataFrame representing the updated df_train_val
    df_train_val_updated = dataframe.iloc[train_val_idx].copy()
    df_test_updated = dataframe.iloc[test_idx].copy()

    ############################
    # LOGGING AGE GROUP SPLITS #
    ############################

    # Get the distribution of age groups of age groups before the update
    training_validation_age_group_distribution = df_train_val['age_group'].value_counts()
    testing_age_group_distribution = df_test['age_group'].value_counts()
    
    # Logthe distribution
    logger(f"Train Age Group Distribution BEFORE SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution BEFORE SWAP:\n{testing_age_group_distribution}", file=log_file_path)

    # Get the distribution of age groups after the update
    training_validation_age_group_distribution = df_train_val_updated['age_group'].value_counts()
    testing_age_group_distribution = df_test_updated['age_group'].value_counts()
    
    # Log the distribution
    logger(f"Train Age Group Distribution AFTER SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution AFTER SWAP:\n{testing_age_group_distribution}", file=log_file_path)
    
    ########################################################
    # TRACKING FINAL CAT_IDs & GENDER AFTER REDISTRIBUTION #
    ########################################################

    # Get the distribution of groups
    training_validation_group_distribution = df_train_val_updated['cat_id'].value_counts()  
    testing_group_distribution = df_test_updated['cat_id'].value_counts()  

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val_updated['gender'].value_counts()
    testing_gender_distribution = df_test_updated['gender'].value_counts()
    
    logger(f"\n Starting training on unseen test set\n", file=log_file_path)

    ######################
    # ADD AUGMENTED DATA #
    ######################

    # Filter out augmented data derived from groups in the training set
    augmented_df_filtered = augmented_df[augmented_df['cat_id'].isin(groups_train_val)]
    
    # Convert augmented_df_filtered to numpy array (excluding target and other columns)
    augmented_array = augmented_df_filtered.drop(columns=['target', 'cat_id', 'age_group']).values
    
    # Concatenate the filtered augmented data with X_train_val
    X_train_val = np.concatenate([X_train_val, augmented_array])

    # Extract target labels from the filtered augmented DataFrame
    y_augmented = augmented_df_filtered['age_group'].values
    
    # Encode the labels using the same LabelEncoder instance
    y_augmented_encoded = label_encoder.transform(y_augmented)
    
    # Concatenate the encoded augmented labels with y_train_val
    y_train_val = np.concatenate([y_train_val, y_augmented_encoded])

    # Calculate the distribution of age groups in y_train_val
    age_group_distribution = Counter(y_train_val)
    print("Age group distribution:", age_group_distribution)

    # EarlyStopping callback: monitor 'loss' instead of 'val_loss' for the test set
    early_stopping = EarlyStopping(
        monitor='loss',  
        min_delta=0.001, 
        patience=30,  
        verbose=1,  
        restore_best_weights=True  
    )

    accuracy_history = AccuracyHistory()

    # One final shuffle to ensure randomness
    outer_shuffle_idx = np.random.permutation(len(X_train_val))
    X_train_val = X_train_val[outer_shuffle_idx]
    y_train_val = y_train_val[outer_shuffle_idx]
    
    # Scale the features
    scaler_full = StandardScaler().fit(X_train_val)
    X_train_full_scaled = scaler_full.transform(X_train_val)
    X_test_scaled = scaler_full.transform(X_test)
    
    # Encode the labels
    y_train_full_encoded = to_categorical(y_train_val)
    y_test_encoded = to_categorical(y_test)

    #######################
    # BUILD & TRAIN MODEL #
    #######################

    optimizers = {
        'Adamax': Adamax(learning_rate=0.00510251984616472)
    }
    
    # Model definition with dynamic number of layers
    model_full = Sequential()
    model_full.add(Dense(480, activation='relu', input_shape=(X_train_full_scaled.shape[1],)))
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.2011047009431978))  
    model_full.add(Dense(256, activation='relu',)) 
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.14956886311951184))  
    model_full.add(Dense(256, activation='relu'))  
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.42291461228250665))  
    model_full.add(Dense(3, activation='softmax'))  
    
    # Use the optimizer from the parameters
    optimizer = optimizers['Adamax']  # optimizer_key from parameters
    
    # Compile the model
    model_full.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    
    # Train the model on the full training set
    history_full = model_full.fit(X_train_full_scaled, y_train_full_encoded, epochs=1500, batch_size=64,
                                  verbose=1, callbacks=[early_stopping, accuracy_history])
    
    # log epochs
    best_epoch_index = np.argmin(history_full.history['loss'])  
    best_training_accuracy = accuracy_history.acc[best_epoch_index]

    # Append training acc to total  
    all_best_training_acc.append(best_training_accuracy)
    total_training_acc.append(accuracy_history.acc)

    # Append training acc just for this CV
    cv_training_acc_total.append(accuracy_history.acc)
    cv_training_acc_best.append(best_training_accuracy)
    
    # Evaluate the model on the held-out test set
    test_loss, test_accuracy = model_full.evaluate(X_test_scaled, y_test_encoded)

    y_test_pred_prob = model_full.predict(X_test_scaled)
    y_test_pred = np.argmax(y_test_pred_prob, axis=1)  
    y_test_true = np.argmax(y_test_encoded, axis=1)    

    ################################
    # LOG MAJORITY VOTE PER CAT_ID #
    ################################

    # Convert numeric predictions back to age group labels
    predicted_age_groups = label_encoder.inverse_transform(y_test_pred)
    actual_labels = label_encoder.inverse_transform(y_test_true)
    
    # Map predictions and actual labels back to cat_ids
    test_results = pd.DataFrame({
        'cat_id': df_test_updated['cat_id'],
        'predicted_age_group': predicted_age_groups,
        'actual_age_group': actual_labels
    })
    
    # Group by cat_id and aggregate predicted age groups
    majority_votes = test_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
    actual_groups = test_results.groupby('cat_id')['actual_age_group'].first()
    
    # Calculate the accuracy of majority voting
    correct_predictions = (majority_votes == actual_groups).sum()
    total_cats = len(actual_groups)
    majority_vote_accuracy = correct_predictions / total_cats
    
    # Log the accuracy of the majority voting
    logger(f"Majority Vote Accuracy for cat_id for this fold: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

    ####################################################
    # COLLECT PREDICTIONS FOR GENDER & CAT_ID ANALYSIS #
    ####################################################

    # Debugging print statements
    print(f'Before appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Extend lists with current fold results
    all_cat_ids.extend(df_test_updated['cat_id'].tolist())
    all_predicted_age_groups.extend(predicted_age_groups)
    all_actual_age_groups.extend(actual_labels)
    all_gender.extend(df_test_updated['gender'].tolist())

    # Debugging print statements
    print(f'After appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Calculate additional metrics
    test_precision = precision_score(y_test_true, y_test_pred, average='macro')  # Use 'macro' for imbalanced datasets
    test_recall = recall_score(y_test_true, y_test_pred, average='macro')
    test_f1 = f1_score(y_test_true, y_test_pred, average='macro')

    # prepare averages of outer metrics
    unseen_f1.append(test_f1)
    unseen_losses.append(test_loss)
    unseen_accuracies.append(test_accuracy)
    unseen_precisions.append(test_precision)
    unseen_recalls.append(test_recall)

    # Print final test results
    logger(f"Final Test Results - Loss: {test_loss}, Accuracy: {test_accuracy}, Precision: {test_precision}, Recall: {test_recall}, F1 Score: {test_f1}", file=log_file_path)

    # Generate the confusion matrix
    cm = confusion_matrix(y_test, y_test_pred)
    logger(f"Confusion Matrix:\n {cm}", file=log_file_path)

# Calculate the overall average metrics
unseen_set_avg_f1 = np.mean(unseen_f1)
unseen_set_avg_loss = np.mean(unseen_losses)
unseen_set_avg_acc = np.mean(unseen_accuracies)
unseen_set_avg_precision = np.mean(unseen_precisions)
unseen_set_avg_recall = np.mean(unseen_recalls)

logger(f"\nFinal Average F1-Score across all UNSEEN TEST sets: {unseen_set_avg_f1}", file=log_file_path)
logger(f"\nFinal Average Loss across all UNSEEN TEST sets: {unseen_set_avg_loss}", file=log_file_path)
logger(f"\nFinal Average Accuracy across all UNSEEN TEST sets: {unseen_set_avg_acc}", file=log_file_path)
logger(f"\nFinal Average Precision across all UNSEEN TEST sets: {unseen_set_avg_precision}", file=log_file_path)
logger(f"\nFinal Average Recall across all UNSEEN TEST sets: {unseen_set_avg_recall}\n", file=log_file_path)

# Append averages to total lists
average_fold_f1.append(unseen_set_avg_f1)
average_fold_losses.append(unseen_set_avg_loss)
average_fold_accuracies.append(unseen_set_avg_acc)
average_fold_precisions.append(unseen_set_avg_precision)
average_fold_recalls.append(unseen_set_avg_recall)

# Append all to total lists
all_f1.append(unseen_f1)
all_losses.append(unseen_losses)
all_accuracies.append(unseen_accuracies)
all_precisions.append(unseen_precisions)
all_recalls.append(unseen_recalls)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# outer_fold 1
# Train Set Group Distribution:
# 046A    45
# 103A    33
# 002B    30
# 047A    22
# 020A    20
# 000B    19
# 057A    17
# 019A    17
# 074A    16
# 029A    15
# 097A    15
# 097B    14
# 106A    13
# 101A    12
# 051A    12
# 055A    12
# 116A    12
# 111A    12
# 042A    11
# 028A    11
# 063A    11
# 040A    10
# 025A    10
# 059A    10
# 014B    10
# 016A     9
# 065A     9
# 051B     9
# 072A     9
# 001A     9
# 005A     9
# 022A     9
# 013B     8
# 068A     8
# 117A     7
# 027A     7
# 031A     7
# 007A     6
# 023A     6
# 039A     6
# 099A     6
# 075A     5
# 108A     5
# 094A     5
# 021A     5
# 008A     5
# 044A     5
# 070A     5
# 109A     5
# 003A     4
# 009A     4
# 045A     4
# 104A     4
# 026A     4
# 025C     4
# 113A     3
# 053A     3
# 056A     3
# 012A     3
# 058A     3
# 010A     3
# 060A     3
# 014A     3
# 025B     2
# 052A     2
# 037A     2
# 102A     2
# 087A     2
# 032A     2
# 110A     1
# 090A     1
# 024A     1
# 115A     1
# 076A     1
# 041A     1
# 019B     1
# 088A     1
# 048A     1
# 026C     1
# 049A     1
# 091A     1
# 073A     1
# 043A     1
# 026B     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 000A    39
# 002A    13
# 067A    11
# 033A     9
# 071A     9
# 015A     7
# 095A     7
# 036A     7
# 050A     5
# 023B     4
# 006A     3
# 105A     3
# 062A     3
# 034A     3
# 061A     2
# 018A     2
# 038A     2
# 054A     2
# 069A     2
# 011A     2
# 093A     2
# 035A     2
# 004A     1
# 096A     1
# 066A     1
# 092A     1
# 064A     1
# 100A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    239
# M    235
# F    174
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# F    57
# M    51
# X    37
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [001A, 103A, 097B, 028A, 019A, 074A, 020A, 002...
# kitten    [044A, 014B, 111A, 040A, 046A, 047A, 042A, 109...
# senior    [097A, 057A, 106A, 104A, 055A, 059A, 113A, 116...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [006A, 000A, 033A, 015A, 071A, 067A, 062A, 095...
# kitten                                               [050A]
# senior                             [093A, 054A, 011A, 061A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 51, 'kitten': 15, 'senior': 18}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 23, 'kitten': 1, 'senior': 4}
# Unique Training/Validation Group IDs:
# ['000B' '001A' '002B' '003A' '005A' '007A' '008A' '009A' '010A' '012A'
#  '013B' '014A' '014B' '016A' '019A' '019B' '020A' '021A' '022A' '023A'
#  '024A' '025A' '025B' '025C' '026A' '026B' '026C' '027A' '028A' '029A'
#  '031A' '032A' '037A' '039A' '040A' '041A' '042A' '043A' '044A' '045A'
#  '046A' '047A' '048A' '049A' '051A' '051B' '052A' '053A' '055A' '056A'
#  '057A' '058A' '059A' '060A' '063A' '065A' '068A' '070A' '072A' '073A'
#  '074A' '075A' '076A' '087A' '088A' '090A' '091A' '094A' '097A' '097B'
#  '099A' '101A' '102A' '103A' '104A' '106A' '108A' '109A' '110A' '111A'
#  '113A' '115A' '116A' '117A']
# Unique Test Group IDs:
# ['000A' '002A' '004A' '006A' '011A' '015A' '018A' '023B' '033A' '034A'
#  '035A' '036A' '038A' '050A' '054A' '061A' '062A' '064A' '066A' '067A'
#  '069A' '071A' '092A' '093A' '095A' '096A' '100A' '105A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'000A'}
# Removed from Training/Validation Set:
# {'010A'}
# Moved to Test Set:
# {'010A'}
# Removed from Test Set
# {'000A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002B' '003A' '005A' '007A' '008A' '009A' '012A'
#  '013B' '014A' '014B' '016A' '019A' '019B' '020A' '021A' '022A' '023A'
#  '024A' '025A' '025B' '025C' '026A' '026B' '026C' '027A' '028A' '029A'
#  '031A' '032A' '037A' '039A' '040A' '041A' '042A' '043A' '044A' '045A'
#  '046A' '047A' '048A' '049A' '051A' '051B' '052A' '053A' '055A' '056A'
#  '057A' '058A' '059A' '060A' '063A' '065A' '068A' '070A' '072A' '073A'
#  '074A' '075A' '076A' '087A' '088A' '090A' '091A' '094A' '097A' '097B'
#  '099A' '101A' '102A' '103A' '104A' '106A' '108A' '109A' '110A' '111A'
#  '113A' '115A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['002A' '004A' '006A' '010A' '011A' '015A' '018A' '023B' '033A' '034A'
#  '035A' '036A' '038A' '050A' '054A' '061A' '062A' '064A' '066A' '067A'
#  '069A' '071A' '092A' '093A' '095A' '096A' '100A' '105A']
# Length of X_train_val:
# 684
# Length of y_train_val:
# 684
# Length of groups_train_val:
# 684
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     377
# senior    141
# kitten    130
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     132
# senior      8
# kitten      5
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     413
# senior    141
# kitten    130
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     96
# senior     8
# kitten     5
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 1016, 2: 997, 1: 922})
# Epoch 1/1500
# 46/46 [==============================] - 1s 6ms/step - loss: 0.4176 - accuracy: 0.8538
# Epoch 2/1500
# 46/46 [==============================] - 0s 5ms/step - loss: 0.1117 - accuracy: 0.9595
# Epoch 3/1500
# 46/46 [==============================] - 0s 6ms/step - loss: 0.0397 - accuracy: 0.9898
# Epoch 4/1500
# 46/46 [==============================] - 0s 6ms/step - loss: 0.0245 - accuracy: 0.9939
# Epoch 5/1500
# 46/46 [==============================] - 0s 6ms/step - loss: 0.0184 - accuracy: 0.9942
# Epoch 6/1500
# 46/46 [==============================] - 0s 6ms/step - loss: 0.0128 - accuracy: 0.9963
# Epoch 7/1500
# 46/46 [==============================] - 0s 6ms/step - loss: 0.0108 - accuracy: 0.9973
# Epoch 8/1500
# 46/46 [==============================] - 0s 6ms/step - loss: 0.0061 - accuracy: 0.9986
# Epoch 9/1500
# 46/46 [==============================] - 0s 6ms/step - loss: 0.0085 - accuracy: 0.9980
# Epoch 10/1500
# 46/46 [==============================] - 0s 6ms/step - loss: 0.0071 - accuracy: 0.9973
# Epoch 11/1500
# 46/46 [==============================] - 0s 6ms/step - loss: 0.0094 - accuracy: 0.9969
# Epoch 12/1500
# 46/46 [==============================] - 0s 6ms/step - loss: 0.0070 - accuracy: 0.9980
# Epoch 13/1500
# 46/46 [==============================] - 0s 6ms/step - loss: 0.0036 - accuracy: 0.9986
# Epoch 14/1500
# 46/46 [==============================] - 0s 6ms/step - loss: 0.0036 - accuracy: 0.9993
# Epoch 15/1500
# 46/46 [==============================] - 0s 6ms/step - loss: 0.0052 - accuracy: 0.9983
# Epoch 16/1500
# 46/46 [==============================] - 0s 6ms/step - loss: 0.0048 - accuracy: 0.9990
# Epoch 17/1500
# 46/46 [==============================] - 0s 6ms/step - loss: 0.0063 - accuracy: 0.9969
# Epoch 18/1500
# 46/46 [==============================] - 0s 6ms/step - loss: 0.0084 - accuracy: 0.9976
# Epoch 19/1500
# 46/46 [==============================] - 0s 6ms/step - loss: 0.0044 - accuracy: 0.9990
# Epoch 20/1500
# 46/46 [==============================] - 0s 6ms/step - loss: 0.0059 - accuracy: 0.9973
# Epoch 21/1500
# 46/46 [==============================] - 0s 6ms/step - loss: 0.0108 - accuracy: 0.9973
# Epoch 22/1500
# 46/46 [==============================] - 0s 6ms/step - loss: 0.0105 - accuracy: 0.9963
# Epoch 23/1500
# 46/46 [==============================] - 0s 6ms/step - loss: 0.0075 - accuracy: 0.9976
# Epoch 24/1500
# 46/46 [==============================] - 0s 7ms/step - loss: 0.0077 - accuracy: 0.9976
# Epoch 25/1500
# 46/46 [==============================] - 0s 7ms/step - loss: 0.0078 - accuracy: 0.9963
# Epoch 26/1500
# 46/46 [==============================] - 0s 6ms/step - loss: 0.0239 - accuracy: 0.9966
# Epoch 27/1500
# 46/46 [==============================] - 0s 6ms/step - loss: 0.0143 - accuracy: 0.9973
# Epoch 28/1500
# 46/46 [==============================] - 0s 6ms/step - loss: 0.0045 - accuracy: 0.9986
# Epoch 29/1500
# 46/46 [==============================] - 0s 6ms/step - loss: 0.0070 - accuracy: 0.9969
# Epoch 30/1500
# 46/46 [==============================] - 0s 7ms/step - loss: 0.0052 - accuracy: 0.9986
# Epoch 31/1500
# 46/46 [==============================] - 0s 6ms/step - loss: 0.0043 - accuracy: 0.9983
# Epoch 32/1500
# 46/46 [==============================] - 0s 6ms/step - loss: 0.0029 - accuracy: 0.9993
# Epoch 33/1500
# 46/46 [==============================] - 0s 6ms/step - loss: 0.0051 - accuracy: 0.9993
# Epoch 34/1500
# 46/46 [==============================] - 0s 6ms/step - loss: 0.0022 - accuracy: 0.9997
# Epoch 35/1500
# 46/46 [==============================] - 0s 6ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 36/1500
# 46/46 [==============================] - 0s 6ms/step - loss: 0.0020 - accuracy: 0.9993
# Epoch 37/1500
# 46/46 [==============================] - 0s 6ms/step - loss: 0.0038 - accuracy: 0.9983
# Epoch 38/1500
# 46/46 [==============================] - 0s 6ms/step - loss: 0.0040 - accuracy: 0.9993
# Epoch 39/1500
# 46/46 [==============================] - 0s 6ms/step - loss: 0.0056 - accuracy: 0.9976
# Epoch 40/1500
# 46/46 [==============================] - 0s 6ms/step - loss: 0.0042 - accuracy: 0.9980
# Epoch 41/1500
# 46/46 [==============================] - 0s 6ms/step - loss: 0.0068 - accuracy: 0.9980
# Epoch 42/1500
# 46/46 [==============================] - 0s 6ms/step - loss: 0.0063 - accuracy: 0.9973
# Epoch 43/1500
# 46/46 [==============================] - 0s 6ms/step - loss: 0.0036 - accuracy: 0.9990
# Epoch 44/1500
# 46/46 [==============================] - 0s 6ms/step - loss: 0.0037 - accuracy: 0.9990
# Epoch 45/1500
# 46/46 [==============================] - 0s 6ms/step - loss: 0.0037 - accuracy: 0.9983
# Epoch 46/1500
# 46/46 [==============================] - 0s 6ms/step - loss: 0.0021 - accuracy: 0.9993
# Epoch 47/1500
# 46/46 [==============================] - 0s 6ms/step - loss: 0.0057 - accuracy: 0.9976
# Epoch 48/1500
# 46/46 [==============================] - 0s 6ms/step - loss: 0.0050 - accuracy: 0.9993
# Epoch 49/1500
# 46/46 [==============================] - 0s 6ms/step - loss: 0.0052 - accuracy: 0.9983
# Epoch 50/1500
# 46/46 [==============================] - 0s 6ms/step - loss: 0.0025 - accuracy: 0.9990
# Epoch 51/1500
# 46/46 [==============================] - 0s 7ms/step - loss: 0.0043 - accuracy: 0.9983
# Epoch 52/1500
# 46/46 [==============================] - 0s 7ms/step - loss: 0.0024 - accuracy: 0.9990
# Epoch 53/1500
# 46/46 [==============================] - 0s 6ms/step - loss: 0.0047 - accuracy: 0.9983
# Epoch 54/1500
# 46/46 [==============================] - 0s 6ms/step - loss: 0.0028 - accuracy: 0.9986
# Epoch 55/1500
# 46/46 [==============================] - 0s 6ms/step - loss: 0.0029 - accuracy: 0.9990
# Epoch 56/1500
# 46/46 [==============================] - 0s 7ms/step - loss: 0.0018 - accuracy: 0.9997
# Epoch 57/1500
# 46/46 [==============================] - 0s 6ms/step - loss: 0.0027 - accuracy: 0.9990
# Epoch 58/1500
# 46/46 [==============================] - 0s 6ms/step - loss: 0.0035 - accuracy: 0.9983
# Epoch 59/1500
# 46/46 [==============================] - 0s 6ms/step - loss: 0.0032 - accuracy: 0.9993
# Epoch 60/1500
# 46/46 [==============================] - 0s 6ms/step - loss: 0.0027 - accuracy: 0.9986
# Epoch 61/1500
# 46/46 [==============================] - 0s 6ms/step - loss: 0.0039 - accuracy: 0.9990
# Epoch 62/1500
# 46/46 [==============================] - 0s 7ms/step - loss: 0.0061 - accuracy: 0.9983
# Epoch 63/1500
# 46/46 [==============================] - 0s 6ms/step - loss: 0.0102 - accuracy: 0.9959
# Epoch 64/1500
# 43/46 [===========================>..] - ETA: 0s - loss: 0.0041 - accuracy: 0.9982Restoring model weights from the end of the best epoch: 34.
# 46/46 [==============================] - 0s 7ms/step - loss: 0.0039 - accuracy: 0.9983
# Epoch 64: early stopping
# 4/4 [==============================] - 0s 2ms/step - loss: 1.0778 - accuracy: 0.8257
# 4/4 [==============================] - 0s 2ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.75 (21/28)
# Before appending - Cat IDs: 0, Predictions: 0, Actuals: 0, Gender: 0
# After appending - Cat IDs: 109, Predictions: 109, Actuals: 109, Gender: 109
# Final Test Results - Loss: 1.0778368711471558, Accuracy: 0.8256880640983582, Precision: 0.5416666666666667, Recall: 0.7048611111111112, F1 Score: 0.5931222984998729
# Confusion Matrix:
#  [[83  4  9]
#  [ 0  5  0]
#  [ 5  1  2]]
# outer_fold 2
# Train Set Group Distribution:
# 046A    45
# 000A    39
# 047A    22
# 057A    17
# 019A    17
# 074A    16
# 097A    15
# 002A    13
# 106A    13
# 051A    12
# 111A    12
# 116A    12
# 055A    12
# 067A    11
# 063A    11
# 059A    10
# 040A    10
# 025A    10
# 071A     9
# 022A     9
# 001A     9
# 005A     9
# 072A     9
# 065A     9
# 033A     9
# 068A     8
# 027A     7
# 031A     7
# 095A     7
# 117A     7
# 015A     7
# 036A     7
# 023A     6
# 039A     6
# 099A     6
# 007A     6
# 109A     5
# 075A     5
# 050A     5
# 094A     5
# 108A     5
# 023B     4
# 009A     4
# 003A     4
# 045A     4
# 026A     4
# 025C     4
# 058A     3
# 060A     3
# 006A     3
# 062A     3
# 034A     3
# 113A     3
# 014A     3
# 105A     3
# 037A     2
# 061A     2
# 011A     2
# 035A     2
# 093A     2
# 018A     2
# 069A     2
# 054A     2
# 038A     2
# 091A     1
# 024A     1
# 100A     1
# 110A     1
# 115A     1
# 096A     1
# 019B     1
# 004A     1
# 048A     1
# 066A     1
# 043A     1
# 073A     1
# 026C     1
# 064A     1
# 041A     1
# 092A     1
# 049A     1
# 026B     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 103A    33
# 002B    30
# 020A    20
# 000B    19
# 029A    15
# 097B    14
# 101A    12
# 028A    11
# 042A    11
# 014B    10
# 051B     9
# 016A     9
# 013B     8
# 008A     5
# 021A     5
# 044A     5
# 070A     5
# 104A     4
# 056A     3
# 012A     3
# 053A     3
# 010A     3
# 032A     2
# 087A     2
# 052A     2
# 102A     2
# 025B     2
# 076A     1
# 088A     1
# 090A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    231
# F    164
# M    148
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# M    138
# F     67
# X     45
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [006A, 000A, 033A, 015A, 001A, 071A, 019A, 074...
# kitten    [111A, 040A, 046A, 047A, 109A, 050A, 043A, 049...
# senior    [093A, 097A, 057A, 106A, 055A, 059A, 113A, 116...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [103A, 097B, 028A, 020A, 002B, 101A, 029A, 013...
# kitten                                   [044A, 014B, 042A]
# senior                       [104A, 051B, 056A, 016A, 090A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 52, 'kitten': 13, 'senior': 17}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 22, 'kitten': 3, 'senior': 5}
# Unique Training/Validation Group IDs:
# ['000A' '001A' '002A' '003A' '004A' '005A' '006A' '007A' '009A' '011A'
#  '014A' '015A' '018A' '019A' '019B' '022A' '023A' '023B' '024A' '025A'
#  '025C' '026A' '026B' '026C' '027A' '031A' '033A' '034A' '035A' '036A'
#  '037A' '038A' '039A' '040A' '041A' '043A' '045A' '046A' '047A' '048A'
#  '049A' '050A' '051A' '054A' '055A' '057A' '058A' '059A' '060A' '061A'
#  '062A' '063A' '064A' '065A' '066A' '067A' '068A' '069A' '071A' '072A'
#  '073A' '074A' '075A' '091A' '092A' '093A' '094A' '095A' '096A' '097A'
#  '099A' '100A' '105A' '106A' '108A' '109A' '110A' '111A' '113A' '115A'
#  '116A' '117A']
# Unique Test Group IDs:
# ['000B' '002B' '008A' '010A' '012A' '013B' '014B' '016A' '020A' '021A'
#  '025B' '028A' '029A' '032A' '042A' '044A' '051B' '052A' '053A' '056A'
#  '070A' '076A' '087A' '088A' '090A' '097B' '101A' '102A' '103A' '104A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '001A' '002A' '003A' '004A' '005A' '006A' '007A' '009A' '011A'
#  '014A' '015A' '018A' '019A' '019B' '022A' '023A' '023B' '024A' '025A'
#  '025C' '026A' '026B' '026C' '027A' '031A' '033A' '034A' '035A' '036A'
#  '037A' '038A' '039A' '040A' '041A' '043A' '045A' '046A' '047A' '048A'
#  '049A' '050A' '051A' '054A' '055A' '057A' '058A' '059A' '060A' '061A'
#  '062A' '063A' '064A' '065A' '066A' '067A' '068A' '069A' '071A' '072A'
#  '073A' '074A' '075A' '091A' '092A' '093A' '094A' '095A' '096A' '097A'
#  '099A' '100A' '105A' '106A' '108A' '109A' '110A' '111A' '113A' '115A'
#  '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['000B' '002B' '008A' '010A' '012A' '013B' '014B' '016A' '020A' '021A'
#  '025B' '028A' '029A' '032A' '042A' '044A' '051B' '052A' '053A' '056A'
#  '070A' '076A' '087A' '088A' '090A' '097B' '101A' '102A' '103A' '104A']
# Length of X_train_val:
# 543
# Length of y_train_val:
# 543
# Length of groups_train_val:
# 543
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     311
# senior    123
# kitten    109
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     198
# kitten     26
# senior     26
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     311
# senior    123
# kitten    109
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     198
# kitten     26
# senior     26
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Age group distribution: Counter({2: 875, 1: 785, 0: 769})
# Epoch 1/1500
# 38/38 [==============================] - 1s 5ms/step - loss: 0.4660 - accuracy: 0.8378
# Epoch 2/1500
# 38/38 [==============================] - 0s 5ms/step - loss: 0.0831 - accuracy: 0.9683
# Epoch 3/1500
# 38/38 [==============================] - 0s 5ms/step - loss: 0.0434 - accuracy: 0.9864
# Epoch 4/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0245 - accuracy: 0.9922
# Epoch 5/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0160 - accuracy: 0.9938
# Epoch 6/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0136 - accuracy: 0.9963
# Epoch 7/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0119 - accuracy: 0.9963
# Epoch 8/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0087 - accuracy: 0.9984
# Epoch 9/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0121 - accuracy: 0.9959
# Epoch 10/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0106 - accuracy: 0.9959
# Epoch 11/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 12/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0065 - accuracy: 0.9988
# Epoch 13/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0064 - accuracy: 0.9988
# Epoch 14/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 15/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0046 - accuracy: 0.9984
# Epoch 16/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0048 - accuracy: 0.9992
# Epoch 17/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 18/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0038 - accuracy: 0.9992
# Epoch 19/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0018 - accuracy: 0.9996
# Epoch 20/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 21/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0019 - accuracy: 0.9992
# Epoch 22/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0018 - accuracy: 0.9996
# Epoch 23/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0028 - accuracy: 0.9992
# Epoch 24/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 25/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0020 - accuracy: 0.9996
# Epoch 26/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0023 - accuracy: 0.9996
# Epoch 27/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0019 - accuracy: 0.9992
# Epoch 28/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0044 - accuracy: 0.9984
# Epoch 29/1500
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0056 - accuracy: 0.9984
# Epoch 30/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0059 - accuracy: 0.9979
# Epoch 31/1500
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0110 - accuracy: 0.9963
# Epoch 32/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0085 - accuracy: 0.9979
# Epoch 33/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0078 - accuracy: 0.9975
# Epoch 34/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0050 - accuracy: 0.9984
# Epoch 35/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0039 - accuracy: 0.9988
# Epoch 36/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0040 - accuracy: 0.9979
# Epoch 37/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0058 - accuracy: 0.9984
# Epoch 38/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0107 - accuracy: 0.9955
# Epoch 39/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0070 - accuracy: 0.9975
# Epoch 40/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0063 - accuracy: 0.9979
# Epoch 41/1500
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0030 - accuracy: 0.9992
# Epoch 42/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0027 - accuracy: 0.9992
# Epoch 43/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0021 - accuracy: 0.9996
# Epoch 44/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0025 - accuracy: 0.9988
# Epoch 45/1500
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0016 - accuracy: 0.9996
# Epoch 46/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0014 - accuracy: 0.9996
# Epoch 47/1500
# 33/38 [=========================>....] - ETA: 0s - loss: 0.0034 - accuracy: 0.9991Restoring model weights from the end of the best epoch: 17.
# 38/38 [==============================] - 1s 15ms/step - loss: 0.0037 - accuracy: 0.9988
# Epoch 47: early stopping
# 8/8 [==============================] - 0s 2ms/step - loss: 1.8332 - accuracy: 0.7240
# 8/8 [==============================] - 0s 2ms/step
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Majority Vote Accuracy for cat_id for this fold: 0.77 (23/30)
# Before appending - Cat IDs: 109, Predictions: 109, Actuals: 109, Gender: 109
# After appending - Cat IDs: 359, Predictions: 359, Actuals: 359, Gender: 359
# Final Test Results - Loss: 1.8332140445709229, Accuracy: 0.7239999771118164, Precision: 0.5955387205387205, Recall: 0.494042994042994, F1 Score: 0.5305745628326274
# Confusion Matrix:
#  [[164   2  32]
#  [ 11  14   1]
#  [ 23   0   3]]
# outer_fold 3
# Train Set Group Distribution:
# 046A    45
# 000A    39
# 103A    33
# 002B    30
# 020A    20
# 000B    19
# 019A    17
# 074A    16
# 029A    15
# 097A    15
# 097B    14
# 002A    13
# 106A    13
# 101A    12
# 051A    12
# 028A    11
# 067A    11
# 042A    11
# 063A    11
# 014B    10
# 005A     9
# 016A     9
# 051B     9
# 065A     9
# 072A     9
# 071A     9
# 033A     9
# 068A     8
# 013B     8
# 036A     7
# 015A     7
# 095A     7
# 023A     6
# 099A     6
# 070A     5
# 094A     5
# 108A     5
# 075A     5
# 008A     5
# 044A     5
# 021A     5
# 050A     5
# 104A     4
# 026A     4
# 003A     4
# 023B     4
# 025C     4
# 012A     3
# 056A     3
# 053A     3
# 060A     3
# 010A     3
# 006A     3
# 062A     3
# 105A     3
# 014A     3
# 034A     3
# 038A     2
# 093A     2
# 025B     2
# 037A     2
# 102A     2
# 061A     2
# 011A     2
# 035A     2
# 018A     2
# 052A     2
# 087A     2
# 069A     2
# 032A     2
# 054A     2
# 043A     1
# 090A     1
# 100A     1
# 096A     1
# 110A     1
# 076A     1
# 064A     1
# 092A     1
# 088A     1
# 004A     1
# 048A     1
# 066A     1
# 026B     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 047A    22
# 057A    17
# 055A    12
# 116A    12
# 111A    12
# 059A    10
# 025A    10
# 040A    10
# 022A     9
# 001A     9
# 027A     7
# 117A     7
# 031A     7
# 039A     6
# 007A     6
# 109A     5
# 045A     4
# 009A     4
# 058A     3
# 113A     3
# 073A     1
# 049A     1
# 041A     1
# 091A     1
# 026C     1
# 019B     1
# 115A     1
# 024A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    252
# X    192
# F    166
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    84
# F    65
# M    34
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [006A, 000A, 033A, 015A, 103A, 071A, 097B, 028...
# kitten     [044A, 014B, 046A, 042A, 050A, 043A, 048A, 110A]
# senior    [093A, 097A, 106A, 104A, 051B, 054A, 056A, 051...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [001A, 022A, 091A, 039A, 009A, 027A, 025A, 007...
# kitten     [111A, 040A, 047A, 109A, 049A, 041A, 045A, 115A]
# senior     [057A, 055A, 059A, 113A, 116A, 117A, 058A, 024A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 62, 'kitten': 8, 'senior': 14}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 12, 'kitten': 8, 'senior': 8}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '002A' '002B' '003A' '004A' '005A' '006A' '008A' '010A'
#  '011A' '012A' '013B' '014A' '014B' '015A' '016A' '018A' '019A' '020A'
#  '021A' '023A' '023B' '025B' '025C' '026A' '026B' '028A' '029A' '032A'
#  '033A' '034A' '035A' '036A' '037A' '038A' '042A' '043A' '044A' '046A'
#  '048A' '050A' '051A' '051B' '052A' '053A' '054A' '056A' '060A' '061A'
#  '062A' '063A' '064A' '065A' '066A' '067A' '068A' '069A' '070A' '071A'
#  '072A' '074A' '075A' '076A' '087A' '088A' '090A' '092A' '093A' '094A'
#  '095A' '096A' '097A' '097B' '099A' '100A' '101A' '102A' '103A' '104A'
#  '105A' '106A' '108A' '110A']
# Unique Test Group IDs:
# ['001A' '007A' '009A' '019B' '022A' '024A' '025A' '026C' '027A' '031A'
#  '039A' '040A' '041A' '045A' '047A' '049A' '055A' '057A' '058A' '059A'
#  '073A' '091A' '109A' '111A' '113A' '115A' '116A' '117A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '002A' '002B' '003A' '004A' '005A' '006A' '008A' '010A'
#  '011A' '012A' '013B' '014A' '014B' '015A' '016A' '018A' '019A' '020A'
#  '021A' '023A' '023B' '025B' '025C' '026A' '026B' '028A' '029A' '032A'
#  '033A' '034A' '035A' '036A' '037A' '038A' '042A' '043A' '044A' '046A'
#  '048A' '050A' '051A' '051B' '052A' '053A' '054A' '056A' '060A' '061A'
#  '062A' '063A' '064A' '065A' '066A' '067A' '068A' '069A' '070A' '071A'
#  '072A' '074A' '075A' '076A' '087A' '088A' '090A' '092A' '093A' '094A'
#  '095A' '096A' '097A' '097B' '099A' '100A' '101A' '102A' '103A' '104A'
#  '105A' '106A' '108A' '110A']
# AFTER SWAP - Unique Test Group IDs:
# ['001A' '007A' '009A' '019B' '022A' '024A' '025A' '026C' '027A' '031A'
#  '039A' '040A' '041A' '045A' '047A' '049A' '055A' '057A' '058A' '059A'
#  '073A' '091A' '109A' '111A' '113A' '115A' '116A' '117A']
# Length of X_train_val:
# 610
# Length of y_train_val:
# 610
# Length of groups_train_val:
# 610
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     447
# senior     84
# kitten     79
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# senior    65
# adult     62
# kitten    56
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     447
# senior     84
# kitten     79
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# senior    65
# adult     62
# kitten    56
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 1108, 2: 556, 1: 527})
# Epoch 1/1500
# 35/35 [==============================] - 1s 5ms/step - loss: 0.4884 - accuracy: 0.8257
# Epoch 2/1500
# 35/35 [==============================] - 0s 5ms/step - loss: 0.1179 - accuracy: 0.9612
# Epoch 3/1500
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0518 - accuracy: 0.9822
# Epoch 4/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0344 - accuracy: 0.9886
# Epoch 5/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0174 - accuracy: 0.9950
# Epoch 6/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0189 - accuracy: 0.9941
# Epoch 7/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0064 - accuracy: 0.9982
# Epoch 8/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0089 - accuracy: 0.9982
# Epoch 9/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0096 - accuracy: 0.9977
# Epoch 10/1500
# 35/35 [==============================] - 0s 7ms/step - loss: 0.0081 - accuracy: 0.9963
# Epoch 11/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0048 - accuracy: 0.9986
# Epoch 12/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0066 - accuracy: 0.9986
# Epoch 13/1500
# 35/35 [==============================] - 0s 7ms/step - loss: 0.0046 - accuracy: 0.9991
# Epoch 14/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0053 - accuracy: 0.9982
# Epoch 15/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0027 - accuracy: 0.9991
# Epoch 16/1500
# 35/35 [==============================] - 0s 7ms/step - loss: 0.0040 - accuracy: 0.9986
# Epoch 17/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0063 - accuracy: 0.9977
# Epoch 18/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0051 - accuracy: 0.9986
# Epoch 19/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0079 - accuracy: 0.9973
# Epoch 20/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0036 - accuracy: 0.9995
# Epoch 21/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0067 - accuracy: 0.9982
# Epoch 22/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0091 - accuracy: 0.9963
# Epoch 23/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0089 - accuracy: 0.9982
# Epoch 24/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0110 - accuracy: 0.9968
# Epoch 25/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0107 - accuracy: 0.9954
# Epoch 26/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0051 - accuracy: 0.9986
# Epoch 27/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0109 - accuracy: 0.9963
# Epoch 28/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0067 - accuracy: 0.9968
# Epoch 29/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0047 - accuracy: 0.9977
# Epoch 30/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0116 - accuracy: 0.9963
# Epoch 31/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0093 - accuracy: 0.9977
# Epoch 32/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0030 - accuracy: 0.9995
# Epoch 33/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0094 - accuracy: 0.9973
# Epoch 34/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0093 - accuracy: 0.9986
# Epoch 35/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0132 - accuracy: 0.9959
# Epoch 36/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0122 - accuracy: 0.9963
# Epoch 37/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0148 - accuracy: 0.9950
# Epoch 38/1500
# 35/35 [==============================] - 0s 7ms/step - loss: 0.0038 - accuracy: 0.9991
# Epoch 39/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0014 - accuracy: 0.9995
# Epoch 40/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 7.4827e-04 - accuracy: 1.0000
# Epoch 41/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0020 - accuracy: 0.9995
# Epoch 42/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0020 - accuracy: 0.9995
# Epoch 43/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0025 - accuracy: 0.9995
# Epoch 44/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 5.3207e-04 - accuracy: 1.0000
# Epoch 45/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0016 - accuracy: 0.9995
# Epoch 46/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 47/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 48/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 6.3854e-04 - accuracy: 1.0000
# Epoch 49/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 6.2377e-04 - accuracy: 0.9995
# Epoch 50/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 4.7388e-04 - accuracy: 1.0000
# Epoch 51/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0011 - accuracy: 0.9995
# Epoch 52/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 9.0753e-04 - accuracy: 1.0000
# Epoch 53/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 9.3416e-04 - accuracy: 1.0000
# Epoch 54/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 7.2430e-04 - accuracy: 0.9995
# Epoch 55/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 2.8214e-04 - accuracy: 1.0000
# Epoch 56/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 8.1093e-04 - accuracy: 0.9995
# Epoch 57/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0014 - accuracy: 0.9995
# Epoch 58/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0119 - accuracy: 0.9977
# Epoch 59/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0028 - accuracy: 0.9991
# Epoch 60/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0042 - accuracy: 0.9982
# Epoch 61/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0028 - accuracy: 0.9986
# Epoch 62/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0027 - accuracy: 0.9995
# Epoch 63/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0044 - accuracy: 0.9991
# Epoch 64/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 65/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 7.8982e-04 - accuracy: 1.0000
# Epoch 66/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0017 - accuracy: 0.9995
# Epoch 67/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0017 - accuracy: 0.9991
# Epoch 68/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0025 - accuracy: 0.9986
# Epoch 69/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0063 - accuracy: 0.9986
# Epoch 70/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0028 - accuracy: 0.9991
# Epoch 71/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0025 - accuracy: 0.9991
# Epoch 72/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0015 - accuracy: 0.9995
# Epoch 73/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 8.8150e-04 - accuracy: 0.9995
# Epoch 74/1500
# 35/35 [==============================] - 0s 7ms/step - loss: 7.6744e-04 - accuracy: 0.9995
# Epoch 75/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0015 - accuracy: 0.9991
# Epoch 76/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0012 - accuracy: 0.9995
# Epoch 77/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0029 - accuracy: 0.9995
# Epoch 78/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 2.9911e-04 - accuracy: 1.0000
# Epoch 79/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 7.3255e-04 - accuracy: 1.0000
# Epoch 80/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 3.8772e-04 - accuracy: 1.0000
# Epoch 81/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 2.5616e-04 - accuracy: 1.0000
# Epoch 82/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 1.5389e-04 - accuracy: 1.0000
# Epoch 83/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 1.4159e-04 - accuracy: 1.0000
# Epoch 84/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 2.8405e-04 - accuracy: 1.0000
# Epoch 85/1500
# 28/35 [=======================>......] - ETA: 0s - loss: 1.7876e-04 - accuracy: 1.0000Restoring model weights from the end of the best epoch: 55.
# 35/35 [==============================] - 0s 6ms/step - loss: 1.7755e-04 - accuracy: 1.0000
# Epoch 85: early stopping
# 6/6 [==============================] - 0s 2ms/step - loss: 4.4221 - accuracy: 0.5355
# 6/6 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.57 (16/28)
# Before appending - Cat IDs: 359, Predictions: 359, Actuals: 359, Gender: 359
# After appending - Cat IDs: 542, Predictions: 542, Actuals: 542, Gender: 542
# Final Test Results - Loss: 4.422096252441406, Accuracy: 0.5355191230773926, Precision: 0.739307732008462, Recall: 0.540609122060735, F1 Score: 0.510747340852925
# Confusion Matrix:
#  [[57  4  1]
#  [27 29  0]
#  [53  0 12]]
# outer_fold 4
# Train Set Group Distribution:
# 000A    39
# 103A    33
# 002B    30
# 047A    22
# 020A    20
# 000B    19
# 057A    17
# 029A    15
# 097B    14
# 002A    13
# 111A    12
# 055A    12
# 101A    12
# 116A    12
# 067A    11
# 028A    11
# 042A    11
# 059A    10
# 025A    10
# 040A    10
# 014B    10
# 022A     9
# 071A     9
# 033A     9
# 001A     9
# 051B     9
# 016A     9
# 013B     8
# 027A     7
# 036A     7
# 031A     7
# 117A     7
# 095A     7
# 015A     7
# 007A     6
# 039A     6
# 050A     5
# 044A     5
# 021A     5
# 070A     5
# 008A     5
# 109A     5
# 009A     4
# 045A     4
# 023B     4
# 104A     4
# 058A     3
# 053A     3
# 010A     3
# 105A     3
# 012A     3
# 056A     3
# 006A     3
# 062A     3
# 034A     3
# 113A     3
# 093A     2
# 038A     2
# 035A     2
# 061A     2
# 052A     2
# 102A     2
# 025B     2
# 011A     2
# 087A     2
# 069A     2
# 032A     2
# 054A     2
# 018A     2
# 088A     1
# 115A     1
# 100A     1
# 090A     1
# 019B     1
# 096A     1
# 026C     1
# 004A     1
# 066A     1
# 076A     1
# 091A     1
# 041A     1
# 092A     1
# 049A     1
# 064A     1
# 073A     1
# 024A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 046A    45
# 019A    17
# 074A    16
# 097A    15
# 106A    13
# 051A    12
# 063A    11
# 005A     9
# 072A     9
# 065A     9
# 068A     8
# 023A     6
# 099A     6
# 075A     5
# 108A     5
# 094A     5
# 026A     4
# 003A     4
# 025C     4
# 060A     3
# 014A     3
# 037A     2
# 043A     1
# 048A     1
# 110A     1
# 026B     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    223
# F    189
# X    166
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    110
# M     63
# F     42
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [006A, 000A, 033A, 015A, 001A, 103A, 071A, 097...
# kitten    [044A, 014B, 111A, 040A, 047A, 042A, 109A, 050...
# senior    [093A, 057A, 104A, 055A, 059A, 113A, 116A, 051...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [019A, 074A, 005A, 072A, 065A, 023A, 063A, 099...
# kitten                             [046A, 043A, 048A, 110A]
# senior                       [097A, 106A, 051A, 094A, 108A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 57, 'kitten': 12, 'senior': 17}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 17, 'kitten': 4, 'senior': 5}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '004A' '006A' '007A' '008A' '009A'
#  '010A' '011A' '012A' '013B' '014B' '015A' '016A' '018A' '019B' '020A'
#  '021A' '022A' '023B' '024A' '025A' '025B' '026C' '027A' '028A' '029A'
#  '031A' '032A' '033A' '034A' '035A' '036A' '038A' '039A' '040A' '041A'
#  '042A' '044A' '045A' '047A' '049A' '050A' '051B' '052A' '053A' '054A'
#  '055A' '056A' '057A' '058A' '059A' '061A' '062A' '064A' '066A' '067A'
#  '069A' '070A' '071A' '073A' '076A' '087A' '088A' '090A' '091A' '092A'
#  '093A' '095A' '096A' '097B' '100A' '101A' '102A' '103A' '104A' '105A'
#  '109A' '111A' '113A' '115A' '116A' '117A']
# Unique Test Group IDs:
# ['003A' '005A' '014A' '019A' '023A' '025C' '026A' '026B' '037A' '043A'
#  '046A' '048A' '051A' '060A' '063A' '065A' '068A' '072A' '074A' '075A'
#  '094A' '097A' '099A' '106A' '108A' '110A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'046A'}
# Removed from Training/Validation Set:
# {'041A'}
# Moved to Test Set:
# {'041A'}
# Removed from Test Set
# {'046A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '004A' '006A' '007A' '008A' '009A'
#  '010A' '011A' '012A' '013B' '014B' '015A' '016A' '018A' '019B' '020A'
#  '021A' '022A' '023B' '024A' '025A' '025B' '026C' '027A' '028A' '029A'
#  '031A' '032A' '033A' '034A' '035A' '036A' '038A' '039A' '040A' '042A'
#  '044A' '045A' '046A' '047A' '049A' '050A' '051B' '052A' '053A' '054A'
#  '055A' '056A' '057A' '058A' '059A' '061A' '062A' '064A' '066A' '067A'
#  '069A' '070A' '071A' '073A' '076A' '087A' '088A' '090A' '091A' '092A'
#  '093A' '095A' '096A' '097B' '100A' '101A' '102A' '103A' '104A' '105A'
#  '109A' '111A' '113A' '115A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['003A' '005A' '014A' '019A' '023A' '025C' '026A' '026B' '037A' '041A'
#  '043A' '048A' '051A' '060A' '063A' '065A' '068A' '072A' '074A' '075A'
#  '094A' '097A' '099A' '106A' '108A' '110A']
# Length of X_train_val:
# 622
# Length of y_train_val:
# 622
# Length of groups_train_val:
# 622
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     392
# senior     99
# kitten     87
# Name: age_group, dtype: int64
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     117
# senior     50
# kitten     48
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     392
# kitten    131
# senior     99
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     117
# senior     50
# kitten      4
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 983, 1: 931, 2: 719})
# Epoch 1/1500
# 42/42 [==============================] - 1s 5ms/step - loss: 0.4714 - accuracy: 0.8390
# Epoch 2/1500
# 42/42 [==============================] - 0s 5ms/step - loss: 0.0930 - accuracy: 0.9662
# Epoch 3/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0619 - accuracy: 0.9784
# Epoch 4/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0362 - accuracy: 0.9867
# Epoch 5/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0227 - accuracy: 0.9901
# Epoch 6/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0121 - accuracy: 0.9962
# Epoch 7/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0144 - accuracy: 0.9947
# Epoch 8/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0087 - accuracy: 0.9973
# Epoch 9/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0144 - accuracy: 0.9958
# Epoch 10/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0126 - accuracy: 0.9951
# Epoch 11/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0104 - accuracy: 0.9966
# Epoch 12/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0124 - accuracy: 0.9954
# Epoch 13/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0070 - accuracy: 0.9985
# Epoch 14/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0101 - accuracy: 0.9966
# Epoch 15/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0053 - accuracy: 0.9985
# Epoch 16/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0111 - accuracy: 0.9958
# Epoch 17/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0103 - accuracy: 0.9977
# Epoch 18/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0067 - accuracy: 0.9977
# Epoch 19/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0103 - accuracy: 0.9962
# Epoch 20/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0144 - accuracy: 0.9954
# Epoch 21/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0117 - accuracy: 0.9962
# Epoch 22/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0077 - accuracy: 0.9973
# Epoch 23/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0077 - accuracy: 0.9981
# Epoch 24/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0066 - accuracy: 0.9985
# Epoch 25/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0096 - accuracy: 0.9962
# Epoch 26/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0025 - accuracy: 0.9996
# Epoch 27/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0027 - accuracy: 0.9992
# Epoch 28/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0060 - accuracy: 0.9973
# Epoch 29/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0114 - accuracy: 0.9966
# Epoch 30/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0179 - accuracy: 0.9958
# Epoch 31/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0091 - accuracy: 0.9962
# Epoch 32/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 33/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0104 - accuracy: 0.9970
# Epoch 34/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0100 - accuracy: 0.9970
# Epoch 35/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0047 - accuracy: 0.9989
# Epoch 36/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0060 - accuracy: 0.9973
# Epoch 37/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0039 - accuracy: 0.9989
# Epoch 38/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0023 - accuracy: 0.9996
# Epoch 39/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0042 - accuracy: 0.9981
# Epoch 40/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0100 - accuracy: 0.9973
# Epoch 41/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0047 - accuracy: 0.9992
# Epoch 42/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0044 - accuracy: 0.9985
# Epoch 43/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0062 - accuracy: 0.9985
# Epoch 44/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0140 - accuracy: 0.9951
# Epoch 45/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0047 - accuracy: 0.9985
# Epoch 46/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0055 - accuracy: 0.9981
# Epoch 47/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0077 - accuracy: 0.9970
# Epoch 48/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0146 - accuracy: 0.9977
# Epoch 49/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0088 - accuracy: 0.9973
# Epoch 50/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0055 - accuracy: 0.9985
# Epoch 51/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0046 - accuracy: 0.9985
# Epoch 52/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0036 - accuracy: 0.9989
# Epoch 53/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0105 - accuracy: 0.9977
# Epoch 54/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0037 - accuracy: 0.9996
# Epoch 55/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0054 - accuracy: 0.9981
# Epoch 56/1500
# 37/42 [=========================>....] - ETA: 0s - loss: 0.0028 - accuracy: 0.9992Restoring model weights from the end of the best epoch: 26.
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0029 - accuracy: 0.9992
# Epoch 56: early stopping
# 6/6 [==============================] - 0s 1ms/step - loss: 2.5128 - accuracy: 0.7076
# 6/6 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.85 (22/26)
# Before appending - Cat IDs: 542, Predictions: 542, Actuals: 542, Gender: 542
# After appending - Cat IDs: 713, Predictions: 713, Actuals: 713, Gender: 713
# Final Test Results - Loss: 2.512807846069336, Accuracy: 0.707602322101593, Precision: 0.6259633699633699, Recall: 0.7468376068376069, F1 Score: 0.6641904231281147
# Confusion Matrix:
#  [[96  3 18]
#  [ 0  4  0]
#  [29  0 21]]
#
# Final Average F1-Score across all UNSEEN TEST sets: 0.574658656328385
#
# Final Average Loss across all UNSEEN TEST sets: 2.461488753557205
#
# Final Average Accuracy across all UNSEEN TEST sets: 0.69820237159729
#
# Final Average Precision across all UNSEEN TEST sets: 0.6256191222943047
#
# Final Average Recall across all UNSEEN TEST sets: 0.6215877085131117

# %%
seed_2_folds_values = [unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1]

seed_2_training_acc_values = cv_training_acc_total

# Plotting all fold metrics
seed_2_folds_plot = plot_all_metrics(unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1, "Folds", "Fold Number")

# %% [markdown]
# ## Majority Voting on Total Entries per cat_id

# %%
# Debugging print statements
print(f'Checking - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
# Out:
# Checking - Cat IDs: 713, Predictions: 713, Actuals: 713, Gender: 713

# %%
# Create results df
full_results = pd.DataFrame({
    'cat_id': all_cat_ids,
    'predicted_age_group': all_predicted_age_groups,
    'actual_age_group': all_actual_age_groups,
    'all_gender': all_gender
})

# create a correct majority prediction column
full_results['correct'] = full_results['predicted_age_group'] == full_results['actual_age_group']

# %%
# Group by cat_id and aggregate predicted age groups
majority_votes = full_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first()

# Calculate the accuracy of majority voting
correct_predictions = (majority_votes == actual_groups).sum()
total_cats = len(actual_groups)
majority_vote_accuracy = correct_predictions / total_cats

logger(f"Overall Majority Vote Accuracy for cat_id: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

# store for final evaluation 
all_majority_vote_accuracies.append(majority_vote_accuracy)
# Out:
# Overall Majority Vote Accuracy for cat_id: 0.73 (80/110)

# %%
# Detailed df with predictions, actual labels, and comparison including majority vote
detailed_results = full_results.groupby('cat_id').apply(
    lambda x: pd.Series({
        'Predictions': list(x['predicted_age_group']),
        'Majority Vote': x['predicted_age_group'].mode()[0],
        'Actual Age Group': x['actual_age_group'].iloc[0],
        'Correct Majority Vote': x['predicted_age_group'].mode()[0] == x['actual_age_group'].iloc[0]
    })
).reset_index()

# Convert to DataFrame for better formatting and display
detailed_results = pd.DataFrame(detailed_results)

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 10)
pd.set_option('display.width', 1000)

sorted_detailed_results = detailed_results.sort_values(by='Correct Majority Vote', ascending=False)

# Display the sorted DataFrame
sorted_detailed_results
# Out:
#     cat_id                                        Predictions Majority Vote Actual Age Group  Correct Majority Vote
# 0     000B  [adult, senior, adult, adult, adult, adult, ad...         adult            adult                   True
# 45    039A         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 80    074A  [adult, adult, senior, adult, adult, adult, ad...         adult            adult                   True
# 79    073A                                            [adult]         adult            adult                   True
# 78    072A  [adult, adult, adult, senior, adult, adult, ad...         adult            adult                   True
# 77    071A  [adult, adult, adult, adult, adult, adult, sen...         adult            adult                   True
# 76    070A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 74    068A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 73    067A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 71    065A  [senior, adult, adult, adult, adult, senior, a...         adult            adult                   True
# 70    064A                                            [adult]         adult            adult                   True
# 69    063A  [adult, adult, adult, senior, adult, kitten, a...         adult            adult                   True
# 68    062A                              [adult, adult, adult]         adult            adult                   True
# 66    060A                             [adult, kitten, adult]         adult            adult                   True
# 64    058A                            [senior, adult, senior]        senior           senior                   True
# 58    052A                                    [adult, senior]         adult            adult                   True
# 1     001A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 53    048A                                           [kitten]        kitten           kitten                   True
# 51    045A                    [kitten, kitten, kitten, adult]        kitten           kitten                   True
# 50    044A            [kitten, kitten, kitten, adult, kitten]        kitten           kitten                   True
# 49    043A                                           [kitten]        kitten           kitten                   True
# 81    075A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 82    076A                                            [adult]         adult            adult                   True
# 83    087A                                     [adult, adult]         adult            adult                   True
# 95    100A                                            [adult]         adult            adult                   True
# 107   115A                                           [kitten]        kitten           kitten                   True
# 105   111A  [kitten, kitten, kitten, kitten, kitten, kitte...        kitten           kitten                   True
# 104   110A                                           [kitten]        kitten           kitten                   True
# 102   108A             [senior, senior, adult, senior, adult]        senior           senior                   True
# 100   105A                             [adult, adult, senior]         adult            adult                   True
# 98    103A  [adult, adult, adult, adult, adult, senior, ad...         adult            adult                   True
# 97    102A                                     [adult, adult]         adult            adult                   True
# 96    101A  [kitten, adult, adult, adult, adult, adult, ad...         adult            adult                   True
# 94    099A        [adult, adult, adult, kitten, adult, adult]         adult            adult                   True
# 84    088A                                            [adult]         adult            adult                   True
# 93    097B  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 92    097A  [adult, senior, adult, adult, senior, senior, ...        senior           senior                   True
# 91    096A                                            [adult]         adult            adult                   True
# 90    095A  [senior, adult, adult, adult, adult, adult, se...         adult            adult                   True
# 89    094A           [senior, senior, senior, senior, senior]        senior           senior                   True
# 87    092A                                            [adult]         adult            adult                   True
# 86    091A                                            [adult]         adult            adult                   True
# 85    090A                                           [senior]        senior           senior                   True
# 46    040A  [kitten, kitten, kitten, kitten, kitten, kitte...        kitten           kitten                   True
# 55    050A           [kitten, kitten, kitten, kitten, kitten]        kitten           kitten                   True
# 44    038A                                    [kitten, adult]         adult            adult                   True
# 14    013B  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 34    027A  [adult, adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 11    010A         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 32    026B                                            [adult]         adult            adult                   True
# 31    026A                       [adult, adult, adult, adult]         adult            adult                   True
# 30    025C                       [adult, adult, adult, adult]         adult            adult                   True
# 29    025B                                    [senior, adult]         adult            adult                   True
# 13    012A                              [adult, adult, adult]         adult            adult                   True
# 28    025A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 26    023B                       [adult, adult, adult, adult]         adult            adult                   True
# 16    014B  [senior, kitten, adult, adult, kitten, kitten,...        kitten           kitten                   True
# 25    023A         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 24    022A  [adult, adult, kitten, kitten, adult, adult, k...         adult            adult                   True
# 23    021A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 22    020A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 21    019B                                            [adult]         adult            adult                   True
# 20    019A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 19    018A                                     [adult, adult]         adult            adult                   True
# 15    014A                              [adult, adult, adult]         adult            adult                   True
# 10    009A                       [adult, adult, adult, adult]         adult            adult                   True
# 35    028A  [senior, senior, adult, senior, adult, adult, ...         adult            adult                   True
# 9     008A               [adult, adult, adult, kitten, adult]         adult            adult                   True
# 8     007A        [adult, adult, adult, adult, senior, adult]         adult            adult                   True
# 2     002A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 42    036A  [adult, adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 41    035A                                    [adult, senior]         adult            adult                   True
# 40    034A                             [adult, adult, kitten]         adult            adult                   True
# 39    033A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 3     002B  [adult, senior, adult, adult, adult, adult, ad...         adult            adult                   True
# 38    032A                                     [adult, adult]         adult            adult                   True
# 4     003A                       [adult, adult, adult, adult]         adult            adult                   True
# 37    031A  [adult, adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 7     006A                             [adult, adult, senior]         adult            adult                   True
# 17    015A  [adult, adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 103   109A                [adult, adult, adult, adult, adult]         adult           kitten                  False
# 5     004A                                           [kitten]        kitten            adult                  False
# 101   106A  [adult, adult, adult, senior, adult, adult, ad...         adult           senior                  False
# 106   113A                             [adult, adult, senior]         adult           senior                  False
# 12    011A                                    [adult, senior]         adult           senior                  False
# 6     005A  [senior, senior, senior, senior, senior, senio...        senior            adult                  False
# 99    104A                       [adult, adult, adult, adult]         adult           senior                  False
# 108   116A  [senior, senior, adult, senior, adult, adult, ...         adult           senior                  False
# 27    024A                                            [adult]         adult           senior                  False
# 88    093A                                    [adult, kitten]         adult           senior                  False
# 61    055A  [adult, senior, adult, adult, adult, adult, ad...         adult           senior                  False
# 47    041A                                    [adult, kitten]         adult           kitten                  False
# 48    042A  [kitten, adult, adult, kitten, adult, kitten, ...         adult           kitten                  False
# 52    047A  [adult, adult, kitten, adult, adult, adult, ad...         adult           kitten                  False
# 54    049A                                            [adult]         adult           kitten                  False
# 56    051A  [adult, adult, adult, adult, adult, adult, adu...         adult           senior                  False
# 57    051B  [adult, adult, adult, adult, adult, adult, adu...         adult           senior                  False
# 59    053A                           [senior, senior, senior]        senior            adult                  False
# 60    054A                                     [adult, adult]         adult           senior                  False
# 62    056A                             [adult, senior, adult]         adult           senior                  False
# 18    016A  [adult, adult, adult, senior, adult, adult, ad...         adult           senior                  False
# 63    057A  [adult, adult, adult, adult, adult, adult, adu...         adult           senior                  False
# 36    029A  [senior, senior, adult, adult, senior, senior,...        senior            adult                  False
# 65    059A  [senior, adult, adult, adult, senior, adult, s...         adult           senior                  False
# 67    061A                                    [adult, senior]         adult           senior                  False
# 33    026C                                           [kitten]        kitten            adult                  False
# 72    066A                                           [kitten]        kitten            adult                  False
# 75    069A                                   [senior, senior]        senior            adult                  False
# 43    037A                                   [senior, senior]        senior            adult                  False
# 109   117A  [adult, adult, adult, adult, adult, adult, adult]         adult           senior                  False

# %%
# Create df for majority votes
majority_df = majority_votes.reset_index()
majority_df.columns = ['cat_id', 'Majority_Vote']

# Get actual groups for each cat_id
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first().reset_index()

# Merge majority votes with actual groups
majority_with_actual = pd.merge(majority_df, actual_groups, on='cat_id')

# Add a column to check if the majority vote was correct
majority_with_actual['Majority_Correct'] = majority_with_actual['Majority_Vote'] == majority_with_actual['actual_age_group']

# Count correct majority votes per class
correct_majority_votes_per_class = majority_with_actual.groupby('actual_age_group')['Majority_Correct'].sum()

print("Correct Majority Votes per Class:")
print(correct_majority_votes_per_class)
# Out:
# Correct Majority Votes per Class:
# actual_age_group
# adult     65
# kitten    10
# senior     5
# Name: Majority_Correct, dtype: int64

# %%
# Calculate the total count and the number of correct predictions for each class
class_stats = majority_with_actual.groupby('actual_age_group').agg(
    total_count=('Majority_Correct', 'size'),  # Total number of cases per class
    correct_count=('Majority_Correct', 'sum')  # Sum of correct predictions per class
).reset_index()

# Calculate accuracy for each class
class_stats['accuracy'] = class_stats['correct_count'] / class_stats['total_count'] * 100

# store for final evaluation 
all_majority_vote_details.append(class_stats)

# Log detailed stats
print("Detailed Class Statistics for Majority Votes:")
print(class_stats)
# Out:
# Detailed Class Statistics for Majority Votes:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult           73             65  89.041096
# 1           kitten           15             10  66.666667
# 2           senior           22              5  22.727273

# %%
# Plot for Detailed Class Statistics for Majority Votes
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Accuracy of Majority Votes by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Detailed Class Statistics

# %%
# Calculate the total count and the number of correct predictions for each class
class_stats = full_results.groupby('actual_age_group').agg(
    total_count=('correct', 'size'),
    correct_count=('correct', 'sum')
).reset_index()

# Calculate accuracy for each class
class_stats['accuracy'] = class_stats['correct_count'] / class_stats['total_count'] * 100

# store for final evaluation 
all_class_stats.append(class_stats)

# Log the detailed stats
print("Detailed Class Statistics:")
print(class_stats)
# Out:
# Detailed Class Statistics:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult          473            400  84.566596
# 1           kitten           91             52  57.142857
# 2           senior          149             38  25.503356

# %%
# Plot for Detailed Class Statistics (Overall)
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Overall Accuracy by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Gender Exploration

# %%
# Group by gender and calculate the total count, correct predictions, and accuracy
gender_stats = full_results.groupby('all_gender').agg(
    count=('cat_id', 'size'),  # Total number of cases per gender
    correct=('correct', 'sum')  # Sum of correct predictions per gender
).reset_index()

# Calculate accuracy for each gender
gender_stats['accuracy'] = (gender_stats['correct'] / gender_stats['count'] * 100).round(2)

# Display the DataFrame
print("Accuracy by Gender:")
print(gender_stats)

# store for final evaluation 
all_gender_stats.append(gender_stats)
# Out:
# Accuracy by Gender:
#   all_gender  count  correct  accuracy
# 0          F    192      126     65.62
# 1          M    289      213     73.70
# 2          X    232      151     65.09

# %%
# Plot for Accuracy by Gender
styled_barplot(gender_stats, 'all_gender', 'accuracy', 
               'Accuracy by Gender', 
               'Gender', 'Accuracy (%)')

# %% [markdown]
# ### Log current total CV Stats

# %%
print("Total Majority Vote Accuracy so far:", all_majority_vote_accuracies)
print("Total Class Statistics so far:\n", all_class_stats)
print("Total Gender Accuracy so far:\n", all_gender_stats)
# Out:
# Total Majority Vote Accuracy so far: [0.7454545454545455, 0.7272727272727273]
# Total Class Statistics so far:
#  [  actual_age_group  total_count  correct_count   accuracy
# 0            adult          474            409  86.286920
# 1           kitten           91             50  54.945055
# 2           senior          149             44  29.530201,   actual_age_group  total_count  correct_count   accuracy
# 0            adult          473            400  84.566596
# 1           kitten           91             52  57.142857
# 2           senior          149             38  25.503356]
# Total Gender Accuracy so far:
#  [  all_gender  count  correct  accuracy
# 0          F    196      131     66.84
# 1          M    286      222     77.62
# 2          X    232      150     64.66,   all_gender  count  correct  accuracy
# 0          F    192      126     65.62
# 1          M    289      213     73.70
# 2          X    232      151     65.09]

# %% [markdown]
# # RANDOM SEED 3

# %%
# Set a fixed random seed for reproducibility
random.seed(int(random_seeds[2]))
np.random.seed(int(random_seeds[2]))
tf.random.set_seed(int(random_seeds[2]))

# Load datasets
dataframe = pd.read_csv('/Users/astrid/PycharmProjects/perch-2/scripts/perch_embeddings_april_10.csv')
augmented_df = pd.read_csv('/Users/astrid/PycharmProjects/perch-2/scripts/perch_embeddings_augmented_d3.csv')

dataframe.drop('mean_freq', axis=1, inplace=True)

augmented_df.drop('mean_freq', axis=1, inplace=True)
augmented_df.drop('gender', axis=1, inplace=True)

def assign_age_group(age, age_groups):
    for group_name, age_range in age_groups.items():
        if age_range[0] <= age < age_range[1]:
            return group_name
    return 'Unknown'  # For any age that doesn't fit the defined groups

# Define age groups
age_groups = {
    'kitten': (0, 0.5),
    'adult': (0.5, 12),
    'senior': (12, 20)
}

# Create a new column for the age group
dataframe['age_group'] = dataframe['target'].apply(assign_age_group, age_groups=age_groups)
augmented_df['age_group'] = augmented_df['target'].apply(assign_age_group, age_groups=age_groups)

print(dataframe['age_group'].value_counts())
print(augmented_df['age_group'].value_counts())
# Out:
# adult     509
# senior    149
# kitten    135
# Name: age_group, dtype: int64
# senior    900
# kitten    820
# adult     758
# Name: age_group, dtype: int64

# %%
# Separate features and labels
X = dataframe.iloc[:, :-4].values  # all columns except the last four

# Encode the 'age_group' column as integers using LabelEncoder
label_encoder = LabelEncoder()
encoded_y = label_encoder.fit_transform(dataframe['age_group'].values)

# Use the encoded labels for splitting and one-hot encoding
y = encoded_y  

# Convert 'cat_id' column to numpy array to be used as groups array for GroupKFold
groups = dataframe['cat_id'].values

# %%
tf.keras.backend.clear_session()

# %% [markdown]
# ## Run Setup

# %%
all_cat_ids = []
all_predicted_age_groups = []
all_actual_age_groups = []
all_gender = []

# Define the StratifiedGroupKFold splitter for 4 fold CV with random shuffling
outer_cv = StratifiedGroupKFold(n_splits=4, shuffle=True, random_state=int(random_seeds[2]))

# unseen test set metrics
unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1 = [], [], [], [], []

cv_training_acc_total = []
cv_training_acc_best = []

outer_fold = 0

# Use the splitter to generate indices for training and testing sets
# Note: GroupShuffleSplit.split returns indices, so we use it to index the arrays
for train_val_idx, test_idx in outer_cv.split(X, y, groups):
    outer_fold += 1
    logger(f"outer_fold {outer_fold}", file=log_file_path)

    # Convert indices back to DataFrame for easy manipulation
    df_train_val = dataframe.iloc[train_val_idx]
    df_test = dataframe.iloc[test_idx]

    ##############################
    # ASSESSING SPLITS BY CAT_ID #
    ##############################
    
    # Get the distribution of groups
    training_validation_group_distribution = df_train_val['cat_id'].value_counts()  
    testing_group_distribution = df_test['cat_id'].value_counts()  
    
    # Log or print the distribution
    logger(f"Train Set Group Distribution:\n{training_validation_group_distribution}", file=log_file_path)
    logger(f"Testing Set Group Distribution:\n{testing_group_distribution}", file=log_file_path)

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val['gender'].value_counts()
    testing_gender_distribution = df_test['gender'].value_counts()
    
    # Log the distribution
    logger(f"Training Set Gender Distribution BEFORE SWAP:\n{training_gender_distribution}", file=log_file_path)
    logger(f"Testing Set Gender Distribution BEFORE SWAP:\n{testing_gender_distribution}", file=log_file_path)

    # Group by 'age_group' and then list unique 'cat_id' within each age group
    unique_cat_ids_per_age_group_train_val = df_train_val.groupby('age_group')['cat_id'].unique()
    unique_cat_ids_per_age_group_test = df_test.groupby('age_group')['cat_id'].unique()
    
    # Log results
    logger(f"Unique Cat IDs per Age Group in Training/Validation Set:\n{unique_cat_ids_per_age_group_train_val}", file=log_file_path)
    logger(f"Unique Cat IDs per Age Group in Testing Set:\n{unique_cat_ids_per_age_group_test}", file=log_file_path)

    # Calculate the count of unique identifiers per age group for training and testing set
    counts_train_val = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_train_val.items()}
    counts_test = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_test.items()}

    # Log the counts of unique identifiers per age group
    logger(f"Count of Unique Cat IDs per Age Group in Training/Validation Set:\n{counts_train_val}", file=log_file_path)
    logger(f"Count of Unique Cat IDs per Age Group in Testing Set:\n{counts_test}", file=log_file_path)

    #######################################################
    # CONTINUE WITH ENSURING VALID AND APPROPRIATE SPLITS #
    #######################################################
    
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    groups_train_val, groups_test = groups[train_val_idx], groups[test_idx]

    # logging identifier splits 
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)

    # check group splits
    check_initial_group_split(groups_train_val, groups_test)

    # Specify the cat_ids that must be in the training/validation set
    specific_cat_ids = ['000A', '046A']
    
    # Perform the swapping operation
    train_val_idx, test_idx = swap_cat_id_instances(dataframe, train_val_idx, test_idx, specific_cat_ids)
    
    # Re-assign the sets based on the updated indices
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    new_groups_train_val, new_groups_test = groups[train_val_idx], groups[test_idx]

    # Find differences for training and test sets
    moved_to_train_val, removed_from_train_val = find_group_differences(groups_train_val, new_groups_train_val)
    moved_to_test, removed_from_test = find_group_differences(groups_test, new_groups_test)
    
    # Display the results
    logger(f"Moved to Training/Validation Set:\n{moved_to_train_val}", file=log_file_path)
    logger(f"Removed from Training/Validation Set:\n{removed_from_train_val}", file=log_file_path)
    logger(f"Moved to Test Set:\n{moved_to_test}", file=log_file_path)
    logger(f"Removed from Test Set\n{removed_from_test}", file=log_file_path)

    # Update X_train_val, X_test, y_train_val, y_test, groups_train_val, groups_test based on updated indices
    X_train_val = X[train_val_idx]
    y_train_val = y[train_val_idx]
    groups_train_val = groups[train_val_idx]
    
    X_test = X[test_idx]
    y_test = y[test_idx]
    groups_test = groups[test_idx]

    # logging identifier splits again after potential swaps
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"AFTER SWAP - Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"AFTER SWAP - Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)
    
    # Verify the lengths are consistent
    logger(f"Length of X_train_val:\n{len(X_train_val)}", file=log_file_path)
    logger(f"Length of y_train_val:\n{len(y_train_val)}", file=log_file_path)
    logger(f"Length of groups_train_val:\n{len(groups_train_val)}", file=log_file_path)

    # Check group splits once more
    check_initial_group_split(groups_train_val, groups_test)

    # Convert the modified indices back to a DataFrame representing the updated df_train_val
    df_train_val_updated = dataframe.iloc[train_val_idx].copy()
    df_test_updated = dataframe.iloc[test_idx].copy()

    ############################
    # LOGGING AGE GROUP SPLITS #
    ############################

    # Get the distribution of age groups of age groups before the update
    training_validation_age_group_distribution = df_train_val['age_group'].value_counts()
    testing_age_group_distribution = df_test['age_group'].value_counts()
    
    # Logthe distribution
    logger(f"Train Age Group Distribution BEFORE SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution BEFORE SWAP:\n{testing_age_group_distribution}", file=log_file_path)

    # Get the distribution of age groups after the update
    training_validation_age_group_distribution = df_train_val_updated['age_group'].value_counts()
    testing_age_group_distribution = df_test_updated['age_group'].value_counts()
    
    # Log the distribution
    logger(f"Train Age Group Distribution AFTER SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution AFTER SWAP:\n{testing_age_group_distribution}", file=log_file_path)
    
    ########################################################
    # TRACKING FINAL CAT_IDs & GENDER AFTER REDISTRIBUTION #
    ########################################################

    # Get the distribution of groups
    training_validation_group_distribution = df_train_val_updated['cat_id'].value_counts()  
    testing_group_distribution = df_test_updated['cat_id'].value_counts()  

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val_updated['gender'].value_counts()
    testing_gender_distribution = df_test_updated['gender'].value_counts()
    
    logger(f"\n Starting training on unseen test set\n", file=log_file_path)

    ######################
    # ADD AUGMENTED DATA #
    ######################

    # Filter out augmented data derived from groups in the training set
    augmented_df_filtered = augmented_df[augmented_df['cat_id'].isin(groups_train_val)]
    
    # Convert augmented_df_filtered to numpy array (excluding target and other columns)
    augmented_array = augmented_df_filtered.drop(columns=['target', 'cat_id', 'age_group']).values
    
    # Concatenate the filtered augmented data with X_train_val
    X_train_val = np.concatenate([X_train_val, augmented_array])

    # Extract target labels from the filtered augmented DataFrame
    y_augmented = augmented_df_filtered['age_group'].values
    
    # Encode the labels using the same LabelEncoder instance
    y_augmented_encoded = label_encoder.transform(y_augmented)
    
    # Concatenate the encoded augmented labels with y_train_val
    y_train_val = np.concatenate([y_train_val, y_augmented_encoded])

    # Calculate the distribution of age groups in y_train_val
    age_group_distribution = Counter(y_train_val)
    print("Age group distribution:", age_group_distribution)

    # EarlyStopping callback: monitor 'loss' instead of 'val_loss' for the test set
    early_stopping = EarlyStopping(
        monitor='loss',  
        min_delta=0.001, 
        patience=30,  
        verbose=1,  
        restore_best_weights=True  
    )

    accuracy_history = AccuracyHistory()

    # One final shuffle to ensure randomness
    outer_shuffle_idx = np.random.permutation(len(X_train_val))
    X_train_val = X_train_val[outer_shuffle_idx]
    y_train_val = y_train_val[outer_shuffle_idx]
    
    # Scale the features
    scaler_full = StandardScaler().fit(X_train_val)
    X_train_full_scaled = scaler_full.transform(X_train_val)
    X_test_scaled = scaler_full.transform(X_test)
    
    # Encode the labels
    y_train_full_encoded = to_categorical(y_train_val)
    y_test_encoded = to_categorical(y_test)

    #######################
    # BUILD & TRAIN MODEL #
    #######################

    optimizers = {
        'Adamax': Adamax(learning_rate=0.00510251984616472)
    }
    
    # Model definition with dynamic number of layers
    model_full = Sequential()
    model_full.add(Dense(480, activation='relu', input_shape=(X_train_full_scaled.shape[1],)))
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.2011047009431978))  
    model_full.add(Dense(256, activation='relu',)) 
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.14956886311951184))  
    model_full.add(Dense(256, activation='relu'))  
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.42291461228250665))  
    model_full.add(Dense(3, activation='softmax'))  
    
    # Use the optimizer from the parameters
    optimizer = optimizers['Adamax']  # optimizer_key from parameters
    
    # Compile the model
    model_full.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    
    # Train the model on the full training set
    history_full = model_full.fit(X_train_full_scaled, y_train_full_encoded, epochs=1500, batch_size=64,
                                  verbose=1, callbacks=[early_stopping, accuracy_history])
    
    # log epochs
    best_epoch_index = np.argmin(history_full.history['loss'])  
    best_training_accuracy = accuracy_history.acc[best_epoch_index]

    # Append training acc to total  
    all_best_training_acc.append(best_training_accuracy)
    total_training_acc.append(accuracy_history.acc)

    # Append training acc just for this CV
    cv_training_acc_total.append(accuracy_history.acc)
    cv_training_acc_best.append(best_training_accuracy)
    
    # Evaluate the model on the held-out test set
    test_loss, test_accuracy = model_full.evaluate(X_test_scaled, y_test_encoded)

    y_test_pred_prob = model_full.predict(X_test_scaled)
    y_test_pred = np.argmax(y_test_pred_prob, axis=1)  
    y_test_true = np.argmax(y_test_encoded, axis=1)    

    ################################
    # LOG MAJORITY VOTE PER CAT_ID #
    ################################

    # Convert numeric predictions back to age group labels
    predicted_age_groups = label_encoder.inverse_transform(y_test_pred)
    actual_labels = label_encoder.inverse_transform(y_test_true)
    
    # Map predictions and actual labels back to cat_ids
    test_results = pd.DataFrame({
        'cat_id': df_test_updated['cat_id'],
        'predicted_age_group': predicted_age_groups,
        'actual_age_group': actual_labels
    })
    
    # Group by cat_id and aggregate predicted age groups
    majority_votes = test_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
    actual_groups = test_results.groupby('cat_id')['actual_age_group'].first()
    
    # Calculate the accuracy of majority voting
    correct_predictions = (majority_votes == actual_groups).sum()
    total_cats = len(actual_groups)
    majority_vote_accuracy = correct_predictions / total_cats
    
    # Log the accuracy of the majority voting
    logger(f"Majority Vote Accuracy for cat_id for this fold: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

    ####################################################
    # COLLECT PREDICTIONS FOR GENDER & CAT_ID ANALYSIS #
    ####################################################

    # Debugging print statements
    print(f'Before appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Extend lists with current fold results
    all_cat_ids.extend(df_test_updated['cat_id'].tolist())
    all_predicted_age_groups.extend(predicted_age_groups)
    all_actual_age_groups.extend(actual_labels)
    all_gender.extend(df_test_updated['gender'].tolist())

    # Debugging print statements
    print(f'After appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Calculate additional metrics
    test_precision = precision_score(y_test_true, y_test_pred, average='macro')  # Use 'macro' for imbalanced datasets
    test_recall = recall_score(y_test_true, y_test_pred, average='macro')
    test_f1 = f1_score(y_test_true, y_test_pred, average='macro')

    # prepare averages of outer metrics
    unseen_f1.append(test_f1)
    unseen_losses.append(test_loss)
    unseen_accuracies.append(test_accuracy)
    unseen_precisions.append(test_precision)
    unseen_recalls.append(test_recall)

    # Print final test results
    logger(f"Final Test Results - Loss: {test_loss}, Accuracy: {test_accuracy}, Precision: {test_precision}, Recall: {test_recall}, F1 Score: {test_f1}", file=log_file_path)

    # Generate the confusion matrix
    cm = confusion_matrix(y_test, y_test_pred)
    logger(f"Confusion Matrix:\n {cm}", file=log_file_path)

# Calculate the overall average metrics
unseen_set_avg_f1 = np.mean(unseen_f1)
unseen_set_avg_loss = np.mean(unseen_losses)
unseen_set_avg_acc = np.mean(unseen_accuracies)
unseen_set_avg_precision = np.mean(unseen_precisions)
unseen_set_avg_recall = np.mean(unseen_recalls)

logger(f"\nFinal Average F1-Score across all UNSEEN TEST sets: {unseen_set_avg_f1}", file=log_file_path)
logger(f"\nFinal Average Loss across all UNSEEN TEST sets: {unseen_set_avg_loss}", file=log_file_path)
logger(f"\nFinal Average Accuracy across all UNSEEN TEST sets: {unseen_set_avg_acc}", file=log_file_path)
logger(f"\nFinal Average Precision across all UNSEEN TEST sets: {unseen_set_avg_precision}", file=log_file_path)
logger(f"\nFinal Average Recall across all UNSEEN TEST sets: {unseen_set_avg_recall}\n", file=log_file_path)

# Append averages to total lists
average_fold_f1.append(unseen_set_avg_f1)
average_fold_losses.append(unseen_set_avg_loss)
average_fold_accuracies.append(unseen_set_avg_acc)
average_fold_precisions.append(unseen_set_avg_precision)
average_fold_recalls.append(unseen_set_avg_recall)

# Append all to total lists
all_f1.append(unseen_f1)
all_losses.append(unseen_losses)
all_accuracies.append(unseen_accuracies)
all_precisions.append(unseen_precisions)
all_recalls.append(unseen_recalls)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# outer_fold 1
# Train Set Group Distribution:
# 046A    45
# 000A    39
# 103A    33
# 002B    30
# 047A    22
# 000B    19
# 057A    17
# 074A    16
# 097A    15
# 029A    15
# 002A    13
# 106A    13
# 051A    12
# 101A    12
# 116A    12
# 055A    12
# 111A    12
# 067A    11
# 063A    11
# 040A    10
# 025A    10
# 051B     9
# 016A     9
# 065A     9
# 072A     9
# 001A     9
# 005A     9
# 033A     9
# 022A     9
# 071A     9
# 013B     8
# 068A     8
# 015A     7
# 036A     7
# 031A     7
# 117A     7
# 027A     7
# 095A     7
# 007A     6
# 023A     6
# 044A     5
# 109A     5
# 021A     5
# 070A     5
# 094A     5
# 050A     5
# 108A     5
# 008A     5
# 026A     4
# 009A     4
# 025C     4
# 045A     4
# 104A     4
# 003A     4
# 058A     3
# 060A     3
# 012A     3
# 053A     3
# 006A     3
# 056A     3
# 113A     3
# 034A     3
# 035A     2
# 032A     2
# 025B     2
# 087A     2
# 038A     2
# 037A     2
# 061A     2
# 054A     2
# 004A     1
# 100A     1
# 110A     1
# 115A     1
# 088A     1
# 076A     1
# 048A     1
# 066A     1
# 096A     1
# 091A     1
# 026C     1
# 041A     1
# 049A     1
# 073A     1
# 024A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 020A    20
# 019A    17
# 097B    14
# 028A    11
# 042A    11
# 014B    10
# 059A    10
# 039A     6
# 099A     6
# 075A     5
# 023B     4
# 010A     3
# 105A     3
# 014A     3
# 062A     3
# 093A     2
# 018A     2
# 069A     2
# 052A     2
# 011A     2
# 102A     2
# 043A     1
# 064A     1
# 092A     1
# 019B     1
# 090A     1
# 026B     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    235
# X    208
# F    206
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    68
# M    51
# F    25
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [006A, 000A, 033A, 015A, 001A, 103A, 071A, 074...
# kitten    [044A, 111A, 040A, 046A, 047A, 109A, 050A, 049...
# senior    [097A, 057A, 106A, 104A, 055A, 113A, 116A, 051...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [097B, 028A, 019A, 020A, 062A, 039A, 099A, 014...
# kitten                                   [014B, 042A, 043A]
# senior                             [093A, 059A, 011A, 090A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 54, 'kitten': 13, 'senior': 18}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 20, 'kitten': 3, 'senior': 4}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '004A' '005A' '006A' '007A'
#  '008A' '009A' '012A' '013B' '015A' '016A' '021A' '022A' '023A' '024A'
#  '025A' '025B' '025C' '026A' '026C' '027A' '029A' '031A' '032A' '033A'
#  '034A' '035A' '036A' '037A' '038A' '040A' '041A' '044A' '045A' '046A'
#  '047A' '048A' '049A' '050A' '051A' '051B' '053A' '054A' '055A' '056A'
#  '057A' '058A' '060A' '061A' '063A' '065A' '066A' '067A' '068A' '070A'
#  '071A' '072A' '073A' '074A' '076A' '087A' '088A' '091A' '094A' '095A'
#  '096A' '097A' '100A' '101A' '103A' '104A' '106A' '108A' '109A' '110A'
#  '111A' '113A' '115A' '116A' '117A']
# Unique Test Group IDs:
# ['010A' '011A' '014A' '014B' '018A' '019A' '019B' '020A' '023B' '026B'
#  '028A' '039A' '042A' '043A' '052A' '059A' '062A' '064A' '069A' '075A'
#  '090A' '092A' '093A' '097B' '099A' '102A' '105A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '004A' '005A' '006A' '007A'
#  '008A' '009A' '012A' '013B' '015A' '016A' '021A' '022A' '023A' '024A'
#  '025A' '025B' '025C' '026A' '026C' '027A' '029A' '031A' '032A' '033A'
#  '034A' '035A' '036A' '037A' '038A' '040A' '041A' '044A' '045A' '046A'
#  '047A' '048A' '049A' '050A' '051A' '051B' '053A' '054A' '055A' '056A'
#  '057A' '058A' '060A' '061A' '063A' '065A' '066A' '067A' '068A' '070A'
#  '071A' '072A' '073A' '074A' '076A' '087A' '088A' '091A' '094A' '095A'
#  '096A' '097A' '100A' '101A' '103A' '104A' '106A' '108A' '109A' '110A'
#  '111A' '113A' '115A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['010A' '011A' '014A' '014B' '018A' '019A' '019B' '020A' '023B' '026B'
#  '028A' '039A' '042A' '043A' '052A' '059A' '062A' '064A' '069A' '075A'
#  '090A' '092A' '093A' '097B' '099A' '102A' '105A']
# Length of X_train_val:
# 649
# Length of y_train_val:
# 649
# Length of groups_train_val:
# 649
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     402
# senior    134
# kitten    113
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     107
# kitten     22
# senior     15
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     402
# senior    134
# kitten    113
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     107
# kitten     22
# senior     15
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 1005, 2: 922, 1: 817})
# Epoch 1/1500
# 43/43 [==============================] - 1s 6ms/step - loss: 0.4657 - accuracy: 0.8324
# Epoch 2/1500
# 43/43 [==============================] - 0s 12ms/step - loss: 0.1230 - accuracy: 0.9544
# Epoch 3/1500
# 43/43 [==============================] - 0s 8ms/step - loss: 0.0579 - accuracy: 0.9770
# Epoch 4/1500
# 43/43 [==============================] - 0s 6ms/step - loss: 0.0296 - accuracy: 0.9909
# Epoch 5/1500
# 43/43 [==============================] - 0s 6ms/step - loss: 0.0228 - accuracy: 0.9913
# Epoch 6/1500
# 43/43 [==============================] - 0s 6ms/step - loss: 0.0136 - accuracy: 0.9967
# Epoch 7/1500
# 43/43 [==============================] - 0s 6ms/step - loss: 0.0136 - accuracy: 0.9956
# Epoch 8/1500
# 43/43 [==============================] - 0s 7ms/step - loss: 0.0085 - accuracy: 0.9982
# Epoch 9/1500
# 43/43 [==============================] - 0s 6ms/step - loss: 0.0081 - accuracy: 0.9974
# Epoch 10/1500
# 43/43 [==============================] - 0s 6ms/step - loss: 0.0109 - accuracy: 0.9967
# Epoch 11/1500
# 43/43 [==============================] - 0s 6ms/step - loss: 0.0107 - accuracy: 0.9964
# Epoch 12/1500
# 43/43 [==============================] - 0s 6ms/step - loss: 0.0055 - accuracy: 0.9978
# Epoch 13/1500
# 43/43 [==============================] - 0s 6ms/step - loss: 0.0052 - accuracy: 0.9978
# Epoch 14/1500
# 43/43 [==============================] - 0s 6ms/step - loss: 0.0047 - accuracy: 0.9985
# Epoch 15/1500
# 43/43 [==============================] - 0s 6ms/step - loss: 0.0032 - accuracy: 0.9993
# Epoch 16/1500
# 43/43 [==============================] - 0s 6ms/step - loss: 0.0079 - accuracy: 0.9971
# Epoch 17/1500
# 43/43 [==============================] - 0s 6ms/step - loss: 0.0081 - accuracy: 0.9974
# Epoch 18/1500
# 43/43 [==============================] - 0s 6ms/step - loss: 0.0113 - accuracy: 0.9960
# Epoch 19/1500
# 43/43 [==============================] - 0s 6ms/step - loss: 0.0055 - accuracy: 0.9982
# Epoch 20/1500
# 43/43 [==============================] - 0s 6ms/step - loss: 0.0082 - accuracy: 0.9974
# Epoch 21/1500
# 43/43 [==============================] - 0s 6ms/step - loss: 0.0083 - accuracy: 0.9971
# Epoch 22/1500
# 43/43 [==============================] - 0s 6ms/step - loss: 0.0048 - accuracy: 0.9985
# Epoch 23/1500
# 43/43 [==============================] - 0s 6ms/step - loss: 0.0019 - accuracy: 0.9996
# Epoch 24/1500
# 43/43 [==============================] - 0s 6ms/step - loss: 0.0036 - accuracy: 0.9996
# Epoch 25/1500
# 43/43 [==============================] - 0s 6ms/step - loss: 0.0051 - accuracy: 0.9982
# Epoch 26/1500
# 43/43 [==============================] - 0s 6ms/step - loss: 0.0101 - accuracy: 0.9974
# Epoch 27/1500
# 43/43 [==============================] - 0s 7ms/step - loss: 0.0068 - accuracy: 0.9971
# Epoch 28/1500
# 43/43 [==============================] - 0s 6ms/step - loss: 0.0035 - accuracy: 0.9993
# Epoch 29/1500
# 43/43 [==============================] - 0s 6ms/step - loss: 0.0058 - accuracy: 0.9982
# Epoch 30/1500
# 43/43 [==============================] - 0s 6ms/step - loss: 0.0078 - accuracy: 0.9964
# Epoch 31/1500
# 43/43 [==============================] - 0s 6ms/step - loss: 0.0076 - accuracy: 0.9971
# Epoch 32/1500
# 43/43 [==============================] - 0s 6ms/step - loss: 0.0037 - accuracy: 0.9985
# Epoch 33/1500
# 43/43 [==============================] - 0s 6ms/step - loss: 0.0059 - accuracy: 0.9985
# Epoch 34/1500
# 43/43 [==============================] - 0s 6ms/step - loss: 0.0050 - accuracy: 0.9974
# Epoch 35/1500
# 43/43 [==============================] - 0s 7ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 36/1500
# 43/43 [==============================] - 0s 6ms/step - loss: 0.0014 - accuracy: 0.9996
# Epoch 37/1500
# 43/43 [==============================] - 0s 6ms/step - loss: 0.0028 - accuracy: 0.9989
# Epoch 38/1500
# 43/43 [==============================] - 0s 6ms/step - loss: 4.4390e-04 - accuracy: 1.0000
# Epoch 39/1500
# 43/43 [==============================] - 0s 6ms/step - loss: 0.0029 - accuracy: 0.9993
# Epoch 40/1500
# 43/43 [==============================] - 0s 6ms/step - loss: 0.0034 - accuracy: 0.9985
# Epoch 41/1500
# 43/43 [==============================] - 0s 6ms/step - loss: 0.0042 - accuracy: 0.9989
# Epoch 42/1500
# 43/43 [==============================] - 0s 6ms/step - loss: 0.0089 - accuracy: 0.9974
# Epoch 43/1500
# 43/43 [==============================] - 0s 6ms/step - loss: 0.0080 - accuracy: 0.9971
# Epoch 44/1500
# 43/43 [==============================] - 0s 6ms/step - loss: 0.0059 - accuracy: 0.9985
# Epoch 45/1500
# 43/43 [==============================] - 0s 6ms/step - loss: 0.0079 - accuracy: 0.9974
# Epoch 46/1500
# 43/43 [==============================] - 0s 6ms/step - loss: 0.0042 - accuracy: 0.9982
# Epoch 47/1500
# 43/43 [==============================] - 0s 6ms/step - loss: 0.0037 - accuracy: 0.9985
# Epoch 48/1500
# 43/43 [==============================] - 0s 6ms/step - loss: 0.0062 - accuracy: 0.9974
# Epoch 49/1500
# 43/43 [==============================] - 0s 6ms/step - loss: 0.0072 - accuracy: 0.9978
# Epoch 50/1500
# 43/43 [==============================] - 0s 7ms/step - loss: 0.0090 - accuracy: 0.9967
# Epoch 51/1500
# 43/43 [==============================] - 0s 7ms/step - loss: 0.0037 - accuracy: 0.9982
# Epoch 52/1500
# 43/43 [==============================] - 0s 7ms/step - loss: 0.0198 - accuracy: 0.9945
# Epoch 53/1500
# 43/43 [==============================] - 0s 6ms/step - loss: 0.0082 - accuracy: 0.9967
# Epoch 54/1500
# 43/43 [==============================] - 0s 6ms/step - loss: 0.0102 - accuracy: 0.9971
# Epoch 55/1500
# 43/43 [==============================] - 0s 6ms/step - loss: 0.0059 - accuracy: 0.9996
# Epoch 56/1500
# 43/43 [==============================] - 0s 6ms/step - loss: 0.0068 - accuracy: 0.9982
# Epoch 57/1500
# 43/43 [==============================] - 0s 6ms/step - loss: 0.0019 - accuracy: 0.9993
# Epoch 58/1500
# 43/43 [==============================] - 0s 6ms/step - loss: 0.0038 - accuracy: 0.9993
# Epoch 59/1500
# 43/43 [==============================] - 0s 6ms/step - loss: 0.0032 - accuracy: 0.9985
# Epoch 60/1500
# 43/43 [==============================] - 0s 6ms/step - loss: 0.0037 - accuracy: 0.9996
# Epoch 61/1500
# 43/43 [==============================] - 0s 6ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 62/1500
# 43/43 [==============================] - 0s 6ms/step - loss: 6.7206e-04 - accuracy: 0.9996
# Epoch 63/1500
# 43/43 [==============================] - 0s 6ms/step - loss: 0.0017 - accuracy: 0.9993
# Epoch 64/1500
# 43/43 [==============================] - 0s 6ms/step - loss: 4.6469e-04 - accuracy: 1.0000
# Epoch 65/1500
# 43/43 [==============================] - 0s 6ms/step - loss: 0.0014 - accuracy: 0.9996
# Epoch 66/1500
# 43/43 [==============================] - 0s 6ms/step - loss: 0.0011 - accuracy: 0.9996
# Epoch 67/1500
# 43/43 [==============================] - 0s 6ms/step - loss: 2.8195e-04 - accuracy: 1.0000
# Epoch 68/1500
# 35/43 [=======================>......] - ETA: 0s - loss: 5.0927e-04 - accuracy: 1.0000Restoring model weights from the end of the best epoch: 38.
# 43/43 [==============================] - 0s 7ms/step - loss: 4.4830e-04 - accuracy: 1.0000
# Epoch 68: early stopping
# 5/5 [==============================] - 0s 2ms/step - loss: 1.4428 - accuracy: 0.7500
# 5/5 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.70 (19/27)
# Before appending - Cat IDs: 0, Predictions: 0, Actuals: 0, Gender: 0
# After appending - Cat IDs: 144, Predictions: 144, Actuals: 144, Gender: 144
# Final Test Results - Loss: 1.442808747291565, Accuracy: 0.75, Precision: 0.6172461797461798, Recall: 0.5282733880864722, F1 Score: 0.551881138574687
# Confusion Matrix:
#  [[95  3  9]
#  [12  8  2]
#  [10  0  5]]
# outer_fold 2
# Train Set Group Distribution:
# 046A    45
# 000A    39
# 103A    33
# 002B    30
# 047A    22
# 020A    20
# 000B    19
# 019A    17
# 057A    17
# 097A    15
# 029A    15
# 097B    14
# 002A    13
# 106A    13
# 116A    12
# 111A    12
# 051A    12
# 055A    12
# 028A    11
# 042A    11
# 025A    10
# 014B    10
# 059A    10
# 065A     9
# 072A     9
# 071A     9
# 033A     9
# 068A     8
# 015A     7
# 031A     7
# 036A     7
# 117A     7
# 007A     6
# 039A     6
# 099A     6
# 023A     6
# 075A     5
# 094A     5
# 008A     5
# 050A     5
# 070A     5
# 003A     4
# 023B     4
# 025C     4
# 105A     3
# 053A     3
# 113A     3
# 014A     3
# 062A     3
# 056A     3
# 034A     3
# 012A     3
# 060A     3
# 010A     3
# 035A     2
# 011A     2
# 061A     2
# 052A     2
# 102A     2
# 054A     2
# 093A     2
# 018A     2
# 038A     2
# 069A     2
# 032A     2
# 064A     1
# 088A     1
# 090A     1
# 100A     1
# 110A     1
# 115A     1
# 019B     1
# 004A     1
# 049A     1
# 048A     1
# 076A     1
# 043A     1
# 026C     1
# 073A     1
# 041A     1
# 092A     1
# 026B     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 074A    16
# 101A    12
# 067A    11
# 063A    11
# 040A    10
# 001A     9
# 022A     9
# 005A     9
# 016A     9
# 051B     9
# 013B     8
# 095A     7
# 027A     7
# 109A     5
# 021A     5
# 108A     5
# 044A     5
# 045A     4
# 009A     4
# 104A     4
# 026A     4
# 058A     3
# 006A     3
# 087A     2
# 037A     2
# 025B     2
# 096A     1
# 091A     1
# 066A     1
# 024A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    235
# M    196
# F    183
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# M    90
# F    48
# X    41
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [000A, 033A, 015A, 103A, 071A, 097B, 028A, 019...
# kitten    [014B, 111A, 046A, 047A, 042A, 050A, 043A, 049...
# senior    [093A, 097A, 057A, 106A, 055A, 059A, 113A, 116...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [006A, 001A, 074A, 067A, 101A, 022A, 095A, 005...
# kitten                             [044A, 040A, 109A, 045A]
# senior                 [104A, 051B, 058A, 016A, 108A, 024A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 54, 'kitten': 12, 'senior': 16}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 20, 'kitten': 4, 'senior': 6}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '002A' '002B' '003A' '004A' '007A' '008A' '010A' '011A'
#  '012A' '014A' '014B' '015A' '018A' '019A' '019B' '020A' '023A' '023B'
#  '025A' '025C' '026B' '026C' '028A' '029A' '031A' '032A' '033A' '034A'
#  '035A' '036A' '038A' '039A' '041A' '042A' '043A' '046A' '047A' '048A'
#  '049A' '050A' '051A' '052A' '053A' '054A' '055A' '056A' '057A' '059A'
#  '060A' '061A' '062A' '064A' '065A' '068A' '069A' '070A' '071A' '072A'
#  '073A' '075A' '076A' '088A' '090A' '092A' '093A' '094A' '097A' '097B'
#  '099A' '100A' '102A' '103A' '105A' '106A' '110A' '111A' '113A' '115A'
#  '116A' '117A']
# Unique Test Group IDs:
# ['001A' '005A' '006A' '009A' '013B' '016A' '021A' '022A' '024A' '025B'
#  '026A' '027A' '037A' '040A' '044A' '045A' '051B' '058A' '063A' '066A'
#  '067A' '074A' '087A' '091A' '095A' '096A' '101A' '104A' '108A' '109A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '002A' '002B' '003A' '004A' '007A' '008A' '010A' '011A'
#  '012A' '014A' '014B' '015A' '018A' '019A' '019B' '020A' '023A' '023B'
#  '025A' '025C' '026B' '026C' '028A' '029A' '031A' '032A' '033A' '034A'
#  '035A' '036A' '038A' '039A' '041A' '042A' '043A' '046A' '047A' '048A'
#  '049A' '050A' '051A' '052A' '053A' '054A' '055A' '056A' '057A' '059A'
#  '060A' '061A' '062A' '064A' '065A' '068A' '069A' '070A' '071A' '072A'
#  '073A' '075A' '076A' '088A' '090A' '092A' '093A' '094A' '097A' '097B'
#  '099A' '100A' '102A' '103A' '105A' '106A' '110A' '111A' '113A' '115A'
#  '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['001A' '005A' '006A' '009A' '013B' '016A' '021A' '022A' '024A' '025B'
#  '026A' '027A' '037A' '040A' '044A' '045A' '051B' '058A' '063A' '066A'
#  '067A' '074A' '087A' '091A' '095A' '096A' '101A' '104A' '108A' '109A']
# Length of X_train_val:
# 614
# Length of y_train_val:
# 614
# Length of groups_train_val:
# 614
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     385
# senior    118
# kitten    111
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     124
# senior     31
# kitten     24
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     385
# senior    118
# kitten    111
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     124
# senior     31
# kitten     24
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 950, 2: 846, 1: 779})
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Epoch 1/1500
# 41/41 [==============================] - 1s 5ms/step - loss: 0.3852 - accuracy: 0.8629
# Epoch 2/1500
# 41/41 [==============================] - 0s 5ms/step - loss: 0.0883 - accuracy: 0.9682
# Epoch 3/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0369 - accuracy: 0.9872
# Epoch 4/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0181 - accuracy: 0.9961
# Epoch 5/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0205 - accuracy: 0.9938
# Epoch 6/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0127 - accuracy: 0.9953
# Epoch 7/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0134 - accuracy: 0.9973
# Epoch 8/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0072 - accuracy: 0.9973
# Epoch 9/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0088 - accuracy: 0.9973
# Epoch 10/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0054 - accuracy: 0.9984
# Epoch 11/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0073 - accuracy: 0.9988
# Epoch 12/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0102 - accuracy: 0.9969
# Epoch 13/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0045 - accuracy: 0.9992
# Epoch 14/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0033 - accuracy: 0.9988
# Epoch 15/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0032 - accuracy: 0.9988
# Epoch 16/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0035 - accuracy: 0.9988
# Epoch 17/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0024 - accuracy: 0.9996
# Epoch 18/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0042 - accuracy: 0.9981
# Epoch 19/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0046 - accuracy: 0.9981
# Epoch 20/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0039 - accuracy: 0.9992
# Epoch 21/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0079 - accuracy: 0.9984
# Epoch 22/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0189 - accuracy: 0.9946
# Epoch 23/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0072 - accuracy: 0.9973
# Epoch 24/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0058 - accuracy: 0.9977
# Epoch 25/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0077 - accuracy: 0.9977
# Epoch 26/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0055 - accuracy: 0.9981
# Epoch 27/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0051 - accuracy: 0.9984
# Epoch 28/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0062 - accuracy: 0.9988
# Epoch 29/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0016 - accuracy: 0.9996
# Epoch 30/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 31/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0033 - accuracy: 0.9984
# Epoch 32/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0040 - accuracy: 0.9981
# Epoch 33/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0029 - accuracy: 0.9992
# Epoch 34/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0019 - accuracy: 0.9996
# Epoch 35/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0012 - accuracy: 0.9996
# Epoch 36/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0017 - accuracy: 0.9992
# Epoch 37/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0025 - accuracy: 0.9988
# Epoch 38/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0055 - accuracy: 0.9984
# Epoch 39/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0026 - accuracy: 0.9988
# Epoch 40/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0017 - accuracy: 0.9996
# Epoch 41/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0039 - accuracy: 0.9984
# Epoch 42/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0113 - accuracy: 0.9973
# Epoch 43/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0040 - accuracy: 0.9984
# Epoch 44/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0055 - accuracy: 0.9981
# Epoch 45/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0107 - accuracy: 0.9981
# Epoch 46/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0113 - accuracy: 0.9953
# Epoch 47/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0044 - accuracy: 0.9984
# Epoch 48/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0025 - accuracy: 0.9988
# Epoch 49/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0018 - accuracy: 0.9996
# Epoch 50/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0024 - accuracy: 0.9996
# Epoch 51/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0022 - accuracy: 0.9996
# Epoch 52/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0020 - accuracy: 0.9996
# Epoch 53/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0054 - accuracy: 0.9988
# Epoch 54/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0049 - accuracy: 0.9977
# Epoch 55/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0025 - accuracy: 0.9984
# Epoch 56/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0027 - accuracy: 0.9988
# Epoch 57/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 58/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0035 - accuracy: 0.9992
# Epoch 59/1500
# 37/41 [==========================>...] - ETA: 0s - loss: 0.0016 - accuracy: 0.9996Restoring model weights from the end of the best epoch: 29.
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0018 - accuracy: 0.9996
# Epoch 59: early stopping
# 6/6 [==============================] - 0s 2ms/step - loss: 2.4230 - accuracy: 0.6816
# 6/6 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.73 (22/30)
# Before appending - Cat IDs: 144, Predictions: 144, Actuals: 144, Gender: 144
# After appending - Cat IDs: 323, Predictions: 323, Actuals: 323, Gender: 323
# Final Test Results - Loss: 2.422973394393921, Accuracy: 0.6815642714500427, Precision: 0.6051229403008059, Recall: 0.6039426523297492, F1 Score: 0.6039447887472204
# Confusion Matrix:
#  [[94  7 23]
#  [ 8 16  0]
#  [19  0 12]]
# outer_fold 3
# Train Set Group Distribution:
# 046A    45
# 103A    33
# 002B    30
# 020A    20
# 057A    17
# 019A    17
# 074A    16
# 029A    15
# 097B    14
# 055A    12
# 051A    12
# 101A    12
# 042A    11
# 063A    11
# 067A    11
# 028A    11
# 040A    10
# 014B    10
# 025A    10
# 059A    10
# 071A     9
# 022A     9
# 001A     9
# 005A     9
# 016A     9
# 051B     9
# 068A     8
# 013B     8
# 117A     7
# 031A     7
# 036A     7
# 027A     7
# 095A     7
# 023A     6
# 039A     6
# 099A     6
# 044A     5
# 075A     5
# 094A     5
# 050A     5
# 109A     5
# 108A     5
# 021A     5
# 003A     4
# 026A     4
# 045A     4
# 023B     4
# 104A     4
# 009A     4
# 060A     3
# 058A     3
# 010A     3
# 006A     3
# 062A     3
# 014A     3
# 105A     3
# 093A     2
# 025B     2
# 037A     2
# 102A     2
# 061A     2
# 011A     2
# 052A     2
# 018A     2
# 087A     2
# 069A     2
# 032A     2
# 054A     2
# 092A     1
# 115A     1
# 024A     1
# 090A     1
# 096A     1
# 110A     1
# 076A     1
# 064A     1
# 043A     1
# 041A     1
# 019B     1
# 004A     1
# 066A     1
# 091A     1
# 026B     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 000A    39
# 047A    22
# 000B    19
# 097A    15
# 106A    13
# 002A    13
# 111A    12
# 116A    12
# 072A     9
# 065A     9
# 033A     9
# 015A     7
# 007A     6
# 008A     5
# 070A     5
# 025C     4
# 053A     3
# 012A     3
# 113A     3
# 056A     3
# 034A     3
# 038A     2
# 035A     2
# 073A     1
# 049A     1
# 026C     1
# 048A     1
# 088A     1
# 100A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    237
# X    207
# F    125
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# F    106
# X     69
# M     49
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [006A, 001A, 103A, 071A, 097B, 028A, 019A, 074...
# kitten    [044A, 014B, 040A, 046A, 042A, 109A, 050A, 043...
# senior    [093A, 057A, 104A, 055A, 059A, 051B, 054A, 117...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [000A, 033A, 015A, 034A, 072A, 065A, 002A, 038...
# kitten                             [111A, 047A, 049A, 048A]
# senior                       [097A, 106A, 113A, 116A, 056A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 54, 'kitten': 12, 'senior': 17}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 20, 'kitten': 4, 'senior': 5}
# Unique Training/Validation Group IDs:
# ['001A' '002B' '003A' '004A' '005A' '006A' '009A' '010A' '011A' '013B'
#  '014A' '014B' '016A' '018A' '019A' '019B' '020A' '021A' '022A' '023A'
#  '023B' '024A' '025A' '025B' '026A' '026B' '027A' '028A' '029A' '031A'
#  '032A' '036A' '037A' '039A' '040A' '041A' '042A' '043A' '044A' '045A'
#  '046A' '050A' '051A' '051B' '052A' '054A' '055A' '057A' '058A' '059A'
#  '060A' '061A' '062A' '063A' '064A' '066A' '067A' '068A' '069A' '071A'
#  '074A' '075A' '076A' '087A' '090A' '091A' '092A' '093A' '094A' '095A'
#  '096A' '097B' '099A' '101A' '102A' '103A' '104A' '105A' '108A' '109A'
#  '110A' '115A' '117A']
# Unique Test Group IDs:
# ['000A' '000B' '002A' '007A' '008A' '012A' '015A' '025C' '026C' '033A'
#  '034A' '035A' '038A' '047A' '048A' '049A' '053A' '056A' '065A' '070A'
#  '072A' '073A' '088A' '097A' '100A' '106A' '111A' '113A' '116A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'000A'}
# Removed from Training/Validation Set:
# {'076A'}
# Moved to Test Set:
# {'076A'}
# Removed from Test Set
# {'000A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '001A' '002B' '003A' '004A' '005A' '006A' '009A' '010A' '011A'
#  '013B' '014A' '014B' '016A' '018A' '019A' '019B' '020A' '021A' '022A'
#  '023A' '023B' '024A' '025A' '025B' '026A' '026B' '027A' '028A' '029A'
#  '031A' '032A' '036A' '037A' '039A' '040A' '041A' '042A' '043A' '044A'
#  '045A' '046A' '050A' '051A' '051B' '052A' '054A' '055A' '057A' '058A'
#  '059A' '060A' '061A' '062A' '063A' '064A' '066A' '067A' '068A' '069A'
#  '071A' '074A' '075A' '087A' '090A' '091A' '092A' '093A' '094A' '095A'
#  '096A' '097B' '099A' '101A' '102A' '103A' '104A' '105A' '108A' '109A'
#  '110A' '115A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['000B' '002A' '007A' '008A' '012A' '015A' '025C' '026C' '033A' '034A'
#  '035A' '038A' '047A' '048A' '049A' '053A' '056A' '065A' '070A' '072A'
#  '073A' '076A' '088A' '097A' '100A' '106A' '111A' '113A' '116A']
# Length of X_train_val:
# 607
# Length of y_train_val:
# 607
# Length of groups_train_val:
# 607
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     367
# senior    103
# kitten     99
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     142
# senior     46
# kitten     36
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     405
# senior    103
# kitten     99
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     104
# senior     46
# kitten     36
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Age group distribution: Counter({0: 1005, 2: 731, 1: 667})
# Epoch 1/1500
# 38/38 [==============================] - 1s 6ms/step - loss: 0.4739 - accuracy: 0.8398
# Epoch 2/1500
# 38/38 [==============================] - 0s 5ms/step - loss: 0.1164 - accuracy: 0.9542
# Epoch 3/1500
# 38/38 [==============================] - 0s 5ms/step - loss: 0.0535 - accuracy: 0.9792
# Epoch 4/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0180 - accuracy: 0.9950
# Epoch 5/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0193 - accuracy: 0.9933
# Epoch 6/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0137 - accuracy: 0.9967
# Epoch 7/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0130 - accuracy: 0.9954
# Epoch 8/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0099 - accuracy: 0.9975
# Epoch 9/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0083 - accuracy: 0.9967
# Epoch 10/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0079 - accuracy: 0.9975
# Epoch 11/1500
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0059 - accuracy: 0.9988
# Epoch 12/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0048 - accuracy: 0.9988
# Epoch 13/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0023 - accuracy: 0.9996
# Epoch 14/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0023 - accuracy: 0.9996
# Epoch 15/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0018 - accuracy: 0.9996
# Epoch 16/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0055 - accuracy: 0.9983
# Epoch 17/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0031 - accuracy: 0.9988
# Epoch 18/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0058 - accuracy: 0.9979
# Epoch 19/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0043 - accuracy: 0.9983
# Epoch 20/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0049 - accuracy: 0.9983
# Epoch 21/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0034 - accuracy: 0.9988
# Epoch 22/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0026 - accuracy: 0.9992
# Epoch 23/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0030 - accuracy: 0.9992
# Epoch 24/1500
# 38/38 [==============================] - 1s 15ms/step - loss: 0.0040 - accuracy: 0.9983
# Epoch 25/1500
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0048 - accuracy: 0.9988
# Epoch 26/1500
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0201 - accuracy: 0.9938
# Epoch 27/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0076 - accuracy: 0.9979
# Epoch 28/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0151 - accuracy: 0.9958
# Epoch 29/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0096 - accuracy: 0.9967
# Epoch 30/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0043 - accuracy: 0.9996
# Epoch 31/1500
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 32/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0020 - accuracy: 0.9996
# Epoch 33/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0026 - accuracy: 0.9988
# Epoch 34/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 35/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0014 - accuracy: 0.9996
# Epoch 36/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 6.2132e-04 - accuracy: 1.0000
# Epoch 37/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 6.8844e-04 - accuracy: 1.0000
# Epoch 38/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0012 - accuracy: 0.9996
# Epoch 39/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0037 - accuracy: 0.9988
# Epoch 40/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0024 - accuracy: 0.9988
# Epoch 41/1500
# 38/38 [==============================] - 1s 19ms/step - loss: 0.0054 - accuracy: 0.9992
# Epoch 42/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0036 - accuracy: 0.9992
# Epoch 43/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 44/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 45/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 6.2873e-04 - accuracy: 1.0000
# Epoch 46/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0015 - accuracy: 0.9992
# Epoch 47/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0037 - accuracy: 0.9992
# Epoch 48/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0129 - accuracy: 0.9971
# Epoch 49/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0049 - accuracy: 0.9983
# Epoch 50/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0121 - accuracy: 0.9979
# Epoch 51/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0044 - accuracy: 0.9983
# Epoch 52/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0075 - accuracy: 0.9983
# Epoch 53/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0060 - accuracy: 0.9971
# Epoch 54/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0050 - accuracy: 0.9988
# Epoch 55/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0025 - accuracy: 0.9992
# Epoch 56/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 57/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0047 - accuracy: 0.9983
# Epoch 58/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0026 - accuracy: 0.9988
# Epoch 59/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0051 - accuracy: 0.9983
# Epoch 60/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0045 - accuracy: 0.9983
# Epoch 61/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0017 - accuracy: 0.9996
# Epoch 62/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 63/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0015 - accuracy: 0.9996
# Epoch 64/1500
# 37/38 [============================>.] - ETA: 0s - loss: 7.2568e-04 - accuracy: 1.0000Restoring model weights from the end of the best epoch: 34.
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 64: early stopping
# 6/6 [==============================] - 0s 1ms/step - loss: 1.6781 - accuracy: 0.7312
# 6/6 [==============================] - 0s 1ms/step
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Majority Vote Accuracy for cat_id for this fold: 0.76 (22/29)
# Before appending - Cat IDs: 323, Predictions: 323, Actuals: 323, Gender: 323
# After appending - Cat IDs: 509, Predictions: 509, Actuals: 509, Gender: 509
# Final Test Results - Loss: 1.6781033277511597, Accuracy: 0.7311828136444092, Precision: 0.7764196587725999, Recall: 0.637805029109377, F1 Score: 0.6767319043181113
# Confusion Matrix:
#  [[96  1  7]
#  [15 20  1]
#  [25  1 20]]
# outer_fold 4
# Train Set Group Distribution:
# 000A    39
# 047A    22
# 020A    20
# 000B    19
# 019A    17
# 074A    16
# 097A    15
# 097B    14
# 106A    13
# 002A    13
# 111A    12
# 116A    12
# 101A    12
# 067A    11
# 042A    11
# 063A    11
# 028A    11
# 059A    10
# 014B    10
# 040A    10
# 065A     9
# 016A     9
# 051B     9
# 072A     9
# 033A     9
# 022A     9
# 005A     9
# 001A     9
# 013B     8
# 095A     7
# 015A     7
# 027A     7
# 039A     6
# 099A     6
# 007A     6
# 109A     5
# 044A     5
# 008A     5
# 108A     5
# 075A     5
# 021A     5
# 070A     5
# 025C     4
# 104A     4
# 026A     4
# 023B     4
# 045A     4
# 009A     4
# 058A     3
# 006A     3
# 012A     3
# 053A     3
# 010A     3
# 056A     3
# 113A     3
# 034A     3
# 014A     3
# 062A     3
# 105A     3
# 052A     2
# 093A     2
# 025B     2
# 037A     2
# 102A     2
# 011A     2
# 035A     2
# 018A     2
# 038A     2
# 087A     2
# 069A     2
# 019B     1
# 024A     1
# 090A     1
# 100A     1
# 043A     1
# 096A     1
# 073A     1
# 088A     1
# 026C     1
# 064A     1
# 048A     1
# 066A     1
# 049A     1
# 092A     1
# 091A     1
# 026B     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 046A    45
# 103A    33
# 002B    30
# 057A    17
# 029A    15
# 055A    12
# 051A    12
# 025A    10
# 071A     9
# 068A     8
# 036A     7
# 117A     7
# 031A     7
# 023A     6
# 094A     5
# 050A     5
# 003A     4
# 060A     3
# 054A     2
# 032A     2
# 061A     2
# 076A     1
# 041A     1
# 004A     1
# 115A     1
# 110A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    190
# F    179
# X    178
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    98
# M    96
# F    52
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [006A, 000A, 033A, 015A, 001A, 097B, 028A, 019...
# kitten    [044A, 014B, 111A, 040A, 047A, 042A, 109A, 043...
# senior    [093A, 097A, 106A, 104A, 059A, 113A, 116A, 051...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [103A, 071A, 002B, 029A, 023A, 025A, 032A, 076...
# kitten                       [046A, 050A, 041A, 115A, 110A]
# senior           [057A, 055A, 054A, 117A, 051A, 094A, 061A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 60, 'kitten': 11, 'senior': 15}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 14, 'kitten': 5, 'senior': 7}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '005A' '006A' '007A' '008A' '009A' '010A'
#  '011A' '012A' '013B' '014A' '014B' '015A' '016A' '018A' '019A' '019B'
#  '020A' '021A' '022A' '023B' '024A' '025B' '025C' '026A' '026B' '026C'
#  '027A' '028A' '033A' '034A' '035A' '037A' '038A' '039A' '040A' '042A'
#  '043A' '044A' '045A' '047A' '048A' '049A' '051B' '052A' '053A' '056A'
#  '058A' '059A' '062A' '063A' '064A' '065A' '066A' '067A' '069A' '070A'
#  '072A' '073A' '074A' '075A' '087A' '088A' '090A' '091A' '092A' '093A'
#  '095A' '096A' '097A' '097B' '099A' '100A' '101A' '102A' '104A' '105A'
#  '106A' '108A' '109A' '111A' '113A' '116A']
# Unique Test Group IDs:
# ['002B' '003A' '004A' '023A' '025A' '029A' '031A' '032A' '036A' '041A'
#  '046A' '050A' '051A' '054A' '055A' '057A' '060A' '061A' '068A' '071A'
#  '076A' '094A' '103A' '110A' '115A' '117A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'046A'}
# Removed from Training/Validation Set:
# {'047A'}
# Moved to Test Set:
# {'047A'}
# Removed from Test Set
# {'046A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '005A' '006A' '007A' '008A' '009A' '010A'
#  '011A' '012A' '013B' '014A' '014B' '015A' '016A' '018A' '019A' '019B'
#  '020A' '021A' '022A' '023B' '024A' '025B' '025C' '026A' '026B' '026C'
#  '027A' '028A' '033A' '034A' '035A' '037A' '038A' '039A' '040A' '042A'
#  '043A' '044A' '045A' '046A' '048A' '049A' '051B' '052A' '053A' '056A'
#  '058A' '059A' '062A' '063A' '064A' '065A' '066A' '067A' '069A' '070A'
#  '072A' '073A' '074A' '075A' '087A' '088A' '090A' '091A' '092A' '093A'
#  '095A' '096A' '097A' '097B' '099A' '100A' '101A' '102A' '104A' '105A'
#  '106A' '108A' '109A' '111A' '113A' '116A']
# AFTER SWAP - Unique Test Group IDs:
# ['002B' '003A' '004A' '023A' '025A' '029A' '031A' '032A' '036A' '041A'
#  '047A' '050A' '051A' '054A' '055A' '057A' '060A' '061A' '068A' '071A'
#  '076A' '094A' '103A' '110A' '115A' '117A']
# Length of X_train_val:
# 570
# Length of y_train_val:
# 570
# Length of groups_train_val:
# 570
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     373
# senior     92
# kitten     82
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     136
# senior     57
# kitten     53
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     373
# kitten    105
# senior     92
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     136
# senior     57
# kitten     30
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 923, 1: 713, 2: 648})
# Epoch 1/1500
# 36/36 [==============================] - 1s 5ms/step - loss: 0.4528 - accuracy: 0.8433
# Epoch 2/1500
# 36/36 [==============================] - 0s 5ms/step - loss: 0.1056 - accuracy: 0.9606
# Epoch 3/1500
# 36/36 [==============================] - 0s 6ms/step - loss: 0.0529 - accuracy: 0.9816
# Epoch 4/1500
# 36/36 [==============================] - 0s 6ms/step - loss: 0.0275 - accuracy: 0.9908
# Epoch 5/1500
# 36/36 [==============================] - 0s 6ms/step - loss: 0.0174 - accuracy: 0.9939
# Epoch 6/1500
# 36/36 [==============================] - 0s 6ms/step - loss: 0.0110 - accuracy: 0.9969
# Epoch 7/1500
# 36/36 [==============================] - 0s 6ms/step - loss: 0.0104 - accuracy: 0.9965
# Epoch 8/1500
# 36/36 [==============================] - 0s 6ms/step - loss: 0.0100 - accuracy: 0.9956
# Epoch 9/1500
# 36/36 [==============================] - 0s 6ms/step - loss: 0.0118 - accuracy: 0.9969
# Epoch 10/1500
# 36/36 [==============================] - 0s 6ms/step - loss: 0.0064 - accuracy: 0.9978
# Epoch 11/1500
# 36/36 [==============================] - 0s 6ms/step - loss: 0.0079 - accuracy: 0.9987
# Epoch 12/1500
# 36/36 [==============================] - 0s 6ms/step - loss: 0.0038 - accuracy: 0.9987
# Epoch 13/1500
# 36/36 [==============================] - 0s 6ms/step - loss: 0.0037 - accuracy: 0.9996
# Epoch 14/1500
# 36/36 [==============================] - 0s 6ms/step - loss: 0.0038 - accuracy: 0.9987
# Epoch 15/1500
# 36/36 [==============================] - 0s 6ms/step - loss: 0.0024 - accuracy: 0.9996
# Epoch 16/1500
# 36/36 [==============================] - 0s 6ms/step - loss: 0.0045 - accuracy: 0.9987
# Epoch 17/1500
# 36/36 [==============================] - 0s 6ms/step - loss: 0.0043 - accuracy: 0.9991
# Epoch 18/1500
# 36/36 [==============================] - 0s 6ms/step - loss: 0.0044 - accuracy: 0.9991
# Epoch 19/1500
# 36/36 [==============================] - 0s 6ms/step - loss: 0.0062 - accuracy: 0.9978
# Epoch 20/1500
# 36/36 [==============================] - 0s 6ms/step - loss: 0.0041 - accuracy: 0.9987
# Epoch 21/1500
# 36/36 [==============================] - 0s 6ms/step - loss: 0.0018 - accuracy: 0.9996
# Epoch 22/1500
# 36/36 [==============================] - 0s 6ms/step - loss: 0.0042 - accuracy: 0.9987
# Epoch 23/1500
# 36/36 [==============================] - 0s 6ms/step - loss: 0.0020 - accuracy: 0.9996
# Epoch 24/1500
# 36/36 [==============================] - 0s 6ms/step - loss: 0.0018 - accuracy: 0.9996
# Epoch 25/1500
# 36/36 [==============================] - 0s 6ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 26/1500
# 36/36 [==============================] - 0s 6ms/step - loss: 6.7616e-04 - accuracy: 1.0000
# Epoch 27/1500
# 36/36 [==============================] - 0s 6ms/step - loss: 0.0017 - accuracy: 0.9996
# Epoch 28/1500
# 36/36 [==============================] - 0s 6ms/step - loss: 0.0018 - accuracy: 0.9996
# Epoch 29/1500
# 36/36 [==============================] - 0s 6ms/step - loss: 0.0103 - accuracy: 0.9974
# Epoch 30/1500
# 36/36 [==============================] - 0s 6ms/step - loss: 0.0095 - accuracy: 0.9974
# Epoch 31/1500
# 36/36 [==============================] - 0s 6ms/step - loss: 0.0058 - accuracy: 0.9982
# Epoch 32/1500
# 36/36 [==============================] - 0s 6ms/step - loss: 0.0049 - accuracy: 0.9991
# Epoch 33/1500
# 36/36 [==============================] - 0s 6ms/step - loss: 0.0029 - accuracy: 0.9982
# Epoch 34/1500
# 36/36 [==============================] - 0s 6ms/step - loss: 0.0020 - accuracy: 0.9991
# Epoch 35/1500
# 36/36 [==============================] - 0s 6ms/step - loss: 0.0038 - accuracy: 0.9982
# Epoch 36/1500
# 36/36 [==============================] - 0s 6ms/step - loss: 0.0046 - accuracy: 0.9991
# Epoch 37/1500
# 36/36 [==============================] - 0s 6ms/step - loss: 0.0035 - accuracy: 0.9987
# Epoch 38/1500
# 36/36 [==============================] - 0s 6ms/step - loss: 0.0016 - accuracy: 0.9996
# Epoch 39/1500
# 36/36 [==============================] - 0s 6ms/step - loss: 0.0018 - accuracy: 0.9996
# Epoch 40/1500
# 36/36 [==============================] - 0s 6ms/step - loss: 8.9993e-04 - accuracy: 1.0000
# Epoch 41/1500
# 36/36 [==============================] - 0s 6ms/step - loss: 0.0022 - accuracy: 0.9996
# Epoch 42/1500
# 36/36 [==============================] - 0s 6ms/step - loss: 0.0057 - accuracy: 0.9982
# Epoch 43/1500
# 36/36 [==============================] - 0s 6ms/step - loss: 0.0055 - accuracy: 0.9991
# Epoch 44/1500
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0118 - accuracy: 0.9943
# Epoch 45/1500
# 36/36 [==============================] - 0s 6ms/step - loss: 0.0046 - accuracy: 0.9987
# Epoch 46/1500
# 36/36 [==============================] - 0s 6ms/step - loss: 0.0078 - accuracy: 0.9978
# Epoch 47/1500
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0028 - accuracy: 0.9996
# Epoch 48/1500
# 36/36 [==============================] - 0s 7ms/step - loss: 0.0067 - accuracy: 0.9978
# Epoch 49/1500
# 36/36 [==============================] - 0s 6ms/step - loss: 0.0067 - accuracy: 0.9982
# Epoch 50/1500
# 36/36 [==============================] - 0s 6ms/step - loss: 0.0022 - accuracy: 0.9991
# Epoch 51/1500
# 36/36 [==============================] - 0s 6ms/step - loss: 0.0049 - accuracy: 0.9974
# Epoch 52/1500
# 36/36 [==============================] - 0s 6ms/step - loss: 0.0042 - accuracy: 0.9982
# Epoch 53/1500
# 36/36 [==============================] - 0s 6ms/step - loss: 0.0089 - accuracy: 0.9978
# Epoch 54/1500
# 36/36 [==============================] - 0s 6ms/step - loss: 0.0027 - accuracy: 0.9991
# Epoch 55/1500
# 36/36 [==============================] - ETA: 0s - loss: 0.0064 - accuracy: 0.9974Restoring model weights from the end of the best epoch: 25.
# 36/36 [==============================] - 0s 6ms/step - loss: 0.0064 - accuracy: 0.9974
# Epoch 55: early stopping
# 7/7 [==============================] - 0s 2ms/step - loss: 2.8253 - accuracy: 0.6547
# 7/7 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.73 (19/26)
# Before appending - Cat IDs: 509, Predictions: 509, Actuals: 509, Gender: 509
# After appending - Cat IDs: 732, Predictions: 732, Actuals: 732, Gender: 732
# Final Test Results - Loss: 2.825324058532715, Accuracy: 0.6547085046768188, Precision: 0.6304093567251462, Recall: 0.50812693498452, F1 Score: 0.5195126107702795
# Confusion Matrix:
#  [[125   3   8]
#  [ 14  15   1]
#  [ 51   0   6]]
#
# Final Average F1-Score across all UNSEEN TEST sets: 0.5880176106025745
#
# Final Average Loss across all UNSEEN TEST sets: 2.09230238199234
#
# Final Average Accuracy across all UNSEEN TEST sets: 0.7043638974428177
#
# Final Average Precision across all UNSEEN TEST sets: 0.6572995338861829
#
# Final Average Recall across all UNSEEN TEST sets: 0.5695370011275296

# %%
seed_3_folds_values = [unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1]

seed_3_training_acc_values = cv_training_acc_total

# Plotting all fold metrics
seed_3_folds_plot = plot_all_metrics(unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1, "Folds", "Fold Number")

# %% [markdown]
# ## Majority Voting on Total Entries per cat_id

# %%
# Debugging print statements
print(f'Checking - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
# Out:
# Checking - Cat IDs: 732, Predictions: 732, Actuals: 732, Gender: 732

# %%
# Create results df
full_results = pd.DataFrame({
    'cat_id': all_cat_ids,
    'predicted_age_group': all_predicted_age_groups,
    'actual_age_group': all_actual_age_groups,
    'all_gender': all_gender
})

# create a correct majority prediction column
full_results['correct'] = full_results['predicted_age_group'] == full_results['actual_age_group']

# %%
# Group by cat_id and aggregate predicted age groups
majority_votes = full_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first()

# Calculate the accuracy of majority voting
correct_predictions = (majority_votes == actual_groups).sum()
total_cats = len(actual_groups)
majority_vote_accuracy = correct_predictions / total_cats

logger(f"Overall Majority Vote Accuracy for cat_id: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

# store for final evaluation 
all_majority_vote_accuracies.append(majority_vote_accuracy)
# Out:
# Overall Majority Vote Accuracy for cat_id: 0.74 (81/110)

# %%
# Detailed df with predictions, actual labels, and comparison including majority vote
detailed_results = full_results.groupby('cat_id').apply(
    lambda x: pd.Series({
        'Predictions': list(x['predicted_age_group']),
        'Majority Vote': x['predicted_age_group'].mode()[0],
        'Actual Age Group': x['actual_age_group'].iloc[0],
        'Correct Majority Vote': x['predicted_age_group'].mode()[0] == x['actual_age_group'].iloc[0]
    })
).reset_index()

# Convert to DataFrame for better formatting and display
detailed_results = pd.DataFrame(detailed_results)

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 10)
pd.set_option('display.width', 1000)

sorted_detailed_results = detailed_results.sort_values(by='Correct Majority Vote', ascending=False)

# Display the sorted DataFrame
sorted_detailed_results
# Out:
#     cat_id                                        Predictions Majority Vote Actual Age Group  Correct Majority Vote
# 0     000B  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 66    060A                             [adult, adult, kitten]         adult            adult                   True
# 78    072A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 77    071A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 76    070A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 74    068A  [adult, adult, adult, adult, senior, adult, se...         adult            adult                   True
# 73    067A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 71    065A  [senior, adult, adult, adult, adult, adult, ad...         adult            adult                   True
# 69    063A  [adult, adult, adult, adult, kitten, senior, a...         adult            adult                   True
# 68    062A                              [adult, adult, adult]         adult            adult                   True
# 58    052A                                     [adult, adult]         adult            adult                   True
# 80    074A  [adult, adult, senior, adult, adult, adult, ad...         adult            adult                   True
# 54    049A                                           [kitten]        kitten           kitten                   True
# 53    048A                                           [kitten]        kitten           kitten                   True
# 51    045A                    [kitten, kitten, kitten, adult]        kitten           kitten                   True
# 50    044A             [kitten, adult, kitten, adult, kitten]        kitten           kitten                   True
# 49    043A                                           [kitten]        kitten           kitten                   True
# 47    041A                                           [kitten]        kitten           kitten                   True
# 46    040A  [kitten, kitten, kitten, kitten, kitten, kitte...        kitten           kitten                   True
# 45    039A         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 79    073A                                            [adult]         adult            adult                   True
# 81    075A               [adult, kitten, adult, adult, adult]         adult            adult                   True
# 43    037A                                     [adult, adult]         adult            adult                   True
# 95    100A                                            [adult]         adult            adult                   True
# 107   115A                                           [kitten]        kitten           kitten                   True
# 105   111A  [kitten, kitten, kitten, kitten, kitten, kitte...        kitten           kitten                   True
# 104   110A                                           [kitten]        kitten           kitten                   True
# 102   108A             [senior, adult, senior, adult, senior]        senior           senior                   True
# 100   105A                              [adult, adult, adult]         adult            adult                   True
# 98    103A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 97    102A                                    [adult, senior]         adult            adult                   True
# 96    101A  [kitten, adult, adult, adult, senior, adult, a...         adult            adult                   True
# 94    099A         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 82    076A                                     [adult, adult]         adult            adult                   True
# 93    097B  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 92    097A  [adult, senior, adult, senior, senior, senior,...        senior           senior                   True
# 91    096A                                            [adult]         adult            adult                   True
# 90    095A  [adult, adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 89    094A             [adult, adult, senior, senior, senior]        senior           senior                   True
# 87    092A                                            [adult]         adult            adult                   True
# 84    088A                                            [adult]         adult            adult                   True
# 83    087A                                     [adult, adult]         adult            adult                   True
# 44    038A                                    [kitten, adult]         adult            adult                   True
# 55    050A           [kitten, kitten, kitten, kitten, kitten]        kitten           kitten                   True
# 42    036A  [adult, adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 14    013B  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 27    024A                                           [senior]        senior           senior                   True
# 26    023B                       [adult, adult, adult, adult]         adult            adult                   True
# 24    022A  [kitten, adult, kitten, adult, senior, kitten,...         adult            adult                   True
# 23    021A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 22    020A  [adult, adult, senior, adult, adult, adult, ad...         adult            adult                   True
# 20    019A  [adult, adult, adult, kitten, adult, adult, ad...         adult            adult                   True
# 19    018A                                     [adult, adult]         adult            adult                   True
# 18    016A  [senior, adult, adult, senior, senior, senior,...        senior           senior                   True
# 17    015A  [adult, adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 15    014A                              [adult, adult, adult]         adult            adult                   True
# 13    012A                              [adult, adult, adult]         adult            adult                   True
# 29    025B                                    [senior, adult]         adult            adult                   True
# 12    011A                                   [senior, senior]        senior           senior                   True
# 11    010A                              [adult, adult, adult]         adult            adult                   True
# 10    009A                      [adult, adult, senior, adult]         adult            adult                   True
# 9     008A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 8     007A         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 7     006A                              [adult, adult, adult]         adult            adult                   True
# 5     004A                                            [adult]         adult            adult                   True
# 4     003A                       [adult, adult, adult, adult]         adult            adult                   True
# 3     002B  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 2     002A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 28    025A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 25    023A         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 33    026C                                            [adult]         adult            adult                   True
# 39    033A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 34    027A  [adult, adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 35    028A  [senior, adult, adult, senior, adult, adult, a...         adult            adult                   True
# 36    029A  [adult, senior, adult, adult, adult, adult, ad...         adult            adult                   True
# 37    031A  [adult, adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 38    032A                                     [adult, adult]         adult            adult                   True
# 32    026B                                            [adult]         adult            adult                   True
# 40    034A                              [adult, adult, adult]         adult            adult                   True
# 31    026A                       [adult, adult, adult, adult]         adult            adult                   True
# 30    025C                      [adult, senior, adult, adult]         adult            adult                   True
# 48    042A  [adult, adult, adult, kitten, adult, adult, ad...         adult           kitten                  False
# 103   109A                [adult, adult, adult, adult, adult]         adult           kitten                  False
# 56    051A  [adult, senior, adult, adult, adult, adult, ad...         adult           senior                  False
# 101   106A  [adult, adult, adult, senior, adult, senior, a...         adult           senior                  False
# 6     005A  [senior, senior, senior, senior, senior, senio...        senior            adult                  False
# 99    104A                       [adult, adult, adult, adult]         adult           senior                  False
# 106   113A                             [adult, senior, adult]         adult           senior                  False
# 52    047A  [adult, adult, kitten, adult, adult, kitten, k...         adult           kitten                  False
# 108   116A  [senior, senior, adult, senior, adult, adult, ...         adult           senior                  False
# 1     001A  [adult, senior, adult, senior, adult, senior, ...        senior            adult                  False
# 70    064A                                           [kitten]        kitten            adult                  False
# 57    051B  [adult, adult, adult, adult, adult, adult, adu...         adult           senior                  False
# 16    014B  [senior, kitten, adult, adult, kitten, adult, ...         adult           kitten                  False
# 72    066A                                           [senior]        senior            adult                  False
# 67    061A                                     [adult, adult]         adult           senior                  False
# 75    069A                                   [senior, senior]        senior            adult                  False
# 41    035A                                   [senior, senior]        senior            adult                  False
# 65    059A  [adult, senior, senior, adult, adult, adult, a...         adult           senior                  False
# 64    058A                             [adult, adult, senior]         adult           senior                  False
# 63    057A  [adult, adult, adult, adult, adult, adult, adu...         adult           senior                  False
# 21    019B                                           [senior]        senior            adult                  False
# 62    056A                             [adult, senior, adult]         adult           senior                  False
# 61    055A  [adult, senior, adult, adult, adult, senior, a...         adult           senior                  False
# 60    054A                                     [adult, adult]         adult           senior                  False
# 85    090A                                            [adult]         adult           senior                  False
# 86    091A                                           [senior]        senior            adult                  False
# 59    053A                           [senior, senior, senior]        senior            adult                  False
# 88    093A                                     [adult, adult]         adult           senior                  False
# 109   117A  [adult, adult, adult, adult, adult, adult, adult]         adult           senior                  False

# %%
# Create df for majority votes
majority_df = majority_votes.reset_index()
majority_df.columns = ['cat_id', 'Majority_Vote']

# Get actual groups for each cat_id
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first().reset_index()

# Merge majority votes with actual groups
majority_with_actual = pd.merge(majority_df, actual_groups, on='cat_id')

# Add a column to check if the majority vote was correct
majority_with_actual['Majority_Correct'] = majority_with_actual['Majority_Vote'] == majority_with_actual['actual_age_group']

# Count correct majority votes per class
correct_majority_votes_per_class = majority_with_actual.groupby('actual_age_group')['Majority_Correct'].sum()

print("Correct Majority Votes per Class:")
print(correct_majority_votes_per_class)
# Out:
# Correct Majority Votes per Class:
# actual_age_group
# adult     64
# kitten    11
# senior     6
# Name: Majority_Correct, dtype: int64

# %%
# Calculate the total count and the number of correct predictions for each class
class_stats = majority_with_actual.groupby('actual_age_group').agg(
    total_count=('Majority_Correct', 'size'),  # Total number of cases per class
    correct_count=('Majority_Correct', 'sum')  # Sum of correct predictions per class
).reset_index()

# Calculate accuracy for each class
class_stats['accuracy'] = class_stats['correct_count'] / class_stats['total_count'] * 100

# store for final evaluation 
all_majority_vote_details.append(class_stats)

# Log detailed stats
print("Detailed Class Statistics for Majority Votes:")
print(class_stats)
# Out:
# Detailed Class Statistics for Majority Votes:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult           73             64  87.671233
# 1           kitten           15             11  73.333333
# 2           senior           22              6  27.272727

# %%
# Plot for Detailed Class Statistics for Majority Votes
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Accuracy of Majority Votes by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Detailed Class Statistics

# %%
# Calculate the total count and the number of correct predictions for each class
class_stats = full_results.groupby('actual_age_group').agg(
    total_count=('correct', 'size'),
    correct_count=('correct', 'sum')
).reset_index()

# Calculate accuracy for each class
class_stats['accuracy'] = class_stats['correct_count'] / class_stats['total_count'] * 100

# store for final evaluation 
all_class_stats.append(class_stats)

# Log the detailed stats
print("Detailed Class Statistics:")
print(class_stats)
# Out:
# Detailed Class Statistics:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult          471            410  87.048832
# 1           kitten          112             59  52.678571
# 2           senior          149             43  28.859060

# %%
# Plot for Detailed Class Statistics (Overall)
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Overall Accuracy by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Gender Exploration

# %%
# Group by gender and calculate the total count, correct predictions, and accuracy
gender_stats = full_results.groupby('all_gender').agg(
    count=('cat_id', 'size'),  # Total number of cases per gender
    correct=('correct', 'sum')  # Sum of correct predictions per gender
).reset_index()

# Calculate accuracy for each gender
gender_stats['accuracy'] = (gender_stats['correct'] / gender_stats['count'] * 100).round(2)

# Display the DataFrame
print("Accuracy by Gender:")
print(gender_stats)

# store for final evaluation 
all_gender_stats.append(gender_stats)
# Out:
# Accuracy by Gender:
#   all_gender  count  correct  accuracy
# 0          F    192      132     68.75
# 1          M    287      224     78.05
# 2          X    253      156     61.66

# %%
# Plot for Accuracy by Gender
styled_barplot(gender_stats, 'all_gender', 'accuracy', 
               'Accuracy by Gender', 
               'Gender', 'Accuracy (%)')

# %% [markdown]
# ### Log current total CV Stats

# %%
print("Total Majority Vote Accuracy so far:", all_majority_vote_accuracies)
print("Total Class Statistics so far:\n", all_class_stats)
print("Total Gender Accuracy so far:\n", all_gender_stats)
# Out:
# Total Majority Vote Accuracy so far: [0.7454545454545455, 0.7272727272727273, 0.7363636363636363]
# Total Class Statistics so far:
#  [  actual_age_group  total_count  correct_count   accuracy
# 0            adult          474            409  86.286920
# 1           kitten           91             50  54.945055
# 2           senior          149             44  29.530201,   actual_age_group  total_count  correct_count   accuracy
# 0            adult          473            400  84.566596
# 1           kitten           91             52  57.142857
# 2           senior          149             38  25.503356,   actual_age_group  total_count  correct_count   accuracy
# 0            adult          471            410  87.048832
# 1           kitten          112             59  52.678571
# 2           senior          149             43  28.859060]
# Total Gender Accuracy so far:
#  [  all_gender  count  correct  accuracy
# 0          F    196      131     66.84
# 1          M    286      222     77.62
# 2          X    232      150     64.66,   all_gender  count  correct  accuracy
# 0          F    192      126     65.62
# 1          M    289      213     73.70
# 2          X    232      151     65.09,   all_gender  count  correct  accuracy
# 0          F    192      132     68.75
# 1          M    287      224     78.05
# 2          X    253      156     61.66]

# %% [markdown]
# # RANDOM SEED 4

# %%
# Set a fixed random seed for reproducibility
random.seed(int(random_seeds[3])) 
np.random.seed(int(random_seeds[3]))
tf.random.set_seed(int(random_seeds[3]))

# Load datasets
dataframe = pd.read_csv('/Users/astrid/PycharmProjects/perch-2/scripts/perch_embeddings_april_10.csv')
augmented_df = pd.read_csv('/Users/astrid/PycharmProjects/perch-2/scripts/perch_embeddings_augmented_d3.csv')

dataframe.drop('mean_freq', axis=1, inplace=True)

augmented_df.drop('mean_freq', axis=1, inplace=True)
augmented_df.drop('gender', axis=1, inplace=True)

def assign_age_group(age, age_groups):
    for group_name, age_range in age_groups.items():
        if age_range[0] <= age < age_range[1]:
            return group_name
    return 'Unknown'  # For any age that doesn't fit the defined groups

# Define age groups
age_groups = {
    'kitten': (0, 0.5),
    'adult': (0.5, 12),
    'senior': (12, 20)
}

# Create a new column for the age group
dataframe['age_group'] = dataframe['target'].apply(assign_age_group, age_groups=age_groups)
augmented_df['age_group'] = augmented_df['target'].apply(assign_age_group, age_groups=age_groups)

print(dataframe['age_group'].value_counts())
print(augmented_df['age_group'].value_counts())
# Out:
# adult     509
# senior    149
# kitten    135
# Name: age_group, dtype: int64
# senior    900
# kitten    820
# adult     758
# Name: age_group, dtype: int64

# %%
# Separate features and labels
X = dataframe.iloc[:, :-4].values  # all columns except the last four

# Encode the 'age_group' column as integers using LabelEncoder
label_encoder = LabelEncoder()
encoded_y = label_encoder.fit_transform(dataframe['age_group'].values)

# Use the encoded labels for splitting and one-hot encoding
y = encoded_y  

# Convert 'cat_id' column to numpy array to be used as groups array for GroupKFold
groups = dataframe['cat_id'].values

# %%
tf.keras.backend.clear_session()

# %% [markdown]
# ## Run Setup

# %%
all_cat_ids = []
all_predicted_age_groups = []
all_actual_age_groups = []
all_gender = []

# Define the StratifiedGroupKFold splitter for 4 fold CV with random shuffling
outer_cv = StratifiedGroupKFold(n_splits=4, shuffle=True, random_state=int(random_seeds[3]))

# unseen test set metrics
unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1 = [], [], [], [], []

cv_training_acc_total = []
cv_training_acc_best = []

outer_fold = 0

# Use the splitter to generate indices for training and testing sets
# Note: GroupShuffleSplit.split returns indices, so we use it to index the arrays
for train_val_idx, test_idx in outer_cv.split(X, y, groups):
    outer_fold += 1
    logger(f"outer_fold {outer_fold}", file=log_file_path)

    # Convert indices back to DataFrame for easy manipulation
    df_train_val = dataframe.iloc[train_val_idx]
    df_test = dataframe.iloc[test_idx]

    ##############################
    # ASSESSING SPLITS BY CAT_ID #
    ##############################
    
    # Get the distribution of groups
    training_validation_group_distribution = df_train_val['cat_id'].value_counts()  
    testing_group_distribution = df_test['cat_id'].value_counts()  
    
    # Log or print the distribution
    logger(f"Train Set Group Distribution:\n{training_validation_group_distribution}", file=log_file_path)
    logger(f"Testing Set Group Distribution:\n{testing_group_distribution}", file=log_file_path)

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val['gender'].value_counts()
    testing_gender_distribution = df_test['gender'].value_counts()
    
    # Log the distribution
    logger(f"Training Set Gender Distribution BEFORE SWAP:\n{training_gender_distribution}", file=log_file_path)
    logger(f"Testing Set Gender Distribution BEFORE SWAP:\n{testing_gender_distribution}", file=log_file_path)

    # Group by 'age_group' and then list unique 'cat_id' within each age group
    unique_cat_ids_per_age_group_train_val = df_train_val.groupby('age_group')['cat_id'].unique()
    unique_cat_ids_per_age_group_test = df_test.groupby('age_group')['cat_id'].unique()
    
    # Log results
    logger(f"Unique Cat IDs per Age Group in Training/Validation Set:\n{unique_cat_ids_per_age_group_train_val}", file=log_file_path)
    logger(f"Unique Cat IDs per Age Group in Testing Set:\n{unique_cat_ids_per_age_group_test}", file=log_file_path)

    # Calculate the count of unique identifiers per age group for training and testing set
    counts_train_val = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_train_val.items()}
    counts_test = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_test.items()}

    # Log the counts of unique identifiers per age group
    logger(f"Count of Unique Cat IDs per Age Group in Training/Validation Set:\n{counts_train_val}", file=log_file_path)
    logger(f"Count of Unique Cat IDs per Age Group in Testing Set:\n{counts_test}", file=log_file_path)

    #######################################################
    # CONTINUE WITH ENSURING VALID AND APPROPRIATE SPLITS #
    #######################################################
    
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    groups_train_val, groups_test = groups[train_val_idx], groups[test_idx]

    # logging identifier splits 
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)

    # check group splits
    check_initial_group_split(groups_train_val, groups_test)

    # Specify the cat_ids that must be in the training/validation set
    specific_cat_ids = ['000A', '046A']
    
    # Perform the swapping operation
    train_val_idx, test_idx = swap_cat_id_instances(dataframe, train_val_idx, test_idx, specific_cat_ids)
    
    # Re-assign the sets based on the updated indices
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    new_groups_train_val, new_groups_test = groups[train_val_idx], groups[test_idx]

    # Find differences for training and test sets
    moved_to_train_val, removed_from_train_val = find_group_differences(groups_train_val, new_groups_train_val)
    moved_to_test, removed_from_test = find_group_differences(groups_test, new_groups_test)
    
    # Display the results
    logger(f"Moved to Training/Validation Set:\n{moved_to_train_val}", file=log_file_path)
    logger(f"Removed from Training/Validation Set:\n{removed_from_train_val}", file=log_file_path)
    logger(f"Moved to Test Set:\n{moved_to_test}", file=log_file_path)
    logger(f"Removed from Test Set\n{removed_from_test}", file=log_file_path)

    # Update X_train_val, X_test, y_train_val, y_test, groups_train_val, groups_test based on updated indices
    X_train_val = X[train_val_idx]
    y_train_val = y[train_val_idx]
    groups_train_val = groups[train_val_idx]
    
    X_test = X[test_idx]
    y_test = y[test_idx]
    groups_test = groups[test_idx]

    # logging identifier splits again after potential swaps
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"AFTER SWAP - Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"AFTER SWAP - Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)
    
    # Verify the lengths are consistent
    logger(f"Length of X_train_val:\n{len(X_train_val)}", file=log_file_path)
    logger(f"Length of y_train_val:\n{len(y_train_val)}", file=log_file_path)
    logger(f"Length of groups_train_val:\n{len(groups_train_val)}", file=log_file_path)

    # Check group splits once more
    check_initial_group_split(groups_train_val, groups_test)

    # Convert the modified indices back to a DataFrame representing the updated df_train_val
    df_train_val_updated = dataframe.iloc[train_val_idx].copy()
    df_test_updated = dataframe.iloc[test_idx].copy()

    ############################
    # LOGGING AGE GROUP SPLITS #
    ############################

    # Get the distribution of age groups of age groups before the update
    training_validation_age_group_distribution = df_train_val['age_group'].value_counts()
    testing_age_group_distribution = df_test['age_group'].value_counts()
    
    # Logthe distribution
    logger(f"Train Age Group Distribution BEFORE SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution BEFORE SWAP:\n{testing_age_group_distribution}", file=log_file_path)

    # Get the distribution of age groups after the update
    training_validation_age_group_distribution = df_train_val_updated['age_group'].value_counts()
    testing_age_group_distribution = df_test_updated['age_group'].value_counts()
    
    # Log the distribution
    logger(f"Train Age Group Distribution AFTER SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution AFTER SWAP:\n{testing_age_group_distribution}", file=log_file_path)
    
    ########################################################
    # TRACKING FINAL CAT_IDs & GENDER AFTER REDISTRIBUTION #
    ########################################################

    # Get the distribution of groups
    training_validation_group_distribution = df_train_val_updated['cat_id'].value_counts()  
    testing_group_distribution = df_test_updated['cat_id'].value_counts()  

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val_updated['gender'].value_counts()
    testing_gender_distribution = df_test_updated['gender'].value_counts()
    
    logger(f"\n Starting training on unseen test set\n", file=log_file_path)

    ######################
    # ADD AUGMENTED DATA #
    ######################

    # Filter out augmented data derived from groups in the training set
    augmented_df_filtered = augmented_df[augmented_df['cat_id'].isin(groups_train_val)]
    
    # Convert augmented_df_filtered to numpy array (excluding target and other columns)
    augmented_array = augmented_df_filtered.drop(columns=['target', 'cat_id', 'age_group']).values
    
    # Concatenate the filtered augmented data with X_train_val
    X_train_val = np.concatenate([X_train_val, augmented_array])

    # Extract target labels from the filtered augmented DataFrame
    y_augmented = augmented_df_filtered['age_group'].values
    
    # Encode the labels using the same LabelEncoder instance
    y_augmented_encoded = label_encoder.transform(y_augmented)
    
    # Concatenate the encoded augmented labels with y_train_val
    y_train_val = np.concatenate([y_train_val, y_augmented_encoded])

    # Calculate the distribution of age groups in y_train_val
    age_group_distribution = Counter(y_train_val)
    print("Age group distribution:", age_group_distribution)

    # EarlyStopping callback: monitor 'loss' instead of 'val_loss' for the test set
    early_stopping = EarlyStopping(
        monitor='loss',  
        min_delta=0.001, 
        patience=30,  
        verbose=1,  
        restore_best_weights=True  
    )

    accuracy_history = AccuracyHistory()

    # One final shuffle to ensure randomness
    outer_shuffle_idx = np.random.permutation(len(X_train_val))
    X_train_val = X_train_val[outer_shuffle_idx]
    y_train_val = y_train_val[outer_shuffle_idx]
    
    # Scale the features
    scaler_full = StandardScaler().fit(X_train_val)
    X_train_full_scaled = scaler_full.transform(X_train_val)
    X_test_scaled = scaler_full.transform(X_test)
    
    # Encode the labels
    y_train_full_encoded = to_categorical(y_train_val)
    y_test_encoded = to_categorical(y_test)

    #######################
    # BUILD & TRAIN MODEL #
    #######################

    optimizers = {
        'Adamax': Adamax(learning_rate=0.00510251984616472)
    }
    
    # Model definition with dynamic number of layers
    model_full = Sequential()
    model_full.add(Dense(480, activation='relu', input_shape=(X_train_full_scaled.shape[1],)))
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.2011047009431978))  
    model_full.add(Dense(256, activation='relu',)) 
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.14956886311951184))  
    model_full.add(Dense(256, activation='relu'))  
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.42291461228250665))  
    model_full.add(Dense(3, activation='softmax'))  
    
    # Use the optimizer from the parameters
    optimizer = optimizers['Adamax']  # optimizer_key from parameters
    
    # Compile the model
    model_full.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    
    # Train the model on the full training set
    history_full = model_full.fit(X_train_full_scaled, y_train_full_encoded, epochs=1500, batch_size=64,
                                  verbose=1, callbacks=[early_stopping, accuracy_history])
    
    # log epochs
    best_epoch_index = np.argmin(history_full.history['loss'])  
    best_training_accuracy = accuracy_history.acc[best_epoch_index]

    # Append training acc to total  
    all_best_training_acc.append(best_training_accuracy)
    total_training_acc.append(accuracy_history.acc)

    # Append training acc just for this CV
    cv_training_acc_total.append(accuracy_history.acc)
    cv_training_acc_best.append(best_training_accuracy)
    
    # Evaluate the model on the held-out test set
    test_loss, test_accuracy = model_full.evaluate(X_test_scaled, y_test_encoded)

    y_test_pred_prob = model_full.predict(X_test_scaled)
    y_test_pred = np.argmax(y_test_pred_prob, axis=1)  
    y_test_true = np.argmax(y_test_encoded, axis=1)    

    ################################
    # LOG MAJORITY VOTE PER CAT_ID #
    ################################

    # Convert numeric predictions back to age group labels
    predicted_age_groups = label_encoder.inverse_transform(y_test_pred)
    actual_labels = label_encoder.inverse_transform(y_test_true)
    
    # Map predictions and actual labels back to cat_ids
    test_results = pd.DataFrame({
        'cat_id': df_test_updated['cat_id'],
        'predicted_age_group': predicted_age_groups,
        'actual_age_group': actual_labels
    })
    
    # Group by cat_id and aggregate predicted age groups
    majority_votes = test_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
    actual_groups = test_results.groupby('cat_id')['actual_age_group'].first()
    
    # Calculate the accuracy of majority voting
    correct_predictions = (majority_votes == actual_groups).sum()
    total_cats = len(actual_groups)
    majority_vote_accuracy = correct_predictions / total_cats
    
    # Log the accuracy of the majority voting
    logger(f"Majority Vote Accuracy for cat_id for this fold: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

    ####################################################
    # COLLECT PREDICTIONS FOR GENDER & CAT_ID ANALYSIS #
    ####################################################

    # Debugging print statements
    print(f'Before appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Extend lists with current fold results
    all_cat_ids.extend(df_test_updated['cat_id'].tolist())
    all_predicted_age_groups.extend(predicted_age_groups)
    all_actual_age_groups.extend(actual_labels)
    all_gender.extend(df_test_updated['gender'].tolist())

    # Debugging print statements
    print(f'After appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Calculate additional metrics
    test_precision = precision_score(y_test_true, y_test_pred, average='macro')  # Use 'macro' for imbalanced datasets
    test_recall = recall_score(y_test_true, y_test_pred, average='macro')
    test_f1 = f1_score(y_test_true, y_test_pred, average='macro')

    # prepare averages of outer metrics
    unseen_f1.append(test_f1)
    unseen_losses.append(test_loss)
    unseen_accuracies.append(test_accuracy)
    unseen_precisions.append(test_precision)
    unseen_recalls.append(test_recall)

    # Print final test results
    logger(f"Final Test Results - Loss: {test_loss}, Accuracy: {test_accuracy}, Precision: {test_precision}, Recall: {test_recall}, F1 Score: {test_f1}", file=log_file_path)

    # Generate the confusion matrix
    cm = confusion_matrix(y_test, y_test_pred)
    logger(f"Confusion Matrix:\n {cm}", file=log_file_path)

# Calculate the overall average metrics
unseen_set_avg_f1 = np.mean(unseen_f1)
unseen_set_avg_loss = np.mean(unseen_losses)
unseen_set_avg_acc = np.mean(unseen_accuracies)
unseen_set_avg_precision = np.mean(unseen_precisions)
unseen_set_avg_recall = np.mean(unseen_recalls)

logger(f"\nFinal Average F1-Score across all UNSEEN TEST sets: {unseen_set_avg_f1}", file=log_file_path)
logger(f"\nFinal Average Loss across all UNSEEN TEST sets: {unseen_set_avg_loss}", file=log_file_path)
logger(f"\nFinal Average Accuracy across all UNSEEN TEST sets: {unseen_set_avg_acc}", file=log_file_path)
logger(f"\nFinal Average Precision across all UNSEEN TEST sets: {unseen_set_avg_precision}", file=log_file_path)
logger(f"\nFinal Average Recall across all UNSEEN TEST sets: {unseen_set_avg_recall}\n", file=log_file_path)

# Append averages to total lists
average_fold_f1.append(unseen_set_avg_f1)
average_fold_losses.append(unseen_set_avg_loss)
average_fold_accuracies.append(unseen_set_avg_acc)
average_fold_precisions.append(unseen_set_avg_precision)
average_fold_recalls.append(unseen_set_avg_recall)

# Append all to total lists
all_f1.append(unseen_f1)
all_losses.append(unseen_losses)
all_accuracies.append(unseen_accuracies)
all_precisions.append(unseen_precisions)
all_recalls.append(unseen_recalls)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# outer_fold 1
# Train Set Group Distribution:
# 046A    45
# 000A    39
# 103A    33
# 002B    30
# 047A    22
# 000B    19
# 057A    17
# 019A    17
# 074A    16
# 029A    15
# 097A    15
# 097B    14
# 002A    13
# 101A    12
# 111A    12
# 051A    12
# 028A    11
# 042A    11
# 067A    11
# 059A    10
# 014B    10
# 025A    10
# 065A     9
# 016A     9
# 072A     9
# 005A     9
# 022A     9
# 001A     9
# 013B     8
# 095A     7
# 027A     7
# 117A     7
# 031A     7
# 023A     6
# 021A     5
# 094A     5
# 050A     5
# 008A     5
# 109A     5
# 070A     5
# 108A     5
# 044A     5
# 045A     4
# 025C     4
# 009A     4
# 026A     4
# 012A     3
# 058A     3
# 010A     3
# 053A     3
# 006A     3
# 034A     3
# 014A     3
# 113A     3
# 105A     3
# 093A     2
# 025B     2
# 037A     2
# 102A     2
# 061A     2
# 035A     2
# 038A     2
# 052A     2
# 018A     2
# 032A     2
# 087A     2
# 041A     1
# 090A     1
# 100A     1
# 043A     1
# 110A     1
# 076A     1
# 115A     1
# 073A     1
# 064A     1
# 092A     1
# 019B     1
# 088A     1
# 004A     1
# 048A     1
# 066A     1
# 049A     1
# 091A     1
# 026B     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 020A    20
# 106A    13
# 116A    12
# 055A    12
# 063A    11
# 040A    10
# 051B     9
# 033A     9
# 071A     9
# 068A     8
# 015A     7
# 036A     7
# 039A     6
# 099A     6
# 007A     6
# 075A     5
# 023B     4
# 003A     4
# 104A     4
# 056A     3
# 062A     3
# 060A     3
# 054A     2
# 069A     2
# 011A     2
# 096A     1
# 026C     1
# 024A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    214
# M    208
# F    191
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# M    78
# X    62
# F    40
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [006A, 000A, 001A, 103A, 097B, 028A, 019A, 074...
# kitten    [044A, 014B, 111A, 046A, 047A, 042A, 109A, 050...
# senior    [093A, 097A, 057A, 059A, 113A, 117A, 051A, 058...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [033A, 015A, 071A, 020A, 062A, 039A, 063A, 099...
# kitten                                               [040A]
# senior    [106A, 104A, 055A, 116A, 051B, 054A, 056A, 011...
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 56, 'kitten': 15, 'senior': 13}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 18, 'kitten': 1, 'senior': 9}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '004A' '005A' '006A' '008A' '009A'
#  '010A' '012A' '013B' '014A' '014B' '016A' '018A' '019A' '019B' '021A'
#  '022A' '023A' '025A' '025B' '025C' '026A' '026B' '027A' '028A' '029A'
#  '031A' '032A' '034A' '035A' '037A' '038A' '041A' '042A' '043A' '044A'
#  '045A' '046A' '047A' '048A' '049A' '050A' '051A' '052A' '053A' '057A'
#  '058A' '059A' '061A' '064A' '065A' '066A' '067A' '070A' '072A' '073A'
#  '074A' '076A' '087A' '088A' '090A' '091A' '092A' '093A' '094A' '095A'
#  '097A' '097B' '100A' '101A' '102A' '103A' '105A' '108A' '109A' '110A'
#  '111A' '113A' '115A' '117A']
# Unique Test Group IDs:
# ['003A' '007A' '011A' '015A' '020A' '023B' '024A' '026C' '033A' '036A'
#  '039A' '040A' '051B' '054A' '055A' '056A' '060A' '062A' '063A' '068A'
#  '069A' '071A' '075A' '096A' '099A' '104A' '106A' '116A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '004A' '005A' '006A' '008A' '009A'
#  '010A' '012A' '013B' '014A' '014B' '016A' '018A' '019A' '019B' '021A'
#  '022A' '023A' '025A' '025B' '025C' '026A' '026B' '027A' '028A' '029A'
#  '031A' '032A' '034A' '035A' '037A' '038A' '041A' '042A' '043A' '044A'
#  '045A' '046A' '047A' '048A' '049A' '050A' '051A' '052A' '053A' '057A'
#  '058A' '059A' '061A' '064A' '065A' '066A' '067A' '070A' '072A' '073A'
#  '074A' '076A' '087A' '088A' '090A' '091A' '092A' '093A' '094A' '095A'
#  '097A' '097B' '100A' '101A' '102A' '103A' '105A' '108A' '109A' '110A'
#  '111A' '113A' '115A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['003A' '007A' '011A' '015A' '020A' '023B' '024A' '026C' '033A' '036A'
#  '039A' '040A' '051B' '054A' '055A' '056A' '060A' '062A' '063A' '068A'
#  '069A' '071A' '075A' '096A' '099A' '104A' '106A' '116A']
# Length of X_train_val:
# 613
# Length of y_train_val:
# 613
# Length of groups_train_val:
# 613
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     397
# kitten    125
# senior     91
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     112
# senior     58
# kitten     10
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     397
# kitten    125
# senior     91
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     112
# senior     58
# kitten     10
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 980, 1: 889, 2: 635})
# Epoch 1/1500
# 40/40 [==============================] - 1s 5ms/step - loss: 0.4876 - accuracy: 0.8407
# Epoch 2/1500
# 40/40 [==============================] - 0s 5ms/step - loss: 0.1130 - accuracy: 0.9613
# Epoch 3/1500
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0508 - accuracy: 0.9832
# Epoch 4/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0306 - accuracy: 0.9912
# Epoch 5/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0221 - accuracy: 0.9932
# Epoch 6/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0227 - accuracy: 0.9936
# Epoch 7/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0174 - accuracy: 0.9952
# Epoch 8/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0129 - accuracy: 0.9960
# Epoch 9/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0115 - accuracy: 0.9960
# Epoch 10/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0072 - accuracy: 0.9980
# Epoch 11/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0077 - accuracy: 0.9984
# Epoch 12/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0099 - accuracy: 0.9964
# Epoch 13/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0094 - accuracy: 0.9964
# Epoch 14/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0221 - accuracy: 0.9952
# Epoch 15/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0236 - accuracy: 0.9924
# Epoch 16/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0147 - accuracy: 0.9956
# Epoch 17/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0100 - accuracy: 0.9964
# Epoch 18/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0050 - accuracy: 0.9992
# Epoch 19/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0041 - accuracy: 0.9992
# Epoch 20/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0067 - accuracy: 0.9976
# Epoch 21/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0074 - accuracy: 0.9992
# Epoch 22/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0041 - accuracy: 0.9992
# Epoch 23/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0077 - accuracy: 0.9968
# Epoch 24/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0044 - accuracy: 0.9988
# Epoch 25/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0067 - accuracy: 0.9980
# Epoch 26/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0031 - accuracy: 0.9992
# Epoch 27/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0017 - accuracy: 0.9996
# Epoch 28/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0068 - accuracy: 0.9984
# Epoch 29/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0100 - accuracy: 0.9972
# Epoch 30/1500
# 40/40 [==============================] - 1s 13ms/step - loss: 0.0207 - accuracy: 0.9936
# Epoch 31/1500
# 40/40 [==============================] - 0s 8ms/step - loss: 0.0122 - accuracy: 0.9956
# Epoch 32/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0073 - accuracy: 0.9972
# Epoch 33/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0091 - accuracy: 0.9980
# Epoch 34/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0072 - accuracy: 0.9976
# Epoch 35/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0071 - accuracy: 0.9976
# Epoch 36/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0131 - accuracy: 0.9968
# Epoch 37/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0078 - accuracy: 0.9980
# Epoch 38/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0056 - accuracy: 0.9980
# Epoch 39/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0071 - accuracy: 0.9988
# Epoch 40/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0093 - accuracy: 0.9976
# Epoch 41/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0022 - accuracy: 0.9996
# Epoch 42/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 43/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0056 - accuracy: 0.9996
# Epoch 44/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0042 - accuracy: 0.9988
# Epoch 45/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0024 - accuracy: 0.9996
# Epoch 46/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0037 - accuracy: 0.9980
# Epoch 47/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0042 - accuracy: 0.9996
# Epoch 48/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0053 - accuracy: 0.9984
# Epoch 49/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0038 - accuracy: 0.9988
# Epoch 50/1500
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0037 - accuracy: 0.9992
# Epoch 51/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0034 - accuracy: 0.9996
# Epoch 52/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0048 - accuracy: 0.9992
# Epoch 53/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0021 - accuracy: 0.9992
# Epoch 54/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 7.5429e-04 - accuracy: 1.0000
# Epoch 55/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0042 - accuracy: 0.9988
# Epoch 56/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0061 - accuracy: 0.9980
# Epoch 57/1500
# 36/40 [==========================>...] - ETA: 0s - loss: 0.0071 - accuracy: 0.9970Restoring model weights from the end of the best epoch: 27.
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0081 - accuracy: 0.9964
# Epoch 57: early stopping
# 6/6 [==============================] - 0s 2ms/step - loss: 2.1835 - accuracy: 0.7000
# 6/6 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.64 (18/28)
# Before appending - Cat IDs: 0, Predictions: 0, Actuals: 0, Gender: 0
# After appending - Cat IDs: 180, Predictions: 180, Actuals: 180, Gender: 180
# Final Test Results - Loss: 2.183525323867798, Accuracy: 0.699999988079071, Precision: 0.7034649476228848, Recall: 0.7173645320197043, F1 Score: 0.6349239161642262
# Confusion Matrix:
#  [[102   7   3]
#  [  0  10   0]
#  [ 44   0  14]]
# outer_fold 2
# Train Set Group Distribution:
# 046A    45
# 103A    33
# 047A    22
# 020A    20
# 057A    17
# 019A    17
# 097A    15
# 106A    13
# 116A    12
# 055A    12
# 051A    12
# 101A    12
# 111A    12
# 028A    11
# 042A    11
# 063A    11
# 040A    10
# 025A    10
# 059A    10
# 033A     9
# 016A     9
# 051B     9
# 072A     9
# 001A     9
# 071A     9
# 005A     9
# 068A     8
# 095A     7
# 031A     7
# 117A     7
# 015A     7
# 036A     7
# 027A     7
# 099A     6
# 039A     6
# 007A     6
# 075A     5
# 050A     5
# 021A     5
# 108A     5
# 008A     5
# 109A     5
# 094A     5
# 070A     5
# 104A     4
# 023B     4
# 003A     4
# 026A     4
# 045A     4
# 009A     4
# 060A     3
# 056A     3
# 010A     3
# 006A     3
# 014A     3
# 062A     3
# 034A     3
# 018A     2
# 025B     2
# 061A     2
# 011A     2
# 038A     2
# 052A     2
# 087A     2
# 054A     2
# 069A     2
# 090A     1
# 076A     1
# 043A     1
# 115A     1
# 073A     1
# 088A     1
# 004A     1
# 048A     1
# 066A     1
# 064A     1
# 026C     1
# 096A     1
# 091A     1
# 041A     1
# 092A     1
# 024A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 000A    39
# 002B    30
# 000B    19
# 074A    16
# 029A    15
# 097B    14
# 002A    13
# 067A    11
# 014B    10
# 022A     9
# 065A     9
# 013B     8
# 023A     6
# 044A     5
# 025C     4
# 113A     3
# 105A     3
# 058A     3
# 012A     3
# 053A     3
# 037A     2
# 035A     2
# 102A     2
# 032A     2
# 093A     2
# 019B     1
# 049A     1
# 110A     1
# 100A     1
# 026B     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    233
# M    194
# F    128
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# F    103
# M     92
# X     43
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [006A, 033A, 015A, 001A, 103A, 071A, 028A, 019...
# kitten    [111A, 040A, 046A, 047A, 042A, 109A, 050A, 043...
# senior    [097A, 057A, 106A, 104A, 055A, 059A, 116A, 051...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [000A, 097B, 074A, 067A, 002B, 022A, 029A, 065...
# kitten                             [044A, 014B, 049A, 110A]
# senior                                   [093A, 113A, 058A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 51, 'kitten': 12, 'senior': 19}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 23, 'kitten': 4, 'senior': 3}
# Unique Training/Validation Group IDs:
# ['001A' '003A' '004A' '005A' '006A' '007A' '008A' '009A' '010A' '011A'
#  '014A' '015A' '016A' '018A' '019A' '020A' '021A' '023B' '024A' '025A'
#  '025B' '026A' '026C' '027A' '028A' '031A' '033A' '034A' '036A' '038A'
#  '039A' '040A' '041A' '042A' '043A' '045A' '046A' '047A' '048A' '050A'
#  '051A' '051B' '052A' '054A' '055A' '056A' '057A' '059A' '060A' '061A'
#  '062A' '063A' '064A' '066A' '068A' '069A' '070A' '071A' '072A' '073A'
#  '075A' '076A' '087A' '088A' '090A' '091A' '092A' '094A' '095A' '096A'
#  '097A' '099A' '101A' '103A' '104A' '106A' '108A' '109A' '111A' '115A'
#  '116A' '117A']
# Unique Test Group IDs:
# ['000A' '000B' '002A' '002B' '012A' '013B' '014B' '019B' '022A' '023A'
#  '025C' '026B' '029A' '032A' '035A' '037A' '044A' '049A' '053A' '058A'
#  '065A' '067A' '074A' '093A' '097B' '100A' '102A' '105A' '110A' '113A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'000A'}
# Removed from Training/Validation Set:
# {'092A'}
# Moved to Test Set:
# {'092A'}
# Removed from Test Set
# {'000A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '001A' '003A' '004A' '005A' '006A' '007A' '008A' '009A' '010A'
#  '011A' '014A' '015A' '016A' '018A' '019A' '020A' '021A' '023B' '024A'
#  '025A' '025B' '026A' '026C' '027A' '028A' '031A' '033A' '034A' '036A'
#  '038A' '039A' '040A' '041A' '042A' '043A' '045A' '046A' '047A' '048A'
#  '050A' '051A' '051B' '052A' '054A' '055A' '056A' '057A' '059A' '060A'
#  '061A' '062A' '063A' '064A' '066A' '068A' '069A' '070A' '071A' '072A'
#  '073A' '075A' '076A' '087A' '088A' '090A' '091A' '094A' '095A' '096A'
#  '097A' '099A' '101A' '103A' '104A' '106A' '108A' '109A' '111A' '115A'
#  '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['000B' '002A' '002B' '012A' '013B' '014B' '019B' '022A' '023A' '025C'
#  '026B' '029A' '032A' '035A' '037A' '044A' '049A' '053A' '058A' '065A'
#  '067A' '074A' '092A' '093A' '097B' '100A' '102A' '105A' '110A' '113A']
# Length of X_train_val:
# 593
# Length of y_train_val:
# 593
# Length of groups_train_val:
# 593
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     296
# senior    141
# kitten    118
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     213
# kitten     17
# senior      8
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     334
# senior    141
# kitten    118
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     175
# kitten     17
# senior      8
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({2: 1005, 1: 854, 0: 812})
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Epoch 1/1500
# 42/42 [==============================] - 1s 5ms/step - loss: 0.4694 - accuracy: 0.8469
# Epoch 2/1500
# 42/42 [==============================] - 0s 5ms/step - loss: 0.1089 - accuracy: 0.9611
# Epoch 3/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0572 - accuracy: 0.9813
# Epoch 4/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0364 - accuracy: 0.9850
# Epoch 5/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0225 - accuracy: 0.9918
# Epoch 6/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0184 - accuracy: 0.9944
# Epoch 7/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0164 - accuracy: 0.9955
# Epoch 8/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0152 - accuracy: 0.9959
# Epoch 9/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0078 - accuracy: 0.9981
# Epoch 10/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0093 - accuracy: 0.9981
# Epoch 11/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0051 - accuracy: 0.9989
# Epoch 12/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0049 - accuracy: 0.9985
# Epoch 13/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0047 - accuracy: 0.9993
# Epoch 14/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0031 - accuracy: 0.9996
# Epoch 15/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 16/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0048 - accuracy: 0.9985
# Epoch 17/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0022 - accuracy: 0.9996
# Epoch 18/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0039 - accuracy: 0.9985
# Epoch 19/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0047 - accuracy: 0.9993
# Epoch 20/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0070 - accuracy: 0.9970
# Epoch 21/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0075 - accuracy: 0.9978
# Epoch 22/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0088 - accuracy: 0.9963
# Epoch 23/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0070 - accuracy: 0.9974
# Epoch 24/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0111 - accuracy: 0.9966
# Epoch 25/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0143 - accuracy: 0.9940
# Epoch 26/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0085 - accuracy: 0.9978
# Epoch 27/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0057 - accuracy: 0.9993
# Epoch 28/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0038 - accuracy: 0.9985
# Epoch 29/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0057 - accuracy: 0.9985
# Epoch 30/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0022 - accuracy: 0.9996
# Epoch 31/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0034 - accuracy: 0.9981
# Epoch 32/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0197 - accuracy: 0.9951
# Epoch 33/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0122 - accuracy: 0.9955
# Epoch 34/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0063 - accuracy: 0.9985
# Epoch 35/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0021 - accuracy: 0.9993
# Epoch 36/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0060 - accuracy: 0.9974
# Epoch 37/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0045 - accuracy: 0.9981
# Epoch 38/1500
# 42/42 [==============================] - 0s 7ms/step - loss: 0.0039 - accuracy: 0.9978
# Epoch 39/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 40/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0026 - accuracy: 0.9993
# Epoch 41/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0019 - accuracy: 0.9996
# Epoch 42/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0039 - accuracy: 0.9989
# Epoch 43/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0040 - accuracy: 0.9989
# Epoch 44/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0049 - accuracy: 0.9985
# Epoch 45/1500
# 34/42 [=======================>......] - ETA: 0s - loss: 0.0098 - accuracy: 0.9972Restoring model weights from the end of the best epoch: 15.
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0083 - accuracy: 0.9978
# Epoch 45: early stopping
# 7/7 [==============================] - 0s 1ms/step - loss: 0.8317 - accuracy: 0.8450
# 7/7 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.90 (27/30)
# Before appending - Cat IDs: 180, Predictions: 180, Actuals: 180, Gender: 180
# After appending - Cat IDs: 380, Predictions: 380, Actuals: 380, Gender: 380
# Final Test Results - Loss: 0.8316957950592041, Accuracy: 0.8450000286102295, Precision: 0.6046296029435781, Recall: 0.7154481792717088, F1 Score: 0.6209544058587291
# Confusion Matrix:
#  [[153   6  16]
#  [  1  11   5]
#  [  3   0   5]]
# outer_fold 3
# Train Set Group Distribution:
# 000A    39
# 002B    30
# 020A    20
# 000B    19
# 019A    17
# 057A    17
# 074A    16
# 029A    15
# 097A    15
# 097B    14
# 002A    13
# 106A    13
# 055A    12
# 111A    12
# 116A    12
# 028A    11
# 063A    11
# 067A    11
# 014B    10
# 040A    10
# 065A     9
# 005A     9
# 022A     9
# 051B     9
# 033A     9
# 071A     9
# 001A     9
# 068A     8
# 013B     8
# 117A     7
# 036A     7
# 015A     7
# 095A     7
# 031A     7
# 039A     6
# 023A     6
# 099A     6
# 007A     6
# 044A     5
# 094A     5
# 050A     5
# 075A     5
# 026A     4
# 003A     4
# 023B     4
# 009A     4
# 025C     4
# 104A     4
# 053A     3
# 113A     3
# 105A     3
# 060A     3
# 034A     3
# 062A     3
# 056A     3
# 012A     3
# 058A     3
# 006A     3
# 011A     2
# 061A     2
# 102A     2
# 035A     2
# 052A     2
# 037A     2
# 032A     2
# 093A     2
# 054A     2
# 038A     2
# 069A     2
# 087A     2
# 049A     1
# 019B     1
# 024A     1
# 100A     1
# 110A     1
# 004A     1
# 088A     1
# 092A     1
# 066A     1
# 096A     1
# 043A     1
# 026C     1
# 073A     1
# 026B     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 046A    45
# 103A    33
# 047A    22
# 101A    12
# 051A    12
# 042A    11
# 059A    10
# 025A    10
# 072A     9
# 016A     9
# 027A     7
# 108A     5
# 008A     5
# 021A     5
# 109A     5
# 070A     5
# 045A     4
# 014A     3
# 010A     3
# 018A     2
# 025B     2
# 076A     1
# 064A     1
# 041A     1
# 091A     1
# 048A     1
# 115A     1
# 090A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    210
# F    181
# X    176
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    100
# M     76
# F     50
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [006A, 000A, 033A, 015A, 001A, 071A, 097B, 028...
# kitten     [044A, 014B, 111A, 040A, 050A, 043A, 049A, 110A]
# senior    [093A, 097A, 057A, 106A, 104A, 055A, 113A, 116...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [103A, 101A, 072A, 091A, 027A, 025A, 070A, 014...
# kitten     [046A, 047A, 042A, 109A, 041A, 045A, 048A, 115A]
# senior                       [059A, 051A, 016A, 108A, 090A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 59, 'kitten': 8, 'senior': 17}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 15, 'kitten': 8, 'senior': 5}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '004A' '005A' '006A' '007A'
#  '009A' '011A' '012A' '013B' '014B' '015A' '019A' '019B' '020A' '022A'
#  '023A' '023B' '024A' '025C' '026A' '026B' '026C' '028A' '029A' '031A'
#  '032A' '033A' '034A' '035A' '036A' '037A' '038A' '039A' '040A' '043A'
#  '044A' '049A' '050A' '051B' '052A' '053A' '054A' '055A' '056A' '057A'
#  '058A' '060A' '061A' '062A' '063A' '065A' '066A' '067A' '068A' '069A'
#  '071A' '073A' '074A' '075A' '087A' '088A' '092A' '093A' '094A' '095A'
#  '096A' '097A' '097B' '099A' '100A' '102A' '104A' '105A' '106A' '110A'
#  '111A' '113A' '116A' '117A']
# Unique Test Group IDs:
# ['008A' '010A' '014A' '016A' '018A' '021A' '025A' '025B' '027A' '041A'
#  '042A' '045A' '046A' '047A' '048A' '051A' '059A' '064A' '070A' '072A'
#  '076A' '090A' '091A' '101A' '103A' '108A' '109A' '115A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'046A'}
# Removed from Training/Validation Set:
# {'110A'}
# Moved to Test Set:
# {'110A'}
# Removed from Test Set
# {'046A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '004A' '005A' '006A' '007A'
#  '009A' '011A' '012A' '013B' '014B' '015A' '019A' '019B' '020A' '022A'
#  '023A' '023B' '024A' '025C' '026A' '026B' '026C' '028A' '029A' '031A'
#  '032A' '033A' '034A' '035A' '036A' '037A' '038A' '039A' '040A' '043A'
#  '044A' '046A' '049A' '050A' '051B' '052A' '053A' '054A' '055A' '056A'
#  '057A' '058A' '060A' '061A' '062A' '063A' '065A' '066A' '067A' '068A'
#  '069A' '071A' '073A' '074A' '075A' '087A' '088A' '092A' '093A' '094A'
#  '095A' '096A' '097A' '097B' '099A' '100A' '102A' '104A' '105A' '106A'
#  '111A' '113A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['008A' '010A' '014A' '016A' '018A' '021A' '025A' '025B' '027A' '041A'
#  '042A' '045A' '047A' '048A' '051A' '059A' '064A' '070A' '072A' '076A'
#  '090A' '091A' '101A' '103A' '108A' '109A' '110A' '115A']
# Length of X_train_val:
# 611
# Length of y_train_val:
# 611
# Length of groups_train_val:
# 611
# No common groups found between train and test sets.
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Train Age Group Distribution BEFORE SWAP:
# adult     410
# senior    112
# kitten     45
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     99
# kitten    90
# senior    37
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     410
# senior    112
# kitten     89
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     99
# kitten    46
# senior    37
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 1031, 2: 788, 1: 585})
# Epoch 1/1500
# 38/38 [==============================] - 1s 5ms/step - loss: 0.4208 - accuracy: 0.8615
# Epoch 2/1500
# 38/38 [==============================] - 0s 5ms/step - loss: 0.0904 - accuracy: 0.9663
# Epoch 3/1500
# 38/38 [==============================] - 0s 5ms/step - loss: 0.0552 - accuracy: 0.9834
# Epoch 4/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0219 - accuracy: 0.9921
# Epoch 5/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0173 - accuracy: 0.9950
# Epoch 6/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0154 - accuracy: 0.9942
# Epoch 7/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0088 - accuracy: 0.9971
# Epoch 8/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0099 - accuracy: 0.9963
# Epoch 9/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0070 - accuracy: 0.9983
# Epoch 10/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0056 - accuracy: 0.9979
# Epoch 11/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0055 - accuracy: 0.9988
# Epoch 12/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0069 - accuracy: 0.9979
# Epoch 13/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0067 - accuracy: 0.9983
# Epoch 14/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0030 - accuracy: 0.9992
# Epoch 15/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0022 - accuracy: 0.9996
# Epoch 16/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0028 - accuracy: 0.9988
# Epoch 17/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0033 - accuracy: 0.9996
# Epoch 18/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0053 - accuracy: 0.9979
# Epoch 19/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0054 - accuracy: 0.9988
# Epoch 20/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0071 - accuracy: 0.9983
# Epoch 21/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0026 - accuracy: 0.9992
# Epoch 22/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0015 - accuracy: 0.9996
# Epoch 23/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 24/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0020 - accuracy: 0.9996
# Epoch 25/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0043 - accuracy: 0.9992
# Epoch 26/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0064 - accuracy: 0.9975
# Epoch 27/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0061 - accuracy: 0.9979
# Epoch 28/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0163 - accuracy: 0.9942
# Epoch 29/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0073 - accuracy: 0.9979
# Epoch 30/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0048 - accuracy: 0.9975
# Epoch 31/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0035 - accuracy: 0.9988
# Epoch 32/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 33/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 9.8612e-04 - accuracy: 1.0000
# Epoch 34/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0075 - accuracy: 0.9975
# Epoch 35/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0186 - accuracy: 0.9958
# Epoch 36/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0062 - accuracy: 0.9975
# Epoch 37/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0026 - accuracy: 0.9996
# Epoch 38/1500
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0092 - accuracy: 0.9983
# Epoch 39/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0021 - accuracy: 0.9996
# Epoch 40/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0033 - accuracy: 0.9992
# Epoch 41/1500
# 38/38 [==============================] - 0s 5ms/step - loss: 0.0020 - accuracy: 0.9996
# Epoch 42/1500
# 38/38 [==============================] - 0s 5ms/step - loss: 0.0011 - accuracy: 0.9996
# Epoch 43/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 8.0670e-04 - accuracy: 1.0000
# Epoch 44/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 6.7287e-04 - accuracy: 1.0000
# Epoch 45/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0017 - accuracy: 0.9996
# Epoch 46/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 6.3591e-04 - accuracy: 1.0000
# Epoch 47/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0022 - accuracy: 0.9992
# Epoch 48/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0052 - accuracy: 0.9979
# Epoch 49/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0026 - accuracy: 0.9996
# Epoch 50/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0068 - accuracy: 0.9983
# Epoch 51/1500
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0033 - accuracy: 0.9988
# Epoch 52/1500
# 37/38 [============================>.] - ETA: 0s - loss: 0.0018 - accuracy: 0.9987Restoring model weights from the end of the best epoch: 22.
# 38/38 [==============================] - 0s 6ms/step - loss: 0.0018 - accuracy: 0.9988
# Epoch 52: early stopping
# 6/6 [==============================] - 0s 2ms/step - loss: 3.0230 - accuracy: 0.5714
# 6/6 [==============================] - 0s 2ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.75 (21/28)
# Before appending - Cat IDs: 380, Predictions: 380, Actuals: 380, Gender: 380
# After appending - Cat IDs: 562, Predictions: 562, Actuals: 562, Gender: 562
# Final Test Results - Loss: 3.0229897499084473, Accuracy: 0.5714285969734192, Precision: 0.6079182630906769, Recall: 0.4489074054291446, F1 Score: 0.4497462919594068
# Confusion Matrix:
#  [[84  2 13]
#  [36  8  2]
#  [25  0 12]]
# outer_fold 4
# Train Set Group Distribution:
# 046A    45
# 000A    39
# 103A    33
# 002B    30
# 047A    22
# 020A    20
# 000B    19
# 074A    16
# 029A    15
# 097B    14
# 106A    13
# 002A    13
# 055A    12
# 116A    12
# 101A    12
# 051A    12
# 067A    11
# 042A    11
# 063A    11
# 025A    10
# 040A    10
# 014B    10
# 059A    10
# 072A     9
# 016A     9
# 065A     9
# 022A     9
# 071A     9
# 051B     9
# 033A     9
# 013B     8
# 068A     8
# 027A     7
# 036A     7
# 015A     7
# 099A     6
# 039A     6
# 007A     6
# 023A     6
# 044A     5
# 108A     5
# 109A     5
# 075A     5
# 021A     5
# 008A     5
# 070A     5
# 045A     4
# 003A     4
# 023B     4
# 025C     4
# 104A     4
# 010A     3
# 053A     3
# 056A     3
# 113A     3
# 058A     3
# 014A     3
# 012A     3
# 105A     3
# 062A     3
# 060A     3
# 011A     2
# 025B     2
# 035A     2
# 093A     2
# 102A     2
# 037A     2
# 069A     2
# 032A     2
# 054A     2
# 018A     2
# 110A     1
# 100A     1
# 090A     1
# 024A     1
# 115A     1
# 096A     1
# 026C     1
# 019B     1
# 048A     1
# 041A     1
# 049A     1
# 091A     1
# 064A     1
# 076A     1
# 026B     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 057A    17
# 019A    17
# 097A    15
# 111A    12
# 028A    11
# 001A     9
# 005A     9
# 117A     7
# 095A     7
# 031A     7
# 094A     5
# 050A     5
# 026A     4
# 009A     4
# 006A     3
# 034A     3
# 087A     2
# 038A     2
# 052A     2
# 061A     2
# 043A     1
# 073A     1
# 092A     1
# 066A     1
# 004A     1
# 088A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    246
# X    205
# F    193
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    71
# M    40
# F    38
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [000A, 033A, 015A, 103A, 071A, 097B, 074A, 067...
# kitten    [044A, 014B, 040A, 046A, 047A, 042A, 109A, 049...
# senior    [093A, 106A, 104A, 055A, 059A, 113A, 116A, 051...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [006A, 001A, 028A, 019A, 095A, 034A, 005A, 009...
# kitten                                   [111A, 050A, 043A]
# senior                       [097A, 057A, 117A, 094A, 061A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 56, 'kitten': 13, 'senior': 17}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 18, 'kitten': 3, 'senior': 5}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '002A' '002B' '003A' '007A' '008A' '010A' '011A' '012A'
#  '013B' '014A' '014B' '015A' '016A' '018A' '019B' '020A' '021A' '022A'
#  '023A' '023B' '024A' '025A' '025B' '025C' '026B' '026C' '027A' '029A'
#  '032A' '033A' '035A' '036A' '037A' '039A' '040A' '041A' '042A' '044A'
#  '045A' '046A' '047A' '048A' '049A' '051A' '051B' '053A' '054A' '055A'
#  '056A' '058A' '059A' '060A' '062A' '063A' '064A' '065A' '067A' '068A'
#  '069A' '070A' '071A' '072A' '074A' '075A' '076A' '090A' '091A' '093A'
#  '096A' '097B' '099A' '100A' '101A' '102A' '103A' '104A' '105A' '106A'
#  '108A' '109A' '110A' '113A' '115A' '116A']
# Unique Test Group IDs:
# ['001A' '004A' '005A' '006A' '009A' '019A' '026A' '028A' '031A' '034A'
#  '038A' '043A' '050A' '052A' '057A' '061A' '066A' '073A' '087A' '088A'
#  '092A' '094A' '095A' '097A' '111A' '117A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '002A' '002B' '003A' '007A' '008A' '010A' '011A' '012A'
#  '013B' '014A' '014B' '015A' '016A' '018A' '019B' '020A' '021A' '022A'
#  '023A' '023B' '024A' '025A' '025B' '025C' '026B' '026C' '027A' '029A'
#  '032A' '033A' '035A' '036A' '037A' '039A' '040A' '041A' '042A' '044A'
#  '045A' '046A' '047A' '048A' '049A' '051A' '051B' '053A' '054A' '055A'
#  '056A' '058A' '059A' '060A' '062A' '063A' '064A' '065A' '067A' '068A'
#  '069A' '070A' '071A' '072A' '074A' '075A' '076A' '090A' '091A' '093A'
#  '096A' '097B' '099A' '100A' '101A' '102A' '103A' '104A' '105A' '106A'
#  '108A' '109A' '110A' '113A' '115A' '116A']
# AFTER SWAP - Unique Test Group IDs:
# ['001A' '004A' '005A' '006A' '009A' '019A' '026A' '028A' '031A' '034A'
#  '038A' '043A' '050A' '052A' '057A' '061A' '066A' '073A' '087A' '088A'
#  '092A' '094A' '095A' '097A' '111A' '117A']
# Length of X_train_val:
# 644
# Length of y_train_val:
# 644
# Length of groups_train_val:
# 644
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     424
# kitten    117
# senior    103
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     85
# senior    46
# kitten    18
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     424
# kitten    117
# senior    103
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     85
# senior    46
# kitten    18
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 1060, 1: 837, 2: 719})
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Epoch 1/1500
# 41/41 [==============================] - 1s 5ms/step - loss: 0.4483 - accuracy: 0.8471
# Epoch 2/1500
# 41/41 [==============================] - 0s 5ms/step - loss: 0.0876 - accuracy: 0.9671
# Epoch 3/1500
# 41/41 [==============================] - 0s 5ms/step - loss: 0.0386 - accuracy: 0.9866
# Epoch 4/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0263 - accuracy: 0.9912
# Epoch 5/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0160 - accuracy: 0.9943
# Epoch 6/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0135 - accuracy: 0.9962
# Epoch 7/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0159 - accuracy: 0.9966
# Epoch 8/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0133 - accuracy: 0.9954
# Epoch 9/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0084 - accuracy: 0.9977
# Epoch 10/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0075 - accuracy: 0.9969
# Epoch 11/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0029 - accuracy: 0.9996
# Epoch 12/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0053 - accuracy: 0.9989
# Epoch 13/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0039 - accuracy: 0.9992
# Epoch 14/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0051 - accuracy: 0.9989
# Epoch 15/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0049 - accuracy: 0.9992
# Epoch 16/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0050 - accuracy: 0.9989
# Epoch 17/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0021 - accuracy: 0.9996
# Epoch 18/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0088 - accuracy: 0.9981
# Epoch 19/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0031 - accuracy: 0.9992
# Epoch 20/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0037 - accuracy: 0.9985
# Epoch 21/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0038 - accuracy: 0.9992
# Epoch 22/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0050 - accuracy: 0.9989
# Epoch 23/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0024 - accuracy: 0.9992
# Epoch 24/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 25/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0041 - accuracy: 0.9989
# Epoch 26/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0044 - accuracy: 0.9981
# Epoch 27/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0069 - accuracy: 0.9973
# Epoch 28/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0094 - accuracy: 0.9969
# Epoch 29/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0043 - accuracy: 0.9981
# Epoch 30/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 31/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0030 - accuracy: 0.9989
# Epoch 32/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0061 - accuracy: 0.9977
# Epoch 33/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0058 - accuracy: 0.9981
# Epoch 34/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0066 - accuracy: 0.9985
# Epoch 35/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0062 - accuracy: 0.9989
# Epoch 36/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0031 - accuracy: 0.9992
# Epoch 37/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0076 - accuracy: 0.9981
# Epoch 38/1500
# 41/41 [==============================] - 1s 15ms/step - loss: 0.0019 - accuracy: 0.9996
# Epoch 39/1500
# 41/41 [==============================] - 0s 8ms/step - loss: 0.0070 - accuracy: 0.9973
# Epoch 40/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0129 - accuracy: 0.9962
# Epoch 41/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0087 - accuracy: 0.9973
# Epoch 42/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0062 - accuracy: 0.9977
# Epoch 43/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0041 - accuracy: 0.9981
# Epoch 44/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0051 - accuracy: 0.9981
# Epoch 45/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0030 - accuracy: 0.9985
# Epoch 46/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0028 - accuracy: 0.9992
# Epoch 47/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0029 - accuracy: 0.9989
# Epoch 48/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 49/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0012 - accuracy: 0.9996
# Epoch 50/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 3.7182e-04 - accuracy: 1.0000
# Epoch 51/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 3.9315e-04 - accuracy: 1.0000
# Epoch 52/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0034 - accuracy: 0.9989
# Epoch 53/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 8.0310e-04 - accuracy: 0.9996
# Epoch 54/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0136 - accuracy: 0.9981
# Epoch 55/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0047 - accuracy: 0.9989
# Epoch 56/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0043 - accuracy: 0.9985
# Epoch 57/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0044 - accuracy: 0.9989
# Epoch 58/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0022 - accuracy: 0.9992
# Epoch 59/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0024 - accuracy: 0.9992
# Epoch 60/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0055 - accuracy: 0.9969
# Epoch 61/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0038 - accuracy: 0.9989
# Epoch 62/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0015 - accuracy: 0.9996
# Epoch 63/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0031 - accuracy: 0.9989
# Epoch 64/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0038 - accuracy: 0.9989
# Epoch 65/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0065 - accuracy: 0.9985
# Epoch 66/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0034 - accuracy: 0.9989
# Epoch 67/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 6.9197e-04 - accuracy: 1.0000
# Epoch 68/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0013 - accuracy: 0.9996
# Epoch 69/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0028 - accuracy: 0.9989
# Epoch 70/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0032 - accuracy: 0.9992
# Epoch 71/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0013 - accuracy: 0.9996
# Epoch 72/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0017 - accuracy: 0.9996
# Epoch 73/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0011 - accuracy: 0.9996
# Epoch 74/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 0.0014 - accuracy: 0.9992
# Epoch 75/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 4.7942e-04 - accuracy: 1.0000
# Epoch 76/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 1.9736e-04 - accuracy: 1.0000
# Epoch 77/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 4.0189e-04 - accuracy: 1.0000
# Epoch 78/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 1.2666e-04 - accuracy: 1.0000
# Epoch 79/1500
# 41/41 [==============================] - 0s 6ms/step - loss: 1.3301e-04 - accuracy: 1.0000
# Epoch 80/1500
# 37/41 [==========================>...] - ETA: 0s - loss: 1.5574e-04 - accuracy: 1.0000Restoring model weights from the end of the best epoch: 50.
# 41/41 [==============================] - 0s 6ms/step - loss: 1.8715e-04 - accuracy: 1.0000
# Epoch 80: early stopping
# 5/5 [==============================] - 0s 1ms/step - loss: 3.7726 - accuracy: 0.6913
# 5/5 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.81 (21/26)
# Before appending - Cat IDs: 562, Predictions: 562, Actuals: 562, Gender: 562
# After appending - Cat IDs: 711, Predictions: 711, Actuals: 711, Gender: 711
# Final Test Results - Loss: 3.772618532180786, Accuracy: 0.6912751793861389, Precision: 0.7101010101010101, Recall: 0.7198635976129583, F1 Score: 0.7061403508771931
# Confusion Matrix:
#  [[69  2 14]
#  [ 0 18  0]
#  [30  0 16]]
#
# Final Average F1-Score across all UNSEEN TEST sets: 0.6029412412148888
#
# Final Average Loss across all UNSEEN TEST sets: 2.452707350254059
#
# Final Average Accuracy across all UNSEEN TEST sets: 0.7019259482622147
#
# Final Average Precision across all UNSEEN TEST sets: 0.6565284559395375
#
# Final Average Recall across all UNSEEN TEST sets: 0.650395928583379

# %%
seed_4_folds_values = [unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1]

seed_4_training_acc_values = cv_training_acc_total

# Plotting all fold metrics
seed_4_folds_plot = plot_all_metrics(unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1, "Folds", "Fold Number")

# %% [markdown]
# ## Majority Voting on Total Entries per cat_id

# %%
# Debugging print statements
print(f'Checking - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
# Out:
# Checking - Cat IDs: 711, Predictions: 711, Actuals: 711, Gender: 711

# %%
# Create results df
full_results = pd.DataFrame({
    'cat_id': all_cat_ids,
    'predicted_age_group': all_predicted_age_groups,
    'actual_age_group': all_actual_age_groups,
    'all_gender': all_gender
})

# create a correct majority prediction column
full_results['correct'] = full_results['predicted_age_group'] == full_results['actual_age_group']

# %%
# Group by cat_id and aggregate predicted age groups
majority_votes = full_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first()

# Calculate the accuracy of majority voting
correct_predictions = (majority_votes == actual_groups).sum()
total_cats = len(actual_groups)
majority_vote_accuracy = correct_predictions / total_cats

logger(f"Overall Majority Vote Accuracy for cat_id: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

# store for final evaluation 
all_majority_vote_accuracies.append(majority_vote_accuracy)
# Out:
# Overall Majority Vote Accuracy for cat_id: 0.77 (85/110)

# %%
# Detailed df with predictions, actual labels, and comparison including majority vote
detailed_results = full_results.groupby('cat_id').apply(
    lambda x: pd.Series({
        'Predictions': list(x['predicted_age_group']),
        'Majority Vote': x['predicted_age_group'].mode()[0],
        'Actual Age Group': x['actual_age_group'].iloc[0],
        'Correct Majority Vote': x['predicted_age_group'].mode()[0] == x['actual_age_group'].iloc[0]
    })
).reset_index()

# Convert to DataFrame for better formatting and display
detailed_results = pd.DataFrame(detailed_results)

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 10)
pd.set_option('display.width', 1000)

sorted_detailed_results = detailed_results.sort_values(by='Correct Majority Vote', ascending=False)

# Display the sorted DataFrame
sorted_detailed_results
# Out:
#     cat_id                                        Predictions Majority Vote Actual Age Group  Correct Majority Vote
# 0     000B  [adult, senior, adult, adult, adult, adult, ad...         adult            adult                   True
# 71    065A  [senior, adult, adult, adult, adult, senior, a...         adult            adult                   True
# 80    074A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 79    073A                                            [adult]         adult            adult                   True
# 78    072A  [adult, adult, adult, senior, adult, adult, ad...         adult            adult                   True
# 77    071A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 76    070A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 75    069A                                    [adult, senior]         adult            adult                   True
# 74    068A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 73    067A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 72    066A                                            [adult]         adult            adult                   True
# 70    064A                                            [adult]         adult            adult                   True
# 46    040A  [kitten, kitten, kitten, kitten, kitten, kitte...        kitten           kitten                   True
# 69    063A  [kitten, adult, adult, adult, adult, kitten, a...         adult            adult                   True
# 68    062A                              [adult, adult, adult]         adult            adult                   True
# 64    058A                           [senior, senior, senior]        senior           senior                   True
# 58    052A                                     [adult, adult]         adult            adult                   True
# 1     001A  [adult, adult, adult, senior, adult, adult, ad...         adult            adult                   True
# 54    049A                                           [kitten]        kitten           kitten                   True
# 53    048A                                           [kitten]        kitten           kitten                   True
# 50    044A           [kitten, kitten, kitten, kitten, kitten]        kitten           kitten                   True
# 49    043A                                           [kitten]        kitten           kitten                   True
# 81    075A               [adult, kitten, adult, adult, adult]         adult            adult                   True
# 82    076A                                            [adult]         adult            adult                   True
# 83    087A                                     [adult, adult]         adult            adult                   True
# 84    088A                                            [adult]         adult            adult                   True
# 107   115A                                           [kitten]        kitten           kitten                   True
# 106   113A                            [adult, senior, senior]        senior           senior                   True
# 105   111A  [kitten, kitten, kitten, kitten, kitten, kitte...        kitten           kitten                   True
# 104   110A                                   [kitten, kitten]        kitten           kitten                   True
# 102   108A             [senior, adult, adult, senior, senior]        senior           senior                   True
# 100   105A                              [adult, adult, adult]         adult            adult                   True
# 98    103A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 97    102A                                     [adult, adult]         adult            adult                   True
# 96    101A  [kitten, adult, adult, adult, senior, adult, a...         adult            adult                   True
# 95    100A                                            [adult]         adult            adult                   True
# 94    099A         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 93    097B  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 92    097A  [adult, senior, adult, adult, senior, senior, ...        senior           senior                   True
# 91    096A                                            [adult]         adult            adult                   True
# 90    095A  [senior, adult, adult, adult, adult, adult, ad...         adult            adult                   True
# 89    094A           [senior, senior, senior, senior, senior]        senior           senior                   True
# 87    092A                                     [adult, adult]         adult            adult                   True
# 86    091A                                            [adult]         adult            adult                   True
# 85    090A                                           [senior]        senior           senior                   True
# 47    041A                                           [kitten]        kitten           kitten                   True
# 55    050A           [kitten, kitten, kitten, kitten, kitten]        kitten           kitten                   True
# 45    039A         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 14    013B  [adult, adult, adult, senior, adult, adult, ad...         adult            adult                   True
# 34    027A  [adult, senior, adult, adult, adult, adult, ad...         adult            adult                   True
# 33    026C                                            [adult]         adult            adult                   True
# 32    026B                                            [adult]         adult            adult                   True
# 31    026A                       [adult, adult, adult, adult]         adult            adult                   True
# 30    025C                      [adult, adult, senior, adult]         adult            adult                   True
# 29    025B                                    [senior, adult]         adult            adult                   True
# 28    025A  [adult, senior, adult, adult, adult, adult, ad...         adult            adult                   True
# 10    009A                      [adult, adult, senior, adult]         adult            adult                   True
# 26    023B                       [adult, adult, adult, adult]         adult            adult                   True
# 25    023A         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 24    022A  [adult, adult, kitten, adult, adult, adult, ki...         adult            adult                   True
# 23    021A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 22    020A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 21    019B                                            [adult]         adult            adult                   True
# 20    019A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 19    018A                                     [adult, adult]         adult            adult                   True
# 11    010A                              [adult, adult, adult]         adult            adult                   True
# 17    015A  [adult, adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 13    012A                              [adult, adult, adult]         adult            adult                   True
# 35    028A  [adult, adult, adult, senior, adult, adult, ad...         adult            adult                   True
# 36    029A  [senior, senior, adult, adult, adult, adult, a...         adult            adult                   True
# 37    031A  [adult, adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 39    033A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 44    038A                                     [adult, adult]         adult            adult                   True
# 43    037A                                     [adult, adult]         adult            adult                   True
# 2     002A  [adult, adult, kitten, adult, adult, adult, ad...         adult            adult                   True
# 42    036A  [senior, adult, adult, adult, adult, adult, ad...         adult            adult                   True
# 41    035A                                     [adult, adult]         adult            adult                   True
# 40    034A                             [adult, adult, kitten]         adult            adult                   True
# 3     002B  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 9     008A               [adult, adult, adult, kitten, adult]         adult            adult                   True
# 4     003A                      [kitten, adult, adult, adult]         adult            adult                   True
# 7     006A                              [adult, adult, adult]         adult            adult                   True
# 38    032A                                     [adult, adult]         adult            adult                   True
# 8     007A        [adult, senior, adult, adult, adult, adult]         adult            adult                   True
# 15    014A                              [adult, adult, adult]         adult            adult                   True
# 5     004A                                           [kitten]        kitten            adult                  False
# 103   109A              [adult, adult, adult, senior, senior]         adult           kitten                  False
# 6     005A  [senior, senior, senior, senior, senior, senio...        senior            adult                  False
# 101   106A  [adult, adult, adult, senior, adult, adult, ad...         adult           senior                  False
# 108   116A  [senior, senior, adult, senior, adult, senior,...         adult           senior                  False
# 12    011A                                    [adult, senior]         adult           senior                  False
# 99    104A                       [adult, adult, adult, adult]         adult           senior                  False
# 27    024A                                            [adult]         adult           senior                  False
# 16    014B  [senior, kitten, senior, senior, kitten, kitte...        senior           kitten                  False
# 61    055A  [adult, senior, adult, adult, adult, senior, a...         adult           senior                  False
# 51    045A                     [kitten, adult, kitten, adult]         adult           kitten                  False
# 52    047A  [adult, adult, adult, adult, adult, adult, adu...         adult           kitten                  False
# 56    051A  [adult, senior, adult, adult, adult, adult, ad...         adult           senior                  False
# 57    051B  [adult, adult, adult, adult, adult, adult, adu...         adult           senior                  False
# 59    053A                           [senior, senior, senior]        senior            adult                  False
# 60    054A                                     [adult, adult]         adult           senior                  False
# 62    056A                              [adult, adult, adult]         adult           senior                  False
# 88    093A                                     [adult, adult]         adult           senior                  False
# 63    057A  [adult, senior, senior, adult, senior, adult, ...         adult           senior                  False
# 65    059A  [adult, senior, senior, adult, adult, adult, a...         adult           senior                  False
# 66    060A                            [adult, kitten, kitten]        kitten            adult                  False
# 67    061A                                     [adult, adult]         adult           senior                  False
# 48    042A  [adult, adult, adult, adult, adult, adult, adu...         adult           kitten                  False
# 18    016A  [adult, adult, adult, senior, senior, adult, a...         adult           senior                  False
# 109   117A  [adult, adult, adult, adult, adult, adult, adult]         adult           senior                  False

# %%
# Create df for majority votes
majority_df = majority_votes.reset_index()
majority_df.columns = ['cat_id', 'Majority_Vote']

# Get actual groups for each cat_id
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first().reset_index()

# Merge majority votes with actual groups
majority_with_actual = pd.merge(majority_df, actual_groups, on='cat_id')

# Add a column to check if the majority vote was correct
majority_with_actual['Majority_Correct'] = majority_with_actual['Majority_Vote'] == majority_with_actual['actual_age_group']

# Count correct majority votes per class
correct_majority_votes_per_class = majority_with_actual.groupby('actual_age_group')['Majority_Correct'].sum()

print("Correct Majority Votes per Class:")
print(correct_majority_votes_per_class)
# Out:
# Correct Majority Votes per Class:
# actual_age_group
# adult     69
# kitten    10
# senior     6
# Name: Majority_Correct, dtype: int64

# %%
# Calculate the total count and the number of correct predictions for each class
class_stats = majority_with_actual.groupby('actual_age_group').agg(
    total_count=('Majority_Correct', 'size'),  # Total number of cases per class
    correct_count=('Majority_Correct', 'sum')  # Sum of correct predictions per class
).reset_index()

# Calculate accuracy for each class
class_stats['accuracy'] = class_stats['correct_count'] / class_stats['total_count'] * 100

# store for final evaluation 
all_majority_vote_details.append(class_stats)

# Log detailed stats
print("Detailed Class Statistics for Majority Votes:")
print(class_stats)
# Out:
# Detailed Class Statistics for Majority Votes:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult           73             69  94.520548
# 1           kitten           15             10  66.666667
# 2           senior           22              6  27.272727

# %%
# Plot for Detailed Class Statistics for Majority Votes
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Accuracy of Majority Votes by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Detailed Class Statistics

# %%
# Calculate the total count and the number of correct predictions for each class
class_stats = full_results.groupby('actual_age_group').agg(
    total_count=('correct', 'size'),
    correct_count=('correct', 'sum')
).reset_index()

# Calculate accuracy for each class
class_stats['accuracy'] = class_stats['correct_count'] / class_stats['total_count'] * 100

# store for final evaluation 
all_class_stats.append(class_stats)

# Log the detailed stats
print("Detailed Class Statistics:")
print(class_stats)
# Out:
# Detailed Class Statistics:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult          471            408  86.624204
# 1           kitten           91             47  51.648352
# 2           senior          149             47  31.543624

# %%
# Plot for Detailed Class Statistics (Overall)
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Overall Accuracy by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Gender Exploration

# %%
# Group by gender and calculate the total count, correct predictions, and accuracy
gender_stats = full_results.groupby('all_gender').agg(
    count=('cat_id', 'size'),  # Total number of cases per gender
    correct=('correct', 'sum')  # Sum of correct predictions per gender
).reset_index()

# Calculate accuracy for each gender
gender_stats['accuracy'] = (gender_stats['correct'] / gender_stats['count'] * 100).round(2)

# Display the DataFrame
print("Accuracy by Gender:")
print(gender_stats)

# store for final evaluation 
all_gender_stats.append(gender_stats)
# Out:
# Accuracy by Gender:
#   all_gender  count  correct  accuracy
# 0          F    192      132     68.75
# 1          M    287      217     75.61
# 2          X    232      153     65.95

# %%
# Plot for Accuracy by Gender
styled_barplot(gender_stats, 'all_gender', 'accuracy', 
               'Accuracy by Gender', 
               'Gender', 'Accuracy (%)')

# %% [markdown]
# ### Log current total CV Stats

# %%
print("Total Majority Vote Accuracy so far:", all_majority_vote_accuracies)
print("Total Class Statistics so far:\n", all_class_stats)
print("Total Gender Accuracy so far:\n", all_gender_stats)
# Out:
# Total Majority Vote Accuracy so far: [0.7454545454545455, 0.7272727272727273, 0.7363636363636363, 0.7727272727272727]
# Total Class Statistics so far:
#  [  actual_age_group  total_count  correct_count   accuracy
# 0            adult          474            409  86.286920
# 1           kitten           91             50  54.945055
# 2           senior          149             44  29.530201,   actual_age_group  total_count  correct_count   accuracy
# 0            adult          473            400  84.566596
# 1           kitten           91             52  57.142857
# 2           senior          149             38  25.503356,   actual_age_group  total_count  correct_count   accuracy
# 0            adult          471            410  87.048832
# 1           kitten          112             59  52.678571
# 2           senior          149             43  28.859060,   actual_age_group  total_count  correct_count   accuracy
# 0            adult          471            408  86.624204
# 1           kitten           91             47  51.648352
# 2           senior          149             47  31.543624]
# Total Gender Accuracy so far:
#  [  all_gender  count  correct  accuracy
# 0          F    196      131     66.84
# 1          M    286      222     77.62
# 2          X    232      150     64.66,   all_gender  count  correct  accuracy
# 0          F    192      126     65.62
# 1          M    289      213     73.70
# 2          X    232      151     65.09,   all_gender  count  correct  accuracy
# 0          F    192      132     68.75
# 1          M    287      224     78.05
# 2          X    253      156     61.66,   all_gender  count  correct  accuracy
# 0          F    192      132     68.75
# 1          M    287      217     75.61
# 2          X    232      153     65.95]

# %% [markdown]
# # RANDOM SEED 5

# %%
# Set a fixed random seed for reproducibility
random.seed(int(random_seeds[4]))
np.random.seed(int(random_seeds[4]))
tf.random.set_seed(int(random_seeds[4]))

# Load datasets
dataframe = pd.read_csv('/Users/astrid/PycharmProjects/perch-2/scripts/perch_embeddings_april_10.csv')
augmented_df = pd.read_csv('/Users/astrid/PycharmProjects/perch-2/scripts/perch_embeddings_augmented_d3.csv')

dataframe.drop('mean_freq', axis=1, inplace=True)

augmented_df.drop('mean_freq', axis=1, inplace=True)
augmented_df.drop('gender', axis=1, inplace=True)

def assign_age_group(age, age_groups):
    for group_name, age_range in age_groups.items():
        if age_range[0] <= age < age_range[1]:
            return group_name
    return 'Unknown'  # For any age that doesn't fit the defined groups

# Define age groups
age_groups = {
    'kitten': (0, 0.5),
    'adult': (0.5, 12),
    'senior': (12, 20)
}

# Create a new column for the age group
dataframe['age_group'] = dataframe['target'].apply(assign_age_group, age_groups=age_groups)
augmented_df['age_group'] = augmented_df['target'].apply(assign_age_group, age_groups=age_groups)

print(dataframe['age_group'].value_counts())
print(augmented_df['age_group'].value_counts())
# Out:
# adult     509
# senior    149
# kitten    135
# Name: age_group, dtype: int64
# senior    900
# kitten    820
# adult     758
# Name: age_group, dtype: int64

# %%
# Separate features and labels
X = dataframe.iloc[:, :-4].values  # all columns except the last four

# Encode the 'age_group' column as integers using LabelEncoder
label_encoder = LabelEncoder()
encoded_y = label_encoder.fit_transform(dataframe['age_group'].values)

# Use the encoded labels for splitting and one-hot encoding
y = encoded_y  

# Convert 'cat_id' column to numpy array to be used as groups array for GroupKFold
groups = dataframe['cat_id'].values

# %%
tf.keras.backend.clear_session()

# %% [markdown]
# ## Run Setup

# %%
all_cat_ids = []
all_predicted_age_groups = []
all_actual_age_groups = []
all_gender = []

# Define the StratifiedGroupKFold splitter for 4 fold CV with random shuffling
outer_cv = StratifiedGroupKFold(n_splits=4, shuffle=True, random_state=int(random_seeds[4]))

# unseen test set metrics
unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1 = [], [], [], [], []

cv_training_acc_total = []
cv_training_acc_best = []

outer_fold = 0

# Use the splitter to generate indices for training and testing sets
# Note: GroupShuffleSplit.split returns indices, so we use it to index the arrays
for train_val_idx, test_idx in outer_cv.split(X, y, groups):
    outer_fold += 1
    logger(f"outer_fold {outer_fold}", file=log_file_path)

    # Convert indices back to DataFrame for easy manipulation
    df_train_val = dataframe.iloc[train_val_idx]
    df_test = dataframe.iloc[test_idx]

    ##############################
    # ASSESSING SPLITS BY CAT_ID #
    ##############################
    
    # Get the distribution of groups
    training_validation_group_distribution = df_train_val['cat_id'].value_counts()  
    testing_group_distribution = df_test['cat_id'].value_counts()  
    
    # Log or print the distribution
    logger(f"Train Set Group Distribution:\n{training_validation_group_distribution}", file=log_file_path)
    logger(f"Testing Set Group Distribution:\n{testing_group_distribution}", file=log_file_path)

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val['gender'].value_counts()
    testing_gender_distribution = df_test['gender'].value_counts()
    
    # Log the distribution
    logger(f"Training Set Gender Distribution BEFORE SWAP:\n{training_gender_distribution}", file=log_file_path)
    logger(f"Testing Set Gender Distribution BEFORE SWAP:\n{testing_gender_distribution}", file=log_file_path)

    # Group by 'age_group' and then list unique 'cat_id' within each age group
    unique_cat_ids_per_age_group_train_val = df_train_val.groupby('age_group')['cat_id'].unique()
    unique_cat_ids_per_age_group_test = df_test.groupby('age_group')['cat_id'].unique()
    
    # Log results
    logger(f"Unique Cat IDs per Age Group in Training/Validation Set:\n{unique_cat_ids_per_age_group_train_val}", file=log_file_path)
    logger(f"Unique Cat IDs per Age Group in Testing Set:\n{unique_cat_ids_per_age_group_test}", file=log_file_path)

    # Calculate the count of unique identifiers per age group for training and testing set
    counts_train_val = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_train_val.items()}
    counts_test = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_test.items()}

    # Log the counts of unique identifiers per age group
    logger(f"Count of Unique Cat IDs per Age Group in Training/Validation Set:\n{counts_train_val}", file=log_file_path)
    logger(f"Count of Unique Cat IDs per Age Group in Testing Set:\n{counts_test}", file=log_file_path)

    #######################################################
    # CONTINUE WITH ENSURING VALID AND APPROPRIATE SPLITS #
    #######################################################
    
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    groups_train_val, groups_test = groups[train_val_idx], groups[test_idx]

    # logging identifier splits 
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)

    # check group splits
    check_initial_group_split(groups_train_val, groups_test)

    # Specify the cat_ids that must be in the training/validation set
    specific_cat_ids = ['000A', '046A']
    
    # Perform the swapping operation
    train_val_idx, test_idx = swap_cat_id_instances(dataframe, train_val_idx, test_idx, specific_cat_ids)
    
    # Re-assign the sets based on the updated indices
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    new_groups_train_val, new_groups_test = groups[train_val_idx], groups[test_idx]

    # Find differences for training and test sets
    moved_to_train_val, removed_from_train_val = find_group_differences(groups_train_val, new_groups_train_val)
    moved_to_test, removed_from_test = find_group_differences(groups_test, new_groups_test)
    
    # Display the results
    logger(f"Moved to Training/Validation Set:\n{moved_to_train_val}", file=log_file_path)
    logger(f"Removed from Training/Validation Set:\n{removed_from_train_val}", file=log_file_path)
    logger(f"Moved to Test Set:\n{moved_to_test}", file=log_file_path)
    logger(f"Removed from Test Set\n{removed_from_test}", file=log_file_path)

    # Update X_train_val, X_test, y_train_val, y_test, groups_train_val, groups_test based on updated indices
    X_train_val = X[train_val_idx]
    y_train_val = y[train_val_idx]
    groups_train_val = groups[train_val_idx]
    
    X_test = X[test_idx]
    y_test = y[test_idx]
    groups_test = groups[test_idx]

    # logging identifier splits again after potential swaps
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"AFTER SWAP - Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"AFTER SWAP - Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)
    
    # Verify the lengths are consistent
    logger(f"Length of X_train_val:\n{len(X_train_val)}", file=log_file_path)
    logger(f"Length of y_train_val:\n{len(y_train_val)}", file=log_file_path)
    logger(f"Length of groups_train_val:\n{len(groups_train_val)}", file=log_file_path)

    # Check group splits once more
    check_initial_group_split(groups_train_val, groups_test)

    # Convert the modified indices back to a DataFrame representing the updated df_train_val
    df_train_val_updated = dataframe.iloc[train_val_idx].copy()
    df_test_updated = dataframe.iloc[test_idx].copy()

    ############################
    # LOGGING AGE GROUP SPLITS #
    ############################

    # Get the distribution of age groups of age groups before the update
    training_validation_age_group_distribution = df_train_val['age_group'].value_counts()
    testing_age_group_distribution = df_test['age_group'].value_counts()
    
    # Logthe distribution
    logger(f"Train Age Group Distribution BEFORE SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution BEFORE SWAP:\n{testing_age_group_distribution}", file=log_file_path)

    # Get the distribution of age groups after the update
    training_validation_age_group_distribution = df_train_val_updated['age_group'].value_counts()
    testing_age_group_distribution = df_test_updated['age_group'].value_counts()
    
    # Log the distribution
    logger(f"Train Age Group Distribution AFTER SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution AFTER SWAP:\n{testing_age_group_distribution}", file=log_file_path)
    
    ########################################################
    # TRACKING FINAL CAT_IDs & GENDER AFTER REDISTRIBUTION #
    ########################################################

    # Get the distribution of groups
    training_validation_group_distribution = df_train_val_updated['cat_id'].value_counts()  
    testing_group_distribution = df_test_updated['cat_id'].value_counts()  

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val_updated['gender'].value_counts()
    testing_gender_distribution = df_test_updated['gender'].value_counts()
    
    logger(f"\n Starting training on unseen test set\n", file=log_file_path)

    ######################
    # ADD AUGMENTED DATA #
    ######################

    # Filter out augmented data derived from groups in the training set
    augmented_df_filtered = augmented_df[augmented_df['cat_id'].isin(groups_train_val)]
    
    # Convert augmented_df_filtered to numpy array (excluding target and other columns)
    augmented_array = augmented_df_filtered.drop(columns=['target', 'cat_id', 'age_group']).values
    
    # Concatenate the filtered augmented data with X_train_val
    X_train_val = np.concatenate([X_train_val, augmented_array])

    # Extract target labels from the filtered augmented DataFrame
    y_augmented = augmented_df_filtered['age_group'].values
    
    # Encode the labels using the same LabelEncoder instance
    y_augmented_encoded = label_encoder.transform(y_augmented)
    
    # Concatenate the encoded augmented labels with y_train_val
    y_train_val = np.concatenate([y_train_val, y_augmented_encoded])

    # Calculate the distribution of age groups in y_train_val
    age_group_distribution = Counter(y_train_val)
    print("Age group distribution:", age_group_distribution)

    # EarlyStopping callback: monitor 'loss' instead of 'val_loss' for the test set
    early_stopping = EarlyStopping(
        monitor='loss',  
        min_delta=0.001, 
        patience=30,  
        verbose=1,  
        restore_best_weights=True  
    )

    accuracy_history = AccuracyHistory()

    # One final shuffle to ensure randomness
    outer_shuffle_idx = np.random.permutation(len(X_train_val))
    X_train_val = X_train_val[outer_shuffle_idx]
    y_train_val = y_train_val[outer_shuffle_idx]
    
    # Scale the features
    scaler_full = StandardScaler().fit(X_train_val)
    X_train_full_scaled = scaler_full.transform(X_train_val)
    X_test_scaled = scaler_full.transform(X_test)
    
    # Encode the labels
    y_train_full_encoded = to_categorical(y_train_val)
    y_test_encoded = to_categorical(y_test)

    #######################
    # BUILD & TRAIN MODEL #
    #######################

    optimizers = {
        'Adamax': Adamax(learning_rate=0.00510251984616472)
    }
    
    # Model definition with dynamic number of layers
    model_full = Sequential()
    model_full.add(Dense(480, activation='relu', input_shape=(X_train_full_scaled.shape[1],)))
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.2011047009431978))  
    model_full.add(Dense(256, activation='relu',)) 
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.14956886311951184))  
    model_full.add(Dense(256, activation='relu'))  
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.42291461228250665))  
    model_full.add(Dense(3, activation='softmax'))  
    
    # Use the optimizer from the parameters
    optimizer = optimizers['Adamax']  # optimizer_key from parameters
    
    # Compile the model
    model_full.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    
    # Train the model on the full training set
    history_full = model_full.fit(X_train_full_scaled, y_train_full_encoded, epochs=1500, batch_size=64,
                                  verbose=1, callbacks=[early_stopping, accuracy_history])
    
    # log epochs
    best_epoch_index = np.argmin(history_full.history['loss'])  
    best_training_accuracy = accuracy_history.acc[best_epoch_index]

    # Append training acc to total  
    all_best_training_acc.append(best_training_accuracy)
    total_training_acc.append(accuracy_history.acc)

    # Append training acc just for this CV
    cv_training_acc_total.append(accuracy_history.acc)
    cv_training_acc_best.append(best_training_accuracy)
    
    # Evaluate the model on the held-out test set
    test_loss, test_accuracy = model_full.evaluate(X_test_scaled, y_test_encoded)

    y_test_pred_prob = model_full.predict(X_test_scaled)
    y_test_pred = np.argmax(y_test_pred_prob, axis=1)  
    y_test_true = np.argmax(y_test_encoded, axis=1)    

    ################################
    # LOG MAJORITY VOTE PER CAT_ID #
    ################################

    # Convert numeric predictions back to age group labels
    predicted_age_groups = label_encoder.inverse_transform(y_test_pred)
    actual_labels = label_encoder.inverse_transform(y_test_true)
    
    # Map predictions and actual labels back to cat_ids
    test_results = pd.DataFrame({
        'cat_id': df_test_updated['cat_id'],
        'predicted_age_group': predicted_age_groups,
        'actual_age_group': actual_labels
    })
    
    # Group by cat_id and aggregate predicted age groups
    majority_votes = test_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
    actual_groups = test_results.groupby('cat_id')['actual_age_group'].first()
    
    # Calculate the accuracy of majority voting
    correct_predictions = (majority_votes == actual_groups).sum()
    total_cats = len(actual_groups)
    majority_vote_accuracy = correct_predictions / total_cats
    
    # Log the accuracy of the majority voting
    logger(f"Majority Vote Accuracy for cat_id for this fold: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

    ####################################################
    # COLLECT PREDICTIONS FOR GENDER & CAT_ID ANALYSIS #
    ####################################################

    # Debugging print statements
    print(f'Before appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Extend lists with current fold results
    all_cat_ids.extend(df_test_updated['cat_id'].tolist())
    all_predicted_age_groups.extend(predicted_age_groups)
    all_actual_age_groups.extend(actual_labels)
    all_gender.extend(df_test_updated['gender'].tolist())

    # Debugging print statements
    print(f'After appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Calculate additional metrics
    test_precision = precision_score(y_test_true, y_test_pred, average='macro')  # Use 'macro' for imbalanced datasets
    test_recall = recall_score(y_test_true, y_test_pred, average='macro')
    test_f1 = f1_score(y_test_true, y_test_pred, average='macro')

    # prepare averages of outer metrics
    unseen_f1.append(test_f1)
    unseen_losses.append(test_loss)
    unseen_accuracies.append(test_accuracy)
    unseen_precisions.append(test_precision)
    unseen_recalls.append(test_recall)

    # Print final test results
    logger(f"Final Test Results - Loss: {test_loss}, Accuracy: {test_accuracy}, Precision: {test_precision}, Recall: {test_recall}, F1 Score: {test_f1}", file=log_file_path)

    # Generate the confusion matrix
    cm = confusion_matrix(y_test, y_test_pred)
    logger(f"Confusion Matrix:\n {cm}", file=log_file_path)

# Calculate the overall average metrics
unseen_set_avg_f1 = np.mean(unseen_f1)
unseen_set_avg_loss = np.mean(unseen_losses)
unseen_set_avg_acc = np.mean(unseen_accuracies)
unseen_set_avg_precision = np.mean(unseen_precisions)
unseen_set_avg_recall = np.mean(unseen_recalls)

logger(f"\nFinal Average F1-Score across all UNSEEN TEST sets: {unseen_set_avg_f1}", file=log_file_path)
logger(f"\nFinal Average Loss across all UNSEEN TEST sets: {unseen_set_avg_loss}", file=log_file_path)
logger(f"\nFinal Average Accuracy across all UNSEEN TEST sets: {unseen_set_avg_acc}", file=log_file_path)
logger(f"\nFinal Average Precision across all UNSEEN TEST sets: {unseen_set_avg_precision}", file=log_file_path)
logger(f"\nFinal Average Recall across all UNSEEN TEST sets: {unseen_set_avg_recall}\n", file=log_file_path)

# Append averages to total lists
average_fold_f1.append(unseen_set_avg_f1)
average_fold_losses.append(unseen_set_avg_loss)
average_fold_accuracies.append(unseen_set_avg_acc)
average_fold_precisions.append(unseen_set_avg_precision)
average_fold_recalls.append(unseen_set_avg_recall)

# Append all to total lists
all_f1.append(unseen_f1)
all_losses.append(unseen_losses)
all_accuracies.append(unseen_accuracies)
all_precisions.append(unseen_precisions)
all_recalls.append(unseen_recalls)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# outer_fold 1
# Train Set Group Distribution:
# 046A    45
# 103A    33
# 002B    30
# 020A    20
# 019A    17
# 057A    17
# 074A    16
# 097A    15
# 029A    15
# 097B    14
# 106A    13
# 002A    13
# 051A    12
# 055A    12
# 111A    12
# 116A    12
# 063A    11
# 028A    11
# 067A    11
# 014B    10
# 059A    10
# 025A    10
# 065A     9
# 005A     9
# 071A     9
# 033A     9
# 001A     9
# 013B     8
# 068A     8
# 117A     7
# 095A     7
# 027A     7
# 031A     7
# 036A     7
# 039A     6
# 007A     6
# 050A     5
# 094A     5
# 108A     5
# 008A     5
# 075A     5
# 021A     5
# 044A     5
# 109A     5
# 104A     4
# 003A     4
# 025C     4
# 026A     4
# 009A     4
# 045A     4
# 023B     4
# 060A     3
# 056A     3
# 014A     3
# 012A     3
# 105A     3
# 053A     3
# 061A     2
# 037A     2
# 093A     2
# 054A     2
# 035A     2
# 025B     2
# 011A     2
# 038A     2
# 087A     2
# 069A     2
# 032A     2
# 110A     1
# 090A     1
# 019B     1
# 004A     1
# 100A     1
# 049A     1
# 048A     1
# 026C     1
# 041A     1
# 092A     1
# 096A     1
# 064A     1
# 091A     1
# 073A     1
# 043A     1
# 026B     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 000A    39
# 047A    22
# 000B    19
# 101A    12
# 042A    11
# 040A    10
# 051B     9
# 072A     9
# 016A     9
# 022A     9
# 015A     7
# 023A     6
# 099A     6
# 070A     5
# 058A     3
# 010A     3
# 006A     3
# 113A     3
# 034A     3
# 062A     3
# 018A     2
# 052A     2
# 102A     2
# 076A     1
# 066A     1
# 088A     1
# 115A     1
# 024A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    241
# X    214
# F    136
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# F    95
# X    62
# M    45
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [033A, 001A, 103A, 071A, 097B, 028A, 019A, 074...
# kitten    [044A, 014B, 111A, 046A, 109A, 050A, 043A, 049...
# senior    [093A, 097A, 057A, 106A, 104A, 055A, 059A, 116...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [006A, 000A, 015A, 062A, 101A, 022A, 034A, 072...
# kitten                             [040A, 047A, 042A, 115A]
# senior                       [113A, 051B, 058A, 016A, 024A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 55, 'kitten': 12, 'senior': 17}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 19, 'kitten': 4, 'senior': 5}
# Unique Training/Validation Group IDs:
# ['001A' '002A' '002B' '003A' '004A' '005A' '007A' '008A' '009A' '011A'
#  '012A' '013B' '014A' '014B' '019A' '019B' '020A' '021A' '023B' '025A'
#  '025B' '025C' '026A' '026B' '026C' '027A' '028A' '029A' '031A' '032A'
#  '033A' '035A' '036A' '037A' '038A' '039A' '041A' '043A' '044A' '045A'
#  '046A' '048A' '049A' '050A' '051A' '053A' '054A' '055A' '056A' '057A'
#  '059A' '060A' '061A' '063A' '064A' '065A' '067A' '068A' '069A' '071A'
#  '073A' '074A' '075A' '087A' '090A' '091A' '092A' '093A' '094A' '095A'
#  '096A' '097A' '097B' '100A' '103A' '104A' '105A' '106A' '108A' '109A'
#  '110A' '111A' '116A' '117A']
# Unique Test Group IDs:
# ['000A' '000B' '006A' '010A' '015A' '016A' '018A' '022A' '023A' '024A'
#  '034A' '040A' '042A' '047A' '051B' '052A' '058A' '062A' '066A' '070A'
#  '072A' '076A' '088A' '099A' '101A' '102A' '113A' '115A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'000A'}
# Removed from Training/Validation Set:
# {'096A'}
# Moved to Test Set:
# {'096A'}
# Removed from Test Set
# {'000A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '001A' '002A' '002B' '003A' '004A' '005A' '007A' '008A' '009A'
#  '011A' '012A' '013B' '014A' '014B' '019A' '019B' '020A' '021A' '023B'
#  '025A' '025B' '025C' '026A' '026B' '026C' '027A' '028A' '029A' '031A'
#  '032A' '033A' '035A' '036A' '037A' '038A' '039A' '041A' '043A' '044A'
#  '045A' '046A' '048A' '049A' '050A' '051A' '053A' '054A' '055A' '056A'
#  '057A' '059A' '060A' '061A' '063A' '064A' '065A' '067A' '068A' '069A'
#  '071A' '073A' '074A' '075A' '087A' '090A' '091A' '092A' '093A' '094A'
#  '095A' '097A' '097B' '100A' '103A' '104A' '105A' '106A' '108A' '109A'
#  '110A' '111A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['000B' '006A' '010A' '015A' '016A' '018A' '022A' '023A' '024A' '034A'
#  '040A' '042A' '047A' '051B' '052A' '058A' '062A' '066A' '070A' '072A'
#  '076A' '088A' '096A' '099A' '101A' '102A' '113A' '115A']
# Length of X_train_val:
# 629
# Length of y_train_val:
# 629
# Length of groups_train_val:
# 629
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     376
# senior    124
# kitten     91
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     133
# kitten     44
# senior     25
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     414
# senior    124
# kitten     91
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     95
# kitten    44
# senior    25
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 1024, 2: 900, 1: 611})
# Epoch 1/1500
# 40/40 [==============================] - 1s 5ms/step - loss: 0.4682 - accuracy: 0.8347
# Epoch 2/1500
# 40/40 [==============================] - 0s 5ms/step - loss: 0.1030 - accuracy: 0.9645
# Epoch 3/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0457 - accuracy: 0.9830
# Epoch 4/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0290 - accuracy: 0.9905
# Epoch 5/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0172 - accuracy: 0.9941
# Epoch 6/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0132 - accuracy: 0.9972
# Epoch 7/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0102 - accuracy: 0.9968
# Epoch 8/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0082 - accuracy: 0.9972
# Epoch 9/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0083 - accuracy: 0.9976
# Epoch 10/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0158 - accuracy: 0.9953
# Epoch 11/1500
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0062 - accuracy: 0.9992
# Epoch 12/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0037 - accuracy: 0.9992
# Epoch 13/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0063 - accuracy: 0.9976
# Epoch 14/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0062 - accuracy: 0.9980
# Epoch 15/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0042 - accuracy: 0.9984
# Epoch 16/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0092 - accuracy: 0.9984
# Epoch 17/1500
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0058 - accuracy: 0.9984
# Epoch 18/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0083 - accuracy: 0.9980
# Epoch 19/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0022 - accuracy: 0.9996
# Epoch 20/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 9.1000e-04 - accuracy: 1.0000
# Epoch 21/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0077 - accuracy: 0.9996
# Epoch 22/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0028 - accuracy: 0.9992
# Epoch 23/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0038 - accuracy: 0.9988
# Epoch 24/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0022 - accuracy: 0.9996
# Epoch 25/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0052 - accuracy: 0.9992
# Epoch 26/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0026 - accuracy: 0.9988
# Epoch 27/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0020 - accuracy: 0.9996
# Epoch 28/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0014 - accuracy: 0.9992
# Epoch 29/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0043 - accuracy: 0.9988
# Epoch 30/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0067 - accuracy: 0.9976
# Epoch 31/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0073 - accuracy: 0.9972
# Epoch 32/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0028 - accuracy: 0.9992
# Epoch 33/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0065 - accuracy: 0.9972
# Epoch 34/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0043 - accuracy: 0.9988
# Epoch 35/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0032 - accuracy: 0.9992
# Epoch 36/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0049 - accuracy: 0.9984
# Epoch 37/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0014 - accuracy: 0.9996
# Epoch 38/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0060 - accuracy: 0.9996
# Epoch 39/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 40/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0079 - accuracy: 0.9984
# Epoch 41/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0052 - accuracy: 0.9992
# Epoch 42/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0043 - accuracy: 0.9980
# Epoch 43/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0049 - accuracy: 0.9984
# Epoch 44/1500
# 40/40 [==============================] - 0s 9ms/step - loss: 0.0046 - accuracy: 0.9984
# Epoch 45/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0038 - accuracy: 0.9988
# Epoch 46/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0103 - accuracy: 0.9968
# Epoch 47/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0191 - accuracy: 0.9933
# Epoch 48/1500
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0049 - accuracy: 0.9980
# Epoch 49/1500
# 40/40 [==============================] - 0s 7ms/step - loss: 0.0037 - accuracy: 0.9984
# Epoch 50/1500
# 36/40 [==========================>...] - ETA: 0s - loss: 0.0020 - accuracy: 0.9996Restoring model weights from the end of the best epoch: 20.
# 40/40 [==============================] - 0s 6ms/step - loss: 0.0022 - accuracy: 0.9992
# Epoch 50: early stopping
# 6/6 [==============================] - 0s 2ms/step - loss: 3.0271 - accuracy: 0.6585
# 6/6 [==============================] - 0s 2ms/step
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Majority Vote Accuracy for cat_id for this fold: 0.82 (23/28)
# Before appending - Cat IDs: 0, Predictions: 0, Actuals: 0, Gender: 0
# After appending - Cat IDs: 164, Predictions: 164, Actuals: 164, Gender: 164
# Final Test Results - Loss: 3.0271451473236084, Accuracy: 0.6585366129875183, Precision: 0.7183312173790379, Recall: 0.49076555023923446, F1 Score: 0.5168498775056153
# Confusion Matrix:
#  [[89  4  2]
#  [31 13  0]
#  [19  0  6]]
# outer_fold 2
# Train Set Group Distribution:
# 046A    45
# 000A    39
# 002B    30
# 047A    22
# 020A    20
# 000B    19
# 019A    17
# 029A    15
# 002A    13
# 101A    12
# 055A    12
# 067A    11
# 028A    11
# 063A    11
# 042A    11
# 040A    10
# 059A    10
# 072A     9
# 016A     9
# 065A     9
# 051B     9
# 071A     9
# 001A     9
# 005A     9
# 022A     9
# 013B     8
# 068A     8
# 036A     7
# 117A     7
# 015A     7
# 027A     7
# 095A     7
# 099A     6
# 007A     6
# 023A     6
# 039A     6
# 108A     5
# 075A     5
# 070A     5
# 109A     5
# 050A     5
# 026A     4
# 104A     4
# 025C     4
# 023B     4
# 058A     3
# 010A     3
# 053A     3
# 060A     3
# 006A     3
# 105A     3
# 062A     3
# 034A     3
# 113A     3
# 014A     3
# 018A     2
# 037A     2
# 011A     2
# 102A     2
# 052A     2
# 061A     2
# 087A     2
# 093A     2
# 054A     2
# 115A     1
# 019B     1
# 100A     1
# 090A     1
# 024A     1
# 110A     1
# 066A     1
# 088A     1
# 004A     1
# 048A     1
# 041A     1
# 092A     1
# 049A     1
# 064A     1
# 043A     1
# 076A     1
# 096A     1
# 026B     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 103A    33
# 057A    17
# 074A    16
# 097A    15
# 097B    14
# 106A    13
# 111A    12
# 051A    12
# 116A    12
# 014B    10
# 025A    10
# 033A     9
# 031A     7
# 044A     5
# 021A     5
# 094A     5
# 008A     5
# 045A     4
# 003A     4
# 009A     4
# 012A     3
# 056A     3
# 035A     2
# 032A     2
# 069A     2
# 038A     2
# 025B     2
# 073A     1
# 026C     1
# 091A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    192
# X    189
# F    181
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# M    94
# X    87
# F    50
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [006A, 000A, 015A, 001A, 071A, 028A, 019A, 067...
# kitten    [040A, 046A, 047A, 042A, 109A, 050A, 043A, 049...
# senior    [093A, 104A, 055A, 059A, 113A, 051B, 054A, 117...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [033A, 103A, 097B, 074A, 091A, 009A, 038A, 025...
# kitten                             [044A, 014B, 111A, 045A]
# senior           [097A, 057A, 106A, 116A, 056A, 051A, 094A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 55, 'kitten': 12, 'senior': 15}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 19, 'kitten': 4, 'senior': 7}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '004A' '005A' '006A' '007A' '010A'
#  '011A' '013B' '014A' '015A' '016A' '018A' '019A' '019B' '020A' '022A'
#  '023A' '023B' '024A' '025C' '026A' '026B' '027A' '028A' '029A' '034A'
#  '036A' '037A' '039A' '040A' '041A' '042A' '043A' '046A' '047A' '048A'
#  '049A' '050A' '051B' '052A' '053A' '054A' '055A' '058A' '059A' '060A'
#  '061A' '062A' '063A' '064A' '065A' '066A' '067A' '068A' '070A' '071A'
#  '072A' '075A' '076A' '087A' '088A' '090A' '092A' '093A' '095A' '096A'
#  '099A' '100A' '101A' '102A' '104A' '105A' '108A' '109A' '110A' '113A'
#  '115A' '117A']
# Unique Test Group IDs:
# ['003A' '008A' '009A' '012A' '014B' '021A' '025A' '025B' '026C' '031A'
#  '032A' '033A' '035A' '038A' '044A' '045A' '051A' '056A' '057A' '069A'
#  '073A' '074A' '091A' '094A' '097A' '097B' '103A' '106A' '111A' '116A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '004A' '005A' '006A' '007A' '010A'
#  '011A' '013B' '014A' '015A' '016A' '018A' '019A' '019B' '020A' '022A'
#  '023A' '023B' '024A' '025C' '026A' '026B' '027A' '028A' '029A' '034A'
#  '036A' '037A' '039A' '040A' '041A' '042A' '043A' '046A' '047A' '048A'
#  '049A' '050A' '051B' '052A' '053A' '054A' '055A' '058A' '059A' '060A'
#  '061A' '062A' '063A' '064A' '065A' '066A' '067A' '068A' '070A' '071A'
#  '072A' '075A' '076A' '087A' '088A' '090A' '092A' '093A' '095A' '096A'
#  '099A' '100A' '101A' '102A' '104A' '105A' '108A' '109A' '110A' '113A'
#  '115A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['003A' '008A' '009A' '012A' '014B' '021A' '025A' '025B' '026C' '031A'
#  '032A' '033A' '035A' '038A' '044A' '045A' '051A' '056A' '057A' '069A'
#  '073A' '074A' '091A' '094A' '097A' '097B' '103A' '106A' '111A' '116A']
# Length of X_train_val:
# 562
# Length of y_train_val:
# 562
# Length of groups_train_val:
# 562
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     386
# kitten    104
# senior     72
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     123
# senior     77
# kitten     31
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     386
# kitten    104
# senior     72
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     123
# senior     77
# kitten     31
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 963, 1: 748, 2: 508})
# Epoch 1/1500
# 35/35 [==============================] - 1s 5ms/step - loss: 0.4587 - accuracy: 0.8463
# Epoch 2/1500
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0994 - accuracy: 0.9644
# Epoch 3/1500
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0373 - accuracy: 0.9887
# Epoch 4/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0227 - accuracy: 0.9923
# Epoch 5/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0122 - accuracy: 0.9959
# Epoch 6/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0129 - accuracy: 0.9955
# Epoch 7/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0072 - accuracy: 0.9986
# Epoch 8/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0086 - accuracy: 0.9977
# Epoch 9/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0083 - accuracy: 0.9968
# Epoch 10/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0061 - accuracy: 0.9986
# Epoch 11/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0047 - accuracy: 0.9982
# Epoch 12/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0046 - accuracy: 0.9991
# Epoch 13/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0027 - accuracy: 0.9995
# Epoch 14/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0027 - accuracy: 0.9991
# Epoch 15/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0026 - accuracy: 0.9995
# Epoch 16/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0048 - accuracy: 0.9982
# Epoch 17/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 18/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0029 - accuracy: 0.9991
# Epoch 19/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 20/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0024 - accuracy: 0.9995
# Epoch 21/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0097 - accuracy: 0.9968
# Epoch 22/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0029 - accuracy: 0.9995
# Epoch 23/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0044 - accuracy: 0.9991
# Epoch 24/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0034 - accuracy: 0.9995
# Epoch 25/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 26/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 27/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0023 - accuracy: 0.9991
# Epoch 28/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0022 - accuracy: 0.9986
# Epoch 29/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0030 - accuracy: 0.9982
# Epoch 30/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 31/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0061 - accuracy: 0.9968
# Epoch 32/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0044 - accuracy: 0.9995
# Epoch 33/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0027 - accuracy: 0.9995
# Epoch 34/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0012 - accuracy: 0.9995
# Epoch 35/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0020 - accuracy: 0.9991
# Epoch 36/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0057 - accuracy: 0.9977
# Epoch 37/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0062 - accuracy: 0.9986
# Epoch 38/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0124 - accuracy: 0.9959
# Epoch 39/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0036 - accuracy: 0.9991
# Epoch 40/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0040 - accuracy: 0.9991
# Epoch 41/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0108 - accuracy: 0.9968
# Epoch 42/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0057 - accuracy: 0.9986
# Epoch 43/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0063 - accuracy: 0.9986
# Epoch 44/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0068 - accuracy: 0.9973
# Epoch 45/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0085 - accuracy: 0.9982
# Epoch 46/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0074 - accuracy: 0.9973
# Epoch 47/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0028 - accuracy: 0.9995
# Epoch 48/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0033 - accuracy: 0.9991
# Epoch 49/1500
# 27/35 [======================>.......] - ETA: 0s - loss: 0.0044 - accuracy: 0.9983Restoring model weights from the end of the best epoch: 19.
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0041 - accuracy: 0.9986
# Epoch 49: early stopping
# 8/8 [==============================] - 0s 2ms/step - loss: 2.1264 - accuracy: 0.6840
# 8/8 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.73 (22/30)
# Before appending - Cat IDs: 164, Predictions: 164, Actuals: 164, Gender: 164
# After appending - Cat IDs: 395, Predictions: 395, Actuals: 395, Gender: 395
# Final Test Results - Loss: 2.126350164413452, Accuracy: 0.6839826703071594, Precision: 0.7818104062722737, Recall: 0.6166123412386196, F1 Score: 0.6332607116920842
# Confusion Matrix:
#  [[117   4   2]
#  [ 11  19   1]
#  [ 55   0  22]]
# outer_fold 3
# Train Set Group Distribution:
# 000A    39
# 103A    33
# 047A    22
# 000B    19
# 057A    17
# 074A    16
# 029A    15
# 097A    15
# 097B    14
# 002A    13
# 106A    13
# 101A    12
# 055A    12
# 051A    12
# 111A    12
# 116A    12
# 028A    11
# 067A    11
# 042A    11
# 025A    10
# 059A    10
# 040A    10
# 014B    10
# 016A     9
# 072A     9
# 051B     9
# 033A     9
# 001A     9
# 065A     9
# 022A     9
# 013B     8
# 031A     7
# 015A     7
# 007A     6
# 099A     6
# 023A     6
# 039A     6
# 094A     5
# 008A     5
# 050A     5
# 070A     5
# 021A     5
# 044A     5
# 109A     5
# 003A     4
# 026A     4
# 023B     4
# 009A     4
# 104A     4
# 045A     4
# 056A     3
# 058A     3
# 012A     3
# 006A     3
# 105A     3
# 113A     3
# 010A     3
# 034A     3
# 062A     3
# 035A     2
# 061A     2
# 102A     2
# 052A     2
# 025B     2
# 032A     2
# 038A     2
# 018A     2
# 069A     2
# 054A     2
# 064A     1
# 088A     1
# 090A     1
# 091A     1
# 110A     1
# 115A     1
# 004A     1
# 049A     1
# 066A     1
# 076A     1
# 026C     1
# 043A     1
# 073A     1
# 092A     1
# 024A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 046A    45
# 002B    30
# 020A    20
# 019A    17
# 063A    11
# 071A     9
# 005A     9
# 068A     8
# 117A     7
# 095A     7
# 027A     7
# 036A     7
# 075A     5
# 108A     5
# 025C     4
# 053A     3
# 060A     3
# 014A     3
# 011A     2
# 037A     2
# 093A     2
# 087A     2
# 041A     1
# 048A     1
# 096A     1
# 019B     1
# 100A     1
# 026B     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# F    208
# M    200
# X    171
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    105
# M     86
# F     23
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [006A, 000A, 033A, 015A, 001A, 103A, 097B, 028...
# kitten    [044A, 014B, 111A, 040A, 047A, 042A, 109A, 050...
# senior    [097A, 057A, 106A, 104A, 055A, 059A, 113A, 116...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [071A, 019A, 020A, 002B, 095A, 005A, 063A, 027...
# kitten                                   [046A, 041A, 048A]
# senior                             [093A, 117A, 108A, 011A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 53, 'kitten': 13, 'senior': 18}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 21, 'kitten': 3, 'senior': 4}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '003A' '004A' '006A' '007A' '008A' '009A'
#  '010A' '012A' '013B' '014B' '015A' '016A' '018A' '021A' '022A' '023A'
#  '023B' '024A' '025A' '025B' '026A' '026C' '028A' '029A' '031A' '032A'
#  '033A' '034A' '035A' '038A' '039A' '040A' '042A' '043A' '044A' '045A'
#  '047A' '049A' '050A' '051A' '051B' '052A' '054A' '055A' '056A' '057A'
#  '058A' '059A' '061A' '062A' '064A' '065A' '066A' '067A' '069A' '070A'
#  '072A' '073A' '074A' '076A' '088A' '090A' '091A' '092A' '094A' '097A'
#  '097B' '099A' '101A' '102A' '103A' '104A' '105A' '106A' '109A' '110A'
#  '111A' '113A' '115A' '116A']
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Unique Test Group IDs:
# ['002B' '005A' '011A' '014A' '019A' '019B' '020A' '025C' '026B' '027A'
#  '036A' '037A' '041A' '046A' '048A' '053A' '060A' '063A' '068A' '071A'
#  '075A' '087A' '093A' '095A' '096A' '100A' '108A' '117A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'046A'}
# Removed from Training/Validation Set:
# {'115A'}
# Moved to Test Set:
# {'115A'}
# Removed from Test Set
# {'046A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '003A' '004A' '006A' '007A' '008A' '009A'
#  '010A' '012A' '013B' '014B' '015A' '016A' '018A' '021A' '022A' '023A'
#  '023B' '024A' '025A' '025B' '026A' '026C' '028A' '029A' '031A' '032A'
#  '033A' '034A' '035A' '038A' '039A' '040A' '042A' '043A' '044A' '045A'
#  '046A' '047A' '049A' '050A' '051A' '051B' '052A' '054A' '055A' '056A'
#  '057A' '058A' '059A' '061A' '062A' '064A' '065A' '066A' '067A' '069A'
#  '070A' '072A' '073A' '074A' '076A' '088A' '090A' '091A' '092A' '094A'
#  '097A' '097B' '099A' '101A' '102A' '103A' '104A' '105A' '106A' '109A'
#  '110A' '111A' '113A' '116A']
# AFTER SWAP - Unique Test Group IDs:
# ['002B' '005A' '011A' '014A' '019A' '019B' '020A' '025C' '026B' '027A'
#  '036A' '037A' '041A' '048A' '053A' '060A' '063A' '068A' '071A' '075A'
#  '087A' '093A' '095A' '096A' '100A' '108A' '115A' '117A']
# Length of X_train_val:
# 623
# Length of y_train_val:
# 623
# Length of groups_train_val:
# 623
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     358
# senior    133
# kitten     88
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     151
# kitten     47
# senior     16
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     358
# senior    133
# kitten    132
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     151
# senior     16
# kitten      3
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({2: 941, 1: 936, 0: 897})
# Epoch 1/1500
# 44/44 [==============================] - 1s 5ms/step - loss: 0.4631 - accuracy: 0.8446
# Epoch 2/1500
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0989 - accuracy: 0.9647
# Epoch 3/1500
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0558 - accuracy: 0.9809
# Epoch 4/1500
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0271 - accuracy: 0.9928
# Epoch 5/1500
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0162 - accuracy: 0.9942
# Epoch 6/1500
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0215 - accuracy: 0.9946
# Epoch 7/1500
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0170 - accuracy: 0.9957
# Epoch 8/1500
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0121 - accuracy: 0.9964
# Epoch 9/1500
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0067 - accuracy: 0.9986
# Epoch 10/1500
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0062 - accuracy: 0.9989
# Epoch 11/1500
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0046 - accuracy: 0.9989
# Epoch 12/1500
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0055 - accuracy: 0.9993
# Epoch 13/1500
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0033 - accuracy: 0.9993
# Epoch 14/1500
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0044 - accuracy: 0.9986
# Epoch 15/1500
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0072 - accuracy: 0.9982
# Epoch 16/1500
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0081 - accuracy: 0.9975
# Epoch 17/1500
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0100 - accuracy: 0.9968
# Epoch 18/1500
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0094 - accuracy: 0.9960
# Epoch 19/1500
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0049 - accuracy: 0.9989
# Epoch 20/1500
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0062 - accuracy: 0.9978
# Epoch 21/1500
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0111 - accuracy: 0.9971
# Epoch 22/1500
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0148 - accuracy: 0.9964
# Epoch 23/1500
# 44/44 [==============================] - 0s 7ms/step - loss: 0.0101 - accuracy: 0.9971
# Epoch 24/1500
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0027 - accuracy: 0.9993
# Epoch 25/1500
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0022 - accuracy: 0.9996
# Epoch 26/1500
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0033 - accuracy: 0.9993
# Epoch 27/1500
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 28/1500
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0028 - accuracy: 0.9986
# Epoch 29/1500
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0034 - accuracy: 0.9996
# Epoch 30/1500
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0016 - accuracy: 0.9996
# Epoch 31/1500
# 44/44 [==============================] - 1s 16ms/step - loss: 0.0016 - accuracy: 0.9996
# Epoch 32/1500
# 44/44 [==============================] - 0s 6ms/step - loss: 9.2012e-04 - accuracy: 1.0000
# Epoch 33/1500
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0016 - accuracy: 0.9996
# Epoch 34/1500
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0021 - accuracy: 0.9996
# Epoch 35/1500
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0065 - accuracy: 0.9975
# Epoch 36/1500
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0052 - accuracy: 0.9989
# Epoch 37/1500
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0017 - accuracy: 0.9996
# Epoch 38/1500
# 44/44 [==============================] - 0s 7ms/step - loss: 0.0077 - accuracy: 0.9978
# Epoch 39/1500
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0058 - accuracy: 0.9982
# Epoch 40/1500
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0026 - accuracy: 0.9989
# Epoch 41/1500
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0058 - accuracy: 0.9971
# Epoch 42/1500
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0082 - accuracy: 0.9964
# Epoch 43/1500
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 44/1500
# 44/44 [==============================] - 0s 7ms/step - loss: 0.0030 - accuracy: 0.9989
# Epoch 45/1500
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0040 - accuracy: 0.9986
# Epoch 46/1500
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0014 - accuracy: 0.9996
# Epoch 47/1500
# 44/44 [==============================] - 0s 6ms/step - loss: 9.3105e-04 - accuracy: 0.9996
# Epoch 48/1500
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0031 - accuracy: 0.9986
# Epoch 49/1500
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0056 - accuracy: 0.9986
# Epoch 50/1500
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0089 - accuracy: 0.9975
# Epoch 51/1500
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0122 - accuracy: 0.9939
# Epoch 52/1500
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0102 - accuracy: 0.9975
# Epoch 53/1500
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0055 - accuracy: 0.9986
# Epoch 54/1500
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0018 - accuracy: 0.9993
# Epoch 55/1500
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0079 - accuracy: 0.9975
# Epoch 56/1500
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0016 - accuracy: 0.9996
# Epoch 57/1500
# 35/44 [======================>.......] - ETA: 0s - loss: 0.0012 - accuracy: 0.9991Restoring model weights from the end of the best epoch: 27.
# 44/44 [==============================] - 0s 6ms/step - loss: 0.0019 - accuracy: 0.9989
# Epoch 57: early stopping
# 6/6 [==============================] - 0s 1ms/step - loss: 1.6421 - accuracy: 0.7647
# 6/6 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.75 (21/28)
# Before appending - Cat IDs: 395, Predictions: 395, Actuals: 395, Gender: 395
# After appending - Cat IDs: 565, Predictions: 565, Actuals: 565, Gender: 565
# Final Test Results - Loss: 1.6420984268188477, Accuracy: 0.7647058963775635, Precision: 0.5041771094402673, Recall: 0.7068156732891833, F1 Score: 0.5588487446417636
# Confusion Matrix:
#  [[122   4  25]
#  [  0   3   0]
#  [ 11   0   5]]
# outer_fold 4
# Train Set Group Distribution:
# 046A    45
# 000A    39
# 103A    33
# 002B    30
# 047A    22
# 020A    20
# 000B    19
# 057A    17
# 019A    17
# 074A    16
# 097A    15
# 097B    14
# 106A    13
# 101A    12
# 051A    12
# 116A    12
# 111A    12
# 042A    11
# 063A    11
# 040A    10
# 014B    10
# 025A    10
# 071A     9
# 022A     9
# 033A     9
# 051B     9
# 005A     9
# 072A     9
# 016A     9
# 068A     8
# 117A     7
# 031A     7
# 036A     7
# 095A     7
# 015A     7
# 027A     7
# 099A     6
# 023A     6
# 070A     5
# 044A     5
# 094A     5
# 075A     5
# 008A     5
# 021A     5
# 108A     5
# 045A     4
# 025C     4
# 003A     4
# 009A     4
# 053A     3
# 056A     3
# 058A     3
# 010A     3
# 060A     3
# 012A     3
# 006A     3
# 062A     3
# 113A     3
# 014A     3
# 034A     3
# 052A     2
# 093A     2
# 025B     2
# 037A     2
# 102A     2
# 011A     2
# 035A     2
# 018A     2
# 069A     2
# 038A     2
# 032A     2
# 087A     2
# 026C     1
# 024A     1
# 100A     1
# 076A     1
# 115A     1
# 073A     1
# 019B     1
# 091A     1
# 088A     1
# 048A     1
# 066A     1
# 041A     1
# 096A     1
# 026B     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 029A    15
# 002A    13
# 055A    12
# 067A    11
# 028A    11
# 059A    10
# 001A     9
# 065A     9
# 013B     8
# 039A     6
# 007A     6
# 109A     5
# 050A     5
# 023B     4
# 104A     4
# 026A     4
# 105A     3
# 061A     2
# 054A     2
# 064A     1
# 049A     1
# 092A     1
# 004A     1
# 043A     1
# 110A     1
# 090A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    254
# M    225
# F    168
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# F    63
# M    61
# X    22
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [006A, 000A, 033A, 015A, 103A, 071A, 097B, 019...
# kitten    [044A, 014B, 111A, 040A, 046A, 047A, 042A, 041...
# senior    [093A, 097A, 057A, 106A, 113A, 116A, 051B, 117...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [001A, 028A, 067A, 029A, 065A, 002A, 039A, 013...
# kitten                       [109A, 050A, 043A, 049A, 110A]
# senior                 [104A, 055A, 059A, 054A, 061A, 090A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 59, 'kitten': 11, 'senior': 16}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 15, 'kitten': 5, 'senior': 6}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '002B' '003A' '005A' '006A' '008A' '009A' '010A' '011A'
#  '012A' '014A' '014B' '015A' '016A' '018A' '019A' '019B' '020A' '021A'
#  '022A' '023A' '024A' '025A' '025B' '025C' '026B' '026C' '027A' '031A'
#  '032A' '033A' '034A' '035A' '036A' '037A' '038A' '040A' '041A' '042A'
#  '044A' '045A' '046A' '047A' '048A' '051A' '051B' '052A' '053A' '056A'
#  '057A' '058A' '060A' '062A' '063A' '066A' '068A' '069A' '070A' '071A'
#  '072A' '073A' '074A' '075A' '076A' '087A' '088A' '091A' '093A' '094A'
#  '095A' '096A' '097A' '097B' '099A' '100A' '101A' '102A' '103A' '106A'
#  '108A' '111A' '113A' '115A' '116A' '117A']
# Unique Test Group IDs:
# ['001A' '002A' '004A' '007A' '013B' '023B' '026A' '028A' '029A' '039A'
#  '043A' '049A' '050A' '054A' '055A' '059A' '061A' '064A' '065A' '067A'
#  '090A' '092A' '104A' '105A' '109A' '110A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '002B' '003A' '005A' '006A' '008A' '009A' '010A' '011A'
#  '012A' '014A' '014B' '015A' '016A' '018A' '019A' '019B' '020A' '021A'
#  '022A' '023A' '024A' '025A' '025B' '025C' '026B' '026C' '027A' '031A'
#  '032A' '033A' '034A' '035A' '036A' '037A' '038A' '040A' '041A' '042A'
#  '044A' '045A' '046A' '047A' '048A' '051A' '051B' '052A' '053A' '056A'
#  '057A' '058A' '060A' '062A' '063A' '066A' '068A' '069A' '070A' '071A'
#  '072A' '073A' '074A' '075A' '076A' '087A' '088A' '091A' '093A' '094A'
#  '095A' '096A' '097A' '097B' '099A' '100A' '101A' '102A' '103A' '106A'
#  '108A' '111A' '113A' '115A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['001A' '002A' '004A' '007A' '013B' '023B' '026A' '028A' '029A' '039A'
#  '043A' '049A' '050A' '054A' '055A' '059A' '061A' '064A' '065A' '067A'
#  '090A' '092A' '104A' '105A' '109A' '110A']
# Length of X_train_val:
# 647
# Length of y_train_val:
# 647
# Length of groups_train_val:
# 647
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     407
# kitten    122
# senior    118
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     102
# senior     31
# kitten     13
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     407
# kitten    122
# senior    118
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     102
# senior     31
# kitten     13
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 998, 1: 870, 2: 798})
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Epoch 1/1500
# 42/42 [==============================] - 1s 5ms/step - loss: 0.4614 - accuracy: 0.8361
# Epoch 2/1500
# 42/42 [==============================] - 0s 5ms/step - loss: 0.1142 - accuracy: 0.9546
# Epoch 3/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0483 - accuracy: 0.9831
# Epoch 4/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0345 - accuracy: 0.9891
# Epoch 5/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0206 - accuracy: 0.9944
# Epoch 6/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0128 - accuracy: 0.9966
# Epoch 7/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0131 - accuracy: 0.9959
# Epoch 8/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0116 - accuracy: 0.9962
# Epoch 9/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0088 - accuracy: 0.9977
# Epoch 10/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0082 - accuracy: 0.9981
# Epoch 11/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0065 - accuracy: 0.9977
# Epoch 12/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0056 - accuracy: 0.9981
# Epoch 13/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0084 - accuracy: 0.9966
# Epoch 14/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0086 - accuracy: 0.9974
# Epoch 15/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0174 - accuracy: 0.9947
# Epoch 16/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0051 - accuracy: 0.9989
# Epoch 17/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0057 - accuracy: 0.9977
# Epoch 18/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0149 - accuracy: 0.9955
# Epoch 19/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0059 - accuracy: 0.9985
# Epoch 20/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0062 - accuracy: 0.9981
# Epoch 21/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0051 - accuracy: 0.9985
# Epoch 22/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 23/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0039 - accuracy: 0.9992
# Epoch 24/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0023 - accuracy: 0.9992
# Epoch 25/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0026 - accuracy: 0.9985
# Epoch 26/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0045 - accuracy: 0.9981
# Epoch 27/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0087 - accuracy: 0.9977
# Epoch 28/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0045 - accuracy: 0.9981
# Epoch 29/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0015 - accuracy: 0.9996
# Epoch 30/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0047 - accuracy: 0.9985
# Epoch 31/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0080 - accuracy: 0.9974
# Epoch 32/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0081 - accuracy: 0.9974
# Epoch 33/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0051 - accuracy: 0.9974
# Epoch 34/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0066 - accuracy: 0.9970
# Epoch 35/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0039 - accuracy: 0.9985
# Epoch 36/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0132 - accuracy: 0.9955
# Epoch 37/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0130 - accuracy: 0.9940
# Epoch 38/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0128 - accuracy: 0.9966
# Epoch 39/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0044 - accuracy: 0.9985
# Epoch 40/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0088 - accuracy: 0.9962
# Epoch 41/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0038 - accuracy: 0.9992
# Epoch 42/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0048 - accuracy: 0.9989
# Epoch 43/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0037 - accuracy: 0.9985
# Epoch 44/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0030 - accuracy: 0.9985
# Epoch 45/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0020 - accuracy: 0.9996
# Epoch 46/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 47/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0015 - accuracy: 0.9992
# Epoch 48/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0054 - accuracy: 0.9989
# Epoch 49/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0067 - accuracy: 0.9977
# Epoch 50/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0036 - accuracy: 0.9989
# Epoch 51/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 9.4818e-04 - accuracy: 1.0000
# Epoch 52/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0033 - accuracy: 0.9996
# Epoch 53/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 7.5251e-04 - accuracy: 0.9996
# Epoch 54/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0032 - accuracy: 0.9992
# Epoch 55/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0110 - accuracy: 0.9966
# Epoch 56/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0026 - accuracy: 0.9996
# Epoch 57/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0054 - accuracy: 0.9981
# Epoch 58/1500
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0029 - accuracy: 0.9985
# Epoch 59/1500
# 37/42 [=========================>....] - ETA: 0s - loss: 0.0042 - accuracy: 0.9983Restoring model weights from the end of the best epoch: 29.
# 42/42 [==============================] - 0s 6ms/step - loss: 0.0038 - accuracy: 0.9985
# Epoch 59: early stopping
# 5/5 [==============================] - 0s 2ms/step - loss: 1.5019 - accuracy: 0.7123
# 5/5 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.77 (20/26)
# Before appending - Cat IDs: 565, Predictions: 565, Actuals: 565, Gender: 565
# After appending - Cat IDs: 711, Predictions: 711, Actuals: 711, Gender: 711
# Final Test Results - Loss: 1.5019254684448242, Accuracy: 0.7123287916183472, Precision: 0.6498316498316499, Recall: 0.6086702671142898, F1 Score: 0.6268199233716475
# Confusion Matrix:
#  [[84  3 15]
#  [ 5  8  0]
#  [19  0 12]]
#
# Final Average F1-Score across all UNSEEN TEST sets: 0.5839448143027777
#
# Final Average Loss across all UNSEEN TEST sets: 2.074379801750183
#
# Final Average Accuracy across all UNSEEN TEST sets: 0.7048884928226471
#
# Final Average Precision across all UNSEEN TEST sets: 0.6635375957308072
#
# Final Average Recall across all UNSEEN TEST sets: 0.6057159579703317

# %%
seed_5_folds_values = [unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1]

seed_5_training_acc_values = cv_training_acc_total

# Plotting all fold metrics|
seed_5_folds_plot = plot_all_metrics(unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1, "Folds", "Fold Number")

# %% [markdown]
# ## Majority Voting on Total Entries per cat_id

# %%
# Debugging print statements
print(f'Checking - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
# Out:
# Checking - Cat IDs: 711, Predictions: 711, Actuals: 711, Gender: 711

# %%
# Create results df
full_results = pd.DataFrame({
    'cat_id': all_cat_ids,
    'predicted_age_group': all_predicted_age_groups,
    'actual_age_group': all_actual_age_groups,
    'all_gender': all_gender
})

# create a correct majority prediction column
full_results['correct'] = full_results['predicted_age_group'] == full_results['actual_age_group']

# %%
# Group by cat_id and aggregate predicted age groups
majority_votes = full_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first()

# Calculate the accuracy of majority voting
correct_predictions = (majority_votes == actual_groups).sum()
total_cats = len(actual_groups)
majority_vote_accuracy = correct_predictions / total_cats

logger(f"Overall Majority Vote Accuracy for cat_id: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

# store for final evaluation 
all_majority_vote_accuracies.append(majority_vote_accuracy)
# Out:
# Overall Majority Vote Accuracy for cat_id: 0.76 (84/110)

# %%
# Detailed df with predictions, actual labels, and comparison including majority vote
detailed_results = full_results.groupby('cat_id').apply(
    lambda x: pd.Series({
        'Predictions': list(x['predicted_age_group']),
        'Majority Vote': x['predicted_age_group'].mode()[0],
        'Actual Age Group': x['actual_age_group'].iloc[0],
        'Correct Majority Vote': x['predicted_age_group'].mode()[0] == x['actual_age_group'].iloc[0]
    })
).reset_index()

# Convert to DataFrame for better formatting and display
detailed_results = pd.DataFrame(detailed_results)

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 10)
pd.set_option('display.width', 1000)

sorted_detailed_results = detailed_results.sort_values(by='Correct Majority Vote', ascending=False)

# Display the sorted DataFrame
sorted_detailed_results
# Out:
#     cat_id                                        Predictions Majority Vote Actual Age Group  Correct Majority Vote
# 0     000B  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 70    064A                                            [adult]         adult            adult                   True
# 79    073A                                            [adult]         adult            adult                   True
# 78    072A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 77    071A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 76    070A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 75    069A                                    [adult, senior]         adult            adult                   True
# 74    068A  [adult, senior, adult, adult, senior, adult, s...         adult            adult                   True
# 73    067A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 72    066A                                            [adult]         adult            adult                   True
# 71    065A  [senior, adult, adult, adult, adult, senior, a...         adult            adult                   True
# 69    063A  [adult, adult, adult, senior, adult, adult, ad...         adult            adult                   True
# 46    040A  [kitten, kitten, kitten, kitten, kitten, kitte...        kitten           kitten                   True
# 68    062A                              [adult, adult, adult]         adult            adult                   True
# 65    059A  [adult, adult, senior, senior, senior, adult, ...        senior           senior                   True
# 64    058A                            [senior, adult, senior]        senior           senior                   True
# 58    052A                                    [adult, senior]         adult            adult                   True
# 1     001A  [adult, senior, adult, adult, adult, adult, se...         adult            adult                   True
# 54    049A                                           [kitten]        kitten           kitten                   True
# 53    048A                                           [kitten]        kitten           kitten                   True
# 50    044A            [kitten, kitten, kitten, adult, kitten]        kitten           kitten                   True
# 49    043A                                           [kitten]        kitten           kitten                   True
# 80    074A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 81    075A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 82    076A                                            [adult]         adult            adult                   True
# 83    087A                                     [adult, adult]         adult            adult                   True
# 107   115A                                   [kitten, kitten]        kitten           kitten                   True
# 106   113A                            [adult, senior, senior]        senior           senior                   True
# 105   111A  [kitten, kitten, kitten, kitten, kitten, kitte...        kitten           kitten                   True
# 104   110A                                           [kitten]        kitten           kitten                   True
# 102   108A            [senior, adult, senior, senior, senior]        senior           senior                   True
# 100   105A                             [adult, adult, senior]         adult            adult                   True
# 98    103A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 97    102A                                     [adult, adult]         adult            adult                   True
# 96    101A  [senior, adult, adult, adult, adult, adult, ad...         adult            adult                   True
# 95    100A                                            [adult]         adult            adult                   True
# 94    099A        [adult, adult, adult, kitten, adult, adult]         adult            adult                   True
# 93    097B  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 91    096A                                     [adult, adult]         adult            adult                   True
# 90    095A  [senior, adult, adult, adult, adult, senior, s...         adult            adult                   True
# 89    094A             [senior, adult, senior, adult, senior]        senior           senior                   True
# 87    092A                                            [adult]         adult            adult                   True
# 86    091A                                            [adult]         adult            adult                   True
# 85    090A                                           [senior]        senior           senior                   True
# 84    088A                                            [adult]         adult            adult                   True
# 47    041A                                           [kitten]        kitten           kitten                   True
# 55    050A           [kitten, kitten, kitten, kitten, kitten]        kitten           kitten                   True
# 45    039A         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 32    026B                                            [adult]         adult            adult                   True
# 30    025C                       [adult, adult, adult, adult]         adult            adult                   True
# 29    025B                                     [adult, adult]         adult            adult                   True
# 28    025A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 25    023A         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 24    022A  [adult, adult, kitten, kitten, adult, adult, k...         adult            adult                   True
# 23    021A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 22    020A  [adult, senior, adult, adult, adult, adult, ad...         adult            adult                   True
# 20    019A  [adult, adult, adult, adult, senior, adult, ad...         adult            adult                   True
# 19    018A                                     [adult, adult]         adult            adult                   True
# 17    015A  [adult, adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 15    014A                              [adult, adult, adult]         adult            adult                   True
# 14    013B  [adult, adult, adult, senior, adult, adult, ad...         adult            adult                   True
# 13    012A                              [adult, adult, adult]         adult            adult                   True
# 11    010A                              [adult, adult, adult]         adult            adult                   True
# 10    009A                      [adult, adult, senior, adult]         adult            adult                   True
# 9     008A               [adult, adult, adult, kitten, adult]         adult            adult                   True
# 8     007A         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 7     006A                              [adult, adult, adult]         adult            adult                   True
# 4     003A                      [kitten, adult, adult, adult]         adult            adult                   True
# 3     002B  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 2     002A  [adult, adult, kitten, adult, adult, adult, ad...         adult            adult                   True
# 31    026A                       [adult, adult, adult, adult]         adult            adult                   True
# 26    023B                       [adult, adult, adult, adult]         adult            adult                   True
# 33    026C                                            [adult]         adult            adult                   True
# 38    032A                                    [adult, kitten]         adult            adult                   True
# 44    038A                                    [kitten, adult]         adult            adult                   True
# 43    037A                                    [senior, adult]         adult            adult                   True
# 42    036A  [adult, adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 41    035A                                     [adult, adult]         adult            adult                   True
# 40    034A                              [adult, adult, adult]         adult            adult                   True
# 34    027A  [adult, adult, adult, adult, kitten, adult, ad...         adult            adult                   True
# 39    033A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 37    031A  [adult, adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 35    028A  [adult, adult, adult, senior, adult, adult, ad...         adult            adult                   True
# 36    029A  [adult, senior, adult, adult, senior, adult, a...         adult            adult                   True
# 48    042A  [adult, adult, adult, adult, adult, adult, adu...         adult           kitten                  False
# 108   116A  [senior, senior, adult, senior, adult, adult, ...         adult           senior                  False
# 51    045A                      [kitten, adult, adult, adult]         adult           kitten                  False
# 5     004A                                           [kitten]        kitten            adult                  False
# 103   109A                [adult, adult, adult, adult, adult]         adult           kitten                  False
# 6     005A  [senior, senior, senior, senior, senior, adult...        senior            adult                  False
# 101   106A  [senior, adult, adult, senior, adult, senior, ...         adult           senior                  False
# 52    047A  [adult, adult, adult, adult, adult, adult, adu...         adult           kitten                  False
# 99    104A                       [adult, adult, adult, adult]         adult           senior                  False
# 67    061A                                     [adult, adult]         adult           senior                  False
# 27    024A                                            [adult]         adult           senior                  False
# 56    051A  [adult, adult, adult, adult, adult, adult, adu...         adult           senior                  False
# 63    057A  [adult, adult, adult, adult, adult, adult, adu...         adult           senior                  False
# 12    011A                                    [adult, senior]         adult           senior                  False
# 57    051B  [adult, adult, adult, adult, adult, adult, adu...         adult           senior                  False
# 92    097A  [adult, senior, adult, adult, senior, senior, ...         adult           senior                  False
# 66    060A                            [adult, kitten, kitten]        kitten            adult                  False
# 59    053A                           [senior, senior, senior]        senior            adult                  False
# 16    014B  [adult, kitten, adult, adult, kitten, adult, a...         adult           kitten                  False
# 88    093A                                     [adult, adult]         adult           senior                  False
# 60    054A                                     [adult, adult]         adult           senior                  False
# 18    016A  [adult, adult, adult, adult, senior, adult, ad...         adult           senior                  False
# 61    055A  [adult, senior, senior, adult, adult, senior, ...         adult           senior                  False
# 62    056A                             [adult, senior, adult]         adult           senior                  False
# 21    019B                                           [senior]        senior            adult                  False
# 109   117A  [adult, adult, adult, adult, adult, adult, adult]         adult           senior                  False

# %%
# Create df for majority votes
majority_df = majority_votes.reset_index()
majority_df.columns = ['cat_id', 'Majority_Vote']

# Get actual groups for each cat_id
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first().reset_index()

# Merge majority votes with actual groups
majority_with_actual = pd.merge(majority_df, actual_groups, on='cat_id')

# Add a column to check if the majority vote was correct
majority_with_actual['Majority_Correct'] = majority_with_actual['Majority_Vote'] == majority_with_actual['actual_age_group']

# Count correct majority votes per class
correct_majority_votes_per_class = majority_with_actual.groupby('actual_age_group')['Majority_Correct'].sum()

print("Correct Majority Votes per Class:")
print(correct_majority_votes_per_class)
# Out:
# Correct Majority Votes per Class:
# actual_age_group
# adult     68
# kitten    10
# senior     6
# Name: Majority_Correct, dtype: int64

# %%
# Calculate the total count and the number of correct predictions for each class
class_stats = majority_with_actual.groupby('actual_age_group').agg(
    total_count=('Majority_Correct', 'size'),  # Total number of cases per class
    correct_count=('Majority_Correct', 'sum')  # Sum of correct predictions per class
).reset_index()

# Calculate accuracy for each class
class_stats['accuracy'] = class_stats['correct_count'] / class_stats['total_count'] * 100

# store for final evaluation 
all_majority_vote_details.append(class_stats)

# Log detailed stats
print("Detailed Class Statistics for Majority Votes:")
print(class_stats)
# Out:
# Detailed Class Statistics for Majority Votes:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult           73             68  93.150685
# 1           kitten           15             10  66.666667
# 2           senior           22              6  27.272727

# %%
# Plot for Detailed Class Statistics for Majority Votes
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Accuracy of Majority Votes by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Detailed Class Statistics

# %%
# Calculate the total count and the number of correct predictions for each class
class_stats = full_results.groupby('actual_age_group').agg(
    total_count=('correct', 'size'),
    correct_count=('correct', 'sum')
).reset_index()

# Calculate accuracy for each class
class_stats['accuracy'] = class_stats['correct_count'] / class_stats['total_count'] * 100

# store for final evaluation 
all_class_stats.append(class_stats)

# Log the detailed stats
print("Detailed Class Statistics:")
print(class_stats)
# Out:
# Detailed Class Statistics:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult          471            412  87.473461
# 1           kitten           91             43  47.252747
# 2           senior          149             45  30.201342

# %%
# Plot for Detailed Class Statistics (Overall)
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Overall Accuracy by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Gender Exploration

# %%
# Group by gender and calculate the total count, correct predictions, and accuracy
gender_stats = full_results.groupby('all_gender').agg(
    count=('cat_id', 'size'),  # Total number of cases per gender
    correct=('correct', 'sum')  # Sum of correct predictions per gender
).reset_index()

# Calculate accuracy for each gender
gender_stats['accuracy'] = (gender_stats['correct'] / gender_stats['count'] * 100).round(2)

# Display the DataFrame
print("Accuracy by Gender:")
print(gender_stats)

# store for final evaluation 
all_gender_stats.append(gender_stats)
# Out:
# Accuracy by Gender:
#   all_gender  count  correct  accuracy
# 0          F    192      133     69.27
# 1          M    286      224     78.32
# 2          X    233      143     61.37

# %%
# Plot for Accuracy by Gender
styled_barplot(gender_stats, 'all_gender', 'accuracy', 
               'Accuracy by Gender', 
               'Gender', 'Accuracy (%)')

# %% [markdown]
# ### Log current total CV Stats

# %%
print("Total Majority Vote Accuracy so far:", all_majority_vote_accuracies)
print("Total Class Statistics so far:\n", all_class_stats) 
print("Total Majority Vote Statistics so far:\n", all_majority_vote_details) 
print("Total Gender Accuracy so far:\n", all_gender_stats)
# Out:
# Total Majority Vote Accuracy so far: [0.7454545454545455, 0.7272727272727273, 0.7363636363636363, 0.7727272727272727, 0.7636363636363637]
# Total Class Statistics so far:
#  [  actual_age_group  total_count  correct_count   accuracy
# 0            adult          474            409  86.286920
# 1           kitten           91             50  54.945055
# 2           senior          149             44  29.530201,   actual_age_group  total_count  correct_count   accuracy
# 0            adult          473            400  84.566596
# 1           kitten           91             52  57.142857
# 2           senior          149             38  25.503356,   actual_age_group  total_count  correct_count   accuracy
# 0            adult          471            410  87.048832
# 1           kitten          112             59  52.678571
# 2           senior          149             43  28.859060,   actual_age_group  total_count  correct_count   accuracy
# 0            adult          471            408  86.624204
# 1           kitten           91             47  51.648352
# 2           senior          149             47  31.543624,   actual_age_group  total_count  correct_count   accuracy
# 0            adult          471            412  87.473461
# 1           kitten           91             43  47.252747
# 2           senior          149             45  30.201342]
# Total Majority Vote Statistics so far:
#  [  actual_age_group  total_count  correct_count   accuracy
# 0            adult           73             67  91.780822
# 1           kitten           15             10  66.666667
# 2           senior           22              5  22.727273,   actual_age_group  total_count  correct_count   accuracy
# 0            adult           73             65  89.041096
# 1           kitten           15             10  66.666667
# 2           senior           22              5  22.727273,   actual_age_group  total_count  correct_count   accuracy
# 0            adult           73             64  87.671233
# 1           kitten           15             11  73.333333
# 2           senior           22              6  27.272727,   actual_age_group  total_count  correct_count   accuracy
# 0            adult           73             69  94.520548
# 1           kitten           15             10  66.666667
# 2           senior           22              6  27.272727,   actual_age_group  total_count  correct_count   accuracy
# 0            adult           73             68  93.150685
# 1           kitten           15             10  66.666667
# 2           senior           22              6  27.272727]
# Total Gender Accuracy so far:
#  [  all_gender  count  correct  accuracy
# 0          F    196      131     66.84
# 1          M    286      222     77.62
# 2          X    232      150     64.66,   all_gender  count  correct  accuracy
# 0          F    192      126     65.62
# 1          M    289      213     73.70
# 2          X    232      151     65.09,   all_gender  count  correct  accuracy
# 0          F    192      132     68.75
# 1          M    287      224     78.05
# 2          X    253      156     61.66,   all_gender  count  correct  accuracy
# 0          F    192      132     68.75
# 1          M    287      217     75.61
# 2          X    232      153     65.95,   all_gender  count  correct  accuracy
# 0          F    192      133     69.27
# 1          M    286      224     78.32
# 2          X    233      143     61.37]

# %% [markdown]
# # --------------

# %% [markdown]
# # Total Final Results & Analysis

# %%
# Count unique cat_id per age group 
unique_cats_per_age_group = dataframe.groupby('age_group')['cat_id'].nunique()

# Display the counts
print("Unique cat_id counts in original dataframe:", unique_cats_per_age_group)
# Out:
# Unique cat_id counts in original dataframe: age_group
# adult     74
# kitten    16
# senior    22
# Name: cat_id, dtype: int64

# %% [markdown]
# ## Metrics

# %%
# Calculate overall metrics
overall_avg_loss = np.mean(all_losses)
overall_avg_acc = np.mean(all_accuracies)
overall_avg_precision = np.mean(all_precisions)
overall_avg_recall = np.mean(all_recalls)
overall_avg_f1 = np.mean(all_f1)

print("Overall Average Metrics:")
print("Loss:", overall_avg_loss)
print("Accuracy:", overall_avg_acc)
print("Precision:", overall_avg_precision)
print("Recall:", overall_avg_recall)
print("F1 Score:", overall_avg_f1)
# Out:
# Overall Average Metrics:
# Loss: 2.3351282835006715
# Accuracy: 0.7017180800437928
# Precision: 0.6484727546386674
# Recall: 0.6121980538562749
# F1 Score: 0.5906314207686019

# %% [markdown]
# ## Majority Votes

# %%
# Average of majority vote accuracies
average_majority_vote_accuracy = np.mean(all_majority_vote_accuracies)
print("Average Majority Vote Accuracy:", average_majority_vote_accuracy)
# Out:
# Average Majority Vote Accuracy: 0.749090909090909

# %%
# Concatenate all class stats DataFrames and calculate the mean of accuracies
total_majority_vote_details = pd.concat(all_majority_vote_details)
average_majority_vote_details = total_majority_vote_details.groupby('actual_age_group').agg({
    'total_count': 'sum', 
    'correct_count': 'sum' 
}).reset_index()
average_majority_vote_details['accuracy'] = (average_majority_vote_details['correct_count'] / average_majority_vote_details['total_count']) * 100

print("Average Class Statistics:")
print(average_majority_vote_details)
# Out:
# Average Class Statistics:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult          365            333  91.232877
# 1           kitten           75             51  68.000000
# 2           senior          110             28  25.454545

# %%
# Plot for Detailed Class Statistics for Majority Votes
styled_barplot(average_majority_vote_details, 'actual_age_group', 'accuracy', 
               'Accuracy of Majority Votes by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Detailed Class Statistics

# %%
# Concatenate all class stats DataFrames and calculate the mean of accuracies
total_class_stats = pd.concat(all_class_stats)
average_class_stats = total_class_stats.groupby('actual_age_group').agg({
    'total_count': 'sum',  
    'correct_count': 'sum' 
}).reset_index()
average_class_stats['accuracy'] = (average_class_stats['correct_count'] / average_class_stats['total_count']) * 100

print("Average Class Statistics:")
print(average_class_stats)
# Out:
# Average Class Statistics:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult         2360           2039  86.398305
# 1           kitten          476            251  52.731092
# 2           senior          745            217  29.127517

# %%
# Plot for Detailed Class Statistics (Overall)
styled_barplot(average_class_stats, 'actual_age_group', 'accuracy', 
               'Overall Accuracy by Age Group', 
               'Age Group', 'Accuracy (%)')

# %%
# Concatenate all gender stats DataFrames and calculate the mean of accuracies
total_gender_stats = pd.concat(all_gender_stats)
average_gender_stats = total_gender_stats.groupby('all_gender').agg({
    'count': 'sum',  
    'correct': 'sum'  
}).reset_index()
average_gender_stats['accuracy'] = (average_gender_stats['correct'] / average_gender_stats['count']) * 100

print("Average Gender Accuracy:")
print(average_gender_stats)
# Out:
# Average Gender Accuracy:
#   all_gender  count  correct   accuracy
# 0          F    964      654  67.842324
# 1          M   1435     1100  76.655052
# 2          X   1182      753  63.705584

# %%
# Plot for Accuracy by Gender
styled_barplot(total_gender_stats, 'all_gender', 'accuracy', 
               'Accuracy by Gender', 
               'Gender', 'Accuracy (%)')

# %% [markdown]
# # Visualisations

# %%
# Plotting all metrics
metrics_across_seeds = plot_all_metrics(average_fold_losses, average_fold_accuracies, average_fold_precisions, average_fold_recalls, average_fold_f1, "Seeds", "Seed Number")

# %% [markdown]
# ## Display the seed folds results together

# %%
# Create a figure with subplots
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(18, 12))  

# Flatten the axes array for easier indexing
axes = axes.flatten()

def plot_metrics_on_axes(ax, losses, accuracies, precisions, recalls, f1, title):
    ax.plot(range(1, len(losses)+1), losses, marker='o', color='blue', label='Loss')
    ax.plot(range(1, len(accuracies)+1), accuracies, marker='o', color='green', label='Accuracy')
    ax.plot(range(1, len(precisions)+1), precisions, marker='o', color='red', label='Precision')
    ax.plot(range(1, len(recalls)+1), recalls, marker='o', color='purple', label='Recall')
    ax.plot(range(1, len(f1)+1), f1, marker='o', color='orange', label='F1 Score')
    ax.set_xticks([1, 2, 3, 4])  # Set x-axis ticks to full integers
    ax.set_title(title)
    ax.set_xlabel('Fold Number')
    ax.set_ylabel('Metric Value')
    ax.legend()
    ax.grid(True)

# Plot onto each axes object
plot_metrics_on_axes(axes[0], *seed_1_folds_values, "Seed 1 Metrics")
plot_metrics_on_axes(axes[1], *seed_2_folds_values, "Seed 2 Metrics")
plot_metrics_on_axes(axes[2], *seed_3_folds_values, "Seed 3 Metrics")
plot_metrics_on_axes(axes[3], *seed_4_folds_values, "Seed 4 Metrics")
plot_metrics_on_axes(axes[4], *seed_5_folds_values, "Seed 5 Metrics")

# Hide the unused subplot 
for ax in axes[5:]:
    ax.set_visible(False)

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# # Statistics

# %% [markdown]
# ### Standard Deviation

# %%
# Calculate the standard deviation for each metric
std_loss = np.std(all_losses)
std_accuracy = np.std(all_accuracies)
std_precision = np.std(all_precisions)
std_recall = np.std(all_recalls)
std_f1 = np.std(all_f1)

print("Standard Deviations:")
print(f"Loss: {std_loss}")
print(f"Accuracy: {std_accuracy}")
print(f"Precision: {std_precision}")
print(f"Recall: {std_recall}")
print(f"F1 Score: {std_f1}")
# Out:
# Standard Deviations:
# Loss: 0.9645118576526373
# Accuracy: 0.07676975170544677
# Precision: 0.07332033271416062
# Recall: 0.09991040778427335
# F1 Score: 0.07589880064573121

# %% [markdown]
# ### Interquartile Range

# %%
# Calculate the interquartile range for each metric
iqr_loss = np.percentile(all_losses, 75) - np.percentile(all_losses, 25)
iqr_accuracy = np.percentile(all_accuracies, 75) - np.percentile(all_accuracies, 25)
iqr_precision = np.percentile(all_precisions, 75) - np.percentile(all_precisions, 25)
iqr_recall = np.percentile(all_recalls, 75) - np.percentile(all_recalls, 25)
iqr_f1 = np.percentile(all_f1, 75) - np.percentile(all_f1, 25)

print("Interquartile Ranges:")
print(f"Loss: {iqr_loss}")
print(f"Accuracy: {iqr_accuracy}")
print(f"Precision: {iqr_precision}")
print(f"Recall: {iqr_recall}")
print(f"F1 Score: {iqr_f1}")
# Out:
# Interquartile Ranges:
# Loss: 1.3316879868507385
# Accuracy: 0.08483369648456573
# Precision: 0.10012435728091706
# Recall: 0.1857370249738306
# F1 Score: 0.11443146808815785

# %% [markdown]
# ### Variation

# %%
# Calculate the variation for each metric
var_loss = np.var(all_losses)
var_accuracy = np.var(all_accuracies)
var_precision = np.var(all_precisions)
var_recall = np.var(all_recalls)
var_f1 = np.var(all_f1)

print("Variations:")
print(f"Loss: {var_loss}")
print(f"Accuracy: {var_accuracy}")
print(f"Precision: {var_precision}")
print(f"Recall: {var_recall}")
print(f"F1 Score: {var_f1}")
# Out:
# Variations:
# Loss: 0.9302831235525412
# Accuracy: 0.005893594776915948
# Precision: 0.005375871189315212
# Recall: 0.00998208958361979
# F1 Score: 0.005760627939460448

# %% [markdown]
# ### Levene tests for variation significance between seeds

# %% [markdown]
# #### Levene across seeds for LOSS

# %%
# Levene across seeds for LOSS
stat_val, p_val = levene(seed_1_folds_values[0], seed_2_folds_values[0], seed_3_folds_values[0], seed_4_folds_values[0], seed_5_folds_values[0])
print(f'levene test statistic: {stat_val:.2f}, P-value: {p_val:.3f}')
# Out:
# levene test statistic: 0.62, P-value: 0.656

# %% [markdown]
# #### Levene across seeds for ACCURACY

# %%
# Levene across seeds for ACCURACY
stat_val, p_val = levene(seed_1_folds_values[1], seed_2_folds_values[1], seed_3_folds_values[1], seed_4_folds_values[1], seed_5_folds_values[1])
print(f'levene test statistic: {stat_val:.2f}, P-value: {p_val:.3f}')
# Out:
# levene test statistic: 0.62, P-value: 0.655

# %% [markdown]
# #### Levene across seeds for PRECISION

# %%
# Levene across seeds for PRECISION
stat_val, p_val = levene(seed_1_folds_values[2], seed_2_folds_values[2], seed_3_folds_values[2], seed_4_folds_values[2], seed_5_folds_values[2])
print(f'levene test statistic: {stat_val:.2f}, P-value: {p_val:.3f}')
# Out:
# levene test statistic: 0.51, P-value: 0.730

# %% [markdown]
# #### Levene across seeds for RECALL

# %%
# Levene across seeds for RECALL
stat_val, p_val = levene(seed_1_folds_values[3], seed_2_folds_values[3], seed_3_folds_values[3], seed_4_folds_values[3], seed_5_folds_values[3])
print(f'levene test statistic: {stat_val:.2f}, P-value: {p_val:.3f}')
# Out:
# levene test statistic: 0.44, P-value: 0.779

# %% [markdown]
# #### Levene across seeds for F1

# %%
# Levene across seeds for F1
stat_val, p_val = levene(seed_1_folds_values[4], seed_2_folds_values[4], seed_3_folds_values[4], seed_4_folds_values[4], seed_5_folds_values[4])
print(f'levene test statistic: {stat_val:.2f}, P-value: {p_val:.3f}')
# Out:
# levene test statistic: 0.34, P-value: 0.846

# %% [markdown]
# ## Print out measurements for future further analysis (without rerunning notebook)

# %%
seed_1_folds_values
# Out:
# [[2.1876420974731445, 4.027976036071777, 1.252773404121399, 2.910660982131958],
#  [0.7398843765258789,
#   0.6216216087341309,
#   0.807881772518158,
#   0.6274510025978088],
#  [0.6652421652421653,
#   0.5496031746031746,
#   0.6749482401656315,
#   0.6677226813590451],
#  [0.7219127792898284,
#   0.4379012345679012,
#   0.7051069703243616,
#   0.5900937081659973],
#  [0.6894607159460716,
#   0.44679186228482,
#   0.6883371501062655,
#   0.5897893972403777]]

# %%
seed_2_folds_values
# Out:
# [[1.0778368711471558,
#   1.8332140445709229,
#   4.422096252441406,
#   2.512807846069336],
#  [0.8256880640983582,
#   0.7239999771118164,
#   0.5355191230773926,
#   0.707602322101593],
#  [0.5416666666666667,
#   0.5955387205387205,
#   0.739307732008462,
#   0.6259633699633699],
#  [0.7048611111111112,
#   0.494042994042994,
#   0.540609122060735,
#   0.7468376068376069],
#  [0.5931222984998729,
#   0.5305745628326274,
#   0.510747340852925,
#   0.6641904231281147]]

# %%
seed_3_folds_values
# Out:
# [[1.442808747291565, 2.422973394393921, 1.6781033277511597, 2.825324058532715],
#  [0.75, 0.6815642714500427, 0.7311828136444092, 0.6547085046768188],
#  [0.6172461797461798,
#   0.6051229403008059,
#   0.7764196587725999,
#   0.6304093567251462],
#  [0.5282733880864722, 0.6039426523297492, 0.637805029109377, 0.50812693498452],
#  [0.551881138574687,
#   0.6039447887472204,
#   0.6767319043181113,
#   0.5195126107702795]]

# %%
seed_4_folds_values
# Out:
# [[2.183525323867798,
#   0.8316957950592041,
#   3.0229897499084473,
#   3.772618532180786],
#  [0.699999988079071,
#   0.8450000286102295,
#   0.5714285969734192,
#   0.6912751793861389],
#  [0.7034649476228848,
#   0.6046296029435781,
#   0.6079182630906769,
#   0.7101010101010101],
#  [0.7173645320197043,
#   0.7154481792717088,
#   0.4489074054291446,
#   0.7198635976129583],
#  [0.6349239161642262,
#   0.6209544058587291,
#   0.4497462919594068,
#   0.7061403508771931]]

# %%
seed_5_folds_values
# Out:
# [[3.0271451473236084,
#   2.126350164413452,
#   1.6420984268188477,
#   1.5019254684448242],
#  [0.6585366129875183,
#   0.6839826703071594,
#   0.7647058963775635,
#   0.7123287916183472],
#  [0.7183312173790379,
#   0.7818104062722737,
#   0.5041771094402673,
#   0.6498316498316499],
#  [0.49076555023923446,
#   0.6166123412386196,
#   0.7068156732891833,
#   0.6086702671142898],
#  [0.5168498775056153,
#   0.6332607116920842,
#   0.5588487446417636,
#   0.6268199233716475]]

# %% [markdown]
# ## Training Accuracy Analysis

# %%
all_best_training_acc
# Out:
# [0.9996196031570435,
#  1.0,
#  1.0,
#  1.0,
#  1.0,
#  0.