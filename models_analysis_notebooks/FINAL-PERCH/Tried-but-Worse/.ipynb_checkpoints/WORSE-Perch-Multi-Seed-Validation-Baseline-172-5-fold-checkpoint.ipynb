# %% [markdown]
# # Perch Multi Seed Validation
# #### 5 Random (but reproducible) seeds are selected for 5 different runs of train/test
# #### Models have been optimised and verified on validation sets thoroughly, running a final train/test evaluation here
# #### The setup:
#
# - 4 fold StratifiedGroupKFold for stratification and ensuring each cat_id group only appears in one set at a time
# - Final scores averaged over the 4 folds
# - For each seed run we will explore the cat_id predictions through majority voting
# - For each run we will explore the potential impact of gender
# - Includes visualisations & analysis
#
# The dataset is highly unbalanced.

# %%
# Standard imports
import numpy as np
import pandas as pd
import random
from datetime import datetime
from collections import Counter

# Sklearn imports
from sklearn.model_selection import train_test_split, GroupShuffleSplit, GroupKFold, StratifiedGroupKFold
from sklearn.preprocessing import LabelEncoder, MinMaxScaler, RobustScaler, StandardScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report
from sklearn.utils.class_weight import compute_class_weight
from sklearn.inspection import permutation_importance

# Imbalanced-learn import
from imblearn.over_sampling import SMOTE

# TensorFlow and Keras imports
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Dropout, Input, BatchNormalization, concatenate
from tensorflow.keras.optimizers import Adam, RMSprop, SGD, Adamax, AdamW
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import to_categorical
from keras.regularizers import l1, l2, L1L2

# Optuna import
import optuna

# Visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns

from IPython.display import display

# %%
# Set an initial seed for reproducibility
np.random.seed(42)  

# Generate a list of 5 random seeds
random_seeds = np.random.randint(0, 10000, size=5)
print("Random Seeds:", random_seeds)
# Out:
# Random Seeds: [7270  860 5390 5191 5734]

# %% [markdown]
# #### TOTAL RESULTS ACROSS SEED INITIATION

# %%
# Lists to collect statistics across all CVs
all_losses, all_accuracies, all_precisions, all_recalls, all_f1 = [], [], [], [], []
all_majority_vote_accuracies, all_majority_vote_details, all_class_stats, all_gender_stats  = [], [], [], []

# %% [markdown]
# ## Define Functions

# %%
def check_initial_group_split(groups_train, groups_test):
    """
    Check if any group is present in both the train and test sets.

    Parameters:
    - groups_train: Array of group identifiers for the train set
    - groups_test: Array of group identifiers for the test set

    Returns:
    - Prints out any groups found in both sets and the count of such groups
    """
    train_groups = set(groups_train)
    test_groups = set(groups_test)
    common_groups = train_groups.intersection(test_groups)

    if common_groups:
        print(f"Warning: Found {len(common_groups)} common groups in both train/validation and test sets: {common_groups}")
    else:
        print("No common groups found between train and test sets.")

# %%
# Function to perform the swaps based on cat_id, ensuring swaps within the same age_group
def swap_cat_id_instances(dataframe, train_val_idx, test_idx, specific_cat_ids):
    for cat_id in specific_cat_ids:
        # Check if the specific cat_id is not in the training set
        if cat_id not in dataframe.iloc[train_val_idx]['cat_id'].values:
            # Get the age_group of this cat_id
            age_group = dataframe[dataframe['cat_id'] == cat_id]['age_group'].iloc[0]
                
            # Find a different cat_id within the same age_group in the train set that is not in the test set
            other_cat_ids_in_age_group = dataframe[(dataframe['age_group'] == age_group) & 
                                                   (dataframe['cat_id'] != cat_id) &
                                                   (~dataframe['cat_id'].isin(dataframe.iloc[test_idx]['cat_id']))]['cat_id'].unique()
            
            # Choose one other cat_id for swapping
            if len(other_cat_ids_in_age_group) > 0:
                other_cat_id = np.random.choice(other_cat_ids_in_age_group)

                # Find all instances of the other_cat_id in the train set
                other_cat_id_train_val_indices = train_val_idx[dataframe.iloc[train_val_idx]['cat_id'] == other_cat_id]
                
                # Find all instances of the specific cat_id in the test set
                cat_id_test_indices = test_idx[dataframe.iloc[test_idx]['cat_id'] == cat_id]
                
                # Swap the indices
                train_val_idx = np.setdiff1d(train_val_idx, other_cat_id_train_val_indices, assume_unique=True)
                test_idx = np.setdiff1d(test_idx, cat_id_test_indices, assume_unique=True)

                train_val_idx = np.concatenate((train_val_idx, cat_id_test_indices))
                test_idx = np.concatenate((test_idx, other_cat_id_train_val_indices))
            else:
                print(f"No alternative cat_id found in the same age_group as {cat_id} for swapping.")
                
    return train_val_idx, test_idx

# %%
# Function to identify differences in groups
def find_group_differences(original, new):
    # Convert numpy arrays to sets for easy difference computation
    original_set = set(original)
    new_set = set(new)
    # Find differences
    moved_to_new = new_set - original_set
    moved_to_original = original_set - new_set
    return moved_to_new, moved_to_original

# %%
# create custom logger function for local logs & stored in a .txt
def logger(message, file=None):
    print(message)
    if file is not None:
        with open(file, "a") as log_file:
            log_file.write(message + "\n")

log_file_path = "multi-seed-val-D13.txt"

# %%
# Set the aesthetic style of the plots
sns.set(style="whitegrid", palette="deep")

# Define a custom color palette
colors = ["#6aabd1", "#b6e2d3", "#dac292"] 
sns.set_palette(sns.color_palette(colors))

# Function to create bar plots with enhanced style
def styled_barplot(data, x, y, title, xlabel, ylabel):
    plt.figure(figsize=(8, 4))
    bar_plot = sns.barplot(x=x, y=y, data=data, errorbar=None, width=0.5)  
    plt.title(title, fontsize=16, fontweight='bold', color="#333333")
    plt.xlabel(xlabel, fontsize=14, fontweight='bold', color="#333333")
    plt.ylabel(ylabel, fontsize=14, fontweight='bold', color="#333333")
    plt.xticks(fontsize=12, color="#333333")
    plt.yticks(fontsize=12, color="#333333")
    plt.ylim(0, 100) 

    # Adding value labels on top of each bar
    for p in bar_plot.patches:
        height = p.get_height()
        # Annotate the height value on the bar
        bar_plot.annotate(f'{height:.1f}', 
                          (p.get_x() + p.get_width() / 2., height), 
                          ha='center', va='center', 
                          xytext=(0, 9), 
                          textcoords='offset points', fontsize=12, color="#333333")

    plt.show()

# %%
def plot_all_metrics(losses, accuracies, precisions, recalls, f1, metrics_across, x_axis_label):
    fig, ax = plt.subplots(figsize=(12, 8))
    seeds = range(1, len(losses) + 1)

    ax.plot(seeds, losses, marker='o', color='blue', label='Loss')
    ax.plot(seeds, accuracies, marker='o', color='green', label='Accuracy')
    ax.plot(seeds, precisions, marker='o', color='red', label='Precision')
    ax.plot(seeds, recalls, marker='o', color='purple', label='Recall')
    ax.plot(seeds, f1, marker='o', color='orange', label='F1 Score')

    ax.set_title(f'Metrics Across {metrics_across}')
    ax.set_xlabel(x_axis_label)
    ax.set_ylabel('Metric Value')
    ax.set_xticks(seeds)
    ax.legend()
    ax.grid(True)

    return fig

# %% [markdown]
# # RANDOM SEED 1

# %% [markdown]
# ## Prepare Data

# %%
# Set a fixed random seed for reproducibility
random.seed(int(random_seeds[0])) 
np.random.seed(int(random_seeds[0]))
tf.random.set_seed(int(random_seeds[0]))

# Load datasets
dataframe = pd.read_csv('/Users/astrid/PycharmProjects/perch-2/scripts/perch_embeddings_april_10.csv')

dataframe.drop('mean_freq', axis=1, inplace=True)

def assign_age_group(age, age_groups):
    for group_name, age_range in age_groups.items():
        if age_range[0] <= age < age_range[1]:
            return group_name
    return 'Unknown'  # For any age that doesn't fit the defined groups

# Define age groups
age_groups = {
    'kitten': (0, 0.5),
    'adult': (0.5, 12),
    'senior': (12, 20)
}

# Create a new column for the age group
dataframe['age_group'] = dataframe['target'].apply(assign_age_group, age_groups=age_groups)

print(dataframe['age_group'].value_counts())
# Out:
# adult     509
# senior    149
# kitten    135
# Name: age_group, dtype: int64

# %%
# Separate features and labels
X = dataframe.iloc[:, :-4].values  # all columns except the last four

# Encode the 'age_group' column as integers using LabelEncoder
label_encoder = LabelEncoder()
encoded_y = label_encoder.fit_transform(dataframe['age_group'].values)

# Use the encoded labels for splitting and one-hot encoding
y = encoded_y  

# Convert 'cat_id' column to numpy array to be used as groups array for GroupKFold
groups = dataframe['cat_id'].values

# %%
tf.keras.backend.clear_session()

# %% [markdown]
# ## Run Setup

# %%
all_cat_ids = []
all_predicted_age_groups = []
all_actual_age_groups = []
all_gender = []

# Define the StratifiedGroupKFold splitter for 4 fold CV with random shuffling
outer_cv = StratifiedGroupKFold(n_splits=5, shuffle=True, random_state=int(random_seeds[0]))

# unseen test set metrics
unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1 = [], [], [], [], []

outer_fold = 0

# Use the splitter to generate indices for training and testing sets
# Note: GroupShuffleSplit.split returns indices, so we use it to index the arrays
for train_val_idx, test_idx in outer_cv.split(X, y, groups):
    outer_fold += 1
    logger(f"outer_fold {outer_fold}", file=log_file_path)

    # Convert indices back to DataFrame for easy manipulation
    df_train_val = dataframe.iloc[train_val_idx]
    df_test = dataframe.iloc[test_idx]

    ##############################
    # ASSESSING SPLITS BY CAT_ID #
    ##############################
    
    # Get the distribution of groups
    training_validation_group_distribution = df_train_val['cat_id'].value_counts()  
    testing_group_distribution = df_test['cat_id'].value_counts()  
    
    # Log or print the distribution
    logger(f"Train Set Group Distribution:\n{training_validation_group_distribution}", file=log_file_path)
    logger(f"Testing Set Group Distribution:\n{testing_group_distribution}", file=log_file_path)

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val['gender'].value_counts()
    testing_gender_distribution = df_test['gender'].value_counts()
    
    # Log the distribution
    logger(f"Training Set Gender Distribution BEFORE SWAP:\n{training_gender_distribution}", file=log_file_path)
    logger(f"Testing Set Gender Distribution BEFORE SWAP:\n{testing_gender_distribution}", file=log_file_path)

    # Group by 'age_group' and then list unique 'cat_id' within each age group
    unique_cat_ids_per_age_group_train_val = df_train_val.groupby('age_group')['cat_id'].unique()
    unique_cat_ids_per_age_group_test = df_test.groupby('age_group')['cat_id'].unique()
    
    # Log results
    logger(f"Unique Cat IDs per Age Group in Training/Validation Set:\n{unique_cat_ids_per_age_group_train_val}", file=log_file_path)
    logger(f"Unique Cat IDs per Age Group in Testing Set:\n{unique_cat_ids_per_age_group_test}", file=log_file_path)

    # Calculate the count of unique identifiers per age group for training and testing set
    counts_train_val = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_train_val.items()}
    counts_test = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_test.items()}

    # Log the counts of unique identifiers per age group
    logger(f"Count of Unique Cat IDs per Age Group in Training/Validation Set:\n{counts_train_val}", file=log_file_path)
    logger(f"Count of Unique Cat IDs per Age Group in Testing Set:\n{counts_test}", file=log_file_path)

    #######################################################
    # CONTINUE WITH ENSURING VALID AND APPROPRIATE SPLITS #
    #######################################################
    
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    groups_train_val, groups_test = groups[train_val_idx], groups[test_idx]

    # logging identifier splits 
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)

    # check group splits
    check_initial_group_split(groups_train_val, groups_test)

    # Specify the cat_ids that must be in the training/validation set
    specific_cat_ids = ['000A', '046A']
    
    # Perform the swapping operation
    train_val_idx, test_idx = swap_cat_id_instances(dataframe, train_val_idx, test_idx, specific_cat_ids)
    
    # Re-assign the sets based on the updated indices
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    new_groups_train_val, new_groups_test = groups[train_val_idx], groups[test_idx]

    # Find differences for training and test sets
    moved_to_train_val, removed_from_train_val = find_group_differences(groups_train_val, new_groups_train_val)
    moved_to_test, removed_from_test = find_group_differences(groups_test, new_groups_test)
    
    # Display the results
    logger(f"Moved to Training/Validation Set:\n{moved_to_train_val}", file=log_file_path)
    logger(f"Removed from Training/Validation Set:\n{removed_from_train_val}", file=log_file_path)
    logger(f"Moved to Test Set:\n{moved_to_test}", file=log_file_path)
    logger(f"Removed from Test Set\n{removed_from_test}", file=log_file_path)

    # Update X_train_val, X_test, y_train_val, y_test, groups_train_val, groups_test based on updated indices
    X_train_val = X[train_val_idx]
    y_train_val = y[train_val_idx]
    groups_train_val = groups[train_val_idx]
    
    X_test = X[test_idx]
    y_test = y[test_idx]
    groups_test = groups[test_idx]

    # logging identifier splits again after potential swaps
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"AFTER SWAP - Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"AFTER SWAP - Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)
    
    # Verify the lengths are consistent
    logger(f"Length of X_train_val:\n{len(X_train_val)}", file=log_file_path)
    logger(f"Length of y_train_val:\n{len(y_train_val)}", file=log_file_path)
    logger(f"Length of groups_train_val:\n{len(groups_train_val)}", file=log_file_path)

    # Check group splits once more
    check_initial_group_split(groups_train_val, groups_test)

    # Convert the modified indices back to a DataFrame representing the updated df_train_val
    df_train_val_updated = dataframe.iloc[train_val_idx].copy()
    df_test_updated = dataframe.iloc[test_idx].copy()

    ############################
    # LOGGING AGE GROUP SPLITS #
    ############################

    # Get the distribution of age groups of age groups before the update
    training_validation_age_group_distribution = df_train_val['age_group'].value_counts()
    testing_age_group_distribution = df_test['age_group'].value_counts()
    
    # Logthe distribution
    logger(f"Train Age Group Distribution BEFORE SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution BEFORE SWAP:\n{testing_age_group_distribution}", file=log_file_path)

    # Get the distribution of age groups after the update
    training_validation_age_group_distribution = df_train_val_updated['age_group'].value_counts()
    testing_age_group_distribution = df_test_updated['age_group'].value_counts()
    
    # Log the distribution
    logger(f"Train Age Group Distribution AFTER SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution AFTER SWAP:\n{testing_age_group_distribution}", file=log_file_path)
    
    ########################################################
    # TRACKING FINAL CAT_IDs & GENDER AFTER REDISTRIBUTION #
    ########################################################

    # Get the distribution of groups
    training_validation_group_distribution = df_train_val_updated['cat_id'].value_counts()  
    testing_group_distribution = df_test_updated['cat_id'].value_counts()  

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val_updated['gender'].value_counts()
    testing_gender_distribution = df_test_updated['gender'].value_counts()
    
    logger(f"\n Starting training on unseen test set\n", file=log_file_path)

    ###################
    # PREPARING MODEL #
    ###################

    # Calculate the distribution of age groups in y_train_val
    age_group_distribution = Counter(y_train_val)
    print("Age group distribution:", age_group_distribution)

    # EarlyStopping callback: monitor 'loss' instead of 'val_loss' for the test set
    early_stopping = EarlyStopping(
        monitor='loss',  
        min_delta=0.001, 
        patience=30,  
        verbose=1,  
        restore_best_weights=True  
    )

    # One final shuffle to ensure randomness
    outer_shuffle_idx = np.random.permutation(len(X_train_val))
    X_train_val = X_train_val[outer_shuffle_idx]
    y_train_val = y_train_val[outer_shuffle_idx]
    
    # Scale the features
    scaler_full = StandardScaler().fit(X_train_val)
    X_train_full_scaled = scaler_full.transform(X_train_val)
    X_test_scaled = scaler_full.transform(X_test)
    
    # Encode the labels
    y_train_full_encoded = to_categorical(y_train_val)
    y_test_encoded = to_categorical(y_test)

    #######################
    # BUILD & TRAIN MODEL #
    #######################

    optimizers = {
        'Adamax': Adamax(learning_rate=0.00510251984616472)
    }
    
    # Model definition with dynamic number of layers
    model_full = Sequential()
    model_full.add(Dense(480, activation='relu', input_shape=(X_train_full_scaled.shape[1],)))
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.2011047009431978))  
    model_full.add(Dense(256, activation='relu',)) 
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.14956886311951184))  
    model_full.add(Dense(256, activation='relu'))  
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.42291461228250665))  
    model_full.add(Dense(3, activation='softmax'))  
    
    # Use the optimizer from the parameters
    optimizer = optimizers['Adamax']  # optimizer_key from parameters
    
    # Compile the model
    model_full.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    
    # Train the model on the full training set
    history_full = model_full.fit(X_train_full_scaled, y_train_full_encoded, epochs=1500, batch_size=64,
                                  verbose=1, callbacks=[early_stopping])
    
    # Evaluate the model on the held-out test set
    test_loss, test_accuracy = model_full.evaluate(X_test_scaled, y_test_encoded)

    y_test_pred_prob = model_full.predict(X_test_scaled)
    y_test_pred = np.argmax(y_test_pred_prob, axis=1)  
    y_test_true = np.argmax(y_test_encoded, axis=1)    

    ################################
    # LOG MAJORITY VOTE PER CAT_ID #
    ################################

    # Convert numeric predictions back to age group labels
    predicted_age_groups = label_encoder.inverse_transform(y_test_pred)
    actual_labels = label_encoder.inverse_transform(y_test_true)
    
    # Map predictions and actual labels back to cat_ids
    test_results = pd.DataFrame({
        'cat_id': df_test_updated['cat_id'],
        'predicted_age_group': predicted_age_groups,
        'actual_age_group': actual_labels
    })
    
    # Group by cat_id and aggregate predicted age groups
    majority_votes = test_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
    actual_groups = test_results.groupby('cat_id')['actual_age_group'].first()
    
    # Calculate the accuracy of majority voting
    correct_predictions = (majority_votes == actual_groups).sum()
    total_cats = len(actual_groups)
    majority_vote_accuracy = correct_predictions / total_cats
    
    # Log the accuracy of the majority voting
    logger(f"Majority Vote Accuracy for cat_id for this fold: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

    ####################################################
    # COLLECT PREDICTIONS FOR GENDER & CAT_ID ANALYSIS #
    ####################################################

    # Debugging print statements
    print(f'Before appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Extend lists with current fold results
    all_cat_ids.extend(df_test_updated['cat_id'].tolist())
    all_predicted_age_groups.extend(predicted_age_groups)
    all_actual_age_groups.extend(actual_labels)
    all_gender.extend(df_test_updated['gender'].tolist())

    # Debugging print statements
    print(f'After appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Calculate additional metrics
    test_precision = precision_score(y_test_true, y_test_pred, average='macro')  # Use 'macro' for imbalanced datasets
    test_recall = recall_score(y_test_true, y_test_pred, average='macro')
    test_f1 = f1_score(y_test_true, y_test_pred, average='macro')

    # prepare averages of outer metrics
    unseen_f1.append(test_f1)
    unseen_losses.append(test_loss)
    unseen_accuracies.append(test_accuracy)
    unseen_precisions.append(test_precision)
    unseen_recalls.append(test_recall)

    # Print final test results
    logger(f"Final Test Results - Loss: {test_loss}, Accuracy: {test_accuracy}, Precision: {test_precision}, Recall: {test_recall}, F1 Score: {test_f1}", file=log_file_path)

    # Generate the confusion matrix
    cm = confusion_matrix(y_test, y_test_pred)
    logger(f"Confusion Matrix:\n {cm}", file=log_file_path)

# Calculate the overall average metrics
unseen_set_avg_f1 = np.mean(unseen_f1)
unseen_set_avg_loss = np.mean(unseen_losses)
unseen_set_avg_acc = np.mean(unseen_accuracies)
unseen_set_avg_precision = np.mean(unseen_precisions)
unseen_set_avg_recall = np.mean(unseen_recalls)

logger(f"\nFinal Average F1-Score across all UNSEEN TEST sets: {unseen_set_avg_f1}", file=log_file_path)
logger(f"\nFinal Average Loss across all UNSEEN TEST sets: {unseen_set_avg_loss}", file=log_file_path)
logger(f"\nFinal Average Accuracy across all UNSEEN TEST sets: {unseen_set_avg_acc}", file=log_file_path)
logger(f"\nFinal Average Precision across all UNSEEN TEST sets: {unseen_set_avg_precision}", file=log_file_path)
logger(f"\nFinal Average Recall across all UNSEEN TEST sets: {unseen_set_avg_recall}\n", file=log_file_path)

# Append averages to total lists
all_f1.append(unseen_set_avg_f1)
all_losses.append(unseen_set_avg_loss)
all_accuracies.append(unseen_set_avg_acc)
all_precisions.append(unseen_set_avg_precision)
all_recalls.append(unseen_set_avg_recall)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# outer_fold 1
# Train Set Group Distribution:
# 046A    45
# 000A    39
# 103A    33
# 002B    30
# 047A    22
#         ..
# 048A     1
# 066A     1
# 049A     1
# 026C     1
# 026B     1
# Name: cat_id, Length: 92, dtype: int64
# Testing Set Group Distribution:
# 020A    20
# 014B    10
# 025A    10
# 015A     7
# 023A     6
# 094A     5
# 021A     5
# 109A     5
# 104A     4
# 026A     4
# 023B     4
# 056A     3
# 058A     3
# 062A     3
# 053A     3
# 087A     2
# 093A     2
# 025B     2
# 091A     1
# 076A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    250
# M    235
# F    208
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# M    51
# X    26
# F    23
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [006A, 000A, 033A, 001A, 103A, 071A, 097B, 028...
# kitten    [044A, 111A, 040A, 046A, 047A, 042A, 050A, 043...
# senior    [097A, 057A, 106A, 055A, 059A, 113A, 116A, 051...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [015A, 020A, 062A, 091A, 023A, 025A, 087A, 076...
# kitten                                         [014B, 109A]
# senior                       [093A, 104A, 056A, 058A, 094A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 61, 'kitten': 14, 'senior': 17}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 13, 'kitten': 2, 'senior': 5}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '004A' '005A' '006A' '007A'
#  '008A' '009A' '010A' '011A' '012A' '013B' '014A' '016A' '018A' '019A'
#  '019B' '022A' '024A' '025C' '026B' '026C' '027A' '028A' '029A' '031A'
#  '032A' '033A' '034A' '035A' '036A' '037A' '038A' '039A' '040A' '041A'
#  '042A' '043A' '044A' '045A' '046A' '047A' '048A' '049A' '050A' '051A'
#  '051B' '052A' '054A' '055A' '057A' '059A' '060A' '061A' '063A' '064A'
#  '065A' '066A' '067A' '068A' '069A' '070A' '071A' '072A' '073A' '074A'
#  '075A' '088A' '090A' '092A' '095A' '096A' '097A' '097B' '099A' '100A'
#  '101A' '102A' '103A' '105A' '106A' '108A' '110A' '111A' '113A' '115A'
#  '116A' '117A']
# Unique Test Group IDs:
# ['014B' '015A' '020A' '021A' '023A' '023B' '025A' '025B' '026A' '053A'
#  '056A' '058A' '062A' '076A' '087A' '091A' '093A' '094A' '104A' '109A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '004A' '005A' '006A' '007A'
#  '008A' '009A' '010A' '011A' '012A' '013B' '014A' '016A' '018A' '019A'
#  '019B' '022A' '024A' '025C' '026B' '026C' '027A' '028A' '029A' '031A'
#  '032A' '033A' '034A' '035A' '036A' '037A' '038A' '039A' '040A' '041A'
#  '042A' '043A' '044A' '045A' '046A' '047A' '048A' '049A' '050A' '051A'
#  '051B' '052A' '054A' '055A' '057A' '059A' '060A' '061A' '063A' '064A'
#  '065A' '066A' '067A' '068A' '069A' '070A' '071A' '072A' '073A' '074A'
#  '075A' '088A' '090A' '092A' '095A' '096A' '097A' '097B' '099A' '100A'
#  '101A' '102A' '103A' '105A' '106A' '108A' '110A' '111A' '113A' '115A'
#  '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['014B' '015A' '020A' '021A' '023A' '023B' '025A' '025B' '026A' '053A'
#  '056A' '058A' '062A' '076A' '087A' '091A' '093A' '094A' '104A' '109A']
# Length of X_train_val:
# 693
# Length of y_train_val:
# 693
# Length of groups_train_val:
# 693
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     441
# senior    132
# kitten    120
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     68
# senior    17
# kitten    15
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     441
# senior    132
# kitten    120
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     68
# senior    17
# kitten    15
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 441, 2: 132, 1: 120})
# Epoch 1/1500
# 11/11 [==============================] - 1s 7ms/step - loss: 1.0739 - accuracy: 0.6248
# Epoch 2/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.2999 - accuracy: 0.9004
# Epoch 3/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1613 - accuracy: 0.9452
# Epoch 4/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0753 - accuracy: 0.9740
# Epoch 5/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0578 - accuracy: 0.9856
# Epoch 6/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0340 - accuracy: 0.9928
# Epoch 7/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0267 - accuracy: 0.9928
# Epoch 8/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0169 - accuracy: 0.9957
# Epoch 9/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0421 - accuracy: 0.9885
# Epoch 10/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0136 - accuracy: 0.9971
# Epoch 11/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0126 - accuracy: 0.9971
# Epoch 12/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0107 - accuracy: 0.9986
# Epoch 13/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0068 - accuracy: 1.0000
# Epoch 14/1500
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0088 - accuracy: 0.9986
# Epoch 15/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0046 - accuracy: 1.0000
# Epoch 16/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0078 - accuracy: 0.9986
# Epoch 17/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 18/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0139 - accuracy: 0.9957
# Epoch 19/1500
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 20/1500
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0054 - accuracy: 0.9986
# Epoch 21/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 22/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0045 - accuracy: 1.0000
# Epoch 23/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0040 - accuracy: 0.9986
# Epoch 24/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0081 - accuracy: 0.9971
# Epoch 25/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 26/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 27/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 28/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 29/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0052 - accuracy: 1.0000
# Epoch 30/1500
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 31/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 32/1500
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 33/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0038 - accuracy: 0.9986
# Epoch 34/1500
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 35/1500
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 36/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0039 - accuracy: 0.9986
# Epoch 37/1500
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 38/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0036 - accuracy: 0.9986
# Epoch 39/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0067 - accuracy: 0.9986
# Epoch 40/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 41/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 42/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0024 - accuracy: 0.9986
# Epoch 43/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0034 - accuracy: 0.9986
# Epoch 44/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 45/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 46/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 47/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 48/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 49/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 50/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 7.5276e-04 - accuracy: 1.0000
# Epoch 51/1500
# 11/11 [==============================] - 0s 8ms/step - loss: 8.5684e-04 - accuracy: 1.0000
# Epoch 52/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 6.1583e-04 - accuracy: 1.0000
# Epoch 53/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 54/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 5.9438e-04 - accuracy: 1.0000
# Epoch 55/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 7.4077e-04 - accuracy: 1.0000
# Epoch 56/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 4.2102e-04 - accuracy: 1.0000
# Epoch 57/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 6.9886e-04 - accuracy: 1.0000
# Epoch 58/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 4.9153e-04 - accuracy: 1.0000
# Epoch 59/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 5.2814e-04 - accuracy: 1.0000
# Epoch 60/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 8.2945e-04 - accuracy: 1.0000
# Epoch 61/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 5.2479e-04 - accuracy: 1.0000
# Epoch 62/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 3.5030e-04 - accuracy: 1.0000
# Epoch 63/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 4.7332e-04 - accuracy: 1.0000
# Epoch 64/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 3.7097e-04 - accuracy: 1.0000
# Epoch 65/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 6.6639e-04 - accuracy: 1.0000
# Epoch 66/1500
# 11/11 [==============================] - 0s 8ms/step - loss: 4.1303e-04 - accuracy: 1.0000
# Epoch 67/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 7.5503e-04 - accuracy: 1.0000
# Epoch 68/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 9.3202e-04 - accuracy: 1.0000
# Epoch 69/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 3.7219e-04 - accuracy: 1.0000
# Epoch 70/1500
# 11/11 [==============================] - 0s 8ms/step - loss: 5.3416e-04 - accuracy: 1.0000
# Epoch 71/1500
# 11/11 [==============================] - 0s 9ms/step - loss: 8.9349e-04 - accuracy: 1.0000
# Epoch 72/1500
# 11/11 [==============================] - 0s 8ms/step - loss: 5.0924e-04 - accuracy: 1.0000
# Epoch 73/1500
# 11/11 [==============================] - 0s 8ms/step - loss: 3.8403e-04 - accuracy: 1.0000
# Epoch 74/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 5.0604e-04 - accuracy: 1.0000
# Epoch 75/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 5.8874e-04 - accuracy: 1.0000
# Epoch 76/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 3.2560e-04 - accuracy: 1.0000
# Epoch 77/1500
#  8/11 [====================>.........] - ETA: 0s - loss: 6.5081e-04 - accuracy: 1.0000Restoring model weights from the end of the best epoch: 47.
# 11/11 [==============================] - 0s 9ms/step - loss: 6.6708e-04 - accuracy: 1.0000
# Epoch 77: early stopping
# 4/4 [==============================] - 0s 2ms/step - loss: 1.3019 - accuracy: 0.7700
# 4/4 [==============================] - 0s 2ms/step
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Majority Vote Accuracy for cat_id for this fold: 0.75 (15/20)
# Before appending - Cat IDs: 0, Predictions: 0, Actuals: 0, Gender: 0
# After appending - Cat IDs: 100, Predictions: 100, Actuals: 100, Gender: 100
# Final Test Results - Loss: 1.301863431930542, Accuracy: 0.7699999809265137, Precision: 0.7798461156614543, Recall: 0.5790849673202615, F1 Score: 0.6070708985348525
# Confusion Matrix:
#  [[64  0  4]
#  [ 7  4  4]
#  [ 8  0  9]]
# outer_fold 2
# Train Set Group Distribution:
# 000A    39
# 103A    33
# 002B    30
# 047A    22
# 020A    20
#         ..
# 096A     1
# 026C     1
# 049A     1
# 091A     1
# 026B     1
# Name: cat_id, Length: 87, dtype: int64
# Testing Set Group Distribution:
# 046A    45
# 019A    17
# 002A    13
# 111A    12
# 028A    11
# 040A    10
# 033A     9
# 016A     9
# 072A     9
# 051B     9
# 068A     8
# 027A     7
# 007A     6
# 099A     6
# 039A     6
# 105A     3
# 034A     3
# 012A     3
# 010A     3
# 069A     2
# 032A     2
# 054A     2
# 102A     2
# 019B     1
# 024A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    234
# F    201
# X    159
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    117
# M     52
# F     30
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [006A, 000A, 015A, 001A, 103A, 071A, 097B, 074...
# kitten    [044A, 014B, 047A, 042A, 109A, 050A, 043A, 049...
# senior    [093A, 097A, 057A, 106A, 104A, 055A, 059A, 113...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [033A, 028A, 019A, 034A, 072A, 002A, 039A, 027...
# kitten                                   [111A, 040A, 046A]
# senior                             [051B, 054A, 016A, 024A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 56, 'kitten': 13, 'senior': 18}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 18, 'kitten': 3, 'senior': 4}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002B' '003A' '004A' '005A' '006A' '008A' '009A'
#  '011A' '013B' '014A' '014B' '015A' '018A' '020A' '021A' '022A' '023A'
#  '023B' '025A' '025B' '025C' '026A' '026B' '026C' '029A' '031A' '035A'
#  '036A' '037A' '038A' '041A' '042A' '043A' '044A' '045A' '047A' '048A'
#  '049A' '050A' '051A' '052A' '053A' '055A' '056A' '057A' '058A' '059A'
#  '060A' '061A' '062A' '063A' '064A' '065A' '066A' '067A' '070A' '071A'
#  '073A' '074A' '075A' '076A' '087A' '088A' '090A' '091A' '092A' '093A'
#  '094A' '095A' '096A' '097A' '097B' '100A' '101A' '103A' '104A' '106A'
#  '108A' '109A' '110A' '113A' '115A' '116A' '117A']
# Unique Test Group IDs:
# ['002A' '007A' '010A' '012A' '016A' '019A' '019B' '024A' '027A' '028A'
#  '032A' '033A' '034A' '039A' '040A' '046A' '051B' '054A' '068A' '069A'
#  '072A' '099A' '102A' '105A' '111A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'046A'}
# Removed from Training/Validation Set:
# {'044A'}
# Moved to Test Set:
# {'044A'}
# Removed from Test Set
# {'046A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002B' '003A' '004A' '005A' '006A' '008A' '009A'
#  '011A' '013B' '014A' '014B' '015A' '018A' '020A' '021A' '022A' '023A'
#  '023B' '025A' '025B' '025C' '026A' '026B' '026C' '029A' '031A' '035A'
#  '036A' '037A' '038A' '041A' '042A' '043A' '045A' '046A' '047A' '048A'
#  '049A' '050A' '051A' '052A' '053A' '055A' '056A' '057A' '058A' '059A'
#  '060A' '061A' '062A' '063A' '064A' '065A' '066A' '067A' '070A' '071A'
#  '073A' '074A' '075A' '076A' '087A' '088A' '090A' '091A' '092A' '093A'
#  '094A' '095A' '096A' '097A' '097B' '100A' '101A' '103A' '104A' '106A'
#  '108A' '109A' '110A' '113A' '115A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['002A' '007A' '010A' '012A' '016A' '019A' '019B' '024A' '027A' '028A'
#  '032A' '033A' '034A' '039A' '040A' '044A' '051B' '054A' '068A' '069A'
#  '072A' '099A' '102A' '105A' '111A']
# Length of X_train_val:
# 634
# Length of y_train_val:
# 634
# Length of groups_train_val:
# 634
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     398
# senior    128
# kitten     68
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     111
# kitten     67
# senior     21
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     398
# senior    128
# kitten    108
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     111
# kitten     27
# senior     21
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 398, 2: 128, 1: 108})
# Epoch 1/1500
# 10/10 [==============================] - 1s 7ms/step - loss: 0.9606 - accuracy: 0.6435
# Epoch 2/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2233 - accuracy: 0.9243
# Epoch 3/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1228 - accuracy: 0.9543
# Epoch 4/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0558 - accuracy: 0.9842
# Epoch 5/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0467 - accuracy: 0.9937
# Epoch 6/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0258 - accuracy: 0.9968
# Epoch 7/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0161 - accuracy: 0.9968
# Epoch 8/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0292 - accuracy: 0.9905
# Epoch 9/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0236 - accuracy: 0.9953
# Epoch 10/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0100 - accuracy: 0.9984
# Epoch 11/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0085 - accuracy: 0.9984
# Epoch 12/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0097 - accuracy: 0.9984
# Epoch 13/1500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0054 - accuracy: 1.0000
# Epoch 14/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0042 - accuracy: 1.0000
# Epoch 15/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0050 - accuracy: 1.0000
# Epoch 16/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 17/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0053 - accuracy: 1.0000
# Epoch 18/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0089 - accuracy: 0.9968
# Epoch 19/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 20/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 21/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0073 - accuracy: 0.9984
# Epoch 22/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0040 - accuracy: 0.9984
# Epoch 23/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0036 - accuracy: 0.9984
# Epoch 24/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0041 - accuracy: 0.9984
# Epoch 25/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 26/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 27/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0092 - accuracy: 0.9968
# Epoch 28/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 29/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 30/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0049 - accuracy: 0.9984
# Epoch 31/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 32/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 33/1500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 34/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 35/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 36/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 37/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 38/1500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 39/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 40/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 41/1500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 42/1500
# 10/10 [==============================] - 0s 9ms/step - loss: 9.5094e-04 - accuracy: 1.0000
# Epoch 43/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 44/1500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 45/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0019 - accuracy: 0.9984
# Epoch 46/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 47/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 6.3730e-04 - accuracy: 1.0000
# Epoch 48/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 4.9570e-04 - accuracy: 1.0000
# Epoch 49/1500
# 10/10 [==============================] - 0s 8ms/step - loss: 5.2131e-04 - accuracy: 1.0000
# Epoch 50/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 8.7939e-04 - accuracy: 1.0000
# Epoch 51/1500
# 10/10 [==============================] - 0s 8ms/step - loss: 6.3099e-04 - accuracy: 1.0000
# Epoch 52/1500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0041 - accuracy: 0.9984
# Epoch 53/1500
# 10/10 [==============================] - 0s 8ms/step - loss: 8.1756e-04 - accuracy: 1.0000
# Epoch 54/1500
# 10/10 [==============================] - 0s 8ms/step - loss: 7.1601e-04 - accuracy: 1.0000
# Epoch 55/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 56/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 7.5567e-04 - accuracy: 1.0000
# Epoch 57/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 7.0673e-04 - accuracy: 1.0000
# Epoch 58/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 9.0822e-04 - accuracy: 1.0000
# Epoch 59/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 60/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 61/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 62/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 4.8969e-04 - accuracy: 1.0000
# Epoch 63/1500
# 10/10 [==============================] - 0s 9ms/step - loss: 4.1767e-04 - accuracy: 1.0000
# Epoch 64/1500
# 10/10 [==============================] - 0s 8ms/step - loss: 6.1106e-04 - accuracy: 1.0000
# Epoch 65/1500
#  8/10 [=======================>......] - ETA: 0s - loss: 0.0025 - accuracy: 0.9980    Restoring model weights from the end of the best epoch: 35.
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0021 - accuracy: 0.9984
# Epoch 65: early stopping
# 5/5 [==============================] - 0s 2ms/step - loss: 1.1357 - accuracy: 0.8050
# 5/5 [==============================] - 0s 2ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.80 (20/25)
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Before appending - Cat IDs: 100, Predictions: 100, Actuals: 100, Gender: 100
# After appending - Cat IDs: 259, Predictions: 259, Actuals: 259, Gender: 259
# Final Test Results - Loss: 1.135689616203308, Accuracy: 0.805031418800354, Precision: 0.6317434059369543, Recall: 0.6308212974879642, F1 Score: 0.6260493331549133
# Confusion Matrix:
#  [[102   1   8]
#  [  2  25   0]
#  [ 20   0   1]]
# outer_fold 3
# Train Set Group Distribution:
# 046A    45
# 002B    30
# 020A    20
# 019A    17
# 074A    16
#         ..
# 026C     1
# 041A     1
# 092A     1
# 049A     1
# 026B     1
# Name: cat_id, Length: 89, dtype: int64
# Testing Set Group Distribution:
# 000A    39
# 103A    33
# 047A    22
# 000B    19
# 057A    17
# 097A    15
# 097B    14
# 106A    13
# 051A    12
# 116A    12
# 059A    10
# 071A     9
# 031A     7
# 075A     5
# 060A     3
# 052A     2
# 035A     2
# 011A     2
# 064A     1
# 066A     1
# 088A     1
# 115A     1
# 100A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    222
# X    195
# F    135
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# F    96
# X    81
# M    64
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [006A, 033A, 015A, 001A, 028A, 019A, 074A, 067...
# kitten    [044A, 014B, 111A, 040A, 046A, 042A, 109A, 050...
# senior    [093A, 104A, 055A, 113A, 051B, 054A, 117A, 056...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [000A, 103A, 071A, 097B, 000B, 031A, 075A, 064...
# kitten                                         [047A, 115A]
# senior           [097A, 057A, 106A, 059A, 116A, 051A, 011A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 60, 'kitten': 14, 'senior': 15}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 14, 'kitten': 2, 'senior': 7}
# Unique Training/Validation Group IDs:
# ['001A' '002A' '002B' '003A' '004A' '005A' '006A' '007A' '008A' '009A'
#  '010A' '012A' '013B' '014A' '014B' '015A' '016A' '018A' '019A' '019B'
#  '020A' '021A' '022A' '023A' '023B' '024A' '025A' '025B' '025C' '026A'
#  '026B' '026C' '027A' '028A' '029A' '032A' '033A' '034A' '036A' '037A'
#  '038A' '039A' '040A' '041A' '042A' '043A' '044A' '045A' '046A' '048A'
#  '049A' '050A' '051B' '053A' '054A' '055A' '056A' '058A' '061A' '062A'
#  '063A' '065A' '067A' '068A' '069A' '070A' '072A' '073A' '074A' '076A'
#  '087A' '090A' '091A' '092A' '093A' '094A' '095A' '096A' '099A' '101A'
#  '102A' '104A' '105A' '108A' '109A' '110A' '111A' '113A' '117A']
# Unique Test Group IDs:
# ['000A' '000B' '011A' '031A' '035A' '047A' '051A' '052A' '057A' '059A'
#  '060A' '064A' '066A' '071A' '075A' '088A' '097A' '097B' '100A' '103A'
#  '106A' '115A' '116A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'000A'}
# Removed from Training/Validation Set:
# {'038A'}
# Moved to Test Set:
# {'038A'}
# Removed from Test Set
# {'000A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '001A' '002A' '002B' '003A' '004A' '005A' '006A' '007A' '008A'
#  '009A' '010A' '012A' '013B' '014A' '014B' '015A' '016A' '018A' '019A'
#  '019B' '020A' '021A' '022A' '023A' '023B' '024A' '025A' '025B' '025C'
#  '026A' '026B' '026C' '027A' '028A' '029A' '032A' '033A' '034A' '036A'
#  '037A' '039A' '040A' '041A' '042A' '043A' '044A' '045A' '046A' '048A'
#  '049A' '050A' '051B' '053A' '054A' '055A' '056A' '058A' '061A' '062A'
#  '063A' '065A' '067A' '068A' '069A' '070A' '072A' '073A' '074A' '076A'
#  '087A' '090A' '091A' '092A' '093A' '094A' '095A' '096A' '099A' '101A'
#  '102A' '104A' '105A' '108A' '109A' '110A' '111A' '113A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['000B' '011A' '031A' '035A' '038A' '047A' '051A' '052A' '057A' '059A'
#  '060A' '064A' '066A' '071A' '075A' '088A' '097A' '097B' '100A' '103A'
#  '106A' '115A' '116A']
# Length of X_train_val:
# 589
# Length of y_train_val:
# 589
# Length of groups_train_val:
# 589
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     372
# kitten    112
# senior     68
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     137
# senior     81
# kitten     23
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     409
# kitten    112
# senior     68
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     100
# senior     81
# kitten     23
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 409, 1: 112, 2: 68})
# Epoch 1/1500
# 10/10 [==============================] - 1s 6ms/step - loss: 1.0889 - accuracy: 0.6553
# Epoch 2/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2639 - accuracy: 0.8862
# Epoch 3/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1238 - accuracy: 0.9643
# Epoch 4/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0753 - accuracy: 0.9762
# Epoch 5/1500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0415 - accuracy: 0.9881
# Epoch 6/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0301 - accuracy: 0.9881
# Epoch 7/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0272 - accuracy: 0.9932
# Epoch 8/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0129 - accuracy: 0.9983
# Epoch 9/1500
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0127 - accuracy: 0.9966
# Epoch 10/1500
# 10/10 [==============================] - 0s 25ms/step - loss: 0.0092 - accuracy: 1.0000
# Epoch 11/1500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0128 - accuracy: 0.9966
# Epoch 12/1500
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0093 - accuracy: 0.9983
# Epoch 13/1500
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0140 - accuracy: 0.9949
# Epoch 14/1500
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0068 - accuracy: 1.0000
# Epoch 15/1500
# 10/10 [==============================] - 0s 9ms/step - loss: 0.0122 - accuracy: 0.9983
# Epoch 16/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0093 - accuracy: 1.0000
# Epoch 17/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0156 - accuracy: 0.9966
# Epoch 18/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0276 - accuracy: 0.9949
# Epoch 19/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0122 - accuracy: 0.9949
# Epoch 20/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0196 - accuracy: 0.9966
# Epoch 21/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0204 - accuracy: 0.9949
# Epoch 22/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0197 - accuracy: 0.9966
# Epoch 23/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0077 - accuracy: 0.9983
# Epoch 24/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0064 - accuracy: 1.0000
# Epoch 25/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0078 - accuracy: 0.9983
# Epoch 26/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0105 - accuracy: 0.9966
# Epoch 27/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0046 - accuracy: 1.0000
# Epoch 28/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0121 - accuracy: 0.9966
# Epoch 29/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0137 - accuracy: 0.9949
# Epoch 30/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0618 - accuracy: 0.9915
# Epoch 31/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0172 - accuracy: 0.9983
# Epoch 32/1500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0231 - accuracy: 0.9949
# Epoch 33/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0105 - accuracy: 0.9966
# Epoch 34/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0154 - accuracy: 0.9949
# Epoch 35/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0098 - accuracy: 0.9966
# Epoch 36/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0084 - accuracy: 0.9983
# Epoch 37/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0058 - accuracy: 0.9983
# Epoch 38/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 39/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0078 - accuracy: 0.9983
# Epoch 40/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0041 - accuracy: 0.9983
# Epoch 41/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0043 - accuracy: 0.9983
# Epoch 42/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 43/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 44/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0050 - accuracy: 0.9983
# Epoch 45/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 46/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0032 - accuracy: 0.9983
# Epoch 47/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 48/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 49/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0037 - accuracy: 0.9983
# Epoch 50/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0094 - accuracy: 0.9966
# Epoch 51/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0049 - accuracy: 0.9983
# Epoch 52/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0053 - accuracy: 0.9983
# Epoch 53/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0080 - accuracy: 0.9966
# Epoch 54/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0044 - accuracy: 0.9983
# Epoch 55/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0293 - accuracy: 0.9898
# Epoch 56/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0127 - accuracy: 0.9966
# Epoch 57/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 58/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0190 - accuracy: 0.9966
# Epoch 59/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0077 - accuracy: 0.9983
# Epoch 60/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0077 - accuracy: 0.9983
# Epoch 61/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0199 - accuracy: 0.9915
# Epoch 62/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 63/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 64/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 65/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 66/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0087 - accuracy: 0.9966
# Epoch 67/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 8.1250e-04 - accuracy: 1.0000
# Epoch 68/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 69/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 70/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 71/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 72/1500
# 10/10 [==============================] - ETA: 0s - loss: 0.0066 - accuracy: 0.9983Restoring model weights from the end of the best epoch: 42.
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0066 - accuracy: 0.9983
# Epoch 72: early stopping
# 7/7 [==============================] - 0s 2ms/step - loss: 2.9908 - accuracy: 0.5490
# 7/7 [==============================] - 0s 2ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.70 (16/23)
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Before appending - Cat IDs: 259, Predictions: 259, Actuals: 259, Gender: 259
# After appending - Cat IDs: 463, Predictions: 463, Actuals: 463, Gender: 463
# Final Test Results - Loss: 2.990849256515503, Accuracy: 0.5490196347236633, Precision: 0.673758865248227, Recall: 0.40503488996242615, F1 Score: 0.36225607327757864
# Confusion Matrix:
#  [[98  2  0]
#  [21  2  0]
#  [69  0 12]]
# outer_fold 4
# Train Set Group Distribution:
# 046A    45
# 000A    39
# 103A    33
# 047A    22
# 020A    20
#         ..
# 004A     1
# 066A     1
# 043A     1
# 091A     1
# 024A     1
# Name: cat_id, Length: 89, dtype: int64
# Testing Set Group Distribution:
# 002B    30
# 029A    15
# 067A    11
# 063A    11
# 042A    11
# 065A     9
# 095A     7
# 044A     5
# 108A     5
# 070A     5
# 025C     4
# 006A     3
# 018A     2
# 038A     2
# 037A     2
# 096A     1
# 049A     1
# 092A     1
# 041A     1
# 026C     1
# 048A     1
# 090A     1
# 026B     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    243
# M    212
# F    208
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# M    74
# X    33
# F    23
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [000A, 033A, 015A, 001A, 103A, 071A, 097B, 028...
# kitten    [014B, 111A, 040A, 046A, 047A, 109A, 050A, 043...
# senior    [093A, 097A, 057A, 106A, 104A, 055A, 059A, 113...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [006A, 067A, 002B, 029A, 095A, 065A, 063A, 038...
# kitten                       [044A, 042A, 049A, 041A, 048A]
# senior                                         [108A, 090A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 58, 'kitten': 11, 'senior': 20}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 16, 'kitten': 5, 'senior': 2}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '003A' '004A' '005A' '007A' '008A' '009A'
#  '010A' '011A' '012A' '013B' '014A' '014B' '015A' '016A' '019A' '019B'
#  '020A' '021A' '022A' '023A' '023B' '024A' '025A' '025B' '026A' '027A'
#  '028A' '031A' '032A' '033A' '034A' '035A' '036A' '039A' '040A' '043A'
#  '045A' '046A' '047A' '050A' '051A' '051B' '052A' '053A' '054A' '055A'
#  '056A' '057A' '058A' '059A' '060A' '061A' '062A' '064A' '066A' '068A'
#  '069A' '071A' '072A' '073A' '074A' '075A' '076A' '087A' '088A' '091A'
#  '093A' '094A' '097A' '097B' '099A' '100A' '101A' '102A' '103A' '104A'
#  '105A' '106A' '109A' '110A' '111A' '113A' '115A' '116A' '117A']
# Unique Test Group IDs:
# ['002B' '006A' '018A' '025C' '026B' '026C' '029A' '037A' '038A' '041A'
#  '042A' '044A' '048A' '049A' '063A' '065A' '067A' '070A' '090A' '092A'
#  '095A' '096A' '108A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '003A' '004A' '005A' '007A' '008A' '009A'
#  '010A' '011A' '012A' '013B' '014A' '014B' '015A' '016A' '019A' '019B'
#  '020A' '021A' '022A' '023A' '023B' '024A' '025A' '025B' '026A' '027A'
#  '028A' '031A' '032A' '033A' '034A' '035A' '036A' '039A' '040A' '043A'
#  '045A' '046A' '047A' '050A' '051A' '051B' '052A' '053A' '054A' '055A'
#  '056A' '057A' '058A' '059A' '060A' '061A' '062A' '064A' '066A' '068A'
#  '069A' '071A' '072A' '073A' '074A' '075A' '076A' '087A' '088A' '091A'
#  '093A' '094A' '097A' '097B' '099A' '100A' '101A' '102A' '103A' '104A'
#  '105A' '106A' '109A' '110A' '111A' '113A' '115A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['002B' '006A' '018A' '025C' '026B' '026C' '029A' '037A' '038A' '041A'
#  '042A' '044A' '048A' '049A' '063A' '065A' '067A' '070A' '090A' '092A'
#  '095A' '096A' '108A']
# Length of X_train_val:
# 663
# Length of y_train_val:
# 663
# Length of groups_train_val:
# 663
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     404
# senior    143
# kitten    116
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     105
# kitten     19
# senior      6
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     404
# senior    143
# kitten    116
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     105
# kitten     19
# senior      6
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 404, 2: 143, 1: 116})
# Epoch 1/1500
# 11/11 [==============================] - 1s 5ms/step - loss: 0.8877 - accuracy: 0.6893
# Epoch 2/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.2472 - accuracy: 0.9005
# Epoch 3/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1291 - accuracy: 0.9502
# Epoch 4/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0821 - accuracy: 0.9744
# Epoch 5/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0446 - accuracy: 0.9879
# Epoch 6/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0396 - accuracy: 0.9894
# Epoch 7/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0211 - accuracy: 0.9925
# Epoch 8/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0160 - accuracy: 0.9970
# Epoch 9/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0160 - accuracy: 0.9970
# Epoch 10/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0185 - accuracy: 0.9970
# Epoch 11/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0123 - accuracy: 0.9970
# Epoch 12/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0070 - accuracy: 0.9985
# Epoch 13/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0107 - accuracy: 0.9970
# Epoch 14/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0066 - accuracy: 1.0000
# Epoch 15/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0054 - accuracy: 1.0000
# Epoch 16/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 17/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0068 - accuracy: 1.0000
# Epoch 18/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0043 - accuracy: 1.0000
# Epoch 19/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0040 - accuracy: 1.0000
# Epoch 20/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0074 - accuracy: 0.9985
# Epoch 21/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0073 - accuracy: 0.9970
# Epoch 22/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 23/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 24/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 25/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0042 - accuracy: 1.0000
# Epoch 26/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0044 - accuracy: 0.9985
# Epoch 27/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0128 - accuracy: 0.9970
# Epoch 28/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 29/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0058 - accuracy: 0.9985
# Epoch 30/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 31/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 32/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0074 - accuracy: 0.9985
# Epoch 33/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 34/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0105 - accuracy: 0.9955
# Epoch 35/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 36/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 37/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0039 - accuracy: 0.9985
# Epoch 38/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 39/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 40/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 41/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0020 - accuracy: 0.9985
# Epoch 42/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 43/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 9.1124e-04 - accuracy: 1.0000
# Epoch 44/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 7.8339e-04 - accuracy: 1.0000
# Epoch 45/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 46/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 4.4198e-04 - accuracy: 1.0000
# Epoch 47/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 7.5744e-04 - accuracy: 1.0000
# Epoch 48/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0018 - accuracy: 0.9985
# Epoch 49/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0044 - accuracy: 0.9970
# Epoch 50/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 51/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 52/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0043 - accuracy: 0.9985
# Epoch 53/1500
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0069 - accuracy: 0.9985
# Epoch 54/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0107 - accuracy: 0.9970
# Epoch 55/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 56/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0039 - accuracy: 0.9985
# Epoch 57/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0084 - accuracy: 0.9985
# Epoch 58/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 7.1457e-04 - accuracy: 1.0000
# Epoch 59/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0041 - accuracy: 0.9985
# Epoch 60/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 61/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 62/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 63/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 64/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 65/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 3.5872e-04 - accuracy: 1.0000
# Epoch 66/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 6.7922e-04 - accuracy: 1.0000
# Epoch 67/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 7.2930e-04 - accuracy: 1.0000
# Epoch 68/1500
# ...
# Epoch 75/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0082 - accuracy: 0.9985
# Epoch 76/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0092 - accuracy: 0.9985
# Epoch 77/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0021 - accuracy: 0.9985
# Epoch 78/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0054 - accuracy: 0.9985
# Epoch 79/1500
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0235 - accuracy: 0.9970
# Epoch 80/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0045 - accuracy: 0.9970
# Epoch 81/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0114 - accuracy: 0.9985
# Epoch 82/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0051 - accuracy: 0.9970
# Epoch 83/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 84/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 85/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0072 - accuracy: 0.9985
# Epoch 86/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0034 - accuracy: 0.9985
# Epoch 87/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 88/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0075 - accuracy: 0.9970
# Epoch 89/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0049 - accuracy: 0.9985
# Epoch 90/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 91/1500
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0026 - accuracy: 0.9985
# Epoch 92/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 93/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 6.1470e-04 - accuracy: 1.0000
# Epoch 94/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 95/1500
#  9/11 [=======================>......] - ETA: 0s - loss: 6.1604e-04 - accuracy: 1.0000Restoring model weights from the end of the best epoch: 65.
# 11/11 [==============================] - 0s 7ms/step - loss: 7.4816e-04 - accuracy: 1.0000
# Epoch 95: early stopping
# 5/5 [==============================] - 0s 2ms/step - loss: 1.4700 - accuracy: 0.7231
# 5/5 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.87 (20/23)
# Before appending - Cat IDs: 463, Predictions: 463, Actuals: 463, Gender: 463
# After appending - Cat IDs: 593, Predictions: 593, Actuals: 593, Gender: 593
# Final Test Results - Loss: 1.4699819087982178, Accuracy: 0.7230769395828247, Precision: 0.6052393857271906, Recall: 0.7471177944862156, F1 Score: 0.5977715683598036
# Confusion Matrix:
#  [[76  5 24]
#  [ 5 13  1]
#  [ 1  0  5]]
# outer_fold 5
# Train Set Group Distribution:
# 046A    45
# 000A    39
# 103A    33
# 002B    30
# 047A    22
#         ..
# 066A     1
# 091A     1
# 026C     1
# 049A     1
# 026B     1
# Name: cat_id, Length: 91, dtype: int64
# Testing Set Group Distribution:
# 074A    16
# 101A    12
# 055A    12
# 001A     9
# 022A     9
# 005A     9
# 013B     8
# 036A     7
# 117A     7
# 050A     5
# 008A     5
# 009A     4
# 003A     4
# 045A     4
# 113A     3
# 014A     3
# 061A     2
# 043A     1
# 073A     1
# 004A     1
# 110A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    257
# M    241
# F    172
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# F    59
# M    45
# X    19
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [006A, 000A, 033A, 015A, 103A, 071A, 097B, 028...
# kitten    [044A, 014B, 111A, 040A, 046A, 047A, 042A, 109...
# senior    [093A, 097A, 057A, 106A, 104A, 059A, 116A, 051...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [001A, 074A, 101A, 022A, 005A, 009A, 013B, 014...
# kitten                             [050A, 043A, 045A, 110A]
# senior                             [055A, 113A, 117A, 061A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 61, 'kitten': 12, 'senior': 18}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 13, 'kitten': 4, 'senior': 4}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '002A' '002B' '006A' '007A' '010A' '011A' '012A' '014B'
#  '015A' '016A' '018A' '019A' '019B' '020A' '021A' '023A' '023B' '024A'
#  '025A' '025B' '025C' '026A' '026B' '026C' '027A' '028A' '029A' '031A'
#  '032A' '033A' '034A' '035A' '037A' '038A' '039A' '040A' '041A' '042A'
#  '044A' '046A' '047A' '048A' '049A' '051A' '051B' '052A' '053A' '054A'
#  '056A' '057A' '058A' '059A' '060A' '062A' '063A' '064A' '065A' '066A'
#  '067A' '068A' '069A' '070A' '071A' '072A' '075A' '076A' '087A' '088A'
#  '090A' '091A' '092A' '093A' '094A' '095A' '096A' '097A' '097B' '099A'
#  '100A' '102A' '103A' '104A' '105A' '106A' '108A' '109A' '111A' '115A'
#  '116A']
# Unique Test Group IDs:
# ['001A' '003A' '004A' '005A' '008A' '009A' '013B' '014A' '022A' '036A'
#  '043A' '045A' '050A' '055A' '061A' '073A' '074A' '101A' '110A' '113A'
#  '117A']
# No common groups found between train and test sets.
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '002A' '002B' '006A' '007A' '010A' '011A' '012A' '014B'
#  '015A' '016A' '018A' '019A' '019B' '020A' '021A' '023A' '023B' '024A'
#  '025A' '025B' '025C' '026A' '026B' '026C' '027A' '028A' '029A' '031A'
#  '032A' '033A' '034A' '035A' '037A' '038A' '039A' '040A' '041A' '042A'
#  '044A' '046A' '047A' '048A' '049A' '051A' '051B' '052A' '053A' '054A'
#  '056A' '057A' '058A' '059A' '060A' '062A' '063A' '064A' '065A' '066A'
#  '067A' '068A' '069A' '070A' '071A' '072A' '075A' '076A' '087A' '088A'
#  '090A' '091A' '092A' '093A' '094A' '095A' '096A' '097A' '097B' '099A'
#  '100A' '102A' '103A' '104A' '105A' '106A' '108A' '109A' '111A' '115A'
#  '116A']
# AFTER SWAP - Unique Test Group IDs:
# ['001A' '003A' '004A' '005A' '008A' '009A' '013B' '014A' '022A' '036A'
#  '043A' '045A' '050A' '055A' '061A' '073A' '074A' '101A' '110A' '113A'
#  '117A']
# Length of X_train_val:
# 670
# Length of y_train_val:
# 670
# Length of groups_train_val:
# 670
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     421
# senior    125
# kitten    124
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     88
# senior    24
# kitten    11
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     421
# senior    125
# kitten    124
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     88
# senior    24
# kitten    11
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 421, 2: 125, 1: 124})
# Epoch 1/1500
# 11/11 [==============================] - 1s 6ms/step - loss: 1.0785 - accuracy: 0.6269
# Epoch 2/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.2982 - accuracy: 0.9090
# Epoch 3/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1388 - accuracy: 0.9522
# Epoch 4/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0557 - accuracy: 0.9851
# Epoch 5/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0351 - accuracy: 0.9881
# Epoch 6/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0311 - accuracy: 0.9925
# Epoch 7/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0268 - accuracy: 0.9910
# Epoch 8/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0243 - accuracy: 0.9970
# Epoch 9/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0188 - accuracy: 0.9940
# Epoch 10/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0187 - accuracy: 0.9970
# Epoch 11/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0099 - accuracy: 0.9985
# Epoch 12/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 13/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0118 - accuracy: 0.9970
# Epoch 14/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0054 - accuracy: 1.0000
# Epoch 15/1500
# 11/11 [==============================] - 0s 29ms/step - loss: 0.0097 - accuracy: 0.9985
# Epoch 16/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0088 - accuracy: 0.9970
# Epoch 17/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0106 - accuracy: 0.9985
# Epoch 18/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0085 - accuracy: 0.9955
# Epoch 19/1500
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 20/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0109 - accuracy: 0.9955
# Epoch 21/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0044 - accuracy: 1.0000
# Epoch 22/1500
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0068 - accuracy: 0.9985
# Epoch 23/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 24/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0048 - accuracy: 0.9985
# Epoch 25/1500
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 26/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0140 - accuracy: 0.9970
# Epoch 27/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0060 - accuracy: 1.0000
# Epoch 28/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0086 - accuracy: 0.9985
# Epoch 29/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0044 - accuracy: 0.9985
# Epoch 30/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 31/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0028 - accuracy: 0.9985
# Epoch 32/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 33/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 34/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0056 - accuracy: 0.9985
# Epoch 35/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 36/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 37/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 38/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 39/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0060 - accuracy: 0.9985
# Epoch 40/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 41/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 42/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0045 - accuracy: 0.9985
# Epoch 43/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 44/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 45/1500
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0061 - accuracy: 0.9985
# Epoch 46/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 9.7702e-04 - accuracy: 1.0000
# Epoch 47/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 48/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 49/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 50/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0037 - accuracy: 0.9985
# Epoch 51/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 52/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 53/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 54/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 8.3092e-04 - accuracy: 1.0000
# Epoch 55/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 56/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 57/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 6.8386e-04 - accuracy: 1.0000
# Epoch 58/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 4.3576e-04 - accuracy: 1.0000
# Epoch 59/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 60/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 61/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 8.9653e-04 - accuracy: 1.0000
# Epoch 62/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 6.7361e-04 - accuracy: 1.0000
# Epoch 63/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 6.2275e-04 - accuracy: 1.0000
# Epoch 64/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 4.8743e-04 - accuracy: 1.0000
# Epoch 65/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 9.0965e-04 - accuracy: 1.0000
# Epoch 66/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 5.6654e-04 - accuracy: 1.0000
# Epoch 67/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 68/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 5.2304e-04 - accuracy: 1.0000
# Epoch 69/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 7.4062e-04 - accuracy: 1.0000
# Epoch 70/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 8.3079e-04 - accuracy: 1.0000
# Epoch 71/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 7.5567e-04 - accuracy: 1.0000
# Epoch 72/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 9.9571e-04 - accuracy: 1.0000
# Epoch 73/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 74/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 5.3735e-04 - accuracy: 1.0000
# Epoch 75/1500
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 76/1500
#  8/11 [====================>.........] - ETA: 0s - loss: 5.2687e-04 - accuracy: 1.0000Restoring model weights from the end of the best epoch: 46.
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 76: early stopping
# 4/4 [==============================] - 0s 2ms/step - loss: 2.0705 - accuracy: 0.7236
# 4/4 [==============================] - 0s 2ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.76 (16/21)
# Before appending - Cat IDs: 593, Predictions: 593, Actuals: 593, Gender: 593
# After appending - Cat IDs: 716, Predictions: 716, Actuals: 716, Gender: 716
# Final Test Results - Loss: 2.0704755783081055, Accuracy: 0.7235772609710693, Precision: 0.7009155306067897, Recall: 0.6439393939393939, F1 Score: 0.6647566650306094
# Confusion Matrix:
#  [[70  1 17]
#  [ 4  7  0]
#  [12  0 12]]
#
# Final Average F1-Score across all UNSEEN TEST sets: 0.5715809076715515
#
# Final Average Loss across all UNSEEN TEST sets: 1.7937719583511353
#
# Final Average Accuracy across all UNSEEN TEST sets: 0.714141047000885
#
# Final Average Precision across all UNSEEN TEST sets: 0.6783006606361233
#
# Final Average Recall across all UNSEEN TEST sets: 0.6011996686392523

# %%
seed_1_folds_values = (unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1)

# Plotting all fold metrics
seed_1_folds_plot = plot_all_metrics(unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1, "Folds", "Fold Number")

# %% [markdown]
# ## Majority Voting on Total Entries per cat_id

# %%
# Debugging print statements
print(f'Checking - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
# Out:
# Checking - Cat IDs: 716, Predictions: 716, Actuals: 716, Gender: 716

# %%
# Create results df
full_results = pd.DataFrame({
    'cat_id': all_cat_ids,
    'predicted_age_group': all_predicted_age_groups,
    'actual_age_group': all_actual_age_groups,
    'all_gender': all_gender
})

# create a correct majority prediction column
full_results['correct'] = full_results['predicted_age_group'] == full_results['actual_age_group']

# %%
# Group by cat_id and aggregate predicted age groups
majority_votes = full_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first()

# Calculate the accuracy of majority voting
correct_predictions = (majority_votes == actual_groups).sum()
total_cats = len(actual_groups)
majority_vote_accuracy = correct_predictions / total_cats

logger(f"Overall Majority Vote Accuracy for cat_id: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

# store for final evaluation 
all_majority_vote_accuracies.append(majority_vote_accuracy)
# Out:
# Overall Majority Vote Accuracy for cat_id: 0.77 (85/110)

# %%
# Detailed df with predictions, actual labels, and comparison including majority vote
detailed_results = full_results.groupby('cat_id').apply(
    lambda x: pd.Series({
        'Predictions': list(x['predicted_age_group']),
        'Majority Vote': x['predicted_age_group'].mode()[0],
        'Actual Age Group': x['actual_age_group'].iloc[0],
        'Correct Majority Vote': x['predicted_age_group'].mode()[0] == x['actual_age_group'].iloc[0]
    })
).reset_index()

# Convert to DataFrame for better formatting and display
detailed_results = pd.DataFrame(detailed_results)

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 10)
pd.set_option('display.width', 1000)

sorted_detailed_results = detailed_results.sort_values(by='Correct Majority Vote', ascending=False)

# Display the sorted DataFrame
sorted_detailed_results
# Out:
#     cat_id                                        Predictions Majority Vote Actual Age Group  Correct Majority Vote
# 0     000B  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 81    075A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 79    073A                                            [adult]         adult            adult                   True
# 78    072A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 77    071A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 76    070A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 74    068A  [adult, senior, adult, adult, adult, adult, ad...         adult            adult                   True
# 73    067A  [adult, adult, adult, kitten, adult, adult, ad...         adult            adult                   True
# 72    066A                                            [adult]         adult            adult                   True
# 71    065A  [senior, adult, adult, adult, adult, senior, a...         adult            adult                   True
# 70    064A                                            [adult]         adult            adult                   True
# 69    063A  [adult, adult, adult, senior, senior, senior, ...         adult            adult                   True
# 68    062A                              [adult, adult, adult]         adult            adult                   True
# 66    060A                             [adult, kitten, adult]         adult            adult                   True
# 64    058A                            [senior, adult, senior]        senior           senior                   True
# 62    056A                            [senior, senior, adult]        senior           senior                   True
# 61    055A  [adult, senior, adult, adult, senior, senior, ...        senior           senior                   True
# 58    052A                                     [adult, adult]         adult            adult                   True
# 53    048A                                           [kitten]        kitten           kitten                   True
# 50    044A  [kitten, kitten, kitten, kitten, kitten, kitte...        kitten           kitten                   True
# 49    043A                                           [kitten]        kitten           kitten                   True
# 80    074A  [adult, adult, senior, adult, adult, adult, ad...         adult            adult                   True
# 82    076A                                            [adult]         adult            adult                   True
# 46    040A  [kitten, kitten, kitten, kitten, adult, kitten...        kitten           kitten                   True
# 83    087A                                     [adult, adult]         adult            adult                   True
# 107   115A                                           [kitten]        kitten           kitten                   True
# 106   113A                           [senior, senior, senior]        senior           senior                   True
# 105   111A  [adult, kitten, kitten, kitten, kitten, kitten...        kitten           kitten                   True
# 104   110A                                           [kitten]        kitten           kitten                   True
# 102   108A            [senior, adult, senior, senior, senior]        senior           senior                   True
# 100   105A                              [adult, adult, adult]         adult            adult                   True
# 98    103A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 97    102A                                     [adult, adult]         adult            adult                   True
# 96    101A  [adult, adult, adult, adult, senior, adult, ad...         adult            adult                   True
# 95    100A                                            [adult]         adult            adult                   True
# 94    099A        [adult, adult, adult, kitten, adult, adult]         adult            adult                   True
# 93    097B  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 91    096A                                            [adult]         adult            adult                   True
# 90    095A  [senior, adult, senior, senior, adult, adult, ...         adult            adult                   True
# 89    094A           [senior, senior, senior, senior, senior]        senior           senior                   True
# 87    092A                                            [adult]         adult            adult                   True
# 86    091A                                            [adult]         adult            adult                   True
# 85    090A                                           [senior]        senior           senior                   True
# 84    088A                                            [adult]         adult            adult                   True
# 48    042A  [senior, adult, kitten, kitten, adult, kitten,...        kitten           kitten                   True
# 55    050A           [kitten, kitten, kitten, kitten, kitten]        kitten           kitten                   True
# 45    039A         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 31    026A                       [adult, adult, adult, adult]         adult            adult                   True
# 29    025B                                     [adult, adult]         adult            adult                   True
# 28    025A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 27    024A                                           [senior]        senior           senior                   True
# 25    023A        [adult, senior, adult, adult, adult, adult]         adult            adult                   True
# 24    022A  [adult, adult, adult, adult, adult, adult, kit...         adult            adult                   True
# 23    021A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 22    020A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 20    019A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 19    018A                                     [adult, adult]         adult            adult                   True
# 17    015A  [adult, adult, adult, senior, adult, adult, ad...         adult            adult                   True
# 15    014A                              [adult, adult, adult]         adult            adult                   True
# 14    013B  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 13    012A                              [adult, adult, adult]         adult            adult                   True
# 12    011A                                   [senior, senior]        senior           senior                   True
# 11    010A                              [adult, adult, adult]         adult            adult                   True
# 10    009A                       [adult, adult, adult, adult]         adult            adult                   True
# 9     008A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 8     007A         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 7     006A                              [adult, adult, adult]         adult            adult                   True
# 5     004A                                            [adult]         adult            adult                   True
# 4     003A                       [adult, adult, adult, adult]         adult            adult                   True
# 3     002B  [adult, adult, senior, adult, adult, senior, a...         adult            adult                   True
# 2     002A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 30    025C                     [adult, adult, senior, senior]         adult            adult                   True
# 26    023B                       [adult, adult, adult, adult]         adult            adult                   True
# 32    026B                                            [adult]         adult            adult                   True
# 40    034A                             [adult, adult, senior]         adult            adult                   True
# 34    027A  [adult, senior, senior, adult, adult, adult, a...         adult            adult                   True
# 35    028A  [senior, adult, adult, adult, adult, adult, ad...         adult            adult                   True
# 44    038A                     [kitten, adult, kitten, adult]         adult            adult                   True
# 43    037A                                    [senior, adult]         adult            adult                   True
# 42    036A  [senior, adult, adult, adult, adult, adult, ad...         adult            adult                   True
# 37    031A  [adult, adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 33    026C                                            [adult]         adult            adult                   True
# 41    035A                                     [adult, adult]         adult            adult                   True
# 38    032A                                     [adult, adult]         adult            adult                   True
# 39    033A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 52    047A  [adult, adult, adult, adult, adult, adult, adu...         adult           kitten                  False
# 54    049A                                            [adult]         adult           kitten                  False
# 99    104A                       [adult, adult, adult, adult]         adult           senior                  False
# 6     005A  [adult, senior, senior, senior, senior, senior...        senior            adult                  False
# 101   106A  [adult, adult, adult, adult, adult, adult, adu...         adult           senior                  False
# 56    051A  [adult, adult, adult, adult, adult, adult, adu...         adult           senior                  False
# 103   109A              [senior, adult, adult, senior, adult]         adult           kitten                  False
# 51    045A                       [adult, adult, adult, adult]         adult           kitten                  False
# 108   116A  [senior, senior, adult, adult, adult, adult, a...         adult           senior                  False
# 1     001A  [adult, senior, adult, senior, adult, senior, ...        senior            adult                  False
# 59    053A                            [senior, adult, senior]        senior            adult                  False
# 57    051B  [adult, adult, adult, adult, adult, adult, adu...         adult           senior                  False
# 92    097A  [adult, adult, adult, adult, adult, senior, ad...         adult           senior                  False
# 60    054A                                     [adult, adult]         adult           senior                  False
# 16    014B  [senior, adult, adult, adult, kitten, kitten, ...         adult           kitten                  False
# 88    093A                                     [adult, adult]         adult           senior                  False
# 18    016A  [adult, adult, adult, adult, adult, adult, adu...         adult           senior                  False
# 63    057A  [adult, adult, adult, adult, adult, adult, adu...         adult           senior                  False
# 21    019B                                           [senior]        senior            adult                  False
# 65    059A  [senior, senior, adult, senior, adult, adult, ...         adult           senior                  False
# 36    029A  [senior, senior, senior, adult, adult, adult, ...        senior            adult                  False
# 67    061A                                     [adult, adult]         adult           senior                  False
# 47    041A                                            [adult]         adult           kitten                  False
# 75    069A                                   [senior, senior]        senior            adult                  False
# 109   117A  [adult, adult, senior, adult, adult, adult, ad...         adult           senior                  False

# %%
# Create df for majority votes
majority_df = majority_votes.reset_index()
majority_df.columns = ['cat_id', 'Majority_Vote']

# Get actual groups for each cat_id
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first().reset_index()

# Merge majority votes with actual groups
majority_with_actual = pd.merge(majority_df, actual_groups, on='cat_id')

# Add a column to check if the majority vote was correct
majority_with_actual['Majority_Correct'] = majority_with_actual['Majority_Vote'] == majority_with_actual['actual_age_group']

# Count correct majority votes per class
correct_majority_votes_per_class = majority_with_actual.groupby('actual_age_group')['Majority_Correct'].sum()

print("Correct Majority Votes per Class:")
print(correct_majority_votes_per_class)
# Out:
# Correct Majority Votes per Class:
# actual_age_group
# adult     67
# kitten     9
# senior     9
# Name: Majority_Correct, dtype: int64

# %%
# Calculate the total count and the number of correct predictions for each class
class_stats = majority_with_actual.groupby('actual_age_group').agg(
    total_count=('Majority_Correct', 'size'),  # Total number of cases per class
    correct_count=('Majority_Correct', 'sum')  # Sum of correct predictions per class
).reset_index()

# Calculate accuracy for each class
class_stats['accuracy'] = class_stats['correct_count'] / class_stats['total_count'] * 100

# store for final evaluation 
all_majority_vote_details.append(class_stats)

# Log detailed stats
print("Detailed Class Statistics for Majority Votes:")
print(class_stats)
# Out:
# Detailed Class Statistics for Majority Votes:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult           73             67  91.780822
# 1           kitten           15              9  60.000000
# 2           senior           22              9  40.909091

# %%
# Plot for Detailed Class Statistics for Majority Votes
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Accuracy of Majority Votes by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Detailed Class Statistics

# %%
# Calculate the total count and the number of correct predictions for each class
class_stats = full_results.groupby('actual_age_group').agg(
    total_count=('correct', 'size'),
    correct_count=('correct', 'sum')
).reset_index()

# Calculate accuracy for each class
class_stats['accuracy'] = class_stats['correct_count'] / class_stats['total_count'] * 100

# store for final evaluation 
all_class_stats.append(class_stats)

# Log the detailed stats
print("Detailed Class Statistics:")
print(class_stats)
# Out:
# Detailed Class Statistics:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult          472            410  86.864407
# 1           kitten           95             51  53.684211
# 2           senior          149             39  26.174497

# %%
# Plot for Detailed Class Statistics (Overall)
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Overall Accuracy by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Gender Exploration

# %%
# Group by gender and calculate the total count, correct predictions, and accuracy
gender_stats = full_results.groupby('all_gender').agg(
    count=('cat_id', 'size'),  # Total number of cases per gender
    correct=('correct', 'sum')  # Sum of correct predictions per gender
).reset_index()

# Calculate accuracy for each gender
gender_stats['accuracy'] = (gender_stats['correct'] / gender_stats['count'] * 100).round(2)

# Display the DataFrame
print("Accuracy by Gender:")
print(gender_stats)

# store for final evaluation 
all_gender_stats.append(gender_stats)
# Out:
# Accuracy by Gender:
#   all_gender  count  correct  accuracy
# 0          F    194      148     76.29
# 1          M    286      206     72.03
# 2          X    236      146     61.86

# %%
# Plot for Accuracy by Gender
styled_barplot(gender_stats, 'all_gender', 'accuracy', 
               'Accuracy by Gender', 
               'Gender', 'Accuracy (%)')

# %% [markdown]
# ### Log current total CV Stats

# %%
print("Total Majority Vote Accuracy so far:", all_majority_vote_accuracies)
print("Total Class Statistics so far:\n", all_class_stats)
print("Total Gender Accuracy so far:\n", all_gender_stats)
# Out:
# Total Majority Vote Accuracy so far: [0.7727272727272727]
# Total Class Statistics so far:
#  [  actual_age_group  total_count  correct_count   accuracy
# 0            adult          472            410  86.864407
# 1           kitten           95             51  53.684211
# 2           senior          149             39  26.174497]
# Total Gender Accuracy so far:
#  [  all_gender  count  correct  accuracy
# 0          F    194      148     76.29
# 1          M    286      206     72.03
# 2          X    236      146     61.86]

# %% [markdown]
# # RANDOM SEED 2

# %%
# Set a fixed random seed for reproducibility
random.seed(int(random_seeds[1]))
np.random.seed(int(random_seeds[1]))
tf.random.set_seed(int(random_seeds[1]))

# Load datasets
dataframe = pd.read_csv('/Users/astrid/PycharmProjects/perch-2/scripts/perch_embeddings_april_10.csv')

dataframe.drop('mean_freq', axis=1, inplace=True)

def assign_age_group(age, age_groups):
    for group_name, age_range in age_groups.items():
        if age_range[0] <= age < age_range[1]:
            return group_name
    return 'Unknown'  # For any age that doesn't fit the defined groups

# Define age groups
age_groups = {
    'kitten': (0, 0.5),
    'adult': (0.5, 12),
    'senior': (12, 20)
}

# Create a new column for the age group
dataframe['age_group'] = dataframe['target'].apply(assign_age_group, age_groups=age_groups)

print(dataframe['age_group'].value_counts())
# Out:
# adult     509
# senior    149
# kitten    135
# Name: age_group, dtype: int64

# %%
# Separate features and labels
X = dataframe.iloc[:, :-4].values  # all columns except the last four

# Encode the 'age_group' column as integers using LabelEncoder
label_encoder = LabelEncoder()
encoded_y = label_encoder.fit_transform(dataframe['age_group'].values)

# Use the encoded labels for splitting and one-hot encoding
y = encoded_y  

# Convert 'cat_id' column to numpy array to be used as groups array for GroupKFold
groups = dataframe['cat_id'].values

# %%
tf.keras.backend.clear_session()

# %% [markdown]
# ## Run Setup

# %%
all_cat_ids = []
all_predicted_age_groups = []
all_actual_age_groups = []
all_gender = []

# Define the StratifiedGroupKFold splitter for 4 fold CV with random shuffling
outer_cv = StratifiedGroupKFold(n_splits=5, shuffle=True, random_state=int(random_seeds[1]))

# unseen test set metrics
unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1 = [], [], [], [], []

outer_fold = 0

# Use the splitter to generate indices for training and testing sets
# Note: GroupShuffleSplit.split returns indices, so we use it to index the arrays
for train_val_idx, test_idx in outer_cv.split(X, y, groups):
    outer_fold += 1
    logger(f"outer_fold {outer_fold}", file=log_file_path)

    # Convert indices back to DataFrame for easy manipulation
    df_train_val = dataframe.iloc[train_val_idx]
    df_test = dataframe.iloc[test_idx]

    ##############################
    # ASSESSING SPLITS BY CAT_ID #
    ##############################
    
    # Get the distribution of groups
    training_validation_group_distribution = df_train_val['cat_id'].value_counts()  
    testing_group_distribution = df_test['cat_id'].value_counts()  
    
    # Log or print the distribution
    logger(f"Train Set Group Distribution:\n{training_validation_group_distribution}", file=log_file_path)
    logger(f"Testing Set Group Distribution:\n{testing_group_distribution}", file=log_file_path)

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val['gender'].value_counts()
    testing_gender_distribution = df_test['gender'].value_counts()
    
    # Log the distribution
    logger(f"Training Set Gender Distribution BEFORE SWAP:\n{training_gender_distribution}", file=log_file_path)
    logger(f"Testing Set Gender Distribution BEFORE SWAP:\n{testing_gender_distribution}", file=log_file_path)

    # Group by 'age_group' and then list unique 'cat_id' within each age group
    unique_cat_ids_per_age_group_train_val = df_train_val.groupby('age_group')['cat_id'].unique()
    unique_cat_ids_per_age_group_test = df_test.groupby('age_group')['cat_id'].unique()
    
    # Log results
    logger(f"Unique Cat IDs per Age Group in Training/Validation Set:\n{unique_cat_ids_per_age_group_train_val}", file=log_file_path)
    logger(f"Unique Cat IDs per Age Group in Testing Set:\n{unique_cat_ids_per_age_group_test}", file=log_file_path)

    # Calculate the count of unique identifiers per age group for training and testing set
    counts_train_val = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_train_val.items()}
    counts_test = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_test.items()}

    # Log the counts of unique identifiers per age group
    logger(f"Count of Unique Cat IDs per Age Group in Training/Validation Set:\n{counts_train_val}", file=log_file_path)
    logger(f"Count of Unique Cat IDs per Age Group in Testing Set:\n{counts_test}", file=log_file_path)

    #######################################################
    # CONTINUE WITH ENSURING VALID AND APPROPRIATE SPLITS #
    #######################################################
    
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    groups_train_val, groups_test = groups[train_val_idx], groups[test_idx]

    # logging identifier splits 
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)

    # check group splits
    check_initial_group_split(groups_train_val, groups_test)

    # Specify the cat_ids that must be in the training/validation set
    specific_cat_ids = ['000A', '046A']
    
    # Perform the swapping operation
    train_val_idx, test_idx = swap_cat_id_instances(dataframe, train_val_idx, test_idx, specific_cat_ids)
    
    # Re-assign the sets based on the updated indices
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    new_groups_train_val, new_groups_test = groups[train_val_idx], groups[test_idx]

    # Find differences for training and test sets
    moved_to_train_val, removed_from_train_val = find_group_differences(groups_train_val, new_groups_train_val)
    moved_to_test, removed_from_test = find_group_differences(groups_test, new_groups_test)
    
    # Display the results
    logger(f"Moved to Training/Validation Set:\n{moved_to_train_val}", file=log_file_path)
    logger(f"Removed from Training/Validation Set:\n{removed_from_train_val}", file=log_file_path)
    logger(f"Moved to Test Set:\n{moved_to_test}", file=log_file_path)
    logger(f"Removed from Test Set\n{removed_from_test}", file=log_file_path)

    # Update X_train_val, X_test, y_train_val, y_test, groups_train_val, groups_test based on updated indices
    X_train_val = X[train_val_idx]
    y_train_val = y[train_val_idx]
    groups_train_val = groups[train_val_idx]
    
    X_test = X[test_idx]
    y_test = y[test_idx]
    groups_test = groups[test_idx]

    # logging identifier splits again after potential swaps
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"AFTER SWAP - Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"AFTER SWAP - Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)
    
    # Verify the lengths are consistent
    logger(f"Length of X_train_val:\n{len(X_train_val)}", file=log_file_path)
    logger(f"Length of y_train_val:\n{len(y_train_val)}", file=log_file_path)
    logger(f"Length of groups_train_val:\n{len(groups_train_val)}", file=log_file_path)

    # Check group splits once more
    check_initial_group_split(groups_train_val, groups_test)

    # Convert the modified indices back to a DataFrame representing the updated df_train_val
    df_train_val_updated = dataframe.iloc[train_val_idx].copy()
    df_test_updated = dataframe.iloc[test_idx].copy()

    ############################
    # LOGGING AGE GROUP SPLITS #
    ############################

    # Get the distribution of age groups of age groups before the update
    training_validation_age_group_distribution = df_train_val['age_group'].value_counts()
    testing_age_group_distribution = df_test['age_group'].value_counts()
    
    # Logthe distribution
    logger(f"Train Age Group Distribution BEFORE SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution BEFORE SWAP:\n{testing_age_group_distribution}", file=log_file_path)

    # Get the distribution of age groups after the update
    training_validation_age_group_distribution = df_train_val_updated['age_group'].value_counts()
    testing_age_group_distribution = df_test_updated['age_group'].value_counts()
    
    # Log the distribution
    logger(f"Train Age Group Distribution AFTER SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution AFTER SWAP:\n{testing_age_group_distribution}", file=log_file_path)
    
    ########################################################
    # TRACKING FINAL CAT_IDs & GENDER AFTER REDISTRIBUTION #
    ########################################################

    # Get the distribution of groups
    training_validation_group_distribution = df_train_val_updated['cat_id'].value_counts()  
    testing_group_distribution = df_test_updated['cat_id'].value_counts()  

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val_updated['gender'].value_counts()
    testing_gender_distribution = df_test_updated['gender'].value_counts()
    
    logger(f"\n Starting training on unseen test set\n", file=log_file_path)

    ###################
    # PREPARING MODEL #
    ###################

    # Calculate the distribution of age groups in y_train_val
    age_group_distribution = Counter(y_train_val)
    print("Age group distribution:", age_group_distribution)

    # EarlyStopping callback: monitor 'loss' instead of 'val_loss' for the test set
    early_stopping = EarlyStopping(
        monitor='loss',  
        min_delta=0.001, 
        patience=30,  
        verbose=1,  
        restore_best_weights=True  
    )

    # One final shuffle to ensure randomness
    outer_shuffle_idx = np.random.permutation(len(X_train_val))
    X_train_val = X_train_val[outer_shuffle_idx]
    y_train_val = y_train_val[outer_shuffle_idx]
    
    # Scale the features
    scaler_full = StandardScaler().fit(X_train_val)
    X_train_full_scaled = scaler_full.transform(X_train_val)
    X_test_scaled = scaler_full.transform(X_test)
    
    # Encode the labels
    y_train_full_encoded = to_categorical(y_train_val)
    y_test_encoded = to_categorical(y_test)

    #######################
    # BUILD & TRAIN MODEL #
    #######################

    optimizers = {
        'Adamax': Adamax(learning_rate=0.00510251984616472)
    }
    
    # Model definition with dynamic number of layers
    model_full = Sequential()
    model_full.add(Dense(480, activation='relu', input_shape=(X_train_full_scaled.shape[1],)))
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.2011047009431978))  
    model_full.add(Dense(256, activation='relu',)) 
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.14956886311951184))  
    model_full.add(Dense(256, activation='relu'))  
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.42291461228250665))  
    model_full.add(Dense(3, activation='softmax'))  
    
    # Use the optimizer from the parameters
    optimizer = optimizers['Adamax']  # optimizer_key from parameters
    
    # Compile the model
    model_full.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    
    # Train the model on the full training set
    history_full = model_full.fit(X_train_full_scaled, y_train_full_encoded, epochs=1500, batch_size=64,
                                  verbose=1, callbacks=[early_stopping])
    
    # Evaluate the model on the held-out test set
    test_loss, test_accuracy = model_full.evaluate(X_test_scaled, y_test_encoded)

    y_test_pred_prob = model_full.predict(X_test_scaled)
    y_test_pred = np.argmax(y_test_pred_prob, axis=1)  
    y_test_true = np.argmax(y_test_encoded, axis=1)    

    ################################
    # LOG MAJORITY VOTE PER CAT_ID #
    ################################

    # Convert numeric predictions back to age group labels
    predicted_age_groups = label_encoder.inverse_transform(y_test_pred)
    actual_labels = label_encoder.inverse_transform(y_test_true)
    
    # Map predictions and actual labels back to cat_ids
    test_results = pd.DataFrame({
        'cat_id': df_test_updated['cat_id'],
        'predicted_age_group': predicted_age_groups,
        'actual_age_group': actual_labels
    })
    
    # Group by cat_id and aggregate predicted age groups
    majority_votes = test_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
    actual_groups = test_results.groupby('cat_id')['actual_age_group'].first()
    
    # Calculate the accuracy of majority voting
    correct_predictions = (majority_votes == actual_groups).sum()
    total_cats = len(actual_groups)
    majority_vote_accuracy = correct_predictions / total_cats
    
    # Log the accuracy of the majority voting
    logger(f"Majority Vote Accuracy for cat_id for this fold: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

    ####################################################
    # COLLECT PREDICTIONS FOR GENDER & CAT_ID ANALYSIS #
    ####################################################

    # Debugging print statements
    print(f'Before appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Extend lists with current fold results
    all_cat_ids.extend(df_test_updated['cat_id'].tolist())
    all_predicted_age_groups.extend(predicted_age_groups)
    all_actual_age_groups.extend(actual_labels)
    all_gender.extend(df_test_updated['gender'].tolist())

    # Debugging print statements
    print(f'After appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Calculate additional metrics
    test_precision = precision_score(y_test_true, y_test_pred, average='macro')  # Use 'macro' for imbalanced datasets
    test_recall = recall_score(y_test_true, y_test_pred, average='macro')
    test_f1 = f1_score(y_test_true, y_test_pred, average='macro')

    # prepare averages of outer metrics
    unseen_f1.append(test_f1)
    unseen_losses.append(test_loss)
    unseen_accuracies.append(test_accuracy)
    unseen_precisions.append(test_precision)
    unseen_recalls.append(test_recall)

    # Print final test results
    logger(f"Final Test Results - Loss: {test_loss}, Accuracy: {test_accuracy}, Precision: {test_precision}, Recall: {test_recall}, F1 Score: {test_f1}", file=log_file_path)

    # Generate the confusion matrix
    cm = confusion_matrix(y_test, y_test_pred)
    logger(f"Confusion Matrix:\n {cm}", file=log_file_path)

# Calculate the overall average metrics
unseen_set_avg_f1 = np.mean(unseen_f1)
unseen_set_avg_loss = np.mean(unseen_losses)
unseen_set_avg_acc = np.mean(unseen_accuracies)
unseen_set_avg_precision = np.mean(unseen_precisions)
unseen_set_avg_recall = np.mean(unseen_recalls)

logger(f"\nFinal Average F1-Score across all UNSEEN TEST sets: {unseen_set_avg_f1}", file=log_file_path)
logger(f"\nFinal Average Loss across all UNSEEN TEST sets: {unseen_set_avg_loss}", file=log_file_path)
logger(f"\nFinal Average Accuracy across all UNSEEN TEST sets: {unseen_set_avg_acc}", file=log_file_path)
logger(f"\nFinal Average Precision across all UNSEEN TEST sets: {unseen_set_avg_precision}", file=log_file_path)
logger(f"\nFinal Average Recall across all UNSEEN TEST sets: {unseen_set_avg_recall}\n", file=log_file_path)

# Append averages to total lists
all_f1.append(unseen_set_avg_f1)
all_losses.append(unseen_set_avg_loss)
all_accuracies.append(unseen_set_avg_acc)
all_precisions.append(unseen_set_avg_precision)
all_recalls.append(unseen_set_avg_recall)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# outer_fold 1
# Train Set Group Distribution:
# 046A    45
# 000A    39
# 103A    33
# 002B    30
# 020A    20
# 000B    19
# 057A    17
# 019A    17
# 074A    16
# 029A    15
# 097B    14
# 106A    13
# 002A    13
# 116A    12
# 101A    12
# 051A    12
# 055A    12
# 028A    11
# 063A    11
# 067A    11
# 040A    10
# 072A     9
# 051B     9
# 016A     9
# 065A     9
# 033A     9
# 071A     9
# 001A     9
# 005A     9
# 013B     8
# 117A     7
# 095A     7
# 015A     7
# 036A     7
# 027A     7
# 031A     7
# 039A     6
# 023A     6
# 099A     6
# 109A     5
# 075A     5
# 070A     5
# 044A     5
# 008A     5
# 108A     5
# 094A     5
# 023B     4
# 003A     4
# 104A     4
# 025C     4
# 045A     4
# 009A     4
# 012A     3
# 053A     3
# 058A     3
# 010A     3
# 060A     3
# 006A     3
# 056A     3
# 113A     3
# 062A     3
# 105A     3
# 034A     3
# 025B     2
# 037A     2
# 061A     2
# 011A     2
# 035A     2
# 087A     2
# 052A     2
# 038A     2
# 018A     2
# 032A     2
# 054A     2
# 041A     1
# 096A     1
# 090A     1
# 100A     1
# 110A     1
# 073A     1
# 115A     1
# 064A     1
# 004A     1
# 019B     1
# 092A     1
# 076A     1
# 048A     1
# 066A     1
# 043A     1
# 049A     1
# 026C     1
# 026B     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 047A    22
# 097A    15
# 111A    12
# 042A    11
# 014B    10
# 059A    10
# 025A    10
# 022A     9
# 068A     8
# 007A     6
# 021A     5
# 050A     5
# 026A     4
# 014A     3
# 069A     2
# 093A     2
# 102A     2
# 091A     1
# 088A     1
# 024A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    260
# F    205
# X    189
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    87
# F    26
# M    26
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [006A, 000A, 033A, 015A, 001A, 103A, 071A, 097...
# kitten    [044A, 040A, 046A, 109A, 043A, 049A, 041A, 045...
# senior    [057A, 106A, 104A, 055A, 113A, 116A, 051B, 054...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [022A, 091A, 025A, 014A, 007A, 069A, 021A, 026...
# kitten                       [014B, 111A, 047A, 042A, 050A]
# senior                             [093A, 097A, 059A, 024A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 63, 'kitten': 11, 'senior': 18}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 11, 'kitten': 5, 'senior': 4}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '004A' '005A' '006A' '008A'
#  '009A' '010A' '011A' '012A' '013B' '015A' '016A' '018A' '019A' '019B'
#  '020A' '023A' '023B' '025B' '025C' '026B' '026C' '027A' '028A' '029A'
#  '031A' '032A' '033A' '034A' '035A' '036A' '037A' '038A' '039A' '040A'
#  '041A' '043A' '044A' '045A' '046A' '048A' '049A' '051A' '051B' '052A'
#  '053A' '054A' '055A' '056A' '057A' '058A' '060A' '061A' '062A' '063A'
#  '064A' '065A' '066A' '067A' '070A' '071A' '072A' '073A' '074A' '075A'
#  '076A' '087A' '090A' '092A' '094A' '095A' '096A' '097B' '099A' '100A'
#  '101A' '103A' '104A' '105A' '106A' '108A' '109A' '110A' '113A' '115A'
#  '116A' '117A']
# Unique Test Group IDs:
# ['007A' '014A' '014B' '021A' '022A' '024A' '025A' '026A' '042A' '047A'
#  '050A' '059A' '068A' '069A' '088A' '091A' '093A' '097A' '102A' '111A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '004A' '005A' '006A' '008A'
#  '009A' '010A' '011A' '012A' '013B' '015A' '016A' '018A' '019A' '019B'
#  '020A' '023A' '023B' '025B' '025C' '026B' '026C' '027A' '028A' '029A'
#  '031A' '032A' '033A' '034A' '035A' '036A' '037A' '038A' '039A' '040A'
#  '041A' '043A' '044A' '045A' '046A' '048A' '049A' '051A' '051B' '052A'
#  '053A' '054A' '055A' '056A' '057A' '058A' '060A' '061A' '062A' '063A'
#  '064A' '065A' '066A' '067A' '070A' '071A' '072A' '073A' '074A' '075A'
#  '076A' '087A' '090A' '092A' '094A' '095A' '096A' '097B' '099A' '100A'
#  '101A' '103A' '104A' '105A' '106A' '108A' '109A' '110A' '113A' '115A'
#  '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['007A' '014A' '014B' '021A' '022A' '024A' '025A' '026A' '042A' '047A'
#  '050A' '059A' '068A' '069A' '088A' '091A' '093A' '097A' '102A' '111A']
# Length of X_train_val:
# 654
# Length of y_train_val:
# 654
# Length of groups_train_val:
# 654
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     458
# senior    121
# kitten     75
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# kitten    60
# adult     51
# senior    28
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     458
# senior    121
# kitten     75
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# kitten    60
# adult     51
# senior    28
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 458, 2: 121, 1: 75})
# Epoch 1/1500
# 11/11 [==============================] - 1s 6ms/step - loss: 1.0806 - accuracy: 0.6101
# Epoch 2/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.2945 - accuracy: 0.8960
# Epoch 3/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1780 - accuracy: 0.9450
# Epoch 4/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0875 - accuracy: 0.9817
# Epoch 5/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0571 - accuracy: 0.9893
# Epoch 6/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0670 - accuracy: 0.9878
# Epoch 7/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0276 - accuracy: 0.9939
# Epoch 8/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0701 - accuracy: 0.9817
# Epoch 9/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0352 - accuracy: 0.9924
# Epoch 10/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0360 - accuracy: 0.9908
# Epoch 11/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0387 - accuracy: 0.9939
# Epoch 12/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0361 - accuracy: 0.9878
# Epoch 13/1500
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0245 - accuracy: 0.9924
# Epoch 14/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0252 - accuracy: 0.9939
# Epoch 15/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0307 - accuracy: 0.9939
# Epoch 16/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0508 - accuracy: 0.9893
# Epoch 17/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0121 - accuracy: 0.9969
# Epoch 18/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0123 - accuracy: 0.9954
# Epoch 19/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0207 - accuracy: 0.9939
# Epoch 20/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0123 - accuracy: 0.9969
# Epoch 21/1500
# 11/11 [==============================] - 0s 18ms/step - loss: 0.0140 - accuracy: 0.9969
# Epoch 22/1500
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0180 - accuracy: 0.9954
# Epoch 23/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0103 - accuracy: 0.9969
# Epoch 24/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0081 - accuracy: 0.9985
# Epoch 25/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0061 - accuracy: 0.9985
# Epoch 26/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0157 - accuracy: 0.9969
# Epoch 27/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0045 - accuracy: 1.0000
# Epoch 28/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0068 - accuracy: 1.0000
# Epoch 29/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 30/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 31/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0049 - accuracy: 1.0000
# Epoch 32/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 33/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0056 - accuracy: 0.9985
# Epoch 34/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0064 - accuracy: 0.9985
# Epoch 35/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 36/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0201 - accuracy: 0.9969
# Epoch 37/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0128 - accuracy: 0.9954
# Epoch 38/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0224 - accuracy: 0.9939
# Epoch 39/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0061 - accuracy: 0.9985
# Epoch 40/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0089 - accuracy: 0.9985
# Epoch 41/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 42/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0046 - accuracy: 0.9985
# Epoch 43/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0046 - accuracy: 0.9985
# Epoch 44/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0199 - accuracy: 0.9939
# Epoch 45/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 46/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0105 - accuracy: 0.9969
# Epoch 47/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0077 - accuracy: 0.9985
# Epoch 48/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 49/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0041 - accuracy: 0.9985
# Epoch 50/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0064 - accuracy: 0.9969
# Epoch 51/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 52/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0043 - accuracy: 0.9985
# Epoch 53/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0114 - accuracy: 0.9985
# Epoch 54/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 55/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 56/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 57/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0054 - accuracy: 0.9985
# Epoch 58/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 59/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 60/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0135 - accuracy: 0.9985
# Epoch 61/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0242 - accuracy: 0.9939
# Epoch 62/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0054 - accuracy: 1.0000
# Epoch 63/1500
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0303 - accuracy: 0.9847
# Epoch 64/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0055 - accuracy: 0.9985
# Epoch 65/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0055 - accuracy: 1.0000
# Epoch 66/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0031 - accuracy: 0.9985
# Epoch 67/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0053 - accuracy: 0.9985
# Epoch 68/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 69/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 70/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 71/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 72/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0209 - accuracy: 0.9954
# Epoch 73/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0187 - accuracy: 0.9939
# Epoch 74/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0101 - accuracy: 0.9985
# Epoch 75/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0109 - accuracy: 0.9954
# Epoch 76/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0085 - accuracy: 0.9969
# Epoch 77/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0162 - accuracy: 0.9969
# Epoch 78/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0104 - accuracy: 0.9954
# Epoch 79/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0130 - accuracy: 0.9969
# Epoch 80/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0051 - accuracy: 0.9985
# Epoch 81/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0071 - accuracy: 0.9969
# Epoch 82/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0052 - accuracy: 0.9985
# Epoch 83/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0051 - accuracy: 0.9985
# Epoch 84/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 85/1500
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0016 - accuracy: 1.0000Restoring model weights from the end of the best epoch: 55.
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 85: early stopping
# 5/5 [==============================] - 0s 2ms/step - loss: 3.4899 - accuracy: 0.4892
# 5/5 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.65 (13/20)
# Before appending - Cat IDs: 0, Predictions: 0, Actuals: 0, Gender: 0
# After appending - Cat IDs: 139, Predictions: 139, Actuals: 139, Gender: 139
# Final Test Results - Loss: 3.4898712635040283, Accuracy: 0.4892086386680603, Precision: 0.5797152194211018, Recall: 0.4570494864612511, F1 Score: 0.43852468035474573
# Confusion Matrix:
#  [[42  1  8]
#  [38 20  2]
#  [22  0  6]]
# outer_fold 2
# Train Set Group Distribution:
# 046A    45
# 000A    39
# 103A    33
# 047A    22
# 000B    19
# 057A    17
# 074A    16
# 097A    15
# 106A    13
# 002A    13
# 055A    12
# 101A    12
# 116A    12
# 111A    12
# 028A    11
# 042A    11
# 063A    11
# 014B    10
# 025A    10
# 059A    10
# 040A    10
# 022A     9
# 033A     9
# 072A     9
# 065A     9
# 001A     9
# 068A     8
# 013B     8
# 117A     7
# 027A     7
# 031A     7
# 095A     7
# 015A     7
# 023A     6
# 039A     6
# 099A     6
# 007A     6
# 044A     5
# 050A     5
# 075A     5
# 094A     5
# 108A     5
# 109A     5
# 021A     5
# 070A     5
# 009A     4
# 104A     4
# 023B     4
# 003A     4
# 025C     4
# 026A     4
# 045A     4
# 062A     3
# 105A     3
# 034A     3
# 012A     3
# 014A     3
# 113A     3
# 060A     3
# 010A     3
# 037A     2
# 102A     2
# 035A     2
# 011A     2
# 052A     2
# 069A     2
# 025B     2
# 093A     2
# 018A     2
# 038A     2
# 054A     2
# 061A     2
# 110A     1
# 019B     1
# 115A     1
# 100A     1
# 090A     1
# 041A     1
# 088A     1
# 048A     1
# 066A     1
# 026C     1
# 092A     1
# 049A     1
# 064A     1
# 091A     1
# 076A     1
# 024A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 002B    30
# 020A    20
# 019A    17
# 029A    15
# 097B    14
# 051A    12
# 067A    11
# 005A     9
# 016A     9
# 051B     9
# 071A     9
# 036A     7
# 008A     5
# 053A     3
# 058A     3
# 006A     3
# 056A     3
# 087A     2
# 032A     2
# 004A     1
# 096A     1
# 073A     1
# 043A     1
# 026B     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    218
# F    215
# M    172
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# M    114
# X     58
# F     16
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [000A, 033A, 015A, 001A, 103A, 028A, 074A, 062...
# kitten    [044A, 014B, 111A, 040A, 046A, 047A, 042A, 109...
# senior    [093A, 097A, 057A, 106A, 104A, 055A, 059A, 113...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [006A, 071A, 097B, 019A, 067A, 020A, 002B, 029...
# kitten                                               [043A]
# senior                       [051B, 056A, 051A, 058A, 016A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 56, 'kitten': 15, 'senior': 17}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 18, 'kitten': 1, 'senior': 5}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '003A' '007A' '009A' '010A' '011A' '012A'
#  '013B' '014A' '014B' '015A' '018A' '019B' '021A' '022A' '023A' '023B'
#  '024A' '025A' '025B' '025C' '026A' '026C' '027A' '028A' '031A' '033A'
#  '034A' '035A' '037A' '038A' '039A' '040A' '041A' '042A' '044A' '045A'
#  '046A' '047A' '048A' '049A' '050A' '052A' '054A' '055A' '057A' '059A'
#  '060A' '061A' '062A' '063A' '064A' '065A' '066A' '068A' '069A' '070A'
#  '072A' '074A' '075A' '076A' '088A' '090A' '091A' '092A' '093A' '094A'
#  '095A' '097A' '099A' '100A' '101A' '102A' '103A' '104A' '105A' '106A'
#  '108A' '109A' '110A' '111A' '113A' '115A' '116A' '117A']
# Unique Test Group IDs:
# ['002B' '004A' '005A' '006A' '008A' '016A' '019A' '020A' '026B' '029A'
#  '032A' '036A' '043A' '051A' '051B' '053A' '056A' '058A' '067A' '071A'
#  '073A' '087A' '096A' '097B']
# No common groups found between train and test sets.
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '003A' '007A' '009A' '010A' '011A' '012A'
#  '013B' '014A' '014B' '015A' '018A' '019B' '021A' '022A' '023A' '023B'
#  '024A' '025A' '025B' '025C' '026A' '026C' '027A' '028A' '031A' '033A'
#  '034A' '035A' '037A' '038A' '039A' '040A' '041A' '042A' '044A' '045A'
#  '046A' '047A' '048A' '049A' '050A' '052A' '054A' '055A' '057A' '059A'
#  '060A' '061A' '062A' '063A' '064A' '065A' '066A' '068A' '069A' '070A'
#  '072A' '074A' '075A' '076A' '088A' '090A' '091A' '092A' '093A' '094A'
#  '095A' '097A' '099A' '100A' '101A' '102A' '103A' '104A' '105A' '106A'
#  '108A' '109A' '110A' '111A' '113A' '115A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['002B' '004A' '005A' '006A' '008A' '016A' '019A' '020A' '026B' '029A'
#  '032A' '036A' '043A' '051A' '051B' '053A' '056A' '058A' '067A' '071A'
#  '073A' '087A' '096A' '097B']
# Length of X_train_val:
# 605
# Length of y_train_val:
# 605
# Length of groups_train_val:
# 605
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     358
# kitten    134
# senior    113
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     151
# senior     36
# kitten      1
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     358
# kitten    134
# senior    113
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     151
# senior     36
# kitten      1
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 358, 1: 134, 2: 113})
# Epoch 1/1500
# 10/10 [==============================] - 1s 5ms/step - loss: 0.9280 - accuracy: 0.7058
# Epoch 2/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2663 - accuracy: 0.9091
# Epoch 3/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1072 - accuracy: 0.9636
# Epoch 4/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0569 - accuracy: 0.9835
# Epoch 5/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0347 - accuracy: 0.9901
# Epoch 6/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0143 - accuracy: 0.9983
# Epoch 7/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0225 - accuracy: 0.9950
# Epoch 8/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0159 - accuracy: 0.9967
# Epoch 9/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0133 - accuracy: 0.9950
# Epoch 10/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0216 - accuracy: 0.9950
# Epoch 11/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0171 - accuracy: 0.9934
# Epoch 12/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0077 - accuracy: 0.9983
# Epoch 13/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0126 - accuracy: 0.9967
# Epoch 14/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0046 - accuracy: 1.0000
# Epoch 15/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0058 - accuracy: 1.0000
# Epoch 16/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0040 - accuracy: 1.0000
# Epoch 17/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 18/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0042 - accuracy: 1.0000
# Epoch 19/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 20/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0052 - accuracy: 1.0000
# Epoch 21/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0041 - accuracy: 0.9983
# Epoch 22/1500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 23/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0058 - accuracy: 0.9983
# Epoch 24/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 25/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0041 - accuracy: 1.0000
# Epoch 26/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 27/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0046 - accuracy: 0.9983
# Epoch 28/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 29/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 30/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0065 - accuracy: 0.9967
# Epoch 31/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 32/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 33/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0035 - accuracy: 0.9983
# Epoch 34/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 35/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 36/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 9.9065e-04 - accuracy: 1.0000
# Epoch 37/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 38/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 39/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 8.8208e-04 - accuracy: 1.0000
# Epoch 40/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 41/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 42/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 43/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 44/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0141 - accuracy: 0.9967
# Epoch 45/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 46/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 47/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 48/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0047 - accuracy: 0.9983
# Epoch 49/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 50/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 51/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0026 - accuracy: 0.9983
# Epoch 52/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 53/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 54/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 55/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 56/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 57/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 58/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 8.8974e-04 - accuracy: 1.0000
# Epoch 59/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 6.7439e-04 - accuracy: 1.0000
# Epoch 60/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 6.9044e-04 - accuracy: 1.0000
# Epoch 61/1500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 62/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 7.3534e-04 - accuracy: 1.0000
# Epoch 63/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 64/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 65/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 66/1500
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0025 - accuracy: 0.9983
# Epoch 67/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 8.2180e-04 - accuracy: 1.0000
# Epoch 68/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 69/1500
#  8/10 [=======================>......] - ETA: 0s - loss: 8.7870e-04 - accuracy: 1.0000Restoring model weights from the end of the best epoch: 39.
# 10/10 [==============================] - 0s 8ms/step - loss: 8.6466e-04 - accuracy: 1.0000
# Epoch 69: early stopping
# 6/6 [==============================] - 0s 2ms/step - loss: 1.7960 - accuracy: 0.7287
# 6/6 [==============================] - 0s 2ms/step
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Majority Vote Accuracy for cat_id for this fold: 0.79 (19/24)
# Before appending - Cat IDs: 139, Predictions: 139, Actuals: 139, Gender: 139
# After appending - Cat IDs: 327, Predictions: 327, Actuals: 327, Gender: 327
# Final Test Results - Loss: 1.795952320098877, Accuracy: 0.728723406791687, Precision: 0.44522882181110024, Recall: 0.6829163600686781, F1 Score: 0.48691930264119426
# Confusion Matrix:
#  [[129   3  19]
#  [  0   1   0]
#  [ 29   0   7]]
# outer_fold 3
# Train Set Group Distribution:
# 103A    33
# 002B    30
# 047A    22
# 020A    20
# 019A    17
# 074A    16
# 029A    15
# 097A    15
# 097B    14
# 002A    13
# 051A    12
# 055A    12
# 111A    12
# 101A    12
# 028A    11
# 067A    11
# 042A    11
# 025A    10
# 059A    10
# 040A    10
# 014B    10
# 051B     9
# 001A     9
# 065A     9
# 071A     9
# 005A     9
# 016A     9
# 033A     9
# 022A     9
# 068A     8
# 013B     8
# 036A     7
# 031A     7
# 117A     7
# 015A     7
# 023A     6
# 039A     6
# 099A     6
# 007A     6
# 021A     5
# 108A     5
# 044A     5
# 050A     5
# 075A     5
# 070A     5
# 008A     5
# 003A     4
# 025C     4
# 009A     4
# 026A     4
# 023B     4
# 056A     3
# 105A     3
# 058A     3
# 006A     3
# 060A     3
# 053A     3
# 113A     3
# 014A     3
# 034A     3
# 035A     2
# 011A     2
# 037A     2
# 025B     2
# 102A     2
# 032A     2
# 038A     2
# 093A     2
# 054A     2
# 069A     2
# 087A     2
# 064A     1
# 024A     1
# 090A     1
# 100A     1
# 110A     1
# 115A     1
# 091A     1
# 004A     1
# 088A     1
# 073A     1
# 066A     1
# 076A     1
# 092A     1
# 049A     1
# 096A     1
# 043A     1
# 026B     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 046A    45
# 000A    39
# 000B    19
# 057A    17
# 106A    13
# 116A    12
# 063A    11
# 072A     9
# 095A     7
# 027A     7
# 109A     5
# 094A     5
# 045A     4
# 104A     4
# 062A     3
# 012A     3
# 010A     3
# 052A     2
# 061A     2
# 018A     2
# 026C     1
# 041A     1
# 048A     1
# 019B     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    244
# X    179
# F    154
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    97
# F    77
# M    42
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [006A, 033A, 015A, 001A, 103A, 071A, 097B, 028...
# kitten    [044A, 014B, 111A, 040A, 047A, 042A, 050A, 043...
# senior    [093A, 097A, 055A, 059A, 113A, 051B, 054A, 117...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [000A, 062A, 095A, 072A, 063A, 027A, 000B, 018...
# kitten                       [046A, 109A, 041A, 045A, 048A]
# senior                 [057A, 106A, 104A, 116A, 094A, 061A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 61, 'kitten': 11, 'senior': 16}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 13, 'kitten': 5, 'senior': 6}
# Unique Training/Validation Group IDs:
# ['001A' '002A' '002B' '003A' '004A' '005A' '006A' '007A' '008A' '009A'
#  '011A' '013B' '014A' '014B' '015A' '016A' '019A' '020A' '021A' '022A'
#  '023A' '023B' '024A' '025A' '025B' '025C' '026A' '026B' '028A' '029A'
#  '031A' '032A' '033A' '034A' '035A' '036A' '037A' '038A' '039A' '040A'
#  '042A' '043A' '044A' '047A' '049A' '050A' '051A' '051B' '053A' '054A'
#  '055A' '056A' '058A' '059A' '060A' '064A' '065A' '066A' '067A' '068A'
#  '069A' '070A' '071A' '073A' '074A' '075A' '076A' '087A' '088A' '090A'
#  '091A' '092A' '093A' '096A' '097A' '097B' '099A' '100A' '101A' '102A'
#  '103A' '105A' '108A' '110A' '111A' '113A' '115A' '117A']
# Unique Test Group IDs:
# ['000A' '000B' '010A' '012A' '018A' '019B' '026C' '027A' '041A' '045A'
#  '046A' '048A' '052A' '057A' '061A' '062A' '063A' '072A' '094A' '095A'
#  '104A' '106A' '109A' '116A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'000A', '046A'}
# Removed from Training/Validation Set:
# {'047A', '099A'}
# Moved to Test Set:
# {'047A', '099A'}
# Removed from Test Set
# {'000A', '046A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '001A' '002A' '002B' '003A' '004A' '005A' '006A' '007A' '008A'
#  '009A' '011A' '013B' '014A' '014B' '015A' '016A' '019A' '020A' '021A'
#  '022A' '023A' '023B' '024A' '025A' '025B' '025C' '026A' '026B' '028A'
#  '029A' '031A' '032A' '033A' '034A' '035A' '036A' '037A' '038A' '039A'
#  '040A' '042A' '043A' '044A' '046A' '049A' '050A' '051A' '051B' '053A'
#  '054A' '055A' '056A' '058A' '059A' '060A' '064A' '065A' '066A' '067A'
#  '068A' '069A' '070A' '071A' '073A' '074A' '075A' '076A' '087A' '088A'
#  '090A' '091A' '092A' '093A' '096A' '097A' '097B' '100A' '101A' '102A'
#  '103A' '105A' '108A' '110A' '111A' '113A' '115A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['000B' '010A' '012A' '018A' '019B' '026C' '027A' '041A' '045A' '047A'
#  '048A' '052A' '057A' '061A' '062A' '063A' '072A' '094A' '095A' '099A'
#  '104A' '106A' '109A' '116A']
# Length of X_train_val:
# 633
# Length of y_train_val:
# 633
# Length of groups_train_val:
# 633
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     402
# senior     96
# kitten     79
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     107
# kitten     56
# senior     53
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     435
# kitten    102
# senior     96
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     74
# senior    53
# kitten    33
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 435, 1: 102, 2: 96})
# Epoch 1/1500
# 10/10 [==============================] - 1s 6ms/step - loss: 1.0351 - accuracy: 0.6524
# Epoch 2/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2807 - accuracy: 0.8942
# Epoch 3/1500
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1229 - accuracy: 0.9621
# Epoch 4/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0693 - accuracy: 0.9731
# Epoch 5/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0269 - accuracy: 0.9921
# Epoch 6/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0232 - accuracy: 0.9953
# Epoch 7/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 8/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0135 - accuracy: 0.9968
# Epoch 9/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0121 - accuracy: 0.9984
# Epoch 10/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0060 - accuracy: 1.0000
# Epoch 11/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0064 - accuracy: 0.9984
# Epoch 12/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0147 - accuracy: 0.9968
# Epoch 13/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0053 - accuracy: 1.0000
# Epoch 14/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0100 - accuracy: 0.9984
# Epoch 15/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0056 - accuracy: 1.0000
# Epoch 16/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0099 - accuracy: 0.9984
# Epoch 17/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0079 - accuracy: 0.9968
# Epoch 18/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0185 - accuracy: 0.9968
# Epoch 19/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0068 - accuracy: 0.9984
# Epoch 20/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 21/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0057 - accuracy: 1.0000
# Epoch 22/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 23/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 24/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 25/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 26/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 27/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 28/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 29/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 30/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 31/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 8.6225e-04 - accuracy: 1.0000
# Epoch 32/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 33/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 34/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 35/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 36/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 37/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 38/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 9.7718e-04 - accuracy: 1.0000
# Epoch 39/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 40/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 9.6860e-04 - accuracy: 1.0000
# Epoch 41/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 42/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 43/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 4.8290e-04 - accuracy: 1.0000
# Epoch 44/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 45/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 46/1500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 47/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0024 - accuracy: 0.9984
# Epoch 48/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 49/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 50/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 9.7250e-04 - accuracy: 1.0000
# Epoch 51/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 52/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 53/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 5.0394e-04 - accuracy: 1.0000
# Epoch 54/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 5.9427e-04 - accuracy: 1.0000
# Epoch 55/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 7.4665e-04 - accuracy: 1.0000
# Epoch 56/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 8.2795e-04 - accuracy: 1.0000
# Epoch 57/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 58/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 59/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 5.0507e-04 - accuracy: 1.0000
# Epoch 60/1500
# 10/10 [==============================] - 0s 9ms/step - loss: 8.5753e-04 - accuracy: 1.0000
# Epoch 61/1500
#  9/10 [==========================>...] - ETA: 0s - loss: 4.7429e-04 - accuracy: 1.0000Restoring model weights from the end of the best epoch: 31.
# 10/10 [==============================] - 0s 7ms/step - loss: 4.5233e-04 - accuracy: 1.0000
# Epoch 61: early stopping
# 5/5 [==============================] - 0s 2ms/step - loss: 2.7274 - accuracy: 0.5688
# 5/5 [==============================] - 0s 2ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.67 (16/24)
# Before appending - Cat IDs: 327, Predictions: 327, Actuals: 327, Gender: 327
# After appending - Cat IDs: 487, Predictions: 487, Actuals: 487, Gender: 487
# Final Test Results - Loss: 2.727426528930664, Accuracy: 0.5687500238418579, Precision: 0.6555085741132253, Recall: 0.47383060590607756, F1 Score: 0.4696661193212918
# Confusion Matrix:
#  [[68  1  5]
#  [27  6  0]
#  [34  2 17]]
# outer_fold 4
# Train Set Group Distribution:
# 046A    45
# 000A    39
# 103A    33
# 002B    30
# 047A    22
# 020A    20
# 000B    19
# 057A    17
# 019A    17
# 074A    16
# 029A    15
# 097A    15
# 097B    14
# 106A    13
# 116A    12
# 051A    12
# 111A    12
# 055A    12
# 067A    11
# 042A    11
# 063A    11
# 025A    10
# 040A    10
# 059A    10
# 014B    10
# 072A     9
# 065A     9
# 005A     9
# 022A     9
# 071A     9
# 001A     9
# 051B     9
# 033A     9
# 016A     9
# 068A     8
# 036A     7
# 027A     7
# 095A     7
# 015A     7
# 023A     6
# 099A     6
# 007A     6
# 108A     5
# 075A     5
# 008A     5
# 109A     5
# 094A     5
# 021A     5
# 050A     5
# 003A     4
# 026A     4
# 023B     4
# 045A     4
# 104A     4
# 058A     3
# 053A     3
# 012A     3
# 060A     3
# 010A     3
# 062A     3
# 034A     3
# 006A     3
# 056A     3
# 014A     3
# 113A     3
# 035A     2
# 037A     2
# 052A     2
# 102A     2
# 061A     2
# 011A     2
# 032A     2
# 069A     2
# 018A     2
# 093A     2
# 087A     2
# 026C     1
# 024A     1
# 100A     1
# 115A     1
# 091A     1
# 019B     1
# 041A     1
# 088A     1
# 004A     1
# 096A     1
# 048A     1
# 043A     1
# 073A     1
# 026B     1
# Name: cat_id, dtype: int64
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Testing Set Group Distribution:
# 002A    13
# 101A    12
# 028A    11
# 013B     8
# 031A     7
# 117A     7
# 039A     6
# 044A     5
# 070A     5
# 025C     4
# 009A     4
# 105A     3
# 054A     2
# 038A     2
# 025B     2
# 066A     1
# 110A     1
# 076A     1
# 092A     1
# 049A     1
# 064A     1
# 090A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    276
# X    260
# F    159
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# F    72
# X    16
# M    10
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [006A, 000A, 033A, 015A, 001A, 103A, 071A, 097...
# kitten    [014B, 111A, 040A, 046A, 047A, 042A, 109A, 050...
# senior    [093A, 097A, 057A, 106A, 104A, 055A, 059A, 113...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [028A, 101A, 002A, 039A, 009A, 038A, 013B, 070...
# kitten                                   [044A, 049A, 110A]
# senior                                   [054A, 117A, 090A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 58, 'kitten': 13, 'senior': 19}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 16, 'kitten': 3, 'senior': 3}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002B' '003A' '004A' '005A' '006A' '007A' '008A'
#  '010A' '011A' '012A' '014A' '014B' '015A' '016A' '018A' '019A' '019B'
#  '020A' '021A' '022A' '023A' '023B' '024A' '025A' '026A' '026B' '026C'
#  '027A' '029A' '032A' '033A' '034A' '035A' '036A' '037A' '040A' '041A'
#  '042A' '043A' '045A' '046A' '047A' '048A' '050A' '051A' '051B' '052A'
#  '053A' '055A' '056A' '057A' '058A' '059A' '060A' '061A' '062A' '063A'
#  '065A' '067A' '068A' '069A' '071A' '072A' '073A' '074A' '075A' '087A'
#  '088A' '091A' '093A' '094A' '095A' '096A' '097A' '097B' '099A' '100A'
#  '102A' '103A' '104A' '106A' '108A' '109A' '111A' '113A' '115A' '116A']
# Unique Test Group IDs:
# ['002A' '009A' '013B' '025B' '025C' '028A' '031A' '038A' '039A' '044A'
#  '049A' '054A' '064A' '066A' '070A' '076A' '090A' '092A' '101A' '105A'
#  '110A' '117A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002B' '003A' '004A' '005A' '006A' '007A' '008A'
#  '010A' '011A' '012A' '014A' '014B' '015A' '016A' '018A' '019A' '019B'
#  '020A' '021A' '022A' '023A' '023B' '024A' '025A' '026A' '026B' '026C'
#  '027A' '029A' '032A' '033A' '034A' '035A' '036A' '037A' '040A' '041A'
#  '042A' '043A' '045A' '046A' '047A' '048A' '050A' '051A' '051B' '052A'
#  '053A' '055A' '056A' '057A' '058A' '059A' '060A' '061A' '062A' '063A'
#  '065A' '067A' '068A' '069A' '071A' '072A' '073A' '074A' '075A' '087A'
#  '088A' '091A' '093A' '094A' '095A' '096A' '097A' '097B' '099A' '100A'
#  '102A' '103A' '104A' '106A' '108A' '109A' '111A' '113A' '115A' '116A']
# AFTER SWAP - Unique Test Group IDs:
# ['002A' '009A' '013B' '025B' '025C' '028A' '031A' '038A' '039A' '044A'
#  '049A' '054A' '064A' '066A' '070A' '076A' '090A' '092A' '101A' '105A'
#  '110A' '117A']
# Length of X_train_val:
# 695
# Length of y_train_val:
# 695
# Length of groups_train_val:
# 695
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     428
# senior    139
# kitten    128
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     81
# senior    10
# kitten     7
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     428
# senior    139
# kitten    128
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     81
# senior    10
# kitten     7
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 428, 2: 139, 1: 128})
# Epoch 1/1500
# 11/11 [==============================] - 1s 8ms/step - loss: 1.0657 - accuracy: 0.6216
# Epoch 2/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.2553 - accuracy: 0.9108
# Epoch 3/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.1327 - accuracy: 0.9525
# Epoch 4/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0483 - accuracy: 0.9871
# Epoch 5/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0419 - accuracy: 0.9842
# Epoch 6/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0308 - accuracy: 0.9928
# Epoch 7/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0238 - accuracy: 0.9957
# Epoch 8/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0286 - accuracy: 0.9928
# Epoch 9/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0151 - accuracy: 0.9986
# Epoch 10/1500
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0144 - accuracy: 0.9986
# Epoch 11/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0214 - accuracy: 0.9957
# Epoch 12/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0086 - accuracy: 1.0000
# Epoch 13/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0068 - accuracy: 1.0000
# Epoch 14/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0068 - accuracy: 0.9986
# Epoch 15/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0127 - accuracy: 0.9942
# Epoch 16/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0097 - accuracy: 0.9971
# Epoch 17/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0054 - accuracy: 1.0000
# Epoch 18/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0047 - accuracy: 1.0000
# Epoch 19/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0072 - accuracy: 0.9986
# Epoch 20/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0057 - accuracy: 0.9986
# Epoch 21/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 22/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0064 - accuracy: 0.9986
# Epoch 23/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 24/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0049 - accuracy: 0.9986
# Epoch 25/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0131 - accuracy: 0.9971
# Epoch 26/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 27/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0076 - accuracy: 0.9971
# Epoch 28/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 29/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 30/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 31/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 32/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0039 - accuracy: 0.9986
# Epoch 33/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0039 - accuracy: 0.9986
# Epoch 34/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 35/1500
# ...
# Epoch 55/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0050 - accuracy: 0.9971
# Epoch 56/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0050 - accuracy: 0.9971
# Epoch 57/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 6.2981e-04 - accuracy: 1.0000
# Epoch 58/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0058 - accuracy: 0.9986
# Epoch 59/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 60/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0068 - accuracy: 0.9971
# Epoch 61/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 62/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0052 - accuracy: 0.9986
# Epoch 63/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 64/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 65/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 66/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 4.9996e-04 - accuracy: 1.0000
# Epoch 67/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0026 - accuracy: 0.9986
# Epoch 68/1500
# 10/11 [==========================>...] - ETA: 0s - loss: 9.1753e-04 - accuracy: 1.0000Restoring model weights from the end of the best epoch: 38.
# 11/11 [==============================] - 0s 6ms/step - loss: 8.5853e-04 - accuracy: 1.0000
# Epoch 68: early stopping
# 4/4 [==============================] - 0s 2ms/step - loss: 1.0646 - accuracy: 0.7755
# 4/4 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.86 (19/22)
# Before appending - Cat IDs: 487, Predictions: 487, Actuals: 487, Gender: 487
# After appending - Cat IDs: 585, Predictions: 585, Actuals: 585, Gender: 585
# Final Test Results - Loss: 1.0646154880523682, Accuracy: 0.7755101919174194, Precision: 0.5814093314093314, Recall: 0.6465020576131687, F1 Score: 0.6088895281933256
# Confusion Matrix:
#  [[68  2 11]
#  [ 0  7  0]
#  [ 9  0  1]]
# outer_fold 5
# Train Set Group Distribution:
# 046A    45
# 000A    39
# 002B    30
# 047A    22
# 020A    20
# 000B    19
# 019A    17
# 057A    17
# 029A    15
# 097A    15
# 097B    14
# 106A    13
# 002A    13
# 051A    12
# 101A    12
# 116A    12
# 111A    12
# 028A    11
# 067A    11
# 042A    11
# 063A    11
# 025A    10
# 059A    10
# 014B    10
# 051B     9
# 016A     9
# 072A     9
# 005A     9
# 022A     9
# 071A     9
# 068A     8
# 013B     8
# 027A     7
# 095A     7
# 036A     7
# 117A     7
# 031A     7
# 039A     6
# 007A     6
# 021A     5
# 050A     5
# 109A     5
# 008A     5
# 094A     5
# 070A     5
# 044A     5
# 025C     4
# 045A     4
# 104A     4
# 026A     4
# 009A     4
# 058A     3
# 012A     3
# 056A     3
# 053A     3
# 010A     3
# 006A     3
# 062A     3
# 105A     3
# 014A     3
# 018A     2
# 087A     2
# 093A     2
# 025B     2
# 102A     2
# 061A     2
# 038A     2
# 052A     2
# 069A     2
# 032A     2
# 054A     2
# 064A     1
# 088A     1
# 024A     1
# 090A     1
# 096A     1
# 110A     1
# 076A     1
# 043A     1
# 019B     1
# 004A     1
# 049A     1
# 048A     1
# 066A     1
# 091A     1
# 026C     1
# 073A     1
# 041A     1
# 092A     1
# 026B     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 103A    33
# 074A    16
# 055A    12
# 040A    10
# 033A     9
# 001A     9
# 065A     9
# 015A     7
# 023A     6
# 099A     6
# 108A     5
# 075A     5
# 003A     4
# 023B     4
# 060A     3
# 113A     3
# 034A     3
# 035A     2
# 011A     2
# 037A     2
# 115A     1
# 100A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    258
# M    192
# F    191
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# M    94
# F    40
# X    18
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [006A, 000A, 071A, 097B, 028A, 019A, 067A, 020...
# kitten    [044A, 014B, 111A, 046A, 047A, 042A, 109A, 050...
# senior    [093A, 097A, 057A, 106A, 104A, 059A, 116A, 051...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [033A, 015A, 001A, 103A, 074A, 034A, 065A, 023...
# kitten                                         [040A, 115A]
# senior                             [055A, 113A, 108A, 011A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 58, 'kitten': 14, 'senior': 18}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 16, 'kitten': 2, 'senior': 4}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '002A' '002B' '004A' '005A' '006A' '007A' '008A' '009A'
#  '010A' '012A' '013B' '014A' '014B' '016A' '018A' '019A' '019B' '020A'
#  '021A' '022A' '024A' '025A' '025B' '025C' '026A' '026B' '026C' '027A'
#  '028A' '029A' '031A' '032A' '036A' '038A' '039A' '041A' '042A' '043A'
#  '044A' '045A' '046A' '047A' '048A' '049A' '050A' '051A' '051B' '052A'
#  '053A' '054A' '056A' '057A' '058A' '059A' '061A' '062A' '063A' '064A'
#  '066A' '067A' '068A' '069A' '070A' '071A' '072A' '073A' '076A' '087A'
#  '088A' '090A' '091A' '092A' '093A' '094A' '095A' '096A' '097A' '097B'
#  '101A' '102A' '104A' '105A' '106A' '109A' '110A' '111A' '116A' '117A']
# Unique Test Group IDs:
# ['001A' '003A' '011A' '015A' '023A' '023B' '033A' '034A' '035A' '037A'
#  '040A' '055A' '060A' '065A' '074A' '075A' '099A' '100A' '103A' '108A'
#  '113A' '115A']
# No common groups found between train and test sets.
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '002A' '002B' '004A' '005A' '006A' '007A' '008A' '009A'
#  '010A' '012A' '013B' '014A' '014B' '016A' '018A' '019A' '019B' '020A'
#  '021A' '022A' '024A' '025A' '025B' '025C' '026A' '026B' '026C' '027A'
#  '028A' '029A' '031A' '032A' '036A' '038A' '039A' '041A' '042A' '043A'
#  '044A' '045A' '046A' '047A' '048A' '049A' '050A' '051A' '051B' '052A'
#  '053A' '054A' '056A' '057A' '058A' '059A' '061A' '062A' '063A' '064A'
#  '066A' '067A' '068A' '069A' '070A' '071A' '072A' '073A' '076A' '087A'
#  '088A' '090A' '091A' '092A' '093A' '094A' '095A' '096A' '097A' '097B'
#  '101A' '102A' '104A' '105A' '106A' '109A' '110A' '111A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['001A' '003A' '011A' '015A' '023A' '023B' '033A' '034A' '035A' '037A'
#  '040A' '055A' '060A' '065A' '074A' '075A' '099A' '100A' '103A' '108A'
#  '113A' '115A']
# Length of X_train_val:
# 641
# Length of y_train_val:
# 641
# Length of groups_train_val:
# 641
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     390
# senior    127
# kitten    124
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     119
# senior     22
# kitten     11
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     390
# senior    127
# kitten    124
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     119
# senior     22
# kitten     11
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 390, 2: 127, 1: 124})
# Epoch 1/1500
# 11/11 [==============================] - 1s 6ms/step - loss: 1.0587 - accuracy: 0.6334
# Epoch 2/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.3393 - accuracy: 0.8783
# Epoch 3/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1284 - accuracy: 0.9626
# Epoch 4/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0696 - accuracy: 0.9797
# Epoch 5/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0456 - accuracy: 0.9860
# Epoch 6/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0368 - accuracy: 0.9875
# Epoch 7/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0196 - accuracy: 0.9953
# Epoch 8/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0141 - accuracy: 0.9984
# Epoch 9/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0175 - accuracy: 0.9969
# Epoch 10/1500
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0112 - accuracy: 1.0000
# Epoch 11/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0137 - accuracy: 0.9969
# Epoch 12/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0072 - accuracy: 1.0000
# Epoch 13/1500
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0078 - accuracy: 1.0000
# Epoch 14/1500
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0156 - accuracy: 0.9969
# Epoch 15/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0066 - accuracy: 1.0000
# Epoch 16/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0109 - accuracy: 0.9953
# Epoch 17/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0073 - accuracy: 0.9984
# Epoch 18/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0068 - accuracy: 0.9969
# Epoch 19/1500
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0072 - accuracy: 0.9984
# Epoch 20/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 21/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0156 - accuracy: 0.9938
# Epoch 22/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 23/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0080 - accuracy: 0.9969
# Epoch 24/1500
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0061 - accuracy: 1.0000
# Epoch 25/1500
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0079 - accuracy: 0.9984
# Epoch 26/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 27/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 28/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0046 - accuracy: 0.9984
# Epoch 29/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 30/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0049 - accuracy: 1.0000
# Epoch 31/1500
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0093 - accuracy: 0.9984
# Epoch 32/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0096 - accuracy: 0.9953
# Epoch 33/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 34/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0042 - accuracy: 0.9984
# Epoch 35/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0045 - accuracy: 0.9984
# Epoch 36/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0043 - accuracy: 0.9984
# Epoch 37/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 38/1500
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0038 - accuracy: 0.9984
# Epoch 39/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 40/1500
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0046 - accuracy: 0.9984
# Epoch 41/1500
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 42/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 43/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0068 - accuracy: 0.9969
# Epoch 44/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0048 - accuracy: 0.9969
# Epoch 45/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 46/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0044 - accuracy: 0.9984
# Epoch 47/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 48/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0054 - accuracy: 0.9984
# Epoch 49/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0037 - accuracy: 0.9984
# Epoch 50/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 51/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0040 - accuracy: 0.9984
# Epoch 52/1500
# 11/11 [==============================] - 0s 15ms/step - loss: 0.0032 - accuracy: 0.9984
# Epoch 53/1500
# 11/11 [==============================] - 0s 20ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 54/1500
# 11/11 [==============================] - 0s 9ms/step - loss: 0.0036 - accuracy: 0.9984
# Epoch 55/1500
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 56/1500
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 57/1500
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0045 - accuracy: 0.9984
# Epoch 58/1500
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0057 - accuracy: 0.9984
# Epoch 59/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0034 - accuracy: 0.9984
# Epoch 60/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 61/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0064 - accuracy: 0.9969
# Epoch 62/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 63/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 64/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0045 - accuracy: 0.9984
# Epoch 65/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 66/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0069 - accuracy: 0.9984
# Epoch 67/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 68/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 69/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 70/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 71/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0030 - accuracy: 0.9984
# Epoch 72/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 73/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0033 - accuracy: 0.9984
# Epoch 74/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 75/1500
# 10/11 [==========================>...] - ETA: 0s - loss: 7.7262e-04 - accuracy: 1.0000Restoring model weights from the end of the best epoch: 45.
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 75: early stopping
# 5/5 [==============================] - 0s 1ms/step - loss: 1.0160 - accuracy: 0.7237
# 5/5 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.77 (17/22)
# Before appending - Cat IDs: 585, Predictions: 585, Actuals: 585, Gender: 585
# After appending - Cat IDs: 737, Predictions: 737, Actuals: 737, Gender: 737
# Final Test Results - Loss: 1.0160062313079834, Accuracy: 0.7236841917037964, Precision: 0.6166666666666667, Recall: 0.7094474153297683, F1 Score: 0.6516500474833807
# Confusion Matrix:
#  [[91  4 24]
#  [ 0 11  0]
#  [14  0  8]]
#
# Final Average F1-Score across all UNSEEN TEST sets: 0.5311299355987876
#
# Final Average Loss across all UNSEEN TEST sets: 2.0187743663787843
#
# Final Average Accuracy across all UNSEEN TEST sets: 0.6571752905845643
#
# Final Average Precision across all UNSEEN TEST sets: 0.5757057226842851
#
# Final Average Recall across all UNSEEN TEST sets: 0.5939491850757888

# %%
seed_2_folds_values = (unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1)

# Plotting all fold metrics
seed_2_folds_plot = plot_all_metrics(unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1, "Folds", "Fold Number")

# %% [markdown]
# ## Majority Voting on Total Entries per cat_id

# %%
# Debugging print statements
print(f'Checking - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
# Out:
# Checking - Cat IDs: 737, Predictions: 737, Actuals: 737, Gender: 737

# %%
# Create results df
full_results = pd.DataFrame({
    'cat_id': all_cat_ids,
    'predicted_age_group': all_predicted_age_groups,
    'actual_age_group': all_actual_age_groups,
    'all_gender': all_gender
})

# create a correct majority prediction column
full_results['correct'] = full_results['predicted_age_group'] == full_results['actual_age_group']

# %%
# Group by cat_id and aggregate predicted age groups
majority_votes = full_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first()

# Calculate the accuracy of majority voting
correct_predictions = (majority_votes == actual_groups).sum()
total_cats = len(actual_groups)
majority_vote_accuracy = correct_predictions / total_cats

logger(f"Overall Majority Vote Accuracy for cat_id: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

# store for final evaluation 
all_majority_vote_accuracies.append(majority_vote_accuracy)
# Out:
# Overall Majority Vote Accuracy for cat_id: 0.75 (83/110)

# %%
# Detailed df with predictions, actual labels, and comparison including majority vote
detailed_results = full_results.groupby('cat_id').apply(
    lambda x: pd.Series({
        'Predictions': list(x['predicted_age_group']),
        'Majority Vote': x['predicted_age_group'].mode()[0],
        'Actual Age Group': x['actual_age_group'].iloc[0],
        'Correct Majority Vote': x['predicted_age_group'].mode()[0] == x['actual_age_group'].iloc[0]
    })
).reset_index()

# Convert to DataFrame for better formatting and display
detailed_results = pd.DataFrame(detailed_results)

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 10)
pd.set_option('display.width', 1000)

sorted_detailed_results = detailed_results.sort_values(by='Correct Majority Vote', ascending=False)

# Display the sorted DataFrame
sorted_detailed_results
# Out:
#     cat_id                                        Predictions Majority Vote Actual Age Group  Correct Majority Vote
# 0     000B  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 80    074A  [adult, adult, senior, adult, adult, adult, ad...         adult            adult                   True
# 78    072A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 77    071A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 76    070A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 75    069A                                    [adult, senior]         adult            adult                   True
# 74    068A  [adult, senior, adult, adult, senior, adult, s...         adult            adult                   True
# 73    067A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 72    066A                                            [adult]         adult            adult                   True
# 71    065A  [senior, adult, adult, adult, kitten, senior, ...         adult            adult                   True
# 70    064A                                            [adult]         adult            adult                   True
# 69    063A  [adult, adult, adult, senior, senior, adult, a...         adult            adult                   True
# 68    062A                              [adult, adult, adult]         adult            adult                   True
# 66    060A                             [adult, kitten, adult]         adult            adult                   True
# 64    058A                           [senior, senior, senior]        senior           senior                   True
# 62    056A                            [senior, senior, adult]        senior           senior                   True
# 58    052A                                     [adult, adult]         adult            adult                   True
# 54    049A                                           [kitten]        kitten           kitten                   True
# 53    048A                                           [kitten]        kitten           kitten                   True
# 50    044A           [kitten, kitten, kitten, kitten, kitten]        kitten           kitten                   True
# 49    043A                                           [kitten]        kitten           kitten                   True
# 79    073A                                            [adult]         adult            adult                   True
# 81    075A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 46    040A  [kitten, kitten, kitten, kitten, kitten, kitte...        kitten           kitten                   True
# 82    076A                                            [adult]         adult            adult                   True
# 108   116A  [senior, senior, senior, kitten, adult, adult,...        senior           senior                   True
# 107   115A                                           [kitten]        kitten           kitten                   True
# 105   111A  [adult, kitten, kitten, kitten, kitten, kitten...        kitten           kitten                   True
# 104   110A                                           [kitten]        kitten           kitten                   True
# 100   105A                              [adult, adult, adult]         adult            adult                   True
# 98    103A  [adult, adult, senior, adult, senior, adult, a...         adult            adult                   True
# 97    102A                                    [adult, senior]         adult            adult                   True
# 96    101A  [adult, senior, adult, adult, senior, adult, a...         adult            adult                   True
# 95    100A                                            [adult]         adult            adult                   True
# 94    099A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 93    097B  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 91    096A                                            [adult]         adult            adult                   True
# 90    095A  [senior, adult, senior, adult, adult, adult, a...         adult            adult                   True
# 89    094A           [senior, senior, senior, senior, senior]        senior           senior                   True
# 87    092A                                            [adult]         adult            adult                   True
# 86    091A                                            [adult]         adult            adult                   True
# 85    090A                                           [senior]        senior           senior                   True
# 84    088A                                            [adult]         adult            adult                   True
# 83    087A                                     [adult, adult]         adult            adult                   True
# 47    041A                                           [kitten]        kitten           kitten                   True
# 55    050A           [kitten, kitten, kitten, kitten, kitten]        kitten           kitten                   True
# 45    039A         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 15    014A                              [adult, adult, adult]         adult            adult                   True
# 29    025B                                    [senior, adult]         adult            adult                   True
# 28    025A  [adult, adult, adult, senior, adult, adult, ad...         adult            adult                   True
# 26    023B                       [adult, adult, adult, adult]         adult            adult                   True
# 24    022A  [adult, adult, adult, adult, adult, adult, kit...         adult            adult                   True
# 23    021A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 22    020A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 21    019B                                            [adult]         adult            adult                   True
# 20    019A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 19    018A                                     [adult, adult]         adult            adult                   True
# 17    015A  [adult, adult, adult, senior, adult, adult, ad...         adult            adult                   True
# 14    013B  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 31    026A                       [adult, adult, adult, adult]         adult            adult                   True
# 13    012A                              [adult, adult, adult]         adult            adult                   True
# 11    010A                             [adult, adult, senior]         adult            adult                   True
# 10    009A                       [adult, adult, adult, adult]         adult            adult                   True
# 9     008A               [adult, adult, adult, senior, adult]         adult            adult                   True
# 8     007A        [adult, adult, adult, adult, senior, adult]         adult            adult                   True
# 7     006A                              [adult, adult, adult]         adult            adult                   True
# 5     004A                                            [adult]         adult            adult                   True
# 4     003A                       [adult, adult, adult, adult]         adult            adult                   True
# 3     002B  [adult, adult, senior, adult, adult, adult, ad...         adult            adult                   True
# 2     002A  [adult, adult, senior, adult, adult, adult, ad...         adult            adult                   True
# 30    025C                      [adult, senior, adult, adult]         adult            adult                   True
# 25    023A        [adult, senior, adult, adult, adult, adult]         adult            adult                   True
# 32    026B                                            [adult]         adult            adult                   True
# 36    029A  [senior, senior, adult, adult, adult, adult, a...         adult            adult                   True
# 40    034A                              [adult, adult, adult]         adult            adult                   True
# 41    035A                                    [senior, adult]         adult            adult                   True
# 39    033A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 37    031A  [adult, adult, adult, senior, adult, adult, ad...         adult            adult                   True
# 42    036A  [adult, adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 38    032A                                     [adult, adult]         adult            adult                   True
# 43    037A                                    [senior, adult]         adult            adult                   True
# 35    028A  [senior, adult, adult, senior, adult, adult, s...         adult            adult                   True
# 34    027A  [adult, adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 106   113A                             [adult, adult, senior]         adult           senior                  False
# 51    045A                      [kitten, adult, adult, adult]         adult           kitten                  False
# 56    051A  [adult, adult, adult, adult, adult, adult, adu...         adult           senior                  False
# 103   109A              [adult, kitten, adult, kitten, adult]         adult           kitten                  False
# 102   108A              [senior, adult, adult, senior, adult]         adult           senior                  False
# 101   106A  [adult, adult, adult, kitten, adult, adult, ad...         adult           senior                  False
# 6     005A  [adult, senior, senior, senior, senior, senior...        senior            adult                  False
# 99    104A                       [adult, adult, adult, adult]         adult           senior                  False
# 52    047A  [adult, adult, adult, adult, adult, adult, adu...         adult           kitten                  False
# 48    042A  [adult, adult, adult, adult, adult, adult, adu...         adult           kitten                  False
# 1     001A  [adult, senior, adult, senior, senior, senior,...        senior            adult                  False
# 57    051B  [adult, adult, adult, adult, adult, adult, adu...         adult           senior                  False
# 12    011A                                    [adult, senior]         adult           senior                  False
# 92    097A  [adult, senior, adult, adult, adult, senior, a...         adult           senior                  False
# 33    026C                                           [kitten]        kitten            adult                  False
# 59    053A                            [senior, adult, senior]        senior            adult                  False
# 88    093A                                     [adult, adult]         adult           senior                  False
# 16    014B  [senior, kitten, adult, adult, kitten, adult, ...         adult           kitten                  False
# 60    054A                                     [adult, adult]         adult           senior                  False
# 18    016A  [adult, adult, adult, adult, senior, adult, se...         adult           senior                  False
# 61    055A  [adult, senior, adult, adult, adult, senior, s...         adult           senior                  False
# 63    057A  [adult, senior, adult, adult, senior, adult, a...         adult           senior                  False
# 65    059A  [adult, senior, adult, adult, adult, adult, ad...         adult           senior                  False
# 44    038A                                   [kitten, kitten]        kitten            adult                  False
# 67    061A                                     [adult, adult]         adult           senior                  False
# 27    024A                                            [adult]         adult           senior                  False
# 109   117A  [adult, adult, adult, adult, adult, adult, adult]         adult           senior                  False

# %%
# Create df for majority votes
majority_df = majority_votes.reset_index()
majority_df.columns = ['cat_id', 'Majority_Vote']

# Get actual groups for each cat_id
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first().reset_index()

# Merge majority votes with actual groups
majority_with_actual = pd.merge(majority_df, actual_groups, on='cat_id')

# Add a column to check if the majority vote was correct
majority_with_actual['Majority_Correct'] = majority_with_actual['Majority_Vote'] == majority_with_actual['actual_age_group']

# Count correct majority votes per class
correct_majority_votes_per_class = majority_with_actual.groupby('actual_age_group')['Majority_Correct'].sum()

print("Correct Majority Votes per Class:")
print(correct_majority_votes_per_class)
# Out:
# Correct Majority Votes per Class:
# actual_age_group
# adult     68
# kitten    10
# senior     5
# Name: Majority_Correct, dtype: int64

# %%
# Calculate the total count and the number of correct predictions for each class
class_stats = majority_with_actual.groupby('actual_age_group').agg(
    total_count=('Majority_Correct', 'size'),  # Total number of cases per class
    correct_count=('Majority_Correct', 'sum')  # Sum of correct predictions per class
).reset_index()

# Calculate accuracy for each class
class_stats['accuracy'] = class_stats['correct_count'] / class_stats['total_count'] * 100

# store for final evaluation 
all_majority_vote_details.append(class_stats)

# Log detailed stats
print("Detailed Class Statistics for Majority Votes:")
print(class_stats)
# Out:
# Detailed Class Statistics for Majority Votes:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult           73             68  93.150685
# 1           kitten           15             10  66.666667
# 2           senior           22              5  22.727273

# %%
# Plot for Detailed Class Statistics for Majority Votes
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Accuracy of Majority Votes by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Detailed Class Statistics

# %%
# Calculate the total count and the number of correct predictions for each class
class_stats = full_results.groupby('actual_age_group').agg(
    total_count=('correct', 'size'),
    correct_count=('correct', 'sum')
).reset_index()

# Calculate accuracy for each class
class_stats['accuracy'] = class_stats['correct_count'] / class_stats['total_count'] * 100

# store for final evaluation 
all_class_stats.append(class_stats)

# Log the detailed stats
print("Detailed Class Statistics:")
print(class_stats)
# Out:
# Detailed Class Statistics:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult          476            398  83.613445
# 1           kitten          112             45  40.178571
# 2           senior          149             39  26.174497

# %%
# Plot for Detailed Class Statistics (Overall)
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Overall Accuracy by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Gender Exploration

# %%
# Group by gender and calculate the total count, correct predictions, and accuracy
gender_stats = full_results.groupby('all_gender').agg(
    count=('cat_id', 'size'),  # Total number of cases per gender
    correct=('correct', 'sum')  # Sum of correct predictions per gender
).reset_index()

# Calculate accuracy for each gender
gender_stats['accuracy'] = (gender_stats['correct'] / gender_stats['count'] * 100).round(2)

# Display the DataFrame
print("Accuracy by Gender:")
print(gender_stats)

# store for final evaluation 
all_gender_stats.append(gender_stats)
# Out:
# Accuracy by Gender:
#   all_gender  count  correct  accuracy
# 0          F    198      132     66.67
# 1          M    286      204     71.33
# 2          X    253      146     57.71

# %%
# Plot for Accuracy by Gender
styled_barplot(gender_stats, 'all_gender', 'accuracy', 
               'Accuracy by Gender', 
               'Gender', 'Accuracy (%)')

# %% [markdown]
# ### Log current total CV Stats

# %%
print("Total Majority Vote Accuracy so far:", all_majority_vote_accuracies)
print("Total Class Statistics so far:\n", all_class_stats)
print("Total Gender Accuracy so far:\n", all_gender_stats)
# Out:
# Total Majority Vote Accuracy so far: [0.7727272727272727, 0.7545454545454545]
# Total Class Statistics so far:
#  [  actual_age_group  total_count  correct_count   accuracy
# 0            adult          472            410  86.864407
# 1           kitten           95             51  53.684211
# 2           senior          149             39  26.174497,   actual_age_group  total_count  correct_count   accuracy
# 0            adult          476            398  83.613445
# 1           kitten          112             45  40.178571
# 2           senior          149             39  26.174497]
# Total Gender Accuracy so far:
#  [  all_gender  count  correct  accuracy
# 0          F    194      148     76.29
# 1          M    286      206     72.03
# 2          X    236      146     61.86,   all_gender  count  correct  accuracy
# 0          F    198      132     66.67
# 1          M    286      204     71.33
# 2          X    253      146     57.71]

# %% [markdown]
# # RANDOM SEED 3

# %%
# Set a fixed random seed for reproducibility
random.seed(int(random_seeds[2]))
np.random.seed(int(random_seeds[2]))
tf.random.set_seed(int(random_seeds[2]))

# Load datasets
dataframe = pd.read_csv('/Users/astrid/PycharmProjects/perch-2/scripts/perch_embeddings_april_10.csv')
dataframe.drop('mean_freq', axis=1, inplace=True)

def assign_age_group(age, age_groups):
    for group_name, age_range in age_groups.items():
        if age_range[0] <= age < age_range[1]:
            return group_name
    return 'Unknown'  # For any age that doesn't fit the defined groups

# Define age groups
age_groups = {
    'kitten': (0, 0.5),
    'adult': (0.5, 12),
    'senior': (12, 20)
}

# Create a new column for the age group
dataframe['age_group'] = dataframe['target'].apply(assign_age_group, age_groups=age_groups)

print(dataframe['age_group'].value_counts())
# Out:
# adult     509
# senior    149
# kitten    135
# Name: age_group, dtype: int64

# %%
# Separate features and labels
X = dataframe.iloc[:, :-4].values  # all columns except the last four

# Encode the 'age_group' column as integers using LabelEncoder
label_encoder = LabelEncoder()
encoded_y = label_encoder.fit_transform(dataframe['age_group'].values)

# Use the encoded labels for splitting and one-hot encoding
y = encoded_y  

# Convert 'cat_id' column to numpy array to be used as groups array for GroupKFold
groups = dataframe['cat_id'].values

# %%
tf.keras.backend.clear_session()

# %% [markdown]
# ## Run Setup

# %%
all_cat_ids = []
all_predicted_age_groups = []
all_actual_age_groups = []
all_gender = []

# Define the StratifiedGroupKFold splitter for 4 fold CV with random shuffling
outer_cv = StratifiedGroupKFold(n_splits=5, shuffle=True, random_state=int(random_seeds[2]))

# unseen test set metrics
unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1 = [], [], [], [], []

outer_fold = 0

# Use the splitter to generate indices for training and testing sets
# Note: GroupShuffleSplit.split returns indices, so we use it to index the arrays
for train_val_idx, test_idx in outer_cv.split(X, y, groups):
    outer_fold += 1
    logger(f"outer_fold {outer_fold}", file=log_file_path)

    # Convert indices back to DataFrame for easy manipulation
    df_train_val = dataframe.iloc[train_val_idx]
    df_test = dataframe.iloc[test_idx]

    ##############################
    # ASSESSING SPLITS BY CAT_ID #
    ##############################
    
    # Get the distribution of groups
    training_validation_group_distribution = df_train_val['cat_id'].value_counts()  
    testing_group_distribution = df_test['cat_id'].value_counts()  
    
    # Log or print the distribution
    logger(f"Train Set Group Distribution:\n{training_validation_group_distribution}", file=log_file_path)
    logger(f"Testing Set Group Distribution:\n{testing_group_distribution}", file=log_file_path)

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val['gender'].value_counts()
    testing_gender_distribution = df_test['gender'].value_counts()
    
    # Log the distribution
    logger(f"Training Set Gender Distribution BEFORE SWAP:\n{training_gender_distribution}", file=log_file_path)
    logger(f"Testing Set Gender Distribution BEFORE SWAP:\n{testing_gender_distribution}", file=log_file_path)

    # Group by 'age_group' and then list unique 'cat_id' within each age group
    unique_cat_ids_per_age_group_train_val = df_train_val.groupby('age_group')['cat_id'].unique()
    unique_cat_ids_per_age_group_test = df_test.groupby('age_group')['cat_id'].unique()
    
    # Log results
    logger(f"Unique Cat IDs per Age Group in Training/Validation Set:\n{unique_cat_ids_per_age_group_train_val}", file=log_file_path)
    logger(f"Unique Cat IDs per Age Group in Testing Set:\n{unique_cat_ids_per_age_group_test}", file=log_file_path)

    # Calculate the count of unique identifiers per age group for training and testing set
    counts_train_val = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_train_val.items()}
    counts_test = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_test.items()}

    # Log the counts of unique identifiers per age group
    logger(f"Count of Unique Cat IDs per Age Group in Training/Validation Set:\n{counts_train_val}", file=log_file_path)
    logger(f"Count of Unique Cat IDs per Age Group in Testing Set:\n{counts_test}", file=log_file_path)

    #######################################################
    # CONTINUE WITH ENSURING VALID AND APPROPRIATE SPLITS #
    #######################################################
    
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    groups_train_val, groups_test = groups[train_val_idx], groups[test_idx]

    # logging identifier splits 
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)

    # check group splits
    check_initial_group_split(groups_train_val, groups_test)

    # Specify the cat_ids that must be in the training/validation set
    specific_cat_ids = ['000A', '046A']
    
    # Perform the swapping operation
    train_val_idx, test_idx = swap_cat_id_instances(dataframe, train_val_idx, test_idx, specific_cat_ids)
    
    # Re-assign the sets based on the updated indices
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    new_groups_train_val, new_groups_test = groups[train_val_idx], groups[test_idx]

    # Find differences for training and test sets
    moved_to_train_val, removed_from_train_val = find_group_differences(groups_train_val, new_groups_train_val)
    moved_to_test, removed_from_test = find_group_differences(groups_test, new_groups_test)
    
    # Display the results
    logger(f"Moved to Training/Validation Set:\n{moved_to_train_val}", file=log_file_path)
    logger(f"Removed from Training/Validation Set:\n{removed_from_train_val}", file=log_file_path)
    logger(f"Moved to Test Set:\n{moved_to_test}", file=log_file_path)
    logger(f"Removed from Test Set\n{removed_from_test}", file=log_file_path)

    # Update X_train_val, X_test, y_train_val, y_test, groups_train_val, groups_test based on updated indices
    X_train_val = X[train_val_idx]
    y_train_val = y[train_val_idx]
    groups_train_val = groups[train_val_idx]
    
    X_test = X[test_idx]
    y_test = y[test_idx]
    groups_test = groups[test_idx]

    # logging identifier splits again after potential swaps
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"AFTER SWAP - Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"AFTER SWAP - Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)
    
    # Verify the lengths are consistent
    logger(f"Length of X_train_val:\n{len(X_train_val)}", file=log_file_path)
    logger(f"Length of y_train_val:\n{len(y_train_val)}", file=log_file_path)
    logger(f"Length of groups_train_val:\n{len(groups_train_val)}", file=log_file_path)

    # Check group splits once more
    check_initial_group_split(groups_train_val, groups_test)

    # Convert the modified indices back to a DataFrame representing the updated df_train_val
    df_train_val_updated = dataframe.iloc[train_val_idx].copy()
    df_test_updated = dataframe.iloc[test_idx].copy()

    ############################
    # LOGGING AGE GROUP SPLITS #
    ############################

    # Get the distribution of age groups of age groups before the update
    training_validation_age_group_distribution = df_train_val['age_group'].value_counts()
    testing_age_group_distribution = df_test['age_group'].value_counts()
    
    # Logthe distribution
    logger(f"Train Age Group Distribution BEFORE SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution BEFORE SWAP:\n{testing_age_group_distribution}", file=log_file_path)

    # Get the distribution of age groups after the update
    training_validation_age_group_distribution = df_train_val_updated['age_group'].value_counts()
    testing_age_group_distribution = df_test_updated['age_group'].value_counts()
    
    # Log the distribution
    logger(f"Train Age Group Distribution AFTER SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution AFTER SWAP:\n{testing_age_group_distribution}", file=log_file_path)
    
    ########################################################
    # TRACKING FINAL CAT_IDs & GENDER AFTER REDISTRIBUTION #
    ########################################################

    # Get the distribution of groups
    training_validation_group_distribution = df_train_val_updated['cat_id'].value_counts()  
    testing_group_distribution = df_test_updated['cat_id'].value_counts()  

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val_updated['gender'].value_counts()
    testing_gender_distribution = df_test_updated['gender'].value_counts()
    
    logger(f"\n Starting training on unseen test set\n", file=log_file_path)

    ###################
    # PREPARING MODEL #
    ###################

    # Calculate the distribution of age groups in y_train_val
    age_group_distribution = Counter(y_train_val)
    print("Age group distribution:", age_group_distribution)

    # EarlyStopping callback: monitor 'loss' instead of 'val_loss' for the test set
    early_stopping = EarlyStopping(
        monitor='loss',  
        min_delta=0.001, 
        patience=30,  
        verbose=1,  
        restore_best_weights=True  
    )

    # One final shuffle to ensure randomness
    outer_shuffle_idx = np.random.permutation(len(X_train_val))
    X_train_val = X_train_val[outer_shuffle_idx]
    y_train_val = y_train_val[outer_shuffle_idx]
    
    # Scale the features
    scaler_full = StandardScaler().fit(X_train_val)
    X_train_full_scaled = scaler_full.transform(X_train_val)
    X_test_scaled = scaler_full.transform(X_test)
    
    # Encode the labels
    y_train_full_encoded = to_categorical(y_train_val)
    y_test_encoded = to_categorical(y_test)

    #######################
    # BUILD & TRAIN MODEL #
    #######################

    optimizers = {
        'Adamax': Adamax(learning_rate=0.00510251984616472)
    }
    
    # Model definition with dynamic number of layers
    model_full = Sequential()
    model_full.add(Dense(480, activation='relu', input_shape=(X_train_full_scaled.shape[1],)))
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.2011047009431978))  
    model_full.add(Dense(256, activation='relu',)) 
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.14956886311951184))  
    model_full.add(Dense(256, activation='relu'))  
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.42291461228250665))  
    model_full.add(Dense(3, activation='softmax'))  
    
    # Use the optimizer from the parameters
    optimizer = optimizers['Adamax']  # optimizer_key from parameters
    
    # Compile the model
    model_full.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    
    # Train the model on the full training set
    history_full = model_full.fit(X_train_full_scaled, y_train_full_encoded, epochs=1500, batch_size=64,
                                  verbose=1, callbacks=[early_stopping])
    
    # Evaluate the model on the held-out test set
    test_loss, test_accuracy = model_full.evaluate(X_test_scaled, y_test_encoded)

    y_test_pred_prob = model_full.predict(X_test_scaled)
    y_test_pred = np.argmax(y_test_pred_prob, axis=1)  
    y_test_true = np.argmax(y_test_encoded, axis=1)    

    ################################
    # LOG MAJORITY VOTE PER CAT_ID #
    ################################

    # Convert numeric predictions back to age group labels
    predicted_age_groups = label_encoder.inverse_transform(y_test_pred)
    actual_labels = label_encoder.inverse_transform(y_test_true)
    
    # Map predictions and actual labels back to cat_ids
    test_results = pd.DataFrame({
        'cat_id': df_test_updated['cat_id'],
        'predicted_age_group': predicted_age_groups,
        'actual_age_group': actual_labels
    })
    
    # Group by cat_id and aggregate predicted age groups
    majority_votes = test_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
    actual_groups = test_results.groupby('cat_id')['actual_age_group'].first()
    
    # Calculate the accuracy of majority voting
    correct_predictions = (majority_votes == actual_groups).sum()
    total_cats = len(actual_groups)
    majority_vote_accuracy = correct_predictions / total_cats
    
    # Log the accuracy of the majority voting
    logger(f"Majority Vote Accuracy for cat_id for this fold: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

    ####################################################
    # COLLECT PREDICTIONS FOR GENDER & CAT_ID ANALYSIS #
    ####################################################

    # Debugging print statements
    print(f'Before appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Extend lists with current fold results
    all_cat_ids.extend(df_test_updated['cat_id'].tolist())
    all_predicted_age_groups.extend(predicted_age_groups)
    all_actual_age_groups.extend(actual_labels)
    all_gender.extend(df_test_updated['gender'].tolist())

    # Debugging print statements
    print(f'After appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Calculate additional metrics
    test_precision = precision_score(y_test_true, y_test_pred, average='macro')  # Use 'macro' for imbalanced datasets
    test_recall = recall_score(y_test_true, y_test_pred, average='macro')
    test_f1 = f1_score(y_test_true, y_test_pred, average='macro')

    # prepare averages of outer metrics
    unseen_f1.append(test_f1)
    unseen_losses.append(test_loss)
    unseen_accuracies.append(test_accuracy)
    unseen_precisions.append(test_precision)
    unseen_recalls.append(test_recall)

    # Print final test results
    logger(f"Final Test Results - Loss: {test_loss}, Accuracy: {test_accuracy}, Precision: {test_precision}, Recall: {test_recall}, F1 Score: {test_f1}", file=log_file_path)

    # Generate the confusion matrix
    cm = confusion_matrix(y_test, y_test_pred)
    logger(f"Confusion Matrix:\n {cm}", file=log_file_path)

# Calculate the overall average metrics
unseen_set_avg_f1 = np.mean(unseen_f1)
unseen_set_avg_loss = np.mean(unseen_losses)
unseen_set_avg_acc = np.mean(unseen_accuracies)
unseen_set_avg_precision = np.mean(unseen_precisions)
unseen_set_avg_recall = np.mean(unseen_recalls)

logger(f"\nFinal Average F1-Score across all UNSEEN TEST sets: {unseen_set_avg_f1}", file=log_file_path)
logger(f"\nFinal Average Loss across all UNSEEN TEST sets: {unseen_set_avg_loss}", file=log_file_path)
logger(f"\nFinal Average Accuracy across all UNSEEN TEST sets: {unseen_set_avg_acc}", file=log_file_path)
logger(f"\nFinal Average Precision across all UNSEEN TEST sets: {unseen_set_avg_precision}", file=log_file_path)
logger(f"\nFinal Average Recall across all UNSEEN TEST sets: {unseen_set_avg_recall}\n", file=log_file_path)

# Append averages to total lists
all_f1.append(unseen_set_avg_f1)
all_losses.append(unseen_set_avg_loss)
all_accuracies.append(unseen_set_avg_acc)
all_precisions.append(unseen_set_avg_precision)
all_recalls.append(unseen_set_avg_recall)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# outer_fold 1
# Train Set Group Distribution:
# 046A    45
# 000A    39
# 103A    33
# 002B    30
# 047A    22
# 020A    20
# 019A    17
# 057A    17
# 074A    16
# 029A    15
# 106A    13
# 055A    12
# 101A    12
# 116A    12
# 111A    12
# 028A    11
# 067A    11
# 063A    11
# 042A    11
# 040A    10
# 059A    10
# 014B    10
# 025A    10
# 051B     9
# 005A     9
# 072A     9
# 022A     9
# 071A     9
# 001A     9
# 033A     9
# 016A     9
# 068A     8
# 013B     8
# 095A     7
# 027A     7
# 117A     7
# 039A     6
# 099A     6
# 109A     5
# 008A     5
# 075A     5
# 050A     5
# 094A     5
# 108A     5
# 044A     5
# 023B     4
# 003A     4
# 026A     4
# 025C     4
# 058A     3
# 056A     3
# 060A     3
# 105A     3
# 012A     3
# 010A     3
# 006A     3
# 034A     3
# 014A     3
# 062A     3
# 113A     3
# 093A     2
# 037A     2
# 061A     2
# 011A     2
# 035A     2
# 038A     2
# 018A     2
# 087A     2
# 054A     2
# 069A     2
# 032A     2
# 004A     1
# 024A     1
# 090A     1
# 100A     1
# 076A     1
# 110A     1
# 115A     1
# 019B     1
# 088A     1
# 043A     1
# 064A     1
# 048A     1
# 066A     1
# 073A     1
# 096A     1
# 026C     1
# 041A     1
# 092A     1
# 049A     1
# 091A     1
# 026B     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 000B    19
# 097A    15
# 097B    14
# 002A    13
# 051A    12
# 065A     9
# 036A     7
# 031A     7
# 015A     7
# 007A     6
# 023A     6
# 070A     5
# 021A     5
# 009A     4
# 104A     4
# 045A     4
# 053A     3
# 052A     2
# 102A     2
# 025B     2
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    260
# X    236
# F    151
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# F    80
# X    40
# M    26
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [006A, 000A, 033A, 001A, 103A, 071A, 028A, 019...
# kitten    [044A, 014B, 111A, 040A, 046A, 047A, 042A, 109...
# senior    [093A, 057A, 106A, 055A, 059A, 113A, 116A, 051...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [015A, 097B, 065A, 002A, 009A, 023A, 070A, 007...
# kitten                                               [045A]
# senior                                   [097A, 104A, 051A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 58, 'kitten': 15, 'senior': 19}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 16, 'kitten': 1, 'senior': 3}
# Unique Training/Validation Group IDs:
# ['000A' '001A' '002B' '003A' '004A' '005A' '006A' '008A' '010A' '011A'
#  '012A' '013B' '014A' '014B' '016A' '018A' '019A' '019B' '020A' '022A'
#  '023B' '024A' '025A' '025C' '026A' '026B' '026C' '027A' '028A' '029A'
#  '032A' '033A' '034A' '035A' '037A' '038A' '039A' '040A' '041A' '042A'
#  '043A' '044A' '046A' '047A' '048A' '049A' '050A' '051B' '054A' '055A'
#  '056A' '057A' '058A' '059A' '060A' '061A' '062A' '063A' '064A' '066A'
#  '067A' '068A' '069A' '071A' '072A' '073A' '074A' '075A' '076A' '087A'
#  '088A' '090A' '091A' '092A' '093A' '094A' '095A' '096A' '099A' '100A'
#  '101A' '103A' '105A' '106A' '108A' '109A' '110A' '111A' '113A' '115A'
#  '116A' '117A']
# Unique Test Group IDs:
# ['000B' '002A' '007A' '009A' '015A' '021A' '023A' '025B' '031A' '036A'
#  '045A' '051A' '052A' '053A' '065A' '070A' '097A' '097B' '102A' '104A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '001A' '002B' '003A' '004A' '005A' '006A' '008A' '010A' '011A'
#  '012A' '013B' '014A' '014B' '016A' '018A' '019A' '019B' '020A' '022A'
#  '023B' '024A' '025A' '025C' '026A' '026B' '026C' '027A' '028A' '029A'
#  '032A' '033A' '034A' '035A' '037A' '038A' '039A' '040A' '041A' '042A'
#  '043A' '044A' '046A' '047A' '048A' '049A' '050A' '051B' '054A' '055A'
#  '056A' '057A' '058A' '059A' '060A' '061A' '062A' '063A' '064A' '066A'
#  '067A' '068A' '069A' '071A' '072A' '073A' '074A' '075A' '076A' '087A'
#  '088A' '090A' '091A' '092A' '093A' '094A' '095A' '096A' '099A' '100A'
#  '101A' '103A' '105A' '106A' '108A' '109A' '110A' '111A' '113A' '115A'
#  '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['000B' '002A' '007A' '009A' '015A' '021A' '023A' '025B' '031A' '036A'
#  '045A' '051A' '052A' '053A' '065A' '070A' '097A' '097B' '102A' '104A']
# Length of X_train_val:
# 647
# Length of y_train_val:
# 647
# Length of groups_train_val:
# 647
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     398
# kitten    131
# senior    118
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     111
# senior     31
# kitten      4
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     398
# kitten    131
# senior    118
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     111
# senior     31
# kitten      4
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 398, 1: 131, 2: 118})
# Epoch 1/1500
# 11/11 [==============================] - 1s 7ms/step - loss: 0.9571 - accuracy: 0.6785
# Epoch 2/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.2504 - accuracy: 0.9026
# Epoch 3/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1189 - accuracy: 0.9629
# Epoch 4/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0899 - accuracy: 0.9753
# Epoch 5/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1009 - accuracy: 0.9614
# Epoch 6/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0313 - accuracy: 0.9938
# Epoch 7/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0282 - accuracy: 0.9938
# Epoch 8/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0265 - accuracy: 0.9923
# Epoch 9/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0337 - accuracy: 0.9892
# Epoch 10/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0246 - accuracy: 0.9938
# Epoch 11/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0147 - accuracy: 0.9969
# Epoch 12/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0172 - accuracy: 0.9954
# Epoch 13/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0186 - accuracy: 0.9923
# Epoch 14/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0262 - accuracy: 0.9938
# Epoch 15/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0170 - accuracy: 0.9969
# Epoch 16/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0089 - accuracy: 1.0000
# Epoch 17/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0161 - accuracy: 0.9969
# Epoch 18/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0252 - accuracy: 0.9954
# Epoch 19/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0296 - accuracy: 0.9892
# Epoch 20/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0380 - accuracy: 0.9892
# Epoch 21/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0307 - accuracy: 0.9923
# Epoch 22/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0184 - accuracy: 0.9938
# Epoch 23/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0112 - accuracy: 0.9969
# Epoch 24/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0164 - accuracy: 0.9938
# Epoch 25/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0197 - accuracy: 0.9954
# Epoch 26/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0124 - accuracy: 0.9985
# Epoch 27/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0120 - accuracy: 0.9969
# Epoch 28/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0216 - accuracy: 0.9954
# Epoch 29/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0332 - accuracy: 0.9907
# Epoch 30/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0158 - accuracy: 0.9954
# Epoch 31/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0113 - accuracy: 0.9969
# Epoch 32/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0140 - accuracy: 0.9938
# Epoch 33/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0175 - accuracy: 0.9938
# Epoch 34/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0102 - accuracy: 0.9969
# Epoch 35/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0061 - accuracy: 1.0000
# Epoch 36/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0182 - accuracy: 0.9969
# Epoch 37/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0229 - accuracy: 0.9969
# Epoch 38/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0253 - accuracy: 0.9938
# Epoch 39/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0485 - accuracy: 0.9861
# Epoch 40/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0240 - accuracy: 0.9923
# Epoch 41/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0483 - accuracy: 0.9861
# Epoch 42/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0203 - accuracy: 0.9954
# Epoch 43/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0083 - accuracy: 1.0000
# Epoch 44/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0177 - accuracy: 0.9954
# Epoch 45/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0173 - accuracy: 0.9938
# Epoch 46/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0230 - accuracy: 0.9985
# Epoch 47/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0255 - accuracy: 0.9923
# Epoch 48/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0168 - accuracy: 0.9969
# Epoch 49/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0564 - accuracy: 0.9938
# Epoch 50/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0087 - accuracy: 0.9969
# Epoch 51/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0177 - accuracy: 0.9938
# Epoch 52/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0114 - accuracy: 0.9985
# Epoch 53/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0118 - accuracy: 0.9985
# Epoch 54/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0122 - accuracy: 0.9954
# Epoch 55/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0090 - accuracy: 0.9969
# Epoch 56/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0274 - accuracy: 0.9923
# Epoch 57/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0051 - accuracy: 0.9985
# Epoch 58/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0080 - accuracy: 1.0000
# Epoch 59/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0109 - accuracy: 0.9985
# Epoch 60/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0078 - accuracy: 0.9985
# Epoch 61/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0278 - accuracy: 0.9954
# Epoch 62/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0077 - accuracy: 0.9985
# Epoch 63/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0064 - accuracy: 0.9985
# Epoch 64/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0084 - accuracy: 0.9985
# Epoch 65/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0073 - accuracy: 1.0000
# Epoch 66/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0088 - accuracy: 0.9985
# Epoch 67/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0060 - accuracy: 1.0000
# Epoch 68/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0046 - accuracy: 1.0000
# Epoch 69/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0079 - accuracy: 0.9969
# Epoch 70/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0146 - accuracy: 0.9969
# Epoch 71/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0093 - accuracy: 0.9985
# Epoch 72/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0265 - accuracy: 0.9954
# Epoch 73/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0103 - accuracy: 0.9969
# Epoch 74/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0222 - accuracy: 0.9907
# Epoch 75/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0080 - accuracy: 0.9985
# Epoch 76/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0180 - accuracy: 0.9938
# Epoch 77/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0105 - accuracy: 0.9954
# Epoch 78/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0091 - accuracy: 0.9969
# Epoch 79/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0053 - accuracy: 0.9985
# Epoch 80/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0094 - accuracy: 0.9985
# Epoch 81/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0194 - accuracy: 0.9969
# Epoch 82/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0124 - accuracy: 0.9985
# Epoch 83/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0088 - accuracy: 0.9969
# Epoch 84/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0070 - accuracy: 0.9985
# Epoch 85/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0125 - accuracy: 0.9969
# Epoch 86/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0072 - accuracy: 0.9969
# Epoch 87/1500
#  9/11 [=======================>......] - ETA: 0s - loss: 0.0029 - accuracy: 1.0000Restoring model weights from the end of the best epoch: 57.
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0080 - accuracy: 0.9969
# Epoch 87: early stopping
# 5/5 [==============================] - 0s 2ms/step - loss: 1.0909 - accuracy: 0.8151
# 5/5 [==============================] - 0s 2ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.80 (16/20)
# Before appending - Cat IDs: 0, Predictions: 0, Actuals: 0, Gender: 0
# After appending - Cat IDs: 146, Predictions: 146, Actuals: 146, Gender: 146
# Final Test Results - Loss: 1.0909357070922852, Accuracy: 0.8150684833526611, Precision: 0.5068426197458455, Recall: 0.47360263489295745, F1 Score: 0.4837147062759268
# Confusion Matrix:
#  [[104   0   7]
#  [  4   0   0]
#  [ 16   0  15]]
# outer_fold 2
# Train Set Group Distribution:
# 046A    45
# 000A    39
# 103A    33
# 020A    20
# 000B    19
# 019A    17
# 057A    17
# 097A    15
# 097B    14
# 002A    13
# 106A    13
# 051A    12
# 055A    12
# 101A    12
# 116A    12
# 067A    11
# 063A    11
# 028A    11
# 042A    11
# 014B    10
# 059A    10
# 040A    10
# 022A     9
# 071A     9
# 005A     9
# 072A     9
# 065A     9
# 051B     9
# 033A     9
# 016A     9
# 068A     8
# 013B     8
# 031A     7
# 117A     7
# 036A     7
# 027A     7
# 015A     7
# 039A     6
# 099A     6
# 007A     6
# 023A     6
# 050A     5
# 075A     5
# 021A     5
# 044A     5
# 070A     5
# 109A     5
# 094A     5
# 009A     4
# 003A     4
# 045A     4
# 104A     4
# 012A     3
# 056A     3
# 058A     3
# 053A     3
# 060A     3
# 006A     3
# 034A     3
# 113A     3
# 014A     3
# 062A     3
# 052A     2
# 102A     2
# 011A     2
# 037A     2
# 093A     2
# 025B     2
# 061A     2
# 038A     2
# 069A     2
# 054A     2
# 019B     1
# 110A     1
# 100A     1
# 115A     1
# 090A     1
# 096A     1
# 066A     1
# 088A     1
# 004A     1
# 048A     1
# 076A     1
# 026C     1
# 041A     1
# 049A     1
# 043A     1
# 024A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 002B    30
# 047A    22
# 074A    16
# 029A    15
# 111A    12
# 025A    10
# 001A     9
# 095A     7
# 108A     5
# 008A     5
# 023B     4
# 026A     4
# 025C     4
# 105A     3
# 010A     3
# 018A     2
# 032A     2
# 087A     2
# 035A     2
# 073A     1
# 064A     1
# 092A     1
# 091A     1
# 026B     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    236
# F    212
# M    183
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# M    103
# X     40
# F     19
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [006A, 000A, 033A, 015A, 103A, 071A, 097B, 028...
# kitten    [044A, 014B, 040A, 046A, 042A, 109A, 050A, 043...
# senior    [093A, 097A, 057A, 106A, 104A, 055A, 059A, 113...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [001A, 074A, 002B, 029A, 095A, 091A, 025A, 087...
# kitten                                         [111A, 047A]
# senior                                               [108A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 53, 'kitten': 14, 'senior': 21}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 21, 'kitten': 2, 'senior': 1}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '002A' '003A' '004A' '005A' '006A' '007A' '009A' '011A'
#  '012A' '013B' '014A' '014B' '015A' '016A' '019A' '019B' '020A' '021A'
#  '022A' '023A' '024A' '025B' '026C' '027A' '028A' '031A' '033A' '034A'
#  '036A' '037A' '038A' '039A' '040A' '041A' '042A' '043A' '044A' '045A'
#  '046A' '048A' '049A' '050A' '051A' '051B' '052A' '053A' '054A' '055A'
#  '056A' '057A' '058A' '059A' '060A' '061A' '062A' '063A' '065A' '066A'
#  '067A' '068A' '069A' '070A' '071A' '072A' '075A' '076A' '088A' '090A'
#  '093A' '094A' '096A' '097A' '097B' '099A' '100A' '101A' '102A' '103A'
#  '104A' '106A' '109A' '110A' '113A' '115A' '116A' '117A']
# Unique Test Group IDs:
# ['001A' '002B' '008A' '010A' '018A' '023B' '025A' '025C' '026A' '026B'
#  '029A' '032A' '035A' '047A' '064A' '073A' '074A' '087A' '091A' '092A'
#  '095A' '105A' '108A' '111A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# /Users/astrid/miniforge3/envs/april2-env/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '002A' '003A' '004A' '005A' '006A' '007A' '009A' '011A'
#  '012A' '013B' '014A' '014B' '015A' '016A' '019A' '019B' '020A' '021A'
#  '022A' '023A' '024A' '025B' '026C' '027A' '028A' '031A' '033A' '034A'
#  '036A' '037A' '038A' '039A' '040A' '041A' '042A' '043A' '044A' '045A'
#  '046A' '048A' '049A' '050A' '051A' '051B' '052A' '053A' '054A' '055A'
#  '056A' '057A' '058A' '059A' '060A' '061A' '062A' '063A' '065A' '066A'
#  '067A' '068A' '069A' '070A' '071A' '072A' '075A' '076A' '088A' '090A'
#  '093A' '094A' '096A' '097A' '097B' '099A' '100A' '101A' '102A' '103A'
#  '104A' '106A' '109A' '110A' '113A' '115A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['001A' '002B' '008A' '010A' '018A' '023B' '025A' '025C' '026A' '026B'
#  '029A' '032A' '035A' '047A' '064A' '073A' '074A' '087A' '091A' '092A'
#  '095A' '105A' '108A' '111A']
# Length of X_train_val:
# 631
# Length of y_train_val:
# 631
# Length of groups_train_val:
# 631
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     386
# senior    144
# kitten    101
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     123
# kitten     34
# senior      5
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     386
# senior    144
# kitten    101
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     123
# kitten     34
# senior      5
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 386, 2: 144, 1: 101})
# Epoch 1/1500
# 10/10 [==============================] - 1s 5ms/step - loss: 0.9448 - accuracy: 0.6799
# Epoch 2/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3134 - accuracy: 0.9017
# Epoch 3/1500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1147 - accuracy: 0.9635
# Epoch 4/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0869 - accuracy: 0.9667
# Epoch 5/1500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0323 - accuracy: 0.9905
# Epoch 6/1500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0306 - accuracy: 0.9952
# Epoch 7/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0161 - accuracy: 0.9984
# Epoch 8/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0159 - accuracy: 0.9984
# Epoch 9/1500
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0115 - accuracy: 0.9984
# Epoch 10/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0164 - accuracy: 0.9952
# Epoch 11/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0117 - accuracy: 0.9952
# Epoch 12/1500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0060 - accuracy: 0.9984
# Epoch 13/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0087 - accuracy: 0.9984
# Epoch 14/1500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 15/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0075 - accuracy: 0.9984
# Epoch 16/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0053 - accuracy: 1.0000
# Epoch 17/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0074 - accuracy: 0.9984
# Epoch 18/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0042 - accuracy: 1.0000
# Epoch 19/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 20/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 21/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0044 - accuracy: 1.0000
# Epoch 22/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0053 - accuracy: 1.0000
# Epoch 23/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 24/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 25/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 26/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 27/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0112 - accuracy: 0.9952
# Epoch 28/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 29/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0073 - accuracy: 0.9968
# Epoch 30/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0116 - accuracy: 0.9984
# Epoch 31/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 32/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 33/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 34/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0046 - accuracy: 0.9984
# Epoch 35/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 36/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 37/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0035 - accuracy: 0.9984
# Epoch 38/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 39/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 40/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0033 - accuracy: 0.9984
# Epoch 41/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 8.2296e-04 - accuracy: 1.0000
# Epoch 42/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 43/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 9.4906e-04 - accuracy: 1.0000
# Epoch 44/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 7.0702e-04 - accuracy: 1.0000
# Epoch 45/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 9.1172e-04 - accuracy: 1.0000
# Epoch 46/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 47/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 6.0893e-04 - accuracy: 1.0000
# Epoch 48/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 49/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0065 - accuracy: 0.9984
# Epoch 50/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 9.1522e-04 - accuracy: 1.0000
# Epoch 51/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 52/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 8.0574e-04 - accuracy: 1.0000
# Epoch 53/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0041 - accuracy: 0.9984
# Epoch 54/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 55/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 56/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 57/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0027 - accuracy: 0.9984
# Epoch 58/1500
# 10/10 [==============================] - ETA: 0s - loss: 0.0020 - accuracy: 1.0000    Restoring model weights from the end of the best epoch: 28.
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 58: early stopping
# 6/6 [==============================] - 0s 2ms/step - loss: 1.2205 - accuracy: 0.7099
# 6/6 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.79 (19/24)
# Before appending - Cat IDs: 146, Predictions: 146, Actuals: 146, Gender: 146
# After appending - Cat IDs: 308, Predictions: 308, Actuals: 308, Gender: 308
# Final Test Results - Loss: 1.2204805612564087, Accuracy: 0.709876537322998, Precision: 0.6262527233115468, Recall: 0.6951697752271642, F1 Score: 0.558996558996559
# Confusion Matrix:
#  [[93  2 28]
#  [14 18  2]
#  [ 1  0  4]]
# outer_fold 3
# Train Set Group Distribution:
# 046A    45
# 000A    39
# 103A    33
# 002B    30
# 047A    22
# 020A    20
# 000B    19
# 057A    17
# 019A    17
# 074A    16
# 029A    15
# 097A    15
# 097B    14
# 106A    13
# 002A    13
# 111A    12
# 051A    12
# 116A    12
# 042A    11
# 028A    11
# 059A    10
# 025A    10
# 014B    10
# 022A     9
# 071A     9
# 065A     9
# 033A     9
# 001A     9
# 068A     8
# 031A     7
# 117A     7
# 036A     7
# 095A     7
# 015A     7
# 023A     6
# 039A     6
# 007A     6
# 075A     5
# 044A     5
# 070A     5
# 021A     5
# 108A     5
# 008A     5
# 026A     4
# 025C     4
# 023B     4
# 045A     4
# 104A     4
# 009A     4
# 012A     3
# 010A     3
# 056A     3
# 060A     3
# 053A     3
# 006A     3
# 034A     3
# 062A     3
# 105A     3
# 087A     2
# 025B     2
# 037A     2
# 102A     2
# 061A     2
# 011A     2
# 035A     2
# 038A     2
# 052A     2
# 018A     2
# 069A     2
# 032A     2
# 054A     2
# 041A     1
# 064A     1
# 090A     1
# 096A     1
# 110A     1
# 076A     1
# 115A     1
# 073A     1
# 088A     1
# 019B     1
# 026C     1
# 004A     1
# 048A     1
# 066A     1
# 049A     1
# 091A     1
# 092A     1
# 026B     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 101A    12
# 055A    12
# 063A    11
# 067A    11
# 040A    10
# 005A     9
# 072A     9
# 016A     9
# 051B     9
# 013B     8
# 027A     7
# 099A     6
# 094A     5
# 109A     5
# 050A     5
# 003A     4
# 014A     3
# 113A     3
# 058A     3
# 093A     2
# 043A     1
# 100A     1
# 024A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    230
# X    230
# F    187
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# M    56
# X    46
# F    44
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [006A, 000A, 033A, 015A, 001A, 103A, 071A, 097...
# kitten    [044A, 014B, 111A, 046A, 047A, 042A, 049A, 041...
# senior    [097A, 057A, 106A, 104A, 059A, 116A, 054A, 117...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [067A, 101A, 005A, 072A, 063A, 027A, 013B, 099...
# kitten                             [040A, 109A, 050A, 043A]
# senior     [093A, 055A, 113A, 051B, 058A, 016A, 094A, 024A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 63, 'kitten': 12, 'senior': 14}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 11, 'kitten': 4, 'senior': 8}
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '004A' '006A' '007A' '008A' '009A'
#  '010A' '011A' '012A' '014B' '015A' '018A' '019A' '019B' '020A' '021A'
#  '022A' '023A' '023B' '025A' '025B' '025C' '026A' '026B' '026C' '028A'
#  '029A' '031A' '032A' '033A' '034A' '035A' '036A' '037A' '038A' '039A'
#  '041A' '042A' '044A' '045A' '046A' '047A' '048A' '049A' '051A' '052A'
#  '053A' '054A' '056A' '057A' '059A' '060A' '061A' '062A' '064A' '065A'
#  '066A' '068A' '069A' '070A' '071A' '073A' '074A' '075A' '076A' '087A'
#  '088A' '090A' '091A' '092A' '095A' '096A' '097A' '097B' '102A' '103A'
#  '104A' '105A' '106A' '108A' '110A' '111A' '115A' '116A' '117A']
# Unique Test Group IDs:
# ['003A' '005A' '013B' '014A' '016A' '024A' '027A' '040A' '043A' '050A'
#  '051B' '055A' '058A' '063A' '067A' '072A' '093A' '094A' '099A' '100A'
#  '101A' '109A' '113A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '004A' '006A' '007A' '008A' '009A'
#  '010A' '011A' '012A' '014B' '015A' '018A' '019A' '019B' '020A' '021A'
#  '022A' '023A' '023B' '025A' '025B' '025C' '026A' '026B' '026C' '028A'
#  '029A' '031A' '032A' '033A' '034A' '035A' '036A' '037A' '038A' '039A'
#  '041A' '042A' '044A' '045A' '046A' '047A' '048A' '049A' '051A' '052A'
#  '053A' '054A' '056A' '057A' '059A' '060A' '061A' '062A' '064A' '065A'
#  '066A' '068A' '069A' '070A' '071A' '073A' '074A' '075A' '076A' '087A'
#  '088A' '090A' '091A' '092A' '095A' '096A' '097A' '097B' '102A' '103A'
#  '104A' '105A' '106A' '108A' '110A' '111A' '115A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['003A' '005A' '013B' '014A' '016A' '024A' '027A' '040A' '043A' '050A'
#  '051B' '055A' '058A' '063A' '067A' '072A' '093A' '094A' '099A' '100A'
#  '101A' '109A' '113A']
# Length of X_train_val:
# 647
# Length of y_train_val:
# 647
# Length of groups_train_val:
# 647
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     428
# kitten    114
# senior    105
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     81
# senior    44
# kitten    21
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     428
# kitten    114
# senior    105
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     81
# senior    44
# kitten    21
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 428, 1: 114, 2: 105})
# Epoch 1/1500
# 11/11 [==============================] - 1s 6ms/step - loss: 1.1107 - accuracy: 0.5966
# Epoch 2/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.2864 - accuracy: 0.8841
# Epoch 3/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1816 - accuracy: 0.9382
# Epoch 4/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1094 - accuracy: 0.9706
# Epoch 5/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1096 - accuracy: 0.9753
# Epoch 6/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0814 - accuracy: 0.9706
# Epoch 7/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0595 - accuracy: 0.9830
# Epoch 8/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0544 - accuracy: 0.9876
# Epoch 9/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0391 - accuracy: 0.9907
# Epoch 10/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0307 - accuracy: 0.9876
# Epoch 11/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0359 - accuracy: 0.9923
# Epoch 12/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0286 - accuracy: 0.9954
# Epoch 13/1500
# 11/11 [==============================] - 0s 28ms/step - loss: 0.0355 - accuracy: 0.9876
# Epoch 14/1500
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0260 - accuracy: 0.9907
# Epoch 15/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0265 - accuracy: 0.9938
# Epoch 16/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0212 - accuracy: 0.9969
# Epoch 17/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0387 - accuracy: 0.9954
# Epoch 18/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0227 - accuracy: 0.9938
# Epoch 19/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0159 - accuracy: 0.9969
# Epoch 20/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0231 - accuracy: 0.9954
# Epoch 21/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0160 - accuracy: 0.9985
# Epoch 22/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0124 - accuracy: 0.9985
# Epoch 23/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0097 - accuracy: 0.9985
# Epoch 24/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0107 - accuracy: 0.9985
# Epoch 25/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0092 - accuracy: 1.0000
# Epoch 26/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0098 - accuracy: 0.9969
# Epoch 27/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0099 - accuracy: 1.0000
# Epoch 28/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0191 - accuracy: 0.9938
# Epoch 29/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0154 - accuracy: 0.9954
# Epoch 30/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0073 - accuracy: 0.9985
# Epoch 31/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0107 - accuracy: 0.9969
# Epoch 32/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0135 - accuracy: 0.9954
# Epoch 33/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0059 - accuracy: 1.0000
# Epoch 34/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0057 - accuracy: 1.0000
# Epoch 35/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0086 - accuracy: 0.9969
# Epoch 36/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0076 - accuracy: 0.9969
# Epoch 37/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0075 - accuracy: 0.9969
# Epoch 38/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0159 - accuracy: 0.9985
# Epoch 39/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0075 - accuracy: 1.0000
# Epoch 40/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0216 - accuracy: 0.9969
# Epoch 41/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0057 - accuracy: 1.0000
# Epoch 42/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0095 - accuracy: 0.9969
# Epoch 43/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0051 - accuracy: 1.0000
# Epoch 44/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0074 - accuracy: 0.9969
# Epoch 45/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0080 - accuracy: 0.9985
# Epoch 46/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0317 - accuracy: 0.9938
# Epoch 47/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0110 - accuracy: 0.9985
# Epoch 48/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0171 - accuracy: 0.9938
# Epoch 49/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0170 - accuracy: 0.9969
# Epoch 50/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0106 - accuracy: 0.9985
# Epoch 51/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0138 - accuracy: 0.9969
# Epoch 52/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0186 - accuracy: 0.9954
# Epoch 53/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0114 - accuracy: 0.9954
# Epoch 54/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0075 - accuracy: 0.9985
# Epoch 55/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0104 - accuracy: 0.9954
# Epoch 56/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0182 - accuracy: 0.9938
# Epoch 57/1500
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0101 - accuracy: 0.9985
# Epoch 58/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0102 - accuracy: 0.9969
# Epoch 59/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0090 - accuracy: 0.9969
# Epoch 60/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0075 - accuracy: 0.9985
# Epoch 61/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0036 - accuracy: 0.9985
# Epoch 62/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 63/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0268 - accuracy: 0.9954
# Epoch 64/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0066 - accuracy: 0.9985
# Epoch 65/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0130 - accuracy: 0.9954
# Epoch 66/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0064 - accuracy: 1.0000
# Epoch 67/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0131 - accuracy: 0.9954
# Epoch 68/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0150 - accuracy: 0.9954
# Epoch 69/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0173 - accuracy: 0.9985
# Epoch 70/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0268 - accuracy: 0.9907
# Epoch 71/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0142 - accuracy: 0.9969
# Epoch 72/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0232 - accuracy: 0.9938
# Epoch 73/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0095 - accuracy: 0.9969
# Epoch 74/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0096 - accuracy: 0.9985
# Epoch 75/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0077 - accuracy: 0.9985
# Epoch 76/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0068 - accuracy: 0.9985
# Epoch 77/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0105 - accuracy: 0.9938
# Epoch 78/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0073 - accuracy: 0.9985
# Epoch 79/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0168 - accuracy: 0.9954
# Epoch 80/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0131 - accuracy: 0.9969
# Epoch 81/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0161 - accuracy: 0.9969
# Epoch 82/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0122 - accuracy: 0.9938
# Epoch 83/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0062 - accuracy: 0.9985
# Epoch 84/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0054 - accuracy: 1.0000
# Epoch 85/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0099 - accuracy: 0.9985
# Epoch 86/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0049 - accuracy: 1.0000
# Epoch 87/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 88/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 89/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0095 - accuracy: 0.9969
# Epoch 90/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0101 - accuracy: 0.9985
# Epoch 91/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0052 - accuracy: 0.9985
# Epoch 92/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0066 - accuracy: 0.9985
# Epoch 93/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0109 - accuracy: 0.9985
# Epoch 94/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0071 - accuracy: 0.9969
# Epoch 95/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0050 - accuracy: 0.9985
# Epoch 96/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0069 - accuracy: 0.9985
# Epoch 97/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0062 - accuracy: 0.9985
# Epoch 98/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 99/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 100/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 101/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0057 - accuracy: 0.9985
# Epoch 102/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0143 - accuracy: 0.9954
# Epoch 103/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0036 - accuracy: 0.9985
# Epoch 104/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 105/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0047 - accuracy: 0.9985
# Epoch 106/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 107/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0028 - accuracy: 0.9985
# Epoch 108/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 109/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0062 - accuracy: 0.9985
# Epoch 110/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0036 - accuracy: 0.9985
# Epoch 111/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0088 - accuracy: 0.9985
# Epoch 112/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 113/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0041 - accuracy: 1.0000
# Epoch 114/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0169 - accuracy: 0.9923
# Epoch 115/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 116/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 117/1500
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0039 - accuracy: 0.9984Restoring model weights from the end of the best epoch: 87.
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0040 - accuracy: 0.9985
# Epoch 117: early stopping
# 5/5 [==============================] - 0s 2ms/step - loss: 1.6747 - accuracy: 0.7329
# 5/5 [==============================] - 0s 3ms/step
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Majority Vote Accuracy for cat_id for this fold: 0.74 (17/23)
# Before appending - Cat IDs: 308, Predictions: 308, Actuals: 308, Gender: 308
# After appending - Cat IDs: 454, Predictions: 454, Actuals: 454, Gender: 454
# Final Test Results - Loss: 1.6747262477874756, Accuracy: 0.732876718044281, Precision: 0.7985125084516566, Recall: 0.6859066859066859, F1 Score: 0.722721261571475
# Confusion Matrix:
#  [[72  0  9]
#  [ 6 15  0]
#  [24  0 20]]
# outer_fold 4
# Train Set Group Distribution:
# 046A    45
# 000A    39
# 002B    30
# 047A    22
# 020A    20
# 000B    19
# 057A    17
# 074A    16
# 097A    15
# 029A    15
# 097B    14
# 002A    13
# 111A    12
# 116A    12
# 051A    12
# 101A    12
# 055A    12
# 063A    11
# 067A    11
# 025A    10
# 014B    10
# 040A    10
# 016A     9
# 005A     9
# 072A     9
# 071A     9
# 065A     9
# 051B     9
# 001A     9
# 068A     8
# 013B     8
# 027A     7
# 031A     7
# 036A     7
# 015A     7
# 095A     7
# 099A     6
# 007A     6
# 039A     6
# 023A     6
# 021A     5
# 094A     5
# 070A     5
# 008A     5
# 108A     5
# 044A     5
# 109A     5
# 050A     5
# 045A     4
# 026A     4
# 025C     4
# 104A     4
# 023B     4
# 003A     4
# 009A     4
# 053A     3
# 058A     3
# 012A     3
# 060A     3
# 105A     3
# 113A     3
# 014A     3
# 062A     3
# 010A     3
# 035A     2
# 102A     2
# 052A     2
# 025B     2
# 037A     2
# 032A     2
# 038A     2
# 093A     2
# 018A     2
# 069A     2
# 087A     2
# 092A     1
# 024A     1
# 100A     1
# 110A     1
# 091A     1
# 115A     1
# 019B     1
# 041A     1
# 004A     1
# 043A     1
# 073A     1
# 064A     1
# 049A     1
# 026B     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 103A    33
# 019A    17
# 106A    13
# 028A    11
# 042A    11
# 059A    10
# 033A     9
# 022A     9
# 117A     7
# 075A     5
# 056A     3
# 006A     3
# 034A     3
# 061A     2
# 054A     2
# 011A     2
# 048A     1
# 088A     1
# 076A     1
# 066A     1
# 026C     1
# 096A     1
# 090A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    238
# M    208
# F    200
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# M    78
# X    38
# F    31
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [000A, 015A, 001A, 071A, 097B, 074A, 067A, 020...
# kitten    [044A, 014B, 111A, 040A, 046A, 047A, 109A, 050...
# senior    [093A, 097A, 057A, 104A, 055A, 113A, 116A, 051...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [006A, 033A, 103A, 028A, 019A, 022A, 034A, 076...
# kitten                                         [042A, 048A]
# senior     [106A, 059A, 054A, 117A, 056A, 011A, 061A, 090A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 61, 'kitten': 14, 'senior': 14}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 13, 'kitten': 2, 'senior': 8}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '004A' '005A' '007A' '008A'
#  '009A' '010A' '012A' '013B' '014A' '014B' '015A' '016A' '018A' '019B'
#  '020A' '021A' '023A' '023B' '024A' '025A' '025B' '025C' '026A' '026B'
#  '027A' '029A' '031A' '032A' '035A' '036A' '037A' '038A' '039A' '040A'
#  '041A' '043A' '044A' '045A' '046A' '047A' '049A' '050A' '051A' '051B'
#  '052A' '053A' '055A' '057A' '058A' '060A' '062A' '063A' '064A' '065A'
#  '067A' '068A' '069A' '070A' '071A' '072A' '073A' '074A' '087A' '091A'
#  '092A' '093A' '094A' '095A' '097A' '097B' '099A' '100A' '101A' '102A'
#  '104A' '105A' '108A' '109A' '110A' '111A' '113A' '115A' '116A']
# Unique Test Group IDs:
# ['006A' '011A' '019A' '022A' '026C' '028A' '033A' '034A' '042A' '048A'
#  '054A' '056A' '059A' '061A' '066A' '075A' '076A' '088A' '090A' '096A'
#  '103A' '106A' '117A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# ...
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0366 - accuracy: 0.9923
# Epoch 115/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 116/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 117/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 118/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 119/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0289 - accuracy: 0.9985
# Epoch 120/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0093 - accuracy: 0.9969
# Epoch 121/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0046 - accuracy: 0.9985
# Epoch 122/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 123/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0058 - accuracy: 0.9985
# Epoch 124/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0047 - accuracy: 1.0000
# Epoch 125/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 126/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 127/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 128/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0057 - accuracy: 0.9985
# Epoch 129/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 130/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 131/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 132/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 133/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 134/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 135/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0122 - accuracy: 0.9969
# Epoch 136/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0035 - accuracy: 0.9985
# Epoch 137/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0076 - accuracy: 0.9969
# Epoch 138/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 139/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0079 - accuracy: 0.9985
# Epoch 140/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0119 - accuracy: 0.9954
# Epoch 141/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 142/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 143/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0077 - accuracy: 0.9985
# Epoch 144/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0087 - accuracy: 0.9969
# Epoch 145/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0073 - accuracy: 0.9985
# Epoch 146/1500
# 11/11 [==============================] - ETA: 0s - loss: 0.0028 - accuracy: 1.0000Restoring model weights from the end of the best epoch: 116.
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 146: early stopping
# 5/5 [==============================] - 0s 1ms/step - loss: 1.8314 - accuracy: 0.6939
# 5/5 [==============================] - 0s 2ms/step
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Majority Vote Accuracy for cat_id for this fold: 0.61 (14/23)
# Before appending - Cat IDs: 454, Predictions: 454, Actuals: 454, Gender: 454
# After appending - Cat IDs: 601, Predictions: 601, Actuals: 601, Gender: 601
# Final Test Results - Loss: 1.831409215927124, Accuracy: 0.6938775777816772, Precision: 0.6383577052868392, Recall: 0.4789473684210526, F1 Score: 0.5018351685018351
# Confusion Matrix:
#  [[89  3  3]
#  [ 8  3  1]
#  [30  0 10]]
# outer_fold 5
# Train Set Group Distribution:
# 103A    33
# 002B    30
# 047A    22
# 000B    19
# 019A    17
# 074A    16
# 029A    15
# 097A    15
# 097B    14
# 002A    13
# 106A    13
# 101A    12
# 111A    12
# 055A    12
# 051A    12
# 042A    11
# 063A    11
# 067A    11
# 028A    11
# 059A    10
# 040A    10
# 025A    10
# 022A     9
# 005A     9
# 072A     9
# 065A     9
# 001A     9
# 051B     9
# 033A     9
# 016A     9
# 013B     8
# 027A     7
# 036A     7
# 117A     7
# 015A     7
# 031A     7
# 095A     7
# 007A     6
# 023A     6
# 099A     6
# 109A     5
# 021A     5
# 094A     5
# 075A     5
# 050A     5
# 108A     5
# 008A     5
# 070A     5
# 026A     4
# 104A     4
# 045A     4
# 009A     4
# 003A     4
# 025C     4
# 023B     4
# 053A     3
# 010A     3
# 056A     3
# 058A     3
# 006A     3
# 113A     3
# 034A     3
# 105A     3
# 014A     3
# 087A     2
# 035A     2
# 061A     2
# 052A     2
# 102A     2
# 018A     2
# 011A     2
# 032A     2
# 025B     2
# 054A     2
# 093A     2
# 100A     1
# 090A     1
# 024A     1
# 088A     1
# 091A     1
# 048A     1
# 066A     1
# 026C     1
# 092A     1
# 064A     1
# 073A     1
# 076A     1
# 043A     1
# 096A     1
# 026B     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 046A    45
# 000A    39
# 020A    20
# 057A    17
# 116A    12
# 014B    10
# 071A     9
# 068A     8
# 039A     6
# 044A     5
# 012A     3
# 062A     3
# 060A     3
# 069A     2
# 038A     2
# 037A     2
# 049A     1
# 041A     1
# 004A     1
# 019B     1
# 115A     1
# 110A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    263
# F    174
# X    164
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    112
# F     57
# M     23
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [006A, 033A, 015A, 001A, 103A, 097B, 028A, 019...
# kitten    [111A, 040A, 047A, 042A, 109A, 050A, 043A, 045...
# senior    [093A, 097A, 106A, 104A, 055A, 059A, 113A, 051...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [000A, 071A, 020A, 062A, 039A, 038A, 069A, 068...
# kitten           [044A, 014B, 046A, 049A, 041A, 115A, 110A]
# senior                                         [057A, 116A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 61, 'kitten': 9, 'senior': 20}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 13, 'kitten': 7, 'senior': 2}
# Unique Training/Validation Group IDs:
# ['000B' '001A' '002A' '002B' '003A' '005A' '006A' '007A' '008A' '009A'
#  '010A' '011A' '013B' '014A' '015A' '016A' '018A' '019A' '021A' '022A'
#  '023A' '023B' '024A' '025A' '025B' '025C' '026A' '026B' '026C' '027A'
#  '028A' '029A' '031A' '032A' '033A' '034A' '035A' '036A' '040A' '042A'
#  '043A' '045A' '047A' '048A' '050A' '051A' '051B' '052A' '053A' '054A'
#  '055A' '056A' '058A' '059A' '061A' '063A' '064A' '065A' '066A' '067A'
#  '070A' '072A' '073A' '074A' '075A' '076A' '087A' '088A' '090A' '091A'
#  '092A' '093A' '094A' '095A' '096A' '097A' '097B' '099A' '100A' '101A'
#  '102A' '103A' '104A' '105A' '106A' '108A' '109A' '111A' '113A' '117A']
# Unique Test Group IDs:
# ['000A' '004A' '012A' '014B' '019B' '020A' '037A' '038A' '039A' '041A'
#  '044A' '046A' '049A' '057A' '060A' '062A' '068A' '069A' '071A' '110A'
#  '115A' '116A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'000A', '046A'}
# Removed from Training/Validation Set:
# {'047A', '000B'}
# Moved to Test Set:
# {'047A', '000B'}
# Removed from Test Set
# {'000A', '046A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '001A' '002A' '002B' '003A' '005A' '006A' '007A' '008A' '009A'
#  '010A' '011A' '013B' '014A' '015A' '016A' '018A' '019A' '021A' '022A'
#  '023A' '023B' '024A' '025A' '025B' '025C' '026A' '026B' '026C' '027A'
#  '028A' '029A' '031A' '032A' '033A' '034A' '035A' '036A' '040A' '042A'
#  '043A' '045A' '046A' '048A' '050A' '051A' '051B' '052A' '053A' '054A'
#  '055A' '056A' '058A' '059A' '061A' '063A' '064A' '065A' '066A' '067A'
#  '070A' '072A' '073A' '074A' '075A' '076A' '087A' '088A' '090A' '091A'
#  '092A' '093A' '094A' '095A' '096A' '097A' '097B' '099A' '100A' '101A'
#  '102A' '103A' '104A' '105A' '106A' '108A' '109A' '111A' '113A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['000B' '004A' '012A' '014B' '019B' '020A' '037A' '038A' '039A' '041A'
#  '044A' '047A' '049A' '057A' '060A' '062A' '068A' '069A' '071A' '110A'
#  '115A' '116A']
# Length of X_train_val:
# 644
# Length of y_train_val:
# 644
# Length of groups_train_val:
# 644
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     410
# senior    120
# kitten     71
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     99
# kitten    64
# senior    29
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     430
# senior    120
# kitten     94
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     79
# kitten    41
# senior    29
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 430, 2: 120, 1: 94})
# Epoch 1/1500
# 11/11 [==============================] - 1s 5ms/step - loss: 1.1696 - accuracy: 0.6304
# Epoch 2/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.3123 - accuracy: 0.8898
# Epoch 3/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.1557 - accuracy: 0.9348
# Epoch 4/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1238 - accuracy: 0.9550
# Epoch 5/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0983 - accuracy: 0.9720
# Epoch 6/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0527 - accuracy: 0.9860
# Epoch 7/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0477 - accuracy: 0.9876
# Epoch 8/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0570 - accuracy: 0.9860
# Epoch 9/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0467 - accuracy: 0.9876
# Epoch 10/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0344 - accuracy: 0.9891
# Epoch 11/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0277 - accuracy: 0.9938
# Epoch 12/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0317 - accuracy: 0.9938
# Epoch 13/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0340 - accuracy: 0.9891
# Epoch 14/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0362 - accuracy: 0.9845
# Epoch 15/1500
# 11/11 [==============================] - 0s 27ms/step - loss: 0.0202 - accuracy: 0.9953
# Epoch 16/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0429 - accuracy: 0.9938
# Epoch 17/1500
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0228 - accuracy: 0.9969
# Epoch 18/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0343 - accuracy: 0.9891
# Epoch 19/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0230 - accuracy: 0.9938
# Epoch 20/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0252 - accuracy: 0.9953
# Epoch 21/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0237 - accuracy: 0.9969
# Epoch 22/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0282 - accuracy: 0.9938
# Epoch 23/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0228 - accuracy: 0.9938
# Epoch 24/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0162 - accuracy: 0.9984
# Epoch 25/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0170 - accuracy: 0.9969
# Epoch 26/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0118 - accuracy: 0.9984
# Epoch 27/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0289 - accuracy: 0.9953
# Epoch 28/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0318 - accuracy: 0.9922
# Epoch 29/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0312 - accuracy: 0.9907
# Epoch 30/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0209 - accuracy: 0.9938
# Epoch 31/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0217 - accuracy: 0.9938
# Epoch 32/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0204 - accuracy: 0.9922
# Epoch 33/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0134 - accuracy: 0.9984
# Epoch 34/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0199 - accuracy: 0.9938
# Epoch 35/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0223 - accuracy: 0.9938
# Epoch 36/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0234 - accuracy: 0.9938
# Epoch 37/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0209 - accuracy: 0.9984
# Epoch 38/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0252 - accuracy: 0.9938
# Epoch 39/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0298 - accuracy: 0.9938
# Epoch 40/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0322 - accuracy: 0.9938
# Epoch 41/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0217 - accuracy: 0.9922
# Epoch 42/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0229 - accuracy: 0.9922
# Epoch 43/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0163 - accuracy: 0.9938
# Epoch 44/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0268 - accuracy: 0.9969
# Epoch 45/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0216 - accuracy: 0.9922
# Epoch 46/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0240 - accuracy: 0.9922
# Epoch 47/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0199 - accuracy: 0.9938
# Epoch 48/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0298 - accuracy: 0.9922
# Epoch 49/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0389 - accuracy: 0.9891
# Epoch 50/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0416 - accuracy: 0.9922
# Epoch 51/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0375 - accuracy: 0.9891
# Epoch 52/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0144 - accuracy: 0.9984
# Epoch 53/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0267 - accuracy: 0.9922
# Epoch 54/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0136 - accuracy: 0.9984
# Epoch 55/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0180 - accuracy: 0.9984
# Epoch 56/1500
# 11/11 [==============================] - ETA: 0s - loss: 0.0183 - accuracy: 0.9953Restoring model weights from the end of the best epoch: 26.
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0183 - accuracy: 0.9953
# Epoch 56: early stopping
# 5/5 [==============================] - 0s 1ms/step - loss: 1.6442 - accuracy: 0.6174
# 5/5 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.73 (16/22)
# Before appending - Cat IDs: 601, Predictions: 601, Actuals: 601, Gender: 601
# After appending - Cat IDs: 750, Predictions: 750, Actuals: 750, Gender: 750
# Final Test Results - Loss: 1.6441632509231567, Accuracy: 0.6174496412277222, Precision: 0.646125116713352, Recall: 0.48994829537994206, F1 Score: 0.5032467532467532
# Confusion Matrix:
#  [[72  2  5]
#  [25 13  3]
#  [22  0  7]]
#
# Final Average F1-Score across all UNSEEN TEST sets: 0.5541028897185097
#
# Final Average Loss across all UNSEEN TEST sets: 1.49234299659729
#
# Final Average Accuracy across all UNSEEN TEST sets: 0.7138297915458679
#
# Final Average Precision across all UNSEEN TEST sets: 0.643218134701848
#
# Final Average Recall across all UNSEEN TEST sets: 0.5647149519655603

# %%
seed_3_folds_values = (unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1)

# Plotting all fold metrics
seed_3_folds_plot = plot_all_metrics(unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1, "Folds", "Fold Number")

# %% [markdown]
# ## Majority Voting on Total Entries per cat_id

# %%
# Debugging print statements
print(f'Checking - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
# Out:
# Checking - Cat IDs: 750, Predictions: 750, Actuals: 750, Gender: 750

# %%
# Create results df
full_results = pd.DataFrame({
    'cat_id': all_cat_ids,
    'predicted_age_group': all_predicted_age_groups,
    'actual_age_group': all_actual_age_groups,
    'all_gender': all_gender
})

# create a correct majority prediction column
full_results['correct'] = full_results['predicted_age_group'] == full_results['actual_age_group']

# %%
# Group by cat_id and aggregate predicted age groups
majority_votes = full_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first()

# Calculate the accuracy of majority voting
correct_predictions = (majority_votes == actual_groups).sum()
total_cats = len(actual_groups)
majority_vote_accuracy = correct_predictions / total_cats

logger(f"Overall Majority Vote Accuracy for cat_id: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

# store for final evaluation 
all_majority_vote_accuracies.append(majority_vote_accuracy)
# Out:
# Overall Majority Vote Accuracy for cat_id: 0.74 (81/110)

# %%
# Detailed df with predictions, actual labels, and comparison including majority vote
detailed_results = full_results.groupby('cat_id').apply(
    lambda x: pd.Series({
        'Predictions': list(x['predicted_age_group']),
        'Majority Vote': x['predicted_age_group'].mode()[0],
        'Actual Age Group': x['actual_age_group'].iloc[0],
        'Correct Majority Vote': x['predicted_age_group'].mode()[0] == x['actual_age_group'].iloc[0]
    })
).reset_index()

# Convert to DataFrame for better formatting and display
detailed_results = pd.DataFrame(detailed_results)

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 10)
pd.set_option('display.width', 1000)

sorted_detailed_results = detailed_results.sort_values(by='Correct Majority Vote', ascending=False)

# Display the sorted DataFrame
sorted_detailed_results
# Out:
#     cat_id                                        Predictions Majority Vote Actual Age Group  Correct Majority Vote
# 0     000B  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 45    039A         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 79    073A                                            [adult]         adult            adult                   True
# 78    072A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 77    071A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 76    070A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 75    069A                                    [adult, senior]         adult            adult                   True
# 74    068A  [adult, adult, adult, adult, senior, adult, ad...         adult            adult                   True
# 73    067A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 72    066A                                            [adult]         adult            adult                   True
# 71    065A  [senior, adult, adult, adult, adult, adult, ad...         adult            adult                   True
# 70    064A                                            [adult]         adult            adult                   True
# 69    063A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 68    062A                              [adult, adult, adult]         adult            adult                   True
# 66    060A                              [adult, adult, adult]         adult            adult                   True
# 64    058A                           [senior, senior, senior]        senior           senior                   True
# 61    055A  [adult, senior, adult, adult, senior, senior, ...        senior           senior                   True
# 58    052A                                    [adult, senior]         adult            adult                   True
# 53    048A                                           [kitten]        kitten           kitten                   True
# 50    044A           [kitten, kitten, kitten, kitten, kitten]        kitten           kitten                   True
# 49    043A                                           [kitten]        kitten           kitten                   True
# 80    074A  [adult, adult, senior, adult, adult, adult, ad...         adult            adult                   True
# 81    075A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 82    076A                                            [adult]         adult            adult                   True
# 96    101A  [adult, adult, adult, adult, senior, adult, ad...         adult            adult                   True
# 107   115A                                           [kitten]        kitten           kitten                   True
# 106   113A                           [senior, senior, senior]        senior           senior                   True
# 105   111A  [adult, kitten, kitten, kitten, kitten, kitten...        kitten           kitten                   True
# 104   110A                                           [kitten]        kitten           kitten                   True
# 102   108A            [senior, adult, senior, senior, senior]        senior           senior                   True
# 100   105A                             [adult, adult, senior]         adult            adult                   True
# 98    103A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 97    102A                                     [adult, adult]         adult            adult                   True
# 95    100A                                            [adult]         adult            adult                   True
# 83    087A                                     [adult, adult]         adult            adult                   True
# 94    099A         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 93    097B  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 92    097A  [adult, senior, adult, senior, senior, senior,...        senior           senior                   True
# 91    096A                                            [adult]         adult            adult                   True
# 89    094A           [senior, senior, senior, senior, senior]        senior           senior                   True
# 87    092A                                            [adult]         adult            adult                   True
# 85    090A                                           [senior]        senior           senior                   True
# 84    088A                                            [adult]         adult            adult                   True
# 46    040A  [kitten, kitten, kitten, kitten, adult, kitten...        kitten           kitten                   True
# 55    050A           [kitten, kitten, kitten, kitten, kitten]        kitten           kitten                   True
# 26    023B                       [adult, adult, adult, adult]         adult            adult                   True
# 16    014B  [senior, kitten, kitten, adult, kitten, kitten...        kitten           kitten                   True
# 34    027A  [adult, adult, senior, adult, adult, adult, ad...         adult            adult                   True
# 13    012A                              [adult, adult, adult]         adult            adult                   True
# 32    026B                                            [adult]         adult            adult                   True
# 31    026A                       [adult, adult, adult, adult]         adult            adult                   True
# 30    025C                      [adult, adult, senior, adult]         adult            adult                   True
# 29    025B                                     [adult, adult]         adult            adult                   True
# 28    025A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 14    013B  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 43    037A                                     [adult, adult]         adult            adult                   True
# 25    023A         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 24    022A  [adult, adult, kitten, kitten, adult, adult, a...         adult            adult                   True
# 23    021A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 22    020A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 21    019B                                            [adult]         adult            adult                   True
# 20    019A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 19    018A                                     [adult, adult]         adult            adult                   True
# 15    014A                              [adult, adult, adult]         adult            adult                   True
# 35    028A  [senior, adult, adult, senior, adult, adult, a...         adult            adult                   True
# 11    010A                             [adult, adult, senior]         adult            adult                   True
# 10    009A                       [adult, adult, adult, adult]         adult            adult                   True
# 5     004A                                            [adult]         adult            adult                   True
# 2     002A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 42    036A  [senior, adult, adult, adult, adult, adult, ad...         adult            adult                   True
# 41    035A                                     [adult, adult]         adult            adult                   True
# 3     002B  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 4     003A                       [adult, adult, adult, adult]         adult            adult                   True
# 40    034A                             [adult, adult, senior]         adult            adult                   True
# 17    015A  [adult, adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 39    033A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 7     006A                              [adult, adult, adult]         adult            adult                   True
# 38    032A                                     [adult, adult]         adult            adult                   True
# 8     007A        [adult, adult, adult, adult, senior, adult]         adult            adult                   True
# 9     008A               [adult, adult, adult, senior, adult]         adult            adult                   True
# 37    031A  [adult, adult, adult, senior, adult, adult, ad...         adult            adult                   True
# 101   106A  [adult, adult, adult, senior, adult, adult, ad...         adult           senior                  False
# 6     005A  [adult, senior, senior, senior, senior, senior...        senior            adult                  False
# 12    011A                                    [senior, adult]         adult           senior                  False
# 99    104A                       [adult, adult, adult, adult]         adult           senior                  False
# 108   116A  [senior, senior, adult, adult, adult, adult, a...         adult           senior                  False
# 90    095A  [senior, adult, senior, adult, senior, adult, ...        senior            adult                  False
# 103   109A                [adult, adult, adult, adult, adult]         adult           kitten                  False
# 44    038A                                   [kitten, kitten]        kitten            adult                  False
# 88    093A                                     [adult, adult]         adult           senior                  False
# 59    053A                            [senior, adult, senior]        senior            adult                  False
# 47    041A                                            [adult]         adult           kitten                  False
# 48    042A  [senior, adult, adult, adult, adult, kitten, a...         adult           kitten                  False
# 51    045A                       [adult, adult, adult, adult]         adult           kitten                  False
# 52    047A  [adult, adult, kitten, kitten, kitten, senior,...         adult           kitten                  False
# 54    049A                                            [adult]         adult           kitten                  False
# 1     001A  [adult, senior, adult, senior, adult, senior, ...        senior            adult                  False
# 56    051A  [adult, senior, adult, adult, adult, senior, a...         adult           senior                  False
# 57    051B  [adult, adult, adult, adult, adult, adult, adu...         adult           senior                  False
# 60    054A                                     [adult, adult]         adult           senior                  False
# 86    091A                                           [senior]        senior            adult                  False
# 62    056A                             [senior, adult, adult]         adult           senior                  False
# 63    057A  [adult, senior, adult, adult, senior, adult, a...         adult           senior                  False
# 65    059A  [adult, adult, senior, adult, adult, adult, ad...         adult           senior                  False
# 36    029A  [senior, senior, senior, adult, adult, adult, ...        senior            adult                  False
# 67    061A                                    [senior, adult]         adult           senior                  False
# 33    026C                                           [kitten]        kitten            adult                  False
# 27    024A                                            [adult]         adult           senior                  False
# 18    016A  [adult, adult, adult, adult, senior, adult, ad...         adult           senior                  False
# 109   117A  [adult, adult, adult, adult, adult, adult, adult]         adult           senior                  False

# %%
# Create df for majority votes
majority_df = majority_votes.reset_index()
majority_df.columns = ['cat_id', 'Majority_Vote']

# Get actual groups for each cat_id
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first().reset_index()

# Merge majority votes with actual groups
majority_with_actual = pd.merge(majority_df, actual_groups, on='cat_id')

# Add a column to check if the majority vote was correct
majority_with_actual['Majority_Correct'] = majority_with_actual['Majority_Vote'] == majority_with_actual['actual_age_group']

# Count correct majority votes per class
correct_majority_votes_per_class = majority_with_actual.groupby('actual_age_group')['Majority_Correct'].sum()

print("Correct Majority Votes per Class:")
print(correct_majority_votes_per_class)
# Out:
# Correct Majority Votes per Class:
# actual_age_group
# adult     65
# kitten     9
# senior     7
# Name: Majority_Correct, dtype: int64

# %%
# Calculate the total count and the number of correct predictions for each class
class_stats = majority_with_actual.groupby('actual_age_group').agg(
    total_count=('Majority_Correct', 'size'),  # Total number of cases per class
    correct_count=('Majority_Correct', 'sum')  # Sum of correct predictions per class
).reset_index()

# Calculate accuracy for each class
class_stats['accuracy'] = class_stats['correct_count'] / class_stats['total_count'] * 100

# store for final evaluation 
all_majority_vote_details.append(class_stats)

# Log detailed stats
print("Detailed Class Statistics for Majority Votes:")
print(class_stats)
# Out:
# Detailed Class Statistics for Majority Votes:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult           73             65  89.041096
# 1           kitten           15              9  60.000000
# 2           senior           22              7  31.818182

# %%
# Plot for Detailed Class Statistics for Majority Votes
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Accuracy of Majority Votes by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Detailed Class Statistics

# %%
# Calculate the total count and the number of correct predictions for each class
class_stats = full_results.groupby('actual_age_group').agg(
    total_count=('correct', 'size'),
    correct_count=('correct', 'sum')
).reset_index()

# Calculate accuracy for each class
class_stats['accuracy'] = class_stats['correct_count'] / class_stats['total_count'] * 100

# store for final evaluation 
all_class_stats.append(class_stats)

# Log the detailed stats
print("Detailed Class Statistics:")
print(class_stats)
# Out:
# Detailed Class Statistics:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult          489            430  87.934560
# 1           kitten          112             49  43.750000
# 2           senior          149             56  37.583893

# %%
# Plot for Detailed Class Statistics (Overall)
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Overall Accuracy by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Gender Exploration

# %%
# Group by gender and calculate the total count, correct predictions, and accuracy
gender_stats = full_results.groupby('all_gender').agg(
    count=('cat_id', 'size'),  # Total number of cases per gender
    correct=('correct', 'sum')  # Sum of correct predictions per gender
).reset_index()

# Calculate accuracy for each gender
gender_stats['accuracy'] = (gender_stats['correct'] / gender_stats['count'] * 100).round(2)

# Display the DataFrame
print("Accuracy by Gender:")
print(gender_stats)

# store for final evaluation 
all_gender_stats.append(gender_stats)
# Out:
# Accuracy by Gender:
#   all_gender  count  correct  accuracy
# 0          F    211      163     77.25
# 1          M    286      211     73.78
# 2          X    253      161     63.64

# %%
# Plot for Accuracy by Gender
styled_barplot(gender_stats, 'all_gender', 'accuracy', 
               'Accuracy by Gender', 
               'Gender', 'Accuracy (%)')

# %% [markdown]
# ### Log current total CV Stats

# %%
print("Total Majority Vote Accuracy so far:", all_majority_vote_accuracies)
print("Total Class Statistics so far:\n", all_class_stats)
print("Total Gender Accuracy so far:\n", all_gender_stats)
# Out:
# Total Majority Vote Accuracy so far: [0.7727272727272727, 0.7545454545454545, 0.7363636363636363]
# Total Class Statistics so far:
#  [  actual_age_group  total_count  correct_count   accuracy
# 0            adult          472            410  86.864407
# 1           kitten           95             51  53.684211
# 2           senior          149             39  26.174497,   actual_age_group  total_count  correct_count   accuracy
# 0            adult          476            398  83.613445
# 1           kitten          112             45  40.178571
# 2           senior          149             39  26.174497,   actual_age_group  total_count  correct_count   accuracy
# 0            adult          489            430  87.934560
# 1           kitten          112             49  43.750000
# 2           senior          149             56  37.583893]
# Total Gender Accuracy so far:
#  [  all_gender  count  correct  accuracy
# 0          F    194      148     76.29
# 1          M    286      206     72.03
# 2          X    236      146     61.86,   all_gender  count  correct  accuracy
# 0          F    198      132     66.67
# 1          M    286      204     71.33
# 2          X    253      146     57.71,   all_gender  count  correct  accuracy
# 0          F    211      163     77.25
# 1          M    286      211     73.78
# 2          X    253      161     63.64]

# %% [markdown]
# # RANDOM SEED 4

# %%
# Set a fixed random seed for reproducibility
random.seed(int(random_seeds[3])) 
np.random.seed(int(random_seeds[3]))
tf.random.set_seed(int(random_seeds[3]))

# Load datasets
dataframe = pd.read_csv('/Users/astrid/PycharmProjects/perch-2/scripts/perch_embeddings_april_10.csv')
dataframe.drop('mean_freq', axis=1, inplace=True)

def assign_age_group(age, age_groups):
    for group_name, age_range in age_groups.items():
        if age_range[0] <= age < age_range[1]:
            return group_name
    return 'Unknown'  # For any age that doesn't fit the defined groups

# Define age groups
age_groups = {
    'kitten': (0, 0.5),
    'adult': (0.5, 12),
    'senior': (12, 20)
}

# Create a new column for the age group
dataframe['age_group'] = dataframe['target'].apply(assign_age_group, age_groups=age_groups)

print(dataframe['age_group'].value_counts())
# Out:
# adult     509
# senior    149
# kitten    135
# Name: age_group, dtype: int64

# %%
# Separate features and labels
X = dataframe.iloc[:, :-4].values  # all columns except the last four

# Encode the 'age_group' column as integers using LabelEncoder
label_encoder = LabelEncoder()
encoded_y = label_encoder.fit_transform(dataframe['age_group'].values)

# Use the encoded labels for splitting and one-hot encoding
y = encoded_y  

# Convert 'cat_id' column to numpy array to be used as groups array for GroupKFold
groups = dataframe['cat_id'].values

# %%
tf.keras.backend.clear_session()

# %% [markdown]
# ## Run Setup

# %%
all_cat_ids = []
all_predicted_age_groups = []
all_actual_age_groups = []
all_gender = []

# Define the StratifiedGroupKFold splitter for 4 fold CV with random shuffling
outer_cv = StratifiedGroupKFold(n_splits=5, shuffle=True, random_state=int(random_seeds[3]))

# unseen test set metrics
unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1 = [], [], [], [], []

outer_fold = 0

# Use the splitter to generate indices for training and testing sets
# Note: GroupShuffleSplit.split returns indices, so we use it to index the arrays
for train_val_idx, test_idx in outer_cv.split(X, y, groups):
    outer_fold += 1
    logger(f"outer_fold {outer_fold}", file=log_file_path)

    # Convert indices back to DataFrame for easy manipulation
    df_train_val = dataframe.iloc[train_val_idx]
    df_test = dataframe.iloc[test_idx]

    ##############################
    # ASSESSING SPLITS BY CAT_ID #
    ##############################
    
    # Get the distribution of groups
    training_validation_group_distribution = df_train_val['cat_id'].value_counts()  
    testing_group_distribution = df_test['cat_id'].value_counts()  
    
    # Log or print the distribution
    logger(f"Train Set Group Distribution:\n{training_validation_group_distribution}", file=log_file_path)
    logger(f"Testing Set Group Distribution:\n{testing_group_distribution}", file=log_file_path)

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val['gender'].value_counts()
    testing_gender_distribution = df_test['gender'].value_counts()
    
    # Log the distribution
    logger(f"Training Set Gender Distribution BEFORE SWAP:\n{training_gender_distribution}", file=log_file_path)
    logger(f"Testing Set Gender Distribution BEFORE SWAP:\n{testing_gender_distribution}", file=log_file_path)

    # Group by 'age_group' and then list unique 'cat_id' within each age group
    unique_cat_ids_per_age_group_train_val = df_train_val.groupby('age_group')['cat_id'].unique()
    unique_cat_ids_per_age_group_test = df_test.groupby('age_group')['cat_id'].unique()
    
    # Log results
    logger(f"Unique Cat IDs per Age Group in Training/Validation Set:\n{unique_cat_ids_per_age_group_train_val}", file=log_file_path)
    logger(f"Unique Cat IDs per Age Group in Testing Set:\n{unique_cat_ids_per_age_group_test}", file=log_file_path)

    # Calculate the count of unique identifiers per age group for training and testing set
    counts_train_val = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_train_val.items()}
    counts_test = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_test.items()}

    # Log the counts of unique identifiers per age group
    logger(f"Count of Unique Cat IDs per Age Group in Training/Validation Set:\n{counts_train_val}", file=log_file_path)
    logger(f"Count of Unique Cat IDs per Age Group in Testing Set:\n{counts_test}", file=log_file_path)

    #######################################################
    # CONTINUE WITH ENSURING VALID AND APPROPRIATE SPLITS #
    #######################################################
    
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    groups_train_val, groups_test = groups[train_val_idx], groups[test_idx]

    # logging identifier splits 
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)

    # check group splits
    check_initial_group_split(groups_train_val, groups_test)

    # Specify the cat_ids that must be in the training/validation set
    specific_cat_ids = ['000A', '046A']
    
    # Perform the swapping operation
    train_val_idx, test_idx = swap_cat_id_instances(dataframe, train_val_idx, test_idx, specific_cat_ids)
    
    # Re-assign the sets based on the updated indices
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    new_groups_train_val, new_groups_test = groups[train_val_idx], groups[test_idx]

    # Find differences for training and test sets
    moved_to_train_val, removed_from_train_val = find_group_differences(groups_train_val, new_groups_train_val)
    moved_to_test, removed_from_test = find_group_differences(groups_test, new_groups_test)
    
    # Display the results
    logger(f"Moved to Training/Validation Set:\n{moved_to_train_val}", file=log_file_path)
    logger(f"Removed from Training/Validation Set:\n{removed_from_train_val}", file=log_file_path)
    logger(f"Moved to Test Set:\n{moved_to_test}", file=log_file_path)
    logger(f"Removed from Test Set\n{removed_from_test}", file=log_file_path)

    # Update X_train_val, X_test, y_train_val, y_test, groups_train_val, groups_test based on updated indices
    X_train_val = X[train_val_idx]
    y_train_val = y[train_val_idx]
    groups_train_val = groups[train_val_idx]
    
    X_test = X[test_idx]
    y_test = y[test_idx]
    groups_test = groups[test_idx]

    # logging identifier splits again after potential swaps
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"AFTER SWAP - Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"AFTER SWAP - Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)
    
    # Verify the lengths are consistent
    logger(f"Length of X_train_val:\n{len(X_train_val)}", file=log_file_path)
    logger(f"Length of y_train_val:\n{len(y_train_val)}", file=log_file_path)
    logger(f"Length of groups_train_val:\n{len(groups_train_val)}", file=log_file_path)

    # Check group splits once more
    check_initial_group_split(groups_train_val, groups_test)

    # Convert the modified indices back to a DataFrame representing the updated df_train_val
    df_train_val_updated = dataframe.iloc[train_val_idx].copy()
    df_test_updated = dataframe.iloc[test_idx].copy()

    ############################
    # LOGGING AGE GROUP SPLITS #
    ############################

    # Get the distribution of age groups of age groups before the update
    training_validation_age_group_distribution = df_train_val['age_group'].value_counts()
    testing_age_group_distribution = df_test['age_group'].value_counts()
    
    # Logthe distribution
    logger(f"Train Age Group Distribution BEFORE SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution BEFORE SWAP:\n{testing_age_group_distribution}", file=log_file_path)

    # Get the distribution of age groups after the update
    training_validation_age_group_distribution = df_train_val_updated['age_group'].value_counts()
    testing_age_group_distribution = df_test_updated['age_group'].value_counts()
    
    # Log the distribution
    logger(f"Train Age Group Distribution AFTER SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution AFTER SWAP:\n{testing_age_group_distribution}", file=log_file_path)
    
    ########################################################
    # TRACKING FINAL CAT_IDs & GENDER AFTER REDISTRIBUTION #
    ########################################################

    # Get the distribution of groups
    training_validation_group_distribution = df_train_val_updated['cat_id'].value_counts()  
    testing_group_distribution = df_test_updated['cat_id'].value_counts()  

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val_updated['gender'].value_counts()
    testing_gender_distribution = df_test_updated['gender'].value_counts()
    
    logger(f"\n Starting training on unseen test set\n", file=log_file_path)

    ###################
    # PREPARING MODEL #
    ###################

    # Calculate the distribution of age groups in y_train_val
    age_group_distribution = Counter(y_train_val)
    print("Age group distribution:", age_group_distribution)

    # EarlyStopping callback: monitor 'loss' instead of 'val_loss' for the test set
    early_stopping = EarlyStopping(
        monitor='loss',  
        min_delta=0.001, 
        patience=30,  
        verbose=1,  
        restore_best_weights=True  
    )

    # One final shuffle to ensure randomness
    outer_shuffle_idx = np.random.permutation(len(X_train_val))
    X_train_val = X_train_val[outer_shuffle_idx]
    y_train_val = y_train_val[outer_shuffle_idx]
    
    # Scale the features
    scaler_full = StandardScaler().fit(X_train_val)
    X_train_full_scaled = scaler_full.transform(X_train_val)
    X_test_scaled = scaler_full.transform(X_test)
    
    # Encode the labels
    y_train_full_encoded = to_categorical(y_train_val)
    y_test_encoded = to_categorical(y_test)

    #######################
    # BUILD & TRAIN MODEL #
    #######################

    optimizers = {
        'Adamax': Adamax(learning_rate=0.00510251984616472)
    }
    
    # Model definition with dynamic number of layers
    model_full = Sequential()
    model_full.add(Dense(480, activation='relu', input_shape=(X_train_full_scaled.shape[1],)))
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.2011047009431978))  
    model_full.add(Dense(256, activation='relu',)) 
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.14956886311951184))  
    model_full.add(Dense(256, activation='relu'))  
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.42291461228250665))  
    model_full.add(Dense(3, activation='softmax'))  
    
    # Use the optimizer from the parameters
    optimizer = optimizers['Adamax']  # optimizer_key from parameters
    
    # Compile the model
    model_full.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    
    # Train the model on the full training set
    history_full = model_full.fit(X_train_full_scaled, y_train_full_encoded, epochs=1500, batch_size=64,
                                  verbose=1, callbacks=[early_stopping])
    
    # Evaluate the model on the held-out test set
    test_loss, test_accuracy = model_full.evaluate(X_test_scaled, y_test_encoded)

    y_test_pred_prob = model_full.predict(X_test_scaled)
    y_test_pred = np.argmax(y_test_pred_prob, axis=1)  
    y_test_true = np.argmax(y_test_encoded, axis=1)    

    ################################
    # LOG MAJORITY VOTE PER CAT_ID #
    ################################

    # Convert numeric predictions back to age group labels
    predicted_age_groups = label_encoder.inverse_transform(y_test_pred)
    actual_labels = label_encoder.inverse_transform(y_test_true)
    
    # Map predictions and actual labels back to cat_ids
    test_results = pd.DataFrame({
        'cat_id': df_test_updated['cat_id'],
        'predicted_age_group': predicted_age_groups,
        'actual_age_group': actual_labels
    })
    
    # Group by cat_id and aggregate predicted age groups
    majority_votes = test_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
    actual_groups = test_results.groupby('cat_id')['actual_age_group'].first()
    
    # Calculate the accuracy of majority voting
    correct_predictions = (majority_votes == actual_groups).sum()
    total_cats = len(actual_groups)
    majority_vote_accuracy = correct_predictions / total_cats
    
    # Log the accuracy of the majority voting
    logger(f"Majority Vote Accuracy for cat_id for this fold: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

    ####################################################
    # COLLECT PREDICTIONS FOR GENDER & CAT_ID ANALYSIS #
    ####################################################

    # Debugging print statements
    print(f'Before appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Extend lists with current fold results
    all_cat_ids.extend(df_test_updated['cat_id'].tolist())
    all_predicted_age_groups.extend(predicted_age_groups)
    all_actual_age_groups.extend(actual_labels)
    all_gender.extend(df_test_updated['gender'].tolist())

    # Debugging print statements
    print(f'After appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Calculate additional metrics
    test_precision = precision_score(y_test_true, y_test_pred, average='macro')  # Use 'macro' for imbalanced datasets
    test_recall = recall_score(y_test_true, y_test_pred, average='macro')
    test_f1 = f1_score(y_test_true, y_test_pred, average='macro')

    # prepare averages of outer metrics
    unseen_f1.append(test_f1)
    unseen_losses.append(test_loss)
    unseen_accuracies.append(test_accuracy)
    unseen_precisions.append(test_precision)
    unseen_recalls.append(test_recall)

    # Print final test results
    logger(f"Final Test Results - Loss: {test_loss}, Accuracy: {test_accuracy}, Precision: {test_precision}, Recall: {test_recall}, F1 Score: {test_f1}", file=log_file_path)

    # Generate the confusion matrix
    cm = confusion_matrix(y_test, y_test_pred)
    logger(f"Confusion Matrix:\n {cm}", file=log_file_path)

# Calculate the overall average metrics
unseen_set_avg_f1 = np.mean(unseen_f1)
unseen_set_avg_loss = np.mean(unseen_losses)
unseen_set_avg_acc = np.mean(unseen_accuracies)
unseen_set_avg_precision = np.mean(unseen_precisions)
unseen_set_avg_recall = np.mean(unseen_recalls)

logger(f"\nFinal Average F1-Score across all UNSEEN TEST sets: {unseen_set_avg_f1}", file=log_file_path)
logger(f"\nFinal Average Loss across all UNSEEN TEST sets: {unseen_set_avg_loss}", file=log_file_path)
logger(f"\nFinal Average Accuracy across all UNSEEN TEST sets: {unseen_set_avg_acc}", file=log_file_path)
logger(f"\nFinal Average Precision across all UNSEEN TEST sets: {unseen_set_avg_precision}", file=log_file_path)
logger(f"\nFinal Average Recall across all UNSEEN TEST sets: {unseen_set_avg_recall}\n", file=log_file_path)

# Append averages to total lists
all_f1.append(unseen_set_avg_f1)
all_losses.append(unseen_set_avg_loss)
all_accuracies.append(unseen_set_avg_acc)
all_precisions.append(unseen_set_avg_precision)
all_recalls.append(unseen_set_avg_recall)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# outer_fold 1
# Train Set Group Distribution:
# 046A    45
# 000A    39
# 103A    33
# 002B    30
# 047A    22
# 020A    20
# 000B    19
# 057A    17
# 029A    15
# 097A    15
# 097B    14
# 106A    13
# 002A    13
# 051A    12
# 116A    12
# 111A    12
# 101A    12
# 055A    12
# 028A    11
# 063A    11
# 042A    11
# 067A    11
# 059A    10
# 040A    10
# 022A     9
# 072A     9
# 001A     9
# 051B     9
# 016A     9
# 033A     9
# 071A     9
# 005A     9
# 068A     8
# 031A     7
# 117A     7
# 036A     7
# 095A     7
# 015A     7
# 027A     7
# 099A     6
# 007A     6
# 023A     6
# 109A     5
# 070A     5
# 094A     5
# 108A     5
# 008A     5
# 075A     5
# 021A     5
# 026A     4
# 025C     4
# 104A     4
# 003A     4
# 009A     4
# 023B     4
# 058A     3
# 053A     3
# 012A     3
# 060A     3
# 006A     3
# 105A     3
# 113A     3
# 062A     3
# 054A     2
# 052A     2
# 025B     2
# 037A     2
# 102A     2
# 061A     2
# 011A     2
# 035A     2
# 093A     2
# 032A     2
# 038A     2
# 069A     2
# 087A     2
# 092A     1
# 019B     1
# 024A     1
# 090A     1
# 110A     1
# 064A     1
# 043A     1
# 004A     1
# 049A     1
# 048A     1
# 066A     1
# 073A     1
# 076A     1
# 091A     1
# 026C     1
# 026B     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 019A    17
# 074A    16
# 025A    10
# 014B    10
# 065A     9
# 013B     8
# 039A     6
# 044A     5
# 050A     5
# 045A     4
# 034A     3
# 014A     3
# 056A     3
# 010A     3
# 018A     2
# 115A     1
# 096A     1
# 088A     1
# 041A     1
# 100A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    263
# X    220
# F    201
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    56
# F    30
# M    23
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [006A, 000A, 033A, 015A, 001A, 103A, 071A, 097...
# kitten    [111A, 040A, 046A, 047A, 042A, 109A, 043A, 049...
# senior    [093A, 097A, 057A, 106A, 104A, 055A, 059A, 113...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [019A, 074A, 034A, 065A, 039A, 013B, 025A, 014...
# kitten                 [044A, 014B, 050A, 041A, 045A, 115A]
# senior                                               [056A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 61, 'kitten': 10, 'senior': 21}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 13, 'kitten': 6, 'senior': 1}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '004A' '005A' '006A' '007A'
#  '008A' '009A' '011A' '012A' '015A' '016A' '019B' '020A' '021A' '022A'
#  '023A' '023B' '024A' '025B' '025C' '026A' '026B' '026C' '027A' '028A'
#  '029A' '031A' '032A' '033A' '035A' '036A' '037A' '038A' '040A' '042A'
#  '043A' '046A' '047A' '048A' '049A' '051A' '051B' '052A' '053A' '054A'
#  '055A' '057A' '058A' '059A' '060A' '061A' '062A' '063A' '064A' '066A'
#  '067A' '068A' '069A' '070A' '071A' '072A' '073A' '075A' '076A' '087A'
#  '090A' '091A' '092A' '093A' '094A' '095A' '097A' '097B' '099A' '101A'
#  '102A' '103A' '104A' '105A' '106A' '108A' '109A' '110A' '111A' '113A'
#  '116A' '117A']
# Unique Test Group IDs:
# ['010A' '013B' '014A' '014B' '018A' '019A' '025A' '034A' '039A' '041A'
#  '044A' '045A' '050A' '056A' '065A' '074A' '088A' '096A' '100A' '115A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '004A' '005A' '006A' '007A'
#  '008A' '009A' '011A' '012A' '015A' '016A' '019B' '020A' '021A' '022A'
#  '023A' '023B' '024A' '025B' '025C' '026A' '026B' '026C' '027A' '028A'
#  '029A' '031A' '032A' '033A' '035A' '036A' '037A' '038A' '040A' '042A'
#  '043A' '046A' '047A' '048A' '049A' '051A' '051B' '052A' '053A' '054A'
#  '055A' '057A' '058A' '059A' '060A' '061A' '062A' '063A' '064A' '066A'
#  '067A' '068A' '069A' '070A' '071A' '072A' '073A' '075A' '076A' '087A'
#  '090A' '091A' '092A' '093A' '094A' '095A' '097A' '097B' '099A' '101A'
#  '102A' '103A' '104A' '105A' '106A' '108A' '109A' '110A' '111A' '113A'
#  '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['010A' '013B' '014A' '014B' '018A' '019A' '025A' '034A' '039A' '041A'
#  '044A' '045A' '050A' '056A' '065A' '074A' '088A' '096A' '100A' '115A']
# Length of X_train_val:
# 684
# Length of y_train_val:
# 684
# Length of groups_train_val:
# 684
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     429
# senior    146
# kitten    109
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     80
# kitten    26
# senior     3
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     429
# senior    146
# kitten    109
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     80
# kitten    26
# senior     3
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 429, 2: 146, 1: 109})
# Epoch 1/1500
# 11/11 [==============================] - 1s 5ms/step - loss: 1.0416 - accuracy: 0.6316
# Epoch 2/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.3134 - accuracy: 0.8947
# Epoch 3/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1374 - accuracy: 0.9591
# Epoch 4/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0806 - accuracy: 0.9751
# Epoch 5/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0314 - accuracy: 0.9912
# Epoch 6/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0319 - accuracy: 0.9912
# Epoch 7/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0143 - accuracy: 1.0000
# Epoch 8/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0203 - accuracy: 0.9985
# Epoch 9/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0149 - accuracy: 0.9971
# Epoch 10/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0121 - accuracy: 0.9971
# Epoch 11/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0180 - accuracy: 0.9971
# Epoch 12/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0069 - accuracy: 1.0000
# Epoch 13/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0078 - accuracy: 1.0000
# Epoch 14/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0127 - accuracy: 0.9971
# Epoch 15/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0060 - accuracy: 1.0000
# Epoch 16/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0050 - accuracy: 1.0000
# Epoch 17/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0079 - accuracy: 0.9971
# Epoch 18/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0045 - accuracy: 1.0000
# Epoch 19/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0076 - accuracy: 0.9971
# Epoch 20/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 21/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0087 - accuracy: 0.9971
# Epoch 22/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0046 - accuracy: 1.0000
# Epoch 23/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 24/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0043 - accuracy: 1.0000
# Epoch 25/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 26/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 27/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 28/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 29/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 30/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 31/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 32/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 33/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0040 - accuracy: 0.9985
# Epoch 34/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0037 - accuracy: 0.9985
# Epoch 35/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 36/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 37/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 38/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 39/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 40/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 41/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 42/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 43/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0068 - accuracy: 0.9971
# Epoch 44/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 45/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 46/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 47/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 48/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0025 - accuracy: 0.9985
# Epoch 49/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 8.7200e-04 - accuracy: 1.0000
# Epoch 50/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 8.8620e-04 - accuracy: 1.0000
# Epoch 51/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 52/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 8.8951e-04 - accuracy: 1.0000
# Epoch 53/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 54/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 4.8548e-04 - accuracy: 1.0000
# Epoch 55/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0022 - accuracy: 0.9985
# Epoch 56/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 4.8444e-04 - accuracy: 1.0000
# Epoch 57/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 9.2212e-04 - accuracy: 1.0000
# Epoch 58/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 5.4924e-04 - accuracy: 1.0000
# Epoch 59/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 60/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0026 - accuracy: 0.9985
# Epoch 61/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 62/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 7.3700e-04 - accuracy: 1.0000
# Epoch 63/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 4.2870e-04 - accuracy: 1.0000
# Epoch 64/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 65/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0045 - accuracy: 0.9985
# Epoch 66/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 67/1500
#  1/11 [=>............................] - ETA: 0s - loss: 3.7456e-04 - accuracy: 1.0000Restoring model weights from the end of the best epoch: 37.
# 11/11 [==============================] - 0s 5ms/step - loss: 6.0851e-04 - accuracy: 1.0000
# Epoch 67: early stopping
# 4/4 [==============================] - 0s 1ms/step - loss: 0.7917 - accuracy: 0.8532
# 4/4 [==============================] - 0s 1ms/step
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Majority Vote Accuracy for cat_id for this fold: 0.95 (19/20)
# Before appending - Cat IDs: 0, Predictions: 0, Actuals: 0, Gender: 0
# After appending - Cat IDs: 109, Predictions: 109, Actuals: 109, Gender: 109
# Final Test Results - Loss: 0.7917216420173645, Accuracy: 0.853210985660553, Precision: 0.685270205643233, Recall: 0.7398504273504273, F1 Score: 0.6592680933766205
# Confusion Matrix:
#  [[75  1  4]
#  [ 6 16  4]
#  [ 1  0  2]]
# outer_fold 2
# Train Set Group Distribution:
# 046A    45
# 002B    30
# 020A    20
# 000B    19
# 019A    17
# 057A    17
# 074A    16
# 029A    15
# 097A    15
# 101A    12
# 055A    12
# 111A    12
# 051A    12
# 028A    11
# 067A    11
# 042A    11
# 063A    11
# 059A    10
# 025A    10
# 040A    10
# 014B    10
# 072A     9
# 016A     9
# 051B     9
# 065A     9
# 001A     9
# 071A     9
# 005A     9
# 033A     9
# 068A     8
# 013B     8
# 117A     7
# 031A     7
# 015A     7
# 036A     7
# 095A     7
# 007A     6
# 039A     6
# 021A     5
# 070A     5
# 050A     5
# 108A     5
# 008A     5
# 109A     5
# 044A     5
# 026A     4
# 003A     4
# 104A     4
# 045A     4
# 009A     4
# 056A     3
# 010A     3
# 012A     3
# 053A     3
# 060A     3
# 006A     3
# 014A     3
# 034A     3
# 113A     3
# 018A     2
# 011A     2
# 035A     2
# 102A     2
# 038A     2
# 037A     2
# 052A     2
# 025B     2
# 087A     2
# 069A     2
# 093A     2
# 054A     2
# 061A     2
# 115A     1
# 019B     1
# 110A     1
# 100A     1
# 090A     1
# 091A     1
# 088A     1
# 096A     1
# 026C     1
# 041A     1
# 092A     1
# 064A     1
# 073A     1
# 043A     1
# 076A     1
# 026B     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 000A    39
# 103A    33
# 047A    22
# 097B    14
# 002A    13
# 106A    13
# 116A    12
# 022A     9
# 027A     7
# 023A     6
# 099A     6
# 094A     5
# 075A     5
# 025C     4
# 023B     4
# 105A     3
# 062A     3
# 058A     3
# 032A     2
# 049A     1
# 066A     1
# 048A     1
# 004A     1
# 024A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    230
# M    204
# F    151
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# M    82
# F    80
# X    46
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [006A, 033A, 015A, 001A, 071A, 028A, 019A, 074...
# kitten    [044A, 014B, 111A, 040A, 046A, 042A, 109A, 050...
# senior    [093A, 097A, 057A, 104A, 055A, 059A, 113A, 051...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [000A, 103A, 097B, 062A, 022A, 002A, 023A, 027...
# kitten                                   [047A, 049A, 048A]
# senior                       [106A, 116A, 058A, 094A, 024A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 58, 'kitten': 13, 'senior': 17}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 16, 'kitten': 3, 'senior': 5}
# Unique Training/Validation Group IDs:
# ['000B' '001A' '002B' '003A' '005A' '006A' '007A' '008A' '009A' '010A'
#  '011A' '012A' '013B' '014A' '014B' '015A' '016A' '018A' '019A' '019B'
#  '020A' '021A' '025A' '025B' '026A' '026B' '026C' '028A' '029A' '031A'
#  '033A' '034A' '035A' '036A' '037A' '038A' '039A' '040A' '041A' '042A'
#  '043A' '044A' '045A' '046A' '050A' '051A' '051B' '052A' '053A' '054A'
#  '055A' '056A' '057A' '059A' '060A' '061A' '063A' '064A' '065A' '067A'
#  '068A' '069A' '070A' '071A' '072A' '073A' '074A' '076A' '087A' '088A'
#  '090A' '091A' '092A' '093A' '095A' '096A' '097A' '100A' '101A' '102A'
#  '104A' '108A' '109A' '110A' '111A' '113A' '115A' '117A']
# Unique Test Group IDs:
# ['000A' '002A' '004A' '022A' '023A' '023B' '024A' '025C' '027A' '032A'
#  '047A' '048A' '049A' '058A' '062A' '066A' '075A' '094A' '097B' '099A'
#  '103A' '105A' '106A' '116A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'000A'}
# Removed from Training/Validation Set:
# {'010A'}
# Moved to Test Set:
# {'010A'}
# Removed from Test Set
# {'000A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002B' '003A' '005A' '006A' '007A' '008A' '009A'
#  '011A' '012A' '013B' '014A' '014B' '015A' '016A' '018A' '019A' '019B'
#  '020A' '021A' '025A' '025B' '026A' '026B' '026C' '028A' '029A' '031A'
#  '033A' '034A' '035A' '036A' '037A' '038A' '039A' '040A' '041A' '042A'
#  '043A' '044A' '045A' '046A' '050A' '051A' '051B' '052A' '053A' '054A'
#  '055A' '056A' '057A' '059A' '060A' '061A' '063A' '064A' '065A' '067A'
#  '068A' '069A' '070A' '071A' '072A' '073A' '074A' '076A' '087A' '088A'
#  '090A' '091A' '092A' '093A' '095A' '096A' '097A' '100A' '101A' '102A'
#  '104A' '108A' '109A' '110A' '111A' '113A' '115A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['002A' '004A' '010A' '022A' '023A' '023B' '024A' '025C' '027A' '032A'
#  '047A' '048A' '049A' '058A' '062A' '066A' '075A' '094A' '097B' '099A'
#  '103A' '105A' '106A' '116A']
# Length of X_train_val:
# 621
# Length of y_train_val:
# 621
# Length of groups_train_val:
# 621
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     359
# senior    115
# kitten    111
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     150
# senior     34
# kitten     24
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     395
# senior    115
# kitten    111
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     114
# senior     34
# kitten     24
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 395, 2: 115, 1: 111})
# Epoch 1/1500
# 10/10 [==============================] - 1s 4ms/step - loss: 1.1634 - accuracy: 0.6055
# Epoch 2/1500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2877 - accuracy: 0.8937
# Epoch 3/1500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1558 - accuracy: 0.9597
# Epoch 4/1500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0727 - accuracy: 0.9791
# Epoch 5/1500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0388 - accuracy: 0.9903
# Epoch 6/1500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0230 - accuracy: 0.9984
# Epoch 7/1500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0315 - accuracy: 0.9936
# Epoch 8/1500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0185 - accuracy: 0.9968
# Epoch 9/1500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0160 - accuracy: 0.9984
# Epoch 10/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0139 - accuracy: 0.9984
# Epoch 11/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0117 - accuracy: 0.9968
# Epoch 12/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0089 - accuracy: 1.0000
# Epoch 13/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0103 - accuracy: 0.9968
# Epoch 14/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0168 - accuracy: 0.9936
# Epoch 15/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0057 - accuracy: 1.0000
# Epoch 16/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0044 - accuracy: 0.9984
# Epoch 17/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 18/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0077 - accuracy: 0.9984
# Epoch 19/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 20/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0049 - accuracy: 0.9984
# Epoch 21/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0071 - accuracy: 0.9968
# Epoch 22/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 23/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 24/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 25/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 26/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0072 - accuracy: 0.9984
# Epoch 27/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 28/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 29/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 30/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 31/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 32/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0032 - accuracy: 0.9984
# Epoch 33/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0059 - accuracy: 0.9984
# Epoch 34/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 35/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 36/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 37/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0050 - accuracy: 0.9984
# Epoch 38/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 39/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 40/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 41/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 42/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 43/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0037 - accuracy: 0.9984
# Epoch 44/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 45/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 46/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 47/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 9.6550e-04 - accuracy: 1.0000
# Epoch 48/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 49/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 50/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 51/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 52/1500
#  1/10 [==>...........................] - ETA: 0s - loss: 8.8121e-04 - accuracy: 1.0000Restoring model weights from the end of the best epoch: 22.
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 52: early stopping
# 6/6 [==============================] - 0s 1ms/step - loss: 1.4145 - accuracy: 0.7326
# 6/6 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.83 (20/24)
# Before appending - Cat IDs: 109, Predictions: 109, Actuals: 109, Gender: 109
# After appending - Cat IDs: 281, Predictions: 281, Actuals: 281, Gender: 281
# Final Test Results - Loss: 1.4145299196243286, Accuracy: 0.7325581312179565, Precision: 0.679958985831469, Recall: 0.4976350189198486, F1 Score: 0.5292753032772044
# Confusion Matrix:
#  [[109   4   1]
#  [ 21   3   0]
#  [ 19   1  14]]
# outer_fold 3
# Train Set Group Distribution:
# 046A    45
# 000A    39
# 103A    33
# 002B    30
# 047A    22
# 020A    20
# 057A    17
# 019A    17
# 074A    16
# 097A    15
# 029A    15
# 097B    14
# 106A    13
# 002A    13
# 116A    12
# 055A    12
# 042A    11
# 067A    11
# 025A    10
# 040A    10
# 014B    10
# 059A    10
# 051B     9
# 072A     9
# 065A     9
# 005A     9
# 016A     9
# 071A     9
# 022A     9
# 013B     8
# 095A     7
# 015A     7
# 027A     7
# 007A     6
# 039A     6
# 023A     6
# 099A     6
# 094A     5
# 021A     5
# 050A     5
# 008A     5
# 075A     5
# 108A     5
# 044A     5
# 045A     4
# 009A     4
# 025C     4
# 104A     4
# 023B     4
# 003A     4
# 060A     3
# 012A     3
# 056A     3
# 053A     3
# 010A     3
# 058A     3
# 006A     3
# 113A     3
# 062A     3
# 014A     3
# 105A     3
# 034A     3
# 061A     2
# 102A     2
# 035A     2
# 018A     2
# 037A     2
# 052A     2
# 011A     2
# 025B     2
# 093A     2
# 087A     2
# 032A     2
# 054A     2
# 088A     1
# 100A     1
# 024A     1
# 115A     1
# 043A     1
# 004A     1
# 048A     1
# 066A     1
# 091A     1
# 041A     1
# 092A     1
# 049A     1
# 096A     1
# 073A     1
# 026B     1
# Name: cat_id, dtype: int64
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Testing Set Group Distribution:
# 000B    19
# 101A    12
# 051A    12
# 111A    12
# 028A    11
# 063A    11
# 033A     9
# 001A     9
# 068A     8
# 117A     7
# 036A     7
# 031A     7
# 109A     5
# 070A     5
# 026A     4
# 069A     2
# 038A     2
# 019B     1
# 110A     1
# 076A     1
# 026C     1
# 064A     1
# 090A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    267
# X    228
# F    150
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# F    81
# X    48
# M    19
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [006A, 000A, 015A, 103A, 071A, 097B, 019A, 074...
# kitten    [044A, 014B, 040A, 046A, 047A, 042A, 050A, 043...
# senior    [093A, 097A, 057A, 106A, 104A, 055A, 059A, 113...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [033A, 001A, 028A, 101A, 063A, 038A, 070A, 069...
# kitten                                   [111A, 109A, 110A]
# senior                                   [117A, 051A, 090A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 57, 'kitten': 13, 'senior': 19}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 17, 'kitten': 3, 'senior': 3}
# Unique Training/Validation Group IDs:
# ['000A' '002A' '002B' '003A' '004A' '005A' '006A' '007A' '008A' '009A'
#  '010A' '011A' '012A' '013B' '014A' '014B' '015A' '016A' '018A' '019A'
#  '020A' '021A' '022A' '023A' '023B' '024A' '025A' '025B' '025C' '026B'
#  '027A' '029A' '032A' '034A' '035A' '037A' '039A' '040A' '041A' '042A'
#  '043A' '044A' '045A' '046A' '047A' '048A' '049A' '050A' '051B' '052A'
#  '053A' '054A' '055A' '056A' '057A' '058A' '059A' '060A' '061A' '062A'
#  '065A' '066A' '067A' '071A' '072A' '073A' '074A' '075A' '087A' '088A'
#  '091A' '092A' '093A' '094A' '095A' '096A' '097A' '097B' '099A' '100A'
#  '102A' '103A' '104A' '105A' '106A' '108A' '113A' '115A' '116A']
# Unique Test Group IDs:
# ['000B' '001A' '019B' '026A' '026C' '028A' '031A' '033A' '036A' '038A'
#  '051A' '063A' '064A' '068A' '069A' '070A' '076A' '090A' '101A' '109A'
#  '110A' '111A' '117A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '002A' '002B' '003A' '004A' '005A' '006A' '007A' '008A' '009A'
#  '010A' '011A' '012A' '013B' '014A' '014B' '015A' '016A' '018A' '019A'
#  '020A' '021A' '022A' '023A' '023B' '024A' '025A' '025B' '025C' '026B'
#  '027A' '029A' '032A' '034A' '035A' '037A' '039A' '040A' '041A' '042A'
#  '043A' '044A' '045A' '046A' '047A' '048A' '049A' '050A' '051B' '052A'
#  '053A' '054A' '055A' '056A' '057A' '058A' '059A' '060A' '061A' '062A'
#  '065A' '066A' '067A' '071A' '072A' '073A' '074A' '075A' '087A' '088A'
#  '091A' '092A' '093A' '094A' '095A' '096A' '097A' '097B' '099A' '100A'
#  '102A' '103A' '104A' '105A' '106A' '108A' '113A' '115A' '116A']
# AFTER SWAP - Unique Test Group IDs:
# ['000B' '001A' '019B' '026A' '026C' '028A' '031A' '033A' '036A' '038A'
#  '051A' '063A' '064A' '068A' '069A' '070A' '076A' '090A' '101A' '109A'
#  '110A' '111A' '117A']
# Length of X_train_val:
# 645
# Length of y_train_val:
# 645
# Length of groups_train_val:
# 645
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     399
# senior    129
# kitten    117
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     110
# senior     20
# kitten     18
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     399
# senior    129
# kitten    117
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     110
# senior     20
# kitten     18
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 399, 2: 129, 1: 117})
# Epoch 1/1500
# 11/11 [==============================] - 1s 4ms/step - loss: 1.0118 - accuracy: 0.6558
# Epoch 2/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.3008 - accuracy: 0.9039
# Epoch 3/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.1929 - accuracy: 0.9380
# Epoch 4/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0868 - accuracy: 0.9752
# Epoch 5/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0675 - accuracy: 0.9845
# Epoch 6/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0586 - accuracy: 0.9860
# Epoch 7/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0461 - accuracy: 0.9876
# Epoch 8/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0515 - accuracy: 0.9845
# Epoch 9/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0502 - accuracy: 0.9891
# Epoch 10/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0298 - accuracy: 0.9953
# Epoch 11/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0432 - accuracy: 0.9845
# Epoch 12/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0374 - accuracy: 0.9876
# Epoch 13/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0385 - accuracy: 0.9829
# Epoch 14/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0412 - accuracy: 0.9922
# Epoch 15/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0548 - accuracy: 0.9845
# Epoch 16/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0191 - accuracy: 0.9969
# Epoch 17/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0262 - accuracy: 0.9938
# Epoch 18/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0266 - accuracy: 0.9922
# Epoch 19/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0149 - accuracy: 1.0000
# Epoch 20/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0157 - accuracy: 0.9984
# Epoch 21/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0216 - accuracy: 0.9969
# Epoch 22/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0249 - accuracy: 0.9922
# Epoch 23/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0230 - accuracy: 0.9938
# Epoch 24/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0252 - accuracy: 0.9922
# Epoch 25/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0242 - accuracy: 0.9938
# Epoch 26/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0345 - accuracy: 0.9922
# Epoch 27/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0207 - accuracy: 0.9953
# Epoch 28/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0311 - accuracy: 0.9969
# Epoch 29/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0577 - accuracy: 0.9891
# Epoch 30/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0199 - accuracy: 0.9969
# Epoch 31/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0228 - accuracy: 0.9938
# Epoch 32/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0250 - accuracy: 0.9922
# Epoch 33/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0287 - accuracy: 0.9891
# Epoch 34/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0458 - accuracy: 0.9907
# Epoch 35/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0233 - accuracy: 0.9938
# Epoch 36/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0208 - accuracy: 0.9938
# Epoch 37/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0166 - accuracy: 0.9953
# Epoch 38/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0263 - accuracy: 0.9922
# Epoch 39/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0303 - accuracy: 0.9984
# Epoch 40/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0445 - accuracy: 0.9938
# Epoch 41/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0233 - accuracy: 0.9922
# Epoch 42/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0213 - accuracy: 0.9922
# Epoch 43/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0155 - accuracy: 0.9969
# Epoch 44/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0246 - accuracy: 0.9922
# Epoch 45/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0182 - accuracy: 0.9938
# Epoch 46/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0165 - accuracy: 0.9969
# Epoch 47/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0115 - accuracy: 0.9984
# Epoch 48/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0224 - accuracy: 0.9922
# Epoch 49/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0204 - accuracy: 0.9953
# Epoch 50/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0171 - accuracy: 0.9938
# Epoch 51/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0289 - accuracy: 0.9907
# Epoch 52/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0154 - accuracy: 0.9984
# Epoch 53/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0133 - accuracy: 0.9984
# Epoch 54/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0181 - accuracy: 0.9938
# Epoch 55/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0147 - accuracy: 0.9969
# Epoch 56/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0127 - accuracy: 0.9953
# Epoch 57/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0146 - accuracy: 0.9969
# Epoch 58/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0287 - accuracy: 0.9907
# Epoch 59/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0156 - accuracy: 0.9969
# Epoch 60/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0192 - accuracy: 0.9938
# Epoch 61/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0221 - accuracy: 0.9953
# Epoch 62/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0219 - accuracy: 0.9953
# Epoch 63/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0181 - accuracy: 0.9953
# Epoch 64/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0201 - accuracy: 0.9969
# Epoch 65/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0109 - accuracy: 0.9984
# Epoch 66/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0161 - accuracy: 0.9969
# Epoch 67/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0173 - accuracy: 0.9969
# Epoch 68/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0156 - accuracy: 0.9984
# Epoch 69/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0087 - accuracy: 1.0000
# Epoch 70/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0132 - accuracy: 0.9969
# Epoch 71/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0086 - accuracy: 1.0000
# Epoch 72/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0472 - accuracy: 0.9860
# Epoch 73/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0129 - accuracy: 0.9969
# Epoch 74/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0251 - accuracy: 0.9938
# Epoch 75/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0123 - accuracy: 0.9984
# Epoch 76/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0219 - accuracy: 0.9953
# Epoch 77/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0278 - accuracy: 0.9876
# Epoch 78/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0075 - accuracy: 1.0000
# Epoch 79/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0122 - accuracy: 0.9953
# Epoch 80/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0093 - accuracy: 0.9969
# Epoch 81/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0142 - accuracy: 0.9953
# Epoch 82/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0179 - accuracy: 0.9969
# Epoch 83/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0132 - accuracy: 0.9969
# Epoch 84/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0145 - accuracy: 0.9953
# Epoch 85/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0102 - accuracy: 0.9984
# Epoch 86/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0099 - accuracy: 0.9969
# Epoch 87/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0253 - accuracy: 0.9953
# Epoch 88/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0270 - accuracy: 0.9953
# Epoch 89/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0238 - accuracy: 0.9907
# Epoch 90/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0261 - accuracy: 0.9907
# Epoch 91/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0235 - accuracy: 0.9922
# Epoch 92/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0354 - accuracy: 0.9860
# Epoch 93/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0202 - accuracy: 0.9953
# Epoch 94/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0186 - accuracy: 0.9984
# Epoch 95/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0082 - accuracy: 1.0000
# Epoch 96/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0378 - accuracy: 0.9907
# Epoch 97/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0148 - accuracy: 0.9969
# Epoch 98/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0207 - accuracy: 0.9938
# Epoch 99/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0123 - accuracy: 0.9984
# Epoch 100/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0187 - accuracy: 0.9953
# Epoch 101/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0136 - accuracy: 0.9969
# Epoch 102/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0133 - accuracy: 0.9984
# Epoch 103/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0172 - accuracy: 0.9953
# Epoch 104/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0150 - accuracy: 0.9953
# Epoch 105/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0311 - accuracy: 0.9922
# Epoch 106/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0226 - accuracy: 0.9922
# Epoch 107/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0191 - accuracy: 0.9922
# Epoch 108/1500
#  1/11 [=>............................] - ETA: 0s - loss: 0.0113 - accuracy: 1.0000Restoring model weights from the end of the best epoch: 78.
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0128 - accuracy: 1.0000
# Epoch 108: early stopping
# 5/5 [==============================] - 0s 1ms/step - loss: 1.6949 - accuracy: 0.6892
# 5/5 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.78 (18/23)
# Before appending - Cat IDs: 281, Predictions: 281, Actuals: 281, Gender: 281
# After appending - Cat IDs: 429, Predictions: 429, Actuals: 429, Gender: 429
# Final Test Results - Loss: 1.6949121952056885, Accuracy: 0.6891891956329346, Precision: 0.591017316017316, Recall: 0.5358585858585858, F1 Score: 0.5590909090909091
# Confusion Matrix:
#  [[87  2 21]
#  [ 6 12  0]
#  [17  0  3]]
# outer_fold 4
# Train Set Group Distribution:
# 000A    39
# 103A    33
# 047A    22
# 020A    20
# 000B    19
# 019A    17
# 057A    17
# 074A    16
# 097A    15
# 097B    14
# 106A    13
# 002A    13
# 051A    12
# 111A    12
# 101A    12
# 116A    12
# 063A    11
# 028A    11
# 025A    10
# 014B    10
# 065A     9
# 016A     9
# 001A     9
# 072A     9
# 005A     9
# 033A     9
# 022A     9
# 068A     8
# 013B     8
# 015A     7
# 036A     7
# 031A     7
# 117A     7
# 027A     7
# 095A     7
# 023A     6
# 099A     6
# 039A     6
# 007A     6
# 044A     5
# 094A     5
# 075A     5
# 050A     5
# 108A     5
# 021A     5
# 109A     5
# 070A     5
# 025C     4
# 045A     4
# 009A     4
# 003A     4
# 023B     4
# 026A     4
# 105A     3
# 014A     3
# 056A     3
# 034A     3
# 053A     3
# 058A     3
# 010A     3
# 062A     3
# 052A     2
# 102A     2
# 061A     2
# 054A     2
# 018A     2
# 038A     2
# 069A     2
# 032A     2
# 064A     1
# 088A     1
# 024A     1
# 090A     1
# 100A     1
# 110A     1
# 115A     1
# 019B     1
# 004A     1
# 049A     1
# 048A     1
# 066A     1
# 076A     1
# 096A     1
# 026C     1
# 043A     1
# 041A     1
# 092A     1
# 026B     1
# Name: cat_id, dtype: int64
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Testing Set Group Distribution:
# 046A    45
# 002B    30
# 029A    15
# 055A    12
# 067A    11
# 042A    11
# 059A    10
# 040A    10
# 051B     9
# 071A     9
# 008A     5
# 104A     4
# 012A     3
# 060A     3
# 006A     3
# 113A     3
# 087A     2
# 093A     2
# 035A     2
# 011A     2
# 037A     2
# 025B     2
# 073A     1
# 091A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# F    205
# M    197
# X    194
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# M    89
# X    82
# F    26
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [000A, 033A, 015A, 001A, 103A, 097B, 028A, 019...
# kitten    [044A, 014B, 111A, 047A, 109A, 050A, 043A, 049...
# senior    [097A, 057A, 106A, 116A, 054A, 117A, 056A, 051...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [006A, 071A, 067A, 002B, 029A, 091A, 087A, 073...
# kitten                                   [040A, 046A, 042A]
# senior           [093A, 104A, 055A, 059A, 113A, 051B, 011A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 60, 'kitten': 13, 'senior': 15}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 14, 'kitten': 3, 'senior': 7}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '003A' '004A' '005A' '007A' '009A' '010A'
#  '013B' '014A' '014B' '015A' '016A' '018A' '019A' '019B' '020A' '021A'
#  '022A' '023A' '023B' '024A' '025A' '025C' '026A' '026B' '026C' '027A'
#  '028A' '031A' '032A' '033A' '034A' '036A' '038A' '039A' '041A' '043A'
#  '044A' '045A' '047A' '048A' '049A' '050A' '051A' '052A' '053A' '054A'
#  '056A' '057A' '058A' '061A' '062A' '063A' '064A' '065A' '066A' '068A'
#  '069A' '070A' '072A' '074A' '075A' '076A' '088A' '090A' '092A' '094A'
#  '095A' '096A' '097A' '097B' '099A' '100A' '101A' '102A' '103A' '105A'
#  '106A' '108A' '109A' '110A' '111A' '115A' '116A' '117A']
# Unique Test Group IDs:
# ['002B' '006A' '008A' '011A' '012A' '025B' '029A' '035A' '037A' '040A'
#  '042A' '046A' '051B' '055A' '059A' '060A' '067A' '071A' '073A' '087A'
#  '091A' '093A' '104A' '113A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'046A'}
# Removed from Training/Validation Set:
# {'044A'}
# Moved to Test Set:
# {'044A'}
# Removed from Test Set
# {'046A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '003A' '004A' '005A' '007A' '009A' '010A'
#  '013B' '014A' '014B' '015A' '016A' '018A' '019A' '019B' '020A' '021A'
#  '022A' '023A' '023B' '024A' '025A' '025C' '026A' '026B' '026C' '027A'
#  '028A' '031A' '032A' '033A' '034A' '036A' '038A' '039A' '041A' '043A'
#  '045A' '046A' '047A' '048A' '049A' '050A' '051A' '052A' '053A' '054A'
#  '056A' '057A' '058A' '061A' '062A' '063A' '064A' '065A' '066A' '068A'
#  '069A' '070A' '072A' '074A' '075A' '076A' '088A' '090A' '092A' '094A'
#  '095A' '096A' '097A' '097B' '099A' '100A' '101A' '102A' '103A' '105A'
#  '106A' '108A' '109A' '110A' '111A' '115A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['002B' '006A' '008A' '011A' '012A' '025B' '029A' '035A' '037A' '040A'
#  '042A' '044A' '051B' '055A' '059A' '060A' '067A' '071A' '073A' '087A'
#  '091A' '093A' '104A' '113A']
# Length of X_train_val:
# 636
# Length of y_train_val:
# 636
# Length of groups_train_val:
# 636
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     420
# senior    107
# kitten     69
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     89
# kitten    66
# senior    42
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     420
# kitten    109
# senior    107
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     89
# senior    42
# kitten    26
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 420, 1: 109, 2: 107})
# Epoch 1/1500
# 10/10 [==============================] - 1s 5ms/step - loss: 1.1223 - accuracy: 0.6195
# Epoch 2/1500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3047 - accuracy: 0.8994
# Epoch 3/1500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1559 - accuracy: 0.9481
# Epoch 4/1500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0809 - accuracy: 0.9733
# Epoch 5/1500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0492 - accuracy: 0.9827
# Epoch 6/1500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0345 - accuracy: 0.9874
# Epoch 7/1500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0222 - accuracy: 0.9953
# Epoch 8/1500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0198 - accuracy: 0.9953
# Epoch 9/1500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0169 - accuracy: 0.9984
# Epoch 10/1500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0364 - accuracy: 0.9906
# Epoch 11/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0165 - accuracy: 0.9953
# Epoch 12/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0179 - accuracy: 0.9969
# Epoch 13/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0091 - accuracy: 1.0000
# Epoch 14/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0082 - accuracy: 1.0000
# Epoch 15/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0093 - accuracy: 0.9969
# Epoch 16/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0070 - accuracy: 1.0000
# Epoch 17/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0105 - accuracy: 0.9984
# Epoch 18/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0094 - accuracy: 0.9969
# Epoch 19/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 20/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 21/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 22/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 23/1500
# ...
# Epoch 31/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0051 - accuracy: 0.9984
# Epoch 32/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 33/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0069 - accuracy: 0.9969
# Epoch 34/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 35/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0054 - accuracy: 0.9984
# Epoch 36/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 37/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 38/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 39/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 40/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 8.2167e-04 - accuracy: 1.0000
# Epoch 41/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 42/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 43/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 44/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0031 - accuracy: 0.9984
# Epoch 45/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 46/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 47/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 48/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 49/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 50/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 51/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 52/1500
#  1/10 [==>...........................] - ETA: 0s - loss: 4.0523e-04 - accuracy: 1.0000Restoring model weights from the end of the best epoch: 22.
# 10/10 [==============================] - 0s 5ms/step - loss: 8.7274e-04 - accuracy: 1.0000
# Epoch 52: early stopping
# 5/5 [==============================] - 0s 1ms/step - loss: 1.6320 - accuracy: 0.6624
# 5/5 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.71 (17/24)
# Before appending - Cat IDs: 429, Predictions: 429, Actuals: 429, Gender: 429
# After appending - Cat IDs: 586, Predictions: 586, Actuals: 586, Gender: 586
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Final Test Results - Loss: 1.6319801807403564, Accuracy: 0.662420392036438, Precision: 0.6402691511387163, Recall: 0.6555336049718072, F1 Score: 0.6452548372437875
# Confusion Matrix:
#  [[65  8 16]
#  [ 4 21  1]
#  [23  1 18]]
# outer_fold 5
# Train Set Group Distribution:
# 046A    45
# 000A    39
# 103A    33
# 002B    30
# 047A    22
# 000B    19
# 019A    17
# 074A    16
# 029A    15
# 097B    14
# 002A    13
# 106A    13
# 055A    12
# 101A    12
# 116A    12
# 051A    12
# 111A    12
# 067A    11
# 063A    11
# 042A    11
# 028A    11
# 040A    10
# 025A    10
# 059A    10
# 014B    10
# 001A     9
# 022A     9
# 071A     9
# 051B     9
# 065A     9
# 033A     9
# 013B     8
# 068A     8
# 117A     7
# 027A     7
# 031A     7
# 036A     7
# 023A     6
# 099A     6
# 039A     6
# 050A     5
# 075A     5
# 094A     5
# 109A     5
# 008A     5
# 044A     5
# 070A     5
# 026A     4
# 025C     4
# 045A     4
# 104A     4
# 023B     4
# 105A     3
# 062A     3
# 034A     3
# 060A     3
# 006A     3
# 113A     3
# 010A     3
# 058A     3
# 012A     3
# 014A     3
# 056A     3
# 035A     2
# 037A     2
# 011A     2
# 025B     2
# 032A     2
# 087A     2
# 018A     2
# 093A     2
# 069A     2
# 038A     2
# 088A     1
# 090A     1
# 100A     1
# 110A     1
# 091A     1
# 115A     1
# 019B     1
# 064A     1
# 004A     1
# 073A     1
# 048A     1
# 066A     1
# 076A     1
# 026C     1
# 096A     1
# 041A     1
# 049A     1
# 024A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 020A    20
# 057A    17
# 097A    15
# 005A     9
# 072A     9
# 016A     9
# 015A     7
# 095A     7
# 007A     6
# 108A     5
# 021A     5
# 003A     4
# 009A     4
# 053A     3
# 054A     2
# 052A     2
# 061A     2
# 102A     2
# 043A     1
# 092A     1
# 026B     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    232
# F    217
# M    213
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# M    73
# X    44
# F    14
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [006A, 000A, 033A, 001A, 103A, 071A, 097B, 028...
# kitten    [044A, 014B, 111A, 040A, 046A, 047A, 042A, 109...
# senior    [093A, 106A, 104A, 055A, 059A, 113A, 116A, 051...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [015A, 020A, 095A, 005A, 072A, 009A, 007A, 021...
# kitten                                               [043A]
# senior                 [097A, 057A, 054A, 016A, 108A, 061A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 60, 'kitten': 15, 'senior': 16}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 14, 'kitten': 1, 'senior': 6}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '004A' '006A' '008A' '010A' '011A'
#  '012A' '013B' '014A' '014B' '018A' '019A' '019B' '022A' '023A' '023B'
#  '024A' '025A' '025B' '025C' '026A' '026C' '027A' '028A' '029A' '031A'
#  '032A' '033A' '034A' '035A' '036A' '037A' '038A' '039A' '040A' '041A'
#  '042A' '044A' '045A' '046A' '047A' '048A' '049A' '050A' '051A' '051B'
#  '055A' '056A' '058A' '059A' '060A' '062A' '063A' '064A' '065A' '066A'
#  '067A' '068A' '069A' '070A' '071A' '073A' '074A' '075A' '076A' '087A'
#  '088A' '090A' '091A' '093A' '094A' '096A' '097B' '099A' '100A' '101A'
#  '103A' '104A' '105A' '106A' '109A' '110A' '111A' '113A' '115A' '116A'
#  '117A']
# Unique Test Group IDs:
# ['003A' '005A' '007A' '009A' '015A' '016A' '020A' '021A' '026B' '043A'
#  '052A' '053A' '054A' '057A' '061A' '072A' '092A' '095A' '097A' '102A'
#  '108A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '004A' '006A' '008A' '010A' '011A'
#  '012A' '013B' '014A' '014B' '018A' '019A' '019B' '022A' '023A' '023B'
#  '024A' '025A' '025B' '025C' '026A' '026C' '027A' '028A' '029A' '031A'
#  '032A' '033A' '034A' '035A' '036A' '037A' '038A' '039A' '040A' '041A'
#  '042A' '044A' '045A' '046A' '047A' '048A' '049A' '050A' '051A' '051B'
#  '055A' '056A' '058A' '059A' '060A' '062A' '063A' '064A' '065A' '066A'
#  '067A' '068A' '069A' '070A' '071A' '073A' '074A' '075A' '076A' '087A'
#  '088A' '090A' '091A' '093A' '094A' '096A' '097B' '099A' '100A' '101A'
#  '103A' '104A' '105A' '106A' '109A' '110A' '111A' '113A' '115A' '116A'
#  '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['003A' '005A' '007A' '009A' '015A' '016A' '020A' '021A' '026B' '043A'
#  '052A' '053A' '054A' '057A' '061A' '072A' '092A' '095A' '097A' '102A'
#  '108A']
# Length of X_train_val:
# 662
# Length of y_train_val:
# 662
# Length of groups_train_val:
# 662
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     429
# kitten    134
# senior     99
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     80
# senior    50
# kitten     1
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     429
# kitten    134
# senior     99
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     80
# senior    50
# kitten     1
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 429, 1: 134, 2: 99})
# Epoch 1/1500
# 11/11 [==============================] - 1s 5ms/step - loss: 0.9304 - accuracy: 0.6828
# Epoch 2/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.2884 - accuracy: 0.9124
# Epoch 3/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0910 - accuracy: 0.9743
# Epoch 4/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0571 - accuracy: 0.9804
# Epoch 5/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0449 - accuracy: 0.9834
# Epoch 6/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0140 - accuracy: 0.9985
# Epoch 7/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0155 - accuracy: 0.9955
# Epoch 8/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0128 - accuracy: 0.9970
# Epoch 9/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0128 - accuracy: 0.9955
# Epoch 10/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0118 - accuracy: 0.9955
# Epoch 11/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0170 - accuracy: 0.9940
# Epoch 12/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0059 - accuracy: 0.9985
# Epoch 13/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0239 - accuracy: 0.9940
# Epoch 14/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0329 - accuracy: 0.9955
# Epoch 15/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0279 - accuracy: 0.9940
# Epoch 16/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0110 - accuracy: 0.9970
# Epoch 17/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0054 - accuracy: 1.0000
# Epoch 18/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0071 - accuracy: 0.9985
# Epoch 19/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0051 - accuracy: 0.9985
# Epoch 20/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0064 - accuracy: 0.9970
# Epoch 21/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0278 - accuracy: 0.9894
# Epoch 22/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0051 - accuracy: 1.0000
# Epoch 23/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0089 - accuracy: 0.9955
# Epoch 24/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0088 - accuracy: 0.9985
# Epoch 25/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0066 - accuracy: 0.9985
# Epoch 26/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0047 - accuracy: 0.9985
# Epoch 27/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 28/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0106 - accuracy: 0.9985
# Epoch 29/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 30/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0055 - accuracy: 0.9985
# Epoch 31/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 32/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 33/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 34/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 35/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 36/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0063 - accuracy: 0.9970
# Epoch 37/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 38/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0115 - accuracy: 0.9985
# Epoch 39/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 40/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0043 - accuracy: 0.9985
# Epoch 41/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 42/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0054 - accuracy: 0.9985
# Epoch 43/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0071 - accuracy: 0.9985
# Epoch 44/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0060 - accuracy: 0.9985
# Epoch 45/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 46/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 47/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 48/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0076 - accuracy: 0.9955
# Epoch 49/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 50/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 4.9303e-04 - accuracy: 1.0000
# Epoch 51/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0038 - accuracy: 0.9985
# Epoch 52/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 53/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 54/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0104 - accuracy: 0.9955
# Epoch 55/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 56/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0204 - accuracy: 0.9970
# Epoch 57/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 58/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 9.1398e-04 - accuracy: 1.0000
# Epoch 59/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 8.1281e-04 - accuracy: 1.0000
# Epoch 60/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 8.6977e-04 - accuracy: 1.0000
# Epoch 61/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 62/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 7.8505e-04 - accuracy: 1.0000
# Epoch 63/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0038 - accuracy: 0.9985
# Epoch 64/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0077 - accuracy: 0.9985
# Epoch 65/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0077 - accuracy: 0.9985
# Epoch 66/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0023 - accuracy: 0.9985
# Epoch 67/1500
#  1/11 [=>............................] - ETA: 0s - loss: 1.3376e-04 - accuracy: 1.0000Restoring model weights from the end of the best epoch: 37.
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 67: early stopping
# 5/5 [==============================] - 0s 1ms/step - loss: 2.4685 - accuracy: 0.6412
# 5/5 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.71 (15/21)
# Before appending - Cat IDs: 586, Predictions: 586, Actuals: 586, Gender: 586
# After appending - Cat IDs: 717, Predictions: 717, Actuals: 717, Gender: 717
# Final Test Results - Loss: 2.468468189239502, Accuracy: 0.6412213444709778, Precision: 0.7398076662603277, Recall: 0.7116666666666666, F1 Score: 0.701609161721974
# Confusion Matrix:
#  [[70  0 10]
#  [ 0  1  0]
#  [37  0 13]]
#
# Final Average F1-Score across all UNSEEN TEST sets: 0.6188996609420991
#
# Final Average Loss across all UNSEEN TEST sets: 1.600322425365448
#
# Final Average Accuracy across all UNSEEN TEST sets: 0.7157200098037719
#
# Final Average Precision across all UNSEEN TEST sets: 0.6672646649782125
#
# Final Average Recall across all UNSEEN TEST sets: 0.6281088607534671

# %%
seed_4_folds_values = (unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1)

# Plotting all fold metrics
seed_4_folds_plot = plot_all_metrics(unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1, "Folds", "Fold Number")

# %% [markdown]
# ## Majority Voting on Total Entries per cat_id

# %%
# Debugging print statements
print(f'Checking - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
# Out:
# Checking - Cat IDs: 717, Predictions: 717, Actuals: 717, Gender: 717

# %%
# Create results df
full_results = pd.DataFrame({
    'cat_id': all_cat_ids,
    'predicted_age_group': all_predicted_age_groups,
    'actual_age_group': all_actual_age_groups,
    'all_gender': all_gender
})

# create a correct majority prediction column
full_results['correct'] = full_results['predicted_age_group'] == full_results['actual_age_group']

# %%
# Group by cat_id and aggregate predicted age groups
majority_votes = full_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first()

# Calculate the accuracy of majority voting
correct_predictions = (majority_votes == actual_groups).sum()
total_cats = len(actual_groups)
majority_vote_accuracy = correct_predictions / total_cats

logger(f"Overall Majority Vote Accuracy for cat_id: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

# store for final evaluation 
all_majority_vote_accuracies.append(majority_vote_accuracy)
# Out:
# Overall Majority Vote Accuracy for cat_id: 0.79 (87/110)

# %%
# Detailed df with predictions, actual labels, and comparison including majority vote
detailed_results = full_results.groupby('cat_id').apply(
    lambda x: pd.Series({
        'Predictions': list(x['predicted_age_group']),
        'Majority Vote': x['predicted_age_group'].mode()[0],
        'Actual Age Group': x['actual_age_group'].iloc[0],
        'Correct Majority Vote': x['predicted_age_group'].mode()[0] == x['actual_age_group'].iloc[0]
    })
).reset_index()

# Convert to DataFrame for better formatting and display
detailed_results = pd.DataFrame(detailed_results)

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 10)
pd.set_option('display.width', 1000)

sorted_detailed_results = detailed_results.sort_values(by='Correct Majority Vote', ascending=False)

# Display the sorted DataFrame
sorted_detailed_results
# Out:
#     cat_id                                        Predictions Majority Vote Actual Age Group  Correct Majority Vote
# 0     000B  [adult, senior, adult, adult, adult, adult, ad...         adult            adult                   True
# 66    060A                             [adult, senior, adult]         adult            adult                   True
# 77    071A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 76    070A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 75    069A                                    [senior, adult]         adult            adult                   True
# 74    068A  [adult, senior, adult, adult, senior, adult, a...         adult            adult                   True
# 73    067A  [adult, adult, kitten, kitten, adult, kitten, ...         adult            adult                   True
# 72    066A                                            [adult]         adult            adult                   True
# 71    065A  [senior, adult, adult, adult, adult, senior, a...         adult            adult                   True
# 69    063A  [adult, adult, senior, senior, senior, adult, ...         adult            adult                   True
# 68    062A                              [adult, adult, adult]         adult            adult                   True
# 64    058A                           [senior, senior, senior]        senior           senior                   True
# 79    073A                                            [adult]         adult            adult                   True
# 62    056A                            [senior, senior, adult]        senior           senior                   True
# 61    055A  [senior, senior, senior, senior, senior, senio...        senior           senior                   True
# 59    053A                              [adult, adult, adult]         adult            adult                   True
# 58    052A                                     [adult, adult]         adult            adult                   True
# 1     001A  [adult, senior, adult, senior, adult, adult, a...         adult            adult                   True
# 54    049A                                           [kitten]        kitten           kitten                   True
# 53    048A                                           [kitten]        kitten           kitten                   True
# 50    044A  [kitten, kitten, kitten, kitten, adult, kitten...        kitten           kitten                   True
# 49    043A                                           [kitten]        kitten           kitten                   True
# 78    072A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 80    074A  [adult, adult, senior, adult, adult, adult, ad...         adult            adult                   True
# 47    041A                                           [kitten]        kitten           kitten                   True
# 94    099A         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 107   115A                                           [kitten]        kitten           kitten                   True
# 105   111A  [adult, kitten, kitten, kitten, kitten, kitten...        kitten           kitten                   True
# 104   110A                                           [kitten]        kitten           kitten                   True
# 102   108A             [adult, senior, senior, senior, adult]        senior           senior                   True
# 100   105A                              [adult, adult, adult]         adult            adult                   True
# 98    103A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 97    102A                                     [adult, adult]         adult            adult                   True
# 96    101A  [adult, senior, adult, adult, senior, adult, a...         adult            adult                   True
# 95    100A                                            [adult]         adult            adult                   True
# 93    097B  [adult, adult, adult, adult, adult, adult, kit...         adult            adult                   True
# 81    075A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 91    096A                                            [adult]         adult            adult                   True
# 90    095A  [senior, adult, senior, adult, adult, adult, a...         adult            adult                   True
# 89    094A            [senior, adult, senior, senior, senior]        senior           senior                   True
# 87    092A                                            [adult]         adult            adult                   True
# 86    091A                                            [adult]         adult            adult                   True
# 85    090A                                           [senior]        senior           senior                   True
# 84    088A                                            [adult]         adult            adult                   True
# 83    087A                                     [adult, adult]         adult            adult                   True
# 82    076A                                            [adult]         adult            adult                   True
# 48    042A  [senior, adult, adult, kitten, adult, kitten, ...        kitten           kitten                   True
# 55    050A           [senior, kitten, kitten, kitten, kitten]        kitten           kitten                   True
# 46    040A  [kitten, kitten, kitten, kitten, kitten, kitte...        kitten           kitten                   True
# 14    013B  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 26    023B                       [adult, adult, adult, adult]         adult            adult                   True
# 25    023A        [adult, senior, adult, adult, adult, adult]         adult            adult                   True
# 45    039A         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 23    021A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 22    020A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 20    019A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 19    018A                                     [adult, adult]         adult            adult                   True
# 17    015A  [adult, adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 16    014B  [senior, kitten, adult, adult, kitten, kitten,...        kitten           kitten                   True
# 15    014A                              [adult, adult, adult]         adult            adult                   True
# 13    012A                              [adult, adult, adult]         adult            adult                   True
# 29    025B                                    [senior, adult]         adult            adult                   True
# 12    011A                                   [senior, senior]        senior           senior                   True
# 11    010A         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 10    009A                       [adult, adult, adult, adult]         adult            adult                   True
# 9     008A               [adult, adult, adult, kitten, adult]         adult            adult                   True
# 8     007A         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 7     006A                              [adult, adult, adult]         adult            adult                   True
# 5     004A                                            [adult]         adult            adult                   True
# 4     003A                       [adult, adult, adult, adult]         adult            adult                   True
# 3     002B  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 2     002A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 28    025A  [senior, adult, adult, adult, adult, adult, ad...         adult            adult                   True
# 24    022A  [adult, adult, kitten, kitten, adult, adult, k...         adult            adult                   True
# 30    025C                       [adult, adult, adult, adult]         adult            adult                   True
# 35    028A  [senior, adult, adult, senior, adult, adult, s...         adult            adult                   True
# 40    034A                             [adult, adult, kitten]         adult            adult                   True
# 39    033A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 31    026A                       [adult, adult, adult, adult]         adult            adult                   True
# 38    032A                                     [adult, adult]         adult            adult                   True
# 37    031A  [adult, adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 43    037A                                     [adult, adult]         adult            adult                   True
# 42    036A  [adult, adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 34    027A  [adult, adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 33    026C                                            [adult]         adult            adult                   True
# 44    038A                                    [kitten, adult]         adult            adult                   True
# 32    026B                                            [adult]         adult            adult                   True
# 51    045A                     [kitten, kitten, adult, adult]         adult           kitten                  False
# 52    047A  [adult, adult, adult, adult, adult, adult, adu...         adult           kitten                  False
# 41    035A                                   [senior, senior]        senior            adult                  False
# 106   113A                             [adult, adult, senior]         adult           senior                  False
# 101   106A  [adult, adult, adult, adult, senior, adult, ad...         adult           senior                  False
# 6     005A  [senior, senior, senior, senior, senior, senio...        senior            adult                  False
# 99    104A                       [adult, adult, adult, adult]         adult           senior                  False
# 108   116A  [senior, senior, adult, kitten, adult, adult, ...         adult           senior                  False
# 103   109A                [adult, adult, adult, adult, adult]         adult           kitten                  False
# 92    097A  [adult, senior, adult, adult, adult, senior, s...         adult           senior                  False
# 56    051A  [adult, adult, adult, adult, adult, senior, ad...         adult           senior                  False
# 57    051B  [adult, adult, adult, adult, adult, adult, adu...         adult           senior                  False
# 60    054A                                     [adult, adult]         adult           senior                  False
# 88    093A                                    [kitten, adult]         adult           senior                  False
# 63    057A  [adult, senior, adult, adult, adult, adult, ad...         adult           senior                  False
# 36    029A  [senior, senior, senior, adult, senior, adult,...        senior            adult                  False
# 18    016A  [adult, adult, adult, adult, senior, adult, ad...         adult           senior                  False
# 65    059A  [adult, adult, senior, senior, adult, adult, a...         adult           senior                  False
# 21    019B                                           [senior]        senior            adult                  False
# 67    061A                                    [adult, senior]         adult           senior                  False
# 70    064A                                           [kitten]        kitten            adult                  False
# 27    024A                                            [adult]         adult           senior                  False
# 109   117A  [adult, adult, adult, adult, adult, adult, adult]         adult           senior                  False

# %%
# Create df for majority votes
majority_df = majority_votes.reset_index()
majority_df.columns = ['cat_id', 'Majority_Vote']

# Get actual groups for each cat_id
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first().reset_index()

# Merge majority votes with actual groups
majority_with_actual = pd.merge(majority_df, actual_groups, on='cat_id')

# Add a column to check if the majority vote was correct
majority_with_actual['Majority_Correct'] = majority_with_actual['Majority_Vote'] == majority_with_actual['actual_age_group']

# Count correct majority votes per class
correct_majority_votes_per_class = majority_with_actual.groupby('actual_age_group')['Majority_Correct'].sum()

print("Correct Majority Votes per Class:")
print(correct_majority_votes_per_class)
# Out:
# Correct Majority Votes per Class:
# actual_age_group
# adult     68
# kitten    12
# senior     7
# Name: Majority_Correct, dtype: int64

# %%
# Calculate the total count and the number of correct predictions for each class
class_stats = majority_with_actual.groupby('actual_age_group').agg(
    total_count=('Majority_Correct', 'size'),  # Total number of cases per class
    correct_count=('Majority_Correct', 'sum')  # Sum of correct predictions per class
).reset_index()

# Calculate accuracy for each class
class_stats['accuracy'] = class_stats['correct_count'] / class_stats['total_count'] * 100

# store for final evaluation 
all_majority_vote_details.append(class_stats)

# Log detailed stats
print("Detailed Class Statistics for Majority Votes:")
print(class_stats)
# Out:
# Detailed Class Statistics for Majority Votes:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult           73             68  93.150685
# 1           kitten           15             12  80.000000
# 2           senior           22              7  31.818182

# %%
# Plot for Detailed Class Statistics for Majority Votes
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Accuracy of Majority Votes by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Detailed Class Statistics

# %%
# Calculate the total count and the number of correct predictions for each class
class_stats = full_results.groupby('actual_age_group').agg(
    total_count=('correct', 'size'),
    correct_count=('correct', 'sum')
).reset_index()

# Calculate accuracy for each class
class_stats['accuracy'] = class_stats['correct_count'] / class_stats['total_count'] * 100

# store for final evaluation 
all_class_stats.append(class_stats)

# Log the detailed stats
print("Detailed Class Statistics:")
print(class_stats)
# Out:
# Detailed Class Statistics:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult          473            406  85.835095
# 1           kitten           95             53  55.789474
# 2           senior          149             50  33.557047

# %%
# Plot for Detailed Class Statistics (Overall)
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Overall Accuracy by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Gender Exploration

# %%
# Group by gender and calculate the total count, correct predictions, and accuracy
gender_stats = full_results.groupby('all_gender').agg(
    count=('cat_id', 'size'),  # Total number of cases per gender
    correct=('correct', 'sum')  # Sum of correct predictions per gender
).reset_index()

# Calculate accuracy for each gender
gender_stats['accuracy'] = (gender_stats['correct'] / gender_stats['count'] * 100).round(2)

# Display the DataFrame
print("Accuracy by Gender:")
print(gender_stats)

# store for final evaluation 
all_gender_stats.append(gender_stats)
# Out:
# Accuracy by Gender:
#   all_gender  count  correct  accuracy
# 0          F    192      139     72.40
# 1          M    289      219     75.78
# 2          X    236      151     63.98

# %%
# Plot for Accuracy by Gender
styled_barplot(gender_stats, 'all_gender', 'accuracy', 
               'Accuracy by Gender', 
               'Gender', 'Accuracy (%)')

# %% [markdown]
# ### Log current total CV Stats

# %%
print("Total Majority Vote Accuracy so far:", all_majority_vote_accuracies)
print("Total Class Statistics so far:\n", all_class_stats)
print("Total Gender Accuracy so far:\n", all_gender_stats)
# Out:
# Total Majority Vote Accuracy so far: [0.7727272727272727, 0.7545454545454545, 0.7363636363636363, 0.7909090909090909]
# Total Class Statistics so far:
#  [  actual_age_group  total_count  correct_count   accuracy
# 0            adult          472            410  86.864407
# 1           kitten           95             51  53.684211
# 2           senior          149             39  26.174497,   actual_age_group  total_count  correct_count   accuracy
# 0            adult          476            398  83.613445
# 1           kitten          112             45  40.178571
# 2           senior          149             39  26.174497,   actual_age_group  total_count  correct_count   accuracy
# 0            adult          489            430  87.934560
# 1           kitten          112             49  43.750000
# 2           senior          149             56  37.583893,   actual_age_group  total_count  correct_count   accuracy
# 0            adult          473            406  85.835095
# 1           kitten           95             53  55.789474
# 2           senior          149             50  33.557047]
# Total Gender Accuracy so far:
#  [  all_gender  count  correct  accuracy
# 0          F    194      148     76.29
# 1          M    286      206     72.03
# 2          X    236      146     61.86,   all_gender  count  correct  accuracy
# 0          F    198      132     66.67
# 1          M    286      204     71.33
# 2          X    253      146     57.71,   all_gender  count  correct  accuracy
# 0          F    211      163     77.25
# 1          M    286      211     73.78
# 2          X    253      161     63.64,   all_gender  count  correct  accuracy
# 0          F    192      139     72.40
# 1          M    289      219     75.78
# 2          X    236      151     63.98]

# %% [markdown]
# # RANDOM SEED 5

# %%
# Set a fixed random seed for reproducibility
random.seed(int(random_seeds[4]))
np.random.seed(int(random_seeds[4]))
tf.random.set_seed(int(random_seeds[4]))

# Load datasets
dataframe = pd.read_csv('/Users/astrid/PycharmProjects/perch-2/scripts/perch_embeddings_april_10.csv')
dataframe.drop('mean_freq', axis=1, inplace=True)

def assign_age_group(age, age_groups):
    for group_name, age_range in age_groups.items():
        if age_range[0] <= age < age_range[1]:
            return group_name
    return 'Unknown'  # For any age that doesn't fit the defined groups

# Define age groups
age_groups = {
    'kitten': (0, 0.5),
    'adult': (0.5, 12),
    'senior': (12, 20)
}

# Create a new column for the age group
dataframe['age_group'] = dataframe['target'].apply(assign_age_group, age_groups=age_groups)

print(dataframe['age_group'].value_counts())
# Out:
# adult     509
# senior    149
# kitten    135
# Name: age_group, dtype: int64

# %%
# Separate features and labels
X = dataframe.iloc[:, :-4].values  # all columns except the last four

# Encode the 'age_group' column as integers using LabelEncoder
label_encoder = LabelEncoder()
encoded_y = label_encoder.fit_transform(dataframe['age_group'].values)

# Use the encoded labels for splitting and one-hot encoding
y = encoded_y  

# Convert 'cat_id' column to numpy array to be used as groups array for GroupKFold
groups = dataframe['cat_id'].values

# %%
tf.keras.backend.clear_session()

# %% [markdown]
# ## Run Setup

# %%
all_cat_ids = []
all_predicted_age_groups = []
all_actual_age_groups = []
all_gender = []

# Define the StratifiedGroupKFold splitter for 4 fold CV with random shuffling
outer_cv = StratifiedGroupKFold(n_splits=5, shuffle=True, random_state=int(random_seeds[4]))

# unseen test set metrics
unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1 = [], [], [], [], []

outer_fold = 0

# Use the splitter to generate indices for training and testing sets
# Note: GroupShuffleSplit.split returns indices, so we use it to index the arrays
for train_val_idx, test_idx in outer_cv.split(X, y, groups):
    outer_fold += 1
    logger(f"outer_fold {outer_fold}", file=log_file_path)

    # Convert indices back to DataFrame for easy manipulation
    df_train_val = dataframe.iloc[train_val_idx]
    df_test = dataframe.iloc[test_idx]

    ##############################
    # ASSESSING SPLITS BY CAT_ID #
    ##############################
    
    # Get the distribution of groups
    training_validation_group_distribution = df_train_val['cat_id'].value_counts()  
    testing_group_distribution = df_test['cat_id'].value_counts()  
    
    # Log or print the distribution
    logger(f"Train Set Group Distribution:\n{training_validation_group_distribution}", file=log_file_path)
    logger(f"Testing Set Group Distribution:\n{testing_group_distribution}", file=log_file_path)

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val['gender'].value_counts()
    testing_gender_distribution = df_test['gender'].value_counts()
    
    # Log the distribution
    logger(f"Training Set Gender Distribution BEFORE SWAP:\n{training_gender_distribution}", file=log_file_path)
    logger(f"Testing Set Gender Distribution BEFORE SWAP:\n{testing_gender_distribution}", file=log_file_path)

    # Group by 'age_group' and then list unique 'cat_id' within each age group
    unique_cat_ids_per_age_group_train_val = df_train_val.groupby('age_group')['cat_id'].unique()
    unique_cat_ids_per_age_group_test = df_test.groupby('age_group')['cat_id'].unique()
    
    # Log results
    logger(f"Unique Cat IDs per Age Group in Training/Validation Set:\n{unique_cat_ids_per_age_group_train_val}", file=log_file_path)
    logger(f"Unique Cat IDs per Age Group in Testing Set:\n{unique_cat_ids_per_age_group_test}", file=log_file_path)

    # Calculate the count of unique identifiers per age group for training and testing set
    counts_train_val = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_train_val.items()}
    counts_test = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_test.items()}

    # Log the counts of unique identifiers per age group
    logger(f"Count of Unique Cat IDs per Age Group in Training/Validation Set:\n{counts_train_val}", file=log_file_path)
    logger(f"Count of Unique Cat IDs per Age Group in Testing Set:\n{counts_test}", file=log_file_path)

    #######################################################
    # CONTINUE WITH ENSURING VALID AND APPROPRIATE SPLITS #
    #######################################################
    
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    groups_train_val, groups_test = groups[train_val_idx], groups[test_idx]

    # logging identifier splits 
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)

    # check group splits
    check_initial_group_split(groups_train_val, groups_test)

    # Specify the cat_ids that must be in the training/validation set
    specific_cat_ids = ['000A', '046A']
    
    # Perform the swapping operation
    train_val_idx, test_idx = swap_cat_id_instances(dataframe, train_val_idx, test_idx, specific_cat_ids)
    
    # Re-assign the sets based on the updated indices
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    new_groups_train_val, new_groups_test = groups[train_val_idx], groups[test_idx]

    # Find differences for training and test sets
    moved_to_train_val, removed_from_train_val = find_group_differences(groups_train_val, new_groups_train_val)
    moved_to_test, removed_from_test = find_group_differences(groups_test, new_groups_test)
    
    # Display the results
    logger(f"Moved to Training/Validation Set:\n{moved_to_train_val}", file=log_file_path)
    logger(f"Removed from Training/Validation Set:\n{removed_from_train_val}", file=log_file_path)
    logger(f"Moved to Test Set:\n{moved_to_test}", file=log_file_path)
    logger(f"Removed from Test Set\n{removed_from_test}", file=log_file_path)

    # Update X_train_val, X_test, y_train_val, y_test, groups_train_val, groups_test based on updated indices
    X_train_val = X[train_val_idx]
    y_train_val = y[train_val_idx]
    groups_train_val = groups[train_val_idx]
    
    X_test = X[test_idx]
    y_test = y[test_idx]
    groups_test = groups[test_idx]

    # logging identifier splits again after potential swaps
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"AFTER SWAP - Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"AFTER SWAP - Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)
    
    # Verify the lengths are consistent
    logger(f"Length of X_train_val:\n{len(X_train_val)}", file=log_file_path)
    logger(f"Length of y_train_val:\n{len(y_train_val)}", file=log_file_path)
    logger(f"Length of groups_train_val:\n{len(groups_train_val)}", file=log_file_path)

    # Check group splits once more
    check_initial_group_split(groups_train_val, groups_test)

    # Convert the modified indices back to a DataFrame representing the updated df_train_val
    df_train_val_updated = dataframe.iloc[train_val_idx].copy()
    df_test_updated = dataframe.iloc[test_idx].copy()

    ############################
    # LOGGING AGE GROUP SPLITS #
    ############################

    # Get the distribution of age groups of age groups before the update
    training_validation_age_group_distribution = df_train_val['age_group'].value_counts()
    testing_age_group_distribution = df_test['age_group'].value_counts()
    
    # Logthe distribution
    logger(f"Train Age Group Distribution BEFORE SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution BEFORE SWAP:\n{testing_age_group_distribution}", file=log_file_path)

    # Get the distribution of age groups after the update
    training_validation_age_group_distribution = df_train_val_updated['age_group'].value_counts()
    testing_age_group_distribution = df_test_updated['age_group'].value_counts()
    
    # Log the distribution
    logger(f"Train Age Group Distribution AFTER SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution AFTER SWAP:\n{testing_age_group_distribution}", file=log_file_path)
    
    ########################################################
    # TRACKING FINAL CAT_IDs & GENDER AFTER REDISTRIBUTION #
    ########################################################

    # Get the distribution of groups
    training_validation_group_distribution = df_train_val_updated['cat_id'].value_counts()  
    testing_group_distribution = df_test_updated['cat_id'].value_counts()  

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val_updated['gender'].value_counts()
    testing_gender_distribution = df_test_updated['gender'].value_counts()
    
    logger(f"\n Starting training on unseen test set\n", file=log_file_path)

    ###################
    # PREPARING MODEL #
    ###################

    # Calculate the distribution of age groups in y_train_val
    age_group_distribution = Counter(y_train_val)
    print("Age group distribution:", age_group_distribution)

    # EarlyStopping callback: monitor 'loss' instead of 'val_loss' for the test set
    early_stopping = EarlyStopping(
        monitor='loss',  
        min_delta=0.001, 
        patience=30,  
        verbose=1,  
        restore_best_weights=True  
    )

    # One final shuffle to ensure randomness
    outer_shuffle_idx = np.random.permutation(len(X_train_val))
    X_train_val = X_train_val[outer_shuffle_idx]
    y_train_val = y_train_val[outer_shuffle_idx]
    
    # Scale the features
    scaler_full = StandardScaler().fit(X_train_val)
    X_train_full_scaled = scaler_full.transform(X_train_val)
    X_test_scaled = scaler_full.transform(X_test)
    
    # Encode the labels
    y_train_full_encoded = to_categorical(y_train_val)
    y_test_encoded = to_categorical(y_test)

    #######################
    # BUILD & TRAIN MODEL #
    #######################

    optimizers = {
        'Adamax': Adamax(learning_rate=0.00510251984616472)
    }
    
    # Model definition with dynamic number of layers
    model_full = Sequential()
    model_full.add(Dense(480, activation='relu', input_shape=(X_train_full_scaled.shape[1],)))
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.2011047009431978))  
    model_full.add(Dense(256, activation='relu',)) 
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.14956886311951184))  
    model_full.add(Dense(256, activation='relu'))  
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.42291461228250665))  
    model_full.add(Dense(3, activation='softmax'))  
    
    # Use the optimizer from the parameters
    optimizer = optimizers['Adamax']  # optimizer_key from parameters
    
    # Compile the model
    model_full.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    
    # Train the model on the full training set
    history_full = model_full.fit(X_train_full_scaled, y_train_full_encoded, epochs=1500, batch_size=64,
                                  verbose=1, callbacks=[early_stopping])
    
    # Evaluate the model on the held-out test set
    test_loss, test_accuracy = model_full.evaluate(X_test_scaled, y_test_encoded)

    y_test_pred_prob = model_full.predict(X_test_scaled)
    y_test_pred = np.argmax(y_test_pred_prob, axis=1)  
    y_test_true = np.argmax(y_test_encoded, axis=1)    

    ################################
    # LOG MAJORITY VOTE PER CAT_ID #
    ################################

    # Convert numeric predictions back to age group labels
    predicted_age_groups = label_encoder.inverse_transform(y_test_pred)
    actual_labels = label_encoder.inverse_transform(y_test_true)
    
    # Map predictions and actual labels back to cat_ids
    test_results = pd.DataFrame({
        'cat_id': df_test_updated['cat_id'],
        'predicted_age_group': predicted_age_groups,
        'actual_age_group': actual_labels
    })
    
    # Group by cat_id and aggregate predicted age groups
    majority_votes = test_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
    actual_groups = test_results.groupby('cat_id')['actual_age_group'].first()
    
    # Calculate the accuracy of majority voting
    correct_predictions = (majority_votes == actual_groups).sum()
    total_cats = len(actual_groups)
    majority_vote_accuracy = correct_predictions / total_cats
    
    # Log the accuracy of the majority voting
    logger(f"Majority Vote Accuracy for cat_id for this fold: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

    ####################################################
    # COLLECT PREDICTIONS FOR GENDER & CAT_ID ANALYSIS #
    ####################################################

    # Debugging print statements
    print(f'Before appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Extend lists with current fold results
    all_cat_ids.extend(df_test_updated['cat_id'].tolist())
    all_predicted_age_groups.extend(predicted_age_groups)
    all_actual_age_groups.extend(actual_labels)
    all_gender.extend(df_test_updated['gender'].tolist())

    # Debugging print statements
    print(f'After appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Calculate additional metrics
    test_precision = precision_score(y_test_true, y_test_pred, average='macro')  # Use 'macro' for imbalanced datasets
    test_recall = recall_score(y_test_true, y_test_pred, average='macro')
    test_f1 = f1_score(y_test_true, y_test_pred, average='macro')

    # prepare averages of outer metrics
    unseen_f1.append(test_f1)
    unseen_losses.append(test_loss)
    unseen_accuracies.append(test_accuracy)
    unseen_precisions.append(test_precision)
    unseen_recalls.append(test_recall)

    # Print final test results
    logger(f"Final Test Results - Loss: {test_loss}, Accuracy: {test_accuracy}, Precision: {test_precision}, Recall: {test_recall}, F1 Score: {test_f1}", file=log_file_path)

    # Generate the confusion matrix
    cm = confusion_matrix(y_test, y_test_pred)
    logger(f"Confusion Matrix:\n {cm}", file=log_file_path)

# Calculate the overall average metrics
unseen_set_avg_f1 = np.mean(unseen_f1)
unseen_set_avg_loss = np.mean(unseen_losses)
unseen_set_avg_acc = np.mean(unseen_accuracies)
unseen_set_avg_precision = np.mean(unseen_precisions)
unseen_set_avg_recall = np.mean(unseen_recalls)

logger(f"\nFinal Average F1-Score across all UNSEEN TEST sets: {unseen_set_avg_f1}", file=log_file_path)
logger(f"\nFinal Average Loss across all UNSEEN TEST sets: {unseen_set_avg_loss}", file=log_file_path)
logger(f"\nFinal Average Accuracy across all UNSEEN TEST sets: {unseen_set_avg_acc}", file=log_file_path)
logger(f"\nFinal Average Precision across all UNSEEN TEST sets: {unseen_set_avg_precision}", file=log_file_path)
logger(f"\nFinal Average Recall across all UNSEEN TEST sets: {unseen_set_avg_recall}\n", file=log_file_path)

# Append averages to total lists
all_f1.append(unseen_set_avg_f1)
all_losses.append(unseen_set_avg_loss)
all_accuracies.append(unseen_set_avg_acc)
all_precisions.append(unseen_set_avg_precision)
all_recalls.append(unseen_set_avg_recall)
# Out:
# outer_fold 1
# Train Set Group Distribution:
# 046A    45
# 000A    39
# 103A    33
# 002B    30
# 047A    22
# 020A    20
# 000B    19
# 057A    17
# 019A    17
# 074A    16
# 029A    15
# 097A    15
# 106A    13
# 055A    12
# 116A    12
# 051A    12
# 111A    12
# 067A    11
# 028A    11
# 042A    11
# 040A    10
# 014B    10
# 022A     9
# 001A     9
# 071A     9
# 033A     9
# 005A     9
# 016A     9
# 072A     9
# 065A     9
# 051B     9
# 013B     8
# 068A     8
# 027A     7
# 031A     7
# 036A     7
# 117A     7
# 015A     7
# 095A     7
# 023A     6
# 039A     6
# 099A     6
# 007A     6
# 109A     5
# 050A     5
# 021A     5
# 108A     5
# 094A     5
# 025C     4
# 009A     4
# 023B     4
# 104A     4
# 045A     4
# 003A     4
# 010A     3
# 058A     3
# 056A     3
# 060A     3
# 012A     3
# 053A     3
# 006A     3
# 105A     3
# 034A     3
# 062A     3
# 113A     3
# 014A     3
# 052A     2
# 061A     2
# 054A     2
# 032A     2
# 069A     2
# 087A     2
# 038A     2
# 025B     2
# 102A     2
# 110A     1
# 115A     1
# 004A     1
# 100A     1
# 090A     1
# 019B     1
# 026C     1
# 066A     1
# 091A     1
# 096A     1
# 041A     1
# 092A     1
# 049A     1
# 073A     1
# 043A     1
# 076A     1
# 024A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 097B    14
# 002A    13
# 101A    12
# 063A    11
# 059A    10
# 025A    10
# 044A     5
# 070A     5
# 075A     5
# 008A     5
# 026A     4
# 035A     2
# 037A     2
# 011A     2
# 018A     2
# 093A     2
# 048A     1
# 064A     1
# 088A     1
# 026B     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    262
# X    238
# F    185
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# F    46
# X    38
# M    24
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [006A, 000A, 033A, 015A, 001A, 103A, 071A, 028...
# kitten    [014B, 111A, 040A, 046A, 047A, 042A, 109A, 050...
# senior    [097A, 057A, 106A, 104A, 055A, 113A, 116A, 051...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [097B, 101A, 002A, 063A, 025A, 070A, 026A, 018...
# kitten                                         [044A, 048A]
# senior                                   [093A, 059A, 011A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 59, 'kitten': 14, 'senior': 19}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 15, 'kitten': 2, 'senior': 3}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002B' '003A' '004A' '005A' '006A' '007A' '009A'
#  '010A' '012A' '013B' '014A' '014B' '015A' '016A' '019A' '019B' '020A'
#  '021A' '022A' '023A' '023B' '024A' '025B' '025C' '026C' '027A' '028A'
#  '029A' '031A' '032A' '033A' '034A' '036A' '038A' '039A' '040A' '041A'
#  '042A' '043A' '045A' '046A' '047A' '049A' '050A' '051A' '051B' '052A'
#  '053A' '054A' '055A' '056A' '057A' '058A' '060A' '061A' '062A' '065A'
#  '066A' '067A' '068A' '069A' '071A' '072A' '073A' '074A' '076A' '087A'
#  '090A' '091A' '092A' '094A' '095A' '096A' '097A' '099A' '100A' '102A'
#  '103A' '104A' '105A' '106A' '108A' '109A' '110A' '111A' '113A' '115A'
#  '116A' '117A']
# Unique Test Group IDs:
# ['002A' '008A' '011A' '018A' '025A' '026A' '026B' '035A' '037A' '044A'
#  '048A' '059A' '063A' '064A' '070A' '075A' '088A' '093A' '097B' '101A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002B' '003A' '004A' '005A' '006A' '007A' '009A'
#  '010A' '012A' '013B' '014A' '014B' '015A' '016A' '019A' '019B' '020A'
#  '021A' '022A' '023A' '023B' '024A' '025B' '025C' '026C' '027A' '028A'
#  '029A' '031A' '032A' '033A' '034A' '036A' '038A' '039A' '040A' '041A'
#  '042A' '043A' '045A' '046A' '047A' '049A' '050A' '051A' '051B' '052A'
#  '053A' '054A' '055A' '056A' '057A' '058A' '060A' '061A' '062A' '065A'
#  '066A' '067A' '068A' '069A' '071A' '072A' '073A' '074A' '076A' '087A'
#  '090A' '091A' '092A' '094A' '095A' '096A' '097A' '099A' '100A' '102A'
#  '103A' '104A' '105A' '106A' '108A' '109A' '110A' '111A' '113A' '115A'
#  '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['002A' '008A' '011A' '018A' '025A' '026A' '026B' '035A' '037A' '044A'
#  '048A' '059A' '063A' '064A' '070A' '075A' '088A' '093A' '097B' '101A']
# Length of X_train_val:
# 685
# Length of y_train_val:
# 685
# Length of groups_train_val:
# 685
# No common groups found between train and test sets.
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Train Age Group Distribution BEFORE SWAP:
# adult     421
# senior    135
# kitten    129
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     88
# senior    14
# kitten     6
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     421
# senior    135
# kitten    129
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     88
# senior    14
# kitten     6
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 421, 2: 135, 1: 129})
# Epoch 1/1500
# 11/11 [==============================] - 1s 5ms/step - loss: 1.0018 - accuracy: 0.6657
# Epoch 2/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.3390 - accuracy: 0.8803
# Epoch 3/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.1344 - accuracy: 0.9518
# Epoch 4/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0762 - accuracy: 0.9737
# Epoch 5/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0545 - accuracy: 0.9810
# Epoch 6/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0259 - accuracy: 0.9942
# Epoch 7/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0218 - accuracy: 0.9971
# Epoch 8/1500
# 11/11 [==============================] - 0s 18ms/step - loss: 0.0090 - accuracy: 1.0000
# Epoch 9/1500
# 11/11 [==============================] - 0s 16ms/step - loss: 0.0161 - accuracy: 0.9956
# Epoch 10/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0105 - accuracy: 1.0000
# Epoch 11/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0089 - accuracy: 1.0000
# Epoch 12/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0187 - accuracy: 0.9956
# Epoch 13/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0162 - accuracy: 0.9971
# Epoch 14/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0100 - accuracy: 0.9971
# Epoch 15/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0200 - accuracy: 0.9942
# Epoch 16/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0073 - accuracy: 0.9985
# Epoch 17/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0045 - accuracy: 1.0000
# Epoch 18/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0086 - accuracy: 0.9971
# Epoch 19/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 20/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0051 - accuracy: 0.9985
# Epoch 21/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0042 - accuracy: 0.9985
# Epoch 22/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 23/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 24/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 25/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 26/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 27/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 28/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 29/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0028 - accuracy: 0.9985
# Epoch 30/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0036 - accuracy: 0.9985
# Epoch 31/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 32/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 33/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 34/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 9.9346e-04 - accuracy: 1.0000
# Epoch 35/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 9.9424e-04 - accuracy: 1.0000
# Epoch 36/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 37/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 38/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 39/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 7.9367e-04 - accuracy: 1.0000
# Epoch 40/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 41/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 5.5407e-04 - accuracy: 1.0000
# Epoch 42/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 43/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 44/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 45/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 46/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0031 - accuracy: 0.9985
# Epoch 47/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 48/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 8.1105e-04 - accuracy: 1.0000
# Epoch 49/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 50/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 8.8859e-04 - accuracy: 1.0000
# Epoch 51/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 52/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 8.4479e-04 - accuracy: 1.0000
# Epoch 53/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 54/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 6.5211e-04 - accuracy: 1.0000
# Epoch 55/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 8.1164e-04 - accuracy: 1.0000
# Epoch 56/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 8.8764e-04 - accuracy: 1.0000
# Epoch 57/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 5.0006e-04 - accuracy: 1.0000
# Epoch 58/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 5.8527e-04 - accuracy: 1.0000
# Epoch 59/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 7.4807e-04 - accuracy: 1.0000
# Epoch 60/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 8.7427e-04 - accuracy: 1.0000
# Epoch 61/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 9.9305e-04 - accuracy: 1.0000
# Epoch 62/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0052 - accuracy: 0.9985
# Epoch 63/1500
#  8/11 [====================>.........] - ETA: 0s - loss: 0.0027 - accuracy: 0.9980    Restoring model weights from the end of the best epoch: 33.
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0022 - accuracy: 0.9985
# Epoch 63: early stopping
# 4/4 [==============================] - 0s 1ms/step - loss: 0.3931 - accuracy: 0.8889
# 4/4 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.85 (17/20)
# Before appending - Cat IDs: 0, Predictions: 0, Actuals: 0, Gender: 0
# After appending - Cat IDs: 108, Predictions: 108, Actuals: 108, Gender: 108
# Final Test Results - Loss: 0.39310669898986816, Accuracy: 0.8888888955116272, Precision: 0.757748538011696, Recall: 0.9145021645021645, F1 Score: 0.8186147186147187
# Confusion Matrix:
#  [[78  3  7]
#  [ 0  6  0]
#  [ 2  0 12]]
# outer_fold 2
# Train Set Group Distribution:
# 046A    45
# 103A    33
# 002B    30
# 020A    20
# 000B    19
# 057A    17
# 019A    17
# 074A    16
# 029A    15
# 097A    15
# 097B    14
# 106A    13
# 002A    13
# 055A    12
# 101A    12
# 116A    12
# 067A    11
# 042A    11
# 063A    11
# 028A    11
# 025A    10
# 059A    10
# 040A    10
# 016A     9
# 065A     9
# 072A     9
# 005A     9
# 051B     9
# 022A     9
# 001A     9
# 071A     9
# 068A     8
# 013B     8
# 095A     7
# 027A     7
# 117A     7
# 031A     7
# 036A     7
# 023A     6
# 099A     6
# 044A     5
# 075A     5
# 008A     5
# 108A     5
# 094A     5
# 109A     5
# 070A     5
# 025C     4
# 026A     4
# 023B     4
# 014A     3
# 034A     3
# 012A     3
# 053A     3
# 056A     3
# 010A     3
# 062A     3
# 105A     3
# 113A     3
# 060A     3
# 037A     2
# 035A     2
# 102A     2
# 052A     2
# 054A     2
# 061A     2
# 093A     2
# 038A     2
# 087A     2
# 018A     2
# 011A     2
# 115A     1
# 088A     1
# 100A     1
# 090A     1
# 024A     1
# 019B     1
# 041A     1
# 048A     1
# 066A     1
# 026C     1
# 049A     1
# 091A     1
# 064A     1
# 073A     1
# 043A     1
# 096A     1
# 026B     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 000A    39
# 047A    22
# 111A    12
# 051A    12
# 014B    10
# 033A     9
# 015A     7
# 039A     6
# 007A     6
# 021A     5
# 050A     5
# 104A     4
# 009A     4
# 045A     4
# 003A     4
# 058A     3
# 006A     3
# 025B     2
# 032A     2
# 069A     2
# 092A     1
# 076A     1
# 004A     1
# 110A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    250
# X    209
# F    169
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    67
# F    62
# M    36
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [001A, 103A, 071A, 097B, 028A, 019A, 074A, 067...
# kitten    [044A, 040A, 046A, 042A, 109A, 043A, 049A, 041...
# senior    [093A, 097A, 057A, 106A, 055A, 059A, 113A, 116...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [006A, 000A, 033A, 015A, 039A, 009A, 007A, 069...
# kitten                 [014B, 111A, 047A, 050A, 045A, 110A]
# senior                                   [104A, 051A, 058A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 59, 'kitten': 10, 'senior': 19}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 15, 'kitten': 6, 'senior': 3}
# Unique Training/Validation Group IDs:
# ['000B' '001A' '002A' '002B' '005A' '008A' '010A' '011A' '012A' '013B'
#  '014A' '016A' '018A' '019A' '019B' '020A' '022A' '023A' '023B' '024A'
#  '025A' '025C' '026A' '026B' '026C' '027A' '028A' '029A' '031A' '034A'
#  '035A' '036A' '037A' '038A' '040A' '041A' '042A' '043A' '044A' '046A'
#  '048A' '049A' '051B' '052A' '053A' '054A' '055A' '056A' '057A' '059A'
#  '060A' '061A' '062A' '063A' '064A' '065A' '066A' '067A' '068A' '070A'
#  '071A' '072A' '073A' '074A' '075A' '087A' '088A' '090A' '091A' '093A'
#  '094A' '095A' '096A' '097A' '097B' '099A' '100A' '101A' '102A' '103A'
#  '105A' '106A' '108A' '109A' '113A' '115A' '116A' '117A']
# Unique Test Group IDs:
# ['000A' '003A' '004A' '006A' '007A' '009A' '014B' '015A' '021A' '025B'
#  '032A' '033A' '039A' '045A' '047A' '050A' '051A' '058A' '069A' '076A'
#  '092A' '104A' '110A' '111A']
# No common groups found between train and test sets.
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Moved to Training/Validation Set:
# {'000A'}
# Removed from Training/Validation Set:
# {'088A'}
# Moved to Test Set:
# {'088A'}
# Removed from Test Set
# {'000A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '005A' '008A' '010A' '011A' '012A'
#  '013B' '014A' '016A' '018A' '019A' '019B' '020A' '022A' '023A' '023B'
#  '024A' '025A' '025C' '026A' '026B' '026C' '027A' '028A' '029A' '031A'
#  '034A' '035A' '036A' '037A' '038A' '040A' '041A' '042A' '043A' '044A'
#  '046A' '048A' '049A' '051B' '052A' '053A' '054A' '055A' '056A' '057A'
#  '059A' '060A' '061A' '062A' '063A' '064A' '065A' '066A' '067A' '068A'
#  '070A' '071A' '072A' '073A' '074A' '075A' '087A' '090A' '091A' '093A'
#  '094A' '095A' '096A' '097A' '097B' '099A' '100A' '101A' '102A' '103A'
#  '105A' '106A' '108A' '109A' '113A' '115A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['003A' '004A' '006A' '007A' '009A' '014B' '015A' '021A' '025B' '032A'
#  '033A' '039A' '045A' '047A' '050A' '051A' '058A' '069A' '076A' '088A'
#  '092A' '104A' '110A' '111A']
# Length of X_train_val:
# 666
# Length of y_train_val:
# 666
# Length of groups_train_val:
# 666
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     417
# senior    130
# kitten     81
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     92
# kitten    54
# senior    19
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     455
# senior    130
# kitten     81
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     54
# kitten    54
# senior    19
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 455, 2: 130, 1: 81})
# Epoch 1/1500
# 11/11 [==============================] - 1s 4ms/step - loss: 1.0545 - accuracy: 0.6411
# Epoch 2/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.2648 - accuracy: 0.9069
# Epoch 3/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.1223 - accuracy: 0.9535
# Epoch 4/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0718 - accuracy: 0.9775
# Epoch 5/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0550 - accuracy: 0.9850
# Epoch 6/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0299 - accuracy: 0.9940
# Epoch 7/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0311 - accuracy: 0.9940
# Epoch 8/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0165 - accuracy: 0.9970
# Epoch 9/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0211 - accuracy: 0.9940
# Epoch 10/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0203 - accuracy: 0.9940
# Epoch 11/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0101 - accuracy: 0.9985
# Epoch 12/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0160 - accuracy: 0.9970
# Epoch 13/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0076 - accuracy: 0.9985
# Epoch 14/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0076 - accuracy: 1.0000
# Epoch 15/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0066 - accuracy: 1.0000
# Epoch 16/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0074 - accuracy: 1.0000
# Epoch 17/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 18/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0065 - accuracy: 1.0000
# Epoch 19/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 20/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 21/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0038 - accuracy: 0.9985
# Epoch 22/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 23/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 24/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0102 - accuracy: 0.9985
# Epoch 25/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0071 - accuracy: 0.9985
# Epoch 26/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0086 - accuracy: 0.9985
# Epoch 27/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0054 - accuracy: 0.9985
# Epoch 28/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 29/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0045 - accuracy: 0.9985
# Epoch 30/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 31/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 32/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0054 - accuracy: 1.0000
# Epoch 33/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0037 - accuracy: 0.9985
# Epoch 34/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 35/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 36/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 37/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0130 - accuracy: 0.9985
# Epoch 38/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 39/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0108 - accuracy: 0.9970
# Epoch 40/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 41/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0070 - accuracy: 0.9985
# Epoch 42/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0063 - accuracy: 0.9985
# Epoch 43/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 44/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 45/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 46/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 47/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 9.4493e-04 - accuracy: 1.0000
# Epoch 48/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 49/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 50/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 51/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 52/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 53/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 54/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 7.2735e-04 - accuracy: 1.0000
# Epoch 55/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 8.7230e-04 - accuracy: 1.0000
# Epoch 56/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0036 - accuracy: 0.9985
# Epoch 57/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 58/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0066 - accuracy: 0.9985
# Epoch 59/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0024 - accuracy: 0.9985
# Epoch 60/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 61/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 6.3774e-04 - accuracy: 1.0000
# Epoch 62/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 8.3446e-04 - accuracy: 1.0000
# Epoch 63/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 7.6593e-04 - accuracy: 1.0000
# Epoch 64/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 65/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 6.4814e-04 - accuracy: 1.0000
# Epoch 66/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 67/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 9.5824e-04 - accuracy: 1.0000
# Epoch 68/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 69/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 2.5271e-04 - accuracy: 1.0000
# Epoch 70/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0030 - accuracy: 0.9985
# Epoch 71/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 5.6558e-04 - accuracy: 1.0000
# Epoch 72/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 6.8692e-04 - accuracy: 1.0000
# Epoch 73/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 5.3640e-04 - accuracy: 1.0000
# Epoch 74/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 8.7463e-04 - accuracy: 1.0000
# Epoch 75/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 76/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 8.5475e-04 - accuracy: 1.0000
# Epoch 77/1500
#  1/11 [=>............................] - ETA: 0s - loss: 3.0458e-04 - accuracy: 1.0000Restoring model weights from the end of the best epoch: 47.
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 77: early stopping
# 4/4 [==============================] - 0s 2ms/step - loss: 2.3336 - accuracy: 0.5984
# 4/4 [==============================] - 0s 2ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.75 (18/24)
# Before appending - Cat IDs: 108, Predictions: 108, Actuals: 108, Gender: 108
# After appending - Cat IDs: 235, Predictions: 235, Actuals: 235, Gender: 235
# Final Test Results - Loss: 2.3336358070373535, Accuracy: 0.5984252095222473, Precision: 0.5878950798305637, Recall: 0.5032488628979858, F1 Score: 0.4845543197471405
# Confusion Matrix:
#  [[52  1  1]
#  [25 21  8]
#  [16  0  3]]
# outer_fold 3
# Train Set Group Distribution:
# 046A    45
# 000A    39
# 103A    33
# 002B    30
# 047A    22
# 020A    20
# 057A    17
# 097A    15
# 029A    15
# 097B    14
# 002A    13
# 106A    13
# 051A    12
# 101A    12
# 055A    12
# 111A    12
# 116A    12
# 042A    11
# 063A    11
# 067A    11
# 059A    10
# 025A    10
# 014B    10
# 065A     9
# 022A     9
# 071A     9
# 001A     9
# 005A     9
# 072A     9
# 033A     9
# 013B     8
# 117A     7
# 027A     7
# 015A     7
# 036A     7
# 099A     6
# 007A     6
# 023A     6
# 039A     6
# 109A     5
# 094A     5
# 050A     5
# 070A     5
# 008A     5
# 044A     5
# 021A     5
# 108A     5
# 075A     5
# 003A     4
# 026A     4
# 025C     4
# 045A     4
# 009A     4
# 104A     4
# 058A     3
# 060A     3
# 006A     3
# 034A     3
# 113A     3
# 014A     3
# 062A     3
# 018A     2
# 025B     2
# 037A     2
# 102A     2
# 011A     2
# 035A     2
# 093A     2
# 054A     2
# 032A     2
# 069A     2
# 091A     1
# 088A     1
# 024A     1
# 090A     1
# 110A     1
# 115A     1
# 019B     1
# 004A     1
# 049A     1
# 043A     1
# 048A     1
# 066A     1
# 073A     1
# 076A     1
# 064A     1
# 041A     1
# 092A     1
# 026B     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 000B    19
# 019A    17
# 074A    16
# 028A    11
# 040A    10
# 051B     9
# 016A     9
# 068A     8
# 095A     7
# 031A     7
# 023B     4
# 010A     3
# 053A     3
# 012A     3
# 105A     3
# 056A     3
# 052A     2
# 087A     2
# 061A     2
# 038A     2
# 026C     1
# 096A     1
# 100A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    237
# M    227
# F    186
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# M    59
# F    45
# X    39
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [006A, 000A, 033A, 015A, 001A, 103A, 071A, 097...
# kitten    [044A, 014B, 111A, 046A, 047A, 042A, 109A, 050...
# senior    [093A, 097A, 057A, 106A, 104A, 055A, 059A, 113...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [028A, 019A, 074A, 095A, 038A, 087A, 000B, 096...
# kitten                                               [040A]
# senior                             [051B, 056A, 016A, 061A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 56, 'kitten': 15, 'senior': 18}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 18, 'kitten': 1, 'senior': 4}
# Unique Training/Validation Group IDs:
# ['000A' '001A' '002A' '002B' '003A' '004A' '005A' '006A' '007A' '008A'
#  '009A' '011A' '013B' '014A' '014B' '015A' '018A' '019B' '020A' '021A'
#  '022A' '023A' '024A' '025A' '025B' '025C' '026A' '026B' '027A' '029A'
#  '032A' '033A' '034A' '035A' '036A' '037A' '039A' '041A' '042A' '043A'
#  '044A' '045A' '046A' '047A' '048A' '049A' '050A' '051A' '054A' '055A'
#  '057A' '058A' '059A' '060A' '062A' '063A' '064A' '065A' '066A' '067A'
#  '069A' '070A' '071A' '072A' '073A' '075A' '076A' '088A' '090A' '091A'
#  '092A' '093A' '094A' '097A' '097B' '099A' '101A' '102A' '103A' '104A'
#  '106A' '108A' '109A' '110A' '111A' '113A' '115A' '116A' '117A']
# Unique Test Group IDs:
# ['000B' '010A' '012A' '016A' '019A' '023B' '026C' '028A' '031A' '038A'
#  '040A' '051B' '052A' '053A' '056A' '061A' '068A' '074A' '087A' '095A'
#  '096A' '100A' '105A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '001A' '002A' '002B' '003A' '004A' '005A' '006A' '007A' '008A'
#  '009A' '011A' '013B' '014A' '014B' '015A' '018A' '019B' '020A' '021A'
#  '022A' '023A' '024A' '025A' '025B' '025C' '026A' '026B' '027A' '029A'
#  '032A' '033A' '034A' '035A' '036A' '037A' '039A' '041A' '042A' '043A'
#  '044A' '045A' '046A' '047A' '048A' '049A' '050A' '051A' '054A' '055A'
#  '057A' '058A' '059A' '060A' '062A' '063A' '064A' '065A' '066A' '067A'
#  '069A' '070A' '071A' '072A' '073A' '075A' '076A' '088A' '090A' '091A'
#  '092A' '093A' '094A' '097A' '097B' '099A' '101A' '102A' '103A' '104A'
#  '106A' '108A' '109A' '110A' '111A' '113A' '115A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['000B' '010A' '012A' '016A' '019A' '023B' '026C' '028A' '031A' '038A'
#  '040A' '051B' '052A' '053A' '056A' '061A' '068A' '074A' '087A' '095A'
#  '096A' '100A' '105A']
# Length of X_train_val:
# 650
# Length of y_train_val:
# 650
# Length of groups_train_val:
# 650
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     399
# senior    126
# kitten    125
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     110
# senior     23
# kitten     10
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     399
# senior    126
# kitten    125
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     110
# senior     23
# kitten     10
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 399, 2: 126, 1: 125})
# Epoch 1/1500
# 11/11 [==============================] - 1s 4ms/step - loss: 1.0466 - accuracy: 0.6292
# Epoch 2/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.2512 - accuracy: 0.9154
# Epoch 3/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.1292 - accuracy: 0.9600
# Epoch 4/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0974 - accuracy: 0.9646
# Epoch 5/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0486 - accuracy: 0.9892
# Epoch 6/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0481 - accuracy: 0.9892
# Epoch 7/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0280 - accuracy: 0.9923
# Epoch 8/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0287 - accuracy: 0.9923
# Epoch 9/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0254 - accuracy: 0.9908
# Epoch 10/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0240 - accuracy: 0.9923
# Epoch 11/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0190 - accuracy: 0.9969
# Epoch 12/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0319 - accuracy: 0.9908
# Epoch 13/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0704 - accuracy: 0.9862
# Epoch 14/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0216 - accuracy: 0.9985
# Epoch 15/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0290 - accuracy: 0.9938
# Epoch 16/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0284 - accuracy: 0.9938
# Epoch 17/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0185 - accuracy: 0.9938
# Epoch 18/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0206 - accuracy: 0.9969
# Epoch 19/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0091 - accuracy: 1.0000
# Epoch 20/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0126 - accuracy: 0.9969
# Epoch 21/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0136 - accuracy: 0.9954
# Epoch 22/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0101 - accuracy: 0.9969
# Epoch 23/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0380 - accuracy: 0.9923
# Epoch 24/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0249 - accuracy: 0.9938
# Epoch 25/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0373 - accuracy: 0.9908
# Epoch 26/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0104 - accuracy: 1.0000
# Epoch 27/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0141 - accuracy: 0.9954
# Epoch 28/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0106 - accuracy: 0.9969
# Epoch 29/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0090 - accuracy: 0.9985
# Epoch 30/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0066 - accuracy: 0.9985
# Epoch 31/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0073 - accuracy: 0.9985
# Epoch 32/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 33/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 34/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0105 - accuracy: 0.9954
# Epoch 35/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0090 - accuracy: 0.9969
# Epoch 36/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0148 - accuracy: 0.9938
# Epoch 37/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0047 - accuracy: 1.0000
# Epoch 38/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0045 - accuracy: 1.0000
# Epoch 39/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0048 - accuracy: 0.9985
# Epoch 40/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0080 - accuracy: 0.9985
# Epoch 41/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0055 - accuracy: 0.9985
# Epoch 42/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0037 - accuracy: 0.9985
# Epoch 43/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0162 - accuracy: 0.9938
# Epoch 44/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0380 - accuracy: 0.9892
# Epoch 45/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0072 - accuracy: 0.9985
# Epoch 46/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0280 - accuracy: 0.9938
# Epoch 47/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0261 - accuracy: 0.9908
# Epoch 48/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0058 - accuracy: 1.0000
# Epoch 49/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0075 - accuracy: 0.9985
# Epoch 50/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0112 - accuracy: 0.9969
# Epoch 51/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0142 - accuracy: 0.9954
# Epoch 52/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0091 - accuracy: 0.9985
# Epoch 53/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0132 - accuracy: 0.9985
# Epoch 54/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0464 - accuracy: 0.9923
# Epoch 55/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0175 - accuracy: 0.9954
# Epoch 56/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0286 - accuracy: 0.9908
# Epoch 57/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0225 - accuracy: 0.9938
# Epoch 58/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0107 - accuracy: 0.9969
# Epoch 59/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0062 - accuracy: 1.0000
# Epoch 60/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0064 - accuracy: 0.9985
# Epoch 61/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0091 - accuracy: 0.9985
# Epoch 62/1500
# 10/11 [==========================>...] - ETA: 0s - loss: 0.0086 - accuracy: 0.9969Restoring model weights from the end of the best epoch: 32.
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0249 - accuracy: 0.9938
# Epoch 62: early stopping
# 5/5 [==============================] - 0s 1ms/step - loss: 1.0409 - accuracy: 0.7832
# 5/5 [==============================] - 0s 1ms/step
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Majority Vote Accuracy for cat_id for this fold: 0.78 (18/23)
# Before appending - Cat IDs: 235, Predictions: 235, Actuals: 235, Gender: 235
# After appending - Cat IDs: 378, Predictions: 378, Actuals: 378, Gender: 378
# Final Test Results - Loss: 1.0409278869628906, Accuracy: 0.7832167744636536, Precision: 0.6643709825528007, Recall: 0.6653491436100132, F1 Score: 0.6600288600288601
# Confusion Matrix:
#  [[100   0  10]
#  [  0  10   0]
#  [ 21   0   2]]
# outer_fold 4
# Train Set Group Distribution:
# 046A    45
# 000A    39
# 103A    33
# 002B    30
# 047A    22
# 020A    20
# 000B    19
# 019A    17
# 074A    16
# 097B    14
# 002A    13
# 101A    12
# 111A    12
# 051A    12
# 055A    12
# 042A    11
# 063A    11
# 067A    11
# 028A    11
# 040A    10
# 014B    10
# 025A    10
# 059A    10
# 033A     9
# 051B     9
# 016A     9
# 001A     9
# 065A     9
# 071A     9
# 022A     9
# 013B     8
# 068A     8
# 015A     7
# 027A     7
# 031A     7
# 095A     7
# 039A     6
# 099A     6
# 007A     6
# 021A     5
# 008A     5
# 050A     5
# 075A     5
# 070A     5
# 108A     5
# 044A     5
# 045A     4
# 023B     4
# 026A     4
# 104A     4
# 003A     4
# 009A     4
# 060A     3
# 012A     3
# 053A     3
# 056A     3
# 058A     3
# 010A     3
# 006A     3
# 034A     3
# 105A     3
# 052A     2
# 093A     2
# 025B     2
# 037A     2
# 061A     2
# 011A     2
# 035A     2
# 038A     2
# 087A     2
# 018A     2
# 054A     2
# 032A     2
# 069A     2
# 115A     1
# 024A     1
# 090A     1
# 100A     1
# 096A     1
# 110A     1
# 064A     1
# 026C     1
# 076A     1
# 088A     1
# 004A     1
# 048A     1
# 049A     1
# 043A     1
# 092A     1
# 026B     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 057A    17
# 097A    15
# 029A    15
# 106A    13
# 116A    12
# 005A     9
# 072A     9
# 036A     7
# 117A     7
# 023A     6
# 094A     5
# 109A     5
# 025C     4
# 062A     3
# 113A     3
# 014A     3
# 102A     2
# 073A     1
# 091A     1
# 041A     1
# 066A     1
# 019B     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    230
# X    217
# F    206
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    59
# M    56
# F    25
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [006A, 000A, 033A, 015A, 001A, 103A, 071A, 097...
# kitten    [044A, 014B, 111A, 040A, 046A, 047A, 042A, 050...
# senior    [093A, 104A, 055A, 059A, 051B, 054A, 056A, 051...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [062A, 029A, 005A, 072A, 091A, 023A, 014A, 025...
# kitten                                         [109A, 041A]
# senior           [097A, 057A, 106A, 113A, 116A, 117A, 094A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 61, 'kitten': 14, 'senior': 15}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 13, 'kitten': 2, 'senior': 7}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '004A' '006A' '007A' '008A'
#  '009A' '010A' '011A' '012A' '013B' '014B' '015A' '016A' '018A' '019A'
#  '020A' '021A' '022A' '023B' '024A' '025A' '025B' '026A' '026B' '026C'
#  '027A' '028A' '031A' '032A' '033A' '034A' '035A' '037A' '038A' '039A'
#  '040A' '042A' '043A' '044A' '045A' '046A' '047A' '048A' '049A' '050A'
#  '051A' '051B' '052A' '053A' '054A' '055A' '056A' '058A' '059A' '060A'
#  '061A' '063A' '064A' '065A' '067A' '068A' '069A' '070A' '071A' '074A'
#  '075A' '076A' '087A' '088A' '090A' '092A' '093A' '095A' '096A' '097B'
#  '099A' '100A' '101A' '103A' '104A' '105A' '108A' '110A' '111A' '115A']
# Unique Test Group IDs:
# ['005A' '014A' '019B' '023A' '025C' '029A' '036A' '041A' '057A' '062A'
#  '066A' '072A' '073A' '091A' '094A' '097A' '102A' '106A' '109A' '113A'
#  '116A' '117A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '004A' '006A' '007A' '008A'
#  '009A' '010A' '011A' '012A' '013B' '014B' '015A' '016A' '018A' '019A'
#  '020A' '021A' '022A' '023B' '024A' '025A' '025B' '026A' '026B' '026C'
#  '027A' '028A' '031A' '032A' '033A' '034A' '035A' '037A' '038A' '039A'
#  '040A' '042A' '043A' '044A' '045A' '046A' '047A' '048A' '049A' '050A'
#  '051A' '051B' '052A' '053A' '054A' '055A' '056A' '058A' '059A' '060A'
#  '061A' '063A' '064A' '065A' '067A' '068A' '069A' '070A' '071A' '074A'
#  '075A' '076A' '087A' '088A' '090A' '092A' '093A' '095A' '096A' '097B'
#  '099A' '100A' '101A' '103A' '104A' '105A' '108A' '110A' '111A' '115A']
# AFTER SWAP - Unique Test Group IDs:
# ['005A' '014A' '019B' '023A' '025C' '029A' '036A' '041A' '057A' '062A'
#  '066A' '072A' '073A' '091A' '094A' '097A' '102A' '106A' '109A' '113A'
#  '116A' '117A']
# Length of X_train_val:
# 653
# Length of y_train_val:
# 653
# Length of groups_train_val:
# 653
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     447
# kitten    129
# senior     77
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# senior    72
# adult     62
# kitten     6
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     447
# kitten    129
# senior     77
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# senior    72
# adult     62
# kitten     6
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 447, 1: 129, 2: 77})
# Epoch 1/1500
# 11/11 [==============================] - 1s 4ms/step - loss: 1.0356 - accuracy: 0.6600
# Epoch 2/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.2897 - accuracy: 0.9020
# Epoch 3/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1146 - accuracy: 0.9632
# Epoch 4/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0538 - accuracy: 0.9893
# Epoch 5/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0520 - accuracy: 0.9801
# Epoch 6/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0296 - accuracy: 0.9954
# Epoch 7/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0277 - accuracy: 0.9908
# Epoch 8/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0141 - accuracy: 0.9985
# Epoch 9/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0199 - accuracy: 0.9969
# Epoch 10/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0184 - accuracy: 0.9923
# Epoch 11/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0096 - accuracy: 0.9985
# Epoch 12/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0225 - accuracy: 0.9923
# Epoch 13/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0077 - accuracy: 0.9985
# Epoch 14/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0223 - accuracy: 0.9954
# Epoch 15/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0119 - accuracy: 0.9985
# Epoch 16/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0107 - accuracy: 0.9954
# Epoch 17/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0140 - accuracy: 0.9969
# Epoch 18/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0077 - accuracy: 1.0000
# Epoch 19/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0042 - accuracy: 1.0000
# Epoch 20/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0047 - accuracy: 1.0000
# Epoch 21/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0069 - accuracy: 1.0000
# Epoch 22/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0071 - accuracy: 1.0000
# Epoch 23/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0132 - accuracy: 0.9985
# Epoch 24/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0051 - accuracy: 0.9985
# Epoch 25/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0118 - accuracy: 0.9939
# Epoch 26/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0117 - accuracy: 0.9985
# Epoch 27/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0349 - accuracy: 0.9954
# Epoch 28/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0136 - accuracy: 0.9954
# Epoch 29/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0216 - accuracy: 0.9939
# Epoch 30/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0186 - accuracy: 0.9939
# Epoch 31/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0246 - accuracy: 0.9939
# Epoch 32/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0129 - accuracy: 0.9969
# Epoch 33/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0195 - accuracy: 0.9939
# Epoch 34/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0110 - accuracy: 0.9985
# Epoch 35/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0090 - accuracy: 0.9969
# Epoch 36/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0153 - accuracy: 0.9908
# Epoch 37/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0058 - accuracy: 1.0000
# Epoch 38/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0037 - accuracy: 0.9985
# Epoch 39/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0057 - accuracy: 0.9985
# Epoch 40/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 41/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0138 - accuracy: 0.9969
# Epoch 42/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0049 - accuracy: 0.9985
# Epoch 43/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 44/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 45/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0132 - accuracy: 0.9969
# Epoch 46/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0106 - accuracy: 0.9985
# Epoch 47/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0071 - accuracy: 0.9985
# Epoch 48/1500
# ...
# 11/11 [==============================] - 0s 11ms/step - loss: 0.0043 - accuracy: 1.0000
# Epoch 67/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0064 - accuracy: 0.9985
# Epoch 68/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0115 - accuracy: 0.9923
# Epoch 69/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0055 - accuracy: 0.9985
# Epoch 70/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 71/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0074 - accuracy: 1.0000
# Epoch 72/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0070 - accuracy: 0.9969
# Epoch 73/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 74/1500
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0040 - accuracy: 1.0000
# Epoch 75/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0060 - accuracy: 0.9985
# Epoch 76/1500
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 77/1500
# 11/11 [==============================] - 0s 10ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 78/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0037 - accuracy: 0.9985
# Epoch 79/1500
# 11/11 [==============================] - 0s 33ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 80/1500
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 81/1500
# 11/11 [==============================] - 0s 8ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 82/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 6.8395e-04 - accuracy: 1.0000
# Epoch 83/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 6.3793e-04 - accuracy: 1.0000
# Epoch 84/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 9.3954e-04 - accuracy: 1.0000
# Epoch 85/1500
#  8/11 [====================>.........] - ETA: 0s - loss: 9.3552e-04 - accuracy: 1.0000Restoring model weights from the end of the best epoch: 55.
# 11/11 [==============================] - 0s 8ms/step - loss: 9.0687e-04 - accuracy: 1.0000
# Epoch 85: early stopping
# 5/5 [==============================] - 0s 1ms/step - loss: 3.6417 - accuracy: 0.4357
# 5/5 [==============================] - 0s 2ms/step
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Majority Vote Accuracy for cat_id for this fold: 0.64 (14/22)
# Before appending - Cat IDs: 378, Predictions: 378, Actuals: 378, Gender: 378
# After appending - Cat IDs: 518, Predictions: 518, Actuals: 518, Gender: 518
# Final Test Results - Loss: 3.6417064666748047, Accuracy: 0.4357142746448517, Precision: 0.6226226226226227, Recall: 0.41935483870967744, F1 Score: 0.4285922811934373
# Confusion Matrix:
#  [[47  0 15]
#  [ 4  2  0]
#  [60  0 12]]
# outer_fold 5
# Train Set Group Distribution:
# 000A    39
# 047A    22
# 000B    19
# 057A    17
# 019A    17
# 074A    16
# 097A    15
# 029A    15
# 097B    14
# 002A    13
# 106A    13
# 111A    12
# 101A    12
# 116A    12
# 051A    12
# 028A    11
# 063A    11
# 040A    10
# 014B    10
# 025A    10
# 059A    10
# 033A     9
# 016A     9
# 005A     9
# 072A     9
# 051B     9
# 068A     8
# 036A     7
# 031A     7
# 117A     7
# 015A     7
# 095A     7
# 007A     6
# 023A     6
# 039A     6
# 094A     5
# 021A     5
# 075A     5
# 008A     5
# 050A     5
# 109A     5
# 070A     5
# 044A     5
# 003A     4
# 026A     4
# 045A     4
# 025C     4
# 009A     4
# 023B     4
# 104A     4
# 056A     3
# 012A     3
# 053A     3
# 058A     3
# 010A     3
# 006A     3
# 014A     3
# 062A     3
# 105A     3
# 113A     3
# 018A     2
# 035A     2
# 061A     2
# 052A     2
# 038A     2
# 102A     2
# 037A     2
# 087A     2
# 025B     2
# 069A     2
# 032A     2
# 093A     2
# 011A     2
# 004A     1
# 110A     1
# 100A     1
# 019B     1
# 088A     1
# 091A     1
# 048A     1
# 066A     1
# 026C     1
# 041A     1
# 092A     1
# 064A     1
# 073A     1
# 076A     1
# 096A     1
# 026B     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 046A    45
# 103A    33
# 002B    30
# 020A    20
# 055A    12
# 042A    11
# 067A    11
# 001A     9
# 071A     9
# 022A     9
# 065A     9
# 013B     8
# 027A     7
# 099A     6
# 108A     5
# 034A     3
# 060A     3
# 054A     2
# 043A     1
# 049A     1
# 115A     1
# 090A     1
# 024A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    203
# F    178
# M    175
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# M    111
# X     73
# F     53
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [006A, 000A, 033A, 015A, 097B, 028A, 019A, 074...
# kitten    [044A, 014B, 111A, 040A, 047A, 109A, 050A, 041...
# senior    [093A, 097A, 057A, 106A, 104A, 059A, 113A, 116...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [001A, 103A, 071A, 067A, 020A, 002B, 022A, 034...
# kitten                       [046A, 042A, 043A, 049A, 115A]
# senior                       [055A, 054A, 108A, 090A, 024A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 61, 'kitten': 11, 'senior': 17}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 13, 'kitten': 5, 'senior': 5}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '002A' '003A' '004A' '005A' '006A' '007A' '008A' '009A'
#  '010A' '011A' '012A' '014A' '014B' '015A' '016A' '018A' '019A' '019B'
#  '021A' '023A' '023B' '025A' '025B' '025C' '026A' '026B' '026C' '028A'
#  '029A' '031A' '032A' '033A' '035A' '036A' '037A' '038A' '039A' '040A'
#  '041A' '044A' '045A' '047A' '048A' '050A' '051A' '051B' '052A' '053A'
#  '056A' '057A' '058A' '059A' '061A' '062A' '063A' '064A' '066A' '068A'
#  '069A' '070A' '072A' '073A' '074A' '075A' '076A' '087A' '088A' '091A'
#  '092A' '093A' '094A' '095A' '096A' '097A' '097B' '100A' '101A' '102A'
#  '104A' '105A' '106A' '109A' '110A' '111A' '113A' '116A' '117A']
# Unique Test Group IDs:
# ['001A' '002B' '013B' '020A' '022A' '024A' '027A' '034A' '042A' '043A'
#  '046A' '049A' '054A' '055A' '060A' '065A' '067A' '071A' '090A' '099A'
#  '103A' '108A' '115A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'046A'}
# Removed from Training/Validation Set:
# {'040A'}
# Moved to Test Set:
# {'040A'}
# Removed from Test Set
# {'046A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '002A' '003A' '004A' '005A' '006A' '007A' '008A' '009A'
#  '010A' '011A' '012A' '014A' '014B' '015A' '016A' '018A' '019A' '019B'
#  '021A' '023A' '023B' '025A' '025B' '025C' '026A' '026B' '026C' '028A'
#  '029A' '031A' '032A' '033A' '035A' '036A' '037A' '038A' '039A' '041A'
#  '044A' '045A' '046A' '047A' '048A' '050A' '051A' '051B' '052A' '053A'
#  '056A' '057A' '058A' '059A' '061A' '062A' '063A' '064A' '066A' '068A'
#  '069A' '070A' '072A' '073A' '074A' '075A' '076A' '087A' '088A' '091A'
#  '092A' '093A' '094A' '095A' '096A' '097A' '097B' '100A' '101A' '102A'
#  '104A' '105A' '106A' '109A' '110A' '111A' '113A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['001A' '002B' '013B' '020A' '022A' '024A' '027A' '034A' '040A' '042A'
#  '043A' '049A' '054A' '055A' '060A' '065A' '067A' '071A' '090A' '099A'
#  '103A' '108A' '115A']
# Length of X_train_val:
# 591
# Length of y_train_val:
# 591
# Length of groups_train_val:
# 591
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     352
# senior    128
# kitten     76
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     157
# kitten     59
# senior     21
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     352
# senior    128
# kitten    111
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     157
# kitten     24
# senior     21
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 352, 2: 128, 1: 111})
# Epoch 1/1500
# 10/10 [==============================] - 1s 7ms/step - loss: 1.0748 - accuracy: 0.6413
# Epoch 2/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3824 - accuracy: 0.8629
# Epoch 3/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1795 - accuracy: 0.9492
# Epoch 4/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0810 - accuracy: 0.9763
# Epoch 5/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0620 - accuracy: 0.9746
# Epoch 6/1500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0542 - accuracy: 0.9814
# Epoch 7/1500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0246 - accuracy: 0.9932
# Epoch 8/1500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0332 - accuracy: 0.9915
# Epoch 9/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0351 - accuracy: 0.9949
# Epoch 10/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0273 - accuracy: 0.9865
# Epoch 11/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0300 - accuracy: 0.9882
# Epoch 12/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0088 - accuracy: 1.0000
# Epoch 13/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0092 - accuracy: 0.9966
# Epoch 14/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0189 - accuracy: 0.9949
# Epoch 15/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0181 - accuracy: 0.9949
# Epoch 16/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0209 - accuracy: 0.9966
# Epoch 17/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0187 - accuracy: 0.9949
# Epoch 18/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0055 - accuracy: 0.9983
# Epoch 19/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0146 - accuracy: 0.9949
# Epoch 20/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0110 - accuracy: 0.9983
# Epoch 21/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0168 - accuracy: 0.9949
# Epoch 22/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0070 - accuracy: 0.9983
# Epoch 23/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 24/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0083 - accuracy: 0.9966
# Epoch 25/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0047 - accuracy: 0.9983
# Epoch 26/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0053 - accuracy: 1.0000
# Epoch 27/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0092 - accuracy: 0.9966
# Epoch 28/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0133 - accuracy: 0.9983
# Epoch 29/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 30/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0119 - accuracy: 0.9966
# Epoch 31/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 32/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0062 - accuracy: 0.9983
# Epoch 33/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0084 - accuracy: 0.9966
# Epoch 34/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0043 - accuracy: 1.0000
# Epoch 35/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 36/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0042 - accuracy: 0.9983
# Epoch 37/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 38/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0093 - accuracy: 0.9983
# Epoch 39/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 9.2652e-04 - accuracy: 1.0000
# Epoch 40/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0185 - accuracy: 0.9966
# Epoch 41/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 42/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0101 - accuracy: 0.9966
# Epoch 43/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0062 - accuracy: 0.9983
# Epoch 44/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0126 - accuracy: 0.9949
# Epoch 45/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0155 - accuracy: 0.9949
# Epoch 46/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0091 - accuracy: 0.9966
# Epoch 47/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0055 - accuracy: 0.9983
# Epoch 48/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0048 - accuracy: 1.0000
# Epoch 49/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0147 - accuracy: 0.9966
# Epoch 50/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0113 - accuracy: 0.9966
# Epoch 51/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0265 - accuracy: 0.9898
# Epoch 52/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0234 - accuracy: 0.9949
# Epoch 53/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0080 - accuracy: 0.9966
# Epoch 54/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0103 - accuracy: 0.9966
# Epoch 55/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0051 - accuracy: 0.9983
# Epoch 56/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0172 - accuracy: 0.9949
# Epoch 57/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0042 - accuracy: 0.9983
# Epoch 58/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 59/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0155 - accuracy: 0.9966
# Epoch 60/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0082 - accuracy: 0.9983
# Epoch 61/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0057 - accuracy: 0.9983
# Epoch 62/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0067 - accuracy: 0.9983
# Epoch 63/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 64/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 65/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0056 - accuracy: 0.9983
# Epoch 66/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 67/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 68/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 69/1500
#  1/10 [==>...........................] - ETA: 0s - loss: 3.3148e-04 - accuracy: 1.0000Restoring model weights from the end of the best epoch: 39.
# 10/10 [==============================] - 0s 5ms/step - loss: 9.2241e-04 - accuracy: 1.0000
# Epoch 69: early stopping
# 7/7 [==============================] - 0s 1ms/step - loss: 0.6076 - accuracy: 0.8416
# 7/7 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.91 (21/23)
# Before appending - Cat IDs: 518, Predictions: 518, Actuals: 518, Gender: 518
# After appending - Cat IDs: 720, Predictions: 720, Actuals: 720, Gender: 720
# Final Test Results - Loss: 0.607560396194458, Accuracy: 0.8415841460227966, Precision: 0.7293630573248407, Recall: 0.7279344858962693, F1 Score: 0.7284322459759109
# Confusion Matrix:
#  [[141   9   7]
#  [  8  16   0]
#  [  8   0  13]]
#
# Final Average F1-Score across all UNSEEN TEST sets: 0.6240444851120135
#
# Final Average Loss across all UNSEEN TEST sets: 1.603387451171875
#
# Final Average Accuracy across all UNSEEN TEST sets: 0.7095658600330352
#
# Final Average Precision across all UNSEEN TEST sets: 0.6724000560685047
#
# Final Average Recall across all UNSEEN TEST sets: 0.646077899123222

# %%
seed_5_folds_values = (unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1)

# Plotting all fold metrics|
seed_5_folds_plot = plot_all_metrics(unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1, "Folds", "Fold Number")

# %% [markdown]
# ## Majority Voting on Total Entries per cat_id

# %%
# Debugging print statements
print(f'Checking - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
# Out:
# Checking - Cat IDs: 720, Predictions: 720, Actuals: 720, Gender: 720

# %%
# Create results df
full_results = pd.DataFrame({
    'cat_id': all_cat_ids,
    'predicted_age_group': all_predicted_age_groups,
    'actual_age_group': all_actual_age_groups,
    'all_gender': all_gender
})

# create a correct majority prediction column
full_results['correct'] = full_results['predicted_age_group'] == full_results['actual_age_group']

# %%
# Group by cat_id and aggregate predicted age groups
majority_votes = full_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first()

# Calculate the accuracy of majority voting
correct_predictions = (majority_votes == actual_groups).sum()
total_cats = len(actual_groups)
majority_vote_accuracy = correct_predictions / total_cats

logger(f"Overall Majority Vote Accuracy for cat_id: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

# store for final evaluation 
all_majority_vote_accuracies.append(majority_vote_accuracy)
# Out:
# Overall Majority Vote Accuracy for cat_id: 0.78 (86/110)

# %%
# Detailed df with predictions, actual labels, and comparison including majority vote
detailed_results = full_results.groupby('cat_id').apply(
    lambda x: pd.Series({
        'Predictions': list(x['predicted_age_group']),
        'Majority Vote': x['predicted_age_group'].mode()[0],
        'Actual Age Group': x['actual_age_group'].iloc[0],
        'Correct Majority Vote': x['predicted_age_group'].mode()[0] == x['actual_age_group'].iloc[0]
    })
).reset_index()

# Convert to DataFrame for better formatting and display
detailed_results = pd.DataFrame(detailed_results)

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 10)
pd.set_option('display.width', 1000)

sorted_detailed_results = detailed_results.sort_values(by='Correct Majority Vote', ascending=False)

# Display the sorted DataFrame
sorted_detailed_results
# Out:
#     cat_id                                        Predictions Majority Vote Actual Age Group  Correct Majority Vote
# 0     000B  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 68    062A                              [adult, adult, adult]         adult            adult                   True
# 78    072A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 77    071A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 76    070A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 75    069A                                     [adult, adult]         adult            adult                   True
# 74    068A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 73    067A  [adult, adult, kitten, kitten, adult, kitten, ...         adult            adult                   True
# 72    066A                                            [adult]         adult            adult                   True
# 71    065A  [senior, adult, adult, kitten, adult, senior, ...         adult            adult                   True
# 69    063A  [adult, kitten, senior, adult, senior, adult, ...         adult            adult                   True
# 66    060A                              [adult, adult, adult]         adult            adult                   True
# 80    074A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 65    059A  [senior, senior, senior, senior, senior, senio...        senior           senior                   True
# 64    058A                           [senior, senior, senior]        senior           senior                   True
# 62    056A                            [senior, senior, adult]        senior           senior                   True
# 61    055A  [adult, senior, senior, senior, senior, senior...        senior           senior                   True
# 58    052A                                    [adult, senior]         adult            adult                   True
# 1     001A  [adult, senior, adult, adult, adult, adult, ad...         adult            adult                   True
# 54    049A                                           [kitten]        kitten           kitten                   True
# 53    048A                                           [kitten]        kitten           kitten                   True
# 50    044A           [kitten, kitten, kitten, kitten, kitten]        kitten           kitten                   True
# 79    073A                                            [adult]         adult            adult                   True
# 81    075A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 47    041A                                           [kitten]        kitten           kitten                   True
# 95    100A                                            [adult]         adult            adult                   True
# 107   115A                                           [kitten]        kitten           kitten                   True
# 106   113A                            [senior, adult, senior]        senior           senior                   True
# 105   111A  [adult, kitten, kitten, kitten, kitten, kitten...        kitten           kitten                   True
# 104   110A                                           [kitten]        kitten           kitten                   True
# 102   108A            [senior, adult, senior, senior, senior]        senior           senior                   True
# 100   105A                              [adult, adult, adult]         adult            adult                   True
# 98    103A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 97    102A                                     [adult, adult]         adult            adult                   True
# 96    101A  [adult, adult, adult, adult, senior, adult, ad...         adult            adult                   True
# 94    099A         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 82    076A                                            [adult]         adult            adult                   True
# 93    097B  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 91    096A                                            [adult]         adult            adult                   True
# 90    095A  [adult, adult, senior, adult, adult, adult, ad...         adult            adult                   True
# 89    094A           [senior, senior, senior, senior, senior]        senior           senior                   True
# 87    092A                                            [adult]         adult            adult                   True
# 86    091A                                            [adult]         adult            adult                   True
# 85    090A                                           [senior]        senior           senior                   True
# 84    088A                                     [adult, adult]         adult            adult                   True
# 83    087A                                     [adult, adult]         adult            adult                   True
# 49    043A                                           [kitten]        kitten           kitten                   True
# 55    050A           [senior, kitten, kitten, kitten, kitten]        kitten           kitten                   True
# 25    023A         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 13    012A                              [adult, adult, adult]         adult            adult                   True
# 32    026B                                            [adult]         adult            adult                   True
# 31    026A                       [adult, adult, adult, adult]         adult            adult                   True
# 30    025C                       [adult, adult, adult, adult]         adult            adult                   True
# 29    025B                                     [adult, adult]         adult            adult                   True
# 28    025A  [adult, adult, adult, senior, adult, adult, ad...         adult            adult                   True
# 27    024A                                           [senior]        senior           senior                   True
# 26    023B                       [adult, adult, adult, adult]         adult            adult                   True
# 46    040A  [kitten, kitten, kitten, kitten, kitten, kitte...        kitten           kitten                   True
# 24    022A  [adult, adult, kitten, kitten, adult, adult, k...         adult            adult                   True
# 23    021A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 22    020A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 21    019B                                            [adult]         adult            adult                   True
# 20    019A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 19    018A                                     [adult, adult]         adult            adult                   True
# 10    009A                       [adult, adult, adult, adult]         adult            adult                   True
# 17    015A  [adult, adult, adult, senior, adult, adult, ad...         adult            adult                   True
# 11    010A                             [adult, adult, senior]         adult            adult                   True
# 12    011A                                   [senior, senior]        senior           senior                   True
# 15    014A                              [adult, adult, adult]         adult            adult                   True
# 9     008A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 8     007A         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 34    027A  [senior, adult, adult, adult, adult, adult, ad...         adult            adult                   True
# 35    028A  [senior, adult, adult, senior, adult, adult, a...         adult            adult                   True
# 45    039A         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 2     002A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 44    038A                                     [adult, adult]         adult            adult                   True
# 43    037A                                     [adult, adult]         adult            adult                   True
# 42    036A  [adult, adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 3     002B  [adult, adult, senior, adult, adult, adult, ad...         adult            adult                   True
# 4     003A                       [adult, adult, adult, adult]         adult            adult                   True
# 14    013B  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 40    034A                              [adult, adult, adult]         adult            adult                   True
# 39    033A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 38    032A                                     [adult, adult]         adult            adult                   True
# 37    031A  [adult, adult, adult, senior, adult, adult, ad...         adult            adult                   True
# 7     006A                              [adult, adult, adult]         adult            adult                   True
# 6     005A  [adult, senior, senior, senior, senior, senior...        senior            adult                  False
# 5     004A                                           [kitten]        kitten            adult                  False
# 101   106A  [adult, adult, adult, adult, adult, adult, adu...         adult           senior                  False
# 108   116A  [senior, adult, adult, adult, adult, adult, se...         adult           senior                  False
# 99    104A                       [adult, adult, adult, adult]         adult           senior                  False
# 103   109A               [adult, adult, adult, kitten, adult]         adult           kitten                  False
# 48    042A  [adult, kitten, adult, adult, adult, kitten, a...         adult           kitten                  False
# 92    097A  [adult, adult, adult, adult, adult, senior, ad...         adult           senior                  False
# 60    054A                                     [adult, adult]         adult           senior                  False
# 51    045A                      [adult, kitten, adult, adult]         adult           kitten                  False
# 52    047A  [adult, adult, kitten, adult, adult, adult, ad...         adult           kitten                  False
# 56    051A  [adult, adult, adult, adult, adult, adult, adu...         adult           senior                  False
# 57    051B  [adult, adult, adult, adult, adult, adult, adu...         adult           senior                  False
# 41    035A                                   [senior, senior]        senior            adult                  False
# 59    053A                            [senior, adult, senior]        senior            adult                  False
# 63    057A  [adult, adult, adult, adult, adult, adult, adu...         adult           senior                  False
# 16    014B  [senior, kitten, adult, senior, kitten, senior...        senior           kitten                  False
# 36    029A  [senior, senior, senior, adult, adult, adult, ...        senior            adult                  False
# 67    061A                                     [adult, adult]         adult           senior                  False
# 70    064A                                           [kitten]        kitten            adult                  False
# 33    026C                                           [senior]        senior            adult                  False
# 18    016A  [adult, adult, adult, adult, adult, adult, adu...         adult           senior                  False
# 88    093A                                     [adult, adult]         adult           senior                  False
# 109   117A  [adult, adult, adult, adult, adult, adult, adult]         adult           senior                  False

# %%
# Create df for majority votes
majority_df = majority_votes.reset_index()
majority_df.columns = ['cat_id', 'Majority_Vote']

# Get actual groups for each cat_id
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first().reset_index()

# Merge majority votes with actual groups
majority_with_actual = pd.merge(majority_df, actual_groups, on='cat_id')

# Add a column to check if the majority vote was correct
majority_with_actual['Majority_Correct'] = majority_with_actual['Majority_Vote'] == majority_with_actual['actual_age_group']

# Count correct majority votes per class
correct_majority_votes_per_class = majority_with_actual.groupby('actual_age_group')['Majority_Correct'].sum()

print("Correct Majority Votes per Class:")
print(correct_majority_votes_per_class)
# Out:
# Correct Majority Votes per Class:
# actual_age_group
# adult     66
# kitten    10
# senior    10
# Name: Majority_Correct, dtype: int64

# %%
# Calculate the total count and the number of correct predictions for each class
class_stats = majority_with_actual.groupby('actual_age_group').agg(
    total_count=('Majority_Correct', 'size'),  # Total number of cases per class
    correct_count=('Majority_Correct', 'sum')  # Sum of correct predictions per class
).reset_index()

# Calculate accuracy for each class
class_stats['accuracy'] = class_stats['correct_count'] / class_stats['total_count'] * 100

# store for final evaluation 
all_majority_vote_details.append(class_stats)

# Log detailed stats
print("Detailed Class Statistics for Majority Votes:")
print(class_stats)
# Out:
# Detailed Class Statistics for Majority Votes:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult           73             66  90.410959
# 1           kitten           15             10  66.666667
# 2           senior           22             10  45.454545

# %%
# Plot for Detailed Class Statistics for Majority Votes
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Accuracy of Majority Votes by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Detailed Class Statistics

# %%
# Calculate the total count and the number of correct predictions for each class
class_stats = full_results.groupby('actual_age_group').agg(
    total_count=('correct', 'size'),
    correct_count=('correct', 'sum')
).reset_index()

# Calculate accuracy for each class
class_stats['accuracy'] = class_stats['correct_count'] / class_stats['total_count'] * 100

# store for final evaluation 
all_class_stats.append(class_stats)

# Log the detailed stats
print("Detailed Class Statistics:")
print(class_stats)
# Out:
# Detailed Class Statistics:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult          471            418  88.747346
# 1           kitten          100             55  55.000000
# 2           senior          149             42  28.187919

# %%
# Plot for Detailed Class Statistics (Overall)
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Overall Accuracy by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Gender Exploration

# %%
# Group by gender and calculate the total count, correct predictions, and accuracy
gender_stats = full_results.groupby('all_gender').agg(
    count=('cat_id', 'size'),  # Total number of cases per gender
    correct=('correct', 'sum')  # Sum of correct predictions per gender
).reset_index()

# Calculate accuracy for each gender
gender_stats['accuracy'] = (gender_stats['correct'] / gender_stats['count'] * 100).round(2)

# Display the DataFrame
print("Accuracy by Gender:")
print(gender_stats)

# store for final evaluation 
all_gender_stats.append(gender_stats)
# Out:
# Accuracy by Gender:
#   all_gender  count  correct  accuracy
# 0          F    192      136     70.83
# 1          M    287      226     78.75
# 2          X    241      153     63.49

# %%
# Plot for Accuracy by Gender
styled_barplot(gender_stats, 'all_gender', 'accuracy', 
               'Accuracy by Gender', 
               'Gender', 'Accuracy (%)')

# %% [markdown]
# ### Log current total CV Stats

# %%
print("Total Majority Vote Accuracy so far:", all_majority_vote_accuracies)
print("Total Class Statistics so far:\n", all_class_stats) 
print("Total Majority Vote Statistics so far:\n", all_majority_vote_details) 
print("Total Gender Accuracy so far:\n", all_gender_stats)
# Out:
# Total Majority Vote Accuracy so far: [0.7727272727272727, 0.7545454545454545, 0.7363636363636363, 0.7909090909090909, 0.7818181818181819]
# Total Class Statistics so far:
#  [  actual_age_group  total_count  correct_count   accuracy
# 0            adult          472            410  86.864407
# 1           kitten           95             51  53.684211
# 2           senior          149             39  26.174497,   actual_age_group  total_count  correct_count   accuracy
# 0            adult          476            398  83.613445
# 1           kitten          112             45  40.178571
# 2           senior          149             39  26.174497,   actual_age_group  total_count  correct_count   accuracy
# 0            adult          489            430  87.934560
# 1           kitten          112             49  43.750000
# 2           senior          149             56  37.583893,   actual_age_group  total_count  correct_count   accuracy
# 0            adult          473            406  85.835095
# 1           kitten           95             53  55.789474
# 2           senior          149             50  33.557047,   actual_age_group  total_count  correct_count   accuracy
# 0            adult          471            418  88.747346
# 1           kitten          100             55  55.000000
# 2           senior          149             42  28.187919]
# Total Majority Vote Statistics so far:
#  [  actual_age_group  total_count  correct_count   accuracy
# 0            adult           73             67  91.780822
# 1           kitten           15              9  60.000000
# 2           senior           22              9  40.909091,   actual_age_group  total_count  correct_count   accuracy
# 0            adult           73             68  93.150685
# 1           kitten           15             10  66.666667
# 2           senior           22              5  22.727273,   actual_age_group  total_count  correct_count   accuracy
# 0            adult           73             65  89.041096
# 1           kitten           15              9  60.000000
# 2           senior           22              7  31.818182,   actual_age_group  total_count  correct_count   accuracy
# 0            adult           73             68  93.150685
# 1           kitten           15             12  80.000000
# 2           senior           22              7  31.818182,   actual_age_group  total_count  correct_count   accuracy
# 0            adult           73             66  90.410959
# 1           kitten           15             10  66.666667
# 2           senior           22             10  45.454545]
# Total Gender Accuracy so far:
#  [  all_gender  count  correct  accuracy
# 0          F    194      148     76.29
# 1          M    286      206     72.03
# 2          X    236      146     61.86,   all_gender  count  correct  accuracy
# 0          F    198      132     66.67
# 1          M    286      204     71.33
# 2          X    253      146     57.71,   all_gender  count  correct  accuracy
# 0          F    211      163     77.25
# 1          M    286      211     73.78
# 2          X    253      161     63.64,   all_gender  count  correct  accuracy
# 0          F    192      139     72.40
# 1          M    289      219     75.78
# 2          X    236      151     63.98,   all_gender  count  correct  accuracy
# 0          F    192      136     70.83
# 1          M    287      226     78.75
# 2          X    241      153     63.49]

# %% [markdown]
# # --------------

# %% [markdown]
# # Total Final Results & Analysis

# %%
# Count unique cat_id per age group 
unique_cats_per_age_group = dataframe.groupby('age_group')['cat_id'].nunique()

# Display the counts
print("Unique cat_id counts in original dataframe:", unique_cats_per_age_group)
# Out:
# Unique cat_id counts in original dataframe: age_group
# adult     74
# kitten    16
# senior    22
# Name: cat_id, dtype: int64

# %% [markdown]
# ## Metrics

# %%
# Calculate overall metrics
overall_avg_loss = np.mean(all_losses)
overall_avg_acc = np.mean(all_accuracies)
overall_avg_precision = np.mean(all_precisions)
overall_avg_recall = np.mean(all_recalls)
overall_avg_f1 = np.mean(all_f1)

print("Overall Average Metrics:")
print("Loss:", overall_avg_loss)
print("Accuracy:", overall_avg_acc)
print("Precision:", overall_avg_precision)
print("Recall:", overall_avg_recall)
print("F1 Score:", overall_avg_f1)
# Out:
# Overall Average Metrics:
# Loss: 1.7017198395729065
# Accuracy: 0.702086399793625
# Precision: 0.6473778478137946
# Recall: 0.606810113111458
# F1 Score: 0.5799515758085922

# %% [markdown]
# ## Majority Votes

# %%
# Average of majority vote accuracies
average_majority_vote_accuracy = np.mean(all_majority_vote_accuracies)
print("Average Majority Vote Accuracy:", average_majority_vote_accuracy)
# Out:
# Average Majority Vote Accuracy: 0.7672727272727273

# %%
# Concatenate all class stats DataFrames and calculate the mean of accuracies
total_majority_vote_details = pd.concat(all_majority_vote_details)
average_majority_vote_details = total_majority_vote_details.groupby('actual_age_group').agg({
    'total_count': 'sum', 
    'correct_count': 'sum' 
}).reset_index()
average_majority_vote_details['accuracy'] = (average_majority_vote_details['correct_count'] / average_majority_vote_details['total_count']) * 100

print("Average Class Statistics:")
print(average_majority_vote_details)
# Out:
# Average Class Statistics:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult          365            334  91.506849
# 1           kitten           75             50  66.666667
# 2           senior          110             38  34.545455

# %%
# Plot for Detailed Class Statistics for Majority Votes
styled_barplot(average_majority_vote_details, 'actual_age_group', 'accuracy', 
               'Accuracy of Majority Votes by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Detailed Class Statistics

# %%
# Concatenate all class stats DataFrames and calculate the mean of accuracies
total_class_stats = pd.concat(all_class_stats)
average_class_stats = total_class_stats.groupby('actual_age_group').agg({
    'total_count': 'sum',  
    'correct_count': 'sum' 
}).reset_index()
average_class_stats['accuracy'] = (average_class_stats['correct_count'] / average_class_stats['total_count']) * 100

print("Average Class Statistics:")
print(average_class_stats)
# Out:
# Average Class Statistics:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult         2381           2062  86.602268
# 1           kitten          514            253  49.221790
# 2           senior          745            226  30.335570

# %%
# Plot for Detailed Class Statistics (Overall)
styled_barplot(average_class_stats, 'actual_age_group', 'accuracy', 
               'Overall Accuracy by Age Group', 
               'Age Group', 'Accuracy (%)')

# %%
# Concatenate all gender stats DataFrames and calculate the mean of accuracies
total_gender_stats = pd.concat(all_gender_stats)
average_gender_stats = total_gender_stats.groupby('all_gender').agg({
    'count': 'sum',  
    'correct': 'sum'  
}).reset_index()
average_gender_stats['accuracy'] = (average_gender_stats['correct'] / average_gender_stats['count']) * 100

print("Average Gender Accuracy:")
print(average_gender_stats)
# Out:
# Average Gender Accuracy:
#   all_gender  count  correct   accuracy
# 0          F    987      718  72.745694
# 1          M   1434     1066  74.337517
# 2          X   1219      757  62.100082

# %%
# Plot for Accuracy by Gender
styled_barplot(total_gender_stats, 'all_gender', 'accuracy', 
               'Accuracy by Gender', 
               'Gender', 'Accuracy (%)')

# %% [markdown]
# # Visualisations

# %%
# Plotting all metrics
metrics_across_seeds = plot_all_metrics(all_losses, all_accuracies, all_precisions, all_recalls, all_f1, "Seeds", "Seed Number")

# %%
# Calculate the standard deviation for each metric
std_loss = np.std(all_losses)
std_accuracy = np.std(all_accuracies)
std_precision = np.std(all_precisions)
std_recall = np.std(all_recalls)
std_f1 = np.std(all_f1)

print("Standard Deviations:")
print(f"Loss: {std_loss}")
print(f"Accuracy: {std_accuracy}")
print(f"Precision: {std_precision}")
print(f"Recall: {std_recall}")
print(f"F1 Score: {std_f1}")
# Out:
# Standard Deviations:
# Loss: 0.1858959505372327
# Accuracy: 0.022547936255489218
# Precision: 0.037767746793981795
# Recall: 0.02815840484969678
# F1 Score: 0.03628474389278871

# %%
# Calculate the interquartile range for each metric
iqr_loss = np.percentile(all_losses, 75) - np.percentile(all_losses, 25)
iqr_accuracy = np.percentile(all_accuracies, 75) - np.percentile(all_accuracies, 25)
iqr_precision = np.percentile(all_precisions, 75) - np.percentile(all_precisions, 25)
iqr_recall = np.percentile(all_recalls, 75) - np.percentile(all_recalls, 25)
iqr_f1 = np.percentile(all_f1, 75) - np.percentile(all_f1, 25)

print("Interquartile Ranges:")
print(f"Loss: {iqr_loss}")
print(f"Accuracy: {iqr_accuracy}")
print(f"Precision: {iqr_precision}")
print(f"Recall: {iqr_recall}")
print(f"F1 Score: {iqr_f1}")
# Out:
# Interquartile Ranges:
# Loss: 0.19344953298568734
# Accuracy: 0.004575186967849754
# Precision: 0.02918192136665676
# Recall: 0.0341596756776783
# F1 Score: 0.0647967712235894

# %% [markdown]
# ## Display the seed folds results together

# %%
# Create a figure with subplots
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(18, 12))  

# Flatten the axes array for easier indexing
axes = axes.flatten()

def plot_metrics_on_axes(ax, losses, accuracies, precisions, recalls, f1, title):
    ax.plot(range(1, len(losses)+1), losses, marker='o', color='blue', label='Loss')
    ax.plot(range(1, len(accuracies)+1), accuracies, marker='o', color='green', label='Accuracy')
    ax.plot(range(1, len(precisions)+1), precisions, marker='o', color='red', label='Precision')
    ax.plot(range(1, len(recalls)+1), recalls, marker='o', color='purple', label='Recall')
    ax.plot(range(1, len(f1)+1), f1, marker='o', color='orange', label='F1 Score')
    ax.set_xticks([1, 2, 3, 4])  # Set x-axis ticks to full integers
    ax.set_title(title)
    ax.set_xlabel('Fold Number')
    ax.set_ylabel('Metric Value')
    ax.legend()
    ax.grid(True)

# Plot onto each axes object
plot_metrics_on_axes(axes[0], *seed_1_folds_values, "Seed 1 Metrics")
plot_metrics_on_axes(axes[1], *seed_2_folds_values, "Seed 2 Metrics")
plot_metrics_on_axes(axes[2], *seed_3_folds_values, "Seed 3 Metrics")
plot_metrics_on_axes(axes[3], *seed_4_folds_values, "Seed 4 Metrics")
plot_metrics_on_axes(axes[4], *seed_5_folds_values, "Seed 5 Metrics")

# Hide the unused subplot 
for ax in axes[5:]:
    ax.set_visible(False)

# Adjust layout
plt.tight_layout()
plt.show()
