# %% [markdown]
# # Perch Multi Seed Validation
# #### 5 Random (but reproducible) seeds are selected for 5 different runs of train/test
# #### Models have been optimised and verified on validation sets thoroughly, running a final train/test evaluation here
# #### The setup:
#
# - 4 fold StratifiedGroupKFold for stratification and ensuring each cat_id group only appears in one set at a time
# - Final scores averaged over the 4 folds
# - For each seed run we will explore the cat_id predictions through majority voting
# - For each run we will explore the potential impact of gender
# - Includes visualisations & analysis
#
# The dataset is highly unbalanced.

# %%
# Standard imports
import numpy as np
import pandas as pd
import random
from datetime import datetime
from collections import Counter

# Sklearn imports
from sklearn.model_selection import train_test_split, GroupShuffleSplit, GroupKFold, StratifiedGroupKFold
from sklearn.preprocessing import LabelEncoder, MinMaxScaler, RobustScaler, StandardScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report
from sklearn.utils.class_weight import compute_class_weight
from sklearn.inspection import permutation_importance

# Imbalanced-learn import
from imblearn.over_sampling import SMOTE

# TensorFlow and Keras imports
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Dropout, Input, BatchNormalization, concatenate
from tensorflow.keras.optimizers import Adam, RMSprop, SGD, Adamax, AdamW
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import to_categorical
from keras.regularizers import l1, l2, L1L2

# Optuna import
import optuna

# Visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns

from IPython.display import display

# MixUp imports
import tensorflow_probability as tfp

# %%
# Set an initial seed for reproducibility
np.random.seed(42)  

# Generate a list of 5 random seeds
random_seeds = np.random.randint(0, 10000, size=5)
print("Random Seeds:", random_seeds)
# Out:
# Random Seeds: [7270  860 5390 5191 5734]

# %% [markdown]
# #### TOTAL RESULTS ACROSS SEED INITIATION

# %%
# Lists to collect statistics across all CVs
all_losses, all_accuracies, all_precisions, all_recalls, all_f1 = [], [], [], [], []
all_majority_vote_accuracies, all_majority_vote_details, all_class_stats, all_gender_stats  = [], [], [], []

# %% [markdown]
# ## Define Functions

# %%
def check_initial_group_split(groups_train, groups_test):
    """
    Check if any group is present in both the train and test sets.

    Parameters:
    - groups_train: Array of group identifiers for the train set
    - groups_test: Array of group identifiers for the test set

    Returns:
    - Prints out any groups found in both sets and the count of such groups
    """
    train_groups = set(groups_train)
    test_groups = set(groups_test)
    common_groups = train_groups.intersection(test_groups)

    if common_groups:
        print(f"Warning: Found {len(common_groups)} common groups in both train/validation and test sets: {common_groups}")
    else:
        print("No common groups found between train and test sets.")

# %%
# Function to perform the swaps based on cat_id, ensuring swaps within the same age_group
def swap_cat_id_instances(dataframe, train_val_idx, test_idx, specific_cat_ids):
    for cat_id in specific_cat_ids:
        # Check if the specific cat_id is not in the training set
        if cat_id not in dataframe.iloc[train_val_idx]['cat_id'].values:
            # Get the age_group of this cat_id
            age_group = dataframe[dataframe['cat_id'] == cat_id]['age_group'].iloc[0]
                
            # Find a different cat_id within the same age_group in the train set that is not in the test set
            other_cat_ids_in_age_group = dataframe[(dataframe['age_group'] == age_group) & 
                                                   (dataframe['cat_id'] != cat_id) &
                                                   (~dataframe['cat_id'].isin(dataframe.iloc[test_idx]['cat_id']))]['cat_id'].unique()
            
            # Choose one other cat_id for swapping
            if len(other_cat_ids_in_age_group) > 0:
                other_cat_id = np.random.choice(other_cat_ids_in_age_group)

                # Find all instances of the other_cat_id in the train set
                other_cat_id_train_val_indices = train_val_idx[dataframe.iloc[train_val_idx]['cat_id'] == other_cat_id]
                
                # Find all instances of the specific cat_id in the test set
                cat_id_test_indices = test_idx[dataframe.iloc[test_idx]['cat_id'] == cat_id]
                
                # Swap the indices
                train_val_idx = np.setdiff1d(train_val_idx, other_cat_id_train_val_indices, assume_unique=True)
                test_idx = np.setdiff1d(test_idx, cat_id_test_indices, assume_unique=True)

                train_val_idx = np.concatenate((train_val_idx, cat_id_test_indices))
                test_idx = np.concatenate((test_idx, other_cat_id_train_val_indices))
            else:
                print(f"No alternative cat_id found in the same age_group as {cat_id} for swapping.")
                
    return train_val_idx, test_idx

# %%
# Function to identify differences in groups
def find_group_differences(original, new):
    # Convert numpy arrays to sets for easy difference computation
    original_set = set(original)
    new_set = set(new)
    # Find differences
    moved_to_new = new_set - original_set
    moved_to_original = original_set - new_set
    return moved_to_new, moved_to_original

# %%
# create custom logger function for local logs & stored in a .txt
def logger(message, file=None):
    print(message)
    if file is not None:
        with open(file, "a") as log_file:
            log_file.write(message + "\n")

log_file_path = "multi-seed-val-D13.txt"

# %%
# Set the aesthetic style of the plots
sns.set(style="whitegrid", palette="deep")

# Define a custom color palette
colors = ["#6aabd1", "#b6e2d3", "#dac292"] 
sns.set_palette(sns.color_palette(colors))

# Function to create bar plots with enhanced style
def styled_barplot(data, x, y, title, xlabel, ylabel):
    plt.figure(figsize=(8, 4))
    bar_plot = sns.barplot(x=x, y=y, data=data, errorbar=None, width=0.5)  
    plt.title(title, fontsize=16, fontweight='bold', color="#333333")
    plt.xlabel(xlabel, fontsize=14, fontweight='bold', color="#333333")
    plt.ylabel(ylabel, fontsize=14, fontweight='bold', color="#333333")
    plt.xticks(fontsize=12, color="#333333")
    plt.yticks(fontsize=12, color="#333333")
    plt.ylim(0, 100) 

    # Adding value labels on top of each bar
    for p in bar_plot.patches:
        height = p.get_height()
        # Annotate the height value on the bar
        bar_plot.annotate(f'{height:.1f}', 
                          (p.get_x() + p.get_width() / 2., height), 
                          ha='center', va='center', 
                          xytext=(0, 9), 
                          textcoords='offset points', fontsize=12, color="#333333")

    plt.show()

# %%
def plot_all_metrics(losses, accuracies, precisions, recalls, f1, metrics_across, x_axis_label):
    fig, ax = plt.subplots(figsize=(12, 8))
    seeds = range(1, len(losses) + 1)

    ax.plot(seeds, losses, marker='o', color='blue', label='Loss')
    ax.plot(seeds, accuracies, marker='o', color='green', label='Accuracy')
    ax.plot(seeds, precisions, marker='o', color='red', label='Precision')
    ax.plot(seeds, recalls, marker='o', color='purple', label='Recall')
    ax.plot(seeds, f1, marker='o', color='orange', label='F1 Score')

    ax.set_title(f'Metrics Across {metrics_across}')
    ax.set_xlabel(x_axis_label)
    ax.set_ylabel('Metric Value')
    ax.set_xticks(seeds)
    ax.legend()
    ax.grid(True)

    return fig

# %%
def mixup_data(x, y, alpha=0.2):
    if alpha > 0:
        # Create a Beta distribution and sample lambda values from it
        beta_distribution = tfp.distributions.Beta(alpha, alpha)
        lam = beta_distribution.sample([tf.shape(x)[0]])
    else:
        lam = 1

    lam = tf.maximum(lam, 1 - lam)  # Ensure lambda is always between 0.5 and 1
    index = tf.random.shuffle(tf.range(tf.shape(x)[0]))

    x_mix = lam[:, tf.newaxis] * x + (1 - lam[:, tf.newaxis]) * tf.gather(x, index)
    y_mix = lam[:, tf.newaxis] * y + (1 - lam[:, tf.newaxis]) * tf.gather(y, index)

    return x_mix, y_mix

# %% [markdown]
# # RANDOM SEED 1

# %% [markdown]
# ## Prepare Data

# %%
# Set a fixed random seed for reproducibility
random.seed(int(random_seeds[0])) 
np.random.seed(int(random_seeds[0]))
tf.random.set_seed(int(random_seeds[0]))

# Load datasets
dataframe = pd.read_csv('/Users/astrid/PycharmProjects/perch-2/scripts/perch_embeddings_april_10.csv')

dataframe.drop('mean_freq', axis=1, inplace=True)

def assign_age_group(age, age_groups):
    for group_name, age_range in age_groups.items():
        if age_range[0] <= age < age_range[1]:
            return group_name
    return 'Unknown'  # For any age that doesn't fit the defined groups

# Define age groups
age_groups = {
    'kitten': (0, 0.5),
    'adult': (0.5, 12),
    'senior': (12, 20)
}

# Create a new column for the age group
dataframe['age_group'] = dataframe['target'].apply(assign_age_group, age_groups=age_groups)

print(dataframe['age_group'].value_counts())
# Out:
# adult     509
# senior    149
# kitten    135
# Name: age_group, dtype: int64

# %%
# Separate features and labels
X = dataframe.iloc[:, :-4].values  # all columns except the last four

# Encode the 'age_group' column as integers using LabelEncoder
label_encoder = LabelEncoder()
encoded_y = label_encoder.fit_transform(dataframe['age_group'].values)

# Use the encoded labels for splitting and one-hot encoding
y = encoded_y  

# Convert 'cat_id' column to numpy array to be used as groups array for GroupKFold
groups = dataframe['cat_id'].values

# %%
tf.keras.backend.clear_session()

# %% [markdown]
# ## Run Setup

# %%
all_cat_ids = []
all_predicted_age_groups = []
all_actual_age_groups = []
all_gender = []

# Define the StratifiedGroupKFold splitter for 4 fold CV with random shuffling
outer_cv = StratifiedGroupKFold(n_splits=4, shuffle=True, random_state=int(random_seeds[0]))

# unseen test set metrics
unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1 = [], [], [], [], []

outer_fold = 0

# Use the splitter to generate indices for training and testing sets
# Note: GroupShuffleSplit.split returns indices, so we use it to index the arrays
for train_val_idx, test_idx in outer_cv.split(X, y, groups):
    outer_fold += 1
    logger(f"outer_fold {outer_fold}", file=log_file_path)

    # Convert indices back to DataFrame for easy manipulation
    df_train_val = dataframe.iloc[train_val_idx]
    df_test = dataframe.iloc[test_idx]

    ##############################
    # ASSESSING SPLITS BY CAT_ID #
    ##############################
    
    # Get the distribution of groups
    training_validation_group_distribution = df_train_val['cat_id'].value_counts()  
    testing_group_distribution = df_test['cat_id'].value_counts()  
    
    # Log or print the distribution
    logger(f"Train Set Group Distribution:\n{training_validation_group_distribution}", file=log_file_path)
    logger(f"Testing Set Group Distribution:\n{testing_group_distribution}", file=log_file_path)

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val['gender'].value_counts()
    testing_gender_distribution = df_test['gender'].value_counts()
    
    # Log the distribution
    logger(f"Training Set Gender Distribution BEFORE SWAP:\n{training_gender_distribution}", file=log_file_path)
    logger(f"Testing Set Gender Distribution BEFORE SWAP:\n{testing_gender_distribution}", file=log_file_path)

    # Group by 'age_group' and then list unique 'cat_id' within each age group
    unique_cat_ids_per_age_group_train_val = df_train_val.groupby('age_group')['cat_id'].unique()
    unique_cat_ids_per_age_group_test = df_test.groupby('age_group')['cat_id'].unique()
    
    # Log results
    logger(f"Unique Cat IDs per Age Group in Training/Validation Set:\n{unique_cat_ids_per_age_group_train_val}", file=log_file_path)
    logger(f"Unique Cat IDs per Age Group in Testing Set:\n{unique_cat_ids_per_age_group_test}", file=log_file_path)

    # Calculate the count of unique identifiers per age group for training and testing set
    counts_train_val = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_train_val.items()}
    counts_test = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_test.items()}

    # Log the counts of unique identifiers per age group
    logger(f"Count of Unique Cat IDs per Age Group in Training/Validation Set:\n{counts_train_val}", file=log_file_path)
    logger(f"Count of Unique Cat IDs per Age Group in Testing Set:\n{counts_test}", file=log_file_path)

    #######################################################
    # CONTINUE WITH ENSURING VALID AND APPROPRIATE SPLITS #
    #######################################################
    
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    groups_train_val, groups_test = groups[train_val_idx], groups[test_idx]

    # logging identifier splits 
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)

    # check group splits
    check_initial_group_split(groups_train_val, groups_test)

    # Specify the cat_ids that must be in the training/validation set
    specific_cat_ids = ['000A', '046A']
    
    # Perform the swapping operation
    train_val_idx, test_idx = swap_cat_id_instances(dataframe, train_val_idx, test_idx, specific_cat_ids)
    
    # Re-assign the sets based on the updated indices
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    new_groups_train_val, new_groups_test = groups[train_val_idx], groups[test_idx]

    # Find differences for training and test sets
    moved_to_train_val, removed_from_train_val = find_group_differences(groups_train_val, new_groups_train_val)
    moved_to_test, removed_from_test = find_group_differences(groups_test, new_groups_test)
    
    # Display the results
    logger(f"Moved to Training/Validation Set:\n{moved_to_train_val}", file=log_file_path)
    logger(f"Removed from Training/Validation Set:\n{removed_from_train_val}", file=log_file_path)
    logger(f"Moved to Test Set:\n{moved_to_test}", file=log_file_path)
    logger(f"Removed from Test Set\n{removed_from_test}", file=log_file_path)

    # Update X_train_val, X_test, y_train_val, y_test, groups_train_val, groups_test based on updated indices
    X_train_val = X[train_val_idx]
    y_train_val = y[train_val_idx]
    groups_train_val = groups[train_val_idx]
    
    X_test = X[test_idx]
    y_test = y[test_idx]
    groups_test = groups[test_idx]

    # logging identifier splits again after potential swaps
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"AFTER SWAP - Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"AFTER SWAP - Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)
    
    # Verify the lengths are consistent
    logger(f"Length of X_train_val:\n{len(X_train_val)}", file=log_file_path)
    logger(f"Length of y_train_val:\n{len(y_train_val)}", file=log_file_path)
    logger(f"Length of groups_train_val:\n{len(groups_train_val)}", file=log_file_path)

    # Check group splits once more
    check_initial_group_split(groups_train_val, groups_test)

    # Convert the modified indices back to a DataFrame representing the updated df_train_val
    df_train_val_updated = dataframe.iloc[train_val_idx].copy()
    df_test_updated = dataframe.iloc[test_idx].copy()

    ############################
    # LOGGING AGE GROUP SPLITS #
    ############################

    # Get the distribution of age groups of age groups before the update
    training_validation_age_group_distribution = df_train_val['age_group'].value_counts()
    testing_age_group_distribution = df_test['age_group'].value_counts()
    
    # Logthe distribution
    logger(f"Train Age Group Distribution BEFORE SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution BEFORE SWAP:\n{testing_age_group_distribution}", file=log_file_path)

    # Get the distribution of age groups after the update
    training_validation_age_group_distribution = df_train_val_updated['age_group'].value_counts()
    testing_age_group_distribution = df_test_updated['age_group'].value_counts()
    
    # Log the distribution
    logger(f"Train Age Group Distribution AFTER SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution AFTER SWAP:\n{testing_age_group_distribution}", file=log_file_path)
    
    ########################################################
    # TRACKING FINAL CAT_IDs & GENDER AFTER REDISTRIBUTION #
    ########################################################

    # Get the distribution of groups
    training_validation_group_distribution = df_train_val_updated['cat_id'].value_counts()  
    testing_group_distribution = df_test_updated['cat_id'].value_counts()  

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val_updated['gender'].value_counts()
    testing_gender_distribution = df_test_updated['gender'].value_counts()
    
    logger(f"\n Starting training on unseen test set\n", file=log_file_path)

    ###################
    # PREPARING MODEL #
    ###################

    # Calculate the distribution of age groups in y_train_val
    age_group_distribution = Counter(y_train_val)
    print("Age group distribution:", age_group_distribution)

    # EarlyStopping callback: monitor 'loss' instead of 'val_loss' for the test set
    early_stopping = EarlyStopping(
        monitor='loss',  
        min_delta=0.001, 
        patience=30,  
        verbose=1,  
        restore_best_weights=True  
    )

    # One final shuffle to ensure randomness
    outer_shuffle_idx = np.random.permutation(len(X_train_val))
    X_train_val = X_train_val[outer_shuffle_idx]
    y_train_val = y_train_val[outer_shuffle_idx]
    
    # Scale the features
    scaler_full = StandardScaler().fit(X_train_val)
    X_train_full_scaled = scaler_full.transform(X_train_val)
    X_test_scaled = scaler_full.transform(X_test)
    
    # Convert features to TensorFlow tensors
    X_train_full_scaled = tf.convert_to_tensor(X_train_full_scaled, dtype=tf.float32)
    X_test_scaled = tf.convert_to_tensor(X_test_scaled, dtype=tf.float32)
    
    # One-hot encode labels before mixup
    y_train_full_encoded = to_categorical(y_train_val)
    y_test_encoded = to_categorical(y_test)
    
    # Convert labels to TensorFlow tensors
    y_train_full_encoded = tf.convert_to_tensor(y_train_full_encoded, dtype=tf.float32)
    
    # Apply Mixup
    X_train_mix_outer, y_train_mix_outer = mixup_data(X_train_full_scaled, y_train_full_encoded, alpha=0.2)
    
    #######################
    # BUILD & TRAIN MODEL #
    #######################

    optimizers = {
        'Adamax': Adamax(learning_rate=0.00510251984616472)
    }
    
    # Model definition with dynamic number of layers
    model_full = Sequential()
    model_full.add(Dense(480, activation='relu', input_shape=(X_train_full_scaled.shape[1],)))
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.2011047009431978))  
    model_full.add(Dense(256, activation='relu',)) 
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.14956886311951184))  
    model_full.add(Dense(256, activation='relu'))  
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.42291461228250665))  
    model_full.add(Dense(3, activation='softmax'))  
    
    # Use the optimizer from the parameters
    optimizer = optimizers['Adamax']  # optimizer_key from parameters
    
    # Compile the model
    model_full.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    
    # Train the model on the full training set
    history_full = model_full.fit(X_train_mix_outer, y_train_mix_outer, epochs=1500, batch_size=64,
                                  verbose=1, callbacks=[early_stopping])
    
    # Evaluate the model on the held-out test set
    test_loss, test_accuracy = model_full.evaluate(X_test_scaled, y_test_encoded)

    y_test_pred_prob = model_full.predict(X_test_scaled)
    y_test_pred = np.argmax(y_test_pred_prob, axis=1)  
    y_test_true = np.argmax(y_test_encoded, axis=1)    

    ################################
    # LOG MAJORITY VOTE PER CAT_ID #
    ################################

    # Convert numeric predictions back to age group labels
    predicted_age_groups = label_encoder.inverse_transform(y_test_pred)
    actual_labels = label_encoder.inverse_transform(y_test_true)
    
    # Map predictions and actual labels back to cat_ids
    test_results = pd.DataFrame({
        'cat_id': df_test_updated['cat_id'],
        'predicted_age_group': predicted_age_groups,
        'actual_age_group': actual_labels
    })
    
    # Group by cat_id and aggregate predicted age groups
    majority_votes = test_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
    actual_groups = test_results.groupby('cat_id')['actual_age_group'].first()
    
    # Calculate the accuracy of majority voting
    correct_predictions = (majority_votes == actual_groups).sum()
    total_cats = len(actual_groups)
    majority_vote_accuracy = correct_predictions / total_cats
    
    # Log the accuracy of the majority voting
    logger(f"Majority Vote Accuracy for cat_id for this fold: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

    ####################################################
    # COLLECT PREDICTIONS FOR GENDER & CAT_ID ANALYSIS #
    ####################################################

    # Debugging print statements
    print(f'Before appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Extend lists with current fold results
    all_cat_ids.extend(df_test_updated['cat_id'].tolist())
    all_predicted_age_groups.extend(predicted_age_groups)
    all_actual_age_groups.extend(actual_labels)
    all_gender.extend(df_test_updated['gender'].tolist())

    # Debugging print statements
    print(f'After appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Calculate additional metrics
    test_precision = precision_score(y_test_true, y_test_pred, average='macro')  # Use 'macro' for imbalanced datasets
    test_recall = recall_score(y_test_true, y_test_pred, average='macro')
    test_f1 = f1_score(y_test_true, y_test_pred, average='macro')

    # prepare averages of outer metrics
    unseen_f1.append(test_f1)
    unseen_losses.append(test_loss)
    unseen_accuracies.append(test_accuracy)
    unseen_precisions.append(test_precision)
    unseen_recalls.append(test_recall)

    # Print final test results
    logger(f"Final Test Results - Loss: {test_loss}, Accuracy: {test_accuracy}, Precision: {test_precision}, Recall: {test_recall}, F1 Score: {test_f1}", file=log_file_path)

    # Generate the confusion matrix
    cm = confusion_matrix(y_test, y_test_pred)
    logger(f"Confusion Matrix:\n {cm}", file=log_file_path)

# Calculate the overall average metrics
unseen_set_avg_f1 = np.mean(unseen_f1)
unseen_set_avg_loss = np.mean(unseen_losses)
unseen_set_avg_acc = np.mean(unseen_accuracies)
unseen_set_avg_precision = np.mean(unseen_precisions)
unseen_set_avg_recall = np.mean(unseen_recalls)

logger(f"\nFinal Average F1-Score across all UNSEEN TEST sets: {unseen_set_avg_f1}", file=log_file_path)
logger(f"\nFinal Average Loss across all UNSEEN TEST sets: {unseen_set_avg_loss}", file=log_file_path)
logger(f"\nFinal Average Accuracy across all UNSEEN TEST sets: {unseen_set_avg_acc}", file=log_file_path)
logger(f"\nFinal Average Precision across all UNSEEN TEST sets: {unseen_set_avg_precision}", file=log_file_path)
logger(f"\nFinal Average Recall across all UNSEEN TEST sets: {unseen_set_avg_recall}\n", file=log_file_path)

# Append averages to total lists
all_f1.append(unseen_set_avg_f1)
all_losses.append(unseen_set_avg_loss)
all_accuracies.append(unseen_set_avg_acc)
all_precisions.append(unseen_set_avg_precision)
all_recalls.append(unseen_set_avg_recall)
# Out:
# outer_fold 1
# Train Set Group Distribution:
# 046A    45
# 103A    33
# 002B    30
# 047A    22
# 020A    20
#         ..
# 110A     1
# 064A     1
# 100A     1
# 090A     1
# 024A     1
# Name: cat_id, Length: 85, dtype: int64
# Testing Set Group Distribution:
# 000A    39
# 000B    19
# 019A    17
# 097A    15
# 051A    12
# 063A    11
# 028A    11
# 059A    10
# 040A    10
# 022A     9
# 005A     9
# 013B     8
# 095A     7
# 036A     7
# 039A     6
# 003A     4
# 018A     2
# 087A     2
# 069A     2
# 076A     1
# 091A     1
# 043A     1
# 049A     1
# 041A     1
# 048A     1
# 019B     1
# 026B     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    249
# X    203
# F    133
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# F    98
# X    73
# M    37
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [006A, 033A, 015A, 001A, 103A, 071A, 097B, 074...
# kitten    [044A, 014B, 111A, 046A, 047A, 042A, 109A, 050...
# senior    [093A, 057A, 106A, 104A, 055A, 113A, 116A, 051...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [000A, 028A, 019A, 022A, 095A, 005A, 091A, 039...
# kitten                       [040A, 043A, 049A, 041A, 048A]
# senior                                   [097A, 059A, 051A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 55, 'kitten': 11, 'senior': 19}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 19, 'kitten': 5, 'senior': 3}
# Unique Training/Validation Group IDs:
# ['001A' '002A' '002B' '004A' '006A' '007A' '008A' '009A' '010A' '011A'
#  '012A' '014A' '014B' '015A' '016A' '020A' '021A' '023A' '023B' '024A'
#  '025A' '025B' '025C' '026A' '026C' '027A' '029A' '031A' '032A' '033A'
#  '034A' '035A' '037A' '038A' '042A' '044A' '045A' '046A' '047A' '050A'
#  '051B' '052A' '053A' '054A' '055A' '056A' '057A' '058A' '060A' '061A'
#  '062A' '064A' '065A' '066A' '067A' '068A' '070A' '071A' '072A' '073A'
#  '074A' '075A' '088A' '090A' '092A' '093A' '094A' '096A' '097B' '099A'
#  '100A' '101A' '102A' '103A' '104A' '105A' '106A' '108A' '109A' '110A'
#  '111A' '113A' '115A' '116A' '117A']
# Unique Test Group IDs:
# ['000A' '000B' '003A' '005A' '013B' '018A' '019A' '019B' '022A' '026B'
#  '028A' '036A' '039A' '040A' '041A' '043A' '048A' '049A' '051A' '059A'
#  '063A' '069A' '076A' '087A' '091A' '095A' '097A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'000A'}
# Removed from Training/Validation Set:
# {'009A'}
# Moved to Test Set:
# {'009A'}
# Removed from Test Set
# {'000A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '001A' '002A' '002B' '004A' '006A' '007A' '008A' '010A' '011A'
#  '012A' '014A' '014B' '015A' '016A' '020A' '021A' '023A' '023B' '024A'
#  '025A' '025B' '025C' '026A' '026C' '027A' '029A' '031A' '032A' '033A'
#  '034A' '035A' '037A' '038A' '042A' '044A' '045A' '046A' '047A' '050A'
#  '051B' '052A' '053A' '054A' '055A' '056A' '057A' '058A' '060A' '061A'
#  '062A' '064A' '065A' '066A' '067A' '068A' '070A' '071A' '072A' '073A'
#  '074A' '075A' '088A' '090A' '092A' '093A' '094A' '096A' '097B' '099A'
#  '100A' '101A' '102A' '103A' '104A' '105A' '106A' '108A' '109A' '110A'
#  '111A' '113A' '115A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['000B' '003A' '005A' '009A' '013B' '018A' '019A' '019B' '022A' '026B'
#  '028A' '036A' '039A' '040A' '041A' '043A' '048A' '049A' '051A' '059A'
#  '063A' '069A' '076A' '087A' '091A' '095A' '097A']
# Length of X_train_val:
# 620
# Length of y_train_val:
# 620
# Length of groups_train_val:
# 620
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     352
# kitten    121
# senior    112
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     157
# senior     37
# kitten     14
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     387
# kitten    121
# senior    112
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     122
# senior     37
# kitten     14
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 387, 1: 121, 2: 112})
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Epoch 1/1500
# 10/10 [==============================] - 1s 5ms/step - loss: 1.2134 - accuracy: 0.6065
# Epoch 2/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4983 - accuracy: 0.8823
# Epoch 3/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3973 - accuracy: 0.9129
# Epoch 4/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.3434 - accuracy: 0.9226
# Epoch 5/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3154 - accuracy: 0.9290
# Epoch 6/1500
# 10/10 [==============================] - 0s 9ms/step - loss: 0.3106 - accuracy: 0.9613
# Epoch 7/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2540 - accuracy: 0.9532
# Epoch 8/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2556 - accuracy: 0.9548
# Epoch 9/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2356 - accuracy: 0.9629
# Epoch 10/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2438 - accuracy: 0.9613
# Epoch 11/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2352 - accuracy: 0.9468
# Epoch 12/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2325 - accuracy: 0.9629
# Epoch 13/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2291 - accuracy: 0.9581
# Epoch 14/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2105 - accuracy: 0.9613
# Epoch 15/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2204 - accuracy: 0.9532
# Epoch 16/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2122 - accuracy: 0.9645
# Epoch 17/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2226 - accuracy: 0.9500
# Epoch 18/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2069 - accuracy: 0.9629
# Epoch 19/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2098 - accuracy: 0.9500
# Epoch 20/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2172 - accuracy: 0.9613
# Epoch 21/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2011 - accuracy: 0.9613
# Epoch 22/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2021 - accuracy: 0.9516
# Epoch 23/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2021 - accuracy: 0.9565
# Epoch 24/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2012 - accuracy: 0.9774
# Epoch 25/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1970 - accuracy: 0.9565
# Epoch 26/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1962 - accuracy: 0.9581
# Epoch 27/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1948 - accuracy: 0.9532
# Epoch 28/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1877 - accuracy: 0.9565
# Epoch 29/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.
1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1447 - accuracy: 0.9823
# Epoch 221/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1454 - accuracy: 0.9774
# Epoch 222/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1430 - accuracy: 0.9790
# Epoch 223/1500
# 10/10 [==============================] - 0s 12ms/step - loss: 0.1469 - accuracy: 0.9871
# Epoch 224/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1431 - accuracy: 0.9742
# Epoch 225/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1455 - accuracy: 0.9790
# Epoch 226/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1475 - accuracy: 0.9758
# Epoch 227/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1458 - accuracy: 0.9806
# Epoch 228/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1454 - accuracy: 0.9774
# Epoch 229/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1450 - accuracy: 0.9774
# Epoch 230/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1467 - accuracy: 0.9774
# Epoch 231/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1451 - accuracy: 0.9887
# Epoch 232/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1454 - accuracy: 0.9742
# Epoch 233/1500
# 10/10 [==============================] - ETA: 0s - loss: 0.1470 - accuracy: 0.9823Restoring model weights from the end of the best epoch: 203.
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1470 - accuracy: 0.9823
# Epoch 233: early stopping
# 6/6 [==============================] - 0s 1ms/step - loss: 0.8772 - accuracy: 0.7341
# 6/6 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.70 (19/27)
# Before appending - Cat IDs: 0, Predictions: 0, Actuals: 0, Gender: 0
# After appending - Cat IDs: 173, Predictions: 173, Actuals: 173, Gender: 173
# Final Test Results - Loss: 0.8771759867668152, Accuracy: 0.7341040372848511, Precision: 0.6879731379731381, Recall: 0.6918264869084542, F1 Score: 0.6897719505375007
# Confusion Matrix:
#  [[98  3 21]
#  [ 3 11  0]
#  [19  0 18]]
# outer_fold 2
# Train Set Group Distribution:
# 046A    45
# 000A    39
# 103A    33
# 002B    30
# 020A    20
#         ..
# 041A     1
# 092A     1
# 049A     1
# 043A     1
# 026B     1
# Name: cat_id, Length: 82, dtype: int64
# Testing Set Group Distribution:
# 047A    22
# 029A    15
# 097B    14
# 002A    13
# 111A    12
# 042A    11
# 051B     9
# 071A     9
# 072A     9
# 117A     7
# 027A     7
# 099A     6
# 023A     6
# 109A     5
# 025C     4
# 026A     4
# 056A     3
# 012A     3
# 010A     3
# 060A     3
# 006A     3
# 105A     3
# 052A     2
# 054A     2
# 061A     2
# 102A     2
# 037A     2
# 093A     2
# 090A     1
# 024A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    228
# F    195
# X    185
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    91
# M    58
# F    36
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [000A, 033A, 015A, 001A, 103A, 028A, 019A, 074...
# kitten    [044A, 014B, 040A, 046A, 050A, 043A, 049A, 041...
# senior    [097A, 057A, 106A, 104A, 055A, 059A, 113A, 116...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [006A, 071A, 097B, 029A, 072A, 002A, 023A, 027...
# kitten                             [111A, 047A, 042A, 109A]
# senior     [093A, 051B, 054A, 117A, 056A, 061A, 090A, 024A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 56, 'kitten': 12, 'senior': 14}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 18, 'kitten': 4, 'senior': 8}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002B' '003A' '004A' '005A' '007A' '008A' '009A'
#  '011A' '013B' '014A' '014B' '015A' '016A' '018A' '019A' '019B' '020A'
#  '021A' '022A' '023B' '025A' '025B' '026B' '026C' '028A' '031A' '032A'
#  '033A' '034A' '035A' '036A' '038A' '039A' '040A' '041A' '043A' '044A'
#  '045A' '046A' '048A' '049A' '050A' '051A' '053A' '055A' '057A' '058A'
#  '059A' '062A' '063A' '064A' '065A' '066A' '067A' '068A' '069A' '070A'
#  '073A' '074A' '075A' '076A' '087A' '088A' '091A' '092A' '094A' '095A'
#  '096A' '097A' '100A' '101A' '103A' '104A' '106A' '108A' '110A' '113A'
#  '115A' '116A']
# Unique Test Group IDs:
# ['002A' '006A' '010A' '012A' '023A' '024A' '025C' '026A' '027A' '029A'
#  '037A' '042A' '047A' '051B' '052A' '054A' '056A' '060A' '061A' '071A'
#  '072A' '090A' '093A' '097B' '099A' '102A' '105A' '109A' '111A' '117A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002B' '003A' '004A' '005A' '007A' '008A' '009A'
#  '011A' '013B' '014A' '014B' '015A' '016A' '018A' '019A' '019B' '020A'
#  '021A' '022A' '023B' '025A' '025B' '026B' '026C' '028A' '031A' '032A'
#  '033A' '034A' '035A' '036A' '038A' '039A' '040A' '041A' '043A' '044A'
#  '045A' '046A' '048A' '049A' '050A' '051A' '053A' '055A' '057A' '058A'
#  '059A' '062A' '063A' '064A' '065A' '066A' '067A' '068A' '069A' '070A'
#  '073A' '074A' '075A' '076A' '087A' '088A' '091A' '092A' '094A' '095A'
#  '096A' '097A' '100A' '101A' '103A' '104A' '106A' '108A' '110A' '113A'
#  '115A' '116A']
# AFTER SWAP - Unique Test Group IDs:
# ['002A' '006A' '010A' '012A' '023A' '024A' '025C' '026A' '027A' '029A'
#  '037A' '042A' '047A' '051B' '052A' '054A' '056A' '060A' '061A' '071A'
#  '072A' '090A' '093A' '097B' '099A' '102A' '105A' '109A' '111A' '117A']
# Length of X_train_val:
# 608
# Length of y_train_val:
# 608
# Length of groups_train_val:
# 608
# No common groups found between train and test sets.
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Train Age Group Distribution BEFORE SWAP:
# adult     401
# senior    122
# kitten     85
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     108
# kitten     50
# senior     27
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     401
# senior    122
# kitten     85
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     108
# kitten     50
# senior     27
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 401, 2: 122, 1: 85})
# Epoch 1/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 1.2303 - accuracy: 0.6151
# Epoch 2/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4834 - accuracy: 0.8553
# Epoch 3/1500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3533 - accuracy: 0.9178
# Epoch 4/1500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3275 - accuracy: 0.9408
# Epoch 5/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2961 - accuracy: 0.9375
# Epoch 6/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2610 - accuracy: 0.9605
# Epoch 7/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2315 - accuracy: 0.9572
# Epoch 8/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2457 - accuracy: 0.9490
# Epoch 9/1500
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2315 - accuracy: 0.9572
# Epoch 10/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2350 - accuracy: 0.9688
# Epoch 11/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2234 - accuracy: 0.9556
# Epoch 12/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2179 - accuracy: 0.9490
# Epoch 13/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2078 - accuracy: 0.9539
# Epoch 14/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2094 - accuracy: 0.9605
# Epoch 15/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1939 - accuracy: 0.9655
# Epoch 16/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2065 - accuracy: 0.9539
# Epoch 17/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2046 - accuracy: 0.9638
# Epoch 18/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2143 - accuracy: 0.9507
# Epoch 19/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2031 - accuracy: 0.9572
# Epoch 20/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2027 - accuracy: 0.9539
# Epoch 21/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1972 - accuracy: 0.9655
# Epoch 22/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2028 - accuracy: 0.9539
# Epoch 23/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2003 - accuracy: 0.9605
# Epoch 24/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2170 - accuracy: 0.9457
# Epoch 25/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1970 - accuracy: 0.9605
# Epoch 26/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1857 - accuracy: 0.9622
# Epoch 27/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1921 - accuracy: 0.9720
# Epoch 28/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1862 - accuracy: 0.9605
# Epoch 29/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1847 - accuracy: 0.9638
# Epoch 30/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1779 - accuracy: 0.9572
# Epoch 31/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1939 - accuracy: 0.9605
# Epoch 32/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1877 - accuracy: 0.9605
# Epoch 33/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.
1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1275 - accuracy: 0.9875
# Epoch 189/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1271 - accuracy: 0.9734
# Epoch 190/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1273 - accuracy: 0.9844
# Epoch 191/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1283 - accuracy: 0.9875
# Epoch 192/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1283 - accuracy: 0.9719
# Epoch 193/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1262 - accuracy: 0.9937
# Epoch 194/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1325 - accuracy: 0.9781
# Epoch 195/1500
# 10/10 [==============================] - ETA: 0s - loss: 0.1298 - accuracy: 0.9828Restoring model weights from the end of the best epoch: 165.
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1298 - accuracy: 0.9828
# Epoch 195: early stopping
# 5/5 [==============================] - 0s 2ms/step - loss: 1.1951 - accuracy: 0.6013
# 5/5 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.73 (19/26)
# Before appending - Cat IDs: 561, Predictions: 561, Actuals: 561, Gender: 561
# After appending - Cat IDs: 714, Predictions: 714, Actuals: 714, Gender: 714
# Final Test Results - Loss: 1.1951110363006592, Accuracy: 0.601307213306427, Precision: 0.6132633844498251, Recall: 0.5740294511378848, F1 Score: 0.5618655061052872
# Confusion Matrix:
#  [[71  4  8]
#  [ 3 10  2]
#  [44  0 11]]
#
# Final Average F1-Score across all UNSEEN TEST sets: 0.5685774476381644
#
# Final Average Loss across all UNSEEN TEST sets: 1.1585907191038132
#
# Final Average Accuracy across all UNSEEN TEST sets: 0.6614656448364258
#
# Final Average Precision across all UNSEEN TEST sets: 0.6183447199908377
#
# Final Average Recall across all UNSEEN TEST sets: 0.5830135205901064

# %%
seed_1_folds_values = (unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1)

# Plotting all fold metrics
seed_1_folds_plot = plot_all_metrics(unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1, "Folds", "Fold Number")

# %% [markdown]
# ## Majority Voting on Total Entries per cat_id

# %%
# Debugging print statements
print(f'Checking - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
# Out:
# Checking - Cat IDs: 714, Predictions: 714, Actuals: 714, Gender: 714

# %%
# Create results df
full_results = pd.DataFrame({
    'cat_id': all_cat_ids,
    'predicted_age_group': all_predicted_age_groups,
    'actual_age_group': all_actual_age_groups,
    'all_gender': all_gender
})

# create a correct majority prediction column
full_results['correct'] = full_results['predicted_age_group'] == full_results['actual_age_group']

# %%
# Group by cat_id and aggregate predicted age groups
majority_votes = full_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first()

# Calculate the accuracy of majority voting
correct_predictions = (majority_votes == actual_groups).sum()
total_cats = len(actual_groups)
majority_vote_accuracy = correct_predictions / total_cats

logger(f"Overall Majority Vote Accuracy for cat_id: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

# store for final evaluation 
all_majority_vote_accuracies.append(majority_vote_accuracy)
# Out:
# Overall Majority Vote Accuracy for cat_id: 0.73 (80/110)

# %%
# Detailed df with predictions, actual labels, and comparison including majority vote
detailed_results = full_results.groupby('cat_id').apply(
    lambda x: pd.Series({
        'Predictions': list(x['predicted_age_group']),
        'Majority Vote': x['predicted_age_group'].mode()[0],
        'Actual Age Group': x['actual_age_group'].iloc[0],
        'Correct Majority Vote': x['predicted_age_group'].mode()[0] == x['actual_age_group'].iloc[0]
    })
).reset_index()

# Convert to DataFrame for better formatting and display
detailed_results = pd.DataFrame(detailed_results)

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 10)
pd.set_option('display.width', 1000)

sorted_detailed_results = detailed_results.sort_values(by='Correct Majority Vote', ascending=False)

# Display the sorted DataFrame
sorted_detailed_results
# Out:
#     cat_id                                        Predictions Majority Vote Actual Age Group  Correct Majority Vote
# 0     000B  [adult, senior, adult, adult, adult, adult, ad...         adult            adult                   True
# 66    060A                              [adult, adult, adult]         adult            adult                   True
# 77    071A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 76    070A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 74    068A  [senior, adult, adult, adult, senior, adult, s...         adult            adult                   True
# 73    067A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 72    066A                                            [adult]         adult            adult                   True
# 71    065A  [senior, adult, adult, adult, adult, adult, ad...         adult            adult                   True
# 69    063A  [kitten, adult, senior, adult, adult, adult, a...         adult            adult                   True
# 68    062A                              [adult, adult, adult]         adult            adult                   True
# 65    059A  [senior, senior, senior, senior, senior, senio...        senior           senior                   True
# 79    073A                                            [adult]         adult            adult                   True
# 64    058A                           [senior, kitten, senior]        senior           senior                   True
# 62    056A                            [senior, senior, adult]        senior           senior                   True
# 59    053A                              [adult, adult, adult]         adult            adult                   True
# 58    052A                                    [adult, senior]         adult            adult                   True
# 53    048A                                           [kitten]        kitten           kitten                   True
# 51    045A                   [kitten, kitten, kitten, kitten]        kitten           kitten                   True
# 50    044A           [kitten, kitten, kitten, kitten, kitten]        kitten           kitten                   True
# 49    043A                                   [kitten, kitten]        kitten           kitten                   True
# 78    072A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 80    074A  [adult, adult, kitten, adult, adult, adult, ad...         adult            adult                   True
# 45    039A         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 94    099A         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 107   115A                                           [kitten]        kitten           kitten                   True
# 105   111A  [senior, kitten, kitten, kitten, kitten, kitte...        kitten           kitten                   True
# 104   110A                                           [kitten]        kitten           kitten                   True
# 100   105A                              [adult, adult, adult]         adult            adult                   True
# 98    103A  [adult, adult, adult, adult, adult, senior, ad...         adult            adult                   True
# 97    102A                                    [adult, senior]         adult            adult                   True
# 96    101A  [senior, adult, adult, adult, senior, adult, a...         adult            adult                   True
# 95    100A                                            [adult]         adult            adult                   True
# 93    097B  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 81    075A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 91    096A                                            [adult]         adult            adult                   True
# 90    095A  [senior, adult, adult, adult, adult, adult, ad...         adult            adult                   True
# 89    094A             [senior, adult, senior, adult, senior]        senior           senior                   True
# 87    092A                                            [adult]         adult            adult                   True
# 85    090A                                           [senior]        senior           senior                   True
# 84    088A                                            [adult]         adult            adult                   True
# 83    087A                                     [adult, adult]         adult            adult                   True
# 82    076A                                            [adult]         adult            adult                   True
# 46    040A  [kitten, kitten, kitten, kitten, adult, kitten...        kitten           kitten                   True
# 55    050A           [senior, kitten, kitten, kitten, kitten]        kitten           kitten                   True
# 24    022A  [adult, adult, kitten, kitten, adult, adult, a...         adult            adult                   True
# 25    023A        [adult, senior, adult, adult, adult, adult]         adult            adult                   True
# 31    026A                       [adult, adult, adult, adult]         adult            adult                   True
# 30    025C                       [adult, adult, adult, adult]         adult            adult                   True
# 8     007A         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 29    025B                                    [senior, adult]         adult            adult                   True
# 28    025A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 9     008A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 26    023B                       [adult, adult, adult, adult]         adult            adult                   True
# 10    009A  [adult, adult, senior, adult, adult, adult, ad...         adult            adult                   True
# 43    037A                                    [senior, adult]         adult            adult                   True
# 14    013B  [adult, adult, adult, senior, adult, adult, ad...         adult            adult                   True
# 23    021A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 22    020A  [adult, senior, adult, adult, adult, adult, ad...         adult            adult                   True
# 11    010A                             [adult, adult, senior]         adult            adult                   True
# 20    019A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 19    018A                                     [adult, adult]         adult            adult                   True
# 17    015A  [adult, adult, adult, senior, adult, adult, ad...         adult            adult                   True
# 16    014B  [senior, kitten, adult, adult, kitten, kitten,...        kitten           kitten                   True
# 15    014A                              [adult, adult, adult]         adult            adult                   True
# 7     006A                              [adult, adult, adult]         adult            adult                   True
# 32    026B                                            [adult]         adult            adult                   True
# 33    026C                                            [adult]         adult            adult                   True
# 4     003A                       [adult, adult, adult, adult]         adult            adult                   True
# 42    036A  [senior, adult, adult, adult, adult, adult, ad...         adult            adult                   True
# 2     002A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 41    035A                                     [adult, adult]         adult            adult                   True
# 40    034A                             [adult, adult, kitten]         adult            adult                   True
# 39    033A  [adult, adult, adult, adult, adult, senior, ad...         adult            adult                   True
# 38    032A                                    [adult, kitten]         adult            adult                   True
# 34    027A  [adult, adult, adult, adult, senior, adult, ad...         adult            adult                   True
# 3     002B  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 37    031A  [adult, adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 5     004A                                            [adult]         adult            adult                   True
# 35    028A  [senior, adult, adult, senior, adult, adult, a...         adult            adult                   True
# 13    012A                              [adult, adult, adult]         adult            adult                   True
# 103   109A                [adult, adult, adult, adult, adult]         adult           kitten                  False
# 102   108A               [adult, adult, adult, senior, adult]         adult           senior                  False
# 106   113A                             [adult, adult, senior]         adult           senior                  False
# 101   106A  [adult, adult, adult, senior, adult, adult, ad...         adult           senior                  False
# 99    104A                       [adult, adult, adult, adult]         adult           senior                  False
# 92    097A  [senior, senior, adult, adult, adult, senior, ...         adult           senior                  False
# 108   116A  [senior, senior, adult, senior, adult, adult, ...         adult           senior                  False
# 12    011A                                    [adult, senior]         adult           senior                  False
# 6     005A  [senior, senior, senior, senior, senior, senio...        senior            adult                  False
# 44    038A                                   [kitten, kitten]        kitten            adult                  False
# 88    093A                                     [adult, adult]         adult           senior                  False
# 86    091A                                           [senior]        senior            adult                  False
# 47    041A                                            [adult]         adult           kitten                  False
# 48    042A  [senior, adult, adult, adult, adult, adult, ad...         adult           kitten                  False
# 52    047A  [adult, adult, adult, adult, adult, adult, adu...         adult           kitten                  False
# 54    049A                                            [adult]         adult           kitten                  False
# 1     001A  [adult, senior, adult, senior, senior, senior,...        senior            adult                  False
# 56    051A  [adult, adult, adult, adult, adult, adult, adu...         adult           senior                  False
# 57    051B  [adult, adult, adult, adult, adult, adult, adu...         adult           senior                  False
# 36    029A  [senior, senior, senior, senior, adult, senior...        senior            adult                  False
# 60    054A                                     [adult, adult]         adult           senior                  False
# 61    055A  [adult, senior, adult, adult, adult, senior, a...         adult           senior                  False
# 63    057A  [adult, adult, adult, adult, adult, adult, adu...         adult           senior                  False
# 67    061A                                     [adult, adult]         adult           senior                  False
# 70    064A                                           [kitten]        kitten            adult                  False
# 27    024A                                            [adult]         adult           senior                  False
# 75    069A                                   [senior, senior]        senior            adult                  False
# 21    019B                                           [senior]        senior            adult                  False
# 18    016A  [adult, adult, adult, adult, adult, adult, adu...         adult           senior                  False
# 109   117A  [adult, adult, senior, adult, adult, adult, ad...         adult           senior                  False

# %%
# Create df for majority votes
majority_df = majority_votes.reset_index()
majority_df.columns = ['cat_id', 'Majority_Vote']

# Get actual groups for each cat_id
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first().reset_index()

# Merge majority votes with actual groups
majority_with_actual = pd.merge(majority_df, actual_groups, on='cat_id')

# Add a column to check if the majority vote was correct
majority_with_actual['Majority_Correct'] = majority_with_actual['Majority_Vote'] == majority_with_actual['actual_age_group']

# Count correct majority votes per class
correct_majority_votes_per_class = majority_with_actual.groupby('actual_age_group')['Majority_Correct'].sum()

print("Correct Majority Votes per Class:")
print(correct_majority_votes_per_class)
# Out:
# Correct Majority Votes per Class:
# actual_age_group
# adult     65
# kitten    10
# senior     5
# Name: Majority_Correct, dtype: int64

# %%
# Calculate the total count and the number of correct predictions for each class
class_stats = majority_with_actual.groupby('actual_age_group').agg(
    total_count=('Majority_Correct', 'size'),  # Total number of cases per class
    correct_count=('Majority_Correct', 'sum')  # Sum of correct predictions per class
).reset_index()

# Calculate accuracy for each class
class_stats['accuracy'] = class_stats['correct_count'] / class_stats['total_count'] * 100

# store for final evaluation 
all_majority_vote_details.append(class_stats)

# Log detailed stats
print("Detailed Class Statistics for Majority Votes:")
print(class_stats)
# Out:
# Detailed Class Statistics for Majority Votes:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult           73             65  89.041096
# 1           kitten           15             10  66.666667
# 2           senior           22              5  22.727273

# %%
# Plot for Detailed Class Statistics for Majority Votes
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Accuracy of Majority Votes by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Detailed Class Statistics

# %%
# Calculate the total count and the number of correct predictions for each class
class_stats = full_results.groupby('actual_age_group').agg(
    total_count=('correct', 'size'),
    correct_count=('correct', 'sum')
).reset_index()

# Calculate accuracy for each class
class_stats['accuracy'] = class_stats['correct_count'] / class_stats['total_count'] * 100

# store for final evaluation 
all_class_stats.append(class_stats)

# Log the detailed stats
print("Detailed Class Statistics:")
print(class_stats)
# Out:
# Detailed Class Statistics:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult          474            391  82.489451
# 1           kitten           91             43  47.252747
# 2           senior          149             41  27.516779

# %%
# Plot for Detailed Class Statistics (Overall)
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Overall Accuracy by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Gender Exploration

# %%
# Group by gender and calculate the total count, correct predictions, and accuracy
gender_stats = full_results.groupby('all_gender').agg(
    count=('cat_id', 'size'),  # Total number of cases per gender
    correct=('correct', 'sum')  # Sum of correct predictions per gender
).reset_index()

# Calculate accuracy for each gender
gender_stats['accuracy'] = (gender_stats['correct'] / gender_stats['count'] * 100).round(2)

# Display the DataFrame
print("Accuracy by Gender:")
print(gender_stats)

# store for final evaluation 
all_gender_stats.append(gender_stats)
# Out:
# Accuracy by Gender:
#   all_gender  count  correct  accuracy
# 0          F    196      135     68.88
# 1          M    286      202     70.63
# 2          X    232      138     59.48

# %%
# Plot for Accuracy by Gender
styled_barplot(gender_stats, 'all_gender', 'accuracy', 
               'Accuracy by Gender', 
               'Gender', 'Accuracy (%)')

# %% [markdown]
# ### Log current total CV Stats

# %%
print("Total Majority Vote Accuracy so far:", all_majority_vote_accuracies)
print("Total Class Statistics so far:\n", all_class_stats)
print("Total Gender Accuracy so far:\n", all_gender_stats)
# Out:
# Total Majority Vote Accuracy so far: [0.7272727272727273]
# Total Class Statistics so far:
#  [  actual_age_group  total_count  correct_count   accuracy
# 0            adult          474            391  82.489451
# 1           kitten           91             43  47.252747
# 2           senior          149             41  27.516779]
# Total Gender Accuracy so far:
#  [  all_gender  count  correct  accuracy
# 0          F    196      135     68.88
# 1          M    286      202     70.63
# 2          X    232      138     59.48]

# %% [markdown]
# # RANDOM SEED 2

# %%
# Set a fixed random seed for reproducibility
random.seed(int(random_seeds[1]))
np.random.seed(int(random_seeds[1]))
tf.random.set_seed(int(random_seeds[1]))

# Load datasets
dataframe = pd.read_csv('/Users/astrid/PycharmProjects/perch-2/scripts/perch_embeddings_april_10.csv')

dataframe.drop('mean_freq', axis=1, inplace=True)

def assign_age_group(age, age_groups):
    for group_name, age_range in age_groups.items():
        if age_range[0] <= age < age_range[1]:
            return group_name
    return 'Unknown'  # For any age that doesn't fit the defined groups

# Define age groups
age_groups = {
    'kitten': (0, 0.5),
    'adult': (0.5, 12),
    'senior': (12, 20)
}

# Create a new column for the age group
dataframe['age_group'] = dataframe['target'].apply(assign_age_group, age_groups=age_groups)

print(dataframe['age_group'].value_counts())
# Out:
# adult     509
# senior    149
# kitten    135
# Name: age_group, dtype: int64

# %%
# Separate features and labels
X = dataframe.iloc[:, :-4].values  # all columns except the last four

# Encode the 'age_group' column as integers using LabelEncoder
label_encoder = LabelEncoder()
encoded_y = label_encoder.fit_transform(dataframe['age_group'].values)

# Use the encoded labels for splitting and one-hot encoding
y = encoded_y  

# Convert 'cat_id' column to numpy array to be used as groups array for GroupKFold
groups = dataframe['cat_id'].values

# %%
tf.keras.backend.clear_session()

# %% [markdown]
# ## Run Setup

# %%
all_cat_ids = []
all_predicted_age_groups = []
all_actual_age_groups = []
all_gender = []

# Define the StratifiedGroupKFold splitter for 4 fold CV with random shuffling
outer_cv = StratifiedGroupKFold(n_splits=4, shuffle=True, random_state=int(random_seeds[1]))

# unseen test set metrics
unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1 = [], [], [], [], []

outer_fold = 0

# Use the splitter to generate indices for training and testing sets
# Note: GroupShuffleSplit.split returns indices, so we use it to index the arrays
for train_val_idx, test_idx in outer_cv.split(X, y, groups):
    outer_fold += 1
    logger(f"outer_fold {outer_fold}", file=log_file_path)

    # Convert indices back to DataFrame for easy manipulation
    df_train_val = dataframe.iloc[train_val_idx]
    df_test = dataframe.iloc[test_idx]

    ##############################
    # ASSESSING SPLITS BY CAT_ID #
    ##############################
    
    # Get the distribution of groups
    training_validation_group_distribution = df_train_val['cat_id'].value_counts()  
    testing_group_distribution = df_test['cat_id'].value_counts()  
    
    # Log or print the distribution
    logger(f"Train Set Group Distribution:\n{training_validation_group_distribution}", file=log_file_path)
    logger(f"Testing Set Group Distribution:\n{testing_group_distribution}", file=log_file_path)

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val['gender'].value_counts()
    testing_gender_distribution = df_test['gender'].value_counts()
    
    # Log the distribution
    logger(f"Training Set Gender Distribution BEFORE SWAP:\n{training_gender_distribution}", file=log_file_path)
    logger(f"Testing Set Gender Distribution BEFORE SWAP:\n{testing_gender_distribution}", file=log_file_path)

    # Group by 'age_group' and then list unique 'cat_id' within each age group
    unique_cat_ids_per_age_group_train_val = df_train_val.groupby('age_group')['cat_id'].unique()
    unique_cat_ids_per_age_group_test = df_test.groupby('age_group')['cat_id'].unique()
    
    # Log results
    logger(f"Unique Cat IDs per Age Group in Training/Validation Set:\n{unique_cat_ids_per_age_group_train_val}", file=log_file_path)
    logger(f"Unique Cat IDs per Age Group in Testing Set:\n{unique_cat_ids_per_age_group_test}", file=log_file_path)

    # Calculate the count of unique identifiers per age group for training and testing set
    counts_train_val = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_train_val.items()}
    counts_test = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_test.items()}

    # Log the counts of unique identifiers per age group
    logger(f"Count of Unique Cat IDs per Age Group in Training/Validation Set:\n{counts_train_val}", file=log_file_path)
    logger(f"Count of Unique Cat IDs per Age Group in Testing Set:\n{counts_test}", file=log_file_path)

    #######################################################
    # CONTINUE WITH ENSURING VALID AND APPROPRIATE SPLITS #
    #######################################################
    
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    groups_train_val, groups_test = groups[train_val_idx], groups[test_idx]

    # logging identifier splits 
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)

    # check group splits
    check_initial_group_split(groups_train_val, groups_test)

    # Specify the cat_ids that must be in the training/validation set
    specific_cat_ids = ['000A', '046A']
    
    # Perform the swapping operation
    train_val_idx, test_idx = swap_cat_id_instances(dataframe, train_val_idx, test_idx, specific_cat_ids)
    
    # Re-assign the sets based on the updated indices
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    new_groups_train_val, new_groups_test = groups[train_val_idx], groups[test_idx]

    # Find differences for training and test sets
    moved_to_train_val, removed_from_train_val = find_group_differences(groups_train_val, new_groups_train_val)
    moved_to_test, removed_from_test = find_group_differences(groups_test, new_groups_test)
    
    # Display the results
    logger(f"Moved to Training/Validation Set:\n{moved_to_train_val}", file=log_file_path)
    logger(f"Removed from Training/Validation Set:\n{removed_from_train_val}", file=log_file_path)
    logger(f"Moved to Test Set:\n{moved_to_test}", file=log_file_path)
    logger(f"Removed from Test Set\n{removed_from_test}", file=log_file_path)

    # Update X_train_val, X_test, y_train_val, y_test, groups_train_val, groups_test based on updated indices
    X_train_val = X[train_val_idx]
    y_train_val = y[train_val_idx]
    groups_train_val = groups[train_val_idx]
    
    X_test = X[test_idx]
    y_test = y[test_idx]
    groups_test = groups[test_idx]

    # logging identifier splits again after potential swaps
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"AFTER SWAP - Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"AFTER SWAP - Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)
    
    # Verify the lengths are consistent
    logger(f"Length of X_train_val:\n{len(X_train_val)}", file=log_file_path)
    logger(f"Length of y_train_val:\n{len(y_train_val)}", file=log_file_path)
    logger(f"Length of groups_train_val:\n{len(groups_train_val)}", file=log_file_path)

    # Check group splits once more
    check_initial_group_split(groups_train_val, groups_test)

    # Convert the modified indices back to a DataFrame representing the updated df_train_val
    df_train_val_updated = dataframe.iloc[train_val_idx].copy()
    df_test_updated = dataframe.iloc[test_idx].copy()

    ############################
    # LOGGING AGE GROUP SPLITS #
    ############################

    # Get the distribution of age groups of age groups before the update
    training_validation_age_group_distribution = df_train_val['age_group'].value_counts()
    testing_age_group_distribution = df_test['age_group'].value_counts()
    
    # Logthe distribution
    logger(f"Train Age Group Distribution BEFORE SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution BEFORE SWAP:\n{testing_age_group_distribution}", file=log_file_path)

    # Get the distribution of age groups after the update
    training_validation_age_group_distribution = df_train_val_updated['age_group'].value_counts()
    testing_age_group_distribution = df_test_updated['age_group'].value_counts()
    
    # Log the distribution
    logger(f"Train Age Group Distribution AFTER SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution AFTER SWAP:\n{testing_age_group_distribution}", file=log_file_path)
    
    ########################################################
    # TRACKING FINAL CAT_IDs & GENDER AFTER REDISTRIBUTION #
    ########################################################

    # Get the distribution of groups
    training_validation_group_distribution = df_train_val_updated['cat_id'].value_counts()  
    testing_group_distribution = df_test_updated['cat_id'].value_counts()  

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val_updated['gender'].value_counts()
    testing_gender_distribution = df_test_updated['gender'].value_counts()
    
    logger(f"\n Starting training on unseen test set\n", file=log_file_path)

    ###################
    # PREPARING MODEL #
    ###################

    # Calculate the distribution of age groups in y_train_val
    age_group_distribution = Counter(y_train_val)
    print("Age group distribution:", age_group_distribution)

    # EarlyStopping callback: monitor 'loss' instead of 'val_loss' for the test set
    early_stopping = EarlyStopping(
        monitor='loss',  
        min_delta=0.001, 
        patience=30,  
        verbose=1,  
        restore_best_weights=True  
    )

    # One final shuffle to ensure randomness
    outer_shuffle_idx = np.random.permutation(len(X_train_val))
    X_train_val = X_train_val[outer_shuffle_idx]
    y_train_val = y_train_val[outer_shuffle_idx]
    
    # Scale the features
    scaler_full = StandardScaler().fit(X_train_val)
    X_train_full_scaled = scaler_full.transform(X_train_val)
    X_test_scaled = scaler_full.transform(X_test)
    
    # Convert features to TensorFlow tensors
    X_train_full_scaled = tf.convert_to_tensor(X_train_full_scaled, dtype=tf.float32)
    X_test_scaled = tf.convert_to_tensor(X_test_scaled, dtype=tf.float32)
    
    # One-hot encode labels before mixup
    y_train_full_encoded = to_categorical(y_train_val)
    y_test_encoded = to_categorical(y_test)
    
    # Convert labels to TensorFlow tensors
    y_train_full_encoded = tf.convert_to_tensor(y_train_full_encoded, dtype=tf.float32)
    
    # Apply Mixup
    X_train_mix_outer, y_train_mix_outer = mixup_data(X_train_full_scaled, y_train_full_encoded, alpha=0.2)
    
    #######################
    # BUILD & TRAIN MODEL #
    #######################

    optimizers = {
        'Adamax': Adamax(learning_rate=0.00510251984616472)
    }
    
    # Model definition with dynamic number of layers
    model_full = Sequential()
    model_full.add(Dense(480, activation='relu', input_shape=(X_train_full_scaled.shape[1],)))
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.2011047009431978))  
    model_full.add(Dense(256, activation='relu',)) 
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.14956886311951184))  
    model_full.add(Dense(256, activation='relu'))  
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.42291461228250665))  
    model_full.add(Dense(3, activation='softmax'))  
    
    # Use the optimizer from the parameters
    optimizer = optimizers['Adamax']  # optimizer_key from parameters
    
    # Compile the model
    model_full.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    
    # Train the model on the full training set
    history_full = model_full.fit(X_train_mix_outer, y_train_mix_outer, epochs=1500, batch_size=64,
                                  verbose=1, callbacks=[early_stopping])
    
    # Evaluate the model on the held-out test set
    test_loss, test_accuracy = model_full.evaluate(X_test_scaled, y_test_encoded)

    y_test_pred_prob = model_full.predict(X_test_scaled)
    y_test_pred = np.argmax(y_test_pred_prob, axis=1)  
    y_test_true = np.argmax(y_test_encoded, axis=1)    

    ################################
    # LOG MAJORITY VOTE PER CAT_ID #
    ################################

    # Convert numeric predictions back to age group labels
    predicted_age_groups = label_encoder.inverse_transform(y_test_pred)
    actual_labels = label_encoder.inverse_transform(y_test_true)
    
    # Map predictions and actual labels back to cat_ids
    test_results = pd.DataFrame({
        'cat_id': df_test_updated['cat_id'],
        'predicted_age_group': predicted_age_groups,
        'actual_age_group': actual_labels
    })
    
    # Group by cat_id and aggregate predicted age groups
    majority_votes = test_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
    actual_groups = test_results.groupby('cat_id')['actual_age_group'].first()
    
    # Calculate the accuracy of majority voting
    correct_predictions = (majority_votes == actual_groups).sum()
    total_cats = len(actual_groups)
    majority_vote_accuracy = correct_predictions / total_cats
    
    # Log the accuracy of the majority voting
    logger(f"Majority Vote Accuracy for cat_id for this fold: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

    ####################################################
    # COLLECT PREDICTIONS FOR GENDER & CAT_ID ANALYSIS #
    ####################################################

    # Debugging print statements
    print(f'Before appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Extend lists with current fold results
    all_cat_ids.extend(df_test_updated['cat_id'].tolist())
    all_predicted_age_groups.extend(predicted_age_groups)
    all_actual_age_groups.extend(actual_labels)
    all_gender.extend(df_test_updated['gender'].tolist())

    # Debugging print statements
    print(f'After appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Calculate additional metrics
    test_precision = precision_score(y_test_true, y_test_pred, average='macro')  # Use 'macro' for imbalanced datasets
    test_recall = recall_score(y_test_true, y_test_pred, average='macro')
    test_f1 = f1_score(y_test_true, y_test_pred, average='macro')

    # prepare averages of outer metrics
    unseen_f1.append(test_f1)
    unseen_losses.append(test_loss)
    unseen_accuracies.append(test_accuracy)
    unseen_precisions.append(test_precision)
    unseen_recalls.append(test_recall)

    # Print final test results
    logger(f"Final Test Results - Loss: {test_loss}, Accuracy: {test_accuracy}, Precision: {test_precision}, Recall: {test_recall}, F1 Score: {test_f1}", file=log_file_path)

    # Generate the confusion matrix
    cm = confusion_matrix(y_test, y_test_pred)
    logger(f"Confusion Matrix:\n {cm}", file=log_file_path)

# Calculate the overall average metrics
unseen_set_avg_f1 = np.mean(unseen_f1)
unseen_set_avg_loss = np.mean(unseen_losses)
unseen_set_avg_acc = np.mean(unseen_accuracies)
unseen_set_avg_precision = np.mean(unseen_precisions)
unseen_set_avg_recall = np.mean(unseen_recalls)

logger(f"\nFinal Average F1-Score across all UNSEEN TEST sets: {unseen_set_avg_f1}", file=log_file_path)
logger(f"\nFinal Average Loss across all UNSEEN TEST sets: {unseen_set_avg_loss}", file=log_file_path)
logger(f"\nFinal Average Accuracy across all UNSEEN TEST sets: {unseen_set_avg_acc}", file=log_file_path)
logger(f"\nFinal Average Precision across all UNSEEN TEST sets: {unseen_set_avg_precision}", file=log_file_path)
logger(f"\nFinal Average Recall across all UNSEEN TEST sets: {unseen_set_avg_recall}\n", file=log_file_path)

# Append averages to total lists
all_f1.append(unseen_set_avg_f1)
all_losses.append(unseen_set_avg_loss)
all_accuracies.append(unseen_set_avg_acc)
all_precisions.append(unseen_set_avg_precision)
all_recalls.append(unseen_set_avg_recall)
# Out:
# outer_fold 1
# Train Set Group Distribution:
# 046A    45
# 103A    33
# 002B    30
# 047A    22
# 020A    20
# 000B    19
# 057A    17
# 019A    17
# 074A    16
# 029A    15
# 097A    15
# 097B    14
# 106A    13
# 101A    12
# 051A    12
# 055A    12
# 116A    12
# 111A    12
# 042A    11
# 028A    11
# 063A    11
# 040A    10
# 025A    10
# 059A    10
# 014B    10
# 016A     9
# 065A     9
# 051B     9
# 072A     9
# 001A     9
# 005A     9
# 022A     9
# 013B     8
# 068A     8
# 117A     7
# 027A     7
# 031A     7
# 007A     6
# 023A     6
# 039A     6
# 099A     6
# 075A     5
# 108A     5
# 094A     5
# 021A     5
# 008A     5
# 044A     5
# 070A     5
# 109A     5
# 003A     4
# 009A     4
# 045A     4
# 104A     4
# 026A     4
# 025C     4
# 113A     3
# 053A     3
# 056A     3
# 012A     3
# 058A     3
# 010A     3
# 060A     3
# 014A     3
# 025B     2
# 052A     2
# 037A     2
# 102A     2
# 087A     2
# 032A     2
# 110A     1
# 090A     1
# 024A     1
# 115A     1
# 076A     1
# 041A     1
# 019B     1
# 088A     1
# 048A     1
# 026C     1
# 049A     1
# 091A     1
# 073A     1
# 043A     1
# 026B     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 000A    39
# 002A    13
# 067A    11
# 033A     9
# 071A     9
# 015A     7
# 095A     7
# 036A     7
# 050A     5
# 023B     4
# 006A     3
# 105A     3
# 062A     3
# 034A     3
# 061A     2
# 018A     2
# 038A     2
# 054A     2
# 069A     2
# 011A     2
# 093A     2
# 035A     2
# 004A     1
# 096A     1
# 066A     1
# 092A     1
# 064A     1
# 100A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    239
# M    235
# F    174
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# F    57
# M    51
# X    37
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [001A, 103A, 097B, 028A, 019A, 074A, 020A, 002...
# kitten    [044A, 014B, 111A, 040A, 046A, 047A, 042A, 109...
# senior    [097A, 057A, 106A, 104A, 055A, 059A, 113A, 116...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [006A, 000A, 033A, 015A, 071A, 067A, 062A, 095...
# kitten                                               [050A]
# senior                             [093A, 054A, 011A, 061A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 51, 'kitten': 15, 'senior': 18}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 23, 'kitten': 1, 'senior': 4}
# Unique Training/Validation Group IDs:
# ['000B' '001A' '002B' '003A' '005A' '007A' '008A' '009A' '010A' '012A'
#  '013B' '014A' '014B' '016A' '019A' '019B' '020A' '021A' '022A' '023A'
#  '024A' '025A' '025B' '025C' '026A' '026B' '026C' '027A' '028A' '029A'
#  '031A' '032A' '037A' '039A' '040A' '041A' '042A' '043A' '044A' '045A'
#  '046A' '047A' '048A' '049A' '051A' '051B' '052A' '053A' '055A' '056A'
#  '057A' '058A' '059A' '060A' '063A' '065A' '068A' '070A' '072A' '073A'
#  '074A' '075A' '076A' '087A' '088A' '090A' '091A' '094A' '097A' '097B'
#  '099A' '101A' '102A' '103A' '104A' '106A' '108A' '109A' '110A' '111A'
#  '113A' '115A' '116A' '117A']
# Unique Test Group IDs:
# ['000A' '002A' '004A' '006A' '011A' '015A' '018A' '023B' '033A' '034A'
#  '035A' '036A' '038A' '050A' '054A' '061A' '062A' '064A' '066A' '067A'
#  '069A' '071A' '092A' '093A' '095A' '096A' '100A' '105A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'000A'}
# Removed from Training/Validation Set:
# {'010A'}
# Moved to Test Set:
# {'010A'}
# Removed from Test Set
# {'000A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002B' '003A' '005A' '007A' '008A' '009A' '012A'
#  '013B' '014A' '014B' '016A' '019A' '019B' '020A' '021A' '022A' '023A'
#  '024A' '025A' '025B' '025C' '026A' '026B' '026C' '027A' '028A' '029A'
#  '031A' '032A' '037A' '039A' '040A' '041A' '042A' '043A' '044A' '045A'
#  '046A' '047A' '048A' '049A' '051A' '051B' '052A' '053A' '055A' '056A'
#  '057A' '058A' '059A' '060A' '063A' '065A' '068A' '070A' '072A' '073A'
#  '074A' '075A' '076A' '087A' '088A' '090A' '091A' '094A' '097A' '097B'
#  '099A' '101A' '102A' '103A' '104A' '106A' '108A' '109A' '110A' '111A'
#  '113A' '115A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['002A' '004A' '006A' '010A' '011A' '015A' '018A' '023B' '033A' '034A'
#  '035A' '036A' '038A' '050A' '054A' '061A' '062A' '064A' '066A' '067A'
#  '069A' '071A' '092A' '093A' '095A' '096A' '100A' '105A']
# Length of X_train_val:
# 684
# Length of y_train_val:
# 684
# Length of groups_train_val:
# 684
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     377
# senior    141
# kitten    130
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     132
# senior      8
# kitten      5
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     413
# senior    141
# kitten    130
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     96
# senior     8
# kitten     5
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 413, 2: 141, 1: 130})
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Epoch 1/1500
# 11/11 [==============================] - 1s 5ms/step - loss: 1.0981 - accuracy: 0.6140
# Epoch 2/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.5060 - accuracy: 0.8743
# Epoch 3/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.3873 - accuracy: 0.9137
# Epoch 4/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.3179 - accuracy: 0.9401
# Epoch 5/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.2640 - accuracy: 0.9430
# Epoch 6/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.2698 - accuracy: 0.9547
# Epoch 7/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.2541 - accuracy: 0.9576
# Epoch 8/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.2329 - accuracy: 0.9503
# Epoch 9/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.2479 - accuracy: 0.9518
# Epoch 10/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.2290 - accuracy: 0.9605
# Epoch 11/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.2262 - accuracy: 0.9561
# Epoch 12/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.2277 - accuracy: 0.9649
# Epoch 13/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.2186 - accuracy: 0.9576
# Epoch 14/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.2084 - accuracy: 0.9620
# Epoch 15/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.2055 - accuracy: 0.9561
# Epoch 16/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.2111 - accuracy: 0.9664
# Epoch 17/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.2021 - accuracy: 0.9547
# Epoch 18/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1976 - accuracy: 0.9547
# Epoch 19/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.2045 - accuracy: 0.9518
# Epoch 20/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.2028 - accuracy: 0.9605
# Epoch 21/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1946 - accuracy: 0.9605
# Epoch 22/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1953 - accuracy: 0.9635
# Epoch 23/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1922 - accuracy: 0.9561
# Epoch 24/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1936 - accuracy: 0.9664
# Epoch 25/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1935 - accuracy: 0.9547
# Epoch 26/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1923 - accuracy: 0.9591
# Epoch 27/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1974 - accuracy: 0.9678
# Epoch 28/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1860 - accuracy: 0.9576
# Epoch 29/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1832 - accuracy: 0.9664
# Epoch 30/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1788 - accuracy: 0.9678
# Epoch 31/1500
# 11/11 [==============================] - 0s 8ms/step - loss: 0.1867 - accuracy: 0.9737
# Epoch 32/1500
# 11/11 [==============================] - 0s 8ms/step - loss: 0.2020 - accuracy: 0.9591
# Epoch 33/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1884 - accuracy: 0.9518
# Epoch 34/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1815 - accuracy: 0.9561
# Epoch 35/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1858 - accuracy: 0.9591
# Epoch 36/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1888 - accuracy: 0.9561
# Epoch 37/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1834 - accuracy: 0.9649
# Epoch 38/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1821 - accuracy: 0.9620
# Epoch 39/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1783 - accuracy: 0.9722
# Epoch 40/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1772 - accuracy: 0.9591
# Epoch 41/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1725 - accuracy: 0.9708
# Epoch 42/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.
1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1540 - accuracy: 0.9678
# Epoch 104/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1537 - accuracy: 0.9737
# Epoch 105/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1516 - accuracy: 0.9708
# Epoch 106/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1570 - accuracy: 0.9722
# Epoch 107/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1535 - accuracy: 0.9795
# Epoch 108/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1557 - accuracy: 0.9722
# Epoch 109/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1539 - accuracy: 0.9708
# Epoch 110/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1575 - accuracy: 0.9708
# Epoch 111/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1561 - accuracy: 0.9678
# Epoch 112/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1536 - accuracy: 0.9751
# Epoch 113/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1540 - accuracy: 0.9678
# Epoch 114/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1550 - accuracy: 0.9635
# Epoch 115/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1593 - accuracy: 0.9649
# Epoch 116/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1497 - accuracy: 0.9781
# Epoch 117/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1509 - accuracy: 0.9751
# Epoch 118/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1511 - accuracy: 0.9795
# Epoch 119/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1557 - accuracy: 0.9635
# Epoch 120/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1518 - accuracy: 0.9781
# Epoch 121/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1572 - accuracy: 0.9722
# Epoch 122/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1511 - accuracy: 0.9810
# Epoch 123/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1510 - accuracy: 0.9795
# Epoch 124/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1511 - accuracy: 0.9737
# Epoch 125/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1515 - accuracy: 0.9854
# Epoch 126/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1522 - accuracy: 0.9649
# Epoch 127/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.1507 - accuracy: 0.9737
# Epoch 128/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1510 - accuracy: 0.9708
# Epoch 129/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1508 - accuracy: 0.9664
# Epoch 130/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1514 - accuracy: 0.9678
# Epoch 131/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1512 - accuracy: 0.9781
# Epoch 132/1500
# 11/11 [==============================] - 0s 9ms/step - loss: 0.1499 - accuracy: 0.9708
# Epoch 133/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1504 - accuracy: 0.9722
# Epoch 134/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1491 - accuracy: 0.9766
# Epoch 135/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1500 - accuracy: 0.9810
# Epoch 136/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1523 - accuracy: 0.9810
# Epoch 137/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1500 - accuracy: 0.9664
# Epoch 138/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1512 - accuracy: 0.9766
# Epoch 139/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1510 - accuracy: 0.9693
# Epoch 140/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1530 - accuracy: 0.9708
# Epoch 141/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1527 - accuracy: 0.9795
# Epoch 142/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1500 - accuracy: 0.9737
# Epoch 143/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1506 - accuracy: 0.9795
# Epoch 144/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1502 - accuracy: 0.9795
# Epoch 145/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1491 - accuracy: 0.9708
# Epoch 146/1500
#  1/11 [=>............................] - ETA: 0s - loss: 0.1182 - accuracy: 0.9688Restoring model weights from the end of the best epoch: 116.
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1507 - accuracy: 0.9620
# Epoch 146: early stopping
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6605 - accuracy: 0.7248
# 4/4 [==============================] - 0s 2ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.71 (20/28)
# Before appending - Cat IDs: 0, Predictions: 0, Actuals: 0, Gender: 0
# After appending - Cat IDs: 109, Predictions: 109, Actuals: 109, Gender: 109
# Final Test Results - Loss: 0.6605347990989685, Accuracy: 0.7247706651687622, Precision: 0.4773279352226721, Recall: 0.6666666666666666, F1 Score: 0.5118740002460932
# Confusion Matrix:
#  [[72  6 18]
#  [ 0  5  0]
#  [ 4  2  2]]
# outer_fold 2
# Train Set Group Distribution:
# 046A    45
# 000A    39
# 047A    22
# 057A    17
# 019A    17
# 074A    16
# 097A    15
# 002A    13
# 106A    13
# 051A    12
# 111A    12
# 116A    12
# 055A    12
# 067A    11
# 063A    11
# 059A    10
# 040A    10
# 025A    10
# 071A     9
# 022A     9
# 001A     9
# 005A     9
# 072A     9
# 065A     9
# 033A     9
# 068A     8
# 027A     7
# 031A     7
# 095A     7
# 117A     7
# 015A     7
# 036A     7
# 023A     6
# 039A     6
# 099A     6
# 007A     6
# 109A     5
# 075A     5
# 050A     5
# 094A     5
# 108A     5
# 023B     4
# 009A     4
# 003A     4
# 045A     4
# 026A     4
# 025C     4
# 058A     3
# 060A     3
# 006A     3
# 062A     3
# 034A     3
# 113A     3
# 014A     3
# 105A     3
# 037A     2
# 061A     2
# 011A     2
# 035A     2
# 093A     2
# 018A     2
# 069A     2
# 054A     2
# 038A     2
# 091A     1
# 024A     1
# 100A     1
# 110A     1
# 115A     1
# 096A     1
# 019B     1
# 004A     1
# 048A     1
# 066A     1
# 043A     1
# 073A     1
# 026C     1
# 064A     1
# 041A     1
# 092A     1
# 049A     1
# 026B     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 103A    33
# 002B    30
# 020A    20
# 000B    19
# 029A    15
# 097B    14
# 101A    12
# 028A    11
# 042A    11
# 014B    10
# 051B     9
# 016A     9
# 013B     8
# 008A     5
# 021A     5
# 044A     5
# 070A     5
# 104A     4
# 056A     3
# 012A     3
# 053A     3
# 010A     3
# 032A     2
# 087A     2
# 052A     2
# 102A     2
# 025B     2
# 076A     1
# 088A     1
# 090A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    231
# F    164
# M    148
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# M    138
# F     67
# X     45
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [006A, 000A, 033A, 015A, 001A, 071A, 019A, 074...
# kitten    [111A, 040A, 046A, 047A, 109A, 050A, 043A, 049...
# senior    [093A, 097A, 057A, 106A, 055A, 059A, 113A, 116...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [103A, 097B, 028A, 020A, 002B, 101A, 029A, 013...
# kitten                                   [044A, 014B, 042A]
# senior                       [104A, 051B, 056A, 016A, 090A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 52, 'kitten': 13, 'senior': 17}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 22, 'kitten': 3, 'senior': 5}
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Unique Training/Validation Group IDs:
# ['000A' '001A' '002A' '003A' '004A' '005A' '006A' '007A' '009A' '011A'
#  '014A' '015A' '018A' '019A' '019B' '022A' '023A' '023B' '024A' '025A'
#  '025C' '026A' '026B' '026C' '027A' '031A' '033A' '034A' '035A' '036A'
#  '037A' '038A' '039A' '040A' '041A' '043A' '045A' '046A' '047A' '048A'
#  '049A' '050A' '051A' '054A' '055A' '057A' '058A' '059A' '060A' '061A'
#  '062A' '063A' '064A' '065A' '066A' '067A' '068A' '069A' '071A' '072A'
#  '073A' '074A' '075A' '091A' '092A' '093A' '094A' '095A' '096A' '097A'
#  '099A' '100A' '105A' '106A' '108A' '109A' '110A' '111A' '113A' '115A'
#  '116A' '117A']
# Unique Test Group IDs:
# ['000B' '002B' '008A' '010A' '012A' '013B' '014B' '016A' '020A' '021A'
#  '025B' '028A' '029A' '032A' '042A' '044A' '051B' '052A' '053A' '056A'
#  '070A' '076A' '087A' '088A' '090A' '097B' '101A' '102A' '103A' '104A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '001A' '002A' '003A' '004A' '005A' '006A' '007A' '009A' '011A'
#  '014A' '015A' '018A' '019A' '019B' '022A' '023A' '023B' '024A' '025A'
#  '025C' '026A' '026B' '026C' '027A' '031A' '033A' '034A' '035A' '036A'
#  '037A' '038A' '039A' '040A' '041A' '043A' '045A' '046A' '047A' '048A'
#  '049A' '050A' '051A' '054A' '055A' '057A' '058A' '059A' '060A' '061A'
#  '062A' '063A' '064A' '065A' '066A' '067A' '068A' '069A' '071A' '072A'
#  '073A' '074A' '075A' '091A' '092A' '093A' '094A' '095A' '096A' '097A'
#  '099A' '100A' '105A' '106A' '108A' '109A' '110A' '111A' '113A' '115A'
#  '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['000B' '002B' '008A' '010A' '012A' '013B' '014B' '016A' '020A' '021A'
#  '025B' '028A' '029A' '032A' '042A' '044A' '051B' '052A' '053A' '056A'
#  '070A' '076A' '087A' '088A' '090A' '097B' '101A' '102A' '103A' '104A']
# Length of X_train_val:
# 543
# Length of y_train_val:
# 543
# Length of groups_train_val:
# 543
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     311
# senior    123
# kitten    109
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     198
# kitten     26
# senior     26
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     311
# senior    123
# kitten    109
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     198
# kitten     26
# senior     26
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 311, 2: 123, 1: 109})
# Epoch 1/1500
# 9/9 [==============================] - 1s 7ms/step - loss: 1.0848 - accuracy: 0.6519
# Epoch 2/1500
# 9/9 [==============================] - 0s 7ms/step - loss: 0.4784 - accuracy: 0.8748
# Epoch 3/1500
# 9/9 [==============================] - 0s 7ms/step - loss: 0.3290 - accuracy: 0.9392
# Epoch 4/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2951 - accuracy: 0.9448
# Epoch 5/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2586 - accuracy: 0.9558
# Epoch 6/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2423 - accuracy: 0.9466
# Epoch 7/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2421 - accuracy: 0.9521
# Epoch 8/1500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2321 - accuracy: 0.9595
# Epoch 9/1500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2327 - accuracy: 0.9503
# Epoch 10/1500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2244 - accuracy: 0.9576
# Epoch 11/1500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2011 - accuracy: 0.9448
# Epoch 12/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2093 - accuracy: 0.9558
# Epoch 13/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2167 - accuracy: 0.9613
# Epoch 14/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2005 - accuracy: 0.9595
# Epoch 15/1500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2197 - accuracy: 0.9448
# Epoch 16/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.1978 - accuracy: 0.9613
# Epoch 17/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2030 - accuracy: 0.9558
# Epoch 18/1500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2033 - accuracy: 0.9669
# Epoch 19/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1915 - accuracy: 0.9558
# Epoch 20/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2049 - accuracy: 0.9650
# Epoch 21/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.2057 - accuracy: 0.9503
# Epoch 22/1500
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2010 - accuracy: 0.9484
# Epoch 23/1500
# 9/9 [==============================] - 0s 14ms/step - loss: 0.1858 - accuracy: 0.9669
# Epoch 24/1500
# 9/9 [==============================] - 0s 9ms/step - loss: 0.1898 - accuracy: 0.9540
# Epoch 25/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.1833 - accuracy: 0.9576
# Epoch 26/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.1855 - accuracy: 0.9595
# Epoch 27/1500
# 9/9 [==============================] - 0s 9ms/step - loss: 0.1853 - accuracy: 0.9503
# Epoch 28/1500
# 9/9 [==============================] - 0s 9ms/step - loss: 0.1830 - accuracy: 0.9595
# Epoch 29/1500
# 9/9 [==============================] - 0s 8ms/step - loss: 0.1875 - accuracy: 0.9669
# Epoch 30/1500
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1932 - accuracy: 0.9558
# Epoch 31/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1830 - accuracy: 0.9669
# Epoch 32/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1744 - accuracy: 0.9650
# Epoch 33/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1831 - accuracy: 0.9429
# Epoch 34/1500
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1750 - accuracy: 0.9687
# Epoch 35/1500
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1739 - accuracy: 0.9669
# Epoch 36/1500
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1845 - accuracy: 0.9540
# Epoch 37/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1747 - accuracy: 0.9687
# Epoch 38/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1747 - accuracy: 0.9595
# Epoch 39/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1764 - accuracy: 0.9503
# Epoch 40/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1738 - accuracy: 0.9613
# Epoch 41/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1749 - accuracy: 0.9632
# Epoch 42/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1729 - accuracy: 0.9521
# Epoch 43/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1702 - accuracy: 0.9632
# Epoch 44/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1723 - accuracy: 0.9503
# Epoch 45/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1766 - accuracy: 0.9558
# Epoch 46/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1738 - accuracy: 0.9613
# Epoch 47/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.
1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1468 - accuracy: 0.9669
# Epoch 174/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1471 - accuracy: 0.9779
# Epoch 175/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1578 - accuracy: 0.9558
# Epoch 176/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1453 - accuracy: 0.9724
# Epoch 177/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1467 - accuracy: 0.9742
# Epoch 178/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1450 - accuracy: 0.9650
# Epoch 179/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1483 - accuracy: 0.9705
# Epoch 180/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1456 - accuracy: 0.9650
# Epoch 181/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1459 - accuracy: 0.9797
# Epoch 182/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1448 - accuracy: 0.9742
# Epoch 183/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1468 - accuracy: 0.9724
# Epoch 184/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1466 - accuracy: 0.9669
# Epoch 185/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1442 - accuracy: 0.9687
# Epoch 186/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1459 - accuracy: 0.9797
# Epoch 187/1500
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1458 - accuracy: 0.9705
# Epoch 188/1500
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1460 - accuracy: 0.9761
# Epoch 189/1500
# 9/9 [==============================] - ETA: 0s - loss: 0.1451 - accuracy: 0.9558Restoring model weights from the end of the best epoch: 159.
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1451 - accuracy: 0.9558
# Epoch 189: early stopping
# 8/8 [==============================] - 0s 1ms/step - loss: 0.9857 - accuracy: 0.7000
# 8/8 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.70 (21/30)
# Before appending - Cat IDs: 109, Predictions: 109, Actuals: 109, Gender: 109
# After appending - Cat IDs: 359, Predictions: 359, Actuals: 359, Gender: 359
# Final Test Results - Loss: 0.9857363104820251, Accuracy: 0.699999988079071, Precision: 0.5789959394610558, Recall: 0.5173530173530173, F1 Score: 0.543740042655977
# Confusion Matrix:
#  [[155   3  40]
#  [  7  18   1]
#  [ 24   0   2]]
# outer_fold 3
# Train Set Group Distribution:
# 046A    45
# 000A    39
# 103A    33
# 002B    30
# 020A    20
# 000B    19
# 019A    17
# 074A    16
# 029A    15
# 097A    15
# 097B    14
# 002A    13
# 106A    13
# 101A    12
# 051A    12
# 028A    11
# 067A    11
# 042A    11
# 063A    11
# 014B    10
# 005A     9
# 016A     9
# 051B     9
# 065A     9
# 072A     9
# 071A     9
# 033A     9
# 068A     8
# 013B     8
# 036A     7
# 015A     7
# 095A     7
# 023A     6
# 099A     6
# 070A     5
# 094A     5
# 108A     5
# 075A     5
# 008A     5
# 044A     5
# 021A     5
# 050A     5
# 104A     4
# 026A     4
# 003A     4
# 023B     4
# 025C     4
# 012A     3
# 056A     3
# 053A     3
# 060A     3
# 010A     3
# 006A     3
# 062A     3
# 105A     3
# 014A     3
# 034A     3
# 038A     2
# 093A     2
# 025B     2
# 037A     2
# 102A     2
# 061A     2
# 011A     2
# 035A     2
# 018A     2
# 052A     2
# 087A     2
# 069A     2
# 032A     2
# 054A     2
# 043A     1
# 090A     1
# 100A     1
# 096A     1
# 110A     1
# 076A     1
# 064A     1
# 092A     1
# 088A     1
# 004A     1
# 048A     1
# 066A     1
# 026B     1
# Name: cat_id, dtype: int64
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Testing Set Group Distribution:
# 047A    22
# 057A    17
# 055A    12
# 116A    12
# 111A    12
# 059A    10
# 025A    10
# 040A    10
# 022A     9
# 001A     9
# 027A     7
# 117A     7
# 031A     7
# 039A     6
# 007A     6
# 109A     5
# 045A     4
# 009A     4
# 058A     3
# 113A     3
# 073A     1
# 049A     1
# 041A     1
# 091A     1
# 026C     1
# 019B     1
# 115A     1
# 024A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    252
# X    192
# F    166
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    84
# F    65
# M    34
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [006A, 000A, 033A, 015A, 103A, 071A, 097B, 028...
# kitten     [044A, 014B, 046A, 042A, 050A, 043A, 048A, 110A]
# senior    [093A, 097A, 106A, 104A, 051B, 054A, 056A, 051...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [001A, 022A, 091A, 039A, 009A, 027A, 025A, 007...
# kitten     [111A, 040A, 047A, 109A, 049A, 041A, 045A, 115A]
# senior     [057A, 055A, 059A, 113A, 116A, 117A, 058A, 024A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 62, 'kitten': 8, 'senior': 14}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 12, 'kitten': 8, 'senior': 8}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '002A' '002B' '003A' '004A' '005A' '006A' '008A' '010A'
# ...
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1874 - accuracy: 0.9625
# Epoch 22/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1796 - accuracy: 0.9641
# Epoch 23/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1825 - accuracy: 0.9641
# Epoch 24/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1791 - accuracy: 0.9674
# Epoch 25/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1928 - accuracy: 0.9674
# Epoch 26/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1979 - accuracy: 0.9494
# Epoch 27/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1755 - accuracy: 0.9723
# Epoch 28/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1837 - accuracy: 0.9641
# Epoch 29/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1785 - accuracy: 0.9755
# Epoch 30/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1717 - accuracy: 0.9755
# Epoch 31/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1768 - accuracy: 0.9625
# Epoch 32/1500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1783 - accuracy: 0.9592
# Epoch 33/1500
# 10/10 [==============================] - 0s 9ms/step - loss: 0.1706 - accuracy: 0.9739
# Epoch 34/1500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1656 - accuracy: 0.9772
# Epoch 35/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1683 - accuracy: 0.9674
# Epoch 36/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1677 - accuracy: 0.9706
# Epoch 37/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1671 - accuracy: 0.9739
# Epoch 38/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1688 - accuracy: 0.9625
# Epoch 39/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1658 - accuracy: 0.9772
# Epoch 40/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1680 - accuracy: 0.9657
# Epoch 41/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1696 - accuracy: 0.9641
# Epoch 42/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1673 - accuracy: 0.9674
# Epoch 43/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1642 - accuracy: 0.9706
# Epoch 44/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1681 - accuracy: 0.9690
# Epoch 45/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1631 - accuracy: 0.9608
# Epoch 46/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1647 - accuracy: 0.9674
# Epoch 47/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1659 - accuracy: 0.9657
# Epoch 48/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1638 - accuracy: 0.9755
# Epoch 49/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1664 - accuracy: 0.9706
# Epoch 50/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1702 - accuracy: 0.9592
# Epoch 51/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1624 - accuracy: 0.9723
# Epoch 52/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1610 - accuracy: 0.9755
# Epoch 53/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1594 - accuracy: 0.9706
# Epoch 54/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1685 - accuracy: 0.9674
# Epoch 55/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1611 - accuracy: 0.9723
# Epoch 56/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1600 - accuracy: 0.9723
# Epoch 57/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1674 - accuracy: 0.9674
# Epoch 58/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1585 - accuracy: 0.9739
# Epoch 59/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1605 - accuracy: 0.9723
# Epoch 60/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1603 - accuracy: 0.9723
# Epoch 61/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1607 - accuracy: 0.9690
# Epoch 62/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1573 - accuracy: 0.9608
# Epoch 63/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1642 - accuracy: 0.9706
# Epoch 64/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1539 - accuracy: 0.9674
# Epoch 65/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1521 - accuracy: 0.9706
# Epoch 66/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1538 - accuracy: 0.9723
# Epoch 67/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1557 - accuracy: 0.9690
# Epoch 68/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1587 - accuracy: 0.9657
# Epoch 69/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1608 - accuracy: 0.9641
# Epoch 70/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1548 - accuracy: 0.9739
# Epoch 71/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1565 - accuracy: 0.9739
# Epoch 72/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1479 - accuracy: 0.9723
# Epoch 73/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.
1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1363 - accuracy: 0.9853
# Epoch 138/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1413 - accuracy: 0.9821
# Epoch 139/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1407 - accuracy: 0.9739
# Epoch 140/1500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1426 - accuracy: 0.9788
# Epoch 141/1500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1448 - accuracy: 0.9739
# Epoch 142/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1390 - accuracy: 0.9690
# Epoch 143/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1391 - accuracy: 0.9739
# Epoch 144/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1386 - accuracy: 0.9821
# Epoch 145/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1392 - accuracy: 0.9837
# Epoch 146/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1402 - accuracy: 0.9723
# Epoch 147/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1396 - accuracy: 0.9723
# Epoch 148/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1404 - accuracy: 0.9821
# Epoch 149/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1413 - accuracy: 0.9788
# Epoch 150/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1386 - accuracy: 0.9804
# Epoch 151/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1399 - accuracy: 0.9706
# Epoch 152/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1369 - accuracy: 0.9804
# Epoch 153/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1374 - accuracy: 0.9755
# Epoch 154/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1360 - accuracy: 0.9837
# Epoch 155/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1393 - accuracy: 0.9755
# Epoch 156/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1391 - accuracy: 0.9739
# Epoch 157/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1374 - accuracy: 0.9837
# Epoch 158/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1358 - accuracy: 0.9869
# Epoch 159/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1408 - accuracy: 0.9723
# Epoch 160/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1375 - accuracy: 0.9853
# Epoch 161/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1380 - accuracy: 0.9821
# Epoch 162/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1394 - accuracy: 0.9706
# Epoch 163/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1385 - accuracy: 0.9755
# Epoch 164/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1411 - accuracy: 0.9821
# Epoch 165/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1401 - accuracy: 0.9772
# Epoch 166/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1415 - accuracy: 0.9837
# Epoch 167/1500
# 10/10 [==============================] - ETA: 0s - loss: 0.1378 - accuracy: 0.9755Restoring model weights from the end of the best epoch: 137.
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1378 - accuracy: 0.9755
# Epoch 167: early stopping
# 6/6 [==============================] - 0s 2ms/step - loss: 1.2583 - accuracy: 0.6889
# 6/6 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.85 (22/26)
# Before appending - Cat IDs: 542, Predictions: 542, Actuals: 542, Gender: 542
# After appending - Cat IDs: 722, Predictions: 722, Actuals: 722, Gender: 722
# Final Test Results - Loss: 1.2583215236663818, Accuracy: 0.6888889074325562, Precision: 0.6181216931216931, Recall: 0.7144729344729345, F1 Score: 0.6337884180476773
# Confusion Matrix:
#  [[94 10 13]
#  [ 0 13  0]
#  [32  1 17]]
#
# Final Average F1-Score across all UNSEEN TEST sets: 0.5705015782292239
#
# Final Average Loss across all UNSEEN TEST sets: 1.0935983061790466
#
# Final Average Accuracy across all UNSEEN TEST sets: 0.678688108921051
#
# Final Average Precision across all UNSEEN TEST sets: 0.6092350249347322
#
# Final Average Recall across all UNSEEN TEST sets: 0.625284120001862

# %%
seed_2_folds_values = (unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1)

# Plotting all fold metrics
seed_2_folds_plot = plot_all_metrics(unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1, "Folds", "Fold Number")

# %% [markdown]
# ## Majority Voting on Total Entries per cat_id

# %%
# Debugging print statements
print(f'Checking - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
# Out:
# Checking - Cat IDs: 722, Predictions: 722, Actuals: 722, Gender: 722

# %%
# Create results df
full_results = pd.DataFrame({
    'cat_id': all_cat_ids,
    'predicted_age_group': all_predicted_age_groups,
    'actual_age_group': all_actual_age_groups,
    'all_gender': all_gender
})

# create a correct majority prediction column
full_results['correct'] = full_results['predicted_age_group'] == full_results['actual_age_group']

# %%
# Group by cat_id and aggregate predicted age groups
majority_votes = full_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first()

# Calculate the accuracy of majority voting
correct_predictions = (majority_votes == actual_groups).sum()
total_cats = len(actual_groups)
majority_vote_accuracy = correct_predictions / total_cats

logger(f"Overall Majority Vote Accuracy for cat_id: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

# store for final evaluation 
all_majority_vote_accuracies.append(majority_vote_accuracy)
# Out:
# Overall Majority Vote Accuracy for cat_id: 0.75 (82/110)

# %%
# Detailed df with predictions, actual labels, and comparison including majority vote
detailed_results = full_results.groupby('cat_id').apply(
    lambda x: pd.Series({
        'Predictions': list(x['predicted_age_group']),
        'Majority Vote': x['predicted_age_group'].mode()[0],
        'Actual Age Group': x['actual_age_group'].iloc[0],
        'Correct Majority Vote': x['predicted_age_group'].mode()[0] == x['actual_age_group'].iloc[0]
    })
).reset_index()

# Convert to DataFrame for better formatting and display
detailed_results = pd.DataFrame(detailed_results)

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 10)
pd.set_option('display.width', 1000)

sorted_detailed_results = detailed_results.sort_values(by='Correct Majority Vote', ascending=False)

# Display the sorted DataFrame
sorted_detailed_results
# Out:
#     cat_id                                        Predictions Majority Vote Actual Age Group  Correct Majority Vote
# 0     000B  [adult, senior, adult, adult, adult, adult, ad...         adult            adult                   True
# 80    074A  [adult, adult, kitten, adult, adult, adult, ad...         adult            adult                   True
# 78    072A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 76    070A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 74    068A  [adult, senior, adult, adult, senior, adult, s...         adult            adult                   True
# 73    067A  [adult, adult, kitten, kitten, adult, adult, a...         adult            adult                   True
# 72    066A                                            [adult]         adult            adult                   True
# 71    065A  [senior, adult, adult, kitten, adult, senior, ...         adult            adult                   True
# 70    064A                                            [adult]         adult            adult                   True
# 69    063A  [kitten, kitten, kitten, adult, adult, kitten,...         adult            adult                   True
# 68    062A                              [adult, adult, adult]         adult            adult                   True
# 66    060A                             [adult, kitten, adult]         adult            adult                   True
# 65    059A  [adult, adult, senior, senior, senior, adult, ...        senior           senior                   True
# 64    058A                            [senior, senior, adult]        senior           senior                   True
# 1     001A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 54    049A                                           [kitten]        kitten           kitten                   True
#
adult           senior                  False

# %%
# Create df for majority votes
majority_df = majority_votes.reset_index()
majority_df.columns = ['cat_id', 'Majority_Vote']

# Get actual groups for each cat_id
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first().reset_index()

# Merge majority votes with actual groups
majority_with_actual = pd.merge(majority_df, actual_groups, on='cat_id')

# Add a column to check if the majority vote was correct
majority_with_actual['Majority_Correct'] = majority_with_actual['Majority_Vote'] == majority_with_actual['actual_age_group']

# Count correct majority votes per class
correct_majority_votes_per_class = majority_with_actual.groupby('actual_age_group')['Majority_Correct'].sum()

print("Correct Majority Votes per Class:")
print(correct_majority_votes_per_class)
# Out:
# Correct Majority Votes per Class:
# actual_age_group
# adult     62
# kitten    13
# senior     7
# Name: Majority_Correct, dtype: int64

# %%
# Calculate the total count and the number of correct predictions for each class
class_stats = majority_with_actual.groupby('actual_age_group').agg(
    total_count=('Majority_Correct', 'size'),  # Total number of cases per class
    correct_count=('Majority_Correct', 'sum')  # Sum of correct predictions per class
).reset_index()

# Calculate accuracy for each class
class_stats['accuracy'] = class_stats['correct_count'] / class_stats['total_count'] * 100

# store for final evaluation 
all_majority_vote_details.append(class_stats)

# Log detailed stats
print("Detailed Class Statistics for Majority Votes:")
print(class_stats)
# Out:
# Detailed Class Statistics for Majority Votes:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult           73             62  84.931507
# 1           kitten           15             13  86.666667
# 2           senior           22              7  31.818182

# %%
# Plot for Detailed Class Statistics for Majority Votes
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Accuracy of Majority Votes by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Detailed Class Statistics

# %%
# Calculate the total count and the number of correct predictions for each class
class_stats = full_results.groupby('actual_age_group').agg(
    total_count=('correct', 'size'),
    correct_count=('correct', 'sum')
).reset_index()

# Calculate accuracy for each class
class_stats['accuracy'] = class_stats['correct_count'] / class_stats['total_count'] * 100

# store for final evaluation 
all_class_stats.append(class_stats)

# Log the detailed stats
print("Detailed Class Statistics:")
print(class_stats)
# Out:
# Detailed Class Statistics:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult          473            380  80.338266
# 1           kitten          100             65  65.000000
# 2           senior          149             43  28.859060

# %%
# Plot for Detailed Class Statistics (Overall)
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Overall Accuracy by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Gender Exploration

# %%
# Group by gender and calculate the total count, correct predictions, and accuracy
gender_stats = full_results.groupby('all_gender').agg(
    count=('cat_id', 'size'),  # Total number of cases per gender
    correct=('correct', 'sum')  # Sum of correct predictions per gender
).reset_index()

# Calculate accuracy for each gender
gender_stats['accuracy'] = (gender_stats['correct'] / gender_stats['count'] * 100).round(2)

# Display the DataFrame
print("Accuracy by Gender:")
print(gender_stats)

# store for final evaluation 
all_gender_stats.append(gender_stats)
# Out:
# Accuracy by Gender:
#   all_gender  count  correct  accuracy
# 0          F    192      126     65.62
# 1          M    289      206     71.28
# 2          X    241      156     64.73

# %%
# Plot for Accuracy by Gender
styled_barplot(gender_stats, 'all_gender', 'accuracy', 
               'Accuracy by Gender', 
               'Gender', 'Accuracy (%)')

# %% [markdown]
# ### Log current total CV Stats

# %%
print("Total Majority Vote Accuracy so far:", all_majority_vote_accuracies)
print("Total Class Statistics so far:\n", all_class_stats)
print("Total Gender Accuracy so far:\n", all_gender_stats)
# Out:
# Total Majority Vote Accuracy so far: [0.7272727272727273, 0.7454545454545455]
# Total Class Statistics so far:
#  [  actual_age_group  total_count  correct_count   accuracy
# 0            adult          474            391  82.489451
# 1           kitten           91             43  47.252747
# 2           senior          149             41  27.516779,   actual_age_group  total_count  correct_count   accuracy
# 0            adult          473            380  80.338266
# 1           kitten          100             65  65.000000
# 2           senior          149             43  28.859060]
# Total Gender Accuracy so far:
#  [  all_gender  count  correct  accuracy
# 0          F    196      135     68.88
# 1          M    286      202     70.63
# 2          X    232      138     59.48,   all_gender  count  correct  accuracy
# 0          F    192      126     65.62
# 1          M    289      206     71.28
# 2          X    241      156     64.73]

# %% [markdown]
# # RANDOM SEED 3

# %%
# Set a fixed random seed for reproducibility
random.seed(int(random_seeds[2]))
np.random.seed(int(random_seeds[2]))
tf.random.set_seed(int(random_seeds[2]))

# Load datasets
dataframe = pd.read_csv('/Users/astrid/PycharmProjects/perch-2/scripts/perch_embeddings_april_10.csv')
dataframe.drop('mean_freq', axis=1, inplace=True)

def assign_age_group(age, age_groups):
    for group_name, age_range in age_groups.items():
        if age_range[0] <= age < age_range[1]:
            return group_name
    return 'Unknown'  # For any age that doesn't fit the defined groups

# Define age groups
age_groups = {
    'kitten': (0, 0.5),
    'adult': (0.5, 12),
    'senior': (12, 20)
}

# Create a new column for the age group
dataframe['age_group'] = dataframe['target'].apply(assign_age_group, age_groups=age_groups)

print(dataframe['age_group'].value_counts())
# Out:
# adult     509
# senior    149
# kitten    135
# Name: age_group, dtype: int64

# %%
# Separate features and labels
X = dataframe.iloc[:, :-4].values  # all columns except the last four

# Encode the 'age_group' column as integers using LabelEncoder
label_encoder = LabelEncoder()
encoded_y = label_encoder.fit_transform(dataframe['age_group'].values)

# Use the encoded labels for splitting and one-hot encoding
y = encoded_y  

# Convert 'cat_id' column to numpy array to be used as groups array for GroupKFold
groups = dataframe['cat_id'].values

# %%
tf.keras.backend.clear_session()

# %% [markdown]
# ## Run Setup

# %%
all_cat_ids = []
all_predicted_age_groups = []
all_actual_age_groups = []
all_gender = []

# Define the StratifiedGroupKFold splitter for 4 fold CV with random shuffling
outer_cv = StratifiedGroupKFold(n_splits=4, shuffle=True, random_state=int(random_seeds[2]))

# unseen test set metrics
unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1 = [], [], [], [], []

outer_fold = 0

# Use the splitter to generate indices for training and testing sets
# Note: GroupShuffleSplit.split returns indices, so we use it to index the arrays
for train_val_idx, test_idx in outer_cv.split(X, y, groups):
    outer_fold += 1
    logger(f"outer_fold {outer_fold}", file=log_file_path)

    # Convert indices back to DataFrame for easy manipulation
    df_train_val = dataframe.iloc[train_val_idx]
    df_test = dataframe.iloc[test_idx]

    ##############################
    # ASSESSING SPLITS BY CAT_ID #
    ##############################
    
    # Get the distribution of groups
    training_validation_group_distribution = df_train_val['cat_id'].value_counts()  
    testing_group_distribution = df_test['cat_id'].value_counts()  
    
    # Log or print the distribution
    logger(f"Train Set Group Distribution:\n{training_validation_group_distribution}", file=log_file_path)
    logger(f"Testing Set Group Distribution:\n{testing_group_distribution}", file=log_file_path)

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val['gender'].value_counts()
    testing_gender_distribution = df_test['gender'].value_counts()
    
    # Log the distribution
    logger(f"Training Set Gender Distribution BEFORE SWAP:\n{training_gender_distribution}", file=log_file_path)
    logger(f"Testing Set Gender Distribution BEFORE SWAP:\n{testing_gender_distribution}", file=log_file_path)

    # Group by 'age_group' and then list unique 'cat_id' within each age group
    unique_cat_ids_per_age_group_train_val = df_train_val.groupby('age_group')['cat_id'].unique()
    unique_cat_ids_per_age_group_test = df_test.groupby('age_group')['cat_id'].unique()
    
    # Log results
    logger(f"Unique Cat IDs per Age Group in Training/Validation Set:\n{unique_cat_ids_per_age_group_train_val}", file=log_file_path)
    logger(f"Unique Cat IDs per Age Group in Testing Set:\n{unique_cat_ids_per_age_group_test}", file=log_file_path)

    # Calculate the count of unique identifiers per age group for training and testing set
    counts_train_val = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_train_val.items()}
    counts_test = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_test.items()}

    # Log the counts of unique identifiers per age group
    logger(f"Count of Unique Cat IDs per Age Group in Training/Validation Set:\n{counts_train_val}", file=log_file_path)
    logger(f"Count of Unique Cat IDs per Age Group in Testing Set:\n{counts_test}", file=log_file_path)

    #######################################################
    # CONTINUE WITH ENSURING VALID AND APPROPRIATE SPLITS #
    #######################################################
    
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    groups_train_val, groups_test = groups[train_val_idx], groups[test_idx]

    # logging identifier splits 
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)

    # check group splits
    check_initial_group_split(groups_train_val, groups_test)

    # Specify the cat_ids that must be in the training/validation set
    specific_cat_ids = ['000A', '046A']
    
    # Perform the swapping operation
    train_val_idx, test_idx = swap_cat_id_instances(dataframe, train_val_idx, test_idx, specific_cat_ids)
    
    # Re-assign the sets based on the updated indices
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    new_groups_train_val, new_groups_test = groups[train_val_idx], groups[test_idx]

    # Find differences for training and test sets
    moved_to_train_val, removed_from_train_val = find_group_differences(groups_train_val, new_groups_train_val)
    moved_to_test, removed_from_test = find_group_differences(groups_test, new_groups_test)
    
    # Display the results
    logger(f"Moved to Training/Validation Set:\n{moved_to_train_val}", file=log_file_path)
    logger(f"Removed from Training/Validation Set:\n{removed_from_train_val}", file=log_file_path)
    logger(f"Moved to Test Set:\n{moved_to_test}", file=log_file_path)
    logger(f"Removed from Test Set\n{removed_from_test}", file=log_file_path)

    # Update X_train_val, X_test, y_train_val, y_test, groups_train_val, groups_test based on updated indices
    X_train_val = X[train_val_idx]
    y_train_val = y[train_val_idx]
    groups_train_val = groups[train_val_idx]
    
    X_test = X[test_idx]
    y_test = y[test_idx]
    groups_test = groups[test_idx]

    # logging identifier splits again after potential swaps
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"AFTER SWAP - Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"AFTER SWAP - Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)
    
    # Verify the lengths are consistent
    logger(f"Length of X_train_val:\n{len(X_train_val)}", file=log_file_path)
    logger(f"Length of y_train_val:\n{len(y_train_val)}", file=log_file_path)
    logger(f"Length of groups_train_val:\n{len(groups_train_val)}", file=log_file_path)

    # Check group splits once more
    check_initial_group_split(groups_train_val, groups_test)

    # Convert the modified indices back to a DataFrame representing the updated df_train_val
    df_train_val_updated = dataframe.iloc[train_val_idx].copy()
    df_test_updated = dataframe.iloc[test_idx].copy()

    ############################
    # LOGGING AGE GROUP SPLITS #
    ############################

    # Get the distribution of age groups of age groups before the update
    training_validation_age_group_distribution = df_train_val['age_group'].value_counts()
    testing_age_group_distribution = df_test['age_group'].value_counts()
    
    # Logthe distribution
    logger(f"Train Age Group Distribution BEFORE SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution BEFORE SWAP:\n{testing_age_group_distribution}", file=log_file_path)

    # Get the distribution of age groups after the update
    training_validation_age_group_distribution = df_train_val_updated['age_group'].value_counts()
    testing_age_group_distribution = df_test_updated['age_group'].value_counts()
    
    # Log the distribution
    logger(f"Train Age Group Distribution AFTER SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution AFTER SWAP:\n{testing_age_group_distribution}", file=log_file_path)
    
    ########################################################
    # TRACKING FINAL CAT_IDs & GENDER AFTER REDISTRIBUTION #
    ########################################################

    # Get the distribution of groups
    training_validation_group_distribution = df_train_val_updated['cat_id'].value_counts()  
    testing_group_distribution = df_test_updated['cat_id'].value_counts()  

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val_updated['gender'].value_counts()
    testing_gender_distribution = df_test_updated['gender'].value_counts()
    
    logger(f"\n Starting training on unseen test set\n", file=log_file_path)

    ###################
    # PREPARING MODEL #
    ###################

    # Calculate the distribution of age groups in y_train_val
    age_group_distribution = Counter(y_train_val)
    print("Age group distribution:", age_group_distribution)

    # EarlyStopping callback: monitor 'loss' instead of 'val_loss' for the test set
    early_stopping = EarlyStopping(
        monitor='loss',  
        min_delta=0.001, 
        patience=30,  
        verbose=1,  
        restore_best_weights=True  
    )

    # One final shuffle to ensure randomness
    outer_shuffle_idx = np.random.permutation(len(X_train_val))
    X_train_val = X_train_val[outer_shuffle_idx]
    y_train_val = y_train_val[outer_shuffle_idx]
    
    # Scale the features
    scaler_full = StandardScaler().fit(X_train_val)
    X_train_full_scaled = scaler_full.transform(X_train_val)
    X_test_scaled = scaler_full.transform(X_test)
    
    # Convert features to TensorFlow tensors
    X_train_full_scaled = tf.convert_to_tensor(X_train_full_scaled, dtype=tf.float32)
    X_test_scaled = tf.convert_to_tensor(X_test_scaled, dtype=tf.float32)
    
    # One-hot encode labels before mixup
    y_train_full_encoded = to_categorical(y_train_val)
    y_test_encoded = to_categorical(y_test)
    
    # Convert labels to TensorFlow tensors
    y_train_full_encoded = tf.convert_to_tensor(y_train_full_encoded, dtype=tf.float32)
    
    # Apply Mixup
    X_train_mix_outer, y_train_mix_outer = mixup_data(X_train_full_scaled, y_train_full_encoded, alpha=0.2)
    
    #######################
    # BUILD & TRAIN MODEL #
    #######################

    optimizers = {
        'Adamax': Adamax(learning_rate=0.00510251984616472)
    }
    
    # Model definition with dynamic number of layers
    model_full = Sequential()
    model_full.add(Dense(480, activation='relu', input_shape=(X_train_full_scaled.shape[1],)))
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.2011047009431978))  
    model_full.add(Dense(256, activation='relu',)) 
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.14956886311951184))  
    model_full.add(Dense(256, activation='relu'))  
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.42291461228250665))  
    model_full.add(Dense(3, activation='softmax'))  
    
    # Use the optimizer from the parameters
    optimizer = optimizers['Adamax']  # optimizer_key from parameters
    
    # Compile the model
    model_full.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    
    # Train the model on the full training set
    history_full = model_full.fit(X_train_mix_outer, y_train_mix_outer, epochs=1500, batch_size=64,
                                  verbose=1, callbacks=[early_stopping])
    
    # Evaluate the model on the held-out test set
    test_loss, test_accuracy = model_full.evaluate(X_test_scaled, y_test_encoded)

    y_test_pred_prob = model_full.predict(X_test_scaled)
    y_test_pred = np.argmax(y_test_pred_prob, axis=1)  
    y_test_true = np.argmax(y_test_encoded, axis=1)    

    ################################
    # LOG MAJORITY VOTE PER CAT_ID #
    ################################

    # Convert numeric predictions back to age group labels
    predicted_age_groups = label_encoder.inverse_transform(y_test_pred)
    actual_labels = label_encoder.inverse_transform(y_test_true)
    
    # Map predictions and actual labels back to cat_ids
    test_results = pd.DataFrame({
        'cat_id': df_test_updated['cat_id'],
        'predicted_age_group': predicted_age_groups,
        'actual_age_group': actual_labels
    })
    
    # Group by cat_id and aggregate predicted age groups
    majority_votes = test_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
    actual_groups = test_results.groupby('cat_id')['actual_age_group'].first()
    
    # Calculate the accuracy of majority voting
    correct_predictions = (majority_votes == actual_groups).sum()
    total_cats = len(actual_groups)
    majority_vote_accuracy = correct_predictions / total_cats
    
    # Log the accuracy of the majority voting
    logger(f"Majority Vote Accuracy for cat_id for this fold: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

    ####################################################
    # COLLECT PREDICTIONS FOR GENDER & CAT_ID ANALYSIS #
    ####################################################

    # Debugging print statements
    print(f'Before appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Extend lists with current fold results
    all_cat_ids.extend(df_test_updated['cat_id'].tolist())
    all_predicted_age_groups.extend(predicted_age_groups)
    all_actual_age_groups.extend(actual_labels)
    all_gender.extend(df_test_updated['gender'].tolist())

    # Debugging print statements
    print(f'After appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Calculate additional metrics
    test_precision = precision_score(y_test_true, y_test_pred, average='macro')  # Use 'macro' for imbalanced datasets
    test_recall = recall_score(y_test_true, y_test_pred, average='macro')
    test_f1 = f1_score(y_test_true, y_test_pred, average='macro')

    # prepare averages of outer metrics
    unseen_f1.append(test_f1)
    unseen_losses.append(test_loss)
    unseen_accuracies.append(test_accuracy)
    unseen_precisions.append(test_precision)
    unseen_recalls.append(test_recall)

    # Print final test results
    logger(f"Final Test Results - Loss: {test_loss}, Accuracy: {test_accuracy}, Precision: {test_precision}, Recall: {test_recall}, F1 Score: {test_f1}", file=log_file_path)

    # Generate the confusion matrix
    cm = confusion_matrix(y_test, y_test_pred)
    logger(f"Confusion Matrix:\n {cm}", file=log_file_path)

# Calculate the overall average metrics
unseen_set_avg_f1 = np.mean(unseen_f1)
unseen_set_avg_loss = np.mean(unseen_losses)
unseen_set_avg_acc = np.mean(unseen_accuracies)
unseen_set_avg_precision = np.mean(unseen_precisions)
unseen_set_avg_recall = np.mean(unseen_recalls)

logger(f"\nFinal Average F1-Score across all UNSEEN TEST sets: {unseen_set_avg_f1}", file=log_file_path)
logger(f"\nFinal Average Loss across all UNSEEN TEST sets: {unseen_set_avg_loss}", file=log_file_path)
logger(f"\nFinal Average Accuracy across all UNSEEN TEST sets: {unseen_set_avg_acc}", file=log_file_path)
logger(f"\nFinal Average Precision across all UNSEEN TEST sets: {unseen_set_avg_precision}", file=log_file_path)
logger(f"\nFinal Average Recall across all UNSEEN TEST sets: {unseen_set_avg_recall}\n", file=log_file_path)

# Append averages to total lists
all_f1.append(unseen_set_avg_f1)
all_losses.append(unseen_set_avg_loss)
all_accuracies.append(unseen_set_avg_acc)
all_precisions.append(unseen_set_avg_precision)
all_recalls.append(unseen_set_avg_recall)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# outer_fold 1
# Train Set Group Distribution:
# 046A    45
# 000A    39
# 103A    33
# 002B    30
# 047A    22
# 000B    19
# 057A    17
# 074A    16
# 097A    15
# 029A    15
# 002A    13
# 106A    13
# 051A    12
# 101A    12
# 116A    12
# 055A    12
# 111A    12
# 067A    11
# 063A    11
# 040A    10
# 025A    10
# 051B     9
# 016A     9
# 065A     9
# 072A     9
# 001A     9
# 005A     9
# 033A     9
# 022A     9
# 071A     9
# 013B     8
# 068A     8
# 015A     7
# 036A     7
# 031A     7
# 117A     7
# 027A     7
# 095A     7
# 007A     6
# 023A     6
# 044A     5
# 109A     5
# 021A     5
# 070A     5
# 094A     5
# 050A     5
# 108A     5
# 008A     5
# 026A     4
# 009A     4
# 025C     4
# 045A     4
# 104A     4
# 003A     4
# 058A     3
# 060A     3
# 012A     3
# 053A     3
# 006A     3
# 056A     3
# 113A     3
# 034A     3
# 035A     2
# 032A     2
# 025B     2
# 087A     2
# 038A     2
# 037A     2
# 061A     2
# 054A     2
# 004A     1
# 100A     1
# 110A     1
# 115A     1
# 088A     1
# 076A     1
# 048A     1
# 066A     1
# 096A     1
# 091A     1
# 026C     1
# 041A     1
# 049A     1
# 073A     1
# 024A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 020A    20
# 019A    17
# 097B    14
# 028A    11
# 042A    11
# 014B    10
# 059A    10
# 039A     6
# 099A     6
# 075A     5
# 023B     4
# 010A     3
# 105A     3
# 014A     3
# 062A     3
# 093A     2
# 018A     2
# 069A     2
# 052A     2
# 011A     2
# 102A     2
# 043A     1
# 064A     1
# 092A     1
# 019B     1
# 090A     1
# 026B     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    235
# X    208
# F    206
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    68
# M    51
# F    25
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [006A, 000A, 033A, 015A, 001A, 103A, 071A, 074...
# kitten    [044A, 111A, 040A, 046A, 047A, 109A, 050A, 049...
# senior    [097A, 057A, 106A, 104A, 055A, 113A, 116A, 051...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [097B, 028A, 019A, 020A, 062A, 039A, 099A, 014...
# kitten                                   [014B, 042A, 043A]
# senior                             [093A, 059A, 011A, 090A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 54, 'kitten': 13, 'senior': 18}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 20, 'kitten': 3, 'senior': 4}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '004A' '005A' '006A' '007A'
#  '008A' '009A' '012A' '013B' '015A' '016A' '021A' '022A' '023A' '024A'
#  '025A' '025B' '025C' '026A' '026C' '027A' '029A' '031A' '032A' '033A'
#  '034A' '035A' '036A' '037A' '038A' '040A' '041A' '044A' '045A' '046A'
#  '047A' '048A' '049A' '050A' '051A' '051B' '053A' '054A' '055A' '056A'
#  '057A' '058A' '060A' '061A' '063A' '065A' '066A' '067A' '068A' '070A'
#  '071A' '072A' '073A' '074A' '076A' '087A' '088A' '091A' '094A' '095A'
#  '096A' '097A' '100A' '101A' '103A' '104A' '106A' '108A' '109A' '110A'
#  '111A' '113A' '115A' '116A' '117A']
# Unique Test Group IDs:
# ['010A' '011A' '014A' '014B' '018A' '019A' '019B' '020A' '023B' '026B'
#  '028A' '039A' '042A' '043A' '052A' '059A' '062A' '064A' '069A' '075A'
#  '090A' '092A' '093A' '097B' '099A' '102A' '105A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '004A' '005A' '006A' '007A'
#  '008A' '009A' '012A' '013B' '015A' '016A' '021A' '022A' '023A' '024A'
#  '025A' '025B' '025C' '026A' '026C' '027A' '029A' '031A' '032A' '033A'
#  '034A' '035A' '036A' '037A' '038A' '040A' '041A' '044A' '045A' '046A'
#  '047A' '048A' '049A' '050A' '051A' '051B' '053A' '054A' '055A' '056A'
#  '057A' '058A' '060A' '061A' '063A' '065A' '066A' '067A' '068A' '070A'
#  '071A' '072A' '073A' '074A' '076A' '087A' '088A' '091A' '094A' '095A'
#  '096A' '097A' '100A' '101A' '103A' '104A' '106A' '108A' '109A' '110A'
#  '111A' '113A' '115A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['010A' '011A' '014A' '014B' '018A' '019A' '019B' '020A' '023B' '026B'
#  '028A' '039A' '042A' '043A' '052A' '059A' '062A' '064A' '069A' '075A'
#  '090A' '092A' '093A' '097B' '099A' '102A' '105A']
# Length of X_train_val:
# 649
# Length of y_train_val:
# 649
# Length of groups_train_val:
# 649
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     402
# senior    134
# kitten    113
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     107
# kitten     22
# senior     15
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     402
# senior    134
# kitten    113
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     107
# kitten     22
# senior     15
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 402, 2: 134, 1: 113})
# Epoch 1/1500
# 11/11 [==============================] - 1s 5ms/step - loss: 1.1914 - accuracy: 0.6287
# Epoch 2/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.4968 - accuracy: 0.8521
# Epoch 3/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.3725 - accuracy: 0.9230
# Epoch 4/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.3190 - accuracy: 0.9353
# Epoch 5/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.2921 - accuracy: 0.9353
# Epoch 6/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.2664 - accuracy: 0.9538
# Epoch 7/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.2820 - accuracy: 0.9476
# Epoch 8/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.
1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1533 - accuracy: 0.9738
# Epoch 196/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1529 - accuracy: 0.9707
# Epoch 197/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1551 - accuracy: 0.9753
# Epoch 198/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1560 - accuracy: 0.9738
# Epoch 199/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1571 - accuracy: 0.9676
# Epoch 200/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1560 - accuracy: 0.9723
# Epoch 201/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1517 - accuracy: 0.9877
# Epoch 202/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1534 - accuracy: 0.9738
# Epoch 203/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1495 - accuracy: 0.9753
# Epoch 204/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1554 - accuracy: 0.9753
# Epoch 205/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1554 - accuracy: 0.9753
# Epoch 206/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1542 - accuracy: 0.9784
# Epoch 207/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1557 - accuracy: 0.9661
# Epoch 208/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1566 - accuracy: 0.9753
# Epoch 209/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1542 - accuracy: 0.9738
# Epoch 210/1500
# 11/11 [==============================] - 0s 13ms/step - loss: 0.1563 - accuracy: 0.9676
# Epoch 211/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1614 - accuracy: 0.9723
# Epoch 212/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1562 - accuracy: 0.9661
# Epoch 213/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1644 - accuracy: 0.9615
# Epoch 214/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1605 - accuracy: 0.9676
# Epoch 215/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1563 - accuracy: 0.9753
# Epoch 216/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1534 - accuracy: 0.9753
# Epoch 217/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1563 - accuracy: 0.9738
# Epoch 218/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.1531 - accuracy: 0.9800
# Epoch 219/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1543 - accuracy: 0.9815
# Epoch 220/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1619 - accuracy: 0.9661
# Epoch 221/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.1540 - accuracy: 0.9599
# Epoch 222/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1510 - accuracy: 0.9753
# Epoch 223/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1563 - accuracy: 0.9676
# Epoch 224/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1526 - accuracy: 0.9753
# Epoch 225/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1528 - accuracy: 0.9769
# Epoch 226/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1575 - accuracy: 0.9723
# Epoch 227/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1533 - accuracy: 0.9738
# Epoch 228/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1550 - accuracy: 0.9769
# Epoch 229/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1495 - accuracy: 0.9784
# Epoch 230/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1550 - accuracy: 0.9692
# Epoch 231/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1550 - accuracy: 0.9769
# Epoch 232/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1529 - accuracy: 0.9707
# Epoch 233/1500
# 11/11 [==============================] - ETA: 0s - loss: 0.1541 - accuracy: 0.9753Restoring model weights from the end of the best epoch: 203.
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1541 - accuracy: 0.9753
# Epoch 233: early stopping
# 5/5 [==============================] - 0s 1ms/step - loss: 0.5649 - accuracy: 0.8056
# 5/5 [==============================] - 0s 1ms/step
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Majority Vote Accuracy for cat_id for this fold: 0.81 (22/27)
# Before appending - Cat IDs: 0, Predictions: 0, Actuals: 0, Gender: 0
# After appending - Cat IDs: 144, Predictions: 144, Actuals: 144, Gender: 144
# Final Test Results - Loss: 0.5648623108863831, Accuracy: 0.8055555820465088, Precision: 0.778889316403745, Recall: 0.667837251014821, F1 Score: 0.6646996278575226
# Confusion Matrix:
#  [[97  0 10]
#  [12  8  2]
#  [ 4  0 11]]
# outer_fold 2
# Train Set Group Distribution:
# 046A    45
# 000A    39
# 103A    33
# 002B    30
# 047A    22
# 020A    20
# 000B    19
# 019A    17
# 057A    17
# 097A    15
# 029A    15
# 097B    14
# 002A    13
# 106A    13
# 116A    12
# 111A    12
# 051A    12
# 055A    12
# 028A    11
# 042A    11
# 025A    10
# 014B    10
# 059A    10
# 065A     9
# 072A     9
# 071A     9
# 033A     9
# 068A     8
# 015A     7
# 031A     7
# 036A     7
# 117A     7
# 007A     6
# 039A     6
# 099A     6
# 023A     6
# 075A     5
# 094A     5
# 008A     5
# 050A     5
# 070A     5
# 003A     4
# 023B     4
# 025C     4
# 105A     3
# 053A     3
# 113A     3
# 014A     3
# 062A     3
# 056A     3
# 034A     3
# 012A     3
# 060A     3
# 010A     3
# 035A     2
# 011A     2
# 061A     2
# 052A     2
# 102A     2
# 054A     2
# 093A     2
# 018A     2
# 038A     2
# 069A     2
# 032A     2
# 064A     1
# 088A     1
# 090A     1
# 100A     1
# 110A     1
# 115A     1
# 019B     1
# 004A     1
# 049A     1
# 048A     1
# 076A     1
# 043A     1
# 026C     1
# 073A     1
# 041A     1
# 092A     1
# 026B     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 074A    16
# 101A    12
# 067A    11
# 063A    11
# 040A    10
# 001A     9
# 022A     9
# 005A     9
# 016A     9
# 051B     9
# 013B     8
# 095A     7
# 027A     7
# 109A     5
# 021A     5
# 108A     5
# 044A     5
# 045A     4
# 009A     4
# 104A     4
# 026A     4
# 058A     3
# 006A     3
# 087A     2
# 037A     2
# 025B     2
# 096A     1
# 091A     1
# 066A     1
# 024A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    235
# M    196
# F    183
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# M    90
# F    48
# X    41
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [000A, 033A, 015A, 103A, 071A, 097B, 028A, 019...
# kitten    [014B, 111A, 046A, 047A, 042A, 050A, 043A, 049...
# senior    [093A, 097A, 057A, 106A, 055A, 059A, 113A, 116...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [006A, 001A, 074A, 067A, 101A, 022A, 095A, 005...
# kitten                             [044A, 040A, 109A, 045A]
# senior                 [104A, 051B, 058A, 016A, 108A, 024A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 54, 'kitten': 12, 'senior': 16}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 20, 'kitten': 4, 'senior': 6}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '002A' '002B' '003A' '004A' '007A' '008A' '010A' '011A'
#  '012A' '014A' '014B' '015A' '018A' '019A' '019B' '020A' '023A' '023B'
#  '025A' '025C' '026B' '026C' '028A' '029A' '031A' '032A' '033A' '034A'
#  '035A' '036A' '038A' '039A' '041A' '042A' '043A' '046A' '047A' '048A'
#  '049A' '050A' '051A' '052A' '053A' '054A' '055A' '056A' '057A' '059A'
#  '060A' '061A' '062A' '064A' '065A' '068A' '069A' '070A' '071A' '072A'
#  '073A' '075A' '076A' '088A' '090A' '092A' '093A' '094A' '097A' '097B'
#  '099A' '100A' '102A' '103A' '105A' '106A' '110A' '111A' '113A' '115A'
#  '116A' '117A']
# Unique Test Group IDs:
# ['001A' '005A' '006A' '009A' '013B' '016A' '021A' '022A' '024A' '025B'
#  '026A' '027A' '037A' '040A' '044A' '045A' '051B' '058A' '063A' '066A'
#  '067A' '074A' '087A' '091A' '095A' '096A' '101A' '104A' '108A' '109A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '002A' '002B' '003A' '004A' '007A' '008A' '010A' '011A'
#  '012A' '014A' '014B' '015A' '018A' '019A' '019B' '020A' '023A' '023B'
#  '025A' '025C' '026B' '026C' '028A' '029A' '031A' '032A' '033A' '034A'
#  '035A' '036A' '038A' '039A' '041A' '042A' '043A' '046A' '047A' '048A'
#  '049A' '050A' '051A' '052A' '053A' '054A' '055A' '056A' '057A' '059A'
#  '060A' '061A' '062A' '064A' '065A' '068A' '069A' '070A' '071A' '072A'
#  '073A' '075A' '076A' '088A' '090A' '092A' '093A' '094A' '097A' '097B'
#  '099A' '100A' '102A' '103A' '105A' '106A' '110A' '111A' '113A' '115A'
#  '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['001A' '005A' '006A' '009A' '013B' '016A' '021A' '022A' '024A' '025B'
#  '026A' '027A' '037A' '040A' '044A' '045A' '051B' '058A' '063A' '066A'
#  '067A' '074A' '087A' '091A' '095A' '096A' '101A' '104A' '108A' '109A']
# Length of X_train_val:
# 614
# Length of y_train_val:
# 614
# Length of groups_train_val:
# 614
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     385
# senior    118
# kitten    111
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     124
# senior     31
# kitten     24
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     385
# senior    118
# kitten    111
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     124
# senior     31
# kitten     24
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 385, 2: 118, 1: 111})
# Epoch 1/1500
# 10/10 [==============================] - 1s 6ms/step - loss: 1.1758 - accuracy: 0.6352
# Epoch 2/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4950 - accuracy: 0.8795
# Epoch 3/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3177 - accuracy: 0.9463
# Epoch 4/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3081 - accuracy: 0.9332
# Epoch 5/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2512 - accuracy: 0.9511
# Epoch 6/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2396 - accuracy: 0.9593
# Epoch 7/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2503 - accuracy: 0.9642
# Epoch 8/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2207 - accuracy: 0.9577
# Epoch 9/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2165 - accuracy: 0.9642
# Epoch 10/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2249 - accuracy: 0.9625
# Epoch 11/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2124 - accuracy: 0.9658
# Epoch 12/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2149 - accuracy: 0.9707
# Epoch 13/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2226 - accuracy: 0.9479
# Epoch 14/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1960 - accuracy: 0.9739
# Epoch 15/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2006 - accuracy: 0.9674
# Epoch 16/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2001 - accuracy: 0.9625
# Epoch 17/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2006 - accuracy: 0.9577
# Epoch 18/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1887 - accuracy: 0.9593
# Epoch 19/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1805 - accuracy: 0.9625
# Epoch 20/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1904 - accuracy: 0.9625
# Epoch 21/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1877 - accuracy: 0.9707
# Epoch 22/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1816 - accuracy: 0.9642
# Epoch 23/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1853 - accuracy: 0.9756
# Epoch 24/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1778 - accuracy: 0.9739
# Epoch 25/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1901 - accuracy: 0.9593
# Epoch 26/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1766 - accuracy: 0.9560
# Epoch 27/1500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1853 - accuracy: 0.9609
# Epoch 28/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1803 - accuracy: 0.9625
# Epoch 29/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1779 - accuracy: 0.9674
# Epoch 30/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1694 - accuracy: 0.9723
# Epoch 31/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1831 - accuracy: 0.9609
# Epoch 32/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1706 - accuracy: 0.9609
# Epoch 33/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1717 - accuracy: 0.9756
# Epoch 34/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1744 - accuracy: 0.9625
# Epoch 35/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1803 - accuracy: 0.9756
# Epoch 36/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1811 - accuracy: 0.9511
# Epoch 37/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1636 - accuracy: 0.9723
# Epoch 38/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1776 - accuracy: 0.9642
# Epoch 39/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1623 - accuracy: 0.9723
# Epoch 40/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1638 - accuracy: 0.9772
# Epoch 41/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1789 - accuracy: 0.9593
# Epoch 42/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1645 - accuracy: 0.9707
# Epoch 43/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1728 - accuracy: 0.9544
# Epoch 44/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1630 - accuracy: 0.9723
# Epoch 45/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1853 - accuracy: 0.9609
# Epoch 46/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1646 - accuracy: 0.9674
# Epoch 47/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1595 - accuracy: 0.9821
# Epoch 48/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1584 - accuracy: 0.9805
# Epoch 49/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1587 - accuracy: 0.9658
# Epoch 50/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1573 - accuracy: 0.9707
# Epoch 51/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1516 - accuracy: 0.9772
# Epoch 52/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1592 - accuracy: 0.9674
# Epoch 53/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1580 - accuracy: 0.9658
# Epoch 54/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.
1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1388 - accuracy: 0.9772
# Epoch 119/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1421 - accuracy: 0.9756
# Epoch 120/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1417 - accuracy: 0.9723
# Epoch 121/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1453 - accuracy: 0.9658
# Epoch 122/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1423 - accuracy: 0.9691
# Epoch 123/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1450 - accuracy: 0.9691
# Epoch 124/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1394 - accuracy: 0.9837
# Epoch 125/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1428 - accuracy: 0.9723
# Epoch 126/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1395 - accuracy: 0.9723
# Epoch 127/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1451 - accuracy: 0.9707
# Epoch 128/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1387 - accuracy: 0.9756
# Epoch 129/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1406 - accuracy: 0.9772
# Epoch 130/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1402 - accuracy: 0.9658
# Epoch 131/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1395 - accuracy: 0.9707
# Epoch 132/1500
# ...
#  '105A' '106A' '108A' '109A' '113A' '116A']
# AFTER SWAP - Unique Test Group IDs:
# ['002B' '003A' '004A' '023A' '025A' '029A' '031A' '032A' '036A' '041A'
#  '050A' '051A' '054A' '055A' '057A' '060A' '061A' '068A' '071A' '076A'
#  '094A' '103A' '110A' '111A' '115A' '117A']
# Length of X_train_val:
# 580
# Length of y_train_val:
# 580
# Length of groups_train_val:
# 580
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     373
# senior     92
# kitten     82
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     136
# senior     57
# kitten     53
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     373
# kitten    115
# senior     92
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     136
# senior     57
# kitten     20
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 373, 1: 115, 2: 92})
# Epoch 1/1500
# 10/10 [==============================] - 1s 5ms/step - loss: 1.1072 - accuracy: 0.6034
# Epoch 2/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5072 - accuracy: 0.8690
# Epoch 3/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4294 - accuracy: 0.9034
# Epoch 4/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3348 - accuracy: 0.9362
# Epoch 5/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2958 - accuracy: 0.9310
# Epoch 6/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2601 - accuracy: 0.9552
# Epoch 7/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2461 - accuracy: 0.9621
# Epoch 8/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2566 - accuracy: 0.9586
# Epoch 9/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2342 - accuracy: 0.9586
# Epoch 10/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2369 - accuracy: 0.9638
# Epoch 11/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2448 - accuracy: 0.9500
# Epoch 12/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2048 - accuracy: 0.9672
# Epoch 13/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2286 - accuracy: 0.9603
# Epoch 14/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2064 - accuracy: 0.9707
# Epoch 15/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2176 - accuracy: 0.9569
# Epoch 16/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2188 - accuracy: 0.9586
# Epoch 17/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2118 - accuracy: 0.9655
# Epoch 18/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2005 - accuracy: 0.9724
# Epoch 19/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2042 - accuracy: 0.9552
# Epoch 20/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2140 - accuracy: 0.9586
# Epoch 21/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2126 - accuracy: 0.9534
# Epoch 22/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2129 - accuracy: 0.9586
# Epoch 23/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2030 - accuracy: 0.9672
# Epoch 24/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1999 - accuracy: 0.9569
# Epoch 25/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2100 - accuracy: 0.9603
# Epoch 26/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2164 - accuracy: 0.9655
# Epoch 27/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2068 - accuracy: 0.9655
# Epoch 28/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2040 - accuracy: 0.9586
# Epoch 29/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1984 - accuracy: 0.9638
# Epoch 30/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1940 - accuracy: 0.9603
# Epoch 31/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1899 - accuracy: 0.9638
# Epoch 32/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1979 - accuracy: 0.9672
# Epoch 33/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1867 - accuracy: 0.9655
# Epoch 34/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1994 - accuracy: 0.9586
# Epoch 35/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1770 - accuracy: 0.9793
# Epoch 36/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1936 - accuracy: 0.9603
# Epoch 37/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1825 - accuracy: 0.9724
# Epoch 38/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.
1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1707 - accuracy: 0.9759
# Epoch 102/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1645 - accuracy: 0.9845
# Epoch 103/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1643 - accuracy: 0.9741
# Epoch 104/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1917 - accuracy: 0.9655
# Epoch 105/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1751 - accuracy: 0.9655
# Epoch 106/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1675 - accuracy: 0.9672
# Epoch 107/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1620 - accuracy: 0.9724
# Epoch 108/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1876 - accuracy: 0.9690
# Epoch 109/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1679 - accuracy: 0.9741
# Epoch 110/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1667 - accuracy: 0.9759
# Epoch 111/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1716 - accuracy: 0.9724
# Epoch 112/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1653 - accuracy: 0.9638
# Epoch 113/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1674 - accuracy: 0.9621
# Epoch 114/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1707 - accuracy: 0.9655
# Epoch 115/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1757 - accuracy: 0.9500
# Epoch 116/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1736 - accuracy: 0.9621
# Epoch 117/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1717 - accuracy: 0.9672
# Epoch 118/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1781 - accuracy: 0.9552
# Epoch 119/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1758 - accuracy: 0.9603
# Epoch 120/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1688 - accuracy: 0.9707
# Epoch 121/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1647 - accuracy: 0.9793
# Epoch 122/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1636 - accuracy: 0.9707
# Epoch 123/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1678 - accuracy: 0.9672
# Epoch 124/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1702 - accuracy: 0.9690
# Epoch 125/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1615 - accuracy: 0.9741
# Epoch 126/1500
# 10/10 [==============================] - 0s 14ms/step - loss: 0.1644 - accuracy: 0.9759
# Epoch 127/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1654 - accuracy: 0.9776
# Epoch 128/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1752 - accuracy: 0.9638
# Epoch 129/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1709 - accuracy: 0.9655
# Epoch 130/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1672 - accuracy: 0.9776
# Epoch 131/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1652 - accuracy: 0.9690
# Epoch 132/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1661 - accuracy: 0.9724
# Epoch 133/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1741 - accuracy: 0.9707
# Epoch 134/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1677 - accuracy: 0.9672
# Epoch 135/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1621 - accuracy: 0.9707
# Epoch 136/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1690 - accuracy: 0.9655
# Epoch 137/1500
# 10/10 [==============================] - ETA: 0s - loss: 0.1729 - accuracy: 0.9621Restoring model weights from the end of the best epoch: 107.
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1729 - accuracy: 0.9621
# Epoch 137: early stopping
# 7/7 [==============================] - 0s 2ms/step - loss: 1.2967 - accuracy: 0.7230
# 7/7 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.77 (20/26)
# Before appending - Cat IDs: 513, Predictions: 513, Actuals: 513, Gender: 513
# After appending - Cat IDs: 726, Predictions: 726, Actuals: 726, Gender: 726
# Final Test Results - Loss: 1.296720266342163, Accuracy: 0.7230046987533569, Precision: 0.7225047080979284, Recall: 0.6747248022015824, F1 Score: 0.6602265598786236
# Confusion Matrix:
#  [[127   1   8]
#  [  1  19   0]
#  [ 49   0   8]]
#
# Final Average F1-Score across all UNSEEN TEST sets: 0.6031095832325344
#
# Final Average Loss across all UNSEEN TEST sets: 1.001096174120903
#
# Final Average Accuracy across all UNSEEN TEST sets: 0.7142115235328674
#
# Final Average Precision across all UNSEEN TEST sets: 0.6927469557702448
#
# Final Average Recall across all UNSEEN TEST sets: 0.5989044346588357

# %%
seed_3_folds_values = (unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1)

# Plotting all fold metrics
seed_3_folds_plot = plot_all_metrics(unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1, "Folds", "Fold Number")

# %% [markdown]
# ## Majority Voting on Total Entries per cat_id

# %%
# Debugging print statements
print(f'Checking - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
# Out:
# Checking - Cat IDs: 726, Predictions: 726, Actuals: 726, Gender: 726

# %%
# Create results df
full_results = pd.DataFrame({
    'cat_id': all_cat_ids,
    'predicted_age_group': all_predicted_age_groups,
    'actual_age_group': all_actual_age_groups,
    'all_gender': all_gender
})

# create a correct majority prediction column
full_results['correct'] = full_results['predicted_age_group'] == full_results['actual_age_group']

# %%
# Group by cat_id and aggregate predicted age groups
majority_votes = full_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first()

# Calculate the accuracy of majority voting
correct_predictions = (majority_votes == actual_groups).sum()
total_cats = len(actual_groups)
majority_vote_accuracy = correct_predictions / total_cats

logger(f"Overall Majority Vote Accuracy for cat_id: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

# store for final evaluation 
all_majority_vote_accuracies.append(majority_vote_accuracy)
# Out:
# Overall Majority Vote Accuracy for cat_id: 0.74 (81/110)

# %%
# Detailed df with predictions, actual labels, and comparison including majority vote
detailed_results = full_results.groupby('cat_id').apply(
    lambda x: pd.Series({
        'Predictions': list(x['predicted_age_group']),
        'Majority Vote': x['predicted_age_group'].mode()[0],
        'Actual Age Group': x['actual_age_group'].iloc[0],
        'Correct Majority Vote': x['predicted_age_group'].mode()[0] == x['actual_age_group'].iloc[0]
    })
).reset_index()

# Convert to DataFrame for better formatting and display
detailed_results = pd.DataFrame(detailed_results)

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 10)
pd.set_option('display.width', 1000)

sorted_detailed_results = detailed_results.sort_values(by='Correct Majority Vote', ascending=False)

# Display the sorted DataFrame
sorted_detailed_results
# Out:
#     cat_id                                        Predictions Majority Vote Actual Age Group  Correct Majority Vote
# 0     000B  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 78    072A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 76    070A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 74    068A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 73    067A  [adult, adult, adult, kitten, adult, adult, ad...         adult            adult                   True
# 72    066A                                            [adult]         adult            adult                   True
# 71    065A  [senior, adult, adult, adult, kitten, kitten, ...         adult            adult                   True
# 70    064A                                            [adult]         adult            adult                   True
# 69    063A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
#
# %%
# Plot for Detailed Class Statistics (Overall)
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Overall Accuracy by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Gender Exploration

# %%
# Group by gender and calculate the total count, correct predictions, and accuracy
gender_stats = full_results.groupby('all_gender').agg(
    count=('cat_id', 'size'),  # Total number of cases per gender
    correct=('correct', 'sum')  # Sum of correct predictions per gender
).reset_index()

# Calculate accuracy for each gender
gender_stats['accuracy'] = (gender_stats['correct'] / gender_stats['count'] * 100).round(2)

# Display the DataFrame
print("Accuracy by Gender:")
print(gender_stats)

# store for final evaluation 
all_gender_stats.append(gender_stats)
# Out:
# Accuracy by Gender:
#   all_gender  count  correct  accuracy
# 0          F    192      130     67.71
# 1          M    291      229     78.69
# 2          X    243      156     64.20

# %%
# Plot for Accuracy by Gender
styled_barplot(gender_stats, 'all_gender', 'accuracy', 
               'Accuracy by Gender', 
               'Gender', 'Accuracy (%)')

# %% [markdown]
# ### Log current total CV Stats

# %%
print("Total Majority Vote Accuracy so far:", all_majority_vote_accuracies)
print("Total Class Statistics so far:\n", all_class_stats)
print("Total Gender Accuracy so far:\n", all_gender_stats)
# Out:
# Total Majority Vote Accuracy so far: [0.7272727272727273, 0.7454545454545455, 0.7363636363636363]
# Total Class Statistics so far:
#  [  actual_age_group  total_count  correct_count   accuracy
# 0            adult          474            391  82.489451
# 1           kitten           91             43  47.252747
# 2           senior          149             41  27.516779,   actual_age_group  total_count  correct_count   accuracy
# 0            adult          473            380  80.338266
# 1           kitten          100             65  65.000000
# 2           senior          149             43  28.859060,   actual_age_group  total_count  correct_count   accuracy
# 0            adult          475            423  89.052632
# 1           kitten          102             56  54.901961
# 2           senior          149             36  24.161074]
# Total Gender Accuracy so far:
#  [  all_gender  count  correct  accuracy
# 0          F    196      135     68.88
# 1          M    286      202     70.63
# 2          X    232      138     59.48,   all_gender  count  correct  accuracy
# 0          F    192      126     65.62
# 1          M    289      206     71.28
# 2          X    241      156     64.73,   all_gender  count  correct  accuracy
# 0          F    192      130     67.71
# 1          M    291      229     78.69
# 2          X    243      156     64.20]

# %% [markdown]
# # RANDOM SEED 4

# %%
# Set a fixed random seed for reproducibility
random.seed(int(random_seeds[3])) 
np.random.seed(int(random_seeds[3]))
tf.random.set_seed(int(random_seeds[3]))

# Load datasets
dataframe = pd.read_csv('/Users/astrid/PycharmProjects/perch-2/scripts/perch_embeddings_april_10.csv')
dataframe.drop('mean_freq', axis=1, inplace=True)

def assign_age_group(age, age_groups):
    for group_name, age_range in age_groups.items():
        if age_range[0] <= age < age_range[1]:
            return group_name
    return 'Unknown'  # For any age that doesn't fit the defined groups

# Define age groups
age_groups = {
    'kitten': (0, 0.5),
    'adult': (0.5, 12),
    'senior': (12, 20)
}

# Create a new column for the age group
dataframe['age_group'] = dataframe['target'].apply(assign_age_group, age_groups=age_groups)

print(dataframe['age_group'].value_counts())
# Out:
# adult     509
# senior    149
# kitten    135
# Name: age_group, dtype: int64

# %%
# Separate features and labels
X = dataframe.iloc[:, :-4].values  # all columns except the last four

# Encode the 'age_group' column as integers using LabelEncoder
label_encoder = LabelEncoder()
encoded_y = label_encoder.fit_transform(dataframe['age_group'].values)

# Use the encoded labels for splitting and one-hot encoding
y = encoded_y  

# Convert 'cat_id' column to numpy array to be used as groups array for GroupKFold
groups = dataframe['cat_id'].values

# %%
tf.keras.backend.clear_session()

# %% [markdown]
# ## Run Setup

# %%
all_cat_ids = []
all_predicted_age_groups = []
all_actual_age_groups = []
all_gender = []

# Define the StratifiedGroupKFold splitter for 4 fold CV with random shuffling
outer_cv = StratifiedGroupKFold(n_splits=4, shuffle=True, random_state=int(random_seeds[3]))

# unseen test set metrics
unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1 = [], [], [], [], []

outer_fold = 0

# Use the splitter to generate indices for training and testing sets
# Note: GroupShuffleSplit.split returns indices, so we use it to index the arrays
for train_val_idx, test_idx in outer_cv.split(X, y, groups):
    outer_fold += 1
    logger(f"outer_fold {outer_fold}", file=log_file_path)

    # Convert indices back to DataFrame for easy manipulation
    df_train_val = dataframe.iloc[train_val_idx]
    df_test = dataframe.iloc[test_idx]

    ##############################
    # ASSESSING SPLITS BY CAT_ID #
    ##############################
    
    # Get the distribution of groups
    training_validation_group_distribution = df_train_val['cat_id'].value_counts()  
    testing_group_distribution = df_test['cat_id'].value_counts()  
    
    # Log or print the distribution
    logger(f"Train Set Group Distribution:\n{training_validation_group_distribution}", file=log_file_path)
    logger(f"Testing Set Group Distribution:\n{testing_group_distribution}", file=log_file_path)

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val['gender'].value_counts()
    testing_gender_distribution = df_test['gender'].value_counts()
    
    # Log the distribution
    logger(f"Training Set Gender Distribution BEFORE SWAP:\n{training_gender_distribution}", file=log_file_path)
    logger(f"Testing Set Gender Distribution BEFORE SWAP:\n{testing_gender_distribution}", file=log_file_path)

    # Group by 'age_group' and then list unique 'cat_id' within each age group
    unique_cat_ids_per_age_group_train_val = df_train_val.groupby('age_group')['cat_id'].unique()
    unique_cat_ids_per_age_group_test = df_test.groupby('age_group')['cat_id'].unique()
    
    # Log results
    logger(f"Unique Cat IDs per Age Group in Training/Validation Set:\n{unique_cat_ids_per_age_group_train_val}", file=log_file_path)
    logger(f"Unique Cat IDs per Age Group in Testing Set:\n{unique_cat_ids_per_age_group_test}", file=log_file_path)

    # Calculate the count of unique identifiers per age group for training and testing set
    counts_train_val = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_train_val.items()}
    counts_test = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_test.items()}

    # Log the counts of unique identifiers per age group
    logger(f"Count of Unique Cat IDs per Age Group in Training/Validation Set:\n{counts_train_val}", file=log_file_path)
    logger(f"Count of Unique Cat IDs per Age Group in Testing Set:\n{counts_test}", file=log_file_path)

    #######################################################
    # CONTINUE WITH ENSURING VALID AND APPROPRIATE SPLITS #
    #######################################################
    
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    groups_train_val, groups_test = groups[train_val_idx], groups[test_idx]

    # logging identifier splits 
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)

    # check group splits
    check_initial_group_split(groups_train_val, groups_test)

    # Specify the cat_ids that must be in the training/validation set
    specific_cat_ids = ['000A', '046A']
    
    # Perform the swapping operation
    train_val_idx, test_idx = swap_cat_id_instances(dataframe, train_val_idx, test_idx, specific_cat_ids)
    
    # Re-assign the sets based on the updated indices
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    new_groups_train_val, new_groups_test = groups[train_val_idx], groups[test_idx]

    # Find differences for training and test sets
    moved_to_train_val, removed_from_train_val = find_group_differences(groups_train_val, new_groups_train_val)
    moved_to_test, removed_from_test = find_group_differences(groups_test, new_groups_test)
    
    # Display the results
    logger(f"Moved to Training/Validation Set:\n{moved_to_train_val}", file=log_file_path)
    logger(f"Removed from Training/Validation Set:\n{removed_from_train_val}", file=log_file_path)
    logger(f"Moved to Test Set:\n{moved_to_test}", file=log_file_path)
    logger(f"Removed from Test Set\n{removed_from_test}", file=log_file_path)

    # Update X_train_val, X_test, y_train_val, y_test, groups_train_val, groups_test based on updated indices
    X_train_val = X[train_val_idx]
    y_train_val = y[train_val_idx]
    groups_train_val = groups[train_val_idx]
    
    X_test = X[test_idx]
    y_test = y[test_idx]
    groups_test = groups[test_idx]

    # logging identifier splits again after potential swaps
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"AFTER SWAP - Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"AFTER SWAP - Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)
    
    # Verify the lengths are consistent
    logger(f"Length of X_train_val:\n{len(X_train_val)}", file=log_file_path)
    logger(f"Length of y_train_val:\n{len(y_train_val)}", file=log_file_path)
    logger(f"Length of groups_train_val:\n{len(groups_train_val)}", file=log_file_path)

    # Check group splits once more
    check_initial_group_split(groups_train_val, groups_test)

    # Convert the modified indices back to a DataFrame representing the updated df_train_val
    df_train_val_updated = dataframe.iloc[train_val_idx].copy()
    df_test_updated = dataframe.iloc[test_idx].copy()

    ############################
    # LOGGING AGE GROUP SPLITS #
    ############################

    # Get the distribution of age groups of age groups before the update
    training_validation_age_group_distribution = df_train_val['age_group'].value_counts()
    testing_age_group_distribution = df_test['age_group'].value_counts()
    
    # Logthe distribution
    logger(f"Train Age Group Distribution BEFORE SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution BEFORE SWAP:\n{testing_age_group_distribution}", file=log_file_path)

    # Get the distribution of age groups after the update
    training_validation_age_group_distribution = df_train_val_updated['age_group'].value_counts()
    testing_age_group_distribution = df_test_updated['age_group'].value_counts()
    
    # Log the distribution
    logger(f"Train Age Group Distribution AFTER SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution AFTER SWAP:\n{testing_age_group_distribution}", file=log_file_path)
    
    ########################################################
    # TRACKING FINAL CAT_IDs & GENDER AFTER REDISTRIBUTION #
    ########################################################

    # Get the distribution of groups
    training_validation_group_distribution = df_train_val_updated['cat_id'].value_counts()  
    testing_group_distribution = df_test_updated['cat_id'].value_counts()  

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val_updated['gender'].value_counts()
    testing_gender_distribution = df_test_updated['gender'].value_counts()
    
    logger(f"\n Starting training on unseen test set\n", file=log_file_path)

    ###################
    # PREPARING MODEL #
    ###################

    # Calculate the distribution of age groups in y_train_val
    age_group_distribution = Counter(y_train_val)
    print("Age group distribution:", age_group_distribution)

    # EarlyStopping callback: monitor 'loss' instead of 'val_loss' for the test set
    early_stopping = EarlyStopping(
        monitor='loss',  
        min_delta=0.001, 
        patience=30,  
        verbose=1,  
        restore_best_weights=True  
    )

    # One final shuffle to ensure randomness
    outer_shuffle_idx = np.random.permutation(len(X_train_val))
    X_train_val = X_train_val[outer_shuffle_idx]
    y_train_val = y_train_val[outer_shuffle_idx]
    
    # Scale the features
    scaler_full = StandardScaler().fit(X_train_val)
    X_train_full_scaled = scaler_full.transform(X_train_val)
    X_test_scaled = scaler_full.transform(X_test)
    
    # Convert features to TensorFlow tensors
    X_train_full_scaled = tf.convert_to_tensor(X_train_full_scaled, dtype=tf.float32)
    X_test_scaled = tf.convert_to_tensor(X_test_scaled, dtype=tf.float32)
    
    # One-hot encode labels before mixup
    y_train_full_encoded = to_categorical(y_train_val)
    y_test_encoded = to_categorical(y_test)
    
    # Convert labels to TensorFlow tensors
    y_train_full_encoded = tf.convert_to_tensor(y_train_full_encoded, dtype=tf.float32)
    
    # Apply Mixup
    X_train_mix_outer, y_train_mix_outer = mixup_data(X_train_full_scaled, y_train_full_encoded, alpha=0.2)
    
    #######################
    # BUILD & TRAIN MODEL #
    #######################

    optimizers = {
        'Adamax': Adamax(learning_rate=0.00510251984616472)
    }
    
    # Model definition with dynamic number of layers
    model_full = Sequential()
    model_full.add(Dense(480, activation='relu', input_shape=(X_train_full_scaled.shape[1],)))
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.2011047009431978))  
    model_full.add(Dense(256, activation='relu',)) 
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.14956886311951184))  
    model_full.add(Dense(256, activation='relu'))  
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.42291461228250665))  
    model_full.add(Dense(3, activation='softmax'))  
    
    # Use the optimizer from the parameters
    optimizer = optimizers['Adamax']  # optimizer_key from parameters
    
    # Compile the model
    model_full.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    
    # Train the model on the full training set
    history_full = model_full.fit(X_train_mix_outer, y_train_mix_outer, epochs=1500, batch_size=64,
                                  verbose=1, callbacks=[early_stopping])
    
    # Evaluate the model on the held-out test set
    test_loss, test_accuracy = model_full.evaluate(X_test_scaled, y_test_encoded)

    y_test_pred_prob = model_full.predict(X_test_scaled)
    y_test_pred = np.argmax(y_test_pred_prob, axis=1)  
    y_test_true = np.argmax(y_test_encoded, axis=1)    

    ################################
    # LOG MAJORITY VOTE PER CAT_ID #
    ################################

    # Convert numeric predictions back to age group labels
    predicted_age_groups = label_encoder.inverse_transform(y_test_pred)
    actual_labels = label_encoder.inverse_transform(y_test_true)
    
    # Map predictions and actual labels back to cat_ids
    test_results = pd.DataFrame({
        'cat_id': df_test_updated['cat_id'],
        'predicted_age_group': predicted_age_groups,
        'actual_age_group': actual_labels
    })
    
    # Group by cat_id and aggregate predicted age groups
    majority_votes = test_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
    actual_groups = test_results.groupby('cat_id')['actual_age_group'].first()
    
    # Calculate the accuracy of majority voting
    correct_predictions = (majority_votes == actual_groups).sum()
    total_cats = len(actual_groups)
    majority_vote_accuracy = correct_predictions / total_cats
    
    # Log the accuracy of the majority voting
    logger(f"Majority Vote Accuracy for cat_id for this fold: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

    ####################################################
    # COLLECT PREDICTIONS FOR GENDER & CAT_ID ANALYSIS #
    ####################################################

    # Debugging print statements
    print(f'Before appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Extend lists with current fold results
    all_cat_ids.extend(df_test_updated['cat_id'].tolist())
    all_predicted_age_groups.extend(predicted_age_groups)
    all_actual_age_groups.extend(actual_labels)
    all_gender.extend(df_test_updated['gender'].tolist())

    # Debugging print statements
    print(f'After appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Calculate additional metrics
    test_precision = precision_score(y_test_true, y_test_pred, average='macro')  # Use 'macro' for imbalanced datasets
    test_recall = recall_score(y_test_true, y_test_pred, average='macro')
    test_f1 = f1_score(y_test_true, y_test_pred, average='macro')

    # prepare averages of outer metrics
    unseen_f1.append(test_f1)
    unseen_losses.append(test_loss)
    unseen_accuracies.append(test_accuracy)
    unseen_precisions.append(test_precision)
    unseen_recalls.append(test_recall)

    # Print final test results
    logger(f"Final Test Results - Loss: {test_loss}, Accuracy: {test_accuracy}, Precision: {test_precision}, Recall: {test_recall}, F1 Score: {test_f1}", file=log_file_path)

    # Generate the confusion matrix
    cm = confusion_matrix(y_test, y_test_pred)
    logger(f"Confusion Matrix:\n {cm}", file=log_file_path)

# Calculate the overall average metrics
unseen_set_avg_f1 = np.mean(unseen_f1)
unseen_set_avg_loss = np.mean(unseen_losses)
unseen_set_avg_acc = np.mean(unseen_accuracies)
unseen_set_avg_precision = np.mean(unseen_precisions)
unseen_set_avg_recall = np.mean(unseen_recalls)

logger(f"\nFinal Average F1-Score across all UNSEEN TEST sets: {unseen_set_avg_f1}", file=log_file_path)
logger(f"\nFinal Average Loss across all UNSEEN TEST sets: {unseen_set_avg_loss}", file=log_file_path)
logger(f"\nFinal Average Accuracy across all UNSEEN TEST sets: {unseen_set_avg_acc}", file=log_file_path)
logger(f"\nFinal Average Precision across all UNSEEN TEST sets: {unseen_set_avg_precision}", file=log_file_path)
logger(f"\nFinal Average Recall across all UNSEEN TEST sets: {unseen_set_avg_recall}\n", file=log_file_path)

# Append averages to total lists
all_f1.append(unseen_set_avg_f1)
all_losses.append(unseen_set_avg_loss)
all_accuracies.append(unseen_set_avg_acc)
all_precisions.append(unseen_set_avg_precision)
all_recalls.append(unseen_set_avg_recall)
# Out:
# outer_fold 1
# Train Set Group Distribution:
# 046A    45
# 000A    39
# 103A    33
# 002B    30
# 047A    22
# 000B    19
# 057A    17
# 019A    17
# 074A    16
# 029A    15
# 097A    15
# 097B    14
# 002A    13
# 101A    12
# 111A    12
# 051A    12
# 028A    11
# 042A    11
# 067A    11
# 059A    10
# 014B    10
# 025A    10
# 065A     9
# 016A     9
# 072A     9
# 005A     9
# 022A     9
# 001A     9
# 013B     8
# 095A     7
# 027A     7
# 117A     7
# 031A     7
# 023A     6
# 021A     5
# 094A     5
# 050A     5
# 008A     5
# 109A     5
# 070A     5
# 108A     5
# 044A     5
# 045A     4
# 025C     4
# 009A     4
# 026A     4
# 012A     3
# 058A     3
# 010A     3
# 053A     3
# 006A     3
# 034A     3
# 014A     3
# 113A     3
# 105A     3
# 093A     2
# 025B     2
# 037A     2
# 102A     2
# 061A     2
# 035A     2
# 038A     2
# 052A     2
# 018A     2
# 032A     2
# 087A     2
# 041A     1
# 090A     1
# 100A     1
# 043A     1
# 110A     1
# 076A     1
# 115A     1
# 073A     1
# 064A     1
# 092A     1
# 019B     1
# 088A     1
# 004A     1
# 048A     1
# 066A     1
# 049A     1
# 091A     1
# 026B     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 020A    20
# 106A    13
# 116A    12
# 055A    12
# 063A    11
# 040A    10
# 051B     9
# 033A     9
# 071A     9
# 068A     8
# 015A     7
# 036A     7
# 039A     6
# 099A     6
# 007A     6
# 075A     5
# 023B     4
# 003A     4
# 104A     4
# 056A     3
# 062A     3
# 060A     3
# 054A     2
# 069A     2
# 011A     2
# 096A     1
# 026C     1
# 024A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    214
# M    208
# F    191
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# M    78
# X    62
# F    40
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [006A, 000A, 001A, 103A, 097B, 028A, 019A, 074...
# kitten    [044A, 014B, 111A, 046A, 047A, 042A, 109A, 050...
# senior    [093A, 097A, 057A, 059A, 113A, 117A, 051A, 058...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [033A, 015A, 071A, 020A, 062A, 039A, 063A, 099...
# kitten                                               [040A]
# senior    [106A, 104A, 055A, 116A, 051B, 054A, 056A, 011...
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 56, 'kitten': 15, 'senior': 13}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 18, 'kitten': 1, 'senior': 9}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '004A' '005A' '006A' '008A' '009A'
#  '010A' '012A' '013B' '014A' '014B' '016A' '018A' '019A' '019B' '021A'
#  '022A' '023A' '025A' '025B' '025C' '026A' '026B' '027A' '028A' '029A'
#  '031A' '032A' '034A' '035A' '037A' '038A' '041A' '042A' '043A' '044A'
#  '045A' '046A' '047A' '048A' '049A' '050A' '051A' '052A' '053A' '057A'
#  '058A' '059A' '061A' '064A' '065A' '066A' '067A' '070A' '072A' '073A'
#  '074A' '076A' '087A' '088A' '090A' '091A' '092A' '093A' '094A' '095A'
#  '097A' '097B' '100A' '101A' '102A' '103A' '105A' '108A' '109A' '110A'
#  '111A' '113A' '115A' '117A']
# Unique Test Group IDs:
# ['003A' '007A' '011A' '015A' '020A' '023B' '024A' '026C' '033A' '036A'
#  '039A' '040A' '051B' '054A' '055A' '056A' '060A' '062A' '063A' '068A'
#  '069A' '071A' '075A' '096A' '099A' '104A' '106A' '116A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '004A' '005A' '006A' '008A' '009A'
#  '010A' '012A' '013B' '014A' '014B' '016A' '018A' '019A' '019B' '021A'
#  '022A' '023A' '025A' '025B' '025C' '026A' '026B' '027A' '028A' '029A'
#  '031A' '032A' '034A' '035A' '037A' '038A' '041A' '042A' '043A' '044A'
#  '045A' '046A' '047A' '048A' '049A' '050A' '051A' '052A' '053A' '057A'
#  '058A' '059A' '061A' '064A' '065A' '066A' '067A' '070A' '072A' '073A'
#  '074A' '076A' '087A' '088A' '090A' '091A' '092A' '093A' '094A' '095A'
#  '097A' '097B' '100A' '101A' '102A' '103A' '105A' '108A' '109A' '110A'
#  '111A' '113A' '115A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['003A' '007A' '011A' '015A' '020A' '023B' '024A' '026C' '033A' '036A'
#  '039A' '040A' '051B' '054A' '055A' '056A' '060A' '062A' '063A' '068A'
#  '069A' '071A' '075A' '096A' '099A' '104A' '106A' '116A']
# Length of X_train_val:
# 613
# Length of y_train_val:
# 613
# Length of groups_train_val:
# 613
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     397
# kitten    125
# senior     91
# Name: age_group, dtype: int64
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     112
# senior     58
# kitten     10
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     397
# kitten    125
# senior     91
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     112
# senior     58
# kitten     10
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 397, 1: 125, 2: 91})
# Epoch 1/1500
# 10/10 [==============================] - 1s 5ms/step - loss: 1.1569 - accuracy: 0.6232
# Epoch 2/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5676 - accuracy: 0.8434
# Epoch 3/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3489 - accuracy: 0.9103
# Epoch 4/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.
1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1354 - accuracy: 0.9804
# Epoch 196/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1331 - accuracy: 0.9788
# Epoch 197/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1374 - accuracy: 0.9788
# Epoch 198/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1336 - accuracy: 0.9853
# Epoch 199/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1380 - accuracy: 0.9723
# Epoch 200/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1360 - accuracy: 0.9853
# Epoch 201/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1358 - accuracy: 0.9804
# Epoch 202/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1352 - accuracy: 0.9772
# Epoch 203/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1328 - accuracy: 0.9804
# Epoch 204/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1345 - accuracy: 0.9804
# Epoch 205/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1363 - accuracy: 0.9821
# Epoch 206/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1348 - accuracy: 0.9853
# Epoch 207/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1340 - accuracy: 0.9772
# Epoch 208/1500
# 10/10 [==============================] - 0s 14ms/step - loss: 0.1358 - accuracy: 0.9821
# Epoch 209/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1325 - accuracy: 0.9837
# Epoch 210/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1368 - accuracy: 0.9788
# Epoch 211/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1347 - accuracy: 0.9821
# Epoch 212/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1363 - accuracy: 0.9739
# Epoch 213/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1340 - accuracy: 0.9853
# Epoch 214/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1347 - accuracy: 0.9788
# Epoch 215/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1378 - accuracy: 0.9755
# Epoch 216/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1341 - accuracy: 0.9869
# Epoch 217/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1344 - accuracy: 0.9837
# Epoch 218/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1335 - accuracy: 0.9821
# Epoch 219/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1338 - accuracy: 0.9837
# Epoch 220/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1336 - accuracy: 0.9804
# Epoch 221/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1345 - accuracy: 0.9886
# Epoch 222/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1349 - accuracy: 0.9788
# Epoch 223/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1351 - accuracy: 0.9772
# Epoch 224/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1401 - accuracy: 0.9837
# Epoch 225/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1395 - accuracy: 0.9706
# Epoch 226/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1389 - accuracy: 0.9869
# Epoch 227/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1347 - accuracy: 0.9821
# Epoch 228/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1358 - accuracy: 0.9804
# Epoch 229/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1341 - accuracy: 0.9837
# Epoch 230/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1369 - accuracy: 0.9821
# Epoch 231/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1361 - accuracy: 0.9755
# Epoch 232/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1378 - accuracy: 0.9788
# Epoch 233/1500
# 10/10 [==============================] - ETA: 0s - loss: 0.1346 - accuracy: 0.9853Restoring model weights from the end of the best epoch: 203.
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1346 - accuracy: 0.9853
# Epoch 233: early stopping
# 6/6 [==============================] - 0s 2ms/step - loss: 1.1173 - accuracy: 0.7611
# 6/6 [==============================] - 0s 2ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.79 (22/28)
# Before appending - Cat IDs: 0, Predictions: 0, Actuals: 0, Gender: 0
# After appending - Cat IDs: 180, Predictions: 180, Actuals: 180, Gender: 180
# Final Test Results - Loss: 1.1173025369644165, Accuracy: 0.7611111402511597, Precision: 0.7888107263107264, Recall: 0.7667282430213463, F1 Score: 0.7230902777777777
# Confusion Matrix:
#  [[107   3   2]
#  [  0  10   0]
#  [ 37   1  20]]
# outer_fold 2
# Train Set Group Distribution:
# 046A    45
# 103A    33
# 047A    22
# 020A    20
# 057A    17
# 019A    17
# 097A    15
# 106A    13
# 116A    12
# 055A    12
# 051A    12
# 101A    12
# 111A    12
# 028A    11
# 042A    11
# 063A    11
# 040A    10
# 025A    10
# 059A    10
# 033A     9
# 016A     9
# 051B     9
# 072A     9
# 001A     9
# 071A     9
# 005A     9
# 068A     8
# 095A     7
# 031A     7
# 117A     7
# 015A     7
# 036A     7
# 027A     7
# 099A     6
# 039A     6
# 007A     6
# 075A     5
# 050A     5
# 021A     5
# 108A     5
# 008A     5
# 109A     5
# 094A     5
# 070A     5
# 104A     4
# 023B     4
# 003A     4
# 026A     4
# 045A     4
# 009A     4
# 060A     3
# 056A     3
# 010A     3
# 006A     3
# 014A     3
# 062A     3
# 034A     3
# 018A     2
# 025B     2
# 061A     2
# 011A     2
# 038A     2
# 052A     2
# 087A     2
# 054A     2
# 069A     2
# 090A     1
# 076A     1
# 043A     1
# 115A     1
# 073A     1
# 088A     1
# 004A     1
# 048A     1
# 066A     1
# 064A     1
# 026C     1
# 096A     1
# 091A     1
# 041A     1
# 092A     1
# 024A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 000A    39
# 002B    30
# 000B    19
# 074A    16
# 029A    15
# 097B    14
# 002A    13
# 067A    11
# 014B    10
# 022A     9
# 065A     9
# 013B     8
# 023A     6
# 044A     5
# 025C     4
# 113A     3
# 105A     3
# 058A     3
# 012A     3
# 053A     3
# 037A     2
# 035A     2
# 102A     2
# 032A     2
# 093A     2
# 019B     1
# 049A     1
# 110A     1
# 100A     1
# 026B     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    233
# M    194
# F    128
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# F    103
# M     92
# X     43
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [006A, 033A, 015A, 001A, 103A, 071A, 028A, 019...
# kitten    [111A, 040A, 046A, 047A, 042A, 109A, 050A, 043...
# senior    [097A, 057A, 106A, 104A, 055A, 059A, 116A, 051...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [000A, 097B, 074A, 067A, 002B, 022A, 029A, 065...
# kitten                             [044A, 014B, 049A, 110A]
# senior                                   [093A, 113A, 058A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 51, 'kitten': 12, 'senior': 19}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 23, 'kitten': 4, 'senior': 3}
# Unique Training/Validation Group IDs:
# ['001A' '003A' '004A' '005A' '006A' '007A' '008A' '009A' '010A' '011A'
#  '014A' '015A' '016A' '018A' '019A' '020A' '021A' '023B' '024A' '025A'
#  '025B' '026A' '026C' '027A' '028A' '031A' '033A' '034A' '036A' '038A'
#  '039A' '040A' '041A' '042A' '043A' '045A' '046A' '047A' '048A' '050A'
#  '051A' '051B' '052A' '054A' '055A' '056A' '057A' '059A' '060A' '061A'
#  '062A' '063A' '064A' '066A' '068A' '069A' '070A' '071A' '072A' '073A'
#  '075A' '076A' '087A' '088A' '090A' '091A' '092A' '094A' '095A' '096A'
#  '097A' '099A' '101A' '103A' '104A' '106A' '108A' '109A' '111A' '115A'
#  '116A' '117A']
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Unique Test Group IDs:
# ['000A' '000B' '002A' '002B' '012A' '013B' '014B' '019B' '022A' '023A'
#  '025C' '026B' '029A' '032A' '035A' '037A' '044A' '049A' '053A' '058A'
#  '065A' '067A' '074A' '093A' '097B' '100A' '102A' '105A' '110A' '113A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'000A'}
# Removed from Training/Validation Set:
# {'027A'}
# Moved to Test Set:
# {'027A'}
# Removed from Test Set
# {'000A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '001A' '003A' '004A' '005A' '006A' '007A' '008A' '009A' '010A'
#  '011A' '014A' '015A' '016A' '018A' '019A' '020A' '021A' '023B' '024A'
#  '025A' '025B' '026A' '026C' '028A' '031A' '033A' '034A' '036A' '038A'
#  '039A' '040A' '041A' '042A' '043A' '045A' '046A' '047A' '048A' '050A'
#  '051A' '051B' '052A' '054A' '055A' '056A' '057A' '059A' '060A' '061A'
#  '062A' '063A' '064A' '066A' '068A' '069A' '070A' '071A' '072A' '073A'
#  '075A' '076A' '087A' '088A' '090A' '091A' '092A' '094A' '095A' '096A'
#  '097A' '099A' '101A' '103A' '104A' '106A' '108A' '109A' '111A' '115A'
#  '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['000B' '002A' '002B' '012A' '013B' '014B' '019B' '022A' '023A' '025C'
#  '026B' '027A' '029A' '032A' '035A' '037A' '044A' '049A' '053A' '058A'
#  '065A' '067A' '074A' '093A' '097B' '100A' '102A' '105A' '110A' '113A']
# Length of X_train_val:
# 587
# Length of y_train_val:
# 587
# Length of groups_train_val:
# 587
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     296
# senior    141
# kitten    118
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     213
# kitten     17
# senior      8
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     328
# senior    141
# kitten    118
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     181
# kitten     17
# senior      8
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 328, 2: 141, 1: 118})
# Epoch 1/1500
# 10/10 [==============================] - 1s 5ms/step - loss: 1.2469 - accuracy: 0.6133
# Epoch 2/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4692 - accuracy: 0.8842
# Epoch 3/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3697 - accuracy: 0.9012
# Epoch 4/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3138 - accuracy: 0.9438
# Epoch 5/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3264 - accuracy: 0.9387
# Epoch 6/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2550 - accuracy: 0.9506
# Epoch 7/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2445 - accuracy: 0.9557
# Epoch 8/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2316 - accuracy: 0.9557
# Epoch 9/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2295 - accuracy: 0.9625
# Epoch 10/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2275 - accuracy: 0.9506
# Epoch 11/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2439 - accuracy: 0.9421
# Epoch 12/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2311 - accuracy: 0.9489
# Epoch 13/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2317 - accuracy: 0.9523
# Epoch 14/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.2338 - accuracy: 0.9404
# Epoch 15/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2302 - accuracy: 0.9557
# Epoch 16/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2344 - accuracy: 0.9404
# Epoch 17/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2197 - accuracy: 0.9506
# Epoch 18/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2117 - accuracy: 0.9659
# Epoch 19/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2136 - accuracy: 0.9591
# Epoch 20/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2077 - accuracy: 0.9574
# Epoch 21/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2168 - accuracy: 0.9540
# Epoch 22/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2104 - accuracy: 0.9404
# Epoch 23/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2089 - accuracy: 0.9625
# Epoch 24/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2072 - accuracy: 0.9608
# Epoch 25/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2155 - accuracy: 0.9557
# Epoch 26/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1950 - accuracy: 0.9608
# Epoch 27/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1938 - accuracy: 0.9642
# Epoch 28/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1848 - accuracy: 0.9659
# Epoch 29/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1867 - accuracy: 0.9744
# Epoch 30/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1915 - accuracy: 0.9574
# Epoch 31/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2034 - accuracy: 0.9540
# Epoch 32/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1833 - accuracy: 0.9727
# Epoch 33/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1989 - accuracy: 0.9574
# Epoch 34/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1865 - accuracy: 0.9625
# Epoch 35/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1901 - accuracy: 0.9591
# Epoch 36/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1927 - accuracy: 0.9523
# Epoch 37/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2016 - accuracy: 0.9557
# Epoch 38/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1931 - accuracy: 0.9523
# Epoch 39/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1901 - accuracy: 0.9540
# Epoch 40/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1777 - accuracy: 0.9744
# Epoch 41/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1879 - accuracy: 0.9710
# Epoch 42/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1880 - accuracy: 0.9710
# Epoch 43/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1866 - accuracy: 0.9540
# Epoch 44/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1882 - accuracy: 0.9472
# Epoch 45/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1801 - accuracy: 0.9727
# Epoch 46/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1794 - accuracy: 0.9557
# Epoch 47/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1929 - accuracy: 0.9557
# Epoch 48/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1792 - accuracy: 0.9625
# Epoch 49/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1811 - accuracy: 0.9574
# Epoch 50/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1884 - accuracy: 0.9557
# Epoch 51/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1824 - accuracy: 0.9608
# Epoch 52/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1790 - accuracy: 0.9693
# Epoch 53/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1807 - accuracy: 0.9642
# Epoch 54/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1750 - accuracy: 0.9574
# Epoch 55/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1813 - accuracy: 0.9557
# Epoch 56/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1808 - accuracy: 0.9574
# Epoch 57/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1821 - accuracy: 0.9472
# Epoch 58/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1746 - accuracy: 0.9625
# Epoch 59/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1759 - accuracy: 0.9574
# Epoch 60/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1723 - accuracy: 0.9625
# Epoch 61/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1714 - accuracy: 0.9727
# Epoch 62/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1754 - accuracy: 0.9625
# Epoch 63/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1765 - accuracy: 0.9710
# Epoch 64/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1722 - accuracy: 0.9761
# Epoch 65/1500
# 10/10 [==============================] - 0s 17ms/step - loss: 0.1687 - accuracy: 0.9608
# Epoch 66/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1677 - accuracy: 0.9693
# Epoch 67/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1705 - accuracy: 0.9625
# Epoch 68/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1721 - accuracy: 0.9608
# Epoch 69/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1725 - accuracy: 0.9659
# Epoch 70/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1685 - accuracy: 0.9693
# Epoch 71/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1758 - accuracy: 0.9591
# Epoch 72/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1643 - accuracy: 0.9659
# Epoch 73/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1742 - accuracy: 0.9540
# Epoch 74/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1683 - accuracy: 0.9676
# Epoch 75/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1710 - accuracy: 0.9625
# Epoch 76/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1647 - accuracy: 0.9506
# Epoch 77/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1646 - accuracy: 0.9625
# Epoch 78/1500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1628 - accuracy: 0.9557
# Epoch 79/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1679 - accuracy: 0.9727
# Epoch 80/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1690 - accuracy: 0.9710
# Epoch 81/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1666 - accuracy: 0.9727
# Epoch 82/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1671 - accuracy: 0.9676
# Epoch 83/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1686 - accuracy: 0.9591
# Epoch 84/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1742 - accuracy: 0.9591
# Epoch 85/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1606 - accuracy: 0.9693
# Epoch 86/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1611 - accuracy: 0.9625
# Epoch 87/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1582 - accuracy: 0.9710
# Epoch 88/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1657 - accuracy: 0.9557
# Epoch 89/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1690 - accuracy: 0.9506
# Epoch 90/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1623 - accuracy: 0.9710
# Epoch 91/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1593 - accuracy: 0.9591
# Epoch 92/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1606 - accuracy: 0.9625
# Epoch 93/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1655 - accuracy: 0.9676
# Epoch 94/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1618 - accuracy: 0.9625
# Epoch 95/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1590 - accuracy: 0.9744
# Epoch 96/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1589 - accuracy: 0.9676
# Epoch 97/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1631 - accuracy: 0.9710
# Epoch 98/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1612 - accuracy: 0.9642
# Epoch 99/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1596 - accuracy: 0.9608
# Epoch 100/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1639 - accuracy: 0.9642
# Epoch 101/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1679 - accuracy: 0.9710
# Epoch 102/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1644 - accuracy: 0.9659
# Epoch 103/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1614 - accuracy: 0.9642
# Epoch 104/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1671 - accuracy: 0.9625
# Epoch 105/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1667 - accuracy: 0.9608
# Epoch 106/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1603 - accuracy: 0.9796
# Epoch 107/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1641 - accuracy: 0.9676
# Epoch 108/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1619 - accuracy: 0.9744
# Epoch 109/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1598 - accuracy: 0.9727
# Epoch 110/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1687 - accuracy: 0.9591
# Epoch 111/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1592 - accuracy: 0.9625
# Epoch 112/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1541 - accuracy: 0.9659
# Epoch 113/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.
1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1636 - accuracy: 0.9720
# Epoch 163/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1592 - accuracy: 0.9612
# Epoch 164/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1666 - accuracy: 0.9705
# Epoch 165/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1630 - accuracy: 0.9720
# Epoch 166/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1535 - accuracy: 0.9720
# Epoch 167/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1602 - accuracy: 0.9783
# Epoch 168/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1505 - accuracy: 0.9720
# Epoch 169/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1478 - accuracy: 0.9736
# Epoch 170/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1508 - accuracy: 0.9705
# Epoch 171/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1528 - accuracy: 0.9658
# Epoch 172/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1621 - accuracy: 0.9596
# Epoch 173/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1613 - accuracy: 0.9752
# Epoch 174/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.1552 - accuracy: 0.9689
# Epoch 175/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1498 - accuracy: 0.9705
# Epoch 176/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1497 - accuracy: 0.9767
# Epoch 177/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1566 - accuracy: 0.9720
# Epoch 178/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1498 - accuracy: 0.9736
# Epoch 179/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1531 - accuracy: 0.9705
# Epoch 180/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1654 - accuracy: 0.9752
# Epoch 181/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1535 - accuracy: 0.9705
# Epoch 182/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1479 - accuracy: 0.9798
# Epoch 183/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1557 - accuracy: 0.9643
# Epoch 184/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1605 - accuracy: 0.9643
# Epoch 185/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1577 - accuracy: 0.9736
# Epoch 186/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1577 - accuracy: 0.9689
# Epoch 187/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1530 - accuracy: 0.9752
# Epoch 188/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1603 - accuracy: 0.9674
# Epoch 189/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1587 - accuracy: 0.9752
# Epoch 190/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1597 - accuracy: 0.9689
# Epoch 191/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1567 - accuracy: 0.9689
# Epoch 192/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1485 - accuracy: 0.9736
# Epoch 193/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1520 - accuracy: 0.9767
# Epoch 194/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1526 - accuracy: 0.9798
# Epoch 195/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1566 - accuracy: 0.9767
# Epoch 196/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1577 - accuracy: 0.9798
# Epoch 197/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1535 - accuracy: 0.9736
# Epoch 198/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1504 - accuracy: 0.9658
# Epoch 199/1500
# 10/11 [==========================>...] - ETA: 0s - loss: 0.1514 - accuracy: 0.9828Restoring model weights from the end of the best epoch: 169.
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1630 - accuracy: 0.9798
# Epoch 199: early stopping
# 5/5 [==============================] - 0s 2ms/step - loss: 1.2213 - accuracy: 0.6242
# 5/5 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.73 (19/26)
# Before appending - Cat IDs: 572, Predictions: 572, Actuals: 572, Gender: 572
# After appending - Cat IDs: 721, Predictions: 721, Actuals: 721, Gender: 721
# Final Test Results - Loss: 1.2213414907455444, Accuracy: 0.6241610646247864, Precision: 0.6167668361843118, Recall: 0.6461021123425216, F1 Score: 0.6185375574048034
# Confusion Matrix:
#  [[66  4 15]
#  [ 1 17  0]
#  [36  0 10]]
#
# Final Average F1-Score across all UNSEEN TEST sets: 0.6064476784508228
#
# Final Average Loss across all UNSEEN TEST sets: 1.1380788385868073
#
# Final Average Accuracy across all UNSEEN TEST sets: 0.6937186121940613
#
# Final Average Precision across all UNSEEN TEST sets: 0.6629153827697516
#
# Final Average Recall across all UNSEEN TEST sets: 0.6688915656502281

# %%
seed_4_folds_values = (unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1)

# Plotting all fold metrics
seed_4_folds_plot = plot_all_metrics(unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1, "Folds", "Fold Number")

# %% [markdown]
# ## Majority Voting on Total Entries per cat_id

# %%
# Debugging print statements
print(f'Checking - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
# Out:
# Checking - Cat IDs: 721, Predictions: 721, Actuals: 721, Gender: 721

# %%
# Create results df
full_results = pd.DataFrame({
    'cat_id': all_cat_ids,
    'predicted_age_group': all_predicted_age_groups,
    'actual_age_group': all_actual_age_groups,
    'all_gender': all_gender
})

# create a correct majority prediction column
full_results['correct'] = full_results['predicted_age_group'] == full_results['actual_age_group']

# %%
# Group by cat_id and aggregate predicted age groups
majority_votes = full_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first()

# Calculate the accuracy of majority voting
correct_predictions = (majority_votes == actual_groups).sum()
total_cats = len(actual_groups)
majority_vote_accuracy = correct_predictions / total_cats

logger(f"Overall Majority Vote Accuracy for cat_id: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

# store for final evaluation 
all_majority_vote_accuracies.append(majority_vote_accuracy)
# Out:
# Overall Majority Vote Accuracy for cat_id: 0.81 (89/110)

# %%
# Detailed df with predictions, actual labels, and comparison including majority vote
detailed_results = full_results.groupby('cat_id').apply(
    lambda x: pd.Series({
        'Predictions': list(x['predicted_age_group']),
        'Majority Vote': x['predicted_age_group'].mode()[0],
        'Actual Age Group': x['actual_age_group'].iloc[0],
        'Correct Majority Vote': x['predicted_age_group'].mode()[0] == x['actual_age_group'].iloc[0]
    })
).reset_index()

# Convert to DataFrame for better formatting and display
detailed_results = pd.DataFrame(detailed_results)

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 10)
pd.set_option('display.width', 1000)

sorted_detailed_results = detailed_results.sort_values(by='Correct Majority Vote', ascending=False)

# Display the sorted DataFrame
sorted_detailed_results
# Out:
#     cat_id                                        Predictions Majority Vote Actual Age Group  Correct Majority Vote
# 0     000B  [adult, senior, adult, adult, adult, adult, ad...         adult            adult                   True
# 49    043A                                           [kitten]        kitten           kitten                   True
# 79    073A                                            [adult]         adult            adult                   True
# 78    072A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 77    071A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 76    070A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 75    069A                                     [adult, adult]         adult            adult                   True
# 74    068A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 73    067A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 72    066A                                            [adult]         adult            adult                   True
# 71    065A  [senior, adult, adult, kitten, kitten, senior,...         adult            adult                   True
# 70    064A                                            [adult]         adult            adult                   True
# 69    063A  [adult, adult, adult, adult, senior, adult, ad...         adult            adult                   True
#
# Name: Majority_Correct, dtype: int64

# %%
# Calculate the total count and the number of correct predictions for each class
class_stats = majority_with_actual.groupby('actual_age_group').agg(
    total_count=('Majority_Correct', 'size'),  # Total number of cases per class
    correct_count=('Majority_Correct', 'sum')  # Sum of correct predictions per class
).reset_index()

# Calculate accuracy for each class
class_stats['accuracy'] = class_stats['correct_count'] / class_stats['total_count'] * 100

# store for final evaluation 
all_majority_vote_details.append(class_stats)

# Log detailed stats
print("Detailed Class Statistics for Majority Votes:")
print(class_stats)
# Out:
# Detailed Class Statistics for Majority Votes:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult           73             68  93.150685
# 1           kitten           15             11  73.333333
# 2           senior           22             10  45.454545

# %%
# Plot for Detailed Class Statistics for Majority Votes
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Accuracy of Majority Votes by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Detailed Class Statistics

# %%
# Calculate the total count and the number of correct predictions for each class
class_stats = full_results.groupby('actual_age_group').agg(
    total_count=('correct', 'size'),
    correct_count=('correct', 'sum')
).reset_index()

# Calculate accuracy for each class
class_stats['accuracy'] = class_stats['correct_count'] / class_stats['total_count'] * 100

# store for final evaluation 
all_class_stats.append(class_stats)

# Log the detailed stats
print("Detailed Class Statistics:")
print(class_stats)
# Out:
# Detailed Class Statistics:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult          477            404  84.696017
# 1           kitten           95             49  51.578947
# 2           senior          149             51  34.228188

# %%
# Plot for Detailed Class Statistics (Overall)
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Overall Accuracy by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Gender Exploration

# %%
# Group by gender and calculate the total count, correct predictions, and accuracy
gender_stats = full_results.groupby('all_gender').agg(
    count=('cat_id', 'size'),  # Total number of cases per gender
    correct=('correct', 'sum')  # Sum of correct predictions per gender
).reset_index()

# Calculate accuracy for each gender
gender_stats['accuracy'] = (gender_stats['correct'] / gender_stats['count'] * 100).round(2)

# Display the DataFrame
print("Accuracy by Gender:")
print(gender_stats)

# store for final evaluation 
all_gender_stats.append(gender_stats)
# Out:
# Accuracy by Gender:
#   all_gender  count  correct  accuracy
# 0          F    192      136     70.83
# 1          M    293      214     73.04
# 2          X    236      154     65.25

# %%
# Plot for Accuracy by Gender
styled_barplot(gender_stats, 'all_gender', 'accuracy', 
               'Accuracy by Gender', 
               'Gender', 'Accuracy (%)')

# %% [markdown]
# ### Log current total CV Stats

# %%
print("Total Majority Vote Accuracy so far:", all_majority_vote_accuracies)
print("Total Class Statistics so far:\n", all_class_stats)
print("Total Gender Accuracy so far:\n", all_gender_stats)
# Out:
# Total Majority Vote Accuracy so far: [0.7272727272727273, 0.7454545454545455, 0.7363636363636363, 0.8090909090909091]
# Total Class Statistics so far:
#  [  actual_age_group  total_count  correct_count   accuracy
# 0            adult          474            391  82.489451
# 1           kitten           91             43  47.252747
# 2           senior          149             41  27.516779,   actual_age_group  total_count  correct_count   accuracy
# 0            adult          473            380  80.338266
# 1           kitten          100             65  65.000000
# 2           senior          149             43  28.859060,   actual_age_group  total_count  correct_count   accuracy
# 0            adult          475            423  89.052632
# 1           kitten          102             56  54.901961
# 2           senior          149             36  24.161074,   actual_age_group  total_count  correct_count   accuracy
# 0            adult          477            404  84.696017
# 1           kitten           95             49  51.578947
# 2           senior          149             51  34.228188]
# Total Gender Accuracy so far:
#  [  all_gender  count  correct  accuracy
# 0          F    196      135     68.88
# 1          M    286      202     70.63
# 2          X    232      138     59.48,   all_gender  count  correct  accuracy
# 0          F    192      126     65.62
# 1          M    289      206     71.28
# 2          X    241      156     64.73,   all_gender  count  correct  accuracy
# 0          F    192      130     67.71
# 1          M    291      229     78.69
# 2          X    243      156     64.20,   all_gender  count  correct  accuracy
# 0          F    192      136     70.83
# 1          M    293      214     73.04
# 2          X    236      154     65.25]

# %% [markdown]
# # RANDOM SEED 5

# %%
# Set a fixed random seed for reproducibility
random.seed(int(random_seeds[4]))
np.random.seed(int(random_seeds[4]))
tf.random.set_seed(int(random_seeds[4]))

# Load datasets
dataframe = pd.read_csv('/Users/astrid/PycharmProjects/perch-2/scripts/perch_embeddings_april_10.csv')
dataframe.drop('mean_freq', axis=1, inplace=True)

def assign_age_group(age, age_groups):
    for group_name, age_range in age_groups.items():
        if age_range[0] <= age < age_range[1]:
            return group_name
    return 'Unknown'  # For any age that doesn't fit the defined groups

# Define age groups
age_groups = {
    'kitten': (0, 0.5),
    'adult': (0.5, 12),
    'senior': (12, 20)
}

# Create a new column for the age group
dataframe['age_group'] = dataframe['target'].apply(assign_age_group, age_groups=age_groups)

print(dataframe['age_group'].value_counts())
# Out:
# adult     509
# senior    149
# kitten    135
# Name: age_group, dtype: int64

# %%
# Separate features and labels
X = dataframe.iloc[:, :-4].values  # all columns except the last four

# Encode the 'age_group' column as integers using LabelEncoder
label_encoder = LabelEncoder()
encoded_y = label_encoder.fit_transform(dataframe['age_group'].values)

# Use the encoded labels for splitting and one-hot encoding
y = encoded_y  

# Convert 'cat_id' column to numpy array to be used as groups array for GroupKFold
groups = dataframe['cat_id'].values

# %%
tf.keras.backend.clear_session()

# %% [markdown]
# ## Run Setup

# %%
all_cat_ids = []
all_predicted_age_groups = []
all_actual_age_groups = []
all_gender = []

# Define the StratifiedGroupKFold splitter for 4 fold CV with random shuffling
outer_cv = StratifiedGroupKFold(n_splits=4, shuffle=True, random_state=int(random_seeds[4]))

# unseen test set metrics
unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1 = [], [], [], [], []

outer_fold = 0

# Use the splitter to generate indices for training and testing sets
# Note: GroupShuffleSplit.split returns indices, so we use it to index the arrays
for train_val_idx, test_idx in outer_cv.split(X, y, groups):
    outer_fold += 1
    logger(f"outer_fold {outer_fold}", file=log_file_path)

    # Convert indices back to DataFrame for easy manipulation
    df_train_val = dataframe.iloc[train_val_idx]
    df_test = dataframe.iloc[test_idx]

    ##############################
    # ASSESSING SPLITS BY CAT_ID #
    ##############################
    
    # Get the distribution of groups
    training_validation_group_distribution = df_train_val['cat_id'].value_counts()  
    testing_group_distribution = df_test['cat_id'].value_counts()  
    
    # Log or print the distribution
    logger(f"Train Set Group Distribution:\n{training_validation_group_distribution}", file=log_file_path)
    logger(f"Testing Set Group Distribution:\n{testing_group_distribution}", file=log_file_path)

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val['gender'].value_counts()
    testing_gender_distribution = df_test['gender'].value_counts()
    
    # Log the distribution
    logger(f"Training Set Gender Distribution BEFORE SWAP:\n{training_gender_distribution}", file=log_file_path)
    logger(f"Testing Set Gender Distribution BEFORE SWAP:\n{testing_gender_distribution}", file=log_file_path)

    # Group by 'age_group' and then list unique 'cat_id' within each age group
    unique_cat_ids_per_age_group_train_val = df_train_val.groupby('age_group')['cat_id'].unique()
    unique_cat_ids_per_age_group_test = df_test.groupby('age_group')['cat_id'].unique()
    
    # Log results
    logger(f"Unique Cat IDs per Age Group in Training/Validation Set:\n{unique_cat_ids_per_age_group_train_val}", file=log_file_path)
    logger(f"Unique Cat IDs per Age Group in Testing Set:\n{unique_cat_ids_per_age_group_test}", file=log_file_path)

    # Calculate the count of unique identifiers per age group for training and testing set
    counts_train_val = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_train_val.items()}
    counts_test = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_test.items()}

    # Log the counts of unique identifiers per age group
    logger(f"Count of Unique Cat IDs per Age Group in Training/Validation Set:\n{counts_train_val}", file=log_file_path)
    logger(f"Count of Unique Cat IDs per Age Group in Testing Set:\n{counts_test}", file=log_file_path)

    #######################################################
    # CONTINUE WITH ENSURING VALID AND APPROPRIATE SPLITS #
    #######################################################
    
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    groups_train_val, groups_test = groups[train_val_idx], groups[test_idx]

    # logging identifier splits 
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)

    # check group splits
    check_initial_group_split(groups_train_val, groups_test)

    # Specify the cat_ids that must be in the training/validation set
    specific_cat_ids = ['000A', '046A']
    
    # Perform the swapping operation
    train_val_idx, test_idx = swap_cat_id_instances(dataframe, train_val_idx, test_idx, specific_cat_ids)
    
    # Re-assign the sets based on the updated indices
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    new_groups_train_val, new_groups_test = groups[train_val_idx], groups[test_idx]

    # Find differences for training and test sets
    moved_to_train_val, removed_from_train_val = find_group_differences(groups_train_val, new_groups_train_val)
    moved_to_test, removed_from_test = find_group_differences(groups_test, new_groups_test)
    
    # Display the results
    logger(f"Moved to Training/Validation Set:\n{moved_to_train_val}", file=log_file_path)
    logger(f"Removed from Training/Validation Set:\n{removed_from_train_val}", file=log_file_path)
    logger(f"Moved to Test Set:\n{moved_to_test}", file=log_file_path)
    logger(f"Removed from Test Set\n{removed_from_test}", file=log_file_path)

    # Update X_train_val, X_test, y_train_val, y_test, groups_train_val, groups_test based on updated indices
    X_train_val = X[train_val_idx]
    y_train_val = y[train_val_idx]
    groups_train_val = groups[train_val_idx]
    
    X_test = X[test_idx]
    y_test = y[test_idx]
    groups_test = groups[test_idx]

    # logging identifier splits again after potential swaps
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"AFTER SWAP - Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"AFTER SWAP - Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)
    
    # Verify the lengths are consistent
    logger(f"Length of X_train_val:\n{len(X_train_val)}", file=log_file_path)
    logger(f"Length of y_train_val:\n{len(y_train_val)}", file=log_file_path)
    logger(f"Length of groups_train_val:\n{len(groups_train_val)}", file=log_file_path)

    # Check group splits once more
    check_initial_group_split(groups_train_val, groups_test)

    # Convert the modified indices back to a DataFrame representing the updated df_train_val
    df_train_val_updated = dataframe.iloc[train_val_idx].copy()
    df_test_updated = dataframe.iloc[test_idx].copy()

    ############################
    # LOGGING AGE GROUP SPLITS #
    ############################

    # Get the distribution of age groups of age groups before the update
    training_validation_age_group_distribution = df_train_val['age_group'].value_counts()
    testing_age_group_distribution = df_test['age_group'].value_counts()
    
    # Logthe distribution
    logger(f"Train Age Group Distribution BEFORE SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution BEFORE SWAP:\n{testing_age_group_distribution}", file=log_file_path)

    # Get the distribution of age groups after the update
    training_validation_age_group_distribution = df_train_val_updated['age_group'].value_counts()
    testing_age_group_distribution = df_test_updated['age_group'].value_counts()
    
    # Log the distribution
    logger(f"Train Age Group Distribution AFTER SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution AFTER SWAP:\n{testing_age_group_distribution}", file=log_file_path)
    
    ########################################################
    # TRACKING FINAL CAT_IDs & GENDER AFTER REDISTRIBUTION #
    ########################################################

    # Get the distribution of groups
    training_validation_group_distribution = df_train_val_updated['cat_id'].value_counts()  
    testing_group_distribution = df_test_updated['cat_id'].value_counts()  

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val_updated['gender'].value_counts()
    testing_gender_distribution = df_test_updated['gender'].value_counts()
    
    logger(f"\n Starting training on unseen test set\n", file=log_file_path)

    ###################
    # PREPARING MODEL #
    ###################

    # Calculate the distribution of age groups in y_train_val
    age_group_distribution = Counter(y_train_val)
    print("Age group distribution:", age_group_distribution)

    # EarlyStopping callback: monitor 'loss' instead of 'val_loss' for the test set
    early_stopping = EarlyStopping(
        monitor='loss',  
        min_delta=0.001, 
        patience=30,  
        verbose=1,  
        restore_best_weights=True  
    )

    # One final shuffle to ensure randomness
    outer_shuffle_idx = np.random.permutation(len(X_train_val))
    X_train_val = X_train_val[outer_shuffle_idx]
    y_train_val = y_train_val[outer_shuffle_idx]
    
    # Scale the features
    scaler_full = StandardScaler().fit(X_train_val)
    X_train_full_scaled = scaler_full.transform(X_train_val)
    X_test_scaled = scaler_full.transform(X_test)
    
    # Convert features to TensorFlow tensors
    X_train_full_scaled = tf.convert_to_tensor(X_train_full_scaled, dtype=tf.float32)
    X_test_scaled = tf.convert_to_tensor(X_test_scaled, dtype=tf.float32)
    
    # One-hot encode labels before mixup
    y_train_full_encoded = to_categorical(y_train_val)
    y_test_encoded = to_categorical(y_test)
    
    # Convert labels to TensorFlow tensors
    y_train_full_encoded = tf.convert_to_tensor(y_train_full_encoded, dtype=tf.float32)
    
    # Apply Mixup
    X_train_mix_outer, y_train_mix_outer = mixup_data(X_train_full_scaled, y_train_full_encoded, alpha=0.2)
    
    #######################
    # BUILD & TRAIN MODEL #
    #######################

    optimizers = {
        'Adamax': Adamax(learning_rate=0.00510251984616472)
    }
    
    # Model definition with dynamic number of layers
    model_full = Sequential()
    model_full.add(Dense(480, activation='relu', input_shape=(X_train_full_scaled.shape[1],)))
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.2011047009431978))  
    model_full.add(Dense(256, activation='relu',)) 
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.14956886311951184))  
    model_full.add(Dense(256, activation='relu'))  
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.42291461228250665))  
    model_full.add(Dense(3, activation='softmax'))  
    
    # Use the optimizer from the parameters
    optimizer = optimizers['Adamax']  # optimizer_key from parameters
    
    # Compile the model
    model_full.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    
    # Train the model on the full training set
    history_full = model_full.fit(X_train_mix_outer, y_train_mix_outer, epochs=1500, batch_size=64,
                                  verbose=1, callbacks=[early_stopping])
    
    # Evaluate the model on the held-out test set
    test_loss, test_accuracy = model_full.evaluate(X_test_scaled, y_test_encoded)

    y_test_pred_prob = model_full.predict(X_test_scaled)
    y_test_pred = np.argmax(y_test_pred_prob, axis=1)  
    y_test_true = np.argmax(y_test_encoded, axis=1)    

    ################################
    # LOG MAJORITY VOTE PER CAT_ID #
    ################################

    # Convert numeric predictions back to age group labels
    predicted_age_groups = label_encoder.inverse_transform(y_test_pred)
    actual_labels = label_encoder.inverse_transform(y_test_true)
    
    # Map predictions and actual labels back to cat_ids
    test_results = pd.DataFrame({
        'cat_id': df_test_updated['cat_id'],
        'predicted_age_group': predicted_age_groups,
        'actual_age_group': actual_labels
    })
    
    # Group by cat_id and aggregate predicted age groups
    majority_votes = test_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
    actual_groups = test_results.groupby('cat_id')['actual_age_group'].first()
    
    # Calculate the accuracy of majority voting
    correct_predictions = (majority_votes == actual_groups).sum()
    total_cats = len(actual_groups)
    majority_vote_accuracy = correct_predictions / total_cats
    
    # Log the accuracy of the majority voting
    logger(f"Majority Vote Accuracy for cat_id for this fold: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

    ####################################################
    # COLLECT PREDICTIONS FOR GENDER & CAT_ID ANALYSIS #
    ####################################################

    # Debugging print statements
    print(f'Before appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Extend lists with current fold results
    all_cat_ids.extend(df_test_updated['cat_id'].tolist())
    all_predicted_age_groups.extend(predicted_age_groups)
    all_actual_age_groups.extend(actual_labels)
    all_gender.extend(df_test_updated['gender'].tolist())

    # Debugging print statements
    print(f'After appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Calculate additional metrics
    test_precision = precision_score(y_test_true, y_test_pred, average='macro')  # Use 'macro' for imbalanced datasets
    test_recall = recall_score(y_test_true, y_test_pred, average='macro')
    test_f1 = f1_score(y_test_true, y_test_pred, average='macro')

    # prepare averages of outer metrics
    unseen_f1.append(test_f1)
    unseen_losses.append(test_loss)
    unseen_accuracies.append(test_accuracy)
    unseen_precisions.append(test_precision)
    unseen_recalls.append(test_recall)

    # Print final test results
    logger(f"Final Test Results - Loss: {test_loss}, Accuracy: {test_accuracy}, Precision: {test_precision}, Recall: {test_recall}, F1 Score: {test_f1}", file=log_file_path)

    # Generate the confusion matrix
    cm = confusion_matrix(y_test, y_test_pred)
    logger(f"Confusion Matrix:\n {cm}", file=log_file_path)

# Calculate the overall average metrics
unseen_set_avg_f1 = np.mean(unseen_f1)
unseen_set_avg_loss = np.mean(unseen_losses)
unseen_set_avg_acc = np.mean(unseen_accuracies)
unseen_set_avg_precision = np.mean(unseen_precisions)
unseen_set_avg_recall = np.mean(unseen_recalls)

logger(f"\nFinal Average F1-Score across all UNSEEN TEST sets: {unseen_set_avg_f1}", file=log_file_path)
logger(f"\nFinal Average Loss across all UNSEEN TEST sets: {unseen_set_avg_loss}", file=log_file_path)
logger(f"\nFinal Average Accuracy across all UNSEEN TEST sets: {unseen_set_avg_acc}", file=log_file_path)
logger(f"\nFinal Average Precision across all UNSEEN TEST sets: {unseen_set_avg_precision}", file=log_file_path)
logger(f"\nFinal Average Recall across all UNSEEN TEST sets: {unseen_set_avg_recall}\n", file=log_file_path)

# Append averages to total lists
all_f1.append(unseen_set_avg_f1)
all_losses.append(unseen_set_avg_loss)
all_accuracies.append(unseen_set_avg_acc)
all_precisions.append(unseen_set_avg_precision)
all_recalls.append(unseen_set_avg_recall)
# Out:
# outer_fold 1
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Train Set Group Distribution:
# 046A    45
# 103A    33
# 002B    30
# 020A    20
# 019A    17
# 057A    17
# 074A    16
# 097A    15
# 029A    15
# 097B    14
# 106A    13
# 002A    13
# 051A    12
# 055A    12
# 111A    12
# 116A    12
# 063A    11
# 028A    11
# 067A    11
# 014B    10
# 059A    10
# 025A    10
# 065A     9
# 005A     9
# 071A     9
# 033A     9
# 001A     9
# 013B     8
# 068A     8
# 117A     7
# 095A     7
# 027A     7
# 031A     7
# 036A     7
# 039A     6
# 007A     6
# 050A     5
# 094A     5
# 108A     5
# 008A     5
# 075A     5
# 021A     5
# 044A     5
# 109A     5
# 104A     4
# 003A     4
# 025C     4
# 026A     4
# 009A     4
# 045A     4
# 023B     4
# 060A     3
# 056A     3
# 014A     3
# 012A     3
# 105A     3
# 053A     3
# 061A     2
# 037A     2
# 093A     2
# 054A     2
# 035A     2
# 025B     2
# 011A     2
# 038A     2
# 087A     2
# 069A     2
# 032A     2
# 110A     1
# 090A     1
# 019B     1
# 004A     1
# 100A     1
# 049A     1
# 048A     1
# 026C     1
# 041A     1
# 092A     1
# 096A     1
# 064A     1
# 091A     1
# 073A     1
# 043A     1
# 026B     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 000A    39
# 047A    22
# 000B    19
# 101A    12
# 042A    11
# 040A    10
# 051B     9
# 072A     9
# 016A     9
# 022A     9
# 015A     7
# 023A     6
# 099A     6
# 070A     5
# 058A     3
# 010A     3
# 006A     3
# 113A     3
# 034A     3
# 062A     3
# 018A     2
# 052A     2
# 102A     2
# 076A     1
# 066A     1
# 088A     1
# 115A     1
# 024A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    241
# X    214
# F    136
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# F    95
# X    62
# M    45
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [033A, 001A, 103A, 071A, 097B, 028A, 019A, 074...
# kitten    [044A, 014B, 111A, 046A, 109A, 050A, 043A, 049...
# senior    [093A, 097A, 057A, 106A, 104A, 055A, 059A, 116...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [006A, 000A, 015A, 062A, 101A, 022A, 034A, 072...
# kitten                             [040A, 047A, 042A, 115A]
# senior                       [113A, 051B, 058A, 016A, 024A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 55, 'kitten': 12, 'senior': 17}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 19, 'kitten': 4, 'senior': 5}
# Unique Training/Validation Group IDs:
# ['001A' '002A' '002B' '003A' '004A' '005A' '007A' '008A' '009A' '011A'
#  '012A' '013B' '014A' '014B' '019A' '019B' '020A' '021A' '023B' '025A'
#  '025B' '025C' '026A' '026B' '026C' '027A' '028A' '029A' '031A' '032A'
#  '033A' '035A' '036A' '037A' '038A' '039A' '041A' '043A' '044A' '045A'
#  '046A' '048A' '049A' '050A' '051A' '053A' '054A' '055A' '056A' '057A'
#  '059A' '060A' '061A' '063A' '064A' '065A' '067A' '068A' '069A' '071A'
#  '073A' '074A' '075A' '087A' '090A' '091A' '092A' '093A' '094A' '095A'
#  '096A' '097A' '097B' '100A' '103A' '104A' '105A' '106A' '108A' '109A'
#  '110A' '111A' '116A' '117A']
# Unique Test Group IDs:
# ['000A' '000B' '006A' '010A' '015A' '016A' '018A' '022A' '023A' '024A'
#  '034A' '040A' '042A' '047A' '051B' '052A' '058A' '062A' '066A' '070A'
#  '072A' '076A' '088A' '099A' '101A' '102A' '113A' '115A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'000A'}
# Removed from Training/Validation Set:
# {'096A'}
# Moved to Test Set:
# {'096A'}
# Removed from Test Set
# {'000A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '001A' '002A' '002B' '003A' '004A' '005A' '007A' '008A' '009A'
#  '011A' '012A' '013B' '014A' '014B' '019A' '019B' '020A' '021A' '023B'
#  '025A' '025B' '025C' '026A' '026B' '026C' '027A' '028A' '029A' '031A'
#  '032A' '033A' '035A' '036A' '037A' '038A' '039A' '041A' '043A' '044A'
#  '045A' '046A' '048A' '049A' '050A' '051A' '053A' '054A' '055A' '056A'
#  '057A' '059A' '060A' '061A' '063A' '064A' '065A' '067A' '068A' '069A'
#  '071A' '073A' '074A' '075A' '087A' '090A' '091A' '092A' '093A' '094A'
#  '095A' '097A' '097B' '100A' '103A' '104A' '105A' '106A' '108A' '109A'
#  '110A' '111A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['000B' '006A' '010A' '015A' '016A' '018A' '022A' '023A' '024A' '034A'
#  '040A' '042A' '047A' '051B' '052A' '058A' '062A' '066A' '070A' '072A'
#  '076A' '088A' '096A' '099A' '101A' '102A' '113A' '115A']
# Length of X_train_val:
# 629
# Length of y_train_val:
# 629
# Length of groups_train_val:
# 629
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     376
# senior    124
# kitten     91
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     133
# kitten     44
# senior     25
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     414
# senior    124
# kitten     91
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     95
# kitten    44
# senior    25
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 414, 2: 124, 1: 91})
# Epoch 1/1500
# 10/10 [==============================] - 1s 6ms/step - loss: 1.1236 - accuracy: 0.6216
# Epoch 2/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.4647 - accuracy: 0.8633
# Epoch 3/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3107 - accuracy: 0.9444
# Epoch 4/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2740 - accuracy: 0.9603
# Epoch 5/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2404 - accuracy: 0.9634
# Epoch 6/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2208 - accuracy: 0.9714
# Epoch 7/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2317 - accuracy: 0.9523
# Epoch 8/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2319 - accuracy: 0.9698
# Epoch 9/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2142 - accuracy: 0.9587
# Epoch 10/1500
# 10/10 [==============================] - 0s 5ms/step - loss: 0.2016 - accuracy: 0.9666
# Epoch 11/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1996 - accuracy: 0.9650
# Epoch 12/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1968 - accuracy: 0.9698
# Epoch 13/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1861 - accuracy: 0.9746
# Epoch 14/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1923 - accuracy: 0.9618
# Epoch 15/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1995 - accuracy: 0.9634
# Epoch 16/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1939 - accuracy: 0.9475
# Epoch 17/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1936 - accuracy: 0.9603
# Epoch 18/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1804 - accuracy: 0.9682
# Epoch 19/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1687 - accuracy: 0.9634
# Epoch 20/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1881 - accuracy: 0.9603
# Epoch 21/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1835 - accuracy: 0.9650
# Epoch 22/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1779 - accuracy: 0.9571
# Epoch 23/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1765 - accuracy: 0.9603
# Epoch 24/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1775 - accuracy: 0.9698
# Epoch 25/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1695 - accuracy: 0.9666
# Epoch 26/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1572 - accuracy: 0.9650
# Epoch 27/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1644 - accuracy: 0.9746
# Epoch 28/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1629 - accuracy: 0.9650
# Epoch 29/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1621 - accuracy: 0.9618
# Epoch 30/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1605 - accuracy: 0.9555
# Epoch 31/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1619 - accuracy: 0.9650
# Epoch 32/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1551 - accuracy: 0.9746
# Epoch 33/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1625 - accuracy: 0.9730
# Epoch 34/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1625 - accuracy: 0.9666
# Epoch 35/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1645 - accuracy: 0.9682
# Epoch 36/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1604 - accuracy: 0.9634
# Epoch 37/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1614 - accuracy: 0.9698
# Epoch 38/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1547 - accuracy: 0.9730
# Epoch 39/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1504 - accuracy: 0.9698
# Epoch 40/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1534 - accuracy: 0.9603
# Epoch 41/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1696 - accuracy: 0.9555
# Epoch 42/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1521 - accuracy: 0.9603
# Epoch 43/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1509 - accuracy: 0.9634
# Epoch 44/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1483 - accuracy: 0.9714
# Epoch 45/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1463 - accuracy: 0.9714
# Epoch 46/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1520 - accuracy: 0.9730
# Epoch 47/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1509 - accuracy: 0.9698
# Epoch 48/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1538 - accuracy: 0.9634
# Epoch 49/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1478 - accuracy: 0.9762
# Epoch 50/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1492 - accuracy: 0.9730
# Epoch 51/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1474 - accuracy: 0.9618
# Epoch 52/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1498 - accuracy: 0.9666
# Epoch 53/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1468 - accuracy: 0.9603
# Epoch 54/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1443 - accuracy: 0.9714
# Epoch 55/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1463 - accuracy: 0.9698
# Epoch 56/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1456 - accuracy: 0.9730
# Epoch 57/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1429 - accuracy: 0.9762
# Epoch 58/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1447 - accuracy: 0.9650
# Epoch 59/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1395 - accuracy: 0.9762
# Epoch 60/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1408 - accuracy: 0.9746
# Epoch 61/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1410 - accuracy: 0.9762
# Epoch 62/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1393 - accuracy: 0.9666
# Epoch 63/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1392 - accuracy: 0.9825
# Epoch 64/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1460 - accuracy: 0.9793
# Epoch 65/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1451 - accuracy: 0.9793
# Epoch 66/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1401 - accuracy: 0.9746
# Epoch 67/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1413 - accuracy: 0.9730
# Epoch 68/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1362 - accuracy: 0.9714
# Epoch 69/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1370 - accuracy: 0.9746
# Epoch 70/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1384 - accuracy: 0.9682
# Epoch 71/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1445 - accuracy: 0.9682
# Epoch 72/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1394 - accuracy: 0.9698
# Epoch 73/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1397 - accuracy: 0.9730
# Epoch 74/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1367 - accuracy: 0.9762
# Epoch 75/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1432 - accuracy: 0.9666
# Epoch 76/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1361 - accuracy: 0.9698
# Epoch 77/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1386 - accuracy: 0.9650
# Epoch 78/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1363 - accuracy: 0.9650
# Epoch 79/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1376 - accuracy: 0.9730
# Epoch 80/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1349 - accuracy: 0.9841
# Epoch 81/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1389 - accuracy: 0.9714
# Epoch 82/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1342 - accuracy: 0.9746
# Epoch 83/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1351 - accuracy: 0.9730
# Epoch 84/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1365 - accuracy: 0.9777
# Epoch 85/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1354 - accuracy: 0.9793
# Epoch 86/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1363 - accuracy: 0.9682
# Epoch 87/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1332 - accuracy: 0.9777
# Epoch 88/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1338 - accuracy: 0.9730
# Epoch 89/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1370 - accuracy: 0.9698
# Epoch 90/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1348 - accuracy: 0.9682
# Epoch 91/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1354 - accuracy: 0.9682
# Epoch 92/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1365 - accuracy: 0.9730
# Epoch 93/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1339 - accuracy: 0.9793
# Epoch 94/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1339 - accuracy: 0.9730
# Epoch 95/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1343 - accuracy: 0.9841
# Epoch 96/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1324 - accuracy: 0.9841
# Epoch 97/1500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1308 - accuracy: 0.9777
# Epoch 98/1500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1339 - accuracy: 0.9746
# Epoch 99/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1335 - accuracy: 0.9714
# Epoch 100/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1320 - accuracy: 0.9746
# Epoch 101/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1296 - accuracy: 0.9825
# Epoch 102/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1300 - accuracy: 0.9762
# Epoch 103/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1289 - accuracy: 0.9762
# Epoch 104/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1264 - accuracy: 0.9777
# Epoch 105/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1342 - accuracy: 0.9777
# Epoch 106/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1299 - accuracy: 0.9762
# Epoch 107/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1370 - accuracy: 0.9666
# Epoch 108/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1291 - accuracy: 0.9809
# Epoch 109/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1274 - accuracy: 0.9730
# Epoch 110/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1331 - accuracy: 0.9762
# Epoch 111/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1281 - accuracy: 0.9777
# Epoch 112/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1328 - accuracy: 0.9714
# Epoch 113/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1314 - accuracy: 0.9777
# Epoch 114/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1305 - accuracy: 0.9793
# Epoch 115/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1335 - accuracy: 0.9746
# Epoch 116/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1328 - accuracy: 0.9698
# Epoch 117/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1339 - accuracy: 0.9650
# Epoch 118/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1317 - accuracy: 0.9714
# Epoch 119/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1326 - accuracy: 0.9682
# Epoch 120/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1287 - accuracy: 0.9809
# Epoch 121/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1310 - accuracy: 0.9746
# Epoch 122/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1310 - accuracy: 0.9746
# Epoch 123/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1270 - accuracy: 0.9777
# Epoch 124/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1279 - accuracy: 0.9746
# Epoch 125/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1307 - accuracy: 0.9746
# Epoch 126/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1256 - accuracy: 0.9809
# Epoch 127/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1280 - accuracy: 0.9809
# Epoch 128/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1317 - accuracy: 0.9730
# Epoch 129/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1288 - accuracy: 0.9809
# Epoch 130/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1261 - accuracy: 0.9746
# Epoch 131/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1297 - accuracy: 0.9714
# Epoch 132/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1263 - accuracy: 0.9793
# Epoch 133/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1243 - accuracy: 0.9809
# Epoch 134/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1288 - accuracy: 0.9714
# Epoch 135/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1268 - accuracy: 0.9793
# Epoch 136/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1310 - accuracy: 0.9777
# Epoch 137/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1265 - accuracy: 0.9809
# Epoch 138/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1287 - accuracy: 0.9762
# Epoch 139/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1330 - accuracy: 0.9666
# Epoch 140/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1272 - accuracy: 0.9746
# Epoch 141/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1271 - accuracy: 0.9809
# Epoch 142/1500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1277 - accuracy: 0.9714
# Epoch 143/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1282 - accuracy: 0.9762
# Epoch 144/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1244 - accuracy: 0.9825
# Epoch 145/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1253 - accuracy: 0.9793
# Epoch 146/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1247 - accuracy: 0.9809
# Epoch 147/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1247 - accuracy: 0.9777
# Epoch 148/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1251 - accuracy: 0.9825
# Epoch 149/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1273 - accuracy: 0.9714
# Epoch 150/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1265 - accuracy: 0.9825
# Epoch 151/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1247 - accuracy: 0.9746
# Epoch 152/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1262 - accuracy: 0.9841
# Epoch 153/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1293 - accuracy: 0.9825
# Epoch 154/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1252 - accuracy: 0.9762
# Epoch 155/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1274 - accuracy: 0.9762
# Epoch 156/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1252 - accuracy: 0.9841
# Epoch 157/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1263 - accuracy: 0.9730
# Epoch 158/1500
# 10/10 [==============================] - 0s 16ms/step - loss: 0.1260 - accuracy: 0.9746
# Epoch 159/1500
# 10/10 [==============================] - 0s 8ms/step - loss: 0.1250 - accuracy: 0.9777
# Epoch 160/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1241 - accuracy: 0.9825
# Epoch 161/1500
# 10/10 [==============================] - 0s 6ms/step - loss: 0.1250 - accuracy: 0.9777
# Epoch 162/1500
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1257 - accuracy: 0.9809
# Epoch 163/1500
# 10/10 [==============================] - ETA: 0s - loss: 0.1236 - accuracy: 0.9857Restoring model weights from the end of the best epoch: 133.
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1236 - accuracy: 0.9857
# Epoch 163: early stopping
# 6/6 [==============================] - 0s 2ms/step - loss: 1.4677 - accuracy: 0.6402
# 6/6 [==============================] - 0s 2ms/step
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Majority Vote Accuracy for cat_id for this fold: 0.82 (23/28)
# Before appending - Cat IDs: 0, Predictions: 0, Actuals: 0, Gender: 0
# After appending - Cat IDs: 164, Predictions: 164, Actuals: 164, Gender: 164
# Final Test Results - Loss: 1.4677338600158691, Accuracy: 0.6402438879013062, Precision: 0.6388230127360561, Recall: 0.47210526315789475, F1 Score: 0.4871931653774965
# Confusion Matrix:
#  [[88  4  3]
#  [31 11  2]
#  [19  0  6]]
# outer_fold 2
# Train Set Group Distribution:
# 046A    45
# 000A    39
# 002B    30
# 047A    22
# 020A    20
# 000B    19
# 019A    17
# 029A    15
# 002A    13
# 101A    12
# 055A    12
# 067A    11
# 028A    11
# 063A    11
# 042A    11
# 040A    10
# 059A    10
# 072A     9
# 016A     9
# 065A     9
# 051B     9
# 071A     9
# 001A     9
# 005A     9
# 022A     9
# 013B     8
# 068A     8
# 036A     7
# 117A     7
# 015A     7
# 027A     7
# 095A     7
# 099A     6
# 007A     6
# 023A     6
# 039A     6
# 108A     5
# 075A     5
# 070A     5
# 109A     5
# 050A     5
# 026A     4
# 104A     4
# 025C     4
# 023B     4
# 058A     3
# 010A     3
# 053A     3
# 060A     3
# 006A     3
# 105A     3
# 062A     3
# 034A     3
# 113A     3
# 014A     3
# 018A     2
# 037A     2
# 011A     2
# 102A     2
# 052A     2
# 061A     2
# 087A     2
# 093A     2
# 054A     2
# 115A     1
# 019B     1
# 100A     1
# 090A     1
# 024A     1
# 110A     1
# 066A     1
# 088A     1
# 004A     1
# 048A     1
# 041A     1
# 092A     1
# 049A     1
# 064A     1
# 043A     1
# 076A     1
# 096A     1
# 026B     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 103A    33
# 057A    17
# 074A    16
# 097A    15
# 097B    14
# 106A    13
# 111A    12
# 051A    12
# 116A    12
# 014B    10
# 025A    10
# 033A     9
# 031A     7
# 044A     5
# 021A     5
# 094A     5
# 008A     5
# 045A     4
# 003A     4
# 009A     4
# 012A     3
# 056A     3
# 035A     2
# 032A     2
# 069A     2
# 038A     2
# 025B     2
# 073A     1
# 026C     1
# 091A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    192
# X    189
# F    181
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# M    94
# X    87
# F    50
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [006A, 000A, 015A, 001A, 071A, 028A, 019A, 067...
# kitten    [040A, 046A, 047A, 042A, 109A, 050A, 043A, 049...
# senior    [093A, 104A, 055A, 059A, 113A, 051B, 054A, 117...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [033A, 103A, 097B, 074A, 091A, 009A, 038A, 025...
# kitten                             [044A, 014B, 111A, 045A]
# senior           [097A, 057A, 106A, 116A, 056A, 051A, 094A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 55, 'kitten': 12, 'senior': 15}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 19, 'kitten': 4, 'senior': 7}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '004A' '005A' '006A' '007A' '010A'
#  '011A' '013B' '014A' '015A' '016A' '018A' '019A' '019B' '020A' '022A'
#  '023A' '023B' '024A' '025C' '026A' '026B' '027A' '028A' '029A' '034A'
#  '036A' '037A' '039A' '040A' '041A' '042A' '043A' '046A' '047A' '048A'
#  '049A' '050A' '051B' '052A' '053A' '054A' '055A' '058A' '059A' '060A'
#  '061A' '062A' '063A' '064A' '065A' '066A' '067A' '068A' '070A' '071A'
#  '072A' '075A' '076A' '087A' '088A' '090A' '092A' '093A' '095A' '096A'
#  '099A' '100A' '101A' '102A' '104A' '105A' '108A' '109A' '110A' '113A'
#  '115A' '117A']
# Unique Test Group IDs:
# ['003A' '008A' '009A' '012A' '014B' '021A' '025A' '025B' '026C' '031A'
#  '032A' '033A' '035A' '038A' '044A' '045A' '051A' '056A' '057A' '069A'
#  '073A' '074A' '091A' '094A' '097A' '097B' '103A' '106A' '111A' '116A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '004A' '005A' '006A' '007A' '010A'
#  '011A' '013B' '014A' '015A' '016A' '018A' '019A' '019B' '020A' '022A'
#  '023A' '023B' '024A' '025C' '026A' '026B' '027A' '028A' '029A' '034A'
#  '036A' '037A' '039A' '040A' '041A' '042A' '043A' '046A' '047A' '048A'
#  '049A' '050A' '051B' '052A' '053A' '054A' '055A' '058A' '059A' '060A'
#  '061A' '062A' '063A' '064A' '065A' '066A' '067A' '068A' '070A' '071A'
#  '072A' '075A' '076A' '087A' '088A' '090A' '092A' '093A' '095A' '096A'
#  '099A' '100A' '101A' '102A' '104A' '105A' '108A' '109A' '110A' '113A'
#  '115A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['003A' '008A' '009A' '012A' '014B' '021A' '025A' '025B' '026C' '031A'
#  '032A' '033A' '035A' '038A' '044A' '045A' '051A' '056A' '057A' '069A'
#  '073A' '074A' '091A' '094A' '097A' '097B' '103A' '106A' '111A' '116A']
# Length of X_train_val:
# 562
# Length of y_train_val:
# 562
# Length of groups_train_val:
# 562
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     386
# kitten    104
# senior     72
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     123
# senior     77
# kitten     31
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     386
# kitten    104
# senior     72
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     123
# senior     77
# kitten     31
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 386, 1: 104, 2: 72})
# Epoch 1/1500
# 9/9 [==============================] - 1s 5ms/step - loss: 1.2292 - accuracy: 0.5943
# Epoch 2/1500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.4621 - accuracy: 0.8594
# Epoch 3/1500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.3084 - accuracy: 0.9306
# Epoch 4/1500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2589 - accuracy: 0.9573
# Epoch 5/1500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2449 - accuracy: 0.9555
# Epoch 6/1500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2162 - accuracy: 0.9644
# Epoch 7/1500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2181 - accuracy: 0.9573
# Epoch 8/1500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1951 - accuracy: 0.9715
# Epoch 9/1500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.2043 - accuracy: 0.9698
# Epoch 10/1500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1821 - accuracy: 0.9715
# Epoch 11/1500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1734 - accuracy: 0.9698
# Epoch 12/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1799 - accuracy: 0.9573
# Epoch 13/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1842 - accuracy: 0.9591
# Epoch 14/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1693 - accuracy: 0.9786
# Epoch 15/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1747 - accuracy: 0.9715
# Epoch 16/1500
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1671 - accuracy: 0.9715
# Epoch 17/1500
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1680 - accuracy: 0.9751
# Epoch 18/1500
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1572 - accuracy: 0.9751
# Epoch 19/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1674 - accuracy: 0.9751
# Epoch 20/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1599 - accuracy: 0.9644
# Epoch 21/1500
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1501 - accuracy: 0.9733
# Epoch 22/1500
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1594 - accuracy: 0.9644
# Epoch 23/1500
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1497 - accuracy: 0.9733
# Epoch 24/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1474 - accuracy: 0.9786
# Epoch 25/1500
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1436 - accuracy: 0.9733
# Epoch 26/1500
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1476 - accuracy: 0.9555
# Epoch 27/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1471 - accuracy: 0.9786
# Epoch 28/1500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1473 - accuracy: 0.9698
# Epoch 29/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1572 - accuracy: 0.9680
# Epoch 30/1500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1467 - accuracy: 0.9680
# Epoch 31/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1439 - accuracy: 0.9769
# Epoch 32/1500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1579 - accuracy: 0.9698
# Epoch 33/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1457 - accuracy: 0.9733
# Epoch 34/1500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1368 - accuracy: 0.9751
# Epoch 35/1500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1435 - accuracy: 0.9698
# Epoch 36/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1409 - accuracy: 0.9804
# Epoch 37/1500
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1325 - accuracy: 0.9715
# Epoch 38/1500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1359 - accuracy: 0.9698
# Epoch 39/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1343 - accuracy: 0.9769
# Epoch 40/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1381 - accuracy: 0.9662
# Epoch 41/1500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1360 - accuracy: 0.9680
# Epoch 42/1500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1374 - accuracy: 0.9786
# Epoch 43/1500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1328 - accuracy: 0.9751
# Epoch 44/1500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1290 - accuracy: 0.9786
# Epoch 45/1500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1295 - accuracy: 0.9733
# Epoch 46/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1316 - accuracy: 0.9733
# Epoch 47/1500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1463 - accuracy: 0.9609
# Epoch 48/1500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1331 - accuracy: 0.9662
# Epoch 49/1500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1306 - accuracy: 0.9786
# Epoch 50/1500
# 9/9 [==============================] - 0s 5ms/step - loss: 0.1373 - accuracy: 0.9715
# Epoch 51/1500
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1299 - accuracy: 0.9751
# Epoch 52/1500
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1292 - accuracy: 0.9715
# Epoch 53/1500
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1288 - accuracy: 0.9751
# Epoch 54/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1343 - accuracy: 0.9662
# Epoch 55/1500
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1274 - accuracy: 0.9769
# Epoch 56/1500
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1300 - accuracy: 0.9715
# Epoch 57/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1302 - accuracy: 0.9698
# Epoch 58/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1307 - accuracy: 0.9733
# Epoch 59/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1331 - accuracy: 0.9769
# Epoch 60/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1296 - accuracy: 0.9715
# Epoch 61/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1401 - accuracy: 0.9840
# Epoch 62/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1244 - accuracy: 0.9733
# Epoch 63/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1326 - accuracy: 0.9840
# Epoch 64/1500
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1345 - accuracy: 0.9662
# Epoch 65/1500
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1217 - accuracy: 0.9804
# Epoch 66/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1275 - accuracy: 0.9680
# Epoch 67/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1277 - accuracy: 0.9715
# Epoch 68/1500
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1255 - accuracy: 0.9698
# Epoch 69/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1241 - accuracy: 0.9769
# Epoch 70/1500
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1352 - accuracy: 0.9662
# Epoch 71/1500
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1234 - accuracy: 0.9822
# Epoch 72/1500
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1206 - accuracy: 0.9822
# Epoch 73/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1238 - accuracy: 0.9609
# Epoch 74/1500
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1239 - accuracy: 0.9733
# Epoch 75/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1262 - accuracy: 0.9786
# Epoch 76/1500
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1189 - accuracy: 0.9804
# Epoch 77/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1301 - accuracy: 0.9715
# Epoch 78/1500
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1320 - accuracy: 0.9644
# Epoch 79/1500
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1225 - accuracy: 0.9804
# Epoch 80/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1161 - accuracy: 0.9769
# Epoch 81/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1208 - accuracy: 0.9769
# Epoch 82/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1233 - accuracy: 0.9804
# Epoch 83/1500
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1168 - accuracy: 0.9733
# Epoch 84/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1162 - accuracy: 0.9875
# Epoch 85/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1140 - accuracy: 0.9822
# Epoch 86/1500
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1178 - accuracy: 0.9662
# Epoch 87/1500
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1201 - accuracy: 0.9733
# Epoch 88/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1219 - accuracy: 0.9662
# Epoch 89/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1269 - accuracy: 0.9644
# Epoch 90/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1147 - accuracy: 0.9875
# Epoch 91/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1224 - accuracy: 0.9804
# Epoch 92/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1162 - accuracy: 0.9840
# Epoch 93/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1213 - accuracy: 0.9698
# Epoch 94/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1185 - accuracy: 0.9822
# Epoch 95/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1159 - accuracy: 0.9733
# Epoch 96/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1143 - accuracy: 0.9893
# Epoch 97/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1214 - accuracy: 0.9715
# Epoch 98/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1171 - accuracy: 0.9698
# Epoch 99/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1150 - accuracy: 0.9751
# Epoch 100/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1141 - accuracy: 0.9822
# Epoch 101/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1202 - accuracy: 0.9733
# Epoch 102/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1153 - accuracy: 0.9786
# Epoch 103/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1124 - accuracy: 0.9751
# Epoch 104/1500
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1171 - accuracy: 0.9715
# Epoch 105/1500
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1194 - accuracy: 0.9858
# Epoch 106/1500
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1143 - accuracy: 0.9698
# Epoch 107/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1214 - accuracy: 0.9626
# Epoch 108/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1144 - accuracy: 0.9875
# Epoch 109/1500
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1153 - accuracy: 0.9715
# Epoch 110/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1129 - accuracy: 0.9822
# Epoch 111/1500
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1159 - accuracy: 0.9858
# Epoch 112/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.
1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1043 - accuracy: 0.9840
# Epoch 175/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1081 - accuracy: 0.9858
# Epoch 176/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1037 - accuracy: 0.9769
# Epoch 177/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1052 - accuracy: 0.9769
# Epoch 178/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1064 - accuracy: 0.9822
# Epoch 179/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1095 - accuracy: 0.9804
# Epoch 180/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1072 - accuracy: 0.9875
# Epoch 181/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1081 - accuracy: 0.9858
# Epoch 182/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1070 - accuracy: 0.9840
# Epoch 183/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1055 - accuracy: 0.9875
# Epoch 184/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1051 - accuracy: 0.9875
# Epoch 185/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1094 - accuracy: 0.9751
# Epoch 186/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1061 - accuracy: 0.9840
# Epoch 187/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1064 - accuracy: 0.9822
# Epoch 188/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1073 - accuracy: 0.9858
# Epoch 189/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1065 - accuracy: 0.9786
# Epoch 190/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1046 - accuracy: 0.9804
# Epoch 191/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1039 - accuracy: 0.9804
# Epoch 192/1500
# 9/9 [==============================] - 0s 6ms/step - loss: 0.1035 - accuracy: 0.9786
# Epoch 193/1500
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1039 - accuracy: 0.9858
# Epoch 194/1500
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1059 - accuracy: 0.9751
# Epoch 195/1500
# 9/9 [==============================] - ETA: 0s - loss: 0.1028 - accuracy: 0.9858Restoring model weights from the end of the best epoch: 165.
# 9/9 [==============================] - 0s 7ms/step - loss: 0.1028 - accuracy: 0.9858
# Epoch 195: early stopping
# 8/8 [==============================] - 0s 2ms/step - loss: 1.4333 - accuracy: 0.6320
# 8/8 [==============================] - 0s 1ms/step
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Majority Vote Accuracy for cat_id for this fold: 0.73 (22/30)
# Before appending - Cat IDs: 164, Predictions: 164, Actuals: 164, Gender: 164
# After appending - Cat IDs: 395, Predictions: 395, Actuals: 395, Gender: 395
# Final Test Results - Loss: 1.4332901239395142, Accuracy: 0.6320346593856812, Precision: 0.690163281561131, Recall: 0.5775638820485398, F1 Score: 0.5649103229002089
# Confusion Matrix:
#  [[113   6   4]
#  [ 10  20   1]
#  [ 63   1  13]]
# outer_fold 3
# Train Set Group Distribution:
# 000A    39
# 103A    33
# 047A    22
# 000B    19
# 057A    17
# 074A    16
# 029A    15
# 097A    15
# ...
# ['000A' '000B' '002B' '003A' '005A' '006A' '008A' '009A' '010A' '011A'
#  '012A' '014A' '014B' '015A' '016A' '018A' '019A' '019B' '020A' '021A'
#  '022A' '023A' '024A' '025A' '025B' '025C' '026B' '026C' '027A' '031A'
#  '032A' '033A' '034A' '035A' '036A' '037A' '038A' '040A' '041A' '042A'
#  '044A' '045A' '046A' '047A' '048A' '051A' '051B' '052A' '053A' '056A'
#  '057A' '058A' '060A' '062A' '063A' '066A' '068A' '069A' '070A' '071A'
#  '072A' '073A' '074A' '075A' '076A' '087A' '088A' '091A' '093A' '094A'
#  '095A' '096A' '097A' '097B' '099A' '100A' '101A' '102A' '103A' '106A'
#  '108A' '111A' '113A' '115A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['001A' '002A' '004A' '007A' '013B' '023B' '026A' '028A' '029A' '039A'
#  '043A' '049A' '050A' '054A' '055A' '059A' '061A' '064A' '065A' '067A'
#  '090A' '092A' '104A' '105A' '109A' '110A']
# Length of X_train_val:
# 647
# Length of y_train_val:
# 647
# Length of groups_train_val:
# 647
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     407
# kitten    122
# senior    118
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     102
# senior     31
# kitten     13
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     407
# kitten    122
# senior    118
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     102
# senior     31
# kitten     13
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 407, 1: 122, 2: 118})
# Epoch 1/1500
# 11/11 [==============================] - 1s 5ms/step - loss: 1.2769 - accuracy: 0.5920
# Epoch 2/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.5071 - accuracy: 0.8408
# Epoch 3/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.3481 - accuracy: 0.9150
# Epoch 4/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.2914 - accuracy: 0.9474
# Epoch 5/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.2637 - accuracy: 0.9598
# Epoch 6/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.2483 - accuracy: 0.9521
# Epoch 7/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.2401 - accuracy: 0.9614
# Epoch 8/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.2428 - accuracy: 0.9552
# Epoch 9/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.2241 - accuracy: 0.9691
# Epoch 10/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.2404 - accuracy: 0.9444
# Epoch 11/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.2547 - accuracy: 0.9382
# Epoch 12/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.2240 - accuracy: 0.9598
# Epoch 13/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.2219 - accuracy: 0.9583
# Epoch 14/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.2195 - accuracy: 0.9691
# Epoch 15/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.2056 - accuracy: 0.9536
# Epoch 16/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.2044 - accuracy: 0.9629
# Epoch 17/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.2238 - accuracy: 0.9505
# Epoch 18/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.2046 - accuracy: 0.9660
# Epoch 19/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.2177 - accuracy: 0.9521
# Epoch 20/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.2033 - accuracy: 0.9521
# Epoch 21/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.2079 - accuracy: 0.9583
# Epoch 22/1500
# 11/11 [==============================] - 0s 11ms/step - loss: 0.2165 - accuracy: 0.9521
# Epoch 23/1500
# 11/11 [==============================] - 0s 8ms/step - loss: 0.2072 - accuracy: 0.9614
# Epoch 24/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.2066 - accuracy: 0.9567
# Epoch 25/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1944 - accuracy: 0.9660
# Epoch 26/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1983 - accuracy: 0.9552
# Epoch 27/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1974 - accuracy: 0.9521
# Epoch 28/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1984 - accuracy: 0.9552
# Epoch 29/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.2029 - accuracy: 0.9645
# Epoch 30/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1928 - accuracy: 0.9675
# Epoch 31/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.2048 - accuracy: 0.9536
# Epoch 32/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1968 - accuracy: 0.9521
# Epoch 33/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1938 - accuracy: 0.9614
# Epoch 34/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1910 - accuracy: 0.9490
# Epoch 35/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1903 - accuracy: 0.9583
# Epoch 36/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1887 - accuracy: 0.9722
# Epoch 37/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1975 - accuracy: 0.9552
# Epoch 38/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1912 - accuracy: 0.9660
# Epoch 39/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1984 - accuracy: 0.9614
# Epoch 40/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1891 - accuracy: 0.9536
# Epoch 41/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1858 - accuracy: 0.9583
# Epoch 42/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1891 - accuracy: 0.9583
# Epoch 43/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1915 - accuracy: 0.9753
# Epoch 44/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1782 - accuracy: 0.9675
# Epoch 45/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1841 - accuracy: 0.9629
# Epoch 46/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1836 - accuracy: 0.9614
# Epoch 47/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1763 - accuracy: 0.9614
# Epoch 48/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1805 - accuracy: 0.9645
# Epoch 49/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1720 - accuracy: 0.9629
# Epoch 50/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1759 - accuracy: 0.9629
# Epoch 51/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1752 - accuracy: 0.9753
# Epoch 52/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1852 - accuracy: 0.9629
# Epoch 53/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1789 - accuracy: 0.9675
# Epoch 54/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1816 - accuracy: 0.9675
# Epoch 55/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1685 - accuracy: 0.9753
# Epoch 56/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1805 - accuracy: 0.9598
# Epoch 57/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1711 - accuracy: 0.9552
# Epoch 58/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1664 - accuracy: 0.9598
# Epoch 59/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1739 - accuracy: 0.9583
# Epoch 60/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1776 - accuracy: 0.9629
# Epoch 61/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1698 - accuracy: 0.9691
# Epoch 62/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1697 - accuracy: 0.9675
# Epoch 63/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1717 - accuracy: 0.9583
# Epoch 64/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1774 - accuracy: 0.9614
# Epoch 65/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1670 - accuracy: 0.9675
# Epoch 66/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1717 - accuracy: 0.9614
# Epoch 67/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1673 - accuracy: 0.9629
# Epoch 68/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1794 - accuracy: 0.9552
# Epoch 69/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1657 - accuracy: 0.9753
# Epoch 70/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1679 - accuracy: 0.9614
# Epoch 71/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1696 - accuracy: 0.9598
# Epoch 72/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1690 - accuracy: 0.9691
# Epoch 73/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1711 - accuracy: 0.9598
# Epoch 74/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1657 - accuracy: 0.9706
# Epoch 75/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1623 - accuracy: 0.9737
# Epoch 76/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1715 - accuracy: 0.9737
# Epoch 77/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1643 - accuracy: 0.9660
# Epoch 78/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.1651 - accuracy: 0.9675
# Epoch 79/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1717 - accuracy: 0.9675
# Epoch 80/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1684 - accuracy: 0.9691
# Epoch 81/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.1611 - accuracy: 0.9722
# Epoch 82/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.1710 - accuracy: 0.9660
# Epoch 83/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1614 - accuracy: 0.9675
# Epoch 84/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1607 - accuracy: 0.9660
# Epoch 85/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.1642 - accuracy: 0.9614
# Epoch 86/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1669 - accuracy: 0.9645
# Epoch 87/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1649 - accuracy: 0.9645
# Epoch 88/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1577 - accuracy: 0.9691
# Epoch 89/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1624 - accuracy: 0.9660
# Epoch 90/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1632 - accuracy: 0.9799
# Epoch 91/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1600 - accuracy: 0.9784
# Epoch 92/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1591 - accuracy: 0.9675
# Epoch 93/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1625 - accuracy: 0.9722
# Epoch 94/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1633 - accuracy: 0.9675
# Epoch 95/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1718 - accuracy: 0.9552
# Epoch 96/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1558 - accuracy: 0.9737
# Epoch 97/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1605 - accuracy: 0.9722
# Epoch 98/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1666 - accuracy: 0.9629
# Epoch 99/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1747 - accuracy: 0.9691
# Epoch 100/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1633 - accuracy: 0.9675
# Epoch 101/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1593 - accuracy: 0.9675
# Epoch 102/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1509 - accuracy: 0.9753
# Epoch 103/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1620 - accuracy: 0.9645
# Epoch 104/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1555 - accuracy: 0.9706
# Epoch 105/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1540 - accuracy: 0.9753
# Epoch 106/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1573 - accuracy: 0.9691
# Epoch 107/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1561 - accuracy: 0.9675
# Epoch 108/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1549 - accuracy: 0.9614
# Epoch 109/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1642 - accuracy: 0.9660
# Epoch 110/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1512 - accuracy: 0.9660
# Epoch 111/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1536 - accuracy: 0.9691
# Epoch 112/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1678 - accuracy: 0.9583
# Epoch 113/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1610 - accuracy: 0.9645
# Epoch 114/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1597 - accuracy: 0.9645
# Epoch 115/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1630 - accuracy: 0.9706
# Epoch 116/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1588 - accuracy: 0.9660
# Epoch 117/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1606 - accuracy: 0.9737
# Epoch 118/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1620 - accuracy: 0.9753
# Epoch 119/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1573 - accuracy: 0.9691
# Epoch 120/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1568 - accuracy: 0.9845
# Epoch 121/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1531 - accuracy: 0.9722
# Epoch 122/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1615 - accuracy: 0.9629
# Epoch 123/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1565 - accuracy: 0.9629
# Epoch 124/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1588 - accuracy: 0.9706
# Epoch 125/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1658 - accuracy: 0.9675
# Epoch 126/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1565 - accuracy: 0.9737
# Epoch 127/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1610 - accuracy: 0.9660
# Epoch 128/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1594 - accuracy: 0.9675
# Epoch 129/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1534 - accuracy: 0.9660
# Epoch 130/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1551 - accuracy: 0.9645
# Epoch 131/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1507 - accuracy: 0.9737
# Epoch 132/1500
# 10/11 [==========================>...] - ETA: 0s - loss: 0.1547 - accuracy: 0.9750Restoring model weights from the end of the best epoch: 102.
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1562 - accuracy: 0.9753
# Epoch 132: early stopping
# 5/5 [==============================] - 0s 2ms/step - loss: 0.7180 - accuracy: 0.7877
# 5/5 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.85 (22/26)
# Before appending - Cat IDs: 574, Predictions: 574, Actuals: 574, Gender: 574
# After appending - Cat IDs: 720, Predictions: 720, Actuals: 720, Gender: 720
# Final Test Results - Loss: 0.7179722785949707, Accuracy: 0.7876712083816528, Precision: 0.7707480207480207, Recall: 0.7043335117338912, F1 Score: 0.7322947787736519
# Confusion Matrix:
#  [[91  1 10]
#  [ 3 10  0]
#  [17  0 14]]
#
# Final Average F1-Score across all UNSEEN TEST sets: 0.5891677523274904
#
# Final Average Loss across all UNSEEN TEST sets: 1.1327301263809204
#
# Final Average Accuracy across all UNSEEN TEST sets: 0.70074163377285
#
# Final Average Precision across all UNSEEN TEST sets: 0.6694293931044446
#
# Final Average Recall across all UNSEEN TEST sets: 0.5892433978627489

# %%
seed_5_folds_values = (unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1)

# Plotting all fold metrics|
seed_5_folds_plot = plot_all_metrics(unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1, "Folds", "Fold Number")

# %% [markdown]
# ## Majority Voting on Total Entries per cat_id

# %%
# Debugging print statements
print(f'Checking - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
# Out:
# Checking - Cat IDs: 720, Predictions: 720, Actuals: 720, Gender: 720

# %%
# Create results df
full_results = pd.DataFrame({
    'cat_id': all_cat_ids,
    'predicted_age_group': all_predicted_age_groups,
    'actual_age_group': all_actual_age_groups,
    'all_gender': all_gender
})

# create a correct majority prediction column
full_results['correct'] = full_results['predicted_age_group'] == full_results['actual_age_group']

# %%
# Group by cat_id and aggregate predicted age groups
majority_votes = full_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first()

# Calculate the accuracy of majority voting
correct_predictions = (majority_votes == actual_groups).sum()
total_cats = len(actual_groups)
majority_vote_accuracy = correct_predictions / total_cats

logger(f"Overall Majority Vote Accuracy for cat_id: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

# store for final evaluation 
all_majority_vote_accuracies.append(majority_vote_accuracy)
# Out:
# Overall Majority Vote Accuracy for cat_id: 0.79 (87/110)

# %%
# Detailed df with predictions, actual labels, and comparison including majority vote
detailed_results = full_results.groupby('cat_id').apply(
    lambda x: pd.Series({
        'Predictions': list(x['predicted_age_group']),
        'Majority Vote': x['predicted_age_group'].mode()[0],
        'Actual Age Group': x['actual_age_group'].iloc[0],
        'Correct Majority Vote': x['predicted_age_group'].mode()[0] == x['actual_age_group'].iloc[0]
    })
).reset_index()

# Convert to DataFrame for better formatting and display
detailed_results = pd.DataFrame(detailed_results)

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 10)
pd.set_option('display.width', 1000)

sorted_detailed_results = detailed_results.sort_values(by='Correct Majority Vote', ascending=False)

# Display the sorted DataFrame
sorted_detailed_results
# Out:
#     cat_id                                        Predictions Majority Vote Actual Age Group  Correct Majority Vote
# 0     000B  [adult, senior, adult, adult, adult, adult, ad...         adult            adult                   True
# 70    064A                                            [adult]         adult            adult                   True
# 79    073A                                            [adult]         adult            adult                   True
# 78    072A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 77    071A  [adult, adult, adult, adult, adult, senior, ad...         adult            adult                   True
# 76    070A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 75    069A                                    [adult, senior]         adult            adult                   True
# 74    068A  [adult, adult, senior, adult, senior, adult, s...         adult            adult                   True
# 73    067A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 72    066A                                            [adult]         adult            adult                   True
# 71    065A  [senior, adult, adult, adult, kitten, senior, ...         adult            adult                   True
# 69    063A  [adult, adult, senior, senior, adult, senior, ...         adult            adult                   True
# 81    075A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 68    062A                              [adult, adult, adult]         adult            adult                   True
# 65    059A  [senior, adult, senior, senior, senior, adult,...        senior           senior                   True
# 64    058A                           [senior, senior, senior]        senior           senior                   True
# 58    052A                                    [adult, senior]         adult            adult                   True
# 1     001A  [adult, senior, adult, adult, adult, senior, a...         adult            adult                   True
# 54    049A                                           [kitten]        kitten           kitten                   True
# 53    048A                                           [kitten]        kitten           kitten                   True
# 51    045A                    [adult, kitten, kitten, kitten]        kitten           kitten                   True
# 50    044A           [kitten, kitten, kitten, kitten, kitten]        kitten           kitten                   True
# 80    074A  [adult, adult, kitten, adult, adult, adult, ad...         adult            adult                   True
# 82    076A                                            [adult]         adult            adult                   True
# 47    041A                                           [kitten]        kitten           kitten                   True
# 96    101A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 107   115A                                           [kitten]        kitten           kitten                   True
# 106   113A                            [adult, senior, senior]        senior           senior                   True
# 105   111A  [adult, adult, kitten, kitten, kitten, kitten,...        kitten           kitten                   True
# 104   110A                                           [kitten]        kitten           kitten                   True
# 103   109A             [kitten, adult, adult, kitten, kitten]        kitten           kitten                   True
# 102   108A           [senior, senior, senior, senior, senior]        senior           senior                   True
# 100   105A                              [adult, adult, adult]         adult            adult                   True
# 98    103A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 97    102A                                     [adult, adult]         adult            adult                   True
# 95    100A                                            [adult]         adult            adult                   True
# 83    087A                                     [adult, adult]         adult            adult                   True
# 94    099A        [adult, adult, adult, kitten, adult, adult]         adult            adult                   True
# 93    097B  [adult, adult, adult, adult, adult, adult, kit...         adult            adult                   True
# 91    096A                                     [adult, adult]         adult            adult                   True
# 90    095A  [senior, adult, senior, adult, adult, adult, a...         adult            adult                   True
# 89    094A           [senior, senior, senior, senior, senior]        senior           senior                   True
# 87    092A                                            [adult]         adult            adult                   True
# 86    091A                                            [adult]         adult            adult                   True
# 85    090A                                           [senior]        senior           senior                   True
# 84    088A                                            [adult]         adult            adult                   True
# 49    043A                                           [kitten]        kitten           kitten                   True
# 55    050A            [adult, kitten, kitten, kitten, kitten]        kitten           kitten                   True
# 26    023B                       [adult, adult, adult, adult]         adult            adult                   True
# 24    022A  [adult, adult, kitten, kitten, adult, adult, a...         adult            adult                   True
# 32    026B                                            [adult]         adult            adult                   True
# 31    026A                       [adult, adult, adult, adult]         adult            adult                   True
# 30    025C                      [adult, adult, senior, adult]         adult            adult                   True
# 29    025B                                    [adult, senior]         adult            adult                   True
# 28    025A  [adult, adult, adult, senior, adult, adult, ad...         adult            adult                   True
# 10    009A                      [adult, adult, senior, adult]         adult            adult                   True
# 46    040A  [kitten, kitten, kitten, kitten, kitten, kitte...        kitten           kitten                   True
# 25    023A         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 23    021A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 34    027A  [adult, adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 22    020A  [adult, senior, senior, adult, adult, adult, a...         adult            adult                   True
# 11    010A                              [adult, adult, adult]         adult            adult                   True
# 20    019A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 19    018A                                    [adult, senior]         adult            adult                   True
# 12    011A                                   [senior, senior]        senior           senior                   True
# 13    012A                              [adult, adult, adult]         adult            adult                   True
# 17    015A  [adult, adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 14    013B  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
#

# Total Gender Accuracy so far:
#  [  all_gender  count  correct  accuracy
# 0          F    196      135     68.88
# 1          M    286      202     70.63
# 2          X    232      138     59.48,   all_gender  count  correct  accuracy
# 0          F    192      126     65.62
# 1          M    289      206     71.28
# 2          X    241      156     64.73,   all_gender  count  correct  accuracy
# 0          F    192      130     67.71
# 1          M    291      229     78.69
# 2          X    243      156     64.20,   all_gender  count  correct  accuracy
# 0          F    192      136     70.83
# 1          M    293      214     73.04
# 2          X    236      154     65.25,   all_gender  count  correct  accuracy
# 0          F    192      137     71.35
# 1          M    286      223     77.97
# 2          X    242      139     57.44]

# %% [markdown]
# # --------------

# %% [markdown]
# # Total Final Results & Analysis

# %%
# Count unique cat_id per age group 
unique_cats_per_age_group = dataframe.groupby('age_group')['cat_id'].nunique()

# Display the counts
print("Unique cat_id counts in original dataframe:", unique_cats_per_age_group)
# Out:
# Unique cat_id counts in original dataframe: age_group
# adult     74
# kitten    16
# senior    22
# Name: cat_id, dtype: int64

# %% [markdown]
# ## Metrics

# %%
# Calculate overall metrics
overall_avg_loss = np.mean(all_losses)
overall_avg_acc = np.mean(all_accuracies)
overall_avg_precision = np.mean(all_precisions)
overall_avg_recall = np.mean(all_recalls)
overall_avg_f1 = np.mean(all_f1)

print("Overall Average Metrics:")
print("Loss:", overall_avg_loss)
print("Accuracy:", overall_avg_acc)
print("Precision:", overall_avg_precision)
print("Recall:", overall_avg_recall)
print("F1 Score:", overall_avg_f1)
# Out:
# Overall Average Metrics:
# Loss: 1.104818832874298
# Accuracy: 0.6897651046514511
# Precision: 0.6505342953140022
# Recall: 0.6130674077527563
# F1 Score: 0.5875608079756472

# %% [markdown]
# ## Majority Votes

# %%
# Average of majority vote accuracies
average_majority_vote_accuracy = np.mean(all_majority_vote_accuracies)
print("Average Majority Vote Accuracy:", average_majority_vote_accuracy)
# Out:
# Average Majority Vote Accuracy: 0.7618181818181818

# %%
# Concatenate all class stats DataFrames and calculate the mean of accuracies
total_majority_vote_details = pd.concat(all_majority_vote_details)
average_majority_vote_details = total_majority_vote_details.groupby('actual_age_group').agg({
    'total_count': 'sum', 
    'correct_count': 'sum' 
}).reset_index()
average_majority_vote_details['accuracy'] = (average_majority_vote_details['correct_count'] / average_majority_vote_details['total_count']) * 100

print("Average Class Statistics:")
print(average_majority_vote_details)
# Out:
# Average Class Statistics:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult          365            328  89.863014
# 1           kitten           75             56  74.666667
# 2           senior          110             35  31.818182

# %%
# Plot for Detailed Class Statistics for Majority Votes
styled_barplot(average_majority_vote_details, 'actual_age_group', 'accuracy', 
               'Accuracy of Majority Votes by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Detailed Class Statistics

# %%
# Concatenate all class stats DataFrames and calculate the mean of accuracies
total_class_stats = pd.concat(all_class_stats)
average_class_stats = total_class_stats.groupby('actual_age_group').agg({
    'total_count': 'sum',  
    'correct_count': 'sum' 
}).reset_index()
average_class_stats['accuracy'] = (average_class_stats['correct_count'] / average_class_stats['total_count']) * 100

print("Average Class Statistics:")
print(average_class_stats)
# Out:
# Average Class Statistics:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult         2370           2009  84.767932
# 1           kitten          488            261  53.483607
# 2           senior          745            211  28.322148

# %%
# Plot for Detailed Class Statistics (Overall)
styled_barplot(average_class_stats, 'actual_age_group', 'accuracy', 
               'Overall Accuracy by Age Group', 
               'Age Group', 'Accuracy (%)')

# %%
# Concatenate all gender stats DataFrames and calculate the mean of accuracies
total_gender_stats = pd.concat(all_gender_stats)
average_gender_stats = total_gender_stats.groupby('all_gender').agg({
    'count': 'sum',  
    'correct': 'sum'  
}).reset_index()
average_gender_stats['accuracy'] = (average_gender_stats['correct'] / average_gender_stats['count']) * 100

print("Average Gender Accuracy:")
print(average_gender_stats)
# Out:
# Average Gender Accuracy:
#   all_gender  count  correct   accuracy
# 0          F    964      664  68.879668
# 1          M   1445     1074  74.325260
# 2          X   1194      743  62.227806

# %%
# Plot for Accuracy by Gender
styled_barplot(total_gender_stats, 'all_gender', 'accuracy', 
               'Accuracy by Gender', 
               'Gender', 'Accuracy (%)')

# %% [markdown]
# # Visualisations

# %%
# Plotting all metrics
metrics_across_seeds = plot_all_metrics(all_losses, all_accuracies, all_precisions, all_recalls, all_f1, "Seeds", "Seed Number")

# %%
# Calculate the standard deviation for each metric
std_loss = np.std(all_losses)
std_accuracy = np.std(all_accuracies)
std_precision = np.std(all_precisions)
std_recall = np.std(all_recalls)
std_f1 = np.std(all_f1)

print("Standard Deviations:")
print(f"Loss: {std_loss}")
print(f"Accuracy: {std_accuracy}")
print(f"Precision: {std_precision}")
print(f"Recall: {std_recall}")
print(f"F1 Score: {std_f1}")
# Out:
# Standard Deviations:
# Loss: 0.05596601503069692
# Accuracy: 0.018206048828900784
# Precision: 0.03173018513414962
# Recall: 0.0314229026374805
# F1 Score: 0.01582684964058948

# %%
# Calculate the interquartile range for each metric
iqr_loss = np.percentile(all_losses, 75) - np.percentile(all_losses, 25)
iqr_accuracy = np.percentile(all_accuracies, 75) - np.percentile(all_accuracies, 25)
iqr_precision = np.percentile(all_precisions, 75) - np.percentile(all_precisions, 25)
iqr_recall = np.percentile(all_recalls, 75) - np.percentile(all_recalls, 25)
iqr_f1 = np.percentile(all_f1, 75) - np.percentile(all_f1, 25)

print("Interquartile Ranges:")
print(f"Loss: {iqr_loss}")
print(f"Accuracy: {iqr_accuracy}")
print(f"Precision: {iqr_precision}")
print(f"Recall: {iqr_recall}")
print(f"F1 Score: {iqr_f1}")
# Out:
# Interquartile Ranges:
# Loss: 0.04448053240776062
# Accuracy: 0.02205352485179901
# Precision: 0.05108467311360687
# Recall: 0.036040722139113024
# F1 Score: 0.032608005003310514

# %% [markdown]
# ## Display the seed folds results together

# %%
# Create a figure with subplots
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(18, 12))  

# Flatten the axes array for easier indexing
axes = axes.flatten()

def plot_metrics_on_axes(ax, losses, accuracies, precisions, recalls, f1, title):
    ax.plot(range(1, len(losses)+1), losses, marker='o', color='blue', label='Loss')
    ax.plot(range(1, len(accuracies)+1), accuracies, marker='o', color='green', label='Accuracy')
    ax.plot(range(1, len(precisions)+1), precisions, marker='o', color='red', label='Precision')
    ax.plot(range(1, len(recalls)+1), recalls, marker='o', color='purple', label='Recall')
    ax.plot(range(1, len(f1)+1), f1, marker='o', color='orange', label='F1 Score')
    ax.set_xticks([1, 2, 3, 4])  # Set x-axis ticks to full integers
    ax.set_title(title)
    ax.set_xlabel('Fold Number')
    ax.set_ylabel('Metric Value')
    ax.legend()
    ax.grid(True)

# Plot onto each axes object
plot_metrics_on_axes(axes[0], *seed_1_folds_values, "Seed 1 Metrics")
plot_metrics_on_axes(axes[1], *seed_2_folds_values, "Seed 2 Metrics")
plot_metrics_on_axes(axes[2], *seed_3_folds_values, "Seed 3 Metrics")
plot_metrics_on_axes(axes[3], *seed_4_folds_values, "Seed 4 Metrics")
plot_metrics_on_axes(axes[4], *seed_5_folds_values, "Seed 5 Metrics")

# Hide the unused subplot 
for ax in axes[5:]:
    ax.set_visible(False)

# Adjust layout
plt.tight_layout()
plt.show()
