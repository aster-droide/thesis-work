# %% [markdown]
# # VGGIsh Multi Seed Validation
# #### 5 Random (but reproducible) seeds are selected for 5 different runs of train/test
# #### Models have been optimised and verified on validation sets thoroughly, running a final train/test evaluation here
# #### The setup:
#
# - 4 fold StratifiedGroupKFold for stratification and ensuring each cat_id group only appears in one set at a time
# - Final scores averaged over the 4 folds
# - For each seed run we will explore the cat_id predictions through majority voting
# - For each run we will explore the potential impact of gender
# - Includes visualisations & analysis
#
# The dataset is highly unbalanced.

# %%
# Standard imports
import numpy as np
import pandas as pd
import random
from datetime import datetime
from collections import Counter

# Sklearn imports
from sklearn.model_selection import train_test_split, GroupShuffleSplit, GroupKFold, StratifiedGroupKFold
from sklearn.preprocessing import LabelEncoder, MinMaxScaler, RobustScaler, StandardScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report
from sklearn.utils.class_weight import compute_class_weight
from sklearn.inspection import permutation_importance

# Imbalanced-learn import
from imblearn.over_sampling import SMOTE

# TensorFlow and Keras imports
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Dropout, Input, BatchNormalization, concatenate
from tensorflow.keras.optimizers import Adam, RMSprop, SGD, Adamax, AdamW
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import to_categorical
from keras.regularizers import l1, l2, L1L2

# Optuna import
import optuna

# Visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns

from IPython.display import display

# %%
# Set an initial seed for reproducibility
np.random.seed(42)  

# Generate a list of 5 random seeds
random_seeds = np.random.randint(0, 10000, size=5)
print("Random Seeds:", random_seeds)
# Out:
# Random Seeds: [7270  860 5390 5191 5734]

# %% [markdown]
# #### TOTAL RESULTS ACROSS SEED INITIATION

# %%
# Lists to collect statistics across all CVs
all_losses, all_accuracies, all_precisions, all_recalls, all_f1 = [], [], [], [], []
all_majority_vote_accuracies, all_majority_vote_details, all_class_stats, all_gender_stats  = [], [], [], []

# %% [markdown]
# ## Define Functions

# %%
def check_initial_group_split(groups_train, groups_test):
    """
    Check if any group is present in both the train and test sets.

    Parameters:
    - groups_train: Array of group identifiers for the train set
    - groups_test: Array of group identifiers for the test set

    Returns:
    - Prints out any groups found in both sets and the count of such groups
    """
    train_groups = set(groups_train)
    test_groups = set(groups_test)
    common_groups = train_groups.intersection(test_groups)

    if common_groups:
        print(f"Warning: Found {len(common_groups)} common groups in both train/validation and test sets: {common_groups}")
    else:
        print("No common groups found between train and test sets.")

# %%
# Function to perform the swaps based on cat_id, ensuring swaps within the same age_group
def swap_cat_id_instances(dataframe, train_val_idx, test_idx, specific_cat_ids):
    for cat_id in specific_cat_ids:
        # Check if the specific cat_id is not in the training set
        if cat_id not in dataframe.iloc[train_val_idx]['cat_id'].values:
            # Get the age_group of this cat_id
            age_group = dataframe[dataframe['cat_id'] == cat_id]['age_group'].iloc[0]
                
            # Find a different cat_id within the same age_group in the train set that is not in the test set
            other_cat_ids_in_age_group = dataframe[(dataframe['age_group'] == age_group) & 
                                                   (dataframe['cat_id'] != cat_id) &
                                                   (~dataframe['cat_id'].isin(dataframe.iloc[test_idx]['cat_id']))]['cat_id'].unique()
            
            # Choose one other cat_id for swapping
            if len(other_cat_ids_in_age_group) > 0:
                other_cat_id = np.random.choice(other_cat_ids_in_age_group)

                # Find all instances of the other_cat_id in the train set
                other_cat_id_train_val_indices = train_val_idx[dataframe.iloc[train_val_idx]['cat_id'] == other_cat_id]
                
                # Find all instances of the specific cat_id in the test set
                cat_id_test_indices = test_idx[dataframe.iloc[test_idx]['cat_id'] == cat_id]
                
                # Swap the indices
                train_val_idx = np.setdiff1d(train_val_idx, other_cat_id_train_val_indices, assume_unique=True)
                test_idx = np.setdiff1d(test_idx, cat_id_test_indices, assume_unique=True)

                train_val_idx = np.concatenate((train_val_idx, cat_id_test_indices))
                test_idx = np.concatenate((test_idx, other_cat_id_train_val_indices))
            else:
                print(f"No alternative cat_id found in the same age_group as {cat_id} for swapping.")
                
    return train_val_idx, test_idx

# %%
# Function to identify differences in groups
def find_group_differences(original, new):
    # Convert numpy arrays to sets for easy difference computation
    original_set = set(original)
    new_set = set(new)
    # Find differences
    moved_to_new = new_set - original_set
    moved_to_original = original_set - new_set
    return moved_to_new, moved_to_original

# %%
# create custom logger function for local logs & stored in a .txt
def logger(message, file=None):
    print(message)
    if file is not None:
        with open(file, "a") as log_file:
            log_file.write(message + "\n")

log_file_path = "multi-seed-val-D13.txt"

# %%
# Set the aesthetic style of the plots
sns.set(style="whitegrid", palette="deep")

# Define a custom color palette
colors = ["#6aabd1", "#b6e2d3", "#dac292"] 
sns.set_palette(sns.color_palette(colors))

# Function to create bar plots with enhanced style
def styled_barplot(data, x, y, title, xlabel, ylabel):
    plt.figure(figsize=(8, 4))
    bar_plot = sns.barplot(x=x, y=y, data=data, errorbar=None, width=0.5)  
    plt.title(title, fontsize=16, fontweight='bold', color="#333333")
    plt.xlabel(xlabel, fontsize=14, fontweight='bold', color="#333333")
    plt.ylabel(ylabel, fontsize=14, fontweight='bold', color="#333333")
    plt.xticks(fontsize=12, color="#333333")
    plt.yticks(fontsize=12, color="#333333")
    plt.ylim(0, 100) 

    # Adding value labels on top of each bar
    for p in bar_plot.patches:
        height = p.get_height()
        # Annotate the height value on the bar
        bar_plot.annotate(f'{height:.1f}', 
                          (p.get_x() + p.get_width() / 2., height), 
                          ha='center', va='center', 
                          xytext=(0, 9), 
                          textcoords='offset points', fontsize=12, color="#333333")

    plt.show()

# %%
def plot_all_metrics(losses, accuracies, precisions, recalls, f1, metrics_across, x_axis_label):
    fig, ax = plt.subplots(figsize=(12, 8))
    seeds = range(1, len(losses) + 1)

    ax.plot(seeds, losses, marker='o', color='blue', label='Loss')
    ax.plot(seeds, accuracies, marker='o', color='green', label='Accuracy')
    ax.plot(seeds, precisions, marker='o', color='red', label='Precision')
    ax.plot(seeds, recalls, marker='o', color='purple', label='Recall')
    ax.plot(seeds, f1, marker='o', color='orange', label='F1 Score')

    ax.set_title(f'Metrics Across {metrics_across}')
    ax.set_xlabel(x_axis_label)
    ax.set_ylabel('Metric Value')
    ax.set_xticks(seeds)
    ax.legend()
    ax.grid(True)

    return fig

# %% [markdown]
# # RANDOM SEED 1

# %% [markdown]
# ## Prepare Data

# %%
# Set a fixed random seed for reproducibility
random.seed(int(random_seeds[0])) 
np.random.seed(int(random_seeds[0]))
tf.random.set_seed(int(random_seeds[0]))

# Load datasets
dataframe = pd.read_csv('/Users/astrid/PycharmProjects/audioset-thesis-work/audioset/vggish/embeddings/8april_looped_embeddings.csv')
augmented_df = pd.read_csv('/Users/astrid/PycharmProjects/audioset-thesis-work/audioset/vggish/embeddings/augmented_dataset_19.csv')

dataframe.drop('mean_freq', axis=1, inplace=True)

augmented_df.drop('gender', axis=1, inplace=True)

def assign_age_group(age, age_groups):
    for group_name, age_range in age_groups.items():
        if age_range[0] <= age < age_range[1]:
            return group_name
    return 'Unknown'  # For any age that doesn't fit the defined groups

# Define age groups
age_groups = {
    'kitten': (0, 0.5),
    'adult': (0.5, 12),
    'senior': (12, 20)
}

# Create a new column for the age group
dataframe['age_group'] = dataframe['target'].apply(assign_age_group, age_groups=age_groups)
augmented_df['age_group'] = augmented_df['target'].apply(assign_age_group, age_groups=age_groups)

print(dataframe['age_group'].value_counts())
print(augmented_df['age_group'].value_counts())
# Out:
# adult     588
# senior    178
# kitten    171
# Name: age_group, dtype: int64
# adult     588
# senior    534
# kitten    513
# Name: age_group, dtype: int64

# %%
# Separate features and labels
X = dataframe.iloc[:, :-4].values  # all columns except the last four

# Encode the 'age_group' column as integers using LabelEncoder
label_encoder = LabelEncoder()
encoded_y = label_encoder.fit_transform(dataframe['age_group'].values)

# Use the encoded labels for splitting and one-hot encoding
y = encoded_y  

# Convert 'cat_id' column to numpy array to be used as groups array for GroupKFold
groups = dataframe['cat_id'].values

# %%
tf.keras.backend.clear_session()

# %% [markdown]
# ## Run Setup

# %%
all_cat_ids = []
all_predicted_age_groups = []
all_actual_age_groups = []
all_gender = []

# Define the StratifiedGroupKFold splitter for 4 fold CV with random shuffling
outer_cv = StratifiedGroupKFold(n_splits=4, shuffle=True, random_state=int(random_seeds[0]))

# unseen test set metrics
unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1 = [], [], [], [], []

outer_fold = 0

# Use the splitter to generate indices for training and testing sets
# Note: GroupShuffleSplit.split returns indices, so we use it to index the arrays
for train_val_idx, test_idx in outer_cv.split(X, y, groups):
    outer_fold += 1
    logger(f"outer_fold {outer_fold}", file=log_file_path)

    # Convert indices back to DataFrame for easy manipulation
    df_train_val = dataframe.iloc[train_val_idx]
    df_test = dataframe.iloc[test_idx]

    ##############################
    # ASSESSING SPLITS BY CAT_ID #
    ##############################
    
    # Get the distribution of groups
    training_validation_group_distribution = df_train_val['cat_id'].value_counts()  
    testing_group_distribution = df_test['cat_id'].value_counts()  
    
    # Log or print the distribution
    logger(f"Train Set Group Distribution:\n{training_validation_group_distribution}", file=log_file_path)
    logger(f"Testing Set Group Distribution:\n{testing_group_distribution}", file=log_file_path)

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val['gender'].value_counts()
    testing_gender_distribution = df_test['gender'].value_counts()
    
    # Log the distribution
    logger(f"Training Set Gender Distribution BEFORE SWAP:\n{training_gender_distribution}", file=log_file_path)
    logger(f"Testing Set Gender Distribution BEFORE SWAP:\n{testing_gender_distribution}", file=log_file_path)

    # Group by 'age_group' and then list unique 'cat_id' within each age group
    unique_cat_ids_per_age_group_train_val = df_train_val.groupby('age_group')['cat_id'].unique()
    unique_cat_ids_per_age_group_test = df_test.groupby('age_group')['cat_id'].unique()
    
    # Log results
    logger(f"Unique Cat IDs per Age Group in Training/Validation Set:\n{unique_cat_ids_per_age_group_train_val}", file=log_file_path)
    logger(f"Unique Cat IDs per Age Group in Testing Set:\n{unique_cat_ids_per_age_group_test}", file=log_file_path)

    # Calculate the count of unique identifiers per age group for training and testing set
    counts_train_val = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_train_val.items()}
    counts_test = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_test.items()}

    # Log the counts of unique identifiers per age group
    logger(f"Count of Unique Cat IDs per Age Group in Training/Validation Set:\n{counts_train_val}", file=log_file_path)
    logger(f"Count of Unique Cat IDs per Age Group in Testing Set:\n{counts_test}", file=log_file_path)

    #######################################################
    # CONTINUE WITH ENSURING VALID AND APPROPRIATE SPLITS #
    #######################################################
    
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    groups_train_val, groups_test = groups[train_val_idx], groups[test_idx]

    # logging identifier splits 
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)

    # check group splits
    check_initial_group_split(groups_train_val, groups_test)

    # Specify the cat_ids that must be in the training/validation set
    specific_cat_ids = ['000A', '046A']
    
    # Perform the swapping operation
    train_val_idx, test_idx = swap_cat_id_instances(dataframe, train_val_idx, test_idx, specific_cat_ids)
    
    # Re-assign the sets based on the updated indices
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    new_groups_train_val, new_groups_test = groups[train_val_idx], groups[test_idx]

    # Find differences for training and test sets
    moved_to_train_val, removed_from_train_val = find_group_differences(groups_train_val, new_groups_train_val)
    moved_to_test, removed_from_test = find_group_differences(groups_test, new_groups_test)
    
    # Display the results
    logger(f"Moved to Training/Validation Set:\n{moved_to_train_val}", file=log_file_path)
    logger(f"Removed from Training/Validation Set:\n{removed_from_train_val}", file=log_file_path)
    logger(f"Moved to Test Set:\n{moved_to_test}", file=log_file_path)
    logger(f"Removed from Test Set\n{removed_from_test}", file=log_file_path)

    # Update X_train_val, X_test, y_train_val, y_test, groups_train_val, groups_test based on updated indices
    X_train_val = X[train_val_idx]
    y_train_val = y[train_val_idx]
    groups_train_val = groups[train_val_idx]
    
    X_test = X[test_idx]
    y_test = y[test_idx]
    groups_test = groups[test_idx]

    # logging identifier splits again after potential swaps
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"AFTER SWAP - Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"AFTER SWAP - Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)
    
    # Verify the lengths are consistent
    logger(f"Length of X_train_val:\n{len(X_train_val)}", file=log_file_path)
    logger(f"Length of y_train_val:\n{len(y_train_val)}", file=log_file_path)
    logger(f"Length of groups_train_val:\n{len(groups_train_val)}", file=log_file_path)

    # Check group splits once more
    check_initial_group_split(groups_train_val, groups_test)

    # Convert the modified indices back to a DataFrame representing the updated df_train_val
    df_train_val_updated = dataframe.iloc[train_val_idx].copy()
    df_test_updated = dataframe.iloc[test_idx].copy()

    ############################
    # LOGGING AGE GROUP SPLITS #
    ############################

    # Get the distribution of age groups of age groups before the update
    training_validation_age_group_distribution = df_train_val['age_group'].value_counts()
    testing_age_group_distribution = df_test['age_group'].value_counts()
    
    # Logthe distribution
    logger(f"Train Age Group Distribution BEFORE SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution BEFORE SWAP:\n{testing_age_group_distribution}", file=log_file_path)

    # Get the distribution of age groups after the update
    training_validation_age_group_distribution = df_train_val_updated['age_group'].value_counts()
    testing_age_group_distribution = df_test_updated['age_group'].value_counts()
    
    # Log the distribution
    logger(f"Train Age Group Distribution AFTER SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution AFTER SWAP:\n{testing_age_group_distribution}", file=log_file_path)
    
    ########################################################
    # TRACKING FINAL CAT_IDs & GENDER AFTER REDISTRIBUTION #
    ########################################################

    # Get the distribution of groups
    training_validation_group_distribution = df_train_val_updated['cat_id'].value_counts()  
    testing_group_distribution = df_test_updated['cat_id'].value_counts()  

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val_updated['gender'].value_counts()
    testing_gender_distribution = df_test_updated['gender'].value_counts()
    
    logger(f"\n Starting training on unseen test set\n", file=log_file_path)

    ######################
    # ADD AUGMENTED DATA #
    ######################

    # Filter out augmented data derived from groups in the training set
    augmented_df_filtered = augmented_df[augmented_df['cat_id'].isin(groups_train_val)]
    
    # Convert augmented_df_filtered to numpy array (excluding target and other columns)
    augmented_array = augmented_df_filtered.drop(columns=['target', 'cat_id', 'age_group']).values
    
    # Concatenate the filtered augmented data with X_train_val
    X_train_val = np.concatenate([X_train_val, augmented_array])

    # Extract target labels from the filtered augmented DataFrame
    y_augmented = augmented_df_filtered['age_group'].values
    
    # Encode the labels using the same LabelEncoder instance
    y_augmented_encoded = label_encoder.transform(y_augmented)
    
    # Concatenate the encoded augmented labels with y_train_val
    y_train_val = np.concatenate([y_train_val, y_augmented_encoded])

    # Calculate the distribution of age groups in y_train_val
    age_group_distribution = Counter(y_train_val)
    print("Age group distribution:", age_group_distribution)

    # EarlyStopping callback: monitor 'loss' instead of 'val_loss' for the test set
    early_stopping = EarlyStopping(
        monitor='loss',  
        min_delta=0.001, 
        patience=30,  
        verbose=1,  
        restore_best_weights=True  
    )

    # One final shuffle to ensure randomness
    outer_shuffle_idx = np.random.permutation(len(X_train_val))
    X_train_val = X_train_val[outer_shuffle_idx]
    y_train_val = y_train_val[outer_shuffle_idx]

    class_weights = compute_class_weight(
        class_weight='balanced',
        classes=np.unique(y_train_val),
        y=y_train_val
    )
    weight_dict = {i: class_weights[i] for i in range(len(class_weights))}
    
    # Scale the features
    scaler_full = StandardScaler().fit(X_train_val)
    X_train_full_scaled = scaler_full.transform(X_train_val)
    X_test_scaled = scaler_full.transform(X_test)
    
    # Encode the labels
    y_train_full_encoded = to_categorical(y_train_val)
    y_test_encoded = to_categorical(y_test)

    #######################
    # BUILD & TRAIN MODEL #
    #######################

    optimizers = {
        'Adamax': Adamax(learning_rate=0.00038188800331973483)
    }
    
    # Full model definition with dynamic number of layers
    model_full = Sequential()
    model_full.add(Dense(480, activation='relu', input_shape=(X_train_full_scaled.shape[1],)))  # units_l0 and activation from parameters
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.27188281261238406))  
    model_full.add(Dense(3, activation='softmax'))  
    
    optimizer = optimizers['Adamax']  # optimizer_key from parameters
    
    # Compile the model
    model_full.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    
    # Train the model on the full training set
    history_full = model_full.fit(X_train_full_scaled, y_train_full_encoded, epochs=1500, batch_size=64,
                                  verbose=1, callbacks=[early_stopping], class_weight=weight_dict)
    
    # Evaluate the model on the held-out test set
    test_loss, test_accuracy = model_full.evaluate(X_test_scaled, y_test_encoded)

    y_test_pred_prob = model_full.predict(X_test_scaled)
    y_test_pred = np.argmax(y_test_pred_prob, axis=1)  
    y_test_true = np.argmax(y_test_encoded, axis=1)    

    ################################
    # LOG MAJORITY VOTE PER CAT_ID #
    ################################

    # Convert numeric predictions back to age group labels
    predicted_age_groups = label_encoder.inverse_transform(y_test_pred)
    actual_labels = label_encoder.inverse_transform(y_test_true)
    
    # Map predictions and actual labels back to cat_ids
    test_results = pd.DataFrame({
        'cat_id': df_test_updated['cat_id'],
        'predicted_age_group': predicted_age_groups,
        'actual_age_group': actual_labels
    })
    
    # Group by cat_id and aggregate predicted age groups
    majority_votes = test_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
    actual_groups = test_results.groupby('cat_id')['actual_age_group'].first()
    
    # Calculate the accuracy of majority voting
    correct_predictions = (majority_votes == actual_groups).sum()
    total_cats = len(actual_groups)
    majority_vote_accuracy = correct_predictions / total_cats
    
    # Log the accuracy of the majority voting
    logger(f"Majority Vote Accuracy for cat_id for this fold: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

    ####################################################
    # COLLECT PREDICTIONS FOR GENDER & CAT_ID ANALYSIS #
    ####################################################

    # Debugging print statements
    print(f'Before appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Extend lists with current fold results
    all_cat_ids.extend(df_test_updated['cat_id'].tolist())
    all_predicted_age_groups.extend(predicted_age_groups)
    all_actual_age_groups.extend(actual_labels)
    all_gender.extend(df_test_updated['gender'].tolist())

    # Debugging print statements
    print(f'After appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Calculate additional metrics
    test_precision = precision_score(y_test_true, y_test_pred, average='macro')  # Use 'macro' for imbalanced datasets
    test_recall = recall_score(y_test_true, y_test_pred, average='macro')
    test_f1 = f1_score(y_test_true, y_test_pred, average='macro')

    # prepare averages of outer metrics
    unseen_f1.append(test_f1)
    unseen_losses.append(test_loss)
    unseen_accuracies.append(test_accuracy)
    unseen_precisions.append(test_precision)
    unseen_recalls.append(test_recall)

    # Print final test results
    logger(f"Final Test Results - Loss: {test_loss}, Accuracy: {test_accuracy}, Precision: {test_precision}, Recall: {test_recall}, F1 Score: {test_f1}", file=log_file_path)

    # Generate the confusion matrix
    cm = confusion_matrix(y_test, y_test_pred)
    logger(f"Confusion Matrix:\n {cm}", file=log_file_path)

# Calculate the overall average metrics
unseen_set_avg_f1 = np.mean(unseen_f1)
unseen_set_avg_loss = np.mean(unseen_losses)
unseen_set_avg_acc = np.mean(unseen_accuracies)
unseen_set_avg_precision = np.mean(unseen_precisions)
unseen_set_avg_recall = np.mean(unseen_recalls)

# Append averages to total lists
all_f1.append(unseen_set_avg_f1)
all_losses.append(unseen_set_avg_loss)
all_accuracies.append(unseen_set_avg_acc)
all_precisions.append(unseen_set_avg_precision)
all_recalls.append(unseen_set_avg_recall)

logger(f"\nFinal Average F1-Score across all UNSEEN TEST sets: {unseen_set_avg_f1}", file=log_file_path)
logger(f"\nFinal Average Loss across all UNSEEN TEST sets: {unseen_set_avg_loss}", file=log_file_path)
logger(f"\nFinal Average Accuracy across all UNSEEN TEST sets: {unseen_set_avg_acc}", file=log_file_path)
logger(f"\nFinal Average Precision across all UNSEEN TEST sets: {unseen_set_avg_precision}", file=log_file_path)
logger(f"\nFinal Average Recall across all UNSEEN TEST sets: {unseen_set_avg_recall}\n", file=log_file_path)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# outer_fold 1
# Train Set Group Distribution:
# 046A    63
# 000A    39
# 002B    32
# 047A    28
# 057A    27
#         ..
# 066A     1
# 096A     1
# 026C     1
# 041A     1
# 026B     1
# Name: cat_id, Length: 87, dtype: int64
# Testing Set Group Distribution:
# 103A    33
# 055A    20
# 001A    14
# 025A    11
# 016A    10
# 045A     9
# 015A     9
# 094A     8
# 117A     7
# 008A     6
# 053A     6
# 104A     4
# 009A     4
# 060A     3
# 056A     3
# 058A     3
# 093A     2
# 032A     2
# 069A     2
# 073A     1
# 076A     1
# 092A     1
# 091A     1
# 110A     1
# 024A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    325
# M    253
# F    197
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# M    84
# F    55
# X    23
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [006A, 000A, 033A, 071A, 097B, 028A, 019A, 074...
# kitten    [044A, 014B, 111A, 040A, 046A, 047A, 042A, 109...
# senior    [097A, 057A, 106A, 059A, 113A, 116A, 051B, 054...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [015A, 001A, 103A, 091A, 009A, 025A, 069A, 032...
# kitten                                         [045A, 110A]
# senior    [093A, 104A, 055A, 117A, 056A, 058A, 016A, 094...
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 60, 'kitten': 14, 'senior': 13}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 14, 'kitten': 2, 'senior': 9}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '002A' '002B' '003A' '004A' '005A' '006A' '007A' '010A'
#  '011A' '012A' '013B' '014A' '014B' '018A' '019A' '019B' '020A' '021A'
#  '022A' '023A' '023B' '025B' '025C' '026A' '026B' '026C' '027A' '028A'
#  '029A' '031A' '033A' '034A' '035A' '036A' '037A' '038A' '039A' '040A'
#  '041A' '042A' '043A' '044A' '046A' '047A' '048A' '049A' '050A' '051A'
#  '051B' '052A' '054A' '057A' '059A' '061A' '062A' '063A' '064A' '065A'
#  '066A' '067A' '068A' '070A' '071A' '072A' '074A' '075A' '087A' '088A'
#  '090A' '095A' '096A' '097A' '097B' '099A' '100A' '101A' '102A' '105A'
#  '106A' '108A' '109A' '111A' '113A' '115A' '116A']
# Unique Test Group IDs:
# ['001A' '008A' '009A' '015A' '016A' '024A' '025A' '032A' '045A' '053A'
#  '055A' '056A' '058A' '060A' '069A' '073A' '076A' '091A' '092A' '093A'
#  '094A' '103A' '104A' '110A' '117A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '002A' '002B' '003A' '004A' '005A' '006A' '007A' '010A'
#  '011A' '012A' '013B' '014A' '014B' '018A' '019A' '019B' '020A' '021A'
#  '022A' '023A' '023B' '025B' '025C' '026A' '026B' '026C' '027A' '028A'
#  '029A' '031A' '033A' '034A' '035A' '036A' '037A' '038A' '039A' '040A'
#  '041A' '042A' '043A' '044A' '046A' '047A' '048A' '049A' '050A' '051A'
#  '051B' '052A' '054A' '057A' '059A' '061A' '062A' '063A' '064A' '065A'
#  '066A' '067A' '068A' '070A' '071A' '072A' '074A' '075A' '087A' '088A'
#  '090A' '095A' '096A' '097A' '097B' '099A' '100A' '101A' '102A' '105A'
#  '106A' '108A' '109A' '111A' '113A' '115A' '116A']
# AFTER SWAP - Unique Test Group IDs:
# ['001A' '008A' '009A' '015A' '016A' '024A' '025A' '032A' '045A' '053A'
#  '055A' '056A' '058A' '060A' '069A' '073A' '076A' '091A' '092A' '093A'
#  '094A' '103A' '104A' '110A' '117A']
# Length of X_train_val:
# 775
# Length of y_train_val:
# 775
# Length of groups_train_val:
# 775
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     494
# kitten    161
# senior    120
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     94
# senior    58
# kitten    10
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     494
# kitten    161
# senior    120
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     94
# senior    58
# kitten    10
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 988, 1: 644, 2: 480})
# Epoch 1/1500
# 33/33 [==============================] - 0s 2ms/step - loss: 0.9628 - accuracy: 0.5578
# Epoch 2/1500
# 33/33 [==============================] - 0s 1ms/step - loss: 0.7310 - accuracy: 0.6581
# Epoch 3/1500
# 33/33 [==============================] - 0s 1ms/step - loss: 0.6438 - accuracy: 0.7003
# Epoch 4/1500
# 33/33 [==============================] - 0s 1ms/step - loss: 0.6310 - accuracy: 0.7259
# Epoch 5/1500
# 33/33 [==============================] - 0s 1ms/step - loss: 0.5688 - accuracy: 0.7405
# Epoch 6/1500
# 33/33 [==============================] - 0s 1ms/step - loss: 0.5619 - accuracy: 0.7453
# Epoch 7/1500
# 33/33 [==============================] - 0s 2ms/step - loss: 0.5346 - accuracy: 0.7599
# Epoch 8/1500
# 33/33 [==============================] - 0s 1ms/step - loss: 0.5333 - accuracy: 0.7538
# Epoch 9/1500
# 33/33 [==============================] - 0s 1ms/step - loss: 0.4976 - accuracy: 0.7732
# Epoch 10/1500
# 33/33 [==============================] - 0s 1ms/step - loss: 0
1500
# 33/33 [==============================] - 0s 1ms/step - loss: 0.0629 - accuracy: 0.9787
# Epoch 330/1500
# 33/33 [==============================] - 0s 1ms/step - loss: 0.0572 - accuracy: 0.9796
# Epoch 331/1500
# 33/33 [==============================] - 0s 1ms/step - loss: 0.0511 - accuracy: 0.9815
# Epoch 332/1500
# 33/33 [==============================] - 0s 1ms/step - loss: 0.0536 - accuracy: 0.9825
# Epoch 333/1500
# 33/33 [==============================] - 0s 1ms/step - loss: 0.0482 - accuracy: 0.9815
# Epoch 334/1500
# 33/33 [==============================] - 0s 1ms/step - loss: 0.0535 - accuracy: 0.9806
# Epoch 335/1500
# 33/33 [==============================] - 0s 1ms/step - loss: 0.0599 - accuracy: 0.9773
# Epoch 336/1500
# 33/33 [==============================] - 0s 1ms/step - loss: 0.0619 - accuracy: 0.9806
# Epoch 337/1500
# 33/33 [==============================] - 0s 1ms/step - loss: 0.0525 - accuracy: 0.9825
# Epoch 338/1500
# 33/33 [==============================] - 0s 1ms/step - loss: 0.0633 - accuracy: 0.9787
# Epoch 339/1500
# 33/33 [==============================] - 0s 1ms/step - loss: 0.0590 - accuracy: 0.9801
# Epoch 340/1500
# 33/33 [==============================] - 0s 1ms/step - loss: 0.0528 - accuracy: 0.9796
# Epoch 341/1500
# 33/33 [==============================] - 0s 1ms/step - loss: 0.0544 - accuracy: 0.9806
# Epoch 342/1500
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0650 - accuracy: 0.9796
# Epoch 343/1500
# 33/33 [==============================] - 0s 1ms/step - loss: 0.0558 - accuracy: 0.9825
# Epoch 344/1500
# 33/33 [==============================] - 0s 1ms/step - loss: 0.0534 - accuracy: 0.9782
# Epoch 345/1500
# 33/33 [==============================] - 0s 1ms/step - loss: 0.0704 - accuracy: 0.9763
# Epoch 346/1500
# 33/33 [==============================] - 0s 1ms/step - loss: 0.0485 - accuracy: 0.9844
# Epoch 347/1500
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0530 - accuracy: 0.9815
# Epoch 348/1500
# 33/33 [==============================] - 0s 1ms/step - loss: 0.0666 - accuracy: 0.9754
# Epoch 349/1500
# 33/33 [==============================] - 0s 1ms/step - loss: 0.0559 - accuracy: 0.9830
# Epoch 350/1500
# 33/33 [==============================] - 0s 1ms/step - loss: 0.0548 - accuracy: 0.9830
# Epoch 351/1500
# 33/33 [==============================] - 0s 1ms/step - loss: 0.0505 - accuracy: 0.9839
# Epoch 352/1500
# 33/33 [==============================] - 0s 1ms/step - loss: 0.0579 - accuracy: 0.9777
# Epoch 353/1500
# 33/33 [==============================] - 0s 1ms/step - loss: 0.0509 - accuracy: 0.9815
# Epoch 354/1500
# 33/33 [==============================] - 0s 1ms/step - loss: 0.0535 - accuracy: 0.9825
# Epoch 355/1500
# 33/33 [==============================] - 0s 1ms/step - loss: 0.0576 - accuracy: 0.9792
# Epoch 356/1500
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0589 - accuracy: 0.9792
# Epoch 357/1500
# 33/33 [==============================] - 0s 1ms/step - loss: 0.0562 - accuracy: 0.9777
# Epoch 358/1500
# 33/33 [==============================] - 0s 1ms/step - loss: 0.0790 - accuracy: 0.9716
# Epoch 359/1500
# 33/33 [==============================] - 0s 1ms/step - loss: 0.0515 - accuracy: 0.9834
# Epoch 360/1500
# 33/33 [==============================] - 0s 1ms/step - loss: 0.0593 - accuracy: 0.9773
# Epoch 361/1500
# 33/33 [==============================] - 0s 1ms/step - loss: 0.0573 - accuracy: 0.9815
# Epoch 362/1500
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0513 - accuracy: 0.9806
# Epoch 363/1500
# 33/33 [==============================] - ETA: 0s - loss: 0.0606 - accuracy: 0.9768Restoring model weights from the end of the best epoch: 333.
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0606 - accuracy: 0.9768
# Epoch 363: early stopping
# 6/6 [==============================] - 0s 1ms/step - loss: 1.2559 - accuracy: 0.6914
# 6/6 [==============================] - 0s 849us/step
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Majority Vote Accuracy for cat_id for this fold: 0.72 (18/25)
# Before appending - Cat IDs: 0, Predictions: 0, Actuals: 0, Gender: 0
# After appending - Cat IDs: 162, Predictions: 162, Actuals: 162, Gender: 162
# Final Test Results - Loss: 1.2559489011764526, Accuracy: 0.6913580298423767, Precision: 0.6818244049365331, Recall: 0.7422841770604061, F1 Score: 0.7074957145083371
# Confusion Matrix:
#  [[68  4 22]
#  [ 1  9  0]
#  [23  0 35]]
# outer_fold 2
# Train Set Group Distribution:
# 000A    39
# 103A    33
# 002B    32
# 047A    28
# 074A    25
#         ..
# 041A     1
# 092A     1
# 076A     1
# 043A     1
# 024A     1
# Name: cat_id, Length: 83, dtype: int64
# Testing Set Group Distribution:
# 046A    63
# 057A    27
# 000B    19
# 029A    17
# 106A    14
# 028A    13
# 039A    12
# 036A    11
# 068A    11
# 071A    10
# 005A    10
# 051B     9
# 022A     9
# 010A     8
# 013B     8
# 095A     8
# 037A     6
# 044A     5
# 070A     5
# 105A     4
# 014A     3
# 054A     2
# 025B     2
# 096A     1
# 049A     1
# 048A     1
# 088A     1
# 100A     1
# 026B     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    264
# X    198
# F    193
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    150
# M     73
# F     59
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [006A, 000A, 033A, 015A, 001A, 103A, 097B, 019...
# kitten    [014B, 111A, 040A, 047A, 042A, 109A, 050A, 043...
# senior    [093A, 097A, 104A, 055A, 059A, 113A, 116A, 117...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [071A, 028A, 022A, 029A, 095A, 005A, 039A, 013...
# kitten                             [044A, 046A, 049A, 048A]
# senior                             [057A, 106A, 051B, 054A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 53, 'kitten': 12, 'senior': 18}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 21, 'kitten': 4, 'senior': 4}
# Unique Training/Validation Group IDs:
# ['000A' '001A' '002A' '002B' '003A' '004A' '006A' '007A' '008A' '009A'
#  '011A' '012A' '014B' '015A' '016A' '018A' '019A' '019B' '020A' '021A'
#  '023A' '023B' '024A' '025A' '025C' '026A' '026C' '027A' '031A' '032A'
#  '033A' '034A' '035A' '038A' '040A' '041A' '042A' '043A' '045A' '047A'
#  '050A' '051A' '052A' '053A' '055A' '056A' '058A' '059A' '060A' '061A'
#  '062A' '063A' '064A' '065A' '066A' '067A' '069A' '072A' '073A' '074A'
#  '075A' '076A' '087A' '090A' '091A' '092A' '093A' '094A' '097A' '097B'
#  '099A' '101A' '102A' '103A' '104A' '108A' '109A' '110A' '111A' '113A'
#  '115A' '116A' '117A']
# Unique Test Group IDs:
# ['000B' '005A' '010A' '013B' '014A' '022A' '025B' '026B' '028A' '029A'
#  '036A' '037A' '039A' '044A' '046A' '048A' '049A' '051B' '054A' '057A'
#  '068A' '070A' '071A' '088A' '095A' '096A' '100A' '105A' '106A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'046A'}
# Removed from Training/Validation Set:
# {'115A'}
# Moved to Test Set:
# {'115A'}
# Removed from Test Set
# {'046A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '001A' '002A' '002B' '003A' '004A' '006A' '007A' '008A' '009A'
#  '011A' '012A' '014B' '015A' '016A' '018A' '019A' '019B' '020A' '021A'
#  '023A' '023B' '024A' '025A' '025C' '026A' '026C' '027A' '031A' '032A'
#  '033A' '034A' '035A' '038A' '040A' '041A' '042A' '043A' '045A' '046A'
#  '047A' '050A' '051A' '052A' '053A' '055A' '056A' '058A' '059A' '060A'
#  '061A' '062A' '063A' '064A' '065A' '066A' '067A' '069A' '072A' '073A'
#  '074A' '075A' '076A' '087A' '090A' '091A' '092A' '093A' '094A' '097A'
#  '097B' '099A' '101A' '102A' '103A' '104A' '108A' '109A' '110A' '111A'
#  '113A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['000B' '005A' '010A' '013B' '014A' '022A' '025B' '026B' '028A' '029A'
#  '036A' '037A' '039A' '044A' '048A' '049A' '051B' '054A' '057A' '068A'
#  '070A' '071A' '088A' '095A' '096A' '100A' '105A' '106A' '115A']
# Length of X_train_val:
# 717
# Length of y_train_val:
# 717
# Length of groups_train_val:
# 717
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     428
# senior    126
# kitten    101
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     160
# kitten     70
# senior     52
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     428
# kitten    163
# senior    126
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     160
# senior     52
# kitten      8
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 856, 1: 652, 2: 504})
# Epoch 1/1500
# 32/32 [==============================] - 0s 2ms/step - loss: 1.0038 - accuracy: 0.5577
# Epoch 2/1500
# 32/32 [==============================] - 0s 1ms/step - loss: 0.7148 - accuracy: 0.6859
# Epoch 3/1500
# 32/32 [==============================] - 0s 2ms/step - loss: 0.6485 - accuracy: 0.7286
# Epoch 4/1500
# 32/32 [==============================] - 0s 2ms/step - loss: 0.5771 - accuracy: 0.7475
# Epoch 5/1500
# 32/32 [==============================] - 0s 2ms/step - loss: 0.5430 - accuracy: 0.7714
# Epoch 6/1500
# 32/32 [==============================] - 0s 2ms/step - loss: 0.5391 - accuracy: 0.7684
# Epoch 7/1500
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4987 - accuracy: 0.7848
# Epoch 8/1500
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4988 - accuracy: 0.7883
# Epoch 9/1500
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4800 - accuracy: 0.7873
# Epoch 10/1500
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4658 - accuracy: 0.8007
# Epoch 11/1500
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4274 - accuracy: 0.8231
# Epoch 12/1500
# 32/32 [==============================] - 0s 2ms/step - loss: 0.4301 - accuracy: 0.8186
# Epoch 13/1500
# 32/32 [==============================] - 0s 2ms/step - loss: 0.4299 - accuracy: 0.8176
# Epoch 14/1500
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3880 - accuracy: 0.8429
# Epoch 15/1500
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3948 - accuracy: 0.8390
# Epoch 16/1500
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3861 - accuracy: 0.8320
# Epoch 17/1500
# ...
# Epoch 138/1500
# 33/33 [==============================] - 0s 2ms/step - loss: 0.1336 - accuracy: 0.9441
# Epoch 139/1500
# 33/33 [==============================] - 0s 1ms/step - loss: 0.
1500
# 33/33 [==============================] - 0s 1ms/step - loss: 0.0879 - accuracy: 0.9665
# Epoch 268/1500
# 33/33 [==============================] - 0s 1ms/step - loss: 0.0898 - accuracy: 0.9632
# Epoch 269/1500
# 33/33 [==============================] - 0s 1ms/step - loss: 0.0826 - accuracy: 0.9699
# Epoch 270/1500
# 33/33 [==============================] - 0s 1ms/step - loss: 0.0770 - accuracy: 0.9685
# Epoch 271/1500
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0836 - accuracy: 0.9656
# Epoch 272/1500
# 33/33 [==============================] - 0s 1ms/step - loss: 0.0878 - accuracy: 0.9613
# Epoch 273/1500
# 33/33 [==============================] - 0s 1ms/step - loss: 0.0707 - accuracy: 0.9728
# Epoch 274/1500
# 33/33 [==============================] - 0s 1ms/step - loss: 0.0804 - accuracy: 0.9661
# Epoch 275/1500
# 33/33 [==============================] - 0s 1ms/step - loss: 0.0779 - accuracy: 0.9713
# Epoch 276/1500
# 33/33 [==============================] - 0s 1ms/step - loss: 0.0784 - accuracy: 0.9680
# Epoch 277/1500
# 33/33 [==============================] - 0s 1ms/step - loss: 0.0861 - accuracy: 0.9637
# Epoch 278/1500
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0781 - accuracy: 0.9670
# Epoch 279/1500
# 33/33 [==============================] - 0s 1ms/step - loss: 0.0777 - accuracy: 0.9680
# Epoch 280/1500
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0742 - accuracy: 0.9704
# Epoch 281/1500
# 33/33 [==============================] - 0s 8ms/step - loss: 0.0913 - accuracy: 0.9632
# Epoch 282/1500
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0711 - accuracy: 0.9747
# Epoch 283/1500
# 16/33 [=============>................] - ETA: 0s - loss: 0.0645 - accuracy: 0.9717Restoring model weights from the end of the best epoch: 253.
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0700 - accuracy: 0.9728
# Epoch 283: early stopping
# 6/6 [==============================] - 0s 1ms/step - loss: 0.5480 - accuracy: 0.7965
# 6/6 [==============================] - 0s 844us/step
# Majority Vote Accuracy for cat_id for this fold: 0.82 (23/28)
# Before appending - Cat IDs: 687, Predictions: 687, Actuals: 687, Gender: 687
# After appending - Cat IDs: 859, Predictions: 859, Actuals: 859, Gender: 859
# Final Test Results - Loss: 0.5480179190635681, Accuracy: 0.7965116500854492, Precision: 0.6868814580349302, Recall: 0.7303613053613054, F1 Score: 0.6987470057121797
# Confusion Matrix:
#  [[83  6 15]
#  [ 8 47  0]
#  [ 6  0  7]]
#
# Final Average F1-Score across all UNSEEN TEST sets: 0.713608165608122
#
# Final Average Loss across all UNSEEN TEST sets: 0.9484249800443649
#
# Final Average Accuracy across all UNSEEN TEST sets: 0.7396462559700012
#
# Final Average Precision across all UNSEEN TEST sets: 0.6954440892633272
#
# Final Average Recall across all UNSEEN TEST sets: 0.7448405455322664

# %%
seed_1_folds_values = (unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1)

# Plotting all fold metrics
seed_1_folds_plot = plot_all_metrics(unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1, "Folds", "Fold Number")

# %% [markdown]
# ## Majority Voting on Total Entries per cat_id

# %%
# Debugging print statements
print(f'Checking - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
# Out:
# Checking - Cat IDs: 859, Predictions: 859, Actuals: 859, Gender: 859

# %%
# Create results df
full_results = pd.DataFrame({
    'cat_id': all_cat_ids,
    'predicted_age_group': all_predicted_age_groups,
    'actual_age_group': all_actual_age_groups,
    'all_gender': all_gender
})

# create a correct majority prediction column
full_results['correct'] = full_results['predicted_age_group'] == full_results['actual_age_group']

# %%
# Group by cat_id and aggregate predicted age groups
majority_votes = full_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first()

# Calculate the accuracy of majority voting
correct_predictions = (majority_votes == actual_groups).sum()
total_cats = len(actual_groups)
majority_vote_accuracy = correct_predictions / total_cats

logger(f"Overall Majority Vote Accuracy for cat_id: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

# store for final evaluation 
all_majority_vote_accuracies.append(majority_vote_accuracy)
# Out:
# Overall Majority Vote Accuracy for cat_id: 0.74 (81/110)

# %%
# Detailed df with predictions, actual labels, and comparison including majority vote
detailed_results = full_results.groupby('cat_id').apply(
    lambda x: pd.Series({
        'Predictions': list(x['predicted_age_group']),
        'Majority Vote': x['predicted_age_group'].mode()[0],
        'Actual Age Group': x['actual_age_group'].iloc[0],
        'Correct Majority Vote': x['predicted_age_group'].mode()[0] == x['actual_age_group'].iloc[0]
    })
).reset_index()

# Convert to DataFrame for better formatting and display
detailed_results = pd.DataFrame(detailed_results)

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 10)
pd.set_option('display.width', 1000)

sorted_detailed_results = detailed_results.sort_values(by='Correct Majority Vote', ascending=False)

# Display the sorted DataFrame
sorted_detailed_results
# Out:
#     cat_id                                        Predictions Majority Vote Actual Age Group  Correct Majority Vote
# 0     000B  [adult, adult, kitten, senior, adult, adult, a...         adult            adult                   True
# 49    043A                                           [kitten]        kitten           kitten                   True
# 78    072A  [adult, adult, adult, senior, adult, adult, ad...         adult            adult                   True
# 77    071A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 76    070A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 75    069A                                     [adult, adult]         adult            adult                   True
# 73    067A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 72    066A                                            [adult]         adult            adult                   True
# 71    065A  [senior, adult, adult, adult, adult, senior, k...         adult            adult                   True
# 70    064A                              [adult, adult, adult]         adult            adult                   True
# 68    062A                       [adult, adult, adult, adult]         adult            adult                   True
# 65    059A  [adult, adult, senior, senior, senior, senior,...        senior           senior                   True
# 64    058A                            [senior, senior, adult]        senior           senior                   True
# 63    057A  [adult, adult, adult, senior, senior, senior, ...        senior           senior                   True
# 62    056A                           [senior, senior, senior]        senior           senior                   True
# 61    055A  [senior, senior, senior, senior, senior, senio...        senior           senior                   True
# 59    053A       [adult, adult, adult, senior, kitten, adult]         adult            adult                   True
# 58    052A                      [adult, adult, senior, adult]         adult            adult                   True
# 57    051B  [senior, senior, adult, adult, senior, senior,...        senior           senior                   True
# 1     001A  [adult, adult, senior, adult, adult, adult, ad...         adult            adult                   True
# 54    049A                                           [kitten]        kitten           kitten                   True
# 52    047A  [kitten, kitten, kitten, kitten, kitten, kitte...        kitten           kitten                   True
# 51    045A  [kitten, kitten, kitten, kitten, kitten, kitte...        kitten           kitten                   True
# 79    073A                                            [adult]         adult            adult                   True
# 80    074A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 81    075A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 96    101A  [adult, adult, senior, adult, adult, adult, ad...         adult            adult                   True
# 108   116A  [senior, senior, senior, senior, adult, senior...        senior           senior                   True
# 107   115A                                   [kitten, kitten]        kitten           kitten                   True
# 106   113A                           [senior, senior, senior]        senior           senior                   True
# 105   111A  [kitten, kitten, kitten, kitten, kitten, kitte...        kitten           kitten                   True
# 102   108A     [senior, adult, adult, senior, senior, senior]        senior           senior                   True
# 100   105A                      [adult, adult, adult, senior]         adult            adult                   True
# 99    104A                   [senior, senior, senior, senior]        senior           senior                   True
# 98    103A  [adult, adult, adult, adult, senior, senior, a...         adult            adult                   True
# 97    102A                                     [adult, adult]         adult            adult                   True
# 95    100A                                            [adult]         adult            adult                   True
# 82    076A                                            [adult]         adult            adult                   True
# 94    099A  [adult, adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 93    097B  [adult, adult, adult, senior, adult, adult, ad...         adult            adult                   True
# 92    097A  [adult, senior, senior, adult, senior, senior,...        senior           senior                   True
# 91    096A                                            [adult]         adult            adult                   True
# 87    092A                                            [adult]         adult            adult                   True
# 86    091A                                            [adult]         adult            adult                   True
# 85    090A                                           [senior]        senior           senior                   True
# 84    088A                                            [adult]         adult            adult                   True
# 83    087A                                     [adult, adult]         adult            adult                   True
# 50    044A           [kitten, kitten, kitten, kitten, kitten]        kitten           kitten                   True
# 55    050A  [kitten, adult, kitten, kitten, kitten, kitten...        kitten           kitten                   True
# 48    042A  [adult, kitten, kitten, kitten, kitten, kitten...        kitten           kitten                   True
# 15    014A                              [adult, adult, adult]         adult            adult                   True
# 26    023B                [adult, adult, adult, adult, adult]         adult            adult                   True
# 47    041A                                           [kitten]        kitten           kitten                   True
# 24    022A  [adult, kitten, adult, adult, adult, adult, ad...         adult            adult                   True
# 23    021A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 22    020A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 20    019A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 17    015A  [adult, senior, adult, adult, senior, adult, a...         adult            adult                   True
# 16    014B  [kitten, kitten, kitten, adult, kitten, kitten...        kitten           kitten                   True
# 14    013B  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 31    026A                       [adult, adult, adult, adult]         adult            adult                   True
# 11    010A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 10    009A                       [adult, adult, adult, adult]         adult            adult                   True
# 9     008A         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 8     007A       [adult, senior, adult, adult, senior, adult]         adult            adult                   True
# 5     004A                                            [adult]         adult            adult                   True
# 4     003A                      [adult, adult, adult, senior]         adult            adult                   True
# 3     002B  [adult, adult, adult, senior, adult, senior, s...         adult            adult                   True
# 2     002A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 28    025A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 25    023A        [adult, kitten, adult, adult, adult, adult]         adult            adult                   True
# 36    029A  [adult, adult, adult, adult, adult, adult, sen...         adult            adult                   True
# 37    031A  [adult, adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 46    040A  [kitten, kitten, kitten, kitten, kitten, kitte...        kitten           kitten                   True
# 45    039A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 39    033A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 41    035A                      [senior, adult, adult, adult]         adult            adult                   True
# 38    032A                                    [kitten, adult]         adult            adult                   True
# 35    028A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 40    034A              [adult, senior, adult, senior, adult]         adult            adult                   True
# 43    037A        [adult, senior, adult, adult, adult, adult]         adult            adult                   True
# 12    011A                                     [adult, adult]         adult           senior                  False
# 42    036A  [senior, senior, senior, senior, adult, senior...        senior            adult                  False
# 56    051A  [adult, adult, adult, adult, senior, senior, a...         adult           senior                  False
# 32    026B                                           [senior]        senior            adult                  False
# 7     006A                            [senior, senior, adult]        senior            adult                  False
# 101   106A  [adult, senior, senior, senior, adult, adult, ...         adult           senior                  False
# 6     005A  [senior, senior, senior, senior, senior, senio...        senior            adult                  False
# 103   109A       [adult, adult, kitten, kitten, adult, adult]         adult           kitten                  False
# 104   110A                                            [adult]         adult           kitten                  False
# 44    038A                                   [kitten, kitten]        kitten            adult                  False
# 53    048A                                            [adult]         adult           kitten                  False
# 13    012A                            [senior, adult, senior]        senior            adult                  False
# 90    095A  [senior, adult, senior, senior, senior, senior...        senior            adult                  False
# 60    054A                                     [adult, adult]         adult           senior                  False
# 33    026C                                           [kitten]        kitten            adult                  False
# 89    094A  [senior, senior, adult, adult, adult, senior, ...         adult           senior                  False
# 88    093A                                     [adult, adult]         adult           senior                  False
# 18    016A  [adult, adult, adult, adult, adult, adult, adu...         adult           senior                  False
# 19    018A                                   [senior, senior]        senior            adult                  False
# 21    019B                                           [senior]        senior            adult                  False
# 66    060A                            [adult, kitten, kitten]        kitten            adult                  False
# 67    061A                                     [adult, adult]         adult           senior                  False
# 34    027A  [adult, senior, senior, senior, senior, adult,...        senior            adult                  False
# 27    024A                                            [adult]         adult           senior                  False
# 69    063A  [adult, senior, senior, kitten, senior, senior...        senior            adult                  False
# 29    025B                                   [senior, senior]        senior            adult                  False
# 74    068A  [adult, adult, senior, senior, senior, adult, ...        senior            adult                  False
# 30    025C            [senior, senior, senior, senior, adult]        senior            adult                  False
# 109   117A  [senior, senior, senior, adult, adult, adult, ...         adult           senior                  False

# %%
# Create df for majority votes
majority_df = majority_votes.reset_index()
majority_df.columns = ['cat_id', 'Majority_Vote']

# Get actual groups for each cat_id
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first().reset_index()

# Merge majority votes with actual groups
majority_with_actual = pd.merge(majority_df, actual_groups, on='cat_id')

# Add a column to check if the majority vote was correct
majority_with_actual['Majority_Correct'] = majority_with_actual['Majority_Vote'] == majority_with_actual['actual_age_group']

# Count correct majority votes per class
correct_majority_votes_per_class = majority_with_actual.groupby('actual_age_group')['Majority_Correct'].sum()

print("Correct Majority Votes per Class:")
print(correct_majority_votes_per_class)
# Out:
# Correct Majority Votes per Class:
# actual_age_group
# adult     57
# kitten    12
# senior    12
# Name: Majority_Correct, dtype: int64

# %%
# Calculate the total count and the number of correct predictions for each class
class_stats = majority_with_actual.groupby('actual_age_group').agg(
    total_count=('Majority_Correct', 'size'),  # Total number of cases per class
    correct_count=('Majority_Correct', 'sum')  # Sum of correct predictions per class
).reset_index()

# Calculate accuracy for each class
class_stats['accuracy'] = class_stats['correct_count'] / class_stats['total_count'] * 100

# store for final evaluation 
all_majority_vote_details.append(class_stats)

# Log detailed stats
print("Detailed Class Statistics for Majority Votes:")
print(class_stats)
# Out:
# Detailed Class Statistics for Majority Votes:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult           73             57  78.082192
# 1           kitten           15             12  80.000000
# 2           senior           22             12  54.545455

# %%
# Plot for Detailed Class Statistics for Majority Votes
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Accuracy of Majority Votes by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Detailed Class Statistics

# %%
# Calculate the total count and the number of correct predictions for each class
class_stats = full_results.groupby('actual_age_group').agg(
    total_count=('correct', 'size'),
    correct_count=('correct', 'sum')
).reset_index()

# Calculate accuracy for each class
class_stats['accuracy'] = class_stats['correct_count'] / class_stats['total_count'] * 100

# store for final evaluation 
all_class_stats.append(class_stats)

# Log the detailed stats
print("Detailed Class Statistics:")
print(class_stats)
# Out:
# Detailed Class Statistics:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult          572            437  76.398601
# 1           kitten          109             96  88.073394
# 2           senior          178            107  60.112360

# %%
# Plot for Detailed Class Statistics (Overall)
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Overall Accuracy by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Gender Exploration

# %%
# Group by gender and calculate the total count, correct predictions, and accuracy
gender_stats = full_results.groupby('all_gender').agg(
    count=('cat_id', 'size'),  # Total number of cases per gender
    correct=('correct', 'sum')  # Sum of correct predictions per gender
).reset_index()

# Calculate accuracy for each gender
gender_stats['accuracy'] = (gender_stats['correct'] / gender_stats['count'] * 100).round(2)

# Display the DataFrame
print("Accuracy by Gender:")
print(gender_stats)

# store for final evaluation 
all_gender_stats.append(gender_stats)
# Out:
# Accuracy by Gender:
#   all_gender  count  correct  accuracy
# 0          F    213      174     81.69
# 1          M    360      250     69.44
# 2          X    286      216     75.52

# %%
# Plot for Accuracy by Gender
styled_barplot(gender_stats, 'all_gender', 'accuracy', 
               'Accuracy by Gender', 
               'Gender', 'Accuracy (%)')

# %% [markdown]
# ### Log current total CV Stats

# %%
print("Total Majority Vote Accuracy so far:", all_majority_vote_accuracies)
print("Total Class Statistics so far:\n", all_class_stats)
print("Total Gender Accuracy so far:\n", all_gender_stats)
# Out:
# Total Majority Vote Accuracy so far: [0.7363636363636363]
# Total Class Statistics so far:
#  [  actual_age_group  total_count  correct_count   accuracy
# 0            adult          572            437  76.398601
# 1           kitten          109             96  88.073394
# 2           senior          178            107  60.112360]
# Total Gender Accuracy so far:
#  [  all_gender  count  correct  accuracy
# 0          F    213      174     81.69
# 1          M    360      250     69.44
# 2          X    286      216     75.52]

# %% [markdown]
# # RANDOM SEED 2

# %%
# Set a fixed random seed for reproducibility
random.seed(int(random_seeds[1]))
np.random.seed(int(random_seeds[1]))
tf.random.set_seed(int(random_seeds[1]))

# Load datasets
dataframe = pd.read_csv('/Users/astrid/PycharmProjects/audioset-thesis-work/audioset/vggish/embeddings/8april_looped_embeddings.csv')
augmented_df = pd.read_csv('/Users/astrid/PycharmProjects/audioset-thesis-work/audioset/vggish/embeddings/augmented_dataset_19.csv')

dataframe.drop('mean_freq', axis=1, inplace=True)

augmented_df.drop('gender', axis=1, inplace=True)

def assign_age_group(age, age_groups):
    for group_name, age_range in age_groups.items():
        if age_range[0] <= age < age_range[1]:
            return group_name
    return 'Unknown'  # For any age that doesn't fit the defined groups

# Define age groups
age_groups = {
    'kitten': (0, 0.5),
    'adult': (0.5, 12),
    'senior': (12, 20)
}

# Create a new column for the age group
dataframe['age_group'] = dataframe['target'].apply(assign_age_group, age_groups=age_groups)
augmented_df['age_group'] = augmented_df['target'].apply(assign_age_group, age_groups=age_groups)

print(dataframe['age_group'].value_counts())
print(augmented_df['age_group'].value_counts())
# Out:
# adult     588
# senior    178
# kitten    171
# Name: age_group, dtype: int64
# adult     588
# senior    534
# kitten    513
# Name: age_group, dtype: int64

# %%
# Separate features and labels
X = dataframe.iloc[:, :-4].values  # all columns except the last four

# Encode the 'age_group' column as integers using LabelEncoder
label_encoder = LabelEncoder()
encoded_y = label_encoder.fit_transform(dataframe['age_group'].values)

# Use the encoded labels for splitting and one-hot encoding
y = encoded_y  

# Convert 'cat_id' column to numpy array to be used as groups array for GroupKFold
groups = dataframe['cat_id'].values

# %%
tf.keras.backend.clear_session()

# %% [markdown]
# ## Run Setup

# %%
all_cat_ids = []
all_predicted_age_groups = []
all_actual_age_groups = []
all_gender = []

# Define the StratifiedGroupKFold splitter for 4 fold CV with random shuffling
outer_cv = StratifiedGroupKFold(n_splits=4, shuffle=True, random_state=int(random_seeds[1]))

# unseen test set metrics
unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1 = [], [], [], [], []

outer_fold = 0

# Use the splitter to generate indices for training and testing sets
# Note: GroupShuffleSplit.split returns indices, so we use it to index the arrays
for train_val_idx, test_idx in outer_cv.split(X, y, groups):
    outer_fold += 1
    logger(f"outer_fold {outer_fold}", file=log_file_path)

    # Convert indices back to DataFrame for easy manipulation
    df_train_val = dataframe.iloc[train_val_idx]
    df_test = dataframe.iloc[test_idx]

    ##############################
    # ASSESSING SPLITS BY CAT_ID #
    ##############################
    
    # Get the distribution of groups
    training_validation_group_distribution = df_train_val['cat_id'].value_counts()  
    testing_group_distribution = df_test['cat_id'].value_counts()  
    
    # Log or print the distribution
    logger(f"Train Set Group Distribution:\n{training_validation_group_distribution}", file=log_file_path)
    logger(f"Testing Set Group Distribution:\n{testing_group_distribution}", file=log_file_path)

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val['gender'].value_counts()
    testing_gender_distribution = df_test['gender'].value_counts()
    
    # Log the distribution
    logger(f"Training Set Gender Distribution BEFORE SWAP:\n{training_gender_distribution}", file=log_file_path)
    logger(f"Testing Set Gender Distribution BEFORE SWAP:\n{testing_gender_distribution}", file=log_file_path)

    # Group by 'age_group' and then list unique 'cat_id' within each age group
    unique_cat_ids_per_age_group_train_val = df_train_val.groupby('age_group')['cat_id'].unique()
    unique_cat_ids_per_age_group_test = df_test.groupby('age_group')['cat_id'].unique()
    
    # Log results
    logger(f"Unique Cat IDs per Age Group in Training/Validation Set:\n{unique_cat_ids_per_age_group_train_val}", file=log_file_path)
    logger(f"Unique Cat IDs per Age Group in Testing Set:\n{unique_cat_ids_per_age_group_test}", file=log_file_path)

    # Calculate the count of unique identifiers per age group for training and testing set
    counts_train_val = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_train_val.items()}
    counts_test = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_test.items()}

    # Log the counts of unique identifiers per age group
    logger(f"Count of Unique Cat IDs per Age Group in Training/Validation Set:\n{counts_train_val}", file=log_file_path)
    logger(f"Count of Unique Cat IDs per Age Group in Testing Set:\n{counts_test}", file=log_file_path)

    #######################################################
    # CONTINUE WITH ENSURING VALID AND APPROPRIATE SPLITS #
    #######################################################
    
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    groups_train_val, groups_test = groups[train_val_idx], groups[test_idx]

    # logging identifier splits 
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)

    # check group splits
    check_initial_group_split(groups_train_val, groups_test)

    # Specify the cat_ids that must be in the training/validation set
    specific_cat_ids = ['000A', '046A']
    
    # Perform the swapping operation
    train_val_idx, test_idx = swap_cat_id_instances(dataframe, train_val_idx, test_idx, specific_cat_ids)
    
    # Re-assign the sets based on the updated indices
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    new_groups_train_val, new_groups_test = groups[train_val_idx], groups[test_idx]

    # Find differences for training and test sets
    moved_to_train_val, removed_from_train_val = find_group_differences(groups_train_val, new_groups_train_val)
    moved_to_test, removed_from_test = find_group_differences(groups_test, new_groups_test)
    
    # Display the results
    logger(f"Moved to Training/Validation Set:\n{moved_to_train_val}", file=log_file_path)
    logger(f"Removed from Training/Validation Set:\n{removed_from_train_val}", file=log_file_path)
    logger(f"Moved to Test Set:\n{moved_to_test}", file=log_file_path)
    logger(f"Removed from Test Set\n{removed_from_test}", file=log_file_path)

    # Update X_train_val, X_test, y_train_val, y_test, groups_train_val, groups_test based on updated indices
    X_train_val = X[train_val_idx]
    y_train_val = y[train_val_idx]
    groups_train_val = groups[train_val_idx]
    
    X_test = X[test_idx]
    y_test = y[test_idx]
    groups_test = groups[test_idx]

    # logging identifier splits again after potential swaps
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"AFTER SWAP - Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"AFTER SWAP - Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)
    
    # Verify the lengths are consistent
    logger(f"Length of X_train_val:\n{len(X_train_val)}", file=log_file_path)
    logger(f"Length of y_train_val:\n{len(y_train_val)}", file=log_file_path)
    logger(f"Length of groups_train_val:\n{len(groups_train_val)}", file=log_file_path)

    # Check group splits once more
    check_initial_group_split(groups_train_val, groups_test)

    # Convert the modified indices back to a DataFrame representing the updated df_train_val
    df_train_val_updated = dataframe.iloc[train_val_idx].copy()
    df_test_updated = dataframe.iloc[test_idx].copy()

    ############################
    # LOGGING AGE GROUP SPLITS #
    ############################

    # Get the distribution of age groups of age groups before the update
    training_validation_age_group_distribution = df_train_val['age_group'].value_counts()
    testing_age_group_distribution = df_test['age_group'].value_counts()
    
    # Logthe distribution
    logger(f"Train Age Group Distribution BEFORE SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution BEFORE SWAP:\n{testing_age_group_distribution}", file=log_file_path)

    # Get the distribution of age groups after the update
    training_validation_age_group_distribution = df_train_val_updated['age_group'].value_counts()
    testing_age_group_distribution = df_test_updated['age_group'].value_counts()
    
    # Log the distribution
    logger(f"Train Age Group Distribution AFTER SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution AFTER SWAP:\n{testing_age_group_distribution}", file=log_file_path)
    
    ########################################################
    # TRACKING FINAL CAT_IDs & GENDER AFTER REDISTRIBUTION #
    ########################################################

    # Get the distribution of groups
    training_validation_group_distribution = df_train_val_updated['cat_id'].value_counts()  
    testing_group_distribution = df_test_updated['cat_id'].value_counts()  

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val_updated['gender'].value_counts()
    testing_gender_distribution = df_test_updated['gender'].value_counts()
    
    logger(f"\n Starting training on unseen test set\n", file=log_file_path)

    ######################
    # ADD AUGMENTED DATA #
    ######################

    # Filter out augmented data derived from groups in the training set
    augmented_df_filtered = augmented_df[augmented_df['cat_id'].isin(groups_train_val)]
    
    # Convert augmented_df_filtered to numpy array (excluding target and other columns)
    augmented_array = augmented_df_filtered.drop(columns=['target', 'cat_id', 'age_group']).values
    
    # Concatenate the filtered augmented data with X_train_val
    X_train_val = np.concatenate([X_train_val, augmented_array])

    # Extract target labels from the filtered augmented DataFrame
    y_augmented = augmented_df_filtered['age_group'].values
    
    # Encode the labels using the same LabelEncoder instance
    y_augmented_encoded = label_encoder.transform(y_augmented)
    
    # Concatenate the encoded augmented labels with y_train_val
    y_train_val = np.concatenate([y_train_val, y_augmented_encoded])

    # Calculate the distribution of age groups in y_train_val
    age_group_distribution = Counter(y_train_val)
    print("Age group distribution:", age_group_distribution)

    # EarlyStopping callback: monitor 'loss' instead of 'val_loss' for the test set
    early_stopping = EarlyStopping(
        monitor='loss',  
        min_delta=0.001, 
        patience=30,  
        verbose=1,  
        restore_best_weights=True  
    )

    # One final shuffle to ensure randomness
    outer_shuffle_idx = np.random.permutation(len(X_train_val))
    X_train_val = X_train_val[outer_shuffle_idx]
    y_train_val = y_train_val[outer_shuffle_idx]

    class_weights = compute_class_weight(
        class_weight='balanced',
        classes=np.unique(y_train_val),
        y=y_train_val
    )
    weight_dict = {i: class_weights[i] for i in range(len(class_weights))}
    
    # Scale the features
    scaler_full = StandardScaler().fit(X_train_val)
    X_train_full_scaled = scaler_full.transform(X_train_val)
    X_test_scaled = scaler_full.transform(X_test)
    
    # Encode the labels
    y_train_full_encoded = to_categorical(y_train_val)
    y_test_encoded = to_categorical(y_test)

    #######################
    # BUILD & TRAIN MODEL #
    #######################

    optimizers = {
        'Adamax': Adamax(learning_rate=0.00038188800331973483)
    }
    
    # Full model definition with dynamic number of layers
    model_full = Sequential()
    model_full.add(Dense(480, activation='relu', input_shape=(X_train_full_scaled.shape[1],)))  # units_l0 and activation from parameters
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.27188281261238406))  
    model_full.add(Dense(3, activation='softmax'))  
    
    optimizer = optimizers['Adamax']  # optimizer_key from parameters
    
    # Compile the model
    model_full.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    
    # Train the model on the full training set
    history_full = model_full.fit(X_train_full_scaled, y_train_full_encoded, epochs=1500, batch_size=64,
                                  verbose=1, callbacks=[early_stopping], class_weight=weight_dict)
    
    # Evaluate the model on the held-out test set
    test_loss, test_accuracy = model_full.evaluate(X_test_scaled, y_test_encoded)

    y_test_pred_prob = model_full.predict(X_test_scaled)
    y_test_pred = np.argmax(y_test_pred_prob, axis=1)  
    y_test_true = np.argmax(y_test_encoded, axis=1)    

    ################################
    # LOG MAJORITY VOTE PER CAT_ID #
    ################################

    # Convert numeric predictions back to age group labels
    predicted_age_groups = label_encoder.inverse_transform(y_test_pred)
    actual_labels = label_encoder.inverse_transform(y_test_true)
    
    # Map predictions and actual labels back to cat_ids
    test_results = pd.DataFrame({
        'cat_id': df_test_updated['cat_id'],
        'predicted_age_group': predicted_age_groups,
        'actual_age_group': actual_labels
    })
    
    # Group by cat_id and aggregate predicted age groups
    majority_votes = test_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
    actual_groups = test_results.groupby('cat_id')['actual_age_group'].first()
    
    # Calculate the accuracy of majority voting
    correct_predictions = (majority_votes == actual_groups).sum()
    total_cats = len(actual_groups)
    majority_vote_accuracy = correct_predictions / total_cats
    
    # Log the accuracy of the majority voting
    logger(f"Majority Vote Accuracy for cat_id for this fold: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

    ####################################################
    # COLLECT PREDICTIONS FOR GENDER & CAT_ID ANALYSIS #
    ####################################################

    # Debugging print statements
    print(f'Before appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Extend lists with current fold results
    all_cat_ids.extend(df_test_updated['cat_id'].tolist())
    all_predicted_age_groups.extend(predicted_age_groups)
    all_actual_age_groups.extend(actual_labels)
    all_gender.extend(df_test_updated['gender'].tolist())

    # Debugging print statements
    print(f'After appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Calculate additional metrics
    test_precision = precision_score(y_test_true, y_test_pred, average='macro')  # Use 'macro' for imbalanced datasets
    test_recall = recall_score(y_test_true, y_test_pred, average='macro')
    test_f1 = f1_score(y_test_true, y_test_pred, average='macro')

    # prepare averages of outer metrics
    unseen_f1.append(test_f1)
    unseen_losses.append(test_loss)
    unseen_accuracies.append(test_accuracy)
    unseen_precisions.append(test_precision)
    unseen_recalls.append(test_recall)

    # Print final test results
    logger(f"Final Test Results - Loss: {test_loss}, Accuracy: {test_accuracy}, Precision: {test_precision}, Recall: {test_recall}, F1 Score: {test_f1}", file=log_file_path)

    # Generate the confusion matrix
    cm = confusion_matrix(y_test, y_test_pred)
    logger(f"Confusion Matrix:\n {cm}", file=log_file_path)

# Calculate the overall average metrics
unseen_set_avg_f1 = np.mean(unseen_f1)
unseen_set_avg_loss = np.mean(unseen_losses)
unseen_set_avg_acc = np.mean(unseen_accuracies)
unseen_set_avg_precision = np.mean(unseen_precisions)
unseen_set_avg_recall = np.mean(unseen_recalls)

# Append averages to total lists
all_f1.append(unseen_set_avg_f1)
all_losses.append(unseen_set_avg_loss)
all_accuracies.append(unseen_set_avg_acc)
all_precisions.append(unseen_set_avg_precision)
all_recalls.append(unseen_set_avg_recall)

logger(f"\nFinal Average F1-Score across all UNSEEN TEST sets: {unseen_set_avg_f1}", file=log_file_path)
logger(f"\nFinal Average Loss across all UNSEEN TEST sets: {unseen_set_avg_loss}", file=log_file_path)
logger(f"\nFinal Average Accuracy across all UNSEEN TEST sets: {unseen_set_avg_acc}", file=log_file_path)
logger(f"\nFinal Average Precision across all UNSEEN TEST sets: {unseen_set_avg_precision}", file=log_file_path)
logger(f"\nFinal Average Recall across all UNSEEN TEST sets: {unseen_set_avg_recall}\n", file=log_file_path)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# outer_fold 1
# Train Set Group Distribution:
# 046A    63
# 000A    39
# 057A    27
# 020A    23
# 055A    20
# 000B    19
# 067A    19
# 019A    17
# 029A    17
# 106A    14
# 097B    14
# 001A    14
# 059A    14
# 028A    13
# 002A    13
# 039A    12
# 116A    12
# 063A    11
# 025A    11
# 005A    10
# 040A    10
# 016A    10
# 071A    10
# 022A     9
# 051B     9
# 072A     9
# 065A     9
# 045A     9
# 033A     9
# 013B     8
# 094A     8
# 010A     8
# 095A     8
# 027A     7
# 117A     7
# 031A     7
# 109A     6
# 108A     6
# 053A     6
# 008A     6
# 023A     6
# 037A     6
# 007A     6
# 034A     5
# 025C     5
# 070A     5
# 023B     5
# 044A     5
# 075A     5
# 035A     4
# 062A     4
# 026A     4
# 105A     4
# 104A     4
# 052A     4
# 009A     4
# 060A     3
# 012A     3
# 006A     3
# 064A     3
# 058A     3
# 054A     2
# 061A     2
# 087A     2
# 069A     2
# 032A     2
# 011A     2
# 018A     2
# 025B     2
# 093A     2
# 088A     1
# 091A     1
# 100A     1
# 090A     1
# 019B     1
# 115A     1
# 066A     1
# 004A     1
# 048A     1
# 073A     1
# 026C     1
# 076A     1
# 041A     1
# 092A     1
# 049A     1
# 043A     1
# 026B     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 103A    33
# 002B    32
# 047A    28
# 074A    25
# 097A    16
# 101A    15
# 042A    14
# 111A    13
# 051A    12
# 068A    11
# 036A    11
# 014B    10
# 015A     9
# 099A     7
# 050A     7
# 021A     5
# 003A     4
# 056A     3
# 014A     3
# 113A     3
# 038A     2
# 102A     2
# 096A     1
# 110A     1
# 024A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    233
# M    226
# F    210
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    115
# M    111
# F     42
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [006A, 000A, 033A, 001A, 071A, 097B, 028A, 019...
# kitten    [044A, 040A, 046A, 109A, 043A, 049A, 041A, 045...
# senior    [093A, 057A, 106A, 104A, 055A, 059A, 116A, 051...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [015A, 103A, 074A, 002B, 101A, 038A, 099A, 014...
# kitten                 [014B, 111A, 047A, 042A, 050A, 110A]
# senior                       [097A, 113A, 056A, 051A, 024A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 60, 'kitten': 10, 'senior': 17}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 14, 'kitten': 6, 'senior': 5}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '004A' '005A' '006A' '007A' '008A' '009A'
#  '010A' '011A' '012A' '013B' '016A' '018A' '019A' '019B' '020A' '022A'
#  '023A' '023B' '025A' '025B' '025C' '026A' '026B' '026C' '027A' '028A'
#  '029A' '031A' '032A' '033A' '034A' '035A' '037A' '039A' '040A' '041A'
#  '043A' '044A' '045A' '046A' '048A' '049A' '051B' '052A' '053A' '054A'
#  '055A' '057A' '058A' '059A' '060A' '061A' '062A' '063A' '064A' '065A'
#  '066A' '067A' '069A' '070A' '071A' '072A' '073A' '075A' '076A' '087A'
#  '088A' '090A' '091A' '092A' '093A' '094A' '095A' '097B' '100A' '104A'
#  '105A' '106A' '108A' '109A' '115A' '116A' '117A']
# Unique Test Group IDs:
# ['002B' '003A' '014A' '014B' '015A' '021A' '024A' '036A' '038A' '042A'
#  '047A' '050A' '051A' '056A' '068A' '074A' '096A' '097A' '099A' '101A'
#  '102A' '103A' '110A' '111A' '113A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '004A' '005A' '006A' '007A' '008A' '009A'
#  '010A' '011A' '012A' '013B' '016A' '018A' '019A' '019B' '020A' '022A'
#  '023A' '023B' '025A' '025B' '025C' '026A' '026B' '026C' '027A' '028A'
#  '029A' '031A' '032A' '033A' '034A' '035A' '037A' '039A' '040A' '041A'
#  '043A' '044A' '045A' '046A' '048A' '049A' '051B' '052A' '053A' '054A'
#  '055A' '057A' '058A' '059A' '060A' '061A' '062A' '063A' '064A' '065A'
#  '066A' '067A' '069A' '070A' '071A' '072A' '073A' '075A' '076A' '087A'
#  '088A' '090A' '091A' '092A' '093A' '094A' '095A' '097B' '100A' '104A'
#  '105A' '106A' '108A' '109A' '115A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['002B' '003A' '014A' '014B' '015A' '021A' '024A' '036A' '038A' '042A'
#  '047A' '050A' '051A' '056A' '068A' '074A' '096A' '097A' '099A' '101A'
#  '102A' '103A' '110A' '111A' '113A']
# Length of X_train_val:
# 669
# Length of y_train_val:
# 669
# Length of groups_train_val:
# 669
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     428
# senior    143
# kitten     98
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     160
# kitten     73
# senior     35
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     428
# senior    143
# kitten     98
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     160
# kitten     73
# senior     35
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 856, 2: 572, 1: 392})
# Epoch 1/1500
# 29/29 [==============================] - 0s 2ms/step - loss: 1.0370 - accuracy: 0.4967
# Epoch 2/1500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.7700 - accuracy: 0.6011
# Epoch 3/1500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.6919 - accuracy: 0.6571
# Epoch 4/1500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.6470 - accuracy: 0.6923
# Epoch 5/1500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.6142 - accuracy: 0.6945
# Epoch 6/1500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.5906 - accuracy: 0.7154
# Epoch 7/1500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.5679 - accuracy: 0.7247
# Epoch 8/1500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.5526 - accuracy: 0.7401
# Epoch 9/1500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.5098 - accuracy: 0.7429
# Epoch 10/1500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.5156 - accuracy: 0.7407
# Epoch 11/1500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.
1500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0539 - accuracy: 0.9808
# Epoch 332/1500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0566 - accuracy: 0.9791
# Epoch 333/1500
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0560 - accuracy: 0.9769
# Epoch 334/1500
# 29/29 [==============================] - 0s 1ms/step - loss: 0.0574 - accuracy: 0.9791
# Epoch 335/1500
#  1/29 [>.............................] - ETA: 0s - loss: 0.0251 - accuracy: 1.0000Restoring model weights from the end of the best epoch: 305.
# 29/29 [==============================] - 0s 2ms/step - loss: 0.0612 - accuracy: 0.9736
# Epoch 335: early stopping
# 9/9 [==============================] - 0s 874us/step - loss: 0.8207 - accuracy: 0.7463
# 9/9 [==============================] - 0s 766us/step
# Majority Vote Accuracy for cat_id for this fold: 0.80 (20/25)
# Before appending - Cat IDs: 0, Predictions: 0, Actuals: 0, Gender: 0
# After appending - Cat IDs: 268, Predictions: 268, Actuals: 268, Gender: 268
# Final Test Results - Loss: 0.8207231760025024, Accuracy: 0.746268630027771, Precision: 0.7241828294459873, Recall: 0.7392367906066536, F1 Score: 0.7118595690024261
# Confusion Matrix:
#  [[120   2  38]
#  [ 18  55   0]
#  [ 10   0  25]]
# outer_fold 2
# Train Set Group Distribution:
# 000A    39
# 103A    33
# 002B    32
# 047A    28
# 057A    27
# 074A    25
# 020A    23
# 055A    20
# 000B    19
# 097A    16
# 101A    15
# 059A    14
# 042A    14
# 097B    14
# 106A    14
# 028A    13
# 002A    13
# 111A    13
# 039A    12
# 116A    12
# 051A    12
# 036A    11
# 068A    11
# 025A    11
# 014B    10
# 040A    10
# 016A    10
# 005A    10
# 071A    10
# 015A     9
# 013B     8
# 094A     8
# 010A     8
# 099A     7
# 050A     7
# 117A     7
# 031A     7
# 027A     7
# 053A     6
# 108A     6
# 023A     6
# 007A     6
# 025C     5
# 044A     5
# 023B     5
# 021A     5
# 070A     5
# 034A     5
# 003A     4
# 009A     4
# 026A     4
# 062A     4
# 035A     4
# 052A     4
# 104A     4
# 058A     3
# 012A     3
# 006A     3
# 014A     3
# 113A     3
# 056A     3
# 018A     2
# 038A     2
# 025B     2
# 054A     2
# 032A     2
# 069A     2
# 102A     2
# 088A     1
# 090A     1
# 110A     1
# 115A     1
# 019B     1
# 073A     1
# 004A     1
# 048A     1
# 066A     1
# 026C     1
# 041A     1
# 092A     1
# 049A     1
# 096A     1
# 024A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 046A    63
# 067A    19
# 019A    17
# 029A    17
# 001A    14
# 063A    11
# 033A     9
# 051B     9
# 022A     9
# 072A     9
# 065A     9
# 045A     9
# 095A     8
# 037A     6
# 008A     6
# 109A     6
# 075A     5
# 105A     4
# 064A     3
# 060A     3
# 093A     2
# 087A     2
# 011A     2
# 061A     2
# 076A     1
# 043A     1
# 091A     1
# 100A     1
# 026B     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    238
# F    229
# X    221
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    127
# M     99
# F     23
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [006A, 000A, 015A, 103A, 071A, 097B, 028A, 074...
# kitten    [044A, 014B, 111A, 040A, 047A, 042A, 050A, 049...
# senior    [097A, 057A, 106A, 104A, 055A, 059A, 113A, 116...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [033A, 001A, 019A, 067A, 022A, 029A, 095A, 072...
# kitten                             [046A, 109A, 043A, 045A]
# senior                             [093A, 051B, 011A, 061A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 53, 'kitten': 12, 'senior': 18}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 21, 'kitten': 4, 'senior': 4}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '002A' '002B' '003A' '004A' '005A' '006A' '007A' '009A'
#  '010A' '012A' '013B' '014A' '014B' '015A' '016A' '018A' '019B' '020A'
#  '021A' '023A' '023B' '024A' '025A' '025B' '025C' '026A' '026C' '027A'
#  '028A' '031A' '032A' '034A' '035A' '036A' '038A' '039A' '040A' '041A'
#  '042A' '044A' '047A' '048A' '049A' '050A' '051A' '052A' '053A' '054A'
#  '055A' '056A' '057A' '058A' '059A' '062A' '066A' '068A' '069A' '070A'
#  '071A' '073A' '074A' '088A' '090A' '092A' '094A' '096A' '097A' '097B'
#  '099A' '101A' '102A' '103A' '104A' '106A' '108A' '110A' '111A' '113A'
#  '115A' '116A' '117A']
# Unique Test Group IDs:
# ['001A' '008A' '011A' '019A' '022A' '026B' '029A' '033A' '037A' '043A'
#  '045A' '046A' '051B' '060A' '061A' '063A' '064A' '065A' '067A' '072A'
#  '075A' '076A' '087A' '091A' '093A' '095A' '100A' '105A' '109A']
# No common groups found between train and test sets.
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Moved to Training/Validation Set:
# {'046A'}
# Removed from Training/Validation Set:
# {'044A'}
# Moved to Test Set:
# {'044A'}
# Removed from Test Set
# {'046A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '002A' '002B' '003A' '004A' '005A' '006A' '007A' '009A'
#  '010A' '012A' '013B' '014A' '014B' '015A' '016A' '018A' '019B' '020A'
#  '021A' '023A' '023B' '024A' '025A' '025B' '025C' '026A' '026C' '027A'
#  '028A' '031A' '032A' '034A' '035A' '036A' '038A' '039A' '040A' '041A'
#  '042A' '046A' '047A' '048A' '049A' '050A' '051A' '052A' '053A' '054A'
#  '055A' '056A' '057A' '058A' '059A' '062A' '066A' '068A' '069A' '070A'
#  '071A' '073A' '074A' '088A' '090A' '092A' '094A' '096A' '097A' '097B'
#  '099A' '101A' '102A' '103A' '104A' '106A' '108A' '110A' '111A' '113A'
#  '115A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['001A' '008A' '011A' '019A' '022A' '026B' '029A' '033A' '037A' '043A'
#  '044A' '045A' '051B' '060A' '061A' '063A' '064A' '065A' '067A' '072A'
#  '075A' '076A' '087A' '091A' '093A' '095A' '100A' '105A' '109A']
# Length of X_train_val:
# 746
# Length of y_train_val:
# 746
# Length of groups_train_val:
# 746
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     433
# senior    163
# kitten     92
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     155
# kitten     79
# senior     15
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     433
# senior    163
# kitten    150
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     155
# kitten     21
# senior     15
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 866, 2: 652, 1: 600})
# Epoch 1/1500
# 34/34 [==============================] - 0s 2ms/step - loss: 0.9154 - accuracy: 0.5845
# Epoch 2/1500
# 34/34 [==============================] - 0s 1ms/step - loss: 0.7056 - accuracy: 0.6775
# Epoch 3/1500
# 34/34 [==============================] - 0s 2ms/step - loss: 0.6219 - accuracy: 0.7219
# Epoch 4/1500
# 34/34 [==============================] - 0s 2ms/step - loss: 0.5635 - accuracy: 0.7540
# Epoch 5/1500
# 34/34 [==============================] - 0s 2ms/step - loss: 0.5510 - accuracy: 0.7653
# Epoch 6/1500
# 34/34 [==============================] - 0s 3ms/step - loss: 0.5257 - accuracy: 0.7691
# Epoch 7/1500
# 34/34 [==============================] - 0s 2ms/step - loss: 0.5002 - accuracy: 0.7908
# Epoch 8/1500
# 34/34 [==============================] - 0s 2ms/step - loss: 0.4841 - accuracy: 0.7871
# Epoch 9/1500
# 34/34 [==============================] - 0s 2ms/step - loss: 0.4932 - accuracy: 0.7899
# Epoch 10/1500
# 34/34 [==============================] - 0s 3ms/step - loss: 0.4880 - accuracy: 0.8003
# Epoch 11/1500
# 34/34 [==============================] - 0s 2ms/step - loss: 0.4473 - accuracy: 0.8182
# Epoch 12/1500
# 34/34 [==============================] - 0s 2ms/step - loss: 0.4376 - accuracy: 0.8178
# Epoch 13/1500
# 34/34 [==============================] - 0s 2ms/step - loss: 0.4320 - accuracy: 0.8244
# Epoch 14/1500
# 34/34 [==============================] - 0s 2ms/step - loss: 0.4304 - accuracy: 0.8159
# Epoch 15/1500
# 34/34 [==============================] - 0s 2ms/step - loss: 0.4028 - accuracy: 0.8381
# Epoch 16/1500
# 34/34 [==============================] - 0s 2ms/step - loss: 0.4234 - accuracy: 0.8163
# Epoch 17/1500
# 34/34 [==============================] - 0s 1ms/step - loss: 0.3951 - accuracy: 0.8362
# Epoch 18/1500
# 34/34 [==============================] - 0s 1ms/step - loss: 0.3868 - accuracy: 0.8333
# Epoch 19/1500
# 34/34 [==============================] - 0s 1ms/step - loss: 0.3848 - accuracy: 0.8338
# Epoch 20/1500
# 34/34 [==============================] - 0s 2ms/step - loss: 0.3788 - accuracy: 0.8414
# Epoch 21/1500
# 34/34 [==============================] - 0s 2ms/step - loss: 0.3758 - accuracy: 0.8390
# Epoch 22/1500
# 34/34 [==============================] - 0s 1ms/step - loss: 0.3876 - accuracy: 0.8362
# Epoch 23/1500
# 34/34 [==============================] - 0s 3ms/step - loss: 0.3814 - accuracy: 0.8395
# Epoch 24/1500
# 34/34 [==============================] - 0s 2ms/step - loss: 0.3649 - accuracy: 0.8461
# Epoch 25/1500
# 34/34 [==============================] - 0s 2ms/step - loss: 0.3520 - accuracy: 0.8503
# Epoch 26/1500
# 34/34 [==============================] - 0s 2ms/step - loss: 0.3766 - accuracy: 0.8390
# Epoch 27/1500
# 34/34 [==============================] - 0s 2ms/step - loss: 0.3557 - accuracy: 0
1500
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0678 - accuracy: 0.9704
# Epoch 398/1500
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0678 - accuracy: 0.9734
# Epoch 399/1500
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0520 - accuracy: 0.9855
# Epoch 400/1500
# 33/33 [==============================] - 0s 1ms/step - loss: 0.0567 - accuracy: 0.9792
# Epoch 401/1500
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0609 - accuracy: 0.9743
# Epoch 402/1500
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0544 - accuracy: 0.9777
# Epoch 403/1500
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0551 - accuracy: 0.9797
# Epoch 404/1500
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0561 - accuracy: 0.9758
# Epoch 405/1500
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0593 - accuracy: 0.9811
# Epoch 406/1500
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0662 - accuracy: 0.9772
# Epoch 407/1500
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0624 - accuracy: 0.9767
# Epoch 408/1500
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0497 - accuracy: 0.9826
# Epoch 409/1500
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0501 - accuracy: 0.9787
# Epoch 410/1500
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0587 - accuracy: 0.9792
# Epoch 411/1500
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0574 - accuracy: 0.9787
# Epoch 412/1500
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0754 - accuracy: 0.9738
# Epoch 413/1500
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0646 - accuracy: 0.9758
# Epoch 414/1500
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0520 - accuracy: 0.9782
# Epoch 415/1500
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0548 - accuracy: 0.9767
# Epoch 416/1500
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0630 - accuracy: 0.9738
# Epoch 417/1500
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0553 - accuracy: 0.9811
# Epoch 418/1500
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0610 - accuracy: 0.9772
# Epoch 419/1500
#  1/33 [..............................] - ETA: 0s - loss: 0.0936 - accuracy: 0.9375Restoring model weights from the end of the best epoch: 389.
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0518 - accuracy: 0.9835
# Epoch 419: early stopping
# 6/6 [==============================] - 0s 1ms/step - loss: 1.4134 - accuracy: 0.6608
# 6/6 [==============================] - 0s 918us/step
# Majority Vote Accuracy for cat_id for this fold: 0.71 (20/28)
# Before appending - Cat IDs: 674, Predictions: 674, Actuals: 674, Gender: 674
# After appending - Cat IDs: 845, Predictions: 845, Actuals: 845, Gender: 845
# Final Test Results - Loss: 1.4133824110031128, Accuracy: 0.6608186960220337, Precision: 0.7474400630138335, Recall: 0.7155000711338739, F1 Score: 0.7073192239858906
# Confusion Matrix:
#  [[76  1 11]
#  [ 1 11  0]
#  [45  0 26]]
#
# Final Average F1-Score across all UNSEEN TEST sets: 0.6809128760581674
#
# Final Average Loss across all UNSEEN TEST sets: 1.0122801661491394
#
# Final Average Accuracy across all UNSEEN TEST sets: 0.7197555154561996
#
# Final Average Precision across all UNSEEN TEST sets: 0.6780011892196642
#
# Final Average Recall across all UNSEEN TEST sets: 0.7235634495883067

# %%
seed_2_folds_values = (unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1)

# Plotting all fold metrics
seed_2_folds_plot = plot_all_metrics(unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1, "Folds", "Fold Number")

# %% [markdown]
# ## Majority Voting on Total Entries per cat_id

# %%
# Debugging print statements
print(f'Checking - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
# Out:
# Checking - Cat IDs: 845, Predictions: 845, Actuals: 845, Gender: 845

# %%
# Create results df
full_results = pd.DataFrame({
    'cat_id': all_cat_ids,
    'predicted_age_group': all_predicted_age_groups,
    'actual_age_group': all_actual_age_groups,
    'all_gender': all_gender
})

# create a correct majority prediction column
full_results['correct'] = full_results['predicted_age_group'] == full_results['actual_age_group']

# %%
# Group by cat_id and aggregate predicted age groups
majority_votes = full_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first()

# Calculate the accuracy of majority voting
correct_predictions = (majority_votes == actual_groups).sum()
total_cats = len(actual_groups)
majority_vote_accuracy = correct_predictions / total_cats

logger(f"Overall Majority Vote Accuracy for cat_id: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

# store for final evaluation 
all_majority_vote_accuracies.append(majority_vote_accuracy)
# Out:
# Overall Majority Vote Accuracy for cat_id: 0.75 (82/110)

# %%
# Detailed df with predictions, actual labels, and comparison including majority vote
detailed_results = full_results.groupby('cat_id').apply(
    lambda x: pd.Series({
        'Predictions': list(x['predicted_age_group']),
        'Majority Vote': x['predicted_age_group'].mode()[0],
        'Actual Age Group': x['actual_age_group'].iloc[0],
        'Correct Majority Vote': x['predicted_age_group'].mode()[0] == x['actual_age_group'].iloc[0]
    })
).reset_index()

# Convert to DataFrame for better formatting and display
detailed_results = pd.DataFrame(detailed_results)

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 10)
pd.set_option('display.width', 1000)

sorted_detailed_results = detailed_results.sort_values(by='Correct Majority Vote', ascending=False)

# Display the sorted DataFrame
sorted_detailed_results
# Out:
#     cat_id                                        Predictions Majority Vote Actual Age Group  Correct Majority Vote
# 0     000B  [adult, adult, kitten, senior, adult, adult, a...         adult            adult                   True
# 62    056A                           [senior, senior, senior]        senior           senior                   True
# 76    070A               [adult, adult, adult, adult, senior]         adult            adult                   True
# 75    069A                                     [adult, adult]         adult            adult                   True
# 73    067A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 72    066A                                            [adult]         adult            adult                   True
# 71    065A  [senior, adult, adult, adult, adult, senior, a...         adult            adult                   True
# 70    064A                             [kitten, adult, adult]         adult            adult                   True
# 69    063A  [adult, senior, adult, kitten, adult, senior, ...         adult            adult                   True
# 68    062A                       [adult, adult, adult, adult]         adult            adult                   True
# 65    059A  [senior, adult, adult, senior, senior, senior,...        senior           senior                   True
# 59    053A         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 47    041A                                           [kitten]        kitten           kitten                   True
# 58    052A                       [adult, adult, adult, adult]         adult            adult                   True
# 57    051B  [senior, adult, senior, adult, senior, senior,...        senior           senior                   True
# 56    051A  [adult, senior, adult, adult, senior, senior, ...        senior           senior                   True
# 1     001A  [adult, adult, senior, adult, adult, adult, ad...         adult            adult                   True
# 54    049A                                           [kitten]        kitten           kitten                   True
# 52    047A  [adult, adult, adult, kitten, kitten, kitten, ...        kitten           kitten                   True
# 51    045A  [kitten, kitten, kitten, kitten, kitten, kitte...        kitten           kitten                   True
# 50    044A  [kitten, kitten, kitten, kitten, kitten, kitte...        kitten           kitten                   True
# 49    043A                                           [kitten]        kitten           kitten                   True
# 77    071A  [adult, senior, adult, adult, adult, adult, ad...         adult            adult                   True
# 78    072A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 79    073A                                            [adult]         adult            adult                   True
# 80    074A  [adult, senior, adult, adult, adult, adult, ad...         adult            adult                   True
# 108   116A  [senior, senior, senior, senior, adult, senior...        senior           senior                   True
# 107   115A                                           [kitten]        kitten           kitten                   True
# 106   113A                           [senior, senior, senior]        senior           senior                   True
# 105   111A  [kitten, kitten, kitten, kitten, kitten, kitte...        kitten           kitten                   True
# 100   105A                      [adult, adult, adult, senior]         adult            adult                   True
# 98    103A  [adult, adult, adult, adult, senior, senior, s...         adult            adult                   True
# 97    102A                                    [senior, adult]         adult            adult                   True
# 96    101A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 95    100A                                            [adult]         adult            adult                   True
# 94    099A  [adult, senior, adult, adult, adult, adult, ad...         adult            adult                   True
# 92    097A  [adult, senior, senior, adult, senior, senior,...        senior           senior                   True
# 91    096A                                            [adult]         adult            adult                   True
# 90    095A  [senior, adult, adult, senior, senior, senior,...         adult            adult                   True
# 89    094A  [senior, senior, senior, senior, senior, senio...        senior           senior                   True
# 85    090A                                           [senior]        senior           senior                   True
# 84    088A                                            [adult]         adult            adult                   True
# 83    087A                                     [adult, adult]         adult            adult                   True
# 82    076A                                            [adult]         adult            adult                   True
# 81    075A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 48    042A  [kitten, kitten, kitten, kitten, adult, kitten...        kitten           kitten                   True
# 55    050A  [kitten, kitten, kitten, kitten, kitten, kitte...        kitten           kitten                   True
# 46    040A  [kitten, kitten, kitten, kitten, kitten, kitte...        kitten           kitten                   True
# 15    014A                              [adult, adult, adult]         adult            adult                   True
# 25    023A         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 24    022A  [adult, adult, adult, adult, adult, adult, kit...         adult            adult                   True
# 45    039A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 22    020A  [adult, adult, adult, adult, senior, adult, ad...         adult            adult                   True
# 21    019B                                            [adult]         adult            adult                   True
# 20    019A  [adult, adult, adult, adult, kitten, adult, ad...         adult            adult                   True
# 19    018A                                    [adult, senior]         adult            adult                   True
# 18    016A  [senior, adult, adult, senior, senior, senior,...        senior           senior                   True
# 17    015A  [adult, senior, adult, adult, adult, adult, ad...         adult            adult                   True
# 16    014B  [kitten, kitten, kitten, adult, kitten, kitten...        kitten           kitten                   True
# 14    013B  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 28    025A  [senior, adult, adult, adult, adult, adult, se...         adult            adult                   True
# 13    012A                             [senior, adult, adult]         adult            adult                   True
# 11    010A  [adult, adult, adult, adult, adult, adult, sen...         adult            adult                   True
# 10    009A                       [adult, adult, adult, adult]         adult            adult                   True
# 9     008A         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 8     007A         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 7     006A                             [adult, adult, senior]         adult            adult                   True
# 5     004A                                            [adult]         adult            adult                   True
# 4     003A                       [adult, adult, adult, adult]         adult            adult                   True
# 3     002B  [adult, adult, senior, senior, adult, adult, s...         adult            adult                   True
# 2     002A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 26    023B                [adult, adult, adult, adult, adult]         adult            adult                   True
# 23    021A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 36    029A  [adult, adult, adult, adult, adult, senior, se...         adult            adult                   True
# 41    035A                      [senior, adult, adult, adult]         adult            adult                   True
# 38    032A                                    [kitten, adult]         adult            adult                   True
# 35    028A  [adult, senior, adult, adult, adult, adult, ad...         adult            adult                   True
# 40    034A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 34    027A  [adult, adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 37    031A  [adult, adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 31    026A                       [adult, adult, adult, adult]         adult            adult                   True
# 43    037A        [adult, senior, adult, adult, adult, adult]         adult            adult                   True
# 104   110A                                            [adult]         adult           kitten                  False
# 103   109A      [adult, adult, kitten, kitten, kitten, adult]         adult           kitten                  False
# 102   108A         [adult, adult, adult, adult, adult, adult]         adult           senior                  False
# 93    097B  [senior, adult, kitten, senior, adult, senior,...        senior            adult                  False
# 42    036A  [senior, senior, senior, senior, adult, senior...        senior            adult                  False
# 6     005A  [senior, senior, senior, senior, senior, senio...        senior            adult                  False
# 99    104A                     [adult, senior, adult, senior]         adult           senior                  False
# 53    048A                                            [adult]         adult           kitten                  False
# 39    033A  [kitten, adult, kitten, kitten, adult, adult, ...        kitten            adult                  False
# 44    038A                                   [kitten, kitten]        kitten            adult                  False
# 101   106A  [adult, adult, senior, senior, senior, adult, ...         adult           senior                  False
# 27    024A                                            [adult]         adult           senior                  False
# 12    011A                                     [adult, adult]         adult           senior                  False
# 74    068A  [adult, adult, senior, senior, senior, adult, ...        senior            adult                  False
# 60    054A                                     [adult, adult]         adult           senior                  False
# 88    093A                                     [adult, adult]         adult           senior                  False
# 87    092A                                           [senior]        senior            adult                  False
# 86    091A                                           [senior]        senior            adult                  False
# 61    055A  [senior, adult, senior, adult, senior, adult, ...         adult           senior                  False
# 63    057A  [adult, adult, senior, senior, adult, senior, ...         adult           senior                  False
# 64    058A                              [adult, adult, adult]         adult           senior                  False
# 33    026C                                           [kitten]        kitten            adult                  False
# 66    060A                           [kitten, kitten, kitten]        kitten            adult                  False
# 67    061A                                     [adult, adult]         adult           senior                  False
# 32    026B                                           [senior]        senior            adult                  False
# 30    025C            [senior, senior, senior, senior, adult]        senior            adult                  False
# 29    025B                                   [senior, senior]        senior            adult                  False
# 109   117A  [adult, adult, adult, adult, adult, adult, adult]         adult           senior                  False

# %%
# Create df for majority votes
majority_df = majority_votes.reset_index()
majority_df.columns = ['cat_id', 'Majority_Vote']

# Get actual groups for each cat_id
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first().reset_index()

# Merge majority votes with actual groups
majority_with_actual = pd.merge(majority_df, actual_groups, on='cat_id')

# Add a column to check if the majority vote was correct
majority_with_actual['Majority_Correct'] = majority_with_actual['Majority_Vote'] == majority_with_actual['actual_age_group']

# Count correct majority votes per class
correct_majority_votes_per_class = majority_with_actual.groupby('actual_age_group')['Majority_Correct'].sum()

print("Correct Majority Votes per Class:")
print(correct_majority_votes_per_class)
# Out:
# Correct Majority Votes per Class:
# actual_age_group
# adult     60
# kitten    12
# senior    10
# Name: Majority_Correct, dtype: int64

# %%
# Calculate the total count and the number of correct predictions for each class
class_stats = majority_with_actual.groupby('actual_age_group').agg(
    total_count=('Majority_Correct', 'size'),  # Total number of cases per class
    correct_count=('Majority_Correct', 'sum')  # Sum of correct predictions per class
).reset_index()

# Calculate accuracy for each class
class_stats['accuracy'] = class_stats['correct_count'] / class_stats['total_count'] * 100

# store for final evaluation 
all_majority_vote_details.append(class_stats)

# Log detailed stats
print("Detailed Class Statistics for Majority Votes:")
print(class_stats)
# Out:
# Detailed Class Statistics for Majority Votes:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult           73             60  82.191781
# 1           kitten           15             12  80.000000
# 2           senior           22             10  45.454545

# %%
# Plot for Detailed Class Statistics for Majority Votes
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Accuracy of Majority Votes by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Detailed Class Statistics

# %%
# Calculate the total count and the number of correct predictions for each class
class_stats = full_results.groupby('actual_age_group').agg(
    total_count=('correct', 'size'),
    correct_count=('correct', 'sum')
).reset_index()

# Calculate accuracy for each class
class_stats['accuracy'] = class_stats['correct_count'] / class_stats['total_count'] * 100

# store for final evaluation 
all_class_stats.append(class_stats)

# Log the detailed stats
print("Detailed Class Statistics:")
print(class_stats)
# Out:
# Detailed Class Statistics:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult          554            429  77.436823
# 1           kitten          113             90  79.646018
# 2           senior          178             93  52.247191

# %%
# Plot for Detailed Class Statistics (Overall)
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Overall Accuracy by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Gender Exploration

# %%
# Group by gender and calculate the total count, correct predictions, and accuracy
gender_stats = full_results.groupby('all_gender').agg(
    count=('cat_id', 'size'),  # Total number of cases per gender
    correct=('correct', 'sum')  # Sum of correct predictions per gender
).reset_index()

# Calculate accuracy for each gender
gender_stats['accuracy'] = (gender_stats['correct'] / gender_stats['count'] * 100).round(2)

# Display the DataFrame
print("Accuracy by Gender:")
print(gender_stats)

# store for final evaluation 
all_gender_stats.append(gender_stats)
# Out:
# Accuracy by Gender:
#   all_gender  count  correct  accuracy
# 0          F    213      155     72.77
# 1          M    342      256     74.85
# 2          X    290      201     69.31

# %%
# Plot for Accuracy by Gender
styled_barplot(gender_stats, 'all_gender', 'accuracy', 
               'Accuracy by Gender', 
               'Gender', 'Accuracy (%)')

# %% [markdown]
# ### Log current total CV Stats

# %%
print("Total Majority Vote Accuracy so far:", all_majority_vote_accuracies)
print("Total Class Statistics so far:\n", all_class_stats)
print("Total Gender Accuracy so far:\n", all_gender_stats)
# Out:
# Total Majority Vote Accuracy so far: [0.7363636363636363, 0.7454545454545455]
# Total Class Statistics so far:
#  [  actual_age_group  total_count  correct_count   accuracy
# 0            adult          572            437  76.398601
# 1           kitten          109             96  88.073394
# 2           senior          178            107  60.112360,   actual_age_group  total_count  correct_count   accuracy
# 0            adult          554            429  77.436823
# 1           kitten          113             90  79.646018
# 2           senior          178             93  52.247191]
# Total Gender Accuracy so far:
#  [  all_gender  count  correct  accuracy
# 0          F    213      174     81.69
# 1          M    360      250     69.44
# 2          X    286      216     75.52,   all_gender  count  correct  accuracy
# 0          F    213      155     72.77
# 1          M    342      256     74.85
# 2          X    290      201     69.31]

# %% [markdown]
# # RANDOM SEED 3

# %%
# Set a fixed random seed for reproducibility
random.seed(int(random_seeds[2]))
np.random.seed(int(random_seeds[2]))
tf.random.set_seed(int(random_seeds[2]))

# Load datasets
dataframe = pd.read_csv('/Users/astrid/PycharmProjects/audioset-thesis-work/audioset/vggish/embeddings/8april_looped_embeddings.csv')
augmented_df = pd.read_csv('/Users/astrid/PycharmProjects/audioset-thesis-work/audioset/vggish/embeddings/augmented_dataset_19.csv')

dataframe.drop('mean_freq', axis=1, inplace=True)

augmented_df.drop('gender', axis=1, inplace=True)

def assign_age_group(age, age_groups):
    for group_name, age_range in age_groups.items():
        if age_range[0] <= age < age_range[1]:
            return group_name
    return 'Unknown'  # For any age that doesn't fit the defined groups

# Define age groups
age_groups = {
    'kitten': (0, 0.5),
    'adult': (0.5, 12),
    'senior': (12, 20)
}

# Create a new column for the age group
dataframe['age_group'] = dataframe['target'].apply(assign_age_group, age_groups=age_groups)
augmented_df['age_group'] = augmented_df['target'].apply(assign_age_group, age_groups=age_groups)

print(dataframe['age_group'].value_counts())
print(augmented_df['age_group'].value_counts())
# Out:
# adult     588
# senior    178
# kitten    171
# Name: age_group, dtype: int64
# adult     588
# senior    534
# kitten    513
# Name: age_group, dtype: int64

# %%
# Separate features and labels
X = dataframe.iloc[:, :-4].values  # all columns except the last four

# Encode the 'age_group' column as integers using LabelEncoder
label_encoder = LabelEncoder()
encoded_y = label_encoder.fit_transform(dataframe['age_group'].values)

# Use the encoded labels for splitting and one-hot encoding
y = encoded_y  

# Convert 'cat_id' column to numpy array to be used as groups array for GroupKFold
groups = dataframe['cat_id'].values

# %%
tf.keras.backend.clear_session()

# %% [markdown]
# ## Run Setup

# %%
all_cat_ids = []
all_predicted_age_groups = []
all_actual_age_groups = []
all_gender = []

# Define the StratifiedGroupKFold splitter for 4 fold CV with random shuffling
outer_cv = StratifiedGroupKFold(n_splits=4, shuffle=True, random_state=int(random_seeds[2]))

# unseen test set metrics
unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1 = [], [], [], [], []

outer_fold = 0

# Use the splitter to generate indices for training and testing sets
# Note: GroupShuffleSplit.split returns indices, so we use it to index the arrays
for train_val_idx, test_idx in outer_cv.split(X, y, groups):
    outer_fold += 1
    logger(f"outer_fold {outer_fold}", file=log_file_path)

    # Convert indices back to DataFrame for easy manipulation
    df_train_val = dataframe.iloc[train_val_idx]
    df_test = dataframe.iloc[test_idx]

    ##############################
    # ASSESSING SPLITS BY CAT_ID #
    ##############################
    
    # Get the distribution of groups
    training_validation_group_distribution = df_train_val['cat_id'].value_counts()  
    testing_group_distribution = df_test['cat_id'].value_counts()  
    
    # Log or print the distribution
    logger(f"Train Set Group Distribution:\n{training_validation_group_distribution}", file=log_file_path)
    logger(f"Testing Set Group Distribution:\n{testing_group_distribution}", file=log_file_path)

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val['gender'].value_counts()
    testing_gender_distribution = df_test['gender'].value_counts()
    
    # Log the distribution
    logger(f"Training Set Gender Distribution BEFORE SWAP:\n{training_gender_distribution}", file=log_file_path)
    logger(f"Testing Set Gender Distribution BEFORE SWAP:\n{testing_gender_distribution}", file=log_file_path)

    # Group by 'age_group' and then list unique 'cat_id' within each age group
    unique_cat_ids_per_age_group_train_val = df_train_val.groupby('age_group')['cat_id'].unique()
    unique_cat_ids_per_age_group_test = df_test.groupby('age_group')['cat_id'].unique()
    
    # Log results
    logger(f"Unique Cat IDs per Age Group in Training/Validation Set:\n{unique_cat_ids_per_age_group_train_val}", file=log_file_path)
    logger(f"Unique Cat IDs per Age Group in Testing Set:\n{unique_cat_ids_per_age_group_test}", file=log_file_path)

    # Calculate the count of unique identifiers per age group for training and testing set
    counts_train_val = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_train_val.items()}
    counts_test = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_test.items()}

    # Log the counts of unique identifiers per age group
    logger(f"Count of Unique Cat IDs per Age Group in Training/Validation Set:\n{counts_train_val}", file=log_file_path)
    logger(f"Count of Unique Cat IDs per Age Group in Testing Set:\n{counts_test}", file=log_file_path)

    #######################################################
    # CONTINUE WITH ENSURING VALID AND APPROPRIATE SPLITS #
    #######################################################
    
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    groups_train_val, groups_test = groups[train_val_idx], groups[test_idx]

    # logging identifier splits 
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)

    # check group splits
    check_initial_group_split(groups_train_val, groups_test)

    # Specify the cat_ids that must be in the training/validation set
    specific_cat_ids = ['000A', '046A']
    
    # Perform the swapping operation
    train_val_idx, test_idx = swap_cat_id_instances(dataframe, train_val_idx, test_idx, specific_cat_ids)
    
    # Re-assign the sets based on the updated indices
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    new_groups_train_val, new_groups_test = groups[train_val_idx], groups[test_idx]

    # Find differences for training and test sets
    moved_to_train_val, removed_from_train_val = find_group_differences(groups_train_val, new_groups_train_val)
    moved_to_test, removed_from_test = find_group_differences(groups_test, new_groups_test)
    
    # Display the results
    logger(f"Moved to Training/Validation Set:\n{moved_to_train_val}", file=log_file_path)
    logger(f"Removed from Training/Validation Set:\n{removed_from_train_val}", file=log_file_path)
    logger(f"Moved to Test Set:\n{moved_to_test}", file=log_file_path)
    logger(f"Removed from Test Set\n{removed_from_test}", file=log_file_path)

    # Update X_train_val, X_test, y_train_val, y_test, groups_train_val, groups_test based on updated indices
    X_train_val = X[train_val_idx]
    y_train_val = y[train_val_idx]
    groups_train_val = groups[train_val_idx]
    
    X_test = X[test_idx]
    y_test = y[test_idx]
    groups_test = groups[test_idx]

    # logging identifier splits again after potential swaps
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"AFTER SWAP - Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"AFTER SWAP - Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)
    
    # Verify the lengths are consistent
    logger(f"Length of X_train_val:\n{len(X_train_val)}", file=log_file_path)
    logger(f"Length of y_train_val:\n{len(y_train_val)}", file=log_file_path)
    logger(f"Length of groups_train_val:\n{len(groups_train_val)}", file=log_file_path)

    # Check group splits once more
    check_initial_group_split(groups_train_val, groups_test)

    # Convert the modified indices back to a DataFrame representing the updated df_train_val
    df_train_val_updated = dataframe.iloc[train_val_idx].copy()
    df_test_updated = dataframe.iloc[test_idx].copy()

    ############################
    # LOGGING AGE GROUP SPLITS #
    ############################

    # Get the distribution of age groups of age groups before the update
    training_validation_age_group_distribution = df_train_val['age_group'].value_counts()
    testing_age_group_distribution = df_test['age_group'].value_counts()
    
    # Logthe distribution
    logger(f"Train Age Group Distribution BEFORE SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution BEFORE SWAP:\n{testing_age_group_distribution}", file=log_file_path)

    # Get the distribution of age groups after the update
    training_validation_age_group_distribution = df_train_val_updated['age_group'].value_counts()
    testing_age_group_distribution = df_test_updated['age_group'].value_counts()
    
    # Log the distribution
    logger(f"Train Age Group Distribution AFTER SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution AFTER SWAP:\n{testing_age_group_distribution}", file=log_file_path)
    
    ########################################################
    # TRACKING FINAL CAT_IDs & GENDER AFTER REDISTRIBUTION #
    ########################################################

    # Get the distribution of groups
    training_validation_group_distribution = df_train_val_updated['cat_id'].value_counts()  
    testing_group_distribution = df_test_updated['cat_id'].value_counts()  

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val_updated['gender'].value_counts()
    testing_gender_distribution = df_test_updated['gender'].value_counts()
    
    logger(f"\n Starting training on unseen test set\n", file=log_file_path)

    ######################
    # ADD AUGMENTED DATA #
    ######################

    # Filter out augmented data derived from groups in the training set
    augmented_df_filtered = augmented_df[augmented_df['cat_id'].isin(groups_train_val)]
    
    # Convert augmented_df_filtered to numpy array (excluding target and other columns)
    augmented_array = augmented_df_filtered.drop(columns=['target', 'cat_id', 'age_group']).values
    
    # Concatenate the filtered augmented data with X_train_val
    X_train_val = np.concatenate([X_train_val, augmented_array])

    # Extract target labels from the filtered augmented DataFrame
    y_augmented = augmented_df_filtered['age_group'].values
    
    # Encode the labels using the same LabelEncoder instance
    y_augmented_encoded = label_encoder.transform(y_augmented)
    
    # Concatenate the encoded augmented labels with y_train_val
    y_train_val = np.concatenate([y_train_val, y_augmented_encoded])

    # Calculate the distribution of age groups in y_train_val
    age_group_distribution = Counter(y_train_val)
    print("Age group distribution:", age_group_distribution)

    # EarlyStopping callback: monitor 'loss' instead of 'val_loss' for the test set
    early_stopping = EarlyStopping(
        monitor='loss',  
        min_delta=0.001, 
        patience=30,  
        verbose=1,  
        restore_best_weights=True  
    )

    # One final shuffle to ensure randomness
    outer_shuffle_idx = np.random.permutation(len(X_train_val))
    X_train_val = X_train_val[outer_shuffle_idx]
    y_train_val = y_train_val[outer_shuffle_idx]

    class_weights = compute_class_weight(
        class_weight='balanced',
        classes=np.unique(y_train_val),
        y=y_train_val
    )
    weight_dict = {i: class_weights[i] for i in range(len(class_weights))}
    
    # Scale the features
    scaler_full = StandardScaler().fit(X_train_val)
    X_train_full_scaled = scaler_full.transform(X_train_val)
    X_test_scaled = scaler_full.transform(X_test)
    
    # Encode the labels
    y_train_full_encoded = to_categorical(y_train_val)
    y_test_encoded = to_categorical(y_test)

    #######################
    # BUILD & TRAIN MODEL #
    #######################

    optimizers = {
        'Adamax': Adamax(learning_rate=0.00038188800331973483)
    }
    
    # Full model definition with dynamic number of layers
    model_full = Sequential()
    model_full.add(Dense(480, activation='relu', input_shape=(X_train_full_scaled.shape[1],)))  # units_l0 and activation from parameters
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.27188281261238406))  
    model_full.add(Dense(3, activation='softmax'))  
    
    optimizer = optimizers['Adamax']  # optimizer_key from parameters
    
    # Compile the model
    model_full.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    
    # Train the model on the full training set
    history_full = model_full.fit(X_train_full_scaled, y_train_full_encoded, epochs=1500, batch_size=64,
                                  verbose=1, callbacks=[early_stopping], class_weight=weight_dict)
    
    # Evaluate the model on the held-out test set
    test_loss, test_accuracy = model_full.evaluate(X_test_scaled, y_test_encoded)

    y_test_pred_prob = model_full.predict(X_test_scaled)
    y_test_pred = np.argmax(y_test_pred_prob, axis=1)  
    y_test_true = np.argmax(y_test_encoded, axis=1)    

    ################################
    # LOG MAJORITY VOTE PER CAT_ID #
    ################################

    # Convert numeric predictions back to age group labels
    predicted_age_groups = label_encoder.inverse_transform(y_test_pred)
    actual_labels = label_encoder.inverse_transform(y_test_true)
    
    # Map predictions and actual labels back to cat_ids
    test_results = pd.DataFrame({
        'cat_id': df_test_updated['cat_id'],
        'predicted_age_group': predicted_age_groups,
        'actual_age_group': actual_labels
    })
    
    # Group by cat_id and aggregate predicted age groups
    majority_votes = test_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
    actual_groups = test_results.groupby('cat_id')['actual_age_group'].first()
    
    # Calculate the accuracy of majority voting
    correct_predictions = (majority_votes == actual_groups).sum()
    total_cats = len(actual_groups)
    majority_vote_accuracy = correct_predictions / total_cats
    
    # Log the accuracy of the majority voting
    logger(f"Majority Vote Accuracy for cat_id for this fold: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

    ####################################################
    # COLLECT PREDICTIONS FOR GENDER & CAT_ID ANALYSIS #
    ####################################################

    # Debugging print statements
    print(f'Before appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Extend lists with current fold results
    all_cat_ids.extend(df_test_updated['cat_id'].tolist())
    all_predicted_age_groups.extend(predicted_age_groups)
    all_actual_age_groups.extend(actual_labels)
    all_gender.extend(df_test_updated['gender'].tolist())

    # Debugging print statements
    print(f'After appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Calculate additional metrics
    test_precision = precision_score(y_test_true, y_test_pred, average='macro')  # Use 'macro' for imbalanced datasets
    test_recall = recall_score(y_test_true, y_test_pred, average='macro')
    test_f1 = f1_score(y_test_true, y_test_pred, average='macro')

    # prepare averages of outer metrics
    unseen_f1.append(test_f1)
    unseen_losses.append(test_loss)
    unseen_accuracies.append(test_accuracy)
    unseen_precisions.append(test_precision)
    unseen_recalls.append(test_recall)

    # Print final test results
    logger(f"Final Test Results - Loss: {test_loss}, Accuracy: {test_accuracy}, Precision: {test_precision}, Recall: {test_recall}, F1 Score: {test_f1}", file=log_file_path)

    # Generate the confusion matrix
    cm = confusion_matrix(y_test, y_test_pred)
    logger(f"Confusion Matrix:\n {cm}", file=log_file_path)

# Calculate the overall average metrics
unseen_set_avg_f1 = np.mean(unseen_f1)
unseen_set_avg_loss = np.mean(unseen_losses)
unseen_set_avg_acc = np.mean(unseen_accuracies)
unseen_set_avg_precision = np.mean(unseen_precisions)
unseen_set_avg_recall = np.mean(unseen_recalls)

# Append averages to total lists
all_f1.append(unseen_set_avg_f1)
all_losses.append(unseen_set_avg_loss)
all_accuracies.append(unseen_set_avg_acc)
all_precisions.append(unseen_set_avg_precision)
all_recalls.append(unseen_set_avg_recall)

logger(f"\nFinal Average F1-Score across all UNSEEN TEST sets: {unseen_set_avg_f1}", file=log_file_path)
logger(f"\nFinal Average Loss across all UNSEEN TEST sets: {unseen_set_avg_loss}", file=log_file_path)
logger(f"\nFinal Average Accuracy across all UNSEEN TEST sets: {unseen_set_avg_acc}", file=log_file_path)
logger(f"\nFinal Average Precision across all UNSEEN TEST sets: {unseen_set_avg_precision}", file=log_file_path)
logger(f"\nFinal Average Recall across all UNSEEN TEST sets: {unseen_set_avg_recall}\n", file=log_file_path)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# outer_fold 1
# Train Set Group Distribution:
# 046A    63
# 000A    39
# 103A    33
# 002B    32
# 047A    28
# 057A    27
# 020A    23
# 055A    20
# 067A    19
# 097A    16
# 101A    15
# 042A    14
# 106A    14
# 059A    14
# 028A    13
# 002A    13
# 039A    12
# 116A    12
# 063A    11
# 025A    11
# 071A    10
# 016A    10
# 040A    10
# 014B    10
# 033A     9
# 072A     9
# 015A     9
# 022A     9
# 051B     9
# 065A     9
# 095A     8
# 013B     8
# 010A     8
# 094A     8
# 027A     7
# 099A     7
# 031A     7
# 050A     7
# 108A     6
# 109A     6
# 037A     6
# 007A     6
# 008A     6
# 025C     5
# 070A     5
# 021A     5
# 034A     5
# 075A     5
# 023B     5
# 035A     4
# 009A     4
# 026A     4
# 062A     4
# 003A     4
# 012A     3
# 060A     3
# 064A     3
# 006A     3
# 113A     3
# 056A     3
# 058A     3
# 014A     3
# 011A     2
# 061A     2
# 032A     2
# 093A     2
# 025B     2
# 087A     2
# 069A     2
# 073A     1
# 115A     1
# 088A     1
# 100A     1
# 090A     1
# 024A     1
# 019B     1
# 066A     1
# 004A     1
# 048A     1
# 026C     1
# 041A     1
# 092A     1
# 049A     1
# 076A     1
# 096A     1
# 043A     1
# 026B     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 074A    25
# 000B    19
# 019A    17
# 029A    17
# 001A    14
# 097B    14
# 111A    13
# 051A    12
# 068A    11
# 036A    11
# 005A    10
# 045A     9
# 117A     7
# 053A     6
# 023A     6
# 044A     5
# 105A     4
# 052A     4
# 104A     4
# 018A     2
# 054A     2
# 038A     2
# 102A     2
# 091A     1
# 110A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    265
# M    256
# F    198
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    83
# M    81
# F    54
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [006A, 000A, 033A, 015A, 103A, 071A, 028A, 067...
# kitten    [014B, 040A, 046A, 047A, 042A, 109A, 050A, 043...
# senior    [093A, 097A, 057A, 106A, 055A, 059A, 113A, 116...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [001A, 097B, 019A, 074A, 029A, 005A, 091A, 023...
# kitten                             [044A, 111A, 045A, 110A]
# senior                             [104A, 054A, 117A, 051A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 57, 'kitten': 12, 'senior': 18}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 17, 'kitten': 4, 'senior': 4}
# Unique Training/Validation Group IDs:
# ['000A' '002A' '002B' '003A' '004A' '006A' '007A' '008A' '009A' '010A'
#  '011A' '012A' '013B' '014A' '014B' '015A' '016A' '019B' '020A' '021A'
#  '022A' '023B' '024A' '025A' '025B' '025C' '026A' '026B' '026C' '027A'
#  '028A' '031A' '032A' '033A' '034A' '035A' '037A' '039A' '040A' '041A'
#  '042A' '043A' '046A' '047A' '048A' '049A' '050A' '051B' '055A' '056A'
#  '057A' '058A' '059A' '060A' '061A' '062A' '063A' '064A' '065A' '066A'
#  '067A' '069A' '070A' '071A' '072A' '073A' '075A' '076A' '087A' '088A'
#  '090A' '092A' '093A' '094A' '095A' '096A' '097A' '099A' '100A' '101A'
#  '103A' '106A' '108A' '109A' '113A' '115A' '116A']
# Unique Test Group IDs:
# ['000B' '001A' '005A' '018A' '019A' '023A' '029A' '036A' '038A' '044A'
#  '045A' '051A' '052A' '053A' '054A' '068A' '074A' '091A' '097B' '102A'
#  '104A' '105A' '110A' '111A' '117A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '002A' '002B' '003A' '004A' '006A' '007A' '008A' '009A' '010A'
#  '011A' '012A' '013B' '014A' '014B' '015A' '016A' '019B' '020A' '021A'
#  '022A' '023B' '024A' '025A' '025B' '025C' '026A' '026B' '026C' '027A'
#  '028A' '031A' '032A' '033A' '034A' '035A' '037A' '039A' '040A' '041A'
#  '042A' '043A' '046A' '047A' '048A' '049A' '050A' '051B' '055A' '056A'
#  '057A' '058A' '059A' '060A' '061A' '062A' '063A' '064A' '065A' '066A'
#  '067A' '069A' '070A' '071A' '072A' '073A' '075A' '076A' '087A' '088A'
#  '090A' '092A' '093A' '094A' '095A' '096A' '097A' '099A' '100A' '101A'
#  '103A' '106A' '108A' '109A' '113A' '115A' '116A']
# AFTER SWAP - Unique Test Group IDs:
# ['000B' '001A' '005A' '018A' '019A' '023A' '029A' '036A' '038A' '044A'
#  '045A' '051A' '052A' '053A' '054A' '068A' '074A' '091A' '097B' '102A'
#  '104A' '105A' '110A' '111A' '117A']
# Length of X_train_val:
# 719
# Length of y_train_val:
# 719
# Length of groups_train_val:
# 719
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     423
# senior    153
# kitten    143
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     165
# kitten     28
# senior     25
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult
25)
# Before appending - Cat IDs: 0, Predictions: 0, Actuals: 0, Gender: 0
# After appending - Cat IDs: 218, Predictions: 218, Actuals: 218, Gender: 218
# Final Test Results - Loss: 1.2826462984085083, Accuracy: 0.6330274939537048, Precision: 0.6042850868937826, Recall: 0.6729725829725831, F1 Score: 0.6025473519865238
# Confusion Matrix:
#  [[100   8  57]
#  [  3  25   0]
#  [ 12   0  13]]
# outer_fold 2
# Train Set Group Distribution:
# 046A    63
# 103A    33
# 047A    28
# 057A    27
# 074A    25
# 020A    23
# 055A    20
# 067A    19
# 000B    19
# 019A    17
# 029A    17
# 097A    16
# 101A    15
# 001A    14
# 097B    14
# 059A    14
# 028A    13
# 002A    13
# 111A    13
# 051A    12
# 025A    11
# 036A    11
# 068A    11
# 005A    10
# 072A     9
# 033A     9
# 045A     9
# 022A     9
# 094A     8
# 013B     8
# 010A     8
# 031A     7
# 050A     7
# 117A     7
# 099A     7
# 027A     7
# 108A     6
# 109A     6
# 008A     6
# 023A     6
# 007A     6
# 037A     6
# 053A     6
# 044A     5
# 025C     5
# 034A     5
# 021A     5
# 035A     4
# 003A     4
# 052A     4
# 026A     4
# 104A     4
# 009A     4
# 105A     4
# 058A     3
# 064A     3
# 012A     3
# 006A     3
# 113A     3
# 056A     3
# 014A     3
# 093A     2
# 025B     2
# 038A     2
# 087A     2
# 102A     2
# 032A     2
# 054A     2
# 018A     2
# 115A     1
# 100A     1
# 090A     1
# 024A     1
# 110A     1
# 073A     1
# 066A     1
# 091A     1
# 088A     1
# 048A     1
# 026C     1
# 041A     1
# 049A     1
# 096A     1
# 026B     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 000A    39
# 002B    32
# 042A    14
# 106A    14
# 116A    12
# 039A    12
# 063A    11
# 040A    10
# 016A    10
# 071A    10
# 014B    10
# 065A     9
# 015A     9
# 051B     9
# 095A     8
# 070A     5
# 075A     5
# 023B     5
# 062A     4
# 060A     3
# 011A     2
# 069A     2
# 061A     2
# 043A     1
# 092A     1
# 076A     1
# 004A     1
# 019B     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    273
# M    241
# F    181
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# M    96
# X    75
# F    71
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [006A, 033A, 001A, 103A, 097B, 028A, 019A, 074...
# kitten    [044A, 111A, 046A, 047A, 109A, 050A, 049A, 041...
# senior    [093A, 097A, 057A, 104A, 055A, 059A, 113A, 054...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [000A, 015A, 071A, 062A, 002B, 095A, 065A, 039...
# kitten                             [014B, 040A, 042A, 043A]
# senior                 [106A, 116A, 051B, 016A, 011A, 061A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 56, 'kitten': 12, 'senior': 16}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 18, 'kitten': 4, 'senior': 6}
# Unique Training/Validation Group IDs:
# ['000B' '001A' '002A' '003A' '005A' '006A' '007A' '008A' '009A' '010A'
#  '012A' '013B' '014A' '018A' '019A' '020A' '021A' '022A' '023A' '024A'
#  '025A' '025B' '025C' '026A' '026B' '026C' '027A' '028A' '029A' '031A'
#  '032A' '033A' '034A' '035A' '036A' '037A' '038A' '041A' '044A' '045A'
#  '046A' '047A' '048A' '049A' '050A' '051A' '052A' '053A' '054A' '055A'
#  '056A' '057A' '058A' '059A' '064A' '066A' '067A' '068A' '072A' '073A'
#  '074A' '087A' '088A' '090A' '091A' '093A' '094A' '096A' '097A' '097B'
#  '099A' '100A' '101A' '102A' '103A' '104A' '105A' '108A' '109A' '110A'
#  '111A' '113A' '115A' '117A']
# Unique Test Group IDs:
# ['000A' '002B' '004A' '011A' '014B' '015A' '016A' '019B' '023B' '039A'
#  '040A' '042A' '043A' '051B' '060A' '061A' '062A' '063A' '065A' '069A'
#  '070A' '071A' '075A' '076A' '092A' '095A' '106A' '116A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'000A'}
# Removed from Training/Validation Set:
# {'025B'}
# Moved to Test Set:
# {'025B'}
# Removed from Test Set
# {'000A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '003A' '005A' '006A' '007A' '008A' '009A'
#  '010A' '012A' '013B' '014A' '018A' '019A' '020A' '021A' '022A' '023A'
#  '024A' '025A' '025C' '026A' '026B' '026C' '027A' '028A' '029A' '031A'
#  '032A' '033A' '034A' '035A' '036A' '037A' '038A' '041A' '044A' '045A'
#  '046A' '047A' '048A' '049A' '050A' '051A' '052A' '053A' '054A' '055A'
#  '056A' '057A' '058A' '059A' '064A' '066A' '067A' '068A' '072A' '073A'
#  '074A' '087A' '088A' '090A' '091A' '093A' '094A' '096A' '097A' '097B'
#  '099A' '100A' '101A' '102A' '103A' '104A' '105A' '108A' '109A' '110A'
#  '111A' '113A' '115A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['002B' '004A' '011A' '014B' '015A' '016A' '019B' '023B' '025B' '039A'
#  '040A' '042A' '043A' '051B' '060A' '061A' '062A' '063A' '065A' '069A'
#  '070A' '071A' '075A' '076A' '092A' '095A' '106A' '116A']
# Length of X_train_val:
# 732
# Length of y_train_val:
# 732
# Length of groups_train_val:
# 732
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     430
# kitten    136
# senior    129
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     158
# senior     49
# kitten     35
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     467
# kitten    136
# senior    129
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     121
# senior     49
# kitten     35
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 934, 1: 544, 2: 516})
# Epoch 1/1500
# 32/32 [==============================] - 0s 2ms/step - loss: 1.0116 - accuracy: 0.5512
# Epoch 2/1500
# 32/32 [==============================] - 0s 3ms/step - loss: 0.7447 - accuracy: 0.6595
# Epoch 3/1500
# 32/32 [==============================] - 0s 2ms/step - loss: 0.6563 - accuracy: 0.7001
# Epoch 4/1500
# 32/32 [==============================] - 0s 2ms/step - loss: 0.6426 - accuracy: 0.7091
# Epoch 5/1500
# 32/32 [==============================] - 0s 2ms/step - loss: 0.5820 - accuracy: 0.7372
# Epoch 6/1500
# 32/32 [==============================] - 0s 3ms/step - loss: 0.5831 - accuracy: 0.7337
# Epoch 7/1500
# 32/32 [==============================] - 0s 2ms/step - loss: 0.5582 - accuracy: 0.7508
# Epoch 8/1500
# 32/32 [==============================] - 0s 2ms/step - loss: 0.5407 - accuracy: 0.7648
# Epoch 9/1500
# 32/32 [==============================] - 0s 2ms/step - loss: 0.5056 - accuracy: 0.7708
# Epoch 10/1500
# 32/32 [==============================] - 0s 2ms/step - loss: 0.4837 - accuracy: 0.7748
# Epoch 11/1500
# 32/32 [==============================] - 0s 3ms/step - loss: 0.4827 - accuracy: 0.7738
# Epoch 12/1500
# 32/32 [==============================] - 0s 2ms/step - loss: 0.4990 - accuracy: 0.7874
# Epoch 13/1500
# 32/32 [==============================] - 0s 2ms/step - loss: 0.4816 - accuracy: 0.7944
# Epoch 14/1500
# 32/32 [==============================] - 0s 2ms/step - loss: 0.4530 - accuracy: 0.7874
# Epoch 15/1500
# 32/32 [==============================] - 0s 3ms/step - loss: 0.4406 - accuracy: 0.8069
# Epoch 16/1500
# 32/32 [==============================] - 0s 2ms/step - loss: 0.4370 - accuracy: 0.8014
# Epoch 17/1500
# 32/32 [==============================] - 0s 2ms/step - loss: 0.4229 - accuracy: 0.8124
# Epoch 18/1500
# 32/32 [==============================] - 0s 2ms/step - loss: 0.4065 - accuracy: 0.8250
# Epoch 19/1500
# 32/32 [==============================] - 0s 2ms/step - loss: 0.4124 - accuracy: 0.8285
# Epoch 20/1500
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3991 - accuracy: 0.8170
# Epoch 21/1500
# 32/32 [==============================] - 0s 2ms/step - loss: 0.4004 - accuracy: 0.8280
# Epoch 22/1500
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3829 - accuracy: 0.8320
# Epoch 23/1500
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3900 - accuracy: 0.8205
# Epoch 24/1500
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3720 - accuracy: 0.8375
# Epoch 25/1500
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3646 - accuracy: 0.8410
# Epoch 26/1500
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3612 - accuracy: 0.8430
# Epoch 27/1500
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3563 - accuracy: 0.8390
# Epoch 28/1500
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3517 - accuracy: 0.8531
# Epoch 29/1500
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3387 - accuracy: 0.8521
# Epoch 30/1500
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3223 - accuracy: 0.8661
# Epoch 31/1500
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3292 - accuracy: 0.8490
# Epoch 32/1500
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3416 - accuracy: 0.8536
# Epoch 33/1500
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3310 - accuracy: 0.8591
# Epoch 34/1500
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3228 - accuracy: 0.8490
# Epoch 35/1500
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3357 - accuracy: 0.8506
# Epoch 36/1500
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3145 - accuracy: 0.8536
# Epoch 37/1500
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3091 - accuracy: 0.8716
# Epoch 38/1500
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3305 - accuracy: 0.8475
# Epoch 39/1500
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3152 - accuracy: 0.8616
# Epoch 40/1500
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2976 - accuracy: 0.8736
# Epoch 41/1500
# 32/32 [==============================] - 0s 5ms/step - loss: 0.2955 - accuracy: 0.8716
# Epoch 42/1500
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2981 - accuracy: 0.8631
# Epoch 43/1500
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2929 - accuracy: 0.8676
# Epoch 44/1500
# 32/32 [==============================] - 0s 2ms/step - loss: 0.
1500
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0718 - accuracy: 0.9739
# Epoch 244/1500
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0756 - accuracy: 0.9718
# Epoch 245/1500
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0744 - accuracy: 0.9734
# Epoch 246/1500
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0587 - accuracy: 0.9807
# Epoch 247/1500
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0691 - accuracy: 0.9770
# Epoch 248/1500
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0698 - accuracy: 0.9760
# Epoch 249/1500
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0774 - accuracy: 0.9702
# Epoch 250/1500
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0702 - accuracy: 0.9734
# Epoch 251/1500
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0654 - accuracy: 0.9754
# Epoch 252/1500
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0650 - accuracy: 0.9754
# Epoch 253/1500
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0887 - accuracy: 0.9666
# Epoch 254/1500
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0624 - accuracy: 0.9739
# Epoch 255/1500
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0693 - accuracy: 0.9765
# Epoch 256/1500
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0741 - accuracy: 0.9728
# Epoch 257/1500
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0804 - accuracy: 0.9697
# Epoch 258/1500
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0640 - accuracy: 0.9786
# Epoch 259/1500
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0662 - accuracy: 0.9786
# Epoch 260/1500
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0638 - accuracy: 0.9770
# Epoch 261/1500
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0693 - accuracy: 0.9749
# Epoch 262/1500
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0763 - accuracy: 0.9707
# Epoch 263/1500
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0613 - accuracy: 0.9770
# Epoch 264/1500
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0659 - accuracy: 0.9770
# Epoch 265/1500
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0756 - accuracy: 0.9734
# Epoch 266/1500
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0813 - accuracy: 0.9692
# Epoch 267/1500
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0727 - accuracy: 0.9707
# Epoch 268/1500
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0744 - accuracy: 0.9713
# Epoch 269/1500
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0747 - accuracy: 0.9697
# Epoch 270/1500
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0706 - accuracy: 0.9749
# Epoch 271/1500
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0745 - accuracy: 0.9707
# Epoch 272/1500
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0647 - accuracy: 0.9723
# Epoch 273/1500
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0658 - accuracy: 0.9749
# Epoch 274/1500
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0724 - accuracy: 0.9702
# Epoch 275/1500
# 30/30 [==============================] - 0s 3ms/step - loss: 0.0711 - accuracy: 0.9781
# Epoch 276/1500
#  1/30 [>.............................] - ETA: 0s - loss: 0.1054 - accuracy: 0.9531Restoring model weights from the end of the best epoch: 246.
# 30/30 [==============================] - 0s 2ms/step - loss: 0.0718 - accuracy: 0.9718
# Epoch 276: early stopping
# 8/8 [==============================] - 0s 988us/step - loss: 1.0030 - accuracy: 0.6723
# 8/8 [==============================] - 0s 754us/step
# Majority Vote Accuracy for cat_id for this fold: 0.76 (22/29)
# Before appending - Cat IDs: 604, Predictions: 604, Actuals: 604, Gender: 604
# After appending - Cat IDs: 842, Predictions: 842, Actuals: 842, Gender: 842
# Final Test Results - Loss: 1.0030077695846558, Accuracy: 0.6722689270973206, Precision: 0.6920506812462032, Recall: 0.6463278674465708, F1 Score: 0.664111032476213
# Confusion Matrix:
#  [[118   0  29]
#  [  4  25   0]
#  [ 45   0  17]]
#
# Final Average F1-Score across all UNSEEN TEST sets: 0.6643043610462034
#
# Final Average Loss across all UNSEEN TEST sets: 0.9642886817455292
#
# Final Average Accuracy across all UNSEEN TEST sets: 0.6977430433034897
#
# Final Average Precision across all UNSEEN TEST sets: 0.6898941441310351
#
# Final Average Recall across all UNSEEN TEST sets: 0.6685802546672166

# %%
seed_3_folds_values = (unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1)

# Plotting all fold metrics
seed_3_folds_plot = plot_all_metrics(unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1, "Folds", "Fold Number")

# %% [markdown]
# ## Majority Voting on Total Entries per cat_id

# %%
# Debugging print statements
print(f'Checking - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
# Out:
# Checking - Cat IDs: 842, Predictions: 842, Actuals: 842, Gender: 842

# %%
# Create results df
full_results = pd.DataFrame({
    'cat_id': all_cat_ids,
    'predicted_age_group': all_predicted_age_groups,
    'actual_age_group': all_actual_age_groups,
    'all_gender': all_gender
})

# create a correct majority prediction column
full_results['correct'] = full_results['predicted_age_group'] == full_results['actual_age_group']

# %%
# Group by cat_id and aggregate predicted age groups
majority_votes = full_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first()

# Calculate the accuracy of majority voting
correct_predictions = (majority_votes == actual_groups).sum()
total_cats = len(actual_groups)
majority_vote_accuracy = correct_predictions / total_cats

logger(f"Overall Majority Vote Accuracy for cat_id: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

# store for final evaluation 
all_majority_vote_accuracies.append(majority_vote_accuracy)
# Out:
# Overall Majority Vote Accuracy for cat_id: 0.73 (80/110)

# %%
# Detailed df with predictions, actual labels, and comparison including majority vote
detailed_results = full_results.groupby('cat_id').apply(
    lambda x: pd.Series({
        'Predictions': list(x['predicted_age_group']),
        'Majority Vote': x['predicted_age_group'].mode()[0],
        'Actual Age Group': x['actual_age_group'].iloc[0],
        'Correct Majority Vote': x['predicted_age_group'].mode()[0] == x['actual_age_group'].iloc[0]
    })
).reset_index()

# Convert to DataFrame for better formatting and display
detailed_results = pd.DataFrame(detailed_results)

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 10)
pd.set_option('display.width', 1000)

sorted_detailed_results = detailed_results.sort_values(by='Correct Majority Vote', ascending=False)

# Display the sorted DataFrame
sorted_detailed_results
# Out:
#     cat_id                                        Predictions Majority Vote Actual Age Group  Correct Majority Vote
# 0     000B  [adult, adult, kitten, senior, adult, senior, ...         adult            adult                   True
# 82    076A                                            [adult]         adult            adult                   True
# 80    074A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 79    073A                                            [adult]         adult            adult                   True
# 78    072A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 77    071A  [adult, senior, adult, adult, adult, adult, ad...         adult            adult                   True
# 76    070A               [adult, adult, adult, adult, senior]         adult            adult                   True
# 75    069A                                     [adult, adult]         adult            adult                   True
# 73    067A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 72    066A                                            [adult]         adult            adult                   True
# 71    065A  [senior, adult, adult, adult, adult, senior, a...         adult            adult                   True
# 70    064A                              [adult, adult, adult]         adult            adult                   True
# 68    062A                       [adult, adult, adult, adult]         adult            adult                   True
# 59    053A       [adult, adult, senior, senior, adult, adult]         adult            adult                   True
# 56    051A  [senior, adult, adult, adult, senior, senior, ...        senior           senior                   True
# 1     001A  [adult, adult, senior, adult, adult, senior, a...         adult            adult                   True
# 54    049A                                           [kitten]        kitten           kitten                   True
# 52    047A  [adult, kitten, kitten, kitten, kitten, kitten...        kitten           kitten                   True
# 51    045A  [adult, kitten, kitten, kitten, kitten, kitten...        kitten           kitten                   True
# 49    043A                                           [kitten]        kitten           kitten                   True
# 48    042A  [kitten, kitten, kitten, kitten, kitten, kitte...        kitten           kitten                   True
# 81    075A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 83    087A                                     [adult, adult]         adult            adult                   True
# 46    040A  [kitten, kitten, kitten, kitten, kitten, kitte...        kitten           kitten                   True
# 84    088A                                            [adult]         adult            adult                   True
# 108   116A  [senior, senior, senior, senior, adult, senior...        senior           senior                   True
# 107   115A                                           [kitten]        kitten           kitten                   True
# 106   113A                           [senior, senior, senior]        senior           senior                   True
# 105   111A  [kitten, kitten, kitten, kitten, kitten, kitte...        kitten           kitten                   True
# 104   110A                                           [kitten]        kitten           kitten                   True
#
# %%
# Plot for Detailed Class Statistics (Overall)
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Overall Accuracy by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Gender Exploration

# %%
# Group by gender and calculate the total count, correct predictions, and accuracy
gender_stats = full_results.groupby('all_gender').agg(
    count=('cat_id', 'size'),  # Total number of cases per gender
    correct=('correct', 'sum')  # Sum of correct predictions per gender
).reset_index()

# Calculate accuracy for each gender
gender_stats['accuracy'] = (gender_stats['correct'] / gender_stats['count'] * 100).round(2)

# Display the DataFrame
print("Accuracy by Gender:")
print(gender_stats)

# store for final evaluation 
all_gender_stats.append(gender_stats)
# Out:
# Accuracy by Gender:
#   all_gender  count  correct  accuracy
# 0          F    215      147     68.37
# 1          M    337      236     70.03
# 2          X    290      201     69.31

# %%
# Plot for Accuracy by Gender
styled_barplot(gender_stats, 'all_gender', 'accuracy', 
               'Accuracy by Gender', 
               'Gender', 'Accuracy (%)')

# %% [markdown]
# ### Log current total CV Stats

# %%
print("Total Majority Vote Accuracy so far:", all_majority_vote_accuracies)
print("Total Class Statistics so far:\n", all_class_stats)
print("Total Gender Accuracy so far:\n", all_gender_stats)
# Out:
# Total Majority Vote Accuracy so far: [0.7363636363636363, 0.7454545454545455, 0.7272727272727273]
# Total Class Statistics so far:
#  [  actual_age_group  total_count  correct_count   accuracy
# 0            adult          572            437  76.398601
# 1           kitten          109             96  88.073394
# 2           senior          178            107  60.112360,   actual_age_group  total_count  correct_count   accuracy
# 0            adult          554            429  77.436823
# 1           kitten          113             90  79.646018
# 2           senior          178             93  52.247191,   actual_age_group  total_count  correct_count   accuracy
# 0            adult          551            419  76.043557
# 1           kitten          113             94  83.185841
# 2           senior          178             71  39.887640]
# Total Gender Accuracy so far:
#  [  all_gender  count  correct  accuracy
# 0          F    213      174     81.69
# 1          M    360      250     69.44
# 2          X    286      216     75.52,   all_gender  count  correct  accuracy
# 0          F    213      155     72.77
# 1          M    342      256     74.85
# 2          X    290      201     69.31,   all_gender  count  correct  accuracy
# 0          F    215      147     68.37
# 1          M    337      236     70.03
# 2          X    290      201     69.31]

# %% [markdown]
# # RANDOM SEED 4

# %%
# Set a fixed random seed for reproducibility
random.seed(int(random_seeds[3])) 
np.random.seed(int(random_seeds[3]))
tf.random.set_seed(int(random_seeds[3]))

# Load datasets
dataframe = pd.read_csv('/Users/astrid/PycharmProjects/audioset-thesis-work/audioset/vggish/embeddings/8april_looped_embeddings.csv')
augmented_df = pd.read_csv('/Users/astrid/PycharmProjects/audioset-thesis-work/audioset/vggish/embeddings/augmented_dataset_19.csv')

dataframe.drop('mean_freq', axis=1, inplace=True)

augmented_df.drop('gender', axis=1, inplace=True)

def assign_age_group(age, age_groups):
    for group_name, age_range in age_groups.items():
        if age_range[0] <= age < age_range[1]:
            return group_name
    return 'Unknown'  # For any age that doesn't fit the defined groups

# Define age groups
age_groups = {
    'kitten': (0, 0.5),
    'adult': (0.5, 12),
    'senior': (12, 20)
}

# Create a new column for the age group
dataframe['age_group'] = dataframe['target'].apply(assign_age_group, age_groups=age_groups)
augmented_df['age_group'] = augmented_df['target'].apply(assign_age_group, age_groups=age_groups)

print(dataframe['age_group'].value_counts())
print(augmented_df['age_group'].value_counts())
# Out:
# adult     588
# senior    178
# kitten    171
# Name: age_group, dtype: int64
# adult     588
# senior    534
# kitten    513
# Name: age_group, dtype: int64

# %%
# Separate features and labels
X = dataframe.iloc[:, :-4].values  # all columns except the last four

# Encode the 'age_group' column as integers using LabelEncoder
label_encoder = LabelEncoder()
encoded_y = label_encoder.fit_transform(dataframe['age_group'].values)

# Use the encoded labels for splitting and one-hot encoding
y = encoded_y  

# Convert 'cat_id' column to numpy array to be used as groups array for GroupKFold
groups = dataframe['cat_id'].values

# %%
tf.keras.backend.clear_session()

# %% [markdown]
# ## Run Setup

# %%
all_cat_ids = []
all_predicted_age_groups = []
all_actual_age_groups = []
all_gender = []

# Define the StratifiedGroupKFold splitter for 4 fold CV with random shuffling
outer_cv = StratifiedGroupKFold(n_splits=4, shuffle=True, random_state=int(random_seeds[3]))

# unseen test set metrics
unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1 = [], [], [], [], []

outer_fold = 0

# Use the splitter to generate indices for training and testing sets
# Note: GroupShuffleSplit.split returns indices, so we use it to index the arrays
for train_val_idx, test_idx in outer_cv.split(X, y, groups):
    outer_fold += 1
    logger(f"outer_fold {outer_fold}", file=log_file_path)

    # Convert indices back to DataFrame for easy manipulation
    df_train_val = dataframe.iloc[train_val_idx]
    df_test = dataframe.iloc[test_idx]

    ##############################
    # ASSESSING SPLITS BY CAT_ID #
    ##############################
    
    # Get the distribution of groups
    training_validation_group_distribution = df_train_val['cat_id'].value_counts()  
    testing_group_distribution = df_test['cat_id'].value_counts()  
    
    # Log or print the distribution
    logger(f"Train Set Group Distribution:\n{training_validation_group_distribution}", file=log_file_path)
    logger(f"Testing Set Group Distribution:\n{testing_group_distribution}", file=log_file_path)

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val['gender'].value_counts()
    testing_gender_distribution = df_test['gender'].value_counts()
    
    # Log the distribution
    logger(f"Training Set Gender Distribution BEFORE SWAP:\n{training_gender_distribution}", file=log_file_path)
    logger(f"Testing Set Gender Distribution BEFORE SWAP:\n{testing_gender_distribution}", file=log_file_path)

    # Group by 'age_group' and then list unique 'cat_id' within each age group
    unique_cat_ids_per_age_group_train_val = df_train_val.groupby('age_group')['cat_id'].unique()
    unique_cat_ids_per_age_group_test = df_test.groupby('age_group')['cat_id'].unique()
    
    # Log results
    logger(f"Unique Cat IDs per Age Group in Training/Validation Set:\n{unique_cat_ids_per_age_group_train_val}", file=log_file_path)
    logger(f"Unique Cat IDs per Age Group in Testing Set:\n{unique_cat_ids_per_age_group_test}", file=log_file_path)

    # Calculate the count of unique identifiers per age group for training and testing set
    counts_train_val = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_train_val.items()}
    counts_test = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_test.items()}

    # Log the counts of unique identifiers per age group
    logger(f"Count of Unique Cat IDs per Age Group in Training/Validation Set:\n{counts_train_val}", file=log_file_path)
    logger(f"Count of Unique Cat IDs per Age Group in Testing Set:\n{counts_test}", file=log_file_path)

    #######################################################
    # CONTINUE WITH ENSURING VALID AND APPROPRIATE SPLITS #
    #######################################################
    
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    groups_train_val, groups_test = groups[train_val_idx], groups[test_idx]

    # logging identifier splits 
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)

    # check group splits
    check_initial_group_split(groups_train_val, groups_test)

    # Specify the cat_ids that must be in the training/validation set
    specific_cat_ids = ['000A', '046A']
    
    # Perform the swapping operation
    train_val_idx, test_idx = swap_cat_id_instances(dataframe, train_val_idx, test_idx, specific_cat_ids)
    
    # Re-assign the sets based on the updated indices
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    new_groups_train_val, new_groups_test = groups[train_val_idx], groups[test_idx]

    # Find differences for training and test sets
    moved_to_train_val, removed_from_train_val = find_group_differences(groups_train_val, new_groups_train_val)
    moved_to_test, removed_from_test = find_group_differences(groups_test, new_groups_test)
    
    # Display the results
    logger(f"Moved to Training/Validation Set:\n{moved_to_train_val}", file=log_file_path)
    logger(f"Removed from Training/Validation Set:\n{removed_from_train_val}", file=log_file_path)
    logger(f"Moved to Test Set:\n{moved_to_test}", file=log_file_path)
    logger(f"Removed from Test Set\n{removed_from_test}", file=log_file_path)

    # Update X_train_val, X_test, y_train_val, y_test, groups_train_val, groups_test based on updated indices
    X_train_val = X[train_val_idx]
    y_train_val = y[train_val_idx]
    groups_train_val = groups[train_val_idx]
    
    X_test = X[test_idx]
    y_test = y[test_idx]
    groups_test = groups[test_idx]

    # logging identifier splits again after potential swaps
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"AFTER SWAP - Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"AFTER SWAP - Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)
    
    # Verify the lengths are consistent
    logger(f"Length of X_train_val:\n{len(X_train_val)}", file=log_file_path)
    logger(f"Length of y_train_val:\n{len(y_train_val)}", file=log_file_path)
    logger(f"Length of groups_train_val:\n{len(groups_train_val)}", file=log_file_path)

    # Check group splits once more
    check_initial_group_split(groups_train_val, groups_test)

    # Convert the modified indices back to a DataFrame representing the updated df_train_val
    df_train_val_updated = dataframe.iloc[train_val_idx].copy()
    df_test_updated = dataframe.iloc[test_idx].copy()

    ############################
    # LOGGING AGE GROUP SPLITS #
    ############################

    # Get the distribution of age groups of age groups before the update
    training_validation_age_group_distribution = df_train_val['age_group'].value_counts()
    testing_age_group_distribution = df_test['age_group'].value_counts()
    
    # Logthe distribution
    logger(f"Train Age Group Distribution BEFORE SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution BEFORE SWAP:\n{testing_age_group_distribution}", file=log_file_path)

    # Get the distribution of age groups after the update
    training_validation_age_group_distribution = df_train_val_updated['age_group'].value_counts()
    testing_age_group_distribution = df_test_updated['age_group'].value_counts()
    
    # Log the distribution
    logger(f"Train Age Group Distribution AFTER SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution AFTER SWAP:\n{testing_age_group_distribution}", file=log_file_path)
    
    ########################################################
    # TRACKING FINAL CAT_IDs & GENDER AFTER REDISTRIBUTION #
    ########################################################

    # Get the distribution of groups
    training_validation_group_distribution = df_train_val_updated['cat_id'].value_counts()  
    testing_group_distribution = df_test_updated['cat_id'].value_counts()  

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val_updated['gender'].value_counts()
    testing_gender_distribution = df_test_updated['gender'].value_counts()
    
    logger(f"\n Starting training on unseen test set\n", file=log_file_path)

    ######################
    # ADD AUGMENTED DATA #
    ######################

    # Filter out augmented data derived from groups in the training set
    augmented_df_filtered = augmented_df[augmented_df['cat_id'].isin(groups_train_val)]
    
    # Convert augmented_df_filtered to numpy array (excluding target and other columns)
    augmented_array = augmented_df_filtered.drop(columns=['target', 'cat_id', 'age_group']).values
    
    # Concatenate the filtered augmented data with X_train_val
    X_train_val = np.concatenate([X_train_val, augmented_array])

    # Extract target labels from the filtered augmented DataFrame
    y_augmented = augmented_df_filtered['age_group'].values
    
    # Encode the labels using the same LabelEncoder instance
    y_augmented_encoded = label_encoder.transform(y_augmented)
    
    # Concatenate the encoded augmented labels with y_train_val
    y_train_val = np.concatenate([y_train_val, y_augmented_encoded])

    # Calculate the distribution of age groups in y_train_val
    age_group_distribution = Counter(y_train_val)
    print("Age group distribution:", age_group_distribution)

    # EarlyStopping callback: monitor 'loss' instead of 'val_loss' for the test set
    early_stopping = EarlyStopping(
        monitor='loss',  
        min_delta=0.001, 
        patience=30,  
        verbose=1,  
        restore_best_weights=True  
    )

    # One final shuffle to ensure randomness
    outer_shuffle_idx = np.random.permutation(len(X_train_val))
    X_train_val = X_train_val[outer_shuffle_idx]
    y_train_val = y_train_val[outer_shuffle_idx]

    class_weights = compute_class_weight(
        class_weight='balanced',
        classes=np.unique(y_train_val),
        y=y_train_val
    )
    weight_dict = {i: class_weights[i] for i in range(len(class_weights))}
    
    # Scale the features
    scaler_full = StandardScaler().fit(X_train_val)
    X_train_full_scaled = scaler_full.transform(X_train_val)
    X_test_scaled = scaler_full.transform(X_test)
    
    # Encode the labels
    y_train_full_encoded = to_categorical(y_train_val)
    y_test_encoded = to_categorical(y_test)

    #######################
    # BUILD & TRAIN MODEL #
    #######################

    optimizers = {
        'Adamax': Adamax(learning_rate=0.00038188800331973483)
    }
    
    # Full model definition with dynamic number of layers
    model_full = Sequential()
    model_full.add(Dense(480, activation='relu', input_shape=(X_train_full_scaled.shape[1],)))  # units_l0 and activation from parameters
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.27188281261238406))  
    model_full.add(Dense(3, activation='softmax'))  
    
    optimizer = optimizers['Adamax']  # optimizer_key from parameters
    
    # Compile the model
    model_full.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    
    # Train the model on the full training set
    history_full = model_full.fit(X_train_full_scaled, y_train_full_encoded, epochs=1500, batch_size=64,
                                  verbose=1, callbacks=[early_stopping], class_weight=weight_dict)
    
    # Evaluate the model on the held-out test set
    test_loss, test_accuracy = model_full.evaluate(X_test_scaled, y_test_encoded)

    y_test_pred_prob = model_full.predict(X_test_scaled)
    y_test_pred = np.argmax(y_test_pred_prob, axis=1)  
    y_test_true = np.argmax(y_test_encoded, axis=1)    

    ################################
    # LOG MAJORITY VOTE PER CAT_ID #
    ################################

    # Convert numeric predictions back to age group labels
    predicted_age_groups = label_encoder.inverse_transform(y_test_pred)
    actual_labels = label_encoder.inverse_transform(y_test_true)
    
    # Map predictions and actual labels back to cat_ids
    test_results = pd.DataFrame({
        'cat_id': df_test_updated['cat_id'],
        'predicted_age_group': predicted_age_groups,
        'actual_age_group': actual_labels
    })
    
    # Group by cat_id and aggregate predicted age groups
    majority_votes = test_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
    actual_groups = test_results.groupby('cat_id')['actual_age_group'].first()
    
    # Calculate the accuracy of majority voting
    correct_predictions = (majority_votes == actual_groups).sum()
    total_cats = len(actual_groups)
    majority_vote_accuracy = correct_predictions / total_cats
    
    # Log the accuracy of the majority voting
    logger(f"Majority Vote Accuracy for cat_id for this fold: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

    ####################################################
    # COLLECT PREDICTIONS FOR GENDER & CAT_ID ANALYSIS #
    ####################################################

    # Debugging print statements
    print(f'Before appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Extend lists with current fold results
    all_cat_ids.extend(df_test_updated['cat_id'].tolist())
    all_predicted_age_groups.extend(predicted_age_groups)
    all_actual_age_groups.extend(actual_labels)
    all_gender.extend(df_test_updated['gender'].tolist())

    # Debugging print statements
    print(f'After appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Calculate additional metrics
    test_precision = precision_score(y_test_true, y_test_pred, average='macro')  # Use 'macro' for imbalanced datasets
    test_recall = recall_score(y_test_true, y_test_pred, average='macro')
    test_f1 = f1_score(y_test_true, y_test_pred, average='macro')

    # prepare averages of outer metrics
    unseen_f1.append(test_f1)
    unseen_losses.append(test_loss)
    unseen_accuracies.append(test_accuracy)
    unseen_precisions.append(test_precision)
    unseen_recalls.append(test_recall)

    # Print final test results
    logger(f"Final Test Results - Loss: {test_loss}, Accuracy: {test_accuracy}, Precision: {test_precision}, Recall: {test_recall}, F1 Score: {test_f1}", file=log_file_path)

    # Generate the confusion matrix
    cm = confusion_matrix(y_test, y_test_pred)
    logger(f"Confusion Matrix:\n {cm}", file=log_file_path)

# Calculate the overall average metrics
unseen_set_avg_f1 = np.mean(unseen_f1)
unseen_set_avg_loss = np.mean(unseen_losses)
unseen_set_avg_acc = np.mean(unseen_accuracies)
unseen_set_avg_precision = np.mean(unseen_precisions)
unseen_set_avg_recall = np.mean(unseen_recalls)

# Append averages to total lists
all_f1.append(unseen_set_avg_f1)
all_losses.append(unseen_set_avg_loss)
all_accuracies.append(unseen_set_avg_acc)
all_precisions.append(unseen_set_avg_precision)
all_recalls.append(unseen_set_avg_recall)

logger(f"\nFinal Average F1-Score across all UNSEEN TEST sets: {unseen_set_avg_f1}", file=log_file_path)
logger(f"\nFinal Average Loss across all UNSEEN TEST sets: {unseen_set_avg_loss}", file=log_file_path)
logger(f"\nFinal Average Accuracy across all UNSEEN TEST sets: {unseen_set_avg_acc}", file=log_file_path)
logger(f"\nFinal Average Precision across all UNSEEN TEST sets: {unseen_set_avg_precision}", file=log_file_path)
logger(f"\nFinal Average Recall across all UNSEEN TEST sets: {unseen_set_avg_recall}\n", file=log_file_path)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# outer_fold 1
# Train Set Group Distribution:
# 046A    63
# 000A    39
# 103A    33
# 002B    32
# 047A    28
# 057A    27
# 074A    25
# 020A    23
# 055A    20
# 067A    19
# 000B    19
# 029A    17
# 097A    16
# 059A    14
# 042A    14
# 001A    14
# 097B    14
# 106A    14
# 111A    13
# 028A    13
# 002A    13
# 051A    12
# 116A    12
# 036A    11
# 068A    11
# 025A    11
# 014B    10
# 016A    10
# 040A    10
# 072A     9
# 015A     9
# 051B     9
# 022A     9
# 033A     9
# 045A     9
# 095A     8
# 013B     8
# 117A     7
# 031A     7
# 027A     7
# 007A     6
# 108A     6
# 053A     6
# 109A     6
# 023A     6
# 037A     6
# 075A     5
# 070A     5
# 025C     5
# 021A     5
# 034A     5
# 044A     5
# 023B     5
# 003A     4
# 105A     4
# 035A     4
# 026A     4
# 052A     4
# 062A     4
# 012A     3
# 113A     3
# 058A     3
# 060A     3
# 064A     3
# 006A     3
# 025B     2
# 032A     2
# 093A     2
# 054A     2
# 069A     2
# 087A     2
# 038A     2
# 073A     1
# 004A     1
# 090A     1
# 110A     1
# 115A     1
# 091A     1
# 019B     1
# 066A     1
# 048A     1
# 092A     1
# 026C     1
# 076A     1
# 043A     1
# 041A     1
# 024A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 019A    17
# 101A    15
# 039A    12
# 063A    11
# 071A    10
# 005A    10
# 065A     9
# 010A     8
# 094A     8
# 050A     7
# 099A     7
# 008A     6
# 009A     4
# 104A     4
# 014A     3
# 056A     3
# 018A     2
# 011A     2
# 061A     2
# 102A     2
# 096A     1
# 049A     1
# 088A     1
# 100A     1
# 026B     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    296
# X    286
# F    208
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    62
# F    44
# M    41
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [006A, 000A, 033A, 015A, 001A, 103A, 097B, 028...
# kitten    [044A, 014B, 111A, 040A, 046A, 047A, 042A, 109...
# senior    [093A, 097A, 057A, 106A, 055A, 059A, 113A, 116...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [071A, 019A, 101A, 005A, 065A, 039A, 009A, 063...
# kitten                                         [050A, 049A]
# senior                       [104A, 056A, 094A, 011A, 061A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 56, 'kitten': 14, 'senior': 17}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 18, 'kitten': 2, 'senior': 5}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '004A' '006A' '007A' '012A'
#  '013B' '014B' '015A' '016A' '019B' '020A' '021A' '022A' '023A' '023B'
#  '024A' '025A' '025B' '025C' '026A' '026C' '027A' '028A' '029A' '031A'
#  '032A' '033A' '034A' '035A' '036A' '037A' '038A' '040A' '041A' '042A'
#  '043A' '044A' '045A' '046A' '047A' '048A' '051A' '051B' '052A' '053A'
#  '054A' '055A' '057A' '058A' '059A' '060A' '062A' '064A' '066A' '067A'
#  '068A' '069A' '070A' '072A' '073A' '074A' '075A' '076A' '087A' '090A'
#  '091A' '092A' '093A' '095A' '097A' '097B' '103A' '105A' '106A' '108A'
#  '109A' '110A' '111A' '113A' '115A' '116A' '117A']
# Unique Test Group IDs:
# ['005A' '008A' '009A' '010A' '011A' '014A' '018A' '019A' '026B' '039A'
#  '049A' '050A' '056A' '061A' '063A' '065A' '071A' '088A' '094A' '096A'
#  '099A' '100A' '101A' '102A' '104A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '004A' '006A' '007A' '012A'
#  '013B' '014B' '015A' '016A' '019B' '020A' '021A' '022A' '023A' '023B'
#  '024A' '025A' '025B' '025C' '026A' '026C' '027A' '028A' '029A' '031A'
#  '032A' '033A' '034A' '035A' '036A' '037A' '038A' '040A' '041A' '042A'
#  '043A' '044A' '045A' '046A' '047A' '048A' '051A' '051B' '052A' '053A'
#  '054A' '055A' '057A' '058A' '059A' '060A' '062A' '064A' '066A' '067A'
#  '068A' '069A' '070A' '072A' '073A' '074A' '075A' '076A' '087A' '090A'
#  '091A' '092A' '093A' '095A' '097A' '097B' '103A' '105A' '106A' '108A'
#  '109A' '110A' '111A' '113A' '115A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['005A' '008A' '009A' '010A' '011A' '014A' '018A' '019A' '026B' '039A'
#  '049A' '050A' '056A' '061A' '063A' '065A' '071A' '088A' '094A' '096A'
#  '099A' '100A' '101A' '102A' '104A']
# Length of X_train_val:
# 790
# Length of y_train_val:
# 790
# Length of groups_train_val:
# 790
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     468
# kitten    163
# senior    159
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     120
# senior     19
# kitten      8
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     468
# kitten    163
# senior    159
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     120
# senior     19
# kitten      8
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 936, 1: 652, 2: 636})
# Epoch 1/1500
# 35/35 [==============================] - 0s 3ms/step - loss: 0.9520 - accuracy: 0.5841
# Epoch 2/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.6980 - accuracy: 0.6844
# Epoch 3/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.6728 - accuracy: 0.7059
# Epoch 4/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.5984 - accuracy: 0.7365
# Epoch 5/1500
# 35/35 [==============================] - 0s 3ms/step - loss: 0.5849 - accuracy: 0.7460
# Epoch 6/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.5394 - accuracy: 0.7626
# Epoch 7/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.5436 - accuracy: 0.7635
# Epoch 8/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.5170 - accuracy: 0.7738
# Epoch 9/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.4969 - accuracy: 0.7783
# Epoch 10/1500
# 35/35 [==============================] - 0s 3ms/step - loss: 0.4914 - accuracy: 0.7864
# Epoch 11/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.4598 - accuracy: 0.7968
# Epoch 12/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.4816 - accuracy: 0.7873
# Epoch 13/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.4486 - accuracy: 0.8044
# Epoch 14/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.4287 - accuracy: 0.8035
# Epoch 15/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.4286 - accuracy: 0.8071
# Epoch 16/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.4233 - accuracy: 0.8255
# Epoch 17/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.4102 - accuracy: 0.8246
# Epoch 18/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.4149 - accuracy: 0.8116
# Epoch 19/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.3841 - accuracy: 0.8359
# Epoch 20/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.3800 - accuracy: 0.8318
# Epoch 21/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.3867 - accuracy: 0.8336
# Epoch 22/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.3755 - accuracy: 0.8318
# Epoch 23/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.3643 - accuracy: 0.8462
# Epoch 24/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.3753 - accuracy: 0.8269
# Epoch 25/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.3944 - accuracy: 0.8332
# Epoch 26/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.3572 - accuracy: 0.8494
# Epoch 27/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.3531 - accuracy: 0.8408
# Epoch 28/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.3528 - accuracy: 0.8435
# Epoch 29/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.3374 - accuracy: 0.8485
# Epoch 30/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.3325 - accuracy: 0.8494
# Epoch 31/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.3153 - accuracy: 0.8597
# Epoch 32/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.3207 - accuracy: 0.8615
# Epoch 33/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.3190 - accuracy: 0.8678
# Epoch 34/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.
]
# outer_fold 2
# Train Set Group Distribution:
# 046A    63
# 000A    39
# 103A    33
# 047A    28
# 057A    27
# 074A    25
# 000B    19
# 019A    17
# 097A    16
# 101A    15
# 106A    14
# 042A    14
# 059A    14
# 001A    14
# 028A    13
# 002A    13
# 111A    13
# 116A    12
# 039A    12
# 051A    12
# 063A    11
# 025A    11
# 036A    11
# 040A    10
# 016A    10
# 005A    10
# 071A    10
# 014B    10
# 022A     9
# 065A     9
# 051B     9
# 072A     9
# 010A     8
# 013B     8
# 095A     8
# 094A     8
# 031A     7
# 050A     7
# 117A     7
# 027A     7
# 099A     7
# 008A     6
# 108A     6
# 007A     6
# 023A     6
# 037A     6
# 023B     5
# 070A     5
# 044A     5
# 021A     5
# 034A     5
# 052A     4
# 026A     4
# 009A     4
# 105A     4
# 035A     4
# 003A     4
# 104A     4
# 064A     3
# 058A     3
# 006A     3
# 056A     3
# 113A     3
# 014A     3
# 012A     3
# 011A     2
# 061A     2
# 102A     2
# 069A     2
# 018A     2
# 032A     2
# 093A     2
# 092A     1
# 049A     1
# 073A     1
# 048A     1
# 096A     1
# 088A     1
# 076A     1
# 091A     1
# 115A     1
# 110A     1
# 100A     1
# 026B     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 002B    32
# 020A    23
# 055A    20
# 067A    19
# 029A    17
# 097B    14
# 068A    11
# 015A     9
# 045A     9
# 033A     9
# 109A     6
# 053A     6
# 075A     5
# 025C     5
# 062A     4
# 060A     3
# 025B     2
# 087A     2
# 038A     2
# 054A     2
# 041A     1
# 043A     1
# 026C     1
# 066A     1
# 004A     1
# 019B     1
# 090A     1
# 024A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    299
# F    216
# M    214
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# M    123
# X     49
# F     36
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [006A, 000A, 001A, 103A, 071A, 028A, 019A, 074...
# kitten    [044A, 014B, 111A, 040A, 046A, 047A, 042A, 050...
# senior    [093A, 097A, 057A, 106A, 104A, 059A, 113A, 116...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [033A, 015A, 097B, 067A, 020A, 062A, 002B, 029...
# kitten                             [109A, 043A, 041A, 045A]
# senior                             [055A, 054A, 090A, 024A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 54, 'kitten': 12, 'senior': 18}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 20, 'kitten': 4, 'senior': 4}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '003A' '005A' '006A' '007A' '008A' '009A'
#  '010A' '011A' '012A' '013B' '014A' '014B' '016A' '018A' '019A' '021A'
#  '022A' '023A' '023B' '025A' '026A' '026B' '027A' '028A' '031A' '032A'
#  '034A' '035A' '036A' '037A' '039A' '040A' '042A' '044A' '046A' '047A'
#  '048A' '049A' '050A' '051A' '051B' '052A' '056A' '057A' '058A' '059A'
#  '061A' '063A' '064A' '065A' '069A' '070A' '071A' '072A' '073A' '074A'
#  '076A' '088A' '091A' '092A' '093A' '094A' '095A' '096A' '097A' '099A'
#  '100A' '101A' '102A' '103A' '104A' '105A' '106A' '108A' '110A' '111A'
#  '113A' '115A' '116A' '117A']
# Unique Test Group IDs:
# ['002B' '004A' '015A' '019B' '020A' '024A' '025B' '025C' '026C' '029A'
#  '033A' '038A' '041A' '043A' '045A' '053A' '054A' '055A' '060A' '062A'
#  '066A' '067A' '068A' '075A' '087A' '090A' '097B' '109A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '003A' '005A' '006A' '007A' '008A' '009A'
#  '010A' '011A' '012A' '013B' '014A' '014B' '016A' '018A' '019A' '021A'
#  '022A' '023A' '023B' '025A' '026A' '026B' '027A' '028A' '031A' '032A'
#  '034A' '035A' '036A' '037A' '039A' '040A' '042A' '044A' '046A' '047A'
#  '048A' '049A' '050A' '051A' '051B' '052A' '056A' '057A' '058A' '059A'
#  '061A' '063A' '064A' '065A' '069A' '070A' '071A' '072A' '073A' '074A'
#  '076A' '088A' '091A' '092A' '093A' '094A' '095A' '096A' '097A' '099A'
#  '100A' '101A' '102A' '103A' '104A' '105A' '106A' '108A' '110A' '111A'
#  '113A' '115A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['002B' '004A' '015A' '019B' '020A' '024A' '025B' '025C' '026C' '029A'
#  '033A' '038A' '041A' '043A' '045A' '053A' '054A' '055A' '060A' '062A'
#  '066A' '067A' '068A' '075A' '087A' '090A' '097B' '109A']
# Length of X_train_val:
# 729
# Length of y_train_val:
# 729
# Length of groups_train_val:
# 729
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     421
# kitten    154
# senior    154
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     167
# senior     24
# kitten     17
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     421
# kitten    154
# senior    154
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     167
# senior     24
# kitten     17
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Age group distribution: Counter({0: 842, 1: 616, 2: 616})
# Epoch 1/1500
# 33/33 [==============================] - 0s 2ms/step - loss: 0.9386 - accuracy: 0.5685
# Epoch 2/1500
# 33/33 [==============================] - 0s 2ms/step - loss: 0.7456 - accuracy: 0.6668
# Epoch 3/1500
# 33/33 [==============================] - 0s 2ms/step - loss: 0.6612 - accuracy: 0.7093
# Epoch 4/1500
# 33/33 [==============================] - 0s 2ms/step - loss: 0.6178 - accuracy: 0.7295
# Epoch 5/1500
# 33/33 [==============================] - 0s 2ms/step - loss: 0.5948 - accuracy: 0.7396
# Epoch 6/1500
# 33/33 [==============================] - 0s 2ms/step - loss: 0.5750 - accuracy: 0.7334
# Epoch 7/1500
# 33/33 [==============================] - 0s 2ms/step - loss: 0.5420 - accuracy: 0.7666
# Epoch 8/1500
# 33/33 [==============================] - 0s 2ms/step - loss: 0.5241 - accuracy: 0.7715
# Epoch 9/1500
# 33/33 [==============================] - 0s 2ms/step - loss: 0.5237 - accuracy: 0.7719
# Epoch 10/1500
# 33/33 [==============================] - 0s 2ms/step - loss: 0.4824 - accuracy: 0.7946
# Epoch 11/1500
# 33/33 [==============================] - 0s 2ms/step - loss: 0.4749 - accuracy: 0.7941
# Epoch 12/1500
# 33/33 [==============================] - 0s 2ms/step - loss: 0.4867 - accuracy: 0.7869
# Epoch 13/1500
# 33/33 [==============================] - 0s 2ms/step - loss: 0.4539 - accuracy: 0.7941
# Epoch 14/1500
# 33/33 [==============================] - 0s 2ms/step - loss: 0.4586 - accuracy: 0.8086
# Epoch 15/1500
# 33/33 [==============================] - 0s 2ms/step - loss: 0.4388 - accuracy: 0.8173
# Epoch 16/1500
# 33/33 [==============================] - 0s 3ms/step - loss: 0.4374 - accuracy: 0.8144
# Epoch 17/1500
# 33/33 [==============================] - 0s 2ms/step - loss: 0.4376 - accuracy: 0.8067
# Epoch 18/1500
# 33/33 [==============================] - 0s 2ms/step - loss: 0.4213 - accuracy: 0.8129
# Epoch 19/1500
# 33/33 [==============================] - 0s 2ms/step - loss: 0.4064 - accuracy: 0.8274
# Epoch 20/1500
# 33/33 [==============================] - 0s 2ms/step - loss: 0.4031 - accuracy: 0.8240
# Epoch 21/1500
# 33/33 [==============================] - 0s 2ms/step - loss: 0.4061 - accuracy: 0.8168
# Epoch 22/1500
# 33/33 [==============================] - 0s 2ms/step - loss: 0.3928 - accuracy: 0.8322
# Epoch 23/1500
# 33/33 [==============================] - 0s 2ms/step - loss: 0.3797 - accuracy: 0.8293
# Epoch 24/1500
# 33/33 [==============================] - 0s 2ms/step - loss: 0.3663 - accuracy: 0.8462
# Epoch 25/1500
# 33/33 [==============================] - 0s 2ms/step - loss: 0.3711 - accuracy: 0.8303
# Epoch 26/1500
# 33/33 [==============================] - 0s 2ms/step - loss: 0.3632 - accuracy: 0.8346
# Epoch 27/1500
# 33/33 [==============================] - 0s 2ms/step - loss: 0.3640 - accuracy: 0.8419
# Epoch 28/1500
# 33/33 [==============================] - 0s 3ms/step - loss: 0.3467 - accuracy: 0.8481
# Epoch 29/1500
# 33/33 [==============================] - 0s 2ms/step - loss: 0.3507 - accuracy: 0.8491
# Epoch 30/1500
# 33/33 [==============================] - 0s 2ms/step - loss: 0.3283 - accuracy: 0.8602
# Epoch 31/1500
# 33/33 [==============================] - 0s 2ms/step - loss: 0.3525 - accuracy: 0.8476
# Epoch 32/1500
# 33/33 [==============================] - 0s 2ms/step - loss: 0.3206 - accuracy: 0.8631
# Epoch 33/1500
# 33/33 [==============================] - 0s 2ms/step - loss: 0.3180 - accuracy: 0.8592
# Epoch 34/1500
# 33/33 [==============================] - 0s 2ms/step - loss: 0.3203 - accuracy: 0.8597
# Epoch 35/1500
# 33/33 [==============================] - 0s 2ms/step - loss: 0.3229 - accuracy: 0.8602
# Epoch 36/1500
# 33/33 [==============================] - 0s 2ms/step - loss: 0.3026 - accuracy: 0.8679
# Epoch 37/1500
# 33/33 [==============================] - 0s 2ms/step - loss: 0.3157 - accuracy: 0.8597
# Epoch 38/1500
# 33/33 [==============================] - 0s 2ms/step - loss: 0.3101 - accuracy: 0.8689
# Epoch 39/1500
# 33/33 [==============================] - 0s 2ms/step - loss: 0.3079 - accuracy: 0.8722
# Epoch 40/1500
# 33/33 [==============================] - 0s 3ms/step - loss: 0.2912 - accuracy: 0.8713
# Epoch 41/1500
# 33/33 [==============================] - 0s 2ms/step - loss: 0.3041 - accuracy: 0.8693
# Epoch 42/1500
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2999 - accuracy: 0.8785
# Epoch 43/1500
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2792 - accuracy: 0.8795
# Epoch 44/1500
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2949 - accuracy: 0.8775
# Epoch 45/1500
# 33/33 [==============================] - 0s 3ms/step - loss: 0.2935 - accuracy: 0.8809
# Epoch 46/1500
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2773 - accuracy: 0.8727
# Epoch 47/1500
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2758 - accuracy: 0.8867
# Epoch 48/1500
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2973 - accuracy: 0.8722
# Epoch 49/1500
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2730 - accuracy: 0.8790
# Epoch 50/1500
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2624 - accuracy: 0.8886
# Epoch 51/1500
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2741 - accuracy: 0.8877
# Epoch 52/1500
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2631 - accuracy: 0.8934
# Epoch 53/1500
# 33/33 [==============================] - 0s 2ms/step - loss: 0.
adult                  False
# 67    061A                                     [adult, adult]         adult           senior                  False
# 21    019B                                           [senior]        senior            adult                  False
# 82    076A                                           [kitten]        kitten            adult                  False
# 33    026C                                           [senior]        senior            adult                  False
# 32    026B                                           [senior]        senior            adult                  False
# 109   117A  [adult, senior, adult, adult, adult, adult, ad...         adult           senior                  False

# %%
# Create df for majority votes
majority_df = majority_votes.reset_index()
majority_df.columns = ['cat_id', 'Majority_Vote']

# Get actual groups for each cat_id
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first().reset_index()

# Merge majority votes with actual groups
majority_with_actual = pd.merge(majority_df, actual_groups, on='cat_id')

# Add a column to check if the majority vote was correct
majority_with_actual['Majority_Correct'] = majority_with_actual['Majority_Vote'] == majority_with_actual['actual_age_group']

# Count correct majority votes per class
correct_majority_votes_per_class = majority_with_actual.groupby('actual_age_group')['Majority_Correct'].sum()

print("Correct Majority Votes per Class:")
print(correct_majority_votes_per_class)
# Out:
# Correct Majority Votes per Class:
# actual_age_group
# adult     64
# kitten    12
# senior    12
# Name: Majority_Correct, dtype: int64

# %%
# Calculate the total count and the number of correct predictions for each class
class_stats = majority_with_actual.groupby('actual_age_group').agg(
    total_count=('Majority_Correct', 'size'),  # Total number of cases per class
    correct_count=('Majority_Correct', 'sum')  # Sum of correct predictions per class
).reset_index()

# Calculate accuracy for each class
class_stats['accuracy'] = class_stats['correct_count'] / class_stats['total_count'] * 100

# store for final evaluation 
all_majority_vote_details.append(class_stats)

# Log detailed stats
print("Detailed Class Statistics for Majority Votes:")
print(class_stats)
# Out:
# Detailed Class Statistics for Majority Votes:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult           73             64  87.671233
# 1           kitten           15             12  80.000000
# 2           senior           22             12  54.545455

# %%
# Plot for Detailed Class Statistics for Majority Votes
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Accuracy of Majority Votes by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Detailed Class Statistics

# %%
# Calculate the total count and the number of correct predictions for each class
class_stats = full_results.groupby('actual_age_group').agg(
    total_count=('correct', 'size'),
    correct_count=('correct', 'sum')
).reset_index()

# Calculate accuracy for each class
class_stats['accuracy'] = class_stats['correct_count'] / class_stats['total_count'] * 100

# store for final evaluation 
all_class_stats.append(class_stats)

# Log the detailed stats
print("Detailed Class Statistics:")
print(class_stats)
# Out:
# Detailed Class Statistics:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult          552            453  82.065217
# 1           kitten          109             90  82.568807
# 2           senior          178            109  61.235955

# %%
# Plot for Detailed Class Statistics (Overall)
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Overall Accuracy by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Gender Exploration

# %%
# Group by gender and calculate the total count, correct predictions, and accuracy
gender_stats = full_results.groupby('all_gender').agg(
    count=('cat_id', 'size'),  # Total number of cases per gender
    correct=('correct', 'sum')  # Sum of correct predictions per gender
).reset_index()

# Calculate accuracy for each gender
gender_stats['accuracy'] = (gender_stats['correct'] / gender_stats['count'] * 100).round(2)

# Display the DataFrame
print("Accuracy by Gender:")
print(gender_stats)

# store for final evaluation 
all_gender_stats.append(gender_stats)
# Out:
# Accuracy by Gender:
#   all_gender  count  correct  accuracy
# 0          F    216      169     78.24
# 1          M    337      268     79.53
# 2          X    286      215     75.17

# %%
# Plot for Accuracy by Gender
styled_barplot(gender_stats, 'all_gender', 'accuracy', 
               'Accuracy by Gender', 
               'Gender', 'Accuracy (%)')

# %% [markdown]
# ### Log current total CV Stats

# %%
print("Total Majority Vote Accuracy so far:", all_majority_vote_accuracies)
print("Total Class Statistics so far:\n", all_class_stats)
print("Total Gender Accuracy so far:\n", all_gender_stats)
# Out:
# Total Majority Vote Accuracy so far: [0.7363636363636363, 0.7454545454545455, 0.7272727272727273, 0.8]
# Total Class Statistics so far:
#  [  actual_age_group  total_count  correct_count   accuracy
# 0            adult          572            437  76.398601
# 1           kitten          109             96  88.073394
# 2           senior          178            107  60.112360,   actual_age_group  total_count  correct_count   accuracy
# 0            adult          554            429  77.436823
# 1           kitten          113             90  79.646018
# 2           senior          178             93  52.247191,   actual_age_group  total_count  correct_count   accuracy
# 0            adult          551            419  76.043557
# 1           kitten          113             94  83.185841
# 2           senior          178             71  39.887640,   actual_age_group  total_count  correct_count   accuracy
# 0            adult          552            453  82.065217
# 1           kitten          109             90  82.568807
# 2           senior          178            109  61.235955]
# Total Gender Accuracy so far:
#  [  all_gender  count  correct  accuracy
# 0          F    213      174     81.69
# 1          M    360      250     69.44
# 2          X    286      216     75.52,   all_gender  count  correct  accuracy
# 0          F    213      155     72.77
# 1          M    342      256     74.85
# 2          X    290      201     69.31,   all_gender  count  correct  accuracy
# 0          F    215      147     68.37
# 1          M    337      236     70.03
# 2          X    290      201     69.31,   all_gender  count  correct  accuracy
# 0          F    216      169     78.24
# 1          M    337      268     79.53
# 2          X    286      215     75.17]

# %% [markdown]
# # RANDOM SEED 5

# %%
# Set a fixed random seed for reproducibility
random.seed(int(random_seeds[4]))
np.random.seed(int(random_seeds[4]))
tf.random.set_seed(int(random_seeds[4]))

# Load datasets
dataframe = pd.read_csv('/Users/astrid/PycharmProjects/audioset-thesis-work/audioset/vggish/embeddings/8april_looped_embeddings.csv')
augmented_df = pd.read_csv('/Users/astrid/PycharmProjects/audioset-thesis-work/audioset/vggish/embeddings/augmented_dataset_19.csv')

dataframe.drop('mean_freq', axis=1, inplace=True)

augmented_df.drop('gender', axis=1, inplace=True)

def assign_age_group(age, age_groups):
    for group_name, age_range in age_groups.items():
        if age_range[0] <= age < age_range[1]:
            return group_name
    return 'Unknown'  # For any age that doesn't fit the defined groups

# Define age groups
age_groups = {
    'kitten': (0, 0.5),
    'adult': (0.5, 12),
    'senior': (12, 20)
}

# Create a new column for the age group
dataframe['age_group'] = dataframe['target'].apply(assign_age_group, age_groups=age_groups)
augmented_df['age_group'] = augmented_df['target'].apply(assign_age_group, age_groups=age_groups)

print(dataframe['age_group'].value_counts())
print(augmented_df['age_group'].value_counts())
# Out:
# adult     588
# senior    178
# kitten    171
# Name: age_group, dtype: int64
# adult     588
# senior    534
# kitten    513
# Name: age_group, dtype: int64

# %%
# Separate features and labels
X = dataframe.iloc[:, :-4].values  # all columns except the last four

# Encode the 'age_group' column as integers using LabelEncoder
label_encoder = LabelEncoder()
encoded_y = label_encoder.fit_transform(dataframe['age_group'].values)

# Use the encoded labels for splitting and one-hot encoding
y = encoded_y  

# Convert 'cat_id' column to numpy array to be used as groups array for GroupKFold
groups = dataframe['cat_id'].values

# %%
tf.keras.backend.clear_session()

# %% [markdown]
# ## Run Setup

# %%
all_cat_ids = []
all_predicted_age_groups = []
all_actual_age_groups = []
all_gender = []

# Define the StratifiedGroupKFold splitter for 4 fold CV with random shuffling
outer_cv = StratifiedGroupKFold(n_splits=4, shuffle=True, random_state=int(random_seeds[4]))

# unseen test set metrics
unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1 = [], [], [], [], []

outer_fold = 0

# Use the splitter to generate indices for training and testing sets
# Note: GroupShuffleSplit.split returns indices, so we use it to index the arrays
for train_val_idx, test_idx in outer_cv.split(X, y, groups):
    outer_fold += 1
    logger(f"outer_fold {outer_fold}", file=log_file_path)

    # Convert indices back to DataFrame for easy manipulation
    df_train_val = dataframe.iloc[train_val_idx]
    df_test = dataframe.iloc[test_idx]

    ##############################
    # ASSESSING SPLITS BY CAT_ID #
    ##############################
    
    # Get the distribution of groups
    training_validation_group_distribution = df_train_val['cat_id'].value_counts()  
    testing_group_distribution = df_test['cat_id'].value_counts()  
    
    # Log or print the distribution
    logger(f"Train Set Group Distribution:\n{training_validation_group_distribution}", file=log_file_path)
    logger(f"Testing Set Group Distribution:\n{testing_group_distribution}", file=log_file_path)

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val['gender'].value_counts()
    testing_gender_distribution = df_test['gender'].value_counts()
    
    # Log the distribution
    logger(f"Training Set Gender Distribution BEFORE SWAP:\n{training_gender_distribution}", file=log_file_path)
    logger(f"Testing Set Gender Distribution BEFORE SWAP:\n{testing_gender_distribution}", file=log_file_path)

    # Group by 'age_group' and then list unique 'cat_id' within each age group
    unique_cat_ids_per_age_group_train_val = df_train_val.groupby('age_group')['cat_id'].unique()
    unique_cat_ids_per_age_group_test = df_test.groupby('age_group')['cat_id'].unique()
    
    # Log results
    logger(f"Unique Cat IDs per Age Group in Training/Validation Set:\n{unique_cat_ids_per_age_group_train_val}", file=log_file_path)
    logger(f"Unique Cat IDs per Age Group in Testing Set:\n{unique_cat_ids_per_age_group_test}", file=log_file_path)

    # Calculate the count of unique identifiers per age group for training and testing set
    counts_train_val = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_train_val.items()}
    counts_test = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_test.items()}

    # Log the counts of unique identifiers per age group
    logger(f"Count of Unique Cat IDs per Age Group in Training/Validation Set:\n{counts_train_val}", file=log_file_path)
    logger(f"Count of Unique Cat IDs per Age Group in Testing Set:\n{counts_test}", file=log_file_path)

    #######################################################
    # CONTINUE WITH ENSURING VALID AND APPROPRIATE SPLITS #
    #######################################################
    
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    groups_train_val, groups_test = groups[train_val_idx], groups[test_idx]

    # logging identifier splits 
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)

    # check group splits
    check_initial_group_split(groups_train_val, groups_test)

    # Specify the cat_ids that must be in the training/validation set
    specific_cat_ids = ['000A', '046A']
    
    # Perform the swapping operation
    train_val_idx, test_idx = swap_cat_id_instances(dataframe, train_val_idx, test_idx, specific_cat_ids)
    
    # Re-assign the sets based on the updated indices
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    new_groups_train_val, new_groups_test = groups[train_val_idx], groups[test_idx]

    # Find differences for training and test sets
    moved_to_train_val, removed_from_train_val = find_group_differences(groups_train_val, new_groups_train_val)
    moved_to_test, removed_from_test = find_group_differences(groups_test, new_groups_test)
    
    # Display the results
    logger(f"Moved to Training/Validation Set:\n{moved_to_train_val}", file=log_file_path)
    logger(f"Removed from Training/Validation Set:\n{removed_from_train_val}", file=log_file_path)
    logger(f"Moved to Test Set:\n{moved_to_test}", file=log_file_path)
    logger(f"Removed from Test Set\n{removed_from_test}", file=log_file_path)

    # Update X_train_val, X_test, y_train_val, y_test, groups_train_val, groups_test based on updated indices
    X_train_val = X[train_val_idx]
    y_train_val = y[train_val_idx]
    groups_train_val = groups[train_val_idx]
    
    X_test = X[test_idx]
    y_test = y[test_idx]
    groups_test = groups[test_idx]

    # logging identifier splits again after potential swaps
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"AFTER SWAP - Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"AFTER SWAP - Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)
    
    # Verify the lengths are consistent
    logger(f"Length of X_train_val:\n{len(X_train_val)}", file=log_file_path)
    logger(f"Length of y_train_val:\n{len(y_train_val)}", file=log_file_path)
    logger(f"Length of groups_train_val:\n{len(groups_train_val)}", file=log_file_path)

    # Check group splits once more
    check_initial_group_split(groups_train_val, groups_test)

    # Convert the modified indices back to a DataFrame representing the updated df_train_val
    df_train_val_updated = dataframe.iloc[train_val_idx].copy()
    df_test_updated = dataframe.iloc[test_idx].copy()

    ############################
    # LOGGING AGE GROUP SPLITS #
    ############################

    # Get the distribution of age groups of age groups before the update
    training_validation_age_group_distribution = df_train_val['age_group'].value_counts()
    testing_age_group_distribution = df_test['age_group'].value_counts()
    
    # Logthe distribution
    logger(f"Train Age Group Distribution BEFORE SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution BEFORE SWAP:\n{testing_age_group_distribution}", file=log_file_path)

    # Get the distribution of age groups after the update
    training_validation_age_group_distribution = df_train_val_updated['age_group'].value_counts()
    testing_age_group_distribution = df_test_updated['age_group'].value_counts()
    
    # Log the distribution
    logger(f"Train Age Group Distribution AFTER SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution AFTER SWAP:\n{testing_age_group_distribution}", file=log_file_path)
    
    ########################################################
    # TRACKING FINAL CAT_IDs & GENDER AFTER REDISTRIBUTION #
    ########################################################

    # Get the distribution of groups
    training_validation_group_distribution = df_train_val_updated['cat_id'].value_counts()  
    testing_group_distribution = df_test_updated['cat_id'].value_counts()  

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val_updated['gender'].value_counts()
    testing_gender_distribution = df_test_updated['gender'].value_counts()
    
    logger(f"\n Starting training on unseen test set\n", file=log_file_path)

    ######################
    # ADD AUGMENTED DATA #
    ######################

    # Filter out augmented data derived from groups in the training set
    augmented_df_filtered = augmented_df[augmented_df['cat_id'].isin(groups_train_val)]
    
    # Convert augmented_df_filtered to numpy array (excluding target and other columns)
    augmented_array = augmented_df_filtered.drop(columns=['target', 'cat_id', 'age_group']).values
    
    # Concatenate the filtered augmented data with X_train_val
    X_train_val = np.concatenate([X_train_val, augmented_array])

    # Extract target labels from the filtered augmented DataFrame
    y_augmented = augmented_df_filtered['age_group'].values
    
    # Encode the labels using the same LabelEncoder instance
    y_augmented_encoded = label_encoder.transform(y_augmented)
    
    # Concatenate the encoded augmented labels with y_train_val
    y_train_val = np.concatenate([y_train_val, y_augmented_encoded])

    # Calculate the distribution of age groups in y_train_val
    age_group_distribution = Counter(y_train_val)
    print("Age group distribution:", age_group_distribution)

    # EarlyStopping callback: monitor 'loss' instead of 'val_loss' for the test set
    early_stopping = EarlyStopping(
        monitor='loss',  
        min_delta=0.001, 
        patience=30,  
        verbose=1,  
        restore_best_weights=True  
    )

    # One final shuffle to ensure randomness
    outer_shuffle_idx = np.random.permutation(len(X_train_val))
    X_train_val = X_train_val[outer_shuffle_idx]
    y_train_val = y_train_val[outer_shuffle_idx]

    class_weights = compute_class_weight(
        class_weight='balanced',
        classes=np.unique(y_train_val),
        y=y_train_val
    )
    weight_dict = {i: class_weights[i] for i in range(len(class_weights))}
    
    # Scale the features
    scaler_full = StandardScaler().fit(X_train_val)
    X_train_full_scaled = scaler_full.transform(X_train_val)
    X_test_scaled = scaler_full.transform(X_test)
    
    # Encode the labels
    y_train_full_encoded = to_categorical(y_train_val)
    y_test_encoded = to_categorical(y_test)

    #######################
    # BUILD & TRAIN MODEL #
    #######################

    optimizers = {
        'Adamax': Adamax(learning_rate=0.00038188800331973483)
    }
    
    # Full model definition with dynamic number of layers
    model_full = Sequential()
    model_full.add(Dense(480, activation='relu', input_shape=(X_train_full_scaled.shape[1],)))  # units_l0 and activation from parameters
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.27188281261238406))  
    model_full.add(Dense(3, activation='softmax'))  
    
    optimizer = optimizers['Adamax']  # optimizer_key from parameters
    
    # Compile the model
    model_full.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    
    # Train the model on the full training set
    history_full = model_full.fit(X_train_full_scaled, y_train_full_encoded, epochs=1500, batch_size=64,
                                  verbose=1, callbacks=[early_stopping], class_weight=weight_dict)
    
    # Evaluate the model on the held-out test set
    test_loss, test_accuracy = model_full.evaluate(X_test_scaled, y_test_encoded)

    y_test_pred_prob = model_full.predict(X_test_scaled)
    y_test_pred = np.argmax(y_test_pred_prob, axis=1)  
    y_test_true = np.argmax(y_test_encoded, axis=1)    

    ################################
    # LOG MAJORITY VOTE PER CAT_ID #
    ################################

    # Convert numeric predictions back to age group labels
    predicted_age_groups = label_encoder.inverse_transform(y_test_pred)
    actual_labels = label_encoder.inverse_transform(y_test_true)
    
    # Map predictions and actual labels back to cat_ids
    test_results = pd.DataFrame({
        'cat_id': df_test_updated['cat_id'],
        'predicted_age_group': predicted_age_groups,
        'actual_age_group': actual_labels
    })
    
    # Group by cat_id and aggregate predicted age groups
    majority_votes = test_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
    actual_groups = test_results.groupby('cat_id')['actual_age_group'].first()
    
    # Calculate the accuracy of majority voting
    correct_predictions = (majority_votes == actual_groups).sum()
    total_cats = len(actual_groups)
    majority_vote_accuracy = correct_predictions / total_cats
    
    # Log the accuracy of the majority voting
    logger(f"Majority Vote Accuracy for cat_id for this fold: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

    ####################################################
    # COLLECT PREDICTIONS FOR GENDER & CAT_ID ANALYSIS #
    ####################################################

    # Debugging print statements
    print(f'Before appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Extend lists with current fold results
    all_cat_ids.extend(df_test_updated['cat_id'].tolist())
    all_predicted_age_groups.extend(predicted_age_groups)
    all_actual_age_groups.extend(actual_labels)
    all_gender.extend(df_test_updated['gender'].tolist())

    # Debugging print statements
    print(f'After appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Calculate additional metrics
    test_precision = precision_score(y_test_true, y_test_pred, average='macro')  # Use 'macro' for imbalanced datasets
    test_recall = recall_score(y_test_true, y_test_pred, average='macro')
    test_f1 = f1_score(y_test_true, y_test_pred, average='macro')

    # prepare averages of outer metrics
    unseen_f1.append(test_f1)
    unseen_losses.append(test_loss)
    unseen_accuracies.append(test_accuracy)
    unseen_precisions.append(test_precision)
    unseen_recalls.append(test_recall)

    # Print final test results
    logger(f"Final Test Results - Loss: {test_loss}, Accuracy: {test_accuracy}, Precision: {test_precision}, Recall: {test_recall}, F1 Score: {test_f1}", file=log_file_path)

    # Generate the confusion matrix
    cm = confusion_matrix(y_test, y_test_pred)
    logger(f"Confusion Matrix:\n {cm}", file=log_file_path)

# Calculate the overall average metrics
unseen_set_avg_f1 = np.mean(unseen_f1)
unseen_set_avg_loss = np.mean(unseen_losses)
unseen_set_avg_acc = np.mean(unseen_accuracies)
unseen_set_avg_precision = np.mean(unseen_precisions)
unseen_set_avg_recall = np.mean(unseen_recalls)

# Append averages to total lists
all_f1.append(unseen_set_avg_f1)
all_losses.append(unseen_set_avg_loss)
all_accuracies.append(unseen_set_avg_acc)
all_precisions.append(unseen_set_avg_precision)
all_recalls.append(unseen_set_avg_recall)

logger(f"\nFinal Average F1-Score across all UNSEEN TEST sets: {unseen_set_avg_f1}", file=log_file_path)
logger(f"\nFinal Average Loss across all UNSEEN TEST sets: {unseen_set_avg_loss}", file=log_file_path)
logger(f"\nFinal Average Accuracy across all UNSEEN TEST sets: {unseen_set_avg_acc}", file=log_file_path)
logger(f"\nFinal Average Precision across all UNSEEN TEST sets: {unseen_set_avg_precision}", file=log_file_path)
logger(f"\nFinal Average Recall across all UNSEEN TEST sets: {unseen_set_avg_recall}\n", file=log_file_path)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# outer_fold 1
# Train Set Group Distribution:
# 000A    39
# 002B    32
# 047A    28
# 057A    27
# 074A    25
# 020A    23
# 055A    20
# 067A    19
# 029A    17
# 019A    17
# 097A    16
# 101A    15
# 059A    14
# 042A    14
# 106A    14
# 097B    14
# 028A    13
# 111A    13
# 051A    12
# 039A    12
# 116A    12
# 025A    11
# 036A    11
# 063A    11
# 068A    11
# 014B    10
# 016A    10
# 071A    10
# 005A    10
# 072A     9
# 051B     9
# 033A     9
# 045A     9
# 015A     9
# 013B     8
# 094A     8
# 095A     8
# 010A     8
# 050A     7
# 027A     7
# 031A     7
# 099A     7
# 117A     7
# 053A     6
# 008A     6
# 007A     6
# 037A     6
# 023A     6
# 025C     5
# 075A     5
# 021A     5
# 023B     5
# 070A     5
# 034A     5
# 062A     4
# 052A     4
# 003A     4
# 104A     4
# 105A     4
# 009A     4
# 035A     4
# 056A     3
# 014A     3
# 058A     3
# 060A     3
# 025B     2
# 102A     2
# 061A     2
# 069A     2
# 032A     2
# 093A     2
# 038A     2
# 087A     2
# 073A     1
# 090A     1
# 100A     1
# 110A     1
# 091A     1
# 041A     1
# 088A     1
# 048A     1
# 066A     1
# 076A     1
# 096A     1
# 026C     1
# 043A     1
# 024A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 046A    63
# 103A    33
# 000B    19
# 001A    14
# 002A    13
# 040A    10
# 022A     9
# 065A     9
# 109A     6
# 108A     6
# 044A     5
# 026A     4
# 113A     3
# 012A     3
# 064A     3
# 006A     3
# 011A     2
# 054A     2
# 018A     2
# 092A     1
# 049A     1
# 004A     1
# 019B     1
# 115A     1
# 026B     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    280
# X    256
# F    186
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    92
# F    66
# M    57
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [000A, 033A, 015A, 071A, 097B, 028A, 019A, 074...
# kitten    [014B, 111A, 047A, 042A, 050A, 043A, 041A, 045...
# senior    [093A, 097A, 057A, 106A, 104A, 055A, 059A, 116...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [006A, 001A, 103A, 022A, 065A, 002A, 000B, 026...
# kitten                 [044A, 040A, 046A, 109A, 049A, 115A]
# senior                             [113A, 054A, 108A, 011A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 59, 'kitten': 10, 'senior': 18}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 15, 'kitten': 6, 'senior': 4}
# Unique Training/Validation Group IDs:
# ['000A' '002B' '003A' '005A' '007A' '008A' '009A' '010A' '013B' '014A'
#  '014B' '015A' '016A' '019A' '020A' '021A' '023A' '023B' '024A' '025A'
#  '025B' '025C' '026C' '027A' '028A' '029A' '031A' '032A' '033A' '034A'
#  '035A' '036A' '037A' '038A' '039A' '041A' '042A' '043A' '045A' '047A'
#  '048A' '050A' '051A' '051B' '052A' '053A' '055A' '056A' '057A' '058A'
#  '059A' '060A' '061A' '062A' '063A' '066A' '067A' '068A' '069A' '070A'
#  '071A' '072A' '073A' '074A' '075A' '076A' '087A' '088A' '090A' '091A'
#  '093A' '094A' '095A' '096A' '097A' '097B' '099A' '100A' '101A' '102A'
#  '104A' '105A' '106A' '110A' '111A' '116A' '117A']
# Unique Test Group IDs:
# ['000B' '001A' '002A' '004A' '006A' '011A' '012A' '018A' '019B' '022A'
#  '026A' '026B' '040A' '044A' '046A' '049A' '054A' '064A' '065A' '092A'
#  '103A' '108A' '109A' '113A' '115A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'046A'}
# Removed from Training/Validation Set:
# {'041A'}
# Moved to Test Set:
# {'041A'}
# Removed from Test Set
# {'046A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '002B' '003A' '005A' '007A' '008A' '009A' '010A' '013B' '014A'
#  '014B' '015A' '016A' '019A' '020A' '021A' '023A' '023B' '024A' '025A'
#  '025B' '025C' '026C' '027A' '028A' '029A' '031A' '032A' '033A' '034A'
#  '035A' '036A' '037A' '038A' '039A' '042A' '043A' '045A' '046A' '047A'
#  '048A' '050A' '051A' '051B' '052A' '053A' '055A' '056A' '057A' '058A'
#  '059A' '060A' '061A' '062A' '063A' '066A' '067A' '068A' '069A' '070A'
#  '071A' '072A' '073A' '074A' '075A' '076A' '087A' '088A' '090A' '091A'
#  '093A' '094A' '095A' '096A' '097A' '097B' '099A' '100A' '101A' '102A'
#  '104A' '105A' '106A' '110A' '111A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['000B' '001A' '002A' '004A' '006A' '011A' '012A' '018A' '019B' '022A'
#  '026A' '026B' '040A' '041A' '044A' '049A' '054A' '064A' '065A' '092A'
#  '103A' '108A' '109A' '113A' '115A']
# Length of X_train_val:
# 784
# Length of y_train_val:
# 784
# Length of groups_train_val:
# 784
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     472
# senior    165
# kitten     85
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     116
# kitten     86
# senior     13
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     472
# senior    165
# kitten    147
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     116
# kitten     24
# senior     13
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 944, 2: 660, 1: 588})
# Epoch 1/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.9231 - accuracy: 0.5817
# Epoch 2/1500
# 35/35 [==============================] - 0s 3ms/step - loss: 0.7433 - accuracy: 0.6852
# Epoch 3/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.6862 - accuracy: 0.7076
# Epoch 4/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.6472 - accuracy: 0.7249
# Epoch 5/1500
# 35/35 [==============================] - 0s 3ms/step - loss: 0.6006 - accuracy: 0.7372
# Epoch 6/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.5701 - accuracy: 0.7500
# Epoch 7/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.5566 - accuracy: 0.7646
# Epoch 8/1500
# 35/35 [==============================] - 0s 3ms/step - loss: 0.5435 - accuracy: 0.7678
# Epoch 9/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.4910 - accuracy: 0.7819
# Epoch 10/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.4991 - accuracy: 0.7851
# Epoch 11/1500
# 35/35 [==============================] - 0s 3ms/step - loss: 0.4915 - accuracy: 0.7892
# Epoch 12/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.4789 - accuracy: 0.7943
# Epoch 13/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.4928 - accuracy: 0.7801
# Epoch 14/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.4606 - accuracy: 0.8006
# Epoch 15/1500
# 35/35 [==============================] - 0s 3ms/step - loss: 0.4329 - accuracy: 0.8070
# Epoch 16/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.4397 - accuracy: 0.8038
# Epoch 17/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.4197 - accuracy: 0.8089
# Epoch 18/1500
# 35/35 [==============================] - 0s 3ms/step - loss: 0.4378 - accuracy: 0.8193
# Epoch 19/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.4129 - accuracy: 0.8225
# Epoch 20/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.4051 - accuracy: 0.8239
# Epoch 21/1500
# 35/35 [==============================] - 0s 5ms/step - loss: 0.4037 - accuracy: 0.8225
# Epoch 22/1500
# 35/35 [==============================] - 0s 4ms/step - loss: 0.3934 - accuracy: 0.8271
# Epoch 23/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.3746 - accuracy: 0.8390
# Epoch 24/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.3826 - accuracy: 0.8353
# Epoch 25/1500
# 35/35 [==============================] - 0s 3ms/step - loss: 0.3862 - accuracy: 0.8349
# Epoch 26/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.3713 - accuracy: 0.8376
# Epoch 27/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.3728 - accuracy: 0.8399
# Epoch 28/1500
# 35/35 [==============================] - 0s 3ms/step - loss: 0.3707 - accuracy: 0.8367
# Epoch 29/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.3498 - accuracy: 0.8499
# Epoch 30/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.3599 - accuracy: 0.8431
# Epoch 31/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.3373 - accuracy: 0.8595
# Epoch 32/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.3616 - accuracy: 0.8458
# Epoch 33/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.3215 - accuracy: 0.8595
# Epoch 34/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.3272 - accuracy: 0.8499
# Epoch 35/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.3255 - accuracy: 0.8563
# Epoch 36/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.3223 - accuracy: 0.8659
# Epoch 37/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.3320 - accuracy: 0.8508
# Epoch 38/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.3036 - accuracy: 0.8768
# Epoch 39/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.3123 - accuracy: 0.8645
# Epoch 40/1500
# 35/35 [==============================] - 0s 3ms/step - loss: 0.3051 - accuracy: 0.8631
# Epoch 41/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.2946 - accuracy: 0.8759
# Epoch 42/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.2899 - accuracy: 0.8796
# Epoch 43/1500
# 35/35 [==============================] - 0s 3ms/step - loss: 0.3153 - accuracy: 0.8654
# Epoch 44/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.2834 - accuracy: 0.8727
# Epoch 45/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.3230 - accuracy: 0.8686
# Epoch 46/1500
# 35/35 [==============================] - 0s 3ms/step - loss: 0.2897 - accuracy: 0.8718
# Epoch 47/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.2786 - accuracy: 0.8805
# Epoch 48/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.2864 - accuracy: 0.8759
# Epoch 49/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.2765 - accuracy: 0.8777
# Epoch 50/1500
# 35/35 [==============================] - 0s 3ms/step - loss: 0.2917 - accuracy: 0.8768
# Epoch 51/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.2855 - accuracy: 0.8773
# Epoch 52/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.2695 - accuracy: 0.8841
# Epoch 53/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.2918 - accuracy: 0.8805
# Epoch 54/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.2746 - accuracy: 0.8864
# Epoch 55/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.2685 - accuracy: 0.8837
# Epoch 56/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.2730 - accuracy: 0.8764
# Epoch 57/1500
# 35/35 [==============================] - 0s 3ms/step - loss: 0.2649 - accuracy: 0.8887
# Epoch 58/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.2677 - accuracy: 0.8960
# Epoch 59/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.2566 - accuracy: 0.8891
# Epoch 60/1500
# 35/35 [==============================] - 0s 3ms/step - loss: 0.2580 - accuracy: 0.8946
# Epoch 61/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.2529 - accuracy: 0.8932
# Epoch 62/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.2461 - accuracy: 0.8992
# Epoch 63/1500
# 35/35 [==============================] - 0s 3ms/step - loss: 0.2436 - accuracy: 0.9015
# Epoch 64/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.2451 - accuracy: 0.8992
# Epoch 65/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.2366 - accuracy: 0.8992
# Epoch 66/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.2428 - accuracy: 0.9005
# Epoch 67/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.2475 - accuracy: 0.8928
# Epoch 68/1500
# 35/35 [==============================] - 0s 3ms/step - loss: 0.2290 - accuracy: 0.8951
# Epoch 69/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.2409 - accuracy: 0.8978
# Epoch 70/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.2370 - accuracy: 0.8996
# Epoch 71/1500
# 35/35 [==============================] - 0s 3ms/step - loss: 0
1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.1314 - accuracy: 0.9512
# Epoch 195/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.1117 - accuracy: 0.9548
# Epoch 196/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.1276 - accuracy: 0.9503
# Epoch 197/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.1216 - accuracy: 0.9494
# Epoch 198/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.1127 - accuracy: 0.9553
# Epoch 199/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.1013 - accuracy: 0.9626
# Epoch 200/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.1158 - accuracy: 0.9599
# Epoch 201/1500
# 35/35 [==============================] - 0s 3ms/step - loss: 0.1085 - accuracy: 0.9553
# Epoch 202/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.1226 - accuracy: 0.9530
# Epoch 203/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.1200 - accuracy: 0.9544
# Epoch 204/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.1073 - accuracy: 0.9557
# Epoch 205/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.1062 - accuracy: 0.9544
# Epoch 206/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.1221 - accuracy: 0.9521
# Epoch 207/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.1288 - accuracy: 0.9471
# Epoch 208/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.1088 - accuracy: 0.9571
# Epoch 209/1500
# 35/35 [==============================] - 0s 3ms/step - loss: 0.1085 - accuracy: 0.9617
# Epoch 210/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.1285 - accuracy: 0.9535
# Epoch 211/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.1101 - accuracy: 0.9571
# Epoch 212/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0947 - accuracy: 0.9662
# Epoch 213/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.1098 - accuracy: 0.9557
# Epoch 214/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.1089 - accuracy: 0.9594
# Epoch 215/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.1085 - accuracy: 0.9544
# Epoch 216/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.1025 - accuracy: 0.9612
# Epoch 217/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.1018 - accuracy: 0.9612
# Epoch 218/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.1102 - accuracy: 0.9603
# Epoch 219/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.1066 - accuracy: 0.9603
# Epoch 220/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.1042 - accuracy: 0.9599
# Epoch 221/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.1076 - accuracy: 0.9612
# Epoch 222/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.1187 - accuracy: 0.9507
# Epoch 223/1500
# 35/35 [==============================] - 0s 3ms/step - loss: 0.1108 - accuracy: 0.9571
# Epoch 224/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.1000 - accuracy: 0.9589
# Epoch 225/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0951 - accuracy: 0.9612
# Epoch 226/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.1013 - accuracy: 0.9626
# Epoch 227/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.1083 - accuracy: 0.9557
# Epoch 228/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.1080 - accuracy: 0.9580
# Epoch 229/1500
# 35/35 [==============================] - 0s 3ms/step - loss: 0.1192 - accuracy: 0.9576
# Epoch 230/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0962 - accuracy: 0.9621
# Epoch 231/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.1007 - accuracy: 0.9635
# Epoch 232/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.1198 - accuracy: 0.9498
# Epoch 233/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.1156 - accuracy: 0.9530
# Epoch 234/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.1087 - accuracy: 0.9548
# Epoch 235/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.1040 - accuracy: 0.9599
# Epoch 236/1500
# 35/35 [==============================] - 0s 3ms/step - loss: 0.1211 - accuracy: 0.9512
# Epoch 237/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.1041 - accuracy: 0.9599
# Epoch 238/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.1071 - accuracy: 0.9599
# Epoch 239/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.1014 - accuracy: 0.9594
# Epoch 240/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.1145 - accuracy: 0.9557
# Epoch 241/1500
# 35/35 [==============================] - 0s 2ms/step - loss: 0.0946 - accuracy: 0.9640
# Epoch 242/1500
# 34/35 [============================>.] - ETA: 0s - loss: 0.1016 - accuracy: 0.9623Restoring model weights from the end of the best epoch: 212.
# 35/35 [==============================] - 0s 3ms/step - loss: 0.1012 - accuracy: 0.9626
# Epoch 242: early stopping
# 5/5 [==============================] - 0s 1ms/step - loss: 0.7799 - accuracy: 0.6993
# 5/5 [==============================] - 0s 870us/step
# Majority Vote Accuracy for cat_id for this fold: 0.72 (18/25)
# Before appending - Cat IDs: 0, Predictions: 0, Actuals: 0, Gender: 0
# After appending - Cat IDs: 153, Predictions: 153, Actuals: 153, Gender: 153
# Final Test Results - Loss: 0.7799285650253296, Accuracy: 0.6993464231491089, Precision: 0.609240492535687, Recall: 0.6423519009725908, F1 Score: 0.600895768209472
# Confusion Matrix:
#  [[83  5 28]
#  [ 5 18  1]
#  [ 7  0  6]]
# outer_fold 2
# Train Set Group Distribution:
# 046A    63
# 103A    33
# 057A    27
# 074A    25
# 020A    23
# 055A    20
# 000B    19
# 029A    17
# 019A    17
# 097A    16
# 101A    15
# 059A    14
# 001A    14
# 097B    14
# 106A    14
# 028A    13
# 002A    13
# 111A    13
# 051A    12
# 025A    11
# 036A    11
# 005A    10
# 040A    10
# 071A    10
# 014B    10
# 022A     9
# 015A     9
# 065A     9
# 045A     9
# 072A     9
# 095A     8
# 094A     8
# 031A     7
# 027A     7
# 008A     6
# 108A     6
# 109A     6
# 053A     6
# 023A     6
# 037A     6
# 023B     5
# 070A     5
# 044A     5
# 021A     5
# 034A     5
# 052A     4
# 003A     4
# 105A     4
# 009A     4
# 026A     4
# 035A     4
# 104A     4
# 062A     4
# 064A     3
# 058A     3
# 006A     3
# 056A     3
# 012A     3
# 113A     3
# 014A     3
# 060A     3
# 011A     2
# 102A     2
# 032A     2
# 069A     2
# 018A     2
# 093A     2
# 054A     2
# 038A     2
# 019B     1
# 090A     1
# 100A     1
# 110A     1
# 115A     1
# 092A     1
# 004A     1
# 041A     1
# 076A     1
# 096A     1
# 026C     1
# 073A     1
# 049A     1
# 026B     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 000A    39
# 002B    32
# 047A    28
# 067A    19
# 042A    14
# 116A    12
# 039A    12
# 068A    11
# 063A    11
# 016A    10
# 033A     9
# 051B     9
# 010A     8
# 013B     8
# 099A     7
# 117A     7
# 050A     7
# 007A     6
# 075A     5
# 025C     5
# 087A     2
# 061A     2
# 025B     2
# 043A     1
# 066A     1
# 048A     1
# 088A     1
# 091A     1
# 024A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    263
# M    226
# F    177
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# M    111
# X     85
# F     75
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [006A, 015A, 001A, 103A, 071A, 097B, 028A, 019...
# kitten    [044A, 014B, 111A, 040A, 046A, 109A, 049A, 041...
# senior    [093A, 097A, 057A, 106A, 104A, 055A, 059A, 113...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [000A, 033A, 067A, 002B, 091A, 039A, 063A, 013...
# kitten                       [047A, 042A, 050A, 043A, 048A]
# senior                 [116A, 051B, 117A, 016A, 061A, 024A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 56, 'kitten': 11, 'senior': 16}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 18, 'kitten': 5, 'senior': 6}
# Unique Training/Validation Group IDs:
# ['000B' '001A' '002A' '003A' '004A' '005A' '006A' '008A' '009A' '011A'
#  '012A' '014A' '014B' '015A' '018A' '019A' '019B' '020A' '021A' '022A'
#  '023A' '023B' '025A' '026A' '026B' '026C' '027A' '028A' '029A' '031A'
#  '032A' '034A' '035A' '036A' '037A' '038A' '040A' '041A' '044A' '045A'
#  '046A' '049A' '051A' '052A' '053A' '054A' '055A' '056A' '057A' '058A'
#  '059A' '060A' '062A' '064A' '065A' '069A' '070A' '071A' '072A' '073A'
#  '074A' '076A' '090A' '092A' '093A' '094A' '095A' '096A' '097A' '097B'
#  '100A' '101A' '102A' '103A' '104A' '105A' '106A' '108A' '109A' '110A'
#  '111A' '113A' '115A']
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Unique Test Group IDs:
# ['000A' '002B' '007A' '010A' '013B' '016A' '024A' '025B' '025C' '033A'
#  '039A' '042A' '043A' '047A' '048A' '050A' '051B' '061A' '063A' '066A'
#  '067A' '068A' '075A' '087A' '088A' '091A' '099A' '116A' '117A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'000A'}
# Removed from Training/Validation Set:
# {'074A'}
# Moved to Test Set:
# {'074A'}
# Removed from Test Set
# {'000A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '003A' '004A' '005A' '006A' '008A' '009A'
#  '011A' '012A' '014A' '014B' '015A' '018A' '019A' '019B' '020A' '021A'
#  '022A' '023A' '023B' '025A' '026A' '026B' '026C' '027A' '028A' '029A'
#  '031A' '032A' '034A' '035A' '036A' '037A' '038A' '040A' '041A' '044A'
#  '045A' '046A' '049A' '051A' '052A' '053A' '054A' '055A' '056A' '057A'
#  '058A' '059A' '060A' '062A' '064A' '065A' '069A' '070A' '071A' '072A'
#  '073A' '076A' '090A' '092A' '093A' '094A' '095A' '096A' '097A' '097B'
#  '100A' '101A' '102A' '103A' '104A' '105A' '106A' '108A' '109A' '110A'
#  '111A' '113A' '115A']
# AFTER SWAP - Unique Test Group IDs:
# ['002B' '007A' '010A' '013B' '016A' '024A' '025B' '025C' '033A' '039A'
#  '042A' '043A' '047A' '048A' '050A' '051B' '061A' '063A' '066A' '067A'
#  '068A' '074A' '075A' '087A' '088A' '091A' '099A' '116A' '117A']
# Length of X_train_val:
# 680
# Length of y_train_val:
# 680
# Length of groups_train_val:
# 680
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     409
# senior    137
# kitten    120
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     179
# kitten     51
# senior     41
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     423
# senior    137
# kitten    120
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     165
# kitten     51
# senior     41
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 846, 2: 548, 1: 480})
# Epoch 1/1500
# 30/30 [==============================] - 0s 2ms/step - loss: 1.0154 - accuracy: 0.5267
# Epoch 2/1500
# 30/30 [==============================] - 0s 2ms/step - loss: 0.7623 - accuracy: 0.6265
# Epoch 3/1500
# 30/30 [==============================] - 0s 3ms/step - loss: 0.6669 - accuracy: 0.6638
# Epoch 4/1500
# 30/30 [==============================] - 0s 2ms/step - loss: 0.6278 - accuracy: 0.6894
# Epoch 5/1500
# 30/30 [==============================] - 0s 2ms/step - loss: 0.5860 - accuracy: 0.7166
# Epoch 6/1500
# 30/30 [==============================] - 0s 2ms/step - loss: 0.5764 - accuracy: 0.7156
# Epoch 7/1500
# 30/30 [==============================] - 0s 2ms/step - loss: 0.5303 - accuracy: 0.7455
# Epoch 8/1500
# 30/30 [==============================] - 0s 2ms/step - loss: 0.5387 - accuracy: 0.7481
# Epoch 9/1500
# 30/30 [==============================] - 0s 3ms/step - loss: 0.5101 - accuracy: 0.7604
# Epoch 10/1500
# 30/30 [==============================] - 0s 2ms/step - loss: 0.5050 - accuracy: 0.7615
# Epoch 11/1500
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4656 - accuracy: 0.7850
# Epoch 12/1500
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4604 - accuracy: 0.7785
# Epoch 13/1500
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4601 - accuracy: 0.7823
# Epoch 14/1500
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4561 - accuracy: 0.7914
# Epoch 15/1500
# 30/30 [==============================] - 0s 3ms/step - loss: 0.4407 - accuracy: 0.7930
# Epoch 16/1500
# 30/30 [==============================] - 0s 2ms/step - loss: 0.3994 - accuracy: 0.8191
# Epoch 17/1500
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4162 - accuracy: 0.8106
# Epoch 18/1500
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4183 - accuracy: 0.8058
# Epoch 19/1500
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4081 - accuracy: 0.8010
# Epoch 20/1500
# 30/30 [==============================] - 0s 2ms/step - loss: 0.3779 - accuracy: 0.8346
# Epoch 21/1500
# 30/30 [==============================] - 0s 2ms/step - loss: 0.3914 - accuracy: 0.8250
# Epoch 22/1500
# 30/30 [==============================] - 0s 3ms/step - loss: 0.3898 - accuracy: 0.8180
# Epoch 23/1500
# 30/30 [==============================] - 0s 2ms/step - loss: 0.3854 - accuracy: 0.8271
# Epoch 24/1500
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4066 - accuracy: 0.8170
# Epoch 25/1500
# 30/30 [==============================] - 0s 2ms/step - loss: 0.3781 - accuracy: 0.8239
# Epoch 26/1500
# 30/30 [==============================] - 0s 2ms/step - loss: 0.3687 - accuracy: 0.8356
# Epoch 27/1500
# 30/30 [==============================] - 0s 3ms/step - loss: 0.3553 - accuracy: 0.8388
# Epoch 28/1500
# 30/30 [==============================] - 0s 2ms/step - loss: 0.3647 - accuracy: 0.8292
# Epoch 29/1500
# 30/30 [==============================] - 0s 2ms/step - loss: 0.3701 - accuracy: 0.8180
# Epoch 30/1500
# 30/30 [==============================] - 0s 2ms/step - loss: 0.3402 - accuracy: 0.8447
# Epoch 31/1500
# 30/30 [==============================] - 0s 2ms/step - loss: 0.3163 - accuracy: 0.8554
# Epoch 32/1500
# 30/30 [==============================] - 0s 3ms/step - loss: 0.3202 - accuracy: 0.8581
# Epoch 33/1500
# 30/30 [==============================] - 0s 2ms/step - loss: 0.3197 - accuracy: 0.8495
# Epoch 34/1500
# 30/30 [==============================] - 0s 2ms/step - loss: 0.3194 - accuracy: 0.8581
# Epoch 35/1500
# 30/30 [==============================] - 0s 2ms/step - loss: 0.3024 - accuracy: 0.8629
# Epoch 36/1500
# 30/30 [==============================] - 0s 2ms/step - loss: 0.3057 - accuracy: 0.8661
# Epoch 37/1500
# 30/30 [==============================] - 0s 2ms/step - loss: 0.3069 - accuracy: 0.8581
# Epoch 38/1500
# 30/30 [==============================] - 0s 3ms/step - loss: 0.3079 - accuracy: 0.8629
# Epoch 39/1500
# 30/30 [==============================] - 0s 2ms/step - loss: 0.3180 - accuracy: 0.8597
# Epoch 40/1500
# 30/30 [==============================] - 0s 2ms/step - loss: 0.3165 - accuracy: 0.8538
# Epoch 41/1500
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2908 - accuracy: 0.8650
# Epoch 42/1500
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2802 - accuracy: 0.8719
# Epoch 43/1500
# 30/30 [==============================] - 0s 3ms/step - loss: 0.2984 - accuracy: 0.8629
# Epoch 44/1500
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2880 - accuracy: 0.8762
# Epoch 45/1500
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2964 - accuracy: 0.8682
# Epoch 46/1500
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2694 - accuracy: 0.8773
# Epoch 47/1500
# 30/30 [==============================] - 0s 2ms/step - loss: 0.2829 - accuracy: 0.8730
# Epoch 48/1500
# 30/30 [==============================] - 0s 2ms/step - loss: 0.
1500
# 31/31 [==============================] - 0s 2ms/step - loss: 0.0729 - accuracy: 0.9757
# Epoch 316/1500
# 31/31 [==============================] - 0s 2ms/step - loss: 0.0591 - accuracy: 0.9797
# Epoch 317/1500
# 31/31 [==============================] - 0s 3ms/step - loss: 0.0589 - accuracy: 0.9807
# Epoch 318/1500
# 31/31 [==============================] - 0s 2ms/step - loss: 0.0649 - accuracy: 0.9812
# Epoch 319/1500
# 31/31 [==============================] - 0s 2ms/step - loss: 0.0621 - accuracy: 0.9792
# Epoch 320/1500
# 31/31 [==============================] - 0s 2ms/step - loss: 0.0645 - accuracy: 0.9752
# Epoch 321/1500
# 31/31 [==============================] - 0s 3ms/step - loss: 0.0743 - accuracy: 0.9752
# Epoch 322/1500
# 31/31 [==============================] - 0s 2ms/step - loss: 0.0709 - accuracy: 0.9736
# Epoch 323/1500
# 31/31 [==============================] - 0s 2ms/step - loss: 0.0652 - accuracy: 0.9777
# Epoch 324/1500
#  1/31 [..............................] - ETA: 0s - loss: 0.1571 - accuracy: 0.9531Restoring model weights from the end of the best epoch: 294.
# 31/31 [==============================] - 0s 2ms/step - loss: 0.0690 - accuracy: 0.9762
# Epoch 324: early stopping
# 8/8 [==============================] - 0s 939us/step - loss: 0.7816 - accuracy: 0.7632
# 8/8 [==============================] - 0s 892us/step
# Majority Vote Accuracy for cat_id for this fold: 0.68 (19/28)
# Before appending - Cat IDs: 633, Predictions: 633, Actuals: 633, Gender: 633
# After appending - Cat IDs: 861, Predictions: 861, Actuals: 861, Gender: 861
# Final Test Results - Loss: 0.7816435694694519, Accuracy: 0.7631579041481018, Precision: 0.7551527924130664, Recall: 0.7965157301327513, F1 Score: 0.7637296037296037
# Confusion Matrix:
#  [[116   3  37]
#  [  3  22   0]
#  [ 11   0  36]]
#
# Final Average F1-Score across all UNSEEN TEST sets: 0.6839242890585846
#
# Final Average Loss across all UNSEEN TEST sets: 0.7886078953742981
#
# Final Average Accuracy across all UNSEEN TEST sets: 0.731027141213417
#
# Final Average Precision across all UNSEEN TEST sets: 0.6899107571466213
#
# Final Average Recall across all UNSEEN TEST sets: 0.7179590416020445

# %%
seed_5_folds_values = (unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1)

# Plotting all fold metrics|
seed_5_folds_plot = plot_all_metrics(unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1, "Folds", "Fold Number")

# %% [markdown]
# ## Majority Voting on Total Entries per cat_id

# %%
# Debugging print statements
print(f'Checking - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
# Out:
# Checking - Cat IDs: 861, Predictions: 861, Actuals: 861, Gender: 861

# %%
# Create results df
full_results = pd.DataFrame({
    'cat_id': all_cat_ids,
    'predicted_age_group': all_predicted_age_groups,
    'actual_age_group': all_actual_age_groups,
    'all_gender': all_gender
})

# create a correct majority prediction column
full_results['correct'] = full_results['predicted_age_group'] == full_results['actual_age_group']

# %%
# Group by cat_id and aggregate predicted age groups
majority_votes = full_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first()

# Calculate the accuracy of majority voting
correct_predictions = (majority_votes == actual_groups).sum()
total_cats = len(actual_groups)
majority_vote_accuracy = correct_predictions / total_cats

logger(f"Overall Majority Vote Accuracy for cat_id: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

# store for final evaluation 
all_majority_vote_accuracies.append(majority_vote_accuracy)
# Out:
# Overall Majority Vote Accuracy for cat_id: 0.72 (79/110)

# %%
# Detailed df with predictions, actual labels, and comparison including majority vote
detailed_results = full_results.groupby('cat_id').apply(
    lambda x: pd.Series({
        'Predictions': list(x['predicted_age_group']),
        'Majority Vote': x['predicted_age_group'].mode()[0],
        'Actual Age Group': x['actual_age_group'].iloc[0],
        'Correct Majority Vote': x['predicted_age_group'].mode()[0] == x['actual_age_group'].iloc[0]
    })
).reset_index()

# Convert to DataFrame for better formatting and display
detailed_results = pd.DataFrame(detailed_results)

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 10)
pd.set_option('display.width', 1000)

sorted_detailed_results = detailed_results.sort_values(by='Correct Majority Vote', ascending=False)

# Display the sorted DataFrame
sorted_detailed_results
# Out:
#     cat_id                                        Predictions Majority Vote Actual Age Group  Correct Majority Vote
# 0     000B  [adult, adult, kitten, senior, adult, adult, a...         adult            adult                   True
# 76    070A               [adult, adult, adult, adult, senior]         adult            adult                   True
# 74    068A  [adult, adult, adult, senior, senior, adult, s...         adult            adult                   True
# 73    067A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 72    066A                                            [adult]         adult            adult                   True
# 71    065A  [senior, adult, adult, adult, adult, senior, s...         adult            adult                   True
# 70    064A                              [adult, adult, adult]         adult            adult                   True
# 69    063A  [senior, senior, adult, senior, adult, senior,...         adult            adult                   True
# 68    062A                       [adult, adult, adult, adult]         adult            adult                   True
# 65    059A  [senior, senior, senior, senior, senior, senio...        senior           senior                   True
# 61    055A  [senior, senior, senior, senior, senior, senio...        senior           senior                   True
# 59    053A       [adult, adult, senior, adult, kitten, adult]         adult            adult                   True
# 57    051B  [senior, senior, senior, adult, senior, senior...        senior           senior                   True
# 1     001A  [adult, adult, senior, adult, adult, adult, ad...         adult            adult                   True
# 54    049A                                           [kitten]        kitten           kitten                   True
# 52    047A  [adult, adult, kitten, kitten, kitten, kitten,...        kitten           kitten                   True
# 51    045A  [kitten, kitten, kitten, kitten, kitten, kitte...        kitten           kitten                   True
# 50    044A            [kitten, kitten, adult, kitten, kitten]        kitten           kitten                   True
# 49    043A                                           [kitten]        kitten           kitten                   True
# 48    042A  [adult, kitten, kitten, kitten, adult, kitten,...        kitten           kitten                   True
# 47    041A                                   [kitten, kitten]        kitten           kitten                   True
# 75    069A                                     [adult, adult]         adult            adult                   True
# 77    071A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 45    039A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 78    072A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 108   116A  [senior, senior, senior, senior, adult, senior...        senior           senior                   True
# 107   115A                                           [kitten]        kitten           kitten                   True
# 106   113A                           [senior, senior, senior]        senior           senior                   True
# 105   111A  [kitten, kitten, kitten, kitten, kitten, kitte...        kitten           kitten                   True
# 100   105A                       [adult, adult, adult, adult]         adult            adult                   True
# 98    103A  [adult, adult, adult, adult, senior, senior, a...         adult            adult                   True
# 96    101A  [adult, adult, senior, adult, adult, adult, ad...         adult            adult                   True
# 95    100A                                            [adult]         adult            adult                   True
# 94    099A  [adult, adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 92    097A  [senior, senior, senior, adult, senior, senior...        senior           senior                   True
# 91    096A                                            [adult]         adult            adult                   True
# 89    094A  [senior, senior, senior, senior, senior, senio...        senior           senior                   True
# 85    090A                                           [senior]        senior           senior                   True
# 84    088A                                            [adult]         adult            adult                   True
# 83    087A                                     [adult, adult]         adult            adult                   True
# 82    076A                                            [adult]         adult            adult                   True
# 81    075A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 80    074A  [adult, adult, adult, kitten, adult, adult, ad...         adult            adult                   True
# 79    073A                                            [adult]         adult            adult                   True
# 46    040A  [kitten, kitten, kitten, kitten, kitten, kitte...        kitten           kitten                   True
# 55    050A  [kitten, kitten, kitten, kitten, kitten, kitte...        kitten           kitten                   True
# 31    026A                       [adult, adult, adult, adult]         adult            adult                   True
# 7     006A                              [adult, adult, adult]         adult            adult                   True
# 29    025B                                    [senior, adult]         adult            adult                   True
# 28    025A  [senior, adult, adult, adult, adult, adult, ad...         adult            adult                   True
# 9     008A         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 26    023B                [adult, adult, adult, adult, adult]         adult            adult                   True
# 25    023A         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 24    022A  [adult, adult, adult, senior, adult, adult, ki...         adult            adult                   True
# 23    021A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 22    020A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 43    037A         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 20    019A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 19    018A                                    [adult, senior]         adult            adult                   True
# 10    009A                       [adult, adult, adult, adult]         adult            adult                   True
# 17    015A  [adult, adult, adult, adult, adult, adult, sen...         adult            adult                   True
# 16    014B  [kitten, kitten, kitten, adult, kitten, kitten...        kitten           kitten                   True
# 15    014A                              [adult, adult, adult]         adult            adult                   True
# 14    013B  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 11    010A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 8     007A         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 13    012A                             [senior, adult, adult]         adult            adult                   True
# 5     004A                                            [adult]         adult            adult                   True
# 4     003A                       [adult, adult, adult, adult]         adult            adult                   True
# 2     002A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 41    035A                      [senior, adult, adult, adult]         adult            adult                   True
# 33    026C                                            [adult]         adult            adult                   True
# 3     002B  [adult, adult, adult, adult, adult, adult, sen...         adult            adult                   True
# 34    027A  [adult, senior, adult, senior, adult, adult, a...         adult            adult                   True
# 39    033A  [adult, adult, adult, adult, adult, adult, kit...         adult            adult                   True
# 35    028A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 38    032A                                    [kitten, adult]         adult            adult                   True
# 36    029A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 37    031A  [adult, adult, adult, adult, adult, adult, adult]         adult            adult                   True
#

# Total Gender Accuracy so far:
#  [  all_gender  count  correct  accuracy
# 0          F    213      174     81.69
# 1          M    360      250     69.44
# 2          X    286      216     75.52,   all_gender  count  correct  accuracy
# 0          F    213      155     72.77
# 1          M    342      256     74.85
# 2          X    290      201     69.31,   all_gender  count  correct  accuracy
# 0          F    215      147     68.37
# 1          M    337      236     70.03
# 2          X    290      201     69.31,   all_gender  count  correct  accuracy
# 0          F    216      169     78.24
# 1          M    337      268     79.53
# 2          X    286      215     75.17,   all_gender  count  correct  accuracy
# 0          F    213      163     76.53
# 1          M    362      281     77.62
# 2          X    286      189     66.08]

# %% [markdown]
# # --------------

# %% [markdown]
# # Total Final Results & Analysis

# %%
# Count unique cat_id per age group 
unique_cats_per_age_group = dataframe.groupby('age_group')['cat_id'].nunique()

# Display the counts
print("Unique cat_id counts in original dataframe:", unique_cats_per_age_group)
# Out:
# Unique cat_id counts in original dataframe: age_group
# adult     74
# kitten    16
# senior    22
# Name: cat_id, dtype: int64

# %% [markdown]
# ## Metrics

# %%
# Calculate overall metrics
overall_avg_loss = np.mean(all_losses)
overall_avg_acc = np.mean(all_accuracies)
overall_avg_precision = np.mean(all_precisions)
overall_avg_recall = np.mean(all_recalls)
overall_avg_f1 = np.mean(all_f1)

print("Overall Average Metrics:")
print("Loss:", overall_avg_loss)
print("Accuracy:", overall_avg_acc)
print("Precision:", overall_avg_precision)
print("Recall:", overall_avg_recall)
print("F1 Score:", overall_avg_f1)
# Out:
# Overall Average Metrics:
# Loss: 0.8740462779998779
# Accuracy: 0.7339416652917862
# Precision: 0.6974762408827466
# Recall: 0.7273795462703843
# F1 Score: 0.6972710299258482

# %% [markdown]
# ## Majority Votes

# %%
# Average of majority vote accuracies
average_majority_vote_accuracy = np.mean(all_majority_vote_accuracies)
print("Average Majority Vote Accuracy:", average_majority_vote_accuracy)
# Out:
# Average Majority Vote Accuracy: 0.7454545454545454

# %%
# Concatenate all class stats DataFrames and calculate the mean of accuracies
total_majority_vote_details = pd.concat(all_majority_vote_details)
average_majority_vote_details = total_majority_vote_details.groupby('actual_age_group').agg({
    'total_count': 'sum', 
    'correct_count': 'sum' 
}).reset_index()
average_majority_vote_details['accuracy'] = (average_majority_vote_details['correct_count'] / average_majority_vote_details['total_count']) * 100

print("Average Class Statistics:")
print(average_majority_vote_details)
# Out:
# Average Class Statistics:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult          365            301  82.465753
# 1           kitten           75             60  80.000000
# 2           senior          110             49  44.545455

# %%
# Plot for Detailed Class Statistics for Majority Votes
styled_barplot(average_majority_vote_details, 'actual_age_group', 'accuracy', 
               'Accuracy of Majority Votes by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Detailed Class Statistics

# %%
# Concatenate all class stats DataFrames and calculate the mean of accuracies
total_class_stats = pd.concat(all_class_stats)
average_class_stats = total_class_stats.groupby('actual_age_group').agg({
    'total_count': 'sum',  
    'correct_count': 'sum' 
}).reset_index()
average_class_stats['accuracy'] = (average_class_stats['correct_count'] / average_class_stats['total_count']) * 100

print("Average Class Statistics:")
print(average_class_stats)
# Out:
# Average Class Statistics:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult         2803           2194  78.273279
# 1           kitten          553            452  81.735986
# 2           senior          890            475  53.370787

# %%
# Plot for Detailed Class Statistics (Overall)
styled_barplot(average_class_stats, 'actual_age_group', 'accuracy', 
               'Overall Accuracy by Age Group', 
               'Age Group', 'Accuracy (%)')

# %%
# Concatenate all gender stats DataFrames and calculate the mean of accuracies
total_gender_stats = pd.concat(all_gender_stats)
average_gender_stats = total_gender_stats.groupby('all_gender').agg({
    'count': 'sum',  
    'correct': 'sum'  
}).reset_index()
average_gender_stats['accuracy'] = (average_gender_stats['correct'] / average_gender_stats['count']) * 100

print("Average Gender Accuracy:")
print(average_gender_stats)
# Out:
# Average Gender Accuracy:
#   all_gender  count  correct   accuracy
# 0          F   1070      808  75.514019
# 1          M   1738     1291  74.280783
# 2          X   1438     1022  71.070932

# %%
# Plot for Accuracy by Gender
styled_barplot(total_gender_stats, 'all_gender', 'accuracy', 
               'Accuracy by Gender', 
               'Gender', 'Accuracy (%)')

# %% [markdown]
# # Visualisations

# %%
# Plotting all metrics
metrics_across_seeds = plot_all_metrics(all_losses, all_accuracies, all_precisions, all_recalls, all_f1, "Seeds", "Seed Number")

# %%
# Calculate the standard deviation for each metric
std_loss = np.std(all_losses)
std_accuracy = np.std(all_accuracies)
std_precision = np.std(all_precisions)
std_recall = np.std(all_recalls)
std_f1 = np.std(all_f1)

print("Standard Deviations:")
print(f"Loss: {std_loss}")
print(f"Accuracy: {std_accuracy}")
print(f"Precision: {std_precision}")
print(f"Recall: {std_recall}")
print(f"F1 Score: {std_f1}")
# Out:
# Standard Deviations:
# Loss: 0.13217729811532528
# Accuracy: 0.027632878430527856
# Precision: 0.019192212931541993
# Recall: 0.03699721803544585
# F1 Score: 0.028093797040886936

# %%
# Calculate the interquartile range for each metric
iqr_loss = np.percentile(all_losses, 75) - np.percentile(all_losses, 25)
iqr_accuracy = np.percentile(all_accuracies, 75) - np.percentile(all_accuracies, 25)
iqr_precision = np.percentile(all_precisions, 75) - np.percentile(all_precisions, 25)
iqr_recall = np.percentile(all_recalls, 75) - np.percentile(all_recalls, 25)
iqr_f1 = np.percentile(all_f1, 75) - np.percentile(all_f1, 25)

print("Interquartile Ranges:")
print(f"Loss: {iqr_loss}")
print(f"Accuracy: {iqr_accuracy}")
print(f"Precision: {iqr_precision}")
print(f"Recall: {iqr_recall}")
print(f"F1 Score: {iqr_f1}")
# Out:
# Interquartile Ranges:
# Loss: 0.17568078637123108
# Accuracy: 0.019890740513801575
# Precision: 0.005549945132292122
# Recall: 0.02688150393022193
# F1 Score: 0.0326952895499546

# %% [markdown]
# ## Display the seed folds results together

# %%
# Create a figure with subplots
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(18, 12))  

# Flatten the axes array for easier indexing
axes = axes.flatten()

def plot_metrics_on_axes(ax, losses, accuracies, precisions, recalls, f1, title):
    ax.plot(range(1, len(losses)+1), losses, marker='o', color='blue', label='Loss')
    ax.plot(range(1, len(accuracies)+1), accuracies, marker='o', color='green', label='Accuracy')
    ax.plot(range(1, len(precisions)+1), precisions, marker='o', color='red', label='Precision')
    ax.plot(range(1, len(recalls)+1), recalls, marker='o', color='purple', label='Recall')
    ax.plot(range(1, len(f1)+1), f1, marker='o', color='orange', label='F1 Score')
    ax.set_xticks([1, 2, 3, 4])  # Set x-axis ticks to full integers
    ax.set_title(title)
    ax.set_xlabel('Fold Number')
    ax.set_ylabel('Metric Value')
    ax.legend()
    ax.grid(True)

# Plot onto each axes object
plot_metrics_on_axes(axes[0], *seed_1_folds_values, "Seed 1 Metrics")
plot_metrics_on_axes(axes[1], *seed_2_folds_values, "Seed 2 Metrics")
plot_metrics_on_axes(axes[2], *seed_3_folds_values, "Seed 3 Metrics")
plot_metrics_on_axes(axes[3], *seed_4_folds_values, "Seed 4 Metrics")
plot_metrics_on_axes(axes[4], *seed_5_folds_values, "Seed 5 Metrics")

# Hide the unused subplot 
for ax in axes[5:]:
    ax.set_visible(False)

# Adjust layout
plt.tight_layout()
plt.show()
