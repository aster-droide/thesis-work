# %% [markdown]
# # YAMNet Multi Seed Validation
# #### 5 Random (but reproducible) seeds are selected for 5 different runs of train/test
# #### Models have been optimised and verified on validation sets thoroughly, running a final train/test evaluation here
# #### The setup:
#
# - 4 fold StratifiedGroupKFold for stratification and ensuring each cat_id group only appears in one set at a time
# - Final scores averaged over the 4 folds
# - For each seed run we will explore the cat_id predictions through majority voting
# - For each run we will explore the potential impact of gender
# - Includes visualisations & analysis
#
# The dataset is highly unbalanced.

# %%
# Standard imports
import numpy as np
import pandas as pd
import random
from datetime import datetime
from collections import Counter

# Sklearn imports
from sklearn.model_selection import train_test_split, GroupShuffleSplit, GroupKFold, StratifiedGroupKFold
from sklearn.preprocessing import LabelEncoder, MinMaxScaler, RobustScaler, StandardScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report
from sklearn.utils.class_weight import compute_class_weight
from sklearn.inspection import permutation_importance

# Imbalanced-learn import
from imblearn.over_sampling import SMOTE

# TensorFlow and Keras imports
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Dropout, Input, BatchNormalization, concatenate
from tensorflow.keras.optimizers import Adam, RMSprop, SGD, Adamax, AdamW
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import to_categorical
from keras.regularizers import l1, l2, L1L2

# Optuna import
import optuna

# Visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns

from IPython.display import display

# %%
# Set an initial seed for reproducibility
np.random.seed(42)  

# Generate a list of 5 random seeds
random_seeds = np.random.randint(0, 10000, size=5)
print("Random Seeds:", random_seeds)
# Out:
# Random Seeds: [7270  860 5390 5191 5734]

# %% [markdown]
# #### TOTAL RESULTS ACROSS SEED INITIATION

# %%
# Lists to collect statistics across all CVs
all_losses, all_accuracies, all_precisions, all_recalls, all_f1 = [], [], [], [], []
all_majority_vote_accuracies, all_majority_vote_details, all_class_stats, all_gender_stats  = [], [], [], []

# %% [markdown]
# ## Define Functions

# %%
def check_initial_group_split(groups_train, groups_test):
    """
    Check if any group is present in both the train and test sets.

    Parameters:
    - groups_train: Array of group identifiers for the train set
    - groups_test: Array of group identifiers for the test set

    Returns:
    - Prints out any groups found in both sets and the count of such groups
    """
    train_groups = set(groups_train)
    test_groups = set(groups_test)
    common_groups = train_groups.intersection(test_groups)

    if common_groups:
        print(f"Warning: Found {len(common_groups)} common groups in both train/validation and test sets: {common_groups}")
    else:
        print("No common groups found between train and test sets.")

# %%
# Function to perform the swaps based on cat_id, ensuring swaps within the same age_group
def swap_cat_id_instances(dataframe, train_val_idx, test_idx, specific_cat_ids):
    for cat_id in specific_cat_ids:
        # Check if the specific cat_id is not in the training set
        if cat_id not in dataframe.iloc[train_val_idx]['cat_id'].values:
            # Get the age_group of this cat_id
            age_group = dataframe[dataframe['cat_id'] == cat_id]['age_group'].iloc[0]
                
            # Find a different cat_id within the same age_group in the train set that is not in the test set
            other_cat_ids_in_age_group = dataframe[(dataframe['age_group'] == age_group) & 
                                                   (dataframe['cat_id'] != cat_id) &
                                                   (~dataframe['cat_id'].isin(dataframe.iloc[test_idx]['cat_id']))]['cat_id'].unique()
            
            # Choose one other cat_id for swapping
            if len(other_cat_ids_in_age_group) > 0:
                other_cat_id = np.random.choice(other_cat_ids_in_age_group)

                # Find all instances of the other_cat_id in the train set
                other_cat_id_train_val_indices = train_val_idx[dataframe.iloc[train_val_idx]['cat_id'] == other_cat_id]
                
                # Find all instances of the specific cat_id in the test set
                cat_id_test_indices = test_idx[dataframe.iloc[test_idx]['cat_id'] == cat_id]
                
                # Swap the indices
                train_val_idx = np.setdiff1d(train_val_idx, other_cat_id_train_val_indices, assume_unique=True)
                test_idx = np.setdiff1d(test_idx, cat_id_test_indices, assume_unique=True)

                train_val_idx = np.concatenate((train_val_idx, cat_id_test_indices))
                test_idx = np.concatenate((test_idx, other_cat_id_train_val_indices))
            else:
                print(f"No alternative cat_id found in the same age_group as {cat_id} for swapping.")
                
    return train_val_idx, test_idx

# %%
# Function to identify differences in groups
def find_group_differences(original, new):
    # Convert numpy arrays to sets for easy difference computation
    original_set = set(original)
    new_set = set(new)
    # Find differences
    moved_to_new = new_set - original_set
    moved_to_original = original_set - new_set
    return moved_to_new, moved_to_original

# %%
# create custom logger function for local logs & stored in a .txt
def logger(message, file=None):
    print(message)
    if file is not None:
        with open(file, "a") as log_file:
            log_file.write(message + "\n")

log_file_path = "multi-seed-val-D13.txt"

# %%
# Set the aesthetic style of the plots
sns.set(style="whitegrid", palette="deep")

# Define a custom color palette
colors = ["#6aabd1", "#b6e2d3", "#dac292"] 
sns.set_palette(sns.color_palette(colors))

# Function to create bar plots with enhanced style
def styled_barplot(data, x, y, title, xlabel, ylabel):
    plt.figure(figsize=(8, 4))
    bar_plot = sns.barplot(x=x, y=y, data=data, errorbar=None, width=0.5)  
    plt.title(title, fontsize=16, fontweight='bold', color="#333333")
    plt.xlabel(xlabel, fontsize=14, fontweight='bold', color="#333333")
    plt.ylabel(ylabel, fontsize=14, fontweight='bold', color="#333333")
    plt.xticks(fontsize=12, color="#333333")
    plt.yticks(fontsize=12, color="#333333")
    plt.ylim(0, 100) 

    # Adding value labels on top of each bar
    for p in bar_plot.patches:
        height = p.get_height()
        # Annotate the height value on the bar
        bar_plot.annotate(f'{height:.1f}', 
                          (p.get_x() + p.get_width() / 2., height), 
                          ha='center', va='center', 
                          xytext=(0, 9), 
                          textcoords='offset points', fontsize=12, color="#333333")

    plt.show()

# %%
def plot_all_metrics(losses, accuracies, precisions, recalls, f1, metrics_across, x_axis_label):
    fig, ax = plt.subplots(figsize=(12, 8))
    seeds = range(1, len(losses) + 1)

    ax.plot(seeds, losses, marker='o', color='blue', label='Loss')
    ax.plot(seeds, accuracies, marker='o', color='green', label='Accuracy')
    ax.plot(seeds, precisions, marker='o', color='red', label='Precision')
    ax.plot(seeds, recalls, marker='o', color='purple', label='Recall')
    ax.plot(seeds, f1, marker='o', color='orange', label='F1 Score')

    ax.set_title(f'Metrics Across {metrics_across}')
    ax.set_xlabel(x_axis_label)
    ax.set_ylabel('Metric Value')
    ax.set_xticks(seeds)
    ax.legend()
    ax.grid(True)

    return fig

# %% [markdown]
# # RANDOM SEED 1

# %% [markdown]
# ## Prepare Data

# %%
# Set a fixed random seed for reproducibility
random.seed(int(random_seeds[0]))
np.random.seed(int(random_seeds[0]))
tf.random.set_seed(int(random_seeds[0]))

# Load datasets
dataframe = pd.read_csv('/Users/astrid/PycharmProjects/perch-2/scripts/perch_embeddings_april_10.csv')
augmented_df = pd.read_csv('/Users/astrid/PycharmProjects/perch-2/scripts/perch_embeddings_augm_d1.csv')

dataframe.drop('mean_freq', axis=1, inplace=True)

augmented_df.drop('mean_freq', axis=1, inplace=True)
augmented_df.drop('gender', axis=1, inplace=True)

def assign_age_group(age, age_groups):
    for group_name, age_range in age_groups.items():
        if age_range[0] <= age < age_range[1]:
            return group_name
    return 'Unknown'  # For any age that doesn't fit the defined groups

# Define age groups
age_groups = {
    'kitten': (0, 0.5),
    'adult': (0.5, 12),
    'senior': (12, 20)
}

# Create a new column for the age group
dataframe['age_group'] = dataframe['target'].apply(assign_age_group, age_groups=age_groups)
augmented_df['age_group'] = augmented_df['target'].apply(assign_age_group, age_groups=age_groups)

print(dataframe['age_group'].value_counts())
print(augmented_df['age_group'].value_counts())
# Out:
# adult     509
# senior    149
# kitten    135
# Name: age_group, dtype: int64
# senior    596
# kitten    540
# adult     509
# Name: age_group, dtype: int64

# %%
# Separate features and labels
X = dataframe.iloc[:, :-4].values  # all columns except the last four

# Encode the 'age_group' column as integers using LabelEncoder
label_encoder = LabelEncoder()
encoded_y = label_encoder.fit_transform(dataframe['age_group'].values)

# Use the encoded labels for splitting and one-hot encoding
y = encoded_y  

# Convert 'cat_id' column to numpy array to be used as groups array for GroupKFold
groups = dataframe['cat_id'].values

# %%
tf.keras.backend.clear_session()

# %% [markdown]
# ## Run Setup

# %%
all_cat_ids = []
all_predicted_age_groups = []
all_actual_age_groups = []
all_gender = []

# Define the StratifiedGroupKFold splitter for 4 fold CV with random shuffling
outer_cv = StratifiedGroupKFold(n_splits=4, shuffle=True, random_state=int(random_seeds[0]))

# unseen test set metrics
unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1 = [], [], [], [], []

outer_fold = 0

# Use the splitter to generate indices for training and testing sets
# Note: GroupShuffleSplit.split returns indices, so we use it to index the arrays
for train_val_idx, test_idx in outer_cv.split(X, y, groups):
    outer_fold += 1
    logger(f"outer_fold {outer_fold}", file=log_file_path)

    # Convert indices back to DataFrame for easy manipulation
    df_train_val = dataframe.iloc[train_val_idx]
    df_test = dataframe.iloc[test_idx]

    ##############################
    # ASSESSING SPLITS BY CAT_ID #
    ##############################
    
    # Get the distribution of groups
    training_validation_group_distribution = df_train_val['cat_id'].value_counts()  
    testing_group_distribution = df_test['cat_id'].value_counts()  
    
    # Log or print the distribution
    logger(f"Train Set Group Distribution:\n{training_validation_group_distribution}", file=log_file_path)
    logger(f"Testing Set Group Distribution:\n{testing_group_distribution}", file=log_file_path)

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val['gender'].value_counts()
    testing_gender_distribution = df_test['gender'].value_counts()
    
    # Log the distribution
    logger(f"Training Set Gender Distribution BEFORE SWAP:\n{training_gender_distribution}", file=log_file_path)
    logger(f"Testing Set Gender Distribution BEFORE SWAP:\n{testing_gender_distribution}", file=log_file_path)

    # Group by 'age_group' and then list unique 'cat_id' within each age group
    unique_cat_ids_per_age_group_train_val = df_train_val.groupby('age_group')['cat_id'].unique()
    unique_cat_ids_per_age_group_test = df_test.groupby('age_group')['cat_id'].unique()
    
    # Log results
    logger(f"Unique Cat IDs per Age Group in Training/Validation Set:\n{unique_cat_ids_per_age_group_train_val}", file=log_file_path)
    logger(f"Unique Cat IDs per Age Group in Testing Set:\n{unique_cat_ids_per_age_group_test}", file=log_file_path)

    # Calculate the count of unique identifiers per age group for training and testing set
    counts_train_val = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_train_val.items()}
    counts_test = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_test.items()}

    # Log the counts of unique identifiers per age group
    logger(f"Count of Unique Cat IDs per Age Group in Training/Validation Set:\n{counts_train_val}", file=log_file_path)
    logger(f"Count of Unique Cat IDs per Age Group in Testing Set:\n{counts_test}", file=log_file_path)

    #######################################################
    # CONTINUE WITH ENSURING VALID AND APPROPRIATE SPLITS #
    #######################################################
    
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    groups_train_val, groups_test = groups[train_val_idx], groups[test_idx]

    # logging identifier splits 
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)

    # check group splits
    check_initial_group_split(groups_train_val, groups_test)

    # Specify the cat_ids that must be in the training/validation set
    specific_cat_ids = ['000A', '046A']
    
    # Perform the swapping operation
    train_val_idx, test_idx = swap_cat_id_instances(dataframe, train_val_idx, test_idx, specific_cat_ids)
    
    # Re-assign the sets based on the updated indices
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    new_groups_train_val, new_groups_test = groups[train_val_idx], groups[test_idx]

    # Find differences for training and test sets
    moved_to_train_val, removed_from_train_val = find_group_differences(groups_train_val, new_groups_train_val)
    moved_to_test, removed_from_test = find_group_differences(groups_test, new_groups_test)
    
    # Display the results
    logger(f"Moved to Training/Validation Set:\n{moved_to_train_val}", file=log_file_path)
    logger(f"Removed from Training/Validation Set:\n{removed_from_train_val}", file=log_file_path)
    logger(f"Moved to Test Set:\n{moved_to_test}", file=log_file_path)
    logger(f"Removed from Test Set\n{removed_from_test}", file=log_file_path)

    # Update X_train_val, X_test, y_train_val, y_test, groups_train_val, groups_test based on updated indices
    X_train_val = X[train_val_idx]
    y_train_val = y[train_val_idx]
    groups_train_val = groups[train_val_idx]
    
    X_test = X[test_idx]
    y_test = y[test_idx]
    groups_test = groups[test_idx]

    # logging identifier splits again after potential swaps
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"AFTER SWAP - Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"AFTER SWAP - Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)
    
    # Verify the lengths are consistent
    logger(f"Length of X_train_val:\n{len(X_train_val)}", file=log_file_path)
    logger(f"Length of y_train_val:\n{len(y_train_val)}", file=log_file_path)
    logger(f"Length of groups_train_val:\n{len(groups_train_val)}", file=log_file_path)

    # Check group splits once more
    check_initial_group_split(groups_train_val, groups_test)

    # Convert the modified indices back to a DataFrame representing the updated df_train_val
    df_train_val_updated = dataframe.iloc[train_val_idx].copy()
    df_test_updated = dataframe.iloc[test_idx].copy()

    ############################
    # LOGGING AGE GROUP SPLITS #
    ############################

    # Get the distribution of age groups of age groups before the update
    training_validation_age_group_distribution = df_train_val['age_group'].value_counts()
    testing_age_group_distribution = df_test['age_group'].value_counts()
    
    # Logthe distribution
    logger(f"Train Age Group Distribution BEFORE SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution BEFORE SWAP:\n{testing_age_group_distribution}", file=log_file_path)

    # Get the distribution of age groups after the update
    training_validation_age_group_distribution = df_train_val_updated['age_group'].value_counts()
    testing_age_group_distribution = df_test_updated['age_group'].value_counts()
    
    # Log the distribution
    logger(f"Train Age Group Distribution AFTER SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution AFTER SWAP:\n{testing_age_group_distribution}", file=log_file_path)
    
    ########################################################
    # TRACKING FINAL CAT_IDs & GENDER AFTER REDISTRIBUTION #
    ########################################################

    # Get the distribution of groups
    training_validation_group_distribution = df_train_val_updated['cat_id'].value_counts()  
    testing_group_distribution = df_test_updated['cat_id'].value_counts()  

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val_updated['gender'].value_counts()
    testing_gender_distribution = df_test_updated['gender'].value_counts()
    
    logger(f"\n Starting training on unseen test set\n", file=log_file_path)

    ######################
    # ADD AUGMENTED DATA #
    ######################

    # Filter out augmented data derived from groups in the training set
    augmented_df_filtered = augmented_df[augmented_df['cat_id'].isin(groups_train_val)]
    
    # Convert augmented_df_filtered to numpy array (excluding target and other columns)
    augmented_array = augmented_df_filtered.drop(columns=['target', 'cat_id', 'age_group']).values
    
    # Concatenate the filtered augmented data with X_train_val
    X_train_val = np.concatenate([X_train_val, augmented_array])

    # Extract target labels from the filtered augmented DataFrame
    y_augmented = augmented_df_filtered['age_group'].values
    
    # Encode the labels using the same LabelEncoder instance
    y_augmented_encoded = label_encoder.transform(y_augmented)
    
    # Concatenate the encoded augmented labels with y_train_val
    y_train_val = np.concatenate([y_train_val, y_augmented_encoded])

    # Calculate the distribution of age groups in y_train_val
    age_group_distribution = Counter(y_train_val)
    print("Age group distribution:", age_group_distribution)

    # EarlyStopping callback: monitor 'loss' instead of 'val_loss' for the test set
    early_stopping = EarlyStopping(
        monitor='loss',  
        min_delta=0.001, 
        patience=30,  
        verbose=1,  
        restore_best_weights=True  
    )

    # One final shuffle to ensure randomness
    outer_shuffle_idx = np.random.permutation(len(X_train_val))
    X_train_val = X_train_val[outer_shuffle_idx]
    y_train_val = y_train_val[outer_shuffle_idx]
    
    # Scale the features
    scaler_full = StandardScaler().fit(X_train_val)
    X_train_full_scaled = scaler_full.transform(X_train_val)
    X_test_scaled = scaler_full.transform(X_test)
    
    # Encode the labels
    y_train_full_encoded = to_categorical(y_train_val)
    y_test_encoded = to_categorical(y_test)

    #######################
    # BUILD & TRAIN MODEL #
    #######################

    optimizers = {
        'Adamax': Adamax(learning_rate=0.00510251984616472)
    }
    
    # Model definition with dynamic number of layers
    model_full = Sequential()
    model_full.add(Dense(480, activation='relu', input_shape=(X_train_full_scaled.shape[1],)))
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.2011047009431978))  
    model_full.add(Dense(256, activation='relu',)) 
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.14956886311951184))  
    model_full.add(Dense(256, activation='relu'))  
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.42291461228250665))  
    model_full.add(Dense(3, activation='softmax'))  
    
    # Use the optimizer from the parameters
    optimizer = optimizers['Adamax']  # optimizer_key from parameters
    
    # Compile the model
    model_full.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    
    # Train the model on the full training set
    history_full = model_full.fit(X_train_full_scaled, y_train_full_encoded, epochs=1500, batch_size=64,
                                  verbose=1, callbacks=[early_stopping])
    
    # Evaluate the model on the held-out test set
    test_loss, test_accuracy = model_full.evaluate(X_test_scaled, y_test_encoded)

    y_test_pred_prob = model_full.predict(X_test_scaled)
    y_test_pred = np.argmax(y_test_pred_prob, axis=1)  
    y_test_true = np.argmax(y_test_encoded, axis=1)    

    ################################
    # LOG MAJORITY VOTE PER CAT_ID #
    ################################

    # Convert numeric predictions back to age group labels
    predicted_age_groups = label_encoder.inverse_transform(y_test_pred)
    actual_labels = label_encoder.inverse_transform(y_test_true)
    
    # Map predictions and actual labels back to cat_ids
    test_results = pd.DataFrame({
        'cat_id': df_test_updated['cat_id'],
        'predicted_age_group': predicted_age_groups,
        'actual_age_group': actual_labels
    })
    
    # Group by cat_id and aggregate predicted age groups
    majority_votes = test_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
    actual_groups = test_results.groupby('cat_id')['actual_age_group'].first()
    
    # Calculate the accuracy of majority voting
    correct_predictions = (majority_votes == actual_groups).sum()
    total_cats = len(actual_groups)
    majority_vote_accuracy = correct_predictions / total_cats
    
    # Log the accuracy of the majority voting
    logger(f"Majority Vote Accuracy for cat_id for this fold: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

    ####################################################
    # COLLECT PREDICTIONS FOR GENDER & CAT_ID ANALYSIS #
    ####################################################

    # Debugging print statements
    print(f'Before appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Extend lists with current fold results
    all_cat_ids.extend(df_test_updated['cat_id'].tolist())
    all_predicted_age_groups.extend(predicted_age_groups)
    all_actual_age_groups.extend(actual_labels)
    all_gender.extend(df_test_updated['gender'].tolist())

    # Debugging print statements
    print(f'After appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Calculate additional metrics
    test_precision = precision_score(y_test_true, y_test_pred, average='macro')  # Use 'macro' for imbalanced datasets
    test_recall = recall_score(y_test_true, y_test_pred, average='macro')
    test_f1 = f1_score(y_test_true, y_test_pred, average='macro')

    # prepare averages of outer metrics
    unseen_f1.append(test_f1)
    unseen_losses.append(test_loss)
    unseen_accuracies.append(test_accuracy)
    unseen_precisions.append(test_precision)
    unseen_recalls.append(test_recall)

    # Print final test results
    logger(f"Final Test Results - Loss: {test_loss}, Accuracy: {test_accuracy}, Precision: {test_precision}, Recall: {test_recall}, F1 Score: {test_f1}", file=log_file_path)

    # Generate the confusion matrix
    cm = confusion_matrix(y_test, y_test_pred)
    logger(f"Confusion Matrix:\n {cm}", file=log_file_path)

# Calculate the overall average metrics
unseen_set_avg_f1 = np.mean(unseen_f1)
unseen_set_avg_loss = np.mean(unseen_losses)
unseen_set_avg_acc = np.mean(unseen_accuracies)
unseen_set_avg_precision = np.mean(unseen_precisions)
unseen_set_avg_recall = np.mean(unseen_recalls)

# Append averages to total lists
all_f1.append(unseen_set_avg_f1)
all_losses.append(unseen_set_avg_loss)
all_accuracies.append(unseen_set_avg_acc)
all_precisions.append(unseen_set_avg_precision)
all_recalls.append(unseen_set_avg_recall)

logger(f"\nFinal Average F1-Score across all UNSEEN TEST sets: {unseen_set_avg_f1}", file=log_file_path)
logger(f"\nFinal Average Loss across all UNSEEN TEST sets: {unseen_set_avg_loss}", file=log_file_path)
logger(f"\nFinal Average Accuracy across all UNSEEN TEST sets: {unseen_set_avg_acc}", file=log_file_path)
logger(f"\nFinal Average Precision across all UNSEEN TEST sets: {unseen_set_avg_precision}", file=log_file_path)
logger(f"\nFinal Average Recall across all UNSEEN TEST sets: {unseen_set_avg_recall}\n", file=log_file_path)
# Out:
# outer_fold 1
# Train Set Group Distribution:
# 046A    45
# 103A    33
# 002B    30
# 047A    22
# 020A    20
# 057A    17
# 074A    16
# 029A    15
# 097B    14
# 106A    13
# 002A    13
# 116A    12
# 111A    12
# 101A    12
# 055A    12
# 067A    11
# 042A    11
# 025A    10
# 014B    10
# 072A     9
# 065A     9
# 016A     9
# 033A     9
# 051B     9
# 071A     9
# 001A     9
# 068A     8
# 031A     7
# 117A     7
# 027A     7
# 015A     7
# 007A     6
# 023A     6
# 099A     6
# 109A     5
# 021A     5
# 050A     5
# 008A     5
# 044A     5
# 075A     5
# 094A     5
# 070A     5
# 108A     5
# 025C     4
# 045A     4
# 023B     4
# 026A     4
# 104A     4
# 009A     4
# 060A     3
# 012A     3
# 058A     3
# 053A     3
# 010A     3
# 006A     3
# 056A     3
# 034A     3
# 105A     3
# 113A     3
# 014A     3
# 062A     3
# 093A     2
# 025B     2
# 037A     2
# 102A     2
# 061A     2
# 011A     2
# 035A     2
# 038A     2
# 052A     2
# 054A     2
# 032A     2
# 066A     1
# 004A     1
# 088A     1
# 092A     1
# 026C     1
# 073A     1
# 115A     1
# 096A     1
# 110A     1
# 064A     1
# 100A     1
# 090A     1
# 024A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 000A    39
# 000B    19
# 019A    17
# 097A    15
# 051A    12
# 063A    11
# 028A    11
# 059A    10
# 040A    10
# 022A     9
# 005A     9
# 013B     8
# 095A     7
# 036A     7
# 039A     6
# 003A     4
# 018A     2
# 087A     2
# 069A     2
# 076A     1
# 091A     1
# 043A     1
# 049A     1
# 041A     1
# 048A     1
# 019B     1
# 026B     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    249
# X    203
# F    133
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# F    98
# X    73
# M    37
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [006A, 033A, 015A, 001A, 103A, 071A, 097B, 074...
# kitten    [044A, 014B, 111A, 046A, 047A, 042A, 109A, 050...
# senior    [093A, 057A, 106A, 104A, 055A, 113A, 116A, 051...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [000A, 028A, 019A, 022A, 095A, 005A, 091A, 039...
# kitten                       [040A, 043A, 049A, 041A, 048A]
# senior                                   [097A, 059A, 051A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 55, 'kitten': 11, 'senior': 19}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 19, 'kitten': 5, 'senior': 3}
# Unique Training/Validation Group IDs:
# ['001A' '002A' '002B' '004A' '006A' '007A' '008A' '009A' '010A' '011A'
#  '012A' '014A' '014B' '015A' '016A' '020A' '021A' '023A' '023B' '024A'
#  '025A' '025B' '025C' '026A' '026C' '027A' '029A' '031A' '032A' '033A'
#  '034A' '035A' '037A' '038A' '042A' '044A' '045A' '046A' '047A' '050A'
#  '051B' '052A' '053A' '054A' '055A' '056A' '057A' '058A' '060A' '061A'
#  '062A' '064A' '065A' '066A' '067A' '068A' '070A' '071A' '072A' '073A'
#  '074A' '075A' '088A' '090A' '092A' '093A' '094A' '096A' '097B' '099A'
#  '100A' '101A' '102A' '103A' '104A' '105A' '106A' '108A' '109A' '110A'
#  '111A' '113A' '115A' '116A' '117A']
# Unique Test Group IDs:
# ['000A' '000B' '003A' '005A' '013B' '018A' '019A' '019B' '022A' '026B'
#  '028A' '036A' '039A' '040A' '041A' '043A' '048A' '049A' '051A' '059A'
#  '063A' '069A' '076A' '087A' '091A' '095A' '097A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'000A'}
# Removed from Training/Validation Set:
# {'009A'}
# Moved to Test Set:
# {'009A'}
# Removed from Test Set
# {'000A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '001A' '002A' '002B' '004A' '006A' '007A' '008A' '010A' '011A'
#  '012A' '014A' '014B' '015A' '016A' '020A' '021A' '023A' '023B' '024A'
#  '025A' '025B' '025C' '026A' '026C' '027A' '029A' '031A' '032A' '033A'
#  '034A' '035A' '037A' '038A' '042A' '044A' '045A' '046A' '047A' '050A'
#  '051B' '052A' '053A' '054A' '055A' '056A' '057A' '058A' '060A' '061A'
#  '062A' '064A' '065A' '066A' '067A' '068A' '070A' '071A' '072A' '073A'
#  '074A' '075A' '088A' '090A' '092A' '093A' '094A' '096A' '097B' '099A'
#  '100A' '101A' '102A' '103A' '104A' '105A' '106A' '108A' '109A' '110A'
#  '111A' '113A' '115A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['000B' '003A' '005A' '009A' '013B' '018A' '019A' '019B' '022A' '026B'
#  '028A' '036A' '039A' '040A' '041A' '043A' '048A' '049A' '051A' '059A'
#  '063A' '069A' '076A' '087A' '091A' '095A' '097A']
# Length of X_train_val:
# 620
# Length of y_train_val:
# 620
# Length of groups_train_val:
# 620
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     352
# kitten    121
# senior    112
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     157
# senior     37
# kitten     14
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     387
# kitten    121
# senior    112
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     122
# senior     37
# kitten     14
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 774, 1: 605, 2: 560})
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Epoch 1/1500
# 31/31 [==============================] - 1s 7ms/step - loss: 0.4276 - accuracy: 0.8525
# Epoch 2/1500
# 31/31 [==============================] - 0s 6ms/step - loss: 0.0720 - accuracy: 0.9763
# Epoch 3/1500
# 31/31 [==============================] - 0s 6ms/step - loss: 0.0210 - accuracy: 0.9943
# Epoch 4/1500
# 31/31 [==============================] - 0s 7ms/step - loss: 0.0146 - accuracy: 0.9959
# Epoch 5/1500
# 31/31 [==============================] - 0s 7ms/step - loss: 0.0088 - accuracy: 0.9979
# Epoch 6/1500
# 31/31 [==============================] - 0s 6ms/step - loss: 0.0073 - accuracy: 0.9990
# Epoch 7/1500
# 31/31 [==============================] - 0s 7ms/step - loss: 0.0040 - accuracy: 0.9995
# Epoch 8/1500
# 31/31 [==============================] - 0s 7ms/step - loss: 0.0097 - accuracy: 0.9964
# Epoch 9/1500
# 31/31 [==============================] - 0s 7ms/step - loss: 0.0061 - accuracy: 0.9974
# Epoch 10/1500
# 31/31 [==============================] - 0s 7ms/step - loss: 0.0048 - accuracy: 0.9995
# Epoch 11/1500
# 31/31 [==============================] - 0s 7ms/step - loss: 0.0039 - accuracy: 0.9990
# Epoch 12/1500
# 31/31 [==============================] - 0s 7ms/step - loss: 0.0097 - accuracy: 0.9969
# Epoch 13/1500
# 31/31 [==============================] - 0s 6ms/step - loss: 0.0043 - accuracy: 0.9990
# Epoch 14/1500
# 31/31 [==============================] - 0s 6ms/step - loss: 0.0046 - accuracy: 0.9979
# Epoch 15/1500
# 31/31 [==============================] - 0s 6ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 16/1500
# 31/31 [==============================] - 0s 6ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 17/1500
# 31/31 [==============================] - 0s 6ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 18/1500
# 31/31 [==============================] - 0s 7ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 19/1500
# 31/31 [==============================] - 0s 7ms/step - loss: 0.0021 - accuracy: 0.9995
# Epoch 20/1500
# 31/31 [==============================] - 0s 7ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 21/1500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.0023 - accuracy: 0.9990
# Epoch 22/1500
# 31/31 [==============================] - 0s 7ms/step - loss: 0.0025 - accuracy: 0.9990
# Epoch 23/1500
# 31/31 [==============================] - 0s 7ms/step - loss: 0.0028 - accuracy: 0.9990
# Epoch 24/1500
# 31/31 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 25/1500
# 31/31 [==============================] - 0s 7ms/step - loss: 6.6547e-04 - accuracy: 1.0000
# Epoch 26/1500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 0.9995
# Epoch 27/1500
# 31/31 [==============================] - 0s 9ms/step - loss: 9.7033e-04 - accuracy: 1.0000
# Epoch 28/1500
# 31/31 [==============================] - 0s 7ms/step - loss: 4.0846e-04 - accuracy: 1.0000
# Epoch 29/1500
# 31/31 [==============================] - 0s 8ms/step - loss: 5.9570e-04 - accuracy: 1.0000
# Epoch 30/1500
# 31/31 [==============================] - 0s 7ms/step - loss: 0.0019 - accuracy: 0.9995
# Epoch 31/1500
# 31/31 [==============================] - 0s 6ms/step - loss: 0.0021 - accuracy: 0.9990
# Epoch 32/1500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.0017 - accuracy: 0.9995
# Epoch 33/1500
# 31/31 [==============================] - 0s 7ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 34/1500
# 31/31 [==============================] - 0s 7ms/step - loss: 4.5050e-04 - accuracy: 1.0000
# Epoch 35/1500
# 31/31 [==============================] - 0s 8ms/step - loss: 4.5207e-04 - accuracy: 1.0000
# Epoch 36/1500
# 31/31 [==============================] - 0s 6ms/step - loss: 3.2117e-04 - accuracy: 1.0000
# Epoch 37/1500
# 31/31 [==============================] - 0s 7ms/step - loss: 4.2084e-04 - accuracy: 1.0000
# Epoch 38/1500
# 31/31 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 0.9995
# Epoch 39/1500
# 31/31 [==============================] - 0s 8ms/step - loss: 4.7778e-04 - accuracy: 1.0000
# Epoch 40/1500
# 31/31 [==============================] - 0s 7ms/step - loss: 6.1047e-04 - accuracy: 1.0000
# Epoch 41/1500
# 31/31 [==============================] - 1s 18ms/step - loss: 8.3891e-04 - accuracy: 1.0000
# Epoch 42/1500
# 31/31 [==============================] - 0s 8ms/step - loss: 1.9854e-04 - accuracy: 1.0000
# Epoch 43/1500
# 31/31 [==============================] - 0s 8ms/step - loss: 3.8916e-04 - accuracy: 1.0000
# Epoch 44/1500
# 31/31 [==============================] - 0s 9ms/step - loss: 5.0331e-04 - accuracy: 1.0000
# Epoch 45/1500
# 31/31 [==============================] - 0s 8ms/step - loss: 2.6452e-04 - accuracy: 1.0000
# Epoch 46/1500
# 31/31 [==============================] - 0s 7ms/step - loss: 2.6102e-04 - accuracy: 1.0000
# Epoch 47/1500
# 31/31 [==============================] - 0s 13ms/step - loss: 1.4300e-04 - accuracy: 1.0000
# Epoch 48/1500
# 31/31 [==============================] - 0s 9ms/step - loss: 1.9399e-04 - accuracy: 1.0000
# Epoch 49/1500
# 31/31 [==============================] - 0s 6ms/step - loss: 8.5080e-05 - accuracy: 1.0000
# Epoch 50/1500
# 31/31 [==============================] - 0s 7ms/step - loss: 1.2625e-04 - accuracy: 1.0000
# Epoch 51/1500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.0013 - accuracy: 0.9995
# Epoch 52/1500
# 31/31 [==============================] - 0s 8ms/step - loss: 4.6660e-04 - accuracy: 1.0000
# Epoch 53/1500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 54/1500
# 31/31 [==============================] - 0s 8ms/step - loss: 1.9241e-04 - accuracy: 1.0000
# Epoch 55/1500
# 31/31 [==============================] - 0s 7ms/step - loss: 7.2879e-04 - accuracy: 1.0000
# Epoch 56/1500
# 31/31 [==============================] - 0s 7ms/step - loss: 4.1907e-04 - accuracy: 1.0000
# Epoch 57/1500
# 31/31 [==============================] - 0s 7ms/step - loss: 1.5141e-04 - accuracy: 1.0000
# Epoch 58/1500
# 31/31 [==============================] - 0s 8ms/step - loss: 1.9189e-04 - accuracy: 1.0000
# Epoch 59/1500
# 31/31 [==============================] - 0s 7ms/step - loss: 2.9212e-04 - accuracy: 1.0000
# Epoch 60/1500
# 31/31 [==============================] - 0s 8ms/step - loss: 6.1665e-05 - accuracy: 1.0000
# Epoch 61/1500
# 31/31 [==============================] - 0s 8ms/step - loss: 1.4391e-04 - accuracy: 1.0000
# Epoch 62/1500
# 31/31 [==============================] - 0s 7ms/step - loss: 1.4117e-04 - accuracy: 1.0000
# Epoch 63/1500
# 31/31 [==============================] - 0s 7ms/step - loss: 2.9637e-04 - accuracy: 1.0000
# Epoch 64/1500
# 31/31 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 0.9995
# Epoch 65/1500
# 31/31 [==============================] - 0s 12ms/step - loss: 0.0110 - accuracy: 0.9979
# Epoch 66/1500
# 27/31 [=========================>....] - ETA: 0s - loss: 0.0048 - accuracy: 0.9983Restoring model weights from the end of the best epoch: 36.
# 31/31 [==============================] - 0s 9ms/step - loss: 0.0044 - accuracy: 0.9985
# Epoch 66: early stopping
# 6/6 [==============================] - 0s 2ms/step - loss: 2.2990 - accuracy: 0.7514
# 6/6 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.74 (20/27)
# Before appending - Cat IDs: 0, Predictions: 0, Actuals: 0, Gender: 0
# After appending - Cat IDs: 173, Predictions: 173, Actuals: 173, Gender: 173
# Final Test Results - Loss: 2.299041509628296, Accuracy: 0.7514451146125793, Precision: 0.7190911162203029, Recall: 0.7211004915922948, F1 Score: 0.7200627082108563
# Confusion Matrix:
#  [[100   2  20]
#  [  2  12   0]
#  [ 19   0  18]]
# outer_fold 2
# Train Set Group Distribution:
# 046A    45
# 000A    39
# 103A    33
# 002B    30
# 020A    20
# 000B    19
# 057A    17
# 019A    17
# 074A    16
# 097A    15
# 106A    13
# 055A    12
# 116A    12
# 101A    12
# 051A    12
# 028A    11
# 067A    11
# 063A    11
# 025A    10
# 059A    10
# 040A    10
# 014B    10
# 065A     9
# 005A     9
# 033A     9
# 022A     9
# 016A     9
# 001A     9
# 013B     8
# 068A     8
# 095A     7
# 036A     7
# 015A     7
# 031A     7
# 039A     6
# 007A     6
# 075A     5
# 108A     5
# 050A     5
# 044A     5
# 070A     5
# 094A     5
# 008A     5
# 021A     5
# 045A     4
# 003A     4
# 009A     4
# 104A     4
# 023B     4
# 053A     3
# 113A     3
# 014A     3
# 034A     3
# 062A     3
# 058A     3
# 035A     2
# 011A     2
# 025B     2
# 032A     2
# 087A     2
# 018A     2
# 069A     2
# 038A     2
# 048A     1
# 100A     1
# 110A     1
# 091A     1
# 115A     1
# 019B     1
# 088A     1
# 004A     1
# 064A     1
# 066A     1
# 073A     1
# 076A     1
# 026C     1
# 096A     1
# 041A     1
# 092A     1
# 049A     1
# 043A     1
# 026B     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 047A    22
# 029A    15
# 097B    14
# 002A    13
# 111A    12
# 042A    11
# 051B     9
# 071A     9
# 072A     9
# 117A     7
# 027A     7
# 099A     6
# 023A     6
# 109A     5
# 025C     4
# 026A     4
# 056A     3
# 012A     3
# 010A     3
# 060A     3
# 006A     3
# 105A     3
# 052A     2
# 054A     2
# 061A     2
# 102A     2
# 037A     2
# 093A     2
# 090A     1
# 024A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    228
# F    195
# X    185
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    91
# M    58
# F    36
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [000A, 033A, 015A, 001A, 103A, 028A, 019A, 074...
# kitten    [044A, 014B, 040A, 046A, 050A, 043A, 049A, 041...
# senior    [097A, 057A, 106A, 104A, 055A, 059A, 113A, 116...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [006A, 071A, 097B, 029A, 072A, 002A, 023A, 027...
# kitten                             [111A, 047A, 042A, 109A]
# senior     [093A, 051B, 054A, 117A, 056A, 061A, 090A, 024A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 56, 'kitten': 12, 'senior': 14}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 18, 'kitten': 4, 'senior': 8}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002B' '003A' '004A' '005A' '007A' '008A' '009A'
#  '011A' '013B' '014A' '014B' '015A' '016A' '018A' '019A' '019B' '020A'
#  '021A' '022A' '023B' '025A' '025B' '026B' '026C' '028A' '031A' '032A'
#  '033A' '034A' '035A' '036A' '038A' '039A' '040A' '041A' '043A' '044A'
#  '045A' '046A' '048A' '049A' '050A' '051A' '053A' '055A' '057A' '058A'
#  '059A' '062A' '063A' '064A' '065A' '066A' '067A' '068A' '069A' '070A'
#  '073A' '074A' '075A' '076A' '087A' '088A' '091A' '092A' '094A' '095A'
#  '096A' '097A' '100A' '101A' '103A' '104A' '106A' '108A' '110A' '113A'
#  '115A' '116A']
# Unique Test Group IDs:
# ['002A' '006A' '010A' '012A' '023A' '024A' '025C' '026A' '027A' '029A'
#  '037A' '042A' '047A' '051B' '052A' '054A' '056A' '060A' '061A' '071A'
#  '072A' '090A' '093A' '097B' '099A' '102A' '105A' '109A' '111A' '117A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002B' '003A' '004A' '005A' '007A' '008A' '009A'
#  '011A' '013B' '014A' '014B' '015A' '016A' '018A' '019A' '019B' '020A'
#  '021A' '022A' '023B' '025A' '025B' '026B' '026C' '028A' '031A' '032A'
#  '033A' '034A' '035A' '036A' '038A' '039A' '040A' '041A' '043A' '044A'
#  '045A' '046A' '048A' '049A' '050A' '051A' '053A' '055A' '057A' '058A'
#  '059A' '062A' '063A' '064A' '065A' '066A' '067A' '068A' '069A' '070A'
#  '073A' '074A' '075A' '076A' '087A' '088A' '091A' '092A' '094A' '095A'
#  '096A' '097A' '100A' '101A' '103A' '104A' '106A' '108A' '110A' '113A'
#  '115A' '116A']
# AFTER SWAP - Unique Test Group IDs:
# ['002A' '006A' '010A' '012A' '023A' '024A' '025C' '026A' '027A' '029A'
#  '037A' '042A' '047A' '051B' '052A' '054A' '056A' '060A' '061A' '071A'
#  '072A' '090A' '093A' '097B' '099A' '102A' '105A' '109A' '111A' '117A']
# Length of X_train_val:
# 608
# Length of y_train_val:
# 608
# Length of groups_train_val:
# 608
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     401
# senior    122
# kitten     85
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     108
# kitten     50
# senior     27
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     401
# senior    122
# kitten     85
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     108
# kitten     50
# senior     27
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 802, 2: 610, 1: 425})
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Epoch 1/1500
# 29/29 [==============================] - 1s 7ms/step - loss: 0.3594 - accuracy: 0.8819
# Epoch 2/1500
# 29/29 [==============================] - 0s 7ms/step - loss: 0.0448 - accuracy: 0.9869
# Epoch 3/1500
# 29/29 [==============================] - 0s 8ms/step - loss: 0.0122 - accuracy: 0.9973
# Epoch 4/1500
# 29/29 [==============================] - 0s 8ms/step - loss: 0.0099 - accuracy: 0.9984
# Epoch 5/1500
# 29/29 [==============================] - 0s 8ms/step - loss: 0.0087 - accuracy: 0.9984
# Epoch 6/1500
# 29/29 [==============================] - 0s 7ms/step - loss: 0.0062 - accuracy: 0.9989
# Epoch 7/1500
# 29/29 [==============================] - 0s 9ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 8/1500
# 29/29 [==============================] - 0s 9ms/step - loss: 0.0029 - accuracy: 0.9995
# Epoch 9/1500
# 29/29 [==============================] - 0s 8ms/step - loss: 0.0022 - accuracy: 0.9995
# Epoch 10/1500
# 29/29 [==============================] - 0s 7ms/step - loss: 0.0032 - accuracy: 0.9995
# Epoch 11/1500
# 29/29 [==============================] - 0s 7ms/step - loss: 0.0020 - accuracy: 0.9995
# Epoch 12/1500
# 29/29 [==============================] - 0s 8ms/step - loss: 0.0022 - accuracy: 0.9995
# Epoch 13/1500
# 29/29 [==============================] - 0s 8ms/step - loss: 0.0040 - accuracy: 0.9989
# Epoch 14/1500
# 29/29 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 15/1500
# 29/29 [==============================] - 0s 7ms/step - loss: 0.0027 - accuracy: 0.9995
# Epoch 16/1500
# 29/29 [==============================] - 0s 8ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 17/1500
# 29/29 [==============================] - 0s 8ms/step - loss: 5.7108e-04 - accuracy: 1.0000
# Epoch 18/1500
# 29/29 [==============================] - 0s 7ms/step - loss: 0.0031 - accuracy: 0.9995
# Epoch 19/1500
# 29/29 [==============================] - 0s 7ms/step - loss: 3.9168e-04 - accuracy: 1.0000
# Epoch 20/1500
# 29/29 [==============================] - 0s 7ms/step - loss: 8.4914e-04 - accuracy: 1.0000
# Epoch 21/1500
# 29/29 [==============================] - 0s 7ms/step - loss: 4.9917e-04 - accuracy: 1.0000
# Epoch 22/1500
# 29/29 [==============================] - 0s 6ms/step - loss: 3.8150e-04 - accuracy: 1.0000
# Epoch 23/1500
# 29/29 [==============================] - 0s 6ms/step - loss: 6.7673e-04 - accuracy: 1.0000
# Epoch 24/1500
# 29/29 [==============================] - 0s 6ms/step - loss: 8.0416e-04 - accuracy: 1.0000
# Epoch 25/1500
# 29/29 [==============================] - 0s 7ms/step - loss: 5.4213e-04 - accuracy: 1.0000
# Epoch 26/1500
# 29/29 [==============================] - 0s 6ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 27/1500
# 29/29 [==============================] - 0s 7ms/step - loss: 3.8775e-04 - accuracy: 1.0000
# Epoch 28/1500
# 29/29 [==============================] - 0s 7ms/step - loss: 3.9929e-04 - accuracy: 1.0000
# Epoch 29/1500
# 29/29 [==============================] - 0s 7ms/step - loss: 3.9211e-04 - accuracy: 1.0000
# Epoch 30/1500
# 29/29 [==============================] - 0s 7ms/step - loss: 5.1094e-04 - accuracy: 1.0000
# Epoch 31/1500
# 29/29 [==============================] - 0s 8ms/step - loss: 3.6725e-04 - accuracy: 1.0000
# Epoch 32/1500
# 29/29 [==============================] - 0s 8ms/step - loss: 9.6090e-04 - accuracy: 1.0000
# Epoch 33/1500
# 29/29 [==============================] - 0s 6ms/step - loss: 9.0819e-04 - accuracy: 1.0000
# Epoch 34/1500
# 29/29 [==============================] - 0s 7ms/step - loss: 5.1347e-04 - accuracy: 1.0000
# Epoch 35/1500
# 29/29 [==============================] - 0s 8ms/step - loss: 4.3608e-04 - accuracy: 1.0000
# Epoch 36/1500
# 29/29 [==============================] - 0s 10ms/step - loss: 0.0045 - accuracy: 0.9989
# Epoch 37/1500
# 29/29 [==============================] - 0s 8ms/step - loss: 7.2057e-04 - accuracy: 0.9995
# Epoch 38/1500
# 29/29 [==============================] - 0s 9ms/step - loss: 0.0061 - accuracy: 0.9978
# Epoch 39/1500
# 29/29 [==============================] - 0s 7ms/step - loss: 0.0069 - accuracy: 0.9973
# Epoch 40/1500
# 29/29 [==============================] - 0s 8ms/step - loss: 0.0038 - accuracy: 0.9984
# Epoch 41/1500
# 29/29 [==============================] - 0s 8ms/step - loss: 0.0030 - accuracy: 0.9989
# Epoch 42/1500
# 29/29 [==============================] - 0s 7ms/step - loss: 0.0035 - accuracy: 0.9995
# Epoch 43/1500
# 29/29 [==============================] - 0s 10ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 44/1500
# 29/29 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 0.9995
# Epoch 45/1500
# 29/29 [==============================] - 0s 7ms/step - loss: 7.9423e-04 - accuracy: 1.0000
# Epoch 46/1500
# 29/29 [==============================] - 0s 7ms/step - loss: 3.4338e-04 - accuracy: 1.0000
# Epoch 47/1500
# 24/29 [=======================>......] - ETA: 0s - loss: 0.0025 - accuracy: 0.9993  Restoring model weights from the end of the best epoch: 17.
# 29/29 [==============================] - 0s 13ms/step - loss: 0.0021 - accuracy: 0.9995
# Epoch 47: early stopping
# 6/6 [==============================] - 0s 5ms/step - loss: 3.4803 - accuracy: 0.5838
# 6/6 [==============================] - 0s 5ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.60 (18/30)
# Before appending - Cat IDs: 173, Predictions: 173, Actuals: 173, Gender: 173
# After appending - Cat IDs: 358, Predictions: 358, Actuals: 358, Gender: 358
# Final Test Results - Loss: 3.480332851409912, Accuracy: 0.5837838053703308, Precision: 0.556304282719377, Recall: 0.3855555555555555, F1 Score: 0.3824959162966041
# Confusion Matrix:
#  [[95  0 13]
#  [38 12  0]
#  [26  0  1]]
# outer_fold 3
# Train Set Group Distribution:
# 046A    45
# 000A    39
# 047A    22
# 000B    19
# 057A    17
# 019A    17
# 074A    16
# 029A    15
# 097A    15
# 097B    14
# 002A    13
# 051A    12
# 116A    12
# 055A    12
# 101A    12
# 111A    12
# 028A    11
# 063A    11
# 042A    11
# 025A    10
# 040A    10
# 014B    10
# 059A    10
# 033A     9
# 022A     9
# 005A     9
# 072A     9
# 051B     9
# 071A     9
# 013B     8
# 068A     8
# 036A     7
# 095A     7
# 117A     7
# 027A     7
# 039A     6
# 099A     6
# 023A     6
# 070A     5
# 109A     5
# 008A     5
# 108A     5
# 045A     4
# 003A     4
# 009A     4
# 025C     4
# 104A     4
# 026A     4
# 056A     3
# 053A     3
# 012A     3
# 060A     3
# 006A     3
# 105A     3
# 113A     3
# 034A     3
# 010A     3
# 035A     2
# 011A     2
# 061A     2
# 102A     2
# 037A     2
# 052A     2
# 032A     2
# 069A     2
# 018A     2
# 093A     2
# 054A     2
# 087A     2
# 041A     1
# 024A     1
# 090A     1
# 100A     1
# 091A     1
# 088A     1
# 019B     1
# 092A     1
# 048A     1
# 076A     1
# 096A     1
# 043A     1
# 049A     1
# 026B     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 103A    33
# 002B    30
# 020A    20
# 106A    13
# 067A    11
# 001A     9
# 065A     9
# 016A     9
# 015A     7
# 031A     7
# 007A     6
# 044A     5
# 094A     5
# 075A     5
# 050A     5
# 021A     5
# 023B     4
# 014A     3
# 058A     3
# 062A     3
# 038A     2
# 025B     2
# 073A     1
# 064A     1
# 026C     1
# 066A     1
# 004A     1
# 115A     1
# 110A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    256
# F    206
# M    128
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# M    158
# F     25
# X     20
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [006A, 000A, 033A, 071A, 097B, 028A, 019A, 074...
# kitten    [014B, 111A, 040A, 046A, 047A, 042A, 109A, 043...
# senior    [093A, 097A, 057A, 104A, 055A, 059A, 113A, 116...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [015A, 001A, 103A, 067A, 020A, 062A, 002B, 065...
# kitten                             [044A, 050A, 115A, 110A]
# senior                             [106A, 058A, 016A, 094A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 53, 'kitten': 12, 'senior': 18}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 21, 'kitten': 4, 'senior': 4}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '002A' '003A' '005A' '006A' '008A' '009A' '010A' '011A'
#  '012A' '013B' '014B' '018A' '019A' '019B' '022A' '023A' '024A' '025A'
#  '025C' '026A' '026B' '027A' '028A' '029A' '032A' '033A' '034A' '035A'
#  '036A' '037A' '039A' '040A' '041A' '042A' '043A' '045A' '046A' '047A'
#  '048A' '049A' '051A' '051B' '052A' '053A' '054A' '055A' '056A' '057A'
#  '059A' '060A' '061A' '063A' '068A' '069A' '070A' '071A' '072A' '074A'
#  '076A' '087A' '088A' '090A' '091A' '092A' '093A' '095A' '096A' '097A'
#  '097B' '099A' '100A' '101A' '102A' '104A' '105A' '108A' '109A' '111A'
#  '113A' '116A' '117A']
# Unique Test Group IDs:
# ['001A' '002B' '004A' '007A' '014A' '015A' '016A' '020A' '021A' '023B'
#  '025B' '026C' '031A' '038A' '044A' '050A' '058A' '062A' '064A' '065A'
#  '066A' '067A' '073A' '075A' '094A' '103A' '106A' '110A' '115A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '002A' '003A' '005A' '006A' '008A' '009A' '010A' '011A'
#  '012A' '013B' '014B' '018A' '019A' '019B' '022A' '023A' '024A' '025A'
#  '025C' '026A' '026B' '027A' '028A' '029A' '032A' '033A' '034A' '035A'
#  '036A' '037A' '039A' '040A' '041A' '042A' '043A' '045A' '046A' '047A'
#  '048A' '049A' '051A' '051B' '052A' '053A' '054A' '055A' '056A' '057A'
#  '059A' '060A' '061A' '063A' '068A' '069A' '070A' '071A' '072A' '074A'
#  '076A' '087A' '088A' '090A' '091A' '092A' '093A' '095A' '096A' '097A'
#  '097B' '099A' '100A' '101A' '102A' '104A' '105A' '108A' '109A' '111A'
#  '113A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['001A' '002B' '004A' '007A' '014A' '015A' '016A' '020A' '021A' '023B'
#  '025B' '026C' '031A' '038A' '044A' '050A' '058A' '062A' '064A' '065A'
#  '066A' '067A' '073A' '075A' '094A' '103A' '106A' '110A' '115A']
# Length of X_train_val:
# 590
# Length of y_train_val:
# 590
# Length of groups_train_val:
# 590
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     348
# kitten    123
# senior    119
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     161
# senior     30
# kitten     12
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     348
# kitten    123
# senior    119
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     161
# senior     30
# kitten     12
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 696, 1: 615, 2: 595})
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Epoch 1/1500
# 30/30 [==============================] - 2s 9ms/step - loss: 0.3708 - accuracy: 0.8725
# Epoch 2/1500
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0653 - accuracy: 0.9769
# Epoch 3/1500
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0176 - accuracy: 0.9953
# Epoch 4/1500
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0088 - accuracy: 0.9990
# Epoch 5/1500
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0069 - accuracy: 0.9979
# Epoch 6/1500
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0052 - accuracy: 0.9984
# Epoch 7/1500
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0048 - accuracy: 0.9995
# Epoch 8/1500
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0040 - accuracy: 0.9990
# Epoch 9/1500
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0035 - accuracy: 0.9990
# Epoch 10/1500
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0025 - accuracy: 0.9995
# Epoch 11/1500
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 12/1500
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0038 - accuracy: 0.9990
# Epoch 13/1500
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0037 - accuracy: 0.9995
# Epoch 14/1500
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0022 - accuracy: 0.9995
# Epoch 15/1500
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0023 - accuracy: 0.9995
# Epoch 16/1500
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 17/1500
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 18/1500
# 30/30 [==============================] - 0s 8ms/step - loss: 6.8884e-04 - accuracy: 1.0000
# Epoch 19/1500
# 30/30 [==============================] - 0s 8ms/step - loss: 6.3306e-04 - accuracy: 1.0000
# Epoch 20/1500
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0018 - accuracy: 0.9995
# Epoch 21/1500
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0018 - accuracy: 0.9995
# Epoch 22/1500
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0089 - accuracy: 0.9979
# Epoch 23/1500
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 24/1500
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 25/1500
# 30/30 [==============================] - 0s 7ms/step - loss: 5.9605e-04 - accuracy: 1.0000
# Epoch 26/1500
# 30/30 [==============================] - 0s 8ms/step - loss: 9.9535e-04 - accuracy: 1.0000
# Epoch 27/1500
# 30/30 [==============================] - 0s 14ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 28/1500
# 30/30 [==============================] - 0s 9ms/step - loss: 4.0099e-04 - accuracy: 1.0000
# Epoch 29/1500
# 30/30 [==============================] - 0s 7ms/step - loss: 9.4590e-04 - accuracy: 1.0000
# Epoch 30/1500
# 30/30 [==============================] - 0s 7ms/step - loss: 5.7000e-04 - accuracy: 1.0000
# Epoch 31/1500
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0026 - accuracy: 0.9990
# Epoch 32/1500
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 0.9995
# Epoch 33/1500
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0027 - accuracy: 0.9995
# Epoch 34/1500
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 0.9995
# Epoch 35/1500
# 30/30 [==============================] - 0s 7ms/step - loss: 8.7358e-04 - accuracy: 1.0000
# Epoch 36/1500
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0020 - accuracy: 0.9995
# Epoch 37/1500
# 30/30 [==============================] - 0s 7ms/step - loss: 7.5299e-04 - accuracy: 1.0000
# Epoch 38/1500
# 30/30 [==============================] - 0s 8ms/step - loss: 5.7576e-04 - accuracy: 1.0000
# Epoch 39/1500
# 30/30 [==============================] - 0s 7ms/step - loss: 4.4803e-04 - accuracy: 1.0000
# Epoch 40/1500
# 30/30 [==============================] - 0s 6ms/step - loss: 3.7563e-04 - accuracy: 1.0000
# Epoch 41/1500
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0094 - accuracy: 0.9979
# Epoch 42/1500
# 30/30 [==============================] - 0s 7ms/step - loss: 5.6508e-04 - accuracy: 1.0000
# Epoch 43/1500
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0023 - accuracy: 0.9995
# Epoch 44/1500
# 30/30 [==============================] - 0s 8ms/step - loss: 8.2108e-04 - accuracy: 1.0000
# Epoch 45/1500
# 30/30 [==============================] - 0s 7ms/step - loss: 7.3991e-04 - accuracy: 1.0000
# Epoch 46/1500
# 30/30 [==============================] - 0s 7ms/step - loss: 8.6110e-04 - accuracy: 1.0000
# Epoch 47/1500
# 30/30 [==============================] - 0s 7ms/step - loss: 5.7941e-04 - accuracy: 1.0000
# Epoch 48/1500
# 30/30 [==============================] - 0s 7ms/step - loss: 7.5325e-04 - accuracy: 0.9995
# Epoch 49/1500
# 30/30 [==============================] - 0s 7ms/step - loss: 5.1228e-04 - accuracy: 1.0000
# Epoch 50/1500
# 30/30 [==============================] - 0s 6ms/step - loss: 1.6198e-04 - accuracy: 1.0000
# Epoch 51/1500
# 30/30 [==============================] - 0s 8ms/step - loss: 2.6206e-04 - accuracy: 1.0000
# Epoch 52/1500
# 30/30 [==============================] - 0s 7ms/step - loss: 1.7926e-04 - accuracy: 1.0000
# Epoch 53/1500
# 30/30 [==============================] - 0s 6ms/step - loss: 1.5362e-04 - accuracy: 1.0000
# Epoch 54/1500
# 30/30 [==============================] - 0s 7ms/step - loss: 1.6608e-04 - accuracy: 1.0000
# Epoch 55/1500
# 30/30 [==============================] - 0s 6ms/step - loss: 2.2968e-04 - accuracy: 1.0000
# Epoch 56/1500
# 30/30 [==============================] - 0s 6ms/step - loss: 9.0419e-05 - accuracy: 1.0000
# Epoch 57/1500
# 30/30 [==============================] - 0s 7ms/step - loss: 1.3214e-04 - accuracy: 1.0000
# Epoch 58/1500
# 25/30 [========================>.....] - ETA: 0s - loss: 1.9951e-04 - accuracy: 1.0000Restoring model weights from the end of the best epoch: 28.
# 30/30 [==============================] - 0s 7ms/step - loss: 1.8294e-04 - accuracy: 1.0000
# Epoch 58: early stopping
# 7/7 [==============================] - 0s 3ms/step - loss: 1.3324 - accuracy: 0.8079
# 7/7 [==============================] - 0s 2ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.90 (26/29)
# Before appending - Cat IDs: 358, Predictions: 358, Actuals: 358, Gender: 358
# After appending - Cat IDs: 561, Predictions: 561, Actuals: 561, Gender: 561
# Final Test Results - Loss: 1.3323997259140015, Accuracy: 0.807881772518158, Precision: 0.6739051360395751, Recall: 0.7474810213940648, F1 Score: 0.7046789174200044
# Confusion Matrix:
#  [[141   2  18]
#  [  0  12   0]
#  [ 17   2  11]]
# outer_fold 4
# Train Set Group Distribution:
# 000A    39
# 103A    33
# 002B    30
# 047A    22
# 020A    20
# 000B    19
# 019A    17
# 097A    15
# 029A    15
# 097B    14
# 002A    13
# 106A    13
# 111A    12
# 051A    12
# 042A    11
# 063A    11
# 067A    11
# 028A    11
# 040A    10
# 059A    10
# 072A     9
# 065A     9
# 051B     9
# 005A     9
# 022A     9
# 016A     9
# 071A     9
# 001A     9
# 013B     8
# 095A     7
# 036A     7
# 015A     7
# 027A     7
# 117A     7
# 031A     7
# 007A     6
# 039A     6
# 099A     6
# 023A     6
# 021A     5
# 075A     5
# 044A     5
# 050A     5
# 109A     5
# 094A     5
# 026A     4
# 003A     4
# 025C     4
# 023B     4
# 056A     3
# 010A     3
# 060A     3
# 058A     3
# 012A     3
# 006A     3
# 014A     3
# 062A     3
# 105A     3
# 038A     2
# 102A     2
# 052A     2
# 037A     2
# 025B     2
# 018A     2
# 087A     2
# 093A     2
# 069A     2
# 054A     2
# 061A     2
# 019B     1
# 110A     1
# 115A     1
# 090A     1
# 024A     1
# 026C     1
# 004A     1
# 048A     1
# 066A     1
# 041A     1
# 049A     1
# 091A     1
# 064A     1
# 073A     1
# 043A     1
# 076A     1
# 026B     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 046A    45
# 057A    17
# 074A    16
# 055A    12
# 101A    12
# 116A    12
# 014B    10
# 025A    10
# 033A     9
# 068A     8
# 108A     5
# 070A     5
# 008A     5
# 104A     4
# 009A     4
# 045A     4
# 113A     3
# 034A     3
# 053A     3
# 011A     2
# 035A     2
# 032A     2
# 092A     1
# 096A     1
# 088A     1
# 100A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    253
# X    184
# F    159
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    92
# F    72
# M    33
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [006A, 000A, 015A, 001A, 103A, 071A, 097B, 028...
# kitten    [044A, 111A, 040A, 047A, 042A, 109A, 050A, 043...
# senior    [093A, 097A, 106A, 059A, 051B, 054A, 117A, 056...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [033A, 074A, 101A, 034A, 009A, 025A, 070A, 032...
# kitten                                   [014B, 046A, 045A]
# senior           [057A, 104A, 055A, 113A, 116A, 108A, 011A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 58, 'kitten': 13, 'senior': 15}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 16, 'kitten': 3, 'senior': 7}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '004A' '005A' '006A' '007A'
#  '010A' '012A' '013B' '014A' '015A' '016A' '018A' '019A' '019B' '020A'
#  '021A' '022A' '023A' '023B' '024A' '025B' '025C' '026A' '026B' '026C'
#  '027A' '028A' '029A' '031A' '036A' '037A' '038A' '039A' '040A' '041A'
#  '042A' '043A' '044A' '047A' '048A' '049A' '050A' '051A' '051B' '052A'
#  '054A' '056A' '058A' '059A' '060A' '061A' '062A' '063A' '064A' '065A'
#  '066A' '067A' '069A' '071A' '072A' '073A' '075A' '076A' '087A' '090A'
#  '091A' '093A' '094A' '095A' '097A' '097B' '099A' '102A' '103A' '105A'
#  '106A' '109A' '110A' '111A' '115A' '117A']
# Unique Test Group IDs:
# ['008A' '009A' '011A' '014B' '025A' '032A' '033A' '034A' '035A' '045A'
#  '046A' '053A' '055A' '057A' '068A' '070A' '074A' '088A' '092A' '096A'
#  '100A' '101A' '104A' '108A' '113A' '116A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'046A'}
# Removed from Training/Validation Set:
# {'109A'}
# Moved to Test Set:
# {'109A'}
# Removed from Test Set
# {'046A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '004A' '005A' '006A' '007A'
#  '010A' '012A' '013B' '014A' '015A' '016A' '018A' '019A' '019B' '020A'
#  '021A' '022A' '023A' '023B' '024A' '025B' '025C' '026A' '026B' '026C'
#  '027A' '028A' '029A' '031A' '036A' '037A' '038A' '039A' '040A' '041A'
#  '042A' '043A' '044A' '046A' '047A' '048A' '049A' '050A' '051A' '051B'
#  '052A' '054A' '056A' '058A' '059A' '060A' '061A' '062A' '063A' '064A'
#  '065A' '066A' '067A' '069A' '071A' '072A' '073A' '075A' '076A' '087A'
#  '090A' '091A' '093A' '094A' '095A' '097A' '097B' '099A' '102A' '103A'
#  '105A' '106A' '110A' '111A' '115A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['008A' '009A' '011A' '014B' '025A' '032A' '033A' '034A' '035A' '045A'
#  '053A' '055A' '057A' '068A' '070A' '074A' '088A' '092A' '096A' '100A'
#  '101A' '104A' '108A' '109A' '113A' '116A']
# Length of X_train_val:
# 636
# Length of y_train_val:
# 636
# Length of groups_train_val:
# 636
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     426
# senior     94
# kitten     76
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     83
# kitten    59
# senior    55
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     426
# kitten    116
# senior     94
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     83
# senior    55
# kitten    19
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Age group distribution: Counter({0: 852, 1: 580, 2: 470})
# Epoch 1/1500
# 30/30 [==============================] - 1s 10ms/step - loss: 0.3801 - accuracy: 0.8675
# Epoch 2/1500
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0622 - accuracy: 0.9805
# Epoch 3/1500
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0168 - accuracy: 0.9979
# Epoch 4/1500
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0104 - accuracy: 0.9974
# Epoch 5/1500
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0117 - accuracy: 0.9968
# Epoch 6/1500
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0060 - accuracy: 0.9979
# Epoch 7/1500
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0040 - accuracy: 1.0000
# Epoch 8/1500
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0053 - accuracy: 0.9989
# Epoch 9/1500
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0028 - accuracy: 0.9995
# Epoch 10/1500
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0060 - accuracy: 0.9984
# Epoch 11/1500
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0027 - accuracy: 0.9995
# Epoch 12/1500
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0016 - accuracy: 0.9995
# Epoch 13/1500
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 14/1500
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 15/1500
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 16/1500
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 17/1500
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0019 - accuracy: 0.9995
# Epoch 18/1500
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 19/1500
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0019 - accuracy: 0.9995
# Epoch 20/1500
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 21/1500
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 22/1500
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 23/1500
# 30/30 [==============================] - 0s 7ms/step - loss: 5.3506e-04 - accuracy: 1.0000
# Epoch 24/1500
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0012 - accuracy: 0.9995
# Epoch 25/1500
# 30/30 [==============================] - 0s 7ms/step - loss: 9.8158e-04 - accuracy: 0.9995
# Epoch 26/1500
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 27/1500
# 30/30 [==============================] - 0s 7ms/step - loss: 7.0655e-04 - accuracy: 1.0000
# Epoch 28/1500
# 30/30 [==============================] - 0s 9ms/step - loss: 5.7060e-04 - accuracy: 1.0000
# Epoch 29/1500
# 30/30 [==============================] - 0s 6ms/step - loss: 9.6894e-04 - accuracy: 1.0000
# Epoch 30/1500
# 30/30 [==============================] - 0s 7ms/step - loss: 9.0341e-04 - accuracy: 1.0000
# Epoch 31/1500
# 30/30 [==============================] - 0s 8ms/step - loss: 4.3608e-04 - accuracy: 1.0000
# Epoch 32/1500
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 33/1500
# 30/30 [==============================] - 0s 6ms/step - loss: 5.5777e-04 - accuracy: 1.0000
# Epoch 34/1500
# 30/30 [==============================] - 0s 11ms/step - loss: 4.1081e-04 - accuracy: 1.0000
# Epoch 35/1500
# 30/30 [==============================] - 0s 10ms/step - loss: 4.8307e-04 - accuracy: 1.0000
# Epoch 36/1500
# 30/30 [==============================] - 0s 14ms/step - loss: 0.0012 - accuracy: 0.9995
# Epoch 37/1500
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0025 - accuracy: 0.9995
# Epoch 38/1500
# 30/30 [==============================] - 0s 13ms/step - loss: 7.4721e-04 - accuracy: 1.0000
# Epoch 39/1500
# 30/30 [==============================] - 0s 10ms/step - loss: 0.0015 - accuracy: 0.9995
# Epoch 40/1500
# 30/30 [==============================] - 0s 9ms/step - loss: 5.7866e-04 - accuracy: 1.0000
# Epoch 41/1500
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 42/1500
# 30/30 [==============================] - 0s 7ms/step - loss: 5.0603e-04 - accuracy: 1.0000
# Epoch 43/1500
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0015 - accuracy: 0.9995
# Epoch 44/1500
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0013 - accuracy: 0.9995
# Epoch 45/1500
# 30/30 [==============================] - 0s 6ms/step - loss: 7.2794e-04 - accuracy: 1.0000
# Epoch 46/1500
# 30/30 [==============================] - 0s 6ms/step - loss: 3.2472e-04 - accuracy: 1.0000
# Epoch 47/1500
# 30/30 [==============================] - 0s 6ms/step - loss: 2.5811e-04 - accuracy: 1.0000
# Epoch 48/1500
# 30/30 [==============================] - 0s 6ms/step - loss: 3.5464e-04 - accuracy: 1.0000
# Epoch 49/1500
# 30/30 [==============================] - 0s 9ms/step - loss: 8.6729e-04 - accuracy: 0.9995
# Epoch 50/1500
# 30/30 [==============================] - 0s 8ms/step - loss: 2.8449e-04 - accuracy: 1.0000
# Epoch 51/1500
# 30/30 [==============================] - 0s 7ms/step - loss: 3.4960e-04 - accuracy: 1.0000
# Epoch 52/1500
# 30/30 [==============================] - 0s 8ms/step - loss: 6.0914e-04 - accuracy: 1.0000
# Epoch 53/1500
# 24/30 [=======================>......] - ETA: 0s - loss: 0.0012 - accuracy: 1.0000  Restoring model weights from the end of the best epoch: 23.
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 53: early stopping
# 5/5 [==============================] - 0s 2ms/step - loss: 2.8144 - accuracy: 0.6051
# 5/5 [==============================] - 0s 3ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.69 (18/26)
# Before appending - Cat IDs: 561, Predictions: 561, Actuals: 561, Gender: 561
# After appending - Cat IDs: 718, Predictions: 718, Actuals: 718, Gender: 718
# Final Test Results - Loss: 2.8144266605377197, Accuracy: 0.6050955653190613, Precision: 0.6828703703703703, Recall: 0.49871063200169097, F1 Score: 0.5087127415656731
# Confusion Matrix:
#  [[77  2  4]
#  [11  7  1]
#  [44  0 11]]
#
# Final Average F1-Score across all UNSEEN TEST sets: 0.5789875708732846
#
# Final Average Loss across all UNSEEN TEST sets: 2.4815501868724823
#
# Final Average Accuracy across all UNSEEN TEST sets: 0.6870515644550323
#
# Final Average Precision across all UNSEEN TEST sets: 0.6580427263374063
#
# Final Average Recall across all UNSEEN TEST sets: 0.5882119251359015

# %%
seed_1_folds_values = (unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1)

# Plotting all fold metrics
seed_1_folds_plot = plot_all_metrics(unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1, "Folds", "Fold Number")

# %% [markdown]
# ## Majority Voting on Total Entries per cat_id

# %%
# Debugging print statements
print(f'Checking - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
# Out:
# Checking - Cat IDs: 718, Predictions: 718, Actuals: 718, Gender: 718

# %%
# Create results df
full_results = pd.DataFrame({
    'cat_id': all_cat_ids,
    'predicted_age_group': all_predicted_age_groups,
    'actual_age_group': all_actual_age_groups,
    'all_gender': all_gender
})

# create a correct majority prediction column
full_results['correct'] = full_results['predicted_age_group'] == full_results['actual_age_group']

# %%
# Group by cat_id and aggregate predicted age groups
majority_votes = full_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first()

# Calculate the accuracy of majority voting
correct_predictions = (majority_votes == actual_groups).sum()
total_cats = len(actual_groups)
majority_vote_accuracy = correct_predictions / total_cats

logger(f"Overall Majority Vote Accuracy for cat_id: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

# store for final evaluation 
all_majority_vote_accuracies.append(majority_vote_accuracy)
# Out:
# Overall Majority Vote Accuracy for cat_id: 0.74 (81/110)

# %%
# Detailed df with predictions, actual labels, and comparison including majority vote
detailed_results = full_results.groupby('cat_id').apply(
    lambda x: pd.Series({
        'Predictions': list(x['predicted_age_group']),
        'Majority Vote': x['predicted_age_group'].mode()[0],
        'Actual Age Group': x['actual_age_group'].iloc[0],
        'Correct Majority Vote': x['predicted_age_group'].mode()[0] == x['actual_age_group'].iloc[0]
    })
).reset_index()

# Convert to DataFrame for better formatting and display
detailed_results = pd.DataFrame(detailed_results)

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 10)
pd.set_option('display.width', 1000)

sorted_detailed_results = detailed_results.sort_values(by='Correct Majority Vote', ascending=False)

# Display the sorted DataFrame
sorted_detailed_results
# Out:
#     cat_id                                        Predictions Majority Vote Actual Age Group  Correct Majority Vote
# 0     000B  [adult, senior, adult, adult, adult, adult, ad...         adult            adult                   True
# 45    039A         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 79    073A                                            [adult]         adult            adult                   True
# 78    072A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 77    071A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 76    070A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 74    068A  [adult, adult, adult, adult, senior, adult, ad...         adult            adult                   True
# 73    067A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 72    066A                                            [adult]         adult            adult                   True
# 71    065A  [senior, adult, adult, adult, kitten, senior, ...         adult            adult                   True
# 70    064A                                            [adult]         adult            adult                   True
# 69    063A  [adult, adult, senior, senior, senior, adult, ...         adult            adult                   True
# 68    062A                              [adult, adult, adult]         adult            adult                   True
# 66    060A                              [adult, adult, adult]         adult            adult                   True
# 65    059A  [senior, senior, senior, senior, senior, senio...        senior           senior                   True
# 64    058A                           [senior, senior, senior]        senior           senior                   True
# 59    053A                              [adult, adult, adult]         adult            adult                   True
# 53    048A                                           [kitten]        kitten           kitten                   True
# 51    045A                   [kitten, kitten, kitten, kitten]        kitten           kitten                   True
# 50    044A           [kitten, kitten, kitten, kitten, kitten]        kitten           kitten                   True
# 49    043A                                           [kitten]        kitten           kitten                   True
# 80    074A  [adult, adult, kitten, adult, adult, adult, ad...         adult            adult                   True
# 81    075A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 82    076A                                            [adult]         adult            adult                   True
# 95    100A                                            [adult]         adult            adult                   True
# 107   115A                                           [kitten]        kitten           kitten                   True
# 106   113A                            [adult, senior, senior]        senior           senior                   True
# 105   111A  [kitten, kitten, kitten, kitten, kitten, kitte...        kitten           kitten                   True
# 104   110A                                           [kitten]        kitten           kitten                   True
# 100   105A                              [adult, adult, adult]         adult            adult                   True
# 98    103A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 97    102A                                     [adult, adult]         adult            adult                   True
# 96    101A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 94    099A         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 83    087A                                     [adult, adult]         adult            adult                   True
# 93    097B  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 91    096A                                            [adult]         adult            adult                   True
# 90    095A  [senior, adult, adult, adult, adult, adult, ad...         adult            adult                   True
# 89    094A            [senior, senior, senior, adult, senior]        senior           senior                   True
# 87    092A                                            [adult]         adult            adult                   True
# 86    091A                                            [adult]         adult            adult                   True
# 85    090A                                           [senior]        senior           senior                   True
# 84    088A                                            [adult]         adult            adult                   True
# 46    040A  [kitten, kitten, kitten, kitten, kitten, kitte...        kitten           kitten                   True
# 55    050A           [kitten, kitten, kitten, kitten, kitten]        kitten           kitten                   True
# 44    038A                                     [adult, adult]         adult            adult                   True
# 15    014A                              [adult, adult, adult]         adult            adult                   True
# 29    025B                                    [senior, adult]         adult            adult                   True
# 28    025A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 43    037A                                    [senior, adult]         adult            adult                   True
# 25    023A         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 24    022A  [adult, adult, adult, kitten, adult, adult, ki...         adult            adult                   True
# 23    021A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 22    020A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 20    019A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 19    018A                                     [adult, adult]         adult            adult                   True
# 17    015A  [senior, adult, adult, senior, adult, adult, a...         adult            adult                   True
# 14    013B  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 31    026A                       [adult, adult, adult, adult]         adult            adult                   True
# 13    012A                              [adult, adult, adult]         adult            adult                   True
# 11    010A                             [adult, adult, senior]         adult            adult                   True
# 10    009A  [adult, adult, senior, adult, adult, adult, ad...         adult            adult                   True
# 9     008A               [adult, adult, adult, senior, adult]         adult            adult                   True
# 8     007A         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 7     006A                              [adult, adult, adult]         adult            adult                   True
# 5     004A                                            [adult]         adult            adult                   True
# 4     003A                       [adult, adult, adult, adult]         adult            adult                   True
# 3     002B  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 2     002A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 30    025C                       [adult, adult, adult, adult]         adult            adult                   True
# 26    023B                       [adult, adult, adult, adult]         adult            adult                   True
# 32    026B                                            [adult]         adult            adult                   True
# 34    027A  [adult, adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 33    026C                                            [adult]         adult            adult                   True
# 39    033A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 35    028A  [adult, adult, adult, senior, adult, adult, ad...         adult            adult                   True
# 42    036A  [adult, adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 37    031A  [adult, adult, adult, senior, adult, adult, ad...         adult            adult                   True
# 41    035A                                     [adult, adult]         adult            adult                   True
# 40    034A                            [adult, senior, kitten]         adult            adult                   True
# 38    032A                                     [adult, adult]         adult            adult                   True
# 99    104A                       [adult, adult, adult, adult]         adult           senior                  False
# 54    049A                                            [adult]         adult           kitten                  False
# 52    047A  [adult, adult, adult, adult, adult, adult, adu...         adult           kitten                  False
# 102   108A               [adult, adult, adult, senior, adult]         adult           senior                  False
# 6     005A  [senior, senior, senior, senior, senior, senio...        senior            adult                  False
# 101   106A  [adult, kitten, adult, senior, adult, adult, a...         adult           senior                  False
# 12    011A                                    [adult, senior]         adult           senior                  False
# 103   109A  [adult, adult, adult, adult, adult, adult, adu...         adult           kitten                  False
# 48    042A  [adult, adult, adult, adult, adult, adult, adu...         adult           kitten                  False
# 47    041A                                            [adult]         adult           kitten                  False
# 108   116A  [senior, senior, adult, adult, adult, adult, a...         adult           senior                  False
# 1     001A  [adult, senior, adult, senior, senior, senior,...        senior            adult                  False
# 57    051B  [adult, adult, adult, adult, adult, adult, adu...         adult           senior                  False
# 92    097A  [adult, senior, adult, adult, senior, senior, ...         adult           senior                  False
# 56    051A  [adult, adult, adult, adult, adult, senior, ad...         adult           senior                  False
# 58    052A                                   [senior, senior]        senior            adult                  False
# 88    093A                                     [adult, adult]         adult           senior                  False
# 16    014B  [senior, kitten, adult, adult, kitten, kitten,...         adult           kitten                  False
# 18    016A  [adult, adult, adult, adult, senior, adult, ad...         adult           senior                  False
# 60    054A                                     [adult, adult]         adult           senior                  False
# 61    055A  [adult, senior, senior, adult, adult, adult, a...         adult           senior                  False
# 21    019B                                           [senior]        senior            adult                  False
# 62    056A                              [adult, adult, adult]         adult           senior                  False
# 63    057A  [adult, adult, adult, adult, adult, adult, adu...         adult           senior                  False
# 36    029A  [senior, senior, adult, senior, senior, senior...        senior            adult                  False
# 27    024A                                            [adult]         adult           senior                  False
# 75    069A                                   [senior, senior]        senior            adult                  False
# 67    061A                                     [adult, adult]         adult           senior                  False
# 109   117A  [adult, adult, adult, adult, adult, adult, adult]         adult           senior                  False

# %%
# Create df for majority votes
majority_df = majority_votes.reset_index()
majority_df.columns = ['cat_id', 'Majority_Vote']

# Get actual groups for each cat_id
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first().reset_index()

# Merge majority votes with actual groups
majority_with_actual = pd.merge(majority_df, actual_groups, on='cat_id')

# Add a column to check if the majority vote was correct
majority_with_actual['Majority_Correct'] = majority_with_actual['Majority_Vote'] == majority_with_actual['actual_age_group']

# Count correct majority votes per class
correct_majority_votes_per_class = majority_with_actual.groupby('actual_age_group')['Majority_Correct'].sum()

print("Correct Majority Votes per Class:")
print(correct_majority_votes_per_class)
# Out:
# Correct Majority Votes per Class:
# actual_age_group
# adult     67
# kitten     9
# senior     5
# Name: Majority_Correct, dtype: int64

# %%
# Calculate the total count and the number of correct predictions for each class
class_stats = majority_with_actual.groupby('actual_age_group').agg(
    total_count=('Majority_Correct', 'size'),  # Total number of cases per class
    correct_count=('Majority_Correct', 'sum')  # Sum of correct predictions per class
).reset_index()

# Calculate accuracy for each class
class_stats['accuracy'] = class_stats['correct_count'] / class_stats['total_count'] * 100

# store for final evaluation 
all_majority_vote_details.append(class_stats)

# Log detailed stats
print("Detailed Class Statistics for Majority Votes:")
print(class_stats)
# Out:
# Detailed Class Statistics for Majority Votes:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult           73             67  91.780822
# 1           kitten           15              9  60.000000
# 2           senior           22              5  22.727273

# %%
# Plot for Detailed Class Statistics for Majority Votes
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Accuracy of Majority Votes by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Detailed Class Statistics

# %%
# Calculate the total count and the number of correct predictions for each class
class_stats = full_results.groupby('actual_age_group').agg(
    total_count=('correct', 'size'),
    correct_count=('correct', 'sum')
).reset_index()

# Calculate accuracy for each class
class_stats['accuracy'] = class_stats['correct_count'] / class_stats['total_count'] * 100

# store for final evaluation 
all_class_stats.append(class_stats)

# Log the detailed stats
print("Detailed Class Statistics:")
print(class_stats)
# Out:
# Detailed Class Statistics:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult          474            413  87.130802
# 1           kitten           95             43  45.263158
# 2           senior          149             41  27.516779

# %%
# Plot for Detailed Class Statistics (Overall)
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Overall Accuracy by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Gender Exploration

# %%
# Group by gender and calculate the total count, correct predictions, and accuracy
gender_stats = full_results.groupby('all_gender').agg(
    count=('cat_id', 'size'),  # Total number of cases per gender
    correct=('correct', 'sum')  # Sum of correct predictions per gender
).reset_index()

# Calculate accuracy for each gender
gender_stats['accuracy'] = (gender_stats['correct'] / gender_stats['count'] * 100).round(2)

# Display the DataFrame
print("Accuracy by Gender:")
print(gender_stats)

# store for final evaluation 
all_gender_stats.append(gender_stats)
# Out:
# Accuracy by Gender:
#   all_gender  count  correct  accuracy
# 0          F    196      137     69.90
# 1          M    286      219     76.57
# 2          X    236      141     59.75

# %%
# Plot for Accuracy by Gender
styled_barplot(gender_stats, 'all_gender', 'accuracy', 
               'Accuracy by Gender', 
               'Gender', 'Accuracy (%)')

# %% [markdown]
# ### Log current total CV Stats

# %%
print("Total Majority Vote Accuracy so far:", all_majority_vote_accuracies)
print("Total Class Statistics so far:\n", all_class_stats)
print("Total Gender Accuracy so far:\n", all_gender_stats)
# Out:
# Total Majority Vote Accuracy so far: [0.7363636363636363]
# Total Class Statistics so far:
#  [  actual_age_group  total_count  correct_count   accuracy
# 0            adult          474            413  87.130802
# 1           kitten           95             43  45.263158
# 2           senior          149             41  27.516779]
# Total Gender Accuracy so far:
#  [  all_gender  count  correct  accuracy
# 0          F    196      137     69.90
# 1          M    286      219     76.57
# 2          X    236      141     59.75]

# %% [markdown]
# # RANDOM SEED 2

# %%
# Set a fixed random seed for reproducibility
random.seed(int(random_seeds[1]))
np.random.seed(int(random_seeds[1]))
tf.random.set_seed(int(random_seeds[1]))

# Load datasets
dataframe = pd.read_csv('/Users/astrid/PycharmProjects/perch-2/scripts/perch_embeddings_april_10.csv')
augmented_df = pd.read_csv('/Users/astrid/PycharmProjects/perch-2/scripts/perch_embeddings_augm_d1.csv')

dataframe.drop('mean_freq', axis=1, inplace=True)

augmented_df.drop('mean_freq', axis=1, inplace=True)
augmented_df.drop('gender', axis=1, inplace=True)

def assign_age_group(age, age_groups):
    for group_name, age_range in age_groups.items():
        if age_range[0] <= age < age_range[1]:
            return group_name
    return 'Unknown'  # For any age that doesn't fit the defined groups

# Define age groups
age_groups = {
    'kitten': (0, 0.5),
    'adult': (0.5, 12),
    'senior': (12, 20)
}

# Create a new column for the age group
dataframe['age_group'] = dataframe['target'].apply(assign_age_group, age_groups=age_groups)
augmented_df['age_group'] = augmented_df['target'].apply(assign_age_group, age_groups=age_groups)

print(dataframe['age_group'].value_counts())
print(augmented_df['age_group'].value_counts())
# Out:
# adult     509
# senior    149
# kitten    135
# Name: age_group, dtype: int64
# senior    596
# kitten    540
# adult     509
# Name: age_group, dtype: int64

# %%
# Separate features and labels
X = dataframe.iloc[:, :-4].values  # all columns except the last four

# Encode the 'age_group' column as integers using LabelEncoder
label_encoder = LabelEncoder()
encoded_y = label_encoder.fit_transform(dataframe['age_group'].values)

# Use the encoded labels for splitting and one-hot encoding
y = encoded_y  

# Convert 'cat_id' column to numpy array to be used as groups array for GroupKFold
groups = dataframe['cat_id'].values

# %%
tf.keras.backend.clear_session()

# %% [markdown]
# ## Run Setup

# %%
all_cat_ids = []
all_predicted_age_groups = []
all_actual_age_groups = []
all_gender = []

# Define the StratifiedGroupKFold splitter for 4 fold CV with random shuffling
outer_cv = StratifiedGroupKFold(n_splits=4, shuffle=True, random_state=int(random_seeds[1]))

# unseen test set metrics
unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1 = [], [], [], [], []

outer_fold = 0

# Use the splitter to generate indices for training and testing sets
# Note: GroupShuffleSplit.split returns indices, so we use it to index the arrays
for train_val_idx, test_idx in outer_cv.split(X, y, groups):
    outer_fold += 1
    logger(f"outer_fold {outer_fold}", file=log_file_path)

    # Convert indices back to DataFrame for easy manipulation
    df_train_val = dataframe.iloc[train_val_idx]
    df_test = dataframe.iloc[test_idx]

    ##############################
    # ASSESSING SPLITS BY CAT_ID #
    ##############################
    
    # Get the distribution of groups
    training_validation_group_distribution = df_train_val['cat_id'].value_counts()  
    testing_group_distribution = df_test['cat_id'].value_counts()  
    
    # Log or print the distribution
    logger(f"Train Set Group Distribution:\n{training_validation_group_distribution}", file=log_file_path)
    logger(f"Testing Set Group Distribution:\n{testing_group_distribution}", file=log_file_path)

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val['gender'].value_counts()
    testing_gender_distribution = df_test['gender'].value_counts()
    
    # Log the distribution
    logger(f"Training Set Gender Distribution BEFORE SWAP:\n{training_gender_distribution}", file=log_file_path)
    logger(f"Testing Set Gender Distribution BEFORE SWAP:\n{testing_gender_distribution}", file=log_file_path)

    # Group by 'age_group' and then list unique 'cat_id' within each age group
    unique_cat_ids_per_age_group_train_val = df_train_val.groupby('age_group')['cat_id'].unique()
    unique_cat_ids_per_age_group_test = df_test.groupby('age_group')['cat_id'].unique()
    
    # Log results
    logger(f"Unique Cat IDs per Age Group in Training/Validation Set:\n{unique_cat_ids_per_age_group_train_val}", file=log_file_path)
    logger(f"Unique Cat IDs per Age Group in Testing Set:\n{unique_cat_ids_per_age_group_test}", file=log_file_path)

    # Calculate the count of unique identifiers per age group for training and testing set
    counts_train_val = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_train_val.items()}
    counts_test = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_test.items()}

    # Log the counts of unique identifiers per age group
    logger(f"Count of Unique Cat IDs per Age Group in Training/Validation Set:\n{counts_train_val}", file=log_file_path)
    logger(f"Count of Unique Cat IDs per Age Group in Testing Set:\n{counts_test}", file=log_file_path)

    #######################################################
    # CONTINUE WITH ENSURING VALID AND APPROPRIATE SPLITS #
    #######################################################
    
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    groups_train_val, groups_test = groups[train_val_idx], groups[test_idx]

    # logging identifier splits 
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)

    # check group splits
    check_initial_group_split(groups_train_val, groups_test)

    # Specify the cat_ids that must be in the training/validation set
    specific_cat_ids = ['000A', '046A']
    
    # Perform the swapping operation
    train_val_idx, test_idx = swap_cat_id_instances(dataframe, train_val_idx, test_idx, specific_cat_ids)
    
    # Re-assign the sets based on the updated indices
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    new_groups_train_val, new_groups_test = groups[train_val_idx], groups[test_idx]

    # Find differences for training and test sets
    moved_to_train_val, removed_from_train_val = find_group_differences(groups_train_val, new_groups_train_val)
    moved_to_test, removed_from_test = find_group_differences(groups_test, new_groups_test)
    
    # Display the results
    logger(f"Moved to Training/Validation Set:\n{moved_to_train_val}", file=log_file_path)
    logger(f"Removed from Training/Validation Set:\n{removed_from_train_val}", file=log_file_path)
    logger(f"Moved to Test Set:\n{moved_to_test}", file=log_file_path)
    logger(f"Removed from Test Set\n{removed_from_test}", file=log_file_path)

    # Update X_train_val, X_test, y_train_val, y_test, groups_train_val, groups_test based on updated indices
    X_train_val = X[train_val_idx]
    y_train_val = y[train_val_idx]
    groups_train_val = groups[train_val_idx]
    
    X_test = X[test_idx]
    y_test = y[test_idx]
    groups_test = groups[test_idx]

    # logging identifier splits again after potential swaps
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"AFTER SWAP - Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"AFTER SWAP - Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)
    
    # Verify the lengths are consistent
    logger(f"Length of X_train_val:\n{len(X_train_val)}", file=log_file_path)
    logger(f"Length of y_train_val:\n{len(y_train_val)}", file=log_file_path)
    logger(f"Length of groups_train_val:\n{len(groups_train_val)}", file=log_file_path)

    # Check group splits once more
    check_initial_group_split(groups_train_val, groups_test)

    # Convert the modified indices back to a DataFrame representing the updated df_train_val
    df_train_val_updated = dataframe.iloc[train_val_idx].copy()
    df_test_updated = dataframe.iloc[test_idx].copy()

    ############################
    # LOGGING AGE GROUP SPLITS #
    ############################

    # Get the distribution of age groups of age groups before the update
    training_validation_age_group_distribution = df_train_val['age_group'].value_counts()
    testing_age_group_distribution = df_test['age_group'].value_counts()
    
    # Logthe distribution
    logger(f"Train Age Group Distribution BEFORE SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution BEFORE SWAP:\n{testing_age_group_distribution}", file=log_file_path)

    # Get the distribution of age groups after the update
    training_validation_age_group_distribution = df_train_val_updated['age_group'].value_counts()
    testing_age_group_distribution = df_test_updated['age_group'].value_counts()
    
    # Log the distribution
    logger(f"Train Age Group Distribution AFTER SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution AFTER SWAP:\n{testing_age_group_distribution}", file=log_file_path)
    
    ########################################################
    # TRACKING FINAL CAT_IDs & GENDER AFTER REDISTRIBUTION #
    ########################################################

    # Get the distribution of groups
    training_validation_group_distribution = df_train_val_updated['cat_id'].value_counts()  
    testing_group_distribution = df_test_updated['cat_id'].value_counts()  

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val_updated['gender'].value_counts()
    testing_gender_distribution = df_test_updated['gender'].value_counts()
    
    logger(f"\n Starting training on unseen test set\n", file=log_file_path)

    ######################
    # ADD AUGMENTED DATA #
    ######################

    # Filter out augmented data derived from groups in the training set
    augmented_df_filtered = augmented_df[augmented_df['cat_id'].isin(groups_train_val)]
    
    # Convert augmented_df_filtered to numpy array (excluding target and other columns)
    augmented_array = augmented_df_filtered.drop(columns=['target', 'cat_id', 'age_group']).values
    
    # Concatenate the filtered augmented data with X_train_val
    X_train_val = np.concatenate([X_train_val, augmented_array])

    # Extract target labels from the filtered augmented DataFrame
    y_augmented = augmented_df_filtered['age_group'].values
    
    # Encode the labels using the same LabelEncoder instance
    y_augmented_encoded = label_encoder.transform(y_augmented)
    
    # Concatenate the encoded augmented labels with y_train_val
    y_train_val = np.concatenate([y_train_val, y_augmented_encoded])

    # Calculate the distribution of age groups in y_train_val
    age_group_distribution = Counter(y_train_val)
    print("Age group distribution:", age_group_distribution)

    # EarlyStopping callback: monitor 'loss' instead of 'val_loss' for the test set
    early_stopping = EarlyStopping(
        monitor='loss',  
        min_delta=0.001, 
        patience=30,  
        verbose=1,  
        restore_best_weights=True  
    )

    # One final shuffle to ensure randomness
    outer_shuffle_idx = np.random.permutation(len(X_train_val))
    X_train_val = X_train_val[outer_shuffle_idx]
    y_train_val = y_train_val[outer_shuffle_idx]
    
    # Scale the features
    scaler_full = StandardScaler().fit(X_train_val)
    X_train_full_scaled = scaler_full.transform(X_train_val)
    X_test_scaled = scaler_full.transform(X_test)
    
    # Encode the labels
    y_train_full_encoded = to_categorical(y_train_val)
    y_test_encoded = to_categorical(y_test)

    #######################
    # BUILD & TRAIN MODEL #
    #######################

    optimizers = {
        'Adamax': Adamax(learning_rate=0.00510251984616472)
    }
    
    # Model definition with dynamic number of layers
    model_full = Sequential()
    model_full.add(Dense(480, activation='relu', input_shape=(X_train_full_scaled.shape[1],)))
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.2011047009431978))  
    model_full.add(Dense(256, activation='relu',)) 
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.14956886311951184))  
    model_full.add(Dense(256, activation='relu'))  
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.42291461228250665))  
    model_full.add(Dense(3, activation='softmax'))  
    
    # Use the optimizer from the parameters
    optimizer = optimizers['Adamax']  # optimizer_key from parameters
    
    # Compile the model
    model_full.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    
    # Train the model on the full training set
    history_full = model_full.fit(X_train_full_scaled, y_train_full_encoded, epochs=1500, batch_size=64,
                                  verbose=1, callbacks=[early_stopping])
    
    # Evaluate the model on the held-out test set
    test_loss, test_accuracy = model_full.evaluate(X_test_scaled, y_test_encoded)

    y_test_pred_prob = model_full.predict(X_test_scaled)
    y_test_pred = np.argmax(y_test_pred_prob, axis=1)  
    y_test_true = np.argmax(y_test_encoded, axis=1)    

    ################################
    # LOG MAJORITY VOTE PER CAT_ID #
    ################################

    # Convert numeric predictions back to age group labels
    predicted_age_groups = label_encoder.inverse_transform(y_test_pred)
    actual_labels = label_encoder.inverse_transform(y_test_true)
    
    # Map predictions and actual labels back to cat_ids
    test_results = pd.DataFrame({
        'cat_id': df_test_updated['cat_id'],
        'predicted_age_group': predicted_age_groups,
        'actual_age_group': actual_labels
    })
    
    # Group by cat_id and aggregate predicted age groups
    majority_votes = test_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
    actual_groups = test_results.groupby('cat_id')['actual_age_group'].first()
    
    # Calculate the accuracy of majority voting
    correct_predictions = (majority_votes == actual_groups).sum()
    total_cats = len(actual_groups)
    majority_vote_accuracy = correct_predictions / total_cats
    
    # Log the accuracy of the majority voting
    logger(f"Majority Vote Accuracy for cat_id for this fold: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

    ####################################################
    # COLLECT PREDICTIONS FOR GENDER & CAT_ID ANALYSIS #
    ####################################################

    # Debugging print statements
    print(f'Before appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Extend lists with current fold results
    all_cat_ids.extend(df_test_updated['cat_id'].tolist())
    all_predicted_age_groups.extend(predicted_age_groups)
    all_actual_age_groups.extend(actual_labels)
    all_gender.extend(df_test_updated['gender'].tolist())

    # Debugging print statements
    print(f'After appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Calculate additional metrics
    test_precision = precision_score(y_test_true, y_test_pred, average='macro')  # Use 'macro' for imbalanced datasets
    test_recall = recall_score(y_test_true, y_test_pred, average='macro')
    test_f1 = f1_score(y_test_true, y_test_pred, average='macro')

    # prepare averages of outer metrics
    unseen_f1.append(test_f1)
    unseen_losses.append(test_loss)
    unseen_accuracies.append(test_accuracy)
    unseen_precisions.append(test_precision)
    unseen_recalls.append(test_recall)

    # Print final test results
    logger(f"Final Test Results - Loss: {test_loss}, Accuracy: {test_accuracy}, Precision: {test_precision}, Recall: {test_recall}, F1 Score: {test_f1}", file=log_file_path)

    # Generate the confusion matrix
    cm = confusion_matrix(y_test, y_test_pred)
    logger(f"Confusion Matrix:\n {cm}", file=log_file_path)

# Calculate the overall average metrics
unseen_set_avg_f1 = np.mean(unseen_f1)
unseen_set_avg_loss = np.mean(unseen_losses)
unseen_set_avg_acc = np.mean(unseen_accuracies)
unseen_set_avg_precision = np.mean(unseen_precisions)
unseen_set_avg_recall = np.mean(unseen_recalls)

# Append averages to total lists
all_f1.append(unseen_set_avg_f1)
all_losses.append(unseen_set_avg_loss)
all_accuracies.append(unseen_set_avg_acc)
all_precisions.append(unseen_set_avg_precision)
all_recalls.append(unseen_set_avg_recall)

logger(f"\nFinal Average F1-Score across all UNSEEN TEST sets: {unseen_set_avg_f1}", file=log_file_path)
logger(f"\nFinal Average Loss across all UNSEEN TEST sets: {unseen_set_avg_loss}", file=log_file_path)
logger(f"\nFinal Average Accuracy across all UNSEEN TEST sets: {unseen_set_avg_acc}", file=log_file_path)
logger(f"\nFinal Average Precision across all UNSEEN TEST sets: {unseen_set_avg_precision}", file=log_file_path)
logger(f"\nFinal Average Recall across all UNSEEN TEST sets: {unseen_set_avg_recall}\n", file=log_file_path)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# outer_fold 1
# Train Set Group Distribution:
# 046A    45
# 103A    33
# 002B    30
# 047A    22
# 020A    20
# 000B    19
# 057A    17
# 019A    17
# 074A    16
# 029A    15
# 097A    15
# 097B    14
# 106A    13
# 101A    12
# 051A    12
# 055A    12
# 116A    12
# 111A    12
# 042A    11
# 028A    11
# 063A    11
# 040A    10
# 025A    10
# 059A    10
# 014B    10
# 016A     9
# 065A     9
# 051B     9
# 072A     9
# 001A     9
# 005A     9
# 022A     9
# 013B     8
# 068A     8
# 117A     7
# 027A     7
# 031A     7
# 007A     6
# 023A     6
# 039A     6
# 099A     6
# 075A     5
# 108A     5
# 094A     5
# 021A     5
# 008A     5
# 044A     5
# 070A     5
# 109A     5
# 003A     4
# 009A     4
# 045A     4
# 104A     4
# 026A     4
# 025C     4
# 113A     3
# 053A     3
# 056A     3
# 012A     3
# 058A     3
# 010A     3
# 060A     3
# 014A     3
# 025B     2
# 052A     2
# 037A     2
# 102A     2
# 087A     2
# 032A     2
# 110A     1
# 090A     1
# 024A     1
# 115A     1
# 076A     1
# 041A     1
# 019B     1
# 088A     1
# 048A     1
# 026C     1
# 049A     1
# 091A     1
# 073A     1
# 043A     1
# 026B     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 000A    39
# 002A    13
# 067A    11
# 033A     9
# 071A     9
# 015A     7
# 095A     7
# 036A     7
# 050A     5
# 023B     4
# 006A     3
# 105A     3
# 062A     3
# 034A     3
# 061A     2
# 018A     2
# 038A     2
# 054A     2
# 069A     2
# 011A     2
# 093A     2
# 035A     2
# 004A     1
# 096A     1
# 066A     1
# 092A     1
# 064A     1
# 100A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    239
# M    235
# F    174
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# F    57
# M    51
# X    37
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [001A, 103A, 097B, 028A, 019A, 074A, 020A, 002...
# kitten    [044A, 014B, 111A, 040A, 046A, 047A, 042A, 109...
# senior    [097A, 057A, 106A, 104A, 055A, 059A, 113A, 116...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [006A, 000A, 033A, 015A, 071A, 067A, 062A, 095...
# kitten                                               [050A]
# senior                             [093A, 054A, 011A, 061A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 51, 'kitten': 15, 'senior': 18}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 23, 'kitten': 1, 'senior': 4}
# Unique Training/Validation Group IDs:
# ['000B' '001A' '002B' '003A' '005A' '007A' '008A' '009A' '010A' '012A'
#  '013B' '014A' '014B' '016A' '019A' '019B' '020A' '021A' '022A' '023A'
#  '024A' '025A' '025B' '025C' '026A' '026B' '026C' '027A' '028A' '029A'
#  '031A' '032A' '037A' '039A' '040A' '041A' '042A' '043A' '044A' '045A'
#  '046A' '047A' '048A' '049A' '051A' '051B' '052A' '053A' '055A' '056A'
#  '057A' '058A' '059A' '060A' '063A' '065A' '068A' '070A' '072A' '073A'
#  '074A' '075A' '076A' '087A' '088A' '090A' '091A' '094A' '097A' '097B'
#  '099A' '101A' '102A' '103A' '104A' '106A' '108A' '109A' '110A' '111A'
#  '113A' '115A' '116A' '117A']
# Unique Test Group IDs:
# ['000A' '002A' '004A' '006A' '011A' '015A' '018A' '023B' '033A' '034A'
#  '035A' '036A' '038A' '050A' '054A' '061A' '062A' '064A' '066A' '067A'
#  '069A' '071A' '092A' '093A' '095A' '096A' '100A' '105A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'000A'}
# Removed from Training/Validation Set:
# {'010A'}
# Moved to Test Set:
# {'010A'}
# Removed from Test Set
# {'000A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002B' '003A' '005A' '007A' '008A' '009A' '012A'
#  '013B' '014A' '014B' '016A' '019A' '019B' '020A' '021A' '022A' '023A'
#  '024A' '025A' '025B' '025C' '026A' '026B' '026C' '027A' '028A' '029A'
#  '031A' '032A' '037A' '039A' '040A' '041A' '042A' '043A' '044A' '045A'
#  '046A' '047A' '048A' '049A' '051A' '051B' '052A' '053A' '055A' '056A'
#  '057A' '058A' '059A' '060A' '063A' '065A' '068A' '070A' '072A' '073A'
#  '074A' '075A' '076A' '087A' '088A' '090A' '091A' '094A' '097A' '097B'
#  '099A' '101A' '102A' '103A' '104A' '106A' '108A' '109A' '110A' '111A'
#  '113A' '115A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['002A' '004A' '006A' '010A' '011A' '015A' '018A' '023B' '033A' '034A'
#  '035A' '036A' '038A' '050A' '054A' '061A' '062A' '064A' '066A' '067A'
#  '069A' '071A' '092A' '093A' '095A' '096A' '100A' '105A']
# Length of X_train_val:
# 684
# Length of y_train_val:
# 684
# Length of groups_train_val:
# 684
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     377
# senior    141
# kitten    130
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     132
# senior      8
# kitten      5
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     413
# senior    141
# kitten    130
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     96
# senior     8
# kitten     5
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 826, 2: 705, 1: 650})
# Epoch 1/1500
# 35/35 [==============================] - 1s 7ms/step - loss: 0.3978 - accuracy: 0.8624
# Epoch 2/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0775 - accuracy: 0.9766
# Epoch 3/1500
# 35/35 [==============================] - 0s 5ms/step - loss: 0.0308 - accuracy: 0.9904
# Epoch 4/1500
# 35/35 [==============================] - 0s 8ms/step - loss: 0.0208 - accuracy: 0.9931
# Epoch 5/1500
# 35/35 [==============================] - 0s 8ms/step - loss: 0.0177 - accuracy: 0.9950
# Epoch 6/1500
# 35/35 [==============================] - 0s 7ms/step - loss: 0.0146 - accuracy: 0.9954
# Epoch 7/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0110 - accuracy: 0.9959
# Epoch 8/1500
# 35/35 [==============================] - 0s 8ms/step - loss: 0.0097 - accuracy: 0.9982
# Epoch 9/1500
# 35/35 [==============================] - 0s 7ms/step - loss: 0.0044 - accuracy: 0.9995
# Epoch 10/1500
# 35/35 [==============================] - 0s 7ms/step - loss: 0.0097 - accuracy: 0.9977
# Epoch 11/1500
# 35/35 [==============================] - 0s 7ms/step - loss: 0.0089 - accuracy: 0.9982
# Epoch 12/1500
# 35/35 [==============================] - 0s 7ms/step - loss: 0.0116 - accuracy: 0.9959
# Epoch 13/1500
# 35/35 [==============================] - 0s 7ms/step - loss: 0.0059 - accuracy: 0.9991
# Epoch 14/1500
# 35/35 [==============================] - 0s 8ms/step - loss: 0.0056 - accuracy: 1.0000
# Epoch 15/1500
# 35/35 [==============================] - 0s 8ms/step - loss: 0.0091 - accuracy: 0.9968
# Epoch 16/1500
# 35/35 [==============================] - 0s 8ms/step - loss: 0.0077 - accuracy: 0.9982
# Epoch 17/1500
# 35/35 [==============================] - 0s 7ms/step - loss: 0.0069 - accuracy: 0.9986
# Epoch 18/1500
# 35/35 [==============================] - 0s 8ms/step - loss: 0.0060 - accuracy: 0.9986
# Epoch 19/1500
# 35/35 [==============================] - 0s 7ms/step - loss: 0.0052 - accuracy: 0.9986
# Epoch 20/1500
# 35/35 [==============================] - 0s 8ms/step - loss: 0.0050 - accuracy: 0.9991
# Epoch 21/1500
# 35/35 [==============================] - 0s 8ms/step - loss: 0.0021 - accuracy: 0.9995
# Epoch 22/1500
# 35/35 [==============================] - 0s 7ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 23/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0046 - accuracy: 0.9986
# Epoch 24/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0040 - accuracy: 0.9991
# Epoch 25/1500
# 35/35 [==============================] - 0s 7ms/step - loss: 0.0045 - accuracy: 0.9991
# Epoch 26/1500
# 35/35 [==============================] - 0s 7ms/step - loss: 0.0073 - accuracy: 0.9972
# Epoch 27/1500
# 35/35 [==============================] - 0s 7ms/step - loss: 0.0046 - accuracy: 0.9986
# Epoch 28/1500
# 35/35 [==============================] - 0s 8ms/step - loss: 0.0068 - accuracy: 0.9977
# Epoch 29/1500
# 35/35 [==============================] - 0s 7ms/step - loss: 0.0071 - accuracy: 0.9986
# Epoch 30/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0045 - accuracy: 0.9991
# Epoch 31/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0068 - accuracy: 0.9982
# Epoch 32/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0056 - accuracy: 0.9991
# Epoch 33/1500
# 35/35 [==============================] - 0s 7ms/step - loss: 0.0195 - accuracy: 0.9954
# Epoch 34/1500
# 35/35 [==============================] - 0s 8ms/step - loss: 0.0046 - accuracy: 0.9991
# Epoch 35/1500
# 35/35 [==============================] - 0s 8ms/step - loss: 0.0089 - accuracy: 0.9977
# Epoch 36/1500
# 35/35 [==============================] - 0s 7ms/step - loss: 0.0045 - accuracy: 0.9986
# Epoch 37/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0062 - accuracy: 0.9982
# Epoch 38/1500
# 35/35 [==============================] - 0s 7ms/step - loss: 0.0063 - accuracy: 0.9986
# Epoch 39/1500
# 35/35 [==============================] - 0s 7ms/step - loss: 0.0080 - accuracy: 0.9972
# Epoch 40/1500
# 35/35 [==============================] - 0s 7ms/step - loss: 0.0091 - accuracy: 0.9972
# Epoch 41/1500
# 35/35 [==============================] - 0s 7ms/step - loss: 0.0141 - accuracy: 0.9972
# Epoch 42/1500
# 35/35 [==============================] - 0s 9ms/step - loss: 0.0061 - accuracy: 0.9991
# Epoch 43/1500
# 35/35 [==============================] - 0s 7ms/step - loss: 0.0100 - accuracy: 0.9972
# Epoch 44/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0047 - accuracy: 0.9991
# Epoch 45/1500
# 35/35 [==============================] - 0s 7ms/step - loss: 0.0044 - accuracy: 0.9991
# Epoch 46/1500
# 35/35 [==============================] - 0s 7ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 47/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0040 - accuracy: 0.9986
# Epoch 48/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0059 - accuracy: 0.9991
# Epoch 49/1500
# 35/35 [==============================] - 0s 6ms/step - loss: 0.0096 - accuracy: 0.9986
# Epoch 50/1500
# 35/35 [==============================] - 0s 7ms/step - loss: 0.0057 - accuracy: 0.9991
# Epoch 51/1500
# 33/35 [===========================>..] - ETA: 0s - loss: 0.0049 - accuracy: 0.9986Restoring model weights from the end of the best epoch: 21.
# 35/35 [==============================] - 0s 7ms/step - loss: 0.0073 - accuracy: 0.9977
# Epoch 51: early stopping
# 4/4 [==============================] - 0s 2ms/step - loss: 0.6791 - accuracy: 0.8165
# 4/4 [==============================] - 0s 2ms/step
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Majority Vote Accuracy for cat_id for this fold: 0.79 (22/28)
# Before appending - Cat IDs: 0, Predictions: 0, Actuals: 0, Gender: 0
# After appending - Cat IDs: 109, Predictions: 109, Actuals: 109, Gender: 109
# Final Test Results - Loss: 0.6791003942489624, Accuracy: 0.8165137767791748, Precision: 0.5513468013468014, Recall: 0.7013888888888888, F1 Score: 0.6018633540372671
# Confusion Matrix:
#  [[82  4 10]
#  [ 0  5  0]
#  [ 6  0  2]]
# outer_fold 2
# Train Set Group Distribution:
# 046A    45
# 000A    39
# 047A    22
# 057A    17
# 019A    17
# 074A    16
# 097A    15
# 002A    13
# 106A    13
# 051A    12
# 111A    12
# 116A    12
# 055A    12
# 067A    11
# 063A    11
# 059A    10
# 040A    10
# 025A    10
# 071A     9
# 022A     9
# 001A     9
# 005A     9
# 072A     9
# 065A     9
# 033A     9
# 068A     8
# 027A     7
# 031A     7
# 095A     7
# 117A     7
# 015A     7
# 036A     7
# 023A     6
# 039A     6
# 099A     6
# 007A     6
# 109A     5
# 075A     5
# 050A     5
# 094A     5
# 108A     5
# 023B     4
# 009A     4
# 003A     4
# 045A     4
# 026A     4
# 025C     4
# 058A     3
# 060A     3
# 006A     3
# 062A     3
# 034A     3
# 113A     3
# 014A     3
# 105A     3
# 037A     2
# 061A     2
# 011A     2
# 035A     2
# 093A     2
# 018A     2
# 069A     2
# 054A     2
# 038A     2
# 091A     1
# 024A     1
# 100A     1
# 110A     1
# 115A     1
# 096A     1
# 019B     1
# 004A     1
# 048A     1
# 066A     1
# 043A     1
# 073A     1
# 026C     1
# 064A     1
# 041A     1
# 092A     1
# 049A     1
# 026B     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 103A    33
# 002B    30
# 020A    20
# 000B    19
# 029A    15
# 097B    14
# 101A    12
# 028A    11
# 042A    11
# 014B    10
# 051B     9
# 016A     9
# 013B     8
# 008A     5
# 021A     5
# 044A     5
# 070A     5
# 104A     4
# 056A     3
# 012A     3
# 053A     3
# 010A     3
# 032A     2
# 087A     2
# 052A     2
# 102A     2
# 025B     2
# 076A     1
# 088A     1
# 090A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    231
# F    164
# M    148
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# M    138
# F     67
# X     45
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [006A, 000A, 033A, 015A, 001A, 071A, 019A, 074...
# kitten    [111A, 040A, 046A, 047A, 109A, 050A, 043A, 049...
# senior    [093A, 097A, 057A, 106A, 055A, 059A, 113A, 116...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [103A, 097B, 028A, 020A, 002B, 101A, 029A, 013...
# kitten                                   [044A, 014B, 042A]
# senior                       [104A, 051B, 056A, 016A, 090A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 52, 'kitten': 13, 'senior': 17}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 22, 'kitten': 3, 'senior': 5}
# Unique Training/Validation Group IDs:
# ['000A' '001A' '002A' '003A' '004A' '005A' '006A' '007A' '009A' '011A'
#  '014A' '015A' '018A' '019A' '019B' '022A' '023A' '023B' '024A' '025A'
#  '025C' '026A' '026B' '026C' '027A' '031A' '033A' '034A' '035A' '036A'
#  '037A' '038A' '039A' '040A' '041A' '043A' '045A' '046A' '047A' '048A'
#  '049A' '050A' '051A' '054A' '055A' '057A' '058A' '059A' '060A' '061A'
#  '062A' '063A' '064A' '065A' '066A' '067A' '068A' '069A' '071A' '072A'
#  '073A' '074A' '075A' '091A' '092A' '093A' '094A' '095A' '096A' '097A'
#  '099A' '100A' '105A' '106A' '108A' '109A' '110A' '111A' '113A' '115A'
#  '116A' '117A']
# Unique Test Group IDs:
# ['000B' '002B' '008A' '010A' '012A' '013B' '014B' '016A' '020A' '021A'
#  '025B' '028A' '029A' '032A' '042A' '044A' '051B' '052A' '053A' '056A'
#  '070A' '076A' '087A' '088A' '090A' '097B' '101A' '102A' '103A' '104A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '001A' '002A' '003A' '004A' '005A' '006A' '007A' '009A' '011A'
#  '014A' '015A' '018A' '019A' '019B' '022A' '023A' '023B' '024A' '025A'
#  '025C' '026A' '026B' '026C' '027A' '031A' '033A' '034A' '035A' '036A'
#  '037A' '038A' '039A' '040A' '041A' '043A' '045A' '046A' '047A' '048A'
#  '049A' '050A' '051A' '054A' '055A' '057A' '058A' '059A' '060A' '061A'
#  '062A' '063A' '064A' '065A' '066A' '067A' '068A' '069A' '071A' '072A'
#  '073A' '074A' '075A' '091A' '092A' '093A' '094A' '095A' '096A' '097A'
#  '099A' '100A' '105A' '106A' '108A' '109A' '110A' '111A' '113A' '115A'
#  '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['000B' '002B' '008A' '010A' '012A' '013B' '014B' '016A' '020A' '021A'
#  '025B' '028A' '029A' '032A' '042A' '044A' '051B' '052A' '053A' '056A'
#  '070A' '076A' '087A' '088A' '090A' '097B' '101A' '102A' '103A' '104A']
# Length of X_train_val:
# 543
# Length of y_train_val:
# 543
# Length of groups_train_val:
# 543
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     311
# senior    123
# kitten    109
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     198
# kitten     26
# senior     26
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     311
# senior    123
# kitten    109
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     198
# kitten     26
# senior     26
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 622, 2: 615, 1: 545})
# Epoch 1/1500
# 28/28 [==============================] - 1s 7ms/step - loss: 0.4021 - accuracy: 0.8636
# Epoch 2/1500
# 28/28 [==============================] - 0s 7ms/step - loss: 0.0568 - accuracy: 0.9781
# Epoch 3/1500
# 28/28 [==============================] - 0s 8ms/step - loss: 0.0143 - accuracy: 0.9972
# Epoch 4/1500
# 28/28 [==============================] - 0s 6ms/step - loss: 0.0115 - accuracy: 0.9989
# Epoch 5/1500
# 28/28 [==============================] - 0s 6ms/step - loss: 0.0083 - accuracy: 0.9989
# Epoch 6/1500
# 28/28 [==============================] - 0s 6ms/step - loss: 0.0065 - accuracy: 0.9972
# Epoch 7/1500
# 28/28 [==============================] - 0s 7ms/step - loss: 0.0046 - accuracy: 0.9994
# Epoch 8/1500
# 28/28 [==============================] - 0s 7ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 9/1500
# 28/28 [==============================] - 0s 7ms/step - loss: 0.0036 - accuracy: 0.9989
# Epoch 10/1500
# 28/28 [==============================] - 0s 7ms/step - loss: 0.0032 - accuracy: 0.9989
# Epoch 11/1500
# 28/28 [==============================] - 0s 7ms/step - loss: 0.0042 - accuracy: 0.9989
# Epoch 12/1500
# 28/28 [==============================] - 0s 7ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 13/1500
# 28/28 [==============================] - 0s 7ms/step - loss: 0.0051 - accuracy: 0.9978
# Epoch 14/1500
# 28/28 [==============================] - 0s 7ms/step - loss: 0.0031 - accuracy: 0.9989
# Epoch 15/1500
# 28/28 [==============================] - 0s 8ms/step - loss: 0.0060 - accuracy: 0.9989
# Epoch 16/1500
# 28/28 [==============================] - 0s 8ms/step - loss: 0.0038 - accuracy: 0.9983
# Epoch 17/1500
# 28/28 [==============================] - 0s 8ms/step - loss: 0.0023 - accuracy: 0.9994
# Epoch 18/1500
# 28/28 [==============================] - 0s 7ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 19/1500
# 28/28 [==============================] - 0s 7ms/step - loss: 0.0019 - accuracy: 0.9994
# Epoch 20/1500
# 28/28 [==============================] - 0s 9ms/step - loss: 0.0026 - accuracy: 0.9994
# Epoch 21/1500
# 28/28 [==============================] - 0s 7ms/step - loss: 0.0030 - accuracy: 0.9994
# Epoch 22/1500
# 28/28 [==============================] - 0s 9ms/step - loss: 6.1844e-04 - accuracy: 1.0000
# Epoch 23/1500
# 28/28 [==============================] - 0s 6ms/step - loss: 8.4449e-04 - accuracy: 1.0000
# Epoch 24/1500
# 28/28 [==============================] - 0s 8ms/step - loss: 7.2676e-04 - accuracy: 1.0000
# Epoch 25/1500
# 28/28 [==============================] - 0s 5ms/step - loss: 2.5598e-04 - accuracy: 1.0000
# Epoch 26/1500
# 28/28 [==============================] - 0s 6ms/step - loss: 0.0013 - accuracy: 0.9994
# Epoch 27/1500
# 28/28 [==============================] - 0s 7ms/step - loss: 3.4601e-04 - accuracy: 1.0000
# Epoch 28/1500
# 28/28 [==============================] - 0s 7ms/step - loss: 8.2294e-04 - accuracy: 1.0000
# Epoch 29/1500
# 28/28 [==============================] - 0s 6ms/step - loss: 0.0020 - accuracy: 0.9994
# Epoch 30/1500
# 28/28 [==============================] - 0s 6ms/step - loss: 4.8938e-04 - accuracy: 1.0000
# Epoch 31/1500
# 28/28 [==============================] - 0s 6ms/step - loss: 4.5851e-04 - accuracy: 1.0000
# Epoch 32/1500
# 28/28 [==============================] - 0s 7ms/step - loss: 6.8491e-04 - accuracy: 1.0000
# Epoch 33/1500
# 28/28 [==============================] - 0s 8ms/step - loss: 3.7835e-04 - accuracy: 1.0000
# Epoch 34/1500
# 28/28 [==============================] - 0s 7ms/step - loss: 5.3955e-04 - accuracy: 1.0000
# Epoch 35/1500
# 28/28 [==============================] - 0s 6ms/step - loss: 2.5754e-04 - accuracy: 1.0000
# Epoch 36/1500
# 28/28 [==============================] - 0s 6ms/step - loss: 9.0920e-04 - accuracy: 0.9994
# Epoch 37/1500
# 28/28 [==============================] - 0s 6ms/step - loss: 0.0016 - accuracy: 0.9994
# Epoch 38/1500
# 28/28 [==============================] - 0s 6ms/step - loss: 0.0023 - accuracy: 0.9983
# Epoch 39/1500
# 28/28 [==============================] - 0s 6ms/step - loss: 0.0043 - accuracy: 0.9983
# Epoch 40/1500
# 28/28 [==============================] - 0s 6ms/step - loss: 0.0034 - accuracy: 0.9983
# Epoch 41/1500
# 28/28 [==============================] - 0s 6ms/step - loss: 7.1493e-04 - accuracy: 1.0000
# Epoch 42/1500
# 28/28 [==============================] - 0s 7ms/step - loss: 7.0653e-04 - accuracy: 1.0000
# Epoch 43/1500
# 28/28 [==============================] - 0s 7ms/step - loss: 3.7951e-04 - accuracy: 1.0000
# Epoch 44/1500
# 28/28 [==============================] - 0s 7ms/step - loss: 0.0015 - accuracy: 0.9994
# Epoch 45/1500
# 28/28 [==============================] - 0s 7ms/step - loss: 5.9433e-04 - accuracy: 1.0000
# Epoch 46/1500
# 28/28 [==============================] - 0s 7ms/step - loss: 3.3588e-04 - accuracy: 1.0000
# Epoch 47/1500
# 28/28 [==============================] - 0s 7ms/step - loss: 4.2799e-04 - accuracy: 1.0000
# Epoch 48/1500
# 28/28 [==============================] - 0s 7ms/step - loss: 2.3946e-04 - accuracy: 1.0000
# Epoch 49/1500
# 28/28 [==============================] - 0s 7ms/step - loss: 0.0015 - accuracy: 0.9994
# Epoch 50/1500
# 28/28 [==============================] - 0s 7ms/step - loss: 0.0015 - accuracy: 0.9994
# Epoch 51/1500
# 28/28 [==============================] - 0s 6ms/step - loss: 0.0044 - accuracy: 0.9994
# Epoch 52/1500
# 24/28 [========================>.....] - ETA: 0s - loss: 6.8609e-04 - accuracy: 1.0000Restoring model weights from the end of the best epoch: 22.
# 28/28 [==============================] - 0s 7ms/step - loss: 6.4481e-04 - accuracy: 1.0000
# Epoch 52: early stopping
# 8/8 [==============================] - 0s 2ms/step - loss: 1.5233 - accuracy: 0.7400
# 8/8 [==============================] - 0s 2ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.73 (22/30)
# Before appending - Cat IDs: 109, Predictions: 109, Actuals: 109, Gender: 109
# After appending - Cat IDs: 359, Predictions: 359, Actuals: 359, Gender: 359
# Final Test Results - Loss: 1.5232943296432495, Accuracy: 0.7400000095367432, Precision: 0.6307557750681689, Recall: 0.44509194509194505, F1 Score: 0.49195128142496564
# Confusion Matrix:
#  [[173   0  25]
#  [ 12  10   4]
#  [ 24   0   2]]
# outer_fold 3
# Train Set Group Distribution:
# 046A    45
# 000A    39
# 103A    33
# 002B    30
# 020A    20
# 000B    19
# 019A    17
# 074A    16
# 029A    15
# 097A    15
# 097B    14
# 002A    13
# 106A    13
# 101A    12
# 051A    12
# 028A    11
# 067A    11
# 042A    11
# 063A    11
# 014B    10
# 005A     9
# 016A     9
# 051B     9
# 065A     9
# 072A     9
# 071A     9
# 033A     9
# 068A     8
# 013B     8
# 036A     7
# 015A     7
# 095A     7
# 023A     6
# 099A     6
# 070A     5
# 094A     5
# 108A     5
# 075A     5
# 008A     5
# 044A     5
# 021A     5
# 050A     5
# 104A     4
# 026A     4
# 003A     4
# 023B     4
# 025C     4
# 012A     3
# 056A     3
# 053A     3
# 060A     3
# 010A     3
# 006A     3
# 062A     3
# 105A     3
# 014A     3
# 034A     3
# 038A     2
# 093A     2
# 025B     2
# 037A     2
# 102A     2
# 061A     2
# 011A     2
# 035A     2
# 018A     2
# 052A     2
# 087A     2
# 069A     2
# 032A     2
# 054A     2
# 043A     1
# 090A     1
# 100A     1
# 096A     1
# 110A     1
# 076A     1
# 064A     1
# 092A     1
# 088A     1
# 004A     1
# 048A     1
# 066A     1
# 026B     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 047A    22
# 057A    17
# 055A    12
# 116A    12
# 111A    12
# 059A    10
# 025A    10
# 040A    10
# 022A     9
# 001A     9
# 027A     7
# 117A     7
# 031A     7
# 039A     6
# 007A     6
# 109A     5
# 045A     4
# 009A     4
# 058A     3
# 113A     3
# 073A     1
# 049A     1
# 041A     1
# 091A     1
# 026C     1
# 019B     1
# 115A     1
# 024A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    252
# X    192
# F    166
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    84
# F    65
# M    34
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [006A, 000A, 033A, 015A, 103A, 071A, 097B, 028...
# kitten     [044A, 014B, 046A, 042A, 050A, 043A, 048A, 110A]
# senior    [093A, 097A, 106A, 104A, 051B, 054A, 056A, 051...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [001A, 022A, 091A, 039A, 009A, 027A, 025A, 007...
# kitten     [111A, 040A, 047A, 109A, 049A, 041A, 045A, 115A]
# senior     [057A, 055A, 059A, 113A, 116A, 117A, 058A, 024A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 62, 'kitten': 8, 'senior': 14}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 12, 'kitten': 8, 'senior': 8}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '002A' '002B' '003A' '004A' '005A' '006A' '008A' '010A'
#  '011A' '012A' '013B' '014A' '014B' '015A' '016A' '018A' '019A' '020A'
#  '021A' '023A' '023B' '025B' '025C' '026A' '026B' '028A' '029A' '032A'
#  '033A' '034A' '035A' '036A' '037A' '038A' '042A' '043A' '044A' '046A'
#  '048A' '050A' '051A' '051B' '052A' '053A' '054A' '056A' '060A' '061A'
#  '062A' '063A' '064A' '065A' '066A' '067A' '068A' '069A' '070A' '071A'
#  '072A' '074A' '075A' '076A' '087A' '088A' '090A' '092A' '093A' '094A'
#  '095A' '096A' '097A' '097B' '099A' '100A' '101A' '102A' '103A' '104A'
#  '105A' '106A' '108A' '110A']
# Unique Test Group IDs:
# ['001A' '007A' '009A' '019B' '022A' '024A' '025A' '026C' '027A' '031A'
#  '039A' '040A' '041A' '045A' '047A' '049A' '055A' '057A' '058A' '059A'
#  '073A' '091A' '109A' '111A' '113A' '115A' '116A' '117A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '002A' '002B' '003A' '004A' '005A' '006A' '008A' '010A'
#  '011A' '012A' '013B' '014A' '014B' '015A' '016A' '018A' '019A' '020A'
#  '021A' '023A' '023B' '025B' '025C' '026A' '026B' '028A' '029A' '032A'
#  '033A' '034A' '035A' '036A' '037A' '038A' '042A' '043A' '044A' '046A'
#  '048A' '050A' '051A' '051B' '052A' '053A' '054A' '056A' '060A' '061A'
#  '062A' '063A' '064A' '065A' '066A' '067A' '068A' '069A' '070A' '071A'
#  '072A' '074A' '075A' '076A' '087A' '088A' '090A' '092A' '093A' '094A'
#  '095A' '096A' '097A' '097B' '099A' '100A' '101A' '102A' '103A' '104A'
#  '105A' '106A' '108A' '110A']
# AFTER SWAP - Unique Test Group IDs:
# ['001A' '007A' '009A' '019B' '022A' '024A' '025A' '026C' '027A' '031A'
#  '039A' '040A' '041A' '045A' '047A' '049A' '055A' '057A' '058A' '059A'
#  '073A' '091A' '109A' '111A' '113A' '115A' '116A' '117A']
# Length of X_train_val:
# 610
# Length of y_train_val:
# 610
# Length of groups_train_val:
# 610
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     447
# senior     84
# kitten     79
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# senior    65
# adult     62
# kitten    56
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     447
# senior     84
# kitten     79
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# senior    65
# adult     62
# kitten    56
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 894, 2: 420, 1: 395})
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Epoch 1/1500
# 27/27 [==============================] - 1s 5ms/step - loss: 0.4471 - accuracy: 0.8403
# Epoch 2/1500
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0584 - accuracy: 0.9795
# Epoch 3/1500
# 27/27 [==============================] - 0s 5ms/step - loss: 0.0225 - accuracy: 0.9930
# Epoch 4/1500
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0148 - accuracy: 0.9947
# Epoch 5/1500
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0062 - accuracy: 0.9994
# Epoch 6/1500
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0080 - accuracy: 0.9988
# Epoch 7/1500
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0038 - accuracy: 0.9994
# Epoch 8/1500
# 27/27 [==============================] - 0s 8ms/step - loss: 0.0046 - accuracy: 0.9994
# Epoch 9/1500
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0038 - accuracy: 0.9994
# Epoch 10/1500
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0022 - accuracy: 0.9994
# Epoch 11/1500
# 27/27 [==============================] - 0s 12ms/step - loss: 0.0023 - accuracy: 0.9994
# Epoch 12/1500
# 27/27 [==============================] - 0s 8ms/step - loss: 0.0033 - accuracy: 0.9994
# Epoch 13/1500
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0041 - accuracy: 0.9988
# Epoch 14/1500
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0028 - accuracy: 0.9988
# Epoch 15/1500
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 16/1500
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0027 - accuracy: 0.9994
# Epoch 17/1500
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 18/1500
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0031 - accuracy: 0.9994
# Epoch 19/1500
# 27/27 [==============================] - 0s 9ms/step - loss: 0.0013 - accuracy: 0.9994
# Epoch 20/1500
# 27/27 [==============================] - 0s 9ms/step - loss: 5.7199e-04 - accuracy: 1.0000
# Epoch 21/1500
# 27/27 [==============================] - 0s 10ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 22/1500
# 27/27 [==============================] - 0s 8ms/step - loss: 9.1709e-04 - accuracy: 1.0000
# Epoch 23/1500
# 27/27 [==============================] - 0s 8ms/step - loss: 7.4727e-04 - accuracy: 1.0000
# Epoch 24/1500
# 27/27 [==============================] - 0s 7ms/step - loss: 7.6737e-04 - accuracy: 1.0000
# Epoch 25/1500
# 27/27 [==============================] - 0s 7ms/step - loss: 8.2064e-04 - accuracy: 1.0000
# Epoch 26/1500
# 27/27 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 0.9994
# Epoch 27/1500
# 27/27 [==============================] - 0s 7ms/step - loss: 9.7572e-04 - accuracy: 1.0000
# Epoch 28/1500
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 29/1500
# 27/27 [==============================] - 0s 8ms/step - loss: 0.0016 - accuracy: 0.9994
# Epoch 30/1500
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0026 - accuracy: 0.9994
# Epoch 31/1500
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0022 - accuracy: 0.9994
# Epoch 32/1500
# 27/27 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 33/1500
# 27/27 [==============================] - 0s 8ms/step - loss: 8.4512e-04 - accuracy: 1.0000
# Epoch 34/1500
# 27/27 [==============================] - 0s 8ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 35/1500
# 27/27 [==============================] - 0s 7ms/step - loss: 2.2109e-04 - accuracy: 1.0000
# Epoch 36/1500
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0021 - accuracy: 0.9988
# Epoch 37/1500
# 27/27 [==============================] - 0s 7ms/step - loss: 0.0015 - accuracy: 0.9994
# Epoch 38/1500
# 27/27 [==============================] - 0s 7ms/step - loss: 7.6491e-04 - accuracy: 1.0000
# Epoch 39/1500
# 27/27 [==============================] - 0s 7ms/step - loss: 7.4162e-04 - accuracy: 1.0000
# Epoch 40/1500
# 27/27 [==============================] - 0s 6ms/step - loss: 5.7509e-04 - accuracy: 1.0000
# Epoch 41/1500
# 27/27 [==============================] - 0s 6ms/step - loss: 4.2397e-04 - accuracy: 1.0000
# Epoch 42/1500
# 27/27 [==============================] - 0s 6ms/step - loss: 7.3316e-04 - accuracy: 1.0000
# Epoch 43/1500
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0015 - accuracy: 0.9994
# Epoch 44/1500
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 45/1500
# 27/27 [==============================] - 0s 7ms/step - loss: 3.9736e-04 - accuracy: 1.0000
# Epoch 46/1500
# 27/27 [==============================] - 0s 6ms/step - loss: 2.5400e-04 - accuracy: 1.0000
# Epoch 47/1500
# 27/27 [==============================] - 0s 7ms/step - loss: 4.1113e-04 - accuracy: 1.0000
# Epoch 48/1500
# 27/27 [==============================] - 0s 6ms/step - loss: 0.0022 - accuracy: 0.9988
# Epoch 49/1500
# 27/27 [==============================] - 0s 7ms/step - loss: 4.3176e-04 - accuracy: 1.0000
# Epoch 50/1500
# 25/27 [==========================>...] - ETA: 0s - loss: 2.8686e-04 - accuracy: 1.0000Restoring model weights from the end of the best epoch: 20.
# 27/27 [==============================] - 0s 7ms/step - loss: 2.9734e-04 - accuracy: 1.0000
# Epoch 50: early stopping
# 6/6 [==============================] - 0s 2ms/step - loss: 3.4508 - accuracy: 0.5628
# 6/6 [==============================] - 0s 2ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.61 (17/28)
# Before appending - Cat IDs: 359, Predictions: 359, Actuals: 359, Gender: 359
# After appending - Cat IDs: 542, Predictions: 542, Actuals: 542, Gender: 542
# Final Test Results - Loss: 3.4508259296417236, Accuracy: 0.562841534614563, Precision: 0.7628892136564772, Recall: 0.5655943518846746, F1 Score: 0.5395702671312428
# Confusion Matrix:
#  [[61  1  0]
#  [27 27  2]
#  [50  0 15]]
# outer_fold 4
# Train Set Group Distribution:
# 000A    39
# 103A    33
# 002B    30
# 047A    22
# 020A    20
# 000B    19
# 057A    17
# 029A    15
# 097B    14
# 002A    13
# 111A    12
# 055A    12
# 101A    12
# 116A    12
# 067A    11
# 028A    11
# 042A    11
# 059A    10
# 025A    10
# 040A    10
# 014B    10
# 022A     9
# 071A     9
# 033A     9
# 001A     9
# 051B     9
# 016A     9
# 013B     8
# 027A     7
# 036A     7
# 031A     7
# 117A     7
# 095A     7
# 015A     7
# 007A     6
# 039A     6
# 050A     5
# 044A     5
# 021A     5
# 070A     5
# 008A     5
# 109A     5
# 009A     4
# 045A     4
# 023B     4
# 104A     4
# 058A     3
# 053A     3
# 010A     3
# 105A     3
# 012A     3
# 056A     3
# 006A     3
# 062A     3
# 034A     3
# 113A     3
# 093A     2
# 038A     2
# 035A     2
# 061A     2
# 052A     2
# 102A     2
# 025B     2
# 011A     2
# 087A     2
# 069A     2
# 032A     2
# 054A     2
# 018A     2
# 088A     1
# 115A     1
# 100A     1
# 090A     1
# 019B     1
# 096A     1
# 026C     1
# 004A     1
# 066A     1
# 076A     1
# 091A     1
# 041A     1
# 092A     1
# 049A     1
# 064A     1
# 073A     1
# 024A     1
# Name: cat_id, dtype: int64
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Testing Set Group Distribution:
# 046A    45
# 019A    17
# 074A    16
# 097A    15
# 106A    13
# 051A    12
# 063A    11
# 005A     9
# 072A     9
# 065A     9
# 068A     8
# 023A     6
# 099A     6
# 075A     5
# 108A     5
# 094A     5
# 026A     4
# 003A     4
# 025C     4
# 060A     3
# 014A     3
# 037A     2
# 043A     1
# 048A     1
# 110A     1
# 026B     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    223
# F    189
# X    166
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    110
# M     63
# F     42
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [006A, 000A, 033A, 015A, 001A, 103A, 071A, 097...
# kitten    [044A, 014B, 111A, 040A, 047A, 042A, 109A, 050...
# senior    [093A, 057A, 104A, 055A, 059A, 113A, 116A, 051...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [019A, 074A, 005A, 072A, 065A, 023A, 063A, 099...
# kitten                             [046A, 043A, 048A, 110A]
# senior                       [097A, 106A, 051A, 094A, 108A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 57, 'kitten': 12, 'senior': 17}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 17, 'kitten': 4, 'senior': 5}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '004A' '006A' '007A' '008A' '009A'
#  '010A' '011A' '012A' '013B' '014B' '015A' '016A' '018A' '019B' '020A'
#  '021A' '022A' '023B' '024A' '025A' '025B' '026C' '027A' '028A' '029A'
#  '031A' '032A' '033A' '034A' '035A' '036A' '038A' '039A' '040A' '041A'
#  '042A' '044A' '045A' '047A' '049A' '050A' '051B' '052A' '053A' '054A'
#  '055A' '056A' '057A' '058A' '059A' '061A' '062A' '064A' '066A' '067A'
#  '069A' '070A' '071A' '073A' '076A' '087A' '088A' '090A' '091A' '092A'
#  '093A' '095A' '096A' '097B' '100A' '101A' '102A' '103A' '104A' '105A'
#  '109A' '111A' '113A' '115A' '116A' '117A']
# Unique Test Group IDs:
# ['003A' '005A' '014A' '019A' '023A' '025C' '026A' '026B' '037A' '043A'
#  '046A' '048A' '051A' '060A' '063A' '065A' '068A' '072A' '074A' '075A'
#  '094A' '097A' '099A' '106A' '108A' '110A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'046A'}
# Removed from Training/Validation Set:
# {'049A'}
# Moved to Test Set:
# {'049A'}
# Removed from Test Set
# {'046A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '004A' '006A' '007A' '008A' '009A'
#  '010A' '011A' '012A' '013B' '014B' '015A' '016A' '018A' '019B' '020A'
#  '021A' '022A' '023B' '024A' '025A' '025B' '026C' '027A' '028A' '029A'
#  '031A' '032A' '033A' '034A' '035A' '036A' '038A' '039A' '040A' '041A'
#  '042A' '044A' '045A' '046A' '047A' '050A' '051B' '052A' '053A' '054A'
#  '055A' '056A' '057A' '058A' '059A' '061A' '062A' '064A' '066A' '067A'
#  '069A' '070A' '071A' '073A' '076A' '087A' '088A' '090A' '091A' '092A'
#  '093A' '095A' '096A' '097B' '100A' '101A' '102A' '103A' '104A' '105A'
#  '109A' '111A' '113A' '115A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['003A' '005A' '014A' '019A' '023A' '025C' '026A' '026B' '037A' '043A'
#  '048A' '049A' '051A' '060A' '063A' '065A' '068A' '072A' '074A' '075A'
#  '094A' '097A' '099A' '106A' '108A' '110A']
# Length of X_train_val:
# 622
# Length of y_train_val:
# 622
# Length of groups_train_val:
# 622
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     392
# senior     99
# kitten     87
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     117
# senior     50
# kitten     48
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     392
# kitten    131
# senior     99
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     117
# senior     50
# kitten      4
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 784, 1: 655, 2: 495})
# Epoch 1/1500
# 31/31 [==============================] - 1s 5ms/step - loss: 0.3765 - accuracy: 0.8656
# Epoch 2/1500
# 31/31 [==============================] - 0s 6ms/step - loss: 0.0770 - accuracy: 0.9747
# Epoch 3/1500
# 31/31 [==============================] - 0s 6ms/step - loss: 0.0200 - accuracy: 0.9943
# Epoch 4/1500
# 31/31 [==============================] - 0s 7ms/step - loss: 0.0238 - accuracy: 0.9938
# Epoch 5/1500
# 31/31 [==============================] - 0s 7ms/step - loss: 0.0139 - accuracy: 0.9964
# Epoch 6/1500
# 31/31 [==============================] - 0s 7ms/step - loss: 0.0121 - accuracy: 0.9974
# Epoch 7/1500
# 31/31 [==============================] - 0s 7ms/step - loss: 0.0080 - accuracy: 0.9979
# Epoch 8/1500
# 31/31 [==============================] - 0s 7ms/step - loss: 0.0088 - accuracy: 0.9979
# Epoch 9/1500
# 31/31 [==============================] - 0s 14ms/step - loss: 0.0045 - accuracy: 0.9990
# Epoch 10/1500
# 31/31 [==============================] - 0s 11ms/step - loss: 0.0044 - accuracy: 0.9990
# Epoch 11/1500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 12/1500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.0026 - accuracy: 0.9995
# Epoch 13/1500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.0027 - accuracy: 0.9990
# Epoch 14/1500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.0067 - accuracy: 0.9979
# Epoch 15/1500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.0095 - accuracy: 0.9969
# Epoch 16/1500
# 31/31 [==============================] - 0s 7ms/step - loss: 0.0057 - accuracy: 0.9984
# Epoch 17/1500
# 31/31 [==============================] - 0s 6ms/step - loss: 0.0027 - accuracy: 0.9990
# Epoch 18/1500
# 31/31 [==============================] - 0s 6ms/step - loss: 0.0033 - accuracy: 0.9990
# Epoch 19/1500
# 31/31 [==============================] - 0s 6ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 20/1500
# 31/31 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 21/1500
# 31/31 [==============================] - 0s 7ms/step - loss: 8.7675e-04 - accuracy: 1.0000
# Epoch 22/1500
# 31/31 [==============================] - 0s 7ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 23/1500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.0022 - accuracy: 0.9995
# Epoch 24/1500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.0016 - accuracy: 0.9995
# Epoch 25/1500
# 31/31 [==============================] - 0s 7ms/step - loss: 0.0025 - accuracy: 0.9990
# Epoch 26/1500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 27/1500
# 31/31 [==============================] - 0s 7ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 28/1500
# 31/31 [==============================] - 0s 7ms/step - loss: 0.0034 - accuracy: 0.9990
# Epoch 29/1500
# 31/31 [==============================] - 0s 7ms/step - loss: 7.0878e-04 - accuracy: 1.0000
# Epoch 30/1500
# 31/31 [==============================] - 0s 7ms/step - loss: 0.0020 - accuracy: 0.9995
# Epoch 31/1500
# 31/31 [==============================] - 0s 7ms/step - loss: 0.0054 - accuracy: 0.9984
# Epoch 32/1500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.0036 - accuracy: 0.9984
# Epoch 33/1500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.0040 - accuracy: 0.9990
# Epoch 34/1500
# 31/31 [==============================] - 0s 9ms/step - loss: 0.0016 - accuracy: 0.9995
# Epoch 35/1500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.0012 - accuracy: 0.9995
# Epoch 36/1500
# 31/31 [==============================] - 0s 7ms/step - loss: 0.0062 - accuracy: 0.9979
# Epoch 37/1500
# 31/31 [==============================] - 0s 7ms/step - loss: 0.0020 - accuracy: 0.9995
# Epoch 38/1500
# 31/31 [==============================] - 0s 7ms/step - loss: 0.0017 - accuracy: 0.9990
# Epoch 39/1500
# 31/31 [==============================] - 0s 7ms/step - loss: 0.0036 - accuracy: 0.9990
# Epoch 40/1500
# 31/31 [==============================] - 0s 7ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 41/1500
# 31/31 [==============================] - 0s 8ms/step - loss: 8.1274e-04 - accuracy: 1.0000
# Epoch 42/1500
# 31/31 [==============================] - 0s 7ms/step - loss: 0.0025 - accuracy: 0.9990
# Epoch 43/1500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 44/1500
# 31/31 [==============================] - 0s 7ms/step - loss: 0.0042 - accuracy: 0.9990
# Epoch 45/1500
# 31/31 [==============================] - 0s 7ms/step - loss: 0.0030 - accuracy: 0.9990
# Epoch 46/1500
# 31/31 [==============================] - 0s 7ms/step - loss: 0.0034 - accuracy: 0.9984
# Epoch 47/1500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.0083 - accuracy: 0.9974
# Epoch 48/1500
# 31/31 [==============================] - 0s 7ms/step - loss: 0.0043 - accuracy: 0.9990
# Epoch 49/1500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.0023 - accuracy: 0.9995
# Epoch 50/1500
# 31/31 [==============================] - 0s 8ms/step - loss: 0.0023 - accuracy: 0.9990
# Epoch 51/1500
# 28/31 [==========================>...] - ETA: 0s - loss: 0.0021 - accuracy: 0.9994Restoring model weights from the end of the best epoch: 21.
# 31/31 [==============================] - 0s 8ms/step - loss: 0.0020 - accuracy: 0.9995
# Epoch 51: early stopping
# 6/6 [==============================] - 0s 2ms/step - loss: 2.3325 - accuracy: 0.6491
# 6/6 [==============================] - 0s 2ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.81 (21/26)
# Before appending - Cat IDs: 542, Predictions: 542, Actuals: 542, Gender: 542
# After appending - Cat IDs: 713, Predictions: 713, Actuals: 713, Gender: 713
# Final Test Results - Loss: 2.332531213760376, Accuracy: 0.6491228342056274, Precision: 0.5373497324716837, Recall: 0.703076923076923, F1 Score: 0.5824690290982425
# Confusion Matrix:
#  [[90  5 22]
#  [ 0  4  0]
#  [33  0 17]]
#
# Final Average F1-Score across all UNSEEN TEST sets: 0.5539634829229295
#
# Final Average Loss across all UNSEEN TEST sets: 1.9964379668235779
#
# Final Average Accuracy across all UNSEEN TEST sets: 0.6921195387840271
#
# Final Average Precision across all UNSEEN TEST sets: 0.6205853806357828
#
# Final Average Recall across all UNSEEN TEST sets: 0.6037880272356079

# %%
seed_2_folds_values = (unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1)

# Plotting all fold metrics
seed_2_folds_plot = plot_all_metrics(unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1, "Folds", "Fold Number")

# %% [markdown]
# ## Majority Voting on Total Entries per cat_id

# %%
# Debugging print statements
print(f'Checking - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
# Out:
# Checking - Cat IDs: 713, Predictions: 713, Actuals: 713, Gender: 713

# %%
# Create results df
full_results = pd.DataFrame({
    'cat_id': all_cat_ids,
    'predicted_age_group': all_predicted_age_groups,
    'actual_age_group': all_actual_age_groups,
    'all_gender': all_gender
})

# create a correct majority prediction column
full_results['correct'] = full_results['predicted_age_group'] == full_results['actual_age_group']

# %%
# Group by cat_id and aggregate predicted age groups
majority_votes = full_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first()

# Calculate the accuracy of majority voting
correct_predictions = (majority_votes == actual_groups).sum()
total_cats = len(actual_groups)
majority_vote_accuracy = correct_predictions / total_cats

logger(f"Overall Majority Vote Accuracy for cat_id: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

# store for final evaluation 
all_majority_vote_accuracies.append(majority_vote_accuracy)
# Out:
# Overall Majority Vote Accuracy for cat_id: 0.74 (81/110)

# %%
# Detailed df with predictions, actual labels, and comparison including majority vote
detailed_results = full_results.groupby('cat_id').apply(
    lambda x: pd.Series({
        'Predictions': list(x['predicted_age_group']),
        'Majority Vote': x['predicted_age_group'].mode()[0],
        'Actual Age Group': x['actual_age_group'].iloc[0],
        'Correct Majority Vote': x['predicted_age_group'].mode()[0] == x['actual_age_group'].iloc[0]
    })
).reset_index()

# Convert to DataFrame for better formatting and display
detailed_results = pd.DataFrame(detailed_results)

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 10)
pd.set_option('display.width', 1000)

sorted_detailed_results = detailed_results.sort_values(by='Correct Majority Vote', ascending=False)

# Display the sorted DataFrame
sorted_detailed_results
# Out:
#     cat_id                                        Predictions Majority Vote Actual Age Group  Correct Majority Vote
# 0     000B  [adult, senior, adult, adult, adult, adult, ad...         adult            adult                   True
# 80    074A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 78    072A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 77    071A  [adult, senior, adult, adult, adult, senior, a...         adult            adult                   True
# 76    070A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 74    068A  [adult, senior, adult, adult, senior, adult, s...         adult            adult                   True
# 73    067A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 72    066A                                            [adult]         adult            adult                   True
# 71    065A  [senior, senior, adult, adult, kitten, senior,...         adult            adult                   True
# 70    064A                                            [adult]         adult            adult                   True
# 69    063A  [senior, adult, senior, senior, kitten, adult,...         adult            adult                   True
# 68    062A                              [adult, adult, adult]         adult            adult                   True
# 66    060A                             [adult, kitten, adult]         adult            adult                   True
# 65    059A  [senior, adult, senior, senior, adult, adult, ...        senior           senior                   True
# 64    058A                            [adult, senior, senior]        senior           senior                   True
# 58    052A                                    [adult, senior]         adult            adult                   True
# 1     001A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 54    049A                                   [senior, kitten]        kitten           kitten                   True
# 53    048A                                           [kitten]        kitten           kitten                   True
# 51    045A                    [kitten, kitten, kitten, adult]        kitten           kitten                   True
# 50    044A           [kitten, kitten, kitten, kitten, kitten]        kitten           kitten                   True
# 79    073A                                            [adult]         adult            adult                   True
# 81    075A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 46    040A  [kitten, kitten, kitten, kitten, kitten, kitte...        kitten           kitten                   True
# 82    076A                                            [adult]         adult            adult                   True
# 107   115A                                           [kitten]        kitten           kitten                   True
# 105   111A  [kitten, kitten, kitten, kitten, kitten, kitte...        kitten           kitten                   True
# 104   110A                                           [kitten]        kitten           kitten                   True
# 102   108A            [senior, adult, senior, senior, senior]        senior           senior                   True
# 100   105A                             [adult, adult, senior]         adult            adult                   True
# 98    103A  [adult, adult, adult, adult, adult, senior, ad...         adult            adult                   True
# 97    102A                                     [adult, adult]         adult            adult                   True
# 96    101A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 95    100A                                            [adult]         adult            adult                   True
# 94    099A        [adult, adult, adult, kitten, adult, adult]         adult            adult                   True
# 93    097B  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 91    096A                                            [adult]         adult            adult                   True
# 90    095A  [senior, adult, adult, adult, adult, adult, ad...         adult            adult                   True
# 89    094A           [senior, senior, senior, senior, senior]        senior           senior                   True
# 87    092A                                            [adult]         adult            adult                   True
# 86    091A                                            [adult]         adult            adult                   True
# 85    090A                                           [senior]        senior           senior                   True
# 84    088A                                            [adult]         adult            adult                   True
# 83    087A                                     [adult, adult]         adult            adult                   True
# 49    043A                                           [kitten]        kitten           kitten                   True
# 55    050A           [kitten, kitten, kitten, kitten, kitten]        kitten           kitten                   True
# 45    039A         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 31    026A                       [adult, adult, adult, adult]         adult            adult                   True
# 28    025A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 26    023B                       [adult, adult, adult, adult]         adult            adult                   True
# 24    022A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 23    021A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 22    020A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 21    019B                                            [adult]         adult            adult                   True
# 20    019A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 19    018A                                     [adult, adult]         adult            adult                   True
# 17    015A  [senior, adult, adult, adult, adult, adult, ad...         adult            adult                   True
# 15    014A                              [adult, adult, adult]         adult            adult                   True
# 14    013B  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 13    012A                              [adult, adult, adult]         adult            adult                   True
# 12    011A                                   [senior, senior]        senior           senior                   True
# 11    010A         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 10    009A                       [adult, adult, adult, adult]         adult            adult                   True
# 9     008A               [adult, adult, adult, senior, adult]         adult            adult                   True
# 8     007A         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 7     006A                              [adult, adult, adult]         adult            adult                   True
# 4     003A                       [adult, adult, adult, adult]         adult            adult                   True
# 3     002B  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 2     002A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 29    025B                                    [senior, adult]         adult            adult                   True
# 25    023A         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 32    026B                                            [adult]         adult            adult                   True
# 35    028A  [senior, adult, adult, senior, adult, adult, a...         adult            adult                   True
# 43    037A                                    [senior, adult]         adult            adult                   True
# 42    036A  [senior, adult, adult, adult, adult, adult, ad...         adult            adult                   True
# 41    035A                                    [adult, senior]         adult            adult                   True
# 40    034A                             [adult, adult, kitten]         adult            adult                   True
# 39    033A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 37    031A  [adult, adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 38    032A                                     [adult, adult]         adult            adult                   True
# 34    027A  [adult, adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 36    029A  [senior, senior, senior, senior, adult, senior...        senior            adult                  False
# 47    041A                                           [senior]        senior           kitten                  False
# 108   116A  [senior, senior, adult, senior, adult, adult, ...         adult           senior                  False
# 48    042A  [senior, adult, adult, adult, adult, adult, ad...         adult           kitten                  False
# 106   113A                             [adult, adult, senior]         adult           senior                  False
# 44    038A                                   [kitten, kitten]        kitten            adult                  False
# 33    026C                                           [kitten]        kitten            adult                  False
# 103   109A                [adult, adult, adult, adult, adult]         adult           kitten                  False
# 5     004A                                           [kitten]        kitten            adult                  False
# 101   106A  [adult, adult, adult, adult, adult, adult, adu...         adult           senior                  False
# 6     005A  [adult, senior, senior, senior, senior, senior...        senior            adult                  False
# 99    104A                       [adult, adult, adult, adult]         adult           senior                  False
# 52    047A  [adult, adult, kitten, adult, adult, adult, ad...         adult           kitten                  False
# 75    069A                                   [senior, senior]        senior            adult                  False
# 27    024A                                            [adult]         adult           senior                  False
# 67    061A                                     [adult, adult]         adult           senior                  False
# 56    051A  [adult, adult, adult, adult, adult, adult, adu...         adult           senior                  False
# 92    097A  [adult, senior, adult, adult, adult, senior, s...         adult           senior                  False
# 57    051B  [adult, adult, adult, adult, adult, adult, adu...         adult           senior                  False
# 30    025C                    [adult, senior, senior, senior]        senior            adult                  False
# 59    053A                            [senior, adult, senior]        senior            adult                  False
# 88    093A                                     [adult, adult]         adult           senior                  False
# 16    014B  [senior, adult, adult, adult, kitten, kitten, ...         adult           kitten                  False
# 60    054A                                     [adult, adult]         adult           senior                  False
# 18    016A  [adult, adult, adult, adult, adult, adult, adu...         adult           senior                  False
# 61    055A  [adult, adult, adult, adult, adult, adult, adu...         adult           senior                  False
# 62    056A                             [adult, senior, adult]         adult           senior                  False
# 63    057A  [adult, adult, adult, adult, senior, adult, ad...         adult           senior                  False
# 109   117A  [adult, adult, adult, adult, adult, adult, adult]         adult           senior                  False

# %%
# Create df for majority votes
majority_df = majority_votes.reset_index()
majority_df.columns = ['cat_id', 'Majority_Vote']

# Get actual groups for each cat_id
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first().reset_index()

# Merge majority votes with actual groups
majority_with_actual = pd.merge(majority_df, actual_groups, on='cat_id')

# Add a column to check if the majority vote was correct
majority_with_actual['Majority_Correct'] = majority_with_actual['Majority_Vote'] == majority_with_actual['actual_age_group']

# Count correct majority votes per class
correct_majority_votes_per_class = majority_with_actual.groupby('actual_age_group')['Majority_Correct'].sum()

print("Correct Majority Votes per Class:")
print(correct_majority_votes_per_class)
# Out:
# Correct Majority Votes per Class:
# actual_age_group
# adult     65
# kitten    10
# senior     6
# Name: Majority_Correct, dtype: int64

# %%
# Calculate the total count and the number of correct predictions for each class
class_stats = majority_with_actual.groupby('actual_age_group').agg(
    total_count=('Majority_Correct', 'size'),  # Total number of cases per class
    correct_count=('Majority_Correct', 'sum')  # Sum of correct predictions per class
).reset_index()

# Calculate accuracy for each class
class_stats['accuracy'] = class_stats['correct_count'] / class_stats['total_count'] * 100

# store for final evaluation 
all_majority_vote_details.append(class_stats)

# Log detailed stats
print("Detailed Class Statistics for Majority Votes:")
print(class_stats)
# Out:
# Detailed Class Statistics for Majority Votes:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult           73             65  89.041096
# 1           kitten           15             10  66.666667
# 2           senior           22              6  27.272727

# %%
# Plot for Detailed Class Statistics for Majority Votes
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Accuracy of Majority Votes by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Detailed Class Statistics

# %%
# Calculate the total count and the number of correct predictions for each class
class_stats = full_results.groupby('actual_age_group').agg(
    total_count=('correct', 'size'),
    correct_count=('correct', 'sum')
).reset_index()

# Calculate accuracy for each class
class_stats['accuracy'] = class_stats['correct_count'] / class_stats['total_count'] * 100

# store for final evaluation 
all_class_stats.append(class_stats)

# Log the detailed stats
print("Detailed Class Statistics:")
print(class_stats)
# Out:
# Detailed Class Statistics:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult          473            406  85.835095
# 1           kitten           91             46  50.549451
# 2           senior          149             36  24.161074

# %%
# Plot for Detailed Class Statistics (Overall)
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Overall Accuracy by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Gender Exploration

# %%
# Group by gender and calculate the total count, correct predictions, and accuracy
gender_stats = full_results.groupby('all_gender').agg(
    count=('cat_id', 'size'),  # Total number of cases per gender
    correct=('correct', 'sum')  # Sum of correct predictions per gender
).reset_index()

# Calculate accuracy for each gender
gender_stats['accuracy'] = (gender_stats['correct'] / gender_stats['count'] * 100).round(2)

# Display the DataFrame
print("Accuracy by Gender:")
print(gender_stats)

# store for final evaluation 
all_gender_stats.append(gender_stats)
# Out:
# Accuracy by Gender:
#   all_gender  count  correct  accuracy
# 0          F    192      130     67.71
# 1          M    289      219     75.78
# 2          X    232      139     59.91

# %%
# Plot for Accuracy by Gender
styled_barplot(gender_stats, 'all_gender', 'accuracy', 
               'Accuracy by Gender', 
               'Gender', 'Accuracy (%)')

# %% [markdown]
# ### Log current total CV Stats

# %%
print("Total Majority Vote Accuracy so far:", all_majority_vote_accuracies)
print("Total Class Statistics so far:\n", all_class_stats)
print("Total Gender Accuracy so far:\n", all_gender_stats)
# Out:
# Total Majority Vote Accuracy so far: [0.7363636363636363, 0.7363636363636363]
# Total Class Statistics so far:
#  [  actual_age_group  total_count  correct_count   accuracy
# 0            adult          474            413  87.130802
# 1           kitten           95             43  45.263158
# 2           senior          149             41  27.516779,   actual_age_group  total_count  correct_count   accuracy
# 0            adult          473            406  85.835095
# 1           kitten           91             46  50.549451
# 2           senior          149             36  24.161074]
# Total Gender Accuracy so far:
#  [  all_gender  count  correct  accuracy
# 0          F    196      137     69.90
# 1          M    286      219     76.57
# 2          X    236      141     59.75,   all_gender  count  correct  accuracy
# 0          F    192      130     67.71
# 1          M    289      219     75.78
# 2          X    232      139     59.91]

# %% [markdown]
# # RANDOM SEED 3

# %%
# Set a fixed random seed for reproducibility
random.seed(int(random_seeds[2]))
np.random.seed(int(random_seeds[2]))
tf.random.set_seed(int(random_seeds[2]))

# Load datasets
dataframe = pd.read_csv('/Users/astrid/PycharmProjects/perch-2/scripts/perch_embeddings_april_10.csv')
augmented_df = pd.read_csv('/Users/astrid/PycharmProjects/perch-2/scripts/perch_embeddings_augm_d1.csv')

dataframe.drop('mean_freq', axis=1, inplace=True)

augmented_df.drop('mean_freq', axis=1, inplace=True)
augmented_df.drop('gender', axis=1, inplace=True)

def assign_age_group(age, age_groups):
    for group_name, age_range in age_groups.items():
        if age_range[0] <= age < age_range[1]:
            return group_name
    return 'Unknown'  # For any age that doesn't fit the defined groups

# Define age groups
age_groups = {
    'kitten': (0, 0.5),
    'adult': (0.5, 12),
    'senior': (12, 20)
}

# Create a new column for the age group
dataframe['age_group'] = dataframe['target'].apply(assign_age_group, age_groups=age_groups)
augmented_df['age_group'] = augmented_df['target'].apply(assign_age_group, age_groups=age_groups)

print(dataframe['age_group'].value_counts())
print(augmented_df['age_group'].value_counts())
# Out:
# adult     509
# senior    149
# kitten    135
# Name: age_group, dtype: int64
# senior    596
# kitten    540
# adult     509
# Name: age_group, dtype: int64

# %%
# Separate features and labels
X = dataframe.iloc[:, :-4].values  # all columns except the last four

# Encode the 'age_group' column as integers using LabelEncoder
label_encoder = LabelEncoder()
encoded_y = label_encoder.fit_transform(dataframe['age_group'].values)

# Use the encoded labels for splitting and one-hot encoding
y = encoded_y  

# Convert 'cat_id' column to numpy array to be used as groups array for GroupKFold
groups = dataframe['cat_id'].values

# %%
tf.keras.backend.clear_session()

# %% [markdown]
# ## Run Setup

# %%
all_cat_ids = []
all_predicted_age_groups = []
all_actual_age_groups = []
all_gender = []

# Define the StratifiedGroupKFold splitter for 4 fold CV with random shuffling
outer_cv = StratifiedGroupKFold(n_splits=4, shuffle=True, random_state=int(random_seeds[2]))

# unseen test set metrics
unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1 = [], [], [], [], []

outer_fold = 0

# Use the splitter to generate indices for training and testing sets
# Note: GroupShuffleSplit.split returns indices, so we use it to index the arrays
for train_val_idx, test_idx in outer_cv.split(X, y, groups):
    outer_fold += 1
    logger(f"outer_fold {outer_fold}", file=log_file_path)

    # Convert indices back to DataFrame for easy manipulation
    df_train_val = dataframe.iloc[train_val_idx]
    df_test = dataframe.iloc[test_idx]

    ##############################
    # ASSESSING SPLITS BY CAT_ID #
    ##############################
    
    # Get the distribution of groups
    training_validation_group_distribution = df_train_val['cat_id'].value_counts()  
    testing_group_distribution = df_test['cat_id'].value_counts()  
    
    # Log or print the distribution
    logger(f"Train Set Group Distribution:\n{training_validation_group_distribution}", file=log_file_path)
    logger(f"Testing Set Group Distribution:\n{testing_group_distribution}", file=log_file_path)

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val['gender'].value_counts()
    testing_gender_distribution = df_test['gender'].value_counts()
    
    # Log the distribution
    logger(f"Training Set Gender Distribution BEFORE SWAP:\n{training_gender_distribution}", file=log_file_path)
    logger(f"Testing Set Gender Distribution BEFORE SWAP:\n{testing_gender_distribution}", file=log_file_path)

    # Group by 'age_group' and then list unique 'cat_id' within each age group
    unique_cat_ids_per_age_group_train_val = df_train_val.groupby('age_group')['cat_id'].unique()
    unique_cat_ids_per_age_group_test = df_test.groupby('age_group')['cat_id'].unique()
    
    # Log results
    logger(f"Unique Cat IDs per Age Group in Training/Validation Set:\n{unique_cat_ids_per_age_group_train_val}", file=log_file_path)
    logger(f"Unique Cat IDs per Age Group in Testing Set:\n{unique_cat_ids_per_age_group_test}", file=log_file_path)

    # Calculate the count of unique identifiers per age group for training and testing set
    counts_train_val = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_train_val.items()}
    counts_test = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_test.items()}

    # Log the counts of unique identifiers per age group
    logger(f"Count of Unique Cat IDs per Age Group in Training/Validation Set:\n{counts_train_val}", file=log_file_path)
    logger(f"Count of Unique Cat IDs per Age Group in Testing Set:\n{counts_test}", file=log_file_path)

    #######################################################
    # CONTINUE WITH ENSURING VALID AND APPROPRIATE SPLITS #
    #######################################################
    
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    groups_train_val, groups_test = groups[train_val_idx], groups[test_idx]

    # logging identifier splits 
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)

    # check group splits
    check_initial_group_split(groups_train_val, groups_test)

    # Specify the cat_ids that must be in the training/validation set
    specific_cat_ids = ['000A', '046A']
    
    # Perform the swapping operation
    train_val_idx, test_idx = swap_cat_id_instances(dataframe, train_val_idx, test_idx, specific_cat_ids)
    
    # Re-assign the sets based on the updated indices
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    new_groups_train_val, new_groups_test = groups[train_val_idx], groups[test_idx]

    # Find differences for training and test sets
    moved_to_train_val, removed_from_train_val = find_group_differences(groups_train_val, new_groups_train_val)
    moved_to_test, removed_from_test = find_group_differences(groups_test, new_groups_test)
    
    # Display the results
    logger(f"Moved to Training/Validation Set:\n{moved_to_train_val}", file=log_file_path)
    logger(f"Removed from Training/Validation Set:\n{removed_from_train_val}", file=log_file_path)
    logger(f"Moved to Test Set:\n{moved_to_test}", file=log_file_path)
    logger(f"Removed from Test Set\n{removed_from_test}", file=log_file_path)

    # Update X_train_val, X_test, y_train_val, y_test, groups_train_val, groups_test based on updated indices
    X_train_val = X[train_val_idx]
    y_train_val = y[train_val_idx]
    groups_train_val = groups[train_val_idx]
    
    X_test = X[test_idx]
    y_test = y[test_idx]
    groups_test = groups[test_idx]

    # logging identifier splits again after potential swaps
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"AFTER SWAP - Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"AFTER SWAP - Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)
    
    # Verify the lengths are consistent
    logger(f"Length of X_train_val:\n{len(X_train_val)}", file=log_file_path)
    logger(f"Length of y_train_val:\n{len(y_train_val)}", file=log_file_path)
    logger(f"Length of groups_train_val:\n{len(groups_train_val)}", file=log_file_path)

    # Check group splits once more
    check_initial_group_split(groups_train_val, groups_test)

    # Convert the modified indices back to a DataFrame representing the updated df_train_val
    df_train_val_updated = dataframe.iloc[train_val_idx].copy()
    df_test_updated = dataframe.iloc[test_idx].copy()

    ############################
    # LOGGING AGE GROUP SPLITS #
    ############################

    # Get the distribution of age groups of age groups before the update
    training_validation_age_group_distribution = df_train_val['age_group'].value_counts()
    testing_age_group_distribution = df_test['age_group'].value_counts()
    
    # Logthe distribution
    logger(f"Train Age Group Distribution BEFORE SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution BEFORE SWAP:\n{testing_age_group_distribution}", file=log_file_path)

    # Get the distribution of age groups after the update
    training_validation_age_group_distribution = df_train_val_updated['age_group'].value_counts()
    testing_age_group_distribution = df_test_updated['age_group'].value_counts()
    
    # Log the distribution
    logger(f"Train Age Group Distribution AFTER SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution AFTER SWAP:\n{testing_age_group_distribution}", file=log_file_path)
    
    ########################################################
    # TRACKING FINAL CAT_IDs & GENDER AFTER REDISTRIBUTION #
    ########################################################

    # Get the distribution of groups
    training_validation_group_distribution = df_train_val_updated['cat_id'].value_counts()  
    testing_group_distribution = df_test_updated['cat_id'].value_counts()  

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val_updated['gender'].value_counts()
    testing_gender_distribution = df_test_updated['gender'].value_counts()
    
    logger(f"\n Starting training on unseen test set\n", file=log_file_path)

    ######################
    # ADD AUGMENTED DATA #
    ######################

    # Filter out augmented data derived from groups in the training set
    augmented_df_filtered = augmented_df[augmented_df['cat_id'].isin(groups_train_val)]
    
    # Convert augmented_df_filtered to numpy array (excluding target and other columns)
    augmented_array = augmented_df_filtered.drop(columns=['target', 'cat_id', 'age_group']).values
    
    # Concatenate the filtered augmented data with X_train_val
    X_train_val = np.concatenate([X_train_val, augmented_array])

    # Extract target labels from the filtered augmented DataFrame
    y_augmented = augmented_df_filtered['age_group'].values
    
    # Encode the labels using the same LabelEncoder instance
    y_augmented_encoded = label_encoder.transform(y_augmented)
    
    # Concatenate the encoded augmented labels with y_train_val
    y_train_val = np.concatenate([y_train_val, y_augmented_encoded])

    # Calculate the distribution of age groups in y_train_val
    age_group_distribution = Counter(y_train_val)
    print("Age group distribution:", age_group_distribution)

    # EarlyStopping callback: monitor 'loss' instead of 'val_loss' for the test set
    early_stopping = EarlyStopping(
        monitor='loss',  
        min_delta=0.001, 
        patience=30,  
        verbose=1,  
        restore_best_weights=True  
    )

    # One final shuffle to ensure randomness
    outer_shuffle_idx = np.random.permutation(len(X_train_val))
    X_train_val = X_train_val[outer_shuffle_idx]
    y_train_val = y_train_val[outer_shuffle_idx]
    
    # Scale the features
    scaler_full = StandardScaler().fit(X_train_val)
    X_train_full_scaled = scaler_full.transform(X_train_val)
    X_test_scaled = scaler_full.transform(X_test)
    
    # Encode the labels
    y_train_full_encoded = to_categorical(y_train_val)
    y_test_encoded = to_categorical(y_test)

    #######################
    # BUILD & TRAIN MODEL #
    #######################

    optimizers = {
        'Adamax': Adamax(learning_rate=0.00510251984616472)
    }
    
    # Model definition with dynamic number of layers
    model_full = Sequential()
    model_full.add(Dense(480, activation='relu', input_shape=(X_train_full_scaled.shape[1],)))
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.2011047009431978))  
    model_full.add(Dense(256, activation='relu',)) 
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.14956886311951184))  
    model_full.add(Dense(256, activation='relu'))  
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.42291461228250665))  
    model_full.add(Dense(3, activation='softmax'))  
    
    # Use the optimizer from the parameters
    optimizer = optimizers['Adamax']  # optimizer_key from parameters
    
    # Compile the model
    model_full.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    
    # Train the model on the full training set
    history_full = model_full.fit(X_train_full_scaled, y_train_full_encoded, epochs=1500, batch_size=64,
                                  verbose=1, callbacks=[early_stopping])
    
    # Evaluate the model on the held-out test set
    test_loss, test_accuracy = model_full.evaluate(X_test_scaled, y_test_encoded)

    y_test_pred_prob = model_full.predict(X_test_scaled)
    y_test_pred = np.argmax(y_test_pred_prob, axis=1)  
    y_test_true = np.argmax(y_test_encoded, axis=1)    

    ################################
    # LOG MAJORITY VOTE PER CAT_ID #
    ################################

    # Convert numeric predictions back to age group labels
    predicted_age_groups = label_encoder.inverse_transform(y_test_pred)
    actual_labels = label_encoder.inverse_transform(y_test_true)
    
    # Map predictions and actual labels back to cat_ids
    test_results = pd.DataFrame({
        'cat_id': df_test_updated['cat_id'],
        'predicted_age_group': predicted_age_groups,
        'actual_age_group': actual_labels
    })
    
    # Group by cat_id and aggregate predicted age groups
    majority_votes = test_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
    actual_groups = test_results.groupby('cat_id')['actual_age_group'].first()
    
    # Calculate the accuracy of majority voting
    correct_predictions = (majority_votes == actual_groups).sum()
    total_cats = len(actual_groups)
    majority_vote_accuracy = correct_predictions / total_cats
    
    # Log the accuracy of the majority voting
    logger(f"Majority Vote Accuracy for cat_id for this fold: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

    ####################################################
    # COLLECT PREDICTIONS FOR GENDER & CAT_ID ANALYSIS #
    ####################################################

    # Debugging print statements
    print(f'Before appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Extend lists with current fold results
    all_cat_ids.extend(df_test_updated['cat_id'].tolist())
    all_predicted_age_groups.extend(predicted_age_groups)
    all_actual_age_groups.extend(actual_labels)
    all_gender.extend(df_test_updated['gender'].tolist())

    # Debugging print statements
    print(f'After appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Calculate additional metrics
    test_precision = precision_score(y_test_true, y_test_pred, average='macro')  # Use 'macro' for imbalanced datasets
    test_recall = recall_score(y_test_true, y_test_pred, average='macro')
    test_f1 = f1_score(y_test_true, y_test_pred, average='macro')

    # prepare averages of outer metrics
    unseen_f1.append(test_f1)
    unseen_losses.append(test_loss)
    unseen_accuracies.append(test_accuracy)
    unseen_precisions.append(test_precision)
    unseen_recalls.append(test_recall)

    # Print final test results
    logger(f"Final Test Results - Loss: {test_loss}, Accuracy: {test_accuracy}, Precision: {test_precision}, Recall: {test_recall}, F1 Score: {test_f1}", file=log_file_path)

    # Generate the confusion matrix
    cm = confusion_matrix(y_test, y_test_pred)
    logger(f"Confusion Matrix:\n {cm}", file=log_file_path)

# Calculate the overall average metrics
unseen_set_avg_f1 = np.mean(unseen_f1)
unseen_set_avg_loss = np.mean(unseen_losses)
unseen_set_avg_acc = np.mean(unseen_accuracies)
unseen_set_avg_precision = np.mean(unseen_precisions)
unseen_set_avg_recall = np.mean(unseen_recalls)

# Append averages to total lists
all_f1.append(unseen_set_avg_f1)
all_losses.append(unseen_set_avg_loss)
all_accuracies.append(unseen_set_avg_acc)
all_precisions.append(unseen_set_avg_precision)
all_recalls.append(unseen_set_avg_recall)

logger(f"\nFinal Average F1-Score across all UNSEEN TEST sets: {unseen_set_avg_f1}", file=log_file_path)
logger(f"\nFinal Average Loss across all UNSEEN TEST sets: {unseen_set_avg_loss}", file=log_file_path)
logger(f"\nFinal Average Accuracy across all UNSEEN TEST sets: {unseen_set_avg_acc}", file=log_file_path)
logger(f"\nFinal Average Precision across all UNSEEN TEST sets: {unseen_set_avg_precision}", file=log_file_path)
logger(f"\nFinal Average Recall across all UNSEEN TEST sets: {unseen_set_avg_recall}\n", file=log_file_path)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# outer_fold 1
# Train Set Group Distribution:
# 046A    45
# 000A    39
# 103A    33
# 002B    30
# 047A    22
# 000B    19
# 057A    17
# 074A    16
# 097A    15
# 029A    15
# 002A    13
# 106A    13
# 051A    12
# 101A    12
# 116A    12
# 055A    12
# 111A    12
# 067A    11
# 063A    11
# 040A    10
# 025A    10
# 051B     9
# 016A     9
# 065A     9
# 072A     9
# 001A     9
# 005A     9
# 033A     9
# 022A     9
# 071A     9
# 013B     8
# 068A     8
# 015A     7
# 036A     7
# 031A     7
# 117A     7
# 027A     7
# 095A     7
# 007A     6
# 023A     6
# 044A     5
# 109A     5
# 021A     5
# 070A     5
# 094A     5
# 050A     5
# 108A     5
# 008A     5
# 026A     4
# 009A     4
# 025C     4
# 045A     4
# 104A     4
# 003A     4
# 058A     3
# 060A     3
# 012A     3
# 053A     3
# 006A     3
# 056A     3
# 113A     3
# 034A     3
# 035A     2
# 032A     2
# 025B     2
# 087A     2
# 038A     2
# 037A     2
# 061A     2
# 054A     2
# 004A     1
# 100A     1
# 110A     1
# 115A     1
# 088A     1
# 076A     1
# 048A     1
# 066A     1
# 096A     1
# 091A     1
# 026C     1
# 041A     1
# 049A     1
# 073A     1
# 024A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 020A    20
# 019A    17
# 097B    14
# 028A    11
# 042A    11
# 014B    10
# 059A    10
# 039A     6
# 099A     6
# 075A     5
# 023B     4
# 010A     3
# 105A     3
# 014A     3
# 062A     3
# 093A     2
# 018A     2
# 069A     2
# 052A     2
# 011A     2
# 102A     2
# 043A     1
# 064A     1
# 092A     1
# 019B     1
# 090A     1
# 026B     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    235
# X    208
# F    206
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    68
# M    51
# F    25
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [006A, 000A, 033A, 015A, 001A, 103A, 071A, 074...
# kitten    [044A, 111A, 040A, 046A, 047A, 109A, 050A, 049...
# senior    [097A, 057A, 106A, 104A, 055A, 113A, 116A, 051...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [097B, 028A, 019A, 020A, 062A, 039A, 099A, 014...
# kitten                                   [014B, 042A, 043A]
# senior                             [093A, 059A, 011A, 090A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 54, 'kitten': 13, 'senior': 18}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 20, 'kitten': 3, 'senior': 4}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '004A' '005A' '006A' '007A'
#  '008A' '009A' '012A' '013B' '015A' '016A' '021A' '022A' '023A' '024A'
#  '025A' '025B' '025C' '026A' '026C' '027A' '029A' '031A' '032A' '033A'
#  '034A' '035A' '036A' '037A' '038A' '040A' '041A' '044A' '045A' '046A'
#  '047A' '048A' '049A' '050A' '051A' '051B' '053A' '054A' '055A' '056A'
#  '057A' '058A' '060A' '061A' '063A' '065A' '066A' '067A' '068A' '070A'
#  '071A' '072A' '073A' '074A' '076A' '087A' '088A' '091A' '094A' '095A'
#  '096A' '097A' '100A' '101A' '103A' '104A' '106A' '108A' '109A' '110A'
#  '111A' '113A' '115A' '116A' '117A']
# Unique Test Group IDs:
# ['010A' '011A' '014A' '014B' '018A' '019A' '019B' '020A' '023B' '026B'
#  '028A' '039A' '042A' '043A' '052A' '059A' '062A' '064A' '069A' '075A'
#  '090A' '092A' '093A' '097B' '099A' '102A' '105A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '004A' '005A' '006A' '007A'
#  '008A' '009A' '012A' '013B' '015A' '016A' '021A' '022A' '023A' '024A'
#  '025A' '025B' '025C' '026A' '026C' '027A' '029A' '031A' '032A' '033A'
#  '034A' '035A' '036A' '037A' '038A' '040A' '041A' '044A' '045A' '046A'
#  '047A' '048A' '049A' '050A' '051A' '051B' '053A' '054A' '055A' '056A'
#  '057A' '058A' '060A' '061A' '063A' '065A' '066A' '067A' '068A' '070A'
#  '071A' '072A' '073A' '074A' '076A' '087A' '088A' '091A' '094A' '095A'
#  '096A' '097A' '100A' '101A' '103A' '104A' '106A' '108A' '109A' '110A'
#  '111A' '113A' '115A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['010A' '011A' '014A' '014B' '018A' '019A' '019B' '020A' '023B' '026B'
#  '028A' '039A' '042A' '043A' '052A' '059A' '062A' '064A' '069A' '075A'
#  '090A' '092A' '093A' '097B' '099A' '102A' '105A']
# Length of X_train_val:
# 649
# Length of y_train_val:
# 649
# Length of groups_train_val:
# 649
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     402
# senior    134
# kitten    113
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     107
# kitten     22
# senior     15
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     402
# senior    134
# kitten    113
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     107
# kitten     22
# senior     15
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 804, 2: 670, 1: 565})
# Epoch 1/1500
# 32/32 [==============================] - 1s 6ms/step - loss: 0.4252 - accuracy: 0.8460
# Epoch 2/1500
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0567 - accuracy: 0.9794
# Epoch 3/1500
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0244 - accuracy: 0.9931
# Epoch 4/1500
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0116 - accuracy: 0.9975
# Epoch 5/1500
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0079 - accuracy: 0.9985
# Epoch 6/1500
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0079 - accuracy: 0.9980
# Epoch 7/1500
# 32/32 [==============================] - 0s 8ms/step - loss: 0.0037 - accuracy: 0.9995
# Epoch 8/1500
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0044 - accuracy: 0.9985
# Epoch 9/1500
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0053 - accuracy: 0.9985
# Epoch 10/1500
# 32/32 [==============================] - 0s 8ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 11/1500
# 32/32 [==============================] - 0s 13ms/step - loss: 0.0031 - accuracy: 0.9995
# Epoch 12/1500
# 32/32 [==============================] - 0s 14ms/step - loss: 0.0064 - accuracy: 0.9985
# Epoch 13/1500
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0024 - accuracy: 0.9995
# Epoch 14/1500
# 32/32 [==============================] - 0s 8ms/step - loss: 0.0024 - accuracy: 0.9995
# Epoch 15/1500
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0024 - accuracy: 0.9995
# Epoch 16/1500
# 32/32 [==============================] - 0s 7ms/step - loss: 9.8701e-04 - accuracy: 1.0000
# Epoch 17/1500
# 32/32 [==============================] - 0s 6ms/step - loss: 0.0029 - accuracy: 0.9990
# Epoch 18/1500
# 32/32 [==============================] - 0s 6ms/step - loss: 7.5987e-04 - accuracy: 1.0000
# Epoch 19/1500
# 32/32 [==============================] - 0s 9ms/step - loss: 0.0042 - accuracy: 0.9985
# Epoch 20/1500
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0014 - accuracy: 0.9995
# Epoch 21/1500
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0023 - accuracy: 0.9995
# Epoch 22/1500
# 32/32 [==============================] - 0s 6ms/step - loss: 9.5857e-04 - accuracy: 1.0000
# Epoch 23/1500
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0013 - accuracy: 0.9995
# Epoch 24/1500
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 25/1500
# 32/32 [==============================] - 0s 8ms/step - loss: 0.0025 - accuracy: 0.9985
# Epoch 26/1500
# 32/32 [==============================] - 0s 8ms/step - loss: 0.0017 - accuracy: 0.9995
# Epoch 27/1500
# 32/32 [==============================] - 0s 7ms/step - loss: 9.5774e-04 - accuracy: 1.0000
# Epoch 28/1500
# 32/32 [==============================] - 0s 8ms/step - loss: 9.8541e-04 - accuracy: 1.0000
# Epoch 29/1500
# 32/32 [==============================] - 0s 8ms/step - loss: 4.5972e-04 - accuracy: 1.0000
# Epoch 30/1500
# 32/32 [==============================] - 0s 8ms/step - loss: 9.8416e-04 - accuracy: 1.0000
# Epoch 31/1500
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0022 - accuracy: 0.9995
# Epoch 32/1500
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0013 - accuracy: 0.9995
# Epoch 33/1500
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 34/1500
# 32/32 [==============================] - 0s 7ms/step - loss: 2.2632e-04 - accuracy: 1.0000
# Epoch 35/1500
# 32/32 [==============================] - 0s 6ms/step - loss: 3.5102e-04 - accuracy: 1.0000
# Epoch 36/1500
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0017 - accuracy: 0.9995
# Epoch 37/1500
# 32/32 [==============================] - 0s 7ms/step - loss: 3.8250e-04 - accuracy: 1.0000
# Epoch 38/1500
# 32/32 [==============================] - 0s 8ms/step - loss: 3.3207e-04 - accuracy: 1.0000
# Epoch 39/1500
# 32/32 [==============================] - 0s 8ms/step - loss: 2.8742e-04 - accuracy: 1.0000
# Epoch 40/1500
# 32/32 [==============================] - 0s 7ms/step - loss: 4.6962e-04 - accuracy: 1.0000
# Epoch 41/1500
# 32/32 [==============================] - 0s 7ms/step - loss: 4.0940e-04 - accuracy: 1.0000
# Epoch 42/1500
# 32/32 [==============================] - 0s 7ms/step - loss: 2.8237e-04 - accuracy: 1.0000
# Epoch 43/1500
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0032 - accuracy: 0.9990
# Epoch 44/1500
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0102 - accuracy: 0.9975
# Epoch 45/1500
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0108 - accuracy: 0.9956
# Epoch 46/1500
# 32/32 [==============================] - ETA: 0s - loss: 0.0048 - accuracy: 0.9980Restoring model weights from the end of the best epoch: 16.
# 32/32 [==============================] - 0s 7ms/step - loss: 0.0048 - accuracy: 0.9980
# Epoch 46: early stopping
# 5/5 [==============================] - 0s 2ms/step - loss: 0.9387 - accuracy: 0.7917
# 5/5 [==============================] - 0s 2ms/step
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Majority Vote Accuracy for cat_id for this fold: 0.78 (21/27)
# Before appending - Cat IDs: 0, Predictions: 0, Actuals: 0, Gender: 0
# After appending - Cat IDs: 144, Predictions: 144, Actuals: 144, Gender: 144
# Final Test Results - Loss: 0.9386683702468872, Accuracy: 0.7916666865348816, Precision: 0.7579365079365079, Recall: 0.6424997639950911, F1 Score: 0.6409553916403231
# Confusion Matrix:
#  [[96  0 11]
#  [11  8  3]
#  [ 5  0 10]]
# outer_fold 2
# Train Set Group Distribution:
# 046A    45
# 000A    39
# 103A    33
# 002B    30
# 047A    22
# 020A    20
# 000B    19
# 019A    17
# 057A    17
# 097A    15
# 029A    15
# 097B    14
# 002A    13
# 106A    13
# 116A    12
# 111A    12
# 051A    12
# 055A    12
# 028A    11
# 042A    11
# 025A    10
# 014B    10
# 059A    10
# 065A     9
# 072A     9
# 071A     9
# 033A     9
# 068A     8
# 015A     7
# 031A     7
# 036A     7
# 117A     7
# 007A     6
# 039A     6
# 099A     6
# 023A     6
# 075A     5
# 094A     5
# 008A     5
# 050A     5
# 070A     5
# 003A     4
# 023B     4
# 025C     4
# 105A     3
# 053A     3
# 113A     3
# 014A     3
# 062A     3
# 056A     3
# 034A     3
# 012A     3
# 060A     3
# 010A     3
# 035A     2
# 011A     2
# 061A     2
# 052A     2
# 102A     2
# 054A     2
# 093A     2
# 018A     2
# 038A     2
# 069A     2
# 032A     2
# 064A     1
# 088A     1
# 090A     1
# 100A     1
# 110A     1
# 115A     1
# 019B     1
# 004A     1
# 049A     1
# 048A     1
# 076A     1
# 043A     1
# 026C     1
# 073A     1
# 041A     1
# 092A     1
# 026B     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 074A    16
# 101A    12
# 067A    11
# 063A    11
# 040A    10
# 001A     9
# 022A     9
# 005A     9
# 016A     9
# 051B     9
# 013B     8
# 095A     7
# 027A     7
# 109A     5
# 021A     5
# 108A     5
# 044A     5
# 045A     4
# 009A     4
# 104A     4
# 026A     4
# 058A     3
# 006A     3
# 087A     2
# 037A     2
# 025B     2
# 096A     1
# 091A     1
# 066A     1
# 024A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    235
# M    196
# F    183
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# M    90
# F    48
# X    41
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [000A, 033A, 015A, 103A, 071A, 097B, 028A, 019...
# kitten    [014B, 111A, 046A, 047A, 042A, 050A, 043A, 049...
# senior    [093A, 097A, 057A, 106A, 055A, 059A, 113A, 116...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [006A, 001A, 074A, 067A, 101A, 022A, 095A, 005...
# kitten                             [044A, 040A, 109A, 045A]
# senior                 [104A, 051B, 058A, 016A, 108A, 024A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 54, 'kitten': 12, 'senior': 16}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 20, 'kitten': 4, 'senior': 6}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '002A' '002B' '003A' '004A' '007A' '008A' '010A' '011A'
#  '012A' '014A' '014B' '015A' '018A' '019A' '019B' '020A' '023A' '023B'
#  '025A' '025C' '026B' '026C' '028A' '029A' '031A' '032A' '033A' '034A'
#  '035A' '036A' '038A' '039A' '041A' '042A' '043A' '046A' '047A' '048A'
#  '049A' '050A' '051A' '052A' '053A' '054A' '055A' '056A' '057A' '059A'
#  '060A' '061A' '062A' '064A' '065A' '068A' '069A' '070A' '071A' '072A'
#  '073A' '075A' '076A' '088A' '090A' '092A' '093A' '094A' '097A' '097B'
#  '099A' '100A' '102A' '103A' '105A' '106A' '110A' '111A' '113A' '115A'
#  '116A' '117A']
# Unique Test Group IDs:
# ['001A' '005A' '006A' '009A' '013B' '016A' '021A' '022A' '024A' '025B'
#  '026A' '027A' '037A' '040A' '044A' '045A' '051B' '058A' '063A' '066A'
#  '067A' '074A' '087A' '091A' '095A' '096A' '101A' '104A' '108A' '109A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '002A' '002B' '003A' '004A' '007A' '008A' '010A' '011A'
#  '012A' '014A' '014B' '015A' '018A' '019A' '019B' '020A' '023A' '023B'
#  '025A' '025C' '026B' '026C' '028A' '029A' '031A' '032A' '033A' '034A'
#  '035A' '036A' '038A' '039A' '041A' '042A' '043A' '046A' '047A' '048A'
#  '049A' '050A' '051A' '052A' '053A' '054A' '055A' '056A' '057A' '059A'
#  '060A' '061A' '062A' '064A' '065A' '068A' '069A' '070A' '071A' '072A'
#  '073A' '075A' '076A' '088A' '090A' '092A' '093A' '094A' '097A' '097B'
#  '099A' '100A' '102A' '103A' '105A' '106A' '110A' '111A' '113A' '115A'
#  '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['001A' '005A' '006A' '009A' '013B' '016A' '021A' '022A' '024A' '025B'
#  '026A' '027A' '037A' '040A' '044A' '045A' '051B' '058A' '063A' '066A'
#  '067A' '074A' '087A' '091A' '095A' '096A' '101A' '104A' '108A' '109A']
# Length of X_train_val:
# 614
# Length of y_train_val:
# 614
# Length of groups_train_val:
# 614
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     385
# senior    118
# kitten    111
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     124
# senior     31
# kitten     24
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     385
# senior    118
# kitten    111
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     124
# senior     31
# kitten     24
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 770, 2: 590, 1: 555})
# Epoch 1/1500
# 30/30 [==============================] - 1s 7ms/step - loss: 0.3686 - accuracy: 0.8721
# Epoch 2/1500
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0467 - accuracy: 0.9833
# Epoch 3/1500
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0174 - accuracy: 0.9927
# Epoch 4/1500
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0129 - accuracy: 0.9963
# Epoch 5/1500
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0057 - accuracy: 1.0000
# Epoch 6/1500
# 30/30 [==============================] - 0s 9ms/step - loss: 0.0063 - accuracy: 0.9979
# Epoch 7/1500
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0046 - accuracy: 0.9984
# Epoch 8/1500
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0031 - accuracy: 0.9995
# Epoch 9/1500
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 10/1500
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0019 - accuracy: 0.9995
# Epoch 11/1500
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 12/1500
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 13/1500
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0017 - accuracy: 0.9995
# Epoch 14/1500
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0017 - accuracy: 0.9995
# Epoch 15/1500
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0033 - accuracy: 0.9990
# Epoch 16/1500
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 17/1500
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0016 - accuracy: 0.9995
# Epoch 18/1500
# 30/30 [==============================] - 0s 6ms/step - loss: 8.1003e-04 - accuracy: 1.0000
# Epoch 19/1500
# 30/30 [==============================] - 0s 8ms/step - loss: 0.0020 - accuracy: 0.9995
# Epoch 20/1500
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0028 - accuracy: 0.9984
# Epoch 21/1500
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0021 - accuracy: 0.9990
# Epoch 22/1500
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0016 - accuracy: 0.9995
# Epoch 23/1500
# 30/30 [==============================] - 0s 7ms/step - loss: 9.9709e-04 - accuracy: 1.0000
# Epoch 24/1500
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0025 - accuracy: 0.9990
# Epoch 25/1500
# 30/30 [==============================] - 0s 6ms/step - loss: 7.5052e-04 - accuracy: 1.0000
# Epoch 26/1500
# 30/30 [==============================] - 0s 7ms/step - loss: 7.2121e-04 - accuracy: 1.0000
# Epoch 27/1500
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0011 - accuracy: 0.9995
# Epoch 28/1500
# 30/30 [==============================] - 0s 6ms/step - loss: 5.6194e-04 - accuracy: 1.0000
# Epoch 29/1500
# 30/30 [==============================] - 0s 11ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 30/1500
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0016 - accuracy: 0.9995
# Epoch 31/1500
# 30/30 [==============================] - 0s 6ms/step - loss: 3.7431e-04 - accuracy: 1.0000
# Epoch 32/1500
# 30/30 [==============================] - 0s 7ms/step - loss: 8.0276e-04 - accuracy: 1.0000
# Epoch 33/1500
# 30/30 [==============================] - 0s 7ms/step - loss: 4.1164e-04 - accuracy: 1.0000
# Epoch 34/1500
# 30/30 [==============================] - 0s 8ms/step - loss: 9.4579e-04 - accuracy: 0.9995
# Epoch 35/1500
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 0.9995
# Epoch 36/1500
# 30/30 [==============================] - 0s 7ms/step - loss: 4.6760e-04 - accuracy: 1.0000
# Epoch 37/1500
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0019 - accuracy: 0.9990
# Epoch 38/1500
# 30/30 [==============================] - 0s 7ms/step - loss: 8.8482e-04 - accuracy: 0.9995
# Epoch 39/1500
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0031 - accuracy: 0.9995
# Epoch 40/1500
# 30/30 [==============================] - 0s 7ms/step - loss: 8.8834e-04 - accuracy: 1.0000
# Epoch 41/1500
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0035 - accuracy: 0.9990
# Epoch 42/1500
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0014 - accuracy: 0.9995
# Epoch 43/1500
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0065 - accuracy: 0.9990
# Epoch 44/1500
# 30/30 [==============================] - 0s 6ms/step - loss: 3.9471e-04 - accuracy: 1.0000
# Epoch 45/1500
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0014 - accuracy: 0.9995
# Epoch 46/1500
# 30/30 [==============================] - 0s 7ms/step - loss: 7.3595e-04 - accuracy: 1.0000
# Epoch 47/1500
# 30/30 [==============================] - 0s 7ms/step - loss: 0.0024 - accuracy: 0.9984
# Epoch 48/1500
# 25/30 [========================>.....] - ETA: 0s - loss: 4.6694e-04 - accuracy: 1.0000Restoring model weights from the end of the best epoch: 18.
# 30/30 [==============================] - 0s 7ms/step - loss: 5.5476e-04 - accuracy: 1.0000
# Epoch 48: early stopping
# 6/6 [==============================] - 0s 2ms/step - loss: 2.1704 - accuracy: 0.6872
# 6/6 [==============================] - 0s 2ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.67 (20/30)
# Before appending - Cat IDs: 144, Predictions: 144, Actuals: 144, Gender: 144
# After appending - Cat IDs: 323, Predictions: 323, Actuals: 323, Gender: 323
# Final Test Results - Loss: 2.1704487800598145, Accuracy: 0.6871508359909058, Precision: 0.6561996779388083, Recall: 0.53584229390681, F1 Score: 0.5766660663240095
# Confusion Matrix:
#  [[103   0  21]
#  [ 10  14   0]
#  [ 25   0   6]]
# outer_fold 3
# Train Set Group Distribution:
# 046A    45
# 103A    33
# 002B    30
# 020A    20
# 057A    17
# 019A    17
# 074A    16
# 029A    15
# 097B    14
# 055A    12
# 051A    12
# 101A    12
# 042A    11
# 063A    11
# 067A    11
# 028A    11
# 040A    10
# 014B    10
# 025A    10
# 059A    10
# 071A     9
# 022A     9
# 001A     9
# 005A     9
# 016A     9
# 051B     9
# 068A     8
# 013B     8
# 117A     7
# 031A     7
# 036A     7
# 027A     7
# 095A     7
# 023A     6
# 039A     6
# 099A     6
# 044A     5
# 075A     5
# 094A     5
# 050A     5
# 109A     5
# 108A     5
# 021A     5
# 003A     4
# 026A     4
# 045A     4
# 023B     4
# 104A     4
# 009A     4
# 060A     3
# 058A     3
# 010A     3
# 006A     3
# 062A     3
# 014A     3
# 105A     3
# 093A     2
# 025B     2
# 037A     2
# 102A     2
# 061A     2
# 011A     2
# 052A     2
# 018A     2
# 087A     2
# 069A     2
# 032A     2
# 054A     2
# 092A     1
# 115A     1
# 024A     1
# 090A     1
# 096A     1
# 110A     1
# 076A     1
# 064A     1
# 043A     1
# 041A     1
# 019B     1
# 004A     1
# 066A     1
# 091A     1
# 026B     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 000A    39
# 047A    22
# 000B    19
# 097A    15
# 106A    13
# 002A    13
# 111A    12
# 116A    12
# 072A     9
# 065A     9
# 033A     9
# 015A     7
# 007A     6
# 008A     5
# 070A     5
# 025C     4
# 053A     3
# 012A     3
# 113A     3
# 056A     3
# 034A     3
# 038A     2
# 035A     2
# 073A     1
# 049A     1
# 026C     1
# 048A     1
# 088A     1
# 100A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    237
# X    207
# F    125
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# F    106
# X     69
# M     49
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [006A, 001A, 103A, 071A, 097B, 028A, 019A, 074...
# kitten    [044A, 014B, 040A, 046A, 042A, 109A, 050A, 043...
# senior    [093A, 057A, 104A, 055A, 059A, 051B, 054A, 117...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [000A, 033A, 015A, 034A, 072A, 065A, 002A, 038...
# kitten                             [111A, 047A, 049A, 048A]
# senior                       [097A, 106A, 113A, 116A, 056A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 54, 'kitten': 12, 'senior': 17}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 20, 'kitten': 4, 'senior': 5}
# Unique Training/Validation Group IDs:
# ['001A' '002B' '003A' '004A' '005A' '006A' '009A' '010A' '011A' '013B'
#  '014A' '014B' '016A' '018A' '019A' '019B' '020A' '021A' '022A' '023A'
#  '023B' '024A' '025A' '025B' '026A' '026B' '027A' '028A' '029A' '031A'
#  '032A' '036A' '037A' '039A' '040A' '041A' '042A' '043A' '044A' '045A'
#  '046A' '050A' '051A' '051B' '052A' '054A' '055A' '057A' '058A' '059A'
#  '060A' '061A' '062A' '063A' '064A' '066A' '067A' '068A' '069A' '071A'
#  '074A' '075A' '076A' '087A' '090A' '091A' '092A' '093A' '094A' '095A'
#  '096A' '097B' '099A' '101A' '102A' '103A' '104A' '105A' '108A' '109A'
#  '110A' '115A' '117A']
# Unique Test Group IDs:
# ['000A' '000B' '002A' '007A' '008A' '012A' '015A' '025C' '026C' '033A'
#  '034A' '035A' '038A' '047A' '048A' '049A' '053A' '056A' '065A' '070A'
#  '072A' '073A' '088A' '097A' '100A' '106A' '111A' '113A' '116A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'000A'}
# Removed from Training/Validation Set:
# {'019A'}
# Moved to Test Set:
# {'019A'}
# Removed from Test Set
# {'000A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '001A' '002B' '003A' '004A' '005A' '006A' '009A' '010A' '011A'
#  '013B' '014A' '014B' '016A' '018A' '019B' '020A' '021A' '022A' '023A'
#  '023B' '024A' '025A' '025B' '026A' '026B' '027A' '028A' '029A' '031A'
#  '032A' '036A' '037A' '039A' '040A' '041A' '042A' '043A' '044A' '045A'
#  '046A' '050A' '051A' '051B' '052A' '054A' '055A' '057A' '058A' '059A'
#  '060A' '061A' '062A' '063A' '064A' '066A' '067A' '068A' '069A' '071A'
#  '074A' '075A' '076A' '087A' '090A' '091A' '092A' '093A' '094A' '095A'
#  '096A' '097B' '099A' '101A' '102A' '103A' '104A' '105A' '108A' '109A'
#  '110A' '115A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['000B' '002A' '007A' '008A' '012A' '015A' '019A' '025C' '026C' '033A'
#  '034A' '035A' '038A' '047A' '048A' '049A' '053A' '056A' '065A' '070A'
#  '072A' '073A' '088A' '097A' '100A' '106A' '111A' '113A' '116A']
# Length of X_train_val:
# 591
# Length of y_train_val:
# 591
# Length of groups_train_val:
# 591
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     367
# senior    103
# kitten     99
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     142
# senior     46
# kitten     36
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     389
# senior    103
# kitten     99
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     120
# senior     46
# kitten     36
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 778, 2: 515, 1: 495})
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Epoch 1/1500
# 28/28 [==============================] - 1s 5ms/step - loss: 0.4359 - accuracy: 0.8473
# Epoch 2/1500
# 28/28 [==============================] - 0s 5ms/step - loss: 0.0639 - accuracy: 0.9782
# Epoch 3/1500
# 28/28 [==============================] - 0s 6ms/step - loss: 0.0199 - accuracy: 0.9922
# Epoch 4/1500
# 28/28 [==============================] - 0s 7ms/step - loss: 0.0188 - accuracy: 0.9933
# Epoch 5/1500
# 28/28 [==============================] - 0s 6ms/step - loss: 0.0081 - accuracy: 0.9989
# Epoch 6/1500
# 28/28 [==============================] - 0s 7ms/step - loss: 0.0088 - accuracy: 0.9966
# Epoch 7/1500
# 28/28 [==============================] - 0s 7ms/step - loss: 0.0080 - accuracy: 0.9972
# Epoch 8/1500
# 28/28 [==============================] - 0s 7ms/step - loss: 0.0048 - accuracy: 0.9989
# Epoch 9/1500
# 28/28 [==============================] - 0s 6ms/step - loss: 0.0035 - accuracy: 0.9994
# Epoch 10/1500
# 28/28 [==============================] - 0s 7ms/step - loss: 0.0025 - accuracy: 0.9994
# Epoch 11/1500
# 28/28 [==============================] - 0s 6ms/step - loss: 0.0043 - accuracy: 0.9994
# Epoch 12/1500
# 28/28 [==============================] - 0s 6ms/step - loss: 0.0032 - accuracy: 0.9989
# Epoch 13/1500
# 28/28 [==============================] - 0s 7ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 14/1500
# 28/28 [==============================] - 0s 6ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 15/1500
# 28/28 [==============================] - 0s 7ms/step - loss: 9.6453e-04 - accuracy: 1.0000
# Epoch 16/1500
# 28/28 [==============================] - 0s 7ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 17/1500
# 28/28 [==============================] - 0s 7ms/step - loss: 8.6516e-04 - accuracy: 1.0000
# Epoch 18/1500
# 28/28 [==============================] - 0s 6ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 19/1500
# 28/28 [==============================] - 0s 6ms/step - loss: 6.1061e-04 - accuracy: 1.0000
# Epoch 20/1500
# 28/28 [==============================] - 0s 6ms/step - loss: 0.0026 - accuracy: 0.9994
# Epoch 21/1500
# 28/28 [==============================] - 0s 7ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 22/1500
# 28/28 [==============================] - 0s 7ms/step - loss: 0.0020 - accuracy: 0.9994
# Epoch 23/1500
# 28/28 [==============================] - 0s 6ms/step - loss: 0.0019 - accuracy: 0.9994
# Epoch 24/1500
# 28/28 [==============================] - 0s 7ms/step - loss: 8.1414e-04 - accuracy: 1.0000
# Epoch 25/1500
# 28/28 [==============================] - 0s 6ms/step - loss: 5.4393e-04 - accuracy: 1.0000
# Epoch 26/1500
# 28/28 [==============================] - 0s 7ms/step - loss: 7.4570e-04 - accuracy: 1.0000
# Epoch 27/1500
# 28/28 [==============================] - 0s 7ms/step - loss: 0.0018 - accuracy: 0.9989
# Epoch 28/1500
# 28/28 [==============================] - 0s 7ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 29/1500
# 28/28 [==============================] - 0s 7ms/step - loss: 0.0015 - accuracy: 0.9994
# Epoch 30/1500
# 28/28 [==============================] - 0s 7ms/step - loss: 7.5197e-04 - accuracy: 1.0000
# Epoch 31/1500
# 28/28 [==============================] - 0s 6ms/step - loss: 6.6375e-04 - accuracy: 1.0000
# Epoch 32/1500
# 28/28 [==============================] - 0s 6ms/step - loss: 4.7836e-04 - accuracy: 1.0000
# Epoch 33/1500
# 28/28 [==============================] - 0s 6ms/step - loss: 0.0014 - accuracy: 0.9994
# Epoch 34/1500
# 28/28 [==============================] - 0s 6ms/step - loss: 6.0200e-04 - accuracy: 1.0000
# Epoch 35/1500
# 28/28 [==============================] - 0s 6ms/step - loss: 4.0683e-04 - accuracy: 1.0000
# Epoch 36/1500
# 28/28 [==============================] - 0s 7ms/step - loss: 7.7793e-04 - accuracy: 1.0000
# Epoch 37/1500
# 28/28 [==============================] - 0s 7ms/step - loss: 7.0761e-04 - accuracy: 1.0000
# Epoch 38/1500
# 28/28 [==============================] - 0s 7ms/step - loss: 4.3942e-04 - accuracy: 1.0000
# Epoch 39/1500
# 28/28 [==============================] - 0s 7ms/step - loss: 1.9740e-04 - accuracy: 1.0000
# Epoch 40/1500
# 28/28 [==============================] - 0s 7ms/step - loss: 5.9716e-04 - accuracy: 1.0000
# Epoch 41/1500
# 28/28 [==============================] - 0s 6ms/step - loss: 0.0015 - accuracy: 0.9994
# Epoch 42/1500
# 28/28 [==============================] - 0s 6ms/step - loss: 3.9692e-04 - accuracy: 1.0000
# Epoch 43/1500
# 28/28 [==============================] - 0s 7ms/step - loss: 6.3811e-04 - accuracy: 1.0000
# Epoch 44/1500
# 25/28 [=========================>....] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000Restoring model weights from the end of the best epoch: 14.
# 28/28 [==============================] - 0s 7ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 44: early stopping
# 7/7 [==============================] - 0s 2ms/step - loss: 2.3618 - accuracy: 0.6980
# 7/7 [==============================] - 0s 2ms/step
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Majority Vote Accuracy for cat_id for this fold: 0.79 (23/29)
# Before appending - Cat IDs: 323, Predictions: 323, Actuals: 323, Gender: 323
# After appending - Cat IDs: 525, Predictions: 525, Actuals: 525, Gender: 525
# Final Test Results - Loss: 2.361757755279541, Accuracy: 0.698019802570343, Precision: 0.7365124911753319, Recall: 0.5474235104669888, F1 Score: 0.5856367908001845
# Confusion Matrix:
#  [[112   3   5]
#  [ 23  13   0]
#  [ 29   1  16]]
# outer_fold 4
# Train Set Group Distribution:
# 000A    39
# 047A    22
# 020A    20
# 000B    19
# 019A    17
# 074A    16
# 097A    15
# 097B    14
# 106A    13
# 002A    13
# 111A    12
# 116A    12
# 101A    12
# 067A    11
# 042A    11
# 063A    11
# 028A    11
# 059A    10
# 014B    10
# 040A    10
# 065A     9
# 016A     9
# 051B     9
# 072A     9
# 033A     9
# 022A     9
# 005A     9
# 001A     9
# 013B     8
# 095A     7
# 015A     7
# 027A     7
# 039A     6
# 099A     6
# 007A     6
# 109A     5
# 044A     5
# 008A     5
# 108A     5
# 075A     5
# 021A     5
# 070A     5
# 025C     4
# 104A     4
# 026A     4
# 023B     4
# 045A     4
# 009A     4
# 058A     3
# 006A     3
# 012A     3
# 053A     3
# 010A     3
# 056A     3
# 113A     3
# 034A     3
# 014A     3
# 062A     3
# 105A     3
# 052A     2
# 093A     2
# 025B     2
# 037A     2
# 102A     2
# 011A     2
# 035A     2
# 018A     2
# 038A     2
# 087A     2
# 069A     2
# 019B     1
# 024A     1
# 090A     1
# 100A     1
# 043A     1
# 096A     1
# 073A     1
# 088A     1
# 026C     1
# 064A     1
# 048A     1
# 066A     1
# 049A     1
# 092A     1
# 091A     1
# 026B     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 046A    45
# 103A    33
# 002B    30
# 057A    17
# 029A    15
# 055A    12
# 051A    12
# 025A    10
# 071A     9
# 068A     8
# 036A     7
# 117A     7
# 031A     7
# 023A     6
# 094A     5
# 050A     5
# 003A     4
# 060A     3
# 054A     2
# 032A     2
# 061A     2
# 076A     1
# 041A     1
# 004A     1
# 115A     1
# 110A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    190
# F    179
# X    178
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    98
# M    96
# F    52
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [006A, 000A, 033A, 015A, 001A, 097B, 028A, 019...
# kitten    [044A, 014B, 111A, 040A, 047A, 042A, 109A, 043...
# senior    [093A, 097A, 106A, 104A, 059A, 113A, 116A, 051...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [103A, 071A, 002B, 029A, 023A, 025A, 032A, 076...
# kitten                       [046A, 050A, 041A, 115A, 110A]
# senior           [057A, 055A, 054A, 117A, 051A, 094A, 061A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 60, 'kitten': 11, 'senior': 15}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 14, 'kitten': 5, 'senior': 7}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '005A' '006A' '007A' '008A' '009A' '010A'
#  '011A' '012A' '013B' '014A' '014B' '015A' '016A' '018A' '019A' '019B'
#  '020A' '021A' '022A' '023B' '024A' '025B' '025C' '026A' '026B' '026C'
#  '027A' '028A' '033A' '034A' '035A' '037A' '038A' '039A' '040A' '042A'
#  '043A' '044A' '045A' '047A' '048A' '049A' '051B' '052A' '053A' '056A'
#  '058A' '059A' '062A' '063A' '064A' '065A' '066A' '067A' '069A' '070A'
#  '072A' '073A' '074A' '075A' '087A' '088A' '090A' '091A' '092A' '093A'
#  '095A' '096A' '097A' '097B' '099A' '100A' '101A' '102A' '104A' '105A'
#  '106A' '108A' '109A' '111A' '113A' '116A']
# Unique Test Group IDs:
# ['002B' '003A' '004A' '023A' '025A' '029A' '031A' '032A' '036A' '041A'
#  '046A' '050A' '051A' '054A' '055A' '057A' '060A' '061A' '068A' '071A'
#  '076A' '094A' '103A' '110A' '115A' '117A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'046A'}
# Removed from Training/Validation Set:
# {'049A'}
# Moved to Test Set:
# {'049A'}
# Removed from Test Set
# {'046A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '005A' '006A' '007A' '008A' '009A' '010A'
#  '011A' '012A' '013B' '014A' '014B' '015A' '016A' '018A' '019A' '019B'
#  '020A' '021A' '022A' '023B' '024A' '025B' '025C' '026A' '026B' '026C'
#  '027A' '028A' '033A' '034A' '035A' '037A' '038A' '039A' '040A' '042A'
#  '043A' '044A' '045A' '046A' '047A' '048A' '051B' '052A' '053A' '056A'
#  '058A' '059A' '062A' '063A' '064A' '065A' '066A' '067A' '069A' '070A'
#  '072A' '073A' '074A' '075A' '087A' '088A' '090A' '091A' '092A' '093A'
#  '095A' '096A' '097A' '097B' '099A' '100A' '101A' '102A' '104A' '105A'
#  '106A' '108A' '109A' '111A' '113A' '116A']
# AFTER SWAP - Unique Test Group IDs:
# ['002B' '003A' '004A' '023A' '025A' '029A' '031A' '032A' '036A' '041A'
#  '049A' '050A' '051A' '054A' '055A' '057A' '060A' '061A' '068A' '071A'
#  '076A' '094A' '103A' '110A' '115A' '117A']
# Length of X_train_val:
# 591
# Length of y_train_val:
# 591
# Length of groups_train_val:
# 591
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     373
# senior     92
# kitten     82
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     136
# senior     57
# kitten     53
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     373
# kitten    126
# senior     92
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     136
# senior     57
# kitten      9
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 746, 1: 630, 2: 460})
# Epoch 1/1500
# 29/29 [==============================] - 1s 6ms/step - loss: 0.4243 - accuracy: 0.8393
# Epoch 2/1500
# 29/29 [==============================] - 0s 6ms/step - loss: 0.0465 - accuracy: 0.9842
# Epoch 3/1500
# 29/29 [==============================] - 0s 5ms/step - loss: 0.0201 - accuracy: 0.9924
# Epoch 4/1500
# 29/29 [==============================] - 0s 6ms/step - loss: 0.0138 - accuracy: 0.9956
# Epoch 5/1500
# 29/29 [==============================] - 0s 7ms/step - loss: 0.0062 - accuracy: 0.9989
# Epoch 6/1500
# 29/29 [==============================] - 0s 6ms/step - loss: 0.0089 - accuracy: 0.9984
# Epoch 7/1500
# 29/29 [==============================] - 0s 6ms/step - loss: 0.0036 - accuracy: 0.9995
# Epoch 8/1500
# 29/29 [==============================] - 0s 6ms/step - loss: 0.0029 - accuracy: 0.9989
# Epoch 9/1500
# 29/29 [==============================] - 0s 6ms/step - loss: 0.0049 - accuracy: 0.9995
# Epoch 10/1500
# 29/29 [==============================] - 0s 7ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 11/1500
# 29/29 [==============================] - 0s 7ms/step - loss: 0.0033 - accuracy: 0.9995
# Epoch 12/1500
# 29/29 [==============================] - 0s 6ms/step - loss: 0.0022 - accuracy: 0.9995
# Epoch 13/1500
# 29/29 [==============================] - 0s 7ms/step - loss: 0.0053 - accuracy: 0.9984
# Epoch 14/1500
# 29/29 [==============================] - 0s 7ms/step - loss: 0.0029 - accuracy: 0.9995
# Epoch 15/1500
# 29/29 [==============================] - 0s 10ms/step - loss: 0.0019 - accuracy: 0.9995
# Epoch 16/1500
# 29/29 [==============================] - 0s 6ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 17/1500
# 29/29 [==============================] - 0s 6ms/step - loss: 7.9870e-04 - accuracy: 1.0000
# Epoch 18/1500
# 29/29 [==============================] - 0s 6ms/step - loss: 9.6285e-04 - accuracy: 1.0000
# Epoch 19/1500
# 29/29 [==============================] - 0s 7ms/step - loss: 8.0125e-04 - accuracy: 1.0000
# Epoch 20/1500
# 29/29 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 0.9995
# Epoch 21/1500
# 29/29 [==============================] - 0s 8ms/step - loss: 0.0022 - accuracy: 0.9984
# Epoch 22/1500
# 29/29 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 0.9995
# Epoch 23/1500
# 29/29 [==============================] - 0s 7ms/step - loss: 0.0038 - accuracy: 0.9984
# Epoch 24/1500
# 29/29 [==============================] - 0s 7ms/step - loss: 7.7347e-04 - accuracy: 1.0000
# Epoch 25/1500
# 29/29 [==============================] - 0s 7ms/step - loss: 6.2580e-04 - accuracy: 1.0000
# Epoch 26/1500
# 29/29 [==============================] - 0s 7ms/step - loss: 8.3655e-04 - accuracy: 1.0000
# Epoch 27/1500
# 29/29 [==============================] - 0s 5ms/step - loss: 4.0386e-04 - accuracy: 1.0000
# Epoch 28/1500
# 29/29 [==============================] - 0s 5ms/step - loss: 7.0149e-04 - accuracy: 1.0000
# Epoch 29/1500
# 29/29 [==============================] - 0s 6ms/step - loss: 8.0659e-04 - accuracy: 1.0000
# Epoch 30/1500
# 29/29 [==============================] - 0s 6ms/step - loss: 6.9994e-04 - accuracy: 1.0000
# Epoch 31/1500
# 29/29 [==============================] - 0s 6ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 32/1500
# 29/29 [==============================] - 0s 6ms/step - loss: 7.3979e-04 - accuracy: 1.0000
# Epoch 33/1500
# 29/29 [==============================] - 0s 6ms/step - loss: 3.6050e-04 - accuracy: 1.0000
# Epoch 34/1500
# 29/29 [==============================] - 0s 6ms/step - loss: 8.5639e-04 - accuracy: 1.0000
# Epoch 35/1500
# 29/29 [==============================] - 0s 6ms/step - loss: 3.1229e-04 - accuracy: 1.0000
# Epoch 36/1500
# 29/29 [==============================] - 0s 6ms/step - loss: 2.6198e-04 - accuracy: 1.0000
# Epoch 37/1500
# 29/29 [==============================] - 0s 6ms/step - loss: 1.5969e-04 - accuracy: 1.0000
# Epoch 38/1500
# 29/29 [==============================] - 0s 6ms/step - loss: 3.4470e-04 - accuracy: 1.0000
# Epoch 39/1500
# 29/29 [==============================] - 0s 5ms/step - loss: 1.8696e-04 - accuracy: 1.0000
# Epoch 40/1500
# 29/29 [==============================] - 0s 6ms/step - loss: 5.4511e-04 - accuracy: 1.0000
# Epoch 41/1500
# 29/29 [==============================] - 0s 6ms/step - loss: 3.0239e-04 - accuracy: 1.0000
# Epoch 42/1500
# 29/29 [==============================] - 0s 6ms/step - loss: 2.0997e-04 - accuracy: 1.0000
# Epoch 43/1500
# 29/29 [==============================] - 0s 6ms/step - loss: 2.3753e-04 - accuracy: 1.0000
# Epoch 44/1500
# 29/29 [==============================] - 0s 6ms/step - loss: 2.6153e-04 - accuracy: 1.0000
# Epoch 45/1500
# 29/29 [==============================] - 0s 6ms/step - loss: 5.9159e-04 - accuracy: 1.0000
# Epoch 46/1500
# 29/29 [==============================] - 0s 5ms/step - loss: 2.6180e-04 - accuracy: 1.0000
# Epoch 47/1500
# 21/29 [====================>.........] - ETA: 0s - loss: 2.2267e-04 - accuracy: 1.0000Restoring model weights from the end of the best epoch: 17.
# 29/29 [==============================] - 0s 5ms/step - loss: 7.9628e-04 - accuracy: 0.9995
# Epoch 47: early stopping
# 7/7 [==============================] - 0s 1ms/step - loss: 2.4057 - accuracy: 0.6931
# 7/7 [==============================] - 0s 983us/step
# Majority Vote Accuracy for cat_id for this fold: 0.65 (17/26)
# Before appending - Cat IDs: 525, Predictions: 525, Actuals: 525, Gender: 525
# After appending - Cat IDs: 727, Predictions: 727, Actuals: 727, Gender: 727
# Final Test Results - Loss: 2.4057347774505615, Accuracy: 0.6930692791938782, Precision: 0.7137383689107827, Recall: 0.6158124068340787, F1 Score: 0.6352564102564103
# Confusion Matrix:
#  [[124   0  12]
#  [  2   7   0]
#  [ 48   0   9]]
#
# Final Average F1-Score across all UNSEEN TEST sets: 0.6096286647552318
#
# Final Average Loss across all UNSEEN TEST sets: 1.969152420759201
#
# Final Average Accuracy across all UNSEEN TEST sets: 0.7174766510725021
#
# Final Average Precision across all UNSEEN TEST sets: 0.7160967614903576
#
# Final Average Recall across all UNSEEN TEST sets: 0.5853944938007423

# %%
seed_3_folds_values = (unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1)

# Plotting all fold metrics
seed_3_folds_plot = plot_all_metrics(unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1, "Folds", "Fold Number")

# %% [markdown]
# ## Majority Voting on Total Entries per cat_id

# %%
# Debugging print statements
print(f'Checking - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
# Out:
# Checking - Cat IDs: 727, Predictions: 727, Actuals: 727, Gender: 727

# %%
# Create results df
full_results = pd.DataFrame({
    'cat_id': all_cat_ids,
    'predicted_age_group': all_predicted_age_groups,
    'actual_age_group': all_actual_age_groups,
    'all_gender': all_gender
})

# create a correct majority prediction column
full_results['correct'] = full_results['predicted_age_group'] == full_results['actual_age_group']

# %%
# Group by cat_id and aggregate predicted age groups
majority_votes = full_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first()

# Calculate the accuracy of majority voting
correct_predictions = (majority_votes == actual_groups).sum()
total_cats = len(actual_groups)
majority_vote_accuracy = correct_predictions / total_cats

logger(f"Overall Majority Vote Accuracy for cat_id: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

# store for final evaluation 
all_majority_vote_accuracies.append(majority_vote_accuracy)
# Out:
# Overall Majority Vote Accuracy for cat_id: 0.72 (79/110)

# %%
# Detailed df with predictions, actual labels, and comparison including majority vote
detailed_results = full_results.groupby('cat_id').apply(
    lambda x: pd.Series({
        'Predictions': list(x['predicted_age_group']),
        'Majority Vote': x['predicted_age_group'].mode()[0],
        'Actual Age Group': x['actual_age_group'].iloc[0],
        'Correct Majority Vote': x['predicted_age_group'].mode()[0] == x['actual_age_group'].iloc[0]
    })
).reset_index()

# Convert to DataFrame for better formatting and display
detailed_results = pd.DataFrame(detailed_results)

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 10)
pd.set_option('display.width', 1000)

sorted_detailed_results = detailed_results.sort_values(by='Correct Majority Vote', ascending=False)

# Display the sorted DataFrame
sorted_detailed_results
# Out:
#     cat_id                                        Predictions Majority Vote Actual Age Group  Correct Majority Vote
# 0     000B  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 69    063A  [adult, adult, adult, senior, adult, adult, se...         adult            adult                   True
# 78    072A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 77    071A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 76    070A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 74    068A  [adult, adult, adult, adult, senior, adult, se...         adult            adult                   True
# 73    067A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 72    066A                                            [adult]         adult            adult                   True
# 71    065A  [senior, adult, adult, adult, adult, senior, a...         adult            adult                   True
# 70    064A                                            [adult]         adult            adult                   True
# 68    062A                              [adult, adult, adult]         adult            adult                   True
# 80    074A  [adult, adult, senior, adult, adult, adult, ad...         adult            adult                   True
# 66    060A                              [adult, adult, adult]         adult            adult                   True
# 65    059A  [adult, senior, senior, adult, senior, senior,...        senior           senior                   True
# 62    056A                            [senior, senior, adult]        senior           senior                   True
# 59    053A                             [senior, adult, adult]         adult            adult                   True
# 53    048A                                           [kitten]        kitten           kitten                   True
# 50    044A            [kitten, adult, kitten, kitten, kitten]        kitten           kitten                   True
# 49    043A                                           [kitten]        kitten           kitten                   True
# 46    040A  [kitten, kitten, kitten, kitten, kitten, kitte...        kitten           kitten                   True
# 79    073A                                            [adult]         adult            adult                   True
# 81    075A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 43    037A                                    [adult, senior]         adult            adult                   True
# 95    100A                                            [adult]         adult            adult                   True
# 108   116A  [senior, senior, adult, kitten, adult, senior,...        senior           senior                   True
# 107   115A                                           [kitten]        kitten           kitten                   True
# 105   111A  [adult, kitten, kitten, kitten, kitten, kitten...        kitten           kitten                   True
# 104   110A                                           [kitten]        kitten           kitten                   True
# 100   105A                             [adult, adult, senior]         adult            adult                   True
# 98    103A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 97    102A                                    [adult, senior]         adult            adult                   True
# 96    101A  [adult, adult, adult, adult, senior, adult, ad...         adult            adult                   True
# 94    099A         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 82    076A                                            [adult]         adult            adult                   True
# 93    097B  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 91    096A                                            [adult]         adult            adult                   True
# 90    095A  [adult, adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 89    094A           [senior, senior, senior, senior, senior]        senior           senior                   True
# 87    092A                                            [adult]         adult            adult                   True
# 85    090A                                           [senior]        senior           senior                   True
# 84    088A                                            [adult]         adult            adult                   True
# 83    087A                                     [adult, adult]         adult            adult                   True
# 45    039A         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 55    050A           [kitten, kitten, kitten, kitten, kitten]        kitten           kitten                   True
# 25    023A         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 34    027A  [adult, adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 12    011A                                   [senior, senior]        senior           senior                   True
# 32    026B                                            [adult]         adult            adult                   True
# 31    026A                       [adult, adult, adult, adult]         adult            adult                   True
# 30    025C                       [adult, adult, adult, adult]         adult            adult                   True
# 29    025B                                     [adult, adult]         adult            adult                   True
# 28    025A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 27    024A                                           [senior]        senior           senior                   True
# 26    023B                       [adult, adult, adult, adult]         adult            adult                   True
# 42    036A  [adult, senior, adult, adult, adult, adult, ad...         adult            adult                   True
# 24    022A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 23    021A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 22    020A  [adult, senior, adult, adult, adult, adult, ad...         adult            adult                   True
# 13    012A                              [adult, adult, adult]         adult            adult                   True
# 20    019A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 19    018A                                     [adult, adult]         adult            adult                   True
# 14    013B  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 17    015A  [adult, adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 11    010A                              [adult, adult, adult]         adult            adult                   True
# 35    028A  [adult, adult, adult, senior, adult, adult, ad...         adult            adult                   True
# 15    014A                              [adult, adult, adult]         adult            adult                   True
# 9     008A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 8     007A         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 7     006A                              [adult, adult, adult]         adult            adult                   True
# 41    035A                                    [adult, senior]         adult            adult                   True
# 37    031A  [adult, adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 2     002A  [adult, adult, adult, adult, adult, senior, ad...         adult            adult                   True
# 3     002B  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 40    034A                              [adult, adult, adult]         adult            adult                   True
# 39    033A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 10    009A                       [adult, adult, adult, adult]         adult            adult                   True
# 5     004A                                            [adult]         adult            adult                   True
# 38    032A                                     [adult, adult]         adult            adult                   True
# 4     003A                       [adult, adult, adult, adult]         adult            adult                   True
# 106   113A                             [adult, adult, senior]         adult           senior                  False
# 88    093A                                     [adult, adult]         adult           senior                  False
# 92    097A  [adult, senior, adult, adult, senior, senior, ...         adult           senior                  False
# 102   108A              [senior, adult, senior, adult, adult]         adult           senior                  False
# 101   106A  [adult, adult, adult, adult, adult, adult, adu...         adult           senior                  False
# 6     005A  [senior, senior, senior, senior, senior, senio...        senior            adult                  False
# 99    104A                       [adult, adult, adult, adult]         adult           senior                  False
# 103   109A                [adult, adult, adult, adult, adult]         adult           kitten                  False
# 44    038A                                   [kitten, kitten]        kitten            adult                  False
# 16    014B  [senior, adult, adult, adult, kitten, kitten, ...         adult           kitten                  False
# 86    091A                                           [senior]        senior            adult                  False
# 47    041A                                            [adult]         adult           kitten                  False
# 48    042A  [senior, kitten, adult, kitten, adult, adult, ...         adult           kitten                  False
# 51    045A                       [adult, adult, adult, adult]         adult           kitten                  False
# 52    047A  [adult, adult, adult, adult, adult, adult, adu...         adult           kitten                  False
# 54    049A                                    [kitten, adult]         adult           kitten                  False
# 1     001A  [adult, senior, adult, senior, adult, senior, ...        senior            adult                  False
# 56    051A  [adult, adult, adult, adult, adult, adult, adu...         adult           senior                  False
# 57    051B  [adult, adult, adult, adult, adult, adult, adu...         adult           senior                  False
# 58    052A                                   [senior, senior]        senior            adult                  False
# 60    054A                                     [adult, adult]         adult           senior                  False
# 61    055A  [adult, senior, senior, adult, adult, adult, a...         adult           senior                  False
# 36    029A  [senior, senior, senior, adult, adult, adult, ...        senior            adult                  False
# 63    057A  [adult, senior, adult, adult, senior, adult, a...         adult           senior                  False
# 64    058A                             [senior, adult, adult]         adult           senior                  False
# 67    061A                                     [adult, adult]         adult           senior                  False
# 33    026C                                           [kitten]        kitten            adult                  False
# 75    069A                                   [senior, senior]        senior            adult                  False
# 21    019B                                           [senior]        senior            adult                  False
# 18    016A  [adult, adult, adult, adult, senior, adult, ad...         adult           senior                  False
# 109   117A  [adult, adult, adult, adult, adult, adult, adult]         adult           senior                  False

# %%
# Create df for majority votes
majority_df = majority_votes.reset_index()
majority_df.columns = ['cat_id', 'Majority_Vote']

# Get actual groups for each cat_id
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first().reset_index()

# Merge majority votes with actual groups
majority_with_actual = pd.merge(majority_df, actual_groups, on='cat_id')

# Add a column to check if the majority vote was correct
majority_with_actual['Majority_Correct'] = majority_with_actual['Majority_Vote'] == majority_with_actual['actual_age_group']

# Count correct majority votes per class
correct_majority_votes_per_class = majority_with_actual.groupby('actual_age_group')['Majority_Correct'].sum()

print("Correct Majority Votes per Class:")
print(correct_majority_votes_per_class)
# Out:
# Correct Majority Votes per Class:
# actual_age_group
# adult     64
# kitten     8
# senior     7
# Name: Majority_Correct, dtype: int64

# %%
# Calculate the total count and the number of correct predictions for each class
class_stats = majority_with_actual.groupby('actual_age_group').agg(
    total_count=('Majority_Correct', 'size'),  # Total number of cases per class
    correct_count=('Majority_Correct', 'sum')  # Sum of correct predictions per class
).reset_index()

# Calculate accuracy for each class
class_stats['accuracy'] = class_stats['correct_count'] / class_stats['total_count'] * 100

# store for final evaluation 
all_majority_vote_details.append(class_stats)

# Log detailed stats
print("Detailed Class Statistics for Majority Votes:")
print(class_stats)
# Out:
# Detailed Class Statistics for Majority Votes:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult           73             64  87.671233
# 1           kitten           15              8  53.333333
# 2           senior           22              7  31.818182

# %%
# Plot for Detailed Class Statistics for Majority Votes
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Accuracy of Majority Votes by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Detailed Class Statistics

# %%
# Calculate the total count and the number of correct predictions for each class
class_stats = full_results.groupby('actual_age_group').agg(
    total_count=('correct', 'size'),
    correct_count=('correct', 'sum')
).reset_index()

# Calculate accuracy for each class
class_stats['accuracy'] = class_stats['correct_count'] / class_stats['total_count'] * 100

# store for final evaluation 
all_class_stats.append(class_stats)

# Log the detailed stats
print("Detailed Class Statistics:")
print(class_stats)
# Out:
# Detailed Class Statistics:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult          487            435  89.322382
# 1           kitten           91             42  46.153846
# 2           senior          149             41  27.516779

# %%
# Plot for Detailed Class Statistics (Overall)
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Overall Accuracy by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Gender Exploration

# %%
# Group by gender and calculate the total count, correct predictions, and accuracy
gender_stats = full_results.groupby('all_gender').agg(
    count=('cat_id', 'size'),  # Total number of cases per gender
    correct=('correct', 'sum')  # Sum of correct predictions per gender
).reset_index()

# Calculate accuracy for each gender
gender_stats['accuracy'] = (gender_stats['correct'] / gender_stats['count'] * 100).round(2)

# Display the DataFrame
print("Accuracy by Gender:")
print(gender_stats)

# store for final evaluation 
all_gender_stats.append(gender_stats)
# Out:
# Accuracy by Gender:
#   all_gender  count  correct  accuracy
# 0          F    192      137     71.35
# 1          M    286      223     77.97
# 2          X    249      158     63.45

# %%
# Plot for Accuracy by Gender
styled_barplot(gender_stats, 'all_gender', 'accuracy', 
               'Accuracy by Gender', 
               'Gender', 'Accuracy (%)')

# %% [markdown]
# ### Log current total CV Stats

# %%
print("Total Majority Vote Accuracy so far:", all_majority_vote_accuracies)
print("Total Class Statistics so far:\n", all_class_stats)
print("Total Gender Accuracy so far:\n", all_gender_stats)
# Out:
# Total Majority Vote Accuracy so far: [0.7363636363636363, 0.7363636363636363, 0.7181818181818181]
# Total Class Statistics so far:
#  [  actual_age_group  total_count  correct_count   accuracy
# 0            adult          474            413  87.130802
# 1           kitten           95             43  45.263158
# 2           senior          149             41  27.516779,   actual_age_group  total_count  correct_count   accuracy
# 0            adult          473            406  85.835095
# 1           kitten           91             46  50.549451
# 2           senior          149             36  24.161074,   actual_age_group  total_count  correct_count   accuracy
# 0            adult          487            435  89.322382
# 1           kitten           91             42  46.153846
# 2           senior          149             41  27.516779]
# Total Gender Accuracy so far:
#  [  all_gender  count  correct  accuracy
# 0          F    196      137     69.90
# 1          M    286      219     76.57
# 2          X    236      141     59.75,   all_gender  count  correct  accuracy
# 0          F    192      130     67.71
# 1          M    289      219     75.78
# 2          X    232      139     59.91,   all_gender  count  correct  accuracy
# 0          F    192      137     71.35
# 1          M    286      223     77.97
# 2          X    249      158     63.45]

# %% [markdown]
# # RANDOM SEED 4

# %%
# Set a fixed random seed for reproducibility
random.seed(int(random_seeds[3])) 
np.random.seed(int(random_seeds[3]))
tf.random.set_seed(int(random_seeds[3]))

# Load datasets
dataframe = pd.read_csv('/Users/astrid/PycharmProjects/perch-2/scripts/perch_embeddings_april_10.csv')
augmented_df = pd.read_csv('/Users/astrid/PycharmProjects/perch-2/scripts/perch_embeddings_augm_d1.csv')

dataframe.drop('mean_freq', axis=1, inplace=True)

augmented_df.drop('mean_freq', axis=1, inplace=True)
augmented_df.drop('gender', axis=1, inplace=True)

def assign_age_group(age, age_groups):
    for group_name, age_range in age_groups.items():
        if age_range[0] <= age < age_range[1]:
            return group_name
    return 'Unknown'  # For any age that doesn't fit the defined groups

# Define age groups
age_groups = {
    'kitten': (0, 0.5),
    'adult': (0.5, 12),
    'senior': (12, 20)
}

# Create a new column for the age group
dataframe['age_group'] = dataframe['target'].apply(assign_age_group, age_groups=age_groups)
augmented_df['age_group'] = augmented_df['target'].apply(assign_age_group, age_groups=age_groups)

print(dataframe['age_group'].value_counts())
print(augmented_df['age_group'].value_counts())
# Out:
# adult     509
# senior    149
# kitten    135
# Name: age_group, dtype: int64
# senior    596
# kitten    540
# adult     509
# Name: age_group, dtype: int64

# %%
# Separate features and labels
X = dataframe.iloc[:, :-4].values  # all columns except the last four

# Encode the 'age_group' column as integers using LabelEncoder
label_encoder = LabelEncoder()
encoded_y = label_encoder.fit_transform(dataframe['age_group'].values)

# Use the encoded labels for splitting and one-hot encoding
y = encoded_y  

# Convert 'cat_id' column to numpy array to be used as groups array for GroupKFold
groups = dataframe['cat_id'].values

# %%
tf.keras.backend.clear_session()

# %% [markdown]
# ## Run Setup

# %%
all_cat_ids = []
all_predicted_age_groups = []
all_actual_age_groups = []
all_gender = []

# Define the StratifiedGroupKFold splitter for 4 fold CV with random shuffling
outer_cv = StratifiedGroupKFold(n_splits=4, shuffle=True, random_state=int(random_seeds[3]))

# unseen test set metrics
unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1 = [], [], [], [], []

outer_fold = 0

# Use the splitter to generate indices for training and testing sets
# Note: GroupShuffleSplit.split returns indices, so we use it to index the arrays
for train_val_idx, test_idx in outer_cv.split(X, y, groups):
    outer_fold += 1
    logger(f"outer_fold {outer_fold}", file=log_file_path)

    # Convert indices back to DataFrame for easy manipulation
    df_train_val = dataframe.iloc[train_val_idx]
    df_test = dataframe.iloc[test_idx]

    ##############################
    # ASSESSING SPLITS BY CAT_ID #
    ##############################
    
    # Get the distribution of groups
    training_validation_group_distribution = df_train_val['cat_id'].value_counts()  
    testing_group_distribution = df_test['cat_id'].value_counts()  
    
    # Log or print the distribution
    logger(f"Train Set Group Distribution:\n{training_validation_group_distribution}", file=log_file_path)
    logger(f"Testing Set Group Distribution:\n{testing_group_distribution}", file=log_file_path)

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val['gender'].value_counts()
    testing_gender_distribution = df_test['gender'].value_counts()
    
    # Log the distribution
    logger(f"Training Set Gender Distribution BEFORE SWAP:\n{training_gender_distribution}", file=log_file_path)
    logger(f"Testing Set Gender Distribution BEFORE SWAP:\n{testing_gender_distribution}", file=log_file_path)

    # Group by 'age_group' and then list unique 'cat_id' within each age group
    unique_cat_ids_per_age_group_train_val = df_train_val.groupby('age_group')['cat_id'].unique()
    unique_cat_ids_per_age_group_test = df_test.groupby('age_group')['cat_id'].unique()
    
    # Log results
    logger(f"Unique Cat IDs per Age Group in Training/Validation Set:\n{unique_cat_ids_per_age_group_train_val}", file=log_file_path)
    logger(f"Unique Cat IDs per Age Group in Testing Set:\n{unique_cat_ids_per_age_group_test}", file=log_file_path)

    # Calculate the count of unique identifiers per age group for training and testing set
    counts_train_val = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_train_val.items()}
    counts_test = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_test.items()}

    # Log the counts of unique identifiers per age group
    logger(f"Count of Unique Cat IDs per Age Group in Training/Validation Set:\n{counts_train_val}", file=log_file_path)
    logger(f"Count of Unique Cat IDs per Age Group in Testing Set:\n{counts_test}", file=log_file_path)

    #######################################################
    # CONTINUE WITH ENSURING VALID AND APPROPRIATE SPLITS #
    #######################################################
    
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    groups_train_val, groups_test = groups[train_val_idx], groups[test_idx]

    # logging identifier splits 
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)

    # check group splits
    check_initial_group_split(groups_train_val, groups_test)

    # Specify the cat_ids that must be in the training/validation set
    specific_cat_ids = ['000A', '046A']
    
    # Perform the swapping operation
    train_val_idx, test_idx = swap_cat_id_instances(dataframe, train_val_idx, test_idx, specific_cat_ids)
    
    # Re-assign the sets based on the updated indices
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    new_groups_train_val, new_groups_test = groups[train_val_idx], groups[test_idx]

    # Find differences for training and test sets
    moved_to_train_val, removed_from_train_val = find_group_differences(groups_train_val, new_groups_train_val)
    moved_to_test, removed_from_test = find_group_differences(groups_test, new_groups_test)
    
    # Display the results
    logger(f"Moved to Training/Validation Set:\n{moved_to_train_val}", file=log_file_path)
    logger(f"Removed from Training/Validation Set:\n{removed_from_train_val}", file=log_file_path)
    logger(f"Moved to Test Set:\n{moved_to_test}", file=log_file_path)
    logger(f"Removed from Test Set\n{removed_from_test}", file=log_file_path)

    # Update X_train_val, X_test, y_train_val, y_test, groups_train_val, groups_test based on updated indices
    X_train_val = X[train_val_idx]
    y_train_val = y[train_val_idx]
    groups_train_val = groups[train_val_idx]
    
    X_test = X[test_idx]
    y_test = y[test_idx]
    groups_test = groups[test_idx]

    # logging identifier splits again after potential swaps
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"AFTER SWAP - Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"AFTER SWAP - Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)
    
    # Verify the lengths are consistent
    logger(f"Length of X_train_val:\n{len(X_train_val)}", file=log_file_path)
    logger(f"Length of y_train_val:\n{len(y_train_val)}", file=log_file_path)
    logger(f"Length of groups_train_val:\n{len(groups_train_val)}", file=log_file_path)

    # Check group splits once more
    check_initial_group_split(groups_train_val, groups_test)

    # Convert the modified indices back to a DataFrame representing the updated df_train_val
    df_train_val_updated = dataframe.iloc[train_val_idx].copy()
    df_test_updated = dataframe.iloc[test_idx].copy()

    ############################
    # LOGGING AGE GROUP SPLITS #
    ############################

    # Get the distribution of age groups of age groups before the update
    training_validation_age_group_distribution = df_train_val['age_group'].value_counts()
    testing_age_group_distribution = df_test['age_group'].value_counts()
    
    # Logthe distribution
    logger(f"Train Age Group Distribution BEFORE SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution BEFORE SWAP:\n{testing_age_group_distribution}", file=log_file_path)

    # Get the distribution of age groups after the update
    training_validation_age_group_distribution = df_train_val_updated['age_group'].value_counts()
    testing_age_group_distribution = df_test_updated['age_group'].value_counts()
    
    # Log the distribution
    logger(f"Train Age Group Distribution AFTER SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution AFTER SWAP:\n{testing_age_group_distribution}", file=log_file_path)
    
    ########################################################
    # TRACKING FINAL CAT_IDs & GENDER AFTER REDISTRIBUTION #
    ########################################################

    # Get the distribution of groups
    training_validation_group_distribution = df_train_val_updated['cat_id'].value_counts()  
    testing_group_distribution = df_test_updated['cat_id'].value_counts()  

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val_updated['gender'].value_counts()
    testing_gender_distribution = df_test_updated['gender'].value_counts()
    
    logger(f"\n Starting training on unseen test set\n", file=log_file_path)

    ######################
    # ADD AUGMENTED DATA #
    ######################

    # Filter out augmented data derived from groups in the training set
    augmented_df_filtered = augmented_df[augmented_df['cat_id'].isin(groups_train_val)]
    
    # Convert augmented_df_filtered to numpy array (excluding target and other columns)
    augmented_array = augmented_df_filtered.drop(columns=['target', 'cat_id', 'age_group']).values
    
    # Concatenate the filtered augmented data with X_train_val
    X_train_val = np.concatenate([X_train_val, augmented_array])

    # Extract target labels from the filtered augmented DataFrame
    y_augmented = augmented_df_filtered['age_group'].values
    
    # Encode the labels using the same LabelEncoder instance
    y_augmented_encoded = label_encoder.transform(y_augmented)
    
    # Concatenate the encoded augmented labels with y_train_val
    y_train_val = np.concatenate([y_train_val, y_augmented_encoded])

    # Calculate the distribution of age groups in y_train_val
    age_group_distribution = Counter(y_train_val)
    print("Age group distribution:", age_group_distribution)

    # EarlyStopping callback: monitor 'loss' instead of 'val_loss' for the test set
    early_stopping = EarlyStopping(
        monitor='loss',  
        min_delta=0.001, 
        patience=30,  
        verbose=1,  
        restore_best_weights=True  
    )

    # One final shuffle to ensure randomness
    outer_shuffle_idx = np.random.permutation(len(X_train_val))
    X_train_val = X_train_val[outer_shuffle_idx]
    y_train_val = y_train_val[outer_shuffle_idx]
    
    # Scale the features
    scaler_full = StandardScaler().fit(X_train_val)
    X_train_full_scaled = scaler_full.transform(X_train_val)
    X_test_scaled = scaler_full.transform(X_test)
    
    # Encode the labels
    y_train_full_encoded = to_categorical(y_train_val)
    y_test_encoded = to_categorical(y_test)

    #######################
    # BUILD & TRAIN MODEL #
    #######################

    optimizers = {
        'Adamax': Adamax(learning_rate=0.00510251984616472)
    }
    
    # Model definition with dynamic number of layers
    model_full = Sequential()
    model_full.add(Dense(480, activation='relu', input_shape=(X_train_full_scaled.shape[1],)))
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.2011047009431978))  
    model_full.add(Dense(256, activation='relu',)) 
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.14956886311951184))  
    model_full.add(Dense(256, activation='relu'))  
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.42291461228250665))  
    model_full.add(Dense(3, activation='softmax'))  
    
    # Use the optimizer from the parameters
    optimizer = optimizers['Adamax']  # optimizer_key from parameters
    
    # Compile the model
    model_full.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    
    # Train the model on the full training set
    history_full = model_full.fit(X_train_full_scaled, y_train_full_encoded, epochs=1500, batch_size=64,
                                  verbose=1, callbacks=[early_stopping])
    
    # Evaluate the model on the held-out test set
    test_loss, test_accuracy = model_full.evaluate(X_test_scaled, y_test_encoded)

    y_test_pred_prob = model_full.predict(X_test_scaled)
    y_test_pred = np.argmax(y_test_pred_prob, axis=1)  
    y_test_true = np.argmax(y_test_encoded, axis=1)    

    ################################
    # LOG MAJORITY VOTE PER CAT_ID #
    ################################

    # Convert numeric predictions back to age group labels
    predicted_age_groups = label_encoder.inverse_transform(y_test_pred)
    actual_labels = label_encoder.inverse_transform(y_test_true)
    
    # Map predictions and actual labels back to cat_ids
    test_results = pd.DataFrame({
        'cat_id': df_test_updated['cat_id'],
        'predicted_age_group': predicted_age_groups,
        'actual_age_group': actual_labels
    })
    
    # Group by cat_id and aggregate predicted age groups
    majority_votes = test_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
    actual_groups = test_results.groupby('cat_id')['actual_age_group'].first()
    
    # Calculate the accuracy of majority voting
    correct_predictions = (majority_votes == actual_groups).sum()
    total_cats = len(actual_groups)
    majority_vote_accuracy = correct_predictions / total_cats
    
    # Log the accuracy of the majority voting
    logger(f"Majority Vote Accuracy for cat_id for this fold: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

    ####################################################
    # COLLECT PREDICTIONS FOR GENDER & CAT_ID ANALYSIS #
    ####################################################

    # Debugging print statements
    print(f'Before appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Extend lists with current fold results
    all_cat_ids.extend(df_test_updated['cat_id'].tolist())
    all_predicted_age_groups.extend(predicted_age_groups)
    all_actual_age_groups.extend(actual_labels)
    all_gender.extend(df_test_updated['gender'].tolist())

    # Debugging print statements
    print(f'After appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Calculate additional metrics
    test_precision = precision_score(y_test_true, y_test_pred, average='macro')  # Use 'macro' for imbalanced datasets
    test_recall = recall_score(y_test_true, y_test_pred, average='macro')
    test_f1 = f1_score(y_test_true, y_test_pred, average='macro')

    # prepare averages of outer metrics
    unseen_f1.append(test_f1)
    unseen_losses.append(test_loss)
    unseen_accuracies.append(test_accuracy)
    unseen_precisions.append(test_precision)
    unseen_recalls.append(test_recall)

    # Print final test results
    logger(f"Final Test Results - Loss: {test_loss}, Accuracy: {test_accuracy}, Precision: {test_precision}, Recall: {test_recall}, F1 Score: {test_f1}", file=log_file_path)

    # Generate the confusion matrix
    cm = confusion_matrix(y_test, y_test_pred)
    logger(f"Confusion Matrix:\n {cm}", file=log_file_path)

# Calculate the overall average metrics
unseen_set_avg_f1 = np.mean(unseen_f1)
unseen_set_avg_loss = np.mean(unseen_losses)
unseen_set_avg_acc = np.mean(unseen_accuracies)
unseen_set_avg_precision = np.mean(unseen_precisions)
unseen_set_avg_recall = np.mean(unseen_recalls)

# Append averages to total lists
all_f1.append(unseen_set_avg_f1)
all_losses.append(unseen_set_avg_loss)
all_accuracies.append(unseen_set_avg_acc)
all_precisions.append(unseen_set_avg_precision)
all_recalls.append(unseen_set_avg_recall)

logger(f"\nFinal Average F1-Score across all UNSEEN TEST sets: {unseen_set_avg_f1}", file=log_file_path)
logger(f"\nFinal Average Loss across all UNSEEN TEST sets: {unseen_set_avg_loss}", file=log_file_path)
logger(f"\nFinal Average Accuracy across all UNSEEN TEST sets: {unseen_set_avg_acc}", file=log_file_path)
logger(f"\nFinal Average Precision across all UNSEEN TEST sets: {unseen_set_avg_precision}", file=log_file_path)
logger(f"\nFinal Average Recall across all UNSEEN TEST sets: {unseen_set_avg_recall}\n", file=log_file_path)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# outer_fold 1
# Train Set Group Distribution:
# 046A    45
# 000A    39
# 103A    33
# 002B    30
# 047A    22
# 000B    19
# 057A    17
# 019A    17
# 074A    16
# 029A    15
# 097A    15
# 097B    14
# 002A    13
# 101A    12
# 111A    12
# 051A    12
# 028A    11
# 042A    11
# 067A    11
# 059A    10
# 014B    10
# 025A    10
# 065A     9
# 016A     9
# 072A     9
# 005A     9
# 022A     9
# 001A     9
# 013B     8
# 095A     7
# 027A     7
# 117A     7
# 031A     7
# 023A     6
# 021A     5
# 094A     5
# 050A     5
# 008A     5
# 109A     5
# 070A     5
# 108A     5
# 044A     5
# 045A     4
# 025C     4
# 009A     4
# 026A     4
# 012A     3
# 058A     3
# 010A     3
# 053A     3
# 006A     3
# 034A     3
# 014A     3
# 113A     3
# 105A     3
# 093A     2
# 025B     2
# 037A     2
# 102A     2
# 061A     2
# 035A     2
# 038A     2
# 052A     2
# 018A     2
# 032A     2
# 087A     2
# 041A     1
# 090A     1
# 100A     1
# 043A     1
# 110A     1
# 076A     1
# 115A     1
# 073A     1
# 064A     1
# 092A     1
# 019B     1
# 088A     1
# 004A     1
# 048A     1
# 066A     1
# 049A     1
# 091A     1
# 026B     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 020A    20
# 106A    13
# 116A    12
# 055A    12
# 063A    11
# 040A    10
# 051B     9
# 033A     9
# 071A     9
# 068A     8
# 015A     7
# 036A     7
# 039A     6
# 099A     6
# 007A     6
# 075A     5
# 023B     4
# 003A     4
# 104A     4
# 056A     3
# 062A     3
# 060A     3
# 054A     2
# 069A     2
# 011A     2
# 096A     1
# 026C     1
# 024A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    214
# M    208
# F    191
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# M    78
# X    62
# F    40
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [006A, 000A, 001A, 103A, 097B, 028A, 019A, 074...
# kitten    [044A, 014B, 111A, 046A, 047A, 042A, 109A, 050...
# senior    [093A, 097A, 057A, 059A, 113A, 117A, 051A, 058...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [033A, 015A, 071A, 020A, 062A, 039A, 063A, 099...
# kitten                                               [040A]
# senior    [106A, 104A, 055A, 116A, 051B, 054A, 056A, 011...
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 56, 'kitten': 15, 'senior': 13}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 18, 'kitten': 1, 'senior': 9}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '004A' '005A' '006A' '008A' '009A'
#  '010A' '012A' '013B' '014A' '014B' '016A' '018A' '019A' '019B' '021A'
#  '022A' '023A' '025A' '025B' '025C' '026A' '026B' '027A' '028A' '029A'
#  '031A' '032A' '034A' '035A' '037A' '038A' '041A' '042A' '043A' '044A'
#  '045A' '046A' '047A' '048A' '049A' '050A' '051A' '052A' '053A' '057A'
#  '058A' '059A' '061A' '064A' '065A' '066A' '067A' '070A' '072A' '073A'
#  '074A' '076A' '087A' '088A' '090A' '091A' '092A' '093A' '094A' '095A'
#  '097A' '097B' '100A' '101A' '102A' '103A' '105A' '108A' '109A' '110A'
#  '111A' '113A' '115A' '117A']
# Unique Test Group IDs:
# ['003A' '007A' '011A' '015A' '020A' '023B' '024A' '026C' '033A' '036A'
#  '039A' '040A' '051B' '054A' '055A' '056A' '060A' '062A' '063A' '068A'
#  '069A' '071A' '075A' '096A' '099A' '104A' '106A' '116A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '004A' '005A' '006A' '008A' '009A'
#  '010A' '012A' '013B' '014A' '014B' '016A' '018A' '019A' '019B' '021A'
#  '022A' '023A' '025A' '025B' '025C' '026A' '026B' '027A' '028A' '029A'
#  '031A' '032A' '034A' '035A' '037A' '038A' '041A' '042A' '043A' '044A'
#  '045A' '046A' '047A' '048A' '049A' '050A' '051A' '052A' '053A' '057A'
#  '058A' '059A' '061A' '064A' '065A' '066A' '067A' '070A' '072A' '073A'
#  '074A' '076A' '087A' '088A' '090A' '091A' '092A' '093A' '094A' '095A'
#  '097A' '097B' '100A' '101A' '102A' '103A' '105A' '108A' '109A' '110A'
#  '111A' '113A' '115A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['003A' '007A' '011A' '015A' '020A' '023B' '024A' '026C' '033A' '036A'
#  '039A' '040A' '051B' '054A' '055A' '056A' '060A' '062A' '063A' '068A'
#  '069A' '071A' '075A' '096A' '099A' '104A' '106A' '116A']
# Length of X_train_val:
# 613
# Length of y_train_val:
# 613
# Length of groups_train_val:
# 613
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     397
# kitten    125
# senior     91
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     112
# senior     58
# kitten     10
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     397
# kitten    125
# senior     91
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     112
# senior     58
# kitten     10
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 794, 1: 625, 2: 455})
# Epoch 1/1500
# 30/30 [==============================] - 1s 5ms/step - loss: 0.4101 - accuracy: 0.8586
# Epoch 2/1500
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0468 - accuracy: 0.9824
# Epoch 3/1500
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0324 - accuracy: 0.9915
# Epoch 4/1500
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0181 - accuracy: 0.9952
# Epoch 5/1500
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0070 - accuracy: 0.9989
# Epoch 6/1500
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0097 - accuracy: 0.9979
# Epoch 7/1500
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0056 - accuracy: 0.9979
# Epoch 8/1500
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0041 - accuracy: 0.9989
# Epoch 9/1500
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 10/1500
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0022 - accuracy: 0.9995
# Epoch 11/1500
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 12/1500
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0016 - accuracy: 0.9995
# Epoch 13/1500
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0032 - accuracy: 0.9989
# Epoch 14/1500
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0019 - accuracy: 0.9995
# Epoch 15/1500
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 16/1500
# 30/30 [==============================] - 0s 6ms/step - loss: 8.9905e-04 - accuracy: 1.0000
# Epoch 17/1500
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 18/1500
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0014 - accuracy: 0.9995
# Epoch 19/1500
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 20/1500
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0058 - accuracy: 0.9979
# Epoch 21/1500
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0066 - accuracy: 0.9984
# Epoch 22/1500
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0044 - accuracy: 0.9979
# Epoch 23/1500
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 24/1500
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 25/1500
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0030 - accuracy: 0.9989
# Epoch 26/1500
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 27/1500
# 30/30 [==============================] - 0s 10ms/step - loss: 0.0022 - accuracy: 0.9995
# Epoch 28/1500
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0064 - accuracy: 0.9984
# Epoch 29/1500
# 30/30 [==============================] - 0s 6ms/step - loss: 9.6857e-04 - accuracy: 1.0000
# Epoch 30/1500
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0021 - accuracy: 0.9989
# Epoch 31/1500
# 30/30 [==============================] - 0s 6ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 32/1500
# 30/30 [==============================] - 0s 6ms/step - loss: 8.0531e-04 - accuracy: 1.0000
# Epoch 33/1500
# 30/30 [==============================] - 0s 6ms/step - loss: 7.9335e-04 - accuracy: 1.0000
# Epoch 34/1500
# 30/30 [==============================] - 0s 6ms/step - loss: 2.6424e-04 - accuracy: 1.0000
# Epoch 35/1500
# 30/30 [==============================] - 0s 6ms/step - loss: 9.9706e-04 - accuracy: 1.0000
# Epoch 36/1500
# 30/30 [==============================] - 0s 6ms/step - loss: 5.3882e-04 - accuracy: 1.0000
# Epoch 37/1500
# 30/30 [==============================] - 0s 5ms/step - loss: 8.8300e-04 - accuracy: 1.0000
# Epoch 38/1500
# 30/30 [==============================] - 0s 5ms/step - loss: 5.3909e-04 - accuracy: 1.0000
# Epoch 39/1500
# 30/30 [==============================] - 0s 6ms/step - loss: 5.1210e-04 - accuracy: 1.0000
# Epoch 40/1500
# 30/30 [==============================] - 0s 5ms/step - loss: 4.1499e-04 - accuracy: 1.0000
# Epoch 41/1500
# 30/30 [==============================] - 0s 6ms/step - loss: 2.9210e-04 - accuracy: 1.0000
# Epoch 42/1500
# 30/30 [==============================] - 0s 6ms/step - loss: 4.9302e-04 - accuracy: 1.0000
# Epoch 43/1500
# 30/30 [==============================] - 0s 6ms/step - loss: 2.8703e-04 - accuracy: 1.0000
# Epoch 44/1500
# 30/30 [==============================] - 0s 6ms/step - loss: 2.4352e-04 - accuracy: 1.0000
# Epoch 45/1500
# 30/30 [==============================] - 0s 6ms/step - loss: 2.3806e-04 - accuracy: 1.0000
# Epoch 46/1500
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0012 - accuracy: 0.9989
# Epoch 47/1500
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0066 - accuracy: 0.9979
# Epoch 48/1500
# 30/30 [==============================] - 0s 5ms/step - loss: 8.9206e-04 - accuracy: 1.0000
# Epoch 49/1500
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0016 - accuracy: 0.9995
# Epoch 50/1500
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0012 - accuracy: 0.9995
# Epoch 51/1500
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 52/1500
# 30/30 [==============================] - 0s 5ms/step - loss: 4.6074e-04 - accuracy: 1.0000
# Epoch 53/1500
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0032 - accuracy: 0.9984
# Epoch 54/1500
# 30/30 [==============================] - 0s 5ms/step - loss: 5.5884e-04 - accuracy: 1.0000
# Epoch 55/1500
# 30/30 [==============================] - 0s 5ms/step - loss: 4.7349e-04 - accuracy: 1.0000
# Epoch 56/1500
# 30/30 [==============================] - 0s 5ms/step - loss: 3.1735e-04 - accuracy: 1.0000
# Epoch 57/1500
# 30/30 [==============================] - 0s 5ms/step - loss: 4.2892e-04 - accuracy: 1.0000
# Epoch 58/1500
# 30/30 [==============================] - 0s 5ms/step - loss: 9.1803e-04 - accuracy: 1.0000
# Epoch 59/1500
# 30/30 [==============================] - 0s 5ms/step - loss: 5.4255e-04 - accuracy: 1.0000
# Epoch 60/1500
# 30/30 [==============================] - 0s 5ms/step - loss: 3.9305e-04 - accuracy: 1.0000
# Epoch 61/1500
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0030 - accuracy: 0.9989
# Epoch 62/1500
# 30/30 [==============================] - 0s 5ms/step - loss: 9.3795e-04 - accuracy: 1.0000
# Epoch 63/1500
# 30/30 [==============================] - 0s 5ms/step - loss: 8.2072e-04 - accuracy: 0.9995
# Epoch 64/1500
# 23/30 [======================>.......] - ETA: 0s - loss: 3.3962e-04 - accuracy: 1.0000Restoring model weights from the end of the best epoch: 34.
# 30/30 [==============================] - 0s 5ms/step - loss: 2.8719e-04 - accuracy: 1.0000
# Epoch 64: early stopping
# 6/6 [==============================] - 0s 1ms/step - loss: 2.5132 - accuracy: 0.7333
# 6/6 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.75 (21/28)
# Before appending - Cat IDs: 0, Predictions: 0, Actuals: 0, Gender: 0
# After appending - Cat IDs: 180, Predictions: 180, Actuals: 180, Gender: 180
# Final Test Results - Loss: 2.51324725151062, Accuracy: 0.7333333492279053, Precision: 0.7573308602720368, Recall: 0.7379926108374385, F1 Score: 0.6743589743589743
# Confusion Matrix:
#  [[107   3   2]
#  [  0  10   0]
#  [ 41   2  15]]
# outer_fold 2
# Train Set Group Distribution:
# 046A    45
# 103A    33
# 047A    22
# 020A    20
# 057A    17
# 019A    17
# 097A    15
# 106A    13
# 116A    12
# 055A    12
# 051A    12
# 101A    12
# 111A    12
# 028A    11
# 042A    11
# 063A    11
# 040A    10
# 025A    10
# 059A    10
# 033A     9
# 016A     9
# 051B     9
# 072A     9
# 001A     9
# 071A     9
# 005A     9
# 068A     8
# 095A     7
# 031A     7
# 117A     7
# 015A     7
# 036A     7
# 027A     7
# 099A     6
# 039A     6
# 007A     6
# 075A     5
# 050A     5
# 021A     5
# 108A     5
# 008A     5
# 109A     5
# 094A     5
# 070A     5
# 104A     4
# 023B     4
# 003A     4
# 026A     4
# 045A     4
# 009A     4
# 060A     3
# 056A     3
# 010A     3
# 006A     3
# 014A     3
# 062A     3
# 034A     3
# 018A     2
# 025B     2
# 061A     2
# 011A     2
# 038A     2
# 052A     2
# 087A     2
# 054A     2
# 069A     2
# 090A     1
# 076A     1
# 043A     1
# 115A     1
# 073A     1
# 088A     1
# 004A     1
# 048A     1
# 066A     1
# 064A     1
# 026C     1
# 096A     1
# 091A     1
# 041A     1
# 092A     1
# 024A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 000A    39
# 002B    30
# 000B    19
# 074A    16
# 029A    15
# 097B    14
# 002A    13
# 067A    11
# 014B    10
# 022A     9
# 065A     9
# 013B     8
# 023A     6
# 044A     5
# 025C     4
# 113A     3
# 105A     3
# 058A     3
# 012A     3
# 053A     3
# 037A     2
# 035A     2
# 102A     2
# 032A     2
# 093A     2
# 019B     1
# 049A     1
# 110A     1
# 100A     1
# 026B     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    233
# M    194
# F    128
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# F    103
# M     92
# X     43
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [006A, 033A, 015A, 001A, 103A, 071A, 028A, 019...
# kitten    [111A, 040A, 046A, 047A, 042A, 109A, 050A, 043...
# senior    [097A, 057A, 106A, 104A, 055A, 059A, 116A, 051...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [000A, 097B, 074A, 067A, 002B, 022A, 029A, 065...
# kitten                             [044A, 014B, 049A, 110A]
# senior                                   [093A, 113A, 058A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 51, 'kitten': 12, 'senior': 19}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 23, 'kitten': 4, 'senior': 3}
# Unique Training/Validation Group IDs:
# ['001A' '003A' '004A' '005A' '006A' '007A' '008A' '009A' '010A' '011A'
#  '014A' '015A' '016A' '018A' '019A' '020A' '021A' '023B' '024A' '025A'
#  '025B' '026A' '026C' '027A' '028A' '031A' '033A' '034A' '036A' '038A'
#  '039A' '040A' '041A' '042A' '043A' '045A' '046A' '047A' '048A' '050A'
#  '051A' '051B' '052A' '054A' '055A' '056A' '057A' '059A' '060A' '061A'
#  '062A' '063A' '064A' '066A' '068A' '069A' '070A' '071A' '072A' '073A'
#  '075A' '076A' '087A' '088A' '090A' '091A' '092A' '094A' '095A' '096A'
#  '097A' '099A' '101A' '103A' '104A' '106A' '108A' '109A' '111A' '115A'
#  '116A' '117A']
# Unique Test Group IDs:
# ['000A' '000B' '002A' '002B' '012A' '013B' '014B' '019B' '022A' '023A'
#  '025C' '026B' '029A' '032A' '035A' '037A' '044A' '049A' '053A' '058A'
#  '065A' '067A' '074A' '093A' '097B' '100A' '102A' '105A' '110A' '113A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'000A'}
# Removed from Training/Validation Set:
# {'069A'}
# Moved to Test Set:
# {'069A'}
# Removed from Test Set
# {'000A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '001A' '003A' '004A' '005A' '006A' '007A' '008A' '009A' '010A'
#  '011A' '014A' '015A' '016A' '018A' '019A' '020A' '021A' '023B' '024A'
#  '025A' '025B' '026A' '026C' '027A' '028A' '031A' '033A' '034A' '036A'
#  '038A' '039A' '040A' '041A' '042A' '043A' '045A' '046A' '047A' '048A'
#  '050A' '051A' '051B' '052A' '054A' '055A' '056A' '057A' '059A' '060A'
#  '061A' '062A' '063A' '064A' '066A' '068A' '070A' '071A' '072A' '073A'
#  '075A' '076A' '087A' '088A' '090A' '091A' '092A' '094A' '095A' '096A'
#  '097A' '099A' '101A' '103A' '104A' '106A' '108A' '109A' '111A' '115A'
#  '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['000B' '002A' '002B' '012A' '013B' '014B' '019B' '022A' '023A' '025C'
#  '026B' '029A' '032A' '035A' '037A' '044A' '049A' '053A' '058A' '065A'
#  '067A' '069A' '074A' '093A' '097B' '100A' '102A' '105A' '110A' '113A']
# Length of X_train_val:
# 592
# Length of y_train_val:
# 592
# Length of groups_train_val:
# 592
# No common groups found between train and test sets.
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Train Age Group Distribution BEFORE SWAP:
# adult     296
# senior    141
# kitten    118
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     213
# kitten     17
# senior      8
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     333
# senior    141
# kitten    118
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     176
# kitten     17
# senior      8
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({2: 705, 0: 666, 1: 590})
# Epoch 1/1500
# 31/31 [==============================] - 1s 4ms/step - loss: 0.4216 - accuracy: 0.8542
# Epoch 2/1500
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0776 - accuracy: 0.9760
# Epoch 3/1500
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0232 - accuracy: 0.9929
# Epoch 4/1500
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0173 - accuracy: 0.9964
# Epoch 5/1500
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0059 - accuracy: 0.9990
# Epoch 6/1500
# 31/31 [==============================] - 0s 5ms/step - loss: 0.0065 - accuracy: 0.9975
# Epoch 7/1500
# 31/31 [==============================] - 0s 5ms/step - loss: 0.0070 - accuracy: 0.9980
# Epoch 8/1500
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0056 - accuracy: 0.9990
# Epoch 9/1500
# 31/31 [==============================] - 0s 5ms/step - loss: 0.0032 - accuracy: 0.9995
# Epoch 10/1500
# 31/31 [==============================] - 0s 5ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 11/1500
# 31/31 [==============================] - 0s 5ms/step - loss: 0.0048 - accuracy: 0.9990
# Epoch 12/1500
# 31/31 [==============================] - 0s 5ms/step - loss: 0.0026 - accuracy: 0.9995
# Epoch 13/1500
# 31/31 [==============================] - 0s 5ms/step - loss: 0.0033 - accuracy: 0.9995
# Epoch 14/1500
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0052 - accuracy: 0.9985
# Epoch 15/1500
# 31/31 [==============================] - 0s 5ms/step - loss: 0.0046 - accuracy: 0.9980
# Epoch 16/1500
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 17/1500
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0029 - accuracy: 0.9990
# Epoch 18/1500
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 19/1500
# 31/31 [==============================] - 0s 4ms/step - loss: 6.2220e-04 - accuracy: 1.0000
# Epoch 20/1500
# 31/31 [==============================] - 0s 5ms/step - loss: 0.0016 - accuracy: 0.9995
# Epoch 21/1500
# 31/31 [==============================] - 0s 5ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 22/1500
# 31/31 [==============================] - 0s 5ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 23/1500
# 31/31 [==============================] - 0s 5ms/step - loss: 6.8785e-04 - accuracy: 1.0000
# Epoch 24/1500
# 31/31 [==============================] - 0s 4ms/step - loss: 5.3246e-04 - accuracy: 1.0000
# Epoch 25/1500
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 26/1500
# 31/31 [==============================] - 0s 4ms/step - loss: 9.1470e-04 - accuracy: 1.0000
# Epoch 27/1500
# 31/31 [==============================] - 0s 5ms/step - loss: 0.0019 - accuracy: 0.9995
# Epoch 28/1500
# 31/31 [==============================] - 0s 5ms/step - loss: 7.8057e-04 - accuracy: 1.0000
# Epoch 29/1500
# 31/31 [==============================] - 0s 5ms/step - loss: 4.1685e-04 - accuracy: 1.0000
# Epoch 30/1500
# 31/31 [==============================] - 0s 5ms/step - loss: 7.4298e-04 - accuracy: 1.0000
# Epoch 31/1500
# 31/31 [==============================] - 0s 5ms/step - loss: 6.7007e-04 - accuracy: 0.9995
# Epoch 32/1500
# 31/31 [==============================] - 0s 5ms/step - loss: 8.6909e-04 - accuracy: 0.9995
# Epoch 33/1500
# 31/31 [==============================] - 0s 5ms/step - loss: 6.7553e-04 - accuracy: 1.0000
# Epoch 34/1500
# 31/31 [==============================] - 0s 4ms/step - loss: 6.0332e-04 - accuracy: 1.0000
# Epoch 35/1500
# 31/31 [==============================] - 0s 5ms/step - loss: 1.9117e-04 - accuracy: 1.0000
# Epoch 36/1500
# 31/31 [==============================] - 0s 5ms/step - loss: 6.2271e-04 - accuracy: 1.0000
# Epoch 37/1500
# 31/31 [==============================] - 0s 5ms/step - loss: 4.1294e-04 - accuracy: 1.0000
# Epoch 38/1500
# 31/31 [==============================] - 0s 5ms/step - loss: 2.9304e-04 - accuracy: 1.0000
# Epoch 39/1500
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 40/1500
# 31/31 [==============================] - 0s 5ms/step - loss: 4.8690e-04 - accuracy: 1.0000
# Epoch 41/1500
# 31/31 [==============================] - 0s 4ms/step - loss: 3.2346e-04 - accuracy: 1.0000
# Epoch 42/1500
# 31/31 [==============================] - 0s 4ms/step - loss: 4.4003e-04 - accuracy: 1.0000
# Epoch 43/1500
# 31/31 [==============================] - 0s 5ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 44/1500
# 31/31 [==============================] - 0s 5ms/step - loss: 3.9862e-04 - accuracy: 1.0000
# Epoch 45/1500
# 31/31 [==============================] - 0s 4ms/step - loss: 4.4486e-04 - accuracy: 1.0000
# Epoch 46/1500
# 31/31 [==============================] - 0s 5ms/step - loss: 2.5513e-04 - accuracy: 1.0000
# Epoch 47/1500
# 31/31 [==============================] - 0s 5ms/step - loss: 1.9281e-04 - accuracy: 1.0000
# Epoch 48/1500
# 31/31 [==============================] - 0s 5ms/step - loss: 1.3468e-04 - accuracy: 1.0000
# Epoch 49/1500
# 24/31 [======================>.......] - ETA: 0s - loss: 1.3099e-04 - accuracy: 1.0000Restoring model weights from the end of the best epoch: 19.
# 31/31 [==============================] - 0s 5ms/step - loss: 1.5204e-04 - accuracy: 1.0000
# Epoch 49: early stopping
# 7/7 [==============================] - 0s 1ms/step - loss: 0.6974 - accuracy: 0.8209
# 7/7 [==============================] - 0s 851us/step
# Majority Vote Accuracy for cat_id for this fold: 0.90 (27/30)
# Before appending - Cat IDs: 180, Predictions: 180, Actuals: 180, Gender: 180
# After appending - Cat IDs: 381, Predictions: 381, Actuals: 381, Gender: 381
# Final Test Results - Loss: 0.6974382400512695, Accuracy: 0.8208954930305481, Precision: 0.5518620452395286, Recall: 0.7282754010695186, F1 Score: 0.5858229436211088
# Confusion Matrix:
#  [[149  10  17]
#  [  2  10   5]
#  [  0   2   6]]
# outer_fold 3
# Train Set Group Distribution:
# 000A    39
# 002B    30
# 020A    20
# 000B    19
# 019A    17
# 057A    17
# 074A    16
# 029A    15
# 097A    15
# 097B    14
# 002A    13
# 106A    13
# 055A    12
# 111A    12
# 116A    12
# 028A    11
# 063A    11
# 067A    11
# 014B    10
# 040A    10
# 065A     9
# 005A     9
# 022A     9
# 051B     9
# 033A     9
# 071A     9
# 001A     9
# 068A     8
# 013B     8
# 117A     7
# 036A     7
# 015A     7
# 095A     7
# 031A     7
# 039A     6
# 023A     6
# 099A     6
# 007A     6
# 044A     5
# 094A     5
# 050A     5
# 075A     5
# 026A     4
# 003A     4
# 023B     4
# 009A     4
# 025C     4
# 104A     4
# 053A     3
# 113A     3
# 105A     3
# 060A     3
# 034A     3
# 062A     3
# 056A     3
# 012A     3
# 058A     3
# 006A     3
# 011A     2
# 061A     2
# 102A     2
# 035A     2
# 052A     2
# 037A     2
# 032A     2
# 093A     2
# 054A     2
# 038A     2
# 069A     2
# 087A     2
# 049A     1
# 019B     1
# 024A     1
# 100A     1
# 110A     1
# 004A     1
# 088A     1
# 092A     1
# 066A     1
# 096A     1
# 043A     1
# 026C     1
# 073A     1
# 026B     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 046A    45
# 103A    33
# 047A    22
# 101A    12
# 051A    12
# 042A    11
# 059A    10
# 025A    10
# 072A     9
# 016A     9
# 027A     7
# 108A     5
# 008A     5
# 021A     5
# 109A     5
# 070A     5
# 045A     4
# 014A     3
# 010A     3
# 018A     2
# 025B     2
# 076A     1
# 064A     1
# 041A     1
# 091A     1
# 048A     1
# 115A     1
# 090A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    210
# F    181
# X    176
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    100
# M     76
# F     50
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [006A, 000A, 033A, 015A, 001A, 071A, 097B, 028...
# kitten     [044A, 014B, 111A, 040A, 050A, 043A, 049A, 110A]
# senior    [093A, 097A, 057A, 106A, 104A, 055A, 113A, 116...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [103A, 101A, 072A, 091A, 027A, 025A, 070A, 014...
# kitten     [046A, 047A, 042A, 109A, 041A, 045A, 048A, 115A]
# senior                       [059A, 051A, 016A, 108A, 090A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 59, 'kitten': 8, 'senior': 17}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 15, 'kitten': 8, 'senior': 5}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '004A' '005A' '006A' '007A'
#  '009A' '011A' '012A' '013B' '014B' '015A' '019A' '019B' '020A' '022A'
#  '023A' '023B' '024A' '025C' '026A' '026B' '026C' '028A' '029A' '031A'
#  '032A' '033A' '034A' '035A' '036A' '037A' '038A' '039A' '040A' '043A'
#  '044A' '049A' '050A' '051B' '052A' '053A' '054A' '055A' '056A' '057A'
#  '058A' '060A' '061A' '062A' '063A' '065A' '066A' '067A' '068A' '069A'
#  '071A' '073A' '074A' '075A' '087A' '088A' '092A' '093A' '094A' '095A'
#  '096A' '097A' '097B' '099A' '100A' '102A' '104A' '105A' '106A' '110A'
#  '111A' '113A' '116A' '117A']
# Unique Test Group IDs:
# ['008A' '010A' '014A' '016A' '018A' '021A' '025A' '025B' '027A' '041A'
#  '042A' '045A' '046A' '047A' '048A' '051A' '059A' '064A' '070A' '072A'
#  '076A' '090A' '091A' '101A' '103A' '108A' '109A' '115A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'046A'}
# Removed from Training/Validation Set:
# {'040A'}
# Moved to Test Set:
# {'040A'}
# Removed from Test Set
# {'046A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '004A' '005A' '006A' '007A'
#  '009A' '011A' '012A' '013B' '014B' '015A' '019A' '019B' '020A' '022A'
#  '023A' '023B' '024A' '025C' '026A' '026B' '026C' '028A' '029A' '031A'
#  '032A' '033A' '034A' '035A' '036A' '037A' '038A' '039A' '043A' '044A'
#  '046A' '049A' '050A' '051B' '052A' '053A' '054A' '055A' '056A' '057A'
#  '058A' '060A' '061A' '062A' '063A' '065A' '066A' '067A' '068A' '069A'
#  '071A' '073A' '074A' '075A' '087A' '088A' '092A' '093A' '094A' '095A'
#  '096A' '097A' '097B' '099A' '100A' '102A' '104A' '105A' '106A' '110A'
#  '111A' '113A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['008A' '010A' '014A' '016A' '018A' '021A' '025A' '025B' '027A' '040A'
#  '041A' '042A' '045A' '047A' '048A' '051A' '059A' '064A' '070A' '072A'
#  '076A' '090A' '091A' '101A' '103A' '108A' '109A' '115A']
# Length of X_train_val:
# 602
# Length of y_train_val:
# 602
# Length of groups_train_val:
# 602
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     410
# senior    112
# kitten     45
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     99
# kitten    90
# senior    37
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     410
# senior    112
# kitten     80
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     99
# kitten    55
# senior    37
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Age group distribution: Counter({0: 820, 2: 560, 1: 400})
# Epoch 1/1500
# 28/28 [==============================] - 1s 4ms/step - loss: 0.4653 - accuracy: 0.8461
# Epoch 2/1500
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0649 - accuracy: 0.9747
# Epoch 3/1500
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0302 - accuracy: 0.9899
# Epoch 4/1500
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0160 - accuracy: 0.9961
# Epoch 5/1500
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0068 - accuracy: 0.9978
# Epoch 6/1500
# 28/28 [==============================] - 0s 5ms/step - loss: 0.0066 - accuracy: 0.9983
# Epoch 7/1500
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0066 - accuracy: 0.9978
# Epoch 8/1500
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0056 - accuracy: 0.9978
# Epoch 9/1500
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 10/1500
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 11/1500
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 12/1500
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 13/1500
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 14/1500
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0031 - accuracy: 0.9989
# Epoch 15/1500
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0058 - accuracy: 0.9989
# Epoch 16/1500
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0024 - accuracy: 0.9994
# Epoch 17/1500
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 18/1500
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0025 - accuracy: 0.9994
# Epoch 19/1500
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 20/1500
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0016 - accuracy: 0.9994
# Epoch 21/1500
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 22/1500
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 23/1500
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0035 - accuracy: 0.9983
# Epoch 24/1500
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0032 - accuracy: 0.9989
# Epoch 25/1500
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0017 - accuracy: 0.9994
# Epoch 26/1500
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 27/1500
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0016 - accuracy: 0.9994
# Epoch 28/1500
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 29/1500
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0013 - accuracy: 0.9994
# Epoch 30/1500
# 28/28 [==============================] - 0s 4ms/step - loss: 6.0811e-04 - accuracy: 1.0000
# Epoch 31/1500
# 28/28 [==============================] - 0s 4ms/step - loss: 6.6540e-04 - accuracy: 1.0000
# Epoch 32/1500
# 28/28 [==============================] - 0s 5ms/step - loss: 4.7613e-04 - accuracy: 1.0000
# Epoch 33/1500
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 34/1500
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0019 - accuracy: 0.9994
# Epoch 35/1500
# 28/28 [==============================] - 0s 4ms/step - loss: 7.5550e-04 - accuracy: 1.0000
# Epoch 36/1500
# 28/28 [==============================] - 0s 4ms/step - loss: 4.2333e-04 - accuracy: 1.0000
# Epoch 37/1500
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0014 - accuracy: 0.9994
# Epoch 38/1500
# 28/28 [==============================] - 0s 4ms/step - loss: 4.9982e-04 - accuracy: 1.0000
# Epoch 39/1500
# 28/28 [==============================] - 0s 4ms/step - loss: 8.4288e-04 - accuracy: 1.0000
# Epoch 40/1500
# 28/28 [==============================] - 0s 4ms/step - loss: 8.4007e-04 - accuracy: 0.9994
# Epoch 41/1500
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0016 - accuracy: 0.9994
# Epoch 42/1500
# 28/28 [==============================] - 0s 5ms/step - loss: 0.0021 - accuracy: 0.9994
# Epoch 43/1500
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0043 - accuracy: 0.9983
# Epoch 44/1500
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0023 - accuracy: 0.9994
# Epoch 45/1500
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0014 - accuracy: 0.9994
# Epoch 46/1500
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0027 - accuracy: 0.9989
# Epoch 47/1500
# 25/28 [=========================>....] - ETA: 0s - loss: 0.0013 - accuracy: 0.9994  Restoring model weights from the end of the best epoch: 17.
# 28/28 [==============================] - 0s 5ms/step - loss: 0.0012 - accuracy: 0.9994
# Epoch 47: early stopping
# 6/6 [==============================] - 0s 1ms/step - loss: 2.6225 - accuracy: 0.6178
# 6/6 [==============================] - 0s 985us/step
# Majority Vote Accuracy for cat_id for this fold: 0.79 (22/28)
# Before appending - Cat IDs: 381, Predictions: 381, Actuals: 381, Gender: 381
# After appending - Cat IDs: 572, Predictions: 572, Actuals: 572, Gender: 572
# Final Test Results - Loss: 2.622523784637451, Accuracy: 0.6178010702133179, Precision: 0.6997854997854999, Recall: 0.5252889252889252, F1 Score: 0.5349527665317139
# Confusion Matrix:
#  [[88  0 11]
#  [40 14  1]
#  [20  1 16]]
# outer_fold 4
# Train Set Group Distribution:
# 046A    45
# 000A    39
# 103A    33
# 002B    30
# 047A    22
# 020A    20
# 000B    19
# 074A    16
# 029A    15
# 097B    14
# 106A    13
# 002A    13
# 055A    12
# 116A    12
# 101A    12
# 051A    12
# 067A    11
# 042A    11
# 063A    11
# 025A    10
# 040A    10
# 014B    10
# 059A    10
# 072A     9
# 016A     9
# 065A     9
# 022A     9
# 071A     9
# 051B     9
# 033A     9
# 013B     8
# 068A     8
# 027A     7
# 036A     7
# 015A     7
# 099A     6
# 039A     6
# 007A     6
# 023A     6
# 044A     5
# 108A     5
# 109A     5
# 075A     5
# 021A     5
# 008A     5
# 070A     5
# 045A     4
# 003A     4
# 023B     4
# 025C     4
# 104A     4
# 010A     3
# 053A     3
# 056A     3
# 113A     3
# 058A     3
# 014A     3
# 012A     3
# 105A     3
# 062A     3
# 060A     3
# 011A     2
# 025B     2
# 035A     2
# 093A     2
# 102A     2
# 037A     2
# 069A     2
# 032A     2
# 054A     2
# 018A     2
# 110A     1
# 100A     1
# 090A     1
# 024A     1
# 115A     1
# 096A     1
# 026C     1
# 019B     1
# 048A     1
# 041A     1
# 049A     1
# 091A     1
# 064A     1
# 076A     1
# 026B     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 057A    17
# 019A    17
# 097A    15
# 111A    12
# 028A    11
# 001A     9
# 005A     9
# 117A     7
# 095A     7
# 031A     7
# 094A     5
# 050A     5
# 026A     4
# 009A     4
# 006A     3
# 034A     3
# 087A     2
# 038A     2
# 052A     2
# 061A     2
# 043A     1
# 073A     1
# 092A     1
# 066A     1
# 004A     1
# 088A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    246
# X    205
# F    193
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    71
# M    40
# F    38
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [000A, 033A, 015A, 103A, 071A, 097B, 074A, 067...
# kitten    [044A, 014B, 040A, 046A, 047A, 042A, 109A, 049...
# senior    [093A, 106A, 104A, 055A, 059A, 113A, 116A, 051...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [006A, 001A, 028A, 019A, 095A, 034A, 005A, 009...
# kitten                                   [111A, 050A, 043A]
# senior                       [097A, 057A, 117A, 094A, 061A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 56, 'kitten': 13, 'senior': 17}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 18, 'kitten': 3, 'senior': 5}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '002A' '002B' '003A' '007A' '008A' '010A' '011A' '012A'
#  '013B' '014A' '014B' '015A' '016A' '018A' '019B' '020A' '021A' '022A'
#  '023A' '023B' '024A' '025A' '025B' '025C' '026B' '026C' '027A' '029A'
#  '032A' '033A' '035A' '036A' '037A' '039A' '040A' '041A' '042A' '044A'
#  '045A' '046A' '047A' '048A' '049A' '051A' '051B' '053A' '054A' '055A'
#  '056A' '058A' '059A' '060A' '062A' '063A' '064A' '065A' '067A' '068A'
#  '069A' '070A' '071A' '072A' '074A' '075A' '076A' '090A' '091A' '093A'
#  '096A' '097B' '099A' '100A' '101A' '102A' '103A' '104A' '105A' '106A'
#  '108A' '109A' '110A' '113A' '115A' '116A']
# Unique Test Group IDs:
# ['001A' '004A' '005A' '006A' '009A' '019A' '026A' '028A' '031A' '034A'
#  '038A' '043A' '050A' '052A' '057A' '061A' '066A' '073A' '087A' '088A'
#  '092A' '094A' '095A' '097A' '111A' '117A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '002A' '002B' '003A' '007A' '008A' '010A' '011A' '012A'
#  '013B' '014A' '014B' '015A' '016A' '018A' '019B' '020A' '021A' '022A'
#  '023A' '023B' '024A' '025A' '025B' '025C' '026B' '026C' '027A' '029A'
#  '032A' '033A' '035A' '036A' '037A' '039A' '040A' '041A' '042A' '044A'
#  '045A' '046A' '047A' '048A' '049A' '051A' '051B' '053A' '054A' '055A'
#  '056A' '058A' '059A' '060A' '062A' '063A' '064A' '065A' '067A' '068A'
#  '069A' '070A' '071A' '072A' '074A' '075A' '076A' '090A' '091A' '093A'
#  '096A' '097B' '099A' '100A' '101A' '102A' '103A' '104A' '105A' '106A'
#  '108A' '109A' '110A' '113A' '115A' '116A']
# AFTER SWAP - Unique Test Group IDs:
# ['001A' '004A' '005A' '006A' '009A' '019A' '026A' '028A' '031A' '034A'
#  '038A' '043A' '050A' '052A' '057A' '061A' '066A' '073A' '087A' '088A'
#  '092A' '094A' '095A' '097A' '111A' '117A']
# Length of X_train_val:
# 644
# Length of y_train_val:
# 644
# Length of groups_train_val:
# 644
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     424
# kitten    117
# senior    103
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     85
# senior    46
# kitten    18
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     424
# kitten    117
# senior    103
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     85
# senior    46
# kitten    18
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 848, 1: 585, 2: 515})
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Epoch 1/1500
# 31/31 [==============================] - 1s 4ms/step - loss: 0.4227 - accuracy: 0.8624
# Epoch 2/1500
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0639 - accuracy: 0.9815
# Epoch 3/1500
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0262 - accuracy: 0.9913
# Epoch 4/1500
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0134 - accuracy: 0.9974
# Epoch 5/1500
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0095 - accuracy: 0.9969
# Epoch 6/1500
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0052 - accuracy: 0.9990
# Epoch 7/1500
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0058 - accuracy: 0.9985
# Epoch 8/1500
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0027 - accuracy: 0.9995
# Epoch 9/1500
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0049 - accuracy: 0.9990
# Epoch 10/1500
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0053 - accuracy: 0.9985
# Epoch 11/1500
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0032 - accuracy: 0.9995
# Epoch 12/1500
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0042 - accuracy: 0.9995
# Epoch 13/1500
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 14/1500
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0042 - accuracy: 0.9990
# Epoch 15/1500
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0026 - accuracy: 0.9990
# Epoch 16/1500
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 17/1500
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 18/1500
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 19/1500
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0011 - accuracy: 0.9995
# Epoch 20/1500
# 31/31 [==============================] - 0s 4ms/step - loss: 8.6065e-04 - accuracy: 1.0000
# Epoch 21/1500
# 31/31 [==============================] - 0s 4ms/step - loss: 6.4468e-04 - accuracy: 1.0000
# Epoch 22/1500
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0010 - accuracy: 0.9995
# Epoch 23/1500
# 31/31 [==============================] - 0s 4ms/step - loss: 9.2453e-04 - accuracy: 1.0000
# Epoch 24/1500
# 31/31 [==============================] - 0s 4ms/step - loss: 5.3793e-04 - accuracy: 1.0000
# Epoch 25/1500
# 31/31 [==============================] - 0s 4ms/step - loss: 7.3485e-04 - accuracy: 1.0000
# Epoch 26/1500
# 31/31 [==============================] - 0s 4ms/step - loss: 7.0180e-04 - accuracy: 1.0000
# Epoch 27/1500
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0011 - accuracy: 0.9995
# Epoch 28/1500
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0022 - accuracy: 0.9990
# Epoch 29/1500
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0017 - accuracy: 0.9995
# Epoch 30/1500
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 31/1500
# 31/31 [==============================] - 0s 4ms/step - loss: 5.3832e-04 - accuracy: 1.0000
# Epoch 32/1500
# 31/31 [==============================] - 0s 4ms/step - loss: 3.2080e-04 - accuracy: 1.0000
# Epoch 33/1500
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0015 - accuracy: 0.9995
# Epoch 34/1500
# 31/31 [==============================] - 0s 4ms/step - loss: 3.1557e-04 - accuracy: 1.0000
# Epoch 35/1500
# 31/31 [==============================] - 0s 4ms/step - loss: 3.6534e-04 - accuracy: 1.0000
# Epoch 36/1500
# 31/31 [==============================] - 0s 4ms/step - loss: 2.7600e-04 - accuracy: 1.0000
# Epoch 37/1500
# 31/31 [==============================] - 0s 4ms/step - loss: 6.7834e-04 - accuracy: 1.0000
# Epoch 38/1500
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 39/1500
# 31/31 [==============================] - 0s 4ms/step - loss: 7.6319e-04 - accuracy: 0.9995
# Epoch 40/1500
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0017 - accuracy: 0.9995
# Epoch 41/1500
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0017 - accuracy: 0.9995
# Epoch 42/1500
# 31/31 [==============================] - 0s 4ms/step - loss: 5.4212e-04 - accuracy: 1.0000
# Epoch 43/1500
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0052 - accuracy: 0.9985
# Epoch 44/1500
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0029 - accuracy: 0.9979
# Epoch 45/1500
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0066 - accuracy: 0.9985
# Epoch 46/1500
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0034 - accuracy: 0.9990
# Epoch 47/1500
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0065 - accuracy: 0.9979
# Epoch 48/1500
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0035 - accuracy: 0.9995
# Epoch 49/1500
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0053 - accuracy: 0.9990
# Epoch 50/1500
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0037 - accuracy: 0.9995
# Epoch 51/1500
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0046 - accuracy: 0.9974
# Epoch 52/1500
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0039 - accuracy: 0.9995
# Epoch 53/1500
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 54/1500
# 31/31 [==============================] - 0s 4ms/step - loss: 6.9227e-04 - accuracy: 1.0000
# Epoch 55/1500
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 56/1500
# 31/31 [==============================] - 0s 4ms/step - loss: 3.3973e-04 - accuracy: 1.0000
# Epoch 57/1500
# 31/31 [==============================] - 0s 4ms/step - loss: 1.2677e-04 - accuracy: 1.0000
# Epoch 58/1500
# 31/31 [==============================] - 0s 4ms/step - loss: 2.2219e-04 - accuracy: 1.0000
# Epoch 59/1500
# 31/31 [==============================] - 0s 4ms/step - loss: 7.7344e-04 - accuracy: 0.9995
# Epoch 60/1500
# 31/31 [==============================] - 0s 4ms/step - loss: 2.8899e-04 - accuracy: 1.0000
# Epoch 61/1500
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0011 - accuracy: 0.9995
# Epoch 62/1500
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0102 - accuracy: 0.9990
# Epoch 63/1500
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0023 - accuracy: 0.9985
# Epoch 64/1500
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0019 - accuracy: 0.9995
# Epoch 65/1500
# 31/31 [==============================] - 0s 4ms/step - loss: 0.0035 - accuracy: 0.9985
# Epoch 66/1500
# 25/31 [=======================>......] - ETA: 0s - loss: 0.0011 - accuracy: 0.9994    Restoring model weights from the end of the best epoch: 36.
# 31/31 [==============================] - 0s 4ms/step - loss: 8.9362e-04 - accuracy: 0.9995
# Epoch 66: early stopping
# 5/5 [==============================] - 0s 1ms/step - loss: 2.7576 - accuracy: 0.6510
# 5/5 [==============================] - 0s 963us/step
# Majority Vote Accuracy for cat_id for this fold: 0.77 (20/26)
# Before appending - Cat IDs: 572, Predictions: 572, Actuals: 572, Gender: 572
# After appending - Cat IDs: 721, Predictions: 721, Actuals: 721, Gender: 721
# Final Test Results - Loss: 2.7575783729553223, Accuracy: 0.6510066986083984, Precision: 0.6611111111111111, Recall: 0.6750876195888984, F1 Score: 0.6601830663615561
# Confusion Matrix:
#  [[66  3 16]
#  [ 1 17  0]
#  [32  0 14]]
#
# Final Average F1-Score across all UNSEEN TEST sets: 0.6138294377183383
#
# Final Average Loss across all UNSEEN TEST sets: 2.1476969122886658
#
# Final Average Accuracy across all UNSEEN TEST sets: 0.7057591527700424
#
# Final Average Precision across all UNSEEN TEST sets: 0.667522379102044
#
# Final Average Recall across all UNSEEN TEST sets: 0.6666611391961952

# %%
seed_4_folds_values = (unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1)

# Plotting all fold metrics
seed_4_folds_plot = plot_all_metrics(unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1, "Folds", "Fold Number")

# %% [markdown]
# ## Majority Voting on Total Entries per cat_id

# %%
# Debugging print statements
print(f'Checking - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
# Out:
# Checking - Cat IDs: 721, Predictions: 721, Actuals: 721, Gender: 721

# %%
# Create results df
full_results = pd.DataFrame({
    'cat_id': all_cat_ids,
    'predicted_age_group': all_predicted_age_groups,
    'actual_age_group': all_actual_age_groups,
    'all_gender': all_gender
})

# create a correct majority prediction column
full_results['correct'] = full_results['predicted_age_group'] == full_results['actual_age_group']

# %%
# Group by cat_id and aggregate predicted age groups
majority_votes = full_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first()

# Calculate the accuracy of majority voting
correct_predictions = (majority_votes == actual_groups).sum()
total_cats = len(actual_groups)
majority_vote_accuracy = correct_predictions / total_cats

logger(f"Overall Majority Vote Accuracy for cat_id: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

# store for final evaluation 
all_majority_vote_accuracies.append(majority_vote_accuracy)
# Out:
# Overall Majority Vote Accuracy for cat_id: 0.80 (88/110)

# %%
# Detailed df with predictions, actual labels, and comparison including majority vote
detailed_results = full_results.groupby('cat_id').apply(
    lambda x: pd.Series({
        'Predictions': list(x['predicted_age_group']),
        'Majority Vote': x['predicted_age_group'].mode()[0],
        'Actual Age Group': x['actual_age_group'].iloc[0],
        'Correct Majority Vote': x['predicted_age_group'].mode()[0] == x['actual_age_group'].iloc[0]
    })
).reset_index()

# Convert to DataFrame for better formatting and display
detailed_results = pd.DataFrame(detailed_results)

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 10)
pd.set_option('display.width', 1000)

sorted_detailed_results = detailed_results.sort_values(by='Correct Majority Vote', ascending=False)

# Display the sorted DataFrame
sorted_detailed_results
# Out:
#     cat_id                                        Predictions Majority Vote Actual Age Group  Correct Majority Vote
# 0     000B  [adult, senior, adult, adult, adult, adult, ad...         adult            adult                   True
# 71    065A  [senior, adult, adult, adult, adult, senior, a...         adult            adult                   True
# 80    074A  [adult, adult, senior, adult, adult, adult, ad...         adult            adult                   True
# 79    073A                                            [adult]         adult            adult                   True
# 78    072A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 77    071A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 76    070A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 75    069A                     [adult, senior, senior, adult]         adult            adult                   True
# 74    068A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 73    067A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 72    066A                                            [adult]         adult            adult                   True
# 70    064A                                            [adult]         adult            adult                   True
# 47    041A                                           [kitten]        kitten           kitten                   True
# 69    063A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 68    062A                              [adult, adult, adult]         adult            adult                   True
# 65    059A  [senior, senior, senior, senior, senior, adult...        senior           senior                   True
# 64    058A                           [senior, senior, senior]        senior           senior                   True
# 58    052A                                     [adult, adult]         adult            adult                   True
# 1     001A  [adult, senior, adult, senior, adult, adult, a...         adult            adult                   True
# 54    049A                                           [kitten]        kitten           kitten                   True
# 53    048A                                           [kitten]        kitten           kitten                   True
# 50    044A           [kitten, kitten, kitten, kitten, kitten]        kitten           kitten                   True
# 81    075A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 82    076A                                            [adult]         adult            adult                   True
# 83    087A                                     [adult, adult]         adult            adult                   True
# 84    088A                                            [adult]         adult            adult                   True
# 108   116A  [senior, senior, adult, kitten, adult, senior,...        senior           senior                   True
# 107   115A                                           [kitten]        kitten           kitten                   True
# 106   113A                           [senior, senior, senior]        senior           senior                   True
# 105   111A  [adult, kitten, kitten, kitten, kitten, kitten...        kitten           kitten                   True
# 104   110A                                           [kitten]        kitten           kitten                   True
# 102   108A             [senior, adult, adult, senior, senior]        senior           senior                   True
# 100   105A                              [adult, adult, adult]         adult            adult                   True
# 98    103A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 97    102A                                     [adult, adult]         adult            adult                   True
# 96    101A  [adult, adult, adult, adult, senior, senior, a...         adult            adult                   True
# 95    100A                                            [adult]         adult            adult                   True
# 94    099A        [adult, adult, adult, kitten, adult, adult]         adult            adult                   True
# 93    097B  [adult, adult, adult, adult, adult, adult, kit...         adult            adult                   True
# 91    096A                                            [adult]         adult            adult                   True
# 90    095A  [senior, adult, senior, adult, adult, adult, a...         adult            adult                   True
# 89    094A           [senior, senior, senior, senior, senior]        senior           senior                   True
# 87    092A                                            [adult]         adult            adult                   True
# 86    091A                                            [adult]         adult            adult                   True
# 85    090A                                           [senior]        senior           senior                   True
# 49    043A                                           [kitten]        kitten           kitten                   True
# 55    050A           [kitten, kitten, kitten, kitten, kitten]        kitten           kitten                   True
# 46    040A  [kitten, kitten, kitten, kitten, kitten, kitte...        kitten           kitten                   True
# 15    014A                              [adult, adult, adult]         adult            adult                   True
# 29    025B                                     [adult, adult]         adult            adult                   True
# 28    025A  [adult, adult, adult, senior, adult, adult, ad...         adult            adult                   True
# 26    023B                       [adult, adult, adult, adult]         adult            adult                   True
# 25    023A        [adult, kitten, adult, adult, adult, adult]         adult            adult                   True
# 24    022A  [adult, adult, kitten, kitten, adult, adult, k...         adult            adult                   True
# 23    021A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 22    020A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 21    019B                                            [adult]         adult            adult                   True
# 20    019A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 19    018A                                     [adult, adult]         adult            adult                   True
# 17    015A  [adult, adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 14    013B  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 31    026A                       [adult, adult, adult, adult]         adult            adult                   True
# 13    012A                              [adult, adult, adult]         adult            adult                   True
# 12    011A                                   [senior, senior]        senior           senior                   True
# 11    010A                              [adult, adult, adult]         adult            adult                   True
# 10    009A                       [adult, adult, adult, adult]         adult            adult                   True
# 9     008A               [adult, adult, adult, senior, adult]         adult            adult                   True
# 8     007A         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 7     006A                              [adult, adult, adult]         adult            adult                   True
# 5     004A                                            [adult]         adult            adult                   True
# 4     003A                       [adult, adult, adult, adult]         adult            adult                   True
# 3     002B  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 2     002A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 30    025C                      [adult, adult, senior, adult]         adult            adult                   True
# 27    024A                                           [senior]        senior           senior                   True
# 32    026B                                            [adult]         adult            adult                   True
# 38    032A                                     [adult, adult]         adult            adult                   True
# 41    035A                                    [senior, adult]         adult            adult                   True
# 33    026C                                            [adult]         adult            adult                   True
# 42    036A  [senior, adult, adult, adult, adult, adult, ad...         adult            adult                   True
# 43    037A                                    [senior, adult]         adult            adult                   True
# 39    033A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 37    031A  [adult, adult, adult, senior, adult, adult, ad...         adult            adult                   True
# 36    029A  [senior, senior, adult, adult, adult, adult, a...         adult            adult                   True
# 35    028A  [senior, adult, adult, senior, adult, adult, a...         adult            adult                   True
# 45    039A         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 34    027A  [adult, senior, adult, adult, adult, senior, a...         adult            adult                   True
# 40    034A                             [adult, adult, kitten]         adult            adult                   True
# 44    038A                                   [kitten, kitten]        kitten            adult                  False
# 51    045A                       [adult, adult, adult, adult]         adult           kitten                  False
# 56    051A  [adult, adult, adult, adult, adult, senior, ad...         adult           senior                  False
# 52    047A  [adult, adult, adult, adult, adult, adult, adu...         adult           kitten                  False
# 6     005A  [senior, senior, senior, senior, senior, senio...        senior            adult                  False
# 103   109A                [adult, adult, adult, adult, adult]         adult           kitten                  False
# 101   106A  [adult, adult, adult, kitten, adult, adult, ad...         adult           senior                  False
# 99    104A                       [adult, adult, adult, adult]         adult           senior                  False
# 92    097A  [adult, senior, adult, adult, senior, senior, ...         adult           senior                  False
# 57    051B  [adult, adult, adult, adult, adult, adult, adu...         adult           senior                  False
# 59    053A                            [senior, senior, adult]        senior            adult                  False
# 60    054A                                     [adult, adult]         adult           senior                  False
# 61    055A  [adult, senior, senior, adult, adult, senior, ...         adult           senior                  False
# 16    014B  [senior, senior, adult, senior, kitten, kitten...        senior           kitten                  False
# 62    056A                             [adult, senior, adult]         adult           senior                  False
# 88    093A                                   [kitten, kitten]        kitten           senior                  False
# 18    016A  [adult, adult, adult, adult, senior, adult, ad...         adult           senior                  False
# 63    057A  [adult, senior, adult, adult, senior, adult, a...         adult           senior                  False
# 66    060A                            [adult, kitten, kitten]        kitten            adult                  False
# 67    061A                                     [adult, adult]         adult           senior                  False
# 48    042A  [adult, adult, adult, adult, adult, adult, adu...         adult           kitten                  False
# 109   117A  [adult, adult, adult, adult, adult, adult, adult]         adult           senior                  False

# %%
# Create df for majority votes
majority_df = majority_votes.reset_index()
majority_df.columns = ['cat_id', 'Majority_Vote']

# Get actual groups for each cat_id
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first().reset_index()

# Merge majority votes with actual groups
majority_with_actual = pd.merge(majority_df, actual_groups, on='cat_id')

# Add a column to check if the majority vote was correct
majority_with_actual['Majority_Correct'] = majority_with_actual['Majority_Vote'] == majority_with_actual['actual_age_group']

# Count correct majority votes per class
correct_majority_votes_per_class = majority_with_actual.groupby('actual_age_group')['Majority_Correct'].sum()

print("Correct Majority Votes per Class:")
print(correct_majority_votes_per_class)
# Out:
# Correct Majority Votes per Class:
# actual_age_group
# adult     69
# kitten    10
# senior     9
# Name: Majority_Correct, dtype: int64

# %%
# Calculate the total count and the number of correct predictions for each class
class_stats = majority_with_actual.groupby('actual_age_group').agg(
    total_count=('Majority_Correct', 'size'),  # Total number of cases per class
    correct_count=('Majority_Correct', 'sum')  # Sum of correct predictions per class
).reset_index()

# Calculate accuracy for each class
class_stats['accuracy'] = class_stats['correct_count'] / class_stats['total_count'] * 100

# store for final evaluation 
all_majority_vote_details.append(class_stats)

# Log detailed stats
print("Detailed Class Statistics for Majority Votes:")
print(class_stats)
# Out:
# Detailed Class Statistics for Majority Votes:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult           73             69  94.520548
# 1           kitten           15             10  66.666667
# 2           senior           22              9  40.909091

# %%
# Plot for Detailed Class Statistics for Majority Votes
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Accuracy of Majority Votes by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Detailed Class Statistics

# %%
# Calculate the total count and the number of correct predictions for each class
class_stats = full_results.groupby('actual_age_group').agg(
    total_count=('correct', 'size'),
    correct_count=('correct', 'sum')
).reset_index()

# Calculate accuracy for each class
class_stats['accuracy'] = class_stats['correct_count'] / class_stats['total_count'] * 100

# store for final evaluation 
all_class_stats.append(class_stats)

# Log the detailed stats
print("Detailed Class Statistics:")
print(class_stats)
# Out:
# Detailed Class Statistics:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult          472            410  86.864407
# 1           kitten          100             51  51.000000
# 2           senior          149             51  34.228188

# %%
# Plot for Detailed Class Statistics (Overall)
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Overall Accuracy by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Gender Exploration

# %%
# Group by gender and calculate the total count, correct predictions, and accuracy
gender_stats = full_results.groupby('all_gender').agg(
    count=('cat_id', 'size'),  # Total number of cases per gender
    correct=('correct', 'sum')  # Sum of correct predictions per gender
).reset_index()

# Calculate accuracy for each gender
gender_stats['accuracy'] = (gender_stats['correct'] / gender_stats['count'] * 100).round(2)

# Display the DataFrame
print("Accuracy by Gender:")
print(gender_stats)

# store for final evaluation 
all_gender_stats.append(gender_stats)
# Out:
# Accuracy by Gender:
#   all_gender  count  correct  accuracy
# 0          F    192      137     71.35
# 1          M    286      220     76.92
# 2          X    243      155     63.79

# %%
# Plot for Accuracy by Gender
styled_barplot(gender_stats, 'all_gender', 'accuracy', 
               'Accuracy by Gender', 
               'Gender', 'Accuracy (%)')

# %% [markdown]
# ### Log current total CV Stats

# %%
print("Total Majority Vote Accuracy so far:", all_majority_vote_accuracies)
print("Total Class Statistics so far:\n", all_class_stats)
print("Total Gender Accuracy so far:\n", all_gender_stats)
# Out:
# Total Majority Vote Accuracy so far: [0.7363636363636363, 0.7363636363636363, 0.7181818181818181, 0.8]
# Total Class Statistics so far:
#  [  actual_age_group  total_count  correct_count   accuracy
# 0            adult          474            413  87.130802
# 1           kitten           95             43  45.263158
# 2           senior          149             41  27.516779,   actual_age_group  total_count  correct_count   accuracy
# 0            adult          473            406  85.835095
# 1           kitten           91             46  50.549451
# 2           senior          149             36  24.161074,   actual_age_group  total_count  correct_count   accuracy
# 0            adult          487            435  89.322382
# 1           kitten           91             42  46.153846
# 2           senior          149             41  27.516779,   actual_age_group  total_count  correct_count   accuracy
# 0            adult          472            410  86.864407
# 1           kitten          100             51  51.000000
# 2           senior          149             51  34.228188]
# Total Gender Accuracy so far:
#  [  all_gender  count  correct  accuracy
# 0          F    196      137     69.90
# 1          M    286      219     76.57
# 2          X    236      141     59.75,   all_gender  count  correct  accuracy
# 0          F    192      130     67.71
# 1          M    289      219     75.78
# 2          X    232      139     59.91,   all_gender  count  correct  accuracy
# 0          F    192      137     71.35
# 1          M    286      223     77.97
# 2          X    249      158     63.45,   all_gender  count  correct  accuracy
# 0          F    192      137     71.35
# 1          M    286      220     76.92
# 2          X    243      155     63.79]

# %% [markdown]
# # RANDOM SEED 5

# %%
# Set a fixed random seed for reproducibility
random.seed(int(random_seeds[4]))
np.random.seed(int(random_seeds[4]))
tf.random.set_seed(int(random_seeds[4]))

# Load datasets
dataframe = pd.read_csv('/Users/astrid/PycharmProjects/perch-2/scripts/perch_embeddings_april_10.csv')
augmented_df = pd.read_csv('/Users/astrid/PycharmProjects/perch-2/scripts/perch_embeddings_augm_d1.csv')

dataframe.drop('mean_freq', axis=1, inplace=True)

augmented_df.drop('mean_freq', axis=1, inplace=True)
augmented_df.drop('gender', axis=1, inplace=True)

def assign_age_group(age, age_groups):
    for group_name, age_range in age_groups.items():
        if age_range[0] <= age < age_range[1]:
            return group_name
    return 'Unknown'  # For any age that doesn't fit the defined groups

# Define age groups
age_groups = {
    'kitten': (0, 0.5),
    'adult': (0.5, 12),
    'senior': (12, 20)
}

# Create a new column for the age group
dataframe['age_group'] = dataframe['target'].apply(assign_age_group, age_groups=age_groups)
augmented_df['age_group'] = augmented_df['target'].apply(assign_age_group, age_groups=age_groups)

print(dataframe['age_group'].value_counts())
print(augmented_df['age_group'].value_counts())
# Out:
# adult     509
# senior    149
# kitten    135
# Name: age_group, dtype: int64
# senior    596
# kitten    540
# adult     509
# Name: age_group, dtype: int64

# %%
# Separate features and labels
X = dataframe.iloc[:, :-4].values  # all columns except the last four

# Encode the 'age_group' column as integers using LabelEncoder
label_encoder = LabelEncoder()
encoded_y = label_encoder.fit_transform(dataframe['age_group'].values)

# Use the encoded labels for splitting and one-hot encoding
y = encoded_y  

# Convert 'cat_id' column to numpy array to be used as groups array for GroupKFold
groups = dataframe['cat_id'].values

# %%
tf.keras.backend.clear_session()

# %% [markdown]
# ## Run Setup

# %%
all_cat_ids = []
all_predicted_age_groups = []
all_actual_age_groups = []
all_gender = []

# Define the StratifiedGroupKFold splitter for 4 fold CV with random shuffling
outer_cv = StratifiedGroupKFold(n_splits=4, shuffle=True, random_state=int(random_seeds[4]))

# unseen test set metrics
unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1 = [], [], [], [], []

outer_fold = 0

# Use the splitter to generate indices for training and testing sets
# Note: GroupShuffleSplit.split returns indices, so we use it to index the arrays
for train_val_idx, test_idx in outer_cv.split(X, y, groups):
    outer_fold += 1
    logger(f"outer_fold {outer_fold}", file=log_file_path)

    # Convert indices back to DataFrame for easy manipulation
    df_train_val = dataframe.iloc[train_val_idx]
    df_test = dataframe.iloc[test_idx]

    ##############################
    # ASSESSING SPLITS BY CAT_ID #
    ##############################
    
    # Get the distribution of groups
    training_validation_group_distribution = df_train_val['cat_id'].value_counts()  
    testing_group_distribution = df_test['cat_id'].value_counts()  
    
    # Log or print the distribution
    logger(f"Train Set Group Distribution:\n{training_validation_group_distribution}", file=log_file_path)
    logger(f"Testing Set Group Distribution:\n{testing_group_distribution}", file=log_file_path)

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val['gender'].value_counts()
    testing_gender_distribution = df_test['gender'].value_counts()
    
    # Log the distribution
    logger(f"Training Set Gender Distribution BEFORE SWAP:\n{training_gender_distribution}", file=log_file_path)
    logger(f"Testing Set Gender Distribution BEFORE SWAP:\n{testing_gender_distribution}", file=log_file_path)

    # Group by 'age_group' and then list unique 'cat_id' within each age group
    unique_cat_ids_per_age_group_train_val = df_train_val.groupby('age_group')['cat_id'].unique()
    unique_cat_ids_per_age_group_test = df_test.groupby('age_group')['cat_id'].unique()
    
    # Log results
    logger(f"Unique Cat IDs per Age Group in Training/Validation Set:\n{unique_cat_ids_per_age_group_train_val}", file=log_file_path)
    logger(f"Unique Cat IDs per Age Group in Testing Set:\n{unique_cat_ids_per_age_group_test}", file=log_file_path)

    # Calculate the count of unique identifiers per age group for training and testing set
    counts_train_val = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_train_val.items()}
    counts_test = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_test.items()}

    # Log the counts of unique identifiers per age group
    logger(f"Count of Unique Cat IDs per Age Group in Training/Validation Set:\n{counts_train_val}", file=log_file_path)
    logger(f"Count of Unique Cat IDs per Age Group in Testing Set:\n{counts_test}", file=log_file_path)

    #######################################################
    # CONTINUE WITH ENSURING VALID AND APPROPRIATE SPLITS #
    #######################################################
    
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    groups_train_val, groups_test = groups[train_val_idx], groups[test_idx]

    # logging identifier splits 
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)

    # check group splits
    check_initial_group_split(groups_train_val, groups_test)

    # Specify the cat_ids that must be in the training/validation set
    specific_cat_ids = ['000A', '046A']
    
    # Perform the swapping operation
    train_val_idx, test_idx = swap_cat_id_instances(dataframe, train_val_idx, test_idx, specific_cat_ids)
    
    # Re-assign the sets based on the updated indices
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    new_groups_train_val, new_groups_test = groups[train_val_idx], groups[test_idx]

    # Find differences for training and test sets
    moved_to_train_val, removed_from_train_val = find_group_differences(groups_train_val, new_groups_train_val)
    moved_to_test, removed_from_test = find_group_differences(groups_test, new_groups_test)
    
    # Display the results
    logger(f"Moved to Training/Validation Set:\n{moved_to_train_val}", file=log_file_path)
    logger(f"Removed from Training/Validation Set:\n{removed_from_train_val}", file=log_file_path)
    logger(f"Moved to Test Set:\n{moved_to_test}", file=log_file_path)
    logger(f"Removed from Test Set\n{removed_from_test}", file=log_file_path)

    # Update X_train_val, X_test, y_train_val, y_test, groups_train_val, groups_test based on updated indices
    X_train_val = X[train_val_idx]
    y_train_val = y[train_val_idx]
    groups_train_val = groups[train_val_idx]
    
    X_test = X[test_idx]
    y_test = y[test_idx]
    groups_test = groups[test_idx]

    # logging identifier splits again after potential swaps
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"AFTER SWAP - Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"AFTER SWAP - Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)
    
    # Verify the lengths are consistent
    logger(f"Length of X_train_val:\n{len(X_train_val)}", file=log_file_path)
    logger(f"Length of y_train_val:\n{len(y_train_val)}", file=log_file_path)
    logger(f"Length of groups_train_val:\n{len(groups_train_val)}", file=log_file_path)

    # Check group splits once more
    check_initial_group_split(groups_train_val, groups_test)

    # Convert the modified indices back to a DataFrame representing the updated df_train_val
    df_train_val_updated = dataframe.iloc[train_val_idx].copy()
    df_test_updated = dataframe.iloc[test_idx].copy()

    ############################
    # LOGGING AGE GROUP SPLITS #
    ############################

    # Get the distribution of age groups of age groups before the update
    training_validation_age_group_distribution = df_train_val['age_group'].value_counts()
    testing_age_group_distribution = df_test['age_group'].value_counts()
    
    # Logthe distribution
    logger(f"Train Age Group Distribution BEFORE SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution BEFORE SWAP:\n{testing_age_group_distribution}", file=log_file_path)

    # Get the distribution of age groups after the update
    training_validation_age_group_distribution = df_train_val_updated['age_group'].value_counts()
    testing_age_group_distribution = df_test_updated['age_group'].value_counts()
    
    # Log the distribution
    logger(f"Train Age Group Distribution AFTER SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution AFTER SWAP:\n{testing_age_group_distribution}", file=log_file_path)
    
    ########################################################
    # TRACKING FINAL CAT_IDs & GENDER AFTER REDISTRIBUTION #
    ########################################################

    # Get the distribution of groups
    training_validation_group_distribution = df_train_val_updated['cat_id'].value_counts()  
    testing_group_distribution = df_test_updated['cat_id'].value_counts()  

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val_updated['gender'].value_counts()
    testing_gender_distribution = df_test_updated['gender'].value_counts()
    
    logger(f"\n Starting training on unseen test set\n", file=log_file_path)

    ######################
    # ADD AUGMENTED DATA #
    ######################

    # Filter out augmented data derived from groups in the training set
    augmented_df_filtered = augmented_df[augmented_df['cat_id'].isin(groups_train_val)]
    
    # Convert augmented_df_filtered to numpy array (excluding target and other columns)
    augmented_array = augmented_df_filtered.drop(columns=['target', 'cat_id', 'age_group']).values
    
    # Concatenate the filtered augmented data with X_train_val
    X_train_val = np.concatenate([X_train_val, augmented_array])

    # Extract target labels from the filtered augmented DataFrame
    y_augmented = augmented_df_filtered['age_group'].values
    
    # Encode the labels using the same LabelEncoder instance
    y_augmented_encoded = label_encoder.transform(y_augmented)
    
    # Concatenate the encoded augmented labels with y_train_val
    y_train_val = np.concatenate([y_train_val, y_augmented_encoded])

    # Calculate the distribution of age groups in y_train_val
    age_group_distribution = Counter(y_train_val)
    print("Age group distribution:", age_group_distribution)

    # EarlyStopping callback: monitor 'loss' instead of 'val_loss' for the test set
    early_stopping = EarlyStopping(
        monitor='loss',  
        min_delta=0.001, 
        patience=30,  
        verbose=1,  
        restore_best_weights=True  
    )

    # One final shuffle to ensure randomness
    outer_shuffle_idx = np.random.permutation(len(X_train_val))
    X_train_val = X_train_val[outer_shuffle_idx]
    y_train_val = y_train_val[outer_shuffle_idx]
    
    # Scale the features
    scaler_full = StandardScaler().fit(X_train_val)
    X_train_full_scaled = scaler_full.transform(X_train_val)
    X_test_scaled = scaler_full.transform(X_test)
    
    # Encode the labels
    y_train_full_encoded = to_categorical(y_train_val)
    y_test_encoded = to_categorical(y_test)

    #######################
    # BUILD & TRAIN MODEL #
    #######################

    optimizers = {
        'Adamax': Adamax(learning_rate=0.00510251984616472)
    }
    
    # Model definition with dynamic number of layers
    model_full = Sequential()
    model_full.add(Dense(480, activation='relu', input_shape=(X_train_full_scaled.shape[1],)))
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.2011047009431978))  
    model_full.add(Dense(256, activation='relu',)) 
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.14956886311951184))  
    model_full.add(Dense(256, activation='relu'))  
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.42291461228250665))  
    model_full.add(Dense(3, activation='softmax'))  
    
    # Use the optimizer from the parameters
    optimizer = optimizers['Adamax']  # optimizer_key from parameters
    
    # Compile the model
    model_full.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    
    # Train the model on the full training set
    history_full = model_full.fit(X_train_full_scaled, y_train_full_encoded, epochs=1500, batch_size=64,
                                  verbose=1, callbacks=[early_stopping])
    
    # Evaluate the model on the held-out test set
    test_loss, test_accuracy = model_full.evaluate(X_test_scaled, y_test_encoded)

    y_test_pred_prob = model_full.predict(X_test_scaled)
    y_test_pred = np.argmax(y_test_pred_prob, axis=1)  
    y_test_true = np.argmax(y_test_encoded, axis=1)    

    ################################
    # LOG MAJORITY VOTE PER CAT_ID #
    ################################

    # Convert numeric predictions back to age group labels
    predicted_age_groups = label_encoder.inverse_transform(y_test_pred)
    actual_labels = label_encoder.inverse_transform(y_test_true)
    
    # Map predictions and actual labels back to cat_ids
    test_results = pd.DataFrame({
        'cat_id': df_test_updated['cat_id'],
        'predicted_age_group': predicted_age_groups,
        'actual_age_group': actual_labels
    })
    
    # Group by cat_id and aggregate predicted age groups
    majority_votes = test_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
    actual_groups = test_results.groupby('cat_id')['actual_age_group'].first()
    
    # Calculate the accuracy of majority voting
    correct_predictions = (majority_votes == actual_groups).sum()
    total_cats = len(actual_groups)
    majority_vote_accuracy = correct_predictions / total_cats
    
    # Log the accuracy of the majority voting
    logger(f"Majority Vote Accuracy for cat_id for this fold: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

    ####################################################
    # COLLECT PREDICTIONS FOR GENDER & CAT_ID ANALYSIS #
    ####################################################

    # Debugging print statements
    print(f'Before appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Extend lists with current fold results
    all_cat_ids.extend(df_test_updated['cat_id'].tolist())
    all_predicted_age_groups.extend(predicted_age_groups)
    all_actual_age_groups.extend(actual_labels)
    all_gender.extend(df_test_updated['gender'].tolist())

    # Debugging print statements
    print(f'After appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Calculate additional metrics
    test_precision = precision_score(y_test_true, y_test_pred, average='macro')  # Use 'macro' for imbalanced datasets
    test_recall = recall_score(y_test_true, y_test_pred, average='macro')
    test_f1 = f1_score(y_test_true, y_test_pred, average='macro')

    # prepare averages of outer metrics
    unseen_f1.append(test_f1)
    unseen_losses.append(test_loss)
    unseen_accuracies.append(test_accuracy)
    unseen_precisions.append(test_precision)
    unseen_recalls.append(test_recall)

    # Print final test results
    logger(f"Final Test Results - Loss: {test_loss}, Accuracy: {test_accuracy}, Precision: {test_precision}, Recall: {test_recall}, F1 Score: {test_f1}", file=log_file_path)

    # Generate the confusion matrix
    cm = confusion_matrix(y_test, y_test_pred)
    logger(f"Confusion Matrix:\n {cm}", file=log_file_path)

# Calculate the overall average metrics
unseen_set_avg_f1 = np.mean(unseen_f1)
unseen_set_avg_loss = np.mean(unseen_losses)
unseen_set_avg_acc = np.mean(unseen_accuracies)
unseen_set_avg_precision = np.mean(unseen_precisions)
unseen_set_avg_recall = np.mean(unseen_recalls)

# Append averages to total lists
all_f1.append(unseen_set_avg_f1)
all_losses.append(unseen_set_avg_loss)
all_accuracies.append(unseen_set_avg_acc)
all_precisions.append(unseen_set_avg_precision)
all_recalls.append(unseen_set_avg_recall)

logger(f"\nFinal Average F1-Score across all UNSEEN TEST sets: {unseen_set_avg_f1}", file=log_file_path)
logger(f"\nFinal Average Loss across all UNSEEN TEST sets: {unseen_set_avg_loss}", file=log_file_path)
logger(f"\nFinal Average Accuracy across all UNSEEN TEST sets: {unseen_set_avg_acc}", file=log_file_path)
logger(f"\nFinal Average Precision across all UNSEEN TEST sets: {unseen_set_avg_precision}", file=log_file_path)
logger(f"\nFinal Average Recall across all UNSEEN TEST sets: {unseen_set_avg_recall}\n", file=log_file_path)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# outer_fold 1
# Train Set Group Distribution:
# 046A    45
# 103A    33
# 002B    30
# 020A    20
# 019A    17
# 057A    17
# 074A    16
# 097A    15
# 029A    15
# 097B    14
# 106A    13
# 002A    13
# 051A    12
# 055A    12
# 111A    12
# 116A    12
# 063A    11
# 028A    11
# 067A    11
# 014B    10
# 059A    10
# 025A    10
# 065A     9
# 005A     9
# 071A     9
# 033A     9
# 001A     9
# 013B     8
# 068A     8
# 117A     7
# 095A     7
# 027A     7
# 031A     7
# 036A     7
# 039A     6
# 007A     6
# 050A     5
# 094A     5
# 108A     5
# 008A     5
# 075A     5
# 021A     5
# 044A     5
# 109A     5
# 104A     4
# 003A     4
# 025C     4
# 026A     4
# 009A     4
# 045A     4
# 023B     4
# 060A     3
# 056A     3
# 014A     3
# 012A     3
# 105A     3
# 053A     3
# 061A     2
# 037A     2
# 093A     2
# 054A     2
# 035A     2
# 025B     2
# 011A     2
# 038A     2
# 087A     2
# 069A     2
# 032A     2
# 110A     1
# 090A     1
# 019B     1
# 004A     1
# 100A     1
# 049A     1
# 048A     1
# 026C     1
# 041A     1
# 092A     1
# 096A     1
# 064A     1
# 091A     1
# 073A     1
# 043A     1
# 026B     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 000A    39
# 047A    22
# 000B    19
# 101A    12
# 042A    11
# 040A    10
# 051B     9
# 072A     9
# 016A     9
# 022A     9
# 015A     7
# 023A     6
# 099A     6
# 070A     5
# 058A     3
# 010A     3
# 006A     3
# 113A     3
# 034A     3
# 062A     3
# 018A     2
# 052A     2
# 102A     2
# 076A     1
# 066A     1
# 088A     1
# 115A     1
# 024A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    241
# X    214
# F    136
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# F    95
# X    62
# M    45
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [033A, 001A, 103A, 071A, 097B, 028A, 019A, 074...
# kitten    [044A, 014B, 111A, 046A, 109A, 050A, 043A, 049...
# senior    [093A, 097A, 057A, 106A, 104A, 055A, 059A, 116...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [006A, 000A, 015A, 062A, 101A, 022A, 034A, 072...
# kitten                             [040A, 047A, 042A, 115A]
# senior                       [113A, 051B, 058A, 016A, 024A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 55, 'kitten': 12, 'senior': 17}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 19, 'kitten': 4, 'senior': 5}
# Unique Training/Validation Group IDs:
# ['001A' '002A' '002B' '003A' '004A' '005A' '007A' '008A' '009A' '011A'
#  '012A' '013B' '014A' '014B' '019A' '019B' '020A' '021A' '023B' '025A'
#  '025B' '025C' '026A' '026B' '026C' '027A' '028A' '029A' '031A' '032A'
#  '033A' '035A' '036A' '037A' '038A' '039A' '041A' '043A' '044A' '045A'
#  '046A' '048A' '049A' '050A' '051A' '053A' '054A' '055A' '056A' '057A'
#  '059A' '060A' '061A' '063A' '064A' '065A' '067A' '068A' '069A' '071A'
#  '073A' '074A' '075A' '087A' '090A' '091A' '092A' '093A' '094A' '095A'
#  '096A' '097A' '097B' '100A' '103A' '104A' '105A' '106A' '108A' '109A'
#  '110A' '111A' '116A' '117A']
# Unique Test Group IDs:
# ['000A' '000B' '006A' '010A' '015A' '016A' '018A' '022A' '023A' '024A'
#  '034A' '040A' '042A' '047A' '051B' '052A' '058A' '062A' '066A' '070A'
#  '072A' '076A' '088A' '099A' '101A' '102A' '113A' '115A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'000A'}
# Removed from Training/Validation Set:
# {'096A'}
# Moved to Test Set:
# {'096A'}
# Removed from Test Set
# {'000A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '001A' '002A' '002B' '003A' '004A' '005A' '007A' '008A' '009A'
#  '011A' '012A' '013B' '014A' '014B' '019A' '019B' '020A' '021A' '023B'
#  '025A' '025B' '025C' '026A' '026B' '026C' '027A' '028A' '029A' '031A'
#  '032A' '033A' '035A' '036A' '037A' '038A' '039A' '041A' '043A' '044A'
#  '045A' '046A' '048A' '049A' '050A' '051A' '053A' '054A' '055A' '056A'
#  '057A' '059A' '060A' '061A' '063A' '064A' '065A' '067A' '068A' '069A'
#  '071A' '073A' '074A' '075A' '087A' '090A' '091A' '092A' '093A' '094A'
#  '095A' '097A' '097B' '100A' '103A' '104A' '105A' '106A' '108A' '109A'
#  '110A' '111A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['000B' '006A' '010A' '015A' '016A' '018A' '022A' '023A' '024A' '034A'
#  '040A' '042A' '047A' '051B' '052A' '058A' '062A' '066A' '070A' '072A'
#  '076A' '088A' '096A' '099A' '101A' '102A' '113A' '115A']
# Length of X_train_val:
# 629
# Length of y_train_val:
# 629
# Length of groups_train_val:
# 629
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     376
# senior    124
# kitten     91
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     133
# kitten     44
# senior     25
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     414
# senior    124
# kitten     91
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     95
# kitten    44
# senior    25
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 828, 2: 620, 1: 455})
# Epoch 1/1500
# 30/30 [==============================] - 1s 4ms/step - loss: 0.4748 - accuracy: 0.8339
# Epoch 2/1500
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0519 - accuracy: 0.9848
# Epoch 3/1500
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0257 - accuracy: 0.9932
# Epoch 4/1500
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0177 - accuracy: 0.9942
# Epoch 5/1500
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0199 - accuracy: 0.9937
# Epoch 6/1500
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0087 - accuracy: 0.9979
# Epoch 7/1500
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0049 - accuracy: 0.9995
# Epoch 8/1500
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0057 - accuracy: 0.9979
# Epoch 9/1500
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0049 - accuracy: 0.9989
# Epoch 10/1500
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0057 - accuracy: 0.9974
# Epoch 11/1500
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0039 - accuracy: 0.9984
# Epoch 12/1500
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0054 - accuracy: 0.9989
# Epoch 13/1500
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 14/1500
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0024 - accuracy: 0.9995
# Epoch 15/1500
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 16/1500
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 17/1500
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0032 - accuracy: 0.9989
# Epoch 18/1500
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0024 - accuracy: 0.9995
# Epoch 19/1500
# 30/30 [==============================] - 0s 5ms/step - loss: 8.5652e-04 - accuracy: 1.0000
# Epoch 20/1500
# 30/30 [==============================] - 0s 4ms/step - loss: 9.6562e-04 - accuracy: 1.0000
# Epoch 21/1500
# 30/30 [==============================] - 0s 5ms/step - loss: 8.4448e-04 - accuracy: 1.0000
# Epoch 22/1500
# 30/30 [==============================] - 0s 5ms/step - loss: 9.7484e-04 - accuracy: 1.0000
# Epoch 23/1500
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0011 - accuracy: 0.9995
# Epoch 24/1500
# 30/30 [==============================] - 0s 5ms/step - loss: 7.0192e-04 - accuracy: 1.0000
# Epoch 25/1500
# 30/30 [==============================] - 0s 5ms/step - loss: 4.8781e-04 - accuracy: 1.0000
# Epoch 26/1500
# 30/30 [==============================] - 0s 5ms/step - loss: 5.6394e-04 - accuracy: 1.0000
# Epoch 27/1500
# 30/30 [==============================] - 0s 5ms/step - loss: 7.8342e-04 - accuracy: 0.9995
# Epoch 28/1500
# 30/30 [==============================] - 0s 5ms/step - loss: 8.9944e-04 - accuracy: 1.0000
# Epoch 29/1500
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 30/1500
# 30/30 [==============================] - 0s 5ms/step - loss: 3.8403e-04 - accuracy: 1.0000
# Epoch 31/1500
# 30/30 [==============================] - 0s 5ms/step - loss: 6.5222e-04 - accuracy: 1.0000
# Epoch 32/1500
# 30/30 [==============================] - 0s 4ms/step - loss: 5.8415e-04 - accuracy: 1.0000
# Epoch 33/1500
# 30/30 [==============================] - 0s 5ms/step - loss: 3.9019e-04 - accuracy: 1.0000
# Epoch 34/1500
# 30/30 [==============================] - 0s 5ms/step - loss: 2.1852e-04 - accuracy: 1.0000
# Epoch 35/1500
# 30/30 [==============================] - 0s 5ms/step - loss: 4.1297e-04 - accuracy: 1.0000
# Epoch 36/1500
# 30/30 [==============================] - 0s 5ms/step - loss: 2.1992e-04 - accuracy: 1.0000
# Epoch 37/1500
# 30/30 [==============================] - 0s 5ms/step - loss: 2.6252e-04 - accuracy: 1.0000
# Epoch 38/1500
# 30/30 [==============================] - 0s 5ms/step - loss: 2.1983e-04 - accuracy: 1.0000
# Epoch 39/1500
# 30/30 [==============================] - 0s 5ms/step - loss: 3.7001e-04 - accuracy: 1.0000
# Epoch 40/1500
# 30/30 [==============================] - 0s 5ms/step - loss: 3.8363e-04 - accuracy: 1.0000
# Epoch 41/1500
# 30/30 [==============================] - 0s 5ms/step - loss: 6.7454e-04 - accuracy: 1.0000
# Epoch 42/1500
# 30/30 [==============================] - 0s 5ms/step - loss: 6.3385e-04 - accuracy: 1.0000
# Epoch 43/1500
# 30/30 [==============================] - 0s 4ms/step - loss: 0.0045 - accuracy: 0.9984
# Epoch 44/1500
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0018 - accuracy: 0.9989
# Epoch 45/1500
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 46/1500
# 30/30 [==============================] - 0s 5ms/step - loss: 3.1715e-04 - accuracy: 1.0000
# Epoch 47/1500
# 30/30 [==============================] - 0s 5ms/step - loss: 2.9185e-04 - accuracy: 1.0000
# Epoch 48/1500
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0025 - accuracy: 0.9989
# Epoch 49/1500
# 25/30 [========================>.....] - ETA: 0s - loss: 0.0022 - accuracy: 0.9987  Restoring model weights from the end of the best epoch: 19.
# 30/30 [==============================] - 0s 5ms/step - loss: 0.0020 - accuracy: 0.9989
# Epoch 49: early stopping
# 6/6 [==============================] - 0s 1ms/step - loss: 3.1450 - accuracy: 0.6280
# 6/6 [==============================] - 1s 1ms/step
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Majority Vote Accuracy for cat_id for this fold: 0.75 (21/28)
# Before appending - Cat IDs: 0, Predictions: 0, Actuals: 0, Gender: 0
# After appending - Cat IDs: 164, Predictions: 164, Actuals: 164, Gender: 164
# Final Test Results - Loss: 3.145040273666382, Accuracy: 0.6280487775802612, Precision: 0.6339920948616601, Recall: 0.46508771929824566, F1 Score: 0.4814707047194135
# Confusion Matrix:
#  [[86  4  5]
#  [33 11  0]
#  [19  0  6]]
# outer_fold 2
# Train Set Group Distribution:
# 046A    45
# 000A    39
# 002B    30
# 047A    22
# 020A    20
# 000B    19
# 019A    17
# 029A    15
# 002A    13
# 101A    12
# 055A    12
# 067A    11
# 028A    11
# 063A    11
# 042A    11
# 040A    10
# 059A    10
# 072A     9
# 016A     9
# 065A     9
# 051B     9
# 071A     9
# 001A     9
# 005A     9
# 022A     9
# 013B     8
# 068A     8
# 036A     7
# 117A     7
# 015A     7
# 027A     7
# 095A     7
# 099A     6
# 007A     6
# 023A     6
# 039A     6
# 108A     5
# 075A     5
# 070A     5
# 109A     5
# 050A     5
# 026A     4
# 104A     4
# 025C     4
# 023B     4
# 058A     3
# 010A     3
# 053A     3
# 060A     3
# 006A     3
# 105A     3
# 062A     3
# 034A     3
# 113A     3
# 014A     3
# 018A     2
# 037A     2
# 011A     2
# 102A     2
# 052A     2
# 061A     2
# 087A     2
# 093A     2
# 054A     2
# 115A     1
# 019B     1
# 100A     1
# 090A     1
# 024A     1
# 110A     1
# 066A     1
# 088A     1
# 004A     1
# 048A     1
# 041A     1
# 092A     1
# 049A     1
# 064A     1
# 043A     1
# 076A     1
# 096A     1
# 026B     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 103A    33
# 057A    17
# 074A    16
# 097A    15
# 097B    14
# 106A    13
# 111A    12
# 051A    12
# 116A    12
# 014B    10
# 025A    10
# 033A     9
# 031A     7
# 044A     5
# 021A     5
# 094A     5
# 008A     5
# 045A     4
# 003A     4
# 009A     4
# 012A     3
# 056A     3
# 035A     2
# 032A     2
# 069A     2
# 038A     2
# 025B     2
# 073A     1
# 026C     1
# 091A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    192
# X    189
# F    181
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# M    94
# X    87
# F    50
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [006A, 000A, 015A, 001A, 071A, 028A, 019A, 067...
# kitten    [040A, 046A, 047A, 042A, 109A, 050A, 043A, 049...
# senior    [093A, 104A, 055A, 059A, 113A, 051B, 054A, 117...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [033A, 103A, 097B, 074A, 091A, 009A, 038A, 025...
# kitten                             [044A, 014B, 111A, 045A]
# senior           [097A, 057A, 106A, 116A, 056A, 051A, 094A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 55, 'kitten': 12, 'senior': 15}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 19, 'kitten': 4, 'senior': 7}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '004A' '005A' '006A' '007A' '010A'
#  '011A' '013B' '014A' '015A' '016A' '018A' '019A' '019B' '020A' '022A'
#  '023A' '023B' '024A' '025C' '026A' '026B' '027A' '028A' '029A' '034A'
#  '036A' '037A' '039A' '040A' '041A' '042A' '043A' '046A' '047A' '048A'
#  '049A' '050A' '051B' '052A' '053A' '054A' '055A' '058A' '059A' '060A'
#  '061A' '062A' '063A' '064A' '065A' '066A' '067A' '068A' '070A' '071A'
#  '072A' '075A' '076A' '087A' '088A' '090A' '092A' '093A' '095A' '096A'
#  '099A' '100A' '101A' '102A' '104A' '105A' '108A' '109A' '110A' '113A'
#  '115A' '117A']
# Unique Test Group IDs:
# ['003A' '008A' '009A' '012A' '014B' '021A' '025A' '025B' '026C' '031A'
#  '032A' '033A' '035A' '038A' '044A' '045A' '051A' '056A' '057A' '069A'
#  '073A' '074A' '091A' '094A' '097A' '097B' '103A' '106A' '111A' '116A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '004A' '005A' '006A' '007A' '010A'
#  '011A' '013B' '014A' '015A' '016A' '018A' '019A' '019B' '020A' '022A'
#  '023A' '023B' '024A' '025C' '026A' '026B' '027A' '028A' '029A' '034A'
#  '036A' '037A' '039A' '040A' '041A' '042A' '043A' '046A' '047A' '048A'
#  '049A' '050A' '051B' '052A' '053A' '054A' '055A' '058A' '059A' '060A'
#  '061A' '062A' '063A' '064A' '065A' '066A' '067A' '068A' '070A' '071A'
#  '072A' '075A' '076A' '087A' '088A' '090A' '092A' '093A' '095A' '096A'
#  '099A' '100A' '101A' '102A' '104A' '105A' '108A' '109A' '110A' '113A'
#  '115A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['003A' '008A' '009A' '012A' '014B' '021A' '025A' '025B' '026C' '031A'
#  '032A' '033A' '035A' '038A' '044A' '045A' '051A' '056A' '057A' '069A'
#  '073A' '074A' '091A' '094A' '097A' '097B' '103A' '106A' '111A' '116A']
# Length of X_train_val:
# 562
# Length of y_train_val:
# 562
# Length of groups_train_val:
# 562
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     386
# kitten    104
# senior     72
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     123
# senior     77
# kitten     31
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     386
# kitten    104
# senior     72
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     123
# senior     77
# kitten     31
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 772, 1: 520, 2: 360})
# Epoch 1/1500
# 26/26 [==============================] - 1s 4ms/step - loss: 0.3812 - accuracy: 0.8620
# Epoch 2/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0528 - accuracy: 0.9794
# Epoch 3/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0200 - accuracy: 0.9927
# Epoch 4/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0170 - accuracy: 0.9952
# Epoch 5/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0118 - accuracy: 0.9976
# Epoch 6/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0041 - accuracy: 1.0000
# Epoch 7/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 8/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0041 - accuracy: 0.9988
# Epoch 9/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0037 - accuracy: 0.9988
# Epoch 10/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0052 - accuracy: 0.9988
# Epoch 11/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0031 - accuracy: 0.9994
# Epoch 12/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 13/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 14/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 9.4240e-04 - accuracy: 1.0000
# Epoch 15/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0039 - accuracy: 0.9988
# Epoch 16/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0038 - accuracy: 0.9988
# Epoch 17/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0050 - accuracy: 0.9988
# Epoch 18/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 19/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0025 - accuracy: 0.9994
# Epoch 20/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 9.4756e-04 - accuracy: 1.0000
# Epoch 21/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 7.7583e-04 - accuracy: 1.0000
# Epoch 22/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0039 - accuracy: 0.9988
# Epoch 23/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0016 - accuracy: 0.9994
# Epoch 24/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 25/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 26/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0022 - accuracy: 0.9988
# Epoch 27/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0047 - accuracy: 0.9988
# Epoch 28/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0019 - accuracy: 0.9994
# Epoch 29/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 7.9286e-04 - accuracy: 1.0000
# Epoch 30/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0031 - accuracy: 0.9988
# Epoch 31/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0016 - accuracy: 0.9994
# Epoch 32/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 7.2184e-04 - accuracy: 1.0000
# Epoch 33/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0010 - accuracy: 0.9994
# Epoch 34/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 7.8323e-04 - accuracy: 1.0000
# Epoch 35/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0030 - accuracy: 0.9982
# Epoch 36/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 37/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 6.2879e-04 - accuracy: 1.0000
# Epoch 38/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 6.7216e-04 - accuracy: 1.0000
# Epoch 39/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 5.0037e-04 - accuracy: 1.0000
# Epoch 40/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0010 - accuracy: 0.9994
# Epoch 41/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0022 - accuracy: 0.9994
# Epoch 42/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0021 - accuracy: 0.9994
# Epoch 43/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0024 - accuracy: 0.9994
# Epoch 44/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 2.8387e-04 - accuracy: 1.0000
# Epoch 45/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 4.6938e-04 - accuracy: 1.0000
# Epoch 46/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 2.7373e-04 - accuracy: 1.0000
# Epoch 47/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 3.9863e-04 - accuracy: 1.0000
# Epoch 48/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 2.5036e-04 - accuracy: 1.0000
# Epoch 49/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 2.2803e-04 - accuracy: 1.0000
# Epoch 50/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 1.1083e-04 - accuracy: 1.0000
# Epoch 51/1500
# 24/26 [==========================>...] - ETA: 0s - loss: 3.7840e-04 - accuracy: 1.0000Restoring model weights from the end of the best epoch: 21.
# 26/26 [==============================] - 0s 5ms/step - loss: 3.5370e-04 - accuracy: 1.0000
# Epoch 51: early stopping
# 8/8 [==============================] - 0s 1ms/step - loss: 2.3121 - accuracy: 0.6580
# 8/8 [==============================] - 0s 990us/step
# Majority Vote Accuracy for cat_id for this fold: 0.73 (22/30)
# Before appending - Cat IDs: 164, Predictions: 164, Actuals: 164, Gender: 164
# After appending - Cat IDs: 395, Predictions: 395, Actuals: 395, Gender: 395
# Final Test Results - Loss: 2.3120734691619873, Accuracy: 0.6580086350440979, Precision: 0.7421409041324889, Recall: 0.5922572924933271, F1 Score: 0.6025967311880481
# Confusion Matrix:
#  [[116   3   4]
#  [ 10  19   2]
#  [ 60   0  17]]
# outer_fold 3
# Train Set Group Distribution:
# 000A    39
# 103A    33
# 047A    22
# 000B    19
# 057A    17
# 074A    16
# 029A    15
# 097A    15
# 097B    14
# 002A    13
# 106A    13
# 101A    12
# 055A    12
# 051A    12
# 111A    12
# 116A    12
# 028A    11
# 067A    11
# 042A    11
# 025A    10
# 059A    10
# 040A    10
# 014B    10
# 016A     9
# 072A     9
# 051B     9
# 033A     9
# 001A     9
# 065A     9
# 022A     9
# 013B     8
# 031A     7
# 015A     7
# 007A     6
# 099A     6
# 023A     6
# 039A     6
# 094A     5
# 008A     5
# 050A     5
# 070A     5
# 021A     5
# 044A     5
# 109A     5
# 003A     4
# 026A     4
# 023B     4
# 009A     4
# 104A     4
# 045A     4
# 056A     3
# 058A     3
# 012A     3
# 006A     3
# 105A     3
# 113A     3
# 010A     3
# 034A     3
# 062A     3
# 035A     2
# 061A     2
# 102A     2
# 052A     2
# 025B     2
# 032A     2
# 038A     2
# 018A     2
# 069A     2
# 054A     2
# 064A     1
# 088A     1
# 090A     1
# 091A     1
# 110A     1
# 115A     1
# 004A     1
# 049A     1
# 066A     1
# 076A     1
# 026C     1
# 043A     1
# 073A     1
# 092A     1
# 024A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 046A    45
# 002B    30
# 020A    20
# 019A    17
# 063A    11
# 071A     9
# 005A     9
# 068A     8
# 117A     7
# 095A     7
# 027A     7
# 036A     7
# 075A     5
# 108A     5
# 025C     4
# 053A     3
# 060A     3
# 014A     3
# 011A     2
# 037A     2
# 093A     2
# 087A     2
# 041A     1
# 048A     1
# 096A     1
# 019B     1
# 100A     1
# 026B     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# F    208
# M    200
# X    171
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    105
# M     86
# F     23
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [006A, 000A, 033A, 015A, 001A, 103A, 097B, 028...
# kitten    [044A, 014B, 111A, 040A, 047A, 042A, 109A, 050...
# senior    [097A, 057A, 106A, 104A, 055A, 059A, 113A, 116...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [071A, 019A, 020A, 002B, 095A, 005A, 063A, 027...
# kitten                                   [046A, 041A, 048A]
# senior                             [093A, 117A, 108A, 011A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 53, 'kitten': 13, 'senior': 18}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 21, 'kitten': 3, 'senior': 4}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '003A' '004A' '006A' '007A' '008A' '009A'
#  '010A' '012A' '013B' '014B' '015A' '016A' '018A' '021A' '022A' '023A'
#  '023B' '024A' '025A' '025B' '026A' '026C' '028A' '029A' '031A' '032A'
#  '033A' '034A' '035A' '038A' '039A' '040A' '042A' '043A' '044A' '045A'
#  '047A' '049A' '050A' '051A' '051B' '052A' '054A' '055A' '056A' '057A'
#  '058A' '059A' '061A' '062A' '064A' '065A' '066A' '067A' '069A' '070A'
#  '072A' '073A' '074A' '076A' '088A' '090A' '091A' '092A' '094A' '097A'
#  '097B' '099A' '101A' '102A' '103A' '104A' '105A' '106A' '109A' '110A'
#  '111A' '113A' '115A' '116A']
# Unique Test Group IDs:
# ['002B' '005A' '011A' '014A' '019A' '019B' '020A' '025C' '026B' '027A'
#  '036A' '037A' '041A' '046A' '048A' '053A' '060A' '063A' '068A' '071A'
#  '075A' '087A' '093A' '095A' '096A' '100A' '108A' '117A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'046A'}
# Removed from Training/Validation Set:
# {'014B'}
# Moved to Test Set:
# {'014B'}
# Removed from Test Set
# {'046A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '003A' '004A' '006A' '007A' '008A' '009A'
#  '010A' '012A' '013B' '015A' '016A' '018A' '021A' '022A' '023A' '023B'
#  '024A' '025A' '025B' '026A' '026C' '028A' '029A' '031A' '032A' '033A'
#  '034A' '035A' '038A' '039A' '040A' '042A' '043A' '044A' '045A' '046A'
#  '047A' '049A' '050A' '051A' '051B' '052A' '054A' '055A' '056A' '057A'
#  '058A' '059A' '061A' '062A' '064A' '065A' '066A' '067A' '069A' '070A'
#  '072A' '073A' '074A' '076A' '088A' '090A' '091A' '092A' '094A' '097A'
#  '097B' '099A' '101A' '102A' '103A' '104A' '105A' '106A' '109A' '110A'
#  '111A' '113A' '115A' '116A']
# AFTER SWAP - Unique Test Group IDs:
# ['002B' '005A' '011A' '014A' '014B' '019A' '019B' '020A' '025C' '026B'
#  '027A' '036A' '037A' '041A' '048A' '053A' '060A' '063A' '068A' '071A'
#  '075A' '087A' '093A' '095A' '096A' '100A' '108A' '117A']
# Length of X_train_val:
# 614
# Length of y_train_val:
# 614
# Length of groups_train_val:
# 614
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     358
# senior    133
# kitten     88
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     151
# kitten     47
# senior     16
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     358
# senior    133
# kitten    123
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     151
# senior     16
# kitten     12
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 716, 2: 665, 1: 615})
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Epoch 1/1500
# 32/32 [==============================] - 1s 4ms/step - loss: 0.4132 - accuracy: 0.8577
# Epoch 2/1500
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0801 - accuracy: 0.9760
# Epoch 3/1500
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0366 - accuracy: 0.9885
# Epoch 4/1500
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0147 - accuracy: 0.9960
# Epoch 5/1500
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0103 - accuracy: 0.9970
# Epoch 6/1500
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0078 - accuracy: 0.9985
# Epoch 7/1500
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0095 - accuracy: 0.9975
# Epoch 8/1500
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0059 - accuracy: 0.9980
# Epoch 9/1500
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0095 - accuracy: 0.9985
# Epoch 10/1500
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0066 - accuracy: 0.9975
# Epoch 11/1500
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0062 - accuracy: 0.9985
# Epoch 12/1500
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0028 - accuracy: 0.9990
# Epoch 13/1500
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0033 - accuracy: 0.9990
# Epoch 14/1500
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0032 - accuracy: 0.9990
# Epoch 15/1500
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0035 - accuracy: 0.9990
# Epoch 16/1500
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0022 - accuracy: 0.9995
# Epoch 17/1500
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 18/1500
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0035 - accuracy: 0.9980
# Epoch 19/1500
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0026 - accuracy: 0.9995
# Epoch 20/1500
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0036 - accuracy: 0.9990
# Epoch 21/1500
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 22/1500
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0028 - accuracy: 0.9990
# Epoch 23/1500
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0026 - accuracy: 0.9990
# Epoch 24/1500
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0039 - accuracy: 0.9985
# Epoch 25/1500
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0012 - accuracy: 0.9995
# Epoch 26/1500
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0015 - accuracy: 0.9995
# Epoch 27/1500
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0039 - accuracy: 0.9985
# Epoch 28/1500
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0111 - accuracy: 0.9960
# Epoch 29/1500
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0027 - accuracy: 0.9995
# Epoch 30/1500
# 32/32 [==============================] - 0s 4ms/step - loss: 6.9667e-04 - accuracy: 1.0000
# Epoch 31/1500
# 32/32 [==============================] - 0s 4ms/step - loss: 6.5824e-04 - accuracy: 1.0000
# Epoch 32/1500
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 33/1500
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 34/1500
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0015 - accuracy: 0.9995
# Epoch 35/1500
# 32/32 [==============================] - 0s 4ms/step - loss: 6.0946e-04 - accuracy: 1.0000
# Epoch 36/1500
# 32/32 [==============================] - 0s 4ms/step - loss: 5.8426e-04 - accuracy: 1.0000
# Epoch 37/1500
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0037 - accuracy: 0.9980
# Epoch 38/1500
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0030 - accuracy: 0.9990
# Epoch 39/1500
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0054 - accuracy: 0.9990
# Epoch 40/1500
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0030 - accuracy: 0.9990
# Epoch 41/1500
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0045 - accuracy: 0.9985
# Epoch 42/1500
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 43/1500
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0082 - accuracy: 0.9970
# Epoch 44/1500
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0063 - accuracy: 0.9980
# Epoch 45/1500
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0043 - accuracy: 0.9985
# Epoch 46/1500
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0057 - accuracy: 0.9985
# Epoch 47/1500
# 32/32 [==============================] - 0s 4ms/step - loss: 9.5004e-04 - accuracy: 1.0000
# Epoch 48/1500
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0032 - accuracy: 0.9985
# Epoch 49/1500
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0018 - accuracy: 0.9995
# Epoch 50/1500
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0013 - accuracy: 0.9995
# Epoch 51/1500
# 32/32 [==============================] - 0s 5ms/step - loss: 6.9017e-04 - accuracy: 1.0000
# Epoch 52/1500
# 32/32 [==============================] - 0s 5ms/step - loss: 7.7499e-04 - accuracy: 1.0000
# Epoch 53/1500
# 32/32 [==============================] - 0s 5ms/step - loss: 9.4357e-04 - accuracy: 1.0000
# Epoch 54/1500
# 32/32 [==============================] - 0s 5ms/step - loss: 6.5116e-04 - accuracy: 1.0000
# Epoch 55/1500
# 23/32 [====================>.........] - ETA: 0s - loss: 2.6525e-04 - accuracy: 1.0000Restoring model weights from the end of the best epoch: 25.
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0015 - accuracy: 0.9995
# Epoch 55: early stopping
# 6/6 [==============================] - 0s 1ms/step - loss: 1.7171 - accuracy: 0.7095
# 6/6 [==============================] - 0s 956us/step
# Majority Vote Accuracy for cat_id for this fold: 0.68 (19/28)
# Before appending - Cat IDs: 395, Predictions: 395, Actuals: 395, Gender: 395
# After appending - Cat IDs: 574, Predictions: 574, Actuals: 574, Gender: 574
# Final Test Results - Loss: 1.7171061038970947, Accuracy: 0.7094972133636475, Precision: 0.6028911564625851, Recall: 0.6269775570272259, F1 Score: 0.5774916350562108
# Confusion Matrix:
#  [[111   3  37]
#  [  2   7   3]
#  [  7   0   9]]
# outer_fold 4
# Train Set Group Distribution:
# 046A    45
# 000A    39
# 103A    33
# 002B    30
# 047A    22
# 020A    20
# 000B    19
# 057A    17
# 019A    17
# 074A    16
# 097A    15
# 097B    14
# 106A    13
# 101A    12
# 051A    12
# 116A    12
# 111A    12
# 042A    11
# 063A    11
# 040A    10
# 014B    10
# 025A    10
# 071A     9
# 022A     9
# 033A     9
# 051B     9
# 005A     9
# 072A     9
# 016A     9
# 068A     8
# 117A     7
# 031A     7
# 036A     7
# 095A     7
# 015A     7
# 027A     7
# 099A     6
# 023A     6
# 070A     5
# 044A     5
# 094A     5
# 075A     5
# 008A     5
# 021A     5
# 108A     5
# 045A     4
# 025C     4
# 003A     4
# 009A     4
# 053A     3
# 056A     3
# 058A     3
# 010A     3
# 060A     3
# 012A     3
# 006A     3
# 062A     3
# 113A     3
# 014A     3
# 034A     3
# 052A     2
# 093A     2
# 025B     2
# 037A     2
# 102A     2
# 011A     2
# 035A     2
# 018A     2
# 069A     2
# 038A     2
# 032A     2
# 087A     2
# 026C     1
# 024A     1
# 100A     1
# 076A     1
# 115A     1
# 073A     1
# 019B     1
# 091A     1
# 088A     1
# 048A     1
# 066A     1
# 041A     1
# 096A     1
# 026B     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 029A    15
# 002A    13
# 055A    12
# 067A    11
# 028A    11
# 059A    10
# 001A     9
# 065A     9
# 013B     8
# 039A     6
# 007A     6
# 109A     5
# 050A     5
# 023B     4
# 104A     4
# 026A     4
# 105A     3
# 061A     2
# 054A     2
# 064A     1
# 049A     1
# 092A     1
# 004A     1
# 043A     1
# 110A     1
# 090A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    254
# M    225
# F    168
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# F    63
# M    61
# X    22
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [006A, 000A, 033A, 015A, 103A, 071A, 097B, 019...
# kitten    [044A, 014B, 111A, 040A, 046A, 047A, 042A, 041...
# senior    [093A, 097A, 057A, 106A, 113A, 116A, 051B, 117...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [001A, 028A, 067A, 029A, 065A, 002A, 039A, 013...
# kitten                       [109A, 050A, 043A, 049A, 110A]
# senior                 [104A, 055A, 059A, 054A, 061A, 090A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 59, 'kitten': 11, 'senior': 16}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 15, 'kitten': 5, 'senior': 6}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '002B' '003A' '005A' '006A' '008A' '009A' '010A' '011A'
#  '012A' '014A' '014B' '015A' '016A' '018A' '019A' '019B' '020A' '021A'
#  '022A' '023A' '024A' '025A' '025B' '025C' '026B' '026C' '027A' '031A'
#  '032A' '033A' '034A' '035A' '036A' '037A' '038A' '040A' '041A' '042A'
#  '044A' '045A' '046A' '047A' '048A' '051A' '051B' '052A' '053A' '056A'
#  '057A' '058A' '060A' '062A' '063A' '066A' '068A' '069A' '070A' '071A'
#  '072A' '073A' '074A' '075A' '076A' '087A' '088A' '091A' '093A' '094A'
#  '095A' '096A' '097A' '097B' '099A' '100A' '101A' '102A' '103A' '106A'
#  '108A' '111A' '113A' '115A' '116A' '117A']
# Unique Test Group IDs:
# ['001A' '002A' '004A' '007A' '013B' '023B' '026A' '028A' '029A' '039A'
#  '043A' '049A' '050A' '054A' '055A' '059A' '061A' '064A' '065A' '067A'
#  '090A' '092A' '104A' '105A' '109A' '110A']
# No common groups found between train and test sets.
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '002B' '003A' '005A' '006A' '008A' '009A' '010A' '011A'
#  '012A' '014A' '014B' '015A' '016A' '018A' '019A' '019B' '020A' '021A'
#  '022A' '023A' '024A' '025A' '025B' '025C' '026B' '026C' '027A' '031A'
#  '032A' '033A' '034A' '035A' '036A' '037A' '038A' '040A' '041A' '042A'
#  '044A' '045A' '046A' '047A' '048A' '051A' '051B' '052A' '053A' '056A'
#  '057A' '058A' '060A' '062A' '063A' '066A' '068A' '069A' '070A' '071A'
#  '072A' '073A' '074A' '075A' '076A' '087A' '088A' '091A' '093A' '094A'
#  '095A' '096A' '097A' '097B' '099A' '100A' '101A' '102A' '103A' '106A'
#  '108A' '111A' '113A' '115A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['001A' '002A' '004A' '007A' '013B' '023B' '026A' '028A' '029A' '039A'
#  '043A' '049A' '050A' '054A' '055A' '059A' '061A' '064A' '065A' '067A'
#  '090A' '092A' '104A' '105A' '109A' '110A']
# Length of X_train_val:
# 647
# Length of y_train_val:
# 647
# Length of groups_train_val:
# 647
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     407
# kitten    122
# senior    118
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     102
# senior     31
# kitten     13
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     407
# kitten    122
# senior    118
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     102
# senior     31
# kitten     13
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 814, 1: 610, 2: 590})
# Epoch 1/1500
# 32/32 [==============================] - 1s 4ms/step - loss: 0.4186 - accuracy: 0.8585
# Epoch 2/1500
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0549 - accuracy: 0.9816
# Epoch 3/1500
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0270 - accuracy: 0.9916
# Epoch 4/1500
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0125 - accuracy: 0.9975
# Epoch 5/1500
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0106 - accuracy: 0.9980
# Epoch 6/1500
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0051 - accuracy: 0.9995
# Epoch 7/1500
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0048 - accuracy: 0.9990
# Epoch 8/1500
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0051 - accuracy: 0.9975
# Epoch 9/1500
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0040 - accuracy: 0.9990
# Epoch 10/1500
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 11/1500
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 12/1500
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0018 - accuracy: 0.9995
# Epoch 13/1500
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 14/1500
# 32/32 [==============================] - 0s 5ms/step - loss: 7.1936e-04 - accuracy: 1.0000
# Epoch 15/1500
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 16/1500
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 17/1500
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 18/1500
# 32/32 [==============================] - 0s 5ms/step - loss: 6.8659e-04 - accuracy: 1.0000
# Epoch 19/1500
# 32/32 [==============================] - 0s 5ms/step - loss: 5.6512e-04 - accuracy: 1.0000
# Epoch 20/1500
# 32/32 [==============================] - 0s 5ms/step - loss: 7.2721e-04 - accuracy: 1.0000
# Epoch 21/1500
# 32/32 [==============================] - 0s 5ms/step - loss: 4.0804e-04 - accuracy: 1.0000
# Epoch 22/1500
# 32/32 [==============================] - 0s 5ms/step - loss: 9.8896e-04 - accuracy: 1.0000
# Epoch 23/1500
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0070 - accuracy: 0.9990
# Epoch 24/1500
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0034 - accuracy: 0.9985
# Epoch 25/1500
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 26/1500
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 27/1500
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0047 - accuracy: 0.9980
# Epoch 28/1500
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0015 - accuracy: 0.9995
# Epoch 29/1500
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0024 - accuracy: 0.9995
# Epoch 30/1500
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0045 - accuracy: 0.9990
# Epoch 31/1500
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0032 - accuracy: 0.9980
# Epoch 32/1500
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0013 - accuracy: 0.9995
# Epoch 33/1500
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0017 - accuracy: 0.9995
# Epoch 34/1500
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 35/1500
# 32/32 [==============================] - 0s 5ms/step - loss: 5.4193e-04 - accuracy: 1.0000
# Epoch 36/1500
# 32/32 [==============================] - 0s 5ms/step - loss: 6.4120e-04 - accuracy: 1.0000
# Epoch 37/1500
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0014 - accuracy: 0.9995
# Epoch 38/1500
# 32/32 [==============================] - 0s 5ms/step - loss: 6.5301e-04 - accuracy: 1.0000
# Epoch 39/1500
# 32/32 [==============================] - 0s 5ms/step - loss: 9.4694e-04 - accuracy: 0.9995
# Epoch 40/1500
# 32/32 [==============================] - 0s 5ms/step - loss: 9.0811e-04 - accuracy: 1.0000
# Epoch 41/1500
# 32/32 [==============================] - 0s 5ms/step - loss: 5.4990e-04 - accuracy: 1.0000
# Epoch 42/1500
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0014 - accuracy: 0.9995
# Epoch 43/1500
# 32/32 [==============================] - 0s 5ms/step - loss: 3.8825e-04 - accuracy: 1.0000
# Epoch 44/1500
# 24/32 [=====================>........] - ETA: 0s - loss: 7.7847e-04 - accuracy: 0.9993Restoring model weights from the end of the best epoch: 14.
# 32/32 [==============================] - 0s 5ms/step - loss: 6.3942e-04 - accuracy: 0.9995
# Epoch 44: early stopping
# 5/5 [==============================] - 0s 1ms/step - loss: 1.4050 - accuracy: 0.7740
# 5/5 [==============================] - 0s 979us/step
# Majority Vote Accuracy for cat_id for this fold: 0.77 (20/26)
# Before appending - Cat IDs: 574, Predictions: 574, Actuals: 574, Gender: 574
# After appending - Cat IDs: 720, Predictions: 720, Actuals: 720, Gender: 720
# Final Test Results - Loss: 1.4049906730651855, Accuracy: 0.7739726305007935, Precision: 0.7408831908831909, Recall: 0.6231936943511897, F1 Score: 0.6651608754751382
# Confusion Matrix:
#  [[93  2  7]
#  [ 6  7  0]
#  [18  0 13]]
#
# Final Average F1-Score across all UNSEEN TEST sets: 0.5816799866097027
#
# Final Average Loss across all UNSEEN TEST sets: 2.1448026299476624
#
# Final Average Accuracy across all UNSEEN TEST sets: 0.6923818141222
#
# Final Average Precision across all UNSEEN TEST sets: 0.6799768365849812
#
# Final Average Recall across all UNSEEN TEST sets: 0.576879065792497

# %%
seed_5_folds_values = (unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1)

# Plotting all fold metrics|
seed_5_folds_plot = plot_all_metrics(unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1, "Folds", "Fold Number")

# %% [markdown]
# ## Majority Voting on Total Entries per cat_id

# %%
# Debugging print statements
print(f'Checking - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
# Out:
# Checking - Cat IDs: 720, Predictions: 720, Actuals: 720, Gender: 720

# %%
# Create results df
full_results = pd.DataFrame({
    'cat_id': all_cat_ids,
    'predicted_age_group': all_predicted_age_groups,
    'actual_age_group': all_actual_age_groups,
    'all_gender': all_gender
})

# create a correct majority prediction column
full_results['correct'] = full_results['predicted_age_group'] == full_results['actual_age_group']

# %%
# Group by cat_id and aggregate predicted age groups
majority_votes = full_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first()

# Calculate the accuracy of majority voting
correct_predictions = (majority_votes == actual_groups).sum()
total_cats = len(actual_groups)
majority_vote_accuracy = correct_predictions / total_cats

logger(f"Overall Majority Vote Accuracy for cat_id: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

# store for final evaluation 
all_majority_vote_accuracies.append(majority_vote_accuracy)
# Out:
# Overall Majority Vote Accuracy for cat_id: 0.73 (80/110)

# %%
# Detailed df with predictions, actual labels, and comparison including majority vote
detailed_results = full_results.groupby('cat_id').apply(
    lambda x: pd.Series({
        'Predictions': list(x['predicted_age_group']),
        'Majority Vote': x['predicted_age_group'].mode()[0],
        'Actual Age Group': x['actual_age_group'].iloc[0],
        'Correct Majority Vote': x['predicted_age_group'].mode()[0] == x['actual_age_group'].iloc[0]
    })
).reset_index()

# Convert to DataFrame for better formatting and display
detailed_results = pd.DataFrame(detailed_results)

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 10)
pd.set_option('display.width', 1000)

sorted_detailed_results = detailed_results.sort_values(by='Correct Majority Vote', ascending=False)

# Display the sorted DataFrame
sorted_detailed_results
# Out:
#     cat_id                                        Predictions Majority Vote Actual Age Group  Correct Majority Vote
# 0     000B  [adult, senior, adult, adult, adult, adult, ad...         adult            adult                   True
# 44    038A                                    [kitten, adult]         adult            adult                   True
# 78    072A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 76    070A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 75    069A                                     [adult, adult]         adult            adult                   True
# 73    067A  [adult, adult, adult, kitten, adult, adult, ad...         adult            adult                   True
# 72    066A                                            [adult]         adult            adult                   True
# 71    065A  [senior, adult, adult, adult, adult, senior, a...         adult            adult                   True
# 70    064A                                            [adult]         adult            adult                   True
# 69    063A  [adult, adult, senior, senior, senior, senior,...         adult            adult                   True
# 68    062A                              [adult, adult, adult]         adult            adult                   True
# 66    060A                             [adult, kitten, adult]         adult            adult                   True
# 65    059A  [adult, adult, senior, senior, senior, adult, ...        senior           senior                   True
# 64    058A                           [senior, senior, senior]        senior           senior                   True
# 1     001A  [adult, senior, adult, adult, adult, adult, ad...         adult            adult                   True
# 54    049A                                           [kitten]        kitten           kitten                   True
# 53    048A                                           [kitten]        kitten           kitten                   True
# 50    044A           [kitten, kitten, kitten, kitten, kitten]        kitten           kitten                   True
# 49    043A                                           [kitten]        kitten           kitten                   True
# 47    041A                                           [kitten]        kitten           kitten                   True
# 46    040A  [kitten, kitten, kitten, kitten, kitten, kitte...        kitten           kitten                   True
# 79    073A                                            [adult]         adult            adult                   True
# 80    074A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 81    075A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 96    101A  [adult, adult, adult, adult, senior, adult, ad...         adult            adult                   True
# 107   115A                                           [kitten]        kitten           kitten                   True
# 106   113A                            [adult, senior, senior]        senior           senior                   True
# 105   111A  [adult, senior, kitten, kitten, kitten, kitten...        kitten           kitten                   True
# 104   110A                                           [kitten]        kitten           kitten                   True
# 102   108A            [senior, adult, senior, senior, senior]        senior           senior                   True
# 100   105A                              [adult, adult, adult]         adult            adult                   True
# 98    103A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 97    102A                                    [adult, senior]         adult            adult                   True
# 95    100A                                            [adult]         adult            adult                   True
# 83    087A                                     [adult, adult]         adult            adult                   True
# 94    099A        [adult, adult, adult, kitten, adult, adult]         adult            adult                   True
# 93    097B  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 91    096A                                     [adult, adult]         adult            adult                   True
# 89    094A           [senior, senior, senior, senior, senior]        senior           senior                   True
# 87    092A                                            [adult]         adult            adult                   True
# 86    091A                                            [adult]         adult            adult                   True
# 85    090A                                           [senior]        senior           senior                   True
# 84    088A                                            [adult]         adult            adult                   True
# 45    039A         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 55    050A            [adult, kitten, kitten, kitten, kitten]        kitten           kitten                   True
# 43    037A                                    [senior, adult]         adult            adult                   True
# 25    023A         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 32    026B                                            [adult]         adult            adult                   True
# 31    026A                       [adult, adult, adult, adult]         adult            adult                   True
# 10    009A                      [adult, adult, senior, adult]         adult            adult                   True
# 29    025B                                    [adult, senior]         adult            adult                   True
# 28    025A  [adult, adult, adult, senior, adult, adult, ad...         adult            adult                   True
# 11    010A                              [adult, adult, adult]         adult            adult                   True
# 12    011A                                   [senior, senior]        senior           senior                   True
# 26    023B                       [adult, adult, adult, adult]         adult            adult                   True
# 42    036A  [adult, adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 15    014A                              [adult, adult, adult]         adult            adult                   True
# 24    022A  [adult, adult, adult, kitten, adult, adult, ki...         adult            adult                   True
# 23    021A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 22    020A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 13    012A                              [adult, adult, adult]         adult            adult                   True
# 20    019A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 19    018A                                     [adult, adult]         adult            adult                   True
# 14    013B  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 17    015A  [adult, adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 9     008A               [adult, adult, adult, kitten, adult]         adult            adult                   True
# 33    026C                                            [adult]         adult            adult                   True
# 34    027A  [adult, adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 35    028A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 41    035A                                     [adult, adult]         adult            adult                   True
# 40    034A                              [adult, adult, adult]         adult            adult                   True
# 39    033A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 2     002A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 3     002B  [adult, adult, senior, adult, adult, adult, ad...         adult            adult                   True
# 38    032A                                     [adult, adult]         adult            adult                   True
# 37    031A  [adult, adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 36    029A  [adult, senior, adult, adult, adult, adult, ad...         adult            adult                   True
# 4     003A                       [adult, adult, adult, adult]         adult            adult                   True
# 7     006A                              [adult, adult, adult]         adult            adult                   True
# 8     007A         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 5     004A                                           [kitten]        kitten            adult                  False
# 103   109A                [adult, adult, adult, adult, adult]         adult           kitten                  False
# 6     005A  [senior, senior, senior, senior, senior, senio...        senior            adult                  False
# 101   106A  [adult, adult, adult, adult, adult, adult, adu...         adult           senior                  False
# 92    097A  [adult, adult, adult, adult, senior, senior, s...         adult           senior                  False
# 99    104A                       [adult, adult, adult, adult]         adult           senior                  False
# 108   116A  [senior, senior, adult, adult, adult, adult, a...         adult           senior                  False
# 90    095A  [senior, senior, senior, senior, senior, adult...        senior            adult                  False
# 77    071A  [adult, senior, adult, adult, adult, senior, s...        senior            adult                  False
# 88    093A                                     [adult, adult]         adult           senior                  False
# 61    055A  [adult, senior, senior, adult, adult, senior, ...         adult           senior                  False
# 48    042A  [adult, adult, adult, adult, adult, adult, adu...         adult           kitten                  False
# 51    045A                     [kitten, kitten, adult, adult]         adult           kitten                  False
# 52    047A  [adult, adult, adult, adult, adult, adult, adu...         adult           kitten                  False
# 56    051A  [adult, adult, adult, adult, adult, senior, ad...         adult           senior                  False
# 57    051B  [adult, adult, adult, adult, adult, adult, adu...         adult           senior                  False
# 58    052A                                   [senior, senior]        senior            adult                  False
# 59    053A                            [senior, senior, adult]        senior            adult                  False
# 60    054A                                     [adult, adult]         adult           senior                  False
# 62    056A                              [adult, adult, adult]         adult           senior                  False
# 16    014B  [senior, adult, adult, adult, kitten, adult, a...         adult           kitten                  False
# 63    057A  [adult, adult, adult, adult, adult, adult, adu...         adult           senior                  False
# 67    061A                                     [adult, adult]         adult           senior                  False
# 30    025C                    [adult, senior, senior, senior]        senior            adult                  False
# 27    024A                                            [adult]         adult           senior                  False
# 74    068A  [adult, senior, adult, adult, senior, kitten, ...        senior            adult                  False
# 21    019B                                           [senior]        senior            adult                  False
# 82    076A                                           [kitten]        kitten            adult                  False
# 18    016A  [adult, adult, adult, adult, adult, adult, adu...         adult           senior                  False
# 109   117A  [adult, senior, senior, adult, adult, adult, s...         adult           senior                  False

# %%
# Create df for majority votes
majority_df = majority_votes.reset_index()
majority_df.columns = ['cat_id', 'Majority_Vote']

# Get actual groups for each cat_id
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first().reset_index()

# Merge majority votes with actual groups
majority_with_actual = pd.merge(majority_df, actual_groups, on='cat_id')

# Add a column to check if the majority vote was correct
majority_with_actual['Majority_Correct'] = majority_with_actual['Majority_Vote'] == majority_with_actual['actual_age_group']

# Count correct majority votes per class
correct_majority_votes_per_class = majority_with_actual.groupby('actual_age_group')['Majority_Correct'].sum()

print("Correct Majority Votes per Class:")
print(correct_majority_votes_per_class)
# Out:
# Correct Majority Votes per Class:
# actual_age_group
# adult     63
# kitten    10
# senior     7
# Name: Majority_Correct, dtype: int64

# %%
# Calculate the total count and the number of correct predictions for each class
class_stats = majority_with_actual.groupby('actual_age_group').agg(
    total_count=('Majority_Correct', 'size'),  # Total number of cases per class
    correct_count=('Majority_Correct', 'sum')  # Sum of correct predictions per class
).reset_index()

# Calculate accuracy for each class
class_stats['accuracy'] = class_stats['correct_count'] / class_stats['total_count'] * 100

# store for final evaluation 
all_majority_vote_details.append(class_stats)

# Log detailed stats
print("Detailed Class Statistics for Majority Votes:")
print(class_stats)
# Out:
# Detailed Class Statistics for Majority Votes:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult           73             63  86.301370
# 1           kitten           15             10  66.666667
# 2           senior           22              7  31.818182

# %%
# Plot for Detailed Class Statistics for Majority Votes
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Accuracy of Majority Votes by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Detailed Class Statistics

# %%
# Calculate the total count and the number of correct predictions for each class
class_stats = full_results.groupby('actual_age_group').agg(
    total_count=('correct', 'size'),
    correct_count=('correct', 'sum')
).reset_index()

# Calculate accuracy for each class
class_stats['accuracy'] = class_stats['correct_count'] / class_stats['total_count'] * 100

# store for final evaluation 
all_class_stats.append(class_stats)

# Log the detailed stats
print("Detailed Class Statistics:")
print(class_stats)
# Out:
# Detailed Class Statistics:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult          471            406  86.199575
# 1           kitten          100             44  44.000000
# 2           senior          149             45  30.201342

# %%
# Plot for Detailed Class Statistics (Overall)
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Overall Accuracy by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Gender Exploration

# %%
# Group by gender and calculate the total count, correct predictions, and accuracy
gender_stats = full_results.groupby('all_gender').agg(
    count=('cat_id', 'size'),  # Total number of cases per gender
    correct=('correct', 'sum')  # Sum of correct predictions per gender
).reset_index()

# Calculate accuracy for each gender
gender_stats['accuracy'] = (gender_stats['correct'] / gender_stats['count'] * 100).round(2)

# Display the DataFrame
print("Accuracy by Gender:")
print(gender_stats)

# store for final evaluation 
all_gender_stats.append(gender_stats)
# Out:
# Accuracy by Gender:
#   all_gender  count  correct  accuracy
# 0          F    192      140     72.92
# 1          M    286      220     76.92
# 2          X    242      135     55.79

# %%
# Plot for Accuracy by Gender
styled_barplot(gender_stats, 'all_gender', 'accuracy', 
               'Accuracy by Gender', 
               'Gender', 'Accuracy (%)')

# %% [markdown]
# ### Log current total CV Stats

# %%
print("Total Majority Vote Accuracy so far:", all_majority_vote_accuracies)
print("Total Class Statistics so far:\n", all_class_stats) 
print("Total Majority Vote Statistics so far:\n", all_majority_vote_details) 
print("Total Gender Accuracy so far:\n", all_gender_stats)
# Out:
# Total Majority Vote Accuracy so far: [0.7363636363636363, 0.7363636363636363, 0.7181818181818181, 0.8, 0.7272727272727273]
# Total Class Statistics so far:
#  [  actual_age_group  total_count  correct_count   accuracy
# 0            adult          474            413  87.130802
# 1           kitten           95             43  45.263158
# 2           senior          149             41  27.516779,   actual_age_group  total_count  correct_count   accuracy
# 0            adult          473            406  85.835095
# 1           kitten           91             46  50.549451
# 2           senior          149             36  24.161074,   actual_age_group  total_count  correct_count   accuracy
# 0            adult          487            435  89.322382
# 1           kitten           91             42  46.153846
# 2           senior          149             41  27.516779,   actual_age_group  total_count  correct_count   accuracy
# 0            adult          472            410  86.864407
# 1           kitten          100             51  51.000000
# 2           senior          149             51  34.228188,   actual_age_group  total_count  correct_count   accuracy
# 0            adult          471            406  86.199575
# 1           kitten          100             44  44.000000
# 2           senior          149             45  30.201342]
# Total Majority Vote Statistics so far:
#  [  actual_age_group  total_count  correct_count   accuracy
# 0            adult           73             67  91.780822
# 1           kitten           15              9  60.000000
# 2           senior           22              5  22.727273,   actual_age_group  total_count  correct_count   accuracy
# 0            adult           73             65  89.041096
# 1           kitten           15             10  66.666667
# 2           senior           22              6  27.272727,   actual_age_group  total_count  correct_count   accuracy
# 0            adult           73             64  87.671233
# 1           kitten           15              8  53.333333
# 2           senior           22              7  31.818182,   actual_age_group  total_count  correct_count   accuracy
# 0            adult           73             69  94.520548
# 1           kitten           15             10  66.666667
# 2           senior           22              9  40.909091,   actual_age_group  total_count  correct_count   accuracy
# 0            adult           73             63  86.301370
# 1           kitten           15             10  66.666667
# 2           senior           22              7  31.818182]
# Total Gender Accuracy so far:
#  [  all_gender  count  correct  accuracy
# 0          F    196      137     69.90
# 1          M    286      219     76.57
# 2          X    236      141     59.75,   all_gender  count  correct  accuracy
# 0          F    192      130     67.71
# 1          M    289      219     75.78
# 2          X    232      139     59.91,   all_gender  count  correct  accuracy
# 0          F    192      137     71.35
# 1          M    286      223     77.97
# 2          X    249      158     63.45,   all_gender  count  correct  accuracy
# 0          F    192      137     71.35
# 1          M    286      220     76.92
# 2          X    243      155     63.79,   all_gender  count  correct  accuracy
# 0          F    192      140     72.92
# 1          M    286      220     76.92
# 2          X    242      135     55.79]

# %% [markdown]
# # --------------

# %% [markdown]
# # Total Final Results & Analysis

# %%
# Count unique cat_id per age group 
unique_cats_per_age_group = dataframe.groupby('age_group')['cat_id'].nunique()

# Display the counts
print("Unique cat_id counts in original dataframe:", unique_cats_per_age_group)
# Out:
# Unique cat_id counts in original dataframe: age_group
# adult     74
# kitten    16
# senior    22
# Name: cat_id, dtype: int64

# %% [markdown]
# ## Metrics

# %%
# Calculate overall metrics
overall_avg_loss = np.mean(all_losses)
overall_avg_acc = np.mean(all_accuracies)
overall_avg_precision = np.mean(all_precisions)
overall_avg_recall = np.mean(all_recalls)
overall_avg_f1 = np.mean(all_f1)

print("Overall Average Metrics:")
print("Loss:", overall_avg_loss)
print("Accuracy:", overall_avg_acc)
print("Precision:", overall_avg_precision)
print("Recall:", overall_avg_recall)
print("F1 Score:", overall_avg_f1)
# Out:
# Overall Average Metrics:
# Loss: 2.147928023338318
# Accuracy: 0.6989577442407608
# Precision: 0.6684448168301145
# Recall: 0.6041869302321887
# F1 Score: 0.5876178285758973

# %% [markdown]
# ## Majority Votes

# %%
# Average of majority vote accuracies
average_majority_vote_accuracy = np.mean(all_majority_vote_accuracies)
print("Average Majority Vote Accuracy:", average_majority_vote_accuracy)
# Out:
# Average Majority Vote Accuracy: 0.7436363636363638

# %%
# Concatenate all class stats DataFrames and calculate the mean of accuracies
total_majority_vote_details = pd.concat(all_majority_vote_details)
average_majority_vote_details = total_majority_vote_details.groupby('actual_age_group').agg({
    'total_count': 'sum', 
    'correct_count': 'sum' 
}).reset_index()
average_majority_vote_details['accuracy'] = (average_majority_vote_details['correct_count'] / average_majority_vote_details['total_count']) * 100

print("Average Class Statistics:")
print(average_majority_vote_details)
# Out:
# Average Class Statistics:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult          365            328  89.863014
# 1           kitten           75             47  62.666667
# 2           senior          110             34  30.909091

# %%
# Plot for Detailed Class Statistics for Majority Votes
styled_barplot(average_majority_vote_details, 'actual_age_group', 'accuracy', 
               'Accuracy of Majority Votes by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Detailed Class Statistics

# %%
# Concatenate all class stats DataFrames and calculate the mean of accuracies
total_class_stats = pd.concat(all_class_stats)
average_class_stats = total_class_stats.groupby('actual_age_group').agg({
    'total_count': 'sum',  
    'correct_count': 'sum' 
}).reset_index()
average_class_stats['accuracy'] = (average_class_stats['correct_count'] / average_class_stats['total_count']) * 100

print("Average Class Statistics:")
print(average_class_stats)
# Out:
# Average Class Statistics:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult         2377           2070  87.084560
# 1           kitten          477            226  47.379455
# 2           senior          745            214  28.724832

# %%
# Plot for Detailed Class Statistics (Overall)
styled_barplot(average_class_stats, 'actual_age_group', 'accuracy', 
               'Overall Accuracy by Age Group', 
               'Age Group', 'Accuracy (%)')

# %%
# Concatenate all gender stats DataFrames and calculate the mean of accuracies
total_gender_stats = pd.concat(all_gender_stats)
average_gender_stats = total_gender_stats.groupby('all_gender').agg({
    'count': 'sum',  
    'correct': 'sum'  
}).reset_index()
average_gender_stats['accuracy'] = (average_gender_stats['correct'] / average_gender_stats['count']) * 100

print("Average Gender Accuracy:")
print(average_gender_stats)
# Out:
# Average Gender Accuracy:
#   all_gender  count  correct   accuracy
# 0          F    964      681  70.643154
# 1          M   1433     1101  76.831821
# 2          X   1202      728  60.565724

# %%
# Plot for Accuracy by Gender
styled_barplot(total_gender_stats, 'all_gender', 'accuracy', 
               'Accuracy by Gender', 
               'Gender', 'Accuracy (%)')

# %% [markdown]
# # Visualisations

# %%
# Plotting all metrics
metrics_across_seeds = plot_all_metrics(all_losses, all_accuracies, all_precisions, all_recalls, all_f1, "Seeds", "Seed Number")

# %%
# Calculate the standard deviation for each metric
std_loss = np.std(all_losses)
std_accuracy = np.std(all_accuracies)
std_precision = np.std(all_precisions)
std_recall = np.std(all_recalls)
std_f1 = np.std(all_f1)

print("Standard Deviations:")
print(f"Loss: {std_loss}")
print(f"Accuracy: {std_accuracy}")
print(f"Precision: {std_precision}")
print(f"Recall: {std_recall}")
print(f"F1 Score: {std_f1}")
# Out:
# Standard Deviations:
# Loss: 0.1823313043872312
# Accuracy: 0.01114423704079994
# Precision: 0.030994436017935438
# Recall: 0.03242610622443578
# F1 Score: 0.021972162659638392

# %%
# Calculate the interquartile range for each metric
iqr_loss = np.percentile(all_losses, 75) - np.percentile(all_losses, 25)
iqr_accuracy = np.percentile(all_accuracies, 75) - np.percentile(all_accuracies, 25)
iqr_precision = np.percentile(all_precisions, 75) - np.percentile(all_precisions, 25)
iqr_recall = np.percentile(all_recalls, 75) - np.percentile(all_recalls, 25)
iqr_f1 = np.percentile(all_f1, 75) - np.percentile(all_f1, 25)

print("Interquartile Ranges:")
print(f"Loss: {iqr_loss}")
print(f"Accuracy: {iqr_accuracy}")
print(f"Precision: {iqr_precision}")
print(f"Recall: {iqr_recall}")
print(f"F1 Score: {iqr_f1}")
# Out:
# Interquartile Ranges:
# Loss: 0.1512589454650879
# Accuracy: 0.01363961398601532
# Precision: 0.021934110247574856
# Recall: 0.018393533434865605
# F1 Score: 0.030641093881947246

# %% [markdown]
# ## Display the seed folds results together

# %%
# Create a figure with subplots
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(18, 12))  

# Flatten the axes array for easier indexing
axes = axes.flatten()

def plot_metrics_on_axes(ax, losses, accuracies, precisions, recalls, f1, title):
    ax.plot(range(1, len(losses)+1), losses, marker='o', color='blue', label='Loss')
    ax.plot(range(1, len(accuracies)+1), accuracies, marker='o', color='green', label='Accuracy')
    ax.plot(range(1, len(precisions)+1), precisions, marker='o', color='red', label='Precision')
    ax.plot(range(1, len(recalls)+1), recalls, marker='o', color='purple', label='Recall')
    ax.plot(range(1, len(f1)+1), f1, marker='o', color='orange', label='F1 Score')
    ax.set_xticks([1, 2, 3, 4])  # Set x-axis ticks to full integers
    ax.set_title(title)
    ax.set_xlabel('Fold Number')
    ax.set_ylabel('Metric Value')
    ax.legend()
    ax.grid(True)

# Plot onto each axes object
plot_metrics_on_axes(axes[0], *seed_1_folds_values, "Seed 1 Metrics")
plot_metrics_on_axes(axes[1], *seed_2_folds_values, "Seed 2 Metrics")
plot_metrics_on_axes(axes[2], *seed_3_folds_values, "Seed 3 Metrics")
plot_metrics_on_axes(axes[3], *seed_4_folds_values, "Seed 4 Metrics")
plot_metrics_on_axes(axes[4], *seed_5_folds_values, "Seed 5 Metrics")

# Hide the unused subplot 
for ax in axes[5:]:
    ax.set_visible(False)

# Adjust layout
plt.tight_layout()
plt.show()
