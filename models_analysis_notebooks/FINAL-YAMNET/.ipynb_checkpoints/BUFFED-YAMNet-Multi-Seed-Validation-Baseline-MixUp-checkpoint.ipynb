# %% [markdown]
# # YAMNet Multi Seed Validation
# #### 5 Random (but reproducible) seeds are selected for 5 different runs of train/test
# #### Models have been optimised and verified on validation sets thoroughly, running a final train/test evaluation here
# #### The setup:
#
# - 4 fold StratifiedGroupKFold for stratification and ensuring each cat_id group only appears in one set at a time
# - Final scores averaged over the 4 folds
# - For each seed run we will explore the cat_id predictions through majority voting
# - For each run we will explore the potential impact of gender
# - Includes visualisations & analysis
#
# The dataset is highly unbalanced.

# %%
# Standard imports
import numpy as np
import pandas as pd
import random
from datetime import datetime
from collections import Counter

# Sklearn imports
from sklearn.model_selection import train_test_split, GroupShuffleSplit, GroupKFold, StratifiedGroupKFold
from sklearn.preprocessing import LabelEncoder, MinMaxScaler, RobustScaler, StandardScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report
from sklearn.utils.class_weight import compute_class_weight
from sklearn.inspection import permutation_importance

# Imbalanced-learn import
from imblearn.over_sampling import SMOTE

# TensorFlow and Keras imports
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Dropout, Input, BatchNormalization, concatenate
from tensorflow.keras.optimizers import Adam, RMSprop, SGD, Adamax, AdamW
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import to_categorical
from keras.regularizers import l1, l2, L1L2

# Optuna import
import optuna

# Visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns

from IPython.display import display

# MixUp imports
import tensorflow_probability as tfp

# %%
# Set an initial seed for reproducibility
np.random.seed(42)  

# Generate a list of 5 random seeds
random_seeds = np.random.randint(0, 10000, size=5)
print("Random Seeds:", random_seeds)
# Out:
# Random Seeds: [7270  860 5390 5191 5734]

# %% [markdown]
# #### TOTAL RESULTS ACROSS SEED INITIATION

# %%
# Lists to collect statistics across all CVs
all_losses, all_accuracies, all_precisions, all_recalls, all_f1 = [], [], [], [], []
all_majority_vote_accuracies, all_majority_vote_details, all_class_stats, all_gender_stats  = [], [], [], []

# %% [markdown]
# ## Define Functions

# %%
def check_initial_group_split(groups_train, groups_test):
    """
    Check if any group is present in both the train and test sets.

    Parameters:
    - groups_train: Array of group identifiers for the train set
    - groups_test: Array of group identifiers for the test set

    Returns:
    - Prints out any groups found in both sets and the count of such groups
    """
    train_groups = set(groups_train)
    test_groups = set(groups_test)
    common_groups = train_groups.intersection(test_groups)

    if common_groups:
        print(f"Warning: Found {len(common_groups)} common groups in both train/validation and test sets: {common_groups}")
    else:
        print("No common groups found between train and test sets.")

# %%
# Function to perform the swaps based on cat_id, ensuring swaps within the same age_group
def swap_cat_id_instances(dataframe, train_val_idx, test_idx, specific_cat_ids):
    for cat_id in specific_cat_ids:
        # Check if the specific cat_id is not in the training set
        if cat_id not in dataframe.iloc[train_val_idx]['cat_id'].values:
            # Get the age_group of this cat_id
            age_group = dataframe[dataframe['cat_id'] == cat_id]['age_group'].iloc[0]
                
            # Find a different cat_id within the same age_group in the train set that is not in the test set
            other_cat_ids_in_age_group = dataframe[(dataframe['age_group'] == age_group) & 
                                                   (dataframe['cat_id'] != cat_id) &
                                                   (~dataframe['cat_id'].isin(dataframe.iloc[test_idx]['cat_id']))]['cat_id'].unique()
            
            # Choose one other cat_id for swapping
            if len(other_cat_ids_in_age_group) > 0:
                other_cat_id = np.random.choice(other_cat_ids_in_age_group)

                # Find all instances of the other_cat_id in the train set
                other_cat_id_train_val_indices = train_val_idx[dataframe.iloc[train_val_idx]['cat_id'] == other_cat_id]
                
                # Find all instances of the specific cat_id in the test set
                cat_id_test_indices = test_idx[dataframe.iloc[test_idx]['cat_id'] == cat_id]
                
                # Swap the indices
                train_val_idx = np.setdiff1d(train_val_idx, other_cat_id_train_val_indices, assume_unique=True)
                test_idx = np.setdiff1d(test_idx, cat_id_test_indices, assume_unique=True)

                train_val_idx = np.concatenate((train_val_idx, cat_id_test_indices))
                test_idx = np.concatenate((test_idx, other_cat_id_train_val_indices))
            else:
                print(f"No alternative cat_id found in the same age_group as {cat_id} for swapping.")
                
    return train_val_idx, test_idx

# %%
# Function to identify differences in groups
def find_group_differences(original, new):
    # Convert numpy arrays to sets for easy difference computation
    original_set = set(original)
    new_set = set(new)
    # Find differences
    moved_to_new = new_set - original_set
    moved_to_original = original_set - new_set
    return moved_to_new, moved_to_original

# %%
# create custom logger function for local logs & stored in a .txt
def logger(message, file=None):
    print(message)
    if file is not None:
        with open(file, "a") as log_file:
            log_file.write(message + "\n")

log_file_path = "multi-seed-val-D13.txt"

# %%
# Set the aesthetic style of the plots
sns.set(style="whitegrid", palette="deep")

# Define a custom color palette
colors = ["#6aabd1", "#b6e2d3", "#dac292"] 
sns.set_palette(sns.color_palette(colors))

# Function to create bar plots with enhanced style
def styled_barplot(data, x, y, title, xlabel, ylabel):
    plt.figure(figsize=(8, 4))
    bar_plot = sns.barplot(x=x, y=y, data=data, errorbar=None, width=0.5)  
    plt.title(title, fontsize=16, fontweight='bold', color="#333333")
    plt.xlabel(xlabel, fontsize=14, fontweight='bold', color="#333333")
    plt.ylabel(ylabel, fontsize=14, fontweight='bold', color="#333333")
    plt.xticks(fontsize=12, color="#333333")
    plt.yticks(fontsize=12, color="#333333")
    plt.ylim(0, 100) 

    # Adding value labels on top of each bar
    for p in bar_plot.patches:
        height = p.get_height()
        # Annotate the height value on the bar
        bar_plot.annotate(f'{height:.1f}', 
                          (p.get_x() + p.get_width() / 2., height), 
                          ha='center', va='center', 
                          xytext=(0, 9), 
                          textcoords='offset points', fontsize=12, color="#333333")

    plt.show()

# %%
def plot_all_metrics(losses, accuracies, precisions, recalls, f1, metrics_across, x_axis_label):
    fig, ax = plt.subplots(figsize=(12, 8))
    seeds = range(1, len(losses) + 1)

    ax.plot(seeds, losses, marker='o', color='blue', label='Loss')
    ax.plot(seeds, accuracies, marker='o', color='green', label='Accuracy')
    ax.plot(seeds, precisions, marker='o', color='red', label='Precision')
    ax.plot(seeds, recalls, marker='o', color='purple', label='Recall')
    ax.plot(seeds, f1, marker='o', color='orange', label='F1 Score')

    ax.set_title(f'Metrics Across {metrics_across}')
    ax.set_xlabel(x_axis_label)
    ax.set_ylabel('Metric Value')
    ax.set_xticks(seeds)
    ax.legend()
    ax.grid(True)

    return fig

# %%
def mixup_data(x, y, alpha=0.2):
    if alpha > 0:
        # Create a Beta distribution and sample lambda values from it
        beta_distribution = tfp.distributions.Beta(alpha, alpha)
        lam = beta_distribution.sample([tf.shape(x)[0]])
    else:
        lam = 1

    lam = tf.maximum(lam, 1 - lam)  # Ensure lambda is always between 0.5 and 1
    index = tf.random.shuffle(tf.range(tf.shape(x)[0]))

    x_mix = lam[:, tf.newaxis] * x + (1 - lam[:, tf.newaxis]) * tf.gather(x, index)
    y_mix = lam[:, tf.newaxis] * y + (1 - lam[:, tf.newaxis]) * tf.gather(y, index)

    return x_mix, y_mix

# %% [markdown]
# # RANDOM SEED 1

# %% [markdown]
# ## Prepare Data

# %%
# Set a fixed random seed for reproducibility
random.seed(int(random_seeds[0])) 
np.random.seed(int(random_seeds[0]))
tf.random.set_seed(int(random_seeds[0]))

# Load datasets
dataframe = pd.read_csv('/Users/astrid/PycharmProjects/data-aug-and-more/yamnet-tfhub-extraction/yamnet_embeddings_looped_april_23.csv')

def assign_age_group(age, age_groups):
    for group_name, age_range in age_groups.items():
        if age_range[0] <= age < age_range[1]:
            return group_name
    return 'Unknown'  # For any age that doesn't fit the defined groups

# Define age groups
age_groups = {
    'kitten': (0, 0.5),
    'adult': (0.5, 12),
    'senior': (12, 20)
}

# Create a new column for the age group
dataframe['age_group'] = dataframe['target'].apply(assign_age_group, age_groups=age_groups)

print(dataframe['age_group'].value_counts())
# Out:
# adult     606
# senior    186
# kitten    176
# Name: age_group, dtype: int64

# %%
# Separate features and labels
X = dataframe.iloc[:, :-4].values  # all columns except the last four

# Encode the 'age_group' column as integers using LabelEncoder
label_encoder = LabelEncoder()
encoded_y = label_encoder.fit_transform(dataframe['age_group'].values)

# Use the encoded labels for splitting and one-hot encoding
y = encoded_y  

# Convert 'cat_id' column to numpy array to be used as groups array for GroupKFold
groups = dataframe['cat_id'].values

# %%
tf.keras.backend.clear_session()

# %% [markdown]
# ## Run Setup

# %%
all_cat_ids = []
all_predicted_age_groups = []
all_actual_age_groups = []
all_gender = []

# Define the StratifiedGroupKFold splitter for 4 fold CV with random shuffling
outer_cv = StratifiedGroupKFold(n_splits=4, shuffle=True, random_state=int(random_seeds[0]))

# unseen test set metrics
unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1 = [], [], [], [], []

outer_fold = 0

# Use the splitter to generate indices for training and testing sets
# Note: GroupShuffleSplit.split returns indices, so we use it to index the arrays
for train_val_idx, test_idx in outer_cv.split(X, y, groups):
    outer_fold += 1
    logger(f"outer_fold {outer_fold}", file=log_file_path)

    # Convert indices back to DataFrame for easy manipulation
    df_train_val = dataframe.iloc[train_val_idx]
    df_test = dataframe.iloc[test_idx]

    ##############################
    # ASSESSING SPLITS BY CAT_ID #
    ##############################
    
    # Get the distribution of groups
    training_validation_group_distribution = df_train_val['cat_id'].value_counts()  
    testing_group_distribution = df_test['cat_id'].value_counts()  
    
    # Log or print the distribution
    logger(f"Train Set Group Distribution:\n{training_validation_group_distribution}", file=log_file_path)
    logger(f"Testing Set Group Distribution:\n{testing_group_distribution}", file=log_file_path)

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val['gender'].value_counts()
    testing_gender_distribution = df_test['gender'].value_counts()
    
    # Log the distribution
    logger(f"Training Set Gender Distribution BEFORE SWAP:\n{training_gender_distribution}", file=log_file_path)
    logger(f"Testing Set Gender Distribution BEFORE SWAP:\n{testing_gender_distribution}", file=log_file_path)

    # Group by 'age_group' and then list unique 'cat_id' within each age group
    unique_cat_ids_per_age_group_train_val = df_train_val.groupby('age_group')['cat_id'].unique()
    unique_cat_ids_per_age_group_test = df_test.groupby('age_group')['cat_id'].unique()
    
    # Log results
    logger(f"Unique Cat IDs per Age Group in Training/Validation Set:\n{unique_cat_ids_per_age_group_train_val}", file=log_file_path)
    logger(f"Unique Cat IDs per Age Group in Testing Set:\n{unique_cat_ids_per_age_group_test}", file=log_file_path)

    # Calculate the count of unique identifiers per age group for training and testing set
    counts_train_val = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_train_val.items()}
    counts_test = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_test.items()}

    # Log the counts of unique identifiers per age group
    logger(f"Count of Unique Cat IDs per Age Group in Training/Validation Set:\n{counts_train_val}", file=log_file_path)
    logger(f"Count of Unique Cat IDs per Age Group in Testing Set:\n{counts_test}", file=log_file_path)

    #######################################################
    # CONTINUE WITH ENSURING VALID AND APPROPRIATE SPLITS #
    #######################################################
    
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    groups_train_val, groups_test = groups[train_val_idx], groups[test_idx]

    # logging identifier splits 
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)

    # check group splits
    check_initial_group_split(groups_train_val, groups_test)

    # Specify the cat_ids that must be in the training/validation set
    specific_cat_ids = ['000A', '046A']
    
    # Perform the swapping operation
    train_val_idx, test_idx = swap_cat_id_instances(dataframe, train_val_idx, test_idx, specific_cat_ids)
    
    # Re-assign the sets based on the updated indices
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    new_groups_train_val, new_groups_test = groups[train_val_idx], groups[test_idx]

    # Find differences for training and test sets
    moved_to_train_val, removed_from_train_val = find_group_differences(groups_train_val, new_groups_train_val)
    moved_to_test, removed_from_test = find_group_differences(groups_test, new_groups_test)
    
    # Display the results
    logger(f"Moved to Training/Validation Set:\n{moved_to_train_val}", file=log_file_path)
    logger(f"Removed from Training/Validation Set:\n{removed_from_train_val}", file=log_file_path)
    logger(f"Moved to Test Set:\n{moved_to_test}", file=log_file_path)
    logger(f"Removed from Test Set\n{removed_from_test}", file=log_file_path)

    # Update X_train_val, X_test, y_train_val, y_test, groups_train_val, groups_test based on updated indices
    X_train_val = X[train_val_idx]
    y_train_val = y[train_val_idx]
    groups_train_val = groups[train_val_idx]
    
    X_test = X[test_idx]
    y_test = y[test_idx]
    groups_test = groups[test_idx]

    # logging identifier splits again after potential swaps
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"AFTER SWAP - Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"AFTER SWAP - Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)
    
    # Verify the lengths are consistent
    logger(f"Length of X_train_val:\n{len(X_train_val)}", file=log_file_path)
    logger(f"Length of y_train_val:\n{len(y_train_val)}", file=log_file_path)
    logger(f"Length of groups_train_val:\n{len(groups_train_val)}", file=log_file_path)

    # Check group splits once more
    check_initial_group_split(groups_train_val, groups_test)

    # Convert the modified indices back to a DataFrame representing the updated df_train_val
    df_train_val_updated = dataframe.iloc[train_val_idx].copy()
    df_test_updated = dataframe.iloc[test_idx].copy()

    ############################
    # LOGGING AGE GROUP SPLITS #
    ############################

    # Get the distribution of age groups of age groups before the update
    training_validation_age_group_distribution = df_train_val['age_group'].value_counts()
    testing_age_group_distribution = df_test['age_group'].value_counts()
    
    # Logthe distribution
    logger(f"Train Age Group Distribution BEFORE SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution BEFORE SWAP:\n{testing_age_group_distribution}", file=log_file_path)

    # Get the distribution of age groups after the update
    training_validation_age_group_distribution = df_train_val_updated['age_group'].value_counts()
    testing_age_group_distribution = df_test_updated['age_group'].value_counts()
    
    # Log the distribution
    logger(f"Train Age Group Distribution AFTER SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution AFTER SWAP:\n{testing_age_group_distribution}", file=log_file_path)
    
    ########################################################
    # TRACKING FINAL CAT_IDs & GENDER AFTER REDISTRIBUTION #
    ########################################################

    # Get the distribution of groups
    training_validation_group_distribution = df_train_val_updated['cat_id'].value_counts()  
    testing_group_distribution = df_test_updated['cat_id'].value_counts()  

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val_updated['gender'].value_counts()
    testing_gender_distribution = df_test_updated['gender'].value_counts()
    
    logger(f"\n Starting training on unseen test set\n", file=log_file_path)

    ###################
    # PREPARING MODEL #
    ###################

    # Calculate the distribution of age groups in y_train_val
    age_group_distribution = Counter(y_train_val)
    print("Age group distribution:", age_group_distribution)

    # EarlyStopping callback: monitor 'loss' instead of 'val_loss' for the test set
    early_stopping = EarlyStopping(
        monitor='loss',  
        min_delta=0.001, 
        patience=30,  
        verbose=1,  
        restore_best_weights=True  
    )

    # One final shuffle to ensure randomness
    outer_shuffle_idx = np.random.permutation(len(X_train_val))
    X_train_val = X_train_val[outer_shuffle_idx]
    y_train_val = y_train_val[outer_shuffle_idx]
    
    # Scale the features
    scaler_full = StandardScaler().fit(X_train_val)
    X_train_full_scaled = scaler_full.transform(X_train_val)
    X_test_scaled = scaler_full.transform(X_test)
    
    # Convert features to TensorFlow tensors
    X_train_full_scaled = tf.convert_to_tensor(X_train_full_scaled, dtype=tf.float32)
    X_test_scaled = tf.convert_to_tensor(X_test_scaled, dtype=tf.float32)
    
    # One-hot encode labels before mixup
    y_train_full_encoded = to_categorical(y_train_val)
    y_test_encoded = to_categorical(y_test)
    
    # Convert labels to TensorFlow tensors
    y_train_full_encoded = tf.convert_to_tensor(y_train_full_encoded, dtype=tf.float32)
    
    # Apply Mixup
    X_train_mix_outer, y_train_mix_outer = mixup_data(X_train_full_scaled, y_train_full_encoded, alpha=0.2)
    
    #######################
    # BUILD & TRAIN MODEL #
    #######################

    optimizers = {
        'Adamax': Adamax(learning_rate=0.00510251984616472)
    }
    
    # Model definition with dynamic number of layers
    model_full = Sequential()
    model_full.add(Dense(480, activation='relu', input_shape=(X_train_full_scaled.shape[1],)))
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.2011047009431978))  
    model_full.add(Dense(256, activation='relu',)) 
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.14956886311951184))  
    model_full.add(Dense(256, activation='relu'))  
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.42291461228250665))  
    model_full.add(Dense(3, activation='softmax'))  
    
    # Use the optimizer from the parameters
    optimizer = optimizers['Adamax']  # optimizer_key from parameters
    
    # Compile the model
    model_full.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    
    # Train the model on the full training set
    history_full = model_full.fit(X_train_full_scaled, y_train_full_encoded, epochs=1500, batch_size=64,
                                  verbose=1, callbacks=[early_stopping])
    
    # Evaluate the model on the held-out test set
    test_loss, test_accuracy = model_full.evaluate(X_test_scaled, y_test_encoded)

    y_test_pred_prob = model_full.predict(X_test_scaled)
    y_test_pred = np.argmax(y_test_pred_prob, axis=1)  
    y_test_true = np.argmax(y_test_encoded, axis=1)    

    ################################
    # LOG MAJORITY VOTE PER CAT_ID #
    ################################

    # Convert numeric predictions back to age group labels
    predicted_age_groups = label_encoder.inverse_transform(y_test_pred)
    actual_labels = label_encoder.inverse_transform(y_test_true)
    
    # Map predictions and actual labels back to cat_ids
    test_results = pd.DataFrame({
        'cat_id': df_test_updated['cat_id'],
        'predicted_age_group': predicted_age_groups,
        'actual_age_group': actual_labels
    })
    
    # Group by cat_id and aggregate predicted age groups
    majority_votes = test_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
    actual_groups = test_results.groupby('cat_id')['actual_age_group'].first()
    
    # Calculate the accuracy of majority voting
    correct_predictions = (majority_votes == actual_groups).sum()
    total_cats = len(actual_groups)
    majority_vote_accuracy = correct_predictions / total_cats
    
    # Log the accuracy of the majority voting
    logger(f"Majority Vote Accuracy for cat_id for this fold: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

    ####################################################
    # COLLECT PREDICTIONS FOR GENDER & CAT_ID ANALYSIS #
    ####################################################

    # Debugging print statements
    print(f'Before appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Extend lists with current fold results
    all_cat_ids.extend(df_test_updated['cat_id'].tolist())
    all_predicted_age_groups.extend(predicted_age_groups)
    all_actual_age_groups.extend(actual_labels)
    all_gender.extend(df_test_updated['gender'].tolist())

    # Debugging print statements
    print(f'After appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Calculate additional metrics
    test_precision = precision_score(y_test_true, y_test_pred, average='macro')  # Use 'macro' for imbalanced datasets
    test_recall = recall_score(y_test_true, y_test_pred, average='macro')
    test_f1 = f1_score(y_test_true, y_test_pred, average='macro')

    # prepare averages of outer metrics
    unseen_f1.append(test_f1)
    unseen_losses.append(test_loss)
    unseen_accuracies.append(test_accuracy)
    unseen_precisions.append(test_precision)
    unseen_recalls.append(test_recall)

    # Print final test results
    logger(f"Final Test Results - Loss: {test_loss}, Accuracy: {test_accuracy}, Precision: {test_precision}, Recall: {test_recall}, F1 Score: {test_f1}", file=log_file_path)

    # Generate the confusion matrix
    cm = confusion_matrix(y_test, y_test_pred)
    logger(f"Confusion Matrix:\n {cm}", file=log_file_path)

# Calculate the overall average metrics
unseen_set_avg_f1 = np.mean(unseen_f1)
unseen_set_avg_loss = np.mean(unseen_losses)
unseen_set_avg_acc = np.mean(unseen_accuracies)
unseen_set_avg_precision = np.mean(unseen_precisions)
unseen_set_avg_recall = np.mean(unseen_recalls)

logger(f"\nFinal Average F1-Score across all UNSEEN TEST sets: {unseen_set_avg_f1}", file=log_file_path)
logger(f"\nFinal Average Loss across all UNSEEN TEST sets: {unseen_set_avg_loss}", file=log_file_path)
logger(f"\nFinal Average Accuracy across all UNSEEN TEST sets: {unseen_set_avg_acc}", file=log_file_path)
logger(f"\nFinal Average Precision across all UNSEEN TEST sets: {unseen_set_avg_precision}", file=log_file_path)
logger(f"\nFinal Average Recall across all UNSEEN TEST sets: {unseen_set_avg_recall}\n", file=log_file_path)

# Append averages to total lists
all_f1.append(unseen_set_avg_f1)
all_losses.append(unseen_set_avg_loss)
all_accuracies.append(unseen_set_avg_acc)
all_precisions.append(unseen_set_avg_precision)
all_recalls.append(unseen_set_avg_recall)
# Out:
# outer_fold 1
# Train Set Group Distribution:
# 000A    39
# 002B    36
# 103A    33
# 047A    30
# 057A    28
#         ..
# 049A     1
# 026C     1
# 073A     1
# 091A     1
# 100A     1
# Name: cat_id, Length: 87, dtype: int64
# Testing Set Group Distribution:
# 046A    66
# 055A    20
# 059A    18
# 116A    12
# 063A    11
# 072A     9
# 051B     9
# 045A     9
# 013B     8
# 053A     7
# 050A     7
# 117A     7
# 108A     6
# 008A     6
# 025C     6
# 070A     5
# 060A     3
# 058A     3
# 011A     3
# 025B     2
# 069A     2
# 093A     2
# 088A     1
# 024A     1
# 041A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    315
# X    245
# F    184
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    110
# F     73
# M     41
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [002A, 028A, 033A, 000B, 071A, 020A, 000A, 015...
# kitten    [042A, 014B, 110A, 109A, 040A, 047A, 049A, 048...
# senior    [106A, 057A, 090A, 113A, 051A, 097A, 094A, 016...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [070A, 053A, 072A, 013B, 063A, 069A, 060A, 088...
# kitten                             [046A, 045A, 050A, 041A]
# senior    [117A, 051B, 116A, 024A, 059A, 055A, 058A, 108...
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 63, 'kitten': 12, 'senior': 12}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 11, 'kitten': 4, 'senior': 10}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '004A' '005A' '006A' '007A'
#  '009A' '010A' '012A' '014A' '014B' '015A' '016A' '018A' '019A' '019B'
#  '020A' '021A' '022A' '023A' '023B' '025A' '026A' '026B' '026C' '027A'
#  '028A' '029A' '031A' '032A' '033A' '034A' '035A' '036A' '037A' '038A'
#  '039A' '040A' '042A' '043A' '044A' '047A' '048A' '049A' '051A' '052A'
#  '054A' '056A' '057A' '061A' '062A' '064A' '065A' '066A' '067A' '068A'
#  '071A' '073A' '074A' '075A' '076A' '087A' '090A' '091A' '092A' '094A'
#  '095A' '096A' '097A' '097B' '099A' '100A' '101A' '102A' '103A' '104A'
#  '105A' '106A' '109A' '110A' '111A' '113A' '115A']
# Unique Test Group IDs:
# ['008A' '011A' '013B' '024A' '025B' '025C' '041A' '045A' '046A' '050A'
#  '051B' '053A' '055A' '058A' '059A' '060A' '063A' '069A' '070A' '072A'
#  '088A' '093A' '108A' '116A' '117A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'046A'}
# Removed from Training/Validation Set:
# {'110A'}
# Moved to Test Set:
# {'110A'}
# Removed from Test Set
# {'046A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '004A' '005A' '006A' '007A'
#  '009A' '010A' '012A' '014A' '014B' '015A' '016A' '018A' '019A' '019B'
#  '020A' '021A' '022A' '023A' '023B' '025A' '026A' '026B' '026C' '027A'
#  '028A' '029A' '031A' '032A' '033A' '034A' '035A' '036A' '037A' '038A'
#  '039A' '040A' '042A' '043A' '044A' '046A' '047A' '048A' '049A' '051A'
#  '052A' '054A' '056A' '057A' '061A' '062A' '064A' '065A' '066A' '067A'
#  '068A' '071A' '073A' '074A' '075A' '076A' '087A' '090A' '091A' '092A'
#  '094A' '095A' '096A' '097A' '097B' '099A' '100A' '101A' '102A' '103A'
#  '104A' '105A' '106A' '109A' '111A' '113A' '115A']
# AFTER SWAP - Unique Test Group IDs:
# ['008A' '011A' '013B' '024A' '025B' '025C' '041A' '045A' '050A' '051B'
#  '053A' '055A' '058A' '059A' '060A' '063A' '069A' '070A' '072A' '088A'
#  '093A' '108A' '110A' '116A' '117A']
# Length of X_train_val:
# 809
# Length of y_train_val:
# 809
# Length of groups_train_val:
# 809
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     546
# senior    105
# kitten     93
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# kitten    83
# senior    81
# adult     60
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     546
# kitten    158
# senior    105
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# senior    81
# adult     60
# kitten    18
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 546, 1: 158, 2: 105})
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Epoch 1/1500
# 13/13 [==============================] - 1s 5ms/step - loss: 1.3596 - accuracy: 0.5562
# Epoch 2/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.6875 - accuracy: 0.7392
# Epoch 3/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4601 - accuracy: 0.8344
# Epoch 4/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2479 - accuracy: 0.8962
# Epoch 5/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2541 - accuracy: 0.9048
# Epoch 6/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.1557 - accuracy: 0.9370
# Epoch 7/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.1133 - accuracy: 0.9679
# Epoch 8/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1155 - accuracy: 0.9530
# Epoch 9/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1424 - accuracy: 0.9530
# Epoch 10/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1019 - accuracy: 0.9629
# Epoch 11/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0878 - accuracy: 0.9654
# Epoch 12/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0659 - accuracy: 0.9778
# Epoch 13/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0648 - accuracy: 0.9765
# Epoch 14/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0509 - accuracy: 0.9802
# Epoch 15/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0459 - accuracy: 0.9889
# Epoch 16/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0660 - accuracy: 0.9802
# Epoch 17/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0369 - accuracy: 0.9926
# Epoch 18/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0423 - accuracy: 0.9876
# Epoch 19/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0345 - accuracy: 0.9926
# Epoch 20/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0337 - accuracy: 0.9889
# Epoch 21/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0270 - accuracy: 0.9926
# Epoch 22/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0367 - accuracy: 0.9901
# Epoch 23/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0286 - accuracy: 0.9938
# Epoch 24/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0137 - accuracy: 0.9975
# Epoch 25/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0227 - accuracy: 0.9938
# Epoch 26/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0259 - accuracy: 0.9951
# Epoch 27/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0301 - accuracy: 0.9913
# Epoch 28/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0316 - accuracy: 0.9901
# Epoch 29/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0160 - accuracy: 0.9951
# Epoch 30/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0330 - accuracy: 0.9901
# Epoch 31/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0241 - accuracy: 0.9926
# Epoch 32/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0229 - accuracy: 0.9926
# Epoch 33/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0094 - accuracy: 0.9988
# Epoch 34/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0253 - accuracy: 0.9938
# Epoch 35/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0168 - accuracy: 0.9951
# Epoch 36/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0082 - accuracy: 0.9988
# Epoch 37/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0108 - accuracy: 0.9963
# Epoch 38/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0078 - accuracy: 0.9975
# Epoch 39/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0127 - accuracy: 0.9963
# Epoch 40/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0073 - accuracy: 1.0000
# Epoch 41/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0040 - accuracy: 1.0000
# Epoch 42/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0053 - accuracy: 1.0000
# Epoch 43/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0126 - accuracy: 0.9975
# Epoch 44/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0198 - accuracy: 0.9926
# Epoch 45/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0161 - accuracy: 0.9963
# Epoch 46/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0261 - accuracy: 0.9901
# Epoch 47/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0147 - accuracy: 0.9913
# Epoch 48/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0236 - accuracy: 0.9926
# Epoch 49/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0112 - accuracy: 0.9975
# Epoch 50/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0148 - accuracy: 0.9963
# Epoch 51/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0172 - accuracy: 0.9963
# Epoch 52/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0052 - accuracy: 1.0000
# Epoch 53/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0077 - accuracy: 0.9963
# Epoch 54/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 55/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0045 - accuracy: 0.9988
# Epoch 56/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0099 - accuracy: 0.9963
# Epoch 57/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 58/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0043 - accuracy: 0.9988
# Epoch 59/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0053 - accuracy: 0.9975
# Epoch 60/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 61/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0130 - accuracy: 0.9963
# Epoch 62/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0130 - accuracy: 0.9951
# Epoch 63/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0069 - accuracy: 0.9975
# Epoch 64/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0160 - accuracy: 0.9951
# Epoch 65/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0203 - accuracy: 0.9926
# Epoch 66/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0079 - accuracy: 0.9963
# Epoch 67/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 68/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0264 - accuracy: 0.9901
# Epoch 69/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0111 - accuracy: 0.9963
# Epoch 70/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0140 - accuracy: 0.9975
# Epoch 71/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0068 - accuracy: 0.9975
# Epoch 72/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0159 - accuracy: 0.9975
# Epoch 73/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 74/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0071 - accuracy: 0.9975
# Epoch 75/1500
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0137 - accuracy: 0.9951
# Epoch 76/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0141 - accuracy: 0.9963
# Epoch 77/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0114 - accuracy: 0.9951
# Epoch 78/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0180 - accuracy: 0.9938
# Epoch 79/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0107 - accuracy: 0.9988
# Epoch 80/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0139 - accuracy: 0.9938
# Epoch 81/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0064 - accuracy: 0.9975
# Epoch 82/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0193 - accuracy: 0.9926
# Epoch 83/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0088 - accuracy: 0.9975
# Epoch 84/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0252 - accuracy: 0.9938
# Epoch 85/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0082 - accuracy: 0.9975
# Epoch 86/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0041 - accuracy: 0.9988
# Epoch 87/1500
# 11/13 [========================>.....] - ETA: 0s - loss: 0.0024 - accuracy: 1.0000    Restoring model weights from the end of the best epoch: 57.
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0092 - accuracy: 0.9963
# Epoch 87: early stopping
# 5/5 [==============================] - 0s 2ms/step - loss: 3.1779 - accuracy: 0.5220
# 5/5 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.68 (17/25)
# Before appending - Cat IDs: 0, Predictions: 0, Actuals: 0, Gender: 0
# After appending - Cat IDs: 159, Predictions: 159, Actuals: 159, Gender: 159
# Final Test Results - Loss: 3.1779470443725586, Accuracy: 0.5220125913619995, Precision: 0.6004593381355047, Recall: 0.6209876543209877, F1 Score: 0.5553743825965255
# Confusion Matrix:
#  [[44 10  6]
#  [ 2 15  1]
#  [57  0 24]]
# outer_fold 2
# Train Set Group Distribution:
# 046A    66
# 000A    39
# 047A    30
# 020A    23
# 000B    20
#         ..
# 115A     1
# 090A     1
# 004A     1
# 026B     1
# 100A     1
# Name: cat_id, Length: 80, dtype: int64
# Testing Set Group Distribution:
# 002B    36
# 103A    33
# 057A    28
# 074A    25
# 019A    17
# 101A    16
# 028A    14
# 051A    12
# 036A    11
# 068A    11
# 016A    11
# 005A    11
# 015A    10
# 010A     8
# 027A     7
# 031A     7
# 044A     5
# 012A     5
# 035A     4
# 052A     4
# 014A     3
# 018A     2
# 054A     2
# 038A     2
# 087A     2
# 066A     2
# 091A     1
# 049A     1
# 048A     1
# 110A     1
# 073A     1
# 076A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    273
# M    202
# F    199
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# M    154
# X     82
# F     58
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [002A, 070A, 033A, 000B, 071A, 020A, 000A, 026...
# kitten    [046A, 042A, 014B, 109A, 040A, 047A, 045A, 111...
# senior    [117A, 106A, 090A, 113A, 051B, 116A, 024A, 097...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [028A, 015A, 038A, 068A, 018A, 002B, 005A, 091...
# kitten                             [110A, 049A, 048A, 044A]
# senior                             [057A, 051A, 016A, 054A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 50, 'kitten': 12, 'senior': 18}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 24, 'kitten': 4, 'senior': 4}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '003A' '004A' '006A' '007A' '008A' '009A'
#  '011A' '013B' '014B' '019B' '020A' '021A' '022A' '023A' '023B' '024A'
#  '025A' '025B' '025C' '026A' '026B' '026C' '029A' '032A' '033A' '034A'
#  '037A' '039A' '040A' '041A' '042A' '043A' '045A' '046A' '047A' '050A'
#  '051B' '053A' '055A' '056A' '058A' '059A' '060A' '061A' '062A' '063A'
#  '064A' '065A' '067A' '069A' '070A' '071A' '072A' '075A' '088A' '090A'
#  '092A' '093A' '094A' '095A' '096A' '097A' '097B' '099A' '100A' '102A'
#  '104A' '105A' '106A' '108A' '109A' '111A' '113A' '115A' '116A' '117A']
# Unique Test Group IDs:
# ['002B' '005A' '010A' '012A' '014A' '015A' '016A' '018A' '019A' '027A'
#  '028A' '031A' '035A' '036A' '038A' '044A' '048A' '049A' '051A' '052A'
#  '054A' '057A' '066A' '068A' '073A' '074A' '076A' '087A' '091A' '101A'
#  '103A' '110A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '003A' '004A' '006A' '007A' '008A' '009A'
#  '011A' '013B' '014B' '019B' '020A' '021A' '022A' '023A' '023B' '024A'
#  '025A' '025B' '025C' '026A' '026B' '026C' '029A' '032A' '033A' '034A'
#  '037A' '039A' '040A' '041A' '042A' '043A' '045A' '046A' '047A' '050A'
#  '051B' '053A' '055A' '056A' '058A' '059A' '060A' '061A' '062A' '063A'
#  '064A' '065A' '067A' '069A' '070A' '071A' '072A' '075A' '088A' '090A'
#  '092A' '093A' '094A' '095A' '096A' '097A' '097B' '099A' '100A' '102A'
#  '104A' '105A' '106A' '108A' '109A' '111A' '113A' '115A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['002B' '005A' '010A' '012A' '014A' '015A' '016A' '018A' '019A' '027A'
#  '028A' '031A' '035A' '036A' '038A' '044A' '048A' '049A' '051A' '052A'
#  '054A' '057A' '066A' '068A' '073A' '074A' '076A' '087A' '091A' '101A'
#  '103A' '110A']
# Length of X_train_val:
# 674
# Length of y_train_val:
# 674
# Length of groups_train_val:
# 674
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     373
# kitten    168
# senior    133
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     233
# senior     53
# kitten      8
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     373
# kitten    168
# senior    133
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     233
# senior     53
# kitten      8
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Age group distribution: Counter({0: 373, 1: 168, 2: 133})
# Epoch 1/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 1.3119 - accuracy: 0.5608
# Epoch 2/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.6322 - accuracy: 0.7478
# Epoch 3/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.4183 - accuracy: 0.8561
# Epoch 4/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.2118 - accuracy: 0.9214
# Epoch 5/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.2322 - accuracy: 0.9110
# Epoch 6/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.1786 - accuracy: 0.9318
# Epoch 7/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1160 - accuracy: 0.9688
# Epoch 8/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.1101 - accuracy: 0.9614
# Epoch 9/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0918 - accuracy: 0.9659
# Epoch 10/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0750 - accuracy: 0.9748
# Epoch 11/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0934 - accuracy: 0.9733
# Epoch 12/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0457 - accuracy: 0.9866
# Epoch 13/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0474 - accuracy: 0.9852
# Epoch 14/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0581 - accuracy: 0.9792
# Epoch 15/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0498 - accuracy: 0.9852
# Epoch 16/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0374 - accuracy: 0.9896
# Epoch 17/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0234 - accuracy: 0.9926
# Epoch 18/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0370 - accuracy: 0.9896
# Epoch 19/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0276 - accuracy: 0.9941
# Epoch 20/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0221 - accuracy: 0.9941
# Epoch 21/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0085 - accuracy: 1.0000
# Epoch 22/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0258 - accuracy: 0.9866
# Epoch 23/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0245 - accuracy: 0.9926
# Epoch 24/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0176 - accuracy: 0.9926
# Epoch 25/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0225 - accuracy: 0.9926
# Epoch 26/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0183 - accuracy: 0.9926
# Epoch 27/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0220 - accuracy: 0.9941
# Epoch 28/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0244 - accuracy: 0.9955
# Epoch 29/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0156 - accuracy: 0.9926
# Epoch 30/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0068 - accuracy: 1.0000
# Epoch 31/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0258 - accuracy: 0.9896
# Epoch 32/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0190 - accuracy: 0.9955
# Epoch 33/1500
# 11/11 [==============================] - 0s 17ms/step - loss: 0.0121 - accuracy: 0.9955
# Epoch 34/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0194 - accuracy: 0.9941
# Epoch 35/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0134 - accuracy: 0.9970
# Epoch 36/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0102 - accuracy: 0.9970
# Epoch 37/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0134 - accuracy: 0.9970
# Epoch 38/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0099 - accuracy: 0.9941
# Epoch 39/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0060 - accuracy: 0.9970
# Epoch 40/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0129 - accuracy: 0.9941
# Epoch 41/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0103 - accuracy: 0.9955
# Epoch 42/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 43/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0096 - accuracy: 0.9970
# Epoch 44/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0191 - accuracy: 0.9955
# Epoch 45/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0038 - accuracy: 0.9985
# Epoch 46/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0059 - accuracy: 0.9985
# Epoch 47/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0054 - accuracy: 0.9970
# Epoch 48/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 49/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 50/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0039 - accuracy: 0.9985
# Epoch 51/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0075 - accuracy: 0.9955
# Epoch 52/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0078 - accuracy: 0.9970
# Epoch 53/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0050 - accuracy: 1.0000
# Epoch 54/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0143 - accuracy: 0.9955
# Epoch 55/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0038 - accuracy: 0.9985
# Epoch 56/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0075 - accuracy: 0.9985
# Epoch 57/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0040 - accuracy: 0.9985
# Epoch 58/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0130 - accuracy: 0.9941
# Epoch 59/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0094 - accuracy: 0.9955
# Epoch 60/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0139 - accuracy: 0.9970
# Epoch 61/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 62/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0099 - accuracy: 0.9955
# Epoch 63/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0127 - accuracy: 0.9941
# Epoch 64/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0079 - accuracy: 0.9970
# Epoch 65/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0055 - accuracy: 0.9985
# Epoch 66/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0059 - accuracy: 0.9985
# Epoch 67/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0103 - accuracy: 0.9985
# Epoch 68/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0104 - accuracy: 0.9985
# Epoch 69/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0102 - accuracy: 0.9985
# Epoch 70/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0058 - accuracy: 0.9970
# Epoch 71/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 72/1500
# 11/11 [==============================] - ETA: 0s - loss: 0.0058 - accuracy: 0.9970Restoring model weights from the end of the best epoch: 42.
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0058 - accuracy: 0.9970
# Epoch 72: early stopping
# 10/10 [==============================] - 0s 1ms/step - loss: 1.8678 - accuracy: 0.7177
# 10/10 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.94 (30/32)
# Before appending - Cat IDs: 159, Predictions: 159, Actuals: 159, Gender: 159
# After appending - Cat IDs: 453, Predictions: 453, Actuals: 453, Gender: 453
# Final Test Results - Loss: 1.8678407669067383, Accuracy: 0.7176870703697205, Precision: 0.529345334412082, Recall: 0.7452155370205414, F1 Score: 0.579428122708305
# Confusion Matrix:
#  [[178  16  39]
#  [  0   8   0]
#  [ 28   0  25]]
# outer_fold 3
# Train Set Group Distribution:
# 046A    66
# 000A    39
# 002B    36
# 103A    33
# 047A    30
#         ..
# 049A     1
# 092A     1
# 048A     1
# 073A     1
# 100A     1
# Name: cat_id, Length: 84, dtype: int64
# Testing Set Group Distribution:
# 000B    20
# 106A    15
# 042A    14
# 097B    14
# 002A    13
# 111A    13
# 025A    11
# 071A    10
# 065A     9
# 033A     9
# 095A     8
# 094A     8
# 099A     7
# 037A     6
# 023A     6
# 075A     5
# 062A     5
# 023B     5
# 003A     4
# 105A     4
# 006A     3
# 056A     3
# 102A     2
# 061A     2
# 043A     1
# 090A     1
# 026C     1
# 019B     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    288
# M    285
# F    195
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# M    71
# X    67
# F    62
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [028A, 070A, 020A, 000A, 015A, 026A, 053A, 038...
# kitten    [046A, 014B, 110A, 109A, 040A, 047A, 049A, 045...
# senior    [117A, 057A, 113A, 051B, 116A, 051A, 024A, 097...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [002A, 033A, 000B, 071A, 065A, 023B, 026C, 105...
# kitten                                   [042A, 111A, 043A]
# senior                       [106A, 090A, 094A, 061A, 056A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 54, 'kitten': 13, 'senior': 17}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 20, 'kitten': 3, 'senior': 5}
# Unique Training/Validation Group IDs:
# ['000A' '001A' '002B' '004A' '005A' '007A' '008A' '009A' '010A' '011A'
#  '012A' '013B' '014A' '014B' '015A' '016A' '018A' '019A' '020A' '021A'
#  '022A' '024A' '025B' '025C' '026A' '026B' '027A' '028A' '029A' '031A'
#  '032A' '034A' '035A' '036A' '038A' '039A' '040A' '041A' '044A' '045A'
#  '046A' '047A' '048A' '049A' '050A' '051A' '051B' '052A' '053A' '054A'
#  '055A' '057A' '058A' '059A' '060A' '063A' '064A' '066A' '067A' '068A'
#  '069A' '070A' '072A' '073A' '074A' '076A' '087A' '088A' '091A' '092A'
#  '093A' '096A' '097A' '100A' '101A' '103A' '104A' '108A' '109A' '110A'
#  '113A' '115A' '116A' '117A']
# Unique Test Group IDs:
# ['000B' '002A' '003A' '006A' '019B' '023A' '023B' '025A' '026C' '033A'
#  '037A' '042A' '043A' '056A' '061A' '062A' '065A' '071A' '075A' '090A'
#  '094A' '095A' '097B' '099A' '102A' '105A' '106A' '111A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '001A' '002B' '004A' '005A' '007A' '008A' '009A' '010A' '011A'
#  '012A' '013B' '014A' '014B' '015A' '016A' '018A' '019A' '020A' '021A'
#  '022A' '024A' '025B' '025C' '026A' '026B' '027A' '028A' '029A' '031A'
#  '032A' '034A' '035A' '036A' '038A' '039A' '040A' '041A' '044A' '045A'
#  '046A' '047A' '048A' '049A' '050A' '051A' '051B' '052A' '053A' '054A'
#  '055A' '057A' '058A' '059A' '060A' '063A' '064A' '066A' '067A' '068A'
#  '069A' '070A' '072A' '073A' '074A' '076A' '087A' '088A' '091A' '092A'
#  '093A' '096A' '097A' '100A' '101A' '103A' '104A' '108A' '109A' '110A'
#  '113A' '115A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['000B' '002A' '003A' '006A' '019B' '023A' '023B' '025A' '026C' '033A'
#  '037A' '042A' '043A' '056A' '061A' '062A' '065A' '071A' '075A' '090A'
#  '094A' '095A' '097B' '099A' '102A' '105A' '106A' '111A']
# Length of X_train_val:
# 768
# Length of y_train_val:
# 768
# Length of groups_train_val:
# 768
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     463
# senior    157
# kitten    148
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     143
# senior     29
# kitten     28
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     463
# senior    157
# kitten    148
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     143
# senior     29
# kitten     28
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 463, 2: 157, 1: 148})
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Epoch 1/1500
# 12/12 [==============================] - 1s 4ms/step - loss: 1.3160 - accuracy: 0.5469
# Epoch 2/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.6143 - accuracy: 0.7656
# Epoch 3/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.4537 - accuracy: 0.8307
# Epoch 4/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3691 - accuracy: 0.8581
# Epoch 5/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.2683 - accuracy: 0.8997
# Epoch 6/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2359 - accuracy: 0.9102
# Epoch 7/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1600 - accuracy: 0.9388
# Epoch 8/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1165 - accuracy: 0.9635
# Epoch 9/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1093 - accuracy: 0.9661
# Epoch 10/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0961 - accuracy: 0.9661
# Epoch 11/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0832 - accuracy: 0.9727
# Epoch 12/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1031 - accuracy: 0.9688
# Epoch 13/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0705 - accuracy: 0.9766
# Epoch 14/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0802 - accuracy: 0.9753
# Epoch 15/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0433 - accuracy: 0.9883
# Epoch 16/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0604 - accuracy: 0.9779
# Epoch 17/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0393 - accuracy: 0.9896
# Epoch 18/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0541 - accuracy: 0.9779
# Epoch 19/1500
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0463 - accuracy: 0.9857
# Epoch 20/1500
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0396 - accuracy: 0.9883
# Epoch 21/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0232 - accuracy: 0.9922
# Epoch 22/1500
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0203 - accuracy: 0.9961
# Epoch 23/1500
# 12/12 [==============================] - 0s 17ms/step - loss: 0.0317 - accuracy: 0.9935
# Epoch 24/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0180 - accuracy: 0.9974
# Epoch 25/1500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0397 - accuracy: 0.9844
# Epoch 26/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0256 - accuracy: 0.9909
# Epoch 27/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0220 - accuracy: 0.9935
# Epoch 28/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0137 - accuracy: 0.9961
# Epoch 29/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0173 - accuracy: 0.9948
# Epoch 30/1500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0161 - accuracy: 0.9948
# Epoch 31/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0155 - accuracy: 0.9922
# Epoch 32/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0207 - accuracy: 0.9909
# Epoch 33/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0131 - accuracy: 0.9974
# Epoch 34/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0100 - accuracy: 0.9961
# Epoch 35/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0231 - accuracy: 0.9948
# Epoch 36/1500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0113 - accuracy: 0.9987
# Epoch 37/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0160 - accuracy: 0.9948
# Epoch 38/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0106 - accuracy: 0.9961
# Epoch 39/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0198 - accuracy: 0.9935
# Epoch 40/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0165 - accuracy: 0.9935
# Epoch 41/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0138 - accuracy: 0.9948
# Epoch 42/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0144 - accuracy: 0.9961
# Epoch 43/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0239 - accuracy: 0.9896
# Epoch 44/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0269 - accuracy: 0.9948
# Epoch 45/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0258 - accuracy: 0.9948
# Epoch 46/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0074 - accuracy: 0.9974
# Epoch 47/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0111 - accuracy: 0.9948
# Epoch 48/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0049 - accuracy: 0.9987
# Epoch 49/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0083 - accuracy: 0.9961
# Epoch 50/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0043 - accuracy: 0.9987
# Epoch 51/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0096 - accuracy: 0.9974
# Epoch 52/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0094 - accuracy: 0.9961
# Epoch 53/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0089 - accuracy: 0.9974
# Epoch 54/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0104 - accuracy: 0.9961
# Epoch 55/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0110 - accuracy: 0.9974
# Epoch 56/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0055 - accuracy: 0.9987
# Epoch 57/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0040 - accuracy: 0.9987
# Epoch 58/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0060 - accuracy: 0.9987
# Epoch 59/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0124 - accuracy: 0.9935
# Epoch 60/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0156 - accuracy: 0.9948
# Epoch 61/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0125 - accuracy: 0.9974
# Epoch 62/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0077 - accuracy: 0.9974
# Epoch 63/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0143 - accuracy: 0.9961
# Epoch 64/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0195 - accuracy: 0.9974
# Epoch 65/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0090 - accuracy: 0.9974
# Epoch 66/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0063 - accuracy: 0.9987
# Epoch 67/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0093 - accuracy: 0.9961
# Epoch 68/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 69/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 70/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 71/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0101 - accuracy: 0.9974
# Epoch 72/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0137 - accuracy: 0.9948
# Epoch 73/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0175 - accuracy: 0.9935
# Epoch 74/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0242 - accuracy: 0.9909
# Epoch 75/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0071 - accuracy: 0.9974
# Epoch 76/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0038 - accuracy: 0.9987
# Epoch 77/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0312 - accuracy: 0.9935
# Epoch 78/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0104 - accuracy: 0.9961
# Epoch 79/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 80/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0048 - accuracy: 0.9974
# Epoch 81/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0083 - accuracy: 0.9961
# Epoch 82/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 83/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 84/1500
# 12/12 [==============================] - 0s 15ms/step - loss: 0.0054 - accuracy: 0.9987
# Epoch 85/1500
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0091 - accuracy: 0.9987
# Epoch 86/1500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0114 - accuracy: 0.9948
# Epoch 87/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0061 - accuracy: 0.9987
# Epoch 88/1500
# 12/12 [==============================] - 0s 11ms/step - loss: 0.0085 - accuracy: 0.9961
# Epoch 89/1500
# 12/12 [==============================] - 0s 10ms/step - loss: 0.0042 - accuracy: 0.9987
# Epoch 90/1500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0046 - accuracy: 0.9974
# Epoch 91/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0047 - accuracy: 0.9987
# Epoch 92/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 93/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0071 - accuracy: 0.9974
# Epoch 94/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0037 - accuracy: 0.9987
# Epoch 95/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0116 - accuracy: 0.9974
# Epoch 96/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0074 - accuracy: 0.9961
# Epoch 97/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0318 - accuracy: 0.9909
# Epoch 98/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0102 - accuracy: 0.9961
# Epoch 99/1500
# 12/12 [==============================] - ETA: 0s - loss: 0.0030 - accuracy: 0.9987Restoring model weights from the end of the best epoch: 69.
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0030 - accuracy: 0.9987
# Epoch 99: early stopping
# 7/7 [==============================] - 0s 2ms/step - loss: 2.2396 - accuracy: 0.7250
# 7/7 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.79 (22/28)
# Before appending - Cat IDs: 453, Predictions: 453, Actuals: 453, Gender: 453
# After appending - Cat IDs: 653, Predictions: 653, Actuals: 653, Gender: 653
# Final Test Results - Loss: 2.239636182785034, Accuracy: 0.7250000238418579, Precision: 0.589567597153804, Recall: 0.5844500327258948, F1 Score: 0.5846803584615692
# Confusion Matrix:
#  [[119   9  15]
#  [  8  20   0]
#  [ 23   0   6]]
# outer_fold 4
# Train Set Group Distribution:
# 046A    66
# 002B    36
# 103A    33
# 057A    28
# 074A    25
#         ..
# 110A     1
# 048A     1
# 090A     1
# 049A     1
# 076A     1
# Name: cat_id, Length: 85, dtype: int64
# Testing Set Group Distribution:
# 000A    39
# 047A    30
# 020A    23
# 067A    20
# 029A    17
# 097A    16
# 001A    15
# 039A    12
# 014B    10
# 040A    10
# 022A     9
# 109A     6
# 021A     6
# 007A     6
# 034A     5
# 009A     4
# 104A     4
# 026A     4
# 113A     3
# 064A     3
# 032A     2
# 092A     1
# 096A     1
# 115A     1
# 004A     1
# 026B     1
# 100A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    266
# X    259
# F    193
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    96
# M    90
# F    64
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [002A, 028A, 070A, 033A, 000B, 071A, 015A, 065...
# kitten    [046A, 042A, 110A, 049A, 045A, 048A, 111A, 044...
# senior    [117A, 106A, 057A, 090A, 051B, 116A, 051A, 024...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [020A, 000A, 026A, 007A, 021A, 001A, 034A, 009...
# kitten                       [014B, 109A, 040A, 047A, 115A]
# senior                                   [113A, 097A, 104A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 55, 'kitten': 11, 'senior': 19}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 19, 'kitten': 5, 'senior': 3}
# Unique Training/Validation Group IDs:
# ['000B' '002A' '002B' '003A' '005A' '006A' '008A' '010A' '011A' '012A'
#  '013B' '014A' '015A' '016A' '018A' '019A' '019B' '023A' '023B' '024A'
#  '025A' '025B' '025C' '026C' '027A' '028A' '031A' '033A' '035A' '036A'
#  '037A' '038A' '041A' '042A' '043A' '044A' '045A' '046A' '048A' '049A'
#  '050A' '051A' '051B' '052A' '053A' '054A' '055A' '056A' '057A' '058A'
#  '059A' '060A' '061A' '062A' '063A' '065A' '066A' '068A' '069A' '070A'
#  '071A' '072A' '073A' '074A' '075A' '076A' '087A' '088A' '090A' '091A'
#  '093A' '094A' '095A' '097B' '099A' '101A' '102A' '103A' '105A' '106A'
#  '108A' '110A' '111A' '116A' '117A']
# Unique Test Group IDs:
# ['000A' '001A' '004A' '007A' '009A' '014B' '020A' '021A' '022A' '026A'
#  '026B' '029A' '032A' '034A' '039A' '040A' '047A' '064A' '067A' '092A'
#  '096A' '097A' '100A' '104A' '109A' '113A' '115A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'000A'}
# Removed from Training/Validation Set:
# {'025C'}
# Moved to Test Set:
# {'025C'}
# Removed from Test Set
# {'000A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '002A' '002B' '003A' '005A' '006A' '008A' '010A' '011A'
#  '012A' '013B' '014A' '015A' '016A' '018A' '019A' '019B' '023A' '023B'
#  '024A' '025A' '025B' '026C' '027A' '028A' '031A' '033A' '035A' '036A'
#  '037A' '038A' '041A' '042A' '043A' '044A' '045A' '046A' '048A' '049A'
#  '050A' '051A' '051B' '052A' '053A' '054A' '055A' '056A' '057A' '058A'
#  '059A' '060A' '061A' '062A' '063A' '065A' '066A' '068A' '069A' '070A'
#  '071A' '072A' '073A' '074A' '075A' '076A' '087A' '088A' '090A' '091A'
#  '093A' '094A' '095A' '097B' '099A' '101A' '102A' '103A' '105A' '106A'
#  '108A' '110A' '111A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['001A' '004A' '007A' '009A' '014B' '020A' '021A' '022A' '025C' '026A'
#  '026B' '029A' '032A' '034A' '039A' '040A' '047A' '064A' '067A' '092A'
#  '096A' '097A' '100A' '104A' '109A' '113A' '115A']
# Length of X_train_val:
# 751
# Length of y_train_val:
# 751
# Length of groups_train_val:
# 751
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     436
# senior    163
# kitten    119
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     170
# kitten     57
# senior     23
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     469
# senior    163
# kitten    119
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     137
# kitten     57
# senior     23
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 469, 2: 163, 1: 119})
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Epoch 1/1500
# 12/12 [==============================] - 1s 5ms/step - loss: 1.3416 - accuracy: 0.5060
# Epoch 2/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.6236 - accuracy: 0.7763
# Epoch 3/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.4259 - accuracy: 0.8429
# Epoch 4/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3259 - accuracy: 0.8775
# Epoch 5/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2473 - accuracy: 0.9148
# Epoch 6/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2123 - accuracy: 0.9308
# Epoch 7/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1416 - accuracy: 0.9521
# Epoch 8/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1399 - accuracy: 0.9534
# Epoch 9/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1339 - accuracy: 0.9481
# Epoch 10/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1044 - accuracy: 0.9601
# Epoch 11/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0824 - accuracy: 0.9734
# Epoch 12/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0792 - accuracy: 0.9734
# Epoch 13/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0591 - accuracy: 0.9814
# Epoch 14/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0449 - accuracy: 0.9854
# Epoch 15/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0729 - accuracy: 0.9747
# Epoch 16/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0396 - accuracy: 0.9840
# Epoch 17/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0314 - accuracy: 0.9893
# Epoch 18/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0435 - accuracy: 0.9827
# Epoch 19/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0395 - accuracy: 0.9907
# Epoch 20/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0239 - accuracy: 0.9973
# Epoch 21/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0204 - accuracy: 0.9933
# Epoch 22/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0288 - accuracy: 0.9933
# Epoch 23/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0195 - accuracy: 0.9933
# Epoch 24/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0227 - accuracy: 0.9947
# Epoch 25/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0211 - accuracy: 0.9933
# Epoch 26/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0301 - accuracy: 0.9867
# Epoch 27/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0244 - accuracy: 0.9933
# Epoch 28/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0146 - accuracy: 0.9973
# Epoch 29/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0100 - accuracy: 0.9947
# Epoch 30/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0157 - accuracy: 0.9973
# Epoch 31/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0137 - accuracy: 0.9973
# Epoch 32/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0093 - accuracy: 0.9987
# Epoch 33/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0114 - accuracy: 0.9947
# Epoch 34/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0115 - accuracy: 0.9973
# Epoch 35/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0113 - accuracy: 0.9973
# Epoch 36/1500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0115 - accuracy: 0.9973
# Epoch 37/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0132 - accuracy: 0.9947
# Epoch 38/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0113 - accuracy: 0.9960
# Epoch 39/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0184 - accuracy: 0.9933
# Epoch 40/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0200 - accuracy: 0.9920
# Epoch 41/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0183 - accuracy: 0.9947
# Epoch 42/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0055 - accuracy: 1.0000
# Epoch 43/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0065 - accuracy: 0.9973
# Epoch 44/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0072 - accuracy: 1.0000
# Epoch 45/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0069 - accuracy: 0.9987
# Epoch 46/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0087 - accuracy: 0.9987
# Epoch 47/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0081 - accuracy: 0.9987
# Epoch 48/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0084 - accuracy: 0.9987
# Epoch 49/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 50/1500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0063 - accuracy: 0.9987
# Epoch 51/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0081 - accuracy: 0.9960
# Epoch 52/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0039 - accuracy: 0.9987
# Epoch 53/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 54/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 55/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0080 - accuracy: 0.9987
# Epoch 56/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 57/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0048 - accuracy: 0.9987
# Epoch 58/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0049 - accuracy: 0.9987
# Epoch 59/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0063 - accuracy: 0.9973
# Epoch 60/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0069 - accuracy: 1.0000
# Epoch 61/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 62/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0118 - accuracy: 0.9960
# Epoch 63/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0032 - accuracy: 0.9987
# Epoch 64/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0050 - accuracy: 0.9973
# Epoch 65/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0040 - accuracy: 0.9987
# Epoch 66/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0038 - accuracy: 0.9987
# Epoch 67/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0112 - accuracy: 0.9973
# Epoch 68/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0168 - accuracy: 0.9960
# Epoch 69/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0141 - accuracy: 0.9960
# Epoch 70/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 71/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0204 - accuracy: 0.9973
# Epoch 72/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0287 - accuracy: 0.9907
# Epoch 73/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0082 - accuracy: 0.9960
# Epoch 74/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0049 - accuracy: 0.9987
# Epoch 75/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0163 - accuracy: 0.9947
# Epoch 76/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0168 - accuracy: 0.9960
# Epoch 77/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0073 - accuracy: 0.9987
# Epoch 78/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0260 - accuracy: 0.9920
# Epoch 79/1500
# 10/12 [========================>.....] - ETA: 0s - loss: 0.0118 - accuracy: 0.9953Restoring model weights from the end of the best epoch: 49.
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0163 - accuracy: 0.9947
# Epoch 79: early stopping
# 7/7 [==============================] - 0s 2ms/step - loss: 3.0049 - accuracy: 0.6774
# 7/7 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.78 (21/27)
# Before appending - Cat IDs: 653, Predictions: 653, Actuals: 653, Gender: 653
# After appending - Cat IDs: 870, Predictions: 870, Actuals: 870, Gender: 870
# Final Test Results - Loss: 3.0048770904541016, Accuracy: 0.6774193644523621, Precision: 0.6505063563887094, Recall: 0.5105944274629236, F1 Score: 0.5246916003854607
# Confusion Matrix:
#  [[125   4   8]
#  [ 43  13   1]
#  [ 14   0   9]]
#
# Final Average F1-Score across all UNSEEN TEST sets: 0.561043616037965
#
# Final Average Loss across all UNSEEN TEST sets: 2.572575271129608
#
# Final Average Accuracy across all UNSEEN TEST sets: 0.660529762506485
#
# Final Average Precision across all UNSEEN TEST sets: 0.5924696565225249
#
# Final Average Recall across all UNSEEN TEST sets: 0.6153119128825869

# %%
seed_1_folds_values = (unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1)

# Plotting all fold metrics
seed_1_folds_plot = plot_all_metrics(unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1, "Folds", "Fold Number")

# %% [markdown]
# ## Majority Voting on Total Entries per cat_id

# %%
# Debugging print statements
print(f'Checking - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
# Out:
# Checking - Cat IDs: 870, Predictions: 870, Actuals: 870, Gender: 870

# %%
# Create results df
full_results = pd.DataFrame({
    'cat_id': all_cat_ids,
    'predicted_age_group': all_predicted_age_groups,
    'actual_age_group': all_actual_age_groups,
    'all_gender': all_gender
})

# create a correct majority prediction column
full_results['correct'] = full_results['predicted_age_group'] == full_results['actual_age_group']

# %%
# Group by cat_id and aggregate predicted age groups
majority_votes = full_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first()

# Calculate the accuracy of majority voting
correct_predictions = (majority_votes == actual_groups).sum()
total_cats = len(actual_groups)
majority_vote_accuracy = correct_predictions / total_cats

logger(f"Overall Majority Vote Accuracy for cat_id: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

# store for final evaluation 
all_majority_vote_accuracies.append(majority_vote_accuracy)
# Out:
# Overall Majority Vote Accuracy for cat_id: 0.80 (88/110)

# %%
# Detailed df with predictions, actual labels, and comparison including majority vote
detailed_results = full_results.groupby('cat_id').apply(
    lambda x: pd.Series({
        'Predictions': list(x['predicted_age_group']),
        'Majority Vote': x['predicted_age_group'].mode()[0],
        'Actual Age Group': x['actual_age_group'].iloc[0],
        'Correct Majority Vote': x['predicted_age_group'].mode()[0] == x['actual_age_group'].iloc[0]
    })
).reset_index()

# Convert to DataFrame for better formatting and display
detailed_results = pd.DataFrame(detailed_results)

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 10)
pd.set_option('display.width', 1000)

sorted_detailed_results = detailed_results.sort_values(by='Correct Majority Vote', ascending=False)

# Display the sorted DataFrame
sorted_detailed_results
# Out:
#     cat_id                                        Predictions Majority Vote Actual Age Group  Correct Majority Vote
# 0     000B  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 60    054A                                   [senior, senior]        senior           senior                   True
# 75    069A                                     [adult, adult]         adult            adult                   True
# 74    068A  [adult, adult, adult, senior, senior, adult, a...         adult            adult                   True
# 73    067A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 72    066A                                    [adult, kitten]         adult            adult                   True
# 71    065A  [adult, adult, adult, kitten, adult, adult, ad...         adult            adult                   True
# 70    064A                              [adult, adult, adult]         adult            adult                   True
# 68    062A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 66    060A                            [kitten, adult, senior]         adult            adult                   True
# 65    059A  [senior, senior, senior, adult, adult, senior,...        senior           senior                   True
# 59    053A  [adult, adult, senior, adult, adult, adult, ad...         adult            adult                   True
# 46    040A  [kitten, adult, adult, kitten, kitten, adult, ...        kitten           kitten                   True
# 58    052A                      [adult, senior, adult, adult]         adult            adult                   True
# 56    051A  [adult, senior, senior, senior, senior, adult,...        senior           senior                   True
# 1     001A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 54    049A                                           [kitten]        kitten           kitten                   True
# 53    048A                                           [kitten]        kitten           kitten                   True
# 51    045A  [kitten, adult, kitten, kitten, kitten, kitten...        kitten           kitten                   True
# 50    044A           [kitten, kitten, kitten, kitten, kitten]        kitten           kitten                   True
# 49    043A                                           [kitten]        kitten           kitten                   True
# 48    042A  [kitten, kitten, kitten, adult, adult, kitten,...        kitten           kitten                   True
# 76    070A               [adult, senior, adult, adult, adult]         adult            adult                   True
# 77    071A  [adult, senior, adult, adult, adult, senior, s...         adult            adult                   True
# 78    072A  [adult, adult, adult, adult, adult, kitten, ad...         adult            adult                   True
# 79    073A                                            [adult]         adult            adult                   True
# 107   115A                                           [kitten]        kitten           kitten                   True
# 105   111A  [kitten, adult, kitten, kitten, kitten, kitten...        kitten           kitten                   True
# 104   110A                                   [kitten, kitten]        kitten           kitten                   True
# 100   105A                      [adult, adult, adult, kitten]         adult            adult                   True
# 98    103A  [adult, adult, senior, adult, adult, senior, a...         adult            adult                   True
# 97    102A                                     [adult, adult]         adult            adult                   True
# 96    101A  [adult, senior, adult, adult, adult, senior, s...         adult            adult                   True
# 95    100A                                            [adult]         adult            adult                   True
# 94    099A  [adult, adult, adult, kitten, adult, adult, ad...         adult            adult                   True
# 93    097B  [senior, adult, adult, adult, adult, adult, ad...         adult            adult                   True
# 91    096A                                            [adult]         adult            adult                   True
# 90    095A  [adult, adult, senior, senior, adult, adult, a...         adult            adult                   True
# 87    092A                                            [adult]         adult            adult                   True
# 86    091A                                            [adult]         adult            adult                   True
# 84    088A                                            [adult]         adult            adult                   True
# 83    087A                                     [adult, adult]         adult            adult                   True
# 82    076A                                            [adult]         adult            adult                   True
# 81    075A               [adult, senior, adult, adult, adult]         adult            adult                   True
# 80    074A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 47    041A                                           [kitten]        kitten           kitten                   True
# 55    050A  [kitten, kitten, kitten, senior, adult, kitten...        kitten           kitten                   True
# 45    039A  [senior, adult, adult, adult, adult, adult, ad...         adult            adult                   True
# 28    025A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 25    023A       [adult, kitten, senior, adult, adult, adult]         adult            adult                   True
# 24    022A  [adult, kitten, kitten, adult, adult, adult, a...         adult            adult                   True
# 23    021A         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 44    038A                                    [adult, kitten]         adult            adult                   True
# 21    019B                                            [adult]         adult            adult                   True
# 20    019A  [adult, kitten, kitten, adult, adult, adult, k...         adult            adult                   True
# 19    018A                                     [adult, adult]         adult            adult                   True
# 17    015A  [adult, adult, adult, adult, adult, adult, sen...         adult            adult                   True
# 15    014A                             [kitten, adult, adult]         adult            adult                   True
# 14    013B  [adult, adult, adult, adult, kitten, senior, a...         adult            adult                   True
# 13    012A               [adult, adult, adult, adult, kitten]         adult            adult                   True
# 11    010A  [adult, adult, adult, adult, adult, adult, sen...         adult            adult                   True
# 10    009A                      [adult, adult, senior, adult]         adult            adult                   True
# 9     008A         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 8     007A         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 7     006A                              [adult, adult, adult]         adult            adult                   True
# 6     005A  [adult, adult, adult, adult, senior, adult, se...         adult            adult                   True
# 5     004A                                            [adult]         adult            adult                   True
# 4     003A                      [adult, kitten, adult, adult]         adult            adult                   True
# 3     002B  [kitten, adult, adult, senior, senior, adult, ...         adult            adult                   True
# 2     002A  [adult, kitten, kitten, adult, adult, adult, s...         adult            adult                   True
# 27    024A                                           [senior]        senior           senior                   True
# 22    020A  [adult, adult, adult, adult, adult, adult, kit...         adult            adult                   True
# 29    025B                                    [senior, adult]         adult            adult                   True
# 34    027A  [adult, kitten, senior, adult, adult, adult, k...         adult            adult                   True
# 43    037A       [kitten, adult, senior, adult, adult, adult]         adult            adult                   True
# 42    036A  [senior, senior, senior, adult, adult, adult, ...         adult            adult                   True
# 41    035A                      [adult, senior, adult, adult]         adult            adult                   True
# 40    034A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 39    033A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 38    032A                                     [adult, adult]         adult            adult                   True
# 37    031A  [adult, adult, adult, adult, kitten, adult, se...         adult            adult                   True
# 36    029A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 30    025C  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 35    028A  [adult, adult, senior, adult, adult, adult, ad...         adult            adult                   True
# 109   117A  [adult, senior, senior, senior, adult, senior,...        senior           senior                   True
# 32    026B                                            [adult]         adult            adult                   True
# 31    026A                       [adult, adult, adult, adult]         adult            adult                   True
# 33    026C                                            [adult]         adult            adult                   True
# 67    061A                                     [adult, adult]         adult           senior                  False
# 108   116A  [senior, adult, senior, adult, adult, adult, s...         adult           senior                  False
# 26    023B             [adult, adult, senior, senior, senior]        senior            adult                  False
# 106   113A                             [adult, senior, adult]         adult           senior                  False
# 69    063A  [kitten, kitten, kitten, kitten, senior, adult...        kitten            adult                  False
# 103   109A      [adult, adult, kitten, kitten, kitten, adult]         adult           kitten                  False
# 102   108A        [adult, adult, adult, senior, adult, adult]         adult           senior                  False
# 101   106A  [adult, adult, adult, adult, adult, adult, sen...         adult           senior                  False
# 52    047A  [adult, adult, adult, adult, adult, adult, adu...         adult           kitten                  False
# 99    104A                      [senior, adult, adult, adult]         adult           senior                  False
# 85    090A                                            [adult]         adult           senior                  False
# 61    055A  [adult, adult, adult, senior, adult, senior, a...         adult           senior                  False
# 64    058A                              [adult, adult, adult]         adult           senior                  False
# 57    051B  [adult, adult, adult, adult, adult, adult, adu...         adult           senior                  False
# 63    057A  [adult, adult, senior, adult, adult, adult, se...         adult           senior                  False
# 92    097A  [adult, senior, senior, adult, senior, adult, ...         adult           senior                  False
# 18    016A  [adult, adult, adult, adult, adult, adult, sen...         adult           senior                  False
# 62    056A                             [adult, senior, adult]         adult           senior                  False
# 89    094A  [adult, senior, adult, senior, adult, senior, ...         adult           senior                  False
# 88    093A                                     [adult, adult]         adult           senior                  False
# 16    014B  [adult, adult, senior, adult, adult, kitten, a...         adult           kitten                  False
# 12    011A                              [adult, adult, adult]         adult           senior                  False

# %%
# Create df for majority votes
majority_df = majority_votes.reset_index()
majority_df.columns = ['cat_id', 'Majority_Vote']

# Get actual groups for each cat_id
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first().reset_index()

# Merge majority votes with actual groups
majority_with_actual = pd.merge(majority_df, actual_groups, on='cat_id')

# Add a column to check if the majority vote was correct
majority_with_actual['Majority_Correct'] = majority_with_actual['Majority_Vote'] == majority_with_actual['actual_age_group']

# Count correct majority votes per class
correct_majority_votes_per_class = majority_with_actual.groupby('actual_age_group')['Majority_Correct'].sum()

print("Correct Majority Votes per Class:")
print(correct_majority_votes_per_class)
# Out:
# Correct Majority Votes per Class:
# actual_age_group
# adult     71
# kitten    12
# senior     5
# Name: Majority_Correct, dtype: int64

# %%
# Calculate the total count and the number of correct predictions for each class
class_stats = majority_with_actual.groupby('actual_age_group').agg(
    total_count=('Majority_Correct', 'size'),  # Total number of cases per class
    correct_count=('Majority_Correct', 'sum')  # Sum of correct predictions per class
).reset_index()

# Calculate accuracy for each class
class_stats['accuracy'] = class_stats['correct_count'] / class_stats['total_count'] * 100

# store for final evaluation 
all_majority_vote_details.append(class_stats)

# Log detailed stats
print("Detailed Class Statistics for Majority Votes:")
print(class_stats)
# Out:
# Detailed Class Statistics for Majority Votes:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult           73             71  97.260274
# 1           kitten           15             12  80.000000
# 2           senior           22              5  22.727273

# %%
# Plot for Detailed Class Statistics for Majority Votes
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Accuracy of Majority Votes by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Detailed Class Statistics

# %%
# Calculate the total count and the number of correct predictions for each class
class_stats = full_results.groupby('actual_age_group').agg(
    total_count=('correct', 'size'),
    correct_count=('correct', 'sum')
).reset_index()

# Calculate accuracy for each class
class_stats['accuracy'] = class_stats['correct_count'] / class_stats['total_count'] * 100

# store for final evaluation 
all_class_stats.append(class_stats)

# Log the detailed stats
print("Detailed Class Statistics:")
print(class_stats)
# Out:
# Detailed Class Statistics:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult          573            466  81.326353
# 1           kitten          111             56  50.450450
# 2           senior          186             64  34.408602

# %%
# Plot for Detailed Class Statistics (Overall)
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Overall Accuracy by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Gender Exploration

# %%
# Group by gender and calculate the total count, correct predictions, and accuracy
gender_stats = full_results.groupby('all_gender').agg(
    count=('cat_id', 'size'),  # Total number of cases per gender
    correct=('correct', 'sum')  # Sum of correct predictions per gender
).reset_index()

# Calculate accuracy for each gender
gender_stats['accuracy'] = (gender_stats['correct'] / gender_stats['count'] * 100).round(2)

# Display the DataFrame
print("Accuracy by Gender:")
print(gender_stats)

# store for final evaluation 
all_gender_stats.append(gender_stats)
# Out:
# Accuracy by Gender:
#   all_gender  count  correct  accuracy
# 0          F    218      138     63.30
# 1          M    362      275     75.97
# 2          X    290      173     59.66

# %%
# Plot for Accuracy by Gender
styled_barplot(gender_stats, 'all_gender', 'accuracy', 
               'Accuracy by Gender', 
               'Gender', 'Accuracy (%)')

# %% [markdown]
# ### Log current total CV Stats

# %%
print("Total Majority Vote Accuracy so far:", all_majority_vote_accuracies)
print("Total Class Statistics so far:\n", all_class_stats)
print("Total Gender Accuracy so far:\n", all_gender_stats)
# Out:
# Total Majority Vote Accuracy so far: [0.8]
# Total Class Statistics so far:
#  [  actual_age_group  total_count  correct_count   accuracy
# 0            adult          573            466  81.326353
# 1           kitten          111             56  50.450450
# 2           senior          186             64  34.408602]
# Total Gender Accuracy so far:
#  [  all_gender  count  correct  accuracy
# 0          F    218      138     63.30
# 1          M    362      275     75.97
# 2          X    290      173     59.66]

# %% [markdown]
# # RANDOM SEED 2

# %%
# Set a fixed random seed for reproducibility
random.seed(int(random_seeds[1]))
np.random.seed(int(random_seeds[1]))
tf.random.set_seed(int(random_seeds[1]))

# Load datasets
dataframe = pd.read_csv('/Users/astrid/PycharmProjects/data-aug-and-more/yamnet-tfhub-extraction/yamnet_embeddings_looped_april_23.csv')

def assign_age_group(age, age_groups):
    for group_name, age_range in age_groups.items():
        if age_range[0] <= age < age_range[1]:
            return group_name
    return 'Unknown'  # For any age that doesn't fit the defined groups

# Define age groups
age_groups = {
    'kitten': (0, 0.5),
    'adult': (0.5, 12),
    'senior': (12, 20)
}

# Create a new column for the age group
dataframe['age_group'] = dataframe['target'].apply(assign_age_group, age_groups=age_groups)

print(dataframe['age_group'].value_counts())
# Out:
# adult     606
# senior    186
# kitten    176
# Name: age_group, dtype: int64

# %%
# Separate features and labels
X = dataframe.iloc[:, :-4].values  # all columns except the last four

# Encode the 'age_group' column as integers using LabelEncoder
label_encoder = LabelEncoder()
encoded_y = label_encoder.fit_transform(dataframe['age_group'].values)

# Use the encoded labels for splitting and one-hot encoding
y = encoded_y  

# Convert 'cat_id' column to numpy array to be used as groups array for GroupKFold
groups = dataframe['cat_id'].values

# %%
tf.keras.backend.clear_session()

# %% [markdown]
# ## Run Setup

# %%
all_cat_ids = []
all_predicted_age_groups = []
all_actual_age_groups = []
all_gender = []

# Define the StratifiedGroupKFold splitter for 4 fold CV with random shuffling
outer_cv = StratifiedGroupKFold(n_splits=4, shuffle=True, random_state=int(random_seeds[1]))

# unseen test set metrics
unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1 = [], [], [], [], []

outer_fold = 0

# Use the splitter to generate indices for training and testing sets
# Note: GroupShuffleSplit.split returns indices, so we use it to index the arrays
for train_val_idx, test_idx in outer_cv.split(X, y, groups):
    outer_fold += 1
    logger(f"outer_fold {outer_fold}", file=log_file_path)

    # Convert indices back to DataFrame for easy manipulation
    df_train_val = dataframe.iloc[train_val_idx]
    df_test = dataframe.iloc[test_idx]

    ##############################
    # ASSESSING SPLITS BY CAT_ID #
    ##############################
    
    # Get the distribution of groups
    training_validation_group_distribution = df_train_val['cat_id'].value_counts()  
    testing_group_distribution = df_test['cat_id'].value_counts()  
    
    # Log or print the distribution
    logger(f"Train Set Group Distribution:\n{training_validation_group_distribution}", file=log_file_path)
    logger(f"Testing Set Group Distribution:\n{testing_group_distribution}", file=log_file_path)

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val['gender'].value_counts()
    testing_gender_distribution = df_test['gender'].value_counts()
    
    # Log the distribution
    logger(f"Training Set Gender Distribution BEFORE SWAP:\n{training_gender_distribution}", file=log_file_path)
    logger(f"Testing Set Gender Distribution BEFORE SWAP:\n{testing_gender_distribution}", file=log_file_path)

    # Group by 'age_group' and then list unique 'cat_id' within each age group
    unique_cat_ids_per_age_group_train_val = df_train_val.groupby('age_group')['cat_id'].unique()
    unique_cat_ids_per_age_group_test = df_test.groupby('age_group')['cat_id'].unique()
    
    # Log results
    logger(f"Unique Cat IDs per Age Group in Training/Validation Set:\n{unique_cat_ids_per_age_group_train_val}", file=log_file_path)
    logger(f"Unique Cat IDs per Age Group in Testing Set:\n{unique_cat_ids_per_age_group_test}", file=log_file_path)

    # Calculate the count of unique identifiers per age group for training and testing set
    counts_train_val = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_train_val.items()}
    counts_test = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_test.items()}

    # Log the counts of unique identifiers per age group
    logger(f"Count of Unique Cat IDs per Age Group in Training/Validation Set:\n{counts_train_val}", file=log_file_path)
    logger(f"Count of Unique Cat IDs per Age Group in Testing Set:\n{counts_test}", file=log_file_path)

    #######################################################
    # CONTINUE WITH ENSURING VALID AND APPROPRIATE SPLITS #
    #######################################################
    
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    groups_train_val, groups_test = groups[train_val_idx], groups[test_idx]

    # logging identifier splits 
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)

    # check group splits
    check_initial_group_split(groups_train_val, groups_test)

    # Specify the cat_ids that must be in the training/validation set
    specific_cat_ids = ['000A', '046A']
    
    # Perform the swapping operation
    train_val_idx, test_idx = swap_cat_id_instances(dataframe, train_val_idx, test_idx, specific_cat_ids)
    
    # Re-assign the sets based on the updated indices
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    new_groups_train_val, new_groups_test = groups[train_val_idx], groups[test_idx]

    # Find differences for training and test sets
    moved_to_train_val, removed_from_train_val = find_group_differences(groups_train_val, new_groups_train_val)
    moved_to_test, removed_from_test = find_group_differences(groups_test, new_groups_test)
    
    # Display the results
    logger(f"Moved to Training/Validation Set:\n{moved_to_train_val}", file=log_file_path)
    logger(f"Removed from Training/Validation Set:\n{removed_from_train_val}", file=log_file_path)
    logger(f"Moved to Test Set:\n{moved_to_test}", file=log_file_path)
    logger(f"Removed from Test Set\n{removed_from_test}", file=log_file_path)

    # Update X_train_val, X_test, y_train_val, y_test, groups_train_val, groups_test based on updated indices
    X_train_val = X[train_val_idx]
    y_train_val = y[train_val_idx]
    groups_train_val = groups[train_val_idx]
    
    X_test = X[test_idx]
    y_test = y[test_idx]
    groups_test = groups[test_idx]

    # logging identifier splits again after potential swaps
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"AFTER SWAP - Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"AFTER SWAP - Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)
    
    # Verify the lengths are consistent
    logger(f"Length of X_train_val:\n{len(X_train_val)}", file=log_file_path)
    logger(f"Length of y_train_val:\n{len(y_train_val)}", file=log_file_path)
    logger(f"Length of groups_train_val:\n{len(groups_train_val)}", file=log_file_path)

    # Check group splits once more
    check_initial_group_split(groups_train_val, groups_test)

    # Convert the modified indices back to a DataFrame representing the updated df_train_val
    df_train_val_updated = dataframe.iloc[train_val_idx].copy()
    df_test_updated = dataframe.iloc[test_idx].copy()

    ############################
    # LOGGING AGE GROUP SPLITS #
    ############################

    # Get the distribution of age groups of age groups before the update
    training_validation_age_group_distribution = df_train_val['age_group'].value_counts()
    testing_age_group_distribution = df_test['age_group'].value_counts()
    
    # Logthe distribution
    logger(f"Train Age Group Distribution BEFORE SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution BEFORE SWAP:\n{testing_age_group_distribution}", file=log_file_path)

    # Get the distribution of age groups after the update
    training_validation_age_group_distribution = df_train_val_updated['age_group'].value_counts()
    testing_age_group_distribution = df_test_updated['age_group'].value_counts()
    
    # Log the distribution
    logger(f"Train Age Group Distribution AFTER SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution AFTER SWAP:\n{testing_age_group_distribution}", file=log_file_path)
    
    ########################################################
    # TRACKING FINAL CAT_IDs & GENDER AFTER REDISTRIBUTION #
    ########################################################

    # Get the distribution of groups
    training_validation_group_distribution = df_train_val_updated['cat_id'].value_counts()  
    testing_group_distribution = df_test_updated['cat_id'].value_counts()  

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val_updated['gender'].value_counts()
    testing_gender_distribution = df_test_updated['gender'].value_counts()
    
    logger(f"\n Starting training on unseen test set\n", file=log_file_path)

    ###################
    # PREPARING MODEL #
    ###################

    # Calculate the distribution of age groups in y_train_val
    age_group_distribution = Counter(y_train_val)
    print("Age group distribution:", age_group_distribution)

    # EarlyStopping callback: monitor 'loss' instead of 'val_loss' for the test set
    early_stopping = EarlyStopping(
        monitor='loss',  
        min_delta=0.001, 
        patience=30,  
        verbose=1,  
        restore_best_weights=True  
    )

    # One final shuffle to ensure randomness
    outer_shuffle_idx = np.random.permutation(len(X_train_val))
    X_train_val = X_train_val[outer_shuffle_idx]
    y_train_val = y_train_val[outer_shuffle_idx]
    
    # Scale the features
    scaler_full = StandardScaler().fit(X_train_val)
    X_train_full_scaled = scaler_full.transform(X_train_val)
    X_test_scaled = scaler_full.transform(X_test)
    
    # Convert features to TensorFlow tensors
    X_train_full_scaled = tf.convert_to_tensor(X_train_full_scaled, dtype=tf.float32)
    X_test_scaled = tf.convert_to_tensor(X_test_scaled, dtype=tf.float32)
    
    # One-hot encode labels before mixup
    y_train_full_encoded = to_categorical(y_train_val)
    y_test_encoded = to_categorical(y_test)
    
    # Convert labels to TensorFlow tensors
    y_train_full_encoded = tf.convert_to_tensor(y_train_full_encoded, dtype=tf.float32)
    
    # Apply Mixup
    X_train_mix_outer, y_train_mix_outer = mixup_data(X_train_full_scaled, y_train_full_encoded, alpha=0.2)
    
    #######################
    # BUILD & TRAIN MODEL #
    #######################

    optimizers = {
        'Adamax': Adamax(learning_rate=0.00510251984616472)
    }
    
    # Model definition with dynamic number of layers
    model_full = Sequential()
    model_full.add(Dense(480, activation='relu', input_shape=(X_train_full_scaled.shape[1],)))
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.2011047009431978))  
    model_full.add(Dense(256, activation='relu',)) 
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.14956886311951184))  
    model_full.add(Dense(256, activation='relu'))  
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.42291461228250665))  
    model_full.add(Dense(3, activation='softmax'))  
    
    # Use the optimizer from the parameters
    optimizer = optimizers['Adamax']  # optimizer_key from parameters
    
    # Compile the model
    model_full.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    
    # Train the model on the full training set
    history_full = model_full.fit(X_train_full_scaled, y_train_full_encoded, epochs=1500, batch_size=64,
                                  verbose=1, callbacks=[early_stopping])
    
    # Evaluate the model on the held-out test set
    test_loss, test_accuracy = model_full.evaluate(X_test_scaled, y_test_encoded)

    y_test_pred_prob = model_full.predict(X_test_scaled)
    y_test_pred = np.argmax(y_test_pred_prob, axis=1)  
    y_test_true = np.argmax(y_test_encoded, axis=1)    

    ################################
    # LOG MAJORITY VOTE PER CAT_ID #
    ################################

    # Convert numeric predictions back to age group labels
    predicted_age_groups = label_encoder.inverse_transform(y_test_pred)
    actual_labels = label_encoder.inverse_transform(y_test_true)
    
    # Map predictions and actual labels back to cat_ids
    test_results = pd.DataFrame({
        'cat_id': df_test_updated['cat_id'],
        'predicted_age_group': predicted_age_groups,
        'actual_age_group': actual_labels
    })
    
    # Group by cat_id and aggregate predicted age groups
    majority_votes = test_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
    actual_groups = test_results.groupby('cat_id')['actual_age_group'].first()
    
    # Calculate the accuracy of majority voting
    correct_predictions = (majority_votes == actual_groups).sum()
    total_cats = len(actual_groups)
    majority_vote_accuracy = correct_predictions / total_cats
    
    # Log the accuracy of the majority voting
    logger(f"Majority Vote Accuracy for cat_id for this fold: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

    ####################################################
    # COLLECT PREDICTIONS FOR GENDER & CAT_ID ANALYSIS #
    ####################################################

    # Debugging print statements
    print(f'Before appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Extend lists with current fold results
    all_cat_ids.extend(df_test_updated['cat_id'].tolist())
    all_predicted_age_groups.extend(predicted_age_groups)
    all_actual_age_groups.extend(actual_labels)
    all_gender.extend(df_test_updated['gender'].tolist())

    # Debugging print statements
    print(f'After appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Calculate additional metrics
    test_precision = precision_score(y_test_true, y_test_pred, average='macro')  # Use 'macro' for imbalanced datasets
    test_recall = recall_score(y_test_true, y_test_pred, average='macro')
    test_f1 = f1_score(y_test_true, y_test_pred, average='macro')

    # prepare averages of outer metrics
    unseen_f1.append(test_f1)
    unseen_losses.append(test_loss)
    unseen_accuracies.append(test_accuracy)
    unseen_precisions.append(test_precision)
    unseen_recalls.append(test_recall)

    # Print final test results
    logger(f"Final Test Results - Loss: {test_loss}, Accuracy: {test_accuracy}, Precision: {test_precision}, Recall: {test_recall}, F1 Score: {test_f1}", file=log_file_path)

    # Generate the confusion matrix
    cm = confusion_matrix(y_test, y_test_pred)
    logger(f"Confusion Matrix:\n {cm}", file=log_file_path)

# Calculate the overall average metrics
unseen_set_avg_f1 = np.mean(unseen_f1)
unseen_set_avg_loss = np.mean(unseen_losses)
unseen_set_avg_acc = np.mean(unseen_accuracies)
unseen_set_avg_precision = np.mean(unseen_precisions)
unseen_set_avg_recall = np.mean(unseen_recalls)

logger(f"\nFinal Average F1-Score across all UNSEEN TEST sets: {unseen_set_avg_f1}", file=log_file_path)
logger(f"\nFinal Average Loss across all UNSEEN TEST sets: {unseen_set_avg_loss}", file=log_file_path)
logger(f"\nFinal Average Accuracy across all UNSEEN TEST sets: {unseen_set_avg_acc}", file=log_file_path)
logger(f"\nFinal Average Precision across all UNSEEN TEST sets: {unseen_set_avg_precision}", file=log_file_path)
logger(f"\nFinal Average Recall across all UNSEEN TEST sets: {unseen_set_avg_recall}\n", file=log_file_path)

# Append averages to total lists
all_f1.append(unseen_set_avg_f1)
all_losses.append(unseen_set_avg_loss)
all_accuracies.append(unseen_set_avg_acc)
all_precisions.append(unseen_set_avg_precision)
all_recalls.append(unseen_set_avg_recall)
# Out:
# outer_fold 1
# Train Set Group Distribution:
# 000A    39
# 002B    36
# 047A    30
# 057A    28
# 074A    25
# 020A    23
# 000B    20
# 067A    20
# 055A    20
# 029A    17
# 019A    17
# 101A    16
# 097A    16
# 001A    15
# 042A    14
# 097B    14
# 028A    14
# 002A    13
# 039A    12
# 116A    12
# 005A    11
# 016A    11
# 040A    10
# 014B    10
# 071A    10
# 051B     9
# 022A     9
# 065A     9
# 072A     9
# 013B     8
# 095A     8
# 010A     8
# 117A     7
# 027A     7
# 050A     7
# 053A     7
# 031A     7
# 023A     6
# 037A     6
# 021A     6
# 025C     6
# 108A     6
# 008A     6
# 109A     6
# 007A     6
# 012A     5
# 034A     5
# 062A     5
# 070A     5
# 026A     4
# 009A     4
# 105A     4
# 003A     4
# 104A     4
# 058A     3
# 006A     3
# 113A     3
# 056A     3
# 011A     3
# 064A     3
# 060A     3
# 014A     3
# 087A     2
# 025B     2
# 093A     2
# 066A     2
# 054A     2
# 032A     2
# 102A     2
# 069A     2
# 038A     2
# 061A     2
# 073A     1
# 041A     1
# 026B     1
# 004A     1
# 076A     1
# 110A     1
# 115A     1
# 024A     1
# 091A     1
# 026C     1
# 049A     1
# 043A     1
# 096A     1
# 088A     1
# 100A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 046A    66
# 103A    33
# 059A    18
# 106A    15
# 111A    13
# 051A    12
# 063A    11
# 036A    11
# 068A    11
# 025A    11
# 015A    10
# 045A     9
# 033A     9
# 094A     8
# 099A     7
# 075A     5
# 023B     5
# 044A     5
# 035A     4
# 052A     4
# 018A     2
# 092A     1
# 048A     1
# 090A     1
# 019B     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    250
# X    223
# F    222
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    132
# M    106
# F     35
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [002A, 028A, 070A, 000B, 071A, 020A, 000A, 026...
# kitten    [042A, 014B, 110A, 109A, 040A, 047A, 049A, 043...
# senior    [117A, 057A, 113A, 051B, 116A, 024A, 097A, 055...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [033A, 015A, 023B, 068A, 018A, 103A, 063A, 075...
# kitten                       [046A, 045A, 048A, 111A, 044A]
# senior                       [106A, 090A, 051A, 094A, 059A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 59, 'kitten': 11, 'senior': 17}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 15, 'kitten': 5, 'senior': 5}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '004A' '005A' '006A' '007A'
#  '008A' '009A' '010A' '011A' '012A' '013B' '014A' '014B' '016A' '019A'
#  '020A' '021A' '022A' '023A' '024A' '025B' '025C' '026A' '026B' '026C'
#  '027A' '028A' '029A' '031A' '032A' '034A' '037A' '038A' '039A' '040A'
#  '041A' '042A' '043A' '047A' '049A' '050A' '051B' '053A' '054A' '055A'
#  '056A' '057A' '058A' '060A' '061A' '062A' '064A' '065A' '066A' '067A'
#  '069A' '070A' '071A' '072A' '073A' '074A' '076A' '087A' '088A' '091A'
#  '093A' '095A' '096A' '097A' '097B' '100A' '101A' '102A' '104A' '105A'
#  '108A' '109A' '110A' '113A' '115A' '116A' '117A']
# Unique Test Group IDs:
# ['015A' '018A' '019B' '023B' '025A' '033A' '035A' '036A' '044A' '045A'
#  '046A' '048A' '051A' '052A' '059A' '063A' '068A' '075A' '090A' '092A'
#  '094A' '099A' '103A' '106A' '111A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'046A'}
# Removed from Training/Validation Set:
# {'014B'}
# Moved to Test Set:
# {'014B'}
# Removed from Test Set
# {'046A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '004A' '005A' '006A' '007A'
#  '008A' '009A' '010A' '011A' '012A' '013B' '014A' '016A' '019A' '020A'
#  '021A' '022A' '023A' '024A' '025B' '025C' '026A' '026B' '026C' '027A'
#  '028A' '029A' '031A' '032A' '034A' '037A' '038A' '039A' '040A' '041A'
#  '042A' '043A' '046A' '047A' '049A' '050A' '051B' '053A' '054A' '055A'
#  '056A' '057A' '058A' '060A' '061A' '062A' '064A' '065A' '066A' '067A'
#  '069A' '070A' '071A' '072A' '073A' '074A' '076A' '087A' '088A' '091A'
#  '093A' '095A' '096A' '097A' '097B' '100A' '101A' '102A' '104A' '105A'
#  '108A' '109A' '110A' '113A' '115A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['014B' '015A' '018A' '019B' '023B' '025A' '033A' '035A' '036A' '044A'
#  '045A' '048A' '051A' '052A' '059A' '063A' '068A' '075A' '090A' '092A'
#  '094A' '099A' '103A' '106A' '111A']
# Length of X_train_val:
# 751
# Length of y_train_val:
# 751
# Length of groups_train_val:
# 751
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     481
# senior    132
# kitten     82
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     125
# kitten     94
# senior     54
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     481
# kitten    138
# senior    132
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     125
# senior     54
# kitten     38
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 481, 1: 138, 2: 132})
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Epoch 1/1500
# 12/12 [==============================] - 1s 4ms/step - loss: 1.3525 - accuracy: 0.5087
# Epoch 2/1500
# 12/12 [==============================] - 0s 16ms/step - loss: 0.7125 - accuracy: 0.7204
# Epoch 3/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.4408 - accuracy: 0.8269
# Epoch 4/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.3058 - accuracy: 0.8868
# Epoch 5/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2376 - accuracy: 0.9041
# Epoch 6/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1924 - accuracy: 0.9281
# Epoch 7/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1665 - accuracy: 0.9401
# Epoch 8/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1656 - accuracy: 0.9414
# Epoch 9/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1390 - accuracy: 0.9521
# Epoch 10/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1195 - accuracy: 0.9587
# Epoch 11/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1082 - accuracy: 0.9614
# Epoch 12/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0665 - accuracy: 0.9760
# Epoch 13/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0623 - accuracy: 0.9774
# Epoch 14/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0546 - accuracy: 0.9867
# Epoch 15/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0626 - accuracy: 0.9814
# Epoch 16/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0338 - accuracy: 0.9880
# Epoch 17/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0334 - accuracy: 0.9933
# Epoch 18/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0292 - accuracy: 0.9854
# Epoch 19/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0400 - accuracy: 0.9867
# Epoch 20/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0236 - accuracy: 0.9947
# Epoch 21/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0256 - accuracy: 0.9920
# Epoch 22/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0229 - accuracy: 0.9933
# Epoch 23/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0319 - accuracy: 0.9854
# Epoch 24/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0277 - accuracy: 0.9907
# Epoch 25/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0179 - accuracy: 0.9960
# Epoch 26/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0213 - accuracy: 0.9920
# Epoch 27/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0153 - accuracy: 0.9947
# Epoch 28/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0201 - accuracy: 0.9920
# Epoch 29/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0287 - accuracy: 0.9893
# Epoch 30/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0140 - accuracy: 0.9960
# Epoch 31/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0111 - accuracy: 0.9973
# Epoch 32/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0200 - accuracy: 0.9920
# Epoch 33/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0205 - accuracy: 0.9933
# Epoch 34/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0140 - accuracy: 0.9960
# Epoch 35/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0103 - accuracy: 0.9987
# Epoch 36/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0144 - accuracy: 0.9960
# Epoch 37/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0294 - accuracy: 0.9867
# Epoch 38/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0174 - accuracy: 0.9973
# Epoch 39/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0085 - accuracy: 0.9973
# Epoch 40/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0095 - accuracy: 0.9987
# Epoch 41/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0140 - accuracy: 0.9960
# Epoch 42/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0284 - accuracy: 0.9907
# Epoch 43/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0079 - accuracy: 0.9987
# Epoch 44/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0123 - accuracy: 0.9973
# Epoch 45/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0254 - accuracy: 0.9907
# Epoch 46/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0120 - accuracy: 0.9973
# Epoch 47/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0073 - accuracy: 0.9987
# Epoch 48/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0186 - accuracy: 0.9933
# Epoch 49/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0229 - accuracy: 0.9907
# Epoch 50/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0104 - accuracy: 0.9973
# Epoch 51/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0131 - accuracy: 0.9973
# Epoch 52/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0170 - accuracy: 0.9933
# Epoch 53/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0200 - accuracy: 0.9947
# Epoch 54/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0121 - accuracy: 0.9960
# Epoch 55/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0252 - accuracy: 0.9920
# Epoch 56/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0063 - accuracy: 0.9973
# Epoch 57/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0057 - accuracy: 0.9987
# Epoch 58/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0068 - accuracy: 0.9973
# Epoch 59/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0045 - accuracy: 0.9987
# Epoch 60/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0085 - accuracy: 0.9973
# Epoch 61/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0042 - accuracy: 1.0000
# Epoch 62/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0080 - accuracy: 0.9973
# Epoch 63/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0070 - accuracy: 0.9973
# Epoch 64/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0040 - accuracy: 1.0000
# Epoch 65/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0056 - accuracy: 1.0000
# Epoch 66/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0079 - accuracy: 0.9973
# Epoch 67/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0114 - accuracy: 0.9987
# Epoch 68/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0044 - accuracy: 0.9987
# Epoch 69/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0054 - accuracy: 0.9973
# Epoch 70/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0051 - accuracy: 1.0000
# Epoch 71/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 72/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0087 - accuracy: 0.9973
# Epoch 73/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 74/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 75/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 76/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 77/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 78/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0061 - accuracy: 0.9960
# Epoch 79/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 80/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 81/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 82/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 83/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0038 - accuracy: 0.9987
# Epoch 84/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0050 - accuracy: 0.9973
# Epoch 85/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0106 - accuracy: 0.9973
# Epoch 86/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0116 - accuracy: 0.9960
# Epoch 87/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0150 - accuracy: 0.9960
# Epoch 88/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0132 - accuracy: 0.9960
# Epoch 89/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0074 - accuracy: 0.9973
# Epoch 90/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0365 - accuracy: 0.9907
# Epoch 91/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0123 - accuracy: 0.9960
# Epoch 92/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0069 - accuracy: 0.9973
# Epoch 93/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0124 - accuracy: 0.9960
# Epoch 94/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0057 - accuracy: 0.9973
# Epoch 95/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0095 - accuracy: 0.9960
# Epoch 96/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0224 - accuracy: 0.9947
# Epoch 97/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0053 - accuracy: 0.9987
# Epoch 98/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0162 - accuracy: 0.9947
# Epoch 99/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0052 - accuracy: 0.9987
# Epoch 100/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0040 - accuracy: 0.9987
# Epoch 101/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0080 - accuracy: 0.9973
# Epoch 102/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 103/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 104/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0033 - accuracy: 0.9987
# Epoch 105/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0028 - accuracy: 0.9987
# Epoch 106/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 107/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0064 - accuracy: 0.9960
# Epoch 108/1500
# 12/12 [==============================] - 0s 18ms/step - loss: 0.0043 - accuracy: 0.9987
# Epoch 109/1500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 110/1500
# 12/12 [==============================] - 0s 10ms/step - loss: 0.0028 - accuracy: 0.9987
# Epoch 111/1500
# 12/12 [==============================] - 0s 16ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 112/1500
#  8/12 [===================>..........] - ETA: 0s - loss: 5.5554e-04 - accuracy: 1.0000Restoring model weights from the end of the best epoch: 82.
# 12/12 [==============================] - 0s 13ms/step - loss: 9.9727e-04 - accuracy: 1.0000
# Epoch 112: early stopping
# 7/7 [==============================] - 0s 4ms/step - loss: 6.5700 - accuracy: 0.6544
# 7/7 [==============================] - 0s 2ms/step
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Majority Vote Accuracy for cat_id for this fold: 0.80 (20/25)
# Before appending - Cat IDs: 0, Predictions: 0, Actuals: 0, Gender: 0
# After appending - Cat IDs: 217, Predictions: 217, Actuals: 217, Gender: 217
# Final Test Results - Loss: 6.569979667663574, Accuracy: 0.6543778777122498, Precision: 0.6470731368186874, Recall: 0.6163534762833008, F1 Score: 0.6290702051571616
# Confusion Matrix:
#  [[92  6 27]
#  [ 9 24  5]
#  [27  1 26]]
# outer_fold 2
# Train Set Group Distribution:
# 046A    66
# 000A    39
# 002B    36
# 103A    33
# 057A    28
# 074A    25
# 020A    23
# 055A    20
# 000B    20
# 059A    18
# 097A    16
# 101A    16
# 106A    15
# 001A    15
# 028A    14
# 097B    14
# 111A    13
# 002A    13
# 039A    12
# 051A    12
# 116A    12
# 016A    11
# 068A    11
# 063A    11
# 025A    11
# 036A    11
# 040A    10
# 014B    10
# 071A    10
# 015A    10
# 033A     9
# 045A     9
# 051B     9
# 072A     9
# 013B     8
# 094A     8
# 010A     8
# 053A     7
# 099A     7
# 117A     7
# 031A     7
# 027A     7
# 023A     6
# 108A     6
# 008A     6
# 037A     6
# 025C     6
# 007A     6
# 075A     5
# 034A     5
# 062A     5
# 070A     5
# 023B     5
# 044A     5
# 035A     4
# 026A     4
# 003A     4
# 009A     4
# 052A     4
# 056A     3
# 113A     3
# 011A     3
# 060A     3
# 018A     2
# 025B     2
# 038A     2
# 032A     2
# 054A     2
# 102A     2
# 026C     1
# 041A     1
# 019B     1
# 115A     1
# 110A     1
# 043A     1
# 090A     1
# 073A     1
# 088A     1
# 092A     1
# 048A     1
# 049A     1
# 026B     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 047A    30
# 067A    20
# 019A    17
# 029A    17
# 042A    14
# 005A    11
# 022A     9
# 065A     9
# 095A     8
# 050A     7
# 109A     6
# 021A     6
# 012A     5
# 104A     4
# 105A     4
# 014A     3
# 064A     3
# 058A     3
# 006A     3
# 061A     2
# 087A     2
# 066A     2
# 069A     2
# 093A     2
# 096A     1
# 024A     1
# 091A     1
# 076A     1
# 004A     1
# 100A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    272
# X    270
# F    231
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    85
# M    84
# F    26
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [002A, 028A, 070A, 033A, 000B, 071A, 020A, 000...
# kitten    [046A, 014B, 110A, 040A, 049A, 045A, 048A, 111...
# senior    [117A, 106A, 057A, 090A, 113A, 051B, 116A, 051...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [065A, 021A, 105A, 005A, 006A, 091A, 019A, 022...
# kitten                             [042A, 109A, 047A, 050A]
# senior                       [024A, 058A, 061A, 104A, 093A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 53, 'kitten': 12, 'senior': 17}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 21, 'kitten': 4, 'senior': 5}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '007A' '008A' '009A' '010A'
#  '011A' '013B' '014B' '015A' '016A' '018A' '019B' '020A' '023A' '023B'
#  '025A' '025B' '025C' '026A' '026B' '026C' '027A' '028A' '031A' '032A'
#  '033A' '034A' '035A' '036A' '037A' '038A' '039A' '040A' '041A' '043A'
#  '044A' '045A' '046A' '048A' '049A' '051A' '051B' '052A' '053A' '054A'
#  '055A' '056A' '057A' '059A' '060A' '062A' '063A' '068A' '070A' '071A'
#  '072A' '073A' '074A' '075A' '088A' '090A' '092A' '094A' '097A' '097B'
#  '099A' '101A' '102A' '103A' '106A' '108A' '110A' '111A' '113A' '115A'
#  '116A' '117A']
# Unique Test Group IDs:
# ['004A' '005A' '006A' '012A' '014A' '019A' '021A' '022A' '024A' '029A'
#  '042A' '047A' '050A' '058A' '061A' '064A' '065A' '066A' '067A' '069A'
#  '076A' '087A' '091A' '093A' '095A' '096A' '100A' '104A' '105A' '109A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '007A' '008A' '009A' '010A'
#  '011A' '013B' '014B' '015A' '016A' '018A' '019B' '020A' '023A' '023B'
#  '025A' '025B' '025C' '026A' '026B' '026C' '027A' '028A' '031A' '032A'
#  '033A' '034A' '035A' '036A' '037A' '038A' '039A' '040A' '041A' '043A'
#  '044A' '045A' '046A' '048A' '049A' '051A' '051B' '052A' '053A' '054A'
#  '055A' '056A' '057A' '059A' '060A' '062A' '063A' '068A' '070A' '071A'
#  '072A' '073A' '074A' '075A' '088A' '090A' '092A' '094A' '097A' '097B'
#  '099A' '101A' '102A' '103A' '106A' '108A' '110A' '111A' '113A' '115A'
#  '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['004A' '005A' '006A' '012A' '014A' '019A' '021A' '022A' '024A' '029A'
#  '042A' '047A' '050A' '058A' '061A' '064A' '065A' '066A' '067A' '069A'
#  '076A' '087A' '091A' '093A' '095A' '096A' '100A' '104A' '105A' '109A']
# Length of X_train_val:
# 773
# Length of y_train_val:
# 773
# Length of groups_train_val:
# 773
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     480
# senior    174
# kitten    119
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     126
# kitten     57
# senior     12
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     480
# senior    174
# kitten    119
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     126
# kitten     57
# senior     12
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 480, 2: 174, 1: 119})
# Epoch 1/1500
# 13/13 [==============================] - 1s 4ms/step - loss: 1.2501 - accuracy: 0.5459
# Epoch 2/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.6571 - accuracy: 0.7814
# Epoch 3/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4915 - accuracy: 0.8176
# Epoch 4/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3530 - accuracy: 0.8642
# Epoch 5/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2917 - accuracy: 0.8952
# Epoch 6/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2074 - accuracy: 0.9301
# Epoch 7/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2058 - accuracy: 0.9211
# Epoch 8/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2133 - accuracy: 0.9198
# Epoch 9/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1855 - accuracy: 0.9353
# Epoch 10/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1347 - accuracy: 0.9560
# Epoch 11/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1398 - accuracy: 0.9483
# Epoch 12/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1524 - accuracy: 0.9379
# Epoch 13/1500
# 13/13 [==============================] - 0s 7ms/step - loss: 0.1386 - accuracy: 0.9521
# Epoch 14/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0995 - accuracy: 0.9728
# Epoch 15/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0968 - accuracy: 0.9664
# Epoch 16/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0835 - accuracy: 0.9741
# Epoch 17/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0904 - accuracy: 0.9690
# Epoch 18/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0743 - accuracy: 0.9780
# Epoch 19/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0790 - accuracy: 0.9728
# Epoch 20/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0734 - accuracy: 0.9767
# Epoch 21/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0993 - accuracy: 0.9612
# Epoch 22/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0735 - accuracy: 0.9715
# Epoch 23/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0876 - accuracy: 0.9741
# Epoch 24/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0618 - accuracy: 0.9806
# Epoch 25/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0739 - accuracy: 0.9793
# Epoch 26/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0542 - accuracy: 0.9832
# Epoch 27/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0814 - accuracy: 0.9690
# Epoch 28/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0942 - accuracy: 0.9664
# Epoch 29/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0769 - accuracy: 0.9728
# Epoch 30/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0571 - accuracy: 0.9819
# Epoch 31/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0625 - accuracy: 0.9767
# Epoch 32/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0747 - accuracy: 0.9690
# Epoch 33/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0665 - accuracy: 0.9767
# Epoch 34/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0617 - accuracy: 0.9767
# Epoch 35/1500
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0501 - accuracy: 0.9832
# Epoch 36/1500
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0851 - accuracy: 0.9728
# Epoch 37/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0716 - accuracy: 0.9793
# Epoch 38/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0604 - accuracy: 0.9780
# Epoch 39/1500
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0724 - accuracy: 0.9728
# Epoch 40/1500
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0526 - accuracy: 0.9806
# Epoch 41/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0567 - accuracy: 0.9767
# Epoch 42/1500
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0372 - accuracy: 0.9884
# Epoch 43/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0386 - accuracy: 0.9884
# Epoch 44/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0302 - accuracy: 0.9909
# Epoch 45/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0375 - accuracy: 0.9884
# Epoch 46/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0220 - accuracy: 0.9974
# Epoch 47/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0392 - accuracy: 0.9832
# Epoch 48/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0399 - accuracy: 0.9832
# Epoch 49/1500
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0432 - accuracy: 0.9858
# Epoch 50/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0265 - accuracy: 0.9922
# Epoch 51/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0414 - accuracy: 0.9871
# Epoch 52/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0279 - accuracy: 0.9871
# Epoch 53/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0292 - accuracy: 0.9909
# Epoch 54/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0394 - accuracy: 0.9858
# Epoch 55/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0369 - accuracy: 0.9884
# Epoch 56/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0277 - accuracy: 0.9909
# Epoch 57/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0371 - accuracy: 0.9935
# Epoch 58/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0416 - accuracy: 0.9858
# Epoch 59/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0242 - accuracy: 0.9922
# Epoch 60/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0264 - accuracy: 0.9922
# Epoch 61/1500
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0367 - accuracy: 0.9897
# Epoch 62/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0287 - accuracy: 0.9909
# Epoch 63/1500
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0499 - accuracy: 0.9793
# Epoch 64/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0484 - accuracy: 0.9832
# Epoch 65/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0311 - accuracy: 0.9909
# Epoch 66/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0634 - accuracy: 0.9741
# Epoch 67/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0292 - accuracy: 0.9922
# Epoch 68/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0324 - accuracy: 0.9884
# Epoch 69/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0262 - accuracy: 0.9922
# Epoch 70/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0337 - accuracy: 0.9897
# Epoch 71/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0345 - accuracy: 0.9935
# Epoch 72/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0370 - accuracy: 0.9884
# Epoch 73/1500
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0287 - accuracy: 0.9845
# Epoch 74/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0344 - accuracy: 0.9948
# Epoch 75/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0222 - accuracy: 0.9909
# Epoch 76/1500
# 10/13 [======================>.......] - ETA: 0s - loss: 0.0327 - accuracy: 0.9859Restoring model weights from the end of the best epoch: 46.
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0366 - accuracy: 0.9845
# Epoch 76: early stopping
# 7/7 [==============================] - 0s 1ms/step - loss: 2.5439 - accuracy: 0.6154
# 7/7 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.77 (23/30)
# Before appending - Cat IDs: 217, Predictions: 217, Actuals: 217, Gender: 217
# After appending - Cat IDs: 412, Predictions: 412, Actuals: 412, Gender: 412
# Final Test Results - Loss: 2.543889045715332, Accuracy: 0.6153846383094788, Precision: 0.49983692106979777, Recall: 0.5162907268170426, F1 Score: 0.48150623885918
# Confusion Matrix:
#  [[99 13 14]
#  [41 15  1]
#  [ 6  0  6]]
# outer_fold 3
# Train Set Group Distribution:
# 046A    66
# 000A    39
# 103A    33
# 047A    30
# 074A    25
# 055A    20
# 000B    20
# 067A    20
# 059A    18
# 029A    17
# 019A    17
# 097A    16
# 106A    15
# 042A    14
# 097B    14
# 111A    13
# 051A    12
# 068A    11
# 063A    11
# 005A    11
# 025A    11
# 036A    11
# 040A    10
# 015A    10
# 022A     9
# 033A     9
# 045A     9
# 051B     9
# 072A     9
# 065A     9
# 095A     8
# 094A     8
# 010A     8
# 099A     7
# 027A     7
# 053A     7
# 050A     7
# 031A     7
# 025C     6
# 023A     6
# 021A     6
# 109A     6
# 012A     5
# 044A     5
# 075A     5
# 023B     5
# 035A     4
# 052A     4
# 104A     4
# 105A     4
# 026A     4
# 003A     4
# 064A     3
# 006A     3
# 014A     3
# 011A     3
# 058A     3
# 056A     3
# 087A     2
# 025B     2
# 066A     2
# 061A     2
# 093A     2
# 069A     2
# 018A     2
# 019B     1
# 041A     1
# 115A     1
# 004A     1
# 026B     1
# 076A     1
# 073A     1
# 110A     1
# 090A     1
# 088A     1
# 096A     1
# 043A     1
# 091A     1
# 024A     1
# 092A     1
# 048A     1
# 100A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 002B    36
# 057A    28
# 020A    23
# 101A    16
# 001A    15
# 028A    14
# 002A    13
# 116A    12
# 039A    12
# 016A    11
# 014B    10
# 071A    10
# 013B     8
# 117A     7
# 007A     6
# 037A     6
# 008A     6
# 108A     6
# 070A     5
# 034A     5
# 062A     5
# 009A     4
# 060A     3
# 113A     3
# 102A     2
# 054A     2
# 032A     2
# 038A     2
# 026C     1
# 049A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    274
# M    257
# F    163
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# M    99
# F    94
# X    81
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [033A, 000B, 000A, 015A, 026A, 065A, 053A, 023...
# kitten    [046A, 042A, 110A, 109A, 040A, 047A, 045A, 048...
# senior    [106A, 090A, 051B, 051A, 024A, 097A, 094A, 059...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [002A, 028A, 070A, 071A, 020A, 038A, 026C, 007...
# kitten                                         [014B, 049A]
# senior           [117A, 057A, 113A, 116A, 016A, 054A, 108A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 53, 'kitten': 14, 'senior': 15}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 21, 'kitten': 2, 'senior': 7}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '003A' '004A' '005A' '006A' '010A' '011A' '012A' '014A'
#  '015A' '018A' '019A' '019B' '021A' '022A' '023A' '023B' '024A' '025A'
#  '025B' '025C' '026A' '026B' '027A' '029A' '031A' '033A' '035A' '036A'
#  '040A' '041A' '042A' '043A' '044A' '045A' '046A' '047A' '048A' '050A'
#  '051A' '051B' '052A' '053A' '055A' '056A' '058A' '059A' '061A' '063A'
#  '064A' '065A' '066A' '067A' '068A' '069A' '072A' '073A' '074A' '075A'
#  '076A' '087A' '088A' '090A' '091A' '092A' '093A' '094A' '095A' '096A'
#  '097A' '097B' '099A' '100A' '103A' '104A' '105A' '106A' '109A' '110A'
#  '111A' '115A']
# Unique Test Group IDs:
# ['001A' '002A' '002B' '007A' '008A' '009A' '013B' '014B' '016A' '020A'
#  '026C' '028A' '032A' '034A' '037A' '038A' '039A' '049A' '054A' '057A'
#  '060A' '062A' '070A' '071A' '101A' '102A' '108A' '113A' '116A' '117A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '003A' '004A' '005A' '006A' '010A' '011A' '012A' '014A'
#  '015A' '018A' '019A' '019B' '021A' '022A' '023A' '023B' '024A' '025A'
#  '025B' '025C' '026A' '026B' '027A' '029A' '031A' '033A' '035A' '036A'
#  '040A' '041A' '042A' '043A' '044A' '045A' '046A' '047A' '048A' '050A'
#  '051A' '051B' '052A' '053A' '055A' '056A' '058A' '059A' '061A' '063A'
#  '064A' '065A' '066A' '067A' '068A' '069A' '072A' '073A' '074A' '075A'
#  '076A' '087A' '088A' '090A' '091A' '092A' '093A' '094A' '095A' '096A'
#  '097A' '097B' '099A' '100A' '103A' '104A' '105A' '106A' '109A' '110A'
#  '111A' '115A']

# %%
seed_2_folds_values = (unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1)

# Plotting all fold metrics
seed_2_folds_plot = plot_all_metrics(unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1, "Folds", "Fold Number")

# %% [markdown]
# ## Majority Voting on Total Entries per cat_id

# %%
# Debugging print statements
print(f'Checking - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')

# %%
# Create results df
full_results = pd.DataFrame({
    'cat_id': all_cat_ids,
    'predicted_age_group': all_predicted_age_groups,
    'actual_age_group': all_actual_age_groups,
    'all_gender': all_gender
})

# create a correct majority prediction column
full_results['correct'] = full_results['predicted_age_group'] == full_results['actual_age_group']

# %%
# Group by cat_id and aggregate predicted age groups
majority_votes = full_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first()

# Calculate the accuracy of majority voting
correct_predictions = (majority_votes == actual_groups).sum()
total_cats = len(actual_groups)
majority_vote_accuracy = correct_predictions / total_cats

logger(f"Overall Majority Vote Accuracy for cat_id: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

# store for final evaluation 
all_majority_vote_accuracies.append(majority_vote_accuracy)

# %%
# Detailed df with predictions, actual labels, and comparison including majority vote
detailed_results = full_results.groupby('cat_id').apply(
    lambda x: pd.Series({
        'Predictions': list(x['predicted_age_group']),
        'Majority Vote': x['predicted_age_group'].mode()[0],
        'Actual Age Group': x['actual_age_group'].iloc[0],
        'Correct Majority Vote': x['predicted_age_group'].mode()[0] == x['actual_age_group'].iloc[0]
    })
).reset_index()

# Convert to DataFrame for better formatting and display
detailed_results = pd.DataFrame(detailed_results)

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 10)
pd.set_option('display.width', 1000)

sorted_detailed_results = detailed_results.sort_values(by='Correct Majority Vote', ascending=False)

# Display the sorted DataFrame
sorted_detailed_results

# %%
# Create df for majority votes
majority_df = majority_votes.reset_index()
majority_df.columns = ['cat_id', 'Majority_Vote']

# Get actual groups for each cat_id
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first().reset_index()

# Merge majority votes with actual groups
majority_with_actual = pd.merge(majority_df, actual_groups, on='cat_id')

# Add a column to check if the majority vote was correct
majority_with_actual['Majority_Correct'] = majority_with_actual['Majority_Vote'] == majority_with_actual['actual_age_group']

# Count correct majority votes per class
correct_majority_votes_per_class = majority_with_actual.groupby('actual_age_group')['Majority_Correct'].sum()

print("Correct Majority Votes per Class:")
print(correct_majority_votes_per_class)

# %%
# Calculate the total count and the number of correct predictions for each class
class_stats = majority_with_actual.groupby('actual_age_group').agg(
    total_count=('Majority_Correct', 'size'),  # Total number of cases per class
    correct_count=('Majority_Correct', 'sum')  # Sum of correct predictions per class
).reset_index()

# Calculate accuracy for each class
class_stats['accuracy'] = class_stats['correct_count'] / class_stats['total_count'] * 100

# store for final evaluation 
all_majority_vote_details.append(class_stats)

# Log detailed stats
print("Detailed Class Statistics for Majority Votes:")
print(class_stats)

# %%
# Plot for Detailed Class Statistics for Majority Votes
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Accuracy of Majority Votes by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Detailed Class Statistics

# %%
# Calculate the total count and the number of correct predictions for each class
class_stats = full_results.groupby('actual_age_group').agg(
    total_count=('correct', 'size'),
    correct_count=('correct', 'sum')
).reset_index()

# Calculate accuracy for each class
class_stats['accuracy'] = class_stats['correct_count'] / class_stats['total_count'] * 100

# store for final evaluation 
all_class_stats.append(class_stats)

# Log the detailed stats
print("Detailed Class Statistics:")
print(class_stats)

# %%
# Plot for Detailed Class Statistics (Overall)
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Overall Accuracy by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Gender Exploration

# %%
# Group by gender and calculate the total count, correct predictions, and accuracy
gender_stats = full_results.groupby('all_gender').agg(
    count=('cat_id', 'size'),  # Total number of cases per gender
    correct=('correct', 'sum')  # Sum of correct predictions per gender
).reset_index()

# Calculate accuracy for each gender
gender_stats['accuracy'] = (gender_stats['correct'] / gender_stats['count'] * 100).round(2)

# Display the DataFrame
print("Accuracy by Gender:")
print(gender_stats)

# store for final evaluation 
all_gender_stats.append(gender_stats)

# %%
# Plot for Accuracy by Gender
styled_barplot(gender_stats, 'all_gender', 'accuracy', 
               'Accuracy by Gender', 
               'Gender', 'Accuracy (%)')

# %% [markdown]
# ### Log current total CV Stats

# %%
print("Total Majority Vote Accuracy so far:", all_majority_vote_accuracies)
print("Total Class Statistics so far:\n", all_class_stats)
print("Total Gender Accuracy so far:\n", all_gender_stats)

# %% [markdown]
# # RANDOM SEED 3

# %%
# Set a fixed random seed for reproducibility
random.seed(int(random_seeds[2]))
np.random.seed(int(random_seeds[2]))
tf.random.set_seed(int(random_seeds[2]))

# Load datasets
dataframe = pd.read_csv('/Users/astrid/PycharmProjects/data-aug-and-more/yamnet-tfhub-extraction/yamnet_embeddings_looped_april_23.csv')

def assign_age_group(age, age_groups):
    for group_name, age_range in age_groups.items():
        if age_range[0] <= age < age_range[1]:
            return group_name
    return 'Unknown'  # For any age that doesn't fit the defined groups

# Define age groups
age_groups = {
    'kitten': (0, 0.5),
    'adult': (0.5, 12),
    'senior': (12, 20)
}

# Create a new column for the age group
dataframe['age_group'] = dataframe['target'].apply(assign_age_group, age_groups=age_groups)

print(dataframe['age_group'].value_counts())

# %%
# Separate features and labels
X = dataframe.iloc[:, :-4].values  # all columns except the last four

# Encode the 'age_group' column as integers using LabelEncoder
label_encoder = LabelEncoder()
encoded_y = label_encoder.fit_transform(dataframe['age_group'].values)

# Use the encoded labels for splitting and one-hot encoding
y = encoded_y  

# Convert 'cat_id' column to numpy array to be used as groups array for GroupKFold
groups = dataframe['cat_id'].values

# %%
tf.keras.backend.clear_session()

# %% [markdown]
# ## Run Setup

# %%
all_cat_ids = []
all_predicted_age_groups = []
all_actual_age_groups = []
all_gender = []

# Define the StratifiedGroupKFold splitter for 4 fold CV with random shuffling
outer_cv = StratifiedGroupKFold(n_splits=4, shuffle=True, random_state=int(random_seeds[2]))

# unseen test set metrics
unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1 = [], [], [], [], []

outer_fold = 0

# Use the splitter to generate indices for training and testing sets
# Note: GroupShuffleSplit.split returns indices, so we use it to index the arrays
for train_val_idx, test_idx in outer_cv.split(X, y, groups):
    outer_fold += 1
    logger(f"outer_fold {outer_fold}", file=log_file_path)

    # Convert indices back to DataFrame for easy manipulation
    df_train_val = dataframe.iloc[train_val_idx]
    df_test = dataframe.iloc[test_idx]

    ##############################
    # ASSESSING SPLITS BY CAT_ID #
    ##############################
    
    # Get the distribution of groups
    training_validation_group_distribution = df_train_val['cat_id'].value_counts()  
    testing_group_distribution = df_test['cat_id'].value_counts()  
    
    # Log or print the distribution
    logger(f"Train Set Group Distribution:\n{training_validation_group_distribution}", file=log_file_path)
    logger(f"Testing Set Group Distribution:\n{testing_group_distribution}", file=log_file_path)

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val['gender'].value_counts()
    testing_gender_distribution = df_test['gender'].value_counts()
    
    # Log the distribution
    logger(f"Training Set Gender Distribution BEFORE SWAP:\n{training_gender_distribution}", file=log_file_path)
    logger(f"Testing Set Gender Distribution BEFORE SWAP:\n{testing_gender_distribution}", file=log_file_path)

    # Group by 'age_group' and then list unique 'cat_id' within each age group
    unique_cat_ids_per_age_group_train_val = df_train_val.groupby('age_group')['cat_id'].unique()
    unique_cat_ids_per_age_group_test = df_test.groupby('age_group')['cat_id'].unique()
    
    # Log results
    logger(f"Unique Cat IDs per Age Group in Training/Validation Set:\n{unique_cat_ids_per_age_group_train_val}", file=log_file_path)
    logger(f"Unique Cat IDs per Age Group in Testing Set:\n{unique_cat_ids_per_age_group_test}", file=log_file_path)

    # Calculate the count of unique identifiers per age group for training and testing set
    counts_train_val = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_train_val.items()}
    counts_test = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_test.items()}

    # Log the counts of unique identifiers per age group
    logger(f"Count of Unique Cat IDs per Age Group in Training/Validation Set:\n{counts_train_val}", file=log_file_path)
    logger(f"Count of Unique Cat IDs per Age Group in Testing Set:\n{counts_test}", file=log_file_path)

    #######################################################
    # CONTINUE WITH ENSURING VALID AND APPROPRIATE SPLITS #
    #######################################################
    
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    groups_train_val, groups_test = groups[train_val_idx], groups[test_idx]

    # logging identifier splits 
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)

    # check group splits
    check_initial_group_split(groups_train_val, groups_test)

    # Specify the cat_ids that must be in the training/validation set
    specific_cat_ids = ['000A', '046A']
    
    # Perform the swapping operation
    train_val_idx, test_idx = swap_cat_id_instances(dataframe, train_val_idx, test_idx, specific_cat_ids)
    
    # Re-assign the sets based on the updated indices
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    new_groups_train_val, new_groups_test = groups[train_val_idx], groups[test_idx]

    # Find differences for training and test sets
    moved_to_train_val, removed_from_train_val = find_group_differences(groups_train_val, new_groups_train_val)
    moved_to_test, removed_from_test = find_group_differences(groups_test, new_groups_test)
    
    # Display the results
    logger(f"Moved to Training/Validation Set:\n{moved_to_train_val}", file=log_file_path)
    logger(f"Removed from Training/Validation Set:\n{removed_from_train_val}", file=log_file_path)
    logger(f"Moved to Test Set:\n{moved_to_test}", file=log_file_path)
    logger(f"Removed from Test Set\n{removed_from_test}", file=log_file_path)

    # Update X_train_val, X_test, y_train_val, y_test, groups_train_val, groups_test based on updated indices
    X_train_val = X[train_val_idx]
    y_train_val = y[train_val_idx]
    groups_train_val = groups[train_val_idx]
    
    X_test = X[test_idx]
    y_test = y[test_idx]
    groups_test = groups[test_idx]

    # logging identifier splits again after potential swaps
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"AFTER SWAP - Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"AFTER SWAP - Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)
    
    # Verify the lengths are consistent
    logger(f"Length of X_train_val:\n{len(X_train_val)}", file=log_file_path)
    logger(f"Length of y_train_val:\n{len(y_train_val)}", file=log_file_path)
    logger(f"Length of groups_train_val:\n{len(groups_train_val)}", file=log_file_path)

    # Check group splits once more
    check_initial_group_split(groups_train_val, groups_test)

    # Convert the modified indices back to a DataFrame representing the updated df_train_val
    df_train_val_updated = dataframe.iloc[train_val_idx].copy()
    df_test_updated = dataframe.iloc[test_idx].copy()

    ############################
    # LOGGING AGE GROUP SPLITS #
    ############################

    # Get the distribution of age groups of age groups before the update
    training_validation_age_group_distribution = df_train_val['age_group'].value_counts()
    testing_age_group_distribution = df_test['age_group'].value_counts()
    
    # Logthe distribution
    logger(f"Train Age Group Distribution BEFORE SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution BEFORE SWAP:\n{testing_age_group_distribution}", file=log_file_path)

    # Get the distribution of age groups after the update
    training_validation_age_group_distribution = df_train_val_updated['age_group'].value_counts()
    testing_age_group_distribution = df_test_updated['age_group'].value_counts()
    
    # Log the distribution
    logger(f"Train Age Group Distribution AFTER SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution AFTER SWAP:\n{testing_age_group_distribution}", file=log_file_path)
    
    ########################################################
    # TRACKING FINAL CAT_IDs & GENDER AFTER REDISTRIBUTION #
    ########################################################

    # Get the distribution of groups
    training_validation_group_distribution = df_train_val_updated['cat_id'].value_counts()  
    testing_group_distribution = df_test_updated['cat_id'].value_counts()  

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val_updated['gender'].value_counts()
    testing_gender_distribution = df_test_updated['gender'].value_counts()
    
    logger(f"\n Starting training on unseen test set\n", file=log_file_path)

    ###################
    # PREPARING MODEL #
    ###################

    # Calculate the distribution of age groups in y_train_val
    age_group_distribution = Counter(y_train_val)
    print("Age group distribution:", age_group_distribution)

    # EarlyStopping callback: monitor 'loss' instead of 'val_loss' for the test set
    early_stopping = EarlyStopping(
        monitor='loss',  
        min_delta=0.001, 
        patience=30,  
        verbose=1,  
        restore_best_weights=True  
    )

    # One final shuffle to ensure randomness
    outer_shuffle_idx = np.random.permutation(len(X_train_val))
    X_train_val = X_train_val[outer_shuffle_idx]
    y_train_val = y_train_val[outer_shuffle_idx]
    
    # Scale the features
    scaler_full = StandardScaler().fit(X_train_val)
    X_train_full_scaled = scaler_full.transform(X_train_val)
    X_test_scaled = scaler_full.transform(X_test)
    
    # Convert features to TensorFlow tensors
    X_train_full_scaled = tf.convert_to_tensor(X_train_full_scaled, dtype=tf.float32)
    X_test_scaled = tf.convert_to_tensor(X_test_scaled, dtype=tf.float32)
    
    # One-hot encode labels before mixup
    y_train_full_encoded = to_categorical(y_train_val)
    y_test_encoded = to_categorical(y_test)
    
    # Convert labels to TensorFlow tensors
    y_train_full_encoded = tf.convert_to_tensor(y_train_full_encoded, dtype=tf.float32)
    
    # Apply Mixup
    X_train_mix_outer, y_train_mix_outer = mixup_data(X_train_full_scaled, y_train_full_encoded, alpha=0.2)
    
    #######################
    # BUILD & TRAIN MODEL #
    #######################

    optimizers = {
        'Adamax': Adamax(learning_rate=0.00510251984616472)
    }
    
    # Model definition with dynamic number of layers
    model_full = Sequential()
    model_full.add(Dense(480, activation='relu', input_shape=(X_train_full_scaled.shape[1],)))
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.2011047009431978))  
    model_full.add(Dense(256, activation='relu',)) 
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.14956886311951184))  
    model_full.add(Dense(256, activation='relu'))  
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.42291461228250665))  
    model_full.add(Dense(3, activation='softmax'))  
    
    # Use the optimizer from the parameters
    optimizer = optimizers['Adamax']  # optimizer_key from parameters
    
    # Compile the model
    model_full.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    
    # Train the model on the full training set
    history_full = model_full.fit(X_train_full_scaled, y_train_full_encoded, epochs=1500, batch_size=64,
                                  verbose=1, callbacks=[early_stopping])
    
    # Evaluate the model on the held-out test set
    test_loss, test_accuracy = model_full.evaluate(X_test_scaled, y_test_encoded)

    y_test_pred_prob = model_full.predict(X_test_scaled)
    y_test_pred = np.argmax(y_test_pred_prob, axis=1)  
    y_test_true = np.argmax(y_test_encoded, axis=1)    

    ################################
    # LOG MAJORITY VOTE PER CAT_ID #
    ################################

    # Convert numeric predictions back to age group labels
    predicted_age_groups = label_encoder.inverse_transform(y_test_pred)
    actual_labels = label_encoder.inverse_transform(y_test_true)
    
    # Map predictions and actual labels back to cat_ids
    test_results = pd.DataFrame({
        'cat_id': df_test_updated['cat_id'],
        'predicted_age_group': predicted_age_groups,
        'actual_age_group': actual_labels
    })
    
    # Group by cat_id and aggregate predicted age groups
    majority_votes = test_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
    actual_groups = test_results.groupby('cat_id')['actual_age_group'].first()
    
    # Calculate the accuracy of majority voting
    correct_predictions = (majority_votes == actual_groups).sum()
    total_cats = len(actual_groups)
    majority_vote_accuracy = correct_predictions / total_cats
    
    # Log the accuracy of the majority voting
    logger(f"Majority Vote Accuracy for cat_id for this fold: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

    ####################################################
    # COLLECT PREDICTIONS FOR GENDER & CAT_ID ANALYSIS #
    ####################################################

    # Debugging print statements
    print(f'Before appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Extend lists with current fold results
    all_cat_ids.extend(df_test_updated['cat_id'].tolist())
    all_predicted_age_groups.extend(predicted_age_groups)
    all_actual_age_groups.extend(actual_labels)
    all_gender.extend(df_test_updated['gender'].tolist())

    # Debugging print statements
    print(f'After appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Calculate additional metrics
    test_precision = precision_score(y_test_true, y_test_pred, average='macro')  # Use 'macro' for imbalanced datasets
    test_recall = recall_score(y_test_true, y_test_pred, average='macro')
    test_f1 = f1_score(y_test_true, y_test_pred, average='macro')

    # prepare averages of outer metrics
    unseen_f1.append(test_f1)
    unseen_losses.append(test_loss)
    unseen_accuracies.append(test_accuracy)
    unseen_precisions.append(test_precision)
    unseen_recalls.append(test_recall)

    # Print final test results
    logger(f"Final Test Results - Loss: {test_loss}, Accuracy: {test_accuracy}, Precision: {test_precision}, Recall: {test_recall}, F1 Score: {test_f1}", file=log_file_path)

    # Generate the confusion matrix
    cm = confusion_matrix(y_test, y_test_pred)
    logger(f"Confusion Matrix:\n {cm}", file=log_file_path)

# Calculate the overall average metrics
unseen_set_avg_f1 = np.mean(unseen_f1)
unseen_set_avg_loss = np.mean(unseen_losses)
unseen_set_avg_acc = np.mean(unseen_accuracies)
unseen_set_avg_precision = np.mean(unseen_precisions)
unseen_set_avg_recall = np.mean(unseen_recalls)

logger(f"\nFinal Average F1-Score across all UNSEEN TEST sets: {unseen_set_avg_f1}", file=log_file_path)
logger(f"\nFinal Average Loss across all UNSEEN TEST sets: {unseen_set_avg_loss}", file=log_file_path)
logger(f"\nFinal Average Accuracy across all UNSEEN TEST sets: {unseen_set_avg_acc}", file=log_file_path)
logger(f"\nFinal Average Precision across all UNSEEN TEST sets: {unseen_set_avg_precision}", file=log_file_path)
logger(f"\nFinal Average Recall across all UNSEEN TEST sets: {unseen_set_avg_recall}\n", file=log_file_path)

# Append averages to total lists
all_f1.append(unseen_set_avg_f1)
all_losses.append(unseen_set_avg_loss)
all_accuracies.append(unseen_set_avg_acc)
all_precisions.append(unseen_set_avg_precision)
all_recalls.append(unseen_set_avg_recall)

# %%
seed_3_folds_values = (unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1)

# Plotting all fold metrics
seed_3_folds_plot = plot_all_metrics(unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1, "Folds", "Fold Number")

# %% [markdown]
# ## Majority Voting on Total Entries per cat_id

# %%
# Debugging print statements
print(f'Checking - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')

# %%
# Create results df
full_results = pd.DataFrame({
    'cat_id': all_cat_ids,
    'predicted_age_group': all_predicted_age_groups,
    'actual_age_group': all_actual_age_groups,
    'all_gender': all_gender
})

# create a correct majority prediction column
full_results['correct'] = full_results['predicted_age_group'] == full_results['actual_age_group']

# %%
# Group by cat_id and aggregate predicted age groups
majority_votes = full_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first()

# Calculate the accuracy of majority voting
correct_predictions = (majority_votes == actual_groups).sum()
total_cats = len(actual_groups)
majority_vote_accuracy = correct_predictions / total_cats

logger(f"Overall Majority Vote Accuracy for cat_id: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

# store for final evaluation 
all_majority_vote_accuracies.append(majority_vote_accuracy)

# %%
# Detailed df with predictions, actual labels, and comparison including majority vote
detailed_results = full_results.groupby('cat_id').apply(
    lambda x: pd.Series({
        'Predictions': list(x['predicted_age_group']),
        'Majority Vote': x['predicted_age_group'].mode()[0],
        'Actual Age Group': x['actual_age_group'].iloc[0],
        'Correct Majority Vote': x['predicted_age_group'].mode()[0] == x['actual_age_group'].iloc[0]
    })
).reset_index()

# Convert to DataFrame for better formatting and display
detailed_results = pd.DataFrame(detailed_results)

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 10)
pd.set_option('display.width', 1000)

sorted_detailed_results = detailed_results.sort_values(by='Correct Majority Vote', ascending=False)

# Display the sorted DataFrame
sorted_detailed_results

# %%
# Create df for majority votes
majority_df = majority_votes.reset_index()
majority_df.columns = ['cat_id', 'Majority_Vote']

# Get actual groups for each cat_id
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first().reset_index()

# Merge majority votes with actual groups
majority_with_actual = pd.merge(majority_df, actual_groups, on='cat_id')

# Add a column to check if the majority vote was correct
majority_with_actual['Majority_Correct'] = majority_with_actual['Majority_Vote'] == majority_with_actual['actual_age_group']

# Count correct majority votes per class
correct_majority_votes_per_class = majority_with_actual.groupby('actual_age_group')['Majority_Correct'].sum()

print("Correct Majority Votes per Class:")
print(correct_majority_votes_per_class)

# %%
# Calculate the total count and the number of correct predictions for each class
class_stats = majority_with_actual.groupby('actual_age_group').agg(
    total_count=('Majority_Correct', 'size'),  # Total number of cases per class
    correct_count=('Majority_Correct', 'sum')  # Sum of correct predictions per class
).reset_index()

# Calculate accuracy for each class
class_stats['accuracy'] = class_stats['correct_count'] / class_stats['total_count'] * 100

# store for final evaluation 
all_majority_vote_details.append(class_stats)

# Log detailed stats
print("Detailed Class Statistics for Majority Votes:")
print(class_stats)

# %%
# Plot for Detailed Class Statistics for Majority Votes
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Accuracy of Majority Votes by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Detailed Class Statistics

# %%
# Calculate the total count and the number of correct predictions for each class
class_stats = full_results.groupby('actual_age_group').agg(
    total_count=('correct', 'size'),
    correct_count=('correct', 'sum')
).reset_index()

# Calculate accuracy for each class
class_stats['accuracy'] = class_stats['correct_count'] / class_stats['total_count'] * 100

# store for final evaluation 
all_class_stats.append(class_stats)

# Log the detailed stats
print("Detailed Class Statistics:")
print(class_stats)

# %%
# Plot for Detailed Class Statistics (Overall)
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Overall Accuracy by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Gender Exploration

# %%
# Group by gender and calculate the total count, correct predictions, and accuracy
gender_stats = full_results.groupby('all_gender').agg(
    count=('cat_id', 'size'),  # Total number of cases per gender
    correct=('correct', 'sum')  # Sum of correct predictions per gender
).reset_index()

# Calculate accuracy for each gender
gender_stats['accuracy'] = (gender_stats['correct'] / gender_stats['count'] * 100).round(2)

# Display the DataFrame
print("Accuracy by Gender:")
print(gender_stats)

# store for final evaluation 
all_gender_stats.append(gender_stats)

# %%
# Plot for Accuracy by Gender
styled_barplot(gender_stats, 'all_gender', 'accuracy', 
               'Accuracy by Gender', 
               'Gender', 'Accuracy (%)')

# %% [markdown]
# ### Log current total CV Stats

# %%
print("Total Majority Vote Accuracy so far:", all_majority_vote_accuracies)
print("Total Class Statistics so far:\n", all_class_stats)
print("Total Gender Accuracy so far:\n", all_gender_stats)

# %% [markdown]
# # RANDOM SEED 4

# %%
# Set a fixed random seed for reproducibility
random.seed(int(random_seeds[3])) 
np.random.seed(int(random_seeds[3]))
tf.random.set_seed(int(random_seeds[3]))

# Load datasets
dataframe = pd.read_csv('/Users/astrid/PycharmProjects/data-aug-and-more/yamnet-tfhub-extraction/yamnet_embeddings_looped_april_23.csv')

def assign_age_group(age, age_groups):
    for group_name, age_range in age_groups.items():
        if age_range[0] <= age < age_range[1]:
            return group_name
    return 'Unknown'  # For any age that doesn't fit the defined groups

# Define age groups
age_groups = {
    'kitten': (0, 0.5),
    'adult': (0.5, 12),
    'senior': (12, 20)
}

# Create a new column for the age group
dataframe['age_group'] = dataframe['target'].apply(assign_age_group, age_groups=age_groups)

print(dataframe['age_group'].value_counts())

# %%
# Separate features and labels
X = dataframe.iloc[:, :-4].values  # all columns except the last four

# Encode the 'age_group' column as integers using LabelEncoder
label_encoder = LabelEncoder()
encoded_y = label_encoder.fit_transform(dataframe['age_group'].values)

# Use the encoded labels for splitting and one-hot encoding
y = encoded_y  

# Convert 'cat_id' column to numpy array to be used as groups array for GroupKFold
groups = dataframe['cat_id'].values

# %%
tf.keras.backend.clear_session()

# %% [markdown]
# ## Run Setup

# %%
all_cat_ids = []
all_predicted_age_groups = []
all_actual_age_groups = []
all_gender = []

# Define the StratifiedGroupKFold splitter for 4 fold CV with random shuffling
outer_cv = StratifiedGroupKFold(n_splits=4, shuffle=True, random_state=int(random_seeds[3]))

# unseen test set metrics
unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1 = [], [], [], [], []

outer_fold = 0

# Use the splitter to generate indices for training and testing sets
# Note: GroupShuffleSplit.split returns indices, so we use it to index the arrays
for train_val_idx, test_idx in outer_cv.split(X, y, groups):
    outer_fold += 1
    logger(f"outer_fold {outer_fold}", file=log_file_path)

    # Convert indices back to DataFrame for easy manipulation
    df_train_val = dataframe.iloc[train_val_idx]
    df_test = dataframe.iloc[test_idx]

    ##############################
    # ASSESSING SPLITS BY CAT_ID #
    ##############################
    
    # Get the distribution of groups
    training_validation_group_distribution = df_train_val['cat_id'].value_counts()  
    testing_group_distribution = df_test['cat_id'].value_counts()  
    
    # Log or print the distribution
    logger(f"Train Set Group Distribution:\n{training_validation_group_distribution}", file=log_file_path)
    logger(f"Testing Set Group Distribution:\n{testing_group_distribution}", file=log_file_path)

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val['gender'].value_counts()
    testing_gender_distribution = df_test['gender'].value_counts()
    
    # Log the distribution
    logger(f"Training Set Gender Distribution BEFORE SWAP:\n{training_gender_distribution}", file=log_file_path)
    logger(f"Testing Set Gender Distribution BEFORE SWAP:\n{testing_gender_distribution}", file=log_file_path)

    # Group by 'age_group' and then list unique 'cat_id' within each age group
    unique_cat_ids_per_age_group_train_val = df_train_val.groupby('age_group')['cat_id'].unique()
    unique_cat_ids_per_age_group_test = df_test.groupby('age_group')['cat_id'].unique()
    
    # Log results
    logger(f"Unique Cat IDs per Age Group in Training/Validation Set:\n{unique_cat_ids_per_age_group_train_val}", file=log_file_path)
    logger(f"Unique Cat IDs per Age Group in Testing Set:\n{unique_cat_ids_per_age_group_test}", file=log_file_path)

    # Calculate the count of unique identifiers per age group for training and testing set
    counts_train_val = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_train_val.items()}
    counts_test = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_test.items()}

    # Log the counts of unique identifiers per age group
    logger(f"Count of Unique Cat IDs per Age Group in Training/Validation Set:\n{counts_train_val}", file=log_file_path)
    logger(f"Count of Unique Cat IDs per Age Group in Testing Set:\n{counts_test}", file=log_file_path)

    #######################################################
    # CONTINUE WITH ENSURING VALID AND APPROPRIATE SPLITS #
    #######################################################
    
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    groups_train_val, groups_test = groups[train_val_idx], groups[test_idx]

    # logging identifier splits 
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)

    # check group splits
    check_initial_group_split(groups_train_val, groups_test)

    # Specify the cat_ids that must be in the training/validation set
    specific_cat_ids = ['000A', '046A']
    
    # Perform the swapping operation
    train_val_idx, test_idx = swap_cat_id_instances(dataframe, train_val_idx, test_idx, specific_cat_ids)
    
    # Re-assign the sets based on the updated indices
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    new_groups_train_val, new_groups_test = groups[train_val_idx], groups[test_idx]

    # Find differences for training and test sets
    moved_to_train_val, removed_from_train_val = find_group_differences(groups_train_val, new_groups_train_val)
    moved_to_test, removed_from_test = find_group_differences(groups_test, new_groups_test)
    
    # Display the results
    logger(f"Moved to Training/Validation Set:\n{moved_to_train_val}", file=log_file_path)
    logger(f"Removed from Training/Validation Set:\n{removed_from_train_val}", file=log_file_path)
    logger(f"Moved to Test Set:\n{moved_to_test}", file=log_file_path)
    logger(f"Removed from Test Set\n{removed_from_test}", file=log_file_path)

    # Update X_train_val, X_test, y_train_val, y_test, groups_train_val, groups_test based on updated indices
    X_train_val = X[train_val_idx]
    y_train_val = y[train_val_idx]
    groups_train_val = groups[train_val_idx]
    
    X_test = X[test_idx]
    y_test = y[test_idx]
    groups_test = groups[test_idx]

    # logging identifier splits again after potential swaps
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"AFTER SWAP - Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"AFTER SWAP - Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)
    
    # Verify the lengths are consistent
    logger(f"Length of X_train_val:\n{len(X_train_val)}", file=log_file_path)
    logger(f"Length of y_train_val:\n{len(y_train_val)}", file=log_file_path)
    logger(f"Length of groups_train_val:\n{len(groups_train_val)}", file=log_file_path)

    # Check group splits once more
    check_initial_group_split(groups_train_val, groups_test)

    # Convert the modified indices back to a DataFrame representing the updated df_train_val
    df_train_val_updated = dataframe.iloc[train_val_idx].copy()
    df_test_updated = dataframe.iloc[test_idx].copy()

    ############################
    # LOGGING AGE GROUP SPLITS #
    ############################

    # Get the distribution of age groups of age groups before the update
    training_validation_age_group_distribution = df_train_val['age_group'].value_counts()
    testing_age_group_distribution = df_test['age_group'].value_counts()
    
    # Logthe distribution
    logger(f"Train Age Group Distribution BEFORE SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution BEFORE SWAP:\n{testing_age_group_distribution}", file=log_file_path)

    # Get the distribution of age groups after the update
    training_validation_age_group_distribution = df_train_val_updated['age_group'].value_counts()
    testing_age_group_distribution = df_test_updated['age_group'].value_counts()
    
    # Log the distribution
    logger(f"Train Age Group Distribution AFTER SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution AFTER SWAP:\n{testing_age_group_distribution}", file=log_file_path)
    
    ########################################################
    # TRACKING FINAL CAT_IDs & GENDER AFTER REDISTRIBUTION #
    ########################################################

    # Get the distribution of groups
    training_validation_group_distribution = df_train_val_updated['cat_id'].value_counts()  
    testing_group_distribution = df_test_updated['cat_id'].value_counts()  

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val_updated['gender'].value_counts()
    testing_gender_distribution = df_test_updated['gender'].value_counts()
    
    logger(f"\n Starting training on unseen test set\n", file=log_file_path)

    ###################
    # PREPARING MODEL #
    ###################

    # Calculate the distribution of age groups in y_train_val
    age_group_distribution = Counter(y_train_val)
    print("Age group distribution:", age_group_distribution)

    # EarlyStopping callback: monitor 'loss' instead of 'val_loss' for the test set
    early_stopping = EarlyStopping(
        monitor='loss',  
        min_delta=0.001, 
        patience=30,  
        verbose=1,  
        restore_best_weights=True  
    )

    # One final shuffle to ensure randomness
    outer_shuffle_idx = np.random.permutation(len(X_train_val))
    X_train_val = X_train_val[outer_shuffle_idx]
    y_train_val = y_train_val[outer_shuffle_idx]
    
    # Scale the features
    scaler_full = StandardScaler().fit(X_train_val)
    X_train_full_scaled = scaler_full.transform(X_train_val)
    X_test_scaled = scaler_full.transform(X_test)
    
    # Convert features to TensorFlow tensors
    X_train_full_scaled = tf.convert_to_tensor(X_train_full_scaled, dtype=tf.float32)
    X_test_scaled = tf.convert_to_tensor(X_test_scaled, dtype=tf.float32)
    
    # One-hot encode labels before mixup
    y_train_full_encoded = to_categorical(y_train_val)
    y_test_encoded = to_categorical(y_test)
    
    # Convert labels to TensorFlow tensors
    y_train_full_encoded = tf.convert_to_tensor(y_train_full_encoded, dtype=tf.float32)
    
    # Apply Mixup
    X_train_mix_outer, y_train_mix_outer = mixup_data(X_train_full_scaled, y_train_full_encoded, alpha=0.2)
    
    #######################
    # BUILD & TRAIN MODEL #
    #######################

    optimizers = {
        'Adamax': Adamax(learning_rate=0.00510251984616472)
    }
    
    # Model definition with dynamic number of layers
    model_full = Sequential()
    model_full.add(Dense(480, activation='relu', input_shape=(X_train_full_scaled.shape[1],)))
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.2011047009431978))  
    model_full.add(Dense(256, activation='relu',)) 
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.14956886311951184))  
    model_full.add(Dense(256, activation='relu'))  
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.42291461228250665))  
    model_full.add(Dense(3, activation='softmax'))  
    
    # Use the optimizer from the parameters
    optimizer = optimizers['Adamax']  # optimizer_key from parameters
    
    # Compile the model
    model_full.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    
    # Train the model on the full training set
    history_full = model_full.fit(X_train_full_scaled, y_train_full_encoded, epochs=1500, batch_size=64,
                                  verbose=1, callbacks=[early_stopping])
    
    # Evaluate the model on the held-out test set
    test_loss, test_accuracy = model_full.evaluate(X_test_scaled, y_test_encoded)

    y_test_pred_prob = model_full.predict(X_test_scaled)
    y_test_pred = np.argmax(y_test_pred_prob, axis=1)  
    y_test_true = np.argmax(y_test_encoded, axis=1)    

    ################################
    # LOG MAJORITY VOTE PER CAT_ID #
    ################################

    # Convert numeric predictions back to age group labels
    predicted_age_groups = label_encoder.inverse_transform(y_test_pred)
    actual_labels = label_encoder.inverse_transform(y_test_true)
    
    # Map predictions and actual labels back to cat_ids
    test_results = pd.DataFrame({
        'cat_id': df_test_updated['cat_id'],
        'predicted_age_group': predicted_age_groups,
        'actual_age_group': actual_labels
    })
    
    # Group by cat_id and aggregate predicted age groups
    majority_votes = test_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
    actual_groups = test_results.groupby('cat_id')['actual_age_group'].first()
    
    # Calculate the accuracy of majority voting
    correct_predictions = (majority_votes == actual_groups).sum()
    total_cats = len(actual_groups)
    majority_vote_accuracy = correct_predictions / total_cats
    
    # Log the accuracy of the majority voting
    logger(f"Majority Vote Accuracy for cat_id for this fold: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

    ####################################################
    # COLLECT PREDICTIONS FOR GENDER & CAT_ID ANALYSIS #
    ####################################################

    # Debugging print statements
    print(f'Before appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Extend lists with current fold results
    all_cat_ids.extend(df_test_updated['cat_id'].tolist())
    all_predicted_age_groups.extend(predicted_age_groups)
    all_actual_age_groups.extend(actual_labels)
    all_gender.extend(df_test_updated['gender'].tolist())

    # Debugging print statements
    print(f'After appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Calculate additional metrics
    test_precision = precision_score(y_test_true, y_test_pred, average='macro')  # Use 'macro' for imbalanced datasets
    test_recall = recall_score(y_test_true, y_test_pred, average='macro')
    test_f1 = f1_score(y_test_true, y_test_pred, average='macro')

    # prepare averages of outer metrics
    unseen_f1.append(test_f1)
    unseen_losses.append(test_loss)
    unseen_accuracies.append(test_accuracy)
    unseen_precisions.append(test_precision)
    unseen_recalls.append(test_recall)

    # Print final test results
    logger(f"Final Test Results - Loss: {test_loss}, Accuracy: {test_accuracy}, Precision: {test_precision}, Recall: {test_recall}, F1 Score: {test_f1}", file=log_file_path)

    # Generate the confusion matrix
    cm = confusion_matrix(y_test, y_test_pred)
    logger(f"Confusion Matrix:\n {cm}", file=log_file_path)

# Calculate the overall average metrics
unseen_set_avg_f1 = np.mean(unseen_f1)
unseen_set_avg_loss = np.mean(unseen_losses)
unseen_set_avg_acc = np.mean(unseen_accuracies)
unseen_set_avg_precision = np.mean(unseen_precisions)
unseen_set_avg_recall = np.mean(unseen_recalls)

logger(f"\nFinal Average F1-Score across all UNSEEN TEST sets: {unseen_set_avg_f1}", file=log_file_path)
logger(f"\nFinal Average Loss across all UNSEEN TEST sets: {unseen_set_avg_loss}", file=log_file_path)
logger(f"\nFinal Average Accuracy across all UNSEEN TEST sets: {unseen_set_avg_acc}", file=log_file_path)
logger(f"\nFinal Average Precision across all UNSEEN TEST sets: {unseen_set_avg_precision}", file=log_file_path)
logger(f"\nFinal Average Recall across all UNSEEN TEST sets: {unseen_set_avg_recall}\n", file=log_file_path)

# Append averages to total lists
all_f1.append(unseen_set_avg_f1)
all_losses.append(unseen_set_avg_loss)
all_accuracies.append(unseen_set_avg_acc)
all_precisions.append(unseen_set_avg_precision)
all_recalls.append(unseen_set_avg_recall)

# %%
seed_4_folds_values = (unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1)

# Plotting all fold metrics
seed_4_folds_plot = plot_all_metrics(unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1, "Folds", "Fold Number")

# %% [markdown]
# ## Majority Voting on Total Entries per cat_id

# %%
# Debugging print statements
print(f'Checking - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')

# %%
# Create results df
full_results = pd.DataFrame({
    'cat_id': all_cat_ids,
    'predicted_age_group': all_predicted_age_groups,
    'actual_age_group': all_actual_age_groups,
    'all_gender': all_gender
})

# create a correct majority prediction column
full_results['correct'] = full_results['predicted_age_group'] == full_results['actual_age_group']

# %%
# Group by cat_id and aggregate predicted age groups
majority_votes = full_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first()

# Calculate the accuracy of majority voting
correct_predictions = (majority_votes == actual_groups).sum()
total_cats = len(actual_groups)
majority_vote_accuracy = correct_predictions / total_cats

logger(f"Overall Majority Vote Accuracy for cat_id: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

# store for final evaluation 
all_majority_vote_accuracies.append(majority_vote_accuracy)

# %%
# Detailed df with predictions, actual labels, and comparison including majority vote
detailed_results = full_results.groupby('cat_id').apply(
    lambda x: pd.Series({
        'Predictions': list(x['predicted_age_group']),
        'Majority Vote': x['predicted_age_group'].mode()[0],
        'Actual Age Group': x['actual_age_group'].iloc[0],
        'Correct Majority Vote': x['predicted_age_group'].mode()[0] == x['actual_age_group'].iloc[0]
    })
).reset_index()

# Convert to DataFrame for better formatting and display
detailed_results = pd.DataFrame(detailed_results)

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 10)
pd.set_option('display.width', 1000)

sorted_detailed_results = detailed_results.sort_values(by='Correct Majority Vote', ascending=False)

# Display the sorted DataFrame
sorted_detailed_results

# %%
# Create df for majority votes
majority_df = majority_votes.reset_index()
majority_df.columns = ['cat_id', 'Majority_Vote']

# Get actual groups for each cat_id
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first().reset_index()

# Merge majority votes with actual groups
majority_with_actual = pd.merge(majority_df, actual_groups, on='cat_id')

# Add a column to check if the majority vote was correct
majority_with_actual['Majority_Correct'] = majority_with_actual['Majority_Vote'] == majority_with_actual['actual_age_group']

# Count correct majority votes per class
correct_majority_votes_per_class = majority_with_actual.groupby('actual_age_group')['Majority_Correct'].sum()

print("Correct Majority Votes per Class:")
print(correct_majority_votes_per_class)

# %%
# Calculate the total count and the number of correct predictions for each class
class_stats = majority_with_actual.groupby('actual_age_group').agg(
    total_count=('Majority_Correct', 'size'),  # Total number of cases per class
    correct_count=('Majority_Correct', 'sum')  # Sum of correct predictions per class
).reset_index()

# Calculate accuracy for each class
class_stats['accuracy'] = class_stats['correct_count'] / class_stats['total_count'] * 100

# store for final evaluation 
all_majority_vote_details.append(class_stats)

# Log detailed stats
print("Detailed Class Statistics for Majority Votes:")
print(class_stats)

# %%
# Plot for Detailed Class Statistics for Majority Votes
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Accuracy of Majority Votes by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Detailed Class Statistics

# %%
# Calculate the total count and the number of correct predictions for each class
class_stats = full_results.groupby('actual_age_group').agg(
    total_count=('correct', 'size'),
    correct_count=('correct', 'sum')
).reset_index()

# Calculate accuracy for each class
class_stats['accuracy'] = class_stats['correct_count'] / class_stats['total_count'] * 100

# store for final evaluation 
all_class_stats.append(class_stats)

# Log the detailed stats
print("Detailed Class Statistics:")
print(class_stats)

# %%
# Plot for Detailed Class Statistics (Overall)
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Overall Accuracy by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Gender Exploration

# %%
# Group by gender and calculate the total count, correct predictions, and accuracy
gender_stats = full_results.groupby('all_gender').agg(
    count=('cat_id', 'size'),  # Total number of cases per gender
    correct=('correct', 'sum')  # Sum of correct predictions per gender
).reset_index()

# Calculate accuracy for each gender
gender_stats['accuracy'] = (gender_stats['correct'] / gender_stats['count'] * 100).round(2)

# Display the DataFrame
print("Accuracy by Gender:")
print(gender_stats)

# store for final evaluation 
all_gender_stats.append(gender_stats)

# %%
# Plot for Accuracy by Gender
styled_barplot(gender_stats, 'all_gender', 'accuracy', 
               'Accuracy by Gender', 
               'Gender', 'Accuracy (%)')

# %% [markdown]
# ### Log current total CV Stats

# %%
print("Total Majority Vote Accuracy so far:", all_majority_vote_accuracies)
print("Total Class Statistics so far:\n", all_class_stats)
print("Total Gender Accuracy so far:\n", all_gender_stats)

# %% [markdown]
# # RANDOM SEED 5

# %%
# Set a fixed random seed for reproducibility
random.seed(int(random_seeds[4]))
np.random.seed(int(random_seeds[4]))
tf.random.set_seed(int(random_seeds[4]))

# Load datasets
dataframe = pd.read_csv('/Users/astrid/PycharmProjects/data-aug-and-more/yamnet-tfhub-extraction/yamnet_embeddings_looped_april_23.csv')

def assign_age_group(age, age_groups):
    for group_name, age_range in age_groups.items():
        if age_range[0] <= age < age_range[1]:
            return group_name
    return 'Unknown'  # For any age that doesn't fit the defined groups

# Define age groups
age_groups = {
    'kitten': (0, 0.5),
    'adult': (0.5, 12),
    'senior': (12, 20)
}

# Create a new column for the age group
dataframe['age_group'] = dataframe['target'].apply(assign_age_group, age_groups=age_groups)

print(dataframe['age_group'].value_counts())

# %%
# Separate features and labels
X = dataframe.iloc[:, :-4].values  # all columns except the last four

# Encode the 'age_group' column as integers using LabelEncoder
label_encoder = LabelEncoder()
encoded_y = label_encoder.fit_transform(dataframe['age_group'].values)

# Use the encoded labels for splitting and one-hot encoding
y = encoded_y  

# Convert 'cat_id' column to numpy array to be used as groups array for GroupKFold
groups = dataframe['cat_id'].values

# %%
tf.keras.backend.clear_session()

# %% [markdown]
# ## Run Setup

# %%
all_cat_ids = []
all_predicted_age_groups = []
all_actual_age_groups = []
all_gender = []

# Define the StratifiedGroupKFold splitter for 4 fold CV with random shuffling
outer_cv = StratifiedGroupKFold(n_splits=4, shuffle=True, random_state=int(random_seeds[4]))

# unseen test set metrics
unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1 = [], [], [], [], []

outer_fold = 0

# Use the splitter to generate indices for training and testing sets
# Note: GroupShuffleSplit.split returns indices, so we use it to index the arrays
for train_val_idx, test_idx in outer_cv.split(X, y, groups):
    outer_fold += 1
    logger(f"outer_fold {outer_fold}", file=log_file_path)

    # Convert indices back to DataFrame for easy manipulation
    df_train_val = dataframe.iloc[train_val_idx]
    df_test = dataframe.iloc[test_idx]

    ##############################
    # ASSESSING SPLITS BY CAT_ID #
    ##############################
    
    # Get the distribution of groups
    training_validation_group_distribution = df_train_val['cat_id'].value_counts()  
    testing_group_distribution = df_test['cat_id'].value_counts()  
    
    # Log or print the distribution
    logger(f"Train Set Group Distribution:\n{training_validation_group_distribution}", file=log_file_path)
    logger(f"Testing Set Group Distribution:\n{testing_group_distribution}", file=log_file_path)

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val['gender'].value_counts()
    testing_gender_distribution = df_test['gender'].value_counts()
    
    # Log the distribution
    logger(f"Training Set Gender Distribution BEFORE SWAP:\n{training_gender_distribution}", file=log_file_path)
    logger(f"Testing Set Gender Distribution BEFORE SWAP:\n{testing_gender_distribution}", file=log_file_path)

    # Group by 'age_group' and then list unique 'cat_id' within each age group
    unique_cat_ids_per_age_group_train_val = df_train_val.groupby('age_group')['cat_id'].unique()
    unique_cat_ids_per_age_group_test = df_test.groupby('age_group')['cat_id'].unique()
    
    # Log results
    logger(f"Unique Cat IDs per Age Group in Training/Validation Set:\n{unique_cat_ids_per_age_group_train_val}", file=log_file_path)
    logger(f"Unique Cat IDs per Age Group in Testing Set:\n{unique_cat_ids_per_age_group_test}", file=log_file_path)

    # Calculate the count of unique identifiers per age group for training and testing set
    counts_train_val = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_train_val.items()}
    counts_test = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_test.items()}

    # Log the counts of unique identifiers per age group
    logger(f"Count of Unique Cat IDs per Age Group in Training/Validation Set:\n{counts_train_val}", file=log_file_path)
    logger(f"Count of Unique Cat IDs per Age Group in Testing Set:\n{counts_test}", file=log_file_path)

    #######################################################
    # CONTINUE WITH ENSURING VALID AND APPROPRIATE SPLITS #
    #######################################################
    
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    groups_train_val, groups_test = groups[train_val_idx], groups[test_idx]

    # logging identifier splits 
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)

    # check group splits
    check_initial_group_split(groups_train_val, groups_test)

    # Specify the cat_ids that must be in the training/validation set
    specific_cat_ids = ['000A', '046A']
    
    # Perform the swapping operation
    train_val_idx, test_idx = swap_cat_id_instances(dataframe, train_val_idx, test_idx, specific_cat_ids)
    
    # Re-assign the sets based on the updated indices
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    new_groups_train_val, new_groups_test = groups[train_val_idx], groups[test_idx]

    # Find differences for training and test sets
    moved_to_train_val, removed_from_train_val = find_group_differences(groups_train_val, new_groups_train_val)
    moved_to_test, removed_from_test = find_group_differences(groups_test, new_groups_test)
    
    # Display the results
    logger(f"Moved to Training/Validation Set:\n{moved_to_train_val}", file=log_file_path)
    logger(f"Removed from Training/Validation Set:\n{removed_from_train_val}", file=log_file_path)
    logger(f"Moved to Test Set:\n{moved_to_test}", file=log_file_path)
    logger(f"Removed from Test Set\n{removed_from_test}", file=log_file_path)

    # Update X_train_val, X_test, y_train_val, y_test, groups_train_val, groups_test based on updated indices
    X_train_val = X[train_val_idx]
    y_train_val = y[train_val_idx]
    groups_train_val = groups[train_val_idx]
    
    X_test = X[test_idx]
    y_test = y[test_idx]
    groups_test = groups[test_idx]

    # logging identifier splits again after potential swaps
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"AFTER SWAP - Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"AFTER SWAP - Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)
    
    # Verify the lengths are consistent
    logger(f"Length of X_train_val:\n{len(X_train_val)}", file=log_file_path)
    logger(f"Length of y_train_val:\n{len(y_train_val)}", file=log_file_path)
    logger(f"Length of groups_train_val:\n{len(groups_train_val)}", file=log_file_path)

    # Check group splits once more
    check_initial_group_split(groups_train_val, groups_test)

    # Convert the modified indices back to a DataFrame representing the updated df_train_val
    df_train_val_updated = dataframe.iloc[train_val_idx].copy()
    df_test_updated = dataframe.iloc[test_idx].copy()

    ############################
    # LOGGING AGE GROUP SPLITS #
    ############################

    # Get the distribution of age groups of age groups before the update
    training_validation_age_group_distribution = df_train_val['age_group'].value_counts()
    testing_age_group_distribution = df_test['age_group'].value_counts()
    
    # Logthe distribution
    logger(f"Train Age Group Distribution BEFORE SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution BEFORE SWAP:\n{testing_age_group_distribution}", file=log_file_path)

    # Get the distribution of age groups after the update
    training_validation_age_group_distribution = df_train_val_updated['age_group'].value_counts()
    testing_age_group_distribution = df_test_updated['age_group'].value_counts()
    
    # Log the distribution
    logger(f"Train Age Group Distribution AFTER SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution AFTER SWAP:\n{testing_age_group_distribution}", file=log_file_path)
    
    ########################################################
    # TRACKING FINAL CAT_IDs & GENDER AFTER REDISTRIBUTION #
    ########################################################

    # Get the distribution of groups
    training_validation_group_distribution = df_train_val_updated['cat_id'].value_counts()  
    testing_group_distribution = df_test_updated['cat_id'].value_counts()  

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val_updated['gender'].value_counts()
    testing_gender_distribution = df_test_updated['gender'].value_counts()
    
    logger(f"\n Starting training on unseen test set\n", file=log_file_path)

    ###################
    # PREPARING MODEL #
    ###################

    # Calculate the distribution of age groups in y_train_val
    age_group_distribution = Counter(y_train_val)
    print("Age group distribution:", age_group_distribution)

    # EarlyStopping callback: monitor 'loss' instead of 'val_loss' for the test set
    early_stopping = EarlyStopping(
        monitor='loss',  
        min_delta=0.001, 
        patience=30,  
        verbose=1,  
        restore_best_weights=True  
    )

    # One final shuffle to ensure randomness
    outer_shuffle_idx = np.random.permutation(len(X_train_val))
    X_train_val = X_train_val[outer_shuffle_idx]
    y_train_val = y_train_val[outer_shuffle_idx]
    
    # Scale the features
    scaler_full = StandardScaler().fit(X_train_val)
    X_train_full_scaled = scaler_full.transform(X_train_val)
    X_test_scaled = scaler_full.transform(X_test)
    
    # Convert features to TensorFlow tensors
    X_train_full_scaled = tf.convert_to_tensor(X_train_full_scaled, dtype=tf.float32)
    X_test_scaled = tf.convert_to_tensor(X_test_scaled, dtype=tf.float32)
    
    # One-hot encode labels before mixup
    y_train_full_encoded = to_categorical(y_train_val)
    y_test_encoded = to_categorical(y_test)
    
    # Convert labels to TensorFlow tensors
    y_train_full_encoded = tf.convert_to_tensor(y_train_full_encoded, dtype=tf.float32)
    
    # Apply Mixup
    X_train_mix_outer, y_train_mix_outer = mixup_data(X_train_full_scaled, y_train_full_encoded, alpha=0.2)
    
    #######################
    # BUILD & TRAIN MODEL #
    #######################

    optimizers = {
        'Adamax': Adamax(learning_rate=0.00510251984616472)
    }
    
    # Model definition with dynamic number of layers
    model_full = Sequential()
    model_full.add(Dense(480, activation='relu', input_shape=(X_train_full_scaled.shape[1],)))
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.2011047009431978))  
    model_full.add(Dense(256, activation='relu',)) 
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.14956886311951184))  
    model_full.add(Dense(256, activation='relu'))  
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.42291461228250665))  
    model_full.add(Dense(3, activation='softmax'))  
    
    # Use the optimizer from the parameters
    optimizer = optimizers['Adamax']  # optimizer_key from parameters
    
    # Compile the model
    model_full.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    
    # Train the model on the full training set
    history_full = model_full.fit(X_train_full_scaled, y_train_full_encoded, epochs=1500, batch_size=64,
                                  verbose=1, callbacks=[early_stopping])
    
    # Evaluate the model on the held-out test set
    test_loss, test_accuracy = model_full.evaluate(X_test_scaled, y_test_encoded)

    y_test_pred_prob = model_full.predict(X_test_scaled)
    y_test_pred = np.argmax(y_test_pred_prob, axis=1)  
    y_test_true = np.argmax(y_test_encoded, axis=1)    

    ################################
    # LOG MAJORITY VOTE PER CAT_ID #
    ################################

    # Convert numeric predictions back to age group labels
    predicted_age_groups = label_encoder.inverse_transform(y_test_pred)
    actual_labels = label_encoder.inverse_transform(y_test_true)
    
    # Map predictions and actual labels back to cat_ids
    test_results = pd.DataFrame({
        'cat_id': df_test_updated['cat_id'],
        'predicted_age_group': predicted_age_groups,
        'actual_age_group': actual_labels
    })
    
    # Group by cat_id and aggregate predicted age groups
    majority_votes = test_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
    actual_groups = test_results.groupby('cat_id')['actual_age_group'].first()
    
    # Calculate the accuracy of majority voting
    correct_predictions = (majority_votes == actual_groups).sum()
    total_cats = len(actual_groups)
    majority_vote_accuracy = correct_predictions / total_cats
    
    # Log the accuracy of the majority voting
    logger(f"Majority Vote Accuracy for cat_id for this fold: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

    ####################################################
    # COLLECT PREDICTIONS FOR GENDER & CAT_ID ANALYSIS #
    ####################################################

    # Debugging print statements
    print(f'Before appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Extend lists with current fold results
    all_cat_ids.extend(df_test_updated['cat_id'].tolist())
    all_predicted_age_groups.extend(predicted_age_groups)
    all_actual_age_groups.extend(actual_labels)
    all_gender.extend(df_test_updated['gender'].tolist())

    # Debugging print statements
    print(f'After appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Calculate additional metrics
    test_precision = precision_score(y_test_true, y_test_pred, average='macro')  # Use 'macro' for imbalanced datasets
    test_recall = recall_score(y_test_true, y_test_pred, average='macro')
    test_f1 = f1_score(y_test_true, y_test_pred, average='macro')

    # prepare averages of outer metrics
    unseen_f1.append(test_f1)
    unseen_losses.append(test_loss)
    unseen_accuracies.append(test_accuracy)
    unseen_precisions.append(test_precision)
    unseen_recalls.append(test_recall)

    # Print final test results
    logger(f"Final Test Results - Loss: {test_loss}, Accuracy: {test_accuracy}, Precision: {test_precision}, Recall: {test_recall}, F1 Score: {test_f1}", file=log_file_path)

    # Generate the confusion matrix
    cm = confusion_matrix(y_test, y_test_pred)
    logger(f"Confusion Matrix:\n {cm}", file=log_file_path)

# Calculate the overall average metrics
unseen_set_avg_f1 = np.mean(unseen_f1)
unseen_set_avg_loss = np.mean(unseen_losses)
unseen_set_avg_acc = np.mean(unseen_accuracies)
unseen_set_avg_precision = np.mean(unseen_precisions)
unseen_set_avg_recall = np.mean(unseen_recalls)

logger(f"\nFinal Average F1-Score across all UNSEEN TEST sets: {unseen_set_avg_f1}", file=log_file_path)
logger(f"\nFinal Average Loss across all UNSEEN TEST sets: {unseen_set_avg_loss}", file=log_file_path)
logger(f"\nFinal Average Accuracy across all UNSEEN TEST sets: {unseen_set_avg_acc}", file=log_file_path)
logger(f"\nFinal Average Precision across all UNSEEN TEST sets: {unseen_set_avg_precision}", file=log_file_path)
logger(f"\nFinal Average Recall across all UNSEEN TEST sets: {unseen_set_avg_recall}\n", file=log_file_path)

# Append averages to total lists
all_f1.append(unseen_set_avg_f1)
all_losses.append(unseen_set_avg_loss)
all_accuracies.append(unseen_set_avg_acc)
all_precisions.append(unseen_set_avg_precision)
all_recalls.append(unseen_set_avg_recall)

# %%
seed_5_folds_values = (unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1)

# Plotting all fold metrics|
seed_5_folds_plot = plot_all_metrics(unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1, "Folds", "Fold Number")

# %% [markdown]
# ## Majority Voting on Total Entries per cat_id

# %%
# Debugging print statements
print(f'Checking - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')

# %%
# Create results df
full_results = pd.DataFrame({
    'cat_id': all_cat_ids,
    'predicted_age_group': all_predicted_age_groups,
    'actual_age_group': all_actual_age_groups,
    'all_gender': all_gender
})

# create a correct majority prediction column
full_results['correct'] = full_results['predicted_age_group'] == full_results['actual_age_group']

# %%
# Group by cat_id and aggregate predicted age groups
majority_votes = full_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first()

# Calculate the accuracy of majority voting
correct_predictions = (majority_votes == actual_groups).sum()
total_cats = len(actual_groups)
majority_vote_accuracy = correct_predictions / total_cats

logger(f"Overall Majority Vote Accuracy for cat_id: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

# store for final evaluation 
all_majority_vote_accuracies.append(majority_vote_accuracy)

# %%
# Detailed df with predictions, actual labels, and comparison including majority vote
detailed_results = full_results.groupby('cat_id').apply(
    lambda x: pd.Series({
        'Predictions': list(x['predicted_age_group']),
        'Majority Vote': x['predicted_age_group'].mode()[0],
        'Actual Age Group': x['actual_age_group'].iloc[0],
        'Correct Majority Vote': x['predicted_age_group'].mode()[0] == x['actual_age_group'].iloc[0]
    })
).reset_index()

# Convert to DataFrame for better formatting and display
detailed_results = pd.DataFrame(detailed_results)

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 10)
pd.set_option('display.width', 1000)

sorted_detailed_results = detailed_results.sort_values(by='Correct Majority Vote', ascending=False)

# Display the sorted DataFrame
sorted_detailed_results

# %%
# Create df for majority votes
majority_df = majority_votes.reset_index()
majority_df.columns = ['cat_id', 'Majority_Vote']

# Get actual groups for each cat_id
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first().reset_index()

# Merge majority votes with actual groups
majority_with_actual = pd.merge(majority_df, actual_groups, on='cat_id')

# Add a column to check if the majority vote was correct
majority_with_actual['Majority_Correct'] = majority_with_actual['Majority_Vote'] == majority_with_actual['actual_age_group']

# Count correct majority votes per class
correct_majority_votes_per_class = majority_with_actual.groupby('actual_age_group')['Majority_Correct'].sum()

print("Correct Majority Votes per Class:")
print(correct_majority_votes_per_class)

# %%
# Calculate the total count and the number of correct predictions for each class
class_stats = majority_with_actual.groupby('actual_age_group').agg(
    total_count=('Majority_Correct', 'size'),  # Total number of cases per class
    correct_count=('Majority_Correct', 'sum')  # Sum of correct predictions per class
).reset_index()

# Calculate accuracy for each class
class_stats['accuracy'] = class_stats['correct_count'] / class_stats['total_count'] * 100

# store for final evaluation 
all_majority_vote_details.append(class_stats)

# Log detailed stats
print("Detailed Class Statistics for Majority Votes:")
print(class_stats)

# %%
# Plot for Detailed Class Statistics for Majority Votes
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Accuracy of Majority Votes by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Detailed Class Statistics

# %%
# Calculate the total count and the number of correct predictions for each class
class_stats = full_results.groupby('actual_age_group').agg(
    total_count=('correct', 'size'),
    correct_count=('correct', 'sum')
).reset_index()

# Calculate accuracy for each class
class_stats['accuracy'] = class_stats['correct_count'] / class_stats['total_count'] * 100

# store for final evaluation 
all_class_stats.append(class_stats)

# Log the detailed stats
print("Detailed Class Statistics:")
print(class_stats)

# %%
# Plot for Detailed Class Statistics (Overall)
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Overall Accuracy by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Gender Exploration

# %%
# Group by gender and calculate the total count, correct predictions, and accuracy
gender_stats = full_results.groupby('all_gender').agg(
    count=('cat_id', 'size'),  # Total number of cases per gender
    correct=('correct', 'sum')  # Sum of correct predictions per gender
).reset_index()

# Calculate accuracy for each gender
gender_stats['accuracy'] = (gender_stats['correct'] / gender_stats['count'] * 100).round(2)

# Display the DataFrame
print("Accuracy by Gender:")
print(gender_stats)

# store for final evaluation 
all_gender_stats.append(gender_stats)

# %%
# Plot for Accuracy by Gender
styled_barplot(gender_stats, 'all_gender', 'accuracy', 
               'Accuracy by Gender', 
               'Gender', 'Accuracy (%)')

# %% [markdown]
# ### Log current total CV Stats

# %%
print("Total Majority Vote Accuracy so far:", all_majority_vote_accuracies)
print("Total Class Statistics so far:\n", all_class_stats) 
print("Total Majority Vote Statistics so far:\n", all_majority_vote_details) 
print("Total Gender Accuracy so far:\n", all_gender_stats)

# %% [markdown]
# # --------------

# %% [markdown]
# # Total Final Results & Analysis

# %%
# Count unique cat_id per age group 
unique_cats_per_age_group = dataframe.groupby('age_group')['cat_id'].nunique()

# Display the counts
print("Unique cat_id counts in original dataframe:", unique_cats_per_age_group)

# %% [markdown]
# ## Metrics

# %%
# Calculate overall metrics
overall_avg_loss = np.mean(all_losses)
overall_avg_acc = np.mean(all_accuracies)
overall_avg_precision = np.mean(all_precisions)
overall_avg_recall = np.mean(all_recalls)
overall_avg_f1 = np.mean(all_f1)

print("Overall Average Metrics:")
print("Loss:", overall_avg_loss)
print("Accuracy:", overall_avg_acc)
print("Precision:", overall_avg_precision)
print("Recall:", overall_avg_recall)
print("F1 Score:", overall_avg_f1)

# %% [markdown]
# ## Majority Votes

# %%
# Average of majority vote accuracies
average_majority_vote_accuracy = np.mean(all_majority_vote_accuracies)
print("Average Majority Vote Accuracy:", average_majority_vote_accuracy)

# %%
# Concatenate all class stats DataFrames and calculate the mean of accuracies
total_majority_vote_details = pd.concat(all_majority_vote_details)
average_majority_vote_details = total_majority_vote_details.groupby('actual_age_group').agg({
    'total_count': 'sum', 
    'correct_count': 'sum' 
}).reset_index()
average_majority_vote_details['accuracy'] = (average_majority_vote_details['correct_count'] / average_majority_vote_details['total_count']) * 100

print("Average Class Statistics:")
print(average_majority_vote_details)

# %%
# Plot for Detailed Class Statistics for Majority Votes
styled_barplot(average_majority_vote_details, 'actual_age_group', 'accuracy', 
               'Accuracy of Majority Votes by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Detailed Class Statistics

# %%
# Concatenate all class stats DataFrames and calculate the mean of accuracies
total_class_stats = pd.concat(all_class_stats)
average_class_stats = total_class_stats.groupby('actual_age_group').agg({
    'total_count': 'sum',  
    'correct_count': 'sum' 
}).reset_index()
average_class_stats['accuracy'] = (average_class_stats['correct_count'] / average_class_stats['total_count']) * 100

print("Average Class Statistics:")
print(average_class_stats)

# %%
# Plot for Detailed Class Statistics (Overall)
styled_barplot(average_class_stats, 'actual_age_group', 'accuracy', 
               'Overall Accuracy by Age Group', 
               'Age Group', 'Accuracy (%)')

# %%
# Concatenate all gender stats DataFrames and calculate the mean of accuracies
total_gender_stats = pd.concat(all_gender_stats)
average_gender_stats = total_gender_stats.groupby('all_gender').agg({
    'count': 'sum',  
    'correct': 'sum'  
}).reset_index()
average_gender_stats['accuracy'] = (average_gender_stats['correct'] / average_gender_stats['count']) * 100

print("Average Gender Accuracy:")
print(average_gender_stats)

# %%
# Plot for Accuracy by Gender
styled_barplot(total_gender_stats, 'all_gender', 'accuracy', 
               'Accuracy by Gender', 
               'Gender', 'Accuracy (%)')

# %% [markdown]
# # Visualisations

# %%
# Plotting all metrics
metrics_across_seeds = plot_all_metrics(all_losses, all_accuracies, all_precisions, all_recalls, all_f1, "Seeds", "Seed Number")

# %%
# Calculate the standard deviation for each metric
std_loss = np.std(all_losses)
std_accuracy = np.std(all_accuracies)
std_precision = np.std(all_precisions)
std_recall = np.std(all_recalls)
std_f1 = np.std(all_f1)

print("Standard Deviations:")
print(f"Loss: {std_loss}")
print(f"Accuracy: {std_accuracy}")
print(f"Precision: {std_precision}")
print(f"Recall: {std_recall}")
print(f"F1 Score: {std_f1}")

# %%
# Calculate the interquartile range for each metric
iqr_loss = np.percentile(all_losses, 75) - np.percentile(all_losses, 25)
iqr_accuracy = np.percentile(all_accuracies, 75) - np.percentile(all_accuracies, 25)
iqr_precision = np.percentile(all_precisions, 75) - np.percentile(all_precisions, 25)
iqr_recall = np.percentile(all_recalls, 75) - np.percentile(all_recalls, 25)
iqr_f1 = np.percentile(all_f1, 75) - np.percentile(all_f1, 25)

print("Interquartile Ranges:")
print(f"Loss: {iqr_loss}")
print(f"Accuracy: {iqr_accuracy}")
print(f"Precision: {iqr_precision}")
print(f"Recall: {iqr_recall}")
print(f"F1 Score: {iqr_f1}")

# %% [markdown]
# ## Display the seed folds results together

# %%
# Create a figure with subplots
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(18, 12))  

# Flatten the axes array for easier indexing
axes = axes.flatten()

def plot_metrics_on_axes(ax, losses, accuracies, precisions, recalls, f1, title):
    ax.plot(range(1, len(losses)+1), losses, marker='o', color='blue', label='Loss')
    ax.plot(range(1, len(accuracies)+1), accuracies, marker='o', color='green', label='Accuracy')
    ax.plot(range(1, len(precisions)+1), precisions, marker='o', color='red', label='Precision')
    ax.plot(range(1, len(recalls)+1), recalls, marker='o', color='purple', label='Recall')
    ax.plot(range(1, len(f1)+1), f1, marker='o', color='orange', label='F1 Score')
    ax.set_xticks([1, 2, 3, 4])  # Set x-axis ticks to full integers
    ax.set_title(title)
    ax.set_xlabel('Fold Number')
    ax.set_ylabel('Metric Value')
    ax.legend()
    ax.grid(True)

# Plot onto each axes object
plot_metrics_on_axes(axes[0], *seed_1_folds_values, "Seed 1 Metrics")
plot_metrics_on_axes(axes[1], *seed_2_folds_values, "Seed 2 Metrics")
plot_metrics_on_axes(axes[2], *seed_3_folds_values, "Seed 3 Metrics")
plot_metrics_on_axes(axes[3], *seed_4_folds_values, "Seed 4 Metrics")
plot_metrics_on_axes(axes[4], *seed_5_folds_values, "Seed 5 Metrics")

# Hide the unused subplot 
for ax in axes[5:]:
    ax.set_visible(False)

# Adjust layout
plt.tight_layout()
plt.show()
