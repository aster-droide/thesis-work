# %% [markdown]
# # YAMNet Multi Seed Validation
# #### 5 Random (but reproducible) seeds are selected for 5 different runs of train/test
# #### Models have been optimised and verified on validation sets thoroughly, running a final train/test evaluation here
# #### The setup:
#
# - 4 fold StratifiedGroupKFold for stratification and ensuring each cat_id group only appears in one set at a time
# - Final scores averaged over the 4 folds
# - For each seed run we will explore the cat_id predictions through majority voting
# - For each run we will explore the potential impact of gender
# - Includes visualisations & analysis
#
# The dataset is highly unbalanced.

# %%
# Standard imports
import numpy as np
import pandas as pd
import random
from datetime import datetime
from collections import Counter

# Sklearn imports
from sklearn.model_selection import train_test_split, GroupShuffleSplit, GroupKFold, StratifiedGroupKFold
from sklearn.preprocessing import LabelEncoder, MinMaxScaler, RobustScaler, StandardScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report
from sklearn.utils.class_weight import compute_class_weight
from sklearn.inspection import permutation_importance

# Imbalanced-learn import
from imblearn.over_sampling import SMOTE

# TensorFlow and Keras imports
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Dropout, Input, BatchNormalization, concatenate
from tensorflow.keras.optimizers import Adam, RMSprop, SGD, Adamax, AdamW
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import to_categorical
from keras.regularizers import l1, l2, L1L2

# Optuna import
import optuna

# Visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns

from IPython.display import display

# %%
# Set an initial seed for reproducibility
np.random.seed(42)  

# Generate a list of 5 random seeds
random_seeds = np.random.randint(0, 10000, size=5)
print("Random Seeds:", random_seeds)
# Out:
# Random Seeds: [7270  860 5390 5191 5734]

# %% [markdown]
# #### TOTAL RESULTS ACROSS SEED INITIATION

# %%
# Lists to collect statistics across all CVs
all_losses, all_accuracies, all_precisions, all_recalls, all_f1 = [], [], [], [], []
all_majority_vote_accuracies, all_majority_vote_details, all_class_stats, all_gender_stats  = [], [], [], []

# %% [markdown]
# ## Define Functions

# %%
def check_initial_group_split(groups_train, groups_test):
    """
    Check if any group is present in both the train and test sets.

    Parameters:
    - groups_train: Array of group identifiers for the train set
    - groups_test: Array of group identifiers for the test set

    Returns:
    - Prints out any groups found in both sets and the count of such groups
    """
    train_groups = set(groups_train)
    test_groups = set(groups_test)
    common_groups = train_groups.intersection(test_groups)

    if common_groups:
        print(f"Warning: Found {len(common_groups)} common groups in both train/validation and test sets: {common_groups}")
    else:
        print("No common groups found between train and test sets.")

# %%
# Function to perform the swaps based on cat_id, ensuring swaps within the same age_group
def swap_cat_id_instances(dataframe, train_val_idx, test_idx, specific_cat_ids):
    for cat_id in specific_cat_ids:
        # Check if the specific cat_id is not in the training set
        if cat_id not in dataframe.iloc[train_val_idx]['cat_id'].values:
            # Get the age_group of this cat_id
            age_group = dataframe[dataframe['cat_id'] == cat_id]['age_group'].iloc[0]
                
            # Find a different cat_id within the same age_group in the train set that is not in the test set
            other_cat_ids_in_age_group = dataframe[(dataframe['age_group'] == age_group) & 
                                                   (dataframe['cat_id'] != cat_id) &
                                                   (~dataframe['cat_id'].isin(dataframe.iloc[test_idx]['cat_id']))]['cat_id'].unique()
            
            # Choose one other cat_id for swapping
            if len(other_cat_ids_in_age_group) > 0:
                other_cat_id = np.random.choice(other_cat_ids_in_age_group)

                # Find all instances of the other_cat_id in the train set
                other_cat_id_train_val_indices = train_val_idx[dataframe.iloc[train_val_idx]['cat_id'] == other_cat_id]
                
                # Find all instances of the specific cat_id in the test set
                cat_id_test_indices = test_idx[dataframe.iloc[test_idx]['cat_id'] == cat_id]
                
                # Swap the indices
                train_val_idx = np.setdiff1d(train_val_idx, other_cat_id_train_val_indices, assume_unique=True)
                test_idx = np.setdiff1d(test_idx, cat_id_test_indices, assume_unique=True)

                train_val_idx = np.concatenate((train_val_idx, cat_id_test_indices))
                test_idx = np.concatenate((test_idx, other_cat_id_train_val_indices))
            else:
                print(f"No alternative cat_id found in the same age_group as {cat_id} for swapping.")
                
    return train_val_idx, test_idx

# %%
# Function to identify differences in groups
def find_group_differences(original, new):
    # Convert numpy arrays to sets for easy difference computation
    original_set = set(original)
    new_set = set(new)
    # Find differences
    moved_to_new = new_set - original_set
    moved_to_original = original_set - new_set
    return moved_to_new, moved_to_original

# %%
# create custom logger function for local logs & stored in a .txt
def logger(message, file=None):
    print(message)
    if file is not None:
        with open(file, "a") as log_file:
            log_file.write(message + "\n")

log_file_path = "multi-seed-val-D13.txt"

# %%
# Set the aesthetic style of the plots
sns.set(style="whitegrid", palette="deep")

# Define a custom color palette
colors = ["#6aabd1", "#b6e2d3", "#dac292"] 
sns.set_palette(sns.color_palette(colors))

# Function to create bar plots with enhanced style
def styled_barplot(data, x, y, title, xlabel, ylabel):
    plt.figure(figsize=(8, 4))
    bar_plot = sns.barplot(x=x, y=y, data=data, errorbar=None, width=0.5)  
    plt.title(title, fontsize=16, fontweight='bold', color="#333333")
    plt.xlabel(xlabel, fontsize=14, fontweight='bold', color="#333333")
    plt.ylabel(ylabel, fontsize=14, fontweight='bold', color="#333333")
    plt.xticks(fontsize=12, color="#333333")
    plt.yticks(fontsize=12, color="#333333")
    plt.ylim(0, 100) 

    # Adding value labels on top of each bar
    for p in bar_plot.patches:
        height = p.get_height()
        # Annotate the height value on the bar
        bar_plot.annotate(f'{height:.1f}', 
                          (p.get_x() + p.get_width() / 2., height), 
                          ha='center', va='center', 
                          xytext=(0, 9), 
                          textcoords='offset points', fontsize=12, color="#333333")

    plt.show()

# %%
def plot_all_metrics(losses, accuracies, precisions, recalls, f1, metrics_across, x_axis_label):
    fig, ax = plt.subplots(figsize=(12, 8))
    seeds = range(1, len(losses) + 1)

    ax.plot(seeds, losses, marker='o', color='blue', label='Loss')
    ax.plot(seeds, accuracies, marker='o', color='green', label='Accuracy')
    ax.plot(seeds, precisions, marker='o', color='red', label='Precision')
    ax.plot(seeds, recalls, marker='o', color='purple', label='Recall')
    ax.plot(seeds, f1, marker='o', color='orange', label='F1 Score')

    ax.set_title(f'Metrics Across {metrics_across}')
    ax.set_xlabel(x_axis_label)
    ax.set_ylabel('Metric Value')
    ax.set_xticks(seeds)
    ax.legend()
    ax.grid(True)

    return fig

# %% [markdown]
# # RANDOM SEED 1

# %% [markdown]
# ## Prepare Data

# %%
# Set a fixed random seed for reproducibility
random.seed(int(random_seeds[0])) 
np.random.seed(int(random_seeds[0]))
tf.random.set_seed(int(random_seeds[0]))

# Load datasets
dataframe = pd.read_csv('/Users/astrid/PycharmProjects/data-aug-and-more/yamnet-tfhub-extraction/yamnet_embeddings_not_looped_april_23.csv')


def assign_age_group(age, age_groups):
    for group_name, age_range in age_groups.items():
        if age_range[0] <= age < age_range[1]:
            return group_name
    return 'Unknown'  # For any age that doesn't fit the defined groups

# Define age groups
age_groups = {
    'kitten': (0, 0.5),
    'adult': (0.5, 12),
    'senior': (12, 20)
}

# Create a new column for the age group
dataframe['age_group'] = dataframe['target'].apply(assign_age_group, age_groups=age_groups)

print(dataframe['age_group'].value_counts())
# Out:
# adult     599
# senior    183
# kitten    176
# Name: age_group, dtype: int64

# %%
# Separate features and labels
X = dataframe.iloc[:, :-4].values  # all columns except the last four

# Encode the 'age_group' column as integers using LabelEncoder
label_encoder = LabelEncoder()
encoded_y = label_encoder.fit_transform(dataframe['age_group'].values)

# Use the encoded labels for splitting and one-hot encoding
y = encoded_y  

# Convert 'cat_id' column to numpy array to be used as groups array for GroupKFold
groups = dataframe['cat_id'].values

# %%
tf.keras.backend.clear_session()

# %% [markdown]
# ## Run Setup

# %%
all_cat_ids = []
all_predicted_age_groups = []
all_actual_age_groups = []
all_gender = []

# Define the StratifiedGroupKFold splitter for 4 fold CV with random shuffling
outer_cv = StratifiedGroupKFold(n_splits=4, shuffle=True, random_state=int(random_seeds[0]))

# unseen test set metrics
unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1 = [], [], [], [], []

outer_fold = 0

# Use the splitter to generate indices for training and testing sets
# Note: GroupShuffleSplit.split returns indices, so we use it to index the arrays
for train_val_idx, test_idx in outer_cv.split(X, y, groups):
    outer_fold += 1
    logger(f"outer_fold {outer_fold}", file=log_file_path)

    # Convert indices back to DataFrame for easy manipulation
    df_train_val = dataframe.iloc[train_val_idx]
    df_test = dataframe.iloc[test_idx]

    ##############################
    # ASSESSING SPLITS BY CAT_ID #
    ##############################
    
    # Get the distribution of groups
    training_validation_group_distribution = df_train_val['cat_id'].value_counts()  
    testing_group_distribution = df_test['cat_id'].value_counts()  
    
    # Log or print the distribution
    logger(f"Train Set Group Distribution:\n{training_validation_group_distribution}", file=log_file_path)
    logger(f"Testing Set Group Distribution:\n{testing_group_distribution}", file=log_file_path)

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val['gender'].value_counts()
    testing_gender_distribution = df_test['gender'].value_counts()
    
    # Log the distribution
    logger(f"Training Set Gender Distribution BEFORE SWAP:\n{training_gender_distribution}", file=log_file_path)
    logger(f"Testing Set Gender Distribution BEFORE SWAP:\n{testing_gender_distribution}", file=log_file_path)

    # Group by 'age_group' and then list unique 'cat_id' within each age group
    unique_cat_ids_per_age_group_train_val = df_train_val.groupby('age_group')['cat_id'].unique()
    unique_cat_ids_per_age_group_test = df_test.groupby('age_group')['cat_id'].unique()
    
    # Log results
    logger(f"Unique Cat IDs per Age Group in Training/Validation Set:\n{unique_cat_ids_per_age_group_train_val}", file=log_file_path)
    logger(f"Unique Cat IDs per Age Group in Testing Set:\n{unique_cat_ids_per_age_group_test}", file=log_file_path)

    # Calculate the count of unique identifiers per age group for training and testing set
    counts_train_val = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_train_val.items()}
    counts_test = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_test.items()}

    # Log the counts of unique identifiers per age group
    logger(f"Count of Unique Cat IDs per Age Group in Training/Validation Set:\n{counts_train_val}", file=log_file_path)
    logger(f"Count of Unique Cat IDs per Age Group in Testing Set:\n{counts_test}", file=log_file_path)

    #######################################################
    # CONTINUE WITH ENSURING VALID AND APPROPRIATE SPLITS #
    #######################################################
    
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    groups_train_val, groups_test = groups[train_val_idx], groups[test_idx]

    # logging identifier splits 
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)

    # check group splits
    check_initial_group_split(groups_train_val, groups_test)

    # Specify the cat_ids that must be in the training/validation set
    specific_cat_ids = ['000A', '046A']
    
    # Perform the swapping operation
    train_val_idx, test_idx = swap_cat_id_instances(dataframe, train_val_idx, test_idx, specific_cat_ids)
    
    # Re-assign the sets based on the updated indices
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    new_groups_train_val, new_groups_test = groups[train_val_idx], groups[test_idx]

    # Find differences for training and test sets
    moved_to_train_val, removed_from_train_val = find_group_differences(groups_train_val, new_groups_train_val)
    moved_to_test, removed_from_test = find_group_differences(groups_test, new_groups_test)
    
    # Display the results
    logger(f"Moved to Training/Validation Set:\n{moved_to_train_val}", file=log_file_path)
    logger(f"Removed from Training/Validation Set:\n{removed_from_train_val}", file=log_file_path)
    logger(f"Moved to Test Set:\n{moved_to_test}", file=log_file_path)
    logger(f"Removed from Test Set\n{removed_from_test}", file=log_file_path)

    # Update X_train_val, X_test, y_train_val, y_test, groups_train_val, groups_test based on updated indices
    X_train_val = X[train_val_idx]
    y_train_val = y[train_val_idx]
    groups_train_val = groups[train_val_idx]
    
    X_test = X[test_idx]
    y_test = y[test_idx]
    groups_test = groups[test_idx]

    # logging identifier splits again after potential swaps
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"AFTER SWAP - Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"AFTER SWAP - Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)
    
    # Verify the lengths are consistent
    logger(f"Length of X_train_val:\n{len(X_train_val)}", file=log_file_path)
    logger(f"Length of y_train_val:\n{len(y_train_val)}", file=log_file_path)
    logger(f"Length of groups_train_val:\n{len(groups_train_val)}", file=log_file_path)

    # Check group splits once more
    check_initial_group_split(groups_train_val, groups_test)

    # Convert the modified indices back to a DataFrame representing the updated df_train_val
    df_train_val_updated = dataframe.iloc[train_val_idx].copy()
    df_test_updated = dataframe.iloc[test_idx].copy()

    ############################
    # LOGGING AGE GROUP SPLITS #
    ############################

    # Get the distribution of age groups of age groups before the update
    training_validation_age_group_distribution = df_train_val['age_group'].value_counts()
    testing_age_group_distribution = df_test['age_group'].value_counts()
    
    # Logthe distribution
    logger(f"Train Age Group Distribution BEFORE SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution BEFORE SWAP:\n{testing_age_group_distribution}", file=log_file_path)

    # Get the distribution of age groups after the update
    training_validation_age_group_distribution = df_train_val_updated['age_group'].value_counts()
    testing_age_group_distribution = df_test_updated['age_group'].value_counts()
    
    # Log the distribution
    logger(f"Train Age Group Distribution AFTER SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution AFTER SWAP:\n{testing_age_group_distribution}", file=log_file_path)
    
    ########################################################
    # TRACKING FINAL CAT_IDs & GENDER AFTER REDISTRIBUTION #
    ########################################################

    # Get the distribution of groups
    training_validation_group_distribution = df_train_val_updated['cat_id'].value_counts()  
    testing_group_distribution = df_test_updated['cat_id'].value_counts()  

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val_updated['gender'].value_counts()
    testing_gender_distribution = df_test_updated['gender'].value_counts()
    
    logger(f"\n Starting training on unseen test set\n", file=log_file_path)

    ###################
    # PREPARING MODEL #
    ###################

    # Calculate the distribution of age groups in y_train_val
    age_group_distribution = Counter(y_train_val)
    print("Age group distribution:", age_group_distribution)

    # EarlyStopping callback: monitor 'loss' instead of 'val_loss' for the test set
    early_stopping = EarlyStopping(
        monitor='loss',  
        min_delta=0.001, 
        patience=30,  
        verbose=1,  
        restore_best_weights=True  
    )

    # One final shuffle to ensure randomness
    outer_shuffle_idx = np.random.permutation(len(X_train_val))
    X_train_val = X_train_val[outer_shuffle_idx]
    y_train_val = y_train_val[outer_shuffle_idx]
    
    # Scale the features
    scaler_full = StandardScaler().fit(X_train_val)
    X_train_full_scaled = scaler_full.transform(X_train_val)
    X_test_scaled = scaler_full.transform(X_test)
    
    # Encode the labels
    y_train_full_encoded = to_categorical(y_train_val)
    y_test_encoded = to_categorical(y_test)

    #######################
    # BUILD & TRAIN MODEL #
    #######################

    optimizers = {
        'Adamax': Adamax(learning_rate=0.00510251984616472)
    }
    
    # Model definition with dynamic number of layers
    model_full = Sequential()
    model_full.add(Dense(480, activation='relu', input_shape=(X_train_full_scaled.shape[1],)))
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.2011047009431978))  
    model_full.add(Dense(256, activation='relu',)) 
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.14956886311951184))  
    model_full.add(Dense(256, activation='relu'))  
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.42291461228250665))  
    model_full.add(Dense(3, activation='softmax'))  
    
    # Use the optimizer from the parameters
    optimizer = optimizers['Adamax']  # optimizer_key from parameters
    
    # Compile the model
    model_full.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    
    # Train the model on the full training set
    history_full = model_full.fit(X_train_full_scaled, y_train_full_encoded, epochs=1500, batch_size=64,
                                  verbose=1, callbacks=[early_stopping])
    
    # Evaluate the model on the held-out test set
    test_loss, test_accuracy = model_full.evaluate(X_test_scaled, y_test_encoded)

    y_test_pred_prob = model_full.predict(X_test_scaled)
    y_test_pred = np.argmax(y_test_pred_prob, axis=1)  
    y_test_true = np.argmax(y_test_encoded, axis=1)    

    ################################
    # LOG MAJORITY VOTE PER CAT_ID #
    ################################

    # Convert numeric predictions back to age group labels
    predicted_age_groups = label_encoder.inverse_transform(y_test_pred)
    actual_labels = label_encoder.inverse_transform(y_test_true)
    
    # Map predictions and actual labels back to cat_ids
    test_results = pd.DataFrame({
        'cat_id': df_test_updated['cat_id'],
        'predicted_age_group': predicted_age_groups,
        'actual_age_group': actual_labels
    })
    
    # Group by cat_id and aggregate predicted age groups
    majority_votes = test_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
    actual_groups = test_results.groupby('cat_id')['actual_age_group'].first()
    
    # Calculate the accuracy of majority voting
    correct_predictions = (majority_votes == actual_groups).sum()
    total_cats = len(actual_groups)
    majority_vote_accuracy = correct_predictions / total_cats
    
    # Log the accuracy of the majority voting
    logger(f"Majority Vote Accuracy for cat_id for this fold: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

    ####################################################
    # COLLECT PREDICTIONS FOR GENDER & CAT_ID ANALYSIS #
    ####################################################

    # Debugging print statements
    print(f'Before appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Extend lists with current fold results
    all_cat_ids.extend(df_test_updated['cat_id'].tolist())
    all_predicted_age_groups.extend(predicted_age_groups)
    all_actual_age_groups.extend(actual_labels)
    all_gender.extend(df_test_updated['gender'].tolist())

    # Debugging print statements
    print(f'After appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Calculate additional metrics
    test_precision = precision_score(y_test_true, y_test_pred, average='macro')  # Use 'macro' for imbalanced datasets
    test_recall = recall_score(y_test_true, y_test_pred, average='macro')
    test_f1 = f1_score(y_test_true, y_test_pred, average='macro')

    # prepare averages of outer metrics
    unseen_f1.append(test_f1)
    unseen_losses.append(test_loss)
    unseen_accuracies.append(test_accuracy)
    unseen_precisions.append(test_precision)
    unseen_recalls.append(test_recall)

    # Print final test results
    logger(f"Final Test Results - Loss: {test_loss}, Accuracy: {test_accuracy}, Precision: {test_precision}, Recall: {test_recall}, F1 Score: {test_f1}", file=log_file_path)

    # Generate the confusion matrix
    cm = confusion_matrix(y_test, y_test_pred)
    logger(f"Confusion Matrix:\n {cm}", file=log_file_path)

# Calculate the overall average metrics
unseen_set_avg_f1 = np.mean(unseen_f1)
unseen_set_avg_loss = np.mean(unseen_losses)
unseen_set_avg_acc = np.mean(unseen_accuracies)
unseen_set_avg_precision = np.mean(unseen_precisions)
unseen_set_avg_recall = np.mean(unseen_recalls)

logger(f"\nFinal Average F1-Score across all UNSEEN TEST sets: {unseen_set_avg_f1}", file=log_file_path)
logger(f"\nFinal Average Loss across all UNSEEN TEST sets: {unseen_set_avg_loss}", file=log_file_path)
logger(f"\nFinal Average Accuracy across all UNSEEN TEST sets: {unseen_set_avg_acc}", file=log_file_path)
logger(f"\nFinal Average Precision across all UNSEEN TEST sets: {unseen_set_avg_precision}", file=log_file_path)
logger(f"\nFinal Average Recall across all UNSEEN TEST sets: {unseen_set_avg_recall}\n", file=log_file_path)

# Append averages to total lists
all_f1.append(unseen_set_avg_f1)
all_losses.append(unseen_set_avg_loss)
all_accuracies.append(unseen_set_avg_acc)
all_precisions.append(unseen_set_avg_precision)
all_recalls.append(unseen_set_avg_recall)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# outer_fold 1
# Train Set Group Distribution:
# 000A    39
# 002B    35
# 047A    30
# 057A    28
# 074A    25
# 020A    23
# 067A    20
# 000B    20
# 029A    17
# 019A    17
# 059A    16
# 106A    15
# 097B    14
# 042A    14
# 001A    14
# 028A    14
# 111A    13
# 002A    13
# 116A    12
# 039A    12
# 051A    12
# 016A    11
# 036A    11
# 005A    11
# 063A    11
# 068A    11
# 015A    10
# 071A    10
# 014B    10
# 033A     9
# 072A     9
# 065A     9
# 051B     9
# 022A     9
# 045A     9
# 094A     8
# 010A     8
# 095A     8
# 013B     8
# 027A     7
# 031A     7
# 099A     7
# 050A     7
# 109A     6
# 108A     6
# 007A     6
# 023A     6
# 008A     6
# 037A     6
# 044A     5
# 070A     5
# 025C     5
# 034A     5
# 075A     5
# 023B     5
# 052A     4
# 105A     4
# 012A     4
# 009A     4
# 035A     4
# 003A     4
# 113A     3
# 006A     3
# 014A     3
# 056A     3
# 038A     2
# 066A     2
# 011A     2
# 018A     2
# 054A     2
# 061A     2
# 087A     2
# 069A     2
# 102A     2
# 093A     2
# 004A     1
# 115A     1
# 019B     1
# 048A     1
# 073A     1
# 096A     1
# 043A     1
# 049A     1
# 026C     1
# 110A     1
# 091A     1
# 090A     1
# 100A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 046A    66
# 103A    33
# 055A    20
# 097A    16
# 101A    15
# 025A    11
# 040A    10
# 117A     7
# 053A     6
# 062A     5
# 021A     5
# 026A     4
# 104A     4
# 058A     3
# 064A     3
# 060A     3
# 025B     2
# 032A     2
# 076A     1
# 041A     1
# 092A     1
# 088A     1
# 024A     1
# 026B     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    306
# X    249
# F    182
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    106
# F     72
# M     43
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [002A, 028A, 070A, 033A, 000B, 071A, 020A, 000...
# kitten    [042A, 014B, 110A, 109A, 047A, 049A, 045A, 048...
# senior    [106A, 057A, 090A, 113A, 051B, 116A, 051A, 094...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [026A, 053A, 021A, 062A, 101A, 103A, 092A, 025...
# kitten                                   [046A, 040A, 041A]
# senior                 [117A, 024A, 097A, 055A, 058A, 104A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 59, 'kitten': 13, 'senior': 16}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 15, 'kitten': 3, 'senior': 6}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '004A' '005A' '006A' '007A'
#  '008A' '009A' '010A' '011A' '012A' '013B' '014A' '014B' '015A' '016A'
#  '018A' '019A' '019B' '020A' '022A' '023A' '023B' '025C' '026C' '027A'
#  '028A' '029A' '031A' '033A' '034A' '035A' '036A' '037A' '038A' '039A'
#  '042A' '043A' '044A' '045A' '047A' '048A' '049A' '050A' '051A' '051B'
#  '052A' '054A' '056A' '057A' '059A' '061A' '063A' '065A' '066A' '067A'
#  '068A' '069A' '070A' '071A' '072A' '073A' '074A' '075A' '087A' '090A'
#  '091A' '093A' '094A' '095A' '096A' '097B' '099A' '100A' '102A' '105A'
#  '106A' '108A' '109A' '110A' '111A' '113A' '115A' '116A']
# Unique Test Group IDs:
# ['021A' '024A' '025A' '025B' '026A' '026B' '032A' '040A' '041A' '046A'
#  '053A' '055A' '058A' '060A' '062A' '064A' '076A' '088A' '092A' '097A'
#  '101A' '103A' '104A' '117A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'046A'}
# Removed from Training/Validation Set:
# {'110A'}
# Moved to Test Set:
# {'110A'}
# Removed from Test Set
# {'046A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '004A' '005A' '006A' '007A'
#  '008A' '009A' '010A' '011A' '012A' '013B' '014A' '014B' '015A' '016A'
#  '018A' '019A' '019B' '020A' '022A' '023A' '023B' '025C' '026C' '027A'
#  '028A' '029A' '031A' '033A' '034A' '035A' '036A' '037A' '038A' '039A'
#  '042A' '043A' '044A' '045A' '046A' '047A' '048A' '049A' '050A' '051A'
#  '051B' '052A' '054A' '056A' '057A' '059A' '061A' '063A' '065A' '066A'
#  '067A' '068A' '069A' '070A' '071A' '072A' '073A' '074A' '075A' '087A'
#  '090A' '091A' '093A' '094A' '095A' '096A' '097B' '099A' '100A' '102A'
#  '105A' '106A' '108A' '109A' '111A' '113A' '115A' '116A']
# AFTER SWAP - Unique Test Group IDs:
# ['021A' '024A' '025A' '025B' '026A' '026B' '032A' '040A' '041A' '053A'
#  '055A' '058A' '060A' '062A' '064A' '076A' '088A' '092A' '097A' '101A'
#  '103A' '104A' '110A' '117A']
# Length of X_train_val:
# 802
# Length of y_train_val:
# 802
# Length of groups_train_val:
# 802
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     506
# senior    132
# kitten     99
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     93
# kitten    77
# senior    51
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     506
# kitten    164
# senior    132
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     93
# senior    51
# kitten    12
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 506, 1: 164, 2: 132})
# Epoch 1/1500
# 13/13 [==============================] - 1s 5ms/step - loss: 1.4695 - accuracy: 0.5100
# Epoch 2/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.7480 - accuracy: 0.6995
# Epoch 3/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.5480 - accuracy: 0.7930
# Epoch 4/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3873 - accuracy: 0.8454
# Epoch 5/1500
# 13/13 [==============================] - 0s 23ms/step - loss: 0.3118 - accuracy: 0.8890
# Epoch 6/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2528 - accuracy: 0.9077
# Epoch 7/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2003 - accuracy: 0.9414
# Epoch 8/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.1756 - accuracy: 0.9302
# Epoch 9/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1746 - accuracy: 0.9439
# Epoch 10/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1896 - accuracy: 0.9377
# Epoch 11/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1218 - accuracy: 0.9613
# Epoch 12/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1335 - accuracy: 0.9613
# Epoch 13/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0922 - accuracy: 0.9738
# Epoch 14/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0896 - accuracy: 0.9813
# Epoch 15/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0591 - accuracy: 0.9825
# Epoch 16/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0559 - accuracy: 0.9776
# Epoch 17/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0621 - accuracy: 0.9788
# Epoch 18/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0603 - accuracy: 0.9763
# Epoch 19/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0468 - accuracy: 0.9863
# Epoch 20/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0425 - accuracy: 0.9900
# Epoch 21/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0444 - accuracy: 0.9900
# Epoch 22/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0296 - accuracy: 0.9950
# Epoch 23/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0312 - accuracy: 0.9938
# Epoch 24/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0394 - accuracy: 0.9838
# Epoch 25/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0287 - accuracy: 0.9888
# Epoch 26/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0364 - accuracy: 0.9900
# Epoch 27/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0306 - accuracy: 0.9900
# Epoch 28/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0438 - accuracy: 0.9838
# Epoch 29/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0482 - accuracy: 0.9875
# Epoch 30/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0273 - accuracy: 0.9913
# Epoch 31/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0415 - accuracy: 0.9863
# Epoch 32/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0283 - accuracy: 0.9900
# Epoch 33/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0272 - accuracy: 0.9913
# Epoch 34/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0242 - accuracy: 0.9950
# Epoch 35/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0249 - accuracy: 0.9938
# Epoch 36/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0312 - accuracy: 0.9863
# Epoch 37/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0312 - accuracy: 0.9888
# Epoch 38/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0237 - accuracy: 0.9925
# Epoch 39/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0154 - accuracy: 0.9950
# Epoch 40/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0272 - accuracy: 0.9913
# Epoch 41/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0166 - accuracy: 0.9938
# Epoch 42/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0109 - accuracy: 0.9975
# Epoch 43/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0108 - accuracy: 0.9963
# Epoch 44/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0046 - accuracy: 1.0000
# Epoch 45/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0072 - accuracy: 0.9988
# Epoch 46/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0063 - accuracy: 1.0000
# Epoch 47/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0051 - accuracy: 0.9988
# Epoch 48/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0166 - accuracy: 0.9913
# Epoch 49/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0062 - accuracy: 0.9975
# Epoch 50/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0281 - accuracy: 0.9863
# Epoch 51/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0320 - accuracy: 0.9900
# Epoch 52/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0071 - accuracy: 0.9975
# Epoch 53/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0097 - accuracy: 0.9975
# Epoch 54/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0240 - accuracy: 0.9888
# Epoch 55/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0079 - accuracy: 0.9988
# Epoch 56/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0154 - accuracy: 0.9950
# Epoch 57/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0074 - accuracy: 0.9988
# Epoch 58/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0063 - accuracy: 0.9988
# Epoch 59/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0078 - accuracy: 0.9975
# Epoch 60/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0191 - accuracy: 0.9925
# Epoch 61/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0202 - accuracy: 0.9938
# Epoch 62/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0207 - accuracy: 0.9963
# Epoch 63/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0110 - accuracy: 0.9975
# Epoch 64/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0105 - accuracy: 0.9925
# Epoch 65/1500
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0072 - accuracy: 0.9975
# Epoch 66/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0152 - accuracy: 0.9963
# Epoch 67/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0256 - accuracy: 0.9913
# Epoch 68/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0172 - accuracy: 0.9938
# Epoch 69/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0103 - accuracy: 0.9975
# Epoch 70/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0163 - accuracy: 0.9938
# Epoch 71/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0105 - accuracy: 0.9975
# Epoch 72/1500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0282 - accuracy: 0.9913
# Epoch 73/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0069 - accuracy: 0.9988
# Epoch 74/1500
# 11/13 [========================>.....] - ETA: 0s - loss: 0.0063 - accuracy: 0.9972    Restoring model weights from the end of the best epoch: 44.
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0095 - accuracy: 0.9950
# Epoch 74: early stopping
# 5/5 [==============================] - 0s 1ms/step - loss: 2.2183 - accuracy: 0.6154
# 5/5 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.71 (17/24)
# Before appending - Cat IDs: 0, Predictions: 0, Actuals: 0, Gender: 0
# After appending - Cat IDs: 156, Predictions: 156, Actuals: 156, Gender: 156
# Final Test Results - Loss: 2.2182998657226562, Accuracy: 0.6153846383094788, Precision: 0.6124725516029864, Recall: 0.5789584651064726, F1 Score: 0.5842898825990612
# Confusion Matrix:
#  [[74  3 16]
#  [ 4  8  0]
#  [37  0 14]]
# outer_fold 2
# Train Set Group Distribution:
# 046A    66
# 000A    39
# 002B    35
# 103A    33
# 047A    30
# 057A    28
# 055A    20
# 067A    20
# 019A    17
# 029A    17
# 097A    16
# 101A    15
# 001A    14
# 042A    14
# 097B    14
# 002A    13
# 116A    12
# 039A    12
# 025A    11
# 063A    11
# 068A    11
# 040A    10
# 071A    10
# 014B    10
# 045A     9
# 065A     9
# 033A     9
# 022A     9
# 051B     9
# 013B     8
# 010A     8
# 027A     7
# 117A     7
# 099A     7
# 108A     6
# 053A     6
# 109A     6
# 023A     6
# 008A     6
# 007A     6
# 034A     5
# 025C     5
# 075A     5
# 062A     5
# 021A     5
# 023B     5
# 012A     4
# 104A     4
# 026A     4
# 035A     4
# 052A     4
# 009A     4
# 056A     3
# 064A     3
# 060A     3
# 058A     3
# 113A     3
# 032A     2
# 102A     2
# 069A     2
# 093A     2
# 061A     2
# 038A     2
# 011A     2
# 018A     2
# 025B     2
# 019B     1
# 026B     1
# 004A     1
# 076A     1
# 115A     1
# 041A     1
# 110A     1
# 091A     1
# 043A     1
# 024A     1
# 073A     1
# 088A     1
# 092A     1
# 090A     1
# 096A     1
# 100A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 074A    25
# 020A    23
# 000B    20
# 059A    16
# 106A    15
# 028A    14
# 111A    13
# 051A    12
# 016A    11
# 005A    11
# 036A    11
# 015A    10
# 072A     9
# 095A     8
# 094A     8
# 050A     7
# 031A     7
# 037A     6
# 070A     5
# 044A     5
# 003A     4
# 105A     4
# 006A     3
# 014A     3
# 054A     2
# 087A     2
# 066A     2
# 049A     1
# 048A     1
# 026C     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    300
# M    207
# F    192
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# M    142
# F     62
# X     55
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [002A, 033A, 071A, 000A, 026A, 065A, 053A, 023...
# kitten    [046A, 042A, 014B, 110A, 109A, 040A, 047A, 045...
# senior    [117A, 057A, 090A, 113A, 051B, 116A, 024A, 097...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [028A, 070A, 000B, 020A, 015A, 026C, 105A, 072...
# kitten                       [049A, 048A, 111A, 044A, 050A]
# senior                 [106A, 051A, 094A, 059A, 016A, 054A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 55, 'kitten': 11, 'senior': 16}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 19, 'kitten': 5, 'senior': 6}
# Unique Training/Validation Group IDs:
# ['000A' '001A' '002A' '002B' '004A' '007A' '008A' '009A' '010A' '011A'
#  '012A' '013B' '014B' '018A' '019A' '019B' '021A' '022A' '023A' '023B'
#  '024A' '025A' '025B' '025C' '026A' '026B' '027A' '029A' '032A' '033A'
#  '034A' '035A' '038A' '039A' '040A' '041A' '042A' '043A' '045A' '046A'
#  '047A' '051B' '052A' '053A' '055A' '056A' '057A' '058A' '060A' '061A'
#  '062A' '063A' '064A' '065A' '067A' '068A' '069A' '071A' '073A' '075A'
#  '076A' '088A' '090A' '091A' '092A' '093A' '096A' '097A' '097B' '099A'
#  '100A' '101A' '102A' '103A' '104A' '108A' '109A' '110A' '113A' '115A'
#  '116A' '117A']
# Unique Test Group IDs:
# ['000B' '003A' '005A' '006A' '014A' '015A' '016A' '020A' '026C' '028A'
#  '031A' '036A' '037A' '044A' '048A' '049A' '050A' '051A' '054A' '059A'
#  '066A' '070A' '072A' '074A' '087A' '094A' '095A' '105A' '106A' '111A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '001A' '002A' '002B' '004A' '007A' '008A' '009A' '010A' '011A'
#  '012A' '013B' '014B' '018A' '019A' '019B' '021A' '022A' '023A' '023B'
#  '024A' '025A' '025B' '025C' '026A' '026B' '027A' '029A' '032A' '033A'
#  '034A' '035A' '038A' '039A' '040A' '041A' '042A' '043A' '045A' '046A'
#  '047A' '051B' '052A' '053A' '055A' '056A' '057A' '058A' '060A' '061A'
#  '062A' '063A' '064A' '065A' '067A' '068A' '069A' '071A' '073A' '075A'
#  '076A' '088A' '090A' '091A' '092A' '093A' '096A' '097A' '097B' '099A'
#  '100A' '101A' '102A' '103A' '104A' '108A' '109A' '110A' '113A' '115A'
#  '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['000B' '003A' '005A' '006A' '014A' '015A' '016A' '020A' '026C' '028A'
#  '031A' '036A' '037A' '044A' '048A' '049A' '050A' '051A' '054A' '059A'
#  '066A' '070A' '072A' '074A' '087A' '094A' '095A' '105A' '106A' '111A']
# Length of X_train_val:
# 699
# Length of y_train_val:
# 699
# Length of groups_train_val:
# 699
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     431
# kitten    149
# senior    119
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     168
# senior     64
# kitten     27
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     431
# kitten    149
# senior    119
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     168
# senior     64
# kitten     27
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 431, 1: 149, 2: 119})
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Epoch 1/1500
# 11/11 [==============================] - 1s 4ms/step - loss: 1.4444 - accuracy: 0.4592
# Epoch 2/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.7165 - accuracy: 0.7411
# Epoch 3/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.4965 - accuracy: 0.8069
# Epoch 4/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.3408 - accuracy: 0.8698
# Epoch 5/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.2845 - accuracy: 0.8856
# Epoch 6/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.2152 - accuracy: 0.9285
# Epoch 7/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.2127 - accuracy: 0.9156
# Epoch 8/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.1713 - accuracy: 0.9428
# Epoch 9/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.1525 - accuracy: 0.9385
# Epoch 10/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1209 - accuracy: 0.9499
# Epoch 11/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1450 - accuracy: 0.9413
# Epoch 12/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1385 - accuracy: 0.9542
# Epoch 13/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0873 - accuracy: 0.9671
# Epoch 14/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0779 - accuracy: 0.9742
# Epoch 15/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0695 - accuracy: 0.9771
# Epoch 16/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0531 - accuracy: 0.9828
# Epoch 17/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0570 - accuracy: 0.9800
# Epoch 18/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0354 - accuracy: 0.9914
# Epoch 19/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0488 - accuracy: 0.9828
# Epoch 20/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0254 - accuracy: 0.9943
# Epoch 21/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0252 - accuracy: 0.9957
# Epoch 22/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0246 - accuracy: 0.9914
# Epoch 23/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0427 - accuracy: 0.9814
# Epoch 24/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0510 - accuracy: 0.9871
# Epoch 25/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0520 - accuracy: 0.9843
# Epoch 26/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0390 - accuracy: 0.9886
# Epoch 27/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0235 - accuracy: 0.9914
# Epoch 28/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0200 - accuracy: 0.9957
# Epoch 29/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0200 - accuracy: 0.9957
# Epoch 30/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0215 - accuracy: 0.9928
# Epoch 31/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0172 - accuracy: 0.9943
# Epoch 32/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0174 - accuracy: 0.9914
# Epoch 33/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0091 - accuracy: 1.0000
# Epoch 34/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0120 - accuracy: 0.9986
# Epoch 35/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0115 - accuracy: 0.9957
# Epoch 36/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0068 - accuracy: 1.0000
# Epoch 37/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0102 - accuracy: 1.0000
# Epoch 38/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0082 - accuracy: 0.9986
# Epoch 39/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0109 - accuracy: 0.9971
# Epoch 40/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0080 - accuracy: 1.0000
# Epoch 41/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0109 - accuracy: 0.9971
# Epoch 42/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0224 - accuracy: 0.9914
# Epoch 43/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0106 - accuracy: 0.9957
# Epoch 44/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0256 - accuracy: 0.9914
# Epoch 45/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0144 - accuracy: 0.9928
# Epoch 46/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0262 - accuracy: 0.9886
# Epoch 47/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0273 - accuracy: 0.9914
# Epoch 48/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0191 - accuracy: 0.9928
# Epoch 49/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0162 - accuracy: 0.9957
# Epoch 50/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0271 - accuracy: 0.9900
# Epoch 51/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0152 - accuracy: 0.9957
# Epoch 52/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0105 - accuracy: 0.9971
# Epoch 53/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0277 - accuracy: 0.9900
# Epoch 54/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0211 - accuracy: 0.9943
# Epoch 55/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0059 - accuracy: 1.0000
# Epoch 56/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0257 - accuracy: 0.9914
# Epoch 57/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.
[==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.77 (23/30)
# Before appending - Cat IDs: 156, Predictions: 156, Actuals: 156, Gender: 156
# After appending - Cat IDs: 415, Predictions: 415, Actuals: 415, Gender: 415
# Final Test Results - Loss: 3.5821890830993652, Accuracy: 0.6640926599502563, Precision: 0.5822822822822823, Recall: 0.6058476631393298, F1 Score: 0.5828657015831706
# Confusion Matrix:
#  [[132  15  21]
#  [  8  19   0]
#  [ 40   3  21]]
# outer_fold 3
# Train Set Group Distribution:
# 046A    66
# 000A    39
# 103A    33
# 047A    30
# 057A    28
# 074A    25
# 020A    23
# 000B    20
# 067A    20
# 055A    20
# 059A    16
# 097A    16
# 106A    15
# 101A    15
# 097B    14
# 001A    14
# 028A    14
# 042A    14
# 111A    13
# 051A    12
# 039A    12
# 016A    11
# 036A    11
# 025A    11
# 005A    11
# 040A    10
# 014B    10
# 015A    10
# 022A     9
# 072A     9
# 010A     8
# 095A     8
# 013B     8
# 094A     8
# 031A     7
# 099A     7
# 117A     7
# 050A     7
# 053A     6
# 037A     6
# 023A     6
# 109A     6
# 062A     5
# 070A     5
# 044A     5
# 021A     5
# 104A     4
# 009A     4
# 105A     4
# 026A     4
# 003A     4
# 064A     3
# 014A     3
# 060A     3
# 058A     3
# 113A     3
# 006A     3
# 011A     2
# 054A     2
# 102A     2
# 093A     2
# 025B     2
# 061A     2
# 087A     2
# 066A     2
# 069A     2
# 032A     2
# 091A     1
# 004A     1
# 076A     1
# 041A     1
# 048A     1
# 024A     1
# 110A     1
# 026C     1
# 088A     1
# 049A     1
# 092A     1
# 096A     1
# 043A     1
# 026B     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 002B    35
# 029A    17
# 019A    17
# 002A    13
# 116A    12
# 068A    11
# 063A    11
# 071A    10
# 051B     9
# 065A     9
# 033A     9
# 045A     9
# 027A     7
# 007A     6
# 108A     6
# 008A     6
# 025C     5
# 034A     5
# 023B     5
# 075A     5
# 012A     4
# 035A     4
# 052A     4
# 056A     3
# 038A     2
# 018A     2
# 090A     1
# 073A     1
# 019B     1
# 115A     1
# 100A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    282
# M    238
# F    207
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# M    111
# X     73
# F     47
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [028A, 070A, 000B, 020A, 000A, 015A, 026A, 053...
# kitten    [046A, 042A, 014B, 110A, 109A, 040A, 047A, 049...
# senior    [117A, 106A, 057A, 113A, 051A, 024A, 097A, 094...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [002A, 033A, 071A, 065A, 023B, 038A, 007A, 068...
# kitten                                         [045A, 115A]
# senior                       [090A, 051B, 116A, 108A, 056A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 50, 'kitten': 14, 'senior': 17}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 24, 'kitten': 2, 'senior': 5}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '003A' '004A' '005A' '006A' '009A' '010A' '011A'
#  '013B' '014A' '014B' '015A' '016A' '020A' '021A' '022A' '023A' '024A'
#  '025A' '025B' '026A' '026B' '026C' '028A' '031A' '032A' '036A' '037A'
#  '039A' '040A' '041A' '042A' '043A' '044A' '046A' '047A' '048A' '049A'
#  '050A' '051A' '053A' '054A' '055A' '057A' '058A' '059A' '060A' '061A'
#  '062A' '064A' '066A' '067A' '069A' '070A' '072A' '074A' '076A' '087A'
#  '088A' '091A' '092A' '093A' '094A' '095A' '096A' '097A' '097B' '099A'
#  '101A' '102A' '103A' '104A' '105A' '106A' '109A' '110A' '111A' '113A'
#  '117A']
# Unique Test Group IDs:
# ['002A' '002B' '007A' '008A' '012A' '018A' '019A' '019B' '023B' '025C'
#  '027A' '029A' '033A' '034A' '035A' '038A' '045A' '051B' '052A' '056A'
#  '063A' '065A' '068A' '071A' '073A' '075A' '090A' '100A' '108A' '115A'
#  '116A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '003A' '004A' '005A' '006A' '009A' '010A' '011A'
#  '013B' '014A' '014B' '015A' '016A' '020A' '021A' '022A' '023A' '024A'
#  '025A' '025B' '026A' '026B' '026C' '028A' '031A' '032A' '036A' '037A'
#  '039A' '040A' '041A' '042A' '043A' '044A' '046A' '047A' '048A' '049A'
#  '050A' '051A' '053A' '054A' '055A' '057A' '058A' '059A' '060A' '061A'
#  '062A' '064A' '066A' '067A' '069A' '070A' '072A' '074A' '076A' '087A'
#  '088A' '091A' '092A' '093A' '094A' '095A' '096A' '097A' '097B' '099A'
#  '101A' '102A' '103A' '104A' '105A' '106A' '109A' '110A' '111A' '113A'
#  '117A']
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# AFTER SWAP - Unique Test Group IDs:
# ['002A' '002B' '007A' '008A' '012A' '018A' '019A' '019B' '023B' '025C'
#  '027A' '029A' '033A' '034A' '035A' '038A' '045A' '051B' '052A' '056A'
#  '063A' '065A' '068A' '071A' '073A' '075A' '090A' '100A' '108A' '115A'
#  '116A']
# Length of X_train_val:
# 727
# Length of y_train_val:
# 727
# Length of groups_train_val:
# 727
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     409
# kitten    166
# senior    152
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     190
# senior     31
# kitten     10
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     409
# kitten    166
# senior    152
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     190
# senior     31
# kitten     10
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 409, 1: 166, 2: 152})
# Epoch 1/1500
# 12/12 [==============================] - 1s 4ms/step - loss: 1.4352 - accuracy: 0.5062
# Epoch 2/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.6750 - accuracy: 0.7510
# Epoch 3/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4929 - accuracy: 0.8074
# Epoch 4/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3674 - accuracy: 0.8583
# Epoch 5/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3012 - accuracy: 0.8817
# Epoch 6/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2361 - accuracy: 0.9023
# Epoch 7/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2079 - accuracy: 0.9271
# Epoch 8/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1638 - accuracy: 0.9354
# Epoch 9/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1549 - accuracy: 0.9436
# Epoch 10/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1557 - accuracy: 0.9450
# Epoch 11/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1006 - accuracy: 0.9587
# Epoch 12/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1114 - accuracy: 0.9574
# Epoch 13/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1054 - accuracy: 0.9615
# Epoch 14/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0787 - accuracy: 0.9766
# Epoch 15/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0649 - accuracy: 0.9725
# Epoch 16/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0501 - accuracy: 0.9862
# Epoch 17/1500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.0748 - accuracy: 0.9752
# Epoch 18/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0487 - accuracy: 0.9849
# Epoch 19/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0328 - accuracy: 0.9876
# Epoch 20/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0717 - accuracy: 0.9711
# Epoch 21/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0350 - accuracy: 0.9904
# Epoch 22/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0416 - accuracy: 0.9890
# Epoch 23/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0484 - accuracy: 0.9807
# Epoch 24/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0290 - accuracy: 0.9945
# Epoch 25/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0314 - accuracy: 0.9945
# Epoch 26/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0215 - accuracy: 0.9945
# Epoch 27/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0287 - accuracy: 0.9904
# Epoch 28/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0552 - accuracy: 0.9794
# Epoch 29/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0283 - accuracy: 0.9904
# Epoch 30/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0300 - accuracy: 0.9904
# Epoch 31/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0092 - accuracy: 0.9986
# Epoch 32/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0251 - accuracy: 0.9917
# Epoch 33/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.
1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0072 - accuracy: 0.9972
# Epoch 101/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0150 - accuracy: 0.9931
# Epoch 102/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0181 - accuracy: 0.9917
# Epoch 103/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0067 - accuracy: 0.9972
# Epoch 104/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0099 - accuracy: 0.9959
# Epoch 105/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 106/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0084 - accuracy: 0.9986
# Epoch 107/1500
# ...
# 8/8 [==============================] - 0s 980us/step
# Majority Vote Accuracy for cat_id for this fold: 0.74 (23/31)
# Before appending - Cat IDs: 415, Predictions: 415, Actuals: 415, Gender: 415
# After appending - Cat IDs: 646, Predictions: 646, Actuals: 646, Gender: 646
# Final Test Results - Loss: 25.637319564819336, Accuracy: 0.6450216174125671, Precision: 0.3906068524970964, Recall: 0.4732880588568195, F1 Score: 0.39745314321585506
# Confusion Matrix:
#  [[138  28  24]
#  [  3   5   2]
#  [ 23   2   6]]
# outer_fold 4
# Train Set Group Distribution:
# 046A    66
# 002B    35
# 103A    33
# 074A    25
# 020A    23
# 000B    20
# 055A    20
# 019A    17
# 029A    17
# 059A    16
# 097A    16
# 101A    15
# 106A    15
# 028A    14
# 002A    13
# 111A    13
# 051A    12
# 116A    12
# 016A    11
# 025A    11
# 036A    11
# 005A    11
# 063A    11
# 068A    11
# 015A    10
# 040A    10
# 071A    10
# 045A     9
# 072A     9
# 051B     9
# 033A     9
# 065A     9
# 094A     8
# 095A     8
# 031A     7
# 117A     7
# 027A     7
# 050A     7
# 037A     6
# 108A     6
# 008A     6
# 053A     6
# 007A     6
# 062A     5
# 044A     5
# 070A     5
# 021A     5
# 034A     5
# 023B     5
# 075A     5
# 025C     5
# 003A     4
# 052A     4
# 012A     4
# 035A     4
# 104A     4
# 026A     4
# 105A     4
# 060A     3
# 064A     3
# 014A     3
# 056A     3
# 006A     3
# 058A     3
# 066A     2
# 025B     2
# 018A     2
# 032A     2
# 054A     2
# 038A     2
# 087A     2
# 073A     1
# 024A     1
# 026B     1
# 076A     1
# 115A     1
# 041A     1
# 090A     1
# 019B     1
# 026C     1
# 049A     1
# 092A     1
# 048A     1
# 088A     1
# 100A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 000A    39
# 047A    30
# 057A    28
# 067A    20
# 042A    14
# 097B    14
# 001A    14
# 039A    12
# 014B    10
# 022A     9
# 010A     8
# 013B     8
# 099A     7
# 109A     6
# 023A     6
# 009A     4
# 113A     3
# 093A     2
# 061A     2
# 011A     2
# 069A     2
# 102A     2
# 096A     1
# 043A     1
# 110A     1
# 091A     1
# 004A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    296
# X    234
# F    181
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    121
# F     73
# M     53
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [002A, 028A, 070A, 033A, 000B, 071A, 020A, 015...
# kitten    [046A, 040A, 049A, 045A, 048A, 111A, 044A, 050...
# senior    [117A, 106A, 090A, 051B, 116A, 051A, 024A, 097...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [000A, 001A, 013B, 009A, 091A, 022A, 010A, 069...
# kitten                 [042A, 014B, 110A, 109A, 047A, 043A]
# senior                       [057A, 113A, 061A, 011A, 093A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 58, 'kitten': 10, 'senior': 17}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 16, 'kitten': 6, 'senior': 5}
# Unique Training/Validation Group IDs:
# ['000B' '002A' '002B' '003A' '005A' '006A' '007A' '008A' '012A' '014A'
#  '015A' '016A' '018A' '019A' '019B' '020A' '021A' '023B' '024A' '025A'
#  '025B' '025C' '026A' '026B' '026C' '027A' '028A' '029A' '031A' '032A'
#  '033A' '034A' '035A' '036A' '037A' '038A' '040A' '041A' '044A' '045A'
#  '046A' '048A' '049A' '050A' '051A' '051B' '052A' '053A' '054A' '055A'
#  '056A' '058A' '059A' '060A' '062A' '063A' '064A' '065A' '066A' '068A'
#  '070A' '071A' '072A' '073A' '074A' '075A' '076A' '087A' '088A' '090A'
#  '092A' '094A' '095A' '097A' '100A' '101A' '103A' '104A' '105A' '106A'
#  '108A' '111A' '115A' '116A' '117A']
# Unique Test Group IDs:
# ['000A' '001A' '004A' '009A' '010A' '011A' '013B' '014B' '022A' '023A'
#  '039A' '042A' '043A' '047A' '057A' '061A' '067A' '069A' '091A' '093A'
#  '096A' '097B' '099A' '102A' '109A' '110A' '113A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'000A'}
# Removed from Training/Validation Set:
# {'003A'}
# Moved to Test Set:
# {'003A'}
# Removed from Test Set
# {'000A'}
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '002A' '002B' '005A' '006A' '007A' '008A' '012A' '014A'
#  '015A' '016A' '018A' '019A' '019B' '020A' '021A' '023B' '024A' '025A'
#  '025B' '025C' '026A' '026B' '026C' '027A' '028A' '029A' '031A' '032A'
#  '033A' '034A' '035A' '036A' '037A' '038A' '040A' '041A' '044A' '045A'
#  '046A' '048A' '049A' '050A' '051A' '051B' '052A' '053A' '054A' '055A'
#  '056A' '058A' '059A' '060A' '062A' '063A' '064A' '065A' '066A' '068A'
#  '070A' '071A' '072A' '073A' '074A' '075A' '076A' '087A' '088A' '090A'
#  '092A' '094A' '095A' '097A' '100A' '101A' '103A' '104A' '105A' '106A'
#  '108A' '111A' '115A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['001A' '003A' '004A' '009A' '010A' '011A' '013B' '014B' '022A' '023A'
#  '039A' '042A' '043A' '047A' '057A' '061A' '067A' '069A' '091A' '093A'
#  '096A' '097B' '099A' '102A' '109A' '110A' '113A']
# Length of X_train_val:
# 746
# Length of y_train_val:
# 746
# Length of groups_train_val:
# 746
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     451
# senior    146
# kitten    114
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     148
# kitten     62
# senior     37
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     486
# senior    146
# kitten    114
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     113
# kitten     62
# senior     37
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 486, 2: 146, 1: 114})
# Epoch 1/1500
# 12/12 [==============================] - 1s 4ms/step - loss: 1.2862 - accuracy: 0.5402
# Epoch 2/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.6983 - accuracy: 0.7212
# Epoch 3/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4827 - accuracy: 0.8271
# Epoch 4/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3434 - accuracy: 0.8780
# Epoch 5/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3118 - accuracy: 0.8941
# Epoch 6/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2619 - accuracy: 0.9035
# Epoch 7/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1892 - accuracy: 0.9196
# Epoch 8/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1752 - accuracy: 0.9410
# Epoch 9/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1322 - accuracy: 0.9477
# Epoch 10/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1222 - accuracy: 0.9504
# Epoch 11/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0835 - accuracy: 0.9745
# Epoch 12/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0894 - accuracy: 0.9705
# Epoch 13/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0643 - accuracy: 0.9786
# Epoch 14/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0481 - accuracy: 0.9853
# Epoch 15/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0557 - accuracy: 0.9786
# Epoch 16/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0421 - accuracy: 0.9799
# Epoch 17/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0414 - accuracy: 0.9879
# Epoch 18/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0521 - accuracy: 0.9759
# Epoch 19/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0348 - accuracy: 0.9866
# Epoch 20/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0399 - accuracy: 0.9879
# Epoch 21/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0264 - accuracy: 0.9933
# Epoch 22/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0294 - accuracy: 0.9853
# Epoch 23/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0341 - accuracy: 0.9866
# Epoch 24/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0515 - accuracy: 0.9799
# Epoch 25/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0238 - accuracy: 0.9933
# Epoch 26/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0278 - accuracy: 0.9920
# Epoch 27/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0313 - accuracy: 0.9920
# Epoch 28/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0234 - accuracy: 0.9933
# Epoch 29/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0271 - accuracy: 0.9920
# Epoch 30/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0313 - accuracy: 0.9920
# Epoch 31/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0202 - accuracy: 0.9920
# Epoch 32/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0123 - accuracy: 0.9960
# Epoch 33/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0125 - accuracy: 0.9973
# Epoch 34/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0134 - accuracy: 0.9960
# Epoch 35/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0224 - accuracy: 0.9906
# Epoch 36/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0164 - accuracy: 0.9933
# Epoch 37/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0174 - accuracy: 0.9933
# Epoch 38/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0069 - accuracy: 1.0000
# Epoch 39/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0180 - accuracy: 0.9906
# Epoch 40/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0122 - accuracy: 0.9973
# Epoch 41/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0219 - accuracy: 0.9933
# Epoch 42/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0250 - accuracy: 0.9920
# Epoch 43/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0273 - accuracy: 0.9933
# Epoch 44/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0179 - accuracy: 0.9933
# Epoch 45/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0090 - accuracy: 0.9987
# Epoch 46/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0092 - accuracy: 0.9973
# Epoch 47/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0099 - accuracy: 0.9987
# Epoch 48/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0114 - accuracy: 0.9973
# Epoch 49/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0088 - accuracy: 0.9960
# Epoch 50/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0068 - accuracy: 0.9973
# Epoch 51/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0059 - accuracy: 0.9987
# Epoch 52/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0151 - accuracy: 0.9920
# Epoch 53/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 54/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 55/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 56/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0039 - accuracy: 0.9987
# Epoch 57/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0045 - accuracy: 1.0000
# Epoch 58/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0045 - accuracy: 0.9987
# Epoch 59/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0051 - accuracy: 0.9987
# Epoch 60/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0047 - accuracy: 1.0000
# Epoch 61/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 62/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 63/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0186 - accuracy: 0.9933
# Epoch 64/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0110 - accuracy: 0.9946
# Epoch 65/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0070 - accuracy: 0.9960
# Epoch 66/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0086 - accuracy: 0.9973
# Epoch 67/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0141 - accuracy: 0.9960
# Epoch 68/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0070 - accuracy: 0.9987
# Epoch 69/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0086 - accuracy: 0.9960
# Epoch 70/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0170 - accuracy: 0.9946
# Epoch 71/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0092 - accuracy: 0.9960
# Epoch 72/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0255 - accuracy: 0.9946
# Epoch 73/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0143 - accuracy: 0.9973
# Epoch 74/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0195 - accuracy: 0.9946
# Epoch 75/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0095 - accuracy: 0.9973
# Epoch 76/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0092 - accuracy: 0.9960
# Epoch 77/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 78/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0049 - accuracy: 0.9987
# Epoch 79/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0094 - accuracy: 0.9973
# Epoch 80/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0049 - accuracy: 0.9973
# Epoch 81/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0169 - accuracy: 0.9933
# Epoch 82/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0067 - accuracy: 0.9973
# Epoch 83/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0067 - accuracy: 0.9973
# Epoch 84/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0067 - accuracy: 0.9973
# Epoch 85/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0143 - accuracy: 0.9946
# Epoch 86/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0049 - accuracy: 0.9987
# Epoch 87/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0074 - accuracy: 0.9987
# Epoch 88/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0193 - accuracy: 0.9920
# Epoch 89/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0219 - accuracy: 0.9893
# Epoch 90/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0039 - accuracy: 0.9987
# Epoch 91/1500
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0198 - accuracy: 0.9943Restoring model weights from the end of the best epoch: 61.
# 12/12 [==============================] - 0s 5ms/step - loss: 0.
definition with dynamic number of layers
    model_full = Sequential()
    model_full.add(Dense(480, activation='relu', input_shape=(X_train_full_scaled.shape[1],)))
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.2011047009431978))  
    model_full.add(Dense(256, activation='relu',)) 
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.14956886311951184))  
    model_full.add(Dense(256, activation='relu'))  
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.42291461228250665))  
    model_full.add(Dense(3, activation='softmax'))  
    
    # Use the optimizer from the parameters
    optimizer = optimizers['Adamax']  # optimizer_key from parameters
    
    # Compile the model
    model_full.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    
    # Train the model on the full training set
    history_full = model_full.fit(X_train_full_scaled, y_train_full_encoded, epochs=1500, batch_size=64,
                                  verbose=1, callbacks=[early_stopping])
    
    # Evaluate the model on the held-out test set
    test_loss, test_accuracy = model_full.evaluate(X_test_scaled, y_test_encoded)

    y_test_pred_prob = model_full.predict(X_test_scaled)
    y_test_pred = np.argmax(y_test_pred_prob, axis=1)  
    y_test_true = np.argmax(y_test_encoded, axis=1)    

    ################################
    # LOG MAJORITY VOTE PER CAT_ID #
    ################################

    # Convert numeric predictions back to age group labels
    predicted_age_groups = label_encoder.inverse_transform(y_test_pred)
    actual_labels = label_encoder.inverse_transform(y_test_true)
    
    # Map predictions and actual labels back to cat_ids
    test_results = pd.DataFrame({
        'cat_id': df_test_updated['cat_id'],
        'predicted_age_group': predicted_age_groups,
        'actual_age_group': actual_labels
    })
    
    # Group by cat_id and aggregate predicted age groups
    majority_votes = test_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
    actual_groups = test_results.groupby('cat_id')['actual_age_group'].first()
    
    # Calculate the accuracy of majority voting
    correct_predictions = (majority_votes == actual_groups).sum()
    total_cats = len(actual_groups)
    majority_vote_accuracy = correct_predictions / total_cats
    
    # Log the accuracy of the majority voting
    logger(f"Majority Vote Accuracy for cat_id for this fold: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

    ####################################################
    # COLLECT PREDICTIONS FOR GENDER & CAT_ID ANALYSIS #
    ####################################################

    # Debugging print statements
    print(f'Before appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Extend lists with current fold results
    all_cat_ids.extend(df_test_updated['cat_id'].tolist())
    all_predicted_age_groups.extend(predicted_age_groups)
    all_actual_age_groups.extend(actual_labels)
    all_gender.extend(df_test_updated['gender'].tolist())

    # Debugging print statements
    print(f'After appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Calculate additional metrics
    test_precision = precision_score(y_test_true, y_test_pred, average='macro')  # Use 'macro' for imbalanced datasets
    test_recall = recall_score(y_test_true, y_test_pred, average='macro')
    test_f1 = f1_score(y_test_true, y_test_pred, average='macro')

    # prepare averages of outer metrics
    unseen_f1.append(test_f1)
    unseen_losses.append(test_loss)
    unseen_accuracies.append(test_accuracy)
    unseen_precisions.append(test_precision)
    unseen_recalls.append(test_recall)

    # Print final test results
    logger(f"Final Test Results - Loss: {test_loss}, Accuracy: {test_accuracy}, Precision: {test_precision}, Recall: {test_recall}, F1 Score: {test_f1}", file=log_file_path)

    # Generate the confusion matrix
    cm = confusion_matrix(y_test, y_test_pred)
    logger(f"Confusion Matrix:\n {cm}", file=log_file_path)

# Calculate the overall average metrics
unseen_set_avg_f1 = np.mean(unseen_f1)
unseen_set_avg_loss = np.mean(unseen_losses)
unseen_set_avg_acc = np.mean(unseen_accuracies)
unseen_set_avg_precision = np.mean(unseen_precisions)
unseen_set_avg_recall = np.mean(unseen_recalls)

logger(f"\nFinal Average F1-Score across all UNSEEN TEST sets: {unseen_set_avg_f1}", file=log_file_path)
logger(f"\nFinal Average Loss across all UNSEEN TEST sets: {unseen_set_avg_loss}", file=log_file_path)
logger(f"\nFinal Average Accuracy across all UNSEEN TEST sets: {unseen_set_avg_acc}", file=log_file_path)
logger(f"\nFinal Average Precision across all UNSEEN TEST sets: {unseen_set_avg_precision}", file=log_file_path)
logger(f"\nFinal Average Recall across all UNSEEN TEST sets: {unseen_set_avg_recall}\n", file=log_file_path)

# Append averages to total lists
all_f1.append(unseen_set_avg_f1)
all_losses.append(unseen_set_avg_loss)
all_accuracies.append(unseen_set_avg_acc)
all_precisions.append(unseen_set_avg_precision)
all_recalls.append(unseen_set_avg_recall)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# outer_fold 1
# Train Set Group Distribution:
# 046A    66
# 000A    39
# 002B    35
# 057A    28
# 074A    25
# 020A    23
# 067A    20
# 000B    20
# 029A    17
# 019A    17
# 106A    15
# 097B    14
# 028A    14
# 042A    14
# 001A    14
# 002A    13
# 051A    12
# 039A    12
# 116A    12
# 005A    11
# 036A    11
# 025A    11
# 016A    11
# 071A    10
# 040A    10
# 015A    10
# 033A     9
# 051B     9
# 022A     9
# 072A     9
# 065A     9
# 010A     8
# 013B     8
# 094A     8
# 095A     8
# 117A     7
# 027A     7
# 007A     6
# 008A     6
# 109A     6
# 053A     6
# 037A     6
# 108A     6
# 023A     6
# 070A     5
# 034A     5
# 044A     5
# 025C     5
# 021A     5
# 075A     5
# 062A     5
# 052A     4
# 003A     4
# 035A     4
# 104A     4
# 012A     4
# 009A     4
# 026A     4
# 105A     4
# 058A     3
# 006A     3
# 113A     3
# 056A     3
# 064A     3
# 060A     3
# 011A     2
# 087A     2
# 061A     2
# 093A     2
# 038A     2
# 069A     2
# 032A     2
# 054A     2
# 018A     2
# 091A     1
# 004A     1
# 076A     1
# 090A     1
# 115A     1
# 019B     1
# 088A     1
# 096A     1
# 049A     1
# 026C     1
# 048A     1
# 073A     1
# 043A     1
# 100A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 103A    33
# 047A    30
# 055A    20
# 097A    16
# 059A    16
# 101A    15
# 111A    13
# 068A    11
# 063A    11
# 014B    10
# 045A     9
# 031A     7
# 050A     7
# 099A     7
# 023B     5
# 014A     3
# 102A     2
# 066A     2
# 025B     2
# 092A     1
# 024A     1
# 110A     1
# 041A     1
# 026B     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    288
# X    246
# F    200
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    109
# M     61
# F     54
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [002A, 028A, 070A, 033A, 000B, 071A, 020A, 000...
# kitten    [046A, 042A, 109A, 040A, 049A, 048A, 044A, 043...
# senior    [117A, 106A, 057A, 090A, 113A, 051B, 116A, 051...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [023B, 068A, 101A, 103A, 063A, 031A, 092A, 102...
# kitten           [014B, 110A, 047A, 045A, 111A, 050A, 041A]
# senior                             [024A, 097A, 059A, 055A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 61, 'kitten': 9, 'senior': 18}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 13, 'kitten': 7, 'senior': 4}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '004A' '005A' '006A' '007A'
#  '008A' '009A' '010A' '011A' '012A' '013B' '015A' '016A' '018A' '019A'
#  '019B' '020A' '021A' '022A' '023A' '025A' '025C' '026A' '026C' '027A'
#  '028A' '029A' '032A' '033A' '034A' '035A' '036A' '037A' '038A' '039A'
#  '040A' '042A' '043A' '044A' '046A' '048A' '049A' '051A' '051B' '052A'
#  '053A' '054A' '056A' '057A' '058A' '060A' '061A' '062A' '064A' '065A'
#  '067A' '069A' '070A' '071A' '072A' '073A' '074A' '075A' '076A' '087A'
#  '088A' '090A' '091A' '093A' '094A' '095A' '096A' '097B' '100A' '104A'
#  '105A' '106A' '108A' '109A' '113A' '115A' '116A' '117A']
# Unique Test Group IDs:
# ['014A' '014B' '023B' '024A' '025B' '026B' '031A' '041A' '045A' '047A'
#  '050A' '055A' '059A' '063A' '066A' '068A' '092A' '097A' '099A' '101A'
#  '102A' '103A' '110A' '111A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '004A' '005A' '006A' '007A'
#  '008A' '009A' '010A' '011A' '012A' '013B' '015A' '016A' '018A' '019A'
#  '019B' '020A' '021A' '022A' '023A' '025A' '025C' '026A' '026C' '027A'
#  '028A' '029A' '032A' '033A' '034A' '035A' '036A' '037A' '038A' '039A'
#  '040A' '042A' '043A' '044A' '046A' '048A' '049A' '051A' '051B' '052A'
#  '053A' '054A' '056A' '057A' '058A' '060A' '061A' '062A' '064A' '065A'
#  '067A' '069A' '070A' '071A' '072A' '073A' '074A' '075A' '076A' '087A'
#  '088A' '090A' '091A' '093A' '094A' '095A' '096A' '097B' '100A' '104A'
#  '105A' '106A' '108A' '109A' '113A' '115A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['014A' '014B' '023B' '024A' '025B' '026B' '031A' '041A' '045A' '047A'
#  '050A' '055A' '059A' '063A' '066A' '068A' '092A' '097A' '099A' '101A'
#  '102A' '103A' '110A' '111A']
# Length of X_train_val:
# 734
# Length of y_train_val:
# 734
# Length of groups_train_val:
# 734
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     499
# senior    130
# kitten    105
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     100
# kitten     71
# senior     53
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     499
# senior    130
# kitten    105
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     100
# kitten     71
# senior     53
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 499, 2: 130, 1: 105})
# Epoch 1/1500
# 12/12 [==============================] - 1s 5ms/step - loss: 1.3457 - accuracy: 0.5232
# Epoch 2/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.7240 - accuracy: 0.7262
# Epoch 3/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4724 - accuracy: 0.8243
# Epoch 4/1500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.3702 - accuracy: 0.8610
# Epoch 5/1500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.2828 - accuracy: 0.8965
# Epoch 6/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2082 - accuracy: 0.9360
# Epoch 7/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1633 - accuracy: 0.9441
# Epoch 8/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1705 - accuracy: 0.9414
# Epoch 9/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1244 - accuracy: 0.9537
# Epoch 10/1500
# 12/12 [==============================] - 0s 19ms/step - loss: 0.0987 - accuracy: 0.9646
# Epoch 11/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0944 - accuracy: 0.9632
# Epoch 12/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0901 - accuracy: 0.9659
# Epoch 13/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1238 - accuracy: 0.9591
# Epoch 14/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0827 - accuracy: 0.9741
# Epoch 15/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0658 - accuracy: 0.9741
# Epoch 16/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0390 - accuracy: 0.9877
# Epoch 17/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0487 - accuracy: 0.9850
# Epoch 18/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0364 - accuracy: 0.9905
# Epoch 19/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0399 - accuracy: 0.9864
# Epoch 20/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0450 - accuracy: 0.9796
# Epoch 21/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0539 - accuracy: 0.9837
# Epoch 22/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0284 - accuracy: 0.9932
# Epoch 23/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0549 - accuracy: 0.9837
# Epoch 24/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0446 - accuracy: 0.9877
# Epoch 25/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0334 - accuracy: 0.9864
# Epoch 26/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0384 - accuracy: 0.9850
# Epoch 27/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0391 - accuracy: 0.9891
# Epoch 28/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0384 - accuracy: 0.9864
# Epoch 29/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0359 - accuracy: 0.9850
# Epoch 30/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0218 - accuracy: 0.9932
# Epoch 31/1500
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0211 - accuracy: 0.9932
# Epoch 32/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0442 - accuracy: 0.9823
# Epoch 33/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0369 - accuracy: 0.9864
# Epoch 34/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0174 - accuracy: 0.9946
# Epoch 35/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0168 - accuracy: 0.9959
# Epoch 36/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0083 - accuracy: 0.9973
# Epoch 37/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0110 - accuracy: 0.9986
# Epoch 38/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0123 - accuracy: 0.9946
# Epoch 39/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0108 - accuracy: 0.9973
# Epoch 40/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0081 - accuracy: 0.9986
# Epoch 41/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0106 - accuracy: 0.9959
# Epoch 42/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0055 - accuracy: 1.0000
# Epoch 43/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0150 - accuracy: 0.9973
# Epoch 44/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0112 - accuracy: 0.9973
# Epoch 45/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0064 - accuracy: 0.9986
# Epoch 46/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0074 - accuracy: 0.9986
# Epoch 47/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0081 - accuracy: 0.9986
# Epoch 48/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0043 - accuracy: 1.0000
# Epoch 49/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0081 - accuracy: 0.9973
# Epoch 50/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0067 - accuracy: 0.9986
# Epoch 51/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 52/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 53/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 54/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0115 - accuracy: 0.9959
# Epoch 55/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0293 - accuracy: 0.9905
# Epoch 56/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0124 - accuracy: 0.9959
# Epoch 57/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0439 - accuracy: 0.9864
# Epoch 58/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0208 - accuracy: 0.9932
# Epoch 59/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0144 - accuracy: 0.9932
# Epoch 60/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0053 - accuracy: 0.9986
# Epoch 61/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0285 - accuracy: 0.9932
# Epoch 62/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0089 - accuracy: 0.9973
# Epoch 63/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0085 - accuracy: 0.9959
# Epoch 64/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0189 - accuracy: 0.9946
# Epoch 65/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0086 - accuracy: 0.9973
# Epoch 66/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0221 - accuracy: 0.9918
# Epoch 67/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0144 - accuracy: 0.9946
# Epoch 68/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0164 - accuracy: 0.9973
# Epoch 69/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0201 - accuracy: 0.9918
# Epoch 70/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0076 - accuracy: 0.9986
# Epoch 71/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0286 - accuracy: 0.9905
# Epoch 72/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0099 - accuracy: 0.9973
# Epoch 73/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0139 - accuracy: 0.9946
# Epoch 74/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0072 - accuracy: 0.9986
# Epoch 75/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0055 - accuracy: 0.9986
# Epoch 76/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0100 - accuracy: 0.9946
# Epoch 77/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0093 - accuracy: 0.9986
# Epoch 78/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0050 - accuracy: 0.9986
# Epoch 79/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0201 - accuracy: 0.9918
# Epoch 80/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0059 - accuracy: 0.9973
# Epoch 81/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0095 - accuracy: 0.9986
# Epoch 82/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 83/1500
# 12/12 [==============================] - ETA: 0s - loss: 0.0054 - accuracy: 0.9986Restoring model weights from the end of the best epoch: 53.
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0054 - accuracy: 0.9986
# Epoch 83: early stopping
# 7/7 [==============================] - 0s 1ms/step - loss: 7.9356 - accuracy: 0.5268
# 7/7 [==============================] - 0s 1ms/step
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Majority Vote Accuracy for cat_id for this fold: 0.75 (18/24)
# Before appending - Cat IDs: 0, Predictions: 0, Actuals: 0, Gender: 0
# After appending - Cat IDs: 224, Predictions: 224, Actuals: 224, Gender: 224
# Final Test Results - Loss: 7.9355854988098145, Accuracy: 0.5267857313156128, Precision: 0.5432937181663836, Recall: 0.4980813180972629, F1 Score: 0.5008519003931848
# Confusion Matrix:
#  [[68 11 21]
#  [26 27 18]
#  [30  0 23]]
# outer_fold 2
# Train Set Group Distribution:
# 046A    66
# 000A    39
# 103A    33
# 047A    30
# 057A    28
# 074A    25
# 020A    23
# 000B    20
# 055A    20
# 059A    16
# 097A    16
# 106A    15
# 101A    15
# 028A    14
# 097B    14
# 001A    14
# 111A    13
# 002A    13
# 039A    12
# 051A    12
# 116A    12
# 016A    11
# 063A    11
# 068A    11
# 036A    11
# 015A    10
# 014B    10
# 040A    10
# 071A    10
# 033A     9
# 072A     9
# 045A     9
# 022A     9
# 013B     8
# 094A     8
# 010A     8
# 027A     7
# 050A     7
# 031A     7
# 117A     7
# 099A     7
# 108A     6
# 053A     6
# 008A     6
# 023A     6
# 037A     6
# 062A     5
# 070A     5
# 025C     5
# 023B     5
# 044A     5
# 035A     4
# 009A     4
# 026A     4
# 104A     4
# 003A     4
# 052A     4
# 006A     3
# 113A     3
# 014A     3
# 061A     2
# 066A     2
# 102A     2
# 032A     2
# 054A     2
# 069A     2
# 025B     2
# 011A     2
# 019B     1
# 041A     1
# 115A     1
# 110A     1
# 088A     1
# 096A     1
# 043A     1
# 048A     1
# 092A     1
# 049A     1
# 024A     1
# 090A     1
# 026C     1
# 026B     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 002B    35
# 067A    20
# 029A    17
# 019A    17
# 042A    14
# 025A    11
# 005A    11
# 065A     9
# 051B     9
# 095A     8
# 007A     6
# 109A     6
# 034A     5
# 075A     5
# 021A     5
# 012A     4
# 105A     4
# 058A     3
# 064A     3
# 060A     3
# 056A     3
# 038A     2
# 087A     2
# 018A     2
# 093A     2
# 076A     1
# 004A     1
# 091A     1
# 073A     1
# 100A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    301
# F    228
# M    218
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# M    131
# X     54
# F     26
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [002A, 028A, 070A, 033A, 000B, 071A, 020A, 000...
# kitten    [046A, 014B, 110A, 040A, 047A, 049A, 045A, 048...
# senior    [117A, 106A, 057A, 090A, 113A, 116A, 051A, 024...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [065A, 038A, 007A, 021A, 105A, 018A, 034A, 002...
# kitten                                         [042A, 109A]
# senior                             [051B, 058A, 056A, 093A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 50, 'kitten': 14, 'senior': 18}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 24, 'kitten': 2, 'senior': 4}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '003A' '006A' '008A' '009A' '010A' '011A'
#  '013B' '014A' '014B' '015A' '016A' '019B' '020A' '022A' '023A' '023B'
#  '024A' '025B' '025C' '026A' '026B' '026C' '027A' '028A' '031A' '032A'
#  '033A' '035A' '036A' '037A' '039A' '040A' '041A' '043A' '044A' '045A'
#  '046A' '047A' '048A' '049A' '050A' '051A' '052A' '053A' '054A' '055A'
#  '057A' '059A' '061A' '062A' '063A' '066A' '068A' '069A' '070A' '071A'
#  '072A' '074A' '088A' '090A' '092A' '094A' '096A' '097A' '097B' '099A'
#  '101A' '102A' '103A' '104A' '106A' '108A' '110A' '111A' '113A' '115A'
#  '116A' '117A']
# Unique Test Group IDs:
# ['002B' '004A' '005A' '007A' '012A' '018A' '019A' '021A' '025A' '029A'
#  '034A' '038A' '042A' '051B' '056A' '058A' '060A' '064A' '065A' '067A'
#  '073A' '075A' '076A' '087A' '091A' '093A' '095A' '100A' '105A' '109A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '003A' '006A' '008A' '009A' '010A' '011A'
#  '013B' '014A' '014B' '015A' '016A' '019B' '020A' '022A' '023A' '023B'
#  '024A' '025B' '025C' '026A' '026B' '026C' '027A' '028A' '031A' '032A'
#  '033A' '035A' '036A' '037A' '039A' '040A' '041A' '043A' '044A' '045A'
#  '046A' '047A' '048A' '049A' '050A' '051A' '052A' '053A' '054A' '055A'
#  '057A' '059A' '061A' '062A' '063A' '066A' '068A' '069A' '070A' '071A'
#  '072A' '074A' '088A' '090A' '092A' '094A' '096A' '097A' '097B' '099A'
#  '101A' '102A' '103A' '104A' '106A' '108A' '110A' '111A' '113A' '115A'
#  '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['002B' '004A' '005A' '007A' '012A' '018A' '019A' '021A' '025A' '029A'
#  '034A' '038A' '042A' '051B' '056A' '058A' '060A' '064A' '065A' '067A'
#  '073A' '075A' '076A' '087A' '091A' '093A' '095A' '100A' '105A' '109A']
# Length of X_train_val:
# 747
# Length of y_train_val:
# 747
# Length of groups_train_val:
# 747
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     425
# senior    166
# kitten    156
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     174
# kitten     20
# senior     17
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     425
# senior    166
# kitten    156
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     174
# kitten     20
# senior     17
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 425, 2: 166, 1: 156})
# Epoch 1/1500
# 12/12 [==============================] - 1s 4ms/step - loss: 1.2119 - accuracy: 0.5636
# Epoch 2/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.6785 - accuracy: 0.7363
# Epoch 3/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4457 - accuracy: 0.8260
# Epoch 4/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3200 - accuracy: 0.8648
# Epoch 5/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3077 - accuracy: 0.8942
# Epoch 6/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2371 - accuracy: 0.9063
# Epoch 7/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1973 - accuracy: 0.9277
# Epoch 8/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1548 - accuracy: 0.9451
# Epoch 9/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1380 - accuracy: 0.9411
# Epoch 10/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1177 - accuracy: 0.9572
# Epoch 11/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0750 - accuracy: 0.9813
# Epoch 12/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0820 - accuracy: 0.9732
# Epoch 13/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0702 - accuracy: 0.9786
# Epoch 14/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0637 - accuracy: 0.9799
# Epoch 15/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0711 - accuracy: 0.9732
# Epoch 16/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0543 - accuracy: 0.9786
# Epoch 17/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0428 - accuracy: 0.9826
# Epoch 18/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0269 - accuracy: 0.9906
# Epoch 19/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0532 - accuracy: 0.9772
# Epoch 20/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0386 - accuracy: 0.9906
# Epoch 21/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0368 - accuracy: 0.9906
# Epoch 22/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0285 - accuracy: 0.9893
# Epoch 23/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0290 - accuracy: 0.9920
# Epoch 24/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0165 - accuracy: 0.9960
# Epoch 25/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0195 - accuracy: 0.9946
# Epoch 26/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0174 - accuracy: 0.9987
# Epoch 27/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0136 - accuracy: 0.9987
# Epoch 28/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0151 - accuracy: 0.9973
# Epoch 29/1500
# 12/12 [==============================] - 0s 10ms/step - loss: 0.0210 - accuracy: 0.9946
# Epoch 30/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0134 - accuracy: 0.9960
# Epoch 31/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0187 - accuracy: 0.9933
# Epoch 32/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0262 - accuracy: 0.9920
# Epoch 33/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0192 - accuracy: 0.9906
# Epoch 34/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0141 - accuracy: 0.9946
# Epoch 35/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0135 - accuracy: 0.9960
# Epoch 36/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0159 - accuracy: 0.9933
# Epoch 37/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0239 - accuracy: 0.9933
# Epoch 38/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0331 - accuracy: 0.9906
# Epoch 39/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0169 - accuracy: 0.9946
# Epoch 40/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0260 - accuracy: 0.9906
# Epoch 41/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0354 - accuracy: 0.9893
# Epoch 42/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0280 - accuracy: 0.9933
# Epoch 43/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0175 - accuracy: 0.9946
# Epoch 44/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0529 - accuracy: 0.9772
# Epoch 45/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0362 - accuracy: 0.9920
# Epoch 46/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0154 - accuracy: 0.9933
# Epoch 47/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0214 - accuracy: 0.9946
# Epoch 48/1500
# 12/12 [==============================] - 0s 17ms/step - loss: 0.0084 - accuracy: 0.9973
# Epoch 49/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0120 - accuracy: 0.9946
# Epoch 50/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0118 - accuracy: 0.9987
# Epoch 51/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0086 - accuracy: 0.9973
# Epoch 52/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0127 - accuracy: 0.9933
# Epoch 53/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0046 - accuracy: 1.0000
# Epoch 54/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0067 - accuracy: 0.9987
# Epoch 55/1500
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0120 - accuracy: 0.9973
# Epoch 56/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0188 - accuracy: 0.9946
# Epoch 57/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0141 - accuracy: 0.9946
# Epoch 58/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0230 - accuracy: 0.9933
# Epoch 59/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0280 - accuracy: 0.9839
# Epoch 60/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0111 - accuracy: 0.9946
# Epoch 61/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0080 - accuracy: 0.9987
# Epoch 62/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0114 - accuracy: 0.9960
# Epoch 63/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 64/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0076 - accuracy: 0.9973
# Epoch 65/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0163 - accuracy: 0.9906
# Epoch 66/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0071 - accuracy: 0.9987
# Epoch 67/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0096 - accuracy: 0.9973
# Epoch 68/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 69/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0067 - accuracy: 0.9973
# Epoch 70/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0100 - accuracy: 0.9960
# Epoch 71/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0078 - accuracy: 0.9973
# Epoch 72/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 73/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0038 - accuracy: 0.9987
# Epoch 74/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0045 - accuracy: 0.9987
# Epoch 75/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 76/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 77/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 78/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0121 - accuracy: 0.9960
# Epoch 79/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0112 - accuracy: 0.9960
# Epoch 80/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0042 - accuracy: 0.9973
# Epoch 81/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0035 - accuracy: 0.9987
# Epoch 82/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0123 - accuracy: 0.9960
# Epoch 83/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 84/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0082 - accuracy: 0.9946
# Epoch 85/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0075 - accuracy: 0.9987
# Epoch 86/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0188 - accuracy: 0.9960
# Epoch 87/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0205 - accuracy: 0.9946
# Epoch 88/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0133 - accuracy: 0.9946
# Epoch 89/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0251 - accuracy: 0.9906
# Epoch 90/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0188 - accuracy: 0.9906
# Epoch 91/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0212 - accuracy: 0.9906
# Epoch 92/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0106 - accuracy: 0.9960
# Epoch 93/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0181 - accuracy: 0.9946
# Epoch 94/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0171 - accuracy: 0.9960
# Epoch 95/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0091 - accuracy: 0.9960
# Epoch 96/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0108 - accuracy: 0.9973
# Epoch 97/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0095 - accuracy: 0.9973
# Epoch 98/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0136 - accuracy: 0.9960
# Epoch 99/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0065 - accuracy: 0.9973
# Epoch 100/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0064 - accuracy: 0.9960
# Epoch 101/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 102/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 103/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0039 - accuracy: 0.9987
# Epoch 104/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0092 - accuracy: 0.9973
# Epoch 105/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 106/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 107/1500
#  1/12 [=>............................] - ETA: 0s - loss: 2.0826e-04 - accuracy: 1.0000Restoring model weights from the end of the best epoch: 77.
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0047 - accuracy: 0.9987
# Epoch 107: early stopping
# 7/7 [==============================] - 0s 1ms/step - loss: 1.9413 - accuracy: 0.7014
# 7/7 [==============================] - 0s 1ms/step
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Majority Vote Accuracy for cat_id for this fold: 0.77 (23/30)
# Before appending - Cat IDs: 224, Predictions: 224, Actuals: 224, Gender: 224
# After appending - Cat IDs: 435, Predictions: 435, Actuals: 435, Gender: 435
# Final Test Results - Loss: 1.9413018226623535, Accuracy: 0.7014217972755432, Precision: 0.42785319255907495, Recall: 0.40447374352039667, F1 Score: 0.4145344855259176
# Confusion Matrix:
#  [[140  10  24]
#  [ 12   7   1]
#  [ 16   0   1]]
# outer_fold 3
# Train Set Group Distribution:
# 000A    39
# 002B    35
# 103A    33
# 047A    30
# 074A    25
# 000B    20
# 067A    20
# 055A    20
# 019A    17
# 029A    17
# 097A    16
# 059A    16
# 101A    15
# 001A    14
# 042A    14
# 097B    14
# 111A    13
# 051A    12
# 068A    11
# 025A    11
# 036A    11
# 005A    11
# 063A    11
# 040A    10
# 014B    10
# 051B     9
# 045A     9
# 065A     9
# 033A     9
# 010A     8
# 095A     8
# 099A     7
# 050A     7
# 031A     7
# 117A     7
# 109A     6
# 053A     6
# 108A     6
# 023A     6
# 007A     6
# 023B     5
# 075A     5
# 021A     5
# 034A     5
# 105A     4
# 026A     4
# 035A     4
# 012A     4
# 003A     4
# 014A     3
# 056A     3
# 058A     3
# 060A     3
# 064A     3
# 113A     3
# 066A     2
# 018A     2
# 069A     2
# 038A     2
# 025B     2
# 093A     2
# 054A     2
# 102A     2
# 011A     2
# 087A     2
# 026B     1
# 041A     1
# 115A     1
# 076A     1
# 004A     1
# 024A     1
# 043A     1
# 073A     1
# 088A     1
# 096A     1
# 091A     1
# 048A     1
# 110A     1
# 092A     1
# 090A     1
# 100A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 046A    66
# 057A    28
# 020A    23
# 106A    15
# 028A    14
# 002A    13
# 039A    12
# 116A    12
# 016A    11
# 071A    10
# 015A    10
# 072A     9
# 022A     9
# 094A     8
# 013B     8
# 027A     7
# 037A     6
# 008A     6
# 025C     5
# 070A     5
# 044A     5
# 062A     5
# 009A     4
# 104A     4
# 052A     4
# 006A     3
# 061A     2
# 032A     2
# 049A     1
# 026C     1
# 019B     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    259
# X    210
# F    180
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    145
# M     90
# F     74
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [033A, 000B, 000A, 026A, 065A, 053A, 023B, 038...
# kitten    [042A, 014B, 110A, 109A, 040A, 047A, 045A, 048...
# senior    [117A, 090A, 113A, 051B, 051A, 024A, 097A, 059...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [002A, 028A, 070A, 071A, 020A, 015A, 026C, 072...
# kitten                                   [046A, 049A, 044A]
# senior           [106A, 057A, 116A, 094A, 016A, 061A, 104A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 53, 'kitten': 13, 'senior': 15}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 21, 'kitten': 3, 'senior': 7}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002B' '003A' '004A' '005A' '007A' '010A' '011A'
#  '012A' '014A' '014B' '018A' '019A' '021A' '023A' '023B' '024A' '025A'
#  '025B' '026A' '026B' '029A' '031A' '033A' '034A' '035A' '036A' '038A'
#  '040A' '041A' '042A' '043A' '045A' '047A' '048A' '050A' '051A' '051B'
#  '053A' '054A' '055A' '056A' '058A' '059A' '060A' '063A' '064A' '065A'
#  '066A' '067A' '068A' '069A' '073A' '074A' '075A' '076A' '087A' '088A'
#  '090A' '091A' '092A' '093A' '095A' '096A' '097A' '097B' '099A' '100A'
#  '101A' '102A' '103A' '105A' '108A' '109A' '110A' '111A' '113A' '115A'
#  '117A']
# Unique Test Group IDs:
# ['002A' '006A' '008A' '009A' '013B' '015A' '016A' '019B' '020A' '022A'
#  '025C' '026C' '027A' '028A' '032A' '037A' '039A' '044A' '046A' '049A'
#  '052A' '057A' '061A' '062A' '070A' '071A' '072A' '094A' '104A' '106A'
#  '116A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'046A'}
# Removed from Training/Validation Set:
# {'109A'}
# Moved to Test Set:
# {'109A'}
# Removed from Test Set
# {'046A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002B' '003A' '004A' '005A' '007A' '010A' '011A'
#  '012A' '014A' '014B' '018A' '019A' '021A' '023A' '023B' '024A' '025A'
#  '025B' '026A' '026B' '029A' '031A' '033A' '034A' '035A' '036A' '038A'
#  '040A' '041A' '042A' '043A' '045A' '046A' '047A' '048A' '050A' '051A'
#  '051B' '053A' '054A' '055A' '056A' '058A' '059A' '060A' '063A' '064A'
#  '065A' '066A' '067A' '068A' '069A' '073A' '074A' '075A' '076A' '087A'
#  '088A' '090A' '091A' '092A' '093A' '095A' '096A' '097A' '097B' '099A'
#  '100A' '101A' '102A' '103A' '105A' '108A' '110A' '111A' '113A' '115A'
#  '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['002A' '006A' '008A' '009A' '013B' '015A' '016A' '019B' '020A' '022A'
#  '025C' '026C' '027A' '028A' '032A' '037A' '039A' '044A' '049A' '052A'
#  '057A' '061A' '062A' '070A' '071A' '072A' '094A' '104A' '106A' '109A'
#  '116A']
# Length of X_train_val:
# 709
# Length of y_train_val:
# 709
# Length of groups_train_val:
# 709
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     442
# kitten    104
# senior    103
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     157
# senior     80
# kitten     72
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     442
# kitten    164
# senior    103
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     157
# senior     80
# kitten     12
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 442, 1: 164, 2: 103})
# Epoch 1/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 1.4863 - accuracy: 0.5049
# Epoch 2/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.7924 - accuracy: 0.6939
# Epoch 3/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4943 - accuracy: 0.8054
# Epoch 4/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3840 - accuracy: 0.8590
# Epoch 5/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2983 - accuracy: 0.8942
# Epoch 6/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2942 - accuracy: 0.8970
# Epoch 7/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2567 - accuracy: 0.9182
# Epoch 8/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2178 - accuracy: 0.9140
# Epoch 9/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2335 - accuracy: 0.9224
# Epoch 10/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1852 - accuracy: 0.9351
# Epoch 11/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1897 - accuracy: 0.9267
# Epoch 12/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1386 - accuracy: 0.9563
# Epoch 13/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1533 - accuracy: 0.9464
# Epoch 14/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1570 - accuracy: 0.9422
# Epoch 15/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1603 - accuracy: 0.9351
# Epoch 16/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1339 - accuracy: 0.9450
# Epoch 17/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1037 - accuracy: 0.9647
# Epoch 18/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1011 - accuracy: 0.9647
# Epoch 19/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0963 - accuracy: 0.9774
# Epoch 20/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0804 - accuracy: 0.9760
# Epoch 21/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0999 - accuracy: 0.9732
# Epoch 22/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1020 - accuracy: 0.9563
# Epoch 23/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1195 - accuracy: 0.9661
# Epoch 24/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0854 - accuracy: 0.9732
# Epoch 25/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0935 - accuracy: 0.9690
# Epoch 26/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0783 - accuracy: 0.9774
# Epoch 27/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0645 - accuracy: 0.9817
# Epoch 28/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0605 - accuracy: 0.9831
# Epoch 29/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0685 - accuracy: 0.9817
# Epoch 30/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0732 - accuracy: 0.9760
# Epoch 31/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0923 - accuracy: 0.9718
# Epoch 32/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0636 - accuracy: 0.9788
# Epoch 33/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0718 - accuracy: 0.9817
# Epoch 34/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0651 - accuracy: 0.9859
# Epoch 35/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0744 - accuracy: 0.9718
# Epoch 36/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0728 - accuracy: 0.9803
# Epoch 37/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0510 - accuracy: 0.9859
# Epoch 38/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0483 - accuracy: 0.9845
# Epoch 39/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0550 - accuracy: 0.9803
# Epoch 40/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0652 - accuracy: 0.9746
# Epoch 41/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0426 - accuracy: 0.9901
# Epoch 42/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0496 - accuracy: 0.9845
# Epoch 43/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0516 - accuracy: 0.9803
# Epoch 44/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0468 - accuracy: 0.9859
# Epoch 45/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0412 - accuracy: 0.9887
# Epoch 46/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0558 - accuracy: 0.9831
# Epoch 47/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0379 - accuracy: 0.9873
# Epoch 48/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0542 - accuracy: 0.9803
# Epoch 49/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0323 - accuracy: 0.9915
# Epoch 50/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0375 - accuracy: 0.9887
# Epoch 51/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0174 - accuracy: 1.0000
# Epoch 52/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0375 - accuracy: 0.9859
# Epoch 53/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0363 - accuracy: 0.9915
# Epoch 54/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0310 - accuracy: 0.9901
# Epoch 55/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0641 - accuracy: 0.9760
# Epoch 56/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0274 - accuracy: 0.9929
# Epoch 57/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0464 - accuracy: 0.9859
# Epoch 58/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0238 - accuracy: 0.9915
# Epoch 59/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0478 - accuracy: 0.9859
# Epoch 60/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0343 - accuracy: 0.9901
# Epoch 61/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0335 - accuracy: 0.9873
# Epoch 62/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0370 - accuracy: 0.9873
# Epoch 63/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0189 - accuracy: 0.9958
# Epoch 64/1500
# 12/12 [==============================] - 0s 20ms/step - loss: 0.0318 - accuracy: 0.9887
# Epoch 65/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0313 - accuracy: 0.9929
# Epoch 66/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0250 - accuracy: 0.9915
# Epoch 67/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0190 - accuracy: 0.9944
# Epoch 68/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0377 - accuracy: 0.9845
# Epoch 69/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0404 - accuracy: 0.9901
# Epoch 70/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0636 - accuracy: 0.9774
# Epoch 71/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0343 - accuracy: 0.9873
# Epoch 72/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0261 - accuracy: 0.9901
# Epoch 73/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0304 - accuracy: 0.9901
# Epoch 74/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0373 - accuracy: 0.9859
# Epoch 75/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0319 - accuracy: 0.9901
# Epoch 76/1500
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0419 - accuracy: 0.9873
# Epoch 77/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0297 - accuracy: 0.9901
# Epoch 78/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0612 - accuracy: 0.9803
# Epoch 79/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0484 - accuracy: 0.9845
# Epoch 80/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0312 - accuracy: 0.9873
# Epoch 81/1500
#  6/12 [==============>...............] - ETA: 0s - loss: 0.0226 - accuracy: 0.9948Restoring model weights from the end of the best epoch: 51.
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0202 - accuracy: 0.9944
# Epoch 81: early stopping
# 8/8 [==============================] - 0s 1ms/step - loss: 2.7180 - accuracy: 0.5783
# 8/8 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.71 (22/31)
# Before appending - Cat IDs: 435, Predictions: 435, Actuals: 435, Gender: 435
# After appending - Cat IDs: 684, Predictions: 684, Actuals: 684, Gender: 684
# Final Test Results - Loss: 2.7180280685424805, Accuracy: 0.5783132314682007, Precision: 0.4550480926519662, Recall: 0.44309094125973103, F1 Score: 0.40101360505453537
# Confusion Matrix:
#  [[123  22  12]
#  [  8   4   0]
#  [ 55   8  17]]
# outer_fold 4
# Train Set Group Distribution:
# 046A    66
# 002B    35
# 103A    33
# 047A    30
# 057A    28
# 020A    23
# 067A    20
# 055A    20
# 029A    17
# 019A    17
# 059A    16
# 097A    16
# 106A    15
# 101A    15
# 042A    14
# 028A    14
# 111A    13
# 002A    13
# 039A    12
# 116A    12
# 063A    11
# 016A    11
# 068A    11
# 025A    11
# 005A    11
# 015A    10
# 014B    10
# 071A    10
# 065A     9
# 022A     9
# 045A     9
# 051B     9
# 072A     9
# 013B     8
# 094A     8
# 095A     8
# 027A     7
# 050A     7
# 031A     7
# 099A     7
# 008A     6
# 037A     6
# 109A     6
# 007A     6
# 023B     5
# 021A     5
# 034A     5
# 044A     5
# 070A     5
# 025C     5
# 062A     5
# 075A     5
# 105A     4
# 009A     4
# 104A     4
# 052A     4
# 012A     4
# 014A     3
# 006A     3
# 056A     3
# 064A     3
# 060A     3
# 058A     3
# 025B     2
# 018A     2
# 093A     2
# 087A     2
# 066A     2
# 038A     2
# 061A     2
# 032A     2
# 102A     2
# 024A     1
# 026B     1
# 004A     1
# 076A     1
# 026C     1
# 041A     1
# 092A     1
# 049A     1
# 110A     1
# 019B     1
# 091A     1
# 073A     1
# 100A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 000A    39
# 074A    25
# 000B    20
# 097B    14
# 001A    14
# 051A    12
# 036A    11
# 040A    10
# 033A     9
# 010A     8
# 117A     7
# 108A     6
# 053A     6
# 023A     6
# 003A     4
# 035A     4
# 026A     4
# 113A     3
# 011A     2
# 069A     2
# 054A     2
# 048A     1
# 043A     1
# 096A     1
# 088A     1
# 090A     1
# 115A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    308
# M    282
# F    154
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# F    100
# M     67
# X     47
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [002A, 028A, 070A, 071A, 020A, 015A, 065A, 023...
# kitten    [046A, 042A, 014B, 110A, 109A, 047A, 049A, 045...
# senior    [106A, 057A, 051B, 116A, 024A, 097A, 094A, 059...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [033A, 000B, 000A, 026A, 053A, 001A, 010A, 074...
# kitten                             [040A, 048A, 043A, 115A]
# senior           [117A, 090A, 113A, 051A, 054A, 108A, 011A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 58, 'kitten': 12, 'senior': 15}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 16, 'kitten': 4, 'senior': 7}
# Unique Training/Validation Group IDs:
# ['002A' '002B' '004A' '005A' '006A' '007A' '008A' '009A' '012A' '013B'
#  '014A' '014B' '015A' '016A' '018A' '019A' '019B' '020A' '021A' '022A'
#  '023B' '024A' '025A' '025B' '025C' '026B' '026C' '027A' '028A' '029A'
#  '031A' '032A' '034A' '037A' '038A' '039A' '041A' '042A' '044A' '045A'
#  '046A' '047A' '049A' '050A' '051B' '052A' '055A' '056A' '057A' '058A'
#  '059A' '060A' '061A' '062A' '063A' '064A' '065A' '066A' '067A' '068A'
#  '070A' '071A' '072A' '073A' '075A' '076A' '087A' '091A' '092A' '093A'
#  '094A' '095A' '097A' '099A' '100A' '101A' '102A' '103A' '104A' '105A'
#  '106A' '109A' '110A' '111A' '116A']
# Unique Test Group IDs:
# ...
# Epoch 15/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0941 - accuracy: 0.9718
# Epoch 16/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.1167 - accuracy: 0.9526
# Epoch 17/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0959 - accuracy: 0.9641
# Epoch 18/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.1055 - accuracy: 0.9603
# Epoch 19/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0660 - accuracy: 0.9808
# Epoch 20/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0832 - accuracy: 0.9692
# Epoch 21/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0606 - accuracy: 0.9744
# Epoch 22/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0460 - accuracy: 0.9872
# Epoch 23/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0667 - accuracy: 0.9692
# Epoch 24/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0489 - accuracy: 0.9821
# Epoch 25/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0544 - accuracy: 0.9833
# Epoch 26/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0556 - accuracy: 0.9795
# Epoch 27/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0486 - accuracy: 0.9821
# Epoch 28/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0631 - accuracy: 0.9821
# Epoch 29/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0618 - accuracy: 0.9718
# Epoch 30/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0453 - accuracy: 0.9833
# Epoch 31/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0406 - accuracy: 0.9885
# Epoch 32/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0507 - accuracy: 0.9833
# Epoch 33/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.
   actual_age_group  total_count  correct_count   accuracy
# 0            adult          563            431  76.554174
# 1           kitten          116             45  38.793103
# 2           senior          183             49  26.775956]
# Total Gender Accuracy so far:
#  [  all_gender  count  correct  accuracy
# 0          F    215      130     60.47
# 1          M    353      248     70.25
# 2          X    290      146     50.34,   all_gender  count  correct  accuracy
# 0          F    218      131     60.09
# 1          M    349      243     69.63
# 2          X    295      151     51.19]

# %% [markdown]
# # RANDOM SEED 3

# %%
# Set a fixed random seed for reproducibility
random.seed(int(random_seeds[2]))
np.random.seed(int(random_seeds[2]))
tf.random.set_seed(int(random_seeds[2]))

# Load datasets
dataframe = pd.read_csv('/Users/astrid/PycharmProjects/data-aug-and-more/yamnet-tfhub-extraction/yamnet_embeddings_not_looped_april_23.csv')

def assign_age_group(age, age_groups):
    for group_name, age_range in age_groups.items():
        if age_range[0] <= age < age_range[1]:
            return group_name
    return 'Unknown'  # For any age that doesn't fit the defined groups

# Define age groups
age_groups = {
    'kitten': (0, 0.5),
    'adult': (0.5, 12),
    'senior': (12, 20)
}

# Create a new column for the age group
dataframe['age_group'] = dataframe['target'].apply(assign_age_group, age_groups=age_groups)

print(dataframe['age_group'].value_counts())
# Out:
# adult     599
# senior    183
# kitten    176
# Name: age_group, dtype: int64

# %%
# Separate features and labels
X = dataframe.iloc[:, :-4].values  # all columns except the last four

# Encode the 'age_group' column as integers using LabelEncoder
label_encoder = LabelEncoder()
encoded_y = label_encoder.fit_transform(dataframe['age_group'].values)

# Use the encoded labels for splitting and one-hot encoding
y = encoded_y  

# Convert 'cat_id' column to numpy array to be used as groups array for GroupKFold
groups = dataframe['cat_id'].values

# %%
tf.keras.backend.clear_session()

# %% [markdown]
# ## Run Setup

# %%
all_cat_ids = []
all_predicted_age_groups = []
all_actual_age_groups = []
all_gender = []

# Define the StratifiedGroupKFold splitter for 4 fold CV with random shuffling
outer_cv = StratifiedGroupKFold(n_splits=4, shuffle=True, random_state=int(random_seeds[2]))

# unseen test set metrics
unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1 = [], [], [], [], []

outer_fold = 0

# Use the splitter to generate indices for training and testing sets
# Note: GroupShuffleSplit.split returns indices, so we use it to index the arrays
for train_val_idx, test_idx in outer_cv.split(X, y, groups):
    outer_fold += 1
    logger(f"outer_fold {outer_fold}", file=log_file_path)

    # Convert indices back to DataFrame for easy manipulation
    df_train_val = dataframe.iloc[train_val_idx]
    df_test = dataframe.iloc[test_idx]

    ##############################
    # ASSESSING SPLITS BY CAT_ID #
    ##############################
    
    # Get the distribution of groups
    training_validation_group_distribution = df_train_val['cat_id'].value_counts()  
    testing_group_distribution = df_test['cat_id'].value_counts()  
    
    # Log or print the distribution
    logger(f"Train Set Group Distribution:\n{training_validation_group_distribution}", file=log_file_path)
    logger(f"Testing Set Group Distribution:\n{testing_group_distribution}", file=log_file_path)

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val['gender'].value_counts()
    testing_gender_distribution = df_test['gender'].value_counts()
    
    # Log the distribution
    logger(f"Training Set Gender Distribution BEFORE SWAP:\n{training_gender_distribution}", file=log_file_path)
    logger(f"Testing Set Gender Distribution BEFORE SWAP:\n{testing_gender_distribution}", file=log_file_path)

    # Group by 'age_group' and then list unique 'cat_id' within each age group
    unique_cat_ids_per_age_group_train_val = df_train_val.groupby('age_group')['cat_id'].unique()
    unique_cat_ids_per_age_group_test = df_test.groupby('age_group')['cat_id'].unique()
    
    # Log results
    logger(f"Unique Cat IDs per Age Group in Training/Validation Set:\n{unique_cat_ids_per_age_group_train_val}", file=log_file_path)
    logger(f"Unique Cat IDs per Age Group in Testing Set:\n{unique_cat_ids_per_age_group_test}", file=log_file_path)

    # Calculate the count of unique identifiers per age group for training and testing set
    counts_train_val = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_train_val.items()}
    counts_test = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_test.items()}

    # Log the counts of unique identifiers per age group
    logger(f"Count of Unique Cat IDs per Age Group in Training/Validation Set:\n{counts_train_val}", file=log_file_path)
    logger(f"Count of Unique Cat IDs per Age Group in Testing Set:\n{counts_test}", file=log_file_path)

    #######################################################
    # CONTINUE WITH ENSURING VALID AND APPROPRIATE SPLITS #
    #######################################################
    
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    groups_train_val, groups_test = groups[train_val_idx], groups[test_idx]

    # logging identifier splits 
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)

    # check group splits
    check_initial_group_split(groups_train_val, groups_test)

    # Specify the cat_ids that must be in the training/validation set
    specific_cat_ids = ['000A', '046A']
    
    # Perform the swapping operation
    train_val_idx, test_idx = swap_cat_id_instances(dataframe, train_val_idx, test_idx, specific_cat_ids)
    
    # Re-assign the sets based on the updated indices
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    new_groups_train_val, new_groups_test = groups[train_val_idx], groups[test_idx]

    # Find differences for training and test sets
    moved_to_train_val, removed_from_train_val = find_group_differences(groups_train_val, new_groups_train_val)
    moved_to_test, removed_from_test = find_group_differences(groups_test, new_groups_test)
    
    # Display the results
    logger(f"Moved to Training/Validation Set:\n{moved_to_train_val}", file=log_file_path)
    logger(f"Removed from Training/Validation Set:\n{removed_from_train_val}", file=log_file_path)
    logger(f"Moved to Test Set:\n{moved_to_test}", file=log_file_path)
    logger(f"Removed from Test Set\n{removed_from_test}", file=log_file_path)

    # Update X_train_val, X_test, y_train_val, y_test, groups_train_val, groups_test based on updated indices
    X_train_val = X[train_val_idx]
    y_train_val = y[train_val_idx]
    groups_train_val = groups[train_val_idx]
    
    X_test = X[test_idx]
    y_test = y[test_idx]
    groups_test = groups[test_idx]

    # logging identifier splits again after potential swaps
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"AFTER SWAP - Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"AFTER SWAP - Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)
    
    # Verify the lengths are consistent
    logger(f"Length of X_train_val:\n{len(X_train_val)}", file=log_file_path)
    logger(f"Length of y_train_val:\n{len(y_train_val)}", file=log_file_path)
    logger(f"Length of groups_train_val:\n{len(groups_train_val)}", file=log_file_path)

    # Check group splits once more
    check_initial_group_split(groups_train_val, groups_test)

    # Convert the modified indices back to a DataFrame representing the updated df_train_val
    df_train_val_updated = dataframe.iloc[train_val_idx].copy()
    df_test_updated = dataframe.iloc[test_idx].copy()

    ############################
    # LOGGING AGE GROUP SPLITS #
    ############################

    # Get the distribution of age groups of age groups before the update
    training_validation_age_group_distribution = df_train_val['age_group'].value_counts()
    testing_age_group_distribution = df_test['age_group'].value_counts()
    
    # Logthe distribution
    logger(f"Train Age Group Distribution BEFORE SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution BEFORE SWAP:\n{testing_age_group_distribution}", file=log_file_path)

    # Get the distribution of age groups after the update
    training_validation_age_group_distribution = df_train_val_updated['age_group'].value_counts()
    testing_age_group_distribution = df_test_updated['age_group'].value_counts()
    
    # Log the distribution
    logger(f"Train Age Group Distribution AFTER SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution AFTER SWAP:\n{testing_age_group_distribution}", file=log_file_path)
    
    ########################################################
    # TRACKING FINAL CAT_IDs & GENDER AFTER REDISTRIBUTION #
    ########################################################

    # Get the distribution of groups
    training_validation_group_distribution = df_train_val_updated['cat_id'].value_counts()  
    testing_group_distribution = df_test_updated['cat_id'].value_counts()  

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val_updated['gender'].value_counts()
    testing_gender_distribution = df_test_updated['gender'].value_counts()
    
    logger(f"\n Starting training on unseen test set\n", file=log_file_path)

    ###################
    # PREPARING MODEL #
    ###################

    # Calculate the distribution of age groups in y_train_val
    age_group_distribution = Counter(y_train_val)
    print("Age group distribution:", age_group_distribution)

    # EarlyStopping callback: monitor 'loss' instead of 'val_loss' for the test set
    early_stopping = EarlyStopping(
        monitor='loss',  
        min_delta=0.001, 
        patience=30,  
        verbose=1,  
        restore_best_weights=True  
    )

    # One final shuffle to ensure randomness
    outer_shuffle_idx = np.random.permutation(len(X_train_val))
    X_train_val = X_train_val[outer_shuffle_idx]
    y_train_val = y_train_val[outer_shuffle_idx]
    
    # Scale the features
    scaler_full = StandardScaler().fit(X_train_val)
    X_train_full_scaled = scaler_full.transform(X_train_val)
    X_test_scaled = scaler_full.transform(X_test)
    
    # Encode the labels
    y_train_full_encoded = to_categorical(y_train_val)
    y_test_encoded = to_categorical(y_test)

    #######################
    # BUILD & TRAIN MODEL #
    #######################

    optimizers = {
        'Adamax': Adamax(learning_rate=0.00510251984616472)
    }
    
    # Model definition with dynamic number of layers
    model_full = Sequential()
    model_full.add(Dense(480, activation='relu', input_shape=(X_train_full_scaled.shape[1],)))
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.2011047009431978))  
    model_full.add(Dense(256, activation='relu',)) 
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.14956886311951184))  
    model_full.add(Dense(256, activation='relu'))  
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.42291461228250665))  
    model_full.add(Dense(3, activation='softmax'))  
    
    # Use the optimizer from the parameters
    optimizer = optimizers['Adamax']  # optimizer_key from parameters
    
    # Compile the model
    model_full.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    
    # Train the model on the full training set
    history_full = model_full.fit(X_train_full_scaled, y_train_full_encoded, epochs=1500, batch_size=64,
                                  verbose=1, callbacks=[early_stopping])
    
    # Evaluate the model on the held-out test set
    test_loss, test_accuracy = model_full.evaluate(X_test_scaled, y_test_encoded)

    y_test_pred_prob = model_full.predict(X_test_scaled)
    y_test_pred = np.argmax(y_test_pred_prob, axis=1)  
    y_test_true = np.argmax(y_test_encoded, axis=1)    

    ################################
    # LOG MAJORITY VOTE PER CAT_ID #
    ################################

    # Convert numeric predictions back to age group labels
    predicted_age_groups = label_encoder.inverse_transform(y_test_pred)
    actual_labels = label_encoder.inverse_transform(y_test_true)
    
    # Map predictions and actual labels back to cat_ids
    test_results = pd.DataFrame({
        'cat_id': df_test_updated['cat_id'],
        'predicted_age_group': predicted_age_groups,
        'actual_age_group': actual_labels
    })
    
    # Group by cat_id and aggregate predicted age groups
    majority_votes = test_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
    actual_groups = test_results.groupby('cat_id')['actual_age_group'].first()
    
    # Calculate the accuracy of majority voting
    correct_predictions = (majority_votes == actual_groups).sum()
    total_cats = len(actual_groups)
    majority_vote_accuracy = correct_predictions / total_cats
    
    # Log the accuracy of the majority voting
    logger(f"Majority Vote Accuracy for cat_id for this fold: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

    ####################################################
    # COLLECT PREDICTIONS FOR GENDER & CAT_ID ANALYSIS #
    ####################################################

    # Debugging print statements
    print(f'Before appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Extend lists with current fold results
    all_cat_ids.extend(df_test_updated['cat_id'].tolist())
    all_predicted_age_groups.extend(predicted_age_groups)
    all_actual_age_groups.extend(actual_labels)
    all_gender.extend(df_test_updated['gender'].tolist())

    # Debugging print statements
    print(f'After appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Calculate additional metrics
    test_precision = precision_score(y_test_true, y_test_pred, average='macro')  # Use 'macro' for imbalanced datasets
    test_recall = recall_score(y_test_true, y_test_pred, average='macro')
    test_f1 = f1_score(y_test_true, y_test_pred, average='macro')

    # prepare averages of outer metrics
    unseen_f1.append(test_f1)
    unseen_losses.append(test_loss)
    unseen_accuracies.append(test_accuracy)
    unseen_precisions.append(test_precision)
    unseen_recalls.append(test_recall)

    # Print final test results
    logger(f"Final Test Results - Loss: {test_loss}, Accuracy: {test_accuracy}, Precision: {test_precision}, Recall: {test_recall}, F1 Score: {test_f1}", file=log_file_path)

    # Generate the confusion matrix
    cm = confusion_matrix(y_test, y_test_pred)
    logger(f"Confusion Matrix:\n {cm}", file=log_file_path)

# Calculate the overall average metrics
unseen_set_avg_f1 = np.mean(unseen_f1)
unseen_set_avg_loss = np.mean(unseen_losses)
unseen_set_avg_acc = np.mean(unseen_accuracies)
unseen_set_avg_precision = np.mean(unseen_precisions)
unseen_set_avg_recall = np.mean(unseen_recalls)

logger(f"\nFinal Average F1-Score across all UNSEEN TEST sets: {unseen_set_avg_f1}", file=log_file_path)
logger(f"\nFinal Average Loss across all UNSEEN TEST sets: {unseen_set_avg_loss}", file=log_file_path)
logger(f"\nFinal Average Accuracy across all UNSEEN TEST sets: {unseen_set_avg_acc}", file=log_file_path)
logger(f"\nFinal Average Precision across all UNSEEN TEST sets: {unseen_set_avg_precision}", file=log_file_path)
logger(f"\nFinal Average Recall across all UNSEEN TEST sets: {unseen_set_avg_recall}\n", file=log_file_path)

# Append averages to total lists
all_f1.append(unseen_set_avg_f1)
all_losses.append(unseen_set_avg_loss)
all_accuracies.append(unseen_set_avg_acc)
all_precisions.append(unseen_set_avg_precision)
all_recalls.append(unseen_set_avg_recall)
# Out:
# outer_fold 1
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Train Set Group Distribution:
# 046A    66
# 000A    39
# 002B    35
# 103A    33
# 057A    28
# 000B    20
# 067A    20
# 019A    17
# 059A    16
# 106A    15
# 028A    14
# 042A    14
# 001A    14
# 111A    13
# 002A    13
# 051A    12
# 039A    12
# 116A    12
# 063A    11
# 025A    11
# 016A    11
# 014B    10
# 040A    10
# 015A    10
# 071A    10
# 072A     9
# 051B     9
# 065A     9
# 022A     9
# 045A     9
# 033A     9
# 010A     8
# 094A     8
# 013B     8
# 095A     8
# 027A     7
# 050A     7
# 099A     7
# 031A     7
# 037A     6
# 008A     6
# 007A     6
# 108A     6
# 109A     6
# 075A     5
# 025C     5
# 070A     5
# 023B     5
# 021A     5
# 062A     5
# 034A     5
# 052A     4
# 105A     4
# 035A     4
# 104A     4
# 003A     4
# 014A     3
# 006A     3
# 113A     3
# 060A     3
# 064A     3
# 056A     3
# 058A     3
# 025B     2
# 093A     2
# 018A     2
# 069A     2
# 061A     2
# 087A     2
# 032A     2
# 066A     2
# 011A     2
# 038A     2
# 041A     1
# 115A     1
# 076A     1
# 024A     1
# 073A     1
# 088A     1
# 091A     1
# 096A     1
# 043A     1
# 110A     1
# 048A     1
# 090A     1
# 092A     1
# 049A     1
# 026B     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 047A    30
# 074A    25
# 020A    23
# 055A    20
# 029A    17
# 097A    16
# 101A    15
# 097B    14
# 068A    11
# 005A    11
# 036A    11
# 117A     7
# 023A     6
# 053A     6
# 044A     5
# 026A     4
# 009A     4
# 012A     4
# 102A     2
# 054A     2
# 026C     1
# 019B     1
# 004A     1
# 100A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    265
# M    260
# F    196
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    90
# M    89
# F    58
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [002A, 028A, 070A, 033A, 000B, 071A, 000A, 015...
# kitten    [046A, 042A, 014B, 110A, 109A, 040A, 049A, 045...
# senior    [106A, 057A, 090A, 113A, 051B, 116A, 051A, 024...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [020A, 026A, 053A, 026C, 068A, 005A, 009A, 101...
# kitten                                         [047A, 044A]
# senior                             [117A, 097A, 055A, 054A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 56, 'kitten': 14, 'senior': 18}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 18, 'kitten': 2, 'senior': 4}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '006A' '007A' '008A' '010A'
#  '011A' '013B' '014A' '014B' '015A' '016A' '018A' '019A' '021A' '022A'
#  '023B' '024A' '025A' '025B' '025C' '026B' '027A' '028A' '031A' '032A'
#  '033A' '034A' '035A' '037A' '038A' '039A' '040A' '041A' '042A' '043A'
#  '045A' '046A' '048A' '049A' '050A' '051A' '051B' '052A' '056A' '057A'
#  '058A' '059A' '060A' '061A' '062A' '063A' '064A' '065A' '066A' '067A'
#  '069A' '070A' '071A' '072A' '073A' '075A' '076A' '087A' '088A' '090A'
#  '091A' '092A' '093A' '094A' '095A' '096A' '099A' '103A' '104A' '105A'
#  '106A' '108A' '109A' '110A' '111A' '113A' '115A' '116A']
# Unique Test Group IDs:
# ['004A' '005A' '009A' '012A' '019B' '020A' '023A' '026A' '026C' '029A'
#  '036A' '044A' '047A' '053A' '054A' '055A' '068A' '074A' '097A' '097B'
#  '100A' '101A' '102A' '117A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '006A' '007A' '008A' '010A'
#  '011A' '013B' '014A' '014B' '015A' '016A' '018A' '019A' '021A' '022A'
#  '023B' '024A' '025A' '025B' '025C' '026B' '027A' '028A' '031A' '032A'
#  '033A' '034A' '035A' '037A' '038A' '039A' '040A' '041A' '042A' '043A'
#  '045A' '046A' '048A' '049A' '050A' '051A' '051B' '052A' '056A' '057A'
#  '058A' '059A' '060A' '061A' '062A' '063A' '064A' '065A' '066A' '067A'
#  '069A' '070A' '071A' '072A' '073A' '075A' '076A' '087A' '088A' '090A'
#  '091A' '092A' '093A' '094A' '095A' '096A' '099A' '103A' '104A' '105A'
#  '106A' '108A' '109A' '110A' '111A' '113A' '115A' '116A']
# AFTER SWAP - Unique Test Group IDs:
# ['004A' '005A' '009A' '012A' '019B' '020A' '023A' '026A' '026C' '029A'
#  '036A' '044A' '047A' '053A' '054A' '055A' '068A' '074A' '097A' '097B'
#  '100A' '101A' '102A' '117A']
# Length of X_train_val:
# 721
# Length of y_train_val:
# 721
# Length of groups_train_val:
# 721
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     442
# kitten    141
# senior    138
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     157
# senior     45
# kitten     35
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     442
# kitten    141
# senior    138
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     157
# senior     45
# kitten     35
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 442, 1: 141, 2: 138})
# Epoch 1/1500
# 12/12 [==============================] - 1s 4ms/step - loss: 1.3834 - accuracy: 0.5187
# Epoch 2/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.6773 - accuracy: 0.7462
# Epoch 3/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4809 - accuracy: 0.8239
# Epoch 4/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3244 - accuracy: 0.8835
# Epoch 5/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3122 - accuracy: 0.8918
# Epoch 6/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2446 - accuracy: 0.9168
# Epoch 7/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2048 - accuracy: 0.9362
# Epoch 8/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1649 - accuracy: 0.9417
# Epoch 9/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1552 - accuracy: 0.9528
# Epoch 10/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1269 - accuracy: 0.9528
# Epoch 11/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1297 - accuracy: 0.9570
# Epoch 12/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1018 - accuracy: 0.9570
# Epoch 13/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0746 - accuracy: 0.9820
# Epoch 14/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0749 - accuracy: 0.9764
# Epoch 15/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0545 - accuracy: 0.9792
# Epoch 16/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0621 - accuracy: 0.9792
# Epoch 17/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0764 - accuracy: 0.9764
# Epoch 18/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0541 - accuracy: 0.9861
# Epoch 19/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0408 - accuracy: 0.9875
# Epoch 20/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0372 - accuracy: 0.9861
# Epoch 21/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0299 - accuracy: 0.9931
# Epoch 22/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0308 - accuracy: 0.9931
# Epoch 23/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0213 - accuracy: 0.9945
# Epoch 24/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0428 - accuracy: 0.9903
# Epoch 25/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0326 - accuracy: 0.9931
# Epoch 26/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0205 - accuracy: 0.9958
# Epoch 27/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0235 - accuracy: 0.9903
# Epoch 28/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.
1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0151 - accuracy: 0.9958
# Epoch 99/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0066 - accuracy: 0.9972
# Epoch 100/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0074 - accuracy: 0.9986
# Epoch 101/1500
# 12/12 [==============================] - 0s 16ms/step - loss: 0.0231 - accuracy: 0.9903
# Epoch 102/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0083 - accuracy: 0.9958
# Epoch 103/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 104/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0033 - accuracy: 0.9986
# Epoch 105/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0062 - accuracy: 0.9986
# Epoch 106/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 107/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0041 - accuracy: 0.9986
# Epoch 108/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0052 - accuracy: 0.9972
# Epoch 109/1500
# 12/12 [==============================] - ETA: 0s - loss: 0.0089 - accuracy: 0.9972    Restoring model weights from the end of the best epoch: 79.
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0089 - accuracy: 0.9972
# Epoch 109: early stopping
# 8/8 [==============================] - 0s 1ms/step - loss: 7.8437 - accuracy: 0.5612
# 8/8 [==============================] - 0s 978us/step
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Majority Vote Accuracy for cat_id for this fold: 0.71 (17/24)
# Before appending - Cat IDs: 0, Predictions: 0, Actuals: 0, Gender: 0
# After appending - Cat IDs: 237, Predictions: 237, Actuals: 237, Gender: 237
# Final Test Results - Loss: 7.843689918518066, Accuracy: 0.5611814260482788, Precision: 0.41213437996448926, Recall: 0.377508172412631, F1 Score: 0.3808547318755104
# Confusion Matrix:
#  [[117   9  31]
#  [ 14   5  16]
#  [ 33   1  11]]
# outer_fold 2
# Train Set Group Distribution:
# 046A    66
# 000A    39
# 103A    33
# 047A    30
# 074A    25
# 020A    23
# 055A    20
# 000B    20
# 067A    20
# 029A    17
# 097A    16
# 059A    16
# 101A    15
# 028A    14
# 097B    14
# 002A    13
# 111A    13
# 039A    12
# 051A    12
# 116A    12
# 005A    11
# 036A    11
# 016A    11
# 068A    11
# 071A    10
# 014B    10
# 022A     9
# 045A     9
# 072A     9
# 051B     9
# 033A     9
# 094A     8
# 117A     7
# 031A     7
# 050A     7
# 099A     7
# 023A     6
# 053A     6
# 108A     6
# 008A     6
# 109A     6
# 007A     6
# 037A     6
# 044A     5
# 025C     5
# 021A     5
# 012A     4
# 003A     4
# 104A     4
# 026A     4
# 009A     4
# 035A     4
# 105A     4
# 060A     3
# 058A     3
# 014A     3
# 056A     3
# 064A     3
# 061A     2
# 093A     2
# 066A     2
# 087A     2
# 032A     2
# 038A     2
# 069A     2
# 102A     2
# 054A     2
# 018A     2
# 076A     1
# 019B     1
# 004A     1
# 115A     1
# 026B     1
# 110A     1
# 091A     1
# 024A     1
# 090A     1
# 048A     1
# 026C     1
# 043A     1
# 049A     1
# 100A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 002B    35
# 057A    28
# 019A    17
# 106A    15
# 042A    14
# 001A    14
# 025A    11
# 063A    11
# 040A    10
# 015A    10
# 065A     9
# 010A     8
# 095A     8
# 013B     8
# 027A     7
# 075A     5
# 070A     5
# 062A     5
# 034A     5
# 023B     5
# 052A     4
# 006A     3
# 113A     3
# 011A     2
# 025B     2
# 092A     1
# 096A     1
# 088A     1
# 073A     1
# 041A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    262
# M    237
# F    210
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# M    112
# X     93
# F     44
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [002A, 028A, 033A, 000B, 071A, 020A, 000A, 026...
# kitten    [046A, 014B, 110A, 109A, 047A, 049A, 045A, 048...
# senior    [117A, 090A, 051B, 116A, 051A, 024A, 097A, 094...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [070A, 015A, 065A, 023B, 001A, 034A, 013B, 062...
# kitten                                   [042A, 040A, 041A]
# senior                             [106A, 057A, 113A, 011A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 51, 'kitten': 13, 'senior': 18}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 23, 'kitten': 3, 'senior': 4}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '002A' '003A' '004A' '005A' '007A' '008A' '009A' '012A'
#  '014A' '014B' '016A' '018A' '019B' '020A' '021A' '022A' '023A' '024A'
#  '025C' '026A' '026B' '026C' '028A' '029A' '031A' '032A' '033A' '035A'
#  '036A' '037A' '038A' '039A' '043A' '044A' '045A' '046A' '047A' '048A'
#  '049A' '050A' '051A' '051B' '053A' '054A' '055A' '056A' '058A' '059A'
#  '060A' '061A' '064A' '066A' '067A' '068A' '069A' '071A' '072A' '074A'
#  '076A' '087A' '090A' '091A' '093A' '094A' '097A' '097B' '099A' '100A'
#  '101A' '102A' '103A' '104A' '105A' '108A' '109A' '110A' '111A' '115A'
#  '116A' '117A']
# Unique Test Group IDs:
# ['001A' '002B' '006A' '010A' '011A' '013B' '015A' '019A' '023B' '025A'
#  '025B' '027A' '034A' '040A' '041A' '042A' '052A' '057A' '062A' '063A'
#  '065A' '070A' '073A' '075A' '088A' '092A' '095A' '096A' '106A' '113A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '002A' '003A' '004A' '005A' '007A' '008A' '009A' '012A'
#  '014A' '014B' '016A' '018A' '019B' '020A' '021A' '022A' '023A' '024A'
#  '025C' '026A' '026B' '026C' '028A' '029A' '031A' '032A' '033A' '035A'
#  '036A' '037A' '038A' '039A' '043A' '044A' '045A' '046A' '047A' '048A'
#  '049A' '050A' '051A' '051B' '053A' '054A' '055A' '056A' '058A' '059A'
#  '060A' '061A' '064A' '066A' '067A' '068A' '069A' '071A' '072A' '074A'
#  '076A' '087A' '090A' '091A' '093A' '094A' '097A' '097B' '099A' '100A'
#  '101A' '102A' '103A' '104A' '105A' '108A' '109A' '110A' '111A' '115A'
#  '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['001A' '002B' '006A' '010A' '011A' '013B' '015A' '019A' '023B' '025A'
#  '025B' '027A' '034A' '040A' '041A' '042A' '052A' '057A' '062A' '063A'
#  '065A' '070A' '073A' '075A' '088A' '092A' '095A' '096A' '106A' '113A']
# Length of X_train_val:
# 709
# Length of y_train_val:
# 709
# Length of groups_train_val:
# 709
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     423
# kitten    151
# senior    135
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     176
# senior     48
# kitten     25
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     423
# kitten    151
# senior    135
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     176
# senior     48
# kitten     25
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 423, 1: 151, 2: 135})
# Epoch 1/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 1.3316 - accuracy: 0.5402
# Epoch 2/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.6772 - accuracy: 0.7391
# Epoch 3/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4642 - accuracy: 0.8181
# Epoch 4/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3588 - accuracy: 0.8717
# Epoch 5/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2743 - accuracy: 0.8900
# Epoch 6/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2392 - accuracy: 0.9083
# Epoch 7/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2322 - accuracy: 0.9097
# Epoch 8/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1794 - accuracy: 0.9379
# Epoch 9/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.2128 - accuracy: 0.9126
# Epoch 10/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1713 - accuracy: 0.9394
# Epoch 11/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1558 - accuracy: 0.9408
# Epoch 12/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1485 - accuracy: 0.9408
# Epoch 13/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1041 - accuracy: 0.9661
# Epoch 14/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1085 - accuracy: 0.9633
# Epoch 15/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1183 - accuracy: 0.9549
# Epoch 16/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1235 - accuracy: 0.9577
# Epoch 17/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1119 - accuracy: 0.9605
# Epoch 18/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1070 - accuracy: 0.9619
# Epoch 19/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.
1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0353 - accuracy: 0.9887
# Epoch 148/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0232 - accuracy: 0.9958
# Epoch 149/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0370 - accuracy: 0.9873
# Epoch 150/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0402 - accuracy: 0.9873
# Epoch 151/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0270 - accuracy: 0.9873
# Epoch 152/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0266 - accuracy: 0.9915
# Epoch 153/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0255 - accuracy: 0.9972
# Epoch 154/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0191 - accuracy: 0.9929
# Epoch 155/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0170 - accuracy: 0.9972
# Epoch 156/1500
# 12/12 [==============================] - ETA: 0s - loss: 0.0189 - accuracy: 0.9929Restoring model weights from the end of the best epoch: 126.
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0189 - accuracy: 0.9929
# Epoch 156: early stopping
# 8/8 [==============================] - 0s 1ms/step - loss: 4.2047 - accuracy: 0.5663
# 8/8 [==============================] - 0s 991us/step
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Majority Vote Accuracy for cat_id for this fold: 0.80 (24/30)
# Before appending - Cat IDs: 237, Predictions: 237, Actuals: 237, Gender: 237
# After appending - Cat IDs: 486, Predictions: 486, Actuals: 486, Gender: 486
# Final Test Results - Loss: 4.2046966552734375, Accuracy: 0.5662650465965271, Precision: 0.4024825224711086, Recall: 0.4575, F1 Score: 0.41916571484504855
# Confusion Matrix:
#  [[121  20  35]
#  [  9  14   2]
#  [ 33   9   6]]
# outer_fold 3
# Train Set Group Distribution:
# 046A    66
# 000A    39
# 002B    35
# 103A    33
# 047A    30
# 057A    28
# 074A    25
# 020A    23
# 055A    20
# 029A    17
# 019A    17
# 097A    16
# 106A    15
# 101A    15
# 097B    14
# 001A    14
# 028A    14
# 042A    14
# 039A    12
# 051A    12
# 025A    11
# 063A    11
# 005A    11
# 036A    11
# 068A    11
# 040A    10
# 015A    10
# 014B    10
# 045A     9
# 065A     9
# 095A     8
# 013B     8
# 010A     8
# 031A     7
# 117A     7
# 027A     7
# 037A     6
# 053A     6
# 109A     6
# 007A     6
# 023A     6
# 108A     6
# 075A     5
# 044A     5
# 023B     5
# 070A     5
# 062A     5
# 034A     5
# 021A     5
# 105A     4
# 012A     4
# 026A     4
# 009A     4
# 052A     4
# 060A     3
# 006A     3
# 113A     3
# 093A     2
# 025B     2
# 011A     2
# 069A     2
# 054A     2
# 018A     2
# 038A     2
# 102A     2
# 026B     1
# 004A     1
# 026C     1
# 115A     1
# 041A     1
# 090A     1
# 019B     1
# 091A     1
# 024A     1
# 073A     1
# 088A     1
# 110A     1
# 049A     1
# 092A     1
# 096A     1
# 100A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 000B    20
# 067A    20
# 059A    16
# 002A    13
# 111A    13
# 116A    12
# 016A    11
# 071A    10
# 072A     9
# 051B     9
# 022A     9
# 033A     9
# 094A     8
# 050A     7
# 099A     7
# 008A     6
# 025C     5
# 003A     4
# 035A     4
# 104A     4
# 056A     3
# 064A     3
# 014A     3
# 058A     3
# 061A     2
# 087A     2
# 066A     2
# 032A     2
# 048A     1
# 043A     1
# 076A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    299
# M    254
# F    186
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# M    95
# F    68
# X    56
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [028A, 070A, 020A, 000A, 015A, 026A, 065A, 053...
# kitten    [046A, 042A, 014B, 110A, 109A, 040A, 047A, 049...
# senior    [117A, 106A, 057A, 090A, 113A, 051A, 024A, 097...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [002A, 033A, 000B, 071A, 072A, 022A, 067A, 035...
# kitten                             [048A, 111A, 043A, 050A]
# senior    [051B, 116A, 094A, 059A, 016A, 058A, 061A, 104...
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 56, 'kitten': 12, 'senior': 13}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 18, 'kitten': 4, 'senior': 9}
# Unique Training/Validation Group IDs:
# ['000A' '001A' '002B' '004A' '005A' '006A' '007A' '009A' '010A' '011A'
#  '012A' '013B' '014B' '015A' '018A' '019A' '019B' '020A' '021A' '023A'
#  '023B' '024A' '025A' '025B' '026A' '026B' '026C' '027A' '028A' '029A'
#  '031A' '034A' '036A' '037A' '038A' '039A' '040A' '041A' '042A' '044A'
#  '045A' '046A' '047A' '049A' '051A' '052A' '053A' '054A' '055A' '057A'
#  '060A' '062A' '063A' '065A' '068A' '069A' '070A' '073A' '074A' '075A'
#  '088A' '090A' '091A' '092A' '093A' '095A' '096A' '097A' '097B' '100A'
#  '101A' '102A' '103A' '105A' '106A' '108A' '109A' '110A' '113A' '115A'
#  '117A']
# Unique Test Group IDs:
# ['000B' '002A' '003A' '008A' '014A' '016A' '022A' '025C' '032A' '033A'
#  '035A' '043A' '048A' '050A' '051B' '056A' '058A' '059A' '061A' '064A'
#  '066A' '067A' '071A' '072A' '076A' '087A' '094A' '099A' '104A' '111A'
#  '116A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '001A' '002B' '004A' '005A' '006A' '007A' '009A' '010A' '011A'
#  '012A' '013B' '014B' '015A' '018A' '019A' '019B' '020A' '021A' '023A'
#  '023B' '024A' '025A' '025B' '026A' '026B' '026C' '027A' '028A' '029A'
#  '031A' '034A' '036A' '037A' '038A' '039A' '040A' '041A' '042A' '044A'
#  '045A' '046A' '047A' '049A' '051A' '052A' '053A' '054A' '055A' '057A'
#  '060A' '062A' '063A' '065A' '068A' '069A' '070A' '073A' '074A' '075A'
#  '088A' '090A' '091A' '092A' '093A' '095A' '096A' '097A' '097B' '100A'
#  '101A' '102A' '103A' '105A' '106A' '108A' '109A' '110A' '113A' '115A'
#  '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['000B' '002A' '003A' '008A' '014A' '016A' '022A' '025C' '032A' '033A'
#  '035A' '043A' '048A' '050A' '051B' '056A' '058A' '059A' '061A' '064A'
#  '066A' '067A' '071A' '072A' '076A' '087A' '094A' '099A' '104A' '111A'
#  '116A']
# Length of X_train_val:
# 739
# Length of y_train_val:
# 739
# Length of groups_train_val:
# 739
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     470
# kitten    154
# senior    115
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     129
# senior     68
# kitten     22
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     470
# kitten    154
# senior    115
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     129
# senior     68
# kitten     22
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 470, 1: 154, 2: 115})
# Epoch 1/1500
# 12/12 [==============================] - 1s 4ms/step - loss: 1.6014 - accuracy: 0.4614
# Epoch 2/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.7696 - accuracy: 0.7104
# Epoch 3/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.5224 - accuracy: 0.8038
# Epoch 4/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3902 - accuracy: 0.8484
# Epoch 5/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3312 - accuracy: 0.8498
# Epoch 6/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2597 - accuracy: 0.9093
# Epoch 7/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2425 - accuracy: 0.9147
# Epoch 8/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1802 - accuracy: 0.9269
# Epoch 9/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1640 - accuracy: 0.9418
# Epoch 10/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1381 - accuracy: 0.9418
# Epoch 11/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1468 - accuracy: 0.9459
# Epoch 12/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1259 - accuracy: 0.9567
# Epoch 13/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1034 - accuracy: 0.9702
# Epoch 14/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0741 - accuracy: 0.9716
# Epoch 15/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0747 - accuracy: 0.9770
# Epoch 16/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0629 - accuracy: 0.9783
# Epoch 17/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0611 - accuracy: 0.9783
# Epoch 18/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0854 - accuracy: 0.9716
# Epoch 19/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0364 - accuracy: 0.9919
# Epoch 20/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0391 - accuracy: 0.9919
# Epoch 21/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0454 - accuracy: 0.9838
# Epoch 22/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0435 - accuracy: 0.9838
# Epoch 23/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0300 - accuracy: 0.9905
# Epoch 24/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0313 - accuracy: 0.9919
# Epoch 25/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0492 - accuracy: 0.9851
# Epoch 26/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0192 - accuracy: 0.9959
# Epoch 27/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0317 - accuracy: 0.9878
# Epoch 28/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0242 - accuracy: 0.9919
# Epoch 29/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0224 - accuracy: 0.9946
# Epoch 30/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0245 - accuracy: 0.9919
# Epoch 31/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0367 - accuracy: 0.9878
# Epoch 32/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0262 - accuracy: 0.9919
# Epoch 33/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0242 - accuracy: 0.9905
# Epoch 34/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0358 - accuracy: 0.9892
# Epoch 35/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0325 - accuracy: 0.9892
# Epoch 36/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0179 - accuracy: 0.9919
# Epoch 37/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0235 - accuracy: 0.9919
# Epoch 38/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0273 - accuracy: 0.9932
# Epoch 39/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0207 - accuracy: 0.9932
# Epoch 40/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0196 - accuracy: 0.9905
# Epoch 41/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0219 - accuracy: 0.9973
# Epoch 42/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0126 - accuracy: 0.9973
# Epoch 43/1500
# ...
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'046A', '000A'}
# Removed from Training/Validation Set:
# {'009A', '044A'}
# Moved to Test Set:
# {'009A', '044A'}
# Removed from Test Set
# {'046A', '000A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '004A' '005A' '006A' '008A'
#  '010A' '011A' '012A' '013B' '014A' '015A' '016A' '019A' '019B' '020A'
#  '022A' '023A' '023B' '025A' '025B' '025C' '026A' '026C' '027A' '029A'
#  '032A' '033A' '034A' '035A' '036A' '040A' '041A' '042A' '043A' '046A'
#  '047A' '048A' '050A' '051B' '052A' '053A' '054A' '055A' '056A' '057A'
#  '058A' '059A' '061A' '062A' '063A' '064A' '065A' '066A' '067A' '068A'
#  '070A' '071A' '072A' '073A' '074A' '075A' '076A' '087A' '088A' '092A'
#  '094A' '095A' '096A' '097A' '097B' '099A' '100A' '101A' '102A' '104A'
#  '106A' '111A' '113A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['007A' '009A' '014B' '018A' '021A' '024A' '026B' '028A' '031A' '037A'
#  '038A' '039A' '044A' '045A' '049A' '051A' '060A' '069A' '090A' '091A'
#  '093A' '103A' '105A' '108A' '109A' '110A' '115A']
# Length of X_train_val:
# 801
# Length of y_train_val:
# 801
# Length of groups_train_val:
# 801
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     462
# senior    161
# kitten     82
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     137
# kitten     94
# senior     22
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     497
# senior    161
# kitten    143
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     102
# kitten     33
# senior     22
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 497, 2: 161, 1: 143})
# Epoch 1/1500
# 13/13 [==============================] - 1s 4ms/step - loss: 1.3754 - accuracy: 0.5343
# Epoch 2/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.7010 - accuracy: 0.7266
# Epoch 3/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.4361 - accuracy: 0.8290
# Epoch 4/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3243 - accuracy: 0.8739
# Epoch 5/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2502 - accuracy: 0.9039
# Epoch 6/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.

# Total Gender Accuracy so far:
#  [  all_gender  count  correct  accuracy
# 0          F    215      130     60.47
# 1          M    353      248     70.25
# 2          X    290      146     50.34,   all_gender  count  correct  accuracy
# 0          F    218      131     60.09
# 1          M    349      243     69.63
# 2          X    295      151     51.19,   all_gender  count  correct  accuracy
# 0          F    219      130     59.36
# 1          M    349      231     66.19
# 2          X    294      150     51.02]

# %% [markdown]
# # RANDOM SEED 4

# %%
# Set a fixed random seed for reproducibility
random.seed(int(random_seeds[3])) 
np.random.seed(int(random_seeds[3]))
tf.random.set_seed(int(random_seeds[3]))

# Load datasets
dataframe = pd.read_csv('/Users/astrid/PycharmProjects/data-aug-and-more/yamnet-tfhub-extraction/yamnet_embeddings_not_looped_april_23.csv')

def assign_age_group(age, age_groups):
    for group_name, age_range in age_groups.items():
        if age_range[0] <= age < age_range[1]:
            return group_name
    return 'Unknown'  # For any age that doesn't fit the defined groups

# Define age groups
age_groups = {
    'kitten': (0, 0.5),
    'adult': (0.5, 12),
    'senior': (12, 20)
}

# Create a new column for the age group
dataframe['age_group'] = dataframe['target'].apply(assign_age_group, age_groups=age_groups)

print(dataframe['age_group'].value_counts())
# Out:
# adult     599
# senior    183
# kitten    176
# Name: age_group, dtype: int64

# %%
# Separate features and labels
X = dataframe.iloc[:, :-4].values  # all columns except the last four

# Encode the 'age_group' column as integers using LabelEncoder
label_encoder = LabelEncoder()
encoded_y = label_encoder.fit_transform(dataframe['age_group'].values)

# Use the encoded labels for splitting and one-hot encoding
y = encoded_y  

# Convert 'cat_id' column to numpy array to be used as groups array for GroupKFold
groups = dataframe['cat_id'].values

# %%
tf.keras.backend.clear_session()

# %% [markdown]
# ## Run Setup

# %%
all_cat_ids = []
all_predicted_age_groups = []
all_actual_age_groups = []
all_gender = []

# Define the StratifiedGroupKFold splitter for 4 fold CV with random shuffling
outer_cv = StratifiedGroupKFold(n_splits=4, shuffle=True, random_state=int(random_seeds[3]))

# unseen test set metrics
unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1 = [], [], [], [], []

outer_fold = 0

# Use the splitter to generate indices for training and testing sets
# Note: GroupShuffleSplit.split returns indices, so we use it to index the arrays
for train_val_idx, test_idx in outer_cv.split(X, y, groups):
    outer_fold += 1
    logger(f"outer_fold {outer_fold}", file=log_file_path)

    # Convert indices back to DataFrame for easy manipulation
    df_train_val = dataframe.iloc[train_val_idx]
    df_test = dataframe.iloc[test_idx]

    ##############################
    # ASSESSING SPLITS BY CAT_ID #
    ##############################
    
    # Get the distribution of groups
    training_validation_group_distribution = df_train_val['cat_id'].value_counts()  
    testing_group_distribution = df_test['cat_id'].value_counts()  
    
    # Log or print the distribution
    logger(f"Train Set Group Distribution:\n{training_validation_group_distribution}", file=log_file_path)
    logger(f"Testing Set Group Distribution:\n{testing_group_distribution}", file=log_file_path)

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val['gender'].value_counts()
    testing_gender_distribution = df_test['gender'].value_counts()
    
    # Log the distribution
    logger(f"Training Set Gender Distribution BEFORE SWAP:\n{training_gender_distribution}", file=log_file_path)
    logger(f"Testing Set Gender Distribution BEFORE SWAP:\n{testing_gender_distribution}", file=log_file_path)

    # Group by 'age_group' and then list unique 'cat_id' within each age group
    unique_cat_ids_per_age_group_train_val = df_train_val.groupby('age_group')['cat_id'].unique()
    unique_cat_ids_per_age_group_test = df_test.groupby('age_group')['cat_id'].unique()
    
    # Log results
    logger(f"Unique Cat IDs per Age Group in Training/Validation Set:\n{unique_cat_ids_per_age_group_train_val}", file=log_file_path)
    logger(f"Unique Cat IDs per Age Group in Testing Set:\n{unique_cat_ids_per_age_group_test}", file=log_file_path)

    # Calculate the count of unique identifiers per age group for training and testing set
    counts_train_val = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_train_val.items()}
    counts_test = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_test.items()}

    # Log the counts of unique identifiers per age group
    logger(f"Count of Unique Cat IDs per Age Group in Training/Validation Set:\n{counts_train_val}", file=log_file_path)
    logger(f"Count of Unique Cat IDs per Age Group in Testing Set:\n{counts_test}", file=log_file_path)

    #######################################################
    # CONTINUE WITH ENSURING VALID AND APPROPRIATE SPLITS #
    #######################################################
    
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    groups_train_val, groups_test = groups[train_val_idx], groups[test_idx]

    # logging identifier splits 
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)

    # check group splits
    check_initial_group_split(groups_train_val, groups_test)

    # Specify the cat_ids that must be in the training/validation set
    specific_cat_ids = ['000A', '046A']
    
    # Perform the swapping operation
    train_val_idx, test_idx = swap_cat_id_instances(dataframe, train_val_idx, test_idx, specific_cat_ids)
    
    # Re-assign the sets based on the updated indices
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    new_groups_train_val, new_groups_test = groups[train_val_idx], groups[test_idx]

    # Find differences for training and test sets
    moved_to_train_val, removed_from_train_val = find_group_differences(groups_train_val, new_groups_train_val)
    moved_to_test, removed_from_test = find_group_differences(groups_test, new_groups_test)
    
    # Display the results
    logger(f"Moved to Training/Validation Set:\n{moved_to_train_val}", file=log_file_path)
    logger(f"Removed from Training/Validation Set:\n{removed_from_train_val}", file=log_file_path)
    logger(f"Moved to Test Set:\n{moved_to_test}", file=log_file_path)
    logger(f"Removed from Test Set\n{removed_from_test}", file=log_file_path)

    # Update X_train_val, X_test, y_train_val, y_test, groups_train_val, groups_test based on updated indices
    X_train_val = X[train_val_idx]
    y_train_val = y[train_val_idx]
    groups_train_val = groups[train_val_idx]
    
    X_test = X[test_idx]
    y_test = y[test_idx]
    groups_test = groups[test_idx]

    # logging identifier splits again after potential swaps
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"AFTER SWAP - Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"AFTER SWAP - Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)
    
    # Verify the lengths are consistent
    logger(f"Length of X_train_val:\n{len(X_train_val)}", file=log_file_path)
    logger(f"Length of y_train_val:\n{len(y_train_val)}", file=log_file_path)
    logger(f"Length of groups_train_val:\n{len(groups_train_val)}", file=log_file_path)

    # Check group splits once more
    check_initial_group_split(groups_train_val, groups_test)

    # Convert the modified indices back to a DataFrame representing the updated df_train_val
    df_train_val_updated = dataframe.iloc[train_val_idx].copy()
    df_test_updated = dataframe.iloc[test_idx].copy()

    ############################
    # LOGGING AGE GROUP SPLITS #
    ############################

    # Get the distribution of age groups of age groups before the update
    training_validation_age_group_distribution = df_train_val['age_group'].value_counts()
    testing_age_group_distribution = df_test['age_group'].value_counts()
    
    # Logthe distribution
    logger(f"Train Age Group Distribution BEFORE SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution BEFORE SWAP:\n{testing_age_group_distribution}", file=log_file_path)

    # Get the distribution of age groups after the update
    training_validation_age_group_distribution = df_train_val_updated['age_group'].value_counts()
    testing_age_group_distribution = df_test_updated['age_group'].value_counts()
    
    # Log the distribution
    logger(f"Train Age Group Distribution AFTER SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution AFTER SWAP:\n{testing_age_group_distribution}", file=log_file_path)
    
    ########################################################
    # TRACKING FINAL CAT_IDs & GENDER AFTER REDISTRIBUTION #
    ########################################################

    # Get the distribution of groups
    training_validation_group_distribution = df_train_val_updated['cat_id'].value_counts()  
    testing_group_distribution = df_test_updated['cat_id'].value_counts()  

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val_updated['gender'].value_counts()
    testing_gender_distribution = df_test_updated['gender'].value_counts()
    
    logger(f"\n Starting training on unseen test set\n", file=log_file_path)

    ###################
    # PREPARING MODEL #
    ###################

    # Calculate the distribution of age groups in y_train_val
    age_group_distribution = Counter(y_train_val)
    print("Age group distribution:", age_group_distribution)

    # EarlyStopping callback: monitor 'loss' instead of 'val_loss' for the test set
    early_stopping = EarlyStopping(
        monitor='loss',  
        min_delta=0.001, 
        patience=30,  
        verbose=1,  
        restore_best_weights=True  
    )

    # One final shuffle to ensure randomness
    outer_shuffle_idx = np.random.permutation(len(X_train_val))
    X_train_val = X_train_val[outer_shuffle_idx]
    y_train_val = y_train_val[outer_shuffle_idx]
    
    # Scale the features
    scaler_full = StandardScaler().fit(X_train_val)
    X_train_full_scaled = scaler_full.transform(X_train_val)
    X_test_scaled = scaler_full.transform(X_test)
    
    # Encode the labels
    y_train_full_encoded = to_categorical(y_train_val)
    y_test_encoded = to_categorical(y_test)

    #######################
    # BUILD & TRAIN MODEL #
    #######################

    optimizers = {
        'Adamax': Adamax(learning_rate=0.00510251984616472)
    }
    
    # Model definition with dynamic number of layers
    model_full = Sequential()
    model_full.add(Dense(480, activation='relu', input_shape=(X_train_full_scaled.shape[1],)))
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.2011047009431978))  
    model_full.add(Dense(256, activation='relu',)) 
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.14956886311951184))  
    model_full.add(Dense(256, activation='relu'))  
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.42291461228250665))  
    model_full.add(Dense(3, activation='softmax'))  
    
    # Use the optimizer from the parameters
    optimizer = optimizers['Adamax']  # optimizer_key from parameters
    
    # Compile the model
    model_full.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    
    # Train the model on the full training set
    history_full = model_full.fit(X_train_full_scaled, y_train_full_encoded, epochs=1500, batch_size=64,
                                  verbose=1, callbacks=[early_stopping])
    
    # Evaluate the model on the held-out test set
    test_loss, test_accuracy = model_full.evaluate(X_test_scaled, y_test_encoded)

    y_test_pred_prob = model_full.predict(X_test_scaled)
    y_test_pred = np.argmax(y_test_pred_prob, axis=1)  
    y_test_true = np.argmax(y_test_encoded, axis=1)    

    ################################
    # LOG MAJORITY VOTE PER CAT_ID #
    ################################

    # Convert numeric predictions back to age group labels
    predicted_age_groups = label_encoder.inverse_transform(y_test_pred)
    actual_labels = label_encoder.inverse_transform(y_test_true)
    
    # Map predictions and actual labels back to cat_ids
    test_results = pd.DataFrame({
        'cat_id': df_test_updated['cat_id'],
        'predicted_age_group': predicted_age_groups,
        'actual_age_group': actual_labels
    })
    
    # Group by cat_id and aggregate predicted age groups
    majority_votes = test_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
    actual_groups = test_results.groupby('cat_id')['actual_age_group'].first()
    
    # Calculate the accuracy of majority voting
    correct_predictions = (majority_votes == actual_groups).sum()
    total_cats = len(actual_groups)
    majority_vote_accuracy = correct_predictions / total_cats
    
    # Log the accuracy of the majority voting
    logger(f"Majority Vote Accuracy for cat_id for this fold: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

    ####################################################
    # COLLECT PREDICTIONS FOR GENDER & CAT_ID ANALYSIS #
    ####################################################

    # Debugging print statements
    print(f'Before appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Extend lists with current fold results
    all_cat_ids.extend(df_test_updated['cat_id'].tolist())
    all_predicted_age_groups.extend(predicted_age_groups)
    all_actual_age_groups.extend(actual_labels)
    all_gender.extend(df_test_updated['gender'].tolist())

    # Debugging print statements
    print(f'After appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Calculate additional metrics
    test_precision = precision_score(y_test_true, y_test_pred, average='macro')  # Use 'macro' for imbalanced datasets
    test_recall = recall_score(y_test_true, y_test_pred, average='macro')
    test_f1 = f1_score(y_test_true, y_test_pred, average='macro')

    # prepare averages of outer metrics
    unseen_f1.append(test_f1)
    unseen_losses.append(test_loss)
    unseen_accuracies.append(test_accuracy)
    unseen_precisions.append(test_precision)
    unseen_recalls.append(test_recall)

    # Print final test results
    logger(f"Final Test Results - Loss: {test_loss}, Accuracy: {test_accuracy}, Precision: {test_precision}, Recall: {test_recall}, F1 Score: {test_f1}", file=log_file_path)

    # Generate the confusion matrix
    cm = confusion_matrix(y_test, y_test_pred)
    logger(f"Confusion Matrix:\n {cm}", file=log_file_path)

# Calculate the overall average metrics
unseen_set_avg_f1 = np.mean(unseen_f1)
unseen_set_avg_loss = np.mean(unseen_losses)
unseen_set_avg_acc = np.mean(unseen_accuracies)
unseen_set_avg_precision = np.mean(unseen_precisions)
unseen_set_avg_recall = np.mean(unseen_recalls)

logger(f"\nFinal Average F1-Score across all UNSEEN TEST sets: {unseen_set_avg_f1}", file=log_file_path)
logger(f"\nFinal Average Loss across all UNSEEN TEST sets: {unseen_set_avg_loss}", file=log_file_path)
logger(f"\nFinal Average Accuracy across all UNSEEN TEST sets: {unseen_set_avg_acc}", file=log_file_path)
logger(f"\nFinal Average Precision across all UNSEEN TEST sets: {unseen_set_avg_precision}", file=log_file_path)
logger(f"\nFinal Average Recall across all UNSEEN TEST sets: {unseen_set_avg_recall}\n", file=log_file_path)

# Append averages to total lists
all_f1.append(unseen_set_avg_f1)
all_losses.append(unseen_set_avg_loss)
all_accuracies.append(unseen_set_avg_acc)
all_precisions.append(unseen_set_avg_precision)
all_recalls.append(unseen_set_avg_recall)
# Out:
# outer_fold 1
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Train Set Group Distribution:
# 046A    66
# 000A    39
# 002B    35
# 103A    33
# 057A    28
# 074A    25
# 020A    23
# 067A    20
# 000B    20
# 055A    20
# 059A    16
# 097A    16
# 106A    15
# 101A    15
# 028A    14
# 097B    14
# 001A    14
# 111A    13
# 002A    13
# 025A    11
# 068A    11
# 036A    11
# 005A    11
# 015A    10
# 040A    10
# 051B     9
# 045A     9
# 065A     9
# 022A     9
# 033A     9
# 072A     9
# 013B     8
# 094A     8
# 095A     8
# 099A     7
# 117A     7
# 031A     7
# 027A     7
# 053A     6
# 023A     6
# 008A     6
# 037A     6
# 007A     6
# 109A     6
# 108A     6
# 023B     5
# 062A     5
# 021A     5
# 070A     5
# 034A     5
# 025C     5
# 003A     4
# 052A     4
# 104A     4
# 035A     4
# 012A     4
# 026A     4
# 009A     4
# 105A     4
# 058A     3
# 014A     3
# 056A     3
# 006A     3
# 113A     3
# 064A     3
# 060A     3
# 066A     2
# 011A     2
# 087A     2
# 102A     2
# 025B     2
# 032A     2
# 054A     2
# 069A     2
# 038A     2
# 093A     2
# 115A     1
# 076A     1
# 041A     1
# 110A     1
# 073A     1
# 043A     1
# 048A     1
# 092A     1
# 049A     1
# 026C     1
# 090A     1
# 004A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 047A    30
# 029A    17
# 019A    17
# 042A    14
# 039A    12
# 116A    12
# 051A    12
# 016A    11
# 063A    11
# 071A    10
# 014B    10
# 010A     8
# 050A     7
# 075A     5
# 044A     5
# 018A     2
# 061A     2
# 024A     1
# 091A     1
# 096A     1
# 088A     1
# 019B     1
# 026B     1
# 100A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    299
# X    237
# F    230
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    118
# M     50
# F     24
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [002A, 028A, 070A, 033A, 000B, 020A, 000A, 015...
# kitten    [046A, 110A, 109A, 040A, 049A, 045A, 048A, 111...
# senior    [117A, 106A, 057A, 090A, 113A, 051B, 097A, 094...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [071A, 018A, 091A, 019A, 010A, 063A, 029A, 075...
# kitten                       [042A, 014B, 047A, 044A, 050A]
# senior                       [116A, 051A, 024A, 016A, 061A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 60, 'kitten': 11, 'senior': 17}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 14, 'kitten': 5, 'senior': 5}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '004A' '005A' '006A' '007A'
#  '008A' '009A' '011A' '012A' '013B' '014A' '015A' '020A' '021A' '022A'
#  '023A' '023B' '025A' '025B' '025C' '026A' '026C' '027A' '028A' '031A'
#  '032A' '033A' '034A' '035A' '036A' '037A' '038A' '040A' '041A' '043A'
#  '045A' '046A' '048A' '049A' '051B' '052A' '053A' '054A' '055A' '056A'
#  '057A' '058A' '059A' '060A' '062A' '064A' '065A' '066A' '067A' '068A'
#  '069A' '070A' '072A' '073A' '074A' '076A' '087A' '090A' '092A' '093A'
#  '094A' '095A' '097A' '097B' '099A' '101A' '102A' '103A' '104A' '105A'
#  '106A' '108A' '109A' '110A' '111A' '113A' '115A' '117A']
# Unique Test Group IDs:
# ['010A' '014B' '016A' '018A' '019A' '019B' '024A' '026B' '029A' '039A'
#  '042A' '044A' '047A' '050A' '051A' '061A' '063A' '071A' '075A' '088A'
#  '091A' '096A' '100A' '116A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '004A' '005A' '006A' '007A'
#  '008A' '009A' '011A' '012A' '013B' '014A' '015A' '020A' '021A' '022A'
#  '023A' '023B' '025A' '025B' '025C' '026A' '026C' '027A' '028A' '031A'
#  '032A' '033A' '034A' '035A' '036A' '037A' '038A' '040A' '041A' '043A'
#  '045A' '046A' '048A' '049A' '051B' '052A' '053A' '054A' '055A' '056A'
#  '057A' '058A' '059A' '060A' '062A' '064A' '065A' '066A' '067A' '068A'
#  '069A' '070A' '072A' '073A' '074A' '076A' '087A' '090A' '092A' '093A'
#  '094A' '095A' '097A' '097B' '099A' '101A' '102A' '103A' '104A' '105A'
#  '106A' '108A' '109A' '110A' '111A' '113A' '115A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['010A' '014B' '016A' '018A' '019A' '019B' '024A' '026B' '029A' '039A'
#  '042A' '044A' '047A' '050A' '051A' '061A' '063A' '071A' '075A' '088A'
#  '091A' '096A' '100A' '116A']
# Length of X_train_val:
# 766
# Length of y_train_val:
# 766
# Length of groups_train_val:
# 766
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     511
# senior    145
# kitten    110
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     88
# kitten    66
# senior    38
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     511
# senior    145
# kitten    110
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     88
# kitten    66
# senior    38
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 511, 2: 145, 1: 110})
# Epoch 1/1500
# 12/12 [==============================] - 1s 4ms/step - loss: 1.3784 - accuracy: 0.5235
# Epoch 2/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.6986 - accuracy: 0.7258
# Epoch 3/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4515 - accuracy: 0.8264
# Epoch 4/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3242 - accuracy: 0.8864
# Epoch 5/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2841 - accuracy: 0.9073
# Epoch 6/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2052 - accuracy: 0.9256
# Epoch 7/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1455 - accuracy: 0.9491
# Epoch 8/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1436 - accuracy: 0.9465
# Epoch 9/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1375 - accuracy: 0.9582
# Epoch 10/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0973 - accuracy: 0.9674
# Epoch 11/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1219 - accuracy: 0.9556
# Epoch 12/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0922 - accuracy: 0.9674
# Epoch 13/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1020 - accuracy: 0.9648
# Epoch 14/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1062 - accuracy: 0.9608
# Epoch 15/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0748 - accuracy: 0.9700
# Epoch 16/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0514 - accuracy: 0.9856
# Epoch 17/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0567 - accuracy: 0.9817
# Epoch 18/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0316 - accuracy: 0.9935
# Epoch 19/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0418 - accuracy: 0.9869
# Epoch 20/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0290 - accuracy: 0.9909
# Epoch 21/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0151 - accuracy: 0.9987
# Epoch 22/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0261 - accuracy: 0.9909
# Epoch 23/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0309 - accuracy: 0.9948
# Epoch 24/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0242 - accuracy: 0.9961
# Epoch 25/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0332 - accuracy: 0.9948
# Epoch 26/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0183 - accuracy: 0.9935
# Epoch 27/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0247 - accuracy: 0.9909
# Epoch 28/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0275 - accuracy: 0.9869
# Epoch 29/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0470 - accuracy: 0.9817
# Epoch 30/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0148 - accuracy: 0.9948
# Epoch 101: early stopping
# 6/6 [==============================] - 0s 1ms/step - loss: 6.2822 - accuracy: 0.4740
# 6/6 [==============================] - 0s 1ms/step
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Majority Vote Accuracy for cat_id for this fold: 0.62 (15/24)
# Before appending - Cat IDs: 0, Predictions: 0, Actuals: 0, Gender: 0
# After appending - Cat IDs: 192, Predictions: 192, Actuals: 192, Gender: 192
# Final Test Results - Loss: 6.28219747543335, Accuracy: 0.4739583432674408, Precision: 0.45589135043610646, Recall: 0.40842636895268475, F1 Score: 0.383772007301419
# Confusion Matrix:
#  [[70  7 11]
#  [40 11 15]
#  [27  1 10]]
# outer_fold 2
# Train Set Group Distribution:
# 047A    30
# 074A    25
# 020A    23
# 055A    20
# 029A    17
# 019A    17
# 059A    16
# 097A    16
# 106A    15
# 001A    14
# 028A    14
# 042A    14
# 111A    13
# 002A    13
# 051A    12
# 039A    12
# 116A    12
# 005A    11
# 063A    11
# 016A    11
# 014B    10
# 071A    10
# 040A    10
# 033A     9
# 065A     9
# 072A     9
# 022A     9
# 010A     8
# 094A     8
# 095A     8
# 013B     8
# 027A     7
# 031A     7
# 099A     7
# 117A     7
# 050A     7
# 008A     6
# 007A     6
# 053A     6
# 037A     6
# 108A     6
# 070A     5
# 044A     5
# 075A     5
# 023B     5
# 021A     5
# 034A     5
# 026A     4
# 003A     4
# 104A     4
# 105A     4
# 052A     4
# 012A     4
# 035A     4
# 058A     3
# 006A     3
# 056A     3
# 113A     3
# 014A     3
# 064A     3
# 032A     2
# 018A     2
# 093A     2
# 069A     2
# 038A     2
# 066A     2
# 061A     2
# 102A     2
# 073A     1
# 048A     1
# 092A     1
# 090A     1
# 088A     1
# 026C     1
# 024A     1
# 110A     1
# 019B     1
# 096A     1
# 115A     1
# 091A     1
# 026B     1
# 100A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 046A    66
# 000A    39
# 002B    35
# 103A    33
# 057A    28
# 000B    20
# 067A    20
# 101A    15
# 097B    14
# 068A    11
# 036A    11
# 025A    11
# 015A    10
# 045A     9
# 051B     9
# 023A     6
# 109A     6
# 062A     5
# 025C     5
# 009A     4
# 060A     3
# 054A     2
# 087A     2
# 011A     2
# 025B     2
# 049A     1
# 043A     1
# 041A     1
# 076A     1
# 004A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    228
# X    200
# F    157
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    155
# M    121
# F     97
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [002A, 028A, 070A, 033A, 071A, 020A, 026A, 065...
# kitten    [042A, 014B, 110A, 040A, 047A, 048A, 111A, 044...
# senior    [117A, 106A, 090A, 113A, 116A, 051A, 024A, 097...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [000B, 000A, 015A, 068A, 062A, 002B, 009A, 101...
# kitten                 [046A, 109A, 049A, 045A, 043A, 041A]
# senior                             [057A, 051B, 054A, 011A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 54, 'kitten': 10, 'senior': 18}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 20, 'kitten': 6, 'senior': 4}
# Unique Training/Validation Group IDs:
# ['001A' '002A' '003A' '005A' '006A' '007A' '008A' '010A' '012A' '013B'
#  '014A' '014B' '016A' '018A' '019A' '019B' '020A' '021A' '022A' '023B'
#  '024A' '026A' '026B' '026C' '027A' '028A' '029A' '031A' '032A' '033A'
#  '034A' '035A' '037A' '038A' '039A' '040A' '042A' '044A' '047A' '048A'
#  '050A' '051A' '052A' '053A' '055A' '056A' '058A' '059A' '061A' '063A'
#  '064A' '065A' '066A' '069A' '070A' '071A' '072A' '073A' '074A' '075A'
#  '088A' '090A' '091A' '092A' '093A' '094A' '095A' '096A' '097A' '099A'
#  '100A' '102A' '104A' '105A' '106A' '108A' '110A' '111A' '113A' '115A'
#  '116A' '117A']
# Unique Test Group IDs:
# ['000A' '000B' '002B' '004A' '009A' '011A' '015A' '023A' '025A' '025B'
#  '025C' '036A' '041A' '043A' '045A' '046A' '049A' '051B' '054A' '057A'
#  '060A' '062A' '067A' '068A' '076A' '087A' '097B' '101A' '103A' '109A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'046A', '000A'}
# Removed from Training/Validation Set:
# {'040A', '037A'}
# Moved to Test Set:
# {'040A', '037A'}
# Removed from Test Set
# {'046A', '000A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '001A' '002A' '003A' '005A' '006A' '007A' '008A' '010A' '012A'
#  '013B' '014A' '014B' '016A' '018A' '019A' '019B' '020A' '021A' '022A'
#  '023B' '024A' '026A' '026B' '026C' '027A' '028A' '029A' '031A' '032A'
#  '033A' '034A' '035A' '038A' '039A' '042A' '044A' '046A' '047A' '048A'
#  '050A' '051A' '052A' '053A' '055A' '056A' '058A' '059A' '061A' '063A'
#  '064A' '065A' '066A' '069A' '070A' '071A' '072A' '073A' '074A' '075A'
#  '088A' '090A' '091A' '092A' '093A' '094A' '095A' '096A' '097A' '099A'
#  '100A' '102A' '104A' '105A' '106A' '108A' '110A' '111A' '113A' '115A'
#  '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['000B' '002B' '004A' '009A' '011A' '015A' '023A' '025A' '025B' '025C'
#  '036A' '037A' '040A' '041A' '043A' '045A' '049A' '051B' '054A' '057A'
#  '060A' '062A' '067A' '068A' '076A' '087A' '097B' '101A' '103A' '109A']
# Length of X_train_val:
# 674
# Length of y_train_val:
# 674
# Length of groups_train_val:
# 674
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     351
# senior    142
# kitten     92
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     248
# kitten     84
# senior     41
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     384
# kitten    148
# senior    142
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     215
# senior     41
# kitten     28
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 384, 1: 148, 2: 142})
# Epoch 1/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 1.4184 - accuracy: 0.5341
# Epoch 2/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.6788 - accuracy: 0.7359
# Epoch 3/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.5055 - accuracy: 0.8071
# Epoch 4/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.3404 - accuracy: 0.8605
# Epoch 5/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.2992 - accuracy: 0.8902
# Epoch 6/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.1961 - accuracy: 0.9273
# Epoch 7/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.1814 - accuracy: 0.9377
# Epoch 8/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.1455 - accuracy: 0.9436
# Epoch 9/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.1240 - accuracy: 0.9555
# Epoch 10/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1040 - accuracy: 0.9688
# Epoch 11/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1009 - accuracy: 0.9748
# Epoch 12/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0895 - accuracy: 0.9688
# Epoch 13/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0761 - accuracy: 0.9777
# Epoch 14/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0852 - accuracy: 0.9674
# Epoch 15/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0764 - accuracy: 0.9763
# Epoch 16/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0794 - accuracy: 0.9748
# Epoch 17/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0373 - accuracy: 0.9896
# Epoch 18/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0461 - accuracy: 0.9852
# Epoch 19/1500
# 11/11 [==============================] - 0s 18ms/step - loss: 0.0546 - accuracy: 0.9777
# Epoch 20/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0287 - accuracy: 0.9941
# Epoch 21/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0359 - accuracy: 0.9881
# Epoch 22/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0233 - accuracy: 0.9955
# Epoch 23/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0217 - accuracy: 0.9941
# Epoch 24/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0251 - accuracy: 0.9926
# Epoch 25/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0281 - accuracy: 0.9896
# Epoch 26/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0174 - accuracy: 0.9941
# Epoch 27/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0534 - accuracy: 0.9807
# Epoch 28/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.
1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0044 - accuracy: 0.9985
# Epoch 96/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0138 - accuracy: 0.9955
# Epoch 97/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0108 - accuracy: 0.9970
# Epoch 98/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0051 - accuracy: 0.9985
# Epoch 99/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0110 - accuracy: 0.9970
# Epoch 100/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0110 - accuracy: 0.9970
# Epoch 101/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 102/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0061 - accuracy: 0.9985
# Epoch 103/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0141 - accuracy: 0.9941
# Epoch 104/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0029 - accuracy: 0.9985
# Epoch 105/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0033 - accuracy: 0.9985
# Epoch 106/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0053 - accuracy: 0.9970
# Epoch 107/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0024 - accuracy: 0.9985
# Epoch 108/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 109/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0057 - accuracy: 0.9985
# Epoch 110/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 111/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 112/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0023 - accuracy: 0.9985
# Epoch 113/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 114/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0035 - accuracy: 0.9985
# Epoch 115/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0044 - accuracy: 0.9985
# Epoch 116/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 117/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 118/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 3.4395e-04 - accuracy: 1.0000
# Epoch 119/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 120/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0063 - accuracy: 0.9970
# Epoch 121/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0015 - accuracy: 0.9985
# Epoch 122/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0042 - accuracy: 0.9985
# Epoch 123/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 124/1500
#  1/11 [=>............................] - ETA: 0s - loss: 0.0121 - accuracy: 0.9844Restoring model weights from the end of the best epoch: 94.
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0023 - accuracy: 0.9985
# Epoch 124: early stopping
# 9/9 [==============================] - 0s 1ms/step - loss: 3.2893 - accuracy: 0.6373
# 9/9 [==============================] - 0s 1ms/step
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Majority Vote Accuracy for cat_id for this fold: 0.73 (22/30)
# Before appending - Cat IDs: 192, Predictions: 192, Actuals: 192, Gender: 192
# After appending - Cat IDs: 476, Predictions: 476, Actuals: 476, Gender: 476
# Final Test Results - Loss: 3.2892608642578125, Accuracy: 0.6373239159584045, Precision: 0.4635517364840673, Recall: 0.5017327066958377, F1 Score: 0.4778165873056384
# Confusion Matrix:
#  [[156  20  39]
#  [ 12  15   1]
#  [ 28   3  10]]
# outer_fold 3
# Train Set Group Distribution:
# 046A    66
# 000A    39
# 002B    35
# 103A    33
# 047A    30
# 057A    28
# 074A    25
# 020A    23
# 000B    20
# 067A    20
# 029A    17
# 019A    17
# 097A    16
# 101A    15
# 097B    14
# 028A    14
# 042A    14
# 111A    13
# 039A    12
# 051A    12
# 116A    12
# 063A    11
# 005A    11
# 068A    11
# 036A    11
# 025A    11
# 016A    11
# 015A    10
# 071A    10
# 014B    10
# 033A     9
# 065A     9
# 022A     9
# 045A     9
# 051B     9
# 072A     9
# 094A     8
# 010A     8
# 013B     8
# 095A     8
# 099A     7
# 050A     7
# 031A     7
# 053A     6
# 108A     6
# 008A     6
# 023A     6
# 109A     6
# 044A     5
# 025C     5
# 075A     5
# 021A     5
# 023B     5
# 034A     5
# 062A     5
# 009A     4
# 003A     4
# 105A     4
# 060A     3
# 087A     2
# 025B     2
# 018A     2
# 011A     2
# 054A     2
# 102A     2
# 061A     2
# 069A     2
# 088A     1
# 110A     1
# 091A     1
# 096A     1
# 043A     1
# 024A     1
# 019B     1
# 049A     1
# 041A     1
# 115A     1
# 076A     1
# 004A     1
# 026B     1
# 100A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 055A    20
# 059A    16
# 106A    15
# 001A    14
# 002A    13
# 040A    10
# 027A     7
# 117A     7
# 007A     6
# 037A     6
# 070A     5
# 052A     4
# 104A     4
# 012A     4
# 026A     4
# 035A     4
# 058A     3
# 113A     3
# 006A     3
# 014A     3
# 056A     3
# 064A     3
# 066A     2
# 093A     2
# 032A     2
# 038A     2
# 073A     1
# 048A     1
# 090A     1
# 026C     1
# 092A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    320
# M    281
# F    187
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# M    68
# F    67
# X    35
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [028A, 033A, 000B, 071A, 020A, 000A, 015A, 065...
# kitten    [046A, 042A, 014B, 110A, 109A, 047A, 049A, 045...
# senior    [057A, 051B, 116A, 051A, 024A, 097A, 094A, 016...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [002A, 070A, 026A, 038A, 026C, 007A, 001A, 006...
# kitten                                         [040A, 048A]
# senior    [117A, 106A, 090A, 113A, 059A, 055A, 058A, 104...
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 55, 'kitten': 14, 'senior': 12}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 19, 'kitten': 2, 'senior': 10}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '002B' '003A' '004A' '005A' '008A' '009A' '010A' '011A'
#  '013B' '014B' '015A' '016A' '018A' '019A' '019B' '020A' '021A' '022A'
#  '023A' '023B' '024A' '025A' '025B' '025C' '026B' '028A' '029A' '031A'
#  '033A' '034A' '036A' '039A' '041A' '042A' '043A' '044A' '045A' '046A'
#  '047A' '049A' '050A' '051A' '051B' '053A' '054A' '057A' '060A' '061A'
#  '062A' '063A' '065A' '067A' '068A' '069A' '071A' '072A' '074A' '075A'
#  '076A' '087A' '088A' '091A' '094A' '095A' '096A' '097A' '097B' '099A'
#  '100A' '101A' '102A' '103A' '105A' '108A' '109A' '110A' '111A' '115A'
#  '116A']
# Unique Test Group IDs:
# ['001A' '002A' '006A' '007A' '012A' '014A' '026A' '026C' '027A' '032A'
#  '035A' '037A' '038A' '040A' '048A' '052A' '055A' '056A' '058A' '059A'
#  '064A' '066A' '070A' '073A' '090A' '092A' '093A' '104A' '106A' '113A'
#  '117A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '002B' '003A' '004A' '005A' '008A' '009A' '010A' '011A'
#  '013B' '014B' '015A' '016A' '018A' '019A' '019B' '020A' '021A' '022A'
#  '023A' '023B' '024A' '025A' '025B' '025C' '026B' '028A' '029A' '031A'
#  '033A' '034A' '036A' '039A' '041A' '042A' '043A' '044A' '045A' '046A'
#  '047A' '049A' '050A' '051A' '051B' '053A' '054A' '057A' '060A' '061A'
#  '062A' '063A' '065A' '067A' '068A' '069A' '071A' '072A' '074A' '075A'
#  '076A' '087A' '088A' '091A' '094A' '095A' '096A' '097A' '097B' '099A'
#  '100A' '101A' '102A' '103A' '105A' '108A' '109A' '110A' '111A' '115A'
#  '116A']
# AFTER SWAP - Unique Test Group IDs:
# ['001A' '002A' '006A' '007A' '012A' '014A' '026A' '026C' '027A' '032A'
#  '035A' '037A' '038A' '040A' '048A' '052A' '055A' '056A' '058A' '059A'
#  '064A' '066A' '070A' '073A' '090A' '092A' '093A' '104A' '106A' '113A'
#  '117A']
# Length of X_train_val:
# 788
# Length of y_train_val:
# 788
# Length of groups_train_val:
# 788
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     514
# kitten    165
# senior    109
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     85
# senior    74
# kitten    11
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     514
# kitten    165
# senior    109
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     85
# senior    74
# kitten    11
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 514, 1: 165, 2: 109})
# Epoch 1/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 1.4426 - accuracy: 0.5140
# Epoch 2/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0
1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0117 - accuracy: 0.9975
# Epoch 66/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0061 - accuracy: 0.9987
# Epoch 67/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0043 - accuracy: 0.9987
# Epoch 68/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0067 - accuracy: 0.9987
# Epoch 69/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0137 - accuracy: 0.9937
# Epoch 70/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0208 - accuracy: 0.9898
# Epoch 71/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0145 - accuracy: 0.9924
# Epoch 72/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0181 - accuracy: 0.9949
# Epoch 73/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0096 - accuracy: 0.9962
# Epoch 74/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0296 - accuracy: 0.9898
# Epoch 75/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0161 - accuracy: 0.9949
# Epoch 76/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0228 - accuracy: 0.9924
# Epoch 77/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0105 - accuracy: 0.9975
# Epoch 78/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0285 - accuracy: 0.9911
# Epoch 79/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0048 - accuracy: 1.0000
# Epoch 80/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0086 - accuracy: 0.9975
# Epoch 81/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0200 - accuracy: 0.9924
# Epoch 82/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0092 - accuracy: 0.9975
# Epoch 83/1500
# ...
#  '106A' '109A' '113A' '116A' '117A']
# Unique Test Group IDs:
# ['003A' '005A' '008A' '013B' '020A' '021A' '022A' '023B' '028A' '031A'
#  '033A' '034A' '053A' '065A' '069A' '072A' '074A' '094A' '095A' '097A'
#  '099A' '102A' '105A' '108A' '110A' '111A' '115A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '004A' '006A' '007A' '009A' '010A'
#  '011A' '012A' '014A' '014B' '015A' '016A' '018A' '019A' '019B' '023A'
#  '024A' '025A' '025B' '025C' '026A' '026B' '026C' '027A' '029A' '032A'
#  '035A' '036A' '037A' '038A' '039A' '040A' '041A' '042A' '043A' '044A'
#  '045A' '046A' '047A' '048A' '049A' '050A' '051A' '051B' '052A' '054A'
#  '055A' '056A' '057A' '058A' '059A' '060A' '061A' '062A' '063A' '064A'
#  '066A' '067A' '068A' '070A' '071A' '073A' '075A' '076A' '087A' '088A'
#  '090A' '091A' '092A' '093A' '096A' '097B' '100A' '101A' '103A' '104A'
#  '106A' '109A' '113A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['003A' '005A' '008A' '013B' '020A' '021A' '022A' '023B' '028A' '031A'
#  '033A' '034A' '053A' '065A' '069A' '072A' '074A' '094A' '095A' '097A'
#  '099A' '102A' '105A' '108A' '110A' '111A' '115A']
# Length of X_train_val:
# 735
# Length of y_train_val:
# 735
# Length of groups_train_val:
# 735
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     421
# kitten    161
# senior    153
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     178
# senior     30
# kitten     15
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     421
# kitten    161
# senior    153
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     178
# senior     30
# kitten     15
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 421, 1: 161, 2: 153})
# Epoch 1/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 1.4560 - accuracy: 0.5197
# Epoch 2/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.6838 - accuracy: 0.7224
# Epoch 3/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4943 - accuracy: 0.7973
# Epoch 4/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4048 - accuracy: 0.8612
# Epoch 5/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2697 - accuracy: 0.8939
# Epoch 6/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2508 - accuracy: 0.8939
# Epoch 7/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2023 - accuracy: 0.9333
# Epoch 8/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1346 - accuracy: 0.9578
# Epoch 9/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1571 - accuracy: 0.9401
# Epoch 10/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1147 - accuracy: 0.9673
# Epoch 11/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1334 - accuracy: 0.9510
# Epoch 12/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0735 - accuracy: 0.9728
# Epoch 13/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0639 - accuracy: 0.9810
# Epoch 14/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0732 - accuracy: 0.9755
# Epoch 15/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0558 - accuracy: 0.9796
# Epoch 16/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0816 - accuracy: 0.9714
# Epoch 17/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0564 - accuracy: 0.9823
# Epoch 18/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.
1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0076 - accuracy: 0.9973
# Epoch 85/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0171 - accuracy: 0.9918
# Epoch 86/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0208 - accuracy: 0.9918
# Epoch 87/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0083 - accuracy: 0.9959
# Epoch 88/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0047 - accuracy: 0.9986
# Epoch 89/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0080 - accuracy: 0.9973
# Epoch 90/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0110 - accuracy: 0.9959
# Epoch 91/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0068 - accuracy: 0.9986
# Epoch 92/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0057 - accuracy: 0.9986
# Epoch 93/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0060 - accuracy: 0.9986
# Epoch 94/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0128 - accuracy: 0.9946
# Epoch 95/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0132 - accuracy: 0.9946
# Epoch 96/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 97/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 8.4642e-04 - accuracy: 1.0000
# Epoch 98/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0058 - accuracy: 0.9986
# Epoch 99/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 100/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0055 - accuracy: 0.9973
# Epoch 101/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0060 - accuracy: 0.9986
# Epoch 102/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0150 - accuracy: 0.9973
# Epoch 103/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0119 - accuracy: 0.9946
# Epoch 104/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0147 - accuracy: 0.9959
# Epoch 105/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0139 - accuracy: 0.9918
# Epoch 106/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0058 - accuracy: 0.9973
# Epoch 107/1500
# 12/12 [==============================] - 0s 15ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 108/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 109/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0071 - accuracy: 0.9986
# Epoch 110/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0130 - accuracy: 0.9959
# Epoch 111/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0132 - accuracy: 0.9959
# Epoch 112/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0045 - accuracy: 1.0000
# Epoch 113/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0109 - accuracy: 0.9959
# Epoch 114/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0050 - accuracy: 0.9986
# Epoch 115/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0049 - accuracy: 0.9986
# Epoch 116/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0050 - accuracy: 0.9986
# Epoch 117/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0043 - accuracy: 0.9986
# Epoch 118/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0034 - accuracy: 0.9986
# Epoch 119/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 120/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0034 - accuracy: 0.9986
# Epoch 121/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 122/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 7.0493e-04 - accuracy: 1.0000
# Epoch 123/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 6.9024e-04 - accuracy: 1.0000
# Epoch 124/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0065 - accuracy: 0.9986
# Epoch 125/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0123 - accuracy: 0.9959
# Epoch 126/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0051 - accuracy: 0.9973
# Epoch 127/1500
#  1/12 [=>............................] - ETA: 0s - loss: 0.0490 - accuracy: 0.9844Restoring model weights from the end of the best epoch: 97.
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0143 - accuracy: 0.9973
# Epoch 127: early stopping
# 7/7 [==============================] - 0s 1ms/step - loss: 3.2936 - accuracy: 0.6996
# 7/7 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.78 (21/27)
# Before appending - Cat IDs: 646, Predictions: 646, Actuals: 646, Gender: 646
# After appending - Cat IDs: 869, Predictions: 869, Actuals: 869, Gender: 869
# Final Test Results - Loss: 3.293572425842285, Accuracy: 0.6995515823364258, Precision: 0.5316407550040413, Recall: 0.6841448189762797, F1 Score: 0.5661884899773264
# Confusion Matrix:
#  [[128  25  25]
#  [  3  12   0]
#  [ 13   1  16]]
#
# Final Average F1-Score across all UNSEEN TEST sets: 0.47600858691447906
#
# Final Average Loss across all UNSEEN TEST sets: 4.62563419342041
#
# Final Average Accuracy across all UNSEEN TEST sets: 0.5909437611699104
#
# Final Average Precision across all UNSEEN TEST sets: 0.5028383005483938
#
# Final Average Recall across all UNSEEN TEST sets: 0.5389406699032497

# %%
seed_4_folds_values = (unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1)

# Plotting all fold metrics
seed_4_folds_plot = plot_all_metrics(unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1, "Folds", "Fold Number")

# %% [markdown]
# ## Majority Voting on Total Entries per cat_id

# %%
# Debugging print statements
print(f'Checking - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
# Out:
# Checking - Cat IDs: 869, Predictions: 869, Actuals: 869, Gender: 869

# %%
# Create results df
full_results = pd.DataFrame({
    'cat_id': all_cat_ids,
    'predicted_age_group': all_predicted_age_groups,
    'actual_age_group': all_actual_age_groups,
    'all_gender': all_gender
})

# create a correct majority prediction column
full_results['correct'] = full_results['predicted_age_group'] == full_results['actual_age_group']

# %%
# Group by cat_id and aggregate predicted age groups
majority_votes = full_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first()

# Calculate the accuracy of majority voting
correct_predictions = (majority_votes == actual_groups).sum()
total_cats = len(actual_groups)
majority_vote_accuracy = correct_predictions / total_cats

logger(f"Overall Majority Vote Accuracy for cat_id: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

# store for final evaluation 
all_majority_vote_accuracies.append(majority_vote_accuracy)
# Out:
# Overall Majority Vote Accuracy for cat_id: 0.72 (79/110)

# %%
# Detailed df with predictions, actual labels, and comparison including majority vote
detailed_results = full_results.groupby('cat_id').apply(
    lambda x: pd.Series({
        'Predictions': list(x['predicted_age_group']),
        'Majority Vote': x['predicted_age_group'].mode()[0],
        'Actual Age Group': x['actual_age_group'].iloc[0],
        'Correct Majority Vote': x['predicted_age_group'].mode()[0] == x['actual_age_group'].iloc[0]
    })
).reset_index()

# Convert to DataFrame for better formatting and display
detailed_results = pd.DataFrame(detailed_results)

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 10)
pd.set_option('display.width', 1000)

sorted_detailed_results = detailed_results.sort_values(by='Correct Majority Vote', ascending=False)

# Display the sorted DataFrame
sorted_detailed_results
# Out:
#     cat_id                                        Predictions Majority Vote Actual Age Group  Correct Majority Vote
# 0     000B  [kitten, kitten, adult, kitten, kitten, senior...         adult            adult                   True
# 66    060A                            [adult, kitten, senior]         adult            adult                   True
# 76    070A              [adult, senior, kitten, adult, adult]         adult            adult                   True
# 75    069A                                    [kitten, adult]         adult            adult                   True
# 74    068A  [adult, adult, adult, adult, senior, adult, ad...         adult            adult                   True
# 73    067A  [adult, adult, adult, adult, kitten, adult, ad...         adult            adult                   True
#
# 103   109A        [adult, adult, adult, adult, kitten, adult]         adult           kitten                  False
# 48    042A  [adult, adult, adult, adult, adult, adult, adu...         adult           kitten                  False
# 47    041A                                            [adult]         adult           kitten                  False
# 106   113A                            [kitten, adult, senior]         adult           senior                  False
# 107   115A                                            [adult]         adult           kitten                  False
# 100   105A                   [senior, senior, senior, kitten]        senior            adult                  False
# 12    011A                                    [adult, senior]         adult           senior                  False
# 56    051A  [adult, adult, senior, adult, adult, kitten, a...         adult           senior                  False
# 62    056A                              [adult, adult, adult]         adult           senior                  False
# 67    061A                                     [adult, adult]         adult           senior                  False
# 27    024A                                            [adult]         adult           senior                  False
# 33    026C                                           [senior]        senior            adult                  False
# 24    022A  [adult, kitten, adult, adult, kitten, kitten, ...        kitten            adult                  False
# 64    058A                              [adult, adult, adult]         adult           senior                  False
# 63    057A  [kitten, adult, adult, adult, adult, adult, se...         adult           senior                  False
# 61    055A  [adult, adult, adult, adult, adult, adult, adu...         adult           senior                  False
# 88    093A                                    [kitten, adult]         adult           senior                  False
# 60    054A                                    [adult, senior]         adult           senior                  False
# 18    016A  [adult, adult, adult, adult, adult, adult, adu...         adult           senior                  False
# 59    053A     [senior, senior, adult, adult, senior, senior]        senior            adult                  False
# 16    014B  [adult, adult, kitten, senior, senior, kitten,...         adult           kitten                  False
# 86    091A                                           [senior]        senior            adult                  False
# 57    051B  [adult, adult, adult, senior, senior, adult, a...         adult           senior                  False
# 109   117A  [adult, adult, adult, senior, adult, adult, se...         adult           senior                  False

# %%
# Create df for majority votes
majority_df = majority_votes.reset_index()
majority_df.columns = ['cat_id', 'Majority_Vote']

# Get actual groups for each cat_id
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first().reset_index()

# Merge majority votes with actual groups
majority_with_actual = pd.merge(majority_df, actual_groups, on='cat_id')

# Add a column to check if the majority vote was correct
majority_with_actual['Majority_Correct'] = majority_with_actual['Majority_Vote'] == majority_with_actual['actual_age_group']

# Count correct majority votes per class
correct_majority_votes_per_class = majority_with_actual.groupby('actual_age_group')['Majority_Correct'].sum()

print("Correct Majority Votes per Class:")
print(correct_majority_votes_per_class)
# Out:
# Correct Majority Votes per Class:
# actual_age_group
# adult     67
# kitten     8
# senior     4
# Name: Majority_Correct, dtype: int64

# %%
# Calculate the total count and the number of correct predictions for each class
class_stats = majority_with_actual.groupby('actual_age_group').agg(
    total_count=('Majority_Correct', 'size'),  # Total number of cases per class
    correct_count=('Majority_Correct', 'sum')  # Sum of correct predictions per class
).reset_index()

# Calculate accuracy for each class
class_stats['accuracy'] = class_stats['correct_count'] / class_stats['total_count'] * 100

# store for final evaluation 
all_majority_vote_details.append(class_stats)

# Log detailed stats
print("Detailed Class Statistics for Majority Votes:")
print(class_stats)
# Out:
# Detailed Class Statistics for Majority Votes:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult           73             67  91.780822
# 1           kitten           15              8  53.333333
# 2           senior           22              4  18.181818

# %%
# Plot for Detailed Class Statistics for Majority Votes
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Accuracy of Majority Votes by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Detailed Class Statistics

# %%
# Calculate the total count and the number of correct predictions for each class
class_stats = full_results.groupby('actual_age_group').agg(
    total_count=('correct', 'size'),
    correct_count=('correct', 'sum')
).reset_index()

# Calculate accuracy for each class
class_stats['accuracy'] = class_stats['correct_count'] / class_stats['total_count'] * 100

# store for final evaluation 
all_class_stats.append(class_stats)

# Log the detailed stats
print("Detailed Class Statistics:")
print(class_stats)
# Out:
# Detailed Class Statistics:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult          566            427  75.441696
# 1           kitten          120             45  37.500000
# 2           senior          183             50  27.322404

# %%
# Plot for Detailed Class Statistics (Overall)
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Overall Accuracy by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Gender Exploration

# %%
# Group by gender and calculate the total count, correct predictions, and accuracy
gender_stats = full_results.groupby('all_gender').agg(
    count=('cat_id', 'size'),  # Total number of cases per gender
    correct=('correct', 'sum')  # Sum of correct predictions per gender
).reset_index()

# Calculate accuracy for each gender
gender_stats['accuracy'] = (gender_stats['correct'] / gender_stats['count'] * 100).round(2)

# Display the DataFrame
print("Accuracy by Gender:")
print(gender_stats)

# store for final evaluation 
all_gender_stats.append(gender_stats)
# Out:
# Accuracy by Gender:
#   all_gender  count  correct  accuracy
# 0          F    215      117     54.42
# 1          M    349      243     69.63
# 2          X    305      162     53.11

# %%
# Plot for Accuracy by Gender
styled_barplot(gender_stats, 'all_gender', 'accuracy', 
               'Accuracy by Gender', 
               'Gender', 'Accuracy (%)')

# %% [markdown]
# ### Log current total CV Stats

# %%
print("Total Majority Vote Accuracy so far:", all_majority_vote_accuracies)
print("Total Class Statistics so far:\n", all_class_stats)
print("Total Gender Accuracy so far:\n", all_gender_stats)
# Out:
# Total Majority Vote Accuracy so far: [0.7090909090909091, 0.7454545454545455, 0.7272727272727273, 0.7181818181818181]
# Total Class Statistics so far:
#  [  actual_age_group  total_count  correct_count   accuracy
# 0            adult          564            437  77.482270
# 1           kitten          111             39  35.135135
# 2           senior          183             48  26.229508,   actual_age_group  total_count  correct_count   accuracy
# 0            adult          563            431  76.554174
# 1           kitten          116             45  38.793103
# 2           senior          183             49  26.775956,   actual_age_group  total_count  correct_count   accuracy
# 0            adult          564            420  74.468085
# 1           kitten          115             50  43.478261
# 2           senior          183             41  22.404372,   actual_age_group  total_count  correct_count   accuracy
# 0            adult          566            427  75.441696
# 1           kitten          120             45  37.500000
# 2           senior          183             50  27.322404]
# Total Gender Accuracy so far:
#  [  all_gender  count  correct  accuracy
# 0          F    215      130     60.47
# 1          M    353      248     70.25
# 2          X    290      146     50.34,   all_gender  count  correct  accuracy
# 0          F    218      131     60.09
# 1          M    349      243     69.63
# 2          X    295      151     51.19,   all_gender  count  correct  accuracy
# 0          F    219      130     59.36
# 1          M    349      231     66.19
# 2          X    294      150     51.02,   all_gender  count  correct  accuracy
# 0          F    215      117     54.42
# 1          M    349      243     69.63
# 2          X    305      162     53.11]

# %% [markdown]
# # RANDOM SEED 5

# %%
# Set a fixed random seed for reproducibility
random.seed(int(random_seeds[4]))
np.random.seed(int(random_seeds[4]))
tf.random.set_seed(int(random_seeds[4]))

# Load datasets
dataframe = pd.read_csv('/Users/astrid/PycharmProjects/data-aug-and-more/yamnet-tfhub-extraction/yamnet_embeddings_not_looped_april_23.csv')

def assign_age_group(age, age_groups):
    for group_name, age_range in age_groups.items():
        if age_range[0] <= age < age_range[1]:
            return group_name
    return 'Unknown'  # For any age that doesn't fit the defined groups

# Define age groups
age_groups = {
    'kitten': (0, 0.5),
    'adult': (0.5, 12),
    'senior': (12, 20)
}

# Create a new column for the age group
dataframe['age_group'] = dataframe['target'].apply(assign_age_group, age_groups=age_groups)

print(dataframe['age_group'].value_counts())
# Out:
# adult     599
# senior    183
# kitten    176
# Name: age_group, dtype: int64

# %%
# Separate features and labels
X = dataframe.iloc[:, :-4].values  # all columns except the last four

# Encode the 'age_group' column as integers using LabelEncoder
label_encoder = LabelEncoder()
encoded_y = label_encoder.fit_transform(dataframe['age_group'].values)

# Use the encoded labels for splitting and one-hot encoding
y = encoded_y  

# Convert 'cat_id' column to numpy array to be used as groups array for GroupKFold
groups = dataframe['cat_id'].values

# %%
tf.keras.backend.clear_session()

# %% [markdown]
# ## Run Setup

# %%
all_cat_ids = []
all_predicted_age_groups = []
all_actual_age_groups = []
all_gender = []

# Define the StratifiedGroupKFold splitter for 4 fold CV with random shuffling
outer_cv = StratifiedGroupKFold(n_splits=4, shuffle=True, random_state=int(random_seeds[4]))

# unseen test set metrics
unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1 = [], [], [], [], []

outer_fold = 0

# Use the splitter to generate indices for training and testing sets
# Note: GroupShuffleSplit.split returns indices, so we use it to index the arrays
for train_val_idx, test_idx in outer_cv.split(X, y, groups):
    outer_fold += 1
    logger(f"outer_fold {outer_fold}", file=log_file_path)

    # Convert indices back to DataFrame for easy manipulation
    df_train_val = dataframe.iloc[train_val_idx]
    df_test = dataframe.iloc[test_idx]

    ##############################
    # ASSESSING SPLITS BY CAT_ID #
    ##############################
    
    # Get the distribution of groups
    training_validation_group_distribution = df_train_val['cat_id'].value_counts()  
    testing_group_distribution = df_test['cat_id'].value_counts()  
    
    # Log or print the distribution
    logger(f"Train Set Group Distribution:\n{training_validation_group_distribution}", file=log_file_path)
    logger(f"Testing Set Group Distribution:\n{testing_group_distribution}", file=log_file_path)

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val['gender'].value_counts()
    testing_gender_distribution = df_test['gender'].value_counts()
    
    # Log the distribution
    logger(f"Training Set Gender Distribution BEFORE SWAP:\n{training_gender_distribution}", file=log_file_path)
    logger(f"Testing Set Gender Distribution BEFORE SWAP:\n{testing_gender_distribution}", file=log_file_path)

    # Group by 'age_group' and then list unique 'cat_id' within each age group
    unique_cat_ids_per_age_group_train_val = df_train_val.groupby('age_group')['cat_id'].unique()
    unique_cat_ids_per_age_group_test = df_test.groupby('age_group')['cat_id'].unique()
    
    # Log results
    logger(f"Unique Cat IDs per Age Group in Training/Validation Set:\n{unique_cat_ids_per_age_group_train_val}", file=log_file_path)
    logger(f"Unique Cat IDs per Age Group in Testing Set:\n{unique_cat_ids_per_age_group_test}", file=log_file_path)

    # Calculate the count of unique identifiers per age group for training and testing set
    counts_train_val = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_train_val.items()}
    counts_test = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_test.items()}

    # Log the counts of unique identifiers per age group
    logger(f"Count of Unique Cat IDs per Age Group in Training/Validation Set:\n{counts_train_val}", file=log_file_path)
    logger(f"Count of Unique Cat IDs per Age Group in Testing Set:\n{counts_test}", file=log_file_path)

    #######################################################
    # CONTINUE WITH ENSURING VALID AND APPROPRIATE SPLITS #
    #######################################################
    
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    groups_train_val, groups_test = groups[train_val_idx], groups[test_idx]

    # logging identifier splits 
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)

    # check group splits
    check_initial_group_split(groups_train_val, groups_test)

    # Specify the cat_ids that must be in the training/validation set
    specific_cat_ids = ['000A', '046A']
    
    # Perform the swapping operation
    train_val_idx, test_idx = swap_cat_id_instances(dataframe, train_val_idx, test_idx, specific_cat_ids)
    
    # Re-assign the sets based on the updated indices
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    new_groups_train_val, new_groups_test = groups[train_val_idx], groups[test_idx]

    # Find differences for training and test sets
    moved_to_train_val, removed_from_train_val = find_group_differences(groups_train_val, new_groups_train_val)
    moved_to_test, removed_from_test = find_group_differences(groups_test, new_groups_test)
    
    # Display the results
    logger(f"Moved to Training/Validation Set:\n{moved_to_train_val}", file=log_file_path)
    logger(f"Removed from Training/Validation Set:\n{removed_from_train_val}", file=log_file_path)
    logger(f"Moved to Test Set:\n{moved_to_test}", file=log_file_path)
    logger(f"Removed from Test Set\n{removed_from_test}", file=log_file_path)

    # Update X_train_val, X_test, y_train_val, y_test, groups_train_val, groups_test based on updated indices
    X_train_val = X[train_val_idx]
    y_train_val = y[train_val_idx]
    groups_train_val = groups[train_val_idx]
    
    X_test = X[test_idx]
    y_test = y[test_idx]
    groups_test = groups[test_idx]

    # logging identifier splits again after potential swaps
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"AFTER SWAP - Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"AFTER SWAP - Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)
    
    # Verify the lengths are consistent
    logger(f"Length of X_train_val:\n{len(X_train_val)}", file=log_file_path)
    logger(f"Length of y_train_val:\n{len(y_train_val)}", file=log_file_path)
    logger(f"Length of groups_train_val:\n{len(groups_train_val)}", file=log_file_path)

    # Check group splits once more
    check_initial_group_split(groups_train_val, groups_test)

    # Convert the modified indices back to a DataFrame representing the updated df_train_val
    df_train_val_updated = dataframe.iloc[train_val_idx].copy()
    df_test_updated = dataframe.iloc[test_idx].copy()

    ############################
    # LOGGING AGE GROUP SPLITS #
    ############################

    # Get the distribution of age groups of age groups before the update
    training_validation_age_group_distribution = df_train_val['age_group'].value_counts()
    testing_age_group_distribution = df_test['age_group'].value_counts()
    
    # Logthe distribution
    logger(f"Train Age Group Distribution BEFORE SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution BEFORE SWAP:\n{testing_age_group_distribution}", file=log_file_path)

    # Get the distribution of age groups after the update
    training_validation_age_group_distribution = df_train_val_updated['age_group'].value_counts()
    testing_age_group_distribution = df_test_updated['age_group'].value_counts()
    
    # Log the distribution
    logger(f"Train Age Group Distribution AFTER SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution AFTER SWAP:\n{testing_age_group_distribution}", file=log_file_path)
    
    ########################################################
    # TRACKING FINAL CAT_IDs & GENDER AFTER REDISTRIBUTION #
    ########################################################

    # Get the distribution of groups
    training_validation_group_distribution = df_train_val_updated['cat_id'].value_counts()  
    testing_group_distribution = df_test_updated['cat_id'].value_counts()  

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val_updated['gender'].value_counts()
    testing_gender_distribution = df_test_updated['gender'].value_counts()
    
    logger(f"\n Starting training on unseen test set\n", file=log_file_path)

    ###################
    # PREPARING MODEL #
    ###################

    # Calculate the distribution of age groups in y_train_val
    age_group_distribution = Counter(y_train_val)
    print("Age group distribution:", age_group_distribution)

    # EarlyStopping callback: monitor 'loss' instead of 'val_loss' for the test set
    early_stopping = EarlyStopping(
        monitor='loss',  
        min_delta=0.001, 
        patience=30,  
        verbose=1,  
        restore_best_weights=True  
    )

    # One final shuffle to ensure randomness
    outer_shuffle_idx = np.random.permutation(len(X_train_val))
    X_train_val = X_train_val[outer_shuffle_idx]
    y_train_val = y_train_val[outer_shuffle_idx]
    
    # Scale the features
    scaler_full = StandardScaler().fit(X_train_val)
    X_train_full_scaled = scaler_full.transform(X_train_val)
    X_test_scaled = scaler_full.transform(X_test)
    
    # Encode the labels
    y_train_full_encoded = to_categorical(y_train_val)
    y_test_encoded = to_categorical(y_test)

    #######################
    # BUILD & TRAIN MODEL #
    #######################

    optimizers = {
        'Adamax': Adamax(learning_rate=0.00510251984616472)
    }
    
    # Model definition with dynamic number of layers
    model_full = Sequential()
    model_full.add(Dense(480, activation='relu', input_shape=(X_train_full_scaled.shape[1],)))
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.2011047009431978))  
    model_full.add(Dense(256, activation='relu',)) 
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.14956886311951184))  
    model_full.add(Dense(256, activation='relu'))  
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.42291461228250665))  
    model_full.add(Dense(3, activation='softmax'))  
    
    # Use the optimizer from the parameters
    optimizer = optimizers['Adamax']  # optimizer_key from parameters
    
    # Compile the model
    model_full.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    
    # Train the model on the full training set
    history_full = model_full.fit(X_train_full_scaled, y_train_full_encoded, epochs=1500, batch_size=64,
                                  verbose=1, callbacks=[early_stopping])
    
    # Evaluate the model on the held-out test set
    test_loss, test_accuracy = model_full.evaluate(X_test_scaled, y_test_encoded)

    y_test_pred_prob = model_full.predict(X_test_scaled)
    y_test_pred = np.argmax(y_test_pred_prob, axis=1)  
    y_test_true = np.argmax(y_test_encoded, axis=1)    

    ################################
    # LOG MAJORITY VOTE PER CAT_ID #
    ################################

    # Convert numeric predictions back to age group labels
    predicted_age_groups = label_encoder.inverse_transform(y_test_pred)
    actual_labels = label_encoder.inverse_transform(y_test_true)
    
    # Map predictions and actual labels back to cat_ids
    test_results = pd.DataFrame({
        'cat_id': df_test_updated['cat_id'],
        'predicted_age_group': predicted_age_groups,
        'actual_age_group': actual_labels
    })
    
    # Group by cat_id and aggregate predicted age groups
    majority_votes = test_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
    actual_groups = test_results.groupby('cat_id')['actual_age_group'].first()
    
    # Calculate the accuracy of majority voting
    correct_predictions = (majority_votes == actual_groups).sum()
    total_cats = len(actual_groups)
    majority_vote_accuracy = correct_predictions / total_cats
    
    # Log the accuracy of the majority voting
    logger(f"Majority Vote Accuracy for cat_id for this fold: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

    ####################################################
    # COLLECT PREDICTIONS FOR GENDER & CAT_ID ANALYSIS #
    ####################################################

    # Debugging print statements
    print(f'Before appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Extend lists with current fold results
    all_cat_ids.extend(df_test_updated['cat_id'].tolist())
    all_predicted_age_groups.extend(predicted_age_groups)
    all_actual_age_groups.extend(actual_labels)
    all_gender.extend(df_test_updated['gender'].tolist())

    # Debugging print statements
    print(f'After appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Calculate additional metrics
    test_precision = precision_score(y_test_true, y_test_pred, average='macro')  # Use 'macro' for imbalanced datasets
    test_recall = recall_score(y_test_true, y_test_pred, average='macro')
    test_f1 = f1_score(y_test_true, y_test_pred, average='macro')

    # prepare averages of outer metrics
    unseen_f1.append(test_f1)
    unseen_losses.append(test_loss)
    unseen_accuracies.append(test_accuracy)
    unseen_precisions.append(test_precision)
    unseen_recalls.append(test_recall)

    # Print final test results
    logger(f"Final Test Results - Loss: {test_loss}, Accuracy: {test_accuracy}, Precision: {test_precision}, Recall: {test_recall}, F1 Score: {test_f1}", file=log_file_path)

    # Generate the confusion matrix
    cm = confusion_matrix(y_test, y_test_pred)
    logger(f"Confusion Matrix:\n {cm}", file=log_file_path)

# Calculate the overall average metrics
unseen_set_avg_f1 = np.mean(unseen_f1)
unseen_set_avg_loss = np.mean(unseen_losses)
unseen_set_avg_acc = np.mean(unseen_accuracies)
unseen_set_avg_precision = np.mean(unseen_precisions)
unseen_set_avg_recall = np.mean(unseen_recalls)

logger(f"\nFinal Average F1-Score across all UNSEEN TEST sets: {unseen_set_avg_f1}", file=log_file_path)
logger(f"\nFinal Average Loss across all UNSEEN TEST sets: {unseen_set_avg_loss}", file=log_file_path)
logger(f"\nFinal Average Accuracy across all UNSEEN TEST sets: {unseen_set_avg_acc}", file=log_file_path)
logger(f"\nFinal Average Precision across all UNSEEN TEST sets: {unseen_set_avg_precision}", file=log_file_path)
logger(f"\nFinal Average Recall across all UNSEEN TEST sets: {unseen_set_avg_recall}\n", file=log_file_path)

# Append averages to total lists
all_f1.append(unseen_set_avg_f1)
all_losses.append(unseen_set_avg_loss)
all_accuracies.append(unseen_set_avg_acc)
all_precisions.append(unseen_set_avg_precision)
all_recalls.append(unseen_set_avg_recall)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# outer_fold 1
# Train Set Group Distribution:
# 046A    66
# 000A    39
# 002B    35
# 047A    30
# 057A    28
# 074A    25
# 020A    23
# 067A    20
# 029A    17
# 019A    17
# 097A    16
# 059A    16
# 101A    15
# 106A    15
# 001A    14
# 028A    14
# 097B    14
# 042A    14
# 111A    13
# 051A    12
# 116A    12
# 063A    11
# 025A    11
# 036A    11
# 005A    11
# 016A    11
# 068A    11
# 040A    10
# 015A    10
# 051B     9
# 033A     9
# 045A     9
# 013B     8
# 094A     8
# 010A     8
# 095A     8
# 099A     7
# 031A     7
# 050A     7
# 027A     7
# 108A     6
# 023A     6
# 037A     6
# 053A     6
# 007A     6
# 070A     5
# 034A     5
# 075A     5
# 062A     5
# 023B     5
# 021A     5
# 003A     4
# 012A     4
# 009A     4
# 035A     4
# 104A     4
# 052A     4
# 006A     3
# 060A     3
# 014A     3
# 056A     3
# 064A     3
# 058A     3
# 011A     2
# 032A     2
# 054A     2
# 066A     2
# 087A     2
# 061A     2
# 025B     2
# 038A     2
# 069A     2
# 102A     2
# 026C     1
# 115A     1
# 076A     1
# 092A     1
# 019B     1
# 004A     1
# 090A     1
# 091A     1
# 110A     1
# 088A     1
# 048A     1
# 024A     1
# 096A     1
# 043A     1
# 100A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 103A    33
# 000B    20
# 055A    20
# 002A    13
# 039A    12
# 071A    10
# 014B    10
# 072A     9
# 022A     9
# 065A     9
# 117A     7
# 109A     6
# 008A     6
# 044A     5
# 025C     5
# 026A     4
# 105A     4
# 113A     3
# 018A     2
# 093A     2
# 049A     1
# 073A     1
# 041A     1
# 026B     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    298
# X    298
# F    169
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# F    85
# X    57
# M    51
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [028A, 070A, 033A, 020A, 000A, 015A, 053A, 023...
# kitten    [046A, 042A, 110A, 040A, 047A, 045A, 048A, 111...
# senior    [106A, 057A, 090A, 051B, 116A, 051A, 024A, 097...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [002A, 000B, 071A, 026A, 065A, 105A, 018A, 072...
# kitten                       [014B, 109A, 049A, 044A, 041A]
# senior                             [117A, 113A, 055A, 093A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 59, 'kitten': 11, 'senior': 18}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 15, 'kitten': 5, 'senior': 4}
# Unique Training/Validation Group IDs:
# ['000A' '001A' '002B' '003A' '004A' '005A' '006A' '007A' '009A' '010A'
#  '011A' '012A' '013B' '014A' '015A' '016A' '019A' '019B' '020A' '021A'
#  '023A' '023B' '024A' '025A' '025B' '026C' '027A' '028A' '029A' '031A'
#  '032A' '033A' '034A' '035A' '036A' '037A' '038A' '040A' '042A' '043A'
#  '045A' '046A' '047A' '048A' '050A' '051A' '051B' '052A' '053A' '054A'
#  '056A' '057A' '058A' '059A' '060A' '061A' '062A' '063A' '064A' '066A'
#  '067A' '068A' '069A' '070A' '074A' '075A' '076A' '087A' '088A' '090A'
#  '091A' '092A' '094A' '095A' '096A' '097A' '097B' '099A' '100A' '101A'
#  '102A' '104A' '106A' '108A' '110A' '111A' '115A' '116A']
# Unique Test Group IDs:
# ['000B' '002A' '008A' '014B' '018A' '022A' '025C' '026A' '026B' '039A'
#  '041A' '044A' '049A' '055A' '065A' '071A' '072A' '073A' '093A' '103A'
#  '105A' '109A' '113A' '117A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '001A' '002B' '003A' '004A' '005A' '006A' '007A' '009A' '010A'
#  '011A' '012A' '013B' '014A' '015A' '016A' '019A' '019B' '020A' '021A'
#  '023A' '023B' '024A' '025A' '025B' '026C' '027A' '028A' '029A' '031A'
#  '032A' '033A' '034A' '035A' '036A' '037A' '038A' '040A' '042A' '043A'
#  '045A' '046A' '047A' '048A' '050A' '051A' '051B' '052A' '053A' '054A'
#  '056A' '057A' '058A' '059A' '060A' '061A' '062A' '063A' '064A' '066A'
#  '067A' '068A' '069A' '070A' '074A' '075A' '076A' '087A' '088A' '090A'
#  '091A' '092A' '094A' '095A' '096A' '097A' '097B' '099A' '100A' '101A'
#  '102A' '104A' '106A' '108A' '110A' '111A' '115A' '116A']
# AFTER SWAP - Unique Test Group IDs:
# ['000B' '002A' '008A' '014B' '018A' '022A' '025C' '026A' '026B' '039A'
#  '041A' '044A' '049A' '055A' '065A' '071A' '072A' '073A' '093A' '103A'
#  '105A' '109A' '113A' '117A']
# Length of X_train_val:
# 765
# Length of y_train_val:
# 765
# Length of groups_train_val:
# 765
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     461
# kitten    153
# senior    151
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     138
# senior     32
# kitten     23
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     461
# kitten    153
# senior    151
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     138
# senior     32
# kitten     23
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 461, 1: 153, 2: 151})
# Epoch 1/1500
# 12/12 [==============================] - 1s 4ms/step - loss: 1.4959 - accuracy: 0.4693
# Epoch 2/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.7524 - accuracy: 0.7059
# Epoch 3/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4542 - accuracy: 0.8196
# Epoch 4/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3433 - accuracy: 0.8523
# Epoch 5/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2885 - accuracy: 0.8967
# Epoch 6/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2336 - accuracy: 0.9190
# Epoch 7/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1811 - accuracy: 0.9229
# Epoch 8/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1526 - accuracy: 0.9399
# Epoch 9/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1314 - accuracy: 0.9569
# Epoch 10/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1099 - accuracy: 0.9621
# Epoch 11/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1117 - accuracy: 0.9595
# Epoch 12/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1118 - accuracy: 0.9673
# Epoch 13/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0757 - accuracy: 0.9686
# Epoch 14/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0582 - accuracy: 0.9791
# Epoch 15/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0735 - accuracy: 0.9699
# Epoch 16/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0720 - accuracy: 0.9752
# Epoch 17/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0705 - accuracy: 0.9739
# Epoch 18/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0397 - accuracy: 0.9843
# Epoch 19/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0386 - accuracy: 0.9830
# Epoch 20/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0551 - accuracy: 0.9817
# Epoch 21/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0506 - accuracy: 0.9856
# Epoch 22/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0427 - accuracy: 0.9843
# Epoch 23/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0366 - accuracy: 0.9856
# Epoch 24/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0523 - accuracy: 0.9804
# Epoch 25/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0248 - accuracy: 0.9908
# Epoch 26/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0166 - accuracy: 0.9961
# Epoch 27/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0221 - accuracy: 0.9935
# Epoch 28/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0277 - accuracy: 0.9869
# Epoch 29/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0091 - accuracy: 1.0000
# Epoch 30/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0213 - accuracy: 0.9922
# Epoch 31/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0148 - accuracy: 0.9961
# Epoch 32/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0166 - accuracy: 0.9935
# Epoch 33/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0140 - accuracy: 0.9961
# Epoch 34/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0170 - accuracy: 0.9961
# Epoch 35/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0200 - accuracy: 0.9908
# Epoch 36/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0152 - accuracy: 0.9961
# Epoch 37/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0151 - accuracy: 0.9935
# Epoch 38/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0232 - accuracy: 0.9908
# Epoch 39/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0105 - accuracy: 0.9974
# Epoch 40/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0125 - accuracy: 0.9948
# Epoch 41/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0234 - accuracy: 0.9935
# Epoch 42/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0181 - accuracy: 0.9935
# Epoch 43/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0170 - accuracy: 0.9935
# Epoch 44/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0255 - accuracy: 0.9895
# Epoch 45/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0137 - accuracy: 0.9961
# Epoch 46/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0086 - accuracy: 0.9974
# Epoch 47/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0076 - accuracy: 0.9987
# Epoch 48/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0141 - accuracy: 0.9974
# Epoch 49/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0107 - accuracy: 0.9974
# Epoch 50/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0154 - accuracy: 0.9961
# Epoch 51/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0170 - accuracy: 0.9948
# Epoch 52/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0134 - accuracy: 0.9948
# Epoch 53/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0214 - accuracy: 0.9935
# Epoch 54/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0181 - accuracy: 0.9935
# Epoch 55/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0155 - accuracy: 0.9948
# Epoch 56/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0229 - accuracy: 0.9961
# Epoch 57/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0271 - accuracy: 0.9935
# Epoch 58/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0121 - accuracy: 0.9935
# Epoch 59/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0089 - accuracy: 0.9974
# Epoch 60/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0091 - accuracy: 0.9974
# Epoch 61/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0075 - accuracy: 0.9961
# Epoch 62/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0124 - accuracy: 0.9922
# Epoch 63/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0091 - accuracy: 0.9961
# Epoch 64/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0059 - accuracy: 0.9987
# Epoch 65/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0057 - accuracy: 0.9987
# Epoch 66/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0112 - accuracy: 0.9948
# Epoch 67/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0090 - accuracy: 0.9961
# Epoch 68/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0047 - accuracy: 0.9987
# Epoch 69/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0043 - accuracy: 0.9987
# Epoch 70/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 71/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 72/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0061 - accuracy: 0.9974
# Epoch 73/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 74/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0081 - accuracy: 0.9974
# Epoch 75/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0094 - accuracy: 0.9974
# Epoch 76/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0038 - accuracy: 0.9987
# Epoch 77/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0066 - accuracy: 0.9974
# Epoch 78/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0064 - accuracy: 0.9987
# Epoch 79/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 80/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0094 - accuracy: 0.9961
# Epoch 81/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0049 - accuracy: 0.9987
# Epoch 82/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0065 - accuracy: 0.9987
# Epoch 83/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0113 - accuracy: 0.9935
# Epoch 84/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0047 - accuracy: 0.9987
# Epoch 85/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0265 - accuracy: 0.9948
# Epoch 86/1500
# 12/12 [==============================] - 0s 17ms/step - loss: 0.0201 - accuracy: 0.9961
# Epoch 87/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0070 - accuracy: 0.9987
# Epoch 88/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0123 - accuracy: 0.9961
# Epoch 89/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0101 - accuracy: 0.9961
# Epoch 90/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0112 - accuracy: 0.9974
# Epoch 91/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0086 - accuracy: 0.9974
# Epoch 92/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0081 - accuracy: 0.9961
# Epoch 93/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 94/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0054 - accuracy: 0.9974
# Epoch 95/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 96/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0054 - accuracy: 0.9974
# Epoch 97/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 98/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0035 - accuracy: 0.9987
# Epoch 99/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 100/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0063 - accuracy: 0.9987
# Epoch 101/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 102/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 103/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 104/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 105/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 106/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 107/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 108/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0124 - accuracy: 0.9961
# Epoch 109/1500
# 12/12 [==============================] - ETA: 0s - loss: 0.0031 - accuracy: 0.9987    Restoring model weights from the end of the best epoch: 79.
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0031 - accuracy: 0.9987
# Epoch 109: early stopping
# 7/7 [==============================] - 0s 1ms/step - loss: 2.2622 - accuracy: 0.7150
# 7/7 [==============================] - 0s 1ms/step
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Majority Vote Accuracy for cat_id for this fold: 0.67 (16/24)
# Before appending - Cat IDs: 0, Predictions: 0, Actuals: 0, Gender: 0
# After appending - Cat IDs: 193, Predictions: 193, Actuals: 193, Gender: 193
# Final Test Results - Loss: 2.2622222900390625, Accuracy: 0.7150259017944336, Precision: 0.5744489548837376, Recall: 0.5421195652173912, F1 Score: 0.5542087542087543
# Confusion Matrix:
#  [[117  11  10]
#  [ 11  10   2]
#  [ 20   1  11]]
# outer_fold 2
# Train Set Group Distribution:
# 046A    66
# 002B    35
# 103A    33
# 047A    30
# 057A    28
# 020A    23
# 055A    20
# 000B    20
# 019A    17
# 029A    17
# 059A    16
# 097A    16
# 106A    15
# 101A    15
# 028A    14
# 042A    14
# 097B    14
# 001A    14
# 111A    13
# 002A    13
# 039A    12
# 051A    12
# 068A    11
# 036A    11
# 005A    11
# 040A    10
# 015A    10
# 014B    10
# 071A    10
# 022A     9
# 065A     9
# 045A     9
# 051B     9
# 072A     9
# 013B     8
# 095A     8
# 094A     8
# 027A     7
# 117A     7
# 023A     6
# 108A     6
# 008A     6
# 037A     6
# 109A     6
# 053A     6
# 021A     5
# 025C     5
# 070A     5
# 044A     5
# 003A     4
# 105A     4
# 026A     4
# 052A     4
# 009A     4
# 113A     3
# 014A     3
# 064A     3
# 006A     3
# 058A     3
# 093A     2
# 038A     2
# 054A     2
# 102A     2
# 018A     2
# 011A     2
# 069A     2
# 115A     1
# 004A     1
# 026B     1
# 041A     1
# 019B     1
# 110A     1
# 049A     1
# 090A     1
# 073A     1
# 088A     1
# 092A     1
# 091A     1
# 024A     1
# 026C     1
# 048A     1
# 100A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 000A    39
# 074A    25
# 067A    20
# 116A    12
# 063A    11
# 025A    11
# 016A    11
# 033A     9
# 010A     8
# 031A     7
# 050A     7
# 099A     7
# 007A     6
# 062A     5
# 034A     5
# 075A     5
# 023B     5
# 012A     4
# 104A     4
# 035A     4
# 060A     3
# 056A     3
# 061A     2
# 087A     2
# 066A     2
# 032A     2
# 025B     2
# 096A     1
# 043A     1
# 076A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    316
# M    249
# F    169
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# M    100
# F     85
# X     39
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [002A, 028A, 070A, 000B, 071A, 020A, 015A, 026...
# kitten    [046A, 042A, 014B, 110A, 109A, 040A, 047A, 049...
# senior    [117A, 106A, 057A, 090A, 113A, 051B, 051A, 024...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [033A, 000A, 023B, 007A, 034A, 062A, 010A, 074...
# kitten                                         [043A, 050A]
# senior                       [116A, 016A, 061A, 104A, 056A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 51, 'kitten': 14, 'senior': 17}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 23, 'kitten': 2, 'senior': 5}
# Unique Training/Validation Group IDs:
# ['000B' '001A' '002A' '002B' '003A' '004A' '005A' '006A' '008A' '009A'
#  '011A' '013B' '014A' '014B' '015A' '018A' '019A' '019B' '020A' '021A'
#  '022A' '023A' '024A' '025C' '026A' '026B' '026C' '027A' '028A' '029A'
#  '036A' '037A' '038A' '039A' '040A' '041A' '042A' '044A' '045A' '046A'
#  '047A' '048A' '049A' '051A' '051B' '052A' '053A' '054A' '055A' '057A'
#  '058A' '059A' '064A' '065A' '068A' '069A' '070A' '071A' '072A' '073A'
#  '088A' '090A' '091A' '092A' '093A' '094A' '095A' '097A' '097B' '100A'
#  '101A' '102A' '103A' '105A' '106A' '108A' '109A' '110A' '111A' '113A'
#  '115A' '117A']
# Unique Test Group IDs:
# ['000A' '007A' '010A' '012A' '016A' '023B' '025A' '025B' '031A' '032A'
#  '033A' '034A' '035A' '043A' '050A' '056A' '060A' '061A' '062A' '063A'
#  '066A' '067A' '074A' '075A' '076A' '087A' '096A' '099A' '104A' '116A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'000A'}
# Removed from Training/Validation Set:
# {'038A'}
# Moved to Test Set:
# {'038A'}
# Removed from Test Set
# {'000A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '004A' '005A' '006A' '008A'
#  '009A' '011A' '013B' '014A' '014B' '015A' '018A' '019A' '019B' '020A'
#  '021A' '022A' '023A' '024A' '025C' '026A' '026B' '026C' '027A' '028A'
#  '029A' '036A' '037A' '039A' '040A' '041A' '042A' '044A' '045A' '046A'
#  '047A' '048A' '049A' '051A' '051B' '052A' '053A' '054A' '055A' '057A'
#  '058A' '059A' '064A' '065A' '068A' '069A' '070A' '071A' '072A' '073A'
#  '088A' '090A' '091A' '092A' '093A' '094A' '095A' '097A' '097B' '100A'
#  '101A' '102A' '103A' '105A' '106A' '108A' '109A' '110A' '111A' '113A'
#  '115A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['007A' '010A' '012A' '016A' '023B' '025A' '025B' '031A' '032A' '033A'
#  '034A' '035A' '038A' '043A' '050A' '056A' '060A' '061A' '062A' '063A'
#  '066A' '067A' '074A' '075A' '076A' '087A' '096A' '099A' '104A' '116A']
# Length of X_train_val:
# 771
# Length of y_train_val:
# 771
# Length of groups_train_val:
# 771
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     415
# kitten    168
# senior    151
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     184
# senior     32
# kitten      8
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     452
# kitten    168
# senior    151
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     147
# senior     32
# kitten      8
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 452, 1: 168, 2: 151})
# Epoch 1/1500
# 13/13 [==============================] - 1s 4ms/step - loss: 1.2720 - accuracy: 0.5344
# Epoch 2/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.6887 - accuracy: 0.7419
# Epoch 3/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.4833 - accuracy: 0.8054
# Epoch 4/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3860 - accuracy: 0.8612
# Epoch 5/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3239 - accuracy: 0.8807
# Epoch 6/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2888 - accuracy: 0.8975
# Epoch 7/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2610 - accuracy: 0.9040
# Epoch 8/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2261 - accuracy: 0.9157
# Epoch 9/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2343 - accuracy: 0.9196
# Epoch 10/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1913 - accuracy: 0.9313
# Epoch 11/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1890 - accuracy: 0.9274
# Epoch 12/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.1850 - accuracy: 0.9261
# Epoch 13/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1521 - accuracy: 0.9494
# Epoch 14/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1355 - accuracy: 0.9507
# Epoch 15/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1274 - accuracy: 0.9429
# Epoch 16/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1372 - accuracy: 0.9481
# Epoch 17/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1398 - accuracy: 0.9546
# Epoch 18/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.1286 - accuracy: 0.9572
# Epoch 19/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.1129 - accuracy: 0.9676
# Epoch 20/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1389 - accuracy: 0.9533
# Epoch 21/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.1133 - accuracy: 0.9637
# Epoch 22/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1207 - accuracy: 0.9494
# Epoch 23/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0968 - accuracy: 0.9598
# Epoch 24/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1124 - accuracy: 0.9598
# Epoch 25/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1188 - accuracy: 0.9611
# Epoch 26/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.1053 - accuracy: 0.9650
# Epoch 27/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1215 - accuracy: 0.9598
# Epoch 28/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1103 - accuracy: 0.9650
# Epoch 29/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1028 - accuracy: 0.9663
# Epoch 30/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1181 - accuracy: 0.9559
# Epoch 31/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.1045 - accuracy: 0.9650
# Epoch 32/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1121 - accuracy: 0.9611
# Epoch 33/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0990 - accuracy: 0.9676
# Epoch 34/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1041 - accuracy: 0.9676
# Epoch 35/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0833 - accuracy: 0.9689
# Epoch 36/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.1171 - accuracy: 0.9546
# Epoch 37/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1072 - accuracy: 0.9663
# Epoch 38/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.1248 - accuracy: 0.9546
# Epoch 39/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0956 - accuracy: 0.9728
# Epoch 40/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1151 - accuracy: 0.9533
# Epoch 41/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.1123 - accuracy: 0.9624
# Epoch 42/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0869 - accuracy: 0.9676
# Epoch 43/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0841 - accuracy: 0.9728
# Epoch 44/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.
1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0627 - accuracy: 0.9857
# Epoch 108/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0680 - accuracy: 0.9792
# Epoch 109/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0621 - accuracy: 0.9780
# Epoch 110/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0597 - accuracy: 0.9792
# Epoch 111/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0570 - accuracy: 0.9767
# Epoch 112/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0504 - accuracy: 0.9831
# Epoch 113/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0707 - accuracy: 0.9767
# Epoch 114/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0444 - accuracy: 0.9870
# Epoch 115/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0527 - accuracy: 0.9844
# Epoch 116/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0520 - accuracy: 0.9818
# Epoch 117/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0555 - accuracy: 0.9831
# Epoch 118/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0557 - accuracy: 0.9883
# Epoch 119/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0503 - accuracy: 0.9844
# Epoch 120/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0534 - accuracy: 0.9792
# Epoch 121/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0310 - accuracy: 0.9896
# Epoch 122/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0703 - accuracy: 0.9754
# Epoch 123/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0527 - accuracy: 0.9767
# Epoch 124/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0540 - accuracy: 0.9844
# Epoch 125/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0544 - accuracy: 0.9792
# Epoch 126/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0467 - accuracy: 0.9909
# Epoch 127/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0349 - accuracy: 0.9870
# Epoch 128/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0528 - accuracy: 0.9767
# Epoch 129/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0407 - accuracy: 0.9896
# Epoch 130/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0645 - accuracy: 0.9754
# Epoch 131/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0381 - accuracy: 0.9870
# Epoch 132/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0741 - accuracy: 0.9676
# Epoch 133/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0484 - accuracy: 0.9818
# Epoch 134/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0342 - accuracy: 0.9896
# Epoch 135/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0527 - accuracy: 0.9780
# Epoch 136/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0508 - accuracy: 0.9767
# Epoch 137/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0460 - accuracy: 0.9857
# Epoch 138/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0573 - accuracy: 0.9818
# Epoch 139/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0602 - accuracy: 0.9857
# Epoch 140/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0541 - accuracy: 0.9792
# Epoch 141/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0395 - accuracy: 0.9857
# Epoch 142/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0560 - accuracy: 0.9767
# Epoch 143/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0508 - accuracy: 0.9896
# Epoch 144/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0446 - accuracy: 0.9857
# Epoch 145/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0576 - accuracy: 0.9754
# Epoch 146/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0715 - accuracy: 0.9767
# Epoch 147/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0444 - accuracy: 0.9844
# Epoch 148/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0439 - accuracy: 0.9870
# Epoch 149/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0422 - accuracy: 0.9883
# Epoch 150/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0460 - accuracy: 0.9896
# Epoch 151/1500
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0650 - accuracy: 0.9740Restoring model weights from the end of the best epoch: 121.
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0653 - accuracy: 0.9741
# Epoch 151: early stopping
# 6/6 [==============================] - 0s 1ms/step - loss: 2.0883 - accuracy: 0.7166
# 6/6 [==============================] - 0s 1ms/step
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Majority Vote Accuracy for cat_id for this fold: 0.77 (23/30)
# Before appending - Cat IDs: 193, Predictions: 193, Actuals: 193, Gender: 193
# After appending - Cat IDs: 380, Predictions: 380, Actuals: 380, Gender: 380
# Final Test Results - Loss: 2.088289260864258, Accuracy: 0.7165775299072266, Precision: 0.5750625168964585, Recall: 0.6067885487528345, F1 Score: 0.5289671361502347
# Confusion Matrix:
#  [[116  26   5]
#  [  3   5   0]
#  [ 18   1  13]]
# outer_fold 3
# Train Set Group Distribution:
# 046A    66
# 000A    39
# 002B    35
# 103A    33
# 074A    25
# 000B    20
# 055A    20
# 067A    20
# 059A    16
# 101A    15
# 106A    15
# 001A    14
# 097B    14
# 042A    14
# 002A    13
# 111A    13
# 116A    12
# 039A    12
# 025A    11
# 016A    11
# 063A    11
# 040A    10
# 071A    10
# 014B    10
# 065A     9
# 072A     9
# 051B     9
# 022A     9
# 033A     9
# 095A     8
# 010A     8
# 050A     7
# 099A     7
# 027A     7
# 031A     7
# 117A     7
# 007A     6
# 109A     6
# 037A     6
# 108A     6
# 008A     6
# 075A     5
# 044A     5
# 025C     5
# 023B     5
# 070A     5
# 034A     5
# 062A     5
# 003A     4
# 012A     4
# 052A     4
# 104A     4
# 026A     4
# 105A     4
# 035A     4
# 064A     3
# 113A     3
# 056A     3
# 006A     3
# 060A     3
# 087A     2
# 018A     2
# 066A     2
# 061A     2
# 093A     2
# 054A     2
# 025B     2
# 032A     2
# 076A     1
# 004A     1
# 041A     1
# 024A     1
# 026C     1
# 073A     1
# 096A     1
# 043A     1
# 110A     1
# 048A     1
# 090A     1
# 049A     1
# 026B     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 047A    30
# 057A    28
# 020A    23
# 029A    17
# 019A    17
# 097A    16
# 028A    14
# 051A    12
# 036A    11
# 068A    11
# 005A    11
# 015A    10
# 045A     9
# 094A     8
# 013B     8
# 023A     6
# 053A     6
# 021A     5
# 009A     4
# 058A     3
# 014A     3
# 069A     2
# 038A     2
# 102A     2
# 011A     2
# 019B     1
# 115A     1
# 091A     1
# 088A     1
# 092A     1
# 100A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    263
# X    226
# F    203
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    129
# M     86
# F     51
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [002A, 070A, 033A, 000B, 071A, 000A, 026A, 065...
# kitten    [046A, 042A, 014B, 110A, 109A, 040A, 049A, 048...
# senior    [117A, 106A, 090A, 113A, 051B, 116A, 024A, 059...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [028A, 020A, 015A, 053A, 038A, 068A, 021A, 013...
# kitten                                   [047A, 045A, 115A]
# senior                 [057A, 051A, 097A, 094A, 058A, 011A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 52, 'kitten': 13, 'senior': 16}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 22, 'kitten': 3, 'senior': 6}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '004A' '006A' '007A' '008A'
#  '010A' '012A' '014B' '016A' '018A' '022A' '023B' '024A' '025A' '025B'
#  '025C' '026A' '026B' '026C' '027A' '031A' '032A' '033A' '034A' '035A'
#  '037A' '039A' '040A' '041A' '042A' '043A' '044A' '046A' '048A' '049A'
#  '050A' '051B' '052A' '054A' '055A' '056A' '059A' '060A' '061A' '062A'
#  '063A' '064A' '065A' '066A' '067A' '070A' '071A' '072A' '073A' '074A'
#  '075A' '076A' '087A' '090A' '093A' '095A' '096A' '097B' '099A' '101A'
#  '103A' '104A' '105A' '106A' '108A' '109A' '110A' '111A' '113A' '116A'
#  '117A']
# Unique Test Group IDs:
# ['005A' '009A' '011A' '013B' '014A' '015A' '019A' '019B' '020A' '021A'
#  '023A' '028A' '029A' '036A' '038A' '045A' '047A' '051A' '053A' '057A'
#  '058A' '068A' '069A' '088A' '091A' '092A' '094A' '097A' '100A' '102A'
#  '115A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '004A' '006A' '007A' '008A'
#  '010A' '012A' '014B' '016A' '018A' '022A' '023B' '024A' '025A' '025B'
#  '025C' '026A' '026B' '026C' '027A' '031A' '032A' '033A' '034A' '035A'
#  '037A' '039A' '040A' '041A' '042A' '043A' '044A' '046A' '048A' '049A'
#  '050A' '051B' '052A' '054A' '055A' '056A' '059A' '060A' '061A' '062A'
#  '063A' '064A' '065A' '066A' '067A' '070A' '071A' '072A' '073A' '074A'
#  '075A' '076A' '087A' '090A' '093A' '095A' '096A' '097B' '099A' '101A'
#  '103A' '104A' '105A' '106A' '108A' '109A' '110A' '111A' '113A' '116A'
#  '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['005A' '009A' '011A' '013B' '014A' '015A' '019A' '019B' '020A' '021A'
#  '023A' '028A' '029A' '036A' '038A' '045A' '047A' '051A' '053A' '057A'
#  '058A' '068A' '069A' '088A' '091A' '092A' '094A' '097A' '100A' '102A'
#  '115A']
# Length of X_train_val:
# 692
# Length of y_train_val:
# 692
# Length of groups_train_val:
# 692
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     442
# kitten    136
# senior    114
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     157
# senior     69
# kitten     40
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     442
# kitten    136
# senior    114
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     157
# senior     69
# kitten     40
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 442, 1: 136, 2: 114})
# Epoch 1/1500
# 11/11 [==============================] - 1s 4ms/step - loss: 1.5835 - accuracy: 0.4841
# Epoch 2/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.8033 - accuracy: 0.6922
# Epoch 3/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.5192 - accuracy: 0.8020
# Epoch 4/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.3685 - accuracy: 0.8642
# Epoch 5/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.3145 - accuracy: 0.8902
# Epoch 6/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.2793 - accuracy: 0.9061
# Epoch 7/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.2221 - accuracy: 0.9176
# Epoch 8/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.1934 - accuracy: 0.9306
# Epoch 9/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.1464 - accuracy: 0.9480
# Epoch 10/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1134 - accuracy: 0.9624
# Epoch 11/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1084 - accuracy: 0.9668
# Epoch 12/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0793 - accuracy: 0.9783
# Epoch 13/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0749 - accuracy: 0.9740
# Epoch 14/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0744 - accuracy: 0.9725
# Epoch 15/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0624 - accuracy: 0.9754
# Epoch 16/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0699 - accuracy: 0.9769
# Epoch 17/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0498 - accuracy: 0.9827
# Epoch 18/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0562 - accuracy: 0.9769
# Epoch 19/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0358 - accuracy: 0.9899
# Epoch 20/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0324 - accuracy: 0.9942
# Epoch 21/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0260 - accuracy: 0.9957
# Epoch 22/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0261 - accuracy: 0.9971
# Epoch 23/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0187 - accuracy: 0.9971
# Epoch 24/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0406 - accuracy: 0.9899
# Epoch 25/1500
# 11/11 [==============================] - 0s 20ms/step - loss: 0.0265 - accuracy: 0.9899
# Epoch 26/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0417 - accuracy: 0.9812
# Epoch 27/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0268 - accuracy: 0.9913
# Epoch 28/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0271 - accuracy: 0.9899
# Epoch 29/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0161 - accuracy: 0.9971
# Epoch 30/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0149 - accuracy: 0.9957
# Epoch 31/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0200 - accuracy: 0.9942
# Epoch 32/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0243 - accuracy: 0.9942
# Epoch 33/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0129 - accuracy: 0.9957
# Epoch 34/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0121 - accuracy: 0.9986
# Epoch 35/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0151 - accuracy: 0.9957
# Epoch 36/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0310 - accuracy: 0.9928
# Epoch 37/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0127 - accuracy: 0.9971
# Epoch 38/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0460 - accuracy: 0.9870
# Epoch 39/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0178 - accuracy: 0.9928
# Epoch 40/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0198 - accuracy: 0.9928
# Epoch 41/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0219 - accuracy: 0.9928
# Epoch 42/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0120 - accuracy: 0.9971
# Epoch 43/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0167 - accuracy: 0.9942
# Epoch 44/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0112 - accuracy: 0.9986
# Epoch 45/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0178 - accuracy: 0.9942
# Epoch 46/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0111 - accuracy: 0.9986
# Epoch 47/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0195 - accuracy: 0.9942
# Epoch 48/1500
# ...
# 065A     9
# 045A     9
# 022A     9
# 072A     9
# 010A     8
# 013B     8
# 094A     8
# 099A     7
# 117A     7
# 050A     7
# 031A     7
# 053A     6
# 109A     6
# 008A     6
# 007A     6
# 023A     6
# 044A     5
# 075A     5
# 062A     5
# 025C     5
# 021A     5
# 023B     5
# 034A     5
# 105A     4
# 026A     4
# 035A     4
# 104A     4
# 009A     4
# 012A     4
# 060A     3
# 014A     3
# 058A     3
# 113A     3
# 056A     3
# 011A     2
# 066A     2
# 087A     2
# 069A     2
# 061A     2
# 093A     2
# 032A     2
# 102A     2
# 018A     2
# 038A     2
# 025B     2
# 041A     1
# 115A     1
# 076A     1
# 026B     1
# 092A     1
# 019B     1
# 073A     1
# 088A     1
# 096A     1
# 043A     1
# 049A     1
# 091A     1
# 100A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 046A    66
# 002B    35
# 059A    16
# 101A    15
# 106A    15
# 097B    14
# 042A    14
# 001A    14
# 111A    13
# 040A    10
# 051B     9
# 095A     8
# 027A     7
# 037A     6
# 108A     6
# 070A     5
# 003A     4
# 052A     4
# 006A     3
# 064A     3
# 054A     2
# 048A     1
# 024A     1
# 090A     1
# 110A     1
# 026C     1
# 004A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    237
# X    225
# F    221
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    130
# M    112
# F     33
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [002A, 028A, 033A, 000B, 071A, 020A, 000A, 015...
# kitten    [014B, 109A, 047A, 049A, 045A, 044A, 043A, 050...
# senior    [117A, 057A, 113A, 116A, 051A, 097A, 094A, 055...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [070A, 026C, 001A, 002B, 006A, 101A, 097B, 003...
# kitten                 [046A, 042A, 110A, 040A, 048A, 111A]
# senior           [106A, 090A, 051B, 024A, 059A, 054A, 108A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 60, 'kitten': 10, 'senior': 15}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 14, 'kitten': 6, 'senior': 7}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '002A' '005A' '007A' '008A' '009A' '010A' '011A' '012A'
#  '013B' '014A' '014B' '015A' '016A' '018A' '019A' '019B' '020A' '021A'
#  '022A' '023A' '023B' '025A' '025B' '025C' '026A' '026B' '028A' '029A'
#  '031A' '032A' '033A' '034A' '035A' '036A' '038A' '039A' '041A' '043A'
#  '044A' '045A' '047A' '049A' '050A' '051A' '053A' '055A' '056A' '057A'
#  '058A' '060A' '061A' '062A' '063A' '065A' '066A' '067A' '068A' '069A'
#  '071A' '072A' '073A' '074A' '075A' '076A' '087A' '088A' '091A' '092A'
#  '093A' '094A' '096A' '097A' '099A' '100A' '102A' '103A' '104A' '105A'
#  '109A' '113A' '115A' '116A' '117A']
# Unique Test Group IDs:
# ['001A' '002B' '003A' '004A' '006A' '024A' '026C' '027A' '037A' '040A'
#  '042A' '046A' '048A' '051B' '052A' '054A' '059A' '064A' '070A' '090A'
#  '095A' '097B' '101A' '106A' '108A' '110A' '111A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'046A'}
# Removed from Training/Validation Set:
# {'043A'}
# Moved to Test Set:
# {'043A'}
# Removed from Test Set
# {'046A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '002A' '005A' '007A' '008A' '009A' '010A' '011A' '012A'
#  '013B' '014A' '014B' '015A' '016A' '018A' '019A' '019B' '020A' '021A'
#  '022A' '023A' '023B' '025A' '025B' '025C' '026A' '026B' '028A' '029A'
#  '031A' '032A' '033A' '034A' '035A' '036A' '038A' '039A' '041A' '044A'
#  '045A' '046A' '047A' '049A' '050A' '051A' '053A' '055A' '056A' '057A'
#  '058A' '060A' '061A' '062A' '063A' '065A' '066A' '067A' '068A' '069A'
#  '071A' '072A' '073A' '074A' '075A' '076A' '087A' '088A' '091A' '092A'
#  '093A' '094A' '096A' '097A' '099A' '100A' '102A' '103A' '104A' '105A'
#  '109A' '113A' '115A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['001A' '002B' '003A' '004A' '006A' '024A' '026C' '027A' '037A' '040A'
#  '042A' '043A' '048A' '051B' '052A' '054A' '059A' '064A' '070A' '090A'
#  '095A' '097B' '101A' '106A' '108A' '110A' '111A']
# Length of X_train_val:
# 748
# Length of y_train_val:
# 748
# Length of groups_train_val:
# 748
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     479
# senior    133
# kitten     71
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     120
# kitten    105
# senior     50
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     479
# kitten    136
# senior    133
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     120
# senior     50
# kitten     40
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 479, 1: 136, 2: 133})
# Epoch 1/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 1.3047 - accuracy: 0.5241
# Epoch 2/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.6689 - accuracy: 0.7500
# Epoch 3/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4724 - accuracy: 0.8316
# Epoch 4/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3838 - accuracy: 0.8596
# Epoch 5/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2856 - accuracy: 0.8904
# Epoch 6/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2179 - accuracy: 0.9171
# Epoch 7/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1925 - accuracy: 0.9291
# Epoch 8/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1498 - accuracy: 0.9559
# Epoch 9/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1162 - accuracy: 0.9679
# Epoch 10/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1047 - accuracy: 0.9693
# Epoch 11/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0964 - accuracy: 0.9706
# Epoch 12/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0918 - accuracy: 0.9652
# Epoch 13/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0654 - accuracy: 0.9813
# Epoch 14/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0539 - accuracy: 0.9840
# Epoch 15/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0654 - accuracy: 0.9786
# Epoch 16/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0507 - accuracy: 0.9853
# Epoch 17/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0762 - accuracy: 0.9706
# Epoch 18/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0384 - accuracy: 0.9920
# Epoch 19/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0619 - accuracy: 0.9813
# Epoch 20/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0327 - accuracy: 0.9920
# Epoch 21/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0506 - accuracy: 0.9853
# Epoch 22/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0597 - accuracy: 0.9773
# Epoch 23/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0373 - accuracy: 0.9853
# Epoch 24/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0457 - accuracy: 0.9866
# Epoch 25/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0231 - accuracy: 0.9960
# Epoch 26/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0420 - accuracy: 0.9893
# Epoch 27/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0198 - accuracy: 0.9947
# Epoch 28/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0211 - accuracy: 0.9947
# Epoch 29/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0115 - accuracy: 0.9960
# Epoch 30/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0114 - accuracy: 0.9973
# Epoch 31/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0097 - accuracy: 0.9987
# Epoch 32/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0125 - accuracy: 0.9987
# Epoch 33/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0223 - accuracy: 0.9933
# Epoch 34/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0156 - accuracy: 0.9987
# Epoch 35/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0073 - accuracy: 0.9960
# Epoch 36/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0151 - accuracy: 0.9947
# Epoch 37/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0123 - accuracy: 0.9960
# Epoch 38/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0140 - accuracy: 0.9960
# Epoch 39/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0129 - accuracy: 0.9933
# Epoch 40/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0219 - accuracy: 0.9973
# Epoch 41/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0258 - accuracy: 0.9906
# Epoch 42/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0257 - accuracy: 0.9906
# Epoch 43/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0224 - accuracy: 0.9933
# Epoch 44/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0085 - accuracy: 1.0000
# Epoch 45/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0042 - accuracy: 1.0000
# Epoch 46/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0052 - accuracy: 1.0000
# Epoch 47/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0092 - accuracy: 0.9973
# Epoch 48/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0119 - accuracy: 0.9987
# Epoch 49/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0264 - accuracy: 0.9893
# Epoch 50/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0064 - accuracy: 1.0000
# Epoch 51/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0099 - accuracy: 0.9960
# Epoch 52/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0159 - accuracy: 0.9933
# Epoch 53/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0153 - accuracy: 0.9960
# Epoch 54/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0151 - accuracy: 0.9947
# Epoch 55/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0243 - accuracy: 0.9906
# Epoch 56/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0151 - accuracy: 0.9960
# Epoch 57/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0290 - accuracy: 0.9920
# Epoch 58/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0137 - accuracy: 0.9960
# Epoch 59/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0057 - accuracy: 1.0000
# Epoch 60/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0114 - accuracy: 0.9960
# Epoch 61/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0161 - accuracy: 0.9933
# Epoch 62/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0115 - accuracy: 0.9960
# Epoch 63/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0198 - accuracy: 0.9947
# Epoch 64/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0116 - accuracy: 0.9973
# Epoch 65/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0065 - accuracy: 0.9987
# Epoch 66/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0140 - accuracy: 0.9920
# Epoch 67/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0171 - accuracy: 0.9947
# Epoch 68/1500
# 12/12 [==============================] - 0s 17ms/step - loss: 0.0095 - accuracy: 0.9947
# Epoch 69/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0135 - accuracy: 0.9973
# Epoch 70/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0044 - accuracy: 1.0000
# Epoch 71/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0084 - accuracy: 0.9960
# Epoch 72/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 73/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0146 - accuracy: 0.9947
# Epoch 74/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0042 - accuracy: 0.9987
# Epoch 75/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0086 - accuracy: 0.9960
# Epoch 76/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0083 - accuracy: 0.9987
# Epoch 77/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 78/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0090 - accuracy: 0.9947
# Epoch 79/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0084 - accuracy: 0.9987
# Epoch 80/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0121 - accuracy: 0.9960
# Epoch 81/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0094 - accuracy: 0.9973
# Epoch 82/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0251 - accuracy: 0.9973
# Epoch 83/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0084 - accuracy: 0.9960
# Epoch 84/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0060 - accuracy: 0.9987
# Epoch 85/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0027 - accuracy: 0.9987
# Epoch 86/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0036 - accuracy: 0.9987
# Epoch 87/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0093 - accuracy: 0.9960
# Epoch 88/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0042 - accuracy: 0.9987
# Epoch 89/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0148 - accuracy: 0.9973
# Epoch 90/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0049 - accuracy: 0.9973
# Epoch 91/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0186 - accuracy: 0.9947
# Epoch 92/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0098 - accuracy: 0.9960
# Epoch 93/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0066 - accuracy: 0.9960
# Epoch 94/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0172 - accuracy: 0.9960
# Epoch 95/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0172 - accuracy: 0.9960
# Epoch 96/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0067 - accuracy: 0.9960
# Epoch 97/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0102 - accuracy: 0.9973
# Epoch 98/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 99/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0138 - accuracy: 0.9933
# Epoch 100/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0253 - accuracy: 0.9893
# Epoch 101/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0092 - accuracy: 0.9947
# Epoch 102/1500
#  1/12 [=>............................] - ETA: 0s - loss: 4.1824e-04 - accuracy: 1.0000Restoring model weights from the end of the best epoch: 72.
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0087 - accuracy: 0.9960
# Epoch 102: early stopping
# 7/7 [==============================] - 0s 1ms/step - loss: 3.2309 - accuracy: 0.6048
# 7/7 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.67 (18/27)
# Before appending - Cat IDs: 646, Predictions: 646, Actuals: 646, Gender: 646
# After appending - Cat IDs: 856, Predictions: 856, Actuals: 856, Gender: 856
# Final Test Results - Loss: 3.230875253677368, Accuracy: 0.6047618985176086, Precision: 0.5700965049556599, Recall: 0.5261111111111111, F1 Score: 0.540768355786996
# Confusion Matrix:
#  [[91  9 20]
#  [20 20  0]
#  [31  3 16]]
#
# Final Average F1-Score across all UNSEEN TEST sets: 0

# Total Gender Accuracy so far:
#  [  all_gender  count  correct  accuracy
# 0          F    215      130     60.47
# 1          M    353      248     70.25
# 2          X    290      146     50.34,   all_gender  count  correct  accuracy
# 0          F    218      131     60.09
# 1          M    349      243     69.63
# 2          X    295      151     51.19,   all_gender  count  correct  accuracy
# 0          F    219      130     59.36
# 1          M    349      231     66.19
# 2          X    294      150     51.02,   all_gender  count  correct  accuracy
# 0          F    215      117     54.42
# 1          M    349      243     69.63
# 2          X    305      162     53.11,   all_gender  count  correct  accuracy
# 0          F    217      143     65.90
# 1          M    349      259     74.21
# 2          X    290      145     50.00]

# %% [markdown]
# # --------------

# %% [markdown]
# # Total Final Results & Analysis

# %%
# Count unique cat_id per age group 
unique_cats_per_age_group = dataframe.groupby('age_group')['cat_id'].nunique()

# Display the counts
print("Unique cat_id counts in original dataframe:", unique_cats_per_age_group)
# Out:
# Unique cat_id counts in original dataframe: age_group
# adult     74
# kitten    16
# senior    22
# Name: cat_id, dtype: int64

# %% [markdown]
# ## Metrics

# %%
# Calculate overall metrics
overall_avg_loss = np.mean(all_losses)
overall_avg_acc = np.mean(all_accuracies)
overall_avg_precision = np.mean(all_precisions)
overall_avg_recall = np.mean(all_recalls)
overall_avg_f1 = np.mean(all_f1)

print("Overall Average Metrics:")
print("Loss:", overall_avg_loss)
print("Accuracy:", overall_avg_acc)
print("Precision:", overall_avg_precision)
print("Recall:", overall_avg_recall)
print("F1 Score:", overall_avg_f1)
# Out:
# Overall Average Metrics:
# Loss: 5.053787362575531
# Accuracy: 0.6107836440205574
# Precision: 0.5036550301982198
# Recall: 0.5028377728844248
# F1 Score: 0.4760253141063952

# %% [markdown]
# ## Majority Votes

# %%
# Average of majority vote accuracies
average_majority_vote_accuracy = np.mean(all_majority_vote_accuracies)
print("Average Majority Vote Accuracy:", average_majority_vote_accuracy)
# Out:
# Average Majority Vote Accuracy: 0.7181818181818181

# %%
# Concatenate all class stats DataFrames and calculate the mean of accuracies
total_majority_vote_details = pd.concat(all_majority_vote_details)
average_majority_vote_details = total_majority_vote_details.groupby('actual_age_group').agg({
    'total_count': 'sum', 
    'correct_count': 'sum' 
}).reset_index()
average_majority_vote_details['accuracy'] = (average_majority_vote_details['correct_count'] / average_majority_vote_details['total_count']) * 100

print("Average Class Statistics:")
print(average_majority_vote_details)
# Out:
# Average Class Statistics:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult          365            341  93.424658
# 1           kitten           75             39  52.000000
# 2           senior          110             15  13.636364

# %%
# Plot for Detailed Class Statistics for Majority Votes
styled_barplot(average_majority_vote_details, 'actual_age_group', 'accuracy', 
               'Accuracy of Majority Votes by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Detailed Class Statistics

# %%
# Concatenate all class stats DataFrames and calculate the mean of accuracies
total_class_stats = pd.concat(all_class_stats)
average_class_stats = total_class_stats.groupby('actual_age_group').agg({
    'total_count': 'sum',  
    'correct_count': 'sum' 
}).reset_index()
average_class_stats['accuracy'] = (average_class_stats['correct_count'] / average_class_stats['total_count']) * 100

print("Average Class Statistics:")
print(average_class_stats)
# Out:
# Average Class Statistics:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult         2819           2164  76.764810
# 1           kitten          573            221  38.568935
# 2           senior          915            244  26.666667

# %%
# Plot for Detailed Class Statistics (Overall)
styled_barplot(average_class_stats, 'actual_age_group', 'accuracy', 
               'Overall Accuracy by Age Group', 
               'Age Group', 'Accuracy (%)')

# %%
# Concatenate all gender stats DataFrames and calculate the mean of accuracies
total_gender_stats = pd.concat(all_gender_stats)
average_gender_stats = total_gender_stats.groupby('all_gender').agg({
    'count': 'sum',  
    'correct': 'sum'  
}).reset_index()
average_gender_stats['accuracy'] = (average_gender_stats['correct'] / average_gender_stats['count']) * 100

print("Average Gender Accuracy:")
print(average_gender_stats)
# Out:
# Average Gender Accuracy:
#   all_gender  count  correct   accuracy
# 0          F   1084      651  60.055351
# 1          M   1749     1224  69.982847
# 2          X   1474      754  51.153324

# %%
# Plot for Accuracy by Gender
styled_barplot(total_gender_stats, 'all_gender', 'accuracy', 
               'Accuracy by Gender', 
               'Gender', 'Accuracy (%)')

# %% [markdown]
# # Visualisations

# %%
# Plotting all metrics
metrics_across_seeds = plot_all_metrics(all_losses, all_accuracies, all_precisions, all_recalls, all_f1, "Seeds", "Seed Number")

# %%
# Calculate the standard deviation for each metric
std_loss = np.std(all_losses)
std_accuracy = np.std(all_accuracies)
std_precision = np.std(all_precisions)
std_recall = np.std(all_recalls)
std_f1 = np.std(all_f1)

print("Standard Deviations:")
print(f"Loss: {std_loss}")
print(f"Accuracy: {std_accuracy}")
print(f"Precision: {std_precision}")
print(f"Recall: {std_recall}")
print(f"F1 Score: {std_f1}")
# Out:
# Standard Deviations:
# Loss: 2.1483549833291034
# Accuracy: 0.020401278753624554
# Precision: 0.0248362206772946
# Recall: 0.02621310885753747
# F1 Score: 0.019482597546529867

# %%
# Calculate the interquartile range for each metric
iqr_loss = np.percentile(all_losses, 75) - np.percentile(all_losses, 25)
iqr_accuracy = np.percentile(all_accuracies, 75) - np.percentile(all_accuracies, 25)
iqr_precision = np.percentile(all_precisions, 75) - np.percentile(all_precisions, 25)
iqr_recall = np.percentile(all_recalls, 75) - np.percentile(all_recalls, 25)
iqr_f1 = np.percentile(all_f1, 75) - np.percentile(all_f1, 25)

print("Interquartile Ranges:")
print(f"Loss: {iqr_loss}")
print(f"Accuracy: {iqr_accuracy}")
print(f"Precision: {iqr_precision}")
print(f"Recall: {iqr_recall}")
print(f"F1 Score: {iqr_f1}")
# Out:
# Interquartile Ranges:
# Loss: 0.9237641096115112
# Accuracy: 0.018812701106071472
# Precision: 0.00586433756832716
# Recall: 0.03567043275469872
# F1 Score: 0.010374765475852976

# %% [markdown]
# ## Display the seed folds results together

# %%
# Create a figure with subplots
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(18, 12))  

# Flatten the axes array for easier indexing
axes = axes.flatten()

def plot_metrics_on_axes(ax, losses, accuracies, precisions, recalls, f1, title):
    ax.plot(range(1, len(losses)+1), losses, marker='o', color='blue', label='Loss')
    ax.plot(range(1, len(accuracies)+1), accuracies, marker='o', color='green', label='Accuracy')
    ax.plot(range(1, len(precisions)+1), precisions, marker='o', color='red', label='Precision')
    ax.plot(range(1, len(recalls)+1), recalls, marker='o', color='purple', label='Recall')
    ax.plot(range(1, len(f1)+1), f1, marker='o', color='orange', label='F1 Score')
    ax.set_xticks([1, 2, 3, 4])  # Set x-axis ticks to full integers
    ax.set_title(title)
    ax.set_xlabel('Fold Number')
    ax.set_ylabel('Metric Value')
    ax.legend()
    ax.grid(True)

# Plot onto each axes object
plot_metrics_on_axes(axes[0], *seed_1_folds_values, "Seed 1 Metrics")
plot_metrics_on_axes(axes[1], *seed_2_folds_values, "Seed 2 Metrics")
plot_metrics_on_axes(axes[2], *seed_3_folds_values, "Seed 3 Metrics")
plot_metrics_on_axes(axes[3], *seed_4_folds_values, "Seed 4 Metrics")
plot_metrics_on_axes(axes[4], *seed_5_folds_values, "Seed 5 Metrics")

# Hide the unused subplot 
for ax in axes[5:]:
    ax.set_visible(False)

# Adjust layout
plt.tight_layout()
plt.show()
