# %% [markdown]
# # YAMNet Multi Seed Validation
# #### 5 Random (but reproducible) seeds are selected for 5 different runs of train/test
# #### Models have been optimised and verified on validation sets thoroughly, running a final train/test evaluation here
# #### The setup:
#
# - 4 fold StratifiedGroupKFold for stratification and ensuring each cat_id group only appears in one set at a time
# - Final scores averaged over the 4 folds
# - For each seed run we will explore the cat_id predictions through majority voting
# - For each run we will explore the potential impact of gender
# - Includes visualisations & analysis
#
# The dataset is highly unbalanced.

# %%
# Standard imports
import numpy as np
import pandas as pd
import random
from datetime import datetime
from collections import Counter

# Sklearn imports
from sklearn.model_selection import train_test_split, GroupShuffleSplit, GroupKFold, StratifiedGroupKFold
from sklearn.preprocessing import LabelEncoder, MinMaxScaler, RobustScaler, StandardScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report
from sklearn.utils.class_weight import compute_class_weight
from sklearn.inspection import permutation_importance

# Imbalanced-learn import
from imblearn.over_sampling import SMOTE

# TensorFlow and Keras imports
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Dropout, Input, BatchNormalization, concatenate
from tensorflow.keras.optimizers import Adam, RMSprop, SGD, Adamax, AdamW
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import to_categorical
from keras.regularizers import l1, l2, L1L2

# Optuna import
import optuna

# Visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns

from IPython.display import display

# MixUp imports
import tensorflow_probability as tfp

# %%
# Set an initial seed for reproducibility
np.random.seed(42)  

# Generate a list of 5 random seeds
random_seeds = np.random.randint(0, 10000, size=5)
print("Random Seeds:", random_seeds)
# Out:
# Random Seeds: [7270  860 5390 5191 5734]

# %% [markdown]
# #### TOTAL RESULTS ACROSS SEED INITIATION

# %%
# Lists to collect statistics across all CVs
all_losses, all_accuracies, all_precisions, all_recalls, all_f1 = [], [], [], [], []
all_majority_vote_accuracies, all_majority_vote_details, all_class_stats, all_gender_stats  = [], [], [], []

# %% [markdown]
# ## Define Functions

# %%
def check_initial_group_split(groups_train, groups_test):
    """
    Check if any group is present in both the train and test sets.

    Parameters:
    - groups_train: Array of group identifiers for the train set
    - groups_test: Array of group identifiers for the test set

    Returns:
    - Prints out any groups found in both sets and the count of such groups
    """
    train_groups = set(groups_train)
    test_groups = set(groups_test)
    common_groups = train_groups.intersection(test_groups)

    if common_groups:
        print(f"Warning: Found {len(common_groups)} common groups in both train/validation and test sets: {common_groups}")
    else:
        print("No common groups found between train and test sets.")

# %%
# Function to perform the swaps based on cat_id, ensuring swaps within the same age_group
def swap_cat_id_instances(dataframe, train_val_idx, test_idx, specific_cat_ids):
    for cat_id in specific_cat_ids:
        # Check if the specific cat_id is not in the training set
        if cat_id not in dataframe.iloc[train_val_idx]['cat_id'].values:
            # Get the age_group of this cat_id
            age_group = dataframe[dataframe['cat_id'] == cat_id]['age_group'].iloc[0]
                
            # Find a different cat_id within the same age_group in the train set that is not in the test set
            other_cat_ids_in_age_group = dataframe[(dataframe['age_group'] == age_group) & 
                                                   (dataframe['cat_id'] != cat_id) &
                                                   (~dataframe['cat_id'].isin(dataframe.iloc[test_idx]['cat_id']))]['cat_id'].unique()
            
            # Choose one other cat_id for swapping
            if len(other_cat_ids_in_age_group) > 0:
                other_cat_id = np.random.choice(other_cat_ids_in_age_group)

                # Find all instances of the other_cat_id in the train set
                other_cat_id_train_val_indices = train_val_idx[dataframe.iloc[train_val_idx]['cat_id'] == other_cat_id]
                
                # Find all instances of the specific cat_id in the test set
                cat_id_test_indices = test_idx[dataframe.iloc[test_idx]['cat_id'] == cat_id]
                
                # Swap the indices
                train_val_idx = np.setdiff1d(train_val_idx, other_cat_id_train_val_indices, assume_unique=True)
                test_idx = np.setdiff1d(test_idx, cat_id_test_indices, assume_unique=True)

                train_val_idx = np.concatenate((train_val_idx, cat_id_test_indices))
                test_idx = np.concatenate((test_idx, other_cat_id_train_val_indices))
            else:
                print(f"No alternative cat_id found in the same age_group as {cat_id} for swapping.")
                
    return train_val_idx, test_idx

# %%
# Function to identify differences in groups
def find_group_differences(original, new):
    # Convert numpy arrays to sets for easy difference computation
    original_set = set(original)
    new_set = set(new)
    # Find differences
    moved_to_new = new_set - original_set
    moved_to_original = original_set - new_set
    return moved_to_new, moved_to_original

# %%
# create custom logger function for local logs & stored in a .txt
def logger(message, file=None):
    print(message)
    if file is not None:
        with open(file, "a") as log_file:
            log_file.write(message + "\n")

log_file_path = "multi-seed-val-D13.txt"

# %%
# Set the aesthetic style of the plots
sns.set(style="whitegrid", palette="deep")

# Define a custom color palette
colors = ["#6aabd1", "#b6e2d3", "#dac292"] 
sns.set_palette(sns.color_palette(colors))

# Function to create bar plots with enhanced style
def styled_barplot(data, x, y, title, xlabel, ylabel):
    plt.figure(figsize=(8, 4))
    bar_plot = sns.barplot(x=x, y=y, data=data, errorbar=None, width=0.5)  
    plt.title(title, fontsize=16, fontweight='bold', color="#333333")
    plt.xlabel(xlabel, fontsize=14, fontweight='bold', color="#333333")
    plt.ylabel(ylabel, fontsize=14, fontweight='bold', color="#333333")
    plt.xticks(fontsize=12, color="#333333")
    plt.yticks(fontsize=12, color="#333333")
    plt.ylim(0, 100) 

    # Adding value labels on top of each bar
    for p in bar_plot.patches:
        height = p.get_height()
        # Annotate the height value on the bar
        bar_plot.annotate(f'{height:.1f}', 
                          (p.get_x() + p.get_width() / 2., height), 
                          ha='center', va='center', 
                          xytext=(0, 9), 
                          textcoords='offset points', fontsize=12, color="#333333")

    plt.show()

# %%
def plot_all_metrics(losses, accuracies, precisions, recalls, f1, metrics_across, x_axis_label):
    fig, ax = plt.subplots(figsize=(12, 8))
    seeds = range(1, len(losses) + 1)

    ax.plot(seeds, losses, marker='o', color='blue', label='Loss')
    ax.plot(seeds, accuracies, marker='o', color='green', label='Accuracy')
    ax.plot(seeds, precisions, marker='o', color='red', label='Precision')
    ax.plot(seeds, recalls, marker='o', color='purple', label='Recall')
    ax.plot(seeds, f1, marker='o', color='orange', label='F1 Score')

    ax.set_title(f'Metrics Across {metrics_across}')
    ax.set_xlabel(x_axis_label)
    ax.set_ylabel('Metric Value')
    ax.set_xticks(seeds)
    ax.legend()
    ax.grid(True)

    return fig

# %%
def mixup_data(x, y, alpha=0.2):
    if alpha > 0:
        # Create a Beta distribution and sample lambda values from it
        beta_distribution = tfp.distributions.Beta(alpha, alpha)
        lam = beta_distribution.sample([tf.shape(x)[0]])
    else:
        lam = 1

    lam = tf.maximum(lam, 1 - lam)  # Ensure lambda is always between 0.5 and 1
    index = tf.random.shuffle(tf.range(tf.shape(x)[0]))

    x_mix = lam[:, tf.newaxis] * x + (1 - lam[:, tf.newaxis]) * tf.gather(x, index)
    y_mix = lam[:, tf.newaxis] * y + (1 - lam[:, tf.newaxis]) * tf.gather(y, index)

    return x_mix, y_mix

# %% [markdown]
# # RANDOM SEED 1

# %% [markdown]
# ## Prepare Data

# %%
# Set a fixed random seed for reproducibility
random.seed(int(random_seeds[0])) 
np.random.seed(int(random_seeds[0]))
tf.random.set_seed(int(random_seeds[0]))

# Load datasets
dataframe = pd.read_csv('/Users/astrid/PycharmProjects/data-aug-and-more/yamnet-tfhub-extraction/yamnet_embeddings_looped_april_23.csv')

def assign_age_group(age, age_groups):
    for group_name, age_range in age_groups.items():
        if age_range[0] <= age < age_range[1]:
            return group_name
    return 'Unknown'  # For any age that doesn't fit the defined groups

# Define age groups
age_groups = {
    'kitten': (0, 0.5),
    'adult': (0.5, 12),
    'senior': (12, 20)
}

# Create a new column for the age group
dataframe['age_group'] = dataframe['target'].apply(assign_age_group, age_groups=age_groups)

print(dataframe['age_group'].value_counts())
# Out:
# adult     606
# senior    186
# kitten    176
# Name: age_group, dtype: int64

# %%
# Separate features and labels
X = dataframe.iloc[:, :-4].values  # all columns except the last four

# Encode the 'age_group' column as integers using LabelEncoder
label_encoder = LabelEncoder()
encoded_y = label_encoder.fit_transform(dataframe['age_group'].values)

# Use the encoded labels for splitting and one-hot encoding
y = encoded_y  

# Convert 'cat_id' column to numpy array to be used as groups array for GroupKFold
groups = dataframe['cat_id'].values

# %%
tf.keras.backend.clear_session()

# %% [markdown]
# ## Run Setup

# %%
all_cat_ids = []
all_predicted_age_groups = []
all_actual_age_groups = []
all_gender = []

# Define the StratifiedGroupKFold splitter for 4 fold CV with random shuffling
outer_cv = StratifiedGroupKFold(n_splits=4, shuffle=True, random_state=int(random_seeds[0]))

# unseen test set metrics
unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1 = [], [], [], [], []

outer_fold = 0

# Use the splitter to generate indices for training and testing sets
# Note: GroupShuffleSplit.split returns indices, so we use it to index the arrays
for train_val_idx, test_idx in outer_cv.split(X, y, groups):
    outer_fold += 1
    logger(f"outer_fold {outer_fold}", file=log_file_path)

    # Convert indices back to DataFrame for easy manipulation
    df_train_val = dataframe.iloc[train_val_idx]
    df_test = dataframe.iloc[test_idx]

    ##############################
    # ASSESSING SPLITS BY CAT_ID #
    ##############################
    
    # Get the distribution of groups
    training_validation_group_distribution = df_train_val['cat_id'].value_counts()  
    testing_group_distribution = df_test['cat_id'].value_counts()  
    
    # Log or print the distribution
    logger(f"Train Set Group Distribution:\n{training_validation_group_distribution}", file=log_file_path)
    logger(f"Testing Set Group Distribution:\n{testing_group_distribution}", file=log_file_path)

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val['gender'].value_counts()
    testing_gender_distribution = df_test['gender'].value_counts()
    
    # Log the distribution
    logger(f"Training Set Gender Distribution BEFORE SWAP:\n{training_gender_distribution}", file=log_file_path)
    logger(f"Testing Set Gender Distribution BEFORE SWAP:\n{testing_gender_distribution}", file=log_file_path)

    # Group by 'age_group' and then list unique 'cat_id' within each age group
    unique_cat_ids_per_age_group_train_val = df_train_val.groupby('age_group')['cat_id'].unique()
    unique_cat_ids_per_age_group_test = df_test.groupby('age_group')['cat_id'].unique()
    
    # Log results
    logger(f"Unique Cat IDs per Age Group in Training/Validation Set:\n{unique_cat_ids_per_age_group_train_val}", file=log_file_path)
    logger(f"Unique Cat IDs per Age Group in Testing Set:\n{unique_cat_ids_per_age_group_test}", file=log_file_path)

    # Calculate the count of unique identifiers per age group for training and testing set
    counts_train_val = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_train_val.items()}
    counts_test = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_test.items()}

    # Log the counts of unique identifiers per age group
    logger(f"Count of Unique Cat IDs per Age Group in Training/Validation Set:\n{counts_train_val}", file=log_file_path)
    logger(f"Count of Unique Cat IDs per Age Group in Testing Set:\n{counts_test}", file=log_file_path)

    #######################################################
    # CONTINUE WITH ENSURING VALID AND APPROPRIATE SPLITS #
    #######################################################
    
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    groups_train_val, groups_test = groups[train_val_idx], groups[test_idx]

    # logging identifier splits 
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)

    # check group splits
    check_initial_group_split(groups_train_val, groups_test)

    # Specify the cat_ids that must be in the training/validation set
    specific_cat_ids = ['000A', '046A']
    
    # Perform the swapping operation
    train_val_idx, test_idx = swap_cat_id_instances(dataframe, train_val_idx, test_idx, specific_cat_ids)
    
    # Re-assign the sets based on the updated indices
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    new_groups_train_val, new_groups_test = groups[train_val_idx], groups[test_idx]

    # Find differences for training and test sets
    moved_to_train_val, removed_from_train_val = find_group_differences(groups_train_val, new_groups_train_val)
    moved_to_test, removed_from_test = find_group_differences(groups_test, new_groups_test)
    
    # Display the results
    logger(f"Moved to Training/Validation Set:\n{moved_to_train_val}", file=log_file_path)
    logger(f"Removed from Training/Validation Set:\n{removed_from_train_val}", file=log_file_path)
    logger(f"Moved to Test Set:\n{moved_to_test}", file=log_file_path)
    logger(f"Removed from Test Set\n{removed_from_test}", file=log_file_path)

    # Update X_train_val, X_test, y_train_val, y_test, groups_train_val, groups_test based on updated indices
    X_train_val = X[train_val_idx]
    y_train_val = y[train_val_idx]
    groups_train_val = groups[train_val_idx]
    
    X_test = X[test_idx]
    y_test = y[test_idx]
    groups_test = groups[test_idx]

    # logging identifier splits again after potential swaps
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"AFTER SWAP - Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"AFTER SWAP - Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)
    
    # Verify the lengths are consistent
    logger(f"Length of X_train_val:\n{len(X_train_val)}", file=log_file_path)
    logger(f"Length of y_train_val:\n{len(y_train_val)}", file=log_file_path)
    logger(f"Length of groups_train_val:\n{len(groups_train_val)}", file=log_file_path)

    # Check group splits once more
    check_initial_group_split(groups_train_val, groups_test)

    # Convert the modified indices back to a DataFrame representing the updated df_train_val
    df_train_val_updated = dataframe.iloc[train_val_idx].copy()
    df_test_updated = dataframe.iloc[test_idx].copy()

    ############################
    # LOGGING AGE GROUP SPLITS #
    ############################

    # Get the distribution of age groups of age groups before the update
    training_validation_age_group_distribution = df_train_val['age_group'].value_counts()
    testing_age_group_distribution = df_test['age_group'].value_counts()
    
    # Logthe distribution
    logger(f"Train Age Group Distribution BEFORE SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution BEFORE SWAP:\n{testing_age_group_distribution}", file=log_file_path)

    # Get the distribution of age groups after the update
    training_validation_age_group_distribution = df_train_val_updated['age_group'].value_counts()
    testing_age_group_distribution = df_test_updated['age_group'].value_counts()
    
    # Log the distribution
    logger(f"Train Age Group Distribution AFTER SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution AFTER SWAP:\n{testing_age_group_distribution}", file=log_file_path)
    
    ########################################################
    # TRACKING FINAL CAT_IDs & GENDER AFTER REDISTRIBUTION #
    ########################################################

    # Get the distribution of groups
    training_validation_group_distribution = df_train_val_updated['cat_id'].value_counts()  
    testing_group_distribution = df_test_updated['cat_id'].value_counts()  

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val_updated['gender'].value_counts()
    testing_gender_distribution = df_test_updated['gender'].value_counts()
    
    logger(f"\n Starting training on unseen test set\n", file=log_file_path)

    ###################
    # PREPARING MODEL #
    ###################

    # Calculate the distribution of age groups in y_train_val
    age_group_distribution = Counter(y_train_val)
    print("Age group distribution:", age_group_distribution)

    # EarlyStopping callback: monitor 'loss' instead of 'val_loss' for the test set
    early_stopping = EarlyStopping(
        monitor='loss',  
        min_delta=0.001, 
        patience=30,  
        verbose=1,  
        restore_best_weights=True  
    )

    # One final shuffle to ensure randomness
    outer_shuffle_idx = np.random.permutation(len(X_train_val))
    X_train_val = X_train_val[outer_shuffle_idx]
    y_train_val = y_train_val[outer_shuffle_idx]
    
    # Scale the features
    scaler_full = StandardScaler().fit(X_train_val)
    X_train_full_scaled = scaler_full.transform(X_train_val)
    X_test_scaled = scaler_full.transform(X_test)
    
    # Convert features to TensorFlow tensors
    X_train_full_scaled = tf.convert_to_tensor(X_train_full_scaled, dtype=tf.float32)
    X_test_scaled = tf.convert_to_tensor(X_test_scaled, dtype=tf.float32)
    
    # One-hot encode labels before mixup
    y_train_full_encoded = to_categorical(y_train_val)
    y_test_encoded = to_categorical(y_test)
    
    # Convert labels to TensorFlow tensors
    y_train_full_encoded = tf.convert_to_tensor(y_train_full_encoded, dtype=tf.float32)
    
    # Apply Mixup
    X_train_mix_outer, y_train_mix_outer = mixup_data(X_train_full_scaled, y_train_full_encoded, alpha=0.2)
    
    #######################
    # BUILD & TRAIN MODEL #
    #######################

    optimizers = {
        'Adamax': Adamax(learning_rate=0.00510251984616472)
    }
    
    # Model definition with dynamic number of layers
    model_full = Sequential()
    model_full.add(Dense(480, activation='relu', input_shape=(X_train_full_scaled.shape[1],)))
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.2011047009431978))  
    model_full.add(Dense(256, activation='relu',)) 
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.14956886311951184))  
    model_full.add(Dense(256, activation='relu'))  
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.42291461228250665))  
    model_full.add(Dense(3, activation='softmax'))  
    
    # Use the optimizer from the parameters
    optimizer = optimizers['Adamax']  # optimizer_key from parameters
    
    # Compile the model
    model_full.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    
    # Train the model on the full training set
    history_full = model_full.fit(X_train_mix_outer, y_train_mix_outer, epochs=1500, batch_size=64,
                                  verbose=1, callbacks=[early_stopping])
    
    # Evaluate the model on the held-out test set
    test_loss, test_accuracy = model_full.evaluate(X_test_scaled, y_test_encoded)

    y_test_pred_prob = model_full.predict(X_test_scaled)
    y_test_pred = np.argmax(y_test_pred_prob, axis=1)  
    y_test_true = np.argmax(y_test_encoded, axis=1)    

    ################################
    # LOG MAJORITY VOTE PER CAT_ID #
    ################################

    # Convert numeric predictions back to age group labels
    predicted_age_groups = label_encoder.inverse_transform(y_test_pred)
    actual_labels = label_encoder.inverse_transform(y_test_true)
    
    # Map predictions and actual labels back to cat_ids
    test_results = pd.DataFrame({
        'cat_id': df_test_updated['cat_id'],
        'predicted_age_group': predicted_age_groups,
        'actual_age_group': actual_labels
    })
    
    # Group by cat_id and aggregate predicted age groups
    majority_votes = test_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
    actual_groups = test_results.groupby('cat_id')['actual_age_group'].first()
    
    # Calculate the accuracy of majority voting
    correct_predictions = (majority_votes == actual_groups).sum()
    total_cats = len(actual_groups)
    majority_vote_accuracy = correct_predictions / total_cats
    
    # Log the accuracy of the majority voting
    logger(f"Majority Vote Accuracy for cat_id for this fold: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

    ####################################################
    # COLLECT PREDICTIONS FOR GENDER & CAT_ID ANALYSIS #
    ####################################################

    # Debugging print statements
    print(f'Before appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Extend lists with current fold results
    all_cat_ids.extend(df_test_updated['cat_id'].tolist())
    all_predicted_age_groups.extend(predicted_age_groups)
    all_actual_age_groups.extend(actual_labels)
    all_gender.extend(df_test_updated['gender'].tolist())

    # Debugging print statements
    print(f'After appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Calculate additional metrics
    test_precision = precision_score(y_test_true, y_test_pred, average='macro')  # Use 'macro' for imbalanced datasets
    test_recall = recall_score(y_test_true, y_test_pred, average='macro')
    test_f1 = f1_score(y_test_true, y_test_pred, average='macro')

    # prepare averages of outer metrics
    unseen_f1.append(test_f1)
    unseen_losses.append(test_loss)
    unseen_accuracies.append(test_accuracy)
    unseen_precisions.append(test_precision)
    unseen_recalls.append(test_recall)

    # Print final test results
    logger(f"Final Test Results - Loss: {test_loss}, Accuracy: {test_accuracy}, Precision: {test_precision}, Recall: {test_recall}, F1 Score: {test_f1}", file=log_file_path)

    # Generate the confusion matrix
    cm = confusion_matrix(y_test, y_test_pred)
    logger(f"Confusion Matrix:\n {cm}", file=log_file_path)

# Calculate the overall average metrics
unseen_set_avg_f1 = np.mean(unseen_f1)
unseen_set_avg_loss = np.mean(unseen_losses)
unseen_set_avg_acc = np.mean(unseen_accuracies)
unseen_set_avg_precision = np.mean(unseen_precisions)
unseen_set_avg_recall = np.mean(unseen_recalls)

logger(f"\nFinal Average F1-Score across all UNSEEN TEST sets: {unseen_set_avg_f1}", file=log_file_path)
logger(f"\nFinal Average Loss across all UNSEEN TEST sets: {unseen_set_avg_loss}", file=log_file_path)
logger(f"\nFinal Average Accuracy across all UNSEEN TEST sets: {unseen_set_avg_acc}", file=log_file_path)
logger(f"\nFinal Average Precision across all UNSEEN TEST sets: {unseen_set_avg_precision}", file=log_file_path)
logger(f"\nFinal Average Recall across all UNSEEN TEST sets: {unseen_set_avg_recall}\n", file=log_file_path)

# Append averages to total lists
all_f1.append(unseen_set_avg_f1)
all_losses.append(unseen_set_avg_loss)
all_accuracies.append(unseen_set_avg_acc)
all_precisions.append(unseen_set_avg_precision)
all_recalls.append(unseen_set_avg_recall)
# Out:
# outer_fold 1
# Train Set Group Distribution:
# 000A    39
# 002B    36
# 103A    33
# 047A    30
# 057A    28
#         ..
# 049A     1
# 026C     1
# 073A     1
# 091A     1
# 100A     1
# Name: cat_id, Length: 87, dtype: int64
# Testing Set Group Distribution:
# 046A    66
# 055A    20
# 059A    18
# 116A    12
# 063A    11
# 072A     9
# 051B     9
# 045A     9
# 013B     8
# 053A     7
# 050A     7
# 117A     7
# 108A     6
# 008A     6
# 025C     6
# 070A     5
# 060A     3
# 058A     3
# 011A     3
# 025B     2
# 069A     2
# 093A     2
# 088A     1
# 024A     1
# 041A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    315
# X    245
# F    184
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    110
# F     73
# M     41
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [002A, 028A, 033A, 000B, 071A, 020A, 000A, 015...
# kitten    [042A, 014B, 110A, 109A, 040A, 047A, 049A, 048...
# senior    [106A, 057A, 090A, 113A, 051A, 097A, 094A, 016...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [070A, 053A, 072A, 013B, 063A, 069A, 060A, 088...
# kitten                             [046A, 045A, 050A, 041A]
# senior    [117A, 051B, 116A, 024A, 059A, 055A, 058A, 108...
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 63, 'kitten': 12, 'senior': 12}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 11, 'kitten': 4, 'senior': 10}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '004A' '005A' '006A' '007A'
#  '009A' '010A' '012A' '014A' '014B' '015A' '016A' '018A' '019A' '019B'
#  '020A' '021A' '022A' '023A' '023B' '025A' '026A' '026B' '026C' '027A'
#  '028A' '029A' '031A' '032A' '033A' '034A' '035A' '036A' '037A' '038A'
#  '039A' '040A' '042A' '043A' '044A' '047A' '048A' '049A' '051A' '052A'
#  '054A' '056A' '057A' '061A' '062A' '064A' '065A' '066A' '067A' '068A'
#  '071A' '073A' '074A' '075A' '076A' '087A' '090A' '091A' '092A' '094A'
#  '095A' '096A' '097A' '097B' '099A' '100A' '101A' '102A' '103A' '104A'
#  '105A' '106A' '109A' '110A' '111A' '113A' '115A']
# Unique Test Group IDs:
# ['008A' '011A' '013B' '024A' '025B' '025C' '041A' '045A' '046A' '050A'
#  '051B' '053A' '055A' '058A' '059A' '060A' '063A' '069A' '070A' '072A'
#  '088A' '093A' '108A' '116A' '117A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'046A'}
# Removed from Training/Validation Set:
# {'110A'}
# Moved to Test Set:
# {'110A'}
# Removed from Test Set
# {'046A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '004A' '005A' '006A' '007A'
#  '009A' '010A' '012A' '014A' '014B' '015A' '016A' '018A' '019A' '019B'
#  '020A' '021A' '022A' '023A' '023B' '025A' '026A' '026B' '026C' '027A'
#  '028A' '029A' '031A' '032A' '033A' '034A' '035A' '036A' '037A' '038A'
#  '039A' '040A' '042A' '043A' '044A' '046A' '047A' '048A' '049A' '051A'
#  '052A' '054A' '056A' '057A' '061A' '062A' '064A' '065A' '066A' '067A'
#  '068A' '071A' '073A' '074A' '075A' '076A' '087A' '090A' '091A' '092A'
#  '094A' '095A' '096A' '097A' '097B' '099A' '100A' '101A' '102A' '103A'
#  '104A' '105A' '106A' '109A' '111A' '113A' '115A']
# AFTER SWAP - Unique Test Group IDs:
# ['008A' '011A' '013B' '024A' '025B' '025C' '041A' '045A' '050A' '051B'
#  '053A' '055A' '058A' '059A' '060A' '063A' '069A' '070A' '072A' '088A'
#  '093A' '108A' '110A' '116A' '117A']
# Length of X_train_val:
# 809
# Length of y_train_val:
# 809
# Length of groups_train_val:
# 809
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     546
# senior    105
# kitten     93
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# kitten    83
# senior    81
# adult     60
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     546
# kitten    158
# senior    105
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# senior    81
# adult     60
# kitten    18
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 546, 1: 158, 2: 105})
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Epoch 1/1500
# 13/13 [==============================] - 1s 8ms/step - loss: 1.4006 - accuracy: 0.5328
# Epoch 2/1500
# 13/13 [==============================] - 0s 8ms/step - loss: 0.7585 - accuracy: 0.7157
# Epoch 3/1500
# 13/13 [==============================] - 0s 7ms/step - loss: 0.5392 - accuracy: 0.8257
# Epoch 4/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3999 - accuracy: 0.8801
# Epoch 5/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.4015 - accuracy: 0.8665
# Epoch 6/1500
# 13/13 [==============================] - 0s 7ms/step - loss: 0.3362 - accuracy: 0.9098
# Epoch 7/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3215 - accuracy: 0.9283
# Epoch 8/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2990 - accuracy: 0.9283
# Epoch 9/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3070 - accuracy: 0.9147
# Epoch 10/1500
# 13/13 [==============================] - 0s 7ms/step - loss: 0.2784 - accuracy: 0.9333
# Epoch 11/1500
# 13/13 [==============================] - 0s 8ms/step - loss: 0.2361 - accuracy: 0.9543
# Epoch 12/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2586 - accuracy: 0.9530
# Epoch 13/1500
# 13/13 [==============================] - 0s 7ms/step - loss: 0.2677 - accuracy: 0.9382
# Epoch 14/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2459 - accuracy: 0.9431
# Epoch 15/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2368 - accuracy: 0.9543
# Epoch 16/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2397 - accuracy: 0.9431
# Epoch 17/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2219 - accuracy: 0.9654
# Epoch 18/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2214 - accuracy: 0.9679
# Epoch 19/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2112 - accuracy: 0.9567
# Epoch 20/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1989 - accuracy: 0.9543
# Epoch 21/1500
# 13/13 [==============================] - 0s 7ms/step - loss: 0.2168 - accuracy: 0.9642
# Epoch 22/1500
# 13/13 [==============================] - 0s 8ms/step - loss: 0.2089 - accuracy: 0.9530
# Epoch 23/1500
# 13/13 [==============================] - 0s 8ms/step - loss: 0.1989 - accuracy: 0.9629
# Epoch 24/1500
# 13/13 [==============================] - 0s 9ms/step - loss: 0.1907 - accuracy: 0.9567
# Epoch 25/1500
# 13/13 [==============================] - 0s 7ms/step - loss: 0.2034 - accuracy: 0.9604
# Epoch 26/1500
# 13/13 [==============================] - 0s 7ms/step - loss: 0.1939 - accuracy: 0.9617
# Epoch 27/1500
# 13/13 [==============================] - 0s 7ms/step - loss: 0.
# 13/13 [==============================] - 0s 8ms/step - loss: 0.1249 - accuracy: 0.9815
# Epoch 217/1500
# 13/13 [==============================] - 0s 7ms/step - loss: 0.1267 - accuracy: 0.9802
# Epoch 218/1500
# 13/13 [==============================] - 0s 8ms/step - loss: 0.1258 - accuracy: 0.9827
# Epoch 219/1500
# 13/13 [==============================] - 0s 7ms/step - loss: 0.1255 - accuracy: 0.9802
# Epoch 220/1500
# 13/13 [==============================] - 0s 8ms/step - loss: 0.1276 - accuracy: 0.9765
# Epoch 221/1500
# 13/13 [==============================] - 0s 7ms/step - loss: 0.1248 - accuracy: 0.9852
# Epoch 222/1500
# 13/13 [==============================] - 0s 7ms/step - loss: 0.1264 - accuracy: 0.9864
# Epoch 223/1500
# 13/13 [==============================] - 0s 7ms/step - loss: 0.1230 - accuracy: 0.9864
# Epoch 224/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1239 - accuracy: 0.9802
# Epoch 225/1500
# 13/13 [==============================] - 0s 7ms/step - loss: 0.1232 - accuracy: 0.9839
# Epoch 226/1500
# 13/13 [==============================] - 0s 7ms/step - loss: 0.1285 - accuracy: 0.9691
# Epoch 227/1500
# 13/13 [==============================] - 0s 7ms/step - loss: 0.1282 - accuracy: 0.9827
# Epoch 228/1500
# 13/13 [==============================] - 0s 8ms/step - loss: 0.1255 - accuracy: 0.9802
# Epoch 229/1500
# 13/13 [==============================] - 0s 8ms/step - loss: 0.1231 - accuracy: 0.9802
# Epoch 230/1500
# 13/13 [==============================] - 0s 7ms/step - loss: 0.1232 - accuracy: 0.9864
# Epoch 231/1500
# 13/13 [==============================] - 0s 7ms/step - loss: 0.1242 - accuracy: 0.9753
# Epoch 232/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1244 - accuracy: 0.9815
# Epoch 233/1500
# 13/13 [==============================] - 0s 7ms/step - loss: 0.1239 - accuracy: 0.9839
# Epoch 234/1500
# 13/13 [==============================] - 0s 10ms/step - loss: 0.1277 - accuracy: 0.9778
# Epoch 235/1500
# 13/13 [==============================] - 0s 9ms/step - loss: 0.1273 - accuracy: 0.9802
# Epoch 236/1500
# 13/13 [==============================] - 0s 7ms/step - loss: 0.1254 - accuracy: 0.9864
# Epoch 237/1500
# 13/13 [==============================] - 0s 7ms/step - loss: 0.1251 - accuracy: 0.9864
# Epoch 238/1500
# 13/13 [==============================] - 0s 8ms/step - loss: 0.1236 - accuracy: 0.9889
# Epoch 239/1500
# 13/13 [==============================] - 0s 7ms/step - loss: 0.1243 - accuracy: 0.9802
# Epoch 240/1500
# 13/13 [==============================] - 0s 7ms/step - loss: 0.1250 - accuracy: 0.9802
# Epoch 241/1500
# 13/13 [==============================] - 0s 7ms/step - loss: 0.1219 - accuracy: 0.9839
# Epoch 242/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1237 - accuracy: 0.9938
# Epoch 243/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1238 - accuracy: 0.9790
# Epoch 244/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1239 - accuracy: 0.9901
# Epoch 245/1500
# 13/13 [==============================] - 0s 7ms/step - loss: 0.1233 - accuracy: 0.9839
# Epoch 246/1500
# 13/13 [==============================] - 0s 7ms/step - loss: 0.1244 - accuracy: 0.9790
# Epoch 247/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1265 - accuracy: 0.9839
# Epoch 248/1500
# 13/13 [==============================] - 0s 7ms/step - loss: 0.1233 - accuracy: 0.9839
# Epoch 249/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1282 - accuracy: 0.9753
# Epoch 250/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1252 - accuracy: 0.9864
# Epoch 251/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1228 - accuracy: 0.9827
# Epoch 252/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1230 - accuracy: 0.9815
# Epoch 253/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1221 - accuracy: 0.9790
# Epoch 254/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1240 - accuracy: 0.9790
# Epoch 255/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1250 - accuracy: 0.9839
# Epoch 256/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1264 - accuracy: 0.9839
# Epoch 257/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1252 - accuracy: 0.9815
# Epoch 258/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1234 - accuracy: 0.9889
# Epoch 259/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1231 - accuracy: 0.9839
# Epoch 260/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1231 - accuracy: 0.9815
# Epoch 261/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1218 - accuracy: 0.9827
# Epoch 262/1500
# 13/13 [==============================] - 0s 7ms/step - loss: 0.1223 - accuracy: 0.9889
# Epoch 263/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1251 - accuracy: 0.9815
# Epoch 264/1500
# 13/13 [==============================] - 0s 7ms/step - loss: 0.1235 - accuracy: 0.9802
# Epoch 265/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1223 - accuracy: 0.9852
# Epoch 266/1500
# 13/13 [==============================] - 0s 7ms/step - loss: 0.1212 - accuracy: 0.9852
# Epoch 267/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1235 - accuracy: 0.9815
# Epoch 268/1500
# 13/13 [==============================] - 0s 7ms/step - loss: 0.1240 - accuracy: 0.9802
# Epoch 269/1500
# 13/13 [==============================] - 0s 7ms/step - loss: 0.1259 - accuracy: 0.9839
# Epoch 270/1500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.1230 - accuracy: 0.9790
# Epoch 271/1500
#  9/13 [===================>..........] - ETA: 0s - loss: 0.1263 - accuracy: 0.9844Restoring model weights from the end of the best epoch: 241.
# 13/13 [==============================] - 0s 7ms/step - loss: 0.1214 - accuracy: 0.9864
# Epoch 271: early stopping
# 5/5 [==============================] - 0s 2ms/step - loss: 2.6796 - accuracy: 0.5094
# 5/5 [==============================] - 0s 1ms/step
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Majority Vote Accuracy for cat_id for this fold: 0.64 (16/25)
# Before appending - Cat IDs: 0, Predictions: 0, Actuals: 0, Gender: 0
# After appending - Cat IDs: 159, Predictions: 159, Actuals: 159, Gender: 159
# Final Test Results - Loss: 2.6795945167541504, Accuracy: 0.5094339847564697, Precision: 0.6152235738559081, Recall: 0.6401234567901234, F1 Score: 0.5327067274920035
# Confusion Matrix:
#  [[43 15  2]
#  [ 1 17  0]
#  [59  1 21]]
# outer_fold 2
# Train Set Group Distribution:
# 046A    66
# 000A    39
# 047A    30
# 020A    23
# 000B    20
#         ..
# 115A     1
# 090A     1
# 004A     1
# 026B     1
# 100A     1
# Name: cat_id, Length: 80, dtype: int64
# Testing Set Group Distribution:
# 002B    36
# 103A    33
# 057A    28
# 074A    25
# 019A    17
# 101A    16
# 028A    14
# 051A    12
# 036A    11
# 068A    11
# 016A    11
# 005A    11
# 015A    10
# 010A     8
# 027A     7
# 031A     7
# 044A     5
# 012A     5
# 035A     4
# 052A     4
# 014A     3
# 018A     2
# 054A     2
# 038A     2
# 087A     2
# 066A     2
# 091A     1
# 049A     1
# 048A     1
# 110A     1
# 073A     1
# 076A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    273
# M    202
# F    199
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# M    154
# X     82
# F     58
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [002A, 070A, 033A, 000B, 071A, 020A, 000A, 026...
# kitten    [046A, 042A, 014B, 109A, 040A, 047A, 045A, 111...
# senior    [117A, 106A, 090A, 113A, 051B, 116A, 024A, 097...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [028A, 015A, 038A, 068A, 018A, 002B, 005A, 091...
# kitten                             [110A, 049A, 048A, 044A]
# senior                             [057A, 051A, 016A, 054A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 50, 'kitten': 12, 'senior': 18}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 24, 'kitten': 4, 'senior': 4}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '003A' '004A' '006A' '007A' '008A' '009A'
#  '011A' '013B' '014B' '019B' '020A' '021A' '022A' '023A' '023B' '024A'
#  '025A' '025B' '025C' '026A' '026B' '026C' '029A' '032A' '033A' '034A'
#  '037A' '039A' '040A' '041A' '042A' '043A' '045A' '046A' '047A' '050A'
#  '051B' '053A' '055A' '056A' '058A' '059A' '060A' '061A' '062A' '063A'
#  '064A' '065A' '067A' '069A' '070A' '071A' '072A' '075A' '088A' '090A'
#  '092A' '093A' '094A' '095A' '096A' '097A' '097B' '099A' '100A' '102A'
#  '104A' '105A' '106A' '108A' '109A' '111A' '113A' '115A' '116A' '117A']
# Unique Test Group IDs:
# ['002B' '005A' '010A' '012A' '014A' '015A' '016A' '018A' '019A' '027A'
#  '028A' '031A' '035A' '036A' '038A' '044A' '048A' '049A' '051A' '052A'
#  '054A' '057A' '066A' '068A' '073A' '074A' '076A' '087A' '091A' '101A'
#  '103A' '110A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '003A' '004A' '006A' '007A' '008A' '009A'
#  '011A' '013B' '014B' '019B' '020A' '021A' '022A' '023A' '023B' '024A'
#  '025A' '025B' '025C' '026A' '026B' '026C' '029A' '032A' '033A' '034A'
#  '037A' '039A' '040A' '041A' '042A' '043A' '045A' '046A' '047A' '050A'
#  '051B' '053A' '055A' '056A' '058A' '059A' '060A' '061A' '062A' '063A'
#  '064A' '065A' '067A' '069A' '070A' '071A' '072A' '075A' '088A' '090A'
#  '092A' '093A' '094A' '095A' '096A' '097A' '097B' '099A' '100A' '102A'
#  '104A' '105A' '106A' '108A' '109A' '111A' '113A' '115A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['002B' '005A' '010A' '012A' '014A' '015A' '016A' '018A' '019A' '027A'
#  '028A' '031A' '035A' '036A' '038A' '044A' '048A' '049A' '051A' '052A'
#  '054A' '057A' '066A' '068A' '073A' '074A' '076A' '087A' '091A' '101A'
#  '103A' '110A']
# Length of X_train_val:
# 674
# Length of y_train_val:
# 674
# Length of groups_train_val:
# 674
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     373
# kitten    168
# senior    133
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     233
# senior     53
# kitten      8
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     373
# kitten    168
# senior    133
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     233
# senior     53
# kitten      8
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 373, 1: 168, 2: 133})
# Epoch 1/1500
# 11/11 [==============================] - 1s 6ms/step - loss: 1.3412 - accuracy: 0.5401
# Epoch 2/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.7417 - accuracy: 0.7522
# Epoch 3/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.5376 - accuracy: 0.8249
# Epoch 4/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.4448 - accuracy: 0.8709
# Epoch 5/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.4203 - accuracy: 0.8798
# Epoch 6/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.3864 - accuracy: 0.8858
# Epoch 7/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.3392 - accuracy: 0.9154
# Epoch 8/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.3157 - accuracy: 0.9199
# Epoch 9/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.3235 - accuracy: 0.9154
# Epoch 10/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.2968 - accuracy: 0.9288
# Epoch 11/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.3044 - accuracy: 0.9288
# Epoch 12/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.2906 - accuracy: 0.9347
# Epoch 13/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.2633 - accuracy: 0.9481
# Epoch 14/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.2872 - accuracy: 0.9347
# Epoch 15/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.2474 - accuracy: 0.9436
# Epoch 16/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.2582 - accuracy: 0.9496
# Epoch 17/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.2592 - accuracy: 0.9451
# Epoch 18/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.2629 - accuracy: 0.9362
# Epoch 19/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.2449 - accuracy: 0.9466
# Epoch 20/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.2529 - accuracy: 0.9525
# Epoch 21/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.2345 - accuracy: 0.9466
# Epoch 22/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.2427 - accuracy: 0.9481
# Epoch 23/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.2327 - accuracy: 0.9614
# Epoch 24/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.2307 - accuracy: 0.9451
# Epoch 25/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.2241 - accuracy: 0.9540
# Epoch 26/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.2239 - accuracy: 0.9540
# Epoch 27/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.2195 - accuracy: 0.9599
# Epoch 28/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.2284 - accuracy: 0.9570
# Epoch 29/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.2308 - accuracy: 0.9451
# Epoch 30/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.2141 - accuracy: 0.9540
# Epoch 31/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.2288 - accuracy: 0.9540
# Epoch 32/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.2189 - accuracy: 0.9496
# Epoch 33/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.2041 - accuracy: 0.9585
# Epoch 34/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.2187 - accuracy: 0.9614
# Epoch 35/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.2137 - accuracy: 0.9570
# Epoch 36/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.2068 - accuracy: 0.9599
# Epoch 37/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.1972 - accuracy: 0.9718
# Epoch 38/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.2004 - accuracy: 0.9466
# Epoch 39/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.1957 - accuracy: 0.9510
# Epoch 40/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.2068 - accuracy: 0.9510
# Epoch 41/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.2012 - accuracy: 0.9525
# Epoch 42/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1986 - accuracy: 0.9540
# Epoch 43/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.2162 - accuracy: 0.9481
# Epoch 44/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1977 - accuracy: 0.9718
# Epoch 45/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1911 - accuracy: 0.9644
# Epoch 46/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.1954 - accuracy: 0.9481
# Epoch 47/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1962 - accuracy: 0.9674
# Epoch 48/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1887 - accuracy: 0.9644
# Epoch 49/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1931 - accuracy: 0.9644
# Epoch 50/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1941 - accuracy: 0.9644
# Epoch 51/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1932 - accuracy: 0.9629
# Epoch 52/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1969 - accuracy: 0.9496
# Epoch 53/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1935 - accuracy: 0.9525
# Epoch 54/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1983 - accuracy: 0.9599
# Epoch 55/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1850 - accuracy: 0.9688
# Epoch 56/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.
1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1342 - accuracy: 0.9694
# Epoch 181/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1384 - accuracy: 0.9734
# Epoch 182/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1332 - accuracy: 0.9827
# Epoch 183/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1356 - accuracy: 0.9707
# Epoch 184/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1329 - accuracy: 0.9800
# Epoch 185/1500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1302 - accuracy: 0.9720
# Epoch 186/1500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1336 - accuracy: 0.9760
# Epoch 187/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1331 - accuracy: 0.9814
# Epoch 188/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1334 - accuracy: 0.9814
# Epoch 189/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1322 - accuracy: 0.9760
# Epoch 190/1500
# 10/12 [========================>.....] - ETA: 0s - loss: 0.1353 - accuracy: 0.9844Restoring model weights from the end of the best epoch: 160.
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1331 - accuracy: 0.9854
# Epoch 190: early stopping
# 7/7 [==============================] - 0s 2ms/step - loss: 2.0326 - accuracy: 0.6820
# 7/7 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.85 (23/27)
# Before appending - Cat IDs: 653, Predictions: 653, Actuals: 653, Gender: 653
# After appending - Cat IDs: 870, Predictions: 870, Actuals: 870, Gender: 870
# Final Test Results - Loss: 2.0325841903686523, Accuracy: 0.6820276379585266, Precision: 0.6176655719759169, Recall: 0.5733258354815421, F1 Score: 0.5565221663582319
# Confusion Matrix:
#  [[121   7   9]
#  [ 38  13   6]
#  [  9   0  14]]
#
# Final Average F1-Score across all UNSEEN TEST sets: 0.5508860730740278
#
# Final Average Loss across all UNSEEN TEST sets: 2.153498947620392
#
# Final Average Accuracy across all UNSEEN TEST sets: 0.6535371690988541
#
# Final Average Precision across all UNSEEN TEST sets: 0.5755956898351385
#
# Final Average Recall across all UNSEEN TEST sets: 0.6213368872569235

# %%
seed_1_folds_values = (unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1)

# Plotting all fold metrics
seed_1_folds_plot = plot_all_metrics(unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1, "Folds", "Fold Number")

# %% [markdown]
# ## Majority Voting on Total Entries per cat_id

# %%
# Debugging print statements
print(f'Checking - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
# Out:
# Checking - Cat IDs: 870, Predictions: 870, Actuals: 870, Gender: 870

# %%
# Create results df
full_results = pd.DataFrame({
    'cat_id': all_cat_ids,
    'predicted_age_group': all_predicted_age_groups,
    'actual_age_group': all_actual_age_groups,
    'all_gender': all_gender
})

# create a correct majority prediction column
full_results['correct'] = full_results['predicted_age_group'] == full_results['actual_age_group']

# %%
# Group by cat_id and aggregate predicted age groups
majority_votes = full_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first()

# Calculate the accuracy of majority voting
correct_predictions = (majority_votes == actual_groups).sum()
total_cats = len(actual_groups)
majority_vote_accuracy = correct_predictions / total_cats

logger(f"Overall Majority Vote Accuracy for cat_id: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

# store for final evaluation 
all_majority_vote_accuracies.append(majority_vote_accuracy)
# Out:
# Overall Majority Vote Accuracy for cat_id: 0.80 (88/110)

# %%
# Detailed df with predictions, actual labels, and comparison including majority vote
detailed_results = full_results.groupby('cat_id').apply(
    lambda x: pd.Series({
        'Predictions': list(x['predicted_age_group']),
        'Majority Vote': x['predicted_age_group'].mode()[0],
        'Actual Age Group': x['actual_age_group'].iloc[0],
        'Correct Majority Vote': x['predicted_age_group'].mode()[0] == x['actual_age_group'].iloc[0]
    })
).reset_index()

# Convert to DataFrame for better formatting and display
detailed_results = pd.DataFrame(detailed_results)

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 10)
pd.set_option('display.width', 1000)

sorted_detailed_results = detailed_results.sort_values(by='Correct Majority Vote', ascending=False)

# Display the sorted DataFrame
sorted_detailed_results
# Out:
#     cat_id                                        Predictions Majority Vote Actual Age Group  Correct Majority Vote
# 0     000B  [adult, adult, adult, kitten, adult, adult, ad...         adult            adult                   True
# 65    059A  [senior, senior, senior, adult, adult, senior,...        senior           senior                   True
# 77    071A  [adult, senior, adult, adult, adult, senior, s...         adult            adult                   True
# 76    070A               [adult, senior, adult, adult, adult]         adult            adult                   True
# 75    069A                                    [senior, adult]         adult            adult                   True
# 74    068A  [adult, adult, adult, senior, senior, adult, a...         adult            adult                   True
# 73    067A  [adult, kitten, adult, kitten, adult, adult, a...         adult            adult                   True
# 72    066A                                    [adult, kitten]         adult            adult                   True
# 71    065A  [adult, adult, adult, kitten, kitten, adult, k...         adult            adult                   True
# 70    064A                              [adult, adult, adult]         adult            adult                   True
# 68    062A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 64    058A                            [senior, adult, senior]        senior           senior                   True
# 47    041A                                           [kitten]        kitten           kitten                   True
# 60    054A                                   [senior, senior]        senior           senior                   True
# 59    053A  [adult, adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 58    052A                      [adult, senior, adult, adult]         adult            adult                   True
# 1     001A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 54    049A                                           [kitten]        kitten           kitten                   True
# 53    048A                                           [kitten]        kitten           kitten                   True
# 51    045A  [kitten, adult, kitten, kitten, kitten, kitten...        kitten           kitten                   True
# 50    044A           [kitten, kitten, kitten, kitten, kitten]        kitten           kitten                   True
# 49    043A                                           [kitten]        kitten           kitten                   True
# 78    072A  [adult, adult, adult, kitten, adult, kitten, a...         adult            adult                   True
# 79    073A                                            [adult]         adult            adult                   True
# 80    074A  [kitten, adult, adult, adult, adult, adult, ad...         adult            adult                   True
# 81    075A               [adult, senior, adult, adult, adult]         adult            adult                   True
# 107   115A                                           [kitten]        kitten           kitten                   True
# 106   113A                           [senior, senior, senior]        senior           senior                   True
# 105   111A  [adult, kitten, kitten, kitten, kitten, kitten...        kitten           kitten                   True
# 104   110A                                   [kitten, kitten]        kitten           kitten                   True
# 100   105A                      [adult, adult, adult, kitten]         adult            adult                   True
# 98    103A  [adult, adult, adult, adult, senior, senior, a...         adult            adult                   True
# 97    102A                                     [adult, adult]         adult            adult                   True
# 96    101A  [adult, senior, adult, adult, adult, senior, s...         adult            adult                   True
# 95    100A                                            [adult]         adult            adult                   True
# 94    099A  [adult, adult, adult, kitten, adult, adult, ad...         adult            adult                   True
# 93    097B  [senior, adult, adult, adult, adult, adult, ad...         adult            adult                   True
# 92    097A  [adult, senior, senior, senior, senior, adult,...        senior           senior                   True
# 91    096A                                            [adult]         adult            adult                   True
# 90    095A  [adult, adult, senior, senior, adult, adult, a...         adult            adult                   True
# 87    092A                                            [adult]         adult            adult                   True
# 86    091A                                            [adult]         adult            adult                   True
# 84    088A                                            [adult]         adult            adult                   True
# 83    087A                                     [adult, adult]         adult            adult                   True
# 82    076A                                            [adult]         adult            adult                   True
#

# Total Gender Accuracy so far:
#  [  all_gender  count  correct  accuracy
# 0          F    218      138     63.30
# 1          M    362      271     74.86
# 2          X    290      172     59.31]

# %% [markdown]
# # RANDOM SEED 2

# %%
# Set a fixed random seed for reproducibility
random.seed(int(random_seeds[1]))
np.random.seed(int(random_seeds[1]))
tf.random.set_seed(int(random_seeds[1]))

# Load datasets
dataframe = pd.read_csv('/Users/astrid/PycharmProjects/data-aug-and-more/yamnet-tfhub-extraction/yamnet_embeddings_looped_april_23.csv')

def assign_age_group(age, age_groups):
    for group_name, age_range in age_groups.items():
        if age_range[0] <= age < age_range[1]:
            return group_name
    return 'Unknown'  # For any age that doesn't fit the defined groups

# Define age groups
age_groups = {
    'kitten': (0, 0.5),
    'adult': (0.5, 12),
    'senior': (12, 20)
}

# Create a new column for the age group
dataframe['age_group'] = dataframe['target'].apply(assign_age_group, age_groups=age_groups)

print(dataframe['age_group'].value_counts())
# Out:
# adult     606
# senior    186
# kitten    176
# Name: age_group, dtype: int64

# %%
# Separate features and labels
X = dataframe.iloc[:, :-4].values  # all columns except the last four

# Encode the 'age_group' column as integers using LabelEncoder
label_encoder = LabelEncoder()
encoded_y = label_encoder.fit_transform(dataframe['age_group'].values)

# Use the encoded labels for splitting and one-hot encoding
y = encoded_y  

# Convert 'cat_id' column to numpy array to be used as groups array for GroupKFold
groups = dataframe['cat_id'].values

# %%
tf.keras.backend.clear_session()

# %% [markdown]
# ## Run Setup

# %%
all_cat_ids = []
all_predicted_age_groups = []
all_actual_age_groups = []
all_gender = []

# Define the StratifiedGroupKFold splitter for 4 fold CV with random shuffling
outer_cv = StratifiedGroupKFold(n_splits=4, shuffle=True, random_state=int(random_seeds[1]))

# unseen test set metrics
unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1 = [], [], [], [], []

outer_fold = 0

# Use the splitter to generate indices for training and testing sets
# Note: GroupShuffleSplit.split returns indices, so we use it to index the arrays
for train_val_idx, test_idx in outer_cv.split(X, y, groups):
    outer_fold += 1
    logger(f"outer_fold {outer_fold}", file=log_file_path)

    # Convert indices back to DataFrame for easy manipulation
    df_train_val = dataframe.iloc[train_val_idx]
    df_test = dataframe.iloc[test_idx]

    ##############################
    # ASSESSING SPLITS BY CAT_ID #
    ##############################
    
    # Get the distribution of groups
    training_validation_group_distribution = df_train_val['cat_id'].value_counts()  
    testing_group_distribution = df_test['cat_id'].value_counts()  
    
    # Log or print the distribution
    logger(f"Train Set Group Distribution:\n{training_validation_group_distribution}", file=log_file_path)
    logger(f"Testing Set Group Distribution:\n{testing_group_distribution}", file=log_file_path)

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val['gender'].value_counts()
    testing_gender_distribution = df_test['gender'].value_counts()
    
    # Log the distribution
    logger(f"Training Set Gender Distribution BEFORE SWAP:\n{training_gender_distribution}", file=log_file_path)
    logger(f"Testing Set Gender Distribution BEFORE SWAP:\n{testing_gender_distribution}", file=log_file_path)

    # Group by 'age_group' and then list unique 'cat_id' within each age group
    unique_cat_ids_per_age_group_train_val = df_train_val.groupby('age_group')['cat_id'].unique()
    unique_cat_ids_per_age_group_test = df_test.groupby('age_group')['cat_id'].unique()
    
    # Log results
    logger(f"Unique Cat IDs per Age Group in Training/Validation Set:\n{unique_cat_ids_per_age_group_train_val}", file=log_file_path)
    logger(f"Unique Cat IDs per Age Group in Testing Set:\n{unique_cat_ids_per_age_group_test}", file=log_file_path)

    # Calculate the count of unique identifiers per age group for training and testing set
    counts_train_val = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_train_val.items()}
    counts_test = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_test.items()}

    # Log the counts of unique identifiers per age group
    logger(f"Count of Unique Cat IDs per Age Group in Training/Validation Set:\n{counts_train_val}", file=log_file_path)
    logger(f"Count of Unique Cat IDs per Age Group in Testing Set:\n{counts_test}", file=log_file_path)

    #######################################################
    # CONTINUE WITH ENSURING VALID AND APPROPRIATE SPLITS #
    #######################################################
    
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    groups_train_val, groups_test = groups[train_val_idx], groups[test_idx]

    # logging identifier splits 
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)

    # check group splits
    check_initial_group_split(groups_train_val, groups_test)

    # Specify the cat_ids that must be in the training/validation set
    specific_cat_ids = ['000A', '046A']
    
    # Perform the swapping operation
    train_val_idx, test_idx = swap_cat_id_instances(dataframe, train_val_idx, test_idx, specific_cat_ids)
    
    # Re-assign the sets based on the updated indices
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    new_groups_train_val, new_groups_test = groups[train_val_idx], groups[test_idx]

    # Find differences for training and test sets
    moved_to_train_val, removed_from_train_val = find_group_differences(groups_train_val, new_groups_train_val)
    moved_to_test, removed_from_test = find_group_differences(groups_test, new_groups_test)
    
    # Display the results
    logger(f"Moved to Training/Validation Set:\n{moved_to_train_val}", file=log_file_path)
    logger(f"Removed from Training/Validation Set:\n{removed_from_train_val}", file=log_file_path)
    logger(f"Moved to Test Set:\n{moved_to_test}", file=log_file_path)
    logger(f"Removed from Test Set\n{removed_from_test}", file=log_file_path)

    # Update X_train_val, X_test, y_train_val, y_test, groups_train_val, groups_test based on updated indices
    X_train_val = X[train_val_idx]
    y_train_val = y[train_val_idx]
    groups_train_val = groups[train_val_idx]
    
    X_test = X[test_idx]
    y_test = y[test_idx]
    groups_test = groups[test_idx]

    # logging identifier splits again after potential swaps
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"AFTER SWAP - Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"AFTER SWAP - Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)
    
    # Verify the lengths are consistent
    logger(f"Length of X_train_val:\n{len(X_train_val)}", file=log_file_path)
    logger(f"Length of y_train_val:\n{len(y_train_val)}", file=log_file_path)
    logger(f"Length of groups_train_val:\n{len(groups_train_val)}", file=log_file_path)

    # Check group splits once more
    check_initial_group_split(groups_train_val, groups_test)

    # Convert the modified indices back to a DataFrame representing the updated df_train_val
    df_train_val_updated = dataframe.iloc[train_val_idx].copy()
    df_test_updated = dataframe.iloc[test_idx].copy()

    ############################
    # LOGGING AGE GROUP SPLITS #
    ############################

    # Get the distribution of age groups of age groups before the update
    training_validation_age_group_distribution = df_train_val['age_group'].value_counts()
    testing_age_group_distribution = df_test['age_group'].value_counts()
    
    # Logthe distribution
    logger(f"Train Age Group Distribution BEFORE SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution BEFORE SWAP:\n{testing_age_group_distribution}", file=log_file_path)

    # Get the distribution of age groups after the update
    training_validation_age_group_distribution = df_train_val_updated['age_group'].value_counts()
    testing_age_group_distribution = df_test_updated['age_group'].value_counts()
    
    # Log the distribution
    logger(f"Train Age Group Distribution AFTER SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution AFTER SWAP:\n{testing_age_group_distribution}", file=log_file_path)
    
    ########################################################
    # TRACKING FINAL CAT_IDs & GENDER AFTER REDISTRIBUTION #
    ########################################################

    # Get the distribution of groups
    training_validation_group_distribution = df_train_val_updated['cat_id'].value_counts()  
    testing_group_distribution = df_test_updated['cat_id'].value_counts()  

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val_updated['gender'].value_counts()
    testing_gender_distribution = df_test_updated['gender'].value_counts()
    
    logger(f"\n Starting training on unseen test set\n", file=log_file_path)

    ###################
    # PREPARING MODEL #
    ###################

    # Calculate the distribution of age groups in y_train_val
    age_group_distribution = Counter(y_train_val)
    print("Age group distribution:", age_group_distribution)

    # EarlyStopping callback: monitor 'loss' instead of 'val_loss' for the test set
    early_stopping = EarlyStopping(
        monitor='loss',  
        min_delta=0.001, 
        patience=30,  
        verbose=1,  
        restore_best_weights=True  
    )

    # One final shuffle to ensure randomness
    outer_shuffle_idx = np.random.permutation(len(X_train_val))
    X_train_val = X_train_val[outer_shuffle_idx]
    y_train_val = y_train_val[outer_shuffle_idx]
    
    # Scale the features
    scaler_full = StandardScaler().fit(X_train_val)
    X_train_full_scaled = scaler_full.transform(X_train_val)
    X_test_scaled = scaler_full.transform(X_test)
    
    # Convert features to TensorFlow tensors
    X_train_full_scaled = tf.convert_to_tensor(X_train_full_scaled, dtype=tf.float32)
    X_test_scaled = tf.convert_to_tensor(X_test_scaled, dtype=tf.float32)
    
    # One-hot encode labels before mixup
    y_train_full_encoded = to_categorical(y_train_val)
    y_test_encoded = to_categorical(y_test)
    
    # Convert labels to TensorFlow tensors
    y_train_full_encoded = tf.convert_to_tensor(y_train_full_encoded, dtype=tf.float32)
    
    # Apply Mixup
    X_train_mix_outer, y_train_mix_outer = mixup_data(X_train_full_scaled, y_train_full_encoded, alpha=0.2)
    
    #######################
    # BUILD & TRAIN MODEL #
    #######################

    optimizers = {
        'Adamax': Adamax(learning_rate=0.00510251984616472)
    }
    
    # Model definition with dynamic number of layers
    model_full = Sequential()
    model_full.add(Dense(480, activation='relu', input_shape=(X_train_full_scaled.shape[1],)))
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.2011047009431978))  
    model_full.add(Dense(256, activation='relu',)) 
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.14956886311951184))  
    model_full.add(Dense(256, activation='relu'))  
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.42291461228250665))  
    model_full.add(Dense(3, activation='softmax'))  
    
    # Use the optimizer from the parameters
    optimizer = optimizers['Adamax']  # optimizer_key from parameters
    
    # Compile the model
    model_full.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    
    # Train the model on the full training set
    history_full = model_full.fit(X_train_mix_outer, y_train_mix_outer, epochs=1500, batch_size=64,
                                  verbose=1, callbacks=[early_stopping])
    
    # Evaluate the model on the held-out test set
    test_loss, test_accuracy = model_full.evaluate(X_test_scaled, y_test_encoded)

    y_test_pred_prob = model_full.predict(X_test_scaled)
    y_test_pred = np.argmax(y_test_pred_prob, axis=1)  
    y_test_true = np.argmax(y_test_encoded, axis=1)    

    ################################
    # LOG MAJORITY VOTE PER CAT_ID #
    ################################

    # Convert numeric predictions back to age group labels
    predicted_age_groups = label_encoder.inverse_transform(y_test_pred)
    actual_labels = label_encoder.inverse_transform(y_test_true)
    
    # Map predictions and actual labels back to cat_ids
    test_results = pd.DataFrame({
        'cat_id': df_test_updated['cat_id'],
        'predicted_age_group': predicted_age_groups,
        'actual_age_group': actual_labels
    })
    
    # Group by cat_id and aggregate predicted age groups
    majority_votes = test_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
    actual_groups = test_results.groupby('cat_id')['actual_age_group'].first()
    
    # Calculate the accuracy of majority voting
    correct_predictions = (majority_votes == actual_groups).sum()
    total_cats = len(actual_groups)
    majority_vote_accuracy = correct_predictions / total_cats
    
    # Log the accuracy of the majority voting
    logger(f"Majority Vote Accuracy for cat_id for this fold: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

    ####################################################
    # COLLECT PREDICTIONS FOR GENDER & CAT_ID ANALYSIS #
    ####################################################

    # Debugging print statements
    print(f'Before appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Extend lists with current fold results
    all_cat_ids.extend(df_test_updated['cat_id'].tolist())
    all_predicted_age_groups.extend(predicted_age_groups)
    all_actual_age_groups.extend(actual_labels)
    all_gender.extend(df_test_updated['gender'].tolist())

    # Debugging print statements
    print(f'After appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Calculate additional metrics
    test_precision = precision_score(y_test_true, y_test_pred, average='macro')  # Use 'macro' for imbalanced datasets
    test_recall = recall_score(y_test_true, y_test_pred, average='macro')
    test_f1 = f1_score(y_test_true, y_test_pred, average='macro')

    # prepare averages of outer metrics
    unseen_f1.append(test_f1)
    unseen_losses.append(test_loss)
    unseen_accuracies.append(test_accuracy)
    unseen_precisions.append(test_precision)
    unseen_recalls.append(test_recall)

    # Print final test results
    logger(f"Final Test Results - Loss: {test_loss}, Accuracy: {test_accuracy}, Precision: {test_precision}, Recall: {test_recall}, F1 Score: {test_f1}", file=log_file_path)

    # Generate the confusion matrix
    cm = confusion_matrix(y_test, y_test_pred)
    logger(f"Confusion Matrix:\n {cm}", file=log_file_path)

# Calculate the overall average metrics
unseen_set_avg_f1 = np.mean(unseen_f1)
unseen_set_avg_loss = np.mean(unseen_losses)
unseen_set_avg_acc = np.mean(unseen_accuracies)
unseen_set_avg_precision = np.mean(unseen_precisions)
unseen_set_avg_recall = np.mean(unseen_recalls)

logger(f"\nFinal Average F1-Score across all UNSEEN TEST sets: {unseen_set_avg_f1}", file=log_file_path)
logger(f"\nFinal Average Loss across all UNSEEN TEST sets: {unseen_set_avg_loss}", file=log_file_path)
logger(f"\nFinal Average Accuracy across all UNSEEN TEST sets: {unseen_set_avg_acc}", file=log_file_path)
logger(f"\nFinal Average Precision across all UNSEEN TEST sets: {unseen_set_avg_precision}", file=log_file_path)
logger(f"\nFinal Average Recall across all UNSEEN TEST sets: {unseen_set_avg_recall}\n", file=log_file_path)

# Append averages to total lists
all_f1.append(unseen_set_avg_f1)
all_losses.append(unseen_set_avg_loss)
all_accuracies.append(unseen_set_avg_acc)
all_precisions.append(unseen_set_avg_precision)
all_recalls.append(unseen_set_avg_recall)
# Out:
# outer_fold 1
# Train Set Group Distribution:
# 000A    39
# 002B    36
# 047A    30
# 057A    28
# 074A    25
# 020A    23
# 000B    20
# 067A    20
# 055A    20
# 029A    17
# 019A    17
# 101A    16
# 097A    16
# 001A    15
# 042A    14
# 097B    14
# 028A    14
# 002A    13
# 039A    12
# 116A    12
# 005A    11
# 016A    11
# 040A    10
# 014B    10
# 071A    10
# 051B     9
# 022A     9
# 065A     9
# 072A     9
# 013B     8
# 095A     8
# 010A     8
# 117A     7
# 027A     7
# 050A     7
# 053A     7
# 031A     7
# 023A     6
# 037A     6
# 021A     6
# 025C     6
# 108A     6
# 008A     6
# 109A     6
# 007A     6
# 012A     5
# 034A     5
# 062A     5
# 070A     5
# 026A     4
# 009A     4
# 105A     4
# 003A     4
# 104A     4
# 058A     3
# 006A     3
# 113A     3
# 056A     3
# 011A     3
# 064A     3
# 060A     3
# 014A     3
# 087A     2
# 025B     2
# 093A     2
# 066A     2
# 054A     2
# 032A     2
# 102A     2
# 069A     2
# 038A     2
# 061A     2
# 073A     1
# 041A     1
# 026B     1
# 004A     1
# 076A     1
# 110A     1
# 115A     1
# 024A     1
# 091A     1
# 026C     1
# 049A     1
# 043A     1
# 096A     1
# 088A     1
# 100A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 046A    66
# 103A    33
# 059A    18
# 106A    15
# 111A    13
# 051A    12
# 063A    11
# 036A    11
# 068A    11
# 025A    11
# 015A    10
# 045A     9
# 033A     9
# 094A     8
# 099A     7
# 075A     5
# 023B     5
# 044A     5
# 035A     4
# 052A     4
# 018A     2
# 092A     1
# 048A     1
# 090A     1
# 019B     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    250
# X    223
# F    222
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    132
# M    106
# F     35
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [002A, 028A, 070A, 000B, 071A, 020A, 000A, 026...
# kitten    [042A, 014B, 110A, 109A, 040A, 047A, 049A, 043...
# senior    [117A, 057A, 113A, 051B, 116A, 024A, 097A, 055...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [033A, 015A, 023B, 068A, 018A, 103A, 063A, 075...
# kitten                       [046A, 045A, 048A, 111A, 044A]
# senior                       [106A, 090A, 051A, 094A, 059A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 59, 'kitten': 11, 'senior': 17}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 15, 'kitten': 5, 'senior': 5}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '004A' '005A' '006A' '007A'
#  '008A' '009A' '010A' '011A' '012A' '013B' '014A' '014B' '016A' '019A'
#  '020A' '021A' '022A' '023A' '024A' '025B' '025C' '026A' '026B' '026C'
#  '027A' '028A' '029A' '031A' '032A' '034A' '037A' '038A' '039A' '040A'
#  '041A' '042A' '043A' '047A' '049A' '050A' '051B' '053A' '054A' '055A'
#  '056A' '057A' '058A' '060A' '061A' '062A' '064A' '065A' '066A' '067A'
#  '069A' '070A' '071A' '072A' '073A' '074A' '076A' '087A' '088A' '091A'
#  '093A' '095A' '096A' '097A' '097B' '100A' '101A' '102A' '104A' '105A'
#  '108A' '109A' '110A' '113A' '115A' '116A' '117A']
# Unique Test Group IDs:
# ['015A' '018A' '019B' '023B' '025A' '033A' '035A' '036A' '044A' '045A'
#  '046A' '048A' '051A' '052A' '059A' '063A' '068A' '075A' '090A' '092A'
#  '094A' '099A' '103A' '106A' '111A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'046A'}
# Removed from Training/Validation Set:
# {'014B'}
# Moved to Test Set:
# {'014B'}
# Removed from Test Set
# {'046A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '004A' '005A' '006A' '007A'
#  '008A' '009A' '010A' '011A' '012A' '013B' '014A' '016A' '019A' '020A'
#  '021A' '022A' '023A' '024A' '025B' '025C' '026A' '026B' '026C' '027A'
#  '028A' '029A' '031A' '032A' '034A' '037A' '038A' '039A' '040A' '041A'
#  '042A' '043A' '046A' '047A' '049A' '050A' '051B' '053A' '054A' '055A'
#  '056A' '057A' '058A' '060A' '061A' '062A' '064A' '065A' '066A' '067A'
#  '069A' '070A' '071A' '072A' '073A' '074A' '076A' '087A' '088A' '091A'
#  '093A' '095A' '096A' '097A' '097B' '100A' '101A' '102A' '104A' '105A'
#  '108A' '109A' '110A' '113A' '115A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['014B' '015A' '018A' '019B' '023B' '025A' '033A' '035A' '036A' '044A'
#  '045A' '048A' '051A' '052A' '059A' '063A' '068A' '075A' '090A' '092A'
#  '094A' '099A' '103A' '106A' '111A']
# Length of X_train_val:
# 751
# Length of y_train_val:
# 751
# Length of groups_train_val:
# 751
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     481
# senior    132
# kitten     82
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     125
# kitten     94
# senior     54
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     481
# kitten    138
# senior    132
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     125
# senior     54
# kitten     38
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 481, 1: 138, 2: 132})
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Epoch 1/1500
# 12/12 [==============================] - 1s 5ms/step - loss: 1.3961 - accuracy: 0.5007
# Epoch 2/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.7537 - accuracy: 0.7150
# Epoch 3/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.5804 - accuracy: 0.7963
# Epoch 4/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.4886 - accuracy: 0.8495
# Epoch 5/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.4342 - accuracy: 0.8735
# Epoch 6/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.3465 - accuracy: 0.9055
# Epoch 7/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.3241 - accuracy: 0.9174
# Epoch 8/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.3429 - accuracy: 0.8988
# Epoch 9/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.3161 - accuracy: 0.9268
# Epoch 10/1500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.3081 - accuracy: 0.9108
# Epoch 11/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.3189 - accuracy: 0.9174
# Epoch 12/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.2710 - accuracy: 0.9294
# Epoch 13/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.2598 - accuracy: 0.9481
# Epoch 14/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.2819 - accuracy: 0.9454
# Epoch 15/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.2535 - accuracy: 0.9401
# Epoch 16/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.2576 - accuracy: 0.9427
# Epoch 17/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.2337 - accuracy: 0.9547
# Epoch 18/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.
1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1420 - accuracy: 0.9814
# Epoch 208/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1415 - accuracy: 0.9867
# Epoch 209/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1437 - accuracy: 0.9787
# Epoch 210/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1442 - accuracy: 0.9814
# Epoch 211/1500
# 10/12 [========================>.....] - ETA: 0s - loss: 0.1383 - accuracy: 0.9812Restoring model weights from the end of the best epoch: 181.
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1432 - accuracy: 0.9814
# Epoch 211: early stopping
# 7/7 [==============================] - 0s 2ms/step - loss: 2.8054 - accuracy: 0.6728
# 7/7 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.80 (20/25)
# Before appending - Cat IDs: 0, Predictions: 0, Actuals: 0, Gender: 0
# After appending - Cat IDs: 217, Predictions: 217, Actuals: 217, Gender: 217
# Final Test Results - Loss: 2.8054099082946777, Accuracy: 0.6728110313415527, Precision: 0.6409569233098645, Recall: 0.5989707602339182, F1 Score: 0.6110219368646335
# Confusion Matrix:
#  [[104   6  15]
#  [ 12  24   2]
#  [ 32   4  18]]
# outer_fold 2
# Train Set Group Distribution:
# 046A    66
# 000A    39
# 002B    36
# 103A    33
# 057A    28
# 074A    25
# 020A    23
# 055A    20
# 000B    20
# 059A    18
# 097A    16
# 101A    16
# 106A    15
# 001A    15
# 028A    14
# 097B    14
# 111A    13
# 002A    13
# 039A    12
# 051A    12
# 116A    12
# 016A    11
# 068A    11
# 063A    11
# 025A    11
# 036A    11
# 040A    10
# 014B    10
# 071A    10
# 015A    10
# 033A     9
# 045A     9
# 051B     9
# 072A     9
# 013B     8
# 094A     8
# 010A     8
# 053A     7
# 099A     7
# 117A     7
# 031A     7
# 027A     7
# 023A     6
# 108A     6
# 008A     6
# 037A     6
# 025C     6
# 007A     6
# 075A     5
# 034A     5
# 062A     5
# 070A     5
# 023B     5
# 044A     5
# 035A     4
# 026A     4
# 003A     4
# 009A     4
# 052A     4
# 056A     3
# 113A     3
# 011A     3
# 060A     3
# 018A     2
# 025B     2
# 038A     2
# 032A     2
# 054A     2
# 102A     2
# 026C     1
# 041A     1
# 019B     1
# 115A     1
# 110A     1
# 043A     1
# 090A     1
# 073A     1
# 088A     1
# 092A     1
# 048A     1
# 049A     1
# 026B     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 047A    30
# 067A    20
# 019A    17
# 029A    17
# 042A    14
# 005A    11
# 022A     9
# 065A     9
# 095A     8
# 050A     7
# 109A     6
# 021A     6
# 012A     5
# 104A     4
# 105A     4
# 014A     3
# 064A     3
# 058A     3
# 006A     3
# 061A     2
# 087A     2
# 066A     2
# 069A     2
# 093A     2
# 096A     1
# 024A     1
# 091A     1
# 076A     1
# 004A     1
# 100A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    272
# X    270
# F    231
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    85
# M    84
# F    26
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [002A, 028A, 070A, 033A, 000B, 071A, 020A, 000...
# kitten    [046A, 014B, 110A, 040A, 049A, 045A, 048A, 111...
# senior    [117A, 106A, 057A, 090A, 113A, 051B, 116A, 051...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [065A, 021A, 105A, 005A, 006A, 091A, 019A, 022...
# kitten                             [042A, 109A, 047A, 050A]
# senior                       [024A, 058A, 061A, 104A, 093A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 53, 'kitten': 12, 'senior': 17}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 21, 'kitten': 4, 'senior': 5}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '007A' '008A' '009A' '010A'
#  '011A' '013B' '014B' '015A' '016A' '018A' '019B' '020A' '023A' '023B'
#  '025A' '025B' '025C' '026A' '026B' '026C' '027A' '028A' '031A' '032A'
#  '033A' '034A' '035A' '036A' '037A' '038A' '039A' '040A' '041A' '043A'
#  '044A' '045A' '046A' '048A' '049A' '051A' '051B' '052A' '053A' '054A'
#  '055A' '056A' '057A' '059A' '060A' '062A' '063A' '068A' '070A' '071A'
#  '072A' '073A' '074A' '075A' '088A' '090A' '092A' '094A' '097A' '097B'
#  '099A' '101A' '102A' '103A' '106A' '108A' '110A' '111A' '113A' '115A'
#  '116A' '117A']
# Unique Test Group IDs:
# ['004A' '005A' '006A' '012A' '014A' '019A' '021A' '022A' '024A' '029A'
#  '042A' '047A' '050A' '058A' '061A' '064A' '065A' '066A' '067A' '069A'
#  '076A' '087A' '091A' '093A' '095A' '096A' '100A' '104A' '105A' '109A']
# No common groups found between train and test sets.
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '007A' '008A' '009A' '010A'
#  '011A' '013B' '014B' '015A' '016A' '018A' '019B' '020A' '023A' '023B'
#  '025A' '025B' '025C' '026A' '026B' '026C' '027A' '028A' '031A' '032A'
#  '033A' '034A' '035A' '036A' '037A' '038A' '039A' '040A' '041A' '043A'
#  '044A' '045A' '046A' '048A' '049A' '051A' '051B' '052A' '053A' '054A'
#  '055A' '056A' '057A' '059A' '060A' '062A' '063A' '068A' '070A' '071A'
#  '072A' '073A' '074A' '075A' '088A' '090A' '092A' '094A' '097A' '097B'
#  '099A' '101A' '102A' '103A' '106A' '108A' '110A' '111A' '113A' '115A'
#  '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['004A' '005A' '006A' '012A' '014A' '019A' '021A' '022A' '024A' '029A'
#  '042A' '047A' '050A' '058A' '061A' '064A' '065A' '066A' '067A' '069A'
#  '076A' '087A' '091A' '093A' '095A' '096A' '100A' '104A' '105A' '109A']
# Length of X_train_val:
# 773
# Length of y_train_val:
# 773
# Length of groups_train_val:
# 773
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     480
# senior    174
# kitten    119
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     126
# kitten     57
# senior     12
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     480
# senior    174
# kitten    119
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     126
# kitten     57
# senior     12
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 480, 2: 174, 1: 119})
# Epoch 1/1500
# 13/13 [==============================] - 1s 5ms/step - loss: 1.3311 - accuracy: 0.4981
# Epoch 2/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.7555 - accuracy: 0.7516
# Epoch 3/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.5958 - accuracy: 0.7930
# Epoch 4/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4811 - accuracy: 0.8409
# Epoch 5/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4186 - accuracy: 0.8719
# Epoch 6/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3838 - accuracy: 0.8836
# Epoch 7/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3723 - accuracy: 0.8926
# Epoch 8/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3497 - accuracy: 0.8887
# Epoch 9/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3792 - accuracy: 0.8939
# Epoch 10/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3224 - accuracy: 0.9133
# Epoch 11/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2972 - accuracy: 0.9172
# Epoch 12/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3304 - accuracy: 0.9107
# Epoch 13/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3055 - accuracy: 0.9314
# Epoch 14/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2724 - accuracy: 0.9353
# Epoch 15/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3204 - accuracy: 0.9198
# Epoch 16/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2735 - accuracy: 0.9340
# Epoch 17/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2804 - accuracy: 0.9379
# Epoch 18/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2561 - accuracy: 0.9457
# Epoch 19/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2681 - accuracy: 0.9405
# Epoch 20/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2711 - accuracy: 0.9457
# Epoch 21/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.3013 - accuracy: 0.9263
# Epoch 22/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2463 - accuracy: 0.9444
# Epoch 23/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2324 - accuracy: 0.9379
# Epoch 24/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2291 - accuracy: 0.9508
# Epoch 25/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2258 - accuracy: 0.9534
# Epoch 26/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2334 - accuracy: 0.9560
# Epoch 27/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2514 - accuracy: 0.9470
# Epoch 28/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2502 - accuracy: 0.9353
# Epoch 29/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2509 - accuracy: 0.9379
# Epoch 30/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2432 - accuracy: 0.9366
# Epoch 31/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2324 - accuracy: 0.9470
# Epoch 32/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2556 - accuracy: 0.9457
# Epoch 33/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2452 - accuracy: 0.9405
# Epoch 34/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2333 - accuracy: 0.9379
# Epoch 35/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2353 - accuracy: 0.9508
# Epoch 36/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2400 - accuracy: 0.9431
# Epoch 37/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2257 - accuracy: 0.9547
# Epoch 38/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2366 - accuracy: 0.9405
# Epoch 39/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2327 - accuracy: 0.9521
# Epoch 40/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2289 - accuracy: 0.9534
# Epoch 41/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2216 - accuracy: 0.9508
# Epoch 42/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2174 - accuracy: 0.9560
# Epoch 43/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2259 - accuracy: 0.9586
# Epoch 44/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2104 - accuracy: 0.9521
# Epoch 45/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2044 - accuracy: 0.9560
# Epoch 46/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2080 - accuracy: 0.9534
# Epoch 47/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2107 - accuracy: 0.9573
# Epoch 48/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2199 - accuracy: 0.9470
# Epoch 49/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2228 - accuracy: 0.9444
# Epoch 50/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2146 - accuracy: 0.9547
# Epoch 51/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2193 - accuracy: 0.9483
# Epoch 52/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2173 - accuracy: 0.9638
# Epoch 53/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2168 - accuracy: 0.9521
# Epoch 54/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2159 - accuracy: 0.9599
# Epoch 55/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2183 - accuracy: 0.9560
# Epoch 56/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2061 - accuracy: 0.9470
# Epoch 57/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2107 - accuracy: 0.9612
# Epoch 58/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2097 - accuracy: 0.9534
# Epoch 59/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2162 - accuracy: 0.9638
# Epoch 60/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1960 - accuracy: 0.9573
# Epoch 61/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2140 - accuracy: 0.9586
# Epoch 62/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2162 - accuracy: 0.9560
# Epoch 63/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2186 - accuracy: 0.9379
# Epoch 64/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2089 - accuracy: 0.9457
# Epoch 65/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1921 - accuracy: 0.9547
# Epoch 66/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2097 - accuracy: 0.9547
# Epoch 67/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2000 - accuracy: 0.9728
# Epoch 68/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2008 - accuracy: 0.9521
# Epoch 69/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1969 - accuracy: 0.9612
# Epoch 70/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2138 - accuracy: 0.9586
# Epoch 71/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2082 - accuracy: 0.9651
# Epoch 72/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2050 - accuracy: 0.9560
# Epoch 73/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1932 - accuracy: 0.9728
# Epoch 74/1500
# 13/13 [==============================] - 0s 11ms/step - loss: 0.2044 - accuracy: 0.9677
# Epoch 75/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2032 - accuracy: 0.9677
# Epoch 76/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1865 - accuracy: 0.9586
# Epoch 77/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1930 - accuracy: 0.9625
# Epoch 78/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2144 - accuracy: 0.9470
# Epoch 79/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1948 - accuracy: 0.9638
# Epoch 80/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1965 - accuracy: 0.9612
# Epoch 81/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1872 - accuracy: 0.9586
# Epoch 82/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1955 - accuracy: 0.9599
# Epoch 83/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1881 - accuracy: 0.9651
# Epoch 84/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1884 - accuracy: 0.9521
# Epoch 85/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1927 - accuracy: 0.9651
# Epoch 86/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1904 - accuracy: 0.9651
# Epoch 87/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1898 - accuracy: 0.9625
# Epoch 88/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2007 - accuracy: 0.9470
# Epoch 89/1500
# 13/13 [==============================] - 0s 7ms/step - loss: 0.1925 - accuracy: 0.9625
# Epoch 90/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.
1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1659 - accuracy: 0.9679
# Epoch 198/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1621 - accuracy: 0.9718
# Epoch 199/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1854 - accuracy: 0.9744
# Epoch 200/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1607 - accuracy: 0.9692
# Epoch 201/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1595 - accuracy: 0.9718
# Epoch 202/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1555 - accuracy: 0.9756
# Epoch 203/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1569 - accuracy: 0.9769
# Epoch 204/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1534 - accuracy: 0.9872
# Epoch 205/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1579 - accuracy: 0.9769
# Epoch 206/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1582 - accuracy: 0.9679
# Epoch 207/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1603 - accuracy: 0.9744
# Epoch 208/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1568 - accuracy: 0.9731
# Epoch 209/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1657 - accuracy: 0.9679
# Epoch 210/1500
# 13/13 [==============================] - 0s 12ms/step - loss: 0.1580 - accuracy: 0.9782
# Epoch 211/1500
# 13/13 [==============================] - 0s 7ms/step - loss: 0.1603 - accuracy: 0.9692
# Epoch 212/1500
# 13/13 [==============================] - 0s 7ms/step - loss: 0.1574 - accuracy: 0.9744
# Epoch 213/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1636 - accuracy: 0.9692
# Epoch 214/1500
# 10/13 [======================>.......] - ETA: 0s - loss: 0.1585 - accuracy: 0.9672Restoring model weights from the end of the best epoch: 184.
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1570 - accuracy: 0.9667
# Epoch 214: early stopping
# 6/6 [==============================] - 0s 2ms/step - loss: 2.4250 - accuracy: 0.6436
# 6/6 [==============================] - 0s 2ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.81 (22/27)
# Before appending - Cat IDs: 686, Predictions: 686, Actuals: 686, Gender: 686
# After appending - Cat IDs: 874, Predictions: 874, Actuals: 874, Gender: 874
# Final Test Results - Loss: 2.425037384033203, Accuracy: 0.6436170339584351, Precision: 0.5151515151515151, Recall: 0.5580378492860559, F1 Score: 0.5024748027508698
# Confusion Matrix:
#  [[106   8   9]
#  [  4  10   0]
#  [ 44   2   5]]
#
# Final Average F1-Score across all UNSEEN TEST sets: 0.49024826379179787
#
# Final Average Loss across all UNSEEN TEST sets: 2.2289435267448425
#
# Final Average Accuracy across all UNSEEN TEST sets: 0.6287654489278793
#
# Final Average Precision across all UNSEEN TEST sets: 0.510161016220212
#
# Final Average Recall across all UNSEEN TEST sets: 0.5098997856730065

# %%
seed_2_folds_values = (unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1)

# Plotting all fold metrics
seed_2_folds_plot = plot_all_metrics(unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1, "Folds", "Fold Number")

# %% [markdown]
# ## Majority Voting on Total Entries per cat_id

# %%
# Debugging print statements
print(f'Checking - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
# Out:
# Checking - Cat IDs: 874, Predictions: 874, Actuals: 874, Gender: 874

# %%
# Create results df
full_results = pd.DataFrame({
    'cat_id': all_cat_ids,
    'predicted_age_group': all_predicted_age_groups,
    'actual_age_group': all_actual_age_groups,
    'all_gender': all_gender
})

# create a correct majority prediction column
full_results['correct'] = full_results['predicted_age_group'] == full_results['actual_age_group']

# %%
# Group by cat_id and aggregate predicted age groups
majority_votes = full_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first()

# Calculate the accuracy of majority voting
correct_predictions = (majority_votes == actual_groups).sum()
total_cats = len(actual_groups)
majority_vote_accuracy = correct_predictions / total_cats

logger(f"Overall Majority Vote Accuracy for cat_id: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

# store for final evaluation 
all_majority_vote_accuracies.append(majority_vote_accuracy)
# Out:
# Overall Majority Vote Accuracy for cat_id: 0.75 (82/110)

# %%
# Detailed df with predictions, actual labels, and comparison including majority vote
detailed_results = full_results.groupby('cat_id').apply(
    lambda x: pd.Series({
        'Predictions': list(x['predicted_age_group']),
        'Majority Vote': x['predicted_age_group'].mode()[0],
        'Actual Age Group': x['actual_age_group'].iloc[0],
        'Correct Majority Vote': x['predicted_age_group'].mode()[0] == x['actual_age_group'].iloc[0]
    })
).reset_index()

# Convert to DataFrame for better formatting and display
detailed_results = pd.DataFrame(detailed_results)

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 10)
pd.set_option('display.width', 1000)

sorted_detailed_results = detailed_results.sort_values(by='Correct Majority Vote', ascending=False)

# Display the sorted DataFrame
sorted_detailed_results
# Out:
#     cat_id                                        Predictions Majority Vote Actual Age Group  Correct Majority Vote
# 0     000B  [adult, adult, adult, senior, adult, adult, ad...         adult            adult                   True
# 45    039A  [senior, senior, adult, adult, senior, adult, ...         adult            adult                   True
# 76    070A               [adult, senior, adult, adult, adult]         adult            adult                   True
# 75    069A                                    [senior, adult]         adult            adult                   True
# 74    068A  [adult, adult, senior, adult, senior, adult, a...         adult            adult                   True
# 73    067A  [adult, adult, adult, kitten, adult, adult, ad...         adult            adult                   True
# 72    066A                                     [adult, adult]         adult            adult                   True
# 71    065A  [adult, adult, adult, kitten, kitten, adult, a...         adult            adult                   True
# 70    064A                              [adult, adult, adult]         adult            adult                   True
# 69    063A  [adult, adult, kitten, adult, adult, adult, ki...         adult            adult                   True
# 68    062A               [adult, adult, adult, kitten, adult]         adult            adult                   True
# 65    059A  [senior, adult, senior, senior, adult, senior,...        senior           senior                   True
# 64    058A                           [senior, senior, senior]        senior           senior                   True
# 59    053A  [adult, adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 58    052A                      [adult, adult, senior, adult]         adult            adult                   True
# 1     001A  [adult, senior, adult, adult, senior, senior, ...         adult            adult                   True
# 54    049A                                           [kitten]        kitten           kitten                   True
# 53    048A                                           [kitten]        kitten           kitten                   True
# 51    045A  [kitten, adult, kitten, kitten, kitten, kitten...        kitten           kitten                   True
# 49    043A                                           [kitten]        kitten           kitten                   True
# 47    041A                                           [kitten]        kitten           kitten                   True
# 77    071A  [adult, senior, adult, adult, adult, senior, s...         adult            adult                   True
# 78    072A  [adult, kitten, senior, adult, adult, kitten, ...         adult            adult                   True
# 79    073A                                            [adult]         adult            adult                   True
# 94    099A  [adult, adult, adult, kitten, adult, adult, ad...         adult            adult                   True
# 107   115A                                           [kitten]        kitten           kitten                   True
# 106   113A                           [senior, senior, senior]        senior           senior                   True
# 105   111A  [kitten, kitten, kitten, kitten, kitten, kitte...        kitten           kitten                   True
# 104   110A                                           [kitten]        kitten           kitten                   True
#
         adult           senior                  False

# %%
# Create df for majority votes
majority_df = majority_votes.reset_index()
majority_df.columns = ['cat_id', 'Majority_Vote']

# Get actual groups for each cat_id
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first().reset_index()

# Merge majority votes with actual groups
majority_with_actual = pd.merge(majority_df, actual_groups, on='cat_id')

# Add a column to check if the majority vote was correct
majority_with_actual['Majority_Correct'] = majority_with_actual['Majority_Vote'] == majority_with_actual['actual_age_group']

# Count correct majority votes per class
correct_majority_votes_per_class = majority_with_actual.groupby('actual_age_group')['Majority_Correct'].sum()

print("Correct Majority Votes per Class:")
print(correct_majority_votes_per_class)
# Out:
# Correct Majority Votes per Class:
# actual_age_group
# adult     68
# kitten    10
# senior     4
# Name: Majority_Correct, dtype: int64

# %%
# Calculate the total count and the number of correct predictions for each class
class_stats = majority_with_actual.groupby('actual_age_group').agg(
    total_count=('Majority_Correct', 'size'),  # Total number of cases per class
    correct_count=('Majority_Correct', 'sum')  # Sum of correct predictions per class
).reset_index()

# Calculate accuracy for each class
class_stats['accuracy'] = class_stats['correct_count'] / class_stats['total_count'] * 100

# store for final evaluation 
all_majority_vote_details.append(class_stats)

# Log detailed stats
print("Detailed Class Statistics for Majority Votes:")
print(class_stats)
# Out:
# Detailed Class Statistics for Majority Votes:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult           73             68  93.150685
# 1           kitten           15             10  66.666667
# 2           senior           22              4  18.181818

# %%
# Plot for Detailed Class Statistics for Majority Votes
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Accuracy of Majority Votes by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Detailed Class Statistics

# %%
# Calculate the total count and the number of correct predictions for each class
class_stats = full_results.groupby('actual_age_group').agg(
    total_count=('correct', 'size'),
    correct_count=('correct', 'sum')
).reset_index()

# Calculate accuracy for each class
class_stats['accuracy'] = class_stats['correct_count'] / class_stats['total_count'] * 100

# store for final evaluation 
all_class_stats.append(class_stats)

# Log the detailed stats
print("Detailed Class Statistics:")
print(class_stats)
# Out:
# Detailed Class Statistics:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult          568            449  79.049296
# 1           kitten          120             49  40.833333
# 2           senior          186             48  25.806452

# %%
# Plot for Detailed Class Statistics (Overall)
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Overall Accuracy by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Gender Exploration

# %%
# Group by gender and calculate the total count, correct predictions, and accuracy
gender_stats = full_results.groupby('all_gender').agg(
    count=('cat_id', 'size'),  # Total number of cases per gender
    correct=('correct', 'sum')  # Sum of correct predictions per gender
).reset_index()

# Calculate accuracy for each gender
gender_stats['accuracy'] = (gender_stats['correct'] / gender_stats['count'] * 100).round(2)

# Display the DataFrame
print("Accuracy by Gender:")
print(gender_stats)

# store for final evaluation 
all_gender_stats.append(gender_stats)
# Out:
# Accuracy by Gender:
#   all_gender  count  correct  accuracy
# 0          F    218      123     56.42
# 1          M    357      265     74.23
# 2          X    299      158     52.84

# %%
# Plot for Accuracy by Gender
styled_barplot(gender_stats, 'all_gender', 'accuracy', 
               'Accuracy by Gender', 
               'Gender', 'Accuracy (%)')

# %% [markdown]
# ### Log current total CV Stats

# %%
print("Total Majority Vote Accuracy so far:", all_majority_vote_accuracies)
print("Total Class Statistics so far:\n", all_class_stats)
print("Total Gender Accuracy so far:\n", all_gender_stats)
# Out:
# Total Majority Vote Accuracy so far: [0.8, 0.7454545454545455]
# Total Class Statistics so far:
#  [  actual_age_group  total_count  correct_count   accuracy
# 0            adult          573            466  81.326353
# 1           kitten          111             57  51.351351
# 2           senior          186             58  31.182796,   actual_age_group  total_count  correct_count   accuracy
# 0            adult          568            449  79.049296
# 1           kitten          120             49  40.833333
# 2           senior          186             48  25.806452]
# Total Gender Accuracy so far:
#  [  all_gender  count  correct  accuracy
# 0          F    218      138     63.30
# 1          M    362      271     74.86
# 2          X    290      172     59.31,   all_gender  count  correct  accuracy
# 0          F    218      123     56.42
# 1          M    357      265     74.23
# 2          X    299      158     52.84]

# %% [markdown]
# # RANDOM SEED 3

# %%
# Set a fixed random seed for reproducibility
random.seed(int(random_seeds[2]))
np.random.seed(int(random_seeds[2]))
tf.random.set_seed(int(random_seeds[2]))

# Load datasets
dataframe = pd.read_csv('/Users/astrid/PycharmProjects/data-aug-and-more/yamnet-tfhub-extraction/yamnet_embeddings_looped_april_23.csv')

def assign_age_group(age, age_groups):
    for group_name, age_range in age_groups.items():
        if age_range[0] <= age < age_range[1]:
            return group_name
    return 'Unknown'  # For any age that doesn't fit the defined groups

# Define age groups
age_groups = {
    'kitten': (0, 0.5),
    'adult': (0.5, 12),
    'senior': (12, 20)
}

# Create a new column for the age group
dataframe['age_group'] = dataframe['target'].apply(assign_age_group, age_groups=age_groups)

print(dataframe['age_group'].value_counts())
# Out:
# adult     606
# senior    186
# kitten    176
# Name: age_group, dtype: int64

# %%
# Separate features and labels
X = dataframe.iloc[:, :-4].values  # all columns except the last four

# Encode the 'age_group' column as integers using LabelEncoder
label_encoder = LabelEncoder()
encoded_y = label_encoder.fit_transform(dataframe['age_group'].values)

# Use the encoded labels for splitting and one-hot encoding
y = encoded_y  

# Convert 'cat_id' column to numpy array to be used as groups array for GroupKFold
groups = dataframe['cat_id'].values

# %%
tf.keras.backend.clear_session()

# %% [markdown]
# ## Run Setup

# %%
all_cat_ids = []
all_predicted_age_groups = []
all_actual_age_groups = []
all_gender = []

# Define the StratifiedGroupKFold splitter for 4 fold CV with random shuffling
outer_cv = StratifiedGroupKFold(n_splits=4, shuffle=True, random_state=int(random_seeds[2]))

# unseen test set metrics
unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1 = [], [], [], [], []

outer_fold = 0

# Use the splitter to generate indices for training and testing sets
# Note: GroupShuffleSplit.split returns indices, so we use it to index the arrays
for train_val_idx, test_idx in outer_cv.split(X, y, groups):
    outer_fold += 1
    logger(f"outer_fold {outer_fold}", file=log_file_path)

    # Convert indices back to DataFrame for easy manipulation
    df_train_val = dataframe.iloc[train_val_idx]
    df_test = dataframe.iloc[test_idx]

    ##############################
    # ASSESSING SPLITS BY CAT_ID #
    ##############################
    
    # Get the distribution of groups
    training_validation_group_distribution = df_train_val['cat_id'].value_counts()  
    testing_group_distribution = df_test['cat_id'].value_counts()  
    
    # Log or print the distribution
    logger(f"Train Set Group Distribution:\n{training_validation_group_distribution}", file=log_file_path)
    logger(f"Testing Set Group Distribution:\n{testing_group_distribution}", file=log_file_path)

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val['gender'].value_counts()
    testing_gender_distribution = df_test['gender'].value_counts()
    
    # Log the distribution
    logger(f"Training Set Gender Distribution BEFORE SWAP:\n{training_gender_distribution}", file=log_file_path)
    logger(f"Testing Set Gender Distribution BEFORE SWAP:\n{testing_gender_distribution}", file=log_file_path)

    # Group by 'age_group' and then list unique 'cat_id' within each age group
    unique_cat_ids_per_age_group_train_val = df_train_val.groupby('age_group')['cat_id'].unique()
    unique_cat_ids_per_age_group_test = df_test.groupby('age_group')['cat_id'].unique()
    
    # Log results
    logger(f"Unique Cat IDs per Age Group in Training/Validation Set:\n{unique_cat_ids_per_age_group_train_val}", file=log_file_path)
    logger(f"Unique Cat IDs per Age Group in Testing Set:\n{unique_cat_ids_per_age_group_test}", file=log_file_path)

    # Calculate the count of unique identifiers per age group for training and testing set
    counts_train_val = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_train_val.items()}
    counts_test = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_test.items()}

    # Log the counts of unique identifiers per age group
    logger(f"Count of Unique Cat IDs per Age Group in Training/Validation Set:\n{counts_train_val}", file=log_file_path)
    logger(f"Count of Unique Cat IDs per Age Group in Testing Set:\n{counts_test}", file=log_file_path)

    #######################################################
    # CONTINUE WITH ENSURING VALID AND APPROPRIATE SPLITS #
    #######################################################
    
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    groups_train_val, groups_test = groups[train_val_idx], groups[test_idx]

    # logging identifier splits 
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)

    # check group splits
    check_initial_group_split(groups_train_val, groups_test)

    # Specify the cat_ids that must be in the training/validation set
    specific_cat_ids = ['000A', '046A']
    
    # Perform the swapping operation
    train_val_idx, test_idx = swap_cat_id_instances(dataframe, train_val_idx, test_idx, specific_cat_ids)
    
    # Re-assign the sets based on the updated indices
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    new_groups_train_val, new_groups_test = groups[train_val_idx], groups[test_idx]

    # Find differences for training and test sets
    moved_to_train_val, removed_from_train_val = find_group_differences(groups_train_val, new_groups_train_val)
    moved_to_test, removed_from_test = find_group_differences(groups_test, new_groups_test)
    
    # Display the results
    logger(f"Moved to Training/Validation Set:\n{moved_to_train_val}", file=log_file_path)
    logger(f"Removed from Training/Validation Set:\n{removed_from_train_val}", file=log_file_path)
    logger(f"Moved to Test Set:\n{moved_to_test}", file=log_file_path)
    logger(f"Removed from Test Set\n{removed_from_test}", file=log_file_path)

    # Update X_train_val, X_test, y_train_val, y_test, groups_train_val, groups_test based on updated indices
    X_train_val = X[train_val_idx]
    y_train_val = y[train_val_idx]
    groups_train_val = groups[train_val_idx]
    
    X_test = X[test_idx]
    y_test = y[test_idx]
    groups_test = groups[test_idx]

    # logging identifier splits again after potential swaps
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"AFTER SWAP - Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"AFTER SWAP - Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)
    
    # Verify the lengths are consistent
    logger(f"Length of X_train_val:\n{len(X_train_val)}", file=log_file_path)
    logger(f"Length of y_train_val:\n{len(y_train_val)}", file=log_file_path)
    logger(f"Length of groups_train_val:\n{len(groups_train_val)}", file=log_file_path)

    # Check group splits once more
    check_initial_group_split(groups_train_val, groups_test)

    # Convert the modified indices back to a DataFrame representing the updated df_train_val
    df_train_val_updated = dataframe.iloc[train_val_idx].copy()
    df_test_updated = dataframe.iloc[test_idx].copy()

    ############################
    # LOGGING AGE GROUP SPLITS #
    ############################

    # Get the distribution of age groups of age groups before the update
    training_validation_age_group_distribution = df_train_val['age_group'].value_counts()
    testing_age_group_distribution = df_test['age_group'].value_counts()
    
    # Logthe distribution
    logger(f"Train Age Group Distribution BEFORE SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution BEFORE SWAP:\n{testing_age_group_distribution}", file=log_file_path)

    # Get the distribution of age groups after the update
    training_validation_age_group_distribution = df_train_val_updated['age_group'].value_counts()
    testing_age_group_distribution = df_test_updated['age_group'].value_counts()
    
    # Log the distribution
    logger(f"Train Age Group Distribution AFTER SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution AFTER SWAP:\n{testing_age_group_distribution}", file=log_file_path)
    
    ########################################################
    # TRACKING FINAL CAT_IDs & GENDER AFTER REDISTRIBUTION #
    ########################################################

    # Get the distribution of groups
    training_validation_group_distribution = df_train_val_updated['cat_id'].value_counts()  
    testing_group_distribution = df_test_updated['cat_id'].value_counts()  

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val_updated['gender'].value_counts()
    testing_gender_distribution = df_test_updated['gender'].value_counts()
    
    logger(f"\n Starting training on unseen test set\n", file=log_file_path)

    ###################
    # PREPARING MODEL #
    ###################

    # Calculate the distribution of age groups in y_train_val
    age_group_distribution = Counter(y_train_val)
    print("Age group distribution:", age_group_distribution)

    # EarlyStopping callback: monitor 'loss' instead of 'val_loss' for the test set
    early_stopping = EarlyStopping(
        monitor='loss',  
        min_delta=0.001, 
        patience=30,  
        verbose=1,  
        restore_best_weights=True  
    )

    # One final shuffle to ensure randomness
    outer_shuffle_idx = np.random.permutation(len(X_train_val))
    X_train_val = X_train_val[outer_shuffle_idx]
    y_train_val = y_train_val[outer_shuffle_idx]
    
    # Scale the features
    scaler_full = StandardScaler().fit(X_train_val)
    X_train_full_scaled = scaler_full.transform(X_train_val)
    X_test_scaled = scaler_full.transform(X_test)
    
    # Convert features to TensorFlow tensors
    X_train_full_scaled = tf.convert_to_tensor(X_train_full_scaled, dtype=tf.float32)
    X_test_scaled = tf.convert_to_tensor(X_test_scaled, dtype=tf.float32)
    
    # One-hot encode labels before mixup
    y_train_full_encoded = to_categorical(y_train_val)
    y_test_encoded = to_categorical(y_test)
    
    # Convert labels to TensorFlow tensors
    y_train_full_encoded = tf.convert_to_tensor(y_train_full_encoded, dtype=tf.float32)
    
    # Apply Mixup
    X_train_mix_outer, y_train_mix_outer = mixup_data(X_train_full_scaled, y_train_full_encoded, alpha=0.2)
    
    #######################
    # BUILD & TRAIN MODEL #
    #######################

    optimizers = {
        'Adamax': Adamax(learning_rate=0.00510251984616472)
    }
    
    # Model definition with dynamic number of layers
    model_full = Sequential()
    model_full.add(Dense(480, activation='relu', input_shape=(X_train_full_scaled.shape[1],)))
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.2011047009431978))  
    model_full.add(Dense(256, activation='relu',)) 
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.14956886311951184))  
    model_full.add(Dense(256, activation='relu'))  
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.42291461228250665))  
    model_full.add(Dense(3, activation='softmax'))  
    
    # Use the optimizer from the parameters
    optimizer = optimizers['Adamax']  # optimizer_key from parameters
    
    # Compile the model
    model_full.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    
    # Train the model on the full training set
    history_full = model_full.fit(X_train_mix_outer, y_train_mix_outer, epochs=1500, batch_size=64,
                                  verbose=1, callbacks=[early_stopping])
    
    # Evaluate the model on the held-out test set
    test_loss, test_accuracy = model_full.evaluate(X_test_scaled, y_test_encoded)

    y_test_pred_prob = model_full.predict(X_test_scaled)
    y_test_pred = np.argmax(y_test_pred_prob, axis=1)  
    y_test_true = np.argmax(y_test_encoded, axis=1)    

    ################################
    # LOG MAJORITY VOTE PER CAT_ID #
    ################################

    # Convert numeric predictions back to age group labels
    predicted_age_groups = label_encoder.inverse_transform(y_test_pred)
    actual_labels = label_encoder.inverse_transform(y_test_true)
    
    # Map predictions and actual labels back to cat_ids
    test_results = pd.DataFrame({
        'cat_id': df_test_updated['cat_id'],
        'predicted_age_group': predicted_age_groups,
        'actual_age_group': actual_labels
    })
    
    # Group by cat_id and aggregate predicted age groups
    majority_votes = test_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
    actual_groups = test_results.groupby('cat_id')['actual_age_group'].first()
    
    # Calculate the accuracy of majority voting
    correct_predictions = (majority_votes == actual_groups).sum()
    total_cats = len(actual_groups)
    majority_vote_accuracy = correct_predictions / total_cats
    
    # Log the accuracy of the majority voting
    logger(f"Majority Vote Accuracy for cat_id for this fold: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

    ####################################################
    # COLLECT PREDICTIONS FOR GENDER & CAT_ID ANALYSIS #
    ####################################################

    # Debugging print statements
    print(f'Before appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Extend lists with current fold results
    all_cat_ids.extend(df_test_updated['cat_id'].tolist())
    all_predicted_age_groups.extend(predicted_age_groups)
    all_actual_age_groups.extend(actual_labels)
    all_gender.extend(df_test_updated['gender'].tolist())

    # Debugging print statements
    print(f'After appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Calculate additional metrics
    test_precision = precision_score(y_test_true, y_test_pred, average='macro')  # Use 'macro' for imbalanced datasets
    test_recall = recall_score(y_test_true, y_test_pred, average='macro')
    test_f1 = f1_score(y_test_true, y_test_pred, average='macro')

    # prepare averages of outer metrics
    unseen_f1.append(test_f1)
    unseen_losses.append(test_loss)
    unseen_accuracies.append(test_accuracy)
    unseen_precisions.append(test_precision)
    unseen_recalls.append(test_recall)

    # Print final test results
    logger(f"Final Test Results - Loss: {test_loss}, Accuracy: {test_accuracy}, Precision: {test_precision}, Recall: {test_recall}, F1 Score: {test_f1}", file=log_file_path)

    # Generate the confusion matrix
    cm = confusion_matrix(y_test, y_test_pred)
    logger(f"Confusion Matrix:\n {cm}", file=log_file_path)

# Calculate the overall average metrics
unseen_set_avg_f1 = np.mean(unseen_f1)
unseen_set_avg_loss = np.mean(unseen_losses)
unseen_set_avg_acc = np.mean(unseen_accuracies)
unseen_set_avg_precision = np.mean(unseen_precisions)
unseen_set_avg_recall = np.mean(unseen_recalls)

logger(f"\nFinal Average F1-Score across all UNSEEN TEST sets: {unseen_set_avg_f1}", file=log_file_path)
logger(f"\nFinal Average Loss across all UNSEEN TEST sets: {unseen_set_avg_loss}", file=log_file_path)
logger(f"\nFinal Average Accuracy across all UNSEEN TEST sets: {unseen_set_avg_acc}", file=log_file_path)
logger(f"\nFinal Average Precision across all UNSEEN TEST sets: {unseen_set_avg_precision}", file=log_file_path)
logger(f"\nFinal Average Recall across all UNSEEN TEST sets: {unseen_set_avg_recall}\n", file=log_file_path)

# Append averages to total lists
all_f1.append(unseen_set_avg_f1)
all_losses.append(unseen_set_avg_loss)
all_accuracies.append(unseen_set_avg_acc)
all_precisions.append(unseen_set_avg_precision)
all_recalls.append(unseen_set_avg_recall)
# Out:
# outer_fold 1
# Train Set Group Distribution:
# 046A    66
# 000A    39
# 002B    36
# 103A    33
# 074A    25
# 067A    20
# 059A    18
# 019A    17
# 029A    17
# 101A    16
# 097A    16
# 106A    15
# 001A    15
# 028A    14
# 042A    14
# 111A    13
# 002A    13
# 051A    12
# 039A    12
# 116A    12
# 016A    11
# 025A    11
# 063A    11
# 071A    10
# 040A    10
# 015A    10
# 014B    10
# 022A     9
# 033A     9
# 072A     9
# 065A     9
# 095A     8
# 010A     8
# 117A     7
# 050A     7
# 031A     7
# 027A     7
# 023A     6
# 008A     6
# 021A     6
# 109A     6
# 108A     6
# 007A     6
# 037A     6
# 034A     5
# 075A     5
# 023B     5
# 012A     5
# 062A     5
# 035A     4
# 003A     4
# 009A     4
# 052A     4
# 104A     4
# 026A     4
# 064A     3
# 058A     3
# 011A     3
# 014A     3
# 056A     3
# 006A     3
# 113A     3
# 060A     3
# 066A     2
# 025B     2
# 087A     2
# 093A     2
# 018A     2
# 032A     2
# 054A     2
# 102A     2
# 069A     2
# 038A     2
# 088A     1
# 024A     1
# 076A     1
# 090A     1
# 115A     1
# 041A     1
# 091A     1
# 026C     1
# 110A     1
# 019B     1
# 096A     1
# 049A     1
# 092A     1
# 026B     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 047A    30
# 057A    28
# 020A    23
# 000B    20
# 055A    20
# 097B    14
# 005A    11
# 036A    11
# 068A    11
# 045A     9
# 051B     9
# 013B     8
# 094A     8
# 099A     7
# 053A     7
# 025C     6
# 044A     5
# 070A     5
# 105A     4
# 061A     2
# 043A     1
# 073A     1
# 048A     1
# 004A     1
# 100A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    292
# X    244
# F    189
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    111
# F     68
# M     64
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [002A, 028A, 033A, 071A, 000A, 015A, 026A, 065...
# kitten    [046A, 042A, 014B, 110A, 109A, 040A, 049A, 111...
# senior    [117A, 106A, 090A, 113A, 116A, 051A, 024A, 097...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [070A, 000B, 020A, 053A, 068A, 105A, 013B, 005...
# kitten                       [047A, 045A, 048A, 044A, 043A]
# senior                       [057A, 051B, 094A, 055A, 061A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 59, 'kitten': 11, 'senior': 17}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 15, 'kitten': 5, 'senior': 5}
# Unique Training/Validation Group IDs:
# ['000A' '001A' '002A' '002B' '003A' '006A' '007A' '008A' '009A' '010A'
#  '011A' '012A' '014A' '014B' '015A' '016A' '018A' '019A' '019B' '021A'
#  '022A' '023A' '023B' '024A' '025A' '025B' '026A' '026B' '026C' '027A'
#  '028A' '029A' '031A' '032A' '033A' '034A' '035A' '037A' '038A' '039A'
#  '040A' '041A' '042A' '046A' '049A' '050A' '051A' '052A' '054A' '056A'
#  '058A' '059A' '060A' '062A' '063A' '064A' '065A' '066A' '067A' '069A'
#  '071A' '072A' '074A' '075A' '076A' '087A' '088A' '090A' '091A' '092A'
#  '093A' '095A' '096A' '097A' '101A' '102A' '103A' '104A' '106A' '108A'
#  '109A' '110A' '111A' '113A' '115A' '116A' '117A']
# Unique Test Group IDs:
# ['000B' '004A' '005A' '013B' '020A' '025C' '036A' '043A' '044A' '045A'
#  '047A' '048A' '051B' '053A' '055A' '057A' '061A' '068A' '070A' '073A'
#  '094A' '097B' '099A' '100A' '105A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '001A' '002A' '002B' '003A' '006A' '007A' '008A' '009A' '010A'
#  '011A' '012A' '014A' '014B' '015A' '016A' '018A' '019A' '019B' '021A'
#  '022A' '023A' '023B' '024A' '025A' '025B' '026A' '026B' '026C' '027A'
#  '028A' '029A' '031A' '032A' '033A' '034A' '035A' '037A' '038A' '039A'
#  '040A' '041A' '042A' '046A' '049A' '050A' '051A' '052A' '054A' '056A'
#  '058A' '059A' '060A' '062A' '063A' '064A' '065A' '066A' '067A' '069A'
#  '071A' '072A' '074A' '075A' '076A' '087A' '088A' '090A' '091A' '092A'
#  '093A' '095A' '096A' '097A' '101A' '102A' '103A' '104A' '106A' '108A'
#  '109A' '110A' '111A' '113A' '115A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['000B' '004A' '005A' '013B' '020A' '025C' '036A' '043A' '044A' '045A'
#  '047A' '048A' '051B' '053A' '055A' '057A' '061A' '068A' '070A' '073A'
#  '094A' '097B' '099A' '100A' '105A']
# Length of X_train_val:
# 725
# Length of y_train_val:
# 725
# Length of groups_train_val:
# 725
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     476
# kitten    130
# senior    119
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     130
# senior     67
# kitten     46
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     476
# kitten    130
# senior    119
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     130
# senior     67
# kitten     46
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 476, 1: 130, 2: 119})
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Epoch 1/1500
# 12/12 [==============================] - 1s 5ms/step - loss: 1.3494 - accuracy: 0.5255
# Epoch 2/1500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.7402 - accuracy: 0.7366
# Epoch 3/1500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.5216 - accuracy: 0.8345
# Epoch 4/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.
1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1340 - accuracy: 0.9752
# Epoch 197/1500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1372 - accuracy: 0.9752
# Epoch 198/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1334 - accuracy: 0.9793
# Epoch 199/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1374 - accuracy: 0.9793
# Epoch 200/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1321 - accuracy: 0.9862
# Epoch 201/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1326 - accuracy: 0.9697
# Epoch 202/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1343 - accuracy: 0.9834
# Epoch 203/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1322 - accuracy: 0.9834
# Epoch 204/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1317 - accuracy: 0.9766
# Epoch 205/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1292 - accuracy: 0.9807
# Epoch 206/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1298 - accuracy: 0.9752
# Epoch 207/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1320 - accuracy: 0.9766
# Epoch 208/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1337 - accuracy: 0.9848
# Epoch 209/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1323 - accuracy: 0.9738
# Epoch 210/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1351 - accuracy: 0.9766
# Epoch 211/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1323 - accuracy: 0.9697
# Epoch 212/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1330 - accuracy: 0.9821
# Epoch 213/1500
# 10/12 [========================>.....] - ETA: 0s - loss: 0.1345 - accuracy: 0.9812Restoring model weights from the end of the best epoch: 183.
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1367 - accuracy: 0.9793
# Epoch 213: early stopping
# 8/8 [==============================] - 0s 1ms/step - loss: 1.8794 - accuracy: 0.5802
# 8/8 [==============================] - 0s 2ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.76 (19/25)
# Before appending - Cat IDs: 0, Predictions: 0, Actuals: 0, Gender: 0
# After appending - Cat IDs: 243, Predictions: 243, Actuals: 243, Gender: 243
# Final Test Results - Loss: 1.8794268369674683, Accuracy: 0.5802469253540039, Precision: 0.5736542210226421, Recall: 0.4747516597613937, F1 Score: 0.48302304964539006
# Confusion Matrix:
#  [[111   7  12]
#  [ 25  18   3]
#  [ 54   1  12]]
# outer_fold 2
# Train Set Group Distribution:
# 046A    66
# 000A    39
# 103A    33
# 047A    30
# 057A    28
# 074A    25
# 020A    23
# 000B    20
# 067A    20
# 055A    20
# 059A    18
# 019A    17
# 097A    16
# 001A    15
# 097B    14
# 028A    14
# 111A    13
# 002A    13
# 116A    12
# 051A    12
# 039A    12
# 005A    11
# 068A    11
# 036A    11
# 025A    11
# 071A    10
# 014B    10
# 051B     9
# 072A     9
# 033A     9
# 045A     9
# 022A     9
# 094A     8
# 013B     8
# 053A     7
# 050A     7
# 117A     7
# 099A     7
# 031A     7
# 027A     7
# 008A     6
# 108A     6
# 021A     6
# 037A     6
# 007A     6
# 025C     6
# 044A     5
# 012A     5
# 070A     5
# 026A     4
# 104A     4
# 035A     4
# 003A     4
# 105A     4
# 052A     4
# 060A     3
# 064A     3
# 014A     3
# 056A     3
# 058A     3
# 006A     3
# 038A     2
# 032A     2
# 102A     2
# 061A     2
# 087A     2
# 066A     2
# 069A     2
# 018A     2
# 026B     1
# 004A     1
# 076A     1
# 115A     1
# 090A     1
# 043A     1
# 091A     1
# 024A     1
# 026C     1
# 048A     1
# 049A     1
# 073A     1
# 110A     1
# 100A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 002B    36
# 029A    17
# 101A    16
# 106A    15
# 042A    14
# 063A    11
# 016A    11
# 015A    10
# 040A    10
# 065A     9
# 010A     8
# 095A     8
# 109A     6
# 023A     6
# 034A     5
# 023B     5
# 075A     5
# 062A     5
# 009A     4
# 113A     3
# 011A     3
# 025B     2
# 093A     2
# 054A     2
# 088A     1
# 096A     1
# 019B     1
# 041A     1
# 092A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    297
# M    233
# F    220
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# M    123
# X     58
# F     37
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [002A, 028A, 070A, 033A, 000B, 071A, 020A, 000...
# kitten    [046A, 014B, 110A, 047A, 049A, 045A, 048A, 111...
# senior    [117A, 057A, 090A, 051B, 116A, 051A, 024A, 097...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [015A, 065A, 023B, 034A, 062A, 002B, 009A, 101...
# kitten                             [042A, 109A, 040A, 041A]
# senior                 [106A, 113A, 016A, 054A, 011A, 093A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 55, 'kitten': 12, 'senior': 16}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 19, 'kitten': 4, 'senior': 6}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '003A' '004A' '005A' '006A' '007A' '008A'
#  '012A' '013B' '014A' '014B' '018A' '019A' '020A' '021A' '022A' '024A'
#  '025A' '025C' '026A' '026B' '026C' '027A' '028A' '031A' '032A' '033A'
#  '035A' '036A' '037A' '038A' '039A' '043A' '044A' '045A' '046A' '047A'
#  '048A' '049A' '050A' '051A' '051B' '052A' '053A' '055A' '056A' '057A'
#  '058A' '059A' '060A' '061A' '064A' '066A' '067A' '068A' '069A' '070A'
#  '071A' '072A' '073A' '074A' '076A' '087A' '090A' '091A' '094A' '097A'
#  '097B' '099A' '100A' '102A' '103A' '104A' '105A' '108A' '110A' '111A'
#  '115A' '116A' '117A']
# Unique Test Group IDs:
# ['002B' '009A' '010A' '011A' '015A' '016A' '019B' '023A' '023B' '025B'
#  '029A' '034A' '040A' '041A' '042A' '054A' '062A' '063A' '065A' '075A'
#  '088A' '092A' '093A' '095A' '096A' '101A' '106A' '109A' '113A']
# No common groups found between train and test sets.
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '003A' '004A' '005A' '006A' '007A' '008A'
#  '012A' '013B' '014A' '014B' '018A' '019A' '020A' '021A' '022A' '024A'
#  '025A' '025C' '026A' '026B' '026C' '027A' '028A' '031A' '032A' '033A'
#  '035A' '036A' '037A' '038A' '039A' '043A' '044A' '045A' '046A' '047A'
#  '048A' '049A' '050A' '051A' '051B' '052A' '053A' '055A' '056A' '057A'
#  '058A' '059A' '060A' '061A' '064A' '066A' '067A' '068A' '069A' '070A'
#  '071A' '072A' '073A' '074A' '076A' '087A' '090A' '091A' '094A' '097A'
#  '097B' '099A' '100A' '102A' '103A' '104A' '105A' '108A' '110A' '111A'
#  '115A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['002B' '009A' '010A' '011A' '015A' '016A' '019B' '023A' '023B' '025B'
#  '029A' '034A' '040A' '041A' '042A' '054A' '062A' '063A' '065A' '075A'
#  '088A' '092A' '093A' '095A' '096A' '101A' '106A' '109A' '113A']
# Length of X_train_val:
# 750
# Length of y_train_val:
# 750
# Length of groups_train_val:
# 750
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     455
# senior    150
# kitten    145
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     151
# senior     36
# kitten     31
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     455
# senior    150
# kitten    145
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     151
# senior     36
# kitten     31
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 455, 2: 150, 1: 145})
# Epoch 1/1500
# 12/12 [==============================] - 1s 5ms/step - loss: 1.3960 - accuracy: 0.5093
# Epoch 2/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.7628 - accuracy: 0.7387
# Epoch 3/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.6255 - accuracy: 0.7787
# Epoch 4/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.5070 - accuracy: 0.8507
# Epoch 5/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4479 - accuracy: 0.8667
# Epoch 6/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.4002 - accuracy: 0.8920
# Epoch 7/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.3469 - accuracy: 0.8947
# Epoch 8/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.3317 - accuracy: 0.9107
# Epoch 9/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.3300 - accuracy: 0.9093
# Epoch 10/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.2990 - accuracy: 0.9227
# Epoch 11/1500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.2806 - accuracy: 0.9373
# Epoch 12/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.3138 - accuracy: 0.9307
# Epoch 13/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.2839 - accuracy: 0.9200
# Epoch 14/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.2697 - accuracy: 0.9400
# Epoch 15/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.2640 - accuracy: 0.9307
# Epoch 16/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.2590 - accuracy: 0.9453
# Epoch 17/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.2507 - accuracy: 0.9440
# Epoch 18/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.2489 - accuracy: 0.9560
# Epoch 19/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.2337 - accuracy: 0.9467
# Epoch 20/1500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.2399 - accuracy: 0.9507
# Epoch 21/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.2338 - accuracy: 0.9387
# Epoch 22/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.2400 - accuracy: 0.9520
# Epoch 23/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.2426 - accuracy: 0.9480
# Epoch 24/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.2446 - accuracy: 0.9427
# Epoch 25/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.2475 - accuracy: 0.9480
# Epoch 26/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.2236 - accuracy: 0.9573
# Epoch 27/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.2266 - accuracy: 0.9493
# Epoch 28/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.2344 - accuracy: 0.9360
# Epoch 29/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.2269 - accuracy: 0.9560
# Epoch 30/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.2234 - accuracy: 0.9533
# Epoch 31/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.2220 - accuracy: 0.9520
# Epoch 32/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.2112 - accuracy: 0.9640
# Epoch 33/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.2156 - accuracy: 0.9467
# Epoch 34/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.2059 - accuracy: 0.9613
# Epoch 35/1500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.2120 - accuracy: 0.9587
# Epoch 36/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.2075 - accuracy: 0.9547
# Epoch 37/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.2004 - accuracy: 0.9600
# Epoch 38/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.2083 - accuracy: 0.9467
# Epoch 39/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.2027 - accuracy: 0.9733
# Epoch 40/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1966 - accuracy: 0.9560
# Epoch 41/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1983 - accuracy: 0.9520
# Epoch 42/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1965 - accuracy: 0.9640
# Epoch 43/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1930 - accuracy: 0.9693
# Epoch 44/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1957 - accuracy: 0.9667
# Epoch 45/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1902 - accuracy: 0.9707
# Epoch 46/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.2009 - accuracy: 0.9520
# Epoch 47/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1930 - accuracy: 0.9520
# Epoch 48/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1967 - accuracy: 0.9600
# Epoch 49/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1971 - accuracy: 0.9547
# Epoch 50/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1957 - accuracy: 0.9467
# Epoch 51/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1946 - accuracy: 0.9640
# Epoch 52/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1922 - accuracy: 0.9640
# Epoch 53/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1909 - accuracy: 0.9627
# Epoch 54/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1900 - accuracy: 0.9640
# Epoch 55/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1866 - accuracy: 0.9627
# Epoch 56/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1864 - accuracy: 0.9547
# Epoch 57/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1822 - accuracy: 0.9627
# Epoch 58/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1895 - accuracy: 0.9640
# Epoch 59/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1848 - accuracy: 0.9560
# Epoch 60/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1897 - accuracy: 0.9600
# Epoch 61/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1888 - accuracy: 0.9613
# Epoch 62/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1870 - accuracy: 0.9613
# Epoch 63/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1816 - accuracy: 0.9640
# Epoch 64/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1915 - accuracy: 0.9667
# Epoch 65/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1857 - accuracy: 0.9560
# Epoch 66/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1851 - accuracy: 0.9627
# Epoch 67/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1849 - accuracy: 0.9587
# Epoch 68/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1861 - accuracy: 0.9547
# Epoch 69/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1775 - accuracy: 0.9680
# Epoch 70/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1823 - accuracy: 0.9520
# Epoch 71/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1752 - accuracy: 0.9707
# Epoch 72/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1757 - accuracy: 0.9773
# Epoch 73/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1721 - accuracy: 0.9733
# Epoch 74/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.
1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1397 - accuracy: 0.9735
# Epoch 174/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1376 - accuracy: 0.9773
# Epoch 175/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1385 - accuracy: 0.9747
# Epoch 176/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1348 - accuracy: 0.9785
# Epoch 177/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1371 - accuracy: 0.9811
# Epoch 178/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1374 - accuracy: 0.9811
# Epoch 179/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1385 - accuracy: 0.9710
# Epoch 180/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1412 - accuracy: 0.9747
# Epoch 181/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1355 - accuracy: 0.9747
# Epoch 182/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1362 - accuracy: 0.9747
# Epoch 183/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1393 - accuracy: 0.9710
# Epoch 184/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1372 - accuracy: 0.9747
# Epoch 185/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1378 - accuracy: 0.9735
# Epoch 186/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1405 - accuracy: 0.9798
# Epoch 187/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1358 - accuracy: 0.9798
# Epoch 188/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1355 - accuracy: 0.9811
# Epoch 189/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1385 - accuracy: 0.9747
# Epoch 190/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1365 - accuracy: 0.9747
# Epoch 191/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1348 - accuracy: 0.9798
# Epoch 192/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1382 - accuracy: 0.9798
# Epoch 193/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1382 - accuracy: 0.9710
# Epoch 194/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1403 - accuracy: 0.9760
# Epoch 195/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1352 - accuracy: 0.9823
# Epoch 196/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1389 - accuracy: 0.9684
# Epoch 197/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1372 - accuracy: 0.9773
# Epoch 198/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1377 - accuracy: 0.9823
# Epoch 199/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1367 - accuracy: 0.9735
# Epoch 200/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1339 - accuracy: 0.9861
# Epoch 201/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1345 - accuracy: 0.9811
# Epoch 202/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1363 - accuracy: 0.9760
# Epoch 203/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1342 - accuracy: 0.9848
# Epoch 204/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1368 - accuracy: 0.9747
# Epoch 205/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1364 - accuracy: 0.9773
# Epoch 206/1500
# 11/13 [========================>.....] - ETA: 0s - loss: 0.1361 - accuracy: 0.9759Restoring model weights from the end of the best epoch: 176.
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1400 - accuracy: 0.9735
# Epoch 206: early stopping
# 6/6 [==============================] - 0s 2ms/step - loss: 3.2126 - accuracy: 0.6932
# 6/6 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.78 (21/27)
# Before appending - Cat IDs: 701, Predictions: 701, Actuals: 701, Gender: 701
# After appending - Cat IDs: 877, Predictions: 877, Actuals: 877, Gender: 877
# Final Test Results - Loss: 3.21258544921875, Accuracy: 0.6931818127632141, Precision: 0.6115464994775339, Recall: 0.5241691234514201, F1 Score: 0.5534803285776048
# Confusion Matrix:
#  [[102   4  15]
#  [ 11   7   1]
#  [ 23   0  13]]
#
# Final Average F1-Score across all UNSEEN TEST sets: 0.5425183363204972
#
# Final Average Loss across all UNSEEN TEST sets: 1.956924945116043
#
# Final Average Accuracy across all UNSEEN TEST sets: 0.6551595479249954
#
# Final Average Precision across all UNSEEN TEST sets: 0.5762717034234559
#
# Final Average Recall across all UNSEEN TEST sets: 0.5461776762621585

# %%
seed_3_folds_values = (unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1)

# Plotting all fold metrics
seed_3_folds_plot = plot_all_metrics(unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1, "Folds", "Fold Number")

# %% [markdown]
# ## Majority Voting on Total Entries per cat_id

# %%
# Debugging print statements
print(f'Checking - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
# Out:
# Checking - Cat IDs: 877, Predictions: 877, Actuals: 877, Gender: 877

# %%
# Create results df
full_results = pd.DataFrame({
    'cat_id': all_cat_ids,
    'predicted_age_group': all_predicted_age_groups,
    'actual_age_group': all_actual_age_groups,
    'all_gender': all_gender
})

# create a correct majority prediction column
full_results['correct'] = full_results['predicted_age_group'] == full_results['actual_age_group']

# %%
# Group by cat_id and aggregate predicted age groups
majority_votes = full_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first()

# Calculate the accuracy of majority voting
correct_predictions = (majority_votes == actual_groups).sum()
total_cats = len(actual_groups)
majority_vote_accuracy = correct_predictions / total_cats

logger(f"Overall Majority Vote Accuracy for cat_id: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

# store for final evaluation 
all_majority_vote_accuracies.append(majority_vote_accuracy)
# Out:
# Overall Majority Vote Accuracy for cat_id: 0.77 (85/110)

# %%
# Detailed df with predictions, actual labels, and comparison including majority vote
detailed_results = full_results.groupby('cat_id').apply(
    lambda x: pd.Series({
        'Predictions': list(x['predicted_age_group']),
        'Majority Vote': x['predicted_age_group'].mode()[0],
        'Actual Age Group': x['actual_age_group'].iloc[0],
        'Correct Majority Vote': x['predicted_age_group'].mode()[0] == x['actual_age_group'].iloc[0]
    })
).reset_index()

# Convert to DataFrame for better formatting and display
detailed_results = pd.DataFrame(detailed_results)

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 10)
pd.set_option('display.width', 1000)

sorted_detailed_results = detailed_results.sort_values(by='Correct Majority Vote', ascending=False)

# Display the sorted DataFrame
sorted_detailed_results
# Out:
#     cat_id                                        Predictions Majority Vote Actual Age Group  Correct Majority Vote
# 0     000B  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 54    049A                                           [kitten]        kitten           kitten                   True
# 66    060A                             [kitten, adult, adult]         adult            adult                   True
# 65    059A  [senior, senior, senior, senior, adult, senior...        senior           senior                   True
# 64    058A                            [senior, adult, senior]        senior           senior                   True
# 62    056A                            [senior, senior, adult]        senior           senior                   True
# 100   105A                      [adult, adult, adult, kitten]         adult            adult                   True
# 59    053A  [adult, adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 58    052A                       [adult, adult, adult, adult]         adult            adult                   True
# 1     001A  [adult, adult, adult, senior, adult, adult, ad...         adult            adult                   True
# 53    048A                                           [kitten]        kitten           kitten                   True
# 68    062A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 104   110A                                           [kitten]        kitten           kitten                   True
# 51    045A  [kitten, adult, kitten, kitten, kitten, kitten...        kitten           kitten                   True
# 50    044A            [kitten, kitten, adult, kitten, kitten]        kitten           kitten                   True
# 49    043A                                           [kitten]        kitten           kitten                   True
#
[adult, adult, adult, adult, adult, adult, adu...         adult           senior                  False
# 12    011A                             [senior, adult, adult]         adult           senior                  False
# 16    014B  [adult, adult, adult, kitten, senior, kitten, ...         adult           kitten                  False
# 18    016A  [adult, adult, adult, senior, adult, adult, ad...         adult           senior                  False
# 21    019B                                           [senior]        senior            adult                  False
# 52    047A  [adult, senior, adult, adult, adult, kitten, a...         adult           kitten                  False
# 56    051A  [senior, senior, adult, adult, senior, adult, ...         adult           senior                  False
# 60    054A                                     [adult, adult]         adult           senior                  False
# 91    096A                                           [kitten]        kitten            adult                  False
# 61    055A  [adult, adult, adult, adult, adult, adult, adu...         adult           senior                  False
# 63    057A  [adult, adult, adult, adult, adult, senior, ad...         adult           senior                  False
# 67    061A                                     [adult, adult]         adult           senior                  False
# 69    063A  [kitten, kitten, kitten, kitten, kitten, adult...        kitten            adult                  False
# 85    090A                                            [adult]         adult           senior                  False
# 88    093A                                    [adult, kitten]         adult           senior                  False
# 109   117A  [adult, adult, adult, senior, adult, adult, ad...         adult           senior                  False

# %%
# Create df for majority votes
majority_df = majority_votes.reset_index()
majority_df.columns = ['cat_id', 'Majority_Vote']

# Get actual groups for each cat_id
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first().reset_index()

# Merge majority votes with actual groups
majority_with_actual = pd.merge(majority_df, actual_groups, on='cat_id')

# Add a column to check if the majority vote was correct
majority_with_actual['Majority_Correct'] = majority_with_actual['Majority_Vote'] == majority_with_actual['actual_age_group']

# Count correct majority votes per class
correct_majority_votes_per_class = majority_with_actual.groupby('actual_age_group')['Majority_Correct'].sum()

print("Correct Majority Votes per Class:")
print(correct_majority_votes_per_class)
# Out:
# Correct Majority Votes per Class:
# actual_age_group
# adult     68
# kitten    11
# senior     6
# Name: Majority_Correct, dtype: int64

# %%
# Calculate the total count and the number of correct predictions for each class
class_stats = majority_with_actual.groupby('actual_age_group').agg(
    total_count=('Majority_Correct', 'size'),  # Total number of cases per class
    correct_count=('Majority_Correct', 'sum')  # Sum of correct predictions per class
).reset_index()

# Calculate accuracy for each class
class_stats['accuracy'] = class_stats['correct_count'] / class_stats['total_count'] * 100

# store for final evaluation 
all_majority_vote_details.append(class_stats)

# Log detailed stats
print("Detailed Class Statistics for Majority Votes:")
print(class_stats)
# Out:
# Detailed Class Statistics for Majority Votes:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult           73             68  93.150685
# 1           kitten           15             11  73.333333
# 2           senior           22              6  27.272727

# %%
# Plot for Detailed Class Statistics for Majority Votes
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Accuracy of Majority Votes by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Detailed Class Statistics

# %%
# Calculate the total count and the number of correct predictions for each class
class_stats = full_results.groupby('actual_age_group').agg(
    total_count=('correct', 'size'),
    correct_count=('correct', 'sum')
).reset_index()

# Calculate accuracy for each class
class_stats['accuracy'] = class_stats['correct_count'] / class_stats['total_count'] * 100

# store for final evaluation 
all_class_stats.append(class_stats)

# Log the detailed stats
print("Detailed Class Statistics:")
print(class_stats)
# Out:
# Detailed Class Statistics:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult          574            455  79.268293
# 1           kitten          117             56  47.863248
# 2           senior          186             61  32.795699

# %%
# Plot for Detailed Class Statistics (Overall)
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Overall Accuracy by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Gender Exploration

# %%
# Group by gender and calculate the total count, correct predictions, and accuracy
gender_stats = full_results.groupby('all_gender').agg(
    count=('cat_id', 'size'),  # Total number of cases per gender
    correct=('correct', 'sum')  # Sum of correct predictions per gender
).reset_index()

# Calculate accuracy for each gender
gender_stats['accuracy'] = (gender_stats['correct'] / gender_stats['count'] * 100).round(2)

# Display the DataFrame
print("Accuracy by Gender:")
print(gender_stats)

# store for final evaluation 
all_gender_stats.append(gender_stats)
# Out:
# Accuracy by Gender:
#   all_gender  count  correct  accuracy
# 0          F    225      141     62.67
# 1          M    356      273     76.69
# 2          X    296      158     53.38

# %%
# Plot for Accuracy by Gender
styled_barplot(gender_stats, 'all_gender', 'accuracy', 
               'Accuracy by Gender', 
               'Gender', 'Accuracy (%)')

# %% [markdown]
# ### Log current total CV Stats

# %%
print("Total Majority Vote Accuracy so far:", all_majority_vote_accuracies)
print("Total Class Statistics so far:\n", all_class_stats)
print("Total Gender Accuracy so far:\n", all_gender_stats)
# Out:
# Total Majority Vote Accuracy so far: [0.8, 0.7454545454545455, 0.7727272727272727]
# Total Class Statistics so far:
#  [  actual_age_group  total_count  correct_count   accuracy
# 0            adult          573            466  81.326353
# 1           kitten          111             57  51.351351
# 2           senior          186             58  31.182796,   actual_age_group  total_count  correct_count   accuracy
# 0            adult          568            449  79.049296
# 1           kitten          120             49  40.833333
# 2           senior          186             48  25.806452,   actual_age_group  total_count  correct_count   accuracy
# 0            adult          574            455  79.268293
# 1           kitten          117             56  47.863248
# 2           senior          186             61  32.795699]
# Total Gender Accuracy so far:
#  [  all_gender  count  correct  accuracy
# 0          F    218      138     63.30
# 1          M    362      271     74.86
# 2          X    290      172     59.31,   all_gender  count  correct  accuracy
# 0          F    218      123     56.42
# 1          M    357      265     74.23
# 2          X    299      158     52.84,   all_gender  count  correct  accuracy
# 0          F    225      141     62.67
# 1          M    356      273     76.69
# 2          X    296      158     53.38]

# %% [markdown]
# # RANDOM SEED 4

# %%
# Set a fixed random seed for reproducibility
random.seed(int(random_seeds[3])) 
np.random.seed(int(random_seeds[3]))
tf.random.set_seed(int(random_seeds[3]))

# Load datasets
dataframe = pd.read_csv('/Users/astrid/PycharmProjects/data-aug-and-more/yamnet-tfhub-extraction/yamnet_embeddings_looped_april_23.csv')

def assign_age_group(age, age_groups):
    for group_name, age_range in age_groups.items():
        if age_range[0] <= age < age_range[1]:
            return group_name
    return 'Unknown'  # For any age that doesn't fit the defined groups

# Define age groups
age_groups = {
    'kitten': (0, 0.5),
    'adult': (0.5, 12),
    'senior': (12, 20)
}

# Create a new column for the age group
dataframe['age_group'] = dataframe['target'].apply(assign_age_group, age_groups=age_groups)

print(dataframe['age_group'].value_counts())
# Out:
# adult     606
# senior    186
# kitten    176
# Name: age_group, dtype: int64

# %%
# Separate features and labels
X = dataframe.iloc[:, :-4].values  # all columns except the last four

# Encode the 'age_group' column as integers using LabelEncoder
label_encoder = LabelEncoder()
encoded_y = label_encoder.fit_transform(dataframe['age_group'].values)

# Use the encoded labels for splitting and one-hot encoding
y = encoded_y  

# Convert 'cat_id' column to numpy array to be used as groups array for GroupKFold
groups = dataframe['cat_id'].values

# %%
tf.keras.backend.clear_session()

# %% [markdown]
# ## Run Setup

# %%
all_cat_ids = []
all_predicted_age_groups = []
all_actual_age_groups = []
all_gender = []

# Define the StratifiedGroupKFold splitter for 4 fold CV with random shuffling
outer_cv = StratifiedGroupKFold(n_splits=4, shuffle=True, random_state=int(random_seeds[3]))

# unseen test set metrics
unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1 = [], [], [], [], []

outer_fold = 0

# Use the splitter to generate indices for training and testing sets
# Note: GroupShuffleSplit.split returns indices, so we use it to index the arrays
for train_val_idx, test_idx in outer_cv.split(X, y, groups):
    outer_fold += 1
    logger(f"outer_fold {outer_fold}", file=log_file_path)

    # Convert indices back to DataFrame for easy manipulation
    df_train_val = dataframe.iloc[train_val_idx]
    df_test = dataframe.iloc[test_idx]

    ##############################
    # ASSESSING SPLITS BY CAT_ID #
    ##############################
    
    # Get the distribution of groups
    training_validation_group_distribution = df_train_val['cat_id'].value_counts()  
    testing_group_distribution = df_test['cat_id'].value_counts()  
    
    # Log or print the distribution
    logger(f"Train Set Group Distribution:\n{training_validation_group_distribution}", file=log_file_path)
    logger(f"Testing Set Group Distribution:\n{testing_group_distribution}", file=log_file_path)

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val['gender'].value_counts()
    testing_gender_distribution = df_test['gender'].value_counts()
    
    # Log the distribution
    logger(f"Training Set Gender Distribution BEFORE SWAP:\n{training_gender_distribution}", file=log_file_path)
    logger(f"Testing Set Gender Distribution BEFORE SWAP:\n{testing_gender_distribution}", file=log_file_path)

    # Group by 'age_group' and then list unique 'cat_id' within each age group
    unique_cat_ids_per_age_group_train_val = df_train_val.groupby('age_group')['cat_id'].unique()
    unique_cat_ids_per_age_group_test = df_test.groupby('age_group')['cat_id'].unique()
    
    # Log results
    logger(f"Unique Cat IDs per Age Group in Training/Validation Set:\n{unique_cat_ids_per_age_group_train_val}", file=log_file_path)
    logger(f"Unique Cat IDs per Age Group in Testing Set:\n{unique_cat_ids_per_age_group_test}", file=log_file_path)

    # Calculate the count of unique identifiers per age group for training and testing set
    counts_train_val = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_train_val.items()}
    counts_test = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_test.items()}

    # Log the counts of unique identifiers per age group
    logger(f"Count of Unique Cat IDs per Age Group in Training/Validation Set:\n{counts_train_val}", file=log_file_path)
    logger(f"Count of Unique Cat IDs per Age Group in Testing Set:\n{counts_test}", file=log_file_path)

    #######################################################
    # CONTINUE WITH ENSURING VALID AND APPROPRIATE SPLITS #
    #######################################################
    
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    groups_train_val, groups_test = groups[train_val_idx], groups[test_idx]

    # logging identifier splits 
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)

    # check group splits
    check_initial_group_split(groups_train_val, groups_test)

    # Specify the cat_ids that must be in the training/validation set
    specific_cat_ids = ['000A', '046A']
    
    # Perform the swapping operation
    train_val_idx, test_idx = swap_cat_id_instances(dataframe, train_val_idx, test_idx, specific_cat_ids)
    
    # Re-assign the sets based on the updated indices
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    new_groups_train_val, new_groups_test = groups[train_val_idx], groups[test_idx]

    # Find differences for training and test sets
    moved_to_train_val, removed_from_train_val = find_group_differences(groups_train_val, new_groups_train_val)
    moved_to_test, removed_from_test = find_group_differences(groups_test, new_groups_test)
    
    # Display the results
    logger(f"Moved to Training/Validation Set:\n{moved_to_train_val}", file=log_file_path)
    logger(f"Removed from Training/Validation Set:\n{removed_from_train_val}", file=log_file_path)
    logger(f"Moved to Test Set:\n{moved_to_test}", file=log_file_path)
    logger(f"Removed from Test Set\n{removed_from_test}", file=log_file_path)

    # Update X_train_val, X_test, y_train_val, y_test, groups_train_val, groups_test based on updated indices
    X_train_val = X[train_val_idx]
    y_train_val = y[train_val_idx]
    groups_train_val = groups[train_val_idx]
    
    X_test = X[test_idx]
    y_test = y[test_idx]
    groups_test = groups[test_idx]

    # logging identifier splits again after potential swaps
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"AFTER SWAP - Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"AFTER SWAP - Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)
    
    # Verify the lengths are consistent
    logger(f"Length of X_train_val:\n{len(X_train_val)}", file=log_file_path)
    logger(f"Length of y_train_val:\n{len(y_train_val)}", file=log_file_path)
    logger(f"Length of groups_train_val:\n{len(groups_train_val)}", file=log_file_path)

    # Check group splits once more
    check_initial_group_split(groups_train_val, groups_test)

    # Convert the modified indices back to a DataFrame representing the updated df_train_val
    df_train_val_updated = dataframe.iloc[train_val_idx].copy()
    df_test_updated = dataframe.iloc[test_idx].copy()

    ############################
    # LOGGING AGE GROUP SPLITS #
    ############################

    # Get the distribution of age groups of age groups before the update
    training_validation_age_group_distribution = df_train_val['age_group'].value_counts()
    testing_age_group_distribution = df_test['age_group'].value_counts()
    
    # Logthe distribution
    logger(f"Train Age Group Distribution BEFORE SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution BEFORE SWAP:\n{testing_age_group_distribution}", file=log_file_path)

    # Get the distribution of age groups after the update
    training_validation_age_group_distribution = df_train_val_updated['age_group'].value_counts()
    testing_age_group_distribution = df_test_updated['age_group'].value_counts()
    
    # Log the distribution
    logger(f"Train Age Group Distribution AFTER SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution AFTER SWAP:\n{testing_age_group_distribution}", file=log_file_path)
    
    ########################################################
    # TRACKING FINAL CAT_IDs & GENDER AFTER REDISTRIBUTION #
    ########################################################

    # Get the distribution of groups
    training_validation_group_distribution = df_train_val_updated['cat_id'].value_counts()  
    testing_group_distribution = df_test_updated['cat_id'].value_counts()  

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val_updated['gender'].value_counts()
    testing_gender_distribution = df_test_updated['gender'].value_counts()
    
    logger(f"\n Starting training on unseen test set\n", file=log_file_path)

    ###################
    # PREPARING MODEL #
    ###################

    # Calculate the distribution of age groups in y_train_val
    age_group_distribution = Counter(y_train_val)
    print("Age group distribution:", age_group_distribution)

    # EarlyStopping callback: monitor 'loss' instead of 'val_loss' for the test set
    early_stopping = EarlyStopping(
        monitor='loss',  
        min_delta=0.001, 
        patience=30,  
        verbose=1,  
        restore_best_weights=True  
    )

    # One final shuffle to ensure randomness
    outer_shuffle_idx = np.random.permutation(len(X_train_val))
    X_train_val = X_train_val[outer_shuffle_idx]
    y_train_val = y_train_val[outer_shuffle_idx]
    
    # Scale the features
    scaler_full = StandardScaler().fit(X_train_val)
    X_train_full_scaled = scaler_full.transform(X_train_val)
    X_test_scaled = scaler_full.transform(X_test)
    
    # Convert features to TensorFlow tensors
    X_train_full_scaled = tf.convert_to_tensor(X_train_full_scaled, dtype=tf.float32)
    X_test_scaled = tf.convert_to_tensor(X_test_scaled, dtype=tf.float32)
    
    # One-hot encode labels before mixup
    y_train_full_encoded = to_categorical(y_train_val)
    y_test_encoded = to_categorical(y_test)
    
    # Convert labels to TensorFlow tensors
    y_train_full_encoded = tf.convert_to_tensor(y_train_full_encoded, dtype=tf.float32)
    
    # Apply Mixup
    X_train_mix_outer, y_train_mix_outer = mixup_data(X_train_full_scaled, y_train_full_encoded, alpha=0.2)
    
    #######################
    # BUILD & TRAIN MODEL #
    #######################

    optimizers = {
        'Adamax': Adamax(learning_rate=0.00510251984616472)
    }
    
    # Model definition with dynamic number of layers
    model_full = Sequential()
    model_full.add(Dense(480, activation='relu', input_shape=(X_train_full_scaled.shape[1],)))
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.2011047009431978))  
    model_full.add(Dense(256, activation='relu',)) 
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.14956886311951184))  
    model_full.add(Dense(256, activation='relu'))  
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.42291461228250665))  
    model_full.add(Dense(3, activation='softmax'))  
    
    # Use the optimizer from the parameters
    optimizer = optimizers['Adamax']  # optimizer_key from parameters
    
    # Compile the model
    model_full.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    
    # Train the model on the full training set
    history_full = model_full.fit(X_train_mix_outer, y_train_mix_outer, epochs=1500, batch_size=64,
                                  verbose=1, callbacks=[early_stopping])
    
    # Evaluate the model on the held-out test set
    test_loss, test_accuracy = model_full.evaluate(X_test_scaled, y_test_encoded)

    y_test_pred_prob = model_full.predict(X_test_scaled)
    y_test_pred = np.argmax(y_test_pred_prob, axis=1)  
    y_test_true = np.argmax(y_test_encoded, axis=1)    

    ################################
    # LOG MAJORITY VOTE PER CAT_ID #
    ################################

    # Convert numeric predictions back to age group labels
    predicted_age_groups = label_encoder.inverse_transform(y_test_pred)
    actual_labels = label_encoder.inverse_transform(y_test_true)
    
    # Map predictions and actual labels back to cat_ids
    test_results = pd.DataFrame({
        'cat_id': df_test_updated['cat_id'],
        'predicted_age_group': predicted_age_groups,
        'actual_age_group': actual_labels
    })
    
    # Group by cat_id and aggregate predicted age groups
    majority_votes = test_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
    actual_groups = test_results.groupby('cat_id')['actual_age_group'].first()
    
    # Calculate the accuracy of majority voting
    correct_predictions = (majority_votes == actual_groups).sum()
    total_cats = len(actual_groups)
    majority_vote_accuracy = correct_predictions / total_cats
    
    # Log the accuracy of the majority voting
    logger(f"Majority Vote Accuracy for cat_id for this fold: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

    ####################################################
    # COLLECT PREDICTIONS FOR GENDER & CAT_ID ANALYSIS #
    ####################################################

    # Debugging print statements
    print(f'Before appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Extend lists with current fold results
    all_cat_ids.extend(df_test_updated['cat_id'].tolist())
    all_predicted_age_groups.extend(predicted_age_groups)
    all_actual_age_groups.extend(actual_labels)
    all_gender.extend(df_test_updated['gender'].tolist())

    # Debugging print statements
    print(f'After appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Calculate additional metrics
    test_precision = precision_score(y_test_true, y_test_pred, average='macro')  # Use 'macro' for imbalanced datasets
    test_recall = recall_score(y_test_true, y_test_pred, average='macro')
    test_f1 = f1_score(y_test_true, y_test_pred, average='macro')

    # prepare averages of outer metrics
    unseen_f1.append(test_f1)
    unseen_losses.append(test_loss)
    unseen_accuracies.append(test_accuracy)
    unseen_precisions.append(test_precision)
    unseen_recalls.append(test_recall)

    # Print final test results
    logger(f"Final Test Results - Loss: {test_loss}, Accuracy: {test_accuracy}, Precision: {test_precision}, Recall: {test_recall}, F1 Score: {test_f1}", file=log_file_path)

    # Generate the confusion matrix
    cm = confusion_matrix(y_test, y_test_pred)
    logger(f"Confusion Matrix:\n {cm}", file=log_file_path)

# Calculate the overall average metrics
unseen_set_avg_f1 = np.mean(unseen_f1)
unseen_set_avg_loss = np.mean(unseen_losses)
unseen_set_avg_acc = np.mean(unseen_accuracies)
unseen_set_avg_precision = np.mean(unseen_precisions)
unseen_set_avg_recall = np.mean(unseen_recalls)

logger(f"\nFinal Average F1-Score across all UNSEEN TEST sets: {unseen_set_avg_f1}", file=log_file_path)
logger(f"\nFinal Average Loss across all UNSEEN TEST sets: {unseen_set_avg_loss}", file=log_file_path)
logger(f"\nFinal Average Accuracy across all UNSEEN TEST sets: {unseen_set_avg_acc}", file=log_file_path)
logger(f"\nFinal Average Precision across all UNSEEN TEST sets: {unseen_set_avg_precision}", file=log_file_path)
logger(f"\nFinal Average Recall across all UNSEEN TEST sets: {unseen_set_avg_recall}\n", file=log_file_path)

# Append averages to total lists
all_f1.append(unseen_set_avg_f1)
all_losses.append(unseen_set_avg_loss)
all_accuracies.append(unseen_set_avg_acc)
all_precisions.append(unseen_set_avg_precision)
all_recalls.append(unseen_set_avg_recall)
# Out:
# outer_fold 1
# Train Set Group Distribution:
# 046A    66
# 000A    39
# 002B    36
# 103A    33
# 047A    30
# 057A    28
# 074A    25
# 020A    23
# 067A    20
# 059A    18
# 019A    17
# 029A    17
# 101A    16
# 097A    16
# 106A    15
# 001A    15
# 042A    14
# 097B    14
# 111A    13
# 002A    13
# 116A    12
# 039A    12
# 051A    12
# 005A    11
# 016A    11
# 025A    11
# 068A    11
# 063A    11
# 014B    10
# 040A    10
# 015A    10
# 065A     9
# 022A     9
# 045A     9
# 051B     9
# 072A     9
# 013B     8
# 095A     8
# 027A     7
# 050A     7
# 053A     7
# 023A     6
# 008A     6
# 037A     6
# 025C     6
# 109A     6
# 007A     6
# 021A     6
# 034A     5
# 070A     5
# 012A     5
# 062A     5
# 023B     5
# 075A     5
# 105A     4
# 052A     4
# 035A     4
# 104A     4
# 026A     4
# 003A     4
# 014A     3
# 060A     3
# 056A     3
# 064A     3
# 058A     3
# 006A     3
# 038A     2
# 032A     2
# 054A     2
# 087A     2
# 093A     2
# 102A     2
# 018A     2
# 069A     2
# 025B     2
# 110A     1
# 004A     1
# 115A     1
# 041A     1
# 092A     1
# 019B     1
# 049A     1
# 090A     1
# 026C     1
# 073A     1
# 091A     1
# 100A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 000B    20
# 055A    20
# 028A    14
# 036A    11
# 071A    10
# 033A     9
# 094A     8
# 010A     8
# 031A     7
# 117A     7
# 099A     7
# 108A     6
# 044A     5
# 009A     4
# 113A     3
# 011A     3
# 061A     2
# 066A     2
# 076A     1
# 048A     1
# 088A     1
# 096A     1
# 043A     1
# 024A     1
# 026B     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    326
# M    323
# F    166
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# F    91
# M    33
# X    29
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [002A, 070A, 020A, 000A, 015A, 026A, 065A, 053...
# kitten    [046A, 042A, 014B, 110A, 109A, 040A, 047A, 049...
# senior    [106A, 057A, 090A, 051B, 116A, 051A, 097A, 059...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [028A, 033A, 000B, 071A, 009A, 010A, 031A, 036...
# kitten                                   [048A, 044A, 043A]
# senior     [117A, 113A, 024A, 094A, 055A, 108A, 061A, 011A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 60, 'kitten': 13, 'senior': 14}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 14, 'kitten': 3, 'senior': 8}
# Unique Training/Validation Group IDs:
# ['000A' '001A' '002A' '002B' '003A' '004A' '005A' '006A' '007A' '008A'
#  '012A' '013B' '014A' '014B' '015A' '016A' '018A' '019A' '019B' '020A'
#  '021A' '022A' '023A' '023B' '025A' '025B' '025C' '026A' '026C' '027A'
#  '029A' '032A' '034A' '035A' '037A' '038A' '039A' '040A' '041A' '042A'
#  '045A' '046A' '047A' '049A' '050A' '051A' '051B' '052A' '053A' '054A'
#  '056A' '057A' '058A' '059A' '060A' '062A' '063A' '064A' '065A' '067A'
#  '068A' '069A' '070A' '072A' '073A' '074A' '075A' '087A' '090A' '091A'
#  '092A' '093A' '095A' '097A' '097B' '100A' '101A' '102A' '103A' '104A'
#  '105A' '106A' '109A' '110A' '111A' '115A' '116A']
# Unique Test Group IDs:
# ['000B' '009A' '010A' '011A' '024A' '026B' '028A' '031A' '033A' '036A'
#  '043A' '044A' '048A' '055A' '061A' '066A' '071A' '076A' '088A' '094A'
#  '096A' '099A' '108A' '113A' '117A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '001A' '002A' '002B' '003A' '004A' '005A' '006A' '007A' '008A'
#  '012A' '013B' '014A' '014B' '015A' '016A' '018A' '019A' '019B' '020A'
#  '021A' '022A' '023A' '023B' '025A' '025B' '025C' '026A' '026C' '027A'
#  '029A' '032A' '034A' '035A' '037A' '038A' '039A' '040A' '041A' '042A'
#  '045A' '046A' '047A' '049A' '050A' '051A' '051B' '052A' '053A' '054A'
#  '056A' '057A' '058A' '059A' '060A' '062A' '063A' '064A' '065A' '067A'
#  '068A' '069A' '070A' '072A' '073A' '074A' '075A' '087A' '090A' '091A'
#  '092A' '093A' '095A' '097A' '097B' '100A' '101A' '102A' '103A' '104A'
#  '105A' '106A' '109A' '110A' '111A' '115A' '116A']
# AFTER SWAP - Unique Test Group IDs:
# ['000B' '009A' '010A' '011A' '024A' '026B' '028A' '031A' '033A' '036A'
#  '043A' '044A' '048A' '055A' '061A' '066A' '071A' '076A' '088A' '094A'
#  '096A' '099A' '108A' '113A' '117A']
# Length of X_train_val:
# 815
# Length of y_train_val:
# 815
# Length of groups_train_val:
# 815
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     510
# kitten    169
# senior    136
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     96
# senior    50
# kitten     7
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     510
# kitten    169
# senior    136
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     96
# senior    50
# kitten     7
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 510, 1: 169, 2: 136})
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Epoch 1/1500
# 13/13 [==============================] - 1s 5ms/step - loss: 1.3880 - accuracy: 0.5448
# Epoch 2/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.7870 - accuracy: 0.7166
# Epoch 3/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.5478 - accuracy: 0.7951
# Epoch 4/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4638 - accuracy: 0.8479
# Epoch 5/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3964 - accuracy: 0.8798
# Epoch 6/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3139 - accuracy: 0.9092
# Epoch 7/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3159 - accuracy: 0.9092
# Epoch 8/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3126 - accuracy: 0.9129
# Epoch 9/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2831 - accuracy: 0.9252
# Epoch 10/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2604 - accuracy: 0.9301
# Epoch 11/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2840 - accuracy: 0.9288
# Epoch 12/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2873 - accuracy: 0.9399
# Epoch 13/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2642 - accuracy: 0.9276
# Epoch 14/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2420 - accuracy: 0.9460
# Epoch 15/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2280 - accuracy: 0.9411
# Epoch 16/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2096 - accuracy: 0.9571
# Epoch 17/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2275 - accuracy: 0.9485
# Epoch 18/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2151 - accuracy: 0.9558
# Epoch 19/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2115 - accuracy: 0.9656
# Epoch 20/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2328 - accuracy: 0.9423
# Epoch 21/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2208 - accuracy: 0.9411
# Epoch 22/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2044 - accuracy: 0.9571
# Epoch 23/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1974 - accuracy: 0.9436
# Epoch 24/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2069 - accuracy: 0.9632
# Epoch 25/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2059 - accuracy: 0.9485
# Epoch 26/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2128 - accuracy: 0.9423
# Epoch 27/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2025 - accuracy: 0.9509
# Epoch 28/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1946 - accuracy: 0.9607
# Epoch 29/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2026 - accuracy: 0.9558
# Epoch 30/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1825 - accuracy: 0.9669
# Epoch 31/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2051 - accuracy: 0.9546
# Epoch 32/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1919 - accuracy: 0.9644
# Epoch 33/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1793 - accuracy: 0.9644
# Epoch 34/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1806 - accuracy: 0.9595
# Epoch 35/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1747 - accuracy: 0.9681
# Epoch 36/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1869 - accuracy: 0.9497
# Epoch 37/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1948 - accuracy: 0.9571
# Epoch 38/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1732 - accuracy: 0.9706
# Epoch 39/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1730 - accuracy: 0.9681
# Epoch 40/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1784 - accuracy: 0.9656
# Epoch 41/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1739 - accuracy: 0.9571
# Epoch 42/1500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.1711 - accuracy: 0.9718
# Epoch 43/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1792 - accuracy: 0.9632
# Epoch 44/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1730 - accuracy: 0.9620
# Epoch 45/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1696 - accuracy: 0.9681
# Epoch 46/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.
1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1332 - accuracy: 0.9840
# Epoch 176/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1323 - accuracy: 0.9706
# Epoch 177/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1379 - accuracy: 0.9632
# Epoch 178/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.1353 - accuracy: 0.9804
# Epoch 179/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1306 - accuracy: 0.9791
# Epoch 180/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1336 - accuracy: 0.9644
# Epoch 181/1500
# 12/13 [==========================>...] - ETA: 0s - loss: 0.1329 - accuracy: 0.9714Restoring model weights from the end of the best epoch: 151.
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1353 - accuracy: 0.9706
# Epoch 181: early stopping
# 5/5 [==============================] - 0s 1ms/step - loss: 1.7348 - accuracy: 0.6601
# 5/5 [==============================] - 0s 1ms/step
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Majority Vote Accuracy for cat_id for this fold: 0.68 (17/25)
# Before appending - Cat IDs: 0, Predictions: 0, Actuals: 0, Gender: 0
# After appending - Cat IDs: 153, Predictions: 153, Actuals: 153, Gender: 153
# Final Test Results - Loss: 1.734826922416687, Accuracy: 0.6601307392120361, Precision: 0.6225378787878788, Recall: 0.7140277777777778, F1 Score: 0.6466615798844072
# Confusion Matrix:
#  [[77  4 15]
#  [ 0  7  0]
#  [33  0 17]]
# outer_fold 2
# Train Set Group Distribution:
# 046A    66
# 000A    39
# 002B    36
# 103A    33
# 047A    30
# 074A    25
# 020A    23
# 000B    20
# 055A    20
# 059A    18
# 019A    17
# 101A    16
# 106A    15
# 001A    15
# 028A    14
# 111A    13
# 116A    12
# 051A    12
# 039A    12
# 016A    11
# 036A    11
# 005A    11
# 071A    10
# 040A    10
# 065A     9
# 072A     9
# 033A     9
# 095A     8
# 010A     8
# 094A     8
# 050A     7
# 099A     7
# 027A     7
# 031A     7
# 053A     7
# 117A     7
# 021A     6
# 008A     6
# 025C     6
# 108A     6
# 007A     6
# 037A     6
# 023A     6
# 075A     5
# 012A     5
# 034A     5
# 070A     5
# 044A     5
# 035A     4
# 009A     4
# 026A     4
# 003A     4
# 104A     4
# 105A     4
# 052A     4
# 014A     3
# 064A     3
# 056A     3
# 058A     3
# 011A     3
# 113A     3
# 087A     2
# 066A     2
# 069A     2
# 061A     2
# 018A     2
# 032A     2
# 026B     1
# 115A     1
# 076A     1
# 024A     1
# 096A     1
# 026C     1
# 073A     1
# 088A     1
# 091A     1
# 043A     1
# 110A     1
# 048A     1
# 092A     1
# 090A     1
# 100A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 057A    28
# 067A    20
# 029A    17
# 097A    16
# 042A    14
# 097B    14
# 002A    13
# 025A    11
# 063A    11
# 068A    11
# 015A    10
# 014B    10
# 045A     9
# 051B     9
# 022A     9
# 013B     8
# 109A     6
# 062A     5
# 023B     5
# 006A     3
# 060A     3
# 038A     2
# 102A     2
# 054A     2
# 025B     2
# 093A     2
# 049A     1
# 019B     1
# 041A     1
# 004A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    290
# X    224
# F    208
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    131
# M     66
# F     49
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [028A, 070A, 033A, 000B, 071A, 020A, 000A, 026...
# kitten    [046A, 110A, 040A, 047A, 048A, 111A, 044A, 043...
# senior    [117A, 106A, 090A, 113A, 116A, 051A, 024A, 094...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [002A, 015A, 023B, 038A, 068A, 013B, 062A, 006...
# kitten                 [042A, 014B, 109A, 049A, 045A, 041A]
# senior                       [057A, 051B, 097A, 054A, 093A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 55, 'kitten': 10, 'senior': 17}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 19, 'kitten': 6, 'senior': 5}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002B' '003A' '005A' '007A' '008A' '009A' '010A'
#  '011A' '012A' '014A' '016A' '018A' '019A' '020A' '021A' '023A' '024A'
#  '025C' '026A' '026B' '026C' '027A' '028A' '031A' '032A' '033A' '034A'
#  '035A' '036A' '037A' '039A' '040A' '043A' '044A' '046A' '047A' '048A'
#  '050A' '051A' '052A' '053A' '055A' '056A' '058A' '059A' '061A' '064A'
#  '065A' '066A' '069A' '070A' '071A' '072A' '073A' '074A' '075A' '076A'
#  '087A' '088A' '090A' '091A' '092A' '094A' '095A' '096A' '099A' '100A'
#  '101A' '103A' '104A' '105A' '106A' '108A' '110A' '111A' '113A' '115A'
#  '116A' '117A']
# Unique Test Group IDs:
# ['002A' '004A' '006A' '013B' '014B' '015A' '019B' '022A' '023B' '025A'
#  '025B' '029A' '038A' '041A' '042A' '045A' '049A' '051B' '054A' '057A'
#  '060A' '062A' '063A' '067A' '068A' '093A' '097A' '097B' '102A' '109A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002B' '003A' '005A' '007A' '008A' '009A' '010A'
#  '011A' '012A' '014A' '016A' '018A' '019A' '020A' '021A' '023A' '024A'
#  '025C' '026A' '026B' '026C' '027A' '028A' '031A' '032A' '033A' '034A'
#  '035A' '036A' '037A' '039A' '040A' '043A' '044A' '046A' '047A' '048A'
#  '050A' '051A' '052A' '053A' '055A' '056A' '058A' '059A' '061A' '064A'
#  '065A' '066A' '069A' '070A' '071A' '072A' '073A' '074A' '075A' '076A'
#  '087A' '088A' '090A' '091A' '092A' '094A' '095A' '096A' '099A' '100A'
#  '101A' '103A' '104A' '105A' '106A' '108A' '110A' '111A' '113A' '115A'
#  '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['002A' '004A' '006A' '013B' '014B' '015A' '019B' '022A' '023B' '025A'
#  '025B' '029A' '038A' '041A' '042A' '045A' '049A' '051B' '054A' '057A'
#  '060A' '062A' '063A' '067A' '068A' '093A' '097A' '097B' '102A' '109A']
# Length of X_train_val:
# 722
# Length of y_train_val:
# 722
# Length of groups_train_val:
# 722
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     458
# kitten    135
# senior    129
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     148
# senior     57
# kitten     41
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     458
# kitten    135
# senior    129
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     148
# senior     57
# kitten     41
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 458, 1: 135, 2: 129})
# Epoch 1/1500
# 12/12 [==============================] - 1s 4ms/step - loss: 1.4548 - accuracy: 0.5180
# Epoch 2/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.7600 - accuracy: 0.7396
# Epoch 3/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.5359 - accuracy: 0.8199
# Epoch 4/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4810 - accuracy: 0.8338
# Epoch 5/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3980 - accuracy: 0.8753
# Epoch 6/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4009 - accuracy: 0.8781
# Epoch 7/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3226 - accuracy: 0.9072
# Epoch 8/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3259 - accuracy: 0.9058
# Epoch 9/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3183 - accuracy: 0.9183
# Epoch 10/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3114 - accuracy: 0.9294
# Epoch 11/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2909 - accuracy: 0.9155
# Epoch 12/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2735 - accuracy: 0.9349
# Epoch 13/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2629 - accuracy: 0.9349
# Epoch 14/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2868 - accuracy: 0.9252
# Epoch 15/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2509 - accuracy: 0.9404
# Epoch 16/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2700 - accuracy: 0.9224
# Epoch 17/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2507 - accuracy: 0.9543
# Epoch 18/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2462 - accuracy: 0.9404
# Epoch 19/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2347 - accuracy: 0.9446
# Epoch 20/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2307 - accuracy: 0.9474
# Epoch 21/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.
1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1497 - accuracy: 0.9651
# Epoch 123/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1634 - accuracy: 0.9637
# Epoch 124/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1481 - accuracy: 0.9763
# Epoch 125/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1573 - accuracy: 0.9707
# Epoch 126/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1566 - accuracy: 0.9679
# Epoch 127/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1528 - accuracy: 0.9665
# Epoch 128/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1519 - accuracy: 0.9637
# Epoch 129/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1460 - accuracy: 0.9749
# Epoch 130/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1485 - accuracy: 0.9763
# Epoch 131/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1536 - accuracy: 0.9679
# Epoch 132/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1500 - accuracy: 0.9581
# Epoch 133/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1549 - accuracy: 0.9595
# Epoch 134/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1553 - accuracy: 0.9651
# Epoch 135/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1458 - accuracy: 0.9721
# Epoch 136/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1485 - accuracy: 0.9763
# Epoch 137/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1474 - accuracy: 0.9749
# Epoch 138/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1503 - accuracy: 0.9651
# Epoch 139/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1499 - accuracy: 0.9679
# Epoch 140/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1464 - accuracy: 0.9637
# Epoch 141/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1527 - accuracy: 0.9651
# Epoch 142/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1512 - accuracy: 0.9707
# Epoch 143/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1476 - accuracy: 0.9721
# Epoch 144/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1510 - accuracy: 0.9749
# Epoch 145/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1406 - accuracy: 0.9791
# Epoch 146/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1701 - accuracy: 0.9567
# Epoch 147/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1479 - accuracy: 0.9791
# Epoch 148/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1546 - accuracy: 0.9791
# Epoch 149/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1465 - accuracy: 0.9735
# Epoch 150/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1537 - accuracy: 0.9707
# Epoch 151/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1502 - accuracy: 0.9735
# Epoch 152/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1489 - accuracy: 0.9651
# Epoch 153/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1452 - accuracy: 0.9721
# Epoch 154/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1437 - accuracy: 0.9735
# Epoch 155/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1474 - accuracy: 0.9665
# Epoch 156/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1455 - accuracy: 0.9749
# Epoch 157/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1447 - accuracy: 0.9721
# Epoch 158/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1453 - accuracy: 0.9791
# Epoch 159/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1456 - accuracy: 0.9693
# Epoch 160/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1426 - accuracy: 0.9721
# Epoch 161/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1424 - accuracy: 0.9721
# Epoch 162/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1483 - accuracy: 0.9735
# Epoch 163/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1471 - accuracy: 0.9721
# Epoch 164/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1500 - accuracy: 0.9749
# Epoch 165/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1508 - accuracy: 0.9721
# Epoch 166/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1478 - accuracy: 0.9721
# Epoch 167/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1521 - accuracy: 0.9693
# Epoch 168/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1513 - accuracy: 0.9623
# Epoch 169/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1467 - accuracy: 0.9679
# Epoch 170/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1432 - accuracy: 0.9693
# Epoch 171/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1411 - accuracy: 0.9707
# Epoch 172/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1482 - accuracy: 0.9721
# Epoch 173/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1445 - accuracy: 0.9777
# Epoch 174/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1419 - accuracy: 0.9623
# Epoch 175/1500
# 12/12 [==============================] - ETA: 0s - loss: 0.1467 - accuracy: 0.9637Restoring model weights from the end of the best epoch: 145.
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1467 - accuracy: 0.9637
# Epoch 175: early stopping
# 8/8 [==============================] - 0s 1ms/step - loss: 7.0793 - accuracy: 0.6627
# 8/8 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.78 (21/27)
# Before appending - Cat IDs: 633, Predictions: 633, Actuals: 633, Gender: 633
# After appending - Cat IDs: 885, Predictions: 885, Actuals: 885, Gender: 885
# Final Test Results - Loss: 7.079252243041992, Accuracy: 0.6626983880996704, Precision: 0.6252168221240387, Recall: 0.5178571428571428, F1 Score: 0.5454538511475159
# Confusion Matrix:
#  [[132   7  15]
#  [ 32  23   1]
#  [ 30   0  12]]
#
# Final Average F1-Score across all UNSEEN TEST sets: 0
# %%
# Set a fixed random seed for reproducibility
random.seed(int(random_seeds[4]))
np.random.seed(int(random_seeds[4]))
tf.random.set_seed(int(random_seeds[4]))

# Load datasets
dataframe = pd.read_csv('/Users/astrid/PycharmProjects/data-aug-and-more/yamnet-tfhub-extraction/yamnet_embeddings_looped_april_23.csv')

def assign_age_group(age, age_groups):
    for group_name, age_range in age_groups.items():
        if age_range[0] <= age < age_range[1]:
            return group_name
    return 'Unknown'  # For any age that doesn't fit the defined groups

# Define age groups
age_groups = {
    'kitten': (0, 0.5),
    'adult': (0.5, 12),
    'senior': (12, 20)
}

# Create a new column for the age group
dataframe['age_group'] = dataframe['target'].apply(assign_age_group, age_groups=age_groups)

print(dataframe['age_group'].value_counts())
# Out:
# adult     606
# senior    186
# kitten    176
# Name: age_group, dtype: int64

# %%
# Separate features and labels
X = dataframe.iloc[:, :-4].values  # all columns except the last four

# Encode the 'age_group' column as integers using LabelEncoder
label_encoder = LabelEncoder()
encoded_y = label_encoder.fit_transform(dataframe['age_group'].values)

# Use the encoded labels for splitting and one-hot encoding
y = encoded_y  

# Convert 'cat_id' column to numpy array to be used as groups array for GroupKFold
groups = dataframe['cat_id'].values

# %%
tf.keras.backend.clear_session()

# %% [markdown]
# ## Run Setup

# %%
all_cat_ids = []
all_predicted_age_groups = []
all_actual_age_groups = []
all_gender = []

# Define the StratifiedGroupKFold splitter for 4 fold CV with random shuffling
outer_cv = StratifiedGroupKFold(n_splits=4, shuffle=True, random_state=int(random_seeds[4]))

# unseen test set metrics
unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1 = [], [], [], [], []

outer_fold = 0

# Use the splitter to generate indices for training and testing sets
# Note: GroupShuffleSplit.split returns indices, so we use it to index the arrays
for train_val_idx, test_idx in outer_cv.split(X, y, groups):
    outer_fold += 1
    logger(f"outer_fold {outer_fold}", file=log_file_path)

    # Convert indices back to DataFrame for easy manipulation
    df_train_val = dataframe.iloc[train_val_idx]
    df_test = dataframe.iloc[test_idx]

    ##############################
    # ASSESSING SPLITS BY CAT_ID #
    ##############################
    
    # Get the distribution of groups
    training_validation_group_distribution = df_train_val['cat_id'].value_counts()  
    testing_group_distribution = df_test['cat_id'].value_counts()  
    
    # Log or print the distribution
    logger(f"Train Set Group Distribution:\n{training_validation_group_distribution}", file=log_file_path)
    logger(f"Testing Set Group Distribution:\n{testing_group_distribution}", file=log_file_path)

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val['gender'].value_counts()
    testing_gender_distribution = df_test['gender'].value_counts()
    
    # Log the distribution
    logger(f"Training Set Gender Distribution BEFORE SWAP:\n{training_gender_distribution}", file=log_file_path)
    logger(f"Testing Set Gender Distribution BEFORE SWAP:\n{testing_gender_distribution}", file=log_file_path)

    # Group by 'age_group' and then list unique 'cat_id' within each age group
    unique_cat_ids_per_age_group_train_val = df_train_val.groupby('age_group')['cat_id'].unique()
    unique_cat_ids_per_age_group_test = df_test.groupby('age_group')['cat_id'].unique()
    
    # Log results
    logger(f"Unique Cat IDs per Age Group in Training/Validation Set:\n{unique_cat_ids_per_age_group_train_val}", file=log_file_path)
    logger(f"Unique Cat IDs per Age Group in Testing Set:\n{unique_cat_ids_per_age_group_test}", file=log_file_path)

    # Calculate the count of unique identifiers per age group for training and testing set
    counts_train_val = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_train_val.items()}
    counts_test = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_test.items()}

    # Log the counts of unique identifiers per age group
    logger(f"Count of Unique Cat IDs per Age Group in Training/Validation Set:\n{counts_train_val}", file=log_file_path)
    logger(f"Count of Unique Cat IDs per Age Group in Testing Set:\n{counts_test}", file=log_file_path)

    #######################################################
    # CONTINUE WITH ENSURING VALID AND APPROPRIATE SPLITS #
    #######################################################
    
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    groups_train_val, groups_test = groups[train_val_idx], groups[test_idx]

    # logging identifier splits 
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)

    # check group splits
    check_initial_group_split(groups_train_val, groups_test)

    # Specify the cat_ids that must be in the training/validation set
    specific_cat_ids = ['000A', '046A']
    
    # Perform the swapping operation
    train_val_idx, test_idx = swap_cat_id_instances(dataframe, train_val_idx, test_idx, specific_cat_ids)
    
    # Re-assign the sets based on the updated indices
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    new_groups_train_val, new_groups_test = groups[train_val_idx], groups[test_idx]

    # Find differences for training and test sets
    moved_to_train_val, removed_from_train_val = find_group_differences(groups_train_val, new_groups_train_val)
    moved_to_test, removed_from_test = find_group_differences(groups_test, new_groups_test)
    
    # Display the results
    logger(f"Moved to Training/Validation Set:\n{moved_to_train_val}", file=log_file_path)
    logger(f"Removed from Training/Validation Set:\n{removed_from_train_val}", file=log_file_path)
    logger(f"Moved to Test Set:\n{moved_to_test}", file=log_file_path)
    logger(f"Removed from Test Set\n{removed_from_test}", file=log_file_path)

    # Update X_train_val, X_test, y_train_val, y_test, groups_train_val, groups_test based on updated indices
    X_train_val = X[train_val_idx]
    y_train_val = y[train_val_idx]
    groups_train_val = groups[train_val_idx]
    
    X_test = X[test_idx]
    y_test = y[test_idx]
    groups_test = groups[test_idx]

    # logging identifier splits again after potential swaps
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"AFTER SWAP - Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"AFTER SWAP - Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)
    
    # Verify the lengths are consistent
    logger(f"Length of X_train_val:\n{len(X_train_val)}", file=log_file_path)
    logger(f"Length of y_train_val:\n{len(y_train_val)}", file=log_file_path)
    logger(f"Length of groups_train_val:\n{len(groups_train_val)}", file=log_file_path)

    # Check group splits once more
    check_initial_group_split(groups_train_val, groups_test)

    # Convert the modified indices back to a DataFrame representing the updated df_train_val
    df_train_val_updated = dataframe.iloc[train_val_idx].copy()
    df_test_updated = dataframe.iloc[test_idx].copy()

    ############################
    # LOGGING AGE GROUP SPLITS #
    ############################

    # Get the distribution of age groups of age groups before the update
    training_validation_age_group_distribution = df_train_val['age_group'].value_counts()
    testing_age_group_distribution = df_test['age_group'].value_counts()
    
    # Logthe distribution
    logger(f"Train Age Group Distribution BEFORE SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution BEFORE SWAP:\n{testing_age_group_distribution}", file=log_file_path)

    # Get the distribution of age groups after the update
    training_validation_age_group_distribution = df_train_val_updated['age_group'].value_counts()
    testing_age_group_distribution = df_test_updated['age_group'].value_counts()
    
    # Log the distribution
    logger(f"Train Age Group Distribution AFTER SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution AFTER SWAP:\n{testing_age_group_distribution}", file=log_file_path)
    
    ########################################################
    # TRACKING FINAL CAT_IDs & GENDER AFTER REDISTRIBUTION #
    ########################################################

    # Get the distribution of groups
    training_validation_group_distribution = df_train_val_updated['cat_id'].value_counts()  
    testing_group_distribution = df_test_updated['cat_id'].value_counts()  

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val_updated['gender'].value_counts()
    testing_gender_distribution = df_test_updated['gender'].value_counts()
    
    logger(f"\n Starting training on unseen test set\n", file=log_file_path)

    ###################
    # PREPARING MODEL #
    ###################

    # Calculate the distribution of age groups in y_train_val
    age_group_distribution = Counter(y_train_val)
    print("Age group distribution:", age_group_distribution)

    # EarlyStopping callback: monitor 'loss' instead of 'val_loss' for the test set
    early_stopping = EarlyStopping(
        monitor='loss',  
        min_delta=0.001, 
        patience=30,  
        verbose=1,  
        restore_best_weights=True  
    )

    # One final shuffle to ensure randomness
    outer_shuffle_idx = np.random.permutation(len(X_train_val))
    X_train_val = X_train_val[outer_shuffle_idx]
    y_train_val = y_train_val[outer_shuffle_idx]
    
    # Scale the features
    scaler_full = StandardScaler().fit(X_train_val)
    X_train_full_scaled = scaler_full.transform(X_train_val)
    X_test_scaled = scaler_full.transform(X_test)
    
    # Convert features to TensorFlow tensors
    X_train_full_scaled = tf.convert_to_tensor(X_train_full_scaled, dtype=tf.float32)
    X_test_scaled = tf.convert_to_tensor(X_test_scaled, dtype=tf.float32)
    
    # One-hot encode labels before mixup
    y_train_full_encoded = to_categorical(y_train_val)
    y_test_encoded = to_categorical(y_test)
    
    # Convert labels to TensorFlow tensors
    y_train_full_encoded = tf.convert_to_tensor(y_train_full_encoded, dtype=tf.float32)
    
    # Apply Mixup
    X_train_mix_outer, y_train_mix_outer = mixup_data(X_train_full_scaled, y_train_full_encoded, alpha=0.2)
    
    #######################
    # BUILD & TRAIN MODEL #
    #######################

    optimizers = {
        'Adamax': Adamax(learning_rate=0.00510251984616472)
    }
    
    # Model definition with dynamic number of layers
    model_full = Sequential()
    model_full.add(Dense(480, activation='relu', input_shape=(X_train_full_scaled.shape[1],)))
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.2011047009431978))  
    model_full.add(Dense(256, activation='relu',)) 
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.14956886311951184))  
    model_full.add(Dense(256, activation='relu'))  
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.42291461228250665))  
    model_full.add(Dense(3, activation='softmax'))  
    
    # Use the optimizer from the parameters
    optimizer = optimizers['Adamax']  # optimizer_key from parameters
    
    # Compile the model
    model_full.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    
    # Train the model on the full training set
    history_full = model_full.fit(X_train_mix_outer, y_train_mix_outer, epochs=1500, batch_size=64,
                                  verbose=1, callbacks=[early_stopping])
    
    # Evaluate the model on the held-out test set
    test_loss, test_accuracy = model_full.evaluate(X_test_scaled, y_test_encoded)

    y_test_pred_prob = model_full.predict(X_test_scaled)
    y_test_pred = np.argmax(y_test_pred_prob, axis=1)  
    y_test_true = np.argmax(y_test_encoded, axis=1)    

    ################################
    # LOG MAJORITY VOTE PER CAT_ID #
    ################################

    # Convert numeric predictions back to age group labels
    predicted_age_groups = label_encoder.inverse_transform(y_test_pred)
    actual_labels = label_encoder.inverse_transform(y_test_true)
    
    # Map predictions and actual labels back to cat_ids
    test_results = pd.DataFrame({
        'cat_id': df_test_updated['cat_id'],
        'predicted_age_group': predicted_age_groups,
        'actual_age_group': actual_labels
    })
    
    # Group by cat_id and aggregate predicted age groups
    majority_votes = test_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
    actual_groups = test_results.groupby('cat_id')['actual_age_group'].first()
    
    # Calculate the accuracy of majority voting
    correct_predictions = (majority_votes == actual_groups).sum()
    total_cats = len(actual_groups)
    majority_vote_accuracy = correct_predictions / total_cats
    
    # Log the accuracy of the majority voting
    logger(f"Majority Vote Accuracy for cat_id for this fold: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

    ####################################################
    # COLLECT PREDICTIONS FOR GENDER & CAT_ID ANALYSIS #
    ####################################################

    # Debugging print statements
    print(f'Before appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Extend lists with current fold results
    all_cat_ids.extend(df_test_updated['cat_id'].tolist())
    all_predicted_age_groups.extend(predicted_age_groups)
    all_actual_age_groups.extend(actual_labels)
    all_gender.extend(df_test_updated['gender'].tolist())

    # Debugging print statements
    print(f'After appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Calculate additional metrics
    test_precision = precision_score(y_test_true, y_test_pred, average='macro')  # Use 'macro' for imbalanced datasets
    test_recall = recall_score(y_test_true, y_test_pred, average='macro')
    test_f1 = f1_score(y_test_true, y_test_pred, average='macro')

    # prepare averages of outer metrics
    unseen_f1.append(test_f1)
    unseen_losses.append(test_loss)
    unseen_accuracies.append(test_accuracy)
    unseen_precisions.append(test_precision)
    unseen_recalls.append(test_recall)

    # Print final test results
    logger(f"Final Test Results - Loss: {test_loss}, Accuracy: {test_accuracy}, Precision: {test_precision}, Recall: {test_recall}, F1 Score: {test_f1}", file=log_file_path)

    # Generate the confusion matrix
    cm = confusion_matrix(y_test, y_test_pred)
    logger(f"Confusion Matrix:\n {cm}", file=log_file_path)

# Calculate the overall average metrics
unseen_set_avg_f1 = np.mean(unseen_f1)
unseen_set_avg_loss = np.mean(unseen_losses)
unseen_set_avg_acc = np.mean(unseen_accuracies)
unseen_set_avg_precision = np.mean(unseen_precisions)
unseen_set_avg_recall = np.mean(unseen_recalls)

logger(f"\nFinal Average F1-Score across all UNSEEN TEST sets: {unseen_set_avg_f1}", file=log_file_path)
logger(f"\nFinal Average Loss across all UNSEEN TEST sets: {unseen_set_avg_loss}", file=log_file_path)
logger(f"\nFinal Average Accuracy across all UNSEEN TEST sets: {unseen_set_avg_acc}", file=log_file_path)
logger(f"\nFinal Average Precision across all UNSEEN TEST sets: {unseen_set_avg_precision}", file=log_file_path)
logger(f"\nFinal Average Recall across all UNSEEN TEST sets: {unseen_set_avg_recall}\n", file=log_file_path)

# Append averages to total lists
all_f1.append(unseen_set_avg_f1)
all_losses.append(unseen_set_avg_loss)
all_accuracies.append(unseen_set_avg_acc)
all_precisions.append(unseen_set_avg_precision)
all_recalls.append(unseen_set_avg_recall)
# Out:
# outer_fold 1
# Train Set Group Distribution:
# 046A    66
# 000A    39
# 002B    36
# 057A    28
# 074A    25
# 020A    23
# 067A    20
# 055A    20
# 059A    18
# 029A    17
# 019A    17
# 101A    16
# 106A    15
# 001A    15
# 097B    14
# 028A    14
# 042A    14
# 111A    13
# 051A    12
# 116A    12
# 039A    12
# 016A    11
# 005A    11
# 063A    11
# 025A    11
# 036A    11
# 068A    11
# 071A    10
# 015A    10
# 040A    10
# 014B    10
# 033A     9
# 022A     9
# 065A     9
# 045A     9
# 051B     9
# 094A     8
# 010A     8
# 013B     8
# 095A     8
# 053A     7
# 099A     7
# 027A     7
# 117A     7
# 007A     6
# 108A     6
# 021A     6
# 023A     6
# 109A     6
# 037A     6
# 075A     5
# 012A     5
# 023B     5
# 044A     5
# 062A     5
# 052A     4
# 009A     4
# 035A     4
# 104A     4
# 003A     4
# 026A     4
# 060A     3
# 064A     3
# 014A     3
# 058A     3
# 018A     2
# 069A     2
# 038A     2
# 054A     2
# 093A     2
# 061A     2
# 087A     2
# 066A     2
# 025B     2
# 019B     1
# 041A     1
# 115A     1
# 026C     1
# 073A     1
# 088A     1
# 043A     1
# 048A     1
# 092A     1
# 024A     1
# 090A     1
# 110A     1
# 100A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 103A    33
# 047A    30
# 000B    20
# 097A    16
# 002A    13
# 072A     9
# 050A     7
# 031A     7
# 008A     6
# 025C     6
# 034A     5
# 070A     5
# 105A     4
# 113A     3
# 006A     3
# 011A     3
# 056A     3
# 102A     2
# 032A     2
# 091A     1
# 076A     1
# 004A     1
# 096A     1
# 049A     1
# 026B     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    299
# X    281
# F    205
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    74
# M    57
# F    52
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [028A, 033A, 071A, 020A, 000A, 015A, 026A, 065...
# kitten    [046A, 042A, 014B, 110A, 109A, 040A, 045A, 048...
# senior    [117A, 106A, 057A, 090A, 051B, 116A, 051A, 024...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [002A, 070A, 000B, 105A, 034A, 072A, 006A, 091...
# kitten                                   [047A, 049A, 050A]
# senior                             [113A, 097A, 011A, 056A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 56, 'kitten': 13, 'senior': 18}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 18, 'kitten': 3, 'senior': 4}
# Unique Training/Validation Group IDs:
# ['000A' '001A' '002B' '003A' '005A' '007A' '009A' '010A' '012A' '013B'
#  '014A' '014B' '015A' '016A' '018A' '019A' '019B' '020A' '021A' '022A'
#  '023A' '023B' '024A' '025A' '025B' '026A' '026C' '027A' '028A' '029A'
#  '033A' '035A' '036A' '037A' '038A' '039A' '040A' '041A' '042A' '043A'
#  '044A' '045A' '046A' '048A' '051A' '051B' '052A' '053A' '054A' '055A'
#  '057A' '058A' '059A' '060A' '061A' '062A' '063A' '064A' '065A' '066A'
#  '067A' '068A' '069A' '071A' '073A' '074A' '075A' '087A' '088A' '090A'
#  '092A' '093A' '094A' '095A' '097B' '099A' '100A' '101A' '104A' '106A'
#  '108A' '109A' '110A' '111A' '115A' '116A' '117A']
# Unique Test Group IDs:
# ['000B' '002A' '004A' '006A' '008A' '011A' '025C' '026B' '031A' '032A'
#  '034A' '047A' '049A' '050A' '056A' '070A' '072A' '076A' '091A' '096A'
#  '097A' '102A' '103A' '105A' '113A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '001A' '002B' '003A' '005A' '007A' '009A' '010A' '012A' '013B'
#  '014A' '014B' '015A' '016A' '018A' '019A' '019B' '020A' '021A' '022A'
#  '023A' '023B' '024A' '025A' '025B' '026A' '026C' '027A' '028A' '029A'
#  '033A' '035A' '036A' '037A' '038A' '039A' '040A' '041A' '042A' '043A'
#  '044A' '045A' '046A' '048A' '051A' '051B' '052A' '053A' '054A' '055A'
#  '057A' '058A' '059A' '060A' '061A' '062A' '063A' '064A' '065A' '066A'
#  '067A' '068A' '069A' '071A' '073A' '074A' '075A' '087A' '088A' '090A'
#  '092A' '093A' '094A' '095A' '097B' '099A' '100A' '101A' '104A' '106A'
#  '108A' '109A' '110A' '111A' '115A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['000B' '002A' '004A' '006A' '008A' '011A' '025C' '026B' '031A' '032A'
#  '034A' '047A' '049A' '050A' '056A' '070A' '072A' '076A' '091A' '096A'
#  '097A' '102A' '103A' '105A' '113A']
# Length of X_train_val:
# 785
# Length of y_train_val:
# 785
# Length of groups_train_val:
# 785
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     486
# senior    161
# kitten    138
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     120
# kitten     38
# senior     25
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     486
# senior    161
# kitten    138
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     120
# kitten     38
# senior     25
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 486, 2: 161, 1: 138})
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Epoch 1/1500
# 13/13 [==============================] - 1s 4ms/step - loss: 1.4286 - accuracy: 0.5134
# Epoch 2/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.7899 - accuracy: 0.6981
# Epoch 3/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.5609 - accuracy: 0.7949
# Epoch 4/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4756 - accuracy: 0.8395
# Epoch 5/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4395 - accuracy: 0.8662
# Epoch 6/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.4340 - accuracy: 0.8637
# Epoch 7/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3736 - accuracy: 0.8917
# Epoch 8/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3238 - accuracy: 0.9032
# Epoch 9/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2980 - accuracy: 0.9185
# Epoch 10/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2951 - accuracy: 0.9325
# Epoch 11/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3108 - accuracy: 0.9172
# Epoch 12/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2837 - accuracy: 0.9389
# Epoch 13/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2586 - accuracy: 0.9478
# Epoch 14/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2678 - accuracy: 0.9223
# Epoch 15/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2784 - accuracy: 0.9248
# Epoch 16/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2481 - accuracy: 0.9478
# Epoch 17/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2303 - accuracy: 0.9427
# Epoch 18/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2311 - accuracy: 0.9580
# Epoch 19/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2421 - accuracy: 0.9541
# Epoch 20/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2202 - accuracy: 0.9478
# Epoch 21/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2302 - accuracy: 0.9452
# Epoch 22/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2426 - accuracy: 0.9427
# Epoch 23/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2288 - accuracy: 0.9452
# Epoch 24/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2204 - accuracy: 0.9401
# Epoch 25/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2246 - accuracy: 0.9478
# Epoch 26/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2389 - accuracy: 0.9427
# Epoch 27/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2119 - accuracy: 0.9618
# Epoch 28/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2235 - accuracy: 0.9503
# Epoch 29/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2016 - accuracy: 0.9541
# Epoch 30/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1989 - accuracy: 0.9554
# Epoch 31/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2012 - accuracy: 0.9516
# Epoch 32/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2034 - accuracy: 0.9669
# Epoch 33/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1961 - accuracy: 0.9567
# Epoch 34/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2167 - accuracy: 0.9465
# Epoch 35/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.2084 - accuracy: 0.9567
# Epoch 36/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2002 - accuracy: 0.9592
# Epoch 37/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2020 - accuracy: 0.9656
# Epoch 38/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2028 - accuracy: 0.9631
# Epoch 39/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1881 - accuracy: 0.9465
# Epoch 40/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1899 - accuracy: 0.9631
# Epoch 41/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1957 - accuracy: 0.9465
# Epoch 42/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1871 - accuracy: 0.9580
# Epoch 43/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1911 - accuracy: 0.9618
# Epoch 44/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1942 - accuracy: 0.9643
# Epoch 45/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1839 - accuracy: 0.9631
# Epoch 46/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1892 - accuracy: 0.9541
# Epoch 47/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1905 - accuracy: 0.9631
# Epoch 48/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.1914 - accuracy: 0.9580
# Epoch 49/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.1838 - accuracy: 0.9631
# Epoch 50/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1906 - accuracy: 0.9529
# Epoch 51/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1826 - accuracy: 0.9656
# Epoch 52/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.1853 - accuracy: 0.9592
# Epoch 53/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.1891 - accuracy: 0.9605
# Epoch 54/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.1816 - accuracy: 0.9682
# Epoch 55/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1847 - accuracy: 0.9592
# Epoch 56/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1917 - accuracy: 0.9605
# Epoch 57/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1858 - accuracy: 0.9643
# Epoch 58/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1784 - accuracy: 0.9643
# Epoch 59/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1785 - accuracy: 0.9669
# Epoch 60/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1755 - accuracy: 0.9656
# Epoch 61/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1705 - accuracy: 0.9656
# Epoch 62/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1741 - accuracy: 0.9643
# Epoch 63/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1721 - accuracy: 0.9631
# Epoch 64/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1765 - accuracy: 0.9592
# Epoch 65/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1766 - accuracy: 0.9605
# Epoch 66/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1641 - accuracy: 0.9682
# Epoch 67/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1616 - accuracy: 0.9732
# Epoch 68/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1793 - accuracy: 0.9631
# Epoch 69/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.1657 - accuracy: 0.9771
# Epoch 70/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.1691 - accuracy: 0.9694
# Epoch 71/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.1751 - accuracy: 0.9643
# Epoch 72/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1671 - accuracy: 0.9669
# Epoch 73/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1720 - accuracy: 0.9631
# Epoch 74/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.1681 - accuracy: 0.9669
# Epoch 75/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1653 - accuracy: 0.9643
# Epoch 76/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1780 - accuracy: 0.9656
# Epoch 77/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1696 - accuracy: 0.9669
# Epoch 78/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1607 - accuracy: 0.9656
# Epoch 79/1500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.1626 - accuracy: 0.9732
# Epoch 80/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1767 - accuracy: 0.9580
# Epoch 81/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.1653 - accuracy: 0.9643
# Epoch 82/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1644 - accuracy: 0.9554
# Epoch 83/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1687 - accuracy: 0.9694
# Epoch 84/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1629 - accuracy: 0.9605
# Epoch 85/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1715 - accuracy: 0.9643
# Epoch 86/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.
1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1484 - accuracy: 0.9758
# Epoch 151/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1474 - accuracy: 0.9682
# Epoch 152/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1477 - accuracy: 0.9732
# Epoch 153/1500
# 12/13 [==========================>...] - ETA: 0s - loss: 0.1499 - accuracy: 0.9766Restoring model weights from the end of the best epoch: 123.
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1484 - accuracy: 0.9758
# Epoch 153: early stopping
# 6/6 [==============================] - 0s 1ms/step - loss: 2.4410 - accuracy: 0.6557
# 6/6 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.80 (20/25)
# Before appending - Cat IDs: 0, Predictions: 0, Actuals: 0, Gender: 0
# After appending - Cat IDs: 183, Predictions: 183, Actuals: 183, Gender: 183
# Final Test Results - Loss: 2.441026449203491, Accuracy: 0.6557376980781555, Precision: 0.582518877013735, Recall: 0.5168128654970761, F1 Score: 0.5290983449910179
# Confusion Matrix:
#  [[97  5 18]
#  [24 13  1]
#  [14  1 10]]
# outer_fold 2
# Train Set Group Distribution:
# 046A    66
# 103A    33
# 047A    30
# 074A    25
# 020A    23
# 000B    20
# 067A    20
# 055A    20
# 059A    18
# 101A    16
# 097A    16
# 106A    15
# 097B    14
# 028A    14
# 042A    14
# 002A    13
# 039A    12
# 116A    12
# 051A    12
# 068A    11
# 025A    11
# 016A    11
# 014B    10
# 015A    10
# 071A    10
# 065A     9
# 051B     9
# 022A     9
# 072A     9
# 013B     8
# 095A     8
# 010A     8
# 094A     8
# 117A     7
# 027A     7
# 050A     7
# 031A     7
# 053A     7
# 025C     6
# 037A     6
# 021A     6
# 008A     6
# 034A     5
# 023B     5
# 070A     5
# 044A     5
# 035A     4
# 105A     4
# 026A     4
# 056A     3
# 011A     3
# 014A     3
# 113A     3
# 064A     3
# 060A     3
# 006A     3
# 025B     2
# 061A     2
# 087A     2
# 069A     2
# 032A     2
# 093A     2
# 102A     2
# 041A     1
# 004A     1
# 019B     1
# 076A     1
# 026B     1
# 115A     1
# 026C     1
# 073A     1
# 088A     1
# 096A     1
# 043A     1
# 049A     1
# 024A     1
# 091A     1
# 090A     1
# 110A     1
# 100A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 000A    39
# 002B    36
# 057A    28
# 029A    17
# 019A    17
# 001A    15
# 111A    13
# 036A    11
# 063A    11
# 005A    11
# 040A    10
# 033A     9
# 045A     9
# 099A     7
# 109A     6
# 007A     6
# 023A     6
# 108A     6
# 012A     5
# 075A     5
# 062A     5
# 003A     4
# 009A     4
# 052A     4
# 104A     4
# 058A     3
# 054A     2
# 018A     2
# 066A     2
# 038A     2
# 048A     1
# 092A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    239
# M    237
# F    191
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# M    119
# X    116
# F     66
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [002A, 028A, 070A, 000B, 071A, 020A, 015A, 026...
# kitten    [046A, 042A, 014B, 110A, 047A, 049A, 044A, 043...
# senior    [117A, 106A, 090A, 113A, 051B, 116A, 051A, 024...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [033A, 000A, 038A, 007A, 001A, 018A, 062A, 002...
# kitten                       [109A, 040A, 045A, 048A, 111A]
# senior                       [057A, 058A, 054A, 108A, 104A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 52, 'kitten': 11, 'senior': 17}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 22, 'kitten': 5, 'senior': 5}
# Unique Training/Validation Group IDs:
# ['000B' '002A' '004A' '006A' '008A' '010A' '011A' '013B' '014A' '014B'
#  '015A' '016A' '019B' '020A' '021A' '022A' '023B' '024A' '025A' '025B'
#  '025C' '026A' '026B' '026C' '027A' '028A' '031A' '032A' '034A' '035A'
#  '037A' '039A' '041A' '042A' '043A' '044A' '046A' '047A' '049A' '050A'
#  '051A' '051B' '053A' '055A' '056A' '059A' '060A' '061A' '064A' '065A'
#  '067A' '068A' '069A' '070A' '071A' '072A' '073A' '074A' '076A' '087A'
#  '088A' '090A' '091A' '093A' '094A' '095A' '096A' '097A' '097B' '100A'
#  '101A' '102A' '103A' '105A' '106A' '110A' '113A' '115A' '116A' '117A']
# Unique Test Group IDs:
# ['000A' '001A' '002B' '003A' '005A' '007A' '009A' '012A' '018A' '019A'
#  '023A' '029A' '033A' '036A' '038A' '040A' '045A' '048A' '052A' '054A'
#  '057A' '058A' '062A' '063A' '066A' '075A' '092A' '099A' '104A' '108A'
#  '109A' '111A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'000A'}
# Removed from Training/Validation Set:
# {'091A'}
# Moved to Test Set:
# {'091A'}
# Removed from Test Set
# {'000A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '002A' '004A' '006A' '008A' '010A' '011A' '013B' '014A'
#  '014B' '015A' '016A' '019B' '020A' '021A' '022A' '023B' '024A' '025A'
#  '025B' '025C' '026A' '026B' '026C' '027A' '028A' '031A' '032A' '034A'
#  '035A' '037A' '039A' '041A' '042A' '043A' '044A' '046A' '047A' '049A'
#  '050A' '051A' '051B' '053A' '055A' '056A' '059A' '060A' '061A' '064A'
#  '065A' '067A' '068A' '069A' '070A' '071A' '072A' '073A' '074A' '076A'
#  '087A' '088A' '090A' '093A' '094A' '095A' '096A' '097A' '097B' '100A'
#  '101A' '102A' '103A' '105A' '106A' '110A' '113A' '115A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['001A' '002B' '003A' '005A' '007A' '009A' '012A' '018A' '019A' '023A'
#  '029A' '033A' '036A' '038A' '040A' '045A' '048A' '052A' '054A' '057A'
#  '058A' '062A' '063A' '066A' '075A' '091A' '092A' '099A' '104A' '108A'
#  '109A' '111A']
# Length of X_train_val:
# 705
# Length of y_train_val:
# 705
# Length of groups_train_val:
# 705
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     387
# senior    143
# kitten    137
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     219
# senior     43
# kitten     39
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     425
# senior    143
# kitten    137
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     181
# senior     43
# kitten     39
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 425, 2: 143, 1: 137})
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Epoch 1/1500
# 12/12 [==============================] - 1s 4ms/step - loss: 1.3666 - accuracy: 0.5305
# Epoch 2/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.8227 - accuracy: 0.7135
# Epoch 3/1500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.5467 - accuracy: 0.8057
# Epoch 4/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4932 - accuracy: 0.8355
# Epoch 5/1500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4478 - accuracy: 0.8652
# Epoch 6/1500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4179 - accuracy: 0.8723
# Epoch 7/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3506 - accuracy: 0.8950
# Epoch 8/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3299 - accuracy: 0.9163
# Epoch 9/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.3069 - accuracy: 0.9305
# Epoch 10/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2686 - accuracy: 0.9461
# Epoch 11/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3053 - accuracy: 0.9248
# Epoch 12/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2531 - accuracy: 0.9518
# Epoch 13/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2482 - accuracy: 0.9574
# Epoch 14/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2493 - accuracy: 0.9489
# Epoch 15/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2486 - accuracy: 0.9433
# Epoch 16/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2391 - accuracy: 0.9504
# Epoch 17/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2426 - accuracy: 0.9574
# Epoch 18/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2428 - accuracy: 0.9418
# Epoch 19/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2247 - accuracy: 0.9560
# Epoch 20/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2363 - accuracy: 0.9489
# Epoch 21/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2214 - accuracy: 0.9645
# Epoch 22/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2392 - accuracy: 0.9546
# Epoch 23/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2325 - accuracy: 0.9574
# Epoch 24/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.
1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1659 - accuracy: 0.9674
# Epoch 89/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1609 - accuracy: 0.9745
# Epoch 90/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1609 - accuracy: 0.9716
# Epoch 91/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1636 - accuracy: 0.9631
# Epoch 92/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1657 - accuracy: 0.9589
# Epoch 93/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1691 - accuracy: 0.9688
# Epoch 94/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1713 - accuracy: 0.9603
# Epoch 95/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1719 - accuracy: 0.9645
# Epoch 96/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1635 - accuracy: 0.9773
# Epoch 97/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1656 - accuracy: 0.9759
# Epoch 98/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1700 - accuracy: 0.9617
# Epoch 99/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1644 - accuracy: 0.9716
# Epoch 100/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1646 - accuracy: 0.9645
# Epoch 101/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1664 - accuracy: 0.9589
# Epoch 102/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1709 - accuracy: 0.9574
# Epoch 103/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1646 - accuracy: 0.9688
# Epoch 104/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1672 - accuracy: 0.9631
# Epoch 105/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1680 - accuracy: 0.9617
# Epoch 106/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1618 - accuracy: 0.9730
# Epoch 107/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1602 - accuracy: 0.9759
# Epoch 108/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1582 - accuracy: 0.9759
# Epoch 109/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1567 - accuracy: 0.9730
# Epoch 110/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1643 - accuracy: 0.9631
# Epoch 111/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1641 - accuracy: 0.9660
# Epoch 112/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1688 - accuracy: 0.9560
# Epoch 113/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1623 - accuracy: 0.9745
# Epoch 114/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1577 - accuracy: 0.9801
# Epoch 115/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1596 - accuracy: 0.9702
# Epoch 116/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1593 - accuracy: 0.9730
# Epoch 117/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1576 - accuracy: 0.9660
# Epoch 118/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1619 - accuracy: 0.9617
# Epoch 119/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1593 - accuracy: 0.9759
# Epoch 120/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1565 - accuracy: 0.9759
# Epoch 121/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1562 - accuracy: 0.9816
# Epoch 122/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1562 - accuracy: 0.9716
# Epoch 123/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1575 - accuracy: 0.9716
# Epoch 124/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1559 - accuracy: 0.9745
# Epoch 125/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1595 - accuracy: 0.9688
# Epoch 126/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1559 - accuracy: 0.9759
# Epoch 127/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1562 - accuracy: 0.9660
# Epoch 128/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1624 - accuracy: 0.9773
# Epoch 129/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1589 - accuracy: 0.9617
# Epoch 130/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1562 - accuracy: 0.9759
# Epoch 131/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1541 - accuracy: 0.9702
# Epoch 132/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1533 - accuracy: 0.9745
# Epoch 133/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1629 - accuracy: 0.9546
# Epoch 134/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1569 - accuracy: 0.9716
# Epoch 135/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1542 - accuracy: 0.9773
# Epoch 136/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1575 - accuracy: 0.9759
# Epoch 137/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1617 - accuracy: 0.9674
# Epoch 138/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1627 - accuracy: 0.9745
# Epoch 139/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1623 - accuracy: 0.9660
# Epoch 140/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1638 - accuracy: 0.9574
# Epoch 141/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1565 - accuracy: 0.9674
# Epoch 142/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1553 - accuracy: 0.9631
# Epoch 143/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1582 - accuracy: 0.9801
# Epoch 144/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1558 - accuracy: 0.9702
# Epoch 145/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1577 - accuracy: 0.9759
# Epoch 146/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1541 - accuracy: 0.9730
# Epoch 147/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1524 - accuracy: 0.9830
# Epoch 148/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1520 - accuracy: 0.9730
# Epoch 149/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1554 - accuracy: 0.9830
# Epoch 150/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1590 - accuracy: 0.9660
# Epoch 151/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1541 - accuracy: 0.9688
# Epoch 152/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1532 - accuracy: 0.9645
# Epoch 153/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1555 - accuracy: 0.9702
# Epoch 154/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1594 - accuracy: 0.9660
# Epoch 155/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1620 - accuracy: 0.9617
# Epoch 156/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1628 - accuracy: 0.9716
# Epoch 157/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1604 - accuracy: 0.9674
# Epoch 158/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1565 - accuracy: 0.9660
# Epoch 159/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1496 - accuracy: 0.9801
# Epoch 160/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1565 - accuracy: 0.9759
# Epoch 161/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1577 - accuracy: 0.9787
# Epoch 162/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1547 - accuracy: 0.9816
# Epoch 163/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1509 - accuracy: 0.9816
# Epoch 164/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1577 - accuracy: 0.9702
# Epoch 165/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1546 - accuracy: 0.9660
# Epoch 166/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1580 - accuracy: 0.9716
# Epoch 167/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1582 - accuracy: 0.9660
# Epoch 168/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1591 - accuracy: 0.9617
# Epoch 169/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1652 - accuracy: 0.9645
# Epoch 170/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1551 - accuracy: 0.9801
# Epoch 171/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1529 - accuracy: 0.9660
# Epoch 172/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1568 - accuracy: 0.9702
# Epoch 173/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1590 - accuracy: 0.9674
# Epoch 174/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1525 - accuracy: 0.9745
# Epoch 175/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1527 - accuracy: 0.9645
# Epoch 176/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1508 - accuracy: 0.9787
# Epoch 177/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1489 - accuracy: 0.9716
# Epoch 178/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1554 - accuracy: 0.9631
# Epoch 179/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1589 - accuracy: 0.9617
# Epoch 180/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1513 - accuracy: 0.9858
# Epoch 181/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1517 - accuracy: 0.9816
# Epoch 182/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1545 - accuracy: 0.9645
# Epoch 183/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1509 - accuracy: 0.9745
# Epoch 184/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1524 - accuracy: 0.9660
# Epoch 185/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1523 - accuracy: 0.9773
# Epoch 186/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1540 - accuracy: 0.9688
# Epoch 187/1500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1536 - accuracy: 0.9716
# Epoch 188/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1516 - accuracy: 0.9801
# Epoch 189/1500
#  1/12 [=>............................] - ETA: 0s - loss: 0.1672 - accuracy: 1.0000Restoring model weights from the end of the best epoch: 159.
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1493 - accuracy: 0.9702
# Epoch 189: early stopping
# 9/9 [==============================] - 0s 1ms/step - loss: 1.6675 - accuracy: 0.6882
# 9/9 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.84 (27/32)
# Before appending - Cat IDs: 183, Predictions: 183, Actuals: 183, Gender: 183
# After appending - Cat IDs: 446, Predictions: 446, Actuals: 446, Gender: 446
# Final Test Results - Loss: 1.667500376701355, Accuracy: 0.6882129311561584, Precision: 0.575856706054438, Recall: 0.5928030739799981, F1 Score: 0.5831352146187916
# Confusion Matrix:
#  [[141  13  27]
#  [ 10  29   0]
#  [ 30   2  11]]
# outer_fold 3
# Train Set Group Distribution:
# 046A    66
# 000A    39
# 002B    36
# 103A    33
# 047A    30
# 057A    28
# 020A    23
# 055A    20
# 000B    20
# 059A    18
# 029A    17
# 019A    17
# 097A    16
# 101A    16
# 001A    15
# 042A    14
# 028A    14
# 097B    14
# 111A    13
# 002A    13
# 005A    11
# 068A    11
# 063A    11
# 036A    11
# 071A    10
# 014B    10
# 040A    10
# 015A    10
# 051B     9
# 072A     9
# 033A     9
# 022A     9
# 045A     9
# 013B     8
# 095A     8
# 099A     7
# 117A     7
# 027A     7
# 031A     7
# 050A     7
# 108A     6
# 023A     6
# 008A     6
# 025C     6
# 109A     6
# 007A     6
# 023B     5
# 034A     5
# 012A     5
# 062A     5
# 075A     5
# 070A     5
# 052A     4
# 009A     4
# 104A     4
# 003A     4
# 105A     4
# 056A     3
# 011A     3
# 113A     3
# 006A     3
# 064A     3
# 058A     3
# 102A     2
# 093A     2
# 038A     2
# 069A     2
# 066A     2
# 054A     2
# 018A     2
# 032A     2
# 115A     1
# 041A     1
# 076A     1
# 110A     1
# 004A     1
# 096A     1
# 088A     1
# 091A     1
# 048A     1
# 024A     1
# 092A     1
# 049A     1
# 026C     1
# 026B     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 074A    25
# 067A    20
# 106A    15
# 039A    12
# 116A    12
# 051A    12
# 025A    11
# 016A    11
# 065A     9
# 094A     8
# 010A     8
# 053A     7
# 021A     6
# 037A     6
# 044A     5
# 026A     4
# 035A     4
# 060A     3
# 014A     3
# 061A     2
# 087A     2
# 025B     2
# 043A     1
# 073A     1
# 090A     1
# 019B     1
# 100A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    325
# M    258
# F    193
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# M    98
# F    64
# X    30
# Name: gender, dtype: int64
# ...
# Epoch 34/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.2057 - accuracy: 0.9451
# Epoch 35/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.2007 - accuracy: 0.9561
# Epoch 36/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1949 - accuracy: 0.9506
# Epoch 37/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1795 - accuracy: 0.9547
# Epoch 38/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1840 - accuracy: 0.9588
# Epoch 39/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1833 - accuracy: 0.9588
# Epoch 40/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1815 - accuracy: 0.9561
# Epoch 41/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1809 - accuracy: 0.9588
# Epoch 42/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1837 - accuracy: 0.9657
# Epoch 43/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1851 - accuracy: 0.9492
# Epoch 44/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1826 - accuracy: 0.9506
# Epoch 45/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1746 - accuracy: 0.9739
# Epoch 46/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1776 - accuracy: 0.9602
# Epoch 47/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1834 - accuracy: 0.9575
# Epoch 48/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1853 - accuracy: 0.9492
# Epoch 49/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1868 - accuracy: 0.9602
# Epoch 50/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1774 - accuracy: 0.9588
# Epoch 51/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1851 - accuracy: 0.9630
# Epoch 52/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1714 - accuracy: 0.9575
# Epoch 53/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1677 - accuracy: 0.9616
# Epoch 54/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1654 - accuracy: 0.9616
# Epoch 55/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1625 - accuracy: 0.9671
# Epoch 56/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1772 - accuracy: 0.9602
# Epoch 57/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1692 - accuracy: 0.9698
# Epoch 58/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1770 - accuracy: 0.9561
# Epoch 59/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1683 - accuracy: 0.9602
# Epoch 60/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1775 - accuracy: 0.9630
# Epoch 61/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1733 - accuracy: 0.9575
# Epoch 62/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1768 - accuracy: 0.9657
# Epoch 63/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1730 - accuracy: 0.9520
# Epoch 64/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1666 - accuracy: 0.9739
# Epoch 65/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1658 - accuracy: 0.9588
# Epoch 66/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1622 - accuracy: 0.9657
# Epoch 67/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1669 - accuracy: 0.9630
# Epoch 68/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1705 - accuracy: 0.9643
# Epoch 69/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1620 - accuracy: 0.9630
# Epoch 70/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1810 - accuracy: 0.9547
# Epoch 71/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1686 - accuracy: 0.9616
# Epoch 72/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1684 - accuracy: 0.9698
# Epoch 73/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1696 - accuracy: 0.9657
# Epoch 74/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1643 - accuracy: 0.9588
# Epoch 75/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1599 - accuracy: 0.9698
# Epoch 76/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.
1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1456 - accuracy: 0.9753
# Epoch 141/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1418 - accuracy: 0.9712
# Epoch 142/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1451 - accuracy: 0.9684
# Epoch 143/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1495 - accuracy: 0.9630
# Epoch 144/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1451 - accuracy: 0.9643
# Epoch 145/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1462 - accuracy: 0.9671
# Epoch 146/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1439 - accuracy: 0.9712
# Epoch 147/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1437 - accuracy: 0.9684
# Epoch 148/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1461 - accuracy: 0.9630
# Epoch 149/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1403 - accuracy: 0.9794
# Epoch 150/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1438 - accuracy: 0.9643
# Epoch 151/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1414 - accuracy: 0.9767
# Epoch 152/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1440 - accuracy: 0.9684
# Epoch 153/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1415 - accuracy: 0.9698
# Epoch 154/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1463 - accuracy: 0.9657
# Epoch 155/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1423 - accuracy: 0.9643
# Epoch 156/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1452 - accuracy: 0.9726
# Epoch 157/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1460 - accuracy: 0.9753
# Epoch 158/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1420 - accuracy: 0.9698
# Epoch 159/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1409 - accuracy: 0.9698
# Epoch 160/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1451 - accuracy: 0.9643
# Epoch 161/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1444 - accuracy: 0.9671
# Epoch 162/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1403 - accuracy: 0.9794
# Epoch 163/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1414 - accuracy: 0.9684
# Epoch 164/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1450 - accuracy: 0.9698
# Epoch 165/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1445 - accuracy: 0.9698
# Epoch 166/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1494 - accuracy: 0.9657
# Epoch 167/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1472 - accuracy: 0.9698
# Epoch 168/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1449 - accuracy: 0.9684
# Epoch 169/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1414 - accuracy: 0.9726
# Epoch 170/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1427 - accuracy: 0.9657
# Epoch 171/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1419 - accuracy: 0.9657
# Epoch 172/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1443 - accuracy: 0.9657
# Epoch 173/1500
# 12/12 [==============================] - 0s 8ms/step - loss: 0.1428 - accuracy: 0.9794
# Epoch 174/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1423 - accuracy: 0.9781
# Epoch 175/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1445 - accuracy: 0.9643
# Epoch 176/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1443 - accuracy: 0.9712
# Epoch 177/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1408 - accuracy: 0.9794
# Epoch 178/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1394 - accuracy: 0.9712
# Epoch 179/1500
# 11/12 [==========================>...] - ETA: 0s - loss: 0.1364 - accuracy: 0.9744Restoring model weights from the end of the best epoch: 149.
# 12/12 [==============================] - 0s 6ms/step - loss: 0.1395 - accuracy: 0.9726
# Epoch 179: early stopping
# 8/8 [==============================] - 0s 1ms/step - loss: 2.1063 - accuracy: 0.6485
# 8/8 [==============================] - 0s 998us/step
# Majority Vote Accuracy for cat_id for this fold: 0.79 (22/28)
# Before appending - Cat IDs: 638, Predictions: 638, Actuals: 638, Gender: 638
# After appending - Cat IDs: 877, Predictions: 877, Actuals: 877, Gender: 877
# Final Test Results - Loss: 2.1062684059143066, Accuracy: 0.6485355496406555, Precision: 0.627342549923195, Recall: 0.5910695165142904, F1 Score: 0.6046795188663702
# Confusion Matrix:
#  [[105   9  28]
#  [ 14  21   5]
#  [ 28   0  29]]
#
# Final Average F1-Score across all UNSEEN TEST sets: 0.5389071640344693
#
# Final Average Loss across all UNSEEN TEST sets: 2.1327371299266815
#
# Final Average Accuracy across all UNSEEN TEST sets: 0.6530694663524628
#
# Final Average Precision across all UNSEEN TEST sets: 0.5623178116361203
#
# Final Average Recall across all UNSEEN TEST sets: 0.5755119833056735

# %%
seed_5_folds_values = (unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1)

# Plotting all fold metrics|
seed_5_folds_plot = plot_all_metrics(unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1, "Folds", "Fold Number")

# %% [markdown]
# ## Majority Voting on Total Entries per cat_id

# %%
# Debugging print statements
print(f'Checking - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
# Out:
# Checking - Cat IDs: 877, Predictions: 877, Actuals: 877, Gender: 877

# %%
# Create results df
full_results = pd.DataFrame({
    'cat_id': all_cat_ids,
    'predicted_age_group': all_predicted_age_groups,
    'actual_age_group': all_actual_age_groups,
    'all_gender': all_gender
})

# create a correct majority prediction column
full_results['correct'] = full_results['predicted_age_group'] == full_results['actual_age_group']

# %%
# Group by cat_id and aggregate predicted age groups
majority_votes = full_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first()

# Calculate the accuracy of majority voting
correct_predictions = (majority_votes == actual_groups).sum()
total_cats = len(actual_groups)
majority_vote_accuracy = correct_predictions / total_cats

logger(f"Overall Majority Vote Accuracy for cat_id: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

# store for final evaluation 
all_majority_vote_accuracies.append(majority_vote_accuracy)
# Out:
# Overall Majority Vote Accuracy for cat_id: 0.78 (86/110)

# %%
# Detailed df with predictions, actual labels, and comparison including majority vote
detailed_results = full_results.groupby('cat_id').apply(
    lambda x: pd.Series({
        'Predictions': list(x['predicted_age_group']),
        'Majority Vote': x['predicted_age_group'].mode()[0],
        'Actual Age Group': x['actual_age_group'].iloc[0],
        'Correct Majority Vote': x['predicted_age_group'].mode()[0] == x['actual_age_group'].iloc[0]
    })
).reset_index()

# Convert to DataFrame for better formatting and display
detailed_results = pd.DataFrame(detailed_results)

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 10)
pd.set_option('display.width', 1000)

sorted_detailed_results = detailed_results.sort_values(by='Correct Majority Vote', ascending=False)

# Display the sorted DataFrame
sorted_detailed_results
# Out:
#     cat_id                                        Predictions Majority Vote Actual Age Group  Correct Majority Vote
# 0     000B  [adult, adult, senior, senior, adult, adult, a...         adult            adult                   True
# 76    070A                [adult, adult, adult, adult, adult]         adult            adult                   True
#

# Total Gender Accuracy so far:
#  [  all_gender  count  correct  accuracy
# 0          F    218      138     63.30
# 1          M    362      271     74.86
# 2          X    290      172     59.31,   all_gender  count  correct  accuracy
# 0          F    218      123     56.42
# 1          M    357      265     74.23
# 2          X    299      158     52.84,   all_gender  count  correct  accuracy
# 0          F    225      141     62.67
# 1          M    356      273     76.69
# 2          X    296      158     53.38,   all_gender  count  correct  accuracy
# 0          F    218      136     62.39
# 1          M    373      282     75.60
# 2          X    294      172     58.50,   all_gender  count  correct  accuracy
# 0          F    218      150     68.81
# 1          M    357      248     69.47
# 2          X    302      177     58.61]

# %% [markdown]
# # --------------

# %% [markdown]
# # Total Final Results & Analysis

# %%
# Count unique cat_id per age group 
unique_cats_per_age_group = dataframe.groupby('age_group')['cat_id'].nunique()

# Display the counts
print("Unique cat_id counts in original dataframe:", unique_cats_per_age_group)
# Out:
# Unique cat_id counts in original dataframe: age_group
# adult     74
# kitten    16
# senior    22
# Name: cat_id, dtype: int64

# %% [markdown]
# ## Metrics

# %%
# Calculate overall metrics
overall_avg_loss = np.mean(all_losses)
overall_avg_acc = np.mean(all_accuracies)
overall_avg_precision = np.mean(all_precisions)
overall_avg_recall = np.mean(all_recalls)
overall_avg_f1 = np.mean(all_f1)

print("Overall Average Metrics:")
print("Loss:", overall_avg_loss)
print("Accuracy:", overall_avg_acc)
print("Precision:", overall_avg_precision)
print("Recall:", overall_avg_recall)
print("F1 Score:", overall_avg_f1)
# Out:
# Overall Average Metrics:
# Loss: 2.360909914970398
# Accuracy: 0.6514773011207581
# Precision: 0.5622803636435293
# Recall: 0.5722200509917508
# F1 Score: 0.5399874406057591

# %% [markdown]
# ## Majority Votes

# %%
# Average of majority vote accuracies
average_majority_vote_accuracy = np.mean(all_majority_vote_accuracies)
print("Average Majority Vote Accuracy:", average_majority_vote_accuracy)
# Out:
# Average Majority Vote Accuracy: 0.7709090909090909

# %%
# Concatenate all class stats DataFrames and calculate the mean of accuracies
total_majority_vote_details = pd.concat(all_majority_vote_details)
average_majority_vote_details = total_majority_vote_details.groupby('actual_age_group').agg({
    'total_count': 'sum', 
    'correct_count': 'sum' 
}).reset_index()
average_majority_vote_details['accuracy'] = (average_majority_vote_details['correct_count'] / average_majority_vote_details['total_count']) * 100

print("Average Class Statistics:")
print(average_majority_vote_details)
# Out:
# Average Class Statistics:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult          365            345  94.520548
# 1           kitten           75             54  72.000000
# 2           senior          110             25  22.727273

# %%
# Plot for Detailed Class Statistics for Majority Votes
styled_barplot(average_majority_vote_details, 'actual_age_group', 'accuracy', 
               'Accuracy of Majority Votes by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Detailed Class Statistics

# %%
# Concatenate all class stats DataFrames and calculate the mean of accuracies
total_class_stats = pd.concat(all_class_stats)
average_class_stats = total_class_stats.groupby('actual_age_group').agg({
    'total_count': 'sum',  
    'correct_count': 'sum' 
}).reset_index()
average_class_stats['accuracy'] = (average_class_stats['correct_count'] / average_class_stats['total_count']) * 100

print("Average Class Statistics:")
print(average_class_stats)
# Out:
# Average Class Statistics:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult         2867           2282  79.595396
# 1           kitten          586            293  50.000000
# 2           senior          930            289  31.075269

# %%
# Plot for Detailed Class Statistics (Overall)
styled_barplot(average_class_stats, 'actual_age_group', 'accuracy', 
               'Overall Accuracy by Age Group', 
               'Age Group', 'Accuracy (%)')

# %%
# Concatenate all gender stats DataFrames and calculate the mean of accuracies
total_gender_stats = pd.concat(all_gender_stats)
average_gender_stats = total_gender_stats.groupby('all_gender').agg({
    'count': 'sum',  
    'correct': 'sum'  
}).reset_index()
average_gender_stats['accuracy'] = (average_gender_stats['correct'] / average_gender_stats['count']) * 100

print("Average Gender Accuracy:")
print(average_gender_stats)
# Out:
# Average Gender Accuracy:
#   all_gender  count  correct   accuracy
# 0          F   1097      688  62.716500
# 1          M   1805     1339  74.182825
# 2          X   1481      837  56.515868

# %%
# Plot for Accuracy by Gender
styled_barplot(total_gender_stats, 'all_gender', 'accuracy', 
               'Accuracy by Gender', 
               'Gender', 'Accuracy (%)')

# %% [markdown]
# # Visualisations

# %%
# Plotting all metrics
metrics_across_seeds = plot_all_metrics(all_losses, all_accuracies, all_precisions, all_recalls, all_f1, "Seeds", "Seed Number")

# %%
# Calculate the standard deviation for each metric
std_loss = np.std(all_losses)
std_accuracy = np.std(all_accuracies)
std_precision = np.std(all_precisions)
std_recall = np.std(all_recalls)
std_f1 = np.std(all_f1)

print("Standard Deviations:")
print(f"Loss: {std_loss}")
print(f"Accuracy: {std_accuracy}")
print(f"Precision: {std_precision}")
print(f"Recall: {std_recall}")
print(f"F1 Score: {std_f1}")
# Out:
# Standard Deviations:
# Loss: 0.4938788482176995
# Accuracy: 0.012430888495084932
# Precision: 0.02721505271561417
# Recall: 0.04068906990247164
# F1 Score: 0.028278418757164133

# %%
# Calculate the interquartile range for each metric
iqr_loss = np.percentile(all_losses, 75) - np.percentile(all_losses, 25)
iqr_accuracy = np.percentile(all_accuracies, 75) - np.percentile(all_accuracies, 25)
iqr_precision = np.percentile(all_precisions, 75) - np.percentile(all_precisions, 25)
iqr_recall = np.percentile(all_recalls, 75) - np.percentile(all_recalls, 25)
iqr_f1 = np.percentile(all_f1, 75) - np.percentile(all_f1, 25)

print("Interquartile Ranges:")
print(f"Loss: {iqr_loss}")
print(f"Accuracy: {iqr_accuracy}")
print(f"Precision: {iqr_precision}")
print(f"Recall: {iqr_recall}")
print(f"F1 Score: {iqr_f1}")
# Out:
# Interquartile Ranges:
# Loss: 0.09620639681816101
# Accuracy: 0.002090081572532654
# Precision: 0.013953891787335637
# Recall: 0.06199624619883326
# F1 Score: 0.01197890903955856

# %% [markdown]
# ## Display the seed folds results together

# %%
# Create a figure with subplots
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(18, 12))  

# Flatten the axes array for easier indexing
axes = axes.flatten()

def plot_metrics_on_axes(ax, losses, accuracies, precisions, recalls, f1, title):
    ax.plot(range(1, len(losses)+1), losses, marker='o', color='blue', label='Loss')
    ax.plot(range(1, len(accuracies)+1), accuracies, marker='o', color='green', label='Accuracy')
    ax.plot(range(1, len(precisions)+1), precisions, marker='o', color='red', label='Precision')
    ax.plot(range(1, len(recalls)+1), recalls, marker='o', color='purple', label='Recall')
    ax.plot(range(1, len(f1)+1), f1, marker='o', color='orange', label='F1 Score')
    ax.set_xticks([1, 2, 3, 4])  # Set x-axis ticks to full integers
    ax.set_title(title)
    ax.set_xlabel('Fold Number')
    ax.set_ylabel('Metric Value')
    ax.legend()
    ax.grid(True)

# Plot onto each axes object
plot_metrics_on_axes(axes[0], *seed_1_folds_values, "Seed 1 Metrics")
plot_metrics_on_axes(axes[1], *seed_2_folds_values, "Seed 2 Metrics")
plot_metrics_on_axes(axes[2], *seed_3_folds_values, "Seed 3 Metrics")
plot_metrics_on_axes(axes[3], *seed_4_folds_values, "Seed 4 Metrics")
plot_metrics_on_axes(axes[4], *seed_5_folds_values, "Seed 5 Metrics")

# Hide the unused subplot 
for ax in axes[5:]:
    ax.set_visible(False)

# Adjust layout
plt.tight_layout()
plt.show()
