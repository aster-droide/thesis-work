# %% [markdown]
# # YAMNet Multi Seed Validation
# #### 5 Random (but reproducible) seeds are selected for 5 different runs of train/test
# #### Models have been optimised and verified on validation sets thoroughly, running a final train/test evaluation here
# #### The setup:
#
# - 4 fold StratifiedGroupKFold for stratification and ensuring each cat_id group only appears in one set at a time
# - Final scores averaged over the 4 folds
# - For each seed run we will explore the cat_id predictions through majority voting
# - For each run we will explore the potential impact of gender
# - Includes visualisations & analysis
#
# The dataset is highly unbalanced.

# %%
# Standard imports
import numpy as np
import pandas as pd
import random
from datetime import datetime
from collections import Counter

# Sklearn imports
from sklearn.model_selection import train_test_split, GroupShuffleSplit, GroupKFold, StratifiedGroupKFold
from sklearn.preprocessing import LabelEncoder, MinMaxScaler, RobustScaler, StandardScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report
from sklearn.utils.class_weight import compute_class_weight
from sklearn.inspection import permutation_importance

# Imbalanced-learn import
from imblearn.over_sampling import SMOTE

# TensorFlow and Keras imports
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Dropout, Input, BatchNormalization, concatenate
from tensorflow.keras.optimizers import Adam, RMSprop, SGD, Adamax, AdamW
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import to_categorical
from keras.regularizers import l1, l2, L1L2

# Optuna import
import optuna

# Visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns

from IPython.display import display

# %%
# Set an initial seed for reproducibility
np.random.seed(42)  

# Generate a list of 5 random seeds
random_seeds = np.random.randint(0, 10000, size=5)
print("Random Seeds:", random_seeds)
# Out:
# Random Seeds: [7270  860 5390 5191 5734]

# %% [markdown]
# #### TOTAL RESULTS ACROSS SEED INITIATION

# %%
# Lists to collect statistics across all CVs
all_losses, all_accuracies, all_precisions, all_recalls, all_f1 = [], [], [], [], []
all_majority_vote_accuracies, all_majority_vote_details, all_class_stats, all_gender_stats  = [], [], [], []

# %% [markdown]
# ## Define Functions

# %%
def check_initial_group_split(groups_train, groups_test):
    """
    Check if any group is present in both the train and test sets.

    Parameters:
    - groups_train: Array of group identifiers for the train set
    - groups_test: Array of group identifiers for the test set

    Returns:
    - Prints out any groups found in both sets and the count of such groups
    """
    train_groups = set(groups_train)
    test_groups = set(groups_test)
    common_groups = train_groups.intersection(test_groups)

    if common_groups:
        print(f"Warning: Found {len(common_groups)} common groups in both train/validation and test sets: {common_groups}")
    else:
        print("No common groups found between train and test sets.")

# %%
# Function to perform the swaps based on cat_id, ensuring swaps within the same age_group
def swap_cat_id_instances(dataframe, train_val_idx, test_idx, specific_cat_ids):
    for cat_id in specific_cat_ids:
        # Check if the specific cat_id is not in the training set
        if cat_id not in dataframe.iloc[train_val_idx]['cat_id'].values:
            # Get the age_group of this cat_id
            age_group = dataframe[dataframe['cat_id'] == cat_id]['age_group'].iloc[0]
                
            # Find a different cat_id within the same age_group in the train set that is not in the test set
            other_cat_ids_in_age_group = dataframe[(dataframe['age_group'] == age_group) & 
                                                   (dataframe['cat_id'] != cat_id) &
                                                   (~dataframe['cat_id'].isin(dataframe.iloc[test_idx]['cat_id']))]['cat_id'].unique()
            
            # Choose one other cat_id for swapping
            if len(other_cat_ids_in_age_group) > 0:
                other_cat_id = np.random.choice(other_cat_ids_in_age_group)

                # Find all instances of the other_cat_id in the train set
                other_cat_id_train_val_indices = train_val_idx[dataframe.iloc[train_val_idx]['cat_id'] == other_cat_id]
                
                # Find all instances of the specific cat_id in the test set
                cat_id_test_indices = test_idx[dataframe.iloc[test_idx]['cat_id'] == cat_id]
                
                # Swap the indices
                train_val_idx = np.setdiff1d(train_val_idx, other_cat_id_train_val_indices, assume_unique=True)
                test_idx = np.setdiff1d(test_idx, cat_id_test_indices, assume_unique=True)

                train_val_idx = np.concatenate((train_val_idx, cat_id_test_indices))
                test_idx = np.concatenate((test_idx, other_cat_id_train_val_indices))
            else:
                print(f"No alternative cat_id found in the same age_group as {cat_id} for swapping.")
                
    return train_val_idx, test_idx

# %%
# Function to identify differences in groups
def find_group_differences(original, new):
    # Convert numpy arrays to sets for easy difference computation
    original_set = set(original)
    new_set = set(new)
    # Find differences
    moved_to_new = new_set - original_set
    moved_to_original = original_set - new_set
    return moved_to_new, moved_to_original

# %%
# create custom logger function for local logs & stored in a .txt
def logger(message, file=None):
    print(message)
    if file is not None:
        with open(file, "a") as log_file:
            log_file.write(message + "\n")

log_file_path = "multi-seed-val-D13.txt"

# %%
# Set the aesthetic style of the plots
sns.set(style="whitegrid", palette="deep")

# Define a custom color palette
colors = ["#6aabd1", "#b6e2d3", "#dac292"] 
sns.set_palette(sns.color_palette(colors))

# Function to create bar plots with enhanced style
def styled_barplot(data, x, y, title, xlabel, ylabel):
    plt.figure(figsize=(8, 4))
    bar_plot = sns.barplot(x=x, y=y, data=data, errorbar=None, width=0.5)  
    plt.title(title, fontsize=16, fontweight='bold', color="#333333")
    plt.xlabel(xlabel, fontsize=14, fontweight='bold', color="#333333")
    plt.ylabel(ylabel, fontsize=14, fontweight='bold', color="#333333")
    plt.xticks(fontsize=12, color="#333333")
    plt.yticks(fontsize=12, color="#333333")
    plt.ylim(0, 100) 

    # Adding value labels on top of each bar
    for p in bar_plot.patches:
        height = p.get_height()
        # Annotate the height value on the bar
        bar_plot.annotate(f'{height:.1f}', 
                          (p.get_x() + p.get_width() / 2., height), 
                          ha='center', va='center', 
                          xytext=(0, 9), 
                          textcoords='offset points', fontsize=12, color="#333333")

    plt.show()

# %%
def plot_all_metrics(losses, accuracies, precisions, recalls, f1, metrics_across, x_axis_label):
    fig, ax = plt.subplots(figsize=(12, 8))
    seeds = range(1, len(losses) + 1)

    ax.plot(seeds, losses, marker='o', color='blue', label='Loss')
    ax.plot(seeds, accuracies, marker='o', color='green', label='Accuracy')
    ax.plot(seeds, precisions, marker='o', color='red', label='Precision')
    ax.plot(seeds, recalls, marker='o', color='purple', label='Recall')
    ax.plot(seeds, f1, marker='o', color='orange', label='F1 Score')

    ax.set_title(f'Metrics Across {metrics_across}')
    ax.set_xlabel(x_axis_label)
    ax.set_ylabel('Metric Value')
    ax.set_xticks(seeds)
    ax.legend()
    ax.grid(True)

    return fig

# %% [markdown]
# # RANDOM SEED 1

# %% [markdown]
# ## Prepare Data

# %%
# Set a fixed random seed for reproducibility
random.seed(int(random_seeds[0])) 
np.random.seed(int(random_seeds[0]))
tf.random.set_seed(int(random_seeds[0]))

# Load datasets
dataframe = pd.read_csv('/Users/astrid/PycharmProjects/data-aug-and-more/yamnet-tfhub-extraction/yamnet_embeddings_looped_april_23.csv')


def assign_age_group(age, age_groups):
    for group_name, age_range in age_groups.items():
        if age_range[0] <= age < age_range[1]:
            return group_name
    return 'Unknown'  # For any age that doesn't fit the defined groups

# Define age groups
age_groups = {
    'kitten': (0, 0.5),
    'adult': (0.5, 12),
    'senior': (12, 20)
}

# Create a new column for the age group
dataframe['age_group'] = dataframe['target'].apply(assign_age_group, age_groups=age_groups)

print(dataframe['age_group'].value_counts())
# Out:
# adult     606
# senior    186
# kitten    176
# Name: age_group, dtype: int64

# %%
# Separate features and labels
X = dataframe.iloc[:, :-4].values  # all columns except the last four

# Encode the 'age_group' column as integers using LabelEncoder
label_encoder = LabelEncoder()
encoded_y = label_encoder.fit_transform(dataframe['age_group'].values)

# Use the encoded labels for splitting and one-hot encoding
y = encoded_y  

# Convert 'cat_id' column to numpy array to be used as groups array for GroupKFold
groups = dataframe['cat_id'].values

# %%
tf.keras.backend.clear_session()

# %% [markdown]
# ## Run Setup

# %%
all_cat_ids = []
all_predicted_age_groups = []
all_actual_age_groups = []
all_gender = []

# Define the StratifiedGroupKFold splitter for 4 fold CV with random shuffling
outer_cv = StratifiedGroupKFold(n_splits=4, shuffle=True, random_state=int(random_seeds[0]))

# unseen test set metrics
unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1 = [], [], [], [], []

outer_fold = 0

# Use the splitter to generate indices for training and testing sets
# Note: GroupShuffleSplit.split returns indices, so we use it to index the arrays
for train_val_idx, test_idx in outer_cv.split(X, y, groups):
    outer_fold += 1
    logger(f"outer_fold {outer_fold}", file=log_file_path)

    # Convert indices back to DataFrame for easy manipulation
    df_train_val = dataframe.iloc[train_val_idx]
    df_test = dataframe.iloc[test_idx]

    ##############################
    # ASSESSING SPLITS BY CAT_ID #
    ##############################
    
    # Get the distribution of groups
    training_validation_group_distribution = df_train_val['cat_id'].value_counts()  
    testing_group_distribution = df_test['cat_id'].value_counts()  
    
    # Log or print the distribution
    logger(f"Train Set Group Distribution:\n{training_validation_group_distribution}", file=log_file_path)
    logger(f"Testing Set Group Distribution:\n{testing_group_distribution}", file=log_file_path)

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val['gender'].value_counts()
    testing_gender_distribution = df_test['gender'].value_counts()
    
    # Log the distribution
    logger(f"Training Set Gender Distribution BEFORE SWAP:\n{training_gender_distribution}", file=log_file_path)
    logger(f"Testing Set Gender Distribution BEFORE SWAP:\n{testing_gender_distribution}", file=log_file_path)

    # Group by 'age_group' and then list unique 'cat_id' within each age group
    unique_cat_ids_per_age_group_train_val = df_train_val.groupby('age_group')['cat_id'].unique()
    unique_cat_ids_per_age_group_test = df_test.groupby('age_group')['cat_id'].unique()
    
    # Log results
    logger(f"Unique Cat IDs per Age Group in Training/Validation Set:\n{unique_cat_ids_per_age_group_train_val}", file=log_file_path)
    logger(f"Unique Cat IDs per Age Group in Testing Set:\n{unique_cat_ids_per_age_group_test}", file=log_file_path)

    # Calculate the count of unique identifiers per age group for training and testing set
    counts_train_val = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_train_val.items()}
    counts_test = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_test.items()}

    # Log the counts of unique identifiers per age group
    logger(f"Count of Unique Cat IDs per Age Group in Training/Validation Set:\n{counts_train_val}", file=log_file_path)
    logger(f"Count of Unique Cat IDs per Age Group in Testing Set:\n{counts_test}", file=log_file_path)

    #######################################################
    # CONTINUE WITH ENSURING VALID AND APPROPRIATE SPLITS #
    #######################################################
    
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    groups_train_val, groups_test = groups[train_val_idx], groups[test_idx]

    # logging identifier splits 
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)

    # check group splits
    check_initial_group_split(groups_train_val, groups_test)

    # Specify the cat_ids that must be in the training/validation set
    specific_cat_ids = ['000A', '046A']
    
    # Perform the swapping operation
    train_val_idx, test_idx = swap_cat_id_instances(dataframe, train_val_idx, test_idx, specific_cat_ids)
    
    # Re-assign the sets based on the updated indices
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    new_groups_train_val, new_groups_test = groups[train_val_idx], groups[test_idx]

    # Find differences for training and test sets
    moved_to_train_val, removed_from_train_val = find_group_differences(groups_train_val, new_groups_train_val)
    moved_to_test, removed_from_test = find_group_differences(groups_test, new_groups_test)
    
    # Display the results
    logger(f"Moved to Training/Validation Set:\n{moved_to_train_val}", file=log_file_path)
    logger(f"Removed from Training/Validation Set:\n{removed_from_train_val}", file=log_file_path)
    logger(f"Moved to Test Set:\n{moved_to_test}", file=log_file_path)
    logger(f"Removed from Test Set\n{removed_from_test}", file=log_file_path)

    # Update X_train_val, X_test, y_train_val, y_test, groups_train_val, groups_test based on updated indices
    X_train_val = X[train_val_idx]
    y_train_val = y[train_val_idx]
    groups_train_val = groups[train_val_idx]
    
    X_test = X[test_idx]
    y_test = y[test_idx]
    groups_test = groups[test_idx]

    # logging identifier splits again after potential swaps
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"AFTER SWAP - Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"AFTER SWAP - Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)
    
    # Verify the lengths are consistent
    logger(f"Length of X_train_val:\n{len(X_train_val)}", file=log_file_path)
    logger(f"Length of y_train_val:\n{len(y_train_val)}", file=log_file_path)
    logger(f"Length of groups_train_val:\n{len(groups_train_val)}", file=log_file_path)

    # Check group splits once more
    check_initial_group_split(groups_train_val, groups_test)

    # Convert the modified indices back to a DataFrame representing the updated df_train_val
    df_train_val_updated = dataframe.iloc[train_val_idx].copy()
    df_test_updated = dataframe.iloc[test_idx].copy()

    ############################
    # LOGGING AGE GROUP SPLITS #
    ############################

    # Get the distribution of age groups of age groups before the update
    training_validation_age_group_distribution = df_train_val['age_group'].value_counts()
    testing_age_group_distribution = df_test['age_group'].value_counts()
    
    # Logthe distribution
    logger(f"Train Age Group Distribution BEFORE SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution BEFORE SWAP:\n{testing_age_group_distribution}", file=log_file_path)

    # Get the distribution of age groups after the update
    training_validation_age_group_distribution = df_train_val_updated['age_group'].value_counts()
    testing_age_group_distribution = df_test_updated['age_group'].value_counts()
    
    # Log the distribution
    logger(f"Train Age Group Distribution AFTER SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution AFTER SWAP:\n{testing_age_group_distribution}", file=log_file_path)
    
    ########################################################
    # TRACKING FINAL CAT_IDs & GENDER AFTER REDISTRIBUTION #
    ########################################################

    # Get the distribution of groups
    training_validation_group_distribution = df_train_val_updated['cat_id'].value_counts()  
    testing_group_distribution = df_test_updated['cat_id'].value_counts()  

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val_updated['gender'].value_counts()
    testing_gender_distribution = df_test_updated['gender'].value_counts()
    
    logger(f"\n Starting training on unseen test set\n", file=log_file_path)

    ###################
    # PREPARING MODEL #
    ###################

    # Calculate the distribution of age groups in y_train_val
    age_group_distribution = Counter(y_train_val)
    print("Age group distribution:", age_group_distribution)

    # EarlyStopping callback: monitor 'loss' instead of 'val_loss' for the test set
    early_stopping = EarlyStopping(
        monitor='loss',  
        min_delta=0.001, 
        patience=30,  
        verbose=1,  
        restore_best_weights=True  
    )

    # Apply SMOTE to the training data only
    smote = SMOTE()
    X_train_val, y_train_val = smote.fit_resample(X_train_val, y_train_val)

    # One final shuffle to ensure randomness
    outer_shuffle_idx = np.random.permutation(len(X_train_val))
    X_train_val = X_train_val[outer_shuffle_idx]
    y_train_val = y_train_val[outer_shuffle_idx]
    
    # Scale the features
    scaler_full = StandardScaler().fit(X_train_val)
    X_train_full_scaled = scaler_full.transform(X_train_val)
    X_test_scaled = scaler_full.transform(X_test)
    
    # Encode the labels
    y_train_full_encoded = to_categorical(y_train_val)
    y_test_encoded = to_categorical(y_test)

    #######################
    # BUILD & TRAIN MODEL #
    #######################

    optimizers = {
        'Adamax': Adamax(learning_rate=0.00510251984616472)
    }
    
    # Model definition with dynamic number of layers
    model_full = Sequential()
    model_full.add(Dense(480, activation='relu', input_shape=(X_train_full_scaled.shape[1],)))
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.2011047009431978))  
    model_full.add(Dense(256, activation='relu',)) 
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.14956886311951184))  
    model_full.add(Dense(256, activation='relu'))  
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.42291461228250665))  
    model_full.add(Dense(3, activation='softmax'))  
    
    # Use the optimizer from the parameters
    optimizer = optimizers['Adamax']  # optimizer_key from parameters
    
    # Compile the model
    model_full.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    
    # Train the model on the full training set
    history_full = model_full.fit(X_train_full_scaled, y_train_full_encoded, epochs=1500, batch_size=64,
                                  verbose=1, callbacks=[early_stopping])
    
    # Evaluate the model on the held-out test set
    test_loss, test_accuracy = model_full.evaluate(X_test_scaled, y_test_encoded)

    y_test_pred_prob = model_full.predict(X_test_scaled)
    y_test_pred = np.argmax(y_test_pred_prob, axis=1)  
    y_test_true = np.argmax(y_test_encoded, axis=1)    

    ################################
    # LOG MAJORITY VOTE PER CAT_ID #
    ################################

    # Convert numeric predictions back to age group labels
    predicted_age_groups = label_encoder.inverse_transform(y_test_pred)
    actual_labels = label_encoder.inverse_transform(y_test_true)
    
    # Map predictions and actual labels back to cat_ids
    test_results = pd.DataFrame({
        'cat_id': df_test_updated['cat_id'],
        'predicted_age_group': predicted_age_groups,
        'actual_age_group': actual_labels
    })
    
    # Group by cat_id and aggregate predicted age groups
    majority_votes = test_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
    actual_groups = test_results.groupby('cat_id')['actual_age_group'].first()
    
    # Calculate the accuracy of majority voting
    correct_predictions = (majority_votes == actual_groups).sum()
    total_cats = len(actual_groups)
    majority_vote_accuracy = correct_predictions / total_cats
    
    # Log the accuracy of the majority voting
    logger(f"Majority Vote Accuracy for cat_id for this fold: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

    ####################################################
    # COLLECT PREDICTIONS FOR GENDER & CAT_ID ANALYSIS #
    ####################################################

    # Debugging print statements
    print(f'Before appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Extend lists with current fold results
    all_cat_ids.extend(df_test_updated['cat_id'].tolist())
    all_predicted_age_groups.extend(predicted_age_groups)
    all_actual_age_groups.extend(actual_labels)
    all_gender.extend(df_test_updated['gender'].tolist())

    # Debugging print statements
    print(f'After appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Calculate additional metrics
    test_precision = precision_score(y_test_true, y_test_pred, average='macro')  # Use 'macro' for imbalanced datasets
    test_recall = recall_score(y_test_true, y_test_pred, average='macro')
    test_f1 = f1_score(y_test_true, y_test_pred, average='macro')

    # prepare averages of outer metrics
    unseen_f1.append(test_f1)
    unseen_losses.append(test_loss)
    unseen_accuracies.append(test_accuracy)
    unseen_precisions.append(test_precision)
    unseen_recalls.append(test_recall)

    # Print final test results
    logger(f"Final Test Results - Loss: {test_loss}, Accuracy: {test_accuracy}, Precision: {test_precision}, Recall: {test_recall}, F1 Score: {test_f1}", file=log_file_path)

    # Generate the confusion matrix
    cm = confusion_matrix(y_test, y_test_pred)
    logger(f"Confusion Matrix:\n {cm}", file=log_file_path)

# Calculate the overall average metrics
unseen_set_avg_f1 = np.mean(unseen_f1)
unseen_set_avg_loss = np.mean(unseen_losses)
unseen_set_avg_acc = np.mean(unseen_accuracies)
unseen_set_avg_precision = np.mean(unseen_precisions)
unseen_set_avg_recall = np.mean(unseen_recalls)

logger(f"\nFinal Average F1-Score across all UNSEEN TEST sets: {unseen_set_avg_f1}", file=log_file_path)
logger(f"\nFinal Average Loss across all UNSEEN TEST sets: {unseen_set_avg_loss}", file=log_file_path)
logger(f"\nFinal Average Accuracy across all UNSEEN TEST sets: {unseen_set_avg_acc}", file=log_file_path)
logger(f"\nFinal Average Precision across all UNSEEN TEST sets: {unseen_set_avg_precision}", file=log_file_path)
logger(f"\nFinal Average Recall across all UNSEEN TEST sets: {unseen_set_avg_recall}\n", file=log_file_path)

# Append averages to total lists
all_f1.append(unseen_set_avg_f1)
all_losses.append(unseen_set_avg_loss)
all_accuracies.append(unseen_set_avg_acc)
all_precisions.append(unseen_set_avg_precision)
all_recalls.append(unseen_set_avg_recall)
# Out:
# outer_fold 1
# Train Set Group Distribution:
# 000A    39
# 002B    36
# 103A    33
# 047A    30
# 057A    28
#         ..
# 049A     1
# 026C     1
# 073A     1
# 091A     1
# 100A     1
# Name: cat_id, Length: 87, dtype: int64
# Testing Set Group Distribution:
# 046A    66
# 055A    20
# 059A    18
# 116A    12
# 063A    11
# 072A     9
# 051B     9
# 045A     9
# 013B     8
# 053A     7
# 050A     7
# 117A     7
# 108A     6
# 008A     6
# 025C     6
# 070A     5
# 060A     3
# 058A     3
# 011A     3
# 025B     2
# 069A     2
# 093A     2
# 088A     1
# 024A     1
# 041A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    315
# X    245
# F    184
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    110
# F     73
# M     41
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [002A, 028A, 033A, 000B, 071A, 020A, 000A, 015...
# kitten    [042A, 014B, 110A, 109A, 040A, 047A, 049A, 048...
# senior    [106A, 057A, 090A, 113A, 051A, 097A, 094A, 016...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [070A, 053A, 072A, 013B, 063A, 069A, 060A, 088...
# kitten                             [046A, 045A, 050A, 041A]
# senior    [117A, 051B, 116A, 024A, 059A, 055A, 058A, 108...
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 63, 'kitten': 12, 'senior': 12}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 11, 'kitten': 4, 'senior': 10}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '004A' '005A' '006A' '007A'
#  '009A' '010A' '012A' '014A' '014B' '015A' '016A' '018A' '019A' '019B'
#  '020A' '021A' '022A' '023A' '023B' '025A' '026A' '026B' '026C' '027A'
#  '028A' '029A' '031A' '032A' '033A' '034A' '035A' '036A' '037A' '038A'
#  '039A' '040A' '042A' '043A' '044A' '047A' '048A' '049A' '051A' '052A'
#  '054A' '056A' '057A' '061A' '062A' '064A' '065A' '066A' '067A' '068A'
#  '071A' '073A' '074A' '075A' '076A' '087A' '090A' '091A' '092A' '094A'
#  '095A' '096A' '097A' '097B' '099A' '100A' '101A' '102A' '103A' '104A'
#  '105A' '106A' '109A' '110A' '111A' '113A' '115A']
# Unique Test Group IDs:
# ['008A' '011A' '013B' '024A' '025B' '025C' '041A' '045A' '046A' '050A'
#  '051B' '053A' '055A' '058A' '059A' '060A' '063A' '069A' '070A' '072A'
#  '088A' '093A' '108A' '116A' '117A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'046A'}
# Removed from Training/Validation Set:
# {'110A'}
# Moved to Test Set:
# {'110A'}
# Removed from Test Set
# {'046A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '004A' '005A' '006A' '007A'
#  '009A' '010A' '012A' '014A' '014B' '015A' '016A' '018A' '019A' '019B'
#  '020A' '021A' '022A' '023A' '023B' '025A' '026A' '026B' '026C' '027A'
#  '028A' '029A' '031A' '032A' '033A' '034A' '035A' '036A' '037A' '038A'
#  '039A' '040A' '042A' '043A' '044A' '046A' '047A' '048A' '049A' '051A'
#  '052A' '054A' '056A' '057A' '061A' '062A' '064A' '065A' '066A' '067A'
#  '068A' '071A' '073A' '074A' '075A' '076A' '087A' '090A' '091A' '092A'
#  '094A' '095A' '096A' '097A' '097B' '099A' '100A' '101A' '102A' '103A'
#  '104A' '105A' '106A' '109A' '111A' '113A' '115A']
# AFTER SWAP - Unique Test Group IDs:
# ['008A' '011A' '013B' '024A' '025B' '025C' '041A' '045A' '050A' '051B'
#  '053A' '055A' '058A' '059A' '060A' '063A' '069A' '070A' '072A' '088A'
#  '093A' '108A' '110A' '116A' '117A']
# Length of X_train_val:
# 809
# Length of y_train_val:
# 809
# Length of groups_train_val:
# 809
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     546
# senior    105
# kitten     93
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# kitten    83
# senior    81
# adult     60
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     546
# kitten    158
# senior    105
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# senior    81
# adult     60
# kitten    18
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 546, 1: 158, 2: 105})
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Epoch 1/1500
# 26/26 [==============================] - 1s 6ms/step - loss: 0.7193 - accuracy: 0.7540
# Epoch 2/1500
# 26/26 [==============================] - 0s 6ms/step - loss: 0.2630 - accuracy: 0.9090
# Epoch 3/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.1410 - accuracy: 0.9548
# Epoch 4/1500
# 26/26 [==============================] - 0s 6ms/step - loss: 0.0878 - accuracy: 0.9701
# Epoch 5/1500
# 26/26 [==============================] - 0s 7ms/step - loss: 0.0665 - accuracy: 0.9774
# Epoch 6/1500
# 26/26 [==============================] - 0s 7ms/step - loss: 0.0453 - accuracy: 0.9841
# Epoch 7/1500
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0263 - accuracy: 0.9915
# Epoch 8/1500
# 26/26 [==============================] - 0s 7ms/step - loss: 0.0240 - accuracy: 0.9908
# Epoch 9/1500
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0291 - accuracy: 0.9921
# Epoch 10/1500
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0231 - accuracy: 0.9927
# Epoch 11/1500
# 26/26 [==============================] - 0s 9ms/step - loss: 0.0301 - accuracy: 0.9915
# Epoch 12/1500
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0255 - accuracy: 0.9915
# Epoch 13/1500
# 26/26 [==============================] - 0s 11ms/step - loss: 0.0200 - accuracy: 0.9927
# Epoch 14/1500
# 26/26 [==============================] - 1s 21ms/step - loss: 0.0142 - accuracy: 0.9945
# Epoch 15/1500
# 26/26 [==============================] - 1s 21ms/step - loss: 0.0162 - accuracy: 0.9939
# Epoch 16/1500
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0213 - accuracy: 0.9933
# Epoch 17/1500
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0081 - accuracy: 0.9969
# Epoch 18/1500
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0114 - accuracy: 0.9976
# Epoch 19/1500
# 26/26 [==============================] - 0s 9ms/step - loss: 0.0112 - accuracy: 0.9957
# Epoch 20/1500
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0139 - accuracy: 0.9945
# Epoch 21/1500
# 26/26 [==============================] - 0s 9ms/step - loss: 0.0189 - accuracy: 0.9939
# Epoch 22/1500
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0105 - accuracy: 0.9969
# Epoch 23/1500
# 26/26 [==============================] - 0s 9ms/step - loss: 0.0099 - accuracy: 0.9963
# Epoch 24/1500
# 26/26 [==============================] - 0s 6ms/step - loss: 0.0162 - accuracy: 0.9921
# Epoch 25/1500
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0071 - accuracy: 0.9969
# Epoch 26/1500
# 26/26 [==============================] - 0s 9ms/step - loss: 0.0052 - accuracy: 0.9988
# Epoch 27/1500
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0102 - accuracy: 0.9969
# Epoch 28/1500
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0060 - accuracy: 0.9982
# Epoch 29/1500
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0071 - accuracy: 0.9988
# Epoch 30/1500
# 26/26 [==============================] - 0s 7ms/step - loss: 0.0041 - accuracy: 0.9988
# Epoch 31/1500
# 26/26 [==============================] - 0s 7ms/step - loss: 0.0052 - accuracy: 0.9982
# Epoch 32/1500
# 26/26 [==============================] - 0s 7ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 33/1500
# 26/26 [==============================] - 0s 7ms/step - loss: 0.0052 - accuracy: 0.9982
# Epoch 34/1500
# 26/26 [==============================] - 0s 7ms/step - loss: 0.0070 - accuracy: 0.9982
# Epoch 35/1500
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0041 - accuracy: 0.9982
# Epoch 36/1500
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0077 - accuracy: 0.9969
# Epoch 37/1500
# 26/26 [==============================] - 0s 9ms/step - loss: 0.0058 - accuracy: 0.9969
# Epoch 38/1500
# 26/26 [==============================] - 0s 7ms/step - loss: 0.0055 - accuracy: 0.9976
# Epoch 39/1500
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0102 - accuracy: 0.9969
# Epoch 40/1500
# 26/26 [==============================] - 0s 7ms/step - loss: 0.0153 - accuracy: 0.9976
# Epoch 41/1500
# 26/26 [==============================] - 0s 14ms/step - loss: 0.0036 - accuracy: 0.9994
# Epoch 42/1500
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 43/1500
# 26/26 [==============================] - 0s 11ms/step - loss: 0.0054 - accuracy: 0.9976
# Epoch 44/1500
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0162 - accuracy: 0.9957
# Epoch 45/1500
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0092 - accuracy: 0.9969
# Epoch 46/1500
# 26/26 [==============================] - 0s 7ms/step - loss: 0.0098 - accuracy: 0.9963
# Epoch 47/1500
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0077 - accuracy: 0.9969
# Epoch 48/1500
# 26/26 [==============================] - 0s 9ms/step - loss: 0.0083 - accuracy: 0.9969
# Epoch 49/1500
# 26/26 [==============================] - 0s 9ms/step - loss: 0.0063 - accuracy: 0.9988
# Epoch 50/1500
# 26/26 [==============================] - 0s 9ms/step - loss: 0.0056 - accuracy: 0.9982
# Epoch 51/1500
# 26/26 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 52/1500
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0041 - accuracy: 0.9982
# Epoch 53/1500
# 26/26 [==============================] - 0s 7ms/step - loss: 0.0066 - accuracy: 0.9988
# Epoch 54/1500
# 26/26 [==============================] - 0s 9ms/step - loss: 0.0050 - accuracy: 0.9988
# Epoch 55/1500
# 26/26 [==============================] - 0s 9ms/step - loss: 0.0032 - accuracy: 0.9988
# Epoch 56/1500
# 26/26 [==============================] - 0s 9ms/step - loss: 0.0029 - accuracy: 0.9988
# Epoch 57/1500
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0029 - accuracy: 0.9994
# Epoch 58/1500
# 26/26 [==============================] - 0s 15ms/step - loss: 0.0053 - accuracy: 0.9982
# Epoch 59/1500
# 26/26 [==============================] - 0s 18ms/step - loss: 0.0027 - accuracy: 0.9994
# Epoch 60/1500
# 26/26 [==============================] - 0s 13ms/step - loss: 0.0043 - accuracy: 0.9988
# Epoch 61/1500
# 26/26 [==============================] - 0s 9ms/step - loss: 0.0103 - accuracy: 0.9963
# Epoch 62/1500
# 26/26 [==============================] - 0s 15ms/step - loss: 0.0098 - accuracy: 0.9969
# Epoch 63/1500
# 26/26 [==============================] - 0s 9ms/step - loss: 0.0071 - accuracy: 0.9976
# Epoch 64/1500
# 26/26 [==============================] - 0s 9ms/step - loss: 0.0020 - accuracy: 0.9994
# Epoch 65/1500
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 66/1500
# 26/26 [==============================] - 0s 14ms/step - loss: 0.0017 - accuracy: 0.9994
# Epoch 67/1500
# 26/26 [==============================] - 0s 16ms/step - loss: 0.0023 - accuracy: 0.9994
# Epoch 68/1500
# 26/26 [==============================] - 0s 10ms/step - loss: 0.0019 - accuracy: 0.9994
# Epoch 69/1500
# 26/26 [==============================] - 0s 9ms/step - loss: 7.3011e-04 - accuracy: 1.0000
# Epoch 70/1500
# 26/26 [==============================] - 0s 14ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 71/1500
# 26/26 [==============================] - 0s 9ms/step - loss: 0.0053 - accuracy: 0.9982
# Epoch 72/1500
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0068 - accuracy: 0.9976
# Epoch 73/1500
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0091 - accuracy: 0.9976
# Epoch 74/1500
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0066 - accuracy: 0.9994
# Epoch 75/1500
# 26/26 [==============================] - 0s 7ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 76/1500
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0072 - accuracy: 0.9982
# Epoch 77/1500
# 26/26 [==============================] - 0s 7ms/step - loss: 0.0067 - accuracy: 0.9976
# Epoch 78/1500
# 26/26 [==============================] - 0s 7ms/step - loss: 0.0094 - accuracy: 0.9976
# Epoch 79/1500
# 26/26 [==============================] - 0s 7ms/step - loss: 0.0038 - accuracy: 0.9982
# Epoch 80/1500
# 26/26 [==============================] - 0s 6ms/step - loss: 0.0078 - accuracy: 0.9976
# Epoch 81/1500
# 24/26 [==========================>...] - ETA: 0s - loss: 0.0012 - accuracy: 0.9993  Restoring model weights from the end of the best epoch: 51.
# 26/26 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 0.9994
# Epoch 81: early stopping
# 5/5 [==============================] - 0s 2ms/step - loss: 4.3625 - accuracy: 0.6038
# 5/5 [==============================] - 0s 2ms/step
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Majority Vote Accuracy for cat_id for this fold: 0.64 (16/25)
# Before appending - Cat IDs: 0, Predictions: 0, Actuals: 0, Gender: 0
# After appending - Cat IDs: 159, Predictions: 159, Actuals: 159, Gender: 159
# Final Test Results - Loss: 4.362491607666016, Accuracy: 0.6037735939025879, Precision: 0.7407365115615187, Recall: 0.647119341563786, F1 Score: 0.626989340139629
# Confusion Matrix:
#  [[55  3  2]
#  [ 6 12  0]
#  [52  0 29]]
# outer_fold 2
# Train Set Group Distribution:
# 046A    66
# 000A    39
# 047A    30
# 020A    23
# 000B    20
#         ..
# 115A     1
# 090A     1
# 004A     1
# 026B     1
# 100A     1
# Name: cat_id, Length: 80, dtype: int64
# Testing Set Group Distribution:
# 002B    36
# 103A    33
# 057A    28
# 074A    25
# 019A    17
# 101A    16
# 028A    14
# 051A    12
# 036A    11
# 068A    11
# 016A    11
# 005A    11
# 015A    10
# 010A     8
# 027A     7
# 031A     7
# 044A     5
# 012A     5
# 035A     4
# 052A     4
# 014A     3
# 018A     2
# 054A     2
# 038A     2
# 087A     2
# 066A     2
# 091A     1
# 049A     1
# 048A     1
# 110A     1
# 073A     1
# 076A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    273
# M    202
# F    199
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# M    154
# X     82
# F     58
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [002A, 070A, 033A, 000B, 071A, 020A, 000A, 026...
# kitten    [046A, 042A, 014B, 109A, 040A, 047A, 045A, 111...
# senior    [117A, 106A, 090A, 113A, 051B, 116A, 024A, 097...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [028A, 015A, 038A, 068A, 018A, 002B, 005A, 091...
# kitten                             [110A, 049A, 048A, 044A]
# senior                             [057A, 051A, 016A, 054A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 50, 'kitten': 12, 'senior': 18}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 24, 'kitten': 4, 'senior': 4}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '003A' '004A' '006A' '007A' '008A' '009A'
#  '011A' '013B' '014B' '019B' '020A' '021A' '022A' '023A' '023B' '024A'
#  '025A' '025B' '025C' '026A' '026B' '026C' '029A' '032A' '033A' '034A'
#  '037A' '039A' '040A' '041A' '042A' '043A' '045A' '046A' '047A' '050A'
#  '051B' '053A' '055A' '056A' '058A' '059A' '060A' '061A' '062A' '063A'
#  '064A' '065A' '067A' '069A' '070A' '071A' '072A' '075A' '088A' '090A'
#  '092A' '093A' '094A' '095A' '096A' '097A' '097B' '099A' '100A' '102A'
#  '104A' '105A' '106A' '108A' '109A' '111A' '113A' '115A' '116A' '117A']
# Unique Test Group IDs:
# ['002B' '005A' '010A' '012A' '014A' '015A' '016A' '018A' '019A' '027A'
#  '028A' '031A' '035A' '036A' '038A' '044A' '048A' '049A' '051A' '052A'
#  '054A' '057A' '066A' '068A' '073A' '074A' '076A' '087A' '091A' '101A'
#  '103A' '110A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '003A' '004A' '006A' '007A' '008A' '009A'
#  '011A' '013B' '014B' '019B' '020A' '021A' '022A' '023A' '023B' '024A'
#  '025A' '025B' '025C' '026A' '026B' '026C' '029A' '032A' '033A' '034A'
#  '037A' '039A' '040A' '041A' '042A' '043A' '045A' '046A' '047A' '050A'
#  '051B' '053A' '055A' '056A' '058A' '059A' '060A' '061A' '062A' '063A'
#  '064A' '065A' '067A' '069A' '070A' '071A' '072A' '075A' '088A' '090A'
#  '092A' '093A' '094A' '095A' '096A' '097A' '097B' '099A' '100A' '102A'
#  '104A' '105A' '106A' '108A' '109A' '111A' '113A' '115A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['002B' '005A' '010A' '012A' '014A' '015A' '016A' '018A' '019A' '027A'
#  '028A' '031A' '035A' '036A' '038A' '044A' '048A' '049A' '051A' '052A'
#  '054A' '057A' '066A' '068A' '073A' '074A' '076A' '087A' '091A' '101A'
#  '103A' '110A']
# Length of X_train_val:
# 674
# Length of y_train_val:
# 674
# Length of groups_train_val:
# 674
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     373
# kitten    168
# senior    133
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     233
# senior     53
# kitten      8
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     373
# kitten    168
# senior    133
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     233
# senior     53
# kitten      8
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 373, 1: 168, 2: 133})
# Epoch 1/1500
# 18/18 [==============================] - 1s 7ms/step - loss: 0.9539 - accuracy: 0.6971
# Epoch 2/1500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.3164 - accuracy: 0.8838
# Epoch 3/1500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1900 - accuracy: 0.9321
# Epoch 4/1500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.1470 - accuracy: 0.9553
# Epoch 5/1500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.1053 - accuracy: 0.9625
# Epoch 6/1500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0900 - accuracy: 0.9651
# Epoch 7/1500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0572 - accuracy: 0.9812
# Epoch 8/1500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0509 - accuracy: 0.9848
# Epoch 9/1500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0487 - accuracy: 0.9857
# Epoch 10/1500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0328 - accuracy: 0.9884
# Epoch 11/1500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0232 - accuracy: 0.9920
# Epoch 12/1500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0148 - accuracy: 0.9964
# Epoch 13/1500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0161 - accuracy: 0.9955
# Epoch 14/1500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0129 - accuracy: 0.9973
# Epoch 15/1500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0150 - accuracy: 0.9964
# Epoch 16/1500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0112 - accuracy: 0.9982
# Epoch 17/1500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0138 - accuracy: 0.9946
# Epoch 18/1500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0197 - accuracy: 0.9920
# Epoch 19/1500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0132 - accuracy: 0.9955
# Epoch 20/1500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0072 - accuracy: 0.9982
# Epoch 21/1500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0060 - accuracy: 0.9991
# Epoch 22/1500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0069 - accuracy: 0.9964
# Epoch 23/1500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0106 - accuracy: 0.9937
# Epoch 24/1500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0091 - accuracy: 0.9964
# Epoch 25/1500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0063 - accuracy: 0.9991
# Epoch 26/1500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 27/1500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0075 - accuracy: 0.9982
# Epoch 28/1500
# 18/18 [==============================] - 0s 5ms/step - loss: 0.0078 - accuracy: 0.9973
# Epoch 29/1500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0046 - accuracy: 0.9991
# Epoch 30/1500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0098 - accuracy: 0.9973
# Epoch 31/1500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0060 - accuracy: 0.9991
# Epoch 32/1500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0044 - accuracy: 1.0000
# Epoch 33/1500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0084 - accuracy: 0.9982
# Epoch 34/1500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0063 - accuracy: 0.9982
# Epoch 35/1500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0078 - accuracy: 0.9982
# Epoch 36/1500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0049 - accuracy: 0.9991
# Epoch 37/1500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0037 - accuracy: 0.9991
# Epoch 38/1500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0024 - accuracy: 0.9991
# Epoch 39/1500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0040 - accuracy: 1.0000
# Epoch 40/1500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 41/1500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0066 - accuracy: 0.9982
# Epoch 42/1500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 43/1500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0031 - accuracy: 0.9991
# Epoch 44/1500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0029 - accuracy: 0.9991
# Epoch 45/1500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 46/1500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0045 - accuracy: 0.9982
# Epoch 47/1500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0068 - accuracy: 0.9973
# Epoch 48/1500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0055 - accuracy: 0.9982
# Epoch 49/1500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0040 - accuracy: 0.9991
# Epoch 50/1500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 51/1500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 52/1500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0098 - accuracy: 0.9964
# Epoch 53/1500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0114 - accuracy: 0.9964
# Epoch 54/1500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0164 - accuracy: 0.9955
# Epoch 55/1500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0100 - accuracy: 0.9973
# Epoch 56/1500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0036 - accuracy: 0.9991
# Epoch 57/1500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0027 - accuracy: 0.9991
# Epoch 58/1500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0026 - accuracy: 0.9991
# Epoch 59/1500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0079 - accuracy: 0.9973
# Epoch 60/1500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0032 - accuracy: 0.9991
# Epoch 61/1500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0066 - accuracy: 0.9982
# Epoch 62/1500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0038 - accuracy: 0.9991
# Epoch 63/1500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 64/1500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 65/1500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0040 - accuracy: 0.9991
# Epoch 66/1500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0017 - accuracy: 0.9991
# Epoch 67/1500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0055 - accuracy: 0.9973
# Epoch 68/1500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0061 - accuracy: 0.9982
# Epoch 69/1500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0028 - accuracy: 0.9991
# Epoch 70/1500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0029 - accuracy: 0.9991
# Epoch 71/1500
# 18/18 [==============================] - 0s 6ms/step - loss: 0.0043 - accuracy: 0.9991
# Epoch 72/1500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0105 - accuracy: 0.9973
# Epoch 73/1500
# 18/18 [==============================] - 0s 8ms/step - loss: 0.0045 - accuracy: 0.9982
# Epoch 74/1500
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0095 - accuracy: 0.9955
# Epoch 75/1500
# 17/18 [===========================>..] - ETA: 0s - loss: 0.0046 - accuracy: 0.9991    Restoring model weights from the end of the best epoch: 45.
# 18/18 [==============================] - 0s 7ms/step - loss: 0.0046 - accuracy: 0.9991
# Epoch 75: early stopping
# 10/10 [==============================] - 0s 2ms/step - loss: 2.3336 - accuracy: 0.7177
# 10/10 [==============================] - 0s 1ms/step
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Majority Vote Accuracy for cat_id for this fold: 0.84 (27/32)
# Before appending - Cat IDs: 159, Predictions: 159, Actuals: 159, Gender: 159
# After appending - Cat IDs: 453, Predictions: 453, Actuals: 453, Gender: 453
# Final Test Results - Loss: 2.333569288253784, Accuracy: 0.7176870703697205, Precision: 0.4959098228663446, Recall: 0.6612512484141765, F1 Score: 0.5319353083826954
# Confusion Matrix:
#  [[188  15  30]
#  [  1   7   0]
#  [ 36   1  16]]
# outer_fold 3
# Train Set Group Distribution:
# 046A    66
# 000A    39
# 002B    36
# 103A    33
# 047A    30
#         ..
# 049A     1
# 092A     1
# 048A     1
# 073A     1
# 100A     1
# Name: cat_id, Length: 84, dtype: int64
# Testing Set Group Distribution:
# 000B    20
# 106A    15
# 042A    14
# 097B    14
# 002A    13
# 111A    13
# 025A    11
# 071A    10
# 065A     9
# 033A     9
# 095A     8
# 094A     8
# 099A     7
# 037A     6
# 023A     6
# 075A     5
# 062A     5
# 023B     5
# 003A     4
# 105A     4
# 006A     3
# 056A     3
# 102A     2
# 061A     2
# 043A     1
# 090A     1
# 026C     1
# 019B     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    288
# M    285
# F    195
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# M    71
# X    67
# F    62
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [028A, 070A, 020A, 000A, 015A, 026A, 053A, 038...
# kitten    [046A, 014B, 110A, 109A, 040A, 047A, 049A, 045...
# senior    [117A, 057A, 113A, 051B, 116A, 051A, 024A, 097...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [002A, 033A, 000B, 071A, 065A, 023B, 026C, 105...
# kitten                                   [042A, 111A, 043A]
# senior                       [106A, 090A, 094A, 061A, 056A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 54, 'kitten': 13, 'senior': 17}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 20, 'kitten': 3, 'senior': 5}
# Unique Training/Validation Group IDs:
# ['000A' '001A' '002B' '004A' '005A' '007A' '008A' '009A' '010A' '011A'
#  '012A' '013B' '014A' '014B' '015A' '016A' '018A' '019A' '020A' '021A'
#  '022A' '024A' '025B' '025C' '026A' '026B' '027A' '028A' '029A' '031A'
#  '032A' '034A' '035A' '036A' '038A' '039A' '040A' '041A' '044A' '045A'
#  '046A' '047A' '048A' '049A' '050A' '051A' '051B' '052A' '053A' '054A'
#  '055A' '057A' '058A' '059A' '060A' '063A' '064A' '066A' '067A' '068A'
#  '069A' '070A' '072A' '073A' '074A' '076A' '087A' '088A' '091A' '092A'
#  '093A' '096A' '097A' '100A' '101A' '103A' '104A' '108A' '109A' '110A'
#  '113A' '115A' '116A' '117A']
# Unique Test Group IDs:
# ['000B' '002A' '003A' '006A' '019B' '023A' '023B' '025A' '026C' '033A'
#  '037A' '042A' '043A' '056A' '061A' '062A' '065A' '071A' '075A' '090A'
#  '094A' '095A' '097B' '099A' '102A' '105A' '106A' '111A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '001A' '002B' '004A' '005A' '007A' '008A' '009A' '010A' '011A'
#  '012A' '013B' '014A' '014B' '015A' '016A' '018A' '019A' '020A' '021A'
#  '022A' '024A' '025B' '025C' '026A' '026B' '027A' '028A' '029A' '031A'
#  '032A' '034A' '035A' '036A' '038A' '039A' '040A' '041A' '044A' '045A'
#  '046A' '047A' '048A' '049A' '050A' '051A' '051B' '052A' '053A' '054A'
#  '055A' '057A' '058A' '059A' '060A' '063A' '064A' '066A' '067A' '068A'
#  '069A' '070A' '072A' '073A' '074A' '076A' '087A' '088A' '091A' '092A'
#  '093A' '096A' '097A' '100A' '101A' '103A' '104A' '108A' '109A' '110A'
#  '113A' '115A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['000B' '002A' '003A' '006A' '019B' '023A' '023B' '025A' '026C' '033A'
#  '037A' '042A' '043A' '056A' '061A' '062A' '065A' '071A' '075A' '090A'
#  '094A' '095A' '097B' '099A' '102A' '105A' '106A' '111A']
# Length of X_train_val:
# 768
# Length of y_train_val:
# 768
# Length of groups_train_val:
# 768
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     463
# senior    157
# kitten    148
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     143
# senior     29
# kitten     28
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     463
# senior    157
# kitten    148
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     143
# senior     29
# kitten     28
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 463, 2: 157, 1: 148})
# Epoch 1/1500
# 22/22 [==============================] - 1s 5ms/step - loss: 0.9287 - accuracy: 0.6847
# Epoch 2/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.3771 - accuracy: 0.8488
# Epoch 3/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.2282 - accuracy: 0.9050
# Epoch 4/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.1590 - accuracy: 0.9482
# Epoch 5/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.1123 - accuracy: 0.9604
# Epoch 6/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0802 - accuracy: 0.9748
# Epoch 7/1500
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0775 - accuracy: 0.9762
# Epoch 8/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0503 - accuracy: 0.9813
# Epoch 9/1500
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0497 - accuracy: 0.9806
# Epoch 10/1500
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0387 - accuracy: 0.9863
# Epoch 11/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0357 - accuracy: 0.9892
# Epoch 12/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0430 - accuracy: 0.9856
# Epoch 13/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0285 - accuracy: 0.9899
# Epoch 14/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0152 - accuracy: 0.9964
# Epoch 15/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0249 - accuracy: 0.9906
# Epoch 16/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0239 - accuracy: 0.9928
# Epoch 17/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0304 - accuracy: 0.9885
# Epoch 18/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0185 - accuracy: 0.9935
# Epoch 19/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0144 - accuracy: 0.9957
# Epoch 20/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0087 - accuracy: 0.9971
# Epoch 21/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0081 - accuracy: 0.9978
# Epoch 22/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0074 - accuracy: 0.9978
# Epoch 23/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0049 - accuracy: 0.9986
# Epoch 24/1500
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0076 - accuracy: 0.9957
# Epoch 25/1500
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0071 - accuracy: 0.9978
# Epoch 26/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0105 - accuracy: 0.9964
# Epoch 27/1500
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0076 - accuracy: 0.9978
# Epoch 28/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0080 - accuracy: 0.9964
# Epoch 29/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0060 - accuracy: 0.9978
# Epoch 30/1500
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0042 - accuracy: 0.9993
# Epoch 31/1500
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0174 - accuracy: 0.9950
# Epoch 32/1500
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0056 - accuracy: 0.9978
# Epoch 33/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0085 - accuracy: 0.9978
# Epoch 34/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0041 - accuracy: 0.9986
# Epoch 35/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0058 - accuracy: 0.9986
# Epoch 36/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0050 - accuracy: 0.9993
# Epoch 37/1500
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0053 - accuracy: 0.9971
# Epoch 38/1500
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0066 - accuracy: 0.9978
# Epoch 39/1500
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0089 - accuracy: 0.9971
# Epoch 40/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0074 - accuracy: 0.9971
# Epoch 41/1500
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0060 - accuracy: 0.9986
# Epoch 42/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0088 - accuracy: 0.9971
# Epoch 43/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0092 - accuracy: 0.9950
# Epoch 44/1500
# 22/22 [==============================] - 0s 10ms/step - loss: 0.0152 - accuracy: 0.9950
# Epoch 45/1500
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0149 - accuracy: 0.9957
# Epoch 46/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0157 - accuracy: 0.9935
# Epoch 47/1500
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0109 - accuracy: 0.9935
# Epoch 48/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0157 - accuracy: 0.9950
# Epoch 49/1500
# 22/22 [==============================] - 0s 11ms/step - loss: 0.0155 - accuracy: 0.9950
# Epoch 50/1500
# 22/22 [==============================] - 0s 8ms/step - loss: 0.0165 - accuracy: 0.9928
# Epoch 51/1500
# 22/22 [==============================] - 0s 9ms/step - loss: 0.0099 - accuracy: 0.9971
# Epoch 52/1500
# 22/22 [==============================] - 0s 9ms/step - loss: 0.0079 - accuracy: 0.9986
# Epoch 53/1500
# 22/22 [==============================] - ETA: 0s - loss: 0.0202 - accuracy: 0.9928Restoring model weights from the end of the best epoch: 23.
# 22/22 [==============================] - 0s 8ms/step - loss: 0.0202 - accuracy: 0.9928
# Epoch 53: early stopping
# 7/7 [==============================] - 0s 2ms/step - loss: 2.0535 - accuracy: 0.7550
# 7/7 [==============================] - 0s 2ms/step
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Majority Vote Accuracy for cat_id for this fold: 0.82 (23/28)
# Before appending - Cat IDs: 453, Predictions: 453, Actuals: 453, Gender: 453
# After appending - Cat IDs: 653, Predictions: 653, Actuals: 653, Gender: 653
# Final Test Results - Loss: 2.05350923538208, Accuracy: 0.7549999952316284, Precision: 0.6350956219377272, Recall: 0.6359100669445498, F1 Score: 0.6287533096726944
# Confusion Matrix:
#  [[121  11  11]
#  [  6  22   0]
#  [ 21   0   8]]
# outer_fold 4
# Train Set Group Distribution:
# 046A    66
# 002B    36
# 103A    33
# 057A    28
# 074A    25
#         ..
# 110A     1
# 048A     1
# 090A     1
# 049A     1
# 076A     1
# Name: cat_id, Length: 85, dtype: int64
# Testing Set Group Distribution:
# 000A    39
# 047A    30
# 020A    23
# 067A    20
# 029A    17
# 097A    16
# 001A    15
# 039A    12
# 014B    10
# 040A    10
# 022A     9
# 109A     6
# 021A     6
# 007A     6
# 034A     5
# 009A     4
# 104A     4
# 026A     4
# 113A     3
# 064A     3
# 032A     2
# 092A     1
# 096A     1
# 115A     1
# 004A     1
# 026B     1
# 100A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    266
# X    259
# F    193
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    96
# M    90
# F    64
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [002A, 028A, 070A, 033A, 000B, 071A, 015A, 065...
# kitten    [046A, 042A, 110A, 049A, 045A, 048A, 111A, 044...
# senior    [117A, 106A, 057A, 090A, 051B, 116A, 051A, 024...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [020A, 000A, 026A, 007A, 021A, 001A, 034A, 009...
# kitten                       [014B, 109A, 040A, 047A, 115A]
# senior                                   [113A, 097A, 104A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 55, 'kitten': 11, 'senior': 19}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 19, 'kitten': 5, 'senior': 3}
# Unique Training/Validation Group IDs:
# ['000B' '002A' '002B' '003A' '005A' '006A' '008A' '010A' '011A' '012A'
#  '013B' '014A' '015A' '016A' '018A' '019A' '019B' '023A' '023B' '024A'
#  '025A' '025B' '025C' '026C' '027A' '028A' '031A' '033A' '035A' '036A'
#  '037A' '038A' '041A' '042A' '043A' '044A' '045A' '046A' '048A' '049A'
#  '050A' '051A' '051B' '052A' '053A' '054A' '055A' '056A' '057A' '058A'
#  '059A' '060A' '061A' '062A' '063A' '065A' '066A' '068A' '069A' '070A'
#  '071A' '072A' '073A' '074A' '075A' '076A' '087A' '088A' '090A' '091A'
#  '093A' '094A' '095A' '097B' '099A' '101A' '102A' '103A' '105A' '106A'
#  '108A' '110A' '111A' '116A' '117A']
# Unique Test Group IDs:
# ['000A' '001A' '004A' '007A' '009A' '014B' '020A' '021A' '022A' '026A'
#  '026B' '029A' '032A' '034A' '039A' '040A' '047A' '064A' '067A' '092A'
#  '096A' '097A' '100A' '104A' '109A' '113A' '115A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'000A'}
# Removed from Training/Validation Set:
# {'025C'}
# Moved to Test Set:
# {'025C'}
# Removed from Test Set
# {'000A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '002A' '002B' '003A' '005A' '006A' '008A' '010A' '011A'
#  '012A' '013B' '014A' '015A' '016A' '018A' '019A' '019B' '023A' '023B'
#  '024A' '025A' '025B' '026C' '027A' '028A' '031A' '033A' '035A' '036A'
#  '037A' '038A' '041A' '042A' '043A' '044A' '045A' '046A' '048A' '049A'
#  '050A' '051A' '051B' '052A' '053A' '054A' '055A' '056A' '057A' '058A'
#  '059A' '060A' '061A' '062A' '063A' '065A' '066A' '068A' '069A' '070A'
#  '071A' '072A' '073A' '074A' '075A' '076A' '087A' '088A' '090A' '091A'
#  '093A' '094A' '095A' '097B' '099A' '101A' '102A' '103A' '105A' '106A'
#  '108A' '110A' '111A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['001A' '004A' '007A' '009A' '014B' '020A' '021A' '022A' '025C' '026A'
#  '026B' '029A' '032A' '034A' '039A' '040A' '047A' '064A' '067A' '092A'
#  '096A' '097A' '100A' '104A' '109A' '113A' '115A']
# Length of X_train_val:
# 751
# Length of y_train_val:
# 751
# Length of groups_train_val:
# 751
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     436
# senior    163
# kitten    119
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     170
# kitten     57
# senior     23
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     469
# senior    163
# kitten    119
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     137
# kitten     57
# senior     23
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 469, 2: 163, 1: 119})
# Epoch 1/1500
# 22/22 [==============================] - 1s 7ms/step - loss: 0.7386 - accuracy: 0.7271
# Epoch 2/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.2658 - accuracy: 0.8962
# Epoch 3/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.1698 - accuracy: 0.9396
# Epoch 4/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.1074 - accuracy: 0.9574
# Epoch 5/1500
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0870 - accuracy: 0.9638
# Epoch 6/1500
# 22/22 [==============================] - 0s 9ms/step - loss: 0.0667 - accuracy: 0.9773
# Epoch 7/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0474 - accuracy: 0.9829
# Epoch 8/1500
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0444 - accuracy: 0.9844
# Epoch 9/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0272 - accuracy: 0.9943
# Epoch 10/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0456 - accuracy: 0.9844
# Epoch 11/1500
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0408 - accuracy: 0.9851
# Epoch 12/1500
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0313 - accuracy: 0.9893
# Epoch 13/1500
# 22/22 [==============================] - 0s 9ms/step - loss: 0.0210 - accuracy: 0.9950
# Epoch 14/1500
# 22/22 [==============================] - 0s 8ms/step - loss: 0.0113 - accuracy: 0.9972
# Epoch 15/1500
# 22/22 [==============================] - 0s 8ms/step - loss: 0.0138 - accuracy: 0.9964
# Epoch 16/1500
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0101 - accuracy: 0.9972
# Epoch 17/1500
# 22/22 [==============================] - 0s 8ms/step - loss: 0.0067 - accuracy: 0.9993
# Epoch 18/1500
# 22/22 [==============================] - 0s 8ms/step - loss: 0.0151 - accuracy: 0.9957
# Epoch 19/1500
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0078 - accuracy: 0.9979
# Epoch 20/1500
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0089 - accuracy: 0.9972
# Epoch 21/1500
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0126 - accuracy: 0.9972
# Epoch 22/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0116 - accuracy: 0.9950
# Epoch 23/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0248 - accuracy: 0.9936
# Epoch 24/1500
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0091 - accuracy: 0.9986
# Epoch 25/1500
# 22/22 [==============================] - 0s 10ms/step - loss: 0.0091 - accuracy: 0.9979
# Epoch 26/1500
# 22/22 [==============================] - 0s 8ms/step - loss: 0.0102 - accuracy: 0.9964
# Epoch 27/1500
# 22/22 [==============================] - 0s 9ms/step - loss: 0.0068 - accuracy: 0.9979
# Epoch 28/1500
# 22/22 [==============================] - 0s 8ms/step - loss: 0.0237 - accuracy: 0.9936
# Epoch 29/1500
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0178 - accuracy: 0.9950
# Epoch 30/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0051 - accuracy: 0.9986
# Epoch 31/1500
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0054 - accuracy: 0.9979
# Epoch 32/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0054 - accuracy: 0.9979
# Epoch 33/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0038 - accuracy: 0.9993
# Epoch 34/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0069 - accuracy: 0.9979
# Epoch 35/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0051 - accuracy: 0.9986
# Epoch 36/1500
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0042 - accuracy: 0.9986
# Epoch 37/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 38/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0078 - accuracy: 0.9964
# Epoch 39/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0086 - accuracy: 0.9972
# Epoch 40/1500
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0053 - accuracy: 0.9986
# Epoch 41/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0067 - accuracy: 0.9972
# Epoch 42/1500
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0043 - accuracy: 0.9986
# Epoch 43/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0079 - accuracy: 0.9950
# Epoch 44/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0043 - accuracy: 0.9993
# Epoch 45/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 46/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0033 - accuracy: 0.9986
# Epoch 47/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0083 - accuracy: 0.9964
# Epoch 48/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 49/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0018 - accuracy: 0.9993
# Epoch 50/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0049 - accuracy: 0.9986
# Epoch 51/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0057 - accuracy: 0.9972
# Epoch 52/1500
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0051 - accuracy: 0.9979
# Epoch 53/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0030 - accuracy: 0.9986
# Epoch 54/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0026 - accuracy: 0.9993
# Epoch 55/1500
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0035 - accuracy: 0.9993
# Epoch 56/1500
# 22/22 [==============================] - 0s 7ms/step - loss: 9.2248e-04 - accuracy: 1.0000
# Epoch 57/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0055 - accuracy: 0.9986
# Epoch 58/1500
# 22/22 [==============================] - 0s 9ms/step - loss: 0.0026 - accuracy: 0.9993
# Epoch 59/1500
# 22/22 [==============================] - 0s 13ms/step - loss: 0.0073 - accuracy: 0.9979
# Epoch 60/1500
# 22/22 [==============================] - 0s 14ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 61/1500
# 22/22 [==============================] - 0s 10ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 62/1500
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 63/1500
# 22/22 [==============================] - 0s 9ms/step - loss: 0.0115 - accuracy: 0.9979
# Epoch 64/1500
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0072 - accuracy: 0.9972
# Epoch 65/1500
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0081 - accuracy: 0.9979
# Epoch 66/1500
# 22/22 [==============================] - 0s 8ms/step - loss: 0.0089 - accuracy: 0.9957
# Epoch 67/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0130 - accuracy: 0.9943
# Epoch 68/1500
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0115 - accuracy: 0.9957
# Epoch 69/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0094 - accuracy: 0.9964
# Epoch 70/1500
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0188 - accuracy: 0.9979
# Epoch 71/1500
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0018 - accuracy: 0.9993
# Epoch 72/1500
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0036 - accuracy: 0.9979
# Epoch 73/1500
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0039 - accuracy: 0.9986
# Epoch 74/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 75/1500
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0026 - accuracy: 0.9993
# Epoch 76/1500
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0166 - accuracy: 0.9972
# Epoch 77/1500
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0044 - accuracy: 0.9986
# Epoch 78/1500
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0021 - accuracy: 0.9993
# Epoch 79/1500
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0029 - accuracy: 0.9979
# Epoch 80/1500
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0029 - accuracy: 0.9993
# Epoch 81/1500
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0031 - accuracy: 0.9993
# Epoch 82/1500
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0020 - accuracy: 0.9993
# Epoch 83/1500
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0025 - accuracy: 0.9993
# Epoch 84/1500
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 85/1500
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0035 - accuracy: 0.9986
# Epoch 86/1500
# 15/22 [===================>..........] - ETA: 0s - loss: 0.0017 - accuracy: 1.0000  Restoring model weights from the end of the best epoch: 56.
# 22/22 [==============================] - 0s 8ms/step - loss: 0.0022 - accuracy: 0.9993
# Epoch 86: early stopping
# 7/7 [==============================] - 0s 3ms/step - loss: 5.4516 - accuracy: 0.6866
# 7/7 [==============================] - 0s 2ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.78 (21/27)
# Before appending - Cat IDs: 653, Predictions: 653, Actuals: 653, Gender: 653
# After appending - Cat IDs: 870, Predictions: 870, Actuals: 870, Gender: 870
# Final Test Results - Loss: 5.4516472816467285, Accuracy: 0.6866359710693359, Precision: 0.6538273056944036, Recall: 0.5136455334888581, F1 Score: 0.5310480843458857
# Confusion Matrix:
#  [[125   3   9]
#  [ 39  16   2]
#  [ 15   0   8]]
#
# Final Average F1-Score across all UNSEEN TEST sets: 0.5796815106352261
#
# Final Average Loss across all UNSEEN TEST sets: 3.550304353237152
#
# Final Average Accuracy across all UNSEEN TEST sets: 0.6907741576433182
#
# Final Average Precision across all UNSEEN TEST sets: 0.6313923155149985
#
# Final Average Recall across all UNSEEN TEST sets: 0.6144815476028427

# %%
seed_1_folds_values = (unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1)

# Plotting all fold metrics
seed_1_folds_plot = plot_all_metrics(unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1, "Folds", "Fold Number")

# %% [markdown]
# ## Majority Voting on Total Entries per cat_id

# %%
# Debugging print statements
print(f'Checking - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
# Out:
# Checking - Cat IDs: 870, Predictions: 870, Actuals: 870, Gender: 870

# %%
# Create results df
full_results = pd.DataFrame({
    'cat_id': all_cat_ids,
    'predicted_age_group': all_predicted_age_groups,
    'actual_age_group': all_actual_age_groups,
    'all_gender': all_gender
})

# create a correct majority prediction column
full_results['correct'] = full_results['predicted_age_group'] == full_results['actual_age_group']

# %%
# Group by cat_id and aggregate predicted age groups
majority_votes = full_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first()

# Calculate the accuracy of majority voting
correct_predictions = (majority_votes == actual_groups).sum()
total_cats = len(actual_groups)
majority_vote_accuracy = correct_predictions / total_cats

logger(f"Overall Majority Vote Accuracy for cat_id: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

# store for final evaluation 
all_majority_vote_accuracies.append(majority_vote_accuracy)
# Out:
# Overall Majority Vote Accuracy for cat_id: 0.77 (85/110)

# %%
# Detailed df with predictions, actual labels, and comparison including majority vote
detailed_results = full_results.groupby('cat_id').apply(
    lambda x: pd.Series({
        'Predictions': list(x['predicted_age_group']),
        'Majority Vote': x['predicted_age_group'].mode()[0],
        'Actual Age Group': x['actual_age_group'].iloc[0],
        'Correct Majority Vote': x['predicted_age_group'].mode()[0] == x['actual_age_group'].iloc[0]
    })
).reset_index()

# Convert to DataFrame for better formatting and display
detailed_results = pd.DataFrame(detailed_results)

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 10)
pd.set_option('display.width', 1000)

sorted_detailed_results = detailed_results.sort_values(by='Correct Majority Vote', ascending=False)

# Display the sorted DataFrame
sorted_detailed_results
# Out:
#     cat_id                                        Predictions Majority Vote Actual Age Group  Correct Majority Vote
# 0     000B  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 59    053A  [adult, adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 68    062A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 96    101A  [adult, senior, adult, adult, adult, senior, s...         adult            adult                   True
# 66    060A                              [adult, adult, adult]         adult            adult                   True
# 65    059A  [senior, senior, senior, adult, adult, senior,...        senior           senior                   True
# 97    102A                                     [adult, adult]         adult            adult                   True
# 98    103A  [adult, adult, adult, adult, adult, senior, ad...         adult            adult                   True
# 100   105A                      [adult, adult, adult, kitten]         adult            adult                   True
# 60    054A                                   [senior, senior]        senior           senior                   True
# 58    052A                       [adult, adult, adult, adult]         adult            adult                   True
# 70    064A                              [adult, adult, adult]         adult            adult                   True
# 1     001A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 54    049A                                           [kitten]        kitten           kitten                   True
# 53    048A                                           [kitten]        kitten           kitten                   True
# 51    045A  [kitten, adult, kitten, kitten, kitten, adult,...        kitten           kitten                   True
# 50    044A            [kitten, kitten, adult, kitten, kitten]        kitten           kitten                   True
# 49    043A                                           [kitten]        kitten           kitten                   True
# 48    042A  [kitten, kitten, kitten, adult, kitten, kitten...        kitten           kitten                   True
# 47    041A                                           [kitten]        kitten           kitten                   True
# 69    063A  [adult, adult, adult, kitten, adult, adult, ad...         adult            adult                   True
# 71    065A  [adult, adult, adult, kitten, kitten, adult, a...         adult            adult                   True
# 104   110A                                   [kitten, kitten]        kitten           kitten                   True
# 95    100A                                            [adult]         adult            adult                   True
# 90    095A  [adult, adult, adult, senior, adult, adult, ad...         adult            adult                   True
# 93    097B  [senior, adult, kitten, adult, adult, adult, a...         adult            adult                   True
# 94    099A  [adult, adult, adult, kitten, adult, adult, ad...         adult            adult                   True
# 87    092A                                            [adult]         adult            adult                   True
# 86    091A                                            [adult]         adult            adult                   True
# 85    090A                                           [senior]        senior           senior                   True
# 84    088A                                            [adult]         adult            adult                   True
# 83    087A                                     [adult, adult]         adult            adult                   True
# 81    075A               [adult, senior, adult, adult, adult]         adult            adult                   True
# 72    066A                                    [adult, kitten]         adult            adult                   True
# 80    074A  [kitten, adult, adult, adult, kitten, adult, a...         adult            adult                   True
# 79    073A                                            [adult]         adult            adult                   True
# 78    072A  [adult, adult, adult, adult, adult, kitten, ad...         adult            adult                   True
# 77    071A  [adult, senior, adult, adult, adult, senior, s...         adult            adult                   True
# 76    070A               [adult, senior, adult, adult, adult]         adult            adult                   True
# 75    069A                                     [adult, adult]         adult            adult                   True
# 74    068A  [adult, adult, adult, senior, senior, adult, a...         adult            adult                   True
# 73    067A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 45    039A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 46    040A  [kitten, kitten, kitten, kitten, kitten, kitte...        kitten           kitten                   True
# 43    037A       [kitten, adult, senior, adult, adult, adult]         adult            adult                   True
# 13    012A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 23    021A         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 22    020A  [adult, adult, adult, adult, adult, adult, kit...         adult            adult                   True
# 21    019B                                            [adult]         adult            adult                   True
# 20    019A  [adult, adult, kitten, adult, adult, senior, a...         adult            adult                   True
# 19    018A                                     [adult, adult]         adult            adult                   True
# 17    015A  [adult, adult, adult, adult, adult, adult, sen...         adult            adult                   True
# 107   115A                                           [kitten]        kitten           kitten                   True
# 15    014A                             [kitten, adult, adult]         adult            adult                   True
# 14    013B  [adult, adult, adult, adult, adult, senior, ad...         adult            adult                   True
# 11    010A  [adult, adult, adult, adult, adult, adult, sen...         adult            adult                   True
# 25    023A        [adult, adult, senior, adult, adult, adult]         adult            adult                   True
# 10    009A                     [senior, adult, senior, adult]         adult            adult                   True
# 9     008A         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 8     007A         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 7     006A                              [adult, adult, adult]         adult            adult                   True
# 6     005A  [adult, adult, adult, senior, senior, adult, s...         adult            adult                   True
# 5     004A                                            [adult]         adult            adult                   True
# 4     003A                     [kitten, kitten, adult, adult]         adult            adult                   True
# 3     002B  [adult, adult, adult, senior, senior, adult, a...         adult            adult                   True
# 2     002A  [adult, adult, adult, adult, adult, adult, sen...         adult            adult                   True
# 42    036A  [senior, senior, adult, adult, adult, adult, a...         adult            adult                   True
# 24    022A  [adult, adult, kitten, adult, adult, adult, ad...         adult            adult                   True
# 26    023B              [adult, adult, senior, senior, adult]         adult            adult                   True
# 27    024A                                           [senior]        senior           senior                   True
# 41    035A                       [adult, adult, adult, adult]         adult            adult                   True
# 40    034A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 39    033A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 38    032A                                     [adult, adult]         adult            adult                   True
# 37    031A  [adult, adult, adult, adult, kitten, adult, se...         adult            adult                   True
# 36    029A  [senior, adult, adult, adult, senior, adult, a...         adult            adult                   True
# 35    028A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 34    027A  [adult, kitten, adult, adult, adult, adult, ad...         adult            adult                   True
# 91    096A                                            [adult]         adult            adult                   True
# 105   111A  [kitten, adult, kitten, kitten, kitten, kitten...        kitten           kitten                   True
# 32    026B                                            [adult]         adult            adult                   True
# 31    026A                       [adult, adult, adult, adult]         adult            adult                   True
# 30    025C  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 29    025B                                     [adult, adult]         adult            adult                   True
# 28    025A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 102   108A         [adult, adult, adult, adult, adult, adult]         adult           senior                  False
# 101   106A  [adult, adult, adult, adult, adult, adult, sen...         adult           senior                  False
# 103   109A        [adult, adult, adult, adult, kitten, adult]         adult           kitten                  False
# 106   113A                             [adult, senior, adult]         adult           senior                  False
# 99    104A                      [senior, adult, adult, adult]         adult           senior                  False
# 92    097A  [adult, adult, senior, adult, senior, adult, a...         adult           senior                  False
# 108   116A  [senior, adult, adult, senior, adult, senior, ...         adult           senior                  False
# 55    050A  [kitten, kitten, adult, adult, adult, kitten, ...         adult           kitten                  False
# 89    094A  [adult, senior, senior, adult, adult, senior, ...         adult           senior                  False
# 56    051A  [adult, adult, adult, senior, adult, adult, ad...         adult           senior                  False
# 12    011A                             [senior, adult, adult]         adult           senior                  False
# 16    014B  [adult, adult, senior, senior, adult, kitten, ...         adult           kitten                  False
# 18    016A  [adult, adult, adult, adult, adult, adult, adu...         adult           senior                  False
# 33    026C                                           [kitten]        kitten            adult                  False
# 44    038A                                   [kitten, kitten]        kitten            adult                  False
# 52    047A  [adult, adult, adult, kitten, adult, adult, ad...         adult           kitten                  False
# 57    051B  [adult, adult, adult, adult, adult, adult, sen...         adult           senior                  False
# 88    093A                                     [adult, adult]         adult           senior                  False
# 61    055A  [senior, adult, senior, senior, adult, senior,...         adult           senior                  False
# 62    056A                              [adult, adult, adult]         adult           senior                  False
# 63    057A  [adult, adult, senior, adult, adult, adult, se...         adult           senior                  False
# 64    058A                              [adult, adult, adult]         adult           senior                  False
# 67    061A                                     [adult, adult]         adult           senior                  False
# 82    076A                                           [kitten]        kitten            adult                  False
# 109   117A  [senior, senior, adult, senior, adult, adult, ...         adult           senior                  False

# %%
# Create df for majority votes
majority_df = majority_votes.reset_index()
majority_df.columns = ['cat_id', 'Majority_Vote']

# Get actual groups for each cat_id
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first().reset_index()

# Merge majority votes with actual groups
majority_with_actual = pd.merge(majority_df, actual_groups, on='cat_id')

# Add a column to check if the majority vote was correct
majority_with_actual['Majority_Correct'] = majority_with_actual['Majority_Vote'] == majority_with_actual['actual_age_group']

# Count correct majority votes per class
correct_majority_votes_per_class = majority_with_actual.groupby('actual_age_group')['Majority_Correct'].sum()

print("Correct Majority Votes per Class:")
print(correct_majority_votes_per_class)
# Out:
# Correct Majority Votes per Class:
# actual_age_group
# adult     70
# kitten    11
# senior     4
# Name: Majority_Correct, dtype: int64

# %%
# Calculate the total count and the number of correct predictions for each class
class_stats = majority_with_actual.groupby('actual_age_group').agg(
    total_count=('Majority_Correct', 'size'),  # Total number of cases per class
    correct_count=('Majority_Correct', 'sum')  # Sum of correct predictions per class
).reset_index()

# Calculate accuracy for each class
class_stats['accuracy'] = class_stats['correct_count'] / class_stats['total_count'] * 100

# store for final evaluation 
all_majority_vote_details.append(class_stats)

# Log detailed stats
print("Detailed Class Statistics for Majority Votes:")
print(class_stats)
# Out:
# Detailed Class Statistics for Majority Votes:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult           73             70  95.890411
# 1           kitten           15             11  73.333333
# 2           senior           22              4  18.181818

# %%
# Plot for Detailed Class Statistics for Majority Votes
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Accuracy of Majority Votes by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Detailed Class Statistics

# %%
# Calculate the total count and the number of correct predictions for each class
class_stats = full_results.groupby('actual_age_group').agg(
    total_count=('correct', 'size'),
    correct_count=('correct', 'sum')
).reset_index()

# Calculate accuracy for each class
class_stats['accuracy'] = class_stats['correct_count'] / class_stats['total_count'] * 100

# store for final evaluation 
all_class_stats.append(class_stats)

# Log the detailed stats
print("Detailed Class Statistics:")
print(class_stats)
# Out:
# Detailed Class Statistics:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult          573            489  85.340314
# 1           kitten          111             57  51.351351
# 2           senior          186             61  32.795699

# %%
# Plot for Detailed Class Statistics (Overall)
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Overall Accuracy by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Gender Exploration

# %%
# Group by gender and calculate the total count, correct predictions, and accuracy
gender_stats = full_results.groupby('all_gender').agg(
    count=('cat_id', 'size'),  # Total number of cases per gender
    correct=('correct', 'sum')  # Sum of correct predictions per gender
).reset_index()

# Calculate accuracy for each gender
gender_stats['accuracy'] = (gender_stats['correct'] / gender_stats['count'] * 100).round(2)

# Display the DataFrame
print("Accuracy by Gender:")
print(gender_stats)

# store for final evaluation 
all_gender_stats.append(gender_stats)
# Out:
# Accuracy by Gender:
#   all_gender  count  correct  accuracy
# 0          F    218      150     68.81
# 1          M    362      279     77.07
# 2          X    290      178     61.38

# %%
# Plot for Accuracy by Gender
styled_barplot(gender_stats, 'all_gender', 'accuracy', 
               'Accuracy by Gender', 
               'Gender', 'Accuracy (%)')

# %% [markdown]
# ### Log current total CV Stats

# %%
print("Total Majority Vote Accuracy so far:", all_majority_vote_accuracies)
print("Total Class Statistics so far:\n", all_class_stats)
print("Total Gender Accuracy so far:\n", all_gender_stats)
# Out:
# Total Majority Vote Accuracy so far: [0.7727272727272727]
# Total Class Statistics so far:
#  [  actual_age_group  total_count  correct_count   accuracy
# 0            adult          573            489  85.340314
# 1           kitten          111             57  51.351351
# 2           senior          186             61  32.795699]
# Total Gender Accuracy so far:
#  [  all_gender  count  correct  accuracy
# 0          F    218      150     68.81
# 1          M    362      279     77.07
# 2          X    290      178     61.38]

# %% [markdown]
# # RANDOM SEED 2

# %%
# Set a fixed random seed for reproducibility
random.seed(int(random_seeds[1]))
np.random.seed(int(random_seeds[1]))
tf.random.set_seed(int(random_seeds[1]))

# Load datasets
dataframe = pd.read_csv('/Users/astrid/PycharmProjects/data-aug-and-more/yamnet-tfhub-extraction/yamnet_embeddings_looped_april_23.csv')


def assign_age_group(age, age_groups):
    for group_name, age_range in age_groups.items():
        if age_range[0] <= age < age_range[1]:
            return group_name
    return 'Unknown'  # For any age that doesn't fit the defined groups

# Define age groups
age_groups = {
    'kitten': (0, 0.5),
    'adult': (0.5, 12),
    'senior': (12, 20)
}

# Create a new column for the age group
dataframe['age_group'] = dataframe['target'].apply(assign_age_group, age_groups=age_groups)

print(dataframe['age_group'].value_counts())
# Out:
# adult     606
# senior    186
# kitten    176
# Name: age_group, dtype: int64

# %%
# Separate features and labels
X = dataframe.iloc[:, :-4].values  # all columns except the last four

# Encode the 'age_group' column as integers using LabelEncoder
label_encoder = LabelEncoder()
encoded_y = label_encoder.fit_transform(dataframe['age_group'].values)

# Use the encoded labels for splitting and one-hot encoding
y = encoded_y  

# Convert 'cat_id' column to numpy array to be used as groups array for GroupKFold
groups = dataframe['cat_id'].values

# %%
tf.keras.backend.clear_session()

# %% [markdown]
# ## Run Setup

# %%
all_cat_ids = []
all_predicted_age_groups = []
all_actual_age_groups = []
all_gender = []

# Define the StratifiedGroupKFold splitter for 4 fold CV with random shuffling
outer_cv = StratifiedGroupKFold(n_splits=4, shuffle=True, random_state=int(random_seeds[1]))

# unseen test set metrics
unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1 = [], [], [], [], []

outer_fold = 0

# Use the splitter to generate indices for training and testing sets
# Note: GroupShuffleSplit.split returns indices, so we use it to index the arrays
for train_val_idx, test_idx in outer_cv.split(X, y, groups):
    outer_fold += 1
    logger(f"outer_fold {outer_fold}", file=log_file_path)

    # Convert indices back to DataFrame for easy manipulation
    df_train_val = dataframe.iloc[train_val_idx]
    df_test = dataframe.iloc[test_idx]

    ##############################
    # ASSESSING SPLITS BY CAT_ID #
    ##############################
    
    # Get the distribution of groups
    training_validation_group_distribution = df_train_val['cat_id'].value_counts()  
    testing_group_distribution = df_test['cat_id'].value_counts()  
    
    # Log or print the distribution
    logger(f"Train Set Group Distribution:\n{training_validation_group_distribution}", file=log_file_path)
    logger(f"Testing Set Group Distribution:\n{testing_group_distribution}", file=log_file_path)

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val['gender'].value_counts()
    testing_gender_distribution = df_test['gender'].value_counts()
    
    # Log the distribution
    logger(f"Training Set Gender Distribution BEFORE SWAP:\n{training_gender_distribution}", file=log_file_path)
    logger(f"Testing Set Gender Distribution BEFORE SWAP:\n{testing_gender_distribution}", file=log_file_path)

    # Group by 'age_group' and then list unique 'cat_id' within each age group
    unique_cat_ids_per_age_group_train_val = df_train_val.groupby('age_group')['cat_id'].unique()
    unique_cat_ids_per_age_group_test = df_test.groupby('age_group')['cat_id'].unique()
    
    # Log results
    logger(f"Unique Cat IDs per Age Group in Training/Validation Set:\n{unique_cat_ids_per_age_group_train_val}", file=log_file_path)
    logger(f"Unique Cat IDs per Age Group in Testing Set:\n{unique_cat_ids_per_age_group_test}", file=log_file_path)

    # Calculate the count of unique identifiers per age group for training and testing set
    counts_train_val = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_train_val.items()}
    counts_test = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_test.items()}

    # Log the counts of unique identifiers per age group
    logger(f"Count of Unique Cat IDs per Age Group in Training/Validation Set:\n{counts_train_val}", file=log_file_path)
    logger(f"Count of Unique Cat IDs per Age Group in Testing Set:\n{counts_test}", file=log_file_path)

    #######################################################
    # CONTINUE WITH ENSURING VALID AND APPROPRIATE SPLITS #
    #######################################################
    
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    groups_train_val, groups_test = groups[train_val_idx], groups[test_idx]

    # logging identifier splits 
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)

    # check group splits
    check_initial_group_split(groups_train_val, groups_test)

    # Specify the cat_ids that must be in the training/validation set
    specific_cat_ids = ['000A', '046A']
    
    # Perform the swapping operation
    train_val_idx, test_idx = swap_cat_id_instances(dataframe, train_val_idx, test_idx, specific_cat_ids)
    
    # Re-assign the sets based on the updated indices
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    new_groups_train_val, new_groups_test = groups[train_val_idx], groups[test_idx]

    # Find differences for training and test sets
    moved_to_train_val, removed_from_train_val = find_group_differences(groups_train_val, new_groups_train_val)
    moved_to_test, removed_from_test = find_group_differences(groups_test, new_groups_test)
    
    # Display the results
    logger(f"Moved to Training/Validation Set:\n{moved_to_train_val}", file=log_file_path)
    logger(f"Removed from Training/Validation Set:\n{removed_from_train_val}", file=log_file_path)
    logger(f"Moved to Test Set:\n{moved_to_test}", file=log_file_path)
    logger(f"Removed from Test Set\n{removed_from_test}", file=log_file_path)

    # Update X_train_val, X_test, y_train_val, y_test, groups_train_val, groups_test based on updated indices
    X_train_val = X[train_val_idx]
    y_train_val = y[train_val_idx]
    groups_train_val = groups[train_val_idx]
    
    X_test = X[test_idx]
    y_test = y[test_idx]
    groups_test = groups[test_idx]

    # logging identifier splits again after potential swaps
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"AFTER SWAP - Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"AFTER SWAP - Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)
    
    # Verify the lengths are consistent
    logger(f"Length of X_train_val:\n{len(X_train_val)}", file=log_file_path)
    logger(f"Length of y_train_val:\n{len(y_train_val)}", file=log_file_path)
    logger(f"Length of groups_train_val:\n{len(groups_train_val)}", file=log_file_path)

    # Check group splits once more
    check_initial_group_split(groups_train_val, groups_test)

    # Convert the modified indices back to a DataFrame representing the updated df_train_val
    df_train_val_updated = dataframe.iloc[train_val_idx].copy()
    df_test_updated = dataframe.iloc[test_idx].copy()

    ############################
    # LOGGING AGE GROUP SPLITS #
    ############################

    # Get the distribution of age groups of age groups before the update
    training_validation_age_group_distribution = df_train_val['age_group'].value_counts()
    testing_age_group_distribution = df_test['age_group'].value_counts()
    
    # Logthe distribution
    logger(f"Train Age Group Distribution BEFORE SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution BEFORE SWAP:\n{testing_age_group_distribution}", file=log_file_path)

    # Get the distribution of age groups after the update
    training_validation_age_group_distribution = df_train_val_updated['age_group'].value_counts()
    testing_age_group_distribution = df_test_updated['age_group'].value_counts()
    
    # Log the distribution
    logger(f"Train Age Group Distribution AFTER SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution AFTER SWAP:\n{testing_age_group_distribution}", file=log_file_path)
    
    ########################################################
    # TRACKING FINAL CAT_IDs & GENDER AFTER REDISTRIBUTION #
    ########################################################

    # Get the distribution of groups
    training_validation_group_distribution = df_train_val_updated['cat_id'].value_counts()  
    testing_group_distribution = df_test_updated['cat_id'].value_counts()  

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val_updated['gender'].value_counts()
    testing_gender_distribution = df_test_updated['gender'].value_counts()
    
    logger(f"\n Starting training on unseen test set\n", file=log_file_path)

    ###################
    # PREPARING MODEL #
    ###################

    # Calculate the distribution of age groups in y_train_val
    age_group_distribution = Counter(y_train_val)
    print("Age group distribution:", age_group_distribution)

    # EarlyStopping callback: monitor 'loss' instead of 'val_loss' for the test set
    early_stopping = EarlyStopping(
        monitor='loss',  
        min_delta=0.001, 
        patience=30,  
        verbose=1,  
        restore_best_weights=True  
    )

    # Apply SMOTE to the training data only
    smote = SMOTE()
    X_train_val, y_train_val = smote.fit_resample(X_train_val, y_train_val)

    # One final shuffle to ensure randomness
    outer_shuffle_idx = np.random.permutation(len(X_train_val))
    X_train_val = X_train_val[outer_shuffle_idx]
    y_train_val = y_train_val[outer_shuffle_idx]
    
    # Scale the features
    scaler_full = StandardScaler().fit(X_train_val)
    X_train_full_scaled = scaler_full.transform(X_train_val)
    X_test_scaled = scaler_full.transform(X_test)
    
    # Encode the labels
    y_train_full_encoded = to_categorical(y_train_val)
    y_test_encoded = to_categorical(y_test)

    #######################
    # BUILD & TRAIN MODEL #
    #######################

    optimizers = {
        'Adamax': Adamax(learning_rate=0.00510251984616472)
    }
    
    # Model definition with dynamic number of layers
    model_full = Sequential()
    model_full.add(Dense(480, activation='relu', input_shape=(X_train_full_scaled.shape[1],)))
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.2011047009431978))  
    model_full.add(Dense(256, activation='relu',)) 
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.14956886311951184))  
    model_full.add(Dense(256, activation='relu'))  
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.42291461228250665))  
    model_full.add(Dense(3, activation='softmax'))  
    
    # Use the optimizer from the parameters
    optimizer = optimizers['Adamax']  # optimizer_key from parameters
    
    # Compile the model
    model_full.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    
    # Train the model on the full training set
    history_full = model_full.fit(X_train_full_scaled, y_train_full_encoded, epochs=1500, batch_size=64,
                                  verbose=1, callbacks=[early_stopping])
    
    # Evaluate the model on the held-out test set
    test_loss, test_accuracy = model_full.evaluate(X_test_scaled, y_test_encoded)

    y_test_pred_prob = model_full.predict(X_test_scaled)
    y_test_pred = np.argmax(y_test_pred_prob, axis=1)  
    y_test_true = np.argmax(y_test_encoded, axis=1)    

    ################################
    # LOG MAJORITY VOTE PER CAT_ID #
    ################################

    # Convert numeric predictions back to age group labels
    predicted_age_groups = label_encoder.inverse_transform(y_test_pred)
    actual_labels = label_encoder.inverse_transform(y_test_true)
    
    # Map predictions and actual labels back to cat_ids
    test_results = pd.DataFrame({
        'cat_id': df_test_updated['cat_id'],
        'predicted_age_group': predicted_age_groups,
        'actual_age_group': actual_labels
    })
    
    # Group by cat_id and aggregate predicted age groups
    majority_votes = test_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
    actual_groups = test_results.groupby('cat_id')['actual_age_group'].first()
    
    # Calculate the accuracy of majority voting
    correct_predictions = (majority_votes == actual_groups).sum()
    total_cats = len(actual_groups)
    majority_vote_accuracy = correct_predictions / total_cats
    
    # Log the accuracy of the majority voting
    logger(f"Majority Vote Accuracy for cat_id for this fold: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

    ####################################################
    # COLLECT PREDICTIONS FOR GENDER & CAT_ID ANALYSIS #
    ####################################################

    # Debugging print statements
    print(f'Before appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Extend lists with current fold results
    all_cat_ids.extend(df_test_updated['cat_id'].tolist())
    all_predicted_age_groups.extend(predicted_age_groups)
    all_actual_age_groups.extend(actual_labels)
    all_gender.extend(df_test_updated['gender'].tolist())

    # Debugging print statements
    print(f'After appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Calculate additional metrics
    test_precision = precision_score(y_test_true, y_test_pred, average='macro')  # Use 'macro' for imbalanced datasets
    test_recall = recall_score(y_test_true, y_test_pred, average='macro')
    test_f1 = f1_score(y_test_true, y_test_pred, average='macro')

    # prepare averages of outer metrics
    unseen_f1.append(test_f1)
    unseen_losses.append(test_loss)
    unseen_accuracies.append(test_accuracy)
    unseen_precisions.append(test_precision)
    unseen_recalls.append(test_recall)

    # Print final test results
    logger(f"Final Test Results - Loss: {test_loss}, Accuracy: {test_accuracy}, Precision: {test_precision}, Recall: {test_recall}, F1 Score: {test_f1}", file=log_file_path)

    # Generate the confusion matrix
    cm = confusion_matrix(y_test, y_test_pred)
    logger(f"Confusion Matrix:\n {cm}", file=log_file_path)

# Calculate the overall average metrics
unseen_set_avg_f1 = np.mean(unseen_f1)
unseen_set_avg_loss = np.mean(unseen_losses)
unseen_set_avg_acc = np.mean(unseen_accuracies)
unseen_set_avg_precision = np.mean(unseen_precisions)
unseen_set_avg_recall = np.mean(unseen_recalls)

logger(f"\nFinal Average F1-Score across all UNSEEN TEST sets: {unseen_set_avg_f1}", file=log_file_path)
logger(f"\nFinal Average Loss across all UNSEEN TEST sets: {unseen_set_avg_loss}", file=log_file_path)
logger(f"\nFinal Average Accuracy across all UNSEEN TEST sets: {unseen_set_avg_acc}", file=log_file_path)
logger(f"\nFinal Average Precision across all UNSEEN TEST sets: {unseen_set_avg_precision}", file=log_file_path)
logger(f"\nFinal Average Recall across all UNSEEN TEST sets: {unseen_set_avg_recall}\n", file=log_file_path)

# Append averages to total lists
all_f1.append(unseen_set_avg_f1)
all_losses.append(unseen_set_avg_loss)
all_accuracies.append(unseen_set_avg_acc)
all_precisions.append(unseen_set_avg_precision)
all_recalls.append(unseen_set_avg_recall)
# Out:
# outer_fold 1
# Train Set Group Distribution:
# 000A    39
# 002B    36
# 047A    30
# 057A    28
# 074A    25
# 020A    23
# 000B    20
# 067A    20
# 055A    20
# 029A    17
# 019A    17
# 101A    16
# 097A    16
# 001A    15
# 042A    14
# 097B    14
# 028A    14
# 002A    13
# 039A    12
# 116A    12
# 005A    11
# 016A    11
# 040A    10
# 014B    10
# 071A    10
# 051B     9
# 022A     9
# 065A     9
# 072A     9
# 013B     8
# 095A     8
# 010A     8
# 117A     7
# 027A     7
# 050A     7
# 053A     7
# 031A     7
# 023A     6
# 037A     6
# 021A     6
# 025C     6
# 108A     6
# 008A     6
# 109A     6
# 007A     6
# 012A     5
# 034A     5
# 062A     5
# 070A     5
# 026A     4
# 009A     4
# 105A     4
# 003A     4
# 104A     4
# 058A     3
# 006A     3
# 113A     3
# 056A     3
# 011A     3
# 064A     3
# 060A     3
# 014A     3
# 087A     2
# 025B     2
# 093A     2
# 066A     2
# 054A     2
# 032A     2
# 102A     2
# 069A     2
# 038A     2
# 061A     2
# 073A     1
# 041A     1
# 026B     1
# 004A     1
# 076A     1
# 110A     1
# 115A     1
# 024A     1
# 091A     1
# 026C     1
# 049A     1
# 043A     1
# 096A     1
# 088A     1
# 100A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 046A    66
# 103A    33
# 059A    18
# 106A    15
# 111A    13
# 051A    12
# 063A    11
# 036A    11
# 068A    11
# 025A    11
# 015A    10
# 045A     9
# 033A     9
# 094A     8
# 099A     7
# 075A     5
# 023B     5
# 044A     5
# 035A     4
# 052A     4
# 018A     2
# 092A     1
# 048A     1
# 090A     1
# 019B     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    250
# X    223
# F    222
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    132
# M    106
# F     35
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [002A, 028A, 070A, 000B, 071A, 020A, 000A, 026...
# kitten    [042A, 014B, 110A, 109A, 040A, 047A, 049A, 043...
# senior    [117A, 057A, 113A, 051B, 116A, 024A, 097A, 055...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [033A, 015A, 023B, 068A, 018A, 103A, 063A, 075...
# kitten                       [046A, 045A, 048A, 111A, 044A]
# senior                       [106A, 090A, 051A, 094A, 059A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 59, 'kitten': 11, 'senior': 17}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 15, 'kitten': 5, 'senior': 5}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '004A' '005A' '006A' '007A'
#  '008A' '009A' '010A' '011A' '012A' '013B' '014A' '014B' '016A' '019A'
#  '020A' '021A' '022A' '023A' '024A' '025B' '025C' '026A' '026B' '026C'
#  '027A' '028A' '029A' '031A' '032A' '034A' '037A' '038A' '039A' '040A'
#  '041A' '042A' '043A' '047A' '049A' '050A' '051B' '053A' '054A' '055A'
#  '056A' '057A' '058A' '060A' '061A' '062A' '064A' '065A' '066A' '067A'
#  '069A' '070A' '071A' '072A' '073A' '074A' '076A' '087A' '088A' '091A'
#  '093A' '095A' '096A' '097A' '097B' '100A' '101A' '102A' '104A' '105A'
#  '108A' '109A' '110A' '113A' '115A' '116A' '117A']
# Unique Test Group IDs:
# ['015A' '018A' '019B' '023B' '025A' '033A' '035A' '036A' '044A' '045A'
#  '046A' '048A' '051A' '052A' '059A' '063A' '068A' '075A' '090A' '092A'
#  '094A' '099A' '103A' '106A' '111A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'046A'}
# Removed from Training/Validation Set:
# {'014B'}
# Moved to Test Set:
# {'014B'}
# Removed from Test Set
# {'046A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '004A' '005A' '006A' '007A'
#  '008A' '009A' '010A' '011A' '012A' '013B' '014A' '016A' '019A' '020A'
#  '021A' '022A' '023A' '024A' '025B' '025C' '026A' '026B' '026C' '027A'
#  '028A' '029A' '031A' '032A' '034A' '037A' '038A' '039A' '040A' '041A'
#  '042A' '043A' '046A' '047A' '049A' '050A' '051B' '053A' '054A' '055A'
#  '056A' '057A' '058A' '060A' '061A' '062A' '064A' '065A' '066A' '067A'
#  '069A' '070A' '071A' '072A' '073A' '074A' '076A' '087A' '088A' '091A'
#  '093A' '095A' '096A' '097A' '097B' '100A' '101A' '102A' '104A' '105A'
#  '108A' '109A' '110A' '113A' '115A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['014B' '015A' '018A' '019B' '023B' '025A' '033A' '035A' '036A' '044A'
#  '045A' '048A' '051A' '052A' '059A' '063A' '068A' '075A' '090A' '092A'
#  '094A' '099A' '103A' '106A' '111A']
# Length of X_train_val:
# 751
# Length of y_train_val:
# 751
# Length of groups_train_val:
# 751
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     481
# senior    132
# kitten     82
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     125
# kitten     94
# senior     54
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     481
# kitten    138
# senior    132
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     125
# senior     54
# kitten     38
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 481, 1: 138, 2: 132})
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Epoch 1/1500
# 23/23 [==============================] - 1s 5ms/step - loss: 0.7933 - accuracy: 0.7193
# Epoch 2/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.2612 - accuracy: 0.9092
# Epoch 3/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1372 - accuracy: 0.9543
# Epoch 4/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.1189 - accuracy: 0.9584
# Epoch 5/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1084 - accuracy: 0.9598
# Epoch 6/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0545 - accuracy: 0.9771
# Epoch 7/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0345 - accuracy: 0.9896
# Epoch 8/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0304 - accuracy: 0.9903
# Epoch 9/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0267 - accuracy: 0.9903
# Epoch 10/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0312 - accuracy: 0.9924
# Epoch 11/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0202 - accuracy: 0.9938
# Epoch 12/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0185 - accuracy: 0.9958
# Epoch 13/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0281 - accuracy: 0.9882
# Epoch 14/1500
# 23/23 [==============================] - 0s 9ms/step - loss: 0.0176 - accuracy: 0.9924
# Epoch 15/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0168 - accuracy: 0.9951
# Epoch 16/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0109 - accuracy: 0.9958
# Epoch 17/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0140 - accuracy: 0.9945
# Epoch 18/1500
# 23/23 [==============================] - 0s 10ms/step - loss: 0.0089 - accuracy: 0.9979
# Epoch 19/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0089 - accuracy: 0.9972
# Epoch 20/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0125 - accuracy: 0.9958
# Epoch 21/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0124 - accuracy: 0.9945
# Epoch 22/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0140 - accuracy: 0.9958
# Epoch 23/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0214 - accuracy: 0.9924
# Epoch 24/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0176 - accuracy: 0.9945
# Epoch 25/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0133 - accuracy: 0.9951
# Epoch 26/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0052 - accuracy: 1.0000
# Epoch 27/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0089 - accuracy: 0.9965
# Epoch 28/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0124 - accuracy: 0.9958
# Epoch 29/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0093 - accuracy: 0.9958
# Epoch 30/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0081 - accuracy: 0.9979
# Epoch 31/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0052 - accuracy: 0.9979
# Epoch 32/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0057 - accuracy: 0.9986
# Epoch 33/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0051 - accuracy: 0.9993
# Epoch 34/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0039 - accuracy: 0.9986
# Epoch 35/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0091 - accuracy: 0.9972
# Epoch 36/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0100 - accuracy: 0.9972
# Epoch 37/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0083 - accuracy: 0.9979
# Epoch 38/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0042 - accuracy: 1.0000
# Epoch 39/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0157 - accuracy: 0.9958
# Epoch 40/1500
# 23/23 [==============================] - 0s 8ms/step - loss: 0.0025 - accuracy: 0.9993
# Epoch 41/1500
# 23/23 [==============================] - 0s 8ms/step - loss: 0.0080 - accuracy: 0.9965
# Epoch 42/1500
# 23/23 [==============================] - 0s 9ms/step - loss: 0.0095 - accuracy: 0.9951
# Epoch 43/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0053 - accuracy: 0.9979
# Epoch 44/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0070 - accuracy: 0.9972
# Epoch 45/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0095 - accuracy: 0.9958
# Epoch 46/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0074 - accuracy: 0.9979
# Epoch 47/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0064 - accuracy: 0.9965
# Epoch 48/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0058 - accuracy: 0.9986
# Epoch 49/1500
# 23/23 [==============================] - 0s 8ms/step - loss: 0.0064 - accuracy: 0.9979
# Epoch 50/1500
# 23/23 [==============================] - 0s 8ms/step - loss: 0.0063 - accuracy: 0.9979
# Epoch 51/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0040 - accuracy: 0.9993
# Epoch 52/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0036 - accuracy: 0.9986
# Epoch 53/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0035 - accuracy: 0.9986
# Epoch 54/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0035 - accuracy: 0.9979
# Epoch 55/1500
# 23/23 [==============================] - 0s 8ms/step - loss: 0.0038 - accuracy: 0.9986
# Epoch 56/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0034 - accuracy: 0.9993
# Epoch 57/1500
# 23/23 [==============================] - 0s 8ms/step - loss: 0.0082 - accuracy: 0.9972
# Epoch 58/1500
# 23/23 [==============================] - 0s 8ms/step - loss: 0.0051 - accuracy: 0.9993
# Epoch 59/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0082 - accuracy: 0.9972
# Epoch 60/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 61/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 8.9771e-04 - accuracy: 1.0000
# Epoch 62/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0017 - accuracy: 0.9993
# Epoch 63/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 7.1032e-04 - accuracy: 1.0000
# Epoch 64/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0023 - accuracy: 0.9993
# Epoch 65/1500
# 23/23 [==============================] - 0s 8ms/step - loss: 0.0021 - accuracy: 0.9993
# Epoch 66/1500
# 23/23 [==============================] - 0s 8ms/step - loss: 0.0030 - accuracy: 0.9993
# Epoch 67/1500
# 23/23 [==============================] - 0s 9ms/step - loss: 0.0020 - accuracy: 0.9993
# Epoch 68/1500
# 23/23 [==============================] - 0s 9ms/step - loss: 0.0038 - accuracy: 0.9986
# Epoch 69/1500
# 23/23 [==============================] - 0s 21ms/step - loss: 0.0030 - accuracy: 0.9986
# Epoch 70/1500
# 23/23 [==============================] - 0s 9ms/step - loss: 0.0069 - accuracy: 0.9972
# Epoch 71/1500
# 23/23 [==============================] - 0s 8ms/step - loss: 0.0108 - accuracy: 0.9958
# Epoch 72/1500
# 23/23 [==============================] - 0s 10ms/step - loss: 0.0101 - accuracy: 0.9965
# Epoch 73/1500
# 23/23 [==============================] - 0s 10ms/step - loss: 0.0109 - accuracy: 0.9972
# Epoch 74/1500
# 23/23 [==============================] - 0s 22ms/step - loss: 0.0110 - accuracy: 0.9965
# Epoch 75/1500
# 23/23 [==============================] - 0s 8ms/step - loss: 0.0033 - accuracy: 0.9986
# Epoch 76/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0031 - accuracy: 0.9986
# Epoch 77/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0033 - accuracy: 0.9993
# Epoch 78/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0089 - accuracy: 0.9972
# Epoch 79/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0028 - accuracy: 0.9986
# Epoch 80/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0074 - accuracy: 0.9993
# Epoch 81/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0067 - accuracy: 0.9986
# Epoch 82/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0064 - accuracy: 0.9965
# Epoch 83/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0051 - accuracy: 0.9972
# Epoch 84/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0018 - accuracy: 0.9993
# Epoch 85/1500
# 23/23 [==============================] - 0s 8ms/step - loss: 0.0059 - accuracy: 0.9972
# Epoch 86/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0093 - accuracy: 0.9972
# Epoch 87/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0061 - accuracy: 0.9986
# Epoch 88/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0070 - accuracy: 0.9972
# Epoch 89/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0137 - accuracy: 0.9938
# Epoch 90/1500
# 17/23 [=====================>........] - ETA: 0s - loss: 0.0052 - accuracy: 0.9963Restoring model weights from the end of the best epoch: 60.
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0121 - accuracy: 0.9938
# Epoch 90: early stopping
# 7/7 [==============================] - 0s 2ms/step - loss: 6.9296 - accuracy: 0.6544
# 7/7 [==============================] - 0s 2ms/step
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Majority Vote Accuracy for cat_id for this fold: 0.80 (20/25)
# Before appending - Cat IDs: 0, Predictions: 0, Actuals: 0, Gender: 0
# After appending - Cat IDs: 217, Predictions: 217, Actuals: 217, Gender: 217
# Final Test Results - Loss: 6.929603099822998, Accuracy: 0.6543778777122498, Precision: 0.642822231531909, Recall: 0.5812917478882391, F1 Score: 0.5977892232161682
# Confusion Matrix:
#  [[102   8  15]
#  [ 14  24   0]
#  [ 38   0  16]]
# outer_fold 2
# Train Set Group Distribution:
# 046A    66
# 000A    39
# 002B    36
# 103A    33
# 057A    28
# 074A    25
# 020A    23
# 055A    20
# 000B    20
# 059A    18
# 097A    16
# 101A    16
# 106A    15
# 001A    15
# 028A    14
# 097B    14
# 111A    13
# 002A    13
# 039A    12
# 051A    12
# 116A    12
# 016A    11
# 068A    11
# 063A    11
# 025A    11
# 036A    11
# 040A    10
# 014B    10
# 071A    10
# 015A    10
# 033A     9
# 045A     9
# 051B     9
# 072A     9
# 013B     8
# 094A     8
# 010A     8
# 053A     7
# 099A     7
# 117A     7
# 031A     7
# 027A     7
# 023A     6
# 108A     6
# 008A     6
# 037A     6
# 025C     6
# 007A     6
# 075A     5
# 034A     5
# 062A     5
# 070A     5
# 023B     5
# 044A     5
# 035A     4
# 026A     4
# 003A     4
# 009A     4
# 052A     4
# 056A     3
# 113A     3
# 011A     3
# 060A     3
# 018A     2
# 025B     2
# 038A     2
# 032A     2
# 054A     2
# 102A     2
# 026C     1
# 041A     1
# 019B     1
# 115A     1
# 110A     1
# 043A     1
# 090A     1
# 073A     1
# 088A     1
# 092A     1
# 048A     1
# 049A     1
# 026B     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 047A    30
# 067A    20
# 019A    17
# 029A    17
# 042A    14
# 005A    11
# 022A     9
# 065A     9
# 095A     8
# 050A     7
# 109A     6
# 021A     6
# 012A     5
# 104A     4
# 105A     4
# 014A     3
# 064A     3
# 058A     3
# 006A     3
# 061A     2
# 087A     2
# 066A     2
# 069A     2
# 093A     2
# 096A     1
# 024A     1
# 091A     1
# 076A     1
# 004A     1
# 100A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    272
# X    270
# F    231
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    85
# M    84
# F    26
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [002A, 028A, 070A, 033A, 000B, 071A, 020A, 000...
# kitten    [046A, 014B, 110A, 040A, 049A, 045A, 048A, 111...
# senior    [117A, 106A, 057A, 090A, 113A, 051B, 116A, 051...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [065A, 021A, 105A, 005A, 006A, 091A, 019A, 022...
# kitten                             [042A, 109A, 047A, 050A]
# senior                       [024A, 058A, 061A, 104A, 093A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 53, 'kitten': 12, 'senior': 17}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 21, 'kitten': 4, 'senior': 5}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '007A' '008A' '009A' '010A'
#  '011A' '013B' '014B' '015A' '016A' '018A' '019B' '020A' '023A' '023B'
#  '025A' '025B' '025C' '026A' '026B' '026C' '027A' '028A' '031A' '032A'
#  '033A' '034A' '035A' '036A' '037A' '038A' '039A' '040A' '041A' '043A'
#  '044A' '045A' '046A' '048A' '049A' '051A' '051B' '052A' '053A' '054A'
#  '055A' '056A' '057A' '059A' '060A' '062A' '063A' '068A' '070A' '071A'
#  '072A' '073A' '074A' '075A' '088A' '090A' '092A' '094A' '097A' '097B'
#  '099A' '101A' '102A' '103A' '106A' '108A' '110A' '111A' '113A' '115A'
#  '116A' '117A']
# Unique Test Group IDs:
# ['004A' '005A' '006A' '012A' '014A' '019A' '021A' '022A' '024A' '029A'
#  '042A' '047A' '050A' '058A' '061A' '064A' '065A' '066A' '067A' '069A'
#  '076A' '087A' '091A' '093A' '095A' '096A' '100A' '104A' '105A' '109A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '007A' '008A' '009A' '010A'
#  '011A' '013B' '014B' '015A' '016A' '018A' '019B' '020A' '023A' '023B'
#  '025A' '025B' '025C' '026A' '026B' '026C' '027A' '028A' '031A' '032A'
#  '033A' '034A' '035A' '036A' '037A' '038A' '039A' '040A' '041A' '043A'
#  '044A' '045A' '046A' '048A' '049A' '051A' '051B' '052A' '053A' '054A'
#  '055A' '056A' '057A' '059A' '060A' '062A' '063A' '068A' '070A' '071A'
#  '072A' '073A' '074A' '075A' '088A' '090A' '092A' '094A' '097A' '097B'
#  '099A' '101A' '102A' '103A' '106A' '108A' '110A' '111A' '113A' '115A'
#  '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['004A' '005A' '006A' '012A' '014A' '019A' '021A' '022A' '024A' '029A'
#  '042A' '047A' '050A' '058A' '061A' '064A' '065A' '066A' '067A' '069A'
#  '076A' '087A' '091A' '093A' '095A' '096A' '100A' '104A' '105A' '109A']
# Length of X_train_val:
# 773
# Length of y_train_val:
# 773
# Length of groups_train_val:
# 773
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     480
# senior    174
# kitten    119
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     126
# kitten     57
# senior     12
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     480
# senior    174
# kitten    119
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     126
# kitten     57
# senior     12
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 480, 2: 174, 1: 119})
# Epoch 1/1500
# 23/23 [==============================] - 1s 5ms/step - loss: 0.7955 - accuracy: 0.7396
# Epoch 2/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.2788 - accuracy: 0.9007
# Epoch 3/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.1578 - accuracy: 0.9465
# Epoch 4/1500
# 23/23 [==============================] - 0s 9ms/step - loss: 0.1318 - accuracy: 0.9590
# Epoch 5/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.1207 - accuracy: 0.9590
# Epoch 6/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0767 - accuracy: 0.9701
# Epoch 7/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0608 - accuracy: 0.9799
# Epoch 8/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0504 - accuracy: 0.9819
# Epoch 9/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0429 - accuracy: 0.9847
# Epoch 10/1500
# 23/23 [==============================] - 0s 8ms/step - loss: 0.0545 - accuracy: 0.9799
# Epoch 11/1500
# 23/23 [==============================] - 0s 8ms/step - loss: 0.0295 - accuracy: 0.9917
# Epoch 12/1500
# 23/23 [==============================] - 0s 8ms/step - loss: 0.0208 - accuracy: 0.9944
# Epoch 13/1500
# 23/23 [==============================] - 0s 8ms/step - loss: 0.0195 - accuracy: 0.9958
# Epoch 14/1500
# 23/23 [==============================] - 0s 8ms/step - loss: 0.0181 - accuracy: 0.9944
# Epoch 15/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0127 - accuracy: 0.9937
# Epoch 16/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0138 - accuracy: 0.9972
# Epoch 17/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0253 - accuracy: 0.9924
# Epoch 18/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0220 - accuracy: 0.9924
# Epoch 19/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0161 - accuracy: 0.9937
# Epoch 20/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0119 - accuracy: 0.9951
# Epoch 21/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0243 - accuracy: 0.9903
# Epoch 22/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0083 - accuracy: 0.9979
# Epoch 23/1500
# 23/23 [==============================] - 0s 8ms/step - loss: 0.0154 - accuracy: 0.9951
# Epoch 24/1500
# 23/23 [==============================] - 0s 8ms/step - loss: 0.0125 - accuracy: 0.9965
# Epoch 25/1500
# 23/23 [==============================] - 0s 8ms/step - loss: 0.0070 - accuracy: 0.9979
# Epoch 26/1500
# 23/23 [==============================] - 0s 8ms/step - loss: 0.0074 - accuracy: 0.9986
# Epoch 27/1500
# 23/23 [==============================] - 0s 8ms/step - loss: 0.0070 - accuracy: 0.9972
# Epoch 28/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0073 - accuracy: 0.9972
# Epoch 29/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0136 - accuracy: 0.9958
# Epoch 30/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0150 - accuracy: 0.9944
# Epoch 31/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0066 - accuracy: 0.9972
# Epoch 32/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0112 - accuracy: 0.9958
# Epoch 33/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0092 - accuracy: 0.9965
# Epoch 34/1500
# 23/23 [==============================] - 0s 10ms/step - loss: 0.0198 - accuracy: 0.9951
# Epoch 35/1500
# 23/23 [==============================] - 0s 10ms/step - loss: 0.0055 - accuracy: 0.9993
# Epoch 36/1500
# 23/23 [==============================] - 0s 8ms/step - loss: 0.0045 - accuracy: 0.9993
# Epoch 37/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0041 - accuracy: 0.9986
# Epoch 38/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0041 - accuracy: 0.9986
# Epoch 39/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0033 - accuracy: 0.9993
# Epoch 40/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0022 - accuracy: 0.9993
# Epoch 41/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0020 - accuracy: 0.9993
# Epoch 42/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0072 - accuracy: 0.9979
# Epoch 43/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0033 - accuracy: 0.9993
# Epoch 44/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 45/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0036 - accuracy: 0.9993
# Epoch 46/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0070 - accuracy: 0.9972
# Epoch 47/1500
# 23/23 [==============================] - 0s 8ms/step - loss: 0.0038 - accuracy: 0.9993
# Epoch 48/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 49/1500
# 23/23 [==============================] - 0s 8ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 50/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 51/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0018 - accuracy: 0.9993
# Epoch 52/1500
# 23/23 [==============================] - 0s 8ms/step - loss: 0.0048 - accuracy: 0.9993
# Epoch 53/1500
# 23/23 [==============================] - 0s 16ms/step - loss: 0.0065 - accuracy: 0.9972
# Epoch 54/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 55/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0021 - accuracy: 0.9993
# Epoch 56/1500
# 23/23 [==============================] - 0s 14ms/step - loss: 0.0065 - accuracy: 0.9972
# Epoch 57/1500
# 23/23 [==============================] - 0s 8ms/step - loss: 0.0074 - accuracy: 0.9979
# Epoch 58/1500
# 23/23 [==============================] - 0s 9ms/step - loss: 0.0098 - accuracy: 0.9958
# Epoch 59/1500
# 23/23 [==============================] - 0s 8ms/step - loss: 0.0137 - accuracy: 0.9958
# Epoch 60/1500
# 23/23 [==============================] - 0s 9ms/step - loss: 0.0194 - accuracy: 0.9931
# Epoch 61/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0384 - accuracy: 0.9861
# Epoch 62/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0123 - accuracy: 0.9924
# Epoch 63/1500
# 23/23 [==============================] - 0s 8ms/step - loss: 0.0085 - accuracy: 0.9979
# Epoch 64/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0072 - accuracy: 0.9972
# Epoch 65/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0029 - accuracy: 0.9993
# Epoch 66/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0035 - accuracy: 0.9993
# Epoch 67/1500
# 23/23 [==============================] - 0s 8ms/step - loss: 0.0033 - accuracy: 0.9986
# Epoch 68/1500
# 23/23 [==============================] - 0s 9ms/step - loss: 0.0046 - accuracy: 0.9979
# Epoch 69/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0018 - accuracy: 0.9986
# Epoch 70/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0050 - accuracy: 0.9979
# Epoch 71/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0107 - accuracy: 0.9979
# Epoch 72/1500
# 23/23 [==============================] - 0s 9ms/step - loss: 0.0057 - accuracy: 0.9979
# Epoch 73/1500
# 23/23 [==============================] - 0s 9ms/step - loss: 0.0089 - accuracy: 0.9958
# Epoch 74/1500
# 23/23 [==============================] - 0s 11ms/step - loss: 0.0033 - accuracy: 0.9993
# Epoch 75/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0091 - accuracy: 0.9972
# Epoch 76/1500
# 23/23 [==============================] - 0s 8ms/step - loss: 0.0042 - accuracy: 0.9993
# Epoch 77/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0026 - accuracy: 0.9993
# Epoch 78/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 79/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0027 - accuracy: 0.9986
# Epoch 80/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 8.7533e-04 - accuracy: 1.0000
# Epoch 81/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0032 - accuracy: 0.9986
# Epoch 82/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0026 - accuracy: 0.9986
# Epoch 83/1500
# 23/23 [==============================] - 0s 8ms/step - loss: 0.0044 - accuracy: 0.9979
# Epoch 84/1500
# 23/23 [==============================] - ETA: 0s - loss: 8.5207e-04 - accuracy: 1.0000Restoring model weights from the end of the best epoch: 54.
# 23/23 [==============================] - 0s 8ms/step - loss: 8.5207e-04 - accuracy: 1.0000
# Epoch 84: early stopping
# 7/7 [==============================] - 0s 2ms/step - loss: 4.0312 - accuracy: 0.5692
# 7/7 [==============================] - 0s 2ms/step
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Majority Vote Accuracy for cat_id for this fold: 0.67 (20/30)
# Before appending - Cat IDs: 217, Predictions: 217, Actuals: 217, Gender: 217
# After appending - Cat IDs: 412, Predictions: 412, Actuals: 412, Gender: 412
# Final Test Results - Loss: 4.03124475479126, Accuracy: 0.5692307949066162, Precision: 0.39570614570614576, Recall: 0.36953494848231694, F1 Score: 0.3502858370943478
# Confusion Matrix:
#  [[101  10  15]
#  [ 45   8   4]
#  [ 10   0   2]]
# outer_fold 3
# Train Set Group Distribution:
# 046A    66
# 000A    39
# 103A    33
# 047A    30
# 074A    25
# 055A    20
# 000B    20
# 067A    20
# 059A    18
# 029A    17
# 019A    17
# 097A    16
# 106A    15
# 042A    14
# 097B    14
# 111A    13
# 051A    12
# 068A    11
# 063A    11
# 005A    11
# 025A    11
# 036A    11
# 040A    10
# 015A    10
# 022A     9
# 033A     9
# 045A     9
# 051B     9
# 072A     9
# 065A     9
# 095A     8
# 094A     8
# 010A     8
# 099A     7
# 027A     7
# 053A     7
# 050A     7
# 031A     7
# 025C     6
# 023A     6
# 021A     6
# 109A     6
# 012A     5
# 044A     5
# 075A     5
# 023B     5
# 035A     4
# 052A     4
# 104A     4
# 105A     4
# 026A     4
# 003A     4
# 064A     3
# 006A     3
# 014A     3
# 011A     3
# 058A     3
# 056A     3
# 087A     2
# 025B     2
# 066A     2
# 061A     2
# 093A     2
# 069A     2
# 018A     2
# 019B     1
# 041A     1
# 115A     1
# 004A     1
# 026B     1
# 076A     1
# 073A     1
# 110A     1
# 090A     1
# 088A     1
# 096A     1
# 043A     1
# 091A     1
# 024A     1
# 092A     1
# 048A     1
# 100A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 002B    36
# 057A    28
# 020A    23
# 101A    16
# 001A    15
# 028A    14
# 002A    13
# 116A    12
# 039A    12
# 016A    11
# 014B    10
# 071A    10
# 013B     8
# 117A     7
# 007A     6
# 037A     6
# 008A     6
# 108A     6
# 070A     5
# 034A     5
# 062A     5
# 009A     4
# 060A     3
# 113A     3
# 102A     2
# 054A     2
# 032A     2
# 038A     2
# 026C     1
# 049A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    274
# M    257
# F    163
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# M    99
# F    94
# X    81
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [033A, 000B, 000A, 015A, 026A, 065A, 053A, 023...
# kitten    [046A, 042A, 110A, 109A, 040A, 047A, 045A, 048...
# senior    [106A, 090A, 051B, 051A, 024A, 097A, 094A, 059...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [002A, 028A, 070A, 071A, 020A, 038A, 026C, 007...
# kitten                                         [014B, 049A]
# senior           [117A, 057A, 113A, 116A, 016A, 054A, 108A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 53, 'kitten': 14, 'senior': 15}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 21, 'kitten': 2, 'senior': 7}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '003A' '004A' '005A' '006A' '010A' '011A' '012A' '014A'
#  '015A' '018A' '019A' '019B' '021A' '022A' '023A' '023B' '024A' '025A'
#  '025B' '025C' '026A' '026B' '027A' '029A' '031A' '033A' '035A' '036A'
#  '040A' '041A' '042A' '043A' '044A' '045A' '046A' '047A' '048A' '050A'
#  '051A' '051B' '052A' '053A' '055A' '056A' '058A' '059A' '061A' '063A'
#  '064A' '065A' '066A' '067A' '068A' '069A' '072A' '073A' '074A' '075A'
#  '076A' '087A' '088A' '090A' '091A' '092A' '093A' '094A' '095A' '096A'
#  '097A' '097B' '099A' '100A' '103A' '104A' '105A' '106A' '109A' '110A'
#  '111A' '115A']
# Unique Test Group IDs:
# ['001A' '002A' '002B' '007A' '008A' '009A' '013B' '014B' '016A' '020A'
#  '026C' '028A' '032A' '034A' '037A' '038A' '039A' '049A' '054A' '057A'
#  '060A' '062A' '070A' '071A' '101A' '102A' '108A' '113A' '116A' '117A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '003A' '004A' '005A' '006A' '010A' '011A' '012A' '014A'
#  '015A' '018A' '019A' '019B' '021A' '022A' '023A' '023B' '024A' '025A'
#  '025B' '025C' '026A' '026B' '027A' '029A' '031A' '033A' '035A' '036A'
#  '040A' '041A' '042A' '043A' '044A' '045A' '046A' '047A' '048A' '050A'
#  '051A' '051B' '052A' '053A' '055A' '056A' '058A' '059A' '061A' '063A'
#  '064A' '065A' '066A' '067A' '068A' '069A' '072A' '073A' '074A' '075A'
#  '076A' '087A' '088A' '090A' '091A' '092A' '093A' '094A' '095A' '096A'
#  '097A' '097B' '099A' '100A' '103A' '104A' '105A' '106A' '109A' '110A'
#  '111A' '115A']
# AFTER SWAP - Unique Test Group IDs:
# ['001A' '002A' '002B' '007A' '008A' '009A' '013B' '014B' '016A' '020A'
#  '026C' '028A' '032A' '034A' '037A' '038A' '039A' '049A' '054A' '057A'
#  '060A' '062A' '070A' '071A' '101A' '102A' '108A' '113A' '116A' '117A']
# Length of X_train_val:
# 694
# Length of y_train_val:
# 694
# Length of groups_train_val:
# 694
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     412
# kitten    165
# senior    117
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     194
# senior     69
# kitten     11
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     412
# kitten    165
# senior    117
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     194
# senior     69
# kitten     11
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 412, 1: 165, 2: 117})
# Epoch 1/1500
# 20/20 [==============================] - 1s 6ms/step - loss: 0.7605 - accuracy: 0.7379
# Epoch 2/1500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2854 - accuracy: 0.8948
# Epoch 3/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.2064 - accuracy: 0.9328
# Epoch 4/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.1142 - accuracy: 0.9620
# Epoch 5/1500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0817 - accuracy: 0.9693
# Epoch 6/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0665 - accuracy: 0.9830
# Epoch 7/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0512 - accuracy: 0.9862
# Epoch 8/1500
# 20/20 [==============================] - 0s 7ms/step - loss: 0.0451 - accuracy: 0.9838
# Epoch 9/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0362 - accuracy: 0.9879
# Epoch 10/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0306 - accuracy: 0.9895
# Epoch 11/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0403 - accuracy: 0.9822
# Epoch 12/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0315 - accuracy: 0.9887
# Epoch 13/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0399 - accuracy: 0.9911
# Epoch 14/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0214 - accuracy: 0.9943
# Epoch 15/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0213 - accuracy: 0.9927
# Epoch 16/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0125 - accuracy: 0.9943
# Epoch 17/1500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0119 - accuracy: 0.9951
# Epoch 18/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0112 - accuracy: 0.9968
# Epoch 19/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0098 - accuracy: 0.9968
# Epoch 20/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0114 - accuracy: 0.9976
# Epoch 21/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0069 - accuracy: 0.9976
# Epoch 22/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0080 - accuracy: 0.9960
# Epoch 23/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 24/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0056 - accuracy: 0.9976
# Epoch 25/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0038 - accuracy: 0.9992
# Epoch 26/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0064 - accuracy: 0.9976
# Epoch 27/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0059 - accuracy: 0.9984
# Epoch 28/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 29/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0035 - accuracy: 0.9992
# Epoch 30/1500
# 20/20 [==============================] - 0s 18ms/step - loss: 0.0134 - accuracy: 0.9935
# Epoch 31/1500
# 20/20 [==============================] - 0s 7ms/step - loss: 0.0166 - accuracy: 0.9951
# Epoch 32/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0111 - accuracy: 0.9968
# Epoch 33/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0283 - accuracy: 0.9911
# Epoch 34/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0128 - accuracy: 0.9943
# Epoch 35/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0047 - accuracy: 1.0000
# Epoch 36/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0166 - accuracy: 0.9960
# Epoch 37/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0261 - accuracy: 0.9919
# Epoch 38/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0125 - accuracy: 0.9951
# Epoch 39/1500
# 20/20 [==============================] - 0s 9ms/step - loss: 0.0077 - accuracy: 0.9984
# Epoch 40/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0047 - accuracy: 0.9992
# Epoch 41/1500
# 20/20 [==============================] - 0s 10ms/step - loss: 0.0201 - accuracy: 0.9927
# Epoch 42/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0082 - accuracy: 0.9976
# Epoch 43/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0044 - accuracy: 0.9992
# Epoch 44/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0028 - accuracy: 0.9992
# Epoch 45/1500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0090 - accuracy: 0.9976
# Epoch 46/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0060 - accuracy: 0.9984
# Epoch 47/1500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0075 - accuracy: 0.9976
# Epoch 48/1500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0044 - accuracy: 0.9976
# Epoch 49/1500
# 20/20 [==============================] - 0s 7ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 50/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 51/1500
# 20/20 [==============================] - 0s 5ms/step - loss: 9.7465e-04 - accuracy: 1.0000
# Epoch 52/1500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0024 - accuracy: 0.9992
# Epoch 53/1500
# 20/20 [==============================] - 0s 7ms/step - loss: 0.0032 - accuracy: 0.9992
# Epoch 54/1500
# 20/20 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 55/1500
# 20/20 [==============================] - 0s 7ms/step - loss: 0.0039 - accuracy: 0.9984
# Epoch 56/1500
# 20/20 [==============================] - 0s 7ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 57/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0091 - accuracy: 0.9960
# Epoch 58/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0080 - accuracy: 0.9968
# Epoch 59/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0094 - accuracy: 0.9976
# Epoch 60/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0044 - accuracy: 0.9976
# Epoch 61/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0072 - accuracy: 0.9976
# Epoch 62/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0019 - accuracy: 0.9992
# Epoch 63/1500
# 20/20 [==============================] - 0s 7ms/step - loss: 0.0060 - accuracy: 0.9984
# Epoch 64/1500
# 20/20 [==============================] - 0s 7ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 65/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0029 - accuracy: 0.9984
# Epoch 66/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0042 - accuracy: 0.9992
# Epoch 67/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0057 - accuracy: 0.9976
# Epoch 68/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0021 - accuracy: 0.9992
# Epoch 69/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0085 - accuracy: 0.9968
# Epoch 70/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0095 - accuracy: 0.9951
# Epoch 71/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0037 - accuracy: 0.9984
# Epoch 72/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0072 - accuracy: 0.9968
# Epoch 73/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0022 - accuracy: 0.9992
# Epoch 74/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0028 - accuracy: 0.9992
# Epoch 75/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 76/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0039 - accuracy: 0.9984
# Epoch 77/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0041 - accuracy: 0.9992
# Epoch 78/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0017 - accuracy: 0.9992
# Epoch 79/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0037 - accuracy: 0.9992
# Epoch 80/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 9.5741e-04 - accuracy: 1.0000
# Epoch 81/1500
# 19/20 [===========================>..] - ETA: 0s - loss: 8.6424e-04 - accuracy: 1.0000Restoring model weights from the end of the best epoch: 51.
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 81: early stopping
# 9/9 [==============================] - 0s 2ms/step - loss: 3.5010 - accuracy: 0.5766
# 9/9 [==============================] - 0s 1ms/step
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Majority Vote Accuracy for cat_id for this fold: 0.73 (22/30)
# Before appending - Cat IDs: 412, Predictions: 412, Actuals: 412, Gender: 412
# After appending - Cat IDs: 686, Predictions: 686, Actuals: 686, Gender: 686
# Final Test Results - Loss: 3.5009548664093018, Accuracy: 0.5766423344612122, Precision: 0.41276803118908384, Recall: 0.4194862112836115, F1 Score: 0.41589416949326746
# Confusion Matrix:
#  [[135   8  51]
#  [  7   3   1]
#  [ 48   1  20]]
# outer_fold 4
# Train Set Group Distribution:
# 046A    66
# 002B    36
# 103A    33
# 047A    30
# 057A    28
# 020A    23
# 067A    20
# 059A    18
# 029A    17
# 019A    17
# 101A    16
# 106A    15
# 001A    15
# 028A    14
# 042A    14
# 111A    13
# 002A    13
# 039A    12
# 051A    12
# 116A    12
# 068A    11
# 005A    11
# 036A    11
# 025A    11
# 063A    11
# 016A    11
# 015A    10
# 014B    10
# 071A    10
# 045A     9
# 022A     9
# 065A     9
# 033A     9
# 013B     8
# 094A     8
# 095A     8
# 117A     7
# 099A     7
# 050A     7
# 007A     6
# 109A     6
# 108A     6
# 008A     6
# 021A     6
# 037A     6
# 070A     5
# 023B     5
# 062A     5
# 034A     5
# 012A     5
# 075A     5
# 044A     5
# 105A     4
# 009A     4
# 035A     4
# 104A     4
# 052A     4
# 060A     3
# 064A     3
# 006A     3
# 113A     3
# 058A     3
# 014A     3
# 093A     2
# 032A     2
# 054A     2
# 102A     2
# 038A     2
# 061A     2
# 087A     2
# 066A     2
# 018A     2
# 069A     2
# 004A     1
# 019B     1
# 076A     1
# 092A     1
# 096A     1
# 048A     1
# 049A     1
# 024A     1
# 091A     1
# 090A     1
# 026C     1
# 100A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 000A    39
# 074A    25
# 000B    20
# 055A    20
# 097A    16
# 097B    14
# 040A    10
# 072A     9
# 051B     9
# 010A     8
# 031A     7
# 027A     7
# 053A     7
# 023A     6
# 025C     6
# 026A     4
# 003A     4
# 011A     3
# 056A     3
# 025B     2
# 110A     1
# 043A     1
# 088A     1
# 073A     1
# 041A     1
# 115A     1
# 026B     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    298
# M    289
# F    155
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# F    102
# M     67
# X     57
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [002A, 028A, 070A, 033A, 071A, 020A, 015A, 065...
# kitten    [046A, 042A, 014B, 109A, 047A, 049A, 045A, 048...
# senior    [117A, 106A, 057A, 090A, 113A, 116A, 051A, 024...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [000B, 000A, 026A, 053A, 072A, 010A, 074A, 031...
# kitten                       [110A, 040A, 043A, 041A, 115A]
# senior                       [051B, 097A, 055A, 011A, 056A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 57, 'kitten': 11, 'senior': 17}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 17, 'kitten': 5, 'senior': 5}
# Unique Training/Validation Group IDs:
# ['001A' '002A' '002B' '004A' '005A' '006A' '007A' '008A' '009A' '012A'
#  '013B' '014A' '014B' '015A' '016A' '018A' '019A' '019B' '020A' '021A'
#  '022A' '023B' '024A' '025A' '026C' '028A' '029A' '032A' '033A' '034A'
#  '035A' '036A' '037A' '038A' '039A' '042A' '044A' '045A' '046A' '047A'
#  '048A' '049A' '050A' '051A' '052A' '054A' '057A' '058A' '059A' '060A'
#  '061A' '062A' '063A' '064A' '065A' '066A' '067A' '068A' '069A' '070A'
#  '071A' '075A' '076A' '087A' '090A' '091A' '092A' '093A' '094A' '095A'
#  '096A' '099A' '100A' '101A' '102A' '103A' '104A' '105A' '106A' '108A'
#  '109A' '111A' '113A' '116A' '117A']
# Unique Test Group IDs:
# ['000A' '000B' '003A' '010A' '011A' '023A' '025B' '025C' '026A' '026B'
#  '027A' '031A' '040A' '041A' '043A' '051B' '053A' '055A' '056A' '072A'
#  '073A' '074A' '088A' '097A' '097B' '110A' '115A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'000A'}
# Removed from Training/Validation Set:
# {'038A'}
# Moved to Test Set:
# {'038A'}
# Removed from Test Set
# {'000A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '001A' '002A' '002B' '004A' '005A' '006A' '007A' '008A' '009A'
#  '012A' '013B' '014A' '014B' '015A' '016A' '018A' '019A' '019B' '020A'
#  '021A' '022A' '023B' '024A' '025A' '026C' '028A' '029A' '032A' '033A'
#  '034A' '035A' '036A' '037A' '039A' '042A' '044A' '045A' '046A' '047A'
#  '048A' '049A' '050A' '051A' '052A' '054A' '057A' '058A' '059A' '060A'
#  '061A' '062A' '063A' '064A' '065A' '066A' '067A' '068A' '069A' '070A'
#  '071A' '075A' '076A' '087A' '090A' '091A' '092A' '093A' '094A' '095A'
#  '096A' '099A' '100A' '101A' '102A' '103A' '104A' '105A' '106A' '108A'
#  '109A' '111A' '113A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['000B' '003A' '010A' '011A' '023A' '025B' '025C' '026A' '026B' '027A'
#  '031A' '038A' '040A' '041A' '043A' '051B' '053A' '055A' '056A' '072A'
#  '073A' '074A' '088A' '097A' '097B' '110A' '115A']
# Length of X_train_val:
# 779
# Length of y_train_val:
# 779
# Length of groups_train_val:
# 779
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     445
# kitten    162
# senior    135
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     161
# senior     51
# kitten     14
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     482
# kitten    162
# senior    135
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     124
# senior     51
# kitten     14
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 482, 1: 162, 2: 135})
# Epoch 1/1500
# 23/23 [==============================] - 1s 6ms/step - loss: 0.8200 - accuracy: 0.7075
# Epoch 2/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.2933 - accuracy: 0.8997
# Epoch 3/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.1555 - accuracy: 0.9433
# Epoch 4/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0931 - accuracy: 0.9675
# Epoch 5/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0761 - accuracy: 0.9716
# Epoch 6/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0742 - accuracy: 0.9710
# Epoch 7/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0501 - accuracy: 0.9834
# Epoch 8/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0359 - accuracy: 0.9889
# Epoch 9/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0337 - accuracy: 0.9889
# Epoch 10/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0318 - accuracy: 0.9910
# Epoch 11/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0279 - accuracy: 0.9910
# Epoch 12/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0207 - accuracy: 0.9959
# Epoch 13/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0176 - accuracy: 0.9931
# Epoch 14/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0135 - accuracy: 0.9972
# Epoch 15/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0165 - accuracy: 0.9945
# Epoch 16/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0166 - accuracy: 0.9945
# Epoch 17/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0197 - accuracy: 0.9924
# Epoch 18/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0124 - accuracy: 0.9972
# Epoch 19/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0073 - accuracy: 0.9965
# Epoch 20/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0128 - accuracy: 0.9965
# Epoch 21/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0106 - accuracy: 0.9952
# Epoch 22/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0134 - accuracy: 0.9959
# Epoch 23/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0080 - accuracy: 0.9979
# Epoch 24/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0115 - accuracy: 0.9952
# Epoch 25/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0084 - accuracy: 0.9952
# Epoch 26/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0078 - accuracy: 0.9965
# Epoch 27/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0091 - accuracy: 0.9959
# Epoch 28/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0049 - accuracy: 0.9993
# Epoch 29/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0109 - accuracy: 0.9965
# Epoch 30/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0164 - accuracy: 0.9959
# Epoch 31/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0115 - accuracy: 0.9945
# Epoch 32/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0069 - accuracy: 0.9972
# Epoch 33/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0046 - accuracy: 0.9979
# Epoch 34/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0108 - accuracy: 0.9965
# Epoch 35/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0079 - accuracy: 0.9972
# Epoch 36/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0072 - accuracy: 0.9986
# Epoch 37/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0087 - accuracy: 0.9979
# Epoch 38/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0090 - accuracy: 0.9972
# Epoch 39/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0081 - accuracy: 0.9986
# Epoch 40/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0067 - accuracy: 0.9972
# Epoch 41/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0029 - accuracy: 0.9993
# Epoch 42/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0029 - accuracy: 0.9993
# Epoch 43/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0068 - accuracy: 0.9972
# Epoch 44/1500
# 23/23 [==============================] - 0s 9ms/step - loss: 0.0049 - accuracy: 0.9979
# Epoch 45/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0028 - accuracy: 0.9993
# Epoch 46/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0051 - accuracy: 0.9979
# Epoch 47/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0042 - accuracy: 0.9986
# Epoch 48/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0037 - accuracy: 0.9986
# Epoch 49/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0050 - accuracy: 0.9986
# Epoch 50/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0040 - accuracy: 0.9986
# Epoch 51/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0118 - accuracy: 0.9965
# Epoch 52/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0048 - accuracy: 0.9986
# Epoch 53/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0086 - accuracy: 0.9959
# Epoch 54/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0075 - accuracy: 0.9986
# Epoch 55/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0044 - accuracy: 0.9993
# Epoch 56/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0039 - accuracy: 0.9986
# Epoch 57/1500
# 23/23 [==============================] - 0s 15ms/step - loss: 0.0070 - accuracy: 0.9972
# Epoch 58/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0036 - accuracy: 0.9993
# Epoch 59/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0037 - accuracy: 0.9993
# Epoch 60/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0029 - accuracy: 0.9993
# Epoch 61/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 62/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 63/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0037 - accuracy: 0.9993
# Epoch 64/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0088 - accuracy: 0.9972
# Epoch 65/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 66/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0042 - accuracy: 0.9986
# Epoch 67/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 7.3343e-04 - accuracy: 1.0000
# Epoch 68/1500
# 23/23 [==============================] - 0s 8ms/step - loss: 6.0494e-04 - accuracy: 1.0000
# Epoch 69/1500
# 23/23 [==============================] - 0s 10ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 70/1500
# 23/23 [==============================] - 0s 8ms/step - loss: 9.6372e-04 - accuracy: 1.0000
# Epoch 71/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0025 - accuracy: 0.9993
# Epoch 72/1500
# 23/23 [==============================] - 0s 8ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 73/1500
# 23/23 [==============================] - 0s 9ms/step - loss: 7.0105e-04 - accuracy: 1.0000
# Epoch 74/1500
# 23/23 [==============================] - 0s 10ms/step - loss: 5.6166e-04 - accuracy: 1.0000
# Epoch 75/1500
# 23/23 [==============================] - 0s 9ms/step - loss: 2.2991e-04 - accuracy: 1.0000
# Epoch 76/1500
# 23/23 [==============================] - 0s 8ms/step - loss: 7.2117e-04 - accuracy: 1.0000
# Epoch 77/1500
# 23/23 [==============================] - 0s 10ms/step - loss: 2.6802e-04 - accuracy: 1.0000
# Epoch 78/1500
# 23/23 [==============================] - 0s 9ms/step - loss: 0.0015 - accuracy: 0.9993
# Epoch 79/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 6.7157e-04 - accuracy: 1.0000
# Epoch 80/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0025 - accuracy: 0.9986
# Epoch 81/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0032 - accuracy: 0.9993
# Epoch 82/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0055 - accuracy: 0.9979
# Epoch 83/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0141 - accuracy: 0.9945
# Epoch 84/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0121 - accuracy: 0.9979
# Epoch 85/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0053 - accuracy: 0.9986
# Epoch 86/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0102 - accuracy: 0.9965
# Epoch 87/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0220 - accuracy: 0.9938
# Epoch 88/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0171 - accuracy: 0.9931
# Epoch 89/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0106 - accuracy: 0.9972
# Epoch 90/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0077 - accuracy: 0.9979
# Epoch 91/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0153 - accuracy: 0.9952
# Epoch 92/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0059 - accuracy: 0.9979
# Epoch 93/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0080 - accuracy: 0.9965
# Epoch 94/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0109 - accuracy: 0.9959
# Epoch 95/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0068 - accuracy: 0.9972
# Epoch 96/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0040 - accuracy: 0.9986
# Epoch 97/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 98/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0019 - accuracy: 0.9993
# Epoch 99/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0022 - accuracy: 0.9993
# Epoch 100/1500
# 23/23 [==============================] - 0s 8ms/step - loss: 0.0030 - accuracy: 0.9993
# Epoch 101/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 102/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0064 - accuracy: 0.9979
# Epoch 103/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0020 - accuracy: 0.9993
# Epoch 104/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0050 - accuracy: 0.9979
# Epoch 105/1500
# 18/23 [======================>.......] - ETA: 0s - loss: 0.0037 - accuracy: 0.9991  Restoring model weights from the end of the best epoch: 75.
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0061 - accuracy: 0.9986
# Epoch 105: early stopping
# 6/6 [==============================] - 0s 2ms/step - loss: 4.1543 - accuracy: 0.6561
# 6/6 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.81 (22/27)
# Before appending - Cat IDs: 686, Predictions: 686, Actuals: 686, Gender: 686
# After appending - Cat IDs: 875, Predictions: 875, Actuals: 875, Gender: 875
# Final Test Results - Loss: 4.154326438903809, Accuracy: 0.6560846567153931, Precision: 0.5512820512820512, Recall: 0.5676335050149092, F1 Score: 0.5157212885154062
# Confusion Matrix:
#  [[108   9   7]
#  [  4  10   0]
#  [ 44   1   6]]
#
# Final Average F1-Score across all UNSEEN TEST sets: 0.46992262957979747
#
# Final Average Loss across all UNSEEN TEST sets: 4.654032289981842
#
# Final Average Accuracy across all UNSEEN TEST sets: 0.6140839159488678
#
# Final Average Precision across all UNSEEN TEST sets: 0.5006446149272974
#
# Final Average Recall across all UNSEEN TEST sets: 0.4844866031672692

# %%
seed_2_folds_values = (unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1)

# Plotting all fold metrics
seed_2_folds_plot = plot_all_metrics(unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1, "Folds", "Fold Number")

# %% [markdown]
# ## Majority Voting on Total Entries per cat_id

# %%
# Debugging print statements
print(f'Checking - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
# Out:
# Checking - Cat IDs: 875, Predictions: 875, Actuals: 875, Gender: 875

# %%
# Create results df
full_results = pd.DataFrame({
    'cat_id': all_cat_ids,
    'predicted_age_group': all_predicted_age_groups,
    'actual_age_group': all_actual_age_groups,
    'all_gender': all_gender
})

# create a correct majority prediction column
full_results['correct'] = full_results['predicted_age_group'] == full_results['actual_age_group']

# %%
# Group by cat_id and aggregate predicted age groups
majority_votes = full_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first()

# Calculate the accuracy of majority voting
correct_predictions = (majority_votes == actual_groups).sum()
total_cats = len(actual_groups)
majority_vote_accuracy = correct_predictions / total_cats

logger(f"Overall Majority Vote Accuracy for cat_id: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

# store for final evaluation 
all_majority_vote_accuracies.append(majority_vote_accuracy)
# Out:
# Overall Majority Vote Accuracy for cat_id: 0.75 (83/110)

# %%
# Detailed df with predictions, actual labels, and comparison including majority vote
detailed_results = full_results.groupby('cat_id').apply(
    lambda x: pd.Series({
        'Predictions': list(x['predicted_age_group']),
        'Majority Vote': x['predicted_age_group'].mode()[0],
        'Actual Age Group': x['actual_age_group'].iloc[0],
        'Correct Majority Vote': x['predicted_age_group'].mode()[0] == x['actual_age_group'].iloc[0]
    })
).reset_index()

# Convert to DataFrame for better formatting and display
detailed_results = pd.DataFrame(detailed_results)

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 10)
pd.set_option('display.width', 1000)

sorted_detailed_results = detailed_results.sort_values(by='Correct Majority Vote', ascending=False)

# Display the sorted DataFrame
sorted_detailed_results
# Out:
#     cat_id                                        Predictions Majority Vote Actual Age Group  Correct Majority Vote
# 0     000B  [adult, adult, adult, senior, adult, adult, ki...         adult            adult                   True
# 100   105A                      [adult, adult, adult, kitten]         adult            adult                   True
# 65    059A  [senior, adult, senior, senior, adult, senior,...        senior           senior                   True
# 94    099A  [kitten, adult, adult, kitten, adult, adult, a...         adult            adult                   True
# 95    100A                                            [adult]         adult            adult                   True
# 96    101A  [senior, adult, adult, adult, adult, senior, s...         adult            adult                   True
# 97    102A                                    [senior, adult]         adult            adult                   True
# 98    103A  [adult, adult, adult, adult, senior, adult, ad...         adult            adult                   True
# 59    053A  [adult, adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 58    052A                       [adult, adult, adult, adult]         adult            adult                   True
# 54    049A                                           [kitten]        kitten           kitten                   True
# 42    036A  [senior, senior, adult, adult, adult, adult, a...         adult            adult                   True
# 53    048A                                           [kitten]        kitten           kitten                   True
# 51    045A  [kitten, adult, kitten, kitten, kitten, kitten...        kitten           kitten                   True
# 49    043A                                           [kitten]        kitten           kitten                   True
# 104   110A                                           [kitten]        kitten           kitten                   True
# 47    041A                                           [kitten]        kitten           kitten                   True
# 46    040A  [kitten, adult, adult, kitten, kitten, adult, ...        kitten           kitten                   True
# 45    039A  [senior, senior, adult, adult, adult, adult, a...         adult            adult                   True
# 90    095A  [adult, adult, adult, senior, adult, adult, ad...         adult            adult                   True
# 66    060A                              [adult, adult, adult]         adult            adult                   True
# 93    097B  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 68    062A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 69    063A  [kitten, adult, kitten, kitten, kitten, adult,...         adult            adult                   True
# 87    092A                                            [adult]         adult            adult                   True
# 86    091A                                            [adult]         adult            adult                   True
# 85    090A                                           [senior]        senior           senior                   True
# 84    088A                                            [adult]         adult            adult                   True
# 83    087A                                     [adult, adult]         adult            adult                   True
# 81    075A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 80    074A  [kitten, kitten, adult, adult, adult, adult, a...         adult            adult                   True
# 79    073A                                            [adult]         adult            adult                   True
# 78    072A  [adult, adult, senior, adult, adult, adult, ad...         adult            adult                   True
# 77    071A  [adult, senior, adult, adult, senior, senior, ...         adult            adult                   True
# 76    070A              [adult, senior, adult, adult, senior]         adult            adult                   True
# 75    069A                                    [senior, adult]         adult            adult                   True
# 74    068A  [senior, adult, senior, adult, adult, adult, a...         adult            adult                   True
# 73    067A  [adult, adult, kitten, adult, adult, adult, ad...         adult            adult                   True
# 72    066A                                    [adult, senior]         adult            adult                   True
# 71    065A  [adult, adult, adult, kitten, adult, kitten, k...         adult            adult                   True
# 70    064A                              [adult, adult, adult]         adult            adult                   True
# 43    037A       [kitten, adult, adult, adult, adult, senior]         adult            adult                   True
# 44    038A                     [adult, kitten, adult, kitten]         adult            adult                   True
# 41    035A                      [adult, adult, senior, adult]         adult            adult                   True
# 23    021A         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 21    019B                                            [adult]         adult            adult                   True
# 20    019A  [adult, kitten, kitten, adult, adult, adult, a...         adult            adult                   True
# 19    018A                                     [adult, adult]         adult            adult                   True
# 106   113A                           [senior, senior, senior]        senior           senior                   True
# 17    015A  [adult, adult, adult, adult, adult, adult, sen...         adult            adult                   True
# 107   115A                                           [kitten]        kitten           kitten                   True
# 15    014A                              [adult, adult, adult]         adult            adult                   True
# 14    013B  [adult, adult, adult, adult, kitten, adult, ad...         adult            adult                   True
# 13    012A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 11    010A  [adult, adult, adult, senior, adult, adult, ad...         adult            adult                   True
# 10    009A                     [senior, adult, senior, adult]         adult            adult                   True
# 9     008A         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 8     007A         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 7     006A                              [adult, adult, adult]         adult            adult                   True
# 6     005A  [adult, adult, adult, adult, senior, adult, se...         adult            adult                   True
# 5     004A                                            [adult]         adult            adult                   True
# 4     003A                      [kitten, adult, adult, adult]         adult            adult                   True
# 3     002B  [kitten, adult, adult, senior, senior, senior,...         adult            adult                   True
# 2     002A  [adult, kitten, adult, adult, adult, adult, se...         adult            adult                   True
# 40    034A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 22    020A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 24    022A  [adult, adult, kitten, adult, adult, adult, se...         adult            adult                   True
# 25    023A       [adult, kitten, senior, adult, adult, adult]         adult            adult                   True
# 39    033A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 38    032A                                     [adult, adult]         adult            adult                   True
# 37    031A  [adult, adult, adult, adult, kitten, adult, se...         adult            adult                   True
# 36    029A  [senior, senior, adult, adult, senior, adult, ...         adult            adult                   True
# 35    028A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 34    027A  [adult, adult, senior, adult, adult, senior, a...         adult            adult                   True
# 33    026C                                            [adult]         adult            adult                   True
# 32    026B                                            [adult]         adult            adult                   True
# 31    026A                       [adult, adult, adult, adult]         adult            adult                   True
# 30    025C         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 29    025B                                     [adult, adult]         adult            adult                   True
# 28    025A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 105   111A  [adult, kitten, kitten, kitten, kitten, kitten...        kitten           kitten                   True
# 26    023B              [adult, adult, senior, adult, senior]         adult            adult                   True
# 91    096A                                            [adult]         adult            adult                   True
# 108   116A  [senior, adult, adult, adult, adult, senior, s...         adult           senior                  False
# 101   106A  [adult, adult, adult, adult, adult, adult, adu...         adult           senior                  False
# 102   108A        [adult, adult, adult, senior, adult, adult]         adult           senior                  False
# 99    104A                      [senior, adult, adult, adult]         adult           senior                  False
# 103   109A        [adult, adult, kitten, adult, adult, adult]         adult           kitten                  False
# 92    097A  [adult, adult, senior, adult, adult, adult, ad...         adult           senior                  False
# 55    050A  [kitten, kitten, adult, adult, adult, kitten, ...         adult           kitten                  False
# 89    094A  [adult, senior, adult, senior, adult, senior, ...         adult           senior                  False
# 88    093A                                     [adult, adult]         adult           senior                  False
# 12    011A                              [adult, adult, adult]         adult           senior                  False
# 16    014B  [kitten, adult, adult, kitten, adult, kitten, ...         adult           kitten                  False
# 18    016A  [adult, adult, adult, adult, kitten, adult, se...         adult           senior                  False
# 27    024A                                            [adult]         adult           senior                  False
# 48    042A  [senior, adult, kitten, adult, adult, adult, k...         adult           kitten                  False
# 50    044A              [kitten, adult, adult, kitten, adult]         adult           kitten                  False
# 52    047A  [adult, adult, adult, adult, adult, adult, adu...         adult           kitten                  False
# 1     001A  [adult, senior, adult, senior, senior, senior,...        senior            adult                  False
# 56    051A  [adult, adult, adult, adult, adult, adult, adu...         adult           senior                  False
# 57    051B  [adult, adult, adult, senior, adult, senior, a...         adult           senior                  False
# 60    054A                                     [adult, adult]         adult           senior                  False
# 61    055A  [adult, adult, adult, adult, adult, senior, ad...         adult           senior                  False
# 62    056A                              [adult, adult, adult]         adult           senior                  False
# 63    057A  [adult, adult, adult, adult, adult, adult, adu...         adult           senior                  False
# 64    058A                             [senior, adult, adult]         adult           senior                  False
# 67    061A                                     [adult, adult]         adult           senior                  False
# 82    076A                                           [kitten]        kitten            adult                  False
# 109   117A  [senior, adult, adult, senior, adult, senior, ...         adult           senior                  False

# %%
# Create df for majority votes
majority_df = majority_votes.reset_index()
majority_df.columns = ['cat_id', 'Majority_Vote']

# Get actual groups for each cat_id
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first().reset_index()

# Merge majority votes with actual groups
majority_with_actual = pd.merge(majority_df, actual_groups, on='cat_id')

# Add a column to check if the majority vote was correct
majority_with_actual['Majority_Correct'] = majority_with_actual['Majority_Vote'] == majority_with_actual['actual_age_group']

# Count correct majority votes per class
correct_majority_votes_per_class = majority_with_actual.groupby('actual_age_group')['Majority_Correct'].sum()

print("Correct Majority Votes per Class:")
print(correct_majority_votes_per_class)
# Out:
# Correct Majority Votes per Class:
# actual_age_group
# adult     71
# kitten     9
# senior     3
# Name: Majority_Correct, dtype: int64

# %%
# Calculate the total count and the number of correct predictions for each class
class_stats = majority_with_actual.groupby('actual_age_group').agg(
    total_count=('Majority_Correct', 'size'),  # Total number of cases per class
    correct_count=('Majority_Correct', 'sum')  # Sum of correct predictions per class
).reset_index()

# Calculate accuracy for each class
class_stats['accuracy'] = class_stats['correct_count'] / class_stats['total_count'] * 100

# store for final evaluation 
all_majority_vote_details.append(class_stats)

# Log detailed stats
print("Detailed Class Statistics for Majority Votes:")
print(class_stats)
# Out:
# Detailed Class Statistics for Majority Votes:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult           73             71  97.260274
# 1           kitten           15              9  60.000000
# 2           senior           22              3  13.636364

# %%
# Plot for Detailed Class Statistics for Majority Votes
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Accuracy of Majority Votes by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Detailed Class Statistics

# %%
# Calculate the total count and the number of correct predictions for each class
class_stats = full_results.groupby('actual_age_group').agg(
    total_count=('correct', 'size'),
    correct_count=('correct', 'sum')
).reset_index()

# Calculate accuracy for each class
class_stats['accuracy'] = class_stats['correct_count'] / class_stats['total_count'] * 100

# store for final evaluation 
all_class_stats.append(class_stats)

# Log the detailed stats
print("Detailed Class Statistics:")
print(class_stats)
# Out:
# Detailed Class Statistics:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult          569            446  78.383128
# 1           kitten          120             45  37.500000
# 2           senior          186             44  23.655914

# %%
# Plot for Detailed Class Statistics (Overall)
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Overall Accuracy by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Gender Exploration

# %%
# Group by gender and calculate the total count, correct predictions, and accuracy
gender_stats = full_results.groupby('all_gender').agg(
    count=('cat_id', 'size'),  # Total number of cases per gender
    correct=('correct', 'sum')  # Sum of correct predictions per gender
).reset_index()

# Calculate accuracy for each gender
gender_stats['accuracy'] = (gender_stats['correct'] / gender_stats['count'] * 100).round(2)

# Display the DataFrame
print("Accuracy by Gender:")
print(gender_stats)

# store for final evaluation 
all_gender_stats.append(gender_stats)
# Out:
# Accuracy by Gender:
#   all_gender  count  correct  accuracy
# 0          F    220      133     60.45
# 1          M    356      253     71.07
# 2          X    299      149     49.83

# %%
# Plot for Accuracy by Gender
styled_barplot(gender_stats, 'all_gender', 'accuracy', 
               'Accuracy by Gender', 
               'Gender', 'Accuracy (%)')

# %% [markdown]
# ### Log current total CV Stats

# %%
print("Total Majority Vote Accuracy so far:", all_majority_vote_accuracies)
print("Total Class Statistics so far:\n", all_class_stats)
print("Total Gender Accuracy so far:\n", all_gender_stats)
# Out:
# Total Majority Vote Accuracy so far: [0.7727272727272727, 0.7545454545454545]
# Total Class Statistics so far:
#  [  actual_age_group  total_count  correct_count   accuracy
# 0            adult          573            489  85.340314
# 1           kitten          111             57  51.351351
# 2           senior          186             61  32.795699,   actual_age_group  total_count  correct_count   accuracy
# 0            adult          569            446  78.383128
# 1           kitten          120             45  37.500000
# 2           senior          186             44  23.655914]
# Total Gender Accuracy so far:
#  [  all_gender  count  correct  accuracy
# 0          F    218      150     68.81
# 1          M    362      279     77.07
# 2          X    290      178     61.38,   all_gender  count  correct  accuracy
# 0          F    220      133     60.45
# 1          M    356      253     71.07
# 2          X    299      149     49.83]

# %% [markdown]
# # RANDOM SEED 3

# %%
# Set a fixed random seed for reproducibility
random.seed(int(random_seeds[2]))
np.random.seed(int(random_seeds[2]))
tf.random.set_seed(int(random_seeds[2]))

# Load datasets
dataframe = pd.read_csv('/Users/astrid/PycharmProjects/data-aug-and-more/yamnet-tfhub-extraction/yamnet_embeddings_looped_april_23.csv')

def assign_age_group(age, age_groups):
    for group_name, age_range in age_groups.items():
        if age_range[0] <= age < age_range[1]:
            return group_name
    return 'Unknown'  # For any age that doesn't fit the defined groups

# Define age groups
age_groups = {
    'kitten': (0, 0.5),
    'adult': (0.5, 12),
    'senior': (12, 20)
}

# Create a new column for the age group
dataframe['age_group'] = dataframe['target'].apply(assign_age_group, age_groups=age_groups)

print(dataframe['age_group'].value_counts())
# Out:
# adult     606
# senior    186
# kitten    176
# Name: age_group, dtype: int64

# %%
# Separate features and labels
X = dataframe.iloc[:, :-4].values  # all columns except the last four

# Encode the 'age_group' column as integers using LabelEncoder
label_encoder = LabelEncoder()
encoded_y = label_encoder.fit_transform(dataframe['age_group'].values)

# Use the encoded labels for splitting and one-hot encoding
y = encoded_y  

# Convert 'cat_id' column to numpy array to be used as groups array for GroupKFold
groups = dataframe['cat_id'].values

# %%
tf.keras.backend.clear_session()

# %% [markdown]
# ## Run Setup

# %%
all_cat_ids = []
all_predicted_age_groups = []
all_actual_age_groups = []
all_gender = []

# Define the StratifiedGroupKFold splitter for 4 fold CV with random shuffling
outer_cv = StratifiedGroupKFold(n_splits=4, shuffle=True, random_state=int(random_seeds[2]))

# unseen test set metrics
unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1 = [], [], [], [], []

outer_fold = 0

# Use the splitter to generate indices for training and testing sets
# Note: GroupShuffleSplit.split returns indices, so we use it to index the arrays
for train_val_idx, test_idx in outer_cv.split(X, y, groups):
    outer_fold += 1
    logger(f"outer_fold {outer_fold}", file=log_file_path)

    # Convert indices back to DataFrame for easy manipulation
    df_train_val = dataframe.iloc[train_val_idx]
    df_test = dataframe.iloc[test_idx]

    ##############################
    # ASSESSING SPLITS BY CAT_ID #
    ##############################
    
    # Get the distribution of groups
    training_validation_group_distribution = df_train_val['cat_id'].value_counts()  
    testing_group_distribution = df_test['cat_id'].value_counts()  
    
    # Log or print the distribution
    logger(f"Train Set Group Distribution:\n{training_validation_group_distribution}", file=log_file_path)
    logger(f"Testing Set Group Distribution:\n{testing_group_distribution}", file=log_file_path)

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val['gender'].value_counts()
    testing_gender_distribution = df_test['gender'].value_counts()
    
    # Log the distribution
    logger(f"Training Set Gender Distribution BEFORE SWAP:\n{training_gender_distribution}", file=log_file_path)
    logger(f"Testing Set Gender Distribution BEFORE SWAP:\n{testing_gender_distribution}", file=log_file_path)

    # Group by 'age_group' and then list unique 'cat_id' within each age group
    unique_cat_ids_per_age_group_train_val = df_train_val.groupby('age_group')['cat_id'].unique()
    unique_cat_ids_per_age_group_test = df_test.groupby('age_group')['cat_id'].unique()
    
    # Log results
    logger(f"Unique Cat IDs per Age Group in Training/Validation Set:\n{unique_cat_ids_per_age_group_train_val}", file=log_file_path)
    logger(f"Unique Cat IDs per Age Group in Testing Set:\n{unique_cat_ids_per_age_group_test}", file=log_file_path)

    # Calculate the count of unique identifiers per age group for training and testing set
    counts_train_val = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_train_val.items()}
    counts_test = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_test.items()}

    # Log the counts of unique identifiers per age group
    logger(f"Count of Unique Cat IDs per Age Group in Training/Validation Set:\n{counts_train_val}", file=log_file_path)
    logger(f"Count of Unique Cat IDs per Age Group in Testing Set:\n{counts_test}", file=log_file_path)

    #######################################################
    # CONTINUE WITH ENSURING VALID AND APPROPRIATE SPLITS #
    #######################################################
    
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    groups_train_val, groups_test = groups[train_val_idx], groups[test_idx]

    # logging identifier splits 
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)

    # check group splits
    check_initial_group_split(groups_train_val, groups_test)

    # Specify the cat_ids that must be in the training/validation set
    specific_cat_ids = ['000A', '046A']
    
    # Perform the swapping operation
    train_val_idx, test_idx = swap_cat_id_instances(dataframe, train_val_idx, test_idx, specific_cat_ids)
    
    # Re-assign the sets based on the updated indices
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    new_groups_train_val, new_groups_test = groups[train_val_idx], groups[test_idx]

    # Find differences for training and test sets
    moved_to_train_val, removed_from_train_val = find_group_differences(groups_train_val, new_groups_train_val)
    moved_to_test, removed_from_test = find_group_differences(groups_test, new_groups_test)
    
    # Display the results
    logger(f"Moved to Training/Validation Set:\n{moved_to_train_val}", file=log_file_path)
    logger(f"Removed from Training/Validation Set:\n{removed_from_train_val}", file=log_file_path)
    logger(f"Moved to Test Set:\n{moved_to_test}", file=log_file_path)
    logger(f"Removed from Test Set\n{removed_from_test}", file=log_file_path)

    # Update X_train_val, X_test, y_train_val, y_test, groups_train_val, groups_test based on updated indices
    X_train_val = X[train_val_idx]
    y_train_val = y[train_val_idx]
    groups_train_val = groups[train_val_idx]
    
    X_test = X[test_idx]
    y_test = y[test_idx]
    groups_test = groups[test_idx]

    # logging identifier splits again after potential swaps
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"AFTER SWAP - Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"AFTER SWAP - Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)
    
    # Verify the lengths are consistent
    logger(f"Length of X_train_val:\n{len(X_train_val)}", file=log_file_path)
    logger(f"Length of y_train_val:\n{len(y_train_val)}", file=log_file_path)
    logger(f"Length of groups_train_val:\n{len(groups_train_val)}", file=log_file_path)

    # Check group splits once more
    check_initial_group_split(groups_train_val, groups_test)

    # Convert the modified indices back to a DataFrame representing the updated df_train_val
    df_train_val_updated = dataframe.iloc[train_val_idx].copy()
    df_test_updated = dataframe.iloc[test_idx].copy()

    ############################
    # LOGGING AGE GROUP SPLITS #
    ############################

    # Get the distribution of age groups of age groups before the update
    training_validation_age_group_distribution = df_train_val['age_group'].value_counts()
    testing_age_group_distribution = df_test['age_group'].value_counts()
    
    # Logthe distribution
    logger(f"Train Age Group Distribution BEFORE SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution BEFORE SWAP:\n{testing_age_group_distribution}", file=log_file_path)

    # Get the distribution of age groups after the update
    training_validation_age_group_distribution = df_train_val_updated['age_group'].value_counts()
    testing_age_group_distribution = df_test_updated['age_group'].value_counts()
    
    # Log the distribution
    logger(f"Train Age Group Distribution AFTER SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution AFTER SWAP:\n{testing_age_group_distribution}", file=log_file_path)
    
    ########################################################
    # TRACKING FINAL CAT_IDs & GENDER AFTER REDISTRIBUTION #
    ########################################################

    # Get the distribution of groups
    training_validation_group_distribution = df_train_val_updated['cat_id'].value_counts()  
    testing_group_distribution = df_test_updated['cat_id'].value_counts()  

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val_updated['gender'].value_counts()
    testing_gender_distribution = df_test_updated['gender'].value_counts()
    
    logger(f"\n Starting training on unseen test set\n", file=log_file_path)

    ###################
    # PREPARING MODEL #
    ###################

    # Calculate the distribution of age groups in y_train_val
    age_group_distribution = Counter(y_train_val)
    print("Age group distribution:", age_group_distribution)

    # EarlyStopping callback: monitor 'loss' instead of 'val_loss' for the test set
    early_stopping = EarlyStopping(
        monitor='loss',  
        min_delta=0.001, 
        patience=30,  
        verbose=1,  
        restore_best_weights=True  
    )

    # Apply SMOTE to the training data only
    smote = SMOTE()
    X_train_val, y_train_val = smote.fit_resample(X_train_val, y_train_val)

    # One final shuffle to ensure randomness
    outer_shuffle_idx = np.random.permutation(len(X_train_val))
    X_train_val = X_train_val[outer_shuffle_idx]
    y_train_val = y_train_val[outer_shuffle_idx]
    
    # Scale the features
    scaler_full = StandardScaler().fit(X_train_val)
    X_train_full_scaled = scaler_full.transform(X_train_val)
    X_test_scaled = scaler_full.transform(X_test)
    
    # Encode the labels
    y_train_full_encoded = to_categorical(y_train_val)
    y_test_encoded = to_categorical(y_test)

    #######################
    # BUILD & TRAIN MODEL #
    #######################

    optimizers = {
        'Adamax': Adamax(learning_rate=0.00510251984616472)
    }
    
    # Model definition with dynamic number of layers
    model_full = Sequential()
    model_full.add(Dense(480, activation='relu', input_shape=(X_train_full_scaled.shape[1],)))
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.2011047009431978))  
    model_full.add(Dense(256, activation='relu',)) 
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.14956886311951184))  
    model_full.add(Dense(256, activation='relu'))  
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.42291461228250665))  
    model_full.add(Dense(3, activation='softmax'))  
    
    # Use the optimizer from the parameters
    optimizer = optimizers['Adamax']  # optimizer_key from parameters
    
    # Compile the model
    model_full.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    
    # Train the model on the full training set
    history_full = model_full.fit(X_train_full_scaled, y_train_full_encoded, epochs=1500, batch_size=64,
                                  verbose=1, callbacks=[early_stopping])
    
    # Evaluate the model on the held-out test set
    test_loss, test_accuracy = model_full.evaluate(X_test_scaled, y_test_encoded)

    y_test_pred_prob = model_full.predict(X_test_scaled)
    y_test_pred = np.argmax(y_test_pred_prob, axis=1)  
    y_test_true = np.argmax(y_test_encoded, axis=1)    

    ################################
    # LOG MAJORITY VOTE PER CAT_ID #
    ################################

    # Convert numeric predictions back to age group labels
    predicted_age_groups = label_encoder.inverse_transform(y_test_pred)
    actual_labels = label_encoder.inverse_transform(y_test_true)
    
    # Map predictions and actual labels back to cat_ids
    test_results = pd.DataFrame({
        'cat_id': df_test_updated['cat_id'],
        'predicted_age_group': predicted_age_groups,
        'actual_age_group': actual_labels
    })
    
    # Group by cat_id and aggregate predicted age groups
    majority_votes = test_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
    actual_groups = test_results.groupby('cat_id')['actual_age_group'].first()
    
    # Calculate the accuracy of majority voting
    correct_predictions = (majority_votes == actual_groups).sum()
    total_cats = len(actual_groups)
    majority_vote_accuracy = correct_predictions / total_cats
    
    # Log the accuracy of the majority voting
    logger(f"Majority Vote Accuracy for cat_id for this fold: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

    ####################################################
    # COLLECT PREDICTIONS FOR GENDER & CAT_ID ANALYSIS #
    ####################################################

    # Debugging print statements
    print(f'Before appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Extend lists with current fold results
    all_cat_ids.extend(df_test_updated['cat_id'].tolist())
    all_predicted_age_groups.extend(predicted_age_groups)
    all_actual_age_groups.extend(actual_labels)
    all_gender.extend(df_test_updated['gender'].tolist())

    # Debugging print statements
    print(f'After appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Calculate additional metrics
    test_precision = precision_score(y_test_true, y_test_pred, average='macro')  # Use 'macro' for imbalanced datasets
    test_recall = recall_score(y_test_true, y_test_pred, average='macro')
    test_f1 = f1_score(y_test_true, y_test_pred, average='macro')

    # prepare averages of outer metrics
    unseen_f1.append(test_f1)
    unseen_losses.append(test_loss)
    unseen_accuracies.append(test_accuracy)
    unseen_precisions.append(test_precision)
    unseen_recalls.append(test_recall)

    # Print final test results
    logger(f"Final Test Results - Loss: {test_loss}, Accuracy: {test_accuracy}, Precision: {test_precision}, Recall: {test_recall}, F1 Score: {test_f1}", file=log_file_path)

    # Generate the confusion matrix
    cm = confusion_matrix(y_test, y_test_pred)
    logger(f"Confusion Matrix:\n {cm}", file=log_file_path)

# Calculate the overall average metrics
unseen_set_avg_f1 = np.mean(unseen_f1)
unseen_set_avg_loss = np.mean(unseen_losses)
unseen_set_avg_acc = np.mean(unseen_accuracies)
unseen_set_avg_precision = np.mean(unseen_precisions)
unseen_set_avg_recall = np.mean(unseen_recalls)

logger(f"\nFinal Average F1-Score across all UNSEEN TEST sets: {unseen_set_avg_f1}", file=log_file_path)
logger(f"\nFinal Average Loss across all UNSEEN TEST sets: {unseen_set_avg_loss}", file=log_file_path)
logger(f"\nFinal Average Accuracy across all UNSEEN TEST sets: {unseen_set_avg_acc}", file=log_file_path)
logger(f"\nFinal Average Precision across all UNSEEN TEST sets: {unseen_set_avg_precision}", file=log_file_path)
logger(f"\nFinal Average Recall across all UNSEEN TEST sets: {unseen_set_avg_recall}\n", file=log_file_path)

# Append averages to total lists
all_f1.append(unseen_set_avg_f1)
all_losses.append(unseen_set_avg_loss)
all_accuracies.append(unseen_set_avg_acc)
all_precisions.append(unseen_set_avg_precision)
all_recalls.append(unseen_set_avg_recall)
# Out:
# outer_fold 1
# Train Set Group Distribution:
# 046A    66
# 000A    39
# 002B    36
# 103A    33
# 074A    25
# 067A    20
# 059A    18
# 019A    17
# 029A    17
# 101A    16
# 097A    16
# 106A    15
# 001A    15
# 028A    14
# 042A    14
# 111A    13
# 002A    13
# 051A    12
# 039A    12
# 116A    12
# 016A    11
# 025A    11
# 063A    11
# 071A    10
# 040A    10
# 015A    10
# 014B    10
# 022A     9
# 033A     9
# 072A     9
# 065A     9
# 095A     8
# 010A     8
# 117A     7
# 050A     7
# 031A     7
# 027A     7
# 023A     6
# 008A     6
# 021A     6
# 109A     6
# 108A     6
# 007A     6
# 037A     6
# 034A     5
# 075A     5
# 023B     5
# 012A     5
# 062A     5
# 035A     4
# 003A     4
# 009A     4
# 052A     4
# 104A     4
# 026A     4
# 064A     3
# 058A     3
# 011A     3
# 014A     3
# 056A     3
# 006A     3
# 113A     3
# 060A     3
# 066A     2
# 025B     2
# 087A     2
# 093A     2
# 018A     2
# 032A     2
# 054A     2
# 102A     2
# 069A     2
# 038A     2
# 088A     1
# 024A     1
# 076A     1
# 090A     1
# 115A     1
# 041A     1
# 091A     1
# 026C     1
# 110A     1
# 019B     1
# 096A     1
# 049A     1
# 092A     1
# 026B     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 047A    30
# 057A    28
# 020A    23
# 000B    20
# 055A    20
# 097B    14
# 005A    11
# 036A    11
# 068A    11
# 045A     9
# 051B     9
# 013B     8
# 094A     8
# 099A     7
# 053A     7
# 025C     6
# 044A     5
# 070A     5
# 105A     4
# 061A     2
# 043A     1
# 073A     1
# 048A     1
# 004A     1
# 100A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    292
# X    244
# F    189
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    111
# F     68
# M     64
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [002A, 028A, 033A, 071A, 000A, 015A, 026A, 065...
# kitten    [046A, 042A, 014B, 110A, 109A, 040A, 049A, 111...
# senior    [117A, 106A, 090A, 113A, 116A, 051A, 024A, 097...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [070A, 000B, 020A, 053A, 068A, 105A, 013B, 005...
# kitten                       [047A, 045A, 048A, 044A, 043A]
# senior                       [057A, 051B, 094A, 055A, 061A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 59, 'kitten': 11, 'senior': 17}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 15, 'kitten': 5, 'senior': 5}
# Unique Training/Validation Group IDs:
# ['000A' '001A' '002A' '002B' '003A' '006A' '007A' '008A' '009A' '010A'
#  '011A' '012A' '014A' '014B' '015A' '016A' '018A' '019A' '019B' '021A'
#  '022A' '023A' '023B' '024A' '025A' '025B' '026A' '026B' '026C' '027A'
#  '028A' '029A' '031A' '032A' '033A' '034A' '035A' '037A' '038A' '039A'
#  '040A' '041A' '042A' '046A' '049A' '050A' '051A' '052A' '054A' '056A'
#  '058A' '059A' '060A' '062A' '063A' '064A' '065A' '066A' '067A' '069A'
#  '071A' '072A' '074A' '075A' '076A' '087A' '088A' '090A' '091A' '092A'
#  '093A' '095A' '096A' '097A' '101A' '102A' '103A' '104A' '106A' '108A'
#  '109A' '110A' '111A' '113A' '115A' '116A' '117A']
# Unique Test Group IDs:
# ['000B' '004A' '005A' '013B' '020A' '025C' '036A' '043A' '044A' '045A'
#  '047A' '048A' '051B' '053A' '055A' '057A' '061A' '068A' '070A' '073A'
#  '094A' '097B' '099A' '100A' '105A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '001A' '002A' '002B' '003A' '006A' '007A' '008A' '009A' '010A'
#  '011A' '012A' '014A' '014B' '015A' '016A' '018A' '019A' '019B' '021A'
#  '022A' '023A' '023B' '024A' '025A' '025B' '026A' '026B' '026C' '027A'
#  '028A' '029A' '031A' '032A' '033A' '034A' '035A' '037A' '038A' '039A'
#  '040A' '041A' '042A' '046A' '049A' '050A' '051A' '052A' '054A' '056A'
#  '058A' '059A' '060A' '062A' '063A' '064A' '065A' '066A' '067A' '069A'
#  '071A' '072A' '074A' '075A' '076A' '087A' '088A' '090A' '091A' '092A'
#  '093A' '095A' '096A' '097A' '101A' '102A' '103A' '104A' '106A' '108A'
#  '109A' '110A' '111A' '113A' '115A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['000B' '004A' '005A' '013B' '020A' '025C' '036A' '043A' '044A' '045A'
#  '047A' '048A' '051B' '053A' '055A' '057A' '061A' '068A' '070A' '073A'
#  '094A' '097B' '099A' '100A' '105A']
# Length of X_train_val:
# 725
# Length of y_train_val:
# 725
# Length of groups_train_val:
# 725
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     476
# kitten    130
# senior    119
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     130
# senior     67
# kitten     46
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     476
# kitten    130
# senior    119
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     130
# senior     67
# kitten     46
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 476, 1: 130, 2: 119})
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Epoch 1/1500
# 23/23 [==============================] - 1s 5ms/step - loss: 0.7636 - accuracy: 0.7416
# Epoch 2/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.2471 - accuracy: 0.9167
# Epoch 3/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1716 - accuracy: 0.9384
# Epoch 4/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0964 - accuracy: 0.9601
# Epoch 5/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0703 - accuracy: 0.9755
# Epoch 6/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0458 - accuracy: 0.9832
# Epoch 7/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0324 - accuracy: 0.9888
# Epoch 8/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0282 - accuracy: 0.9916
# Epoch 9/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0244 - accuracy: 0.9930
# Epoch 10/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0308 - accuracy: 0.9909
# Epoch 11/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0178 - accuracy: 0.9951
# Epoch 12/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0154 - accuracy: 0.9937
# Epoch 13/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0111 - accuracy: 0.9972
# Epoch 14/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0192 - accuracy: 0.9958
# Epoch 15/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0181 - accuracy: 0.9951
# Epoch 16/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0184 - accuracy: 0.9944
# Epoch 17/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0134 - accuracy: 0.9958
# Epoch 18/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0151 - accuracy: 0.9951
# Epoch 19/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0086 - accuracy: 0.9972
# Epoch 20/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 21/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 22/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0063 - accuracy: 0.9979
# Epoch 23/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 24/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0083 - accuracy: 0.9986
# Epoch 25/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0107 - accuracy: 0.9965
# Epoch 26/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0137 - accuracy: 0.9965
# Epoch 27/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0296 - accuracy: 0.9902
# Epoch 28/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0203 - accuracy: 0.9937
# Epoch 29/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0115 - accuracy: 0.9944
# Epoch 30/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0126 - accuracy: 0.9951
# Epoch 31/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0133 - accuracy: 0.9951
# Epoch 32/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0125 - accuracy: 0.9986
# Epoch 33/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0087 - accuracy: 0.9986
# Epoch 34/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0054 - accuracy: 0.9986
# Epoch 35/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 36/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0058 - accuracy: 0.9979
# Epoch 37/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 38/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0029 - accuracy: 0.9986
# Epoch 39/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0025 - accuracy: 0.9993
# Epoch 40/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 41/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 42/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0058 - accuracy: 0.9993
# Epoch 43/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0071 - accuracy: 0.9979
# Epoch 44/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0197 - accuracy: 0.9944
# Epoch 45/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0137 - accuracy: 0.9944
# Epoch 46/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0054 - accuracy: 0.9986
# Epoch 47/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0020 - accuracy: 0.9993
# Epoch 48/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0046 - accuracy: 0.9986
# Epoch 49/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0028 - accuracy: 0.9993
# Epoch 50/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0031 - accuracy: 0.9993
# Epoch 51/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 52/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0030 - accuracy: 0.9993
# Epoch 53/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0030 - accuracy: 0.9986
# Epoch 54/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0023 - accuracy: 0.9993
# Epoch 55/1500
# 23/23 [==============================] - 0s 15ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 56/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 57/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0038 - accuracy: 0.9993
# Epoch 58/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 59/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0017 - accuracy: 0.9993
# Epoch 60/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0029 - accuracy: 0.9993
# Epoch 61/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 62/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0016 - accuracy: 0.9993
# Epoch 63/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0013 - accuracy: 0.9993
# Epoch 64/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0155 - accuracy: 0.9944
# Epoch 65/1500
# 21/23 [==========================>...] - ETA: 0s - loss: 0.0099 - accuracy: 0.9985  Restoring model weights from the end of the best epoch: 35.
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0123 - accuracy: 0.9979
# Epoch 65: early stopping
# 8/8 [==============================] - 0s 1ms/step - loss: 3.2408 - accuracy: 0.6132
# 8/8 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.76 (19/25)
# Before appending - Cat IDs: 0, Predictions: 0, Actuals: 0, Gender: 0
# After appending - Cat IDs: 243, Predictions: 243, Actuals: 243, Gender: 243
# Final Test Results - Loss: 3.240788698196411, Accuracy: 0.6131687164306641, Precision: 0.652531328320802, Recall: 0.5097306111582555, F1 Score: 0.5307465406473931
# Confusion Matrix:
#  [[113   7  10]
#  [ 28  18   0]
#  [ 49   0  18]]
# outer_fold 2
# Train Set Group Distribution:
# 046A    66
# 000A    39
# 103A    33
# 047A    30
# 057A    28
# 074A    25
# 020A    23
# 000B    20
# 067A    20
# 055A    20
# 059A    18
# 019A    17
# 097A    16
# 001A    15
# 097B    14
# 028A    14
# 111A    13
# 002A    13
# 116A    12
# 051A    12
# 039A    12
# 005A    11
# 068A    11
# 036A    11
# 025A    11
# 071A    10
# 014B    10
# 051B     9
# 072A     9
# 033A     9
# 045A     9
# 022A     9
# 094A     8
# 013B     8
# 053A     7
# 050A     7
# 117A     7
# 099A     7
# 031A     7
# 027A     7
# 008A     6
# 108A     6
# 021A     6
# 037A     6
# 007A     6
# 025C     6
# 044A     5
# 012A     5
# 070A     5
# 026A     4
# 104A     4
# 035A     4
# 003A     4
# 105A     4
# 052A     4
# 060A     3
# 064A     3
# 014A     3
# 056A     3
# 058A     3
# 006A     3
# 038A     2
# 032A     2
# 102A     2
# 061A     2
# 087A     2
# 066A     2
# 069A     2
# 018A     2
# 026B     1
# 004A     1
# 076A     1
# 115A     1
# 090A     1
# 043A     1
# 091A     1
# 024A     1
# 026C     1
# 048A     1
# 049A     1
# 073A     1
# 110A     1
# 100A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 002B    36
# 029A    17
# 101A    16
# 106A    15
# 042A    14
# 063A    11
# 016A    11
# 015A    10
# 040A    10
# 065A     9
# 010A     8
# 095A     8
# 109A     6
# 023A     6
# 034A     5
# 023B     5
# 075A     5
# 062A     5
# 009A     4
# 113A     3
# 011A     3
# 025B     2
# 093A     2
# 054A     2
# 088A     1
# 096A     1
# 019B     1
# 041A     1
# 092A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    297
# M    233
# F    220
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# M    123
# X     58
# F     37
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [002A, 028A, 070A, 033A, 000B, 071A, 020A, 000...
# kitten    [046A, 014B, 110A, 047A, 049A, 045A, 048A, 111...
# senior    [117A, 057A, 090A, 051B, 116A, 051A, 024A, 097...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [015A, 065A, 023B, 034A, 062A, 002B, 009A, 101...
# kitten                             [042A, 109A, 040A, 041A]
# senior                 [106A, 113A, 016A, 054A, 011A, 093A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 55, 'kitten': 12, 'senior': 16}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 19, 'kitten': 4, 'senior': 6}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '003A' '004A' '005A' '006A' '007A' '008A'
#  '012A' '013B' '014A' '014B' '018A' '019A' '020A' '021A' '022A' '024A'
#  '025A' '025C' '026A' '026B' '026C' '027A' '028A' '031A' '032A' '033A'
#  '035A' '036A' '037A' '038A' '039A' '043A' '044A' '045A' '046A' '047A'
#  '048A' '049A' '050A' '051A' '051B' '052A' '053A' '055A' '056A' '057A'
#  '058A' '059A' '060A' '061A' '064A' '066A' '067A' '068A' '069A' '070A'
#  '071A' '072A' '073A' '074A' '076A' '087A' '090A' '091A' '094A' '097A'
#  '097B' '099A' '100A' '102A' '103A' '104A' '105A' '108A' '110A' '111A'
#  '115A' '116A' '117A']
# Unique Test Group IDs:
# ['002B' '009A' '010A' '011A' '015A' '016A' '019B' '023A' '023B' '025B'
#  '029A' '034A' '040A' '041A' '042A' '054A' '062A' '063A' '065A' '075A'
#  '088A' '092A' '093A' '095A' '096A' '101A' '106A' '109A' '113A']
# No common groups found between train and test sets.
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '003A' '004A' '005A' '006A' '007A' '008A'
#  '012A' '013B' '014A' '014B' '018A' '019A' '020A' '021A' '022A' '024A'
#  '025A' '025C' '026A' '026B' '026C' '027A' '028A' '031A' '032A' '033A'
#  '035A' '036A' '037A' '038A' '039A' '043A' '044A' '045A' '046A' '047A'
#  '048A' '049A' '050A' '051A' '051B' '052A' '053A' '055A' '056A' '057A'
#  '058A' '059A' '060A' '061A' '064A' '066A' '067A' '068A' '069A' '070A'
#  '071A' '072A' '073A' '074A' '076A' '087A' '090A' '091A' '094A' '097A'
#  '097B' '099A' '100A' '102A' '103A' '104A' '105A' '108A' '110A' '111A'
#  '115A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['002B' '009A' '010A' '011A' '015A' '016A' '019B' '023A' '023B' '025B'
#  '029A' '034A' '040A' '041A' '042A' '054A' '062A' '063A' '065A' '075A'
#  '088A' '092A' '093A' '095A' '096A' '101A' '106A' '109A' '113A']
# Length of X_train_val:
# 750
# Length of y_train_val:
# 750
# Length of groups_train_val:
# 750
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     455
# senior    150
# kitten    145
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     151
# senior     36
# kitten     31
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     455
# senior    150
# kitten    145
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     151
# senior     36
# kitten     31
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 455, 2: 150, 1: 145})
# Epoch 1/1500
# 22/22 [==============================] - 1s 5ms/step - loss: 0.8097 - accuracy: 0.7143
# Epoch 2/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.2754 - accuracy: 0.8952
# Epoch 3/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1848 - accuracy: 0.9333
# Epoch 4/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1326 - accuracy: 0.9495
# Epoch 5/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0918 - accuracy: 0.9656
# Epoch 6/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0747 - accuracy: 0.9744
# Epoch 7/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0704 - accuracy: 0.9744
# Epoch 8/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0488 - accuracy: 0.9832
# Epoch 9/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0371 - accuracy: 0.9853
# Epoch 10/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0523 - accuracy: 0.9817
# Epoch 11/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0256 - accuracy: 0.9905
# Epoch 12/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0213 - accuracy: 0.9934
# Epoch 13/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0144 - accuracy: 0.9963
# Epoch 14/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0212 - accuracy: 0.9919
# Epoch 15/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0140 - accuracy: 0.9941
# Epoch 16/1500
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0103 - accuracy: 0.9971
# Epoch 17/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0150 - accuracy: 0.9949
# Epoch 18/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0193 - accuracy: 0.9949
# Epoch 19/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0166 - accuracy: 0.9949
# Epoch 20/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0156 - accuracy: 0.9963
# Epoch 21/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0256 - accuracy: 0.9927
# Epoch 22/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0235 - accuracy: 0.9905
# Epoch 23/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0190 - accuracy: 0.9927
# Epoch 24/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0157 - accuracy: 0.9934
# Epoch 25/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0087 - accuracy: 0.9978
# Epoch 26/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0201 - accuracy: 0.9934
# Epoch 27/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0139 - accuracy: 0.9956
# Epoch 28/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0147 - accuracy: 0.9941
# Epoch 29/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0062 - accuracy: 0.9985
# Epoch 30/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0135 - accuracy: 0.9963
# Epoch 31/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0113 - accuracy: 0.9949
# Epoch 32/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0142 - accuracy: 0.9949
# Epoch 33/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0055 - accuracy: 0.9993
# Epoch 34/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0090 - accuracy: 0.9971
# Epoch 35/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0089 - accuracy: 0.9978
# Epoch 36/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0139 - accuracy: 0.9949
# Epoch 37/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0058 - accuracy: 0.9971
# Epoch 38/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0207 - accuracy: 0.9941
# Epoch 39/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0160 - accuracy: 0.9941
# Epoch 40/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0076 - accuracy: 0.9971
# Epoch 41/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0080 - accuracy: 0.9956
# Epoch 42/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0064 - accuracy: 0.9978
# Epoch 43/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0067 - accuracy: 0.9985
# Epoch 44/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0066 - accuracy: 0.9985
# Epoch 45/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0077 - accuracy: 0.9978
# Epoch 46/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0072 - accuracy: 0.9985
# Epoch 47/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0081 - accuracy: 0.9963
# Epoch 48/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0083 - accuracy: 0.9971
# Epoch 49/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0045 - accuracy: 0.9985
# Epoch 50/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 51/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0053 - accuracy: 0.9978
# Epoch 52/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0030 - accuracy: 0.9993
# Epoch 53/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0027 - accuracy: 0.9993
# Epoch 54/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0031 - accuracy: 0.9993
# Epoch 55/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0029 - accuracy: 0.9993
# Epoch 56/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0027 - accuracy: 0.9993
# Epoch 57/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 58/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 9.4604e-04 - accuracy: 1.0000
# Epoch 59/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0014 - accuracy: 0.9993
# Epoch 60/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0052 - accuracy: 0.9985
# Epoch 61/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0057 - accuracy: 0.9978
# Epoch 62/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0145 - accuracy: 0.9956
# Epoch 63/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0160 - accuracy: 0.9919
# Epoch 64/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0275 - accuracy: 0.9949
# Epoch 65/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0252 - accuracy: 0.9934
# Epoch 66/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0173 - accuracy: 0.9963
# Epoch 67/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0080 - accuracy: 0.9978
# Epoch 68/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0062 - accuracy: 0.9985
# Epoch 69/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0095 - accuracy: 0.9963
# Epoch 70/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 71/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0048 - accuracy: 0.9971
# Epoch 72/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0055 - accuracy: 0.9993
# Epoch 73/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0025 - accuracy: 0.9993
# Epoch 74/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0033 - accuracy: 0.9993
# Epoch 75/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0040 - accuracy: 0.9978
# Epoch 76/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0066 - accuracy: 0.9978
# Epoch 77/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0091 - accuracy: 0.9971
# Epoch 78/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0031 - accuracy: 0.9993
# Epoch 79/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0068 - accuracy: 0.9978
# Epoch 80/1500
# 19/22 [========================>.....] - ETA: 0s - loss: 0.0022 - accuracy: 0.9992  Restoring model weights from the end of the best epoch: 50.
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0020 - accuracy: 0.9993
# Epoch 80: early stopping
# 7/7 [==============================] - 0s 3ms/step - loss: 3.2551 - accuracy: 0.7064
# 7/7 [==============================] - 0s 1ms/step
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Majority Vote Accuracy for cat_id for this fold: 0.76 (22/29)
# Before appending - Cat IDs: 243, Predictions: 243, Actuals: 243, Gender: 243
# After appending - Cat IDs: 461, Predictions: 461, Actuals: 461, Gender: 461
# Final Test Results - Loss: 3.255096197128296, Accuracy: 0.7064220309257507, Precision: 0.5943150994575045, Recall: 0.5929090808390104, F1 Score: 0.5920917450043665
# Confusion Matrix:
#  [[123   8  20]
#  [  8  23   0]
#  [ 27   1   8]]
# outer_fold 3
# Train Set Group Distribution:
# 046A    66
# 002B    36
# 103A    33
# 047A    30
# 057A    28
# 020A    23
# 055A    20
# 000B    20
# 029A    17
# 101A    16
# 097A    16
# 106A    15
# 042A    14
# 097B    14
# 028A    14
# 039A    12
# 051A    12
# 063A    11
# 005A    11
# 016A    11
# 068A    11
# 025A    11
# 036A    11
# 040A    10
# 014B    10
# 015A    10
# 065A     9
# 051B     9
# 033A     9
# 045A     9
# 094A     8
# 095A     8
# 010A     8
# 013B     8
# 053A     7
# 099A     7
# 031A     7
# 109A     6
# 025C     6
# 021A     6
# 108A     6
# 007A     6
# 023A     6
# 012A     5
# 023B     5
# 070A     5
# 034A     5
# 062A     5
# 044A     5
# 075A     5
# 009A     4
# 105A     4
# 026A     4
# 011A     3
# 006A     3
# 113A     3
# 038A     2
# 054A     2
# 093A     2
# 061A     2
# 087A     2
# 025B     2
# 069A     2
# 018A     2
# 024A     1
# 026B     1
# 004A     1
# 076A     1
# 115A     1
# 041A     1
# 019B     1
# 090A     1
# 048A     1
# 073A     1
# 088A     1
# 049A     1
# 092A     1
# 096A     1
# 043A     1
# 026C     1
# 100A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 000A    39
# 074A    25
# 067A    20
# 059A    18
# 019A    17
# 001A    15
# 111A    13
# 002A    13
# 116A    12
# 071A    10
# 022A     9
# 072A     9
# 050A     7
# 117A     7
# 027A     7
# 037A     6
# 008A     6
# 104A     4
# 035A     4
# 003A     4
# 052A     4
# 060A     3
# 014A     3
# 056A     3
# 064A     3
# 058A     3
# 066A     2
# 032A     2
# 102A     2
# 091A     1
# 110A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    277
# M    256
# F    163
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# M    100
# F     94
# X     78
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [028A, 070A, 033A, 000B, 020A, 015A, 026A, 065...
# kitten    [046A, 042A, 014B, 109A, 040A, 047A, 049A, 045...
# senior    [106A, 057A, 090A, 113A, 051B, 051A, 024A, 097...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [002A, 071A, 000A, 001A, 072A, 091A, 019A, 022...
# kitten                                   [110A, 111A, 050A]
# senior                 [117A, 116A, 059A, 058A, 104A, 056A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 52, 'kitten': 13, 'senior': 16}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 22, 'kitten': 3, 'senior': 6}
# Unique Training/Validation Group IDs:
# ['000B' '002B' '004A' '005A' '006A' '007A' '009A' '010A' '011A' '012A'
#  '013B' '014B' '015A' '016A' '018A' '019B' '020A' '021A' '023A' '023B'
#  '024A' '025A' '025B' '025C' '026A' '026B' '026C' '028A' '029A' '031A'
#  '033A' '034A' '036A' '038A' '039A' '040A' '041A' '042A' '043A' '044A'
#  '045A' '046A' '047A' '048A' '049A' '051A' '051B' '053A' '054A' '055A'
#  '057A' '061A' '062A' '063A' '065A' '068A' '069A' '070A' '073A' '075A'
#  '076A' '087A' '088A' '090A' '092A' '093A' '094A' '095A' '096A' '097A'
#  '097B' '099A' '100A' '101A' '103A' '105A' '106A' '108A' '109A' '113A'
#  '115A']
# Unique Test Group IDs:
# ['000A' '001A' '002A' '003A' '008A' '014A' '019A' '022A' '027A' '032A'
#  '035A' '037A' '050A' '052A' '056A' '058A' '059A' '060A' '064A' '066A'
#  '067A' '071A' '072A' '074A' '091A' '102A' '104A' '110A' '111A' '116A'
#  '117A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'000A'}
# Removed from Training/Validation Set:
# {'068A'}
# Moved to Test Set:
# {'068A'}
# Removed from Test Set
# {'000A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '002B' '004A' '005A' '006A' '007A' '009A' '010A' '011A'
#  '012A' '013B' '014B' '015A' '016A' '018A' '019B' '020A' '021A' '023A'
#  '023B' '024A' '025A' '025B' '025C' '026A' '026B' '026C' '028A' '029A'
#  '031A' '033A' '034A' '036A' '038A' '039A' '040A' '041A' '042A' '043A'
#  '044A' '045A' '046A' '047A' '048A' '049A' '051A' '051B' '053A' '054A'
#  '055A' '057A' '061A' '062A' '063A' '065A' '069A' '070A' '073A' '075A'
#  '076A' '087A' '088A' '090A' '092A' '093A' '094A' '095A' '096A' '097A'
#  '097B' '099A' '100A' '101A' '103A' '105A' '106A' '108A' '109A' '113A'
#  '115A']
# AFTER SWAP - Unique Test Group IDs:
# ['001A' '002A' '003A' '008A' '014A' '019A' '022A' '027A' '032A' '035A'
#  '037A' '050A' '052A' '056A' '058A' '059A' '060A' '064A' '066A' '067A'
#  '068A' '071A' '072A' '074A' '091A' '102A' '104A' '110A' '111A' '116A'
#  '117A']
# Length of X_train_val:
# 724
# Length of y_train_val:
# 724
# Length of groups_train_val:
# 724
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     402
# kitten    155
# senior    139
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     204
# senior     47
# kitten     21
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     430
# kitten    155
# senior    139
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     176
# senior     47
# kitten     21
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 430, 1: 155, 2: 139})
# Epoch 1/1500
# 21/21 [==============================] - 1s 5ms/step - loss: 0.8481 - accuracy: 0.7070
# Epoch 2/1500
# 21/21 [==============================] - 0s 5ms/step - loss: 0.2963 - accuracy: 0.8744
# Epoch 3/1500
# 21/21 [==============================] - 0s 7ms/step - loss: 0.2127 - accuracy: 0.9163
# Epoch 4/1500
# 21/21 [==============================] - 0s 5ms/step - loss: 0.1512 - accuracy: 0.9473
# Epoch 5/1500
# 21/21 [==============================] - 0s 6ms/step - loss: 0.1208 - accuracy: 0.9543
# Epoch 6/1500
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0968 - accuracy: 0.9705
# Epoch 7/1500
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0824 - accuracy: 0.9659
# Epoch 8/1500
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0629 - accuracy: 0.9814
# Epoch 9/1500
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0573 - accuracy: 0.9806
# Epoch 10/1500
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0686 - accuracy: 0.9767
# Epoch 11/1500
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0425 - accuracy: 0.9876
# Epoch 12/1500
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0474 - accuracy: 0.9829
# Epoch 13/1500
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0256 - accuracy: 0.9930
# Epoch 14/1500
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0275 - accuracy: 0.9884
# Epoch 15/1500
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0357 - accuracy: 0.9891
# Epoch 16/1500
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0287 - accuracy: 0.9922
# Epoch 17/1500
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0350 - accuracy: 0.9860
# Epoch 18/1500
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0190 - accuracy: 0.9953
# Epoch 19/1500
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0248 - accuracy: 0.9922
# Epoch 20/1500
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0185 - accuracy: 0.9953
# Epoch 21/1500
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0241 - accuracy: 0.9907
# Epoch 22/1500
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0258 - accuracy: 0.9930
# Epoch 23/1500
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0176 - accuracy: 0.9953
# Epoch 24/1500
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0252 - accuracy: 0.9915
# Epoch 25/1500
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0204 - accuracy: 0.9922
# Epoch 26/1500
# 21/21 [==============================] - 0s 20ms/step - loss: 0.0323 - accuracy: 0.9884
# Epoch 27/1500
# 21/21 [==============================] - 0s 10ms/step - loss: 0.0342 - accuracy: 0.9853
# Epoch 28/1500
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0224 - accuracy: 0.9946
# Epoch 29/1500
# 21/21 [==============================] - 1s 36ms/step - loss: 0.0320 - accuracy: 0.9891
# Epoch 30/1500
# 21/21 [==============================] - 0s 9ms/step - loss: 0.0121 - accuracy: 0.9961
# Epoch 31/1500
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0226 - accuracy: 0.9946
# Epoch 32/1500
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0121 - accuracy: 0.9969
# Epoch 33/1500
# 21/21 [==============================] - 0s 11ms/step - loss: 0.0088 - accuracy: 0.9984
# Epoch 34/1500
# 21/21 [==============================] - 0s 14ms/step - loss: 0.0078 - accuracy: 0.9992
# Epoch 35/1500
# 21/21 [==============================] - 0s 14ms/step - loss: 0.0117 - accuracy: 0.9969
# Epoch 36/1500
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0078 - accuracy: 0.9977
# Epoch 37/1500
# 21/21 [==============================] - 0s 12ms/step - loss: 0.0106 - accuracy: 0.9969
# Epoch 38/1500
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0053 - accuracy: 0.9992
# Epoch 39/1500
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0073 - accuracy: 0.9984
# Epoch 40/1500
# 21/21 [==============================] - 0s 10ms/step - loss: 0.0068 - accuracy: 0.9977
# Epoch 41/1500
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0064 - accuracy: 0.9984
# Epoch 42/1500
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0044 - accuracy: 0.9992
# Epoch 43/1500
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0071 - accuracy: 0.9969
# Epoch 44/1500
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0077 - accuracy: 0.9969
# Epoch 45/1500
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0135 - accuracy: 0.9977
# Epoch 46/1500
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0087 - accuracy: 0.9977
# Epoch 47/1500
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0074 - accuracy: 0.9977
# Epoch 48/1500
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0090 - accuracy: 0.9977
# Epoch 49/1500
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0062 - accuracy: 0.9977
# Epoch 50/1500
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0041 - accuracy: 0.9992
# Epoch 51/1500
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0179 - accuracy: 0.9938
# Epoch 52/1500
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0218 - accuracy: 0.9915
# Epoch 53/1500
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0130 - accuracy: 0.9930
# Epoch 54/1500
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0152 - accuracy: 0.9946
# Epoch 55/1500
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0185 - accuracy: 0.9907
# Epoch 56/1500
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0118 - accuracy: 0.9969
# Epoch 57/1500
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0084 - accuracy: 0.9961
# Epoch 58/1500
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0050 - accuracy: 0.9992
# Epoch 59/1500
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0098 - accuracy: 0.9977
# Epoch 60/1500
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0072 - accuracy: 0.9961
# Epoch 61/1500
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0161 - accuracy: 0.9946
# Epoch 62/1500
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0076 - accuracy: 0.9969
# Epoch 63/1500
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0063 - accuracy: 0.9984
# Epoch 64/1500
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0073 - accuracy: 0.9969
# Epoch 65/1500
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0077 - accuracy: 0.9977
# Epoch 66/1500
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0079 - accuracy: 0.9961
# Epoch 67/1500
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0181 - accuracy: 0.9930
# Epoch 68/1500
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0196 - accuracy: 0.9946
# Epoch 69/1500
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0239 - accuracy: 0.9953
# Epoch 70/1500
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0177 - accuracy: 0.9930
# Epoch 71/1500
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0077 - accuracy: 0.9977
# Epoch 72/1500
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0426 - accuracy: 0.9891
# Epoch 73/1500
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0197 - accuracy: 0.9946
# Epoch 74/1500
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0177 - accuracy: 0.9946
# Epoch 75/1500
# 21/21 [==============================] - 0s 8ms/step - loss: 0.0278 - accuracy: 0.9938
# Epoch 76/1500
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0128 - accuracy: 0.9953
# Epoch 77/1500
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0073 - accuracy: 0.9969
# Epoch 78/1500
# 21/21 [==============================] - 0s 5ms/step - loss: 0.0053 - accuracy: 0.9992
# Epoch 79/1500
# 21/21 [==============================] - 0s 6ms/step - loss: 0.0063 - accuracy: 0.9977
# Epoch 80/1500
# 19/21 [==========================>...] - ETA: 0s - loss: 0.0035 - accuracy: 0.9984Restoring model weights from the end of the best epoch: 50.
# 21/21 [==============================] - 0s 7ms/step - loss: 0.0034 - accuracy: 0.9984
# Epoch 80: early stopping
# 8/8 [==============================] - 0s 1ms/step - loss: 1.9991 - accuracy: 0.7049
# 8/8 [==============================] - 0s 2ms/step
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Majority Vote Accuracy for cat_id for this fold: 0.81 (25/31)
# Before appending - Cat IDs: 461, Predictions: 461, Actuals: 461, Gender: 461
# After appending - Cat IDs: 705, Predictions: 705, Actuals: 705, Gender: 705
# Final Test Results - Loss: 1.9991459846496582, Accuracy: 0.7049180269241333, Precision: 0.5907357221720365, Recall: 0.6689827607380799, F1 Score: 0.6086128511686825
# Confusion Matrix:
#  [[133  25  18]
#  [  5  16   0]
#  [ 24   0  23]]
# outer_fold 4
# Train Set Group Distribution:
# 000A    39
# 002B    36
# 047A    30
# 057A    28
# 074A    25
# 020A    23
# 000B    20
# 055A    20
# 067A    20
# 059A    18
# 029A    17
# 019A    17
# 101A    16
# 106A    15
# 001A    15
# 097B    14
# 042A    14
# 002A    13
# 111A    13
# 116A    12
# 063A    11
# 036A    11
# 005A    11
# 016A    11
# 068A    11
# 040A    10
# 071A    10
# 015A    10
# 022A     9
# 045A     9
# 065A     9
# 051B     9
# 072A     9
# 094A     8
# 010A     8
# 095A     8
# 013B     8
# 050A     7
# 099A     7
# 053A     7
# 027A     7
# 117A     7
# 008A     6
# 037A     6
# 109A     6
# 025C     6
# 023A     6
# 044A     5
# 062A     5
# 034A     5
# 075A     5
# 070A     5
# 023B     5
# 104A     4
# 009A     4
# 035A     4
# 003A     4
# 105A     4
# 052A     4
# 064A     3
# 011A     3
# 014A     3
# 060A     3
# 058A     3
# 113A     3
# 056A     3
# 025B     2
# 061A     2
# 054A     2
# 066A     2
# 093A     2
# 102A     2
# 032A     2
# 041A     1
# 004A     1
# 019B     1
# 073A     1
# 091A     1
# 110A     1
# 088A     1
# 096A     1
# 043A     1
# 092A     1
# 048A     1
# 100A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 046A    66
# 103A    33
# 097A    16
# 028A    14
# 039A    12
# 051A    12
# 025A    11
# 014B    10
# 033A     9
# 031A     7
# 108A     6
# 007A     6
# 021A     6
# 012A     5
# 026A     4
# 006A     3
# 087A     2
# 018A     2
# 069A     2
# 038A     2
# 115A     1
# 076A     1
# 024A     1
# 049A     1
# 090A     1
# 026C     1
# 026B     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    287
# X    247
# F    199
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    108
# M     69
# F     58
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [002A, 070A, 000B, 071A, 020A, 000A, 015A, 065...
# kitten    [042A, 110A, 109A, 040A, 047A, 045A, 048A, 111...
# senior    [117A, 106A, 057A, 113A, 051B, 116A, 094A, 059...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [028A, 033A, 026A, 038A, 026C, 007A, 021A, 018...
# kitten                             [046A, 014B, 049A, 115A]
# senior                       [090A, 051A, 024A, 097A, 108A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 56, 'kitten': 12, 'senior': 17}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 18, 'kitten': 4, 'senior': 5}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '004A' '005A' '008A' '009A'
#  '010A' '011A' '013B' '014A' '015A' '016A' '019A' '019B' '020A' '022A'
#  '023A' '023B' '025B' '025C' '027A' '029A' '032A' '034A' '035A' '036A'
#  '037A' '040A' '041A' '042A' '043A' '044A' '045A' '047A' '048A' '050A'
#  '051B' '052A' '053A' '054A' '055A' '056A' '057A' '058A' '059A' '060A'
#  '061A' '062A' '063A' '064A' '065A' '066A' '067A' '068A' '070A' '071A'
#  '072A' '073A' '074A' '075A' '088A' '091A' '092A' '093A' '094A' '095A'
#  '096A' '097B' '099A' '100A' '101A' '102A' '104A' '105A' '106A' '109A'
#  '110A' '111A' '113A' '116A' '117A']
# Unique Test Group IDs:
# ['006A' '007A' '012A' '014B' '018A' '021A' '024A' '025A' '026A' '026B'
#  '026C' '028A' '031A' '033A' '038A' '039A' '046A' '049A' '051A' '069A'
#  '076A' '087A' '090A' '097A' '103A' '108A' '115A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'046A'}
# Removed from Training/Validation Set:
# {'048A'}
# Moved to Test Set:
# {'048A'}
# Removed from Test Set
# {'046A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '004A' '005A' '008A' '009A'
#  '010A' '011A' '013B' '014A' '015A' '016A' '019A' '019B' '020A' '022A'
#  '023A' '023B' '025B' '025C' '027A' '029A' '032A' '034A' '035A' '036A'
#  '037A' '040A' '041A' '042A' '043A' '044A' '045A' '046A' '047A' '050A'
#  '051B' '052A' '053A' '054A' '055A' '056A' '057A' '058A' '059A' '060A'
#  '061A' '062A' '063A' '064A' '065A' '066A' '067A' '068A' '070A' '071A'
#  '072A' '073A' '074A' '075A' '088A' '091A' '092A' '093A' '094A' '095A'
#  '096A' '097B' '099A' '100A' '101A' '102A' '104A' '105A' '106A' '109A'
#  '110A' '111A' '113A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['006A' '007A' '012A' '014B' '018A' '021A' '024A' '025A' '026A' '026B'
#  '026C' '028A' '031A' '033A' '038A' '039A' '048A' '049A' '051A' '069A'
#  '076A' '087A' '090A' '097A' '103A' '108A' '115A']
# Length of X_train_val:
# 798
# Length of y_train_val:
# 798
# Length of groups_train_val:
# 798
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     485
# senior    150
# kitten     98
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     121
# kitten     78
# senior     36
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     485
# kitten    163
# senior    150
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     121
# senior     36
# kitten     13
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 485, 1: 163, 2: 150})
# Epoch 1/1500
# 23/23 [==============================] - 1s 4ms/step - loss: 0.7805 - accuracy: 0.7237
# Epoch 2/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.2991 - accuracy: 0.8887
# Epoch 3/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1554 - accuracy: 0.9416
# Epoch 4/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.1024 - accuracy: 0.9677
# Epoch 5/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0817 - accuracy: 0.9759
# Epoch 6/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0545 - accuracy: 0.9794
# Epoch 7/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0455 - accuracy: 0.9890
# Epoch 8/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0422 - accuracy: 0.9835
# Epoch 9/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0284 - accuracy: 0.9918
# Epoch 10/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0388 - accuracy: 0.9869
# Epoch 11/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0236 - accuracy: 0.9945
# Epoch 12/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0261 - accuracy: 0.9911
# Epoch 13/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0221 - accuracy: 0.9945
# Epoch 14/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0212 - accuracy: 0.9931
# Epoch 15/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0242 - accuracy: 0.9890
# Epoch 16/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0212 - accuracy: 0.9904
# Epoch 17/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0309 - accuracy: 0.9931
# Epoch 18/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0151 - accuracy: 0.9945
# Epoch 19/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0114 - accuracy: 0.9966
# Epoch 20/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0114 - accuracy: 0.9966
# Epoch 21/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0090 - accuracy: 0.9973
# Epoch 22/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0116 - accuracy: 0.9979
# Epoch 23/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0081 - accuracy: 0.9973
# Epoch 24/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0132 - accuracy: 0.9931
# Epoch 25/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0091 - accuracy: 0.9959
# Epoch 26/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0050 - accuracy: 0.9979
# Epoch 27/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0075 - accuracy: 0.9979
# Epoch 28/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0105 - accuracy: 0.9959
# Epoch 29/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0103 - accuracy: 0.9952
# Epoch 30/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0077 - accuracy: 0.9966
# Epoch 31/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0091 - accuracy: 0.9959
# Epoch 32/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0147 - accuracy: 0.9938
# Epoch 33/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0120 - accuracy: 0.9959
# Epoch 34/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0098 - accuracy: 0.9966
# Epoch 35/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0109 - accuracy: 0.9959
# Epoch 36/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0080 - accuracy: 0.9966
# Epoch 37/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 38/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0077 - accuracy: 0.9993
# Epoch 39/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0043 - accuracy: 0.9993
# Epoch 40/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0024 - accuracy: 0.9993
# Epoch 41/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0052 - accuracy: 0.9986
# Epoch 42/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0151 - accuracy: 0.9945
# Epoch 43/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0090 - accuracy: 0.9973
# Epoch 44/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0067 - accuracy: 0.9979
# Epoch 45/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0040 - accuracy: 0.9993
# Epoch 46/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0048 - accuracy: 0.9986
# Epoch 47/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0179 - accuracy: 0.9924
# Epoch 48/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0164 - accuracy: 0.9959
# Epoch 49/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0102 - accuracy: 0.9959
# Epoch 50/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0085 - accuracy: 0.9973
# Epoch 51/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0076 - accuracy: 0.9979
# Epoch 52/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0098 - accuracy: 0.9979
# Epoch 53/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0165 - accuracy: 0.9952
# Epoch 54/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0103 - accuracy: 0.9959
# Epoch 55/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0101 - accuracy: 0.9959
# Epoch 56/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0064 - accuracy: 0.9979
# Epoch 57/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0116 - accuracy: 0.9952
# Epoch 58/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0050 - accuracy: 0.9979
# Epoch 59/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 60/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0026 - accuracy: 0.9986
# Epoch 61/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0033 - accuracy: 0.9979
# Epoch 62/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0055 - accuracy: 0.9979
# Epoch 63/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 64/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 8.8618e-04 - accuracy: 1.0000
# Epoch 65/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 6.4467e-04 - accuracy: 1.0000
# Epoch 66/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0013 - accuracy: 0.9993
# Epoch 67/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 68/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 69/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 9.7530e-04 - accuracy: 1.0000
# Epoch 70/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 71/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 7.8712e-04 - accuracy: 1.0000
# Epoch 72/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 7.7717e-04 - accuracy: 1.0000
# Epoch 73/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0017 - accuracy: 0.9986
# Epoch 74/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0075 - accuracy: 0.9986
# Epoch 75/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 76/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 77/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0020 - accuracy: 0.9986
# Epoch 78/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0083 - accuracy: 0.9986
# Epoch 79/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0053 - accuracy: 0.9986
# Epoch 80/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0069 - accuracy: 0.9973
# Epoch 81/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0017 - accuracy: 0.9993
# Epoch 82/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0061 - accuracy: 0.9979
# Epoch 83/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0030 - accuracy: 0.9986
# Epoch 84/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0068 - accuracy: 0.9973
# Epoch 85/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0072 - accuracy: 0.9986
# Epoch 86/1500
# 23/23 [==============================] - 0s 8ms/step - loss: 0.0097 - accuracy: 0.9966
# Epoch 87/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0029 - accuracy: 0.9993
# Epoch 88/1500
# 23/23 [==============================] - 0s 9ms/step - loss: 0.0055 - accuracy: 0.9986
# Epoch 89/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0076 - accuracy: 0.9959
# Epoch 90/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0031 - accuracy: 0.9979
# Epoch 91/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0021 - accuracy: 0.9993
# Epoch 92/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0017 - accuracy: 0.9993
# Epoch 93/1500
# 23/23 [==============================] - 0s 8ms/step - loss: 0.0036 - accuracy: 0.9986
# Epoch 94/1500
# 19/23 [=======================>......] - ETA: 0s - loss: 0.0022 - accuracy: 0.9992  Restoring model weights from the end of the best epoch: 64.
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0019 - accuracy: 0.9993
# Epoch 94: early stopping
# 6/6 [==============================] - 0s 2ms/step - loss: 5.0211 - accuracy: 0.7118
# 6/6 [==============================] - 0s 2ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.78 (21/27)
# Before appending - Cat IDs: 705, Predictions: 705, Actuals: 705, Gender: 705
# After appending - Cat IDs: 875, Predictions: 875, Actuals: 875, Gender: 875
# Final Test Results - Loss: 5.021097183227539, Accuracy: 0.7117646932601929, Precision: 0.5869565217391305, Recall: 0.5193131784040875, F1 Score: 0.5416345881113498
# Confusion Matrix:
#  [[105   5  11]
#  [  8   5   0]
#  [ 25   0  11]]
#
# Final Average F1-Score across all UNSEEN TEST sets: 0.568271431232948
#
# Final Average Loss across all UNSEEN TEST sets: 3.379032015800476
#
# Final Average Accuracy across all UNSEEN TEST sets: 0.6840683668851852
#
# Final Average Precision across all UNSEEN TEST sets: 0.6061346679223684
#
# Final Average Recall across all UNSEEN TEST sets: 0.5727339077848583

# %%
seed_3_folds_values = (unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1)

# Plotting all fold metrics
seed_3_folds_plot = plot_all_metrics(unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1, "Folds", "Fold Number")

# %% [markdown]
# ## Majority Voting on Total Entries per cat_id

# %%
# Debugging print statements
print(f'Checking - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
# Out:
# Checking - Cat IDs: 875, Predictions: 875, Actuals: 875, Gender: 875

# %%
# Create results df
full_results = pd.DataFrame({
    'cat_id': all_cat_ids,
    'predicted_age_group': all_predicted_age_groups,
    'actual_age_group': all_actual_age_groups,
    'all_gender': all_gender
})

# create a correct majority prediction column
full_results['correct'] = full_results['predicted_age_group'] == full_results['actual_age_group']

# %%
# Group by cat_id and aggregate predicted age groups
majority_votes = full_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first()

# Calculate the accuracy of majority voting
correct_predictions = (majority_votes == actual_groups).sum()
total_cats = len(actual_groups)
majority_vote_accuracy = correct_predictions / total_cats

logger(f"Overall Majority Vote Accuracy for cat_id: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

# store for final evaluation 
all_majority_vote_accuracies.append(majority_vote_accuracy)
# Out:
# Overall Majority Vote Accuracy for cat_id: 0.77 (85/110)

# %%
# Detailed df with predictions, actual labels, and comparison including majority vote
detailed_results = full_results.groupby('cat_id').apply(
    lambda x: pd.Series({
        'Predictions': list(x['predicted_age_group']),
        'Majority Vote': x['predicted_age_group'].mode()[0],
        'Actual Age Group': x['actual_age_group'].iloc[0],
        'Correct Majority Vote': x['predicted_age_group'].mode()[0] == x['actual_age_group'].iloc[0]
    })
).reset_index()

# Convert to DataFrame for better formatting and display
detailed_results = pd.DataFrame(detailed_results)

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 10)
pd.set_option('display.width', 1000)

sorted_detailed_results = detailed_results.sort_values(by='Correct Majority Vote', ascending=False)

# Display the sorted DataFrame
sorted_detailed_results
# Out:
#     cat_id                                        Predictions Majority Vote Actual Age Group  Correct Majority Vote
# 0     000B  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 45    039A  [senior, adult, adult, adult, senior, senior, ...         adult            adult                   True
# 75    069A                                     [adult, adult]         adult            adult                   True
# 74    068A  [adult, adult, adult, adult, senior, adult, ad...         adult            adult                   True
# 73    067A  [adult, adult, kitten, adult, kitten, adult, a...         adult            adult                   True
# 72    066A                                    [adult, kitten]         adult            adult                   True
# 71    065A  [adult, adult, adult, kitten, adult, adult, ad...         adult            adult                   True
# 70    064A                             [adult, adult, kitten]         adult            adult                   True
# 69    063A  [kitten, adult, kitten, adult, adult, adult, k...         adult            adult                   True
# 68    062A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 65    059A  [senior, senior, senior, senior, senior, senio...        senior           senior                   True
# 59    053A  [adult, adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 58    052A                     [adult, adult, senior, senior]         adult            adult                   True
# 1     001A  [adult, adult, adult, senior, senior, adult, a...         adult            adult                   True
# 54    049A                                           [kitten]        kitten           kitten                   True
# 53    048A                                   [kitten, kitten]        kitten           kitten                   True
# 51    045A  [kitten, adult, kitten, kitten, kitten, kitten...        kitten           kitten                   True
# 50    044A             [kitten, kitten, adult, kitten, adult]        kitten           kitten                   True
# 49    043A                                           [kitten]        kitten           kitten                   True
# 48    042A  [kitten, kitten, kitten, adult, kitten, kitten...        kitten           kitten                   True
# 47    041A                                           [kitten]        kitten           kitten                   True
# 76    070A              [adult, senior, senior, adult, adult]         adult            adult                   True
# 77    071A  [adult, senior, adult, adult, adult, senior, s...         adult            adult                   True
# 78    072A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 94    099A  [adult, adult, adult, kitten, senior, adult, a...         adult            adult                   True
# 107   115A                                           [kitten]        kitten           kitten                   True
# 106   113A                            [senior, senior, adult]        senior           senior                   True
# 105   111A  [kitten, kitten, kitten, kitten, kitten, kitte...        kitten           kitten                   True
# 104   110A                                           [kitten]        kitten           kitten                   True
# 100   105A                      [adult, adult, adult, kitten]         adult            adult                   True
# 98    103A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 97    102A                                     [adult, adult]         adult            adult                   True
# 96    101A  [adult, senior, adult, adult, adult, senior, s...         adult            adult                   True
# 93    097B  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 79    073A                                            [adult]         adult            adult                   True
# 91    096A                                            [adult]         adult            adult                   True
# 90    095A  [senior, adult, adult, senior, adult, adult, a...         adult            adult                   True
# 89    094A  [adult, senior, senior, senior, senior, senior...        senior           senior                   True
# 87    092A                                            [adult]         adult            adult                   True
# 84    088A                                            [adult]         adult            adult                   True
# 83    087A                                     [adult, adult]         adult            adult                   True
# 81    075A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 80    074A  [adult, kitten, adult, adult, adult, adult, ad...         adult            adult                   True
# 46    040A  [kitten, adult, adult, kitten, kitten, kitten,...        kitten           kitten                   True
# 55    050A  [kitten, kitten, adult, adult, adult, kitten, ...        kitten           kitten                   True
# 44    038A                                    [adult, kitten]         adult            adult                   True
# 14    013B  [adult, adult, adult, adult, adult, kitten, ki...         adult            adult                   True
# 27    024A                                           [senior]        senior           senior                   True
# 25    023A       [adult, kitten, senior, adult, adult, adult]         adult            adult                   True
# 24    022A  [adult, adult, kitten, adult, adult, adult, ad...         adult            adult                   True
# 23    021A         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 43    037A        [kitten, adult, adult, adult, adult, adult]         adult            adult                   True
# 21    019B                                            [adult]         adult            adult                   True
# 20    019A  [adult, kitten, kitten, adult, adult, adult, k...         adult            adult                   True
# 19    018A                                     [adult, adult]         adult            adult                   True
# 17    015A  [senior, adult, adult, adult, adult, adult, se...         adult            adult                   True
# 15    014A                             [kitten, adult, adult]         adult            adult                   True
# 13    012A               [adult, adult, adult, adult, kitten]         adult            adult                   True
# 29    025B                                     [adult, adult]         adult            adult                   True
# 11    010A  [adult, adult, adult, adult, adult, adult, sen...         adult            adult                   True
# 10    009A                      [adult, adult, senior, adult]         adult            adult                   True
# 9     008A         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 8     007A         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 7     006A                             [adult, kitten, adult]         adult            adult                   True
# 6     005A  [adult, adult, adult, adult, adult, adult, sen...         adult            adult                   True
# 5     004A                                            [adult]         adult            adult                   True
# 4     003A                      [adult, kitten, adult, adult]         adult            adult                   True
# 3     002B  [adult, adult, adult, kitten, adult, adult, ad...         adult            adult                   True
# 2     002A  [adult, kitten, adult, adult, adult, adult, se...         adult            adult                   True
# 28    025A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 22    020A  [kitten, adult, adult, adult, adult, adult, ad...         adult            adult                   True
# 30    025C         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 33    026C                                            [adult]         adult            adult                   True
# 42    036A  [senior, adult, adult, adult, adult, adult, ad...         adult            adult                   True
# 41    035A                      [adult, adult, senior, adult]         adult            adult                   True
# 40    034A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 39    033A  [adult, adult, adult, adult, adult, senior, ad...         adult            adult                   True
# 38    032A                                     [adult, adult]         adult            adult                   True
# 37    031A  [adult, adult, adult, adult, kitten, adult, se...         adult            adult                   True
# 36    029A  [adult, senior, adult, adult, senior, adult, a...         adult            adult                   True
# 35    028A  [adult, adult, senior, adult, adult, adult, ad...         adult            adult                   True
# 31    026A                       [adult, adult, adult, adult]         adult            adult                   True
# 34    027A  [adult, kitten, senior, adult, adult, adult, k...         adult            adult                   True
# 109   117A  [senior, senior, adult, senior, adult, senior,...        senior           senior                   True
# 32    026B                                            [adult]         adult            adult                   True
# 16    014B  [adult, adult, adult, kitten, adult, kitten, a...         adult           kitten                  False
# 85    090A                                            [adult]         adult           senior                  False
# 108   116A  [senior, senior, senior, senior, adult, senior...         adult           senior                  False
# 26    023B             [adult, adult, senior, senior, senior]        senior            adult                  False
# 67    061A                                     [adult, adult]         adult           senior                  False
# 66    060A                           [kitten, kitten, kitten]        kitten            adult                  False
# 103   109A        [adult, adult, kitten, adult, adult, adult]         adult           kitten                  False
# 102   108A        [adult, adult, adult, senior, adult, adult]         adult           senior                  False
# 101   106A  [adult, adult, adult, adult, adult, adult, sen...         adult           senior                  False
# 64    058A                              [adult, adult, adult]         adult           senior                  False
# 99    104A                       [adult, adult, adult, adult]         adult           senior                  False
# 52    047A  [adult, adult, adult, adult, adult, kitten, ad...         adult           kitten                  False
# 63    057A  [adult, adult, senior, adult, adult, adult, ad...         adult           senior                  False
# 62    056A                              [adult, adult, adult]         adult           senior                  False
# 95    100A                                           [kitten]        kitten            adult                  False
# 61    055A  [adult, adult, adult, senior, adult, adult, ad...         adult           senior                  False
# 56    051A  [adult, adult, adult, adult, senior, adult, ad...         adult           senior                  False
# 92    097A  [adult, senior, senior, adult, adult, adult, a...         adult           senior                  False
# 12    011A                             [senior, adult, adult]         adult           senior                  False
# 18    016A  [adult, adult, adult, adult, adult, adult, sen...         adult           senior                  False
# 82    076A                                           [kitten]        kitten            adult                  False
# 88    093A                                    [kitten, adult]         adult           senior                  False
# 60    054A                                    [adult, senior]         adult           senior                  False
# 86    091A                                           [senior]        senior            adult                  False
# 57    051B  [adult, adult, adult, senior, adult, adult, ad...         adult           senior                  False

# %%
# Create df for majority votes
majority_df = majority_votes.reset_index()
majority_df.columns = ['cat_id', 'Majority_Vote']

# Get actual groups for each cat_id
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first().reset_index()

# Merge majority votes with actual groups
majority_with_actual = pd.merge(majority_df, actual_groups, on='cat_id')

# Add a column to check if the majority vote was correct
majority_with_actual['Majority_Correct'] = majority_with_actual['Majority_Vote'] == majority_with_actual['actual_age_group']

# Count correct majority votes per class
correct_majority_votes_per_class = majority_with_actual.groupby('actual_age_group')['Majority_Correct'].sum()

print("Correct Majority Votes per Class:")
print(correct_majority_votes_per_class)
# Out:
# Correct Majority Votes per Class:
# actual_age_group
# adult     68
# kitten    12
# senior     5
# Name: Majority_Correct, dtype: int64

# %%
# Calculate the total count and the number of correct predictions for each class
class_stats = majority_with_actual.groupby('actual_age_group').agg(
    total_count=('Majority_Correct', 'size'),  # Total number of cases per class
    correct_count=('Majority_Correct', 'sum')  # Sum of correct predictions per class
).reset_index()

# Calculate accuracy for each class
class_stats['accuracy'] = class_stats['correct_count'] / class_stats['total_count'] * 100

# store for final evaluation 
all_majority_vote_details.append(class_stats)

# Log detailed stats
print("Detailed Class Statistics for Majority Votes:")
print(class_stats)
# Out:
# Detailed Class Statistics for Majority Votes:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult           73             68  93.150685
# 1           kitten           15             12  80.000000
# 2           senior           22              5  22.727273

# %%
# Plot for Detailed Class Statistics for Majority Votes
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Accuracy of Majority Votes by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Detailed Class Statistics

# %%
# Calculate the total count and the number of correct predictions for each class
class_stats = full_results.groupby('actual_age_group').agg(
    total_count=('correct', 'size'),
    correct_count=('correct', 'sum')
).reset_index()

# Calculate accuracy for each class
class_stats['accuracy'] = class_stats['correct_count'] / class_stats['total_count'] * 100

# store for final evaluation 
all_class_stats.append(class_stats)

# Log the detailed stats
print("Detailed Class Statistics:")
print(class_stats)
# Out:
# Detailed Class Statistics:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult          578            474  82.006920
# 1           kitten          111             62  55.855856
# 2           senior          186             60  32.258065

# %%
# Plot for Detailed Class Statistics (Overall)
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Overall Accuracy by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Gender Exploration

# %%
# Group by gender and calculate the total count, correct predictions, and accuracy
gender_stats = full_results.groupby('all_gender').agg(
    count=('cat_id', 'size'),  # Total number of cases per gender
    correct=('correct', 'sum')  # Sum of correct predictions per gender
).reset_index()

# Calculate accuracy for each gender
gender_stats['accuracy'] = (gender_stats['correct'] / gender_stats['count'] * 100).round(2)

# Display the DataFrame
print("Accuracy by Gender:")
print(gender_stats)

# store for final evaluation 
all_gender_stats.append(gender_stats)
# Out:
# Accuracy by Gender:
#   all_gender  count  correct  accuracy
# 0          F    218      142     65.14
# 1          M    356      271     76.12
# 2          X    301      183     60.80

# %%
# Plot for Accuracy by Gender
styled_barplot(gender_stats, 'all_gender', 'accuracy', 
               'Accuracy by Gender', 
               'Gender', 'Accuracy (%)')

# %% [markdown]
# ### Log current total CV Stats

# %%
print("Total Majority Vote Accuracy so far:", all_majority_vote_accuracies)
print("Total Class Statistics so far:\n", all_class_stats)
print("Total Gender Accuracy so far:\n", all_gender_stats)
# Out:
# Total Majority Vote Accuracy so far: [0.7727272727272727, 0.7545454545454545, 0.7727272727272727]
# Total Class Statistics so far:
#  [  actual_age_group  total_count  correct_count   accuracy
# 0            adult          573            489  85.340314
# 1           kitten          111             57  51.351351
# 2           senior          186             61  32.795699,   actual_age_group  total_count  correct_count   accuracy
# 0            adult          569            446  78.383128
# 1           kitten          120             45  37.500000
# 2           senior          186             44  23.655914,   actual_age_group  total_count  correct_count   accuracy
# 0            adult          578            474  82.006920
# 1           kitten          111             62  55.855856
# 2           senior          186             60  32.258065]
# Total Gender Accuracy so far:
#  [  all_gender  count  correct  accuracy
# 0          F    218      150     68.81
# 1          M    362      279     77.07
# 2          X    290      178     61.38,   all_gender  count  correct  accuracy
# 0          F    220      133     60.45
# 1          M    356      253     71.07
# 2          X    299      149     49.83,   all_gender  count  correct  accuracy
# 0          F    218      142     65.14
# 1          M    356      271     76.12
# 2          X    301      183     60.80]

# %% [markdown]
# # RANDOM SEED 4

# %%
# Set a fixed random seed for reproducibility
random.seed(int(random_seeds[3])) 
np.random.seed(int(random_seeds[3]))
tf.random.set_seed(int(random_seeds[3]))

# Load datasets
dataframe = pd.read_csv('/Users/astrid/PycharmProjects/data-aug-and-more/yamnet-tfhub-extraction/yamnet_embeddings_looped_april_23.csv')

def assign_age_group(age, age_groups):
    for group_name, age_range in age_groups.items():
        if age_range[0] <= age < age_range[1]:
            return group_name
    return 'Unknown'  # For any age that doesn't fit the defined groups

# Define age groups
age_groups = {
    'kitten': (0, 0.5),
    'adult': (0.5, 12),
    'senior': (12, 20)
}

# Create a new column for the age group
dataframe['age_group'] = dataframe['target'].apply(assign_age_group, age_groups=age_groups)

print(dataframe['age_group'].value_counts())
# Out:
# adult     606
# senior    186
# kitten    176
# Name: age_group, dtype: int64

# %%
# Separate features and labels
X = dataframe.iloc[:, :-4].values  # all columns except the last four

# Encode the 'age_group' column as integers using LabelEncoder
label_encoder = LabelEncoder()
encoded_y = label_encoder.fit_transform(dataframe['age_group'].values)

# Use the encoded labels for splitting and one-hot encoding
y = encoded_y  

# Convert 'cat_id' column to numpy array to be used as groups array for GroupKFold
groups = dataframe['cat_id'].values

# %%
tf.keras.backend.clear_session()

# %% [markdown]
# ## Run Setup

# %%
all_cat_ids = []
all_predicted_age_groups = []
all_actual_age_groups = []
all_gender = []

# Define the StratifiedGroupKFold splitter for 4 fold CV with random shuffling
outer_cv = StratifiedGroupKFold(n_splits=4, shuffle=True, random_state=int(random_seeds[3]))

# unseen test set metrics
unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1 = [], [], [], [], []

outer_fold = 0

# Use the splitter to generate indices for training and testing sets
# Note: GroupShuffleSplit.split returns indices, so we use it to index the arrays
for train_val_idx, test_idx in outer_cv.split(X, y, groups):
    outer_fold += 1
    logger(f"outer_fold {outer_fold}", file=log_file_path)

    # Convert indices back to DataFrame for easy manipulation
    df_train_val = dataframe.iloc[train_val_idx]
    df_test = dataframe.iloc[test_idx]

    ##############################
    # ASSESSING SPLITS BY CAT_ID #
    ##############################
    
    # Get the distribution of groups
    training_validation_group_distribution = df_train_val['cat_id'].value_counts()  
    testing_group_distribution = df_test['cat_id'].value_counts()  
    
    # Log or print the distribution
    logger(f"Train Set Group Distribution:\n{training_validation_group_distribution}", file=log_file_path)
    logger(f"Testing Set Group Distribution:\n{testing_group_distribution}", file=log_file_path)

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val['gender'].value_counts()
    testing_gender_distribution = df_test['gender'].value_counts()
    
    # Log the distribution
    logger(f"Training Set Gender Distribution BEFORE SWAP:\n{training_gender_distribution}", file=log_file_path)
    logger(f"Testing Set Gender Distribution BEFORE SWAP:\n{testing_gender_distribution}", file=log_file_path)

    # Group by 'age_group' and then list unique 'cat_id' within each age group
    unique_cat_ids_per_age_group_train_val = df_train_val.groupby('age_group')['cat_id'].unique()
    unique_cat_ids_per_age_group_test = df_test.groupby('age_group')['cat_id'].unique()
    
    # Log results
    logger(f"Unique Cat IDs per Age Group in Training/Validation Set:\n{unique_cat_ids_per_age_group_train_val}", file=log_file_path)
    logger(f"Unique Cat IDs per Age Group in Testing Set:\n{unique_cat_ids_per_age_group_test}", file=log_file_path)

    # Calculate the count of unique identifiers per age group for training and testing set
    counts_train_val = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_train_val.items()}
    counts_test = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_test.items()}

    # Log the counts of unique identifiers per age group
    logger(f"Count of Unique Cat IDs per Age Group in Training/Validation Set:\n{counts_train_val}", file=log_file_path)
    logger(f"Count of Unique Cat IDs per Age Group in Testing Set:\n{counts_test}", file=log_file_path)

    #######################################################
    # CONTINUE WITH ENSURING VALID AND APPROPRIATE SPLITS #
    #######################################################
    
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    groups_train_val, groups_test = groups[train_val_idx], groups[test_idx]

    # logging identifier splits 
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)

    # check group splits
    check_initial_group_split(groups_train_val, groups_test)

    # Specify the cat_ids that must be in the training/validation set
    specific_cat_ids = ['000A', '046A']
    
    # Perform the swapping operation
    train_val_idx, test_idx = swap_cat_id_instances(dataframe, train_val_idx, test_idx, specific_cat_ids)
    
    # Re-assign the sets based on the updated indices
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    new_groups_train_val, new_groups_test = groups[train_val_idx], groups[test_idx]

    # Find differences for training and test sets
    moved_to_train_val, removed_from_train_val = find_group_differences(groups_train_val, new_groups_train_val)
    moved_to_test, removed_from_test = find_group_differences(groups_test, new_groups_test)
    
    # Display the results
    logger(f"Moved to Training/Validation Set:\n{moved_to_train_val}", file=log_file_path)
    logger(f"Removed from Training/Validation Set:\n{removed_from_train_val}", file=log_file_path)
    logger(f"Moved to Test Set:\n{moved_to_test}", file=log_file_path)
    logger(f"Removed from Test Set\n{removed_from_test}", file=log_file_path)

    # Update X_train_val, X_test, y_train_val, y_test, groups_train_val, groups_test based on updated indices
    X_train_val = X[train_val_idx]
    y_train_val = y[train_val_idx]
    groups_train_val = groups[train_val_idx]
    
    X_test = X[test_idx]
    y_test = y[test_idx]
    groups_test = groups[test_idx]

    # logging identifier splits again after potential swaps
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"AFTER SWAP - Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"AFTER SWAP - Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)
    
    # Verify the lengths are consistent
    logger(f"Length of X_train_val:\n{len(X_train_val)}", file=log_file_path)
    logger(f"Length of y_train_val:\n{len(y_train_val)}", file=log_file_path)
    logger(f"Length of groups_train_val:\n{len(groups_train_val)}", file=log_file_path)

    # Check group splits once more
    check_initial_group_split(groups_train_val, groups_test)

    # Convert the modified indices back to a DataFrame representing the updated df_train_val
    df_train_val_updated = dataframe.iloc[train_val_idx].copy()
    df_test_updated = dataframe.iloc[test_idx].copy()

    ############################
    # LOGGING AGE GROUP SPLITS #
    ############################

    # Get the distribution of age groups of age groups before the update
    training_validation_age_group_distribution = df_train_val['age_group'].value_counts()
    testing_age_group_distribution = df_test['age_group'].value_counts()
    
    # Logthe distribution
    logger(f"Train Age Group Distribution BEFORE SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution BEFORE SWAP:\n{testing_age_group_distribution}", file=log_file_path)

    # Get the distribution of age groups after the update
    training_validation_age_group_distribution = df_train_val_updated['age_group'].value_counts()
    testing_age_group_distribution = df_test_updated['age_group'].value_counts()
    
    # Log the distribution
    logger(f"Train Age Group Distribution AFTER SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution AFTER SWAP:\n{testing_age_group_distribution}", file=log_file_path)
    
    ########################################################
    # TRACKING FINAL CAT_IDs & GENDER AFTER REDISTRIBUTION #
    ########################################################

    # Get the distribution of groups
    training_validation_group_distribution = df_train_val_updated['cat_id'].value_counts()  
    testing_group_distribution = df_test_updated['cat_id'].value_counts()  

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val_updated['gender'].value_counts()
    testing_gender_distribution = df_test_updated['gender'].value_counts()
    
    logger(f"\n Starting training on unseen test set\n", file=log_file_path)

    ###################
    # PREPARING MODEL #
    ###################

    # Calculate the distribution of age groups in y_train_val
    age_group_distribution = Counter(y_train_val)
    print("Age group distribution:", age_group_distribution)

    # EarlyStopping callback: monitor 'loss' instead of 'val_loss' for the test set
    early_stopping = EarlyStopping(
        monitor='loss',  
        min_delta=0.001, 
        patience=30,  
        verbose=1,  
        restore_best_weights=True  
    )

    # Apply SMOTE to the training data only
    smote = SMOTE()
    X_train_val, y_train_val = smote.fit_resample(X_train_val, y_train_val)

    # One final shuffle to ensure randomness
    outer_shuffle_idx = np.random.permutation(len(X_train_val))
    X_train_val = X_train_val[outer_shuffle_idx]
    y_train_val = y_train_val[outer_shuffle_idx]
    
    # Scale the features
    scaler_full = StandardScaler().fit(X_train_val)
    X_train_full_scaled = scaler_full.transform(X_train_val)
    X_test_scaled = scaler_full.transform(X_test)
    
    # Encode the labels
    y_train_full_encoded = to_categorical(y_train_val)
    y_test_encoded = to_categorical(y_test)

    #######################
    # BUILD & TRAIN MODEL #
    #######################

    optimizers = {
        'Adamax': Adamax(learning_rate=0.00510251984616472)
    }
    
    # Model definition with dynamic number of layers
    model_full = Sequential()
    model_full.add(Dense(480, activation='relu', input_shape=(X_train_full_scaled.shape[1],)))
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.2011047009431978))  
    model_full.add(Dense(256, activation='relu',)) 
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.14956886311951184))  
    model_full.add(Dense(256, activation='relu'))  
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.42291461228250665))  
    model_full.add(Dense(3, activation='softmax'))  
    
    # Use the optimizer from the parameters
    optimizer = optimizers['Adamax']  # optimizer_key from parameters
    
    # Compile the model
    model_full.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    
    # Train the model on the full training set
    history_full = model_full.fit(X_train_full_scaled, y_train_full_encoded, epochs=1500, batch_size=64,
                                  verbose=1, callbacks=[early_stopping])
    
    # Evaluate the model on the held-out test set
    test_loss, test_accuracy = model_full.evaluate(X_test_scaled, y_test_encoded)

    y_test_pred_prob = model_full.predict(X_test_scaled)
    y_test_pred = np.argmax(y_test_pred_prob, axis=1)  
    y_test_true = np.argmax(y_test_encoded, axis=1)    

    ################################
    # LOG MAJORITY VOTE PER CAT_ID #
    ################################

    # Convert numeric predictions back to age group labels
    predicted_age_groups = label_encoder.inverse_transform(y_test_pred)
    actual_labels = label_encoder.inverse_transform(y_test_true)
    
    # Map predictions and actual labels back to cat_ids
    test_results = pd.DataFrame({
        'cat_id': df_test_updated['cat_id'],
        'predicted_age_group': predicted_age_groups,
        'actual_age_group': actual_labels
    })
    
    # Group by cat_id and aggregate predicted age groups
    majority_votes = test_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
    actual_groups = test_results.groupby('cat_id')['actual_age_group'].first()
    
    # Calculate the accuracy of majority voting
    correct_predictions = (majority_votes == actual_groups).sum()
    total_cats = len(actual_groups)
    majority_vote_accuracy = correct_predictions / total_cats
    
    # Log the accuracy of the majority voting
    logger(f"Majority Vote Accuracy for cat_id for this fold: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

    ####################################################
    # COLLECT PREDICTIONS FOR GENDER & CAT_ID ANALYSIS #
    ####################################################

    # Debugging print statements
    print(f'Before appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Extend lists with current fold results
    all_cat_ids.extend(df_test_updated['cat_id'].tolist())
    all_predicted_age_groups.extend(predicted_age_groups)
    all_actual_age_groups.extend(actual_labels)
    all_gender.extend(df_test_updated['gender'].tolist())

    # Debugging print statements
    print(f'After appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Calculate additional metrics
    test_precision = precision_score(y_test_true, y_test_pred, average='macro')  # Use 'macro' for imbalanced datasets
    test_recall = recall_score(y_test_true, y_test_pred, average='macro')
    test_f1 = f1_score(y_test_true, y_test_pred, average='macro')

    # prepare averages of outer metrics
    unseen_f1.append(test_f1)
    unseen_losses.append(test_loss)
    unseen_accuracies.append(test_accuracy)
    unseen_precisions.append(test_precision)
    unseen_recalls.append(test_recall)

    # Print final test results
    logger(f"Final Test Results - Loss: {test_loss}, Accuracy: {test_accuracy}, Precision: {test_precision}, Recall: {test_recall}, F1 Score: {test_f1}", file=log_file_path)

    # Generate the confusion matrix
    cm = confusion_matrix(y_test, y_test_pred)
    logger(f"Confusion Matrix:\n {cm}", file=log_file_path)

# Calculate the overall average metrics
unseen_set_avg_f1 = np.mean(unseen_f1)
unseen_set_avg_loss = np.mean(unseen_losses)
unseen_set_avg_acc = np.mean(unseen_accuracies)
unseen_set_avg_precision = np.mean(unseen_precisions)
unseen_set_avg_recall = np.mean(unseen_recalls)

logger(f"\nFinal Average F1-Score across all UNSEEN TEST sets: {unseen_set_avg_f1}", file=log_file_path)
logger(f"\nFinal Average Loss across all UNSEEN TEST sets: {unseen_set_avg_loss}", file=log_file_path)
logger(f"\nFinal Average Accuracy across all UNSEEN TEST sets: {unseen_set_avg_acc}", file=log_file_path)
logger(f"\nFinal Average Precision across all UNSEEN TEST sets: {unseen_set_avg_precision}", file=log_file_path)
logger(f"\nFinal Average Recall across all UNSEEN TEST sets: {unseen_set_avg_recall}\n", file=log_file_path)

# Append averages to total lists
all_f1.append(unseen_set_avg_f1)
all_losses.append(unseen_set_avg_loss)
all_accuracies.append(unseen_set_avg_acc)
all_precisions.append(unseen_set_avg_precision)
all_recalls.append(unseen_set_avg_recall)
# Out:
# outer_fold 1
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Train Set Group Distribution:
# 046A    66
# 000A    39
# 002B    36
# 103A    33
# 047A    30
# 057A    28
# 074A    25
# 020A    23
# 067A    20
# 059A    18
# 019A    17
# 029A    17
# 101A    16
# 097A    16
# 106A    15
# 001A    15
# 042A    14
# 097B    14
# 111A    13
# 002A    13
# 116A    12
# 039A    12
# 051A    12
# 005A    11
# 016A    11
# 025A    11
# 068A    11
# 063A    11
# 014B    10
# 040A    10
# 015A    10
# 065A     9
# 022A     9
# 045A     9
# 051B     9
# 072A     9
# 013B     8
# 095A     8
# 027A     7
# 050A     7
# 053A     7
# 023A     6
# 008A     6
# 037A     6
# 025C     6
# 109A     6
# 007A     6
# 021A     6
# 034A     5
# 070A     5
# 012A     5
# 062A     5
# 023B     5
# 075A     5
# 105A     4
# 052A     4
# 035A     4
# 104A     4
# 026A     4
# 003A     4
# 014A     3
# 060A     3
# 056A     3
# 064A     3
# 058A     3
# 006A     3
# 038A     2
# 032A     2
# 054A     2
# 087A     2
# 093A     2
# 102A     2
# 018A     2
# 069A     2
# 025B     2
# 110A     1
# 004A     1
# 115A     1
# 041A     1
# 092A     1
# 019B     1
# 049A     1
# 090A     1
# 026C     1
# 073A     1
# 091A     1
# 100A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 000B    20
# 055A    20
# 028A    14
# 036A    11
# 071A    10
# 033A     9
# 094A     8
# 010A     8
# 031A     7
# 117A     7
# 099A     7
# 108A     6
# 044A     5
# 009A     4
# 113A     3
# 011A     3
# 061A     2
# 066A     2
# 076A     1
# 048A     1
# 088A     1
# 096A     1
# 043A     1
# 024A     1
# 026B     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    326
# M    323
# F    166
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# F    91
# M    33
# X    29
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [002A, 070A, 020A, 000A, 015A, 026A, 065A, 053...
# kitten    [046A, 042A, 014B, 110A, 109A, 040A, 047A, 049...
# senior    [106A, 057A, 090A, 051B, 116A, 051A, 097A, 059...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [028A, 033A, 000B, 071A, 009A, 010A, 031A, 036...
# kitten                                   [048A, 044A, 043A]
# senior     [117A, 113A, 024A, 094A, 055A, 108A, 061A, 011A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 60, 'kitten': 13, 'senior': 14}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 14, 'kitten': 3, 'senior': 8}
# Unique Training/Validation Group IDs:
# ['000A' '001A' '002A' '002B' '003A' '004A' '005A' '006A' '007A' '008A'
#  '012A' '013B' '014A' '014B' '015A' '016A' '018A' '019A' '019B' '020A'
#  '021A' '022A' '023A' '023B' '025A' '025B' '025C' '026A' '026C' '027A'
#  '029A' '032A' '034A' '035A' '037A' '038A' '039A' '040A' '041A' '042A'
#  '045A' '046A' '047A' '049A' '050A' '051A' '051B' '052A' '053A' '054A'
#  '056A' '057A' '058A' '059A' '060A' '062A' '063A' '064A' '065A' '067A'
#  '068A' '069A' '070A' '072A' '073A' '074A' '075A' '087A' '090A' '091A'
#  '092A' '093A' '095A' '097A' '097B' '100A' '101A' '102A' '103A' '104A'
#  '105A' '106A' '109A' '110A' '111A' '115A' '116A']
# Unique Test Group IDs:
# ['000B' '009A' '010A' '011A' '024A' '026B' '028A' '031A' '033A' '036A'
#  '043A' '044A' '048A' '055A' '061A' '066A' '071A' '076A' '088A' '094A'
#  '096A' '099A' '108A' '113A' '117A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '001A' '002A' '002B' '003A' '004A' '005A' '006A' '007A' '008A'
#  '012A' '013B' '014A' '014B' '015A' '016A' '018A' '019A' '019B' '020A'
#  '021A' '022A' '023A' '023B' '025A' '025B' '025C' '026A' '026C' '027A'
#  '029A' '032A' '034A' '035A' '037A' '038A' '039A' '040A' '041A' '042A'
#  '045A' '046A' '047A' '049A' '050A' '051A' '051B' '052A' '053A' '054A'
#  '056A' '057A' '058A' '059A' '060A' '062A' '063A' '064A' '065A' '067A'
#  '068A' '069A' '070A' '072A' '073A' '074A' '075A' '087A' '090A' '091A'
#  '092A' '093A' '095A' '097A' '097B' '100A' '101A' '102A' '103A' '104A'
#  '105A' '106A' '109A' '110A' '111A' '115A' '116A']
# AFTER SWAP - Unique Test Group IDs:
# ['000B' '009A' '010A' '011A' '024A' '026B' '028A' '031A' '033A' '036A'
#  '043A' '044A' '048A' '055A' '061A' '066A' '071A' '076A' '088A' '094A'
#  '096A' '099A' '108A' '113A' '117A']
# Length of X_train_val:
# 815
# Length of y_train_val:
# 815
# Length of groups_train_val:
# 815
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     510
# kitten    169
# senior    136
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     96
# senior    50
# kitten     7
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     510
# kitten    169
# senior    136
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     96
# senior    50
# kitten     7
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 510, 1: 169, 2: 136})
# Epoch 1/1500
# 24/24 [==============================] - 1s 6ms/step - loss: 0.7681 - accuracy: 0.7281
# Epoch 2/1500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.2865 - accuracy: 0.8948
# Epoch 3/1500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1814 - accuracy: 0.9353
# Epoch 4/1500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1192 - accuracy: 0.9582
# Epoch 5/1500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0914 - accuracy: 0.9660
# Epoch 6/1500
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0751 - accuracy: 0.9758
# Epoch 7/1500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0394 - accuracy: 0.9837
# Epoch 8/1500
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0464 - accuracy: 0.9830
# Epoch 9/1500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0287 - accuracy: 0.9895
# Epoch 10/1500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0309 - accuracy: 0.9882
# Epoch 11/1500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0237 - accuracy: 0.9928
# Epoch 12/1500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0217 - accuracy: 0.9935
# Epoch 13/1500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0108 - accuracy: 0.9980
# Epoch 14/1500
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0116 - accuracy: 0.9967
# Epoch 15/1500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0137 - accuracy: 0.9948
# Epoch 16/1500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0099 - accuracy: 0.9974
# Epoch 17/1500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0146 - accuracy: 0.9954
# Epoch 18/1500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0103 - accuracy: 0.9967
# Epoch 19/1500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0170 - accuracy: 0.9954
# Epoch 20/1500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0230 - accuracy: 0.9922
# Epoch 21/1500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0131 - accuracy: 0.9948
# Epoch 22/1500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0101 - accuracy: 0.9974
# Epoch 23/1500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0156 - accuracy: 0.9928
# Epoch 24/1500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0095 - accuracy: 0.9961
# Epoch 25/1500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0099 - accuracy: 0.9974
# Epoch 26/1500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0048 - accuracy: 0.9987
# Epoch 27/1500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0078 - accuracy: 0.9974
# Epoch 28/1500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0121 - accuracy: 0.9961
# Epoch 29/1500
# 24/24 [==============================] - 0s 8ms/step - loss: 0.0070 - accuracy: 0.9974
# Epoch 30/1500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0070 - accuracy: 0.9980
# Epoch 31/1500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0036 - accuracy: 0.9993
# Epoch 32/1500
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0039 - accuracy: 0.9993
# Epoch 33/1500
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0051 - accuracy: 0.9993
# Epoch 34/1500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0061 - accuracy: 0.9980
# Epoch 35/1500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0118 - accuracy: 0.9974
# Epoch 36/1500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.0072 - accuracy: 0.9974
# Epoch 37/1500
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0068 - accuracy: 0.9974
# Epoch 38/1500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 39/1500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0030 - accuracy: 0.9993
# Epoch 40/1500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0022 - accuracy: 0.9993
# Epoch 41/1500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0049 - accuracy: 0.9987
# Epoch 42/1500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0067 - accuracy: 0.9980
# Epoch 43/1500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0035 - accuracy: 0.9987
# Epoch 44/1500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0024 - accuracy: 0.9993
# Epoch 45/1500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0023 - accuracy: 0.9993
# Epoch 46/1500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0036 - accuracy: 0.9980
# Epoch 47/1500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0051 - accuracy: 0.9980
# Epoch 48/1500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0078 - accuracy: 0.9974
# Epoch 49/1500
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0039 - accuracy: 0.9980
# Epoch 50/1500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0047 - accuracy: 0.9980
# Epoch 51/1500
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0061 - accuracy: 0.9967
# Epoch 52/1500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0200 - accuracy: 0.9935
# Epoch 53/1500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0066 - accuracy: 0.9980
# Epoch 54/1500
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0078 - accuracy: 0.9961
# Epoch 55/1500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0133 - accuracy: 0.9948
# Epoch 56/1500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0044 - accuracy: 0.9987
# Epoch 57/1500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0044 - accuracy: 0.9980
# Epoch 58/1500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0091 - accuracy: 0.9954
# Epoch 59/1500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0059 - accuracy: 0.9974
# Epoch 60/1500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0063 - accuracy: 0.9974
# Epoch 61/1500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0096 - accuracy: 0.9961
# Epoch 62/1500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0117 - accuracy: 0.9961
# Epoch 63/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0078 - accuracy: 0.9967
# Epoch 64/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0084 - accuracy: 0.9967
# Epoch 65/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0048 - accuracy: 0.9987
# Epoch 66/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0025 - accuracy: 0.9993
# Epoch 67/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0024 - accuracy: 0.9993
# Epoch 68/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0014 - accuracy: 0.9993
# Epoch 69/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0026 - accuracy: 0.9993
# Epoch 70/1500
# 23/24 [===========================>..] - ETA: 0s - loss: 0.0026 - accuracy: 0.9986Restoring model weights from the end of the best epoch: 40.
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0025 - accuracy: 0.9987
# Epoch 70: early stopping
# 5/5 [==============================] - 0s 2ms/step - loss: 2.7470 - accuracy: 0.7059
# 5/5 [==============================] - 0s 2ms/step
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Majority Vote Accuracy for cat_id for this fold: 0.76 (19/25)
# Before appending - Cat IDs: 0, Predictions: 0, Actuals: 0, Gender: 0
# After appending - Cat IDs: 153, Predictions: 153, Actuals: 153, Gender: 153
# Final Test Results - Loss: 2.747002124786377, Accuracy: 0.7058823704719543, Precision: 0.6771978021978023, Recall: 0.653234126984127, F1 Score: 0.6436828505371956
# Confusion Matrix:
#  [[85  3  8]
#  [ 2  5  0]
#  [32  0 18]]
# outer_fold 2
# Train Set Group Distribution:
# 046A    66
# 000A    39
# 002B    36
# 103A    33
# 047A    30
# 074A    25
# 020A    23
# 000B    20
# 055A    20
# 059A    18
# 019A    17
# 101A    16
# 106A    15
# 001A    15
# 028A    14
# 111A    13
# 116A    12
# 051A    12
# 039A    12
# 016A    11
# 036A    11
# 005A    11
# 071A    10
# 040A    10
# 065A     9
# 072A     9
# 033A     9
# 095A     8
# 010A     8
# 094A     8
# 050A     7
# 099A     7
# 027A     7
# 031A     7
# 053A     7
# 117A     7
# 021A     6
# 008A     6
# 025C     6
# 108A     6
# 007A     6
# 037A     6
# 023A     6
# 075A     5
# 012A     5
# 034A     5
# 070A     5
# 044A     5
# 035A     4
# 009A     4
# 026A     4
# 003A     4
# 104A     4
# 105A     4
# 052A     4
# 014A     3
# 064A     3
# 056A     3
# 058A     3
# 011A     3
# 113A     3
# 087A     2
# 066A     2
# 069A     2
# 061A     2
# 018A     2
# 032A     2
# 026B     1
# 115A     1
# 076A     1
# 024A     1
# 096A     1
# 026C     1
# 073A     1
# 088A     1
# 091A     1
# 043A     1
# 110A     1
# 048A     1
# 092A     1
# 090A     1
# 100A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 057A    28
# 067A    20
# 029A    17
# 097A    16
# 042A    14
# 097B    14
# 002A    13
# 025A    11
# 063A    11
# 068A    11
# 015A    10
# 014B    10
# 045A     9
# 051B     9
# 022A     9
# 013B     8
# 109A     6
# 062A     5
# 023B     5
# 006A     3
# 060A     3
# 038A     2
# 102A     2
# 054A     2
# 025B     2
# 093A     2
# 049A     1
# 019B     1
# 041A     1
# 004A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    290
# X    224
# F    208
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    131
# M     66
# F     49
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [028A, 070A, 033A, 000B, 071A, 020A, 000A, 026...
# kitten    [046A, 110A, 040A, 047A, 048A, 111A, 044A, 043...
# senior    [117A, 106A, 090A, 113A, 116A, 051A, 024A, 094...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [002A, 015A, 023B, 038A, 068A, 013B, 062A, 006...
# kitten                 [042A, 014B, 109A, 049A, 045A, 041A]
# senior                       [057A, 051B, 097A, 054A, 093A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 55, 'kitten': 10, 'senior': 17}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 19, 'kitten': 6, 'senior': 5}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002B' '003A' '005A' '007A' '008A' '009A' '010A'
#  '011A' '012A' '014A' '016A' '018A' '019A' '020A' '021A' '023A' '024A'
#  '025C' '026A' '026B' '026C' '027A' '028A' '031A' '032A' '033A' '034A'
#  '035A' '036A' '037A' '039A' '040A' '043A' '044A' '046A' '047A' '048A'
#  '050A' '051A' '052A' '053A' '055A' '056A' '058A' '059A' '061A' '064A'
#  '065A' '066A' '069A' '070A' '071A' '072A' '073A' '074A' '075A' '076A'
#  '087A' '088A' '090A' '091A' '092A' '094A' '095A' '096A' '099A' '100A'
#  '101A' '103A' '104A' '105A' '106A' '108A' '110A' '111A' '113A' '115A'
#  '116A' '117A']
# Unique Test Group IDs:
# ['002A' '004A' '006A' '013B' '014B' '015A' '019B' '022A' '023B' '025A'
#  '025B' '029A' '038A' '041A' '042A' '045A' '049A' '051B' '054A' '057A'
#  '060A' '062A' '063A' '067A' '068A' '093A' '097A' '097B' '102A' '109A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002B' '003A' '005A' '007A' '008A' '009A' '010A'
#  '011A' '012A' '014A' '016A' '018A' '019A' '020A' '021A' '023A' '024A'
#  '025C' '026A' '026B' '026C' '027A' '028A' '031A' '032A' '033A' '034A'
#  '035A' '036A' '037A' '039A' '040A' '043A' '044A' '046A' '047A' '048A'
#  '050A' '051A' '052A' '053A' '055A' '056A' '058A' '059A' '061A' '064A'
#  '065A' '066A' '069A' '070A' '071A' '072A' '073A' '074A' '075A' '076A'
#  '087A' '088A' '090A' '091A' '092A' '094A' '095A' '096A' '099A' '100A'
#  '101A' '103A' '104A' '105A' '106A' '108A' '110A' '111A' '113A' '115A'
#  '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['002A' '004A' '006A' '013B' '014B' '015A' '019B' '022A' '023B' '025A'
#  '025B' '029A' '038A' '041A' '042A' '045A' '049A' '051B' '054A' '057A'
#  '060A' '062A' '063A' '067A' '068A' '093A' '097A' '097B' '102A' '109A']
# Length of X_train_val:
# 722
# Length of y_train_val:
# 722
# Length of groups_train_val:
# 722
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     458
# kitten    135
# senior    129
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     148
# senior     57
# kitten     41
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     458
# kitten    135
# senior    129
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     148
# senior     57
# kitten     41
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 458, 1: 135, 2: 129})
# Epoch 1/1500
# 22/22 [==============================] - 1s 5ms/step - loss: 0.8240 - accuracy: 0.7140
# Epoch 2/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.2832 - accuracy: 0.9003
# Epoch 3/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1394 - accuracy: 0.9512
# Epoch 4/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0953 - accuracy: 0.9658
# Epoch 5/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0735 - accuracy: 0.9760
# Epoch 6/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0567 - accuracy: 0.9840
# Epoch 7/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0469 - accuracy: 0.9840
# Epoch 8/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0395 - accuracy: 0.9854
# Epoch 9/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0257 - accuracy: 0.9927
# Epoch 10/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0404 - accuracy: 0.9854
# Epoch 11/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0220 - accuracy: 0.9913
# Epoch 12/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0223 - accuracy: 0.9920
# Epoch 13/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0120 - accuracy: 0.9964
# Epoch 14/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0123 - accuracy: 0.9978
# Epoch 15/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0118 - accuracy: 0.9964
# Epoch 16/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0136 - accuracy: 0.9956
# Epoch 17/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0067 - accuracy: 0.9978
# Epoch 18/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0061 - accuracy: 1.0000
# Epoch 19/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0076 - accuracy: 0.9978
# Epoch 20/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0117 - accuracy: 0.9949
# Epoch 21/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0099 - accuracy: 0.9971
# Epoch 22/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0061 - accuracy: 0.9993
# Epoch 23/1500
# 22/22 [==============================] - 0s 9ms/step - loss: 0.0075 - accuracy: 0.9978
# Epoch 24/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0038 - accuracy: 0.9993
# Epoch 25/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0060 - accuracy: 0.9978
# Epoch 26/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0117 - accuracy: 0.9964
# Epoch 27/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0057 - accuracy: 0.9985
# Epoch 28/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0042 - accuracy: 0.9993
# Epoch 29/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 30/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0054 - accuracy: 0.9978
# Epoch 31/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0081 - accuracy: 0.9964
# Epoch 32/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0070 - accuracy: 0.9978
# Epoch 33/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0057 - accuracy: 0.9993
# Epoch 34/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0040 - accuracy: 0.9985
# Epoch 35/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0065 - accuracy: 0.9993
# Epoch 36/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0131 - accuracy: 0.9956
# Epoch 37/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0070 - accuracy: 0.9985
# Epoch 38/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0133 - accuracy: 0.9964
# Epoch 39/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0173 - accuracy: 0.9934
# Epoch 40/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0056 - accuracy: 0.9985
# Epoch 41/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0057 - accuracy: 0.9985
# Epoch 42/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0046 - accuracy: 0.9985
# Epoch 43/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0121 - accuracy: 0.9949
# Epoch 44/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0053 - accuracy: 0.9985
# Epoch 45/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0117 - accuracy: 0.9942
# Epoch 46/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0036 - accuracy: 0.9993
# Epoch 47/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0024 - accuracy: 0.9993
# Epoch 48/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0079 - accuracy: 0.9971
# Epoch 49/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0082 - accuracy: 0.9971
# Epoch 50/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0088 - accuracy: 0.9978
# Epoch 51/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0114 - accuracy: 0.9971
# Epoch 52/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0037 - accuracy: 0.9993
# Epoch 53/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0043 - accuracy: 0.9978
# Epoch 54/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0032 - accuracy: 0.9985
# Epoch 55/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0030 - accuracy: 0.9993
# Epoch 56/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0032 - accuracy: 0.9993
# Epoch 57/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0052 - accuracy: 0.9964
# Epoch 58/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0038 - accuracy: 0.9993
# Epoch 59/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0037 - accuracy: 0.9985
# Epoch 60/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0070 - accuracy: 0.9985
# Epoch 61/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 62/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0043 - accuracy: 0.9978
# Epoch 63/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0038 - accuracy: 0.9985
# Epoch 64/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 65/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0016 - accuracy: 0.9993
# Epoch 66/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 67/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 68/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 3.5149e-04 - accuracy: 1.0000
# Epoch 69/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0031 - accuracy: 0.9993
# Epoch 70/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0016 - accuracy: 0.9993
# Epoch 71/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 3.0105e-04 - accuracy: 1.0000
# Epoch 72/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0024 - accuracy: 0.9993
# Epoch 73/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0018 - accuracy: 0.9993
# Epoch 74/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0028 - accuracy: 0.9993
# Epoch 75/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0035 - accuracy: 0.9978
# Epoch 76/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0035 - accuracy: 0.9993
# Epoch 77/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0080 - accuracy: 0.9964
# Epoch 78/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0044 - accuracy: 0.9993
# Epoch 79/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0069 - accuracy: 0.9985
# Epoch 80/1500
# 22/22 [==============================] - 0s 8ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 81/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0014 - accuracy: 0.9993
# Epoch 82/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0092 - accuracy: 0.9985
# Epoch 83/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0194 - accuracy: 0.9942
# Epoch 84/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0100 - accuracy: 0.9964
# Epoch 85/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0052 - accuracy: 0.9978
# Epoch 86/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0087 - accuracy: 0.9971
# Epoch 87/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0153 - accuracy: 0.9934
# Epoch 88/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0141 - accuracy: 0.9964
# Epoch 89/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0119 - accuracy: 0.9964
# Epoch 90/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0043 - accuracy: 0.9985
# Epoch 91/1500
# 21/22 [===========================>..] - ETA: 0s - loss: 0.0064 - accuracy: 0.9970Restoring model weights from the end of the best epoch: 61.
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0062 - accuracy: 0.9971
# Epoch 91: early stopping
# 8/8 [==============================] - 0s 1ms/step - loss: 3.7621 - accuracy: 0.6382
# 8/8 [==============================] - 0s 1ms/step
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Majority Vote Accuracy for cat_id for this fold: 0.67 (20/30)
# Before appending - Cat IDs: 153, Predictions: 153, Actuals: 153, Gender: 153
# After appending - Cat IDs: 399, Predictions: 399, Actuals: 399, Gender: 399
# Final Test Results - Loss: 3.762122869491577, Accuracy: 0.6382113695144653, Precision: 0.6047864225781846, Recall: 0.525095699036649, F1 Score: 0.5372130811101886
# Confusion Matrix:
#  [[122  18   8]
#  [ 20  20   1]
#  [ 42   0  15]]
# outer_fold 3
# Train Set Group Distribution:
# 046A    66
# 000A    39
# 047A    30
# 057A    28
# 074A    25
# 020A    23
# 000B    20
# 067A    20
# 055A    20
# 029A    17
# 019A    17
# 097A    16
# 097B    14
# 042A    14
# 028A    14
# 111A    13
# 002A    13
# 116A    12
# 051A    12
# 005A    11
# 025A    11
# 036A    11
# 063A    11
# 016A    11
# 068A    11
# 071A    10
# 015A    10
# 014B    10
# 022A     9
# 045A     9
# 051B     9
# 072A     9
# 033A     9
# 095A     8
# 010A     8
# 013B     8
# 094A     8
# 099A     7
# 117A     7
# 050A     7
# 031A     7
# 053A     7
# 007A     6
# 108A     6
# 109A     6
# 021A     6
# 044A     5
# 075A     5
# 034A     5
# 023B     5
# 062A     5
# 009A     4
# 003A     4
# 052A     4
# 104A     4
# 060A     3
# 006A     3
# 014A     3
# 011A     3
# 113A     3
# 056A     3
# 025B     2
# 018A     2
# 066A     2
# 061A     2
# 038A     2
# 102A     2
# 069A     2
# 054A     2
# 093A     2
# 004A     1
# 041A     1
# 076A     1
# 110A     1
# 019B     1
# 088A     1
# 096A     1
# 043A     1
# 048A     1
# 049A     1
# 024A     1
# 026B     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 002B    36
# 103A    33
# 059A    18
# 101A    16
# 106A    15
# 001A    15
# 039A    12
# 040A    10
# 065A     9
# 027A     7
# 023A     6
# 025C     6
# 037A     6
# 008A     6
# 070A     5
# 012A     5
# 035A     4
# 026A     4
# 105A     4
# 058A     3
# 064A     3
# 032A     2
# 087A     2
# 092A     1
# 073A     1
# 091A     1
# 090A     1
# 026C     1
# 115A     1
# 100A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    313
# F    221
# M    200
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# M    156
# X     42
# F     36
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [002A, 028A, 033A, 000B, 071A, 020A, 000A, 015...
# kitten    [046A, 042A, 014B, 110A, 109A, 047A, 049A, 045...
# senior    [117A, 057A, 113A, 051B, 116A, 051A, 024A, 097...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [070A, 026A, 065A, 026C, 001A, 105A, 002B, 091...
# kitten                                         [040A, 115A]
# senior                             [106A, 090A, 059A, 058A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 50, 'kitten': 14, 'senior': 18}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 24, 'kitten': 2, 'senior': 4}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '002A' '003A' '004A' '005A' '006A' '007A' '009A' '010A'
#  '011A' '013B' '014A' '014B' '015A' '016A' '018A' '019A' '019B' '020A'
#  '021A' '022A' '023B' '024A' '025A' '025B' '026B' '028A' '029A' '031A'
#  '033A' '034A' '036A' '038A' '041A' '042A' '043A' '044A' '045A' '046A'
#  '047A' '048A' '049A' '050A' '051A' '051B' '052A' '053A' '054A' '055A'
#  '056A' '057A' '060A' '061A' '062A' '063A' '066A' '067A' '068A' '069A'
#  '071A' '072A' '074A' '075A' '076A' '088A' '093A' '094A' '095A' '096A'
#  '097A' '097B' '099A' '102A' '104A' '108A' '109A' '110A' '111A' '113A'
#  '116A' '117A']
# Unique Test Group IDs:
# ['001A' '002B' '008A' '012A' '023A' '025C' '026A' '026C' '027A' '032A'
#  '035A' '037A' '039A' '040A' '058A' '059A' '064A' '065A' '070A' '073A'
#  '087A' '090A' '091A' '092A' '100A' '101A' '103A' '105A' '106A' '115A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '002A' '003A' '004A' '005A' '006A' '007A' '009A' '010A'
#  '011A' '013B' '014A' '014B' '015A' '016A' '018A' '019A' '019B' '020A'
#  '021A' '022A' '023B' '024A' '025A' '025B' '026B' '028A' '029A' '031A'
#  '033A' '034A' '036A' '038A' '041A' '042A' '043A' '044A' '045A' '046A'
#  '047A' '048A' '049A' '050A' '051A' '051B' '052A' '053A' '054A' '055A'
#  '056A' '057A' '060A' '061A' '062A' '063A' '066A' '067A' '068A' '069A'
#  '071A' '072A' '074A' '075A' '076A' '088A' '093A' '094A' '095A' '096A'
#  '097A' '097B' '099A' '102A' '104A' '108A' '109A' '110A' '111A' '113A'
#  '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['001A' '002B' '008A' '012A' '023A' '025C' '026A' '026C' '027A' '032A'
#  '035A' '037A' '039A' '040A' '058A' '059A' '064A' '065A' '070A' '073A'
#  '087A' '090A' '091A' '092A' '100A' '101A' '103A' '105A' '106A' '115A']
# Length of X_train_val:
# 734
# Length of y_train_val:
# 734
# Length of groups_train_val:
# 734
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     420
# kitten    165
# senior    149
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     186
# senior     37
# kitten     11
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     420
# kitten    165
# senior    149
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     186
# senior     37
# kitten     11
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 420, 1: 165, 2: 149})
# Epoch 1/1500
# 20/20 [==============================] - 1s 5ms/step - loss: 0.8655 - accuracy: 0.6960
# Epoch 2/1500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.3249 - accuracy: 0.8849
# Epoch 3/1500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2256 - accuracy: 0.9190
# Epoch 4/1500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1433 - accuracy: 0.9548
# Epoch 5/1500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0856 - accuracy: 0.9738
# Epoch 6/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0849 - accuracy: 0.9722
# Epoch 7/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0561 - accuracy: 0.9833
# Epoch 8/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0481 - accuracy: 0.9833
# Epoch 9/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0556 - accuracy: 0.9841
# Epoch 10/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0398 - accuracy: 0.9849
# Epoch 11/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0293 - accuracy: 0.9857
# Epoch 12/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0339 - accuracy: 0.9881
# Epoch 13/1500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0240 - accuracy: 0.9952
# Epoch 14/1500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0137 - accuracy: 0.9960
# Epoch 15/1500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0194 - accuracy: 0.9960
# Epoch 16/1500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0174 - accuracy: 0.9952
# Epoch 17/1500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0188 - accuracy: 0.9929
# Epoch 18/1500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0091 - accuracy: 0.9992
# Epoch 19/1500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0150 - accuracy: 0.9913
# Epoch 20/1500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0132 - accuracy: 0.9952
# Epoch 21/1500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0246 - accuracy: 0.9921
# Epoch 22/1500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0269 - accuracy: 0.9913
# Epoch 23/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0102 - accuracy: 0.9984
# Epoch 24/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0145 - accuracy: 0.9968
# Epoch 25/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0044 - accuracy: 0.9992
# Epoch 26/1500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0070 - accuracy: 0.9968
# Epoch 27/1500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0105 - accuracy: 0.9960
# Epoch 28/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0056 - accuracy: 0.9984
# Epoch 29/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0140 - accuracy: 0.9968
# Epoch 30/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0162 - accuracy: 0.9952
# Epoch 31/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0145 - accuracy: 0.9944
# Epoch 32/1500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0099 - accuracy: 0.9976
# Epoch 33/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0101 - accuracy: 0.9976
# Epoch 34/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0047 - accuracy: 0.9992
# Epoch 35/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 36/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0064 - accuracy: 0.9984
# Epoch 37/1500
# 20/20 [==============================] - 0s 9ms/step - loss: 0.0055 - accuracy: 0.9984
# Epoch 38/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0049 - accuracy: 0.9984
# Epoch 39/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0056 - accuracy: 0.9976
# Epoch 40/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0043 - accuracy: 0.9984
# Epoch 41/1500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0096 - accuracy: 0.9968
# Epoch 42/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0059 - accuracy: 0.9976
# Epoch 43/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0124 - accuracy: 0.9952
# Epoch 44/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0109 - accuracy: 0.9960
# Epoch 45/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0154 - accuracy: 0.9937
# Epoch 46/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0119 - accuracy: 0.9960
# Epoch 47/1500
# 20/20 [==============================] - 0s 7ms/step - loss: 0.0042 - accuracy: 0.9976
# Epoch 48/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0148 - accuracy: 0.9944
# Epoch 49/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0053 - accuracy: 0.9976
# Epoch 50/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0075 - accuracy: 0.9968
# Epoch 51/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0136 - accuracy: 0.9968
# Epoch 52/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0068 - accuracy: 0.9984
# Epoch 53/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0135 - accuracy: 0.9968
# Epoch 54/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0048 - accuracy: 0.9976
# Epoch 55/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 56/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0038 - accuracy: 0.9992
# Epoch 57/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0039 - accuracy: 0.9992
# Epoch 58/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 59/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 9.7562e-04 - accuracy: 1.0000
# Epoch 60/1500
# 20/20 [==============================] - 0s 20ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 61/1500
# 20/20 [==============================] - 0s 9ms/step - loss: 0.0026 - accuracy: 0.9992
# Epoch 62/1500
# 20/20 [==============================] - 0s 10ms/step - loss: 8.5496e-04 - accuracy: 1.0000
# Epoch 63/1500
# 20/20 [==============================] - 0s 8ms/step - loss: 0.0041 - accuracy: 0.9984
# Epoch 64/1500
# 20/20 [==============================] - 0s 8ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 65/1500
# 20/20 [==============================] - 0s 7ms/step - loss: 0.0031 - accuracy: 0.9984
# Epoch 66/1500
# 20/20 [==============================] - 0s 7ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 67/1500
# 20/20 [==============================] - 0s 7ms/step - loss: 0.0050 - accuracy: 0.9984
# Epoch 68/1500
# 20/20 [==============================] - 0s 7ms/step - loss: 0.0027 - accuracy: 0.9984
# Epoch 69/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0056 - accuracy: 0.9984
# Epoch 70/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0076 - accuracy: 0.9976
# Epoch 71/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0063 - accuracy: 0.9984
# Epoch 72/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0144 - accuracy: 0.9960
# Epoch 73/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0125 - accuracy: 0.9952
# Epoch 74/1500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0054 - accuracy: 0.9976
# Epoch 75/1500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0051 - accuracy: 0.9984
# Epoch 76/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0046 - accuracy: 0.9992
# Epoch 77/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0061 - accuracy: 0.9976
# Epoch 78/1500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0054 - accuracy: 0.9984
# Epoch 79/1500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0097 - accuracy: 0.9976
# Epoch 80/1500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0117 - accuracy: 0.9944
# Epoch 81/1500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0042 - accuracy: 0.9984
# Epoch 82/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0024 - accuracy: 0.9992
# Epoch 83/1500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 84/1500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0136 - accuracy: 0.9976
# Epoch 85/1500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0037 - accuracy: 0.9984
# Epoch 86/1500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0127 - accuracy: 0.9960
# Epoch 87/1500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0044 - accuracy: 0.9984
# Epoch 88/1500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0025 - accuracy: 0.9984
# Epoch 89/1500
# 12/20 [=================>............] - ETA: 0s - loss: 0.0019 - accuracy: 0.9987    Restoring model weights from the end of the best epoch: 59.
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0030 - accuracy: 0.9984
# Epoch 89: early stopping
# 8/8 [==============================] - 0s 2ms/step - loss: 2.5032 - accuracy: 0.7436
# 8/8 [==============================] - 0s 1ms/step
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Majority Vote Accuracy for cat_id for this fold: 0.87 (26/30)
# Before appending - Cat IDs: 399, Predictions: 399, Actuals: 399, Gender: 399
# After appending - Cat IDs: 633, Predictions: 633, Actuals: 633, Gender: 633
# Final Test Results - Loss: 2.503206968307495, Accuracy: 0.7435897588729858, Precision: 0.5406383189612449, Recall: 0.6196577809481035, F1 Score: 0.5680440771349863
# Confusion Matrix:
#  [[152  11  23]
#  [  4   7   0]
#  [ 21   1  15]]
# outer_fold 4
# Train Set Group Distribution:
# 002B    36
# 103A    33
# 057A    28
# 000B    20
# 055A    20
# 067A    20
# 059A    18
# 029A    17
# 097A    16
# 101A    16
# 106A    15
# 001A    15
# 042A    14
# 028A    14
# 097B    14
# 002A    13
# 039A    12
# 068A    11
# 036A    11
# 063A    11
# 025A    11
# 014B    10
# 040A    10
# 015A    10
# 071A    10
# 065A     9
# 051B     9
# 022A     9
# 033A     9
# 045A     9
# 013B     8
# 094A     8
# 010A     8
# 027A     7
# 099A     7
# 031A     7
# 117A     7
# 023A     6
# 109A     6
# 008A     6
# 108A     6
# 025C     6
# 037A     6
# 044A     5
# 023B     5
# 070A     5
# 012A     5
# 062A     5
# 105A     4
# 035A     4
# 009A     4
# 026A     4
# 060A     3
# 064A     3
# 113A     3
# 006A     3
# 058A     3
# 011A     3
# 087A     2
# 038A     2
# 032A     2
# 066A     2
# 025B     2
# 054A     2
# 102A     2
# 093A     2
# 061A     2
# 026B     1
# 019B     1
# 041A     1
# 004A     1
# 115A     1
# 076A     1
# 024A     1
# 096A     1
# 073A     1
# 088A     1
# 091A     1
# 043A     1
# 048A     1
# 026C     1
# 092A     1
# 049A     1
# 090A     1
# 100A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 046A    66
# 000A    39
# 047A    30
# 074A    25
# 020A    23
# 019A    17
# 111A    13
# 116A    12
# 051A    12
# 005A    11
# 016A    11
# 072A     9
# 095A     8
# 050A     7
# 053A     7
# 021A     6
# 007A     6
# 075A     5
# 034A     5
# 003A     4
# 052A     4
# 104A     4
# 014A     3
# 056A     3
# 069A     2
# 018A     2
# 110A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    255
# X    202
# F    176
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    153
# M    101
# F     81
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [002A, 028A, 070A, 033A, 000B, 071A, 015A, 026...
# kitten    [042A, 014B, 109A, 040A, 049A, 045A, 048A, 044...
# senior    [117A, 106A, 057A, 090A, 113A, 051B, 024A, 097...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [020A, 000A, 053A, 007A, 021A, 018A, 034A, 072...
# kitten                       [046A, 110A, 047A, 111A, 050A]
# senior                       [116A, 051A, 016A, 104A, 056A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 57, 'kitten': 11, 'senior': 17}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 17, 'kitten': 5, 'senior': 5}
# Unique Training/Validation Group IDs:
# ['000B' '001A' '002A' '002B' '004A' '006A' '008A' '009A' '010A' '011A'
#  '012A' '013B' '014B' '015A' '019B' '022A' '023A' '023B' '024A' '025A'
#  '025B' '025C' '026A' '026B' '026C' '027A' '028A' '029A' '031A' '032A'
#  '033A' '035A' '036A' '037A' '038A' '039A' '040A' '041A' '042A' '043A'
#  '044A' '045A' '048A' '049A' '051B' '054A' '055A' '057A' '058A' '059A'
#  '060A' '061A' '062A' '063A' '064A' '065A' '066A' '067A' '068A' '070A'
#  '071A' '073A' '076A' '087A' '088A' '090A' '091A' '092A' '093A' '094A'
#  '096A' '097A' '097B' '099A' '100A' '101A' '102A' '103A' '105A' '106A'
#  '108A' '109A' '113A' '115A' '117A']
# Unique Test Group IDs:
# ['000A' '003A' '005A' '007A' '014A' '016A' '018A' '019A' '020A' '021A'
#  '034A' '046A' '047A' '050A' '051A' '052A' '053A' '056A' '069A' '072A'
#  '074A' '075A' '095A' '104A' '110A' '111A' '116A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'000A', '046A'}
# Removed from Training/Validation Set:
# {'026B', '109A'}
# Moved to Test Set:
# {'026B', '109A'}
# Removed from Test Set
# {'000A', '046A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '004A' '006A' '008A' '009A' '010A'
#  '011A' '012A' '013B' '014B' '015A' '019B' '022A' '023A' '023B' '024A'
#  '025A' '025B' '025C' '026A' '026C' '027A' '028A' '029A' '031A' '032A'
#  '033A' '035A' '036A' '037A' '038A' '039A' '040A' '041A' '042A' '043A'
#  '044A' '045A' '046A' '048A' '049A' '051B' '054A' '055A' '057A' '058A'
#  '059A' '060A' '061A' '062A' '063A' '064A' '065A' '066A' '067A' '068A'
#  '070A' '071A' '073A' '076A' '087A' '088A' '090A' '091A' '092A' '093A'
#  '094A' '096A' '097A' '097B' '099A' '100A' '101A' '102A' '103A' '105A'
#  '106A' '108A' '113A' '115A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['003A' '005A' '007A' '014A' '016A' '018A' '019A' '020A' '021A' '026B'
#  '034A' '047A' '050A' '051A' '052A' '053A' '056A' '069A' '072A' '074A'
#  '075A' '095A' '104A' '109A' '110A' '111A' '116A']
# Length of X_train_val:
# 731
# Length of y_train_val:
# 731
# Length of groups_train_val:
# 731
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     430
# senior    144
# kitten     59
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     176
# kitten    117
# senior     42
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     468
# senior    144
# kitten    119
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     138
# kitten     57
# senior     42
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 468, 2: 144, 1: 119})
# Epoch 1/1500
# 22/22 [==============================] - 1s 5ms/step - loss: 0.8080 - accuracy: 0.7229
# Epoch 2/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.2939 - accuracy: 0.8903
# Epoch 3/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1721 - accuracy: 0.9380
# Epoch 4/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.1188 - accuracy: 0.9544
# Epoch 5/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0935 - accuracy: 0.9665
# Epoch 6/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0641 - accuracy: 0.9765
# Epoch 7/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0676 - accuracy: 0.9772
# Epoch 8/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0328 - accuracy: 0.9886
# Epoch 9/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0338 - accuracy: 0.9900
# Epoch 10/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0280 - accuracy: 0.9900
# Epoch 11/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0212 - accuracy: 0.9915
# Epoch 12/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0323 - accuracy: 0.9865
# Epoch 13/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0142 - accuracy: 0.9964
# Epoch 14/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0176 - accuracy: 0.9957
# Epoch 15/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0199 - accuracy: 0.9936
# Epoch 16/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0128 - accuracy: 0.9957
# Epoch 17/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0132 - accuracy: 0.9943
# Epoch 18/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0117 - accuracy: 0.9950
# Epoch 19/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0061 - accuracy: 1.0000
# Epoch 20/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0113 - accuracy: 0.9957
# Epoch 21/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0156 - accuracy: 0.9943
# Epoch 22/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0128 - accuracy: 0.9936
# Epoch 23/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0152 - accuracy: 0.9950
# Epoch 24/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0115 - accuracy: 0.9957
# Epoch 25/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0305 - accuracy: 0.9936
# Epoch 26/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0165 - accuracy: 0.9929
# Epoch 27/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0088 - accuracy: 0.9972
# Epoch 28/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0173 - accuracy: 0.9943
# Epoch 29/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0094 - accuracy: 0.9986
# Epoch 30/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0097 - accuracy: 0.9972
# Epoch 31/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0094 - accuracy: 0.9957
# Epoch 32/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0082 - accuracy: 0.9972
# Epoch 33/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0048 - accuracy: 0.9979
# Epoch 34/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0044 - accuracy: 0.9986
# Epoch 35/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0116 - accuracy: 0.9979
# Epoch 36/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0090 - accuracy: 0.9964
# Epoch 37/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0056 - accuracy: 0.9979
# Epoch 38/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0075 - accuracy: 0.9979
# Epoch 39/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0104 - accuracy: 0.9957
# Epoch 40/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0061 - accuracy: 0.9986
# Epoch 41/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0023 - accuracy: 0.9993
# Epoch 42/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0043 - accuracy: 0.9986
# Epoch 43/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0073 - accuracy: 0.9972
# Epoch 44/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0056 - accuracy: 0.9972
# Epoch 45/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0085 - accuracy: 0.9964
# Epoch 46/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0098 - accuracy: 0.9964
# Epoch 47/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0054 - accuracy: 0.9979
# Epoch 48/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0029 - accuracy: 0.9993
# Epoch 49/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0023 - accuracy: 0.9993
# Epoch 50/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0032 - accuracy: 0.9993
# Epoch 51/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0045 - accuracy: 0.9986
# Epoch 52/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0044 - accuracy: 0.9986
# Epoch 53/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0063 - accuracy: 0.9979
# Epoch 54/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0031 - accuracy: 0.9993
# Epoch 55/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0026 - accuracy: 0.9993
# Epoch 56/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0025 - accuracy: 0.9986
# Epoch 57/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0043 - accuracy: 0.9986
# Epoch 58/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0072 - accuracy: 0.9986
# Epoch 59/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0037 - accuracy: 0.9993
# Epoch 60/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0047 - accuracy: 0.9986
# Epoch 61/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0064 - accuracy: 0.9972
# Epoch 62/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0091 - accuracy: 0.9979
# Epoch 63/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0021 - accuracy: 0.9993
# Epoch 64/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0041 - accuracy: 0.9986
# Epoch 65/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0064 - accuracy: 0.9993
# Epoch 66/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0020 - accuracy: 0.9993
# Epoch 67/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0063 - accuracy: 0.9979
# Epoch 68/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0030 - accuracy: 0.9986
# Epoch 69/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 70/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 71/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 8.4381e-04 - accuracy: 1.0000
# Epoch 72/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 6.5119e-04 - accuracy: 1.0000
# Epoch 73/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 3.1472e-04 - accuracy: 1.0000
# Epoch 74/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0014 - accuracy: 0.9993
# Epoch 75/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 76/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0018 - accuracy: 0.9993
# Epoch 77/1500
# 22/22 [==============================] - 0s 9ms/step - loss: 0.0104 - accuracy: 0.9972
# Epoch 78/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0025 - accuracy: 0.9993
# Epoch 79/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0021 - accuracy: 0.9993
# Epoch 80/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 81/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0072 - accuracy: 0.9972
# Epoch 82/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 83/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0041 - accuracy: 0.9986
# Epoch 84/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0048 - accuracy: 0.9993
# Epoch 85/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0051 - accuracy: 0.9979
# Epoch 86/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0028 - accuracy: 0.9986
# Epoch 87/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0017 - accuracy: 0.9993
# Epoch 88/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0018 - accuracy: 0.9993
# Epoch 89/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0014 - accuracy: 0.9993
# Epoch 90/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 91/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0031 - accuracy: 0.9993
# Epoch 92/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0075 - accuracy: 0.9964
# Epoch 93/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0125 - accuracy: 0.9950
# Epoch 94/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0164 - accuracy: 0.9943
# Epoch 95/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0092 - accuracy: 0.9964
# Epoch 96/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0192 - accuracy: 0.9957
# Epoch 97/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0057 - accuracy: 0.9986
# Epoch 98/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0132 - accuracy: 0.9950
# Epoch 99/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0094 - accuracy: 0.9964
# Epoch 100/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0055 - accuracy: 0.9979
# Epoch 101/1500
# 20/22 [==========================>...] - ETA: 0s - loss: 0.0127 - accuracy: 0.9953  Restoring model weights from the end of the best epoch: 71.
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0119 - accuracy: 0.9957
# Epoch 101: early stopping
# 8/8 [==============================] - 0s 1ms/step - loss: 14.5345 - accuracy: 0.6329
# 8/8 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.74 (20/27)
# Before appending - Cat IDs: 633, Predictions: 633, Actuals: 633, Gender: 633
# After appending - Cat IDs: 870, Predictions: 870, Actuals: 870, Gender: 870
# Final Test Results - Loss: 14.534513473510742, Accuracy: 0.6329113841056824, Precision: 0.6126329250235564, Recall: 0.49513275943481894, F1 Score: 0.5183711513005882
# Confusion Matrix:
#  [[118  13   7]
#  [ 35  21   1]
#  [ 31   0  11]]
#
# Final Average F1-Score across all UNSEEN TEST sets: 0.5668277900207397
#
# Final Average Loss across all UNSEEN TEST sets: 5.886711359024048
#
# Final Average Accuracy across all UNSEEN TEST sets: 0.680148720741272
#
# Final Average Precision across all UNSEEN TEST sets: 0.608813867190197
#
# Final Average Recall across all UNSEEN TEST sets: 0.5732800916009246

# %%
seed_4_folds_values = (unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1)

# Plotting all fold metrics
seed_4_folds_plot = plot_all_metrics(unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1, "Folds", "Fold Number")

# %% [markdown]
# ## Majority Voting on Total Entries per cat_id

# %%
# Debugging print statements
print(f'Checking - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
# Out:
# Checking - Cat IDs: 870, Predictions: 870, Actuals: 870, Gender: 870

# %%
# Create results df
full_results = pd.DataFrame({
    'cat_id': all_cat_ids,
    'predicted_age_group': all_predicted_age_groups,
    'actual_age_group': all_actual_age_groups,
    'all_gender': all_gender
})

# create a correct majority prediction column
full_results['correct'] = full_results['predicted_age_group'] == full_results['actual_age_group']

# %%
# Group by cat_id and aggregate predicted age groups
majority_votes = full_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first()

# Calculate the accuracy of majority voting
correct_predictions = (majority_votes == actual_groups).sum()
total_cats = len(actual_groups)
majority_vote_accuracy = correct_predictions / total_cats

logger(f"Overall Majority Vote Accuracy for cat_id: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

# store for final evaluation 
all_majority_vote_accuracies.append(majority_vote_accuracy)
# Out:
# Overall Majority Vote Accuracy for cat_id: 0.76 (84/110)

# %%
# Detailed df with predictions, actual labels, and comparison including majority vote
detailed_results = full_results.groupby('cat_id').apply(
    lambda x: pd.Series({
        'Predictions': list(x['predicted_age_group']),
        'Majority Vote': x['predicted_age_group'].mode()[0],
        'Actual Age Group': x['actual_age_group'].iloc[0],
        'Correct Majority Vote': x['predicted_age_group'].mode()[0] == x['actual_age_group'].iloc[0]
    })
).reset_index()

# Convert to DataFrame for better formatting and display
detailed_results = pd.DataFrame(detailed_results)

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 10)
pd.set_option('display.width', 1000)

sorted_detailed_results = detailed_results.sort_values(by='Correct Majority Vote', ascending=False)

# Display the sorted DataFrame
sorted_detailed_results
# Out:
#     cat_id                                        Predictions Majority Vote Actual Age Group  Correct Majority Vote
# 0     000B  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 79    073A                                            [adult]         adult            adult                   True
# 77    071A  [adult, adult, adult, adult, adult, senior, se...         adult            adult                   True
# 76    070A               [adult, senior, adult, adult, adult]         adult            adult                   True
# 75    069A                                     [adult, adult]         adult            adult                   True
# 74    068A  [adult, adult, adult, adult, senior, adult, ad...         adult            adult                   True
# 73    067A  [adult, adult, adult, adult, kitten, adult, ad...         adult            adult                   True
# 72    066A                                    [adult, kitten]         adult            adult                   True
# 71    065A  [adult, adult, adult, kitten, adult, adult, ki...         adult            adult                   True
# 70    064A                              [adult, adult, adult]         adult            adult                   True
# 68    062A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 66    060A                             [kitten, adult, adult]         adult            adult                   True
# 65    059A  [senior, senior, senior, senior, adult, senior...        senior           senior                   True
# 59    053A  [adult, adult, adult, adult, senior, adult, ad...         adult            adult                   True
# 58    052A                       [adult, adult, adult, adult]         adult            adult                   True
# 1     001A  [adult, adult, adult, adult, senior, adult, ad...         adult            adult                   True
# 53    048A                                           [kitten]        kitten           kitten                   True
# 51    045A  [kitten, adult, kitten, kitten, kitten, adult,...        kitten           kitten                   True
# 50    044A             [kitten, kitten, adult, kitten, adult]        kitten           kitten                   True
# 49    043A                                           [kitten]        kitten           kitten                   True
# 48    042A  [kitten, adult, kitten, adult, adult, kitten, ...        kitten           kitten                   True
# 78    072A  [adult, kitten, adult, adult, adult, kitten, k...         adult            adult                   True
# 80    074A  [kitten, adult, adult, adult, adult, adult, ad...         adult            adult                   True
# 45    039A  [senior, senior, adult, adult, adult, senior, ...         adult            adult                   True
# 81    075A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 107   115A                                           [kitten]        kitten           kitten                   True
# 106   113A                           [senior, senior, senior]        senior           senior                   True
# 105   111A  [kitten, kitten, kitten, kitten, kitten, kitte...        kitten           kitten                   True
# 104   110A                                           [kitten]        kitten           kitten                   True
# 100   105A                      [adult, adult, adult, kitten]         adult            adult                   True
# 98    103A  [adult, adult, kitten, adult, senior, kitten, ...         adult            adult                   True
# 97    102A                                     [adult, adult]         adult            adult                   True
# 96    101A  [senior, senior, adult, adult, adult, senior, ...         adult            adult                   True
# 95    100A                                            [adult]         adult            adult                   True
# 94    099A  [adult, adult, adult, kitten, adult, adult, ad...         adult            adult                   True
# 93    097B  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 91    096A                                            [adult]         adult            adult                   True
# 90    095A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 89    094A  [adult, senior, adult, senior, senior, senior,...        senior           senior                   True
# 87    092A                                            [adult]         adult            adult                   True
# 86    091A                                            [adult]         adult            adult                   True
# 84    088A                                            [adult]         adult            adult                   True
# 83    087A                                     [adult, adult]         adult            adult                   True
# 82    076A                                            [adult]         adult            adult                   True
# 46    040A  [kitten, adult, adult, kitten, kitten, adult, ...        kitten           kitten                   True
# 55    050A  [kitten, kitten, adult, adult, adult, kitten, ...        kitten           kitten                   True
# 44    038A                                    [adult, kitten]         adult            adult                   True
# 14    013B  [adult, adult, adult, adult, adult, senior, ad...         adult            adult                   True
# 28    025A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 26    023B                [adult, adult, adult, adult, adult]         adult            adult                   True
# 25    023A        [adult, adult, kitten, adult, adult, adult]         adult            adult                   True
# 23    021A        [adult, adult, adult, adult, adult, kitten]         adult            adult                   True
# 22    020A  [adult, adult, adult, adult, adult, adult, kit...         adult            adult                   True
# 21    019B                                            [adult]         adult            adult                   True
# 20    019A  [adult, kitten, kitten, adult, adult, adult, a...         adult            adult                   True
# 19    018A                                     [adult, adult]         adult            adult                   True
# 17    015A  [senior, adult, adult, adult, adult, adult, se...         adult            adult                   True
# 15    014A                             [kitten, adult, adult]         adult            adult                   True
# 13    012A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 30    025C         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 11    010A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 10    009A                      [adult, adult, senior, adult]         adult            adult                   True
# 9     008A         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 8     007A         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 7     006A                             [senior, adult, adult]         adult            adult                   True
# 6     005A  [adult, adult, adult, senior, adult, adult, se...         adult            adult                   True
# 5     004A                                            [adult]         adult            adult                   True
# 4     003A                     [kitten, kitten, adult, adult]         adult            adult                   True
# 3     002B  [adult, adult, adult, kitten, senior, adult, a...         adult            adult                   True
# 2     002A  [adult, kitten, adult, adult, adult, adult, ad...         adult            adult                   True
# 29    025B                                    [senior, adult]         adult            adult                   True
# 24    022A  [adult, kitten, kitten, adult, adult, adult, a...         adult            adult                   True
# 31    026A                      [senior, adult, adult, adult]         adult            adult                   True
# 36    029A  [adult, adult, adult, adult, senior, adult, ad...         adult            adult                   True
# 43    037A       [kitten, adult, senior, adult, adult, adult]         adult            adult                   True
# 42    036A  [senior, adult, adult, adult, adult, adult, ad...         adult            adult                   True
# 41    035A                     [adult, kitten, senior, adult]         adult            adult                   True
# 40    034A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 39    033A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 38    032A                                     [adult, adult]         adult            adult                   True
# 32    026B                                     [adult, adult]         adult            adult                   True
# 37    031A  [senior, adult, adult, adult, kitten, adult, s...         adult            adult                   True
# 34    027A  [adult, adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 35    028A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 54    049A                                            [adult]         adult           kitten                  False
# 108   116A  [senior, senior, adult, adult, senior, adult, ...         adult           senior                  False
# 69    063A  [kitten, senior, kitten, kitten, kitten, adult...        kitten            adult                  False
# 27    024A                                            [adult]         adult           senior                  False
# 33    026C                                           [kitten]        kitten            adult                  False
# 67    061A                                     [adult, adult]         adult           senior                  False
# 103   109A  [adult, adult, kitten, adult, adult, adult, ad...         adult           kitten                  False
# 102   108A        [adult, adult, adult, senior, adult, adult]         adult           senior                  False
# 101   106A  [adult, adult, adult, adult, adult, adult, sen...         adult           senior                  False
# 52    047A  [adult, adult, adult, kitten, adult, adult, ad...         adult           kitten                  False
# 99    104A                      [senior, adult, adult, adult]         adult           senior                  False
# 47    041A                                            [adult]         adult           kitten                  False
# 63    057A  [adult, adult, adult, adult, adult, senior, ad...         adult           senior                  False
# 62    056A                              [adult, adult, adult]         adult           senior                  False
# 56    051A  [adult, adult, adult, senior, adult, adult, ad...         adult           senior                  False
# 57    051B  [adult, adult, adult, adult, adult, senior, ad...         adult           senior                  False
# 12    011A                             [senior, adult, adult]         adult           senior                  False
# 92    097A  [adult, senior, senior, adult, adult, adult, a...         adult           senior                  False
# 64    058A                              [adult, adult, adult]         adult           senior                  False
# 60    054A                                     [adult, adult]         adult           senior                  False
# 88    093A                                     [adult, adult]         adult           senior                  False
# 16    014B  [adult, adult, senior, kitten, adult, kitten, ...         adult           kitten                  False
# 61    055A  [adult, adult, adult, senior, adult, senior, a...         adult           senior                  False
# 85    090A                                            [adult]         adult           senior                  False
# 18    016A  [adult, adult, adult, adult, adult, adult, adu...         adult           senior                  False
# 109   117A  [adult, adult, adult, senior, adult, senior, a...         adult           senior                  False

# %%
# Create df for majority votes
majority_df = majority_votes.reset_index()
majority_df.columns = ['cat_id', 'Majority_Vote']

# Get actual groups for each cat_id
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first().reset_index()

# Merge majority votes with actual groups
majority_with_actual = pd.merge(majority_df, actual_groups, on='cat_id')

# Add a column to check if the majority vote was correct
majority_with_actual['Majority_Correct'] = majority_with_actual['Majority_Vote'] == majority_with_actual['actual_age_group']

# Count correct majority votes per class
correct_majority_votes_per_class = majority_with_actual.groupby('actual_age_group')['Majority_Correct'].sum()

print("Correct Majority Votes per Class:")
print(correct_majority_votes_per_class)
# Out:
# Correct Majority Votes per Class:
# actual_age_group
# adult     71
# kitten    10
# senior     3
# Name: Majority_Correct, dtype: int64

# %%
# Calculate the total count and the number of correct predictions for each class
class_stats = majority_with_actual.groupby('actual_age_group').agg(
    total_count=('Majority_Correct', 'size'),  # Total number of cases per class
    correct_count=('Majority_Correct', 'sum')  # Sum of correct predictions per class
).reset_index()

# Calculate accuracy for each class
class_stats['accuracy'] = class_stats['correct_count'] / class_stats['total_count'] * 100

# store for final evaluation 
all_majority_vote_details.append(class_stats)

# Log detailed stats
print("Detailed Class Statistics for Majority Votes:")
print(class_stats)
# Out:
# Detailed Class Statistics for Majority Votes:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult           73             71  97.260274
# 1           kitten           15             10  66.666667
# 2           senior           22              3  13.636364

# %%
# Plot for Detailed Class Statistics for Majority Votes
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Accuracy of Majority Votes by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Detailed Class Statistics

# %%
# Calculate the total count and the number of correct predictions for each class
class_stats = full_results.groupby('actual_age_group').agg(
    total_count=('correct', 'size'),
    correct_count=('correct', 'sum')
).reset_index()

# Calculate accuracy for each class
class_stats['accuracy'] = class_stats['correct_count'] / class_stats['total_count'] * 100

# store for final evaluation 
all_class_stats.append(class_stats)

# Log the detailed stats
print("Detailed Class Statistics:")
print(class_stats)
# Out:
# Detailed Class Statistics:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult          568            477  83.978873
# 1           kitten          116             53  45.689655
# 2           senior          186             59  31.720430

# %%
# Plot for Detailed Class Statistics (Overall)
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Overall Accuracy by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Gender Exploration

# %%
# Group by gender and calculate the total count, correct predictions, and accuracy
gender_stats = full_results.groupby('all_gender').agg(
    count=('cat_id', 'size'),  # Total number of cases per gender
    correct=('correct', 'sum')  # Sum of correct predictions per gender
).reset_index()

# Calculate accuracy for each gender
gender_stats['accuracy'] = (gender_stats['correct'] / gender_stats['count'] * 100).round(2)

# Display the DataFrame
print("Accuracy by Gender:")
print(gender_stats)

# store for final evaluation 
all_gender_stats.append(gender_stats)
# Out:
# Accuracy by Gender:
#   all_gender  count  correct  accuracy
# 0          F    218      145     66.51
# 1          M    357      286     80.11
# 2          X    295      158     53.56

# %%
# Plot for Accuracy by Gender
styled_barplot(gender_stats, 'all_gender', 'accuracy', 
               'Accuracy by Gender', 
               'Gender', 'Accuracy (%)')

# %% [markdown]
# ### Log current total CV Stats

# %%
print("Total Majority Vote Accuracy so far:", all_majority_vote_accuracies)
print("Total Class Statistics so far:\n", all_class_stats)
print("Total Gender Accuracy so far:\n", all_gender_stats)
# Out:
# Total Majority Vote Accuracy so far: [0.7727272727272727, 0.7545454545454545, 0.7727272727272727, 0.7636363636363637]
# Total Class Statistics so far:
#  [  actual_age_group  total_count  correct_count   accuracy
# 0            adult          573            489  85.340314
# 1           kitten          111             57  51.351351
# 2           senior          186             61  32.795699,   actual_age_group  total_count  correct_count   accuracy
# 0            adult          569            446  78.383128
# 1           kitten          120             45  37.500000
# 2           senior          186             44  23.655914,   actual_age_group  total_count  correct_count   accuracy
# 0            adult          578            474  82.006920
# 1           kitten          111             62  55.855856
# 2           senior          186             60  32.258065,   actual_age_group  total_count  correct_count   accuracy
# 0            adult          568            477  83.978873
# 1           kitten          116             53  45.689655
# 2           senior          186             59  31.720430]
# Total Gender Accuracy so far:
#  [  all_gender  count  correct  accuracy
# 0          F    218      150     68.81
# 1          M    362      279     77.07
# 2          X    290      178     61.38,   all_gender  count  correct  accuracy
# 0          F    220      133     60.45
# 1          M    356      253     71.07
# 2          X    299      149     49.83,   all_gender  count  correct  accuracy
# 0          F    218      142     65.14
# 1          M    356      271     76.12
# 2          X    301      183     60.80,   all_gender  count  correct  accuracy
# 0          F    218      145     66.51
# 1          M    357      286     80.11
# 2          X    295      158     53.56]

# %% [markdown]
# # RANDOM SEED 5

# %%
# Set a fixed random seed for reproducibility
random.seed(int(random_seeds[4]))
np.random.seed(int(random_seeds[4]))
tf.random.set_seed(int(random_seeds[4]))

# Load datasets
dataframe = pd.read_csv('/Users/astrid/PycharmProjects/data-aug-and-more/yamnet-tfhub-extraction/yamnet_embeddings_looped_april_23.csv')

def assign_age_group(age, age_groups):
    for group_name, age_range in age_groups.items():
        if age_range[0] <= age < age_range[1]:
            return group_name
    return 'Unknown'  # For any age that doesn't fit the defined groups

# Define age groups
age_groups = {
    'kitten': (0, 0.5),
    'adult': (0.5, 12),
    'senior': (12, 20)
}

# Create a new column for the age group
dataframe['age_group'] = dataframe['target'].apply(assign_age_group, age_groups=age_groups)

print(dataframe['age_group'].value_counts())
# Out:
# adult     606
# senior    186
# kitten    176
# Name: age_group, dtype: int64

# %%
# Separate features and labels
X = dataframe.iloc[:, :-4].values  # all columns except the last four

# Encode the 'age_group' column as integers using LabelEncoder
label_encoder = LabelEncoder()
encoded_y = label_encoder.fit_transform(dataframe['age_group'].values)

# Use the encoded labels for splitting and one-hot encoding
y = encoded_y  

# Convert 'cat_id' column to numpy array to be used as groups array for GroupKFold
groups = dataframe['cat_id'].values

# %%
tf.keras.backend.clear_session()

# %% [markdown]
# ## Run Setup

# %%
all_cat_ids = []
all_predicted_age_groups = []
all_actual_age_groups = []
all_gender = []

# Define the StratifiedGroupKFold splitter for 4 fold CV with random shuffling
outer_cv = StratifiedGroupKFold(n_splits=4, shuffle=True, random_state=int(random_seeds[4]))

# unseen test set metrics
unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1 = [], [], [], [], []

outer_fold = 0

# Use the splitter to generate indices for training and testing sets
# Note: GroupShuffleSplit.split returns indices, so we use it to index the arrays
for train_val_idx, test_idx in outer_cv.split(X, y, groups):
    outer_fold += 1
    logger(f"outer_fold {outer_fold}", file=log_file_path)

    # Convert indices back to DataFrame for easy manipulation
    df_train_val = dataframe.iloc[train_val_idx]
    df_test = dataframe.iloc[test_idx]

    ##############################
    # ASSESSING SPLITS BY CAT_ID #
    ##############################
    
    # Get the distribution of groups
    training_validation_group_distribution = df_train_val['cat_id'].value_counts()  
    testing_group_distribution = df_test['cat_id'].value_counts()  
    
    # Log or print the distribution
    logger(f"Train Set Group Distribution:\n{training_validation_group_distribution}", file=log_file_path)
    logger(f"Testing Set Group Distribution:\n{testing_group_distribution}", file=log_file_path)

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val['gender'].value_counts()
    testing_gender_distribution = df_test['gender'].value_counts()
    
    # Log the distribution
    logger(f"Training Set Gender Distribution BEFORE SWAP:\n{training_gender_distribution}", file=log_file_path)
    logger(f"Testing Set Gender Distribution BEFORE SWAP:\n{testing_gender_distribution}", file=log_file_path)

    # Group by 'age_group' and then list unique 'cat_id' within each age group
    unique_cat_ids_per_age_group_train_val = df_train_val.groupby('age_group')['cat_id'].unique()
    unique_cat_ids_per_age_group_test = df_test.groupby('age_group')['cat_id'].unique()
    
    # Log results
    logger(f"Unique Cat IDs per Age Group in Training/Validation Set:\n{unique_cat_ids_per_age_group_train_val}", file=log_file_path)
    logger(f"Unique Cat IDs per Age Group in Testing Set:\n{unique_cat_ids_per_age_group_test}", file=log_file_path)

    # Calculate the count of unique identifiers per age group for training and testing set
    counts_train_val = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_train_val.items()}
    counts_test = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_test.items()}

    # Log the counts of unique identifiers per age group
    logger(f"Count of Unique Cat IDs per Age Group in Training/Validation Set:\n{counts_train_val}", file=log_file_path)
    logger(f"Count of Unique Cat IDs per Age Group in Testing Set:\n{counts_test}", file=log_file_path)

    #######################################################
    # CONTINUE WITH ENSURING VALID AND APPROPRIATE SPLITS #
    #######################################################
    
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    groups_train_val, groups_test = groups[train_val_idx], groups[test_idx]

    # logging identifier splits 
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)

    # check group splits
    check_initial_group_split(groups_train_val, groups_test)

    # Specify the cat_ids that must be in the training/validation set
    specific_cat_ids = ['000A', '046A']
    
    # Perform the swapping operation
    train_val_idx, test_idx = swap_cat_id_instances(dataframe, train_val_idx, test_idx, specific_cat_ids)
    
    # Re-assign the sets based on the updated indices
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    new_groups_train_val, new_groups_test = groups[train_val_idx], groups[test_idx]

    # Find differences for training and test sets
    moved_to_train_val, removed_from_train_val = find_group_differences(groups_train_val, new_groups_train_val)
    moved_to_test, removed_from_test = find_group_differences(groups_test, new_groups_test)
    
    # Display the results
    logger(f"Moved to Training/Validation Set:\n{moved_to_train_val}", file=log_file_path)
    logger(f"Removed from Training/Validation Set:\n{removed_from_train_val}", file=log_file_path)
    logger(f"Moved to Test Set:\n{moved_to_test}", file=log_file_path)
    logger(f"Removed from Test Set\n{removed_from_test}", file=log_file_path)

    # Update X_train_val, X_test, y_train_val, y_test, groups_train_val, groups_test based on updated indices
    X_train_val = X[train_val_idx]
    y_train_val = y[train_val_idx]
    groups_train_val = groups[train_val_idx]
    
    X_test = X[test_idx]
    y_test = y[test_idx]
    groups_test = groups[test_idx]

    # logging identifier splits again after potential swaps
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"AFTER SWAP - Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"AFTER SWAP - Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)
    
    # Verify the lengths are consistent
    logger(f"Length of X_train_val:\n{len(X_train_val)}", file=log_file_path)
    logger(f"Length of y_train_val:\n{len(y_train_val)}", file=log_file_path)
    logger(f"Length of groups_train_val:\n{len(groups_train_val)}", file=log_file_path)

    # Check group splits once more
    check_initial_group_split(groups_train_val, groups_test)

    # Convert the modified indices back to a DataFrame representing the updated df_train_val
    df_train_val_updated = dataframe.iloc[train_val_idx].copy()
    df_test_updated = dataframe.iloc[test_idx].copy()

    ############################
    # LOGGING AGE GROUP SPLITS #
    ############################

    # Get the distribution of age groups of age groups before the update
    training_validation_age_group_distribution = df_train_val['age_group'].value_counts()
    testing_age_group_distribution = df_test['age_group'].value_counts()
    
    # Logthe distribution
    logger(f"Train Age Group Distribution BEFORE SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution BEFORE SWAP:\n{testing_age_group_distribution}", file=log_file_path)

    # Get the distribution of age groups after the update
    training_validation_age_group_distribution = df_train_val_updated['age_group'].value_counts()
    testing_age_group_distribution = df_test_updated['age_group'].value_counts()
    
    # Log the distribution
    logger(f"Train Age Group Distribution AFTER SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution AFTER SWAP:\n{testing_age_group_distribution}", file=log_file_path)
    
    ########################################################
    # TRACKING FINAL CAT_IDs & GENDER AFTER REDISTRIBUTION #
    ########################################################

    # Get the distribution of groups
    training_validation_group_distribution = df_train_val_updated['cat_id'].value_counts()  
    testing_group_distribution = df_test_updated['cat_id'].value_counts()  

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val_updated['gender'].value_counts()
    testing_gender_distribution = df_test_updated['gender'].value_counts()
    
    logger(f"\n Starting training on unseen test set\n", file=log_file_path)

    ###################
    # PREPARING MODEL #
    ###################

    # Calculate the distribution of age groups in y_train_val
    age_group_distribution = Counter(y_train_val)
    print("Age group distribution:", age_group_distribution)

    # EarlyStopping callback: monitor 'loss' instead of 'val_loss' for the test set
    early_stopping = EarlyStopping(
        monitor='loss',  
        min_delta=0.001, 
        patience=30,  
        verbose=1,  
        restore_best_weights=True  
    )

    # Apply SMOTE to the training data only
    smote = SMOTE()
    X_train_val, y_train_val = smote.fit_resample(X_train_val, y_train_val)

    # One final shuffle to ensure randomness
    outer_shuffle_idx = np.random.permutation(len(X_train_val))
    X_train_val = X_train_val[outer_shuffle_idx]
    y_train_val = y_train_val[outer_shuffle_idx]
    
    # Scale the features
    scaler_full = StandardScaler().fit(X_train_val)
    X_train_full_scaled = scaler_full.transform(X_train_val)
    X_test_scaled = scaler_full.transform(X_test)
    
    # Encode the labels
    y_train_full_encoded = to_categorical(y_train_val)
    y_test_encoded = to_categorical(y_test)

    #######################
    # BUILD & TRAIN MODEL #
    #######################

    optimizers = {
        'Adamax': Adamax(learning_rate=0.00510251984616472)
    }
    
    # Model definition with dynamic number of layers
    model_full = Sequential()
    model_full.add(Dense(480, activation='relu', input_shape=(X_train_full_scaled.shape[1],)))
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.2011047009431978))  
    model_full.add(Dense(256, activation='relu',)) 
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.14956886311951184))  
    model_full.add(Dense(256, activation='relu'))  
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.42291461228250665))  
    model_full.add(Dense(3, activation='softmax'))  
    
    # Use the optimizer from the parameters
    optimizer = optimizers['Adamax']  # optimizer_key from parameters
    
    # Compile the model
    model_full.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    
    # Train the model on the full training set
    history_full = model_full.fit(X_train_full_scaled, y_train_full_encoded, epochs=1500, batch_size=64,
                                  verbose=1, callbacks=[early_stopping])
    
    # Evaluate the model on the held-out test set
    test_loss, test_accuracy = model_full.evaluate(X_test_scaled, y_test_encoded)

    y_test_pred_prob = model_full.predict(X_test_scaled)
    y_test_pred = np.argmax(y_test_pred_prob, axis=1)  
    y_test_true = np.argmax(y_test_encoded, axis=1)    

    ################################
    # LOG MAJORITY VOTE PER CAT_ID #
    ################################

    # Convert numeric predictions back to age group labels
    predicted_age_groups = label_encoder.inverse_transform(y_test_pred)
    actual_labels = label_encoder.inverse_transform(y_test_true)
    
    # Map predictions and actual labels back to cat_ids
    test_results = pd.DataFrame({
        'cat_id': df_test_updated['cat_id'],
        'predicted_age_group': predicted_age_groups,
        'actual_age_group': actual_labels
    })
    
    # Group by cat_id and aggregate predicted age groups
    majority_votes = test_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
    actual_groups = test_results.groupby('cat_id')['actual_age_group'].first()
    
    # Calculate the accuracy of majority voting
    correct_predictions = (majority_votes == actual_groups).sum()
    total_cats = len(actual_groups)
    majority_vote_accuracy = correct_predictions / total_cats
    
    # Log the accuracy of the majority voting
    logger(f"Majority Vote Accuracy for cat_id for this fold: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

    ####################################################
    # COLLECT PREDICTIONS FOR GENDER & CAT_ID ANALYSIS #
    ####################################################

    # Debugging print statements
    print(f'Before appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Extend lists with current fold results
    all_cat_ids.extend(df_test_updated['cat_id'].tolist())
    all_predicted_age_groups.extend(predicted_age_groups)
    all_actual_age_groups.extend(actual_labels)
    all_gender.extend(df_test_updated['gender'].tolist())

    # Debugging print statements
    print(f'After appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Calculate additional metrics
    test_precision = precision_score(y_test_true, y_test_pred, average='macro')  # Use 'macro' for imbalanced datasets
    test_recall = recall_score(y_test_true, y_test_pred, average='macro')
    test_f1 = f1_score(y_test_true, y_test_pred, average='macro')

    # prepare averages of outer metrics
    unseen_f1.append(test_f1)
    unseen_losses.append(test_loss)
    unseen_accuracies.append(test_accuracy)
    unseen_precisions.append(test_precision)
    unseen_recalls.append(test_recall)

    # Print final test results
    logger(f"Final Test Results - Loss: {test_loss}, Accuracy: {test_accuracy}, Precision: {test_precision}, Recall: {test_recall}, F1 Score: {test_f1}", file=log_file_path)

    # Generate the confusion matrix
    cm = confusion_matrix(y_test, y_test_pred)
    logger(f"Confusion Matrix:\n {cm}", file=log_file_path)

# Calculate the overall average metrics
unseen_set_avg_f1 = np.mean(unseen_f1)
unseen_set_avg_loss = np.mean(unseen_losses)
unseen_set_avg_acc = np.mean(unseen_accuracies)
unseen_set_avg_precision = np.mean(unseen_precisions)
unseen_set_avg_recall = np.mean(unseen_recalls)

logger(f"\nFinal Average F1-Score across all UNSEEN TEST sets: {unseen_set_avg_f1}", file=log_file_path)
logger(f"\nFinal Average Loss across all UNSEEN TEST sets: {unseen_set_avg_loss}", file=log_file_path)
logger(f"\nFinal Average Accuracy across all UNSEEN TEST sets: {unseen_set_avg_acc}", file=log_file_path)
logger(f"\nFinal Average Precision across all UNSEEN TEST sets: {unseen_set_avg_precision}", file=log_file_path)
logger(f"\nFinal Average Recall across all UNSEEN TEST sets: {unseen_set_avg_recall}\n", file=log_file_path)

# Append averages to total lists
all_f1.append(unseen_set_avg_f1)
all_losses.append(unseen_set_avg_loss)
all_accuracies.append(unseen_set_avg_acc)
all_precisions.append(unseen_set_avg_precision)
all_recalls.append(unseen_set_avg_recall)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# outer_fold 1
# Train Set Group Distribution:
# 046A    66
# 000A    39
# 002B    36
# 057A    28
# 074A    25
# 020A    23
# 067A    20
# 055A    20
# 059A    18
# 029A    17
# 019A    17
# 101A    16
# 106A    15
# 001A    15
# 097B    14
# 028A    14
# 042A    14
# 111A    13
# 051A    12
# 116A    12
# 039A    12
# 016A    11
# 005A    11
# 063A    11
# 025A    11
# 036A    11
# 068A    11
# 071A    10
# 015A    10
# 040A    10
# 014B    10
# 033A     9
# 022A     9
# 065A     9
# 045A     9
# 051B     9
# 094A     8
# 010A     8
# 013B     8
# 095A     8
# 053A     7
# 099A     7
# 027A     7
# 117A     7
# 007A     6
# 108A     6
# 021A     6
# 023A     6
# 109A     6
# 037A     6
# 075A     5
# 012A     5
# 023B     5
# 044A     5
# 062A     5
# 052A     4
# 009A     4
# 035A     4
# 104A     4
# 003A     4
# 026A     4
# 060A     3
# 064A     3
# 014A     3
# 058A     3
# 018A     2
# 069A     2
# 038A     2
# 054A     2
# 093A     2
# 061A     2
# 087A     2
# 066A     2
# 025B     2
# 019B     1
# 041A     1
# 115A     1
# 026C     1
# 073A     1
# 088A     1
# 043A     1
# 048A     1
# 092A     1
# 024A     1
# 090A     1
# 110A     1
# 100A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 103A    33
# 047A    30
# 000B    20
# 097A    16
# 002A    13
# 072A     9
# 050A     7
# 031A     7
# 008A     6
# 025C     6
# 034A     5
# 070A     5
# 105A     4
# 113A     3
# 006A     3
# 011A     3
# 056A     3
# 102A     2
# 032A     2
# 091A     1
# 076A     1
# 004A     1
# 096A     1
# 049A     1
# 026B     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    299
# X    281
# F    205
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    74
# M    57
# F    52
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [028A, 033A, 071A, 020A, 000A, 015A, 026A, 065...
# kitten    [046A, 042A, 014B, 110A, 109A, 040A, 045A, 048...
# senior    [117A, 106A, 057A, 090A, 051B, 116A, 051A, 024...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [002A, 070A, 000B, 105A, 034A, 072A, 006A, 091...
# kitten                                   [047A, 049A, 050A]
# senior                             [113A, 097A, 011A, 056A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 56, 'kitten': 13, 'senior': 18}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 18, 'kitten': 3, 'senior': 4}
# Unique Training/Validation Group IDs:
# ['000A' '001A' '002B' '003A' '005A' '007A' '009A' '010A' '012A' '013B'
#  '014A' '014B' '015A' '016A' '018A' '019A' '019B' '020A' '021A' '022A'
#  '023A' '023B' '024A' '025A' '025B' '026A' '026C' '027A' '028A' '029A'
#  '033A' '035A' '036A' '037A' '038A' '039A' '040A' '041A' '042A' '043A'
#  '044A' '045A' '046A' '048A' '051A' '051B' '052A' '053A' '054A' '055A'
#  '057A' '058A' '059A' '060A' '061A' '062A' '063A' '064A' '065A' '066A'
#  '067A' '068A' '069A' '071A' '073A' '074A' '075A' '087A' '088A' '090A'
#  '092A' '093A' '094A' '095A' '097B' '099A' '100A' '101A' '104A' '106A'
#  '108A' '109A' '110A' '111A' '115A' '116A' '117A']
# Unique Test Group IDs:
# ['000B' '002A' '004A' '006A' '008A' '011A' '025C' '026B' '031A' '032A'
#  '034A' '047A' '049A' '050A' '056A' '070A' '072A' '076A' '091A' '096A'
#  '097A' '102A' '103A' '105A' '113A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '001A' '002B' '003A' '005A' '007A' '009A' '010A' '012A' '013B'
#  '014A' '014B' '015A' '016A' '018A' '019A' '019B' '020A' '021A' '022A'
#  '023A' '023B' '024A' '025A' '025B' '026A' '026C' '027A' '028A' '029A'
#  '033A' '035A' '036A' '037A' '038A' '039A' '040A' '041A' '042A' '043A'
#  '044A' '045A' '046A' '048A' '051A' '051B' '052A' '053A' '054A' '055A'
#  '057A' '058A' '059A' '060A' '061A' '062A' '063A' '064A' '065A' '066A'
#  '067A' '068A' '069A' '071A' '073A' '074A' '075A' '087A' '088A' '090A'
#  '092A' '093A' '094A' '095A' '097B' '099A' '100A' '101A' '104A' '106A'
#  '108A' '109A' '110A' '111A' '115A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['000B' '002A' '004A' '006A' '008A' '011A' '025C' '026B' '031A' '032A'
#  '034A' '047A' '049A' '050A' '056A' '070A' '072A' '076A' '091A' '096A'
#  '097A' '102A' '103A' '105A' '113A']
# Length of X_train_val:
# 785
# Length of y_train_val:
# 785
# Length of groups_train_val:
# 785
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     486
# senior    161
# kitten    138
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     120
# kitten     38
# senior     25
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     486
# senior    161
# kitten    138
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     120
# kitten     38
# senior     25
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 486, 2: 161, 1: 138})
# Epoch 1/1500
# 23/23 [==============================] - 1s 5ms/step - loss: 0.8495 - accuracy: 0.6934
# Epoch 2/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3148 - accuracy: 0.8916
# Epoch 3/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.2056 - accuracy: 0.9259
# Epoch 4/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1354 - accuracy: 0.9534
# Epoch 5/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0794 - accuracy: 0.9746
# Epoch 6/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0757 - accuracy: 0.9739
# Epoch 7/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0572 - accuracy: 0.9781
# Epoch 8/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0513 - accuracy: 0.9787
# Epoch 9/1500
# 23/23 [==============================] - 0s 9ms/step - loss: 0.0373 - accuracy: 0.9870
# Epoch 10/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0245 - accuracy: 0.9938
# Epoch 11/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0263 - accuracy: 0.9918
# Epoch 12/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0288 - accuracy: 0.9890
# Epoch 13/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0168 - accuracy: 0.9952
# Epoch 14/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0148 - accuracy: 0.9979
# Epoch 15/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0133 - accuracy: 0.9959
# Epoch 16/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0091 - accuracy: 0.9973
# Epoch 17/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0173 - accuracy: 0.9925
# Epoch 18/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0101 - accuracy: 0.9973
# Epoch 19/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0137 - accuracy: 0.9966
# Epoch 20/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0065 - accuracy: 0.9986
# Epoch 21/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0176 - accuracy: 0.9938
# Epoch 22/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0118 - accuracy: 0.9973
# Epoch 23/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0131 - accuracy: 0.9966
# Epoch 24/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0126 - accuracy: 0.9973
# Epoch 25/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0169 - accuracy: 0.9945
# Epoch 26/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0158 - accuracy: 0.9945
# Epoch 27/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0092 - accuracy: 0.9973
# Epoch 28/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0105 - accuracy: 0.9966
# Epoch 29/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0142 - accuracy: 0.9938
# Epoch 30/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0063 - accuracy: 0.9986
# Epoch 31/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0144 - accuracy: 0.9945
# Epoch 32/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0094 - accuracy: 0.9979
# Epoch 33/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0040 - accuracy: 0.9993
# Epoch 34/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0056 - accuracy: 0.9993
# Epoch 35/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0046 - accuracy: 0.9993
# Epoch 36/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0062 - accuracy: 0.9986
# Epoch 37/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0097 - accuracy: 0.9966
# Epoch 38/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0052 - accuracy: 0.9986
# Epoch 39/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0081 - accuracy: 0.9973
# Epoch 40/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0054 - accuracy: 0.9979
# Epoch 41/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0122 - accuracy: 0.9945
# Epoch 42/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0066 - accuracy: 0.9979
# Epoch 43/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0049 - accuracy: 0.9986
# Epoch 44/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0040 - accuracy: 0.9993
# Epoch 45/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 46/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 9.4162e-04 - accuracy: 1.0000
# Epoch 47/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 48/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0064 - accuracy: 0.9993
# Epoch 49/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0031 - accuracy: 0.9993
# Epoch 50/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0026 - accuracy: 0.9993
# Epoch 51/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0022 - accuracy: 0.9993
# Epoch 52/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0023 - accuracy: 0.9993
# Epoch 53/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0038 - accuracy: 0.9993
# Epoch 54/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0057 - accuracy: 0.9979
# Epoch 55/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0116 - accuracy: 0.9973
# Epoch 56/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0071 - accuracy: 0.9979
# Epoch 57/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 58/1500
# 23/23 [==============================] - 0s 10ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 59/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0029 - accuracy: 0.9986
# Epoch 60/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0033 - accuracy: 0.9979
# Epoch 61/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0046 - accuracy: 0.9979
# Epoch 62/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0060 - accuracy: 0.9973
# Epoch 63/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 64/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0035 - accuracy: 0.9979
# Epoch 65/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0096 - accuracy: 0.9966
# Epoch 66/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0055 - accuracy: 0.9993
# Epoch 67/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 68/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0038 - accuracy: 0.9986
# Epoch 69/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0043 - accuracy: 0.9973
# Epoch 70/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0067 - accuracy: 0.9979
# Epoch 71/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0158 - accuracy: 0.9931
# Epoch 72/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0066 - accuracy: 0.9959
# Epoch 73/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0161 - accuracy: 0.9925
# Epoch 74/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0123 - accuracy: 0.9959
# Epoch 75/1500
# 20/23 [=========================>....] - ETA: 0s - loss: 0.0065 - accuracy: 0.9969  Restoring model weights from the end of the best epoch: 45.
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0069 - accuracy: 0.9966
# Epoch 75: early stopping
# 6/6 [==============================] - 0s 2ms/step - loss: 4.9205 - accuracy: 0.6284
# 6/6 [==============================] - 0s 2ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.76 (19/25)
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Before appending - Cat IDs: 0, Predictions: 0, Actuals: 0, Gender: 0
# After appending - Cat IDs: 183, Predictions: 183, Actuals: 183, Gender: 183
# Final Test Results - Loss: 4.9204607009887695, Accuracy: 0.6284152865409851, Precision: 0.5201837928153717, Recall: 0.43073099415204674, F1 Score: 0.4428559095225762
# Confusion Matrix:
#  [[101   6  13]
#  [ 30   8   0]
#  [ 19   0   6]]
# outer_fold 2
# Train Set Group Distribution:
# 046A    66
# 103A    33
# 047A    30
# 074A    25
# 020A    23
# 000B    20
# 067A    20
# 055A    20
# 059A    18
# 101A    16
# 097A    16
# 106A    15
# 097B    14
# 028A    14
# 042A    14
# 002A    13
# 039A    12
# 116A    12
# 051A    12
# 068A    11
# 025A    11
# 016A    11
# 014B    10
# 015A    10
# 071A    10
# 065A     9
# 051B     9
# 022A     9
# 072A     9
# 013B     8
# 095A     8
# 010A     8
# 094A     8
# 117A     7
# 027A     7
# 050A     7
# 031A     7
# 053A     7
# 025C     6
# 037A     6
# 021A     6
# 008A     6
# 034A     5
# 023B     5
# 070A     5
# 044A     5
# 035A     4
# 105A     4
# 026A     4
# 056A     3
# 011A     3
# 014A     3
# 113A     3
# 064A     3
# 060A     3
# 006A     3
# 025B     2
# 061A     2
# 087A     2
# 069A     2
# 032A     2
# 093A     2
# 102A     2
# 041A     1
# 004A     1
# 019B     1
# 076A     1
# 026B     1
# 115A     1
# 026C     1
# 073A     1
# 088A     1
# 096A     1
# 043A     1
# 049A     1
# 024A     1
# 091A     1
# 090A     1
# 110A     1
# 100A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 000A    39
# 002B    36
# 057A    28
# 029A    17
# 019A    17
# 001A    15
# 111A    13
# 036A    11
# 063A    11
# 005A    11
# 040A    10
# 033A     9
# 045A     9
# 099A     7
# 109A     6
# 007A     6
# 023A     6
# 108A     6
# 012A     5
# 075A     5
# 062A     5
# 003A     4
# 009A     4
# 052A     4
# 104A     4
# 058A     3
# 054A     2
# 018A     2
# 066A     2
# 038A     2
# 048A     1
# 092A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    239
# M    237
# F    191
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# M    119
# X    116
# F     66
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [002A, 028A, 070A, 000B, 071A, 020A, 015A, 026...
# kitten    [046A, 042A, 014B, 110A, 047A, 049A, 044A, 043...
# senior    [117A, 106A, 090A, 113A, 051B, 116A, 051A, 024...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [033A, 000A, 038A, 007A, 001A, 018A, 062A, 002...
# kitten                       [109A, 040A, 045A, 048A, 111A]
# senior                       [057A, 058A, 054A, 108A, 104A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 52, 'kitten': 11, 'senior': 17}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 22, 'kitten': 5, 'senior': 5}
# Unique Training/Validation Group IDs:
# ['000B' '002A' '004A' '006A' '008A' '010A' '011A' '013B' '014A' '014B'
#  '015A' '016A' '019B' '020A' '021A' '022A' '023B' '024A' '025A' '025B'
#  '025C' '026A' '026B' '026C' '027A' '028A' '031A' '032A' '034A' '035A'
#  '037A' '039A' '041A' '042A' '043A' '044A' '046A' '047A' '049A' '050A'
#  '051A' '051B' '053A' '055A' '056A' '059A' '060A' '061A' '064A' '065A'
#  '067A' '068A' '069A' '070A' '071A' '072A' '073A' '074A' '076A' '087A'
#  '088A' '090A' '091A' '093A' '094A' '095A' '096A' '097A' '097B' '100A'
#  '101A' '102A' '103A' '105A' '106A' '110A' '113A' '115A' '116A' '117A']
# Unique Test Group IDs:
# ['000A' '001A' '002B' '003A' '005A' '007A' '009A' '012A' '018A' '019A'
#  '023A' '029A' '033A' '036A' '038A' '040A' '045A' '048A' '052A' '054A'
#  '057A' '058A' '062A' '063A' '066A' '075A' '092A' '099A' '104A' '108A'
#  '109A' '111A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'000A'}
# Removed from Training/Validation Set:
# {'102A'}
# Moved to Test Set:
# {'102A'}
# Removed from Test Set
# {'000A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '002A' '004A' '006A' '008A' '010A' '011A' '013B' '014A'
#  '014B' '015A' '016A' '019B' '020A' '021A' '022A' '023B' '024A' '025A'
#  '025B' '025C' '026A' '026B' '026C' '027A' '028A' '031A' '032A' '034A'
#  '035A' '037A' '039A' '041A' '042A' '043A' '044A' '046A' '047A' '049A'
#  '050A' '051A' '051B' '053A' '055A' '056A' '059A' '060A' '061A' '064A'
#  '065A' '067A' '068A' '069A' '070A' '071A' '072A' '073A' '074A' '076A'
#  '087A' '088A' '090A' '091A' '093A' '094A' '095A' '096A' '097A' '097B'
#  '100A' '101A' '103A' '105A' '106A' '110A' '113A' '115A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['001A' '002B' '003A' '005A' '007A' '009A' '012A' '018A' '019A' '023A'
#  '029A' '033A' '036A' '038A' '040A' '045A' '048A' '052A' '054A' '057A'
#  '058A' '062A' '063A' '066A' '075A' '092A' '099A' '102A' '104A' '108A'
#  '109A' '111A']
# Length of X_train_val:
# 704
# Length of y_train_val:
# 704
# Length of groups_train_val:
# 704
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     387
# senior    143
# kitten    137
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     219
# senior     43
# kitten     39
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     424
# senior    143
# kitten    137
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     182
# senior     43
# kitten     39
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 424, 2: 143, 1: 137})
# Epoch 1/1500
# 20/20 [==============================] - 1s 6ms/step - loss: 0.8159 - accuracy: 0.7146
# Epoch 2/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.2812 - accuracy: 0.8954
# Epoch 3/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.1766 - accuracy: 0.9387
# Epoch 4/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.1108 - accuracy: 0.9631
# Epoch 5/1500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0951 - accuracy: 0.9638
# Epoch 6/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0711 - accuracy: 0.9780
# Epoch 7/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0585 - accuracy: 0.9803
# Epoch 8/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0393 - accuracy: 0.9906
# Epoch 9/1500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0499 - accuracy: 0.9803
# Epoch 10/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0375 - accuracy: 0.9858
# Epoch 11/1500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0382 - accuracy: 0.9851
# Epoch 12/1500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0179 - accuracy: 0.9929
# Epoch 13/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0156 - accuracy: 0.9969
# Epoch 14/1500
# 20/20 [==============================] - 0s 8ms/step - loss: 0.0166 - accuracy: 0.9969
# Epoch 15/1500
# 20/20 [==============================] - 0s 7ms/step - loss: 0.0109 - accuracy: 0.9976
# Epoch 16/1500
# 20/20 [==============================] - 0s 7ms/step - loss: 0.0133 - accuracy: 0.9961
# Epoch 17/1500
# 20/20 [==============================] - 0s 7ms/step - loss: 0.0094 - accuracy: 0.9961
# Epoch 18/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0187 - accuracy: 0.9953
# Epoch 19/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0115 - accuracy: 0.9976
# Epoch 20/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0070 - accuracy: 0.9976
# Epoch 21/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0058 - accuracy: 0.9992
# Epoch 22/1500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0069 - accuracy: 0.9976
# Epoch 23/1500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0113 - accuracy: 0.9961
# Epoch 24/1500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0044 - accuracy: 1.0000
# Epoch 25/1500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0050 - accuracy: 0.9992
# Epoch 26/1500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0146 - accuracy: 0.9953
# Epoch 27/1500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0072 - accuracy: 0.9984
# Epoch 28/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0074 - accuracy: 0.9976
# Epoch 29/1500
# 20/20 [==============================] - 0s 7ms/step - loss: 0.0048 - accuracy: 0.9992
# Epoch 30/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0064 - accuracy: 0.9976
# Epoch 31/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0162 - accuracy: 0.9961
# Epoch 32/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0093 - accuracy: 0.9969
# Epoch 33/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0086 - accuracy: 0.9976
# Epoch 34/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0067 - accuracy: 0.9976
# Epoch 35/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0050 - accuracy: 0.9976
# Epoch 36/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0018 - accuracy: 0.9992
# Epoch 37/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0086 - accuracy: 0.9969
# Epoch 38/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0047 - accuracy: 0.9992
# Epoch 39/1500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0047 - accuracy: 0.9976
# Epoch 40/1500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0054 - accuracy: 0.9984
# Epoch 41/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0047 - accuracy: 0.9976
# Epoch 42/1500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0052 - accuracy: 0.9976
# Epoch 43/1500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0106 - accuracy: 0.9969
# Epoch 44/1500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0056 - accuracy: 0.9992
# Epoch 45/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0039 - accuracy: 0.9984
# Epoch 46/1500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0057 - accuracy: 0.9976
# Epoch 47/1500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0146 - accuracy: 0.9961
# Epoch 48/1500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0063 - accuracy: 0.9976
# Epoch 49/1500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0089 - accuracy: 0.9945
# Epoch 50/1500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0085 - accuracy: 0.9961
# Epoch 51/1500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0077 - accuracy: 0.9976
# Epoch 52/1500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0028 - accuracy: 0.9992
# Epoch 53/1500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 54/1500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 55/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 9.8499e-04 - accuracy: 1.0000
# Epoch 56/1500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0048 - accuracy: 0.9992
# Epoch 57/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0021 - accuracy: 0.9992
# Epoch 58/1500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0022 - accuracy: 0.9992
# Epoch 59/1500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0035 - accuracy: 0.9992
# Epoch 60/1500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0032 - accuracy: 0.9992
# Epoch 61/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0043 - accuracy: 0.9984
# Epoch 62/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0120 - accuracy: 0.9976
# Epoch 63/1500
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0040 - accuracy: 0.9992
# Epoch 64/1500
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0017 - accuracy: 0.9992
# Epoch 65/1500
# 20/20 [==============================] - 0s 12ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 66/1500
# 11/20 [===============>..............] - ETA: 0s - loss: 0.0057 - accuracy: 0.9986    Restoring model weights from the end of the best epoch: 36.
# 20/20 [==============================] - 0s 6ms/step - loss: 0.0041 - accuracy: 0.9992
# Epoch 66: early stopping
# 9/9 [==============================] - 0s 3ms/step - loss: 2.4861 - accuracy: 0.6364
# 9/9 [==============================] - 0s 2ms/step
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Majority Vote Accuracy for cat_id for this fold: 0.75 (24/32)
# Before appending - Cat IDs: 183, Predictions: 183, Actuals: 183, Gender: 183
# After appending - Cat IDs: 447, Predictions: 447, Actuals: 447, Gender: 447
# Final Test Results - Loss: 2.486128568649292, Accuracy: 0.6363636255264282, Precision: 0.527937412154552, Recall: 0.5525456455689014, F1 Score: 0.5386947352564585
# Confusion Matrix:
#  [[130  20  32]
#  [ 14  25   0]
#  [ 29   1  13]]
# outer_fold 3
# Train Set Group Distribution:
# 046A    66
# 000A    39
# 002B    36
# 103A    33
# 047A    30
# 057A    28
# 020A    23
# 055A    20
# 000B    20
# 059A    18
# 029A    17
# 019A    17
# 097A    16
# 101A    16
# 001A    15
# 042A    14
# 028A    14
# 097B    14
# 111A    13
# 002A    13
# 005A    11
# 068A    11
# 063A    11
# 036A    11
# 071A    10
# 014B    10
# 040A    10
# 015A    10
# 051B     9
# 072A     9
# 033A     9
# 022A     9
# 045A     9
# 013B     8
# 095A     8
# 099A     7
# 117A     7
# 027A     7
# 031A     7
# 050A     7
# 108A     6
# 023A     6
# 008A     6
# 025C     6
# 109A     6
# 007A     6
# 023B     5
# 034A     5
# 012A     5
# 062A     5
# 075A     5
# 070A     5
# 052A     4
# 009A     4
# 104A     4
# 003A     4
# 105A     4
# 056A     3
# 011A     3
# 113A     3
# 006A     3
# 064A     3
# 058A     3
# 102A     2
# 093A     2
# 038A     2
# 069A     2
# 066A     2
# 054A     2
# 018A     2
# 032A     2
# 115A     1
# 041A     1
# 076A     1
# 110A     1
# 004A     1
# 096A     1
# 088A     1
# 091A     1
# 048A     1
# 024A     1
# 092A     1
# 049A     1
# 026C     1
# 026B     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 074A    25
# 067A    20
# 106A    15
# 039A    12
# 116A    12
# 051A    12
# 025A    11
# 016A    11
# 065A     9
# 094A     8
# 010A     8
# 053A     7
# 021A     6
# 037A     6
# 044A     5
# 026A     4
# 035A     4
# 060A     3
# 014A     3
# 061A     2
# 087A     2
# 025B     2
# 043A     1
# 073A     1
# 090A     1
# 019B     1
# 100A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    325
# M    258
# F    193
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# M    98
# F    64
# X    30
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [002A, 028A, 070A, 033A, 000B, 071A, 020A, 000...
# kitten    [046A, 042A, 014B, 110A, 109A, 040A, 047A, 049...
# senior    [117A, 057A, 113A, 051B, 024A, 097A, 059A, 055...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [026A, 065A, 053A, 021A, 010A, 074A, 067A, 025...
# kitten                                         [044A, 043A]
# senior           [106A, 090A, 116A, 051A, 094A, 016A, 061A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 56, 'kitten': 14, 'senior': 15}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 18, 'kitten': 2, 'senior': 7}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '004A' '005A' '006A' '007A'
#  '008A' '009A' '011A' '012A' '013B' '014B' '015A' '018A' '019A' '020A'
#  '022A' '023A' '023B' '024A' '025C' '026B' '026C' '027A' '028A' '029A'
#  '031A' '032A' '033A' '034A' '036A' '038A' '040A' '041A' '042A' '045A'
#  '046A' '047A' '048A' '049A' '050A' '051B' '052A' '054A' '055A' '056A'
#  '057A' '058A' '059A' '062A' '063A' '064A' '066A' '068A' '069A' '070A'
#  '071A' '072A' '075A' '076A' '088A' '091A' '092A' '093A' '095A' '096A'
#  '097A' '097B' '099A' '101A' '102A' '103A' '104A' '105A' '108A' '109A'
#  '110A' '111A' '113A' '115A' '117A']
# Unique Test Group IDs:
# ['010A' '014A' '016A' '019B' '021A' '025A' '025B' '026A' '035A' '037A'
#  '039A' '043A' '044A' '051A' '053A' '060A' '061A' '065A' '067A' '073A'
#  '074A' '087A' '090A' '094A' '100A' '106A' '116A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '004A' '005A' '006A' '007A'
#  '008A' '009A' '011A' '012A' '013B' '014B' '015A' '018A' '019A' '020A'
#  '022A' '023A' '023B' '024A' '025C' '026B' '026C' '027A' '028A' '029A'
#  '031A' '032A' '033A' '034A' '036A' '038A' '040A' '041A' '042A' '045A'
#  '046A' '047A' '048A' '049A' '050A' '051B' '052A' '054A' '055A' '056A'
#  '057A' '058A' '059A' '062A' '063A' '064A' '066A' '068A' '069A' '070A'
#  '071A' '072A' '075A' '076A' '088A' '091A' '092A' '093A' '095A' '096A'
#  '097A' '097B' '099A' '101A' '102A' '103A' '104A' '105A' '108A' '109A'
#  '110A' '111A' '113A' '115A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['010A' '014A' '016A' '019B' '021A' '025A' '025B' '026A' '035A' '037A'
#  '039A' '043A' '044A' '051A' '053A' '060A' '061A' '065A' '067A' '073A'
#  '074A' '087A' '090A' '094A' '100A' '106A' '116A']
# Length of X_train_val:
# 776
# Length of y_train_val:
# 776
# Length of groups_train_val:
# 776
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     481
# kitten    170
# senior    125
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     125
# senior     61
# kitten      6
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     481
# kitten    170
# senior    125
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     125
# senior     61
# kitten      6
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 481, 1: 170, 2: 125})
# Epoch 1/1500
# 23/23 [==============================] - 1s 5ms/step - loss: 0.7716 - accuracy: 0.7401
# Epoch 2/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.2874 - accuracy: 0.8926
# Epoch 3/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1567 - accuracy: 0.9425
# Epoch 4/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0912 - accuracy: 0.9716
# Epoch 5/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0992 - accuracy: 0.9702
# Epoch 6/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0668 - accuracy: 0.9785
# Epoch 7/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0508 - accuracy: 0.9841
# Epoch 8/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0407 - accuracy: 0.9848
# Epoch 9/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0413 - accuracy: 0.9861
# Epoch 10/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0374 - accuracy: 0.9848
# Epoch 11/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0222 - accuracy: 0.9910
# Epoch 12/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0239 - accuracy: 0.9924
# Epoch 13/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0261 - accuracy: 0.9910
# Epoch 14/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0233 - accuracy: 0.9938
# Epoch 15/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0281 - accuracy: 0.9896
# Epoch 16/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0328 - accuracy: 0.9861
# Epoch 17/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0350 - accuracy: 0.9868
# Epoch 18/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0291 - accuracy: 0.9917
# Epoch 19/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0193 - accuracy: 0.9938
# Epoch 20/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0096 - accuracy: 0.9958
# Epoch 21/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0085 - accuracy: 0.9972
# Epoch 22/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0090 - accuracy: 0.9979
# Epoch 23/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0088 - accuracy: 0.9979
# Epoch 24/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0093 - accuracy: 0.9958
# Epoch 25/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0079 - accuracy: 0.9965
# Epoch 26/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0048 - accuracy: 1.0000
# Epoch 27/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0059 - accuracy: 0.9986
# Epoch 28/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0073 - accuracy: 0.9979
# Epoch 29/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0099 - accuracy: 0.9972
# Epoch 30/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0092 - accuracy: 0.9972
# Epoch 31/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0124 - accuracy: 0.9972
# Epoch 32/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0088 - accuracy: 0.9979
# Epoch 33/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0102 - accuracy: 0.9965
# Epoch 34/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 35/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0050 - accuracy: 0.9972
# Epoch 36/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0084 - accuracy: 0.9965
# Epoch 37/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0061 - accuracy: 0.9986
# Epoch 38/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 39/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0115 - accuracy: 0.9958
# Epoch 40/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0042 - accuracy: 0.9993
# Epoch 41/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0039 - accuracy: 0.9993
# Epoch 42/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0053 - accuracy: 0.9993
# Epoch 43/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0039 - accuracy: 0.9986
# Epoch 44/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0055 - accuracy: 0.9972
# Epoch 45/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0053 - accuracy: 0.9979
# Epoch 46/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 47/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0027 - accuracy: 0.9993
# Epoch 48/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 49/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0078 - accuracy: 0.9972
# Epoch 50/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0070 - accuracy: 0.9986
# Epoch 51/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0094 - accuracy: 0.9965
# Epoch 52/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0133 - accuracy: 0.9945
# Epoch 53/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0120 - accuracy: 0.9972
# Epoch 54/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0123 - accuracy: 0.9945
# Epoch 55/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0063 - accuracy: 0.9972
# Epoch 56/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0076 - accuracy: 0.9972
# Epoch 57/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0079 - accuracy: 0.9965
# Epoch 58/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0077 - accuracy: 0.9965
# Epoch 59/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0048 - accuracy: 0.9979
# Epoch 60/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0042 - accuracy: 0.9979
# Epoch 61/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 62/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 63/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 9.8902e-04 - accuracy: 1.0000
# Epoch 64/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 65/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0023 - accuracy: 0.9993
# Epoch 66/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 5.8946e-04 - accuracy: 1.0000
# Epoch 67/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0071 - accuracy: 0.9972
# Epoch 68/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 69/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0063 - accuracy: 0.9979
# Epoch 70/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0028 - accuracy: 0.9986
# Epoch 71/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 72/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0033 - accuracy: 0.9986
# Epoch 73/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0030 - accuracy: 0.9986
# Epoch 74/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0089 - accuracy: 0.9945
# Epoch 75/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0168 - accuracy: 0.9945
# Epoch 76/1500
# 23/23 [==============================] - 0s 7ms/step - loss: 0.0036 - accuracy: 0.9979
# Epoch 77/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 78/1500
# 22/23 [===========================>..] - ETA: 0s - loss: 7.0311e-04 - accuracy: 1.0000Restoring model weights from the end of the best epoch: 48.
# 23/23 [==============================] - 0s 5ms/step - loss: 6.9504e-04 - accuracy: 1.0000
# Epoch 78: early stopping
# 6/6 [==============================] - 0s 1ms/step - loss: 5.9136 - accuracy: 0.6094
# 6/6 [==============================] - 0s 920us/step
# Majority Vote Accuracy for cat_id for this fold: 0.70 (19/27)
# Before appending - Cat IDs: 447, Predictions: 447, Actuals: 447, Gender: 447
# After appending - Cat IDs: 639, Predictions: 639, Actuals: 639, Gender: 639
# Final Test Results - Loss: 5.913623809814453, Accuracy: 0.609375, Precision: 0.44637800849457293, Recall: 0.5403424408014571, F1 Score: 0.43998411432621953
# Confusion Matrix:
#  [[107   8  10]
#  [  2   4   0]
#  [ 54   1   6]]
# outer_fold 4
# Train Set Group Distribution:
# 000A    39
# 002B    36
# 103A    33
# 047A    30
# 057A    28
# 074A    25
# 067A    20
# 000B    20
# 029A    17
# 019A    17
# 097A    16
# 106A    15
# 001A    15
# 111A    13
# 002A    13
# 051A    12
# 116A    12
# 039A    12
# 016A    11
# 025A    11
# 036A    11
# 005A    11
# 063A    11
# 040A    10
# 065A     9
# 045A     9
# 072A     9
# 033A     9
# 010A     8
# 094A     8
# 099A     7
# 050A     7
# 031A     7
# 053A     7
# 108A     6
# 008A     6
# 109A     6
# 021A     6
# 007A     6
# 037A     6
# 023A     6
# 025C     6
# 012A     5
# 044A     5
# 062A     5
# 075A     5
# 034A     5
# 070A     5
# 035A     4
# 104A     4
# 009A     4
# 026A     4
# 003A     4
# 052A     4
# 105A     4
# 014A     3
# 006A     3
# 011A     3
# 060A     3
# 058A     3
# 056A     3
# 113A     3
# 025B     2
# 038A     2
# 018A     2
# 061A     2
# 087A     2
# 066A     2
# 032A     2
# 054A     2
# 102A     2
# 026B     1
# 019B     1
# 004A     1
# 076A     1
# 049A     1
# 073A     1
# 096A     1
# 043A     1
# 048A     1
# 092A     1
# 091A     1
# 090A     1
# 100A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 046A    66
# 020A    23
# 055A    20
# 059A    18
# 101A    16
# 028A    14
# 097B    14
# 042A    14
# 068A    11
# 014B    10
# 071A    10
# 015A    10
# 051B     9
# 022A     9
# 095A     8
# 013B     8
# 117A     7
# 027A     7
# 023B     5
# 064A     3
# 093A     2
# 069A     2
# 110A     1
# 088A     1
# 026C     1
# 041A     1
# 115A     1
# 024A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    274
# X    220
# F    182
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    135
# M     82
# F     75
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [002A, 070A, 033A, 000B, 000A, 026A, 065A, 053...
# kitten    [109A, 040A, 047A, 049A, 045A, 048A, 111A, 044...
# senior    [106A, 057A, 090A, 113A, 116A, 051A, 097A, 094...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [028A, 071A, 020A, 015A, 023B, 026C, 068A, 013...
# kitten                 [046A, 042A, 014B, 110A, 041A, 115A]
# senior                 [117A, 051B, 024A, 059A, 055A, 093A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 58, 'kitten': 10, 'senior': 16}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 16, 'kitten': 6, 'senior': 6}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '004A' '005A' '006A' '007A'
#  '008A' '009A' '010A' '011A' '012A' '014A' '016A' '018A' '019A' '019B'
#  '021A' '023A' '025A' '025B' '025C' '026A' '026B' '029A' '031A' '032A'
#  '033A' '034A' '035A' '036A' '037A' '038A' '039A' '040A' '043A' '044A'
#  '045A' '047A' '048A' '049A' '050A' '051A' '052A' '053A' '054A' '056A'
#  '057A' '058A' '060A' '061A' '062A' '063A' '065A' '066A' '067A' '070A'
#  '072A' '073A' '074A' '075A' '076A' '087A' '090A' '091A' '092A' '094A'
#  '096A' '097A' '099A' '100A' '102A' '103A' '104A' '105A' '106A' '108A'
#  '109A' '111A' '113A' '116A']
# Unique Test Group IDs:
# ['013B' '014B' '015A' '020A' '022A' '023B' '024A' '026C' '027A' '028A'
#  '041A' '042A' '046A' '051B' '055A' '059A' '064A' '068A' '069A' '071A'
#  '088A' '093A' '095A' '097B' '101A' '110A' '115A' '117A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'046A'}
# Removed from Training/Validation Set:
# {'048A'}
# Moved to Test Set:
# {'048A'}
# Removed from Test Set
# {'046A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '004A' '005A' '006A' '007A'
#  '008A' '009A' '010A' '011A' '012A' '014A' '016A' '018A' '019A' '019B'
#  '021A' '023A' '025A' '025B' '025C' '026A' '026B' '029A' '031A' '032A'
#  '033A' '034A' '035A' '036A' '037A' '038A' '039A' '040A' '043A' '044A'
#  '045A' '046A' '047A' '049A' '050A' '051A' '052A' '053A' '054A' '056A'
#  '057A' '058A' '060A' '061A' '062A' '063A' '065A' '066A' '067A' '070A'
#  '072A' '073A' '074A' '075A' '076A' '087A' '090A' '091A' '092A' '094A'
#  '096A' '097A' '099A' '100A' '102A' '103A' '104A' '105A' '106A' '108A'
#  '109A' '111A' '113A' '116A']
# AFTER SWAP - Unique Test Group IDs:
# ['013B' '014B' '015A' '020A' '022A' '023B' '024A' '026C' '027A' '028A'
#  '041A' '042A' '048A' '051B' '055A' '059A' '064A' '068A' '069A' '071A'
#  '088A' '093A' '095A' '097B' '101A' '110A' '115A' '117A']
# Length of X_train_val:
# 741
# Length of y_train_val:
# 741
# Length of groups_train_val:
# 741
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     464
# senior    129
# kitten     83
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     142
# kitten     93
# senior     57
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     464
# kitten    148
# senior    129
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     142
# senior     57
# kitten     28
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 464, 1: 148, 2: 129})
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Epoch 1/1500
# 22/22 [==============================] - 1s 5ms/step - loss: 0.7182 - accuracy: 0.7464
# Epoch 2/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.2452 - accuracy: 0.9088
# Epoch 3/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1484 - accuracy: 0.9483
# Epoch 4/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1172 - accuracy: 0.9619
# Epoch 5/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0690 - accuracy: 0.9727
# Epoch 6/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0425 - accuracy: 0.9856
# Epoch 7/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0579 - accuracy: 0.9799
# Epoch 8/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0268 - accuracy: 0.9943
# Epoch 9/1500
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0229 - accuracy: 0.9935
# Epoch 10/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0173 - accuracy: 0.9928
# Epoch 11/1500
# 22/22 [==============================] - 0s 9ms/step - loss: 0.0288 - accuracy: 0.9892
# Epoch 12/1500
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0209 - accuracy: 0.9950
# Epoch 13/1500
# 22/22 [==============================] - 0s 11ms/step - loss: 0.0118 - accuracy: 0.9964
# Epoch 14/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0142 - accuracy: 0.9943
# Epoch 15/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0157 - accuracy: 0.9950
# Epoch 16/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0072 - accuracy: 0.9986
# Epoch 17/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0104 - accuracy: 0.9957
# Epoch 18/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0065 - accuracy: 0.9978
# Epoch 19/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0080 - accuracy: 0.9978
# Epoch 20/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0081 - accuracy: 0.9964
# Epoch 21/1500
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0071 - accuracy: 0.9971
# Epoch 22/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0103 - accuracy: 0.9950
# Epoch 23/1500
# 22/22 [==============================] - 0s 15ms/step - loss: 0.0107 - accuracy: 0.9957
# Epoch 24/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0082 - accuracy: 0.9964
# Epoch 25/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0035 - accuracy: 0.9993
# Epoch 26/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0057 - accuracy: 0.9978
# Epoch 27/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 28/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0032 - accuracy: 0.9986
# Epoch 29/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0065 - accuracy: 0.9971
# Epoch 30/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0115 - accuracy: 0.9957
# Epoch 31/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0090 - accuracy: 0.9971
# Epoch 32/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0030 - accuracy: 0.9993
# Epoch 33/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0036 - accuracy: 0.9993
# Epoch 34/1500
# 22/22 [==============================] - 0s 7ms/step - loss: 0.0120 - accuracy: 0.9964
# Epoch 35/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0142 - accuracy: 0.9950
# Epoch 36/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0060 - accuracy: 0.9978
# Epoch 37/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0089 - accuracy: 0.9957
# Epoch 38/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0067 - accuracy: 0.9964
# Epoch 39/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0046 - accuracy: 0.9986
# Epoch 40/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0048 - accuracy: 0.9993
# Epoch 41/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0033 - accuracy: 0.9978
# Epoch 42/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0035 - accuracy: 0.9993
# Epoch 43/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0088 - accuracy: 0.9978
# Epoch 44/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0098 - accuracy: 0.9986
# Epoch 45/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0079 - accuracy: 0.9978
# Epoch 46/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0105 - accuracy: 0.9964
# Epoch 47/1500
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0101 - accuracy: 0.9971
# Epoch 48/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0104 - accuracy: 0.9943
# Epoch 49/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0110 - accuracy: 0.9971
# Epoch 50/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0053 - accuracy: 0.9986
# Epoch 51/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0061 - accuracy: 0.9978
# Epoch 52/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0055 - accuracy: 0.9986
# Epoch 53/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 54/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0053 - accuracy: 0.9986
# Epoch 55/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0049 - accuracy: 0.9971
# Epoch 56/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0207 - accuracy: 0.9935
# Epoch 57/1500
# 21/22 [===========================>..] - ETA: 0s - loss: 0.0142 - accuracy: 0.9970Restoring model weights from the end of the best epoch: 27.
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0148 - accuracy: 0.9964
# Epoch 57: early stopping
# 8/8 [==============================] - 0s 1ms/step - loss: 2.1278 - accuracy: 0.6828
# 8/8 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.86 (24/28)
# Before appending - Cat IDs: 639, Predictions: 639, Actuals: 639, Gender: 639
# After appending - Cat IDs: 866, Predictions: 866, Actuals: 866, Gender: 866
# Final Test Results - Loss: 2.127756357192993, Accuracy: 0.6828193664550781, Precision: 0.6559034572733203, Recall: 0.6122259875039712, F1 Score: 0.6296514332228619
# Confusion Matrix:
#  [[110   6  26]
#  [  9  15   4]
#  [ 27   0  30]]
#
# Final Average F1-Score across all UNSEEN TEST sets: 0.512796548082029
#
# Final Average Loss across all UNSEEN TEST sets: 3.861992359161377
#
# Final Average Accuracy across all UNSEEN TEST sets: 0.6392433196306229
#
# Final Average Precision across all UNSEEN TEST sets: 0.5376006676844542
#
# Final Average Recall across all UNSEEN TEST sets: 0.5339612670065941

# %%
seed_5_folds_values = (unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1)

# Plotting all fold metrics|
seed_5_folds_plot = plot_all_metrics(unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1, "Folds", "Fold Number")

# %% [markdown]
# ## Majority Voting on Total Entries per cat_id

# %%
# Debugging print statements
print(f'Checking - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
# Out:
# Checking - Cat IDs: 866, Predictions: 866, Actuals: 866, Gender: 866

# %%
# Create results df
full_results = pd.DataFrame({
    'cat_id': all_cat_ids,
    'predicted_age_group': all_predicted_age_groups,
    'actual_age_group': all_actual_age_groups,
    'all_gender': all_gender
})

# create a correct majority prediction column
full_results['correct'] = full_results['predicted_age_group'] == full_results['actual_age_group']

# %%
# Group by cat_id and aggregate predicted age groups
majority_votes = full_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first()

# Calculate the accuracy of majority voting
correct_predictions = (majority_votes == actual_groups).sum()
total_cats = len(actual_groups)
majority_vote_accuracy = correct_predictions / total_cats

logger(f"Overall Majority Vote Accuracy for cat_id: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

# store for final evaluation 
all_majority_vote_accuracies.append(majority_vote_accuracy)
# Out:
# Overall Majority Vote Accuracy for cat_id: 0.76 (84/110)

# %%
# Detailed df with predictions, actual labels, and comparison including majority vote
detailed_results = full_results.groupby('cat_id').apply(
    lambda x: pd.Series({
        'Predictions': list(x['predicted_age_group']),
        'Majority Vote': x['predicted_age_group'].mode()[0],
        'Actual Age Group': x['actual_age_group'].iloc[0],
        'Correct Majority Vote': x['predicted_age_group'].mode()[0] == x['actual_age_group'].iloc[0]
    })
).reset_index()

# Convert to DataFrame for better formatting and display
detailed_results = pd.DataFrame(detailed_results)

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 10)
pd.set_option('display.width', 1000)

sorted_detailed_results = detailed_results.sort_values(by='Correct Majority Vote', ascending=False)

# Display the sorted DataFrame
sorted_detailed_results
# Out:
#     cat_id                                        Predictions Majority Vote Actual Age Group  Correct Majority Vote
# 0     000B  [adult, adult, senior, kitten, adult, adult, a...         adult            adult                   True
# 45    039A  [senior, adult, adult, adult, senior, senior, ...         adult            adult                   True
# 75    069A                                    [senior, adult]         adult            adult                   True
# 74    068A  [adult, adult, adult, adult, senior, senior, s...         adult            adult                   True
# 73    067A  [adult, adult, kitten, adult, adult, adult, ad...         adult            adult                   True
# 72    066A                                    [adult, kitten]         adult            adult                   True
# 71    065A  [adult, adult, adult, kitten, adult, kitten, a...         adult            adult                   True
# 70    064A                             [senior, adult, adult]         adult            adult                   True
# 68    062A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 66    060A                             [kitten, adult, adult]         adult            adult                   True
# 65    059A  [senior, senior, senior, senior, adult, senior...        senior           senior                   True
# 60    054A                                   [senior, senior]        senior           senior                   True
# 58    052A                       [adult, adult, adult, adult]         adult            adult                   True
# 1     001A  [adult, adult, adult, adult, senior, adult, ad...         adult            adult                   True
# 54    049A                                           [kitten]        kitten           kitten                   True
# 53    048A                                   [kitten, kitten]        kitten           kitten                   True
# 51    045A  [kitten, adult, kitten, kitten, kitten, kitten...        kitten           kitten                   True
# 50    044A             [kitten, adult, kitten, kitten, adult]        kitten           kitten                   True
# 49    043A                                           [kitten]        kitten           kitten                   True
# 48    042A  [kitten, kitten, kitten, adult, kitten, kitten...        kitten           kitten                   True
# 47    041A                                           [kitten]        kitten           kitten                   True
# 76    070A               [adult, senior, adult, adult, adult]         adult            adult                   True
# 77    071A  [adult, adult, adult, adult, adult, senior, se...         adult            adult                   True
# 78    072A  [adult, kitten, adult, adult, adult, senior, s...         adult            adult                   True
# 94    099A  [adult, adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 107   115A                                           [kitten]        kitten           kitten                   True
# 105   111A  [adult, adult, kitten, kitten, kitten, adult, ...        kitten           kitten                   True
# 104   110A                                           [kitten]        kitten           kitten                   True
# 100   105A                      [adult, adult, adult, kitten]         adult            adult                   True
# 98    103A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 97    102A                       [adult, adult, adult, adult]         adult            adult                   True
# 96    101A  [senior, senior, adult, adult, adult, senior, ...         adult            adult                   True
# 95    100A                                            [adult]         adult            adult                   True
# 93    097B  [senior, adult, adult, adult, adult, adult, ad...         adult            adult                   True
# 79    073A                                            [adult]         adult            adult                   True
# 91    096A                                            [adult]         adult            adult                   True
# 90    095A  [adult, adult, adult, senior, adult, adult, se...         adult            adult                   True
# 87    092A                                            [adult]         adult            adult                   True
# 86    091A                                            [adult]         adult            adult                   True
# 84    088A                                            [adult]         adult            adult                   True
# 83    087A                                     [adult, adult]         adult            adult                   True
# 81    075A              [senior, senior, adult, adult, adult]         adult            adult                   True
# 80    074A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 46    040A  [kitten, adult, adult, kitten, kitten, adult, ...        kitten           kitten                   True
# 55    050A  [kitten, kitten, adult, adult, adult, kitten, ...        kitten           kitten                   True
# 22    020A  [senior, adult, adult, adult, adult, adult, ad...         adult            adult                   True
# 15    014A                              [adult, adult, adult]         adult            adult                   True
# 27    024A                                           [senior]        senior           senior                   True
# 26    023B               [adult, adult, adult, adult, senior]         adult            adult                   True
# 25    023A        [adult, kitten, adult, adult, adult, adult]         adult            adult                   True
# 24    022A  [adult, kitten, kitten, adult, adult, adult, a...         adult            adult                   True
# 23    021A        [adult, adult, adult, adult, adult, kitten]         adult            adult                   True
# 43    037A        [kitten, adult, adult, adult, adult, adult]         adult            adult                   True
# 21    019B                                            [adult]         adult            adult                   True
# 20    019A  [adult, kitten, kitten, adult, adult, adult, k...         adult            adult                   True
# 19    018A                                     [adult, adult]         adult            adult                   True
# 17    015A  [senior, adult, adult, adult, adult, senior, s...         adult            adult                   True
# 14    013B  [adult, adult, adult, adult, kitten, senior, a...         adult            adult                   True
# 29    025B                                     [adult, adult]         adult            adult                   True
# 13    012A               [adult, adult, adult, adult, kitten]         adult            adult                   True
# 11    010A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 10    009A                       [adult, adult, adult, adult]         adult            adult                   True
# 9     008A         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 8     007A       [adult, adult, adult, adult, kitten, senior]         adult            adult                   True
# 7     006A                             [senior, adult, adult]         adult            adult                   True
# 5     004A                                            [adult]         adult            adult                   True
# 4     003A                     [kitten, kitten, adult, adult]         adult            adult                   True
# 3     002B  [adult, adult, adult, senior, adult, adult, ad...         adult            adult                   True
# 2     002A  [adult, adult, adult, adult, adult, adult, sen...         adult            adult                   True
# 28    025A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 109   117A  [senior, senior, adult, senior, adult, senior,...        senior           senior                   True
# 36    029A  [senior, adult, adult, adult, senior, adult, a...         adult            adult                   True
# 34    027A  [adult, adult, senior, adult, adult, adult, ad...         adult            adult                   True
# 37    031A  [senior, adult, adult, adult, kitten, adult, s...         adult            adult                   True
# 31    026A                      [adult, senior, adult, adult]         adult            adult                   True
# 32    026B                                            [adult]         adult            adult                   True
# 42    036A  [senior, senior, adult, adult, adult, adult, a...         adult            adult                   True
# 30    025C         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 41    035A                     [adult, senior, senior, adult]         adult            adult                   True
# 40    034A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 33    026C                                            [adult]         adult            adult                   True
# 35    028A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 38    032A                                     [adult, adult]         adult            adult                   True
# 39    033A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 52    047A  [adult, adult, adult, kitten, adult, adult, ad...         adult           kitten                  False
# 6     005A  [senior, senior, adult, adult, senior, adult, ...        senior            adult                  False
# 69    063A  [kitten, adult, kitten, kitten, kitten, adult,...        kitten            adult                  False
# 99    104A                       [adult, adult, adult, adult]         adult           senior                  False
# 101   106A  [adult, adult, adult, adult, adult, adult, adu...         adult           senior                  False
# 103   109A         [adult, adult, adult, adult, adult, adult]         adult           kitten                  False
# 106   113A                             [adult, senior, adult]         adult           senior                  False
# 108   116A  [senior, senior, adult, adult, adult, adult, a...         adult           senior                  False
# 102   108A       [adult, adult, senior, senior, adult, adult]         adult           senior                  False
# 56    051A  [adult, adult, adult, adult, adult, adult, adu...         adult           senior                  False
# 92    097A  [adult, adult, senior, adult, adult, adult, ad...         adult           senior                  False
# 12    011A                              [adult, adult, adult]         adult           senior                  False
# 89    094A  [adult, senior, adult, senior, adult, adult, a...         adult           senior                  False
# 88    093A                                     [adult, adult]         adult           senior                  False
# 57    051B  [adult, adult, adult, senior, adult, senior, s...         adult           senior                  False
# 85    090A                                            [adult]         adult           senior                  False
# 16    014B  [senior, adult, senior, senior, adult, kitten,...         adult           kitten                  False
# 59    053A  [adult, senior, senior, adult, senior, adult, ...        senior            adult                  False
# 82    076A                                           [kitten]        kitten            adult                  False
# 18    016A  [adult, adult, adult, adult, adult, adult, adu...         adult           senior                  False
# 61    055A  [adult, adult, senior, senior, adult, senior, ...         adult           senior                  False
# 62    056A                              [adult, adult, adult]         adult           senior                  False
# 63    057A  [kitten, adult, senior, adult, adult, senior, ...         adult           senior                  False
# 64    058A                              [adult, adult, adult]         adult           senior                  False
# 67    061A                                     [adult, adult]         adult           senior                  False
# 44    038A                                   [kitten, kitten]        kitten            adult                  False

# %%
# Create df for majority votes
majority_df = majority_votes.reset_index()
majority_df.columns = ['cat_id', 'Majority_Vote']

# Get actual groups for each cat_id
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first().reset_index()

# Merge majority votes with actual groups
majority_with_actual = pd.merge(majority_df, actual_groups, on='cat_id')

# Add a column to check if the majority vote was correct
majority_with_actual['Majority_Correct'] = majority_with_actual['Majority_Vote'] == majority_with_actual['actual_age_group']

# Count correct majority votes per class
correct_majority_votes_per_class = majority_with_actual.groupby('actual_age_group')['Majority_Correct'].sum()

print("Correct Majority Votes per Class:")
print(correct_majority_votes_per_class)
# Out:
# Correct Majority Votes per Class:
# actual_age_group
# adult     68
# kitten    12
# senior     4
# Name: Majority_Correct, dtype: int64

# %%
# Calculate the total count and the number of correct predictions for each class
class_stats = majority_with_actual.groupby('actual_age_group').agg(
    total_count=('Majority_Correct', 'size'),  # Total number of cases per class
    correct_count=('Majority_Correct', 'sum')  # Sum of correct predictions per class
).reset_index()

# Calculate accuracy for each class
class_stats['accuracy'] = class_stats['correct_count'] / class_stats['total_count'] * 100

# store for final evaluation 
all_majority_vote_details.append(class_stats)

# Log detailed stats
print("Detailed Class Statistics for Majority Votes:")
print(class_stats)
# Out:
# Detailed Class Statistics for Majority Votes:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult           73             68  93.150685
# 1           kitten           15             12  80.000000
# 2           senior           22              4  18.181818

# %%
# Plot for Detailed Class Statistics for Majority Votes
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Accuracy of Majority Votes by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Detailed Class Statistics

# %%
# Calculate the total count and the number of correct predictions for each class
class_stats = full_results.groupby('actual_age_group').agg(
    total_count=('correct', 'size'),
    correct_count=('correct', 'sum')
).reset_index()

# Calculate accuracy for each class
class_stats['accuracy'] = class_stats['correct_count'] / class_stats['total_count'] * 100

# store for final evaluation 
all_class_stats.append(class_stats)

# Log the detailed stats
print("Detailed Class Statistics:")
print(class_stats)
# Out:
# Detailed Class Statistics:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult          569            448  78.734622
# 1           kitten          111             52  46.846847
# 2           senior          186             55  29.569892

# %%
# Plot for Detailed Class Statistics (Overall)
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Overall Accuracy by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Gender Exploration

# %%
# Group by gender and calculate the total count, correct predictions, and accuracy
gender_stats = full_results.groupby('all_gender').agg(
    count=('cat_id', 'size'),  # Total number of cases per gender
    correct=('correct', 'sum')  # Sum of correct predictions per gender
).reset_index()

# Calculate accuracy for each gender
gender_stats['accuracy'] = (gender_stats['correct'] / gender_stats['count'] * 100).round(2)

# Display the DataFrame
print("Accuracy by Gender:")
print(gender_stats)

# store for final evaluation 
all_gender_stats.append(gender_stats)
# Out:
# Accuracy by Gender:
#   all_gender  count  correct  accuracy
# 0          F    218      136     62.39
# 1          M    358      260     72.63
# 2          X    290      159     54.83

# %%
# Plot for Accuracy by Gender
styled_barplot(gender_stats, 'all_gender', 'accuracy', 
               'Accuracy by Gender', 
               'Gender', 'Accuracy (%)')

# %% [markdown]
# ### Log current total CV Stats

# %%
print("Total Majority Vote Accuracy so far:", all_majority_vote_accuracies)
print("Total Class Statistics so far:\n", all_class_stats) 
print("Total Majority Vote Statistics so far:\n", all_majority_vote_details) 
print("Total Gender Accuracy so far:\n", all_gender_stats)
# Out:
# Total Majority Vote Accuracy so far: [0.7727272727272727, 0.7545454545454545, 0.7727272727272727, 0.7636363636363637, 0.7636363636363637]
# Total Class Statistics so far:
#  [  actual_age_group  total_count  correct_count   accuracy
# 0            adult          573            489  85.340314
# 1           kitten          111             57  51.351351
# 2           senior          186             61  32.795699,   actual_age_group  total_count  correct_count   accuracy
# 0            adult          569            446  78.383128
# 1           kitten          120             45  37.500000
# 2           senior          186             44  23.655914,   actual_age_group  total_count  correct_count   accuracy
# 0            adult          578            474  82.006920
# 1           kitten          111             62  55.855856
# 2           senior          186             60  32.258065,   actual_age_group  total_count  correct_count   accuracy
# 0            adult          568            477  83.978873
# 1           kitten          116             53  45.689655
# 2           senior          186             59  31.720430,   actual_age_group  total_count  correct_count   accuracy
# 0            adult          569            448  78.734622
# 1           kitten          111             52  46.846847
# 2           senior          186             55  29.569892]
# Total Majority Vote Statistics so far:
#  [  actual_age_group  total_count  correct_count   accuracy
# 0            adult           73             70  95.890411
# 1           kitten           15             11  73.333333
# 2           senior           22              4  18.181818,   actual_age_group  total_count  correct_count   accuracy
# 0            adult           73             71  97.260274
# 1           kitten           15              9  60.000000
# 2           senior           22              3  13.636364,   actual_age_group  total_count  correct_count   accuracy
# 0            adult           73             68  93.150685
# 1           kitten           15             12  80.000000
# 2           senior           22              5  22.727273,   actual_age_group  total_count  correct_count   accuracy
# 0            adult           73             71  97.260274
# 1           kitten           15             10  66.666667
# 2           senior           22              3  13.636364,   actual_age_group  total_count  correct_count   accuracy
# 0            adult           73             68  93.150685
# 1           kitten           15             12  80.000000
# 2           senior           22              4  18.181818]
# Total Gender Accuracy so far:
#  [  all_gender  count  correct  accuracy
# 0          F    218      150     68.81
# 1          M    362      279     77.07
# 2          X    290      178     61.38,   all_gender  count  correct  accuracy
# 0          F    220      133     60.45
# 1          M    356      253     71.07
# 2          X    299      149     49.83,   all_gender  count  correct  accuracy
# 0          F    218      142     65.14
# 1          M    356      271     76.12
# 2          X    301      183     60.80,   all_gender  count  correct  accuracy
# 0          F    218      145     66.51
# 1          M    357      286     80.11
# 2          X    295      158     53.56,   all_gender  count  correct  accuracy
# 0          F    218      136     62.39
# 1          M    358      260     72.63
# 2          X    290      159     54.83]

# %% [markdown]
# # --------------

# %% [markdown]
# # Total Final Results & Analysis

# %%
# Count unique cat_id per age group 
unique_cats_per_age_group = dataframe.groupby('age_group')['cat_id'].nunique()

# Display the counts
print("Unique cat_id counts in original dataframe:", unique_cats_per_age_group)
# Out:
# Unique cat_id counts in original dataframe: age_group
# adult     74
# kitten    16
# senior    22
# Name: cat_id, dtype: int64

# %% [markdown]
# ## Metrics

# %%
# Calculate overall metrics
overall_avg_loss = np.mean(all_losses)
overall_avg_acc = np.mean(all_accuracies)
overall_avg_precision = np.mean(all_precisions)
overall_avg_recall = np.mean(all_recalls)
overall_avg_f1 = np.mean(all_f1)

print("Overall Average Metrics:")
print("Loss:", overall_avg_loss)
print("Accuracy:", overall_avg_acc)
print("Precision:", overall_avg_precision)
print("Recall:", overall_avg_recall)
print("F1 Score:", overall_avg_f1)
# Out:
# Overall Average Metrics:
# Loss: 4.266414475440979
# Accuracy: 0.6616636961698532
# Precision: 0.5769172266478632
# Recall: 0.5557886834324979
# F1 Score: 0.539499981910148

# %% [markdown]
# ## Majority Votes

# %%
# Average of majority vote accuracies
average_majority_vote_accuracy = np.mean(all_majority_vote_accuracies)
print("Average Majority Vote Accuracy:", average_majority_vote_accuracy)
# Out:
# Average Majority Vote Accuracy: 0.7654545454545454

# %%
# Concatenate all class stats DataFrames and calculate the mean of accuracies
total_majority_vote_details = pd.concat(all_majority_vote_details)
average_majority_vote_details = total_majority_vote_details.groupby('actual_age_group').agg({
    'total_count': 'sum', 
    'correct_count': 'sum' 
}).reset_index()
average_majority_vote_details['accuracy'] = (average_majority_vote_details['correct_count'] / average_majority_vote_details['total_count']) * 100

print("Average Class Statistics:")
print(average_majority_vote_details)
# Out:
# Average Class Statistics:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult          365            348  95.342466
# 1           kitten           75             54  72.000000
# 2           senior          110             19  17.272727

# %%
# Plot for Detailed Class Statistics for Majority Votes
styled_barplot(average_majority_vote_details, 'actual_age_group', 'accuracy', 
               'Accuracy of Majority Votes by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Detailed Class Statistics

# %%
# Concatenate all class stats DataFrames and calculate the mean of accuracies
total_class_stats = pd.concat(all_class_stats)
average_class_stats = total_class_stats.groupby('actual_age_group').agg({
    'total_count': 'sum',  
    'correct_count': 'sum' 
}).reset_index()
average_class_stats['accuracy'] = (average_class_stats['correct_count'] / average_class_stats['total_count']) * 100

print("Average Class Statistics:")
print(average_class_stats)
# Out:
# Average Class Statistics:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult         2857           2334  81.694085
# 1           kitten          569            269  47.275923
# 2           senior          930            279  30.000000

# %%
# Plot for Detailed Class Statistics (Overall)
styled_barplot(average_class_stats, 'actual_age_group', 'accuracy', 
               'Overall Accuracy by Age Group', 
               'Age Group', 'Accuracy (%)')

# %%
# Concatenate all gender stats DataFrames and calculate the mean of accuracies
total_gender_stats = pd.concat(all_gender_stats)
average_gender_stats = total_gender_stats.groupby('all_gender').agg({
    'count': 'sum',  
    'correct': 'sum'  
}).reset_index()
average_gender_stats['accuracy'] = (average_gender_stats['correct'] / average_gender_stats['count']) * 100

print("Average Gender Accuracy:")
print(average_gender_stats)
# Out:
# Average Gender Accuracy:
#   all_gender  count  correct   accuracy
# 0          F   1092      706  64.652015
# 1          M   1789     1349  75.405254
# 2          X   1475      827  56.067797

# %%
# Plot for Accuracy by Gender
styled_barplot(total_gender_stats, 'all_gender', 'accuracy', 
               'Accuracy by Gender', 
               'Gender', 'Accuracy (%)')

# %% [markdown]
# # Visualisations

# %%
# Plotting all metrics
metrics_across_seeds = plot_all_metrics(all_losses, all_accuracies, all_precisions, all_recalls, all_f1, "Seeds", "Seed Number")

# %%
# Calculate the standard deviation for each metric
std_loss = np.std(all_losses)
std_accuracy = np.std(all_accuracies)
std_precision = np.std(all_precisions)
std_recall = np.std(all_recalls)
std_f1 = np.std(all_f1)

print("Standard Deviations:")
print(f"Loss: {std_loss}")
print(f"Accuracy: {std_accuracy}")
print(f"Precision: {std_precision}")
print(f"Recall: {std_recall}")
print(f"F1 Score: {std_f1}")
# Out:
# Standard Deviations:
# Loss: 0.9208070531913753
# Accuracy: 0.029858309196954355
# Precision: 0.0494001881919446
# Recall: 0.04381407319700784
# F1 Score: 0.04181684344486683

# %%
# Calculate the interquartile range for each metric
iqr_loss = np.percentile(all_losses, 75) - np.percentile(all_losses, 25)
iqr_accuracy = np.percentile(all_accuracies, 75) - np.percentile(all_accuracies, 25)
iqr_precision = np.percentile(all_precisions, 75) - np.percentile(all_precisions, 25)
iqr_recall = np.percentile(all_recalls, 75) - np.percentile(all_recalls, 25)
iqr_f1 = np.percentile(all_f1, 75) - np.percentile(all_f1, 25)

print("Interquartile Ranges:")
print(f"Loss: {iqr_loss}")
print(f"Accuracy: {iqr_accuracy}")
print(f"Precision: {iqr_precision}")
print(f"Recall: {iqr_recall}")
print(f"F1 Score: {iqr_f1}")
# Out:
# Interquartile Ranges:
# Loss: 1.10372793674469
# Accuracy: 0.04482504725456238
# Precision: 0.07121319950574279
# Recall: 0.03931882459433056
# F1 Score: 0.055474883150918974

# %% [markdown]
# ## Display the seed folds results together

# %%
# Create a figure with subplots
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(18, 12))  

# Flatten the axes array for easier indexing
axes = axes.flatten()

def plot_metrics_on_axes(ax, losses, accuracies, precisions, recalls, f1, title):
    ax.plot(range(1, len(losses)+1), losses, marker='o', color='blue', label='Loss')
    ax.plot(range(1, len(accuracies)+1), accuracies, marker='o', color='green', label='Accuracy')
    ax.plot(range(1, len(precisions)+1), precisions, marker='o', color='red', label='Precision')
    ax.plot(range(1, len(recalls)+1), recalls, marker='o', color='purple', label='Recall')
    ax.plot(range(1, len(f1)+1), f1, marker='o', color='orange', label='F1 Score')
    ax.set_xticks([1, 2, 3, 4])  # Set x-axis ticks to full integers
    ax.set_title(title)
    ax.set_xlabel('Fold Number')
    ax.set_ylabel('Metric Value')
    ax.legend()
    ax.grid(True)

# Plot onto each axes object
plot_metrics_on_axes(axes[0], *seed_1_folds_values, "Seed 1 Metrics")
plot_metrics_on_axes(axes[1], *seed_2_folds_values, "Seed 2 Metrics")
plot_metrics_on_axes(axes[2], *seed_3_folds_values, "Seed 3 Metrics")
plot_metrics_on_axes(axes[3], *seed_4_folds_values, "Seed 4 Metrics")
plot_metrics_on_axes(axes[4], *seed_5_folds_values, "Seed 5 Metrics")

# Hide the unused subplot 
for ax in axes[5:]:
    ax.set_visible(False)

# Adjust layout
plt.tight_layout()
plt.show()
