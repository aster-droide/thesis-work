# %% [markdown]
# # YAMNet Multi Seed Validation
# #### 5 Random (but reproducible) seeds are selected for 5 different runs of train/test
# #### Models have been optimised and verified on validation sets thoroughly, running a final train/test evaluation here
# #### The setup:
#
# - 4 fold StratifiedGroupKFold for stratification and ensuring each cat_id group only appears in one set at a time
# - Final scores averaged over the 4 folds
# - For each seed run we will explore the cat_id predictions through majority voting
# - For each run we will explore the potential impact of gender
# - Includes visualisations & analysis
#
# The dataset is highly unbalanced.

# %%
# Standard imports
import numpy as np
import pandas as pd
import random
from datetime import datetime
from collections import Counter

# Sklearn imports
from sklearn.model_selection import train_test_split, GroupShuffleSplit, GroupKFold, StratifiedGroupKFold
from sklearn.preprocessing import LabelEncoder, MinMaxScaler, RobustScaler, StandardScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report
from sklearn.utils.class_weight import compute_class_weight
from sklearn.inspection import permutation_importance

# Imbalanced-learn import
from imblearn.over_sampling import SMOTE

# TensorFlow and Keras imports
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Dropout, Input, BatchNormalization, concatenate
from tensorflow.keras.optimizers import Adam, RMSprop, SGD, Adamax, AdamW
from tensorflow.keras.callbacks import EarlyStopping, Callback
from tensorflow.keras.utils import to_categorical
from keras.regularizers import l1, l2, L1L2

# Optuna import
import optuna

# Visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns

# Import statistical tests
from scipy.stats import levene

from IPython.display import display
import time

# %%
# Track running time (including analysis)
start_time = time.time()

# %%
# Set an initial seed for reproducibility
np.random.seed(42)  

# Generate a list of 5 random seeds
random_seeds = np.random.randint(0, 10000, size=5)
print("Random Seeds:", random_seeds)
# Out:
# Random Seeds: [7270  860 5390 5191 5734]

# %% [markdown]
# #### TOTAL RESULTS ACROSS SEED INITIATION

# %%
# Lists to collect statistics across all CVs
all_losses, all_accuracies, all_precisions, all_recalls, all_f1 = [], [], [], [], []
average_fold_losses, average_fold_accuracies, average_fold_precisions, average_fold_recalls, average_fold_f1 = [], [], [], [], []
all_majority_vote_accuracies, all_majority_vote_details, all_class_stats, all_gender_stats  = [], [], [], []

# training accuracies
all_best_training_acc = []
total_training_acc = []

# %% [markdown]
# ## Define Functions

# %%
def check_initial_group_split(groups_train, groups_test):
    """
    Check if any group is present in both the train and test sets.

    Parameters:
    - groups_train: Array of group identifiers for the train set
    - groups_test: Array of group identifiers for the test set

    Returns:
    - Prints out any groups found in both sets and the count of such groups
    """
    train_groups = set(groups_train)
    test_groups = set(groups_test)
    common_groups = train_groups.intersection(test_groups)

    if common_groups:
        print(f"Warning: Found {len(common_groups)} common groups in both train/validation and test sets: {common_groups}")
    else:
        print("No common groups found between train and test sets.")

# %%
# Function to perform the swaps based on cat_id, ensuring swaps within the same age_group
def swap_cat_id_instances(dataframe, train_val_idx, test_idx, specific_cat_ids):
    for cat_id in specific_cat_ids:
        # Check if the specific cat_id is not in the training set
        if cat_id not in dataframe.iloc[train_val_idx]['cat_id'].values:
            # Get the age_group of this cat_id
            age_group = dataframe[dataframe['cat_id'] == cat_id]['age_group'].iloc[0]
                
            # Find a different cat_id within the same age_group in the train set that is not in the test set
            other_cat_ids_in_age_group = dataframe[(dataframe['age_group'] == age_group) & 
                                                   (dataframe['cat_id'] != cat_id) &
                                                   (~dataframe['cat_id'].isin(dataframe.iloc[test_idx]['cat_id']))]['cat_id'].unique()
            
            # Choose one other cat_id for swapping
            if len(other_cat_ids_in_age_group) > 0:
                other_cat_id = np.random.choice(other_cat_ids_in_age_group)

                # Find all instances of the other_cat_id in the train set
                other_cat_id_train_val_indices = train_val_idx[dataframe.iloc[train_val_idx]['cat_id'] == other_cat_id]
                
                # Find all instances of the specific cat_id in the test set
                cat_id_test_indices = test_idx[dataframe.iloc[test_idx]['cat_id'] == cat_id]
                
                # Swap the indices
                train_val_idx = np.setdiff1d(train_val_idx, other_cat_id_train_val_indices, assume_unique=True)
                test_idx = np.setdiff1d(test_idx, cat_id_test_indices, assume_unique=True)

                train_val_idx = np.concatenate((train_val_idx, cat_id_test_indices))
                test_idx = np.concatenate((test_idx, other_cat_id_train_val_indices))
            else:
                print(f"No alternative cat_id found in the same age_group as {cat_id} for swapping.")
                
    return train_val_idx, test_idx

# %%
# Function to identify differences in groups
def find_group_differences(original, new):
    # Convert numpy arrays to sets for easy difference computation
    original_set = set(original)
    new_set = set(new)
    # Find differences
    moved_to_new = new_set - original_set
    moved_to_original = original_set - new_set
    return moved_to_new, moved_to_original

# %%
# create custom logger function for local logs & stored in a .txt
def logger(message, file=None):
    print(message)
    if file is not None:
        with open(file, "a") as log_file:
            log_file.write(message + "\n")

log_file_path = "multi-seed-val-D13.txt"

# %%
# Set the aesthetic style of the plots
sns.set(style="whitegrid", palette="deep")

# Define a custom color palette
colors = ["#6aabd1", "#b6e2d3", "#dac292"] 
sns.set_palette(sns.color_palette(colors))

# Function to create bar plots with enhanced style
def styled_barplot(data, x, y, title, xlabel, ylabel):
    plt.figure(figsize=(8, 4))
    bar_plot = sns.barplot(x=x, y=y, data=data, errorbar=None, width=0.5)  
    plt.title(title, fontsize=16, fontweight='bold', color="#333333")
    plt.xlabel(xlabel, fontsize=14, fontweight='bold', color="#333333")
    plt.ylabel(ylabel, fontsize=14, fontweight='bold', color="#333333")
    plt.xticks(fontsize=12, color="#333333")
    plt.yticks(fontsize=12, color="#333333")
    plt.ylim(0, 100) 

    # Adding value labels on top of each bar
    for p in bar_plot.patches:
        height = p.get_height()
        # Annotate the height value on the bar
        bar_plot.annotate(f'{height:.1f}', 
                          (p.get_x() + p.get_width() / 2., height), 
                          ha='center', va='center', 
                          xytext=(0, 9), 
                          textcoords='offset points', fontsize=12, color="#333333")

    plt.show()

# %%
def plot_all_metrics(losses, accuracies, precisions, recalls, f1, metrics_across, x_axis_label):
    fig, ax = plt.subplots(figsize=(12, 8))
    seeds = range(1, len(losses) + 1)

    ax.plot(seeds, losses, marker='o', color='blue', label='Loss')
    ax.plot(seeds, accuracies, marker='o', color='green', label='Accuracy')
    ax.plot(seeds, precisions, marker='o', color='red', label='Precision')
    ax.plot(seeds, recalls, marker='o', color='purple', label='Recall')
    ax.plot(seeds, f1, marker='o', color='orange', label='F1 Score')

    ax.set_title(f'Metrics Across {metrics_across}')
    ax.set_xlabel(x_axis_label)
    ax.set_ylabel('Metric Value')
    ax.set_xticks(seeds)
    ax.legend()
    ax.grid(True)

    return fig

# %%
# store epoch accs
class AccuracyHistory(Callback):
    def on_train_begin(self, logs={}):
        self.acc = []

    def on_epoch_end(self, batch, logs={}):
        self.acc.append(logs.get('accuracy'))

# %% [markdown]
# # RANDOM SEED 1

# %% [markdown]
# ## Prepare Data

# %%
# Set a fixed random seed for reproducibility
random.seed(int(random_seeds[0])) 
np.random.seed(int(random_seeds[0]))
tf.random.set_seed(int(random_seeds[0]))

# Load datasets
dataframe = pd.read_csv('/Users/astrid/PycharmProjects/data-aug-and-more/yamnet-tfhub-extraction/yamnet_embeddings_looped_april_23.csv')

def assign_age_group(age, age_groups):
    for group_name, age_range in age_groups.items():
        if age_range[0] <= age < age_range[1]:
            return group_name
    return 'Unknown'  # For any age that doesn't fit the defined groups

# Define age groups
age_groups = {
    'kitten': (0, 0.5),
    'adult': (0.5, 12),
    'senior': (12, 20)
}

# Create a new column for the age group
dataframe['age_group'] = dataframe['target'].apply(assign_age_group, age_groups=age_groups)

print(dataframe['age_group'].value_counts())
# Out:
# adult     606
# senior    186
# kitten    176
# Name: age_group, dtype: int64

# %%
# Separate features and labels
X = dataframe.iloc[:, :-4].values  # all columns except the last four

# Encode the 'age_group' column as integers using LabelEncoder
label_encoder = LabelEncoder()
encoded_y = label_encoder.fit_transform(dataframe['age_group'].values)

# Use the encoded labels for splitting and one-hot encoding
y = encoded_y  

# Convert 'cat_id' column to numpy array to be used as groups array for GroupKFold
groups = dataframe['cat_id'].values

# %%
tf.keras.backend.clear_session()

# %% [markdown]
# ## Run Setup

# %%
all_cat_ids = []
all_predicted_age_groups = []
all_actual_age_groups = []
all_gender = []

# Define the StratifiedGroupKFold splitter for 4 fold CV with random shuffling
outer_cv = StratifiedGroupKFold(n_splits=4, shuffle=True, random_state=int(random_seeds[0]))

# unseen test set metrics
unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1 = [], [], [], [], []

cv_training_acc_total = []
cv_training_acc_best = []

outer_fold = 0


# Use the splitter to generate indices for training and testing sets
# Note: GroupShuffleSplit.split returns indices, so we use it to index the arrays
for train_val_idx, test_idx in outer_cv.split(X, y, groups):
    outer_fold += 1
    logger(f"outer_fold {outer_fold}", file=log_file_path)

    # Convert indices back to DataFrame for easy manipulation
    df_train_val = dataframe.iloc[train_val_idx]
    df_test = dataframe.iloc[test_idx]

    ##############################
    # ASSESSING SPLITS BY CAT_ID #
    ##############################
    
    # Get the distribution of groups
    training_validation_group_distribution = df_train_val['cat_id'].value_counts()  
    testing_group_distribution = df_test['cat_id'].value_counts()  
    
    # Log or print the distribution
    logger(f"Train Set Group Distribution:\n{training_validation_group_distribution}", file=log_file_path)
    logger(f"Testing Set Group Distribution:\n{testing_group_distribution}", file=log_file_path)

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val['gender'].value_counts()
    testing_gender_distribution = df_test['gender'].value_counts()
    
    # Log the distribution
    logger(f"Training Set Gender Distribution BEFORE SWAP:\n{training_gender_distribution}", file=log_file_path)
    logger(f"Testing Set Gender Distribution BEFORE SWAP:\n{testing_gender_distribution}", file=log_file_path)

    # Group by 'age_group' and then list unique 'cat_id' within each age group
    unique_cat_ids_per_age_group_train_val = df_train_val.groupby('age_group')['cat_id'].unique()
    unique_cat_ids_per_age_group_test = df_test.groupby('age_group')['cat_id'].unique()
    
    # Log results
    logger(f"Unique Cat IDs per Age Group in Training/Validation Set:\n{unique_cat_ids_per_age_group_train_val}", file=log_file_path)
    logger(f"Unique Cat IDs per Age Group in Testing Set:\n{unique_cat_ids_per_age_group_test}", file=log_file_path)

    # Calculate the count of unique identifiers per age group for training and testing set
    counts_train_val = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_train_val.items()}
    counts_test = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_test.items()}

    # Log the counts of unique identifiers per age group
    logger(f"Count of Unique Cat IDs per Age Group in Training/Validation Set:\n{counts_train_val}", file=log_file_path)
    logger(f"Count of Unique Cat IDs per Age Group in Testing Set:\n{counts_test}", file=log_file_path)

    #######################################################
    # CONTINUE WITH ENSURING VALID AND APPROPRIATE SPLITS #
    #######################################################
    
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    groups_train_val, groups_test = groups[train_val_idx], groups[test_idx]

    # logging identifier splits 
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)

    # check group splits
    check_initial_group_split(groups_train_val, groups_test)

    # Specify the cat_ids that must be in the training/validation set
    specific_cat_ids = ['000A', '046A']
    
    # Perform the swapping operation
    train_val_idx, test_idx = swap_cat_id_instances(dataframe, train_val_idx, test_idx, specific_cat_ids)
    
    # Re-assign the sets based on the updated indices
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    new_groups_train_val, new_groups_test = groups[train_val_idx], groups[test_idx]

    # Find differences for training and test sets
    moved_to_train_val, removed_from_train_val = find_group_differences(groups_train_val, new_groups_train_val)
    moved_to_test, removed_from_test = find_group_differences(groups_test, new_groups_test)
    
    # Display the results
    logger(f"Moved to Training/Validation Set:\n{moved_to_train_val}", file=log_file_path)
    logger(f"Removed from Training/Validation Set:\n{removed_from_train_val}", file=log_file_path)
    logger(f"Moved to Test Set:\n{moved_to_test}", file=log_file_path)
    logger(f"Removed from Test Set\n{removed_from_test}", file=log_file_path)

    # Update X_train_val, X_test, y_train_val, y_test, groups_train_val, groups_test based on updated indices
    X_train_val = X[train_val_idx]
    y_train_val = y[train_val_idx]
    groups_train_val = groups[train_val_idx]
    
    X_test = X[test_idx]
    y_test = y[test_idx]
    groups_test = groups[test_idx]

    # logging identifier splits again after potential swaps
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"AFTER SWAP - Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"AFTER SWAP - Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)
    
    # Verify the lengths are consistent
    logger(f"Length of X_train_val:\n{len(X_train_val)}", file=log_file_path)
    logger(f"Length of y_train_val:\n{len(y_train_val)}", file=log_file_path)
    logger(f"Length of groups_train_val:\n{len(groups_train_val)}", file=log_file_path)

    # Check group splits once more
    check_initial_group_split(groups_train_val, groups_test)

    # Convert the modified indices back to a DataFrame representing the updated df_train_val
    df_train_val_updated = dataframe.iloc[train_val_idx].copy()
    df_test_updated = dataframe.iloc[test_idx].copy()

    ############################
    # LOGGING AGE GROUP SPLITS #
    ############################

    # Get the distribution of age groups of age groups before the update
    training_validation_age_group_distribution = df_train_val['age_group'].value_counts()
    testing_age_group_distribution = df_test['age_group'].value_counts()
    
    # Logthe distribution
    logger(f"Train Age Group Distribution BEFORE SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution BEFORE SWAP:\n{testing_age_group_distribution}", file=log_file_path)

    # Get the distribution of age groups after the update
    training_validation_age_group_distribution = df_train_val_updated['age_group'].value_counts()
    testing_age_group_distribution = df_test_updated['age_group'].value_counts()
    
    # Log the distribution
    logger(f"Train Age Group Distribution AFTER SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution AFTER SWAP:\n{testing_age_group_distribution}", file=log_file_path)
    
    ########################################################
    # TRACKING FINAL CAT_IDs & GENDER AFTER REDISTRIBUTION #
    ########################################################

    # Get the distribution of groups
    training_validation_group_distribution = df_train_val_updated['cat_id'].value_counts()  
    testing_group_distribution = df_test_updated['cat_id'].value_counts()  

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val_updated['gender'].value_counts()
    testing_gender_distribution = df_test_updated['gender'].value_counts()
    
    logger(f"\n Starting training on unseen test set\n", file=log_file_path)

    ###################
    # PREPARING MODEL #
    ###################

    # Calculate the distribution of age groups in y_train_val
    age_group_distribution = Counter(y_train_val)
    print("Age group distribution:", age_group_distribution)

    # EarlyStopping callback: monitor 'loss' instead of 'val_loss' for the test set
    early_stopping = EarlyStopping(
        monitor='loss',  
        min_delta=0.001, 
        patience=30,  
        verbose=1,  
        restore_best_weights=True  
    )

    accuracy_history = AccuracyHistory()

    # One final shuffle to ensure randomness
    outer_shuffle_idx = np.random.permutation(len(X_train_val))
    X_train_val = X_train_val[outer_shuffle_idx]
    y_train_val = y_train_val[outer_shuffle_idx]

    class_weights = compute_class_weight(
        class_weight='balanced',
        classes=np.unique(y_train_val),
        y=y_train_val
    )
    weight_dict = {i: class_weights[i] for i in range(len(class_weights))}
    
    # Scale the features
    scaler_full = StandardScaler().fit(X_train_val)
    X_train_full_scaled = scaler_full.transform(X_train_val)
    X_test_scaled = scaler_full.transform(X_test)
    
    # Encode the labels
    y_train_full_encoded = to_categorical(y_train_val)
    y_test_encoded = to_categorical(y_test)

    #######################
    # BUILD & TRAIN MODEL #
    #######################

    optimizers = {
        'Adamax': Adamax(learning_rate=0.00510251984616472)
    }
    
    # Model definition with dynamic number of layers
    model_full = Sequential()
    model_full.add(Dense(480, activation='relu', input_shape=(X_train_full_scaled.shape[1],)))
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.2011047009431978))  
    model_full.add(Dense(256, activation='relu',)) 
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.14956886311951184))  
    model_full.add(Dense(256, activation='relu'))  
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.42291461228250665))  
    model_full.add(Dense(3, activation='softmax'))  
    
    # Use the optimizer from the parameters
    optimizer = optimizers['Adamax']  # optimizer_key from parameters
    
    # Compile the model
    model_full.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    
    # Train the model on the full training set
    history_full = model_full.fit(X_train_full_scaled, y_train_full_encoded, epochs=1500, batch_size=64,
                                  verbose=1, callbacks=[early_stopping, accuracy_history], class_weight=weight_dict)
    
    # log epochs
    best_epoch_index = np.argmin(history_full.history['loss'])  
    best_training_accuracy = accuracy_history.acc[best_epoch_index]
    # Append training acc to total  
    all_best_training_acc.append(best_training_accuracy)
    total_training_acc.append(accuracy_history.acc)
    # Append training acc just for this CV
    cv_training_acc_total.append(accuracy_history.acc)
    cv_training_acc_best.append(best_training_accuracy)
    
    # Evaluate the model on the held-out test set
    test_loss, test_accuracy = model_full.evaluate(X_test_scaled, y_test_encoded)

    y_test_pred_prob = model_full.predict(X_test_scaled)
    y_test_pred = np.argmax(y_test_pred_prob, axis=1)  
    y_test_true = np.argmax(y_test_encoded, axis=1)    

    ################################
    # LOG MAJORITY VOTE PER CAT_ID #
    ################################

    # Convert numeric predictions back to age group labels
    predicted_age_groups = label_encoder.inverse_transform(y_test_pred)
    actual_labels = label_encoder.inverse_transform(y_test_true)
    
    # Map predictions and actual labels back to cat_ids
    test_results = pd.DataFrame({
        'cat_id': df_test_updated['cat_id'],
        'predicted_age_group': predicted_age_groups,
        'actual_age_group': actual_labels
    })
    
    # Group by cat_id and aggregate predicted age groups
    majority_votes = test_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
    actual_groups = test_results.groupby('cat_id')['actual_age_group'].first()
    
    # Calculate the accuracy of majority voting
    correct_predictions = (majority_votes == actual_groups).sum()
    total_cats = len(actual_groups)
    majority_vote_accuracy = correct_predictions / total_cats
    
    # Log the accuracy of the majority voting
    logger(f"Majority Vote Accuracy for cat_id for this fold: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

    ####################################################
    # COLLECT PREDICTIONS FOR GENDER & CAT_ID ANALYSIS #
    ####################################################

    # Debugging print statements
    print(f'Before appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Extend lists with current fold results
    all_cat_ids.extend(df_test_updated['cat_id'].tolist())
    all_predicted_age_groups.extend(predicted_age_groups)
    all_actual_age_groups.extend(actual_labels)
    all_gender.extend(df_test_updated['gender'].tolist())

    # Debugging print statements
    print(f'After appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Calculate additional metrics
    test_precision = precision_score(y_test_true, y_test_pred, average='macro')  # Use 'macro' for imbalanced datasets
    test_recall = recall_score(y_test_true, y_test_pred, average='macro')
    test_f1 = f1_score(y_test_true, y_test_pred, average='macro')

    # prepare averages of outer metrics
    unseen_f1.append(test_f1)
    unseen_losses.append(test_loss)
    unseen_accuracies.append(test_accuracy)
    unseen_precisions.append(test_precision)
    unseen_recalls.append(test_recall)

    # Print final test results
    logger(f"Final Test Results - Loss: {test_loss}, Accuracy: {test_accuracy}, Precision: {test_precision}, Recall: {test_recall}, F1 Score: {test_f1}", file=log_file_path)

    # Generate the confusion matrix
    cm = confusion_matrix(y_test, y_test_pred)
    logger(f"Confusion Matrix:\n {cm}", file=log_file_path)

# Calculate the overall average metrics
unseen_set_avg_f1 = np.mean(unseen_f1)
unseen_set_avg_loss = np.mean(unseen_losses)
unseen_set_avg_acc = np.mean(unseen_accuracies)
unseen_set_avg_precision = np.mean(unseen_precisions)
unseen_set_avg_recall = np.mean(unseen_recalls)

logger(f"\nFinal Average F1-Score across all UNSEEN TEST sets: {unseen_set_avg_f1}", file=log_file_path)
logger(f"\nFinal Average Loss across all UNSEEN TEST sets: {unseen_set_avg_loss}", file=log_file_path)
logger(f"\nFinal Average Accuracy across all UNSEEN TEST sets: {unseen_set_avg_acc}", file=log_file_path)
logger(f"\nFinal Average Precision across all UNSEEN TEST sets: {unseen_set_avg_precision}", file=log_file_path)
logger(f"\nFinal Average Recall across all UNSEEN TEST sets: {unseen_set_avg_recall}\n", file=log_file_path)

# Append averages to total lists
average_fold_f1.append(unseen_set_avg_f1)
average_fold_losses.append(unseen_set_avg_loss)
average_fold_accuracies.append(unseen_set_avg_acc)
average_fold_precisions.append(unseen_set_avg_precision)
average_fold_recalls.append(unseen_set_avg_recall)

# Append all to total lists
all_f1.append(unseen_f1)
all_losses.append(unseen_losses)
all_accuracies.append(unseen_accuracies)
all_precisions.append(unseen_precisions)
all_recalls.append(unseen_recalls)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# outer_fold 1
# Train Set Group Distribution:
# 000A    39
# 002B    36
# 103A    33
# 047A    30
# 057A    28
#         ..
# 049A     1
# 026C     1
# 073A     1
# 091A     1
# 100A     1
# Name: cat_id, Length: 87, dtype: int64
# Testing Set Group Distribution:
# 046A    66
# 055A    20
# 059A    18
# 116A    12
# 063A    11
# 072A     9
# 051B     9
# 045A     9
# 013B     8
# 053A     7
# 050A     7
# 117A     7
# 108A     6
# 008A     6
# 025C     6
# 070A     5
# 060A     3
# 058A     3
# 011A     3
# 025B     2
# 069A     2
# 093A     2
# 088A     1
# 024A     1
# 041A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    315
# X    245
# F    184
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    110
# F     73
# M     41
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [002A, 028A, 033A, 000B, 071A, 020A, 000A, 015...
# kitten    [042A, 014B, 110A, 109A, 040A, 047A, 049A, 048...
# senior    [106A, 057A, 090A, 113A, 051A, 097A, 094A, 016...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [070A, 053A, 072A, 013B, 063A, 069A, 060A, 088...
# kitten                             [046A, 045A, 050A, 041A]
# senior    [117A, 051B, 116A, 024A, 059A, 055A, 058A, 108...
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 63, 'kitten': 12, 'senior': 12}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 11, 'kitten': 4, 'senior': 10}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '004A' '005A' '006A' '007A'
#  '009A' '010A' '012A' '014A' '014B' '015A' '016A' '018A' '019A' '019B'
#  '020A' '021A' '022A' '023A' '023B' '025A' '026A' '026B' '026C' '027A'
#  '028A' '029A' '031A' '032A' '033A' '034A' '035A' '036A' '037A' '038A'
#  '039A' '040A' '042A' '043A' '044A' '047A' '048A' '049A' '051A' '052A'
#  '054A' '056A' '057A' '061A' '062A' '064A' '065A' '066A' '067A' '068A'
#  '071A' '073A' '074A' '075A' '076A' '087A' '090A' '091A' '092A' '094A'
#  '095A' '096A' '097A' '097B' '099A' '100A' '101A' '102A' '103A' '104A'
#  '105A' '106A' '109A' '110A' '111A' '113A' '115A']
# Unique Test Group IDs:
# ['008A' '011A' '013B' '024A' '025B' '025C' '041A' '045A' '046A' '050A'
#  '051B' '053A' '055A' '058A' '059A' '060A' '063A' '069A' '070A' '072A'
#  '088A' '093A' '108A' '116A' '117A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'046A'}
# Removed from Training/Validation Set:
# {'110A'}
# Moved to Test Set:
# {'110A'}
# Removed from Test Set
# {'046A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '004A' '005A' '006A' '007A'
#  '009A' '010A' '012A' '014A' '014B' '015A' '016A' '018A' '019A' '019B'
#  '020A' '021A' '022A' '023A' '023B' '025A' '026A' '026B' '026C' '027A'
#  '028A' '029A' '031A' '032A' '033A' '034A' '035A' '036A' '037A' '038A'
#  '039A' '040A' '042A' '043A' '044A' '046A' '047A' '048A' '049A' '051A'
#  '052A' '054A' '056A' '057A' '061A' '062A' '064A' '065A' '066A' '067A'
#  '068A' '071A' '073A' '074A' '075A' '076A' '087A' '090A' '091A' '092A'
#  '094A' '095A' '096A' '097A' '097B' '099A' '100A' '101A' '102A' '103A'
#  '104A' '105A' '106A' '109A' '111A' '113A' '115A']
# AFTER SWAP - Unique Test Group IDs:
# ['008A' '011A' '013B' '024A' '025B' '025C' '041A' '045A' '050A' '051B'
#  '053A' '055A' '058A' '059A' '060A' '063A' '069A' '070A' '072A' '088A'
#  '093A' '108A' '110A' '116A' '117A']
# Length of X_train_val:
# 809
# Length of y_train_val:
# 809
# Length of groups_train_val:
# 809
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     546
# senior    105
# kitten     93
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# kitten    83
# senior    81
# adult     60
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     546
# kitten    158
# senior    105
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# senior    81
# adult     60
# kitten    18
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 546, 1: 158, 2: 105})
# Epoch 1/1500
# 13/13 [==============================] - 1s 5ms/step - loss: 1.3208 - accuracy: 0.4944
# Epoch 2/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.6514 - accuracy: 0.6230
# Epoch 3/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4846 - accuracy: 0.7478
# Epoch 4/1500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.2889 - accuracy: 0.8195
# Epoch 5/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2725 - accuracy: 0.8665
# Epoch 6/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2169 - accuracy: 0.8999
# Epoch 7/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1568 - accuracy: 0.9147
# Epoch 8/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1553 - accuracy: 0.9258
# Epoch 9/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1435 - accuracy: 0.9234
# Epoch 10/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1221 - accuracy: 0.9407
# Epoch 11/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0948 - accuracy: 0.9481
# Epoch 12/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0757 - accuracy: 0.9703
# Epoch 13/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0786 - accuracy: 0.9629
# Epoch 14/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0582 - accuracy: 0.9790
# Epoch 15/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0950 - accuracy: 0.9592
# Epoch 16/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0596 - accuracy: 0.9728
# Epoch 17/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0473 - accuracy: 0.9753
# Epoch 18/1500
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0483 - accuracy: 0.9728
# Epoch 19/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0368 - accuracy: 0.9802
# Epoch 20/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0434 - accuracy: 0.9913
# Epoch 21/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0416 - accuracy: 0.9802
# Epoch 22/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0460 - accuracy: 0.9815
# Epoch 23/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.
1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0029 - accuracy: 0.9988
# Epoch 93/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 94/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0078 - accuracy: 0.9975
# Epoch 95/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0031 - accuracy: 0.9988
# Epoch 96/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0064 - accuracy: 0.9963
# Epoch 97/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0254 - accuracy: 0.9951
# Epoch 98/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0052 - accuracy: 0.9938
# Epoch 99/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 100/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0038 - accuracy: 0.9988
# Epoch 101/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0085 - accuracy: 0.9975
# Epoch 102/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0042 - accuracy: 0.9963
# Epoch 103/1500
# 11/13 [========================>.....] - ETA: 0s - loss: 0.0075 - accuracy: 0.9986Restoring model weights from the end of the best epoch: 73.
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0068 - accuracy: 0.9988
# Epoch 103: early stopping
# 5/5 [==============================] - 0s 2ms/step - loss: 3.1183 - accuracy: 0.5535
# 5/5 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.60 (15/25)
# Before appending - Cat IDs: 0, Predictions: 0, Actuals: 0, Gender: 0
# After appending - Cat IDs: 159, Predictions: 159, Actuals: 159, Gender: 159
# Final Test Results - Loss: 3.1182992458343506, Accuracy: 0.553459107875824, Precision: 0.6245424542454246, Recall: 0.6444444444444445, F1 Score: 0.5809290668531795
# Confusion Matrix:
#  [[46  9  5]
#  [ 2 15  1]
#  [53  1 27]]
# outer_fold 2
# Train Set Group Distribution:
# 046A    66
# 000A    39
# 047A    30
# 020A    23
# 000B    20
#         ..
# 115A     1
# 090A     1
# 004A     1
# 026B     1
# 100A     1
# Name: cat_id, Length: 80, dtype: int64
# Testing Set Group Distribution:
# 002B    36
# 103A    33
# 057A    28
# 074A    25
# 019A    17
# 101A    16
# 028A    14
# 051A    12
# 036A    11
# 068A    11
# 016A    11
# 005A    11
# 015A    10
# 010A     8
# 027A     7
# 031A     7
# 044A     5
# 012A     5
# 035A     4
# 052A     4
# 014A     3
# 018A     2
# 054A     2
# 038A     2
# 087A     2
# 066A     2
# 091A     1
# 049A     1
# 048A     1
# 110A     1
# 073A     1
# 076A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    273
# M    202
# F    199
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# M    154
# X     82
# F     58
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [002A, 070A, 033A, 000B, 071A, 020A, 000A, 026...
# kitten    [046A, 042A, 014B, 109A, 040A, 047A, 045A, 111...
# senior    [117A, 106A, 090A, 113A, 051B, 116A, 024A, 097...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [028A, 015A, 038A, 068A, 018A, 002B, 005A, 091...
# kitten                             [110A, 049A, 048A, 044A]
# senior                             [057A, 051A, 016A, 054A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 50, 'kitten': 12, 'senior': 18}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 24, 'kitten': 4, 'senior': 4}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '003A' '004A' '006A' '007A' '008A' '009A'
#  '011A' '013B' '014B' '019B' '020A' '021A' '022A' '023A' '023B' '024A'
#  '025A' '025B' '025C' '026A' '026B' '026C' '029A' '032A' '033A' '034A'
#  '037A' '039A' '040A' '041A' '042A' '043A' '045A' '046A' '047A' '050A'
#  '051B' '053A' '055A' '056A' '058A' '059A' '060A' '061A' '062A' '063A'
#  '064A' '065A' '067A' '069A' '070A' '071A' '072A' '075A' '088A' '090A'
#  '092A' '093A' '094A' '095A' '096A' '097A' '097B' '099A' '100A' '102A'
#  '104A' '105A' '106A' '108A' '109A' '111A' '113A' '115A' '116A' '117A']
# Unique Test Group IDs:
# ['002B' '005A' '010A' '012A' '014A' '015A' '016A' '018A' '019A' '027A'
#  '028A' '031A' '035A' '036A' '038A' '044A' '048A' '049A' '051A' '052A'
#  '054A' '057A' '066A' '068A' '073A' '074A' '076A' '087A' '091A' '101A'
#  '103A' '110A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '003A' '004A' '006A' '007A' '008A' '009A'
#  '011A' '013B' '014B' '019B' '020A' '021A' '022A' '023A' '023B' '024A'
#  '025A' '025B' '025C' '026A' '026B' '026C' '029A' '032A' '033A' '034A'
#  '037A' '039A' '040A' '041A' '042A' '043A' '045A' '046A' '047A' '050A'
#  '051B' '053A' '055A' '056A' '058A' '059A' '060A' '061A' '062A' '063A'
#  '064A' '065A' '067A' '069A' '070A' '071A' '072A' '075A' '088A' '090A'
#  '092A' '093A' '094A' '095A' '096A' '097A' '097B' '099A' '100A' '102A'
#  '104A' '105A' '106A' '108A' '109A' '111A' '113A' '115A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['002B' '005A' '010A' '012A' '014A' '015A' '016A' '018A' '019A' '027A'
#  '028A' '031A' '035A' '036A' '038A' '044A' '048A' '049A' '051A' '052A'
#  '054A' '057A' '066A' '068A' '073A' '074A' '076A' '087A' '091A' '101A'
#  '103A' '110A']
# Length of X_train_val:
# 674
# Length of y_train_val:
# 674
# Length of groups_train_val:
# 674
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     373
# kitten    168
# senior    133
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     233
# senior     53
# kitten      8
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     373
# kitten    168
# senior    133
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     233
# senior     53
# kitten      8
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 373, 1: 168, 2: 133})
# Epoch 1/1500
# 11/11 [==============================] - 1s 4ms/step - loss: 1.1575 - accuracy: 0.5326
# Epoch 2/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.5466 - accuracy: 0.7374
# Epoch 3/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.4066 - accuracy: 0.8353
# Epoch 4/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.2346 - accuracy: 0.9006
# Epoch 5/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.2136 - accuracy: 0.9050
# Epoch 6/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.1699 - accuracy: 0.9214
# Epoch 7/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.1434 - accuracy: 0.9466
# Epoch 8/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0967 - accuracy: 0.9570
# Epoch 9/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0890 - accuracy: 0.9570
# Epoch 10/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0740 - accuracy: 0.9777
# Epoch 11/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0905 - accuracy: 0.9585
# Epoch 12/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0581 - accuracy: 0.9748
# Epoch 13/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0611 - accuracy: 0.9777
# Epoch 14/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0560 - accuracy: 0.9688
# Epoch 15/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0524 - accuracy: 0.9777
# Epoch 16/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0260 - accuracy: 0.9911
# Epoch 17/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0378 - accuracy: 0.9881
# Epoch 18/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0351 - accuracy: 0.9866
# Epoch 19/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0334 - accuracy: 0.9896
# Epoch 20/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0300 - accuracy: 0.9866
# Epoch 21/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0291 - accuracy: 0.9926
# Epoch 22/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0351 - accuracy: 0.9852
# Epoch 23/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0205 - accuracy: 0.9911
# Epoch 24/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0236 - accuracy: 0.9881
# Epoch 25/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0184 - accuracy: 0.9926
# Epoch 26/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0192 - accuracy: 0.9911
# Epoch 27/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0195 - accuracy: 0.9926
# Epoch 28/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0179 - accuracy: 0.9941
# Epoch 29/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0168 - accuracy: 0.9896
# Epoch 30/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0152 - accuracy: 0.9970
# Epoch 31/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0203 - accuracy: 0.9911
# Epoch 32/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0156 - accuracy: 0.9955
# Epoch 33/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0053 - accuracy: 0.9985
# Epoch 34/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0167 - accuracy: 0.9955
# Epoch 35/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0117 - accuracy: 0.9941
# Epoch 36/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0096 - accuracy: 0.9955
# Epoch 37/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0095 - accuracy: 0.9955
# Epoch 38/1500
# 11/11 [==============================] - 0s 17ms/step - loss: 0.0054 - accuracy: 0.9970
# Epoch 39/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0038 - accuracy: 0.9985
# Epoch 40/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0083 - accuracy: 0.9985
# Epoch 41/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0153 - accuracy: 0.9926
# Epoch 42/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0163 - accuracy: 0.9896
# Epoch 43/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0155 - accuracy: 0.9955
# Epoch 44/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0070 - accuracy: 0.9970
# Epoch 45/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0131 - accuracy: 0.9985
# Epoch 46/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0074 - accuracy: 0.9970
# Epoch 47/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0081 - accuracy: 0.9970
# Epoch 48/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0073 - accuracy: 0.9955
# Epoch 49/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0080 - accuracy: 0.9985
# Epoch 50/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0042 - accuracy: 1.0000
# Epoch 51/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0191 - accuracy: 0.9955
# Epoch 52/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0127 - accuracy: 0.9970
# Epoch 53/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0058 - accuracy: 0.9985
# Epoch 54/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0068 - accuracy: 0.9985
# Epoch 55/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0104 - accuracy: 0.9970
# Epoch 56/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0071 - accuracy: 0.9985
# Epoch 57/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0060 - accuracy: 0.9985
# Epoch 58/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0147 - accuracy: 0.9941
# Epoch 59/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0074 - accuracy: 0.9955
# Epoch 60/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0179 - accuracy: 0.9911
# Epoch 61/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0134 - accuracy: 0.9970
# Epoch 62/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0084 - accuracy: 0.9941
# Epoch 63/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 64/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0127 - accuracy: 0.9985
# Epoch 65/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0161 - accuracy: 0.9955
# Epoch 66/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0066 - accuracy: 0.9970
# Epoch 67/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0105 - accuracy: 0.9955
# Epoch 68/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0060 - accuracy: 0.9985
# Epoch 69/1500
#  1/11 [=>............................] - ETA: 0s - loss: 0.0032 - accuracy: 1.0000Restoring model weights from the end of the best epoch: 39.
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0062 - accuracy: 0.9970
# Epoch 69: early stopping
# 10/10 [==============================] - 0s 1ms/step - loss: 1.9883 - accuracy: 0.6769
# 10/10 [==============================] - 0s 953us/step
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Majority Vote Accuracy for cat_id for this fold: 0.84 (27/32)
# Before appending - Cat IDs: 159, Predictions: 159, Actuals: 159, Gender: 159
# After appending - Cat IDs: 453, Predictions: 453, Actuals: 453, Gender: 453
# Final Test Results - Loss: 1.9882712364196777, Accuracy: 0.6768707633018494, Precision: 0.4793417366946779, Recall: 0.6829534105325666, F1 Score: 0.5089355089355089
# Confusion Matrix:
#  [[168  25  40]
#  [  1   7   0]
#  [ 27   2  24]]
# outer_fold 3
# Train Set Group Distribution:
# 046A    66
# 000A    39
# 002B    36
# 103A    33
# 047A    30
#         ..
# 049A     1
# 092A     1
# 048A     1
# 073A     1
# 100A     1
# Name: cat_id, Length: 84, dtype: int64
# Testing Set Group Distribution:
# 000B    20
# 106A    15
# 042A    14
# 097B    14
# 002A    13
# 111A    13
# 025A    11
# 071A    10
# 065A     9
# 033A     9
# 095A     8
# 094A     8
# 099A     7
# 037A     6
# 023A     6
# 075A     5
# 062A     5
# 023B     5
# 003A     4
# 105A     4
# 006A     3
# 056A     3
# 102A     2
# 061A     2
# 043A     1
# 090A     1
# 026C     1
# 019B     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    288
# M    285
# F    195
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# M    71
# X    67
# F    62
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [028A, 070A, 020A, 000A, 015A, 026A, 053A, 038...
# kitten    [046A, 014B, 110A, 109A, 040A, 047A, 049A, 045...
# senior    [117A, 057A, 113A, 051B, 116A, 051A, 024A, 097...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [002A, 033A, 000B, 071A, 065A, 023B, 026C, 105...
# kitten                                   [042A, 111A, 043A]
# senior                       [106A, 090A, 094A, 061A, 056A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 54, 'kitten': 13, 'senior': 17}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 20, 'kitten': 3, 'senior': 5}
# Unique Training/Validation Group IDs:
# ['000A' '001A' '002B' '004A' '005A' '007A' '008A' '009A' '010A' '011A'
#  '012A' '013B' '014A' '014B' '015A' '016A' '018A' '019A' '020A' '021A'
#  '022A' '024A' '025B' '025C' '026A' '026B' '027A' '028A' '029A' '031A'
#  '032A' '034A' '035A' '036A' '038A' '039A' '040A' '041A' '044A' '045A'
#  '046A' '047A' '048A' '049A' '050A' '051A' '051B' '052A' '053A' '054A'
#  '055A' '057A' '058A' '059A' '060A' '063A' '064A' '066A' '067A' '068A'
#  '069A' '070A' '072A' '073A' '074A' '076A' '087A' '088A' '091A' '092A'
#  '093A' '096A' '097A' '100A' '101A' '103A' '104A' '108A' '109A' '110A'
#  '113A' '115A' '116A' '117A']
# Unique Test Group IDs:
# ['000B' '002A' '003A' '006A' '019B' '023A' '023B' '025A' '026C' '033A'
#  '037A' '042A' '043A' '056A' '061A' '062A' '065A' '071A' '075A' '090A'
#  '094A' '095A' '097B' '099A' '102A' '105A' '106A' '111A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '001A' '002B' '004A' '005A' '007A' '008A' '009A' '010A' '011A'
#  '012A' '013B' '014A' '014B' '015A' '016A' '018A' '019A' '020A' '021A'
#  '022A' '024A' '025B' '025C' '026A' '026B' '027A' '028A' '029A' '031A'
#  '032A' '034A' '035A' '036A' '038A' '039A' '040A' '041A' '044A' '045A'
#  '046A' '047A' '048A' '049A' '050A' '051A' '051B' '052A' '053A' '054A'
#  '055A' '057A' '058A' '059A' '060A' '063A' '064A' '066A' '067A' '068A'
#  '069A' '070A' '072A' '073A' '074A' '076A' '087A' '088A' '091A' '092A'
#  '093A' '096A' '097A' '100A' '101A' '103A' '104A' '108A' '109A' '110A'
#  '113A' '115A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['000B' '002A' '003A' '006A' '019B' '023A' '023B' '025A' '026C' '033A'
#  '037A' '042A' '043A' '056A' '061A' '062A' '065A' '071A' '075A' '090A'
#  '094A' '095A' '097B' '099A' '102A' '105A' '106A' '111A']
# Length of X_train_val:
# 768
# Length of y_train_val:
# 768
# Length of groups_train_val:
# 768
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     463
# senior    157
# kitten    148
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     143
# senior     29
# kitten     28
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     463
# senior    157
# kitten    148
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     143
# senior     29
# kitten     28
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 463, 2: 157, 1: 148})
# Epoch 1/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 1.2978 - accuracy: 0.5065
# Epoch 2/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.5965 - accuracy: 0.6992
# Epoch 3/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4149 - accuracy: 0.8060
# Epoch 4/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3266 - accuracy: 0.8281
# Epoch 5/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2657 - accuracy: 0.8932
# Epoch 6/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2115 - accuracy: 0.8867
# Epoch 7/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1789 - accuracy: 0.9128
# Epoch 8/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1373 - accuracy: 0.9362
# Epoch 9/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1440 - accuracy: 0.9375
# Epoch 10/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1117 - accuracy: 0.9505
# Epoch 11/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1025 - accuracy: 0.9648
# Epoch 12/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0946 - accuracy: 0.9648
# Epoch 13/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0621 - accuracy: 0.9714
# Epoch 14/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0970 - accuracy: 0.9544
# Epoch 15/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0780 - accuracy: 0.9635
# Epoch 16/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0738 - accuracy: 0.9701
# Epoch 17/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0488 - accuracy: 0.9701
# Epoch 18/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0647 - accuracy: 0.9753
# Epoch 19/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0357 - accuracy: 0.9857
# Epoch 20/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0543 - accuracy: 0.9857
# Epoch 21/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0293 - accuracy: 0.9870
# Epoch 22/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0240 - accuracy: 0.9909
# Epoch 23/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0168 - accuracy: 0.9922
# Epoch 24/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0139 - accuracy: 0.9948
# Epoch 25/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0301 - accuracy: 0.9896
# Epoch 26/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0293 - accuracy: 0.9870
# Epoch 27/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0427 - accuracy: 0.9805
# Epoch 28/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0218 - accuracy: 0.9909
# Epoch 29/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0169 - accuracy: 0.9961
# Epoch 30/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0220 - accuracy: 0.9909
# Epoch 31/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0117 - accuracy: 0.9987
# Epoch 32/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0091 - accuracy: 0.9974
# Epoch 33/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0082 - accuracy: 0.9987
# Epoch 34/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0140 - accuracy: 0.9948
# Epoch 35/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0131 - accuracy: 0.9922
# Epoch 36/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0104 - accuracy: 0.9961
# Epoch 37/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0043 - accuracy: 1.0000
# Epoch 38/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0064 - accuracy: 0.9974
# Epoch 39/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0159 - accuracy: 0.9961
# Epoch 40/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0124 - accuracy: 0.9961
# Epoch 41/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0136 - accuracy: 0.9948
# Epoch 42/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0082 - accuracy: 0.9974
# Epoch 43/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0134 - accuracy: 0.9961
# Epoch 44/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0110 - accuracy: 0.9948
# Epoch 45/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0183 - accuracy: 0.9922
# Epoch 46/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0142 - accuracy: 0.9948
# Epoch 47/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0256 - accuracy: 0.9870
# Epoch 48/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0097 - accuracy: 0.9961
# Epoch 49/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0086 - accuracy: 0.9974
# Epoch 50/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0061 - accuracy: 0.9961
# Epoch 51/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0183 - accuracy: 0.9909
# Epoch 52/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0107 - accuracy: 0.9974
# Epoch 53/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0057 - accuracy: 0.9987
# Epoch 54/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0046 - accuracy: 1.0000
# Epoch 55/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0049 - accuracy: 0.9987
# Epoch 56/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0054 - accuracy: 0.9987
# Epoch 57/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0038 - accuracy: 0.9987
# Epoch 58/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 59/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0092 - accuracy: 0.9974
# Epoch 60/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0066 - accuracy: 0.9961
# Epoch 61/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0110 - accuracy: 0.9974
# Epoch 62/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0098 - accuracy: 0.9961
# Epoch 63/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0120 - accuracy: 0.9961
# Epoch 64/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0121 - accuracy: 0.9961
# Epoch 65/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0120 - accuracy: 0.9948
# Epoch 66/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0106 - accuracy: 0.9961
# Epoch 67/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0070 - accuracy: 0.9961
# Epoch 68/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0037 - accuracy: 0.9987
# Epoch 69/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0032 - accuracy: 0.9987
# Epoch 70/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0065 - accuracy: 0.9987
# Epoch 71/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 72/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0055 - accuracy: 0.9961
# Epoch 73/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0105 - accuracy: 0.9974
# Epoch 74/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0197 - accuracy: 0.9883
# Epoch 75/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0056 - accuracy: 0.9974
# Epoch 76/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0050 - accuracy: 0.9987
# Epoch 77/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0045 - accuracy: 1.0000
# Epoch 78/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 79/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0079 - accuracy: 0.9987
# Epoch 80/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0039 - accuracy: 0.9974
# Epoch 81/1500
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0114 - accuracy: 0.9961
# Epoch 82/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0043 - accuracy: 0.9987
# Epoch 83/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0031 - accuracy: 0.9987
# Epoch 84/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0069 - accuracy: 0.9974
# Epoch 85/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 86/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0072 - accuracy: 0.9974
# Epoch 87/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0053 - accuracy: 0.9987
# Epoch 88/1500
# 12/12 [==============================] - ETA: 0s - loss: 0.0027 - accuracy: 0.9987Restoring model weights from the end of the best epoch: 58.
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0027 - accuracy: 0.9987
# Epoch 88: early stopping
# 7/7 [==============================] - 0s 1ms/step - loss: 1.9908 - accuracy: 0.7450
# 7/7 [==============================] - 0s 1ms/step
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Majority Vote Accuracy for cat_id for this fold: 0.86 (24/28)
# Before appending - Cat IDs: 453, Predictions: 453, Actuals: 453, Gender: 453
# After appending - Cat IDs: 653, Predictions: 653, Actuals: 653, Gender: 653
# Final Test Results - Loss: 1.9908283948898315, Accuracy: 0.7450000047683716, Precision: 0.6244737543298694, Recall: 0.6591483229414263, F1 Score: 0.6372718019437877
# Confusion Matrix:
#  [[116  13  14]
#  [  4  23   1]
#  [ 19   0  10]]
# outer_fold 4
# Train Set Group Distribution:
# 046A    66
# 002B    36
# 103A    33
# 057A    28
# 074A    25
#         ..
# 110A     1
# 048A     1
# 090A     1
# 049A     1
# 076A     1
# Name: cat_id, Length: 85, dtype: int64
# Testing Set Group Distribution:
# 000A    39
# 047A    30
# 020A    23
# 067A    20
# 029A    17
# 097A    16
# 001A    15
# 039A    12
# 014B    10
# 040A    10
# 022A     9
# 109A     6
# 021A     6
# 007A     6
# 034A     5
# 009A     4
# 104A     4
# 026A     4
# 113A     3
# 064A     3
# 032A     2
# 092A     1
# 096A     1
# 115A     1
# 004A     1
# 026B     1
# 100A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    266
# X    259
# F    193
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    96
# M    90
# F    64
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [002A, 028A, 070A, 033A, 000B, 071A, 015A, 065...
# kitten    [046A, 042A, 110A, 049A, 045A, 048A, 111A, 044...
# senior    [117A, 106A, 057A, 090A, 051B, 116A, 051A, 024...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [020A, 000A, 026A, 007A, 021A, 001A, 034A, 009...
# kitten                       [014B, 109A, 040A, 047A, 115A]
# senior                                   [113A, 097A, 104A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 55, 'kitten': 11, 'senior': 19}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 19, 'kitten': 5, 'senior': 3}
# Unique Training/Validation Group IDs:
# ['000B' '002A' '002B' '003A' '005A' '006A' '008A' '010A' '011A' '012A'
#  '013B' '014A' '015A' '016A' '018A' '019A' '019B' '023A' '023B' '024A'
#  '025A' '025B' '025C' '026C' '027A' '028A' '031A' '033A' '035A' '036A'
#  '037A' '038A' '041A' '042A' '043A' '044A' '045A' '046A' '048A' '049A'
#  '050A' '051A' '051B' '052A' '053A' '054A' '055A' '056A' '057A' '058A'
#  '059A' '060A' '061A' '062A' '063A' '065A' '066A' '068A' '069A' '070A'
#  '071A' '072A' '073A' '074A' '075A' '076A' '087A' '088A' '090A' '091A'
#  '093A' '094A' '095A' '097B' '099A' '101A' '102A' '103A' '105A' '106A'
#  '108A' '110A' '111A' '116A' '117A']
# Unique Test Group IDs:
# ['000A' '001A' '004A' '007A' '009A' '014B' '020A' '021A' '022A' '026A'
#  '026B' '029A' '032A' '034A' '039A' '040A' '047A' '064A' '067A' '092A'
#  '096A' '097A' '100A' '104A' '109A' '113A' '115A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'000A'}
# Removed from Training/Validation Set:
# {'025C'}
# Moved to Test Set:
# {'025C'}
# Removed from Test Set
# {'000A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '002A' '002B' '003A' '005A' '006A' '008A' '010A' '011A'
#  '012A' '013B' '014A' '015A' '016A' '018A' '019A' '019B' '023A' '023B'
#  '024A' '025A' '025B' '026C' '027A' '028A' '031A' '033A' '035A' '036A'
#  '037A' '038A' '041A' '042A' '043A' '044A' '045A' '046A' '048A' '049A'
#  '050A' '051A' '051B' '052A' '053A' '054A' '055A' '056A' '057A' '058A'
#  '059A' '060A' '061A' '062A' '063A' '065A' '066A' '068A' '069A' '070A'
#  '071A' '072A' '073A' '074A' '075A' '076A' '087A' '088A' '090A' '091A'
#  '093A' '094A' '095A' '097B' '099A' '101A' '102A' '103A' '105A' '106A'
#  '108A' '110A' '111A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['001A' '004A' '007A' '009A' '014B' '020A' '021A' '022A' '025C' '026A'
#  '026B' '029A' '032A' '034A' '039A' '040A' '047A' '064A' '067A' '092A'
#  '096A' '097A' '100A' '104A' '109A' '113A' '115A']
# Length of X_train_val:
# 751
# Length of y_train_val:
# 751
# Length of groups_train_val:
# 751
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     436
# senior    163
# kitten    119
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     170
# kitten     57
# senior     23
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     469
# senior    163
# kitten    119
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     137
# kitten     57
# senior     23
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 469, 2: 163, 1: 119})
# Epoch 1/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 1.2084 - accuracy: 0.4647
# Epoch 2/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.6311 - accuracy: 0.6738
# Epoch 3/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4016 - accuracy: 0.7856
# Epoch 4/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3030 - accuracy: 0.8455
# Epoch 5/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2169 - accuracy: 0.8762
# Epoch 6/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2127 - accuracy: 0.8988
# Epoch 7/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1457 - accuracy: 0.9387
# Epoch 8/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1331 - accuracy: 0.9467
# Epoch 9/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1570 - accuracy: 0.9201
# Epoch 10/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1122 - accuracy: 0.9454
# Epoch 11/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1232 - accuracy: 0.9454
# Epoch 12/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0927 - accuracy: 0.9521
# Epoch 13/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0629 - accuracy: 0.9707
# Epoch 14/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0537 - accuracy: 0.9774
# Epoch 15/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0556 - accuracy: 0.9720
# Epoch 16/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0420 - accuracy: 0.9840
# Epoch 17/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0456 - accuracy: 0.9800
# Epoch 18/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0428 - accuracy: 0.9707
# Epoch 19/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0404 - accuracy: 0.9880
# Epoch 20/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0219 - accuracy: 0.9960
# Epoch 21/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0272 - accuracy: 0.9867
# Epoch 22/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0229 - accuracy: 0.9933
# Epoch 23/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0219 - accuracy: 0.9893
# Epoch 24/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0341 - accuracy: 0.9840
# Epoch 25/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0390 - accuracy: 0.9787
# Epoch 26/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0381 - accuracy: 0.9814
# Epoch 27/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0179 - accuracy: 0.9947
# Epoch 28/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0214 - accuracy: 0.9920
# Epoch 29/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0174 - accuracy: 0.9947
# Epoch 30/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0137 - accuracy: 0.9947
# Epoch 31/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0082 - accuracy: 0.9987
# Epoch 32/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0270 - accuracy: 0.9880
# Epoch 33/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0155 - accuracy: 0.9933
# Epoch 34/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0102 - accuracy: 0.9947
# Epoch 35/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0104 - accuracy: 0.9973
# Epoch 36/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0181 - accuracy: 0.9893
# Epoch 37/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0161 - accuracy: 0.9893
# Epoch 38/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0132 - accuracy: 0.9947
# Epoch 39/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0151 - accuracy: 0.9933
# Epoch 40/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0129 - accuracy: 0.9933
# Epoch 41/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0120 - accuracy: 0.9960
# Epoch 42/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0148 - accuracy: 0.9933
# Epoch 43/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0111 - accuracy: 0.9947
# Epoch 44/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0177 - accuracy: 0.9907
# Epoch 45/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0196 - accuracy: 0.9933
# Epoch 46/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0327 - accuracy: 0.9907
# Epoch 47/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0205 - accuracy: 0.9867
# Epoch 48/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0116 - accuracy: 0.9973
# Epoch 49/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0047 - accuracy: 0.9960
# Epoch 50/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0058 - accuracy: 0.9987
# Epoch 51/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0093 - accuracy: 0.9973
# Epoch 52/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0083 - accuracy: 0.9987
# Epoch 53/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0120 - accuracy: 0.9933
# Epoch 54/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 55/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 56/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 57/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0189 - accuracy: 0.9933
# Epoch 58/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0071 - accuracy: 0.9973
# Epoch 59/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0047 - accuracy: 0.9987
# Epoch 60/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0059 - accuracy: 0.9973
# Epoch 61/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0029 - accuracy: 0.9987
# Epoch 62/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0062 - accuracy: 0.9973
# Epoch 63/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0048 - accuracy: 0.9987
# Epoch 64/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0052 - accuracy: 0.9960
# Epoch 65/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 66/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 67/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0101 - accuracy: 0.9987
# Epoch 68/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0075 - accuracy: 0.9960
# Epoch 69/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 70/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 7.0470e-04 - accuracy: 1.0000
# Epoch 71/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0067 - accuracy: 0.9987
# Epoch 72/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0148 - accuracy: 0.9947
# Epoch 73/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0122 - accuracy: 0.9947
# Epoch 74/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0032 - accuracy: 0.9987
# Epoch 75/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0087 - accuracy: 0.9973
# Epoch 76/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0040 - accuracy: 0.9973
# Epoch 77/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0039 - accuracy: 0.9987
# Epoch 78/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0049 - accuracy: 0.9960
# Epoch 79/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0050 - accuracy: 0.9987
# Epoch 80/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0099 - accuracy: 0.9947
# Epoch 81/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0059 - accuracy: 0.9960
# Epoch 82/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0086 - accuracy: 0.9947
# Epoch 83/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0157 - accuracy: 0.9920
# Epoch 84/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0278 - accuracy: 0.9920
# Epoch 85/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0084 - accuracy: 0.9947
# Epoch 86/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0050 - accuracy: 0.9960
# Epoch 87/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0040 - accuracy: 0.9987
# Epoch 88/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0046 - accuracy: 1.0000
# Epoch 89/1500
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0068 - accuracy: 0.9973
# Epoch 90/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0081 - accuracy: 0.9973
# Epoch 91/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0054 - accuracy: 1.0000
# Epoch 92/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0026 - accuracy: 0.9973
# Epoch 93/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0058 - accuracy: 0.9973
# Epoch 94/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0017 - accuracy: 0.9987
# Epoch 95/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0038 - accuracy: 0.9987
# Epoch 96/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 97/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0183 - accuracy: 0.9973
# Epoch 98/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0106 - accuracy: 0.9960
# Epoch 99/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0034 - accuracy: 0.9960
# Epoch 100/1500
# 12/12 [==============================] - ETA: 0s - loss: 0.0060 - accuracy: 0.9987Restoring model weights from the end of the best epoch: 70.
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0060 - accuracy: 0.9987
# Epoch 100: early stopping
# 7/7 [==============================] - 0s 1ms/step - loss: 3.3838 - accuracy: 0.6544
# 7/7 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.85 (23/27)
# Before appending - Cat IDs: 653, Predictions: 653, Actuals: 653, Gender: 653
# After appending - Cat IDs: 870, Predictions: 870, Actuals: 870, Gender: 870
# Final Test Results - Loss: 3.383787155151367, Accuracy: 0.6543778777122498, Precision: 0.6083263714842663, Recall: 0.51390350413217, F1 Score: 0.5105746541040658
# Confusion Matrix:
#  [[118   4  15]
#  [ 40  14   3]
#  [ 13   0  10]]
#
# Final Average F1-Score across all UNSEEN TEST sets: 0.5594277579591355
#
# Final Average Loss across all UNSEEN TEST sets: 2.6202965080738068
#
# Final Average Accuracy across all UNSEEN TEST sets: 0.6574269384145737
#
# Final Average Precision across all UNSEEN TEST sets: 0.5841710791885596
#
# Final Average Recall across all UNSEEN TEST sets: 0.6251124205126519

# %%
seed_1_folds_values = [unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1]

seed_1_training_acc_values = cv_training_acc_total

# Plotting all fold metrics
seed_1_folds_plot = plot_all_metrics(unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1, "Folds", "Fold Number")

# %% [markdown]
# ## Majority Voting on Total Entries per cat_id

# %%
# Debugging print statements
print(f'Checking - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
# Out:
# Checking - Cat IDs:
  False
# 44    038A                                   [kitten, kitten]        kitten            adult                  False
# 27    024A                                           [kitten]        kitten           senior                  False
# 69    063A  [kitten, adult, kitten, kitten, senior, adult,...        kitten            adult                  False
# 52    047A  [adult, adult, adult, adult, adult, adult, adu...         adult           kitten                  False
# 6     005A  [senior, adult, adult, senior, senior, adult, ...        senior            adult                  False
# 102   108A        [adult, adult, adult, senior, adult, adult]         adult           senior                  False
# 101   106A  [adult, adult, senior, adult, adult, adult, se...         adult           senior                  False
# 18    016A  [adult, adult, adult, adult, adult, adult, sen...         adult           senior                  False
# 67    061A                                     [adult, adult]         adult           senior                  False
# 88    093A                                     [adult, adult]         adult           senior                  False
# 85    090A                                            [adult]         adult           senior                  False
# 65    059A  [senior, senior, senior, adult, adult, senior,...         adult           senior                  False
# 57    051B  [adult, adult, adult, adult, adult, adult, sen...         adult           senior                  False
# 12    011A                              [adult, adult, adult]         adult           senior                  False
# 64    058A                             [senior, adult, adult]         adult           senior                  False
# 92    097A  [adult, senior, senior, adult, adult, adult, a...         adult           senior                  False
# 82    076A                                           [kitten]        kitten            adult                  False
# 63    057A  [adult, adult, senior, adult, adult, adult, ad...         adult           senior                  False
# 16    014B  [adult, adult, senior, adult, adult, kitten, a...         adult           kitten                  False
# 62    056A                              [adult, adult, adult]         adult           senior                  False

# %%
# Create df for majority votes
majority_df = majority_votes.reset_index()
majority_df.columns = ['cat_id', 'Majority_Vote']

# Get actual groups for each cat_id
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first().reset_index()

# Merge majority votes with actual groups
majority_with_actual = pd.merge(majority_df, actual_groups, on='cat_id')

# Add a column to check if the majority vote was correct
majority_with_actual['Majority_Correct'] = majority_with_actual['Majority_Vote'] == majority_with_actual['actual_age_group']

# Count correct majority votes per class
correct_majority_votes_per_class = majority_with_actual.groupby('actual_age_group')['Majority_Correct'].sum()

print("Correct Majority Votes per Class:")
print(correct_majority_votes_per_class)
# Out:
# Correct Majority Votes per Class:
# actual_age_group
# adult     69
# kitten    13
# senior     5
# Name: Majority_Correct, dtype: int64

# %%
# Calculate the total count and the number of correct predictions for each class
class_stats = majority_with_actual.groupby('actual_age_group').agg(
    total_count=('Majority_Correct', 'size'),  # Total number of cases per class
    correct_count=('Majority_Correct', 'sum')  # Sum of correct predictions per class
).reset_index()

# Calculate accuracy for each class
class_stats['accuracy'] = class_stats['correct_count'] / class_stats['total_count'] * 100

# store for final evaluation 
all_majority_vote_details.append(class_stats)

# Log detailed stats
print("Detailed Class Statistics for Majority Votes:")
print(class_stats)
# Out:
# Detailed Class Statistics for Majority Votes:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult           73             69  94.520548
# 1           kitten           15             13  86.666667
# 2           senior           22              5  22.727273

# %%
# Plot for Detailed Class Statistics for Majority Votes
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Accuracy of Majority Votes by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Detailed Class Statistics

# %%
# Calculate the total count and the number of correct predictions for each class
class_stats = full_results.groupby('actual_age_group').agg(
    total_count=('correct', 'size'),
    correct_count=('correct', 'sum')
).reset_index()

# Calculate accuracy for each class
class_stats['accuracy'] = class_stats['correct_count'] / class_stats['total_count'] * 100

# store for final evaluation 
all_class_stats.append(class_stats)

# Log the detailed stats
print("Detailed Class Statistics:")
print(class_stats)
# Out:
# Detailed Class Statistics:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult          573            448  78.184991
# 1           kitten          111             59  53.153153
# 2           senior          186             71  38.172043

# %%
# Plot for Detailed Class Statistics (Overall)
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Overall Accuracy by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Gender Exploration

# %%
# Group by gender and calculate the total count, correct predictions, and accuracy
gender_stats = full_results.groupby('all_gender').agg(
    count=('cat_id', 'size'),  # Total number of cases per gender
    correct=('correct', 'sum')  # Sum of correct predictions per gender
).reset_index()

# Calculate accuracy for each gender
gender_stats['accuracy'] = (gender_stats['correct'] / gender_stats['count'] * 100).round(2)

# Display the DataFrame
print("Accuracy by Gender:")
print(gender_stats)

# store for final evaluation 
all_gender_stats.append(gender_stats)
# Out:
# Accuracy by Gender:
#   all_gender  count  correct  accuracy
# 0          F    218      144     66.06
# 1          M    362      266     73.48
# 2          X    290      168     57.93

# %%
# Plot for Accuracy by Gender
styled_barplot(gender_stats, 'all_gender', 'accuracy', 
               'Accuracy by Gender', 
               'Gender', 'Accuracy (%)')

# %% [markdown]
# ### Log current total CV Stats

# %%
print("Total Majority Vote Accuracy so far:", all_majority_vote_accuracies)
print("Total Class Statistics so far:\n", all_class_stats)
print("Total Gender Accuracy so far:\n", all_gender_stats)
# Out:
# Total Majority Vote Accuracy so far: [0.7909090909090909]
# Total Class Statistics so far:
#  [  actual_age_group  total_count  correct_count   accuracy
# 0            adult          573            448  78.184991
# 1           kitten          111             59  53.153153
# 2           senior          186             71  38.172043]
# Total Gender Accuracy so far:
#  [  all_gender  count  correct  accuracy
# 0          F    218      144     66.06
# 1          M    362      266     73.48
# 2          X    290      168     57.93]

# %% [markdown]
# # RANDOM SEED 2

# %%
# Set a fixed random seed for reproducibility
random.seed(int(random_seeds[1]))
np.random.seed(int(random_seeds[1]))
tf.random.set_seed(int(random_seeds[1]))

# Load datasets
dataframe = pd.read_csv('/Users/astrid/PycharmProjects/data-aug-and-more/yamnet-tfhub-extraction/yamnet_embeddings_looped_april_23.csv')

def assign_age_group(age, age_groups):
    for group_name, age_range in age_groups.items():
        if age_range[0] <= age < age_range[1]:
            return group_name
    return 'Unknown'  # For any age that doesn't fit the defined groups

# Define age groups
age_groups = {
    'kitten': (0, 0.5),
    'adult': (0.5, 12),
    'senior': (12, 20)
}

# Create a new column for the age group
dataframe['age_group'] = dataframe['target'].apply(assign_age_group, age_groups=age_groups)

print(dataframe['age_group'].value_counts())
# Out:
# adult     606
# senior    186
# kitten    176
# Name: age_group, dtype: int64

# %%
# Separate features and labels
X = dataframe.iloc[:, :-4].values  # all columns except the last four

# Encode the 'age_group' column as integers using LabelEncoder
label_encoder = LabelEncoder()
encoded_y = label_encoder.fit_transform(dataframe['age_group'].values)

# Use the encoded labels for splitting and one-hot encoding
y = encoded_y  

# Convert 'cat_id' column to numpy array to be used as groups array for GroupKFold
groups = dataframe['cat_id'].values

# %%
tf.keras.backend.clear_session()

# %% [markdown]
# ## Run Setup

# %%
all_cat_ids = []
all_predicted_age_groups = []
all_actual_age_groups = []
all_gender = []

# Define the StratifiedGroupKFold splitter for 4 fold CV with random shuffling
outer_cv = StratifiedGroupKFold(n_splits=4, shuffle=True, random_state=int(random_seeds[1]))

# unseen test set metrics
unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1 = [], [], [], [], []

cv_training_acc_total = []
cv_training_acc_best = []

outer_fold = 0


# Use the splitter to generate indices for training and testing sets
# Note: GroupShuffleSplit.split returns indices, so we use it to index the arrays
for train_val_idx, test_idx in outer_cv.split(X, y, groups):
    outer_fold += 1
    logger(f"outer_fold {outer_fold}", file=log_file_path)

    # Convert indices back to DataFrame for easy manipulation
    df_train_val = dataframe.iloc[train_val_idx]
    df_test = dataframe.iloc[test_idx]

    ##############################
    # ASSESSING SPLITS BY CAT_ID #
    ##############################
    
    # Get the distribution of groups
    training_validation_group_distribution = df_train_val['cat_id'].value_counts()  
    testing_group_distribution = df_test['cat_id'].value_counts()  
    
    # Log or print the distribution
    logger(f"Train Set Group Distribution:\n{training_validation_group_distribution}", file=log_file_path)
    logger(f"Testing Set Group Distribution:\n{testing_group_distribution}", file=log_file_path)

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val['gender'].value_counts()
    testing_gender_distribution = df_test['gender'].value_counts()
    
    # Log the distribution
    logger(f"Training Set Gender Distribution BEFORE SWAP:\n{training_gender_distribution}", file=log_file_path)
    logger(f"Testing Set Gender Distribution BEFORE SWAP:\n{testing_gender_distribution}", file=log_file_path)

    # Group by 'age_group' and then list unique 'cat_id' within each age group
    unique_cat_ids_per_age_group_train_val = df_train_val.groupby('age_group')['cat_id'].unique()
    unique_cat_ids_per_age_group_test = df_test.groupby('age_group')['cat_id'].unique()
    
    # Log results
    logger(f"Unique Cat IDs per Age Group in Training/Validation Set:\n{unique_cat_ids_per_age_group_train_val}", file=log_file_path)
    logger(f"Unique Cat IDs per Age Group in Testing Set:\n{unique_cat_ids_per_age_group_test}", file=log_file_path)

    # Calculate the count of unique identifiers per age group for training and testing set
    counts_train_val = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_train_val.items()}
    counts_test = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_test.items()}

    # Log the counts of unique identifiers per age group
    logger(f"Count of Unique Cat IDs per Age Group in Training/Validation Set:\n{counts_train_val}", file=log_file_path)
    logger(f"Count of Unique Cat IDs per Age Group in Testing Set:\n{counts_test}", file=log_file_path)

    #######################################################
    # CONTINUE WITH ENSURING VALID AND APPROPRIATE SPLITS #
    #######################################################
    
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    groups_train_val, groups_test = groups[train_val_idx], groups[test_idx]

    # logging identifier splits 
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)

    # check group splits
    check_initial_group_split(groups_train_val, groups_test)

    # Specify the cat_ids that must be in the training/validation set
    specific_cat_ids = ['000A', '046A']
    
    # Perform the swapping operation
    train_val_idx, test_idx = swap_cat_id_instances(dataframe, train_val_idx, test_idx, specific_cat_ids)
    
    # Re-assign the sets based on the updated indices
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    new_groups_train_val, new_groups_test = groups[train_val_idx], groups[test_idx]

    # Find differences for training and test sets
    moved_to_train_val, removed_from_train_val = find_group_differences(groups_train_val, new_groups_train_val)
    moved_to_test, removed_from_test = find_group_differences(groups_test, new_groups_test)
    
    # Display the results
    logger(f"Moved to Training/Validation Set:\n{moved_to_train_val}", file=log_file_path)
    logger(f"Removed from Training/Validation Set:\n{removed_from_train_val}", file=log_file_path)
    logger(f"Moved to Test Set:\n{moved_to_test}", file=log_file_path)
    logger(f"Removed from Test Set\n{removed_from_test}", file=log_file_path)

    # Update X_train_val, X_test, y_train_val, y_test, groups_train_val, groups_test based on updated indices
    X_train_val = X[train_val_idx]
    y_train_val = y[train_val_idx]
    groups_train_val = groups[train_val_idx]
    
    X_test = X[test_idx]
    y_test = y[test_idx]
    groups_test = groups[test_idx]

    # logging identifier splits again after potential swaps
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"AFTER SWAP - Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"AFTER SWAP - Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)
    
    # Verify the lengths are consistent
    logger(f"Length of X_train_val:\n{len(X_train_val)}", file=log_file_path)
    logger(f"Length of y_train_val:\n{len(y_train_val)}", file=log_file_path)
    logger(f"Length of groups_train_val:\n{len(groups_train_val)}", file=log_file_path)

    # Check group splits once more
    check_initial_group_split(groups_train_val, groups_test)

    # Convert the modified indices back to a DataFrame representing the updated df_train_val
    df_train_val_updated = dataframe.iloc[train_val_idx].copy()
    df_test_updated = dataframe.iloc[test_idx].copy()

    ############################
    # LOGGING AGE GROUP SPLITS #
    ############################

    # Get the distribution of age groups of age groups before the update
    training_validation_age_group_distribution = df_train_val['age_group'].value_counts()
    testing_age_group_distribution = df_test['age_group'].value_counts()
    
    # Logthe distribution
    logger(f"Train Age Group Distribution BEFORE SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution BEFORE SWAP:\n{testing_age_group_distribution}", file=log_file_path)

    # Get the distribution of age groups after the update
    training_validation_age_group_distribution = df_train_val_updated['age_group'].value_counts()
    testing_age_group_distribution = df_test_updated['age_group'].value_counts()
    
    # Log the distribution
    logger(f"Train Age Group Distribution AFTER SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution AFTER SWAP:\n{testing_age_group_distribution}", file=log_file_path)
    
    ########################################################
    # TRACKING FINAL CAT_IDs & GENDER AFTER REDISTRIBUTION #
    ########################################################

    # Get the distribution of groups
    training_validation_group_distribution = df_train_val_updated['cat_id'].value_counts()  
    testing_group_distribution = df_test_updated['cat_id'].value_counts()  

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val_updated['gender'].value_counts()
    testing_gender_distribution = df_test_updated['gender'].value_counts()
    
    logger(f"\n Starting training on unseen test set\n", file=log_file_path)

    ###################
    # PREPARING MODEL #
    ###################

    # Calculate the distribution of age groups in y_train_val
    age_group_distribution = Counter(y_train_val)
    print("Age group distribution:", age_group_distribution)

    # EarlyStopping callback: monitor 'loss' instead of 'val_loss' for the test set
    early_stopping = EarlyStopping(
        monitor='loss',  
        min_delta=0.001, 
        patience=30,  
        verbose=1,  
        restore_best_weights=True  
    )

    accuracy_history = AccuracyHistory()

    # One final shuffle to ensure randomness
    outer_shuffle_idx = np.random.permutation(len(X_train_val))
    X_train_val = X_train_val[outer_shuffle_idx]
    y_train_val = y_train_val[outer_shuffle_idx]

    class_weights = compute_class_weight(
        class_weight='balanced',
        classes=np.unique(y_train_val),
        y=y_train_val
    )
    weight_dict = {i: class_weights[i] for i in range(len(class_weights))}
    
    # Scale the features
    scaler_full = StandardScaler().fit(X_train_val)
    X_train_full_scaled = scaler_full.transform(X_train_val)
    X_test_scaled = scaler_full.transform(X_test)
    
    # Encode the labels
    y_train_full_encoded = to_categorical(y_train_val)
    y_test_encoded = to_categorical(y_test)

    #######################
    # BUILD & TRAIN MODEL #
    #######################

    optimizers = {
        'Adamax': Adamax(learning_rate=0.00510251984616472)
    }
    
    # Model definition with dynamic number of layers
    model_full = Sequential()
    model_full.add(Dense(480, activation='relu', input_shape=(X_train_full_scaled.shape[1],)))
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.2011047009431978))  
    model_full.add(Dense(256, activation='relu',)) 
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.14956886311951184))  
    model_full.add(Dense(256, activation='relu'))  
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.42291461228250665))  
    model_full.add(Dense(3, activation='softmax'))  
    
    # Use the optimizer from the parameters
    optimizer = optimizers['Adamax']  # optimizer_key from parameters
    
    # Compile the model
    model_full.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    
    # Train the model on the full training set
    history_full = model_full.fit(X_train_full_scaled, y_train_full_encoded, epochs=1500, batch_size=64,
                                  verbose=1, callbacks=[early_stopping, accuracy_history], class_weight=weight_dict)
    
    # log epochs
    best_epoch_index = np.argmin(history_full.history['loss'])  
    best_training_accuracy = accuracy_history.acc[best_epoch_index]
    # Append training acc to total  
    all_best_training_acc.append(best_training_accuracy)
    total_training_acc.append(accuracy_history.acc)
    # Append training acc just for this CV
    cv_training_acc_total.append(accuracy_history.acc)
    cv_training_acc_best.append(best_training_accuracy)
    
    # Evaluate the model on the held-out test set
    test_loss, test_accuracy = model_full.evaluate(X_test_scaled, y_test_encoded)

    y_test_pred_prob = model_full.predict(X_test_scaled)
    y_test_pred = np.argmax(y_test_pred_prob, axis=1)  
    y_test_true = np.argmax(y_test_encoded, axis=1)    

    ################################
    # LOG MAJORITY VOTE PER CAT_ID #
    ################################

    # Convert numeric predictions back to age group labels
    predicted_age_groups = label_encoder.inverse_transform(y_test_pred)
    actual_labels = label_encoder.inverse_transform(y_test_true)
    
    # Map predictions and actual labels back to cat_ids
    test_results = pd.DataFrame({
        'cat_id': df_test_updated['cat_id'],
        'predicted_age_group': predicted_age_groups,
        'actual_age_group': actual_labels
    })
    
    # Group by cat_id and aggregate predicted age groups
    majority_votes = test_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
    actual_groups = test_results.groupby('cat_id')['actual_age_group'].first()
    
    # Calculate the accuracy of majority voting
    correct_predictions = (majority_votes == actual_groups).sum()
    total_cats = len(actual_groups)
    majority_vote_accuracy = correct_predictions / total_cats
    
    # Log the accuracy of the majority voting
    logger(f"Majority Vote Accuracy for cat_id for this fold: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

    ####################################################
    # COLLECT PREDICTIONS FOR GENDER & CAT_ID ANALYSIS #
    ####################################################

    # Debugging print statements
    print(f'Before appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Extend lists with current fold results
    all_cat_ids.extend(df_test_updated['cat_id'].tolist())
    all_predicted_age_groups.extend(predicted_age_groups)
    all_actual_age_groups.extend(actual_labels)
    all_gender.extend(df_test_updated['gender'].tolist())

    # Debugging print statements
    print(f'After appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Calculate additional metrics
    test_precision = precision_score(y_test_true, y_test_pred, average='macro')  # Use 'macro' for imbalanced datasets
    test_recall = recall_score(y_test_true, y_test_pred, average='macro')
    test_f1 = f1_score(y_test_true, y_test_pred, average='macro')

    # prepare averages of outer metrics
    unseen_f1.append(test_f1)
    unseen_losses.append(test_loss)
    unseen_accuracies.append(test_accuracy)
    unseen_precisions.append(test_precision)
    unseen_recalls.append(test_recall)

    # Print final test results
    logger(f"Final Test Results - Loss: {test_loss}, Accuracy: {test_accuracy}, Precision: {test_precision}, Recall: {test_recall}, F1 Score: {test_f1}", file=log_file_path)

    # Generate the confusion matrix
    cm = confusion_matrix(y_test, y_test_pred)
    logger(f"Confusion Matrix:\n {cm}", file=log_file_path)

# Calculate the overall average metrics
unseen_set_avg_f1 = np.mean(unseen_f1)
unseen_set_avg_loss = np.mean(unseen_losses)
unseen_set_avg_acc = np.mean(unseen_accuracies)
unseen_set_avg_precision = np.mean(unseen_precisions)
unseen_set_avg_recall = np.mean(unseen_recalls)

logger(f"\nFinal Average F1-Score across all UNSEEN TEST sets: {unseen_set_avg_f1}", file=log_file_path)
logger(f"\nFinal Average Loss across all UNSEEN TEST sets: {unseen_set_avg_loss}", file=log_file_path)
logger(f"\nFinal Average Accuracy across all UNSEEN TEST sets: {unseen_set_avg_acc}", file=log_file_path)
logger(f"\nFinal Average Precision across all UNSEEN TEST sets: {unseen_set_avg_precision}", file=log_file_path)
logger(f"\nFinal Average Recall across all UNSEEN TEST sets: {unseen_set_avg_recall}\n", file=log_file_path)

# Append averages to total lists
average_fold_f1.append(unseen_set_avg_f1)
average_fold_losses.append(unseen_set_avg_loss)
average_fold_accuracies.append(unseen_set_avg_acc)
average_fold_precisions.append(unseen_set_avg_precision)
average_fold_recalls.append(unseen_set_avg_recall)

# Append all to total lists
all_f1.append(unseen_f1)
all_losses.append(unseen_losses)
all_accuracies.append(unseen_accuracies)
all_precisions.append(unseen_precisions)
all_recalls.append(unseen_recalls)
# Out:
# outer_fold 1
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Train Set Group Distribution:
# 000A    39
# 002B    36
# 047A    30
# 057A    28
# 074A    25
# 020A    23
# 000B    20
# 067A    20
# 055A    20
# 029A    17
# 019A    17
# 101A    16
# 097A    16
# 001A    15
# 042A    14
# 097B    14
# 028A    14
# 002A    13
# 039A    12
# 116A    12
# 005A    11
# 016A    11
# 040A    10
# 014B    10
# 071A    10
# 051B     9
# 022A     9
# 065A     9
# 072A     9
# 013B     8
# 095A     8
# 010A     8
# 117A     7
# 027A     7
# 050A     7
# 053A     7
# 031A     7
# 023A     6
# 037A     6
# 021A     6
# 025C     6
# 108A     6
# 008A     6
# 109A     6
# 007A     6
# 012A     5
# 034A     5
# 062A     5
# 070A     5
# 026A     4
# 009A     4
# 105A     4
# 003A     4
# 104A     4
# 058A     3
# 006A     3
# 113A     3
# 056A     3
# 011A     3
# 064A     3
# 060A     3
# 014A     3
# 087A     2
# 025B     2
# 093A     2
# 066A     2
# 054A     2
# 032A     2
# 102A     2
# 069A     2
# 038A     2
# 061A     2
# 073A     1
# 041A     1
# 026B     1
# 004A     1
# 076A     1
# 110A     1
# 115A     1
# 024A     1
# 091A     1
# 026C     1
# 049A     1
# 043A     1
# 096A     1
# 088A     1
# 100A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 046A    66
# 103A    33
# 059A    18
# 106A    15
# 111A    13
# 051A    12
# 063A    11
# 036A    11
# 068A    11
# 025A    11
# 015A    10
# 045A     9
# 033A     9
# 094A     8
# 099A     7
# 075A     5
# 023B     5
# 044A     5
# 035A     4
# 052A     4
# 018A     2
# 092A     1
# 048A     1
# 090A     1
# 019B     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    250
# X    223
# F    222
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    132
# M    106
# F     35
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [002A, 028A, 070A, 000B, 071A, 020A, 000A, 026...
# kitten    [042A, 014B, 110A, 109A, 040A, 047A, 049A, 043...
# senior    [117A, 057A, 113A, 051B, 116A, 024A, 097A, 055...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [033A, 015A, 023B, 068A, 018A, 103A, 063A, 075...
# kitten                       [046A, 045A, 048A, 111A, 044A]
# senior                       [106A, 090A, 051A, 094A, 059A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 59, 'kitten': 11, 'senior': 17}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 15, 'kitten': 5, 'senior': 5}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '004A' '005A' '006A' '007A'
#  '008A' '009A' '010A' '011A' '012A' '013B' '014A' '014B' '016A' '019A'
#  '020A' '021A' '022A' '023A' '024A' '025B' '025C' '026A' '026B' '026C'
#  '027A' '028A' '029A' '031A' '032A' '034A' '037A' '038A' '039A' '040A'
#  '041A' '042A' '043A' '047A' '049A' '050A' '051B' '053A' '054A' '055A'
#  '056A' '057A' '058A' '060A' '061A' '062A' '064A' '065A' '066A' '067A'
#  '069A' '070A' '071A' '072A' '073A' '074A' '076A' '087A' '088A' '091A'
#  '093A' '095A' '096A' '097A' '097B' '100A' '101A' '102A' '104A' '105A'
#  '108A' '109A' '110A' '113A' '115A' '116A' '117A']
# Unique Test Group IDs:
# ['015A' '018A' '019B' '023B' '025A' '033A' '035A' '036A' '044A' '045A'
#  '046A' '048A' '051A' '052A' '059A' '063A' '068A' '075A' '090A' '092A'
#  '094A' '099A' '103A' '106A' '111A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'046A'}
# Removed from Training/Validation Set:
# {'014B'}
# Moved to Test Set:
# {'014B'}
# Removed from Test Set
# {'046A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '004A' '005A' '006A' '007A'
#  '008A' '009A' '010A' '011A' '012A' '013B' '014A' '016A' '019A' '020A'
#  '021A' '022A' '023A' '024A' '025B' '025C' '026A' '026B' '026C' '027A'
#  '028A' '029A' '031A' '032A' '034A' '037A' '038A' '039A' '040A' '041A'
#  '042A' '043A' '046A' '047A' '049A' '050A' '051B' '053A' '054A' '055A'
#  '056A' '057A' '058A' '060A' '061A' '062A' '064A' '065A' '066A' '067A'
#  '069A' '070A' '071A' '072A' '073A' '074A' '076A' '087A' '088A' '091A'
#  '093A' '095A' '096A' '097A' '097B' '100A' '101A' '102A' '104A' '105A'
#  '108A' '109A' '110A' '113A' '115A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['014B' '015A' '018A' '019B' '023B' '025A' '033A' '035A' '036A' '044A'
#  '045A' '048A' '051A' '052A' '059A' '063A' '068A' '075A' '090A' '092A'
#  '094A' '099A' '103A' '106A' '111A']
# Length of X_train_val:
# 751
# Length of y_train_val:
# 751
# Length of groups_train_val:
# 751
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     481
# senior    132
# kitten     82
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     125
# kitten     94
# senior     54
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     481
# kitten    138
# senior    132
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     125
# senior     54
# kitten     38
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 481, 1: 138, 2: 132})
# Epoch 1/1500
# 12/12 [==============================] - 1s 4ms/step - loss: 1.2336 - accuracy: 0.4754
# Epoch 2/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.6199 - accuracy: 0.6551
# Epoch 3/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4727 - accuracy: 0.7563
# Epoch 4/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3551 - accuracy: 0.8069
# Epoch 5/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2464 - accuracy: 0.8735
# Epoch 6/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1699 - accuracy: 0.9188
# Epoch 7/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1612 - accuracy: 0.9055
# Epoch 8/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1535 - accuracy: 0.9241
# Epoch 9/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1367 - accuracy: 0.9348
# Epoch 10/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1092 - accuracy: 0.9494
# Epoch 11/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1197 - accuracy: 0.9507
# Epoch 12/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0821 - accuracy: 0.9574
# Epoch 13/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0604 - accuracy: 0.9720
# Epoch 14/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0697 - accuracy: 0.9734
# Epoch 15/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0508 - accuracy: 0.9720
# Epoch 16/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0390 - accuracy: 0.9867
# Epoch 17/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0332 - accuracy: 0.9840
# Epoch 18/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0463 - accuracy: 0.9854
# Epoch 19/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0434 - accuracy: 0.9800
# Epoch 20/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0310 - accuracy: 0.9867
# Epoch 21/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0242 - accuracy: 0.9893
# Epoch 22/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0286 - accuracy: 0.9933
# Epoch 23/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0383 - accuracy: 0.9867
# Epoch 24/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0308 - accuracy: 0.9854
# Epoch 25/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0228 - accuracy: 0.9933
# Epoch 26/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0315 - accuracy: 0.9854
# Epoch 27/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0261 - accuracy: 0.9880
# Epoch 28/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0381 - accuracy: 0.9840
# Epoch 29/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0292 - accuracy: 0.9893
# Epoch 30/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0159 - accuracy: 0.9947
# Epoch 31/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0120 - accuracy: 0.9973
# Epoch 32/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0299 - accuracy: 0.9867
# Epoch 33/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0188 - accuracy: 0.9933
# Epoch 34/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0113 - accuracy: 0.9960
# Epoch 35/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0179 - accuracy: 0.9893
# Epoch 36/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0217 - accuracy: 0.9867
# Epoch 37/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0202 - accuracy: 0.9920
# Epoch 38/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0197 - accuracy: 0.9920
# Epoch 39/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0070 - accuracy: 0.9973
# Epoch 40/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0119 - accuracy: 0.9960
# Epoch 41/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0100 - accuracy: 0.9987
# Epoch 42/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0123 - accuracy: 0.9960
# Epoch 43/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0053 - accuracy: 0.9973
# Epoch 44/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0112 - accuracy: 0.9973
# Epoch 45/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0093 - accuracy: 0.9960
# Epoch 46/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0121 - accuracy: 0.9920
# Epoch 47/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0086 - accuracy: 0.9960
# Epoch 48/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0188 - accuracy: 0.9920
# Epoch 49/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0119 - accuracy: 0.9960
# Epoch 50/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0128 - accuracy: 0.9947
# Epoch 51/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0080 - accuracy: 1.0000
# Epoch 52/1500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0106 - accuracy: 0.9933
# Epoch 53/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0164 - accuracy: 0.9907
# Epoch 54/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0068 - accuracy: 0.9973
# Epoch 55/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0201 - accuracy: 0.9947
# Epoch 56/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0068 - accuracy: 0.9973
# Epoch 57/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0065 - accuracy: 0.9960
# Epoch 58/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0061 - accuracy: 0.9987
# Epoch 59/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0077 - accuracy: 0.9947
# Epoch 60/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0129 - accuracy: 0.9960
# Epoch 61/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0088 - accuracy: 0.9973
# Epoch 62/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0147 - accuracy: 0.9920
# Epoch 63/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0072 - accuracy: 0.9973
# Epoch 64/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0095 - accuracy: 0.9960
# Epoch 65/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0058 - accuracy: 0.9987
# Epoch 66/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0050 - accuracy: 0.9987
# Epoch 67/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0035 - accuracy: 0.9987
# Epoch 68/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0035 - accuracy: 0.9987
# Epoch 69/1500
# 12/12 [==============================] - 0s 15ms/step - loss: 0.0037 - accuracy: 0.9973
# Epoch 70/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0091 - accuracy: 0.9933
# Epoch 71/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0052 - accuracy: 0.9973
# Epoch 72/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0084 - accuracy: 0.9987
# Epoch 73/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0199 - accuracy: 0.9973
# Epoch 74/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0076 - accuracy: 0.9973
# Epoch 75/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0082 - accuracy: 0.9973
# Epoch 76/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0069 - accuracy: 0.9960
# Epoch 77/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0046 - accuracy: 0.9973
# Epoch 78/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0090 - accuracy: 0.9933
# Epoch 79/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0048 - accuracy: 0.9973
# Epoch 80/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0035 - accuracy: 0.9987
# Epoch 81/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0079 - accuracy: 0.9960
# Epoch 82/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 83/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 84/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0055 - accuracy: 0.9987
# Epoch 85/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0031 - accuracy: 0.9987
# Epoch 86/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 87/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0110 - accuracy: 0.9960
# Epoch 88/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0266 - accuracy: 0.9920
# Epoch 89/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0057 - accuracy: 0.9987
# Epoch 90/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0225 - accuracy: 0.9933
# Epoch 91/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0060 - accuracy: 0.9973
# Epoch 92/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0063 - accuracy: 0.9973
# Epoch 93/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0154 - accuracy: 0.9920
# Epoch 94/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0027 - accuracy: 0.9973
# Epoch 95/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0078 - accuracy: 0.9960
# Epoch 96/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0116 - accuracy: 0.9920
# Epoch 97/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0077 - accuracy: 0.9947
# Epoch 98/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0297 - accuracy: 0.9920
# Epoch 99/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0358 - accuracy: 0.9827
# Epoch 100/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0033 - accuracy: 0.9973
# Epoch 101/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0147 - accuracy: 0.9987
# Epoch 102/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0049 - accuracy: 0.9973
# Epoch 103/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0141 - accuracy: 0.9933
# Epoch 104/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 105/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0080 - accuracy: 0.9960
# Epoch 106/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 107/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0022 - accuracy: 0.9987
# Epoch 108/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 109/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 110/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 111/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 112/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0023 - accuracy: 0.9987
# Epoch 113/1500
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0056 - accuracy: 0.9957    Restoring model weights from the end of the best epoch: 83.
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0054 - accuracy: 0.9960
# Epoch 113: early stopping
# 7/7 [==============================] - 0s 1ms/step - loss: 4.8647 - accuracy: 0.6636
# 7/7 [==============================] - 0s 1ms/step
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Majority Vote Accuracy for cat_id for this fold: 0.80 (20/25)
# Before appending - Cat IDs: 0, Predictions: 0, Actuals: 0, Gender: 0
# After appending - Cat IDs: 217, Predictions: 217, Actuals: 217, Gender: 217
# Final Test Results - Loss: 4.864658832550049, Accuracy: 0.6635944843292236, Precision: 0.62496748657054, Recall: 0.6137673814165042, F1 Score: 0.618855032917533
# Confusion Matrix:
#  [[97  5 23]
#  [ 8 25  5]
#  [26  6 22]]
# outer_fold 2
# Train Set Group Distribution:
# 046A    66
# 000A    39
# 002B    36
# 103A    33
# 057A    28
# 074A    25
# 020A    23
# 055A    20
# 000B    20
# 059A    18
# 097A    16
# 101A    16
# 106A    15
# 001A    15
# 028A    14
# 097B    14
# 111A    13
# 002A    13
# 039A    12
# 051A    12
# 116A    12
# 016A    11
# 068A    11
# 063A    11
# 025A    11
# 036A    11
# 040A    10
# 014B    10
# 071A    10
# 015A    10
# 033A     9
# 045A     9
# 051B     9
# 072A     9
# 013B     8
# 094A     8
# 010A     8
# 053A     7
# 099A     7
# 117A     7
# 031A     7
# 027A     7
# 023A     6
# 108A     6
# 008A     6
# 037A     6
# 025C     6
# 007A     6
# 075A     5
# 034A     5
# 062A     5
# 070A     5
# 023B     5
# 044A     5
# 035A     4
# 026A     4
# 003A     4
# 009A     4
# 052A     4
# 056A     3
# 113A     3
# 011A     3
# 060A     3
# 018A     2
# 025B     2
# 038A     2
# 032A     2
# 054A     2
# 102A     2
# 026C     1
# 041A     1
# 019B     1
# 115A     1
# 110A     1
# 043A     1
# 090A     1
# 073A     1
# 088A     1
# 092A     1
# 048A     1
# 049A     1
# 026B     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 047A    30
# 067A    20
# 019A    17
# 029A    17
# 042A    14
# 005A    11
# 022A     9
# 065A     9
# 095A     8
# 050A     7
# 109A     6
# 021A     6
# 012A     5
# 104A     4
# 105A     4
# 014A     3
# 064A     3
# 058A     3
# 006A     3
# 061A     2
# 087A     2
# 066A     2
# 069A     2
# 093A     2
# 096A     1
# 024A     1
# 091A     1
# 076A     1
# 004A     1
# 100A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    272
# X    270
# F    231
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    85
# M    84
# F    26
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [002A, 028A, 070A, 033A, 000B, 071A, 020A, 000...
# kitten    [046A, 014B, 110A, 040A, 049A, 045A, 048A, 111...
# senior    [117A, 106A, 057A, 090A, 113A, 051B, 116A, 051...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [065A, 021A, 105A, 005A, 006A, 091A, 019A, 022...
# kitten                             [042A, 109A, 047A, 050A]
# senior                       [024A, 058A, 061A, 104A, 093A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 53, 'kitten': 12, 'senior': 17}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 21, 'kitten': 4, 'senior': 5}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '007A' '008A' '009A' '010A'
#  '011A' '013B' '014B' '015A' '016A' '018A' '019B' '020A' '023A' '023B'
#  '025A' '025B' '025C' '026A' '026B' '026C' '027A' '028A' '031A' '032A'
#  '033A' '034A' '035A' '036A' '037A' '038A' '039A' '040A' '041A' '043A'
#  '044A' '045A' '046A' '048A' '049A' '051A' '051B' '052A' '053A' '054A'
#  '055A' '056A' '057A' '059A' '060A' '062A' '063A' '068A' '070A' '071A'
#  '072A' '073A' '074A' '075A' '088A' '090A' '092A' '094A' '097A' '097B'
#  '099A' '101A' '102A' '103A' '106A' '108A' '110A' '111A' '113A' '115A'
#  '116A' '117A']
# Unique Test Group IDs:
# ['004A' '005A' '006A' '012A' '014A' '019A' '021A' '022A' '024A' '029A'
#  '042A' '047A' '050A' '058A' '061A' '064A' '065A' '066A' '067A' '069A'
#  '076A' '087A' '091A' '093A' '095A' '096A' '100A' '104A' '105A' '109A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '007A' '008A' '009A' '010A'
#  '011A' '013B' '014B' '015A' '016A' '018A' '019B' '020A' '023A' '023B'
#  '025A' '025B' '025C' '026A' '026B' '026C' '027A' '028A' '031A' '032A'
#  '033A' '034A' '035A' '036A' '037A' '038A' '039A' '040A' '041A' '043A'
#  '044A' '045A' '046A' '048A' '049A' '051A' '051B' '052A' '053A' '054A'
#  '055A' '056A' '057A' '059A' '060A' '062A' '063A' '068A' '070A' '071A'
#  '072A' '073A' '074A' '075A' '088A' '090A' '092A' '094A' '097A' '097B'
#  '099A' '101A' '102A' '103A' '106A' '108A' '110A' '111A' '113A' '115A'
#  '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['004A' '005A' '006A' '012A' '014A' '019A' '021A' '022A' '024A' '029A'
#  '042A' '047A' '050A' '058A' '061A' '064A' '065A' '066A' '067A' '069A'
#  '076A' '087A' '091A' '093A' '095A' '096A' '100A' '104A' '105A' '109A']
# Length of X_train_val:
# 773
# Length of y_train_val:
# 773
# Length of groups_train_val:
# 773
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     480
# senior    174
# kitten    119
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     126
# kitten     57
# senior     12
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     480
# senior    174
# kitten    119
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     126
# kitten     57
# senior     12
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 480, 2: 174, 1: 119})
# Epoch 1/1500
# 13/13 [==============================] - 1s 4ms/step - loss: 1.1114 - accuracy: 0.5395
# Epoch 2/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.5727 - accuracy: 0.7089
# Epoch 3/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.4207 - accuracy: 0.7788
# Epoch 4/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3463 - accuracy: 0.8215
# Epoch 5/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2674 - accuracy: 0.8499
# Epoch 6/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2215 - accuracy: 0.8797
# Epoch 7/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2328 - accuracy: 0.8797
# Epoch 8/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2163 - accuracy: 0.8991
# Epoch 9/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1603 - accuracy: 0.9288
# Epoch 10/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1532 - accuracy: 0.9250
# Epoch 11/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1462 - accuracy: 0.9353
# Epoch 12/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1469 - accuracy: 0.9263
# Epoch 13/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1443 - accuracy: 0.9288
# Epoch 14/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0929 - accuracy: 0.9573
# Epoch 15/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1226 - accuracy: 0.9392
# Epoch 16/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0805 - accuracy: 0.9651
# Epoch 17/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0932 - accuracy: 0.9534
# Epoch 18/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0849 - accuracy: 0.9612
# Epoch 19/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0974 - accuracy: 0.9586
# Epoch 20/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0860 - accuracy: 0.9599
# Epoch 21/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0910 - accuracy: 0.9638
# Epoch 22/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0748 - accuracy: 0.9690
# Epoch 23/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0646 - accuracy: 0.9651
# Epoch 24/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0704 - accuracy: 0.9677
# Epoch 25/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0564 - accuracy: 0.9728
# Epoch 26/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0546 - accuracy: 0.9741
# Epoch 27/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0600 - accuracy: 0.9664
# Epoch 28/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0639 - accuracy: 0.9754
# Epoch 29/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0685 - accuracy: 0.9612
# Epoch 30/1500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0880 - accuracy: 0.9677
# Epoch 31/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0737 - accuracy: 0.9599
# Epoch 32/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0809 - accuracy: 0.9573
# Epoch 33/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0493 - accuracy: 0.9793
# Epoch 34/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0512 - accuracy: 0.9793
# Epoch 35/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0424 - accuracy: 0.9793
# Epoch 36/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0756 - accuracy: 0.9638
# Epoch 37/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0741 - accuracy: 0.9793
# Epoch 38/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0550 - accuracy: 0.9806
# Epoch 39/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0987 - accuracy: 0.9470
# Epoch 40/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0496 - accuracy: 0.9780
# Epoch 41/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0538 - accuracy: 0.9793
# Epoch 42/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0472 - accuracy: 0.9793
# Epoch 43/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0431 - accuracy: 0.9806
# Epoch 44/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0427 - accuracy: 0.9780
# Epoch 45/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0423 - accuracy: 0.9858
# Epoch 46/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0361 - accuracy: 0.9858
# Epoch 47/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0558 - accuracy: 0.9677
# Epoch 48/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0408 - accuracy: 0.9897
# Epoch 49/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0539 - accuracy: 0.9767
# Epoch 50/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0543 - accuracy: 0.9715
# Epoch 51/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0438 - accuracy: 0.9728
# Epoch 52/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0377 - accuracy: 0.9832
# Epoch 53/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0694 - accuracy: 0.9625
# Epoch 54/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0470 - accuracy: 0.9754
# Epoch 55/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0678 - accuracy: 0.9819
# Epoch 56/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0400 - accuracy: 0.9922
# Epoch 57/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0515 - accuracy: 0.9793
# Epoch 58/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0294 - accuracy: 0.9897
# Epoch 59/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0413 - accuracy: 0.9793
# Epoch 60/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0297 - accuracy: 0.9845
# Epoch 61/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0350 - accuracy: 0.9793
# Epoch 62/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0237 - accuracy: 0.9922
# Epoch 63/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0489 - accuracy: 0.9780
# Epoch 64/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0379 - accuracy: 0.9819
# Epoch 65/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0282 - accuracy: 0.9845
# Epoch 66/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0423 - accuracy: 0.9806
# Epoch 67/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0233 - accuracy: 0.9909
# Epoch 68/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0301 - accuracy: 0.9858
# Epoch 69/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0290 - accuracy: 0.9909
# Epoch 70/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0598 - accuracy: 0.9690
# Epoch 71/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0441 - accuracy: 0.9767
# Epoch 72/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0359 - accuracy: 0.9845
# Epoch 73/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0439 - accuracy: 0.9806
# Epoch 74/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0300 - accuracy: 0.9871
# Epoch 75/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0209 - accuracy: 0.9909
# Epoch 76/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0326 - accuracy: 0.9871
# Epoch 77/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0351 - accuracy: 0.9845
# Epoch 78/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0256 - accuracy: 0.9897
# Epoch 79/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0392 - accuracy: 0.9819
# Epoch 80/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0319 - accuracy: 0.9858
# Epoch 81/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0229 - accuracy: 0.9871
# Epoch 82/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0219 - accuracy: 0.9909
# Epoch 83/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0356 - accuracy: 0.9832
# Epoch 84/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0316 - accuracy: 0.9832
# Epoch 85/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0234 - accuracy: 0.9922
# Epoch 86/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0307 - accuracy: 0.9845
# Epoch 87/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0221 - accuracy: 0.9909
# Epoch 88/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0372 - accuracy: 0.9884
# Epoch 89/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0293 - accuracy: 0.9922
# Epoch 90/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0233 - accuracy: 0.9897
# Epoch 91/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0233 - accuracy: 0.9935
# Epoch 92/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0275 - accuracy: 0.9948
# Epoch 93/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0321 - accuracy: 0.9858
# Epoch 94/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.
1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0192 - accuracy: 0.9909
# Epoch 159/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0165 - accuracy: 0.9961
# Epoch 160/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0352 - accuracy: 0.9845
# Epoch 161/1500
# 11/13 [========================>.....] - ETA: 0s - loss: 0.0124 - accuracy: 0.9986Restoring model weights from the end of the best epoch: 131.
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0310 - accuracy: 0.9922
# Epoch 161: early stopping
# 7/7 [==============================] - 0s 1ms/step - loss: 2.3306 - accuracy: 0.5795
# 7/7 [==============================] - 0s 1ms/step
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Majority Vote Accuracy for cat_id for this fold: 0.70 (21/30)
# Before appending - Cat IDs: 217, Predictions: 217, Actuals: 217, Gender: 217
# After appending - Cat IDs: 412, Predictions: 412, Actuals: 412, Gender: 412
# Final Test Results - Loss: 2.3306498527526855, Accuracy: 0.5794872045516968, Precision: 0.46446544296006653, Recall: 0.49825953773322196, F1 Score: 0.463951933654904
# Confusion Matrix:
#  [[85 21 20]
#  [32 23  2]
#  [ 7  0  5]]
# outer_fold 3
# Train Set Group Distribution:
# 046A    66
# 000A    39
# 103A    33
# 047A    30
# 074A    25
# 055A    20
# 000B    20
# 067A    20
# 059A    18
# 029A    17
# 019A    17
# 097A    16
# 106A    15
# 042A    14
# 097B    14
# 111A    13
# 051A    12
# 068A    11
# 063A    11
# 005A    11
# 025A    11
# 036A    11
# 040A    10
# 015A    10
# 022A     9
# 033A     9
# 045A     9
# 051B     9
# 072A     9
# 065A     9
# 095A     8
# 094A     8
# 010A     8
# 099A     7
# 027A     7
# 053A     7
# 050A     7
# 031A     7
# 025C     6
# 023A     6
# 021A     6
# 109A     6
# 012A     5
# 044A     5
# 075A     5
# 023B     5
# 035A     4
# 052A     4
# 104A     4
# 105A     4
# 026A     4
# 003A     4
# 064A     3
# 006A     3
# 014A     3
# 011A     3
# 058A     3
# 056A     3
# 087A     2
# 025B     2
# 066A     2
# 061A     2
# 093A     2
# 069A     2
# 018A     2
# 019B     1
# 041A     1
# 115A     1
# 004A     1
# 026B     1
# 076A     1
# 073A     1
# 110A     1
# 090A     1
# 088A     1
# 096A     1
# 043A     1
# 091A     1
# 024A     1
# 092A     1
# 048A     1
# 100A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 002B    36
# 057A    28
# 020A    23
# 101A    16
# 001A    15
# 028A    14
# 002A    13
# 116A    12
# 039A    12
# 016A    11
# 014B    10
# 071A    10
# 013B     8
# 117A     7
# 007A     6
# 037A     6
# 008A     6
# 108A     6
# 070A     5
# 034A     5
# 062A     5
# 009A     4
# 060A     3
# 113A     3
# 102A     2
# 054A     2
# 032A     2
# 038A     2
# 026C     1
# 049A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    274
# M    257
# F    163
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# M    99
# F    94
# X    81
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [033A, 000B, 000A, 015A, 026A, 065A, 053A, 023...
# kitten    [046A, 042A, 110A, 109A, 040A, 047A, 045A, 048...
# senior    [106A, 090A, 051B, 051A, 024A, 097A, 094A, 059...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [002A, 028A, 070A, 071A, 020A, 038A, 026C, 007...
# kitten                                         [014B, 049A]
# senior           [117A, 057A, 113A, 116A, 016A, 054A, 108A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 53, 'kitten': 14, 'senior': 15}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 21, 'kitten': 2, 'senior': 7}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '003A' '004A' '005A' '006A' '010A' '011A' '012A' '014A'
#  '015A' '018A' '019A' '019B' '021A' '022A' '023A' '023B' '024A' '025A'
#  '025B' '025C' '026A' '026B' '027A' '029A' '031A' '033A' '035A' '036A'
#  '040A' '041A' '042A' '043A' '044A' '045A' '046A' '047A' '048A' '050A'
#  '051A' '051B' '052A' '053A' '055A' '056A' '058A' '059A' '061A' '063A'
#  '064A' '065A' '066A' '067A' '068A' '069A' '072A' '073A' '074A' '075A'
#  '076A' '087A' '088A' '090A' '091A' '092A' '093A' '094A' '095A' '096A'
#  '097A' '097B' '099A' '100A' '103A' '104A' '105A' '106A' '109A' '110A'
#  '111A' '115A']
# Unique Test Group IDs:
# ['001A' '002A' '002B' '007A' '008A' '009A' '013B' '014B' '016A' '020A'
#  '026C' '028A' '032A' '034A' '037A' '038A' '039A' '049A' '054A' '057A'
#  '060A' '062A' '070A' '071A' '101A' '102A' '108A' '113A' '116A' '117A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '003A' '004A' '005A' '006A' '010A' '011A' '012A' '014A'
#  '015A' '018A' '019A' '019B' '021A' '022A' '023A' '023B' '024A' '025A'
#  '025B' '025C' '026A' '026B' '027A' '029A' '031A' '033A' '035A' '036A'
#  '040A' '041A' '042A' '043A' '044A' '045A' '046A' '047A' '048A' '050A'
#  '051A' '051B' '052A' '053A' '055A' '056A' '058A' '059A' '061A' '063A'
#  '064A' '065A' '066A' '067A' '068A' '069A' '072A' '073A' '074A' '075A'
#  '076A' '087A' '088A' '090A' '091A' '092A' '093A' '094A' '095A' '096A'
#  '097A' '097B' '099A' '100A' '103A' '104A' '105A' '106A' '109A' '110A'
#  '111A' '115A']
# AFTER SWAP - Unique Test Group IDs:
# ['001A' '002A' '002B' '007A' '008A' '009A' '013B' '014B' '016A' '020A'
#  '026C' '028A' '032A' '034A' '037A' '038A' '039A' '049A' '054A' '057A'
#  '060A' '062A' '070A' '071A' '101A' '102A' '108A' '113A' '116A' '117A']
# Length of X_train_val:
# 694
# Length of y_train_val:
# 694
# Length of groups_train_val:
# 694
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     412
# kitten    165
# senior    117
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     194
# senior     69
# kitten     11
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     412
# kitten    165
# senior    117
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     194
# senior     69
# kitten     11
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 412, 1: 165, 2: 117})
# Epoch 1/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 1.1773 - accuracy: 0.5288
# Epoch 2/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.5379 - accuracy: 0.7406
# Epoch 3/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.3882 - accuracy: 0.8401
# Epoch 4/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.2768 - accuracy: 0.8573
# Epoch 5/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.1926 - accuracy: 0.9150
# Epoch 6/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.1596 - accuracy: 0.9323
# Epoch 7/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.1385 - accuracy: 0.9222
# Epoch 8/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.1129 - accuracy: 0.9510
# Epoch 9/1500
# 11/11 [==============================] - 0s 4ms/step - loss: 0.0738 - accuracy: 0.9683
# Epoch 10/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0769 - accuracy: 0.9712
# Epoch 11/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0596 - accuracy: 0.9798
# Epoch 12/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0606 - accuracy: 0.9798
# Epoch 13/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0677 - accuracy: 0.9755
# Epoch 14/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0403 - accuracy: 0.9813
# Epoch 15/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0583 - accuracy: 0.9726
# Epoch 16/1500
# 11/11 [==============================] - 0s 7ms/step - loss: 0.0408 - accuracy: 0.9813
# Epoch 17/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0306 - accuracy: 0.9841
# Epoch 18/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0331 - accuracy: 0.9914
# Epoch 19/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0433 - accuracy: 0.9769
# Epoch 20/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0207 - accuracy: 0.9942
# Epoch 21/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0289 - accuracy: 0.9856
# Epoch 22/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0312 - accuracy: 0.9870
# Epoch 23/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0234 - accuracy: 0.9899
# Epoch 24/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0295 - accuracy: 0.9928
# Epoch 25/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0222 - accuracy: 0.9899
# Epoch 26/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0159 - accuracy: 0.9914
# Epoch 27/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0104 - accuracy: 0.9971
# Epoch 28/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0194 - accuracy: 0.9957
# Epoch 29/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0153 - accuracy: 0.9971
# Epoch 30/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0088 - accuracy: 0.9986
# Epoch 31/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0083 - accuracy: 1.0000
# Epoch 32/1500
# 11/11 [==============================] - 0s 5ms/step - loss: 0.0166 - accuracy: 0.9957
# Epoch 33/1500
# 11/11 [==============================] - 0s 6ms/step - loss: 0.0131 - accuracy: 0.9928
# Epoch 34/1500
# ...
# 043A     1
# 088A     1
# 073A     1
# 041A     1
# 115A     1
# 026B     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    298
# M    289
# F    155
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# F    102
# M     67
# X     57
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [002A, 028A, 070A, 033A, 071A, 020A, 015A, 065...
# kitten    [046A, 042A, 014B, 109A, 047A, 049A, 045A, 048...
# senior    [117A, 106A, 057A, 090A, 113A, 116A, 051A, 024...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [000B, 000A, 026A, 053A, 072A, 010A, 074A, 031...
# kitten                       [110A, 040A, 043A, 041A, 115A]
# senior                       [051B, 097A, 055A, 011A, 056A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 57, 'kitten': 11, 'senior': 17}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 17, 'kitten': 5, 'senior': 5}
# Unique Training/Validation Group IDs:
# ['001A' '002A' '002B' '004A' '005A' '006A' '007A' '008A' '009A' '012A'
#  '013B' '014A' '014B' '015A' '016A' '018A' '019A' '019B' '020A' '021A'
#  '022A' '023B' '024A' '025A' '026C' '028A' '029A' '032A' '033A' '034A'
#  '035A' '036A' '037A' '038A' '039A' '042A' '044A' '045A' '046A' '047A'
#  '048A' '049A' '050A' '051A' '052A' '054A' '057A' '058A' '059A' '060A'
#  '061A' '062A' '063A' '064A' '065A' '066A' '067A' '068A' '069A' '070A'
#  '071A' '075A' '076A' '087A' '090A' '091A' '092A' '093A' '094A' '095A'
#  '096A' '099A' '100A' '101A' '102A' '103A' '104A' '105A' '106A' '108A'
#  '109A' '111A' '113A' '116A' '117A']
# Unique Test Group IDs:
# ['000A' '000B' '003A' '010A' '011A' '023A' '025B' '025C' '026A' '026B'
#  '027A' '031A' '040A' '041A' '043A' '051B' '053A' '055A' '056A' '072A'
#  '073A' '074A' '088A' '097A' '097B' '110A' '115A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'000A'}
# Removed from Training/Validation Set:
# {'092A'}
# Moved to Test Set:
# {'092A'}
# Removed from Test Set
# {'000A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '001A' '002A' '002B' '004A' '005A' '006A' '007A' '008A' '009A'
#  '012A' '013B' '014A' '014B' '015A' '016A' '018A' '019A' '019B' '020A'
#  '021A' '022A' '023B' '024A' '025A' '026C' '028A' '029A' '032A' '033A'
#  '034A' '035A' '036A' '037A' '038A' '039A' '042A' '044A' '045A' '046A'
#  '047A' '048A' '049A' '050A' '051A' '052A' '054A' '057A' '058A' '059A'
#  '060A' '061A' '062A' '063A' '064A' '065A' '066A' '067A' '068A' '069A'
#  '070A' '071A' '075A' '076A' '087A' '090A' '091A' '093A' '094A' '095A'
#  '096A' '099A' '100A' '101A' '102A' '103A' '104A' '105A' '106A' '108A'
#  '109A' '111A' '113A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['000B' '003A' '010A' '011A' '023A' '025B' '025C' '026A' '026B' '027A'
#  '031A' '040A' '041A' '043A' '051B' '053A' '055A' '056A' '072A' '073A'
#  '074A' '088A' '092A' '097A' '097B' '110A' '115A']
# Length of X_train_val:
# 780
# Length of y_train_val:
# 780
# Length of groups_train_val:
# 780
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     445
# kitten    162
# senior    135
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     161
# senior     51
# kitten     14
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     483
# kitten    162
# senior    135
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     123
# senior     51
# kitten     14
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 483, 1: 162, 2: 135})
# Epoch 1/1500
# 13/13 [==============================] - 1s 4ms/step - loss: 1.2295 - accuracy: 0.5115
# Epoch 2/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.6386 - accuracy: 0.6692
# Epoch 3/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.4454 - accuracy: 0.7744
# Epoch 4/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3704 - accuracy: 0.7821
# Epoch 5/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2728 - accuracy: 0.8615
# Epoch 6/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2389 - accuracy: 0.9038
# Epoch 7/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2007 - accuracy: 0.9051
# Epoch 8/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1861 - accuracy: 0.9179
# Epoch 9/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1932 - accuracy: 0.9064
# Epoch 10/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1252 - accuracy: 0.9346
# Epoch 11/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1088 - accuracy: 0.9500
# Epoch 12/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1000 - accuracy: 0.9526
# Epoch 13/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0919 - accuracy: 0.9628
# Epoch 14/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0735 - accuracy: 0.9641
# Epoch 15/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0672 - accuracy: 0.9692
# Epoch 16/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0706 - accuracy: 0.9756
# Epoch 17/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0545 - accuracy: 0.9769
# Epoch 18/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0463 - accuracy: 0.9782
# Epoch 19/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0526 - accuracy: 0.9731
# Epoch 20/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0597 - accuracy: 0.9769
# Epoch 21/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0330 - accuracy: 0.9872
# Epoch 22/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0411 - accuracy: 0.9808
# Epoch 23/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0286 - accuracy: 0.9897
# Epoch 24/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0415 - accuracy: 0.9833
# Epoch 25/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0337 - accuracy: 0.9885
# Epoch 26/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0286 - accuracy: 0.9923
# Epoch 27/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0486 - accuracy: 0.9833
# Epoch 28/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0330 - accuracy: 0.9859
# Epoch 29/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0283 - accuracy: 0.9910
# Epoch 30/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0175 - accuracy: 0.9949
# Epoch 31/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0536 - accuracy: 0.9808
# Epoch 32/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0187 - accuracy: 0.9897
# Epoch 33/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0131 - accuracy: 0.9949
# Epoch 34/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0173 - accuracy: 0.9923
# Epoch 35/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0360 - accuracy: 0.9833
# Epoch 36/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0601 - accuracy: 0.9821
# Epoch 37/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0292 - accuracy: 0.9872
# Epoch 38/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0465 - accuracy: 0.9833
# Epoch 39/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0193 - accuracy: 0.9897
# Epoch 40/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0281 - accuracy: 0.9885
# Epoch 41/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0232 - accuracy: 0.9936
# Epoch 42/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0213 - accuracy: 0.9885
# Epoch 43/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0388 - accuracy: 0.9769
# Epoch 44/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0158 - accuracy: 0.9936
# Epoch 45/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0127 - accuracy: 0.9962
# Epoch 46/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0216 - accuracy: 0.9885
# Epoch 47/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0217 - accuracy: 0.9962
# Epoch 48/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0326 - accuracy: 0.9897
# Epoch 49/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0160 - accuracy: 0.9936
# Epoch 50/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0198 - accuracy: 0.9910
# Epoch 51/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0225 - accuracy: 0.9910
# Epoch 52/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0254 - accuracy: 0.9897
# Epoch 53/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0155 - accuracy: 0.9936
# Epoch 54/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0210 - accuracy: 0.9897
# Epoch 55/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0190 - accuracy: 0.9936
# Epoch 56/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0372 - accuracy: 0.9872
# Epoch 57/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0197 - accuracy: 0.9949
# Epoch 58/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0220 - accuracy: 0.9885
# Epoch 59/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0323 - accuracy: 0.9808
# Epoch 60/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0191 - accuracy: 0.9936
# Epoch 61/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0054 - accuracy: 0.9987
# Epoch 62/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0065 - accuracy: 0.9987
# Epoch 63/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0097 - accuracy: 0.9949
# Epoch 64/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0127 - accuracy: 0.9949
# Epoch 65/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0117 - accuracy: 0.9949
# Epoch 66/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0118 - accuracy: 0.9974
# Epoch 67/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0079 - accuracy: 0.9987
# Epoch 68/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0053 - accuracy: 0.9987
# Epoch 69/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0143 - accuracy: 0.9974
# Epoch 70/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0056 - accuracy: 0.9987
# Epoch 71/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0202 - accuracy: 0.9910
# Epoch 72/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0138 - accuracy: 0.9962
# Epoch 73/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0261 - accuracy: 0.9872
# Epoch 74/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0168 - accuracy: 0.9923
# Epoch 75/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0295 - accuracy: 0.9872
# Epoch 76/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0062 - accuracy: 0.9974
# Epoch 77/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0186 - accuracy: 0.9897
# Epoch 78/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0068 - accuracy: 0.9962
# Epoch 79/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0059 - accuracy: 0.9974
# Epoch 80/1500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0055 - accuracy: 0.9974
# Epoch 81/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0044 - accuracy: 1.0000
# Epoch 82/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0045 - accuracy: 0.9987
# Epoch 83/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0105 - accuracy: 0.9962
# Epoch 84/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0149 - accuracy: 0.9949
# Epoch 85/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0149 - accuracy: 0.9962
# Epoch 86/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0334 - accuracy: 0.9872
# Epoch 87/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0099 - accuracy: 0.9974
# Epoch 88/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0234 - accuracy: 0.9897
# Epoch 89/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0152 - accuracy: 0.9923
# Epoch 90/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0176 - accuracy: 0.9936
# Epoch 91/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0249 - accuracy: 0.9923
# Epoch 92/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0147 - accuracy: 0.9949
# Epoch 93/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0116 - accuracy: 0.9962
# Epoch 94/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0214 - accuracy: 0.9936
# Epoch 95/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0163 - accuracy: 0.9910
# Epoch 96/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0131 - accuracy: 0.9962
# Epoch 97/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0204 - accuracy: 0.9923
# Epoch 98/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0108 - accuracy: 0.9949
# Epoch 99/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0077 - accuracy: 0.9974
# Epoch 100/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0062 - accuracy: 1.0000
# Epoch 101/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0061 - accuracy: 0.9974
# Epoch 102/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 103/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0055 - accuracy: 0.9974
# Epoch 104/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0086 - accuracy: 0.9949
# Epoch 105/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0044 - accuracy: 0.9987
# Epoch 106/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0054 - accuracy: 0.9974
# Epoch 107/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0117 - accuracy: 0.9962
# Epoch 108/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0149 - accuracy: 0.9974
# Epoch 109/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0088 - accuracy: 0.9987
# Epoch 110/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0262 - accuracy: 0.9885
# Epoch 111/1500
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0119 - accuracy: 0.9935Restoring model weights from the end of the best epoch: 81.
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0117 - accuracy: 0.9936
# Epoch 111: early stopping
# 6/6 [==============================] - 0s 1ms/step - loss: 3.0134 - accuracy: 0.6383
# 6/6 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.81 (22/27)
# Before appending - Cat IDs: 686, Predictions: 686, Actuals: 686, Gender: 686
# After appending - Cat IDs: 874, Predictions: 874, Actuals: 874, Gender: 874
# Final Test Results - Loss: 3.013449192047119, Accuracy: 0.6382978558540344, Precision: 0.5351390618513907, Recall: 0.5879050807314795, F1 Score: 0.5390554245836441
# Confusion Matrix:
#  [[101   8  14]
#  [  3  11   0]
#  [ 42   1   8]]
#
# Final Average F1-Score across all UNSEEN TEST sets: 0.5064598962176116
#
# Final Average Loss across all UNSEEN TEST sets: 326.0029340982437
#
# Final Average Accuracy across all UNSEEN TEST sets: 0
Use the splitter to generate indices for training and testing sets
# Note: GroupShuffleSplit.split returns indices, so we use it to index the arrays
for train_val_idx, test_idx in outer_cv.split(X, y, groups):
    outer_fold += 1
    logger(f"outer_fold {outer_fold}", file=log_file_path)

    # Convert indices back to DataFrame for easy manipulation
    df_train_val = dataframe.iloc[train_val_idx]
    df_test = dataframe.iloc[test_idx]

    ##############################
    # ASSESSING SPLITS BY CAT_ID #
    ##############################
    
    # Get the distribution of groups
    training_validation_group_distribution = df_train_val['cat_id'].value_counts()  
    testing_group_distribution = df_test['cat_id'].value_counts()  
    
    # Log or print the distribution
    logger(f"Train Set Group Distribution:\n{training_validation_group_distribution}", file=log_file_path)
    logger(f"Testing Set Group Distribution:\n{testing_group_distribution}", file=log_file_path)

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val['gender'].value_counts()
    testing_gender_distribution = df_test['gender'].value_counts()
    
    # Log the distribution
    logger(f"Training Set Gender Distribution BEFORE SWAP:\n{training_gender_distribution}", file=log_file_path)
    logger(f"Testing Set Gender Distribution BEFORE SWAP:\n{testing_gender_distribution}", file=log_file_path)

    # Group by 'age_group' and then list unique 'cat_id' within each age group
    unique_cat_ids_per_age_group_train_val = df_train_val.groupby('age_group')['cat_id'].unique()
    unique_cat_ids_per_age_group_test = df_test.groupby('age_group')['cat_id'].unique()
    
    # Log results
    logger(f"Unique Cat IDs per Age Group in Training/Validation Set:\n{unique_cat_ids_per_age_group_train_val}", file=log_file_path)
    logger(f"Unique Cat IDs per Age Group in Testing Set:\n{unique_cat_ids_per_age_group_test}", file=log_file_path)

    # Calculate the count of unique identifiers per age group for training and testing set
    counts_train_val = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_train_val.items()}
    counts_test = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_test.items()}

    # Log the counts of unique identifiers per age group
    logger(f"Count of Unique Cat IDs per Age Group in Training/Validation Set:\n{counts_train_val}", file=log_file_path)
    logger(f"Count of Unique Cat IDs per Age Group in Testing Set:\n{counts_test}", file=log_file_path)

    #######################################################
    # CONTINUE WITH ENSURING VALID AND APPROPRIATE SPLITS #
    #######################################################
    
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    groups_train_val, groups_test = groups[train_val_idx], groups[test_idx]

    # logging identifier splits 
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)

    # check group splits
    check_initial_group_split(groups_train_val, groups_test)

    # Specify the cat_ids that must be in the training/validation set
    specific_cat_ids = ['000A', '046A']
    
    # Perform the swapping operation
    train_val_idx, test_idx = swap_cat_id_instances(dataframe, train_val_idx, test_idx, specific_cat_ids)
    
    # Re-assign the sets based on the updated indices
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    new_groups_train_val, new_groups_test = groups[train_val_idx], groups[test_idx]

    # Find differences for training and test sets
    moved_to_train_val, removed_from_train_val = find_group_differences(groups_train_val, new_groups_train_val)
    moved_to_test, removed_from_test = find_group_differences(groups_test, new_groups_test)
    
    # Display the results
    logger(f"Moved to Training/Validation Set:\n{moved_to_train_val}", file=log_file_path)
    logger(f"Removed from Training/Validation Set:\n{removed_from_train_val}", file=log_file_path)
    logger(f"Moved to Test Set:\n{moved_to_test}", file=log_file_path)
    logger(f"Removed from Test Set\n{removed_from_test}", file=log_file_path)

    # Update X_train_val, X_test, y_train_val, y_test, groups_train_val, groups_test based on updated indices
    X_train_val = X[train_val_idx]
    y_train_val = y[train_val_idx]
    groups_train_val = groups[train_val_idx]
    
    X_test = X[test_idx]
    y_test = y[test_idx]
    groups_test = groups[test_idx]

    # logging identifier splits again after potential swaps
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"AFTER SWAP - Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"AFTER SWAP - Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)
    
    # Verify the lengths are consistent
    logger(f"Length of X_train_val:\n{len(X_train_val)}", file=log_file_path)
    logger(f"Length of y_train_val:\n{len(y_train_val)}", file=log_file_path)
    logger(f"Length of groups_train_val:\n{len(groups_train_val)}", file=log_file_path)

    # Check group splits once more
    check_initial_group_split(groups_train_val, groups_test)

    # Convert the modified indices back to a DataFrame representing the updated df_train_val
    df_train_val_updated = dataframe.iloc[train_val_idx].copy()
    df_test_updated = dataframe.iloc[test_idx].copy()

    ############################
    # LOGGING AGE GROUP SPLITS #
    ############################

    # Get the distribution of age groups of age groups before the update
    training_validation_age_group_distribution = df_train_val['age_group'].value_counts()
    testing_age_group_distribution = df_test['age_group'].value_counts()
    
    # Logthe distribution
    logger(f"Train Age Group Distribution BEFORE SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution BEFORE SWAP:\n{testing_age_group_distribution}", file=log_file_path)

    # Get the distribution of age groups after the update
    training_validation_age_group_distribution = df_train_val_updated['age_group'].value_counts()
    testing_age_group_distribution = df_test_updated['age_group'].value_counts()
    
    # Log the distribution
    logger(f"Train Age Group Distribution AFTER SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution AFTER SWAP:\n{testing_age_group_distribution}", file=log_file_path)
    
    ########################################################
    # TRACKING FINAL CAT_IDs & GENDER AFTER REDISTRIBUTION #
    ########################################################

    # Get the distribution of groups
    training_validation_group_distribution = df_train_val_updated['cat_id'].value_counts()  
    testing_group_distribution = df_test_updated['cat_id'].value_counts()  

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val_updated['gender'].value_counts()
    testing_gender_distribution = df_test_updated['gender'].value_counts()
    
    logger(f"\n Starting training on unseen test set\n", file=log_file_path)

    ###################
    # PREPARING MODEL #
    ###################

    # Calculate the distribution of age groups in y_train_val
    age_group_distribution = Counter(y_train_val)
    print("Age group distribution:", age_group_distribution)

    # EarlyStopping callback: monitor 'loss' instead of 'val_loss' for the test set
    early_stopping = EarlyStopping(
        monitor='loss',  
        min_delta=0.001, 
        patience=30,  
        verbose=1,  
        restore_best_weights=True  
    )

    accuracy_history = AccuracyHistory()

    # One final shuffle to ensure randomness
    outer_shuffle_idx = np.random.permutation(len(X_train_val))
    X_train_val = X_train_val[outer_shuffle_idx]
    y_train_val = y_train_val[outer_shuffle_idx]

    class_weights = compute_class_weight(
        class_weight='balanced',
        classes=np.unique(y_train_val),
        y=y_train_val
    )
    weight_dict = {i: class_weights[i] for i in range(len(class_weights))}
    
    # Scale the features
    scaler_full = StandardScaler().fit(X_train_val)
    X_train_full_scaled = scaler_full.transform(X_train_val)
    X_test_scaled = scaler_full.transform(X_test)
    
    # Encode the labels
    y_train_full_encoded = to_categorical(y_train_val)
    y_test_encoded = to_categorical(y_test)

    #######################
    # BUILD & TRAIN MODEL #
    #######################

    optimizers = {
        'Adamax': Adamax(learning_rate=0.00510251984616472)
    }
    
    # Model definition with dynamic number of layers
    model_full = Sequential()
    model_full.add(Dense(480, activation='relu', input_shape=(X_train_full_scaled.shape[1],)))
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.2011047009431978))  
    model_full.add(Dense(256, activation='relu',)) 
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.14956886311951184))  
    model_full.add(Dense(256, activation='relu'))  
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.42291461228250665))  
    model_full.add(Dense(3, activation='softmax'))  
    
    # Use the optimizer from the parameters
    optimizer = optimizers['Adamax']  # optimizer_key from parameters
    
    # Compile the model
    model_full.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    
    # Train the model on the full training set
    history_full = model_full.fit(X_train_full_scaled, y_train_full_encoded, epochs=1500, batch_size=64,
                                  verbose=1, callbacks=[early_stopping, accuracy_history], class_weight=weight_dict)
    
    # log epochs
    best_epoch_index = np.argmin(history_full.history['loss'])  
    best_training_accuracy = accuracy_history.acc[best_epoch_index]
    # Append training acc to total  
    all_best_training_acc.append(best_training_accuracy)
    total_training_acc.append(accuracy_history.acc)

    # Append training acc just for this CV
    cv_training_acc_total.append(accuracy_history.acc)
    cv_training_acc_best.append(best_training_accuracy)
    
    # Evaluate the model on the held-out test set
    test_loss, test_accuracy = model_full.evaluate(X_test_scaled, y_test_encoded)

    y_test_pred_prob = model_full.predict(X_test_scaled)
    y_test_pred = np.argmax(y_test_pred_prob, axis=1)  
    y_test_true = np.argmax(y_test_encoded, axis=1)    

    ################################
    # LOG MAJORITY VOTE PER CAT_ID #
    ################################

    # Convert numeric predictions back to age group labels
    predicted_age_groups = label_encoder.inverse_transform(y_test_pred)
    actual_labels = label_encoder.inverse_transform(y_test_true)
    
    # Map predictions and actual labels back to cat_ids
    test_results = pd.DataFrame({
        'cat_id': df_test_updated['cat_id'],
        'predicted_age_group': predicted_age_groups,
        'actual_age_group': actual_labels
    })
    
    # Group by cat_id and aggregate predicted age groups
    majority_votes = test_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
    actual_groups = test_results.groupby('cat_id')['actual_age_group'].first()
    
    # Calculate the accuracy of majority voting
    correct_predictions = (majority_votes == actual_groups).sum()
    total_cats = len(actual_groups)
    majority_vote_accuracy = correct_predictions / total_cats
    
    # Log the accuracy of the majority voting
    logger(f"Majority Vote Accuracy for cat_id for this fold: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

    ####################################################
    # COLLECT PREDICTIONS FOR GENDER & CAT_ID ANALYSIS #
    ####################################################

    # Debugging print statements
    print(f'Before appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Extend lists with current fold results
    all_cat_ids.extend(df_test_updated['cat_id'].tolist())
    all_predicted_age_groups.extend(predicted_age_groups)
    all_actual_age_groups.extend(actual_labels)
    all_gender.extend(df_test_updated['gender'].tolist())

    # Debugging print statements
    print(f'After appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Calculate additional metrics
    test_precision = precision_score(y_test_true, y_test_pred, average='macro')  # Use 'macro' for imbalanced datasets
    test_recall = recall_score(y_test_true, y_test_pred, average='macro')
    test_f1 = f1_score(y_test_true, y_test_pred, average='macro')

    # prepare averages of outer metrics
    unseen_f1.append(test_f1)
    unseen_losses.append(test_loss)
    unseen_accuracies.append(test_accuracy)
    unseen_precisions.append(test_precision)
    unseen_recalls.append(test_recall)

    # Print final test results
    logger(f"Final Test Results - Loss: {test_loss}, Accuracy: {test_accuracy}, Precision: {test_precision}, Recall: {test_recall}, F1 Score: {test_f1}", file=log_file_path)

    # Generate the confusion matrix
    cm = confusion_matrix(y_test, y_test_pred)
    logger(f"Confusion Matrix:\n {cm}", file=log_file_path)

# Calculate the overall average metrics
unseen_set_avg_f1 = np.mean(unseen_f1)
unseen_set_avg_loss = np.mean(unseen_losses)
unseen_set_avg_acc = np.mean(unseen_accuracies)
unseen_set_avg_precision = np.mean(unseen_precisions)
unseen_set_avg_recall = np.mean(unseen_recalls)

logger(f"\nFinal Average F1-Score across all UNSEEN TEST sets: {unseen_set_avg_f1}", file=log_file_path)
logger(f"\nFinal Average Loss across all UNSEEN TEST sets: {unseen_set_avg_loss}", file=log_file_path)
logger(f"\nFinal Average Accuracy across all UNSEEN TEST sets: {unseen_set_avg_acc}", file=log_file_path)
logger(f"\nFinal Average Precision across all UNSEEN TEST sets: {unseen_set_avg_precision}", file=log_file_path)
logger(f"\nFinal Average Recall across all UNSEEN TEST sets: {unseen_set_avg_recall}\n", file=log_file_path)

# Append averages to total lists
average_fold_f1.append(unseen_set_avg_f1)
average_fold_losses.append(unseen_set_avg_loss)
average_fold_accuracies.append(unseen_set_avg_acc)
average_fold_precisions.append(unseen_set_avg_precision)
average_fold_recalls.append(unseen_set_avg_recall)

# Append all to total lists
all_f1.append(unseen_f1)
all_losses.append(unseen_losses)
all_accuracies.append(unseen_accuracies)
all_precisions.append(unseen_precisions)
all_recalls.append(unseen_recalls)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# outer_fold 1
# Train Set Group Distribution:
# 046A    66
# 000A    39
# 002B    36
# 103A    33
# 074A    25
# 067A    20
# 059A    18
# 019A    17
# 029A    17
# 101A    16
# 097A    16
# 106A    15
# 001A    15
# 028A    14
# 042A    14
# 111A    13
# 002A    13
# 051A    12
# 039A    12
# 116A    12
# 016A    11
# 025A    11
# 063A    11
# 071A    10
# 040A    10
# 015A    10
# 014B    10
# 022A     9
# 033A     9
# 072A     9
# 065A     9
# 095A     8
# 010A     8
# 117A     7
# 050A     7
# 031A     7
# 027A     7
# 023A     6
# 008A     6
# 021A     6
# 109A     6
# 108A     6
# 007A     6
# 037A     6
# 034A     5
# 075A     5
# 023B     5
# 012A     5
# 062A     5
# 035A     4
# 003A     4
# 009A     4
# 052A     4
# 104A     4
# 026A     4
# 064A     3
# 058A     3
# 011A     3
# 014A     3
# 056A     3
# 006A     3
# 113A     3
# 060A     3
# 066A     2
# 025B     2
# 087A     2
# 093A     2
# 018A     2
# 032A     2
# 054A     2
# 102A     2
# 069A     2
# 038A     2
# 088A     1
# 024A     1
# 076A     1
# 090A     1
# 115A     1
# 041A     1
# 091A     1
# 026C     1
# 110A     1
# 019B     1
# 096A     1
# 049A     1
# 092A     1
# 026B     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 047A    30
# 057A    28
# 020A    23
# 000B    20
# 055A    20
# 097B    14
# 005A    11
# 036A    11
# 068A    11
# 045A     9
# 051B     9
# 013B     8
# 094A     8
# 099A     7
# 053A     7
# 025C     6
# 044A     5
# 070A     5
# 105A     4
# 061A     2
# 043A     1
# 073A     1
# 048A     1
# 004A     1
# 100A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    292
# X    244
# F    189
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    111
# F     68
# M     64
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [002A, 028A, 033A, 071A, 000A, 015A, 026A, 065...
# kitten    [046A, 042A, 014B, 110A, 109A, 040A, 049A, 111...
# senior    [117A, 106A, 090A, 113A, 116A, 051A, 024A, 097...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [070A, 000B, 020A, 053A, 068A, 105A, 013B, 005...
# kitten                       [047A, 045A, 048A, 044A, 043A]
# senior                       [057A, 051B, 094A, 055A, 061A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 59, 'kitten': 11, 'senior': 17}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 15, 'kitten': 5, 'senior': 5}
# Unique Training/Validation Group IDs:
# ['000A' '001A' '002A' '002B' '003A' '006A' '007A' '008A' '009A' '010A'
#  '011A' '012A' '014A' '014B' '015A' '016A' '018A' '019A' '019B' '021A'
#  '022A' '023A' '023B' '024A' '025A' '025B' '026A' '026B' '026C' '027A'
#  '028A' '029A' '031A' '032A' '033A' '034A' '035A' '037A' '038A' '039A'
#  '040A' '041A' '042A' '046A' '049A' '050A' '051A' '052A' '054A' '056A'
#  '058A' '059A' '060A' '062A' '063A' '064A' '065A' '066A' '067A' '069A'
#  '071A' '072A' '074A' '075A' '076A' '087A' '088A' '090A' '091A' '092A'
#  '093A' '095A' '096A' '097A' '101A' '102A' '103A' '104A' '106A' '108A'
#  '109A' '110A' '111A' '113A' '115A' '116A' '117A']
# Unique Test Group IDs:
# ['000B' '004A' '005A' '013B' '020A' '025C' '036A' '043A' '044A' '045A'
#  '047A' '048A' '051B' '053A' '055A' '057A' '061A' '068A' '070A' '073A'
#  '094A' '097B' '099A' '100A' '105A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '001A' '002A' '002B' '003A' '006A' '007A' '008A' '009A' '010A'
#  '011A' '012A' '014A' '014B' '015A' '016A' '018A' '019A' '019B' '021A'
#  '022A' '023A' '023B' '024A' '025A' '025B' '026A' '026B' '026C' '027A'
#  '028A' '029A' '031A' '032A' '033A' '034A' '035A' '037A' '038A' '039A'
#  '040A' '041A' '042A' '046A' '049A' '050A' '051A' '052A' '054A' '056A'
#  '058A' '059A' '060A' '062A' '063A' '064A' '065A' '066A' '067A' '069A'
#  '071A' '072A' '074A' '075A' '076A' '087A' '088A' '090A' '091A' '092A'
#  '093A' '095A' '096A' '097A' '101A' '102A' '103A' '104A' '106A' '108A'
#  '109A' '110A' '111A' '113A' '115A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['000B' '004A' '005A' '013B' '020A' '025C' '036A' '043A' '044A' '045A'
#  '047A' '048A' '051B' '053A' '055A' '057A' '061A' '068A' '070A' '073A'
#  '094A' '097B' '099A' '100A' '105A']
# Length of X_train_val:
# 725
# Length of y_train_val:
# 725
# Length of groups_train_val:
# 725
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     476
# kitten    130
# senior    119
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     130
# senior     67
# kitten     46
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     476
# kitten    130
# senior    119
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     130
# senior     67
# kitten     46
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 476, 1: 130, 2: 119})
# Epoch 1/1500
# 12/12 [==============================] - 1s 4ms/step - loss: 1.3258 - accuracy: 0.4938
# Epoch 2/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.6480 - accuracy: 0.6483
# Epoch 3/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4008 - accuracy: 0.7669
# Epoch 4/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2911 - accuracy: 0.8359
# Epoch 5/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2645 - accuracy: 0.8566
# Epoch 6/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2167 - accuracy: 0.8938
# Epoch 7/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1698 - accuracy: 0.9200
# Epoch 8/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1228 - accuracy: 0.9352
# Epoch 9/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1267 - accuracy: 0.9503
# Epoch 10/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1206 - accuracy: 0.9434
# Epoch 11/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1015 - accuracy: 0.9503
# Epoch 12/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0839 - accuracy: 0.9586
# Epoch 13/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0661 - accuracy: 0.9766
# Epoch 14/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0710 - accuracy: 0.9628
# Epoch 15/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0522 - accuracy: 0.9793
# Epoch 16/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0437 - accuracy: 0.9834
# Epoch 17/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0344 - accuracy: 0.9876
# Epoch 18/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0401 - accuracy: 0.9862
# Epoch 19/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0281 - accuracy: 0.9890
# Epoch 20/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0299 - accuracy: 0.9876
# Epoch 21/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0376 - accuracy: 0.9793
# Epoch 22/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0341 - accuracy: 0.9890
# Epoch 23/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0189 - accuracy: 0.9945
# Epoch 24/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0322 - accuracy: 0.9876
# Epoch 25/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0274 - accuracy: 0.9876
# Epoch 26/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0194 - accuracy: 0.9903
# Epoch 27/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0259 - accuracy: 0.9890
# Epoch 28/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0221 - accuracy: 0.9903
# Epoch 29/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0184 - accuracy: 0.9917
# Epoch 30/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0287 - accuracy: 0.9945
# Epoch 31/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0139 - accuracy: 0.9945
# Epoch 32/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0171 - accuracy: 0.9876
# Epoch 33/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0211 - accuracy: 0.9890
# Epoch 34/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0149 - accuracy: 0.9931
# Epoch 35/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0417 - accuracy: 0.9862
# Epoch 36/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0186 - accuracy: 0.9931
# Epoch 37/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0334 - accuracy: 0.9890
# Epoch 38/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0277 - accuracy: 0.9848
# Epoch 39/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0337 - accuracy: 0.9876
# Epoch 40/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0141 - accuracy: 0.9917
# Epoch 41/1500
# 12/12 [==============================] - 0s 15ms/step - loss: 0.0176 - accuracy: 0.9903
# Epoch 42/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0143 - accuracy: 0.9986
# Epoch 43/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0119 - accuracy: 0.9945
# Epoch 44/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0168 - accuracy: 0.9945
# Epoch 45/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0133 - accuracy: 0.9931
# Epoch 46/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0181 - accuracy: 0.9945
# Epoch 47/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0137 - accuracy: 0.9917
# Epoch 48/1500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0170 - accuracy: 0.9945
# Epoch 49/1500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0041 - accuracy: 1.0000
# Epoch 50/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0085 - accuracy: 0.9959
# Epoch 51/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0056 - accuracy: 1.0000
# Epoch 52/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0059 - accuracy: 1.0000
# Epoch 53/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0062 - accuracy: 0.9986
# Epoch 54/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0080 - accuracy: 0.9959
# Epoch 55/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0065 - accuracy: 0.9986
# Epoch 56/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0081 - accuracy: 0.9959
# Epoch 57/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0170 - accuracy: 0.9945
# Epoch 58/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0106 - accuracy: 0.9959
# Epoch 59/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0176 - accuracy: 0.9959
# Epoch 60/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0051 - accuracy: 0.9972
# Epoch 61/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0114 - accuracy: 0.9972
# Epoch 62/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0045 - accuracy: 0.9986
# Epoch 63/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 64/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0225 - accuracy: 0.9917
# Epoch 65/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0046 - accuracy: 0.9986
# Epoch 66/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0116 - accuracy: 0.9959
# Epoch 67/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 68/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0122 - accuracy: 0.9945
# Epoch 69/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0111 - accuracy: 0.9959
# Epoch 70/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0182 - accuracy: 0.9917
# Epoch 71/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 72/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 73/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0045 - accuracy: 0.9972
# Epoch 74/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0236 - accuracy: 0.9917
# Epoch 75/1500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0090 - accuracy: 0.9959
# Epoch 76/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0169 - accuracy: 0.9876
# Epoch 77/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0135 - accuracy: 0.9917
# Epoch 78/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0166 - accuracy: 0.9945
# Epoch 79/1500
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0086 - accuracy: 0.9972Restoring model weights from the end of the best epoch: 49.
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0142 - accuracy: 0.9945
# Epoch 79: early stopping
# 8/8 [==============================] - 0s 1ms/step - loss: 2.7732 - accuracy: 0.5720
# 8/8 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.76 (19/25)
# Before appending - Cat IDs: 0, Predictions: 0, Actuals: 0, Gender: 0
# After appending - Cat IDs: 243, Predictions: 243, Actuals: 243, Gender: 243
# Final Test Results - Loss: 2.7732021808624268, Accuracy: 0.5720164775848389, Precision: 0.5612794612794613, Recall: 0.4862210685701925, F1 Score: 0.49552506879166613
# Confusion Matrix:
#  [[104  11  15]
#  [ 26  20   0]
#  [ 50   2  15]]
# outer_fold 2
# Train Set Group Distribution:
# 046A    66
# 000A    39
# 103A    33
# 047A    30
# 057A    28
# 074A    25
# 020A    23
# 000B    20
# 067A    20
# 055A    20
# 059A    18
# 019A    17
# 097A    16
# 001A    15
# 097B    14
# 028A    14
# 111A    13
# 002A    13
# 116A    12
# 051A    12
# 039A    12
# 005A    11
# 068A    11
# 036A    11
# 025A    11
# 071A    10
# 014B    10
# 051B     9
# 072A     9
# 033A     9
# 045A     9
# 022A     9
# 094A     8
# 013B     8
# 053A     7
# 050A     7
# 117A     7
# 099A     7
# 031A     7
# 027A     7
# 008A     6
# 108A     6
# 021A     6
# 037A     6
# 007A     6
# 025C     6
# 044A     5
# 012A     5
# 070A     5
# 026A     4
# 104A     4
# 035A     4
# 003A     4
# 105A     4
# 052A     4
# 060A     3
# 064A     3
# 014A     3
# 056A     3
# 058A     3
# 006A     3
# 038A     2
# 032A     2
# 102A     2
# 061A     2
# 087A     2
# 066A     2
# 069A     2
# 018A     2
# 026B     1
# 004A     1
# 076A     1
# 115A     1
# 090A     1
# 043A     1
# 091A     1
# 024A     1
# 026C     1
# 048A     1
# 049A     1
# 073A     1
# 110A     1
# 100A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 002B    36
# 029A    17
# 101A    16
# 106A    15
# 042A    14
# 063A    11
# 016A    11
# 015A    10
# 040A    10
# 065A     9
# 010A     8
# 095A     8
# 109A     6
# 023A     6
# 034A     5
# 023B     5
# 075A     5
# 062A     5
# 009A     4
# 113A     3
# 011A     3
# 025B     2
# 093A     2
# 054A     2
# 088A     1
# 096A     1
# 019B     1
# 041A     1
# 092A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    297
# M    233
# F    220
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# M    123
# X     58
# F     37
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [002A, 028A, 070A, 033A, 000B, 071A, 020A, 000...
# kitten    [046A, 014B, 110A, 047A, 049A, 045A, 048A, 111...
# senior    [117A, 057A, 090A, 051B, 116A, 051A, 024A, 097...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [015A, 065A, 023B, 034A, 062A, 002B, 009A, 101...
# kitten                             [042A, 109A, 040A, 041A]
# senior                 [106A, 113A, 016A, 054A, 011A, 093A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 55, 'kitten': 12, 'senior': 16}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 19, 'kitten': 4, 'senior': 6}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '003A' '004A' '005A' '006A' '007A' '008A'
#  '012A' '013B' '014A' '014B' '018A' '019A' '020A' '021A' '022A' '024A'
#  '025A' '025C' '026A' '026B' '026C' '027A' '028A' '031A' '032A' '033A'
#  '035A' '036A' '037A' '038A' '039A' '043A' '044A' '045A' '046A' '047A'
#  '048A' '049A' '050A' '051A' '051B' '052A' '053A' '055A' '056A' '057A'
#  '058A' '059A' '060A' '061A' '064A' '066A' '067A' '068A' '069A' '070A'
#  '071A' '072A' '073A' '074A' '076A' '087A' '090A' '091A' '094A' '097A'
#  '097B' '099A' '100A' '102A' '103A' '104A' '105A' '108A' '110A' '111A'
#  '115A' '116A' '117A']
# Unique Test Group IDs:
# ['002B' '009A' '010A' '011A' '015A' '016A' '019B' '023A' '023B' '025B'
#  '029A' '034A' '040A' '041A' '042A' '054A' '062A' '063A' '065A' '075A'
#  '088A' '092A' '093A' '095A' '096A' '101A' '106A' '109A' '113A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '003A' '004A' '005A' '006A' '007A' '008A'
#  '012A' '013B' '014A' '014B' '018A' '019A' '020A' '021A' '022A' '024A'
#  '025A' '025C' '026A' '026B' '026C' '027A' '028A' '031A' '032A' '033A'
#  '035A' '036A' '037A' '038A' '039A' '043A' '044A' '045A' '046A' '047A'
#  '048A' '049A' '050A' '051A' '051B' '052A' '053A' '055A' '056A' '057A'
#  '058A' '059A' '060A' '061A' '064A' '066A' '067A' '068A' '069A' '070A'
#  '071A' '072A' '073A' '074A' '076A' '087A' '090A' '091A' '094A' '097A'
#  '097B' '099A' '100A' '102A' '103A' '104A' '105A' '108A' '110A' '111A'
#  '115A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['002B' '009A' '010A' '011A' '015A' '016A' '019B' '023A' '023B' '025B'
#  '029A' '034A' '040A' '041A' '042A' '054A' '062A' '063A' '065A' '075A'
#  '088A' '092A' '093A' '095A' '096A' '101A' '106A' '109A' '113A']
# Length of X_train_val:
# 750
# Length of y_train_val:
# 750
# Length of groups_train_val:
# 750
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     455
# senior    150
# kitten    145
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     151
# senior     36
# kitten     31
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     455
# senior    150
# kitten    145
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     151
# senior     36
# kitten     31
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 455, 2: 150, 1: 145})
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Epoch 1/1500
# 12/12 [==============================] - 1s 4ms/step - loss: 1.2436 - accuracy: 0.4760
# Epoch 2/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.5983 - accuracy: 0.7147
# Epoch 3/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4752 - accuracy: 0.7613
# Epoch 4/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3026 - accuracy: 0.8440
# Epoch 5/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2253 - accuracy: 0.8933
# Epoch 6/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1587 - accuracy: 0.9133
# Epoch 7/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1639 - accuracy: 0.9240
# Epoch 8/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1234 - accuracy: 0.9467
# Epoch 9/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1103 - accuracy: 0.9507
# Epoch 10/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1033 - accuracy: 0.9387
# Epoch 11/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0803 - accuracy: 0.9667
# Epoch 12/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0622 - accuracy: 0.9720
# Epoch 13/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0655 - accuracy: 0.9733
# Epoch 14/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0682 - accuracy: 0.9720
# Epoch 15/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0635 - accuracy: 0.9693
# Epoch 16/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0456 - accuracy: 0.9813
# Epoch 17/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0637 - accuracy: 0.9733
# Epoch 18/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0520 - accuracy: 0.9853
# Epoch 19/1500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0395 - accuracy: 0.9827
# Epoch 20/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0433 - accuracy: 0.9800
# Epoch 21/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0223 - accuracy: 0.9933
# Epoch 22/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0287 - accuracy: 0.9933
# Epoch 23/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0581 - accuracy: 0.9787
# Epoch 24/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0466 - accuracy: 0.9800
# Epoch 25/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0367 - accuracy: 0.9813
# Epoch 26/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0342 - accuracy: 0.9893
# Epoch 27/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0324 - accuracy: 0.9907
# Epoch 28/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0253 - accuracy: 0.9880
# Epoch 29/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0277 - accuracy: 0.9867
# Epoch 30/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0158 - accuracy: 0.9947
# Epoch 31/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0211 - accuracy: 0.9853
# Epoch 32/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0145 - accuracy: 0.9920
# Epoch 33/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0201 - accuracy: 0.9947
# Epoch 34/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0247 - accuracy: 0.9867
# Epoch 35/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0176 - accuracy: 0.9920
# Epoch 36/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0206 - accuracy: 0.9933
# Epoch 37/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0212 - accuracy: 0.9893
# Epoch 38/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0092 - accuracy: 0.9973
# Epoch 39/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0129 - accuracy: 0.9947
# Epoch 40/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0207 - accuracy: 0.9960
# Epoch 41/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0187 - accuracy: 0.9907
# Epoch 42/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0111 - accuracy: 0.9947
# Epoch 43/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0080 - accuracy: 0.9973
# Epoch 44/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0077 - accuracy: 0.9973
# Epoch 45/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0068 - accuracy: 0.9960
# Epoch 46/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0157 - accuracy: 0.9947
# Epoch 47/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0078 - accuracy: 0.9973
# Epoch 48/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0059 - accuracy: 0.9987
# Epoch 49/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0102 - accuracy: 0.9987
# Epoch 50/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0140 - accuracy: 0.9933
# Epoch 51/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0064 - accuracy: 1.0000
# Epoch 52/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0171 - accuracy: 0.9960
# Epoch 53/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0201 - accuracy: 0.9893
# Epoch 54/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0080 - accuracy: 0.9973
# Epoch 55/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0269 - accuracy: 0.9947
# Epoch 56/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0135 - accuracy: 0.9947
# Epoch 57/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0073 - accuracy: 0.9987
# Epoch 58/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0100 - accuracy: 0.9973
# Epoch 59/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0119 - accuracy: 0.9947
# Epoch 60/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0112 - accuracy: 0.9947
# Epoch 61/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0202 - accuracy: 0.9893
# Epoch 62/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0064 - accuracy: 0.9973
# Epoch 63/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0071 - accuracy: 0.9973
# Epoch 64/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0091 - accuracy: 0.9947
# Epoch 65/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0059 - accuracy: 0.9987
# Epoch 66/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0052 - accuracy: 0.9987
# Epoch 67/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0043 - accuracy: 0.9973
# Epoch 68/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0049 - accuracy: 0.9973
# Epoch 69/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 70/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0035 - accuracy: 0.9987
# Epoch 71/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0034 - accuracy: 0.9987
# Epoch 72/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0123 - accuracy: 0.9973
# Epoch 73/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 74/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0080 - accuracy: 0.9987
# Epoch 75/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0032 - accuracy: 0.9987
# Epoch 76/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0042 - accuracy: 0.9973
# Epoch 77/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 78/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0072 - accuracy: 0.9987
# Epoch 79/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0079 - accuracy: 0.9973
# Epoch 80/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0046 - accuracy: 0.9987
# Epoch 81/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0148 - accuracy: 0.9947
# Epoch 82/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 83/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0088 - accuracy: 0.9933
# Epoch 84/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 85/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0094 - accuracy: 0.9973
# Epoch 86/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0136 - accuracy: 0.9960
# Epoch 87/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0083 - accuracy: 0.9960
# Epoch 88/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0119 - accuracy: 0.9960
# Epoch 89/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0042 - accuracy: 0.9987
# Epoch 90/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0058 - accuracy: 0.9973
# Epoch 91/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0106 - accuracy: 0.9987
# Epoch 92/1500
# 12/12 [==============================] - 0s 15ms/step - loss: 0.0154 - accuracy: 0.9920
# Epoch 93/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 94/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 95/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0022 - accuracy: 0.9987
# Epoch 96/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0022 - accuracy: 0.9987
# Epoch 97/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 98/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 99/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0035 - accuracy: 0.9987
# Epoch 100/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0019 - accuracy: 0.9987
# Epoch 101/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0074 - accuracy: 0.9973
# Epoch 102/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0045 - accuracy: 0.9960
# Epoch 103/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 8.9952e-04 - accuracy: 1.0000
# Epoch 104/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 105/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0046 - accuracy: 0.9973
# Epoch 106/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0109 - accuracy: 0.9960
# Epoch 107/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0223 - accuracy: 0.9920
# Epoch 108/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0099 - accuracy: 0.9973
# Epoch 109/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0077 - accuracy: 0.9947
# Epoch 110/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0105 - accuracy: 0.9947
# Epoch 111/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0070 - accuracy: 0.9960
# Epoch 112/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0260 - accuracy: 0.9867
# Epoch 113/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 114/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0109 - accuracy: 0.9960
# Epoch 115/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0054 - accuracy: 0.9947
# Epoch 116/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0162 - accuracy: 0.9947
# Epoch 117/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0040 - accuracy: 0.9973
# Epoch 118/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0142 - accuracy: 0.9933
# Epoch 119/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0095 - accuracy: 0.9947
# Epoch 120/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 9.1139e-04 - accuracy: 1.0000
# Epoch 121/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 122/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0040 - accuracy: 0.9973
# Epoch 123/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0041 - accuracy: 0.9973
# Epoch 124/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0049 - accuracy: 0.9987
# Epoch 125/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0072 - accuracy: 0.9973
# Epoch 126/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0026 - accuracy: 0.9987
# Epoch 127/1500
# 12/12 [==============================] - ETA: 0s - loss: 0.0078 - accuracy: 0.9987    Restoring model weights from the end of the best epoch: 97.
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0078 - accuracy: 0.9987
# Epoch 127: early stopping
# 7/7 [==============================] - 0s 1ms/step - loss: 2.9907 - accuracy: 0.6743
# 7/7 [==============================] - 0s 1ms/step
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Majority Vote Accuracy for cat_id for this fold: 0.83 (24/29)
# Before appending - Cat IDs: 243, Predictions: 243, Actuals: 243, Gender: 243
# After appending - Cat IDs: 461, Predictions: 461, Actuals: 461, Gender: 461
# Final Test Results - Loss: 2.9907238483428955, Accuracy: 0.6743119359016418, Precision: 0.5618346834047246, Recall: 0.5770411513842405, F1 Score: 0.5688784355451022
# Confusion Matrix:
#  [[115  13  23]
#  [ 12  18   1]
#  [ 19   3  14]]
# outer_fold 3
# Train Set Group Distribution:
# 046A    66
# 002B    36
# 103A    33
# 047A    30
# 057A    28
# 020A    23
# 055A    20
# 000B    20
# 029A    17
# 101A    16
# 097A    16
# 106A    15
# 042A    14
# 097B    14
# 028A    14
# 039A    12
# 051A    12
# 063A    11
# 005A    11
# 016A    11
# 068A    11
# 025A    11
# 036A    11
# 040A    10
# 014B    10
# 015A    10
# 065A     9
# 051B     9
# 033A     9
# 045A     9
# 094A     8
# 095A     8
# 010A     8
# 013B     8
# 053A     7
# 099A     7
# 031A     7
# 109A     6
# 025C     6
# 021A     6
# 108A     6
# 007A     6
# 023A     6
# 012A     5
# 023B     5
# 070A     5
# 034A     5
# 062A     5
# 044A     5
# 075A     5
# 009A     4
# 105A     4
# 026A     4
# 011A     3
# 006A     3
# 113A     3
# 038A     2
# 054A     2
# 093A     2
# 061A     2
# 087A     2
# 025B     2
# 069A     2
# 018A     2
# 024A     1
# 026B     1
# 004A     1
# 076A     1
# 115A     1
# 041A     1
# 019B     1
# 090A     1
# 048A     1
# 073A     1
# 088A     1
# 049A     1
# 092A     1
# 096A     1
# 043A     1
# 026C     1
# 100A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 000A    39
# 074A    25
# 067A    20
# 059A    18
# 019A    17
# 001A    15
# 111A    13
# 002A    13
# 116A    12
# 071A    10
# 022A     9
# 072A     9
# 050A     7
# 117A     7
# 027A     7
# 037A     6
# 008A     6
# 104A     4
# 035A     4
# 003A     4
# 052A     4
# 060A     3
# 014A     3
# 056A     3
# 064A     3
# 058A     3
# 066A     2
# 032A     2
# 102A     2
# 091A     1
# 110A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    277
# M    256
# F    163
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# M    100
# F     94
# X     78
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [028A, 070A, 033A, 000B, 020A, 015A, 026A, 065...
# kitten    [046A, 042A, 014B, 109A, 040A, 047A, 049A, 045...
# senior    [106A, 057A, 090A, 113A, 051B, 051A, 024A, 097...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [002A, 071A, 000A, 001A, 072A, 091A, 019A, 022...
# kitten                                   [110A, 111A, 050A]
# senior                 [117A, 116A, 059A, 058A, 104A, 056A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 52, 'kitten': 13, 'senior': 16}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 22, 'kitten': 3, 'senior': 6}
# Unique Training/Validation Group IDs:
# ['000B' '002B' '004A' '005A' '006A' '007A' '009A' '010A' '011A' '012A'
#  '013B' '014B' '015A' '016A' '018A' '019B' '020A' '021A' '023A' '023B'
#  '024A' '025A' '025B' '025C' '026A' '026B' '026C' '028A' '029A' '031A'
#  '033A' '034A' '036A' '038A' '039A' '040A' '041A' '042A' '043A' '044A'
#  '045A' '046A' '047A' '048A' '049A' '051A' '051B' '053A' '054A' '055A'
#  '057A' '061A' '062A' '063A' '065A' '068A' '069A' '070A' '073A' '075A'
#  '076A' '087A' '088A' '090A' '092A' '093A' '094A' '095A' '096A' '097A'
#  '097B' '099A' '100A' '101A' '103A' '105A' '106A' '108A' '109A' '113A'
#  '115A']
# Unique Test Group IDs:
# ['000A' '001A' '002A' '003A' '008A' '014A' '019A' '022A' '027A' '032A'
#  '035A' '037A' '050A' '052A' '056A' '058A' '059A' '060A' '064A' '066A'
#  '067A' '071A' '072A' '074A' '091A' '102A' '104A' '110A' '111A' '116A'
#  '117A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'000A'}
# Removed from Training/Validation Set:
# {'031A'}
# Moved to Test Set:
# {'031A'}
# Removed from Test Set
# {'000A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '002B' '004A' '005A' '006A' '007A' '009A' '010A' '011A'
#  '012A' '013B' '014B' '015A' '016A' '018A' '019B' '020A' '021A' '023A'
#  '023B' '024A' '025A' '025B' '025C' '026A' '026B' '026C' '028A' '029A'
#  '033A' '034A' '036A' '038A' '039A' '040A' '041A' '042A' '043A' '044A'
#  '045A' '046A' '047A' '048A' '049A' '051A' '051B' '053A' '054A' '055A'
#  '057A' '061A' '062A' '063A' '065A' '068A' '069A' '070A' '073A' '075A'
#  '076A' '087A' '088A' '090A' '092A' '093A' '094A' '095A' '096A' '097A'
#  '097B' '099A' '100A' '101A' '103A' '105A' '106A' '108A' '109A' '113A'
#  '115A']
# AFTER SWAP - Unique Test Group IDs:
# ['001A' '002A' '003A' '008A' '014A' '019A' '022A' '027A' '031A' '032A'
#  '035A' '037A' '050A' '052A' '056A' '058A' '059A' '060A' '064A' '066A'
#  '067A' '071A' '072A' '074A' '091A' '102A' '104A' '110A' '111A' '116A'
#  '117A']
# Length of X_train_val:
# 728
# Length of y_train_val:
# 728
# Length of groups_train_val:
# 728
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     402
# kitten    155
# senior    139
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     204
# senior     47
# kitten     21
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     434
# kitten    155
# senior    139
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     172
# senior     47
# kitten     21
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 434, 1: 155, 2: 139})
# Epoch 1/1500
# 12/12 [==============================] - 1s 4ms/step - loss: 1.1380 - accuracy: 0.5192
# Epoch 2/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.5980 - accuracy: 0.7047
# Epoch 3/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4113 - accuracy: 0.7967
# Epoch 4/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.3693 - accuracy: 0.8146
# Epoch 5/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2576 - accuracy: 0.8626
# Epoch 6/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2143 - accuracy: 0.9038
# Epoch 7/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1740 - accuracy: 0.9107
# Epoch 8/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1391 - accuracy: 0.9396
# Epoch 9/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0905 - accuracy: 0.9615
# Epoch 10/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1214 - accuracy: 0.9519
# Epoch 11/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0749 - accuracy: 0.9643
# Epoch 12/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1027 - accuracy: 0.9615
# Epoch 13/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0780 - accuracy: 0.9698
# Epoch 14/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0761 - accuracy: 0.9684
# Epoch 15/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0749 - accuracy: 0.9643
# Epoch 16/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0769 - accuracy: 0.9712
# Epoch 17/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0803 - accuracy: 0.9629
# Epoch 18/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0369 - accuracy: 0.9876
# Epoch 19/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0410 - accuracy: 0.9808
# Epoch 20/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0278 - accuracy: 0.9876
# Epoch 21/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0302 - accuracy: 0.9904
# Epoch 22/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0311 - accuracy: 0.9849
# Epoch 23/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0321 - accuracy: 0.9918
# Epoch 24/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0293 - accuracy: 0.9863
# Epoch 25/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0225 - accuracy: 0.9945
# Epoch 26/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0179 - accuracy: 0.9973
# Epoch 27/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0325 - accuracy: 0.9876
# Epoch 28/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0178 - accuracy: 0.9931
# Epoch 29/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0279 - accuracy: 0.9890
# Epoch 30/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0125 - accuracy: 0.9959
# Epoch 31/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0291 - accuracy: 0.9876
# Epoch 32/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0097 - accuracy: 0.9973
# Epoch 33/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0177 - accuracy: 0.9931
# Epoch 34/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0263 - accuracy: 0.9890
# Epoch 35/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0116 - accuracy: 0.9931
# Epoch 36/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0115 - accuracy: 0.9931
# Epoch 37/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0124 - accuracy: 0.9945
# Epoch 38/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0073 - accuracy: 0.9986
# Epoch 39/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0172 - accuracy: 0.9904
# Epoch 40/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0142 - accuracy: 0.9931
# Epoch 41/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0136 - accuracy: 0.9918
# Epoch 42/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0164 - accuracy: 0.9890
# Epoch 43/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0060 - accuracy: 1.0000
# Epoch 44/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0116 - accuracy: 0.9986
# Epoch 45/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0137 - accuracy: 0.9931
# Epoch 46/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0108 - accuracy: 0.9959
# Epoch 47/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0109 - accuracy: 0.9945
# Epoch 48/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0094 - accuracy: 0.9931
# Epoch 49/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0071 - accuracy: 0.9986
# Epoch 50/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0129 - accuracy: 0.9945
# Epoch 51/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0222 - accuracy: 0.9918
# Epoch 52/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0281 - accuracy: 0.9918
# Epoch 53/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0177 - accuracy: 0.9918
# Epoch 54/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0409 - accuracy: 0.9959
# Epoch 55/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0361 - accuracy: 0.9808
# Epoch 56/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0162 - accuracy: 0.9931
# Epoch 57/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0072 - accuracy: 0.9986
# Epoch 58/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0183 - accuracy: 0.9945
# Epoch 59/1500
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0094 - accuracy: 0.9945
# Epoch 60/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0172 - accuracy: 0.9876
# Epoch 61/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0188 - accuracy: 0.9959
# Epoch 62/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0091 - accuracy: 0.9959
# Epoch 63/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0070 - accuracy: 0.9986
# Epoch 64/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0076 - accuracy: 0.9959
# Epoch 65/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0047 - accuracy: 0.9986
# Epoch 66/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 67/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0066 - accuracy: 0.9959
# Epoch 68/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 69/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0060 - accuracy: 0.9986
# Epoch 70/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 71/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 72/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0069 - accuracy: 0.9973
# Epoch 73/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 74/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0121 - accuracy: 0.9973
# Epoch 75/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0069 - accuracy: 0.9973
# Epoch 76/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0053 - accuracy: 0.9986
# Epoch 77/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 78/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0081 - accuracy: 0.9973
# Epoch 79/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0059 - accuracy: 0.9986
# Epoch 80/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0053 - accuracy: 0.9973
# Epoch 81/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0032 - accuracy: 0.9986
# Epoch 82/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 83/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0076 - accuracy: 0.9973
# Epoch 84/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0087 - accuracy: 0.9959
# Epoch 85/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0071 - accuracy: 0.9973
# Epoch 86/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0074 - accuracy: 0.9973
# Epoch 87/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0099 - accuracy: 0.9973
# Epoch 88/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0163 - accuracy: 0.9959
# Epoch 89/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0081 - accuracy: 0.9986
# Epoch 90/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0170 - accuracy: 0.9904
# Epoch 91/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0188 - accuracy: 0.9959
# Epoch 92/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0088 - accuracy: 0.9945
# Epoch 93/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0074 - accuracy: 0.9973
# Epoch 94/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0198 - accuracy: 0.9876
# Epoch 95/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 96/1500
# 12/12 [==============================] - ETA: 0s - loss: 0.0218 - accuracy: 0.9959Restoring model weights from the end of the best epoch: 66.
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0218 - accuracy: 0.9959
# Epoch 96: early stopping
# 8/8 [==============================] - 0s 1ms/step - loss: 1.8073 - accuracy: 0.6792
# 8/8 [==============================] - 0s 985us/step
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Majority Vote Accuracy for cat_id for this fold: 0.81 (25/31)
# Before appending - Cat IDs: 461, Predictions: 461, Actuals: 461, Gender: 461
# After appending - Cat IDs: 701, Predictions: 701, Actuals: 701, Gender: 701
# Final Test Results - Loss: 1.8072733879089355, Accuracy: 0.6791666746139526, Precision: 0.5678973962147696, Recall: 0.6310564469891536, F1 Score: 0.5802518315018316
# Confusion Matrix:
#  [[124  30  18]
#  [  8  13   0]
#  [ 21   0  26]]
# outer_fold 4
# Train Set Group Distribution:
# 000A    39
# 002B    36
# 047A    30
# 057A    28
# 074A    25
# 020A    23
# 000B    20
# 055A    20
# 067A    20
# 059A    18
# 029A    17
# 019A    17
# 101A    16
# 106A    15
# 001A    15
# 097B    14
# 042A    14
# 002A    13
# 111A    13
# 116A    12
# 063A    11
# 036A    11
# 005A    11
# 016A    11
# 068A    11
# 040A    10
# 071A    10
# 015A    10
# 022A     9
# 045A     9
# 065A     9
# 051B     9
# 072A     9
# 094A     8
# 010A     8
# 095A     8
# 013B     8
# 050A     7
# 099A     7
# 053A     7
# 027A     7
# 117A     7
# 008A     6
# 037A     6
# 109A     6
# 025C     6
# 023A     6
# 044A     5
# 062A     5
# 034A     5
# 075A     5
# 070A     5
# 023B     5
# 104A     4
# 009A     4
# 035A     4
# 003A     4
# 105A     4
# 052A     4
# 064A     3
# 011A     3
# 014A     3
# 060A     3
# 058A     3
# 113A     3
# 056A     3
# 025B     2
# 061A     2
# 054A     2
# 066A     2
# 093A     2
# 102A     2
# 032A     2
# 041A     1
# 004A     1
# 019B     1
# 073A     1
# 091A     1
# 110A     1
# 088A     1
# 096A     1
# 043A     1
# 092A     1
# 048A     1
# 100A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 046A    66
# 103A    33
# 097A    16
# 028A    14
# 039A    12
# 051A    12
# 025A    11
# 014B    10
# 033A     9
# 031A     7
# 108A     6
# 007A     6
# 021A     6
# 012A     5
# 026A     4
# 006A     3
# 087A     2
# 018A     2
# 069A     2
# 038A     2
# 115A     1
# 076A     1
# 024A     1
# 049A     1
# 090A     1
# 026C     1
# 026B     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    287
# X    247
# F    199
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    108
# M     69
# F     58
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [002A, 070A, 000B, 071A, 020A, 000A, 015A, 065...
# kitten    [042A, 110A, 109A, 040A, 047A, 045A, 048A, 111...
# senior    [117A, 106A, 057A, 113A, 051B, 116A, 094A, 059...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [028A, 033A, 026A, 038A, 026C, 007A, 021A, 018...
# kitten                             [046A, 014B, 049A, 115A]
# senior                       [090A, 051A, 024A, 097A, 108A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 56, 'kitten': 12, 'senior': 17}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 18, 'kitten': 4, 'senior': 5}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '004A' '005A' '008A' '009A'
#  '010A' '011A' '013B' '014A' '015A' '016A' '019A' '019B' '020A' '022A'
#  '023A' '023B' '025B' '025C' '027A' '029A' '032A' '034A' '035A' '036A'
#  '037A' '040A' '041A' '042A' '043A' '044A' '045A' '047A' '048A' '050A'
#  '051B' '052A' '053A' '054A' '055A' '056A' '057A' '058A' '059A' '060A'
#  '061A' '062A' '063A' '064A' '065A' '066A' '067A' '068A' '070A' '071A'
#  '072A' '073A' '074A' '075A' '088A' '091A' '092A' '093A' '094A' '095A'
#  '096A' '097B' '099A' '100A' '101A' '102A' '104A' '105A' '106A' '109A'
#  '110A' '111A' '113A' '116A' '117A']
# Unique Test Group IDs:
# ['006A' '007A' '012A' '014B' '018A' '021A' '024A' '025A' '026A' '026B'
#  '026C' '028A' '031A' '033A' '038A' '039A' '046A' '049A' '051A' '069A'
#  '076A' '087A' '090A' '097A' '103A' '108A' '115A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'046A'}
# Removed from Training/Validation Set:
# {'050A'}
# Moved to Test Set:
# {'050A'}
# Removed from Test Set
# {'046A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '004A' '005A' '008A' '009A'
#  '010A' '011A' '013B' '014A' '015A' '016A' '019A' '019B' '020A' '022A'
#  '023A' '023B' '025B' '025C' '027A' '029A' '032A' '034A' '035A' '036A'
#  '037A' '040A' '041A' '042A' '043A' '044A' '045A' '046A' '047A' '048A'
#  '051B' '052A' '053A' '054A' '055A' '056A' '057A' '058A' '059A' '060A'
#  '061A' '062A' '063A' '064A' '065A' '066A' '067A' '068A' '070A' '071A'
#  '072A' '073A' '074A' '075A' '088A' '091A' '092A' '093A' '094A' '095A'
#  '096A' '097B' '099A' '100A' '101A' '102A' '104A' '105A' '106A' '109A'
#  '110A' '111A' '113A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['006A' '007A' '012A' '014B' '018A' '021A' '024A' '025A' '026A' '026B'
#  '026C' '028A' '031A' '033A' '038A' '039A' '049A' '050A' '051A' '069A'
#  '076A' '087A' '090A' '097A' '103A' '108A' '115A']
# Length of X_train_val:
# 792
# Length of y_train_val:
# 792
# Length of groups_train_val:
# 792
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     485
# senior    150
# kitten     98
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     121
# kitten     78
# senior     36
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     485
# kitten    157
# senior    150
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     121
# senior     36
# kitten     19
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 485, 1: 157, 2: 150})
# Epoch 1/1500
# 13/13 [==============================] - 1s 5ms/step - loss: 1.1952 - accuracy: 0.5177
# Epoch 2/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.6446 - accuracy: 0.6907
# Epoch 3/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.4053 - accuracy: 0.7904
# Epoch 4/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3263 - accuracy: 0.8359
# Epoch 5/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2393 - accuracy: 0.8775
# Epoch 6/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1899 - accuracy: 0.9116
# Epoch 7/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.1678 - accuracy: 0.9104
# Epoch 8/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1280 - accuracy: 0.9394
# Epoch 9/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1209 - accuracy: 0.9520
# Epoch 10/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0959 - accuracy: 0.9583
# Epoch 11/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0905 - accuracy: 0.9545
# Epoch 12/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0765 - accuracy: 0.9634
# Epoch 13/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0645 - accuracy: 0.9747
# Epoch 14/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0527 - accuracy: 0.9773
# Epoch 15/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0621 - accuracy: 0.9697
# Epoch 16/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0548 - accuracy: 0.9697
# Epoch 17/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0397 - accuracy: 0.9861
# Epoch 18/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0467 - accuracy: 0.9760
# Epoch 19/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0622 - accuracy: 0.9747
# Epoch 20/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0402 - accuracy: 0.9760
# Epoch 21/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0375 - accuracy: 0.9836
# Epoch 22/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0416 - accuracy: 0.9811
# Epoch 23/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0288 - accuracy: 0.9874
# Epoch 24/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0196 - accuracy: 0.9962
# Epoch 25/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0235 - accuracy: 0.9886
# Epoch 26/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0191 - accuracy: 0.9937
# Epoch 27/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0220 - accuracy: 0.9912
# Epoch 28/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0137 - accuracy: 0.9962
# Epoch 29/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0246 - accuracy: 0.9924
# Epoch 30/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0387 - accuracy: 0.9811
# Epoch 31/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0191 - accuracy: 0.9962
# Epoch 32/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0328 - accuracy: 0.9886
# Epoch 33/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0262 - accuracy: 0.9886
# Epoch 34/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0134 - accuracy: 0.9962
# Epoch 35/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0288 - accuracy: 0.9924
# Epoch 36/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0202 - accuracy: 0.9924
# Epoch 37/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0243 - accuracy: 0.9924
# Epoch 38/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0238 - accuracy: 0.9848
# Epoch 39/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0163 - accuracy: 0.9886
# Epoch 40/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0103 - accuracy: 0.9949
# Epoch 41/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0136 - accuracy: 0.9949
# Epoch 42/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0224 - accuracy: 0.9886
# Epoch 43/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0174 - accuracy: 0.9899
# Epoch 44/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0138 - accuracy: 0.9937
# Epoch 45/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0087 - accuracy: 0.9962
# Epoch 46/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0049 - accuracy: 1.0000
# Epoch 47/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0080 - accuracy: 0.9975
# Epoch 48/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0150 - accuracy: 0.9962
# Epoch 49/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0091 - accuracy: 0.9975
# Epoch 50/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0120 - accuracy: 0.9949
# Epoch 51/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0069 - accuracy: 0.9987
# Epoch 52/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0098 - accuracy: 0.9975
# Epoch 53/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 54/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0078 - accuracy: 0.9962
# Epoch 55/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0108 - accuracy: 0.9975
# Epoch 56/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0067 - accuracy: 0.9987
# Epoch 57/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0091 - accuracy: 0.9987
# Epoch 58/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0127 - accuracy: 0.9975
# Epoch 59/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0055 - accuracy: 0.9975
# Epoch 60/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0133 - accuracy: 0.9962
# Epoch 61/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0077 - accuracy: 0.9962
# Epoch 62/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0191 - accuracy: 0.9924
# Epoch 63/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0097 - accuracy: 0.9975
# Epoch 64/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0044 - accuracy: 0.9975
# Epoch 65/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0064 - accuracy: 0.9962
# Epoch 66/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0074 - accuracy: 0.9962
# Epoch 67/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0115 - accuracy: 0.9949
# Epoch 68/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0153 - accuracy: 0.9937
# Epoch 69/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0061 - accuracy: 0.9987
# Epoch 70/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0243 - accuracy: 0.9861
# Epoch 71/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0041 - accuracy: 0.9987
# Epoch 72/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0030 - accuracy: 0.9987
# Epoch 73/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 74/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0038 - accuracy: 0.9975
# Epoch 75/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0113 - accuracy: 0.9949
# Epoch 76/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0055 - accuracy: 0.9975
# Epoch 77/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0057 - accuracy: 0.9975
# Epoch 78/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0079 - accuracy: 0.9975
# Epoch 79/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0040 - accuracy: 0.9987
# Epoch 80/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0061 - accuracy: 0.9975
# Epoch 81/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0073 - accuracy: 0.9975
# Epoch 82/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0142 - accuracy: 0.9937
# Epoch 83/1500
# 11/13 [========================>.....] - ETA: 0s - loss: 0.0361 - accuracy: 0.9830Restoring model weights from the end of the best epoch: 53.
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0334 - accuracy: 0.9848
# Epoch 83: early stopping
# 6/6 [==============================] - 0s 1ms/step - loss: 5.1508 - accuracy: 0.6534
# 6/6 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.81 (22/27)
# Before appending - Cat IDs: 701, Predictions: 701, Actuals: 701, Gender: 701
# After appending - Cat IDs: 877, Predictions: 877, Actuals: 877, Gender: 877
# Final Test Results - Loss: 5.1507978439331055, Accuracy: 0.6534090638160706, Precision: 0.5676470588235295, Recall: 0.5557569313550175, F1 Score: 0.5607699805068226
# Confusion Matrix:
#  [[91  5 25]
#  [ 8 10  1]
#  [20  2 14]]
#
# Final Average F1-Score across all UNSEEN TEST sets: 0.5513563290863556
#
# Final Average Loss across all UNSEEN TEST sets: 3.180499315261841
#
# Final Average Accuracy across all UNSEEN TEST sets: 0.644726037979126
#
# Final Average Precision across all UNSEEN TEST sets: 0.5646646499306213
#
# Final Average Recall across all UNSEEN TEST sets: 0.5625188995746511

# %%
seed_3_folds_values = [unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1]

seed_3_training_acc_values = cv_training_acc_total

# Plotting all fold metrics
seed_3_folds_plot = plot_all_metrics(unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1, "Folds", "Fold Number")

# %% [markdown]
# ## Majority Voting on Total Entries per cat_id

# %%
# Debugging print statements
print(f'Checking - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
# Out:
# Checking - Cat IDs: 877, Predictions: 877, Actuals: 877, Gender: 877

# %%
# Create results df
full_results = pd.DataFrame({
    'cat_id': all_cat_ids,
    'predicted_age_group': all_predicted_age_groups,
    'actual_age_group': all_actual_age_groups,
    'all_gender': all_gender
})

# create a correct majority prediction column
full_results['correct'] = full_results['predicted_age_group'] == full_results['actual_age_group']

# %%
# Group by cat_id and aggregate predicted age groups
majority_votes = full_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first()

# Calculate the accuracy of majority voting
correct_predictions = (majority_votes == actual_groups).sum()
total_cats = len(actual_groups)
majority_vote_accuracy = correct_predictions / total_cats

logger(f"Overall Majority Vote Accuracy for cat_id: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

# store for final evaluation 
all_majority_vote_accuracies.append(majority_vote_accuracy)
# Out:
# Overall Majority Vote Accuracy for cat_id: 0.80 (88/110)

# %%
# Detailed df with predictions, actual labels, and comparison including majority vote
detailed_results = full_results.groupby('cat_id').apply(
    lambda x: pd.Series({
        'Predictions': list(x['predicted_age_group']),
        'Majority Vote': x['predicted_age_group'].mode()[0],
        'Actual Age Group': x['actual_age_group'].iloc[0],
        'Correct Majority Vote': x['predicted_age_group'].mode()[0] == x['actual_age_group'].iloc[0]
    })
).reset_index()

# Convert to DataFrame for better formatting and display
detailed_results = pd.DataFrame(detailed_results)

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 10)
pd.set_option('display.width', 1000)

sorted_detailed_results = detailed_results.sort_values(by='Correct Majority Vote', ascending=False)

# Display the sorted DataFrame
sorted_detailed_results
# Out:
#     cat_id                                        Predictions Majority Vote Actual Age Group  Correct Majority Vote
# 0     000B  [adult, adult, senior, adult, adult, adult, ad...         adult            adult                   True
# 78    072A  [adult, adult, adult, senior, adult, senior, a...         adult            adult                   True
# 76    070A              [adult, senior, senior, adult, adult]         adult            adult                   True
# 75    069A                                    [senior, adult]         adult            adult                   True
# 74    068A  [adult, adult, adult, adult, senior, adult, ad...         adult            adult                   True
# 73    067A  [adult, kitten, adult, adult, kitten, adult, a...         adult            adult                   True
# 72    066A                                    [adult, kitten]         adult            adult                   True
# 71    065A  [adult, adult, adult, kitten, adult, adult, ad...         adult            adult                   True
# 70    064A                              [adult, adult, adult]         adult            adult                   True
# 68    062A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 65    059A  [senior, senior, senior, senior, adult, senior...        senior           senior                   True
# 60    054A                                   [senior, senior]        senior           senior                   True
# 59    053A  [adult, adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 58    052A                      [adult, senior, adult, adult]         adult            adult                   True
# 1     001A  [adult, adult, adult, adult, senior, adult, ad...         adult            adult                   True
# 54    049A                                           [kitten]        kitten           kitten                   True
# 53    048A                                           [kitten]        kitten           kitten                   True
# 51    045A  [kitten, kitten, kitten, kitten, kitten, kitte...        kitten           kitten                   True
# 50    044A             [kitten, adult, adult, kitten, kitten]        kitten           kitten                   True
# 49    043A                                           [kitten]        kitten           kitten                   True
# 48    042A  [kitten, adult, kitten, adult, adult, kitten, ...        kitten           kitten                   True
# 77    071A  [adult, senior, senior, adult, adult, senior, ...         adult            adult                   True
# 79    073A                                            [adult]         adult            adult                   True
# 46    040A  [kitten, adult, adult, kitten, kitten, kitten,...        kitten           kitten                   True
# 80    074A  [adult, kitten, adult, adult, kitten, adult, a...         adult            adult                   True
# 107   115A                                           [kitten]        kitten           kitten                   True
# 106   113A                           [senior, senior, senior]        senior           senior                   True
# 105   111A  [adult, kitten, kitten, kitten, kitten, kitten...        kitten           kitten                   True
# 104   110A                                           [kitten]        kitten           kitten                   True
# 100   105A                      [adult, adult, adult, kitten]         adult            adult                   True
# 98    103A  [adult, adult, kitten, adult, adult, senior, a...         adult            adult                   True
# 97    102A                                     [adult, adult]         adult            adult                   True
# 96    101A  [senior, senior, adult, adult, senior, senior,...         adult            adult                   True
# 94    099A  [adult, adult, adult, kitten, senior, adult, k...         adult            adult                   True
# 93    097B  [adult, adult, kitten, adult, kitten, adult, k...         adult            adult                   True
# 91    096A                                            [adult]         adult            adult                   True
# 90    095A  [senior, adult, adult, senior, adult, adult, a...         adult            adult                   True
# 89    094A  [kitten, senior, senior, senior, adult, senior...        senior           senior                   True
# 87    092A                                            [adult]         adult            adult                   True
# 86    091A                                            [adult]         adult            adult                   True
# 85    090A                                           [senior]        senior           senior                   True
# 84    088A                                            [adult]         adult            adult                   True
# 83    087A                
  False

# %%
# Create df for majority votes
majority_df = majority_votes.reset_index()
majority_df.columns = ['cat_id', 'Majority_Vote']

# Get actual groups for each cat_id
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first().reset_index()

# Merge majority votes with actual groups
majority_with_actual = pd.merge(majority_df, actual_groups, on='cat_id')

# Add a column to check if the majority vote was correct
majority_with_actual['Majority_Correct'] = majority_with_actual['Majority_Vote'] == majority_with_actual['actual_age_group']

# Count correct majority votes per class
correct_majority_votes_per_class = majority_with_actual.groupby('actual_age_group')['Majority_Correct'].sum()

print("Correct Majority Votes per Class:")
print(correct_majority_votes_per_class)
# Out:
# Correct Majority Votes per Class:
# actual_age_group
# adult     69
# kitten    11
# senior     8
# Name: Majority_Correct, dtype: int64

# %%
# Calculate the total count and the number of correct predictions for each class
class_stats = majority_with_actual.groupby('actual_age_group').agg(
    total_count=('Majority_Correct', 'size'),  # Total number of cases per class
    correct_count=('Majority_Correct', 'sum')  # Sum of correct predictions per class
).reset_index()

# Calculate accuracy for each class
class_stats['accuracy'] = class_stats['correct_count'] / class_stats['total_count'] * 100

# store for final evaluation 
all_majority_vote_details.append(class_stats)

# Log detailed stats
print("Detailed Class Statistics for Majority Votes:")
print(class_stats)
# Out:
# Detailed Class Statistics for Majority Votes:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult           73             69  94.520548
# 1           kitten           15             11  73.333333
# 2           senior           22              8  36.363636

# %%
# Plot for Detailed Class Statistics for Majority Votes
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Accuracy of Majority Votes by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Detailed Class Statistics

# %%
# Calculate the total count and the number of correct predictions for each class
class_stats = full_results.groupby('actual_age_group').agg(
    total_count=('correct', 'size'),
    correct_count=('correct', 'sum')
).reset_index()

# Calculate accuracy for each class
class_stats['accuracy'] = class_stats['correct_count'] / class_stats['total_count'] * 100

# store for final evaluation 
all_class_stats.append(class_stats)

# Log the detailed stats
print("Detailed Class Statistics:")
print(class_stats)
# Out:
# Detailed Class Statistics:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult          574            434  75.609756
# 1           kitten          117             61  52.136752
# 2           senior          186             69  37.096774

# %%
# Plot for Detailed Class Statistics (Overall)
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Overall Accuracy by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Gender Exploration

# %%
# Group by gender and calculate the total count, correct predictions, and accuracy
gender_stats = full_results.groupby('all_gender').agg(
    count=('cat_id', 'size'),  # Total number of cases per gender
    correct=('correct', 'sum')  # Sum of correct predictions per gender
).reset_index()

# Calculate accuracy for each gender
gender_stats['accuracy'] = (gender_stats['correct'] / gender_stats['count'] * 100).round(2)

# Display the DataFrame
print("Accuracy by Gender:")
print(gender_stats)

# store for final evaluation 
all_gender_stats.append(gender_stats)
# Out:
# Accuracy by Gender:
#   all_gender  count  correct  accuracy
# 0          F    225      140     62.22
# 1          M    356      264     74.16
# 2          X    296      160     54.05

# %%
# Plot for Accuracy by Gender
styled_barplot(gender_stats, 'all_gender', 'accuracy', 
               'Accuracy by Gender', 
               'Gender', 'Accuracy (%)')

# %% [markdown]
# ### Log current total CV Stats

# %%
print("Total Majority Vote Accuracy so far:", all_majority_vote_accuracies)
print("Total Class Statistics so far:\n", all_class_stats)
print("Total Gender Accuracy so far:\n", all_gender_stats)
# Out:
# Total Majority Vote Accuracy so far: [0.7909090909090909, 0.7545454545454545, 0.8]
# Total Class Statistics so far:
#  [  actual_age_group  total_count  correct_count   accuracy
# 0            adult          573            448  78.184991
# 1           kitten          111             59  53.153153
# 2           senior          186             71  38.172043,   actual_age_group  total_count  correct_count   accuracy
# 0            adult          568            415  73.063380
# 1           kitten          120             62  51.666667
# 2           senior          186             58  31.182796,   actual_age_group  total_count  correct_count   accuracy
# 0            adult          574            434  75.609756
# 1           kitten          117             61  52.136752
# 2           senior          186             69  37.096774]
# Total Gender Accuracy so far:
#  [  all_gender  count  correct  accuracy
# 0          F    218      144     66.06
# 1          M    362      266     73.48
# 2          X    290      168     57.93,   all_gender  count  correct  accuracy
# 0          F    218      126     57.80
# 1          M    357      247     69.19
# 2          X    299      162     54.18,   all_gender  count  correct  accuracy
# 0          F    225      140     62.22
# 1          M    356      264     74.16
# 2          X    296      160     54.05]

# %% [markdown]
# # RANDOM SEED 4

# %%
# Set a fixed random seed for reproducibility
random.seed(int(random_seeds[3])) 
np.random.seed(int(random_seeds[3]))
tf.random.set_seed(int(random_seeds[3]))

# Load datasets
dataframe = pd.read_csv('/Users/astrid/PycharmProjects/data-aug-and-more/yamnet-tfhub-extraction/yamnet_embeddings_looped_april_23.csv')

def assign_age_group(age, age_groups):
    for group_name, age_range in age_groups.items():
        if age_range[0] <= age < age_range[1]:
            return group_name
    return 'Unknown'  # For any age that doesn't fit the defined groups

# Define age groups
age_groups = {
    'kitten': (0, 0.5),
    'adult': (0.5, 12),
    'senior': (12, 20)
}

# Create a new column for the age group
dataframe['age_group'] = dataframe['target'].apply(assign_age_group, age_groups=age_groups)

print(dataframe['age_group'].value_counts())
# Out:
# adult     606
# senior    186
# kitten    176
# Name: age_group, dtype: int64

# %%
# Separate features and labels
X = dataframe.iloc[:, :-4].values  # all columns except the last four

# Encode the 'age_group' column as integers using LabelEncoder
label_encoder = LabelEncoder()
encoded_y = label_encoder.fit_transform(dataframe['age_group'].values)

# Use the encoded labels for splitting and one-hot encoding
y = encoded_y  

# Convert 'cat_id' column to numpy array to be used as groups array for GroupKFold
groups = dataframe['cat_id'].values

# %%
tf.keras.backend.clear_session()

# %% [markdown]
# ## Run Setup

# %%
all_cat_ids = []
all_predicted_age_groups = []
all_actual_age_groups = []
all_gender = []

# Define the StratifiedGroupKFold splitter for 4 fold CV with random shuffling
outer_cv = StratifiedGroupKFold(n_splits=4, shuffle=True, random_state=int(random_seeds[3]))

# unseen test set metrics
unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1 = [], [], [], [], []

cv_training_acc_total = []
cv_training_acc_best = []

outer_fold = 0


# Use the splitter to generate indices for training and testing sets
# Note: GroupShuffleSplit.split returns indices, so we use it to index the arrays
for train_val_idx, test_idx in outer_cv.split(X, y, groups):
    outer_fold += 1
    logger(f"outer_fold {outer_fold}", file=log_file_path)

    # Convert indices back to DataFrame for easy manipulation
    df_train_val = dataframe.iloc[train_val_idx]
    df_test = dataframe.iloc[test_idx]

    ##############################
    # ASSESSING SPLITS BY CAT_ID #
    ##############################
    
    # Get the distribution of groups
    training_validation_group_distribution = df_train_val['cat_id'].value_counts()  
    testing_group_distribution = df_test['cat_id'].value_counts()  
    
    # Log or print the distribution
    logger(f"Train Set Group Distribution:\n{training_validation_group_distribution}", file=log_file_path)
    logger(f"Testing Set Group Distribution:\n{testing_group_distribution}", file=log_file_path)

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val['gender'].value_counts()
    testing_gender_distribution = df_test['gender'].value_counts()
    
    # Log the distribution
    logger(f"Training Set Gender Distribution BEFORE SWAP:\n{training_gender_distribution}", file=log_file_path)
    logger(f"Testing Set Gender Distribution BEFORE SWAP:\n{testing_gender_distribution}", file=log_file_path)

    # Group by 'age_group' and then list unique 'cat_id' within each age group
    unique_cat_ids_per_age_group_train_val = df_train_val.groupby('age_group')['cat_id'].unique()
    unique_cat_ids_per_age_group_test = df_test.groupby('age_group')['cat_id'].unique()
    
    # Log results
    logger(f"Unique Cat IDs per Age Group in Training/Validation Set:\n{unique_cat_ids_per_age_group_train_val}", file=log_file_path)
    logger(f"Unique Cat IDs per Age Group in Testing Set:\n{unique_cat_ids_per_age_group_test}", file=log_file_path)

    # Calculate the count of unique identifiers per age group for training and testing set
    counts_train_val = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_train_val.items()}
    counts_test = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_test.items()}

    # Log the counts of unique identifiers per age group
    logger(f"Count of Unique Cat IDs per Age Group in Training/Validation Set:\n{counts_train_val}", file=log_file_path)
    logger(f"Count of Unique Cat IDs per Age Group in Testing Set:\n{counts_test}", file=log_file_path)

    #######################################################
    # CONTINUE WITH ENSURING VALID AND APPROPRIATE SPLITS #
    #######################################################
    
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    groups_train_val, groups_test = groups[train_val_idx], groups[test_idx]

    # logging identifier splits 
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)

    # check group splits
    check_initial_group_split(groups_train_val, groups_test)

    # Specify the cat_ids that must be in the training/validation set
    specific_cat_ids = ['000A', '046A']
    
    # Perform the swapping operation
    train_val_idx, test_idx = swap_cat_id_instances(dataframe, train_val_idx, test_idx, specific_cat_ids)
    
    # Re-assign the sets based on the updated indices
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    new_groups_train_val, new_groups_test = groups[train_val_idx], groups[test_idx]

    # Find differences for training and test sets
    moved_to_train_val, removed_from_train_val = find_group_differences(groups_train_val, new_groups_train_val)
    moved_to_test, removed_from_test = find_group_differences(groups_test, new_groups_test)
    
    # Display the results
    logger(f"Moved to Training/Validation Set:\n{moved_to_train_val}", file=log_file_path)
    logger(f"Removed from Training/Validation Set:\n{removed_from_train_val}", file=log_file_path)
    logger(f"Moved to Test Set:\n{moved_to_test}", file=log_file_path)
    logger(f"Removed from Test Set\n{removed_from_test}", file=log_file_path)

    # Update X_train_val, X_test, y_train_val, y_test, groups_train_val, groups_test based on updated indices
    X_train_val = X[train_val_idx]
    y_train_val = y[train_val_idx]
    groups_train_val = groups[train_val_idx]
    
    X_test = X[test_idx]
    y_test = y[test_idx]
    groups_test = groups[test_idx]

    # logging identifier splits again after potential swaps
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"AFTER SWAP - Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"AFTER SWAP - Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)
    
    # Verify the lengths are consistent
    logger(f"Length of X_train_val:\n{len(X_train_val)}", file=log_file_path)
    logger(f"Length of y_train_val:\n{len(y_train_val)}", file=log_file_path)
    logger(f"Length of groups_train_val:\n{len(groups_train_val)}", file=log_file_path)

    # Check group splits once more
    check_initial_group_split(groups_train_val, groups_test)

    # Convert the modified indices back to a DataFrame representing the updated df_train_val
    df_train_val_updated = dataframe.iloc[train_val_idx].copy()
    df_test_updated = dataframe.iloc[test_idx].copy()

    ############################
    # LOGGING AGE GROUP SPLITS #
    ############################

    # Get the distribution of age groups of age groups before the update
    training_validation_age_group_distribution = df_train_val['age_group'].value_counts()
    testing_age_group_distribution = df_test['age_group'].value_counts()
    
    # Logthe distribution
    logger(f"Train Age Group Distribution BEFORE SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution BEFORE SWAP:\n{testing_age_group_distribution}", file=log_file_path)

    # Get the distribution of age groups after the update
    training_validation_age_group_distribution = df_train_val_updated['age_group'].value_counts()
    testing_age_group_distribution = df_test_updated['age_group'].value_counts()
    
    # Log the distribution
    logger(f"Train Age Group Distribution AFTER SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution AFTER SWAP:\n{testing_age_group_distribution}", file=log_file_path)
    
    ########################################################
    # TRACKING FINAL CAT_IDs & GENDER AFTER REDISTRIBUTION #
    ########################################################

    # Get the distribution of groups
    training_validation_group_distribution = df_train_val_updated['cat_id'].value_counts()  
    testing_group_distribution = df_test_updated['cat_id'].value_counts()  

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val_updated['gender'].value_counts()
    testing_gender_distribution = df_test_updated['gender'].value_counts()
    
    logger(f"\n Starting training on unseen test set\n", file=log_file_path)

    ###################
    # PREPARING MODEL #
    ###################

    # Calculate the distribution of age groups in y_train_val
    age_group_distribution = Counter(y_train_val)
    print("Age group distribution:", age_group_distribution)

    # EarlyStopping callback: monitor 'loss' instead of 'val_loss' for the test set
    early_stopping = EarlyStopping(
        monitor='loss',  
        min_delta=0.001, 
        patience=30,  
        verbose=1,  
        restore_best_weights=True  
    )

    accuracy_history = AccuracyHistory()

    # One final shuffle to ensure randomness
    outer_shuffle_idx = np.random.permutation(len(X_train_val))
    X_train_val = X_train_val[outer_shuffle_idx]
    y_train_val = y_train_val[outer_shuffle_idx]

    class_weights = compute_class_weight(
        class_weight='balanced',
        classes=np.unique(y_train_val),
        y=y_train_val
    )
    weight_dict = {i: class_weights[i] for i in range(len(class_weights))}
    
    # Scale the features
    scaler_full = StandardScaler().fit(X_train_val)
    X_train_full_scaled = scaler_full.transform(X_train_val)
    X_test_scaled = scaler_full.transform(X_test)
    
    # Encode the labels
    y_train_full_encoded = to_categorical(y_train_val)
    y_test_encoded = to_categorical(y_test)

    #######################
    # BUILD & TRAIN MODEL #
    #######################

    optimizers = {
        'Adamax': Adamax(learning_rate=0.00510251984616472)
    }
    
    # Model definition with dynamic number of layers
    model_full = Sequential()
    model_full.add(Dense(480, activation='relu', input_shape=(X_train_full_scaled.shape[1],)))
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.2011047009431978))  
    model_full.add(Dense(256, activation='relu',)) 
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.14956886311951184))  
    model_full.add(Dense(256, activation='relu'))  
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.42291461228250665))  
    model_full.add(Dense(3, activation='softmax'))  
    
    # Use the optimizer from the parameters
    optimizer = optimizers['Adamax']  # optimizer_key from parameters
    
    # Compile the model
    model_full.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    
    # Train the model on the full training set
    history_full = model_full.fit(X_train_full_scaled, y_train_full_encoded, epochs=1500, batch_size=64,
                                  verbose=1, callbacks=[early_stopping, accuracy_history], class_weight=weight_dict)
    
    # log epochs
    best_epoch_index = np.argmin(history_full.history['loss'])  
    best_training_accuracy = accuracy_history.acc[best_epoch_index]
    # Append training acc to total  
    all_best_training_acc.append(best_training_accuracy)
    total_training_acc.append(accuracy_history.acc)
    # Append training acc just for this CV
    cv_training_acc_total.append(accuracy_history.acc)
    cv_training_acc_best.append(best_training_accuracy)
    
    # Evaluate the model on the held-out test set
    test_loss, test_accuracy = model_full.evaluate(X_test_scaled, y_test_encoded)

    y_test_pred_prob = model_full.predict(X_test_scaled)
    y_test_pred = np.argmax(y_test_pred_prob, axis=1)  
    y_test_true = np.argmax(y_test_encoded, axis=1)    

    ################################
    # LOG MAJORITY VOTE PER CAT_ID #
    ################################

    # Convert numeric predictions back to age group labels
    predicted_age_groups = label_encoder.inverse_transform(y_test_pred)
    actual_labels = label_encoder.inverse_transform(y_test_true)
    
    # Map predictions and actual labels back to cat_ids
    test_results = pd.DataFrame({
        'cat_id': df_test_updated['cat_id'],
        'predicted_age_group': predicted_age_groups,
        'actual_age_group': actual_labels
    })
    
    # Group by cat_id and aggregate predicted age groups
    majority_votes = test_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
    actual_groups = test_results.groupby('cat_id')['actual_age_group'].first()
    
    # Calculate the accuracy of majority voting
    correct_predictions = (majority_votes == actual_groups).sum()
    total_cats = len(actual_groups)
    majority_vote_accuracy = correct_predictions / total_cats
    
    # Log the accuracy of the majority voting
    logger(f"Majority Vote Accuracy for cat_id for this fold: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

    ####################################################
    # COLLECT PREDICTIONS FOR GENDER & CAT_ID ANALYSIS #
    ####################################################

    # Debugging print statements
    print(f'Before appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Extend lists with current fold results
    all_cat_ids.extend(df_test_updated['cat_id'].tolist())
    all_predicted_age_groups.extend(predicted_age_groups)
    all_actual_age_groups.extend(actual_labels)
    all_gender.extend(df_test_updated['gender'].tolist())

    # Debugging print statements
    print(f'After appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Calculate additional metrics
    test_precision = precision_score(y_test_true, y_test_pred, average='macro')  # Use 'macro' for imbalanced datasets
    test_recall = recall_score(y_test_true, y_test_pred, average='macro')
    test_f1 = f1_score(y_test_true, y_test_pred, average='macro')

    # prepare averages of outer metrics
    unseen_f1.append(test_f1)
    unseen_losses.append(test_loss)
    unseen_accuracies.append(test_accuracy)
    unseen_precisions.append(test_precision)
    unseen_recalls.append(test_recall)

    # Print final test results
    logger(f"Final Test Results - Loss: {test_loss}, Accuracy: {test_accuracy}, Precision: {test_precision}, Recall: {test_recall}, F1 Score: {test_f1}", file=log_file_path)

    # Generate the confusion matrix
    cm = confusion_matrix(y_test, y_test_pred)
    logger(f"Confusion Matrix:\n {cm}", file=log_file_path)

# Calculate the overall average metrics
unseen_set_avg_f1 = np.mean(unseen_f1)
unseen_set_avg_loss = np.mean(unseen_losses)
unseen_set_avg_acc = np.mean(unseen_accuracies)
unseen_set_avg_precision = np.mean(unseen_precisions)
unseen_set_avg_recall = np.mean(unseen_recalls)

logger(f"\nFinal Average F1-Score across all UNSEEN TEST sets: {unseen_set_avg_f1}", file=log_file_path)
logger(f"\nFinal Average Loss across all UNSEEN TEST sets: {unseen_set_avg_loss}", file=log_file_path)
logger(f"\nFinal Average Accuracy across all UNSEEN TEST sets: {unseen_set_avg_acc}", file=log_file_path)
logger(f"\nFinal Average Precision across all UNSEEN TEST sets: {unseen_set_avg_precision}", file=log_file_path)
logger(f"\nFinal Average Recall across all UNSEEN TEST sets: {unseen_set_avg_recall}\n", file=log_file_path)

# Append averages to total lists
average_fold_f1.append(unseen_set_avg_f1)
average_fold_losses.append(unseen_set_avg_loss)
average_fold_accuracies.append(unseen_set_avg_acc)
average_fold_precisions.append(unseen_set_avg_precision)
average_fold_recalls.append(unseen_set_avg_recall)

# Append all to total lists
all_f1.append(unseen_f1)
all_losses.append(unseen_losses)
all_accuracies.append(unseen_accuracies)
all_precisions.append(unseen_precisions)
all_recalls.append(unseen_recalls)
# Out:
# outer_fold 1
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Train Set Group Distribution:
# 046A    66
# 000A    39
# 002B    36
# 103A    33
# 047A    30
# 057A    28
# 074A    25
# 020A    23
# 067A    20
# 059A    18
# 019A    17
# 029A    17
# 101A    16
# 097A    16
# 106A    15
# 001A    15
# 042A    14
# 097B    14
# 111A    13
# 002A    13
# 116A    12
# 039A    12
# 051A    12
# 005A    11
# 016A    11
# 025A    11
# 068A    11
# 063A    11
# 014B    10
# 040A    10
# 015A    10
# 065A     9
# 022A     9
# 045A     9
# 051B     9
# 072A     9
# 013B     8
# 095A     8
# 027A     7
# 050A     7
# 053A     7
# 023A     6
# 008A     6
# 037A     6
# 025C     6
# 109A     6
# 007A     6
# 021A     6
# 034A     5
# 070A     5
# 012A     5
# 062A     5
# 023B     5
# 075A     5
# 105A     4
# 052A     4
# 035A     4
# 104A     4
# 026A     4
# 003A     4
# 014A     3
# 060A     3
# 056A     3
# 064A     3
# 058A     3
# 006A     3
# 038A     2
# 032A     2
# 054A     2
# 087A     2
# 093A     2
# 102A     2
# 018A     2
# 069A     2
# 025B     2
# 110A     1
# 004A     1
# 115A     1
# 041A     1
# 092A     1
# 019B     1
# 049A     1
# 090A     1
# 026C     1
# 073A     1
# 091A     1
# 100A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 000B    20
# 055A    20
# 028A    14
# 036A    11
# 071A    10
# 033A     9
# 094A     8
# 010A     8
# 031A     7
# 117A     7
# 099A     7
# 108A     6
# 044A     5
# 009A     4
# 113A     3
# 011A     3
# 061A     2
# 066A     2
# 076A     1
# 048A     1
# 088A     1
# 096A     1
# 043A     1
# 024A     1
# 026B     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    326
# M    323
# F    166
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# F    91
# M    33
# X    29
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [002A, 070A, 020A, 000A, 015A, 026A, 065A, 053...
# kitten    [046A, 042A, 014B, 110A, 109A, 040A, 047A, 049...
# senior    [106A, 057A, 090A, 051B, 116A, 051A, 097A, 059...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [028A, 033A, 000B, 071A, 009A, 010A, 031A, 036...
# kitten                                   [048A, 044A, 043A]
# senior     [117A, 113A, 024A, 094A, 055A, 108A, 061A, 011A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 60, 'kitten': 13, 'senior': 14}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 14, 'kitten': 3, 'senior': 8}
# Unique Training/Validation Group IDs:
# ['000A' '001A' '002A' '002B' '003A' '004A' '005A' '006A' '007A' '008A'
#  '012A' '013B' '014A' '014B' '015A' '016A' '018A' '019A' '019B' '020A'
#  '021A' '022A' '023A' '023B' '025A' '025B' '025C' '026A' '026C' '027A'
#  '029A' '032A' '034A' '035A' '037A' '038A' '039A' '040A' '041A' '042A'
#  '045A' '046A' '047A' '049A' '050A' '051A' '051B' '052A' '053A' '054A'
#  '056A' '057A' '058A' '059A' '060A' '062A' '063A' '064A' '065A' '067A'
#  '068A' '069A' '070A' '072A' '073A' '074A' '075A' '087A' '090A' '091A'
#  '092A' '093A' '095A' '097A' '097B' '100A' '101A' '102A' '103A' '104A'
#  '105A' '106A' '109A' '110A' '111A' '115A' '116A']
# Unique Test Group IDs:
# ['000B' '009A' '010A' '011A' '024A' '026B' '028A' '031A' '033A' '036A'
#  '043A' '044A' '048A' '055A' '061A' '066A' '071A' '076A' '088A' '094A'
#  '096A' '099A' '108A' '113A' '117A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '001A' '002A' '002B' '003A' '004A' '005A' '006A' '007A' '008A'
#  '012A' '013B' '014A' '014B' '015A' '016A' '018A' '019A' '019B' '020A'
#  '021A' '022A' '023A' '023B' '025A' '025B' '025C' '026A' '026C' '027A'
#  '029A' '032A' '034A' '035A' '037A' '038A' '039A' '040A' '041A' '042A'
#  '045A' '046A' '047A' '049A' '050A' '051A' '051B' '052A' '053A' '054A'
#  '056A' '057A' '058A' '059A' '060A' '062A' '063A' '064A' '065A' '067A'
#  '068A' '069A' '070A' '072A' '073A' '074A' '075A' '087A' '090A' '091A'
#  '092A' '093A' '095A' '097A' '097B' '100A' '101A' '102A' '103A' '104A'
#  '105A' '106A' '109A' '110A' '111A' '115A' '116A']
# AFTER SWAP - Unique Test Group IDs:
# ['000B' '009A' '010A' '011A' '024A' '026B' '028A' '031A' '033A' '036A'
#  '043A' '044A' '048A' '055A' '061A' '066A' '071A' '076A' '088A' '094A'
#  '096A' '099A' '108A' '113A' '117A']
# Length of X_train_val:
# 815
# Length of y_train_val:
# 815
# Length of groups_train_val:
# 815
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     510
# kitten    169
# senior    136
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     96
# senior    50
# kitten     7
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     510
# kitten    169
# senior    136
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     96
# senior    50
# kitten     7
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 510, 1: 169, 2: 136})
# Epoch 1/1500
# 13/13 [==============================] - 1s 5ms/step - loss: 1.2218 - accuracy: 0.5067
# Epoch 2/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.6820 - accuracy: 0.6761
# Epoch 3/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.4104 - accuracy: 0.7767
# Epoch 4/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3121 - accuracy: 0.8270
# Epoch 5/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2168 - accuracy: 0.8748
# Epoch 6/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.1751 - accuracy: 0.9153
# Epoch 7/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.1691 - accuracy: 0.9239
# Epoch 8/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1401 - accuracy: 0.9374
# Epoch 9/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1092 - accuracy: 0.9423
# Epoch 10/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0869 - accuracy: 0.9583
# Epoch 11/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1012 - accuracy: 0.9509
# Epoch 12/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0882 - accuracy: 0.9546
# Epoch 13/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0668 - accuracy: 0.9681
# Epoch 14/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0568 - accuracy: 0.9779
# Epoch 15/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0509 - accuracy: 0.9742
# Epoch 16/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0349 - accuracy: 0.9853
# Epoch 17/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0494 - accuracy: 0.9804
# Epoch 18/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0338 - accuracy: 0.9840
# Epoch 19/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0354 - accuracy: 0.9902
# Epoch 20/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0456 - accuracy: 0.9804
# Epoch 21/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0278 - accuracy: 0.9853
# Epoch 22/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0284 - accuracy: 0.9890
# Epoch 23/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0215 - accuracy: 0.9914
# Epoch 24/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0301 - accuracy: 0.9840
# Epoch 25/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0294 - accuracy: 0.9902
# Epoch 26/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0276 - accuracy: 0.9890
# Epoch 27/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0249 - accuracy: 0.9902
# Epoch 28/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0302 - accuracy: 0.9865
# Epoch 29/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0321 - accuracy: 0.9828
# Epoch 30/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0318 - accuracy: 0.9877
# Epoch 31/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0313 - accuracy: 0.9804
# Epoch 32/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0122 - accuracy: 0.9951
# Epoch 33/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0171 - accuracy: 0.9939
# Epoch 34/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0107 - accuracy: 0.9963
# Epoch 35/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0227 - accuracy: 0.9902
# Epoch 36/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0235 - accuracy: 0.9926
# Epoch 37/1500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0330 - accuracy: 0.9840
# Epoch 38/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0272 - accuracy: 0.9939
# Epoch 39/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0300 - accuracy: 0.9926
# Epoch 40/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0273 - accuracy: 0.9890
# Epoch 41/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0246 - accuracy: 0.9902
# Epoch 42/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0138 - accuracy: 0.9939
# Epoch 43/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0148 - accuracy: 0.9951
# Epoch 44/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0206 - accuracy: 0.9890
# Epoch 45/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0097 - accuracy: 0.9926
# Epoch 46/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0097 - accuracy: 0.9975
# Epoch 47/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0198 - accuracy: 0.9914
# Epoch 48/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0087 - accuracy: 0.9975
# Epoch 49/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0076 - accuracy: 0.9975
# Epoch 50/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0195 - accuracy: 0.9914
# Epoch 51/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0085 - accuracy: 0.9975
# Epoch 52/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0106 - accuracy: 0.9975
# Epoch 53/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0051 - accuracy: 0.9988
# Epoch 54/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0089 - accuracy: 0.9939
# Epoch 55/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0173 - accuracy: 0.9963
# Epoch 56/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0043 - accuracy: 0.9963
# Epoch 57/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0062 - accuracy: 0.9988
# Epoch 58/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0042 - accuracy: 0.9988
# Epoch 59/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 60/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0082 - accuracy: 0.9975
# Epoch 61/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0078 - accuracy: 0.9963
# Epoch 62/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0102 - accuracy: 0.9939
# Epoch 63/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0095 - accuracy: 0.9963
# Epoch 64/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0039 - accuracy: 0.9975
# Epoch 65/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0097 - accuracy: 0.9988
# Epoch 66/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0079 - accuracy: 0.9951
# Epoch 67/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0119 - accuracy: 0.9963
# Epoch 68/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0088 - accuracy: 0.9926
# Epoch 69/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0143 - accuracy: 0.9939
# Epoch 70/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0123 - accuracy: 0.9926
# Epoch 71/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0074 - accuracy: 0.9963
# Epoch 72/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0120 - accuracy: 0.9951
# Epoch 73/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0072 - accuracy: 0.9988
# Epoch 74/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0067 - accuracy: 0.9951
# Epoch 75/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0073 - accuracy: 0.9963
# Epoch 76/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0043 - accuracy: 1.0000
# Epoch 77/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0069 - accuracy: 0.9988
# Epoch 78/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0175 - accuracy: 0.9939
# Epoch 79/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0063 - accuracy: 0.9975
# Epoch 80/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0076 - accuracy: 0.9951
# Epoch 81/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0031 - accuracy: 0.9988
# Epoch 82/1500
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0043 - accuracy: 0.9988
# Epoch 83/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0020 - accuracy: 0.9988
# Epoch 84/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0075 - accuracy: 0.9963
# Epoch 85/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0054 - accuracy: 0.9975
# Epoch 86/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0018 - accuracy: 0.9988
# Epoch 87/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0032 - accuracy: 0.9988
# Epoch 88/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0063 - accuracy: 0.9963
# Epoch 89/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 90/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0258 - accuracy: 0.9939
# Epoch 91/1500
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0044 - accuracy: 0.9988
# Epoch 92/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0082 - accuracy: 0.9988
# Epoch 93/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0096 - accuracy: 0.9963
# Epoch 94/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0141 - accuracy: 0.9951
# Epoch 95/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 96/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 97/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0053 - accuracy: 0.9988
# Epoch 98/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 99/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0022 - accuracy: 0.9988
# Epoch 100/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0035 - accuracy: 0.9988
# Epoch 101/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 102/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0065 - accuracy: 0.9963
# Epoch 103/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 104/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0032 - accuracy: 0.9988
# Epoch 105/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0066 - accuracy: 0.9963
# Epoch 106/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 107/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 108/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0038 - accuracy: 0.9988
# Epoch 109/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 110/1500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 111/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0031 - accuracy: 0.9975
# Epoch 112/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0020 - accuracy: 0.9988
# Epoch 113/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0103 - accuracy: 0.9963
# Epoch 114/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0107 - accuracy: 0.9975
# Epoch 115/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0038 - accuracy: 0.9975
# Epoch 116/1500
# 12/13 [==========================>...] - ETA: 0s - loss: 0.0023 - accuracy: 1.0000    Restoring model weights from the end of the best epoch: 86.
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 116: early stopping
# 5/5 [==============================] - 0s 1ms/step - loss: 2.6866 - accuracy: 0.6601
# 5/5 [==============================] - 0s 1ms/step
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Majority Vote Accuracy for cat_id for this fold: 0.68 (17/25)
# Before appending - Cat IDs: 0, Predictions: 0, Actuals: 0, Gender: 0
# After appending - Cat IDs: 153, Predictions: 153, Actuals: 153, Gender: 153
# Final Test Results - Loss: 2.686643123626709, Accuracy: 0.6601307392120361, Precision: 0.5930110901862314, Recall: 0.5783928571428572, F1 Score: 0.5686423649040472
# Confusion Matrix:
#  [[81  4 11]
#  [ 3  4  0]
#  [34  0 16]]
# outer_fold 2
# Train Set Group Distribution:
# 046A    66
# 000A    39
# 002B    36
# 103A    33
# 047A    30
# 074A    25
# 020A    23
# 000B    20
# 055A    20
# 059A    18
# 019A    17
# 101A    16
# 106A    15
# 001A    15
# 028A    14
# 111A    13
# 116A    12
# 051A    12
# 039A    12
# 016A    11
# 036A    11
# 005A    11
# 071A    10
# 040A    10
# 065A     9
# 072A     9
# 033A     9
# 095A     8
# 010A     8
# 094A     8
# 050A     7
# 099A     7
# 027A     7
# 031A     7
# 053A     7
# 117A     7
# 021A     6
# 008A     6
# 025C     6
# 108A     6
# 007A     6
# 037A     6
# 023A     6
# 075A     5
# 012A     5
# 034A     5
# 070A     5
# 044A     5
# 035A     4
# 009A     4
# 026A     4
# 003A     4
# 104A     4
# 105A     4
# 052A     4
# 014A     3
# 064A     3
# 056A     3
# 058A     3
# 011A     3
# 113A     3
# 087A     2
# 066A     2
# 069A     2
# 061A     2
# 018A     2
# 032A     2
# 026B     1
# 115A     1
# 076A     1
# 024A     1
# 096A     1
# 026C     1
# 073A     1
# 088A     1
# 091A     1
# 043A     1
# 110A     1
# 048A     1
# 092A     1
# 090A     1
# 100A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 057A    28
# 067A    20
# 029A    17
# 097A    16
# 042A    14
# 097B    14
# 002A    13
# 025A    11
# 063A    11
# 068A    11
# 015A    10
# 014B    10
# 045A     9
# 051B     9
# 022A     9
# 013B     8
# 109A     6
# 062A     5
# 023B     5
# 006A     3
# 060A     3
# 038A     2
# 102A     2
# 054A     2
# 025B     2
# 093A     2
# 049A     1
# 019B     1
# 041A     1
# 004A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    290
# X    224
# F    208
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    131
# M     66
# F     49
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [028A, 070A, 033A, 000B, 071A, 020A, 000A, 026...
# kitten    [046A, 110A, 040A, 047A, 048A, 111A, 044A, 043...
# senior    [117A, 106A, 090A, 113A, 116A, 051A, 024A, 094...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [002A, 015A, 023B, 038A, 068A, 013B, 062A, 006...
# kitten                 [042A, 014B, 109A, 049A, 045A, 041A]
# senior                       [057A, 051B, 097A, 054A, 093A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 55, 'kitten': 10, 'senior': 17}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 19, 'kitten': 6, 'senior': 5}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002B' '003A' '005A' '007A' '008A' '009A' '010A'
#  '011A' '012A' '014A' '016A' '018A' '019A' '020A' '021A' '023A' '024A'
#  '025C' '026A' '026B' '026C' '027A' '028A' '031A' '032A' '033A' '034A'
#  '035A' '036A' '037A' '039A' '040A' '043A' '044A' '046A' '047A' '048A'
#  '050A' '051A' '052A' '053A' '055A' '056A' '058A' '059A' '061A' '064A'
#  '065A' '066A' '069A' '070A' '071A' '072A' '073A' '074A' '075A' '076A'
#  '087A' '088A' '090A' '091A' '092A' '094A' '095A' '096A' '099A' '100A'
#  '101A' '103A' '104A' '105A' '106A' '108A' '110A' '111A' '113A' '115A'
#  '116A' '117A']
# Unique Test Group IDs:
# ['002A' '004A' '006A' '013B' '014B' '015A' '019B' '022A' '023B' '025A'
#  '025B' '029A' '038A' '041A' '042A' '045A' '049A' '051B' '054A' '057A'
#  '060A' '062A' '063A' '067A' '068A' '093A' '097A' '097B' '102A' '109A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002B' '003A' '005A' '007A' '008A' '009A' '010A'
#  '011A' '012A' '014A' '016A' '018A' '019A' '020A' '021A' '023A' '024A'
#  '025C' '026A' '026B' '026C' '027A' '028A' '031A' '032A' '033A' '034A'
#  '035A' '036A' '037A' '039A' '040A' '043A' '044A' '046A' '047A' '048A'
#  '050A' '051A' '052A' '053A' '055A' '056A' '058A' '059A' '061A' '064A'
#  '065A' '066A' '069A' '070A' '071A' '072A' '073A' '074A' '075A' '076A'
#  '087A' '088A' '090A' '091A' '092A' '094A' '095A' '096A' '099A' '100A'
#  '101A' '103A' '104A' '105A' '106A' '108A' '110A' '111A' '113A' '115A'
#  '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['002A' '004A' '006A' '013B' '014B' '015A' '019B' '022A' '023B' '025A'
#  '025B' '029A' '038A' '041A' '042A' '045A' '049A' '051B' '054A' '057A'
#  '060A' '062A' '063A' '067A' '068A' '093A' '097A' '097B' '102A' '109A']
# Length of X_train_val:
# 722
# Length of y_train_val:
# 722
# Length of groups_train_val:
# 722
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     458
# kitten    135
# senior    129
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     148
# senior     57
# kitten     41
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     458
# kitten    135
# senior    129
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     148
# senior     57
# kitten     41
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 458, 1: 135, 2: 129})
# Epoch 1/1500
# 12/12 [==============================] - 1s 4ms/step - loss: 1.3121 - accuracy: 0.4681
# Epoch 2/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.6217 - accuracy: 0.6690
# Epoch 3/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3924 - accuracy: 0.7825
# Epoch 4/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3240 - accuracy: 0.8324
# Epoch 5/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2365 - accuracy: 0.8837
# Epoch 6/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2171 - accuracy: 0.8892
# Epoch 7/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1575 - accuracy: 0.9155
# Epoch 8/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1154 - accuracy: 0.9335
# Epoch 9/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1038 - accuracy: 0.9474
# Epoch 10/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1152 - accuracy: 0.9529
# Epoch 11/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1231 - accuracy: 0.9460
# Epoch 12/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0801 - accuracy: 0.9681
# Epoch 13/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0641 - accuracy: 0.9709
# Epoch 14/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0925 - accuracy: 0.9598
# Epoch 15/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0448 - accuracy: 0.9765
# Epoch 16/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0678 - accuracy: 0.9792
# Epoch 17/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0551 - accuracy: 0.9695
# Epoch 18/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0468 - accuracy: 0.9806
# Epoch 19/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0552 - accuracy: 0.9723
# Epoch 20/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0379 - accuracy: 0.9806
# Epoch 21/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0515 - accuracy: 0.9765
# Epoch 22/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0387 - accuracy: 0.9834
# Epoch 23/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0322 - accuracy: 0.9875
# Epoch 24/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0176 - accuracy: 0.9986
# Epoch 25/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0250 - accuracy: 0.9875
# Epoch 26/1500
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0302 - accuracy: 0.9848
# Epoch 27/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0257 - accuracy: 0.9889
# Epoch 28/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0203 - accuracy: 0.9903
# Epoch 29/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0403 - accuracy: 0.9861
# Epoch 30/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0344 - accuracy: 0.9875
# Epoch 31/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0430 - accuracy: 0.9806
# Epoch 32/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0504 - accuracy: 0.9709
# Epoch 33/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0291 - accuracy: 0.9806
# Epoch 34/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0301 - accuracy: 0.9903
# Epoch 35/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0199 - accuracy: 0.9931
# Epoch 36/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0222 - accuracy: 0.9889
# Epoch 37/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0130 - accuracy: 0.9972
# Epoch 38/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0211 - accuracy: 0.9903
# Epoch 39/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0180 - accuracy: 0.9945
# Epoch 40/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0314 - accuracy: 0.9889
# Epoch 41/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0149 - accuracy: 0.9945
# Epoch 42/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0188 - accuracy: 0.9945
# Epoch 43/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0170 - accuracy: 0.9931
# Epoch 44/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0311 - accuracy: 0.9875
# Epoch 45/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0323 - accuracy: 0.9917
# Epoch 46/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0295 - accuracy: 0.9861
# Epoch 47/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0245 - accuracy: 0.9848
# Epoch 48/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0125 - accuracy: 0.9945
# Epoch 49/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0205 - accuracy: 0.9931
# Epoch 50/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0265 - accuracy: 0.9903
# Epoch 51/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0356 - accuracy: 0.9903
# Epoch 52/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0242 - accuracy: 0.9889
# Epoch 53/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0128 - accuracy: 0.9945
# Epoch 54/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0102 - accuracy: 0.9986
# Epoch 55/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0127 - accuracy: 0.9931
# Epoch 56/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0213 - accuracy: 0.9931
# Epoch 57/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0222 - accuracy: 0.9931
# Epoch 58/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0045 - accuracy: 0.9986
# Epoch 59/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0054 - accuracy: 1.0000
# Epoch 60/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0067 - accuracy: 0.9972
# Epoch 61/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0258 - accuracy: 0.9917
# Epoch 62/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0218 - accuracy: 0.9903
# Epoch 63/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0201 - accuracy: 0.9889
# Epoch 64/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0148 - accuracy: 0.9945
# Epoch 65/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0190 - accuracy: 0.9917
# Epoch 66/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0100 - accuracy: 0.9945
# Epoch 67/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0097 - accuracy: 0.9958
# Epoch 68/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0057 - accuracy: 0.9986
# Epoch 69/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0043 - accuracy: 0.9986
# Epoch 70/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0079 - accuracy: 0.9986
# Epoch 71/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0071 - accuracy: 0.9986
# Epoch 72/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0143 - accuracy: 0.9958
# Epoch 73/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0124 - accuracy: 0.9917
# Epoch 74/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0160 - accuracy: 0.9903
# Epoch 75/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0080 - accuracy: 0.9986
# Epoch 76/1500
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0105 - accuracy: 0.9972
# Epoch 77/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0124 - accuracy: 0.9903
# Epoch 78/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0140 - accuracy: 0.9945
# Epoch 79/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0115 - accuracy: 0.9945
# Epoch 80/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0046 - accuracy: 0.9986
# Epoch 81/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 82/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0044 - accuracy: 0.9986
# Epoch 83/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0047 - accuracy: 0.9986
# Epoch 84/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0054 - accuracy: 0.9986
# Epoch 85/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0088 - accuracy: 0.9958
# Epoch 86/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0061 - accuracy: 0.9972
# Epoch 87/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0337 - accuracy: 0.9903
# Epoch 88/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0057 - accuracy: 0.9986
# Epoch 89/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0090 - accuracy: 0.9958
# Epoch 90/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0044 - accuracy: 0.9958
# Epoch 91/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0057 - accuracy: 1.0000
# Epoch 92/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0049 - accuracy: 1.0000
# Epoch 93/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0077 - accuracy: 0.9972
# Epoch 94/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0022 - accuracy: 0.9986
# Epoch 95/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0068 - accuracy: 0.9972
# Epoch 96/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0071 - accuracy: 0.9986
# Epoch 97/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0052 - accuracy: 1.0000
# Epoch 98/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0019 - accuracy: 0.9986
# Epoch 99/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0162 - accuracy: 0.9945
# Epoch 100/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0060 - accuracy: 0.9986
# Epoch 101/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0265 - accuracy: 0.9958
# Epoch 102/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0234 - accuracy: 0.9861
# Epoch 103/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0133 - accuracy: 0.9958
# Epoch 104/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0176 - accuracy: 0.9903
# Epoch 105/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0061 - accuracy: 0.9986
# Epoch 106/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0098 - accuracy: 0.9931
# Epoch 107/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0196 - accuracy: 0.9931
# Epoch 108/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 109/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0063 - accuracy: 0.9972
# Epoch 110/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 111/1500
# 12/12 [==============================] - ETA: 0s - loss: 0.0030 - accuracy: 1.0000Restoring model weights from the end of the best epoch: 81.
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 111: early stopping
# 8/8 [==============================] - 0s 1ms/step - loss: 3.0355 - accuracy: 0.5935
# 8/8 [==============================] - 0s 1ms/step
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Majority Vote Accuracy for cat_id for this fold: 0.67 (20/30)
# Before appending - Cat IDs: 153, Predictions: 153, Actuals: 153, Gender: 153
# After appending - Cat IDs: 399, Predictions: 399, Actuals: 399, Gender: 399
# Final Test Results - Loss: 3.0354561805725098, Accuracy: 0.5934959053993225, Precision: 0.5344316353530921, Recall: 0.524177258131045, F1 Score: 0.5266928973027595
# Confusion Matrix:
#  [[105  22  21]
#  [ 17  21   3]
#  [ 37   0  20]]
# outer_fold 3
# Train Set Group Distribution:
# 046A    66
# 000A    39
# 047A    30
# 057A    28
# 074A    25
# 020A    23
# 000B    20
# 067A    20
# 055A    20
# 029A    17
# 019A    17
# 097A    16
# 097B    14
# 042A    14
# 028A    14
# 111A    13
# 002A    13
# 116A    12
# 051A    12
# 005A    11
# 025A    11
# 036A    11
# 063A    11
# 016A    11
# 068A    11
# 071A    10
# 015A    10
# 014B    10
# 022A     9
# 045A     9
# 051B     9
# 072A     9
# 033A     9
# 095A     8
# 010A     8
# 013B     8
# 094A     8
# 099A     7
# 117A     7
# 050A     7
# 031A     7
# 053A     7
# 007A     6
# 108A     6
# 109A     6
# 021A     6
# 044A     5
# 075A     5
# 034A     5
# 023B     5
# 062A     5
# 009A     4
# 003A     4
# 052A     4
# 104A     4
# 060A     3
# 006A     3
# 014A     3
# 011A     3
# 113A     3
# 056A     3
# 025B     2
# 018A     2
# 066A     2
# 061A     2
# 038A     2
# 102A     2
# 069A     2
# 054A     2
# 093A     2
# 004A     1
# 041A     1
# 076A     1
# 110A     1
# 019B     1
# 088A     1
# 096A     1
# 043A     1
# 048A     1
# 049A     1
# 024A     1
# 026B     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 002B    36
# 103A    33
# 059A    18
# 101A    16
# 106A    15
# 001A    15
# 039A    12
# 040A    10
# 065A     9
# 027A     7
# 023A     6
# 025C     6
# 037A     6
# 008A     6
# 070A     5
# 012A     5
# 035A     4
# 026A     4
# 105A     4
# 058A     3
# 064A     3
# 032A     2
# 087A     2
# 092A     1
# 073A     1
# 091A     1
# 090A     1
# 026C     1
# 115A     1
# 100A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    313
# F    221
# M    200
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# M    156
# X     42
# F     36
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [002A, 028A, 033A, 000B, 071A, 020A, 000A, 015...
# kitten    [046A, 042A, 014B, 110A, 109A, 047A, 049A, 045...
# senior    [117A, 057A, 113A, 051B, 116A, 051A, 024A, 097...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [070A, 026A, 065A, 026C, 001A, 105A, 002B, 091...
# kitten                                         [040A, 115A]
# senior                             [106A, 090A, 059A, 058A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 50, 'kitten': 14, 'senior': 18}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 24, 'kitten': 2, 'senior': 4}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '002A' '003A' '004A' '005A' '006A' '007A' '009A' '010A'
#  '011A' '013B' '014A' '014B' '015A' '016A' '018A' '019A' '019B' '020A'
#  '021A' '022A' '023B' '024A' '025A' '025B' '026B' '028A' '029A' '031A'
#  '033A' '034A' '036A' '038A' '041A' '042A' '043A' '044A' '045A' '046A'
#  '047A' '048A' '049A' '050A' '051A' '051B' '052A' '053A' '054A' '055A'
#  '056A' '057A' '060A' '061A' '062A' '063A' '066A' '067A' '068A' '069A'
#  '071A' '072A' '074A' '075A' '076A' '088A' '093A' '094A' '095A' '096A'
#  '097A' '097B' '099A' '102A' '104A' '108A' '109A' '110A' '111A' '113A'
#  '116A' '117A']
# Unique Test Group IDs:
# ['001A' '002B' '008A' '012A' '023A' '025C' '026A' '026C' '027A' '032A'
#  '035A' '037A' '039A' '040A' '058A' '059A' '064A' '065A' '070A' '073A'
#  '087A' '090A' '091A' '092A' '100A' '101A' '103A' '105A' '106A' '115A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '002A' '003A' '004A' '005A' '006A' '007A' '009A' '010A'
#  '011A' '013B' '014A' '014B' '015A' '016A' '018A' '019A' '019B' '020A'
#  '021A' '022A' '023B' '024A' '025A' '025B' '026B' '028A' '029A' '031A'
#  '033A' '034A' '036A' '038A' '041A' '042A' '043A' '044A' '045A' '046A'
#  '047A' '048A' '049A' '050A' '051A' '051B' '052A' '053A' '054A' '055A'
#  '056A' '057A' '060A' '061A' '062A' '063A' '066A' '067A' '068A' '069A'
#  '071A' '072A' '074A' '075A' '076A' '088A' '093A' '094A' '095A' '096A'
#  '097A' '097B' '099A' '102A' '104A' '108A' '109A' '110A' '111A' '113A'
#  '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['001A' '002B' '008A' '012A' '023A' '025C' '026A' '026C' '027A' '032A'
#  '035A' '037A' '039A' '040A' '058A' '059A' '064A' '065A' '070A' '073A'
#  '087A' '090A' '091A' '092A' '100A' '101A' '103A' '105A' '106A' '115A']
# Length of X_train_val:
# 734
# Length of y_train_val:
# 734
# Length of groups_train_val:
# 734
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     420
# kitten    165
# senior    149
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     186
# senior     37
# kitten     11
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     420
# kitten    165
# senior    149
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     186
# senior     37
# kitten     11
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 420, 1: 165, 2: 149})
# Epoch 1/1500
# 12/12 [==============================] - 1s 4ms/step - loss: 1.2645 - accuracy: 0.5014
# Epoch 2/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.5710 - accuracy: 0.7398
# Epoch 3/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4063 - accuracy: 0.8025
# Epoch 4/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2732 - accuracy: 0.8719
# Epoch 5/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2426 - accuracy: 0.8815
# Epoch 6/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2064 - accuracy: 0.9142
# Epoch 7/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1476 - accuracy: 0.9223
# Epoch 8/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1166 - accuracy: 0.9496
# Epoch 9/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1116 - accuracy: 0.9578
# Epoch 10/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1020 - accuracy: 0.9482
# Epoch 11/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0723 - accuracy: 0.9646
# Epoch 12/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0847 - accuracy: 0.9700
# Epoch 13/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0869 - accuracy: 0.9728
# Epoch 14/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0725 - accuracy: 0.9728
# Epoch 15/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0777 - accuracy: 0.9673
# Epoch 16/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0493 - accuracy: 0.9741
# Epoch 17/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0684 - accuracy: 0.9728
# Epoch 18/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0449 - accuracy: 0.9768
# Epoch 19/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0352 - accuracy: 0.9877
# Epoch 20/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0339 - accuracy: 0.9837
# Epoch 21/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0209 - accuracy: 0.9946
# Epoch 22/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0304 - accuracy: 0.9891
# Epoch 23/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0270 - accuracy: 0.9891
# Epoch 24/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0263 - accuracy: 0.9877
# Epoch 25/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0190 - accuracy: 0.9905
# Epoch 26/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0194 - accuracy: 0.9946
# Epoch 27/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0172 - accuracy: 0.9932
# Epoch 28/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0327 - accuracy: 0.9877
# Epoch 29/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0236 - accuracy: 0.9877
# Epoch 30/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0268 - accuracy: 0.9891
# Epoch 31/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0112 - accuracy: 0.9986
# Epoch 32/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0225 - accuracy: 0.9877
# Epoch 33/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0221 - accuracy: 0.9891
# Epoch 34/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0227 - accuracy: 0.9891
# Epoch 35/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0180 - accuracy: 0.9986
# Epoch 36/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0271 - accuracy: 0.9877
# Epoch 37/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0125 - accuracy: 0.9973
# Epoch 38/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0091 - accuracy: 0.9973
# Epoch 39/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0069 - accuracy: 0.9973
# Epoch 40/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0122 - accuracy: 0.9959
# Epoch 41/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0139 - accuracy: 0.9932
# Epoch 42/1500
# 12/12 [==============================] - 0s 15ms/step - loss: 0.0085 - accuracy: 0.9973
# Epoch 43/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0152 - accuracy: 0.9946
# Epoch 44/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0121 - accuracy: 0.9946
# Epoch 45/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0196 - accuracy: 0.9905
# Epoch 46/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0109 - accuracy: 0.9973
# Epoch 47/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0196 - accuracy: 0.9918
# Epoch 48/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0203 - accuracy: 0.9918
# Epoch 49/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0147 - accuracy: 0.9932
# Epoch 50/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0121 - accuracy: 0.9959
# Epoch 51/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0140 - accuracy: 0.9946
# Epoch 52/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0077 - accuracy: 0.9959
# Epoch 53/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0113 - accuracy: 0.9946
# Epoch 54/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0074 - accuracy: 0.9959
# Epoch 55/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0083 - accuracy: 0.9959
# Epoch 56/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0096 - accuracy: 0.9959
# Epoch 57/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 58/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 59/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0047 - accuracy: 0.9986
# Epoch 60/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0057 - accuracy: 1.0000
# Epoch 61/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0051 - accuracy: 0.9986
# Epoch 62/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0181 - accuracy: 0.9918
# Epoch 63/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0086 - accuracy: 0.9986
# Epoch 64/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0142 - accuracy: 0.9959
# Epoch 65/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0111 - accuracy: 0.9959
# Epoch 66/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0191 - accuracy: 0.9918
# Epoch 67/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0101 - accuracy: 0.9946
# Epoch 68/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0078 - accuracy: 0.9986
# Epoch 69/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 70/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0045 - accuracy: 1.0000
# Epoch 71/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0091 - accuracy: 0.9946
# Epoch 72/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0032 - accuracy: 0.9986
# Epoch 73/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0066 - accuracy: 0.9973
# Epoch 74/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0124 - accuracy: 0.9959
# Epoch 75/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0053 - accuracy: 0.9986
# Epoch 76/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0213 - accuracy: 0.9946
# Epoch 77/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0236 - accuracy: 0.9905
# Epoch 78/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0233 - accuracy: 0.9891
# Epoch 79/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 80/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0164 - accuracy: 0.9959
# Epoch 81/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0086 - accuracy: 0.9959
# ...
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0116 - accuracy: 0.9946
# Epoch 84/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0052 - accuracy: 0.9973
# Epoch 85/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0096 - accuracy: 0.9959
# Epoch 86/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0261 - accuracy: 0.9932
# Epoch 87/1500
# 12/12 [==============================] - ETA: 0s - loss: 0.0204 - accuracy: 0.9891Restoring model weights from the end of the best epoch: 57.
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0204 - accuracy: 0.9891
# Epoch 87: early stopping
# 8/8 [==============================] - 0s 1ms/step - loss: 2.4523 - accuracy: 0.7222
# 8/8 [==============================] - 0s 1ms/step
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Majority Vote Accuracy for cat_id for this fold: 0.83 (25/30)
# Before appending - Cat IDs: 399, Predictions: 399, Actuals: 399, Gender: 399
# After appending - Cat IDs: 633, Predictions: 633, Actuals: 633, Gender: 633
# Final Test Results - Loss: 2.452299118041992, Accuracy: 0.7222222089767456, Precision: 0.5302113156100886, Recall: 0.6395647847260751, F1 Score: 0.5645886166276938
# Confusion Matrix:
#  [[143  12  31]
#  [  4   7   0]
#  [ 16   2  19]]
# outer_fold 4
# Train Set Group Distribution:
# 002B    36
# 103A    33
# 057A    28
# 000B    20
# 055A    20
# 067A    20
# 059A    18
# 029A    17
# 097A    16
# 101A    16
# 106A    15
# 001A    15
# 042A    14
# 028A    14
# 097B    14
# 002A    13
# 039A    12
# 068A    11
# 036A    11
# 063A    11
# 025A    11
# 014B    10
# 040A    10
# 015A    10
# 071A    10
# 065A     9
# 051B     9
# 022A     9
# 033A     9
# 045A     9
# 013B     8
# 094A     8
# 010A     8
# 027A     7
# 099A     7
# 031A     7
# 117A     7
# 023A     6
# 109A     6
# 008A     6
# 108A     6
# 025C     6
# 037A     6
# 044A     5
# 023B     5
# 070A     5
# 012A     5
# 062A     5
# 105A     4
# 035A     4
# 009A     4
# 026A     4
# 060A     3
# 064A     3
# 113A     3
# 006A     3
# 058A     3
# 011A     3
# 087A     2
# 038A     2
# 032A     2
# 066A     2
# 025B     2
# 054A     2
# 102A     2
# 093A     2
# 061A     2
# 026B     1
# 019B     1
# 041A     1
# 004A     1
# 115A     1
# 076A     1
# 024A     1
# 096A     1
# 073A     1
# 088A     1
# 091A     1
# 043A     1
# 048A     1
# 026C     1
# 092A     1
# 049A     1
# 090A     1
# 100A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 046A    66
# 000A    39
# 047A    30
# 074A    25
# 020A    23
# 019A    17
# 111A    13
# 116A    12
# 051A    12
# 005A    11
# 016A    11
# 072A     9
# 095A     8
# 050A     7
# 053A     7
# 021A     6
# 007A     6
# 075A     5
# 034A     5
# 003A     4
# 052A     4
# 104A     4
# 014A     3
# 056A     3
# 069A     2
# 018A     2
# 110A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    255
# X    202
# F    176
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    153
# M    101
# F     81
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [002A, 028A, 070A, 033A, 000B, 071A, 015A, 026...
# kitten    [042A, 014B, 109A, 040A, 049A, 045A, 048A, 044...
# senior    [117A, 106A, 057A, 090A, 113A, 051B, 024A, 097...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [020A, 000A, 053A, 007A, 021A, 018A, 034A, 072...
# kitten                       [046A, 110A, 047A, 111A, 050A]
# senior                       [116A, 051A, 016A, 104A, 056A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 57, 'kitten': 11, 'senior': 17}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 17, 'kitten': 5, 'senior': 5}
# Unique Training/Validation Group IDs:
# ['000B' '001A' '002A' '002B' '004A' '006A' '008A' '009A' '010A' '011A'
#  '012A' '013B' '014B' '015A' '019B' '022A' '023A' '023B' '024A' '025A'
#  '025B' '025C' '026A' '026B' '026C' '027A' '028A' '029A' '031A' '032A'
#  '033A' '035A' '036A' '037A' '038A' '039A' '040A' '041A' '042A' '043A'
#  '044A' '045A' '048A' '049A' '051B' '054A' '055A' '057A' '058A' '059A'
#  '060A' '061A' '062A' '063A' '064A' '065A' '066A' '067A' '068A' '070A'
#  '071A' '073A' '076A' '087A' '088A' '090A' '091A' '092A' '093A' '094A'
#  '096A' '097A' '097B' '099A' '100A' '101A' '102A' '103A' '105A' '106A'
#  '108A' '109A' '113A' '115A' '117A']
# Unique Test Group IDs:
# ['000A' '003A' '005A' '007A' '014A' '016A' '018A' '019A' '020A' '021A'
#  '034A' '046A' '047A' '050A' '051A' '052A' '053A' '056A' '069A' '072A'
#  '074A' '075A' '095A' '104A' '110A' '111A' '116A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'046A', '000A'}
# Removed from Training/Validation Set:
# {'044A', '029A'}
# Moved to Test Set:
# {'044A', '029A'}
# Removed from Test Set
# {'046A', '000A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '004A' '006A' '008A' '009A' '010A'
#  '011A' '012A' '013B' '014B' '015A' '019B' '022A' '023A' '023B' '024A'
#  '025A' '025B' '025C' '026A' '026B' '026C' '027A' '028A' '031A' '032A'
#  '033A' '035A' '036A' '037A' '038A' '039A' '040A' '041A' '042A' '043A'
#  '045A' '046A' '048A' '049A' '051B' '054A' '055A' '057A' '058A' '059A'
#  '060A' '061A' '062A' '063A' '064A' '065A' '066A' '067A' '068A' '070A'
#  '071A' '073A' '076A' '087A' '088A' '090A' '091A' '092A' '093A' '094A'
#  '096A' '097A' '097B' '099A' '100A' '101A' '102A' '103A' '105A' '106A'
#  '108A' '109A' '113A' '115A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['003A' '005A' '007A' '014A' '016A' '018A' '019A' '020A' '021A' '029A'
#  '034A' '044A' '047A' '050A' '051A' '052A' '053A' '056A' '069A' '072A'
#  '074A' '075A' '095A' '104A' '110A' '111A' '116A']
# Length of X_train_val:
# 716
# Length of y_train_val:
# 716
# Length of groups_train_val:
# 716
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     430
# senior    144
# kitten     59
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     176
# kitten    117
# senior     42
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     452
# senior    144
# kitten    120
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     154
# kitten     56
# senior     42
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 452, 2: 144, 1: 120})
# Epoch 1/1500
# 12/12 [==============================] - 1s 4ms/step - loss: 1.3155 - accuracy: 0.4344
# Epoch 2/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.6452 - accuracy: 0.6802
# Epoch 3/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4361 - accuracy: 0.7779
# Epoch 4/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3055 - accuracy: 0.8422
# Epoch 5/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2679 - accuracy: 0.8478
# Epoch 6/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2687 - accuracy: 0.8715
# Epoch 7/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2421 - accuracy: 0.8715
# Epoch 8/1500
# 12/12 [==============================] - 0s 21ms/step - loss: 0.1951 - accuracy: 0.9190
# Epoch 9/1500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.1525 - accuracy: 0.9204
# Epoch 10/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1388 - accuracy: 0.9385
# Epoch 11/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1387 - accuracy: 0.9316
# Epoch 12/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0874 - accuracy: 0.9497
# Epoch 13/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0949 - accuracy: 0.9511
# Epoch 14/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0913 - accuracy: 0.9553
# Epoch 15/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0683 - accuracy: 0.9581
# Epoch 16/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0792 - accuracy: 0.9595
# Epoch 17/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1034 - accuracy: 0.9525
# Epoch 18/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0713 - accuracy: 0.9623
# Epoch 19/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0812 - accuracy: 0.9637
# Epoch 20/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0826 - accuracy: 0.9623
# Epoch 21/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0590 - accuracy: 0.9749
# Epoch 22/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0590 - accuracy: 0.9763
# Epoch 23/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0512 - accuracy: 0.9804
# Epoch 24/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0358 - accuracy: 0.9846
# Epoch 25/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0416 - accuracy: 0.9777
# Epoch 26/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0416 - accuracy: 0.9763
# Epoch 27/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0565 - accuracy: 0.9749
# Epoch 28/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0764 - accuracy: 0.9721
# Epoch 29/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0546 - accuracy: 0.9679
# Epoch 30/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0477 - accuracy: 0.9832
# Epoch 31/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.
# %%
# Set a fixed random seed for reproducibility
random.seed(int(random_seeds[4]))
np.random.seed(int(random_seeds[4]))
tf.random.set_seed(int(random_seeds[4]))

# Load datasets
dataframe = pd.read_csv('/Users/astrid/PycharmProjects/data-aug-and-more/yamnet-tfhub-extraction/yamnet_embeddings_looped_april_23.csv')

def assign_age_group(age, age_groups):
    for group_name, age_range in age_groups.items():
        if age_range[0] <= age < age_range[1]:
            return group_name
    return 'Unknown'  # For any age that doesn't fit the defined groups

# Define age groups
age_groups = {
    'kitten': (0, 0.5),
    'adult': (0.5, 12),
    'senior': (12, 20)
}

# Create a new column for the age group
dataframe['age_group'] = dataframe['target'].apply(assign_age_group, age_groups=age_groups)

print(dataframe['age_group'].value_counts())
# Out:
# adult     606
# senior    186
# kitten    176
# Name: age_group, dtype: int64

# %%
# Separate features and labels
X = dataframe.iloc[:, :-4].values  # all columns except the last four

# Encode the 'age_group' column as integers using LabelEncoder
label_encoder = LabelEncoder()
encoded_y = label_encoder.fit_transform(dataframe['age_group'].values)

# Use the encoded labels for splitting and one-hot encoding
y = encoded_y  

# Convert 'cat_id' column to numpy array to be used as groups array for GroupKFold
groups = dataframe['cat_id'].values

# %%
tf.keras.backend.clear_session()

# %% [markdown]
# ## Run Setup

# %%
all_cat_ids = []
all_predicted_age_groups = []
all_actual_age_groups = []
all_gender = []

# Define the StratifiedGroupKFold splitter for 4 fold CV with random shuffling
outer_cv = StratifiedGroupKFold(n_splits=4, shuffle=True, random_state=int(random_seeds[4]))

# unseen test set metrics
unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1 = [], [], [], [], []

cv_training_acc_total = []
cv_training_acc_best = []

outer_fold = 0


# Use the splitter to generate indices for training and testing sets
# Note: GroupShuffleSplit.split returns indices, so we use it to index the arrays
for train_val_idx, test_idx in outer_cv.split(X, y, groups):
    outer_fold += 1
    logger(f"outer_fold {outer_fold}", file=log_file_path)

    # Convert indices back to DataFrame for easy manipulation
    df_train_val = dataframe.iloc[train_val_idx]
    df_test = dataframe.iloc[test_idx]

    ##############################
    # ASSESSING SPLITS BY CAT_ID #
    ##############################
    
    # Get the distribution of groups
    training_validation_group_distribution = df_train_val['cat_id'].value_counts()  
    testing_group_distribution = df_test['cat_id'].value_counts()  
    
    # Log or print the distribution
    logger(f"Train Set Group Distribution:\n{training_validation_group_distribution}", file=log_file_path)
    logger(f"Testing Set Group Distribution:\n{testing_group_distribution}", file=log_file_path)

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val['gender'].value_counts()
    testing_gender_distribution = df_test['gender'].value_counts()
    
    # Log the distribution
    logger(f"Training Set Gender Distribution BEFORE SWAP:\n{training_gender_distribution}", file=log_file_path)
    logger(f"Testing Set Gender Distribution BEFORE SWAP:\n{testing_gender_distribution}", file=log_file_path)

    # Group by 'age_group' and then list unique 'cat_id' within each age group
    unique_cat_ids_per_age_group_train_val = df_train_val.groupby('age_group')['cat_id'].unique()
    unique_cat_ids_per_age_group_test = df_test.groupby('age_group')['cat_id'].unique()
    
    # Log results
    logger(f"Unique Cat IDs per Age Group in Training/Validation Set:\n{unique_cat_ids_per_age_group_train_val}", file=log_file_path)
    logger(f"Unique Cat IDs per Age Group in Testing Set:\n{unique_cat_ids_per_age_group_test}", file=log_file_path)

    # Calculate the count of unique identifiers per age group for training and testing set
    counts_train_val = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_train_val.items()}
    counts_test = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_test.items()}

    # Log the counts of unique identifiers per age group
    logger(f"Count of Unique Cat IDs per Age Group in Training/Validation Set:\n{counts_train_val}", file=log_file_path)
    logger(f"Count of Unique Cat IDs per Age Group in Testing Set:\n{counts_test}", file=log_file_path)

    #######################################################
    # CONTINUE WITH ENSURING VALID AND APPROPRIATE SPLITS #
    #######################################################
    
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    groups_train_val, groups_test = groups[train_val_idx], groups[test_idx]

    # logging identifier splits 
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)

    # check group splits
    check_initial_group_split(groups_train_val, groups_test)

    # Specify the cat_ids that must be in the training/validation set
    specific_cat_ids = ['000A', '046A']
    
    # Perform the swapping operation
    train_val_idx, test_idx = swap_cat_id_instances(dataframe, train_val_idx, test_idx, specific_cat_ids)
    
    # Re-assign the sets based on the updated indices
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    new_groups_train_val, new_groups_test = groups[train_val_idx], groups[test_idx]

    # Find differences for training and test sets
    moved_to_train_val, removed_from_train_val = find_group_differences(groups_train_val, new_groups_train_val)
    moved_to_test, removed_from_test = find_group_differences(groups_test, new_groups_test)
    
    # Display the results
    logger(f"Moved to Training/Validation Set:\n{moved_to_train_val}", file=log_file_path)
    logger(f"Removed from Training/Validation Set:\n{removed_from_train_val}", file=log_file_path)
    logger(f"Moved to Test Set:\n{moved_to_test}", file=log_file_path)
    logger(f"Removed from Test Set\n{removed_from_test}", file=log_file_path)

    # Update X_train_val, X_test, y_train_val, y_test, groups_train_val, groups_test based on updated indices
    X_train_val = X[train_val_idx]
    y_train_val = y[train_val_idx]
    groups_train_val = groups[train_val_idx]
    
    X_test = X[test_idx]
    y_test = y[test_idx]
    groups_test = groups[test_idx]

    # logging identifier splits again after potential swaps
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"AFTER SWAP - Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"AFTER SWAP - Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)
    
    # Verify the lengths are consistent
    logger(f"Length of X_train_val:\n{len(X_train_val)}", file=log_file_path)
    logger(f"Length of y_train_val:\n{len(y_train_val)}", file=log_file_path)
    logger(f"Length of groups_train_val:\n{len(groups_train_val)}", file=log_file_path)

    # Check group splits once more
    check_initial_group_split(groups_train_val, groups_test)

    # Convert the modified indices back to a DataFrame representing the updated df_train_val
    df_train_val_updated = dataframe.iloc[train_val_idx].copy()
    df_test_updated = dataframe.iloc[test_idx].copy()

    ############################
    # LOGGING AGE GROUP SPLITS #
    ############################

    # Get the distribution of age groups of age groups before the update
    training_validation_age_group_distribution = df_train_val['age_group'].value_counts()
    testing_age_group_distribution = df_test['age_group'].value_counts()
    
    # Logthe distribution
    logger(f"Train Age Group Distribution BEFORE SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution BEFORE SWAP:\n{testing_age_group_distribution}", file=log_file_path)

    # Get the distribution of age groups after the update
    training_validation_age_group_distribution = df_train_val_updated['age_group'].value_counts()
    testing_age_group_distribution = df_test_updated['age_group'].value_counts()
    
    # Log the distribution
    logger(f"Train Age Group Distribution AFTER SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution AFTER SWAP:\n{testing_age_group_distribution}", file=log_file_path)
    
    ########################################################
    # TRACKING FINAL CAT_IDs & GENDER AFTER REDISTRIBUTION #
    ########################################################

    # Get the distribution of groups
    training_validation_group_distribution = df_train_val_updated['cat_id'].value_counts()  
    testing_group_distribution = df_test_updated['cat_id'].value_counts()  

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val_updated['gender'].value_counts()
    testing_gender_distribution = df_test_updated['gender'].value_counts()
    
    logger(f"\n Starting training on unseen test set\n", file=log_file_path)

    ###################
    # PREPARING MODEL #
    ###################

    # Calculate the distribution of age groups in y_train_val
    age_group_distribution = Counter(y_train_val)
    print("Age group distribution:", age_group_distribution)

    # EarlyStopping callback: monitor 'loss' instead of 'val_loss' for the test set
    early_stopping = EarlyStopping(
        monitor='loss',  
        min_delta=0.001, 
        patience=30,  
        verbose=1,  
        restore_best_weights=True  
    )

    accuracy_history = AccuracyHistory()

    # One final shuffle to ensure randomness
    outer_shuffle_idx = np.random.permutation(len(X_train_val))
    X_train_val = X_train_val[outer_shuffle_idx]
    y_train_val = y_train_val[outer_shuffle_idx]

    class_weights = compute_class_weight(
        class_weight='balanced',
        classes=np.unique(y_train_val),
        y=y_train_val
    )
    weight_dict = {i: class_weights[i] for i in range(len(class_weights))}
    
    # Scale the features
    scaler_full = StandardScaler().fit(X_train_val)
    X_train_full_scaled = scaler_full.transform(X_train_val)
    X_test_scaled = scaler_full.transform(X_test)
    
    # Encode the labels
    y_train_full_encoded = to_categorical(y_train_val)
    y_test_encoded = to_categorical(y_test)

    #######################
    # BUILD & TRAIN MODEL #
    #######################

    optimizers = {
        'Adamax': Adamax(learning_rate=0.00510251984616472)
    }
    
    # Model definition with dynamic number of layers
    model_full = Sequential()
    model_full.add(Dense(480, activation='relu', input_shape=(X_train_full_scaled.shape[1],)))
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.2011047009431978))  
    model_full.add(Dense(256, activation='relu',)) 
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.14956886311951184))  
    model_full.add(Dense(256, activation='relu'))  
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.42291461228250665))  
    model_full.add(Dense(3, activation='softmax'))  
    
    # Use the optimizer from the parameters
    optimizer = optimizers['Adamax']  # optimizer_key from parameters
    
    # Compile the model
    model_full.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    
    # Train the model on the full training set
    history_full = model_full.fit(X_train_full_scaled, y_train_full_encoded, epochs=1500, batch_size=64,
                                  verbose=1, callbacks=[early_stopping, accuracy_history], class_weight=weight_dict)
    
    # log epochs
    best_epoch_index = np.argmin(history_full.history['loss'])  
    best_training_accuracy = accuracy_history.acc[best_epoch_index]
    # Append training acc to total  
    all_best_training_acc.append(best_training_accuracy)
    total_training_acc.append(accuracy_history.acc)
    # Append training acc just for this CV
    cv_training_acc_total.append(accuracy_history.acc)
    cv_training_acc_best.append(best_training_accuracy)
    
    # Evaluate the model on the held-out test set
    test_loss, test_accuracy = model_full.evaluate(X_test_scaled, y_test_encoded)

    y_test_pred_prob = model_full.predict(X_test_scaled)
    y_test_pred = np.argmax(y_test_pred_prob, axis=1)  
    y_test_true = np.argmax(y_test_encoded, axis=1)    

    ################################
    # LOG MAJORITY VOTE PER CAT_ID #
    ################################

    # Convert numeric predictions back to age group labels
    predicted_age_groups = label_encoder.inverse_transform(y_test_pred)
    actual_labels = label_encoder.inverse_transform(y_test_true)
    
    # Map predictions and actual labels back to cat_ids
    test_results = pd.DataFrame({
        'cat_id': df_test_updated['cat_id'],
        'predicted_age_group': predicted_age_groups,
        'actual_age_group': actual_labels
    })
    
    # Group by cat_id and aggregate predicted age groups
    majority_votes = test_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
    actual_groups = test_results.groupby('cat_id')['actual_age_group'].first()
    
    # Calculate the accuracy of majority voting
    correct_predictions = (majority_votes == actual_groups).sum()
    total_cats = len(actual_groups)
    majority_vote_accuracy = correct_predictions / total_cats
    
    # Log the accuracy of the majority voting
    logger(f"Majority Vote Accuracy for cat_id for this fold: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

    ####################################################
    # COLLECT PREDICTIONS FOR GENDER & CAT_ID ANALYSIS #
    ####################################################

    # Debugging print statements
    print(f'Before appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Extend lists with current fold results
    all_cat_ids.extend(df_test_updated['cat_id'].tolist())
    all_predicted_age_groups.extend(predicted_age_groups)
    all_actual_age_groups.extend(actual_labels)
    all_gender.extend(df_test_updated['gender'].tolist())

    # Debugging print statements
    print(f'After appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Calculate additional metrics
    test_precision = precision_score(y_test_true, y_test_pred, average='macro')  # Use 'macro' for imbalanced datasets
    test_recall = recall_score(y_test_true, y_test_pred, average='macro')
    test_f1 = f1_score(y_test_true, y_test_pred, average='macro')

    # prepare averages of outer metrics
    unseen_f1.append(test_f1)
    unseen_losses.append(test_loss)
    unseen_accuracies.append(test_accuracy)
    unseen_precisions.append(test_precision)
    unseen_recalls.append(test_recall)

    # Print final test results
    logger(f"Final Test Results - Loss: {test_loss}, Accuracy: {test_accuracy}, Precision: {test_precision}, Recall: {test_recall}, F1 Score: {test_f1}", file=log_file_path)

    # Generate the confusion matrix
    cm = confusion_matrix(y_test, y_test_pred)
    logger(f"Confusion Matrix:\n {cm}", file=log_file_path)

# Calculate the overall average metrics
unseen_set_avg_f1 = np.mean(unseen_f1)
unseen_set_avg_loss = np.mean(unseen_losses)
unseen_set_avg_acc = np.mean(unseen_accuracies)
unseen_set_avg_precision = np.mean(unseen_precisions)
unseen_set_avg_recall = np.mean(unseen_recalls)

logger(f"\nFinal Average F1-Score across all UNSEEN TEST sets: {unseen_set_avg_f1}", file=log_file_path)
logger(f"\nFinal Average Loss across all UNSEEN TEST sets: {unseen_set_avg_loss}", file=log_file_path)
logger(f"\nFinal Average Accuracy across all UNSEEN TEST sets: {unseen_set_avg_acc}", file=log_file_path)
logger(f"\nFinal Average Precision across all UNSEEN TEST sets: {unseen_set_avg_precision}", file=log_file_path)
logger(f"\nFinal Average Recall across all UNSEEN TEST sets: {unseen_set_avg_recall}\n", file=log_file_path)

# Append averages to total lists
average_fold_f1.append(unseen_set_avg_f1)
average_fold_losses.append(unseen_set_avg_loss)
average_fold_accuracies.append(unseen_set_avg_acc)
average_fold_precisions.append(unseen_set_avg_precision)
average_fold_recalls.append(unseen_set_avg_recall)

# Append all to total lists
all_f1.append(unseen_f1)
all_losses.append(unseen_losses)
all_accuracies.append(unseen_accuracies)
all_precisions.append(unseen_precisions)
all_recalls.append(unseen_recalls)
# Out:
# outer_fold 1
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Train Set Group Distribution:
# 046A    66
# 000A    39
# 002B    36
# 057A    28
# 074A    25
# 020A    23
# 067A    20
# 055A    20
# 059A    18
# 029A    17
# 019A    17
# 101A    16
# 106A    15
# 001A    15
# 097B    14
# 028A    14
# 042A    14
# 111A    13
# 051A    12
# 116A    12
# 039A    12
# 016A    11
# 005A    11
# 063A    11
# 025A    11
# 036A    11
# 068A    11
# 071A    10
# 015A    10
# 040A    10
# 014B    10
# 033A     9
# 022A     9
# 065A     9
# 045A     9
# 051B     9
# 094A     8
# 010A     8
# 013B     8
# 095A     8
# 053A     7
# 099A     7
# 027A     7
# 117A     7
# 007A     6
# 108A     6
# 021A     6
# 023A     6
# 109A     6
# 037A     6
# 075A     5
# 012A     5
# 023B     5
# 044A     5
# 062A     5
# 052A     4
# 009A     4
# 035A     4
# 104A     4
# 003A     4
# 026A     4
# 060A     3
# 064A     3
# 014A     3
# 058A     3
# 018A     2
# 069A     2
# 038A     2
# 054A     2
# 093A     2
# 061A     2
# 087A     2
# 066A     2
# 025B     2
# 019B     1
# 041A     1
# 115A     1
# 026C     1
# 073A     1
# 088A     1
# 043A     1
# 048A     1
# 092A     1
# 024A     1
# 090A     1
# 110A     1
# 100A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 103A    33
# 047A    30
# 000B    20
# 097A    16
# 002A    13
# 072A     9
# 050A     7
# 031A     7
# 008A     6
# 025C     6
# 034A     5
# 070A     5
# 105A     4
# 113A     3
# 006A     3
# 011A     3
# 056A     3
# 102A     2
# 032A     2
# 091A     1
# 076A     1
# 004A     1
# 096A     1
# 049A     1
# 026B     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    299
# X    281
# F    205
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    74
# M    57
# F    52
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [028A, 033A, 071A, 020A, 000A, 015A, 026A, 065...
# kitten    [046A, 042A, 014B, 110A, 109A, 040A, 045A, 048...
# senior    [117A, 106A, 057A, 090A, 051B, 116A, 051A, 024...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [002A, 070A, 000B, 105A, 034A, 072A, 006A, 091...
# kitten                                   [047A, 049A, 050A]
# senior                             [113A, 097A, 011A, 056A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 56, 'kitten': 13, 'senior': 18}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 18, 'kitten': 3, 'senior': 4}
# Unique Training/Validation Group IDs:
# ['000A' '001A' '002B' '003A' '005A' '007A' '009A' '010A' '012A' '013B'
#  '014A' '014B' '015A' '016A' '018A' '019A' '019B' '020A' '021A' '022A'
#  '023A' '023B' '024A' '025A' '025B' '026A' '026C' '027A' '028A' '029A'
#  '033A' '035A' '036A' '037A' '038A' '039A' '040A' '041A' '042A' '043A'
#  '044A' '045A' '046A' '048A' '051A' '051B' '052A' '053A' '054A' '055A'
#  '057A' '058A' '059A' '060A' '061A' '062A' '063A' '064A' '065A' '066A'
#  '067A' '068A' '069A' '071A' '073A' '074A' '075A' '087A' '088A' '090A'
#  '092A' '093A' '094A' '095A' '097B' '099A' '100A' '101A' '104A' '106A'
#  '108A' '109A' '110A' '111A' '115A' '116A' '117A']
# Unique Test Group IDs:
# ['000B' '002A' '004A' '006A' '008A' '011A' '025C' '026B' '031A' '032A'
#  '034A' '047A' '049A' '050A' '056A' '070A' '072A' '076A' '091A' '096A'
#  '097A' '102A' '103A' '105A' '113A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '001A' '002B' '003A' '005A' '007A' '009A' '010A' '012A' '013B'
#  '014A' '014B' '015A' '016A' '018A' '019A' '019B' '020A' '021A' '022A'
#  '023A' '023B' '024A' '025A' '025B' '026A' '026C' '027A' '028A' '029A'
#  '033A' '035A' '036A' '037A' '038A' '039A' '040A' '041A' '042A' '043A'
#  '044A' '045A' '046A' '048A' '051A' '051B' '052A' '053A' '054A' '055A'
#  '057A' '058A' '059A' '060A' '061A' '062A' '063A' '064A' '065A' '066A'
#  '067A' '068A' '069A' '071A' '073A' '074A' '075A' '087A' '088A' '090A'
#  '092A' '093A' '094A' '095A' '097B' '099A' '100A' '101A' '104A' '106A'
#  '108A' '109A' '110A' '111A' '115A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['000B' '002A' '004A' '006A' '008A' '011A' '025C' '026B' '031A' '032A'
#  '034A' '047A' '049A' '050A' '056A' '070A' '072A' '076A' '091A' '096A'
#  '097A' '102A' '103A' '105A' '113A']
# Length of X_train_val:
# 785
# Length of y_train_val:
# 785
# Length of groups_train_val:
# 785
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     486
# senior    161
# kitten    138
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     120
# kitten     38
# senior     25
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     486
# senior    161
# kitten    138
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     120
# kitten     38
# senior     25
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 486, 2: 161, 1: 138})
# Epoch 1/1500
# 13/13 [==============================] - 1s 5ms/step - loss: 1.2115 - accuracy: 0.5096
# Epoch 2/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.7359 - accuracy: 0.6739
# Epoch 3/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.4280 - accuracy: 0.7809
# Epoch 4/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3287 - accuracy: 0.8306
# Epoch 5/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2956 - accuracy: 0.8573
# Epoch 6/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2330 - accuracy: 0.8701
# Epoch 7/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2033 - accuracy: 0.8943
# Epoch 8/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1295 - accuracy: 0.9350
# Epoch 9/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1074 - accuracy: 0.9554
# Epoch 10/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.
1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0043 - accuracy: 0.9975
# Epoch 75/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0055 - accuracy: 0.9987
# Epoch 76/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0113 - accuracy: 0.9949
# Epoch 77/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0047 - accuracy: 0.9975
# Epoch 78/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0033 - accuracy: 0.9987
# Epoch 79/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0066 - accuracy: 0.9962
# Epoch 80/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0027 - accuracy: 0.9987
# Epoch 81/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0130 - accuracy: 0.9962
# Epoch 82/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0133 - accuracy: 0.9936
# Epoch 83/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0079 - accuracy: 0.9962
# Epoch 84/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0130 - accuracy: 0.9924
# Epoch 85/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0126 - accuracy: 0.9949
# Epoch 86/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0262 - accuracy: 0.9924
# Epoch 87/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0180 - accuracy: 0.9911
# Epoch 88/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0104 - accuracy: 0.9962
# Epoch 89/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0047 - accuracy: 0.9987
# Epoch 90/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0197 - accuracy: 0.9924
# Epoch 91/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0147 - accuracy: 0.9911
# Epoch 92/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0222 - accuracy: 0.9911
# Epoch 93/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0141 - accuracy: 0.9949
# Epoch 94/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0086 - accuracy: 0.9936
# Epoch 95/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0079 - accuracy: 0.9962
# Epoch 96/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0048 - accuracy: 1.0000
# Epoch 97/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0053 - accuracy: 0.9962
# Epoch 98/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0163 - accuracy: 0.9936
# Epoch 99/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0074 - accuracy: 0.9936
# Epoch 100/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0231 - accuracy: 0.9911
# Epoch 101/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0076 - accuracy: 0.9975
# Epoch 102/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 103/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0077 - accuracy: 0.9975
# Epoch 104/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0084 - accuracy: 0.9975
# Epoch 105/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0175 - accuracy: 0.9949
# Epoch 106/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0101 - accuracy: 0.9962
# Epoch 107/1500
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0098 - accuracy: 0.9949
# Epoch 108/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0091 - accuracy: 0.9975
# Epoch 109/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0146 - accuracy: 0.9949
# Epoch 110/1500
# 13/13 [==============================] - ETA: 0s - loss: 0.0070 - accuracy: 0.9987Restoring model weights from the end of the best epoch: 80.
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0070 - accuracy: 0.9987
# Epoch 110: early stopping
# 6/6 [==============================] - 0s 1ms/step - loss: 3.8906 - accuracy: 0.6284
# 6/6 [==============================] - 0s 1ms/step
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Majority Vote Accuracy for cat_id for this fold: 0.80 (20/25)
# Before appending - Cat IDs: 0, Predictions: 0, Actuals: 0, Gender: 0
# After appending - Cat IDs: 183, Predictions: 183, Actuals: 183, Gender: 183
# Final Test Results - Loss: 3.890613317489624, Accuracy: 0.6284152865409851, Precision: 0.5391203703703704, Recall: 0.47438596491228074, F1 Score: 0.47970034017505636
# Confusion Matrix:
#  [[96  5 19]
#  [24 10  4]
#  [15  1  9]]
# outer_fold 2
# Train Set Group Distribution:
# 046A    66
# 103A    33
# 047A    30
# 074A    25
# 020A    23
# 000B    20
# 067A    20
# 055A    20
# 059A    18
# 101A    16
# 097A    16
# 106A    15
# 097B    14
# 028A    14
# 042A    14
# 002A    13
# 039A    12
# 116A    12
# 051A    12
# 068A    11
# 025A    11
# 016A    11
# 014B    10
# 015A    10
# 071A    10
# 065A     9
# 051B     9
# 022A     9
# 072A     9
# 013B     8
# 095A     8
# 010A     8
# 094A     8
# 117A     7
# 027A     7
# 050A     7
# 031A     7
# 053A     7
# 025C     6
# 037A     6
# 021A     6
# 008A     6
# 034A     5
# 023B     5
# 070A     5
# 044A     5
# 035A     4
# 105A     4
# 026A     4
# 056A     3
# 011A     3
# 014A     3
# 113A     3
# 064A     3
# 060A     3
# 006A     3
# 025B     2
# 061A     2
# 087A     2
# 069A     2
# 032A     2
# 093A     2
# 102A     2
# 041A     1
# 004A     1
# 019B     1
# 076A     1
# 026B     1
# 115A     1
# 026C     1
# 073A     1
# 088A     1
# 096A     1
# 043A     1
# 049A     1
# 024A     1
# 091A     1
# 090A     1
# 110A     1
# 100A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 000A    39
# 002B    36
# 057A    28
# 029A    17
# 019A    17
# 001A    15
# 111A    13
# 036A    11
# 063A    11
# 005A    11
# 040A    10
# 033A     9
# 045A     9
# 099A     7
# 109A     6
# 007A     6
# 023A     6
# 108A     6
# 012A     5
# 075A     5
# 062A     5
# 003A     4
# 009A     4
# 052A     4
# 104A     4
# 058A     3
# 054A     2
# 018A     2
# 066A     2
# 038A     2
# 048A     1
# 092A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    239
# M    237
# F    191
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# M    119
# X    116
# F     66
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [002A, 028A, 070A, 000B, 071A, 020A, 015A, 026...
# kitten    [046A, 042A, 014B, 110A, 047A, 049A, 044A, 043...
# senior    [117A, 106A, 090A, 113A, 051B, 116A, 051A, 024...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [033A, 000A, 038A, 007A, 001A, 018A, 062A, 002...
# kitten                       [109A, 040A, 045A, 048A, 111A]
# senior                       [057A, 058A, 054A, 108A, 104A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 52, 'kitten': 11, 'senior': 17}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 22, 'kitten': 5, 'senior': 5}
# Unique Training/Validation Group IDs:
# ['000B' '002A' '004A' '006A' '008A' '010A' '011A' '013B' '014A' '014B'
#  '015A' '016A' '019B' '020A' '021A' '022A' '023B' '024A' '025A' '025B'
#  '025C' '026A' '026B' '026C' '027A' '028A' '031A' '032A' '034A' '035A'
#  '037A' '039A' '041A' '042A' '043A' '044A' '046A' '047A' '049A' '050A'
#  '051A' '051B' '053A' '055A' '056A' '059A' '060A' '061A' '064A' '065A'
#  '067A' '068A' '069A' '070A' '071A' '072A' '073A' '074A' '076A' '087A'
#  '088A' '090A' '091A' '093A' '094A' '095A' '096A' '097A' '097B' '100A'
#  '101A' '102A' '103A' '105A' '106A' '110A' '113A' '115A' '116A' '117A']
# Unique Test Group IDs:
# ['000A' '001A' '002B' '003A' '005A' '007A' '009A' '012A' '018A' '019A'
#  '023A' '029A' '033A' '036A' '038A' '040A' '045A' '048A' '052A' '054A'
#  '057A' '058A' '062A' '063A' '066A' '075A' '092A' '099A' '104A' '108A'
#  '109A' '111A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'000A'}
# Removed from Training/Validation Set:
# {'091A'}
# Moved to Test Set:
# {'091A'}
# Removed from Test Set
# {'000A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '002A' '004A' '006A' '008A' '010A' '011A' '013B' '014A'
#  '014B' '015A' '016A' '019B' '020A' '021A' '022A' '023B' '024A' '025A'
#  '025B' '025C' '026A' '026B' '026C' '027A' '028A' '031A' '032A' '034A'
#  '035A' '037A' '039A' '041A' '042A' '043A' '044A' '046A' '047A' '049A'
#  '050A' '051A' '051B' '053A' '055A' '056A' '059A' '060A' '061A' '064A'
#  '065A' '067A' '068A' '069A' '070A' '071A' '072A' '073A' '074A' '076A'
#  '087A' '088A' '090A' '093A' '094A' '095A' '096A' '097A' '097B' '100A'
#  '101A' '102A' '103A' '105A' '106A' '110A' '113A' '115A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['001A' '002B' '003A' '005A' '007A' '009A' '012A' '018A' '019A' '023A'
#  '029A' '033A' '036A' '038A' '040A' '045A' '048A' '052A' '054A' '057A'
#  '058A' '062A' '063A' '066A' '075A' '091A' '092A' '099A' '104A' '108A'
#  '109A' '111A']
# Length of X_train_val:
# 705
# Length of y_train_val:
# 705
# Length of groups_train_val:
# 705
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     387
# senior    143
# kitten    137
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     219
# senior     43
# kitten     39
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     425
# senior    143
# kitten    137
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     181
# senior     43
# kitten     39
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 425, 2: 143, 1: 137})
# Epoch 1/1500
# 12/12 [==============================] - 1s 4ms/step - loss: 1.2034 - accuracy: 0.5021
# Epoch 2/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.6185 - accuracy: 0.7149
# Epoch 3/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3877 - accuracy: 0.8000
# Epoch 4/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2814 - accuracy: 0.8525
# Epoch 5/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2568 - accuracy: 0.8738
# Epoch 6/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1891 - accuracy: 0.9078
# Epoch 7/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1543 - accuracy: 0.9206
# Epoch 8/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1421 - accuracy: 0.9362
# Epoch 9/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0967 - accuracy: 0.9518
# Epoch 10/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0905 - accuracy: 0.9617
# Epoch 11/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0723 - accuracy: 0.9589
# Epoch 12/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0523 - accuracy: 0.9773
# Epoch 13/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0381 - accuracy: 0.9830
# Epoch 14/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0294 - accuracy: 0.9915
# Epoch 15/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0346 - accuracy: 0.9901
# Epoch 16/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0347 - accuracy: 0.9901
# Epoch 17/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0487 - accuracy: 0.9716
# Epoch 18/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0343 - accuracy: 0.9844
# Epoch 19/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0317 - accuracy: 0.9901
# Epoch 20/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0218 - accuracy: 0.9943
# Epoch 21/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0313 - accuracy: 0.9872
# Epoch 22/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0285 - accuracy: 0.9915
# Epoch 23/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0329 - accuracy: 0.9901
# Epoch 24/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0311 - accuracy: 0.9858
# Epoch 25/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0240 - accuracy: 0.9887
# Epoch 26/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0305 - accuracy: 0.9858
# Epoch 27/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0173 - accuracy: 0.9929
# Epoch 28/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0256 - accuracy: 0.9887
# Epoch 29/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0192 - accuracy: 0.9915
# Epoch 30/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0219 - accuracy: 0.9929
# Epoch 31/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0200 - accuracy: 0.9901
# Epoch 32/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0151 - accuracy: 0.9943
# Epoch 33/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0189 - accuracy: 0.9943
# Epoch 34/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0168 - accuracy: 0.9957
# Epoch 35/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0184 - accuracy: 0.9915
# Epoch 36/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0217 - accuracy: 0.9943
# Epoch 37/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0297 - accuracy: 0.9872
# Epoch 38/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0253 - accuracy: 0.9858
# Epoch 39/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0224 - accuracy: 0.9943
# Epoch 40/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0186 - accuracy: 0.9915
# Epoch 41/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0147 - accuracy: 0.9929
# Epoch 42/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0137 - accuracy: 0.9929
# Epoch 43/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0084 - accuracy: 0.9986
# Epoch 44/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0098 - accuracy: 1.0000
# Epoch 45/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0104 - accuracy: 0.9972
# Epoch 46/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0068 - accuracy: 0.9986
# Epoch 47/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0058 - accuracy: 1.0000
# Epoch 48/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0104 - accuracy: 0.9957
# Epoch 49/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0117 - accuracy: 0.9957
# Epoch 50/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0223 - accuracy: 0.9872
# Epoch 51/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0136 - accuracy: 0.9943
# Epoch 52/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0082 - accuracy: 0.9986
# Epoch 53/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0107 - accuracy: 0.9929
# Epoch 54/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0100 - accuracy: 0.9957
# Epoch 55/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 56/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0108 - accuracy: 0.9957
# Epoch 57/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0063 - accuracy: 1.0000
# Epoch 58/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0070 - accuracy: 0.9986
# Epoch 59/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0065 - accuracy: 0.9986
# Epoch 60/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0116 - accuracy: 0.9943
# Epoch 61/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 62/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0071 - accuracy: 0.9986
# Epoch 63/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 64/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0055 - accuracy: 0.9986
# Epoch 65/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0087 - accuracy: 0.9972
# Epoch 66/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0077 - accuracy: 0.9972
# Epoch 67/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0093 - accuracy: 0.9943
# Epoch 68/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0062 - accuracy: 0.9986
# Epoch 69/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0042 - accuracy: 0.9986
# Epoch 70/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0067 - accuracy: 0.9972
# Epoch 71/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0109 - accuracy: 0.9957
# Epoch 72/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0138 - accuracy: 0.9972
# Epoch 73/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0121 - accuracy: 0.9943
# Epoch 74/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0072 - accuracy: 0.9972
# Epoch 75/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0046 - accuracy: 0.9986
# Epoch 76/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0066 - accuracy: 0.9972
# Epoch 77/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0076 - accuracy: 0.9972
# Epoch 78/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0062 - accuracy: 0.9986
# Epoch 79/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0034 - accuracy: 0.9986
# Epoch 80/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0067 - accuracy: 0.9972
# Epoch 81/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0043 - accuracy: 1.0000
# Epoch 82/1500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0048 - accuracy: 0.9986
# Epoch 83/1500
# 12/12 [==============================] - 0s 16ms/step - loss: 0.0052 - accuracy: 0.9972
# Epoch 84/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0031 - accuracy: 0.9986
# Epoch 85/1500
# 12/12 [==============================] - ETA: 0s - loss: 0.0080 - accuracy: 0.9957Restoring model weights from the end of the best epoch: 55.
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0080 - accuracy: 0.9957
# Epoch 85: early stopping
# 9/9 [==============================] - 0s 1ms/step - loss: 2.3368 - accuracy: 0.6730
# 9/9 [==============================] - 0s 1ms/step
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adamax` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adamax`.
# Majority Vote Accuracy for cat_id for this fold: 0.84 (27/32)
# Before appending - Cat IDs: 183, Predictions: 183, Actuals: 183, Gender: 183
# After appending - Cat IDs: 446, Predictions: 446, Actuals: 446, Gender: 446
# Final Test Results - Loss: 2.3367550373077393, Accuracy: 0.6730037927627563, Precision: 0.5703706765311675, Recall: 0.6232837073130019, F1 Score: 0.5908448273461732
# Confusion Matrix:
#  [[131  20  30]
#  [  7  32   0]
#  [ 28   1  14]]
# outer_fold 3
# Train Set Group Distribution:
# 046A    66
# 000A    39
# 002B    36
# 103A    33
# 047A    30
# 057A    28
# 020A    23
# 055A    20
# 000B    20
# 059A    18
# 029A    17
# 019A    17
# 097A    16
# 101A    16
# 001A    15
# 042A    14
# 028A    14
# 097B    14
# 111A    13
# 002A    13
# 005A    11
# 068A    11
# 063A    11
# 036A    11
# 071A    10
# 014B    10
# 040A    10
# 015A    10
# 051B     9
# 072A     9
# 033A     9
# 022A     9
# 045A     9
# 013B     8
# 095A     8
# 099A     7
# 117A     7
# 027A     7
# 031A     7
# 050A     7
# 108A     6
# 023A     6
# 008A     6
# 025C     6
# 109A     6
# 007A     6
# 023B     5
# 034A     5
# 012A     5
# 062A     5
# 075A     5
# 070A     5
# 052A     4
# 009A     4
# 104A     4
# 003A     4
# 105A     4
# 056A     3
# 011A     3
# 113A     3
# 006A     3
# 064A     3
# 058A     3
# 102A     2
# 093A     2
# 038A     2
# 069A     2
# 066A     2
# 054A     2
# 018A     2
# 032A     2
# 115A     1
# 041A     1
# 076A     1
# 110A     1
# 004A     1
# 096A     1
# 088A     1
# 091A     1
# 048A     1
# 024A     1
# 092A     1
# 049A     1
# 026C     1
# 026B     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 074A    25
# 067A    20
# 106A    15
# 039A    12
# 116A    12
# 051A    12
# 025A    11
# 016A    11
# 065A     9
# 094A     8
# 010A     8
# 053A     7
# 021A     6
# 037A     6
# 044A     5
# 026A     4
# 035A     4
# 060A     3
# 014A     3
# 061A     2
# 087A     2
# 025B     2
# 043A     1
# 073A     1
# 090A     1
# 019B     1
# 100A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    325
# M    258
# F    193
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# M    98
# F    64
# X    30
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [002A, 028A, 070A, 033A, 000B, 071A, 020A, 000...
# kitten    [046A, 042A, 014B, 110A, 109A, 040A, 047A, 049...
# senior    [117A, 057A, 113A, 051B, 024A, 097A, 059A, 055...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [026A, 065A, 053A, 021A, 010A, 074A, 067A, 025...
# kitten                                         [044A, 043A]
# senior           [106A, 090A, 116A, 051A, 094A, 016A, 061A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 56, 'kitten': 14, 'senior': 15}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 18, 'kitten': 2, 'senior': 7}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '004A' '005A' '006A' '007A'
#  '008A' '009A' '011A' '012A' '013B' '014B' '015A' '018A' '019A' '020A'
#  '022A' '023A' '023B' '024A' '025C' '026B' '026C' '027A' '028A' '029A'
#  '031A' '032A' '033A' '034A' '036A' '038A' '040A' '041A' '042A' '045A'
#  '046A' '047A' '048A' '049A' '050A' '051B' '052A' '054A' '055A' '056A'
#  '057A' '058A' '059A' '062A' '063A' '064A' '066A' '068A' '069A' '070A'
#  '071A' '072A' '075A' '076A' '088A' '091A' '092A' '093A' '095A' '096A'
#  '097A' '097B' '099A' '101A' '102A' '103A' '104A' '105A' '108A' '109A'
#  '110A' '111A' '113A' '115A' '117A']
# Unique Test Group IDs:
# ['010A' '014A' '016A' '019B' '021A' '025A' '025B' '026A' '035A' '037A'
#  '039A' '043A' '044A' '051A' '053A' '060A' '061A' '065A' '067A' '073A'
#  '074A' '087A' '090A' '094A' '100A' '106A' '116A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '004A' '005A' '006A' '007A'
#  '008A' '009A' '011A' '012A' '013B' '014B' '015A' '018A' '019A' '020A'
#  '022A' '023A' '023B' '024A' '025C' '026B' '026C' '027A' '028A' '029A'
#  '031A' '032A' '033A' '034A' '036A' '038A' '040A' '041A' '042A' '045A'
#  '046A' '047A' '048A' '049A' '050A' '051B' '052A' '054A' '055A' '056A'
#  '057A' '058A' '059A' '062A' '063A' '064A' '066A' '068A' '069A' '070A'
#  '071A' '072A' '075A' '076A' '088A' '091A' '092A' '093A' '095A' '096A'
#  '097A' '097B' '099A' '101A' '102A' '103A' '104A' '105A' '108A' '109A'
#  '110A' '111A' '113A' '115A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['010A' '014A' '016A' '019B' '021A' '025A' '025B' '026A' '035A' '037A'
#  '039A' '043A' '044A' '051A' '053A' '060A' '061A' '065A' '067A' '073A'
#  '074A' '087A' '090A' '094A' '100A' '106A' '116A']
# Length of X_train_val:
# 776
# Length of y_train_val:
# 776
# Length of groups_train_val:
# 776
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     481
# kitten    170
# senior    125
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     125
# senior     61
# kitten      6
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     481
# kitten    170
# senior    125
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     125
# senior     61
# kitten      6
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 481, 1: 170, 2: 125})
# Epoch 1/1500
# 13/13 [==============================] - 1s 4ms/step - loss: 1.2216 - accuracy: 0.5374
# Epoch 2/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.5758 - accuracy: 0.6817
# Epoch 3/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.4374 - accuracy: 0.7693
# Epoch 4/1500
# 13/13 [==============================] - 0s 4ms/step - loss: 0.
1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0257 - accuracy: 0.9948
# Epoch 69/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0391 - accuracy: 0.9832
# Epoch 70/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0274 - accuracy: 0.9858
# Epoch 71/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0231 - accuracy: 0.9923
# Epoch 72/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0211 - accuracy: 0.9910
# Epoch 73/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0202 - accuracy: 0.9910
# Epoch 74/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0485 - accuracy: 0.9807
# Epoch 75/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0277 - accuracy: 0.9884
# Epoch 76/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0326 - accuracy: 0.9884
# Epoch 77/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0175 - accuracy: 0.9910
# Epoch 78/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0151 - accuracy: 0.9884
# Epoch 79/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0239 - accuracy: 0.9910
# Epoch 80/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0163 - accuracy: 0.9936
# Epoch 81/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0157 - accuracy: 0.9948
# Epoch 82/1500
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0252 - accuracy: 0.9871
# Epoch 83/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0154 - accuracy: 0.9948
# Epoch 84/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0155 - accuracy: 0.9923
# Epoch 85/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0112 - accuracy: 0.9936
# Epoch 86/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0103 - accuracy: 0.9961
# Epoch 87/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0269 - accuracy: 0.9923
# Epoch 88/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0289 - accuracy: 0.9897
# Epoch 89/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0138 - accuracy: 0.9987
# Epoch 90/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0332 - accuracy: 0.9871
# Epoch 91/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0182 - accuracy: 0.9936
# Epoch 92/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0314 - accuracy: 0.9871
# Epoch 93/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0136 - accuracy: 0.9936
# Epoch 94/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0081 - accuracy: 0.9987
# Epoch 95/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0124 - accuracy: 0.9923
# Epoch 96/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0139 - accuracy: 0.9936
# Epoch 97/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0137 - accuracy: 0.9923
# Epoch 98/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0172 - accuracy: 0.9936
# Epoch 99/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0118 - accuracy: 0.9936
# Epoch 100/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0085 - accuracy: 0.9987
# Epoch 101/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0210 - accuracy: 0.9923
# Epoch 102/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 103/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0205 - accuracy: 0.9923
# Epoch 104/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0064 - accuracy: 0.9974
# Epoch 105/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 106/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0073 - accuracy: 1.0000
# Epoch 107/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0053 - accuracy: 0.9987
# Epoch 108/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0119 - accuracy: 0.9974
# Epoch 109/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0205 - accuracy: 0.9948
# Epoch 110/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0399 - accuracy: 0.9910
# Epoch 111/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0216 - accuracy: 0.9910
# Epoch 112/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0391 - accuracy: 0.9807
# Epoch 113/1500
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0298 - accuracy: 0.9910
# ...
# 034A     5
# 070A     5
# 035A     4
# 104A     4
# 009A     4
# 026A     4
# 003A     4
# 052A     4
# 105A     4
# 014A     3
# 006A     3
# 011A     3
# 060A     3
# 058A     3
# 056A     3
# 113A     3
# 025B     2
# 038A     2
# 018A     2
# 061A     2
# 087A     2
# 066A     2
# 032A     2
# 054A     2
# 102A     2
# 026B     1
# 019B     1
# 004A     1
# 076A     1
# 049A     1
# 073A     1
# 096A     1
# 043A     1
# 048A     1
# 092A     1
# 091A     1
# 090A     1
# 100A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 046A    66
# 020A    23
# 055A    20
# 059A    18
# 101A    16
# 028A    14
# 097B    14
# 042A    14
# 068A    11
# 014B    10
# 071A    10
# 015A    10
# 051B     9
# 022A     9
# 095A     8
# 013B     8
# 117A     7
# 027A     7
# 023B     5
# 064A     3
# 093A     2
# 069A     2
# 110A     1
# 088A     1
# 026C     1
# 041A     1
# 115A     1
# 024A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    274
# X    220
# F    182
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    135
# M     82
# F     75
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [002A, 070A, 033A, 000B, 000A, 026A, 065A, 053...
# kitten    [109A, 040A, 047A, 049A, 045A, 048A, 111A, 044...
# senior    [106A, 057A, 090A, 113A, 116A, 051A, 097A, 094...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [028A, 071A, 020A, 015A, 023B, 026C, 068A, 013...
# kitten                 [046A, 042A, 014B, 110A, 041A, 115A]
# senior                 [117A, 051B, 024A, 059A, 055A, 093A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 58, 'kitten': 10, 'senior': 16}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 16, 'kitten': 6, 'senior': 6}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '004A' '005A' '006A' '007A'
#  '008A' '009A' '010A' '011A' '012A' '014A' '016A' '018A' '019A' '019B'
#  '021A' '023A' '025A' '025B' '025C' '026A' '026B' '029A' '031A' '032A'
#  '033A' '034A' '035A' '036A' '037A' '038A' '039A' '040A' '043A' '044A'
#  '045A' '047A' '048A' '049A' '050A' '051A' '052A' '053A' '054A' '056A'
#  '057A' '058A' '060A' '061A' '062A' '063A' '065A' '066A' '067A' '070A'
#  '072A' '073A' '074A' '075A' '076A' '087A' '090A' '091A' '092A' '094A'
#  '096A' '097A' '099A' '100A' '102A' '103A' '104A' '105A' '106A' '108A'
#  '109A' '111A' '113A' '116A']
# Unique Test Group IDs:
# ['013B' '014B' '015A' '020A' '022A' '023B' '024A' '026C' '027A' '028A'
#  '041A' '042A' '046A' '051B' '055A' '059A' '064A' '068A' '069A' '071A'
#  '088A' '093A' '095A' '097B' '101A' '110A' '115A' '117A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'046A'}
# Removed from Training/Validation Set:
# {'111A'}
# Moved to Test Set:
# {'111A'}
# Removed from Test Set
# {'046A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '004A' '005A' '006A' '007A'
#  '008A' '009A' '010A' '011A' '012A' '014A' '016A' '018A' '019A' '019B'
#  '021A' '023A' '025A' '025B' '025C' '026A' '026B' '029A' '031A' '032A'
#  '033A' '034A' '035A' '036A' '037A' '038A' '039A' '040A' '043A' '044A'
#  '045A' '046A' '047A' '048A' '049A' '050A' '051A' '052A' '053A' '054A'
#  '056A' '057A' '058A' '060A' '061A' '062A' '063A' '065A' '066A' '067A'
#  '070A' '072A' '073A' '074A' '075A' '076A' '087A' '090A' '091A' '092A'
#  '094A' '096A' '097A' '099A' '100A' '102A' '103A' '104A' '105A' '106A'
#  '108A' '109A' '113A' '116A']
# AFTER SWAP - Unique Test Group IDs:
# ['013B' '014B' '015A' '020A' '022A' '023B' '024A' '026C' '027A' '028A'
#  '041A' '042A' '051B' '055A' '059A' '064A' '068A' '069A' '071A' '088A'
#  '093A' '095A' '097B' '101A' '110A' '111A' '115A' '117A']
# Length of X_train_val:
# 729
# Length of y_train_val:
# 729
# Length of groups_train_val:
# 729
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     464
# senior    129
# kitten     83
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     142
# kitten     93
# senior     57
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     464
# kitten    136
# senior    129
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     142
# senior     57
# kitten     40
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 464, 1: 136, 2: 129})
# Epoch 1/1500
# 12/12 [==============================] - 1s 4ms/step - loss: 1.1640 - accuracy: 0.5391
# Epoch 2/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.6550 - accuracy: 0.6735
# Epoch 3/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4024 - accuracy: 0.7517
# Epoch 4/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3068 - accuracy: 0.8560
# Epoch 5/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2093 - accuracy: 0.8889
# Epoch 6/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1829 - accuracy: 0.9081
# Epoch 7/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1346 - accuracy: 0.9355
# Epoch 8/1500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1428 - accuracy: 0.9177
# Epoch 9/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0948 - accuracy: 0.9561
# Epoch 10/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0931 - accuracy: 0.9643
# Epoch 11/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0744 - accuracy: 0.9602
# Epoch 12/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0623 - accuracy: 0.9698
# Epoch 13/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0810 - accuracy: 0.9712
# Epoch 14/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0602 - accuracy: 0.9657
# Epoch 15/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0567 - accuracy: 0.9712
# Epoch 16/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0628 - accuracy: 0.9726
# Epoch 17/1500
# 12/12 [==============================] - 0s 15ms/step - loss: 0.0879 - accuracy: 0.9753
# Epoch 18/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0471 - accuracy: 0.9753
# Epoch 19/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0363 - accuracy: 0.9808
# Epoch 20/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0394 - accuracy: 0.9835
# Epoch 21/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0317 - accuracy: 0.9849
# Epoch 22/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0410 - accuracy: 0.9849
# Epoch 23/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0309 - accuracy: 0.9890
# Epoch 24/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0518 - accuracy: 0.9726
# Epoch 25/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0429 - accuracy: 0.9767
# Epoch 26/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0264 - accuracy: 0.9863
# Epoch 27/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0281 - accuracy: 0.9931
# Epoch 28/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0276 - accuracy: 0.9863
# Epoch 29/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0193 - accuracy: 0.9877
# Epoch 30/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0146 - accuracy: 0.9931
# Epoch 31/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0190 - accuracy: 0.9918
# Epoch 32/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0125 - accuracy: 0.9959
# Epoch 33/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0197 - accuracy: 0.9904
# Epoch 34/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0068 - accuracy: 0.9959
# Epoch 35/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0176 - accuracy: 0.9890
# Epoch 36/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0101 - accuracy: 0.9959
# Epoch 37/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0082 - accuracy: 0.9973
# Epoch 38/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0041 - accuracy: 0.9986
# Epoch 39/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0106 - accuracy: 0.9945
# Epoch 40/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0067 - accuracy: 0.9986
# Epoch 41/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0041 - accuracy: 1.0000
# Epoch 42/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0055 - accuracy: 0.9986
# Epoch 43/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0144 - accuracy: 0.9904
# Epoch 44/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0048 - accuracy: 0.9986
# Epoch 45/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0054 - accuracy: 0.9986
# Epoch 46/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0090 - accuracy: 0.9973
# Epoch 47/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0268 - accuracy: 0.9890
# Epoch 48/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0208 - accuracy: 0.9890
# Epoch 49/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0121 - accuracy: 0.9931
# Epoch 50/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0042 - accuracy: 1.0000
# Epoch 51/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0054 - accuracy: 0.9986
# Epoch 52/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0135 - accuracy: 0.9945
# Epoch 53/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0095 - accuracy: 0.9931
# Epoch 54/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0074 - accuracy: 0.9959
# Epoch 55/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 56/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0051 - accuracy: 0.9959
# Epoch 57/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0101 - accuracy: 0.9986
# Epoch 58/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0101 - accuracy: 0.9945
# Epoch 59/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0084 - accuracy: 0.9959
# Epoch 60/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0133 - accuracy: 0.9973
# Epoch 61/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0113 - accuracy: 0.9973
# Epoch 62/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0065 - accuracy: 0.9959
# Epoch 63/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0065 - accuracy: 0.9986
# Epoch 64/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0065 - accuracy: 0.9959
# Epoch 65/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0055 - accuracy: 0.9973
# Epoch 66/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0058 - accuracy: 0.9973
# Epoch 67/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0117 - accuracy: 0.9959
# Epoch 68/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0061 - accuracy: 0.9973
# Epoch 69/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 70/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0091 - accuracy: 0.9973
# Epoch 71/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0129 - accuracy: 0.9931
# Epoch 72/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0077 - accuracy: 0.9945
# Epoch 73/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0045 - accuracy: 0.9986
# Epoch 74/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 75/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0059 - accuracy: 0.9973
# Epoch 76/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0045 - accuracy: 0.9973
# Epoch 77/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 78/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0027 - accuracy: 0.9986
# Epoch 79/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0025 - accuracy: 0.9986
# Epoch 80/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 81/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0111 - accuracy: 0.9986
# Epoch 82/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0047 - accuracy: 0.9945
# Epoch 83/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0090 - accuracy: 0.9959
# Epoch 84/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0035 - accuracy: 0.9986
# Epoch 85/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0053 - accuracy: 0.9986
# Epoch 86/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0033 - accuracy: 0.9986
# Epoch 87/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0075 - accuracy: 0.9986
# Epoch 88/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0040 - accuracy: 0.9986
# Epoch 89/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0060 - accuracy: 0.9945
# Epoch 90/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0032 - accuracy: 0.9986
# Epoch 91/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0043 - accuracy: 1.0000
# Epoch 92/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0037 - accuracy: 0.9986
# Epoch 93/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 94/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0123 - accuracy: 0.9973
# Epoch 95/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0052 - accuracy: 0.9973
# Epoch 96/1500
# 12/12 [==============================] - 0s 15ms/step - loss: 0.0069 - accuracy: 0.9959
# Epoch 97/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 98/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0122 - accuracy: 0.9973
# Epoch 99/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0051 - accuracy: 0.9973
# Epoch 100/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0101 - accuracy: 0.9931
# Epoch 101/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0075 - accuracy: 0.9986
# Epoch 102/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0137 - accuracy: 0.9918
# Epoch 103/1500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 104/1500
# 11/12 [==========================>...] - ETA: 0s - loss: 0.0074 - accuracy: 0.9957    Restoring model weights from the end of the best epoch: 74.
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0071 - accuracy: 0.9959
# Epoch 104: early stopping
# 8/8 [==============================] - 0s 1ms/step - loss: 3.0770 - accuracy: 0.6192
# 8/8 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.71 (20/28)
# Before appending - Cat IDs: 638, Predictions: 638, Actuals: 638, Gender: 638
# After appending - Cat IDs: 877, Predictions: 877, Actuals: 877, Gender: 877
# Final Test Results - Loss: 3.0770366191864014, Accuracy: 0.6192468404769897, Precision: 0.6152547874066862, Recall: 0.5921402685116548, F1 Score: 0.5946078431372549
# Confusion Matrix:
#  [[93  9 40]
#  [14 21  5]
#  [23  0 34]]
#
# Final Average F1-Score across all UNSEEN TEST sets: 0.5251883867588002
#
# Final Average Loss across all UNSEEN TEST sets: 3.010000228881836
#
# Final Average Accuracy across all UNSEEN TEST sets: 0.6286039799451828
#
# Final Average Precision across all UNSEEN TEST sets: 0.5422507367646219
#
# Final Average Recall across all UNSEEN TEST sets: 0.5597348166960741

# %%
seed_5_folds_values = [unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1]

seed_5_training_acc_values = cv_training_acc_total

# Plotting all fold metrics
seed_5_folds_plot = plot_all_metrics(unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1, "Folds", "Fold Number")

# %% [markdown]
# ## Majority Voting on Total Entries per cat_id

# %%
# Debugging print statements
print(f'Checking - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
# Out:
# Checking - Cat IDs: 877, Predictions: 877, Actuals: 877, Gender: 877

# %%
# Create results df
full_results = pd.DataFrame({
    'cat_id': all_cat_ids,
    'predicted_age_group': all_predicted_age_groups,
    'actual_age_group': all_actual_age_groups,
    'all_gender': all_gender
})

# create a correct majority prediction column
full_results['correct'] = full_results['predicted_age_group'] == full_results['actual_age_group']

# %%
# Group by cat_id and aggregate predicted age groups
majority_votes = full_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first()

# Calculate the accuracy of majority voting
correct_predictions = (majority_votes == actual_groups).sum()
total_cats = len(actual_groups)
majority_vote_accuracy = correct_predictions / total_cats

logger(f"Overall Majority Vote Accuracy for cat_id: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

# store for final evaluation 
all_majority_vote_accuracies.append(majority_vote_accuracy)
# Out:
# Overall Majority Vote Accuracy for cat_id: 0.76 (84/110)

# %%
# Detailed df with predictions, actual labels, and comparison including majority vote
detailed_results = full_results.groupby('cat_id').apply(
    lambda x: pd.Series({
        'Predictions': list(x['predicted_age_group']),
        'Majority Vote': x['predicted_age_group'].mode()[0],
        'Actual Age Group': x['actual_age_group'].iloc[0],
        'Correct Majority Vote': x['predicted_age_group'].mode()[0] == x['actual_age_group'].iloc[0]
    })
).reset_index()

# Convert to DataFrame for better formatting and display
detailed_results = pd.DataFrame(detailed_results)

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 10)
pd.set_option('display.width', 1000)

sorted_detailed_results = detailed_results.sort_values(by='Correct Majority Vote', ascending=False)

# Display the sorted DataFrame
sorted_detailed_results
# Out:
#     cat_id                                        Predictions Majority Vote Actual Age Group  Correct Majority Vote
# 0     000B  [adult, adult, senior, adult, adult, adult, ad...         adult            adult                   True
# 45    039A  [senior, adult, adult, adult, senior, senior, ...         adult            adult                   True
# 74    068A  [adult, adult, adult, adult, senior, senior, s...         adult            adult                   True
# 73    067A  [adult, adult, kitten, adult, adult, adult, ad...         adult            adult                   True
# 72    066A                                    [adult, kitten]         adult            adult                   True
# 71    065A  [adult, adult, adult, kitten, kitten, kitten, ...         adult            adult                   True
# 70    064A                             [kitten, adult, adult]         adult            adult                   True
# 69    063A  [kitten, adult, kitten, adult, adult, adult, a...         adult            adult                   True
# 68    062A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 65    059A  [senior, senior, senior, senior, adult, senior...        senior           senior                   True
# 60    054A                                   [senior, senior]        senior           senior                   True
# 59    053A  [adult, senior, senior, adult, adult, adult, s...         adult            adult                   True
# 58    052A                       [adult, adult, adult, adult]         adult            adult                   True
# 1     001A  [adult, adult, adult, adult, senior, adult, ad...         adult            adult                   True
# 54    049A                                           [kitten]        kitten           kitten                   True
# 53    048A                                           [kitten]        kitten           kitten                   True
# 51    045A  [kitten, adult, kitten, kitten, kitten, kitten...        kitten           kitten                   True
# 50    044A             [kitten, kitten, adult, kitten, adult]        kitten           kitten                   True
# 49    043A                                           [kitten]        kitten           kitten                   True
# 48    042A  [kitten, adult, kitten, adult, kitten, kitten,...        kitten           kitten                   True
# 47    041A                                           [kitten]        kitten           kitten                   True
# 75    069A                                    [adult, senior]         adult            adult                   True
# 76    070A               [adult, senior, adult, adult, adult]         adult            adult                   True
# 77    071A  [adult, senior, adult, adult, adult, senior, s...         adult            adult                   True
# 94    099A  [adult, adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 107   115A                                           [kitten]        kitten           kitten                   True
# 106   113A                           [senior, senior, senior]        senior           senior                   True
# 105   111A  [kitten, kitten, kitten, kitten, kitten, kitte...        kitten           kitten                   True
#
# 92    097A  [adult, adult, senior, adult, adult, adult, ki...         adult           senior                  False
# 61    055A  [senior, adult, senior, senior, adult, senior,...         adult           senior                  False
# 26    023B             [adult, adult, senior, senior, senior]        senior            adult                  False
# 67    061A                                    [adult, senior]         adult           senior                  False
# 66    060A                            [kitten, adult, kitten]        kitten            adult                  False
# 64    058A                             [kitten, adult, adult]         adult           senior                  False
# 63    057A  [adult, adult, senior, adult, adult, adult, ad...         adult           senior                  False
# 62    056A                              [adult, adult, adult]         adult           senior                  False
# 18    016A  [kitten, adult, adult, adult, adult, adult, ad...         adult           senior                  False
# 12    011A                             [senior, adult, adult]         adult           senior                  False
# 82    076A                                           [kitten]        kitten            adult                  False
# 16    014B  [senior, adult, senior, senior, senior, kitten...         adult           kitten                  False
# 85    090A                                            [adult]         adult           senior                  False
# 57    051B  [adult, adult, adult, senior, adult, senior, s...         adult           senior                  False
# 88    093A                                     [adult, adult]         adult           senior                  False
# 89    094A  [adult, senior, adult, adult, adult, adult, ad...         adult           senior                  False
# 44    038A                                   [kitten, kitten]        kitten            adult                  False

# %%
# Create df for majority votes
majority_df = majority_votes.reset_index()
majority_df.columns = ['cat_id', 'Majority_Vote']

# Get actual groups for each cat_id
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first().reset_index()

# Merge majority votes with actual groups
majority_with_actual = pd.merge(majority_df, actual_groups, on='cat_id')

# Add a column to check if the majority vote was correct
majority_with_actual['Majority_Correct'] = majority_with_actual['Majority_Vote'] == majority_with_actual['actual_age_group']

# Count correct majority votes per class
correct_majority_votes_per_class = majority_with_actual.groupby('actual_age_group')['Majority_Correct'].sum()

print("Correct Majority Votes per Class:")
print(correct_majority_votes_per_class)
# Out:
# Correct Majority Votes per Class:
# actual_age_group
# adult     67
# kitten    12
# senior     5
# Name: Majority_Correct, dtype: int64

# %%
# Calculate the total count and the number of correct predictions for each class
class_stats = majority_with_actual.groupby('actual_age_group').agg(
    total_count=('Majority_Correct', 'size'),  # Total number of cases per class
    correct_count=('Majority_Correct', 'sum')  # Sum of correct predictions per class
).reset_index()

# Calculate accuracy for each class
class_stats['accuracy'] = class_stats['correct_count'] / class_stats['total_count'] * 100

# store for final evaluation 
all_majority_vote_details.append(class_stats)

# Log detailed stats
print("Detailed Class Statistics for Majority Votes:")
print(class_stats)
# Out:
# Detailed Class Statistics for Majority Votes:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult           73             67  91.780822
# 1           kitten           15             12  80.000000
# 2           senior           22              5  22.727273

# %%
# Plot for Detailed Class Statistics for Majority Votes
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Accuracy of Majority Votes by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Detailed Class Statistics

# %%
# Calculate the total count and the number of correct predictions for each class
class_stats = full_results.groupby('actual_age_group').agg(
    total_count=('correct', 'size'),
    correct_count=('correct', 'sum')
).reset_index()

# Calculate accuracy for each class
class_stats['accuracy'] = class_stats['correct_count'] / class_stats['total_count'] * 100

# store for final evaluation 
all_class_stats.append(class_stats)

# Log the detailed stats
print("Detailed Class Statistics:")
print(class_stats)
# Out:
# Detailed Class Statistics:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult          568            418  73.591549
# 1           kitten          123             67  54.471545
# 2           senior          186             69  37.096774

# %%
# Plot for Detailed Class Statistics (Overall)
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Overall Accuracy by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Gender Exploration

# %%
# Group by gender and calculate the total count, correct predictions, and accuracy
gender_stats = full_results.groupby('all_gender').agg(
    count=('cat_id', 'size'),  # Total number of cases per gender
    correct=('correct', 'sum')  # Sum of correct predictions per gender
).reset_index()

# Calculate accuracy for each gender
gender_stats['accuracy'] = (gender_stats['correct'] / gender_stats['count'] * 100).round(2)

# Display the DataFrame
print("Accuracy by Gender:")
print(gender_stats)

# store for final evaluation 
all_gender_stats.append(gender_stats)
# Out:
# Accuracy by Gender:
#   all_gender  count  correct  accuracy
# 0          F    218      138     63.30
# 1          M    357      240     67.23
# 2          X    302      176     58.28

# %%
# Plot for Accuracy by Gender
styled_barplot(gender_stats, 'all_gender', 'accuracy', 
               'Accuracy by Gender', 
               'Gender', 'Accuracy (%)')

# %% [markdown]
# ### Log current total CV Stats

# %%
print("Total Majority Vote Accuracy so far:", all_majority_vote_accuracies)
print("Total Class Statistics so far:\n", all_class_stats) 
print("Total Majority Vote Statistics so far:\n", all_majority_vote_details) 
print("Total Gender Accuracy so far:\n", all_gender_stats)
# Out:
# Total Majority Vote Accuracy so far: [0.7909090909090909, 0.7545454545454545, 0.8, 0.7545454545454545, 0.7636363636363637]
# Total Class Statistics so far:
#  [  actual_age_group  total_count  correct_count   accuracy
# 0            adult          573            448  78.184991
# 1           kitten          111             59  53.153153
# 2           senior          186             71  38.172043,   actual_age_group  total_count  correct_count   accuracy
# 0            adult          568            415  73.063380
# 1           kitten          120             62  51.666667
# 2           senior          186             58  31.182796,   actual_age_group  total_count  correct_count   accuracy
# 0            adult          574            434  75.609756
# 1           kitten          117             61  52.136752
# 2           senior          186             69  37.096774,   actual_age_group  total_count  correct_count   accuracy
# 0            adult          584            459  78.595890
# 1           kitten          115             60  52.173913
# 2           senior          186             72  38.709677,   actual_age_group  total_count  correct_count   accuracy
# 0            adult          568            418  73.591549
# 1           kitten          123             67  54.471545
# 2           senior          186             69  37.096774]
# Total Majority Vote Statistics so far:
#  [  actual_age_group  total_count  correct_count   accuracy
# 0            adult           73             69  94.520548
# 1           kitten           15             13  86.666667
# 2           senior           22              5  22.727273,   actual_age_group  total_count  correct_count   accuracy
# 0            adult           73             68  93.150685
# 1           kitten           15             11  73.333333
# 2           senior           22              4  18.181818,   actual_age_group  total_count  correct_count   accuracy
# 0            adult           73             69  94.520548
# 1           kitten           15             11  73.333333
# 2           senior           22              8  36.363636,   actual_age_group  total_count  correct_count   accuracy
# 0            adult           73             68  93.150685
# 1           kitten           15              9  60.000000
# 2           senior           22              6  27.272727,   actual_age_group  total_count  correct_count   accuracy
# 0            adult           73             67  91.780822
# 1           kitten           15             12  80.000000
# 2           senior           22              5  22.727273]
# Total Gender Accuracy so far:
#  [  all_gender  count  correct  accuracy
# 0          F    218      144     66.06
# 1          M    362      266     73.48
# 2          X    290      168     57.93,   all_gender  count  correct  accuracy
# 0          F    218      126     57.80
# 1          M    357      247     69.19
# 2          X    299      162     54.18,   all_gender  count  correct  accuracy
# 0          F    225      140     62.22
# 1          M    356      264     74.16
# 2          X    296      160     54.05,   all_gender  count  correct  accuracy
# 0          F    218      134     61.47
# 1          M    373      286     76.68
# 2          X    294      171     58.16,   all_gender  count  correct  accuracy
# 0          F    218      138     63.30
# 1          M    357      240     67.23
# 2          X    302      176     58.28]

# %% [markdown]
# # --------------

# %% [markdown]
# # Total Final Results & Analysis

# %%
# Count unique cat_id per age group 
unique_cats_per_age_group = dataframe.groupby('age_group')['cat_id'].nunique()

# Display the counts
print("Unique cat_id counts in original dataframe:", unique_cats_per_age_group)
# Out:
# Unique cat_id counts in original dataframe: age_group
# adult     74
# kitten    16
# senior    22
# Name: cat_id, dtype: int64

# %% [markdown]
# ## Metrics

# %%
# Calculate overall metrics
overall_avg_loss = np.mean(all_losses)
overall_avg_acc = np.mean(all_accuracies)
overall_avg_precision = np.mean(all_precisions)
overall_avg_recall = np.mean(all_recalls)
overall_avg_f1 = np.mean(all_f1)

print("Overall Average Metrics:")
print("Loss:", overall_avg_loss)
print("Accuracy:", overall_avg_acc)
print("Precision:", overall_avg_precision)
print("Recall:", overall_avg_recall)
print("F1 Score:", overall_avg_f1)
# Out:
# Overall Average Metrics:
# Loss: 67.48803970217705
# Accuracy: 0.6425671488046646
# Precision: 0.554983069900503
# Recall: 0.5721664177859408
# F1 Score: 0.54190262489893

# %% [markdown]
# ## Majority Votes

# %%
# Average of majority vote accuracies
average_majority_vote_accuracy = np.mean(all_majority_vote_accuracies)
print("Average Majority Vote Accuracy:", average_majority_vote_accuracy)
# Out:
# Average Majority Vote Accuracy: 0.7727272727272727

# %%
# Concatenate all class stats DataFrames and calculate the mean of accuracies
total_majority_vote_details = pd.concat(all_majority_vote_details)
average_majority_vote_details = total_majority_vote_details.groupby('actual_age_group').agg({
    'total_count': 'sum', 
    'correct_count': 'sum' 
}).reset_index()
average_majority_vote_details['accuracy'] = (average_majority_vote_details['correct_count'] / average_majority_vote_details['total_count']) * 100

print("Average Class Statistics:")
print(average_majority_vote_details)
# Out:
# Average Class Statistics:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult          365            341  93.424658
# 1           kitten           75             56  74.666667
# 2           senior          110             28  25.454545

# %%
# Plot for Detailed Class Statistics for Majority Votes
styled_barplot(average_majority_vote_details, 'actual_age_group', 'accuracy', 
               'Accuracy of Majority Votes by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Detailed Class Statistics

# %%
# Concatenate all class stats DataFrames and calculate the mean of accuracies
total_class_stats = pd.concat(all_class_stats)
average_class_stats = total_class_stats.groupby('actual_age_group').agg({
    'total_count': 'sum',  
    'correct_count': 'sum' 
}).reset_index()
average_class_stats['accuracy'] = (average_class_stats['correct_count'] / average_class_stats['total_count']) * 100

print("Average Class Statistics:")
print(average_class_stats)
# Out:
# Average Class Statistics:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult         2867           2174  75.828392
# 1           kitten          586            309  52.730375
# 2           senior          930            339  36.451613

# %%
# Plot for Detailed Class Statistics (Overall)
styled_barplot(average_class_stats, 'actual_age_group', 'accuracy', 
               'Overall Accuracy by Age Group', 
               'Age Group', 'Accuracy (%)')

# %%
# Concatenate all gender stats DataFrames and calculate the mean of accuracies
total_gender_stats = pd.concat(all_gender_stats)
average_gender_stats = total_gender_stats.groupby('all_gender').agg({
    'count': 'sum',  
    'correct': 'sum'  
}).reset_index()
average_gender_stats['accuracy'] = (average_gender_stats['correct'] / average_gender_stats['count']) * 100

print("Average Gender Accuracy:")
print(average_gender_stats)
# Out:
# Average Gender Accuracy:
#   all_gender  count  correct   accuracy
# 0          F   1097      682  62.169553
# 1          M   1805     1303  72.188366
# 2          X   1481      837  56.515868

# %%
# Plot for Accuracy by Gender
styled_barplot(total_gender_stats, 'all_gender', 'accuracy', 
               'Accuracy by Gender', 
               'Gender', 'Accuracy (%)')

# %% [markdown]
# # Visualisations

# %%
# Plotting all metrics
metrics_across_seeds = plot_all_metrics(average_fold_losses, average_fold_accuracies, average_fold_precisions, average_fold_recalls, average_fold_f1, "Seeds", "Seed Number")

# %% [markdown]
# ## Display the seed folds results together

# %%
# Create a figure with subplots
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(18, 12))  

# Flatten the axes array for easier indexing
axes = axes.flatten()

def plot_metrics_on_axes(ax, losses, accuracies, precisions, recalls, f1, title):
    ax.plot(range(1, len(losses)+1), losses, marker='o', color='blue', label='Loss')
    ax.plot(range(1, len(accuracies)+1), accuracies, marker='o', color='green', label='Accuracy')
    ax.plot(range(1, len(precisions)+1), precisions, marker='o', color='red', label='Precision')
    ax.plot(range(1, len(recalls)+1), recalls, marker='o', color='purple', label='Recall')
    ax.plot(range(1, len(f1)+1), f1, marker='o', color='orange', label='F1 Score')
    ax.set_xticks([1, 2, 3, 4])  # Set x-axis ticks to full integers
    ax.set_title(title)
    ax.set_xlabel('Fold Number')
    ax.set_ylabel('Metric Value')
    ax.legend()
    ax.grid(True)

# Plot onto each axes object
plot_metrics_on_axes(axes[0], *seed_1_folds_values, "Seed 1 Metrics")
plot_metrics_on_axes(axes[1], *seed_2_folds_values, "Seed 2 Metrics")
plot_metrics_on_axes(axes[2], *seed_3_folds_values, "Seed 3 Metrics")
plot_metrics_on_axes(axes[3], *seed_4_folds_values, "Seed 4 Metrics")
plot_metrics_on_axes(axes[4], *seed_5_folds_values, "Seed 5 Metrics")

# Hide the unused subplot 
for ax in axes[5:]:
    ax.set_visible(False)

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# # Statistics

# %% [markdown]
# ### Standard Deviation

# %%
# Calculate the standard deviation for each metric
std_loss = np.std(all_losses)
std_accuracy = np.std(all_accuracies)
std_precision = np.std(all_precisions)
std_recall = np.std(all_recalls)
std_f1 = np.std(all_f1)

print("Standard Deviations:")
print(f"Loss: {std_loss}")
print(f"Accuracy: {std_accuracy}")
print(f"Precision: {std_precision}")
print(f"Recall: {std_recall}")
print(f"F1 Score: {std_f1}")
# Out:
# Standard Deviations:
# Loss: 281.3372147315489
# Accuracy: 0.05088367280781342
# Precision: 0.06577115239312324
# Recall: 0.06621864853662915
# F1 Score: 0.061092785368802346

# %% [markdown]
# ### Interquartile Range

# %%
# Calculate the interquartile range for each metric
iqr_loss = np.percentile(all_losses, 75) - np.percentile(all_losses, 25)
iqr_accuracy = np.percentile(all_accuracies, 75) - np.percentile(all_accuracies, 25)
iqr_precision = np.percentile(all_precisions, 75) - np.percentile(all_precisions, 25)
iqr_recall = np.percentile(all_recalls, 75) - np.percentile(all_recalls, 25)
iqr_f1 = np.percentile(all_f1, 75) - np.percentile(all_f1, 25)

print("Interquartile Ranges:")
print(f"Loss: {iqr_loss}")
print(f"Accuracy: {iqr_accuracy}")
print(f"Precision: {iqr_precision}")
print(f"Recall: {iqr_recall}")
print(f"F1 Score: {iqr_f1}")
# Out:
# Interquartile Ranges:
# Loss: 0.8492361903190613
# Accuracy: 0.0812651664018631
# Precision: 0.07668192004752994
# Recall: 0.10361807260071365
# F1 Score: 0.0778251080768797

# %% [markdown]
# ### Variation

# %%
# Calculate the variation for each metric
var_loss = np.var(all_losses)
var_accuracy = np.var(all_accuracies)
var_precision = np.var(all_precisions)
var_recall = np.var(all_recalls)
var_f1 = np.var(all_f1)

print("Variations:")
print(f"Loss: {var_loss}")
print(f"Accuracy: {var_accuracy}")
print(f"Precision: {var_precision}")
print(f"Recall: {var_recall}")
print(f"F1 Score: {var_f1}")
# Out:
# Variations:
# Loss: 79150.62839290565
# Accuracy: 0.0025891481584126106
# Precision: 0.004325844487119441
# Recall: 0.004384909414017617
# F1 Score: 0.00373232842411855

# %% [markdown]
# ### Levene tests for variation significance between seeds

# %% [markdown]
# #### Levene across seeds for LOSS

# %%
# Levene across seeds for LOSS
stat_val, p_val = levene(seed_1_folds_values[0], seed_2_folds_values[0], seed_3_folds_values[0], seed_4_folds_values[0], seed_5_folds_values[0])
print(f'levene test statistic: {stat_val:.2f}, P-value: {p_val:.3f}')
# Out:
# levene test statistic: 1.00, P-value: 0.436

# %% [markdown]
# #### Levene across seeds for ACCURACY

# %%
# Levene across seeds for ACCURACY
stat_val, p_val = levene(seed_1_folds_values[1], seed_2_folds_values[1], seed_3_folds_values[1], seed_4_folds_values[1], seed_5_folds_values[1])
print(f'levene test statistic: {stat_val:.2f}, P-value: {p_val:.3f}')
# Out:
# levene test statistic: 0.46, P-value: 0.762

# %% [markdown]
# #### Levene across seeds for PRECISION

# %%
# Levene across seeds for PRECISION
stat_val, p_val = levene(seed_1_folds_values[2], seed_2_folds_values[2], seed_3_folds_values[2], seed_4_folds_values[2], seed_5_folds_values[2])
print(f'levene test statistic: {stat_val:.2f}, P-value: {p_val:.3f}')
# Out:
# levene test statistic: 1.44, P-value: 0.271

# %% [markdown]
# #### Levene across seeds for RECALL

# %%
# Levene across seeds for RECALL
stat_val, p_val = levene(seed_1_folds_values[3], seed_2_folds_values[3], seed_3_folds_values[3], seed_4_folds_values[3], seed_5_folds_values[3])
print(f'levene test statistic: {stat_val:.2f}, P-value: {p_val:.3f}')
# Out:
# levene test statistic: 0.46, P-value: 0.762

# %% [markdown]
# #### Levene across seeds for F1

# %%
# Levene across seeds for F1
stat_val, p_val = levene(seed_1_folds_values[4], seed_2_folds_values[4], seed_3_folds_values[4], seed_4_folds_values[4], seed_5_folds_values[4])
print(f'levene test statistic: {stat_val:.2f}, P-value: {p_val:.3f}')
# Out:
# levene test statistic: 2.61, P-value: 0.078

# %% [markdown]
# ## Print out measurements for future further analysis (without rerunning notebook)

# %%
seed_1_folds_values
# Out:
# [[3.1182992458343506,
#   1.9882712364196777,
#   1.9908283948898315,
#   3.383787155151367],
#  [0.553459107875824,
#   0.6768707633018494,
#   0.7450000047683716,
#   0.6543778777122498],
#  [0.6245424542454246,
#   0.4793417366946779,
#   0.6244737543298694,
#   0.6083263714842663],
#  [0.6444444444444445,
#   0.6829534105325666,
#   0.6591483229414263,
#   0.51390350413217],
#  [0.5809290668531795,
#   0.5089355089355089,
#   0.6372718019437877,
#   0.5105746541040658]]

# %%
seed_2_folds_values
# Out:
# [[4.864658832550049, 2.3306498527526855, 1293.802978515625, 3.013449192047119],
#  [0.6635944843292236,
#   0.5794872045516968,
#   0.5766423344612122,
#   0.6382978558540344],
#  [0.62496748657054,
#   0.46446544296006653,
#   0.3963476137389181,
#   0.5351390618513907],
#  [0.6137673814165042,
#   0.49825953773322196,
#   0.4288243257315422,
#   0.5879050807314795],
#  [0.618855032917533,
