# %% [markdown]
# # YAMNet Multi Seed Validation
# #### 5 Random (but reproducible) seeds are selected for 5 different runs of train/test
# #### Models have been optimised and verified on validation sets thoroughly, running a final train/test evaluation here
# #### The setup:
#
# - 4 fold StratifiedGroupKFold for stratification and ensuring each cat_id group only appears in one set at a time
# - Final scores averaged over the 4 folds
# - For each seed run we will explore the cat_id predictions through majority voting
# - For each run we will explore the potential impact of gender
# - Includes visualisations & analysis
#
# The dataset is highly unbalanced.

# %%
# Standard imports
import numpy as np
import pandas as pd
import random
from datetime import datetime
from collections import Counter

# Sklearn imports
from sklearn.model_selection import train_test_split, GroupShuffleSplit, GroupKFold, StratifiedGroupKFold
from sklearn.preprocessing import LabelEncoder, MinMaxScaler, RobustScaler, StandardScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report
from sklearn.utils.class_weight import compute_class_weight
from sklearn.inspection import permutation_importance

# Imbalanced-learn import
from imblearn.over_sampling import SMOTE

# TensorFlow and Keras imports
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Dropout, Input, BatchNormalization, concatenate
from tensorflow.keras.optimizers import Adam, RMSprop, SGD, Adamax, AdamW
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import to_categorical
from keras.regularizers import l1, l2, L1L2

# Optuna import
import optuna

# Visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns

from IPython.display import display

# %%
# Set an initial seed for reproducibility
np.random.seed(42)  

# Generate a list of 5 random seeds
random_seeds = np.random.randint(0, 10000, size=5)
print("Random Seeds:", random_seeds)
# Out:
# Random Seeds: [7270  860 5390 5191 5734]

# %% [markdown]
# #### TOTAL RESULTS ACROSS SEED INITIATION

# %%
# Lists to collect statistics across all CVs
all_losses, all_accuracies, all_precisions, all_recalls, all_f1 = [], [], [], [], []
all_majority_vote_accuracies, all_majority_vote_details, all_class_stats, all_gender_stats  = [], [], [], []

# %% [markdown]
# ## Define Functions

# %%
def check_initial_group_split(groups_train, groups_test):
    """
    Check if any group is present in both the train and test sets.

    Parameters:
    - groups_train: Array of group identifiers for the train set
    - groups_test: Array of group identifiers for the test set

    Returns:
    - Prints out any groups found in both sets and the count of such groups
    """
    train_groups = set(groups_train)
    test_groups = set(groups_test)
    common_groups = train_groups.intersection(test_groups)

    if common_groups:
        print(f"Warning: Found {len(common_groups)} common groups in both train/validation and test sets: {common_groups}")
    else:
        print("No common groups found between train and test sets.")

# %%
# Function to perform the swaps based on cat_id, ensuring swaps within the same age_group
def swap_cat_id_instances(dataframe, train_val_idx, test_idx, specific_cat_ids):
    for cat_id in specific_cat_ids:
        # Check if the specific cat_id is not in the training set
        if cat_id not in dataframe.iloc[train_val_idx]['cat_id'].values:
            # Get the age_group of this cat_id
            age_group = dataframe[dataframe['cat_id'] == cat_id]['age_group'].iloc[0]
                
            # Find a different cat_id within the same age_group in the train set that is not in the test set
            other_cat_ids_in_age_group = dataframe[(dataframe['age_group'] == age_group) & 
                                                   (dataframe['cat_id'] != cat_id) &
                                                   (~dataframe['cat_id'].isin(dataframe.iloc[test_idx]['cat_id']))]['cat_id'].unique()
            
            # Choose one other cat_id for swapping
            if len(other_cat_ids_in_age_group) > 0:
                other_cat_id = np.random.choice(other_cat_ids_in_age_group)

                # Find all instances of the other_cat_id in the train set
                other_cat_id_train_val_indices = train_val_idx[dataframe.iloc[train_val_idx]['cat_id'] == other_cat_id]
                
                # Find all instances of the specific cat_id in the test set
                cat_id_test_indices = test_idx[dataframe.iloc[test_idx]['cat_id'] == cat_id]
                
                # Swap the indices
                train_val_idx = np.setdiff1d(train_val_idx, other_cat_id_train_val_indices, assume_unique=True)
                test_idx = np.setdiff1d(test_idx, cat_id_test_indices, assume_unique=True)

                train_val_idx = np.concatenate((train_val_idx, cat_id_test_indices))
                test_idx = np.concatenate((test_idx, other_cat_id_train_val_indices))
            else:
                print(f"No alternative cat_id found in the same age_group as {cat_id} for swapping.")
                
    return train_val_idx, test_idx

# %%
# Function to identify differences in groups
def find_group_differences(original, new):
    # Convert numpy arrays to sets for easy difference computation
    original_set = set(original)
    new_set = set(new)
    # Find differences
    moved_to_new = new_set - original_set
    moved_to_original = original_set - new_set
    return moved_to_new, moved_to_original

# %%
# create custom logger function for local logs & stored in a .txt
def logger(message, file=None):
    print(message)
    if file is not None:
        with open(file, "a") as log_file:
            log_file.write(message + "\n")

log_file_path = "multi-seed-val-D13.txt"

# %%
# Set the aesthetic style of the plots
sns.set(style="whitegrid", palette="deep")

# Define a custom color palette
colors = ["#6aabd1", "#b6e2d3", "#dac292"] 
sns.set_palette(sns.color_palette(colors))

# Function to create bar plots with enhanced style
def styled_barplot(data, x, y, title, xlabel, ylabel):
    plt.figure(figsize=(8, 4))
    bar_plot = sns.barplot(x=x, y=y, data=data, errorbar=None, width=0.5)  
    plt.title(title, fontsize=16, fontweight='bold', color="#333333")
    plt.xlabel(xlabel, fontsize=14, fontweight='bold', color="#333333")
    plt.ylabel(ylabel, fontsize=14, fontweight='bold', color="#333333")
    plt.xticks(fontsize=12, color="#333333")
    plt.yticks(fontsize=12, color="#333333")
    plt.ylim(0, 100) 

    # Adding value labels on top of each bar
    for p in bar_plot.patches:
        height = p.get_height()
        # Annotate the height value on the bar
        bar_plot.annotate(f'{height:.1f}', 
                          (p.get_x() + p.get_width() / 2., height), 
                          ha='center', va='center', 
                          xytext=(0, 9), 
                          textcoords='offset points', fontsize=12, color="#333333")

    plt.show()

# %%
def plot_all_metrics(losses, accuracies, precisions, recalls, f1, metrics_across, x_axis_label):
    fig, ax = plt.subplots(figsize=(12, 8))
    seeds = range(1, len(losses) + 1)

    ax.plot(seeds, losses, marker='o', color='blue', label='Loss')
    ax.plot(seeds, accuracies, marker='o', color='green', label='Accuracy')
    ax.plot(seeds, precisions, marker='o', color='red', label='Precision')
    ax.plot(seeds, recalls, marker='o', color='purple', label='Recall')
    ax.plot(seeds, f1, marker='o', color='orange', label='F1 Score')

    ax.set_title(f'Metrics Across {metrics_across}')
    ax.set_xlabel(x_axis_label)
    ax.set_ylabel('Metric Value')
    ax.set_xticks(seeds)
    ax.legend()
    ax.grid(True)

    return fig

# %% [markdown]
# # RANDOM SEED 1

# %% [markdown]
# ## Prepare Data

# %%
# Set a fixed random seed for reproducibility
random.seed(int(random_seeds[0])) 
np.random.seed(int(random_seeds[0]))
tf.random.set_seed(int(random_seeds[0]))

# Load datasets
dataframe = pd.read_csv('/Users/astrid/PycharmProjects/data-aug-and-more/yamnet-tfhub-extraction/yamnet_embeddings_looped_april_23.csv')

def assign_age_group(age, age_groups):
    for group_name, age_range in age_groups.items():
        if age_range[0] <= age < age_range[1]:
            return group_name
    return 'Unknown'  # For any age that doesn't fit the defined groups

# Define age groups
age_groups = {
    'kitten': (0, 0.5),
    'adult': (0.5, 12),
    'senior': (12, 20)
}

# Create a new column for the age group
dataframe['age_group'] = dataframe['target'].apply(assign_age_group, age_groups=age_groups)

print(dataframe['age_group'].value_counts())
# Out:
# adult     606
# senior    186
# kitten    176
# Name: age_group, dtype: int64

# %%
# Separate features and labels
X = dataframe.iloc[:, :-4].values  # all columns except the last four

# Encode the 'age_group' column as integers using LabelEncoder
label_encoder = LabelEncoder()
encoded_y = label_encoder.fit_transform(dataframe['age_group'].values)

# Use the encoded labels for splitting and one-hot encoding
y = encoded_y  

# Convert 'cat_id' column to numpy array to be used as groups array for GroupKFold
groups = dataframe['cat_id'].values

# %%
tf.keras.backend.clear_session()

# %% [markdown]
# ## Run Setup

# %%
all_cat_ids = []
all_predicted_age_groups = []
all_actual_age_groups = []
all_gender = []

# Define the StratifiedGroupKFold splitter for 4 fold CV with random shuffling
outer_cv = StratifiedGroupKFold(n_splits=4, shuffle=True, random_state=int(random_seeds[0]))

# unseen test set metrics
unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1 = [], [], [], [], []

outer_fold = 0

# Use the splitter to generate indices for training and testing sets
# Note: GroupShuffleSplit.split returns indices, so we use it to index the arrays
for train_val_idx, test_idx in outer_cv.split(X, y, groups):
    outer_fold += 1
    logger(f"outer_fold {outer_fold}", file=log_file_path)

    # Convert indices back to DataFrame for easy manipulation
    df_train_val = dataframe.iloc[train_val_idx]
    df_test = dataframe.iloc[test_idx]

    ##############################
    # ASSESSING SPLITS BY CAT_ID #
    ##############################
    
    # Get the distribution of groups
    training_validation_group_distribution = df_train_val['cat_id'].value_counts()  
    testing_group_distribution = df_test['cat_id'].value_counts()  
    
    # Log or print the distribution
    logger(f"Train Set Group Distribution:\n{training_validation_group_distribution}", file=log_file_path)
    logger(f"Testing Set Group Distribution:\n{testing_group_distribution}", file=log_file_path)

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val['gender'].value_counts()
    testing_gender_distribution = df_test['gender'].value_counts()
    
    # Log the distribution
    logger(f"Training Set Gender Distribution BEFORE SWAP:\n{training_gender_distribution}", file=log_file_path)
    logger(f"Testing Set Gender Distribution BEFORE SWAP:\n{testing_gender_distribution}", file=log_file_path)

    # Group by 'age_group' and then list unique 'cat_id' within each age group
    unique_cat_ids_per_age_group_train_val = df_train_val.groupby('age_group')['cat_id'].unique()
    unique_cat_ids_per_age_group_test = df_test.groupby('age_group')['cat_id'].unique()
    
    # Log results
    logger(f"Unique Cat IDs per Age Group in Training/Validation Set:\n{unique_cat_ids_per_age_group_train_val}", file=log_file_path)
    logger(f"Unique Cat IDs per Age Group in Testing Set:\n{unique_cat_ids_per_age_group_test}", file=log_file_path)

    # Calculate the count of unique identifiers per age group for training and testing set
    counts_train_val = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_train_val.items()}
    counts_test = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_test.items()}

    # Log the counts of unique identifiers per age group
    logger(f"Count of Unique Cat IDs per Age Group in Training/Validation Set:\n{counts_train_val}", file=log_file_path)
    logger(f"Count of Unique Cat IDs per Age Group in Testing Set:\n{counts_test}", file=log_file_path)

    #######################################################
    # CONTINUE WITH ENSURING VALID AND APPROPRIATE SPLITS #
    #######################################################
    
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    groups_train_val, groups_test = groups[train_val_idx], groups[test_idx]

    # logging identifier splits 
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)

    # check group splits
    check_initial_group_split(groups_train_val, groups_test)

    # Specify the cat_ids that must be in the training/validation set
    specific_cat_ids = ['000A', '046A']
    
    # Perform the swapping operation
    train_val_idx, test_idx = swap_cat_id_instances(dataframe, train_val_idx, test_idx, specific_cat_ids)
    
    # Re-assign the sets based on the updated indices
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    new_groups_train_val, new_groups_test = groups[train_val_idx], groups[test_idx]

    # Find differences for training and test sets
    moved_to_train_val, removed_from_train_val = find_group_differences(groups_train_val, new_groups_train_val)
    moved_to_test, removed_from_test = find_group_differences(groups_test, new_groups_test)
    
    # Display the results
    logger(f"Moved to Training/Validation Set:\n{moved_to_train_val}", file=log_file_path)
    logger(f"Removed from Training/Validation Set:\n{removed_from_train_val}", file=log_file_path)
    logger(f"Moved to Test Set:\n{moved_to_test}", file=log_file_path)
    logger(f"Removed from Test Set\n{removed_from_test}", file=log_file_path)

    # Update X_train_val, X_test, y_train_val, y_test, groups_train_val, groups_test based on updated indices
    X_train_val = X[train_val_idx]
    y_train_val = y[train_val_idx]
    groups_train_val = groups[train_val_idx]
    
    X_test = X[test_idx]
    y_test = y[test_idx]
    groups_test = groups[test_idx]

    # logging identifier splits again after potential swaps
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"AFTER SWAP - Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"AFTER SWAP - Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)
    
    # Verify the lengths are consistent
    logger(f"Length of X_train_val:\n{len(X_train_val)}", file=log_file_path)
    logger(f"Length of y_train_val:\n{len(y_train_val)}", file=log_file_path)
    logger(f"Length of groups_train_val:\n{len(groups_train_val)}", file=log_file_path)

    # Check group splits once more
    check_initial_group_split(groups_train_val, groups_test)

    # Convert the modified indices back to a DataFrame representing the updated df_train_val
    df_train_val_updated = dataframe.iloc[train_val_idx].copy()
    df_test_updated = dataframe.iloc[test_idx].copy()

    ############################
    # LOGGING AGE GROUP SPLITS #
    ############################

    # Get the distribution of age groups of age groups before the update
    training_validation_age_group_distribution = df_train_val['age_group'].value_counts()
    testing_age_group_distribution = df_test['age_group'].value_counts()
    
    # Logthe distribution
    logger(f"Train Age Group Distribution BEFORE SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution BEFORE SWAP:\n{testing_age_group_distribution}", file=log_file_path)

    # Get the distribution of age groups after the update
    training_validation_age_group_distribution = df_train_val_updated['age_group'].value_counts()
    testing_age_group_distribution = df_test_updated['age_group'].value_counts()
    
    # Log the distribution
    logger(f"Train Age Group Distribution AFTER SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution AFTER SWAP:\n{testing_age_group_distribution}", file=log_file_path)
    
    ########################################################
    # TRACKING FINAL CAT_IDs & GENDER AFTER REDISTRIBUTION #
    ########################################################

    # Get the distribution of groups
    training_validation_group_distribution = df_train_val_updated['cat_id'].value_counts()  
    testing_group_distribution = df_test_updated['cat_id'].value_counts()  

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val_updated['gender'].value_counts()
    testing_gender_distribution = df_test_updated['gender'].value_counts()
    
    logger(f"\n Starting training on unseen test set\n", file=log_file_path)

    ###################
    # PREPARING MODEL #
    ###################

    # Calculate the distribution of age groups in y_train_val
    age_group_distribution = Counter(y_train_val)
    print("Age group distribution:", age_group_distribution)

    # EarlyStopping callback: monitor 'loss' instead of 'val_loss' for the test set
    early_stopping = EarlyStopping(
        monitor='loss',  
        min_delta=0.001, 
        patience=30,  
        verbose=1,  
        restore_best_weights=True  
    )

    # One final shuffle to ensure randomness
    outer_shuffle_idx = np.random.permutation(len(X_train_val))
    X_train_val = X_train_val[outer_shuffle_idx]
    y_train_val = y_train_val[outer_shuffle_idx]
    
    # Scale the features
    scaler_full = StandardScaler().fit(X_train_val)
    X_train_full_scaled = scaler_full.transform(X_train_val)
    X_test_scaled = scaler_full.transform(X_test)
    
    # Encode the labels
    y_train_full_encoded = to_categorical(y_train_val)
    y_test_encoded = to_categorical(y_test)

    #######################
    # BUILD & TRAIN MODEL #
    #######################

    optimizers = {
        'Adam': Adam(learning_rate=0.00013808925801643654)
    }
    
    # Model definition with dynamic number of layers
    model_full = Sequential()
    model_full.add(Dense(512, activation='relu', input_shape=(X_train_full_scaled.shape[1],)))
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.19804187627143222))  
    model_full.add(Dense(512, activation='relu',)) 
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.24412907103758918))  
    model_full.add(Dense(3, activation='softmax'))  
    
    # Use the optimizer from the parameters
    optimizer = optimizers['Adam']  # optimizer_key from parameters
    
    # Compile the model
    model_full.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    
    # Train the model on the full training set
    history_full = model_full.fit(X_train_full_scaled, y_train_full_encoded, epochs=1500, batch_size=32,
                                  verbose=1, callbacks=[early_stopping])
    
    # Evaluate the model on the held-out test set
    test_loss, test_accuracy = model_full.evaluate(X_test_scaled, y_test_encoded)

    y_test_pred_prob = model_full.predict(X_test_scaled)
    y_test_pred = np.argmax(y_test_pred_prob, axis=1)  
    y_test_true = np.argmax(y_test_encoded, axis=1)    

    ################################
    # LOG MAJORITY VOTE PER CAT_ID #
    ################################

    # Convert numeric predictions back to age group labels
    predicted_age_groups = label_encoder.inverse_transform(y_test_pred)
    actual_labels = label_encoder.inverse_transform(y_test_true)
    
    # Map predictions and actual labels back to cat_ids
    test_results = pd.DataFrame({
        'cat_id': df_test_updated['cat_id'],
        'predicted_age_group': predicted_age_groups,
        'actual_age_group': actual_labels
    })
    
    # Group by cat_id and aggregate predicted age groups
    majority_votes = test_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
    actual_groups = test_results.groupby('cat_id')['actual_age_group'].first()
    
    # Calculate the accuracy of majority voting
    correct_predictions = (majority_votes == actual_groups).sum()
    total_cats = len(actual_groups)
    majority_vote_accuracy = correct_predictions / total_cats
    
    # Log the accuracy of the majority voting
    logger(f"Majority Vote Accuracy for cat_id for this fold: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

    ####################################################
    # COLLECT PREDICTIONS FOR GENDER & CAT_ID ANALYSIS #
    ####################################################

    # Debugging print statements
    print(f'Before appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Extend lists with current fold results
    all_cat_ids.extend(df_test_updated['cat_id'].tolist())
    all_predicted_age_groups.extend(predicted_age_groups)
    all_actual_age_groups.extend(actual_labels)
    all_gender.extend(df_test_updated['gender'].tolist())

    # Debugging print statements
    print(f'After appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Calculate additional metrics
    test_precision = precision_score(y_test_true, y_test_pred, average='macro')  # Use 'macro' for imbalanced datasets
    test_recall = recall_score(y_test_true, y_test_pred, average='macro')
    test_f1 = f1_score(y_test_true, y_test_pred, average='macro')

    # prepare averages of outer metrics
    unseen_f1.append(test_f1)
    unseen_losses.append(test_loss)
    unseen_accuracies.append(test_accuracy)
    unseen_precisions.append(test_precision)
    unseen_recalls.append(test_recall)

    # Print final test results
    logger(f"Final Test Results - Loss: {test_loss}, Accuracy: {test_accuracy}, Precision: {test_precision}, Recall: {test_recall}, F1 Score: {test_f1}", file=log_file_path)

    # Generate the confusion matrix
    cm = confusion_matrix(y_test, y_test_pred)
    logger(f"Confusion Matrix:\n {cm}", file=log_file_path)

# Calculate the overall average metrics
unseen_set_avg_f1 = np.mean(unseen_f1)
unseen_set_avg_loss = np.mean(unseen_losses)
unseen_set_avg_acc = np.mean(unseen_accuracies)
unseen_set_avg_precision = np.mean(unseen_precisions)
unseen_set_avg_recall = np.mean(unseen_recalls)

logger(f"\nFinal Average F1-Score across all UNSEEN TEST sets: {unseen_set_avg_f1}", file=log_file_path)
logger(f"\nFinal Average Loss across all UNSEEN TEST sets: {unseen_set_avg_loss}", file=log_file_path)
logger(f"\nFinal Average Accuracy across all UNSEEN TEST sets: {unseen_set_avg_acc}", file=log_file_path)
logger(f"\nFinal Average Precision across all UNSEEN TEST sets: {unseen_set_avg_precision}", file=log_file_path)
logger(f"\nFinal Average Recall across all UNSEEN TEST sets: {unseen_set_avg_recall}\n", file=log_file_path)

# Append averages to total lists
all_f1.append(unseen_set_avg_f1)
all_losses.append(unseen_set_avg_loss)
all_accuracies.append(unseen_set_avg_acc)
all_precisions.append(unseen_set_avg_precision)
all_recalls.append(unseen_set_avg_recall)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# outer_fold 1
# Train Set Group Distribution:
# 000A    39
# 002B    36
# 103A    33
# 047A    30
# 057A    28
#         ..
# 049A     1
# 026C     1
# 073A     1
# 091A     1
# 100A     1
# Name: cat_id, Length: 87, dtype: int64
# Testing Set Group Distribution:
# 046A    66
# 055A    20
# 059A    18
# 116A    12
# 063A    11
# 072A     9
# 051B     9
# 045A     9
# 013B     8
# 053A     7
# 050A     7
# 117A     7
# 108A     6
# 008A     6
# 025C     6
# 070A     5
# 060A     3
# 058A     3
# 011A     3
# 025B     2
# 069A     2
# 093A     2
# 088A     1
# 024A     1
# 041A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    315
# X    245
# F    184
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    110
# F     73
# M     41
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [002A, 028A, 033A, 000B, 071A, 020A, 000A, 015...
# kitten    [042A, 014B, 110A, 109A, 040A, 047A, 049A, 048...
# senior    [106A, 057A, 090A, 113A, 051A, 097A, 094A, 016...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [070A, 053A, 072A, 013B, 063A, 069A, 060A, 088...
# kitten                             [046A, 045A, 050A, 041A]
# senior    [117A, 051B, 116A, 024A, 059A, 055A, 058A, 108...
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 63, 'kitten': 12, 'senior': 12}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 11, 'kitten': 4, 'senior': 10}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '004A' '005A' '006A' '007A'
#  '009A' '010A' '012A' '014A' '014B' '015A' '016A' '018A' '019A' '019B'
#  '020A' '021A' '022A' '023A' '023B' '025A' '026A' '026B' '026C' '027A'
#  '028A' '029A' '031A' '032A' '033A' '034A' '035A' '036A' '037A' '038A'
#  '039A' '040A' '042A' '043A' '044A' '047A' '048A' '049A' '051A' '052A'
#  '054A' '056A' '057A' '061A' '062A' '064A' '065A' '066A' '067A' '068A'
#  '071A' '073A' '074A' '075A' '076A' '087A' '090A' '091A' '092A' '094A'
#  '095A' '096A' '097A' '097B' '099A' '100A' '101A' '102A' '103A' '104A'
#  '105A' '106A' '109A' '110A' '111A' '113A' '115A']
# Unique Test Group IDs:
# ['008A' '011A' '013B' '024A' '025B' '025C' '041A' '045A' '046A' '050A'
#  '051B' '053A' '055A' '058A' '059A' '060A' '063A' '069A' '070A' '072A'
#  '088A' '093A' '108A' '116A' '117A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'046A'}
# Removed from Training/Validation Set:
# {'110A'}
# Moved to Test Set:
# {'110A'}
# Removed from Test Set
# {'046A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '004A' '005A' '006A' '007A'
#  '009A' '010A' '012A' '014A' '014B' '015A' '016A' '018A' '019A' '019B'
#  '020A' '021A' '022A' '023A' '023B' '025A' '026A' '026B' '026C' '027A'
#  '028A' '029A' '031A' '032A' '033A' '034A' '035A' '036A' '037A' '038A'
#  '039A' '040A' '042A' '043A' '044A' '046A' '047A' '048A' '049A' '051A'
#  '052A' '054A' '056A' '057A' '061A' '062A' '064A' '065A' '066A' '067A'
#  '068A' '071A' '073A' '074A' '075A' '076A' '087A' '090A' '091A' '092A'
#  '094A' '095A' '096A' '097A' '097B' '099A' '100A' '101A' '102A' '103A'
#  '104A' '105A' '106A' '109A' '111A' '113A' '115A']
# AFTER SWAP - Unique Test Group IDs:
# ['008A' '011A' '013B' '024A' '025B' '025C' '041A' '045A' '050A' '051B'
#  '053A' '055A' '058A' '059A' '060A' '063A' '069A' '070A' '072A' '088A'
#  '093A' '108A' '110A' '116A' '117A']
# Length of X_train_val:
# 809
# Length of y_train_val:
# 809
# Length of groups_train_val:
# 809
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     546
# senior    105
# kitten     93
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# kitten    83
# senior    81
# adult     60
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     546
# kitten    158
# senior    105
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# senior    81
# adult     60
# kitten    18
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 546, 1: 158, 2: 105})
# Epoch 1/1500
# 26/26 [==============================] - 1s 4ms/step - loss: 1.4523 - accuracy: 0.4227
# Epoch 2/1500
# 26/26 [==============================] - 0s 3ms/step - loss: 1.0194 - accuracy: 0.5810
# Epoch 3/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.7661 - accuracy: 0.6959
# Epoch 4/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.6860 - accuracy: 0.7169
# Epoch 5/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.5728 - accuracy: 0.7750
# Epoch 6/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.5321 - accuracy: 0.8133
# Epoch 7/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.4327 - accuracy: 0.8517
# Epoch 8/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.4129 - accuracy: 0.8504
# Epoch 9/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.3223 - accuracy: 0.8690
# Epoch 10/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.3119 - accuracy: 0.8875
# Epoch 11/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.2809 - accuracy: 0.9011
# Epoch 12/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.2602 - accuracy: 0.9085
# Epoch 13/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.2530 - accuracy: 0.9172
# Epoch 14/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.2009 - accuracy: 0.9394
# Epoch 15/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.1925 - accuracy: 0.9345
# Epoch 16/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.2064 - accuracy: 0.9271
# Epoch 17/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.1875 - accuracy: 0.9444
# Epoch 18/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.1523 - accuracy: 0.9543
# Epoch 19/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.1516 - accuracy: 0.9481
# Epoch 20/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.1474 - accuracy: 0.9592
# Epoch 21/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.1465 - accuracy: 0.9518
# Epoch 22/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.1158 - accuracy: 0.9679
# Epoch 23/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0908 - accuracy: 0.9790
# Epoch 24/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.1067 - accuracy: 0.9654
# Epoch 25/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0971 - accuracy: 0.9740
# Epoch 26/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0997 - accuracy: 0.9740
# Epoch 27/1500
# 26/26 [==============================] - 0s 6ms/step - loss: 0.0878 - accuracy: 0.9815
# Epoch 28/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.1037 - accuracy: 0.9740
# Epoch 29/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0940 - accuracy: 0.9753
# Epoch 30/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0792 - accuracy: 0.9815
# Epoch 31/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0661 - accuracy: 0.9852
# Epoch 32/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0715 - accuracy: 0.9815
# Epoch 33/1500
# 26/26 [==============================] - 0s 9ms/step - loss: 0.0613 - accuracy: 0.9852
# Epoch 34/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0584 - accuracy: 0.9864
# Epoch 35/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0532 - accuracy: 0.9913
# Epoch 36/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0571 - accuracy: 0.9876
# Epoch 37/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0543 - accuracy: 0.9864
# Epoch 38/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0658 - accuracy: 0.9815
# Epoch 39/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0562 - accuracy: 0.9864
# Epoch 40/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0429 - accuracy: 0.9901
# Epoch 41/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0410 - accuracy: 0.9901
# Epoch 42/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0476 - accuracy: 0.9852
# Epoch 43/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0302 - accuracy: 0.9963
# Epoch 44/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0548 - accuracy: 0.9790
# Epoch 45/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0326 - accuracy: 0.9963
# Epoch 46/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0502 - accuracy: 0.9852
# Epoch 47/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0434 - accuracy: 0.9889
# Epoch 48/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0289 - accuracy: 0.9963
# Epoch 49/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0355 - accuracy: 0.9901
# Epoch 50/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0416 - accuracy: 0.9951
# Epoch 51/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0353 - accuracy: 0.9938
# Epoch 52/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0307 - accuracy: 0.9901
# Epoch 53/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0418 - accuracy: 0.9827
# Epoch 54/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0256 - accuracy: 0.9951
# Epoch 55/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0280 - accuracy: 0.9951
# Epoch 56/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0290 - accuracy: 0.9963
# Epoch 57/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0239 - accuracy: 0.9951
# Epoch 58/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0430 - accuracy: 0.9864
# Epoch 59/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0264 - accuracy: 0.9938
# Epoch 60/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0270 - accuracy: 0.9926
# Epoch 61/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0455 - accuracy: 0.9901
# Epoch 62/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0261 - accuracy: 0.9913
# Epoch 63/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0295 - accuracy: 0.9938
# Epoch 64/1500
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0183 - accuracy: 0.9975
# Epoch 65/1500
# 26/26 [==============================] - 0s 6ms/step - loss: 0.0289 - accuracy: 0.9926
# Epoch 66/1500
# 26/26 [==============================] - 0s 6ms/step - loss: 0.0261 - accuracy: 0.9926
# Epoch 67/1500
# 26/26 [==============================] - 0s 8ms/step - loss: 0.0353 - accuracy: 0.9889
# Epoch 68/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0364 - accuracy: 0.9926
# Epoch 69/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0164 - accuracy: 0.9988
# Epoch 70/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0154 - accuracy: 0.9988
# Epoch 71/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0177 - accuracy: 0.9975
# Epoch 72/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0118 - accuracy: 0.9988
# Epoch 73/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0241 - accuracy: 0.9913
# Epoch 74/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0279 - accuracy: 0.9926
# Epoch 75/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0151 - accuracy: 0.9988
# Epoch 76/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0182 - accuracy: 0.9963
# Epoch 77/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0224 - accuracy: 0.9963
# Epoch 78/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0199 - accuracy: 0.9938
# Epoch 79/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0157 - accuracy: 0.9975
# Epoch 80/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0158 - accuracy: 0.9975
# Epoch 81/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0204 - accuracy: 0.9938
# Epoch 82/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0169 - accuracy: 0.9951
# Epoch 83/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0093 - accuracy: 1.0000
# Epoch 84/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0125 - accuracy: 0.9988
# Epoch 85/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0144 - accuracy: 0.9963
# Epoch 86/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0154 - accuracy: 0.9938
# Epoch 87/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0235 - accuracy: 0.9938
# Epoch 88/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0208 - accuracy: 0.9975
# Epoch 89/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0194 - accuracy: 0.9938
# Epoch 90/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0214 - accuracy: 0.9938
# Epoch 91/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0107 - accuracy: 0.9988
# Epoch 92/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0170 - accuracy: 0.9951
# Epoch 93/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0174 - accuracy: 0.9951
# Epoch 94/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0061 - accuracy: 1.0000
# Epoch 95/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0087 - accuracy: 0.9975
# Epoch 96/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0165 - accuracy: 0.9975
# Epoch 97/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0107 - accuracy: 0.9975
# Epoch 98/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0085 - accuracy: 0.9988
# Epoch 99/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0097 - accuracy: 0.9975
# Epoch 100/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0062 - accuracy: 0.9988
# Epoch 101/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0089 - accuracy: 0.9975
# Epoch 102/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0126 - accuracy: 0.9988
# Epoch 103/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0151 - accuracy: 0.9975
# Epoch 104/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0151 - accuracy: 0.9951
# Epoch 105/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0100 - accuracy: 1.0000
# Epoch 106/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0083 - accuracy: 0.9975
# Epoch 107/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0064 - accuracy: 1.0000
# Epoch 108/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0064 - accuracy: 1.0000
# Epoch 109/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0079 - accuracy: 0.9988
# Epoch 110/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0124 - accuracy: 0.9951
# Epoch 111/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0075 - accuracy: 0.9988
# Epoch 112/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0077 - accuracy: 0.9975
# Epoch 113/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0043 - accuracy: 1.0000
# Epoch 114/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0167 - accuracy: 0.9951
# Epoch 115/1500
# 26/26 [==============================] - 0s 11ms/step - loss: 0.0067 - accuracy: 1.0000
# Epoch 116/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0040 - accuracy: 1.0000
# Epoch 117/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0058 - accuracy: 1.0000
# Epoch 118/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0147 - accuracy: 0.9975
# Epoch 119/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0083 - accuracy: 0.9988
# Epoch 120/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 121/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0221 - accuracy: 0.9913
# Epoch 122/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0086 - accuracy: 0.9975
# Epoch 123/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0043 - accuracy: 1.0000
# Epoch 124/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0165 - accuracy: 0.9938
# Epoch 125/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0118 - accuracy: 0.9988
# Epoch 126/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0053 - accuracy: 0.9988
# Epoch 127/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0245 - accuracy: 0.9926
# Epoch 128/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0121 - accuracy: 0.9975
# Epoch 129/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0064 - accuracy: 0.9988
# Epoch 130/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0071 - accuracy: 0.9988
# Epoch 131/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0064 - accuracy: 0.9975
# Epoch 132/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0209 - accuracy: 0.9963
# Epoch 133/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0046 - accuracy: 1.0000
# Epoch 134/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0059 - accuracy: 1.0000
# Epoch 135/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0095 - accuracy: 0.9975
# Epoch 136/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0062 - accuracy: 1.0000
# Epoch 137/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0143 - accuracy: 0.9951
# Epoch 138/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0117 - accuracy: 0.9988
# Epoch 139/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0048 - accuracy: 1.0000
# Epoch 140/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0051 - accuracy: 1.0000
# Epoch 141/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0073 - accuracy: 0.9963
# Epoch 142/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0074 - accuracy: 0.9988
# Epoch 143/1500
# 23/26 [=========================>....] - ETA: 0s - loss: 0.0043 - accuracy: 1.0000Restoring model weights from the end of the best epoch: 113.
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0090 - accuracy: 0.9988
# Epoch 143: early stopping
# 5/5 [==============================] - 0s 1ms/step - loss: 2.5359 - accuracy: 0.5031
# 5/5 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.52 (13/25)
# Before appending - Cat IDs: 0, Predictions: 0, Actuals: 0, Gender: 0
# After appending - Cat IDs: 159, Predictions: 159, Actuals: 159, Gender: 159
# Final Test Results - Loss: 2.535942792892456, Accuracy: 0.5031446814537048, Precision: 0.6091587078964358, Recall: 0.6360082304526748, F1 Score: 0.5332350189493046
# Confusion Matrix:
#  [[43 14  3]
#  [ 1 17  0]
#  [61  0 20]]
# outer_fold 2
# Train Set Group Distribution:
# 046A    66
# 000A    39
# 047A    30
# 020A    23
# 000B    20
#         ..
# 115A     1
# 090A     1
# 004A     1
# 026B     1
# 100A     1
# Name: cat_id, Length: 80, dtype: int64
# Testing Set Group Distribution:
# 002B    36
# 103A    33
# 057A    28
# 074A    25
# 019A    17
# 101A    16
# 028A    14
# 051A    12
# 036A    11
# 068A    11
# 016A    11
# 005A    11
# 015A    10
# 010A     8
# 027A     7
# 031A     7
# 044A     5
# 012A     5
# 035A     4
# 052A     4
# 014A     3
# 018A     2
# 054A     2
# 038A     2
# 087A     2
# 066A     2
# 091A     1
# 049A     1
# 048A     1
# 110A     1
# 073A     1
# 076A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    273
# M    202
# F    199
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# M    154
# X     82
# F     58
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [002A, 070A, 033A, 000B, 071A, 020A, 000A, 026...
# kitten    [046A, 042A, 014B, 109A, 040A, 047A, 045A, 111...
# senior    [117A, 106A, 090A, 113A, 051B, 116A, 024A, 097...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [028A, 015A, 038A, 068A, 018A, 002B, 005A, 091...
# kitten                             [110A, 049A, 048A, 044A]
# senior                             [057A, 051A, 016A, 054A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 50, 'kitten': 12, 'senior': 18}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 24, 'kitten': 4, 'senior': 4}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '003A' '004A' '006A' '007A' '008A' '009A'
#  '011A' '013B' '014B' '019B' '020A' '021A' '022A' '023A' '023B' '024A'
#  '025A' '025B' '025C' '026A' '026B' '026C' '029A' '032A' '033A' '034A'
#  '037A' '039A' '040A' '041A' '042A' '043A' '045A' '046A' '047A' '050A'
#  '051B' '053A' '055A' '056A' '058A' '059A' '060A' '061A' '062A' '063A'
#  '064A' '065A' '067A' '069A' '070A' '071A' '072A' '075A' '088A' '090A'
#  '092A' '093A' '094A' '095A' '096A' '097A' '097B' '099A' '100A' '102A'
#  '104A' '105A' '106A' '108A' '109A' '111A' '113A' '115A' '116A' '117A']
# Unique Test Group IDs:
# ['002B' '005A' '010A' '012A' '014A' '015A' '016A' '018A' '019A' '027A'
#  '028A' '031A' '035A' '036A' '038A' '044A' '048A' '049A' '051A' '052A'
#  '054A' '057A' '066A' '068A' '073A' '074A' '076A' '087A' '091A' '101A'
#  '103A' '110A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '003A' '004A' '006A' '007A' '008A' '009A'
#  '011A' '013B' '014B' '019B' '020A' '021A' '022A' '023A' '023B' '024A'
#  '025A' '025B' '025C' '026A' '026B' '026C' '029A' '032A' '033A' '034A'
#  '037A' '039A' '040A' '041A' '042A' '043A' '045A' '046A' '047A' '050A'
#  '051B' '053A' '055A' '056A' '058A' '059A' '060A' '061A' '062A' '063A'
#  '064A' '065A' '067A' '069A' '070A' '071A' '072A' '075A' '088A' '090A'
#  '092A' '093A' '094A' '095A' '096A' '097A' '097B' '099A' '100A' '102A'
#  '104A' '105A' '106A' '108A' '109A' '111A' '113A' '115A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['002B' '005A' '010A' '012A' '014A' '015A' '016A' '018A' '019A' '027A'
#  '028A' '031A' '035A' '036A' '038A' '044A' '048A' '049A' '051A' '052A'
#  '054A' '057A' '066A' '068A' '073A' '074A' '076A' '087A' '091A' '101A'
#  '103A' '110A']
# Length of X_train_val:
# 674
# Length of y_train_val:
# 674
# Length of groups_train_val:
# 674
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     373
# kitten    168
# senior    133
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     233
# senior     53
# kitten      8
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     373
# kitten    168
# senior    133
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     233
# senior     53
# kitten      8
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 373, 1: 168, 2: 133})
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Epoch 1/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 1.4162 - accuracy: 0.4407
# Epoch 2/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.9146 - accuracy: 0.6098
# Epoch 3/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.7400 - accuracy: 0.7047
# Epoch 4/1500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.6048 - accuracy: 0.7567
# Epoch 5/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.5485 - accuracy: 0.7730
# Epoch 6/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.4991 - accuracy: 0.7908
# Epoch 7/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.4095 - accuracy: 0.8131
# Epoch 8/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.3704 - accuracy: 0.8576
# Epoch 9/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.3531 - accuracy: 0.8694
# Epoch 10/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.2968 - accuracy: 0.8991
# Epoch 11/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.3023 - accuracy: 0.8947
# Epoch 12/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.2485 - accuracy: 0.9228
# Epoch 13/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.2320 - accuracy: 0.9184
# Epoch 14/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.2281 - accuracy: 0.9288
# Epoch 15/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1965 - accuracy: 0.9436
# Epoch 16/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1935 - accuracy: 0.9392
# Epoch 17/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1674 - accuracy: 0.9421
# Epoch 18/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1872 - accuracy: 0.9362
# Epoch 19/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1462 - accuracy: 0.9585
# Epoch 20/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1459 - accuracy: 0.9555
# Epoch 21/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1494 - accuracy: 0.9481
# Epoch 22/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1278 - accuracy: 0.9570
# Epoch 23/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1128 - accuracy: 0.9718
# Epoch 24/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1126 - accuracy: 0.9644
# Epoch 25/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1007 - accuracy: 0.9748
# Epoch 26/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.1077 - accuracy: 0.9674
# Epoch 27/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0947 - accuracy: 0.9718
# Epoch 28/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0974 - accuracy: 0.9718
# Epoch 29/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0972 - accuracy: 0.9792
# Epoch 30/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0943 - accuracy: 0.9733
# Epoch 31/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0853 - accuracy: 0.9792
# Epoch 32/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0856 - accuracy: 0.9763
# Epoch 33/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0684 - accuracy: 0.9881
# Epoch 34/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0930 - accuracy: 0.9688
# Epoch 35/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0668 - accuracy: 0.9837
# Epoch 36/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0706 - accuracy: 0.9822
# Epoch 37/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0753 - accuracy: 0.9822
# Epoch 38/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0746 - accuracy: 0.9792
# Epoch 39/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0688 - accuracy: 0.9822
# Epoch 40/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0612 - accuracy: 0.9852
# Epoch 41/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0578 - accuracy: 0.9866
# Epoch 42/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0612 - accuracy: 0.9822
# Epoch 43/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0659 - accuracy: 0.9881
# Epoch 44/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0635 - accuracy: 0.9837
# Epoch 45/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0548 - accuracy: 0.9881
# Epoch 46/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0554 - accuracy: 0.9837
# Epoch 47/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0520 - accuracy: 0.9896
# Epoch 48/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0757 - accuracy: 0.9792
# Epoch 49/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0508 - accuracy: 0.9837
# Epoch 50/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0507 - accuracy: 0.9822
# Epoch 51/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0470 - accuracy: 0.9911
# Epoch 52/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0447 - accuracy: 0.9896
# Epoch 53/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0564 - accuracy: 0.9837
# Epoch 54/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0543 - accuracy: 0.9852
# Epoch 55/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0521 - accuracy: 0.9852
# Epoch 56/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0492 - accuracy: 0.9896
# Epoch 57/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0556 - accuracy: 0.9866
# Epoch 58/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0502 - accuracy: 0.9837
# Epoch 59/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0387 - accuracy: 0.9926
# Epoch 60/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0350 - accuracy: 0.9941
# Epoch 61/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0401 - accuracy: 0.9866
# Epoch 62/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0386 - accuracy: 0.9866
# Epoch 63/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0536 - accuracy: 0.9866
# Epoch 64/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0502 - accuracy: 0.9852
# Epoch 65/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0349 - accuracy: 0.9911
# Epoch 66/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0318 - accuracy: 0.9926
# Epoch 67/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0436 - accuracy: 0.9911
# Epoch 68/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0268 - accuracy: 0.9970
# Epoch 69/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0460 - accuracy: 0.9852
# Epoch 70/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0392 - accuracy: 0.9911
# Epoch 71/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0465 - accuracy: 0.9852
# Epoch 72/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0384 - accuracy: 0.9852
# Epoch 73/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0343 - accuracy: 0.9911
# Epoch 74/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0387 - accuracy: 0.9941
# Epoch 75/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0283 - accuracy: 0.9926
# Epoch 76/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0367 - accuracy: 0.9911
# Epoch 77/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0380 - accuracy: 0.9955
# Epoch 78/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0354 - accuracy: 0.9881
# Epoch 79/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0312 - accuracy: 0.9955
# Epoch 80/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0229 - accuracy: 0.9985
# Epoch 81/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0261 - accuracy: 0.9941
# Epoch 82/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0463 - accuracy: 0.9822
# Epoch 83/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0275 - accuracy: 0.9941
# Epoch 84/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0246 - accuracy: 0.9970
# Epoch 85/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0249 - accuracy: 0.9970
# Epoch 86/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0478 - accuracy: 0.9881
# Epoch 87/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0252 - accuracy: 0.9955
# Epoch 88/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0343 - accuracy: 0.9881
# Epoch 89/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0162 - accuracy: 1.0000
# Epoch 90/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0368 - accuracy: 0.9911
# Epoch 91/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0312 - accuracy: 0.9926
# Epoch 92/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0386 - accuracy: 0.9896
# Epoch 93/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0330 - accuracy: 0.9881
# Epoch 94/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0210 - accuracy: 0.9941
# Epoch 95/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0296 - accuracy: 0.9926
# Epoch 96/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0301 - accuracy: 0.9941
# Epoch 97/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0367 - accuracy: 0.9911
# Epoch 98/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0258 - accuracy: 0.9955
# Epoch 99/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0177 - accuracy: 1.0000
# Epoch 100/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0342 - accuracy: 0.9881
# Epoch 101/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0260 - accuracy: 0.9955
# Epoch 102/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0361 - accuracy: 0.9896
# Epoch 103/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0322 - accuracy: 0.9926
# Epoch 104/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0245 - accuracy: 0.9970
# Epoch 105/1500
# 22/22 [==============================] - 0s 10ms/step - loss: 0.0305 - accuracy: 0.9911
# Epoch 106/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0255 - accuracy: 0.9955
# Epoch 107/1500
# 22/22 [==============================] - 0s 5ms/step - loss: 0.0418 - accuracy: 0.9881
# Epoch 108/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0289 - accuracy: 0.9926
# Epoch 109/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0357 - accuracy: 0.9896
# Epoch 110/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0195 - accuracy: 0.9985
# Epoch 111/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0213 - accuracy: 0.9970
# Epoch 112/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0236 - accuracy: 0.9955
# Epoch 113/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0192 - accuracy: 0.9941
# Epoch 114/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0205 - accuracy: 0.9941
# Epoch 115/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0213 - accuracy: 0.9970
# Epoch 116/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0226 - accuracy: 0.9941
# Epoch 117/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0291 - accuracy: 0.9896
# Epoch 118/1500
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0251 - accuracy: 0.9926
# Epoch 119/1500
# 13/22 [================>.............] - ETA: 0s - loss: 0.0320 - accuracy: 0.9928Restoring model weights from the end of the best epoch: 89.
# 22/22 [==============================] - 0s 4ms/step - loss: 0.0249 - accuracy: 0.9955
# Epoch 119: early stopping
# 10/10 [==============================] - 0s 984us/step - loss: 1.4593 - accuracy: 0.7075
# 10/10 [==============================] - 0s 996us/step
# Majority Vote Accuracy for cat_id for this fold: 0.84 (27/32)
# Before appending - Cat IDs: 159, Predictions: 159, Actuals: 159, Gender: 159
# After appending - Cat IDs: 453, Predictions: 453, Actuals: 453, Gender: 453
# Final Test Results - Loss: 1.4593266248703003, Accuracy: 0.7074829936027527, Precision: 0.49375634557563924, Recall: 0.7117715334575, F1 Score: 0.5291588291588293
# Confusion Matrix:
#  [[181  19  33]
#  [  0   8   0]
#  [ 30   4  19]]
# outer_fold 3
# Train Set Group Distribution:
# 046A    66
# 000A    39
# 002B    36
# 103A    33
# 047A    30
#         ..
# 049A     1
# 092A     1
# 048A     1
# 073A     1
# 100A     1
# Name: cat_id, Length: 84, dtype: int64
# Testing Set Group Distribution:
# 000B    20
# 106A    15
# 042A    14
# 097B    14
# 002A    13
# 111A    13
# 025A    11
# 071A    10
# 065A     9
# 033A     9
# 095A     8
# 094A     8
# 099A     7
# 037A     6
# 023A     6
# 075A     5
# 062A     5
# 023B     5
# 003A     4
# 105A     4
# 006A     3
# 056A     3
# 102A     2
# 061A     2
# 043A     1
# 090A     1
# 026C     1
# 019B     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    288
# M    285
# F    195
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# M    71
# X    67
# F    62
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [028A, 070A, 020A, 000A, 015A, 026A, 053A, 038...
# kitten    [046A, 014B, 110A, 109A, 040A, 047A, 049A, 045...
# senior    [117A, 057A, 113A, 051B, 116A, 051A, 024A, 097...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [002A, 033A, 000B, 071A, 065A, 023B, 026C, 105...
# kitten                                   [042A, 111A, 043A]
# senior                       [106A, 090A, 094A, 061A, 056A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 54, 'kitten': 13, 'senior': 17}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 20, 'kitten': 3, 'senior': 5}
# Unique Training/Validation Group IDs:
# ['000A' '001A' '002B' '004A' '005A' '007A' '008A' '009A' '010A' '011A'
#  '012A' '013B' '014A' '014B' '015A' '016A' '018A' '019A' '020A' '021A'
#  '022A' '024A' '025B' '025C' '026A' '026B' '027A' '028A' '029A' '031A'
#  '032A' '034A' '035A' '036A' '038A' '039A' '040A' '041A' '044A' '045A'
#  '046A' '047A' '048A' '049A' '050A' '051A' '051B' '052A' '053A' '054A'
#  '055A' '057A' '058A' '059A' '060A' '063A' '064A' '066A' '067A' '068A'
#  '069A' '070A' '072A' '073A' '074A' '076A' '087A' '088A' '091A' '092A'
#  '093A' '096A' '097A' '100A' '101A' '103A' '104A' '108A' '109A' '110A'
#  '113A' '115A' '116A' '117A']
# Unique Test Group IDs:
# ['000B' '002A' '003A' '006A' '019B' '023A' '023B' '025A' '026C' '033A'
#  '037A' '042A' '043A' '056A' '061A' '062A' '065A' '071A' '075A' '090A'
#  '094A' '095A' '097B' '099A' '102A' '105A' '106A' '111A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '001A' '002B' '004A' '005A' '007A' '008A' '009A' '010A' '011A'
#  '012A' '013B' '014A' '014B' '015A' '016A' '018A' '019A' '020A' '021A'
#  '022A' '024A' '025B' '025C' '026A' '026B' '027A' '028A' '029A' '031A'
#  '032A' '034A' '035A' '036A' '038A' '039A' '040A' '041A' '044A' '045A'
#  '046A' '047A' '048A' '049A' '050A' '051A' '051B' '052A' '053A' '054A'
#  '055A' '057A' '058A' '059A' '060A' '063A' '064A' '066A' '067A' '068A'
#  '069A' '070A' '072A' '073A' '074A' '076A' '087A' '088A' '091A' '092A'
#  '093A' '096A' '097A' '100A' '101A' '103A' '104A' '108A' '109A' '110A'
#  '113A' '115A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['000B' '002A' '003A' '006A' '019B' '023A' '023B' '025A' '026C' '033A'
#  '037A' '042A' '043A' '056A' '061A' '062A' '065A' '071A' '075A' '090A'
#  '094A' '095A' '097B' '099A' '102A' '105A' '106A' '111A']
# Length of X_train_val:
# 768
# Length of y_train_val:
# 768
# Length of groups_train_val:
# 768
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     463
# senior    157
# kitten    148
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     143
# senior     29
# kitten     28
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     463
# senior    157
# kitten    148
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     143
# senior     29
# kitten     28
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 463, 2: 157, 1: 148})
# Epoch 1/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 1.4165 - accuracy: 0.4271
# Epoch 2/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 1.0088 - accuracy: 0.5599
# Epoch 3/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.7773 - accuracy: 0.6745
# Epoch 4/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6797 - accuracy: 0.6875
# Epoch 5/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.5824 - accuracy: 0.7539
# Epoch 6/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.5141 - accuracy: 0.7995
# Epoch 7/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4639 - accuracy: 0.8151
# Epoch 8/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3951 - accuracy: 0.8385
# Epoch 9/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3787 - accuracy: 0.8633
# Epoch 10/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3119 - accuracy: 0.8958
# Epoch 11/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2755 - accuracy: 0.9089
# Epoch 12/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2628 - accuracy: 0.9128
# Epoch 13/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2195 - accuracy: 0.9297
# Epoch 14/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1936 - accuracy: 0.9505
# Epoch 15/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1944 - accuracy: 0.9414
# Epoch 16/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1785 - accuracy: 0.9544
# Epoch 17/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1840 - accuracy: 0.9349
# Epoch 18/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1366 - accuracy: 0.9622
# Epoch 19/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1330 - accuracy: 0.9701
# Epoch 20/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1334 - accuracy: 0.9570
# Epoch 21/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1109 - accuracy: 0.9753
# Epoch 22/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1062 - accuracy: 0.9753
# Epoch 23/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0996 - accuracy: 0.9753
# Epoch 24/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0887 - accuracy: 0.9740
# Epoch 25/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0995 - accuracy: 0.9674
# Epoch 26/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1041 - accuracy: 0.9701
# Epoch 27/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0898 - accuracy: 0.9740
# Epoch 28/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0820 - accuracy: 0.9779
# Epoch 29/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0559 - accuracy: 0.9909
# Epoch 30/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0549 - accuracy: 0.9909
# Epoch 31/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0792 - accuracy: 0.9753
# Epoch 32/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0528 - accuracy: 0.9896
# Epoch 33/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0577 - accuracy: 0.9831
# Epoch 34/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0481 - accuracy: 0.9870
# Epoch 35/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0594 - accuracy: 0.9857
# Epoch 36/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0525 - accuracy: 0.9883
# Epoch 37/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0429 - accuracy: 0.9935
# Epoch 38/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0329 - accuracy: 0.9961
# Epoch 39/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0603 - accuracy: 0.9792
# Epoch 40/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0406 - accuracy: 0.9883
# Epoch 41/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0410 - accuracy: 0.9922
# Epoch 42/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0407 - accuracy: 0.9909
# Epoch 43/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0416 - accuracy: 0.9909
# Epoch 44/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0472 - accuracy: 0.9870
# Epoch 45/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0384 - accuracy: 0.9896
# Epoch 46/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0287 - accuracy: 0.9935
# Epoch 47/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0324 - accuracy: 0.9922
# Epoch 48/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0218 - accuracy: 0.9974
# Epoch 49/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0383 - accuracy: 0.9935
# Epoch 50/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0336 - accuracy: 0.9922
# Epoch 51/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0252 - accuracy: 0.9935
# Epoch 52/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0280 - accuracy: 0.9948
# Epoch 53/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0256 - accuracy: 0.9948
# Epoch 54/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0257 - accuracy: 0.9974
# Epoch 55/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0219 - accuracy: 0.9961
# Epoch 56/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0184 - accuracy: 0.9961
# Epoch 57/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0217 - accuracy: 0.9961
# Epoch 58/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0311 - accuracy: 0.9883
# Epoch 59/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0186 - accuracy: 0.9987
# Epoch 60/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0152 - accuracy: 0.9974
# Epoch 61/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0187 - accuracy: 0.9974
# Epoch 62/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0220 - accuracy: 0.9961
# Epoch 63/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0224 - accuracy: 0.9961
# Epoch 64/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0219 - accuracy: 0.9922
# Epoch 65/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0315 - accuracy: 0.9935
# Epoch 66/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0225 - accuracy: 0.9935
# Epoch 67/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0176 - accuracy: 0.9961
# Epoch 68/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0206 - accuracy: 0.9961
# Epoch 69/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0272 - accuracy: 0.9935
# ...
# Moved to Test Set:
# {'025C'}
# Removed from Test Set
# {'000A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '002A' '002B' '003A' '005A' '006A' '008A' '010A' '011A'
#  '012A' '013B' '014A' '015A' '016A' '018A' '019A' '019B' '023A' '023B'
#  '024A' '025A' '025B' '026C' '027A' '028A' '031A' '033A' '035A' '036A'
#  '037A' '038A' '041A' '042A' '043A' '044A' '045A' '046A' '048A' '049A'
#  '050A' '051A' '051B' '052A' '053A' '054A' '055A' '056A' '057A' '058A'
#  '059A' '060A' '061A' '062A' '063A' '065A' '066A' '068A' '069A' '070A'
#  '071A' '072A' '073A' '074A' '075A' '076A' '087A' '088A' '090A' '091A'
#  '093A' '094A' '095A' '097B' '099A' '101A' '102A' '103A' '105A' '106A'
#  '108A' '110A' '111A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['001A' '004A' '007A' '009A' '014B' '020A' '021A' '022A' '025C' '026A'
#  '026B' '029A' '032A' '034A' '039A' '040A' '047A' '064A' '067A' '092A'
#  '096A' '097A' '100A' '104A' '109A' '113A' '115A']
# Length of X_train_val:
# 751
# Length of y_train_val:
# 751
# Length of groups_train_val:
# 751
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     436
# senior    163
# kitten    119
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     170
# kitten     57
# senior     23
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     469
# senior    163
# kitten    119
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     137
# kitten     57
# senior     23
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 469, 2: 163, 1: 119})
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Epoch 1/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 1.4186 - accuracy: 0.4234
# Epoch 2/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 1.0038 - accuracy: 0.5686
# Epoch 3/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.8543 - accuracy: 0.6312
# Epoch 4/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6982 - accuracy: 0.7111
# Epoch 5/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.6038 - accuracy: 0.7537
# Epoch 6/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.5375 - accuracy: 0.7936
# Epoch 7/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4672 - accuracy: 0.8162
# Epoch 8/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4061 - accuracy: 0.8429
# Epoch 9/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3935 - accuracy: 0.8615
# Epoch 10/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3314 - accuracy: 0.8762
# Epoch 11/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3232 - accuracy: 0.8855
# Epoch 12/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2566 - accuracy: 0.9134
# Epoch 13/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2564 - accuracy: 0.9108
# Epoch 14/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2149 - accuracy: 0.9241
# Epoch 15/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1801 - accuracy: 0.9427
# Epoch 16/1500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.1906 - accuracy: 0.9467
# Epoch 17/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1544 - accuracy: 0.9614
# Epoch 18/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1824 - accuracy: 0.9401
# Epoch 19/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1378 - accuracy: 0.9627
# Epoch 20/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1339 - accuracy: 0.9614
# Epoch 21/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1299 - accuracy: 0.9587
# Epoch 22/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1200 - accuracy: 0.9654
# Epoch 23/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1234 - accuracy: 0.9601
# Epoch 24/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0950 - accuracy: 0.9827
# Epoch 25/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1246 - accuracy: 0.9667
# Epoch 26/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0924 - accuracy: 0.9814
# Epoch 27/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0896 - accuracy: 0.9774
# Epoch 28/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0676 - accuracy: 0.9827
# Epoch 29/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0678 - accuracy: 0.9867
# Epoch 30/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0693 - accuracy: 0.9854
# Epoch 31/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0759 - accuracy: 0.9827
# Epoch 32/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0687 - accuracy: 0.9867
# Epoch 33/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0663 - accuracy: 0.9854
# Epoch 34/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0656 - accuracy: 0.9814
# Epoch 35/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0640 - accuracy: 0.9880
# Epoch 36/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0488 - accuracy: 0.9907
# Epoch 37/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0564 - accuracy: 0.9840
# Epoch 38/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0551 - accuracy: 0.9867
# Epoch 39/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0388 - accuracy: 0.9933
# Epoch 40/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0379 - accuracy: 0.9920
# Epoch 41/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0660 - accuracy: 0.9840
# Epoch 42/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0433 - accuracy: 0.9907
# Epoch 43/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0421 - accuracy: 0.9907
# Epoch 44/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0486 - accuracy: 0.9867
# Epoch 45/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0397 - accuracy: 0.9920
# Epoch 46/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0346 - accuracy: 0.9920
# Epoch 47/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0370 - accuracy: 0.9947
# Epoch 48/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0418 - accuracy: 0.9880
# Epoch 49/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0297 - accuracy: 0.9947
# Epoch 50/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0343 - accuracy: 0.9907
# Epoch 51/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0288 - accuracy: 0.9933
# Epoch 52/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0312 - accuracy: 0.9933
# Epoch 53/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0252 - accuracy: 0.9933
# Epoch 54/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0314 - accuracy: 0.9933
# Epoch 55/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0469 - accuracy: 0.9854
# Epoch 56/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0328 - accuracy: 0.9920
# Epoch 57/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0192 - accuracy: 0.9973
# Epoch 58/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0308 - accuracy: 0.9947
# Epoch 59/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0180 - accuracy: 0.9987
# Epoch 60/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0439 - accuracy: 0.9880
# Epoch 61/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0207 - accuracy: 0.9960
# Epoch 62/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0213 - accuracy: 0.9960
# Epoch 63/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0203 - accuracy: 0.9960
# Epoch 64/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0254 - accuracy: 0.9920
# Epoch 65/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0210 - accuracy: 0.9947
# Epoch 66/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0245 - accuracy: 0.9933
# Epoch 67/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0165 - accuracy: 0.9987
# Epoch 68/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0212 - accuracy: 0.9947
# Epoch 69/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0226 - accuracy: 0.9960
# Epoch 70/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0121 - accuracy: 0.9947
# Epoch 71/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0172 - accuracy: 0.9960
# Epoch 72/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0239 - accuracy: 0.9933
# Epoch 73/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0134 - accuracy: 1.0000
# Epoch 74/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0120 - accuracy: 0.9960
# Epoch 75/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0164 - accuracy: 0.9960
# Epoch 76/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0155 - accuracy: 1.0000
# Epoch 77/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0301 - accuracy: 0.9867
# Epoch 78/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0187 - accuracy: 0.9973
# Epoch 79/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0108 - accuracy: 1.0000
# Epoch 80/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0130 - accuracy: 0.9987
# Epoch 81/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0119 - accuracy: 0.9960
# Epoch 82/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0203 - accuracy: 0.9933
# Epoch 83/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0113 - accuracy: 0.9987
# Epoch 84/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0128 - accuracy: 1.0000
# Epoch 85/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0090 - accuracy: 0.9987
# Epoch 86/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0057 - accuracy: 1.0000
# Epoch 87/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0071 - accuracy: 1.0000
# Epoch 88/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0083 - accuracy: 1.0000
# Epoch 89/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0138 - accuracy: 0.9947
# Epoch 90/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0142 - accuracy: 0.9987
# Epoch 91/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0070 - accuracy: 0.9987
# Epoch 92/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0128 - accuracy: 0.9960
# Epoch 93/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0099 - accuracy: 0.9987
# Epoch 94/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0073 - accuracy: 0.9987
# Epoch 95/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0125 - accuracy: 0.9960
# Epoch 96/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0072 - accuracy: 1.0000
# Epoch 97/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0173 - accuracy: 0.9960
# Epoch 98/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0077 - accuracy: 1.0000
# Epoch 99/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 100/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0105 - accuracy: 0.9973
# Epoch 101/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0071 - accuracy: 1.0000
# Epoch 102/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0111 - accuracy: 0.9960
# Epoch 103/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0071 - accuracy: 0.9987
# Epoch 104/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0129 - accuracy: 0.9960
# Epoch 105/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0064 - accuracy: 1.0000
# Epoch 106/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0050 - accuracy: 1.0000
# Epoch 107/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0148 - accuracy: 0.9973
# Epoch 108/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0116 - accuracy: 0.9960
# Epoch 109/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0124 - accuracy: 0.9960
# Epoch 110/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0073 - accuracy: 0.9987
# Epoch 111/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0186 - accuracy: 0.9920
# Epoch 112/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0155 - accuracy: 0.9960
# Epoch 113/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0175 - accuracy: 0.9920
# Epoch 114/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0173 - accuracy: 0.9933
# Epoch 115/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0057 - accuracy: 0.9987
# Epoch 116/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0085 - accuracy: 0.9987
# Epoch 117/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0063 - accuracy: 0.9987
# Epoch 118/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0053 - accuracy: 1.0000
# Epoch 119/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0084 - accuracy: 0.9987
# Epoch 120/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0080 - accuracy: 0.9987
# Epoch 121/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0148 - accuracy: 0.9960
# Epoch 122/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0058 - accuracy: 1.0000
# Epoch 123/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0073 - accuracy: 0.9987
# Epoch 124/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0072 - accuracy: 0.9987
# Epoch 125/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0079 - accuracy: 1.0000
# Epoch 126/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0333 - accuracy: 0.9893
# Epoch 127/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0116 - accuracy: 0.9987
# Epoch 128/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0114 - accuracy: 0.9960
# Epoch 129/1500
# 13/24 [===============>..............] - ETA: 0s - loss: 0.0037 - accuracy: 1.0000Restoring model weights from the end of the best epoch: 99.
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0113 - accuracy: 0.9973
# Epoch 129: early stopping
# 7/7 [==============================] - 0s 1ms/step - loss: 2.6735 - accuracy: 0.6267
# 7/7 [==============================] - 0s 912us/step
# Majority Vote Accuracy for cat_id for this fold: 0.81 (22/27)
# Before appending - Cat IDs: 653, Predictions: 653, Actuals: 653, Gender: 653
# After appending - Cat IDs: 870, Predictions: 870, Actuals: 870, Gender: 870
# Final Test Results - Loss: 2.673478126525879, Accuracy: 0.6267281174659729, Precision: 0.5706905832911696, Recall: 0.5423136811668439, F1 Score: 0.5147270114942529
# Confusion Matrix:
#  [[107   7  23]
#  [ 36  16   5]
#  [ 10   0  13]]
#
# Final Average F1-Score across all UNSEEN TEST sets: 0.5418820506993482
#
# Final Average Loss across all UNSEEN TEST sets: 2.433314710855484
#
# Final Average Accuracy across all UNSEEN TEST sets: 0.6380889415740967
#
# Final Average Precision across all UNSEEN TEST sets: 0.5617732593017917
#
# Final Average Recall across all UNSEEN TEST sets: 0.6269415006011871

# %%
seed_1_folds_values = (unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1)

# Plotting all fold metrics
seed_1_folds_plot = plot_all_metrics(unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1, "Folds", "Fold Number")

# %% [markdown]
# ## Majority Voting on Total Entries per cat_id

# %%
# Debugging print statements
print(f'Checking - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
# Out:
# Checking - Cat IDs: 870, Predictions: 870, Actuals: 870, Gender: 870

# %%
# Create results df
full_results = pd.DataFrame({
    'cat_id': all_cat_ids,
    'predicted_age_group': all_predicted_age_groups,
    'actual_age_group': all_actual_age_groups,
    'all_gender': all_gender
})

# create a correct majority prediction column
full_results['correct'] = full_results['predicted_age_group'] == full_results['actual_age_group']

# %%
# Group by cat_id and aggregate predicted age groups
majority_votes = full_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first()

# Calculate the accuracy of majority voting
correct_predictions = (majority_votes == actual_groups).sum()
total_cats = len(actual_groups)
majority_vote_accuracy = correct_predictions / total_cats

logger(f"Overall Majority Vote Accuracy for cat_id: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

# store for final evaluation 
all_majority_vote_accuracies.append(majority_vote_accuracy)
# Out:
# Overall Majority Vote Accuracy for cat_id: 0.75 (82/110)

# %%
# Detailed df with predictions, actual labels, and comparison including majority vote
detailed_results = full_results.groupby('cat_id').apply(
    lambda x: pd.Series({
        'Predictions': list(x['predicted_age_group']),
        'Majority Vote': x['predicted_age_group'].mode()[0],
        'Actual Age Group': x['actual_age_group'].iloc[0],
        'Correct Majority Vote': x['predicted_age_group'].mode()[0] == x['actual_age_group'].iloc[0]
    })
).reset_index()

# Convert to DataFrame for better formatting and display
detailed_results = pd.DataFrame(detailed_results)

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 10)
pd.set_option('display.width', 1000)

sorted_detailed_results = detailed_results.sort_values(by='Correct Majority Vote', ascending=False)

# Display the sorted DataFrame
sorted_detailed_results
# Out:
#     cat_id                                        Predictions Majority Vote Actual Age Group  Correct Majority Vote
# 0     000B  [adult, adult, kitten, adult, adult, adult, ad...         adult            adult                   True
# 78    072A  [adult, adult, adult, adult, adult, kitten, ad...         adult            adult                   True
# 76    070A              [adult, senior, adult, kitten, adult]         adult            adult                   True
# 75    069A                                     [adult, adult]         adult            adult                   True
# 74    068A  [adult, adult, adult, senior, senior, adult, a...         adult            adult                   True
# 73    067A  [adult, adult, adult, adult, kitten, adult, ad...         adult            adult                   True
# 72    066A                                    [adult, kitten]         adult            adult                   True
# 71    065A  [adult, adult, adult, kitten, kitten, adult, k...         adult            adult                   True
# 70    064A                              [adult, adult, adult]         adult            adult                   True
# 68    062A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 60    054A                                   [senior, senior]        senior           senior                   True
# 59    053A  [adult, adult, kitten, adult, adult, adult, ad...         adult            adult                   True
# 58    052A                       [adult, adult, adult, adult]         adult            adult                   True
# 1     001A  [adult, adult, adult, adult, senior, adult, ad...         adult            adult                   True
# 54    049A                                           [kitten]        kitten           kitten                   True
# 53    048A                                           [kitten]        kitten           kitten                   True
# 51    045A  [kitten, adult, kitten, kitten, kitten, kitten...        kitten           kitten                   True
# 50    044A           [kitten, kitten, kitten, kitten, kitten]        kitten           kitten                   True
# 49    043A                                           [kitten]        kitten           kitten                   True
# 48    042A  [kitten, kitten, kitten, adult, kitten, kitten...        kitten           kitten                   True
# 47    041A                                           [kitten]        kitten           kitten                   True
# 77    071A  [adult, senior, adult, kitten, adult, senior, ...         adult            adult                   True
# 79    073A                                            [adult]         adult            adult                   True
# 45    039A  [senior, adult, adult, adult, senior, senior, ...         adult            adult                   True
# 80    074A  [kitten, adult, adult, adult, adult, adult, ad...         adult            adult                   True
# 107   115A                                           [kitten]        kitten           kitten                   True
# 106   113A                            [adult, senior, senior]        senior           senior                   True
# 105   111A  [kitten, kitten, kitten, kitten, kitten, kitte...        kitten           kitten                   True
# 104   110A                                   [kitten, kitten]        kitten           kitten                   True
# 100   105A                      [adult, adult, adult, kitten]         adult            adult                   True
# 98    103A  [adult, adult, adult, adult, adult, senior, ad...         adult            adult                   True
# 97    102A                                     [adult, adult]         adult            adult                   True
# 96    101A  [adult, senior, senior, adult, adult, senior, ...         adult            adult                   True
# 95    100A                                            [adult]         adult            adult                   True
# 94    099A  [adult, adult, adult, kitten, adult, adult, ad...         adult            adult                   True
# 93    097B  [senior, adult, adult, senior, adult, adult, a...         adult            adult                   True
# 92    097A  [adult, senior, senior, senior, senior, adult,...        senior           senior                   True
# 91    096A                                            [adult]         adult            adult                   True
# 90    095A  [adult, adult, senior, senior, adult, adult, a...         adult            adult                   True
# 87    092A                                            [adult]         adult            adult                   True
# 86    091A                                            [adult]         adult            adult                   True
# 84    088A                                            [adult]         adult            adult                   True
# 83    087A                                    [adult, kitten]         adult            adult                   True
# 81    075A               [senior, adult, adult, adult, adult]         adult            adult                   True
# 46    040A  [kitten, adult, kitten, kitten, kitten, kitten...        kitten           kitten                   True
# 55    050A  [kitten, kitten, kitten, kitten, kitten, kitte...        kitten           kitten                   True
# 23    021A         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 15    014A                              [adult, adult, adult]         adult            adult                   True
# 8     007A         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 31    026A                     [senior, adult, adult, senior]         adult            adult                   True
# 30    025C  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 29    025B                                     [adult, adult]         adult            adult                   True
# 28    025A  [adult, adult, senior, adult, adult, adult, ad...         adult            adult                   True
# 9     008A         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 26    023B              [adult, adult, senior, senior, adult]         adult            adult                   True
# 25    023A        [adult, adult, senior, adult, adult, adult]         adult            adult                   True
# 24    022A  [adult, kitten, kitten, kitten, adult, adult, ...         adult            adult                   True
# 43    037A       [kitten, adult, senior, adult, adult, adult]         adult            adult                   True
# 22    020A  [senior, senior, adult, adult, adult, adult, k...         adult            adult                   True
# 21    019B                                            [adult]         adult            adult                   True
# 20    019A  [adult, adult, kitten, adult, adult, adult, ki...         adult            adult                   True
# 19    018A                                     [adult, adult]         adult            adult                   True
# 11    010A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 17    015A  [adult, adult, adult, adult, adult, adult, sen...         adult            adult                   True
# 13    012A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 32    026B                                            [adult]         adult            adult                   True
# 7     006A                             [senior, adult, adult]         adult            adult                   True
# 36    029A  [adult, adult, adult, adult, senior, adult, ad...         adult            adult                   True
# 2     002A  [adult, kitten, kitten, adult, adult, adult, s...         adult            adult                   True
# 42    036A  [senior, senior, adult, adult, adult, adult, a...         adult            adult                   True
# 41    035A                       [adult, adult, adult, adult]         adult            adult                   True
# 40    034A               [adult, adult, adult, adult, senior]         adult            adult                   True
# 39    033A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 38    032A                                     [adult, adult]         adult            adult                   True
# 37    031A  [adult, adult, adult, adult, kitten, adult, se...         adult            adult                   True
# 6     005A  [adult, adult, adult, senior, senior, adult, s...         adult            adult                   True
# 14    013B  [adult, adult, adult, adult, kitten, kitten, a...         adult            adult                   True
# 3     002B  [adult, adult, adult, senior, senior, adult, a...         adult            adult                   True
# 35    028A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 34    027A  [adult, kitten, senior, adult, adult, senior, ...         adult            adult                   True
# 4     003A                      [adult, kitten, adult, adult]         adult            adult                   True
# 5     004A                                            [adult]         adult            adult                   True
# 108   116A  [senior, senior, adult, adult, adult, adult, a...         adult           senior                  False
# 10    009A                    [senior, adult, senior, senior]        senior            adult                  False
# 103   109A        [adult, adult, kitten, adult, adult, adult]         adult           kitten                  False
# 12    011A                              [adult, adult, adult]         adult           senior                  False
# 102   108A        [adult, adult, adult, senior, adult, adult]         adult           senior                  False
# 101   106A  [senior, adult, adult, adult, adult, adult, se...         adult           senior                  False
# 99    104A                     [senior, adult, adult, senior]         adult           senior                  False
# 44    038A                                   [kitten, kitten]        kitten            adult                  False
# 89    094A  [adult, senior, adult, adult, adult, senior, a...         adult           senior                  False
# 88    093A                                     [adult, adult]         adult           senior                  False
# 52    047A  [adult, senior, adult, adult, kitten, adult, a...         adult           kitten                  False
# 56    051A  [adult, kitten, senior, adult, senior, adult, ...         adult           senior                  False
# 57    051B  [adult, adult, adult, adult, adult, adult, sen...         adult           senior                  False
# 33    026C                                           [senior]        senior            adult                  False
# 61    055A  [adult, adult, adult, senior, adult, adult, ad...         adult           senior                  False
# 62    056A                             [adult, senior, adult]         adult           senior                  False
# 63    057A  [adult, adult, senior, adult, adult, senior, a...         adult           senior                  False
# 64    058A                              [adult, adult, adult]         adult           senior                  False
# 65    059A  [senior, senior, senior, adult, adult, adult, ...         adult           senior                  False
# 66    060A                            [kitten, adult, kitten]        kitten            adult                  False
# 67    061A                                     [adult, adult]         adult           senior                  False
# 69    063A  [kitten, kitten, kitten, kitten, senior, adult...        kitten            adult                  False
# 27    024A                                            [adult]         adult           senior                  False
# 82    076A                                           [kitten]        kitten            adult                  False
# 18    016A  [adult, adult, adult, adult, kitten, adult, ad...         adult           senior                  False
# 85    090A                                            [adult]         adult           senior                  False
# 16    014B  [senior, adult, senior, senior, adult, kitten,...         adult           kitten                  False
# 109   117A  [adult, senior, adult, senior, adult, senior, ...         adult           senior                  False

# %%
# Create df for majority votes
majority_df = majority_votes.reset_index()
majority_df.columns = ['cat_id', 'Majority_Vote']

# Get actual groups for each cat_id
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first().reset_index()

# Merge majority votes with actual groups
majority_with_actual = pd.merge(majority_df, actual_groups, on='cat_id')

# Add a column to check if the majority vote was correct
majority_with_actual['Majority_Correct'] = majority_with_actual['Majority_Vote'] == majority_with_actual['actual_age_group']

# Count correct majority votes per class
correct_majority_votes_per_class = majority_with_actual.groupby('actual_age_group')['Majority_Correct'].sum()

print("Correct Majority Votes per Class:")
print(correct_majority_votes_per_class)
# Out:
# Correct Majority Votes per Class:
# actual_age_group
# adult     67
# kitten    12
# senior     3
# Name: Majority_Correct, dtype: int64

# %%
# Calculate the total count and the number of correct predictions for each class
class_stats = majority_with_actual.groupby('actual_age_group').agg(
    total_count=('Majority_Correct', 'size'),  # Total number of cases per class
    correct_count=('Majority_Correct', 'sum')  # Sum of correct predictions per class
).reset_index()

# Calculate accuracy for each class
class_stats['accuracy'] = class_stats['correct_count'] / class_stats['total_count'] * 100

# store for final evaluation 
all_majority_vote_details.append(class_stats)

# Log detailed stats
print("Detailed Class Statistics for Majority Votes:")
print(class_stats)
# Out:
# Detailed Class Statistics for Majority Votes:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult           73             67  91.780822
# 1           kitten           15             12  80.000000
# 2           senior           22              3  13.636364

# %%
# Plot for Detailed Class Statistics for Majority Votes
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Accuracy of Majority Votes by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Detailed Class Statistics

# %%
# Calculate the total count and the number of correct predictions for each class
class_stats = full_results.groupby('actual_age_group').agg(
    total_count=('correct', 'size'),
    correct_count=('correct', 'sum')
).reset_index()

# Calculate accuracy for each class
class_stats['accuracy'] = class_stats['correct_count'] / class_stats['total_count'] * 100

# store for final evaluation 
all_class_stats.append(class_stats)

# Log the detailed stats
print("Detailed Class Statistics:")
print(class_stats)
# Out:
# Detailed Class Statistics:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult          573            444  77.486911
# 1           kitten          111             64  57.657658
# 2           senior          186             59  31.720430

# %%
# Plot for Detailed Class Statistics (Overall)
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Overall Accuracy by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Gender Exploration

# %%
# Group by gender and calculate the total count, correct predictions, and accuracy
gender_stats = full_results.groupby('all_gender').agg(
    count=('cat_id', 'size'),  # Total number of cases per gender
    correct=('correct', 'sum')  # Sum of correct predictions per gender
).reset_index()

# Calculate accuracy for each gender
gender_stats['accuracy'] = (gender_stats['correct'] / gender_stats['count'] * 100).round(2)

# Display the DataFrame
print("Accuracy by Gender:")
print(gender_stats)

# store for final evaluation 
all_gender_stats.append(gender_stats)
# Out:
# Accuracy by Gender:
#   all_gender  count  correct  accuracy
# 0          F    218      128     58.72
# 1          M    362      263     72.65
# 2          X    290      176     60.69

# %%
# Plot for Accuracy by Gender
styled_barplot(gender_stats, 'all_gender', 'accuracy', 
               'Accuracy by Gender', 
               'Gender', 'Accuracy (%)')

# %% [markdown]
# ### Log current total CV Stats

# %%
print("Total Majority Vote Accuracy so far:", all_majority_vote_accuracies)
print("Total Class Statistics so far:\n", all_class_stats)
print("Total Gender Accuracy so far:\n", all_gender_stats)
# Out:
# Total Majority Vote Accuracy so far: [0.7454545454545455]
# Total Class Statistics so far:
#  [  actual_age_group  total_count  correct_count   accuracy
# 0            adult          573            444  77.486911
# 1           kitten          111             64  57.657658
# 2           senior          186             59  31.720430]
# Total Gender Accuracy so far:
#  [  all_gender  count  correct  accuracy
# 0          F    218      128     58.72
# 1          M    362      263     72.65
# 2          X    290      176     60.69]

# %% [markdown]
# # RANDOM SEED 2

# %%
# Set a fixed random seed for reproducibility
random.seed(int(random_seeds[1]))
np.random.seed(int(random_seeds[1]))
tf.random.set_seed(int(random_seeds[1]))

# Load datasets
dataframe = pd.read_csv('/Users/astrid/PycharmProjects/data-aug-and-more/yamnet-tfhub-extraction/yamnet_embeddings_looped_april_23.csv')

def assign_age_group(age, age_groups):
    for group_name, age_range in age_groups.items():
        if age_range[0] <= age < age_range[1]:
            return group_name
    return 'Unknown'  # For any age that doesn't fit the defined groups

# Define age groups
age_groups = {
    'kitten': (0, 0.5),
    'adult': (0.5, 12),
    'senior': (12, 20)
}

# Create a new column for the age group
dataframe['age_group'] = dataframe['target'].apply(assign_age_group, age_groups=age_groups)

print(dataframe['age_group'].value_counts())
# Out:
# adult     606
# senior    186
# kitten    176
# Name: age_group, dtype: int64

# %%
# Separate features and labels
X = dataframe.iloc[:, :-4].values  # all columns except the last four

# Encode the 'age_group' column as integers using LabelEncoder
label_encoder = LabelEncoder()
encoded_y = label_encoder.fit_transform(dataframe['age_group'].values)

# Use the encoded labels for splitting and one-hot encoding
y = encoded_y  

# Convert 'cat_id' column to numpy array to be used as groups array for GroupKFold
groups = dataframe['cat_id'].values

# %%
tf.keras.backend.clear_session()

# %% [markdown]
# ## Run Setup

# %%
all_cat_ids = []
all_predicted_age_groups = []
all_actual_age_groups = []
all_gender = []

# Define the StratifiedGroupKFold splitter for 4 fold CV with random shuffling
outer_cv = StratifiedGroupKFold(n_splits=4, shuffle=True, random_state=int(random_seeds[1]))

# unseen test set metrics
unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1 = [], [], [], [], []

outer_fold = 0

# Use the splitter to generate indices for training and testing sets
# Note: GroupShuffleSplit.split returns indices, so we use it to index the arrays
for train_val_idx, test_idx in outer_cv.split(X, y, groups):
    outer_fold += 1
    logger(f"outer_fold {outer_fold}", file=log_file_path)

    # Convert indices back to DataFrame for easy manipulation
    df_train_val = dataframe.iloc[train_val_idx]
    df_test = dataframe.iloc[test_idx]

    ##############################
    # ASSESSING SPLITS BY CAT_ID #
    ##############################
    
    # Get the distribution of groups
    training_validation_group_distribution = df_train_val['cat_id'].value_counts()  
    testing_group_distribution = df_test['cat_id'].value_counts()  
    
    # Log or print the distribution
    logger(f"Train Set Group Distribution:\n{training_validation_group_distribution}", file=log_file_path)
    logger(f"Testing Set Group Distribution:\n{testing_group_distribution}", file=log_file_path)

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val['gender'].value_counts()
    testing_gender_distribution = df_test['gender'].value_counts()
    
    # Log the distribution
    logger(f"Training Set Gender Distribution BEFORE SWAP:\n{training_gender_distribution}", file=log_file_path)
    logger(f"Testing Set Gender Distribution BEFORE SWAP:\n{testing_gender_distribution}", file=log_file_path)

    # Group by 'age_group' and then list unique 'cat_id' within each age group
    unique_cat_ids_per_age_group_train_val = df_train_val.groupby('age_group')['cat_id'].unique()
    unique_cat_ids_per_age_group_test = df_test.groupby('age_group')['cat_id'].unique()
    
    # Log results
    logger(f"Unique Cat IDs per Age Group in Training/Validation Set:\n{unique_cat_ids_per_age_group_train_val}", file=log_file_path)
    logger(f"Unique Cat IDs per Age Group in Testing Set:\n{unique_cat_ids_per_age_group_test}", file=log_file_path)

    # Calculate the count of unique identifiers per age group for training and testing set
    counts_train_val = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_train_val.items()}
    counts_test = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_test.items()}

    # Log the counts of unique identifiers per age group
    logger(f"Count of Unique Cat IDs per Age Group in Training/Validation Set:\n{counts_train_val}", file=log_file_path)
    logger(f"Count of Unique Cat IDs per Age Group in Testing Set:\n{counts_test}", file=log_file_path)

    #######################################################
    # CONTINUE WITH ENSURING VALID AND APPROPRIATE SPLITS #
    #######################################################
    
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    groups_train_val, groups_test = groups[train_val_idx], groups[test_idx]

    # logging identifier splits 
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)

    # check group splits
    check_initial_group_split(groups_train_val, groups_test)

    # Specify the cat_ids that must be in the training/validation set
    specific_cat_ids = ['000A', '046A']
    
    # Perform the swapping operation
    train_val_idx, test_idx = swap_cat_id_instances(dataframe, train_val_idx, test_idx, specific_cat_ids)
    
    # Re-assign the sets based on the updated indices
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    new_groups_train_val, new_groups_test = groups[train_val_idx], groups[test_idx]

    # Find differences for training and test sets
    moved_to_train_val, removed_from_train_val = find_group_differences(groups_train_val, new_groups_train_val)
    moved_to_test, removed_from_test = find_group_differences(groups_test, new_groups_test)
    
    # Display the results
    logger(f"Moved to Training/Validation Set:\n{moved_to_train_val}", file=log_file_path)
    logger(f"Removed from Training/Validation Set:\n{removed_from_train_val}", file=log_file_path)
    logger(f"Moved to Test Set:\n{moved_to_test}", file=log_file_path)
    logger(f"Removed from Test Set\n{removed_from_test}", file=log_file_path)

    # Update X_train_val, X_test, y_train_val, y_test, groups_train_val, groups_test based on updated indices
    X_train_val = X[train_val_idx]
    y_train_val = y[train_val_idx]
    groups_train_val = groups[train_val_idx]
    
    X_test = X[test_idx]
    y_test = y[test_idx]
    groups_test = groups[test_idx]

    # logging identifier splits again after potential swaps
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"AFTER SWAP - Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"AFTER SWAP - Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)
    
    # Verify the lengths are consistent
    logger(f"Length of X_train_val:\n{len(X_train_val)}", file=log_file_path)
    logger(f"Length of y_train_val:\n{len(y_train_val)}", file=log_file_path)
    logger(f"Length of groups_train_val:\n{len(groups_train_val)}", file=log_file_path)

    # Check group splits once more
    check_initial_group_split(groups_train_val, groups_test)

    # Convert the modified indices back to a DataFrame representing the updated df_train_val
    df_train_val_updated = dataframe.iloc[train_val_idx].copy()
    df_test_updated = dataframe.iloc[test_idx].copy()

    ############################
    # LOGGING AGE GROUP SPLITS #
    ############################

    # Get the distribution of age groups of age groups before the update
    training_validation_age_group_distribution = df_train_val['age_group'].value_counts()
    testing_age_group_distribution = df_test['age_group'].value_counts()
    
    # Logthe distribution
    logger(f"Train Age Group Distribution BEFORE SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution BEFORE SWAP:\n{testing_age_group_distribution}", file=log_file_path)

    # Get the distribution of age groups after the update
    training_validation_age_group_distribution = df_train_val_updated['age_group'].value_counts()
    testing_age_group_distribution = df_test_updated['age_group'].value_counts()
    
    # Log the distribution
    logger(f"Train Age Group Distribution AFTER SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution AFTER SWAP:\n{testing_age_group_distribution}", file=log_file_path)
    
    ########################################################
    # TRACKING FINAL CAT_IDs & GENDER AFTER REDISTRIBUTION #
    ########################################################

    # Get the distribution of groups
    training_validation_group_distribution = df_train_val_updated['cat_id'].value_counts()  
    testing_group_distribution = df_test_updated['cat_id'].value_counts()  

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val_updated['gender'].value_counts()
    testing_gender_distribution = df_test_updated['gender'].value_counts()
    
    logger(f"\n Starting training on unseen test set\n", file=log_file_path)

    ###################
    # PREPARING MODEL #
    ###################

    # Calculate the distribution of age groups in y_train_val
    age_group_distribution = Counter(y_train_val)
    print("Age group distribution:", age_group_distribution)

    # EarlyStopping callback: monitor 'loss' instead of 'val_loss' for the test set
    early_stopping = EarlyStopping(
        monitor='loss',  
        min_delta=0.001, 
        patience=30,  
        verbose=1,  
        restore_best_weights=True  
    )

    # One final shuffle to ensure randomness
    outer_shuffle_idx = np.random.permutation(len(X_train_val))
    X_train_val = X_train_val[outer_shuffle_idx]
    y_train_val = y_train_val[outer_shuffle_idx]
    
    # Scale the features
    scaler_full = StandardScaler().fit(X_train_val)
    X_train_full_scaled = scaler_full.transform(X_train_val)
    X_test_scaled = scaler_full.transform(X_test)
    
    # Encode the labels
    y_train_full_encoded = to_categorical(y_train_val)
    y_test_encoded = to_categorical(y_test)

    #######################
    # BUILD & TRAIN MODEL #
    #######################

    optimizers = {
        'Adam': Adam(learning_rate=0.00013808925801643654)
    }
    
    # Model definition with dynamic number of layers
    model_full = Sequential()
    model_full.add(Dense(512, activation='relu', input_shape=(X_train_full_scaled.shape[1],)))
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.19804187627143222))  
    model_full.add(Dense(512, activation='relu',)) 
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.24412907103758918))  
    model_full.add(Dense(3, activation='softmax'))  
    
    # Use the optimizer from the parameters
    optimizer = optimizers['Adam']  # optimizer_key from parameters
    
    # Compile the model
    model_full.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    
    # Train the model on the full training set
    history_full = model_full.fit(X_train_full_scaled, y_train_full_encoded, epochs=1500, batch_size=32,
                                  verbose=1, callbacks=[early_stopping])
    
    # Evaluate the model on the held-out test set
    test_loss, test_accuracy = model_full.evaluate(X_test_scaled, y_test_encoded)

    y_test_pred_prob = model_full.predict(X_test_scaled)
    y_test_pred = np.argmax(y_test_pred_prob, axis=1)  
    y_test_true = np.argmax(y_test_encoded, axis=1)    

    ################################
    # LOG MAJORITY VOTE PER CAT_ID #
    ################################

    # Convert numeric predictions back to age group labels
    predicted_age_groups = label_encoder.inverse_transform(y_test_pred)
    actual_labels = label_encoder.inverse_transform(y_test_true)
    
    # Map predictions and actual labels back to cat_ids
    test_results = pd.DataFrame({
        'cat_id': df_test_updated['cat_id'],
        'predicted_age_group': predicted_age_groups,
        'actual_age_group': actual_labels
    })
    
    # Group by cat_id and aggregate predicted age groups
    majority_votes = test_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
    actual_groups = test_results.groupby('cat_id')['actual_age_group'].first()
    
    # Calculate the accuracy of majority voting
    correct_predictions = (majority_votes == actual_groups).sum()
    total_cats = len(actual_groups)
    majority_vote_accuracy = correct_predictions / total_cats
    
    # Log the accuracy of the majority voting
    logger(f"Majority Vote Accuracy for cat_id for this fold: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

    ####################################################
    # COLLECT PREDICTIONS FOR GENDER & CAT_ID ANALYSIS #
    ####################################################

    # Debugging print statements
    print(f'Before appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Extend lists with current fold results
    all_cat_ids.extend(df_test_updated['cat_id'].tolist())
    all_predicted_age_groups.extend(predicted_age_groups)
    all_actual_age_groups.extend(actual_labels)
    all_gender.extend(df_test_updated['gender'].tolist())

    # Debugging print statements
    print(f'After appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Calculate additional metrics
    test_precision = precision_score(y_test_true, y_test_pred, average='macro')  # Use 'macro' for imbalanced datasets
    test_recall = recall_score(y_test_true, y_test_pred, average='macro')
    test_f1 = f1_score(y_test_true, y_test_pred, average='macro')

    # prepare averages of outer metrics
    unseen_f1.append(test_f1)
    unseen_losses.append(test_loss)
    unseen_accuracies.append(test_accuracy)
    unseen_precisions.append(test_precision)
    unseen_recalls.append(test_recall)

    # Print final test results
    logger(f"Final Test Results - Loss: {test_loss}, Accuracy: {test_accuracy}, Precision: {test_precision}, Recall: {test_recall}, F1 Score: {test_f1}", file=log_file_path)

    # Generate the confusion matrix
    cm = confusion_matrix(y_test, y_test_pred)
    logger(f"Confusion Matrix:\n {cm}", file=log_file_path)

# Calculate the overall average metrics
unseen_set_avg_f1 = np.mean(unseen_f1)
unseen_set_avg_loss = np.mean(unseen_losses)
unseen_set_avg_acc = np.mean(unseen_accuracies)
unseen_set_avg_precision = np.mean(unseen_precisions)
unseen_set_avg_recall = np.mean(unseen_recalls)

logger(f"\nFinal Average F1-Score across all UNSEEN TEST sets: {unseen_set_avg_f1}", file=log_file_path)
logger(f"\nFinal Average Loss across all UNSEEN TEST sets: {unseen_set_avg_loss}", file=log_file_path)
logger(f"\nFinal Average Accuracy across all UNSEEN TEST sets: {unseen_set_avg_acc}", file=log_file_path)
logger(f"\nFinal Average Precision across all UNSEEN TEST sets: {unseen_set_avg_precision}", file=log_file_path)
logger(f"\nFinal Average Recall across all UNSEEN TEST sets: {unseen_set_avg_recall}\n", file=log_file_path)

# Append averages to total lists
all_f1.append(unseen_set_avg_f1)
all_losses.append(unseen_set_avg_loss)
all_accuracies.append(unseen_set_avg_acc)
all_precisions.append(unseen_set_avg_precision)
all_recalls.append(unseen_set_avg_recall)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# outer_fold 1
# Train Set Group Distribution:
# 000A    39
# 002B    36
# 047A    30
# 057A    28
# 074A    25
# 020A    23
# 000B    20
# 067A    20
# 055A    20
# 029A    17
# 019A    17
# 101A    16
# 097A    16
# 001A    15
# 042A    14
# 097B    14
# 028A    14
# 002A    13
# 039A    12
# 116A    12
# 005A    11
# 016A    11
# 040A    10
# 014B    10
# 071A    10
# 051B     9
# 022A     9
# 065A     9
# 072A     9
# 013B     8
# 095A     8
# 010A     8
# 117A     7
# 027A     7
# 050A     7
# 053A     7
# 031A     7
# 023A     6
# 037A     6
# 021A     6
# 025C     6
# 108A     6
# 008A     6
# 109A     6
# 007A     6
# 012A     5
# 034A     5
# 062A     5
# 070A     5
# 026A     4
# 009A     4
# 105A     4
# 003A     4
# 104A     4
# 058A     3
# 006A     3
# 113A     3
# 056A     3
# 011A     3
# 064A     3
# 060A     3
# 014A     3
# 087A     2
# 025B     2
# 093A     2
# 066A     2
# 054A     2
# 032A     2
# 102A     2
# 069A     2
# 038A     2
# 061A     2
# 073A     1
# 041A     1
# 026B     1
# 004A     1
# 076A     1
# 110A     1
# 115A     1
# 024A     1
# 091A     1
# 026C     1
# 049A     1
# 043A     1
# 096A     1
# 088A     1
# 100A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 046A    66
# 103A    33
# 059A    18
# 106A    15
# 111A    13
# 051A    12
# 063A    11
# 036A    11
# 068A    11
# 025A    11
# 015A    10
# 045A     9
# 033A     9
# 094A     8
# 099A     7
# 075A     5
# 023B     5
# 044A     5
# 035A     4
# 052A     4
# 018A     2
# 092A     1
# 048A     1
# 090A     1
# 019B     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    250
# X    223
# F    222
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    132
# M    106
# F     35
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [002A, 028A, 070A, 000B, 071A, 020A, 000A, 026...
# kitten    [042A, 014B, 110A, 109A, 040A, 047A, 049A, 043...
# senior    [117A, 057A, 113A, 051B, 116A, 024A, 097A, 055...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [033A, 015A, 023B, 068A, 018A, 103A, 063A, 075...
# kitten                       [046A, 045A, 048A, 111A, 044A]
# senior                       [106A, 090A, 051A, 094A, 059A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 59, 'kitten': 11, 'senior': 17}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 15, 'kitten': 5, 'senior': 5}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '004A' '005A' '006A' '007A'
#  '008A' '009A' '010A' '011A' '012A' '013B' '014A' '014B' '016A' '019A'
#  '020A' '021A' '022A' '023A' '024A' '025B' '025C' '026A' '026B' '026C'
#  '027A' '028A' '029A' '031A' '032A' '034A' '037A' '038A' '039A' '040A'
#  '041A' '042A' '043A' '047A' '049A' '050A' '051B' '053A' '054A' '055A'
#  '056A' '057A' '058A' '060A' '061A' '062A' '064A' '065A' '066A' '067A'
#  '069A' '070A' '071A' '072A' '073A' '074A' '076A' '087A' '088A' '091A'
#  '093A' '095A' '096A' '097A' '097B' '100A' '101A' '102A' '104A' '105A'
#  '108A' '109A' '110A' '113A' '115A' '116A' '117A']
# Unique Test Group IDs:
# ['015A' '018A' '019B' '023B' '025A' '033A' '035A' '036A' '044A' '045A'
#  '046A' '048A' '051A' '052A' '059A' '063A' '068A' '075A' '090A' '092A'
#  '094A' '099A' '103A' '106A' '111A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'046A'}
# Removed from Training/Validation Set:
# {'014B'}
# Moved to Test Set:
# {'014B'}
# Removed from Test Set
# {'046A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '004A' '005A' '006A' '007A'
#  '008A' '009A' '010A' '011A' '012A' '013B' '014A' '016A' '019A' '020A'
#  '021A' '022A' '023A' '024A' '025B' '025C' '026A' '026B' '026C' '027A'
#  '028A' '029A' '031A' '032A' '034A' '037A' '038A' '039A' '040A' '041A'
#  '042A' '043A' '046A' '047A' '049A' '050A' '051B' '053A' '054A' '055A'
#  '056A' '057A' '058A' '060A' '061A' '062A' '064A' '065A' '066A' '067A'
#  '069A' '070A' '071A' '072A' '073A' '074A' '076A' '087A' '088A' '091A'
#  '093A' '095A' '096A' '097A' '097B' '100A' '101A' '102A' '104A' '105A'
#  '108A' '109A' '110A' '113A' '115A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['014B' '015A' '018A' '019B' '023B' '025A' '033A' '035A' '036A' '044A'
#  '045A' '048A' '051A' '052A' '059A' '063A' '068A' '075A' '090A' '092A'
#  '094A' '099A' '103A' '106A' '111A']
# Length of X_train_val:
# 751
# Length of y_train_val:
# 751
# Length of groups_train_val:
# 751
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     481
# senior    132
# kitten     82
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     125
# kitten     94
# senior     54
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     481
# kitten    138
# senior    132
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     125
# senior     54
# kitten     38
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 481, 1: 138, 2: 132})
# Epoch 1/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 1.4378 - accuracy: 0.4141
# Epoch 2/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 1.0889 - accuracy: 0.5459
# Epoch 3/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.8242 - accuracy: 0.6565
# Epoch 4/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.7200 - accuracy: 0.7137
# Epoch 5/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.6003 - accuracy: 0.7537
# Epoch 6/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.5766 - accuracy: 0.7710
# Epoch 7/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4428 - accuracy: 0.8202
# Epoch 8/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.4620 - accuracy: 0.8242
# Epoch 9/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3626 - accuracy: 0.8735
# Epoch 10/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3551 - accuracy: 0.8722
# Epoch 11/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3165 - accuracy: 0.8921
# Epoch 12/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2854 - accuracy: 0.9015
# Epoch 13/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2260 - accuracy: 0.9387
# Epoch 14/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2402 - accuracy: 0.9241
# Epoch 15/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2033 - accuracy: 0.9348
# Epoch 16/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1815 - accuracy: 0.9374
# Epoch 17/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1677 - accuracy: 0.9427
# Epoch 18/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1368 - accuracy: 0.9654
# Epoch 19/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1523 - accuracy: 0.9574
# Epoch 20/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1392 - accuracy: 0.9494
# Epoch 21/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1148 - accuracy: 0.9734
# Epoch 22/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1022 - accuracy: 0.9734
# Epoch 23/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1191 - accuracy: 0.9680
# Epoch 24/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1049 - accuracy: 0.9774
# Epoch 25/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1301 - accuracy: 0.9667
# Epoch 26/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0897 - accuracy: 0.9787
# Epoch 27/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0962 - accuracy: 0.9747
# Epoch 28/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0966 - accuracy: 0.9694
# Epoch 29/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0825 - accuracy: 0.9787
# Epoch 30/1500
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0594 - accuracy: 0.9840
# Epoch 31/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0721 - accuracy: 0.9827
# Epoch 32/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0637 - accuracy: 0.9827
# Epoch 33/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0612 - accuracy: 0.9893
# Epoch 34/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0520 - accuracy: 0.9907
# Epoch 35/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0551 - accuracy: 0.9867
# Epoch 36/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0435 - accuracy: 0.9933
# Epoch 37/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0453 - accuracy: 0.9893
# Epoch 38/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0429 - accuracy: 0.9933
# Epoch 39/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0437 - accuracy: 0.9880
# Epoch 40/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0376 - accuracy: 0.9933
# Epoch 41/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0497 - accuracy: 0.9854
# Epoch 42/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0399 - accuracy: 0.9920
# Epoch 43/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0414 - accuracy: 0.9920
# Epoch 44/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0351 - accuracy: 0.9973
# Epoch 45/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0358 - accuracy: 0.9907
# Epoch 46/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0490 - accuracy: 0.9854
# Epoch 47/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0498 - accuracy: 0.9827
# Epoch 48/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0471 - accuracy: 0.9854
# Epoch 49/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0351 - accuracy: 0.9907
# Epoch 50/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0365 - accuracy: 0.9933
# Epoch 51/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0265 - accuracy: 0.9973
# Epoch 52/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0463 - accuracy: 0.9907
# Epoch 53/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0253 - accuracy: 0.9947
# Epoch 54/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0239 - accuracy: 0.9947
# Epoch 55/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0301 - accuracy: 0.9920
# Epoch 56/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0262 - accuracy: 0.9933
# Epoch 57/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0225 - accuracy: 0.9933
# Epoch 58/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0164 - accuracy: 0.9987
# Epoch 59/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0262 - accuracy: 0.9933
# Epoch 60/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0390 - accuracy: 0.9867
# Epoch 61/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0309 - accuracy: 0.9893
# Epoch 62/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0185 - accuracy: 0.9987
# Epoch 63/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0204 - accuracy: 0.9960
# Epoch 64/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0180 - accuracy: 0.9960
# Epoch 65/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0188 - accuracy: 0.9947
# Epoch 66/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0153 - accuracy: 0.9973
# Epoch 67/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0204 - accuracy: 0.9960
# Epoch 68/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0230 - accuracy: 0.9960
# Epoch 69/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0185 - accuracy: 0.9947
# Epoch 70/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0199 - accuracy: 0.9920
# Epoch 71/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0144 - accuracy: 0.9973
# Epoch 72/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0128 - accuracy: 0.9960
# Epoch 73/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0117 - accuracy: 0.9960
# Epoch 74/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0117 - accuracy: 1.0000
# Epoch 75/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0324 - accuracy: 0.9867
# Epoch 76/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0108 - accuracy: 1.0000
# Epoch 77/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0151 - accuracy: 0.9960
# Epoch 78/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0176 - accuracy: 0.9973
# Epoch 79/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0126 - accuracy: 0.9973
# Epoch 80/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0182 - accuracy: 0.9947
# Epoch 81/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0118 - accuracy: 0.9973
# Epoch 82/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0163 - accuracy: 0.9960
# Epoch 83/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0132 - accuracy: 0.9973
# Epoch 84/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0235 - accuracy: 0.9920
# Epoch 85/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0204 - accuracy: 0.9960
# Epoch 86/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0060 - accuracy: 1.0000
# Epoch 87/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0141 - accuracy: 0.9987
# Epoch 88/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0095 - accuracy: 0.9987
# Epoch 89/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0075 - accuracy: 1.0000
# Epoch 90/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0077 - accuracy: 0.9987
# Epoch 91/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0116 - accuracy: 0.9973
# Epoch 92/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0137 - accuracy: 0.9987
# Epoch 93/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0148 - accuracy: 0.9960
# Epoch 94/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0058 - accuracy: 1.0000
# Epoch 95/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0232 - accuracy: 0.9920
# Epoch 96/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0132 - accuracy: 0.9973
# Epoch 97/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0066 - accuracy: 1.0000
# Epoch 98/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0090 - accuracy: 0.9987
# Epoch 99/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0204 - accuracy: 0.9960
# Epoch 100/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0220 - accuracy: 0.9933
# Epoch 101/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0101 - accuracy: 0.9987
# Epoch 102/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0134 - accuracy: 0.9947
# Epoch 103/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0130 - accuracy: 0.9947
# Epoch 104/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0085 - accuracy: 1.0000
# Epoch 105/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0166 - accuracy: 0.9973
# Epoch 106/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0127 - accuracy: 0.9947
# Epoch 107/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0115 - accuracy: 0.9973
# Epoch 108/1500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0060 - accuracy: 1.0000
# Epoch 109/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0141 - accuracy: 0.9973
# Epoch 110/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 111/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0066 - accuracy: 0.9987
# Epoch 112/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0056 - accuracy: 1.0000
# Epoch 113/1500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0078 - accuracy: 1.0000
# Epoch 114/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0073 - accuracy: 1.0000
# Epoch 115/1500
# 24/24 [==============================] - 0s 17ms/step - loss: 0.0077 - accuracy: 0.9973
# Epoch 116/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0148 - accuracy: 0.9947
# Epoch 117/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0226 - accuracy: 0.9907
# Epoch 118/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0084 - accuracy: 0.9973
# Epoch 119/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0137 - accuracy: 0.9973
# Epoch 120/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0175 - accuracy: 0.9947
# Epoch 121/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0113 - accuracy: 0.9960
# Epoch 122/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0087 - accuracy: 0.9973
# Epoch 123/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0088 - accuracy: 0.9973
# Epoch 124/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0048 - accuracy: 1.0000
# Epoch 125/1500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0078 - accuracy: 0.9987
# Epoch 126/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0090 - accuracy: 0.9960
# Epoch 127/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0093 - accuracy: 0.9973
# Epoch 128/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0065 - accuracy: 0.9973
# Epoch 129/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0054 - accuracy: 0.9987
# Epoch 130/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0105 - accuracy: 0.9973
# Epoch 131/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0106 - accuracy: 0.9987
# Epoch 132/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0082 - accuracy: 0.9987
# Epoch 133/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0049 - accuracy: 0.9987
# Epoch 134/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0060 - accuracy: 0.9987
# Epoch 135/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0112 - accuracy: 0.9973
# Epoch 136/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 137/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 138/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0076 - accuracy: 0.9960
# Epoch 139/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0041 - accuracy: 1.0000
# Epoch 140/1500
# 13/24 [===============>..............] - ETA: 0s - loss: 0.0031 - accuracy: 1.0000    Restoring model weights from the end of the best epoch: 110.
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0042 - accuracy: 0.9987
# Epoch 140: early stopping
# 7/7 [==============================] - 0s 1ms/step - loss: 6.4455 - accuracy: 0.6175
# 7/7 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.76 (19/25)
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Before appending - Cat IDs: 0, Predictions: 0, Actuals: 0, Gender: 0
# After appending - Cat IDs: 217, Predictions: 217, Actuals: 217, Gender: 217
# Final Test Results - Loss: 6.445466995239258, Accuracy: 0.617511510848999, Precision: 0.5971092372134038, Recall: 0.584501624431449, F1 Score: 0.5904024026914637
# Confusion Matrix:
#  [[87  8 30]
#  [13 24  1]
#  [28  3 23]]
# outer_fold 2
# Train Set Group Distribution:
# 046A    66
# 000A    39
# 002B    36
# 103A    33
# 057A    28
# 074A    25
# 020A    23
# 055A    20
# 000B    20
# 059A    18
# 097A    16
# 101A    16
# 106A    15
# 001A    15
# 028A    14
# 097B    14
# 111A    13
# 002A    13
# 039A    12
# 051A    12
# 116A    12
# 016A    11
# 068A    11
# 063A    11
# 025A    11
# 036A    11
# 040A    10
# 014B    10
# 071A    10
# 015A    10
# 033A     9
# 045A     9
# 051B     9
# 072A     9
# 013B     8
# 094A     8
# 010A     8
# 053A     7
# 099A     7
# 117A     7
# 031A     7
# 027A     7
# 023A     6
# 108A     6
# 008A     6
# 037A     6
# 025C     6
# 007A     6
# 075A     5
# 034A     5
# 062A     5
# 070A     5
# 023B     5
# 044A     5
# 035A     4
# 026A     4
# 003A     4
# 009A     4
# 052A     4
# 056A     3
# 113A     3
# 011A     3
# 060A     3
# 018A     2
# 025B     2
# 038A     2
# 032A     2
# 054A     2
# 102A     2
# 026C     1
# 041A     1
# 019B     1
# 115A     1
# 110A     1
# 043A     1
# 090A     1
# 073A     1
# 088A     1
# 092A     1
# 048A     1
# 049A     1
# 026B     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 047A    30
# 067A    20
# 019A    17
# 029A    17
# 042A    14
# 005A    11
# 022A     9
# 065A     9
# 095A     8
# 050A     7
# 109A     6
# 021A     6
# 012A     5
# 104A     4
# 105A     4
# 014A     3
# 064A     3
# 058A     3
# 006A     3
# 061A     2
# 087A     2
# 066A     2
# 069A     2
# 093A     2
# 096A     1
# 024A     1
# 091A     1
# 076A     1
# 004A     1
# 100A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    272
# X    270
# F    231
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    85
# M    84
# F    26
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [002A, 028A, 070A, 033A, 000B, 071A, 020A, 000...
# kitten    [046A, 014B, 110A, 040A, 049A, 045A, 048A, 111...
# senior    [117A, 106A, 057A, 090A, 113A, 051B, 116A, 051...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [065A, 021A, 105A, 005A, 006A, 091A, 019A, 022...
# kitten                             [042A, 109A, 047A, 050A]
# senior                       [024A, 058A, 061A, 104A, 093A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 53, 'kitten': 12, 'senior': 17}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 21, 'kitten': 4, 'senior': 5}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '007A' '008A' '009A' '010A'
#  '011A' '013B' '014B' '015A' '016A' '018A' '019B' '020A' '023A' '023B'
#  '025A' '025B' '025C' '026A' '026B' '026C' '027A' '028A' '031A' '032A'
#  '033A' '034A' '035A' '036A' '037A' '038A' '039A' '040A' '041A' '043A'
#  '044A' '045A' '046A' '048A' '049A' '051A' '051B' '052A' '053A' '054A'
#  '055A' '056A' '057A' '059A' '060A' '062A' '063A' '068A' '070A' '071A'
#  '072A' '073A' '074A' '075A' '088A' '090A' '092A' '094A' '097A' '097B'
#  '099A' '101A' '102A' '103A' '106A' '108A' '110A' '111A' '113A' '115A'
#  '116A' '117A']
# Unique Test Group IDs:
# ['004A' '005A' '006A' '012A' '014A' '019A' '021A' '022A' '024A' '029A'
#  '042A' '047A' '050A' '058A' '061A' '064A' '065A' '066A' '067A' '069A'
#  '076A' '087A' '091A' '093A' '095A' '096A' '100A' '104A' '105A' '109A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '007A' '008A' '009A' '010A'
#  '011A' '013B' '014B' '015A' '016A' '018A' '019B' '020A' '023A' '023B'
#  '025A' '025B' '025C' '026A' '026B' '026C' '027A' '028A' '031A' '032A'
#  '033A' '034A' '035A' '036A' '037A' '038A' '039A' '040A' '041A' '043A'
#  '044A' '045A' '046A' '048A' '049A' '051A' '051B' '052A' '053A' '054A'
#  '055A' '056A' '057A' '059A' '060A' '062A' '063A' '068A' '070A' '071A'
#  '072A' '073A' '074A' '075A' '088A' '090A' '092A' '094A' '097A' '097B'
#  '099A' '101A' '102A' '103A' '106A' '108A' '110A' '111A' '113A' '115A'
#  '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['004A' '005A' '006A' '012A' '014A' '019A' '021A' '022A' '024A' '029A'
#  '042A' '047A' '050A' '058A' '061A' '064A' '065A' '066A' '067A' '069A'
#  '076A' '087A' '091A' '093A' '095A' '096A' '100A' '104A' '105A' '109A']
# Length of X_train_val:
# 773
# Length of y_train_val:
# 773
# Length of groups_train_val:
# 773
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     480
# senior    174
# kitten    119
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     126
# kitten     57
# senior     12
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     480
# senior    174
# kitten    119
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     126
# kitten     57
# senior     12
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 480, 2: 174, 1: 119})
# Epoch 1/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.6001 - accuracy: 0.3933
# Epoch 2/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0942 - accuracy: 0.5485
# Epoch 3/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.8737 - accuracy: 0.6261
# Epoch 4/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6906 - accuracy: 0.7219
# Epoch 5/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.6309 - accuracy: 0.7516
# Epoch 6/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.5359 - accuracy: 0.7827
# Epoch 7/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.5149 - accuracy: 0.7878
# Epoch 8/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.4462 - accuracy: 0.8422
# Epoch 9/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.4038 - accuracy: 0.8279
# Epoch 10/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3769 - accuracy: 0.8655
# Epoch 11/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3134 - accuracy: 0.8771
# Epoch 12/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2877 - accuracy: 0.8991
# Epoch 13/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2742 - accuracy: 0.9094
# Epoch 14/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2085 - accuracy: 0.9263
# Epoch 15/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2448 - accuracy: 0.9340
# Epoch 16/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.1915 - accuracy: 0.9379
# Epoch 17/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.1970 - accuracy: 0.9353
# Epoch 18/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.1765 - accuracy: 0.9444
# Epoch 19/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.1658 - accuracy: 0.9495
# Epoch 20/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.1787 - accuracy: 0.9340
# Epoch 21/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.1755 - accuracy: 0.9392
# Epoch 22/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.1291 - accuracy: 0.9612
# Epoch 23/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.1219 - accuracy: 0.9664
# Epoch 24/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.1238 - accuracy: 0.9625
# Epoch 25/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.1125 - accuracy: 0.9715
# Epoch 26/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.1200 - accuracy: 0.9612
# Epoch 27/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.1107 - accuracy: 0.9715
# Epoch 28/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0994 - accuracy: 0.9754
# Epoch 29/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.1168 - accuracy: 0.9599
# Epoch 30/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.1093 - accuracy: 0.9690
# Epoch 31/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.1174 - accuracy: 0.9651
# Epoch 32/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0914 - accuracy: 0.9793
# Epoch 33/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0812 - accuracy: 0.9767
# Epoch 34/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0618 - accuracy: 0.9871
# Epoch 35/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0807 - accuracy: 0.9780
# Epoch 36/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0943 - accuracy: 0.9741
# Epoch 37/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0632 - accuracy: 0.9935
# Epoch 38/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0581 - accuracy: 0.9884
# Epoch 39/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0633 - accuracy: 0.9806
# Epoch 40/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0627 - accuracy: 0.9832
# Epoch 41/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0704 - accuracy: 0.9819
# Epoch 42/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0634 - accuracy: 0.9845
# Epoch 43/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0449 - accuracy: 0.9858
# Epoch 44/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0426 - accuracy: 0.9897
# Epoch 45/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0506 - accuracy: 0.9858
# Epoch 46/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0509 - accuracy: 0.9819
# Epoch 47/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0537 - accuracy: 0.9845
# Epoch 48/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0391 - accuracy: 0.9922
# Epoch 49/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0537 - accuracy: 0.9819
# Epoch 50/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0416 - accuracy: 0.9884
# Epoch 51/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0610 - accuracy: 0.9780
# Epoch 52/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0418 - accuracy: 0.9909
# Epoch 53/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0437 - accuracy: 0.9858
# Epoch 54/1500
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0409 - accuracy: 0.9909
# Epoch 55/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0313 - accuracy: 0.9948
# Epoch 56/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0316 - accuracy: 0.9948
# Epoch 57/1500
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0369 - accuracy: 0.9909
# Epoch 58/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0390 - accuracy: 0.9897
# Epoch 59/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0375 - accuracy: 0.9909
# Epoch 60/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0375 - accuracy: 0.9884
# Epoch 61/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0610 - accuracy: 0.9832
# Epoch 62/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0320 - accuracy: 0.9922
# Epoch 63/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0301 - accuracy: 0.9922
# Epoch 64/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0306 - accuracy: 0.9948
# Epoch 65/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0468 - accuracy: 0.9858
# Epoch 66/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0328 - accuracy: 0.9922
# Epoch 67/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0200 - accuracy: 0.9974
# Epoch 68/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0187 - accuracy: 0.9961
# Epoch 69/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0351 - accuracy: 0.9909
# Epoch 70/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0270 - accuracy: 0.9922
# Epoch 71/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0327 - accuracy: 0.9922
# Epoch 72/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0221 - accuracy: 0.9987
# Epoch 73/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0198 - accuracy: 0.9948
# Epoch 74/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0362 - accuracy: 0.9897
# Epoch 75/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0173 - accuracy: 0.9961
# Epoch 76/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0330 - accuracy: 0.9909
# Epoch 77/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0193 - accuracy: 0.9987
# Epoch 78/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0185 - accuracy: 0.9922
# Epoch 79/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0203 - accuracy: 0.9961
# Epoch 80/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0202 - accuracy: 0.9974
# Epoch 81/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0105 - accuracy: 0.9987
# Epoch 82/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0281 - accuracy: 0.9948
# Epoch 83/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0244 - accuracy: 0.9948
# Epoch 84/1500
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0142 - accuracy: 0.9974
# Epoch 85/1500
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0118 - accuracy: 0.9987
# Epoch 86/1500
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0159 - accuracy: 0.9974
# Epoch 87/1500
# 25/25 [==============================] - 0s 8ms/step - loss: 0.0183 - accuracy: 0.9961
# Epoch 88/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0249 - accuracy: 0.9935
# Epoch 89/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0192 - accuracy: 0.9948
# Epoch 90/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0215 - accuracy: 0.9935
# Epoch 91/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0249 - accuracy: 0.9922
# Epoch 92/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0167 - accuracy: 0.9961
# Epoch 93/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0195 - accuracy: 0.9948
# Epoch 94/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0215 - accuracy: 0.9961
# Epoch 95/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0160 - accuracy: 0.9987
# Epoch 96/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0236 - accuracy: 0.9935
# Epoch 97/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0129 - accuracy: 1.0000
# Epoch 98/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0249 - accuracy: 0.9961
# Epoch 99/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0238 - accuracy: 0.9935
# Epoch 100/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0094 - accuracy: 1.0000
# Epoch 101/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0121 - accuracy: 0.9974
# Epoch 102/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0145 - accuracy: 0.9974
# Epoch 103/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0133 - accuracy: 0.9987
# Epoch 104/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0104 - accuracy: 0.9987
# Epoch 105/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0090 - accuracy: 0.9974
# Epoch 106/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0121 - accuracy: 0.9974
# Epoch 107/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0150 - accuracy: 0.9948
# Epoch 108/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0109 - accuracy: 0.9974
# Epoch 109/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0136 - accuracy: 0.9974
# Epoch 110/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0128 - accuracy: 0.9974
# Epoch 111/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0228 - accuracy: 0.9922
# Epoch 112/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0242 - accuracy: 0.9909
# Epoch 113/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0213 - accuracy: 0.9909
# Epoch 114/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0282 - accuracy: 0.9871
# Epoch 115/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0229 - accuracy: 0.9948
# Epoch 116/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0142 - accuracy: 0.9948
# Epoch 117/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0207 - accuracy: 0.9948
# Epoch 118/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0155 - accuracy: 0.9961
# Epoch 119/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0189 - accuracy: 0.9961
# Epoch 120/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0146 - accuracy: 0.9974
# Epoch 121/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0216 - accuracy: 0.9935
# Epoch 122/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0106 - accuracy: 0.9987
# Epoch 123/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0140 - accuracy: 0.9961
# Epoch 124/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0160 - accuracy: 0.9961
# Epoch 125/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0102 - accuracy: 0.9974
# Epoch 126/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0127 - accuracy: 0.9948
# Epoch 127/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0045 - accuracy: 1.0000
# Epoch 128/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0116 - accuracy: 0.9987
# Epoch 129/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0098 - accuracy: 0.9974
# Epoch 130/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0075 - accuracy: 0.9987
# Epoch 131/1500
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0085 - accuracy: 0.9987
# Epoch 132/1500
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0269 - accuracy: 0.9935
# Epoch 133/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0072 - accuracy: 0.9987
# Epoch 134/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0101 - accuracy: 0.9948
# Epoch 135/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0081 - accuracy: 1.0000
# Epoch 136/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0112 - accuracy: 0.9961
# Epoch 137/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0042 - accuracy: 1.0000
# Epoch 138/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 139/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0094 - accuracy: 0.9987
# Epoch 140/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0097 - accuracy: 0.9961
# Epoch 141/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0112 - accuracy: 0.9974
# Epoch 142/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0177 - accuracy: 0.9974
# Epoch 143/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0229 - accuracy: 0.9961
# Epoch 144/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0218 - accuracy: 0.9961
# Epoch 145/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0117 - accuracy: 0.9987
# Epoch 146/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0149 - accuracy: 0.9974
# Epoch 147/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0126 - accuracy: 0.9961
# Epoch 148/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0261 - accuracy: 0.9909
# Epoch 149/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0104 - accuracy: 0.9961
# Epoch 150/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0119 - accuracy: 0.9961
# Epoch 151/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0176 - accuracy: 0.9935
# Epoch 152/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0214 - accuracy: 0.9935
# Epoch 153/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0105 - accuracy: 0.9987
# Epoch 154/1500
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0059 - accuracy: 1.0000
# Epoch 155/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0071 - accuracy: 1.0000
# Epoch 156/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0127 - accuracy: 0.9961
# Epoch 157/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0174 - accuracy: 0.9935
# Epoch 158/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0158 - accuracy: 0.9961
# Epoch 159/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0173 - accuracy: 0.9922
# Epoch 160/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0182 - accuracy: 0.9922
# Epoch 161/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0134 - accuracy: 0.9987
# Epoch 162/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0187 - accuracy: 0.9974
# Epoch 163/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0182 - accuracy: 0.9922
# Epoch 164/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0062 - accuracy: 0.9987
# Epoch 165/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0067 - accuracy: 0.9987
# Epoch 166/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0076 - accuracy: 0.9987
# Epoch 167/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0129 - accuracy: 0.9961
# Epoch 168/1500
# 14/25 [===============>..............] - ETA: 0s - loss: 0.0056 - accuracy: 1.0000Restoring model weights from the end of the best epoch: 138.
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0079 - accuracy: 1.0000
# Epoch 168: early stopping
# 7/7 [==============================] - 0s 1ms/step - loss: 4.0372 - accuracy: 0.5692
# 7/7 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.63 (19/30)
# Before appending - Cat IDs: 217, Predictions: 217, Actuals: 217, Gender: 217
# After appending - Cat IDs: 412, Predictions: 412, Actuals: 412, Gender: 412
# Final Test Results - Loss: 4.0371880531311035, Accuracy: 0.5692307949066162, Precision: 0.4232198142414861, Recall: 0.4266917293233083, F1 Score: 0.41723510282622994
# Confusion Matrix:
#  [[90 21 15]
#  [38 18  1]
#  [ 8  1  3]]
# outer_fold 3
# Train Set Group Distribution:
# 046A    66
# 000A    39
# 103A    33
# 047A    30
# 074A    25
# 055A    20
# 000B    20
# 067A    20
# 059A    18
# 029A    17
# 019A    17
# 097A    16
# 106A    15
# 042A    14
# 097B    14
# 111A    13
# 051A    12
# 068A    11
# 063A    11
# 005A    11
# 025A    11
# 036A    11
# 040A    10
# 015A    10
# 022A     9
# 033A     9
# 045A     9
# 051B     9
# 072A     9
# 065A     9
# 095A     8
# 094A     8
# 010A     8
# 099A     7
# 027A     7
# 053A     7
# 050A     7
# 031A     7
# 025C     6
# 023A     6
# 021A     6
# 109A     6
# 012A     5
# 044A     5
# 075A     5
# 023B     5
# 035A     4
# 052A     4
# 104A     4
# 105A     4
# 026A     4
# 003A     4
# 064A     3
# 006A     3
# 014A     3
# 011A     3
# 058A     3
# 056A     3
# 087A     2
# 025B     2
# 066A     2
# 061A     2
# 093A     2
# 069A     2
# 018A     2
# 019B     1
# 041A     1
# 115A     1
# 004A     1
# 026B     1
# 076A     1
# 073A     1
# 110A     1
# 090A     1
# 088A     1
# 096A     1
# 043A     1
# 091A     1
# 024A     1
# 092A     1
# 048A     1
# 100A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 002B    36
# 057A    28
# 020A    23
# 101A    16
# 001A    15
# 028A    14
# 002A    13
# 116A    12
# 039A    12
# 016A    11
# 014B    10
# 071A    10
# 013B     8
# 117A     7
# 007A     6
# 037A     6
# 008A     6
# 108A     6
# 070A     5
# 034A     5
# 062A     5
# 009A     4
# 060A     3
# 113A     3
# 102A     2
# 054A     2
# 032A     2
# 038A     2
# 026C     1
# 049A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    274
# M    257
# F    163
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# M    99
# F    94
# X    81
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [033A, 000B, 000A, 015A, 026A, 065A, 053A, 023...
# kitten    [046A, 042A, 110A, 109A, 040A, 047A, 045A, 048...
# senior    [106A, 090A, 051B, 051A, 024A, 097A, 094A, 059...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [002A, 028A, 070A, 071A, 020A, 038A, 026C, 007...
# kitten                                         [014B, 049A]
# senior           [117A, 057A, 113A, 116A, 016A, 054A, 108A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 53, 'kitten': 14, 'senior': 15}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 21, 'kitten': 2, 'senior': 7}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '003A' '004A' '005A' '006A' '010A' '011A' '012A' '014A'
#  '015A' '018A' '019A' '019B' '021A' '022A' '023A' '023B' '024A' '025A'
#  '025B' '025C' '026A' '026B' '027A' '029A' '031A' '033A' '035A' '036A'
#  '040A' '041A' '042A' '043A' '044A' '045A' '046A' '047A' '048A' '050A'
#  '051A' '051B' '052A' '053A' '055A' '056A' '058A' '059A' '061A' '063A'
#  '064A' '065A' '066A' '067A' '068A' '069A' '072A' '073A' '074A' '075A'
#  '076A' '087A' '088A' '090A' '091A' '092A' '093A' '094A' '095A' '096A'
#  '097A' '097B' '099A' '100A' '103A' '104A' '105A' '106A' '109A' '110A'
#  '111A' '115A']
# Unique Test Group IDs:
# ['001A' '002A' '002B' '007A' '008A' '009A' '013B' '014B' '016A' '020A'
#  '026C' '028A' '032A' '034A' '037A' '038A' '039A' '049A' '054A' '057A'
#  '060A' '062A' '070A' '071A' '101A' '102A' '108A' '113A' '116A' '117A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '003A' '004A' '005A' '006A' '010A' '011A' '012A' '014A'
#  '015A' '018A' '019A' '019B' '021A' '022A' '023A' '023B' '024A' '025A'
#  '025B' '025C' '026A' '026B' '027A' '029A' '031A' '033A' '035A' '036A'
#  '040A' '041A' '042A' '043A' '044A' '045A' '046A' '047A' '048A' '050A'
#  '051A' '051B' '052A' '053A' '055A' '056A' '058A' '059A' '061A' '063A'
#  '064A' '065A' '066A' '067A' '068A' '069A' '072A' '073A' '074A' '075A'
#  '076A' '087A' '088A' '090A' '091A' '092A' '093A' '094A' '095A' '096A'
#  '097A' '097B' '099A' '100A' '103A' '104A' '105A' '106A' '109A' '110A'
#  '111A' '115A']
# AFTER SWAP - Unique Test Group IDs:
# ['001A' '002A' '002B' '007A' '008A' '009A' '013B' '014B' '016A' '020A'
#  '026C' '028A' '032A' '034A' '037A' '038A' '039A' '049A' '054A' '057A'
#  '060A' '062A' '070A' '071A' '101A' '102A' '108A' '113A' '116A' '117A']
# Length of X_train_val:
# 694
# Length of y_train_val:
# 694
# Length of groups_train_val:
# 694
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     412
# kitten    165
# senior    117
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     194
# senior     69
# kitten     11
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     412
# kitten    165
# senior    117
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     194
# senior     69
# kitten     11
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
# ...
# age_group
# adult     [002A, 028A, 070A, 033A, 071A, 020A, 015A, 065...
# kitten    [046A, 042A, 014B, 109A, 047A, 049A, 045A, 048...
# senior    [117A, 106A, 057A, 090A, 113A, 116A, 051A, 024...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [000B, 000A, 026A, 053A, 072A, 010A, 074A, 031...
# kitten                       [110A, 040A, 043A, 041A, 115A]
# senior                       [051B, 097A, 055A, 011A, 056A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 57, 'kitten': 11, 'senior': 17}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 17, 'kitten': 5, 'senior': 5}
# Unique Training/Validation Group IDs:
# ['001A' '002A' '002B' '004A' '005A' '006A' '007A' '008A' '009A' '012A'
#  '013B' '014A' '014B' '015A' '016A' '018A' '019A' '019B' '020A' '021A'
#  '022A' '023B' '024A' '025A' '026C' '028A' '029A' '032A' '033A' '034A'
#  '035A' '036A' '037A' '038A' '039A' '042A' '044A' '045A' '046A' '047A'
#  '048A' '049A' '050A' '051A' '052A' '054A' '057A' '058A' '059A' '060A'
#  '061A' '062A' '063A' '064A' '065A' '066A' '067A' '068A' '069A' '070A'
#  '071A' '075A' '076A' '087A' '090A' '091A' '092A' '093A' '094A' '095A'
#  '096A' '099A' '100A' '101A' '102A' '103A' '104A' '105A' '106A' '108A'
#  '109A' '111A' '113A' '116A' '117A']
# Unique Test Group IDs:
# ['000A' '000B' '003A' '010A' '011A' '023A' '025B' '025C' '026A' '026B'
#  '027A' '031A' '040A' '041A' '043A' '051B' '053A' '055A' '056A' '072A'
#  '073A' '074A' '088A' '097A' '097B' '110A' '115A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# {'000A'}
# Removed from Training/Validation Set:
# {'092A'}
# Moved to Test Set:
# {'092A'}
# Removed from Test Set
# {'000A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '001A' '002A' '002B' '004A' '005A' '006A' '007A' '008A' '009A'
#  '012A' '013B' '014A' '014B' '015A' '016A' '018A' '019A' '019B' '020A'
#  '021A' '022A' '023B' '024A' '025A' '026C' '028A' '029A' '032A' '033A'
#  '034A' '035A' '036A' '037A' '038A' '039A' '042A' '044A' '045A' '046A'
#  '047A' '048A' '049A' '050A' '051A' '052A' '054A' '057A' '058A' '059A'
#  '060A' '061A' '062A' '063A' '064A' '065A' '066A' '067A' '068A' '069A'
#  '070A' '071A' '075A' '076A' '087A' '090A' '091A' '093A' '094A' '095A'
#  '096A' '099A' '100A' '101A' '102A' '103A' '104A' '105A' '106A' '108A'
#  '109A' '111A' '113A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['000B' '003A' '010A' '011A' '023A' '025B' '025C' '026A' '026B' '027A'
#  '031A' '040A' '041A' '043A' '051B' '053A' '055A' '056A' '072A' '073A'
#  '074A' '088A' '092A' '097A' '097B' '110A' '115A']
# Length of X_train_val:
# 780
# Length of y_train_val:
# 780
# Length of groups_train_val:
# 780
# No common groups found between train and test sets.
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Train Age Group Distribution BEFORE SWAP:
# adult     445
# kitten    162
# senior    135
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     161
# senior     51
# kitten     14
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     483
# kitten    162
# senior    135
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     123
# senior     51
# kitten     14
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 483, 1: 162, 2: 135})
# Epoch 1/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.4107 - accuracy: 0.4295
# Epoch 2/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.9926 - accuracy: 0.5859
# Epoch 3/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.8333 - accuracy: 0.6731
# Epoch 4/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.7153 - accuracy: 0.7026
# Epoch 5/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.6072 - accuracy: 0.7628
# Epoch 6/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.5299 - accuracy: 0.8077
# Epoch 7/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.4626 - accuracy: 0.8077
# Epoch 8/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3777 - accuracy: 0.8628
# Epoch 9/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3609 - accuracy: 0.8744
# Epoch 10/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3279 - accuracy: 0.8897
# Epoch 11/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2696 - accuracy: 0.9038
# Epoch 12/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2361 - accuracy: 0.9308
# Epoch 13/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2313 - accuracy: 0.9256
# Epoch 14/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2382 - accuracy: 0.9321
# Epoch 15/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.1889 - accuracy: 0.9436
# Epoch 16/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.1968 - accuracy: 0.9449
# Epoch 17/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.1474 - accuracy: 0.9603
# Epoch 18/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.1669 - accuracy: 0.9462
# Epoch 19/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.1473 - accuracy: 0.9538
# Epoch 20/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.1512 - accuracy: 0.9615
# Epoch 21/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.1039 - accuracy: 0.9756
# Epoch 22/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.1158 - accuracy: 0.9667
# Epoch 23/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.1061 - accuracy: 0.9731
# Epoch 24/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0918 - accuracy: 0.9795
# Epoch 25/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0928 - accuracy: 0.9744
# Epoch 26/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0760 - accuracy: 0.9833
# Epoch 27/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0816 - accuracy: 0.9808
# Epoch 28/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0716 - accuracy: 0.9885
# Epoch 29/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0666 - accuracy: 0.9782
# Epoch 30/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0675 - accuracy: 0.9821
# Epoch 31/1500
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0658 - accuracy: 0.9821
# Epoch 32/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0516 - accuracy: 0.9910
# Epoch 33/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0613 - accuracy: 0.9782
# Epoch 34/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0600 - accuracy: 0.9885
# Epoch 35/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0575 - accuracy: 0.9846
# Epoch 36/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0542 - accuracy: 0.9885
# Epoch 37/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0411 - accuracy: 0.9910
# Epoch 38/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0412 - accuracy: 0.9949
# Epoch 39/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0652 - accuracy: 0.9744
# Epoch 40/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0423 - accuracy: 0.9872
# Epoch 41/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0477 - accuracy: 0.9859
# Epoch 42/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0370 - accuracy: 0.9923
# Epoch 43/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0548 - accuracy: 0.9872
# Epoch 44/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0447 - accuracy: 0.9885
# Epoch 45/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0301 - accuracy: 0.9974
# Epoch 46/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0342 - accuracy: 0.9936
# Epoch 47/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0326 - accuracy: 0.9923
# Epoch 48/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0213 - accuracy: 0.9974
# Epoch 49/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0438 - accuracy: 0.9859
# Epoch 50/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0212 - accuracy: 0.9987
# Epoch 51/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0266 - accuracy: 0.9962
# Epoch 52/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0227 - accuracy: 0.9962
# Epoch 53/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0212 - accuracy: 0.9962
# Epoch 54/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0241 - accuracy: 0.9962
# Epoch 55/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0221 - accuracy: 0.9936
# Epoch 56/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0176 - accuracy: 0.9987
# Epoch 57/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0219 - accuracy: 0.9936
# Epoch 58/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0210 - accuracy: 0.9987
# Epoch 59/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0431 - accuracy: 0.9885
# Epoch 60/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0231 - accuracy: 0.9974
# Epoch 61/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0187 - accuracy: 0.9962
# Epoch 62/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0122 - accuracy: 0.9987
# Epoch 63/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0128 - accuracy: 0.9987
# Epoch 64/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0191 - accuracy: 0.9962
# Epoch 65/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0244 - accuracy: 0.9962
# Epoch 66/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0213 - accuracy: 0.9949
# Epoch 67/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0218 - accuracy: 0.9936
# Epoch 68/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0126 - accuracy: 0.9987
# Epoch 69/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0141 - accuracy: 0.9974
# Epoch 70/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0143 - accuracy: 0.9987
# Epoch 71/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0134 - accuracy: 0.9987
# Epoch 72/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0125 - accuracy: 0.9974
# Epoch 73/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0152 - accuracy: 0.9974
# Epoch 74/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0176 - accuracy: 0.9974
# Epoch 75/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0215 - accuracy: 0.9923
# Epoch 76/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0109 - accuracy: 0.9987
# Epoch 77/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0199 - accuracy: 0.9936
# Epoch 78/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0108 - accuracy: 0.9987
# Epoch 79/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0103 - accuracy: 0.9974
# Epoch 80/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0097 - accuracy: 0.9987
# Epoch 81/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0132 - accuracy: 0.9974
# Epoch 82/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0081 - accuracy: 0.9987
# Epoch 83/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0083 - accuracy: 1.0000
# Epoch 84/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0202 - accuracy: 0.9974
# Epoch 85/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0132 - accuracy: 0.9962
# Epoch 86/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0270 - accuracy: 0.9923
# Epoch 87/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0112 - accuracy: 0.9974
# Epoch 88/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0113 - accuracy: 0.9974
# Epoch 89/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0133 - accuracy: 0.9974
# Epoch 90/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0221 - accuracy: 0.9949
# Epoch 91/1500
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0193 - accuracy: 0.9949
# Epoch 92/1500
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0134 - accuracy: 0.9974
# Epoch 93/1500
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0245 - accuracy: 0.9910
# Epoch 94/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0201 - accuracy: 0.9949
# Epoch 95/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0178 - accuracy: 0.9962
# Epoch 96/1500
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0085 - accuracy: 1.0000
# Epoch 97/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0100 - accuracy: 0.9974
# Epoch 98/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0210 - accuracy: 0.9936
# Epoch 99/1500
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0111 - accuracy: 0.9987
# Epoch 100/1500
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0200 - accuracy: 0.9949
# Epoch 101/1500
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0112 - accuracy: 0.9974
# Epoch 102/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0114 - accuracy: 0.9974
# Epoch 103/1500
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0127 - accuracy: 0.9949
# Epoch 104/1500
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 105/1500
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0097 - accuracy: 0.9962
# Epoch 106/1500
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0101 - accuracy: 0.9962
# Epoch 107/1500
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0307 - accuracy: 0.9885
# Epoch 108/1500
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0175 - accuracy: 0.9923
# Epoch 109/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0146 - accuracy: 0.9962
# Epoch 110/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0127 - accuracy: 0.9962
# Epoch 111/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0114 - accuracy: 0.9974
# Epoch 112/1500
# 13/25 [==============>...............] - ETA: 0s - loss: 0.0116 - accuracy: 0.9976Restoring model weights from the end of the best epoch: 82.
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0116 - accuracy: 0.9974
# Epoch 112: early stopping
# 6/6 [==============================] - 0s 1ms/step - loss: 2.5177 - accuracy: 0.6543
# 6/6 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.81 (22/27)
# Before appending - Cat IDs: 686, Predictions: 686, Actuals: 686, Gender: 686
# After appending - Cat IDs: 874, Predictions: 874, Actuals: 874, Gender: 874
# Final Test Results - Loss: 2.5177478790283203, Accuracy: 0.6542553305625916, Precision: 0.554399501208012, Recall: 0.6075129238687346, F1 Score: 0.5402356902356903
# Confusion Matrix:
#  [[101  12  10]
#  [  3  11   0]
#  [ 37   3  11]]
#
# Final Average F1-Score across all UNSEEN TEST sets: 0.48627260406193407
#
# Final Average Loss across all UNSEEN TEST sets: 4.032098114490509
#
# Final Average Accuracy across all UNSEEN TEST sets: 0.5989355444908142
#
# Final Average Precision across all UNSEEN TEST sets: 0.4907983662359009
#
# Final Average Recall across all UNSEEN TEST sets: 0.5093053312511296

# %%
seed_2_folds_values = (unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1)

# Plotting all fold metrics
seed_2_folds_plot = plot_all_metrics(unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1, "Folds", "Fold Number")

# %% [markdown]
# ## Majority Voting on Total Entries per cat_id

# %%
# Debugging print statements
print(f'Checking - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
# Out:
# Checking - Cat IDs: 874, Predictions: 874, Actuals: 874, Gender: 874

# %%
# Create results df
full_results = pd.DataFrame({
    'cat_id': all_cat_ids,
    'predicted_age_group': all_predicted_age_groups,
    'actual_age_group': all_actual_age_groups,
    'all_gender': all_gender
})

# create a correct majority prediction column
full_results['correct'] = full_results['predicted_age_group'] == full_results['actual_age_group']

# %%
# Group by cat_id and aggregate predicted age groups
majority_votes = full_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first()

# Calculate the accuracy of majority voting
correct_predictions = (majority_votes == actual_groups).sum()
total_cats = len(actual_groups)
majority_vote_accuracy = correct_predictions / total_cats

logger(f"Overall Majority Vote Accuracy for cat_id: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

# store for final evaluation 
all_majority_vote_accuracies.append(majority_vote_accuracy)
# Out:
# Overall Majority Vote Accuracy for cat_id: 0.74 (81/110)

# %%
# Detailed df with predictions, actual labels, and comparison including majority vote
detailed_results = full_results.groupby('cat_id').apply(
    lambda x: pd.Series({
        'Predictions': list(x['predicted_age_group']),
        'Majority Vote': x['predicted_age_group'].mode()[0],
        'Actual Age Group': x['actual_age_group'].iloc[0],
        'Correct Majority Vote': x['predicted_age_group'].mode()[0] == x['actual_age_group'].iloc[0]
    })
).reset_index()

# Convert to DataFrame for better formatting and display
detailed_results = pd.DataFrame(detailed_results)

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 10)
pd.set_option('display.width', 1000)

sorted_detailed_results = detailed_results.sort_values(by='Correct Majority Vote', ascending=False)

# Display the sorted DataFrame
sorted_detailed_results
# Out:
#     cat_id                                        Predictions Majority Vote Actual Age Group  Correct Majority Vote
# 0     000B  [adult, adult, senior, adult, adult, adult, ki...         adult            adult                   True
# 66    060A                            [adult, senior, kitten]         adult            adult                   True
# 76    070A              [adult, senior, adult, adult, senior]         adult            adult                   True
# 74    068A  [adult, adult, senior, senior, senior, adult, ...         adult            adult                   True
# 73    067A  [adult, kitten, adult, kitten, kitten, adult, ...         adult            adult                   True
# 72    066A                                    [adult, kitten]         adult            adult                   True
# 71    065A  [adult, adult, adult, kitten, adult, kitten, k...         adult            adult                   True
# 70    064A                              [adult, adult, adult]         adult            adult                   True
# 69    063A  [kitten, adult, kitten, kitten, senior, adult,...         adult            adult                   True
# 68    062A               [senior, adult, adult, adult, adult]         adult            adult                   True
# 65    059A  [senior, senior, senior, senior, adult, senior...        senior           senior                   True
# 78    072A  [adult, adult, senior, adult, adult, kitten, a...         adult            adult                   True
# 59    053A  [adult, adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 58    052A                     [adult, adult, senior, senior]         adult            adult                   True
# 54    049A                                           [kitten]        kitten           kitten                   True
# 53    048A                                           [kitten]        kitten           kitten                   True
# 51    045A  [kitten, adult, adult, kitten, kitten, kitten,...        kitten           kitten                   True
# 49    043A                                           [kitten]        kitten           kitten                   True
# 47    041A                                           [kitten]        kitten           kitten                   True
# 46    040A  [kitten, adult, kitten, kitten, kitten, adult,...        kitten           kitten                   True
# 77    071A  [adult, senior, adult, adult, senior, senior, ...         adult            adult                   True
# 79    073A                                            [adult]         adult            adult                   True
# 44    038A                                    [adult, kitten]         adult            adult                   True
# 95    100A                                            [adult]         adult            adult                   True
# 107   115A                                           [kitten]        kitten           kitten                   True
# 106   113A                           [senior, senior, senior]        senior           senior                   True
# 105   111A  [kitten, kitten, kitten, kitten, kitten, kitte...        kitten           kitten                   True
# 104   110A                                           [kitten]        kitten           kitten                   True
# 100   105A                      [adult, adult, adult, kitten]         adult            adult                   True
# 98    103A  [adult, adult, adult, adult, adult, senior, ad...         adult            adult                   True
# 97    102A                                    [adult, senior]         adult            adult                   True
# 96    101A  [senior, adult, adult, adult, adult, senior, s...         adult            adult                   True
# 94    099A  [adult, adult, adult, kitten, adult, kitten, a...         adult            adult                   True
# 80    074A  [kitten, kitten, adult, adult, adult, adult, a...         adult            adult                   True
# 93    097B  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 91    096A                                            [adult]         adult            adult                   True
# 90    095A  [adult, adult, adult, senior, adult, adult, ad...         adult            adult                   True
# 87    092A                                     [adult, adult]         adult            adult                   True
# 86    091A                                            [adult]         adult            adult                   True
# 84    088A                                            [adult]         adult            adult                   True
# 83    087A                                     [adult, adult]         adult            adult                   True
# 81    075A               [adult, senior, adult, adult, adult]         adult            adult                   True
# 45    039A  [senior, senior, adult, adult, adult, adult, a...         adult            adult                   True
# 55    050A  [kitten, kitten, kitten, adult, adult, kitten,...        kitten           kitten                   True
# 43    037A       [kitten, adult, adult, adult, adult, senior]         adult            adult                   True
# 15    014A                              [adult, adult, adult]         adult            adult                   True
# 28    025A  [adult, adult, kitten, adult, adult, adult, ad...         adult            adult                   True
# 26    023B               [adult, adult, senior, adult, adult]         adult            adult                   True
# 25    023A       [adult, kitten, senior, adult, adult, adult]         adult            adult                   True
# 24    022A  [adult, kitten, kitten, kitten, adult, adult, ...         adult            adult                   True
# 42    036A  [senior, senior, adult, adult, adult, senior, ...         adult            adult                   True
# 22    020A  [adult, adult, adult, kitten, adult, adult, ad...         adult            adult                   True
# 21    019B                                            [adult]         adult            adult                   True
# 20    019A  [senior, adult, adult, adult, adult, adult, ad...         adult            adult                   True
# 19    018A                                     [adult, adult]         adult            adult                   True
# 17    015A  [adult, adult, adult, adult, adult, adult, sen...         adult            adult                   True
# 14    013B  [senior, adult, adult, adult, kitten, kitten, ...         adult            adult                   True
# 30    025C         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 13    012A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 11    010A  [adult, adult, adult, senior, adult, adult, ad...         adult            adult                   True
# 10    009A                     [senior, adult, senior, adult]         adult            adult                   True
# 9     008A         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 8     007A         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 7     006A                             [kitten, adult, adult]         adult            adult                   True
# 6     005A  [adult, senior, adult, kitten, senior, adult, ...         adult            adult                   True
# 4     003A                      [kitten, adult, adult, adult]         adult            adult                   True
# 3     002B  [senior, adult, adult, senior, senior, senior,...         adult            adult                   True
# 2     002A  [adult, kitten, senior, adult, adult, adult, s...         adult            adult                   True
# 29    025B                                     [adult, adult]         adult            adult                   True
# 23    021A       [senior, adult, adult, adult, adult, kitten]         adult            adult                   True
# 31    026A                     [senior, adult, adult, senior]         adult            adult                   True
# 39    033A  [adult, adult, adult, adult, adult, senior, se...         adult            adult                   True
# 36    029A  [adult, adult, adult, adult, senior, adult, ad...         adult            adult                   True
# 37    031A  [senior, adult, adult, adult, kitten, adult, a...         adult            adult                   True
# 38    032A                                     [adult, adult]         adult            adult                   True
# 35    028A  [adult, adult, adult, adult, adult, kitten, ad...         adult            adult                   True
# 34    027A  [kitten, adult, senior, adult, adult, senior, ...         adult            adult                   True
# 40    034A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 41    035A                      [adult, adult, senior, adult]         adult            adult                   True
# 33    026C                                            [adult]         adult            adult                   True
# 32    026B                                            [adult]         adult            adult                   True
# 48    042A  [kitten, adult, kitten, adult, adult, adult, k...         adult           kitten                  False
# 5     004A                                           [senior]        senior            adult                  False
# 103   109A        [adult, adult, kitten, adult, adult, adult]         adult           kitten                  False
# 102   108A       [adult, adult, adult, senior, adult, senior]         adult           senior                  False
# 92    097A  [adult, senior, senior, adult, kitten, adult, ...         adult           senior                  False
# 101   106A  [adult, adult, adult, adult, adult, adult, sen...         adult           senior                  False
# 99    104A                     [senior, adult, adult, senior]         adult           senior                  False
# 50    044A              [kitten, adult, adult, kitten, adult]         adult           kitten                  False
# 52    047A  [adult, adult, adult, kitten, kitten, adult, a...         adult           kitten                  False
# 108   116A  [adult, adult, adult, senior, adult, senior, s...         adult           senior                  False
# 12    011A                              [adult, adult, adult]         adult           senior                  False
# 56    051A  [adult, senior, adult, adult, adult, adult, ki...         adult           senior                  False
# 1     001A  [adult, adult, adult, senior, senior, senior, ...        senior            adult                  False
# 60    054A                                    [senior, adult]         adult           senior                  False
# 27    024A                                            [adult]         adult           senior                  False
# 75    069A                                   [senior, senior]        senior            adult                  False
# 64    058A                            [kitten, senior, adult]         adult           senior                  False
# 63    057A  [adult, adult, senior, adult, adult, adult, ad...         adult           senior                  False
# 62    056A                              [adult, adult, adult]         adult           senior                  False
# 61    055A  [adult, adult, adult, adult, adult, senior, ad...         adult           senior                  False
# 82    076A                                           [kitten]        kitten            adult                  False
# 67    061A                                     [adult, adult]         adult           senior                  False
# 18    016A  [senior, senior, adult, adult, kitten, adult, ...         adult           senior                  False
# 85    090A                                            [adult]         adult           senior                  False
# 16    014B  [kitten, adult, adult, kitten, senior, kitten,...         adult           kitten                  False
# 57    051B  [adult, adult, adult, senior, adult, senior, a...         adult           senior                  False
# 88    093A                                     [adult, adult]         adult           senior                  False
# 89    094A  [adult, senior, adult, senior, adult, senior, ...         adult           senior                  False
# 109   117A  [senior, adult, adult, adult, adult, adult, ad...         adult           senior                  False

# %%
# Create df for majority votes
majority_df = majority_votes.reset_index()
majority_df.columns = ['cat_id', 'Majority_Vote']

# Get actual groups for each cat_id
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first().reset_index()

# Merge majority votes with actual groups
majority_with_actual = pd.merge(majority_df, actual_groups, on='cat_id')

# Add a column to check if the majority vote was correct
majority_with_actual['Majority_Correct'] = majority_with_actual['Majority_Vote'] == majority_with_actual['actual_age_group']

# Count correct majority votes per class
correct_majority_votes_per_class = majority_with_actual.groupby('actual_age_group')['Majority_Correct'].sum()

print("Correct Majority Votes per Class:")
print(correct_majority_votes_per_class)
# Out:
# Correct Majority Votes per Class:
# actual_age_group
# adult     69
# kitten    10
# senior     2
# Name: Majority_Correct, dtype: int64

# %%
# Calculate the total count and the number of correct predictions for each class
class_stats = majority_with_actual.groupby('actual_age_group').agg(
    total_count=('Majority_Correct', 'size'),  # Total number of cases per class
    correct_count=('Majority_Correct', 'sum')  # Sum of correct predictions per class
).reset_index()

# Calculate accuracy for each class
class_stats['accuracy'] = class_stats['correct_count'] / class_stats['total_count'] * 100

# store for final evaluation 
all_majority_vote_details.append(class_stats)

# Log detailed stats
print("Detailed Class Statistics for Majority Votes:")
print(class_stats)
# Out:
# Detailed Class Statistics for Majority Votes:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult           73             69  94.520548
# 1           kitten           15             10  66.666667
# 2           senior           22              2   9.090909

# %%
# Plot for Detailed Class Statistics for Majority Votes
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Accuracy of Majority Votes by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Detailed Class Statistics

# %%
# Calculate the total count and the number of correct predictions for each class
class_stats = full_results.groupby('actual_age_group').agg(
    total_count=('correct', 'size'),
    correct_count=('correct', 'sum')
).reset_index()

# Calculate accuracy for each class
class_stats['accuracy'] = class_stats['correct_count'] / class_stats['total_count'] * 100

# store for final evaluation 
all_class_stats.append(class_stats)

# Log the detailed stats
print("Detailed Class Statistics:")
print(class_stats)
# Out:
# Detailed Class Statistics:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult          568            404  71.126761
# 1           kitten          120             56  46.666667
# 2           senior          186             60  32.258065

# %%
# Plot for Detailed Class Statistics (Overall)
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Overall Accuracy by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Gender Exploration

# %%
# Group by gender and calculate the total count, correct predictions, and accuracy
gender_stats = full_results.groupby('all_gender').agg(
    count=('cat_id', 'size'),  # Total number of cases per gender
    correct=('correct', 'sum')  # Sum of correct predictions per gender
).reset_index()

# Calculate accuracy for each gender
gender_stats['accuracy'] = (gender_stats['correct'] / gender_stats['count'] * 100).round(2)

# Display the DataFrame
print("Accuracy by Gender:")
print(gender_stats)

# store for final evaluation 
all_gender_stats.append(gender_stats)
# Out:
# Accuracy by Gender:
#   all_gender  count  correct  accuracy
# 0          F    218      119     54.59
# 1          M    357      246     68.91
# 2          X    299      155     51.84

# %%
# Plot for Accuracy by Gender
styled_barplot(gender_stats, 'all_gender', 'accuracy', 
               'Accuracy by Gender', 
               'Gender', 'Accuracy (%)')

# %% [markdown]
# ### Log current total CV Stats

# %%
print("Total Majority Vote Accuracy so far:", all_majority_vote_accuracies)
print("Total Class Statistics so far:\n", all_class_stats)
print("Total Gender Accuracy so far:\n", all_gender_stats)
# Out:
# Total Majority Vote Accuracy so far: [0.7454545454545455, 0.7363636363636363]
# Total Class Statistics so far:
#  [  actual_age_group  total_count  correct_count   accuracy
# 0            adult          573            444  77.486911
# 1           kitten          111             64  57.657658
# 2           senior          186             59  31.720430,   actual_age_group  total_count  correct_count   accuracy
# 0            adult          568            404  71.126761
# 1           kitten          120             56  46.666667
# 2           senior          186             60  32.258065]
# Total Gender Accuracy so far:
#  [  all_gender  count  correct  accuracy
# 0          F    218      128     58.72
# 1          M    362      263     72.65
# 2          X    290      176     60.69,   all_gender  count  correct  accuracy
# 0          F    218      119     54.59
# 1          M    357      246     68.91
# 2          X    299      155     51.84]

# %% [markdown]
# # RANDOM SEED 3

# %%
# Set a fixed random seed for reproducibility
random.seed(int(random_seeds[2]))
np.random.seed(int(random_seeds[2]))
tf.random.set_seed(int(random_seeds[2]))

# Load datasets
dataframe = pd.read_csv('/Users/astrid/PycharmProjects/data-aug-and-more/yamnet-tfhub-extraction/yamnet_embeddings_looped_april_23.csv')

def assign_age_group(age, age_groups):
    for group_name, age_range in age_groups.items():
        if age_range[0] <= age < age_range[1]:
            return group_name
    return 'Unknown'  # For any age that doesn't fit the defined groups

# Define age groups
age_groups = {
    'kitten': (0, 0.5),
    'adult': (0.5, 12),
    'senior': (12, 20)
}

# Create a new column for the age group
dataframe['age_group'] = dataframe['target'].apply(assign_age_group, age_groups=age_groups)

print(dataframe['age_group'].value_counts())
# Out:
# adult     606
# senior    186
# kitten    176
# Name: age_group, dtype: int64

# %%
# Separate features and labels
X = dataframe.iloc[:, :-4].values  # all columns except the last four

# Encode the 'age_group' column as integers using LabelEncoder
label_encoder = LabelEncoder()
encoded_y = label_encoder.fit_transform(dataframe['age_group'].values)

# Use the encoded labels for splitting and one-hot encoding
y = encoded_y  

# Convert 'cat_id' column to numpy array to be used as groups array for GroupKFold
groups = dataframe['cat_id'].values

# %%
tf.keras.backend.clear_session()

# %% [markdown]
# ## Run Setup

# %%
all_cat_ids = []
all_predicted_age_groups = []
all_actual_age_groups = []
all_gender = []

# Define the StratifiedGroupKFold splitter for 4 fold CV with random shuffling
outer_cv = StratifiedGroupKFold(n_splits=4, shuffle=True, random_state=int(random_seeds[2]))

# unseen test set metrics
unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1 = [], [], [], [], []

outer_fold = 0

# Use the splitter to generate indices for training and testing sets
# Note: GroupShuffleSplit.split returns indices, so we use it to index the arrays
for train_val_idx, test_idx in outer_cv.split(X, y, groups):
    outer_fold += 1
    logger(f"outer_fold {outer_fold}", file=log_file_path)

    # Convert indices back to DataFrame for easy manipulation
    df_train_val = dataframe.iloc[train_val_idx]
    df_test = dataframe.iloc[test_idx]

    ##############################
    # ASSESSING SPLITS BY CAT_ID #
    ##############################
    
    # Get the distribution of groups
    training_validation_group_distribution = df_train_val['cat_id'].value_counts()  
    testing_group_distribution = df_test['cat_id'].value_counts()  
    
    # Log or print the distribution
    logger(f"Train Set Group Distribution:\n{training_validation_group_distribution}", file=log_file_path)
    logger(f"Testing Set Group Distribution:\n{testing_group_distribution}", file=log_file_path)

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val['gender'].value_counts()
    testing_gender_distribution = df_test['gender'].value_counts()
    
    # Log the distribution
    logger(f"Training Set Gender Distribution BEFORE SWAP:\n{training_gender_distribution}", file=log_file_path)
    logger(f"Testing Set Gender Distribution BEFORE SWAP:\n{testing_gender_distribution}", file=log_file_path)

    # Group by 'age_group' and then list unique 'cat_id' within each age group
    unique_cat_ids_per_age_group_train_val = df_train_val.groupby('age_group')['cat_id'].unique()
    unique_cat_ids_per_age_group_test = df_test.groupby('age_group')['cat_id'].unique()
    
    # Log results
    logger(f"Unique Cat IDs per Age Group in Training/Validation Set:\n{unique_cat_ids_per_age_group_train_val}", file=log_file_path)
    logger(f"Unique Cat IDs per Age Group in Testing Set:\n{unique_cat_ids_per_age_group_test}", file=log_file_path)

    # Calculate the count of unique identifiers per age group for training and testing set
    counts_train_val = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_train_val.items()}
    counts_test = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_test.items()}

    # Log the counts of unique identifiers per age group
    logger(f"Count of Unique Cat IDs per Age Group in Training/Validation Set:\n{counts_train_val}", file=log_file_path)
    logger(f"Count of Unique Cat IDs per Age Group in Testing Set:\n{counts_test}", file=log_file_path)

    #######################################################
    # CONTINUE WITH ENSURING VALID AND APPROPRIATE SPLITS #
    #######################################################
    
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    groups_train_val, groups_test = groups[train_val_idx], groups[test_idx]

    # logging identifier splits 
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)

    # check group splits
    check_initial_group_split(groups_train_val, groups_test)

    # Specify the cat_ids that must be in the training/validation set
    specific_cat_ids = ['000A', '046A']
    
    # Perform the swapping operation
    train_val_idx, test_idx = swap_cat_id_instances(dataframe, train_val_idx, test_idx, specific_cat_ids)
    
    # Re-assign the sets based on the updated indices
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    new_groups_train_val, new_groups_test = groups[train_val_idx], groups[test_idx]

    # Find differences for training and test sets
    moved_to_train_val, removed_from_train_val = find_group_differences(groups_train_val, new_groups_train_val)
    moved_to_test, removed_from_test = find_group_differences(groups_test, new_groups_test)
    
    # Display the results
    logger(f"Moved to Training/Validation Set:\n{moved_to_train_val}", file=log_file_path)
    logger(f"Removed from Training/Validation Set:\n{removed_from_train_val}", file=log_file_path)
    logger(f"Moved to Test Set:\n{moved_to_test}", file=log_file_path)
    logger(f"Removed from Test Set\n{removed_from_test}", file=log_file_path)

    # Update X_train_val, X_test, y_train_val, y_test, groups_train_val, groups_test based on updated indices
    X_train_val = X[train_val_idx]
    y_train_val = y[train_val_idx]
    groups_train_val = groups[train_val_idx]
    
    X_test = X[test_idx]
    y_test = y[test_idx]
    groups_test = groups[test_idx]

    # logging identifier splits again after potential swaps
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"AFTER SWAP - Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"AFTER SWAP - Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)
    
    # Verify the lengths are consistent
    logger(f"Length of X_train_val:\n{len(X_train_val)}", file=log_file_path)
    logger(f"Length of y_train_val:\n{len(y_train_val)}", file=log_file_path)
    logger(f"Length of groups_train_val:\n{len(groups_train_val)}", file=log_file_path)

    # Check group splits once more
    check_initial_group_split(groups_train_val, groups_test)

    # Convert the modified indices back to a DataFrame representing the updated df_train_val
    df_train_val_updated = dataframe.iloc[train_val_idx].copy()
    df_test_updated = dataframe.iloc[test_idx].copy()

    ############################
    # LOGGING AGE GROUP SPLITS #
    ############################

    # Get the distribution of age groups of age groups before the update
    training_validation_age_group_distribution = df_train_val['age_group'].value_counts()
    testing_age_group_distribution = df_test['age_group'].value_counts()
    
    # Logthe distribution
    logger(f"Train Age Group Distribution BEFORE SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution BEFORE SWAP:\n{testing_age_group_distribution}", file=log_file_path)

    # Get the distribution of age groups after the update
    training_validation_age_group_distribution = df_train_val_updated['age_group'].value_counts()
    testing_age_group_distribution = df_test_updated['age_group'].value_counts()
    
    # Log the distribution
    logger(f"Train Age Group Distribution AFTER SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution AFTER SWAP:\n{testing_age_group_distribution}", file=log_file_path)
    
    ########################################################
    # TRACKING FINAL CAT_IDs & GENDER AFTER REDISTRIBUTION #
    ########################################################

    # Get the distribution of groups
    training_validation_group_distribution = df_train_val_updated['cat_id'].value_counts()  
    testing_group_distribution = df_test_updated['cat_id'].value_counts()  

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val_updated['gender'].value_counts()
    testing_gender_distribution = df_test_updated['gender'].value_counts()
    
    logger(f"\n Starting training on unseen test set\n", file=log_file_path)

    ###################
    # PREPARING MODEL #
    ###################

    # Calculate the distribution of age groups in y_train_val
    age_group_distribution = Counter(y_train_val)
    print("Age group distribution:", age_group_distribution)

    # EarlyStopping callback: monitor 'loss' instead of 'val_loss' for the test set
    early_stopping = EarlyStopping(
        monitor='loss',  
        min_delta=0.001, 
        patience=30,  
        verbose=1,  
        restore_best_weights=True  
    )

    # One final shuffle to ensure randomness
    outer_shuffle_idx = np.random.permutation(len(X_train_val))
    X_train_val = X_train_val[outer_shuffle_idx]
    y_train_val = y_train_val[outer_shuffle_idx]
    
    # Scale the features
    scaler_full = StandardScaler().fit(X_train_val)
    X_train_full_scaled = scaler_full.transform(X_train_val)
    X_test_scaled = scaler_full.transform(X_test)
    
    # Encode the labels
    y_train_full_encoded = to_categorical(y_train_val)
    y_test_encoded = to_categorical(y_test)

    #######################
    # BUILD & TRAIN MODEL #
    #######################

    optimizers = {
        'Adam': Adam(learning_rate=0.00013808925801643654)
    }
    
    # Model definition with dynamic number of layers
    model_full = Sequential()
    model_full.add(Dense(512, activation='relu', input_shape=(X_train_full_scaled.shape[1],)))
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.19804187627143222))  
    model_full.add(Dense(512, activation='relu',)) 
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.24412907103758918))  
    model_full.add(Dense(3, activation='softmax'))  
    
    # Use the optimizer from the parameters
    optimizer = optimizers['Adam']  # optimizer_key from parameters
    
    # Compile the model
    model_full.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    
    # Train the model on the full training set
    history_full = model_full.fit(X_train_full_scaled, y_train_full_encoded, epochs=1500, batch_size=32,
                                  verbose=1, callbacks=[early_stopping])
    
    # Evaluate the model on the held-out test set
    test_loss, test_accuracy = model_full.evaluate(X_test_scaled, y_test_encoded)

    y_test_pred_prob = model_full.predict(X_test_scaled)
    y_test_pred = np.argmax(y_test_pred_prob, axis=1)  
    y_test_true = np.argmax(y_test_encoded, axis=1)    

    ################################
    # LOG MAJORITY VOTE PER CAT_ID #
    ################################

    # Convert numeric predictions back to age group labels
    predicted_age_groups = label_encoder.inverse_transform(y_test_pred)
    actual_labels = label_encoder.inverse_transform(y_test_true)
    
    # Map predictions and actual labels back to cat_ids
    test_results = pd.DataFrame({
        'cat_id': df_test_updated['cat_id'],
        'predicted_age_group': predicted_age_groups,
        'actual_age_group': actual_labels
    })
    
    # Group by cat_id and aggregate predicted age groups
    majority_votes = test_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
    actual_groups = test_results.groupby('cat_id')['actual_age_group'].first()
    
    # Calculate the accuracy of majority voting
    correct_predictions = (majority_votes == actual_groups).sum()
    total_cats = len(actual_groups)
    majority_vote_accuracy = correct_predictions / total_cats
    
    # Log the accuracy of the majority voting
    logger(f"Majority Vote Accuracy for cat_id for this fold: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

    ####################################################
    # COLLECT PREDICTIONS FOR GENDER & CAT_ID ANALYSIS #
    ####################################################

    # Debugging print statements
    print(f'Before appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Extend lists with current fold results
    all_cat_ids.extend(df_test_updated['cat_id'].tolist())
    all_predicted_age_groups.extend(predicted_age_groups)
    all_actual_age_groups.extend(actual_labels)
    all_gender.extend(df_test_updated['gender'].tolist())

    # Debugging print statements
    print(f'After appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Calculate additional metrics
    test_precision = precision_score(y_test_true, y_test_pred, average='macro')  # Use 'macro' for imbalanced datasets
    test_recall = recall_score(y_test_true, y_test_pred, average='macro')
    test_f1 = f1_score(y_test_true, y_test_pred, average='macro')

    # prepare averages of outer metrics
    unseen_f1.append(test_f1)
    unseen_losses.append(test_loss)
    unseen_accuracies.append(test_accuracy)
    unseen_precisions.append(test_precision)
    unseen_recalls.append(test_recall)

    # Print final test results
    logger(f"Final Test Results - Loss: {test_loss}, Accuracy: {test_accuracy}, Precision: {test_precision}, Recall: {test_recall}, F1 Score: {test_f1}", file=log_file_path)

    # Generate the confusion matrix
    cm = confusion_matrix(y_test, y_test_pred)
    logger(f"Confusion Matrix:\n {cm}", file=log_file_path)

# Calculate the overall average metrics
unseen_set_avg_f1 = np.mean(unseen_f1)
unseen_set_avg_loss = np.mean(unseen_losses)
unseen_set_avg_acc = np.mean(unseen_accuracies)
unseen_set_avg_precision = np.mean(unseen_precisions)
unseen_set_avg_recall = np.mean(unseen_recalls)

logger(f"\nFinal Average F1-Score across all UNSEEN TEST sets: {unseen_set_avg_f1}", file=log_file_path)
logger(f"\nFinal Average Loss across all UNSEEN TEST sets: {unseen_set_avg_loss}", file=log_file_path)
logger(f"\nFinal Average Accuracy across all UNSEEN TEST sets: {unseen_set_avg_acc}", file=log_file_path)
logger(f"\nFinal Average Precision across all UNSEEN TEST sets: {unseen_set_avg_precision}", file=log_file_path)
logger(f"\nFinal Average Recall across all UNSEEN TEST sets: {unseen_set_avg_recall}\n", file=log_file_path)

# Append averages to total lists
all_f1.append(unseen_set_avg_f1)
all_losses.append(unseen_set_avg_loss)
all_accuracies.append(unseen_set_avg_acc)
all_precisions.append(unseen_set_avg_precision)
all_recalls.append(unseen_set_avg_recall)
# Out:
# outer_fold 1
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Train Set Group Distribution:
# 046A    66
# 000A    39
# 002B    36
# 103A    33
# 074A    25
# 067A    20
# 059A    18
# 019A    17
# 029A    17
# 101A    16
# 097A    16
# 106A    15
# 001A    15
# 028A    14
# 042A    14
# 111A    13
# 002A    13
# 051A    12
# 039A    12
# 116A    12
# 016A    11
# 025A    11
# 063A    11
# 071A    10
# 040A    10
# 015A    10
# 014B    10
# 022A     9
# 033A     9
# 072A     9
# 065A     9
# 095A     8
# 010A     8
# 117A     7
# 050A     7
# 031A     7
# 027A     7
# 023A     6
# 008A     6
# 021A     6
# 109A     6
# 108A     6
# 007A     6
# 037A     6
# 034A     5
# 075A     5
# 023B     5
# 012A     5
# 062A     5
# 035A     4
# 003A     4
# 009A     4
# 052A     4
# 104A     4
# 026A     4
# 064A     3
# 058A     3
# 011A     3
# 014A     3
# 056A     3
# 006A     3
# 113A     3
# 060A     3
# 066A     2
# 025B     2
# 087A     2
# 093A     2
# 018A     2
# 032A     2
# 054A     2
# 102A     2
# 069A     2
# 038A     2
# 088A     1
# 024A     1
# 076A     1
# 090A     1
# 115A     1
# 041A     1
# 091A     1
# 026C     1
# 110A     1
# 019B     1
# 096A     1
# 049A     1
# 092A     1
# 026B     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 047A    30
# 057A    28
# 020A    23
# 000B    20
# 055A    20
# 097B    14
# 005A    11
# 036A    11
# 068A    11
# 045A     9
# 051B     9
# 013B     8
# 094A     8
# 099A     7
# 053A     7
# 025C     6
# 044A     5
# 070A     5
# 105A     4
# 061A     2
# 043A     1
# 073A     1
# 048A     1
# 004A     1
# 100A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    292
# X    244
# F    189
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    111
# F     68
# M     64
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [002A, 028A, 033A, 071A, 000A, 015A, 026A, 065...
# kitten    [046A, 042A, 014B, 110A, 109A, 040A, 049A, 111...
# senior    [117A, 106A, 090A, 113A, 116A, 051A, 024A, 097...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [070A, 000B, 020A, 053A, 068A, 105A, 013B, 005...
# kitten                       [047A, 045A, 048A, 044A, 043A]
# senior                       [057A, 051B, 094A, 055A, 061A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 59, 'kitten': 11, 'senior': 17}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 15, 'kitten': 5, 'senior': 5}
# Unique Training/Validation Group IDs:
# ['000A' '001A' '002A' '002B' '003A' '006A' '007A' '008A' '009A' '010A'
#  '011A' '012A' '014A' '014B' '015A' '016A' '018A' '019A' '019B' '021A'
#  '022A' '023A' '023B' '024A' '025A' '025B' '026A' '026B' '026C' '027A'
#  '028A' '029A' '031A' '032A' '033A' '034A' '035A' '037A' '038A' '039A'
#  '040A' '041A' '042A' '046A' '049A' '050A' '051A' '052A' '054A' '056A'
#  '058A' '059A' '060A' '062A' '063A' '064A' '065A' '066A' '067A' '069A'
#  '071A' '072A' '074A' '075A' '076A' '087A' '088A' '090A' '091A' '092A'
#  '093A' '095A' '096A' '097A' '101A' '102A' '103A' '104A' '106A' '108A'
#  '109A' '110A' '111A' '113A' '115A' '116A' '117A']
# Unique Test Group IDs:
# ['000B' '004A' '005A' '013B' '020A' '025C' '036A' '043A' '044A' '045A'
#  '047A' '048A' '051B' '053A' '055A' '057A' '061A' '068A' '070A' '073A'
#  '094A' '097B' '099A' '100A' '105A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '001A' '002A' '002B' '003A' '006A' '007A' '008A' '009A' '010A'
#  '011A' '012A' '014A' '014B' '015A' '016A' '018A' '019A' '019B' '021A'
#  '022A' '023A' '023B' '024A' '025A' '025B' '026A' '026B' '026C' '027A'
#  '028A' '029A' '031A' '032A' '033A' '034A' '035A' '037A' '038A' '039A'
#  '040A' '041A' '042A' '046A' '049A' '050A' '051A' '052A' '054A' '056A'
#  '058A' '059A' '060A' '062A' '063A' '064A' '065A' '066A' '067A' '069A'
#  '071A' '072A' '074A' '075A' '076A' '087A' '088A' '090A' '091A' '092A'
#  '093A' '095A' '096A' '097A' '101A' '102A' '103A' '104A' '106A' '108A'
#  '109A' '110A' '111A' '113A' '115A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['000B' '004A' '005A' '013B' '020A' '025C' '036A' '043A' '044A' '045A'
#  '047A' '048A' '051B' '053A' '055A' '057A' '061A' '068A' '070A' '073A'
#  '094A' '097B' '099A' '100A' '105A']
# Length of X_train_val:
# 725
# Length of y_train_val:
# 725
# Length of groups_train_val:
# 725
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     476
# kitten    130
# senior    119
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     130
# senior     67
# kitten     46
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     476
# kitten    130
# senior    119
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     130
# senior     67
# kitten     46
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 476, 1: 130, 2: 119})
# Epoch 1/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 1.4980 - accuracy: 0.3890
# Epoch 2/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 1.0672 - accuracy: 0.5697
# Epoch 3/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.8754 - accuracy: 0.6566
# Epoch 4/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.7416 - accuracy: 0.6993
# Epoch 5/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.6399 - accuracy: 0.7531
# Epoch 6/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.5734 - accuracy: 0.7724
# Epoch 7/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.5023 - accuracy: 0.7959
# Epoch 8/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.4098 - accuracy: 0.8497
# Epoch 9/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.3732 - accuracy: 0.8593
# Epoch 10/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.3322 - accuracy: 0.8828
# Epoch 11/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3033 - accuracy: 0.8993
# Epoch 12/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.2737 - accuracy: 0.9048
# Epoch 13/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.2292 - accuracy: 0.9297
# Epoch 14/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.2470 - accuracy: 0.9172
# Epoch 15/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.2259 - accuracy: 0.9228
# Epoch 16/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1930 - accuracy: 0.9407
# Epoch 17/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1683 - accuracy: 0.9517
# Epoch 18/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1689 - accuracy: 0.9545
# Epoch 19/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1516 - accuracy: 0.9545
# Epoch 20/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1233 - accuracy: 0.9766
# Epoch 21/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1310 - accuracy: 0.9724
# Epoch 22/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.1249 - accuracy: 0.9655
# Epoch 23/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.1080 - accuracy: 0.9738
# Epoch 24/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.1087 - accuracy: 0.9724
# Epoch 25/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0893 - accuracy: 0.9793
# Epoch 26/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0968 - accuracy: 0.9752
# Epoch 27/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0833 - accuracy: 0.9779
# Epoch 28/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0849 - accuracy: 0.9807
# Epoch 29/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0824 - accuracy: 0.9807
# Epoch 30/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0580 - accuracy: 0.9862
# Epoch 31/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0579 - accuracy: 0.9876
# Epoch 32/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0480 - accuracy: 0.9862
# Epoch 33/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0793 - accuracy: 0.9752
# Epoch 34/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0437 - accuracy: 0.9931
# Epoch 35/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0543 - accuracy: 0.9890
# Epoch 36/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0579 - accuracy: 0.9890
# Epoch 37/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0456 - accuracy: 0.9917
# Epoch 38/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0391 - accuracy: 0.9903
# Epoch 39/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0497 - accuracy: 0.9848
# Epoch 40/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0327 - accuracy: 0.9959
# Epoch 41/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0335 - accuracy: 0.9917
# Epoch 42/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0490 - accuracy: 0.9834
# Epoch 43/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0340 - accuracy: 0.9903
# Epoch 44/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0351 - accuracy: 0.9903
# Epoch 45/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0310 - accuracy: 0.9945
# Epoch 46/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0574 - accuracy: 0.9834
# Epoch 47/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0276 - accuracy: 0.9945
# Epoch 48/1500
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0339 - accuracy: 0.9890
# Epoch 49/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0273 - accuracy: 0.9959
# Epoch 50/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0292 - accuracy: 0.9945
# Epoch 51/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0262 - accuracy: 0.9945
# Epoch 52/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0290 - accuracy: 0.9931
# Epoch 53/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0170 - accuracy: 0.9972
# Epoch 54/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0235 - accuracy: 0.9972
# Epoch 55/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0263 - accuracy: 0.9945
# Epoch 56/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0330 - accuracy: 0.9890
# Epoch 57/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0419 - accuracy: 0.9876
# Epoch 58/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0209 - accuracy: 0.9959
# Epoch 59/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0315 - accuracy: 0.9917
# Epoch 60/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0291 - accuracy: 0.9917
# Epoch 61/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0227 - accuracy: 0.9917
# Epoch 62/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0211 - accuracy: 0.9945
# Epoch 63/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0306 - accuracy: 0.9903
# Epoch 64/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0217 - accuracy: 0.9959
# Epoch 65/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0194 - accuracy: 0.9959
# Epoch 66/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0172 - accuracy: 0.9972
# Epoch 67/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0110 - accuracy: 1.0000
# Epoch 68/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0255 - accuracy: 0.9903
# Epoch 69/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0206 - accuracy: 0.9959
# Epoch 70/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0192 - accuracy: 0.9986
# Epoch 71/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0143 - accuracy: 0.9986
# Epoch 72/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0100 - accuracy: 1.0000
# Epoch 73/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0095 - accuracy: 0.9972
# Epoch 74/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0154 - accuracy: 0.9959
# Epoch 75/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0073 - accuracy: 1.0000
# Epoch 76/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0175 - accuracy: 0.9945
# Epoch 77/1500
# 23/23 [==============================] - 0s 10ms/step - loss: 0.0100 - accuracy: 1.0000
# Epoch 78/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0121 - accuracy: 0.9986
# Epoch 79/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0169 - accuracy: 0.9972
# Epoch 80/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0128 - accuracy: 0.9945
# Epoch 81/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0152 - accuracy: 0.9972
# Epoch 82/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0094 - accuracy: 0.9986
# Epoch 83/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0053 - accuracy: 1.0000
# Epoch 84/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0104 - accuracy: 0.9986
# Epoch 85/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0105 - accuracy: 0.9972
# Epoch 86/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0113 - accuracy: 0.9986
# Epoch 87/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0107 - accuracy: 0.9986
# Epoch 88/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0103 - accuracy: 0.9986
# Epoch 89/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0081 - accuracy: 1.0000
# Epoch 90/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0109 - accuracy: 0.9986
# Epoch 91/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0148 - accuracy: 0.9972
# Epoch 92/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0071 - accuracy: 1.0000
# Epoch 93/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 94/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0104 - accuracy: 0.9972
# Epoch 95/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0252 - accuracy: 0.9890
# Epoch 96/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0049 - accuracy: 1.0000
# Epoch 97/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0123 - accuracy: 0.9972
# Epoch 98/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0112 - accuracy: 0.9959
# Epoch 99/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0079 - accuracy: 0.9986
# Epoch 100/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0159 - accuracy: 0.9972
# Epoch 101/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0084 - accuracy: 0.9972
# Epoch 102/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0065 - accuracy: 1.0000
# Epoch 103/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0079 - accuracy: 0.9986
# Epoch 104/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0107 - accuracy: 0.9972
# Epoch 105/1500
# 23/23 [==============================] - 0s 10ms/step - loss: 0.0075 - accuracy: 0.9972
# Epoch 106/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0076 - accuracy: 0.9986
# Epoch 107/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0143 - accuracy: 0.9959
# Epoch 108/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0083 - accuracy: 0.9986
# Epoch 109/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0067 - accuracy: 0.9986
# Epoch 110/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0067 - accuracy: 0.9986
# Epoch 111/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0072 - accuracy: 1.0000
# Epoch 112/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0041 - accuracy: 0.9986
# Epoch 113/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0056 - accuracy: 1.0000
# Epoch 114/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0046 - accuracy: 1.0000
# Epoch 115/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0085 - accuracy: 0.9972
# Epoch 116/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0114 - accuracy: 0.9972
# Epoch 117/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0056 - accuracy: 1.0000
# Epoch 118/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0046 - accuracy: 1.0000
# Epoch 119/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0050 - accuracy: 1.0000
# Epoch 120/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0075 - accuracy: 0.9986
# Epoch 121/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 122/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0089 - accuracy: 0.9972
# Epoch 123/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0075 - accuracy: 0.9972
# Epoch 124/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 125/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0064 - accuracy: 0.9986
# Epoch 126/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0041 - accuracy: 0.9986
# Epoch 127/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0059 - accuracy: 0.9986
# Epoch 128/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0047 - accuracy: 1.0000
# Epoch 129/1500
# 23/23 [==============================] - 0s 10ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 130/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0075 - accuracy: 0.9986
# Epoch 131/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0057 - accuracy: 0.9986
# Epoch 132/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 133/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0065 - accuracy: 0.9972
# Epoch 134/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0099 - accuracy: 0.9972
# Epoch 135/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0114 - accuracy: 0.9959
# Epoch 136/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0067 - accuracy: 0.9972
# Epoch 137/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0051 - accuracy: 0.9986
# Epoch 138/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0087 - accuracy: 0.9972
# Epoch 139/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0066 - accuracy: 0.9986
# Epoch 140/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0060 - accuracy: 0.9986
# Epoch 141/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0091 - accuracy: 0.9986
# Epoch 142/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0050 - accuracy: 0.9986
# Epoch 143/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0058 - accuracy: 0.9986
# Epoch 144/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0055 - accuracy: 0.9986
# Epoch 145/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0074 - accuracy: 0.9986
# Epoch 146/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0051 - accuracy: 0.9986
# Epoch 147/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 148/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0071 - accuracy: 0.9986
# Epoch 149/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0061 - accuracy: 1.0000
# Epoch 150/1500
# 23/23 [==============================] - 0s 10ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 151/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0043 - accuracy: 1.0000
# Epoch 152/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0038 - accuracy: 0.9986
# Epoch 153/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0043 - accuracy: 1.0000
# Epoch 154/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0165 - accuracy: 0.9972
# Epoch 155/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0066 - accuracy: 0.9986
# Epoch 156/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0046 - accuracy: 0.9972
# Epoch 157/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0073 - accuracy: 0.9972
# Epoch 158/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0070 - accuracy: 0.9986
# Epoch 159/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0035 - accuracy: 0.9986
# Epoch 160/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 161/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 162/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0043 - accuracy: 0.9986
# Epoch 163/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0049 - accuracy: 0.9986
# Epoch 164/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 165/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0069 - accuracy: 0.9972
# Epoch 166/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 167/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0187 - accuracy: 0.9945
# Epoch 168/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0154 - accuracy: 0.9972
# Epoch 169/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0111 - accuracy: 0.9972
# Epoch 170/1500
# 23/23 [==============================] - 0s 11ms/step - loss: 0.0095 - accuracy: 0.9972
# Epoch 171/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0073 - accuracy: 0.9972
# Epoch 172/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0056 - accuracy: 0.9986
# Epoch 173/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 174/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 175/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0050 - accuracy: 0.9972
# Epoch 176/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0127 - accuracy: 0.9972
# Epoch 177/1500
# 14/23 [=================>............] - ETA: 0s - loss: 0.0020 - accuracy: 1.0000Restoring model weights from the end of the best epoch: 147.
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0087 - accuracy: 0.9972
# Epoch 177: early stopping
# 8/8 [==============================] - 0s 1ms/step - loss: 3.2030 - accuracy: 0.5638
# 8/8 [==============================] - 0s 998us/step
# Majority Vote Accuracy for cat_id for this fold: 0.76 (19/25)
# Before appending - Cat IDs: 0, Predictions: 0, Actuals: 0, Gender: 0
# After appending - Cat IDs: 243, Predictions: 243, Actuals: 243, Gender: 243
# Final Test Results - Loss: 3.2029552459716797, Accuracy: 0.5637860298156738, Precision: 0.5206847890671421, Recall: 0.4596732058769697, F1 Score: 0.4563386140673207
# Confusion Matrix:
#  [[109  10  11]
#  [ 25  18   3]
#  [ 53   4  10]]
# outer_fold 2
# Train Set Group Distribution:
# 046A    66
# 000A    39
# 103A    33
# 047A    30
# 057A    28
# 074A    25
# 020A    23
# 000B    20
# 067A    20
# 055A    20
# 059A    18
# 019A    17
# 097A    16
# 001A    15
# 097B    14
# 028A    14
# 111A    13
# 002A    13
# 116A    12
# 051A    12
# 039A    12
# 005A    11
# 068A    11
# 036A    11
# 025A    11
# 071A    10
# 014B    10
# 051B     9
# 072A     9
# 033A     9
# 045A     9
# 022A     9
# 094A     8
# 013B     8
# 053A     7
# 050A     7
# 117A     7
# 099A     7
# 031A     7
# 027A     7
# 008A     6
# 108A     6
# 021A     6
# 037A     6
# 007A     6
# 025C     6
# 044A     5
# 012A     5
# 070A     5
# 026A     4
# 104A     4
# 035A     4
# 003A     4
# 105A     4
# 052A     4
# 060A     3
# 064A     3
# 014A     3
# 056A     3
# 058A     3
# 006A     3
# 038A     2
# 032A     2
# 102A     2
# 061A     2
# 087A     2
# 066A     2
# 069A     2
# 018A     2
# 026B     1
# 004A     1
# 076A     1
# 115A     1
# 090A     1
# 043A     1
# 091A     1
# 024A     1
# 026C     1
# 048A     1
# 049A     1
# 073A     1
# 110A     1
# 100A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 002B    36
# 029A    17
# 101A    16
# 106A    15
# 042A    14
# 063A    11
# 016A    11
# 015A    10
# 040A    10
# 065A     9
# 010A     8
# 095A     8
# 109A     6
# 023A     6
# 034A     5
# 023B     5
# 075A     5
# 062A     5
# 009A     4
# 113A     3
# 011A     3
# 025B     2
# 093A     2
# 054A     2
# 088A     1
# 096A     1
# 019B     1
# 041A     1
# 092A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    297
# M    233
# F    220
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# M    123
# X     58
# F     37
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [002A, 028A, 070A, 033A, 000B, 071A, 020A, 000...
# kitten    [046A, 014B, 110A, 047A, 049A, 045A, 048A, 111...
# senior    [117A, 057A, 090A, 051B, 116A, 051A, 024A, 097...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [015A, 065A, 023B, 034A, 062A, 002B, 009A, 101...
# kitten                             [042A, 109A, 040A, 041A]
# senior                 [106A, 113A, 016A, 054A, 011A, 093A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 55, 'kitten': 12, 'senior': 16}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 19, 'kitten': 4, 'senior': 6}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '003A' '004A' '005A' '006A' '007A' '008A'
#  '012A' '013B' '014A' '014B' '018A' '019A' '020A' '021A' '022A' '024A'
#  '025A' '025C' '026A' '026B' '026C' '027A' '028A' '031A' '032A' '033A'
#  '035A' '036A' '037A' '038A' '039A' '043A' '044A' '045A' '046A' '047A'
#  '048A' '049A' '050A' '051A' '051B' '052A' '053A' '055A' '056A' '057A'
#  '058A' '059A' '060A' '061A' '064A' '066A' '067A' '068A' '069A' '070A'
#  '071A' '072A' '073A' '074A' '076A' '087A' '090A' '091A' '094A' '097A'
#  '097B' '099A' '100A' '102A' '103A' '104A' '105A' '108A' '110A' '111A'
#  '115A' '116A' '117A']
# Unique Test Group IDs:
# ['002B' '009A' '010A' '011A' '015A' '016A' '019B' '023A' '023B' '025B'
#  '029A' '034A' '040A' '041A' '042A' '054A' '062A' '063A' '065A' '075A'
#  '088A' '092A' '093A' '095A' '096A' '101A' '106A' '109A' '113A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '003A' '004A' '005A' '006A' '007A' '008A'
#  '012A' '013B' '014A' '014B' '018A' '019A' '020A' '021A' '022A' '024A'
#  '025A' '025C' '026A' '026B' '026C' '027A' '028A' '031A' '032A' '033A'
#  '035A' '036A' '037A' '038A' '039A' '043A' '044A' '045A' '046A' '047A'
#  '048A' '049A' '050A' '051A' '051B' '052A' '053A' '055A' '056A' '057A'
#  '058A' '059A' '060A' '061A' '064A' '066A' '067A' '068A' '069A' '070A'
#  '071A' '072A' '073A' '074A' '076A' '087A' '090A' '091A' '094A' '097A'
#  '097B' '099A' '100A' '102A' '103A' '104A' '105A' '108A' '110A' '111A'
#  '115A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['002B' '009A' '010A' '011A' '015A' '016A' '019B' '023A' '023B' '025B'
#  '029A' '034A' '040A' '041A' '042A' '054A' '062A' '063A' '065A' '075A'
#  '088A' '092A' '093A' '095A' '096A' '101A' '106A' '109A' '113A']
# Length of X_train_val:
# 750
# Length of y_train_val:
# 750
# Length of groups_train_val:
# 750
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     455
# senior    150
# kitten    145
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     151
# senior     36
# kitten     31
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     455
# senior    150
# kitten    145
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     151
# senior     36
# kitten     31
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 455, 2: 150, 1: 145})
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Epoch 1/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 1.4135 - accuracy: 0.4347
# Epoch 2/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 1.0053 - accuracy: 0.5987
# Epoch 3/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.8116 - accuracy: 0.6787
# Epoch 4/1500
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6606 - accuracy: 0.7387
# Epoch 5/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.5545 - accuracy: 0.7640
# Epoch 6/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.5028 - accuracy: 0.8053
# Epoch 7/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4644 - accuracy: 0.8160
# Epoch 8/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3623 - accuracy: 0.8653
# Epoch 9/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3345 - accuracy: 0.8733
# Epoch 10/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.3081 - accuracy: 0.8813
# Epoch 11/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2715 - accuracy: 0.8947
# Epoch 12/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2725 - accuracy: 0.9080
# Epoch 13/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2349 - accuracy: 0.9160
# Epoch 14/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1880 - accuracy: 0.9493
# Epoch 15/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1893 - accuracy: 0.9480
# Epoch 16/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1691 - accuracy: 0.9480
# Epoch 17/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.2146 - accuracy: 0.9253
# Epoch 18/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1357 - accuracy: 0.9720
# Epoch 19/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1186 - accuracy: 0.9733
# Epoch 20/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1339 - accuracy: 0.9600
# Epoch 21/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0991 - accuracy: 0.9760
# Epoch 22/1500
# 24/24 [==============================] - 0s 13ms/step - loss: 0.1077 - accuracy: 0.9720
# Epoch 23/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1029 - accuracy: 0.9733
# Epoch 24/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.1007 - accuracy: 0.9787
# Epoch 25/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0929 - accuracy: 0.9720
# Epoch 26/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0874 - accuracy: 0.9800
# Epoch 27/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0828 - accuracy: 0.9827
# Epoch 28/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0695 - accuracy: 0.9800
# Epoch 29/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0874 - accuracy: 0.9787
# Epoch 30/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0766 - accuracy: 0.9813
# Epoch 31/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0696 - accuracy: 0.9853
# Epoch 32/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0713 - accuracy: 0.9827
# Epoch 33/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0556 - accuracy: 0.9867
# Epoch 34/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0598 - accuracy: 0.9867
# Epoch 35/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0464 - accuracy: 0.9947
# Epoch 36/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0587 - accuracy: 0.9880
# Epoch 37/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0451 - accuracy: 0.9867
# Epoch 38/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0485 - accuracy: 0.9880
# Epoch 39/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0477 - accuracy: 0.9893
# Epoch 40/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0324 - accuracy: 0.9933
# Epoch 41/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0441 - accuracy: 0.9893
# Epoch 42/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0457 - accuracy: 0.9907
# Epoch 43/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0408 - accuracy: 0.9880
# Epoch 44/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0376 - accuracy: 0.9933
# Epoch 45/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0434 - accuracy: 0.9947
# Epoch 46/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0302 - accuracy: 0.9973
# Epoch 47/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0375 - accuracy: 0.9893
# Epoch 48/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0324 - accuracy: 0.9920
# Epoch 49/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0320 - accuracy: 0.9920
# Epoch 50/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0276 - accuracy: 0.9947
# Epoch 51/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0292 - accuracy: 0.9960
# Epoch 52/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0355 - accuracy: 0.9893
# Epoch 53/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0325 - accuracy: 0.9907
# Epoch 54/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0300 - accuracy: 0.9920
# Epoch 55/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0300 - accuracy: 0.9920
# Epoch 56/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0283 - accuracy: 0.9933
# Epoch 57/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0390 - accuracy: 0.9893
# Epoch 58/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0299 - accuracy: 0.9933
# Epoch 59/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0275 - accuracy: 0.9933
# Epoch 60/1500
# 24/24 [==============================] - 0s 10ms/step - loss: 0.0310 - accuracy: 0.9880
# Epoch 61/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0174 - accuracy: 0.9973
# Epoch 62/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0228 - accuracy: 0.9947
# Epoch 63/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0238 - accuracy: 0.9973
# Epoch 64/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0259 - accuracy: 0.9933
# Epoch 65/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0228 - accuracy: 0.9960
# Epoch 66/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0161 - accuracy: 0.9987
# Epoch 67/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0172 - accuracy: 0.9973
# Epoch 68/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0194 - accuracy: 0.9960
# Epoch 69/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0185 - accuracy: 0.9987
# Epoch 70/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0135 - accuracy: 0.9987
# Epoch 71/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0140 - accuracy: 0.9987
# Epoch 72/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0176 - accuracy: 0.9947
# Epoch 73/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0154 - accuracy: 0.9960
# Epoch 74/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0139 - accuracy: 0.9973
# Epoch 75/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0130 - accuracy: 0.9987
# Epoch 76/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0148 - accuracy: 0.9987
# Epoch 77/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0176 - accuracy: 0.9947
# Epoch 78/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0198 - accuracy: 0.9947
# Epoch 79/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0163 - accuracy: 0.9960
# Epoch 80/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0165 - accuracy: 0.9973
# Epoch 81/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0104 - accuracy: 0.9973
# Epoch 82/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0091 - accuracy: 0.9987
# Epoch 83/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0154 - accuracy: 0.9973
# Epoch 84/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0153 - accuracy: 0.9973
# Epoch 85/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0106 - accuracy: 0.9973
# Epoch 86/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0182 - accuracy: 0.9987
# Epoch 87/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0199 - accuracy: 0.9947
# Epoch 88/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0162 - accuracy: 0.9960
# Epoch 89/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0114 - accuracy: 0.9987
# Epoch 90/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0136 - accuracy: 0.9933
# Epoch 91/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0084 - accuracy: 1.0000
# Epoch 92/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0214 - accuracy: 0.9933
# Epoch 93/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0114 - accuracy: 0.9973
# Epoch 94/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0200 - accuracy: 0.9920
# Epoch 95/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0070 - accuracy: 1.0000
# Epoch 96/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0127 - accuracy: 0.9973
# Epoch 97/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0055 - accuracy: 1.0000
# Epoch 98/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0075 - accuracy: 1.0000
# Epoch 99/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0064 - accuracy: 1.0000
# Epoch 100/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0107 - accuracy: 0.9960
# Epoch 101/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0053 - accuracy: 1.0000
# Epoch 102/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0104 - accuracy: 0.9973
# Epoch 103/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0110 - accuracy: 0.9973
# Epoch 104/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0049 - accuracy: 0.9987
# Epoch 105/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0102 - accuracy: 0.9987
# Epoch 106/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0149 - accuracy: 0.9947
# Epoch 107/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0189 - accuracy: 0.9933
# Epoch 108/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0117 - accuracy: 0.9973
# Epoch 109/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0090 - accuracy: 0.9987
# Epoch 110/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0123 - accuracy: 0.9960
# Epoch 111/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0112 - accuracy: 0.9973
# Epoch 112/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0060 - accuracy: 0.9987
# Epoch 113/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 114/1500
# 24/24 [==============================] - 0s 9ms/step - loss: 0.0085 - accuracy: 1.0000
# Epoch 115/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0058 - accuracy: 0.9987
# Epoch 116/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0053 - accuracy: 1.0000
# Epoch 117/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0050 - accuracy: 0.9987
# Epoch 118/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0051 - accuracy: 0.9987
# Epoch 119/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0066 - accuracy: 1.0000
# Epoch 120/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0071 - accuracy: 0.9973
# Epoch 121/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0085 - accuracy: 0.9973
# Epoch 122/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0098 - accuracy: 0.9973
# Epoch 123/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0117 - accuracy: 0.9960
# Epoch 124/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0046 - accuracy: 1.0000
# Epoch 125/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0264 - accuracy: 0.9947
# Epoch 126/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 127/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0062 - accuracy: 0.9987
# Epoch 128/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0120 - accuracy: 0.9960
# Epoch 129/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0063 - accuracy: 0.9987
# Epoch 130/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0075 - accuracy: 0.9973
# Epoch 131/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0087 - accuracy: 0.9987
# Epoch 132/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0106 - accuracy: 0.9973
# Epoch 133/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0055 - accuracy: 0.9987
# Epoch 134/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0082 - accuracy: 0.9973
# Epoch 135/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0058 - accuracy: 0.9987
# Epoch 136/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0071 - accuracy: 0.9973
# Epoch 137/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 138/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0081 - accuracy: 0.9973
# Epoch 139/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0058 - accuracy: 1.0000
# Epoch 140/1500
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 141/1500
# 24/24 [==============================] - 0s 6ms/step - loss: 0.0068 - accuracy: 0.9973
# Epoch 142/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0108 - accuracy: 0.9973
# Epoch 143/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0046 - accuracy: 1.0000
# Epoch 144/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0057 - accuracy: 0.9987
# Epoch 145/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0063 - accuracy: 0.9987
# Epoch 146/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 147/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 148/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0054 - accuracy: 0.9987
# Epoch 149/1500
# 24/24 [==============================] - 0s 5ms/step - loss: 0.0068 - accuracy: 0.9987
# Epoch 150/1500
# 24/24 [==============================] - 0s 11ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 151/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0049 - accuracy: 1.0000
# Epoch 152/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0055 - accuracy: 0.9987
# Epoch 153/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0057 - accuracy: 0.9987
# Epoch 154/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0073 - accuracy: 0.9973
# Epoch 155/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0068 - accuracy: 0.9987
# Epoch 156/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 157/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0055 - accuracy: 1.0000
# Epoch 158/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 159/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0040 - accuracy: 1.0000
# Epoch 160/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 161/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 162/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 163/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 164/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0112 - accuracy: 0.9960
# Epoch 165/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0075 - accuracy: 0.9987
# Epoch 166/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 167/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0054 - accuracy: 0.9973
# Epoch 168/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0052 - accuracy: 0.9987
# Epoch 169/1500
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0046 - accuracy: 0.9973
# Epoch 170/1500
# 14/24 [================>.............] - ETA: 0s - loss: 0.0024 - accuracy: 1.0000Restoring model weights from the end of the best epoch: 140.
# 24/24 [==============================] - 0s 4ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 170: early stopping
# 7/7 [==============================] - 0s 1ms/step - loss: 3.9418 - accuracy: 0.6743
# 7/7 [==============================] - 0s 870us/step
# Majority Vote Accuracy for cat_id for this fold: 0.79 (23/29)
# Before appending - Cat IDs: 243, Predictions: 243, Actuals: 243, Gender: 243
# After appending - Cat IDs: 461, Predictions: 461, Actuals: 461, Gender: 461
# Final Test Results - Loss: 3.941755771636963, Accuracy: 0.6743119359016418, Precision: 0.5593650793650793, Recall: 0.5729762554693125, F1 Score: 0.5652217684573599
# Confusion Matrix:
#  [[116  14  21]
#  [ 10  20   1]
#  [ 24   1  11]]
# outer_fold 3
# Train Set Group Distribution:
# 046A    66
# 002B    36
# 103A    33
# 047A    30
# 057A    28
# 020A    23
# 055A    20
# 000B    20
# 029A    17
# 101A    16
# 097A    16
# 106A    15
# 042A    14
# 097B    14
# 028A    14
# 039A    12
# 051A    12
# 063A    11
# 005A    11
# 016A    11
# 068A    11
# 025A    11
# 036A    11
# 040A    10
# 014B    10
# 015A    10
# 065A     9
# 051B     9
# 033A     9
# 045A     9
# 094A     8
# 095A     8
# 010A     8
# 013B     8
# 053A     7
# 099A     7
# 031A     7
# 109A     6
# 025C     6
# 021A     6
# 108A     6
# 007A     6
# 023A     6
# 012A     5
# 023B     5
# 070A     5
# 034A     5
# 062A     5
# 044A     5
# 075A     5
# 009A     4
# 105A     4
# 026A     4
# 011A     3
# 006A     3
# 113A     3
# 038A     2
# 054A     2
# 093A     2
# 061A     2
# 087A     2
# 025B     2
# 069A     2
# 018A     2
# 024A     1
# 026B     1
# 004A     1
# 076A     1
# 115A     1
# 041A     1
# 019B     1
# 090A     1
# 048A     1
# 073A     1
# 088A     1
# 049A     1
# 092A     1
# 096A     1
# 043A     1
# 026C     1
# 100A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 000A    39
# 074A    25
# 067A    20
# 059A    18
# 019A    17
# ...
#  '051B' '052A' '053A' '054A' '055A' '056A' '057A' '058A' '059A' '060A'
#  '061A' '062A' '063A' '064A' '065A' '066A' '067A' '068A' '070A' '071A'
#  '072A' '073A' '074A' '075A' '088A' '091A' '092A' '093A' '094A' '095A'
#  '096A' '097B' '099A' '100A' '101A' '102A' '104A' '105A' '106A' '109A'
#  '110A' '111A' '113A' '116A' '117A']
# Unique Test Group IDs:
# ['006A' '007A' '012A' '014B' '018A' '021A' '024A' '025A' '026A' '026B'
#  '026C' '028A' '031A' '033A' '038A' '039A' '046A' '049A' '051A' '069A'
#  '076A' '087A' '090A' '097A' '103A' '108A' '115A']
# No common groups found between train and test sets.
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Moved to Training/Validation Set:
# {'046A'}
# Removed from Training/Validation Set:
# {'050A'}
# Moved to Test Set:
# {'050A'}
# Removed from Test Set
# {'046A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '004A' '005A' '008A' '009A'
#  '010A' '011A' '013B' '014A' '015A' '016A' '019A' '019B' '020A' '022A'
#  '023A' '023B' '025B' '025C' '027A' '029A' '032A' '034A' '035A' '036A'
#  '037A' '040A' '041A' '042A' '043A' '044A' '045A' '046A' '047A' '048A'
#  '051B' '052A' '053A' '054A' '055A' '056A' '057A' '058A' '059A' '060A'
#  '061A' '062A' '063A' '064A' '065A' '066A' '067A' '068A' '070A' '071A'
#  '072A' '073A' '074A' '075A' '088A' '091A' '092A' '093A' '094A' '095A'
#  '096A' '097B' '099A' '100A' '101A' '102A' '104A' '105A' '106A' '109A'
#  '110A' '111A' '113A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['006A' '007A' '012A' '014B' '018A' '021A' '024A' '025A' '026A' '026B'
#  '026C' '028A' '031A' '033A' '038A' '039A' '049A' '050A' '051A' '069A'
#  '076A' '087A' '090A' '097A' '103A' '108A' '115A']
# Length of X_train_val:
# 792
# Length of y_train_val:
# 792
# Length of groups_train_val:
# 792
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     485
# senior    150
# kitten     98
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     121
# kitten     78
# senior     36
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     485
# kitten    157
# senior    150
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     121
# senior     36
# kitten     19
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 485, 1: 157, 2: 150})
# Epoch 1/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.4151 - accuracy: 0.4066
# Epoch 2/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.9972 - accuracy: 0.5631
# Epoch 3/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.8139 - accuracy: 0.6427
# Epoch 4/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.7193 - accuracy: 0.6932
# Epoch 5/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.5969 - accuracy: 0.7513
# Epoch 6/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.5017 - accuracy: 0.7992
# Epoch 7/1500
# 25/25 [==============================] - 0s 5ms/step - loss: 0.4215 - accuracy: 0.8359
# Epoch 8/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3619 - accuracy: 0.8662
# Epoch 9/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3428 - accuracy: 0.8864
# Epoch 10/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3040 - accuracy: 0.9104
# Epoch 11/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2856 - accuracy: 0.8939
# Epoch 12/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2590 - accuracy: 0.9230
# Epoch 13/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2342 - accuracy: 0.9192
# Epoch 14/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2103 - accuracy: 0.9293
# Epoch 15/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2015 - accuracy: 0.9343
# Epoch 16/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.1689 - accuracy: 0.9533
# Epoch 17/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.1491 - accuracy: 0.9558
# Epoch 18/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.1428 - accuracy: 0.9634
# Epoch 19/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.1252 - accuracy: 0.9722
# Epoch 20/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.1265 - accuracy: 0.9659
# Epoch 21/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.1048 - accuracy: 0.9722
# Epoch 22/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0972 - accuracy: 0.9785
# Epoch 23/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.1006 - accuracy: 0.9697
# Epoch 24/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.1040 - accuracy: 0.9722
# Epoch 25/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0772 - accuracy: 0.9811
# Epoch 26/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0782 - accuracy: 0.9861
# Epoch 27/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0763 - accuracy: 0.9811
# Epoch 28/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0662 - accuracy: 0.9899
# Epoch 29/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0727 - accuracy: 0.9811
# Epoch 30/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0626 - accuracy: 0.9874
# Epoch 31/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0498 - accuracy: 0.9924
# Epoch 32/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0490 - accuracy: 0.9899
# Epoch 33/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0527 - accuracy: 0.9886
# Epoch 34/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0522 - accuracy: 0.9886
# Epoch 35/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0484 - accuracy: 0.9912
# Epoch 36/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0388 - accuracy: 0.9937
# Epoch 37/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0446 - accuracy: 0.9912
# Epoch 38/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0482 - accuracy: 0.9912
# Epoch 39/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0285 - accuracy: 0.9962
# Epoch 40/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0406 - accuracy: 0.9912
# Epoch 41/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0335 - accuracy: 0.9937
# Epoch 42/1500
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0437 - accuracy: 0.9912
# Epoch 43/1500
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0437 - accuracy: 0.9861
# Epoch 44/1500
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0322 - accuracy: 0.9912
# Epoch 45/1500
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0336 - accuracy: 0.9912
# Epoch 46/1500
# 25/25 [==============================] - 0s 11ms/step - loss: 0.0211 - accuracy: 0.9987
# Epoch 47/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0283 - accuracy: 0.9949
# Epoch 48/1500
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0298 - accuracy: 0.9937
# Epoch 49/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0240 - accuracy: 0.9975
# Epoch 50/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0298 - accuracy: 0.9949
# Epoch 51/1500
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0258 - accuracy: 0.9937
# Epoch 52/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0264 - accuracy: 0.9949
# Epoch 53/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0235 - accuracy: 0.9975
# Epoch 54/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0236 - accuracy: 0.9987
# Epoch 55/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0298 - accuracy: 0.9899
# Epoch 56/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0275 - accuracy: 0.9924
# Epoch 57/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0192 - accuracy: 0.9949
# Epoch 58/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0192 - accuracy: 0.9987
# Epoch 59/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0219 - accuracy: 0.9949
# Epoch 60/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0245 - accuracy: 0.9962
# Epoch 61/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0168 - accuracy: 0.9962
# Epoch 62/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0211 - accuracy: 0.9937
# Epoch 63/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0214 - accuracy: 0.9949
# Epoch 64/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0123 - accuracy: 0.9975
# Epoch 65/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0267 - accuracy: 0.9949
# Epoch 66/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0124 - accuracy: 1.0000
# Epoch 67/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0134 - accuracy: 0.9987
# Epoch 68/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0175 - accuracy: 0.9962
# Epoch 69/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0168 - accuracy: 0.9949
# Epoch 70/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0283 - accuracy: 0.9899
# Epoch 71/1500
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0088 - accuracy: 1.0000
# Epoch 72/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0125 - accuracy: 0.9975
# Epoch 73/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0097 - accuracy: 0.9987
# Epoch 74/1500
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0120 - accuracy: 1.0000
# Epoch 75/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0152 - accuracy: 0.9975
# Epoch 76/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0256 - accuracy: 0.9912
# Epoch 77/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0150 - accuracy: 0.9962
# Epoch 78/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0135 - accuracy: 0.9962
# Epoch 79/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0113 - accuracy: 0.9987
# Epoch 80/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0127 - accuracy: 0.9975
# Epoch 81/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0110 - accuracy: 0.9987
# Epoch 82/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0144 - accuracy: 0.9962
# Epoch 83/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0120 - accuracy: 0.9975
# Epoch 84/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0060 - accuracy: 1.0000
# Epoch 85/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0212 - accuracy: 0.9937
# Epoch 86/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0109 - accuracy: 0.9975
# Epoch 87/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0131 - accuracy: 0.9975
# Epoch 88/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0134 - accuracy: 0.9949
# Epoch 89/1500
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0137 - accuracy: 0.9975
# Epoch 90/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0078 - accuracy: 0.9987
# Epoch 91/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0095 - accuracy: 0.9975
# Epoch 92/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 93/1500
# 25/25 [==============================] - 0s 10ms/step - loss: 0.0091 - accuracy: 1.0000
# Epoch 94/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0087 - accuracy: 0.9987
# Epoch 95/1500
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0090 - accuracy: 0.9962
# Epoch 96/1500
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0144 - accuracy: 0.9962
# Epoch 97/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0077 - accuracy: 0.9987
# Epoch 98/1500
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0089 - accuracy: 0.9987
# Epoch 99/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0091 - accuracy: 0.9975
# Epoch 100/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0062 - accuracy: 1.0000
# Epoch 101/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 102/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0117 - accuracy: 0.9949
# Epoch 103/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0200 - accuracy: 0.9949
# Epoch 104/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0040 - accuracy: 1.0000
# Epoch 105/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0075 - accuracy: 0.9975
# Epoch 106/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0068 - accuracy: 1.0000
# Epoch 107/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0045 - accuracy: 0.9987
# Epoch 108/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0078 - accuracy: 0.9987
# Epoch 109/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0096 - accuracy: 0.9987
# Epoch 110/1500
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0069 - accuracy: 0.9975
# Epoch 111/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0043 - accuracy: 1.0000
# Epoch 112/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0105 - accuracy: 0.9975
# Epoch 113/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0068 - accuracy: 1.0000
# Epoch 114/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0041 - accuracy: 1.0000
# Epoch 115/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0075 - accuracy: 0.9975
# Epoch 116/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0061 - accuracy: 0.9975
# Epoch 117/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0104 - accuracy: 0.9987
# Epoch 118/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0069 - accuracy: 0.9962
# Epoch 119/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0140 - accuracy: 0.9924
# Epoch 120/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0057 - accuracy: 1.0000
# Epoch 121/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 122/1500
# 14/25 [===============>..............] - ETA: 0s - loss: 0.0062 - accuracy: 1.0000Restoring model weights from the end of the best epoch: 92.
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0048 - accuracy: 1.0000
# Epoch 122: early stopping
# 6/6 [==============================] - 0s 1ms/step - loss: 5.2952 - accuracy: 0.6648
# 6/6 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.78 (21/27)
# Before appending - Cat IDs: 701, Predictions: 701, Actuals: 701, Gender: 701
# After appending - Cat IDs: 877, Predictions: 877, Actuals: 877, Gender: 877
# Final Test Results - Loss: 5.295238971710205, Accuracy: 0.6647727489471436, Precision: 0.5490554899645809, Recall: 0.5529819728384322, F1 Score: 0.550889571376127
# Confusion Matrix:
#  [[93 10 18]
#  [ 8  9  2]
#  [20  1 15]]
#
# Final Average F1-Score across all UNSEEN TEST sets: 0.5309597106974242
#
# Final Average Loss across all UNSEEN TEST sets: 3.6612690091133118
#
# Final Average Accuracy across all UNSEEN TEST sets: 0.6371760070323944
#
# Final Average Precision across all UNSEEN TEST sets: 0.5429430321166823
#
# Final Average Recall across all UNSEEN TEST sets: 0.5521093029042285

# %%
seed_3_folds_values = (unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1)

# Plotting all fold metrics
seed_3_folds_plot = plot_all_metrics(unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1, "Folds", "Fold Number")

# %% [markdown]
# ## Majority Voting on Total Entries per cat_id

# %%
# Debugging print statements
print(f'Checking - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
# Out:
# Checking - Cat IDs: 877, Predictions: 877, Actuals: 877, Gender: 877

# %%
# Create results df
full_results = pd.DataFrame({
    'cat_id': all_cat_ids,
    'predicted_age_group': all_predicted_age_groups,
    'actual_age_group': all_actual_age_groups,
    'all_gender': all_gender
})

# create a correct majority prediction column
full_results['correct'] = full_results['predicted_age_group'] == full_results['actual_age_group']

# %%
# Group by cat_id and aggregate predicted age groups
majority_votes = full_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first()

# Calculate the accuracy of majority voting
correct_predictions = (majority_votes == actual_groups).sum()
total_cats = len(actual_groups)
majority_vote_accuracy = correct_predictions / total_cats

logger(f"Overall Majority Vote Accuracy for cat_id: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

# store for final evaluation 
all_majority_vote_accuracies.append(majority_vote_accuracy)
# Out:
# Overall Majority Vote Accuracy for cat_id: 0.77 (85/110)

# %%
# Detailed df with predictions, actual labels, and comparison including majority vote
detailed_results = full_results.groupby('cat_id').apply(
    lambda x: pd.Series({
        'Predictions': list(x['predicted_age_group']),
        'Majority Vote': x['predicted_age_group'].mode()[0],
        'Actual Age Group': x['actual_age_group'].iloc[0],
        'Correct Majority Vote': x['predicted_age_group'].mode()[0] == x['actual_age_group'].iloc[0]
    })
).reset_index()

# Convert to DataFrame for better formatting and display
detailed_results = pd.DataFrame(detailed_results)

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 10)
pd.set_option('display.width', 1000)

sorted_detailed_results = detailed_results.sort_values(by='Correct Majority Vote', ascending=False)

# Display the sorted DataFrame
sorted_detailed_results
# Out:
#     cat_id                                        Predictions Majority Vote Actual Age Group  Correct Majority Vote
# 0     000B  [adult, adult, kitten, adult, adult, adult, ad...         adult            adult                   True
# 78    072A  [adult, adult, adult, kitten, adult, senior, a...         adult            adult                   True
# 76    070A              [adult, senior, senior, adult, adult]         adult            adult                   True
# 75    069A                                     [adult, adult]         adult            adult                   True
# 74    068A  [adult, adult, adult, adult, senior, adult, ad...         adult            adult                   True
# 73    067A  [senior, adult, adult, kitten, kitten, adult, ...         adult            adult                   True
# 72    066A                                    [adult, kitten]         adult            adult                   True
# 71    065A  [adult, adult, adult, kitten, adult, adult, ad...         adult            adult                   True
# 70    064A                            [senior, adult, kitten]         adult            adult                   True
# 68    062A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 65    059A  [senior, adult, senior, senior, adult, senior,...        senior           senior                   True
# 59    053A  [adult, adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 58    052A                       [adult, adult, adult, adult]         adult            adult                   True
# 1     001A  [adult, adult, adult, senior, senior, adult, a...         adult            adult                   True
# 54    049A                                           [kitten]        kitten           kitten                   True
# 53    048A                                           [kitten]        kitten           kitten                   True
# 51    045A  [kitten, adult, kitten, kitten, kitten, kitten...        kitten           kitten                   True
# 50    044A            [kitten, kitten, adult, kitten, kitten]        kitten           kitten                   True
# 49    043A                                           [kitten]        kitten           kitten                   True
# 48    042A  [kitten, kitten, kitten, adult, adult, kitten,...        kitten           kitten                   True
# 47    041A                                           [kitten]        kitten           kitten                   True
# 77    071A  [adult, senior, adult, kitten, adult, senior, ...         adult            adult                   True
# 79    073A                                            [adult]         adult            adult                   True
# 45    039A  [senior, senior, senior, adult, senior, adult,...         adult            adult                   True
# 80    074A  [kitten, kitten, adult, adult, kitten, adult, ...         adult            adult                   True
# 107   115A                                           [kitten]        kitten           kitten                   True
# 106   113A                           [senior, senior, kitten]        senior           senior                   True
# 105   111A  [kitten, kitten, kitten, kitten, kitten, kitte...        kitten           kitten                   True
# 104   110A                                           [kitten]        kitten           kitten                   True
# 102   108A     [senior, adult, senior, senior, senior, adult]        senior           senior                   True
# 100   105A                      [adult, adult, adult, kitten]         adult            adult                   True
# 98    103A  [adult, adult, kitten, adult, adult, senior, a...         adult            adult                   True
# 97    102A                                     [adult, adult]         adult            adult                   True
# 96    101A  [adult, senior, adult, adult, adult, senior, s...         adult            adult                   True
# 94    099A  [adult, adult, adult, kitten, adult, adult, ad...         adult            adult                   True
# 93    097B  [adult, adult, adult, adult, kitten, adult, ki...         adult            adult                   True
# 91    096A                                            [adult]         adult            adult                   True
# 90    095A  [senior, adult, senior, senior, adult, adult, ...         adult            adult                   True
# 89    094A  [senior, senior, senior, senior, adult, senior...        senior           senior                   True
# 87    092A                                            [adult]         adult            adult                   True
# 86    091A                                            [adult]         adult            adult                   True
# 84    088A                                            [adult]         adult            adult                   True
# 83    087A                                     [adult, adult]         adult            adult                   True
# 81    075A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 46    040A  [kitten, adult, kitten, kitten, kitten, kitten...        kitten           kitten                   True
# 55    050A  [kitten, kitten, adult, adult, adult, kitten, ...        kitten           kitten                   True
# 44    038A                                    [adult, kitten]         adult            adult                   True
# 29    025B                                     [adult, adult]         adult            adult                   True
# 27    024A                                           [senior]        senior           senior                   True
# 26    023B              [adult, adult, kitten, senior, adult]         adult            adult                   True
# 25    023A       [adult, kitten, kitten, adult, adult, adult]         adult            adult                   True
# 24    022A  [adult, kitten, kitten, adult, kitten, adult, ...         adult            adult                   True
# 43    037A       [kitten, adult, senior, adult, adult, adult]         adult            adult                   True
# 22    020A  [adult, adult, adult, adult, adult, adult, kit...         adult            adult                   True
# 21    019B                                            [adult]         adult            adult                   True
# 20    019A  [adult, adult, kitten, adult, adult, adult, ki...         adult            adult                   True
# 19    018A                                     [adult, adult]         adult            adult                   True
# 17    015A  [adult, adult, adult, adult, adult, adult, sen...         adult            adult                   True
# 14    013B  [adult, adult, adult, adult, adult, kitten, ad...         adult            adult                   True
# 13    012A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 12    011A                            [senior, adult, senior]        senior           senior                   True
# 11    010A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 10    009A                     [senior, adult, senior, adult]         adult            adult                   True
# 9     008A         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 8     007A        [adult, senior, adult, adult, adult, adult]         adult            adult                   True
# 7     006A                             [senior, adult, adult]         adult            adult                   True
# 6     005A  [adult, adult, adult, senior, adult, adult, se...         adult            adult                   True
# 5     004A                                            [adult]         adult            adult                   True
# 4     003A                     [kitten, kitten, adult, adult]         adult            adult                   True
# 3     002B  [adult, adult, adult, kitten, senior, adult, a...         adult            adult                   True
# 2     002A  [adult, kitten, kitten, adult, adult, adult, s...         adult            adult                   True
# 28    025A  [adult, adult, adult, senior, adult, senior, a...         adult            adult                   True
# 23    021A        [kitten, adult, adult, adult, adult, adult]         adult            adult                   True
# 30    025C        [adult, adult, adult, kitten, adult, adult]         adult            adult                   True
# 31    026A                       [adult, adult, adult, adult]         adult            adult                   True
# 42    036A  [senior, senior, adult, adult, adult, adult, a...         adult            adult                   True
# 41    035A                      [adult, adult, senior, adult]         adult            adult                   True
# 40    034A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 39    033A  [kitten, adult, adult, adult, adult, senior, k...         adult            adult                   True
# 38    032A                                     [adult, adult]         adult            adult                   True
# 37    031A  [senior, adult, adult, adult, kitten, adult, s...         adult            adult                   True
# 36    029A  [senior, adult, senior, adult, senior, adult, ...         adult            adult                   True
# 35    028A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 34    027A  [adult, kitten, senior, adult, adult, adult, a...         adult            adult                   True
# 32    026B                                            [adult]         adult            adult                   True
# 18    016A  [adult, adult, adult, senior, adult, adult, ad...         adult           senior                  False
# 85    090A                                            [adult]         adult           senior                  False
# 108   116A  [senior, senior, senior, senior, adult, senior...         adult           senior                  False
# 69    063A  [kitten, kitten, kitten, kitten, kitten, adult...        kitten            adult                  False
# 67    061A                                     [adult, adult]         adult           senior                  False
# 66    060A                           [kitten, kitten, kitten]        kitten            adult                  False
# 103   109A         [adult, adult, adult, adult, adult, adult]         adult           kitten                  False
# 52    047A  [adult, senior, adult, adult, adult, kitten, a...         adult           kitten                  False
# 101   106A  [senior, adult, senior, adult, adult, adult, s...         adult           senior                  False
# 33    026C                                           [kitten]        kitten            adult                  False
# 99    104A                      [senior, adult, adult, adult]         adult           senior                  False
# 64    058A                             [senior, adult, adult]         adult           senior                  False
# 63    057A  [adult, adult, adult, adult, adult, adult, adu...         adult           senior                  False
# 56    051A  [adult, adult, adult, adult, senior, adult, ki...         adult           senior                  False
# 95    100A                                           [kitten]        kitten            adult                  False
# 57    051B  [adult, adult, adult, adult, adult, adult, adu...         adult           senior                  False
# 82    076A                                           [kitten]        kitten            adult                  False
# 92    097A  [adult, senior, senior, adult, senior, adult, ...         adult           senior                  False
# 62    056A                             [adult, senior, adult]         adult           senior                  False
# 60    054A                                     [adult, adult]         adult           senior                  False
# 15    014A                            [kitten, adult, kitten]        kitten            adult                  False
# 88    093A                                     [adult, adult]         adult           senior                  False
# 16    014B  [adult, adult, adult, kitten, senior, kitten, ...         adult           kitten                  False
# 61    055A  [adult, adult, adult, adult, adult, adult, adu...         adult           senior                  False
# 109   117A  [senior, adult, adult, senior, adult, adult, a...         adult           senior                  False

# %%
# Create df for majority votes
majority_df = majority_votes.reset_index()
majority_df.columns = ['cat_id', 'Majority_Vote']

# Get actual groups for each cat_id
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first().reset_index()

# Merge majority votes with actual groups
majority_with_actual = pd.merge(majority_df, actual_groups, on='cat_id')

# Add a column to check if the majority vote was correct
majority_with_actual['Majority_Correct'] = majority_with_actual['Majority_Vote'] == majority_with_actual['actual_age_group']

# Count correct majority votes per class
correct_majority_votes_per_class = majority_with_actual.groupby('actual_age_group')['Majority_Correct'].sum()

print("Correct Majority Votes per Class:")
print(correct_majority_votes_per_class)
# Out:
# Correct Majority Votes per Class:
# actual_age_group
# adult     67
# kitten    12
# senior     6
# Name: Majority_Correct, dtype: int64

# %%
# Calculate the total count and the number of correct predictions for each class
class_stats = majority_with_actual.groupby('actual_age_group').agg(
    total_count=('Majority_Correct', 'size'),  # Total number of cases per class
    correct_count=('Majority_Correct', 'sum')  # Sum of correct predictions per class
).reset_index()

# Calculate accuracy for each class
class_stats['accuracy'] = class_stats['correct_count'] / class_stats['total_count'] * 100

# store for final evaluation 
all_majority_vote_details.append(class_stats)

# Log detailed stats
print("Detailed Class Statistics for Majority Votes:")
print(class_stats)
# Out:
# Detailed Class Statistics for Majority Votes:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult           73             67  91.780822
# 1           kitten           15             12  80.000000
# 2           senior           22              6  27.272727

# %%
# Plot for Detailed Class Statistics for Majority Votes
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Accuracy of Majority Votes by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Detailed Class Statistics

# %%
# Calculate the total count and the number of correct predictions for each class
class_stats = full_results.groupby('actual_age_group').agg(
    total_count=('correct', 'size'),
    correct_count=('correct', 'sum')
).reset_index()

# Calculate accuracy for each class
class_stats['accuracy'] = class_stats['correct_count'] / class_stats['total_count'] * 100

# store for final evaluation 
all_class_stats.append(class_stats)

# Log the detailed stats
print("Detailed Class Statistics:")
print(class_stats)
# Out:
# Detailed Class Statistics:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult          574            436  75.958188
# 1           kitten          117             62  52.991453
# 2           senior          186             58  31.182796

# %%
# Plot for Detailed Class Statistics (Overall)
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Overall Accuracy by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Gender Exploration

# %%
# Group by gender and calculate the total count, correct predictions, and accuracy
gender_stats = full_results.groupby('all_gender').agg(
    count=('cat_id', 'size'),  # Total number of cases per gender
    correct=('correct', 'sum')  # Sum of correct predictions per gender
).reset_index()

# Calculate accuracy for each gender
gender_stats['accuracy'] = (gender_stats['correct'] / gender_stats['count'] * 100).round(2)

# Display the DataFrame
print("Accuracy by Gender:")
print(gender_stats)

# store for final evaluation 
all_gender_stats.append(gender_stats)
# Out:
# Accuracy by Gender:
#   all_gender  count  correct  accuracy
# 0          F    225      136     60.44
# 1          M    356      260     73.03
# 2          X    296      160     54.05

# %%
# Plot for Accuracy by Gender
styled_barplot(gender_stats, 'all_gender', 'accuracy', 
               'Accuracy by Gender', 
               'Gender', 'Accuracy (%)')

# %% [markdown]
# ### Log current total CV Stats

# %%
print("Total Majority Vote Accuracy so far:", all_majority_vote_accuracies)
print("Total Class Statistics so far:\n", all_class_stats)
print("Total Gender Accuracy so far:\n", all_gender_stats)
# Out:
# Total Majority Vote Accuracy so far: [0.7454545454545455, 0.7363636363636363, 0.7727272727272727]
# Total Class Statistics so far:
#  [  actual_age_group  total_count  correct_count   accuracy
# 0            adult          573            444  77.486911
# 1           kitten          111             64  57.657658
# 2           senior          186             59  31.720430,   actual_age_group  total_count  correct_count   accuracy
# 0            adult          568            404  71.126761
# 1           kitten          120             56  46.666667
# 2           senior          186             60  32.258065,   actual_age_group  total_count  correct_count   accuracy
# 0            adult          574            436  75.958188
# 1           kitten          117             62  52.991453
# 2           senior          186             58  31.182796]
# Total Gender Accuracy so far:
#  [  all_gender  count  correct  accuracy
# 0          F    218      128     58.72
# 1          M    362      263     72.65
# 2          X    290      176     60.69,   all_gender  count  correct  accuracy
# 0          F    218      119     54.59
# 1          M    357      246     68.91
# 2          X    299      155     51.84,   all_gender  count  correct  accuracy
# 0          F    225      136     60.44
# 1          M    356      260     73.03
# 2          X    296      160     54.05]

# %% [markdown]
# # RANDOM SEED 4

# %%
# Set a fixed random seed for reproducibility
random.seed(int(random_seeds[3])) 
np.random.seed(int(random_seeds[3]))
tf.random.set_seed(int(random_seeds[3]))

# Load datasets
dataframe = pd.read_csv('/Users/astrid/PycharmProjects/data-aug-and-more/yamnet-tfhub-extraction/yamnet_embeddings_looped_april_23.csv')

def assign_age_group(age, age_groups):
    for group_name, age_range in age_groups.items():
        if age_range[0] <= age < age_range[1]:
            return group_name
    return 'Unknown'  # For any age that doesn't fit the defined groups

# Define age groups
age_groups = {
    'kitten': (0, 0.5),
    'adult': (0.5, 12),
    'senior': (12, 20)
}

# Create a new column for the age group
dataframe['age_group'] = dataframe['target'].apply(assign_age_group, age_groups=age_groups)

print(dataframe['age_group'].value_counts())
# Out:
# adult     606
# senior    186
# kitten    176
# Name: age_group, dtype: int64

# %%
# Separate features and labels
X = dataframe.iloc[:, :-4].values  # all columns except the last four

# Encode the 'age_group' column as integers using LabelEncoder
label_encoder = LabelEncoder()
encoded_y = label_encoder.fit_transform(dataframe['age_group'].values)

# Use the encoded labels for splitting and one-hot encoding
y = encoded_y  

# Convert 'cat_id' column to numpy array to be used as groups array for GroupKFold
groups = dataframe['cat_id'].values

# %%
tf.keras.backend.clear_session()

# %% [markdown]
# ## Run Setup

# %%
all_cat_ids = []
all_predicted_age_groups = []
all_actual_age_groups = []
all_gender = []

# Define the StratifiedGroupKFold splitter for 4 fold CV with random shuffling
outer_cv = StratifiedGroupKFold(n_splits=4, shuffle=True, random_state=int(random_seeds[3]))

# unseen test set metrics
unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1 = [], [], [], [], []

outer_fold = 0

# Use the splitter to generate indices for training and testing sets
# Note: GroupShuffleSplit.split returns indices, so we use it to index the arrays
for train_val_idx, test_idx in outer_cv.split(X, y, groups):
    outer_fold += 1
    logger(f"outer_fold {outer_fold}", file=log_file_path)

    # Convert indices back to DataFrame for easy manipulation
    df_train_val = dataframe.iloc[train_val_idx]
    df_test = dataframe.iloc[test_idx]

    ##############################
    # ASSESSING SPLITS BY CAT_ID #
    ##############################
    
    # Get the distribution of groups
    training_validation_group_distribution = df_train_val['cat_id'].value_counts()  
    testing_group_distribution = df_test['cat_id'].value_counts()  
    
    # Log or print the distribution
    logger(f"Train Set Group Distribution:\n{training_validation_group_distribution}", file=log_file_path)
    logger(f"Testing Set Group Distribution:\n{testing_group_distribution}", file=log_file_path)

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val['gender'].value_counts()
    testing_gender_distribution = df_test['gender'].value_counts()
    
    # Log the distribution
    logger(f"Training Set Gender Distribution BEFORE SWAP:\n{training_gender_distribution}", file=log_file_path)
    logger(f"Testing Set Gender Distribution BEFORE SWAP:\n{testing_gender_distribution}", file=log_file_path)

    # Group by 'age_group' and then list unique 'cat_id' within each age group
    unique_cat_ids_per_age_group_train_val = df_train_val.groupby('age_group')['cat_id'].unique()
    unique_cat_ids_per_age_group_test = df_test.groupby('age_group')['cat_id'].unique()
    
    # Log results
    logger(f"Unique Cat IDs per Age Group in Training/Validation Set:\n{unique_cat_ids_per_age_group_train_val}", file=log_file_path)
    logger(f"Unique Cat IDs per Age Group in Testing Set:\n{unique_cat_ids_per_age_group_test}", file=log_file_path)

    # Calculate the count of unique identifiers per age group for training and testing set
    counts_train_val = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_train_val.items()}
    counts_test = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_test.items()}

    # Log the counts of unique identifiers per age group
    logger(f"Count of Unique Cat IDs per Age Group in Training/Validation Set:\n{counts_train_val}", file=log_file_path)
    logger(f"Count of Unique Cat IDs per Age Group in Testing Set:\n{counts_test}", file=log_file_path)

    #######################################################
    # CONTINUE WITH ENSURING VALID AND APPROPRIATE SPLITS #
    #######################################################
    
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    groups_train_val, groups_test = groups[train_val_idx], groups[test_idx]

    # logging identifier splits 
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)

    # check group splits
    check_initial_group_split(groups_train_val, groups_test)

    # Specify the cat_ids that must be in the training/validation set
    specific_cat_ids = ['000A', '046A']
    
    # Perform the swapping operation
    train_val_idx, test_idx = swap_cat_id_instances(dataframe, train_val_idx, test_idx, specific_cat_ids)
    
    # Re-assign the sets based on the updated indices
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    new_groups_train_val, new_groups_test = groups[train_val_idx], groups[test_idx]

    # Find differences for training and test sets
    moved_to_train_val, removed_from_train_val = find_group_differences(groups_train_val, new_groups_train_val)
    moved_to_test, removed_from_test = find_group_differences(groups_test, new_groups_test)
    
    # Display the results
    logger(f"Moved to Training/Validation Set:\n{moved_to_train_val}", file=log_file_path)
    logger(f"Removed from Training/Validation Set:\n{removed_from_train_val}", file=log_file_path)
    logger(f"Moved to Test Set:\n{moved_to_test}", file=log_file_path)
    logger(f"Removed from Test Set\n{removed_from_test}", file=log_file_path)

    # Update X_train_val, X_test, y_train_val, y_test, groups_train_val, groups_test based on updated indices
    X_train_val = X[train_val_idx]
    y_train_val = y[train_val_idx]
    groups_train_val = groups[train_val_idx]
    
    X_test = X[test_idx]
    y_test = y[test_idx]
    groups_test = groups[test_idx]

    # logging identifier splits again after potential swaps
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"AFTER SWAP - Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"AFTER SWAP - Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)
    
    # Verify the lengths are consistent
    logger(f"Length of X_train_val:\n{len(X_train_val)}", file=log_file_path)
    logger(f"Length of y_train_val:\n{len(y_train_val)}", file=log_file_path)
    logger(f"Length of groups_train_val:\n{len(groups_train_val)}", file=log_file_path)

    # Check group splits once more
    check_initial_group_split(groups_train_val, groups_test)

    # Convert the modified indices back to a DataFrame representing the updated df_train_val
    df_train_val_updated = dataframe.iloc[train_val_idx].copy()
    df_test_updated = dataframe.iloc[test_idx].copy()

    ############################
    # LOGGING AGE GROUP SPLITS #
    ############################

    # Get the distribution of age groups of age groups before the update
    training_validation_age_group_distribution = df_train_val['age_group'].value_counts()
    testing_age_group_distribution = df_test['age_group'].value_counts()
    
    # Logthe distribution
    logger(f"Train Age Group Distribution BEFORE SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution BEFORE SWAP:\n{testing_age_group_distribution}", file=log_file_path)

    # Get the distribution of age groups after the update
    training_validation_age_group_distribution = df_train_val_updated['age_group'].value_counts()
    testing_age_group_distribution = df_test_updated['age_group'].value_counts()
    
    # Log the distribution
    logger(f"Train Age Group Distribution AFTER SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution AFTER SWAP:\n{testing_age_group_distribution}", file=log_file_path)
    
    ########################################################
    # TRACKING FINAL CAT_IDs & GENDER AFTER REDISTRIBUTION #
    ########################################################

    # Get the distribution of groups
    training_validation_group_distribution = df_train_val_updated['cat_id'].value_counts()  
    testing_group_distribution = df_test_updated['cat_id'].value_counts()  

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val_updated['gender'].value_counts()
    testing_gender_distribution = df_test_updated['gender'].value_counts()
    
    logger(f"\n Starting training on unseen test set\n", file=log_file_path)

    ###################
    # PREPARING MODEL #
    ###################

    # Calculate the distribution of age groups in y_train_val
    age_group_distribution = Counter(y_train_val)
    print("Age group distribution:", age_group_distribution)

    # EarlyStopping callback: monitor 'loss' instead of 'val_loss' for the test set
    early_stopping = EarlyStopping(
        monitor='loss',  
        min_delta=0.001, 
        patience=30,  
        verbose=1,  
        restore_best_weights=True  
    )

    # One final shuffle to ensure randomness
    outer_shuffle_idx = np.random.permutation(len(X_train_val))
    X_train_val = X_train_val[outer_shuffle_idx]
    y_train_val = y_train_val[outer_shuffle_idx]
    
    # Scale the features
    scaler_full = StandardScaler().fit(X_train_val)
    X_train_full_scaled = scaler_full.transform(X_train_val)
    X_test_scaled = scaler_full.transform(X_test)
    
    # Encode the labels
    y_train_full_encoded = to_categorical(y_train_val)
    y_test_encoded = to_categorical(y_test)

    #######################
    # BUILD & TRAIN MODEL #
    #######################

    optimizers = {
        'Adam': Adam(learning_rate=0.00013808925801643654)
    }
    
    # Model definition with dynamic number of layers
    model_full = Sequential()
    model_full.add(Dense(512, activation='relu', input_shape=(X_train_full_scaled.shape[1],)))
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.19804187627143222))  
    model_full.add(Dense(512, activation='relu',)) 
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.24412907103758918))  
    model_full.add(Dense(3, activation='softmax'))  
    
    # Use the optimizer from the parameters
    optimizer = optimizers['Adam']  # optimizer_key from parameters
    
    # Compile the model
    model_full.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    
    # Train the model on the full training set
    history_full = model_full.fit(X_train_full_scaled, y_train_full_encoded, epochs=1500, batch_size=32,
                                  verbose=1, callbacks=[early_stopping])
    
    # Evaluate the model on the held-out test set
    test_loss, test_accuracy = model_full.evaluate(X_test_scaled, y_test_encoded)

    y_test_pred_prob = model_full.predict(X_test_scaled)
    y_test_pred = np.argmax(y_test_pred_prob, axis=1)  
    y_test_true = np.argmax(y_test_encoded, axis=1)    

    ################################
    # LOG MAJORITY VOTE PER CAT_ID #
    ################################

    # Convert numeric predictions back to age group labels
    predicted_age_groups = label_encoder.inverse_transform(y_test_pred)
    actual_labels = label_encoder.inverse_transform(y_test_true)
    
    # Map predictions and actual labels back to cat_ids
    test_results = pd.DataFrame({
        'cat_id': df_test_updated['cat_id'],
        'predicted_age_group': predicted_age_groups,
        'actual_age_group': actual_labels
    })
    
    # Group by cat_id and aggregate predicted age groups
    majority_votes = test_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
    actual_groups = test_results.groupby('cat_id')['actual_age_group'].first()
    
    # Calculate the accuracy of majority voting
    correct_predictions = (majority_votes == actual_groups).sum()
    total_cats = len(actual_groups)
    majority_vote_accuracy = correct_predictions / total_cats
    
    # Log the accuracy of the majority voting
    logger(f"Majority Vote Accuracy for cat_id for this fold: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

    ####################################################
    # COLLECT PREDICTIONS FOR GENDER & CAT_ID ANALYSIS #
    ####################################################

    # Debugging print statements
    print(f'Before appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Extend lists with current fold results
    all_cat_ids.extend(df_test_updated['cat_id'].tolist())
    all_predicted_age_groups.extend(predicted_age_groups)
    all_actual_age_groups.extend(actual_labels)
    all_gender.extend(df_test_updated['gender'].tolist())

    # Debugging print statements
    print(f'After appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Calculate additional metrics
    test_precision = precision_score(y_test_true, y_test_pred, average='macro')  # Use 'macro' for imbalanced datasets
    test_recall = recall_score(y_test_true, y_test_pred, average='macro')
    test_f1 = f1_score(y_test_true, y_test_pred, average='macro')

    # prepare averages of outer metrics
    unseen_f1.append(test_f1)
    unseen_losses.append(test_loss)
    unseen_accuracies.append(test_accuracy)
    unseen_precisions.append(test_precision)
    unseen_recalls.append(test_recall)

    # Print final test results
    logger(f"Final Test Results - Loss: {test_loss}, Accuracy: {test_accuracy}, Precision: {test_precision}, Recall: {test_recall}, F1 Score: {test_f1}", file=log_file_path)

    # Generate the confusion matrix
    cm = confusion_matrix(y_test, y_test_pred)
    logger(f"Confusion Matrix:\n {cm}", file=log_file_path)

# Calculate the overall average metrics
unseen_set_avg_f1 = np.mean(unseen_f1)
unseen_set_avg_loss = np.mean(unseen_losses)
unseen_set_avg_acc = np.mean(unseen_accuracies)
unseen_set_avg_precision = np.mean(unseen_precisions)
unseen_set_avg_recall = np.mean(unseen_recalls)

logger(f"\nFinal Average F1-Score across all UNSEEN TEST sets: {unseen_set_avg_f1}", file=log_file_path)
logger(f"\nFinal Average Loss across all UNSEEN TEST sets: {unseen_set_avg_loss}", file=log_file_path)
logger(f"\nFinal Average Accuracy across all UNSEEN TEST sets: {unseen_set_avg_acc}", file=log_file_path)
logger(f"\nFinal Average Precision across all UNSEEN TEST sets: {unseen_set_avg_precision}", file=log_file_path)
logger(f"\nFinal Average Recall across all UNSEEN TEST sets: {unseen_set_avg_recall}\n", file=log_file_path)

# Append averages to total lists
all_f1.append(unseen_set_avg_f1)
all_losses.append(unseen_set_avg_loss)
all_accuracies.append(unseen_set_avg_acc)
all_precisions.append(unseen_set_avg_precision)
all_recalls.append(unseen_set_avg_recall)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# outer_fold 1
# Train Set Group Distribution:
# 046A    66
# 000A    39
# 002B    36
# 103A    33
# 047A    30
# 057A    28
# 074A    25
# 020A    23
# 067A    20
# 059A    18
# 019A    17
# 029A    17
# 101A    16
# 097A    16
# 106A    15
# 001A    15
# 042A    14
# 097B    14
# 111A    13
# 002A    13
# 116A    12
# 039A    12
# 051A    12
# 005A    11
# 016A    11
# 025A    11
# 068A    11
# 063A    11
# 014B    10
# 040A    10
# 015A    10
# 065A     9
# 022A     9
# 045A     9
# 051B     9
# 072A     9
# 013B     8
# 095A     8
# 027A     7
# 050A     7
# 053A     7
# 023A     6
# 008A     6
# 037A     6
# 025C     6
# 109A     6
# 007A     6
# 021A     6
# 034A     5
# 070A     5
# 012A     5
# 062A     5
# 023B     5
# 075A     5
# 105A     4
# 052A     4
# 035A     4
# 104A     4
# 026A     4
# 003A     4
# 014A     3
# 060A     3
# 056A     3
# 064A     3
# 058A     3
# 006A     3
# 038A     2
# 032A     2
# 054A     2
# 087A     2
# 093A     2
# 102A     2
# 018A     2
# 069A     2
# 025B     2
# 110A     1
# 004A     1
# 115A     1
# 041A     1
# 092A     1
# 019B     1
# 049A     1
# 090A     1
# 026C     1
# 073A     1
# 091A     1
# 100A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 000B    20
# 055A    20
# 028A    14
# 036A    11
# 071A    10
# 033A     9
# 094A     8
# 010A     8
# 031A     7
# 117A     7
# 099A     7
# 108A     6
# 044A     5
# 009A     4
# 113A     3
# 011A     3
# 061A     2
# 066A     2
# 076A     1
# 048A     1
# 088A     1
# 096A     1
# 043A     1
# 024A     1
# 026B     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    326
# M    323
# F    166
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# F    91
# M    33
# X    29
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [002A, 070A, 020A, 000A, 015A, 026A, 065A, 053...
# kitten    [046A, 042A, 014B, 110A, 109A, 040A, 047A, 049...
# senior    [106A, 057A, 090A, 051B, 116A, 051A, 097A, 059...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [028A, 033A, 000B, 071A, 009A, 010A, 031A, 036...
# kitten                                   [048A, 044A, 043A]
# senior     [117A, 113A, 024A, 094A, 055A, 108A, 061A, 011A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 60, 'kitten': 13, 'senior': 14}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 14, 'kitten': 3, 'senior': 8}
# Unique Training/Validation Group IDs:
# ['000A' '001A' '002A' '002B' '003A' '004A' '005A' '006A' '007A' '008A'
#  '012A' '013B' '014A' '014B' '015A' '016A' '018A' '019A' '019B' '020A'
#  '021A' '022A' '023A' '023B' '025A' '025B' '025C' '026A' '026C' '027A'
#  '029A' '032A' '034A' '035A' '037A' '038A' '039A' '040A' '041A' '042A'
#  '045A' '046A' '047A' '049A' '050A' '051A' '051B' '052A' '053A' '054A'
#  '056A' '057A' '058A' '059A' '060A' '062A' '063A' '064A' '065A' '067A'
#  '068A' '069A' '070A' '072A' '073A' '074A' '075A' '087A' '090A' '091A'
#  '092A' '093A' '095A' '097A' '097B' '100A' '101A' '102A' '103A' '104A'
#  '105A' '106A' '109A' '110A' '111A' '115A' '116A']
# Unique Test Group IDs:
# ['000B' '009A' '010A' '011A' '024A' '026B' '028A' '031A' '033A' '036A'
#  '043A' '044A' '048A' '055A' '061A' '066A' '071A' '076A' '088A' '094A'
#  '096A' '099A' '108A' '113A' '117A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '001A' '002A' '002B' '003A' '004A' '005A' '006A' '007A' '008A'
#  '012A' '013B' '014A' '014B' '015A' '016A' '018A' '019A' '019B' '020A'
#  '021A' '022A' '023A' '023B' '025A' '025B' '025C' '026A' '026C' '027A'
#  '029A' '032A' '034A' '035A' '037A' '038A' '039A' '040A' '041A' '042A'
#  '045A' '046A' '047A' '049A' '050A' '051A' '051B' '052A' '053A' '054A'
#  '056A' '057A' '058A' '059A' '060A' '062A' '063A' '064A' '065A' '067A'
#  '068A' '069A' '070A' '072A' '073A' '074A' '075A' '087A' '090A' '091A'
#  '092A' '093A' '095A' '097A' '097B' '100A' '101A' '102A' '103A' '104A'
#  '105A' '106A' '109A' '110A' '111A' '115A' '116A']
# AFTER SWAP - Unique Test Group IDs:
# ['000B' '009A' '010A' '011A' '024A' '026B' '028A' '031A' '033A' '036A'
#  '043A' '044A' '048A' '055A' '061A' '066A' '071A' '076A' '088A' '094A'
#  '096A' '099A' '108A' '113A' '117A']
# Length of X_train_val:
# 815
# Length of y_train_val:
# 815
# Length of groups_train_val:
# 815
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     510
# kitten    169
# senior    136
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     96
# senior    50
# kitten     7
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     510
# kitten    169
# senior    136
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     96
# senior    50
# kitten     7
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 510, 1: 169, 2: 136})
# Epoch 1/1500
# 26/26 [==============================] - 0s 3ms/step - loss: 1.4776 - accuracy: 0.4098
# Epoch 2/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 1.0375 - accuracy: 0.5877
# Epoch 3/1500
# 26/26 [==============================] - 0s 3ms/step - loss: 0.8102 - accuracy: 0.6712
# Epoch 4/1500
# 26/26 [==============================] - 0s 3ms/step - loss: 0.7150 - accuracy: 0.6982
# Epoch 5/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.5970 - accuracy: 0.7706
# Epoch 6/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.4983 - accuracy: 0.8086
# Epoch 7/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.4535 - accuracy: 0.8245
# Epoch 8/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.4006 - accuracy: 0.8491
# Epoch 9/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.3591 - accuracy: 0.8638
# Epoch 10/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.3438 - accuracy: 0.8761
# Epoch 11/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.2965 - accuracy: 0.9043
# Epoch 12/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.2655 - accuracy: 0.8982
# Epoch 13/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.2333 - accuracy: 0.9239
# Epoch 14/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.2194 - accuracy: 0.9325
# Epoch 15/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.1828 - accuracy: 0.9374
# Epoch 16/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.1745 - accuracy: 0.9411
# Epoch 17/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.1720 - accuracy: 0.9485
# Epoch 18/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.1484 - accuracy: 0.9583
# Epoch 19/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.1342 - accuracy: 0.9620
# Epoch 20/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.1309 - accuracy: 0.9583
# Epoch 21/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.1222 - accuracy: 0.9681
# Epoch 22/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.1181 - accuracy: 0.9632
# Epoch 23/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.1005 - accuracy: 0.9706
# Epoch 24/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.1030 - accuracy: 0.9730
# Epoch 25/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0924 - accuracy: 0.9755
# Epoch 26/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0818 - accuracy: 0.9791
# Epoch 27/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.1051 - accuracy: 0.9656
# Epoch 28/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0756 - accuracy: 0.9791
# Epoch 29/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0707 - accuracy: 0.9828
# Epoch 30/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0617 - accuracy: 0.9828
# Epoch 31/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0550 - accuracy: 0.9853
# Epoch 32/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0558 - accuracy: 0.9926
# Epoch 33/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0510 - accuracy: 0.9902
# Epoch 34/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0652 - accuracy: 0.9828
# Epoch 35/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0535 - accuracy: 0.9926
# Epoch 36/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0638 - accuracy: 0.9853
# Epoch 37/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0588 - accuracy: 0.9890
# Epoch 38/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0443 - accuracy: 0.9914
# Epoch 39/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0365 - accuracy: 0.9926
# Epoch 40/1500
# 26/26 [==============================] - 0s 9ms/step - loss: 0.0556 - accuracy: 0.9865
# Epoch 41/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0368 - accuracy: 0.9951
# Epoch 42/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0284 - accuracy: 0.9951
# Epoch 43/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0335 - accuracy: 0.9963
# Epoch 44/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0390 - accuracy: 0.9914
# Epoch 45/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0314 - accuracy: 0.9963
# Epoch 46/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0244 - accuracy: 0.9988
# Epoch 47/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0341 - accuracy: 0.9939
# Epoch 48/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0323 - accuracy: 0.9914
# Epoch 49/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0335 - accuracy: 0.9926
# Epoch 50/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0376 - accuracy: 0.9902
# Epoch 51/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0388 - accuracy: 0.9902
# Epoch 52/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0257 - accuracy: 0.9975
# Epoch 53/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0218 - accuracy: 0.9963
# Epoch 54/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0220 - accuracy: 0.9951
# Epoch 55/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0226 - accuracy: 0.9939
# Epoch 56/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0216 - accuracy: 0.9939
# Epoch 57/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0157 - accuracy: 0.9988
# Epoch 58/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0175 - accuracy: 0.9975
# Epoch 59/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0144 - accuracy: 0.9988
# Epoch 60/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0248 - accuracy: 0.9926
# Epoch 61/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0161 - accuracy: 0.9963
# Epoch 62/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0257 - accuracy: 0.9914
# Epoch 63/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0196 - accuracy: 0.9951
# Epoch 64/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0188 - accuracy: 0.9975
# Epoch 65/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0295 - accuracy: 0.9926
# Epoch 66/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0155 - accuracy: 0.9975
# Epoch 67/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0099 - accuracy: 0.9988
# Epoch 68/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0194 - accuracy: 0.9963
# Epoch 69/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0161 - accuracy: 0.9963
# Epoch 70/1500
# 26/26 [==============================] - 0s 11ms/step - loss: 0.0206 - accuracy: 0.9939
# Epoch 71/1500
# 26/26 [==============================] - 0s 5ms/step - loss: 0.0113 - accuracy: 0.9988
# Epoch 72/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0132 - accuracy: 0.9975
# Epoch 73/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0128 - accuracy: 0.9975
# Epoch 74/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0174 - accuracy: 0.9963
# Epoch 75/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0151 - accuracy: 0.9951
# Epoch 76/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0130 - accuracy: 0.9975
# Epoch 77/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0147 - accuracy: 0.9975
# Epoch 78/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0127 - accuracy: 0.9975
# Epoch 79/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0187 - accuracy: 0.9951
# Epoch 80/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0164 - accuracy: 0.9939
# Epoch 81/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0121 - accuracy: 0.9988
# Epoch 82/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0156 - accuracy: 0.9939
# Epoch 83/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0142 - accuracy: 0.9975
# Epoch 84/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0103 - accuracy: 0.9975
# Epoch 85/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0247 - accuracy: 0.9914
# Epoch 86/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0147 - accuracy: 0.9975
# Epoch 87/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0083 - accuracy: 1.0000
# Epoch 88/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0119 - accuracy: 1.0000
# Epoch 89/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0168 - accuracy: 0.9951
# Epoch 90/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0135 - accuracy: 0.9975
# Epoch 91/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0087 - accuracy: 1.0000
# Epoch 92/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0077 - accuracy: 0.9988
# Epoch 93/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0097 - accuracy: 0.9975
# Epoch 94/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0088 - accuracy: 1.0000
# Epoch 95/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0140 - accuracy: 0.9963
# Epoch 96/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0095 - accuracy: 0.9975
# Epoch 97/1500
# 26/26 [==============================] - 0s 9ms/step - loss: 0.0217 - accuracy: 0.9939
# Epoch 98/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0059 - accuracy: 1.0000
# Epoch 99/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0096 - accuracy: 0.9988
# Epoch 100/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0177 - accuracy: 0.9963
# Epoch 101/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0108 - accuracy: 0.9975
# Epoch 102/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0108 - accuracy: 0.9975
# Epoch 103/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0061 - accuracy: 1.0000
# Epoch 104/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0057 - accuracy: 1.0000
# Epoch 105/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0095 - accuracy: 0.9975
# Epoch 106/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0065 - accuracy: 0.9975
# Epoch 107/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0049 - accuracy: 0.9988
# Epoch 108/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0060 - accuracy: 1.0000
# Epoch 109/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0142 - accuracy: 0.9951
# Epoch 110/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0045 - accuracy: 1.0000
# Epoch 111/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0044 - accuracy: 1.0000
# Epoch 112/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0056 - accuracy: 0.9988
# Epoch 113/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0151 - accuracy: 0.9951
# Epoch 114/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0102 - accuracy: 0.9963
# Epoch 115/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 116/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 117/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0051 - accuracy: 0.9988
# Epoch 118/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 119/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0059 - accuracy: 0.9988
# Epoch 120/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0057 - accuracy: 0.9988
# Epoch 121/1500
# 26/26 [==============================] - 0s 9ms/step - loss: 0.0083 - accuracy: 0.9975
# Epoch 122/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0052 - accuracy: 1.0000
# Epoch 123/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0071 - accuracy: 0.9988
# Epoch 124/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0047 - accuracy: 0.9975
# Epoch 125/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0052 - accuracy: 1.0000
# Epoch 126/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0055 - accuracy: 1.0000
# Epoch 127/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0053 - accuracy: 0.9988
# Epoch 128/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 129/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0056 - accuracy: 0.9988
# Epoch 130/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0097 - accuracy: 0.9963
# Epoch 131/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0093 - accuracy: 0.9975
# Epoch 132/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0049 - accuracy: 1.0000
# Epoch 133/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0049 - accuracy: 0.9988
# Epoch 134/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0029 - accuracy: 0.9988
# Epoch 135/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0051 - accuracy: 0.9988
# Epoch 136/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0060 - accuracy: 0.9988
# Epoch 137/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0059 - accuracy: 0.9988
# Epoch 138/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0114 - accuracy: 0.9975
# Epoch 139/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 140/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0046 - accuracy: 0.9988
# Epoch 141/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0135 - accuracy: 0.9975
# Epoch 142/1500
# 26/26 [==============================] - 0s 9ms/step - loss: 0.0079 - accuracy: 0.9975
# Epoch 143/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0076 - accuracy: 1.0000
# Epoch 144/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0047 - accuracy: 0.9988
# Epoch 145/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0044 - accuracy: 0.9988
# Epoch 146/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 147/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 148/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0032 - accuracy: 0.9988
# Epoch 149/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 150/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 151/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 152/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0055 - accuracy: 0.9975
# Epoch 153/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0101 - accuracy: 0.9951
# Epoch 154/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0087 - accuracy: 0.9963
# Epoch 155/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0204 - accuracy: 0.9939
# Epoch 156/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0102 - accuracy: 0.9963
# Epoch 157/1500
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0055 - accuracy: 0.9988
# Epoch 158/1500
# 14/26 [===============>..............] - ETA: 0s - loss: 0.0029 - accuracy: 1.0000    Restoring model weights from the end of the best epoch: 128.
# 26/26 [==============================] - 0s 4ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 158: early stopping
# 5/5 [==============================] - 0s 1ms/step - loss: 2.6464 - accuracy: 0.6667
# 5/5 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.68 (17/25)
# Before appending - Cat IDs: 0, Predictions: 0, Actuals: 0, Gender: 0
# After appending - Cat IDs: 153, Predictions: 153, Actuals: 153, Gender: 153
# Final Test Results - Loss: 2.646406412124634, Accuracy: 0.6666666865348816, Precision: 0.6117719203645553, Recall: 0.6324007936507936, F1 Score: 0.6084751018961546
# Confusion Matrix:
#  [[79  4 13]
#  [ 2  5  0]
#  [32  0 18]]
# outer_fold 2
# Train Set Group Distribution:
# 046A    66
# 000A    39
# 002B    36
# 103A    33
# 047A    30
# 074A    25
# 020A    23
# 000B    20
# 055A    20
# 059A    18
# 019A    17
# 101A    16
# 106A    15
# 001A    15
# 028A    14
# 111A    13
# 116A    12
# 051A    12
# 039A    12
# 016A    11
# 036A    11
# 005A    11
# 071A    10
# 040A    10
# 065A     9
# 072A     9
# 033A     9
# 095A     8
# 010A     8
# 094A     8
# 050A     7
# 099A     7
# 027A     7
# 031A     7
# 053A     7
# 117A     7
# 021A     6
# 008A     6
# 025C     6
# 108A     6
# 007A     6
# 037A     6
# 023A     6
# 075A     5
# 012A     5
# 034A     5
# 070A     5
# 044A     5
# 035A     4
# 009A     4
# 026A     4
# 003A     4
# 104A     4
# 105A     4
# 052A     4
# 014A     3
# 064A     3
# 056A     3
# 058A     3
# 011A     3
# 113A     3
# 087A     2
# 066A     2
# 069A     2
# 061A     2
# 018A     2
# 032A     2
# 026B     1
# 115A     1
# 076A     1
# 024A     1
# 096A     1
# 026C     1
# 073A     1
# 088A     1
# 091A     1
# 043A     1
# 110A     1
# 048A     1
# 092A     1
# 090A     1
# 100A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 057A    28
# 067A    20
# 029A    17
# 097A    16
# 042A    14
# 097B    14
# 002A    13
# 025A    11
# 063A    11
# 068A    11
# 015A    10
# 014B    10
# 045A     9
# 051B     9
# 022A     9
# 013B     8
# 109A     6
# 062A     5
# 023B     5
# 006A     3
# 060A     3
# 038A     2
# 102A     2
# 054A     2
# 025B     2
# 093A     2
# 049A     1
# 019B     1
# 041A     1
# 004A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    290
# X    224
# F    208
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    131
# M     66
# F     49
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [028A, 070A, 033A, 000B, 071A, 020A, 000A, 026...
# kitten    [046A, 110A, 040A, 047A, 048A, 111A, 044A, 043...
# senior    [117A, 106A, 090A, 113A, 116A, 051A, 024A, 094...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [002A, 015A, 023B, 038A, 068A, 013B, 062A, 006...
# kitten                 [042A, 014B, 109A, 049A, 045A, 041A]
# senior                       [057A, 051B, 097A, 054A, 093A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 55, 'kitten': 10, 'senior': 17}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 19, 'kitten': 6, 'senior': 5}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002B' '003A' '005A' '007A' '008A' '009A' '010A'
#  '011A' '012A' '014A' '016A' '018A' '019A' '020A' '021A' '023A' '024A'
#  '025C' '026A' '026B' '026C' '027A' '028A' '031A' '032A' '033A' '034A'
#  '035A' '036A' '037A' '039A' '040A' '043A' '044A' '046A' '047A' '048A'
#  '050A' '051A' '052A' '053A' '055A' '056A' '058A' '059A' '061A' '064A'
#  '065A' '066A' '069A' '070A' '071A' '072A' '073A' '074A' '075A' '076A'
#  '087A' '088A' '090A' '091A' '092A' '094A' '095A' '096A' '099A' '100A'
#  '101A' '103A' '104A' '105A' '106A' '108A' '110A' '111A' '113A' '115A'
#  '116A' '117A']
# Unique Test Group IDs:
# ['002A' '004A' '006A' '013B' '014B' '015A' '019B' '022A' '023B' '025A'
#  '025B' '029A' '038A' '041A' '042A' '045A' '049A' '051B' '054A' '057A'
#  '060A' '062A' '063A' '067A' '068A' '093A' '097A' '097B' '102A' '109A']
# No common groups found between train and test sets.
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002B' '003A' '005A' '007A' '008A' '009A' '010A'
#  '011A' '012A' '014A' '016A' '018A' '019A' '020A' '021A' '023A' '024A'
#  '025C' '026A' '026B' '026C' '027A' '028A' '031A' '032A' '033A' '034A'
#  '035A' '036A' '037A' '039A' '040A' '043A' '044A' '046A' '047A' '048A'
#  '050A' '051A' '052A' '053A' '055A' '056A' '058A' '059A' '061A' '064A'
#  '065A' '066A' '069A' '070A' '071A' '072A' '073A' '074A' '075A' '076A'
#  '087A' '088A' '090A' '091A' '092A' '094A' '095A' '096A' '099A' '100A'
#  '101A' '103A' '104A' '105A' '106A' '108A' '110A' '111A' '113A' '115A'
#  '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['002A' '004A' '006A' '013B' '014B' '015A' '019B' '022A' '023B' '025A'
#  '025B' '029A' '038A' '041A' '042A' '045A' '049A' '051B' '054A' '057A'
#  '060A' '062A' '063A' '067A' '068A' '093A' '097A' '097B' '102A' '109A']
# Length of X_train_val:
# 722
# Length of y_train_val:
# 722
# Length of groups_train_val:
# 722
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     458
# kitten    135
# senior    129
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     148
# senior     57
# kitten     41
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     458
# kitten    135
# senior    129
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     148
# senior     57
# kitten     41
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 458, 1: 135, 2: 129})
# Epoch 1/1500
# 23/23 [==============================] - 1s 3ms/step - loss: 1.5270 - accuracy: 0.4114
# Epoch 2/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 1.0272 - accuracy: 0.5568
# Epoch 3/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.7849 - accuracy: 0.6842
# Epoch 4/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.6294 - accuracy: 0.7493
# Epoch 5/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.5519 - accuracy: 0.7909
# Epoch 6/1500
# 23/23 [==============================] - 0s 10ms/step - loss: 0.4752 - accuracy: 0.8144
# Epoch 7/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4135 - accuracy: 0.8380
# Epoch 8/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3953 - accuracy: 0.8573
# Epoch 9/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3275 - accuracy: 0.8781
# Epoch 10/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3164 - accuracy: 0.8961
# Epoch 11/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.2722 - accuracy: 0.8975
# Epoch 12/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.2446 - accuracy: 0.9141
# Epoch 13/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1983 - accuracy: 0.9377
# Epoch 14/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.2101 - accuracy: 0.9266
# Epoch 15/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1720 - accuracy: 0.9446
# Epoch 16/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1934 - accuracy: 0.9460
# Epoch 17/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1576 - accuracy: 0.9529
# Epoch 18/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1398 - accuracy: 0.9626
# Epoch 19/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1295 - accuracy: 0.9681
# Epoch 20/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0920 - accuracy: 0.9806
# Epoch 21/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1070 - accuracy: 0.9668
# Epoch 22/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0990 - accuracy: 0.9737
# Epoch 23/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1152 - accuracy: 0.9737
# Epoch 24/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1063 - accuracy: 0.9626
# Epoch 25/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0763 - accuracy: 0.9820
# Epoch 26/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0712 - accuracy: 0.9861
# Epoch 27/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1043 - accuracy: 0.9695
# Epoch 28/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0898 - accuracy: 0.9751
# Epoch 29/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0868 - accuracy: 0.9737
# Epoch 30/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0670 - accuracy: 0.9834
# Epoch 31/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0572 - accuracy: 0.9820
# Epoch 32/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0823 - accuracy: 0.9737
# Epoch 33/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0616 - accuracy: 0.9875
# Epoch 34/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0634 - accuracy: 0.9875
# Epoch 35/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0527 - accuracy: 0.9875
# Epoch 36/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0574 - accuracy: 0.9848
# Epoch 37/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0436 - accuracy: 0.9931
# Epoch 38/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0575 - accuracy: 0.9848
# Epoch 39/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0457 - accuracy: 0.9903
# Epoch 40/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0422 - accuracy: 0.9861
# Epoch 41/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0343 - accuracy: 0.9972
# Epoch 42/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0420 - accuracy: 0.9917
# Epoch 43/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0341 - accuracy: 0.9958
# Epoch 44/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0294 - accuracy: 0.9917
# Epoch 45/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0342 - accuracy: 0.9945
# Epoch 46/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0245 - accuracy: 0.9945
# Epoch 47/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0229 - accuracy: 0.9986
# Epoch 48/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0285 - accuracy: 0.9931
# Epoch 49/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0261 - accuracy: 0.9958
# Epoch 50/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0211 - accuracy: 0.9986
# Epoch 51/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0484 - accuracy: 0.9861
# Epoch 52/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0358 - accuracy: 0.9889
# Epoch 53/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0222 - accuracy: 0.9931
# Epoch 54/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0313 - accuracy: 0.9903
# Epoch 55/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0387 - accuracy: 0.9875
# Epoch 56/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0232 - accuracy: 0.9931
# Epoch 57/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0291 - accuracy: 0.9917
# Epoch 58/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0214 - accuracy: 0.9945
# Epoch 59/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0225 - accuracy: 0.9958
# Epoch 60/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0172 - accuracy: 1.0000
# Epoch 61/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0230 - accuracy: 0.9931
# Epoch 62/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0197 - accuracy: 0.9972
# Epoch 63/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0178 - accuracy: 0.9972
# Epoch 64/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0213 - accuracy: 0.9931
# Epoch 65/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0121 - accuracy: 1.0000
# Epoch 66/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0142 - accuracy: 0.9986
# Epoch 67/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0211 - accuracy: 0.9945
# Epoch 68/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0178 - accuracy: 0.9972
# Epoch 69/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0311 - accuracy: 0.9903
# Epoch 70/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0107 - accuracy: 0.9986
# Epoch 71/1500
# 23/23 [==============================] - 0s 8ms/step - loss: 0.0210 - accuracy: 0.9958
# Epoch 72/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0182 - accuracy: 0.9972
# Epoch 73/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0171 - accuracy: 0.9972
# Epoch 74/1500
# 23/23 [==============================] - 0s 11ms/step - loss: 0.0130 - accuracy: 0.9972
# Epoch 75/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0161 - accuracy: 0.9986
# Epoch 76/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0125 - accuracy: 1.0000
# Epoch 77/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0134 - accuracy: 0.9958
# Epoch 78/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0097 - accuracy: 1.0000
# Epoch 79/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0156 - accuracy: 0.9958
# Epoch 80/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0093 - accuracy: 1.0000
# Epoch 81/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0066 - accuracy: 1.0000
# Epoch 82/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0102 - accuracy: 0.9986
# Epoch 83/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0060 - accuracy: 1.0000
# Epoch 84/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0071 - accuracy: 1.0000
# Epoch 85/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0122 - accuracy: 0.9972
# Epoch 86/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0120 - accuracy: 0.9972
# Epoch 87/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0196 - accuracy: 0.9931
# Epoch 88/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0128 - accuracy: 0.9958
# Epoch 89/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0057 - accuracy: 1.0000
# Epoch 90/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0047 - accuracy: 1.0000
# Epoch 91/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0128 - accuracy: 0.9958
# Epoch 92/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0141 - accuracy: 0.9972
# Epoch 93/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0129 - accuracy: 0.9986
# Epoch 94/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0066 - accuracy: 1.0000
# Epoch 95/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0106 - accuracy: 1.0000
# Epoch 96/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0071 - accuracy: 0.9986
# Epoch 97/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0066 - accuracy: 1.0000
# Epoch 98/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0065 - accuracy: 1.0000
# Epoch 99/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0207 - accuracy: 0.9945
# Epoch 100/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0081 - accuracy: 1.0000
# Epoch 101/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0060 - accuracy: 1.0000
# Epoch 102/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0185 - accuracy: 0.9958
# Epoch 103/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0212 - accuracy: 0.9917
# Epoch 104/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0091 - accuracy: 0.9986
# Epoch 105/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0181 - accuracy: 0.9945
# Epoch 106/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0126 - accuracy: 0.9972
# Epoch 107/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0136 - accuracy: 0.9986
# Epoch 108/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0081 - accuracy: 1.0000
# Epoch 109/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0066 - accuracy: 1.0000
# Epoch 110/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0061 - accuracy: 0.9972
# Epoch 111/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0092 - accuracy: 0.9972
# Epoch 112/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0062 - accuracy: 0.9986
# Epoch 113/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 114/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0059 - accuracy: 1.0000
# Epoch 115/1500
# 23/23 [==============================] - 0s 9ms/step - loss: 0.0148 - accuracy: 0.9972
# Epoch 116/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0046 - accuracy: 1.0000
# Epoch 117/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0060 - accuracy: 0.9986
# Epoch 118/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0043 - accuracy: 1.0000
# Epoch 119/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0101 - accuracy: 0.9958
# Epoch 120/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0409 - accuracy: 0.9848
# Epoch 121/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0153 - accuracy: 0.9958
# Epoch 122/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0180 - accuracy: 0.9972
# Epoch 123/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0065 - accuracy: 0.9986
# Epoch 124/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0080 - accuracy: 0.9972
# Epoch 125/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0272 - accuracy: 0.9889
# Epoch 126/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0041 - accuracy: 1.0000
# Epoch 127/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0071 - accuracy: 0.9986
# Epoch 128/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0043 - accuracy: 1.0000
# Epoch 129/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0053 - accuracy: 0.9986
# Epoch 130/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0100 - accuracy: 0.9972
# Epoch 131/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0165 - accuracy: 0.9972
# Epoch 132/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0061 - accuracy: 0.9986
# Epoch 133/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0044 - accuracy: 0.9986
# Epoch 134/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 135/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0117 - accuracy: 0.9972
# Epoch 136/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 137/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0151 - accuracy: 0.9958
# Epoch 138/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0048 - accuracy: 1.0000
# Epoch 139/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0139 - accuracy: 0.9986
# Epoch 140/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0071 - accuracy: 0.9986
# Epoch 141/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0066 - accuracy: 0.9986
# Epoch 142/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 143/1500
# 14/23 [=================>............] - ETA: 0s - loss: 0.0030 - accuracy: 1.0000    Restoring model weights from the end of the best epoch: 113.
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 143: early stopping
# 8/8 [==============================] - 0s 959us/step - loss: 3.1955 - accuracy: 0.5650
# 8/8 [==============================] - 0s 944us/step
# Majority Vote Accuracy for cat_id for this fold: 0.53 (16/30)
# Before appending - Cat IDs: 153, Predictions: 153, Actuals: 153, Gender: 153
# After appending - Cat IDs: 399, Predictions: 399, Actuals: 399, Gender: 399
# Final Test Results - Loss: 3.195464611053467, Accuracy: 0.565040647983551, Precision: 0.4903764536117478, Recall: 0.4646395432659875, F1 Score: 0.4684447099190212
# Confusion Matrix:
#  [[107  27  14]
#  [ 21  16   4]
#  [ 40   1  16]]
# outer_fold 3
# Train Set Group Distribution:
# 046A    66
# 000A    39
# 047A    30
# 057A    28
# 074A    25
# 020A    23
# 000B    20
# 067A    20
# 055A    20
# 029A    17
# 019A    17
# 097A    16
# 097B    14
# 042A    14
# 028A    14
# 111A    13
# 002A    13
# 116A    12
# 051A    12
# 005A    11
# 025A    11
# 036A    11
# 063A    11
# 016A    11
# 068A    11
# 071A    10
# 015A    10
# 014B    10
# 022A     9
# 045A     9
# 051B     9
# 072A     9
# 033A     9
# 095A     8
# 010A     8
# 013B     8
# 094A     8
# 099A     7
# 117A     7
# 050A     7
# 031A     7
# 053A     7
# 007A     6
# 108A     6
# 109A     6
# 021A     6
# 044A     5
# 075A     5
# 034A     5
# 023B     5
# 062A     5
# 009A     4
# 003A     4
# 052A     4
# 104A     4
# 060A     3
# 006A     3
# 014A     3
# 011A     3
# 113A     3
# 056A     3
# 025B     2
# 018A     2
# 066A     2
# 061A     2
# 038A     2
# 102A     2
# 069A     2
# 054A     2
# 093A     2
# 004A     1
# 041A     1
# 076A     1
# 110A     1
# 019B     1
# 088A     1
# 096A     1
# 043A     1
# 048A     1
# 049A     1
# 024A     1
# 026B     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 002B    36
# 103A    33
# 059A    18
# 101A    16
# 106A    15
# 001A    15
# 039A    12
# 040A    10
# 065A     9
# 027A     7
# 023A     6
# 025C     6
# 037A     6
# 008A     6
# 070A     5
# 012A     5
# 035A     4
# 026A     4
# 105A     4
# 058A     3
# 064A     3
# 032A     2
# 087A     2
# 092A     1
# 073A     1
# 091A     1
# 090A     1
# 026C     1
# 115A     1
# 100A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    313
# F    221
# M    200
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# M    156
# X     42
# F     36
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [002A, 028A, 033A, 000B, 071A, 020A, 000A, 015...
# kitten    [046A, 042A, 014B, 110A, 109A, 047A, 049A, 045...
# senior    [117A, 057A, 113A, 051B, 116A, 051A, 024A, 097...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [070A, 026A, 065A, 026C, 001A, 105A, 002B, 091...
# kitten                                         [040A, 115A]
# senior                             [106A, 090A, 059A, 058A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 50, 'kitten': 14, 'senior': 18}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 24, 'kitten': 2, 'senior': 4}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '002A' '003A' '004A' '005A' '006A' '007A' '009A' '010A'
#  '011A' '013B' '014A' '014B' '015A' '016A' '018A' '019A' '019B' '020A'
#  '021A' '022A' '023B' '024A' '025A' '025B' '026B' '028A' '029A' '031A'
#  '033A' '034A' '036A' '038A' '041A' '042A' '043A' '044A' '045A' '046A'
#  '047A' '048A' '049A' '050A' '051A' '051B' '052A' '053A' '054A' '055A'
#  '056A' '057A' '060A' '061A' '062A' '063A' '066A' '067A' '068A' '069A'
#  '071A' '072A' '074A' '075A' '076A' '088A' '093A' '094A' '095A' '096A'
#  '097A' '097B' '099A' '102A' '104A' '108A' '109A' '110A' '111A' '113A'
#  '116A' '117A']
# Unique Test Group IDs:
# ['001A' '002B' '008A' '012A' '023A' '025C' '026A' '026C' '027A' '032A'
#  '035A' '037A' '039A' '040A' '058A' '059A' '064A' '065A' '070A' '073A'
#  '087A' '090A' '091A' '092A' '100A' '101A' '103A' '105A' '106A' '115A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '002A' '003A' '004A' '005A' '006A' '007A' '009A' '010A'
#  '011A' '013B' '014A' '014B' '015A' '016A' '018A' '019A' '019B' '020A'
#  '021A' '022A' '023B' '024A' '025A' '025B' '026B' '028A' '029A' '031A'
#  '033A' '034A' '036A' '038A' '041A' '042A' '043A' '044A' '045A' '046A'
#  '047A' '048A' '049A' '050A' '051A' '051B' '052A' '053A' '054A' '055A'
#  '056A' '057A' '060A' '061A' '062A' '063A' '066A' '067A' '068A' '069A'
#  '071A' '072A' '074A' '075A' '076A' '088A' '093A' '094A' '095A' '096A'
#  '097A' '097B' '099A' '102A' '104A' '108A' '109A' '110A' '111A' '113A'
#  '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['001A' '002B' '008A' '012A' '023A' '025C' '026A' '026C' '027A' '032A'
#  '035A' '037A' '039A' '040A' '058A' '059A' '064A' '065A' '070A' '073A'
#  '087A' '090A' '091A' '092A' '100A' '101A' '103A' '105A' '106A' '115A']
# Length of X_train_val:
# 734
# Length of y_train_val:
# 734
# Length of groups_train_val:
# 734
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     420
# kitten    165
# senior    149
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     186
# senior     37
# kitten     11
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     420
# kitten    165
# senior    149
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     186
# senior     37
# kitten     11
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 420, 1: 165, 2: 149})
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Epoch 1/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 1.4411 - accuracy: 0.4319
# Epoch 2/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.9938 - accuracy: 0.5995
# Epoch 3/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.7832 - accuracy: 0.6744
# Epoch 4/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.6286 - accuracy: 0.7480
# Epoch 5/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.5095 - accuracy: 0.7970
# Epoch 6/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4713 - accuracy: 0.8134
# Epoch 7/1500
# ...
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4381 - accuracy: 0.8268
# Epoch 9/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4204 - accuracy: 0.8506
# Epoch 10/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3577 - accuracy: 0.8687
# Epoch 11/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3230 - accuracy: 0.8771
# Epoch 12/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.2722 - accuracy: 0.9204
# Epoch 13/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.2742 - accuracy: 0.8925
# Epoch 14/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.2373 - accuracy: 0.9176
# Epoch 15/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.2108 - accuracy: 0.9330
# Epoch 16/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.2085 - accuracy: 0.9330
# Epoch 17/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1965 - accuracy: 0.9372
# Epoch 18/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1660 - accuracy: 0.9721
# Epoch 19/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1656 - accuracy: 0.9497
# Epoch 20/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1636 - accuracy: 0.9525
# Epoch 21/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1525 - accuracy: 0.9525
# Epoch 22/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1218 - accuracy: 0.9679
# Epoch 23/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1255 - accuracy: 0.9665
# Epoch 24/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1041 - accuracy: 0.9777
# Epoch 25/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1200 - accuracy: 0.9665
# Epoch 26/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0968 - accuracy: 0.9721
# Epoch 27/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1228 - accuracy: 0.9623
# Epoch 28/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0947 - accuracy: 0.9763
# Epoch 29/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0853 - accuracy: 0.9777
# Epoch 30/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0917 - accuracy: 0.9749
# Epoch 31/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0697 - accuracy: 0.9860
# Epoch 32/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0620 - accuracy: 0.9860
# Epoch 33/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0678 - accuracy: 0.9860
# Epoch 34/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0613 - accuracy: 0.9791
# Epoch 35/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0667 - accuracy: 0.9874
# Epoch 36/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0742 - accuracy: 0.9818
# Epoch 37/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0629 - accuracy: 0.9832
# Epoch 38/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0664 - accuracy: 0.9916
# Epoch 39/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0621 - accuracy: 0.9804
# Epoch 40/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0575 - accuracy: 0.9846
# Epoch 41/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0572 - accuracy: 0.9818
# Epoch 42/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0472 - accuracy: 0.9902
# Epoch 43/1500
# 23/23 [==============================] - 0s 10ms/step - loss: 0.0413 - accuracy: 0.9916
# Epoch 44/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0546 - accuracy: 0.9888
# Epoch 45/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0405 - accuracy: 0.9916
# Epoch 46/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0430 - accuracy: 0.9902
# Epoch 47/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0295 - accuracy: 0.9916
# Epoch 48/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0364 - accuracy: 0.9916
# Epoch 49/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0452 - accuracy: 0.9874
# Epoch 50/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0261 - accuracy: 0.9958
# Epoch 51/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0494 - accuracy: 0.9846
# Epoch 52/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0294 - accuracy: 0.9930
# Epoch 53/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0335 - accuracy: 0.9958
# Epoch 54/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0257 - accuracy: 0.9986
# Epoch 55/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0350 - accuracy: 0.9916
# Epoch 56/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0384 - accuracy: 0.9888
# Epoch 57/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0323 - accuracy: 0.9930
# Epoch 58/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0189 - accuracy: 0.9972
# Epoch 59/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0200 - accuracy: 0.9972
# Epoch 60/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0229 - accuracy: 0.9972
# Epoch 61/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0167 - accuracy: 0.9986
# Epoch 62/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0315 - accuracy: 0.9930
# Epoch 63/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0208 - accuracy: 0.9944
# Epoch 64/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0227 - accuracy: 0.9958
# Epoch 65/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0244 - accuracy: 0.9916
# Epoch 66/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0144 - accuracy: 0.9972
# Epoch 67/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0138 - accuracy: 0.9986
# Epoch 68/1500
# 23/23 [==============================] - 0s 6ms/step - loss: 0.0199 - accuracy: 0.9972
# Epoch 69/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0131 - accuracy: 0.9986
# Epoch 70/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0242 - accuracy: 0.9958
# Epoch 71/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0272 - accuracy: 0.9916
# Epoch 72/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0364 - accuracy: 0.9902
# Epoch 73/1500
# 23/23 [==============================] - 0s 10ms/step - loss: 0.0178 - accuracy: 0.9972
# Epoch 74/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0233 - accuracy: 0.9944
# Epoch 75/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0178 - accuracy: 0.9944
# Epoch 76/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0179 - accuracy: 0.9986
# Epoch 77/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0241 - accuracy: 0.9944
# Epoch 78/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0182 - accuracy: 0.9986
# Epoch 79/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0130 - accuracy: 0.9972
# Epoch 80/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0126 - accuracy: 1.0000
# Epoch 81/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0167 - accuracy: 1.0000
# Epoch 82/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0196 - accuracy: 0.9944
# Epoch 83/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0097 - accuracy: 0.9986
# Epoch 84/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0108 - accuracy: 0.9986
# Epoch 85/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0216 - accuracy: 0.9888
# Epoch 86/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0159 - accuracy: 0.9958
# Epoch 87/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0189 - accuracy: 0.9972
# Epoch 88/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0137 - accuracy: 0.9972
# Epoch 89/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0113 - accuracy: 0.9986
# Epoch 90/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0149 - accuracy: 0.9944
# Epoch 91/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0108 - accuracy: 0.9986
# Epoch 92/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0076 - accuracy: 1.0000
# Epoch 93/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0145 - accuracy: 0.9972
# Epoch 94/1500
# 23/23 [==============================] - 0s 13ms/step - loss: 0.0146 - accuracy: 0.9972
# Epoch 95/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0112 - accuracy: 0.9986
# Epoch 96/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0124 - accuracy: 0.9972
# Epoch 97/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0167 - accuracy: 0.9972
# Epoch 98/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0069 - accuracy: 1.0000
# Epoch 99/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0157 - accuracy: 0.9958
# Epoch 100/1500
# 23/23 [==============================] - 0s 10ms/step - loss: 0.0073 - accuracy: 1.0000
# Epoch 101/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0099 - accuracy: 0.9972
# Epoch 102/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0129 - accuracy: 0.9972
# Epoch 103/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0159 - accuracy: 0.9944
# Epoch 104/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0096 - accuracy: 0.9986
# Epoch 105/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0276 - accuracy: 0.9916
# Epoch 106/1500
# 23/23 [==============================] - 0s 10ms/step - loss: 0.0120 - accuracy: 1.0000
# Epoch 107/1500
# 23/23 [==============================] - 0s 10ms/step - loss: 0.0082 - accuracy: 0.9972
# Epoch 108/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0115 - accuracy: 0.9972
# Epoch 109/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0088 - accuracy: 0.9972
# Epoch 110/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0113 - accuracy: 0.9986
# Epoch 111/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0164 - accuracy: 0.9972
# Epoch 112/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0063 - accuracy: 1.0000
# Epoch 113/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0057 - accuracy: 1.0000
# Epoch 114/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0084 - accuracy: 0.9986
# Epoch 115/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0066 - accuracy: 1.0000
# Epoch 116/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0088 - accuracy: 0.9972
# Epoch 117/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0118 - accuracy: 0.9972
# Epoch 118/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0161 - accuracy: 0.9916
# Epoch 119/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0176 - accuracy: 0.9930
# Epoch 120/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0086 - accuracy: 0.9972
# Epoch 121/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0066 - accuracy: 0.9986
# Epoch 122/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0149 - accuracy: 0.9958
# Epoch 123/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0168 - accuracy: 0.9958
# Epoch 124/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0041 - accuracy: 1.0000
# Epoch 125/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0096 - accuracy: 0.9986
# Epoch 126/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0081 - accuracy: 0.9986
# Epoch 127/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0104 - accuracy: 0.9958
# Epoch 128/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0090 - accuracy: 0.9958
# Epoch 129/1500
# 23/23 [==============================] - 0s 10ms/step - loss: 0.0073 - accuracy: 0.9986
# Epoch 130/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0048 - accuracy: 1.0000
# Epoch 131/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0055 - accuracy: 0.9986
# Epoch 132/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0066 - accuracy: 0.9986
# Epoch 133/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0052 - accuracy: 0.9986
# Epoch 134/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0128 - accuracy: 0.9958
# Epoch 135/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0043 - accuracy: 1.0000
# Epoch 136/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0044 - accuracy: 1.0000
# Epoch 137/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0047 - accuracy: 1.0000
# Epoch 138/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0060 - accuracy: 0.9986
# Epoch 139/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0080 - accuracy: 0.9986
# Epoch 140/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0061 - accuracy: 0.9986
# Epoch 141/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0041 - accuracy: 1.0000
# Epoch 142/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0133 - accuracy: 0.9972
# Epoch 143/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0060 - accuracy: 0.9986
# Epoch 144/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0086 - accuracy: 0.9986
# Epoch 145/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0037 - accuracy: 0.9986
# Epoch 146/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0399 - accuracy: 0.9916
# Epoch 147/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0275 - accuracy: 0.9944
# Epoch 148/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0065 - accuracy: 1.0000
# Epoch 149/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0147 - accuracy: 0.9958
# Epoch 150/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0056 - accuracy: 1.0000
# Epoch 151/1500
# 23/23 [==============================] - 0s 10ms/step - loss: 0.0052 - accuracy: 0.9986
# Epoch 152/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0142 - accuracy: 0.9916
# Epoch 153/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0261 - accuracy: 0.9930
# Epoch 154/1500
# 14/23 [=================>............] - ETA: 0s - loss: 0.0116 - accuracy: 0.9955Restoring model weights from the end of the best epoch: 124.
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0232 - accuracy: 0.9916
# Epoch 154: early stopping
# 8/8 [==============================] - 0s 1ms/step - loss: 6.9393 - accuracy: 0.6746
# 8/8 [==============================] - 0s 983us/step
# Majority Vote Accuracy for cat_id for this fold: 0.81 (22/27)
# Before appending - Cat IDs: 633, Predictions: 633, Actuals: 633, Gender: 633
# After appending - Cat IDs: 885, Predictions: 885, Actuals: 885, Gender: 885
# Final Test Results - Loss: 6.939297199249268, Accuracy: 0.6746031641960144, Precision: 0.6220515803108081, Recall: 0.5643939393939394, F1 Score: 0.5852845448488294
# Confusion Matrix:
#  [[126  14  14]
#  [ 25  29   2]
#  [ 27   0  15]]
#
# Final Average F1-Score across all UNSEEN TEST sets: 0.5491826976279265
#
# Final Average Loss across all UNSEEN TEST sets: 4.288776099681854
#
# Final Average Accuracy across all UNSEEN TEST sets: 0.6453810483217239
#
# Final Average Precision across all UNSEEN TEST sets: 0.5564810704215755
#
# Final Average Recall across all UNSEEN TEST sets: 0.5721256734254296

# %%
seed_4_folds_values = (unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1)

# Plotting all fold metrics
seed_4_folds_plot = plot_all_metrics(unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1, "Folds", "Fold Number")

# %% [markdown]
# ## Majority Voting on Total Entries per cat_id

# %%
# Debugging print statements
print(f'Checking - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
# Out:
# Checking - Cat IDs: 885, Predictions: 885, Actuals: 885, Gender: 885

# %%
# Create results df
full_results = pd.DataFrame({
    'cat_id': all_cat_ids,
    'predicted_age_group': all_predicted_age_groups,
    'actual_age_group': all_actual_age_groups,
    'all_gender': all_gender
})

# create a correct majority prediction column
full_results['correct'] = full_results['predicted_age_group'] == full_results['actual_age_group']

# %%
# Group by cat_id and aggregate predicted age groups
majority_votes = full_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first()

# Calculate the accuracy of majority voting
correct_predictions = (majority_votes == actual_groups).sum()
total_cats = len(actual_groups)
majority_vote_accuracy = correct_predictions / total_cats

logger(f"Overall Majority Vote Accuracy for cat_id: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

# store for final evaluation 
all_majority_vote_accuracies.append(majority_vote_accuracy)
# Out:
# Overall Majority Vote Accuracy for cat_id: 0.71 (78/110)

# %%
# Detailed df with predictions, actual labels, and comparison including majority vote
detailed_results = full_results.groupby('cat_id').apply(
    lambda x: pd.Series({
        'Predictions': list(x['predicted_age_group']),
        'Majority Vote': x['predicted_age_group'].mode()[0],
        'Actual Age Group': x['actual_age_group'].iloc[0],
        'Correct Majority Vote': x['predicted_age_group'].mode()[0] == x['actual_age_group'].iloc[0]
    })
).reset_index()

# Convert to DataFrame for better formatting and display
detailed_results = pd.DataFrame(detailed_results)

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 10)
pd.set_option('display.width', 1000)

sorted_detailed_results = detailed_results.sort_values(by='Correct Majority Vote', ascending=False)

# Display the sorted DataFrame
sorted_detailed_results
# Out:
#     cat_id                                        Predictions Majority Vote Actual Age Group  Correct Majority Vote
# 0     000B  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 65    059A  [senior, senior, senior, senior, adult, senior...        senior           senior                   True
# 76    070A              [senior, senior, adult, adult, adult]         adult            adult                   True
# 75    069A                                    [senior, adult]         adult            adult                   True
# 74    068A  [adult, adult, adult, adult, senior, adult, ad...         adult            adult                   True
# 73    067A  [adult, adult, adult, adult, kitten, adult, ad...         adult            adult                   True
# 72    066A                                    [adult, kitten]         adult            adult                   True
# 71    065A  [adult, adult, adult, kitten, adult, adult, ki...         adult            adult                   True
# 70    064A                             [kitten, adult, adult]         adult            adult                   True
# 68    062A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 62    056A                            [senior, senior, adult]        senior           senior                   True
# 78    072A  [adult, kitten, adult, adult, adult, kitten, k...         adult            adult                   True
# 60    054A                                   [senior, senior]        senior           senior                   True
# 59    053A  [adult, senior, adult, adult, adult, adult, ad...         adult            adult                   True
# 58    052A                      [adult, adult, adult, senior]         adult            adult                   True
# 1     001A  [adult, adult, adult, senior, senior, senior, ...         adult            adult                   True
# 53    048A                                           [kitten]        kitten           kitten                   True
# 51    045A  [kitten, adult, kitten, kitten, kitten, kitten...        kitten           kitten                   True
# 50    044A  [kitten, adult, adult, kitten, kitten, kitten,...        kitten           kitten                   True
# 49    043A                                           [kitten]        kitten           kitten                   True
# 77    071A  [adult, adult, adult, adult, adult, adult, sen...         adult            adult                   True
# 79    073A                                            [adult]         adult            adult                   True
# 45    039A  [senior, senior, adult, adult, adult, senior, ...         adult            adult                   True
# 94    099A  [adult, adult, adult, kitten, adult, adult, ad...         adult            adult                   True
# 107   115A                                           [kitten]        kitten           kitten                   True
# 106   113A                           [senior, senior, senior]        senior           senior                   True
# 105   111A  [kitten, kitten, kitten, kitten, kitten, kitte...        kitten           kitten                   True
# 104   110A                                           [kitten]        kitten           kitten                   True
# 100   105A                      [adult, adult, adult, kitten]         adult            adult                   True
# 98    103A  [adult, adult, kitten, adult, senior, kitten, ...         adult            adult                   True
# 97    102A                                     [adult, adult]         adult            adult                   True
# 95    100A                                            [adult]         adult            adult                   True
# 93    097B  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 80    074A  [kitten, adult, adult, adult, adult, adult, ad...         adult            adult                   True
# 91    096A                                            [adult]         adult            adult                   True
# 90    095A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 89    094A  [adult, senior, adult, senior, senior, senior,...        senior           senior                   True
# 87    092A                                            [adult]         adult            adult                   True
# 86    091A                                            [adult]         adult            adult                   True
# 84    088A                                            [adult]         adult            adult                   True
# 83    087A                                     [adult, adult]         adult            adult                   True
# 81    075A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 46    040A  [kitten, adult, adult, kitten, kitten, adult, ...        kitten           kitten                   True
# 55    050A  [kitten, kitten, kitten, adult, adult, kitten,...        kitten           kitten                   True
# 23    021A        [adult, adult, adult, adult, adult, kitten]         adult            adult                   True
# 7     006A                             [adult, kitten, adult]         adult            adult                   True
# 8     007A         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 31    026A                      [senior, adult, adult, adult]         adult            adult                   True
# 9     008A        [adult, kitten, adult, adult, adult, adult]         adult            adult                   True
# 30    025C        [adult, adult, adult, kitten, adult, adult]         adult            adult                   True
# 29    025B                                    [senior, adult]         adult            adult                   True
# 28    025A  [adult, adult, senior, adult, adult, senior, a...         adult            adult                   True
# 10    009A                      [adult, adult, senior, adult]         adult            adult                   True
# 26    023B               [adult, adult, adult, adult, senior]         adult            adult                   True
# 25    023A       [adult, kitten, senior, adult, adult, adult]         adult            adult                   True
# 11    010A  [adult, adult, adult, adult, adult, adult, sen...         adult            adult                   True
# 43    037A      [kitten, adult, senior, adult, adult, senior]         adult            adult                   True
# 22    020A  [senior, adult, adult, adult, adult, adult, ki...         adult            adult                   True
# 20    019A  [adult, adult, kitten, kitten, adult, adult, k...         adult            adult                   True
# 19    018A                                     [adult, adult]         adult            adult                   True
# 13    012A               [adult, adult, adult, adult, kitten]         adult            adult                   True
# 17    015A  [adult, adult, adult, adult, adult, adult, sen...         adult            adult                   True
# 14    013B  [adult, kitten, adult, adult, kitten, senior, ...         adult            adult                   True
# 15    014A                             [kitten, adult, adult]         adult            adult                   True
# 32    026B                                            [adult]         adult            adult                   True
# 38    032A                                     [adult, adult]         adult            adult                   True
# 40    034A               [adult, adult, kitten, adult, adult]         adult            adult                   True
# 2     002A  [adult, kitten, adult, adult, adult, adult, se...         adult            adult                   True
# 34    027A  [adult, kitten, senior, adult, adult, adult, a...         adult            adult                   True
# 35    028A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 36    029A  [adult, adult, senior, adult, adult, adult, ad...         adult            adult                   True
# 3     002B  [adult, adult, adult, senior, senior, adult, a...         adult            adult                   True
# 37    031A  [adult, adult, adult, adult, kitten, adult, se...         adult            adult                   True
# 5     004A                                            [adult]         adult            adult                   True
# 6     005A  [adult, adult, adult, adult, adult, adult, sen...         adult            adult                   True
# 4     003A                      [adult, kitten, adult, adult]         adult            adult                   True
# 39    033A  [adult, adult, adult, adult, adult, senior, ad...         adult            adult                   True
# 41    035A                     [adult, senior, senior, adult]         adult            adult                   True
# 108   116A  [adult, senior, adult, adult, senior, senior, ...         adult           senior                  False
# 12    011A                             [senior, adult, adult]         adult           senior                  False
# 99    104A                     [senior, adult, adult, senior]         adult           senior                  False
# 92    097A  [adult, senior, senior, adult, adult, adult, a...         adult           senior                  False
# 103   109A        [adult, adult, kitten, adult, adult, adult]         adult           kitten                  False
# 102   108A        [adult, adult, adult, senior, adult, adult]         adult           senior                  False
# 101   106A  [adult, adult, adult, adult, adult, adult, sen...         adult           senior                  False
# 96    101A  [adult, senior, adult, adult, kitten, senior, ...        senior            adult                  False
# 88    093A                                     [adult, adult]         adult           senior                  False
# 44    038A                                   [kitten, kitten]        kitten            adult                  False
# 16    014B  [adult, adult, senior, senior, senior, kitten,...         adult           kitten                  False
# 85    090A                                            [adult]         adult           senior                  False
# 42    036A  [senior, senior, adult, adult, adult, senior, ...        senior            adult                  False
# 47    041A                                            [adult]         adult           kitten                  False
# 48    042A  [adult, adult, adult, adult, adult, kitten, ki...         adult           kitten                  False
# 52    047A  [adult, adult, kitten, adult, adult, kitten, a...         adult           kitten                  False
# 54    049A                                            [adult]         adult           kitten                  False
# 56    051A  [adult, senior, adult, senior, senior, adult, ...         adult           senior                  False
# 57    051B  [adult, adult, adult, adult, adult, adult, adu...         adult           senior                  False
# 61    055A  [adult, adult, adult, senior, adult, adult, ad...         adult           senior                  False
# 33    026C                                           [kitten]        kitten            adult                  False
# 63    057A  [adult, adult, adult, adult, adult, senior, ad...         adult           senior                  False
# 64    058A                             [adult, adult, senior]         adult           senior                  False
# 66    060A                           [kitten, kitten, kitten]        kitten            adult                  False
# 67    061A                                     [adult, adult]         adult           senior                  False
# 69    063A  [kitten, senior, kitten, kitten, kitten, adult...        kitten            adult                  False
# 27    024A                                            [adult]         adult           senior                  False
# 24    022A  [adult, kitten, kitten, kitten, kitten, kitten...        kitten            adult                  False
# 21    019B                                           [senior]        senior            adult                  False
# 82    076A                                           [kitten]        kitten            adult                  False
# 18    016A  [adult, adult, adult, adult, adult, adult, adu...         adult           senior                  False
# 109   117A  [senior, adult, senior, adult, senior, adult, ...         adult           senior                  False

# %%
# Create df for majority votes
majority_df = majority_votes.reset_index()
majority_df.columns = ['cat_id', 'Majority_Vote']

# Get actual groups for each cat_id
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first().reset_index()

# Merge majority votes with actual groups
majority_with_actual = pd.merge(majority_df, actual_groups, on='cat_id')

# Add a column to check if the majority vote was correct
majority_with_actual['Majority_Correct'] = majority_with_actual['Majority_Vote'] == majority_with_actual['actual_age_group']

# Count correct majority votes per class
correct_majority_votes_per_class = majority_with_actual.groupby('actual_age_group')['Majority_Correct'].sum()

print("Correct Majority Votes per Class:")
print(correct_majority_votes_per_class)
# Out:
# Correct Majority Votes per Class:
# actual_age_group
# adult     64
# kitten     9
# senior     5
# Name: Majority_Correct, dtype: int64

# %%
# Calculate the total count and the number of correct predictions for each class
class_stats = majority_with_actual.groupby('actual_age_group').agg(
    total_count=('Majority_Correct', 'size'),  # Total number of cases per class
    correct_count=('Majority_Correct', 'sum')  # Sum of correct predictions per class
).reset_index()

# Calculate accuracy for each class
class_stats['accuracy'] = class_stats['correct_count'] / class_stats['total_count'] * 100

# store for final evaluation 
all_majority_vote_details.append(class_stats)

# Log detailed stats
print("Detailed Class Statistics for Majority Votes:")
print(class_stats)
# Out:
# Detailed Class Statistics for Majority Votes:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult           73             64  87.671233
# 1           kitten           15              9  60.000000
# 2           senior           22              5  22.727273

# %%
# Plot for Detailed Class Statistics for Majority Votes
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Accuracy of Majority Votes by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Detailed Class Statistics

# %%
# Calculate the total count and the number of correct predictions for each class
class_stats = full_results.groupby('actual_age_group').agg(
    total_count=('correct', 'size'),
    correct_count=('correct', 'sum')
).reset_index()

# Calculate accuracy for each class
class_stats['accuracy'] = class_stats['correct_count'] / class_stats['total_count'] * 100

# store for final evaluation 
all_class_stats.append(class_stats)

# Log the detailed stats
print("Detailed Class Statistics:")
print(class_stats)
# Out:
# Detailed Class Statistics:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult          584            443  75.856164
# 1           kitten          115             57  49.565217
# 2           senior          186             69  37.096774

# %%
# Plot for Detailed Class Statistics (Overall)
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Overall Accuracy by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Gender Exploration

# %%
# Group by gender and calculate the total count, correct predictions, and accuracy
gender_stats = full_results.groupby('all_gender').agg(
    count=('cat_id', 'size'),  # Total number of cases per gender
    correct=('correct', 'sum')  # Sum of correct predictions per gender
).reset_index()

# Calculate accuracy for each gender
gender_stats['accuracy'] = (gender_stats['correct'] / gender_stats['count'] * 100).round(2)

# Display the DataFrame
print("Accuracy by Gender:")
print(gender_stats)

# store for final evaluation 
all_gender_stats.append(gender_stats)
# Out:
# Accuracy by Gender:
#   all_gender  count  correct  accuracy
# 0          F    218      131     60.09
# 1          M    373      279     74.80
# 2          X    294      159     54.08

# %%
# Plot for Accuracy by Gender
styled_barplot(gender_stats, 'all_gender', 'accuracy', 
               'Accuracy by Gender', 
               'Gender', 'Accuracy (%)')

# %% [markdown]
# ### Log current total CV Stats

# %%
print("Total Majority Vote Accuracy so far:", all_majority_vote_accuracies)
print("Total Class Statistics so far:\n", all_class_stats)
print("Total Gender Accuracy so far:\n", all_gender_stats)
# Out:
# Total Majority Vote Accuracy so far: [0.7454545454545455, 0.7363636363636363, 0.7727272727272727, 0.7090909090909091]
# Total Class Statistics so far:
#  [  actual_age_group  total_count  correct_count   accuracy
# 0            adult          573            444  77.486911
# 1           kitten          111             64  57.657658
# 2           senior          186             59  31.720430,   actual_age_group  total_count  correct_count   accuracy
# 0            adult          568            404  71.126761
# 1           kitten          120             56  46.666667
# 2           senior          186             60  32.258065,   actual_age_group  total_count  correct_count   accuracy
# 0            adult          574            436  75.958188
# 1           kitten          117             62  52.991453
# 2           senior          186             58  31.182796,   actual_age_group  total_count  correct_count   accuracy
# 0            adult          584            443  75.856164
# 1           kitten          115             57  49.565217
# 2           senior          186             69  37.096774]
# Total Gender Accuracy so far:
#  [  all_gender  count  correct  accuracy
# 0          F    218      128     58.72
# 1          M    362      263     72.65
# 2          X    290      176     60.69,   all_gender  count  correct  accuracy
# 0          F    218      119     54.59
# 1          M    357      246     68.91
# 2          X    299      155     51.84,   all_gender  count  correct  accuracy
# 0          F    225      136     60.44
# 1          M    356      260     73.03
# 2          X    296      160     54.05,   all_gender  count  correct  accuracy
# 0          F    218      131     60.09
# 1          M    373      279     74.80
# 2          X    294      159     54.08]

# %% [markdown]
# # RANDOM SEED 5

# %%
# Set a fixed random seed for reproducibility
random.seed(int(random_seeds[4]))
np.random.seed(int(random_seeds[4]))
tf.random.set_seed(int(random_seeds[4]))

# Load datasets
dataframe = pd.read_csv('/Users/astrid/PycharmProjects/data-aug-and-more/yamnet-tfhub-extraction/yamnet_embeddings_looped_april_23.csv')

def assign_age_group(age, age_groups):
    for group_name, age_range in age_groups.items():
        if age_range[0] <= age < age_range[1]:
            return group_name
    return 'Unknown'  # For any age that doesn't fit the defined groups

# Define age groups
age_groups = {
    'kitten': (0, 0.5),
    'adult': (0.5, 12),
    'senior': (12, 20)
}

# Create a new column for the age group
dataframe['age_group'] = dataframe['target'].apply(assign_age_group, age_groups=age_groups)

print(dataframe['age_group'].value_counts())
# Out:
# adult     606
# senior    186
# kitten    176
# Name: age_group, dtype: int64

# %%
# Separate features and labels
X = dataframe.iloc[:, :-4].values  # all columns except the last four

# Encode the 'age_group' column as integers using LabelEncoder
label_encoder = LabelEncoder()
encoded_y = label_encoder.fit_transform(dataframe['age_group'].values)

# Use the encoded labels for splitting and one-hot encoding
y = encoded_y  

# Convert 'cat_id' column to numpy array to be used as groups array for GroupKFold
groups = dataframe['cat_id'].values

# %%
tf.keras.backend.clear_session()

# %% [markdown]
# ## Run Setup

# %%
all_cat_ids = []
all_predicted_age_groups = []
all_actual_age_groups = []
all_gender = []

# Define the StratifiedGroupKFold splitter for 4 fold CV with random shuffling
outer_cv = StratifiedGroupKFold(n_splits=4, shuffle=True, random_state=int(random_seeds[4]))

# unseen test set metrics
unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1 = [], [], [], [], []

outer_fold = 0

# Use the splitter to generate indices for training and testing sets
# Note: GroupShuffleSplit.split returns indices, so we use it to index the arrays
for train_val_idx, test_idx in outer_cv.split(X, y, groups):
    outer_fold += 1
    logger(f"outer_fold {outer_fold}", file=log_file_path)

    # Convert indices back to DataFrame for easy manipulation
    df_train_val = dataframe.iloc[train_val_idx]
    df_test = dataframe.iloc[test_idx]

    ##############################
    # ASSESSING SPLITS BY CAT_ID #
    ##############################
    
    # Get the distribution of groups
    training_validation_group_distribution = df_train_val['cat_id'].value_counts()  
    testing_group_distribution = df_test['cat_id'].value_counts()  
    
    # Log or print the distribution
    logger(f"Train Set Group Distribution:\n{training_validation_group_distribution}", file=log_file_path)
    logger(f"Testing Set Group Distribution:\n{testing_group_distribution}", file=log_file_path)

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val['gender'].value_counts()
    testing_gender_distribution = df_test['gender'].value_counts()
    
    # Log the distribution
    logger(f"Training Set Gender Distribution BEFORE SWAP:\n{training_gender_distribution}", file=log_file_path)
    logger(f"Testing Set Gender Distribution BEFORE SWAP:\n{testing_gender_distribution}", file=log_file_path)

    # Group by 'age_group' and then list unique 'cat_id' within each age group
    unique_cat_ids_per_age_group_train_val = df_train_val.groupby('age_group')['cat_id'].unique()
    unique_cat_ids_per_age_group_test = df_test.groupby('age_group')['cat_id'].unique()
    
    # Log results
    logger(f"Unique Cat IDs per Age Group in Training/Validation Set:\n{unique_cat_ids_per_age_group_train_val}", file=log_file_path)
    logger(f"Unique Cat IDs per Age Group in Testing Set:\n{unique_cat_ids_per_age_group_test}", file=log_file_path)

    # Calculate the count of unique identifiers per age group for training and testing set
    counts_train_val = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_train_val.items()}
    counts_test = {age_group: len(identifiers) for age_group, identifiers in unique_cat_ids_per_age_group_test.items()}

    # Log the counts of unique identifiers per age group
    logger(f"Count of Unique Cat IDs per Age Group in Training/Validation Set:\n{counts_train_val}", file=log_file_path)
    logger(f"Count of Unique Cat IDs per Age Group in Testing Set:\n{counts_test}", file=log_file_path)

    #######################################################
    # CONTINUE WITH ENSURING VALID AND APPROPRIATE SPLITS #
    #######################################################
    
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    groups_train_val, groups_test = groups[train_val_idx], groups[test_idx]

    # logging identifier splits 
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)

    # check group splits
    check_initial_group_split(groups_train_val, groups_test)

    # Specify the cat_ids that must be in the training/validation set
    specific_cat_ids = ['000A', '046A']
    
    # Perform the swapping operation
    train_val_idx, test_idx = swap_cat_id_instances(dataframe, train_val_idx, test_idx, specific_cat_ids)
    
    # Re-assign the sets based on the updated indices
    X_train_val, X_test = X[train_val_idx], X[test_idx]
    y_train_val, y_test = y[train_val_idx], y[test_idx]
    new_groups_train_val, new_groups_test = groups[train_val_idx], groups[test_idx]

    # Find differences for training and test sets
    moved_to_train_val, removed_from_train_val = find_group_differences(groups_train_val, new_groups_train_val)
    moved_to_test, removed_from_test = find_group_differences(groups_test, new_groups_test)
    
    # Display the results
    logger(f"Moved to Training/Validation Set:\n{moved_to_train_val}", file=log_file_path)
    logger(f"Removed from Training/Validation Set:\n{removed_from_train_val}", file=log_file_path)
    logger(f"Moved to Test Set:\n{moved_to_test}", file=log_file_path)
    logger(f"Removed from Test Set\n{removed_from_test}", file=log_file_path)

    # Update X_train_val, X_test, y_train_val, y_test, groups_train_val, groups_test based on updated indices
    X_train_val = X[train_val_idx]
    y_train_val = y[train_val_idx]
    groups_train_val = groups[train_val_idx]
    
    X_test = X[test_idx]
    y_test = y[test_idx]
    groups_test = groups[test_idx]

    # logging identifier splits again after potential swaps
    unique_train_val_groups = np.unique(groups_train_val)
    unique_test_groups = np.unique(groups_test)
    
    logger(f"AFTER SWAP - Unique Training/Validation Group IDs:\n{unique_train_val_groups}", file=log_file_path)
    logger(f"AFTER SWAP - Unique Test Group IDs:\n{unique_test_groups}", file=log_file_path)
    
    # Verify the lengths are consistent
    logger(f"Length of X_train_val:\n{len(X_train_val)}", file=log_file_path)
    logger(f"Length of y_train_val:\n{len(y_train_val)}", file=log_file_path)
    logger(f"Length of groups_train_val:\n{len(groups_train_val)}", file=log_file_path)

    # Check group splits once more
    check_initial_group_split(groups_train_val, groups_test)

    # Convert the modified indices back to a DataFrame representing the updated df_train_val
    df_train_val_updated = dataframe.iloc[train_val_idx].copy()
    df_test_updated = dataframe.iloc[test_idx].copy()

    ############################
    # LOGGING AGE GROUP SPLITS #
    ############################

    # Get the distribution of age groups of age groups before the update
    training_validation_age_group_distribution = df_train_val['age_group'].value_counts()
    testing_age_group_distribution = df_test['age_group'].value_counts()
    
    # Logthe distribution
    logger(f"Train Age Group Distribution BEFORE SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution BEFORE SWAP:\n{testing_age_group_distribution}", file=log_file_path)

    # Get the distribution of age groups after the update
    training_validation_age_group_distribution = df_train_val_updated['age_group'].value_counts()
    testing_age_group_distribution = df_test_updated['age_group'].value_counts()
    
    # Log the distribution
    logger(f"Train Age Group Distribution AFTER SWAP:\n{training_validation_age_group_distribution}", file=log_file_path)
    logger(f"Testing Set Age Group Distribution AFTER SWAP:\n{testing_age_group_distribution}", file=log_file_path)
    
    ########################################################
    # TRACKING FINAL CAT_IDs & GENDER AFTER REDISTRIBUTION #
    ########################################################

    # Get the distribution of groups
    training_validation_group_distribution = df_train_val_updated['cat_id'].value_counts()  
    testing_group_distribution = df_test_updated['cat_id'].value_counts()  

    # Log gender distribution in training and testing datasets
    training_gender_distribution = df_train_val_updated['gender'].value_counts()
    testing_gender_distribution = df_test_updated['gender'].value_counts()
    
    logger(f"\n Starting training on unseen test set\n", file=log_file_path)

    ###################
    # PREPARING MODEL #
    ###################

    # Calculate the distribution of age groups in y_train_val
    age_group_distribution = Counter(y_train_val)
    print("Age group distribution:", age_group_distribution)

    # EarlyStopping callback: monitor 'loss' instead of 'val_loss' for the test set
    early_stopping = EarlyStopping(
        monitor='loss',  
        min_delta=0.001, 
        patience=30,  
        verbose=1,  
        restore_best_weights=True  
    )

    # One final shuffle to ensure randomness
    outer_shuffle_idx = np.random.permutation(len(X_train_val))
    X_train_val = X_train_val[outer_shuffle_idx]
    y_train_val = y_train_val[outer_shuffle_idx]
    
    # Scale the features
    scaler_full = StandardScaler().fit(X_train_val)
    X_train_full_scaled = scaler_full.transform(X_train_val)
    X_test_scaled = scaler_full.transform(X_test)
    
    # Encode the labels
    y_train_full_encoded = to_categorical(y_train_val)
    y_test_encoded = to_categorical(y_test)

    #######################
    # BUILD & TRAIN MODEL #
    #######################

    optimizers = {
        'Adam': Adam(learning_rate=0.00013808925801643654)
    }
    
    # Model definition with dynamic number of layers
    model_full = Sequential()
    model_full.add(Dense(512, activation='relu', input_shape=(X_train_full_scaled.shape[1],)))
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.19804187627143222))  
    model_full.add(Dense(512, activation='relu',)) 
    model_full.add(BatchNormalization())
    model_full.add(Dropout(0.24412907103758918))  
    model_full.add(Dense(3, activation='softmax'))  
    
    # Use the optimizer from the parameters
    optimizer = optimizers['Adam']  # optimizer_key from parameters
    
    # Compile the model
    model_full.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    
    # Train the model on the full training set
    history_full = model_full.fit(X_train_full_scaled, y_train_full_encoded, epochs=1500, batch_size=32,
                                  verbose=1, callbacks=[early_stopping])
    
    # Evaluate the model on the held-out test set
    test_loss, test_accuracy = model_full.evaluate(X_test_scaled, y_test_encoded)

    y_test_pred_prob = model_full.predict(X_test_scaled)
    y_test_pred = np.argmax(y_test_pred_prob, axis=1)  
    y_test_true = np.argmax(y_test_encoded, axis=1)    

    ################################
    # LOG MAJORITY VOTE PER CAT_ID #
    ################################

    # Convert numeric predictions back to age group labels
    predicted_age_groups = label_encoder.inverse_transform(y_test_pred)
    actual_labels = label_encoder.inverse_transform(y_test_true)
    
    # Map predictions and actual labels back to cat_ids
    test_results = pd.DataFrame({
        'cat_id': df_test_updated['cat_id'],
        'predicted_age_group': predicted_age_groups,
        'actual_age_group': actual_labels
    })
    
    # Group by cat_id and aggregate predicted age groups
    majority_votes = test_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
    actual_groups = test_results.groupby('cat_id')['actual_age_group'].first()
    
    # Calculate the accuracy of majority voting
    correct_predictions = (majority_votes == actual_groups).sum()
    total_cats = len(actual_groups)
    majority_vote_accuracy = correct_predictions / total_cats
    
    # Log the accuracy of the majority voting
    logger(f"Majority Vote Accuracy for cat_id for this fold: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

    ####################################################
    # COLLECT PREDICTIONS FOR GENDER & CAT_ID ANALYSIS #
    ####################################################

    # Debugging print statements
    print(f'Before appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Extend lists with current fold results
    all_cat_ids.extend(df_test_updated['cat_id'].tolist())
    all_predicted_age_groups.extend(predicted_age_groups)
    all_actual_age_groups.extend(actual_labels)
    all_gender.extend(df_test_updated['gender'].tolist())

    # Debugging print statements
    print(f'After appending - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
    
    # Calculate additional metrics
    test_precision = precision_score(y_test_true, y_test_pred, average='macro')  # Use 'macro' for imbalanced datasets
    test_recall = recall_score(y_test_true, y_test_pred, average='macro')
    test_f1 = f1_score(y_test_true, y_test_pred, average='macro')

    # prepare averages of outer metrics
    unseen_f1.append(test_f1)
    unseen_losses.append(test_loss)
    unseen_accuracies.append(test_accuracy)
    unseen_precisions.append(test_precision)
    unseen_recalls.append(test_recall)

    # Print final test results
    logger(f"Final Test Results - Loss: {test_loss}, Accuracy: {test_accuracy}, Precision: {test_precision}, Recall: {test_recall}, F1 Score: {test_f1}", file=log_file_path)

    # Generate the confusion matrix
    cm = confusion_matrix(y_test, y_test_pred)
    logger(f"Confusion Matrix:\n {cm}", file=log_file_path)

# Calculate the overall average metrics
unseen_set_avg_f1 = np.mean(unseen_f1)
unseen_set_avg_loss = np.mean(unseen_losses)
unseen_set_avg_acc = np.mean(unseen_accuracies)
unseen_set_avg_precision = np.mean(unseen_precisions)
unseen_set_avg_recall = np.mean(unseen_recalls)

logger(f"\nFinal Average F1-Score across all UNSEEN TEST sets: {unseen_set_avg_f1}", file=log_file_path)
logger(f"\nFinal Average Loss across all UNSEEN TEST sets: {unseen_set_avg_loss}", file=log_file_path)
logger(f"\nFinal Average Accuracy across all UNSEEN TEST sets: {unseen_set_avg_acc}", file=log_file_path)
logger(f"\nFinal Average Precision across all UNSEEN TEST sets: {unseen_set_avg_precision}", file=log_file_path)
logger(f"\nFinal Average Recall across all UNSEEN TEST sets: {unseen_set_avg_recall}\n", file=log_file_path)

# Append averages to total lists
all_f1.append(unseen_set_avg_f1)
all_losses.append(unseen_set_avg_loss)
all_accuracies.append(unseen_set_avg_acc)
all_precisions.append(unseen_set_avg_precision)
all_recalls.append(unseen_set_avg_recall)
# Out:
# outer_fold 1
# Train Set Group Distribution:
# 046A    66
# 000A    39
# 002B    36
# 057A    28
# 074A    25
# 020A    23
# 067A    20
# 055A    20
# 059A    18
# 029A    17
# 019A    17
# 101A    16
# 106A    15
# 001A    15
# 097B    14
# 028A    14
# 042A    14
# 111A    13
# 051A    12
# 116A    12
# 039A    12
# 016A    11
# 005A    11
# 063A    11
# 025A    11
# 036A    11
# 068A    11
# 071A    10
# 015A    10
# 040A    10
# 014B    10
# 033A     9
# 022A     9
# 065A     9
# 045A     9
# 051B     9
# 094A     8
# 010A     8
# 013B     8
# 095A     8
# 053A     7
# 099A     7
# 027A     7
# 117A     7
# 007A     6
# 108A     6
# 021A     6
# 023A     6
# 109A     6
# 037A     6
# 075A     5
# 012A     5
# 023B     5
# 044A     5
# 062A     5
# 052A     4
# 009A     4
# 035A     4
# 104A     4
# 003A     4
# 026A     4
# 060A     3
# 064A     3
# 014A     3
# 058A     3
# 018A     2
# 069A     2
# 038A     2
# 054A     2
# 093A     2
# 061A     2
# 087A     2
# 066A     2
# 025B     2
# 019B     1
# 041A     1
# 115A     1
# 026C     1
# 073A     1
# 088A     1
# 043A     1
# 048A     1
# 092A     1
# 024A     1
# 090A     1
# 110A     1
# 100A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 103A    33
# 047A    30
# 000B    20
# 097A    16
# 002A    13
# 072A     9
# 050A     7
# 031A     7
# 008A     6
# 025C     6
# 034A     5
# 070A     5
# 105A     4
# 113A     3
# 006A     3
# 011A     3
# 056A     3
# 102A     2
# 032A     2
# 091A     1
# 076A     1
# 004A     1
# 096A     1
# 049A     1
# 026B     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# M    299
# X    281
# F    205
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# X    74
# M    57
# F    52
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [028A, 033A, 071A, 020A, 000A, 015A, 026A, 065...
# kitten    [046A, 042A, 014B, 110A, 109A, 040A, 045A, 048...
# senior    [117A, 106A, 057A, 090A, 051B, 116A, 051A, 024...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [002A, 070A, 000B, 105A, 034A, 072A, 006A, 091...
# kitten                                   [047A, 049A, 050A]
# senior                             [113A, 097A, 011A, 056A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 56, 'kitten': 13, 'senior': 18}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 18, 'kitten': 3, 'senior': 4}
# Unique Training/Validation Group IDs:
# ['000A' '001A' '002B' '003A' '005A' '007A' '009A' '010A' '012A' '013B'
#  '014A' '014B' '015A' '016A' '018A' '019A' '019B' '020A' '021A' '022A'
#  '023A' '023B' '024A' '025A' '025B' '026A' '026C' '027A' '028A' '029A'
#  '033A' '035A' '036A' '037A' '038A' '039A' '040A' '041A' '042A' '043A'
#  '044A' '045A' '046A' '048A' '051A' '051B' '052A' '053A' '054A' '055A'
#  '057A' '058A' '059A' '060A' '061A' '062A' '063A' '064A' '065A' '066A'
#  '067A' '068A' '069A' '071A' '073A' '074A' '075A' '087A' '088A' '090A'
#  '092A' '093A' '094A' '095A' '097B' '099A' '100A' '101A' '104A' '106A'
#  '108A' '109A' '110A' '111A' '115A' '116A' '117A']
# Unique Test Group IDs:
# ['000B' '002A' '004A' '006A' '008A' '011A' '025C' '026B' '031A' '032A'
#  '034A' '047A' '049A' '050A' '056A' '070A' '072A' '076A' '091A' '096A'
#  '097A' '102A' '103A' '105A' '113A']
# No common groups found between train and test sets.
# Moved to Training/Validation Set:
# set()
# Removed from Training/Validation Set:
# set()
# Moved to Test Set:
# set()
# Removed from Test Set
# set()
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '001A' '002B' '003A' '005A' '007A' '009A' '010A' '012A' '013B'
#  '014A' '014B' '015A' '016A' '018A' '019A' '019B' '020A' '021A' '022A'
#  '023A' '023B' '024A' '025A' '025B' '026A' '026C' '027A' '028A' '029A'
#  '033A' '035A' '036A' '037A' '038A' '039A' '040A' '041A' '042A' '043A'
#  '044A' '045A' '046A' '048A' '051A' '051B' '052A' '053A' '054A' '055A'
#  '057A' '058A' '059A' '060A' '061A' '062A' '063A' '064A' '065A' '066A'
#  '067A' '068A' '069A' '071A' '073A' '074A' '075A' '087A' '088A' '090A'
#  '092A' '093A' '094A' '095A' '097B' '099A' '100A' '101A' '104A' '106A'
#  '108A' '109A' '110A' '111A' '115A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['000B' '002A' '004A' '006A' '008A' '011A' '025C' '026B' '031A' '032A'
#  '034A' '047A' '049A' '050A' '056A' '070A' '072A' '076A' '091A' '096A'
#  '097A' '102A' '103A' '105A' '113A']
# Length of X_train_val:
# 785
# Length of y_train_val:
# 785
# Length of groups_train_val:
# 785
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     486
# senior    161
# kitten    138
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     120
# kitten     38
# senior     25
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     486
# senior    161
# kitten    138
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     120
# kitten     38
# senior     25
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 486, 2: 161, 1: 138})
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Epoch 1/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.4537 - accuracy: 0.4089
# Epoch 2/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 1.0489 - accuracy: 0.5707
# Epoch 3/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.8268 - accuracy: 0.6369
# Epoch 4/1500
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6655 - accuracy: 0.7261
# Epoch 5/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.6118 - accuracy: 0.7605
# Epoch 6/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.5259 - accuracy: 0.8000
# Epoch 7/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.4510 - accuracy: 0.8204
# Epoch 8/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3947 - accuracy: 0.8535
# Epoch 9/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3864 - accuracy: 0.8662
# Epoch 10/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3320 - accuracy: 0.8904
# Epoch 11/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2915 - accuracy: 0.9019
# Epoch 12/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2571 - accuracy: 0.9096
# Epoch 13/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2165 - accuracy: 0.9312
# Epoch 14/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2354 - accuracy: 0.9134
# Epoch 15/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.1922 - accuracy: 0.9427
# Epoch 16/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.1909 - accuracy: 0.9312
# Epoch 17/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.1706 - accuracy: 0.9503
# Epoch 18/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.1431 - accuracy: 0.9618
# Epoch 19/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.1379 - accuracy: 0.9682
# Epoch 20/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.1173 - accuracy: 0.9682
# Epoch 21/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.1265 - accuracy: 0.9669
# Epoch 22/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.1244 - accuracy: 0.9669
# Epoch 23/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.1000 - accuracy: 0.9809
# Epoch 24/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.1086 - accuracy: 0.9682
# Epoch 25/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0900 - accuracy: 0.9771
# Epoch 26/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0895 - accuracy: 0.9809
# Epoch 27/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0742 - accuracy: 0.9822
# Epoch 28/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0992 - accuracy: 0.9745
# Epoch 29/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0772 - accuracy: 0.9834
# Epoch 30/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0530 - accuracy: 0.9898
# Epoch 31/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0501 - accuracy: 0.9873
# Epoch 32/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0470 - accuracy: 0.9936
# Epoch 33/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0619 - accuracy: 0.9809
# Epoch 34/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0889 - accuracy: 0.9745
# Epoch 35/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0555 - accuracy: 0.9873
# Epoch 36/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0484 - accuracy: 0.9898
# Epoch 37/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0561 - accuracy: 0.9873
# Epoch 38/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0761 - accuracy: 0.9783
# Epoch 39/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0540 - accuracy: 0.9822
# Epoch 40/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0574 - accuracy: 0.9809
# Epoch 41/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0383 - accuracy: 0.9936
# Epoch 42/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0382 - accuracy: 0.9885
# Epoch 43/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0446 - accuracy: 0.9898
# Epoch 44/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0327 - accuracy: 0.9936
# Epoch 45/1500
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0244 - accuracy: 0.9975
# Epoch 46/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0446 - accuracy: 0.9860
# Epoch 47/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0287 - accuracy: 0.9924
# Epoch 48/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0473 - accuracy: 0.9885
# Epoch 49/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0251 - accuracy: 0.9975
# Epoch 50/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0486 - accuracy: 0.9847
# Epoch 51/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0323 - accuracy: 0.9911
# Epoch 52/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0243 - accuracy: 0.9962
# Epoch 53/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0265 - accuracy: 0.9962
# Epoch 54/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0218 - accuracy: 0.9949
# Epoch 55/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0272 - accuracy: 0.9949
# Epoch 56/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0313 - accuracy: 0.9936
# Epoch 57/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0229 - accuracy: 0.9962
# Epoch 58/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0253 - accuracy: 0.9936
# Epoch 59/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0206 - accuracy: 0.9962
# Epoch 60/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0261 - accuracy: 0.9949
# Epoch 61/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0176 - accuracy: 0.9962
# Epoch 62/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0178 - accuracy: 0.9949
# Epoch 63/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0190 - accuracy: 0.9962
# Epoch 64/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0230 - accuracy: 0.9924
# Epoch 65/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0180 - accuracy: 0.9975
# Epoch 66/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0138 - accuracy: 0.9987
# Epoch 67/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0161 - accuracy: 0.9975
# Epoch 68/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0290 - accuracy: 0.9911
# Epoch 69/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0167 - accuracy: 0.9975
# Epoch 70/1500
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0119 - accuracy: 0.9987
# Epoch 71/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0172 - accuracy: 0.9962
# Epoch 72/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0180 - accuracy: 0.9949
# Epoch 73/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0118 - accuracy: 0.9975
# Epoch 74/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0157 - accuracy: 0.9962
# Epoch 75/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0097 - accuracy: 0.9975
# Epoch 76/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0123 - accuracy: 0.9975
# Epoch 77/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0087 - accuracy: 1.0000
# Epoch 78/1500
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0094 - accuracy: 1.0000
# Epoch 79/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0084 - accuracy: 1.0000
# Epoch 80/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0187 - accuracy: 0.9962
# Epoch 81/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0179 - accuracy: 0.9962
# Epoch 82/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0123 - accuracy: 0.9987
# Epoch 83/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0168 - accuracy: 0.9936
# Epoch 84/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0097 - accuracy: 0.9987
# Epoch 85/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0206 - accuracy: 0.9936
# Epoch 86/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0085 - accuracy: 1.0000
# Epoch 87/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0075 - accuracy: 1.0000
# Epoch 88/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0122 - accuracy: 0.9975
# Epoch 89/1500
# 25/25 [==============================] - 0s 5ms/step - loss: 0.0083 - accuracy: 0.9987
# Epoch 90/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0070 - accuracy: 0.9987
# Epoch 91/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0069 - accuracy: 1.0000
# Epoch 92/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0219 - accuracy: 0.9936
# Epoch 93/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0090 - accuracy: 0.9987
# Epoch 94/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0132 - accuracy: 0.9975
# Epoch 95/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0052 - accuracy: 1.0000
# Epoch 96/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0093 - accuracy: 0.9987
# Epoch 97/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0065 - accuracy: 1.0000
# Epoch 98/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0171 - accuracy: 0.9949
# Epoch 99/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0150 - accuracy: 0.9962
# Epoch 100/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0141 - accuracy: 0.9962
# Epoch 101/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0065 - accuracy: 0.9987
# Epoch 102/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0210 - accuracy: 0.9949
# Epoch 103/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0086 - accuracy: 0.9987
# Epoch 104/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0096 - accuracy: 0.9987
# Epoch 105/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0125 - accuracy: 0.9975
# Epoch 106/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0108 - accuracy: 0.9949
# Epoch 107/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0083 - accuracy: 0.9987
# Epoch 108/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0097 - accuracy: 0.9975
# Epoch 109/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0187 - accuracy: 0.9936
# Epoch 110/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0086 - accuracy: 0.9962
# Epoch 111/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0052 - accuracy: 0.9987
# Epoch 112/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0089 - accuracy: 0.9975
# Epoch 113/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 114/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0054 - accuracy: 1.0000
# Epoch 115/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0114 - accuracy: 0.9962
# Epoch 116/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0188 - accuracy: 0.9911
# Epoch 117/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0080 - accuracy: 0.9975
# Epoch 118/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 119/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0071 - accuracy: 0.9987
# Epoch 120/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 121/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 122/1500
# 25/25 [==============================] - 0s 9ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 123/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0038 - accuracy: 0.9987
# Epoch 124/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0067 - accuracy: 0.9987
# Epoch 125/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0040 - accuracy: 1.0000
# Epoch 126/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0066 - accuracy: 0.9987
# Epoch 127/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0045 - accuracy: 0.9987
# Epoch 128/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0063 - accuracy: 0.9975
# Epoch 129/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0071 - accuracy: 0.9987
# Epoch 130/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0132 - accuracy: 0.9975
# Epoch 131/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0075 - accuracy: 0.9987
# Epoch 132/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0075 - accuracy: 0.9962
# Epoch 133/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0034 - accuracy: 0.9987
# Epoch 134/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0089 - accuracy: 0.9962
# Epoch 135/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 136/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0052 - accuracy: 0.9987
# Epoch 137/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 138/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0047 - accuracy: 0.9987
# Epoch 139/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0192 - accuracy: 0.9936
# Epoch 140/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0201 - accuracy: 0.9962
# Epoch 141/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 142/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0090 - accuracy: 0.9975
# Epoch 143/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0116 - accuracy: 0.9962
# Epoch 144/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0070 - accuracy: 0.9987
# Epoch 145/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0047 - accuracy: 1.0000
# Epoch 146/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0092 - accuracy: 0.9975
# Epoch 147/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0099 - accuracy: 0.9975
# Epoch 148/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0068 - accuracy: 0.9987
# Epoch 149/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 150/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 151/1500
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0074 - accuracy: 0.9962
# Epoch 152/1500
# 14/25 [===============>..............] - ETA: 0s - loss: 0.0043 - accuracy: 1.0000Restoring model weights from the end of the best epoch: 122.
# 25/25 [==============================] - 0s 4ms/step - loss: 0.0108 - accuracy: 0.9975
# Epoch 152: early stopping
# 6/6 [==============================] - 0s 1ms/step - loss: 5.3019 - accuracy: 0.6667
# 6/6 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.84 (21/25)
# Before appending - Cat IDs: 0, Predictions: 0, Actuals: 0, Gender: 0
# After appending - Cat IDs: 183, Predictions: 183, Actuals: 183, Gender: 183
# Final Test Results - Loss: 5.301947116851807, Accuracy: 0.6666666865348816, Precision: 0.568896157605835, Recall: 0.5554678362573099, F1 Score: 0.5537438760128133
# Confusion Matrix:
#  [[95  9 16]
#  [18 15  5]
#  [11  2 12]]
# outer_fold 2
# Train Set Group Distribution:
# 046A    66
# 103A    33
# 047A    30
# 074A    25
# 020A    23
# 000B    20
# 067A    20
# 055A    20
# 059A    18
# 101A    16
# 097A    16
# 106A    15
# 097B    14
# 028A    14
# 042A    14
# 002A    13
# 039A    12
# 116A    12
# 051A    12
# 068A    11
# 025A    11
# 016A    11
# 014B    10
# 015A    10
# 071A    10
# 065A     9
# 051B     9
# 022A     9
# 072A     9
# 013B     8
# 095A     8
# 010A     8
# 094A     8
# 117A     7
# 027A     7
# 050A     7
# 031A     7
# 053A     7
# 025C     6
# 037A     6
# 021A     6
# 008A     6
# 034A     5
# 023B     5
# 070A     5
# 044A     5
# 035A     4
# 105A     4
# 026A     4
# 056A     3
# 011A     3
# 014A     3
# 113A     3
# 064A     3
# 060A     3
# 006A     3
# 025B     2
# 061A     2
# 087A     2
# 069A     2
# 032A     2
# 093A     2
# 102A     2
# 041A     1
# 004A     1
# 019B     1
# 076A     1
# 026B     1
# 115A     1
# 026C     1
# 073A     1
# 088A     1
# 096A     1
# 043A     1
# 049A     1
# 024A     1
# 091A     1
# 090A     1
# 110A     1
# 100A     1
# Name: cat_id, dtype: int64
# Testing Set Group Distribution:
# 000A    39
# 002B    36
# 057A    28
# 029A    17
# 019A    17
# 001A    15
# 111A    13
# 036A    11
# 063A    11
# 005A    11
# 040A    10
# 033A     9
# 045A     9
# 099A     7
# 109A     6
# 007A     6
# 023A     6
# 108A     6
# 012A     5
# 075A     5
# 062A     5
# 003A     4
# 009A     4
# 052A     4
# 104A     4
# 058A     3
# 054A     2
# 018A     2
# 066A     2
# 038A     2
# 048A     1
# 092A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    239
# M    237
# F    191
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# M    119
# X    116
# F     66
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [002A, 028A, 070A, 000B, 071A, 020A, 015A, 026...
# kitten    [046A, 042A, 014B, 110A, 047A, 049A, 044A, 043...
# senior    [117A, 106A, 090A, 113A, 051B, 116A, 051A, 024...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [033A, 000A, 038A, 007A, 001A, 018A, 062A, 002...
# kitten                       [109A, 040A, 045A, 048A, 111A]
# senior                       [057A, 058A, 054A, 108A, 104A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 52, 'kitten': 11, 'senior': 17}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 22, 'kitten': 5, 'senior': 5}
# Unique Training/Validation Group IDs:
# ['000B' '002A' '004A' '006A' '008A' '010A' '011A' '013B' '014A' '014B'
#  '015A' '016A' '019B' '020A' '021A' '022A' '023B' '024A' '025A' '025B'
#  '025C' '026A' '026B' '026C' '027A' '028A' '031A' '032A' '034A' '035A'
#  '037A' '039A' '041A' '042A' '043A' '044A' '046A' '047A' '049A' '050A'
#  '051A' '051B' '053A' '055A' '056A' '059A' '060A' '061A' '064A' '065A'
#  '067A' '068A' '069A' '070A' '071A' '072A' '073A' '074A' '076A' '087A'
#  '088A' '090A' '091A' '093A' '094A' '095A' '096A' '097A' '097B' '100A'
#  '101A' '102A' '103A' '105A' '106A' '110A' '113A' '115A' '116A' '117A']
# Unique Test Group IDs:
# ['000A' '001A' '002B' '003A' '005A' '007A' '009A' '012A' '018A' '019A'
#  '023A' '029A' '033A' '036A' '038A' '040A' '045A' '048A' '052A' '054A'
#  '057A' '058A' '062A' '063A' '066A' '075A' '092A' '099A' '104A' '108A'
#  '109A' '111A']
# No common groups found between train and test sets.
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Moved to Training/Validation Set:
# {'000A'}
# Removed from Training/Validation Set:
# {'091A'}
# Moved to Test Set:
# {'091A'}
# Removed from Test Set
# {'000A'}
# AFTER SWAP - Unique Training/Validation Group IDs:
# ['000A' '000B' '002A' '004A' '006A' '008A' '010A' '011A' '013B' '014A'
#  '014B' '015A' '016A' '019B' '020A' '021A' '022A' '023B' '024A' '025A'
#  '025B' '025C' '026A' '026B' '026C' '027A' '028A' '031A' '032A' '034A'
#  '035A' '037A' '039A' '041A' '042A' '043A' '044A' '046A' '047A' '049A'
#  '050A' '051A' '051B' '053A' '055A' '056A' '059A' '060A' '061A' '064A'
#  '065A' '067A' '068A' '069A' '070A' '071A' '072A' '073A' '074A' '076A'
#  '087A' '088A' '090A' '093A' '094A' '095A' '096A' '097A' '097B' '100A'
#  '101A' '102A' '103A' '105A' '106A' '110A' '113A' '115A' '116A' '117A']
# AFTER SWAP - Unique Test Group IDs:
# ['001A' '002B' '003A' '005A' '007A' '009A' '012A' '018A' '019A' '023A'
#  '029A' '033A' '036A' '038A' '040A' '045A' '048A' '052A' '054A' '057A'
#  '058A' '062A' '063A' '066A' '075A' '091A' '092A' '099A' '104A' '108A'
#  '109A' '111A']
# Length of X_train_val:
# 705
# Length of y_train_val:
# 705
# Length of groups_train_val:
# 705
# No common groups found between train and test sets.
# Train Age Group Distribution BEFORE SWAP:
# adult     387
# senior    143
# kitten    137
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     219
# senior     43
# kitten     39
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     425
# senior    143
# kitten    137
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     181
# senior     43
# kitten     39
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 425, 2: 143, 1: 137})
# Epoch 1/1500
# 23/23 [==============================] - 1s 6ms/step - loss: 1.4103 - accuracy: 0.4326
# Epoch 2/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.9471 - accuracy: 0.5957
# Epoch 3/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.7472 - accuracy: 0.7021
# Epoch 4/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.6178 - accuracy: 0.7532
# Epoch 5/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.5745 - accuracy: 0.7872
# Epoch 6/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.4867 - accuracy: 0.8270
# Epoch 7/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4152 - accuracy: 0.8383
# Epoch 8/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3807 - accuracy: 0.8511
# Epoch 9/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3036 - accuracy: 0.8950
# Epoch 10/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.2977 - accuracy: 0.8950
# Epoch 11/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.2885 - accuracy: 0.8936
# Epoch 12/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.2616 - accuracy: 0.9078
# Epoch 13/1500
# 23/23 [==============================] - 0s 10ms/step - loss: 0.2186 - accuracy: 0.9277
# Epoch 14/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.1950 - accuracy: 0.9333
# Epoch 15/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1744 - accuracy: 0.9532
# Epoch 16/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1631 - accuracy: 0.9461
# Epoch 17/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1513 - accuracy: 0.9645
# Epoch 18/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1195 - accuracy: 0.9645
# Epoch 19/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1442 - accuracy: 0.9560
# Epoch 20/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1090 - accuracy: 0.9730
# Epoch 21/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1012 - accuracy: 0.9730
# Epoch 22/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1189 - accuracy: 0.9702
# Epoch 23/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1386 - accuracy: 0.9546
# Epoch 24/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0966 - accuracy: 0.9702
# Epoch 25/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0753 - accuracy: 0.9830
# Epoch 26/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0809 - accuracy: 0.9759
# Epoch 27/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0764 - accuracy: 0.9858
# Epoch 28/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0611 - accuracy: 0.9872
# Epoch 29/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0718 - accuracy: 0.9773
# Epoch 30/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0660 - accuracy: 0.9844
# Epoch 31/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0565 - accuracy: 0.9901
# Epoch 32/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0599 - accuracy: 0.9816
# Epoch 33/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0492 - accuracy: 0.9872
# Epoch 34/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0594 - accuracy: 0.9844
# Epoch 35/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0460 - accuracy: 0.9943
# Epoch 36/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0523 - accuracy: 0.9844
# Epoch 37/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0508 - accuracy: 0.9901
# Epoch 38/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0671 - accuracy: 0.9830
# Epoch 39/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0428 - accuracy: 0.9872
# Epoch 40/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0483 - accuracy: 0.9872
# Epoch 41/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0499 - accuracy: 0.9830
# Epoch 42/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0478 - accuracy: 0.9901
# Epoch 43/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0651 - accuracy: 0.9787
# Epoch 44/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0327 - accuracy: 0.9915
# Epoch 45/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0375 - accuracy: 0.9901
# Epoch 46/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0434 - accuracy: 0.9872
# Epoch 47/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0319 - accuracy: 0.9915
# Epoch 48/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0217 - accuracy: 0.9972
# Epoch 49/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0461 - accuracy: 0.9858
# Epoch 50/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0347 - accuracy: 0.9929
# Epoch 51/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0399 - accuracy: 0.9887
# Epoch 52/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0240 - accuracy: 0.9957
# Epoch 53/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0195 - accuracy: 0.9986
# Epoch 54/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0392 - accuracy: 0.9915
# Epoch 55/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0244 - accuracy: 0.9957
# Epoch 56/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0294 - accuracy: 0.9915
# Epoch 57/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0268 - accuracy: 0.9929
# Epoch 58/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0327 - accuracy: 0.9915
# Epoch 59/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0318 - accuracy: 0.9887
# Epoch 60/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0453 - accuracy: 0.9830
# Epoch 61/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0386 - accuracy: 0.9901
# Epoch 62/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0305 - accuracy: 0.9929
# Epoch 63/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0189 - accuracy: 0.9972
# Epoch 64/1500
# 23/23 [==============================] - 0s 5ms/step - loss: 0.0255 - accuracy: 0.9943
# Epoch 65/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0212 - accuracy: 0.9957
# Epoch 66/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0165 - accuracy: 0.9957
# Epoch 67/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0190 - accuracy: 0.9929
# Epoch 68/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0266 - accuracy: 0.9915
# Epoch 69/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0231 - accuracy: 0.9957
# Epoch 70/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0229 - accuracy: 0.9943
# Epoch 71/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0232 - accuracy: 0.9943
# Epoch 72/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0170 - accuracy: 0.9972
# Epoch 73/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0171 - accuracy: 0.9972
# Epoch 74/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0151 - accuracy: 0.9972
# Epoch 75/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0133 - accuracy: 0.9986
# Epoch 76/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0167 - accuracy: 0.9957
# Epoch 77/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0114 - accuracy: 0.9986
# Epoch 78/1500
# 23/23 [==============================] - 0s 9ms/step - loss: 0.0140 - accuracy: 0.9957
# Epoch 79/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0242 - accuracy: 0.9943
# Epoch 80/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0184 - accuracy: 0.9929
# Epoch 81/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0176 - accuracy: 0.9943
# Epoch 82/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0099 - accuracy: 0.9972
# Epoch 83/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0123 - accuracy: 0.9972
# Epoch 84/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0188 - accuracy: 0.9943
# Epoch 85/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0225 - accuracy: 0.9901
# Epoch 86/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0157 - accuracy: 0.9957
# Epoch 87/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0069 - accuracy: 1.0000
# Epoch 88/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0115 - accuracy: 0.9972
# Epoch 89/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0119 - accuracy: 1.0000
# Epoch 90/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0098 - accuracy: 0.9972
# Epoch 91/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0138 - accuracy: 0.9972
# Epoch 92/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0130 - accuracy: 0.9957
# Epoch 93/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0155 - accuracy: 0.9957
# Epoch 94/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0155 - accuracy: 0.9972
# Epoch 95/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0121 - accuracy: 0.9972
# Epoch 96/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0124 - accuracy: 0.9986
# Epoch 97/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0107 - accuracy: 0.9986
# Epoch 98/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0075 - accuracy: 1.0000
# Epoch 99/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0086 - accuracy: 0.9972
# Epoch 100/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0070 - accuracy: 0.9986
# Epoch 101/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0173 - accuracy: 0.9957
# Epoch 102/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0137 - accuracy: 0.9943
# Epoch 103/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0144 - accuracy: 0.9986
# Epoch 104/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0141 - accuracy: 0.9929
# Epoch 105/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0127 - accuracy: 0.9972
# Epoch 106/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0148 - accuracy: 0.9972
# Epoch 107/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0108 - accuracy: 0.9957
# Epoch 108/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0074 - accuracy: 1.0000
# Epoch 109/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0077 - accuracy: 0.9986
# Epoch 110/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0101 - accuracy: 0.9972
# Epoch 111/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0100 - accuracy: 0.9986
# Epoch 112/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0120 - accuracy: 0.9972
# Epoch 113/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0120 - accuracy: 0.9972
# Epoch 114/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0064 - accuracy: 0.9972
# Epoch 115/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0057 - accuracy: 0.9986
# Epoch 116/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0131 - accuracy: 0.9957
# Epoch 117/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0085 - accuracy: 0.9972
# Epoch 118/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0189 - accuracy: 0.9957
# Epoch 119/1500
# 23/23 [==============================] - 0s 10ms/step - loss: 0.0160 - accuracy: 0.9957
# Epoch 120/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0136 - accuracy: 0.9972
# Epoch 121/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0133 - accuracy: 0.9957
# Epoch 122/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0110 - accuracy: 0.9972
# Epoch 123/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0145 - accuracy: 0.9957
# Epoch 124/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0137 - accuracy: 0.9943
# Epoch 125/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 126/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0041 - accuracy: 1.0000
# Epoch 127/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0092 - accuracy: 0.9986
# Epoch 128/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 129/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0117 - accuracy: 0.9957
# Epoch 130/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 131/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0081 - accuracy: 0.9972
# Epoch 132/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0055 - accuracy: 1.0000
# Epoch 133/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0042 - accuracy: 1.0000
# Epoch 134/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0046 - accuracy: 1.0000
# Epoch 135/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0081 - accuracy: 0.9986
# Epoch 136/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0070 - accuracy: 0.9972
# Epoch 137/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0081 - accuracy: 0.9986
# Epoch 138/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0087 - accuracy: 0.9986
# Epoch 139/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0087 - accuracy: 0.9986
# Epoch 140/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0072 - accuracy: 0.9986
# Epoch 141/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0189 - accuracy: 0.9943
# Epoch 142/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0085 - accuracy: 0.9972
# Epoch 143/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0055 - accuracy: 0.9986
# Epoch 144/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0061 - accuracy: 0.9986
# Epoch 145/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 146/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0053 - accuracy: 0.9986
# Epoch 147/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0095 - accuracy: 0.9972
# Epoch 148/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0051 - accuracy: 1.0000
# Epoch 149/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0082 - accuracy: 0.9957
# Epoch 150/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0090 - accuracy: 0.9972
# Epoch 151/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0259 - accuracy: 0.9887
# Epoch 152/1500
# 23/23 [==============================] - 0s 10ms/step - loss: 0.0082 - accuracy: 0.9972
# Epoch 153/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0167 - accuracy: 0.9957
# Epoch 154/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0220 - accuracy: 0.9901
# Epoch 155/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0116 - accuracy: 0.9986
# Epoch 156/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0158 - accuracy: 0.9943
# Epoch 157/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0215 - accuracy: 0.9901
# Epoch 158/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0067 - accuracy: 1.0000
# Epoch 159/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0136 - accuracy: 0.9957
# Epoch 160/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0065 - accuracy: 0.9986
# Epoch 161/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0062 - accuracy: 0.9986
# Epoch 162/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0063 - accuracy: 0.9972
# Epoch 163/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0077 - accuracy: 0.9972
# Epoch 164/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0128 - accuracy: 0.9957
# Epoch 165/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0071 - accuracy: 0.9972
# Epoch 166/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 167/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0098 - accuracy: 0.9972
# Epoch 168/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0091 - accuracy: 0.9972
# Epoch 169/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0094 - accuracy: 0.9972
# Epoch 170/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0087 - accuracy: 0.9986
# Epoch 171/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0199 - accuracy: 0.9943
# Epoch 172/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0090 - accuracy: 0.9957
# Epoch 173/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0046 - accuracy: 1.0000
# Epoch 174/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0104 - accuracy: 0.9957
# Epoch 175/1500
# 14/23 [=================>............] - ETA: 0s - loss: 0.0117 - accuracy: 0.9955Restoring model weights from the end of the best epoch: 145.
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0178 - accuracy: 0.9929
# Epoch 175: early stopping
# 9/9 [==============================] - 0s 1ms/step - loss: 2.6311 - accuracy: 0.6692
# 9/9 [==============================] - 0s 1ms/step
# Majority Vote Accuracy for cat_id for this fold: 0.81 (26/32)
# Before appending - Cat IDs: 183, Predictions: 183, Actuals: 183, Gender: 183
# After appending - Cat IDs: 446, Predictions: 446, Actuals: 446, Gender: 446
# Final Test Results - Loss: 2.6311123371124268, Accuracy: 0.6692014932632446, Precision: 0.5827080191050779, Recall: 0.6391730387618862, F1 Score: 0.6046246277146107
# Confusion Matrix:
#  [[127  19  35]
#  [  7  32   0]
#  [ 26   0  17]]
# outer_fold 3
# Train Set Group Distribution:
# 046A    66
# 000A    39
# 002B    36
# 103A    33
# 047A    30
# 057A    28
# 020A    23
# 055A    20
# 000B    20
# 059A    18
# 029A    17
# 019A    17
# 097A    16
# 101A    16
# 001A    15
# 042A    14
# 028A    14
# 097B    14
# 111A    13
# 002A    13
# 005A    11
# 068A    11
# 063A    11
# 036A    11
# 071A    10
# 014B    10
# 040A    10
# 015A    10
# 051B     9
# 072A     9
# 033A     9
# 022A     9
# 045A     9
# 013B     8
# 095A     8
# 099A     7
# 117A     7
# 027A     7
# 031A     7
# 050A     7
# 108A     6
# 023A     6
# 008A     6
# 025C     6
# 109A     6
# 007A     6
# 023B     5
# 034A     5
# 012A     5
# 062A     5
# 075A     5
# 070A     5
# 052A     4
# 009A     4
# 104A     4
# 003A     4
# 105A     4
# 056A     3
# 011A     3
# 113A     3
# 006A     3
# 064A     3
# 058A     3
# 102A     2
# 093A     2
# 038A     2
# 069A     2
# 066A     2
# 054A     2
# 018A     2
# 032A     2
# 115A     1
# 041A     1
# 076A     1
# 110A     1
# 004A     1
# 096A     1
# 088A     1
# 091A     1
# 048A     1
# 024A     1
# 092A     1
# 049A     1
# 026C     1
# 026B     1
# Name: cat_id, dtype: int64
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Testing Set Group Distribution:
# 074A    25
# 067A    20
# 106A    15
# 039A    12
# 116A    12
# 051A    12
# 025A    11
# 016A    11
# 065A     9
# 094A     8
# 010A     8
# 053A     7
# 021A     6
# 037A     6
# 044A     5
# 026A     4
# 035A     4
# 060A     3
# 014A     3
# 061A     2
# 087A     2
# 025B     2
# 043A     1
# 073A     1
# 090A     1
# 019B     1
# 100A     1
# Name: cat_id, dtype: int64
# Training Set Gender Distribution BEFORE SWAP:
# X    325
# M    258
# F    193
# Name: gender, dtype: int64
# Testing Set Gender Distribution BEFORE SWAP:
# M    98
# F    64
# X    30
# Name: gender, dtype: int64
# Unique Cat IDs per Age Group in Training/Validation Set:
# age_group
# adult     [002A, 028A, 070A, 033A, 000B, 071A, 020A, 000...
# kitten    [046A, 042A, 014B, 110A, 109A, 040A, 047A, 049...
# senior    [117A, 057A, 113A, 051B, 024A, 097A, 059A, 055...
# Name: cat_id, dtype: object
# Unique Cat IDs per Age Group in Testing Set:
# age_group
# adult     [026A, 065A, 053A, 021A, 010A, 074A, 067A, 025...
# kitten                                         [044A, 043A]
# senior           [106A, 090A, 116A, 051A, 094A, 016A, 061A]
# Name: cat_id, dtype: object
# Count of Unique Cat IDs per Age Group in Training/Validation Set:
# {'adult': 56, 'kitten': 14, 'senior': 15}
# Count of Unique Cat IDs per Age Group in Testing Set:
# {'adult': 18, 'kitten': 2, 'senior': 7}
# Unique Training/Validation Group IDs:
# ['000A' '000B' '001A' '002A' '002B' '003A' '004A' '005A' '006A' '007A'
#  '008A' '009A' '011A' '012A' '013B' '014B' '015A' '018A' '019A' '020A'
#  '022A' '023A' '023B' '024A' '025C' '026B' '026C' '027A' '028A' '029A'
#  '031A' '032A' '033A' '034A' '036A' '038A' '040A' '041A' '042A' '045A'
#  '046A' '047A' '048A' '049A' '050A' '051B' '052A' '054A' '055A' '056A'
#  '057A' '058A' '059A' '062A' '063A' '064A' '066A' '068A' '069A' '070A'
#  '071A' '072A' '075A' '076A' '088A' '091A' '092A' '093A' '095A' '096A'
#  '097A' '097B' '099A' '101A' '102A' '103A' '104A' '105A' '108A' '109A'
# ...
#  '041A' '042A' '051B' '055A' '059A' '064A' '068A' '069A' '071A' '088A'
#  '093A' '095A' '097B' '101A' '110A' '111A' '115A' '117A']
# Length of X_train_val:
# 729
# Length of y_train_val:
# 729
# Length of groups_train_val:
# 729
# No common groups found between train and test sets.
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Train Age Group Distribution BEFORE SWAP:
# adult     464
# senior    129
# kitten     83
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution BEFORE SWAP:
# adult     142
# kitten     93
# senior     57
# Name: age_group, dtype: int64
# Train Age Group Distribution AFTER SWAP:
# adult     464
# kitten    136
# senior    129
# Name: age_group, dtype: int64
# Testing Set Age Group Distribution AFTER SWAP:
# adult     142
# senior     57
# kitten     40
# Name: age_group, dtype: int64
#
#  Starting training on unseen test set
#
# Age group distribution: Counter({0: 464, 1: 136, 2: 129})
# Epoch 1/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 1.5069 - accuracy: 0.4156
# Epoch 2/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 1.0011 - accuracy: 0.5912
# Epoch 3/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.8249 - accuracy: 0.6447
# Epoch 4/1500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.7561 - accuracy: 0.6859
# Epoch 5/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.5970 - accuracy: 0.7599
# Epoch 6/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.5299 - accuracy: 0.7723
# Epoch 7/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4627 - accuracy: 0.8189
# Epoch 8/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4218 - accuracy: 0.8436
# Epoch 9/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3761 - accuracy: 0.8711
# Epoch 10/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3108 - accuracy: 0.8971
# Epoch 11/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3102 - accuracy: 0.8848
# Epoch 12/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.2497 - accuracy: 0.9191
# Epoch 13/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.2500 - accuracy: 0.9136
# Epoch 14/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.2001 - accuracy: 0.9424
# Epoch 15/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1902 - accuracy: 0.9438
# Epoch 16/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1846 - accuracy: 0.9492
# Epoch 17/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1734 - accuracy: 0.9465
# Epoch 18/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1601 - accuracy: 0.9506
# Epoch 19/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1259 - accuracy: 0.9726
# Epoch 20/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1403 - accuracy: 0.9616
# Epoch 21/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1007 - accuracy: 0.9822
# Epoch 22/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1268 - accuracy: 0.9643
# Epoch 23/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0955 - accuracy: 0.9726
# Epoch 24/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.1078 - accuracy: 0.9781
# Epoch 25/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0939 - accuracy: 0.9794
# Epoch 26/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0776 - accuracy: 0.9835
# Epoch 27/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0755 - accuracy: 0.9835
# Epoch 28/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0725 - accuracy: 0.9808
# Epoch 29/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0695 - accuracy: 0.9822
# Epoch 30/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0679 - accuracy: 0.9794
# Epoch 31/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0602 - accuracy: 0.9877
# Epoch 32/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0820 - accuracy: 0.9781
# Epoch 33/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0619 - accuracy: 0.9890
# Epoch 34/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0612 - accuracy: 0.9849
# Epoch 35/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0458 - accuracy: 0.9931
# Epoch 36/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0424 - accuracy: 0.9918
# Epoch 37/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0630 - accuracy: 0.9794
# Epoch 38/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0362 - accuracy: 0.9986
# Epoch 39/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0423 - accuracy: 0.9890
# Epoch 40/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0390 - accuracy: 0.9918
# Epoch 41/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0438 - accuracy: 0.9877
# Epoch 42/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0300 - accuracy: 0.9931
# Epoch 43/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0406 - accuracy: 0.9931
# Epoch 44/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0375 - accuracy: 0.9931
# Epoch 45/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0291 - accuracy: 0.9945
# Epoch 46/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0321 - accuracy: 0.9931
# Epoch 47/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0442 - accuracy: 0.9863
# Epoch 48/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0290 - accuracy: 0.9959
# Epoch 49/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0231 - accuracy: 0.9973
# Epoch 50/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0237 - accuracy: 0.9945
# Epoch 51/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0236 - accuracy: 0.9959
# Epoch 52/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0265 - accuracy: 0.9945
# Epoch 53/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0281 - accuracy: 0.9959
# Epoch 54/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0264 - accuracy: 0.9931
# Epoch 55/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0235 - accuracy: 0.9945
# Epoch 56/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0306 - accuracy: 0.9931
# Epoch 57/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0219 - accuracy: 0.9973
# Epoch 58/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0225 - accuracy: 0.9945
# Epoch 59/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0175 - accuracy: 0.9959
# Epoch 60/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0272 - accuracy: 0.9890
# Epoch 61/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0214 - accuracy: 0.9959
# Epoch 62/1500
# 23/23 [==============================] - 0s 9ms/step - loss: 0.0203 - accuracy: 0.9973
# Epoch 63/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0159 - accuracy: 0.9986
# Epoch 64/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0163 - accuracy: 0.9959
# Epoch 65/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0160 - accuracy: 0.9986
# Epoch 66/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0144 - accuracy: 0.9959
# Epoch 67/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0203 - accuracy: 0.9945
# Epoch 68/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0149 - accuracy: 0.9973
# Epoch 69/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0165 - accuracy: 0.9959
# Epoch 70/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0182 - accuracy: 0.9973
# Epoch 71/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0204 - accuracy: 0.9945
# Epoch 72/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0124 - accuracy: 0.9986
# Epoch 73/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0196 - accuracy: 0.9959
# Epoch 74/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0114 - accuracy: 0.9973
# Epoch 75/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0147 - accuracy: 0.9986
# Epoch 76/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0109 - accuracy: 0.9986
# Epoch 77/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0138 - accuracy: 0.9973
# Epoch 78/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0156 - accuracy: 0.9945
# Epoch 79/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0093 - accuracy: 0.9986
# Epoch 80/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0118 - accuracy: 0.9986
# Epoch 81/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0191 - accuracy: 0.9973
# Epoch 82/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0128 - accuracy: 0.9986
# Epoch 83/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0071 - accuracy: 1.0000
# Epoch 84/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0178 - accuracy: 0.9931
# Epoch 85/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0211 - accuracy: 0.9931
# Epoch 86/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0283 - accuracy: 0.9931
# Epoch 87/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0180 - accuracy: 0.9959
# Epoch 88/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0105 - accuracy: 0.9973
# Epoch 89/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0084 - accuracy: 1.0000
# Epoch 90/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0064 - accuracy: 1.0000
# Epoch 91/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0054 - accuracy: 1.0000
# Epoch 92/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0162 - accuracy: 0.9945
# Epoch 93/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0085 - accuracy: 1.0000
# Epoch 94/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0219 - accuracy: 0.9959
# Epoch 95/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0068 - accuracy: 1.0000
# Epoch 96/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0069 - accuracy: 1.0000
# Epoch 97/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0075 - accuracy: 0.9986
# Epoch 98/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0056 - accuracy: 0.9986
# Epoch 99/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0129 - accuracy: 0.9959
# Epoch 100/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0096 - accuracy: 0.9973
# Epoch 101/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0052 - accuracy: 1.0000
# Epoch 102/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0171 - accuracy: 0.9931
# Epoch 103/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0145 - accuracy: 0.9945
# Epoch 104/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0139 - accuracy: 0.9973
# Epoch 105/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0103 - accuracy: 0.9973
# Epoch 106/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0071 - accuracy: 0.9973
# Epoch 107/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 108/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0053 - accuracy: 1.0000
# Epoch 109/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0082 - accuracy: 0.9986
# Epoch 110/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0080 - accuracy: 0.9986
# Epoch 111/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0109 - accuracy: 0.9973
# Epoch 112/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0047 - accuracy: 0.9986
# Epoch 113/1500
# 23/23 [==============================] - 0s 9ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 114/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0065 - accuracy: 0.9986
# Epoch 115/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0077 - accuracy: 0.9986
# Epoch 116/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 117/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0050 - accuracy: 1.0000
# Epoch 118/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0098 - accuracy: 0.9959
# Epoch 119/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0053 - accuracy: 0.9986
# Epoch 120/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0064 - accuracy: 0.9986
# Epoch 121/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0096 - accuracy: 0.9945
# Epoch 122/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0099 - accuracy: 0.9973
# Epoch 123/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0059 - accuracy: 0.9973
# Epoch 124/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0068 - accuracy: 0.9973
# Epoch 125/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0150 - accuracy: 0.9959
# Epoch 126/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0176 - accuracy: 0.9959
# Epoch 127/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 128/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0098 - accuracy: 0.9959
# Epoch 129/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0051 - accuracy: 0.9986
# Epoch 130/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0145 - accuracy: 0.9945
# Epoch 131/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0100 - accuracy: 0.9959
# Epoch 132/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 133/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0062 - accuracy: 1.0000
# Epoch 134/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0133 - accuracy: 0.9931
# Epoch 135/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0093 - accuracy: 0.9959
# Epoch 136/1500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0077 - accuracy: 0.9986
# Epoch 137/1500
# 14/23 [=================>............] - ETA: 0s - loss: 0.0032 - accuracy: 1.0000Restoring model weights from the end of the best epoch: 107.
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0048 - accuracy: 1.0000
# Epoch 137: early stopping
# 8/8 [==============================] - 0s 1ms/step - loss: 3.1854 - accuracy: 0.6569
# 8/8 [==============================] - 0s 884us/step
# Majority Vote Accuracy for cat_id for this fold: 0.82 (23/28)
# Before appending - Cat IDs: 638, Predictions: 638, Actuals: 638, Gender: 638
# After appending - Cat IDs: 877, Predictions: 877, Actuals: 877, Gender: 877
# Final Test Results - Loss: 3.1853842735290527, Accuracy: 0.6569037437438965, Precision: 0.6210670314637483, Recall: 0.6351803805287868, F1 Score: 0.6276157942969073
# Confusion Matrix:
#  [[100  16  26]
#  [  9  27   4]
#  [ 27   0  30]]
#
# Final Average F1-Score across all UNSEEN TEST sets: 0.5590537246566725
#
# Final Average Loss across all UNSEEN TEST sets: 3.6169967651367188
#
# Final Average Accuracy across all UNSEEN TEST sets: 0.6518388092517853
#
# Final Average Precision across all UNSEEN TEST sets: 0.5606140031855186
#
# Final Average Recall across all UNSEEN TEST sets: 0.6203514887503837

# %%
seed_5_folds_values = (unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1)

# Plotting all fold metrics|
seed_5_folds_plot = plot_all_metrics(unseen_losses, unseen_accuracies, unseen_precisions, unseen_recalls, unseen_f1, "Folds", "Fold Number")

# %% [markdown]
# ## Majority Voting on Total Entries per cat_id

# %%
# Debugging print statements
print(f'Checking - Cat IDs: {len(all_cat_ids)}, Predictions: {len(all_predicted_age_groups)}, Actuals: {len(all_actual_age_groups)}, Gender: {len(all_gender)}')
# Out:
# Checking - Cat IDs: 877, Predictions: 877, Actuals: 877, Gender: 877

# %%
# Create results df
full_results = pd.DataFrame({
    'cat_id': all_cat_ids,
    'predicted_age_group': all_predicted_age_groups,
    'actual_age_group': all_actual_age_groups,
    'all_gender': all_gender
})

# create a correct majority prediction column
full_results['correct'] = full_results['predicted_age_group'] == full_results['actual_age_group']

# %%
# Group by cat_id and aggregate predicted age groups
majority_votes = full_results.groupby('cat_id')['predicted_age_group'].agg(lambda x: x.mode()[0])
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first()

# Calculate the accuracy of majority voting
correct_predictions = (majority_votes == actual_groups).sum()
total_cats = len(actual_groups)
majority_vote_accuracy = correct_predictions / total_cats

logger(f"Overall Majority Vote Accuracy for cat_id: {majority_vote_accuracy:.2f} ({correct_predictions}/{total_cats})", file=log_file_path)

# store for final evaluation 
all_majority_vote_accuracies.append(majority_vote_accuracy)
# Out:
# Overall Majority Vote Accuracy for cat_id: 0.80 (88/110)

# %%
# Detailed df with predictions, actual labels, and comparison including majority vote
detailed_results = full_results.groupby('cat_id').apply(
    lambda x: pd.Series({
        'Predictions': list(x['predicted_age_group']),
        'Majority Vote': x['predicted_age_group'].mode()[0],
        'Actual Age Group': x['actual_age_group'].iloc[0],
        'Correct Majority Vote': x['predicted_age_group'].mode()[0] == x['actual_age_group'].iloc[0]
    })
).reset_index()

# Convert to DataFrame for better formatting and display
detailed_results = pd.DataFrame(detailed_results)

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 10)
pd.set_option('display.width', 1000)

sorted_detailed_results = detailed_results.sort_values(by='Correct Majority Vote', ascending=False)

# Display the sorted DataFrame
sorted_detailed_results
# Out:
#     cat_id                                        Predictions Majority Vote Actual Age Group  Correct Majority Vote
# 0     000B  [adult, adult, senior, adult, adult, adult, se...         adult            adult                   True
# 60    054A                                   [senior, senior]        senior           senior                   True
# 76    070A              [adult, senior, adult, kitten, adult]         adult            adult                   True
# 74    068A  [adult, adult, adult, adult, senior, adult, ad...         adult            adult                   True
# 73    067A  [adult, adult, kitten, adult, adult, adult, ad...         adult            adult                   True
# 72    066A                                    [adult, kitten]         adult            adult                   True
# 71    065A  [adult, adult, adult, kitten, kitten, adult, k...         adult            adult                   True
# 70    064A                             [kitten, adult, adult]         adult            adult                   True
# 68    062A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 66    060A                            [kitten, adult, senior]         adult            adult                   True
# 65    059A  [senior, senior, senior, senior, adult, senior...        senior           senior                   True
# 59    053A  [adult, adult, senior, adult, adult, adult, ad...         adult            adult                   True
# 46    040A  [kitten, adult, adult, kitten, kitten, kitten,...        kitten           kitten                   True
# 58    052A                      [adult, senior, adult, adult]         adult            adult                   True
# 57    051B  [adult, adult, adult, senior, senior, senior, ...        senior           senior                   True
# 1     001A  [adult, adult, adult, senior, senior, adult, a...         adult            adult                   True
# 54    049A                                           [kitten]        kitten           kitten                   True
# 53    048A                                           [kitten]        kitten           kitten                   True
# 51    045A  [kitten, adult, kitten, kitten, kitten, kitten...        kitten           kitten                   True
# 50    044A           [kitten, kitten, kitten, kitten, kitten]        kitten           kitten                   True
# 49    043A                                           [kitten]        kitten           kitten                   True
# 48    042A  [kitten, kitten, kitten, adult, kitten, kitten...        kitten           kitten                   True
# 77    071A  [adult, adult, adult, adult, adult, senior, se...         adult            adult                   True
# 78    072A  [adult, senior, adult, adult, adult, senior, s...         adult            adult                   True
# 79    073A                                            [adult]         adult            adult                   True
# 80    074A  [kitten, adult, adult, adult, adult, adult, ad...         adult            adult                   True
# 107   115A                                           [kitten]        kitten           kitten                   True
# 106   113A                           [senior, senior, senior]        senior           senior                   True
# 105   111A  [kitten, kitten, kitten, kitten, kitten, kitte...        kitten           kitten                   True
# 104   110A                                           [kitten]        kitten           kitten                   True
# 100   105A                     [kitten, adult, adult, kitten]         adult            adult                   True
# 98    103A  [adult, adult, adult, adult, senior, kitten, a...         adult            adult                   True
# 97    102A                                     [adult, adult]         adult            adult                   True
# 96    101A  [senior, senior, adult, adult, adult, adult, s...         adult            adult                   True
# 95    100A                                            [adult]         adult            adult                   True
# 94    099A  [adult, adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 93    097B  [senior, adult, adult, kitten, kitten, adult, ...         adult            adult                   True
# 92    097A  [adult, senior, senior, adult, senior, adult, ...        senior           senior                   True
# 91    096A                                            [adult]         adult            adult                   True
# 90    095A  [adult, adult, senior, senior, adult, adult, s...         adult            adult                   True
# 87    092A                                            [adult]         adult            adult                   True
# 86    091A                                     [adult, adult]         adult            adult                   True
# 84    088A                                            [adult]         adult            adult                   True
# 83    087A                                     [adult, adult]         adult            adult                   True
# 81    075A              [senior, senior, adult, adult, adult]         adult            adult                   True
# 47    041A                                           [kitten]        kitten           kitten                   True
# 55    050A  [kitten, adult, kitten, senior, kitten, kitten...        kitten           kitten                   True
# 45    039A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 28    025A  [adult, adult, adult, adult, adult, senior, ad...         adult            adult                   True
# 25    023A        [adult, kitten, adult, adult, adult, adult]         adult            adult                   True
# 24    022A  [adult, kitten, kitten, kitten, kitten, adult,...         adult            adult                   True
# 44    038A                                    [adult, kitten]         adult            adult                   True
# 22    020A  [kitten, adult, adult, adult, kitten, adult, k...         adult            adult                   True
# 21    019B                                            [adult]         adult            adult                   True
# 20    019A  [kitten, kitten, kitten, kitten, adult, adult,...         adult            adult                   True
# 19    018A                                     [adult, adult]         adult            adult                   True
# 17    015A  [adult, adult, adult, adult, adult, adult, sen...         adult            adult                   True
# 15    014A                             [kitten, adult, adult]         adult            adult                   True
# 14    013B  [adult, adult, adult, senior, kitten, kitten, ...         adult            adult                   True
# 13    012A                [adult, adult, adult, adult, adult]         adult            adult                   True
# 11    010A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 10    009A                       [adult, adult, adult, adult]         adult            adult                   True
# 9     008A         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 8     007A        [adult, adult, adult, adult, kitten, adult]         adult            adult                   True
# 7     006A                             [senior, adult, adult]         adult            adult                   True
# 6     005A  [adult, adult, adult, adult, senior, adult, se...         adult            adult                   True
# 5     004A                                            [adult]         adult            adult                   True
# 4     003A                     [kitten, kitten, adult, adult]         adult            adult                   True
# 3     002B  [kitten, adult, adult, senior, senior, senior,...         adult            adult                   True
# 2     002A  [adult, adult, kitten, adult, adult, adult, se...         adult            adult                   True
# 27    024A                                           [senior]        senior           senior                   True
# 23    021A         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 29    025B                                     [adult, adult]         adult            adult                   True
# 30    025C         [adult, adult, adult, adult, adult, adult]         adult            adult                   True
# 43    037A      [kitten, adult, senior, adult, adult, senior]         adult            adult                   True
# 42    036A  [senior, senior, adult, adult, adult, adult, a...         adult            adult                   True
# 41    035A                     [adult, senior, senior, adult]         adult            adult                   True
# 40    034A               [adult, adult, kitten, adult, adult]         adult            adult                   True
# 39    033A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 38    032A                                     [adult, adult]         adult            adult                   True
# 37    031A  [senior, adult, adult, adult, kitten, adult, s...         adult            adult                   True
# 36    029A  [senior, senior, adult, adult, senior, adult, ...         adult            adult                   True
# 35    028A  [adult, adult, adult, adult, adult, adult, adu...         adult            adult                   True
# 34    027A  [adult, adult, senior, senior, adult, senior, ...         adult            adult                   True
# 32    026B                                            [adult]         adult            adult                   True
# 33    026C                                            [adult]         adult            adult                   True
# 31    026A                       [adult, adult, adult, adult]         adult            adult                   True
# 109   117A  [senior, adult, senior, senior, adult, adult, ...        senior           senior                   True
# 88    093A                                     [adult, adult]         adult           senior                  False
# 89    094A  [adult, senior, adult, adult, adult, adult, ad...         adult           senior                  False
# 108   116A  [adult, senior, adult, senior, adult, adult, s...         adult           senior                  False
# 26    023B             [adult, adult, senior, senior, senior]        senior            adult                  False
# 75    069A                                   [senior, senior]        senior            adult                  False
# 69    063A  [kitten, senior, kitten, kitten, adult, senior...        kitten            adult                  False
# 52    047A  [adult, senior, kitten, adult, kitten, adult, ...         adult           kitten                  False
# 103   109A       [adult, adult, adult, adult, kitten, kitten]         adult           kitten                  False
# 102   108A      [adult, adult, senior, senior, senior, adult]         adult           senior                  False
# 101   106A  [adult, adult, adult, adult, adult, adult, kit...         adult           senior                  False
# 62    056A                              [adult, adult, adult]         adult           senior                  False
# 99    104A                       [adult, adult, adult, adult]         adult           senior                  False
# 67    061A                                     [adult, adult]         adult           senior                  False
# 85    090A                                            [adult]         adult           senior                  False
# 56    051A  [adult, adult, kitten, adult, adult, adult, ad...         adult           senior                  False
# 16    014B  [senior, adult, senior, kitten, senior, kitten...         adult           kitten                  False
# 64    058A                              [adult, adult, adult]         adult           senior                  False
# 12    011A                             [senior, adult, adult]         adult           senior                  False
# 82    076A                                           [kitten]        kitten            adult                  False
# 63    057A  [adult, adult, senior, senior, adult, senior, ...         adult           senior                  False
# 61    055A  [adult, adult, adult, senior, adult, senior, a...         adult           senior                  False
# 18    016A  [adult, adult, adult, adult, adult, adult, adu...         adult           senior                  False

# %%
# Create df for majority votes
majority_df = majority_votes.reset_index()
majority_df.columns = ['cat_id', 'Majority_Vote']

# Get actual groups for each cat_id
actual_groups = full_results.groupby('cat_id')['actual_age_group'].first().reset_index()

# Merge majority votes with actual groups
majority_with_actual = pd.merge(majority_df, actual_groups, on='cat_id')

# Add a column to check if the majority vote was correct
majority_with_actual['Majority_Correct'] = majority_with_actual['Majority_Vote'] == majority_with_actual['actual_age_group']

# Count correct majority votes per class
correct_majority_votes_per_class = majority_with_actual.groupby('actual_age_group')['Majority_Correct'].sum()

print("Correct Majority Votes per Class:")
print(correct_majority_votes_per_class)
# Out:
# Correct Majority Votes per Class:
# actual_age_group
# adult     69
# kitten    12
# senior     7
# Name: Majority_Correct, dtype: int64

# %%
# Calculate the total count and the number of correct predictions for each class
class_stats = majority_with_actual.groupby('actual_age_group').agg(
    total_count=('Majority_Correct', 'size'),  # Total number of cases per class
    correct_count=('Majority_Correct', 'sum')  # Sum of correct predictions per class
).reset_index()

# Calculate accuracy for each class
class_stats['accuracy'] = class_stats['correct_count'] / class_stats['total_count'] * 100

# store for final evaluation 
all_majority_vote_details.append(class_stats)

# Log detailed stats
print("Detailed Class Statistics for Majority Votes:")
print(class_stats)
# Out:
# Detailed Class Statistics for Majority Votes:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult           73             69  94.520548
# 1           kitten           15             12  80.000000
# 2           senior           22              7  31.818182

# %%
# Plot for Detailed Class Statistics for Majority Votes
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Accuracy of Majority Votes by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Detailed Class Statistics

# %%
# Calculate the total count and the number of correct predictions for each class
class_stats = full_results.groupby('actual_age_group').agg(
    total_count=('correct', 'size'),
    correct_count=('correct', 'sum')
).reset_index()

# Calculate accuracy for each class
class_stats['accuracy'] = class_stats['correct_count'] / class_stats['total_count'] * 100

# store for final evaluation 
all_class_stats.append(class_stats)

# Log the detailed stats
print("Detailed Class Statistics:")
print(class_stats)
# Out:
# Detailed Class Statistics:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult          568            427  75.176056
# 1           kitten          123             80  65.040650
# 2           senior          186             66  35.483871

# %%
# Plot for Detailed Class Statistics (Overall)
styled_barplot(class_stats, 'actual_age_group', 'accuracy', 
               'Overall Accuracy by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Gender Exploration

# %%
# Group by gender and calculate the total count, correct predictions, and accuracy
gender_stats = full_results.groupby('all_gender').agg(
    count=('cat_id', 'size'),  # Total number of cases per gender
    correct=('correct', 'sum')  # Sum of correct predictions per gender
).reset_index()

# Calculate accuracy for each gender
gender_stats['accuracy'] = (gender_stats['correct'] / gender_stats['count'] * 100).round(2)

# Display the DataFrame
print("Accuracy by Gender:")
print(gender_stats)

# store for final evaluation 
all_gender_stats.append(gender_stats)
# Out:
# Accuracy by Gender:
#   all_gender  count  correct  accuracy
# 0          F    218      135     61.93
# 1          M    357      250     70.03
# 2          X    302      188     62.25

# %%
# Plot for Accuracy by Gender
styled_barplot(gender_stats, 'all_gender', 'accuracy', 
               'Accuracy by Gender', 
               'Gender', 'Accuracy (%)')

# %% [markdown]
# ### Log current total CV Stats

# %%
print("Total Majority Vote Accuracy so far:", all_majority_vote_accuracies)
print("Total Class Statistics so far:\n", all_class_stats) 
print("Total Majority Vote Statistics so far:\n", all_majority_vote_details) 
print("Total Gender Accuracy so far:\n", all_gender_stats)
# Out:
# Total Majority Vote Accuracy so far: [0.7454545454545455, 0.7363636363636363, 0.7727272727272727, 0.7090909090909091, 0.8]
# Total Class Statistics so far:
#  [  actual_age_group  total_count  correct_count   accuracy
# 0            adult          573            444  77.486911
# 1           kitten          111             64  57.657658
# 2           senior          186             59  31.720430,   actual_age_group  total_count  correct_count   accuracy
# 0            adult          568            404  71.126761
# 1           kitten          120             56  46.666667
# 2           senior          186             60  32.258065,   actual_age_group  total_count  correct_count   accuracy
# 0            adult          574            436  75.958188
# 1           kitten          117             62  52.991453
# 2           senior          186             58  31.182796,   actual_age_group  total_count  correct_count   accuracy
# 0            adult          584            443  75.856164
# 1           kitten          115             57  49.565217
# 2           senior          186             69  37.096774,   actual_age_group  total_count  correct_count   accuracy
# 0            adult          568            427  75.176056
# 1           kitten          123             80  65.040650
# 2           senior          186             66  35.483871]
# Total Majority Vote Statistics so far:
#  [  actual_age_group  total_count  correct_count   accuracy
# 0            adult           73             67  91.780822
# 1           kitten           15             12  80.000000
# 2           senior           22              3  13.636364,   actual_age_group  total_count  correct_count   accuracy
# 0            adult           73             69  94.520548
# 1           kitten           15             10  66.666667
# 2           senior           22              2   9.090909,   actual_age_group  total_count  correct_count   accuracy
# 0            adult           73             67  91.780822
# 1           kitten           15             12  80.000000
# 2           senior           22              6  27.272727,   actual_age_group  total_count  correct_count   accuracy
# 0            adult           73             64  87.671233
# 1           kitten           15              9  60.000000
# 2           senior           22              5  22.727273,   actual_age_group  total_count  correct_count   accuracy
# 0            adult           73             69  94.520548
# 1           kitten           15             12  80.000000
# 2           senior           22              7  31.818182]
# Total Gender Accuracy so far:
#  [  all_gender  count  correct  accuracy
# 0          F    218      128     58.72
# 1          M    362      263     72.65
# 2          X    290      176     60.69,   all_gender  count  correct  accuracy
# 0          F    218      119     54.59
# 1          M    357      246     68.91
# 2          X    299      155     51.84,   all_gender  count  correct  accuracy
# 0          F    225      136     60.44
# 1          M    356      260     73.03
# 2          X    296      160     54.05,   all_gender  count  correct  accuracy
# 0          F    218      131     60.09
# 1          M    373      279     74.80
# 2          X    294      159     54.08,   all_gender  count  correct  accuracy
# 0          F    218      135     61.93
# 1          M    357      250     70.03
# 2          X    302      188     62.25]

# %% [markdown]
# # --------------

# %% [markdown]
# # Total Final Results & Analysis

# %%
# Count unique cat_id per age group 
unique_cats_per_age_group = dataframe.groupby('age_group')['cat_id'].nunique()

# Display the counts
print("Unique cat_id counts in original dataframe:", unique_cats_per_age_group)
# Out:
# Unique cat_id counts in original dataframe: age_group
# adult     74
# kitten    16
# senior    22
# Name: cat_id, dtype: int64

# %% [markdown]
# ## Metrics

# %%
# Calculate overall metrics
overall_avg_loss = np.mean(all_losses)
overall_avg_acc = np.mean(all_accuracies)
overall_avg_precision = np.mean(all_precisions)
overall_avg_recall = np.mean(all_recalls)
overall_avg_f1 = np.mean(all_f1)

print("Overall Average Metrics:")
print("Loss:", overall_avg_loss)
print("Accuracy:", overall_avg_acc)
print("Precision:", overall_avg_precision)
print("Recall:", overall_avg_recall)
print("F1 Score:", overall_avg_f1)
# Out:
# Overall Average Metrics:
# Loss: 3.6064909398555756
# Accuracy: 0.6342840701341629
# Precision: 0.5425219462522939
# Recall: 0.5761666593864717
# F1 Score: 0.5334701575486611

# %% [markdown]
# ## Majority Votes

# %%
# Average of majority vote accuracies
average_majority_vote_accuracy = np.mean(all_majority_vote_accuracies)
print("Average Majority Vote Accuracy:", average_majority_vote_accuracy)
# Out:
# Average Majority Vote Accuracy: 0.7527272727272727

# %%
# Concatenate all class stats DataFrames and calculate the mean of accuracies
total_majority_vote_details = pd.concat(all_majority_vote_details)
average_majority_vote_details = total_majority_vote_details.groupby('actual_age_group').agg({
    'total_count': 'sum', 
    'correct_count': 'sum' 
}).reset_index()
average_majority_vote_details['accuracy'] = (average_majority_vote_details['correct_count'] / average_majority_vote_details['total_count']) * 100

print("Average Class Statistics:")
print(average_majority_vote_details)
# Out:
# Average Class Statistics:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult          365            336  92.054795
# 1           kitten           75             55  73.333333
# 2           senior          110             23  20.909091

# %%
# Plot for Detailed Class Statistics for Majority Votes
styled_barplot(average_majority_vote_details, 'actual_age_group', 'accuracy', 
               'Accuracy of Majority Votes by Age Group', 
               'Age Group', 'Accuracy (%)')

# %% [markdown]
# ## Detailed Class Statistics

# %%
# Concatenate all class stats DataFrames and calculate the mean of accuracies
total_class_stats = pd.concat(all_class_stats)
average_class_stats = total_class_stats.groupby('actual_age_group').agg({
    'total_count': 'sum',  
    'correct_count': 'sum' 
}).reset_index()
average_class_stats['accuracy'] = (average_class_stats['correct_count'] / average_class_stats['total_count']) * 100

print("Average Class Statistics:")
print(average_class_stats)
# Out:
# Average Class Statistics:
#   actual_age_group  total_count  correct_count   accuracy
# 0            adult         2867           2154  75.130799
# 1           kitten          586            319  54.436860
# 2           senior          930            312  33.548387

# %%
# Plot for Detailed Class Statistics (Overall)
styled_barplot(average_class_stats, 'actual_age_group', 'accuracy', 
               'Overall Accuracy by Age Group', 
               'Age Group', 'Accuracy (%)')

# %%
# Concatenate all gender stats DataFrames and calculate the mean of accuracies
total_gender_stats = pd.concat(all_gender_stats)
average_gender_stats = total_gender_stats.groupby('all_gender').agg({
    'count': 'sum',  
    'correct': 'sum'  
}).reset_index()
average_gender_stats['accuracy'] = (average_gender_stats['correct'] / average_gender_stats['count']) * 100

print("Average Gender Accuracy:")
print(average_gender_stats)
# Out:
# Average Gender Accuracy:
#   all_gender  count  correct   accuracy
# 0          F   1097      649  59.161349
# 1          M   1805     1298  71.911357
# 2          X   1481      838  56.583390

# %%
# Plot for Accuracy by Gender
styled_barplot(total_gender_stats, 'all_gender', 'accuracy', 
               'Accuracy by Gender', 
               'Gender', 'Accuracy (%)')

# %% [markdown]
# # Visualisations

# %%
# Plotting all metrics
metrics_across_seeds = plot_all_metrics(all_losses, all_accuracies, all_precisions, all_recalls, all_f1, "Seeds", "Seed Number")

# %%
# Calculate the standard deviation for each metric
std_loss = np.std(all_losses)
std_accuracy = np.std(all_accuracies)
std_precision = np.std(all_precisions)
std_recall = np.std(all_recalls)
std_f1 = np.std(all_f1)

print("Standard Deviations:")
print(f"Loss: {std_loss}")
print(f"Accuracy: {std_accuracy}")
print(f"Precision: {std_precision}")
print(f"Recall: {std_recall}")
print(f"F1 Score: {std_f1}")
# Out:
# Standard Deviations:
# Loss: 0.63657018151139
# Accuracy: 0.018458983727384578
# Precision: 0.02671441097533548
# Recall: 0.04380846222996314
# F1 Score: 0.025322220149965383

# %%
# Calculate the interquartile range for each metric
iqr_loss = np.percentile(all_losses, 75) - np.percentile(all_losses, 25)
iqr_accuracy = np.percentile(all_accuracies, 75) - np.percentile(all_accuracies, 25)
iqr_precision = np.percentile(all_precisions, 75) - np.percentile(all_precisions, 25)
iqr_recall = np.percentile(all_recalls, 75) - np.percentile(all_recalls, 25)
iqr_f1 = np.percentile(all_f1, 75) - np.percentile(all_f1, 25)

print("Interquartile Ranges:")
print(f"Loss: {iqr_loss}")
print(f"Accuracy: {iqr_accuracy}")
print(f"Precision: {iqr_precision}")
print(f"Recall: {iqr_recall}")
print(f"F1 Score: {iqr_f1}")
# Out:
# Interquartile Ranges:
# Loss: 0.4151013493537903
# Accuracy: 0.008205041289329529
# Precision: 0.017670971068836305
# Recall: 0.06824218584615516
# F1 Score: 0.018222986930502283

# %% [markdown]
# ## Display the seed folds results together

# %%
# Create a figure with subplots
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(18, 12))  

# Flatten the axes array for easier indexing
axes = axes.flatten()

def plot_metrics_on_axes(ax, losses, accuracies, precisions, recalls, f1, title):
    ax.plot(range(1, len(losses)+1), losses, marker='o', color='blue', label='Loss')
    ax.plot(range(1, len(accuracies)+1), accuracies, marker='o', color='green', label='Accuracy')
    ax.plot(range(1, len(precisions)+1), precisions, marker='o', color='red', label='Precision')
    ax.plot(range(1, len(recalls)+1), recalls, marker='o', color='purple', label='Recall')
    ax.plot(range(1, len(f1)+1), f1, marker='o', color='orange', label='F1 Score')
    ax.set_xticks([1, 2, 3, 4])  # Set x-axis ticks to full integers
    ax.set_title(title)
    ax.set_xlabel('Fold Number')
    ax.set_ylabel('Metric Value')
    ax.legend()
    ax.grid(True)

# Plot onto each axes object
plot_metrics_on_axes(axes[0], *seed_1_folds_values, "Seed 1 Metrics")
plot_metrics_on_axes(axes[1], *seed_2_folds_values, "Seed 2 Metrics")
plot_metrics_on_axes(axes[2], *seed_3_folds_values, "Seed 3 Metrics")
plot_metrics_on_axes(axes[3], *seed_4_folds_values, "Seed 4 Metrics")
plot_metrics_on_axes(axes[4], *seed_5_folds_values, "Seed 5 Metrics")

# Hide the unused subplot 
for ax in axes[5:]:
    ax.set_visible(False)

# Adjust layout
plt.tight_layout()
plt.show()
